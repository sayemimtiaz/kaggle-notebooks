# %%
import numpy as np 
import pandas as pd 
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
data=pd.read_csv('/kaggle/input/students-performance-in-exams/StudentsPerformance.csv')
data.head()

# %%
data['math score'][2] #this code give the information of the second index in the math score column

# %%
data.loc[2,'reading score'] #we gain with this code the information of the second row in reading score column

# %%
data[['math score','reading score']] #we can select two columns

# %%
#slicing data frame

# %%
print(type(data["math score"])) #if the column name is inside one square brackets, data type is a serie
print(type(data[["math score"]])) #if the column name is inside two square brackets , data type is a data frame

# %%
#we can slicing dataframe from any index value to each other index value 
data.loc[2:5, 'math score':'writing score']

# %%
data.loc[2:7, 'test preparation course':]

# %%
#filtering data frames

# %%
data = data.rename(columns={'math score': 'math'})
boolean=data.math>70 
boolean_2=data.gender=='female'
data[boolean&boolean_2]

# %%
data.gender[data.math>70]

# %%
#transforming data
#we can apply all values in the columns by defining new def

# %%
def div (n):
    return n/2
data.math.apply(div)

# %%
data.math.apply(lambda n:n/2)

# %%
data= data.rename(columns={'reading score' : 'reading'})
data=data.rename(columns={'writing score' : 'writing'})

data['scoremean']=(data.math+data.reading+data.writing)/3
data.head()
