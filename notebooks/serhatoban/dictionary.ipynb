# %%
# we will learn about data which pokemon- challenge or another. 
#before we need to upload numpy, padas, matplotlib and seaborn library

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns  # visualization tool

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

import os
for dirname, _, filenames in os.walk("/kaggle/input"):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Any results you write to the current directory are saved as output.

# %%
#then we copy the path of the file  named pokemon-challenge from the data part
#the path of the file named pokemon challenge is ../input/pokemon-challenge
#so the file is promoted to pandas library 
#dont forget press ctrl and enter

data =pd.read_csv('../input/pokemon.csv')

# %%
#why do we use dictionary on phyton?
#because it is a structure that can contain keys and values
#and a dictionary faster than a list
#it has a form like dictionary [a:b]
#a is a key and b is a value in this form

# %%
dictionary = {'serhat': 'fizik','ahmet': 'matematik'}
print(dictionary.keys())
print(dictionary.values())

# %%
#now ı want to replace physics value on the serhat key with chemistry value
#thus we can uptade dictionary keys or values

# %%
dictionary['serhat']= "chemistry"
print(dictionary)

# %%
#ı can add new data to dictionary

# %%
dictionary['Ayşe']="Biology"
print(dictionary)

# %%
#we can remove a entry by use a key

# %%
del dictionary['Ayşe']
print(dictionary)

# %%
#we can control whether there is any value in dictionary

# %%
print('serhat' in dictionary)

# %%
#we can clear keys and values in dictionary 
#phyton show null cluster mark

# %%
dictionary.clear()
print(dictionary)

# %%
#we can search for other dictionary method
