# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv(os.path.join('/kaggle/input/titanic', 'train_and_test2.csv'))

# %%
data.info(0)

# %%
data.head()

# %%
data['2urvived'].value_counts(normalize=True)

# %%
sns.countplot(data['2urvived'])

# %%
data['2urvived'].groupby(data['Pclass']).mean()

# %%
sns.countplot(data['Pclass'], hue=data['2urvived'])

# %%
data['Sex'].value_counts(normalize=True)

# %%
data['2urvived'].groupby(data['Sex']).mean()

# %%
data['Embarked'].fillna(data['Embarked'].mean(), inplace = True)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(criterion='gini', 
                             n_estimators=700,
                             min_samples_split=10,
                             min_samples_leaf=1,
                             max_features='auto',
                             oob_score=True,
                             random_state=1,
                             n_jobs=-1)
rf.fit(data.iloc[:, 1:26], data.iloc[:, 27])
print("%.4f" % rf.oob_score_)
# data.iloc[:, 1:26].info()
# data.iloc[:, 27:].info()

# %%
pd.concat((pd.DataFrame(data.iloc[:, 1:].columns, columns = ['variable']), 
           pd.DataFrame(rf.feature_importances_, columns = ['importance'])), 
          axis = 1).sort_values(by='importance', ascending = False)[:20]
