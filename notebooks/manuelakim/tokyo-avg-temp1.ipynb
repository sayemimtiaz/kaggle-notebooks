# %% [markdown]
# This is the code for the selection of the particular city, in a specified country and in a given Region.

# %%
SELECT 
*
FROM poised-team-310601.city_tempertures.city_temperature
WHERE 
Region= "Asia" AND Country= "Japan" AND City='Tokyo'

# %% [markdown]
# This is what it looks like
