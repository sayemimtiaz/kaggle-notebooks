# %% [markdown]
# <img src="https://raw.githubusercontent.com/23subbhashit/StoryTellar/830831f6ede2190853c69998c72abb967d085b04/Welcome%20to%20Vectr%20(2).svg"/>
#
# Hi , i am the creater of this python module and will be showing some functionalities of it here.

# %%
# !pip install --upgrade storyscience

# %%
import storyscience
storyscience.shree()

# %%
import numpy as np 
import pandas as pd
a=pd.read_csv("/kaggle/input/retaildataset/sales data-set.csv")
fea=pd.read_csv("/kaggle/input/retaildataset/stores data-set.csv")
abc=pd.read_csv("/kaggle/input/retaildataset/Features data set.csv")

# %%
a.head()

# %%
#<-----Count----->
#<-----Subbhashit----->
import storyscience as ss
ss.count(a['IsHoliday'])

# %%
#<-----Impute----->
#<-----Subbhashit----->
a.iloc[0,1]=np.nan
b=ss.impute(a['Dept'])
print("b------>",b[:5])

# %%
#<-----Zscore----->
#<-----Subbhashit----->
b=ss.zscore(a['Weekly_Sales'],15981.258123467243)
print(b[:5])

# %%
#<-----SinglePlOT----->
#<-----Subbhashit----->
import warnings
warnings.filterwarnings("ignore")
ss.singleplot(a['Dept'])

# %%
# <-----IQR----->
# <-----Subbhashit----->
rangeIQR = ss.iqr(a['Store'])
rangeIQR

# %%
#<-----Describe----->
#<-----Subbhashit----->
df=ss.describe(abc)
df.head(10)

# %%
data=pd.read_csv("/kaggle/input/fifa-19-player-dataset/FIFA19.csv")
data.head()

# %%
ss.chloropleth(data.Nationality,'Number of players from each country',"NO. of players")

# %%
data=pd.read_json("../input/news-headlines-dataset-for-sarcasm-detection/Sarcasm_Headlines_Dataset_v2.json",lines=True)
data.head()

# %%
data.headline=data.headline.apply(ss.process_text)

# %%
data.head()

# %%
data['headline']=data['headline'].apply(ss.text_to_dict)

# %%
data.head()

# %%
a1=list(data['headline'])
#ss.count(data['headline'])
a1=a1[1000:1500]

# %%
a=ss.similarity_matrix(a1)

# %%
a2=pd.DataFrame(a)

# %%
a2.head()

# %%
import pandas as pd
a=pd.read_csv("/kaggle/input/retaildataset/sales data-set.csv")
a.head()

# %%
import storyscience as ss
ss.catvscatplot(a['Dept'][:100000],a['Store'][:100000])

# %%
ss.catvsnumericalplot(a[:1000],'Dept',"Weekly_Sales")

# %%
ss.numvsnumplot(a['Weekly_Sales'][:1000],a['Weekly_Sales'][:1000])

# %%
import numpy as np
import pandas as pd
data=pd.read_csv("../input/stock-price-predictions/Apple.csv",
                 index_col="Price Date",
                 parse_dates=["Price Date"])

# %%
ss.time_series_plot(data,'2016','2016','Apple stock price',"Modal Price (Rs./Quintal)")

# %%
data= pd.read_csv('../input/pandas-bokeh/long_data_.csv')
data.head()

# %%
ss.wordarraycloud(data['States'])
