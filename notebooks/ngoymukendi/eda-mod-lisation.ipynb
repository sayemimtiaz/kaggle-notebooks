# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
pd.set_option('display.max_row',111)
pd.set_option('display.max_column',111)

# %%
data = pd.read_csv('../input/credit-card-customers/BankChurners.csv')

# %%
data.head(5)

# %%
#------------------------------------------------------ ANALYSE DE FORME ---------------------------------------------------------------------------------------------------

# %%
df = data.copy()

# %%
print(df.columns)

# %%
# Identification de notre Target

# %%
# Notre Target est : Attrition_Flag

# %%
# Identifier quels types des variables

# %%
print(df.dtypes)

# %%
# Analyser des valeurs manquantes

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.isna(),cbar=False)

# %%
# Pourcentage des valeurs manquantes

# %%
print((df.isna().sum()/df.shape[0]).sort_values(ascending= True))

# %%
# Pour ce qui est de valeurs manquantes : Il ya zéro pourcent

# %%
# -------------------------------------------------- ANALYSE DE FOND ------------------------------------------------------------------------------------------------------

# %%
# Elimination des colonnes inutiles

# %%
df = df.drop('Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',axis=1)
df = df.drop('Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2',axis = 1)
df = df.drop('CLIENTNUM',axis=1)

# %%
# ------------------------------------------ Etude de rélation Univarié de differentes variables --------------------------------------------------------------------------

# %%
sns.set()

from subprocess import check_output
import warnings

warnings.filterwarnings('ignore')

def annot_plot(ax,w,h):                                    # function to add data to plot
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    for p in ax.patches:
         ax.annotate(f"{p.get_height() * 100 / df.shape[0]:.2f}%", (p.get_x() + p.get_width() / 2., p.get_height()),
         ha='center', va='center', fontsize=11, color='black', rotation=0, xytext=(0, 10),
         textcoords='offset points')             
def annot_plot_num(ax,w,h):                                    # function to add data to plot
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    for p in ax.patches:
        ax.annotate('{0:.1f}'.format(p.get_height()), (p.get_x()+w, p.get_height()+h))

import os

# %%
#----------------------------------------- Variable qualitative ------------------------------------------------------------

# %%
# Variable Customer_Age:

# %%
plt.hist(df['Customer_Age'])

# %%
df['Customer_Age'].describe()

# %%
# Donc la moyenne d'age est : 46 ans,le plus jeune a : 26 ans et le plus vieu a 73 ans

# %%
# Variable Attrition_Flag : 
ax = sns.countplot('Attrition_Flag',data=df)
plt.ylabel('Total')
annot_plot(ax,1,3)
plt.show()

# %%
# Donc après analyse on voit vite que 83.93% de nos clients sont restant et 16.07% sont partant

# %%
# Variable Gender : 
ax = sns.countplot('Gender',data=df)
plt.ylabel('Total')
annot_plot(ax,1,3)
plt.show()

# %%
# Il ya 52.91% des femmes et  47.09% des hommes

# %%
ax = sns.countplot('Marital_Status',data=df)
plt.ylabel('Total')
annot_plot(ax,0.8,1)
plt.show()

# %%
ax = sns.countplot('Education_Level',data=df)
plt.ylabel('Total')
annot_plot(ax,1,3)
plt.show()

# %%
ax = sns.countplot('Card_Category',data=df)
plt.ylabel('Total')
annot_plot(ax,0.8,1)
plt.show()

# %%
ax = sns.countplot('Income_Category',data=df)
plt.ylabel('Total')
annot_plot(ax,0.8,1)
plt.show()

# %%
#------------------------------------- Variable quantitative --------------------------------------------------------------

# %%
# Total_Amt_Chng_Q4_Q1
# représente combien le client a augmenté les nombres de transaction en comparant le 4e trimestre avec le 1er.

# %%
sns.distplot(df['Total_Amt_Chng_Q4_Q1'])

# %%
effectif = df['Total_Amt_Chng_Q4_Q1'].value_counts()
modalite = effectif.index
tab = pd.DataFrame(modalite,columns = ["Total_Amt_Chng_Q4_Q1"])
tab['n'] = effectif.values
tab['f'] = tab['n']/len(df)
tab['F'] = tab['f'].cumsum()

# %%
tab

# %%
sns.distplot(df['Total_Trans_Amt'])
effectif = df['Total_Trans_Amt'].value_counts()
modalite = effectif.index
tab = pd.DataFrame(modalite,columns = ["Total_Trans_Amt"])
tab['n'] = effectif.values
tab['f'] = tab['n']/len(df)
tab['F'] = tab['f'].cumsum()
tab

# %%
sns.distplot(df['Total_Trans_Ct'])

# %%
sns.distplot(df['Dependent_count'])
effectif = df['Dependent_count'].value_counts()
modalite = effectif.index
tab = pd.DataFrame(modalite,columns = ["Dependent_count"])
tab['n'] = effectif.values
tab['f'] = tab['n']/len(df)
tab['F'] = tab['f'].cumsum()

# %%
tab

# %%
#--------------------------------------------------- Mésure de tendance central --------------------------------------------

# %%
for col in df.select_dtypes('int64'):
    print("moyenne de ",col,"\n :" ,df[col].mean())
    print("médianne  de ",col,"\n", df[col].median())
    print("mode de ",col,"\n",df[col].mode())
    print("var de ",col,"\n",df[col].var(ddof=0))
    print("ect de ",col,"\n",df[col].std(ddof=0))
    plt.figure()
    plt.hist(df[col])
    plt.show()

# %% [markdown]
# # 1. * Analyse bi-varieés****

# %%
# Rélation entre deux variables qualitatives :

# %%
# Entre Attrition_Flag et Gender

# %%
ax = sns.countplot('Attrition_Flag',hue='Gender',data=df)
plt.ylabel('Total')
annot_plot(ax,0.8,1)
plt.show()

# %%
# Entre Attrition_Flag et Card_Categoy
ax = sns.countplot('Attrition_Flag',hue='Card_Category',data=df)
plt.ylabel('Total')
annot_plot(ax,0.8,1)
plt.show()

# %%
# Entre Attrition_Flag et Income_Category
ax = sns.countplot('Attrition_Flag',hue='Income_Category',data=df)
plt.ylabel('Total')
annot_plot(ax,0.8,1)
plt.show()

# %%
ax = sns.countplot('Attrition_Flag',hue='Education_Level',data=df)
plt.ylabel('Total')
annot_plot(ax,0.8,1)
plt.show()

# %%
ax = sns.countplot('Attrition_Flag',hue='Dependent_count',data=df)
plt.ylabel('Total')
annot_plot(ax,0.8,1)
plt.show()

# %%
ax = sns.countplot('Attrition_Flag',hue='Marital_Status',data=df)
plt.ylabel('Total')
annot_plot(ax,0.8,1)
plt.show()

# %%
# Rélation entre Card_Category et Income_Category
# Est ce que le fais de possede une categorie de carte à l'effet sur notre revenus?
ax = sns.countplot('Card_Category',hue='Income_Category',data=df)
plt.ylabel('Total')
annot_plot(ax,0.8,1)
plt.show()

# %%
ax = sns.countplot('Card_Category',hue='Gender',data=df)
plt.ylabel('Total')
annot_plot(ax,0.8,1)
plt.show()

# %%
# Création du tableau de contingence

# %%
X = "Card_Category"
Y = "Gender"
cont = df[[X,Y]].pivot_table(index=X,columns=Y,aggfunc=len,margins=True,margins_name="Total")
cont

# %%
X = "Card_Category"
Y = "Income_Category"
cont = df[[X,Y]].pivot_table(index=X,columns=Y,aggfunc=len,margins=True,margins_name="Total")
cont

# %%
X = "Marital_Status"
Y = "Education_Level"
cont = df[[X,Y]].pivot_table(index=X,columns=Y,aggfunc=len,margins=True,margins_name="Total")
cont

# %%
X = "Card_Category"
Y = "Attrition_Flag"
cont = df[[X,Y]].pivot_table(index=X,columns=Y,aggfunc=len,margins=True,margins_name="Total")
cont

# %%
#------------------------------------------------------------- Rélation entre deux variables quantitatives ----------------------------------------------------------------

# %%
# Analysez corrélative entre deux variables quantitatives

# %%
import scipy.stats as st
import numpy as np

print(st.pearsonr(df["Total_Trans_Amt"],df['Total_Trans_Ct'])[0])
print(np.cov(df["Total_Trans_Amt"],df['Total_Trans_Ct'],ddof=0)[1,0])

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr())

# %%
# Donc il  n'as pas vraiment de corrélation entre variable sauf la variable Total_Trans_Amt et Total_Trans_Ct qui ont une coéfficient de corrélation de 0.80

# %%
plt.figure(figsize=(90,60))
sns.relplot(x='Total_Ct_Chng_Q4_Q1',y='Total_Amt_Chng_Q4_Q1',data=df)
plt.show()

# %%
plt.figure(figsize=(90,60))
sns.relplot(x='Total_Ct_Chng_Q4_Q1',y='Total_Amt_Chng_Q4_Q1',hue='Attrition_Flag',data=df)
plt.show()

# %%
#Months_on_book
plt.figure(figsize=(10,8))
sns.distplot(df['Months_on_book'],kde=True,color='y')
plt.show()

# %%
#Total_Ct_Chng_Q4_Q1
plt.figure(figsize=(10,8))
sns.distplot(df['Total_Ct_Chng_Q4_Q1'],kde=True,color='b')
plt.show()

# %%
#Total_Amt_Chng_Q4_Q1
plt.figure(figsize=(10,8))
sns.distplot(df['Total_Amt_Chng_Q4_Q1'],kde=True,color='g')
plt.show()

# %%
#Credit_Limit
plt.figure(figsize=(10,8))
sns.distplot(df['Credit_Limit'],kde=True,color='b')
plt.show()

# %%
#Total_Trans_amt
plt.figure(figsize=(10,8))
sns.distplot(df['Total_Trans_Amt'],kde=True,color='y')
plt.show()

# %%
#Avg_Open_To_Buy
plt.figure(figsize=(10,8))
sns.distplot(df['Avg_Open_To_Buy'],kde=True,color='g')
plt.show()

# %%
#Total_Revolving_Bal
plt.figure(figsize=(10,8))
sns.distplot(df['Total_Revolving_Bal'],kde=True,color='b')
plt.show()

# %%
#Total_Relationship_Count
plt.figure(figsize=(10,8))
sns.distplot(df['Total_Relationship_Count'],kde=True,color='r')
plt.show()

# %%
#-------------------------------------------------------------  MODELISATION-----------------------------------------------------------------------------------------------

# %%
from sklearn.metrics import f1_score,confusion_matrix,classification_report
from sklearn.model_selection import learning_curve
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import SelectKBest,f_classif
from sklearn.decomposition import PCA
from sklearn.preprocessing import PolynomialFeatures,StandardScaler
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV

# %%
#----------------------------------------------  Encodade des variables ---------------------------------------------------

# %%
encoder  = LabelEncoder()

target = encoder.fit_transform(df['Attrition_Flag'])
sexe   = encoder.fit_transform(df['Gender'])
eduction = encoder.fit_transform(df['Education_Level'])
status   = encoder.fit_transform(df['Marital_Status'])
income   = encoder.fit_transform(df['Income_Category'])
card     = encoder.fit_transform(df['Card_Category'])

# %%
df['Attrition_Flag'] =target
df['Gender'] = sexe
df['Education_Level'] = eduction
df['Marital_Status']   = status
df['Income_Category'] = income
df['Card_Category'] = card

# %%
#-------------------------------------------- Inputation ------------------------------------------------------------------

# %%
def imputation(df):
    df = df.dropna(axis = 0)
    return df

# %%
data = imputation(df)

# %%
X = data.drop('Attrition_Flag',axis= 1)
y = data['Attrition_Flag']
X_train,X_test,y_train,y_test  = train_test_split(X,y,random_state = 0,train_size = 0.3)

# %%
# Transformer

# %%
scaler = StandardScaler()
X_train_transformer = scaler.fit_transform(X_train)

# %%
preprocessor = make_pipeline(PolynomialFeatures(2,include_bias = False),SelectKBest(f_classif,k=10))

RandomForest = make_pipeline(preprocessor,RandomForestClassifier(random_state = 0))
AdaBoost     = make_pipeline(preprocessor,AdaBoostClassifier(random_state = 0))
SVM          = make_pipeline(preprocessor,StandardScaler(),SVC(random_state = 0))
KNN          = make_pipeline(preprocessor,StandardScaler(),KNeighborsClassifier())

dict_of_models = {'RandomForest' : RandomForest,
                  'AdaBoost'     : AdaBoost,
                  'SVM'          : SVM,
                  'KNN'          : KNN}

# %%
#------------------------------------- Procédure d'évaluation -------------------------------------------------------------

# %%
def evaluation(model):
    
    model.fit(X_train,y_train)
    ypred = model.predict(X_test)
    
    print(confusion_matrix(y_test,ypred))
    print(classification_report(y_test,ypred))
    N,train_score,val_score = learning_curve(model,X_train,y_train,cv=4,
                                             scoring = 'f1',
                                             train_sizes = np.linspace(0.1,1,10))
    
    plt.figure(figsize = (12,8))
    #sns.heatmap(confusion_matrix(y_test,ypred),square = True,annot = True,cbar=False)
    plt.plot(N,val_score.mean(axis=1),label='validation score')
    plt.plot(N,train_score.mean(axis=1),label='train score')
    plt.legend()

# %%
model_1 = RandomForestClassifier(random_state=0)
model_2 = make_pipeline(PolynomialFeatures(2),SelectKBest(f_classif,k=10),
                       RandomForestClassifier(random_state = 0))

# %%
dict_list_model = {"RandomForest" : RandomForest,
                  "AdaBoost" : AdaBoost,
                  "SVM" : SVM,
                  "KNN" : KNN}

# %%
for name,model in dict_of_models.items() :
    print(name)
    evaluation(model)

# %%
#------------------------------------------ Optimisation ------------------------------------------------------------

# %%
hyper_params = {"svc__gamma" : [1e-3,1e-4],
                 "svc__C" : [1,10,100,1000],
                "pipeline__polynomialfeatures__degree" : [2,3,4],
               "pipeline__selectkbest__k" : range(40,60)}

# %%
grid = RandomizedSearchCV(SVM,hyper_params,scoring='precision',cv=7,n_iter = 40)
grid.fit(X_train,y_train)

# %%
print(grid.best_params_)

# %%
y_pred = grid.predict(X_test)

# %%
print(classification_report(y_test,y_pred))

# %%
#---------------------------------------- Precision Recall Curve -----------------------------------------------------------

# %%
from sklearn.metrics import precision_recall_curve

# %%
precision,recall,threshold = precision_recall_curve(y_test,grid.best_estimator_.decision_function(X_test))

# %%
plt.plot(threshold,precision[:-1],label = 'precision')
plt.plot(threshold,recall[:-1],label = 'recall')
plt.legend()

# %%
def model_final(model,X,threshold = 0):
    return model.decision_function(X) > threshold

# %%
y_pred = model_final(grid.best_estimator_,X_test,threshold = 0)

# %%
from sklearn.metrics import recall_score,precision_score

# %%
f1_score(y_test,y_pred)

# %%
recall_score(y_test,y_pred)

# %%
precision_score(y_test,y_pred)
