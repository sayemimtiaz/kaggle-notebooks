# %% [markdown]
# EDA- Indain FOOD
#
#      a) Vegeterian / Non-Vegetarian Diet over Flavours
#      b) Categorize Course
#      c) Course preference over Veg/Non-Veg
#      d) Course preference over Flavours
#      e) Veg/Non-Veg by Region
#      f) Course over Region
#      g) Flavours over Region
#      h) Top 10 State Interest towards flavours-Word cloud
#      i) State Interest towards Flavours
#      j) State Ineterst towards Course

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
fooddf=pd.read_csv('/kaggle/input/indian-food-101/indian_food.csv')

fooddf

# %%
fooddf.info()

# %%
fooddf['prep_time']=fooddf['prep_time'].replace(-1,np.nan)
fooddf['cook_time']=fooddf['cook_time'].replace(-1,np.nan)
fooddf['region']=fooddf['region'].replace('-1',np.nan)
fooddf['state']=fooddf['state'].replace('-1',np.nan)
fooddf['flavor_profile']=fooddf['flavor_profile'].replace('-1',np.nan)
fooddf.dropna()

# %% [markdown]
# a) **Distribution of Vegeterian / Non-Vegetarian Diet over Flavours :** Vegetarian foods takes lead over Non-Vegetarian and Preference of Flvaour Profile tends to be Spicy followed by Sweet,while Non-Vegetarin prefers Spicy over Bitter / Sour.

# %%
sns.countplot(x='diet',data=fooddf,hue='flavor_profile')

# %% [markdown]
#  Distribution by course

# %%
sns.countplot(x='course',data=fooddf)

# %% [markdown]
# Distribution by course over Veg/Non-Veg

# %%
sns.countplot(x='course',data=fooddf,hue="diet")

# %% [markdown]
#  Distribution by course over Flavours

# %%
sns.countplot(x='course',data=fooddf,hue='flavor_profile')

# %% [markdown]
# Distribution of Veg/Non-Veg by Region

# %%
sns.countplot(x='region',data=fooddf,hue='diet')

# %% [markdown]
# Distribution of course over Region

# %%
sns.countplot(x='region',data=fooddf,hue='course')

# %% [markdown]
# Distribution of Flavour over Region

# %%
sns.countplot(x='region',data=fooddf,hue='flavor_profile')

# %%
from subprocess import check_output
from wordcloud import WordCloud, STOPWORDS

#mpl.rcParams['figure.figsize']=(8.0,6.0)    #(6.0,4.0)
plt.rcParams['font.size']=12                #10 
plt.rcParams['savefig.dpi']=100             #72 
plt.rcParams['figure.subplot.bottom']=.1 


stopwords = set(STOPWORDS)

# %%
flavour=fooddf.groupby(['flavor_profile','state']).sum()
flavour.reset_index(inplace=True)

# %%
word_string=" ".join(flavour[flavour['flavor_profile']=='bitter']['state'])
wordcloud = WordCloud(stopwords=STOPWORDS,
                          background_color='white', 
                      max_words=300
                         ).generate(word_string)
plt.clf()
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
word_string=" ".join(flavour[flavour['flavor_profile']=='sweet']['state'].head(10))
wordcloud = WordCloud(stopwords=STOPWORDS,
                          background_color='white', 
                      max_words=300
                         ).generate(word_string)
plt.clf()
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
word_string=" ".join(flavour[flavour['flavor_profile']=='sour']['state'].head(10))
wordcloud = WordCloud(stopwords=STOPWORDS,
                          background_color='white', 
                      max_words=300
                         ).generate(word_string)
plt.clf()
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
word_string=" ".join(flavour[flavour['flavor_profile']=='spicy']['state'].head(10))
wordcloud = WordCloud(stopwords=STOPWORDS,
                          background_color='white', 
                      max_words=300
                         ).generate(word_string)
plt.clf()
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# One-Hot Encoding by Flavor_profile and Course to visualize categorgy of Flavour profile/course by states

# %%
categorical_cols = ['flavor_profile', 'course'] 
df = pd.get_dummies(fooddf, columns = categorical_cols)

# %%
d=df.groupby('state').sum()
d.reset_index(inplace=True)

# %%
sns.barplot(x="flavor_profile_sweet", y="state",data=d)

# %%
sns.barplot(x="flavor_profile_bitter", y="state",data=d)

# %%
sns.barplot(x="flavor_profile_spicy", y="state",data=d)

# %%
sns.barplot(x="flavor_profile_sour", y="state",data=d)

# %%
sns.barplot(x="course_dessert", y="state",data=d)

# %%
sns.barplot(x="course_snack", y="state",data=d)

# %%
sns.barplot(x="course_starter", y="state",data=d)

# %%
sns.barplot(x="course_main course", y="state",data=d)
