# %% [markdown]
# # Realitonship Between CO2 Emissions and Life Expectancy
#
# ## Objective
#
# In the next notebook you can find 2 datasets:
# * Emissions of CO2 by country.
# * Life expectancy and mortality causes by country for diferent years.
#
# We want to understand the data and finally know if there is a correlation between the emission of CO2 and the life expectancy in different countries.
#
# The questions we want to start answering are:
# * What is the average live expectancy globally?
# * Is there a difference of life expectancies in between Developed and Developing Countries?
# * What are the top 10 countries with lower life expectancy?
# * What are the top 10 countries with higher life expectancy?
# * What are the emission of the top 10 countries with higher life expectancy?
# * What are the emission of the top 10 countries with lower life expectancy?
# * What are the countires with the highest emissions since 1990?

# %%
#@title Install dependencies
# !pip install pandas

# %%
import pandas

# %%
emission_data = pandas.read_csv('../input/co2-and-ghg-emission-data/emission data.csv')
emission_data['Country'] = emission_data['Country'].str.strip()
emission_data.head()

# %%
life_expectancy_data = pandas.read_csv('../input/life-expectancy-who/Life Expectancy Data.csv')
life_expectancy_data.head()

# %%
countries = pandas.read_csv('../input/countries-of-the-world/countries of the world.csv')
countries['Country'] = countries['Country'].str.strip()
countries.head()
