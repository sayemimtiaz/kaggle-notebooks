# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv('../input/iris-flower-dataset/IRIS.csv')
iris.head()

# %%
iris.info()

# %%
iris.shape

# %%
iris.isna().sum()

# %%
iris.describe()

# %%
iris.species.unique()

# %%
column = iris.columns[:-1].tolist()
label = ['SEPAL LENGTH', 'SEPAL WIDTH', 'PETAL LENGTH', 'PETAL WIDTH']

# %% [markdown]
# ### 1. Line Plot
# ### 2. Scatter Plot
# ### 3. Regression Plot
# ### 4. Dist Plot
# ### 5. Hist Plot
# ### 6. KDE Plot
# ### 7. ECDF Plot
# ### 8. Strip Plot
# ### 9. Box Plot
# ### 10. Violin Plot
# ### 11. Swarm Plot
# ### 12. Joint Plot
# ### 13. Pair Plot
# ### 14. Count Plot
# ### 15. Point Plot
# ### 16. LM Plot
# ### 17. Bar Plot
# ### 18. Cat Plot
# ### 19. Rug Plot
# ### 20. Heatmap

# %% [markdown]
# ## 1. LINE PLOT

# %%
plt.figure(figsize=(10,5))
plt.title('Lineplot for iris data', fontsize=15)
sns.lineplot(data=iris, markers=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Lineplot for {}'.format(label[0]), fontsize=15)
plt.ylabel(label[0], fontsize=12)
sns.lineplot(x=iris.index, y=iris[column[0]])
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Lineplot for {}'.format(label[1]), fontsize=15)
plt.ylabel(label[1], fontsize=12)
sns.lineplot(iris.index, iris[column[1]], color='green')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Lineplot for {}'.format(label[2]), fontsize=15)
plt.ylabel(label[2], fontsize=12)
sns.lineplot(x=iris.index, y=iris[column[2]], color='red', marker= 'o')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Lineplot for {}'.format(label[3]), fontsize=15)
plt.ylabel(label[3], fontsize=12)
sns.lineplot(x=iris.index, y=iris[column[3]], marker= 's', hue=iris.species)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Lineplot - {} vs {}'.format(label[0], label[1]),
           fontsize=15)
plt.xlabel(label[0], fontsize=12)
plt.ylabel(label[1], fontsize=12)
sns.lineplot(x=column[0],
             y=column[1],
             color='green',
             marker='d',
             data=iris)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Lineplot - {} vs {} by Category'.format(label[2], label[3]),
           fontsize=15)
plt.xlabel(label[2], fontsize=12)
plt.ylabel(label[3], fontsize=12)
sns.lineplot(x=column[2],
             y=column[3],
             hue='species',
             marker='v',
             data=iris)
plt.show()

# %% [markdown]
# ## 2. SCATTER PLOT

# %%
plt.figure(figsize=(10,5))
plt.title('Scatterplot for iris data', fontsize=15)
sns.scatterplot(data=iris, s=100)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Scatterplot for {}'.format(label[0]), fontsize=15)
plt.ylabel(label[0], fontsize=12)
sns.scatterplot(x=iris.index, y=iris[column[0]])
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Scatterplot for {}'.format(label[1]), fontsize=15)
plt.ylabel(label[1], fontsize=12)
sns.scatterplot(iris.index, iris[column[1]], color='brown', s=150, marker='d')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Scatterplot for {}'.format(label[2]), fontsize=15)
plt.ylabel(label[2], fontsize=12)
sns.scatterplot(iris.index, iris[column[2]], color='green', marker='s', s=150, alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Scatterplot for {}'.format(label[3]), fontsize=15)
plt.ylabel(label[3], fontsize=12)
sns.scatterplot(iris.index, iris[column[3]], s=150, alpha=0.7, hue=iris.species)
plt.show()

# %% [markdown]
# ## 3. REGRESSION PLOT

# %%
plt.figure(figsize=(10,5))
plt.title('Regplot for {}'.format(label[0]), fontsize=15)
sns.regplot(iris.index, iris[column[0]])
plt.ylabel(label[0], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Regplot for {}'.format(label[1]), fontsize=15)
sns.regplot(iris.index, 
            iris[column[1]],
            color='green',
            marker='s')
plt.ylabel(label[1], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Regplot for {} vs {}'.format(label[2], label[3]), fontsize=15)
sns.regplot(iris[column[2]],iris[column[3]],
            color='orange', marker='d')
plt.xlabel(label[2], fontsize=12)
plt.ylabel(label[3], fontsize=12)
plt.show()

# %% [markdown]
# ## 4. DIST PLOT

# %%
plt.figure(figsize=(10,5))
plt.title('Distplot for IRIS Data', fontsize=15)
sns.distplot(iris.drop('species', axis=1))
plt.show()
# ------------- OR ---------------
plt.figure(figsize=(10,5))
sns.distplot(iris[column])
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Distplot for {}'.format(label[0]), fontsize=15)
sns.distplot(iris[column[0]])
plt.xlabel(label[0], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Distplot for {}'.format(label[1]), fontsize=15)
sns.distplot(iris[column[1]], color='green')
plt.xlabel(label[1], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Distplot for {}'.format(label[2]), fontsize=15)
sns.distplot(iris[column[2]], color='orange', vertical=True)
plt.ylabel(label[2], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Distplot for {}'.format(label[3]), fontsize=15)
sns.distplot(iris[column[3]], color='red', kde=False)
plt.xlabel(label[3], fontsize=12)
plt.show()

# %% [markdown]
# ## 5. HIST PLOT

# %%
plt.figure(figsize=(10,5))
plt.title('Histplot for IRIS Data', fontsize=15)
sns.histplot(iris)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Histplot for {}'.format(label[0]), fontsize=15)
plt.xlabel(label[0], fontsize=12)
sns.histplot(iris[column[0]])
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Histplot for {}'.format(label[1]), fontsize=15)
plt.xlabel(label[1], fontsize=12)
sns.histplot(iris[column[1]], color='green')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Histplot for {}'.format(label[2]), fontsize=15)
plt.xlabel(label[2], fontsize=12)
sns.histplot(iris[column[2]], color='red', bins=15)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Histplot for {}'.format(label[3]), fontsize=15)
plt.xlabel(label[3], fontsize=12)
sns.histplot(iris[column[3]], color='brown', fill=False)
plt.show()

# %% [markdown]
# ## 6. KDE PLOT

# %%
plt.figure(figsize=(10,5))
plt.title('KDEPLOT with Label', fontsize=15)
sns.kdeplot(data=iris)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('KDEPLOT - No Label', fontsize=15)
sns.kdeplot(data=iris, shade=True, legend=False)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('kdeplot for {}'.format(label[0]), fontsize=15)
plt.xlabel(label[0], fontsize=12)
sns.kdeplot(iris[column[0]])
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('kdeplot for {}'.format(label[1]), fontsize=15)
plt.xlabel(label[1], fontsize=12)
sns.kdeplot(iris[column[1]], color='brown')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('kdeplot for {}'.format(label[2]), fontsize=15)
plt.xlabel(label[2], fontsize=12)
sns.kdeplot(iris[column[2]], color='green', shade=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('kdeplot for {}'.format(label[3]), fontsize=15)
plt.xlabel(label[3], fontsize=12)
sns.kdeplot(iris[column[3]], color='red', shade=True, vertical=True)
plt.show()

# %% [markdown]
# ## 7. ECDF PLOT

# %%
plt.figure(figsize=(10,5))
plt.title('ECDF PLOT', fontsize=15)
sns.ecdfplot(data=iris)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('ecdfplot for {}'.format(label[0]), fontsize=15)
plt.xlabel(label[0], fontsize=12)
sns.ecdfplot(data=iris, x=column[0])
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('ecdfplot for {}'.format(label[1]), fontsize=15)
plt.xlabel(label[1], fontsize=12)
sns.ecdfplot(iris[column[1]], color='red')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('ecdfplot for {}'.format(label[2]), fontsize=15)
plt.ylabel(label[2], fontsize=12)
sns.ecdfplot(y=iris[column[2]], color='green')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('ecdfplot for {}'.format(label[3]), fontsize=15)
plt.xlabel(label[3], fontsize=12)
sns.ecdfplot(data=iris, x=column[3], hue='species')
plt.show()

# %% [markdown]
# ## 8. STRIP PLOT

# %%
plt.figure(figsize=(10,5))
plt.title('Stripplot for {}'.format(label[0]), fontsize=15)
sns.stripplot(iris.species, iris[column[0]])
plt.xlabel('SPECIES', fontsize=12)
plt.ylabel(label[0], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Stripplot for {}'.format(label[1]), fontsize=15)
sns.stripplot(iris.species, iris[column[1]], s=12, alpha=0.5)
plt.xlabel('SPECIES', fontsize=12)
plt.ylabel(label[1], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Stripplot for {}'.format(label[2]), fontsize=15)
sns.stripplot(iris[column[2]], iris.species, s=12, alpha=0.5)
plt.ylabel('SPECIES', fontsize=12)
plt.xlabel(label[2], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Stripplot for {}'.format(label[3]), fontsize=15)
sns.stripplot(iris.species, iris[column[3]], s=12, alpha=0.5, jitter=False)
plt.xlabel('SPECIES', fontsize=12)
plt.ylabel(label[3], fontsize=12)
plt.show()

# %% [markdown]
# ## 9. BOX PLOT

# %%
plt.figure(figsize=(10,5))
plt.title('Boxplot for IRIS data', fontsize=15)
sns.boxplot(data=iris)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Boxplot for IRIS data', fontsize=15)
sns.boxplot(data=iris, palette='Paired', orient='h')
plt.show()

# %%
plt.title('Boxplot for {}'.format(label[0]), fontsize=15)
sns.boxplot(column[0], data=iris)
plt.show()

# %%
plt.title('Boxplot for {}'.format(label[1]), fontsize=15)
sns.boxplot(y=column[1], data=iris, palette='Set1')
plt.show()

# %%
plt.title('Boxplot for {}'.format(label[2]), fontsize=15)
sns.boxplot(column[2], data=iris, palette='Set2', width=0.5)
plt.show()

# %%
plt.title('Boxplot for {}'.format(label[3]), fontsize=15)
sns.boxplot(column[3], data=iris, palette='Set3', notch=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Boxplot for {} by Category'.format(label[0]), fontsize=15)
sns.boxplot(x='species', y=column[0], data=iris)
plt.xlabel('SPECIES', fontsize=12)
plt.ylabel(label[0], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Boxplot for {} by Category'.format(label[1]), fontsize=15)
sns.boxplot(x='species', y=column[1], data=iris, palette='Set2')
plt.xlabel('SPECIES', fontsize=12)
plt.ylabel(label[1], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Boxplot for {} by Category'.format(label[2]), fontsize=15)
sns.boxplot(y='species', x=column[2], data=iris, palette='Set3')
plt.ylabel('SPECIES', fontsize=12)
plt.xlabel(label[2], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Boxplot for {} by Category'.format(label[3]), fontsize=15)
sns.boxplot(column[3], 'species', data=iris, palette='Paired', orient='h')
plt.ylabel('SPECIES', fontsize=12)
plt.xlabel(label[3], fontsize=12)
plt.show()

# %% [markdown]
# ## 10. VIOLIN PLOT

# %%
plt.figure(figsize=(10,5))
plt.title('Violinplot for IRIS data', fontsize=15)
sns.violinplot(data=iris)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Boxplot for {}'.format(label[0]), fontsize=15)
sns.violinplot('species', column[0], data=iris, palette='Blues')
plt.xlabel('SPECIES', fontsize=12)
plt.ylabel(label[0], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Boxplot for {}'.format(label[1]), fontsize=15)
sns.violinplot('species', column[1], data=iris, palette='Oranges', scale='count')
plt.xlabel('SPECIES', fontsize=12)
plt.ylabel(label[1], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Boxplot for {}'.format(label[2]), fontsize=15)
sns.violinplot('species', column[1], data=iris, palette='Greens', inner='quartile', bw=0.3)
plt.xlabel('SPECIES', fontsize=12)
plt.ylabel(label[1], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Boxplot for {}'.format(label[2]), fontsize=15)
sns.violinplot(column[1], 'species', data=iris, palette='Reds', inner='stick', cut=0, scale='width')
plt.ylabel('SPECIES', fontsize=12)
plt.xlabel(label[1], fontsize=12)
plt.show()

# %% [markdown]
# ## 11. SWARM PLOT

# %%
plt.figure(figsize=(10,5))
plt.title('Swarmplot for IRIS Data', fontsize=15)
sns.swarmplot(data=iris, s=10, alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Swarmplot for {}'.format(label[0]), fontsize=15)
sns.swarmplot(x=iris[column[0]], s=12)
plt.xlabel(label[0], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Swarmplot for {}'.format(label[1]), fontsize=15)
sns.swarmplot(y=iris[column[1]], s=12, color='green', alpha=0.7)
plt.ylabel(label[1], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Swarmplot for {}'.format(label[2]), fontsize=15)
sns.swarmplot(x=iris[column[2]], y=iris.species, s=12)
plt.xlabel(label[2], fontsize=12)
plt.ylabel('SPECIES', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Swarmplot for {}'.format(label[3]), fontsize=15)
sns.swarmplot(x='species', y=column[3], data=iris, s=12)
plt.xlabel('SPECIES', fontsize=12)
plt.ylabel(label[3], fontsize=12)
plt.show()

# %% [markdown]
# ## 12. JOINT PLOT

# %%
print('Jointplot for IRIS Data')
sns.jointplot(data=iris, s=100, alpha=0.5)
plt.show()

# %%
print('Jointplot for {}'.format(label[0]))
sns.jointplot(iris.index, iris[column[0]],kind='kde')
plt.show()

# %%
print('Jointplot for {}'.format(label[1]))
sns.jointplot(iris.index, iris[column[1]], kind='resid')
plt.show()

# %%
print('Jointplot for {}'.format(label[2]))
sns.jointplot(iris.index, iris[column[2]], kind='hex')
plt.show()

# %%
print('Jointplot for {}'.format(label[3]))
sns.jointplot(iris.index, iris[column[3]], kind='hist')
plt.show()

# %%
print('Jointplot for {} vs {}'.format(label[0],label[1]))
sns.jointplot(iris[column[0]], iris[column[1]], 
              kind='scatter', hue=iris.species,
              s=200, alpha=0.5)
plt.show()

# %%
print('Jointplot for {} vs {}'.format(label[2],label[3]))
sns.jointplot(iris[column[2]], iris[column[3]], 
              kind='kde', hue=iris.species)
plt.show()

# %% [markdown]
# ## 13. PAIR PLOT

# %%
sns.pairplot(data=iris)
plt.show()

# %%
sns.pairplot(data=iris, hue='species')
plt.show()

# %%
print('Pairplot for {} vs {}'.format(label[0], label[1]))
sns.pairplot(iris.drop([column[2], column[3]], axis=1), kind='reg')
plt.show()

# %%
print('Pairplot for {} vs {}'.format(label[2], label[3]))
sns.pairplot(iris.drop([column[0], column[1]], axis=1), kind='kde', hue='species')
plt.show()

# %% [markdown]
# ## 14. COUNT PLOT

# %%
plt.figure(figsize=(10,5))
plt.title('Countplot for IRIS Data', fontsize=15)
sns.countplot(data=iris)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Countplot for {}'.format(label[0]), fontsize=15)
sns.countplot(x=column[0], data=iris)
plt.xlabel(label[0], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Countplot for {} by Category'.format(label[0]), fontsize=15)
sns.countplot(x=column[0], data=iris, hue='species')
plt.xlabel(label[0], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Countplot for {}'.format(label[1]), fontsize=15)
sns.countplot(y=column[1], data=iris)
plt.ylabel(label[1], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Countplot for {}'.format(label[1]), fontsize=15)
sns.countplot(y=column[1], data=iris, hue='species')
plt.ylabel(label[1], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Countplot for {}'.format(label[2]), fontsize=15)
sns.countplot(x=column[2], data=iris, palette='Set1')
plt.xlabel(label[2], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Countplot for {}'.format(label[3]), fontsize=15)
sns.countplot(y=column[3], data=iris, palette='Set3')
plt.ylabel(label[3], fontsize=12)
plt.show()

# %% [markdown]
# ## 15. POINT PLOT

# %%
plt.figure(figsize=(10,5))
plt.title('Pointplot for IRIS Data', fontsize=15)
sns.pointplot(data=iris)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Pointplot for {} vs {} by Category'.format(label[0], label[1]), fontsize=15)
sns.pointplot(x=column[0], y=column[1], data=iris)
plt.xlabel(label[0], fontsize=12)
plt.ylabel(label[1], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Pointplot for {} vs {} by Category'.format(label[0], label[1]), fontsize=15)
sns.pointplot(x=column[0], y=column[1], data=iris, hue='species')
plt.xlabel(label[0], fontsize=12)
plt.ylabel(label[1], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Pointplot for {} vs {} by Category'.format(label[2], label[3]), fontsize=15)
sns.pointplot(x=column[2], y=column[3], data=iris, color='orange', join=False)
plt.xlabel(label[2], fontsize=12)
plt.ylabel(label[3], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Pointplot for {} vs {} by Category'.format(label[2], label[3]), fontsize=15)
sns.pointplot(x=column[2], y=column[3], data=iris, hue='species', palette='Set2')
plt.xlabel(label[2], fontsize=12)
plt.ylabel(label[3], fontsize=12)
plt.show()

# %% [markdown]
# ## 16. LM PLOT

# %%
sns.lmplot(x=column[0], y=column[1], data=iris)
plt.title('Lmplot for {} vs {}'.format(label[0], label[1]), fontsize=15)
plt.show()

sns.lmplot(x=column[2], y=column[3], data=iris)
plt.title('Lmplot for {} vs {}'.format(label[2], label[3]), fontsize=15)
plt.show()

# %%
sns.lmplot(x=column[0], y=column[1], data=iris, hue='species')
plt.title('Lmplot for {} vs {}'.format(label[0], label[1]), fontsize=15)
plt.show()

sns.lmplot(x=column[2], y=column[3], data=iris, hue='species')
plt.title('Lmplot for {} vs {}'.format(label[2], label[3]), fontsize=15)
plt.show()

# %%
sns.lmplot(x=column[0], y=column[1], data=iris, hue='species', 
           palette='Set1', markers=['o','d','x'])
plt.title('Lmplot for {} vs {}'.format(label[0], label[1]), fontsize=15)
plt.show()

sns.lmplot(x=column[2], y=column[3], data=iris, hue='species', 
           palette='Set1', markers=['o','d','x'])
plt.title('Lmplot for {} vs {}'.format(label[2], label[3]), fontsize=15)
plt.show()

# %%
sns.lmplot(x=column[0], y=column[1], data=iris, col='species')
plt.show()

sns.lmplot(x=column[2], y=column[3], data=iris, col='species')
plt.show()

# %% [markdown]
# ## 17. BAR PLOT

# %%
plt.figure(figsize=(10,5))
plt.title('Barplot for IRIS Data', fontsize=15)
sns.barplot(data=iris)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Barplot for {}'.format(label[0]), fontsize=15)
sns.barplot(x=column[0], y='species', data=iris, color='orange')
plt.xlabel(label[0], fontsize=12)
plt.ylabel('SPECIES', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Barplot for {}'.format(label[1]), fontsize=15)
sns.barplot(y=column[1], x='species', data=iris, color='pink')
plt.ylabel(label[1], fontsize=12)
plt.xlabel('SPECIES', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Barplot for {}'.format(label[2]), fontsize=15)
sns.barplot(y=column[2], x='species', data=iris, capsize=0.2,  palette='Blues_d')
plt.ylabel(label[2], fontsize=12)
plt.xlabel('SPECIES', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Barplot for {}'.format(label[3]), fontsize=15)
sns.barplot(y=column[3], x='species', data=iris, ci='sd', palette='Greens_d', 
            order=['Iris-virginica', 'Iris-setosa', 'Iris-versicolor'])
plt.ylabel(label[3], fontsize=12)
plt.xlabel('SPECIES', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Barplot for {} vs {}'.format(label[0], label[1]), fontsize=15)
sns.barplot(x=column[0], y=column[1], data=iris)
plt.xlabel(label[0], fontsize=12)
plt.ylabel(label[1], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Barplot for {} vs {} by Category'.format(label[0], label[1]), fontsize=15)
sns.barplot(x=column[0], y=column[1], data=iris, hue='species')
plt.xlabel(label[0], fontsize=12)
plt.ylabel(label[1], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Barplot for {} vs {}'.format(label[3], label[2]), fontsize=15)
sns.barplot(y=column[2], x=column[3], data=iris)
plt.xlabel(label[3], fontsize=12)
plt.ylabel(label[2], fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Barplot for {} vs {}'.format(label[3], label[2]), fontsize=15)
sns.barplot(y=column[2], x=column[3], data=iris, hue='species')
plt.xlabel(label[3], fontsize=12)
plt.ylabel(label[2], fontsize=12)
plt.show()

# %% [markdown]
# ## 18. CAT PLOT

# %%
sns.catplot(data=iris)
plt.show()

# %%
sns.catplot(data=iris, col='species', s=10, alpha=0.5)
plt.show()

# %%
sns.catplot(data=iris, kind='violin')
plt.show()

# %%
sns.catplot(data=iris, kind='violin', col='species')
plt.show()

# %%
sns.catplot(data=iris, kind='bar')
plt.show()

# %%
sns.catplot(data=iris, kind='bar', col='species')
plt.show()

# %%
print('Catplot for {}'.format(label[0]))
sns.catplot(x=column[0], y=None, data=iris, col='species', kind='count')
plt.show()

# %%
print('Catplot for {} vs {}'.format(label[0], label[1]))
sns.catplot(x=column[0], y=column[1], data=iris)
plt.show()

# %%
print('Catplot for {} vs {} by Category'.format(label[0], label[1]))
sns.catplot(x=column[0], y=column[1], data=iris, col='species')
plt.show()

# %%
print('Catplot for {} vs {} by Category'.format(label[0], label[1]))
sns.catplot(x=column[0], y=column[1], data=iris, col='species', kind='box')
plt.show()

# %%
print('Catplot for {} vs {} by Category'.format(label[2], label[3]))
sns.catplot(x=column[2], y=column[3], data=iris, col='species', kind='violin')
plt.show()

# %%
print('Catplot for {} vs {} by Category'.format(label[0], label[1]))
sns.catplot(x=column[0], y=column[1], data=iris, col='species', kind='bar')
plt.show()

# %% [markdown]
# ## 19. RUG PLOT

# %%
plt.figure(figsize=(10,5))
plt.title('Rugplot for IRIS Data', fontsize=15)
sns.kdeplot(data=iris)
sns.rugplot(data=iris, height=0.05)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Rugplot for {} vs {}'.format(label[0], label[1]), fontsize=15)
plt.xlabel(label[0], fontsize=12)
plt.ylabel(label[1], fontsize=12)
sns.scatterplot(data=iris, x=column[0], y=column[1])
sns.rugplot(data=iris, x=column[0], y=column[1], height=0.1)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Rugplot for {} vs {}'.format(label[2], label[3]), fontsize=15)
plt.xlabel(label[2], fontsize=12)
plt.ylabel(label[3], fontsize=12)
sns.scatterplot(data=iris, x=column[2], y=column[3], hue='species')
sns.rugplot(data=iris, x=column[2], y=column[3], hue='species', height=-0.02, clip_on=False)
plt.show()

# %% [markdown]
# ## 20. HEAT MAP

# %%
plt.figure(figsize=(10,10))
plt.title('Heatmap for IRIS Data', fontsize=15)
sns.heatmap(data=iris[column])
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.title('Heatmap for Correlation of IRIS Data', fontsize=15)
sns.heatmap(data=iris[column].corr(), annot=True, cmap='YlGnBu')
plt.show()

# %%
plt.figure(figsize=(6,3))
plt.title('Heatmap for Correlation of {} & {}'.format(label[0], label[1]), fontsize=15)
sns.heatmap(data=iris[column[0:2]].corr(), annot=True, cmap='Blues')
plt.show()

# %%
plt.figure(figsize=(6,3))
plt.title('Heatmap for Correlation of {} & {}'.format(label[2], label[3]), fontsize=15)
sns.heatmap(data=iris[column[2:4]].corr(), annot=True, cmap='Greens')
plt.show()

# %% [markdown]
# # *-------------------------- Thank You! --------------------------*
