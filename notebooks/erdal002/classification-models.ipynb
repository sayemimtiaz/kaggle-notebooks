# %% [markdown]
# ## For this data I am going to compare accuracy score of Classification Algorithms to see which Model is better for this data

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly as py 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.metrics import roc_auc_score,roc_curve
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split, GridSearchCV,cross_val_score,cross_val_predict
from sklearn.metrics import mean_squared_error
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report,log_loss
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale 
from sklearn import model_selection
import warnings
warnings.filterwarnings("ignore")

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df=pd.read_csv("../input/heart-disease-uci/heart.csv")

# %%
df.head()

# %%
df.info()

# %%
df.isnull().sum()

# %%
df.columns = ['age', 'sex', 'chest_pain_type', 'resting_blood_pressure', 'cholesterol', 'fasting_blood_sugar', 'rest_ecg', 'max_heart_rate_achieved',
'exercise_induced_angina', 'st_depression', 'st_slope', 'num_major_vessels', 'thalassemia', 'target'] # renaming columns

# %%
df.head()

# %% [markdown]
# ## Visualization

# %%
sns.countplot(x="chest_pain_type",hue="target",data=df) # chest pain type-Target

# %% [markdown]
# 0: typical angina,
# 1: atypical angina,
# 2: non-anginal pain,
# 3: asymptomatic,

# %%
sns.scatterplot(x=df.cholesterol,y=df.resting_blood_pressure,hue=df.target) #cholesterol-resting_blood_pressure-Target

# %%
sns.scatterplot(x=df.cholesterol,y=df.max_heart_rate_achieved,hue=df.target,) #cholesterol-max_heart_rate_achieved-Target

# %%
sns.scatterplot(x=df.resting_blood_pressure,y=df.max_heart_rate_achieved,hue=df.target,) #resting_blood_pressure-max_heart_rate_achieved-target

# %%
sns.countplot(x="thalassemia",hue="target",data=df) # thalassemia-Target

# %%
sns.countplot(x="num_major_vessels",hue="target",data=df) #num_major_vessels-Target

# %%
sns.countplot(x="fasting_blood_sugar",hue="target",data=df) #fasting_blood_sugar-Target

# %% [markdown]
# 1: greater than 120
# 0:lower than 120

# %%
sns.countplot(x="rest_ecg",hue="target",data=df) # rest_ecg-Target

# %%
sns.countplot(x="st_slope",hue="target",data=df) #st_slope-Target

# %%
sns.countplot(x="sex",hue="target",data=df)# Sex-Target

# %% [markdown]
# 1: Male,0:Female

# %%
def barplot(x_features,y_features,target):
    for i in x_features:
        for j in y_features:
            f,ax = plt.subplots(figsize = (5,5))
            sns.barplot(x=i,y=j,hue=target,data=df,errwidth=False)

# %% [markdown]
# Now I am going to make bar plots

# %%
x_f=["chest_pain_type","st_slope","sex","rest_ecg","fasting_blood_sugar","num_major_vessels","thalassemia"]
y_f=["st_depression","cholesterol","max_heart_rate_achieved","max_heart_rate_achieved"]
a="target"

barplot(x_f,y_f,a)

# %%
sns.distplot(df.age,color="blue",kde=True)

# %%
def turn_categorical(features):
    for i in features:
        df[i]=df[i].astype("object") # I am going to turn int data to object data to use "one hot encoding" because some columns are categorical like "sex,"thalasemia"

# %%
turn_categorical(["sex","chest_pain_type","fasting_blood_sugar","rest_ecg","exercise_induced_angina","st_slope","thalassemia"])

# %%
df.info()

# %%
df = pd.get_dummies(df, drop_first=True) # make categorical variables to dummy variables

# %%
df.head()

# %%
df=df.rename(columns={"sex_1":"sex_male"})

# %%
df.head()

# %% [markdown]
# ### Train Test Split

# %%
y=df.target
X=df.drop("target",axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# ## Logistic Regression

# %%
log_reg=LogisticRegression(solver="liblinear")
log_reg.fit(X_train,y_train)

# %%
y_pred=log_reg.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,precision_score

print("Accuracy:",accuracy_score(y_test, y_pred))
print("Precision:",precision_score(y_test, y_pred))

# %%
log_reg.score(X_test,y_test) # other way to see accuracy score

# %%
cm=confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True)

# %%
y_pred_proba = log_reg.predict_proba(X_test)[::,1]
fpr, tpr, _ = roc_curve(y_test,  y_pred_proba)
auc =roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %%
# the highest value of auc is 1

# %% [markdown]
# ### KNN Classifier

# %%
knn_model=KNeighborsClassifier(n_neighbors=5)

# %%
knn_model.fit(X_test,y_test)

# %%
y_pred=knn_model.predict(X_test)

# %%
print("Accuracy:",accuracy_score(y_test, y_pred))
print("Precision:",precision_score(y_test, y_pred)) #for k=3,Our accuracy is lower than logistic regression

# %%
k_list=[]
acc_list=[]

for i in range(1,26):
    k_list.append(i)
    knn_model=KNeighborsClassifier(n_neighbors=i)
    knn_model.fit(X_test,y_test)
    acc_list.append(knn_model.score(X_test,y_test))
    
plt.plot(k_list,acc_list) 
plt.xlabel("K = ?")
plt.ylabel("Accuracy Score")
plt.grid()
    
#we can train our model with best K value according to graph

# %% [markdown]
# ### RandomForest Classifier

# %%
rf_model=RandomForestClassifier(random_state=42)
rf_model.fit(X_train,y_train)

# %%
y_pred=rf_model.predict(X_test)

# %%
print("Accuracy:",accuracy_score(y_test, y_pred))
print("Precision:",precision_score(y_test, y_pred))

# %% [markdown]
# ### Model Tunning with GridSearchCV

# %%
rf_params={"max_depth":[2,5,8,10],
           "max_features":[2,5,8],
           "n_estimators":[10,500,1000],
          "min_samples_split":[2,5,10]}

# %%
rf=RandomForestClassifier(random_state=42)

# %%
rf_cv=GridSearchCV(rf,rf_params,cv=10,n_jobs=-1,verbose=2)

# %%
rf_cv_model=rf_cv.fit(X_train,y_train)

# %%
rf_cv_model.best_params_

# %%
rf_tuned_model=RandomForestClassifier(random_state=42,max_depth=2,max_features= 5,min_samples_split= 2,n_estimators= 1000)

# %%
rf_tuned_model.fit(X_train,y_train)

# %%
y_pred=rf_tuned_model.predict(X_test)

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
sns.heatmap(cm,annot=True) # we have 9 false predictions

# %%
Importance=pd.DataFrame({"Importance":rf_tuned_model.feature_importances_*100},index=X_train.columns)

# %%
Importance.sort_values(by="Importance",axis=0,ascending=True).plot(kind="barh",color="r")

plt.xlabel("Feature İmportances")

# %% [markdown]
# cholesterol and others features that below the cholesterol  on graph are not that important than others

# %%
rf_tuned_model.score(X_test,y_test) # Logistic regression gives us a highest accuracy score so far

# %% [markdown]
# Naive Bayes Classification

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
nb=GaussianNB()
nb2=BernoulliNB()

# %%
nb_model=nb.fit(X_train,y_train)
nb2_model=nb2.fit(X_train,y_train)

# %%
y_pred=nb_model.predict(X_test)
y_pred2=nb2_model.predict(X_test)

# %%
print("Accuracy_NB1:",accuracy_score(y_test, y_pred))
print("Precision_NB1:",precision_score(y_test, y_pred))
print("**************************************************************")
print("Accuracy_NB2:",accuracy_score(y_test, y_pred2))
print("Precision_NB2:",precision_score(y_test, y_pred2))

# %%
cm=confusion_matrix(y_test,y_pred)
cm2=confusion_matrix(y_test,y_pred2)

# %%
sns.heatmap(cm,annot=True) # heatmap for GaussianNB 8 false prediction

# %%
sns.heatmap(cm2,annot=True) # Heatmap for Bernoulli 10 false prediction

# %% [markdown]
# Support Vector Machine

# %%
svm=SVC(kernel="linear") #linear model
svm2=SVC(kernel="rbf")   #Non-Linear model

# %%
svm_model1=svm.fit(X_train,y_train)
svm_model2=svm2.fit(X_train,y_train)

# %%
y_pred1=svm_model1.predict(X_test)
y_pred2=svm_model2.predict(X_test)

# %%
print("Accuracy_svm1:",accuracy_score(y_test, y_pred1))
print("Precision_svm1:",precision_score(y_test, y_pred1))
print("**************************************************************")
print("Accuracy_svm2:",accuracy_score(y_test, y_pred2))
print("Precision_svm2:",precision_score(y_test, y_pred2))

# I am going to continue with Linear SVM so I am going to tune 'C' parameter

# %%
cm=confusion_matrix(y_test,y_pred1)
sns.heatmap(cm,annot=True) # 9 false prediction

# %% [markdown]
# ## SVM Model Tunning

# %%
# for linear svm,We can just tune 'C' parameter. C is penalty for each misclassification

# %%
svc_params={"C":(0.001,0.1,0.01,1,5,10,50,100,500,1000,2000)} # these are random number

svc=SVC(kernel="linear")

svm_cv_model=GridSearchCV(svc,svc_params,cv=10,n_jobs=-1,verbose=2)

svv_tuned=svm_cv_model.fit(X_train,y_train)

# %%
svv_tuned.best_params_ # Best parameter for C is 500

# %%
svm_tuned_model=SVC(C=500,kernel="linear")

# %%
svm_tuned_model.fit(X_train,y_train)

# %%
y_pred=svm_tuned_model.predict(X_test)

print("Accuracy:",accuracy_score(y_test, y_pred))
print("Precision:",precision_score(y_test, y_pred))

# %%
#Accuracy of my model decreased. :/

# %% [markdown]
# ## Gradient Boosting Classifier

# %%
gbm_model=GradientBoostingClassifier()
gbm_model.fit(X_train,y_train)

# %%
y_pred=gbm_model.predict(X_test)

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
sns.heatmap(cm,annot=True)

# %%
print("Accuracy:",accuracy_score(y_test, y_pred))
print("Precision:",precision_score(y_test, y_pred))

# %% [markdown]
# GB Classifier Model Tunning

# %%
gbm_params={"learning_rate":[0.001,0.01,0.1,0.05],
           "n_estimators":[100,500,1000],
           "max_depth":[3,5,10],
           "min_samples_split":[2,5,10]}

# %%
gbm=GradientBoostingClassifier()
gbm_cv=GridSearchCV(gbm,gbm_params,cv=10,n_jobs=-1,verbose=2)
gbm_cv_model=gbm_cv.fit(X_train,y_train)

# %%
gbm_cv_model.best_params_

# %%
gbm=GradientBoostingClassifier(learning_rate= 0.1,max_depth= 3,min_samples_split= 5,n_estimators= 100)
gbm_tuned_model=gbm.fit(X_train,y_train)

# %%
y_pred=gbm_tuned_model.predict(X_test)

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
sns.heatmap(cm,annot=True)

# %%
print("Accuracy:",accuracy_score(y_test, y_pred))
print("Precision:",precision_score(y_test, y_pred))  # my accuracy score didnt change

# %%
Importance=pd.DataFrame({"Importance":gbm_tuned_model.feature_importances_*100},index=X_train.columns)

Importance.sort_values(by="Importance",axis=0,ascending=True).plot(kind="barh",color="r")

plt.xlabel("Feature İmportances")

# %%
y_pred_proba = gbm_tuned_model.predict_proba(X_test)[::,1]
fpr, tpr, _ = roc_curve(y_test,  y_pred_proba)
auc =roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show() # auc score is 0.89

# %% [markdown]
# ## Xgbm Classifier

# %%
xgb=XGBClassifier()

# %%
xgb_model=xgb.fit(X_train,y_train)

# %%
y_pred=xgb_model.predict(X_test)

# %%
print("Accuracy:",accuracy_score(y_test, y_pred))
print("Precision:",precision_score(y_test, y_pred))

# %% [markdown]
# ## XGBM Classifier Model Tunning

# %%
xgbm_params={"n_estimators":[100,500,1000,2000],
           "subsample":[0.6,0.8,1],
           "max_depth":[3,4,5,6],
           "learning_rate":[0.1,0.01,0.02,0.05],
           "min_samples_split":[2,5,10]} # n_estimators= number of iterations

# %%
xgbm=XGBClassifier()
xgbm_cv=GridSearchCV(xgbm,xgbm_params,cv=10,n_jobs=-1,verbose=2)
xgbm_cv_model=xgbm_cv.fit(X_train,y_train)

# %%
xgbm_cv_model.best_params_

# %%
xgbm=XGBClassifier(learning_rate= 0.05,max_depth= 3,min_samples_split= 2,n_estimators= 100,subsample= 0.6)
xgbm_tuned_model=xgbm.fit(X_train,y_train)

# %%
y_pred=xgbm_tuned_model.predict(X_test)

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
sns.heatmap(cm,annot=True)

# %%
print("Accuracy:",accuracy_score(y_test, y_pred))
print("Precision:",precision_score(y_test, y_pred))

# %%
y_pred_proba = xgbm_tuned_model.predict_proba(X_test)[::,1]
fpr, tpr, _ = roc_curve(y_test,  y_pred_proba)
auc =roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show() # Auc=0.92

# %% [markdown]
# ## LightGBM Classifier

# %%
lgbm_model=LGBMClassifier().fit(X_train,y_train)

# %%
y_pred=lgbm_model.predict(X_test)

# %%
print("Accuracy:",accuracy_score(y_test, y_pred))
print("Precision:",precision_score(y_test, y_pred))

# %% [markdown]
# ## LightGBM Model Tunning

# %%
lgbm_params={"n_estimators":[100,500,100,2000],
            "subsample":[0.6,0.8,1.0],
            "learning_rate":[0.1,0.01,0.02,0.05],
            "min_child_samples":[5,20,10],
            "max_depth":[3,4,5,6]}

# %%
lgbm=LGBMClassifier()
lgbm_cv=GridSearchCV(lgbm,lgbm_params,cv=10,n_jobs=-1,verbose=2)
lgbm_cv_model=lgbm_cv.fit(X_train,y_train)

# %%
lgbm_cv_model.best_params_

# %%
lgbm=LGBMClassifier(learning_rate= 0.05,max_depth= 6,min_child_samples= 10,n_estimators= 100,subsample= 0.6)
lgbm_tuned_model=lgbm.fit(X_train,y_train)

# %%
y_pred=lgbm_tuned_model.predict(X_test)

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
sns.heatmap(cm,annot=True)

# %%
print("Accuracy:",accuracy_score(y_test, y_pred))
print("Precision:",precision_score(y_test, y_pred))

# %%
y_pred_proba = lgbm_tuned_model.predict_proba(X_test)[::,1]
fpr, tpr, _ = roc_curve(y_test,  y_pred_proba)
auc =roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show() # AUC=0.9

# %%
models=[lgbm_tuned_model,xgbm_tuned_model,gbm_tuned_model,svm_tuned_model,nb_model,knn_model,log_reg]
str_models=["lgbm_tuned_model","xgbm_tuned_model","gbm_tuned_model","svm_tuned_model","nb_model","knn_model","log_reg"]
acc_score=[]

for i in models:
    acc_score.append(i.score(X_test,y_test))

data=pd.DataFrame({"Models": str_models,"Accuracy_Score":acc_score})
data.sort_values(by="Accuracy_Score",ascending=False)
data.reset_index(drop=True)

plt.figure(figsize=(10,10))
sns.barplot(x="Accuracy_Score",y="Models",data=data,orient="h")
plt.xticks(rotation=90)
plt.grid()

# %% [markdown]
# For This Data,Logistic Regression gives best accuracy score

# %%
# ?plt
