# %% [markdown]
# <style>
# aside {
#   font-size: smaller;
#   margin-left:1cm;
# }
# </style>
# # Sissejuhatus
#
# Andmestik on USA massitulistamised aastatel 1966-2017. Püstitasime 3 uurimisküsimust:
# 1. Mitmel korral sai surma 0-5 politseinikku?
# 2. Mis vanuses tulistajad tekitasid kõige rohkem surmajuhtumeid?
# 3. Mis oli erinevatest rassidest tulistajate poolt tekitatud keskmine hukkunute arv?

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# %matplotlib inline 
df = pd.read_csv("../input/Mass Shootings Dataset Ver 5.csv", encoding='latin-1')
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %% [markdown]
# **Mitmel korral sai surma 0-5 politseinikku?**

# %%
df.policeman_killed.plot.hist();

# %% [markdown]
# **Mis vanuses tulistajad tekitasid kõige rohkem surmajuhtumeid?**

# %%
df["age"] = pd.to_numeric(df['age'], errors='coerce') # Kõik floatideks, kui error siis muudab NaN väärtuseks
df = df[pd.notnull(df['age'])] # Kustutab read kus Age on NaN väärtus
df.plot.scatter("age", "fatalities", alpha=0.2); # Teeb scatterploti

# %% [markdown]
# **Mis oli erinevatest rassidest tulistajate poolt tekitatud keskmine hukkunute arv?
# **

# %%
df["race"] = df["race"].str.capitalize()
df.groupby("race")["fatalities"].mean().round()
