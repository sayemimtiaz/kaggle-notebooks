# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

# Классификация
import graphviz 
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score 

# Регрессия
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ## Шаг 1. Загрузка данных и их исследование

# %%
df_train = pd.read_csv('/kaggle/input/mobile-price-classification/train.csv')
df_test = pd.read_csv('/kaggle/input/mobile-price-classification/test.csv')
df_train.head()

# %%
#head\info\describe

# %%
#Работа с пропущенными данными

# %% [markdown]
# #### Назовите категориальные данные и числовые данные:

# %% [markdown]
# ### Вывод: (напишите свои наблюдения)

# %% [markdown]
# ## Шаг 2. EDA

# %%
# какие типы цен самые популярные?
df_price = df_train.groupby('price_range').agg('count').reset_index()


df_price.plot.bar( x = 'price_range', y='battery_power', rot = 0, figsize = (8, 4), alpha = 0.6, legend = False)
plt.xlabel('Тип цены')
plt.ylabel('Количество объектов')
plt.title("Количество объектов каждой категории цены");

# %%
# какой тип Wi-Fi самый популярный в выборке?
df_wifi = #допишите ваш код


df_wifi.plot.bar( #допишите ваш код
plt.xlabel('Тип WiFi')
plt.ylabel('Количество объектов')
plt.title("Количество объектов каждой категории Wi-Fi");

# %%
# какой тип сим карты самый популярный в выборке?
df_dual_sim = #допишите ваш код


df_dual_sim.plot.bar( #допишите ваш код
plt.xlabel( #допишите ваш код
plt.ylabel( #допишите ваш код
plt.title( #допишите ваш код

# %%
# какой тип сим карты самый популярный в выборке?


cols1 = ['battery_power','blue','clock_speed','dual_sim', 'price_range']
cols2 = ['fc','four_g','int_memory','m_dep','pc','price_range']
cols3 = ['px_height','px_width','ram','sc_h', 'mobile_wt','n_cores', 'price_range']
cols4 = ['sc_w','talk_time','three_g','touch_screen','wifi', 'price_range']

heatmap = sns.heatmap(#допишите ваш код

# %%
#  отфильтруйте данные и сохраните в отдельном df

# %% [markdown]
# ### Вывод: (напишите свои наблюдения)

# %% [markdown]
# ## Шаг 3. Классификация

# %% [markdown]
# ### KNN модель

# %%
# Разделяем переменные

# Модель

# Обучаем модель на тренировочных данных

# Строим прогноз на тренировочных и тестовых данных

# Оценка

# %% [markdown]
# ### Деревья решений

# %%
# Разделяем переменные

# Модель

# Обучаем модель на тренировочных данных

# Строим прогноз на тренировочных и тестовых данных

# Оценка

# %% [markdown]
# ## Заключительный ввод: (напишите свои наблюдения)
