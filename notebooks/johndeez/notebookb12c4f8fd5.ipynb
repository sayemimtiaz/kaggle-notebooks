# %% [markdown]
# # **Insurance Company Benchmark**

# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error

train_data = np.array(pd.read_csv('/kaggle/input/the-insurance-company-tic-benchmark/tic_2000_train_data.csv'))
target_data = np.array(pd.read_csv('/kaggle/input/the-insurance-company-tic-benchmark/tic_2000_target_data.csv'))
eval_data = np.array(pd.read_csv('/kaggle/input/the-insurance-company-tic-benchmark/tic_2000_eval_data.csv'))

def RSS(real, prediction):
    res = np.array(real) - np.array(prediction)
    return sum(res * res)[0]

boston_x = pd.DataFrame(boston.data, columns = boston.feature_names)
boston_y = pd.DataFrame(boston.target)
model = LinearRegression()
x_train, x_test, y_train, y_test = train_test_split(boston_x, boston_y, test_size=0.2, random_state=4)
model.fit(x_train, y_train)
result = model.predict(x_test)
mse = mean_squared_error(y_test, result)
print('Mean Square Error Linear : ',mse)
print('RSS Linear : ', RSS(y_test, result))

model = Ridge(alpha=.5)
x_train, x_test, y_train, y_test = train_test_split(boston_x, boston_y, test_size=0.2, random_state=4)
model.fit(x_train, y_train)
result = model.predict(x_test)
mse = mean_squared_error(y_test, result)
print('Mean Square Error Ridge : ',mse)
print('RSS Ridge : ', RSS(y_test, result))

model = Lasso(alpha=.0001)
x_train, x_test, y_train, y_test = train_test_split(boston_x, boston_y, test_size=0.2, random_state=4)
model.fit(x_train, y_train)
result = model.predict(x_test)
mse = mean_squared_error(y_test, result)
print('Mean Square Error Lasso : ',mse)
print('RSS Lasso : ', RSS(y_test, result))

# %% [markdown]
# # Boston House Price Dataset

# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error

def RSS(real, prediction):
    res = np.array(real) - np.array(prediction)
    return sum(res * res)[0]

boston = load_boston()

boston_x = pd.DataFrame(boston.data, columns = boston.feature_names)
boston_y = pd.DataFrame(boston.target)
model = LinearRegression()
x_train, x_test, y_train, y_test = train_test_split(boston_x, boston_y, test_size=0.2, random_state=4)
model.fit(x_train, y_train)
result = model.predict(x_test)
mse = mean_squared_error(y_test, result)
print('Mean Square Error Linear : ',mse)
print('RSS Linear : ', RSS(y_test, result))

model = Ridge(alpha=.5)
x_train, x_test, y_train, y_test = train_test_split(boston_x, boston_y, test_size=0.2, random_state=4)
model.fit(x_train, y_train)
result = model.predict(x_test)
mse = mean_squared_error(y_test, result)
print('Mean Square Error Ridge : ',mse)
print('RSS Ridge : ', RSS(y_test, result))

model = Lasso(alpha=.0001)
x_train, x_test, y_train, y_test = train_test_split(boston_x, boston_y, test_size=0.2, random_state=4)
model.fit(x_train, y_train)
result = model.predict(x_test)
mse = mean_squared_error(y_test, result)
print('Mean Square Error Lasso : ',mse)
print('RSS Lasso : ', RSS(y_test, result))

# %% [markdown]
# # Wine Quality

# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error

def RSS(real, prediction):
    res = np.array(real) - np.array(prediction)
    return sum(res * res)[0]

boston = load_wine()

boston_x = pd.DataFrame(boston.data, columns = boston.feature_names)
boston_y = pd.DataFrame(boston.target)
model = LinearRegression()
x_train, x_test, y_train, y_test = train_test_split(boston_x, boston_y, test_size=0.2, random_state=4)
model.fit(x_train, y_train)
result = model.predict(x_test)
mse = mean_squared_error(y_test, result)
print('Mean Square Error Linear : ',mse)
print('RSS Linear : ', RSS(y_test, result))

model = Ridge(alpha=.5)
x_train, x_test, y_train, y_test = train_test_split(boston_x, boston_y, test_size=0.2, random_state=4)
model.fit(x_train, y_train)
result = model.predict(x_test)
mse = mean_squared_error(y_test, result)
print('Mean Square Error Ridge : ',mse)
print('RSS Ridge : ', RSS(y_test, result))

model = Lasso(alpha=.0001)
x_train, x_test, y_train, y_test = train_test_split(boston_x, boston_y, test_size=0.2, random_state=4)
model.fit(x_train, y_train)
result = model.predict(x_test)
mse = mean_squared_error(y_test, result)
print('Mean Square Error Lasso : ',mse)
print('RSS Lasso : ', RSS(y_test, result))

# %% [markdown]
# # Breast Cancer Wisconsin

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error

def RSS(real, prediction):
    res = np.array(real) - np.array(prediction)
    return sum(res * res)[0]

boston = load_breast_cancer()

boston_x = pd.DataFrame(boston.data, columns = boston.feature_names)
boston_y = pd.DataFrame(boston.target)
model = LinearRegression()
x_train, x_test, y_train, y_test = train_test_split(boston_x, boston_y, test_size=0.2, random_state=4)
model.fit(x_train, y_train)
result = model.predict(x_test)
mse = mean_squared_error(y_test, result)
print('Mean Square Error Linear : ',mse)
print('RSS Linear : ', RSS(y_test, result))

model = Ridge(alpha=.5)
x_train, x_test, y_train, y_test = train_test_split(boston_x, boston_y, test_size=0.2, random_state=4)
model.fit(x_train, y_train)
result = model.predict(x_test)
mse = mean_squared_error(y_test, result)
print('Mean Square Error Ridge : ',mse)
print('RSS Ridge : ', RSS(y_test, result))

model = Lasso(alpha=.0001)
x_train, x_test, y_train, y_test = train_test_split(boston_x, boston_y, test_size=0.2, random_state=4)
model.fit(x_train, y_train)
result = model.predict(x_test)
mse = mean_squared_error(y_test, result)
print('Mean Square Error Lasso : ',mse)
print('RSS Lasso : ', RSS(y_test, result))
