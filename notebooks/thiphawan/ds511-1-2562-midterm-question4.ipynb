# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %% [markdown]
# <h1>**3.ใน Kaggle หาข้อมูล “Agriculture Crop Production In India” โดยสมาชิกชื่อ “SrinivasRao” ซึ่งเป็นข้อมูลผลิตผล
# ทางการเกษตรในประเทศอินเดียตั้งแต่ปี 2006 ถึง 2010 โดยมีไฟล์ในชุดข้อมูลนี้ทั้งหมด 5 ไฟล์ (25 คะแนน)**</h1>

# %%
import pandas as pd 
import numpy as np
import matplotlib as plt 
import seaborn as sns

# %%
dataset1 = pd.read_csv("../input/agricuture-crops-production-in-india/datafile (1).csv")
dataset2 = pd.read_csv("../input/agricuture-crops-production-in-india/datafile (2).csv")
dataset3 = pd.read_csv("../input/agricuture-crops-production-in-india/datafile (3).csv")
dataset4 = pd.read_csv("../input/agricuture-crops-production-in-india/datafile.csv")
dataset5 = pd.read_csv("../input/agricuture-crops-production-in-india/produce.csv")

# %%
dataset1.columns = ['Crop','State','CostofCultivationA2',
                     'CostofCultivationC2','CostofProduction2','Yield']

# %% [markdown]
# <h2>****(a) ใช้ Seaborn Library เพื่อการทํา EDA และ Data Visualization คุณได้ความรู้อะไรเกี่ยวกับข้อมูลชุดนี้บ้าง****</h2>

# %%
dataset1.info()

# %%
dataset2.info()

# %%
dataset3.info()

# %%
dataset4.info()

# %%
dataset5.info()

# %%
print(dataset1.shape)
print(dataset2.shape)
print(dataset3.shape)
print(dataset4.shape)
print(dataset5.shape)

# %%
#check missing values
print('dataset 1 :')
print(dataset1.isnull().sum())
print(dataset1.shape)
print('--------------------------')
print('dataset 2 :')
print(dataset2.isnull().sum())
print(dataset2.shape)
print('--------------------------')
print('dataset 3 :')
print(dataset3.isnull().sum())
print(dataset3.shape)
print('--------------------------')
print('dataset 4 :')
print(dataset4.isnull().sum())
print(dataset4.shape)
print('--------------------------')
print('dataset 5 :')
print(dataset5.isnull().sum())
print(dataset5.shape)

# %%
print('dataset 1 :')

print(dataset1.nunique())
print('---------------------------------------')
print('dataset 2 :')
print(dataset3.nunique())
print('---------------------------------------')
print('dataset 3 :')
print(dataset3.nunique())

print('---------------------------------------')
print('dataset 4 :')
print(dataset4.nunique())
print('---------------------------------------')
print('dataset 5 :')
print(dataset5.nunique())

# %% [markdown]
# **#ดู outlier ของข้อมูลชุด dataset1 ระหว่างพืชกับราคาต้นทุน**

# %%
ax = sns.boxplot(x="Crop", y="CostofCultivationA2", data=dataset1, palette=sns.color_palette("Paired"))

# %% [markdown]
# **#ดูการกระจายตัวของ dataset1
# **

# %%
dataset1.groupby('Crop').sum()
data = {'ARHAR': '1', 'COTTON':'2' ,'GRAM': '3', 'GROUNDNUT':'4','MAIZE': '5', 'MOONG':'6','PADDY': '7', 'RAPESEED AND MUSTARD':'8','SUGARCANE': '9', 'WHEAT':'10' }
dataset1['Crop'] = dataset1['Crop'].map(data)
dataset1.head()

# %%
sns.pairplot(dataset1 ,hue = 'Crop',diag_kind = 'kde',kind = "scatter",palette = sns.color_palette("Paired"))

# %% [markdown]
# **ตอบ จากภาพจะเห็นได้ว่า Yield กับ CostofCultivationA2 และ Yield กับ CostofCultivationC2 และ Yield กับ CostofProduction2 ข้อมูลไม่การจายตัว
# **

# %% [markdown]
# <h2>**(b) คุณจะจัดการกับข้อมูลที่เป็น NA อย่างไรในแต่ละ column ทําไมจึงทําเช่นนั้น**</h2>

# %%
#check missing values
print('dataset 1 :')
print(dataset1.isnull().any())

# %% [markdown]
# **dataset 1 : **ไม่ค่าสูญหาย**

# %%
print(dataset2.isnull().any())

# %% [markdown]
# **dataset 2 : ไม่ค่าสูญหาย**

# %%
print(dataset3.isnull().any())

# %%
print(dataset3.isnull().sum())
print(dataset3.shape)

# %% [markdown]
# **dataset 3 : มีค่าสูญหาย ใช้การแทนค่าด้วยค่าเฉลี่ยของทั้งชุดข้อมูล เพราะข้อมูลมีจำนวนน้อย**

# %%
print(dataset4.isnull().any())

# %% [markdown]
# **dataset 4 : ไม่ค่าสูญหาย**

# %%
print(dataset5.isnull().any())

# %%
print(dataset5.isnull().sum())
print(dataset5.shape)

# %% [markdown]
# **dataset 5 : มีค่าสูญหาย ใช้การ drop หรือลบออกในส่วนที่เดป็นคอลัมน์ 3-1993, 3-1994, 3-1995, 3-1996,3-1997, 3-1998, 3-1999, 3-2000, 3-2001, 3-2002, 3-2003  และคอลัมน์ที่เหลือใช้การแทนค่าด้วยค่าเฉลี่ยของทั้งชุดข้อมูล **

# %% [markdown]
# **<h2>(c) อะไรน่าจะเป็นปัจจัยที่ส่งผลต่อ Yield ได้บ้าง คุณจะตอบคําถามนี้อย่างไร</h2>**

# %%
sns.pairplot(dataset1 ,hue = 'Crop',diag_kind = 'kde',kind = "scatter",palette = sns.color_palette("RdBu_r", 7))

# %% [markdown]
# <h3>**ตอบ: ดูจากภาพกราฟ จะเห็นความสัมพันธ์ของ Yield กับข้อมูลอื่นๆในตาราง จะพบว่าความสัมพันธ์ระหว่าง Yield กับ CostofCultivationA2 และ ความสัมพันธ์ระหว่าง Yield กับ CostofCultivationC2 และ ความสัมพันธ์ระหว่าง Yield กับ CostofProduction2 มีการกระจายตัวน้อย ข้อมูลเกาะกลุ่มกัน
# **</h3>
