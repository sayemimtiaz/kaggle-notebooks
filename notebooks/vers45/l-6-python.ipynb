# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#Part 1

d = {'a': 1, 'b': 2, 'c': 3, 'd' : 4, 'e' : 5}
ser = pd.Series(data=d)
ser [1:4]

# %%
#Part 2

d = {"a": pd.Series([1, 2, 3, 4], index=['e', 'f', 'g', 'h']),
     "b": pd.Series([5, 6, 7, 8], index=['e', 'f', 'g', 'h']),
     "c": pd.Series([9, 10, 11, 12], index=['e', 'f', 'g', 'h']),
     "d": pd.Series([13, 14, 15, 16], index=['e', 'f', 'g', 'h'])}
df = pd.DataFrame(d)
df

# %%
#Part 3

x = df.loc ['e', 'a']
y = df.iloc [0, 0]
print (x, y)

# %%
#Part 4

fd = df[df["a"] > 2]
fd

# %%
#Part 5

d = pd.read_csv('/kaggle/input/student-alcohol-consumption/student-mat.csv')
d

# %%
#Part 6

d.head(5)

# %%
#Part 7

d.info()

# %%
#Part 8

d.shape

# %%
#Part 9

fmd = d[d["sex"] == "M"]
ffd = d[d["sex"] == "F"]

lfmd = len(fmd)
lffd = len(ffd)

print("Male -",lfmd)
print("Female -",lffd)

# %%
#Part 10

a = d.iloc[:,2]
a = d.loc[:,'age']

print(np.mean(a))

# %%
m = pd.read_csv('/kaggle/input/student-alcohol-consumption/student-mat.csv')
p = pd.read_csv('/kaggle/input/student-alcohol-consumption/student-por.csv')

# %%
#Part 11

c = pd.concat([m, p])
c

# %%
#Part 12

nan = c.isnull().values.any()
nan

# %%
#Part 13

c = c.fillna(0)
c

# %%
#Part 14

import matplotlib.pyplot as plt

c = pd.concat([m, p])

plt.hist(c['age'], color = 'red', edgecolor = 'black')

# %%
#Part 15

c = pd.concat([m, p])

sc = c.iloc[:,0]
sx = c.iloc[:,1]
ag = c.iloc[:,2]
fm = c.iloc[:,4]
dc = c.loc[:,'Dalc']
wc = c.loc[:,'Walc']

r = pd.concat([sc, sx, ag, fm, dc, wc], axis = 1)
r
