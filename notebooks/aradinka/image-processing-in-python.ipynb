# %% [markdown]
# # **Import Image**

# %%
original_image = Image.open('../input/flickr-image-dataset/flickr30k_images/flickr30k_images/1000092795.jpg')
original_image

# %% [markdown]
# # **RGB to grayscale**

# %%
from skimage import data, color
import matplotlib.pyplot as plt

# %%
numpy_image = np.asarray(original_image)
grayscale_image = color.rgb2gray(numpy_image)

# %%
def show_image(image, cmap_type='gray'):
    plt.imshow(image, cmap=cmap_type)
    plt.axis('off')
    plt.show()

show_image(original_image)
show_image(grayscale_image)

# %% [markdown]
# # **Flipping Image**

# %%
import PIL
import numpy as np
from PIL import Image

# %%
# Flip vertically
vertical_flip_image = np.flipud(original_image)

# Flip horizontally
horizontal_flip_image = np.fliplr(original_image)

show_image(horizontal_flip_image)
show_image(vertical_flip_image)
