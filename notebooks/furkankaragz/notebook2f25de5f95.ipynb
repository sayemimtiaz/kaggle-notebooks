# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

ds=pd.read_csv("../input/world-happiness-report-2021/world-happiness-report-2021.csv")

# %%
ds.head()

# %%
ds.tail()

# %%
ds1=ds["Ladder score"]
ds1.plot()

# %%
ds2=ds["Standard error of ladder score"]
ds2.plot()

# %%
ds3=ds["upperwhisker"]
ds3.plot()

# %%
ds.describe().T
