# %% [markdown]
# # Simple questions about Pokemon
# We have most information about pokemon in the original nintendo videogames here. Some simple, but interesting questions can be answered with this data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../input/Pokemon.csv')
df.head(3)

# %% [markdown]
# ## What's the strongest pokemon overall?
# We consider the strongest pokemon to be the one with the maximum total stats:

# %%
df.iloc[[df[u'Total'].idxmax()]]

# %% [markdown]
# ## What's the weakest pokemon?
# Well, we could think it's magikarp, but...

# %%
df.iloc[[df[u'Total'].idxmin()]]

# %% [markdown]
# ## What's the pokemon with the highest defense?
# If we are playing against a tough rival, we should have a high defense!

# %%
df.iloc[[df[u'Defense'].idxmax()]]

# %% [markdown]
# ## What's the pokemon with the highest defense?
# This is the one we want to finish a battle quickly!

# %%
df.iloc[[df[u'Attack'].idxmax()]]

# %% [markdown]
# ## Can Attack and Defense predict the type of my pokemon?
# Here is an interesting question:  If it was so It would mean that we could choose the "best" pokemon, and all other pokemon with the same type would have very high stats as well.  Let's plot the data first:

# %%
# Create a pyplot figure big enough for all our pokemon
plt.figure(figsize=(12,8))
# Create the colors for the plot
colors = pd.DataFrame(df['Type 1'].astype('category')).apply(lambda x: x.cat.codes)
print(colors.head())

# Plot the pokemon Attack and Defense as points
plt.scatter(df['Attack'], df['Defense'],c=colors, cmap=plt.cm.prism, s=120)
plt.xlim(0,200)
plt.ylim(0,250)
plt.xlabel('Attack')
plt.ylabel('Defense')
plt.title('Pokemon Attack, Defense, and their Types')

# %% [markdown]
# Can you see any pattern? If Attack and Defense could predict the type of a pokemon you would be able to see clusterng of colors. There seems to be no clustering. Can you find a way to group the colors?
