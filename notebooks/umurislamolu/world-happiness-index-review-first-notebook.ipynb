# %% [markdown]
# **WORLD HAPPINESS INDEX REVIEW**
# A basic review of 2019 world happiness index

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# I am using the head function to basicly examine the dataset (what parameters do we have?, how the data looks?, etc.)

# %%
data_2019 = pd.read_csv("/kaggle/input/world-happiness/2019.csv")
data_2019.head()

# %% [markdown]
# With the info function we saw that our data have mainly float columns,one integer and one string column.

# %%
data_2019.info()

# %%
data_2019.columns

# %% [markdown]
# The describe function shows us the datas mean values, max and min values and standart deviation in a nutshell.

# %%
data_2019.describe()

# %% [markdown]
# The correlation function indicates that Overall Rank and Score has an inverse relationship. So if the Score increase than Overall Rank must decrease. Also Score has direct relationship with GDP per capita Social Support and Healty life expectancy. So one can say that if a country has high GDP,high social support and high life expectancy, it must be a happy country.

# %%
data_2019.corr()

# %% [markdown]
# **direct proportion**

# %%
data_2019.plot(kind="scatter", x="GDP per capita",y="Score",color="red")

# %% [markdown]
# **direct proportion**

# %%
data_2019.plot(kind="scatter", x="Social support",y="Score",color="blue")

# %% [markdown]
# **direct proportion**

# %%
data_2019.plot(kind="scatter", x="Healthy life expectancy",y="Score",color="green")

# %% [markdown]
# ***No direct relationship***

# %%
data_2019.plot(kind="scatter", x="Perceptions of corruption",y="Score",color="black")

# %% [markdown]
# According to Histogram below, most common Score is 5,2.

# %%
data_2019.Score.hist(color="blue",bins=30)

# %% [markdown]
# The heat map visualize the correlation table above

# %%
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(data_2019.corr(), annot = True, linewidths=5,fmt= '.1f',ax=ax)

# %%
data_2019[(data_2019["Healthy life expectancy"]>1)  & (data_2019["Perceptions of corruption"]<0.11)]

# %%
treshold = data_2019.Score.mean()
print(treshold)

# %%
data_2019["Happiness Level"] = ["High" if i> treshold else "Low" for i in data_2019.Score]

# %%
data_2019.head(100)
