# %% [markdown]
# **This notebook is an exercise in the [Pandas](https://www.kaggle.com/learn/pandas) course.  You can reference the tutorial at [this link](https://www.kaggle.com/residentmario/data-types-and-missing-values).**
#
# ---

# %% [markdown]
# # Introduction
#
# Run the following cell to load your data and some utility functions.

# %%
import pandas as pd

reviews = pd.read_csv("../input/wine-reviews/winemag-data-130k-v2.csv", index_col=0)

from learntools.core import binder; binder.bind(globals())
from learntools.pandas.data_types_and_missing_data import *
print("Setup complete.")

# %% [markdown]
# 옆의 데이터 탭을 눌러보면 이 캐글 커널에 어떤 input이 있는 지 알 수 있습니다. 이번 예제에서는 'wine-reviews' 안에 있는 'winemag-data-130k-v2.csv"를 사용하고 있습니다.

# %% [markdown]
# # Exercises

# %% [markdown]
# 문제를 풀기 전에 먼저 reviews가 어떻게 생겼는 지 부터 살펴보겠습니다.

# %%
reviews.head()

# %% [markdown]
# ## 1.
# What is the data type of the `points` column in the dataset?

# %%
# Your code here

dtype = reviews.points.dtype
# dtype = reviews['points'].dtype
# dtype = reviews.loc[:, 'points'].dtype
# print(dtype)

# Check your answer
q1.check()

# %%
#q1.hint()
#q1.solution()

# %% [markdown]
# ## 2.
# Create a Series from entries in the `points` column, but convert the entries to strings. Hint: strings are `str` in native Python.

# %%
point_strings = reviews.points.astype(str)
# point_strings = reviews.points.astype("string")
print(type(point_strings[0]))
print(point_strings.dtype)
# Check your answer
q2.check()

# %% [markdown]
# Pandas에서 자료형을 문자열로 바꾸는 데에는 약간 문제가 있습니다. Pandas는 문자열과 같은 text data를 다음의 2가지 방식으로 저장합니다.
# * object -dtype NumPy array.
# * StringDtype extension type.
# 원래는 object 형식만 가능했지만, 현재는 두 가지 모두 지원하고 있습니다. 또 지금은 두 자료형에 따라 성능적 차이가 없지만 추후에는 StringDtype이 더 좋은 성능을 보일 수 있다고 얘기합니다. 자세한 내용은 [관련 docs](https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html)에서 볼 수 있습니다.

# %%
#q2.hint()
#q2.solution()

# %% [markdown]
# ## 3.
# Sometimes the price column is null. How many reviews in the dataset are missing a price?

# %%
n_missing_prices = reviews.loc[:, 'price'].isna().sum()
print(n_missing_prices)
# Check your answer
q3.check()

# %% [markdown]
# 위 코드는 다음의 두 방법으로 나뉘어서 이해하면 편합니다.

# %%
reviews.loc[:, 'price'].isna()

# %%
print(True + True)
print(True + False)
print(False + False)

# %%
q3.hint()
q3.solution()

# %% [markdown]
# ## 4.
# What are the most common wine-producing regions? Create a Series counting the number of times each value occurs in the `region_1` field. This field is often missing data, so replace missing values with `Unknown`. Sort in descending order.  Your output should look something like this:
#
# ```
# Unknown                    21247
# Napa Valley                 4480
#                            ...
# Bardolino Superiore            1
# Primitivo del Tarantino        1
# Name: region_1, Length: 1230, dtype: int64
# ```

# %%
region_1_reviews = reviews.loc[:, 'region_1']

# %%
region_1_reviews.fillna('Unknown', inplace=True)

# %%
region_1_reviews.isna().sum()

# %%
region_1_reviews.value_counts()

# %%
reviews_per_region = region_1_reviews.value_counts().sort_values(ascending=False)
print(reviews_per_region)

# Check your answer
q4.check()

# %%
q4.hint()
q4.solution()

# %% [markdown]
# # Keep going
#
# Move on to **[renaming and combining](https://www.kaggle.com/residentmario/renaming-and-combining)**.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [Learn Discussion forum](https://www.kaggle.com/learn-forum/161299) to chat with other Learners.*
