# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
bits = pd.read_csv('../input/coinbaseUSD_1-min_data_2014-12-01_to_2019-01-09.csv')
bits.head()
# Out:
#     Timestamp   Open       ...        Volume_(Currency)  Weighted_Price
# 0  1417411980  300.0       ...                      3.0           300.0
# 1  1417412040    NaN       ...                      NaN             NaN
# 2  1417412100    NaN       ...                      NaN             NaN
# 3  1417412160    NaN       ...                      NaN             NaN
# 4  1417412220    NaN       ...                      NaN             NaN
#
# [5 rows x 8 columns]

# %% [markdown]
# We will be using weighted price of bitcoin for prediction. Currently the time is in unix timestamp and has data for every minute. Lets average the price over a day and forecast for next 30 days.

# %%
bits['date'] = pd.to_datetime(bits['Timestamp'],unit='s').dt.date
group = bits.groupby('date')
Real_Price = group['Weighted_Price'].mean()

# %%
Real_Price[0:5]
# Out:
# date
# 2014-12-01    335.000000
# 2014-12-02    377.854911
# 2014-12-03    377.818333
# 2014-12-04    377.100000
# 2014-12-06    378.000000
# Name: Weighted_Price, dtype: float64

# %%
# split data
prediction_days = 30
df_train= Real_Price[:len(Real_Price)-prediction_days]
df_test= Real_Price[len(Real_Price)-prediction_days:]

# %% [markdown]
# ## One Shot LSTM/RNN

# %%
# hyperparameters
n_steps = 10
nb_epochs=20
lr=0.001

# %%
# Data preprocess
training_set = df_train.values
training_set = np.reshape(training_set, (len(training_set), 1))
test_set = df_test.values
test_set = np.reshape(test_set, (len(test_set), 1))
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
training_set = sc.fit_transform(training_set)
test_set = sc.transform(test_set)

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_steps
		# check if we are beyond the sequence
		if end_ix > len(sequence)-1:
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return np.array(X), np.array(y)

# %%
#Prepare batches bs*seq_len*1
X_train,y_train = split_sequence(training_set, n_steps)
print(X_train.shape)
print(len(test_set))
X_test, y_test = split_sequence(test_set, n_steps)
print(X_test.shape)
# Out:
# (1425, 10, 1)
# 30
# (20, 10, 1)

# %%
import tensorflow as tf

# %%
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', verbose=1)
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)

# %%
# define model
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.LSTM(50, activation='relu', input_shape=(n_steps, 1)))
model.add(tf.keras.layers.Dense(1))
model.compile(optimizer='adam', loss='mse')
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
model.fit(X_train, y_train, epochs=nb_epochs, verbose=1, validation_data=(X_test, y_test),callbacks=[mc, es])
# Out:
# Train on 1425 samples, validate on 20 samples
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 0.0239
# Epoch 00001: saving model to best_model.h5
# 1425/1425 [==============================] - 5s 3ms/sample - loss: 0.0231 - val_loss: 2.1318e-04
# Epoch 2/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 0.0010
# Epoch 00002: saving model to best_model.h5
# 1425/1425 [==============================] - 1s 606us/sample - loss: 0.0010 - val_loss: 1.7504e-04
# Epoch 3/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 7.6299e-04
# Epoch 00003: saving model to best_model.h5
# 1425/1425 [==============================] - 1s 696us/sample - loss: 7.4810e-04 - val_loss: 1.3900e-04
# Epoch 4/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 6.8070e-04
# Epoch 00004: saving model to best_model.h5
# 1425/1425 [==============================] - 1s 693us/sample - loss: 6.6492e-04 - val_loss: 3.1608e-04
# Epoch 5/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 6.5932e-04
# Epoch 00005: saving model to best_model.h5
# 1425/1425 [==============================] - 1s 691us/sample - loss: 6.5457e-04 - val_loss: 2.9387e-04
# Epoch 6/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 6.2508e-04
# Epoch 00006: saving model to best_model.h5
# 1425/1425 [==============================] - 1s 691us/sample - loss: 6.3909e-04 - val_loss: 2.0742e-04
# Epoch 7/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 6.3630e-04
# Epoch 00007: saving model to best_model.h5
# 1425/1425 [==============================] - 1s 692us/sample - loss: 6.3046e-04 - val_loss: 1.3112e-04
# Epoch 8/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 6.3494e-04
# Epoch 00008: saving model to best_model.h5
# 1425/1425 [==============================] - 1s 696us/sample - loss: 6.2828e-04 - val_loss: 2.4091e-04
# Epoch 9/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 6.0426e-04
# Epoch 00009: saving model to best_model.h5
# 1425/1425 [==============================] - 1s 697us/sample - loss: 5.9967e-04 - val_loss: 1.4037e-04
# Epoch 10/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 4.9331e-04
# Epoch 00010: saving model to best_model.h5
# 1425/1425 [==============================] - 1s 696us/sample - loss: 5.1341e-04 - val_loss: 1.6591e-04
# Epoch 11/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 4.4394e-04
# Epoch 00011: saving model to best_model.h5
# 1425/1425 [==============================] - 1s 691us/sample - loss: 4.7779e-04 - val_loss: 2.1148e-04
# Epoch 12/20
# 1408/1425 [============================>.] - ETA: 0s - loss: 5.2798e-04
# Epoch 00012: saving model to best_model.h5
# 1425/1425 [==============================] - 1s 729us/sample - loss: 5.2414e-04 - val_loss: 1.7235e-04
# Epoch 00012: early stopping

# %%
# load the saved model
saved_model = tf.keras.models.load_model('best_model.h5')
# evaluate the model
train_loss = saved_model.evaluate(X_train, y_train, verbose=0)
test_loss = saved_model.evaluate(X_test, y_test, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_loss, test_loss))
# Out:
# Train: 0.000, Test: 0.000

# %% [markdown]
# ## Inference

# %%
train_predictions = saved_model.predict(X_train)
test_predictions = saved_model.predict(X_test)

# %%
train_p = sc.inverse_transform(train_predictions)
test_p = sc.inverse_transform(test_predictions)

# %% [markdown]
# ## Training fit

# %%
import math
t = np.linspace(0, 2*math.pi, 1425)
plt.plot(t, sc.inverse_transform(y_train),'r')
plt.plot(t,train_p,'g')
plt.show()

# %% [markdown]
# ## Test fit

# %%
t = np.linspace(0, 2*math.pi, 20)
plt.plot(t, sc.inverse_transform(y_test),'r')
plt.plot(t,test_p,'g')
plt.show()

# %% [markdown]
# Seems like the model is overfitting, we can add dropout and gradient clipping to improve results. Lets look at second architecture.

# %% [markdown]
# ## Bidirectional LSTM Model

# %%
# define model
bi_model = tf.keras.models.Sequential()
bi_model.add(tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(50, activation='relu'), input_shape=(n_steps, 1)))
bi_model.add(tf.keras.layers.Dense(1))
bi_model.compile(optimizer='adam', loss='mse')

# %%
bi_model.fit(X_train, y_train, epochs=nb_epochs, verbose=1, validation_data=(X_test, y_test),callbacks=[mc, es])
# Out:
# Train on 1425 samples, validate on 20 samples
# Epoch 1/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 0.0196
# Epoch 00001: saving model to best_model.h5
# 1425/1425 [==============================] - 4s 3ms/sample - loss: 0.0189 - val_loss: 0.0012
# Epoch 2/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 00002: saving model to best_model.h5
# 1425/1425 [==============================] - 2s 1ms/sample - loss: 0.0011 - val_loss: 3.5031e-04
# Epoch 3/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 7.3032e-04
# Epoch 00003: saving model to best_model.h5
# 1425/1425 [==============================] - 2s 1ms/sample - loss: 7.9765e-04 - val_loss: 1.6180e-04
# Epoch 4/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 8.1081e-04
# Epoch 00004: saving model to best_model.h5
# 1425/1425 [==============================] - 2s 1ms/sample - loss: 8.1916e-04 - val_loss: 1.6325e-04
# Epoch 5/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 7.8932e-04
# Epoch 00005: saving model to best_model.h5
# 1425/1425 [==============================] - 2s 1ms/sample - loss: 7.6828e-04 - val_loss: 2.9112e-04
# Epoch 6/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 7.4772e-04
# Epoch 00006: saving model to best_model.h5
# 1425/1425 [==============================] - 2s 1ms/sample - loss: 7.5183e-04 - val_loss: 1.7511e-04
# Epoch 7/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 7.1544e-04
# Epoch 00007: saving model to best_model.h5
# 1425/1425 [==============================] - 2s 1ms/sample - loss: 7.1161e-04 - val_loss: 1.4927e-04
# Epoch 8/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 6.6033e-04
# Epoch 00008: saving model to best_model.h5
# 1425/1425 [==============================] - 2s 1ms/sample - loss: 6.7914e-04 - val_loss: 1.5791e-04
# Epoch 9/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 6.7350e-04
# Epoch 00009: saving model to best_model.h5
# 1425/1425 [==============================] - 2s 1ms/sample - loss: 6.8227e-04 - val_loss: 2.4084e-04
# Epoch 10/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 6.9682e-04
# Epoch 00010: saving model to best_model.h5
# 1425/1425 [==============================] - 2s 1ms/sample - loss: 6.7656e-04 - val_loss: 1.3375e-04
# Epoch 11/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 6.3321e-04
# Epoch 00011: saving model to best_model.h5
# 1425/1425 [==============================] - 2s 1ms/sample - loss: 6.2373e-04 - val_loss: 1.2670e-04
# Epoch 12/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 5.7550e-04
# Epoch 00012: saving model to best_model.h5
# 1425/1425 [==============================] - 2s 1ms/sample - loss: 5.6689e-04 - val_loss: 1.5011e-04
# Epoch 13/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 5.7707e-04
# Epoch 00013: saving model to best_model.h5
# 1425/1425 [==============================] - 2s 1ms/sample - loss: 5.6461e-04 - val_loss: 1.9051e-04
# Epoch 14/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 5.5518e-04
# Epoch 00014: saving model to best_model.h5
# 1425/1425 [==============================] - 2s 1ms/sample - loss: 5.5568e-04 - val_loss: 1.1818e-04
# Epoch 15/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 4.8044e-04
# Epoch 00015: saving model to best_model.h5
# 1425/1425 [==============================] - 2s 1ms/sample - loss: 4.6683e-04 - val_loss: 1.8072e-04
# Epoch 16/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 4.9889e-04
# Epoch 00016: saving model to best_model.h5
# 1425/1425 [==============================] - 2s 1ms/sample - loss: 5.0503e-04 - val_loss: 1.6196e-04
# Epoch 17/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 4.8571e-04
# Epoch 00017: saving model to best_model.h5
# 1425/1425 [==============================] - 2s 1ms/sample - loss: 5.0052e-04 - val_loss: 1.8361e-04
# Epoch 18/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 4.1473e-04
# Epoch 00018: saving model to best_model.h5
# 1425/1425 [==============================] - 2s 1ms/sample - loss: 4.1647e-04 - val_loss: 1.0606e-04
# Epoch 19/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 4.9415e-04
# Epoch 00019: saving model to best_model.h5
# 1425/1425 [==============================] - 2s 1ms/sample - loss: 4.8244e-04 - val_loss: 1.0655e-04
# Epoch 20/20
# 1376/1425 [===========================>..] - ETA: 0s - loss: 4.2316e-04
# Epoch 00020: saving model to best_model.h5
# 1425/1425 [==============================] - 2s 1ms/sample - loss: 4.1947e-04 - val_loss: 3.2809e-04

# %%
# load the saved model
saved_model2 = tf.keras.models.load_model('best_model.h5')
# evaluate the model
train_loss = saved_model2.evaluate(X_train, y_train, verbose=0)
test_loss = saved_model2.evaluate(X_test, y_test, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_loss, test_loss))
# Out:
# Train: 0.000, Test: 0.000

# %% [markdown]
# ## Inference

# %%
train_predictions = saved_model2.predict(X_train)
test_predictions = saved_model2.predict(X_test)

# %%
train_p = sc.inverse_transform(train_predictions)
test_p = sc.inverse_transform(test_predictions)

# %% [markdown]
# ## Training fit

# %%
import math
t = np.linspace(0, 2*math.pi, 1425)
plt.plot(t, sc.inverse_transform(y_train),'r')
plt.plot(t,train_p,'g')
plt.show()

# %% [markdown]
# ## Test fit

# %%
t = np.linspace(0, 2*math.pi, 20)
plt.plot(t, sc.inverse_transform(y_test),'r', label="True label")
plt.plot(t,test_p,'g', label="Predictions")
plt.legend()
plt.show()

# %% [markdown]
# ## Encoder Decoder Model For Multiple Predictions

# %% [markdown]
# ### Data Processing

# %% [markdown]
# First we need to prepare the data in such a way that multiple steps can go in as input and multiple steps can come as output.

# %%
def split_sequence(sequence, n_steps_in, n_steps_out):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_steps_in
		out_end_ix = end_ix + n_steps_out
		# check if we are beyond the sequence
		if out_end_ix > len(sequence):
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix:out_end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return np.array(X), np.array(y)

# %%
# hyperparameters
n_steps_out = 3

# %%
#Prepare batches bs*seq_len*1
X_train,y_train = split_sequence(training_set, n_steps, n_steps_out)
print(X_train.shape, y_train.shape)
X_test, y_test = split_sequence(test_set, n_steps, n_steps_out)
print(X_test.shape, y_test.shape)
# Out:
# (1423, 10, 1) (1423, 3, 1)
# (18, 10, 1) (18, 3, 1)

# %%
# define model
ed_model = tf.keras.models.Sequential()
ed_model.add(tf.keras.layers.LSTM(100, activation='relu', input_shape=(n_steps, 1)))
ed_model.add(tf.keras.layers.RepeatVector(n_steps_out))
ed_model.add(tf.keras.layers.LSTM(100, activation='relu', return_sequences=True))
ed_model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(1)))
ed_model.compile(optimizer='adam', loss='mse')

# %%
nb_epochs = 50

# %%
history = ed_model.fit(X_train, y_train, epochs=nb_epochs, verbose=1, validation_data=(X_test, y_test),callbacks=[mc, es])
# Out:
# Train on 1423 samples, validate on 18 samples
# Epoch 1/50
# 1408/1423 [============================>.] - ETA: 0s - loss: 0.0219
# Epoch 00001: saving model to best_model.h5
# 1423/1423 [==============================] - 5s 3ms/sample - loss: 0.0217 - val_loss: 0.0050
# Epoch 2/50
# 1344/1423 [===========================>..] - ETA: 0s - loss: 0.0034
# Epoch 00002: saving model to best_model.h5
# 1423/1423 [==============================] - 1s 788us/sample - loss: 0.0034 - val_loss: 4.8535e-04
# Epoch 3/50
# 1408/1423 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 00003: saving model to best_model.h5
# 1423/1423 [==============================] - 1s 798us/sample - loss: 0.0016 - val_loss: 7.0706e-04
# Epoch 4/50
# 1344/1423 [===========================>..] - ETA: 0s - loss: 0.0013
# Epoch 00004: saving model to best_model.h5
# 1423/1423 [==============================] - 1s 794us/sample - loss: 0.0013 - val_loss: 3.1916e-04
# Epoch 5/50
# 1376/1423 [============================>.] - ETA: 0s - loss: 9.9303e-04
# Epoch 00005: saving model to best_model.h5
# 1423/1423 [==============================] - 1s 786us/sample - loss: 0.0010 - val_loss: 4.1979e-04
# Epoch 6/50
# 1344/1423 [===========================>..] - ETA: 0s - loss: 9.6832e-04
# Epoch 00006: saving model to best_model.h5
# 1423/1423 [==============================] - 1s 784us/sample - loss: 9.7543e-04 - val_loss: 2.0203e-04
# Epoch 7/50
# 1408/1423 [============================>.] - ETA: 0s - loss: 8.1184e-04
# Epoch 00007: saving model to best_model.h5
# 1423/1423 [==============================] - 1s 811us/sample - loss: 8.3439e-04 - val_loss: 1.8851e-04
# Epoch 8/50
# 1344/1423 [===========================>..] - ETA: 0s - loss: 8.5237e-04
# Epoch 00008: saving model to best_model.h5
# 1423/1423 [==============================] - 1s 791us/sample - loss: 8.3581e-04 - val_loss: 2.4879e-04
# Epoch 9/50
# 1376/1423 [============================>.] - ETA: 0s - loss: 7.2303e-04
# Epoch 00009: saving model to best_model.h5
# 1423/1423 [==============================] - 1s 784us/sample - loss: 7.7336e-04 - val_loss: 2.4562e-04
# Epoch 10/50
# 1344/1423 [===========================>..] - ETA: 0s - loss: 9.6233e-04
# Epoch 00010: saving model to best_model.h5
# 1423/1423 [==============================] - 1s 797us/sample - loss: 9.4713e-04 - val_loss: 2.6416e-04
# Epoch 11/50
# 1344/1423 [===========================>..] - ETA: 0s - loss: 8.7594e-04
# Epoch 00011: saving model to best_model.h5
# 1423/1423 [==============================] - 1s 785us/sample - loss: 8.4651e-04 - val_loss: 5.0765e-04
# Epoch 12/50
# 1344/1423 [===========================>..] - ETA: 0s - loss: 8.1702e-04
# Epoch 00012: saving model to best_model.h5
# 1423/1423 [==============================] - 1s 794us/sample - loss: 8.0958e-04 - val_loss: 2.1439e-04
# Epoch 00012: early stopping

# %%
# plot training history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.title("Training Losses")
plt.show()

# %% [markdown]
# ### Inference For test set

# %%
test_predictions = ed_model.predict(X_test)
test_predictions.shape
# Out:
# (18, 3, 1)

# %%
y_pred = test_predictions[:,2,:]

# %%
y_true = y_test[:,2,:]
y_true.shape
# Out:
# (18, 1)

# %%
y_pred.shape
# Out:
# (18, 1)

# %%
t = np.linspace(0, 2*math.pi, 18)
plt.plot(t, sc.inverse_transform(y_true),'r', label="True Data")
plt.plot(t,sc.inverse_transform(y_pred),'g', label = "Prediction")
plt.legend()
plt.show()

# %% [markdown]
# ## Visualize the model

# %%
ed_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 100)               40800
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 3, 100)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 3, 100)            80400
# _________________________________________________________________
# time_distributed (TimeDistri (None, 3, 1)              101
# =================================================================
# Total params: 121,301
# Trainable params: 121,301
# Non-trainable params: 0
# _________________________________________________________________
