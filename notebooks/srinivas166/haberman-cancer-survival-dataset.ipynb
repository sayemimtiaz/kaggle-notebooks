# %% [markdown]
# # Our main obective is to classify the persons who are survived after the surgery and who are dead after the surgery.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#read the data
#Information Regarding axillary nodes and how it leads to cancer "https://www.medicalnewstoday.com/articles/319713.php"
Data=pd.read_csv('../input/haberman.csv',names=['Age', 'Year', 'Axillary_nodes_dect', 'Surv_status'])
Data

# %% [markdown]
# # Number of data-points and features including the class label

# %%
print(Data.shape)#output shows no of (rows, columns)

# %% [markdown]
# # Columns of the dataset

# %%
print(Data.columns)#output shows the column names

# %% [markdown]
# Attribute Information:
#
# * Age of patient at time of operation (numerical)
# * Patient's year of operation (year - 1900, numerical)
# * Number of positive axillary nodes detected (numerical)
# * Survival status (class attribute):
# *   1 = the patient survived 5 years or longer
# *   2 = the patient died within 5 year

# %% [markdown]
# We have two classes in Survstatus:
# 1.  person who survived after the surgery.
# 2.  person who is dead after the surgery.

# %%
Data['Surv_status'].value_counts()

# %% [markdown]
# *  It is a imbalanced-dataset
# * The no of persons who survived after the surjery are:225
# * The no of persons who dead after the surjery are:81

# %% [markdown]
# ## 2-D Scatter plot

# %%
#for age and year
Data.plot(kind='scatter', x='Age', y='Year')
plt.show()

# %% [markdown]
# # Observation

# %% [raw]
# This plot doesn't make any sense as both the data points overlap eachother
# what if we change the color of one of the data-points?

# %%
#for age and year
sns.set_style('whitegrid')
sns.FacetGrid(Data,hue='Surv_status',height=4).map(plt.scatter,"Age","Year").add_legend()
plt.title("Scatter-plot of Age and year")
plt.show()

# %% [markdown]
# # observation

# %% [raw]
# Here 1 and 2 are extensively overlapped using age and year features so classification is not possible

# %%
#for age and Axillary_nodes_dect
sns.set_style('whitegrid')
sns.FacetGrid(Data,hue='Surv_status',height=4) .map(plt.scatter,"Age","Axillary_nodes_dect").add_legend()
plt.title("Scatter-plot of Age and Axillary_nodes_dect")
plt.show()

# %% [markdown]
# # Observation

# %% [raw]
# Here also we can see that 1 and 2 are overlapped extensively using "age" and "Auxillary_nodes_dect" as features

# %%
#for year and Axillary_nodes_dect
sns.set_style('whitegrid')
sns.FacetGrid(Data,hue='Surv_status',height=4).map(plt.scatter,"Year","Axillary_nodes_dect").add_legend()
plt.title("Scatter-plot of year and Axillary_nodes_dect")
plt.show()

# %% [markdown]
# # Observation

# %% [raw]
# Here also same overlapping problem like previous two here is also classification possible.

# %% [markdown]
# # Pair-plots

# %% [raw]
# Here we get 3c2 = 3 because 3 features and out of which we only select only 2 features.

# %%
sns.set_style("whitegrid")
sns.pairplot(Data, hue="Surv_status", vars=['Age', 'Year', 'Axillary_nodes_dect'],height=4)
plt.show()

# %% [raw]
# * Ignore the diagonal graphs
# * Upper diagonal plots are same as the lower diagonal plots but axis are interchanged
# * even from pair plots we cannot classify the problem

# %% [markdown]
# # 1-D Scatter plot

# %% [raw]
# * we make use of distribution plots
# * Distribution plots show how data-points are densely distributed with respective frequency
# * Probability Density function(PDF):Is the probability that the value of the variable lies within the same interval.(smoothened histograms)
# * Here height indicates the % of data-points under the same group

# %%
#distribution plot of age
sns.FacetGrid(Data, hue="Surv_status", height=5).map(sns.distplot, "Age").add_legend()
plt.title("Histogram of Age")
plt.show()

# %%
#distribution plot of year
sns.FacetGrid(Data, hue="Surv_status", height=5).map(sns.distplot, "Year").add_legend()
plt.title("Histogram of Year")
plt.show()

# %%
#distribution plot of Auxillary_nodes_dect
sns.FacetGrid(Data, hue="Surv_status", height=10) .map(sns.distplot, "Axillary_nodes_dect") .add_legend()
plt.title("Histogram of Axillary_nodes_dect")
plt.show()

# %% [markdown]
# # Observation

# %% [raw]
# 1.from the above three distribution plots it is clear that based on "Auxillary nodes detected" we can classify the problem
#
# 2.If  <-- Auxillary_nodes_dect<=3-->  there is a high probability that the person may survive else he may dies....

# %% [markdown]
# # CDF (Commulative Distribution Function)

# %% [raw]
# * we choose auxillary_nodes_dect as our feature
# * CDF:is the probability of a variable takes a value less than or equal to the argument of the function.

# %%
surv_data = Data.loc[Data["Surv_status"] == 1]
counts, bin_edges = np.histogram(surv_data['Axillary_nodes_dect'], bins=10,density = True)
pdf = counts/(sum(counts))

cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)
plt.xlabel("Axillary_nodes_dect")
plt.legend(['PDF', 'CDF'])
plt.title("PDF and CDF of Axillary_nodes_detected")

# %% [markdown]
# # Observaton

# %% [raw]
# 1.There is 100% chance that  persons whose survival status=1 has less than 30 axillary nodes detection
# 2.There is 84% chance that  persons whose survival status=1 has less than 4 axillary nodes detection

# %%
dead_data = Data.loc[Data["Surv_status"] == 2]

counts, bin_edges = np.histogram(dead_data['Axillary_nodes_dect'], bins=10,density = True)
pdf = counts/(sum(counts))

cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)
plt.xlabel("Axillary_nodes_dect")
plt.legend(['PDF', 'CDF'])

# %% [markdown]
# # Observation

# %% [raw]
# 1.There is 97% chance that  persons whose survival status=2 has less than 30 axillary nodes detection
# 2.There is 58% chance that  persons whose survival status=2 has less than 4 axillary nodes detection

# %% [markdown]
# # Box plot and Whiskers

# %%
sns.boxplot(x='Surv_status',y='Axillary_nodes_dect',hue = "Surv_status", data=Data).set_title("BOX-plot for survival_status and axillary_nodes_dect")
plt.show()

# %% [markdown]
# # Observation

# %% [raw]
# 1.For box-plot "1" both 25th pencentile and 50th percentile are overlapped
# 2.For box-plot "2" 50th percentile is overlapping with box-plot "1" and 75th percentile shows auxillary node detects is 11

# %% [markdown]
# # Violin plots

# %%
sns.violinplot(x='Surv_status',y='Axillary_nodes_dect',hue = "Surv_status", data=Data, size=10).set_title("violin plot for Surv_status and axillary_nodes_dect")
plt.show()

# %% [raw]
# 1.50th percentile of survivors have 0 axillary nodes, 75th percentie of survivors have less than 3 axilary nodes
# 2.50th percentile of dead have more than 3 axillary nodes, 75th percentie of survivors have less than 11 axilary nodes

# %% [markdown]
# # Multivariate probability density, contour plot

# %%
sns.jointplot(x='Surv_status',y='Axillary_nodes_dect',data=Data, kind="kde")
plt.show()

# %% [markdown]
# # Conclusion

# %% [raw]
# From all the above plots we can conclude that the survival of a patient after the surgery is high who has less number of axillary limph nodes......
