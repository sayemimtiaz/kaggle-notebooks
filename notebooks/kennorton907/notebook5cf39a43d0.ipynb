# %%
# this workbook shows examples of how different countries have faired with vaccination programmes. Bhutan was chozen as a case study of how a country has done well with logistics. 
# Next France and England are examined to show how countries of similar populations have had different results with lowering cases through vaccination programmes. 
# England had much initial success with the Astra zeneca vaccine, this is reflected in evening out the new cases total at a quicker point than France

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
covid_vaccine_prog_file_path = '../input/covid-world-vaccination-progress/country_vaccinations.csv'
covid_vaccine_data = pd.read_csv(covid_vaccine_prog_file_path)

covid_19_by_country_file_path = '../input/covid19-by-country-with-government-response/covid19_by_country.csv'
covid_19_by_country_data = pd.read_csv(covid_19_by_country_file_path)

country_population_file_path = '../input/covid19-by-country-with-government-response/covid19_country_population.csv'
covid_country_pop_data = pd.read_csv(country_population_file_path)

# %%
import seaborn as sns
from scipy import stats

# %%
df_1 = covid_vaccine_data
df_2 = covid_19_by_country_data
covid_vaccine_data = df_1.join(df_2)
covid_vaccine_data.head()

# %%
covid_vaccine_data.columns

# %%
Bhutan_DF = covid_vaccine_data["country"].isin(["Bhutan"])

Bhutan_DF.value_counts()

# %%
covid_vaccine_data.iloc[Bhutan_DF.values]

# %%
Bhutan_DF_Filt = covid_vaccine_data.iloc[Bhutan_DF.values]

# %%
B_histo1 = sns.displot(Bhutan_DF_Filt['people_vaccinated_per_hundred'])

# %%
sns.scatterplot(x="daily_vaccinations", y="deaths", data=Bhutan_DF_Filt)

# %%
sns.scatterplot(x="date", y="daily_vaccinations_raw", hue="deaths", data=Bhutan_DF_Filt)

# %%
sns.scatterplot(x="date", y="daily_vaccinations", hue="confirmed_inc", data=Bhutan_DF_Filt)

# %%
Bhutan_DF_Filt[['total_vaccinations', 'deaths', 'confirmed_inc']].describe()

# %%
France_DF = covid_vaccine_data["country"].isin(["France"])

France_DF.value_counts()

# %%
France_DF_Filt = covid_vaccine_data.iloc[France_DF.values]

# %%
sns.displot(France_DF_Filt['people_vaccinated_per_hundred'])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.plot( 'date', 'total_vaccinations', data=France_DF_Filt, marker='', color='green', linewidth=2)
plt.plot( 'date', 'confirmed', data=France_DF_Filt, marker='', color='black', linewidth=2)
# show legend
plt.legend()

# show graph
plt.show()

# %%
import matplotlib.pyplot as plt

# Initalize a Figure and Axes

fig, ax = plt.subplots()

# Plot the vaccinations in blue
ax.plot(France_DF_Filt["date"], France_DF_Filt["total_vaccinations"], color='blue')

# Create a twin Axes that shares the x-axis
ax2 = ax.twinx()

# Plot the relative cases
ax2.plot(France_DF_Filt["date"], France_DF_Filt["confirmed"], color='red')


plt.show()

# %%
fig, ax = plt.subplots(figsize=(30, 10))

# Plot the vaccinations in blue
ax.plot(France_DF_Filt["date"], France_DF_Filt["total_vaccinations"], color='blue')

# Create a twin Axes that shares the x-axis
ax2 = ax.twinx()

# Plot the relative cases
ax2.plot(France_DF_Filt["date"], France_DF_Filt["confirmed"], color='red')

plt.setp(ax.get_xticklabels(), rotation=45)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(30, 10))

# Plot the vaccinations in blue
ax.plot(France_DF_Filt["date"], France_DF_Filt["daily_vaccinations_per_million"], color='blue')

# Create a twin Axes that shares the x-axis
ax2 = ax.twinx()

# Plot the relative cases
ax2.plot(France_DF_Filt["date"], France_DF_Filt["deaths"], color='red')

plt.setp(ax.get_xticklabels(), rotation=45)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(30, 10))

# Plot the vaccinations in blue
ax.plot(France_DF_Filt["date"], France_DF_Filt["confirmed"], color='blue')

# Create a twin Axes that shares the x-axis
ax2 = ax.twinx()

# Plot the relative cases
ax2.plot(France_DF_Filt["date"], France_DF_Filt["recoveries"], color='red')

plt.setp(ax.get_xticklabels(), rotation=45)

plt.show()

# %%
England_DF = covid_vaccine_data["country"].isin(["England"])

England_DF.value_counts()

# %%
England_DF_Filt = covid_vaccine_data.iloc[England_DF.values]

# %%
sns.displot(England_DF_Filt['people_vaccinated'])

# %%
fig, ax = plt.subplots(figsize=(30, 10))

# Plot the vaccinations in blue
ax.plot(England_DF_Filt["date"], England_DF_Filt["total_vaccinations"], color='green')

# Create a twin Axes that shares the x-axis
ax2 = ax.twinx()

# Plot the relative cases
ax2.plot(England_DF_Filt["date"], England_DF_Filt["confirmed"], color= 'orange')

plt.setp(ax.get_xticklabels(), rotation=45)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(30, 10))

# Plot the vaccinations in blue
ax.plot(England_DF_Filt["date"], England_DF_Filt["daily_vaccinations_per_million"], color='green')

# Create a twin Axes that shares the x-axis
ax2 = ax.twinx()

# Plot the relative deaths
ax2.plot(England_DF_Filt["date"], England_DF_Filt["deaths"], color= 'orange')

plt.setp(ax.get_xticklabels(), rotation=45)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(30, 10))

# Plot the vaccinations in blue
ax.plot(England_DF_Filt["date"], England_DF_Filt["confirmed"], color='green')

# Create a twin Axes that shares the x-axis
ax2 = ax.twinx()

# Plot the relative recoveries
ax2.plot(England_DF_Filt["date"], England_DF_Filt["recoveries"], color= 'orange')

plt.setp(ax.get_xticklabels(), rotation=45)

plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.title('amount of people vaccinated daily (England)')
sns.barplot(x=England_DF_Filt.date, y=England_DF_Filt['daily_vaccinations_per_million'])
plt.xlabel(' ')
plt.ylabel('Amount of people vaccinated');

# %%
plt.figure(figsize=(20, 10))
plt.title(' amount of people vaccinated daily (France)')
sns.barplot(x=France_DF_Filt["date"], y=France_DF_Filt['daily_vaccinations_per_million'])
plt.xlabel('date')
plt.ylabel('Amount of people vaccinated');

# %%
plt.figure(figsize=(20, 10))
plt.title('new cases(England)')
sns.barplot(x=England_DF_Filt.date, y=England_DF_Filt['confirmed'])
plt.xlabel('date')
plt.ylabel('new cases');

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# %%
plt.figure(figsize=(20, 10))
plt.title('new cases(France)')
sns.barplot(x=France_DF_Filt.date, y=France_DF_Filt['confirmed'])
plt.xlabel('date')
plt.ylabel('new cases')
dtFmt = mdates.DateFormatter('%b') # define the formatting
plt.gca().xaxis.set_major_formatter(dtFmt) # apply the format to the desired axis
plt.show();

# %%
England_DF_Filt['total_vaccinations'].corr(England_DF_Filt['confirmed'])

# A very strong relationship exists in England given how close to 1 this pearson correlation is

# %%
England_DF_Filt[['confirmed', 'total_vaccinations', 'deaths','recoveries' ]].corr()

# A strong relationship exists in England for multiple metrics given how close to 1 the pearson correlation is

# %%
England_confirmed_1 = England_DF_Filt.iloc[(England_DF_Filt['confirmed'] <=30000).values]
England_confirmed_1.info()

# %% [markdown]
# England_Jan = England_DF_Filt.iloc[(England_DF_Filt['confirmed'] >= 15000).values]
# England_Jan.info()

# %%
England_Confrimed_2 = England_DF_Filt.iloc[(England_DF_Filt['confirmed'] >=30000).values]
England_Confrimed_2.info()

# %%
stats.ttest_ind(England_confirmed_1['confirmed'], England_Confrimed_2['confirmed'])

# The p-value is small, implying that this is a real difference. New cases changed dramatically in England from Jan to April, as the vaccine lowered new amounts daily.
