# %%
import pandas as pd

# %%
df=pd.read_csv("../input/resized-2015-2019-blindness-detection-images/labels/trainLabels15.csv")

# %%
df

# %%
grp=df.groupby("level")

# %%
grp

# %%
for x in grp:
    print(x)

# %%
grp_0=grp.get_group(0)
Names0=grp_0['image']+".jpg"
Names0
type(Names0)
Names0.to_list()
len(Names0)

# %%
print(Names0)

# %%
grp_1=grp.get_group(1)
Names1=grp_1['image']+".jpg"
Names1
type(Names1)
Names1.to_list()
len(Names1)

# %%
grp_2=grp.get_group(2)
Names2=grp_2['image']+".jpg"
Names2
type(Names2)
Names2.to_list()
len(Names2)

# %%
grp_3=grp.get_group(3)
Names3=grp_3['image']+".jpg"
Names3
type(Names3)
Names3.to_list()
len(Names3)

# %%
grp_4=grp.get_group(4)
Names4=grp_4['image']+".jpg"
Names4
type(Names4)
Names4.to_list()
len(Names4)

# %%
import shutil, os

# %%
os.getcwd()

# %%
os.makedirs('./Class_1')
os.makedirs('./Class_2')
os.makedirs('./Class_3')
os.makedirs('./Class_4')

# %%
os.chdir(r'../input/resized-2015-2019-blindness-detection-images/resized train 15')

# %%
os.getcwd()

# %%
for src in Names0:
    print(os.path.basename(src))
    shutil.copy(src, "./Class_1")

# %%
for src in Names1:
    shutil.copy(src, "/kaggle/working/Class_1")

# %%
for src in Names2:
    shutil.copy(src, "/kaggle/working/Class_2")

# %%
for src in Names3:
    shutil.copy(src, "/kaggle/working/Class_3")

# %%
for src in Names4:
    shutil.copy(src, "/kaggle/working/Class_4")

# %%
os.chdir(r'C:\\Users\\win10\\DRD\\aptos2019-blindness-detection')

# %%
df=pd.read_csv("test.csv")

# %%
df

# %%
grp=df.groupby("diagnosis")
