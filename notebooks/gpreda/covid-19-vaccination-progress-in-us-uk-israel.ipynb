# %% [markdown]
# <center><h1>COVID-19 Vaccination Progress in United States, United Kingdom and Israel</h1></center>
# <br>
# <center><img src="https://c.files.bbci.co.uk/53A9/production/_115371412_gettyimages-1265248637.jpg" width=600></img></center>
#
# <br>
#
# <h1 style='background:#212AA5; border:0; color:black'><center><font color="white">Introduction</font></center></h1>
#
#
# <a id="0"></a>

# %% [markdown]
# We will look to 3 countries with record vaccination results:
#
# - United States;
# - United Kingdom;
# - Israel.
#
#
# We show here the vaccination progress. We will look to:
#
# - Total number of vaccines;
# - Percent of vaccination;
# - Daily vaccinations;
# - Daily vaccinations per million;
# - People vaccinated (vaccination scheme has 2 vaccines/person, 1st vaccination and 2nd vaccination, after 21 days);
# - People vaccination percent;
# - People fully vaccinated;
# - People fully vaccinated percent.

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.graph_objs as go
import plotly.figure_factory as ff
from plotly import tools
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.express as px
init_notebook_mode(connected=True)
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <h1 style='background:#212AA5; border:0; color:black'><center><font color="white">Analysis</font></center></h1>

# %% [markdown]
# We will plot the time evolution of the vaccination.

# %%
data_df = pd.read_csv("/kaggle/input/covid-world-vaccination-progress/country_vaccinations.csv")

# %% [markdown]
# <small><a href='#0'>Go to top</a></small>

# %%
country_vaccine_time = data_df[["country", "vaccines", "date", 'total_vaccinations', 
                                'total_vaccinations_per_hundred',  'people_vaccinated','people_vaccinated_per_hundred',
                               'daily_vaccinations','daily_vaccinations_per_million', 
                                'people_fully_vaccinated', 'people_fully_vaccinated_per_hundred'
                               ]].dropna()
country_vaccine_time.columns = ["Country", "Vaccines", "Date", 'Total vaccinations', 'Percent', 'People vaccinated', 'People percent',
                               "Daily vaccinations", "Daily vaccinations per million", 
                                'People fully vaccinated', 'People fully vaccinated percent']

# %%
from plotly.validators.scatter.marker import SymbolValidator

def plot_time_variation_countries_group(data_df, feature, title, countries):
    data = []
    marker_symbols = ["circle", "square", "hexagram"]
    
    i = 0
    for country in countries:
        df = data_df.loc[data_df.Country==country]
        trace = go.Scatter(
            x = df['Date'],y = df[feature],
            name=country,
            mode = "markers+lines",
            marker_color= 'lightblue',
            line_color= "darkblue",
            marker_line_width = 2,
            marker_size = 9,
            marker_line_color = 'darkblue',
            marker_symbol=marker_symbols[i],
            text=df['Country'])
        data.append(trace)
        i = i + 1
    layout = dict(title = title,
          xaxis = dict(title = 'Date', showticklabels=True,zeroline=True, zerolinewidth=1, zerolinecolor='grey',
                       showline=True, linewidth=2, linecolor='darkblue', mirror=True,
                       tickfont=dict(size=10,color='black'),), 
          yaxis = dict(title = feature, gridcolor='white', zeroline=True, zerolinewidth=1, zerolinecolor='grey',
                       showline=True, linewidth=2, linecolor='darkblue', mirror=True),
                       plot_bgcolor = 'rgba(0, 0, 0, 0)', paper_bgcolor = 'rgba(0, 0, 0, 0)',
         hovermode = 'x', 
         height=500
         )
    fig = dict(data=data, layout=layout)
    iplot(fig, filename='all_countries')

# %%
countries = ['United Kingdom', 'United States', 'Israel']

# %%
plot_time_variation_countries_group(country_vaccine_time, 'Percent', 'Total vaccination percent evolution', countries)

# %%
plot_time_variation_countries_group(country_vaccine_time, 'Total vaccinations', 'Total vaccination evolution', countries)

# %%
plot_time_variation_countries_group(country_vaccine_time, 'People percent', 'People vaccinated percent evolution', countries)

# %%
plot_time_variation_countries_group(country_vaccine_time, 'People vaccinated', 'People vaccinated evolution', countries)

# %%
plot_time_variation_countries_group(country_vaccine_time, 'Daily vaccinations', 'Daily vaccinations evolution', countries)

# %% [markdown]
# Daily vaccinations decreased in the last period in UK and Israel. The reason might be that most of the population that wants to be vaccinated was already vaccinated. IN US, the trend is still increasing.

# %%
plot_time_variation_countries_group(country_vaccine_time, 'Daily vaccinations per million', 'Daily vaccinations per million evolution', countries)

# %% [markdown]
# Daily vaccination per million evolution is very interesting. It was very large in Jan for Israel, now is decreasing, while in UK fluctuates and US is trending up.

# %%
plot_time_variation_countries_group(country_vaccine_time, 'People fully vaccinated percent', 'People fully vaccinated percent evolution', countries)

# %% [markdown]
# In terms of people fully vaccinated percent, Israel is at an outstanding 60%, with a saturation trend. Trend is increasing in both US and UK but in both countries the % is still small, under 9% and under 20%, respectivelly, as of April 8.

# %%
plot_time_variation_countries_group(country_vaccine_time, 'People fully vaccinated', 'People fully vaccinated evolution', countries)

# %% [markdown]
# Trend in US is amazing for people fully vaccinated. In Israel we see a saturation and in UK there is an increasing trend, but smaller than in US.

# %% [markdown]
# <small><a href='#0'>Go to top</a></small>
