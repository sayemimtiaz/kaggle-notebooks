# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns  # visualization tool

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir('../input'))

# Any results you write to the current directory are saved as output.

# %%
#We create Pandas dataframe.
data = pd.read_csv('../input/2015.csv')

# %%
#We will see the information about datasets.
data.info()

# %%
#default value is 5. We will see first 5 dataset.
data.head()

# %%
data.corr()

# %%
#correlation map
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(data.corr(), annot = True, linewidth =.5, fmt = '.1f', ax=ax)
plt.show()

# %%
data.head(10)

# %%
data.columns

# %% [markdown]
# **MATPLOTLIB**

# %%
#Line Plot
#color=color, label=label,linewidth=width of line, alpha=opacity, grid=grid, linestyle=style of line

data.Generosity.plot(kind = 'line', color = 'g',label = 'Generosity',linewidth=1,alpha = 0.5,grid = True,linestyle = ':')
data.Freedom.plot(color = 'r',label = 'Freedom',linewidth=1, alpha = 0.5,grid = True,linestyle = '-.')
plt.legend(loc='upper right')     # legend = puts label into plot
plt.xlabel('x axis')              # label = name of label
plt.ylabel('y axis')
plt.title('Line Plot')            # title = title of plot
plt.show()

# %%
#Scatter Plot
#x=Generosity y=Freedom
data.plot(kind = 'scatter', x = 'Generosity', y = 'Freedom', alpha = 0.5, color = "blue")
plt.xlabel('Generosity')
plt.ylabel('Freedom')
plt.title('Generosity-Freedom Scatter Plot')
plt.show()

# %%
#Histogram
#bins = number of bar figure
data.Freedom.plot(kind = 'hist', bins = 50, figsize = (12,12))
plt.show()

# %% [markdown]
# **DICTIONARY**

# %%
#create dictionary and look its keys and values
dictionary = {'Elon': 'Sönmez', 'Beyza':'Aytar'}
print(dictionary.keys())
print(dictionary.values())

# %%
dictionary['Şule']= "Solmaz"
print(dictionary)
dictionary['Eren'] = "Şahin"
dictionary['Arda'] = "Düzgün"
print(dictionary)
del dictionary['Şule']
print(dictionary)
print('Beyza' in dictionary)
print(dictionary)
dictionary.clear()
print(dictionary)

# %% [markdown]
# **PANDAS**

# %%
data = pd.read_csv('../input/2015.csv')

# %%
series = data['Generosity']
print(type(series))
data_frame = data[['Generosity']]
print(type(data_frame))

# %%
#1-Filtering Pandas data frame
x = data['Generosity'] > 0.5
data[x]

# %%
#2-Filtering pandas with logical_and
data[np.logical_and(data['Generosity'] > 0.5, data['Freedom'] > 0.4)]

# %%
data[(data['Generosity'] > 0.5) & (data['Freedom'] > 0.4)]

# %% [markdown]
# ********While and For Loop****

# %%
i = 0
while i!=3:
    print('i is:', i)
    i+=3
print(i, 'is equal to 3')

# %%
lis=[1, 2, 3, 4 ,5]

for index, value in enumerate(lis):
    print(index, ":", value)

# %%
#For dictionary
dictionary = {'Spain':'Madrid', 'France':'Paris', 'Turkey':'Ankara', 'Germany': 'Berlin' }
for key, value in dictionary.items():
    print(key, "," , value)
print('')
