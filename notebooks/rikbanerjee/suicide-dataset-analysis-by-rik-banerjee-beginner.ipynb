# %% [markdown]
# ***Hello I am RIK Banerjee I will try to do an analysis on this suicidal dataset.
# I will try mostly to visualise in how many ways we can actually realize number of suicides in different countries at different years
# and also some analysis on world population***

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt #data visualization
import seaborn as sns # for some advanced data visualization
# %matplotlib inline
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.

# %% [markdown]
# Now we will import our dataset

# %%
suicide = pd.read_csv('../input/master.csv')

# %% [markdown]
# Now we use dataframe.head() function to know about our dataframe named as 'suicide' here

# %%
suicide.head()

# %%
suicide.info()
suicide.describe()

# %% [markdown]
# We use info() function to find each column's non-null characters this is very much needed.For any ML model
# we have to impute null values with programmer's special care

# %%
suicide.drop(['suicides/100k pop','HDI for year','gdp_per_capita ($)'],axis=1,inplace=True)
suicide.head()

# %% [markdown]
# Here we do not need this specific columns for our analysis so I am going to
# use drop() function for cleaning our dataframe(one can use also pop_method/dropna())

# %%
#1 all over the world suicide according to the age grp
suicide.groupby('age')['suicides_no'].agg('sum').plot(kind='bar')

# %% [markdown]
# From here we can see most of the people age between 35-54 years have a higher rate of suicide
# from year 1985 to 2016
# Now we will analysis in multi level.

# %%
#2 This is a plot telling us how male are more victims of suicide than female from 1985 to 2016
suicide.groupby('sex')['suicides_no'].agg('sum').sort_values(ascending=False).plot(kind='bar',title='sucide comitted male vs female')

# %% [markdown]
# ***We have to find why male commit more suicide and this should be solved***
#
# Now previous(#1) analysis we will do again with extra division of sex

# %%
#3 take age gap and dive it between male and female

### Set figure size
plt.figure(figsize=(16,7))
###Let's plot the barplot
bar_age = sns.barplot(x = 'age', y = 'suicides_no', hue = 'sex',data = suicide)

# %% [markdown]
# ***Here we use one of the most impressive lib seaborn for this visualization*** In here we also see same relation between male and female
# suicide number

# %% [markdown]
# ***In this data sets we find countries like india and china and many more thoes not have a single entry for that
# we will see now each country's entry in dataset and again we will use countplot in seaborn***

# %%
#4
alpha =0.8   #it is a RGB rating ranging from 0<alpha<1
plt.figure(figsize=(15,20))  #This is used for figure's width,lenght
sns.countplot(y='country', data=suicide, alpha=alpha)
plt.title('Data by country')
plt.show()

# %% [markdown]
# ***Now we plot suicide by different aged people and sub group that between male and female***

# %%
#5 

### Set figure size
plt.figure(figsize=(16,7))
###Let's plot the barplot
bar_age = sns.barplot(x = 'sex', y = 'suicides_no', hue = 'age',data = suicide)

# %% [markdown]
# ***Now we will find a series object where we will get top 10 (using head()) countries having most
# number of suicides since 1985***

# %%
#6 use head(any value) to find top countries with most number of suicides
suicide_pie=suicide.groupby('country')['suicides_no'].agg('sum').sort_values(ascending=False).head(10) 
suicide_pie

# %% [markdown]
# ***We found that Russia has the most number of suicides since 1985 ***
#
# NOW Plot a pie chart using above series object

# %%
suicide_pie.plot(kind='pie')

# %% [markdown]
# ***Find above operation for a particular year (suppose 2010)
# We will see in year 2010 worldwide top10 suicidal countries worldwide***

# %%
#7
mask34=suicide['year']==2010
suicide_2010=suicide[mask34]
suicide_2010.groupby('country')['suicides_no'].agg('sum').sort_values(ascending=False).head(10).plot(kind='bar',title='In 2010 suicide no by top 10 country')

# %% [markdown]
# Here we see USA has the most number of suicides in the year of 2010 in this way we can find this data in any given year

# %% [markdown]
# ***Now we see how many types of Generation we have here***

# %%
suicide['generation'].value_counts()

# %% [markdown]
# so we have 6 different generation here

# %% [markdown]
# NOW PLOT WHICH GENERATION SUICIDES MOST AND ALSO DIVIDE THEM INTO SEX

# %%
#8 now plot which generation has most suicide number
plt.figure(figsize=(16,7))
sns.barplot(x = 'sex', y = 'suicides_no', hue = 'generation',data = suicide)

# %% [markdown]
# ***So Boomer males are most victims here***

# %% [markdown]
# ***we will see now each country's entry in dataset and again we will use countplot in seaborn***

# %%
#9
alpha =0.8   #it is a RGB rating ranging from 0<alpha<1
plt.figure(figsize=(10,14))  #This is used for figure's width,lenght
sns.countplot(y='year', data=suicide, alpha=alpha)
plt.title('Data by year')
plt.show()

# %% [markdown]
# ***WE now see suicide number worlwide according to year***

# %%
#10 suicide yearwise worlwide
plt.figure(figsize=(15,6)) 
suicide.groupby('year')['suicides_no'].agg('sum').plot(kind='bar')

# %% [markdown]
# we see from 1999 to 2003 there is a high rate of suicides.
# In 2016 we find less data(from previous operation #9) therefore for this particular year data is insuffient for analysis

# %% [markdown]
# ***Now we analyse suicidal data for any particular COUNTRY (suppose we take australia)***
# For this I prefer masking method one can also use loc or iloc for preproccesing

# %%
#11 suicide no for australia from 2000 to 2015 fo different age group
mask1=suicide['country-year']=='Australia2000'
mask2=suicide['country-year']=='Australia2001'
mask3=suicide['country-year']=='Australia2002'
mask4=suicide['country-year']=='Australia2003'
mask5=suicide['country-year']=='Australia2004'
mask6=suicide['country-year']=='Australia2005'
mask7=suicide['country-year']=='Australia2006'
mask8=suicide['country-year']=='Australia2007'
mask9=suicide['country-year']=='Australia2008'
mask10=suicide['country-year']=='Australia2009'
mask11=suicide['country-year']=='Australia2010'
mask12=suicide['country-year']=='Australia2011'
mask13=suicide['country-year']=='Australia2012'
mask14=suicide['country-year']=='Australia2013'
mask15=suicide['country-year']=='Australia2014'
mask16=suicide['country-year']=='Australia2015'
mask18=suicide['country-year']=='Australia1985'
mask19=suicide['country-year']=='Australia1986'
mask20=suicide['country-year']=='Australia1987'
mask21=suicide['country-year']=='Australia1988'
mask22=suicide['country-year']=='Australia1989'
mask23=suicide['country-year']=='Australia1990'
mask24=suicide['country-year']=='Australia1991'
mask25=suicide['country-year']=='Australia1992'
mask26=suicide['country-year']=='Australia1993'
mask27=suicide['country-year']=='Australia1994'
mask28=suicide['country-year']=='Australia1995'
mask29=suicide['country-year']=='Australia1996'
mask30=suicide['country-year']=='Australia1997'
mask31=suicide['country-year']=='Australia1998'
mask32=suicide['country-year']=='Australia1999'
suicide_australia=suicide[mask1|mask2|mask3|mask4|mask5|mask6|mask7|mask8|mask9|mask10|mask11|mask12|mask13|mask14|mask15|mask16
                         |mask18|mask19|mask20|mask21|mask22|mask23|mask24|mask25|mask26|mask27|mask28|mask29|mask30|mask31|mask32]
suicide_australia.info()
plt.figure(figsize=(15,6)) 
pld=suicide_australia.groupby('age')['suicides_no'].agg('sum').sort_values(ascending=False).plot(kind='bar',title='.......')

# %% [markdown]
# Now we Visualize in australia how suicide occur in each year

# %%
#12
plt.figure(figsize=(20,5)) 
suicide_australia.groupby('country-year')['suicides_no'].agg('sum').plot(kind='bar')

# %% [markdown]
# ***WE SEE MOST SUICIDES IN 2015 FOR AUSTRALIA***

# %%
suicide_australia.head()

# %%
plt.figure(figsize=(15,5))
sns.barplot(x = 'sex', y = 'suicides_no', hue = 'age',data =suicide_australia)

# %% [markdown]
# ***WE CAN SEE HOW FOR 35-54 years aged people commit suicide most in australia and previously we see tha same condition for
# whole world also.Thus australia also has same trend***

# %% [markdown]
# ****NOW WE WILL ANALYSE ABOUT POPULATION WORLDWIDE AND ALSO AT COUNTRY LEVEL****

# %% [markdown]
# ***For australia yearwise population growth

# %%
plt.figure(figsize=(15,5))
suicide_australia.groupby('year')['population'].agg('sum').sort_values(ascending=True).plot(kind='bar')

# %%
plt.figure(figsize=(15,5))
sns.barplot(x = 'year', y = 'population', hue = 'sex',data =suicide_australia)

# %% [markdown]
# ****Above cases we see exponential growth of population and in last plot female population increases more than male we see****

# %% [markdown]
# ***Now for Worldwide***

# %%
plt.figure(figsize=(15,5))
suicide.groupby('year')['population'].agg('sum').plot(kind='bar')

# %% [markdown]
# Here we find disaster we are far away from original result as we have data lacking.For population measurement we can not
# take this dataset we can use this for suicidal cases but when we analyse population from this we find error

# %% [markdown]
# ****let's plot the Catplot The catplot above shows the number of suicides for both males and females of different age groups for every year from 1985 to 2016****

# %%
 sns.catplot('sex','suicides_no',hue='age',col='year',data=suicide,kind='bar',col_wrap=3)

# %% [markdown]
# THIS IS A EFFICIENT WAY TO VISUALISE DATA

# %% [markdown]
# Now make a lineplot for a Male & Female population

# %%
##Now create a varible that stores a 'male' & 'female' data so we can easily plot a Lineplot
male_population = suicide.loc[suicide.loc[:, 'sex']=='male',:]
female_population =suicide.loc[suicide.loc[:, 'sex']=='female',:]

### Set figure size
plt.figure(figsize=(16,7))

##Plot the Lineplot
lp_male = sns.lineplot(x = 'year' , y = 'suicides_no' , data = male_population)
lp_female = sns.lineplot(x = 'year' , y = 'suicides_no' , data = female_population)
leg1 = plt.legend(['Males','Females'])

# %% [markdown]
# Now create the lineplot to see suicides numbers according to year with age group

# %%
###we store a range of age group in variables so we can do easily lineplot
age_5 = suicide.loc[suicide.loc[:, 'age']=='5-14 years',:]
age_15 = suicide.loc[suicide.loc[:, 'age']=='15-24 years',:]
age_25 = suicide.loc[suicide.loc[:, 'age']=='25-34 years',:]
age_35 = suicide.loc[suicide.loc[:, 'age']=='35-54 years',:]
age_55 = suicide.loc[suicide.loc[:, 'age']=='55-74 years',:]
age_75 = suicide.loc[suicide.loc[:, 'age']=='75+ years',:]

### Set figure size
plt.figure(figsize=(16,7))
####Now lets plot a line plot
age_5_lp = sns.lineplot(x='year', y='suicides_no', data=age_5)
age_15_lp = sns.lineplot(x='year', y='suicides_no', data=age_15)
age_25_lp = sns.lineplot(x='year', y='suicides_no', data=age_25)
age_35_lp = sns.lineplot(x='year', y='suicides_no', data=age_35)
age_55_lp = sns.lineplot(x='year', y='suicides_no', data=age_55)
age_75_lp = sns.lineplot(x='year', y='suicides_no', data=age_75)

##Now make the legend
leg = plt.legend(['5-14 years', '15-24 years', '25-34 years', '35-54 years', '55-74 years', '75+ years'])

# %% [markdown]
# ****If you see this useful please upvote☝️ this and follow me
# Give your opinion & Suggesions in commentbox 👇****
