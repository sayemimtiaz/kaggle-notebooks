# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import os

# %%
os.getcwd()

# %%
df_pgen1 = pd.read_csv('../input/solar-power-generation-data/Plant_1_Generation_Data.csv')

# %%
type(df_pgen1)

# %%
df_pgen1

# %%
df_pgen1.head()

# %%
df_pgen1.head(15)

# %% [markdown]
# head-object method (top 5 rows)
# *
# ex:split,join

# %%
df_pgen1.tail()

# %% [markdown]
# to see bottom n rows

# %%
df_pgen1.tail(25)

# %%
df_pgen1['SOURCE_KEY'].unique()

# %%
len(df_pgen1['SOURCE_KEY'].unique())

# %%
df_pgen1['DATE_TIME'].unique()

# %%
len((df_pgen1['DATE_TIME']).unique())

# %%
# ?pd.unique

# %%
df_pgen1['PLANT_ID']

# %%
df_pgen1['TOTAL_YIELD']

# %%
df_pgen1['DC_POWER'].max()

# %%
df_pgen1['DC_POWER'].min()

# %%
df_pgen1['AC_POWER'].max()

# %%
df_pgen1['AC_POWER'].min()

# %%
df_pgen1.info()

# %%
df_pgen1.describe()

# %%
df_pgen1[['AC_POWER','DC_POWER']]

# %%
df_pgen1 [['DATE_TIME','DAILY_YIELD','TOTAL_YIELD']]

# %%
df_pgen1.shape

# %%
df_pgen1.dtypes

# %%
categorical = df_pgen1.dtypes[df_pgen1.dtypes == "object"].index
print(categorical)

# %%
sorted(df_pgen1["DATE_TIME"])[20:25]

# %%
del df_pgen1["SOURCE_KEY"]

# %%
df_pgen1["DAILY_YIELD"].mean()  #mean of daily yield

# %%
import pandas as pd

# %%
df_pgen1 = pd.read_csv('../input/solar-power-generation-data/Plant_1_Weather_Sensor_Data.csv')

# %%
df_pgen1["IRRADIATION"].sum()  #Total Irradiation

# %%
df_pgen1["IRRADIATION"].sum()/34 #Total Irradiation per day

# %%
df_pgen1[['AMBIENT_TEMPERATURE','MODULE_TEMPERATURE']].max()  # max ambient and module temperature

# %%
len(df_pgen1['SOURCE_KEY'].unique()) #Number of inverters

# %%
df_pgen1['AC_POWER'].max() #Maximum amount of AC Power

# %%
df_pgen1['AC_POWER'].max()/34 #Maximum amount of AC power per day

# %%
df_pgen1['DC_POWER'].max() #Maximum amount of DC Power

# %%
df_pgen1['DC_POWER'].max()/34 #Maximum amount of DC Power per day

# %%
df_pgen1['AC_POWER'].min() #Minimum amount of AC Power

# %%
df_pgen1['AC_POWER'].min()/34 #Minimum amount of AC Power per day

# %%
df_pgen1['DC_POWER'].min() #Minimum amount of DC Power

# %%
df_pgen1['DC_POWER'].min()/34 #Minimum amount of DC Power per day

# %%
df_pgen1[['SOURCE_KEY','AC_POWER']].max() #inverter (source_key) has produced maximum AC power

# %%
df_pgen1[['SOURCE_KEY','DC_POWER']].max() #inverter (source_key) has produced maximum DC power

# %%
#Ranking

# %%
df_pgen1.isnull() #Missing Data

# %%
df_pgen1.notnull() #Missing Data

# %%
import pandas as pd
import os
os.getcwd()

# %%
df_pgen2 = pd.read_csv('../input/solar-power-generation-data/Plant_2_Generation_Data.csv')

# %%
df_pgen2 = pd.read_csv('../input/solar-power-generation-data/Plant_2_Weather_Sensor_Data.csv')

# %%
df_pgen2["DAILY_YIELD"].mean()  #mean of daily yield

# %%
df_pgen2["IRRADIATION"].sum()  #Total Irradiation

# %%
df_pgen2["IRRADIATION"].sum()/34 #Total Irradiation per day

# %%
df_pgen2[['AMBIENT_TEMPERATURE','MODULE_TEMPERATURE']].max()  # max ambient and module temperature

# %%
len(df_pgen2['SOURCE_KEY'].unique()) #Number of inverters

# %%
df_pgen2['AC_POWER'].max() #Maximum amount of AC Power

# %%
df_pgen2['AC_POWER'].max()/34 #Maximum amount of AC power per day

# %%
df_pgen2['DC_POWER'].max() #Maximum amount of DC Power

# %%
df_pgen2['DC_POWER'].max()/34 #Maximum amount of DC Power per day

# %%
df_pgen2['AC_POWER'].min() #Minimum amount of AC Power

# %%
df_pgen2['AC_POWER'].min()/34 #Minimum amount of AC Power per day

# %%
df_pgen2['DC_POWER'].min() #Minimum amount of DC Power

# %%
df_pgen2['DC_POWER'].min()/34 #Minimum amount of DC Power per day

# %%
df_pgen2[['SOURCE_KEY','AC_POWER']].max() #inverter (source_key) has produced maximum AC power

# %%
df_pgen2[['SOURCE_KEY','DC_POWER']].max() #inverter (source_key) has produced maximum DC power

# %%
#Ranking

# %%
df_pgen2.isnull() #Missing Data

# %%
df_pgen2.notnull() #Missing Data
