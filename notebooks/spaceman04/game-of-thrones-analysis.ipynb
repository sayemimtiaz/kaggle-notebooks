# %% [markdown]
# ***Thank you for opening my note book
# These are the questions answered in my note book related to GOT....!!**                                                                                                                                                                                                                                             *
# *  **Does Battles effects deaths? **
# * **Which Allegiance had maximum deaths?**
# * **Which Gender died more lets check?**
# * **Checking some data on attackers?**
# * **Does More alliances attacking together helps in wining the battle?**
# * **Does More alliances defending together helps in wining the battle?**
# * **Which type battle is fought most or less?**
# * **which type of battle resulted success for attacker?**
# * **Does defender size leads to wining?**
# * **In which regions most of the fights occured?**
# * **Which king attacked which region?**

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing datasets 
battles = pd.read_csv("../input/battles.csv")
deaths = pd.read_csv("../input/character-deaths.csv")

# %%
battles.describe()

# %% [markdown]
# By these details we can clearly see that, In any battle there are no more that 2 defenders. This is because defender_3 and defender_4 are NULL

# %%
battles = battles.drop(['defender_3','defender_4'],axis = 1)

# %%
deaths.describe()

# %% [markdown]
# **Does Battles effects deaths?**

# %%
#Checking the How many battles caused in which year
plt.subplot(2,1,1)
sns.countplot(battles['year'])
plt.title('How many battles caused in whuch year')
plt.show()

#Checking the maximum death caused in whuch year
plt.subplot(2,1,2)
sns.countplot(deaths['Death Year'])
plt.title('How many death caused in whuch year')
plt.show()

# %% [markdown]
# We can clearly see that the battles are directly proportional to the death. More the battles more will be the deaths and in 297 there must be natural deaths

# %% [markdown]
# **Which Allegiance had maximum deaths?**

# %%
sns.countplot(deaths['Allegiances'])
plt.xticks(Rotation = 90)
plt.title('Which allegiances people died mostly')
plt.show()

# %% [markdown]
# This clearly says those who are not in any allegiances have high chances of getting die in battles

# %% [markdown]
# **Which Gender died more lets check?**

# %%
sns.countplot(deaths['Gender'])
plt.title('Which gender died most')
plt.xticks(np.arange(2),('Female','Male'))
plt.show()

# %% [markdown]
# So In this males have high toll of death this is beacause in battles there are more males as compared to females

# %% [markdown]
# **Checking some data on attackers?**

# %%
sns.countplot(x='attacker_outcome',data = battles)
plt.title('counting of attacker\'s outcome')
plt.show()

# %% [markdown]
# This shows very clearly that mostly all the battles are won by the attackers

# %%
#Lets see which king attacked the most
plt.figure(figsize=(10,10))
plt.subplot(2,1,1)
sns.countplot(x='attacker_king',data = battles)
plt.show()

#Lets see which king defended the most
plt.figure(figsize=(15,10))
plt.subplot(2,1,2)
sns.countplot(x='defender_king',data = battles)
plt.show()

# %% [markdown]
# > Joffrey/Tommen Baratheon  is the one who attacked the most and can be said the most greedy kings
# > Robb Stark is the one who defended the most
# > This show robb stark is the one who suffered the most

# %% [markdown]
# **Does More alliances attacking together helps in wining the battle?
# **

# %%
plt.figure(figsize=(15,10))
plt.subplot(4,1,1)
sns.countplot(x= battles['attacker_1'],hue=battles['attacker_outcome'])
plt.show()

plt.figure(figsize=(15,10))
plt.subplot(4,1,2)
sns.countplot(x= battles['attacker_2'],hue=battles['attacker_outcome'])
plt.show()

plt.figure(figsize=(5,10))
plt.subplot(4,1,3)
sns.countplot(x= battles['attacker_3'],hue=battles['attacker_outcome'])
plt.show()

plt.figure(figsize=(5,10))
plt.subplot(4,1,4)
sns.countplot(x= battles['attacker_4'],hue=battles['attacker_outcome'])

plt.show()

# %% [markdown]
# By these graphs we can clearly say that more attacker will give more winning chances but some exceptions are there giants and thenns

# %% [markdown]
# **Does More alliances defending together helps in wining the battle?**

# %%
plt.figure(figsize = (15,10))
plt.subplot(2,1,1)
sns.countplot(x= battles['defender_1'],hue=battles['attacker_outcome'])
plt.xticks(rotation  = 90)
plt.show()

plt.figure(figsize = (3,5))
plt.subplot(2,1,2)
sns.countplot(x= battles['defender_2'],hue=battles['attacker_outcome'])
plt.show()

# %% [markdown]
# So we can say that more will be the defenders chances of winning will be more

# %% [markdown]
# **Which type battle is fought most or less?**

# %%
 
sns.countplot(x= battles['battle_type'])
plt.title('Which battle type is done most?')
plt.show()

# %% [markdown]
# razing battles are very less as compared to others

# %% [markdown]
# **which type of battle resulted success for attacker?**

# %%
sns.countplot(x= battles['battle_type'],hue=battles['attacker_outcome'])
plt.title('Type of battle VS Attacker_Outcome')
plt.show()

# %% [markdown]
# This clearly show ambush and razing battle are more succesfull for attackers

# %% [markdown]
# Which type of battle done by attacker king?

# %%
sns.countplot(hue= battles['battle_type'],x=battles['attacker_king'],palette = 'Set3')
plt.title('Which type of battle used by attacker king ')
plt.legend(loc = 'upper right')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# This tell which attacker king did which type of battles mostly or none

# %% [markdown]
# **Does attacker's army size leads to winning?**

# %%
sns.barplot(x='attacker_outcome',y='attacker_size',data=battles)
plt.title('Attacker_outcome VS Attacker_size')
plt.show()

# %% [markdown]
# This gave a very strange result because smaller attacker army  mostly won as compared to big army

# %% [markdown]
# **Does defender size leads to wining?**

# %%
sns.barplot(x='attacker_outcome',y='defender_size',data=battles)
plt.title('Attacker_outcome VS defender_size')
plt.show()

# %% [markdown]
# This clearly shows when there will be more defender size then there chances of winning the battle is more

# %% [markdown]
# **Does attacker prefer to battle in summers?**

# %%
sns.countplot(x='summer',data = battles)
plt.title('Counting of battles in summers')
plt.xticks(np.arange(2),('winters','summers'))
plt.show()

# %% [markdown]
# This shows that most of the battles are done in summers
# so we can say that there are more deaths in summers

# %% [markdown]
# **In which regions most of the fights occured?**

# %%
sns.countplot(x='region', data = battles)
plt.title('In which region there are mostly battles done')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# This crealy shows in the The Riverlands most of the battles took place

# %% [markdown]
# **Which king attacked which region?**

# %%
sns.countplot(x='region',hue='attacker_king', data = battles)
plt.title('Which king attacked which region')
plt.xticks(rotation = 90)
plt.legend(loc = 'upper right')
plt.show()

# %% [markdown]
# joffery attacked tthe most in riverlands
