# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import matplotlib.pyplot as plt

import numpy as np
import seaborn as sns
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# #Reading both dataset files given

# %%
import pandas as pd

items = pd.read_csv("/kaggle/input/amazon-cell-phones-reviews/20191226-items.csv")
reviews = pd.read_csv("/kaggle/input/amazon-cell-phones-reviews/20191226-reviews.csv")

# %% [markdown]
# Merging both file into one file to become easy to work with

# %%
reviews = pd.merge(reviews, items, how="left", left_on="asin", right_on="asin")

# %% [markdown]
# After merging the file, some of the column titles got messed up so rechanging the names

# %%
reviews.rename(columns={"rating_x": "rating", "title_x": "title", "title_y": "item_title", "rating_y": "overall_rating"}, inplace=True)

# %% [markdown]
# The dataset given is not ready to be used for supervised machine learning. Lucky enough the datagiven contains rating which will used to convert the data to be used for supervised machine learning. The Bar chart blow showing the distribuation for the rating in the given dataset

# %%
reviews['rating'].iplot(
    kind='hist',
    xTitle='rating',
    linecolor='black',
    yTitle='count',
    title='Review Rating Distribution')

# %% [markdown]
# The code below is checking for any review null values

# %%
reviews = reviews.dropna()
reviews = reviews.reset_index(drop=True)

# %%
reviews.isnull().sum()

# %% [markdown]
# Creating subset of the dataframe based on brands to analyze separately

# %%
#Create Brands
apple = reviews[reviews["brand"]=="Apple"].sort_values(by=["date"], ascending=False)
xiaomi = reviews[reviews["brand"]=="Xiaomi"].sort_values(by=["date"], ascending=False)
samsung = reviews[reviews["brand"]=="Samsung"].sort_values(by=["date"], ascending=False)
Motorola = reviews[reviews["brand"]=="Motorola"].sort_values(by=["date"], ascending=False)

# %% [markdown]
# Converting the column with rating into positivity column such as 1 and 2 equal to 0 which negtive. 4 and 5 to be 1 which is positive

# %%
apple.dropna(inplace=True)
apple[reviews['rating'] != 3]
apple['Positivity'] = np.where(apple['rating'] > 3, 1, 0)
cols = ['asin', 'name', 'rating', 'date','verified', 'title', 'helpfulVotes', 'brand', 'item_title','url','image','overall_rating','reviewUrl','totalReviews','price','originalPrice']
apple.drop(cols, axis=1, inplace=True)
apple.head()

# %% [markdown]
# Renaming the column boday into reviews as it hold review messages

# %%
apple.rename(columns={"body": "Review"}, inplace=True)

# %% [markdown]
#  Doing the same for Xiaomi phone reviews by converting the rating

# %%
xiaomi.dropna(inplace=True)
xiaomi[reviews['rating'] != 3]
xiaomi['Positivity'] = np.where(xiaomi['rating'] > 3, 1, 0)
cols = ['asin', 'name', 'rating', 'date', 'verified', 'title', 'helpfulVotes', 'brand', 'item_title','url','image','overall_rating','reviewUrl','totalReviews','price','originalPrice']
xiaomi.drop(cols, axis=1, inplace=True)
xiaomi.head()

# %% [markdown]
# Renaming review column from boday into Review

# %%
xiaomi.rename(columns={"body": "Review"}, inplace=True)

# %% [markdown]
# Converting Samusung reviews rating into positivty column

# %%
samsung.dropna(inplace=True)
samsung[reviews['rating'] != 3]
samsung['Positivity'] = np.where(samsung['rating'] > 3, 1, 0)
cols = ['asin', 'name', 'rating', 'date', 'verified', 'title', 'helpfulVotes', 'brand', 'item_title','url','image','overall_rating','reviewUrl','totalReviews','price','originalPrice']
samsung.drop(cols, axis=1, inplace=True)
samsung.head()

# %% [markdown]
# Renaming review column from boday into Review

# %%
samsung.rename(columns={"body": "Review"}, inplace=True)

# %% [markdown]
# Converting Samusung reviews rating into positivty column

# %%
Motorola.dropna(inplace=True)
Motorola[reviews['rating'] != 3]
Motorola['Positivity'] = np.where(Motorola['rating'] > 3, 1, 0)
cols = ['asin', 'name', 'rating', 'date', 'verified', 'title', 'helpfulVotes', 'brand', 'item_title','url','image','overall_rating','reviewUrl','totalReviews','price','originalPrice']
Motorola.drop(cols, axis=1, inplace=True)
Motorola.head()

# %%
Motorola.rename(columns={"body": "Review"}, inplace=True)

# %% [markdown]
# The bar chat below showing a comparison between positive and negtive reviews using Motorola phones

# %%
sns.catplot(x="Positivity", data=Motorola, kind="count", height=6, aspect=1.5, palette="PuBuGn_d")
plt.show();

# %% [markdown]
# The bar chat below showing a comparison between positive and negtive reviews using apple phones

# %%
sns.catplot(x="Positivity", data=apple, kind="count", height=6, aspect=1.5, palette="PuBuGn_d")
plt.show();

# %% [markdown]
# The bar chat below showing a comparison between positive and negtive reviews using samsung phones

# %%
sns.catplot(x="Positivity", data=samsung, kind="count", height=6, aspect=1.5, palette="PuBuGn_d")
plt.show();

# %% [markdown]
# The bar chat below showing a comparison between positive and negtive reviews using xiaomi phones

# %%
sns.catplot(x="Positivity", data=xiaomi, kind="count", height=6, aspect=1.5, palette="PuBuGn_d")
plt.show();

# %% [markdown]
# Checking for an empty or blanks reviews

# %%
blanks = []  # start with an empty list

for i,lb,rv in apple.itertuples():  # iterate over the DataFrame
    if type(rv)==str:            # avoid NaN values
        if rv.isspace():         # test 'review' for whitespace
            blanks.append(i)     # add matching index numbers to the list
        
print(len(blanks), 'blanks: ', blanks)

# %%
apple.drop(blanks, inplace=True)

len(apple)

# %%
blanks = []  # start with an empty list

for i,lb,rv in xiaomi.itertuples():  # iterate over the DataFrame
    if type(rv)==str:            # avoid NaN values
        if rv.isspace():         # test 'review' for whitespace
            blanks.append(i)     # add matching index numbers to the list
        
print(len(blanks), 'blanks: ', blanks)

# %%
blanks = []  # start with an empty list

for i,lb,rv in samsung.itertuples():  # iterate over the DataFrame
    if type(rv)==str:            # avoid NaN values
        if rv.isspace():         # test 'review' for whitespace
            blanks.append(i)     # add matching index numbers to the list
        
print(len(blanks), 'blanks: ', blanks)

# %% [markdown]
# #  Apple

# %% [markdown]
# **The code section below runs few actions
# TfidfVectorizer runs the following :
# * remove stop words
# * lower words function
# * bag of words
#
#
#
# And more
# The data split as well into X and Y such as X contain the reviews and Y is the positivity column
# Using the pipline from SKlearn to run tfidf vectorizer and classification algorithm Linear SVC
# printing out the confusion metrics and printing classification report
#
# The classification Algorithm will be used on the data are LinearSVC,RandomForestClassifier,DecisionTreeClassifier,naive_bayes and LogisticRegression. After running all then will compare which gives the best accuracy result for Apple data

# %% [markdown]
# # LinearSVC

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
x = apple['Review']
y = apple['Positivity']

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=42)


from sklearn.pipeline import Pipeline

text_clf = Pipeline([('tfidf',TfidfVectorizer()),('clf',LinearSVC())])

text_clf.fit(X_train,y_train)

predictions = text_clf.predict(X_test)

print(confusion_matrix(y_test,predictions))
cm = confusion_matrix(y_test,predictions)
print(classification_report(y_test,predictions))

# Report the confusion matrix
from sklearn import metrics

# %% [markdown]
# The accuracy result showing below 89% which is good enough

# %%
print(metrics.accuracy_score(y_test,predictions))

# %% [markdown]
# Running the same thing but trying now with diffrent algorithm such as RandomForestClassifier

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
x = apple['Review']
y = apple['Positivity']

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=42)


from sklearn.pipeline import Pipeline

text_clf = Pipeline([('tfidf',TfidfVectorizer()),('clf',RandomForestClassifier())])

text_clf.fit(X_train,y_train)

predictions = text_clf.predict(X_test)

print(confusion_matrix(y_test,predictions))
cm = confusion_matrix(y_test,predictions)
print(classification_report(y_test,predictions))

# %% [markdown]
# RandomForestClassifier gave less 1% accuracy than the user of Linear SVC. RandomForestClassifier gave accuracy of 88%

# %%
# Report the confusion matrix and showing accuracy result 
from sklearn import metrics
print(metrics.accuracy_score(y_test,predictions))

cm = metrics.accuracy_score(y_test,predictions)

# %% [markdown]
# Running the same thing but trying now with diffrent algorithm such as DecisionTreeClassifier

# %% [markdown]
# # DecisionTreeClassifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.tree import DecisionTreeClassifier
x = apple['Review']
y = apple['Positivity']

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=42)


from sklearn.pipeline import Pipeline

text_clf = Pipeline([('tfidf',TfidfVectorizer()),('clf',DecisionTreeClassifier())])

text_clf.fit(X_train,y_train)

predictions = text_clf.predict(X_test)

print(confusion_matrix(y_test,predictions))
cm = confusion_matrix(y_test,predictions)
print(classification_report(y_test,predictions))

# %% [markdown]
# The accuracy of DecisionTreeClassifier is less than both linear SVC and Random Forest algorithm by 6% or 7%

# %%
# Report the confusion matrix
from sklearn import metrics
print(metrics.accuracy_score(y_test,predictions))

cm = metrics.accuracy_score(y_test,predictions)

# %% [markdown]
# Running the same thing but trying now with diffrent algorithm such as naive_bayes

# %% [markdown]
# # Naive_Bayes

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
x = apple['Review']
y = apple['Positivity']

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=42)


from sklearn.pipeline import Pipeline

text_clf = Pipeline([('tfidf',TfidfVectorizer()),('clf',MultinomialNB())])

text_clf.fit(X_train,y_train)

predictions = text_clf.predict(X_test)

print(confusion_matrix(y_test,predictions))
cm = confusion_matrix(y_test,predictions)
print(classification_report(y_test,predictions))

# %% [markdown]
# The accuracy of Navie_bayes is less than both linear SVC and Random Forest algorithm but better than DecisionTreeClassifier

# %%
# Report the confusion matrix
from sklearn import metrics
print(metrics.accuracy_score(y_test,predictions))

cm = metrics.accuracy_score(y_test,predictions)

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
x = apple['Review']
y = apple['Positivity']

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=42)


from sklearn.pipeline import Pipeline

text_clf = Pipeline([('tfidf',TfidfVectorizer()),('clf',LogisticRegression())])

text_clf.fit(X_train,y_train)

predictions = text_clf.predict(X_test)

print(confusion_matrix(y_test,predictions))
cm = confusion_matrix(y_test,predictions)
print(classification_report(y_test,predictions))

# %%
# Report the confusion matrix
from sklearn import metrics
print(metrics.accuracy_score(y_test,predictions))

cm = metrics.accuracy_score(y_test,predictions)

# %% [markdown]
# # Samsung

# %% [markdown]
# The code section below runs few actions TfidfVectorizer runs the following :
#
# remove stop words
# lower words function
# bag of words
# And more
# The data split as well into X and Y such as X contain the reviews and Y is the positivity column Using the pipline from SKlearn to run tfidf vectorizer.
# Classification algorithm Linear SVC printing out the confusion metrics and printing classification report
#
# The classification Algorithm will be used on the data are LinearSVC,RandomForestClassifier,DecisionTreeClassifier,naive_bayes and LogisticRegression. After running all then will compare which gives the best accuracy result for Samsung data

# %% [markdown]
# # LinearSVC

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
x = samsung['Review']
y = samsung['Positivity']

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=42)


from sklearn.pipeline import Pipeline

text_clf = Pipeline([('tfidf',TfidfVectorizer()),('clf',LinearSVC())])

text_clf.fit(X_train,y_train)

predictions = text_clf.predict(X_test)

print(confusion_matrix(y_test,predictions))
cm = confusion_matrix(y_test,predictions)
print(classification_report(y_test,predictions))

# Report the confusion matrix
from sklearn import metrics

# %% [markdown]
# Printing the accuracy result for Samsung reviews based on the LinearSVC

# %%
# Report the confusion matrix
from sklearn import metrics
print(metrics.accuracy_score(y_test,predictions))

cm = metrics.accuracy_score(y_test,predictions)

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
x = samsung['Review']
y = samsung['Positivity']

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=42)


from sklearn.pipeline import Pipeline

text_clf = Pipeline([('tfidf',TfidfVectorizer()),('clf',RandomForestClassifier())])

text_clf.fit(X_train,y_train)

predictions = text_clf.predict(X_test)

print(confusion_matrix(y_test,predictions))
cm = confusion_matrix(y_test,predictions)
print(classification_report(y_test,predictions))

# %% [markdown]
# Printing the accuracy result for samsung reviews based on RandomForestClassifier algorithm

# %%
# Report the confusion matrix
from sklearn import metrics
print(metrics.accuracy_score(y_test,predictions))

cm = metrics.accuracy_score(y_test,predictions)

# %% [markdown]
# # DecisionTreeClassifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.tree import DecisionTreeClassifier
x = samsung['Review']
y = samsung['Positivity']

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=42)


from sklearn.pipeline import Pipeline

text_clf = Pipeline([('tfidf',TfidfVectorizer()),('clf',DecisionTreeClassifier())])

text_clf.fit(X_train,y_train)

predictions = text_clf.predict(X_test)

print(confusion_matrix(y_test,predictions))
cm = confusion_matrix(y_test,predictions)
print(classification_report(y_test,predictions))

# %% [markdown]
# Printing the accuracy result on samaung reviews based on DecisionTreeClassifier

# %%
# Report the confusion matrix
from sklearn import metrics
print(metrics.accuracy_score(y_test,predictions))

cm = metrics.accuracy_score(y_test,predictions)

# %% [markdown]
# # Naive_Bayes

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
x = samsung['Review']
y = samsung['Positivity']

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=42)


from sklearn.pipeline import Pipeline

text_clf = Pipeline([('tfidf',TfidfVectorizer()),('clf',MultinomialNB())])

text_clf.fit(X_train,y_train)

predictions = text_clf.predict(X_test)

print(confusion_matrix(y_test,predictions))
cm = confusion_matrix(y_test,predictions)
print(classification_report(y_test,predictions))

# %% [markdown]
# Printing the accuracy result on samaung reviews based on naive_bayes

# %%
# Report the confusion matrix
from sklearn import metrics
print(metrics.accuracy_score(y_test,predictions))

cm = metrics.accuracy_score(y_test,predictions)

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
x = samsung['Review']
y = samsung['Positivity']

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=42)


from sklearn.pipeline import Pipeline

text_clf = Pipeline([('tfidf',TfidfVectorizer()),('clf',LogisticRegression())])

text_clf.fit(X_train,y_train)

predictions = text_clf.predict(X_test)

print(confusion_matrix(y_test,predictions))
cm = confusion_matrix(y_test,predictions)
print(classification_report(y_test,predictions))

# %% [markdown]
# Printing the accuracy result of samsung reviews based on LogisticRegression

# %%
# Report the confusion matrix
from sklearn import metrics
print(metrics.accuracy_score(y_test,predictions))

cm = metrics.accuracy_score(y_test,predictions)

# %% [markdown]
# # Xiaomi

# %% [markdown]
# The code section below runs few actions TfidfVectorizer runs the following :
#
# remove stop words lower words function bag of words And more The data split as well into X and Y such as X contain the reviews and Y is the positivity column Using the pipline from SKlearn to run tfidf vectorizer. Classification algorithm Linear SVC printing out the confusion metrics and printing classification report
#
#
#
# The classification Algorithms will be used on the data are LinearSVC,RandomForestClassifier,DecisionTreeClassifier,naive_bayes and LogisticRegression. After running all then will compare which gives the best accuracy result for Xiaomi data

# %% [markdown]
# # LinearSVC

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
x = xiaomi['Review']
y = xiaomi['Positivity']

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=42)


from sklearn.pipeline import Pipeline

text_clf = Pipeline([('tfidf',TfidfVectorizer()),('clf',LinearSVC())])

text_clf.fit(X_train,y_train)

predictions = text_clf.predict(X_test)

print(confusion_matrix(y_test,predictions))
cm = confusion_matrix(y_test,predictions)
print(classification_report(y_test,predictions))

# Report the confusion matrix
from sklearn import metrics

# %% [markdown]
# Printing the accuracy result of samsung reviews based on LinearSVC

# %%
# Report the confusion matrix
from sklearn import metrics
print(metrics.accuracy_score(y_test,predictions))

cm = metrics.accuracy_score(y_test,predictions)

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
x = xiaomi['Review']
y = xiaomi['Positivity']

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=42)


from sklearn.pipeline import Pipeline

text_clf = Pipeline([('tfidf',TfidfVectorizer()),('clf',RandomForestClassifier())])

text_clf.fit(X_train,y_train)

predictions = text_clf.predict(X_test)

print(confusion_matrix(y_test,predictions))
cm = confusion_matrix(y_test,predictions)
print(classification_report(y_test,predictions))

# Report the confusion matrix
from sklearn import metrics

# %% [markdown]
# Printing the accuracy result based on xiaomi reviews using RandomForestClassifier

# %%
# Report the confusion matrix
from sklearn import metrics
print(metrics.accuracy_score(y_test,predictions))

cm = metrics.accuracy_score(y_test,predictions)

# %% [markdown]
# # DecisionTreeClassifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.tree import DecisionTreeClassifier
x = xiaomi['Review']
y = xiaomi['Positivity']

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=42)


from sklearn.pipeline import Pipeline

text_clf = Pipeline([('tfidf',TfidfVectorizer()),('clf',DecisionTreeClassifier())])

text_clf.fit(X_train,y_train)

predictions = text_clf.predict(X_test)

print(confusion_matrix(y_test,predictions))
cm = confusion_matrix(y_test,predictions)
print(classification_report(y_test,predictions))

# Report the confusion matrix
from sklearn import metrics

# %% [markdown]
# Printing the accuracy result based on xiaomi reviews using DecisionTreeClassifier

# %%
# Report the confusion matrix
from sklearn import metrics
print(metrics.accuracy_score(y_test,predictions))

cm = metrics.accuracy_score(y_test,predictions)

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
x = xiaomi['Review']
y = xiaomi['Positivity']

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=42)


from sklearn.pipeline import Pipeline

text_clf = Pipeline([('tfidf',TfidfVectorizer()),('clf',LogisticRegression())])

text_clf.fit(X_train,y_train)

predictions = text_clf.predict(X_test)

print(confusion_matrix(y_test,predictions))
cm = confusion_matrix(y_test,predictions)
print(classification_report(y_test,predictions))

# %% [markdown]
# Printing the accuracy result based on xiaomi reviews using LogisticRegression

# %%
# Report the confusion matrix
from sklearn import metrics
print(metrics.accuracy_score(y_test,predictions))

cm = metrics.accuracy_score(y_test,predictions)

# %% [markdown]
# # Motorola

# %% [markdown]
# **The code section below runs few actions
# TfidfVectorizer runs the following :
# * remove stop words
# * lower words function
# * bag of words
#
#
#
# And more
# The data split as well into X and Y such as X contain the reviews and Y is the positivity column
# Using the pipline from SKlearn to run tfidf vectorizer and classification algorithm Linear SVC
# printing out the confusion metrics and printing classification report
#
# The classification Algorithm will be used on the data are LinearSVC,RandomForestClassifier,DecisionTreeClassifier,naive_bayes and LogisticRegression. After running all then will compare which gives the best accuracy result for Motorola data

# %% [markdown]
# # LinearSVC

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
x = Motorola['Review']
y = Motorola['Positivity']

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=42)


from sklearn.pipeline import Pipeline

text_clf = Pipeline([('tfidf',TfidfVectorizer()),('clf',LinearSVC())])

text_clf.fit(X_train,y_train)

predictions = text_clf.predict(X_test)

print(confusion_matrix(y_test,predictions))
cm = confusion_matrix(y_test,predictions)
print(classification_report(y_test,predictions))

# Report the confusion matrix
from sklearn import metrics

# %% [markdown]
# Printing the accuracy result based on Motorola using LinearSVC

# %%
# Report the confusion matrix
from sklearn import metrics
print(metrics.accuracy_score(y_test,predictions))

cm = metrics.accuracy_score(y_test,predictions)

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
x = Motorola['Review']
y = Motorola['Positivity']

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=42)


from sklearn.pipeline import Pipeline

text_clf = Pipeline([('tfidf',TfidfVectorizer()),('clf',RandomForestClassifier())])

text_clf.fit(X_train,y_train)

predictions = text_clf.predict(X_test)

print(confusion_matrix(y_test,predictions))
cm = confusion_matrix(y_test,predictions)
print(classification_report(y_test,predictions))

# %% [markdown]
# Printing the accuracy result based on Motorola reviews using RandomForestClassifier

# %%
# Report the confusion matrix
from sklearn import metrics
print(metrics.accuracy_score(y_test,predictions))

cm = metrics.accuracy_score(y_test,predictions)

# %% [markdown]
# # DecisionTreeClassifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.tree import DecisionTreeClassifier
x = Motorola['Review']
y = Motorola['Positivity']

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=42)


from sklearn.pipeline import Pipeline

text_clf = Pipeline([('tfidf',TfidfVectorizer()),('clf',DecisionTreeClassifier())])

text_clf.fit(X_train,y_train)

predictions = text_clf.predict(X_test)

print(confusion_matrix(y_test,predictions))
cm = confusion_matrix(y_test,predictions)
print(classification_report(y_test,predictions))

# %% [markdown]
# Printing the accuracy result based on Motorola reviews using DecisionTreeClassifier

# %%
# Report the confusion matrix
from sklearn import metrics
print(metrics.accuracy_score(y_test,predictions))

cm = metrics.accuracy_score(y_test,predictions)

# %% [markdown]
# # Naive_Bayes

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
x = Motorola['Review']
y = Motorola['Positivity']

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=42)


from sklearn.pipeline import Pipeline

text_clf = Pipeline([('tfidf',TfidfVectorizer()),('clf',MultinomialNB())])

text_clf.fit(X_train,y_train)

predictions = text_clf.predict(X_test)

print(confusion_matrix(y_test,predictions))
cm = confusion_matrix(y_test,predictions)
print(classification_report(y_test,predictions))

# %% [markdown]
# Printing the accuracy result based on Motorola reviews using naive_bayes

# %%
# Report the confusion matrix
from sklearn import metrics
print(metrics.accuracy_score(y_test,predictions))

cm = metrics.accuracy_score(y_test,predictions)

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
x = Motorola['Review']
y = Motorola['Positivity']

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=42)


from sklearn.pipeline import Pipeline

text_clf = Pipeline([('tfidf',TfidfVectorizer()),('clf',LogisticRegression())])

text_clf.fit(X_train,y_train)

predictions = text_clf.predict(X_test)

print(confusion_matrix(y_test,predictions))
cm = confusion_matrix(y_test,predictions)
print(classification_report(y_test,predictions))

# %% [markdown]
# Printing the accuracy result based on Motorola reviews using LogisticRegression

# %%
# Report the confusion matrix
from sklearn import metrics
print(metrics.accuracy_score(y_test,predictions))

cm = metrics.accuracy_score(y_test,predictions)
