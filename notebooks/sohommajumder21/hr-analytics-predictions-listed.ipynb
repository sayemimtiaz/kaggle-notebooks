# %%
import pandas as pd
import numpy as np
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

# %%
df_train = pd.read_csv("../input/hr-analytics-job-change-of-data-scientists/aug_train.csv")
df_test = pd.read_csv("../input/hr-analytics-job-change-of-data-scientists/aug_test.csv")
df_train.head()

# %%
df_test.head()

# %%
train=df_train.drop(['enrollee_id','city'], axis =1)

# %%
train.head()

# %%
test = df_test.drop(['enrollee_id','city'], axis =1)

# %%
df_train.isnull().sum()

# %%
train.fillna(method='ffill', inplace = True)

# %%
train.isnull().sum()

# %%
train['company_size'].fillna(method = 'bfill', inplace = True)
train['company_type'].fillna(method = 'bfill', inplace = True)

# %%
train.isnull().sum()

# %%
test = pd.get_dummies(data=test)
train = pd.get_dummies(data = train)

# %%
test.isnull().sum().sum()

# %%
X_train = train.drop(['target'], axis = 1)
y_train = train['target']
X_test = test

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators = 200)
model.fit(X_train,y_train)

# %%
pred = model.predict(X_test)

# %%
pred.tolist()
