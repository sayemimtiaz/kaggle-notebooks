# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['coinbaseUSD_1-min_data_2014-12-01_to_2019-01-09.csv', 'bitstampUSD_1-min_data_2012-01-01_to_2019-03-13.csv']

# %%
bc_history = pd.read_csv('../input/bitstampUSD_1-min_data_2012-01-01_to_2019-03-13.csv')
bc_history_nonan = bc_history.dropna(thresh=2)

# %%
bc_history
# Out:
#           Timestamp     Open       ...        Volume_(Currency)  Weighted_Price
# 0        1325317920     4.39       ...                 2.000000        4.390000
# 1        1325317980      NaN       ...                      NaN             NaN
# 2        1325318040      NaN       ...                      NaN             NaN
# 3        1325318100      NaN       ...                      NaN             NaN
# 4        1325318160      NaN       ...                      NaN             NaN
# 5        1325318220      NaN       ...                      NaN             NaN
# 6        1325318280      NaN       ...                      NaN             NaN
# 7        1325318340      NaN       ...                      NaN             NaN
# 8        1325318400      NaN       ...                      NaN             NaN
# 9        1325318460      NaN       ...                      NaN             NaN
# 10       1325318520      NaN       ...                      NaN             NaN
# 11       1325318580      NaN       ...                      NaN             NaN
# 12       1325318640      NaN       ...                      NaN             NaN
# 13       1325318700      NaN       ...                      NaN             NaN
# 14       1325318760      NaN       ...                      NaN             NaN
# 15       1325318820      NaN       ...                      NaN             NaN
# 16       1325318880      NaN       ...                      NaN             NaN
# 17       1325318940      NaN       ...                      NaN             NaN
# 18       1325319000      NaN       ...                      NaN             NaN
# 19       1325319060      NaN       ...                      NaN             NaN
# 20       1325319120      NaN       ...                      NaN             NaN
# 21       1325319180      NaN       ...                      NaN             NaN
# 22       1325319240      NaN       ...                      NaN             NaN
# 23       1325319300      NaN       ...                      NaN             NaN
# 24       1325319360      NaN       ...                      NaN             NaN
# 25       1325319420      NaN       ...                      NaN             NaN
# 26       1325319480      NaN       ...                      NaN             NaN
# 27       1325319540      NaN       ...                      NaN             NaN
# 28       1325319600      NaN       ...                      NaN             NaN
# 29       1325319660      NaN       ...                      NaN             NaN
# ...             ...      ...       ...                      ...             ...
# 3778787  1552433460  3860.32       ...              2431.025630     3860.289590
# 3778788  1552433520  3859.34       ...                27.173613     3859.340000
# 3778789  1552433580  3858.19       ...                64.709563     3858.190000
# 3778790  1552433640  3858.19       ...                48.089135     3857.614252
# 3778791  1552433700  3856.73       ...              4744.210880     3856.976906
# 3778792  1552433760  3857.17       ...               255.563587     3857.170000
# 3778793  1552433820  3856.12       ...               277.648352     3856.120000
# 3778794  1552433880  3854.42       ...            531878.688990     3850.419039
# 3778795  1552433940  3850.00       ...             42108.648691     3850.239829
# 3778796  1552434000  3854.78       ...              1243.595574     3854.780556
# 3778797  1552434060  3854.80       ...                55.566942     3854.800000
# 3778798  1552434120      NaN       ...                      NaN             NaN
# 3778799  1552434180  3854.80       ...               500.820476     3854.842750
# 3778800  1552434240  3855.29       ...                76.972412     3855.085559
# 3778801  1552434300  3855.29       ...              5051.734832     3854.970380
# 3778802  1552434360  3855.29       ...              4112.212414     3856.248195
# 3778803  1552434420      NaN       ...                      NaN             NaN
# 3778804  1552434480  3856.54       ...               826.017167     3856.423605
# 3778805  1552434540      NaN       ...                      NaN             NaN
# 3778806  1552434600  3856.72       ...              2669.846798     3856.974818
# 3778807  1552434660  3857.21       ...              2092.640913     3857.456219
# 3778808  1552434720      NaN       ...                      NaN             NaN
# 3778809  1552434780  3857.59       ...              1147.336872     3857.939815
# 3778810  1552434840  3858.17       ...               186.735428     3858.170000
# 3778811  1552434900  3857.80       ...             78591.965693     3857.823469
# 3778812  1552434960      NaN       ...                      NaN             NaN
# 3778813  1552435020      NaN       ...                      NaN             NaN
# 3778814  1552435080  3860.09       ...              1461.770077     3860.606378
# 3778815  1552435140  3860.18       ...              4077.863045     3860.139080
# 3778816  1552435200  3861.37       ...               765.149137     3861.967464
#
# [3778817 rows x 8 columns]

# %%
bc_history_nonan.head()
# Out:
#        Timestamp  Open       ...        Volume_(Currency)  Weighted_Price
# 0     1325317920  4.39       ...                 2.000000        4.390000
# 478   1325346600  4.39       ...               210.720000        4.390000
# 547   1325350740  4.50       ...               171.380338        4.526411
# 548   1325350800  4.58       ...                41.220000        4.580000
# 1224  1325391360  4.58       ...                 6.879160        4.580000
#
# [5 rows x 8 columns]

# %% [markdown]
# ## Data Preprocessing
#
# There are two possibilities for missing data in our dataset (as explained in the dataset description):
# 1. When at a given timestamp there is no trade or activity the field will be filled with NaN value
# 2. When there are some technical error (such as the API is down) then the timestamp is missing (the dataset are recorded on each minutes

# %% [markdown]
# ### Selecting data
#
# In here, we're going to select dataset with minimal missing timestamp jump

# %%
bc_history_nonan['Delta_Timestamp'] = bc_history_nonan['Timestamp'] - bc_history_nonan['Timestamp'].shift(1)
bc_history_nonan['Delta_Timestamp']
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# 0              NaN
# 478        28680.0
# 547         4140.0
# 548           60.0
# 1224       40560.0
# 1896       40320.0
# 2333       26220.0
# 3612       76740.0
# 4553       56460.0
# 4710        9420.0
# 4742        1920.0
# 4780        2280.0
# 4878        5880.0
# 4882         240.0
# 4894         720.0
# 4895          60.0
# 5545       39000.0
# 5593        2880.0
# 6049       27360.0
# 6065         960.0
# 6227        9720.0
# 6241         840.0
# 6242          60.0
# 6248         360.0
# 6359        6660.0
# 6828       28140.0
# 6960        7920.0
# 7167       12420.0
# 7266        5940.0
# 7271         300.0
#             ...
# 3778779       60.0
# 3778780       60.0
# 3778781       60.0
# 3778782       60.0
# 3778783       60.0
# 3778786      180.0
# 3778787       60.0
# 3778788       60.0
# 3778789       60.0
# 3778790       60.0
# 3778791       60.0
# 3778792       60.0
# 3778793       60.0
# 3778794       60.0
# 3778795       60.0
# 3778796       60.0
# 3778797       60.0
# 3778799      120.0
# 3778800       60.0
# 3778801       60.0
# 3778802       60.0
# 3778804      120.0
# 3778806      120.0
# 3778807       60.0
# 3778809      120.0
# 3778810       60.0
# 3778811       60.0
# 3778814      180.0
# 3778815       60.0
# 3778816       60.0
# Name: Delta_Timestamp, Length: 2551132, dtype: float64

# %%
bc_history_nonan['Delta_Timestamp'].tail(5000)
# Out:
# 3773153    180.0
# 3773154     60.0
# 3773155     60.0
# 3773156     60.0
# 3773157     60.0
# 3773158     60.0
# 3773159     60.0
# 3773160     60.0
# 3773163    180.0
# 3773164     60.0
# 3773165     60.0
# 3773170    300.0
# 3773172    120.0
# 3773173     60.0
# 3773174     60.0
# 3773175     60.0
# 3773176     60.0
# 3773177     60.0
# 3773178     60.0
# 3773179     60.0
# 3773180     60.0
# 3773181     60.0
# 3773182     60.0
# 3773183     60.0
# 3773184     60.0
# 3773185     60.0
# 3773186     60.0
# 3773187     60.0
# 3773188     60.0
# 3773189     60.0
#            ...
# 3778779     60.0
# 3778780     60.0
# 3778781     60.0
# 3778782     60.0
# 3778783     60.0
# 3778786    180.0
# 3778787     60.0
# 3778788     60.0
# 3778789     60.0
# 3778790     60.0
# 3778791     60.0
# 3778792     60.0
# 3778793     60.0
# 3778794     60.0
# 3778795     60.0
# 3778796     60.0
# 3778797     60.0
# 3778799    120.0
# 3778800     60.0
# 3778801     60.0
# 3778802     60.0
# 3778804    120.0
# 3778806    120.0
# 3778807     60.0
# 3778809    120.0
# 3778810     60.0
# 3778811     60.0
# 3778814    180.0
# 3778815     60.0
# 3778816     60.0
# Name: Delta_Timestamp, Length: 5000, dtype: float64

# %% [markdown]
# From the data above, we know 5000 lastest data only missing some empty values (this including timestamp jump and NaN values), so we will use it for processing.

# %%
bc_history = bc_history.tail(5000)
bc_history.head()
# Out:
#           Timestamp     Open       ...        Volume_(Currency)  Weighted_Price
# 3773817  1552135260  3902.62       ...              1883.936114     3903.105223
# 3773818  1552135320  3903.11       ...             18452.636311     3903.110000
# 3773819  1552135380  3903.11       ...              4488.615500     3903.143913
# 3773820  1552135440  3903.11       ...             23395.765313     3903.329266
# 3773821  1552135500  3901.65       ...             34331.851306     3901.924206
#
# [5 rows x 8 columns]

# %% [markdown]
# ### Missing values replacement

# %% [markdown]
# Replace NaN field with previous data for continuous timeseries data

# %%
bc_history['Open'].fillna(method='ffill', inplace=True)
bc_history['High'].fillna(method='ffill', inplace=True)
bc_history['Low'].fillna(method='ffill', inplace=True)
bc_history['Close'].fillna(method='ffill', inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py:5434: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %% [markdown]
# Replace NaN field with zeros for single event data

# %%
bc_history['Volume_(BTC)'].fillna(value=0, inplace=True)
bc_history['Volume_(Currency)'].fillna(value=0, inplace=True)
bc_history['Weighted_Price'].fillna(value=0, inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py:5434: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
bc_history.head()
# Out:
#           Timestamp     Open       ...        Volume_(Currency)  Weighted_Price
# 3773817  1552135260  3902.62       ...              1883.936114     3903.105223
# 3773818  1552135320  3903.11       ...             18452.636311     3903.110000
# 3773819  1552135380  3903.11       ...              4488.615500     3903.143913
# 3773820  1552135440  3903.11       ...             23395.765313     3903.329266
# 3773821  1552135500  3901.65       ...             34331.851306     3901.924206
#
# [5 rows x 8 columns]

# %%
copy_of_bc = bc_history.copy()
bc_history.drop('Timestamp', axis=1, inplace=True)
bc_history
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# 3778808  3857.21  3857.68       ...                 0.000000        0.000000
# 3778809  3857.59  3858.17       ...              1147.336872     3857.939815
# 3778810  3858.17  3858.17       ...               186.735428     3858.170000
# 3778811  3857.80  3860.09       ...             78591.965693     3857.823469
# 3778812  3857.80  3860.09       ...                 0.000000        0.000000
# 3778813  3857.80  3860.09       ...                 0.000000        0.000000
# 3778814  3860.09  3861.05       ...              1461.770077     3860.606378
# 3778815  3860.18  3860.18       ...              4077.863045     3860.139080
# 3778816  3861.37  3862.01       ...               765.149137     3861.967464
#
# [5000 rows x 7 columns]

# %% [markdown]
# # Testing Linear Regression

# %%
from scipy import stats

def rem_outlier(df, col):
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    r = q3 - q1 #range between q1 and q3
    low = q1 - 1.5 * r
    hi = q3 + 1.5 * r
    out = df.loc[(df[col] > low) & (df[col] < hi)]
    return out

for feature in list(bc_history):
    bc_history = rem_outlier(bc_history,feature)

bc_history = bc_history[(np.abs(stats.zscore(bc_history)) < 2.9999999).all(axis=1)]
bc_history = bc_history[(np.abs(stats.zscore(bc_history)) > -2.999999).all(axis=1)]
bc_history
# Out:
#             Open     High       ...        Volume_(Currency)  Weighted_Price
# 3773817  3902.62  3903.11       ...              1883.936114     3903.105223
# 3773818  3903.11  3903.11       ...             18452.636311     3903.110000
# 3773819  3903.11  3903.37       ...              4488.615500     3903.143913
# 3773823  3901.88  3901.88       ...              3318.623076     3901.880000
# 3773825  3900.61  3900.70       ...               939.154696     3900.678811
# 3773826  3901.34  3901.34       ...             19211.923637     3900.709691
# 3773827  3900.70  3900.70       ...                23.404200     3900.700000
# 3773828  3900.70  3900.70       ...                11.066286     3900.700000
# 3773829  3899.49  3900.67       ...              2940.660320     3900.080000
# 3773830  3900.67  3901.07       ...              8566.513231     3900.957744
# 3773831  3902.07  3902.96       ...              2262.996753     3902.564117
# 3773832  3902.96  3902.96       ...              5942.387623     3902.298662
# 3773833  3902.07  3903.49       ...              8357.881284     3902.164048
# 3773834  3903.00  3903.00       ...               121.219241     3902.970571
# 3773835  3903.00  3904.28       ...             15847.941501     3903.458538
# 3773837  3905.46  3908.96       ...              9095.824775     3906.026532
# 3773838  3905.84  3909.26       ...              7877.821393     3908.535765
# 3773839  3907.94  3908.80       ...              6521.280531     3908.760736
# 3773840  3909.13  3909.13       ...              5023.480230     3908.820008
# 3773841  3909.09  3909.09       ...               441.432021     3907.941985
# 3773842  3907.61  3907.61       ...                34.634554     3907.610000
# 3773843  3908.99  3908.99       ...             17820.730664     3907.005288
# 3773844  3909.13  3909.13       ...              5351.459265     3909.075208
# 3773846  3916.54  3916.54       ...             11175.482364     3911.970949
# 3773847  3909.76  3911.07       ...              4083.771738     3910.881559
# 3773856  3905.17  3907.62       ...              4637.383988     3907.192894
# 3773857  3905.04  3907.85       ...               460.389794     3907.156254
# 3773858  3907.75  3909.52       ...             10454.208268     3908.288388
# 3773859  3908.25  3908.25       ...               171.572175     3908.250000

#         }    #T_94d74052_7316_11e9_9443_0242ac130002row4_col4 {
#             background-color:  #b40426;
#         }    #T_94d74052_7316_11e9_9443_0242ac130002row4_col5 {
#             background-color:  #b40426;
#         }    #T_94d74052_7316_11e9_9443_0242ac130002row4_col6 {
#             background-color:  #3c4ec2;
#         }    #T_94d74052_7316_11e9_9443_0242ac130002row5_col0 {
#             background-color:  #3c4ec2;
#         }    #T_94d74052_7316_11e9_9443_0242ac130002row5_col1 {
#             background-color:  #3e51c5;
#         }    #T_94d74052_7316_11e9_9443_0242ac130002row5_col2 {
#             background-color:  #3b4cc0;
#         }    #T_94d74052_7316_11e9_9443_0242ac130002row5_col3 {
#             background-color:  #3c4ec2;
#         }    #T_94d74052_7316_11e9_9443_0242ac130002row5_col4 {
#             background-color:  #b40426;
#         }    #T_94d74052_7316_11e9_9443_0242ac130002row5_col5 {
#             background-color:  #b40426;
#         }    #T_94d74052_7316_11e9_9443_0242ac130002row5_col6 {
#             background-color:  #3c4ec2;
#         }    #T_94d74052_7316_11e9_9443_0242ac130002row6_col0 {
#             background-color:  #b40426;
#         }    #T_94d74052_7316_11e9_9443_0242ac130002row6_col1 {
#             background-color:  #b40426;
#         }    #T_94d74052_7316_11e9_9443_0242ac130002row6_col2 {
#             background-color:  #b40426;
#         }    #T_94d74052_7316_11e9_9443_0242ac130002row6_col3 {
#             background-color:  #b40426;
#         }    #T_94d74052_7316_11e9_9443_0242ac130002row6_col4 {
#             background-color:  #3b4cc0;
#         }    #T_94d74052_7316_11e9_9443_0242ac130002row6_col5 {
#             background-color:  #3c4ec2;
#         }    #T_94d74052_7316_11e9_9443_0242ac130002row6_col6 {
#             background-color:  #b40426;
#         }</style>
# <table id="T_94d74052_7316_11e9_9443_0242ac130002" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Open</th>
#         <th class="col_heading level0 col1" >High</th>
#         <th class="col_heading level0 col2" >Low</th>
#         <th class="col_heading level0 col3" >Close</th>
#         <th class="col_heading level0 col4" >Volume_(BTC)</th>
#         <th class="col_heading level0 col5" >Volume_(Currency)</th>
#         <th class="col_heading level0 col6" >Weighted_Price</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_94d74052_7316_11e9_9443_0242ac130002level0_row0" class="row_heading level0 row0" >Open</th>
#         <td id="T_94d74052_7316_11e9_9443_0242ac130002row0_col0" class="data row0 col0" >1.0</td>
#         <td id="T_94d74052_7316_11e9_9443_0242ac130002row0_col1" class="data row0 col1" >1.0</td>
#         <td id="T_94d74052_7316_11e9_9443_0242ac130002row0_col2" class="data row0 col2" >1.0</td>
#         <td id="T_94d74052_7316_11e9_9443_0242ac130002row0_col3" class="data row0 col3" >1.0</td>
#         <td id="T_94d74052_7316_11e9_9443_0242ac130002row0_col4" class="data row0 col4" >-0.069</td>
#         <td id="T_94d74052_7316_11e9_9443_0242ac130002row0_col5" class="data row0 col5" >-0.062</td>
#         <td id="T_94d74052_7316_11e9_9443_0242ac130002row0_col6" class="data row0 col6" >1.0</td>
#     </tr>    <tr>
#         <th id="T_94d74052_7316_11e9_9443_0242ac130002level0_row1" class="row_heading level0 row1" >High</th>
#         <td id="T_94d74052_7316_11e9_9443_0242ac130002row1_col0" class="data row1 col0" >1.0</td>
#         <td id="T_94d74052_7316_11e9_9443_0242ac130002row1_col1" class="data row1 col1" >1.0</td>
#         <td id="T_94d74052_7316_11e9_9443_0242ac130002row1_col2" class="data row1 col2" >1.0</td>
#         <td id="T_94d74052_7316_11e9_9443_0242ac130002row1_col3" class="data row1 col3" >1.0</td>
#         <td id="T_94d74052_7316_11e9_9443_0242ac130002row1_col4" class="data row1 col4" >-0.061</td>
#         <td id="T_94d74052_7316_11e9_9443_0242ac130002row1_col5" class="data row1 col5" >-0.055</td>
#         <td id="T_94d74052_7316_11e9_9443_0242ac130002row1_col6" class="data row1 col6" >1.0</td>
#     </tr>    <tr>
#         <th id="T_94d74052_7316_11e9_9443_0242ac130002level0_row2" class="row_heading level0 row2" >Low</th>
#         <td id="T_94d74052_7316_11e9_9443_0242ac130002row2_col0" class="data row2 col0" >1.0</td>
#         <td id="T_94d74052_7316_11e9_9443_0242ac130002row2_col1" class="data row2 col1" >1.0</td>
#         <td id="T_94d74052_7316_11e9_9443_0242ac130002row2_col2" class="data row2 col2" >1.0</td>
#         <td id="T_94d74052_7316_11e9_9443_0242ac130002row2_col3" class="data row2 col3" >1.0</td>
#         <td id="T_94d74052_7316_11e9_9443_0242ac130002row2_col4" class="data row2 col4" >-0.077</td>
#         <td id="T_94d74052_731

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# 3778787 -0.450591 -0.470013       ...                -0.439343     3860.289590
# 3778788 -0.485314 -0.504778       ...                -0.870386     3859.340000
# 3778789 -0.526059 -0.545574       ...                -0.863655     3858.190000
# 3778790 -0.526059 -0.545574       ...                -0.866636     3857.614252
# 3778791 -0.577788 -0.584952       ...                -0.024558     3856.976906
# 3778792 -0.562198 -0.581759       ...                -0.829433     3857.170000
# 3778793 -0.599401 -0.619008       ...                -0.825472     3856.120000
# 3778796 -0.646878 -0.666189       ...                -0.652265     3854.780556
# 3778797 -0.646169 -0.665835       ...                -0.865295     3854.800000
# 3778799 -0.646169 -0.648452       ...                -0.785455     3854.842750
# 3778800 -0.628808 -0.648452       ...                -0.861456     3855.085559
# 3778801 -0.628808 -0.648452       ...                 0.030586     3854.970380
# 3778802 -0.628808 -0.604108       ...                -0.137884     3856.248195
# 3778804 -0.584520 -0.604108       ...                -0.727143     3856.423605
# 3778806 -0.578142 -0.586371       ...                -0.396519     3856.974818
# 3778807 -0.560781 -0.563667       ...                -0.500020     3857.456219
# 3778809 -0.547317 -0.546284       ...                -0.669526     3857.939815
# 3778810 -0.526767 -0.546284       ...                -0.841774     3858.170000
# 3778814 -0.458740 -0.444116       ...                -0.613143     3860.606378
# 3778815 -0.455552 -0.474979       ...                -0.144043     3860.139080
# 3778816 -0.413389 -0.410060       ...                -0.738057     3861.967464
#
# [3592 rows x 7 columns]

# %%
msk = np.random.rand(len(bc_history)) < 0.7
bc_history_train = bc_history[msk]
bc_history_test = bc_history[~msk]

y_train = bc_history_train['Weighted_Price']
X_train = bc_history_train[[feature for feature in list(bc_history) if feature != 'Weighted_Price']]

y_test = bc_history['Weighted_Price']
X_test = bc_history[[feature for feature in list(bc_history) if feature != 'Weighted_Price']]

# %%
from sklearn import metrics, decomposition

pca = decomposition.PCA(n_components=6)
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

print(X_train.shape)
print(X_test.shape)
# Out:
# (2511, 6)
# (3592, 6)

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import time
# %matplotlib inline

linear_regression = LinearRegression()
start = time.time()
linear_regression.fit(X_train,y_train)
end = time.time()
print(end - start)
predict = linear_regression.predict(X_test)
print(linear_regression.score(X_test,y_test))

y_len = range(len(y_test)) 
y_act = y_test 
plt.scatter(y_len,y_act) 
plt.scatter(y_len,predict) 
plt.gca().legend(('Actual','Predicted')) 
plt.show()
# Out:
# 0.0031473636627197266
# 0.9997586999649641

# %%
from sklearn.model_selection import GridSearchCV


normalize = [False,True]
n_jobs = [0,1,5,10]
fit_intercept = [False,True]
copy_X = [False,True]
param_grid = dict(normalize=normalize,
                  fit_intercept=fit_intercept,n_jobs=n_jobs,copy_X=copy_X)
grid = GridSearchCV(estimator=linear_regression,
                    param_grid=param_grid,
                    cv=5)
grid_result = grid.fit(X_train, y_train)
grid_result.best_params_
# Out:
# {'copy_X': False, 'fit_intercept': True, 'n_jobs': 0, 'normalize': False}

# %%
linear_regression = LinearRegression(fit_intercept=True, n_jobs=0, normalize=False, copy_X=False)
start = time.time()
linear_regression.fit(X_train,y_train)
end = time.time()
print(end - start)
predict = linear_regression.predict(X_test)
print(linear_regression.score(X_test,y_test))

y_len = range(len(y_test)) 
y_act = y_test 
plt.scatter(y_len,y_act) 
plt.scatter(y_len,predict) 
plt.gca().legend(('Actual','Predicted')) 
plt.show()
# Out:
# 0.09598469734191895
# 0.9997586999649641

# %% [markdown]
# # Testing Recurrent Neural Network
#
# In here, we use Recurrent Neural Network (RNN) using one Long Short Term Memory (LSTM) layer as its hidden layer. We convert the time unit from 60 seconds to be grouped each day. The prediction is for one month length

# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt

from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# Import the dataset and encode the date
df = pd.read_csv("../input/coinbaseUSD_1-min_data_2014-12-01_to_2019-01-09.csv")
df['date'] = pd.to_datetime(df['Timestamp'],unit='s').dt.date
group = df.groupby('date')
Real_Price = group['Weighted_Price'].mean()

# %%
Real_Price
# Out:
# date
# 2014-12-01     335.000000
# 2014-12-02     377.854911
# 2014-12-03     377.818333
# 2014-12-04     377.100000
# 2014-12-06     378.000000
# 2014-12-08     375.000426
# 2014-12-10     379.250000
# 2014-12-12     363.611032
# 2014-12-18     342.500000
# 2015-01-08     295.067977
# 2015-01-13     260.000000
# 2015-01-14     156.175582
# 2015-01-15     203.835678
# 2015-01-16     205.323466
# 2015-01-17     198.217293
# 2015-01-19     215.170000
# 2015-01-20     214.500000
# 2015-01-21     222.590679
# 2015-01-22     227.402181
# 2015-01-23     227.700000
# 2015-01-24     241.381667
# 2015-01-25     250.553665
# 2015-01-26     274.076694
# 2015-01-27     261.003194
# 2015-01-28     251.025118
# 2015-01-29     233.675604
# 2015-01-30     234.118357
# 2015-01-31     229.290324
# 2015-02-01     220.444655
# 2015-02-02     227.313862
#                  ...
# 2018-12-09    3468.663403
# 2018-12-10    3469.771366
# 2018-12-11    3365.448870
# 2018-12-12    3396.440496
# 2018-12-13    3360.501890
# 2018-12-14    3234.106661
# 2018-12-15    3179.783988
# 2018-12-16    3217.446121
# 2018-12-17    3332.899623
# 2018-12-18    3508.728907
# 2018-12-19    3749.330612
# 2018-12-20    3924.280667
# 2018-12-21    3973.468513
# 2018-12-22    3852.283734
# 2018-12-23    3978.574500
# 2018-12-24    4126.049530
# 2018-12-25    3773.672692
# 2018-12-26    3775.034521
# 2018-12-27    3717.586290
# 2018-12-28    3701.117104
# 2018-12-29    3874.102593
# 2018-12-30    3788.855617
# 2018-12-31    3756.536168
# 2019-01-01    3700.539528
# 2019-01-02    3823.152158
# 2019-01-03    3829.900978
# 2019-01-04    3785.337456
# 2019-01-05    3834.565401
# 2019-01-06    3874.337968
# 2019-01-07    4025.017616
# Name: Weighted_Price, Length: 1465, dtype: float64

# %%
# split data
prediction_days = 60
df_train= Real_Price[:len(Real_Price)-prediction_days]
df_test= Real_Price[len(Real_Price)-prediction_days:]
df_helper = df_test[0:30]
df_test = df_test[30:]

# %%
# Data preprocess
training_set = df_train.values
training_set = np.reshape(training_set, (len(training_set), 1))

sc = MinMaxScaler()
training_set = sc.fit_transform(training_set)
X_train = training_set[0:len(training_set)-1]
y_train = training_set[1:len(training_set)]
X_train = np.reshape(X_train, (len(X_train), 1, 1))

# %%
# Initialising the RNN
regressor = Sequential()

# Adding the input layer and the LSTM layer
regressor.add(LSTM(units = 4, activation = 'sigmoid', input_shape = (None, 1)))

# Adding the output layer
regressor.add(Dense(units = 1))

# Compiling the RNN
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
regressor.fit(X_train, y_train
# Epoch 100/100
# 1404/1404 [==============================] - 1s 407us/step - loss: 1.4704e-04

# %%
# Making the predictions
test_set = df_test.values
inputs = np.reshape(test_set, (len(test_set), 1))
inputs = sc.transform(inputs)
inputs = np.reshape(inputs, (len(inputs), 1, 1))
predicted_BTC_price = regressor.predict(inputs)
predicted_BTC_price = sc.inverse_transform(predicted_BTC_price)
predicted_BTC_price
# Out:
# array([[3442.8232],
#        [3443.9246],
#        [3340.1106],
#        [3370.95  ],
#        [3335.1873],
#        [3209.4324],
#        [3155.3943],
#        [3192.8596],
#        [3307.723 ],
#        [3482.6968],
#        [3722.2107],
#        [3896.4194],
#        [3945.4075],
#        [3824.7239],
#        [3950.4927],
#        [4097.384 ],
#        [3746.4485],
#        [3747.8027],
#        [3690.6062],
#        [3674.2085],
#        [3846.45  ],
#        [3761.564 ],
#        [3729.385 ],
#        [3673.6343],
#        [3795.7134],
#        [3802.434 ],
#        [3758.0603],
#        [3807.0803],
#        [3846.6855],
#        [3996.75  ]], dtype=float32)

# %%
test_in = df_test.values
test_in = [test_in[0]]
inputs = np.reshape(test_in, (len(test_in), 1))
inputs = sc.transform(inputs)
inputs = np.reshape(inputs, (len(inputs), 1, 1))
result = []
for i in range(30):
    predict_res = regressor.predict(inputs)
    predict_res = sc.inverse_transform(predict_res)
    result.append(predict_res[0])
    test_in = predict_res
    inputs = np.reshape(test_in, (len(test_in), 1))
    inputs = sc.transform(inputs)
    inputs = np.reshape(inputs, (len(inputs), 1, 1))
result
# Out:
# [array([3442.8242], dtype=float32),
#  array([3417.1086], dtype=float32),
#  array([3391.5176], dtype=float32),
#  array([3366.0515], dtype=float32),
#  array([3340.711], dtype=float32),
#  array([3315.4963], dtype=float32),
#  array([3290.4072], dtype=float32),
#  array([3265.4463], dtype=float32),
#  array([3240.6113], dtype=float32),
#  array([3215.9048], dtype=float32),
#  array([3191.3254], dtype=float32),
#  array([3166.8752], dtype=float32),
#  array([3142.5525], dtype=float32),
#  array([3118.3606], dtype=float32),
#  array([3094.297], dtype=float32),
#  array([3070.3645], dtype=float32),
#  array([3046.5623], dtype=float32),
#  array([3022.891], dtype=float32),
#  array([2999.351], dtype=float32),
#  array([2975.9424], dtype=float32),
#  array([2952.666], dtype=float32),
#  array([2929.521], dtype=float32),
#  array([2906.5088], dtype=float32),
#  array([2883.628], dtype=float32),
#  array([2860.8801], dtype=float32),
#  array([2838.2666], dtype=float32),
#  array([2815.788], dtype=float32),
#  array([2793.442], dtype=float32),
#  array([2771.2302], dtype=float32),
#  array([2749.1519], dtype=float32)]

# %%
test_in = df_helper.values
test_in = np.append(test_in, df_test[0])
inputs = np.reshape(test_in, (len(test_in), 1))
inputs = sc.transform(inputs)
inputs = np.reshape(inputs, (len(inputs), 1, 1))
result2 = []
for i in range(30):
    predict_res = regressor.predict(inputs)
    predict_res = sc.inverse_transform(predict_res)
    result2.append(predict_res[-1])
    test_in = np.delete(test_in,0,0)
    test_in = np.append(test_in,predict_res[-1])
    inputs = np.reshape(test_in, (len(test_in), 1))
    inputs = sc.transform(inputs)
    inputs = np.reshape(inputs, (len(inputs), 1, 1))
result2
# Out:
# [array([3442.8242], dtype=float32),
#  array([3417.1086], dtype=float32),
#  array([3391.5176], dtype=float32),
#  array([3366.0503], dtype=float32),
#  array([3340.711], dtype=float32),
#  array([3315.4963], dtype=float32),
#  array([3290.4072], dtype=float32),
#  array([3265.4463], dtype=float32),
#  array([3240.6113], dtype=float32),
#  array([3215.9048], dtype=float32),
#  array([3191.3254], dtype=float32),
#  array([3166.8752], dtype=float32),
#  array([3142.5525], dtype=float32),
#  array([3118.3606], dtype=float32),
#  array([3094.297], dtype=float32),
#  array([3070.3645], dtype=float32),
#  array([3046.5623], dtype=float32),
#  array([3022.891], dtype=float32),
#  array([2999.351], dtype=float32),
#  array([2975.9412], dtype=float32),
#  array([2952.6636], dtype=float32),
#  array([2929.5178], dtype=float32),
#  array([2906.5068], dtype=float32),
#  array([2883.6262], dtype=float32),
#  array([2860.8792], dtype=float32),
#  array([2838.2666], dtype=float32),
#  array([2815.788], dtype=float32),
#  array([2793.442], dtype=float32),
#  array([2771.2302], dtype=float32),
#  array([2749.1519], dtype=float32)]

# %%
# Visualising the results
plt.figure(figsize=(25,15), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()  
plt.plot(test_set, color = 'red', label = 'Real BTC Price')
plt.plot(result, color = 'blue', label = 'Predicted BTC Price')
plt.title('BTC Price Prediction', fontsize=40)
df_test_reset = df_test.reset_index()
x=df_test_reset.index
labels = df_test_reset['date']
plt.xticks(x, labels, rotation = 'vertical')
for tick in ax.xaxis.get_major_ticks():
    tick.label1.set_fontsize(18)
for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_fontsize(18)
plt.xlabel('Time', fontsize=40)
plt.ylabel('BTC Price(USD)', fontsize=40)
plt.legend(loc=2, prop={'size': 25})
plt.show()

# %%
# Visualising the results
plt.figure(figsize=(25,15), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()  
plt.plot(test_set, color = 'red', label = 'Real BTC Price')
plt.plot(result2, color = 'blue', label = 'Predicted BTC Price')
plt.title('BTC Price Prediction', fontsize=40)
df_test_reset = df_test.reset_index()
x=df_test_reset.index
labels = df_test_reset['date']
plt.xticks(x, labels, rotation = 'vertical')
for tick in ax.xaxis.get_major_ticks():
    tick.label1.set_fontsize(18)
for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_fontsize(18)
plt.xlabel('Time', fontsize=40)
plt.ylabel('BTC Price(USD)', fontsize=40)
plt.legend(loc=2, prop={'size': 25})
plt.show()

# %%
# evaluate data
test_set = df_test.values
test_set = np.reshape(test_set, (len(test_set), 1))

sc = MinMaxScaler()
test_set = sc.fit_transform(test_set)
X_test = test_set[0:len(test_set)-1]
y_test = test_set[1:len(test_set)]
X_test = np.reshape(X_test, (len(X_test), 1, 1))

# %%
score = regressor.evaluate(X_test, y_test, verbose=1)
print("%s: %.2f%%" % (regressor.metrics_names[0], score*100))
# Out:
# 29/29 [==============================] - 0s 12ms/step
# loss: 1.63%

# %% [markdown]
# # SUPPORT VECTOR MACHINE

# %% [markdown]
# In this section we train data using Support Vecor Machine to test how fit this method to doing timeseries fitting.

# %%
# scaling and removing outlier
copy_of_bc = copy_of_bc[(np.abs(stats.zscore(copy_of_bc)) < 2.9999999).all(axis=1)]
copy_of_bc = copy_of_bc[(np.abs(stats.zscore(copy_of_bc)) > -2.999999).all(axis=1)]
copy_of_bc.head(5)
# Out:
#           Timestamp     Open       ...        Volume_(Currency)  Weighted_Price
# 3773817  1552135260  3902.62       ...              1883.936114     3903.105223
# 3773818  1552135320  3903.11       ...             18452.636311     3903.110000
# 3773819  1552135380  3903.11       ...              4488.615500     3903.143913
# 3773820  1552135440  3903.11       ...             23395.765313     3903.329266
# 3773821  1552135500  3901.65       ...             34331.851306     3901.924206
#
# [5 rows x 8 columns]

# %%
plot_bc = copy_of_bc.copy()
plot_bc.index = pd.to_datetime(plot_bc.Timestamp, dayfirst=True)
for cols in plot_bc.keys():
    plt.plot(cols, data=plot_bc)
    plt.show()

# %%
y = copy_of_bc['Weighted_Price']
X = copy_of_bc.drop('Weighted_Price',axis=1)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=100,test_size=0.3)

# %%
timextrain= X_train['Timestamp']
X_train=X_train.drop('Timestamp',axis=1)
timextest= X_test['Timestamp']
X_test=X_test.drop('Timestamp',axis=1)

# %%
from sklearn.svm import SVR

# %%
# for the first trial I use SVR standar/default parameters from the library
predictor = SVR()

# %%
# %%time
predictor.fit(X_train,y_train)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# CPU times: user 740 ms, sys: 32 ms, total: 772 ms
# Wall time: 712 ms
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False)

# %%
predict_val_test = predictor.predict(X_test)
y_len = range(len(y_test)) 
y_act = y_test 
plt.scatter(y_len,y_act) 
plt.scatter(y_len,predict_val_test) 
plt.gca().legend(('Actual','Predicted')) 
plt.show()

# %%
# %%time
predictor.score(X_test, y_test)
# Out:
# CPU times: user 144 ms, sys: 80 ms, total: 224 ms
# Wall time: 137 ms
# -0.11512393582809466

# %% [markdown]
# # Build Our Model
# After considering all the method above

# %%
usedData = copy_of_bc.copy()

# %%
usedData['date'] = pd.to_datetime(usedData['Timestamp'],unit='s').dt.date
groupDate = usedData.groupby('date')
real_Price_Data = groupDate['Weighted_Price'].mean()

# %%
# split data
prediction_days = 30
df_train2= real_Price_Data[:len(real_Price_Data)-prediction_days]
df_test2= real_Price_Data[len(real_Price_Data)-prediction_days:]

# %%
real_Price_Data
# Out:
# date
# 2019-03-09    3534.618860
# 2019-03-10    3183.231378
# 2019-03-11    3501.744953
# 2019-03-12    3579.767531
# 2019-03-13    3861.967464
# Name: Weighted_Price, dtype: float64

# %%
# Data preprocess
train_set = df_train.values
train_set = np.reshape(train_set, (len(train_set), 1))

sc = MinMaxScaler()
train_set = sc.fit_transform(train_set)
X_train = train_set[0:len(train_set)-1]
y_train = train_set[1:len(train_set)]
X_train = np.reshape(X_train, (len(X_train), 1, 1))

# %%
y_train
# Out:
# array([[0.01143791],
#        [0.01143602],
#        [0.01139896],
#        ...,
#        [0.32284293],
#        [0.32764138],
#        [0.32479263]])
