# %% [markdown]
# - **「kaggleGrandmasterに学ぶ機械学習実践アプローチ」の本で書かれているCodeをkaggle環境上で再現するnotebookです。**
#     - 本書で使われているサンプルデータはkaggle Dataset上に著者の方が置いており(AAAMLPというデータセット名)、
#     notebook環境内でのコードを学ぶのに非常に親和性が高いです。
#     - また、輪読会の参加者の実行環境の統一を簡単に実現できます。GPU環境も気兼ねなく使えますしね。
#     - 本notebookではサンプルデータの読み込みまでをフォローします。
#     初心者・初学者の方は当notebookをfolkしていただき、その先は参加者の方が各自説明やコードを記載ください。

# %% [markdown]
# ## library
# - 使用できるライブラリはこちらを参照ください
#   https://github.com/Kaggle/docker-python/blob/main/Dockerfile

# %%
import numpy as ny
import pandas as pd
import sklearn as sk
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## load sample data
# - 例として、第2章の「winequality-red.csv」を読み込みます
# - データセット内の「aaamlp」の中にデータがあるので、pathを読み込むだけです
#
# ![image.png](attachment:d3c1c2b7-c6ab-40b2-979a-50c224d226db.png)

# %%
df = pd.read_csv('../input/aaamlp/winequality-red.csv')

# %%
df.head()

# %% [markdown]
# ## .pyを動かしたい場合
# - 本書では.pyを作って動かすケースも存在します。この場合のアプローチは2通りあります
#     1. notebook上で動くように多少書き直す
#     2. pyを作ってnotebook環境上で動かす
#
# - 1はコードに応じて書き直し方が異なってくると思うので説明は割愛し、2の方法について解説します。
#     1. 自身のDatasetを作って、その中に.pyを格納
#     2. 上記Datasetを右上「Add data」から追加する
#     3. !python {path}/python file.py で動かせる

# %%
# 例としてsample.pyを動かしてみます
# スクリプトの中身
# !cat '../input/kagglegrandmaster-script/sample/sample.py'

# %%
# !python {path}/hogehoge.pyで実行可能です
# !python '../input/kagglegrandmaster-script/sample/sample.py'
