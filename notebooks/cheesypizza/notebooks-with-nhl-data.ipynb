# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
'''
TODO: Specify dtypes with the csv file.
Looks like dtype guessing is memory intensive and its is recommended to specify them in read_csv. More info: 
https://stackoverflow.com/questions/24251219/pandas-read-csv-low-memory-and-dtype-options
'''
    
game_goals = pd.read_csv('/kaggle/input/nhl-game-data/game_goals.csv')
game_officials = pd.read_csv('/kaggle/input/nhl-game-data/game_officials.csv')
game_plays = pd.read_csv('/kaggle/input/nhl-game-data/game_plays.csv')
game_plays_players = pd.read_csv('/kaggle/input/nhl-game-data/game_plays_players.csv')
player_info = pd.read_csv('/kaggle/input/nhl-game-data/player_info.csv')
game_goalie_stats = pd.read_csv('/kaggle/input/nhl-game-data/game_goalie_stats.csv')
team_info = pd.read_csv('/kaggle/input/nhl-game-data/team_info.csv')
game = pd.read_csv('/kaggle/input/nhl-game-data/game.csv')
game_penalties = pd.read_csv('/kaggle/input/nhl-game-data/game_penalties.csv')
game_skater_stats = pd.read_csv('/kaggle/input/nhl-game-data/game_skater_stats.csv')
game_teams_stats = pd.read_csv('/kaggle/input/nhl-game-data/game_teams_stats.csv')
game_scratches = pd.read_csv('/kaggle/input/nhl-game-data/game_scratches.csv')
game_shifts = pd.read_csv('/kaggle/input/nhl-game-data/game_shifts.csv')

# %%
game_goals.info()

# %%
game.head()
print("Number of playoff games = ",len(game.loc[game["type"]=='P'].index))
print("Number of regular games = ",len(game.loc[game["type"]=='R'].index))
