# %% [markdown]
# # Pfizer Vaccine💉 Tweets

# %%
import os
from IPython.display import Image
Image(filename="../input/pfizer-pictures/Pfizer Vaccine Tweets.jpg", width=1000, height=1000)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import warnings
warnings.simplefilter("ignore")

# %%
data = pd.read_csv(r"../input/pfizer-vaccine-tweets/vaccination_tweets.csv")

# %%
data

# %%
data.shape

# %%
data.index

# %%
data.dtypes

# %%
data.count()

# %%
data['user_verified'].value_counts()

# %%
 print('sources of tweeting')
data['source'].value_counts()

# %%
from collections import Counter
df = Counter(data['source'].tolist()).most_common(5)
temp = pd.DataFrame(df, columns=['Source', 'Count'])

plt.figure(figsize=(7,7))
plt.pie(x=temp['Count'], labels=temp['Source'], autopct='%1.1f%%', shadow=True, startangle=0, explode = [0.1,0,0,0,0])
plt.show()

# %%
df = data['user_verified'].value_counts().to_dict()
df['Verified'] = df.pop(True)
df['Not-Verified'] = df.pop(False)

plt.figure(figsize=(7,9))
plt.pie(x=df.values(), labels=df.keys(), autopct='%1.1f%%', shadow=True, startangle=0, explode = [0.2, 0])
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.countplot(y='hashtags', data=data, order=data['hashtags'].value_counts().index[:15])
plt.xlabel('Number of Hashtags', weight='bold')
plt.ylabel('Hashtags', weight='bold')
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.countplot(y='user_name', data=data, order=data['user_name'].value_counts().index[:15])
plt.xlabel('Number of Tweets', weight='bold')
plt.ylabel('Username', weight='bold')
plt.show()

# %%
plt.figure(figsize=(8,10))
sns.countplot(y='user_location', data=data, order=data['user_location'].value_counts().index[:10])
plt.xlabel('Number of User', weight='bold')
plt.ylabel('Location', weight='bold')
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.drop(columns=['id','is_retweet']).corr(), square=True, annot=True)
plt.show()

# %%
stopwords = set(STOPWORDS)

def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color='Black',
        stopwords=stopwords,
        max_words=50,
        max_font_size=40, 
        scale=5,
        random_state=1
    ).generate(str(data))

    fig = plt.figure(1, figsize=(15,15))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()

# %%
show_wordcloud(data['text'], title = 'Tweet Text')

# %%
show_wordcloud(data['hashtags'], title = 'Hashtags Trend')

# %%
my_data=data[['id','text','user_name','user_location']].groupby(by=['id','user_name','user_location']).sum().reset_index()
my_data.head(60)
