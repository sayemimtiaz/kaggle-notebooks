# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

astronauts = pd.read_csv('../input/astronaut-yearbook/astronauts.csv')
astronauts['Birth State'] = astronauts['Birth Place'].str.split(', ', expand=True)[1]
astronauts.head()

# %%
census = pd.read_csv('../input/us_energy_census_gdp_10-14/Energy Census and Economic Data US 2010-2014.csv')
census.head()
