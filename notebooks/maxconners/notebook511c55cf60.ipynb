# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
data = pd.read_csv("../input/database.csv")

from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

# Any results you write to the current directory are saved as output.

# %%
data.head()

# %%
data.info()

# %%
data.describe()

# %%
sns.countplot(data=data, x='Year')

# %%
data['Year'].value_counts(ascending=False).head()

# %% [markdown]
# Why was there a spike in the years 1991-1995?

# %%
spikeYears = data[(data['Year'] >= 1991) & (data['Year'] <= 1995)]

# %%
sns.countplot(data=spikeYears, x='Year')

# %%
data[data['Year'] == 1993].describe().mean()

# %%
data.describe().mean()

# %%
data.describe()

# %%
data.isnull().values.any()

# %%
def rundown(filename):
    
    extension = name.split('.',1)[1]
    
    #CSV
    if (extension == 'csv') | (extension == 'txt'):
        data = pd.read_csv(filename)
        print (data.head())
    
    #EXCEL
    if else extension == 'xls':
        data = pd.read_excel(filename)
        print (data.head())
    
    
    #These are unlikely to be used so I will not be implementing them just yet.
    '''
    #HDF
    if else extension == 'h5':
        data = pd.read_hdf(filename)
        print (data.head())
    if else extension == 'xls':
        data = pd.read_sql(filename)
        print (data.head())
    if else extension == 'xls':
        data = pd.read_json(filename)
        print (data.head())
    if else extension == 'xls':
        data = pd.read_msgpack(filename)
        print (data.head())
    if else extension == 'xls':
        data = pd.read_html(filename)
        print (data.head())
    if else extension == 'xls':
        data = pd.read_stata(filename)
        print (data.head())    
    if else extension == 'xls':
        data = pd.read_sas(filename)
        print (data.head())
    if else extension == 'xls':
        data = pd.read_pickle(filename)
        print (data.head())
    '''
    
    
    
    return

# %%
rundown(name)
