# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../input/heart-attack-analysis-prediction-dataset/heart.csv')
df.head()

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
df.isna().sum()

# %%
df.info()

# %%
df['exng'] = df['exng'].map({1:'yes',0:'no'})
df['cp'] = df['cp'].map({0:'typical angina',1:'atypical angina',2:'non-anginal pain',3:'asymptomatic'})
df['fbs'] = df['fbs'].map({1:'true',0:'false'})
df['restecg'] = df['restecg'].map({0:'normal',1:'having ST-T wave abnormality',2:'showing probable or definite left ventricular hypertrophy'})
df['output'] = df['output'].map({0:'less chance of heart attack',1:'more chance of heart attack'})

# %%
df.head()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(df.corr(),annot=True);

# %%
sns.countplot(x=df["output"],hue=df["sex"]);
plt.title("Comparison on the basis of gender");

# %%
plt.title('Analysis on the basis Chest Pain',fontsize=15)
sns.countplot(x=df['output'], hue=df['cp']);

# %%
plt.title('Analysis on the basis of number of major vessels',fontsize=15)
sns.countplot(x=df['output'],hue=df['caa']);

# %% [markdown]
# # Model Buidling

# %%
df2 = pd.read_csv('../input/heart-attack-analysis-prediction-dataset/heart.csv')
df2.head()

# %%
from sklearn.model_selection import train_test_split
X=df2.iloc[:,:-1].values
y=df2.iloc[:,-1].values
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 0)

# %%
import math
from sklearn.ensemble import RandomForestRegressor as r
from sklearn.linear_model import Ridge,Lasso
from sklearn.preprocessing import PolynomialFeatures as pf
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.fit_transform(X_test)

ridge=Ridge(alpha=0.1,normalize=True)
lasso=Lasso(alpha=0.1,normalize=True)
reg = r(n_estimators=100,max_depth=10,n_jobs=-1)
ridge.fit(X_train, y_train)
y_pred = ridge.predict(X_test)


print(math.sqrt(mean_squared_error(y_pred, y_test)))
print(math.sqrt(mean_absolute_error(y_pred, y_test)))

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

model=SVC(kernel = 'rbf',C = 1, degree = 5, random_state = 0)

# %%
model.fit(X_train,y_train)
y_preds=model.predict(X_test)
acc=accuracy_score(y_test,y_preds)

acc
