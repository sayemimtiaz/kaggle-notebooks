# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# LOAD DATASETS

# %%
medianHouseHoldIncome = pd.read_csv("/kaggle/input/median-house-hold-income-2015/MedianHouseholdIncome2015.csv" , encoding = "windows-1252")

percentOver25CompletedHighSchool = pd.read_csv("/kaggle/input/percent-over-25-completed-high-school/PercentOver25CompletedHighSchool.csv" , encoding = "windows-1252")

percentagePeopleBelowPovertyLevel = pd.read_csv("/kaggle/input/percentage-people-below-poverty-level/PercentagePeopleBelowPovertyLevel.csv" , encoding = "windows-1252")

sharingRaceByCity = pd.read_csv("/kaggle/input/sharing-race-by-city/ShareRaceByCity.csv" , encoding = "windows-1252")

USPoliceShootings = pd.read_csv("/kaggle/input/us-police-shootings/shootings.csv" , encoding = "windows-1252")

# %% [markdown]
# BAR PLOT EXAMPLE

# %%
percentagePeopleBelowPovertyLevel.info()

# %%
percentagePeopleBelowPovertyLevel.head()

# %% [markdown]
# NAN VALUES

# %%
percentagePeopleBelowPovertyLevel["poverty_rate"].isnull().sum()

# %% [markdown]
# UNDEFINED DATA

# %%
percentagePeopleBelowPovertyLevel["poverty_rate"].value_counts()

# %%
percentagePeopleBelowPovertyLevel.replace("-" , 0.0 , inplace = True)

percentagePeopleBelowPovertyLevel["poverty_rate"].value_counts()

# %%
percentagePeopleBelowPovertyLevel.poverty_rate = percentagePeopleBelowPovertyLevel.poverty_rate.astype(float)

percentagePeopleBelowPovertyLevel.info()

# %%
places = percentagePeopleBelowPovertyLevel["Geographic Area"].unique()

places

# %%
ratio = []

for place in places:
    x = percentagePeopleBelowPovertyLevel[percentagePeopleBelowPovertyLevel["Geographic Area"] == place ]
    average = sum(x.poverty_rate) / len(x)
    newData = ratio.append(average)
    

newData2 = pd.DataFrame(
    {"places" : places,
    "poverty" : ratio})
    
index1 = (newData2["poverty"].sort_values(ascending = False)).index.values
newIndex = newData2.reindex(index1)


newIndex.head(10)

# %% [markdown]
# VISUALIZATION

# %%
plt.figure(figsize = (25,15))
sns.barplot(x = newIndex["places"],y = newIndex["poverty"] )

plt.xticks(rotation = 0)
plt.xlabel("PLACES")
plt.ylabel("POVERTY")
plt.title("Poverty Rate By Region")

# %% [markdown]
# BAR PLOT EXAMPLE 2

# %%
data = USPoliceShootings

data.head()

# %%
data.info()

# %%
data["name"].value_counts()

# %%
names = data.name[data.name != "TK TK"].str.split()

names

# %%
a,b = zip(*names)

# %%
nameList = a+b

# %%
nameCount = Counter(nameList)

# %%
mostNames = nameCount.most_common(20)

# %%
x,y = zip(*mostNames)

# %%
x,y = list(x) , list(y)

# %%
plt.figure(figsize = (25,15))
plt.xticks(rotation = 45)

sns.barplot(x = x ,
            y=y ,
            palette = "rocket")

# %% [markdown]
# BAR PLOT EXAMPLE 3

# %%
data = sharingRaceByCity
data.head()

# %%
data.info()

# %%
data["Geographic area"].value_counts()

# %%
data["City"].value_counts()

# %%
data["share_white"].value_counts()

# %%
data["share_black"].value_counts()

# %%
data["share_native_american"].value_counts()

# %%
data["share_asian"].value_counts()

# %%
data["share_hispanic"].value_counts()

# %%
data.replace(["(X)"] ,0.0 , inplace = True)
data.replace(["-"], 0.0 , inplace = True)

# %%
data["share_white"] = data["share_white"].astype(float)
data["share_black"] = data["share_black"].astype(float)
data["share_native_american"] = data["share_native_american"].astype(float)
data["share_asian"] = data["share_asian"].astype(float)
data["share_hispanic"] = data["share_hispanic"].astype(float)



data.info()

# %%
places = list(data["Geographic area"].unique())

places

# %%
share_white = []
share_black = []
share_native_american = []
share_asian = []
share_hispanic = []

# %%
for place in places:
    x = data[data["Geographic area"] == place]
    
    share_white.append(sum(x.share_white)/len(x))
    share_black.append(sum(x.share_black)/len(x))
    share_native_american.append(sum(x.share_native_american)/len(x))
    share_asian.append(sum(x.share_asian)/len(x))
    share_hispanic.append(sum(x.share_hispanic)/len(x))

# %%
f , ax = plt.subplots(figsize = (15 ,25) )


sns.barplot(x=share_white,y=places,color= "orange" , label = "r" , alpha = 1)
sns.barplot(x = share_black , y=places , color = "blue" , label ="b" ,alpha = 1)
sns.barplot(x = share_native_american , y = places , color = "cyan" ,label="g" ,alpha = 1 )

# %%
f , ax = plt.subplots(figsize = (15,25))

sns.barplot(x = share_asian , y= places , color = "red" , alpha = 1)
sns.barplot(x = share_hispanic , y=places , color = "g" ,alpha =0.5)

# %% [markdown]
# THANK YOU FOR READİNG
