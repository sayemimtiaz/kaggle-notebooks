# %% [markdown]
# # This is assignment for lecture 6

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
np.set_printoptions(threshold=np.inf)

selected_country ='Brazil'
df = pd.read_csv('../input/novel-corona-virus-2019-dataset/covid_19_data.csv',header=0)
df = df[df['Country/Region']==selected_country]
df = df.groupby('ObservationDate').sum()
print(df)

# %% [markdown]
# Note: This 'df' is actually a cumulative information.
# June 10th shows the total cases since initial case.
#
#
# # Calculate daily increases

# %%
df['daily_confirmed'] = df['Confirmed'].diff()
df['daily_deaths'] = df['Deaths'].diff()
df['daily_recovery'] = df['Recovered'].diff()

df['daily_confirmed'].plot()
df['daily_deaths'].plot()
df['daily_recovery'].plot()
plt.show()

# %% [markdown]
# # Making an interactive chart
#
# To do this, we need to add 2 of the following modules.

# %%
from plotly.offline import iplot
import plotly.graph_objs as go

daily_confirmed_object = go.Scatter(x=df.index, y=df['daily_confirmed'].values, name = 'Daily Confirmed')
daily_deaths_object = go.Scatter(x=df.index, y=df['daily_deaths'].values, name = 'Daily Death')
daily_recovered_object = go.Scatter(x=df.index, y=df['daily_recovery'].values, name = 'Daily Recovery')

layout_object = go.Layout(title='Brazil Daily cases 20M51636', xaxis = dict(title='Date'), yaxis = dict(title='Number of people'))
fig = go.Figure(data=[daily_confirmed_object, daily_deaths_object, daily_recovered_object], layout = layout_object)
iplot(fig)
fig.write_html('Brazil_daily_cases_20M51636.html')

# %% [markdown]
# # Information from the chart
#
#
# ・Infection of Covid-19 in Brazil started to grow from the biggining of April
#
# ・The largest daily confirmed was marked at May 30th
#
# ・daily confirmed is still growing in Brazil, so we can assume that it is far from　convergence in Brazil
#
# ・I assume that the data of daily recovery at June 8th is wrong.

# %% [markdown]
# # Making an informative table

# %%
df1 = df#[['daily_confirmed']]
df1 = df1.fillna(0.)
styled_object = df1.style.background_gradient(cmap='gist_ncar').highlight_max('daily_confirmed').set_caption('Daily Summaries')
display(styled_object)
f = open('table_20M51636.html','w')
f.write(styled_object.render())

# %% [markdown]
# # Calculating global ranking

# %%
data = pd.read_csv('/kaggle/input/novel-corona-virus-2019-dataset/covid_19_data.csv')
data.index=data['ObservationDate']
data = data.drop(['SNo','ObservationDate'],axis=1)


latest = data[data.index=='06/10/2020']
latest = latest.groupby('Country/Region').sum()
latest = latest.sort_values(by='Confirmed',ascending=False).reset_index() 

#print(latest)
print('Ranking of Brazil: ', latest[latest['Country/Region']=='Brazil'].index.values[0]+1)

# %% [markdown]
# Brazil has the second largest number of Covid-19 confirmed.

# %% [markdown]
# # Covid-19 situation in Brazil
#
# Covid-19 situation in Brazil is very bad because the President is prioritizing economics over infection prevention　and refusing to lock down the city.
# Some people say that this is done to reduce the number of elderly people.
#
# In Brazil, the Ministry of Health suddenly discontinued the release of new corona-related sample data from the June 5th, and criticisms of "trying to conceal the seriousness" erupted from inside and outside the country.
