# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("../input/datasetudemy/data (1).csv")

# %%
data.tail()
# malignant : M kötü huylu tümör
# benign : B iyi huylu tümör

# %%
# id ve unnamed alanını kaldıralım.
data.drop(["id","Unnamed: 32"],axis=1,inplace=True)

# %%
data.tail()

# %%
#veri setini kötü huylu timor ve iyi huylu tümör olarak ikiye ayıralım
M = data[data.diagnosis == 'M']
B = data[data.diagnosis == 'B']

# %%
# kötü huylu timör
M.info()

# %%
#iyi huylu timör
B.info()

# %%
#scatter plot
#radius_mean,area_mean
plt.scatter(M.radius_mean,M.area_mean,color="red",label="kötü",alpha=0.3)
plt.scatter(B.radius_mean,B.area_mean,color="green",label="iyi",alpha=0.3)
plt.xlabel("radius_mean")
plt.ylabel("area_mean")
plt.legend()
plt.show()

# %%
#scatter plot
#radius_mean,area_mean
plt.scatter(M.radius_mean,M.texture_mean,color="red",label="kötü",alpha=0.3)
plt.scatter(B.radius_mean,B.texture_mean,color="green",label="iyi",alpha=0.3)
plt.xlabel("radius_mean")
plt.ylabel("texture_mean")
plt.legend()
plt.show()

# %% [markdown]
# #  KNN(K NEIREST NEIGHBOUR) ALGORITHM
# Sırasıyla aşağıdaki işlemler yapılır.
# 1. K değerini seç
# 2. K'ya en yakın data noktalarını bul.
# 3. K'ya en yakın komşu arasında hangi sınıftan kaç tane var hesapla.
# 4. Test ettiğimiz nokta yada data hangi sınıfa ait tespit et.

# %%
# Sınıf labellerı şu an string bunları number yapmalıyız.
# M olanlar 1 B olanlar 0 olacak.
data.diagnosis = [1 if each=="M" else 0 for each in data.diagnosis]
Y_data = data.diagnosis.values
X_data = data.drop(["diagnosis"],axis=1)

# %%
Y_data

# %%
#normalization işlemi yapalım.
x = (X_data - np.min(X_data))/(np.max(X_data) - np.min(X_data))

# %%
train_test_split
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state = 1)

# %%
#knn model
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
prediction=knn.predict(x_test)

# %%
prediction

# %%
print (" {} skor : {} ".format(3,kkn.score(x_test,y_test)))

# %%
#find k value
score_list = []
for each in range(1,15):
    knn2 = KNeighborsClassifier(n_neighbors = each)
    knn2.fit(x_train,y_train)
    score_list.append(knn2.score(x_test,y_test))
    
plt.plot(range(1,15),score_list)
plt.xlabel("k values")
plt.ylabel("accuracy")
plt.show()
