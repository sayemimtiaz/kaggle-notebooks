# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('../input/pima-indians-diabetes-database/diabetes.csv')
df.head()

# %%
df.info()

# %%
X=df.drop(columns=['Outcome'])
Y=df['Outcome']
X.shape,Y.shape

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
tst=lr.fit(X,Y)
prd=lr.predict(X)

# %%
cf=lr.coef_
cf

# %%
def equator(X,coef=cf):
  y_hat=0;
  print('EQUATION OF THE LINE IS:')
  print('y=({}*{})+({}*{})+({}*{})+({}*{})+({}*{})+({}*{})+({}*{})+({}*{})'.format(coef[0],X[0],coef[1],X[1],coef[2],X[2],coef[3],X[3],coef[4],X[4],coef[5],X[5],coef[6],X[6],coef[7],X[7]))
  for i in range(cf.shape[0]):
    y_hat+=X[i]*coef[i]
  if y_hat>0.5:
    y_hat=1
  else:
    y_hat=0
  
  return y_hat

# %%
x=X.iloc[0]
rs=equator(x,cf)
if(rs==1):
  print('Patient will be diabetic in next 5 years ')
else:
  print('Patient will not diabatic!!Congrats')
