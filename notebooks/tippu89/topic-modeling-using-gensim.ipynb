# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['abcnews-date-text.csv']

# %%
data = pd.read_csv("../input/abcnews-date-text.csv", error_bad_lines=False)

# %%
data.head()
# Out:
#    publish_date                                      headline_text
# 0      20030219  aba decides against community broadcasting lic...
# 1      20030219     act fire witnesses must be aware of defamation
# 2      20030219     a g calls for infrastructure protection summit
# 3      20030219           air nz staff in aust strike for pay rise
# 4      20030219      air nz strike to affect australian travellers

# %%
text = data[['headline_text']]

# %%
text.head()
# Out:
#                                        headline_text
# 0  aba decides against community broadcasting lic...
# 1     act fire witnesses must be aware of defamation
# 2     a g calls for infrastructure protection summit
# 3           air nz staff in aust strike for pay rise
# 4      air nz strike to affect australian travellers

# %%
text['index'] = text.index

# %%
text.head()
# Out:
#                                        headline_text  index
# 0  aba decides against community broadcasting lic...      0
# 1     act fire witnesses must be aware of defamation      1
# 2     a g calls for infrastructure protection summit      2
# 3           air nz staff in aust strike for pay rise      3
# 4      air nz strike to affect australian travellers      4

# %%
documents = text

# %%
documents.head()
# Out:
#                                        headline_text  index
# 0  aba decides against community broadcasting lic...      0
# 1     act fire witnesses must be aware of defamation      1
# 2     a g calls for infrastructure protection summit      2
# 3           air nz staff in aust strike for pay rise      3
# 4      air nz strike to affect australian travellers      4

# %%
print("Total length of the documents: {}".format(len(documents)))
# Out:
# Total length of the documents: 1103663

# %% [markdown]
# ## Data Pre-Processing

# %%
# importing the gensim and nltk libraries

import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *

import nltk
np.random.seed(42)

# %%
def preprocessing(sentence):
    stemmer = SnowballStemmer('english')
    return stemmer.stem(WordNetLemmatizer().lemmatize(sentence, pos='v'))

def preprocess(sentence):
    result = []
    
    for token in gensim.utils.simple_preprocess(sentence):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(preprocessing(token))
            
    return result

# %%
sample = documents[documents['index'] == 4310].values[0][0]

print("Sample document is selected for pre-processing: {}".format(sample))
# Out:
# Sample document is selected for pre-processing: rain helps dampen bushfires

# %%
words = []

for word in sample.split(' '):
    words.append(word)
    
print("Words found after splitting the sample document: {}".format(words))
# Out:
# Words found after splitting the sample document: ['rain', 'helps', 'dampen', 'bushfires']

# %%
print("Tokenized and lemmatized document: {}".format(preprocess(sample)))
# Out:
# Tokenized and lemmatized document: ['rain', 'help', 'dampen', 'bushfir']

# %%
# pre-processing all the documents

preprocessed_documents = documents['headline_text'].map(preprocess)

# %%
preprocessed_documents[:10]
# Out:
# 0            [decid, communiti, broadcast, licenc]
# 1                               [wit, awar, defam]
# 2           [call, infrastructur, protect, summit]
# 3                      [staff, aust, strike, rise]
# 4             [strike, affect, australian, travel]
# 5               [ambiti, olsson, win, tripl, jump]
# 6           [antic, delight, record, break, barca]
# 7    [aussi, qualifi, stosur, wast, memphi, match]
# 8            [aust, address, secur, council, iraq]
# 9                         [australia, lock, timet]
# Name: headline_text, dtype: object

# %%
# creating a dictionary from the above processed documents

dictionary = gensim.corpora.Dictionary(preprocessed_documents)

# %%
count = 0

for key, value in dictionary.iteritems():
    print("Key: {} and Value: {}".format(key, value))
    count += 1
    
    if count > 10:
        break
# Out:
# Key: 0 and Value: broadcast
# Key: 1 and Value: communiti
# Key: 2 and Value: decid
# Key: 3 and Value: licenc
# Key: 4 and Value: awar
# Key: 5 and Value: defam
# Key: 6 and Value: wit
# Key: 7 and Value: call
# Key: 8 and Value: infrastructur
# Key: 9 and Value: protect
# Key: 10 and Value: summit

# %%
# filter out extreme tokens in the document

dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)

# %%
bag_of_words = [dictionary.doc2bow(document=document) for document in preprocessed_documents]

# %%
bag_of_words[4310]
# Out:
# [(76, 1), (112, 1), (483, 1), (4014, 1)]

# %%
## preview of bag of words of our sample preprocessed document

sample_bag_of_words = bag_of_words[4310]

for i in range(len(sample_bag_of_words)):
    print("Word: {} (\"{}\") appears: {} times.".format(sample_bag_of_words[i][0], dictionary[sample_bag_of_words[i][0]], sample_bag_of_words[i][1]))
# Out:
# Word: 76 ("bushfir") appears: 1 times.
# Word: 112 ("help") appears: 1 times.
# Word: 483 ("rain") appears: 1 times.
# Word: 4014 ("dampen") appears: 1 times.

# %% [markdown]
# # TF-IDF

# %%
from gensim import corpora, models

tfidf = models.TfidfModel(bag_of_words)
corpus_tfidf = tfidf[bag_of_words]

from pprint import pprint

for document in corpus_tfidf:
    pprint(document)
    break
# Out:
# [(0, 0.5892908867507543),
#  (1, 0.38929654337861147),
#  (2, 0.4964985175717023),
#  (3, 0.5046520327464028)]

# %% [markdown]
# # Running LDA using Bag of words

# %%
# training our model using gensim LdaMulticore

model = gensim.models.LdaMulticore(bag_of_words, num_topics=10, id2word=dictionary, passes=2, workers=2)

# %%
for index, topic in model.print_topics(-1):
    print("Topic: {} \n Words: {}".format(index, topic))
# Out:
# Topic: 0
#  Words: 0.033*"charg" + 0.031*"court" + 0.020*"face" + 0.020*"murder" + 0.018*"alleg" + 0.017*"brisban" + 0.017*"final" + 0.016*"accus" + 0.015*"child" + 0.013*"trial"
# Topic: 1
#  Words: 0.034*"govern" + 0.018*"year" + 0.016*"hour" + 0.016*"elect" + 0.015*"adelaid" + 0.014*"china" + 0.013*"break" + 0.012*"student" + 0.012*"busi" + 0.011*"news"
# Topic: 2
#  Words: 0.055*"polic" + 0.026*"death" + 0.020*"perth" + 0.017*"hous" + 0.016*"miss" + 0.015*"donald" + 0.014*"arrest" + 0.013*"investig" + 0.013*"woman" + 0.011*"children"
# Topic: 3
#  Words: 0.023*"nation" + 0.021*"home" + 0.019*"countri" + 0.019*"women" + 0.018*"australia" + 0.018*"rural" + 0.016*"world" + 0.016*"rise" + 0.015*"test" + 0.013*"leagu"
# Topic: 4
#  Words: 0.020*"hospit" + 0.016*"leav" + 0.015*"deal" + 0.012*"melbourn" + 0.012*"campaign" + 0.011*"john" + 0.011*"adelaid" + 0.011*"season" + 0.010*"lose" + 0.010*"unit"
# Topic: 5
#  Words: 0.043*"australia" + 0.021*"market" + 0.017*"drug" + 0.015*"australian" + 0.015*"record" + 0.015*"share" + 0.013*"fall" + 0.012*"bank" + 0.011*"victorian" + 0.011*"price"
# Topic: 6
#  Words: 0.024*"australian" + 0.023*"kill" + 0.019*"attack" + 0.019*"die" + 0.018*"interview" + 0.015*"dead" + 0.013*"island" + 0.012*"crash" + 0.011*"forc" + 0.009*"drum"
# Topic: 7
#  Words: 0.022*"plan" + 0.017*"council" + 0.015*"live" + 0.012*"water" + 0.012*"fund" + 0.012*"say" + 0.011*"chang" + 0.011*"concern" + 0.010*"labor" + 0.010*"indigen"
# Topic: 8
#  Words: 0.034*"trump" + 0.031*"sydney" + 0.027*"queensland" + 0.021*"north" + 0.020*"coast" + 0.017*"state" + 0.015*"south" + 0.015*"tasmania" + 0.014*"west" + 0.013*"servic"
# Topic: 9
#  Words: 0.023*"canberra" + 0.021*"help" + 0.017*"win" + 0.016*"turnbul" + 0.012*"guilti" + 0.012*"tasmanian" + 0.011*"releas" + 0.011*"violenc" + 0.010*"korea" + 0.010*"program"

# %%
tfidf_model = gensim.models.LdaMulticore(corpus_tfidf, num_topics=10, id2word=dictionary, passes=2, workers=4)

for index, topic in tfidf_model.print_topics(-1):
    print("Topic: {}, Words: {}".format(index, topic))
# Out:
# Topic: 0, Words: 0.021*"countri" + 0.020*"hour" + 0.010*"price" + 0.009*"market" + 0.007*"rise" + 0.007*"share" + 0.007*"farm" + 0.007*"cattl" + 0.006*"rat" + 0.006*"monday"
# Topic: 1, Words: 0.006*"live" + 0.006*"christma" + 0.006*"abbott" + 0.006*"australia" + 0.006*"fish" + 0.005*"central" + 0.005*"queensland" + 0.005*"histori" + 0.005*"australian" + 0.005*"hunter"
# Topic: 2, Words: 0.010*"grandstand" + 0.009*"dead" + 0.008*"korea" + 0.008*"climat" + 0.008*"kill" + 0.008*"novemb" + 0.007*"dairi" + 0.007*"june" + 0.006*"islam" + 0.006*"syria"
# Topic: 3, Words: 0.018*"polic" + 0.017*"charg" + 0.014*"murder" + 0.013*"crash" + 0.012*"woman" + 0.012*"court" + 0.010*"alleg" + 0.010*"death" + 0.009*"jail" + 0.008*"assault"
# Topic: 4, Words: 0.026*"rural" + 0.011*"turnbul" + 0.011*"donald" + 0.008*"juli" + 0.008*"health" + 0.007*"wednesday" + 0.007*"mental" + 0.007*"thursday" + 0.007*"care" + 0.007*"august"
# Topic: 5, Words: 0.011*"weather" + 0.008*"bushfir" + 0.008*"michael" + 0.007*"flood" + 0.006*"fire" + 0.006*"burn" + 0.006*"cyclon" + 0.006*"jam" + 0.006*"home" + 0.005*"quiz"
# Topic: 6, Words: 0.027*"trump" + 0.014*"drum" + 0.009*"celebr" + 0.009*"friday" + 0.008*"tuesday" + 0.007*"post" + 0.007*"april" + 0.006*"scott" + 0.006*"presid" + 0.006*"wall"
# Topic: 7, Words: 0.018*"news" + 0.009*"busi" + 0.008*"octob" + 0.007*"peter" + 0.006*"zealand" + 0.006*"right" + 0.006*"anim" + 0.005*"know" + 0.005*"human" + 0.005*"breakfast"
# Topic: 8, Words: 0.018*"interview" + 0.010*"final" + 0.009*"podcast" + 0.009*"leagu" + 0.008*"world" + 0.008*"australia" + 0.007*"beat" + 0.006*"win" + 0.006*"open" + 0.005*"test"
# Topic: 9, Words: 0.010*"govern" + 0.010*"elect" + 0.007*"fund" + 0.007*"labor" + 0.007*"sport" + 0.006*"council" + 0.006*"say" + 0.006*"budget" + 0.006*"liber" + 0.006*"feder"

# %% [markdown]
# ## Evaluation by classifing simple document using LDA Bag of words model

# %%
preprocessed_documents[4310]
# Out:
# ['rain', 'help', 'dampen', 'bushfir']

# %%
for index, score in sorted(tfidf_model[bag_of_words[4310]], key=lambda tup: -1 * tup[1]):
    print("\nScore: {} \t \nTopic: {}".format(score, tfidf_model.print_topics(index, 10)))
# Out:
# Score: 0.5588955879211426
# Topic: [(6, '0.027*"trump" + 0.014*"drum" + 0.009*"celebr" + 0.009*"friday" + 0.008*"tuesday" + 0.007*"post" + 0.007*"april" + 0.006*"scott" + 0.006*"presid" + 0.006*"wall"'), (5, '0.011*"weather" + 0.008*"bushfir" + 0.008*"michael" + 0.007*"flood" + 0.006*"fire" + 0.006*"burn" + 0.006*"cyclon" + 0.006*"jam" + 0.006*"home" + 0.005*"quiz"'), (9, '0.010*"govern" + 0.010*"elect" + 0.007*"fund" + 0.007*"labor" + 0.007*"sport" + 0.006*"council" + 0.006*"say" + 0.006*"budget" + 0.006*"liber" + 0.006*"feder"'), (7, '0.018*"news" + 0.009*"busi" + 0.008*"octob" + 0.007*"peter" + 0.006*"zealand" + 0.006*"right" + 0.006*"anim" + 0.005*"know" + 0.005*"human" + 0.005*"breakfast"'), (3, '0.018*"polic" + 0.017*"charg" + 0.014*"murder" + 0.013*"crash" + 0.012*"woman" + 0.012*"court" + 0.010*"alleg" + 0.010*"death" + 0.009*"jail" + 0.008*"assault"')]
#
# Score: 0.2810365855693817
# Topic: [(4, '0.026*"rural" + 0.011*"turnbul" + 0.011*"donald" + 0.008*"juli" + 0.008*"health" + 0.007*"wednesday" + 0.007*"mental" + 0.007*"thursday" + 0.007*"care" + 0.007*"august"'), (7, '0.018*"news" + 0.009*"busi" + 0.008*"octob" + 0.007*"peter" + 0.006*"zealand" + 0.006*"right" + 0.006*"anim" + 0.005*"know" + 0.005*"human" + 0.005*"breakfast"'), (9, '0.010*"govern" + 0.010*"elect" + 0.007*"fund" + 0.007*"labor" + 0.007*"sport" + 0.006*"council" + 0.006*"say" + 0.006*"budget" + 0.006*"liber" + 0.006*"feder"'), (1, '0.006*"live" + 0.006*"christma" + 0.006*"abbott" + 0.006*"australia" + 0.006*"fish" + 0.005*"central" + 0.005*"queensland" + 0.005*"histori" + 0.005*"australian" + 0.005*"hunter"'), (3, '0.018*"polic" + 0.017*"charg" + 0.014*"murder" + 0.013*"crash" + 0.012*"woman" + 0.012*"court" + 0.010*"alleg" + 0.010*"death" + 0.009*"jail" + 0.008*"assault"'), (2, '0.010*"grandstand" + 0.009*"dead" + 0.008*"korea" + 0.008*"climat" + 0.008*"kill" + 0.008*"novemb" + 0.007*"dairi" + 0.007*"june" + 0.006*"islam" + 0.006*"syria"'), (6, '0.027*"trump" + 0.014*"drum" + 0.009*"celebr" + 0.009*"friday" + 0.008*"tuesday" + 0.007*"post" + 0.007*"april" + 0.006*"scott" + 0.006*"presid" + 0.006*"wall"')]
#
# Score: 0.02001221664249897
# Topic: [(1, '0.006*"live" + 0.006*"christma" + 0.006*"abbott" + 0.006*"australia" + 0.006*"fish" + 0.005*"central" + 0.005*"queensland" + 0.005*"histori" + 0.005*"australian" + 0.005*"hunter"')]
#
# Score: 0.020008698105812073
# Topic: [(2, '0.010*"grandstand" + 0.009*"dead" + 0.008*"korea" + 0.008*"climat" + 0.008*"kill" + 0.008*"novemb" + 0.007*"dairi" + 0.007*"june" + 0.006*"islam" + 0.006*"syria"'), (1, '0.006*"live" + 0.006*"christma" + 0.006*"abbott" + 0.006*"australia" + 0.006*"fish" + 0.005*"central" + 0.005*"queensland" + 0.005*"histori" + 0.005*"australian" + 0.005*"hunter"'), (7, '0.018*"news" + 0.009*"busi" + 0.008*"octob" + 0.007*"peter" + 0.006*"zealand" + 0.006*"right" + 0.006*"anim" + 0.005*"know" + 0.005*"human" + 0.005*"breakfast"'), (5, '0.011*"weather" + 0.008*"bushfir" + 0.008*"michael" + 0.007*"flood" + 0.006*"fire" + 0.006*"burn" + 0.006*"cyclon" + 0.006*"jam" + 0.006*"home" + 0.005*"quiz"')]
#
# Score: 0.020008385181427002
# Topic: [(2, '0.010*"grandstand" + 0.009*"dead" + 0.008*"korea" + 0.008*"climat" + 0.008*"kill" + 0.008*"novemb" + 0.007*"dairi" + 0.007*"june" + 0.006*"islam" + 0.006*"syria"'), (1, '0.006*"live" + 0.006*"christma" + 0.006*"abbott" + 0.006*"australia" + 0.006*"fish" + 0.005*"central" + 0.005*"queensland" + 0.005*"histori" + 0.005*"australian" + 0.005*"hunter"'), (6, '0.027*"trump" + 0.014*"drum" + 0.009*"celebr" + 0.009*"friday" + 0.008*"tuesday" + 0.007*"post" + 0.007*"april" + 0.006*"scott" + 0.006*"presid" + 0.006*"wall"'), (5, '0.011*"weather" + 0.008*"bushfir" + 0.008*"michael" + 0.007*"flood" + 0.006*"fire" + 0.006*"burn" + 0.006*"cyclon" + 0.006*"jam" + 0.006*"home" + 0.005*"quiz"'), (0, '0.021*"countri" + 0.020*"hour" + 0.010*"price" + 0.009*"market" + 0.007*"rise" + 0.007*"share" + 0.007*"farm" + 0.007*"cattl" + 0.006*"rat" + 0.006*"monday"'), (7, '0.018*"news" + 0.009*"busi" + 0.008*"octob" + 0.007*"peter" + 0.006*"zealand" + 0.006*"right" + 0.006*"anim" + 0.005*"know" + 0.005*"human" + 0.005*"breakfast"'), (3, '0.018*"polic" + 0.017*"charg" + 0.014*"murder" + 0.013*"crash" + 0.012*"woman" + 0.012*"court" + 0.010*"alleg" + 0.010*"death" + 0.009*"jail" + 0.008*"assault"'), (4, '0.026*"rural" + 0.011*"turnbul" + 0.011*"donald" + 0.008*"juli" + 0.008*"health" + 0.007*"wednesday" + 0.007*"mental" + 0.007*"thursday" + 0.007*"care" + 0.007*"august"'), (8, '0.018*"interview" + 0.010*"final" + 0.009*"podcast" + 0.009*"leagu" + 0.008*"world" + 0.008*"australia" + 0.007*"beat" + 0.006*"win" + 0.006*"open" + 0.005*"test"'), (9, '0.010*"govern" + 0.010*"elect" + 0.007*"fund" + 0.007*"labor" + 0.007*"sport" + 0.006*"council" + 0.006*"say" + 0.006*"budget" + 0.006*"liber" + 0.006*"feder"')]
#
# Score: 0.020008333027362823
# Topic: [(2, '0.010*"grandstand" + 0.009*"dead" + 0.008*"korea" + 0.008*"climat" + 0.008*"kill" + 0.008*"novemb" + 0.007*"dairi" + 0.007*"june" + 0.006*"islam" + 0.006*"syria"'), (5, '0.011*"weather" + 0.008*"bushfir" + 0.008*"michael" + 0.007*"flood" + 0.006*"fire" + 0.006*"burn" + 0.006*"cyclon" + 0.006*"jam" + 0.006*"home" + 0.005*"quiz"'), (6, '0.027*"trump" + 0.014*"drum" + 0.009*"celebr" + 0.009*"friday" + 0.008*"tuesday" + 0.007*"post" + 0.007*"april" + 0.006*"scott" + 0.006*"presid" + 0.006*"wall"'), (9, '0.010*"govern" + 0.010*"elect" + 0.007*"fund" + 0.007*"labor" + 0.007*"sport" + 0.006*"council" + 0.006*"say" + 0.006*"budget" + 0.006*"liber" + 0.006*"feder"'), (4, '0.026*"rural" + 0.011*"turnbul" + 0.011*"donald" + 0.008*"juli" + 0.008*"health" + 0.007*"wednesday" + 0.007*"mental" + 0.007*"thursday" + 0.007*"care" + 0.007*"august"'), (3, '0.018*"polic" + 0.017*"charg" + 0.014*"murder" + 0.013*"crash" + 0.012*"woman" + 0.012*"court" + 0.010*"alleg" + 0.010*"death" + 0.009*"jail" + 0.008*"assault"'), (0, '0.021*"countri" + 0.020*"hour" + 0.010*"price" + 0.009*"market" + 0.007*"rise" + 0.007*"share" + 0.007*"farm" + 0.007*"cattl" + 0.006*"rat" + 0.006*"monday"'), (8, '0.018*"interview" + 0.010*"final" + 0.009*"podcast" + 0.009*"leagu" + 0.008*"world" + 0.008*"australia" + 0.007*"beat" + 0.006*"win" + 0.006*"open" + 0.005*"test"'), (7, '0.018*"news" + 0.009*"busi" + 0.008*"octob" + 0.007*"peter" + 0.006*"zealand" + 0.006*"right" + 0.006*"anim" + 0.005*"know" + 0.005*"human" + 0.005*"breakfast"')]
#
# Score: 0.02000812441110611
# Topic: [(8, '0.018*"interview" + 0.010*"final" + 0.009*"podcast" + 0.009*"leagu" + 0.008*"world" + 0.008*"australia" + 0.007*"beat" + 0.006*"win" + 0.006*"open" + 0.005*"test"'), (3, '0.018*"polic" + 0.017*"charg" + 0.014*"murder" + 0.013*"crash" + 0.012*"woman" + 0.012*"court" + 0.010*"alleg" + 0.010*"death" + 0.009*"jail" + 0.008*"assault"')]
#
# Score: 0.020008089020848274
# Topic: [(9, '0.010*"govern" + 0.010*"elect" + 0.007*"fund" + 0.007*"labor" + 0.007*"sport" + 0.006*"council" + 0.006*"say" + 0.006*"budget" + 0.006*"liber" + 0.006*"feder"'), (5, '0.011*"weather" + 0.008*"bushfir" + 0.008*"michael" + 0.007*"flood" + 0.006*"fire" + 0.006*"burn" + 0.006*"cyclon" + 0.006*"jam" + 0.006*"home" + 0.005*"quiz"'), (7, '0.018*"news" + 0.009*"busi" + 0.008*"octob" + 0.007*"peter" + 0.006*"zealand" + 0.006*"right" + 0.006*"anim" + 0.005*"know" + 0.005*"human" + 0.005*"breakfast"')]
#
# Score: 0.020007029175758362
# Topic: [(9, '0.010*"govern" + 0.010*"elect" + 0.007*"fund" + 0.007*"labor" + 0.007*"sport" + 0.006*"council" + 0.006*"say" + 0.006*"budget" + 0.006*"liber" + 0.006*"feder"'), (4, '0.026*"rural" + 0.011*"turnbul" + 0.011*"donald" + 0.008*"juli" + 0.008*"health" + 0.007*"wednesday" + 0.007*"mental" + 0.007*"thursday" + 0.007*"care" + 0.007*"august"'), (2, '0.010*"grandstand" + 0.009*"dead" + 0.008*"korea" + 0.008*"climat" + 0.008*"kill" + 0.008*"novemb" + 0.007*"dairi" + 0.007*"june" + 0.006*"islam" + 0.006*"syria"'), (3, '0.018*"polic" + 0.017*"charg" + 0.014*"murder" + 0.013*"crash" + 0.012*"woman" + 0.012*"court" + 0.010*"alleg" + 0.010*"death" + 0.009*"jail" + 0.008*"assault"'), (0, '0.021*"countri" + 0.020*"hour" + 0.010*"price" + 0.009*"market" + 0.007*"rise" + 0.007*"share" + 0.007*"farm" + 0.007*"cattl" + 0.006*"rat" + 0.006*"monday"'), (7, '0.018*"news" + 0.009*"busi" + 0.008*"octob" + 0.007*"peter" + 0.006*"zealand" + 0.006*"right" + 0.006*"anim" + 0.005*"know" + 0.005*"human" + 0.005*"breakfast"')]
#
# Score: 0.020006978884339333
# Topic: [(3, '0.018*"polic" + 0.017*"charg" + 0.014*"murder" + 0.013*"crash" + 0.012*"woman" + 0.012*"court" + 0.010*"alleg" + 0.010*"death" + 0.009*"jail" + 0.008*"assault"'), (6, '0.027*"trump" + 0.014*"drum" + 0.009*"celebr" + 0.009*"friday" + 0.008*"tuesday" + 0.007*"post" + 0.007*"april" + 0.006*"scott" + 0.006*"presid" + 0.006*"wall"'), (1, '0.006*"live" + 0.006*"christma" + 0.006*"abbott" + 0.006*"australia" + 0.006*"fish" + 0.005*"central" + 0.005*"queensland" + 0.005*"histori" + 0.005*"australian" + 0.005*"hunter"'), (5, '0.011*"weather" + 0.008*"bushfir" + 0.008*"michael" + 0.007*"flood" + 0.006*"fire" + 0.006*"burn" + 0.006*"cyclon" + 0.006*"jam" + 0.006*"home" + 0.005*"quiz"'), (8, '0.018*"interview" + 0.010*"final" + 0.009*"podcast" + 0.009*"leagu" + 0.008*"world" + 0.008*"australia" + 0.007*"beat" + 0.006*"win" + 0.006*"open" + 0.005*"test"'), (4, '0.026*"rural" + 0.011*"turnbul" + 0.011*"donald" + 0.008*"juli" + 0.008*"health" + 0.007*"wednesday" + 0.007*"mental" + 0.007*"thursday" + 0.007*"care" + 0.007*"august"'), (7, '0.018*"news" + 0.009*"busi" + 0.008*"octob" + 0.007*"peter" + 0.006*"zealand" + 0.006*"right" + 0.006*"anim" + 0.005*"know" + 0.005*"human" + 0.005*"breakfast"'), (0, '0.021*"countri" + 0.020*"hour" + 0.010*"price" + 0.009*"market" + 0.007*"rise" + 0.007*"share" + 0.007*"farm" + 0.007*"cattl" + 0.006*"rat" + 0.006*"monday"')]

# %% [markdown]
# ### Testing on unseen document

# %%
test_document = "How a Pentgon deal became an identity crisis for Google"

bag_of_words_vector = dictionary.doc2bow(preprocess(test_document))

# %%
for index, score in sorted(tfidf_model[bag_of_words_vector], key=lambda tup: -1 * tup[1]):
    print("Score: {} \t Topic: {}\n".format(score, tfidf_model.print_topics(index, 5)))
# Out:
# Score: 0.5894848108291626 	 Topic: [(4, '0.026*"rural" + 0.011*"turnbul" + 0.011*"donald" + 0.008*"juli" + 0.008*"health"'), (2, '0.010*"grandstand" + 0.009*"dead" + 0.008*"korea" + 0.008*"climat" + 0.008*"kill"'), (9, '0.010*"govern" + 0.010*"elect" + 0.007*"fund" + 0.007*"labor" + 0.007*"sport"'), (7, '0.018*"news" + 0.009*"busi" + 0.008*"octob" + 0.007*"peter" + 0.006*"zealand"'), (3, '0.018*"polic" + 0.017*"charg" + 0.014*"murder" + 0.013*"crash" + 0.012*"woman"'), (6, '0.027*"trump" + 0.014*"drum" + 0.009*"celebr" + 0.009*"friday" + 0.008*"tuesday"'), (8, '0.018*"interview" + 0.010*"final" + 0.009*"podcast" + 0.009*"leagu" + 0.008*"world"'), (5, '0.011*"weather" + 0.008*"bushfir" + 0.008*"michael" + 0.007*"flood" + 0.006*"fire"'), (0, '0.021*"countri" + 0.020*"hour" + 0.010*"price" + 0.009*"market" + 0.007*"rise"'), (1, '0.006*"live" + 0.006*"christma" + 0.006*"abbott" + 0.006*"australia" + 0.006*"fish"')]
#
# Score: 0.2504499852657318 	 Topic: [(1, '0.006*"live" + 0.006*"christma" + 0.006*"abbott" + 0.006*"australia" + 0.006*"fish"'), (5, '0.011*"weather" + 0.008*"bushfir" + 0.008*"michael" + 0.007*"flood" + 0.006*"fire"'), (9, '0.010*"govern" + 0.010*"elect" + 0.007*"fund" + 0.007*"labor" + 0.007*"sport"'), (0, '0.021*"countri" + 0.020*"hour" + 0.010*"price" + 0.009*"market" + 0.007*"rise"'), (7, '0.018*"news" + 0.009*"busi" + 0.008*"octob" + 0.007*"peter" + 0.006*"zealand"'), (2, '0.010*"grandstand" + 0.009*"dead" + 0.008*"korea" + 0.008*"climat" + 0.008*"kill"'), (8, '0.018*"interview" + 0.010*"final" + 0.009*"podcast" + 0.009*"leagu" + 0.008*"world"'), (6, '0.027*"trump" + 0.014*"drum" + 0.009*"celebr" + 0.009*"friday" + 0.008*"tuesday"')]
#
# Score: 0.02001933753490448 	 Topic: [(3, '0.018*"polic" + 0.017*"charg" + 0.014*"murder" + 0.013*"crash" + 0.012*"woman"'), (9, '0.010*"govern" + 0.010*"elect" + 0.007*"fund" + 0.007*"labor" + 0.007*"sport"')]
#
# Score: 0.020009759813547134 	 Topic: [(0, '0.021*"countri" + 0.020*"hour" + 0.010*"price" + 0.009*"market" + 0.007*"rise"'), (2, '0.010*"grandstand" + 0.009*"dead" + 0.008*"korea" + 0.008*"climat" + 0.008*"kill"'), (4, '0.026*"rural" + 0.011*"turnbul" + 0.011*"donald" + 0.008*"juli" + 0.008*"health"'), (9, '0.010*"govern" + 0.010*"elect" + 0.007*"fund" + 0.007*"labor" + 0.007*"sport"'), (7, '0.018*"news" + 0.009*"busi" + 0.008*"octob" + 0.007*"peter" + 0.006*"zealand"'), (6, '0.027*"trump" + 0.014*"drum" + 0.009*"celebr" + 0.009*"friday" + 0.008*"tuesday"'), (5, '0.011*"weather" + 0.008*"bushfir" + 0.008*"michael" + 0.007*"flood" + 0.006*"fire"')]
#
# Score: 0.02000696212053299 	 Topic: [(4, '0.026*"rural" + 0.011*"turnbul" + 0.011*"donald" + 0.008*"juli" + 0.008*"health"'), (1, '0.006*"live" + 0.006*"christma" + 0.006*"abbott" + 0.006*"australia" + 0.006*"fish"'), (2, '0.010*"grandstand" + 0.009*"dead" + 0.008*"korea" + 0.008*"climat" + 0.008*"kill"'), (0, '0.021*"countri" + 0.020*"hour" + 0.010*"price" + 0.009*"market" + 0.007*"rise"')]
#
# Score: 0.020006593316793442 	 Topic: [(6, '0.027*"trump" + 0.014*"drum" + 0.009*"celebr" + 0.009*"friday" + 0.008*"tuesday"'), (5, '0.011*"weather" + 0.008*"bushfir" + 0.008*"michael" + 0.007*"flood" + 0.006*"fire"'), (9, '0.010*"govern" + 0.010*"elect" + 0.007*"fund" + 0.007*"labor" + 0.007*"sport"'), (1, '0.006*"live" + 0.006*"christma" + 0.006*"abbott" + 0.006*"australia" + 0.006*"fish"'), (3, '0.018*"polic" + 0.017*"charg" + 0.014*"murder" + 0.013*"crash" + 0.012*"woman"'), (0, '0.021*"countri" + 0.020*"hour" + 0.010*"price" + 0.009*"market" + 0.007*"rise"'), (2, '0.010*"grandstand" + 0.009*"dead" + 0.008*"korea" + 0.008*"climat" + 0.008*"kill"'), (8, '0.018*"interview" + 0.010*"final" + 0.009*"podcast" + 0.009*"leagu" + 0.008*"world"'), (7, '0.018*"news" + 0.009*"busi" + 0.008*"octob" + 0.007*"peter" + 0.006*"zealand"')]
#
# Score: 0.0200062096118927 	 Topic: [(6, '0.027*"trump" + 0.014*"drum" + 0.009*"celebr" + 0.009*"friday" + 0.008*"tuesday"'), (7, '0.018*"news" + 0.009*"busi" + 0.008*"octob" + 0.007*"peter" + 0.006*"zealand"'), (8, '0.018*"interview" + 0.010*"final" + 0.009*"podcast" + 0.009*"leagu" + 0.008*"world"'), (4, '0.026*"rural" + 0.011*"turnbul" + 0.011*"donald" + 0.008*"juli" + 0.008*"health"'), (2, '0.010*"grandstand" + 0.009*"dead" + 0.008*"korea" + 0.008*"climat" + 0.008*"kill"'), (0, '0.021*"countri" + 0.020*"hour" + 0.010*"price" + 0.009*"market" + 0.007*"rise"')]
#
# Score: 0.020005963742733 	 Topic: [(6, '0.027*"trump" + 0.014*"drum" + 0.009*"celebr" + 0.009*"friday" + 0.008*"tuesday"')]
#
# Score: 0.020005276426672935 	 Topic: [(1, '0.006*"live" + 0.006*"christma" + 0.006*"abbott" + 0.006*"australia" + 0.006*"fish"'), (2, '0.010*"grandstand" + 0.009*"dead" + 0.008*"korea" + 0.008*"climat" + 0.008*"kill"'), (4, '0.026*"rural" + 0.011*"turnbul" + 0.011*"donald" + 0.008*"juli" + 0.008*"health"'), (3, '0.018*"polic" + 0.017*"charg" + 0.014*"murder" + 0.013*"crash" + 0.012*"woman"'), (0, '0.021*"countri" + 0.020*"hour" + 0.010*"price" + 0.009*"market" + 0.007*"rise"')]
#
# Score: 0.02000509761273861 	 Topic: [(8, '0.018*"interview" + 0.010*"final" + 0.009*"podcast" + 0.009*"leagu" + 0.008*"world"'), (4, '0.026*"rural" + 0.011*"turnbul" + 0.011*"donald" + 0.008*"juli" + 0.008*"health"'), (1, '0.006*"live" + 0.006*"christma" + 0.006*"abbott" + 0.006*"australia" + 0.006*"fish"')]
