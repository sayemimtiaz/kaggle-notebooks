# %%
import numpy as np 
import pandas as pd 
import os
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from nltk.corpus import stopwords

# %% [markdown]
# # Dataset

# %%
movie_data=pd.read_csv("../input/netflix-shows/netflix_titles.csv")
movie_data.head()

# %%
stopword=stopwords.words('english')

# %% [markdown]
# # TF-IDF matrix generation

# %%
tfidf = TfidfVectorizer(stopword)
movie_data.descrition = movie_data.description.fillna('')
tfidf_matrix = tfidf.fit_transform(movie_data.description)

# %% [markdown]
# # Cosine Similarity according to content

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity_df = pd.DataFrame(cosine_similarity(tfidf_matrix))

# %%
similarity_df.head()

# %%
similarity_df.index=movie_data.title
similarity_df.columns=movie_data.title
similarity_df.head()

# %%
recommended_movies={}
for i in similarity_df.columns:
    recommended_movies[str(i)]=[similarity_df[similarity_df.index!=i][i].sort_values(ascending = False)[0:10].index]

# %% [markdown]
# # Finding 10 similar movies

# %%
def get_recommendation(title):
    return recommended_movies[title]

# %%
get_recommendation('The Matrix')

# %%
recommended_movies
