# %% [markdown]
# ![](https://s2982.pcdn.co/wp-content/uploads/2016/01/goodreads.jpg.optimal.jpg)

# %% [markdown]
# # Modules Required

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import plotly.express as px

# %% [markdown]
# # Fetching the dataset

# %%
df = pd.read_csv('../input/goodreadsbooks/books.csv', error_bad_lines = False)

# %% [markdown]
# # Book with the highest text reviews

# %% [markdown]
# As it can be seen in the following cell, there are multiple entries for a single book:

# %%
print("Number of total books: {}".format(df['title'].count()))
print("Number of unique books: {}".format(df['title'].value_counts().count()))

# %%
most_rated = df.groupby('title')['text_reviews_count'].sum().sort_values(ascending=False).head(10)

# %%
most_rated

# %% [markdown]
# # Vizzzz.....

# %%
plt.figure(figsize=(15,10))
sns.barplot(most_rated, most_rated.index, palette='rocket')

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTxJ-KKXbb3J0IEJifbqRz9Ki7qb_FoBR6bWQ&usqp=CAU)
