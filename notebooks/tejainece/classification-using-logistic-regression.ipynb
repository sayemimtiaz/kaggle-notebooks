# %% [markdown]
# # Learn classification using Logistic regression
#
# Use the dataset to learn classification using Logistic regression

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt

np.random.seed(123456)

# %%
dataset = pd.read_csv("../input/uci-news-aggregator.csv")
dataset.head(n=1)

# %%
import re
import string

# Convert the title to lowercase, replace punctuations with space and replaces multiple spaces
# with single space
def clean_text(s):
    s = s.lower()
    for ch in string.punctuation:                                                                                                     
        s = s.replace(ch, " ") 
        s = re.sub(' +',' ', s)
    return s

dataset['TEXT'] = [clean_text(s) for s in dataset.TITLE]

# %%
dataset.TITLE.head(n=3)

# %%
dataset.TEXT.head(n=3)

# %%
from sklearn.feature_extraction.text import CountVectorizer
# pull the data into vectors
vectorizer = CountVectorizer()
x = vectorizer.fit_transform(dataset['TEXT'])

# %%
v1 = CountVec
