# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Reading csv into panda dataframe
df = pd.read_csv("./../input/craigslist-carstrucks-data/vehicles.csv")

# %%
df.head()

# %%
df.info()

# %%
df['price'].describe() # For descriptive analysis of price

# %% [markdown]
# ### No of cars per manufacturer. Displaying only top 30 manufacturers based on count of cars.

# %%
df['manufacturer'].value_counts().head(30).plot(kind='barh', figsize=(4,10))

# %% [markdown]
# ### For each type of car, plotting count of cars with respect to cylinders and Fuel type.
# ### *Inference*: Cars are mostly of cars/sedan/SUV having 4/8 cylinders and operating on fuel type gas.

# %%
sns.catplot(x="cylinders", hue="fuel", row="type", data=df, kind="count", height=3, aspect=4)

# %%
plt.figure(figsize=(30, 20))
sns.countplot(df['type'])

# %%
plt.figure(figsize=(30, 20))
sns.countplot(df['type'], hue=df['drive'])

# %%
plt.figure(figsize=(30, 20))
sns.countplot(df['type'], hue=df['transmission'])

# %%
plt.figure(figsize=(30, 20))
sns.countplot(df['type'], hue=df['fuel'])

# %%
plt.figure(figsize=(30, 20))
sns.countplot(df['type'], hue=df['cylinders'])

# %%
plt.figure(figsize=(30, 20))
sns.countplot(df['type'], hue=df['size'])

# %%
plt.figure(figsize=(30, 20))
sns.barplot(df['type'], df['price'], hue= df['transmission'])

# %%
# Inference: Cars of type hatchback and fwd drive has higher range of prices.
plt.figure(figsize=(30, 20))
sns.pointplot(df['type'], df['price'], hue=df['drive'])

# %%
# Inference: Cars with fuel type gas are more in quantity and have more variable prices.
plt.figure(figsize=(10, 10))
sns.stripplot(df['fuel'], df['price'], jitter= True)

# %%
# Inference: Cars with less distance travelled reading have more prices.
plt.figure(figsize=(10, 10))
sns.jointplot(df['odometer'], df['price'])

# %%
df = df.head(20000)
df.head()

# %%
import plotly
import plotly.graph_objects as go
import plotly.offline as py
py.init_notebook_mode(connected=True)
print(plotly.__version__)
import pandas as pd

df['text'] = df['manufacturer'] + ' ,' + df['model'] + ', ' + df['type'] + " Price: " +df['price'].astype(str) 

fig = go.Figure(data=go.Scattergeo(
        lon = df['long'],
        lat = df['lat'],
        text = df['text'],
        mode = 'markers',
        #marker_color = df['price'],
         marker = dict(
            size = 8,
            opacity = 0.8,
            reversescale = True,
            autocolorscale = False,
            symbol = 'square',
            line = dict(
                width=1,
                color='rgba(102, 102, 102)'
            ),
            colorscale = 'Blues',
            cmin = 0,
            color = df['price'],
            cmax = df['price'].max(),
            colorbar_title="Used Car Prices"
        )))

fig.update_layout(
        title = 'Geo plot of used cars available for various manufacturers with model/price details. <br>(Hover for manufacturer names)',
        geo = dict(
            scope='usa',
            projection_type='albers usa',
            showland = True,
            landcolor = "rgb(250, 250, 250)",
            subunitcolor = "rgb(217, 217, 217)",
            countrycolor = "rgb(217, 217, 217)",
            countrywidth = 0.5,
            subunitwidth = 0.5
        ),
    )
fig.show()

# %%
import plotly.express as px
df = df.head(1000)
fig = px.box(df, x=df.fuel, y=df.price, color=df.region, notched=True)
fig.show()
