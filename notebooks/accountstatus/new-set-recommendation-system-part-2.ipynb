# %% [markdown]
# # Importing Packages

# %%
import pandas as pd
import numpy as np
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize

# %% [markdown]
# # Having First Look At The Data

# %%
data=pd.read_csv('../input/netflix-shows/netflix_titles.csv')

# %%
data.head()

# %% [markdown]
# # Making some changes :)

# %% [markdown]
# Making a recommendation system just using description :)

# %%
data=data[['title','description']]

# %%
data.head()

# %% [markdown]
# # Starting with the Recommendation System

# %%
data['description']=data['description'].fillna('')

# %%
def rem_stopwords_tokenize(data,name):
      
    def getting(sen):
        example_sent = sen

        stop_words = set(stopwords.words('english')) 

        word_tokens = word_tokenize(example_sent) 

        filtered_sentence = [w for w in word_tokens if not w in stop_words] 

        filtered_sentence = [] 

        for w in word_tokens: 
            if w not in stop_words: 
                filtered_sentence.append(w) 
        return filtered_sentence
    x=[]
    for i in data[name].values:
        x.append(getting(i))
    data[name]=x

# %%
rem_stopwords_tokenize(data,'description')

# %% [markdown]
# # Having a look at the updated data

# %%
data.head()

# %% [markdown]
# # Adding frequency score dictionary for description

# %% [markdown]
# Frequency score dictionary will contain the score of all the words in description . The score is based on the number of times the word occurs . The more number of times the word occurs it will be given less attention at the end ....

# %%
freq_dic={}
for i in data.description:
    for j in i:
        if j not in freq_dic:
            freq_dic[j]=1
        else:
            freq_dic[j]+=1

# %% [markdown]
# # Making Set Recommendation Function

# %%
def set_rec_finder(na,number):
    def intersection(lst1, lst2): 
        return list(set(lst1) & set(lst2)) 
    def find_rec(name):
        x=list(data[data['title']==name]['description'].values)[0]
        score=[]
        for i in range(len(data)):
            inter=intersection(x,data['description'].values[i])
            sc=0
            for pp in inter:
                sc+=freq_dic[pp]
            score.append([sc,data['title'].values[i]])
        return score
    recommendations=find_rec(na)
    recommendations.sort(reverse=True)
    recommendations=np.array(recommendations)
    ans=recommendations[:number,1]
    for i in ans:
        print(i)

# %%
# Enter the movie name and the top n recommendations !!
set_rec_finder('Kabir Singh',10)
