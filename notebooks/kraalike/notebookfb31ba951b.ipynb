# %% [markdown]
# Analüüsime punaste veinide koostisosasid ja kvaliteeti. Rõhk on eriti nendel osadel, mida saame ja oskame ise reguleerida ja muuta, kuna eesmärk on teha paremat veini.
# Graafik 1 näitab erineva kvaliteediga veinide kvantiteeti.

# %%
import itertools
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

datass = pd.read_csv('../input/winequality-red.csv')
datass.groupby(['quality']).count().plot(kind='bar',legend=False,color='blue', figsize=(6,6));

#datass.plot.scatter(x='citric acid', y='pH', s=2, c='red')

#data['quality'].value_counts().plot(kind = 'hist',bins = 6,figsize = (10,12))

# %% [markdown]
# On loogiline, et mida rohkem on veinis sidrunhapet, seda väiksem on pH ehk seda happelisem on vein.
# Allolev hajuvusgraafik näitab aga, et kõige paremad veinid sisaldavad tavaliselt keskmises koguses
# sidrunhapet, seda saab reguleerida mitmel moel.

# %%
import itertools
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
datass = pd.read_csv('../input/winequality-red.csv')
(sns.FacetGrid(datass, hue = 'quality', size = 5, palette = 'Reds')
 .map(plt.scatter, "citric acid", "pH", s = 25)
.add_legend());

# %% [markdown]
# Lisaks tuleb kindlasti jälgida, et pärm sööks enamiku suhkrust ära, muidu jääb alkoholi tase väikseks (!) ja nagu näha, ka kvaliteet langeb.

# %%
import itertools
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
datass = pd.read_csv('../input/winequality-red.csv')
(sns.FacetGrid(datass, hue = 'quality', size = 5, palette = 'Reds')
 .map(plt.scatter, "residual sugar", "alcohol", s = 25)
.add_legend());

# %% [markdown]
# Tuleb välja, et pH sõltub ka sulfaatide sisaldusest.

# %%
import itertools
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
datass = pd.read_csv('../input/winequality-red.csv')
(sns.FacetGrid(datass, hue = 'quality', size = 5, palette = 'Reds')
 .map(plt.scatter, "sulphates", "pH", s = 25)
.add_legend());

# %% [markdown]
# Kokkuvõtvalt näeme, et mida suurem on veini kvaliteet, seda kangem ta on ja seda rohkem sulfaate on
# seal keskmiselt.

# %%
import itertools
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
datass = pd.read_csv('../input/winequality-red.csv')
datass.groupby(["quality"])["citric acid", "sulphates", "alcohol"].mean()
