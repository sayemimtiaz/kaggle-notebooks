# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
data_set = pd.read_csv('../input/students-performance-in-exams/StudentsPerformance.csv')

# %%
data_set.head(5)

# %%
pd.DataFrame([data_set.mean(),
             data_set.median(),
             data_set.std(),
             data_set.var(),],
            index=['Mean', 'Median','Std. dev', 'Variance'])

# %%
data_set['gender'].value_counts()

# %%
data_set.groupby('gender').describe()

# %%
pd.value_counts(data_set['gender']).plot.bar()
plt.title('Students performance histogram')
plt.xlabel('Students')
plt.ylabel('Frequency')

# %%
data_set.duplicated(subset=None, keep='first').sum()

# %%
duplicate_rows = data_set[data_set.duplicated()].copy()
duplicate_rows.groupby('gender').describe()

# %%
pd.DataFrame([data_set.mean(),
            data_set.median(),
             data_set.std(),
             data_set.var()],
             index = ['Mean', 'Median', 'Std dev', 'Variance']
            )

# %%
data_set.isnull().sum().sort_values(ascending = False)

# %%
(data_set.isnull().sum()* 100 / len(data_set)).round(2).sort_values(ascending = False)

# %%
without_duplicate = data_set.drop_duplicates(keep='first').copy()
without_duplicate.head(5)

# %%
without_duplicate.groupby("gender").describe()

# %%
(without_duplicate.isnull().sum()* 100 / len(without_duplicate)).round(2).sort_values(ascending = False)

# %%
sns.heatmap(without_duplicate.isnull(), cbar=True)

# %%
without_dup_na = without_duplicate.dropna(how= "any").copy()

# %%
without_dup_na.isnull().values.any()

# %%
pd.value_counts(without_dup_na['gender']).plot.bar()
plt.title('Student performance histogram')
plt.xlabel('Students')
plt.ylabel('Frequency')

# %%
X = np.array(without_dup_na.iloc[:,without_dup_na.columns != 'type'])
y = np.array(without_dup_na.iloc[:,without_dup_na.columns == 'type'])

print("Shape of X(PREDICTORS): {}".format(X.shape))
print("Shape of y(TARGET): {}".format(y.shape))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=10, shuffle=True)

print("Number of X_train dataset: ", X_train.shape)
print("Number of y_train dataset: ", y_train.shape)
print("\nNumber of X_test dataset: ", X_test.shape)
print("Number of y_test dataset: ", y_test.shape)
