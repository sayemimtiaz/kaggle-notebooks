# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
##importing data
train_data = pd.read_csv('../input/hr-analytics-job-change-of-data-scientists/aug_train.csv')
test_data = pd.read_csv('../input/hr-analytics-job-change-of-data-scientists/aug_test.csv')

# %%
train_data.head()

# %%
test_data.head()

# %%
train_data.isnull().sum()

# %%
test_data.isnull().sum()

# %%
train_data.info()

# %%
train_data.describe().T

# %%
import plotly.express as py
import plotly.graph_objects as go
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.distplot(train_data['training_hours'])

# %%
from sklearn.preprocessing import normalize

# %%
train_data.drop('enrollee_id', axis=1,inplace=True)

# %%
sns.pairplot(train_data)

# %%
train_data.isnull().mean()*100

# %%
# drop enrolled_university, education_level, experience, last_new_job rows with na/null as it it lessthan 5% of total count

train_data.dropna(subset=['enrolled_university','education_level','experience','last_new_job'], axis=0, inplace=True)

# %%
train_data.isnull().mean()*100

# %%
X = train_data.drop('target',axis=1)
y=train_data['target']

# %%
X.head()

# %%
## using imputer to handle missing values
from sklearn.impute import SimpleImputer
imputer =SimpleImputer(strategy='most_frequent')
X_imp = imputer.fit_transform(X)

# %%
X_imp

# %%
X_transformed = pd.DataFrame(X_imp, columns=X.columns, index=X.index)

# %%
X_transformed.head()

# %%
X_transformed.isnull().mean()*100

# %%
#all null values has been removed

# %%
X_transformed.describe().T

# %%
#handling categorical values
plt.title('Distribution by gender')
sns.countplot(data=X_transformed,x='gender', hue='gender')

# %%
plt.title('relevent_experience')
sns.countplot(data=X_transformed,x='relevent_experience', hue='relevent_experience')

# %%
plt.title('education_level')
sns.countplot(data=X_transformed,x='education_level', hue='education_level')

# %%
plt.title('major_discipline')
sns.countplot(data=X_transformed,x='major_discipline', hue='major_discipline')

# %%
X_transformed.head()

# %%
sns.distplot(X_transformed['training_hours'])

# %%
X_transformed['training_hours']=np.log(X_transformed['training_hours'].astype(int))

# %%
X_transformed.info()

# %%
X_transformed['city_development_index']=X_transformed['city_development_index'].astype(float)

# %%
X_transformed.drop('city',axis=1,inplace=True)

# %%
X_transformed['gender'].value_counts()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
gender_encode = LabelEncoder()
X_transformed['gender']=gender_encode.fit_transform(X_transformed['gender'])

# %%
gender_encode.classes_

# %%
exp_encode = LabelEncoder()
X_transformed['relevent_experience']=exp_encode.fit_transform(X_transformed['relevent_experience'])

# %%
exp_encode.classes_

# %%
enrolled_university  = LabelEncoder()
X_transformed['enrolled_university']=enrolled_university .fit_transform(X_transformed['enrolled_university'])

# %%
enrolled_university.classes_

# %%
education_level  = LabelEncoder()
X_transformed['education_level']=education_level .fit_transform(X_transformed['education_level'])

# %%
major_discipline  = LabelEncoder()
X_transformed['major_discipline']=major_discipline.fit_transform(X_transformed['major_discipline'])

# %%
experience  = LabelEncoder()
X_transformed['experience']=experience.fit_transform(X_transformed['experience'])

# %%
company_size   = LabelEncoder()
X_transformed['company_size']=company_size.fit_transform(X_transformed['company_size'])

# %%
company_type   = LabelEncoder()
X_transformed['company_type']=company_type.fit_transform(X_transformed['company_type'])

# %%
last_new_job = LabelEncoder()
X_transformed['last_new_job']=last_new_job.fit_transform(X_transformed['last_new_job'])

# %%
X_transformed.info()

# %%
sns.heatmap(X_transformed.corr())

# %%
X_transformed.drop('company_size',axis=1,inplace=True)

# %%
y.value_counts()

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(max_iter=200, verbose=2)

# %%
X_transformed.columns

# %%
model.fit(X_transformed,y)

# %%
test_data.head()

# %%
#trasforming test data
test_data.drop('enrollee_id', axis=1,inplace=True)
#X_test = test_data.drop('target',axis=1)
#y_test=test_data['target']
X_test=test_data.copy()
X_test = imputer.transform(X_test)
X_test = pd.DataFrame(X_test, columns=test_data.columns, index=test_data.index)
X_test['training_hours']=np.log(X_test['training_hours'].astype(int))
X_test['city_development_index']=X_test['city_development_index'].astype(float)
X_test.drop('city',axis=1,inplace=True)
X_test['gender']=gender_encode.transform(X_test['gender'])
X_test['relevent_experience']=exp_encode.transform(X_test['relevent_experience'])
X_test['enrolled_university']=enrolled_university.transform(X_test['enrolled_university'])
X_test['education_level']=education_level.transform(X_test['education_level'])
X_test['major_discipline']=major_discipline.transform(X_test['major_discipline'])
X_test['experience']=experience.transform(X_test['experience'])
X_test['company_size']=company_size.transform(X_test['company_size'])
X_test['company_type']=company_type.transform(X_test['company_type'])
X_test['last_new_job']=last_new_job.transform(X_test['last_new_job'])
X_test.drop('company_size',axis=1,inplace=True)

# %%
sample = pd.read_csv('../input/hr-analytics-job-change-of-data-scientists/sample_submission.csv')

# %%
X_transformed.head()

# %%
X_test.head()

# %%
pred=model.predict(X_test)

# %%
pred

# %%
pred1= model.predict(X_transformed)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y,pred1))

# %%
sns.heatmap(confusion_matrix(y,pred1))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout

# %%
X_transformed.shape

# %%
model=Sequential()
model.add(Dense(10,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(5,activation='relu'))
model.add(Dense(1,activation='softmax'))

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
callback=EarlyStopping(monitor='val_accuracy', patience=10)

# %%
model.fit(X_transformed,y,verbose=1, epochs=100,callbacks=[callback], validation_split=0.3)

# %%
report = pd.DataFrame(model.history.history)

# %%
report
