# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix 
from sklearn import preprocessing

# %%
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv('../input/diabetes/diabetes.csv')

# %%
df.head(5)

# %%
print(df['Pregnancies'].value_counts())
print('\n')

print('\n')
df['SkinThickness'].value_counts()

# %%
print(df['BloodPressure'].value_counts())

# %%
print(df['BMI'].value_counts())

# %%
df['SkinThickness']=df['SkinThickness'].replace(0,df['SkinThickness'].mean())

# %%
df['BMI']=df['BMI'].replace(0,df['BMI'].mean())

# %%
df['BloodPressure']=df['BloodPressure'].replace(0,df['BloodPressure'].mean())

# %%
df['SkinThickness']=df['SkinThickness'].round(0)
df

# %%
df['BMI'].value_counts()

# %%
sns.pairplot(data=df[:-1],hue = 'Outcome')

# %%
plt.figure(figsize = (12,7))
sns.heatmap(df[:-1].corr(),annot = True)

# %%
df.columns

# %%
X=df[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age']]
y = df['Outcome']

# %%
X.head(5)

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=60)

# %%
sns.catplot(kind='bar',data = df,x = 'Outcome',y = "Pregnancies",hue = "Outcome")

# %%
sns.lineplot(data = df,x = 'Age',y = 'BloodPressure')

# %%
sns.catplot(data=df,x = 'Outcome',y = 'Insulin',kind = 'bar')

# %%
sns.catplot(data=df,x = 'Outcome',y = 'Insulin',kind = 'bar')

# %%
logmodel = LogisticRegression()

# %%
logmodel.fit(X_train,y_train)

# %%
pred = logmodel.predict(X_test)

# %%
print(confusion_matrix(y_test,pred))

# %%
print(classification_report(y_test,pred))
