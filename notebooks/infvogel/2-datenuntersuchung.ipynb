# %% [markdown]
# ## Damit der Code geändert bzw. benutzt werden kann,<br> muss man eingeloggt sein und rechts oben auf Copy+Edit klicken
#
# # Datenuntersuchung
#
# Zu Beginn des **maschinellen Lernens** werden die vorhanden Daten untersucht.
#
# Wir verwenden eine *Pandasdatenbank* abgekürzt als 'pd'. Diese wird mit *import* eingelesen.
# Mehr über [*Pandasdatenbank*](https://www.tutorialspoint.com/python_pandas/python_pandas_introduction.htm

# %%
import pandas as pd

# %% [markdown]
# Die **PD** enthält viele Tabellen mit Datensätzen für verschiedene Themen. Zum Beispiel die [Hauspreise in Melbourne](https://www.kaggle.com/dansbecker/melbourne-housing-snapshot).
#
# Diese befinden sich im Pfad **`../input/melbourne-housing-snapshot/melb_data.csv`**.
#
# Folgender Befehl lädt und zeigt die Daten.

# %%
# Speicherpfad als Variable für einfacheren Zugriff
melbourne_file_path = '../input/melbourne-housing-snapshot/melb_data.csv'
# Daten lesen und speichern in melbourne_data
melbourne_data = pd.read_csv(melbourne_file_path) 
# Ausgabe
melbourne_data.describe()

# %% [markdown]
# # Tabelle interpretieren
# Die Zeile **count** zeigt wie viele Zeilen mit Werten gefüllt sind.
#
# **Aufgabe:** Wann könnten Werte in einem Datensatz fehlen?
#
# **mean** entspricht dem Durchschnitt aller Werte einer Spalte (SQL: AVG).
# **std** entspricht der Standardabweichung aller Werte einer Spalte (Mathe: sigma).
# **min**, **25%**, **50%**, **75%** und **max** teilt die Werte folgermaßen ein:
#
# **min** kleinster vorkommender Wert.
#
# **max** größter vorkommender Wert.
#
# **25%**, **50%**, **75%** entspricht je dem Wert, ab dem mehr als 25% (*untere Quartil*), 50% (*Median*), 75% (*obere Quartil*) der Datensätze kleiner sind.
#
# **Aufgabe:** Bestimme die Werte **mean**, **min**, **25%**, **50%**, **75%** und **max** für die Tabelle auf dem AB!
# Veranschauliche die Tabellenwerte im Diagramm und mean, min, 25%, 50%, 75% und max auf dem AB!
#
# # Fortsetzung
#  mit  **[1. Programmierübung](https://www.kaggle.com/infvogel/3-aufgabe-daten-erforschen)**

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [Learn Discussion forum](https://www.kaggle.com/learn-forum/161285) to chat with other Learners.*
