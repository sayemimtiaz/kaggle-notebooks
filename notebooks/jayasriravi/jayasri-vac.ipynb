# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd
dataset=pd.read_csv('../input/credit-card-customers/BankChurners.csv')
dataset.tail()

# %%
import numpy as np
import pandas as pd
dataset=pd.read_csv('../input/credit-card-customers/BankChurners.csv')
dataset.head()

# %%
print(dataset.shape)

# %%
dataset.info()

# %%
dataset.info

# %%
dataset.iloc[0:6,0:7]

# %%
dataset.iloc[-1]

# %%
dataset.iloc[:]

# %%
columns_to_show = ['Income_Category','Card_Category']
dataset.groupby(['Education_Level'])[columns_to_show].describe(percentiles=[])

# %%
dataset.loc[30:45]

# %%
dataset.describe()

# %%
dataset.describe(include=['object','bool'])

# %%
dataset['Customer_Age'].mean()

# %%
dataset[dataset['Attrition_Flag'].apply(lambda Attrition_Flag:Attrition_Flag[0]=='A')]

# %%
dataset.sort_values(by='Gender', ascending = False).head()

# %%
dataset.loc[dataset['Marital_Status']=='Single']

# %%
dataset['Marital_Status']=='Single'

# %%
dataset['Education_Level'].unique()

# %%
dataset['Education_Level'].nunique()

# %%
Single=dataset.loc[dataset['Marital_Status']=='Single']
Single.sum()

# %%
dataset.loc[dataset['Marital_Status']=='Single']

# %%
dataset.hist(column='Dependent_count')

# %%
Single['Dependent_count'].sum()

# %%
d=[]
d.append(Single['Dependent_count'].sum())

# %%
print(d)

# %%
dataset.hist('Customer_Age')

# %%
columns_to_show = ['Income_Category','Card_Category']
dataset.groupby(['Education_Level'])[columns_to_show].describe(percentiles=[])

# %%
columns_to_show = ['Income_Category','Card_Category']
dataset.groupby(['Education_Level'])[columns_to_show].agg([np.max,np.min])

# %%
columns_to_show = ['Income_Category','Card_Category']
dataset.groupby(['Education_Level'])[columns_to_show].nunique()

# %%
pd.crosstab(dataset['Income_Category'],dataset['Card_Category'])

# %%
pd.crosstab(dataset['Customer_Age'],dataset['Dependent_count']).agg([np.mean,np.max,np.min,np.std])

# %%
pd.crosstab(dataset['Customer_Age'],dataset['Dependent_count'],normalize = True)

# %%
pd.crosstab(dataset['Customer_Age'],dataset['Dependent_count'],normalize ="index")

# %%
pd.crosstab(dataset['Customer_Age'],dataset['Dependent_count'],normalize ='columns')

# %%
pd.crosstab(dataset['Customer_Age'],dataset['Dependent_count'],dropna=False)

# %%
dataset.pivot_table(['Dependent_count','Customer_Age'],['Education_Level'],aggfunc='mean')

# %%
dataset.pivot_table(['Dependent_count','Customer_Age'],['Education_Level'],aggfunc=np.sum)

# %%
Data1=dataset.pivot_table(['Education_Level','Customer_Age'],['Marital_Status'],aggfunc=np.sum)

# %%
print(Data1)

# %%
data=Data1['Customer_Age']
df=pd.DataFrame(data=data)
bar=df.plot.bar()

# %%
data=Data1['Customer_Age']
df=pd.DataFrame(data=data)
area=df.plot.pie(subplots=True,figsize=(5,3))

# %%
data=Data1['Customer_Age']
df=pd.DataFrame(data=data)
density=df.plot.density()

# %%
data=Data1['Customer_Age']
df=pd.DataFrame(data=data)
bar=df.plot.barh()

# %%
data=Data1['Customer_Age']
df=pd.DataFrame(data=data)
line=df.plot.line()

# %%
data=Data1['Customer_Age']
df=pd.DataFrame(data=data)
area=df.plot.area()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data=pd.read_csv('../input/credit-card-customers/BankChurners.csv')

# %%
data.head()

# %%
data.isnull().sum()
