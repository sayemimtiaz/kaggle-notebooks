# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px
import plotly.graph_objs as go

# %%
df = pd.read_csv('../input/breast-cancer-wisconsin-data/data.csv')

# %%
df.head()

# %%
df.columns

# %%
df.shape

# %%
df.describe()

# %%
df.describe(include=['O'])

# %%
df.info()

# %%
df= df.drop(['Unnamed: 32','id'],axis=1)

# %%
df['diagnosis'].value_counts()

# %%
sns.countplot(df.diagnosis)
plt.title("diagnosis",color = 'black',fontsize=15)

# %%
sns.scatterplot(x= 'area_mean', y= 'smoothness_mean', hue= 'diagnosis', data=df)

# %%
sns.scatterplot(x= 'smoothness_mean', y= 'texture_mean', hue= 'diagnosis', data=df)

# %%
sns.scatterplot(x= 'texture_mean', y= 'symmetry_se', hue= 'diagnosis', data=df)

# %%
sns.scatterplot(x= 'fractal_dimension_worst', y= 'texture_mean', hue= 'diagnosis', data=df)

# %%
sns.scatterplot(x= 'texture_mean', y= 'symmetry_mean', hue= 'diagnosis', data=df)

# %%
fig = px.scatter(df, x='symmetry_mean' , y='diagnosis')
fig.show()

# %%
fig = px.scatter(df, x='concavity_se' , y='diagnosis')
fig.show()

# %%
fig = px.scatter(df, x='concavity_se' , y='diagnosis')
fig.show()

# %%
fig = px.scatter(df, x='perimeter_mean' , y='diagnosis')
fig.show()

# %%
fig = px.scatter(df, x='concavity_worst' , y='diagnosis')
fig.show()

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['radius_mean'], color='r')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['texture_mean'], color='b')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['perimeter_mean'], color='g')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['smoothness_mean'])
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['smoothness_worst'])
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['concavity_worst'])
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['symmetry_worst'])
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['fractal_dimension_worst'])
plt.show()

# %%
#correlation map
df.corr
f,ax = plt.subplots(figsize=(25,15))
sns.heatmap(df.corr(), annot =True, linewidth =".5", fmt =".2f", cmap='viridis')
plt.show()

# %%
X = df.drop(columns=["diagnosis"])
y = df["diagnosis"]

# %%
df['diagnosis'] = pd.get_dummies(y)

# %%
df.head()

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=44, shuffle =True)

# %%
df.head()

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier


#loading models for Voting Classifier
DTModel_ = DecisionTreeClassifier(criterion = 'entropy',max_depth=3,random_state = 33)
RFModel_ = RandomForestClassifier(n_estimators=100, criterion='gini',max_depth=1, random_state=33)
KNNModel_ = KNeighborsClassifier(n_neighbors= 4 , weights ='uniform', algorithm='auto')

#loading Voting Classifier
VotingClassifierModel = VotingClassifier(estimators=[('DTModel',DTModel_),('RFModel',RFModel_),('KNNModel',KNNModel_)], voting='hard')
VotingClassifierModel.fit(X_train, y_train)

#Calculating Details
print('VotingClassifierModel Train Score is : ' , VotingClassifierModel.score(X_train, y_train))
print('VotingClassifierModel Test Score is : ' , VotingClassifierModel.score(X_test, y_test))
#print('----------------------------------------------------')

#Calculating Prediction
y_pred = VotingClassifierModel.predict(X_test)
print('Predicted Value for VotingClassifierModel is : ' , y_pred[:10])

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

#Calculating Confusion Matrix
CM = confusion_matrix(y_test, y_pred)
print('Confusion Matrix is : \n', CM)

# drawing confusion matrix
sns.heatmap(CM, center = True,cmap='magma')
plt.show()
