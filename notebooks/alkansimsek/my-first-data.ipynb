# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # visualization tool
import matplotlib.pyplot as plt

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
data_fm=pd.read_csv('/kaggle/input/heart-disease-uci/heart.csv')#veri setini data_fm'e tanımladık.

# %%
data_fm.info()#Data_fm hakkında genel bilgilere ulaştık.

# %%
Data_fm içinde 14 sütun (başlık) bulunmaktadır.bu başlıkların 13 tanesi int64 veri tipinde diğer 1 tanesi ise float64 veri tipindedir.
Veri setimiz hafızada toplam 3.3KB yer kaplamaktadır.

# %%
data_fr.head(10)#Data_fm içindeki ilk 10 veriyi (sütunu) görürüz.

# %%
f,ax=plt.subplots(figsize=(14, 14))#data_fm için oluşturulacak ısı haritasının büyüklüğünü ayarladık.
sns.heatmap(data_fm.corr(),annot=True,linewidths=.9,fmt='.3g',ax=ax,linecolor='y')#data_fm ısı haritasını biçimlendirerek daha anlaşılır hale getirdik.

# %% [markdown]
# Bu ısı haritasında özellikler belli başlıkların birbirini nasıl etkilediğini gözlemledik.Bu etkileşimde birbirini en çok etkileyenler '1' numaraya en çok yakın olanlar hiç bir etkileşimi bulunmayanlar ise '-1' numaraya en yakın olanlardır.

# %%
#scatter plot
# x=attack , y=defense
data_fm.plot(kind='scatter',x='age',y='trestbps',alpha=0.3,color='r')
plt.xlabel('age')
plt.ylabel('trestbps')
plt.legend(loc='upper center')
plt.title('age trestbps scatter plot')

# %%
Data_fm içindeki age ve trestbps verilerini scatter plot ile karşılaştırdık.

# %%
data_fm.age.plot(kind='hist',bins=30,figsize=(13, 13))#data_fm içindeki age sütunundaki insan sayısı dağılımını histogram ile öğrendik.
data_fm.trestbps.plot(kind='hist',bins=30,figsize=(13, 13))#data_fm içindeki trestbps sütunundaki insan sayısı dağılımını histogram ile öğrendik.

# %%
i=0
y=0
while i!=303:
    if(data_fm['age'][i]<65):
        y=y+1
        i=i+1
    else:
        i=i+1
print(y)

# %%
Data_fm içindeki age sütununda istediğimiz yaş aralığında kaç tane insan oldugunu buluruz.
