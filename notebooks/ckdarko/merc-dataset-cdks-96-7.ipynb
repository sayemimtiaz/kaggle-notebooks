# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Importing the dataset

# %%
dataset = pd.read_csv('/kaggle/input/used-car-dataset-ford-and-mercedes/merc.csv')
dataset.head(10)

# %%
dataset.info()

# %%
dataset.isnull().sum()

# %%
dataset.model.unique()

# %%
dataset.fuelType.unique()

# %%
dataset.transmission.unique()

# %% [markdown]
# ### Variables

# %%
y = dataset.price.values
X = dataset.drop('price', axis=1).values

# %%
print(X)
print('------>')
print(y)

# %%
X[0]

# %% [markdown]
# ### Categorical data

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X[:, 0] = le.fit_transform(X[:, 0]) #model

# %%
X[:, 2] = le.fit_transform(X[:, 2]) #transmission

# %%
X[:, 4] = le.fit_transform(X[:, 4]) #fuelType

# %%
X[0]

# %% [markdown]
# ### Splitting dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
X_train

# %%
X_test

# %%
y_train

# %%
y_test

# %%
X_train[0], y_train[0]#for prediction

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ### Train Model + Cross Validation

# %%
from sklearn.tree import DecisionTreeRegressor
reg = DecisionTreeRegressor(random_state = 1)
reg.fit(X_train, y_train)
y_pred = reg.predict(X_test)


from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(reg, X_train, y_train, cv = 10)
print('Accuracy: {:.2f}%'.format(accuracies.mean()*100))
print('Std: {:.2f}%'.format(accuracies.std()*100))

from sklearn.metrics import r2_score
r2_score(y_test, y_pred)*100

# %%
reg.predict(sc.transform([[0, 2018, 0, 7047, 3, 145, 53.3, 1.3]]))

# %%
from sklearn.ensemble import RandomForestRegressor
reg = RandomForestRegressor(n_estimators=10, random_state=42)
reg.fit(X_train, y_train)
y_pred = reg.predict(X_test)


from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(reg, X_train, y_train, cv = 10)
print('Accuracy: {:.2f}%'.format(accuracies.mean()*100))
print('Std: {:.2f}%'.format(accuracies.std()*100))

from sklearn.metrics import r2_score
r2_score(y_test, y_pred)*100

# %%
reg.predict(sc.transform([[0, 2018, 0, 7047, 3, 145, 53.3, 1.3]]))

# %%
from xgboost import XGBRegressor
reg = XGBRegressor()
reg.fit(X_train, y_train)
y_pred = reg.predict(X_test)


from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(reg, X_train, y_train, cv = 10)
print('Accuracy: {:.2f}%'.format(accuracies.mean()*100))
print('Std: {:.2f}%'.format(accuracies.std()*100))

from sklearn.metrics import r2_score
r2_score(y_test, y_pred)*100

# %%
reg.predict(sc.transform([[0, 2018, 0, 7047, 3, 145, 53.3, 1.3]]))

# %%
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

# %% [markdown]
# # TRYING ANN

# %% [markdown]
# ### Building an ANN

# %%
import tensorflow as tf

ann = tf.keras.models.Sequential()

# %%
ann.add(tf.keras.layers.Dense(units = 6, activation = 'relu'))

# %%
ann.add(tf.keras.layers.Dense(units = 6, activation = 'relu'))

# %%
ann.add(tf.keras.layers.Dense(units = 1))

# %% [markdown]
# #### Compile ANN

# %%
ann.compile(optimizer='adam', loss='mean_squared_error')

# %%
#training the model
ann.fit(X_train, y_train, batch_size=50, epochs=300)

# %%
y_pred = ann.predict(X_test)
y_pred

# %%
from sklearn.metrics import r2_score
accuracy = r2_score(y_test, y_pred)
accuracy*100

# %%
ann.predict(sc.transform([[0, 2018, 0, 7047, 3, 145, 53.3, 1.3]]))

# %%
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
