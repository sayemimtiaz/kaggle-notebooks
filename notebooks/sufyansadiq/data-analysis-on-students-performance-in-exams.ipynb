# %% [markdown]
# Data Description: Marks secured by the students in high school.Students from the United States.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
sd="../input/students-performance-in-exams/StudentsPerformance.csv"
sd=pd.read_csv(sd)

# %%
sd.head(5)

# %%
sd.shape

# %%
sd.info()

# %%
sd.describe()

# %% [markdown]
# Renaming columns for convenience

# %%
sd.rename(columns ={"math score":'math_score'}, inplace=True)

# %%
sd.rename(columns={"reading score":"reading_score"}, inplace=True)

# %%
sd.rename(columns={"writing score":"writing_score"}, inplace=True)

# %%
sd.loc[sd.gender == "female"]

# %%
sd.loc[sd.gender == "female"].describe()

# %%
sd.loc[sd.gender == "male"]

# %%
sd.loc[sd.gender == "male"].describe()

# %% [markdown]
# checking if there are any missing values in datset

# %%
sd.isnull().sum()

# %% [markdown]
# 1. According to above stats males have good score in mathematics(on average) while females have good score in reading and writting (on average)

# %% [markdown]
# female students with 90+ score in all subjects

# %%
sd.loc[(sd.gender == "female") & (sd.math_score >= 90) & (sd.reading_score >= 90) & (sd.writing_score >= 90)]

# %% [markdown]
# male students with 90+ score in all subjects

# %%
sd.loc[(sd.gender == "male") & (sd.math_score >=90) & (sd.reading_score >=90) & (sd.writing_score >=90)]

# %%
sd.math_score.unique()

# %%
sd.reading_score.unique()

# %%
sd.writing_score.unique()

# %%
sd.groupby("math_score").math_score.count()

# %%
sd.groupby("reading_score").reading_score.count()

# %%
sd.groupby("writing_score").writing_score.count()

# %% [markdown]
# **visualising our Data**

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# Average marks of all students in each subject

# %%
#plot size
plt.figure(figsize=(6,6))
#plot title
plt.title("Average marks of all students in each subject")
sns.barplot(data=sd,palette=["red", "orange","purple"])

# %% [markdown]
# scores in mathematics based on gender

# %%
sns.scatterplot(y=sd["math_score"], x=sd.index, hue=sd["gender"],palette=["red", "black"])

# %% [markdown]
# scores in reading based on gender

# %%
sns.scatterplot(y=sd["reading_score"], x=sd.index, hue=sd["gender"],palette=["red", "black"])

# %% [markdown]
# scores in writing based on gender

# %%
sns.scatterplot(y=sd["writing_score"], x=sd.index, hue=sd["gender"], palette=["red", "black"])

# %% [markdown]
# ______________________________________________________________________________________________________________________________________

# %%
sns.scatterplot(y=sd["math_score"], x=sd.index, hue=sd["lunch"],palette=["orange", "black"])

# %%
sns.scatterplot(y=sd["reading_score"] ,x=sd.index ,hue=sd["lunch"],palette=["orange", "black"])

# %%
sns.scatterplot(y=sd["writing_score"], x=sd.index, hue=sd["lunch"],palette=["orange", "black"])

# %% [markdown]
# ______________________________________________________________________________________________________________________________________

# %% [markdown]
# scores in mathematics based on test prepartion course

# %%
sns.scatterplot(y=sd["math_score"], x=sd.index, hue=sd["test preparation course"],palette=["purple", "black"])

# %% [markdown]
# scores in reading based on test prepartion course

# %%
sns.scatterplot(y=sd["reading_score"], x=sd.index, hue=sd["test preparation course"],palette=["purple", "black"])

# %% [markdown]
# scores in mathematics based on test prepartion course

# %%
sns.scatterplot(y=sd["writing_score"], x=sd.index, hue=sd["test preparation course"],palette=["purple", "black"])

# %% [markdown]
# ______________________________________________________________________________________________________________________________________

# %% [markdown]
#  Scores in mathematics based on parental level of education

# %%
sns.scatterplot(y=sd["math_score"], x=sd.index, hue=sd["parental level of education"])

# %% [markdown]
# Scores in reading based on parental level of education

# %%
sns.scatterplot(y=sd["reading_score"], x=sd.index, hue=sd["parental level of education"])

# %% [markdown]
# Scores in writing based on parental level of education

# %%
sns.scatterplot(y=sd["writing_score"], x=sd.index, hue=sd["parental level of education"])
