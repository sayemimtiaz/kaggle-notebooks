# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
games = pd.read_csv('/kaggle/input/chess/games.csv')

# %%
games.shape

# %%
games.head(3)

# %%
games.nunique()

# %%
games.info()

# %%
games['opening_eco'].value_counts().head(10)

# %%
games['winner'].value_counts().plot(kind='bar', title='Amount of wins', figsize=(8,6))

# %%
games['victory_status'].value_counts().plot(kind='bar', title='Amount of victory status', figsize=(8,6))

# %% [markdown]
# The 10 most usable opening eco

# %%
games['opening_eco'].value_counts().head(10)

# %%
win_opening_eco = games.groupby(['opening_eco', 'winner']).agg({'winner':['count']})
win_opening_eco.columns = win_opening_eco.columns.map('_'.join)
win_opening_eco.reset_index().sort_values(by='winner_count', ascending=False).head(10)
