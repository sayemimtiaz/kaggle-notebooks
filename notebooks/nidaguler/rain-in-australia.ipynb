# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("../input/weather-dataset-rattle-package/weatherAUS.csv")

# %%
df.head()

# %%
df.tail()

# %%
df.columns

# %%
df.isna().sum()

# %%
df = df.dropna()

# %%
df.info()

# %% [markdown]
# we can see that object values:
# 1. RainToday
# 2. RainTomorrow
# 3. WindDir9am
# 4. WindDir3pm
# 5. WindGustDir

# %%
df[["RainToday","RainTomorrow","WindDir9am","WindDir3pm","WindGustDir"]].head()

# %%
df.RainToday.unique()

# %%
df.RainToday.value_counts()

# %%
sns.barplot(x=df["RainToday"].value_counts().index,y=df["RainToday"].value_counts().values)
plt.title("RainToday")
plt.ylabel("Rates")
plt.legend(loc=0)
plt.show()

# %%
df.RainTomorrow.unique()

# %%
df.RainTomorrow.value_counts()

# %%
sns.barplot(x=df['RainTomorrow'].value_counts().index,y=df['RainTomorrow'].value_counts().values)
plt.title('RainTomorrow')
plt.ylabel('Rates')
plt.legend(loc=0)
plt.show()

# %%
df.WindDir9am.unique()

# %%
sns.barplot(x=df['WindDir9am'].value_counts().index,y=df['WindDir9am'].value_counts().values)
plt.title('WindDir9am')
plt.ylabel('Rates')
plt.legend(loc=0)
plt.show()

# %%
df.WindDir9am.value_counts()

# %%
df.WindDir3pm.unique()

# %%
sns.barplot(x=df['WindDir3pm'].value_counts().index,y=df['WindDir3pm'].value_counts().values)
plt.title('WindDir3pm')
plt.ylabel('Rates')
plt.legend(loc=0)
plt.show()

# %%
df.WindDir3pm.value_counts()

# %%
df.WindGustDir.unique()

# %%
df.WindGustDir.value_counts()

# %%
sns.barplot(x=df['WindGustDir'].value_counts().index,y=df['WindGustDir'].value_counts().values)
plt.title('WindGustDir')
plt.ylabel('Rates')
plt.legend(loc=0)
plt.show()

# %%
df.describe().T

# %%
df.corr()

# %%
for i,col in enumerate(df.columns):
    print(i+1," column is",col )

# %%
plt.figure(figsize=(15,7))
sns.lmplot(x='WindSpeed9am',y='WindSpeed3pm',data=df)
plt.xlabel('WindSpeed9am')
plt.ylabel('WindSpeed3pm')
plt.title('WindSpeed9am vs WindSpeed3pm')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.lmplot(x='Humidity9am',y='Humidity3pm',data=df)
plt.xlabel('Humidity9am')
plt.ylabel('Humidity3pm')
plt.title('Humidity9am vs Humidity3pm')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.lmplot(x='Pressure9am',y='Pressure3pm',data=df)
plt.xlabel('Pressure9am')
plt.ylabel('Pressure3pm')
plt.title('Pressure9am vs Pressure3pm')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.lmplot(x='Cloud9am',y='Cloud3pm',data=df)
plt.xlabel('Cloud9am')
plt.ylabel('Cloud3pm')
plt.title('Cloud9am vs Cloud3pm')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.lmplot(x='Temp9am',y='Temp3pm',data=df)
plt.xlabel('Temp9am')
plt.ylabel('Temp3pm')
plt.title('Temp9am vs Temp3pm')
plt.show()
