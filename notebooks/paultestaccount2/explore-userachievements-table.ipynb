# %%
import pandas as pd
import numpy as np
import os
UserAchievements = pd.read_csv('/kaggle/input/meta-kaggle/UserAchievements.csv')

# %%
value_counts = UserAchievements.value_counts('TierAchievementDate', ascending=True)
value_counts

# %%
UserAchievements_nov_17 = UserAchievements[UserAchievements['TierAchievementDate'] == '11/01/2017']
print('November 1, 2017: ',len(UserAchievements_nov_17),'achievements')
UserAchievements_nov_17.head()

# %%
UserAchievements_nov_18 = UserAchievements[UserAchievements['TierAchievementDate'] == '11/01/2018']
print('November 1, 2018: ',len(UserAchievements_nov_18),'achievements')
UserAchievements_nov_18.head()

# %%
UserAchievements_nov_19 = UserAchievements[UserAchievements['TierAchievementDate'] == '11/01/2019']
print('November 1, 2019: ',len(UserAchievements_nov_19),'achievements')
UserAchievements_nov_19.head()

# %%
UserAchievements_nov_20 = UserAchievements[UserAchievements['TierAchievementDate'] == '11/01/2020']
print('November 1, 2020:',len(UserAchievements_nov_20),'achievements')
UserAchievements_nov_20.head()
