# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
train_data_df=pd.read_csv("../input/resized-2015-2019-blindness-detection-images/labels/trainLabels15.csv")

# %%
grp=train_data_df.groupby("level")

# %%
grp_3=grp.get_group(3)
Names3=grp_3['image']+".jpg"
Names3
type(Names3)
Names3.to_list()
len(Names3)

# %%
Names3_str=list(map(str,Names3))

# %%
df=pd.DataFrame(Names3_str,columns=['id_code'])

# %%
df['diagnosis']=3

# %%
df

# %%
df.to_csv('class3_train.csv', index=False)

# %%
from IPython.display import FileLink
FileLink(r'class3_train.csv')

# %%
import os

# %%
os.chdir(r'../input/resized-2015-2019-blindness-detection-images/resized train 15')

# %%
from PIL import Image
from tqdm import tqdm

# %%
for img_name in tqdm(Names3_str):
    img = Image.open(img_name)
    os.chdir('/kaggle/working/')
    img = img.save(img_name)
    os.chdir('../input/resized-2015-2019-blindness-detection-images/resized train 15')

# %%
os.chdir('/kaggle/working/')

# %%
os.mkdir('./preprocess')

# %%
os.mkdir('./preprocess/3')

# %%
import shutil

# %%
shutil.make_archive('wnld', 'zip', './preprocess')

# %%
len(os.listdir('./preprocess/3'))

# %%
from zipfile import ZipFile
import os

zipObj = ZipFile('Class3.zip', 'w')

for filename in os.listdir("/kaggle/working"):
    if filename.endswith(".jpg"):
        zipObj.write(filename)
zipObj.close()

# %%
FileLink(r'Class3.zip')
