# %% [markdown]
# # What is an EDA?

# %% [markdown]
# Exploritory Data Analysis (**EDA**) is the process of analyzing an existing dataset to find trends to work with later.
# * In this EDA, We will be working with the "Pokemon with stats" data set.
# * This shows the Pokemon's name, number, generation, type 1 , type 2, its stats, and if it is  legendary or not.
# * The data set only includes pokemon up to generation 6.

# %% [markdown]
# # Data Upload

# %%
#This is a practice with EDA Data Visualization and Pandas.
#A lot of this code is referencing :https://www.kaggle.com/yassinealouini/pokemon-eda#%C2%A0Load-the-data
#I am  a beginner with kaggle and am still learning. Some feedback is well appreciated

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling as pdp

#upload the data
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename));
Pokedex=pd.read_csv('/kaggle/input/pokemon/Pokemon.csv');

# %% [markdown]
# # Cleaning and Exploring
#
# Now that the data is input, lets take look at the data.

# %%
sns.boxplot(data=Pokedex);

# %%
Pokedex.head()

# %% [markdown]
# There are a few columns not required for this analysis and can be dropped:
# * Total
# * #
# * Legendary
# * Generation

# %%
pkmn = Pokedex.drop(['Total', '#',"Legendary","Generation"],1)

# %%
sns.boxplot(data=pkmn);

# %% [markdown]
# # Profiling
# Let's look at the profile of the dataset to see everything in more detail.

# %%
profile=pdp.ProfileReport(pkmn)

# %%
profile.to_notebook_iframe();

# %% [markdown]
# Some important information we can take away from this.
# * There are 386 missing values In the Type 2 column.
# * This means that there are 386 poekmon with only 1 type and no secondary type. This can be interesting to look at in the future
# * For the interations, obviously there are high correlations in the statistics that are compared to themselves.
# * More important information lies in the Pearson's r test. There are only positive correlations between all of the stats except for the interaction between **defence and speed**.

# %% [markdown]
# # Statistics

# %% [markdown]
# Let's make a "stats" variable. The melt function will combine the stat related columns.

# %%
pkmn_melt = pd.melt(pkmn, id_vars=["Name", "Type 1", "Type 2"], var_name="Stat")

pkmn_melt.head()

# %% [markdown]
# Let's visualize the stats now

# %%
sns.swarmplot(x="Stat", y="value", data=pkmn_melt, hue="Type 1");

# %% [markdown]
# In order to clean up visualization, let's:
#
# * change the figure size
#
# * change the y
#
# * Organize the points by type and make the points larger
#
# * Move the legend out of the way

# %%
plt.figure(figsize=(12,10))
plt.ylim(0, 275)
sns.swarmplot(x="Stat", y="value", data=pkmn_melt, hue="Type 1", dodge=True, size=7)
plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.);
