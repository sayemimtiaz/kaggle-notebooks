# %% [markdown]
# # Zusammenhang zwischen Covid-19 und dem Wetter. Beeinflusst das Wetter die Covid-19-Ausbreitung ? Haben Temperatur / Niederschlags(mengen) Einfluss auf die Infektionen?.
#
# Hypothese: Höhere Niederschlagsmengen beeinflussen die Ausbreitung des Virus. Die Verbreitung durch die Luft wird durch den Niederschlag erschwert, außerdem halten sich bei schlechtem Wetter weniger Menschen im Freien auf. Das Infektionsrisiko wird vermindert. Außerdem beeinflusst die Durchschnittstemperatur eines Landes die Ausbreitung?.
#
# Können wir die Wetterbedingungen und die Verbreitung des Corona-Virus durch Daten korrelieren? Können wir diese Hypothese bestätigen, dass die Ausbreitung des Corona-Virus durch warmes Wetter verlangsamt wird?
#
# Wir versuchen diese Frage zu beantworten.
#
# # Hinführung zum Thema
#
# COVID-19 ist eine neue und unbekannte Virus-Krankheit. Alle Influenzaviren verbreiten sich rasend schnell in der Gesellschaft [1]. Unsere Forschung befasst sich mit der Ananlyse von Daten und Erstellung von Modellen, um unsere Arbeitshypothese zu beantworten.
#
# Dass die Ausbreitung von herkömmlichen Influenzaviren mit der Temperatur und der relativen Luftfeuchtigkeit zusammenhängt, ist bewiesen [2]. Der Einfluss der Temperatur und der relativen Luftfeuchtigkeit auf Covid-19 wird aktuell noch untersucht [3].
#
# Coronaviren gehören zur "Familie" der Viren, die bei Tieren oder Menschen Krankheiten verursachen können. Es ist bekannt, dass beim Menschen mehrere Coronaviren Infektionen der Atemwege verursachen, die von Erkältungen bis zu schwereren Erkrankungen wie dem Middle East Respiratory Syndrome (MERS) und dem Severe Acute Respiratory Syndrome (SARS) reichen. Das zuletzt entdeckte Coronavirus verursacht die Coronavirus-Krankheit COVID-19 [4]. Das Virus wird mit Sars-CoV-2 bezeichnet, die dadurch ausgelöste Krankheit wird als Covid-19 bezeichnet [5].
#
# # Übertragungswege
#
# ### Infektion durch Tröpfchen
#
# Nach aktuellen Studien ist die Tröpfcheninfektion der Hauptübertragungsweg von Sars-Cov-2. Diese Tröpfchen entstehen beispielsweise beim Niesen, oder beim Husten und werden von anderen Personen über die Schleimhäute, Nase oder den Mund aufgenommen [6].
#
# ### Aerosole
#
# Aerosole sind Tröpfchenkerne, die kleiner als 5 Mikrometer sind. Bei mehreren Studien wurde aufgezeigt, dass sich in der Ausatmeluft, oder in Zimmern von Betroffenen Sars-Cov-2-Viren gibt[7-9].Durch das Tragen von chirugischen Masken (FFP3) kann eine Ausbreitung von Sars-Cov-2 haltigen Aerosolen verhindert werden[10]. Durch lautes Sprechen können ebenfalls Aerosole entstehen, die das Virus übertragen können.[11].
#
# ### Übertragung durch Kontakt
#
# Die Übertragung des Virus über kontaminierte Oberflächen ist nicht auszuschließen, vorallem nicht in unmittelbarer Nähe von bereits infizierten Personen. Sars-Cov-2 Viren können in der Umwelt und auf Oberfllächen nachgewisen werden[12].Auch im Stuhl von Covid-19 Infizierten kann das Virus postitiv nachgewisen werden[13].
#
# ### Übertragung während der Schwangerschaft
#
# Zum aktuellem Zeitpunkt kann eine Übertragung des Erregers von einer Infizierten Mutter auf das ungeborene Kind nicht ausgeschlossen werden[14]. Jedoch sind bei den aller meisten Fällen die Kinder bei der Geburt negativ auf den Erreger und zeigen keinerlei Krankheitsanzeichen[15]. Bei einem postivien Fall findet die Übertragung über Tröpfcheninfektionen statt[16].
#
# ### Gesundheitssektor
#
# Der Gesundheitssektor besitzt ein hohes Infektionsrisiko, da es hier viele Übertragungsmöglichkeiten gibt. Vorallem in disem Sektor müssen die Maßnahmen zum Eigenschutz sichergestellt werden. Das höchste Risiko sind Vorgänge bei denen Aerosole ausgestoßen werden, wie z.B. zahnärztliche Untersuchungen, weil hier viel Speichel ausgestoßen wird. Oder auch Intubationen im Krankenhaus, weil auch hier viel im Mund und Rachenbereich gearbeitet wird. Die arbeitenden Personen schützen sich mit spezillen Atemschutzmasken, um eine Gefahr, mit der Ansteckung so gering wie möglich zu halten [17].
#
#
# ## Quellen
#
# [1] Wang M. et al. Temperature significant change COVID-19 Transmission in 429 cities //medRxiv. – 2020.
# [2] Lowen AC, Mubareka S, Steel J, Palese P (2007) Influenza virus transmission is dependent on relative humidity and temperature. PLoS Pathog 3(10): e151. doi:10. 1371/journal.ppat.0030151
# [3] Bu J. et al. Analysis of meteorological conditions and prediction of epidemic trend of 2019-nCoV infection in 2020 //medRxiv. – 2020.
# [4] WHO:https://www.who.int/emergencies/diseases/novel-coronavirus-2019/question-and-answers-hub/q-a-detail/q-a-coronaviruses
# [5] https://www.rnd.de/gesundheit/was-ist-das-coronavirus-unterschied-zwischen-covid-19-und-sars-cov-2-LCF3ECTAPFB3PJJAIWZBHDKCPA.html
# [6] CDC. How COVID-19 Spreads: Centers for Disease Control and Prevention (CDC); 2020 [updated February 17, 2020. Available from: https://www.cdc.gov/coronavirus/2019-ncov/about/transmission.html.
# [7] Chia PY, Coleman KK, Tan YK, Ong SWX, Gum M, Lau SK, et al. Detection of Air and Surface Contamination by Severe Acute Respiratory Syndrome Coronavirus 2 (SARS-CoV-2) in Hospital Rooms of Infected Patients. medRxiv. 2020.
# [8] Santarpia JL, Rivera DN, Herrera V, Morwitzer MJ, Creager H, Santarpia GW, et al. Transmission Potential of SARS-CoV-2 in Viral Shedding Observed at the University of Nebraska Medical Center. medRxiv. 2020.
# [9] Liu Y, Ning Z, Chen Y, Guo M, Liu Y, Gali NK, et al. Aerodynamic analysis of SARS-CoV-2 in two Wuhan hospitals. Nature. 2020:1-6.
# [10] Leung NH, Chu DK, Shiu EY, Chan K-H, McDevitt JJ, Hau BJ, et al. Respiratory virus shedding in exhaled breath and efficacy of face masks. Nature medicine. 2020:1-5. [11] Asadi S, Wexler AS, Cappa CD, Barreda S, Bouvier NM, Ristenpart WD. Aerosol emission and superemission during human speech increase with voice loudness. Sci Rep. 2019;9(1):2348.
# [12] European Centre for Disease Prevention and Control (ECDC). Factsheet for health professionals on Coronaviruses European Centre for Disease Prevention and Control; 2020 [Available from: https://www.ecdc.europa.eu/en/factsheet-health-professionals-coronaviruses.
# [13] Xiao F, Tang M, Zheng X, Li C, He J, Hong Z, et al. Evidence for gastrointestinal infection of SARS-CoV-2. MedRxiv. 2020.
# [14] Dong L, Tian J, He S, Zhu C, Wang J, Liu C, et al. Possible Vertical Transmission of SARS-CoV-2 From an Infected Mother to Her Newborn. Jama. 2020.
# [15] Zeng H, Xu C, Fan J, Tang Y, Deng Q, Zhang W, et al. Antibodies in Infants Born to Mothers With COVID-19 Pneumonia. Jama. 2020.
# [16] Zeng L, Xia S, Yuan W, Yan K, Xiao F, Shao J, et al. Neonatal Early-Onset Infection With SARS-CoV-2 in 33 Neonates Born to Mothers With COVID-19 in Wuhan, China. JAMA pediatrics. 2020.
# [17] https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Steckbrief.html
#
# In diesem Notebook zeigen wir, wie Wetterdaten in Bezug auf die Datenananalyse und die Vorhersage der Ausbreitung von Covid-19 verwendet werden können.
#
# Die Wetterdaten stammen von: https://www.wunderground.com/

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import geopandas as gpd
import numpy as np
from pathlib import Path
import plotly.offline as py
import plotly.express as px
import cufflinks as cf
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error as MAE
from sklearn.cluster import DBSCAN

# %% [markdown]
# # USA
# Die Stadt New York City steht weltweit im Fokus, weil es hier die meisten Infizierten in den USA momentan gibt.

# %%
#Einlesen der Corona- und Wetterdaten
USA = pd.read_csv('/kaggle/input/covid19-in-usa/us_states_covid19_daily.csv')
WetterNY = pd.read_csv('/kaggle/input/wetterusa/NewYork_all2.csv',sep = ";")
WetterLA = pd.read_csv('/kaggle/input/wetterusa/LosAngeles.csv',sep = ";")

# %%
# erste Zeilen der Coronadaten der USA anzeigen lassen
USA.head()

# %%
# Info über Daten
USA.info()

# %%
# erste Zeilen Wetterdaten New York anzeigen lassen
WetterNY.head()

# %%
# Info über Daten
WetterNY.info()

# %%
# erste Zeilen Wetterdaten New York anzeigen lassen
WetterLA.head()

# %%
#Spalte von Date in date umbenennen, damit matching funktioniert
#Wurde in Preprocessing bereits geändert

#WetterNY.rename(columns={"date": "Date"})
#WetterNY.head()

# %% [markdown]
# # Aufsplittung der Daten in die verschiedenen Bundesstaaten der USA

# %%
# einzelne Werte des Dataframes USA, Spalte State ausgeben 
USA['state'].unique()

# %% [markdown]
# NY steht für den Bundesstaat New York

# %%
#Filtern auf Zeilen mit State New York, erste Zeilen ausgeben
NYC = USA[USA.state=='NY']
NYC.head()

# %%
#Info zu neuem DF
NYC.info()

# %%
#New York nur die positiven Fälle

#NYC = NYC[NYC['positive']>0]
#NYC

# %%
#New York Coronadaten und Wetterdaten in neuem Dataframe zusammenführen an Parameter date, erste Zeilen ausgeben

#coronawetterny = pd.merge(NYC, WetterNY, how='right', on='date')
coronawetterny = pd.merge(WetterNY, NYC, how='inner', on='date')
coronawetterny.head()

# %%
#date als Index setzen

coronawetterny.set_index('date')

# %%
# nicht benötigte Spalten löschen

coronawetterny2 = coronawetterny.copy()
coronawetterny2=coronawetterny2.drop(columns=['pending','hospitalizedCurrently', 'negative', 'hospitalizedCumulative', 'inIcuCurrently','inIcuCumulative', 'onVentilatorCurrently', 'onVentilatorCumulative', 'lastUpdateEt', 'hash', 'recovered', 'dataQualityGrade', 'dateChecked', 'death', 'hospitalized', 'totalTestResults', 'total', 'posNeg', 'fips', 'deathIncrease', 'hospitalizedIncrease', 'negativeIncrease', 'totalTestResultsIncrease'])

# %%
#Coronadaten sind absteigend soritert, Wetterdaten sind aufsteigend sortiert
#nach Datum sortieren
#da in merge zuerst das Wetter und danach NYC genannt wird, ist DF bereits in richtiger Reihenfolge

#sortedcoronawetterny = coronawetterny2.sort_values(by='date')
#sortedcoronawetterny.head()

# %%
#info zu Datentypen
coronawetterny2.info()

# %%
#date in string umwandeln
coronawetterny2['date'] = coronawetterny2['date'].astype(str)

# %%
# date "fest" als index setzen
coronawetterny2.set_index('date', drop=True,inplace=True)
coronawetterny2.head()

# %%
# graphische Darstellung Anzahl Neuerkrankungen

coronawetterny2['positiveIncrease'].plot()
#coronawetterny2['Avg Temperature in C'].plot()
plt.xlabel('Anzahl Neuerkrankungen')

# %%
#graphische Darstellung Temperatur
coronawetterny2['Avg Temperature in C'].plot(kind='line',x='date',y='Avg Temperature in C')

# %%
#Korrelationsmatrix des Dataframes

coronawetterny2.corr(method ='kendall')

#korrelation zwischen -1 und 1
#  1 -> korreliert
#  0 -> kein Zusammenhang
# -1 -> negative Korrelation

# %%
# graphische Darstellung Niederschlag

coronawetterny2['Precipitation'].plot(kind='line')
plt.ylabel('Niederschlag')
plt.xlabel('Datum')
plt.title('Niederschlagswerte')

# %%
#Schleife Neuerkrankungen 14 Mal um jeweils einen Tag verschieben

for i in range(14):
    i=i-14
    coronawetterny2.loc[:,('positiveIncrease ' + str(i) + ' days after weather')] = coronawetterny2.positiveIncrease.shift(i)

# %%
#erweiterten Datanframe ausgeben

coronawetterny2

# %%
# Korrelationsmatrix mit Neuerkrankten x Tage nach Wetter

korrmat=coronawetterny2.corr(method ='kendall')

# %%
# korrelationsmatrix ausgeben

korrmat

# %%
# nicht benötigte Spalten löschen

korrmatcol=korrmat.copy()
korrmatcol=korrmatcol.drop(columns=['positiveIncrease -1 days after weather','positiveIncrease -2 days after weather', 'positiveIncrease -3 days after weather', 'positiveIncrease -5 days after weather', 'positiveIncrease -4 days after weather', 'positiveIncrease -6 days after weather', 'positiveIncrease -7 days after weather', 'positiveIncrease -8 days after weather', 'positiveIncrease -9 days after weather','positiveIncrease -10 days after weather','positiveIncrease -11 days after weather','positiveIncrease -12 days after weather','positiveIncrease -13 days after weather','positiveIncrease -14 days after weather', 'positive', 'positiveIncrease'])

# %%
#nicht benötigte Zeilen löschen

korrmatcol.drop(['Avg Temperature in C', 'Avg Dew Point in C', 'Avg Humidity in Percent', 'Avg Wind Speed in mph', 'Avg Pressure in Hg', 'Precipitation' ])

# %% [markdown]
# höchste Korrelation bei Luftdruck, allerdings ist der Wert dennoch zu niedrig, um von einer Korrelation auszugehen.

# %%
#Korrelation zwischen Luftdruck und anderen Wetterdaten ermitteln

wetterkorr=WetterNY.corr(method ='kendall')
wetterkorr['Avg Pressure in Hg']

# %% [markdown]
# # Bundesstaat Kalifornien (Stadt Los Angeles)

# %% [markdown]
# selbe Vorgehensweise wie für New York

# %%
USA

# %%
LA = USA[USA.state=='CA']
LA

# %%
WetterLA.rename(columns={"date": "Date"})
WetterLA

# %%
coronawetterla = pd.merge(WetterLA, LA, how='inner', on='date')
coronawetterla

# %%
coronawetterla.set_index('date')

# %%
coronawetterla2 = coronawetterla.copy()
coronawetterla2=coronawetterla2.drop(columns=['pending','hospitalizedCurrently', 'negative', 'hospitalizedCumulative', 'inIcuCurrently','inIcuCumulative', 'onVentilatorCurrently', 'onVentilatorCumulative'])

# %%
coronawetterla3 = coronawetterla2.copy()
coronawetterla3=coronawetterla3.drop(columns=['lastUpdateEt', 'hash', 'recovered', 'dataQualityGrade', 'dateChecked', 'death', 'hospitalized', 'totalTestResults', 'total', 'posNeg', 'fips', 'deathIncrease'])

# %%
coronawetterla4 = coronawetterla3.copy()
coronawetterla4=coronawetterla4.drop(columns=['hospitalizedIncrease', 'negativeIncrease', 'totalTestResultsIncrease'])
coronawetterla4

# %%
sortedcoronawetterla = coronawetterla4.sort_values(by='date')
sortedcoronawetterla

# %%
sortedcoronawetterla.info()

# %%
sortedcoronawetterla['date'] = sortedcoronawetterla['date'].astype(str)

# %%
sortedcoronawetterla.set_index('date', drop=True,inplace=True)
sortedcoronawetterla.head()
#sortedcoronawetterla

# %%
sortedcoronawetterla['positiveIncrease'].plot()
sortedcoronawetterla['Avg Temperature in C'].plot()
plt.xlabel('Achsenbeschriftung')

# %%
sortedcoronawetterla['Avg Temperature in C'].plot(kind='line',x='date',y='Avg Temperature in C')

# %%
sortedcoronawetterla.corr(method ='kendall')
#korrelation zwischen -1 und 1
#  1 -> korreliert
#  0 -> kein Zusammenhang
# -1 -> korreliert entgegengesetzt

# %%
sortedcoronawetterla['Precipitation'].plot(kind='line')
plt.ylabel('Niederschlag')
plt.xlabel('Datum')
plt.title('Niederschlagswerte')

# %%
for i in range(14):
    i=i-14
    sortedcoronawetterla.loc[:,('positiveIncrease ' + str(i) + ' days after weather')] = sortedcoronawetterla.positiveIncrease.shift(i)

# %%
sortedcoronawetterla.head()

# %%
korrmatla=sortedcoronawetterla.corr(method ='kendall')

# %%
korrmatla

# %%
korrmatlacol=korrmatla.copy()
korrmatlacol=korrmatlacol.drop(columns=['positiveIncrease -1 days after weather','positiveIncrease -2 days after weather', 'positiveIncrease -3 days after weather', 'positiveIncrease -5 days after weather', 'positiveIncrease -4 days after weather', 'positiveIncrease -6 days after weather', 'positiveIncrease -7 days after weather', 'positiveIncrease -8 days after weather', 'positiveIncrease -9 days after weather','positiveIncrease -10 days after weather','positiveIncrease -11 days after weather','positiveIncrease -12 days after weather','positiveIncrease -13 days after weather','positiveIncrease -14 days after weather', 'positive', 'positiveIncrease'])

# %%
korrmatlacol.drop(['Avg Temperature in C', 'Avg Dew Point in C', 'Avg Humidity in Percent', 'Avg Wind Speed in mph', 'Avg Pressure in Hg', 'Precipitation' ])

# %% [markdown]
# auch hier zunächst keine Korrelation ersichtlich

# %% [markdown]
# ## Weitere Vorgehensweise

# %% [markdown]
# weitere States der USA werden stichprobenartig ausgesucht, dann wird die Gesamtheit der Daten auf Korrelationen untersucht.
#
# In weiteren Notebooks sind weitere mögliche Zusammenhänge ermittelt.
#  -Zusammenhang zwischen der Reproduktionszahl und dem Wetter
#  -Zusammenhang zwischen Bewegungsdaten, Wetter und Covid-19

# %% [markdown]
# ## Einlesen der Wetterdaten für weitere US Bundesstaaten

# %%
USA['state'].unique()

# %%
WetterTX = pd.read_csv('/kaggle/input/usawetter/Austin.csv',sep = ";")
WetterNC = pd.read_csv('/kaggle/input/usawetter/Bismarck.csv',sep = ";")
WetterCO = pd.read_csv('/kaggle/input/usawetter/Denver.csv',sep = ";")
WetterFL = pd.read_csv('/kaggle/input/usawetter/Miami.csv',sep = ";")
WetterAZ = pd.read_csv('/kaggle/input/usawetter/Phoenix.csv',sep = ";")

# %% [markdown]
# ## Bundesstaat Texas

# %%
TX = USA[USA.state=='TX']
TX.head()

# %%
WetterTX

# %%
WetterTX.rename(columns={"date": "Date"})
WetterTX

# %%
coronawettertx = pd.merge(WetterTX, TX, how='inner', on='date')
coronawettertx

# %%
coronawettertx.set_index('date')

# %%
coronawettertx2 = coronawettertx.copy()
coronawettertx2=coronawettertx2.drop(columns=['pending','hospitalizedCurrently', 'negative', 'hospitalizedCumulative', 'inIcuCurrently','inIcuCumulative', 'onVentilatorCurrently', 'onVentilatorCumulative'])

# %%
coronawettertx3 = coronawettertx2.copy()
coronawettertx3=coronawettertx3.drop(columns=['lastUpdateEt', 'hash', 'recovered', 'dataQualityGrade', 'dateChecked', 'death', 'hospitalized', 'totalTestResults', 'total', 'posNeg', 'fips', 'deathIncrease'])

# %%
coronawettertx4 = coronawettertx3.copy()
coronawettertx4=coronawettertx4.drop(columns=['hospitalizedIncrease', 'negativeIncrease', 'totalTestResultsIncrease'])
coronawettertx4

# %%
sortedcoronawettertx = coronawettertx4.sort_values(by='date')
sortedcoronawettertx

# %%
sortedcoronawettertx.info()

# %%
sortedcoronawettertx['date'] = sortedcoronawettertx['date'].astype(str)

# %%
sortedcoronawettertx.set_index('date', drop=True,inplace=True)
sortedcoronawettertx.head()
#sortedcoronawettertx

# %%
sortedcoronawettertx.corr(method ='kendall')
#korrelation zwischen -1 und 1
#  1 -> korreliert
#  0 -> kein Zusammenhang
# -1 -> korreliert entgegengesetzt

# %%
for i in range(14):
    i=i-14
    sortedcoronawettertx.loc[:,('positiveIncrease ' + str(i) + ' days after weather')] = sortedcoronawettertx.positiveIncrease.shift(i)

# %%
sortedcoronawetterla.head()

# %%
korrmattx=sortedcoronawettertx.corr(method ='kendall')

# %%
korrmattx

# %%
korrmattxcol=korrmattx.copy()
korrmattxcol=korrmattxcol.drop(columns=['positiveIncrease -1 days after weather','positiveIncrease -2 days after weather', 'positiveIncrease -3 days after weather', 'positiveIncrease -5 days after weather', 'positiveIncrease -4 days after weather', 'positiveIncrease -6 days after weather', 'positiveIncrease -7 days after weather', 'positiveIncrease -8 days after weather', 'positiveIncrease -9 days after weather','positiveIncrease -10 days after weather','positiveIncrease -11 days after weather','positiveIncrease -12 days after weather','positiveIncrease -13 days after weather','positiveIncrease -14 days after weather', 'positive', 'positiveIncrease'])

# %%
korrmattxcol.drop(['Avg Temperature in C', 'Avg Dew Point in C', 'Avg Humidity in Percent', 'Avg Wind Speed in mph', 'Avg Pressure in Hg', 'Precipitation' ])

# %% [markdown]
# ## Bundesstaat North Carolina

# %%
NC = USA[USA.state=='NC']
NC.head()

# %%
WetterNC

# %%
WetterNC.rename(columns={"date": "Date"})
WetterNC

# %%
coronawetternc = pd.merge(WetterNC, NC, how='inner', on='date')
coronawetternc

# %%
coronawetternc.set_index('date')

# %%
coronawetternc2 = coronawetternc.copy()
coronawetternc2=coronawetternc2.drop(columns=['pending','hospitalizedCurrently', 'negative', 'hospitalizedCumulative', 'inIcuCurrently','inIcuCumulative', 'onVentilatorCurrently', 'onVentilatorCumulative'])

# %%
coronawetternc3 = coronawetternc2.copy()
coronawetternc3=coronawetternc3.drop(columns=['lastUpdateEt', 'hash', 'recovered', 'dataQualityGrade', 'dateChecked', 'death', 'hospitalized', 'totalTestResults', 'total', 'posNeg', 'fips', 'deathIncrease'])

# %%
coronawetternc4 = coronawetternc3.copy()
coronawetternc4=coronawetternc4.drop(columns=['hospitalizedIncrease', 'negativeIncrease', 'totalTestResultsIncrease'])
coronawetternc4

# %%
sortedcoronawetternc = coronawetternc4.sort_values(by='date')
sortedcoronawetternc

# %%
sortedcoronawetternc.info()

# %%
sortedcoronawetternc['date'] = sortedcoronawetternc['date'].astype(str)

# %%
sortedcoronawetternc.set_index('date', drop=True,inplace=True)
sortedcoronawetternc.head()
#sortedcoronawetternc

# %%
sortedcoronawetternc.corr(method ='kendall')
#korrelation zwischen -1 und 1
#  1 -> korreliert
#  0 -> kein Zusammenhang
# -1 -> korreliert entgegengesetzt

# %%
for i in range(14):
    i=i-14
    sortedcoronawetternc.loc[:,('positiveIncrease ' + str(i) + ' days after weather')] = sortedcoronawetternc.positiveIncrease.shift(i)

# %%
sortedcoronawetternc.head()

# %%
korrmatnc=sortedcoronawetternc.corr(method ='kendall')

# %%
korrmatnc

# %%
korrmatnccol=korrmatnc.copy()
korrmatnccol=korrmatnccol.drop(columns=['positiveIncrease -1 days after weather','positiveIncrease -2 days after weather', 'positiveIncrease -3 days after weather', 'positiveIncrease -5 days after weather', 'positiveIncrease -4 days after weather', 'positiveIncrease -6 days after weather', 'positiveIncrease -7 days after weather', 'positiveIncrease -8 days after weather', 'positiveIncrease -9 days after weather','positiveIncrease -10 days after weather','positiveIncrease -11 days after weather','positiveIncrease -12 days after weather','positiveIncrease -13 days after weather','positiveIncrease -14 days after weather', 'positive', 'positiveIncrease'])

# %%
korrmatnccol.drop(['Avg Temperature in C', 'Avg Dew Point in C', 'Avg Humidity in Percent', 'Avg Wind Speed in mph', 'Avg Pressure in Hg', 'Precipitation' ])

# %% [markdown]
# ## Bundesstaat Colorado

# %%
CO = USA[USA.state=='CO']
CO.head()

# %%
WetterCO

# %%
WetterCO.rename(columns={"date": "Date"})
WetterCO

# %%
coronawetterco = pd.merge(WetterCO, CO, how='inner', on='date')
coronawetterco

# %%
coronawetterco.set_index('date')

# %%
coronawetterco2 = coronawetterco.copy()
coronawetterco2=coronawetterco2.drop(columns=['pending','hospitalizedCurrently', 'negative', 'hospitalizedCumulative', 'inIcuCurrently','inIcuCumulative', 'onVentilatorCurrently', 'onVentilatorCumulative'])

# %%
coronawetterco3 = coronawetterco2.copy()
coronawetterco3=coronawetterco3.drop(columns=['lastUpdateEt', 'hash', 'recovered', 'dataQualityGrade', 'dateChecked', 'death', 'hospitalized', 'totalTestResults', 'total', 'posNeg', 'fips', 'deathIncrease'])

# %%
coronawetterco4 = coronawetterco3.copy()
coronawetterco4=coronawetterco4.drop(columns=['hospitalizedIncrease', 'negativeIncrease', 'totalTestResultsIncrease'])
coronawetterco4

# %%
sortedcoronawetterco = coronawetterco4.sort_values(by='date')
sortedcoronawetterco

# %%
sortedcoronawetterco.info()

# %%
sortedcoronawetterco['date'] = sortedcoronawetterco['date'].astype(str)

# %%
sortedcoronawetterco.set_index('date', drop=True,inplace=True)
sortedcoronawetterco.head()
#sortedcoronawetterco

# %%
sortedcoronawetterco.corr(method ='kendall')
#korrelation zwischen -1 und 1
#  1 -> korreliert
#  0 -> kein Zusammenhang
# -1 -> korreliert entgegengesetzt

# %%
for i in range(14):
    i=i-14
    sortedcoronawetterco.loc[:,('positiveIncrease ' + str(i) + ' days after weather')] = sortedcoronawetterco.positiveIncrease.shift(i)

# %%
sortedcoronawetterco.head()

# %%
korrmatco=sortedcoronawetterco.corr(method ='kendall')

# %%
korrmatco

# %%
korrmatcocol=korrmatco.copy()
korrmatcocol=korrmatcocol.drop(columns=['positiveIncrease -1 days after weather','positiveIncrease -2 days after weather', 'positiveIncrease -3 days after weather', 'positiveIncrease -5 days after weather', 'positiveIncrease -4 days after weather', 'positiveIncrease -6 days after weather', 'positiveIncrease -7 days after weather', 'positiveIncrease -8 days after weather', 'positiveIncrease -9 days after weather','positiveIncrease -10 days after weather','positiveIncrease -11 days after weather','positiveIncrease -12 days after weather','positiveIncrease -13 days after weather','positiveIncrease -14 days after weather', 'positive', 'positiveIncrease'])

# %%
korrmatcocol.drop(['Avg Temperature in C', 'Avg Dew Point in C', 'Avg Humidity in Percent', 'Avg Wind Speed in mph', 'Avg Pressure in Hg', 'Precipitation' ])

# %% [markdown]
# ## Bundesstaat Florida

# %%
FL = USA[USA.state=='FL']
FL.head()

# %%
WetterFL

# %%
WetterFL.rename(columns={"date": "Date"})
WetterFL

# %%
coronawetterfl = pd.merge(WetterFL, FL, how='inner', on='date')
coronawetterfl

# %%
coronawetterfl.set_index('date')

# %%
coronawetterfl2 = coronawetterfl.copy()
coronawetterfl2=coronawetterfl2.drop(columns=['pending','hospitalizedCurrently', 'negative', 'hospitalizedCumulative', 'inIcuCurrently','inIcuCumulative', 'onVentilatorCurrently', 'onVentilatorCumulative'])

# %%
coronawetterfl3 = coronawetterfl2.copy()
coronawetterfl3=coronawetterfl3.drop(columns=['lastUpdateEt', 'hash', 'recovered', 'dataQualityGrade', 'dateChecked', 'death', 'hospitalized', 'totalTestResults', 'total', 'posNeg', 'fips', 'deathIncrease'])

# %%
coronawetterfl4 = coronawetterfl3.copy()
coronawetterfl4=coronawetterfl4.drop(columns=['hospitalizedIncrease', 'negativeIncrease', 'totalTestResultsIncrease'])
coronawetterfl4

# %%
sortedcoronawetterfl = coronawetterfl4.sort_values(by='date')
sortedcoronawetterfl

# %%
sortedcoronawetterfl.info()

# %%
sortedcoronawetterfl['date'] = sortedcoronawetterfl['date'].astype(str)

# %%
sortedcoronawetterfl.set_index('date', drop=True,inplace=True)
sortedcoronawetterfl.head()
#sortedcoronawetterfl

# %%
sortedcoronawetterfl.corr(method ='kendall')
#korrelation zwischen -1 und 1
#  1 -> korreliert
#  0 -> kein Zusammenhang
# -1 -> korreliert entgegengesetzt

# %%
for i in range(14):
    i=i-14
    sortedcoronawetterfl.loc[:,('positiveIncrease ' + str(i) + ' days after weather')] = sortedcoronawetterfl.positiveIncrease.shift(i)

# %%
sortedcoronawetterfl.head()

# %%
korrmatfl=sortedcoronawetterfl.corr(method ='kendall')

# %%
korrmatfl

# %%
korrmatflcol=korrmatfl.copy()
korrmatflcol=korrmatflcol.drop(columns=['positiveIncrease -1 days after weather','positiveIncrease -2 days after weather', 'positiveIncrease -3 days after weather', 'positiveIncrease -5 days after weather', 'positiveIncrease -4 days after weather', 'positiveIncrease -6 days after weather', 'positiveIncrease -7 days after weather', 'positiveIncrease -8 days after weather', 'positiveIncrease -9 days after weather','positiveIncrease -10 days after weather','positiveIncrease -11 days after weather','positiveIncrease -12 days after weather','positiveIncrease -13 days after weather','positiveIncrease -14 days after weather', 'positive', 'positiveIncrease'])

# %%
korrmatflcol.drop(['Avg Temperature in C', 'Avg Dew Point in C', 'Avg Humidity in Percent', 'Avg Wind Speed in mph', 'Avg Pressure in Hg', 'Precipitation' ])

# %% [markdown]
# ## Bundesstaat Arizona

# %%
AZ = USA[USA.state=='AZ']
AZ.head()

# %%
WetterAZ

# %%
WetterAZ.rename(columns={"date": "Date"})
WetterAZ

# %%
coronawetteraz = pd.merge(WetterAZ, AZ, how='inner', on='date')
coronawetteraz

# %%
coronawetteraz.set_index('date')

# %%
coronawetteraz2 = coronawetteraz.copy()
coronawetteraz2=coronawetteraz2.drop(columns=['pending','hospitalizedCurrently', 'negative', 'hospitalizedCumulative', 'inIcuCurrently','inIcuCumulative', 'onVentilatorCurrently', 'onVentilatorCumulative'])

# %%
coronawetteraz3 = coronawetteraz2.copy()
coronawetteraz3=coronawetteraz3.drop(columns=['lastUpdateEt', 'hash', 'recovered', 'dataQualityGrade', 'dateChecked', 'death', 'hospitalized', 'totalTestResults', 'total', 'posNeg', 'fips', 'deathIncrease'])

# %%
coronawetteraz4 = coronawetteraz3.copy()
coronawetteraz4=coronawetteraz4.drop(columns=['hospitalizedIncrease', 'negativeIncrease', 'totalTestResultsIncrease'])
coronawetteraz4

# %%
sortedcoronawetteraz = coronawetteraz4.sort_values(by='date')
sortedcoronawetteraz

# %%
sortedcoronawetteraz.info()

# %%
sortedcoronawetteraz['date'] = sortedcoronawetteraz['date'].astype(str)

# %%
sortedcoronawetteraz.set_index('date', drop=True,inplace=True)
sortedcoronawetteraz.head()
#sortedcoronawetteraz

# %%
sortedcoronawetteraz.corr(method ='kendall')
#korrelation zwischen -1 und 1
#  1 -> korreliert
#  0 -> kein Zusammenhang
# -1 -> korreliert entgegengesetzt

# %%
for i in range(14):
    i=i-14
    sortedcoronawetteraz.loc[:,('positiveIncrease ' + str(i) + ' days after weather')] = sortedcoronawetteraz.positiveIncrease.shift(i)

# %%
sortedcoronawetteraz.head()

# %%
korrmataz=sortedcoronawetteraz.corr(method ='kendall')

# %%
korrmataz

# %%
korrmatazcol=korrmataz.copy()
korrmatazcol=korrmatazcol.drop(columns=['positiveIncrease -1 days after weather','positiveIncrease -2 days after weather', 'positiveIncrease -3 days after weather', 'positiveIncrease -5 days after weather', 'positiveIncrease -4 days after weather', 'positiveIncrease -6 days after weather', 'positiveIncrease -7 days after weather', 'positiveIncrease -8 days after weather', 'positiveIncrease -9 days after weather','positiveIncrease -10 days after weather','positiveIncrease -11 days after weather','positiveIncrease -12 days after weather','positiveIncrease -13 days after weather','positiveIncrease -14 days after weather', 'positive', 'positiveIncrease'])

# %%
korrmatazcol.drop(['Avg Temperature in C', 'Avg Dew Point in C', 'Avg Humidity in Percent', 'Avg Wind Speed in mph', 'Avg Pressure in Hg', 'Precipitation' ])
