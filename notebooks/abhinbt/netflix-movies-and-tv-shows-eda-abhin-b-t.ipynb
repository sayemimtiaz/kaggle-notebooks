# %% [markdown]
# # Netflix Movies and TV Shows

# %%
# Import libraries

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read data

data = pd.read_csv('/kaggle/input/netflix-shows/netflix_titles.csv')

# %%
# Number of column present

len(data.columns)

# %%
# column names

data.columns

# %%
# Number of records

data['show_id'].count

# %%
# Head rows

data.head(4)

# %%
# Tail rows

data.tail(4)

# %%
# Information about dataset

data.info()

# %%
# Count of record based on year


plt.hist(data['release_year']);
