# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
pd.read_csv('/kaggle/input/crimes-in-boston/crime.csv')

# %%
data = pd.read_csv('/kaggle/input/crimes-in-boston/crime.csv', encoding='latin-1')

# %%
data.head()

# %%
data.describe()

# %% [markdown]
# **Exercício 1** - Selecione a coluna  "INCIDENT_NUMBER".

# %%
data["INCIDENT_NUMBER"]

# %%
data.loc[:,"INCIDENT_NUMBER"]

# %%
data.iloc[:,1]

# %% [markdown]
# **Exercício 2** - Selecione o primeiro valor da coluna "INCIDENT_NUMBER".

# %%
data["INCIDENT_NUMBER"][0]

# %%
data.loc[0,"INCIDENT_NUMBER"]

# %%
data.iloc[0,0]

# %% [markdown]
# **Exercício 3** - Selecione a primeira linha dos registros.

# %%
data.loc[0,:]

# %%
data.iloc[0,:]

# %% [markdown]
# **Exercício 4** - Selecione as primeiras 10 linhas da coluna.

# %%
data.loc[:10,"OFFENSE_CODE_GROUP"]

# %%
data.iloc[:10,2]

# %% [markdown]
# **Exercício 5** - Selecione as colunas com indice 2, 4, 6, 8 dos registros.

# %%
data.iloc[:,[2, 4, 6, 8]]

# %% [markdown]
# **Exercício 6** - Selecione as linhas com indice 2, 4, 6, 8 e as colunas "OFFENSE_CODE_GROUP", "DISTRICT", "SHOOTING", "YEAR" dos registros.

# %%
data.loc[[2, 4, 6, 8], ["OFFENSE_CODE_GROUP", "DISTRICT", "SHOOTING", "YEAR"]]

# %% [markdown]
# **Exercício 7** - Selecione as  10 primeiras linhas e das colunas "OFFENSE_CODE_GROUP", "DISTRICT", "SHOOTING", "YEAR" dos registros.

# %%
data.loc[:9, ["OFFENSE_CODE_GROUP", "DISTRICT", "SHOOTING", "YEAR"]]

# %%
data.iloc[:10, [2, 4, 6, 8]]

# %% [markdown]
# **Exercício 8** - Selecione todos os registros de "Vandalism".

# %%
data.loc[data.OFFENSE_CODE_GROUP == "Vandalism"]

# %%
data.loc[data["OFFENSE_CODE_GROUP"] == "Vandalism"]

# %% [markdown]
# **Exercício 9** - Selecione todos os registros de "Vandalism" que ocorreram na segunda-feira (Monday).

# %%
data.loc[(data["OFFENSE_CODE_GROUP"] == "Vandalism") & (data["DAY_OF_WEEK"] == "Monday")]

# %% [markdown]
# **Exercício 10** - Em que dia da semana é mais comum ocorrem roubos de carros (Auto Theft)

# %%
data.loc[data["OFFENSE_CODE_GROUP"] == "Auto Theft"].loc[:,"DAY_OF_WEEK"].value_counts().plot.bar()
