# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

# Any results you write to the current directory are saved as output.

# %%
data = pd.read_csv("../input/startup_funding.csv")

# %%
# checking data
print(data.head())

# %%
print(data.info())

# %% [markdown]
# Question 1 : Which city has maximum startups ?

# %%
city = data['CityLocation']
print(city.value_counts().head())
city.value_counts().head(10).plot.bar()

# %% [markdown]
# Clearly Banglore outnumber other cities in India for number of startups

# %% [markdown]
# Question 2 : What are different types of funding for startups ?

# %%
print(data['InvestmentType'].value_counts())

# %% [markdown]
# Maximum funding is avaialble as Seed Funding followed by Private Equity

# %% [markdown]
# Question 3 : Which Investors invested in number of startups or Who are the important investors in the Indian Ecosystem?

# %%
data.InvestorsName.value_counts().head(10)

# %% [markdown]
# Table suggests as an individual **"Ratan Tata"** invested in maximum startups. Let's look at how much he has invested in 24 startups.

# %%
data['AmountInUSD'][data.InvestorsName == 'Ratan Tata']

# %% [markdown]
# Unfortunately no information is available regarding the amount of investment by Ratan Tata. Let's look at maximum investment in indian startups

# %%
# converting object to numeric for arthmetic calculations
data["AmountInUSD"] = data["AmountInUSD"].str.replace(",","")
data["AmountInUSD"] = pd.to_numeric(data["AmountInUSD"])

print(data["AmountInUSD"].dropna().sort_values().max())
data[data.AmountInUSD == 1400000000.0]

# %% [markdown]
# Maximum investment in indian start up is 1400000000 USD in Paytm and Flipkart . Now let's look at startups with least funding.

# %%
print(data["AmountInUSD"].dropna().sort_values().min())
data[data.AmountInUSD == 16000.0]

# %%
print(data["AmountInUSD"].dropna().sort_values().mean())
#data[data.AmountInUSD == 16000.0]

# %% [markdown]
# On average indian startups get 12031073.1 USD in funding.

# %%
data
