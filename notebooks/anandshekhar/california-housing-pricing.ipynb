# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../input/california-housing-prices/housing.csv", sep=",")

# %%
df.head()

# %%
df.shape

# %%
df.describe()

# %%
df.info()

# %%
df.isnull().sum()

# %%
df= df[~pd.isnull(df['total_bedrooms'])]

# %%
df.isnull().sum()

# %%
sns.distplot(df['median_house_value'])
plt.show()

# %%
sns.distplot(df['median_income'])
plt.show()

# %%
    sns.countplot(x= 'ocean_proximity', data = df)
    plt.xticks(rotation=90)

# %%
df.info()

# %%
df.hist(figsize=(10,10), bins=50)
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True)

# %%
df.plot(kind='scatter', x='longitude', y='latitude', figsize=(13,9), alpha=0.5,
       s=df['population']/100, label='population', c='median_house_value',
       cmap=plt.get_cmap('jet'), colorbar=True)
plt.legend(loc='best')
plt.show()

# %%
from collections import Counter
Counter(df.ocean_proximity)

# %%
sns.boxplot(df['total_rooms'])

# %%
sns.boxplot(df['total_bedrooms'])

# %%
# Creating new attributes
df['room_per_households'] = df['total_rooms']/df['households']
df['bedrooms_per_room'] = df['total_bedrooms']/df['total_rooms']
df['population_per_household'] = df['population']/df['households']

# %%
plt.figure(figsize=(20,14))
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, fmt='0.2f', annot_kws={'size':10}, cmap=plt.get_cmap('jet'))

# %%
plt.figure(figsize=(6,5))
sns.boxplot(x='ocean_proximity', y='median_house_value', data=df)

# %%
df = pd.get_dummies(df, columns=['ocean_proximity'], drop_first=True)

# %%
df.head()

# %%
plt.figure(figsize=(20,14))
corr_matrix_1 = df.corr()
sns.heatmap(corr_matrix_1, annot=True, fmt='0.2f', annot_kws={'size':10}, cmap=plt.get_cmap('jet'))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X = df.drop(['median_house_value'], axis=1)
y=df['median_house_value']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state=10)

# %%
sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

# %%
lr = LinearRegression()
lr.fit(X_train_sc, y_train)
print('Training R2')
print(lr.score(X_train_sc, y_train))
print('Testing R2')
print(lr.score(X_test_sc, y_test))

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor(max_depth=1, random_state=10)
dt.fit(X_train, y_train)
print('Training R2')
print(dt.score(X_train, y_train))
print('Testing R2')
print(dt.score(X_test, y_test))

# %%
dt = DecisionTreeRegressor(max_depth=10, random_state=10)
dt.fit(X_train, y_train)
print('Training R2')
print(dt.score(X_train, y_train))
print('Testing R2')
print(dt.score(X_test, y_test))

# %%
    dt.feature_importances_

# %%
X_train

# %%
xg = XGBRegressor(random_state = 10)
xg.fit(X_train_sc, y_train)
print('Training R2')
print(xg.score(X_train_sc, y_train))
print('Testing R2')
print(xg.score(X_test_sc, y_test))

# %%
xg = XGBRegressor(random_state = 10)
xg.fit(X_train_sc, y_train)
print('Training R2')
print(xg.score(X_train_sc, y_train))
print('Testing R2')
print(xg.score(X_test_sc, y_test))

# %%
from xgboost import XGBRegressor
xg = XGBRegressor(n_estimators = 20, random_state = 10)
xg.fit(X_train, y_train)
print('Training R2')
print(xg.score(X_train, y_train))
print('Testing R2')
print(xg.score(X_test, y_test))

# %%
from xgboost import XGBRegressor
xg = XGBRegressor(max_depth=7, n_estimators = 100, random_state = 10)
xg.fit(X_train, y_train)
print('Training R2')
print(xg.score(X_train, y_train))
print('Testing R2')
print(xg.score(X_test, y_test))

# %%
from sklearn.model_selection import cross_val_score
scorexgb = cross_val_score(xg, X_train_sc, y_train, cv=10, scoring='r2')
print(scorexgb)

# %%
np.mean(scorexgb)
