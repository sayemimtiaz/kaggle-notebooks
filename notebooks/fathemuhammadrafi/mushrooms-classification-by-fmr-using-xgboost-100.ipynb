# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print("setup completed")

# %%
filepath  ='../input/mushroom-classification/mushrooms.csv'

# %%
df = pd.read_csv(filepath)
df

# %%
df.shape

# %%
df.isnull().sum().sum()

# %%
df.keys()

# %%
df.info()

# %%
df.describe()

# %%
sns.heatmap(df.isnull(),cbar=False,cmap='Dark2')

# %%
#fininding unique value
col  = df.columns
col
for column in col:
    print(column,'--> ', df[column].unique())

# %%
#encoding object to numeric value
from sklearn.preprocessing import LabelEncoder
l = LabelEncoder()
for i in df.columns:
    df[i] = l.fit_transform(df[i])

# %%
df.corrwith(df["class"])

# %%
#there have nan value in veil-type so i am going to drop it
df = df.drop(columns="veil-type",axis=1)

# %%
sns.countplot(df["class"])

# %%
# formatting for train_test_split
from sklearn.model_selection import train_test_split
X = df.drop(columns="class",axis=1)
y = df["class"]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=51)

# %%
#applying algorithm
from xgboost import XGBClassifier
model = XGBClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

# %%
#here is the accuracy
from sklearn.metrics import classification_report,accuracy_score
print(classification_report(y_test,y_pred))
print("accuracy score is (%) =",accuracy_score(y_test,y_pred)*100)

# %%
print("Thank you!")
