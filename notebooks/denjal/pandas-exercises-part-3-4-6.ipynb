# %% [markdown]
# <h1 style="text-align: center; font-size: 2rem; color: #38565c; font-weight: bold">
#     Welcome to the exercise section of your pandas training!
# </h1>

# %% [markdown]
# <p style="text-align: left; font-size: 1.25rem; color: #38565c;">
#    Import pandas and load data to a dataframe
# </p>

# %%
import pandas as pd
df = pd.read_csv("../input/videogamesales/vgsales.csv")

# %% [markdown]
# <h2 style="text-align: center; font-size: 1.75rem; color: #38565c; font-weight: bold">
#     Metadata analysis
# </h2>
#
# <h3 style="text-align: left; font-size: 1.5rem; color: #38565c; font-weight: bold">
#     Tasks:
# </h3>
# <h4 style="text-align: left; font-size: 1.25rem; color: #38565c; font-weight: bold">
#     How many columns exists in the dataset?
# </h4>
# <h4 style="text-align: left; font-size: 1.25rem; color: #38565c; font-weight: bold">
#     How many records (rows) exists in the dataset?
# </h4>
# <h4 style="text-align: left; font-size: 1.25rem; color: #38565c; font-weight: bold">
#     What are the datatypes?
# </h4>
# <h4 style="text-align: left; font-size: 1.25rem; color: #38565c; font-weight: bold">
#     Which columns has missing data?
# </h4>
# <h4 style="text-align: left; font-size: 1.25rem; color: #38565c; font-weight: bold">
#     What are the memory usage of the Pandas DataFrame?
# </h4>

# %% [markdown]
# hint: use info function

# %% [markdown]
# <h2 style="text-align: center; font-size: 1.75rem; color: #38565c; font-weight: bold">
#     Summary Statistics analysis
# </h2>
#
# <h3 style="text-align: left; font-size: 1.5rem; color: #38565c; font-weight: bold">
#     Tasks:
# </h3>
# <h4 style="text-align: left; font-size: 1.25rem; color: #38565c; font-weight: bold">
#    Between which years do we have records in this dataset?
# </h4>
# <h4 style="text-align: left; font-size: 1.25rem; color: #38565c; font-weight: bold">
#     What region has the highest sales figures on average?
# </h4>
# <h4 style="text-align: left; font-size: 1.25rem; color: #38565c; font-weight: bold">
#     What region has the highest sales figures in total?
# </h4>

# %% [markdown]
# hint: use the describe function and sum function

# %% [markdown]
# <h2 style="text-align: center; font-size: 1.75rem; color: #38565c; font-weight: bold">
#     Data analysis
# </h2>
#
# <h3 style="text-align: left; font-size: 1.5rem; color: #38565c; font-weight: bold">
#     Tasks:
# </h3>
# <h4 style="text-align: left; font-size: 1.25rem; color: #38565c; font-weight: bold">
#     What game has the highest sales figure?
# </h4>
# <h4 style="text-align: left; font-size: 1.25rem; color: #38565c; font-weight: bold">
#     Whats the difference in sales between North America and the EU?
# </h4>
# <h4 style="text-align: left; font-size: 1.25rem; color: #38565c; font-weight: bold">
#     What Genre is most common among the games?
# </h4>
# <h4 style="text-align: left; font-size: 1.25rem; color: #38565c; font-weight: bold">
#     What Platform is most common among the games?
# </h4>

# %% [markdown]
# hint: iloc with idxmax, and value_counts

# %% [markdown]
# <hr style="border-top: 3px solid #bbb;">

# %%
def sort_platform_provider(platform):
    if platform in ["PSP", "PS2", "PS3", "PS", "PS4", "PSV"]:
        return "Sony Playstation"
    elif platform in ["DS", "Wii", "GBA", "3DS", "N64","SNES" "WiiU", "NES", "GC"]:
        return "Nintendo"
    elif platform in ["XB", "XOne", "X360"]:
        return "Microsoft XBOX"
    elif platform in ["PC"]:
        return "PC"
    else:
        return "Other"

df["Platform Provider"] = df["Platform"].map(lambda platform: sort_platform_provider(platform))


def most_copies_sold_in(row):
    col = row.idxmax()
    if col == "NA_Sales":
        return "North America"
    elif col == "EU_Sales":
        return "Europe"
    elif col == "JP_Sales":
        return "Japan"
    else:
        return "Other"
    
df["Top Sales Region"] = df[["NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales"]].apply(lambda row: most_copies_sold_in(row), axis=1)

# %% [markdown]
# <h1 style="text-align: center; font-size: 2rem; color: #38565c; font-weight: bold">
#     Welcome to the next part of exercises for your pandas training!
# </h1>

# %% [markdown]
# <h2 style="text-align: center; font-size: 1.75rem; color: #38565c; font-weight: bold">
#     Data analysis
# </h2>
#
# <h3 style="text-align: left; font-size: 1.5rem; color: #38565c; font-weight: bold">
#     Tasks:
# </h3>
# <h4 style="text-align: left; font-size: 1.25rem; color: #38565c; font-weight: bold">
#     How many Action games is there on the Sony Playstation platform?
# </h4>
# <h4 style="text-align: left; font-size: 1.25rem; color: #38565c; font-weight: bold">
#     How many Adventure games is there on the Nintendo platform?
# </h4>
# <h4 style="text-align: left; font-size: 1.25rem; color: #38565c; font-weight: bold">
#     Whats the difference in sales between North America and the EU?
# </h4>
# <h4 style="text-align: left; font-size: 1.25rem; color: #38565c; font-weight: bold">
#     What Genre is most common among the games?
# </h4>
# <h4 style="text-align: left; font-size: 1.25rem; color: #38565c; font-weight: bold">
#     What Platform is most common among the games?
# </h4>

# %%
df.groupby(["Platform Provider"])["Genre"].value_counts()[["Sony Playstation"]]

# %%
df.groupby(["Platform Provider"])["Genre"].value_counts()[["Nintendo"]]

# %% [markdown]
# <p style="font-size: 1.25rem; color: #38565c;">We can extend the selection of colums to group by to narrow the scope of the aggregating function. Of course, we can also change the order of the columns for our analysis</p>

# %%
df.groupby(["Year", "Platform Provider", "Genre"])["Global_Sales"].max().idxmax()

# %%
df.groupby(["Year", "Platform Provider", "Genre"])["Global_Sales"].min().idxmin()
