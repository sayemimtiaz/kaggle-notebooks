# %% [markdown]
# A notebook for investigative visualisation

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

# from subprocess import check_output
# print(check_output(["ls", "../input"]).decode("utf8"))

# Any results you write to the current directory are saved as output.

# %%
# preparing data

responses = pd.read_csv("../input/responses.csv", index_col=False)

# df1 = responses.dropna(subset=['Giving', 'God']) # drop rows where essential data is missing
# print(np.corrcoef(df1['Giving'], df1['God']))

# df2 = responses.dropna(subset=['Dreams', 'Empathy'])
# print(np.corrcoef(df2['Dreams'], df2['Empathy']))

# droplist = ['Smoking', 'Alcohol', 'Punctuality', 'Lying', 'Internet usage', 'Gender', 'Left - right handed', 'Education', 'Only child', 'Village - town', 'House - block of flats']

# df3 = responses.drop(droplist, axis=1).dropna() # drop nonint columns and missing data

df3 = responses.dropna()

music = df3.ix[:,1:18]

movies = df3.ix[:,19:30]

subjects = df3.ix[:,19:45]

pastimes = df3.ix[:,46:62]

fears = df3.ix[:,63:72]

traits = df3.ix[:,76:132]

# %%
# forming sets and using them in a venn diagram module - basic investigation

from matplotlib_venn import venn3

# interest is a tuple of objects with
# interest = {{'variable name', 'range_floor', 'range_ceiling'}
#             {...}}
# so logically,
# interest = {{'Cats', 1, 3}
#             {'Dogs', 4, 5}}
# should produce a set of responses where the Dogs are preferred to Cats
# But what of categorical responses, such as 'Highest education achieved' or 'Gender'?
# We should detect type of the first criteria range and test that for equality
# Multiple categorical ..?
# Hmm. I need to reconsider if some of this work is already handled by set theory.
# perhaps intersection?
# let's refer

def make_set(data, interest):
# define responses of interest, variables of interest, and criteria for those variables

# for each response of interest:
# create a uid 

# for each variable of interest:
# convert to a dichotomous form 
# create a set
# add response uid to set where response variable meets the criteria


set1 = set(['A', 'B', 'C', 'D'])
set2 = set(['B', 'C', 'D', 'E'])
set3 = set(['C', 'D',' E', 'F', 'G'])

venn3([set1, set2, set3], ('Set1', 'Set2', 'Set3'))
plt.show()
