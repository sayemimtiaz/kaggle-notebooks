# %%
import numpy as np

# %%
np.arange(10)

# %%
np.arange(1,10)

# %%
np.arange(1,10,2)

# %%
np.arange(1,20,3, dtype=np.float64)

# %%
x = np.array([1, 3, 5, 7])
x

# %%
type(x)

# %%
np.array([(1,3,5), (7,9,11), (13, 15,17)]).ndim

# %%
np.zeros((2,3), dtype=np.int16)

# %%
np.ones((3,3), dtype=np.int16)

# %%
np.empty((2, 2, 4))

# %%
np.linspace(2, 4, 10) #start at value 2, end at 4

# %%
np.random.random((3,3))

# %%
ds = np.arange(1, 10, 3)
print(ds)
ds.ndim

# %%
threeD = np.arange(1, 30, 2).reshape(3, 5)
print(threeD)

# %%
ds.shape

# %%
ds.dtype

# %%
ds.itemsize

# %%
#BASIC OPERATIONS
a = np.arange(5)
b = np.array([2, 4, 0, 1, 2])
a

# %%
diff = a - b
diff

# %%
b**2

# %%
2*b

# %%
np.sin(a)

# %%
np.sum(a)

# %%
np.max(a)

# %%
np.min(a)

# %%
b > 2

# %%
a*b

# %%
x = np.array([[1,1], [0,1]])
y = np.array([[2,0], [3,4]])
x*y

# %%
x.dot(y)

# %%
x.sum(axis=1)

# %%
z = np.random.random((3, 4))

# %%
data_set = np.random.random((2,3))
data_set

# %%
data_set = np.random.random((5,10))
data_set

# %%
data_set[1]

# %%
data_set[1][0]

# %%
data_set[1,0]

# %%
data_set[2:4]

# %%
data_set[2:5:2]

# %%
data_set[::]

# %%
data_set[::2]

# %%
data_set[2:4, ::2]
