# %% [markdown]
# ****Diabetes Prediction Using Pima Indian Dataset

# %% [markdown]
# Import Libraries

# %%
import numpy as np
import pandas as pd
import  seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Load Pima Indian Diabetes Dataset

# %%
data = pd.read_csv("../input/pima-indians-diabetes-database/diabetes.csv")

# %%
data.head()

# %%
data.dtypes

# %% [markdown]
# Check for null data

# %%
data.isnull().sum()

# %% [markdown]
# There is no null data

# %%
plt.figure(figsize = (12,10))
sns.heatmap(data.corr(),annot = True)

# %% [markdown]
# Split the data

# %%
X = data.drop(columns = 'Outcome')
y = data['Outcome']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# Importing Models

# %%
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.tree import DecisionTreeClassifier as DTC
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC,LinearSVC
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,ExtraTreesClassifier,BaggingClassifier,GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %% [markdown]
# Now check which Algorithm gives highest accuracy??

# %%
mn = [KNN(),DTC(),GaussianNB(),SVC(),LinearSVC(),RandomForestClassifier(),AdaBoostClassifier(),ExtraTreesClassifier(),BaggingClassifier(),GradientBoostingClassifier(),LogisticRegression(),LDA()]
for i in range(12):
    Model = mn[i]
    Model.fit(X_train,y_train)
    y_pred = Model.predict(X_test)
    print(Model)
    print("Clasification Report:\n",classification_report(y_test,y_pred))
    print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
    print("Accuracy:\n",accuracy_score(y_test,y_pred)*100)

# %% [markdown]
# After running this model we got to know that Logistic Regression, Random Forest and LDA gave same accuracy, i.e., 82.46 % , which is the highest!!!

# %% [markdown]
# Please upvote if found useful!!!
