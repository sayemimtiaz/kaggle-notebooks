# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %%
vac_data = pd.read_csv('../input/covid-world-vaccination-progress/country_vaccinations.csv')
pop_data = pd.read_csv('../input/corona-virus-report/worldometer_data.csv')
vac_manu = pd.read_csv('../input/covid-world-vaccination-progress/country_vaccinations_by_manufacturer.csv')

# %%
vac_data.head()

# %%
vac_data['date'] = pd.to_datetime(vac_data['date'])

# %%
vac_data.columns

# %%
usa_vac = vac_data[vac_data['country'] == 'United States']
uk_vac = vac_data[vac_data['country'] == 'United Kingdom']
ger_vac = vac_data[vac_data['country'] == 'Germany']
ita_vac = vac_data[vac_data['country'] == 'Italy']
fra_vac = vac_data[vac_data['country'] == 'France']
chi_vac = vac_data[vac_data['country'] == 'China']
rus_vac = vac_data[vac_data['country'] == 'Russia']
isr_vac = vac_data[vac_data['country'] == 'Israel']
uae_vac = vac_data[vac_data['country'] == 'United Arab Emirates']
can_vac = vac_data[vac_data['country'] == 'Canada']
jpn_vac = vac_data[vac_data['country'] == 'Japan']
ind_vac = vac_data[vac_data['country'] == 'India']
ino_vac = vac_data[vac_data['country'] == 'Indonesia']
mal_vac = vac_data[vac_data['country'] == 'Malaysia']
ban_vac = vac_data[vac_data['country'] == 'Bangladesh']
nig_vac = vac_data[vac_data['country'] == 'Nigeria']
phi_vac = vac_data[vac_data['country'] == 'Phillipines']
vie_vac = vac_data[vac_data['country'] == 'Vietnam']
egy_vac = vac_data[vac_data['country'] == 'Egypt']
pak_vac = vac_data[vac_data['country'] == 'Pakistan']

# %%
usa_vac.drop(usa_vac[usa_vac['daily_vaccinations'].isnull()].index, inplace=True)
uk_vac.drop(uk_vac[uk_vac['daily_vaccinations'].isnull()].index, inplace=True)
ger_vac.drop(ger_vac[ger_vac['daily_vaccinations'].isnull()].index, inplace=True)
ita_vac.drop(ita_vac[ita_vac['daily_vaccinations'].isnull()].index, inplace=True)
fra_vac.drop(fra_vac[fra_vac['daily_vaccinations'].isnull()].index, inplace=True)
chi_vac.drop(chi_vac[chi_vac['daily_vaccinations'].isnull()].index, inplace=True)
rus_vac.drop(rus_vac[rus_vac['daily_vaccinations'].isnull()].index, inplace=True)
isr_vac.drop(isr_vac[isr_vac['daily_vaccinations'].isnull()].index, inplace=True)
uae_vac.drop(uae_vac[uae_vac['daily_vaccinations'].isnull()].index, inplace=True)
can_vac.drop(can_vac[can_vac['daily_vaccinations'].isnull()].index, inplace=True)
jpn_vac.drop(jpn_vac[jpn_vac['daily_vaccinations'].isnull()].index, inplace=True)
ind_vac.drop(ind_vac[ind_vac['daily_vaccinations'].isnull()].index, inplace=True)
ino_vac.drop(ino_vac[ino_vac['daily_vaccinations'].isnull()].index, inplace=True)
mal_vac.drop(mal_vac[mal_vac['daily_vaccinations'].isnull()].index, inplace=True)
ban_vac.drop(ban_vac[ban_vac['daily_vaccinations'].isnull()].index, inplace=True)
nig_vac.drop(nig_vac[nig_vac['daily_vaccinations'].isnull()].index, inplace=True)
phi_vac.drop(phi_vac[phi_vac['daily_vaccinations'].isnull()].index, inplace=True)
vie_vac.drop(vie_vac[vie_vac['daily_vaccinations'].isnull()].index, inplace=True)
egy_vac.drop(egy_vac[egy_vac['daily_vaccinations'].isnull()].index, inplace=True)
pak_vac.drop(pak_vac[pak_vac['daily_vaccinations'].isnull()].index, inplace=True)

# %% [markdown]
# **Progress in Vaccination Rates:**
#
# Comparing daily vaccination rates of some prominent European Countries

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=fra_vac['date'], y=fra_vac['daily_vaccinations'], mode='lines+markers', name='France'))
fig.add_trace(go.Scatter(x=uk_vac['date'],y=uk_vac['daily_vaccinations'], mode='lines+markers', name='UK'))
fig.add_trace(go.Scatter(x=ger_vac['date'],y=ger_vac['daily_vaccinations'], mode='lines+markers', name='Germany'))
fig.add_trace(go.Scatter(x=ita_vac['date'],y=ita_vac['daily_vaccinations'], mode='lines+markers', name='Italy'))
fig.update_layout(title='Comparison of Daily Vaccinations')
fig.show()

# %% [markdown]
# Comparing daily vaccination rates of some other prominent countries around the world

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=usa_vac['date'], y=usa_vac['daily_vaccinations'], mode='lines+markers', name='USA'))
fig.add_trace(go.Scatter(x=chi_vac['date'],y=chi_vac['daily_vaccinations'], mode='lines+markers', name='China'))
fig.add_trace(go.Scatter(x=rus_vac['date'],y=rus_vac['daily_vaccinations'], mode='lines+markers', name='Russia'))
fig.add_trace(go.Scatter(x=uae_vac['date'],y=uae_vac['daily_vaccinations'], mode='lines+markers', name='UAE'))
fig.update_layout(title='Comparison of Daily Vaccinations')
fig.show()

# %% [markdown]
# **Vaccination Progess in Rich Countries vs. Middle Income Countries:**
#
# Comparing daily vaccination rates in some of the richest countries in the world (G8 countries)

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=usa_vac['date'], y=usa_vac['daily_vaccinations'], mode='lines+markers', name='USA'))
fig.add_trace(go.Scatter(x=ita_vac['date'],y=ita_vac['daily_vaccinations'], mode='lines+markers', name='Italy'))
fig.add_trace(go.Scatter(x=rus_vac['date'],y=rus_vac['daily_vaccinations'], mode='lines+markers', name='Russia'))
fig.add_trace(go.Scatter(x=fra_vac['date'],y=fra_vac['daily_vaccinations'], mode='lines+markers', name='France'))
fig.add_trace(go.Scatter(x=ger_vac['date'], y=ger_vac['daily_vaccinations'], mode='lines+markers', name='Germany'))
fig.add_trace(go.Scatter(x=jpn_vac['date'],y=jpn_vac['daily_vaccinations'], mode='lines+markers', name='Japan'))
fig.add_trace(go.Scatter(x=can_vac['date'],y=can_vac['daily_vaccinations'], mode='lines+markers', name='Canada'))
fig.add_trace(go.Scatter(x=uk_vac['date'],y=uk_vac['daily_vaccinations'], mode='lines+markers', name='UK'))
fig.update_layout(title='Comparison of Daily Vaccinations in G8 Countries', height=500)
fig.show()

# %% [markdown]
# Comparing daily vaccination rates in middle income countries

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=pak_vac['date'], y=pak_vac['daily_vaccinations'], mode='lines+markers', name='Pakistan'))
fig.add_trace(go.Scatter(x=ind_vac['date'],y=ind_vac['daily_vaccinations'], mode='lines+markers', name='India'))
fig.add_trace(go.Scatter(x=ino_vac['date'],y=ino_vac['daily_vaccinations'], mode='lines+markers', name='Indonesia'))
fig.add_trace(go.Scatter(x=mal_vac['date'],y=mal_vac['daily_vaccinations'], mode='lines+markers', name='Malaysia'))
fig.add_trace(go.Scatter(x=nig_vac['date'], y=nig_vac['daily_vaccinations'], mode='lines+markers', name='Nigeria'))
fig.add_trace(go.Scatter(x=phi_vac['date'],y=phi_vac['daily_vaccinations'], mode='lines+markers', name='Phillipines'))
fig.add_trace(go.Scatter(x=ban_vac['date'],y=ban_vac['daily_vaccinations'], mode='lines+markers', name='Bangladesh'))
fig.add_trace(go.Scatter(x=vie_vac['date'],y=vie_vac['daily_vaccinations'], mode='lines+markers', name='Vietnam'))
fig.update_layout(title='Comparison of Daily Vaccinations in 8 Middle Income Countries', height=500)
fig.show()

# %%
tot_vac_usa = usa_vac['total_vaccinations'].max()
tot_vac_uk = uk_vac['total_vaccinations'].max()
tot_vac_ita = ita_vac['total_vaccinations'].max()
tot_vac_fra = fra_vac['total_vaccinations'].max()
tot_vac_jpn = jpn_vac['total_vaccinations'].max()
tot_vac_rus = rus_vac['total_vaccinations'].max()
tot_vac_can = can_vac['total_vaccinations'].max()
tot_vac_ger = ger_vac['total_vaccinations'].max()
tot_vac_pak = pak_vac['total_vaccinations'].max()
tot_vac_ind = ind_vac['total_vaccinations'].max()
tot_vac_ino = ino_vac['total_vaccinations'].max()
tot_vac_mal = mal_vac['total_vaccinations'].max()
tot_vac_vie = vie_vac['total_vaccinations'].max()
tot_vac_ban = ban_vac['total_vaccinations'].max()
tot_vac_nig = nig_vac['total_vaccinations'].max()
tot_vac_phi = phi_vac['total_vaccinations'].max()

# %% [markdown]
# Comparing total vaccine doses administered by each of the G8 countries

# %%
fig = go.Figure()
fig.add_trace(go.Bar(x=usa_vac['country'], y=[tot_vac_usa], showlegend=False))
fig.add_trace(go.Bar(x=uk_vac['country'], y=[tot_vac_uk], showlegend=False))
fig.add_trace(go.Bar(x=ita_vac['country'], y=[tot_vac_ita], showlegend=False))
fig.add_trace(go.Bar(x=fra_vac['country'], y=[tot_vac_fra], showlegend=False))
fig.add_trace(go.Bar(x=jpn_vac['country'], y=[tot_vac_jpn], showlegend=False))
fig.add_trace(go.Bar(x=rus_vac['country'], y=[tot_vac_rus], showlegend=False))
fig.add_trace(go.Bar(x=can_vac['country'], y=[tot_vac_can], showlegend=False))
fig.add_trace(go.Bar(x=ger_vac['country'], y=[tot_vac_ger], showlegend=False))

fig.update_layout(title='Total Vaccines Administered in G8 Countries')
fig.show()

# %% [markdown]
# Comparing total vaccine doses administered by each of the 8 middle income countries

# %%
fig = go.Figure()
fig.add_trace(go.Bar(x=pak_vac['country'], y=[tot_vac_pak], showlegend=False))
fig.add_trace(go.Bar(x=ind_vac['country'], y=[tot_vac_ind], showlegend=False))
fig.add_trace(go.Bar(x=ino_vac['country'], y=[tot_vac_ino], showlegend=False))
fig.add_trace(go.Bar(x=phi_vac['country'], y=[tot_vac_phi], showlegend=False))
fig.add_trace(go.Bar(x=mal_vac['country'], y=[tot_vac_mal], showlegend=False))
fig.add_trace(go.Bar(x=vie_vac['country'], y=[tot_vac_vie], showlegend=False))
fig.add_trace(go.Bar(x=nig_vac['country'], y=[tot_vac_nig], showlegend=False))
fig.add_trace(go.Bar(x=ban_vac['country'], y=[tot_vac_ban], showlegend=False))

fig.update_layout(title='Total Vaccines Administered in 8 Middle Income Countries')
fig.show()

# %% [markdown]
# Plotting them together will paint a better picture

# %%
fig = go.Figure()
fig.add_trace(go.Bar(y=usa_vac['country'], x=[tot_vac_usa], showlegend=False, orientation='h'))
fig.add_trace(go.Bar(y=uk_vac['country'], x=[tot_vac_uk], showlegend=False, orientation='h'))
fig.add_trace(go.Bar(y=ita_vac['country'], x=[tot_vac_ita], showlegend=False, orientation='h'))
fig.add_trace(go.Bar(y=fra_vac['country'], x=[tot_vac_fra], showlegend=False, orientation='h'))
fig.add_trace(go.Bar(y=jpn_vac['country'], x=[tot_vac_jpn], showlegend=False, orientation='h'))
fig.add_trace(go.Bar(y=rus_vac['country'], x=[tot_vac_rus], showlegend=False, orientation='h'))
fig.add_trace(go.Bar(y=can_vac['country'], x=[tot_vac_can], showlegend=False, orientation='h'))
fig.add_trace(go.Bar(y=ger_vac['country'], x=[tot_vac_ger], showlegend=False, orientation='h'))
fig.add_trace(go.Bar(y=pak_vac['country'], x=[tot_vac_pak], showlegend=False, orientation='h'))
fig.add_trace(go.Bar(y=ind_vac['country'], x=[tot_vac_ind], showlegend=False, orientation='h'))
fig.add_trace(go.Bar(y=ino_vac['country'], x=[tot_vac_ino], showlegend=False, orientation='h'))
fig.add_trace(go.Bar(y=phi_vac['country'], x=[tot_vac_phi], showlegend=False, orientation='h'))
fig.add_trace(go.Bar(y=mal_vac['country'], x=[tot_vac_mal], showlegend=False, orientation='h'))
fig.add_trace(go.Bar(y=vie_vac['country'], x=[tot_vac_vie], showlegend=False, orientation='h'))
fig.add_trace(go.Bar(y=nig_vac['country'], x=[tot_vac_nig], showlegend=False, orientation='h'))
fig.add_trace(go.Bar(y=ban_vac['country'], x=[tot_vac_ban], showlegend=False, orientation='h'))

fig.update_layout(title='Comparison of Total Vaccines Administered in G8  and 8 Middle Income Countries', height=500)
fig.show()

# %% [markdown]
# Barring India, which is the largest producer of vaccines worldwide, the middle income countries are generally slow in administering vaccines to their population

# %% [markdown]
# **Fully Vaccinated People vs. Total Population:**
#
# Comparing the number of fully vaccinated people to the total population

# %%
pop_usa = pop_data[pop_data['Country/Region']=='USA']
pop_uk = pop_data[pop_data['Country/Region'] == 'UK']
pop_italy = pop_data[pop_data['Country/Region'] == 'Italy']
pop_france = pop_data[pop_data['Country/Region'] == 'France']
pop_germany = pop_data[pop_data['Country/Region'] == 'Germany']
pop_canada = pop_data[pop_data['Country/Region'] == 'Canada']
pop_japan = pop_data[pop_data['Country/Region'] == 'Japan']
pop_russia = pop_data[pop_data['Country/Region'] == 'Russia']

pop_pak = pop_data[pop_data['Country/Region']=='Pakistan']
pop_ind = pop_data[pop_data['Country/Region'] == 'India']
pop_ino = pop_data[pop_data['Country/Region'] == 'Indonesia']
pop_mal = pop_data[pop_data['Country/Region'] == 'Malaysia']
pop_vie = pop_data[pop_data['Country/Region'] == 'Vietnam']
pop_egy = pop_data[pop_data['Country/Region'] == 'Egypt']
pop_phi = pop_data[pop_data['Country/Region'] == 'Phillipines']
pop_ban= pop_data[pop_data['Country/Region'] == 'Bangladesh']
pop_nig = pop_data[pop_data['Country/Region'] == 'Nigeria']

# %%
pop_usa = pop_usa[['Country/Region', 'Population']]
pop_uk = pop_uk[['Country/Region', 'Population']]
pop_italy = pop_italy[['Country/Region', 'Population']]
pop_france = pop_france[['Country/Region', 'Population']]
pop_germany = pop_germany[['Country/Region', 'Population']]
pop_canada = pop_canada[['Country/Region', 'Population']]
pop_japan = pop_japan[['Country/Region', 'Population']]
pop_russia = pop_russia[['Country/Region', 'Population']]

pop_pak = pop_pak[['Country/Region', 'Population']]
pop_ind = pop_ind[['Country/Region', 'Population']]
pop_ino = pop_ino[['Country/Region', 'Population']]
pop_mal = pop_mal[['Country/Region', 'Population']]
pop_vie = pop_vie[['Country/Region', 'Population']]
pop_phi = pop_phi[['Country/Region', 'Population']]
pop_egy = pop_egy[['Country/Region', 'Population']]
pop_ban = pop_ban[['Country/Region', 'Population']]
pop_nig = pop_nig[['Country/Region', 'Population']]

# %%
us_vac = usa_vac['people_fully_vaccinated'].max()
eng_vac = uk_vac['people_fully_vaccinated'].max()
italy_vac = ita_vac['people_fully_vaccinated'].max()
germany_vac = ger_vac['people_fully_vaccinated'].max()
canada_vac = can_vac['people_fully_vaccinated'].max()
japan_vac = jpn_vac['people_fully_vaccinated'].max()
russia_vac = rus_vac['people_fully_vaccinated'].max()
france_vac = fra_vac['people_fully_vaccinated'].max()

pakistan_vac = pak_vac['people_fully_vaccinated'].max()
india_vac = ind_vac['people_fully_vaccinated'].max()
indonesia_vac = ino_vac['people_fully_vaccinated'].max()
malaysia_vac = mal_vac['people_fully_vaccinated'].max()
phillipines_vac = phi_vac['people_fully_vaccinated'].max()
egypt_vac = egy_vac['people_fully_vaccinated'].max()
bangladesh_vac = ban_vac['people_fully_vaccinated'].max()
vietnam_vac = vie_vac['people_fully_vaccinated'].max()
nigeria_vac = nig_vac['people_fully_vaccinated'].max()

# %%
pop_usa['us_vac'] = us_vac
pop_uk['eng_vac'] = eng_vac
pop_italy['italy_vac'] = italy_vac
pop_germany['germany_vac'] = germany_vac
pop_france['france_vac'] = france_vac
pop_canada['canada_vac'] = canada_vac
pop_japan['japan_vac'] = japan_vac
pop_russia['russia_vac'] = russia_vac

pop_pak['pakistan_vac'] = pakistan_vac
pop_ind['india_vac'] = india_vac
pop_ino['indonesia_vac'] = indonesia_vac
pop_mal['malaysia_vac'] = malaysia_vac
pop_vie['vietnam_vac'] = vietnam_vac
pop_phi['phillipines_vac'] = phillipines_vac
pop_egy['egypt_vac'] = egypt_vac
pop_ban['bangladesh_vac'] = bangladesh_vac
pop_nig['nigeria_vac'] = nigeria_vac

# %% [markdown]
# Comparing vaccination rates of the countries with their respective population numbers

# %%
anchos=0.2
fig = go.Figure()
fig.add_trace(go.Bar(x=pop_usa['Country/Region'], y=pop_usa['Population'], width=anchos, name='Population', marker_color='blue'))
fig.add_trace(go.Bar(x=pop_usa['Country/Region'], y=pop_usa['us_vac'], width=anchos, name='Fully Vaccinated', offset=0.0005, marker_color='red'))
fig.add_trace(go.Bar(x=pop_uk['Country/Region'], y=pop_uk['Population'],width=anchos, marker_color='blue',showlegend=False))
fig.add_trace(go.Bar(x=pop_uk['Country/Region'], y=pop_uk['eng_vac'], width=anchos, offset=0.0005, marker_color='red',showlegend=False))

fig.add_trace(go.Bar(x=pop_italy['Country/Region'], y=pop_italy['Population'], width=anchos, marker_color='blue',showlegend=False))
fig.add_trace(go.Bar(x=pop_italy['Country/Region'], y=pop_italy['italy_vac'], width=anchos, offset=0.0005, marker_color='red',showlegend=False))
fig.add_trace(go.Bar(x=pop_germany['Country/Region'], y=pop_germany['Population'],width=anchos, marker_color= 'blue',showlegend=False))
fig.add_trace(go.Bar(x=pop_germany['Country/Region'], y=pop_germany['germany_vac'], width=anchos, offset=0.0005, marker_color='red',showlegend=False))

fig.add_trace(go.Bar(x=pop_france['Country/Region'], y=pop_france['Population'], width=anchos, marker_color='blue',showlegend=False))
fig.add_trace(go.Bar(x=pop_france['Country/Region'], y=pop_france['france_vac'], width=anchos,offset=0.0005, marker_color='red',showlegend=False))
fig.add_trace(go.Bar(x=pop_canada['Country/Region'], y=pop_canada['Population'],width=anchos,marker_color='blue',showlegend=False))
fig.add_trace(go.Bar(x=pop_canada['Country/Region'], y=pop_canada['canada_vac'], width=anchos, offset=0.0005,marker_color='red',showlegend=False))

fig.add_trace(go.Bar(x=pop_japan['Country/Region'], y=pop_japan['Population'], width=anchos, marker_color='blue',showlegend=False))
fig.add_trace(go.Bar(x=pop_japan['Country/Region'], y=pop_japan['japan_vac'], width=anchos, offset=0.0005, marker_color='red',showlegend=False))
fig.add_trace(go.Bar(x=pop_russia['Country/Region'], y=pop_russia['Population'],width=anchos,marker_color='blue',showlegend=False))
fig.add_trace(go.Bar(x=pop_russia['Country/Region'], y=pop_russia['russia_vac'], width=anchos, offset=0.0005,marker_color='red',showlegend=False))

fig.update_layout(title='Total Population Vs. Fully Vaccinated Population in G8 Countries', barmode='overlay')
fig.show()

# %%
anchos=0.2
fig = go.Figure()
fig.add_trace(go.Bar(x=pop_pak['Country/Region'], y=pop_pak['Population'], width=anchos, name='Population', marker_color='blue'))
fig.add_trace(go.Bar(x=pop_pak['Country/Region'], y=pop_pak['pakistan_vac'], width=anchos, name='Fully Vaccinated', offset=0.0005, marker_color='red'))
fig.add_trace(go.Bar(x=pop_ind['Country/Region'], y=pop_ind['Population'],width=anchos, marker_color='blue', showlegend=False))
fig.add_trace(go.Bar(x=pop_ind['Country/Region'], y=pop_ind['india_vac'], width=anchos, offset=0.0005, marker_color='red', showlegend=False))

fig.add_trace(go.Bar(x=pop_ino['Country/Region'], y=pop_ino['Population'], width=anchos, marker_color='blue', showlegend=False))
fig.add_trace(go.Bar(x=pop_ino['Country/Region'], y=pop_ino['indonesia_vac'], width=anchos, offset=0.0005, marker_color='red',showlegend=False))
fig.add_trace(go.Bar(x=pop_mal['Country/Region'], y=pop_mal['Population'],width=anchos, marker_color= 'blue',showlegend=False))
fig.add_trace(go.Bar(x=pop_mal['Country/Region'], y=pop_mal['malaysia_vac'], width=anchos, offset=0.0005, marker_color='red',showlegend=False))

fig.add_trace(go.Bar(x=pop_phi['Country/Region'], y=pop_phi['Population'], width=anchos, marker_color='blue',showlegend=False))
fig.add_trace(go.Bar(x=pop_phi['Country/Region'], y=pop_phi['phillipines_vac'], width=anchos,offset=0.0005, marker_color='red',showlegend=False))
fig.add_trace(go.Bar(x=pop_vie['Country/Region'], y=pop_vie['Population'],width=anchos,marker_color='blue',showlegend=False))
fig.add_trace(go.Bar(x=pop_vie['Country/Region'], y=pop_vie['vietnam_vac'], width=anchos, offset=0.0005,marker_color='red',showlegend=False))

fig.add_trace(go.Bar(x=pop_egy['Country/Region'], y=pop_egy['Population'], width=anchos, marker_color='blue',showlegend=False))
fig.add_trace(go.Bar(x=pop_egy['Country/Region'], y=pop_egy['egypt_vac'], width=anchos, offset=0.0005, marker_color='red',showlegend=False))
fig.add_trace(go.Bar(x=pop_ban['Country/Region'], y=pop_ban['Population'],width=anchos,marker_color='blue',showlegend=False))
fig.add_trace(go.Bar(x=pop_ban['Country/Region'], y=pop_ban['bangladesh_vac'], width=anchos, offset=0.0005,marker_color='red',showlegend=False))

fig.add_trace(go.Bar(x=pop_nig['Country/Region'], y=pop_nig['Population'],width=anchos,marker_color='blue',showlegend=False))
fig.add_trace(go.Bar(x=pop_nig['Country/Region'], y=pop_nig['nigeria_vac'], width=anchos, offset=0.0005,marker_color='red',showlegend=False))

fig.update_layout(title='Total Population Vs. Fully Vaccinated Population in 8 Middle Income Countries', barmode='overlay')
fig.show()

# %% [markdown]
# **Vaccine Manufacturers:**
#
# Taking a look at the manufacturers and their contribution to the total vaccination numbers

# %%
vac_manu['date'] = pd.to_datetime(vac_manu['date'])

# %%
vac_mac = vac_manu.groupby(['location', 'vaccine'])['total_vaccinations'].max().reset_index()
vac_mac

# %%
pfizer = vac_mac[vac_mac['vaccine'] == 'Pfizer/BioNTech'].sort_values('total_vaccinations',ascending=False)[:10]
moderna = vac_mac[vac_mac['vaccine'] == 'Moderna'].sort_values('total_vaccinations',ascending=False)[:10]
oxford_astrazeneca = vac_mac[vac_mac['vaccine'] == 'Oxford/AstraZeneca'].sort_values('total_vaccinations',ascending=False)[:10]
JJ = vac_mac[vac_mac['vaccine'] == 'Johnson&Johnson'].sort_values('total_vaccinations',ascending=False)[:10]

# %%
usa_pfizer= pfizer[pfizer['location'] == 'United States']
usa_moderna = moderna[moderna['location'] == 'United States']
usa_JJ = JJ[JJ['location'] == 'United States']

ger_pfizer= pfizer[pfizer['location'] == 'Germany']
ger_moderna= moderna[moderna['location'] == 'Germany']
ger_JJ= JJ[JJ['location'] == 'Germany']
ger_oxford= oxford_astrazeneca[oxford_astrazeneca['location'] == 'Germany']

fra_pfizer= pfizer[pfizer['location'] == 'France']
fra_moderna= moderna[moderna['location'] == 'France']
fra_JJ= JJ[JJ['location'] == 'France']
fra_oxford= oxford_astrazeneca[oxford_astrazeneca['location'] == 'France']

ita_pfizer= pfizer[pfizer['location'] == 'Italy']
ita_moderna= moderna[moderna['location'] == 'Italy']
ita_JJ= JJ[JJ['location'] == 'Italy']
ita_oxford= oxford_astrazeneca[oxford_astrazeneca['location'] == 'Italy']

spa_pfizer= pfizer[pfizer['location'] == 'Spain']
spa_moderna= moderna[moderna['location'] == 'Spain']
spa_JJ= JJ[JJ['location'] == 'Spain']
spa_oxford= oxford_astrazeneca[oxford_astrazeneca['location'] == 'Spain']

jpn_pfizer= pfizer[pfizer['location'] == 'Japan']
jpn_moderna= moderna[moderna['location'] == 'Japan']
jpn_JJ= JJ[JJ['location'] == 'Japan']
jpn_oxford= oxford_astrazeneca[oxford_astrazeneca['location'] == 'Japan']

# %%
fig = go.Figure()
fig.add_trace(go.Bar(x=usa_pfizer['location'], y=usa_pfizer['total_vaccinations'], name='Pfizer/BioNTech', marker_color='blue'))
fig.add_trace(go.Bar(x=usa_moderna['location'], y=usa_moderna['total_vaccinations'], name='Moderna', marker_color='green'))
fig.add_trace(go.Bar(x=usa_JJ['location'], y=usa_JJ['total_vaccinations'],name='Johnson&Johnson', marker_color='red'))

fig.add_trace(go.Bar(x=ger_pfizer['location'], y=ger_pfizer['total_vaccinations'], name='Pfizer/BioNTech', marker_color='blue', showlegend=False))
fig.add_trace(go.Bar(x=ger_moderna['location'], y=ger_moderna['total_vaccinations'], name='Moderna', marker_color='green', showlegend=False))
fig.add_trace(go.Bar(x=ger_JJ['location'], y=ger_JJ['total_vaccinations'], name='Johnson&Johnson', marker_color='red', showlegend=False))
fig.add_trace(go.Bar(x=ger_oxford['location'], y=ger_oxford['total_vaccinations'], name='Oxford/AstraZeneza', marker_color='yellow'))

fig.add_trace(go.Bar(x=fra_pfizer['location'], y=fra_pfizer['total_vaccinations'], name='Pfizer/BioNTech', marker_color='blue', showlegend=False))
fig.add_trace(go.Bar(x=fra_moderna['location'], y=fra_moderna['total_vaccinations'], name='Moderna', marker_color='green',showlegend=False))
fig.add_trace(go.Bar(x=fra_JJ['location'], y=fra_JJ['total_vaccinations'], name='Johnson&Johnson', marker_color='red', showlegend=False))
fig.add_trace(go.Bar(x=fra_oxford['location'], y=fra_oxford['total_vaccinations'], name='Oxford/AstraZeneza', marker_color='yellow', showlegend=False))

fig.add_trace(go.Bar(x=ita_pfizer['location'], y=ita_pfizer['total_vaccinations'], name='Pfizer/BioNTech', marker_color='blue', showlegend=False))
fig.add_trace(go.Bar(x=ita_moderna['location'], y=ita_moderna['total_vaccinations'], name='Moderna', marker_color='green',showlegend=False))
fig.add_trace(go.Bar(x=ita_JJ['location'], y=ita_JJ['total_vaccinations'], name='Johnson&Johnson', marker_color='red', showlegend=False))
fig.add_trace(go.Bar(x=ita_oxford['location'], y=ita_oxford['total_vaccinations'], name='Oxford/AstraZeneza', marker_color='yellow', showlegend=False))

fig.add_trace(go.Bar(x=spa_pfizer['location'], y=spa_pfizer['total_vaccinations'], name='Pfizer/BioNTech', marker_color='blue', showlegend=False))
fig.add_trace(go.Bar(x=spa_moderna['location'], y=spa_moderna['total_vaccinations'], name='Moderna', marker_color='green',showlegend=False))
fig.add_trace(go.Bar(x=spa_JJ['location'], y=spa_JJ['total_vaccinations'], name='Johnson&Johnson', marker_color='red', showlegend=False))
fig.add_trace(go.Bar(x=spa_oxford['location'], y=spa_oxford['total_vaccinations'], name='Oxford/AstraZeneza', marker_color='yellow', showlegend=False))

fig.add_trace(go.Bar(x=jpn_pfizer['location'], y=jpn_pfizer['total_vaccinations'], name='Pfizer/BioNTech', marker_color='blue', showlegend=False))
fig.add_trace(go.Bar(x=jpn_moderna['location'], y=jpn_moderna['total_vaccinations'], name='Moderna', marker_color='green',showlegend=False))
fig.add_trace(go.Bar(x=jpn_JJ['location'], y=jpn_JJ['total_vaccinations'], name='Johnson&Johnson', marker_color='red', showlegend=False))
fig.add_trace(go.Bar(x=jpn_oxford['location'], y=jpn_oxford['total_vaccinations'], name='Oxford/AstraZeneza', marker_color='yellow', showlegend=False))

fig.update_layout(title = 'Share of Vaccine Manufacturers in Total Vaccines Administered',barmode='stack')
fig.show()

# %% [markdown]
# Most of the first world countries used Pfizer/BioNTech vaccine - which was the first vaccine to be announced - to vaccinate their population

# %%
vac_mac_2 = vac_mac.groupby('vaccine')['total_vaccinations'].sum().reset_index()

# %%
fig = px.pie(vac_mac_2, values='total_vaccinations', names='vaccine')
fig.show()

# %% [markdown]
# This pie chart also shows that the Pfizer/BioNTech vaccine takes the major share of the total vaccines administered followed by Moderna and Oxford/AstraZeneza
