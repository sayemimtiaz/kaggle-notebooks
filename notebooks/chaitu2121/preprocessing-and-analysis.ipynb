# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df=pd.read_csv('/kaggle/input/anime-recommendations-database/anime.csv')
df.sample(5)

# %%
df['type'].value_counts()

# %% [markdown]
# **Preprocessing**

# %%
df.shape

# %% [markdown]
# **Exploratory Data Analysis**

# %%
df.describe()

# %%
df1=pd.read_csv('/kaggle/input/anime-recommendations-database/rating.csv')

# %%
df1.sample(5)

# %%
df[df['anime_id']==10165]

# %% [markdown]
# **We can observe here that the ratings provides by each user for a particular anime is in the range  of 1 to 10 we also saw that -1 is not the correct value and can be replaced with the cummulative rating which is provided in the anime.csv file**

# %%
df1['rating'].value_counts()

# %%
df['type'].value_counts()

# %% [markdown]
# **We will be looking into the type each anime belongs to**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(df['type'])

# %% [markdown]
# **We can observe that there are more anime shows related to tv**

# %%
sns.displot(df['rating'])

# %% [markdown]
# **majority rating lies between 6 and 8**

# %%
sns.displot(df['rating'],kde=True)

# %% [markdown]
# **Here we can observe the skewness**

# %%
df.dtypes

# %%
mr=df.loc[:,['anime_id','rating','members']]
mr

# %% [markdown]
# ***Here we can observe rating and members are not object attributes we will check the correlation with anime_id***

# %%
mr1=mr.corr()

# %%
sns.heatmap(mr1)

# %% [markdown]
# ***The important points to be noted here are rating id positiveky correlated with members**

# %%
d=df1.corr()
sns.heatmap(d)

# %%
plt.scatter(x=df['members'],y=df['rating'])
plt.show()

# %%
cnt=pd.DataFrame(df['type'].value_counts())
cnt

# %%
cnt.plot.pie(y='type')

# %% [markdown]
# **In this pie chart we can see that the type of anime is evenly divide among ova,movie,tv**

# %%
plt.scatter(df['rating'],df['members'],s=df['rating']**2,alpha=0.8)

# %% [markdown]
# **THE IMPORTANT POINT TO BE NOTED HERE IS ANIME WITH HIGH VIEWERS HAS MORE RATING**

# %% [markdown]
# ***Cummulative frequency analysis***

# %%
df['rating'].mode()

# %%
df['rating'].mean()

# %%
l=df['members'].max()
df[df['members']==l]

# %% [markdown]
# **We can observe Death Note is the most popular anime with highest no of users**

# %%
l=df['members'].values
l.sort()
l=l[::-1]
f=l[:5]

# %%
m={}
for i in f:
    g=df[df['members']==i]
    m[str(g.loc[:,'name'])]=g.loc[:,'members']
m

# %%
df.sort_values('members',ascending=False)

# %% [markdown]
# **We can check top 5 animes with most users.**
