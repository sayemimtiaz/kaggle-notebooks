# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv("/kaggle/input/voicegender/voice.csv")
L = LabelEncoder()

# %%
df.head()

# %%
df.isnull().sum()

# %%
df["label"] = L.fit_transform(df["label"])

# %%
x = df.drop("label",axis="columns")

# %%
x

# %%
y = df["label"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
#x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators=500)

# %%
model.fit(x_train,y_train)

# %%
# %%time
model.score(x_test,y_test)

# %%
x_test #20%

# %%
y_test

# %%
result=model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test,result)

# %%
cm

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.heatmap(cm,annot=True)
plt.xticks([0,1],["female","male"],color="red")
plt.yticks([0,1],["female","male"],color="red")
plt.xlabel("actual data",color="blue")
plt.ylabel("predicted data",color="blue")
