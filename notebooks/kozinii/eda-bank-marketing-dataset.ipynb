# %% [markdown]
# 1) ОЗНАКОМИЛСЯ

# %%
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os

    
# Any results you write to the current directory are saved as output.

# %% [markdown]
# Подключите необходимые библиотеки.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(10, 8)}); # you can change this if needed

# %% [markdown]
# Загрузите данные. Они находятся в директории input.

# %%
df = pd.read_csv('../input/bank-additional-full.csv', sep=';')
df.head()

# %% [markdown]
# Каков средний возраст холостых/незамужних клиентов?

# %%
df[df['marital'] != 'married']['age'].mean()

# %% [markdown]
# В какой день недели (признак **day_of_week**) чаще всего звонили клиентам, отказавшимся от депозита?

# %%
df['day_of_week'].value_counts().idxmax()

# %% [markdown]
# Постройте инфографику по признакам **marital** и **y**. Какие выводы можно сделать?

# %%
df.groupby('marital')['y'].value_counts().plot(kind='bar')

# %% [markdown]
# Замужние чаще просят о кредите, незамужние чаще его получают.

# %% [markdown]
# Имеется ли связь между наличием кредита (**default**) у клиента и результатом? Постройте инфографику.

# %%
from scipy.stats import chi2_contingency, fisher_exact
chi2_contingency(pd.crosstab(df['default'], df['y']))

# %% [markdown]
# Визуализируйте информацию об уровне образования в зависимости от среднего возраста. Есть ли статистически значимая взаимосвязь между ними?

# %%
df.groupby('education')['age'].mean().plot(kind = 'bar')

# %% [markdown]
# Что можно сказать о связи между длительностью контакта (признак **duration**) и возрастом клиента? Найдите коэффициент корреляции.

# %%
from scipy.stats import pointbiserialr
pointbiserialr(df['duration'], df['age'])

# %% [markdown]
# Коэффициент корреляции достаточно мал, следовательно величины не зависят друг от друга

# %% [markdown]
# Как связаны признаки **education** и **housing**?

# %%
df.groupby('education')['housing'].value_counts(normalize = True).plot(kind='bar')

# %% [markdown]
# Более образованные немного чаще имеют ипотеку. P-value показывает, что существует статистическаая зависимость

# %% [markdown]
# Какие ещё инсайты можно найти в имеющихся данных? Творческое задание.

# %%
new_values = {'no':0,'yes':1}
df['new_ans'] = df['y'].map(new_values)
df.info()

# %%
numeric = ['age','duration','campaign','pdays','previous','poutcome','emp.var.rate','cons.price.idx','euribor3m','nr.employed','new_ans']
sns.pairplot(df[numeric]);

# %%
df[numeric].corr(method='spearman')

# %%
sns.heatmap(df[numeric].corr(method='spearman'));

# %% [markdown]
# Из приведенного выше следует, что значительное влияние на итоговый результат оказывают атрибуты "duration" и "previous"(Я, правда, не знаю, насколько корректна корреляция Спирмена для связи булевых и численных значений). Также существует статистическая зависимость между атрибутами социального и экономического контекста
