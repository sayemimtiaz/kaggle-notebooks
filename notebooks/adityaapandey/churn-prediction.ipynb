# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as ex
import plotly.graph_objs as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots
import plotly.offline as pyo
pyo.init_notebook_mode()

# %%
df = pd.read_csv('../input/credit-card-customers/BankChurners.csv')

# %%
df.head()

# %%
df.shape

# %%
df.describe()

# %%
df.isnull().sum()

# %%
df.drop(['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1', 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
       axis = 1, inplace = True)

# %%
df.head()

# %%
df.columns

# %%
df.dtypes

# %%
fig = make_subplots(rows=2, cols=1)

tr1=go.Box(x=df['Customer_Age'],name='Age Box Plot',boxmean=True)
tr2=go.Histogram(x=df['Customer_Age'],name='Age Histogram')

fig.add_trace(tr1,row=1,col=1)
fig.add_trace(tr2,row=2,col=1)

fig.update_layout(height=700, width=1200, title_text="Distribution of Customer Ages")
fig.show()

# %%
plt.figure(figsize = (20,10))
sns.countplot(data = df, x = df["Marital_Status"], hue = "Attrition_Flag")

# %%
ex.pie(df, names = 'Gender', title = 'Gender Proportion')

# %%
ex.pie(df, names = 'Attrition_Flag', title = "Customers Type")

# %%
ex.pie(df, names = 'Education_Level', title = "Education Level Proportion")

# %%
ex.pie(df, names = 'Marital_Status', title = 'Marital status')

# %%
ex.pie(df, names = 'Income_Category', title = 'Income')

# %%
df.head()

# %%
df = df.replace({"Existing Customer" : 0, "Attrited Customer": 1})
df = df.replace({"M" : 0, "F" : 1})
df = pd.concat([df, pd.get_dummies(df['Education_Level']).drop(columns=['Unknown'])],axis=1)
df = pd.concat([df,pd.get_dummies(df['Income_Category']).drop(columns=['Unknown'])],axis=1)
df = pd.concat([df,pd.get_dummies(df['Marital_Status']).drop(columns=['Unknown'])],axis=1)
df = pd.concat([df,pd.get_dummies(df['Card_Category']).drop(columns=['Platinum'])],axis=1)
df.drop(columns = ['Education_Level','Income_Category','Marital_Status','Card_Category','CLIENTNUM'],inplace=True)

# %%
df.head()

# %%
plt.figure(figsize = (20,30))
sns.heatmap(df.corr(), annot = True, cmap="YlGnBu")

# %%
df.drop(["Avg_Open_To_Buy", ], axis = 1, inplace = True)

# %%
df.head()

# %%
x = df.drop(["Attrition_Flag"],axis = 1)
y = df["Attrition_Flag"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(x_train, y_train)
rf_pred = rf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score

# %%
rf.score(x_train, y_train)

# %%
from sklearn import metrics
print(metrics.accuracy_score(y_test, rf_pred))
print(metrics.precision_score(y_test, rf_pred))
print(metrics.recall_score(y_test, rf_pred))

# %%
import pickle
filename = "finalize_model.pkl"
pickle.dump(rf, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(x_test, y_test)
print(result)
