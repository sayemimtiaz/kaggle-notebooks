# %% [markdown]
# ###**Downloading the dataset from Dropbox**

# %%
#Please run this cell in Google Co-Lab

# !wget https://www.dropbox.com/s/buegrvj58j3obiz/datasets_894_813759_2019.csv

# %% [markdown]
# ###**Importing Required Libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ###**Loading and Analyzing the dataset**

# %%
df = pd.read_csv("datasets_894_813759_2019.csv")
df.head()

# %%
df.shape #Checking the shape of the dataframe

# %%
df.describe()

# %%
df.info()

# %%
df.isnull().sum()

# %% [markdown]
# ###**Exploratory Data Analysis**

# %%
df.head(2)

# %%
print('The maximum score achieved is:',df.Score.max())

# %%
fig = px.bar(df, x='Country or region', y='Score')
fig.show()

# %%
fig = px.bar(df, x='Country or region', y='Score',
             hover_data=['Healthy life expectancy', 'Social support'], color='Healthy life expectancy')
fig.show()

# %% [markdown]
# ####**Scatter Plot**

# %%
px.scatter(df, x="GDP per capita", y="Healthy life expectancy")

# %%
df_new = df.head(10)
px.scatter(df_new, x="GDP per capita", y="Healthy life expectancy", color="Country or region")

# %%
df_new = df.tail(10)
px.scatter(df_new, x="GDP per capita", y="Healthy life expectancy", color="Country or region", size='Perceptions of corruption', size_max=60, hover_name='Country or region')
