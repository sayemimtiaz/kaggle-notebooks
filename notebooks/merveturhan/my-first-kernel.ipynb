# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.

# %%
data = pd.read_csv('../input/WA_Fn-UseC_-Telco-Customer-Churn.csv') #importing data
data.head() #show to only 5 rows

# %%
data.describe(include='all')

# %%
data.columns #show to features

# %%
f,ax = plt.subplots(figsize=(9,9)) #If we want to set figure size,we can use this code 
sns.heatmap(data.corr(), annot=True , linewidths = 1.5 ,fmt = '.1f',ax=ax) #fmt= how many digits to show after zero 
plt.show() #annot = True defines whether correlation table includes digits or not

# %%
data.tenure.plot(kind = 'line', color = 'g',label = 'tenure',linewidth=1,alpha = 0.5,grid = True,linestyle = ':') #you can change to kind from hist or scatter
data.MonthlyCharges.plot(color = 'r',label = 'MonthlyCharges',linewidth=1, alpha = 0.5,grid = True,linestyle = '-.')

# %%
data.plot(subplots = True)
plt.show()

# %%
data.MonthlyCharges.plot(kind = 'hist',bins = 50,figsize = (12,12),range=(20,110),normed = True)  #bins defines number of bar; normed=normalization
plt.show()

# %%
data.MonthlyCharges.plot(kind = 'hist',bins = 50,figsize = (12,12),range=(20,110),normed = True,cumulative = True)  
plt.show()

# %%
x = data['PhoneService'] == "No"
data[x]

# %%
data.Partner[data.tenure<30]

# %%
data[np.logical_and(data['MonthlyCharges']>50, data['tenure']>10)]   #data içinden veri çekme

# %%
# For pandas we can achieve index and value
for index,value in data[['tenure']][0:1].iterrows():
    print(index," : ",value)

# %%
data.shape

# %%
print(data['InternetService'].value_counts(dropna =False))    #dropna=False = to show Nan

# %%
Mean_tenure = sum(data.tenure)/len(data.tenure)
data["tenure_level"] = ["high" if i > Mean_tenure else "low" for i in data.tenure]
data.loc[:5,["tenure_level","tenure"]]

# %%
data.boxplot(column='MonthlyCharges',by ='gender')

# %%
data_new = data.head()   
data_new
melted = pd.melt(frame=data_new,id_vars = 'customerID', value_vars= ['MonthlyCharges','tenure'])
melted

# %%
melted.pivot(index = 'customerID', columns = 'variable',values='value')

# %%
data1 = data.head()
data2= data.tail()
conc_data_row = pd.concat([data1,data2],axis =0,ignore_index =True) # axis = 0 : adds dataframes in row
conc_data_row

# %%
data1 = data['tenure'].head()
data2= data['PhoneService'].head()
conc_data_col = pd.concat([data1,data2],axis =1) # combine to columns
conc_data_col

# %%
data.dtypes

# %%
data['SeniorCitizen '] = data['SeniorCitizen'].astype('float64')

# %%
data.dtypes

# %%
data.info()

# %%
data2 = data.head()
date_list = ["1992-01-10","1992-02-10","1992-03-10","1993-03-15","1993-03-16"]
datetime_object = pd.to_datetime(date_list)
data2["date"] = datetime_object
data2= data2.set_index("date")
data2

# %%
data2.resample("A").mean()  #A : year M: mount

# %%
data2.resample("M").mean()  #A : year M: mount

# %%
data2.resample("M").first().interpolate("linear")

# %%
data2.resample("M").mean().interpolate("linear")

# %%
def div(n):
    return n**2
data2.tenure.apply(div)

# %%
data2.tenure.apply(lambda n : n/2)

# %%
data1 = data.set_index(["gender","InternetService"]) 
data1.head(100)

# %%
data.groupby("gender").mean()
