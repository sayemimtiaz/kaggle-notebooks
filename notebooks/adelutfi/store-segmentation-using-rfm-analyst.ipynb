# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../input/iowa-liquor-sales/Iowa_Liquor_Sales.csv')

# %%
df.head()

# %%
df.info()

# %%
df['Item Description'].value_counts()

# %%
df['Store Name'].value_counts()

# %%
df1 = df[df['Item Description'] == 'Black Velvet']
df1

# %%
df2 = df1[df1['Store Name'] == 'Central City 2']

# %%
df2

# %%
df2.isnull().sum()

# %%
duplicated = df2.duplicated().sum()
if duplicated:
  print('Duplicates rows in dataset are : {}'.format(duplicated))
else:
  print('Dataset contains no duplicate value')

# %%
df2.shape

# %%
df2.info()

# %%
df2['Pack'].value_counts()

# %%
df2['Bottles Sold'].value_counts()

# %%
df2['Vendor Name'].value_counts()

# %%
df2['State Bottle Cost'].value_counts()

# %%
df2['State Bottle Retail'].value_counts()
