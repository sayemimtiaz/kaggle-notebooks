# %%
import numpy as np 
import pandas as pd 
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/kaggle/input/heart-failure-clinical-data/heart_failure_clinical_records_dataset.csv')

# %%
df.head()

# %%
df.isnull().sum() #checking for null values in our data

# %%
df.info()

# %%
df.dtypes

# %%
df['age'] = df['age'].astype(int) #converting age column from float to int

# %%
df.dtypes

# %%
plt.style.use('dark_background')
plt.figure(figsize = (20,7))
df['anaemia'].value_counts().plot.bar(color = 'lime')
plt.title('Checking How many patients have anaemia')
plt.xlabel('No Anaemia v/s Anaemia')
plt.ylabel('Count')
plt.show()

# %%
plt.style.use('dark_background')
plt.figure(figsize = (20,7))
df['diabetes'].value_counts().plot.bar(color = 'lime')
plt.title('Checking How many patients have Diabetes')
plt.xlabel('No Diabetes v/s Diabetes')
plt.ylabel('Count')
plt.show()

# %%
plt.style.use('dark_background')
plt.figure(figsize = (20,7))
df['high_blood_pressure'].value_counts().plot.bar(color = 'lime')
plt.title('Checking How many patients have High Blood Pressure')
plt.xlabel('Low Blood Pressure v/s High Blood Pressure')
plt.ylabel('Count')
plt.show()

# %%
plt.style.use('dark_background')
plt.figure(figsize = (20,7))
df['smoking'].value_counts().plot.bar(color = 'lime')
plt.title('Checking How many patients Smoke')
plt.xlabel('Non-Smokers v/s Smokers')
plt.ylabel('Count')
plt.show()

# %%
plt.style.use('dark_background')
plt.figure(figsize = (20,7))
df['sex'].value_counts().plot.bar(color = 'lime')
plt.title('Checking How many male and female patients are present in our data')
plt.xlabel('Male v/s Female')
plt.ylabel('Count')
plt.show()

# %%
df1 = df.copy()

# %%
df1.head()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix ,accuracy_score,recall_score,precision_score

# %%
X = df1[['age','ejection_fraction','serum_creatinine','serum_sodium','time']]
y = df1['DEATH_EVENT']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 1)

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
#scaler = StandardScaler()
#scaler.fit(X_train)
#X_train = scaler.transform(X_train)
#X_test = scaler.transform(X_test)

# %%
lr = LogisticRegression()
lr.fit(X_train,y_train)
pred = lr.predict(X_test)

# %%
print("Accuracy:",accuracy_score(y_test, pred)*100)
print("Precision:",precision_score(y_test, pred)*100)
print("Recall:",recall_score(y_test, pred)*100)

# %%
user_input1 = [[65,20,2.7,116,8]]
user_pred1 = lr.predict(user_input1)
print(user_pred1)

# %%
from sklearn.svm import SVC
svm = SVC(kernel='linear')
svm.fit(X_train,y_train)
pred = svm.predict(X_test)
acc = accuracy_score(pred,y_test)
print('The accuracy is',acc*100,'%')
