# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
covid=pd.read_csv('../input/corona-virus-report/country_wise_latest.csv')

# %%
covid.head()

# %%
covid.info()

# %%
covid.describe()

# %%
diff=covid['Confirmed']-covid['Recovered']-covid['Deaths']

# %%
diff

# %%
covid.loc[covid['Recovered'].idxmax()]

# %%
covid.loc[covid['Deaths'].idxmax()]

# %%
covid.loc[covid['Confirmed'].idxmax()]

# %%
covid.loc[covid['Confirmed'].idxmin()]

# %%
covid.loc[covid['Deaths'].idxmin()]

# %%
covid.loc[covid['Recovered'].idxmin()]

# %%
covid[covid['Country/Region'].str.contains('Canada')]
covid[covid['Country/Region'].str.contains('Bhutan')]
covid[covid['Country/Region'].str.contains('Western Sahara')] 
covid[covid['Country/Region'].str.contains('Brazil')]
covid[covid['Country/Region'].str.contains('US')]
covid[covid['Country/Region'].str.contains('India')]

# %%
COVIDIMP=covid.iloc[['23','183','19','32','173','79']]

# %%
COVIDIMP

# %%
sns.barplot(x='Country/Region',y='Confirmed',data=COVIDIMP,palette='Set1')

# %%
sns.distplot(covid['Confirmed'],bins=100)

# %%
sns.barplot(x='Country/Region',y='Deaths',data=COVIDIMP)

# %%
Random=covid.sample(n=10)

# %%
sns.barplot(x='Deaths',y='Country/Region',data=Random,palette='winter_r')

# %%
sns.lmplot(x='Confirmed',y='Deaths',data=covid)

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf

# %%
data = dict(
        type = 'choropleth',
        locations = covid['Country/Region'],
        locationmode='country names',
        z = covid['Confirmed'],
        text = covid['Country/Region'],
        colorbar = {'title' : 'COVID COFIRMED CASES'},
      )

# %%
layout = dict(
    title = 'COVID CASES BY COUNTRIES',
    geo = dict(
        showframe = False,
        projection = {'type':'mercator'}
    )
)

# %%
import plotly.graph_objs as go 
choromap = go.Figure(data =[data],layout = layout)
iplot(choromap)

# %%
covid['WHO Region'].nunique()

# %%
sns.set(rc={'figure.figsize':(100,5)})
sns.lineplot(x=covid['Country/Region'],y=covid['1 week % increase'],data=covid)

# %%
grouped=covid.groupby('WHO Region')

# %%
grouped.first()

# %%
covid.loc[covid['1 week change'].idxmax()]

# %%
covid.loc[covid['1 week change'].idxmin()]

# %%
grouped.max()

# %%
grouped.min()

# %%
sns.set(rc={'figure.figsize':(20,20)})
sns.heatmap(data=covid.corr())

# %%
sorted=covid.sort_values(by='Deaths',inplace=False,ascending=False)

# %%
top20=sorted.head(20)

# %%
sns.barplot(x=top20['Deaths'],y=top20['Country/Region'],data=top20)

# %%
sortednew=covid.sort_values(by='Active',inplace=False,ascending=True)

# %%
least20active=sortednew.head(20)

# %%
sns.barplot(y=least20active['Country/Region'],x=least20active['Active'],data=least20active)

# %%
part = covid.iloc[:10,:]
part.plot(style='o-')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# %%
datewisecovid=pd.read_csv('../input/corona-virus-report/day_wise.csv')

# %%
datewisecovid

# %%
ar=datewisecovid.head(20)

# %%
sns.barplot(x=ar['Date'],y=ar['Confirmed'])

# %%
import plotly.express as px

fig=px.line(ar,x="Date",y=["Confirmed","Deaths","Recovered","Active"],title="covid cases w.r.t. date",template="plotly_dark")
fig.show()

# %%
usadata=pd.read_csv('../input/corona-virus-report/usa_county_wise.csv')

# %%
usadata

# %%
data = dict(type = 'choropleth',
            locations = usadata['Province_State'],
            locationmode = 'USA-states',
            colorscale= 'Portland',
            text= usadata['Province_State'],
            z=usadata['Confirmed'],
            colorbar = {'title':'Covid confirmed cases by states'})

# %%
layout = dict(geo = {'scope':'usa'})

# %%
choromap = go.Figure(data = [data],layout = layout)

# %%
iplot(choromap)
