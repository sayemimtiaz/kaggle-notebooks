# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
purchase=pd.read_csv('../input/customer-analytics/Train.csv')

# %%
purchase.head()

# %%
purchase.info()

# %%
purchase.describe()

# %%
purchase['Mode_of_Shipment'].nunique()

# %%
purchase['Warehouse_block'].nunique()

# %%
purchase['Product_importance'].nunique()

# %%
purchase[purchase['Customer_rating']==5].count()

# %%
purchase['Customer_rating'].value_counts()

# %%
purchase['Warehouse_block'].value_counts()

# %%
purchase['Mode_of_Shipment'].value_counts()

# %%
purchase['Gender'].value_counts()

# %%
purchase['Reached.on.Time_Y.N'].value_counts()

# %%
purchase[purchase['Product_importance']=='low'].count()

# %%
purchase[(purchase['Product_importance']=='low')&(purchase['Reached.on.Time_Y.N']==0)].count()

# %%
purchase[(purchase['Mode_of_Shipment']=='Flight')&(purchase['Reached.on.Time_Y.N']==0)].count()

# %%
purchase[(purchase['Gender']=='F')&(purchase['Reached.on.Time_Y.N']==0)].count()

# %%
purchase[(purchase['Gender']=='M')&(purchase['Reached.on.Time_Y.N']==0)].count()

# %% [markdown]
# proportion of females who got their parcels late=2249/5545=0.405
# proportion of males who got their parcels late=2187/5454=0.4009

# %%
purchase[(purchase['Warehouse_block']=='A')&(purchase['Reached.on.Time_Y.N']==0)].count()

# %%
purchase[(purchase['Warehouse_block']=='B')&(purchase['Reached.on.Time_Y.N']==0)].count()

# %%
purchase[(purchase['Warehouse_block']=='C')&(purchase['Reached.on.Time_Y.N']==0)].count()

# %%
purchase[(purchase['Warehouse_block']=='D')&(purchase['Reached.on.Time_Y.N']==0)].count()

# %%
purchase[(purchase['Warehouse_block']=='F')&(purchase['Reached.on.Time_Y.N']==0)].count()

# %% [markdown]
# #proportions of delay caused by respective warehouses--
# A=758/1833=0.413
# B=729/1833=0.397
# C=739/1833=0.403
# D=738/1834=0.402
# F=1472/3666=0.401
#
# this tells that just by looking at the highest number of late parcels from F one cannot conclude about its efficiency!

# %%
sns.heatmap(purchase.corr(),annot=True,cmap='Pastel1')

# %%
sns.barplot(x='Customer_rating',y='Cost_of_the_Product',palette='viridis',data=purchase,hue='Gender')

# %%
sns.barplot(x='Product_importance',y='Weight_in_gms',palette='icefire',data=purchase)

# %%
sns.barplot(x='Mode_of_Shipment',y='Reached.on.Time_Y.N',data=purchase,hue='Product_importance',palette='ch:s=-.2,r=.6')

# %%
sns.barplot(x='Gender',y='Cost_of_the_Product',data=purchase,palette='rocket')

# %%
sns.barplot(x='Warehouse_block',y='Reached.on.Time_Y.N',data=purchase,palette='Spectral')

# %%
sns.barplot(x='Warehouse_block',y='Weight_in_gms',data=purchase,palette='coolwarm')

# %%
sns.barplot(x='Customer_rating',y='Prior_purchases',data=purchase,palette='PiYG')

# %%
sns.jointplot(x='Weight_in_gms',y='Cost_of_the_Product',data=purchase,kind='hex')

# %%
sns.jointplot(x='Cost_of_the_Product',y='Discount_offered',data=purchase,kind='kde',color='red',fill=True)

# %%
sns.boxplot(x='Mode_of_Shipment',y='Cost_of_the_Product',data=purchase,hue='Gender')

# %%
sns.clustermap(purchase.corr(),annot=True,cmap='cividis')

# %%
plt.figure(figsize=(10,6))
purchase[purchase['Mode_of_Shipment']=='Flight']['Cost_of_the_Product'].hist(alpha=0.5,color='blue',bins=30,label='Flight')
purchase[purchase['Mode_of_Shipment']=='Road']['Cost_of_the_Product'].hist(alpha=0.5,color='red',bins=30,label='Road')
plt.xlabel('COST')
plt.legend()

# %%
from sklearn.linear_model import LogisticRegression

# %%
X=purchase.drop(['Reached.on.Time_Y.N','Warehouse_block','Mode_of_Shipment','Product_importance','Gender'],axis=1)
y=purchase['Reached.on.Time_Y.N']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=101)

# %%
lm=LogisticRegression()

# %%
lml=lm.fit(X_train,y_train)

# %%
predictions = lml.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))

# %% [markdown]
# creating of dummies so as to extract information from the categorical variable doesnt change the accuracy results in my case.

# %%
A=pd.get_dummies(purchase['Mode_of_Shipment'],drop_first=True)
B=pd.get_dummies(purchase['Warehouse_block'],drop_first=True)
C=pd.get_dummies(purchase['Product_importance'],drop_first=True)
D=pd.get_dummies(purchase['Gender'],drop_first=True)

# %%
newp=pd.concat([A,B,C,D,purchase],axis=1)

# %%
X1=newp.drop(['Reached.on.Time_Y.N','Warehouse_block','Mode_of_Shipment','Product_importance','Gender'],axis=1)
y1=newp['Reached.on.Time_Y.N']

# %%
X1_train, X1_test, y1_train, y1_test =train_test_split(X1,y1,test_size=0.30,random_state=101)

# %%
logmodel=LogisticRegression()

# %%
logmodel.fit(X1_train,y1_train)

# %%
pred = logmodel.predict(X1_test)

# %%
print(classification_report(y1_test,predictions))

# %% [markdown]
# The accuracy results show no change even with K nearest neighbors technique
