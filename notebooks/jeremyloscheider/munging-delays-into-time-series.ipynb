# %% [markdown]
# Working with time series and plotting.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib as mpl # visualization
import csv
from datetime import datetime #for time elemetn
from datetime import date

# Input data files are available in the "../input/" directory.

dfli = pd.read_csv("../input/DelayedFlights.csv")

# %% [markdown]
# ### Summarize by carrier and month to generate a time series

# %%
## Structure flight data into data frame and add time component
## wstr = datetime(int(str(dfli.Year), int(dfli.Month), int(dfli.DayofMonth))
## Year, Month and DayofMonth are series, not integers
y = datetime(dfli.Year,dfli.Month,dfli.DayofMonth)

# %%
flight_df.tail()
## Generate time series structure for summarizing by week
sum_weekly = pd.Series(0, pd.date_range('2008-01-01','2008-12-31', freq = 'W'))

# %%
sum_weekly.head()

# %%
## Summarize delays by week and load into sum_weekly
