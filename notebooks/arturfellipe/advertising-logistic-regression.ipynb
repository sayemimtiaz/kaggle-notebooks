# %%
# Python 3 environment
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## INPUT DATA

# %%
advertising = pd.read_csv('/kaggle/input/advertising/advertising.csv')

# %%
advertising.head()

# %%
advertising.describe()

# %%
advertising.info()

# %% [markdown]
# ## Exploratory Data -> Developing

# %%
sns.pairplot(advertising, hue='Clicked on Ad')

# %% [markdown]
# # Chague text columns with numeric info

# %% [markdown]
# # Training Logistic Regression

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(advertising.drop(['Clicked on Ad','Ad Topic Line','City','Country','Timestamp'],axis=1), 
                                                    advertising['Clicked on Ad'], test_size=0.30)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)

# %% [markdown]
# ## Predictions and Evaluations

# %%
predictions = logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,predictions))

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,predictions))
