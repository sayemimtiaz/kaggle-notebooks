# %% [markdown]
# please reference https://github.com/bettersituation/basic/tree/master/PokemonBattle
# (comments in file are not written English, So it would be hard to understand maybe
# but codes are very easy and readable!)
#
#
# Core insight are as follows
#
# (1) most powerful pokemons are Zygarde, Chansey, Blissey, Guzzlord, Wobbuffet, Slacking, Alomomola, Snorlax, Lunala
#     (which means skill, mind, attribute are critical factors which affect pokemon's power)
#
# (2) 10 weakest pokemons are Shuckle, Duskgull, Shedinja, Magikarp, Togepi, Shieldon, Shellder, Nosepass, Diglett, Krabby, Pichu
#
# (3) pokemons which are defeated to Shedinja have low hp. So they cannot last shedinja's attack
#
# (4) generally, psychic type are powerful. a portion of pokemons which have psychic typs with all pokemons is about 6.6%. On the otherhand, within best 50, pokemons which have psychic type make up of about 20%
#
# (5) Also, dark type and dragon type are powerful generally.
#
# (6) generation 2 pokemons are powerful generally.
#
# (7) there exists a trend that height and weight are related to pokemon's power poistiviely.
# But we cannot guarantee more height or more weight means more power.
