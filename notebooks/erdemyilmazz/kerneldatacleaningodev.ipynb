# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
data=pd.read_csv("/kaggle/input/pokemon/pokemon.csv")

# %%
data.head()

# %%
data.columns

# %%
data.info()

# %%
data.type1.value_counts(dropna=False)

# %%
#nan value değerlerini de görebiliyoruz
data.weight_kg.value_counts(dropna=False)

# %% [markdown]
# quartile min max kavramları
# elimizde [7,3,2,5,5,5,6,100,0.001,10000,40000,4] gibi bir liste olsun
# bu listenin min max mean 25% 50% 75% değerlerini görmek için önce bu listeyi dataFrame' e çevirelim. bunun için dataR=pd.DataFrame(dataRandom) komut satırını koşturalım.

# %%
dataRandom=[7,3,2,5,5,5.2,6,100,0.001,10000,40000,4]
dataR=pd.DataFrame(dataRandom)

# %% [markdown]
# describe()metodu ile dataFrame'i inceleyelim. Dikkat ederseniz listede 10 eleman var ve liste sıralı değil. yani liste küçükten büyüğe sıralanmıyor. ancak describe() metodunu koşturduğumuzda %25 %50 %75 değerleri liste sıralandıktan sonra bulunuyor.
#
# Listenin orjinal hali ---->[7,3,2,5,5,5.2,6,100,0.001,10000,40000,4]
# Listenin sıralı hali------>[0.001,2,3,4,5,5,5.2,6,7,100,10000,40000]
#
#
# Bu durumda 50% elemanı bulmak için listenin orjinal halini değil sıralı halini göz önüne almalıyız. Sıralı halde eleman sayısı 12 olduğu için 5 ile 5.2 nin ortalaması olan 5.1 değeri 50% değeri olarak görünür.

# %%
dataR.info()

# %%
dataR.describe()

# %%
dataR.boxplot(column=0)
#data.boxplot(column="sp_attack",by="is_legendary")
plt.show()

# %% [markdown]
# MELT FONKSİYONU

# %%
melted=pd.melt(data, id_vars=["abilities"],value_vars=["against_poison","attack"])
melted.head(20)

# %%
meltedX=pd.melt(data.head(), id_vars="abilities",value_vars=["against_poison","attack"],var_name ="Degisken",value_name="Deger")
meltedX

# %%
#bu satır koşturulduğunda ValueError: Index contains duplicate entries, cannot reshape
#hatası veriyor. sanırım bunun nedeni abilities sütunundaki yineleyen satırlar.
meltedX.pivot(index="abilities",columns="Degisken", values="Deger")

# %% [markdown]
# missing data and test with assert

# %%
data.info()

# %%
data.type2.value_counts(dropna=False)

# %%
data1=pd.read_csv("/kaggle/input/pokemon/pokemon.csv")
data2=pd.read_csv("/kaggle/input/pokemon/pokemon.csv")
#data1=data
print (id(data1))
print (id(data))

# %%
data1.type2.dropna(inplace=True)

# %%
assert data1.type2.notnull().all()

# %%
print(data1.head())
print(data1.type2.head())

# %%
data2.type2.fillna("empty",inplace=True)
data2.type2.head()

# %%
data2.head()

# %%
assert data2.type2.notnull().all()

# %%
#iki yöntem de çalışıyor görünüyor
data2.against_bug.dtypes==float
assert data2.against_bug.dtypes==np.float
