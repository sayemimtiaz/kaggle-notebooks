# %% [markdown]
# # 1. Introduction
#
# **Facebook, the online social networking platform, founded by Mark Zukerberg in 2004.The largest social media platform with more than 2.6 bn monthly active users, globally**.

# %%
import sys                                                                      # Import packages
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import pie, axis, show
# %matplotlib inline                                                              

import warnings                                                                 # Ignore warning related to pandas_profiling
warnings.filterwarnings('ignore') 

pd.set_option('display.max_columns', 100)

# %%
df_fb= pd.read_csv('../input/facebook-data/pseudo_facebook.csv')

# %%
df_fb.head()

# %%
df_fb.tail()

# %%
df_fb.describe()

# %%
df_fb.info()

# %%
df_fb.shape

# %%
df_fb['age'].value_counts()

# %%
df_fb['age_group'] = pd.cut(df_fb['age'].dropna(),[0,19,25,35,45,99],labels=['Less than 18','19-24','25-34','35-44','45+'],include_lowest=True )

# %%
df_fb['age_group'].value_counts()

# %%
fig = plt.subplots()
df_fb['age_group'].value_counts().plot(kind='pie',autopct='%1.1f%%')

# %%
df_fb['gender'].unique()

# %%
df_fb['gender'].describe()

# %%
df_fb['gender'].value_counts()

# %%
fig = plt.subplots()
df_fb['gender'].value_counts().plot(kind='pie',autopct='%1.1f%%')

# %%
df_fb['friend_count'].value_counts()

# %%
sns.barplot(data=df_fb, x='friend_count',y='age_group')

# %%
sns.barplot(df_fb['gender'],df_fb['friend_count'])

# %%
df_fb['likes'].describe()

# %%
df_fb['likes'].value_counts()

# %%
sns.pairplot(data=df_fb, x_vars=['likes'], y_vars='age_group',size=8)

# %%
sns.barplot(df_fb['gender'],df_fb['likes'])

# %%
df_fb.corr()

# %%
sns.heatmap(df_fb.corr(), annot=True)
