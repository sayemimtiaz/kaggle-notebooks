# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from numpy import cov

# %%
df1 = pd.read_csv('../input/heart-attack-analysis-prediction-dataset/heart.csv')
df2 = pd.read_csv('../input/heart-attack-analysis-prediction-dataset/o2Saturation.csv')
df = pd.concat([df1,df2],axis = 1,join='inner')
print(df.shape)
df.head()

# %%
# missing values
df.isna().sum().sum()

# %%
# just exploring datatypes of data
df.info()

# %%
def uniquev(df):
    for i in df.columns:
        print(f'{i} -  {len(df[i].unique())}')
uniquev(df)

# %%
# scatter plot b/w labels and output
def scatp(df):
    for i in df.columns:
        if i!='output':
            sns.catplot(data=df,x='output',hue='output',y = i)
scatp(df)

# %%
#heat map 
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(),linewidths=0.5,annot=True)

# %%
# 3 least correlated labels with output
def least_corr(df):
    l = []
    for i in df.columns:
        if i!='output':
            d = cov(df[i],df['output'])

# %%
d = cov(df['age'],df['output']) 
print(d)
d = [d[i][0] for i in range(len(d))]
d
