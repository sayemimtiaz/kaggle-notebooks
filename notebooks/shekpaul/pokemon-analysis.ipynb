# %% [markdown]
# # The Following link below contains the file named "Pokemon Dashboard".
# ## This Dashoard is created using tableau.

# %% [markdown]
# ### **https://public.tableau.com/views/PokemonDashboard_15924444272590/Dashboard1?:language=en&:display_count=y&:origin=viz_share_link**

# %%
from IPython.display import IFrame
IFrame('https://public.tableau.com/views/PokemonDashboard_15924444272590/Dashboard1?:language=en&:display_count=y&:origin=viz_share_link',
       width=1750, height=1500)
