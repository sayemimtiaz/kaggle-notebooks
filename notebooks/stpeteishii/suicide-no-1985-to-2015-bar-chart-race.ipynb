# %% [markdown]
# # Bar Chart Race of Suicide Rates 1985 to 2015
# * cf. https://www.dexplo.org/bar_chart_race/
# * cf. https://github.com/dexplo/bar_chart_race/

# %%
import sys
# !{sys.executable} -m pip install bar_chart_race

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

import bar_chart_race as bcr
from IPython.display import HTML
import warnings
warnings.filterwarnings("ignore")
from IPython.display import Video

# %% [markdown]
# # Data preparation

# %%
data=pd.read_csv('../input/suicide-rates-overview-1985-to-2016/master.csv')
data

# %%
data.columns

# %%
data0=data[['country', 'year','suicides_no']]
data0=data0.groupby(['country','year'],as_index=False).sum()
data0

# %%
data0.columns

# %%
data0b=data0.copy()
data0b['CountryNo']=1
data0b=data0b.groupby('year').sum()
data0b
# drop 2016 data

# %%
drop=data0[data0['year']==2016].index.tolist()
data0=data0.drop(index=data0.index[drop])

# %% [markdown]
# # Dataframe for Bar Chart Race

# %%
# set double indexes
data1=data0.copy()
data1['year']=data1['year'].apply(lambda x: str(x))
data2=data1.set_index(['year','country'])
data2

# %%
# unsack!!!
data3=data1.set_index(['year','country']).unstack()['suicides_no']
data3

# %%
data4=data3.fillna(0)

# %% [markdown]
# # Bar Chart Race

# %%
df = data4
bcr.bar_chart_race(
    df=df,
    filename='BCR_SuicideNo.mp4',
    orientation='h',
    sort='desc',
    n_bars=20,
    fixed_order=False,
    fixed_max=False,
    steps_per_period=10,
    interpolate_period=False,
    label_bars=True,
    bar_size=.95,
    period_label={'x': .99, 'y': .25, 'ha': 'right', 'va': 'center'},
    #period_fmt='%B %d, %Y',
    period_summary_func=lambda v, r: {'x': .99, 'y': .18,'s': '',
                                      'ha': 'right', 'size': 8, 'family': 'Courier New'},
    #perpendicular_bar_func='median',
    period_length=1000,
    figsize=(5, 3),
    dpi=500,
    cmap='dark24',
    title='Suicide No. 1985 to 2015 - Bar Chart Race',
    title_size=15,
    bar_label_size=7,
    tick_label_size=5,
    shared_fontdict={'color' : '.1'},
    scale='linear',
    writer=None,
    fig=None,
    bar_kwargs={'alpha': .7},
    filter_column_colors=True)

# %%
Video("/kaggle/working/BCR_SuicideNo.mp4", width=800, height=600, embed=True)
