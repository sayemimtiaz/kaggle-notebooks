# %% [markdown]
# Hello everyone, I am new to data sience and i am trying to improve my skills. Your feedback is welcome!

# %% [markdown]
# * Introduction
# * Data wrangling
#  * Data cleaning
#  * Find duplicates
#  * Data storing
# * EDA
#  * Visualization using Tableau

# %% [markdown]
# Introduction
#
# The data set contains 550 records. Following data is available
# * Name - Book Title
# * Author -  Author of the book
# * User Rating -  Customer rating from 0-5. This is an accumilated count from all the customers
# * Reviews -  Customer reviews.This feature is the most valueble feature for the amazon books.The most reviewd books tend to have provoking content.
# * Price
# * Year
# * Genre
#
# User rating and reviews should have a correlation.

# %% [markdown]
# Importing data

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import numpy as np # numerical
import pandas as pd 

df = pd.read_csv('/kaggle/input/amazon-top-50-bestselling-books-2009-2019/bestsellers with categories.csv')
df.head()

# %%
nRow, nCol = df.shape
print(f'There are {nRow} rows and {nCol} columns')

# %% [markdown]
# Data wranging
#
# * Wrangled the data using Microsoft SSDT BI tools.
# * Data set is cleaned already.
# * Stored the data in MS SQL database table.Total records uploaded = 550.
# * Check for duplicate records
# >     SELECT distinct Author
# >     FROM [db_name].[dbo].[WRK_table_name]
# >     Order by Author  desc

# %% [markdown]
# Anomalies found for 2 records.
# * J.K. Rowling
# * J. K. Rowling
# ----------------
# * George R.R. Martin
# * George R. R. Martin
#
# Removed the anomalies
#
# > UPDATE [db_name].[dbo].[WRK_table_name]
# > SET Author = 'J.K. Rowling'
# > WHERE  Author='J. K. Rowling'
#
# > UPDATE [db_name].[dbo].[WRK_table_name]
# > SET Author = 'George R.R. Martin'
# > WHERE  Author='George R. R. Martin'

# %% [markdown]
# Exploritory Data Analysis.
#
# Connect tableau to MS SQL server.Select the table.

# %% [markdown]
# Genere and Reviews

# %% [markdown]
# ![Genere Vs Reviews.png](attachment:1fc3f38a-fb91-4b7b-88e6-0e7e82232974.png)

# %% [markdown]
# Genere and Price

# %% [markdown]
# ![Genere Vs Price.png](attachment:e73bb06f-0f5b-42f3-92b8-6c03fbe9c1f0.png)

# %% [markdown]
# User rating and Reviews.
# * Number of reviews received for user rating = 4.8 is an outlier.
# * When the number of reviews is high the user rating is also tend to be high.

# %% [markdown]
# ![image.png](attachment:421c9f19-14b5-4204-9e56-113d685fd8d3.png)

# %% [markdown]
# ![image.png](attachment:76533c5b-51f4-40c2-942a-79c9d341e7ef.png)

# %% [markdown]
# Author name and Price
# * Majority of the books price between 0-100. Book by "American phycological association" price is 460.

# %% [markdown]
# ![Author Vs Price.png](attachment:1476d3e5-d04b-4012-b937-cf97494816b9.png)

# %% [markdown]
# User rating and price for a particular book over the years.
# * from 2009 - 2017 same no of user rating has been received. Infact initial rating in 2009 has continued over the years. This shows the ratings in the dataset are accumilated over the years.

# %% [markdown]
# ![User rating and price for a particular book.png](attachment:22b09167-ede8-4f4d-af6a-b8d4d3adff95.png)
