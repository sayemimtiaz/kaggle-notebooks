# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
import squarify
import seaborn as sns                            

#classifier
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.neighbors import KNeighborsClassifier

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
may14 = pd.read_csv(r"/kaggle/input/uber-pickups-in-new-york-city/uber-raw-data-may14.csv", parse_dates=['Date/Time'])
apr14 = pd.read_csv(r"/kaggle/input/uber-pickups-in-new-york-city/uber-raw-data-apr14.csv", parse_dates=['Date/Time'])
jul14 = pd.read_csv(r"/kaggle/input/uber-pickups-in-new-york-city/uber-raw-data-jul14.csv", parse_dates=['Date/Time'])
jun14 = pd.read_csv(r"/kaggle/input/uber-pickups-in-new-york-city/uber-raw-data-jun14.csv", parse_dates=['Date/Time'])
sep14 = pd.read_csv(r"/kaggle/input/uber-pickups-in-new-york-city/uber-raw-data-sep14.csv", parse_dates=['Date/Time'])
aug14 = pd.read_csv(r"/kaggle/input/uber-pickups-in-new-york-city/uber-raw-data-aug14.csv", parse_dates=['Date/Time'])

# %%
print(may14.shape)
may14.head()

# %%
may14.info()

# %%
print(apr14.shape)
apr14.head()

# %%
apr14.info()

# %%
print(jun14.shape)
jun14.head()

# %%
print(jun14.shape)
jun14.head()

# %%
jun14.info()

# %%
print(sep14.shape)
sep14.head()

# %%
sep14.info()

# %%
print(aug14.shape)
aug14.head()

# %%
aug14.info()

# %%
df = pd.concat([may14, apr14, jul14, jun14, sep14, aug14], ignore_index = True, axis = 0).reset_index(drop = True)
print(may14.shape, apr14.shape, jul14.shape, jun14.shape, sep14.shape, aug14.shape, df.shape)

# %%
print(df.shape)
df.head()

# %%
df.info()

# %%
df.dropna(how = 'any').shape

# %%
df.duplicated().sum()

# %%
df.drop_duplicates(keep = 'first').shape

# %%
df.drop_duplicates(keep = 'last').shape

# %%
df.drop_duplicates(keep = False).shape

# %%
df.dropna(subset = ['Date/Time', 'Lat', 'Lon', 'Base'], how = 'any').shape

# %%
df.info()

# %%
df.columns

# %%
df.columns.to_series().groupby(df.dtypes).groups

# %%
df.isnull().sum()

# %%
df.nunique()

# %%
df.notnull().tail()

# %%
df.apply(lambda x: x.dtype)

# %%
df.columns.to_series().groupby(df.dtypes).groups

# %%
df.info()

# %%
df.head()

# %%
df.hist(figsize=(20,20))
plt.show()

# %%
matrix = df.corr() 
f, ax = plt.subplots(figsize=(10, 10)) 
sns.heatmap(matrix, vmax=.8, square=True, cmap="RdYlGn",annot = True);

# %%
sns.pairplot(df)

# %%
df['Lon'].value_counts()

# %%
df['Lat'].value_counts()

# %%
df['Date/Time'].value_counts()

# %%
df['Base'].value_counts()

# %%
plt.figure(figsize=(10,10))
sns.countplot(y = df['Base'])

# %%
plt.figure(figsize=(10,10))
df['Base'].value_counts().plot.pie(autopct="%0.2f%%")

# %%
base = df['Base'].value_counts()

plt.style.use('default')
plt.figure(figsize = (7, 5))
squarify.plot(sizes = base.values, label = base.index, value = base.values)
plt.title('Base Distribution', fontdict = {'fontname' : 'Monospace', 'fontsize' : 20, 'fontweight' : 'bold'})
plt.show()

# %%
df['Base'] = df['Base'].map({'B02617': 0, 'B02598': 1, 'B02682': 2,'B02764': 3, 'B02512': 4})
df.head()

# %%
X = df.iloc[:, 0].values.reshape(-1, 1)
Y = df.iloc[:, 1].values.reshape(-1, 1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 42, shuffle = True)

# %%
regressor = LinearRegression()  
regressor.fit(X_train, Y_train) #training the algorithm
#To retrieve the intercept:
print(regressor.intercept_)

#For retrieving the slope:
print(regressor.coef_)

# %%
import statsmodels.api as sm

X = np.random.rand(100)
Y = X + np.random.rand(100)*0.1

results = sm.OLS(Y,sm.add_constant(X)).fit()

print(results.summary())

plt.scatter(X,Y)

X_plot = np.linspace(0,1,100)
plt.plot(X_plot, X_plot*results.params[0] + results.params[1])

plt.show()
