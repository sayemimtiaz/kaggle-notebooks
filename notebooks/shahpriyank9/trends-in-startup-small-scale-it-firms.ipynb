# %% [markdown]
# <h1>Trends in Startup/Small Scale IT Firms</h1>

# %% [markdown]
# This notebook is a small analysis to understand some of the menial trends in startups/Small Scale IT firms.

# %% [markdown]
# All current major firms or MNC’s like Google, Facebook, Apple , etc . have been at some point of their life cycle a Startup/Small Scale firms. Thus understanding the current ecosystem in these firms might give us the insight on how these firms work. Some of these firms might even turn out to be future MNC’s. This post will walk you through some of the more common thoughts or questions raised when someone sees a startup/small scale firm.
#
# The following questions would be answered using the stack-overflow data set for Startup/Small Scale IT firms :
#
# 1. Percentage of People working in Startup/Small Scale firms out of the total survey received.
# 2. Average Age
# 3. Average Salary
# 4. Languages used
# 5. Operating system used
# 6. Version Control Used
# 7. Percentage of people working as a Hobby

# %% [markdown]
# The data set which will be used in this notebook is taken from kaggle which is contributed by Stackoverflow. The data can be found [here](https://www.kaggle.com/stackoverflow/stack-overflow-2018-developer-survey).Let us first load the dataset which is from kaggle and have a look.

# %%
#Importing dependent modules
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt

# %%
raw_data = pd.read_csv('../input/survey_results_public.csv',dtype=str)
raw_data.head()
# Out:
#   Respondent      ...           SurveyEasy
# 0          1      ...            Very easy
# 1          3      ...        Somewhat easy
# 2          4      ...                  NaN
# 3          5      ...        Somewhat easy
# 4          7      ...        Somewhat easy
#
# [5 rows x 129 columns]

# %% [markdown]
# As we can see the data seems to be straight forward with some columns which have to be engineered. Let us look at the shape of the data

# %%
raw_data.shape
# Out:
# (98855, 129)

# %% [markdown]
# There were 98855 surveys which have been provided by stack-overflow with 129 columns containing various types of information. For the sake of this analysis we will not be considering all the columns and will only consider few columns as below

# %%
columns_selected_for_analysis= ['Hobby','OpenSource','Country','Student','Employment',
                                'FormalEducation','UndergradMajor','CompanySize','DevType',
                                'YearsCoding','YearsCodingProf','JobSatisfaction','CareerSatisfaction',
                                'SalaryType','ConvertedSalary','CommunicationTools','TimeFullyProductive',
                                'EducationTypes','SelfTaughtTypes','LanguageWorkedWith',
                                'LanguageDesireNextYear','DatabaseWorkedWith','DatabaseDesireNextYear',
                                'PlatformWorkedWith','PlatformDesireNextYear','FrameworkWorkedWith',
                                'FrameworkDesireNextYear','IDE','OperatingSystem','Methodology',
                                'VersionControl','CheckInCode','WakeTime','HoursComputer','HoursOutside',
                                'SkipMeals','Gender','Age']

# %%
analysis_data = raw_data[columns_selected_for_analysis]
analysis_data.shape
# Out:
# (98855, 38)

# %% [markdown]
# We have only selected 38 columns which might be relevant. Let us look at the entire data stats and columns stats.

# %%
analysis_data.describe()
# Out:
#         Hobby OpenSource        ...         Gender                Age
# count   98855      98855        ...          64469              64574
# unique      2          2        ...             15                  7
# top       Yes         No        ...           Male  25 - 34 years old
# freq    79897      55769        ...          59458              31759
#
# [4 rows x 38 columns]

# %%
for col in analysis_data.columns :
    print(col)
    print(analysis_data[col].value_counts())
    print()
# Out:
# Hobby
# Yes    79897
# No     18958
# Name: Hobby, dtype: int64
#
# OpenSource
# No     55769
# Yes    43086
# Name: OpenSource, dtype: int64
#
# Country
# United States                            20309
# India                                    13721
# Germany                                   6459
# United Kingdom                            6221
# Canada                                    3393
# Russian Federation                        2869
# France                                    2572
# Brazil                                    2505
# Poland                                    2122
# Australia                                 2018
# Netherlands                               1841
# Spain                                     1769
# Italy                                     1535
# Ukraine                                   1279
# Sweden                                    1164
# Pakistan                                  1050
# China                                     1037
# Switzerland                               1010
# Turkey                                    1004
# Israel                                    1003
# Iran, Islamic Republic of...               921
# Romania                                    793
# Austria                                    788
# Czech Republic                             784
# Belgium                                    743
# Mexico                                     736
# Bangladesh                                 697
# Denmark                                    653
# South Africa                               637
# Indonesia                                  630
#                                          ...
# North Korea                                  4
# Mauritania                                   3
# Cape Verde                                   3
# Liberia                                      3
# Guinea                                       3
# Swaziland                                    3
# Democratic People's Republic of Korea        2
# Dominica                                     2
# Micronesia, Federated States of...           2
# Lesotho                                      2
# Marshall Islands                             2
# Suriname                                     2
# Niger                                        2
# Central African Republic                     2
# Guyana                                       2
# Palau                                        2
# Djibouti                                     1
# Grenada                                      1
# Solomon Islands                              1
# Mali                                         1
# Timor-Leste                                  1
# Nauru                                        1
# Saint Lucia                                  1
# Burundi                                      1
# Guinea-Bissau                                1
# Belize                                       1
# Brunei Darussalam                            1
# Sierra Leone                                 1
# San Marino                                   1
# Eritrea                                      1
# Name: Country, Length: 183, dtype: int64
#
# Student
# No                70399
# Yes, full-time    18394
# Yes, part-time     6108
# Name: Student, dtype: int64
#
# Employment
# Employed full-time                                      70495
# Independent contractor, freelancer, or self-employed     9282
# Not employed, but looking for work                       5805
# Employed part-time                                       5380
# Not employed, and not looking for work                   4132
# Retired                                                   227
# Name: Employment, dtype: int64
#
# FormalEducation
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              43659
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           21396
# Some college/university study without earning a degree                                11710
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     8951
# Associate degree                                                                       2970
# Other doctoral degree (Ph.D, Ed.D., etc.)                                              2214
# Primary/elementary school                                                              1656
# Professional degree (JD, MD, etc.)                                                     1447
# I never completed any formal education                                                  700
# Name: FormalEducation, dtype: int64
#
# UndergradMajor
# Computer science, computer engineering, or software engineering          50336
# Another engineering discipline (ex. civil, electrical, mechanical)        6945
# Information systems, information technology, or system administration     6507
# A natural science (ex. biology, chemistry, physics)                       3050
# Mathematics or statistics                                                 2818
# Web development or web design                                             2418
# A business discipline (ex. accounting, finance, marketing)                1921
# A humanities discipline (ex. literature, history, philosophy)             1590
# A social science (ex. anthropology, psychology, political science)        1377
# Fine arts or performing arts (ex. graphic design, music, studio art)      1135
# I never declared a major                                                   693
# A health science (ex. nursing, pharmacy, radiology)                        246
# Name: UndergradMajor, dtype: int64
#
# CompanySize
# 20 to 99 employees          16996
# 100 to 499 employees        14011
# 10,000 or more employees     9757
# 10 to 19 employees           8007
# 1,000 to 4,999 employees     7634
# Fewer than 10 employees      7479
# 500 to 999 employees         4630
# 5,000 to 9,999 employees     3017
# Name: CompanySize, dtype: int64
#
# DevType
# Back-end developer                                                                                                                                                                                                                                                                                                                                                                          6417
# Full-stack developer                                                                                                                                                                                                                                                                                                                                                                        6104
# Back-end developer;Front-end developer;Full-stack developer                                                                                                                                                                                                                                                                                                                                 4460
# Mobile developer                                                                                                                                                                                                                                                                                                                                                                            3518
# Student                                                                                                                                                                                                                                                                                                                                                                                     3222
# Back-end developer;Full-stack developer                                                                                                                                                                                                                                                                                                                                                     3128
# Front-end developer                                                                                                                                                                                                                                                                                                                                                                         2608
# Front-end developer;Full-stack developer                                                                                                                                                                                                                                                                                                                                                    1117
# Back-end developer;Front-end developer                                                                                                                                                                                                                                                                                                                                                      1030
# Back-end developer;Front-end developer;Full-stack developer;Mobile developer                                                                                                                                                                                                                                                                                                                1008
# Back-end developer;Desktop or enterprise applications developer;Front-end developer;Full-stack developer                                                                                                                                                                                                                                                                                     981
# Desktop or enterprise applications developer                                                                                                                                                                                                                                                                                                                                                 896
# Data scientist or machine learning specialist                                                                                                                                                                                                                                                                                                                                                869
# Back-end developer;Desktop or enterprise applications developer                                                                                                                                                                                                                                                                                                                              779
# Embedded applications or devices developer                                                                                                                                                                                                                                                                                                                                                   708
# Back-end developer;Desktop or enterprise applications developer;Full-stack developer                                                                                                                                                                                                                                                                                                         677
# Back-end developer;Student                                                                                                                                                                                                                                                                                                                                                                   624
# Back-end developer;Designer;Front-end developer;Full-stack developer                                                                                                                                                                                                                                                                                                                         597
# Back-end developer;DevOps specialist                                                                                                                                                                                                                                                                                                                                                         593
# Back-end developer;Front-end developer;Full-stack developer;Student                                                                                                                                                                                                                                                                                                                          567
# QA or test developer                                                                                                                                                                                                                                                                                                                                                                         552
# Front-end developer;Mobile developer                                                                                                                                                                                                                                                                                                                                                         528
# Back-end developer;Mobile developer                                                                                                                                                                                                                                                                                                                                                          517
# Data or business analyst                                                                                                                                                                                                                                                                                                                                                                     499
# Back-end developer;Database administrator;Front-end developer;Full-stack developer                                                                                                                                                                                                                                                                                                           497
# Back-end developer;DevOps specialist;Full-stack developer                                                                                                                                                                                                                                                                                                                                    490
# Full-stack developer;Mobile developer                                                                                                                                                                                                                                                                                                                                                        456
# Data or business analyst;Data scientist or machine learning specialist                                                                                                                                                                                                                                                                                                                       448
# C-suite executive (CEO, CTO, etc.)                                                                                                                                                                                                                                                                                                                                                           438
# Back-end developer;DevOps specialist;Front-end developer;Full-stack developer                                                                                                                                                                                                                                                                                                                428
#                                                                                                                                                                                                                                                                                                                                                                                             ...
# Back-end developer;Data or business analyst;Data scientist or machine learning specialist;Database administrator;Designer;Desktop or enterprise applications developer;Educator or academic researcher;Full-stack developer                                                                                                                                                                    1
# Back-end developer;Data scientist or machine learning specialist;Embedded applications or devices developer;Game or graphics developer;Mobile developer                                                                                                                                                                                                                                        1
# Back-end developer;Data scientist or machine learning specialist;Embedded applications or devices developer;Marketing or sales professional;QA or test developer;Student                                                                                                                                                                                                                       1
# Back-end developer;Database administrator;Designer;Desktop or enterprise applications developer;DevOps specialist;Student;System administrator                                                                                                                                                                                                                                                 1
# Back-end developer;Data or business analyst;Data scientist or machine learning specialist;Designer;Desktop or enterprise applications developer;Embedded applications or devices developer                                                                                                                                                                                                     1
# Back-end developer;Full-stack developer;Game or graphics developer;QA or test developer;Student                                                                                                                                                                                                                                                                                                1
# Back-end developer;Data or business analyst;Data scientist or machine learning specialist;Database administrator;Designer;Engineering manager;Front-end developer;Full-stack developer;System administrator                                                                                                                                                                                    1
# Back-end developer;Designer;Desktop or enterprise applications developer;Full-stack developer;Marketing or sales professional;Mobile developer;QA or test developer                                                                                                                                                                                                                            1
# Back-end developer;Data or business analyst;Database administrator;Designer;Desktop or enterprise applications developer;Front-end developer;Full-stack developer;QA or test developer;Student                                                                                                                                                                                                 1
# Desktop or enterprise applications developer;DevOps specialist;Front-end developer;Mobile developer;System administrator                                                                                                                                                                                                                                                                       1
# Back-end developer;Designer;Desktop or enterprise applications developer;Educator or academic researcher;Engineering manager;Front-end developer;Full-stack developer;Mobile developer;QA or test developer;Student                                                                                                                                                                            1
# Back-end developer;Educator or academic researcher;Embedded applications or devices developer;Engineering manager;Student                                                                                                                                                                                                                                                                      1
# Back-end developer;C-suite executive (CEO, CTO, etc.);Data scientist or machine learning specialist;Database administrator;DevOps specialist;Front-end developer;Full-stack developer;Mobile developer;System administrator                                                                                                                                                                    1
# Data or business analyst;Database administrator;Designer;Desktop or enterprise applications developer;Game or graphics developer;Student                                                                                                                                                                                                                                                       1
# Back-end developer;Data or business analyst;Database administrator;Designer;Desktop or enterprise applications developer;DevOps specialist;Embedded applications or devices developer;Full-stack developer;Game or graphics developer;System administrator                                                                                                                                     1
# Desktop or enterprise applications developer;Front-end developer;Full-stack developer;Mobile developer;QA or test developer                                                                                                                                                                                                                                                                    1
# Back-end developer;Data scientist or machine learning specialist;Designer;Educator or academic researcher;Front-end developer;Full-stack developer;Mobile developer;Product manager                                                                                                                                                                                                            1
# Back-end developer;C-suite executive (CEO, CTO, etc.);DevOps specialist;Embedded applications or devices developer;Full-stack developer;Product manager                                                                                                                                                                                                                                        1
# Educator or academic researcher;Full-stack developer;Mobile developer;Student                                                                                                                                                                                                                                                                                                                  1
# Back-end developer;Database administrator;Designer;Embedded applications or devices developer;Full-stack developer;Mobile developer;Product manager;Student                                                                                                                                                                                                                                    1
# Back-end developer;C-suite executive (CEO, CTO, etc.);Data or business analyst;Data scientist or machine learning specialist;Database administrator;Designer;DevOps specialist;Front-end developer;Full-stack developer;System administrator                                                                                                                                                   1
# Back-end developer;Database administrator;Designer;Desktop or enterprise applications developer;DevOps specialist;Front-end developer;Full-stack developer;Marketing or sales professional;Mobile developer;Product manager;QA or test developer;System administrator                                                                                                                          1
# Back-end developer;Database administrator;Designer;Desktop or enterprise applications developer;Educator or academic researcher;Front-end developer;Full-stack developer;Game or graphics developer;Mobile developer;QA or test developer;Student;System administrator                                                                                                                         1
# Database administrator;Designer;Front-end developer;Full-stack developer;Game or graphics developer                                                                                                                                                                                                                                                                                            1
# Back-end developer;C-suite executive (CEO, CTO, etc.);Data scientist or machine learning specialist;Designer;Front-end developer                                                                                                                                                                                                                                                               1
# Database administrator;Designer;DevOps specialist;Full-stack developer;Product manager;QA or test developer;System administrator                                                                                                                                                                                                                                                               1
# Back-end developer;Data or business analyst;Educator or academic researcher;Front-end developer;Student                                                                                                                                                                                                                                                                                        1
# Back-end developer;C-suite executive (CEO, CTO, etc.);Data or business analyst;Data scientist or machine learning specialist;Database administrator;Designer;Desktop or enterprise applications developer;DevOps specialist;Educator or academic researcher;Embedded applications or devices developer;Engineering manager;Front-end developer;Full-stack developer;System administrator       1
# Back-end developer;C-suite executive (CEO, CTO, etc.);Data or business analyst;Database administrator;Desktop or enterprise applications developer;DevOps specialist;System administrator                                                                                                                                                                                                      1
# Data or business analyst;Desktop or enterprise applications developer;Engineering manager;QA or test developer                                                                                                                                                                                                                                                                                 1
# Name: DevType, Length: 9568, dtype: int64
#
# YearsCoding
# 3-5 years           23313
# 6-8 years           19338
# 9-11 years          12169
# 0-2 years           10682
# 12-14 years          8030
# 15-17 years          6117
# 18-20 years          5072
# 30 or more years     3544
# 21-23 years          2648
# 24-26 years          1862
# 27-29 years          1060
# Name: YearsCoding, dtype: int64
#
# YearsCodingProf
# 0-2 years           23421
# 3-5 years           21362
# 6-8 years           11385
# 9-11 years           7573
# 12-14 years          4287
# 15-17 years          3012
# 18-20 years          2830
# 21-23 years          1368
# 30 or more years     1302
# 24-26 years           857
# 27-29 years           506
# Name: YearsCodingProf, dtype: int64
#
# JobSatisfaction
# Moderately satisfied                  26005
# Extremely satisfied                   12436
# Slightly satisfied                    10012
# Slightly dissatisfied                  7057
# Moderately dissatisfied                6318
# Neither satisfied nor dissatisfied     4966
# Extremely dissatisfied                 2482
# Name: JobSatisfaction, dtype: int64
#
# CareerSatisfaction
# Moderately satisfied                  27926
# Extremely satisfied                   14316
# Slightly satisfied                    13484
# Slightly dissatisfied                  6587
# Neither satisfied nor dissatisfied     6316
# Moderately dissatisfied                5262
# Extremely dissatisfied                 2613
# Name: CareerSatisfaction, dtype: int64
#
# SalaryType
# Monthly    26252
# Yearly     22556
# Weekly      2262
# Name: SalaryType, dtype: int64
#
# ConvertedSalary
# 0         842
# 120000    524
# 1e+05     497
# 80000     396
# 1e+06     382
# 110000    371
# 90000     364
# 150000    357
# 60000     351
# 75000     337
# 130000    333
# 70000     319
# 73433     317
# 61194     308
# 85000     288
# 125000    276
# 115000    255
# 105000    255
# 48955     246
# 44064     245
# 140000    243
# 65000     237
# 2e+06     227
# 95000     218
# 50000     215
# 29376     214
# 55075     211
# 135000    182
# 36716     181
# 58752     181
#          ...
# 8028        1
# 14900       1
# 48192       1
# 75794       1
# 76572       1
# 68341       1
# 50526       1
# 507204      1
# 28474       1
# 56646       1
# 45624       1
# 66952       1
# 56788       1
# 53792       1
# 76960       1
# 103550      1
# 8064        1
# 39840       1
# 8223        1
# 47242       1
# 195192      1
# 123585      1
# 66252       1
# 19020       1
# 38369       1
# 28296       1
# 303000      1
# 696168      1
# 32555       1
# 247917      1
# Name: ConvertedSalary, Length: 7473, dtype: int64
#
# CommunicationTools
# Office / productivity suite (Microsoft Office, Google Suite, etc.)                                                                                                                                                                                                          3523
# Slack                                                                                                                                                                                                                                                                       3391
# Confluence;Jira;Slack                                                                                                                                                                                                                                                       2256
# Other chat system (IRC, proprietary software, etc.)                                                                                                                                                                                                                         1444
# Jira;Slack                                                                                                                                                                                                                                                                  1402
# Slack;Other wiki tool (Github, Google Sites, proprietary software, etc.)                                                                                                                                                                                                    1193
# Slack;Trello                                                                                                                                                                                                                                                                1174
# Confluence;Jira;Office / productivity suite (Microsoft Office, Google Suite, etc.);Slack                                                                                                                                                                                    1053
# Office / productivity suite (Microsoft Office, Google Suite, etc.);Slack                                                                                                                                                                                                    1035
# Other wiki tool (Github, Google Sites, proprietary software, etc.)                                                                                                                                                                                                           975
# Other chat system (IRC, proprietary software, etc.);Other wiki tool (Github, Google Sites, proprietary software, etc.)                                                                                                                                                       968
# Office / productivity suite (Microsoft Office, Google Suite, etc.);Other chat system (IRC, proprietary software, etc.)                                                                                                                                                       959
# Confluence;Jira;Office / productivity suite (Microsoft Office, Google Suite, etc.)                                                                                                                                                                                           949
# Google Hangouts/Chat                                                                                                                                                                                                                                                         896
# Confluence;Jira                                                                                                                                                                                                                                                              890
# Jira                                                                                                                                                                                                                                                                         744
# Google Hangouts/Chat;Slack                                                                                                                                                                                                                                                   728
# Office / productivity suite (Microsoft Office, Google Suite, etc.);Other wiki tool (Github, Google Sites, proprietary software, etc.)                                                                                                                                        687
# Office / productivity suite (Microsoft Office, Google Suite, etc.);Other chat system (IRC, proprietary software, etc.);Other wiki tool (Github, Google Sites, proprietary software, etc.)                                                                                    651
# Jira;Office / productivity suite (Microsoft Office, Google Suite, etc.)                                                                                                                                                                                                      625
# Confluence;Jira;Other chat system (IRC, proprietary software, etc.)                                                                                                                                                                                                          584
# Facebook                                                                                                                                                                                                                                                                     558
# Office / productivity suite (Microsoft Office, Google Suite, etc.);Slack;Other wiki tool (Github, Google Sites, proprietary software, etc.)                                                                                                                                  555
# Confluence;Google Hangouts/Chat;Jira;Slack                                                                                                                                                                                                                                   536
# Slack;Trello;Other wiki tool (Github, Google Sites, proprietary software, etc.)                                                                                                                                                                                              520
# Jira;Office / productivity suite (Microsoft Office, Google Suite, etc.);Slack                                                                                                                                                                                                519
# Confluence;Jira;Office / productivity suite (Microsoft Office, Google Suite, etc.);Other chat system (IRC, proprietary software, etc.)                                                                                                                                       485
# Confluence;HipChat;Jira                                                                                                                                                                                                                                                      479
# Jira;Slack;Other wiki tool (Github, Google Sites, proprietary software, etc.)                                                                                                                                                                                                467
# Confluence;Jira;Slack;Other wiki tool (Github, Google Sites, proprietary software, etc.)                                                                                                                                                                                     463
#                                                                                                                                                                                                                                                                             ...
# Confluence;Google Hangouts/Chat;Jira;Office / productivity suite (Microsoft Office, Google Suite, etc.);Stack Overflow Enterprise                                                                                                                                              1
# Confluence;HipChat;Stack Overflow Enterprise;Other wiki tool (Github, Google Sites, proprietary software, etc.)                                                                                                                                                                1
# Google Hangouts/Chat;HipChat;Jira;Office / productivity suite (Microsoft Office, Google Suite, etc.);Other chat system (IRC, proprietary software, etc.)                                                                                                                       1
# Facebook;Google Hangouts/Chat;HipChat;Jira;Trello                                                                                                                                                                                                                              1
# Confluence;HipChat;Trello;Other chat system (IRC, proprietary software, etc.);Other wiki tool (Github, Google Sites, proprietary software, etc.)                                                                                                                               1
# Facebook;Jira;Office / productivity suite (Microsoft Office, Google Suite, etc.);Slack;Stack Overflow Enterprise;Other chat system (IRC, proprietary software, etc.);Other wiki tool (Github, Google Sites, proprietary software, etc.)                                        1
# Confluence;Facebook;Google Hangouts/Chat;HipChat;Jira;Office / productivity suite (Microsoft Office, Google Suite, etc.);Slack;Stack Overflow Enterprise;Other wiki tool (Github, Google Sites, proprietary software, etc.)                                                    1
# Confluence;Facebook;Jira;Office / productivity suite (Microsoft Office, Google Suite, etc.);Slack;Stack Overflow Enterprise;Other chat system (IRC, proprietary software, etc.);Other wiki tool (Github, Google Sites, proprietary software, etc.)                             1
# Confluence;Facebook;Google Hangouts/Chat;HipChat;Jira;Office / productivity suite (Microsoft Office, Google Suite, etc.);Other chat system (IRC, proprietary software, etc.);Other wiki tool (Github, Google Sites, proprietary software, etc.)                                1
# Confluence;Facebook;Google Hangouts/Chat;HipChat;Jira;Stack Overflow Enterprise;Other wiki tool (Github, Google Sites, proprietary software, etc.)                                                                                                                             1
# HipChat;Stack Overflow Enterprise;Other chat system (IRC, proprietary software, etc.);Other wiki tool (Github, Google Sites, proprietary software, etc.)                                                                                                                       1
# Confluence;Facebook;Jira;Office / productivity suite (Microsoft Office, Google Suite, etc.);Stack Overflow Enterprise;Other wiki tool (Github, Google Sites, proprietary software, etc.)                                                                                       1
# Facebook;Office / productivity suite (Microsoft Office, Google Suite, etc.);Stack Overflow Enterprise;Other chat system (IRC, proprietary software, etc.)                                                                                                                      1
# Confluence;Facebook;Google Hangouts/Chat;Jira;Office / productivity suite (Microsoft Office, Google Suite, etc.);Stack Overflow Enterprise;Trello;Other chat system (IRC, proprietary software, etc.);Other wiki tool (Github, Google Sites, proprietary software, etc.)       1
# Facebook;Google Hangouts/Chat;Office / productivity suite (Microsoft Office, Google Suite, etc.);Slack;Stack Overflow Enterprise                                                                                                                                               1
# Confluence;Google Hangouts/Chat;Jira;Office / productivity suite (Microsoft Office, Google Suite, etc.);Slack;Stack Overflow Enterprise                                                                                                                                        1
# Confluence;Facebook;Office / productivity suite (Microsoft Office, Google Suite, etc.);Stack Overflow Enterprise;Other wiki tool (Github, Google Sites, proprietary software, etc.)                                                                                            1
# Jira;Office / productivity suite (Microsoft Office, Google Suite, etc.);Slack;Stack Overflow Enterprise;Trello                                                                                                                                                                 1
# HipChat;Jira;Office / productivity suite (Microsoft Office, Google Suite, etc.);Slack;Trello;Other wiki tool (Github, Google Sites, proprietary software, etc.)                                                                                                                1
# Confluence;Stack Overflow Enterprise;Trello                                                                                                                                                                                                                                    1
# Confluence;Google Hangouts/Chat;Jira;Stack Overflow Enterprise                                                                                                                                                                                                                 1
# Confluence;HipChat;Office / productivity suite (Microsoft Office, Google Suite, etc.);Other chat system (IRC, proprietary software, etc.);Other wiki tool (Github, Google Sites, proprietary software, etc.)                                                                   1
# Google Hangouts/Chat;Slack;Stack Overflow Enterprise;Other chat system (IRC, proprietary software, etc.)                                                                                                                                                                       1
# Facebook;HipChat;Slack;Other wiki tool (Github, Google Sites, proprietary software, etc.)                                                                                                                                                                                      1
# Confluence;Facebook;Google Hangouts/Chat;HipChat;Jira;Slack;Stack Overflow Enterprise                                                                                                                                                                                          1
# Facebook;Google Hangouts/Chat;HipChat;Office / productivity suite (Microsoft Office, Google Suite, etc.);Slack                                                                                                                                                                 1
# Google Hangouts/Chat;HipChat;Office / productivity suite (Microsoft Office, Google Suite, etc.);Slack;Stack Overflow Enterprise                                                                                                                                                1
# Facebook;Google Hangouts/Chat;Jira;Office / productivity suite (Microsoft Office, Google Suite, etc.);Slack;Stack Overflow Enterprise;Trello;Other chat system (IRC, proprietary software, etc.)                                                                               1
# ...
# Agile;Formal standard such as ISO 9001 or IEEE 12207 (aka “waterfall” methodologies);Mob programming;Lean;PRINCE2;Scrum                                                                                1
# Agile;Evidence-based software engineering;Mob programming;Lean                                                                                                                                         1
# Agile;Evidence-based software engineering;Formal standard such as ISO 9001 or IEEE 12207 (aka “waterfall” methodologies);Mob programming                                                               1
# Extreme programming (XP);Formal standard such as ISO 9001 or IEEE 12207 (aka “waterfall” methodologies);Kanban;Mob programming;PRINCE2                                                                 1
# Extreme programming (XP);Formal standard such as ISO 9001 or IEEE 12207 (aka “waterfall” methodologies);Lean;Scrum                                                                                     1
# Agile;Mob programming;PRINCE2;Scrum                                                                                                                                                                    1
# Agile;Kanban;Mob programming;Pair programming;PRINCE2;Scrum                                                                                                                                            1
# Agile;Formal standard such as ISO 9001 or IEEE 12207 (aka “waterfall” methodologies);Kanban;Mob programming;Lean;Pair programming;PRINCE2;Scrum                                                        1
# Agile;Evidence-based software engineering;Extreme programming (XP);Formal standard such as ISO 9001 or IEEE 12207 (aka “waterfall” methodologies);Mob programming;Lean;Pair programming;Scrum          1
# Evidence-based software engineering;PRINCE2                                                                                                                                                            1
# Agile;Evidence-based software engineering;Extreme programming (XP);Formal standard such as ISO 9001 or IEEE 12207 (aka “waterfall” methodologies);Mob programming;Pair programming;Scrum               1
# Evidence-based software engineering;Mob programming;Pair programming;Scrum                                                                                                                             1
# Formal standard such as ISO 9001 or IEEE 12207 (aka “waterfall” methodologies);Kanban;Mob programming;Lean;Pair programming;PRINCE2;Scrum                                                              1
# Evidence-based software engineering;Extreme programming (XP);Formal standard such as ISO 9001 or IEEE 12207 (aka “waterfall” methodologies);Lean;Scrum                                                 1
# Agile;Formal standard such as ISO 9001 or IEEE 12207 (aka “waterfall” methodologies);Lean;PRINCE2                                                                                                      1
# Agile;Extreme programming (XP);Formal standard such as ISO 9001 or IEEE 12207 (aka “waterfall” methodologies);Kanban;Mob programming;Pair programming                                                  1
# Agile;Evidence-based software engineering;Extreme programming (XP);Kanban;Pair programming;PRINCE2;Scrum                                                                                               1
# Formal standard such as ISO 9001 or IEEE 12207 (aka “waterfall” methodologies);Lean;Pair programming;PRINCE2;Scrum                                                                                     1
# Agile;Evidence-based software engineering;Formal standard such as ISO 9001 or IEEE 12207 (aka “waterfall” methodologies);Lean                                                                          1
# Mob programming;Lean;Scrum                                                                                                                                                                             1
# Extreme programming (XP);Formal standard such as ISO 9001 or IEEE 12207 (aka “waterfall” methodologies);PRINCE2;Scrum                                                                                  1
# Agile;Extreme programming (XP);Kanban;Mob programming;Pair programming;PRINCE2;Scrum                                                                                                                   1
# Agile;Formal standard such as ISO 9001 or IEEE 12207 (aka “waterfall” methodologies);Kanban;Mob programming;Pair programming                                                                           1
# Agile;Evidence-based software engineering;Extreme programming (XP);Kanban;Mob programming;Pair programming;PRINCE2;Scrum                                                                               1
# Name: Methodology, Length: 480, dtype: int64
#
# VersionControl
# Git                                                                                                                              44133
# Git;Subversion                                                                                                                    6789
# Git;Team Foundation Version Control                                                                                               4208
# I don't use version control                                                                                                       2988
# Subversion                                                                                                                        1962
# Git;Zip file back-ups                                                                                                             1774
# Team Foundation Version Control                                                                                                   1581
# Git;Copying and pasting files to network shares                                                                                   1565
# Git;Mercurial                                                                                                                     1444
# Git;Copying and pasting files to network shares;Zip file back-ups                                                                 1251
# Git;Subversion;Team Foundation Version Control                                                                                     797
# Zip file back-ups                                                                                                                  586
# Copying and pasting files to network shares                                                                                        517
# Copying and pasting files to network shares;Zip file back-ups                                                                      435
# Git;Subversion;Copying and pasting files to network shares                                                                         383
# Git;Mercurial;Subversion                                                                                                           354
# Git;Subversion;Zip file back-ups                                                                                                   337
# Git;Subversion;Copying and pasting files to network shares;Zip file back-ups                                                       312
# Mercurial                                                                                                                          312
# Git;Team Foundation Version Control;Copying and pasting files to network shares                                                    201
# Git;I don't use version control                                                                                                    200
# Subversion;Team Foundation Version Control                                                                                         197
# Git;Team Foundation Version Control;Copying and pasting files to network shares;Zip file back-ups                                  191
# Git;Team Foundation Version Control;Zip file back-ups                                                                              145
# Git;Mercurial;Team Foundation Version Control                                                                                      114
# Subversion;Copying and pasting files to network shares                                                                             109
# Subversion;Copying and pasting files to network shares;Zip file back-ups                                                           100
# Team Foundation Version Control;Copying and pasting files to network shares                                                         99
# Copying and pasting files to network shares;I don't use version control                                                             93
# Git;Subversion;Team Foundation Version Control;Copying and pasting files to network shares;Zip file back-ups                        84
#                                                                                                                                  ...
# Git;Subversion;Copying and pasting files to network shares;Zip file back-ups;I don't use version control                             7
# Mercurial;Copying and pasting files to network shares;Zip file back-ups                                                              7
# Git;Mercurial;Subversion;Team Foundation Version Control;Copying and pasting files to network shares                                 6
# Subversion;I don't use version control                                                                                               5
# Team Foundation Version Control;I don't use version control                                                                          5
# Git;Mercurial;Team Foundation Version Control;Zip file back-ups                                                                      5
# Git;Mercurial;Team Foundation Version Control;Copying and pasting files to network shares                                            4
# Mercurial;Subversion;Copying and pasting files to network shares                                                                     4
# Git;Team Foundation Version Control;I don't use version control                                                                      4
# Subversion;Copying and pasting files to network shares;I don't use version control                                                   4
# Mercurial;Team Foundation Version Control;Zip file back-ups                                                                          3
# Mercurial;Team Foundation Version Control;Copying and pasting files to network shares                                                3
# Subversion;Zip file back-ups;I don't use version control                                                                             3
# Mercurial;Subversion;Zip file back-ups                                                                                               3
# Subversion;Team Foundation Version Control;Copying and pasting files to network shares;I don't use version control                   2
# Mercurial;Subversion;Team Foundation Version Control                                                                                 2
# Team Foundation Version Control;Copying and pasting files to network shares;I don't use version control                              2
# Team Foundation Version Control;Zip file back-ups;I don't use version control                                                        2
# Git;Subversion;Zip file back-ups;I don't use version control                                                                         2
# Mercurial;Subversion;Copying and pasting files to network shares;Zip file back-ups                                                   2
# Git;Mercurial;Copying and pasting files to network shares;Zip file back-ups;I don't use version control                              2
# Git;Mercurial;I don't use version control                                                                                            2
# Git;Team Foundation Version Control;Copying and pasting files to network shares;I don't use version control                          2
# Team Foundation Version Control;Copying and pasting files to network shares;Zip file back-ups;I don't use version control            2
# Mercurial;I don't use version control                                                                                                1
# Mercurial;Copying and pasting files to network shares;I don't use version control                                                    1
# Mercurial;Subversion;Team Foundation Version Control;Copying and pasting files to network shares;Zip file back-ups                   1
# Mercurial;Copying and pasting files to network shares;Zip file back-ups;I don't use version control                                  1
# Git;Team Foundation Version Control;Copying and pasting files to network shares;Zip file back-ups;I don't use version control        1
# Mercurial;Subversion;Copying and pasting files to network shares;Zip file back-ups;I don't use version control                       1
# Name: VersionControl, Length: 90, dtype: int64
#
# CheckInCode
# Multiple times per day             43566
# A few times per week               13808
# Once a day                          6587
# Weekly or a few times per month     4983
# Less than once per month            2337
# Never                               1074
# Name: CheckInCode, dtype: int64
#
# WakeTime
# Between 7:01 - 8:00 AM          21250
# Between 6:01 - 7:00 AM          20322
# Between 8:01 - 9:00 AM          10592
# Between 5:00 - 6:00 AM           8922
# I do not have a set schedule     3842
# Between 9:01 - 10:00 AM          3453
# Before 5:00 AM                   1730
# Between 10:01 - 11:00 AM         1020
# Between 11:01 AM - 12:00 PM       387
# I work night shifts               327
# After 12:01 PM                    301
# Name: WakeTime, dtype: int64
#
# HoursComputer
# 9 - 12 hours        37983
# 5 - 8 hours         22070
# Over 12 hours        9549
# 1 - 4 hours          2349
# Less than 1 hour      182
# Name: HoursComputer, dtype: int64
#
# HoursOutside
# 1 - 2 hours             27788
# 30 - 59 minutes         24002
# Less than 30 minutes    11223
# 3 - 4 hours              7186
# Over 4 hours             1825
# Name: HoursOutside, dtype: int64
#
# SkipMeals
# Never                        45772
# 1 - 2 times per week         18164
# 3 - 4 times per week          4303
# Daily or almost every day     3707
# Name: SkipMeals, dtype: int64
#
# Gender
# Male                                                                         59458
# Female                                                                        4025
# Non-binary, genderqueer, or gender non-conforming                              284
# Female;Transgender                                                             145
# Male;Non-binary, genderqueer, or gender non-conforming                         128
# Transgender                                                                    105
# Female;Male                                                                     98
# Transgender;Non-binary, genderqueer, or gender non-conforming                   51
# Female;Non-binary, genderqueer, or gender non-conforming                        50
# Female;Male;Transgender;Non-binary, genderqueer, or gender non-conforming       50
# Male;Transgender                                                                29
# Female;Transgender;Non-binary, genderqueer, or gender non-conforming            24
# Female;Male;Transgender                                                         14
# Male;Transgender;Non-binary, genderqueer, or gender non-conforming               5
# Female;Male;Non-binary, genderqueer, or gender non-conforming                    3
# Name: Gender, dtype: int64
#
# Age
# 25 - 34 years old     31759
# 18 - 24 years old     15249
# 35 - 44 years old     11477
# 45 - 54 years old      3313
# Under 18 years old     1638
# 55 - 64 years old       959
# 65 years or older       179
# Name: Age, dtype: int64

# %% [markdown]
# It seems there are quite a few columns which have Null values. They will be handled individually as the questions are answered.

# %% [markdown]
# Since this analysis is for Startup/Small Scale IT firms, we would have to select only companies with less than 100 employees (this is a personal selection and you can change it based on your preference).

# %%
#Limiting the data to only companies having less than 100 employees
data=analysis_data[analysis_data['CompanySize'].isin([
    '20 to 99 employees','10 to 19 employees','Fewer than 10 employees'])]

# %%
data.shape
# Out:
# (32482, 38)

# %% [markdown]
# We have now about 32K records to work with for the analysis . Seems to be a decent amount though.

# %% [markdown]
# Let us check what percent of total data does it form

# %%
#Determing the perentage of people in startup/smallscale IT frim
x=['Startup/Small Scale', 'Rest']
y=[len(data)/len(analysis_data),(len(analysis_data)-len(data))/len(analysis_data)]
plt.bar(x,y)
plt.xlabel('Data')
plt.ylabel('Percent of total data')
plt.title('People employed in startup');

# %% [markdown]
# That sums up to more than 30% of the entire population of the survey data are in startup/smallscale firms. This bolsters the importance of the analysis even more.
#
# Let us check null values in each of the columns.

# %%
#Checking null values in each column
data.isnull().sum()
# Out:
# Hobby                          0
# OpenSource                     0
# Country                        0
# Student                      449
# Employment                     0
# FormalEducation              625
# UndergradMajor              4155
# CompanySize                    0
# DevType                      349
# YearsCoding                   26
# YearsCodingProf             4474
# JobSatisfaction             5147
# CareerSatisfaction          4943
# SalaryType                 13121
# ConvertedSalary            14382
# CommunicationTools         10410
# TimeFullyProductive         9730
# EducationTypes              9172
# SelfTaughtTypes            12892
# LanguageWorkedWith          5356
# LanguageDesireNextYear      7268
# DatabaseWorkedWith          8318
# DatabaseDesireNextYear     11695
# PlatformWorkedWith          9159
# PlatformDesireNextYear     11057
# FrameworkWorkedWith        13916
# FrameworkDesireNextYear    12800
# IDE                         6326
# OperatingSystem             6137
# Methodology                11329
# VersionControl              6557
# CheckInCode                 6935
# WakeTime                    7614
# HoursComputer               7642
# HoursOutside                7686
# SkipMeals                   7694
# Gender                     10206
# Age                        10125
# dtype: int64

# %%
null_col_data=data.isnull().sum()/len(data)*100
null_col_data.plot(kind='barh',figsize=(12,10));

# %% [markdown]
# We can see that although there are null values in many of the columns , but the percentage of null values in any column is not more than 50%. Thus while analysis we can safely remove or not consider the null value records.

# %% [markdown]
# Let us start with the analysis for the quesions mentioned above in the notebook.

# %% [markdown]
# Since there will be many plots in this notebook making a function for the same seems like a good idea

# %%
#Function which plots bar and barh graphs
def plot_bar_graph(df_series, kind='bar', figsize=(10,10),rot=0, x_label=None, y_label=None,title=None):
    '''
    input :
    df_series: Series dataframe object which is to be plotted. 
                Index values taken as x-axis and values as y-axis by defaiul.
    kind : 'bar','barh' (str object).
           Specifies the type of bar graph
    figsize : (x,y) touple object . Determines the dimensions of the figure 
    rot : rotating the x ticks (integer)
    
    Output : plots bar graph and/or saves the image depending on the save argument 
    
    This functions takes a series object and plots the bar graph 
    '''
    plot_object=df_series.plot(kind=kind,rot=rot,title=title,figsize=figsize)
    plot_object.set_xlabel(x_label)
    plot_object.set_ylabel(y_label);

# %% [markdown]
# > ***1. Percentage of People working in Startup/Small Scale firms out of the total survey received.***

# %% [markdown]
# As seen above about 30% of the people work in startup/smallscale firms. Further distribution of them can be found country wise as below.

# %%
data_country_wise=data['Country'].value_counts()*100/len(data)

# %%
#Considering only top 10 
data_country_wise=data_country_wise.sort_values(ascending=False)[:10]
plot_bar_graph(data_country_wise,kind='bar',rot=60,title='Percentage of people vs Country',figsize=(7,5),
              x_label='Country',y_label='Percentage')

# %% [markdown]
# Seems like US and India are currently booming in the number of Startup/Small Scale IT firms with an astonishing 16 and 14 percentage respectively of the total people who participated being from them.

# %% [markdown]
# > ***2. Average Age***

# %% [markdown]
# Average Age in this case signifies how young the workforce in the company is and generally more young the workforce the more creative and out of the box thinking capability as they have not gotten accustomed to the “ways of the industry”. At the same time the higher average age tend to signify more experience,less errors in work and more structured way of thinking. There have been many speculations on the average age found in these firms.

# %% [markdown]
# Let us check the average age.

# %%
data['Age'].value_counts().sum()
# Out:
# 22357

# %% [markdown]
# Seems like we have about 10,000 null values. We will ignore this and plot the distribution raph for age

# %%
age_total_cnt=data['Age'].value_counts().sum()
age_distribution_data=data['Age'].value_counts()/age_total_cnt*100
plot_bar_graph(age_distribution_data,kind='barh',rot=0,title='Age distribution',figsize=(12,5),
              x_label='Percentage',y_label='Age Range')

# %% [markdown]
# As per the plot , the average age should be between 25-30  years. But looking at the data it is based on range of age rather than an integer number. So we will engineer a new feature called AgeMean which will basically be the mean of the range.

# %%
def get_mean_age_value(x):
    '''
    input:
    X(str) - String object
    optupt :
    Returns value based on string 
    
    Returns middle value for the different date ranges
    '''
    
    if x == 'Under 18 years old' :
        return 18
    elif x == '18 - 24 years old' :
        return (18+24)/2
    elif x == '25 - 34 years old' :
        return (25+34)/2
    elif x == '35 - 44 years old' :
        return (35+44)/2
    elif x == '45 - 54 years old' :
        return (45+54)/2
    elif x == '55 - 64 years old' :
        return (55+64)/2
    elif x == '65 years or older' :
        return 65

# %%
#adding a new engineered column AgeMean
data['AgeMean'] = data['Age'].apply(lambda x : get_mean_age_value(x) if x is not np.nan else np.nan )
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#Getting the mean 
data['AgeMean'].mean()
# Out:
# 30.120320257637427

# %% [markdown]
# Since we have taken the mean and not the exact age , average might differ so considering the average between 25-30

# %% [markdown]
# > ***Average Salary***

# %% [markdown]
# It might be one of the most important factor for a salaried worker. I do not have to explain much in this aspect. Currently the ConvertedSalary is in string type, so for the analysis we will convert it to float type

# %%
data['ConvertedSalary']=data['ConvertedSalary'].astype(float);
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
#Plotting the graph for mean salary for each age range 
salary_data=data.groupby(['Age']).mean()['ConvertedSalary']
plot_bar_graph(salary_data,kind='bar',rot=90,title='Salary vs Age',figsize=(7,5),
              x_label='Age',y_label='Salary in USD($)')

# %%
#Getting the average salary
data.ConvertedSalary.mean()
# Out:
# 85099.82359116022

# %% [markdown]
# As per the above plot it can be seen that the maximum average income is of the age group of 55–64 years . Which seems logical as they might be at a higher post compared to the rest. Also the gradual salary rise with age and then fall after 65 years (retirement) perfectly aligns with the logical view in present day.

# %% [markdown]
# Let us see the distribution of Salary with respect to the formal education

# %%
salary_data_education=data.groupby(['FormalEducation']).mean()['ConvertedSalary']
plot_bar_graph(salary_data_education,kind='barh',rot=0,title='Formal Educations vs Average Salary',figsize=(7,5),
              x_label='FormalEducation',y_label='Salary in USD($)')

# %% [markdown]
# Oh! what is this ? I see that people who have not completed any formal education are at the top ? Well many prominent leadership of a startup/small scale IT firm have not necessarily completed their studies. Next seems people who have done their post graduation like PhD, MS, etc. which seems alright.

# %% [markdown]
# > ***Languages Used ***

# %% [markdown]
# The languages mentioned here pertain to the different programming languages which the people have either worked with or are working with. The data for Language is in the form Lang1;Lang2; . We will need to extract the languages used count the maximum number of people using a particular language. This can be done in a function called get_split_count

# %%
#Function to split the srting and get the count
def get_split_count(df,m=10):
    '''
    input : df (dataframe) : data to be split and counted.
            m : (int) to get the top m entries default 10
    output : pandas Series object which has entries as index and the count as values.
    
    This function is used to get the split count of the data which is seperated by  ;
    
    '''
    
    lang_dict=dict()
    len_df=len(df)
    for i in range(len_df) :
        lang_str =df.iloc[i]
        if lang_str is not np.nan :
            lang_list = lang_str.split(';')
            for lang in lang_list :
                if lang in lang_dict :
                    lang_dict[lang] += 1
                else :
                    lang_dict[lang] = 1
    lang_dict=pd.Series(lang_dict,index=lang_dict.keys()).sort_values(ascending=False)[:m]
    lang_dict=lang_dict/len_df*100
    return lang_dict

# %%
#Get top 10 languages
lang_worked_with = get_split_count(data['LanguageWorkedWith'])
#Plot
plot_bar_graph(lang_worked_with,kind='bar',rot=45,title='Languages Worked/Working With',figsize=(7,5),
              x_label='Programming Languages',y_label='Percentage')

# %% [markdown]
# This graph shows top 10 of all the Languages. It can be seen that JavaScript,HTML,CSS are used by more than 50% of the people. It means that 1 in every 2 startups are using any or combination of these three languages. This goes to show how readily available and robust these languages are.

# %% [markdown]
# Let us check for Languages that people desire to work with next year. The data is similar to the languages data. So the same function can be used.

# %%
#Plot top 10 lang desired next year
plot_bar_graph(get_split_count(data['LanguageDesireNextYear']),kind='bar',rot=45,title='Languages Desired To Work With Next Year',figsize=(7,5),
              x_label='Programming Languages',y_label='Percentage')

# %% [markdown]
# Still JavaScript, HTML and CSS remain on the top 3 of the languages people desire to work with during their next year. But surprisingly there is Python at the 4th place which overtook SQL as well as Java.

# %% [markdown]
# > ***Operating Systems Used***

# %% [markdown]
# An operating system basically is a software through which you interact with the computer or server and different programs. Some examples of operating systems used can be Windows, MacOS, etc.

# %%
os_data=data['OperatingSystem'].value_counts()
os_data_len=data['OperatingSystem'].value_counts().sum()
os_data=os_data/os_data_len*100
plot_bar_graph(os_data,kind='bar',rot=0,title='Operating Systems Used',figsize=(7,5),
              x_label='Operating systems',y_label='Percentage')

# %% [markdown]
# It can be seen that more than 40% of the people use Windows as an operating system. This is followed by MacOS and Linux. One of the reason Windows is preferred is due to its simplicity to use and availability.

# %% [markdown]
# > ***Version Control Used***

# %% [markdown]
# Version Control systems are software which manage/log each change done in a file. This is especially useful for backtracking a code or reverting or looking at the history of the code used in any application or software. They are very important in situations wherein a bunch of people work on the same code. The data is similar to Languages data in that the value string is seperated by ';'. Thus following similar analysis process.

# %%
#Plot top version control system used
plot_bar_graph(get_split_count(data['VersionControl']),kind='barh',rot=0,title='Version Control Methods/Systems Used',figsize=(7,5),
              x_label='Percentage',y_label='Version Control')

# %% [markdown]
# A massive 70 % of the proportion use Git as their version control. This just goes to show how popular Git is in IT sector as a version control. It is followed by subversion with 10% only. And only 2 % of the people do not use version control methods /system.

# %% [markdown]
# > ***Percentage of people working as a Hobby***

# %% [markdown]
# It gives distribution on the percentage of people doing work in IT as a hobby.

# %%
data['Hobby'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Hobby is one of the few columns which do not have any missing values

# %%
hobby_data=data['Hobby'].value_counts()/len(data)*100
plot_bar_graph(hobby_data,kind='bar',rot=0,title='Working as Hobby',figsize=(7,5),
              x_label='Hobby',y_label='Percentage')

# %% [markdown]
# It seems a lot of people working in startup/small scale IT firms are working as a hobby. About 80% of the proportion says they are working as a hobby.

# %% [markdown]
# > ***Conclusion***

# %% [markdown]
# Following points can be concluded from the above analysis :
#
# * More than 30 % of currently employed people of IT firm work in startup/ small scale firms. Out of those 30 % , for about 80% of these people the work that they do is like a hobby.
# * USA, India and Germany are the leading countries where these 30% people who are employed belong.
# * Average working age of people can be said to be about 25–30 years with an average salary of about USD 85,000.00 .
# * Java, HTML, CSS continue to be the top languages used . But we can expect some changes as preferences seem to be changing towards Python,C# etc.
# * The most popular and widely used OS system used is Windows and for Version Control systems is Git.
