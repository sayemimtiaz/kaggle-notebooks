# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns  # visualization tool

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['2015.csv', '2016.csv', '2017.csv']

# %%
data =pd.read_csv('../input/2015.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
# Country                          158 non-null object
# Region                           158 non-null object
# Happiness Rank                   158 non-null int64
# Happiness Score                  158 non-null float64
# Standard Error                   158 non-null float64
# Economy (GDP per Capita)         158 non-null float64
# Family                           158 non-null float64
# Health (Life Expectancy)         158 non-null float64
# Freedom                          158 non-null float64
# Trust (Government Corruption)    158 non-null float64
# Generosity                       158 non-null float64
# Dystopia Residual                158 non-null float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %%
data.corr()
# Out:
#                                Happiness Rank        ...          Dystopia Residual
# Happiness Rank                       1.000000        ...                  -0.521999
# Happiness Score                     -0.992105        ...                   0.530474
# Standard Error                       0.158516        ...                   0.083981
# Economy (GDP per Capita)            -0.785267        ...                   0.040059
# Family                              -0.733644        ...                   0.148117
# Health (Life Expectancy)            -0.735613        ...                   0.018979
# Freedom                             -0.556886        ...                   0.062783
# Trust (Government Corruption)       -0.372315        ...                  -0.033105
# Generosity                          -0.160142        ...                  -0.101301
# Dystopia Residual                   -0.521999        ...                   1.000000
#
# [10 rows x 10 columns]

# %% [markdown]
# Correlation map

# %%
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %%
data.tail(15)
# Out:
#                       Country        ...        Dystopia Residual
# 143                     Niger        ...                  1.87877
# 144                  Cambodia        ...                  0.98195
# 145                  Tanzania        ...                  1.38079
# 146                Madagascar        ...                  1.85100
# 147  Central African Republic        ...                  2.72230
# 148                      Chad        ...                  1.94296
# 149                    Guinea        ...                  1.99172
# 150               Ivory Coast        ...                  1.41723
# 151              Burkina Faso        ...                  1.46494
# 152               Afghanistan        ...                  1.95210
# 153                    Rwanda        ...                  0.67042
# 154                     Benin        ...                  1.63328
# 155                     Syria        ...                  0.32858
# 156                   Burundi        ...                  1.83302
# 157                      Togo        ...                  1.56726
#
# [15 rows x 12 columns]

# %%
data.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# MATPLOTLIB Part

# %%
# Scatter Plot 
# x = attack, y = defense
data.plot(kind='scatter', x='Happiness Score', y='Happiness Rank',alpha = 0.5,color = 'red')
plt.xlabel('Happiness Score')              # label = name of label
plt.ylabel('Happiness Rank')
plt.title('Rank - Score Plot')            # title = title of plot
# Out:
# Text(0.5, 1.0, 'Rank - Score Plot')

# %%
data.plot(kind= 'scatter', x = 'Happiness Score' , y =  'Health (Life Expectancy)' , alpha = 0.5 , color= 'b')
plt.xlabel('HS')              
plt.ylabel('HLE')
plt.title('Happiness Score and HLE relation')
# Out:
# Text(0.5, 1.0, 'Happiness Score and HLE relation')

# %%
# Histogram
# bins = number of bar in figure
data.Generosity.plot(kind = 'hist',bins = 50,figsize = (12,12))
plt.show()

# %%
data.Family.plot(kind = 'hist',bins =25 ,figsize = (12,12))
plt.show()

# %%
series = data['Family']        # data['Defense'] = series
print(type(series))
data_frame = data[['Family']]  # data[['Defense']] = data frame
print(type(data_frame))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
# 2 - Filtering pandas with logical_and

data[np.logical_and(data['Family']<1, data['Happiness Score']>7 )]
# Out:
#    Country        ...        Dystopia Residual
# 13  Mexico        ...                  3.60214
#
# [1 rows x 12 columns]

# %%
data[(data['Family']<1) & (data['Happiness Score']>7 )]
# Out:
#    Country        ...        Dystopia Residual
# 13  Mexico        ...                  3.60214
#
# [1 rows x 12 columns]

# %%
c=data['Country']
for i in c:
    print('i is ', i)
print('')

for index, value in enumerate(c):
    print(index,":",value)
print('')

for index, value in data[['Family','Generosity','Happiness Score']][0:10].iterrows():
    print(index,":",value)
# Out:
# i is  Switzerland
# i is  Iceland
# i is  Denmark
# i is  Norway
# i is  Canada
# i is  Finland
# i is  Netherlands
# i is  Sweden
# i is  New Zealand
# i is  Australia
# i is  Israel
# i is  Costa Rica
# i is  Austria
# i is  Mexico
# i is  United States
# i is  Brazil
# i is  Luxembourg
# i is  Ireland
# i is  Belgium
# i is  United Arab Emirates
# i is  United Kingdom
# i is  Oman
# i is  Venezuela
# i is  Singapore
# i is  Panama
# i is  Germany
# i is  Chile
# i is  Qatar
# i is  France
# i is  Argentina
# i is  Czech Republic
# i is  Uruguay
# i is  Colombia
# i is  Thailand
# i is  Saudi Arabia
# i is  Spain
# i is  Malta
# i is  Taiwan
# i is  Kuwait
# i is  Suriname
# i is  Trinidad and Tobago
# i is  El Salvador
# i is  Guatemala
# i is  Uzbekistan
# i is  Slovakia
# i is  Japan
# i is  South Korea
# i is  Ecuador
# i is  Bahrain
# i is  Italy
# i is  Bolivia
# i is  Moldova
# i is  Paraguay
# i is  Kazakhstan
# i is  Slovenia
# i is  Lithuania
# i is  Nicaragua
# i is  Peru
# i is  Belarus
# i is  Poland
# i is  Malaysia
# i is  Croatia
# i is  Libya
# i is  Russia
# i is  Jamaica
# i is  North Cyprus
# i is  Cyprus
# i is  Algeria
# i is  Kosovo
# i is  Turkmenistan
# i is  Mauritius
# i is  Hong Kong
# i is  Estonia
# i is  Indonesia
# i is  Vietnam
# i is  Turkey
# i is  Kyrgyzstan
# i is  Nigeria
# i is  Bhutan
# i is  Azerbaijan
# i is  Pakistan
# i is  Jordan
# i is  Montenegro
# i is  China
# i is  Zambia
# i is  Romania
# i is  Serbia
# i is  Portugal
# i is  Latvia
# i is  Philippines
# i is  Somaliland region
# i is  Morocco
# i is  Macedonia
# i is  Mozambique
# i is  Albania
# i is  Bosnia and Herzegovina
# i is  Lesotho
# i is  Dominican Republic
# i is  Laos
# i is  Mongolia
# i is  Swaziland
# i is  Greece
# i is  Lebanon
# i is  Hungary
# i is  Honduras
# i is  Tajikistan
# i is  Tunisia
# i is  Palestinian Territories
# i is  Bangladesh
# i is  Iran
# i is  Ukraine
# i is  Iraq
# i is  South Africa
# i is  Ghana
# i is  Zimbabwe
# i is  Liberia
# i is  India
# i is  Sudan
# i is  Haiti
# i is  Congo (Kinshasa)
# i is  Nepal
# i is  Ethiopia
# i is  Sierra Leone
# i is  Mauritania
# i is  Kenya
# i is  Djibouti
# i is  Armenia
# i is  Botswana
# i is  Myanmar
# i is  Georgia
# i is  Malawi
# i is  Sri Lanka
# i is  Cameroon
# i is  Bulgaria
# i is  Egypt
# i is  Yemen
# i is  Angola
# i is  Mali
# i is  Congo (Brazzaville)
# i is  Comoros
# i is  Uganda
# i is  Senegal
# i is  Gabon
# i is  Niger
# i is  Cambodia
# i is  Tanzania
# i is  Madagascar
# i is  Central African Republic
# i is  Chad
# i is  Guinea
# i is  Ivory Coast
# i is  Burkina Faso
# i is  Afghanistan
# i is  Rwanda
# i is  Benin
# i is  Syria
# i is  Burundi
# i is  Togo
#
# 0 : Switzerland
# 1 : Iceland
# 2 : Denmark
# 3 : Norway
# 4 : Canada
# 5 : Finland
# 6 : Netherlands
# 7 : Sweden
# 8 : New Zealand
# 9 : Australia
# 10 : Israel
# 11 : Costa Rica
# 12 : Austria
# 13 : Mexico
# 14 : United States
# 15 : Brazil
# 16 : Luxembourg
# 17 : Ireland
# 18 : Belgium
# 19 : United Arab Emirates
# 20 : United Kingdom
# 21 : Oman
# 22 : Venezuela
# 23 : Singapore
# 24 : Panama
# 25 : Germany
# 26 : Chile
# 27 : Qatar
# 28 : France
# 29 : Argentina
# 30 : Czech Republic
# 31 : Uruguay
# 32 : Colombia
# 33 : Thailand
# 34 : Saudi Arabia
# 35 : Spain
# 36 : Malta
# 37 : Taiwan
# 38 : Kuwait
# 39 : Suriname
# 40 : Trinidad and Tobago
# 41 : El Salvador
# 42 : Guatemala
# 43 : Uzbekistan
# 44 : Slovakia
# 45 : Japan
# 46 : South Korea
# 47 : Ecuador
# 48 : Bahrain
# 49 : Italy
# 50 : Bolivia
# 51 : Moldova
# 52 : Paraguay
# 53 : Kazakhstan
# 54 : Slovenia
# 55 : Lithuania
# 56 : Nicaragua
# 57 : Peru
# 58 : Belarus
# 59 : Poland
# 60 : Malaysia
# 61 : Croatia
# 62 : Libya
# 63 : Russia
# 64 : Jamaica
# 65 : North Cyprus
# 66 : Cyprus
# 67 : Algeria
# 68 : Kosovo
# 69 : Turkmenistan
# 70 : Mauritius
# 71 : Hong Kong
# 72 : Estonia
# 73 : Indonesia
# 74 : Vietnam
# 75 : Turkey
# 76 : Kyrgyzstan
# 77 : Nigeria
# 78 : Bhutan
# 79 : Azerbaijan
# 80 : Pakistan
# 81 : Jordan
# 82 : Montenegro
# 83 : China
# 84 : Zambia
# 85 : Romania
# 86 : Serbia
# 87 : Portugal
# 88 : Latvia
# 89 : Philippines
# 90 : Somaliland region
# 91 : Morocco
# 92 : Macedonia
# 93 : Mozambique
# 94 : Albania
# 95 : Bosnia and Herzegovina
# 96 : Lesotho
# 97 : Dominican Republic
# 98 : Laos
# 99 : Mongolia
# 100 : Swaziland
# 101 : Greece
# 102 : Lebanon
# 103 : Hungary
# 104 : Honduras
# 105 : Tajikistan
# 106 : Tunisia
# 107 : Palestinian Territories
# 108 : Bangladesh
# 109 : Iran
# 110 : Ukraine
# 111 : Iraq
# 112 : South Africa
# 113 : Ghana
# 114 : Zimbabwe
# 115 : Liberia
# 116 : India
# 117 : Sudan
# 118 : Haiti
# 119 : Congo (Kinshasa)
# 120 : Nepal
# 121 : Ethiopia
# 122 : Sierra Leone
# 123 : Mauritania
# 124 : Kenya
# 125 : Djibouti
# 126 : Armenia
# 127 : Botswana
# 128 : Myanmar
# 129 : Georgia
# 130 : Malawi
# 131 : Sri Lanka
# 132 : Cameroon
# 133 : Bulgaria
# 134 : Egypt
# 135 : Yemen
# 136 : Angola
# 137 : Mali
# 138 : Congo (Brazzaville)
# 139 : Comoros
# 140 : Uganda
# 141 : Senegal
# 142 : Gabon
# 143 : Niger
# 144 : Cambodia
# 145 : Tanzania
# 146 : Madagascar
# 147 : Central African Republic
# 148 : Chad
# 149 : Guinea
# 150 : Ivory Coast
# 151 : Burkina Faso
# 152 : Afghanistan
# 153 : Rwanda
# 154 : Benin
# 155 : Syria
# 156 : Burundi
# 157 : Togo
#
# 0 : Family             1.34951
# Generosity         0.29678
# Happiness Score    7.58700
# Name: 0, dtype: float64
# 1 : Family             1.40223
# Generosity         0.43630
# Happiness Score    7.56100
# Name: 1, dtype: float64
# 2 : Family             1.36058
# Generosity         0.34139
# Happiness Score    7.52700
# Name: 2, dtype: float64
# 3 : Family             1.33095
# Generosity         0.34699
# Happiness Score    7.52200
# Name: 3, dtype: float64
# 4 : Family             1.32261
# Generosity         0.45811
# Happiness Score    7.42700
# Name: 4, dtype: float64
# 5 : Family             1.31826
# Generosity         0.23351
# Happiness Score    7.40600
# Name: 5, dtype: float64
# 6 : Family             1.28017
# Generosity         0.47610
# Happiness Score    7.37800
# Name: 6, dtype: float64
# 7 : Family             1.28907
# Generosity         0.36262
# Happiness Score    7.36400
# Name: 7, dtype: float64
# 8 : Family             1.31967
# Generosity         0.47501
# Happiness Score    7.28600
# Name: 8, dtype: float64
# 9 : Family             1.30923
# Generosity         0.43562
# Happiness Score    7.28400
# Name: 9, dtype: float64

# %%
x=data['Generosity']>0.4
data[x]
# Out:
#                Country        ...        Dystopia Residual
# 1              Iceland        ...                  2.70201
# 4               Canada        ...                  2.45176
# 6          Netherlands        ...                  2.46570
# 8          New Zealand        ...                  2.26425
# 9            Australia        ...                  2.26646
# 14       United States        ...                  2.51011
# 17             Ireland        ...                  1.97570
# 20      United Kingdom        ...                  1.96994
# 33            Thailand        ...                  2.31945
# 36               Malta        ...                  1.64880
# 73           Indonesia        ...                  1.86399
# 78              Bhutan        ...                  1.63794
# 90   Somaliland region        ...                  2.11032
# 98                Laos        ...                  1.73799
# 118              Haiti        ...                  2.24173
# 128            Myanmar        ...                  1.41805
# 131          Sri Lanka        ...                  0.67108
# 144           Cambodia        ...                  0.98195
# 155              Syria        ...                  0.32858
#
# [19 rows x 12 columns]
