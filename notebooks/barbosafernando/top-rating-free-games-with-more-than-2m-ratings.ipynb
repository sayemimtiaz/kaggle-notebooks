# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
dataset = pd.read_csv('/kaggle/input/top-play-store-games/android-games.csv')

# %%
dataset.info()

# %%
dataset_types = pd.DataFrame(dataset.dtypes, columns=['Data Type'])
dataset_types

# %%
# Get the most true average rating free games.

dataset.query('paid == False and `average rating` > 4.7 and `total ratings` > 2000000')
