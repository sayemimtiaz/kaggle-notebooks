# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#Read the data set of representation
data = pd.read_csv("../input/women-representation-in-city-property-sanfrancisco/WomenRepresentaionInCityProperty-SanFrancisco.csv")
data.head()

# %%
data2 = pd.read_csv("../input/women-representation-in-city-property-sanfrancisco/WomenRepresentaionInCityProperty-SanFrancisco.csv", header=0, na_filter = False)
data2

# %%
#checking missing values
data.isnull().sum()

# %%
data2.Reference.value_counts(normalize=True)

data2.Reference.value_counts(normalize=True).plot.barh()
data2

# %%
data2.Comments.value_counts(normalize=True)
data2.Comments.value_counts(normalize=True).plot.barh()
data2

# %%
data2.Person.value_

# %%
#Dropping the records with person missing in data dataframe.
data = data[~data.Person.isnull()].copy()

#checking the missing values in the dataset.
data.isnull().sum()

# %%
data = data[~data.Reference.isnull()].copy()
data.isnull().sum()

# %%
data = data[~data.Comments.isnull()].copy()
data.isnull().sum()

# %%
data2.Person.value_counts(normalize=True)
data2.Person.value_counts(normalize=True).plot.barh()
data2

# %%
data2.isnull().sum()

# %%
data2.Gender.value_counts(normalize=True)
data2.Gender.value_counts(normalize=True).plot.barh()
data2

# %%
data2.Gender.describe()

# %%
data2.Reference.describe()

# %%
data2.Neighborhoods.describe()

# %%
data.groupby('Gender')['Neighborhoods'].mean()

# %%
GenGro = data.groupby('Gender')['Neighborhoods'].mean()
GenGro

# %%
data2.groupby('Gender')['Neighborhoods'].mean()

# %%
NeiGro = data2.groupby('Gender')['Neighborhoods'].mean()
NeiGro

# %%
plt.scatter(data2.Gender, data2.Neighborhoods)
plt.show()

data2.plot.scatter(x="Gender", y="Neighborhoods")
plt.show()

# %%
Genmax = data2['Gender'].max
Genmax

# %%
Genmin = data2['Gender'].min
Genmin

# %%
df = pd.DataFrame()

# %%
import pandas as pd
df = pd.DataFrame()

# %%
import numpy as np
import pandas as pd

# %%
# !pip install pandas

# %%
out_df = pd.DataFrame([Genmax]).transpose()
out_df = out_df.rename((Genmax))
#out_df [Genmax] = out_df[Genmax].replace([2,0],[0,2])
out_df.to_csv('submission.csv',index=False)
print("success")
