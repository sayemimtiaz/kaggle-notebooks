# %%
import numpy as np
import pandas as pd 
from subprocess import check_output
print(check_output(["ls", "../input/zoo-animal-classification"]).decode("utf8"))
from sklearn import preprocessing
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="white") 
sns.set(style="whitegrid", color_codes=True)
from sklearn.metrics import accuracy_score

# %%
animal=pd.read_csv('../input/zoo-animal-classification/zoo.csv')
ani_class=pd.read_csv('../input/zoo-animal-classification/class.csv')

# %%
animal.head()

# %%
animal.tail()

# %%
ani_class

# %%
animal.info()

# %%
animal.describe()

# %%
print(animal.legs.unique())

# %%
animal.loc[animal['legs'] == 5]

# %%
df=pd.merge(animal,ani_class,how='left',left_on='class_type',right_on='Class_Number')
df.head()

# %%
plt.hist(df.class_type, bins=7)

# %%
sns.factorplot('Class_Type', data=df,kind="count", aspect=2)

# %%
plt.subplots(figsize=(20,15))
ax = plt.axes()
ax.set_title("Correlation Heatmap")
corr = animal.corr()
sns.heatmap(corr, annot=True,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
corr[corr != 1][abs(corr)> 0.7].dropna(how='all', axis=1).dropna(how='all', axis=0)

# %%
df.groupby('Class_Type').mean()

# %%
g = sns.FacetGrid(df, col="Class_Type")
g.map(plt.hist, "legs")
plt.show()
