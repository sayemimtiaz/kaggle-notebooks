# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
gamelist = pd.read_csv("../input/videogamesales/vgsales.csv")

# %%
gamelist.info()

# %%
gamelist.columns

# %%
gamelist.corr()

# %%
f,ax = plt.subplots(figsize= (14,14))
sns.heatmap(gamelist.corr(), annot= True, linewidths= 5, fmt= ".1f", ax=ax)
plt.show()

# %%
gamelist.head(15)

# %%
minGlobal_Sales = gamelist['Global_Sales'].min()
maxGlobal_Sales = gamelist['Global_Sales'].max()
pl = sns.catplot(x = "Platform",y = "Global_Sales", data = gamelist)
pl.set(ylim=(minGlobal_Sales,maxGlobal_Sales))
fig = plt.gcf()
fig.set_size_inches(12,12)

# %%
 #Histogram
gamelist.Global_Sales.plot(kind="hist",bins= 20, figsize=(10,10))

# %%
data_frame = gamelist[["Platform"]]
print(type(data_frame))

# %%
x = gamelist["Global_Sales"]>=29
gamelist[x]

# %% [markdown]
# #####

# %%
gamelist[np.logical_and(gamelist["Global_Sales"]>30, gamelist["EU_Sales"]<10)]

# %%
#It is an action game and games with more than 15 sales in the world.

gamelist[(gamelist["Genre"]=="Action") & (gamelist["Global_Sales"]>15)]

# %%
gamelist.columns

# %%
gamelist.shape

# %%
gamelist.info()

# %%
print(gamelist.Platform.value_counts(dropna=False))

# %%
gamelist.describe()

# %%
import matplotlib.pyplot as plt
list_try = gamelist.boxplot(column="Rank",by="Genre", figsize=(12,8))
plt.show()

# %%
new_data = gamelist.head(8)
new_data

# %%
data_1 = gamelist.head(8)
data_2 = gamelist.tail(8)
conc_data = pd.concat([data_1, data_2],axis=0, ignore_index = True)
conc_data

# %%
data_1 = gamelist["EU_Sales"].head(8)
data_2 = gamelist["JP_Sales"].head(8)
conc_data_col = pd.concat([data_1,data_2],axis=1)
conc_data_col

# %%
gamelist.dtypes

# %%
gamelist["Genre"] = gamelist["Genre"].astype("category")
gamelist["NA_Sales"] = gamelist["NA_Sales"].astype("float")
gamelist.dtypes

# %%
gamelist.info()

# %%
gamelist["Year"].value_counts(dropna=False)

# %%
#NaN = 271
data1=gamelist
gamelist.Year.dropna(inplace = True)

# %%
gamelist.Year.fillna("empty",inplace = True)
assert gamelist.Year.notnull().all()

# %%
gamelist.Year.value_counts(dropna=False)
