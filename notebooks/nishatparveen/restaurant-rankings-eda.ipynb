# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
file_path = '../input/restaurant-business-rankings-2020/Top250.csv'
top_250 = pd.read_csv(file_path, index_col='Rank')

# %%
top_250.head()

# %%
top_250.info()

# %%
top_250['Headquarters'].value_counts()

# %%
top_250['Segment_Category'].value_counts()

# %%
top_250['YOY_Units'] = top_250['YOY_Units'].str.strip('%').astype('float')

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(y=top_250['YOY_Sales'], x=top_250['YOY_Units'])
plt.yticks([])
plt.show()

# %%
sns.lineplot(data=top_250['Sales'])
plt.show()
