# %% [markdown]
# **Ameerika Ühendriikides tulirelvadest põhjustatud surmad aastatel 2012-2014**
#
# Meie andmestik sisaldab endas 101,000 erinevat tulirelvast põhjustatud surmajuhtumit.
# Iga juhtumi kohta on välja toodud põhilised parameetrid:
# * Toimumise aeg
# * Tapmise põhjus
# * Kas tulistas politsei?
# * Ohvri sugu, vanus ja rass
# * Toimumise koht
# * Ohvri haridus
#
# Uurimisküsimused:
# * Mis haridusega sureb tulirelvade läbi inimesi kõige rohkem?
# * Kas tulistamisi toimub mõnedel kuudel vähem?
# * rass ja politseitulistamised
# * Kuidas on seotud vanus ja haridus tulirelvasurmades?
# * Mis vanuses sureb iga rassi kõige enam?

# %%
import numpy as np
import pandas as pd 

# %matplotlib inline
pd.set_option('display.max_rows', 20)

df = pd.read_csv("../input/guns.csv")

df

# %%
df.intent.value_counts(ascending=False)

# %%
df["year"].value_counts()

# %%
df.education.plot.hist(bins=5, grid=False, rwidth=0.8);

# %% [markdown]
# Eelneval histogrammil jaotuvad haridusastmed järgmiselt
# 1. põhiharidus
# 2. keskharidus
# 3. kõrgharidus omandamisel
# 4. kõrgharidus
# 5. algharidus

# %%
df["age"].describe()

# %%
df.plot.scatter("age", "education", alpha=0.002);

# %%
df["month"].value_counts().plot.bar(width=0.9);

# %%
df2 = pd.DataFrame(df.groupby("race")["age"].mean())
df2.sort_values("age", ascending = False)

# %%
df3 = df[df["police"] == 1]
df3.race.value_counts().plot.bar(width=0.9);

# %%
df4 = pd.DataFrame(df.groupby("sex")["age"].mean())
df4

# %%
df5 = df[df["intent"] == 'Suicide']
df5.sex.value_counts(normalize=True)
