# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../input/gufhtugu-publications-dataset-challenge/GP Orders - 4.csv",encoding="unicode_escape", delimiter=',')
df

# %%
df

# %%
df.info()

# %%
df.describe()

# %%
df['City (Billing)'].value_counts()

# %% [markdown]
# # What is the best-selling book?

# %%
df['Book Name'].value_counts()

# %%
print("We can see that انٹرنیٹ سے پیسہ کمائیں is the best seller!")

# %% [markdown]
# # Visualize order status frequency

# %%
print("Histogram of Order Status:")
df['Order Status'].value_counts().plot(kind='bar',color = list('ygb'))

# %%
df['Order Status'].value_counts()

# %%
import seaborn as sns

# %%
sns.countplot('Order Status',data=df)
plt.show()

# %%
df['Order Status'].value_counts().plot.pie(explode=[0.1,0.1,0.1],autopct='%1.1f%%',shadow=True,figsize=(10,8))
plt.show()
