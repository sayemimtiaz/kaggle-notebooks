# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

df = pd.read_csv('../input/credit-card-customers/BankChurners.csv')
df = df.drop(df[df["Attrition_Flag"] =="Existing Customer"].index)
df.head()

# %%
cardCatData = df['Card_Category'].value_counts()
print(cardCatData)
plt.bar(cardCatData.index.tolist(), cardCatData.tolist())
