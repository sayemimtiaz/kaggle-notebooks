# %% [markdown]
# # Which ones will stay?
# Let's have a look

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/kaggle/input/credit-card-customers/BankChurners.csv',
                dtype={'Income_Category' : 'str'}).iloc[:, :-2]


# to be predicted category
y = df['Attrition_Flag']
# Remove target
df.drop(['Attrition_Flag'], axis = 1, inplace = True)

# %%
df.head()
# Income category $ sign problem

# %% [markdown]
# # Let's see what we have

# %%
plt.figure(1, figsize = (4, 3), dpi=100)
axes = plt.gca()
axes.set_ylim([0.5, 0.9])
plt.text(
    x = 0.00,
    y = 0.75,
    s = "16%",
    fontsize = 60,
    color = '#ae012e',
    fontweight = 'medium'
)
plt.text(
    x = 0.0,
    y = 0.63,
    s = "of total data points have \ncustomers who will attrit",
    fontsize = 20,
    color = 'gray'
)
plt.axis('off')
plt.margins(0.0)
plt.show()

# %% [markdown]
# Typically attrition datasets have imbalance in them. This prompts us to use techniques like SMOTE
