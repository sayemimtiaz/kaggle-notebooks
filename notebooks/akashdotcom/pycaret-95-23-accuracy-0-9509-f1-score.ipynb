# %%
pip install pycaret

# %%
import numpy as np
import pandas as pd
import pandas_profiling
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../input/fetal-health-classification/fetal_health.csv')

# %%
pandas_profiling.ProfileReport(df)

# %%
df.head()

# %%
#pycaret
from pycaret.classification import *

# %%
exp_clf = setup(df, target = 'fetal_health', silent = True)

# %%
best = compare_models()

# %%
clf = create_model('catboost', fold = 5)

# %%
tuned_clf = tune_model(clf, n_iter =10)

# %%
interpret_model(tuned_clf)
