# %% [markdown]
# <h1><center>⚡ Pokemon Stats 🐲</center></h1>
# <h3><center>🥊 (Prediction at the end) ✨</center></h3>
# <center><img src= "https://upload.wikimedia.org/wikipedia/commons/thumb/9/98/International_Pok%C3%A9mon_logo.svg/1200px-International_Pok%C3%A9mon_logo.svg.png" alt ="Pokemon" style='width: 400px;'></center>
#
# <h3>The Brand</h3>
# <p>
# Pokémon, (an abbreviation for Pocket Monsters in Japan) is a Japanese media franchise managed by The Pokémon Company, a company founded by Nintendo, Game Freak, and Creatures. The franchise was created by Satoshi Tajiri in 1995, and is centered on fictional creatures called "Pokémon". In Pokémon, humans, known as Pokémon Trainers, catch and train Pokémon to battle other Pokémon for sport. All media works within the franchise are set in the Pokémon universe. The English slogan for the franchise is "Gotta Catch ‘Em All!". There are currently 900 Pokémon species.
# </p>
#
# <h3>The Types</h3>
# Types refer to different elemental properties associated with both Pokémon and their moves.
#
# There are 18 total official types of Pokémon:
# <center>Normal</center>
# <center><img src= "https://upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Pok%C3%A9mon_Normal_Type_Icon.svg/120px-Pok%C3%A9mon_Normal_Type_Icon.svg.png" alt ="Pokemon" style='width: 15px;'></center>
# <center>Fire</center>
# <center><img src= "https://upload.wikimedia.org/wikipedia/commons/thumb/5/56/Pok%C3%A9mon_Fire_Type_Icon.svg/120px-Pok%C3%A9mon_Fire_Type_Icon.svg.png" alt ="Pokemon" style='width: 15px;'></center>
# <center>Water</center>
# <center><img src= "https://upload.wikimedia.org/wikipedia/commons/thumb/0/0b/Pok%C3%A9mon_Water_Type_Icon.svg/120px-Pok%C3%A9mon_Water_Type_Icon.svg.png" alt ="Pokemon" style='width: 15px;'></center>
# <center>Grass</center>
# <center><img src= "https://upload.wikimedia.org/wikipedia/commons/thumb/f/f6/Pok%C3%A9mon_Grass_Type_Icon.svg/120px-Pok%C3%A9mon_Grass_Type_Icon.svg.png" alt ="Pokemon" style='width: 15px;'></center>
# <center>Electric</center>
# <center><img src= "https://upload.wikimedia.org/wikipedia/commons/thumb/a/a9/Pok%C3%A9mon_Electric_Type_Icon.svg/120px-Pok%C3%A9mon_Electric_Type_Icon.svg.png" alt ="Pokemon" style='width: 15px;'>
# <center>Ice</center>
# <center><img src= "https://upload.wikimedia.org/wikipedia/commons/thumb/8/88/Pok%C3%A9mon_Ice_Type_Icon.svg/120px-Pok%C3%A9mon_Ice_Type_Icon.svg.png" alt ="Pokemon" style='width: 15px;'></center>
# <center>Fighting</center>
# <center><img src= "https://upload.wikimedia.org/wikipedia/commons/thumb/b/be/Pok%C3%A9mon_Fighting_Type_Icon.svg/120px-Pok%C3%A9mon_Fighting_Type_Icon.svg.png" alt ="Pokemon" style='width: 15px;'></center>
# <center>Poison</center>
# <center><img src= "https://upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Pok%C3%A9mon_Poison_Type_Icon.svg/120px-Pok%C3%A9mon_Poison_Type_Icon.svg.png" alt ="Pokemon" style='width: 15px;'> </center>
# <center>Ground</center>
# <center><img src= "https://upload.wikimedia.org/wikipedia/commons/thumb/8/8d/Pok%C3%A9mon_Ground_Type_Icon.svg/120px-Pok%C3%A9mon_Ground_Type_Icon.svg.png" alt ="Pokemon" style='width: 15px;'></center>
# <center>Flying</center>
# <center><img src= "https://upload.wikimedia.org/wikipedia/commons/thumb/e/e0/Pok%C3%A9mon_Flying_Type_Icon.svg/120px-Pok%C3%A9mon_Flying_Type_Icon.svg.png" alt ="Pokemon" style='width: 15px;'></center>
# <center>Psychic</center>
# <center><img src= "https://upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Pok%C3%A9mon_Psychic_Type_Icon.svg/120px-Pok%C3%A9mon_Psychic_Type_Icon.svg.png" alt ="Pokemon" style='width: 15px;'></center>
# <center>Bug</center>
# <center><img src= "https://upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Pok%C3%A9mon_Bug_Type_Icon.svg/120px-Pok%C3%A9mon_Bug_Type_Icon.svg.png" alt ="Pokemon" style='width: 15px;'></center>
# <center>Rock</center>
# <center><img src= "https://upload.wikimedia.org/wikipedia/commons/thumb/b/bb/Pok%C3%A9mon_Rock_Type_Icon.svg/120px-Pok%C3%A9mon_Rock_Type_Icon.svg.png" alt ="Pokemon" style='width: 15px;'></center>
# <center>Ghost</center>
# <center><img src= "https://upload.wikimedia.org/wikipedia/commons/thumb/a/a0/Pok%C3%A9mon_Ghost_Type_Icon.svg/120px-Pok%C3%A9mon_Ghost_Type_Icon.svg.png" alt ="Pokemon" style='width: 15px;'></center>
# <center>Dark</center>
# <center><img src= "https://upload.wikimedia.org/wikipedia/commons/thumb/0/09/Pok%C3%A9mon_Dark_Type_Icon.svg/120px-Pok%C3%A9mon_Dark_Type_Icon.svg.png" alt ="Pokemon" style='width: 15px;'> </center>
# <center>Dragon</center>
# <center><img src= "https://upload.wikimedia.org/wikipedia/commons/thumb/a/a6/Pok%C3%A9mon_Dragon_Type_Icon.svg/120px-Pok%C3%A9mon_Dragon_Type_Icon.svg.png" alt ="Pokemon" style='width: 15px;'></center>
# <center>Steel</center>
# <center><img src= "https://upload.wikimedia.org/wikipedia/commons/thumb/3/38/Pok%C3%A9mon_Steel_Type_Icon.svg/120px-Pok%C3%A9mon_Steel_Type_Icon.svg.png" alt ="Pokemon" style='width: 15px;'></center>
# <center>Fairy</center>
# <center><img src= "https://upload.wikimedia.org/wikipedia/commons/thumb/0/08/Pok%C3%A9mon_Fairy_Type_Icon.svg/120px-Pok%C3%A9mon_Fairy_Type_Icon.svg.png" alt ="Pokemon" style='width: 15px;'> </center>
#
# These 18 types apply to both Pokémon and their moves. Prior to Generation V, there used to be a ??? type which was only applied to the move Curse before having its typing changed, and the Shadow type, which was only present in Pokémon Colosseum and Pokémon XD: Gale of Darkness.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

from sklearn.decomposition import PCA
from sklearn.preprocessing import RobustScaler,StandardScaler,MinMaxScaler
from sklearn.pipeline import make_pipeline

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('../input/pokemon/pokemon.csv')
df = data.copy()
pd.set_option('display.max_row',df.shape[0])
pd.set_option('display.max_column',df.shape[1]) 
df.head()

# %%
corr = df.corr(method='pearson').abs()

fig = plt.figure(figsize=(20,12))
ax = sns.heatmap(corr, annot=True, cmap='Blues', vmin=0, vmax=+1)

ax.axhline(18,0,18/34, ls='--', linewidth=3, color="red")
ax.axvline(18-0.05,16/34,34/34, ls='--', linewidth=3, color="red")
ax.axhline(0+0.05,0,18/34, ls='--', linewidth=3, color="red")
ax.axvline(0.05,16/34,34/34, ls='--', linewidth=3, color="red")

ax.axhline(18,18/34,34/34, ls='--', linewidth=3, color="green")
ax.axvline(18+0.05,0,16/34, ls='--', linewidth=3, color="green")
ax.axhline(34-0.07,18/34,34/34, ls='--', linewidth=3, color="green")
ax.axvline(34-0.07,0,16/34, ls='--', linewidth=3, color="green")

plt.title('Pearson Correlation')
plt.show()

# %% [markdown]
# ## Comments
# - We can see some correlations inside of attack types (red) and other general stats (green)
# - We can also see that general stats don't seem to affect the efficiency of attacks against specific types (not framed in green or red)

# %% [markdown]
# # Visualizing types

# %%
preprocessor = make_pipeline(MinMaxScaler())
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numeric_df = df.select_dtypes(include=numerics)
numeric_df = numeric_df.fillna(numeric_df.mean())
PCAPipeline = make_pipeline(preprocessor, PCA(n_components=3,random_state=0))

# %%
df['type1'].unique()

# %%
df['type2'].unique()

# %%
df['type2'] = df['type2'].fillna('None')

# %%
PCA_df = pd.DataFrame(PCAPipeline.fit_transform(numeric_df))
PCA_df = pd.concat([PCA_df, df['type1']], axis=1)
PCA_df = pd.concat([PCA_df, df['type2']], axis=1)
PCA_df.head()

# %%
figure1 = px.scatter_3d(PCA_df,
        x=0, 
        y=1, 
        z=2, 
        color = 'type1',
                       width=600, height=800)
figure1.update_traces(marker=dict(size=5,
                              line=dict(width=0.2,
                                        color='DarkSlateGrey')),
                  selector=dict(mode='markers'))

figure1.show()

# %%
figure2 = px.scatter_3d(PCA_df,
        x=0, 
        y=1, 
        z=2, 
        color = 'type2',
                       width=600, height=800)

figure2.update_traces(marker=dict(size=5,
                              line=dict(width=0.2,
                                        color='DarkSlateGrey')),
                  selector=dict(mode='markers'))
figure2.show()

# %% [markdown]
# # Strength analysis

# %%
df=data.copy()
df.head()

# %%
strength_df = pd.DataFrame()
strength_features = ['against_bug','against_dark','against_dragon','against_electric','against_fairy',
                     'against_fight','against_fire','against_flying','against_ghost','against_grass',
                     'against_ground','against_ice','against_normal','against_poison','against_psychic',
                     'against_rock','against_steel','against_water']
classic_features = ['attack','defense','hp','sp_attack','sp_defense','speed','type1','type2']
strength_df["against_overall"] = df[strength_features].sum(axis=1)
strength_df = pd.concat([df['name'],strength_df,df[classic_features]],axis=1)
strength_df.head()

# %%
strength_df['attack_overall'] = strength_df['attack']+strength_df['sp_attack']
strength_df['defense_overall'] = strength_df['defense']+strength_df['sp_defense']
strength_df.head()

# %%
figure3 = px.scatter_3d(strength_df,
                        x='attack_overall', 
                        y='defense_overall', 
                        z='against_overall', 
                        color = 'type1',
                        hover_name  = 'name',
                        width=600,
                        height=800)

figure3.update_traces(marker=dict(size=4,
                              line=dict(width=0.2,
                                        color='DarkSlateGrey')),
                  selector=dict(mode='markers'))

figure3.show()

# %%
strongest_df = strength_df[(strength_df['attack_overall']>270) | (strength_df['defense_overall']>290) | (strength_df['against_overall']>23)]
figure4 = px.scatter_3d(strongest_df,
                        x='attack_overall', 
                        y='defense_overall', 
                        z='against_overall', 
                        color = 'type1',
                        hover_name  = 'name',
                        width=600,
                        height=800)

figure4.update_traces(marker=dict(size=4,
                              line=dict(width=0.2,
                                        color='DarkSlateGrey')),
                  selector=dict(mode='markers'))

figure4.show()

# %% [markdown]
# # Conclusion on types strength
#
# #### By looking closely at the scatterplot above, you can tell that a little number of pokemons look way stronger than the others.
# #### For instance : **Schuckle** is the most isolated pokemon. He is really week in attack but super strong in defense (can tank a lot) and is globally strong against other types
# #### We also have **Legendary pokemons** who are a bit isolated, with really great stats (careful not strong against all types !) :
#
# <center>✨</center>
# <center>Mewtwo</center>
# <center>Groudon</center>
# <center>Kyogre</center>
# <center>Latios</center>
#
# #### We can also notice that we have a group of 4 **Rock pokemons** and 3 **Steel pokemons** with **high stats**
#
# <center><img src= "https://upload.wikimedia.org/wikipedia/commons/thumb/b/bb/Pok%C3%A9mon_Rock_Type_Icon.svg/120px-Pok%C3%A9mon_Rock_Type_Icon.svg.png" alt ="Pokemon" style='width: 15px;'></center>
#
# <center>Bastiodon</center>
# <center>Carbink</center>
# <center>Probopass</center>
# <center>Regirock</center>
# <p></p>
# <center><img src= "https://upload.wikimedia.org/wikipedia/commons/thumb/3/38/Pok%C3%A9mon_Steel_Type_Icon.svg/120px-Pok%C3%A9mon_Steel_Type_Icon.svg.png" alt ="Pokemon" style='width: 15px;'></center>
# <center>Aggron</center>
# <center>Steelix</center>
# <center>Registeel</center>
#
# #### In opposite, we can find **very week pokemons** (mainly **Normal types**) such as :
#
# <center><img src= "https://upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Pok%C3%A9mon_Normal_Type_Icon.svg/120px-Pok%C3%A9mon_Normal_Type_Icon.svg.png" alt ="Pokemon" style='width: 15px;'></center>
# <center>Azurill</center>
# <center>Igglybuff</center>
# <center>Jigglypuff</center>
#
#
#
#
# #### On the **topline**, we have **bug and rock pokemons** which are really strong against all other types. A little preference for some rock pokemons who have better attack and defense stats (see paragraph above)
#
# #### And at the **bottomline**, we have **Steel pokemon** who are considered the weakest against all other types

# %% [markdown]
# <h1><center>Conclusion</center></h1>
# <h2><center>Play Rock and Bugs (and use Legendaries carefully)</center></h2>
# <center><img src= "https://upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Pok%C3%A9mon_Bug_Type_Icon.svg/120px-Pok%C3%A9mon_Bug_Type_Icon.svg.png" alt ="Pokemon" style='width: 100px;'><img src= "https://upload.wikimedia.org/wikipedia/commons/thumb/b/bb/Pok%C3%A9mon_Rock_Type_Icon.svg/120px-Pok%C3%A9mon_Rock_Type_Icon.svg.png" alt ="Pokemon" style='width: 100px;'></center>
