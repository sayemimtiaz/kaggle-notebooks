# %% [markdown]
# ## Loan Predicition

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Analysing Train dataset

# %%
df = pd.read_csv("../input/loan-prediction-problem-dataset/train_u6lujuX_CVtuZ9i.csv")
df.head()

# %%
df.info()

# %%
df.isnull().sum()

# %%
df.shape

# %%
df = df.dropna()
df.isnull().sum()

# %%
df = df.drop(["Loan_ID"],axis=1)
df.head()

# %%
df.describe()

# %%
df.replace({"Loan_Status":{'N':0.0,'Y':1.0}},inplace=True)
df.head()

# %%
sns.countplot(x = "Property_Area",hue="Loan_Status",data=df)

# %%
sns.heatmap(df.corr(),annot = True)

# %% [markdown]
# ### Observations:
#
# From the plot it is clear that the Loan Status is positively correlated to the credit history with correlation constant of 0.53 which proves that there are more than 50% chances that the person having more income is more likely to get the loans.

# %%
sns.countplot(x = "Gender",hue="Loan_Status",data=df)

# %% [markdown]
# ### Observation:
#
# The graph clearly shows that if the person is male than he has more chances of getting loan.

# %%
sns.countplot(x="Education",hue="Loan_Status",data=df)

# %% [markdown]
# ### Observation:
#
# The graph clearly shows that if the person is grauate than he/she has more chances of getting loan.

# %%
sns.countplot(x = "Married",hue="Loan_Status",data=df)

# %% [markdown]
# ### Observation:
#
# The graph clearly shows that if the person is married than he/she has more chances of getting loan.

# %%
df2 = df
df2.replace({"Married":{'No':0.0,'Yes':1.0},"Gender":{'Male':1.0,'Female':0.0},"Self_Employed":{'No':0.0,'Yes':1.0},
            "Property_Area":{"Rural":0.0,"Semiurban":1.0,"Urban":2.0},"Education":{'Graduate':1.0,'Not Graduate':0.0}},
            inplace=True)
df2.head()

# %%
df2.replace({"Loan_Status":{'N':0.0,'Y':1.0}},inplace=True)
df2.head()

# %%
df2.isnull().sum()

# %%
df2 = df2.fillna(df2.mean())

# %%
df2.isnull().sum()

# %%
df2 = df2.dropna()

# %%
df2.isnull().sum()

# %%
df2 = df2.replace(to_replace = '3+', value =4)

# %%
df2['Dependents'].value_counts()

# %%
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X = df2.drop("Loan_Status",axis=1)
Y = df2["Loan_Status"]
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=6)

# %%
log = LogisticRegression()
log.fit(x_train,y_train)

# %%
pred = log.predict(x_test)

# %%
accuracy_score(y_test,pred)

# %%
df3 = pd.read_csv('../input/loan-prediction-problem-dataset/test_Y3wMUE5_7gLdaTN.csv')
df3.head()

# %%
df3 = df3.drop("Loan_ID",axis=1)
df3.replace({"Married":{'No':0.0,'Yes':1.0},"Gender":{'Male':1.0,'Female':0.0},"Self_Employed":{'No':0.0,'Yes':1.0},
            "Property_Area":{"Rural":0.0,"Semiurban":1.0,"Urban":2.0},"Education":{'Graduate':1.0,'Not Graduate':0.0}},
            inplace=True)
df3.head()

# %%
df3.shape

# %%
df3 = df3.fillna(df3.mean())

# %%
df3 = df3.replace(to_replace = '3+', value =4)

# %%
df3 = df3.replace(to_replace = np.NaN, value = 0)

# %%
df3.isnull().sum()

# %%
pred = log.predict(df3)

# %%
df3['Loan_Status'] = pred

# %%
df3.head()

# %%
df3.shape
