# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.io as pio
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ***Lecture du dataset***

# %%
df = pd.read_csv("/kaggle/input/netflix-shows/netflix_titles.csv")

# %%
df.head()

# %%
df.shape

# %%
df.isnull().values.any()

# %%
df.corr()

# %%
df.info

# %%
display(df.info(),df.head())

# %% [markdown]
# *pour enlever les nan on va droper les noms des réalisateurs et des acteurs*

# %%
df.drop(["director","cast"],axis =1,inplace=True)

# %%
df.head()

# %%
df['type'].value_counts()

# %%
df['listed_in'].value_counts()

# %%
df['country'].value_counts()

# %%
df['country'].replace(np.nan,"United States",inplace=True)

# %%
df['date_added'].value_counts()

# %%
df['country'].replace(np.nan,"France",inplace=True)

# %%
df['date_added'].value_counts()

# %%
netflix_date = df[['date_added']].replace(np.nan,'Not Added')
netflix_date["release_month"] = netflix_date['date_added'].apply(lambda x: x.lstrip().split(" ")[0])

# %%
netflix_date.head()

# %%
netflix_date["release_month"].value_counts()

# %%
netflix_date.drop("date_added",axis=1,inplace=True)
netflix_date.head()

# %%
netflix = pd.concat([df,netflix_date],axis=1)
netflix.head()

# %%
netflix.drop("date_added",axis=1,inplace=True)
netflix.head()

# %% [markdown]
# **On peut aussi voir le contenu selon la classification :**

# %%
df["rating"].value_counts()

# %%
df["rating"].isnull().sum()

# %% [markdown]
# ***Visualisation graphique du dataset***

# %%
sns.set(style="darkgrid")
ax = sns.countplot(x="type", data=df, palette="Set2")

# %%
plt.figure(figsize=(12,10))
sns.set(style="darkgrid")
ax = sns.countplot(x="rating", data=df, palette="Set2", order=df['rating'].value_counts().index[0:15])

# %% [markdown]
# *On peut representer graphiquement le contenu de la plateforme selon la classification*

# %%
sns.set()
plt.figure(figsize=(25,9))
sns.countplot(x="rating",data= df,hue= "type",order = df['rating'].value_counts().index[0:15])
plt.xticks(rotation=45)
plt.show()

# %%
df.head()

# %% [markdown]
# *Voyons le nombre de sorties apr mois de l'année :*

# %%
sns.set()
plt.figure(figsize=(20,8))
sns.countplot(x="release_month",data= netflix,order = netflix['release_month'].value_counts().index[0:12])
plt.xticks(rotation=45)
plt.show()

# %%
df["country"].value_counts().head()

# %% [markdown]
# *On peux voir que les Etats-Unis sont en tête de classement des créateurs de contenu*

# %%
top = df['country'].value_counts()[0:8]
top.index

# %%
fig = px.pie(netflix,values = top,names = top.index,labels= top.index)
fig.update_traces(textposition ='inside',textinfo='percent+label')
fig.show()

# %% [markdown]
# **Recherche des corrélations**

# %%
tabcorr = df.corr()

# %%
tabcorr

# %%
plt.figure(figsize=(12,12))
sns.heatmap(abs(tabcorr), cmap="coolwarm")

# %% [markdown]
# *On peut voir que ça ne sert à rien de chercher la corrélation entre le nom du programme et l'année de sortie, il faudrait peut-être la faire le type de programme et le nombres de vues si on avait ces données*

# %% [markdown]
# ***Voyons le contenu de la plateforme par genre***

# %%
top_listed_in=netflix["listed_in"].value_counts()[0:25]
top_listed_in.head()

# %%
fig = px.pie(netflix,values = top_listed_in,names = top_listed_in.index,labels= top_listed_in.index)
fig.update_traces(textposition ='inside',textinfo='percent+label')
fig.show()

# %% [markdown]
# ***Regardons par exemple le nombre de vieux films qui sont sur la plateforme***

# %%
old = netflix.sort_values("release_year",ascending=True)
old[["title","type","country","release_year"]].head(20)

# %% [markdown]
# *Selon le pays d'origine du contenu :*

# %%
netflix[netflix["country"] == "France"]

# %%
netflix[netflix["country"] == "United Kingdom"]

# %%
Country = pd.DataFrame(df["country"].value_counts().reset_index().values,columns=["country","TotalShows"])
Country.head()

# %% [markdown]
# *On peut afficher les pays les plus créateurs de contenu :*

# %%
top20=top[0:20]
top20.plot(kind='bar',x='title',y='no_of_shows', color='purple')
