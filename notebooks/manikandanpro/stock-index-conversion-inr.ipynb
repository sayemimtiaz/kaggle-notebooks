# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %% [markdown]
# **Reading the data available in the files and intergrating**

# %%
ii=pd.read_csv("/kaggle/input/stock-exchange-data/indexInfo.csv") #IndexInfo
ii

# %%
iD=pd.read_csv("/kaggle/input/stock-exchange-data/indexData.csv")  #IndexData
iD

# %%
iD.info()

# %%
ip=pd.read_csv("/kaggle/input/stock-exchange-data/indexProcessed.csv") #processed data
ip

# %%
ip.info()

# %% [markdown]
# ***Dropping the NAN columns***

# %%
df=pd.DataFrame(iD)
df.dropna()
df

# %%
df[['Index',"Open",'High',"Low",'Close','Adj Close']]

# %% [markdown]
# **(0) United States	New York Stock Exchange	NYA	USD**
#
# 1.00 US Dollar =74.243277 Indian Rupees

# %%
f=df[df.Index=='NYA']
# dropping the rows having NaN values
df = df.dropna()
# To reset the indices 
df = df.reset_index(drop = True)
df['INR_close']=df['Adj Close']*74.243277
print(df[df.Index=='NYA'])

# %%
figure(figsize=(16, 8), dpi=80)
plt.plot(f['Date'],f['Close'])

# %% [markdown]
# **(1) United States	NASDAQ	IXIC	USD**
#
# 1.00 US Dollar =74.243277 Indian Rupees

# %%
f=df[df.Index=='IXIC']
# dropping the rows having NaN values
df = df.dropna()
  
# To reset the indices 
df = df.reset_index(drop = True)
df['INR_close']=df['Adj Close']*74.243277
print(df[df.Index=='IXIC'])

# %%
figure(figsize=(16, 8), dpi=80)
plt.plot(f['Date'],f['Close'])

# %% [markdown]
# **(2) Hong Kong	Hong Kong Stock Exchange	HSI	HKD**
#
# 1.00 HKD =9.53884 Indian Rupees

# %%
f=df[df.Index=='HSI']
df['INR_close']=df['Adj Close']*9.53884
# dropping the rows having NaN values
df = df.dropna()
  
# To reset the indices 
df = df.reset_index(drop = True)
print(df[df.Index=='HSI'])

# %%
figure(figsize=(16, 8), dpi=80)
plt.plot(f['Date'],f['Close'])

# %% [markdown]
# **(3) China	Shanghai Stock Exchange	000001.SS	CNY**
#
# 1.00 CNY =11.4606 Indian Rupees

# %%
f=df[df.Index=='000001.SS']
df=df.dropna()
df=df.reset_index(drop=True)
df['INR_close']=df['Adj Close']*11.4606
print(df[df.Index=='000001.SS'])

# %%
figure(figsize=(16, 8), dpi=80)
plt.plot(f['Date'],f['Close'])

# %% [markdown]
# **(4) Japan	Tokyo Stock Exchange	N225	JPY**
#
# 1.00 CNY =0.676722 Indian Rupees

# %%
f=df[df.Index=='N225']
df=df.dropna()
df=df.reset_index(drop=True)
df['INR_close']=df['Adj Close']*0.676722
print(df[df.Index=='N225'])

# %%
figure(figsize=(16, 8), dpi=80)
plt.plot(f['Date'],f['Close'])

# %% [markdown]
# **(5) Europe	Euronext	N100	EUR**
#
# 1.00 EUR =87.0449 Indian Rupees

# %%
f=df[df.Index=='N100']
df=df.dropna()
df=df.reset_index(drop=True)
df['INR_close']=df['Adj Close']*87.0449
print(df[df.Index=='N100'])

# %%
figure(figsize=(16, 8), dpi=80)
plt.plot(f['Date'],f['Close'])

# %% [markdown]
# **(6) China	Shenzhen Stock Exchange	399001.SZ	CNY**
#
# 1.00 CNY =11.4597 Indian Rupees

# %%
f=df[df.Index=='399001.SZ']
df=df.dropna()
df=df.reset_index(drop=True)
df['INR_close']=df['Adj Close']*11.4597
print(df[df.Index=='399001.SZ'])

# %%
figure(figsize=(16, 8), dpi=80)
plt.plot(f['Date'],f['Close'])

# %% [markdown]
# **(7) Canada	Toronto Stock Exchange	GSPTSE	CAD**
#
# 1.00 CAD =58.8842 Indian Rupees

# %%
f=df[df.Index=='GSPTSE']
df=df.dropna()
df=df.reset_index(drop=True)
df['INR_close']=df['Adj Close']*58.8842
print(df[df.Index=='GSPTSE'])

# %%
figure(figsize=(16, 8), dpi=80)
plt.plot(f['Date'],f['Close'])

# %% [markdown]
# **(8) India	National Stock Exchange of India	NSEI	INR**
#
# 1.00 INR =1 Indian Rupees

# %%
f=df[df.Index=='NSEI']
df=df.dropna()
df=df.reset_index(drop=True)
df['INR_close']=df['Adj Close']
print(df[df.Index=='NSEI'])

# %%
figure(figsize=(16, 8), dpi=80)
plt.plot(f['Date'],f['Close'])

# %% [markdown]
# **(9) Germany	Frankfurt Stock Exchange	GDAXI	EUR**
#
# 1.00 EUR =11.4606 Indian Rupees

# %%
f=df[df.Index=='GDAXI']
df=df.dropna()
df=df.reset_index(drop=True)
df['INR_close']=df['Adj Close']*87.0449
print(df[df.Index=='GDAXI'])

# %%
figure(figsize=(16, 8), dpi=80)
plt.plot(f['Date'],f['Close'])

# %% [markdown]
# **(10) Korea	Korea Exchange	KS11	KRW**
#
# 1.00 KRW =0.0634347 Indian Rupees

# %%
f=df[df.Index=='KS11']
df.dropna()
df.reset_index(drop=True)
df['INR_close']=df['Adj Close']*0.0634347
print(df[df.Index=='KS11'])

# %%
figure(figsize=(16, 8), dpi=80)
plt.plot(f['Date'],f['Close'])

# %% [markdown]
# **(11) Switzerland	SIX Swiss Exchange	SSMI	CHF**
#
# 1.00 CHF =81.0973 Indian Rupees

# %%
f=df[df.Index=='SSMI']
df.dropna()
df.reset_index(drop=True)
df['INR_close']=df['Adj Close']*81.0973
print(df[df.Index=='SSMI'])

# %%
figure(figsize=(16, 8), dpi=80)
plt.plot(f['Date'],f['Close'])

# %% [markdown]
# **(12) Taiwan	Taiwan Stock Exchange	TWII	TWD**
#
# 1.00 TWD =3.55520 Indian Rupees

# %%
f=df[df.Index=='TWII']
df.dropna()
df.reset_index(drop=True)
df['INR_close']=df['Adj Close']*3.55520
print(df[df.Index=='TWII'])

# %%
figure(figsize=(16, 8), dpi=80)
plt.plot(f['Date'],f['Close'])

# %% [markdown]
# **(13) South Africa	Johannesburg Stock Exchange	J203.JO	ZAR**
#
# 1.00 ZAR =4.98955 Indian Rupees

# %%
f=df[df.Index=='J203.JO']
df.dropna()
df.reset_index(drop=True)
df['INR_close']=df['Adj Close']*4.98955
print(df[df.Index=='J203.JO'])

# %%
figure(figsize=(16, 8), dpi=80)
plt.plot(f['Date'],f['Close'])
