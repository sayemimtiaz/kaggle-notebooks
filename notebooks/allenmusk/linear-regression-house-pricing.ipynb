# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf

# %%
housing = pd.read_csv('../input/california-housing-prices/housing.csv')

# %%
housing.head()

# %%
housing.info()

# %%
housing.describe()

# %%
housing.groupby('ocean_proximity').size()

# %%
import seaborn as sns

# %%
for columns in housing:
  sns.histplot(data=housing[columns],bins=50)
  print(columns)
  plt.show()

# %%
# median_income looks like an important feature
# household, population, total of rooms and bedrooms as well
# ocean proximity looks a bit important

# %%
df = housing
df.head()

# %%
df.pop('latitude')
df.pop('longitude')

# %%
data = df
data.pop('ocean_proximity')

# %%
data['housing_median_age'].isna().sum()

# %%
data['total_bedrooms'].isna().sum()

# %%
data['total_rooms'].isna().sum()

# %%
data['population'].isna().sum()

# %%
data['households'].isna().sum()

# %%
data['median_income'].isna().sum()

# %%
data['total_bedrooms'].median()

# %%
data['total_bedrooms'] = data['total_bedrooms'].fillna(435)

# %%
data['total_bedrooms'].isna().sum()

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(data, test_size=0.2)

# %%
y_train = train.pop('median_house_value')

# %%
x_train = train

# %%
y_test = test.pop('median_house_value')

# %%
x_test = test

# %%
x_train.head()

# %%
y_test.head()

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import r2_score

# %%
x_train.pop('housing_median_age')
x_test.pop('housing_median_age')

# %%
x_train.shape

# %%
y_train.shape

# %%
model = LinearRegression()
model.fit(x_train,y_train)

# %%
predictions = model.predict(x_test)
predictions

# %%
predictions = pd.Series(predictions)
predictions

# %%
y_test

# %%
desempenho = pd.DataFrame()
predictions = pd.DataFrame(data = predictions)
predictions

# %%
y_test = pd.DataFrame(data= y_test)
y_test

# %%
y_test.reset_index()
y_test

# %%
y_test.reset_index().pop('index')
y_test

# %%
predictions

# %%
predictions

# %%
y_test = y_test.reset_index()

# %%
y_test.pop('index')

# %%
performance = pd.concat([predictions, y_test], axis =1)

# %%
performance['erro'] = (performance['median_house_value']- performance[0])/performance['median_house_value']

# %%
performance['erro_abs'] = performance['erro'].abs()

# %%
performance['erro_abs'].mean()
