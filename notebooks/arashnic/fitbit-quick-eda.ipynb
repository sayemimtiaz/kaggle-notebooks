# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# There are 18 csv files in the current version of the dataset:

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# The next hidden code cells define functions for plotting data. Click on the "Code" button in the published kernel to reveal the hidden code.

# %%
weight_log = pd.read_csv('/kaggle/input/Fitabase Data 4.12.16-5.12.16/weightLogInfo_merged.csv')
weight_log.head()

# %%
weight_log.info()

# %% [markdown]
# Distribution graphs (histogram/bar graph) of sampled columns:

# %%
weight_log[weight_log['Id']==1503960366]

# %%
weight_log['BMI'].hist(bins=30, color='darkcyan')

# %%
weight_log.Id.unique().size

# %%
hr_sec = pd.read_csv('/kaggle/input/Fitabase Data 4.12.16-5.12.16/heartrate_seconds_merged.csv')
hr_sec.head()

# %% [markdown]
# Let's take a quick look at what the data looks like:

# %%
hr_sec.info()

# %% [markdown]
# Distribution graphs (histogram/bar graph) of sampled columns:

# %%
hr_sec.Value.hist(bins=30, color='teal')

# %%
sleep_day = pd.read_csv('/kaggle/input/Fitabase Data 4.12.16-5.12.16/sleepDay_merged.csv')
sleep_day.head()

# %% [markdown]
# Let's take a quick look at what the data looks like:

# %%
sleep_day.shape, sleep_day.Id.unique().size

# %%
sleep_day.describe()

# %% [markdown]
# Distribution graphs (histogram/bar graph) of sampled columns:

# %%
step_day = pd.read_csv('/kaggle/input/Fitabase Data 4.12.16-5.12.16/dailySteps_merged.csv')
step_day.head()

# %%
st = step_day.groupby(['Id', 'ActivityDay'], as_index=False)['StepTotal'].sum()

# %%
st['StepTotal'].plot(figsize=(10, 7))

# %%
st['StepTotal'].hist(bins=30, color='skyblue')

# %%
act_day = pd.read_csv('/kaggle/input/Fitabase Data 4.12.16-5.12.16/dailyActivity_merged.csv')
act_day.head()

# %%
import seaborn as sns
plt.figure(figsize=(15, 12))
sns.heatmap(act_day.drop('Id', axis=1).corr(), annot=True, cmap='coolwarm_r')
