# %%
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # plotting
import seaborn as sns
from sklearn.preprocessing import StandardScaler
plt.style.use('fivethirtyeight')

# %% [markdown]
# There is 1 csv file in the current version of the dataset:

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# ### Let's check 1st file: /kaggle/input/COVID-19_Case_Surveillance_Public_Use_Data.csv

# %%
data = pd.read_csv('/kaggle/input/COVID-19_Case_Surveillance_Public_Use_Data.csv')
data.shape

# %%
data.head(10)

# %%
print(data.cdc_report_dt.min(), data.cdc_report_dt.max())
data.cdc_report_dt.describe()

# %%
sns.heatmap(data.isna(),yticklabels=False,cbar=False)

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data.sex)

# %%
plt.figure(figsize=(20, 7))
sns.countplot(data.age_group, palette='twilight_shifted')

# %%
plt.figure(figsize=(15, 8))
sns.countplot(y=data['Race and ethnicity (combined)'], palette='rainbow')
