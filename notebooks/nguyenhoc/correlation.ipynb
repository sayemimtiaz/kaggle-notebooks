# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))
import matplotlib.pyplot as plt


# Any results you write to the current directory are saved as output.

# %% [markdown]
# # Motivation
# This data set has many infomation about countries in the world.
# I want to find out  any strong correlations  from the data

# %% [markdown]
# # About the data
# * 227 rows,  20 columns
# * Some rows contain Null object but not much:
#  * Net migration                         224 non-null object
#  * Infant mortality (per 1000 births)    224 non-null object
#  * GDP ($ per capita)                    226 non-null float64
#  * Literacy (%)                          209 non-null object
#  * Phones (per 1000)                     223 non-null object
#  * Arable (%)                            225 non-null object
#  * Crops (%)                             225 non-null object
#  * Other (%)                             225 non-null object
#  * Climate                               205 non-null object
#  * Birthrate                             224 non-null object
#  * Deathrate                             223 non-null object
#  * Agriculture                           212 non-null object
#  * Industry                              211 non-null object
#  * Service                               212 non-null object
# * Except "Country" and "Region "column,  the others columns' type are number.
#
#   However all most of them are in  text. These columns should be changed  to number
#  * Pop. Density (per sq. mi.)
#  * Coastline (coast/area ratio)
#  * Net migration
#  * Infant mortality (per 1000 births)
#  * Literacy (%)
#  * Phones (per 1000)
#  * Arable (%)
#  * Crops (%)
#  * Other (%)
#  * Climate
#  * Birthrate
#  * Deathrate
#  * Agriculture
#  * Industry
#  * Service

# %%
df = pd.read_csv("../input/countries of the world.csv")
df.head(10)

# %%
df.shape

# %%
df.describe()

# %%
df.info()

# %% [markdown]
# # Clean data

# %% [markdown]
# ## Convert column's type to number

# %% [markdown]
# ### Before convert:

# %%
df.info()

# %% [markdown]
# ### After convert:

# %%
columns = df.columns[2:]
for col in columns:
    if (df[col].dtype == "object"):
        df[col] = df[col].str.replace(",",".")
        df[col] = pd.to_numeric(df[col])
df.info()

# %% [markdown]
# ### Describe  data

# %%
df.describe()

# %% [markdown]
# # Find out CORRELATION

# %% [markdown]
# Calculate all correcations

# %%
correlations = df.corr()
correlations

# %% [markdown]
# The correlation value great than 0.4 or less than -0.4 will give something interesting about relationship between 2 columns.
#
# Let's list them first, then look at them closer latter:

# %%
related_columns_set = []
pair_columns = []
for col in correlations.columns:
    #print(col)
    for idx in correlations.index:
        #print(idx)
        if(correlations.loc[idx,col] >  0.4 or correlations.loc[idx,col] < -0.4) and correlations.loc[idx,col] != 1:
            if(idx+"-"+col+":"+str(correlations.loc[idx,col]) not in related_columns_set):
                related_columns_set.append(col+"-"+idx+":"+str(correlations.loc[idx,col]))
                pair_columns.append([col,idx])
                print(col,"-", idx,":", correlations.loc[idx,col])

# %% [markdown]
# # Draw scatter for related columns

# %%
print(len(pair_columns))
pair_columns

# %%
fig, axes = plt.subplots(nrows=14, ncols=2, figsize=(16,48))

i = 0
for pair in pair_columns:    
    #print(i//2, i%2)
    df.plot(x=pair[0],y=pair[1], kind="scatter", ax=axes[i//2, i%2])
    i += 1

# %% [markdown]
# * Population - Area (sq. mi.) : 0.4699850837184817
#  * No comment
# * Infant mortality (per 1000 births) - GDP ($ per capita) : -0.6007739662612172
#  * The higher GDP, the lower Infant mortality
# * Infant mortality (per 1000 births) - Literacy (%) : -0.7655358136241809
#  * The higher Literacy , the lower Infant mortality
# * Infant mortality (per 1000 births) - Phones (per 1000) : -0.6723118556711715
#  * The more Phones , the lower Infant mortality
# * Infant mortality (per 1000 births) - Birthrate : 0.8457641944976056
#  * The lower Birthrate, the lower Infant mortality
# * Infant mortality (per 1000 births) - Deathrate : 0.6563380061326066
#  * The lower Deathrate, the lower Infant mortality

# %% [markdown]
#  ===
# Infant mortality (per 1000 births) - Agriculture : 0.7094750445695917
#
# Infant mortality (per 1000 births) - Service : -0.6339824701168715
#
# GDP ($ per capita) - Literacy (%) : 0.513143541309271
#
# GDP ($ per capita) - Phones (per 1000) : 0.834499275414044
#
# GDP ($ per capita) - Birthrate : -0.6501370279422611
#
# GDP ($ per capita) - Agriculture : -0.5867685622247596
#
# GDP ($ per capita) - Service : 0.5502157117307866
#
# Literacy (%) - Phones (per 1000) : 0.6019350049670077
#
# Literacy (%) - Birthrate : -0.7908461681610454
#
# Literacy (%) - Agriculture : -0.6096380702072316
#
# Literacy (%) - Service : 0.4946074520473804
#
# Phones (per 1000) - Climate : 0.40216068357686774
#
# Phones (per 1000) - Birthrate : -0.7246144139500446
#
# Phones (per 1000) - Agriculture : -0.601738880745303
#
# Phones (per 1000) - Service : 0.6839341196035666
#
# Arable (%) - Other (%) : -0.8567625920902615
#
# Crops (%) - Other (%) : -0.5942544139586196
#
# Climate - Birthrate : -0.4550973586169035
#
# Birthrate - Agriculture : 0.6782071350548277
#
# Birthrate - Service : -0.5576939105217485
#
# Agriculture - Service : -0.6170388230633276
#
# Industry - Service : -0.5445940699994951
