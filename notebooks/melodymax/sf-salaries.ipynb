# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
sal = pd.read_csv('/kaggle/input/sf-salaries/Salaries.csv', na_values='Not Provided')

# %%
sal.head()

# %%
sal.info()

# %%
sal.describe()

# %%
sal['BasePay'].mean()

# %% [markdown]
# **Average Base Pay**

# %%
sal['OvertimePay'].max()

# %% [markdown]
# **Highest amount of Overtime Pay**

# %%
sal.loc[sal['TotalPayBenefits'].idxmax()]['EmployeeName']

# %% [markdown]
# **Highest paid person (including benefits) is Nathaniel Ford, General Manager-Metropolitan Transit Authority**

# %%
sal[sal['JobTitle']=='GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY'].mean()

# %% [markdown]
# **General Manager-Metropolitan Transit Authority makes an average of 399211.275 with benefits**

# %%
sal.loc[sal['TotalPayBenefits'].idxmin()]

# %% [markdown]
# **Lowest paid person (including benefits) is Joe Lopez**

# %%
sal.groupby('Year').mean()['BasePay']

# %% [markdown]
# **Average (mean) BasePay of all employees per year (2011-2014)**

# %%
sal.groupby('Year').mean()['BasePay'].plot(kind='bar')

# %%
sal.groupby('Year').mean()['TotalPayBenefits']

# %% [markdown]
# **Average (mean) TotalPayBenefits of all employees per year (2011-2014)**

# %%
sal.groupby('Year').mean()['TotalPayBenefits'].plot(kind='bar')

# %%
sal['JobTitle'].nunique()

# %% [markdown]
# **Number of unique job titles**

# %%
sal['JobTitle'].value_counts().head()

# %% [markdown]
# **Top 5 most common jobs**

# %%
sal['JobTitle'].apply(lambda str:('chief' in str.lower())).sum()

# %% [markdown]
# **There are 627 people with the word 'Chief' in their job title**
