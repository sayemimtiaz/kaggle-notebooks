# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as  pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
politics=pd.read_csv("../input/indian-candidates-for-general-election-2019/LS_2.0.csv")

# %%
politics = politics.rename(columns={"CRIMINAL\nCASES": "Criminal", "GENERAL\nVOTES": "Genral_votes","POSTAL\nVOTES":"Postal_votes","TOTAL\nVOTES":"Total_votes"})
politics

# %%
list(politics.columns)

# %%
politics.info()

# %% [markdown]
# # Data cleaning

# %%
politics.isnull().sum()

# %%
plt.figure(figsize=(15,8))
sns.heatmap(politics.isnull(),cbar=False,yticklabels=False)

# %%
politics=politics.dropna()

# %%
politics

# %%
politics=politics.drop_duplicates()

# %%
politics

# %%
plt.figure(figsize=(15,8))
sns.heatmap(politics.isnull(),cbar=False,yticklabels=False)

# %% [markdown]
# # As our Data is cleaned lets Analyze it

# %%
politics.info()

# %%
politics

# %% [markdown]
# # The Number of Constituencies from each State

# %%
plt.figure(figsize=(15,8))
sns.set(style="darkgrid")
L1=list(politics["STATE"].value_counts().keys())
L2=list(politics["STATE"].value_counts())
sns.barplot(data=politics,x=L2,y=L1,palette="ch:s=.25,rot=-.25")
plt.xlabel("count")
plt.ylabel("STATE")

# %% [markdown]
# # Uttar Pradesh has the highest number of CONSTITUENCY - 80

# %% [markdown]
# # The second is from Maharashtra - 48

# %%
politics["EDUCATION"].value_counts()

# %%
politics['EDUCATION'] = politics['EDUCATION'].replace('Post Graduate\n','Post Graduate')
politics['EDUCATION'] = politics['EDUCATION'].replace('Not Available','Others')

# %%
plt.figure(figsize=(15,8))
sns.set(style="darkgrid")
L3=list(politics["EDUCATION"].value_counts().keys())
L4=list(politics["EDUCATION"].value_counts())
sns.barplot(data=politics,x=L4,y=L3,palette="ch:s=.25,rot=-.25")
plt.xlabel("count")
plt.ylabel("Education")
plt.title("Education Level of the Candidates")

# %%
# We have 503 candidates with Post Graduation Degree.
#441 have Graduate Degree.
#336 have Graduate Professional Degree (Students who opt to #pursue graduate study seek master or doctoral degrees in a particular discipline).
#There are 256 Candidates with 12th Pass Certificates.
#73 Candidates have Doctrate degree.
#35 Candidtes have No Degree at all.

# %% [markdown]
# # Winning Candidates Educational Degree

# %%
winner = politics[politics['WINNER']==1]
plt.figure(figsize=(15,8))
sns.set(style="darkgrid")
L5=list(winner["EDUCATION"].value_counts().keys())
L6=list(winner["EDUCATION"].value_counts())
sns.barplot(data=politics,x=L6,y=L5,palette="ch:s=.25,rot=-.25")
plt.xlabel("WINNERS")
plt.ylabel("EDUCATION")
plt.title("Winning Candidates Educational Degree")

# %% [markdown]
# # The Highest number of Winners were Post Graduate

# %% [markdown]
# # Youngster

# %%
young=winner[winner["AGE"]<=30]

# %%
young.shape

# %%
young.head()

# %%
plt.figure(figsize=(15,8))
sns.set(style="darkgrid")
L7=list(young["NAME"])
L8=list(young["AGE"])
sns.barplot(data=young,x=L8,y=L7,palette="ch:s=.25,rot=-.25")
plt.xlabel("AGE")
plt.ylabel("NAME")
plt.title("The Youngest Winners")

# %%
#The Youngest Winners
#Top 3 Winner Details:
#1)Name - GODDETI MADHAVI 
#2)Name - Nusrat Jahan Ruhi 
#3) Name - TEJASVI SURYA

# %% [markdown]
# # Seniocitizen Winners

# %%
old=winner[winner["AGE"]>=75]
old=old.sort_values(by=["AGE"],ascending=True)

# %%
old.shape

# %%
old.head()

# %%
plt.figure(figsize=(15,8))
sns.set(style="darkgrid")
L9=list(old["NAME"])
L0=list(old["AGE"])
sns.barplot(data=old,x=L0,y=L9,palette="ch:s=.25,rot=-.25")
plt.xlabel("AGE")
plt.ylabel("NAME")
plt.title("Seniocitizen Winners")

# %%
#The Oldest Winner
#1) Name - DR. SHAFIQUR REHMAN BARQ

# %% [markdown]
# # AGE of people in elections

# %%
plt.figure(figsize=(15,8))
sns.histplot(data=politics,x="AGE",palette="ch:s=.25,rot=-.25")

# %% [markdown]
# # Total Criminal Cases by respective parties

# %%
politics=politics[politics["Criminal"]!="Not Available"]

# %%
politics["Criminal"]=pd.to_numeric(politics["Criminal"])

# %%
criminal_cases = politics.groupby('PARTY')['Criminal'].sum().reset_index().sort_values('Criminal',ascending=False).head(30)

# %%
plt.figure(figsize=(15,8))
plt.title("PARTY Vs. Criminal cases")
sns.barplot(data=criminal_cases,x="Criminal",y="PARTY",palette="ch:s=.25,rot=-.25")
plt.xlabel("Criminal cases")
plt.ylabel("PARTY")

# %%
#Criminal Cases
#1)BJP - 898 Cases
#2)Congress - 734 Cases

# %% [markdown]
# # Female Winners from different Party

# %%
Female_winner=winner[winner["GENDER"]=="FEMALE"]

# %%
plt.figure(figsize=(15,8))
sns.histplot(data=Female_winner,y="PARTY",palette="ch:s=.25,rot=-.25")
plt.title("Female Winners from different Party")

# %% [markdown]
# # Female Winners from different States

# %%
plt.figure(figsize=(15,8))
sns.histplot(data=Female_winner,y="STATE",palette="ch:s=.25,rot=-.25")
plt.title("Female Winners from different States")

# %%
Male_winner=winner[winner["GENDER"]=="MALE"]

# %% [markdown]
# # Male Winners from different Party

# %%
plt.figure(figsize=(15,8))
sns.histplot(data=Male_winner,y="PARTY",palette="ch:s=.25,rot=-.25")
plt.title("Male Winners from different Party")

# %% [markdown]
# # Male Winners from different States

# %%
plt.figure(figsize=(15,8))
sns.histplot(data=Male_winner,y="STATE",palette="ch:s=.25,rot=-.25")
plt.title("Male Winners from different State")

# %% [markdown]
# # Total Votes cast State Wise

# %%
votes=politics.groupby("STATE")["Total_votes"].sum().sort_values(ascending=False).reset_index()

# %%
votes.head()

# %%
plt.figure(figsize=(15,8))
sns.set(style="darkgrid")
A1=list(votes["STATE"])
A2=list(votes["Total_votes"])
sns.barplot(data=votes,x=A2,y=A1,palette="ch:s=.25,rot=-.25")
plt.xlabel("Total_votes")
plt.ylabel("STATE")
plt.title('Total Votes cast State Wise')

# %% [markdown]
# # Total votes casted is highest in UP were the highest

# %% [markdown]
# # Lets check the candidates WRT there category

# %%
caste=politics["CATEGORY"].value_counts().reset_index()

# %%
caste

# %%
caste.rename(columns={"index":"CATEGORY",
                                    "CATEGORY":"count"},inplace=True)

# %%
caste

# %%
plt.figure(figsize=(5,8))
sns.set(style="darkgrid")
A5=list(caste["CATEGORY"])
A6=list(caste["count"])
sns.barplot(data=votes,x=A5,y=A6,palette="ch:s=.25,rot=-.25")
plt.title('Participants from Various Categories')
plt.xlabel("Category")
plt.ylabel("count")

# %% [markdown]
# # Winners from Various Categories

# %%
category = winner['CATEGORY'].value_counts().reset_index()

# %%
category

# %%
category.rename(columns={"index":"CATEGORY",
                                    "CATEGORY":"count"},inplace=True)

# %%
category

# %%
plt.figure(figsize=(5,8))
sns.set(style="darkgrid")
A7=list(category["CATEGORY"])
A8=list(category["count"])
sns.barplot(data=votes,x=A7,y=A8,palette="ch:s=.25,rot=-.25")
plt.title('Winners from Various Categories')
plt.xlabel("Category")
plt.ylabel("count")

# %% [markdown]
# # Lets check the Top 30 winner having maximum criminal cases

# %%
politics.head()

# %%
winner["Criminal"]=pd.to_numeric(winner["Criminal"])

# %%
politics_cri=winner[winner["Criminal"]!=0]

# %%
politics_cri=politics_cri.sort_values(by=["Criminal"],ascending=False)

# %%
politics_cri.head()

# %%
plt.figure(figsize=(17,10))
sns.set(style="darkgrid")
A7=list(politics_cri["NAME"][0:30])
A8=list(politics_cri["Criminal"][0:30])
sns.barplot(data=politics_cri,x=A8,y=A7,palette="ch:s=.25,rot=-.25")
plt.title('Top 30 winner having maximum criminal cases')
plt.xlabel("Criminal cases count")
plt.ylabel("NAME")

# %% [markdown]
# # States with criminal cases

# %%
politics["Criminal"]=pd.to_numeric(politics["Criminal"])

# %%
plt.figure(figsize=(17,10))
sns.set(style="darkgrid")
A9=list(politics["STATE"])
A8=list(politics["Criminal"])
sns.barplot(data=politics,x=A8,y=A9,palette="ch:s=.25,rot=-.25")
plt.title('States with criminal cases')
plt.xlabel("Criminal cases count")
plt.ylabel("STATE")

# %% [markdown]
# # Kerla has maximum cases followed by Diu and Daman and Telengana

# %%
politics_cri.head()

# %%
politics_cri["ASSETS"]=politics_cri["ASSETS"].str.replace("Rs ","")
politics_cri["ASSETS"]=politics_cri["ASSETS"].str.replace("\n  ","")
politics_cri["ASSETS"]=politics_cri["ASSETS"].str.replace("0\n ~","0")

# %%
politics_cri["LIABILITIES"]=politics_cri["LIABILITIES"].str.replace("Rs ","")
politics_cri["LIABILITIES"]=politics_cri["LIABILITIES"].str.replace("\n  "," ")
politics_cri["LIABILITIES"]=politics_cri["LIABILITIES"].str.replace("0\n ~","0")

# %%
politics_cri.head()

# %% [markdown]
# # Lets check ASSETS and LIABILITIES of top 30 political leaders having highest criminal cases

# %%
leader=politics_cri[["NAME","Criminal","ASSETS","LIABILITIES"]][0:30].reset_index()
leader=leader.drop(["index"],axis=1)

# %%
leader

# %% [markdown]
# # Lets check spread of the top 10 political parties of India statewise

# %%
politics['PARTY'].value_counts()[0:10]

# %%
bjp=politics[politics["PARTY"]=="BJP"].STATE.value_counts().reset_index()
inc=politics[politics["PARTY"]=="INC"].STATE.value_counts().reset_index()
ind=politics[politics["PARTY"]=="IND"].STATE.value_counts().reset_index()
bsp=politics[politics["PARTY"]=="BSP"].STATE.value_counts().reset_index()
cpi=politics[politics["PARTY"]=="CPI(M)"].STATE.value_counts().reset_index()
vba=politics[politics["PARTY"]=="VBA"].STATE.value_counts().reset_index()
aitc=politics[politics["PARTY"]=="AITC"].STATE.value_counts().reset_index()
sp=politics[politics["PARTY"]=="SP"].STATE.value_counts().reset_index()
mnm=politics[politics["PARTY"]=="MNM"].STATE.value_counts().reset_index()
ntk=politics[politics["PARTY"]=="NTK"].STATE.value_counts().reset_index()

# %%
#######################################################
plt.figure(figsize=(17,10))
sns.set(style="darkgrid")
sns.barplot(x=bjp["STATE"],y=bjp["index"],palette="ch:s=.25,rot=-.25")
plt.xlabel("count")
plt.ylabel("STATE")
plt.title('Spread of BJP party in states of India')
plt.show()
#######################################################
plt.figure(figsize=(17,10))
sns.set(style="darkgrid")
sns.barplot(x=inc["STATE"],y=inc["index"],palette="ch:s=.25,rot=-.25")
plt.xlabel("count")
plt.ylabel("STATE")
plt.title('Spread of INC party in states of India')
plt.show()
#######################################################
plt.figure(figsize=(17,10))
sns.set(style="darkgrid")
sns.barplot(x=ind["STATE"],y=ind["index"],palette="ch:s=.25,rot=-.25")
plt.xlabel("count")
plt.ylabel("STATE")
plt.title('Spread of IND party in states of India')
plt.show()
#######################################################
plt.figure(figsize=(17,10))
sns.set(style="darkgrid")
sns.barplot(x=bsp["STATE"],y=bsp["index"],palette="ch:s=.25,rot=-.25")
plt.xlabel("count")
plt.ylabel("STATE")
plt.title('Spread of BSP party in states of India')
plt.show()
#######################################################
plt.figure(figsize=(17,10))
sns.set(style="darkgrid")
sns.barplot(x=cpi["STATE"],y=cpi["index"],palette="ch:s=.25,rot=-.25")
plt.xlabel("count")
plt.ylabel("STATE")
plt.title('Spread of CPI(M) party in states of India')
plt.show()
#######################################################
plt.figure(figsize=(17,2))
sns.set(style="darkgrid")
sns.barplot(x=vba["STATE"],y=vba["index"],palette="ch:s=.25,rot=-.25")
plt.xlabel("count")
plt.ylabel("STATE")
plt.title('Spread of VBA party in states of India')
plt.show()
#######################################################
plt.figure(figsize=(17,4))
sns.set(style="darkgrid")
sns.barplot(x=aitc["STATE"],y=aitc["index"],palette="ch:s=.25,rot=-.25")
plt.xlabel("count")
plt.ylabel("STATE")
plt.title('Spread of AITC party in states of India')
plt.show()
#######################################################
plt.figure(figsize=(17,3))
sns.set(style="darkgrid")
sns.barplot(x=sp["STATE"],y=sp["index"],palette="ch:s=.25,rot=-.25")
plt.xlabel("count")
plt.ylabel("STATE")
plt.title('Spread of SP party in states of India')
plt.show()
#######################################################
plt.figure(figsize=(17,3))
sns.set(style="darkgrid")
sns.barplot(x=mnm["STATE"],y=mnm["index"],palette="ch:s=.25,rot=-.25")
plt.xlabel("count")
plt.ylabel("STATE")
plt.title('Spread of MNM party in states of India')
plt.show()
#######################################################
plt.figure(figsize=(17,2))
sns.set(style="darkgrid")
sns.barplot(x=ntk["STATE"],y=ntk["index"],palette="ch:s=.25,rot=-.25")
plt.xlabel("count")
plt.ylabel("STATE")
plt.title('Spread of NTK party in states of India')
plt.show()

# %%
politics.head()

# %% [markdown]
# # Lets check which party has most Senior leaders

# %%
politics_old=politics[politics["AGE"]>=60].PARTY.value_counts().reset_index()

# %%
politics_old.head()

# %%
plt.figure(figsize=(15,8))
sns.set(style="darkgrid")
sns.barplot(x=politics_old["PARTY"][0:30],y=politics_old["index"][0:30],palette="ch:s=.25,rot=-.25")
plt.xlabel("count")
plt.ylabel("PARTY")
plt.title('Top 30 Political Parties having most Senior leaders')
plt.show()

# %% [markdown]
# # Lets check which party has most youngest leaders

# %%
politics_young=politics[politics["AGE"]<=30].PARTY.value_counts().reset_index()

# %%
politics_young.head()

# %%
plt.figure(figsize=(15,8))
sns.set(style="darkgrid")
sns.barplot(x=politics_young["PARTY"][0:30],y=politics_young["index"][0:30],palette="ch:s=.25,rot=-.25")
plt.xlabel("count")
plt.ylabel("PARTY")
plt.title('Top 30 Political Parties having most youngest leaders')
plt.show()
