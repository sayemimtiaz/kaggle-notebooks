# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Insurance data importing
ins=pd.read_csv('/kaggle/input/insurance/insurance_data.csv')

# %%
ins.head()

# %%
#Getting the shape of the dataset
ins.shape

# %%
#Reshaping the data
X1=ins['age'].values
X1=X1.reshape(-1,1)

# %%
#Importing all the necessary libraries and logistic regression classifier and splitting the dataset
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.linear_model import LogisticRegression
xtrain,xtest,ytrain,ytest=train_test_split(X1,ins['bought_insurance'],test_size=0.3,random_state=3)

# %%
#Creating an instance of Logistic Regression
clf=LogisticRegression()
clf.fit(xtrain,ytrain)

# %%
#Printing the accuracy of the predicted value
pred=clf.predict(xtest)
print(pred)
print('Accuracy:',accuracy_score(pred,ytest))

# %%
#Plotting Confusion Matrix
confusion_matrix(ytest,pred)

# %%
#Importing employee attrition dataset
hr=pd.read_csv('/kaggle/input/hr-analytics/HR_comma_sep.csv')

# %%
hr.head()

# %%
#Getting the shape
hr.shape

# %%
#Checking number of variables in Salary Feature
hr['salary'].describe()

# %%
#Describing the dataset for getting insights
hr.describe()

# %%
#Checking whether any null values present in the dataset.
hr.isnull().any()

# %%
#Plotting bar plot showing impact of employee salaries on retention using cross tab
box_sal=pd.crosstab(hr.left, hr.salary)
print(box_sal)
box_sal.plot(kind='bar')

# %%
#Plotting bar charts showing corelation between department and employee retention
bar_dep=pd.crosstab(hr.Department,hr.left)
bar_dep.plot(kind='bar')

# %%
#Converting Categorical value of Salary to numerical one with 1 has low and 2 as medium
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
hr['salary']=encoder.fit_transform(hr['salary'])

# %%
hr.head()

# %%
#Using groupby of left feature with all other variables mean to get to know what all features are important
hr.groupby('left').mean()

# %%
#From the above code we can see there is significant differences between the 1 and 0 of left in 'SATISFACTION LEVEL'
#'AVG MONTHLY HOURS','PROMOTION','WORK ACCIDENT' indicating that these features play crucial role in determining
#the retention of employee.

# %%
#Separating the target variable and using only the required parameters as feature set.
Y=hr['left']
X=hr.drop(['last_evaluation','number_project','salary','Department','left'],axis='columns')

# %%
X.head()

# %%
#Standard Scaler
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler().fit(X)
X_arr=scaler.transform(X)

# %%
#Splitting the dataset with 70-30 Ratio
X_train,X_test,Y_train,Y_test=train_test_split(X_arr,Y,test_size=0.3,random_state=7)

# %%
#Using Logistic Regression  
clf.fit(X_train,Y_train)
pred2=clf.predict(X_test)
print(pred2)

# %%
#Printing the accuracy
print('Accuracy:',accuracy_score(Y_test,pred2))
