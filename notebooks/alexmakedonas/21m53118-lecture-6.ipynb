# %% [markdown]
# # import numpy as np

# %% [markdown]
# ## Nepal covid daily cases vs daily vaccinations

# %%
# pip install pycountry

import pycountry
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

selected_country_1='Nepal'
selected_country_2='Nepal'

df01 = pd.read_csv('../input/covid19-global-dataset/worldometer_coronavirus_daily_data.csv',header=0)
df1 = df01[df01['country']==selected_country_1]

df02 = pd.read_csv('../input/covid-world-vaccination-progress/country_vaccinations.csv',header=0)
df2 = df02[df02['country']==selected_country_2]
df1.index = pd.to_datetime(df1['date'])
df2.index = pd.to_datetime(df2['date'])

# %%
#print(df1.columns)
#print(df2.columns)
#print(np.unique(df02['country']))

# %% [markdown]
# ## Analysis
#
# From this point analysis of data begins

# %%
#fig,ax = plt.subplots(figsize=(10,5))
#ax.plot(df1.index,df1['daily_new_cases'],'b')
#ax1 = ax.twinx()
#plt.plot(df1.index,df1['daily_new_cases'],'b')
#ax1.plot(df2.index,df2['daily_vaccinations'],'r')
#plt.show()

# %% [markdown]
# ## Improved visualization
#
# From here we will use the modules iplot and plotly

# %%
from plotly.offline import iplot
import plotly.graph_objs as go

daily_new_cases = go.Scatter(x=df1.index,y=df1['daily_new_cases'], yaxis='y1',name='Daily confirmed cases')
daily_vaccinations = go.Scatter(x=df2.index,y=df2['daily_vaccinations'], yaxis='y2',name='Daily vaccinations')

layout_obj = go.Layout(title='Covid vs Vaccines',xaxis=dict(title='Date'),yaxis=dict(title='Daily cases'),yaxis2=dict(title='Vaccinations',side='right',overlaying='y'))
fig = go.Figure(data=[daily_new_cases,daily_vaccinations],layout=layout_obj)        
iplot(fig)

# %% [markdown]
# ## Colored tables
#
# Create colored tables

# %%
style_object=df1.style.background_gradient(cmap = 'jet').highlight_max('daily_new_cases').set_caption('Daily cases')
#display(style_object)
style_object=df2.style.background_gradient(cmap = 'jet').highlight_max('daily_vaccinations').set_caption('Daily Vaccinations')
#display(style_object)

# %% [markdown]
# ## Global ranking
# Nepal Ranks at number 42 for total cases.
#
# Nepal Ranks at number 116 for daily vaccinations.
#
# Nepal had a massive sudden surge in cases. This has now occured due to a multitude of factors, it was the perfect strom. Nepal was begining to open up thanks to 7 months of low infection rates. Many social gathering were occuring in the big cities of Nepal. Next the Indian variant began spreading in India and as India began it's lock down hundreds of thousands of Nepali workers began returning homing to Nepal, bringing the variant with them. The variant itself is extremely virulent. Futhermore, the health care system is not capable to care for so many cases and has now collapsed, this means ill poeple stay witht heir families and cannot be helped or properlly isolated. Futhermore, the govenment has been disolved and there is a lot of political turmoil slowing down any progress.
#
# In the daily vaccinations we can see an ubrupt stop in vaccinations. This is because as India began to worsen, they stopped exporting vaccines to Nepal, they were Nepal biggest vaccine supplier. This has left many Nepalis with only one vaccine. Since then, Chine and US are in the process of donating vacciantions to Nepal.
#
# Nepal however, is in a position where there vacciantion administration infrastructure is rapid and solid. With international help they could come out of this urgent situtation in a better condition rather than worse.
#
# Sources:
# https://www.statnews.com/2021/05/26/in-vaccine-apartheid-nepal-is-ground-zero-it-needs-u-s-help/
# https://www.devex.com/news/nepal-struggles-with-a-surge-in-covid-19-cases-99953
# https://www.nbcnews.com/health/health-news/covid-crisis-reaches-nepal-surge-cases-hospitalizations-n1267419
# https://www.dw.com/en/nepal-political-turmoil-unleashes-more-health-risks-during-covid-surge/a-57674304
# https://www.reuters.com/business/healthcare-pharmaceuticals/china-gift-1-million-covid-19-vaccine-doses-nepal-2021-05-26/
# https://www.devex.com/news/nepal-struggles-with-a-surge-in-covid-19-cases-99953

# %%
df01 = df01.groupby('country').sum()['daily_new_cases'].sort_values(ascending=False)[41:42]
print(df01)

#index=df01['country'].index("Nepal") couldn't make this work, apologes I had to give up cause of other h/w


df02 = df02.groupby('country').max()['people_fully_vaccinated_per_hundred'].sort_values(ascending=False)[115:116]
print(df02)
#index=df02['country'].index("Nepal")

# i was trying to normailise by population, but stopped cause I had other h/w, fogive me
#dpop = pd.read_csv('../input/global-population-estimates/data.csv',header=0)
#dpop_2021 = dpop[dpop['Series Name']=='Population, total']
#dpop_2021 = dpop_2021[["Country Name", "2021 [YR2021]"]].sort_values(ascending=False)[0:10]
#dpop_2021 = dpop_2021[["2021 [YR2021]]"].sort_values(ascending=False)[0:10]
#print(dpop_2021)
