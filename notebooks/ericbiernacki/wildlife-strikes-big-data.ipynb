# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
strikes = pd.read_csv('../input/wildlife-strikes/database.csv')
strikes

# %%
strikes.shape

# %%
strikes.info()

# %% [markdown]
# Let's clean up this huge set. For this example we won't need many of the specifics given to answer the questions we're going to ask.

# %%
important = strikes.drop(columns=["Record ID", "Incident Month", "Incident Day", "Operator ID", "Aircraft Type" , "Aircraft Make" , "Aircraft Model", "Aircraft Mass" , "Engine Make" , "Engine Model" , "Engines" , "Engine Type" , "Engine1 Position" , "Engine2 Position"  , "Engine3 Position" , "Engine4 Position" , "Airport ID" , "Airport" , "Fuselage Strike" , "Fuselage Damage" , "Landing Gear Strike" , "Landing Gear Damage" , "Tail Strike" , "Tail Damage" , "Lights Strike" , "Lights Damage" , "Other Strike" , "Other Damage" , "FAA Region" , "Warning Issued" , "Flight Phase" , "Visibility" , "Precipitation" , "Height" , "Engine3 Strike" , "Engine3 Damage" , "Engine4 Strike" , "Engine4 Damage" , "Engine Ingested" , "Propeller Strike" , "Propeller Damage" , "Wing or Rotor Strike" , "Wing or Rotor Damage" , "Radome Strike" , "Radome Damage" , "Windshield Strike" , "Windshield Damage" , "Nose Strike" , "Nose Damage" , "Engine1 Strike" , "Engine1 Damage" , "Engine2 Strike" , "Engine2 Damage" , "Speed" , "Distance" , "Species ID" , "Species Quantity" , "Flight Impact", "Fatalities", "Injuries"])
important

# %% [markdown]
# For obivous reasons, the wildlife that strikes a plane is not always known, and in this case was marked as unknown in the data set and has to be removed.

# %%
important = important.loc[important["Aircraft"] != "UNKNOWN"]
important = important.loc[important["Operator"] != "UNKNOWN"]
important = important.loc[important["Species Name"] != "UNKNOWN BIRD"]
important = important.loc[important["Species Name"] != "UNKNOWN MEDIUM BIRD"]
important = important.loc[important["Species Name"] != "UNKNOWN SMALL BIRD"]
important = important.loc[important["Species Name"] != "UNKNOWN BIRD OR BAT"]
important

# %% [markdown]
# Now that we've done that we can try to answer some questions about this set like: What types of planes have the most strikes? Where to they most often occur? which year had the most strikes? and others

# %%
important.plot.line()

# %% [markdown]
# Obivously, plotting the data just won't be helpful. We're gonna need another way to count and visualize it.

# %% [markdown]
# Using the method value_counts(), we can count the number of occurences in a data set, or in a specific column.

# %%
important.value_counts()

# %%
important['Operator'].value_counts()

# %%
important['Aircraft'].value_counts()

# %%
important['Incident Year'].value_counts()

# %%
important['Species Name'].value_counts()

# %% [markdown]
# This line of code outputs the name of the known wildlife with the most reported wildlife strikes on aircraft from 1990 to 2015, in this case it is the gull with 5811 reported incidents(occurrences in the species name column).

# %% [markdown]
# As we can see using the value_counts() method is extremely effective when working with datasets that are large and that are not just simple numbers.
