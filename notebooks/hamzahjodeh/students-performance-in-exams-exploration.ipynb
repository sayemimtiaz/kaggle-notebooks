# %% [markdown]
# ## The link of the data set:
# https://www.kaggle.com/spscientist/students-performance-in-exams

# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading the data

# %%
df = pd.read_csv('../input/students-performance-in-exams/StudentsPerformance.csv')

# %%
df.head()

# %%
f"The data frame has {df.shape[0]} Rows, and {df.shape[1]} Columns"

# %% [markdown]
# ## Explore the columns

# %% [markdown]
# ### Gender column

# %%
print(f"Feamle: {df['gender'].value_counts()[0]}")
print(f"Male:   {df['gender'].value_counts()[1]}")

# %%
plt.figure(figsize=(10,6))
sns.countplot(y=df.iloc[:,0])
plt.show()

# %% [markdown]
# ### race/ethnicity column

# %%
df['race/ethnicity'].value_counts()

# %%
plt.figure(figsize=(10,6))
sns.countplot(y=df.iloc[:,1])
plt.show()

# %% [markdown]
# ### parental level of education  column

# %%
df['parental level of education'].value_counts()

# %%
plt.figure(figsize=(10,6))
sns.countplot(y=df.iloc[:,2])
plt.show()

# %% [markdown]
# ### lunch column

# %%
print(f"standard:       {df['lunch'].value_counts()[0]}")
print(f"free/reduced:   {df['lunch'].value_counts()[1]}")

# %%
plt.figure(figsize=(10,6))
sns.countplot(y=df.iloc[:,3])
plt.show()

# %% [markdown]
# ### test preparation course column

# %%
print(f"None:      {df['test preparation course'].value_counts()[0]}")
print(f"completed: {df['test preparation course'].value_counts()[1]}")

# %%
plt.figure(figsize=(10,6))
sns.countplot(y=df.iloc[:,4])
plt.show()

# %% [markdown]
# ### math score column

# %%
df.iloc[:,-3].sort_values(ascending=False).value_counts()[:10]

# %% [markdown]
# ### reading score column

# %%
df.iloc[:,-2].sort_values(ascending=False).value_counts()[:10]

# %% [markdown]
# ### writing score column

# %%
df.iloc[:,-1].sort_values(ascending=False).value_counts()[:10]
