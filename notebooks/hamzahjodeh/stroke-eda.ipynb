# %% [markdown]
# # The link of the data set:
# https://www.kaggle.com/fedesoriano/stroke-prediction-dataset

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read the data

# %%
df = pd.read_csv('../input/stroke-prediction-dataset/healthcare-dataset-stroke-data.csv')

# %% [markdown]
# ## Explore the data

# %%
f'The data has {df.shape[0]} Rows and {df.shape[1]} Columns'

# %%
df.head()

# %%
df.isna().sum()

# %%
df.dropna(inplace=True)

# %% [markdown]
# ## Explore the stroke column

# %%
f = df['stroke'].value_counts()
print(f)

sns.countplot(x=df['stroke'])
plt.show()

# %% [markdown]
# ## Explore the Resideence type column

# %%
f = df['Residence_type'].value_counts()
print(f)

sns.countplot(x=df['Residence_type'])
plt.show()

# %% [markdown]
# ## Explore the work type column

# %%
f = df['work_type'].value_counts()
print(f)

sns.countplot(x=df['work_type'])
plt.show()

# %% [markdown]
# ## Explore the gender column

# %%
f = df['gender'].value_counts()
print(f)

sns.countplot(x=df['gender'])
plt.show()

# %% [markdown]
# ## Explore the smoking status column

# %%
f = df['smoking_status'].value_counts()
print(f)

sns.countplot(x=df['smoking_status'])
plt.show()

# %% [markdown]
# ## Explore the ever marrid column

# %%
f = df['ever_married'].value_counts()
print(f)

sns.countplot(x=df['ever_married'])
plt.show()

# %% [markdown]
# ## Explore the age column

# %%
x = df['age'].value_counts().to_list()
f = df['age'].value_counts().index

for i in range(len(df)):
    if i < 10 :
            print(f'There are: {int(x[i])} At the age:  {f[i]}')

# %% [markdown]
# ## Map the unnumric values to numbers

# %%
df['gender'] = df['gender'].map({'Male':0, 'Female':1, 'Other':2})
df['ever_married'] = df['ever_married'].map({'Yes':0, 'No':1})
df['work_type'] = df['work_type'].map({'Private':0, 'Self-employed':1, 'Govt_job':2, 'children':3, 'Never_worked':4})
df['Residence_type'] = df['Residence_type'].map({'Urban':0, 'Rural':1})
df['smoking_status'] = df['smoking_status'].map({'formerly smoked':0, 'never smoked':1, 'smokes':2, 'Unknown':3})
