# %%
import pandas as pd
import holoviews as hv

hv.extension('bokeh')

# %%
monthly = pd.read_csv('/kaggle/input/gold-prices/monthly_csv.csv', index_col='Date',
            parse_dates=True)
hv.Curve(monthly).opts(width=700, height=400, xrotation=45, show_grid=True)
