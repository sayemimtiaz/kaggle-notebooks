# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.

# %% [markdown]
# ***BUILDING DATA FRAMES FROM SCRATCH***

# %%
guitar_types=["classic","acoustic","bass","electro bass"]
body_types=["les paul","telecaster","strat","V"]
prices=["1000","2000","3000","500"]
list_label=["guitar_types","body_types","prices"]
list_columns=[guitar_types,body_types,prices]
zippedlist=list(zip(list_label,list_columns))
datadict=dict(zippedlist)
datafr=pd.DataFrame(datadict)
datafr

# %%
datafr["string_types"]=["nynlon","nickel","nynlon_nickel","slim nickel"]
datafr

# %%
datafr["string_number"]=6
datafr

# %% [markdown]
# ***VISUAL EXPLORATORY DATA ANALYSIS***

# %%
data=pd.read_csv("../input/pokemon.csv")
data

# %%
dataplot=data.loc[:,["HP","Attack","Defense"]]
dataplot.plot()

# %%
dataplot.plot(subplots=True)
plt.show()

# %%
dataplot.plot(kind="scatter",x="Attack",y="Defense")
plt.show()

# %%
dataplot.plot(kind="hist",y="HP",bins=100,range=(0,500),normed = True)
plt.show()

# %%
fig, axes = plt.subplots(nrows=2,ncols=1)
dataplot.plot(kind = "hist",y = "Defense",bins = 50,range= (0,250),normed = True,ax = axes[0])
dataplot.plot(kind = "hist",y = "Defense",bins = 50,range= (0,250),normed = True,ax = axes[1],cumulative = True)
plt.savefig('graph.png')
plt

# %% [markdown]
# ***STATISTICAL EXPLORATORY DATA ANALYSIS***

# %%
data.describe()

# %% [markdown]
# > ***INDEXING PANDAS TIME SERIES***

# %%
timelist=["1998-12-10","2005-12-03","2005-12-12","2012-04-22","2023-10-10"]
print(type(timelist[1]))
datetimeobject=pd.to_datetime(timelist)
print(type(datetimeobject))

# %%
datatimelist=data.head()
datatimelist["date"]=datetimeobject
datatimelist= datatimelist.set_index("date")
datatimelist

# %%
print(datatimelist.loc["2005-12-03"])
print(datatimelist.loc["2005-12-12":"2023-10-10"])

# %% [markdown]
# > ***RESAMPLING PANDAS TIME SERIES***

# %% [markdown]
# > ***It is for months***

# %%
datatimelist.resample("A").mean()

# %% [markdown]
# > ***It is for years.***

# %%
datatimelist.resample("M").mean()

# %% [markdown]
# *Normally some values are not exist but we can fill these empty values with this function.*

# %%
datatimelist.resample("M").mean().interpolate("linear")

# %% [markdown]
# > ***MANIPULATING DATA FRAMES WITH PANDAS ***

# %%
data = pd.read_csv('../input/pokemon.csv')
data= data.set_index("#")
data.head()

# %%
data[["Type 1","Generation"]].tail(3)

# %% [markdown]
# > ***SLICING DATA FRAME***

# %%
print(type(data["Generation"]))   #with one bracket it is series   
print(type(data[["Generation"]]))  #with two bracket it is data frames

# %%
data.loc[1:56,["Defense","Generation"]]

# %%
data.loc[53:43:-1,["HP","Type 2"]]

# %% [markdown]
# > ***FILTERING DATA FRAMES***

# %%
filterdata1=data.HP<45 
filterdata2=data.Attack<=44
data[filterdata1 & filterdata2]

# %%
data.HP[data.Legendary==False]

# %% [markdown]
# > *** TRANSFORMING DATA> ***

# %%
def function(x):
    return x**2
data.loc[:,["HP","Generation"]].apply(function)

# %%
data.Generation.apply(lambda n : n*2)

# %%
data["total_power"] = (data.Attack + data.Defense)/2
data.head()

# %% [markdown]
# > ***INDEX OBJECTS AND LABELED DATA***

# %%
print(data.index.name)
data.index.name = "index"
data.head()

# %%
datacopy=data.copy()
datacopy.index=range(100,900,1)
datacopy.head(11)

# %% [markdown]
# > ***HIERARCHICAL INDEXING***

# %%
newdata=data.set_index(["Type 1","Type 2"])
newdata.head(10)

# %% [markdown]
# > ***PIVOTING DATA FRAMES***

# %%
dictionry={"brand":["Mercedes","BMW","AUDİ"],"model":["AMG","İ8","A8"],"Age":[1,2,1]}
x=pd.DataFrame(dictionry)

# %%
x.pivot(index="brand",columns = "model",values="Age")
#This code shows NaN because for example Mercedes have not İ8 or A8 model.

# %% [markdown]
# > *** STACKING and UNSTACKING DATAFRAME***

# %%
xx=x.set_index(["brand","model"])

# %%
 xx.unstack(level=0)

# %% [markdown]
# >  MELTING DATA FRAMES
# >

# %%
x

# %%
pd.melt(x,id_vars="brand",value_vars=["Age","model"])

# %% [markdown]
# > ***CATEGORICALS AND GROUPBY***

# %%
x

# %%
x.groupby("brand").mean()

# %%
x.groupby("brand").Age.max()

# %%
x.groupby("brand")[["Age"]].min()
