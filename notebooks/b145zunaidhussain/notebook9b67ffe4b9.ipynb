# %%
import pandas as pd

# %%
##Loading dataset

# %%
data=pd.read_csv('../input/heart-failure-clinical-data/heart_failure_clinical_records_dataset.csv')

# %%
##Displaying the last 3 rows

# %%
data.tail(3)

# %%
##display a column of that dataset having missing values and replace missing values with NaN.

# %%
data.loc[data.creatinine_phosphokinase.isnull()]

# %%
## Since no NAN values are found

# %%
import numpy as np
data_type = [('name', 'S15'), ('class', int), ('height', float)]
students_details = [('Zunaid', 5, 49.5), ('Roy', 6, 52.5),('Edgey', 5, 42.10), ('Tom', 5, 41.11)]
students = np.array(students_details, dtype=data_type)   
print("Original array:")
print(students)
print("Sort by class, then height if class are equal:")
print(np.sort(students, order=['class', 'height']))
