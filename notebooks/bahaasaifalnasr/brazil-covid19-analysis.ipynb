# %% [markdown]
# # first import libaries numpy ,pandas ,os

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('../input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %% [markdown]
# # **then import data**

# %%
data=pd.read_csv('../input/corona-virus-brazil/brazil_covid19.csv')

# %%
data

# %% [markdown]
# # second import matplotlib library to plot data

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# # presenting data type

# %%
type (data)

# %%
type (data.state)

# %% [markdown]
# # ploting state vs suspects

# %%
plt.plot(data.state,data.suspects)
plt.show()

# %% [markdown]
# # ploting state vs deaths

# %%
plt.plot(data.state,data.deaths)
plt.show()

# %% [markdown]
# # ploting cases vs deaths

# %%
plt.plot(data.cases,data.deaths)
plt.show()

# %% [markdown]
# # creating time variable

# %%
time=data.date

# %%
time

# %% [markdown]
# # creating cases variable

# %%
cases=data.cases

# %%
cases

# %% [markdown]
# # ploting date vs cases

# %%
plt.plot(data.date,data.cases)
plt.show()

# %% [markdown]
# # creating data1(time) to obtain total count

# %%
data1=pd.Series((time))

# %%
print (data1.agg(['count']))

# %% [markdown]
# # creating data2(cases) to obtain total mamimum and minmum cases value

# %%
data2=pd.Series((cases))

# %%
print (data2.agg(['max','min','std','max']))

# %% [markdown]
# # creating deaths variable

# %%
deaths=data.deaths

# %%
deaths

# %% [markdown]
# next presenting some parametres for deaths

# %%
deaths=data.deaths
deaths
print (deaths.agg(['max','min','std','max']))

# %% [markdown]
# # ploting deaths vs cases

# %%
ax=plt.axes()
ax.set_xlabel('cases')
ax.set_ylabel('deaths')
plt.plot(data.cases,data.deaths)
plt.show()

# %% [markdown]
# # ploting deaths vs time

# %%
ax=plt.axes()
ax.set_xlabel('time')
ax.set_ylabel('deaths')
plt.plot(data1,deaths)
plt.show()

# %%
deaths.plot(kind='pie')
