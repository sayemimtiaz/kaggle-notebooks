# %% [markdown]
# # SF Salaries Exercise
# using the [SF Salaries Dataset](https://www.kaggle.com/kaggle/sf-salaries) from Kaggle.

# %% [markdown]
# ![](http://)1. ** Importing pandas as pd.**

# %%
import pandas as pd

# %% [markdown]
# ** Reading Salaries.csv file as a dataframe called sal.**

# %%
sal = pd.read_csv("../input/Salaries.csv")

# %% [markdown]
# ** Checking the head of the DataFrame. **

# %%
sal.head()

# %% [markdown]
# ** Using .info() method to find out how many entries are there.**

# %%
sal.info()

# %% [markdown]
# **Since the following data is in string so by using following snippet will convert all the columns to numeric**

# %%
for col in ['BasePay', 'OvertimePay', 'OtherPay', 'Benefits']:
    sal[col] = pd.to_numeric(sal[col], errors='coerce')

# %%
type(sal)

# %%
sal.size

# %%
sal.shape

# %% [markdown]
# **The average BasePay among the jobs:- **

# %%
sal['BasePay'].mean()

# %% [markdown]
# ** The highest amount of OvertimePay in the dataset **

# %%
sal['OvertimePay'].max()

# %% [markdown]
# ** Finding the job title of any random person let say (JOSEPH DRISCOLL)  **

# %%
sal[sal['EmployeeName']=='JOSEPH DRISCOLL']['JobTitle']

# %% [markdown]
# ** How much does JOSEPH DRISCOLL make (including benefits)? **

# %%
sal[sal['EmployeeName']=='JOSEPH DRISCOLL']['TotalPayBenefits']

# %% [markdown]
# ** Finding the name of highest paid person (including benefits).**

# %%
sal[sal['TotalPayBenefits']== sal['TotalPayBenefits'].max()]

# %% [markdown]
# ** Name of lowest paid person (including benefits).**

# %%
sal[sal['TotalPayBenefits']== sal['TotalPayBenefits'].min()]

# %% [markdown]
# ** The average (mean) BasePay of all employees per year (2011-2014) **

# %%
sal.groupby('Year').mean()['BasePay']

# %% [markdown]
# ** Number of unique job titles:-**

# %%
len(sal['JobTitle'].unique())

# %% [markdown]
# ** Top 5 most common jobs **

# %%
sal['JobTitle'].value_counts().head()

# %% [markdown]
# ** How many Job Titles were represented by only one person in 2013? **

# %%
sum(sal[sal['Year']==2013]['JobTitle'].value_counts() == 1)

# %% [markdown]
# ** How many people have the word Chief in their job title? **

# %%
def chief_string(title):
    if 'chief' in title.lower():
        return True
    else:
        return False

# %%
sum(sal['JobTitle'].apply(lambda x: chief_string(x)))

# %% [markdown]
# ## DATA VISUALISATION:- ##

# %% [markdown]
# ** Importing matplotlib and numpy **

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# ** Plotting a graph for visualising the salary trends for all jobs **

# %%
def bar(df, name):
    plt.bar(df.Year, df.TotalPay, color = 'darkorange')
    plt.title('{} Salary Trends'.format(name))
    plt.xticks(np.arange(min(df.Year), max(df.Year)+1, 1.0))
    plt.ylim(min(df.TotalPay)*.99, max(df.TotalPay)*1.01)
    plt.show()
    plt.clf()

# %%
all_groups = sal.groupby(['Year'],as_index=False).mean()
bar(all_groups, 'All Jobs')
