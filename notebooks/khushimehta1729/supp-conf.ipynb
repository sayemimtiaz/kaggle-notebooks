# %%
import numpy as np 
import pandas as pd

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
path = "../input/groceries-dataset/Groceries_dataset.csv"
df = pd.read_csv(path)
df.head(10)

# %%
df.shape

# %%
item_counts=df['itemDescription'].value_counts()

# %%
df['itemDescription'].value_counts()[:10]

# %%
res = df[~df['itemDescription'].isin(item_counts[item_counts < 812].index)]

# %%
len(res)

# %%
res['itemDescription'].value_counts()

# %%
res=res[res.duplicated(subset=['Member_number','Date'], keep=False)]

# %%
dict_t={}

# %%
for i in res['Member_number']:
    dict_t[i]=res[res['Member_number']==i]['itemDescription']

# %%
dict_t[1808]

# %%
res.loc[res['Member_number']==1808]

# %%
li=res[res['Member_number']==1808]['itemDescription']

# %%
li[0]

# %%
for i in res['Member_number']:
    dict_t[i]=list(res[res['Member_number']==i]['itemDescription'])

# %%
#transactions per member number
#dict_t

# %%
dict_2={}

# %%
for k,i in dict_t.items():
    for item in i:
        if (item in dict_2):
            dict_2[item] += 1
        else:
            dict_2[item] = 1

# %%
total=0

# %%
for k, i in dict_2.items():
    total+=i

# %%
dict_2['whole milk']

# %%
support_milk=dict_2['whole milk']/total
support_fruit=dict_2['tropical fruit']/total
support_veg=dict_2['other vegetables']/total
support_bread=dict_2['rolls/buns']/total

# %%
for k,i in dict_2.items():
    print("Support of",k,i/total)

# %%
support_milk

# %%
c=0
for k,i in dict_t.items():
    if 'whole milk'in i and 'rolls/buns' in i:
        c+=1

# %%
conf_mb=c/total #support milk+bread

# %%
conf_mb/support_milk

# %%
conf_mb/support_bread

# %%
d=0
for k,i in dict_t.items():
    if 'whole milk'in i and 'tropical fruit' in i:
        d+=1
d=d/total

# %%
d/support_milk #confidence milk fruits

# %%
d/support_fruit #confidence fruits milk

# %%
e=0
for k,i in dict_t.items():
    if 'whole milk'in i and 'other vegetables' in i:
        e+=1
e=e/total

# %%
e/support_veg #confidence vegetables->whole milk

# %%
# !pip install efficient-apriori

# %%
from efficient_apriori import apriori

# %%
transactions=[]

# %%
for k, i in dict_t.items():
    transactions.append(np.asarray(i))

# %%
transactions[0]

# %%
itemsets, rules = apriori(transactions, min_support=0.1, min_confidence=0.1)

# %%
for i in rules:
    print(i)

# %%
rules[1]
