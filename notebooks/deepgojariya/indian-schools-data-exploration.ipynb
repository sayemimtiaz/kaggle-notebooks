# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Lets First look into data containing schools with water facilities.

# %%
df_sch_water = pd.read_csv('/kaggle/input/indian-school-education-statistics/percentage-of-schools-with-water-facility-2013-2016.csv')

# %%
df_sch_water.head()

# %%
df_sch_water.shape

# %%
df_sch_water.columns

# %%
df_sch_water.isnull().sum()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(15.7,8.27)})

# %%
df_sch_water.groupby('State/UT')['All Schools'].mean()

# %%
df_sch_water.groupby('State/UT')['All Schools'].mean().plot(kind='bar')

# %% [markdown]
# In the Period of 4 years from 2012 to 2016,the total percentage of schools having water facilities in India are 96.11%
# Some of the UT's have well developed schools it seems 5 of them have water facility in each and every school.
# Whereas some of the states in East India like Assam,Arunachal Pradesh,Tripura and Meghalaya have water facilities in only 75% of their schools.
# Rest of the states are having a good water-facility in atleast 90% of their schools.

# %%
df_sch_water[df_sch_water['State/UT']=='Arunachal Pradesh']

# %%
df_sch_water[df_sch_water['State/UT']=='Assam']

# %%
df_sch_water[df_sch_water['State/UT']=='Meghalaya']

# %%
df_sch_water[df_sch_water['State/UT']=='Tripura']

# %% [markdown]
# *All the above results show that the 4 states have very bad water facilitiy in thier Primary Section schools.The overall percentage has increase over the four years of time but is still very low as compared to other states.*

# %% [markdown]
# ************

# %% [markdown]
# # Schools with girls toilet

# %%
df_sch_gt = pd.read_csv('/kaggle/input/indian-school-education-statistics/schools-with-girls-toilet-2013-2016.csv')

# %%
df_sch_gt.shape

# %%
df_sch_gt.isnull().sum()

# %%
df_sch_gt.head()

# %%
df_sch_gt.groupby('State_UT')['All Schools'].mean()

# %%
df_sch_gt.groupby('State_UT')['All Schools'].mean().plot(kind='bar')

# %% [markdown]
# Since women education is been prioritized and also accepted in backward areas of the country ,therefore we can see huge percentage of schools are having girls toilet facility.Some of the developed states do not touch 100% because the data contains boys only schools also.However ,the state of Meghalaya and Assam have the least percentage of schools with girls toilet facility i.e 66% and 78% respectively.We can digest this because these states are not the best developed ones hit by natural calamities all over the year and lack of awareness towards women education in these areas may led to these results.Also less local population may be one of the reasons since people from these areas migrate to other parts of the country for work so it could be a possible case.

# %% [markdown]
# # Schools With Boys Toilets.

# %%
df_sch_bt = pd.read_csv('/kaggle/input/indian-school-education-statistics/schools-with-boys-toilet-2013-2016.csv')

# %%
df_sch_bt.head()

# %%
df_sch_bt.groupby('State_UT')['All Schools'].mean()

# %%
df_sch_bt.groupby('State_UT')['All Schools'].mean().plot(kind='bar')

# %%
df_sch_bt[df_sch_bt['State_UT']=='Andhra Pradesh']

# %% [markdown]
# As we have seen above the states which have underdeveloped education system are listed too frequently in the lack of facilities provided in school.
# This includes states like Assam,Bihar,Meghalaya,Arunachal Praadesh.Which we can see above as well but interesting thing I found is that the state of Andhra Pradesh is having very poor numbers for this case,as low as 73.97% overall.This could be because the state has ever changing goverment and most of its school are goverment controlled and funded by goverment and also boys can litter in open place so they did not require the need for having Boys toilets.But I think the numbers are increasing since,PM Modi announced Swachh Bharat Campaign which focuses on imporving cleanliness in the country and building public toilets wherever nececcary.

# %% [markdown]
# ****

# %% [markdown]
# # Schools with Electricity
#
# I personally think schools should not be allowed to built without an electric conection.

# %%
df_sch_elec = pd.read_csv('/kaggle/input/indian-school-education-statistics/percentage-of-schools-with-electricity-2013-2016.csv')

# %%
df_sch_elec.head()

# %%
df_sch_elec.groupby('State_UT')['All Schools'].mean()

# %%
df_sch_elec[df_sch_elec['State_UT']=='Assam']

# %%
df_sch_elec.groupby('State_UT')['All Schools'].mean().plot(kind='bar')

# %% [markdown]
# Again,very bad numbers in the underdeveloped states.We can only say that this is a very low number and will be improved upon.Since these states do not recieve 24x7 electricity must be a prime reason for these results and also on further researching I came to notice that the Primary and Lower Secondary schools contribute to this schocking results,whereas higher secondary institutes are still having a good percentage of electricity supply,that is the reason why the results have slightly gone up.
# Also the regions which have 100% of their schools equipped with electricity facilities are basically Union Territories and have less,but well developed schools,that's the prime reason their numbers are excellent.
# I firmly believe these numbers have grown in recent times as the goverment today is focusing more in to these development areas.

# %% [markdown]
# ***

# %% [markdown]
# # Schools Having Comuters

# %%
df_sch_comp = pd.read_csv('/kaggle/input/indian-school-education-statistics/percentage-of-schools-with-comps-2013-2016.csv')

# %%
df_sch_comp.head()

# %%
df_sch_comp.groupby('State_UT')['Primary_Only'].mean().plot(kind='bar')

# %%
df_sch_comp.groupby('State_UT')['Primary_with_U_Primary_Sec'].mean().plot(kind='bar')

# %%
df_sch_comp.groupby('State_UT')['Sec_with_HrSec.'].mean().plot(kind='bar')

# %%
df_sch_comp.groupby('State_UT')['All Schools'].mean().plot(kind='bar')

# %% [markdown]
# I think the graphs are self-explanatory if you have followed till here.So the need of computers in a primary school is less as compared to secondary and higher secondary schools and that is the reason why we are seeing these graphs which are very low in Primary but grow in Secondary and higher secondary.
# It is also good to know that many states have a good percentage of their schools havng computer labs in the primary section as well.
# Another factor can be lack of electricity as proven in previous section.

# %% [markdown]
# ***

# %% [markdown]
# # Gross Enrollment Rate

# %%
df_sch_er = pd.read_csv('/kaggle/input/indian-school-education-statistics/gross-enrollment-ratio-2013-2016.csv')

# %%
df_sch_er.head()

# %%
df_sch_er.info()

# %%
df_sch_er.groupby('State_UT')['Upper_Primary_Total'].mean().plot(kind='barh')

# %% [markdown]
# Some of the states have crossed 100% that is because increase in number of admission over the years.

# %% [markdown]
# ***

# %% [markdown]
# # Gross Dropout Rate

# %%
df_sch_dr = pd.read_csv('/kaggle/input/indian-school-education-statistics/dropout-ratio-2012-2015.csv')

# %%
df_sch_dr.head()

# %%
df_sch_dr.replace('NR',0,inplace=True)

# %%
df_sch_dr.replace('Uppe_r_Primary',0,inplace=True)

# %%
df_sch_dr['Upper Primary_Boys'].unique()

# %%
df_sch_dr['Primary_Boys'] = df_sch_dr['Primary_Boys'].astype(float)
df_sch_dr['Primary_Girls'] = df_sch_dr['Primary_Girls'].astype(float)
df_sch_dr['Primary_Total'] = df_sch_dr['Primary_Total'].astype(float)
df_sch_dr['Upper Primary_Girls'] = df_sch_dr['Upper Primary_Girls'].astype(float)
df_sch_dr['Upper Primary_Boys'] = df_sch_dr['Upper Primary_Boys'].astype(float)
df_sch_dr['Upper Primary_Total'] = df_sch_dr['Upper Primary_Total'].astype(float)
df_sch_dr['Secondary _Boys'] = df_sch_dr['Secondary _Boys'].astype(float)
df_sch_dr['Secondary _Girls'] = df_sch_dr['Secondary _Girls'].astype(float)
df_sch_dr['Secondary _Total'] = df_sch_dr['Secondary _Total'].astype(float)
df_sch_dr['HrSecondary_Boys'] = df_sch_dr['HrSecondary_Boys'].astype(float)
df_sch_dr['HrSecondary_Girls'] = df_sch_dr['HrSecondary_Girls'].astype(float)
df_sch_dr['HrSecondary_Total'] = df_sch_dr['HrSecondary_Total'].astype(float)

# %%
df_sch_dr.info()

# %%
df_sch_dr.groupby('State_UT')['Primary_Total'].mean().plot(kind='barh')

# %%
df_sch_dr.groupby('State_UT')['Upper Primary_Total'].mean().plot(kind='barh')

# %%
df_sch_dr.groupby('State_UT')['Secondary _Total'].mean().plot(kind='barh')

# %%
df_sch_dr.groupby('State_UT')['HrSecondary_Total'].mean().plot(kind='barh')

# %% [markdown]
# As we can see due to the migration of poulation towards big cities and towns the dropout rate of underdeveloped states is very much high as compared to the well-Known states consisting of big cities.
# And that is why we have high admission rates in developed states.

# %% [markdown]
# ***

# %% [markdown]
# # Thank You
