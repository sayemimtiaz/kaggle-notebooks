# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))
# Out:
# ['countrieseurope', 'kaggle-survey-2017']

# %%
multiple_choice_df = pd.read_csv("../input/kaggle-survey-2017/multipleChoiceResponses.csv", encoding='latin-1', low_memory=False)
multiple_choice_df.head()
# Out:
#                                         GenderSelect              ...               JobFactorPublishingOpportunity
# 0  Non-binary, genderqueer, or gender non-conforming              ...                                          NaN
# 1                                             Female              ...                                          NaN
# 2                                               Male              ...                               Very Important
# 3                                               Male              ...                                          NaN
# 4                                               Male              ...                                          NaN
#
# [5 rows x 228 columns]

# %%
countries = pd.read_csv("../input/countrieseurope/Countries-Europe.csv", encoding='latin-1')
countries.head()
# Out:
#    zoom     name abbreviation    ...     latitude longitude  continent
# 0     3  Ukraine         Ukr.    ...         49.0      32.0         eu
# 1     3   France          Fr.    ...         46.0       2.0         eu
# 2     3    Spain        Spain    ...         40.0      -4.0         eu
# 3     3   Sweden         Swe.    ...         62.0      15.0         eu
# 4     3  Germany         Ger.    ...         51.5      10.5         eu
#
# [5 rows x 11 columns]

# %%
worklife_questions = ["EmployerSize", "EmployerIndustry", "CurrentJobTitleSelect", "EmploymentStatus", "CodeWriter"]

europe_df = multiple_choice_df.loc[multiple_choice_df.Country.isin(countries.name),
                                   multiple_choice_df.columns.isin(worklife_questions+["Country"]) | (multiple_choice_df.columns.str.contains('WorkChallenge')) ] 
europe_df.shape
# Out:
# (3587, 29)

# %%
europe_df.CodeWriter.value_counts()
# Out:
# Yes    2442
# No      620
# Name: CodeWriter, dtype: int64

# %%
questions = pd.read_csv("../input/kaggle-survey-2017/schema.csv", encoding='latin-1', low_memory=False)
questions.loc[questions.Column.str.contains('WorkChallenge'),:]
# Out:
#                                           Column      ...              Asked
# 228                         WorkChallengesSelect      ...       CodingWorker
# 229                       WorkChallengesFreeForm      ...       CodingWorker
# 230               WorkChallengeFrequencyPolitics      ...       CodingWorker
# 231          WorkChallengeFrequencyUnusedResults      ...       CodingWorker
# 232  WorkChallengeFrequencyUnusefulInstrumenting      ...       CodingWorker
# 233             WorkChallengeFrequencyDeployment      ...       CodingWorker
# 234              WorkChallengeFrequencyDirtyData      ...       CodingWorker
# 235             WorkChallengeFrequencyExplaining      ...       CodingWorker
# 236                   WorkChallengeFrequencyPass      ...       CodingWorker
# 237            WorkChallengeFrequencyIntegration      ...       CodingWorker
# 238                 WorkChallengeFrequencyTalent      ...       CodingWorker
# 239              WorkChallengeFrequencyDataFunds      ...       CodingWorker
# 240        WorkChallengeFrequencyDomainExpertise      ...       CodingWorker
# 241                     WorkChallengeFrequencyML      ...       CodingWorker
# 242                  WorkChallengeFrequencyTools      ...       CodingWorker
# 243           WorkChallengeFrequencyExpectations      ...       CodingWorker
# 244         WorkChallengeFrequencyITCoordination      ...       CodingWorker
# 245            WorkChallengeFrequencyHiringFunds      ...       CodingWorker
# 246                WorkChallengeFrequencyPrivacy      ...       CodingWorker
# 247                WorkChallengeFrequencyScaling      ...       CodingWorker
# 248           WorkChallengeFrequencyEnvironments      ...       CodingWorker
# 249                WorkChallengeFrequencyClarity      ...       CodingWorker
# 250             WorkChallengeFrequencyDataAccess      ...       CodingWorker
# 251            WorkChallengeFrequencyOtherSelect      ...       CodingWorker
# 252          WorkChallengeFrequencyOtherFreeForm      ...       CodingWorker
#
# [25 rows x 3 columns]

# %%
europe_df_coding_workers = europe_df.loc[(europe_df.EmploymentStatus.isin(["Employed full-time", "Employed part-time", "Independent contractor, freelancer, or self-employed"])) &
                                         (europe_df.CodeWriter=='Yes')
                                         ,:]
print(europe_df_coding_workers.shape)
europe_df_coding_workers.EmploymentStatus.value_counts()
# CodingWorker: Respondents who indicated that they were "Employed full-time", "Employed part-time", or an "Independent contractor, freelancer, or self-employed" AND that they write code to analyze data in their current job
# Out:
# (2431, 29)
# Employed full-time                                      2019
# Independent contractor, freelancer, or self-employed     280
# Employed part-time                                       132
# Name: EmploymentStatus, dtype: int64

# %%
europe_df_coding_workers.Country.value_counts()
# Out:
# United Kingdom    382
# Germany           315
# France            306
# Spain             231
# Italy             160
# Netherlands       150
# Poland            119
# Ukraine            98
# Switzerland        91
# Belgium            65
# Ireland            65
# Sweden             59
# Denmark            59
# Portugal           57
# Finland            48
# Czech Republic     45
# Greece             44
# Hungary            40
# Norway             37
# Romania            33
# Belarus            27
# Name: Country, dtype: int64

# %%
europe_df_coding_workers.CurrentJobTitleSelect.value_counts()
# Out:
# Data Scientist                          690
# Scientist/Researcher                    298
# Software Developer/Software Engineer    255
# Data Analyst                            229
# Other                                   191
# Researcher                              128
# Business Analyst                        122
# Machine Learning Engineer               118
# Engineer                                 80
# Computer Scientist                       64
# Statistician                             56
# Programmer                               52
# Predictive Modeler                       30
# DBA/Database Engineer                    27
# Data Miner                               21
# Operations Research Practitioner         10
# Name: CurrentJobTitleSelect, dtype: int64

# %%
europe_df_coding_workers.EmployerIndustry.value_counts()
# Out:
# Academic                            399
# Technology                          371
# Mix of fields                       249
# Financial                           239
# Other                               195
# Internet-based                      167
# CRM/Marketing                       105
# Government                           93
# Telecommunications                   79
# Manufacturing                        59
# Insurance                            57
# Retail                               56
# Pharmaceutical                       49
# Hospitality/Entertainment/Sports     24
# Non-profit                           22
# Military/Security                    18
# Name: EmployerIndustry, dtype: int64

# %%
europe_df_coding_workers.columns[europe_df_coding_workers.columns.str.contains('WorkChallenge')]
# Out:
# Index(['WorkChallengesSelect', 'WorkChallengeFrequencyPolitics',
#        'WorkChallengeFrequencyUnusedResults',
#        'WorkChallengeFrequencyUnusefulInstrumenting',
#        'WorkChallengeFrequencyDeployment', 'WorkChallengeFrequencyDirtyData',
#        'WorkChallengeFrequencyExplaining', 'WorkChallengeFrequencyPass',
#        'WorkChallengeFrequencyIntegration', 'WorkChallengeFrequencyTalent',
#        'WorkChallengeFrequencyDataFunds',
#        'WorkChallengeFrequencyDomainExpertise', 'WorkChallengeFrequencyML',
#        'WorkChallengeFrequencyTools', 'WorkChallengeFrequencyExpectations',
#        'WorkChallengeFrequencyITCoordination',
#        'WorkChallengeFrequencyHiringFunds', 'WorkChallengeFrequencyPrivacy',
#        'WorkChallengeFrequencyScaling', 'WorkChallengeFrequencyEnvironments',
#        'WorkChallengeFrequencyClarity', 'WorkChallengeFrequencyDataAccess',
#        'WorkChallengeFrequencyOtherSelect'],
#       dtype='object')

# %%
for challenge in europe_df_coding_workers.columns[europe_df_coding_workers.columns.str.contains('WorkChallenge')]:
    if challenge not in ['WorkChallengesSelect', 'WorkChallengeFrequencyOtherSelect']:
        display(europe_df_coding_workers.loc[:,challenge].value_counts())
# Out:
# Often               271
# Sometimes           231
# Most of the time    159
# Rarely               30
# Name: WorkChallengeFrequencyPolitics, dtype: int64
# Often               199
# Sometimes           178
# Most of the time     74
# Rarely               15
# Name: WorkChallengeFrequencyUnusedResults, dtype: int64
# Often               75
# Sometimes           71
# Most of the time    26
# Rarely               8
# Name: WorkChallengeFrequencyUnusefulInstrumenting, dtype: int64
# Often               94
# Sometimes           90
# Most of the time    31
# Rarely               8
# Name: WorkChallengeFrequencyDeployment, dtype: int64
# Most of the time    415
# Often               380
# Sometimes           169
# Rarely               11
# Name: WorkChallengeFrequencyDirtyData, dtype: int64
# Often               168
# Sometimes           155
# Most of the time     73
# Rarely               16
# Name: WorkChallengeFrequencyExplaining, dtype: int64
# Most of the time    34
# Rarely              27
# Sometimes           24
# Often               14
# Name: WorkChallengeFrequencyPass, dtype: int64
# Often               107
# Sometimes            87
# Most of the time     49
# Rarely                7
# Name: WorkChallengeFrequencyIntegration, dtype: int64
# Often               287
# Sometimes           220
# Most of the time    216
# Rarely               18
# Name: WorkChallengeFrequencyTalent, dtype: int64
# Sometimes           85
# Often               75
# Most of the time    58
# Rarely              16
# Name: WorkChallengeFrequencyDataFunds, dtype: int64
# Often               155
# Sometimes           117
# Most of the time     71
# Rarely               11
# Name: WorkChallengeFrequencyDomainExpertise, dtype: int64
# Often               72
# Sometimes           69
# Most of the time    25
# Rarely              20
# Name: WorkChallengeFrequencyML, dtype: int64
# Sometimes           125
# Often               124
# Most of the time     72
# Rarely               10
# Name: WorkChallengeFrequencyTools, dtype: int64
# Often               122
# Sometimes           102
# Most of the time     63
# Rarely                8
# Name: WorkChallengeFrequencyExpectations, dtype: int64
# Often               134
# Most of the time    106
# Sometimes           102
# Rarely               13
# Name: WorkChallengeFrequencyITCoordination, dtype: int64
# Most of the time    110
# Often               110
# Sometimes            84
# Rarely                7
# Name: WorkChallengeFrequencyHiringFunds, dtype: int64
# Sometimes           171
# Often               168
# Most of the time     98
# Rarely               21
# Name: WorkChallengeFrequencyPrivacy, dtype: int64
# Often               94
# Sometimes           64
# Most of the time    41
# Rarely              11
# Name: WorkChallengeFrequencyScaling, dtype: int64
# Often               132
# Sometimes           110
# Most of the time     77
# Rarely               17
# Name: WorkChallengeFrequencyEnvironments, dtype: int64
# Often               254
# Sometimes           170
# Most of the time    159
# Rarely               10
# Name: WorkChallengeFrequencyClarity, dtype: int64
# Often               271
# Sometimes           192
# Most of the time    147
# Rarely               15
# Name: WorkChallengeFrequencyDataAccess, dtype: int64

# %%
pd.crosstab(europe_df_coding_workers.Country, europe_df_coding_workers.WorkChallengeFrequencyExpectations, margins='row')
# Out:
# WorkChallengeFrequencyExpectations  Most of the time  Often ...   Sometimes  All
# Country                                                     ...
# Belarus                                            0      0 ...           1    1
# Belgium                                            2      2 ...           5    9
# Czech Republic                                     0      1 ...           1    2
# Denmark                                            3      2 ...           1    6
# Finland                                            3      0 ...           1    5
# France                                             7     16 ...          14   37
# Germany                                           10     20 ...          11   42
# Greece                                             1      0 ...           4    5
# Hungary                                            0      2 ...           0    2
# Ireland                                            0      2 ...           2    5
# Italy                                              5     10 ...           6   21
# Netherlands                                        5      9 ...           5   19
# Norway                                             0      1 ...           3    5
# Poland                                             3      5 ...           7   15
# Portugal                                           0      4 ...           3    7
# Romania                                            1      4 ...           1    6
# Spain                                              6     15 ...           8   29
# Sweden                                             0      2 ...           4    8
# Switzerland                                        2      6 ...           4   12
# Ukraine                                            1      1 ...           2    4
# United Kingdom                                    14     20 ...          19   55
# All                                               63    122 ...         102  295
#
# [22 rows x 5 columns]

# %%
europe_df_coding_workers.loc[:,'WorkChallengesSelectSplit'] = europe_df_coding_workers.WorkChallengesSelect.apply(lambda x: str(x).split(','))
europe_df_coding_workers[['WorkChallengesSelect','WorkChallengesSelectSplit']].head()
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#                                  WorkChallengesSelect                          WorkChallengesSelectSplit
# 23  Lack of data science talent in the organizatio...  [Lack of data science talent in the organizati...
# 26  Dirty data,Lack of data science talent in the ...  [Dirty data, Lack of data science talent in th...
# 28  Difficulties in deployment/scoring,Dirty data,...  [Difficulties in deployment/scoring, Dirty dat...
# 30  Company politics / Lack of management/financia...  [Company politics / Lack of management/financi...
# 31  Limitations of tools,Unavailability of/difficu...  [Limitations of tools, Unavailability of/diffi...

# %%
a = pd.Series([item for sublist in europe_df_coding_workers.WorkChallengesSelectSplit for item in sublist])
total = europe_df_coding_workers.shape[0]
df_workchallenges = a.value_counts().reset_index().rename(columns={'index':'Work Challenge', 0:'Respondents'})
df_workchallenges['Share'] = df_workchallenges.loc[:,'Respondents'] / total
df_workchallenges
# Out:
#                                        Work Challenge    ...        Share
# 0                                          Dirty data    ...     0.409708
# 1     Lack of data science talent in the organization    ...     0.310572
# 2   Company politics / Lack of management/financia...    ...     0.291238
# 3          Unavailability of/difficult access to data    ...     0.260387
# 4   The lack of a clear question to be answering o...    ...     0.249691
# 5                                                 nan    ...     0.240642
# 6   Data Science results not used by business deci...    ...     0.196216
# 7                                      Privacy issues    ...     0.193336
# 8                   Explaining data science to others    ...     0.171123
# 9                          Need to coordinate with IT    ...     0.148910
# 10            Lack of significant domain expert input    ...     0.148499
# 11  Team using multiple ad-hoc development environ...    ...     0.141506
# 12                               Limitations of tools    ...     0.139037
# 13  Organization is small and cannot afford a data...    ...     0.129988
# 14  Maintaining responsible expectations about the...    ...     0.122995
# 15  Inability to integrate findings into organizat...    ...     0.104484
# 16  Lack of funds to buy useful datasets from exte...    ...     0.097079
# 17                 Difficulties in deployment/scoring    ...     0.095023
# 18  Scaling data science solution up to full database    ...     0.088030
# 19  Limitations in the state of the art in machine...    ...     0.077746
# 20  Did not instrument data useful for scientific ...    ...     0.075689
# 21                                I prefer not to say    ...     0.044838
# 22                                              Other    ...     0.027149
#
# [23 rows x 3 columns]

# %%
europe_df_coding_workers.loc[europe_df_coding_workers.WorkChallengesSelect.isnull()].EmploymentStatus.value_counts()
# Out:
# Employed full-time                                      487
# Independent contractor, freelancer, or self-employed     62
# Employed part-time                                       36
# Name: EmploymentStatus, dtype: int64
