# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("../input/pokemon.csv")

data.head()
# Out:
#                      abilities      ...       is_legendary
# 0  ['Overgrow', 'Chlorophyll']      ...                  0
# 1  ['Overgrow', 'Chlorophyll']      ...                  0
# 2  ['Overgrow', 'Chlorophyll']      ...                  0
# 3     ['Blaze', 'Solar Power']      ...                  0
# 4     ['Blaze', 'Solar Power']      ...                  0
#
# [5 rows x 41 columns]

# %%
data['type1'].value_counts().plot.bar()

# %%
data['hp'].value_counts().sort_index().plot.line()

# %%
data['weight_kg'].value_counts().sort_index().plot.hist()

# %%
data.head()
# Out:
#                      abilities      ...       is_legendary
# 0  ['Overgrow', 'Chlorophyll']      ...                  0
# 1  ['Overgrow', 'Chlorophyll']      ...                  0
# 2  ['Overgrow', 'Chlorophyll']      ...                  0
# 3     ['Blaze', 'Solar Power']      ...                  0
# 4     ['Blaze', 'Solar Power']      ...                  0
#
# [5 rows x 41 columns]

# %%
data.plot.hexbin(x='sp_attack',y='sp_defense',gridsize=12)

# %%
data.plot.scatter(x='sp_attack',y='sp_defense')

# %%
data.groupby(['generation','is_legendary']).mean()[['sp_attack','sp_defense']]
# Out:
#                           sp_attack  sp_defense
# generation is_legendary
# 1          0              67.404110   66.500000
#            1             127.800000  104.000000
# 2          0              63.244681   70.702128
#            1              99.166667  116.333333
# 3          0              67.448000   64.864000
#            1             123.000000  126.000000
# 4          0              69.159574   70.404255
#            1             114.230769  104.307692
# 5          0              66.000000   65.314685
#            1             113.692308   94.076923
# 6          0              71.212121   70.439394
#            1             135.500000  103.500000
# 7          0              68.206349   72.984127
#            1             101.352941   85.529412

# %%
data.groupby(['generation','is_legendary']).mean()[['sp_attack','sp_defense']].plot.bar(stacked=True)

# %%
data
# Out:
#                                              abilities      ...       is_legendary
# 0                          ['Overgrow', 'Chlorophyll']      ...                  0
# 1                          ['Overgrow', 'Chlorophyll']      ...                  0
# 2                          ['Overgrow', 'Chlorophyll']      ...                  0
# 3                             ['Blaze', 'Solar Power']      ...                  0
# 4                             ['Blaze', 'Solar Power']      ...                  0
# 5                             ['Blaze', 'Solar Power']      ...                  0
# 6                             ['Torrent', 'Rain Dish']      ...                  0
# 7                             ['Torrent', 'Rain Dish']      ...                  0
# 8                             ['Torrent', 'Rain Dish']      ...                  0
# 9                          ['Shield Dust', 'Run Away']      ...                  0
# 10                                       ['Shed Skin']      ...                  0
# 11                     ['Compoundeyes', 'Tinted Lens']      ...                  0
# 12                         ['Shield Dust', 'Run Away']      ...                  0
# 13                                       ['Shed Skin']      ...                  0
# 14                                 ['Swarm', 'Sniper']      ...                  0
# 15           ['Keen Eye', 'Tangled Feet', 'Big Pecks']      ...                  0
# 16           ['Keen Eye', 'Tangled Feet', 'Big Pecks']      ...                  0
# 17           ['Keen Eye', 'Tangled Feet', 'Big Pecks']      ...                  0
# 18   ['Run Away', 'Guts', 'Hustle', 'Gluttony', 'Hu...      ...                  0
# 19   ['Run Away', 'Guts', 'Hustle', 'Gluttony', 'Hu...      ...                  0
# 20                              ['Keen Eye', 'Sniper']      ...                  0
# 21                              ['Keen Eye', 'Sniper']      ...                  0
# 22              ['Intimidate', 'Shed Skin', 'Unnerve']      ...                  0
# 23              ['Intimidate', 'Shed Skin', 'Unnerve']      ...                  0
# 24                          ['Static', 'Lightningrod']      ...                  0
# 25          ['Static', 'Lightningrod', 'Surge Surfer']      ...                  0
# 26   ['Sand Veil', 'Sand Rush', 'Snow Cloak', 'Slus...      ...                  0
# 27   ['Sand Veil', 'Sand Rush', 'Snow Cloak', 'Slus...      ...                  0
# 28               ['Poison Point', 'Rivalry', 'Hustle']      ...                  0
# 29               ['Poison Point', 'Rivalry', 'Hustle']      ...                  0
# ..                                                 ...      ...                ...
# 771                                   ['Battle Armor']      ...                  0
# 772                                     ['RKS System']      ...                  0
# 773                                   ['Shields Down']      ...                  0
# 774                                       ['Comatose']      ...                  0
# 775                                    ['Shell Armor']      ...                  0
# 776           ['Iron Barbs', 'Lightningrod', 'Sturdy']      ...                  0
# 777                                       ['Disguise']      ...                  0
# 778         ['Dazzling', 'Strong Jaw', 'Wonder Skin ']      ...                  0
# 779            ['Berserk', 'Sap Sipper', 'Cloud Nine']      ...                  0
# 780                                    ['Steelworker']      ...                  0
# 781          ['Bulletproof', 'Soundproof', 'Overcoat']      ...                  0
# 782          ['Bulletproof', 'Soundproof', 'Overcoat']      ...                  0
# 783          ['Bulletproof', 'Soundproof', 'Overcoat']      ...                  0
# 784                    ['Electric Surge', 'Telepathy']      ...                  1
# 785                     ['Psychic Surge', 'Telepathy']      ...                  1
# 786                      ['Grassy Surge', 'Telepathy']      ...                  1
# 787                       ['Misty Surge', 'Telepathy']      ...                  1
# 788                                        ['Unaware']      ...                  1
# 789                                         ['Sturdy']      ...                  1
# 790                                ['Full Metal Body']      ...                  1
# 791                                  ['Shadow Shield']      ...                  1
# 792                                    ['Beast Boost']      ...                  1
# 793                                    ['Beast Boost']      ...                  1
# 794                                    ['Beast Boost']      ...                  1
# 795                                    ['Beast Boost']      ...                  1
# 796                                    ['Beast Boost']      ...                  1
# 797                                    ['Beast Boost']      ...                  1
# 798                                    ['Beast Boost']      ...                  1
# 799                                    ['Prism Armor']      ...                  1
# 800                                     ['Soul-Heart']      ...                  1
#
# [801 rows x 41 columns]

# %%
data.groupby('generation').mean()[['hp','attack','defense','sp_attack','sp_defense','speed']]
# Out:
#                    hp     attack    ...      sp_defense      speed
# generation                          ...
# 1           64.344371  74.529801    ...       67.741722  70.152318
# 2           70.980000  69.960000    ...       73.440000  61.610000
# 3           65.666667  77.185185    ...       69.392593  63.577778
# 4           73.102804  82.672897    ...       74.523364  70.074766
# 5           70.314103  80.557692    ...       67.711538  66.519231
# 6           71.111111  76.527778    ...       73.194444  66.652778
# 7           70.575000  84.637500    ...       75.650000  64.037500
#
# [7 rows x 6 columns]

# %%
data.groupby('generation').mean()[['hp','attack','defense','sp_attack','sp_defense','speed']].plot.line()

# %%
data.head()
# Out:
#                      abilities      ...       is_legendary
# 0  ['Overgrow', 'Chlorophyll']      ...                  0
# 1  ['Overgrow', 'Chlorophyll']      ...                  0
# 2  ['Overgrow', 'Chlorophyll']      ...                  0
# 3     ['Blaze', 'Solar Power']      ...                  0
# 4     ['Blaze', 'Solar Power']      ...                  0
#
# [5 rows x 41 columns]

# %%
sns.countplot(data['generation'])

# %%
sns.distplot(data['hp'] , kde=False)
# Out:
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot(x='attack' , y='defense' , data=data)
# Out:
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot(data['attack'] , data['defense']  , kind='hex')
# Out:
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.kdeplot(data['hp'] , data['attack'])
# Out:
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.boxplot(x='is_legendary' , y='attack' , data=data)

# %%
sns.violinplot(data['is_legendary'] , data['attack'])
# Out:
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
