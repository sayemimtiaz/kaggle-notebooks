# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("../input/students-performance-in-exams/StudentsPerformance.csv")
df.head()

# %%
df.info()

# %%
df.describe()

# %%
df['lunch'].nunique()

# %%
df['parental level of education'].nunique()

# %%
df['race/ethnicity'].value_counts()

# %%
sns.countplot('gender',data=df)

# %%
# the plot shows there isnt much difference between number of male and female students

# %%
sns.countplot('race/ethnicity',data=df)

# %%
plt.figure(figsize=(14,8))
sns.boxplot(x='race/ethnicity',y='math score',hue='gender',data=df)

# %%
# difference in race bring in variations in marks

# %%
plt.figure(figsize=(14,8))
sns.boxplot(x='race/ethnicity',y='reading score',hue='gender',data=df)

# %%
plt.figure(figsize=(14,8))
sns.boxplot(x='race/ethnicity',y='writing score',hue='gender',data=df)

# %%
# girls generally score higher than boys in all three subjects

# %%
df['total score']=df['math score']+df['reading score']+df['writing score']

# %%
df.head()

# %%
plt.figure(figsize=(14,8))
sns.boxplot(x='race/ethnicity',y='total score',hue='gender',data=df)

# %%
plt.figure(figsize=(14,8))
sns.boxplot(x='parental level of education',y='total score',hue='gender',data=df)

# %%
# parental education is really important while considering total scores of students

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x='test preparation course',y='total score',hue='gender',data=df)

# %%
# students completing the test prep course fare better

# %%
plt.figure(figsize=(10,8))
sns.countplot('test preparation course',hue='gender',data=df)

# %%
# most of the students dont prefer the prep course but those who do secure better marks on an average

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x='lunch',y='total score',hue='gender',data=df)

# %%
# students with proper lunch facilities score better

# %%
plt.figure(figsize=(10,8))
sns.countplot('lunch',data=df,hue='gender')

# %%
# large proportion of students have standard lunch

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),cmap='coolwarm',annot=True)

# %%
# a student doing well in one subject most probably performs well in all the subjects

# %%
plt.figure(figsize=(10,8))
sns.boxplot(y='total score',x='gender',data=df)

# %%
# girls generally perform better than boys
