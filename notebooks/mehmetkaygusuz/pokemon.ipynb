# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("../input/pokemon-challenge/pokemon.csv")
df.head()

# %%
df.info()

# %%
df.corr()

# %%
f,ax=plt.subplots(figsize=(18,18))
sns.heatmap(df.corr(),annot=True,linewidth=.5,fmt='.1f',ax=ax)
plt.show()

# %%
df.columns

# %%
df.Speed.plot(kind='line',color='g',label='Speed',linewidth=1,alpha=0.5,grid=True,Linestyle=':')
df.Defense.plot(color='r',label='Defense',linewidth=1,alpha=0.5,grid=True,linestyle='-.')
plt.legend(loc='upper right')
plt.show()

# %%
df.plot(kind='scatter',x='Attack',y='Defense',alpha=0.5,color='red')
plt.xlabel('Attack')
plt.ylabel('Defence')

# %%
df.Speed.plot(kind='hist',bins=50,figsize=(12,12))

# %%
dictionary={'spain':'madrid','turkey':'izmir'}
dictionary.keys()
dictionary.values()

# %%
dictionary['spain']='barca'
dictionary['france']='paris'
dictionary

# %%
series=df['Defense']
type(series)
data_frame=df[['Defense']]
type(data_frame)

# %%
x=df['Defense']<200
x

# %%
y=df['Defense']>200
df[y]

# %%
df[np.logical_and(df['Defense']>200,df['Attack']>100)]

# %%
df[(df['Defense']>200) & (df['Attack']>100)]

# %%
i=0
while i!=5:
    'i is: ',i
    i +=1
i,'is equal to 5'

# %%
lis=[1,2,3,4,5]
for i in lis:
    print('i is: ',i)

# %%
for index,value in enumerate(lis):
    print(index, ":", value)

# %%
dictionary={'spain':'barca','france':'paris'}
for key,value in dictionary.items():
    print(key,":",value)

# %%
for index,value in df[['Attack']][0:1].iterrows():
    print(index,":",value)

# %% [markdown]
# Outlayer value

# %%
df.boxplot(column='Attack',by='Legendary')
plt.show()

# %% [markdown]
# Data melt
# * We can create new dataset with melt function

# %%
df_new=df.head()

# %%
melted=pd.melt(frame=df_new, id_vars='Name', value_vars= ['Attack','Defense'])
melted

# %% [markdown]
# Pivoting
# * This use for reverse our maelted data

# %%
melted.pivot(index='Name', columns='variable',values='value')

# %% [markdown]
# Concatenating, provies concat the dataframe

# %%
df1=df.head()
df2=df.tail()
new_df=pd.concat([df1,df2],axis=0,ignore_index=True)
new_df

# %%
df3=df['Attack'].head()
df4=df['Defense'].head()
new_df2=pd.concat([df3,df4],axis=1)
new_df2

# %%
df.head()

# %%
df['Type 1']=df['Type 1'].astype('category')
df['Speed']=df['Speed'].astype('float')
df.dtypes

# %% [markdown]
# We have a four choose for missing Value
# * leave them like be
# * drop them
# * fill na
# * use statistics method

# %%
df.info()

# %%
df['Type 2'].value_counts(dropna=False)

# %%
df1=df
df1['Type 2'].dropna(inplace=True)

# %%
df1['Type 2'].fillna('empty',inplace=True)

# %%
assert df1.Speed.dtypes == np.float
