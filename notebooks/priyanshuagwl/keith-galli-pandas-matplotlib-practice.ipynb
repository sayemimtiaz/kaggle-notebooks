# %%
import pandas as pd

# %%
df=pd.read_csv("../input/pokemon/Pokemon.csv")

# %%
df

# %%
print(df)

# %%
dfxl=pd.read_excel("https://github.com/KeithGalli/pandas.gitpokemon_data.xlsx")

# %%
dfxl=pd.read_excel("https://raw.githubusercontent.com/KeithGalli/pandas/master/pokemon_data.xlsx")

# %%
df_csv_text=pd.read_csv("https://raw.githubusercontent.com/KeithGalli/pandas/master/pokemon_data.txt",delimiter="\t")

# %%
df_csv_text

# %%
df.columns

# %%
# print(df[['Name','Type 1']])
# print(df.head())
# print(df)
# df
# df.iloc[2,1]
# print(df.iloc[2,1])
# type(df.iloc[0:4])

# %%
df.iterrows??

# %%
next??

# %%
dftest = pd.DataFrame([[1, 1.5]], columns=['int', 'float'])
dftest

# %%
# for index,row in df.iterrows():
#     print(index,row['Name'])
df.loc[df['Type 1']=='Fire'].head()

# %%
df.describe()

# %%
df.sort_values(['Type 1','HP'],ascending=[1,1])

# %%
df['Totaltest']=df['HP']+df['Attack']

# %%
df

# %%
df.iloc[:,5:10].sum(axis=1)

# %%
cols=list(df.columns.values)

# %%
type(df.columns.values)

# %%
arr

# %%
df.to_csv('testcsv',index=False)

# %%
cols[-1]

# %%
#this wont work df[(df['Type 1']=='Grass') and (df['Type 2']=='Poison')]
#df[(df['Type 1']=='Grass') | (df['Type 2']=='Poison')]
new_df=df[(df['Type 1']=='Grass') & (df['Type 2']=='Poison') & (df['HP']>70)]

# %%
new_df.reset_index(drop=True,inplace=True)

# %%
new_df

# %%
df.loc[df['Name'].str.contains('^pi[a-z]*',regex=True)]

# %%
df.loc[df['Type 1']=='test','Type 1']='Fire'

# %%
df.loc[df['Total']>500,['Generation','Legendary']]=['gen1','leg1']

# %%
df

# %%
df

# %%
df.groupby(['Type 1']).mean().sort_values('Defense',ascending=False)

# %%
df.groupby(['Type 1']).count()#.sort_values('Defense',ascending=False)

# %%
df['count']=1

# %%
df.groupby(['Type 1','Type 2']).count()['count']

# %%
for df in pd.read_csv("../input/pokemon/Pokemon.csv",chunksize=10):
    print(df)

# %% [markdown]
# ###                          VISUALISATION WITH MATPLOTLIB

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandasas pd
