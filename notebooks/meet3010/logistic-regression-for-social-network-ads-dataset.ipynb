# %%
# Import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# import the data
data = pd.read_csv('../input/social-network-ads/Social_Network_Ads.csv')
data

# %% [markdown]
# Now we will check that if there are any null values in the dataset

# %%
data.isnull().sum()

# %% [markdown]
# There is no null data in the dataset. Now we will divide the data into independent and dependent variable

# %%
# independent
X = data[['Age','EstimatedSalary']]
X

# %%
# Dependent
Y = data['Purchased']
Y

# %%
X

# %% [markdown]
# We can see that there is a lot of difference in the values of Age and EstimatedSalary, so we scale the values using standardscaler, this is done for better model performance , The mean should be near to 0 and standard deviation should be near 1 before training the model which is ensured by this.

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
X = sc.fit_transform(X)
X

# %% [markdown]
# We can see that our values are scaled properly now we will divide the data into training and testing data.

# %%
from sklearn.model_selection import train_test_split

# %%
train_x,test_x,train_y,test_y = train_test_split(X, Y, test_size=0.3, random_state=99)

# %%
train_x.shape, train_y.shape, test_x.shape, test_y.shape

# %% [markdown]
# Now we will perform Logistic regression on our data

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(train_x,train_y)

# %%
y_pred = lr.predict(test_x)
y_pred

# %%
result = pd.DataFrame({'Actual' : test_y, 'Predicted' : y_pred})
result

# %% [markdown]
# We will check the accuracy with the help of score, accuracy score and confusion matrix

# %%
lr.score(test_x,test_y)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
accuracy_score(test_y,y_pred)

# %%
confusion_matrix(test_y,y_pred)

# %% [markdown]
# We are able to see that we have got 86% accuracy . Let us understand the same by visualization

# %%
from matplotlib.colors import ListedColormap
def plot(X,y,mset):
    p=['Not Purchased','Purchased']
    X1, X2 = np.meshgrid(np.arange(start = X[:, 0].min() - 1, stop = X[:, 0].max() + 1,   step = 0.01),
                         np.arange(start = X[:, 1].min() - 1, stop = X[:, 1].max() + 1, step = 0.01))

    #To plot boundaries
    #In general, the space is divided into decision boundaries
    plt.figure(figsize=(8,6))
    plt.contourf(X1, X2, lr.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
                 alpha = 0.75, cmap = ListedColormap(('#F1674F', '#BEDDB7')))

    plt.xlim(X1.min(), X1.max())
    plt.ylim(X2.min(), X2.max())

    for i, j in enumerate(set(y)):
        plt.scatter(X[y == j, 0], X[y == j, 1],
                    c = ['#F84C51', '#23807A'][i], label = p[j])
    plt.title('Logistic Regression ('+mset+')')
    plt.xlabel('Age')
    plt.ylabel('Estimated Salary')
    plt.legend()
    return plt

# %%
y_pred=lr.predict(train_x)
plt.show(plot(train_x,y_pred,'Training Set'))

# %%
y_pred=lr.predict(test_x)
plt.show(plot(test_x,y_pred,'Training Set'))
