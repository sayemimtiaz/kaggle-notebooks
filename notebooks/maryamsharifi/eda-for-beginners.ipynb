# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('../input/montcoalert/911.csv')

# %%
df.head()

# %%
df.shape

# %%
df.info()

# %%
df['zip'].value_counts().head(5)

# %%
df['title'].nunique()

# %%
df['title'].unique()

# %%
x=df['title'].iloc[0]

# %%
x

# %%
x.split(':')[0]

# %%
df['title'].apply(lambda x:x.split(':')[0])

# %%
df['reason']=df['title'].apply(lambda x:x.split(':')[0])

# %%
df.head()

# %%
df['reason'].value_counts()

# %%
df['timeStamp'].iloc[0]

# %%
type(df['timeStamp'].iloc[0])

# %%
df['timeStamp']=pd.to_datetime(df['timeStamp'])

# %%
type(df['timeStamp'].iloc[0])

# %%
time=df['timeStamp'].iloc[0]

# %%
time.hour

# %%
time.year

# %%
time.dayofyear

# %%
df['Hour']=df['timeStamp'].apply(lambda time:time.hour)

# %%
df['Month']=df['timeStamp'].apply(lambda time:time.month)

# %%
df['Year']=df['timeStamp'].apply(lambda time:time.year)

# %%
df['DayofWeek']=df['timeStamp'].apply(lambda time:time.dayofweek)

# %%
df.head()

# %%
import seaborn as sns

# %%
sns.countplot(x='DayofWeek', data=df, hue='reason')

# %%
df

# %%
df['zip'].nunique()

# %%
df['zip'].max()

# %%
df['zip'].idxmax()

# %% [markdown]
# Showing top 5 zip[](http://)****

# %%
x=df.nlargest(5,['zip'])

# %%
x.zip

# %% [markdown]
# **the top 5 townships (twp) for 911 calls

# %%
df['twp'].value_counts()[:5].index.tolist()

# %% [markdown]
# **Numbers of unique title of emergency codes

# %%
df['title'].nunique()

# %% [markdown]
# **The most common Reason for a 911 call based off of this new column

# %%
df['reason'].value_counts()[:].index.tolist()

# %%
df['reason'].max()

# %%
df['reason'].describe()

# %% [markdown]
# **Features containing blank, null or empty values

# %%
df.isnull()
