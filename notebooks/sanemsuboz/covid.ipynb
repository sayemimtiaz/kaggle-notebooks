# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as pyp
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('../input/covid-world-vaccination-progress/country_vaccinations.csv')

# %%
data.info()
#We reach the columns and types of the covid data set.

# %%
data.plot(kind='scatter',x='total_vaccinations',y='daily_vaccinations')
#When we look at the relationship between the daily case and the total case, we can see that although there seems to be a linear relationship in general, 
#this linearity is affected by different factors or factors.

# %%
data.plot(kind='scatter',x='country',y='people_vaccinated',figsize=(200,40))
#We can say that the most vaccinated country is United States.

# %%
data.total_vaccinations_per_hundred.plot(kind='hist',bins=15)
#We can conclude that the number of people who have been vaccinated is low.

# %%
data.people_fully_vaccinated.plot(kind='hist',bins=15)
#We can conclude that the number of people whose vaccine has not been completed is high.

# %%
data.plot(kind='scatter',x='vaccines',y='people_vaccinated', figsize=(100,40))
#We can conclude that the moderna, pfizer / biontech vaccine is the most widely used vaccine.

# %%
for i in data[['vaccines']].iterrows():
    print(i)

# %%
for index,value in data[['country']].iterrows():
    print(index," : ",value)

# %%
data.head()

# %%
data.columns

# %%
data.tail()

# %%
print(data['country'].value_counts(dropna=False))

# %%
data.describe()

# %%
data.boxplot(column='total_vaccinations_per_hundred',by='people_vaccinated_per_hundred',figsize=(200,15))

# %%
data.boxplot(column='total_vaccinations_per_hundred')

# %%
data_new=data.head(5)
data_new

# %%
melted=pd.melt(frame=data_new,id_vars='country',value_vars=['total_vaccinations','people_vaccinated'])
melted

# %%
data1=data.head()
data2=data.tail()
conc_data_row=pd.concat([data1,data2],axis=0,ignore_index=True)
conc_data_row

# %%
data1=data['total_vaccinations'].head()
data2=data['people_vaccinated'].head()
conc_data_col=pd.concat([data1,data2],axis=1)
conc_data_col

# %%
data.dtypes

# %%
#data['total_vaccinations']=data['total_vaccinations'].astype('int')
#We have missing data

# %%
data.info()

# %%
data["people_vaccinated"].value_counts(dropna=False)

# %%
data1=data
data1["people_vaccinated"].dropna(inplace=True)

# %%
assert 1==1

# %%
data1["people_vaccinated"].fillna(0.0,inplace=True)

# %%
assert data1['people_vaccinated'].notnull().all()

# %%
data["people_vaccinated"].value_counts(dropna=False)

# %%
c=["s","f"]
p=["16","18"]
l_l=["c","p"]
l_c=[c,p]
z=list(zip(l_l,l_c))
d=dict(z)
df=pd.DataFrame(d)
df

# %%
df["cp"]=["ss","ff"]
df

# %%
df["ss"]=0
df

# %%
data2=data.loc[:,["total_vaccinations","people_vaccinated"]]
data2.plot()

# %%
data2.plot(subplots=True)

# %%
fig, axes = plt.subplots(nrows=2,ncols=1)
data2.plot(kind="hist",y="total_vaccinations",bins=50,range=(0,1000),ax=axes[0])
data2.plot(kind="hist",y="total_vaccinations",bins=50,range=(0,1000),ax=axes[1],cumulative=True)
plt.savefig("graph.png")
plt

# %%
data.describe()

# %%
data3=data.head(3)
date_list=["2020-12-15","2021-01-28","2021-04-15"]
datetime_obj=pd.to_datetime(date_list)
data3["date"]=datetime_obj
data3=data3.set_index("date")
data3

# %%
data3.resample("A").mean()

# %%
data3.resample("M").mean()

# %%
data3.resample("M").first().interpolate("linear")

# %%
data=data.set_index("date")
data.head(3)

# %%
data.country[1]

# %%
data.people_vaccinated.apply(lambda n : n/2)

# %%
data["total"]=data.people_vaccinated+data.people_fully_vaccinated
data.head()

# %%
data=pd.read_csv('../input/covid-world-vaccination-progress/country_vaccinations.csv')

# %%
data5=data.set_index(["country","iso_code"])
data.head(100)

# %%
data.groupby("country").mean()

# %%
data.groupby("country").total_vaccinations.max()
