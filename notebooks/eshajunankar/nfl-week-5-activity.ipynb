# %% [markdown]
# # Homework

# %% [markdown]
# Week 5 Homework using an NFL Dataset. All of you football fans can take a glimpse into how people predict future statistics for players, and how people bet in both fantasy football and on teams!

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# open csv file and read it 
df = pd.read_csv("../input/nfl-scores-and-betting-data/spreadspoke_scores.csv")
# Your turn! Please plot a line graph for all the data given to you.
# Also, plot a scatter plot for the 'score_away' data, and the 'score_home' data 
# There are multiple parameters for this function, use that to your advantage! 
# Hint: think about previous concepts and the x and y variables used for a graph! 



# Teachers Version 

df.plot()

plt.show()

df.plot(kind = 'scatter', x = 'score_away', y = 'score_home')

# Note there are different ways to do this and different variable names can be used this is one format of answering this
