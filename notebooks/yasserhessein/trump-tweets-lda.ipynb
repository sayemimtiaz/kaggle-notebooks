# %% [markdown]
# ## All Trump's Twitter insults (2015-2021)
# ### The Complete List of Trump’s Twitter Insults (2015-2021)
#
# ### Datasset
#
# https://www.kaggle.com/ayushggarg/all-trumps-twitter-insults-20152021

# %%
import pandas as pd

# %%
npr = pd.read_csv('../input/all-trumps-twitter-insults-20152021/trump_insult_tweets_2014_to_2021.csv')

# %%
npr

# %%
npr.info()

# %%
npr.describe().T

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
dtm = cv.fit_transform(npr['tweet'])

# %%
len(cv.get_feature_names())

# %%
import random
for i in range(10):
    random_word_id = random.randint(0,7308)
    print(cv.get_feature_names()[random_word_id])

# %%
from sklearn.decomposition import LatentDirichletAllocation
LDA = LatentDirichletAllocation(n_components=7,random_state=42)
LDA.fit(dtm)

# %%
len(LDA.components_)

# %%
LDA.components_

# %%
len(LDA.components_) , len(LDA.components_[0])

# %%
single_topic = LDA.components_[0]
single_topic.argsort()

# %%
single_topic.argsort()[-10:]

# %%
for index in single_topic.argsort()[-10:]:
    print(cv.get_feature_names()[index])

# %%
for index,topic in enumerate(LDA.components_):
    print(f'THE TOP 15 WORDS FOR TOPIC #{index}')
    print([cv.get_feature_names()[i] for i in topic.argsort()[-15:]])
    print('\n')

# %%
topic_results = LDA.transform(dtm)

# %%
topic_results.shape

# %%
topic_results[0].round(2)

# %%
topic_results.argmax(axis=1)

# %%
npr['Topic'] = topic_results.argmax(axis=1)
npr.head(10)

# %%
npr['Topic'].value_counts()
