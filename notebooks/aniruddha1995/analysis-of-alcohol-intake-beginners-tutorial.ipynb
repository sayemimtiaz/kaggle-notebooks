# %% [markdown]
# Load the library's required
# -----------

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # for plotting 
# %matplotlib inline

# %% [markdown]
# >
#
# **Loading CSV to the Environment**
# ----------------------------------

# %%
data = pd.read_csv('../input/student-mat.csv');

# %% [markdown]
# Know the Data Set
# -----------------

# %%
data.head()

# %%
data.describe()

# %%
data.info()

# %% [markdown]
# From the above information we can see that there is no null values as every rows are same in magnitude ie 395. We can also check this by using .isnull()  function as follows .

# %%
data.isnull()

# %% [markdown]
# Getting data on the basis of Sex , location

# %%
male = data[data['sex']=='M'] ; #Seperating male data

# %%
female = data[data['sex']=='F']  #seperating female data

# %%
rural = data[data['address']=='R']   # seperating rural data

# %%
Urban = data[data['address']=='U']    # seperating urban data

# %% [markdown]
# **Now lets Visualise how MALE vs FEMALE alcohole consumption**

# %%
tot_alc_m = (male['Dalc']+male['Walc'])/2   # total alcohol consumption by male

# %%
tot_alc_f = (female['Dalc']+female['Walc'])/2  # total alcohol consumption by Female

# %%
tot_alc_m.mean()

# %%
tot_alc_f.mean()

# %%
plt.hist(tot_alc_f,bins =50,color='b')
plt.hist(tot_alc_m,bins =50,color='r',alpha=0.5)
plt.legend(['Male', 'Female'], loc=1)
plt.xlabel('Alcohole Consumption on scale of 5')
plt.ylabel('Number of Male/Female')
plt.show()
