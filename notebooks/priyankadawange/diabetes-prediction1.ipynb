# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
from matplotlib.colors import ListedColormap
from sklearn.metrics import plot_confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, auc, roc_curve, precision_recall_curve, classification_report, accuracy_score,log_loss, confusion_matrix
import warnings
warnings.simplefilter(action='ignore', category=Warning)
import numpy as np

# %% [markdown]
# # Loading the dataset

# %%
df = pd.read_csv('/kaggle/input/pima-indians-diabetes-database/diabetes.csv')

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.head()

# %%
df.info()

# %%
df.describe()

# %%
df.shape

# %% [markdown]
# In data set there are 768 rows and 9 columns

# %%
df.dtypes

# %%
df.columns

# %%
df.isnull().sum()

# %% [markdown]
# In data set no null values.

# %%
df.duplicated().any()

# %% [markdown]
# In data set no duplicate values

# %%
sns.countplot(x="Outcome", data=df)
plt.show()

# %% [markdown]
# Count of peoples not having diabetes has high count as compared to have diabetes

# %%
df.corr()

# %%
plt.figure(figsize=(10,12))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
sns.pairplot(data=df, hue='Outcome')
plt.show()

# %%
 df.columns

# %%
 sns.countplot(x=df['Pregnancies'] )

# %%
sns.distplot(df["Glucose"])

# %%
sns.distplot(df["BloodPressure"])

# %%
sns.distplot(df["SkinThickness"])

# %%
assert pd.notnull(df).all().all()

# %%
x=df.drop(columns='Outcome')
y=df['Outcome']

# %%
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape, x_test.shape

# %%
y_train.shape, y_test.shape

# %% [markdown]
# # Logistic Regression

# %%
logreg=LogisticRegression()

# %%
logreg.fit(x_train, y_train)

# %%
y_pred=logreg.predict_proba(x_test)[:,1]

# %%
roc_auc_score(y_train, logreg.predict_proba(x_train)[:,1])

# %%
roc_auc_score(y_test, logreg.predict_proba(x_test)[:,1])

# %%
print(f'accuracy of model is:{accuracy_score(y_test, logreg.predict(x_test))}')
print(f"classification report is:{classification_report(y_test, logreg.predict(x_test))}")
print(f"confusion matrix is :{confusion_matrix(y_test, logreg.predict(x_test))}")
print(f'log loss is:{log_loss(y_test, y_pred)}')

# %%
fpr, tpr, _=roc_curve(y_test, logreg.predict_proba(x_test)[:,1])
roc_auc=auc(fpr, tpr)
fpr_tr, tpr_tr, thresholds_roc = roc_curve(y_train, logreg.predict_proba(x_train)[:, 1])
roc_auc_tr = auc(fpr_tr, tpr_tr)

# %%
import matplotlib.pyplot as plt
plt.plot(fpr, tpr, color="red")
plt.plot(fpr_tr,
    tpr_tr,
    color="green")
plt.plot([0, 1], [0, 1], color="navy", lw=2, linestyle="--")

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic")
 
plt.show()

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train,y_train)

# %%
rf.fit(x_train, y_train)

# %%
 y_pred=rf.predict(x_test)

# %%
print(f'accuracy of model is:{accuracy_score(y_test,rf.predict(x_test))}')
print(f'classification report is:{classification_report(y_test, rf.predict(x_test))}')
print(f'Confusion matrix is:{confusion_matrix(y_test, rf.predict(x_test))}')
print(f"log loss of model is:{log_loss(y_test, rf.predict(x_test))}")

# %% [markdown]
# # XGboost

# %%
from xgboost import XGBClassifier

# %%
xgb= XGBClassifier()

# %%
xgb.fit(x_train, y_train)

# %%
y_pred1=xgb.predict(x_test)

# %%
print(f'accuracy of model is:{accuracy_score(y_test,y_pred1)}')
print(f'Classification report is:{classification_report(y_test,y_pred1)}')
print(f'Confusion matrix is:{confusion_matrix(y_test, y_pred1)}')
print(f"log loss of model is:{log_loss(y_test, y_pred1)}")

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(x_train, y_train)

# %%
y_pred2=dtree.predict(x_test)

# %%
print(f'accuracy of model is:{accuracy_score(y_test, y_pred2)}')
print(f'classification report is:{classification_report(y_test, y_pred2)}')
print(f'confusion matrix is:{confusion_matrix(y_test, y_pred2)}')
print(f"log loss of model is:{log_loss(y_test, y_pred2)}")

# %% [markdown]
# # gradient boosting classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbdt=GradientBoostingClassifier()
gbdt.fit(x_train,y_train)

# %%
gbdt.fit(x_train, y_train)

# %%
y_pred=gbdt.predict(x_test)

# %%
print(f"accuarcy of model is:{accuracy_score(y_test, y_pred)}")
print(f'classification report is:{classification_report(y_test, y_pred)}')
print(f'confusion matrix is:{confusion_matrix(y_test, y_pred)}')
print(f"log loss of model is:{log_loss(y_test, y_pred)}")

# %% [markdown]
# # Adaboost

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
adb=AdaBoostClassifier()

# %%
adb.fit(x_train, y_train)

# %%
print(f"accuracy of model is:{accuracy_score(y_test, adb.predict(x_test))}")
print(f"confusion matrix is:{confusion_matrix(y_test, adb.predict(x_test))}")
print(f"classification report is:{classification_report(y_test, adb.predict(x_test))}")
print(f"log loss of model is:{log_loss(y_test, adb.predict(x_test))}")

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier()

# %%
knn.fit(x_train, y_train)

# %%
print(f"the accuracy of model is:{accuracy_score(y_test, knn.predict(x_test))}")
print(f"confusion matrix is:{confusion_matrix(y_test, knn.predict(x_test))}")
print(f"classification report is:{classification_report(y_test, knn.predict(x_test))}")
print(f"log loss of model is:{log_loss(y_test, knn.predict(x_test))}")
