# %% [markdown]
# ## Suicide in India
# In any country suicides are matter of concern, and hence knowing reason behind it becomes really necessary. Here I have taken this data set which consist of suicide details of India. Let's study it in detail.

# %% [markdown]
# ## Importing library
#
# We have imported pandas for reading data from csv and analysis and processing our data

# %%
import pandas as pd

# %%
data = pd.read_csv('../input/suicides-in-india/Suicides in India 2001-2012.csv')

# %% [markdown]
# ## Abstract data
#
# Below is few rows of our data

# %%
data.head()

# %%
data.info()

# %% [markdown]
# ## Importing libraries
#
# Libraries such as Matplotlib and Seaborn is imported to visualize data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Checking for null values in our dataset

# %%
sns.heatmap(data.isna())

# %% [markdown]
# ## Overall EDA
#
# Let's see overall suicide scenario in India

# %% [markdown]
# ## Based on Gender
# Let's see sucide rate in India based on gender

# %%
sns.countplot(data=data,x='Gender')

# %% [markdown]
# As we can see in above graph, both gender have equal suicide rates. But its really matter of concern. Humans are facing so much pressure, I dont know every individual is going through alot

# %% [markdown]
# ## Based on Age group
# Let's see it how is it in different age group

# %%
sns.countplot(data=data,x='Age_group')

# %% [markdown]
# Every age-group ranging from 0 to 60+ have equal rate but age-group of 100+ have lower.
# It might be possible due many reason. As it maybe possible people above 100+ years are less or they might not be under any of such pressure or any of such kind of situation as people belongs to other age-group

# %% [markdown]
# ## Based on State

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=data,y='State')

# %% [markdown]
# There is no major difference

# %% [markdown]
# ## Based on Type
# Here, we are observing reason for suicide

# %%
plt.figure(figsize=(15,25))
sns.countplot(data=data,y='Type')

# %% [markdown]
# ## Based on TypeCode
# It's more genralised category

# %%
plt.figure(figsize=(10,7))
sns.countplot(data=data,x='Type_code')

# %% [markdown]
# As, shown above, reason behind suicide are lesser in Education status, and social status. We have observed least in Social Status

# %% [markdown]
# ## Year-wise Suicide Death Toll
#
# Let's see year wise suicide in India.

# %%
yearWiseData = []
year = data['Year'].unique()
for i in range(len(year)):
    dic = {
        'Year':year[i],
        'Count':len(data[data['Year']==year[i]])
    }
    yearWiseData.append(dic)

# %%
df = pd.DataFrame(data=yearWiseData)

# %%
sns.lineplot(data=df,x='Year',y='Count',marker='o',color='Red')

# %% [markdown]
# From above graph we can conclude following things
# * Year 2003,2004,2006,2009 have relatively lower suicide
# * Year 2011 have highest suicide
# * Year 2004 have least suicide

# %% [markdown]
# ## More specific EDA

# %% [markdown]
# Let's make our EDA specific to our arguments, so that we can get better and clearer picture of this dataset. And could actualy find better outcome.

# %% [markdown]
# Let's try keep one Attribute constant and changing seccond one to get better picture.
# For example, creating a function which we keep 'State' constant but we can change 2nd Attribute to Year, or Type so on. We can also just change value of 2nd Attribute. For example, changing 'Year=2001' to 'Year=2002'

# %% [markdown]
# ## State-wise EDA
#
# Let's do EDA state-wise.

# %%
def stateWise(state,cat='all',arg='all',x=12,y=7,orient='x'):
    plt.figure(figsize=(x,y))
    if cat =='all':
        stateData = data[data['State']==state]
    elif arg=='all':
        stateData = data[data['State']==state]
    else:
        stateData = data[(data['State']==state)&(data[cat]==arg)]

    
    if orient == 'x':
        sns.countplot(data=stateData,x=cat)
    else:
        sns.countplot(data=stateData,y=cat)

# %%
stateWise('Gujarat','Type_code')

# %%
stateWise('Maharashtra','Type',y=25,orient='y')

# %% [markdown]
# We can do this for different attributes as well. Let's see it for years as well.

# %%
def yearWise(year,cat='all',x=12,y=7,orient='x'):
    
    plt.figure(figsize=(x,y))
    yearData = data[data['Year']==year]
    
    if orient == 'x':
        sns.countplot(data=yearData,x=cat)
    else:
        sns.countplot(data=yearData,y=cat)

# %%
yearWise(2004,'Type',y=25,orient='y')

# %% [markdown]
# ## Closure
# Suicide are very serious problem and we must find some solution or way to reduce it. No problem is as important as someone's life. Try to spread positive and if you cannot dont spread negativity or hate. Thank you thats it for this notebook.
# Please give upvote if you like the notebook. And please do share your valuable comments.
