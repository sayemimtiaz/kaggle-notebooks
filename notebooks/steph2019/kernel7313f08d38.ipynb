# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.linear_model import LinearRegression

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.

# %%
import os
#os.chdir('..')
#os.chdir('input')
print(os.listdir(os.getcwd()))

# %%
df=pd.read_csv('hfi_cc_2018.csv')
df.head(2)

# %%
?: Correlation entre différentes situations économiques des pays et leur index de "liberté", 
    quels facteurs infuencent le plus cet index ?

# %% [markdown]
# ?: Correlation entre différentes situations économiques des pays et leur index de "liberté",
#     quels facteurs infuencent le plus cet index ?

# %%
dmean = df['hf_score'].groupby([df['year']]).mean()
dmean

# %% [markdown]
# We can see that the mean of the hfi went slightly up from 08 to 09 but has been decreasing until 2016. The decrease between 2015 and 2016 is about -0.04 or 15%

# %%
#get index of ef_money_growth
df.columns.get_loc('ef_money_growth')

# %%
#create tablewith all data related to economics
eco = df.iloc[:, 81:-2]
eco.head()

# %%
df['hf_score'].groupby([df['countries']]).mean()

# %%
from string import ascii_letters
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="white")

# Compute the correlation matrix
corr = eco.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(20, 15))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0,
            square=False, linewidths=0.5, cbar_kws={"shrink": .5}, annot = True, fmt = '.1f')

# %%
eco2 = df[['ef_money','ef_trade_regulatory_compliance','ef_trade_regulatory',
           'ef_trade_movement','ef_trade','ef_regulation_business_bureaucracy','ef_regulation']]
eco2

# %%
corr
#x.isnull().sum()

# %%
pvt = pd.pivot_table(data=df, index=['countries', 'ef_money'], values='hf_score')
pvt.head(5)

# %%
model = LinearRegression()
x= np.array(df.iloc[:, 81]).reshape((-1,1))
y=np.array(df.iloc[:,-3])
model.fit(x,y)

# %%
df.iloc[0:, [2,81,-3]]
