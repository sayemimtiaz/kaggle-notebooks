# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
import matplotlib.pyplot as plt
import datetime

# %%
vaccin = pd.read_csv("../input/covid-world-vaccination-progress/country_vaccinations.csv")

# %%
print("Data shape : ", vaccin.shape, "\n")
print("Col name : ", vaccin.columns, "\n")
print("Data describe : ", vaccin.describe(), "\n")

# %%
vaccin.head()

# %%
px.bar(vaccin['vaccines'].value_counts())

# %%
fig = px.line(vaccin, x="date", y='daily_vaccinations', color='country')
fig.show()

# %%
fig = px.line(vaccin, x="date", y='total_vaccinations', color='country')
fig.show()

# %%
px.bar(vaccin['country'].value_counts())
