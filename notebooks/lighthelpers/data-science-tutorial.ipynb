# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns  # visualization tool

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# /kaggle/input/bitcoin-historical-data/bitstampUSD_1-min_data_2012-01-01_to_2020-09-14.csv

# %%
# Read Csv-File

data = pd.read_csv('../input/bitcoin-historical-data/bitstampUSD_1-min_data_2012-01-01_to_2020-12-31.csv')

data.head()

# %%
# Overview of data

data.info()

# %%
# Correlation of data: the correlation between two variables
# positive correlation: 1
# negative correlation: -1
# Values that approach the one are correlated

data.corr()

# %%
# Correlation Map
# We use seaborn tool with heatmap
# The previous table will be shown to us as a heatmap

f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(data.corr(), annot=True, linewidths=.9, fmt= '.1f',ax=ax)
plt.show()

# %%
# Gives us the first ten values

data.head(10)

# %%
# The columns name are output

data.columns

# %% [markdown]
# ### MATPLOTLIB
#
# Matplot help us to plot data and have different plots:
#
# * Line
# * Scatter
# * Histogram

# %%
# Line Plot
# color = color, label = label, linewidth = width of line, alpha = opacity, grid = grid, linestyle = sytle of line

data.Close.plot(kind = 'line', color = 'r',label = 'Close',linewidth=1,alpha = 0.5,grid = True,linestyle = ':')
data.Open.plot(color = 'g',label = 'Open',linewidth=1, alpha = 0.5,grid = True,linestyle = '-.')
plt.legend(loc='upper right')     # legend = puts label into plot
plt.xlabel('x axis')              # label = name of label
plt.ylabel('y axis')
plt.title('Line Plot')            # title = title of plot
plt.show()

# %%
# Scatter Plot 
# x = Close, y = Open

data.plot(kind='scatter', x='Close', y='Open',alpha = 0.3, color = 'red')
plt.xlabel('Close')              # label = name of label
plt.ylabel('Open')
plt.title('Close Open Scatter Plot')            # title = title of plot
plt.show()

# %%
# Scatter Plot: another example 
# x = attack, y = defense
data.plot(kind='scatter', x='Timestamp', y='Weighted_Price',alpha = 0.5,color = 'red')
plt.xlabel('Timestamp')              # label = name of label
plt.ylabel('Weighted_Price')
plt.title('Timestamp Weighted_Price Scatter Plot')            # title = title of plot
plt.show()

# %%
# Scatter Plot: different spelling

plt.scatter(data.Timestamp,data.Weighted_Price, color= 'r', alpha = 0.5)
plt.show()

# %%
# Histogram
# bins = number of bar in figure
data.Weighted_Price.plot(kind = 'hist',bins = 50,figsize = (15,15))
plt.show()

# %%
# clf()-Method
# clf() = cleans it up again you can start a fresh
data.Weighted_Price.plot(kind = 'hist',bins = 50)
plt.clf()
# We cannot see plot due to clf()

# %% [markdown]
# ### DICTIONARY
#
# Dictionaries are used to store data values in key:value pairs.
#
# Example:
#
# * dictinary = {'germany': 'berlin'}
# * *key* is germany
# * *value* is berlin.
#
# Is faster than list.

# %%
# Create dictionary and look its keys and values
dictionary = {'germany' : 'berlin','turkey' : 'ankara'}
print(dictionary.keys())
print(dictionary.values())

# %%
# Keys have to be immutable objects like string, boolean, float, integer or tubles
# List is not immutable
# Keys are unique
dictionary['germany'] = "köln"    # update existing entry
print(dictionary)
dictionary['italy'] = 'rom'       # Add new entry
print(dictionary)
del dictionary['italy']           # remove entry with key 'italy'
print(dictionary)
print('germany' in dictionary)    # check include or not
print('spain' in dictionary)
dictionary.clear()               # remove all entries in dictionary
print(dictionary)

# %%
#del dictionary         # delete entire dictionary     
print(dictionary)       # it gives error because dictionary is deleted

# %% [markdown]
# ### PANDAS
#
# Pandas-Library have three different types of objects:
#
# * **Series**: one-dimensional list
# * **DataFrame:** are two-dimensionale data (they consists of columns and rows of a table. The                      columns and rows can be treated as Series objects.
# * **Panel**: consists of three-dimensional data-sets (they can be divided into several levels of two-dimensional tables consisting of data frames).

# %%
# Notation

series = data['High']        # data['High'] = series
print(type(series))
data_frame = data[['High']]  # data[['High']] = data frame
print(type(data_frame))

# %%
# Comparison operator
print(3 > 2)
print(3!=2)
# Boolean operators
print(True and False)
print(True or False)

# %%
# 1 - Filtering Pandas data frame

x = data['High']> 1     # The values higher than 1
data[x]

# %%
# 2 - Filtering pandas with logical_and
# We have 7 results for this filtering
data[np.logical_and(data['High']>1000, data['Volume_(BTC)']>1000 )]

# %%
# This is also same with previous code line. Therefore we can also use '&' for filtering.
data[(data['High']>1000) & (data['Volume_(BTC)']>1000)]

# %% [markdown]
# ### WHILE and FOR LOOPS

# %%
# Stay in loop if condition( i is not equal 7) is true
i = 0
while i != 7 :
    print('i is: ',i)
    i = i + 1
print(i,' is equal to 7')

# %%
# Stay in loop if condition( i is not equal 7) is true
lis = [1,2,3,4,5,6,7]
for i in lis:
    print('i is: ',i)
print('')

# Enumerate index and value of list
# index : value = 0:1, 1:2, 2:3, 3:4, 4:5
for index, value in enumerate(lis):
    print(index," : ",value)
print('')   

# For dictionaries
# We can use for loop to achive key and value of dictionary. 
# items() => give us key and value
dictionary = {'turkey':'ankara','germany':'berlin'}
for key,value in dictionary.items(): 
    print(key," : ",value)
print('')

# For pandas we can achieve index and value
# iterrows() => gives us index:value
for index,value in data[['High']][0:1].iterrows():
    print(index," : ",value)

# %% [markdown]
# ### User defined function
#
# * **docstrings:** a docstring is a string literal that occurs as the first statement in a module, function, class, or method definition
# * **tuble**: a tuple is created by placing all the items (elements) inside parentheses (), separated by commas and immutable python objects

# %%
# Example

def tuble_ex():
    """return defined t tuble"""
    t=(1,2,3)
    return t

a,b,c = tuble_ex()
print(a,b,c)

# %%
# Example
def tuble_ex():
    t=(1,2,3)
    return t

tuble_ex()
print(b)
print(b)
print(c)

# %% [markdown]
# ### Scope
# A variable is only available from inside the region it is created. This is called scope.
# * global: a variable created in the main body of the Python code is a global variable
# * local: a variable created inside a function belongs to the local scope of that function, and can only be used inside that function.
# * built in scope: names in predefined built in scope module such as print, len

# %%
# guess prints what
x = 4
def f():
    x = 2
    return x
print(x)      # x = 4 global scope
print(f())    # x = 2 local scope

# %%
# What if there is no local scope
x = 7
def f():
    y = 2*x        # there is no local scope x
    return y
print(f())         # it uses global scope x  
# First local scope searched, then global scope searched, if two of them cannot be found lastly built in scope searched.

# %%
# How can we learn what is built in scope
import builtins
dir(builtins)

# %% [markdown]
# ### NESTED FUNCTION
# * A function defined inside another function is called a nested function.
# * There is a LEGB rule that is search local scope, enclosing function, global and built in scopes, respectively.

# %%
# Nested function
def square():
    """ return square of value """
    def add():
        """ add two local variable """
        x = 4
        y = 8
        z = x + y
        return z
    return add()**2
print(square())

# %% [markdown]
# <a id="11"></a> <br>
# ### DEFAULT and FLEXIBLE ARGUMENTS
# * Default argument example:
# <br> def f(a, b=1):
#         """ b = 1 is default argument"""
# * Flexible argument example:
# <br> def f(*args):
#        """ *args can be one or more"""
# <br>def f(** kwargs)
#        """ **kwargs is a dictionary"""
#
# <br><br> Example for this arguments:

# %%
# Default arguments
def f(a, b = 1, c = 10):
    y = a + b + c
    return y
print(f(5))
# what if we want to change default arguments
print(f(5,4,3))

# %%
# flexible arguments *args
def f(*args):
    for i in args:
        print(i)
f(1)
print("")

f(1,2,3,4)

# flexible arguments **kwargs that is dictionary
def f(**kwargs):
    """ print key and value of dictionary"""
    for key, value in kwargs.items():           
        print(key, " ", value)
f(country = 'turkey', capital = 'ankara', population = 5504000)

# %% [markdown]
# <a id="12"></a> <br>
# ### LAMBDA FUNCTION
# It is a small and restricted function having no more than one line.

# %%
# Lambda function

square = lambda x: x**2     # where x is name of argument
print(square(4))

result = lambda x,y,z: x+y+z   # where x,y,z are names of arguments
print(result(1,2,3))

# User defined function (long way)

def square(x):
    return x**2
print(square(4))

# %% [markdown]
# <a id="13"></a> <br>
# ### ANONYMOUS FUNCTİON
# Like lambda function but it can take more than one arguments.
# * map(func,seq) : applies a function to all the items in a list

# %%
number_list = [3,2,1]

y = map(lambda x:x**2, number_list)
print(list(y))

# %% [markdown]
# ### ITERATORS

# %%
# Example iteration

name = 'mesutözil'

it = iter(name)
print(next(it))   # print next iteration
print(*it)      # print remaining iteration

# %% [markdown]
# zip()-Method: zip lists

# %%
# Example zip()

list1 = [4,3,2,1]
list2 = [9,8,7,6]

z = zip(list1, list2)
print(z)

z_list = list(z)   # list()-Method
print(z_list)

# %%
un_zip = zip(*z_list)
un_list1, un_list2 = list(un_zip)  # unzip returns tuble

print(un_list1)
print(un_list2)
print(type(un_list2))
print(type(list(un_list1)))

# %% [markdown]
# <a id="15"></a> <br>
# ### List Comprehension
#
# List comprehension is a method for list building and is a method to create lists effectively and with little code

# %%
# Example of list comprehension


num1 = [3,2,1]
num2 = [i +1 for i in num1]
num3 = [i * 4 for i in num1]

print(num2)
print(num3)

# %% [markdown]
# **[i + 1 for i in num1 ]**: list of comprehension
# <br> **i +1**: list comprehension syntax
# <br> **for i in num1**: for loop syntax
# <br> **i**: iterator
# <br> **num1**: iterable object

# %%
# Conditionals on iterable 

num1 = [5,10,15]
num2 = [i**2 if i == 10 else i-5 if i < 7 else i+5 for i in num1]
print(num2)

# %%
# Another Example

num1 = [6, 45,10,15, 34,23]
num2 = [i**2 if i == 34 else i-5 if i < 15 else i+5 for i in num1]
print(num2)

num3 = [i*i if i >20 else i+ 5 if i > 10 else i-5 for i in num1]
print(num3)

# %%
data.head()

# %%
# There are null(NaN) values and we need to clean the missing data

data = data.dropna(how='any',axis=0)
data.head()

# %%
# Example Bitcoins:
# threshold is average Weighted_Price


threshold = sum(data.Weighted_Price/len(data.Weighted_Price))
print(threshold)

data['Level'] = ['high' if i > threshold else 'low' for i in data.Weighted_Price]
data.loc[:1000, ['Level', 'Weighted_Price']]

# %% [markdown]
# ### Cleaning Data
#
# Common data problems:
# * Inconsistent column names Missing data
# * Outliers
# * Duplicate rows
# * Untidy
# * Need to process columns
# * Column types can signal unexpected data value
#
# We will use head, tail, columns, shape and info methods to diagnose data

# %%
data.head()

# %%
# tail()
# show last five rows

data.tail()

# %%
# columns
data.columns

# %%
# shape()
# gives number of rows and columns in a tuble

data.shape

# %%
data.info

# %%
data.head()

# %%
# Example: value_counts()
# gives the frequency of the values that are under this column 'Open'
# the value 580.00 appears 622 times

print(data['Open'].value_counts(dropna = False))

# %% [markdown]
# <a id="18"></a> <br>
# ### Explotary Data Analysis
#
# <br>What is quartile?
#
# In general, the goal of quantiles is to divide a data set into sections.
# Dividing the sample into four equal parts thus creates three quartiles, which are also known as the upper quartile, median and lower quartile.
#
# * First quantile: 25%
# * Median / Second quantile: 50%
# * Third quantile: 75%
# * Outliers: is a statistical observation that deviates significantly from other members of a sample.
# * std: standard deviation
# * mean: average of entries
# * count: number of entries
# <br>Example:
#
# <br>Sequenz: 5,9,8,3,0,8,2,7,12 => 0,2,3,5,7,8,8,9,12
#
# <br>Lower quartile:
# * is the median in between the smallest number and the median i.e. in between 0 and 7, which is 3.
#
# <br>Median:
# * sort the data in ascending order and select the record in the middle
# * for even number of data, the average of the two data in the middle is calculated
# * It would be 7
#
# <br>Upper quartile:
# * you find the median between the median and the largest number i.e. between 7 and 12, which will be 8 according to the question above.

# %%
# this method used for calculating some statistical data like percentile, mean and std etc.
# ignore null entries
data.describe()

# %% [markdown]
# <a id="19"></a> <br>
# ### Visual Exploratory Data Analysis
# * Box plots: visualize basic statistics like outliers, min/max or quantiles

# %%
# For example: 
# Black line at top is max
# Blue line at top is 75%
# Green line is median (50%)
# Blue line at bottom is 25%
# Black line at bottom is min
# There are no outliers

# We create new data from bitcoins, so that the loading of the data does not take a long time
data_new = data.head()    # I only take 5 rows into new data
data_new
data_new = data.head()
data_new.boxplot(column='Volume_(BTC)',by = 'Weighted_Price')

# %% [markdown]
# <a id="20"></a> <br>
# ### Tidy Data
# We tidy data with melt().
# The function is used to change the DataFrame format from wide to long.
#
# It's used to create a specific format of the DataFrame object where one or more columns work as identifiers. All the remaining columns are treated as values and unpivoted to the row axis and only two columns – variable and value.

# %%
data_new

# %%
# lets melt
# id_vars = what we do not wish to melt
# value_vars = what we want to melt
melted = pd.melt(frame=data_new,id_vars = 'Timestamp', value_vars= ['Volume_(Currency)','Weighted_Price'])
melted

# %%
# Index is Timestamp
# we undo the whole thing with pivot()
# Finally the variables get their values listed one below the other again
melted.pivot(index ='Timestamp', columns ='variable',values='value')

# %% [markdown]
# ### Concatenating Data

# %%
data = data.dropna(how='any',axis=0)
data1 = data.head()
data2 = data.tail()

conc_data_row = pd.concat([data1,data2], axis = 0, ignore_index = True) # axis=0: adds dataframe
conc_data_row

# %%
data1 =data['Open'].head()
data2 =data['Close'].head()
conc_data_col = pd.concat([data1, data2], axis =1) # axis = 1:adds dataframes in column
conc_data_col

# %% [markdown]
# ### Data Types

# %%
data.dtypes

# %%
data['High'] = data['High'].astype('float')
data['Low'] = data['Low'].astype('float')

# %%
data.dtypes

# %% [markdown]
# <a id="24"></a> <br>
# ### Missing Data and Testing with assert
#
# If we encounter with missing data, what we can do:
# * leave as is
# * drop them with dropna()
# * fill missing value with fillna()
# * fill missing values with test statistics like mean
# <br>Assert statement: check that you can turn on or turn off when you are done with your testing of the program

# %%
data.info()

# %%
data.head()

# %%
# Check expample Open
data['Open'].value_counts(dropna = False) 
# As you can see, there are 1243472 NAN value

# %%
# Lets drop nan values

data1= data
data1['Open'].dropna(inplace = True)

# %%
data1

# %% [markdown]
# ## Assert statement:
# is used to make sure that a certain condition you make is really true.
# <br>For example, you might start from the premise that there is at least one element in a particular list you are using.
# <br>If you want to check that this is really true and print an error if not, then an assert statement is ideal for this.
# <br>If the check by means of the assert statement fails, then an AssertionError is raised.

# %%
# Lets check with assert statement
# Assert statement:
assert 1==1 # return nothing because it is true

# %%
# In order to run all code, we need to make this line comment
# assert 1==2 # return error because it is false

# %%
assert data['Open'].notnull().all() #returns nothing because we do not have nan values

# %%
data['Open'].fillna('empty', inplace = True)

# %%
# # With assert statement we can check a lot of thing. For example
#assert data.columns[1] == 'Open'
#assert data.High.dtypes == np.float

# %%
data.head()
