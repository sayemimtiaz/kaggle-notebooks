# %%
import numpy as np 
import pandas as pd 
import os
import seaborn as sns

# %%
Amazon = pd.read_csv("../input/amazon-top-50-bestselling-books-2009-2019/bestsellers with categories.csv")

# %%
print(os.listdir())

# %%
Amazon.head()

# %%
Amazon.tail()

# %%
Amazon.isnull()

# %%
Amazon.isnull().sum()

# %%
Amazon.Name.duplicated()

# %%
Amazon.duplicated().sum()

# %%
Amazon.Name.duplicated().sum()

# %%
Amazon.columns

# %%
Amazon.keys

# %%
Amazon.loc[Amazon.Name.duplicated(keep='first'),:]

# %%
Amazon_Edit=Amazon.drop_duplicates(subset=['Name'])

# %%
Amazon_Edit.head()

# %%
sns.pairplot(Amazon_Edit)

# %%
sns.relplot(x='Price',y='User Rating',data=Amazon_Edit)
