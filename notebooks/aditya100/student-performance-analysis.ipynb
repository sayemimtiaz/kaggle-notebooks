# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../input/StudentsPerformance.csv')

# %%
df.head()

# %%
df.describe()

# %%
print(df.shape)

# %% [markdown]
# Let's see the gender demographics

# %%
p = sns.countplot(x='gender', data=df)

# %% [markdown]
# Let's analyse the people from different ethnicity

# %%
p = sns.countplot(x='race/ethnicity', data=df)

# %% [markdown]
# Parental level of eduction

# %%
p = sns.countplot(x='parental level of education', data=df)
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
p = sns.countplot(x='lunch', data=df)

# %%
p = sns.countplot(x='test preparation course', data=df)

# %% [markdown]
# Now let's see how these factors effects the students performance in different subjects

# %%
min_pass_marks = 40
df['passed_maths'] = np.where(df['math score']<min_pass_marks, 'F', 'P')
p = sns.countplot(x='gender', data=df, hue='passed_maths')

# %%
df['passed_reading'] = np.where(df['reading score']<min_pass_marks, 'F','P')
p = sns.countplot(x='gender', data=df, hue='passed_reading')

# %%
df['passed_writing'] = np.where(df['writing score']<min_pass_marks, 'F', 'P')
p = sns.countplot(x='gender', data=df, hue='passed_writing')

# %%
p = sns.countplot(x='race/ethnicity', data=df, hue='passed_maths')

# %%
p = sns.countplot(x='race/ethnicity', data=df, hue='passed_reading')

# %%
q = sns.countplot(x='race/ethnicity', data=df, hue='passed_writing')

# %%
p = sns.countplot(x='parental level of education', data=df, hue='passed_maths')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
p = sns.countplot(x='parental level of education', data=df, hue='passed_reading')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
p = sns.countplot(x='parental level of education', data=df, hue='passed_reading')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
p = sns.countplot(x='lunch', data=df, hue='passed_maths')

# %%
p = sns.countplot(x='lunch', data=df, hue='passed_reading')

# %%
p = sns.countplot(x='lunch', data=df, hue='passed_writing')

# %%
p = sns.countplot(x='test preparation course', data=df, hue='passed_maths')

# %%
p = sns.countplot(x='test preparation course', data=df, hue='passed_reading')

# %%
p = sns.countplot(x='test preparation course', data=df, hue='passed_writing')

# %% [markdown]
# Finding the overall score

# %%
df['overall'] = (df['math score'] + df['reading score'] + df['writing score'])/3

# %%
df.head()
