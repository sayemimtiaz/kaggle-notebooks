# %% [markdown]
# **Import numpy, pandas, matplot, seaborn libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# Read the dataset

# %%
cdbsd = pd.read_csv("../input/chicago-divvy-bicycle-sharing-data/data.csv")

# %% [markdown]
# Explore the dataset

# %%
cdbsd.head()

# %%
cdbsd.info()

# %%
cdbsd.shape

# %% [markdown]
# Clean up the dataset

# %%
cdbsd.dropna(inplace = True)

# %% [markdown]
# Explore data field temperature

# %%
cdbsd['temperature'].describe()

# %% [markdown]
# Round the data field temperature

# %%
cdbsd['new_temperature'] = cdbsd['temperature'].round(0)

# %% [markdown]
# Group by new_temperature

# %%
cdbsd.groupby('new_temperature').count()[['trip_id']]

# %% [markdown]
# Summarizing the dataset measured on temperature

# %%
cdbsd.boxplot(column='new_temperature')

# %%
cdbsd['new_temperature'].hist()
