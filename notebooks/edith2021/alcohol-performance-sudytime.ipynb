# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import MinMaxScaler
ms=MinMaxScaler()

# %%
from scipy.stats import zscore

# %%
df_mat=pd.read_csv('/kaggle/input/student-alcohol-consumption/student-mat.csv')

# %%
df_mat.head()

# %%
#df_por.head()

# %%
df_mat.columns

# %%
df_mat.school.unique()

# %%
df_mat.Mjob.unique()

# %%
df_mat.Fjob.unique()

# %%
df_mat.Medu.unique()

# %%
data.studytime.unique()

# %%
data=df_mat

# %%
data['avg']=(data['G1']+data['G2']+data['G3'])/3

# %%
plt.rcParams["figure.figsize"]=[14,6]

# %%
sns.lineplot(data=data,y='avg',x='studytime')
plt.show()

# %%
sns.scatterplot(data=data,y='avg',x='studytime')
plt.show()

# %%
sns.lineplot(data=data,x='studytime',y='failures')
plt.show()

# %%
sns.scatterplot(data=data,x='studytime',y='failures')
plt.show()

# %%
data.head()

# %%
data.talc.mean()

# %%
data.talc.median()

# %%
data['talc']=data['Walc']+data['Dalc']

# %%
sns.distplot(data['talc'])
plt.axvline(data.talc.mean(),color='black',label='mean')
plt.axvline(data.talc.median(),label='median')
plt.legend()
plt.show()

# %%
sns.distplot(ms.fit_transform(data[['talc']]))

# %%
sns.lineplot(data.studytime,data.talc,)

# %%
sns.scatterplot(data.studytime,data.talc,)

# %%
sns.lmplot(x='studytime',y='talc',data=data)

# %%
sns.lineplot(data=data,y='health',x='talc')

# %%
sns.scatterplot(data=data,y='health',x='talc',)

# %%
sns.scatterplot(data=data,y='avg',x='talc',hue='famsize')

# %%
sns.swarmplot(data=data,y='avg',hue='talc',x='famsize')

# %%
sns.countplot(data.famsize)

# %%
sns.boxplot(data=data,x='talc',y='avg',hue='activities',)

# %%
sns.scatterplot(data=data,x='talc',y='avg',hue='activities',)
