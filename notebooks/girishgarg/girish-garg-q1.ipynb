# %% [markdown]
# # Girish Garg
# # A 34
# # 12019002002048

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Load a dataset of your choice

# %%
dataset = pd.read_csv("../input/suicide-rates-overview-1985-to-2016/master.csv")

# %% [markdown]
# display the first 11 rows

# %%
dataset.iloc[0:11, :]

# %% [markdown]
# display a row of that dataset having missing values, and replace missing values with Nan

# %%
rows_with_missing_val = dataset[dataset.isnull().any(axis=1)]
rows_with_missing_val.iloc[0, :]

# %%
dataset.info()
