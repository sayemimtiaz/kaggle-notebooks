# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn import linear_model, metrics, model_selection


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
titanic=pd.read_csv('../input/titanicdataset-traincsv/train.csv')

# %%
titanic.head(5)

# %%
titanic["Sex"].replace({"male": "0", "female": "1"}, inplace=True)

# %%
titanic["Cabin"].fillna(0)

# %% [markdown]
# titanic[['Cabin']].apply(lambda x: pd.Series([x.str[split_locations[x.name]:][0], x.str[:split_locations[x.name]][0]]), axis=1)

# %%
titanic.head(20)

# %%
le = preprocessing.LabelEncoder()
le.fit(titanic["Cabin"])

# %%
classes=list(le.classes_)

# %%
titanic["Cabin"]=le.transform(titanic["Cabin"])

# %%
  
# Creating an instance of the sklearn.preprocessing.MinMaxScaler()
scaler = MinMaxScaler()
  
# Scaling the Price column of the created dataFrame and storing
# the result in ScaledPrice Column
titanic[["Cabin"]] = scaler.fit_transform(titanic[["Cabin"]])

# %%
titanic["Cabin"].head(4)

# %%
titanic["Fare"]=titanic["Fare"].values.astype(int)

# %%
titanic["Cabin"].value_counts()

# %%
mean=np.mean(titanic['Age'])
titanic['Age']=titanic["Age"].fillna(mean)

# %%
titanic["Age"]=titanic["Age"].values.astype(int)
titanic["Parch"]=titanic["Parch"].values.astype(int)
titanic["SibSp"]=titanic["SibSp"].values.astype(int)

# %%
titanic.dtypes

# %%
len(titanic)-titanic["Embarked"].count()

# %%
titanic["Embarked"].replace({"C": "1", "S": "2","Q":"3"}, inplace=True)
titanic["Embarked"]=titanic["Embarked"].fillna(0)

# %%
titanic

# %%
survivors=titanic[titanic["Survived"]==1]

# %%
titanic.head(4)

# %%
titanic.plot(kind = 'scatter', x = "Fare", y = "Cabin")

# %%
titanic.plot(kind = 'scatter', x = "PassengerId", y = "Survived")

# %%
survivors.dtypes

# %%
 survivors["Age"].plot(kind="bar")

# %%
survivors.plot(kind = 'scatter', x = "PassengerId", y = "Age")

plt.show()

# %%
survivors.plot(kind = 'scatter', x = "PassengerId", y = "Pclass")

# %%
survivors.plot(kind = 'scatter', x = "PassengerId", y = "Parch")

# %%
titanic.corr()

# %%
X_train,X_test,Y_train,Y_test=train_test_split(titanic[["Age","Pclass","Parch","Sex","Cabin","Fare"]],titanic.Survived,test_size=0.2)

# %%
X_train.head(4)

# %%
Y_train.head(3)

# %%
model1=linear_model.LogisticRegression()

# %%
model1.fit(X_train,Y_train)

# %%
X_test

# %%
Y_test

# %%
model1.predict(X_test)

# %%
model1.score(X_test,Y_test)

# %%
titanic

# %%
titanictest=pd.read_csv("../input/titanic-test-set/test.csv")

# %%
titanictest.head(10)

# %%
titanictest["Age"].value_counts()

# %%
titanic.isna().sum()

# %%
titanictest.Age

# %%
mean1=np.mean(titanictest["Age"])

# %%
titanictest["Age"]=titanictest["Age"].fillna(mean)

# %%
titanictest["Fare"]=titanictest["Fare"].values.astype(int)

# %%
le.fit(titanictest["Cabin"])

# %%
titanictest["Cabin"]=le.transform(titanictest["Cabin"])

# %%
titanictest["Cabin"].head(3)

# %%
titanictest[["Cabin"]] = scaler.fit_transform(titanictest[["Cabin"]])

# %%
titanictest["Cabin"].head(3)

# %%
titanictest["Sex"].replace({"female": "1", "male": "0"}, inplace=True)

# %%
test1=titanictest[["Age","Pclass","Parch","Sex","Fare","Cabin"]]

# %%
test1.head(10)

# %%
result1=model1.predict(titanictest[["Age","Pclass","Parch","Sex","Cabin","Fare"]])

# %%
resultData=pd.DataFrame(result1,columns=["Survived"])

# %%
titanic_PassengerId=pd.DataFrame(titanictest["PassengerId"],columns=["PassengerId"])

# %%
titanic_PassengerId

# %%
titanicResult=titanic_PassengerId.join(resultData)

# %%
titanicResult.to_csv("titanic_resultLR.csv",index=None)
