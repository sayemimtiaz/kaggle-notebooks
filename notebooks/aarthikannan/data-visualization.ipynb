# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
dataframe1 = pd.read_csv("/kaggle/input/palmer-archipelago-antarctica-penguin-data/penguins_size.csv")
dataframe2 = pd.read_csv("/kaggle/input/palmer-archipelago-antarctica-penguin-data/penguins_lter.csv")

# %% [markdown]
# *Analyzing the Penguin_data csv initially using Pandas and Data visualization library.*

# %% [markdown]
# **Find out the Shape of the dataset**

# %%
dataframe1.shape

# %% [markdown]
# ***Find out the column names ***

# %%
dataframe1.columns

# %% [markdown]
# ***Find out the null elements in the dataset***

# %%
dataframe1.isnull().sum()

# %%
dataframe1.species.value_counts()

# %% [markdown]
# ***Plotting horizontal bar graph***

# %%
dataframe1.species.value_counts().plot.barh()

# %% [markdown]
# ***Finding the distribution of island***

# %%
dataframe1.island.value_counts().plot.barh()

# %% [markdown]
# ***Using scatter plot find out the distribution of species and island***

# %%
plt.title("Plot between Species and Island")
plt.scatter(dataframe1.species, dataframe1.island)
plt.xlabel("Species")
plt.ylabel("Island")
plt.show()

# %% [markdown]
# ***Plotting line plot***

# %%
sns.pairplot(dataframe1, hue = "species", palette = "husl")
plt.show()

# %%
dataframe1.head(10)
