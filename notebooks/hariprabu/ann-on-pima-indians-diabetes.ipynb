# %%
import pandas as pd
import numpy as np
import tensorflow
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
df=pd.read_csv("../input/pima-indians-diabetes-database/diabetes.csv")
df.head()

# %%
x=df.iloc[:,0:8]
y=df.iloc[:,8]

# %%
x.head(2)

# %%
y.head(2)

# %%
df_model=Sequential()
df_model.add(Dense(64,input_dim=8,activation='sigmoid'))
df_model.add(Dense(32,activation='relu'))
df_model.add(Dense(8,activation='tanh'))
df_model.add(Dense(1,activation='sigmoid'))
df_model.compile(loss='binary_crossentropy',optimizer='adam',metrics='accuracy')

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
df_model.fit(x_train,y_train,epochs=1000,verbose=2,batch_size=20)

# %%
df_model.summary()

# %%
y_pred=df_model.predict_classes(x_test)

# %%
y_pred

# %%
score=df_model.evaluate(x_test,y_test)
score

# %% [markdown]
# For Checking the prediction ver variable is created.

# %%
ver=df.iloc[203:208,:-1]
ver

# %%
df.iloc[203:208,:]

# %%
df_model.predict_classes(ver)
