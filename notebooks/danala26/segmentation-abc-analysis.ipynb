# %% [markdown]
# # Segmentation - ABC Analysis

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/supplier-scm/supplier_data.csv
# /kaggle/input/online-retail-ii-uci/online_retail_II.csv

# %%
pip install inventorize3
# Out:
# Collecting inventorize3
#   Downloading inventorize3-0.0.1.tar.gz (16 kB)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from inventorize3) (1.4.1)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.7/site-packages (from inventorize3) (0.23.2)
# Requirement already satisfied: pandas>=0.23.3 in /opt/conda/lib/python3.7/site-packages (from inventorize3) (1.2.0)
# Requirement already satisfied: numpy>=1.14.5 in /opt/conda/lib/python3.7/site-packages (from inventorize3) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.23.3->inventorize3) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.23.3->inventorize3) (2019.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=0.23.3->inventorize3) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.7/site-packages (from scikit-learn->inventorize3) (1.0.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn->inventorize3) (2.1.0)
# Building wheels for collected packages: inventorize3
#   Building wheel for inventorize3 (setup.py) ... done
#   Created wheel for inventorize3: filename=inventorize3-0.0.1-py3-none-any.whl size=15604 sha256=f8d31dba2ea159254a088d74576ee52f08ca22d0c28f2088438a4def39e47c65
#   Stored in directory: /root/.cache/pip/wheels/10/81/ca/1b8df04e233213dc92a89f64f56f04eeba6e6f1f12ba264de3
# Successfully built inventorize3
# Installing collected packages: inventorize3
# Successfully installed inventorize3-0.0.1
# WARNING: You are using pip version 21.0; however, version 21.0.1 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import inventorize3 as inv

# %%
retail=pd.read_csv('../input/online-retail-ii-uci/online_retail_II.csv')

# %%
retail=retail.drop_duplicates()

# %%
retail=retail.dropna()
retail_clean=retail.copy()
retail_clean.to_csv('retail_clean.csv',index=False)

# %%
# Removing negative values
retail_clean=retail_clean[retail_clean.Quantity>0]

# %%
# Make a calulated revenue column
retail_clean['Revenue']=retail_clean['Quantity']*retail_clean['Price']

# %%
retail_clean.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country', 'Revenue'],
#       dtype='object')

# %%
group_df= retail_clean.groupby('Description').agg(total_sale=('Quantity',np.sum),
                                                 total_rev=('Revenue',np.sum)).reset_index()

# %%
group_df.to_csv('ABC_data.csv',index=False)

# %% [markdown]
# ## ABC analysis

# %%
a = inv.ABC(group_df[['Description','total_sale']])

# %%
a
# Out:
#                              Description  total_sale    Percentage  \
# 5168   WORLD WAR 2 GLIDERS ASSTD DESIGNS      105185  9.990307e-03
# 5047  WHITE HANGING HEART T-LIGHT HOLDER       91757  8.714937e-03
# 3129         PAPER CRAFT , LITTLE BIRDIE       80995  7.692779e-03
# 292        ASSORTED COLOUR BIRD ORNAMENT       78234  7.430543e-03
# 2695      MEDIUM CERAMIC TOP STORAGE JAR       77916  7.400340e-03
# ...                                  ...         ...           ...
# 3451           PINK STRIPES SHOULDER BAG           1  9.497844e-08
# 4370     SILVER AND BLACK ORBIT NECKLACE           1  9.497844e-08
# 479       BLACK DIAMOND CLUSTER EARRINGS           1  9.497844e-08
# 4271     SET/2 SPOTTY + ROSE TEA TOWELS            1  9.497844e-08
# 4046     SET 12 COLOURING PENCILS DOILEY           1  9.497844e-08
#
#       comulative Category
# 5168    0.009990        A
# 5047    0.018705        A
# 3129    0.026398        A
# 292     0.033829        A
# 2695    0.041229        A
# ...          ...      ...
# 3451    1.000000        C
# 4370    1.000000        C
# 479     1.000000        C
# 4271    1.000000        C
# 4046    1.000000        C
#
# [5283 rows x 5 columns]

# %%
a.Category.value_counts()
# Out:
# C    2881
# B    1245
# A    1157
# Name: Category, dtype: int64

# %%
sns.countplot('Category',data=a)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
sns.barplot(x='Category',y='total_sale',data=a)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='total_sale'>

# %% [markdown]
# ## Multi-criteria ABC analysis on agg level

# %%
b = inv.productmix(group_df['Description'],group_df['total_sale'],group_df['total_rev'])
b
# Out:
#                                     skus  sales     revenue     sales_mix  \
# 3769            REGENCY CAKESTAND 3 TIER  24139  277656.250  2.292685e-03
# 5047  WHITE HANGING HEART T-LIGHT HOLDER  91757  247048.010  8.714937e-03
# 3129         PAPER CRAFT , LITTLE BIRDIE  80995  168469.600  7.692779e-03
# 2860                              Manual   9391  151777.670  8.919426e-04
# 2392             JUMBO BAG RED RETROSPOT  74224  134307.440  7.049680e-03
# ...                                  ...    ...         ...           ...
# 894          CAT W SUNGLASSES BLANK CARD      4       0.760  3.799138e-07
# 4046     SET 12 COLOURING PENCILS DOILEY      1       0.650  9.497844e-08
# 3357     PINK HEART CHRISTMAS DECORATION      1       0.380  9.497844e-08
# 2181      HAPPY BIRTHDAY GINGER CAT CARD      2       0.380  1.899569e-07
# 3079          PADS TO MATCH ALL CUSHIONS     18       0.017  1.709612e-06
#
#       comulative_sales   revenue_mix  comulative_revenue sales_category  \
# 3769          0.177816  1.598040e-02            0.015980              A
# 5047          0.018705  1.421875e-02            0.030199              A
# 3129          0.026398  9.696201e-03            0.039895              A
# 2860          0.424068  8.735504e-03            0.048631              A
# 2392          0.048279  7.730012e-03            0.056361              A
# ...                ...           ...                 ...            ...
# 894           0.999966  4.374150e-08            1.000000              C
# 4046          1.000000  3.741049e-08            1.000000              C
# 3357          0.999998  2.187075e-08            1.000000              C
# 2181          0.999991  2.187075e-08            1.000000              C
# 3079          0.999569  9.784283e-10            1.000000              C
#
#      revenue_category product_mix
# 3769                A         A_A
# 5047                A         A_A
# 3129                A         A_A
# 2860                A         A_A
# 2392                A         A_A
# ...               ...         ...
# 894                 C         C_C
# 4046                C         C_C
# 3357                C         C_C
# 2181                C         C_C
# 3079                C         C_C
#
# [5283 rows x 10 columns]

# %%
# Product mix
b.columns
# Out:
# Index(['skus', 'sales', 'revenue', 'sales_mix', 'comulative_sales',
#        'revenue_mix', 'comulative_revenue', 'sales_category',
#        'revenue_category', 'product_mix'],
#       dtype='object')

# %%
b.product_mix.value_counts()
# Out:
# C_C    2394
# A_A     775
# B_B     632
# C_B     413
# B_C     325
# A_B     317
# B_A     288
# C_A      74
# A_C      65
# Name: product_mix, dtype: int64

# %%
sns.countplot('product_mix',data=b)
# Out:
# <AxesSubplot:xlabel='product_mix', ylabel='count'>

# %%
sns.barplot(x='product_mix',y='sales',data=b)
# Out:
# <AxesSubplot:xlabel='product_mix', ylabel='sales'>

# %%
sns.barplot(x='product_mix',y='revenue',data=b)
# Out:
# <AxesSubplot:xlabel='product_mix', ylabel='revenue'>

# %% [markdown]
# ## Multi-criteria ABC analysis on store/department level

# %%
retail_clean.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country', 'Revenue'],
#       dtype='object')

# %%
by_store=retail_clean.groupby(['Description','Country']).agg(total_sales=('Quantity',np.sum),
                                                 total_revenue=('Revenue',np.sum)).reset_index()

# %%
mix_country = inv.productmix_storelevel(by_store['Description'],
                             by_store['total_sales'],
                             by_store['total_revenue'],
                             by_store['Country'])

# %%
mix_country.columns
# Out:
# Index(['sku', 'sales', 'revenue', 'storeofsku', 'sales_mix',
#        'comulative_sales', 'revenue_mix', 'comulative_revenue',
#        'sales_category', 'revenue_category', 'product_mix'],
#       dtype='object')

# %%
product_mix = mix_country.groupby(['storeofsku','product_mix']).count().reset_index().iloc[:,0:3]

# %%
product_mix
# Out:
#       storeofsku product_mix  sku
# 0      Australia         A_A  176
# 1      Australia         A_B   79
# 2      Australia         A_C    7
# 3      Australia         B_A   76
# 4      Australia         B_B  104
# ..           ...         ...  ...
# 348  West Indies         B_B    4
# 349  West Indies         B_C    4
# 350  West Indies         C_A    6
# 351  West Indies         C_B    3
# 352  West Indies         C_C    4
#
# [353 rows x 3 columns]

# %%
product_mix[product_mix.storeofsku=='Australia']
# Out:
#   storeofsku product_mix  sku
# 0  Australia         A_A  176
# 1  Australia         A_B   79
# 2  Australia         A_C    7
# 3  Australia         B_A   76
# 4  Australia         B_B  104
# 5  Australia         B_C   26
# 6  Australia         C_A    8
# 7  Australia         C_B   59
# 8  Australia         C_C  298

# %% [markdown]
# ## Supplier Segmentation

# %%
supplier= pd.read_csv('../input/supplier-scm/supplier_data.csv')

# %%
supplier.head()
# Out:
#     supplier    product  availability  no_suppliers  standard  \
# 0  supplier1  product_1           0.0           0.5       0.0
# 1  supplier1  product_2           0.0           0.5       0.0
# 2  supplier1  product_3           0.0           0.5       0.0
# 3  supplier1  product_4           0.0           0.5       0.0
# 4  supplier1  product_5           0.0           0.5       0.0
#
#    price_fluctuation  Quantity  price
# 0                0.5       710    360
# 1                0.5      2997   2740
# 2                0.5      3917   2919
# 3                0.5      3827   3246
# 4                0.0      3882   3596

# %%
supplier.columns
# Out:
# Index(['supplier', 'product', 'availability', 'no_suppliers', 'standard',
#        'price_fluctuation', 'Quantity', 'price'],
#       dtype='object')

# %%
## Calculate supplier risk index by identifying risk columns
supplier['Risk_index']=supplier['availability']+supplier['no_suppliers']+supplier['standard']+supplier['price_fluctuation']

# %%
# less than 1 can be termed as low-risk and more than one as high-risk
supplier.Risk_index.value_counts()
# Out:
# 1.0    16
# 0.5     6
# 1.5     2
# Name: Risk_index, dtype: int64

# %%
# Calculate value index
supplier['value_index']= supplier['Quantity']*supplier['price']

# %%
supplier.value_index.describe()
# Out:
# count    2.400000e+01
# mean     5.064812e+06
# std      4.847504e+06
# min      1.189500e+05
# 25%      7.975622e+05
# 50%      3.011452e+06
# 75%      8.499426e+06
# max      1.399081e+07
# Name: value_index, dtype: float64

# %% [markdown]
# ### Based on the above statistics we can conclude that the 50 percentile i.e median is at 3M and now we can categorize items below this value as low and above as high.

# %% [markdown]
# ## Visualizing Krajic

# %%
# define a function to map item prioritites on the data

def category(x,y):
    if ((x>=300000) & (y>=1)):
        return 'Strategic'
    if ((x>=300000) & (y<1)):
        return 'Leverage'
    if ((x<300000) & (y>=1)):
        return 'Critical'
    if ((x<300000) & (y<1)):
        return 'Routine'

# %%
for i in range(supplier.shape[0]):
    supplier.loc[i,'category']= category(supplier.loc[i,'value_index'],supplier.loc[i,'Risk_index'])

# %%
supplier.category.value_counts()
# Out:
# Strategic    16
# Leverage      6
# Critical      2
# Name: category, dtype: int64

# %%
sns.scatterplot(x='value_index', y='Risk_index', data=supplier, hue='category')
# Out:
# <AxesSubplot:xlabel='value_index', ylabel='Risk_index'>
