# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from pylab import rcParams
#sklearn 
import sklearn
from sklearn.cluster import KMeans 
from sklearn.preprocessing import scale # for scaling the data
import sklearn.metrics as sm # for evaluating the model
from sklearn import datasets
from sklearn.metrics import confusion_matrix,classification_report
import plotly.express as px
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df=pd.read_csv("/kaggle/input/top50spotify2019/top50.csv",encoding='ISO-8859-1')
df.head()

# %%
df.info()

# %%
df.corr()

# %%
df.columns

# %%
df=df.rename(columns={'Loudness..dB..':"loud",'Valence.':"valence",'Length.':"length",'Acousticness..':"acoust",'Speechiness.':"speech",'Beats.Per.Minute':"bpm",'Track.Name':"track", 'Artist.Name':"artist"})

# %%
df=df.drop(['Unnamed: 0'],axis=1)
df.head()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
heatmap=sns.heatmap(df.corr(),vmax=1, vmin=-1,annot=True,cmap="BrBG")
plt.figure(figsize=(16, 6))

# %% [markdown]
# one can notice that the only relations having r more that .5 are (bpm and speech )and (loud and energy).

# %%
df.Genre.value_counts().plot(kind="bar")

# %%
df.Genre.value_counts()

# %%
df.artist.value_counts()

# %%
for i in df.Genre:
    if "pop" in i:
        df.Genre=df.Genre.replace(i,"pop")
    if "edm" in i:
        df.Genre=df.Genre.replace(i,"edm")
    if "hip hop" in i: 
        df.Genre=df.Genre.replace(i,"hip hop")
    if "room" in i:
        df.Genre=df.Genre.replace(i,"room")
    if "r&b"  in i:  
        df.Genre=df.Genre.replace(i,"r&b")
    if "reggae" in i:  
        df.Genre=df.Genre.replace(i,"reggae")
    if "rap" in i:
        df.Genre =df.Genre.replace(i,"hip hop")
    if "boy band" in i:
        df.Genre=df.Genre.replace(i,"pop")

# %%
df.Genre.unique()

# %%
df.Genre.value_counts()

# %% [markdown]
# to prevent disproportionate clustering we need at least 3

# %%
for i in df.Genre:
    if "pop" in i:
        df.Genre=df.Genre.replace(i,"pop")
    if "edm" in i:
        df.Genre=df.Genre.replace(i,"edm")
    if "hip hop" in i: 
        df.Genre=df.Genre.replace(i,"hip hop")
    if "room" in i:
        df.Genre=df.Genre.replace(i,"other")
    if "r&b"  in i:  
        df.Genre=df.Genre.replace(i,"other")
    if "reggae" in i:  
        df.Genre=df.Genre.replace(i,"reggae")
    if "rap" in i:
        df.Genre =df.Genre.replace(i,"hip hop")
    if "boy band" in i:
        df.Genre=df.Genre.replace(i,"pop")
    if "brostep" in i:
        df.Genre=df.Genre.replace(i,"other")

# %%
df.Genre.value_counts()

# %%
df=df.drop(["track"],axis=1)

# %%
df.head()

# %%
hiphop=df[df.Genre=="hip hop"]
pop=df[df.Genre=="pop"]
reggae=df[df.Genre=="reggae"]
latin=df[df.Genre=="latin"]
other=df[df.Genre=="other"]
edm=df[df.Genre=="edm"]

# %%
hiphop

# %% [markdown]
# the following histograms describe no of tracks on the left and popularity of each track of each individual artist of a genre (color)

# %%
px.histogram(hiphop,x='artist',color='Popularity')

# %%
 px.histogram(edm,x='artist',color='Popularity')

# %%
px.histogram(pop,x='artist',color='Popularity')

# %%
px.histogram(other,x='artist',color='Popularity')

# %%
px.histogram(latin,x='artist',color='Popularity')

# %%
px.histogram(reggae,x='artist',color='Popularity')

# %% [markdown]
# # prediction

# %% [markdown]
# ****Linear regression****

# %%
df.head()

# %%
df=df.drop(["artist","Genre"],axis=1)
df.head()

# %%
X=df.iloc[:,1:-1]
y=df.iloc[:,-1]

# %%
X.shape

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)
model.fit(X_train,y_train)

# %%
y_pred=model.predict(X_test)

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# %%
from statsmodels.api import OLS
OLS(y_train,X_train).fit().summary()

# %% [markdown]
# one can tell from the p-value keeping our hypothesis limit to 0.05 that speech , length,valence has a bad effect.

# %% [markdown]
# **trying to increase r**

# %%
X1=df.iloc[:,1:5]
y1=df.iloc[:,-1]
X1.join(df.iloc[:,7])

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.20)
model.fit(X1_train,y1_train)

# %%
y_pred1=model.predict(X1_test)

# %%
from statsmodels.api import OLS
OLS(y1_train,X1_train).fit().summary()

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y1_test, y_pred1))
print('Mean Squared Error:', metrics.mean_squared_error(y1_test, y_pred1))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y1_test, y_pred1)))

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
model2=DecisionTreeClassifier()
model2.fit(X_train,y_train)

# %%
y1_pred=model2.predict(X_test)

# %%
y1_test

# %%
y1_pred

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y1_test, y1_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y1_test, y1_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y1_test, y1_pred)))

# %%
model3=RandomForestClassifier()
model3.fit(X1_train,y1_train)

# %%
y3_pred=model3.predict(X1_test)

# %%
y1_test

# %%
y3_pred

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y1_test, y1_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y1_test, y1_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y1_test, y1_pred)))
