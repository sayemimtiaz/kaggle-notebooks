# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('../input/hr-analytics/HR_comma_sep.csv')
df

# %%
df.describe()

# %% [markdown]
# # Data exploration and visualization

# %%
left = df.left[df.left==1]
left.shape

# %%
retained = df.left[df.left==0]
retained.shape

# %% [markdown]
# ## Average numbers for all columns

# %%
df.groupby('left').mean()

# %% [markdown]
# - Satisfation_level is relatively low in those who left
# - average_monthly_hours is high in those who left
# - Those who got promotion stayed

# %%
pd.crosstab(df.salary,df.left).plot(kind='bar')

# %%
pd.crosstab(df.Department,df.left).plot(kind='bar')

# %% [markdown]
# ##  After Data Analysis and visualisation
# - using satisfaction_level,average_montly_hours,promotion_last_5years,salary as features
# - label is left

# %%
subdf = df[['satisfaction_level','average_montly_hours','promotion_last_5years','salary']]
subdf.head()

# %% [markdown]
# Salary has categorical values it needs to be converted to numerical so, using dummy variables

# %%
salary_dummies = pd.get_dummies(subdf.salary, prefix = "salary")
df_with_dummies = pd.concat([subdf,salary_dummies],axis='columns')
df_with_dummies.head()

# %%
df_with_dummies.drop('salary',axis='columns',inplace=True)
df_with_dummies.head()

# %%
y = df.left
X = df_with_dummies
X.head()

# %% [markdown]
# # spliting the data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)

# %%
model.predict(X_test)

# %% [markdown]
# # Accuracy

# %%
model.score(X_test,y_test)
