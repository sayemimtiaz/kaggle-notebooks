# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../input/vehicle-dataset-from-cardekho/car data.csv")

# %%
df.head()

# %%
df.drop(['Car_Name'], axis = 1, inplace= True)

# %%
df.isnull().sum()

# %%
df['Fuel_Type'].unique()

# %%
df['Seller_Type'].unique()

# %%
df['Transmission'].unique()

# %%
#current year is 2020
df['Years_ran']  = 2020 - df['Year'] 
df.drop(['Year'], axis = 1, inplace= True)

# %%
X = df.iloc[:, 1:].values
y = df.iloc[:, 0].values

# %%
y = y.reshape(len(y),1)

# %%
#OneHotEncoding for 'Fuel Type'.
from sklearn.compose import  ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

ct = ColumnTransformer(transformers= [('encoder' , OneHotEncoder(), [2])], remainder = 'passthrough')
X = np.array(ct.fit_transform(X))

# %%
#Label Encoding for 'Transmission' - 6
#Label Encoding for 'Seller-Type' - 5
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X[:,6] = le.fit_transform(X[:,6])
X[:,5] = le.fit_transform(X[:, 5])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
X_train

# %%
X_test

# %%
y_train

# %%
y_test

# %% [markdown]
# **Multiple Linear Regression**

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)

# %%
y_pred = lr.predict(X_test)
result = np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1)

# %%
result

# %%
#Accuracy
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)

# %% [markdown]
# **Decision Tree Regression**

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor(random_state = 1)
dtr.fit(X_train, y_train)

y_pred_dtr = dtr.predict(X_test)

from sklearn.metrics import r2_score
r2_score(y_test, y_pred_dtr)

# %% [markdown]
# **Random Forest**

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators = 10, random_state = 1)
rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

from sklearn.metrics import r2_score
r2_score(y_test, y_pred_rf)

# %% [markdown]
# **SVM**

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X_train = sc_X.fit_transform(X_train)
y_train = sc_y.fit_transform(y_train)

# %%
from sklearn.svm import SVR
svr = SVR(kernel = 'rbf')
svr.fit(X_train, y_train)

y_pred_svm = sc_y.inverse_transform(svr.predict(sc_X.transform(X_test)))

from sklearn.metrics import r2_score
r2_score(y_test, y_pred_rf)

# %% [markdown]
# 1. R2 score for Multiple Linear Regression - 0.8625260513310015
# 2. Support Vector Regression R2 Score      - 0.8369462434759469
# 3. Decision Tree Regression R2 Score       - 0.9609582565152528
# 4. Random Forest Regression R2 Score       - 0.8369462434759469

# %% [markdown]
# ***Suggest Method is Decision Tree Regression***
