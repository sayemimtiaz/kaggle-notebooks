# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

import seaborn as sns

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
data = pd.read_csv('../input/heart-failure-clinical-data/heart_failure_clinical_records_dataset.csv')
data.head()

# %%
death = data.loc[data['DEATH_EVENT']==1]
non_death = data.loc[data['DEATH_EVENT']!=1]

sns.distplot(death['age'],hist=False,label='Death')
sns.distplot(non_death['age'],hist=False,label ='Non-Death')
plt.title('Age distribution for death and non-death cases')

# %%
labels=[1,0]
sizes=[death['sex'].value_counts()[0],death['sex'].value_counts()[1]]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Gender distribution for death cases')
plt.show()

# %%
sizes=[non_death['sex'].value_counts()[0],non_death['sex'].value_counts()[1]]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Gender distribution for non-death cases')
plt.show()

# %%
sliced_data = data.loc[data['age']>=70]
sliced_data_death = sliced_data.loc[sliced_data['DEATH_EVENT']==1]
sliced_data_non_death = sliced_data.loc[sliced_data['DEATH_EVENT']==0]

# %%
sizes=[sliced_data_non_death['sex'].value_counts()[0],sliced_data_non_death['sex'].value_counts()[1]]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Gender distribution for non-death cases of age above 70')
plt.show()

# %%
sns.distplot(death['platelets'],hist=False,label='Death')
sns.distplot(non_death['platelets'],hist=False,label='non-Death')
plt.title('Probability Distribution for platelets for death and non death')

# %%
sns.scatterplot(y='platelets',x='age',hue='DEATH_EVENT',data=data)

# %%
labels=death['high_blood_pressure'].value_counts().index
sizes=[death['high_blood_pressure'].value_counts()[0],death['high_blood_pressure'].value_counts()[1]]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Blood Pressure for death cases')
plt.show()

# %%
labels=death['high_blood_pressure'].value_counts().index
sizes=[non_death['high_blood_pressure'].value_counts()[0],non_death['high_blood_pressure'].value_counts()[1]]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Blood Pressure for Non death cases')
plt.show()

# %%
labels1 = death['smoking'].value_counts()
labels1
death['smoking'].value_counts().index
labels1[0],labels1[1]
#labels=data['DEATH_EVENT'].value_counts()
[labels1[0],labels1[1]]

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
cat = [str(item).replace('0', 'non-smoker').replace('1', 'smoker') for item in death['smoking'].value_counts().index.to_list()]
count = death['smoking'].value_counts(normalize=True) * 100
ax.bar(cat,count)
plt.title('For death case')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
cat = [str(item).replace('0', 'non-smoker').replace('1', 'smoker') for item in death['smoking'].value_counts().index.to_list()]
count = non_death['smoking'].value_counts(normalize=True) * 100
ax.bar(cat,count)
plt.title('For non-death case')
plt.show()

# %%
sns.distplot(death['serum_sodium'],hist=False,label='Death')
sns.distplot(non_death['serum_sodium'],hist=False,label ='Non-Death')
plt.title('serum sodium distribution for death and non-death cases')

# %%
sns.distplot(death['serum_creatinine'],hist=False,label='Death')
sns.distplot(non_death['serum_creatinine'],hist=False,label ='Non-Death')
plt.title('serum_creatinine distribution for death and non-death cases')

# %%
sns.scatterplot(y='serum_creatinine',x='serum_sodium',hue='DEATH_EVENT',data=data)

# %%
def t_test1(X,Y):
    ztest ,pval1 = stests.ztest(X, x2=Y, value=0,alternative='two-sided')
    print(float(pval1))
    if pval<0.05:
        print("reject null hypothesis")
    else:
        print("accept null hypothesis")

# %%
t_test1(death['serum_sodium'],non_death['serum_sodium'])

# %%
t_test1(death['serum_creatinine'],non_death['serum_creatinine'])

# %%
t_test1(death['platelets'],non_death['platelets'])

# %%
t_test1(death['age'],non_death['age'])

# %%
Now its clearly visible that above will be all the above are not in same population. Means that rejected the null hypothesis
