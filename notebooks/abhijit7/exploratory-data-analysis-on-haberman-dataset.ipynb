# %% [markdown]
# # Data Visualization with Haberman Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import os
print(os.listdir('../input'))
haberman= pd.read_csv('../input/haberman.csv', header=None, names=['age', 'year', 'nodes', 'status'])

# %%
haberman.head()

# %%
haberman.tail()

# %%
print('No. of points,no. of features in Haberman Cancer Survival dataset : {}'.format(haberman.shape))

# %%
print(haberman.columns)
print('age: Age of the patient')
print('year: Year of ooperation of the patient')
print('Nodes: Number of axillary lymph nodes')
print('Status: Status of the patient')
print('\n')
print('The axillary lymph nodes or armpit lymph nodes (20 to 49 in number) drain lymph vessels from the lateral quadrants of the breast, the superficial lymph vessels from thin walls of the chest and the abdomen above the level of the navel, and the vessels from the upper limb. They are divided in several groups according to their location in the armpit. These lymph nodes are clinically significant in breast cancer, and metastases from the breast to the axillary lymph nodes are considered in the staging of the disease.')

# %%
print('Number of features:3')
print('Number of classes:1')

# %%
print('data points per class')
print("1: Patient survived for more than 5 years")
print('2: Patient survived for less than 5 years')

# %%
print('Objective of EDA on Hyberman Cancer Survival Analysis: To predict whether the cancer patient will survive for more the five years or not '   )

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# # 1-D Scatter Plot

# %%
import numpy as np

haberman_1=haberman.loc[haberman['status']==1]
haberman_2=haberman.loc[haberman['status']==2]


plt.plot(haberman_1['age'],np.zeros_like(haberman_1['age']),'o',label='status 1')
plt.plot(haberman_2['age'],np.zeros_like(haberman_2['age']),'o',label='status 2')
plt.grid()
plt.legend()
plt.title('1-D Scatter Plot of age of patients ')
plt.show()

# %%
plt.plot(haberman_1['year'],np.zeros_like(haberman_1['year']),'o',label='status 1')
plt.plot(haberman_2['year'],np.zeros_like(haberman_2['year']),'o',label='status 2')
plt.grid()
plt.legend()
plt.title('1-D Scatter Plot of year of operation of patients ')
plt.show()

# %%
plt.plot(haberman_1['nodes'],np.zeros_like(haberman_1['nodes']),'o',label='status 1')
plt.plot(haberman_2['nodes'],np.zeros_like(haberman_2['nodes']),'o',label='status 2')
plt.grid()
plt.legend()
plt.title('1-D Scatter Plot of number of axillary lymph nodes ')
plt.show()

# %% [markdown]
# # Observation
# After plotting 1-D scatter plot of age,year and nodes,it is observed that nothing can be concluded as status 1 and status 2 are overlapping.

# %% [markdown]
# # Histogram

# %%
sns.FacetGrid(haberman,hue='status',size=5)\
    .map(sns.distplot,'age')\
    .add_legend();
plt.title("Histogram of patient's age")
plt.grid()
plt.show()

# %%
sns.FacetGrid(haberman,hue='status',size=5) \
    .map(sns.distplot,'year') \
    .add_legend();
plt.title("Histogram of year of operation of patient")
plt.grid()
plt.show()

# %%
sns.FacetGrid(haberman,hue='status',size=5) \
    .map(sns.distplot,'nodes')\
    .add_legend()
plt.title("Histogram of number of axillary lymph nodes")
plt.grid()
plt.show()

# %% [markdown]
# # Observation
# After plotting Histogram of age,year and nodes, we found that status 1 and status 2 are overlapping and hence nothing can be concluded from these analysis.

# %% [markdown]
# # PDF and CDF

# %%
# For status 1
count,bin_edges=np.histogram(haberman_1['age'],bins=10)
pdf=count/sum(count)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf,label='status 1:pdf')
plt.plot(bin_edges[1:],cdf,label='status 1:cdf')
bin_edges

# For status 2
count,bin_edges=np.histogram(haberman_2['age'],bins=10)
pdf=count/sum(count)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf,label='status 2:pdf')
plt.plot(bin_edges[1:],cdf,label='status 2:cdf')
plt.legend()
plt.title('CDF and PDF of age of patients')
plt.grid()
plt.show()

# %%
#for status 1
count,bin_edges=np.histogram(haberman_1['year'],bins=9)
pdf=count/sum(count)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf,label='status 1:pdf')
plt.plot(bin_edges[1:],cdf,label='status 1:cdf')

#for status 2
count,bin_edges=np.histogram(haberman_2['year'],bins=9)
pdf=count/sum(count)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf,label='status 2:pdf')
plt.plot(bin_edges[1:],cdf,label='status 2:cdf')
plt.legend()
plt.title('CDF and PDF of year of operation of patients')
plt.grid()
plt.show()

# %%
# For status 1
count,bin_edges=np.histogram(haberman_1['nodes'],bins=9)
print(count)
pdf=count/sum(count)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf,label='status 1:pdf')
plt.plot(bin_edges[1:],cdf,label='status 1:cdf')

# For status 2
count,bin_edges=np.histogram(haberman_2['nodes'],bins=9)
pdf=count/sum(count)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf,label='status 2:pdf')
plt.plot(bin_edges[1:],cdf,label='status 2:cdf')
plt.title('CDF and PDF of number of axillary lymph nodes')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Observation
# After plotting PDF and CDF of age,year and nodes we found that status 1 and status 2 are overlapping and hence nothing can be concluded from these analysis.

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(x='status',y='age',data=haberman)
plt.grid()
plt.title('Box plot of age and status of patients')
plt.show()

# %%
sns.boxplot(x='status',y='year',data=haberman)
plt.grid()
plt.title('Box plot of year of operation and status of patients')
plt.show()

# %%
sns.boxplot(x='status',y='nodes',data=haberman)
plt.grid()
plt.title('Box plot of number of axillary lymph nodes and status of patients')
plt.show()

# %% [markdown]
# # Violin Plots

# %%
sns.violinplot(x='status',y='age',data=haberman,size=10)
plt.title("violin plot of age of patients and status of patients")
plt.grid()
plt.show()

# %%
sns.violinplot(x='status',y='year',data=haberman,size=10)
plt.title("violin plot of year of operation of patients and status of patients")
plt.grid()
plt.show()

# %%
sns.violinplot(x='status',y='nodes',data=haberman,size=10)
plt.title("violin plot of number of axillary lymph nodes and status of patients")

plt.grid()
plt.show()

# %% [markdown]
# # Observation
# From the box plot and violin plot of age of the patient,it is observed that most of the patients whose age was between 30 and 35 years, survived for more than five years and patients whose age was above 75 years, survived for less than five years.
#
# From the box plot and violin plot of year of operation of patients,it is observed that most of the patients whose operation was done before year 60, survived for less than five years and  most of the patients whose operation was done after year 65, survived for more than five years.
#
# From the box plot and violin plot of number of axillary lymph nodes,it is obseved that only 25% of patients who had axillary lymph nodes more than 3, survived for more than five years.The higher the number of axillary lymph nodes,more is the chances of patients surviving less than five years.

# %% [markdown]
# # Bi-variate Analysis

# %% [markdown]
# # 2-D Scatter Plots

# %%
sns.set_style('whitegrid')
sns.FacetGrid(haberman,hue='status',size=4)\
    .map(plt.scatter,'age','year')\
    .add_legend()
plt.title("2-D scatter plot of age of patients and status of patients")
plt.show()

# %%
sns.set_style('whitegrid')
sns.FacetGrid(haberman,hue='status',size=4)\
    .map(plt.scatter,'age','nodes')\
    .add_legend()
plt.title("2-D scatter plot of year of operation of patients and status of patients")
plt.show()

# %%
sns.set_style('whitegrid')
sns.FacetGrid(haberman,hue='status',size=4)\
    .map(plt.scatter,'year','nodes')\
    .add_legend()
plt.title("2-D scatter plot of number of axillary lymph nodes and status of patients")
plt.show()

# %% [markdown]
# # Observation
# No conclusion can be drawn from 2-D scatter plots of age,year and nodes.

# %% [markdown]
# # Pair-plots

# %%
sns.set_style('whitegrid')
sns.pairplot(haberman,hue='status',size=3,vars=['age','year','nodes'])
plt.suptitle("Pair-plots")
plt.show()

# %% [markdown]
# # Observation
# No conclusion can be drawn after observing pair-plots of age,year and nodes.

# %% [markdown]
# # Final Observation/Conclusion
# 1) The patients whose age was between 20 and 35 years have mostly survived for more than five years whereas patients whose age was above 75 years have mostly survived for less than 5 years.
#
# 2) The patients whose operation was done before year 60 have mostly survived for less than five years and the patients whose operation was done after year 65 have mostly survived for more than five years.
#
# 3) Only 25% of patients who had axillary lymph nodes more than 3, survived for more than five years.The higher the number of axillary lymph nodes,more is the chances of patients surviving for less than five years.
