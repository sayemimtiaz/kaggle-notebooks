# %%
import pandas as pd 
import numpy as np
import plotly.express as px
import plotly

df = pd.read_csv('../input/covid-world-vaccination-progress/country_vaccinations.csv',header=0)
df.index = pd.to_datetime(df['date'])
df = df.sort_index()
print(df.columns)
fig = px.choropleth(df,locations='country',locationmode='country names',color='people_fully_vaccinated_per_hundred',hover_name='country',animation_frame='date',color_continuous_scale='rainbow',range_color=(0.0,80.0))
fig.update_layout(title_text="Percentage of the country's total population that are fully vaccinated",title_x=0.45)
fig.show()  

plotly.offline.plot(fig,filename='vaccinations.html')

# %% [markdown]
# The visualizing shows the percentage of the country's total population that are fully vaccinated.
# In the last assignment, I found that Gibraltar is the only country that got fully vaccinated. Therefore I wanted to see the process of the vaccination in the country. However, when I zoomed in the animation, Gibraltar is not shown in the graph and I am only able to see the changes of the two countries beside it, Portugal and Spain. The reason might be the country is too small and the map is not precise enough to show it.

# %%
df = pd.read_csv('../input/202105recentearthquake/query.csv',header=0)
df.index = pd.to_datetime(df['time'])
df['time'] = df.index.strftime('%Y-%m-%d %H:00:00')
df = df.sort_index()
fig = px.scatter_geo(df,lat='latitude',lon='longitude',color='mag',animation_frame='time',color_continuous_scale='rainbow',range_color=(1.0,3.0))
fig.show()

# %% [markdown]
# Through the data I found there were 22 times of earthquakes in southern Qinghai, China from May 21st to the end of the available data May 27th. The major magnitude is 7.4.
#
# https://www.volcanodiscovery.com/earthquakes/6252725/2021-05-21/18h04/magnitude7-China.html
#
# The 7.4 magnitude earthquake that struck Northwest China's Qinghai province did not cause any glacier collapse on the region's Mount Anyemaqen, according to the provincial bureau of environmental geological exploration.
#
# http://global.chinadaily.com.cn/a/202105/31/WS60b42e8fa31024ad0bac267f.html
#
# Yet highway sections and bridges have seen collapses in the quake-hit area, making vehicles impassable.Well-equipped rescue forces have been dispatched to the quake zone.
#
# http://www.xinhuanet.com/english/2021-05/22/c_139962065.htm
#
# According to statistics, 320 earthquakes of magnitude 3 or higher occurred in China in the first half of the year. The largest earthquake in China so far this year is the 7.4 magnitude earthquake that occurred in Qinghai on May 22nd.
