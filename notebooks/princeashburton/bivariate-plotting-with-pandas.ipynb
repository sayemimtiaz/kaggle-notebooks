# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.

# %%
reviews = pd.read_csv("../input/wine-reviews/winemag-data_first150k.csv", index_col=0)
reviews.head()

# %% [markdown]
# # Scatter Plot
#
# The scatter plot will be able to map each variable to a point in 2D space

# %%
reviews[reviews['price'] < 100].sample(100).plot.scatter(x='price', y='points')

# %% [markdown]
# Below is an example of when we have overrplotted points.

# %%
reviews[reviews['price'] < 100].plot.scatter(x='price', y='points')

# %% [markdown]
# # Hexplot
#
# a hexplot will help us solve this problem by aggregating points into space into hexagons.

# %%
reviews[reviews['price'] < 100].plot.hexbin(x='price', y='points', gridsize=15)

# %% [markdown]
# # Stacked Plots
# This plots variables on top of each other.

# %%
wine_counts = pd.read_csv("../input/most-common-wine-scores/top-five-wine-score-counts.csv", index_col=0) 
##This counts # of times each of the possible review scores were recieved by 
#the 5 most commonly reviewed types of wines

# %%
wine_counts.head()

# %% [markdown]
# For multivarable plots you need 1 categorical variable in the columns,  1 categorical variable in rows and counts at their intersections in the entries. They work great for nominal categorical or small ordinal categorical variables

# %%
wine_counts.plot.bar(stacked=True)

# %%
wine_counts.plot.area()

# %% [markdown]
# Multivariate area charts are for nominal categorical or interval variables

# %% [markdown]
# # Bivariate Line Chart

# %%
wine_counts.plot.line()

# %% [markdown]
# # Exercises

# %% [markdown]
# Time to replicate some plots

# %%
pokemon = pd.read_csv("../input/pokemon/Pokemon.csv", index_col=0)
pokemon.head()

# %%
pokemon.info()

# %% [markdown]
# # Scatter Plot

# %%
pokemon[pokemon['Attack'] < 200].plot.scatter(x='Attack',y='Defense')

# %% [markdown]
#  # Hexbin Plot

# %%
pokemon.plot.hexbin(x='Attack',y='Defense',gridsize=20)

# %%
#SWITCH UP THE DATA
pokemon_stats_legendary = pokemon.groupby(['Legendary','Generation']).mean()[['Attack','Defense']]

# %% [markdown]
# # Stacked Plot

# %%
pokemon_stats_legendary.plot.bar(stacked=True)

# %%
#Switch up the data again
pokemon_stats_by_generation = pokemon.groupby('Generation').mean()[['HP','Attack','Defense','Sp. Atk','Sp. Def','Speed']]

# %% [markdown]
# # Bivariate Line Chart

# %%
pokemon_stats_by_generation.plot.line()
