# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Reading the csv File using Pandas Dataframe

# %%
data=pd.read_csv('../input/amazon-top-50-bestselling-books-2009-2019/bestsellers with categories.csv')

# %%
data.head()

# %%
data.info()

# %%
##column header
data.columns

# %%
##total number of rows and columns
data.shape

# %%
##basics of stats
data.describe()

# %%
##check for any null values 
data.isnull().any()

# %%
data.isnull().sum()

# %%
##plotting relationships
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(data.isnull())
plt.show()

# %%
##outliers detection
##boxplots are gret way to detect outliers

plt.figure(figsize=(20,15))
plt.subplot(4,4,1)
sns.boxplot(data['User Rating'])

plt.subplot(4,4,2)
sns.boxplot(data['Reviews'])

plt.subplot(4,4,3)
sns.boxplot(data['Price'])

##Dots are nothing but outliers.We do have outliers

# %%
##to remove outliers we can clip our outliers with the upper range and lower range which is nothing but 5th and 95th percentile

data['Price']=data['Price'].clip(lower=data['Price'].quantile(0.05),upper=data['Price'].quantile(0.95))

data['User Rating']=data['User Rating'].clip(lower=data['User Rating'].quantile(0.05),upper=data['User Rating'].quantile(0.95))

data['Reviews']=data['Reviews'].clip(lower=data['Reviews'].quantile(0.05),upper=data['Reviews'].quantile(0.95))

# %%
plt.figure(figsize=(20,15))
plt.subplot(4,4,1)
sns.boxplot(data['User Rating'])

plt.subplot(4,4,2)
sns.boxplot(data['Reviews'])

plt.subplot(4,4,3)
sns.boxplot(data['Price'])

# %%
##Number of best selling books each year in each genre using countplot

plt.figure(figsize=(10,2))

sns.countplot(x='Year', data=data ,hue='Genre')

# %%
##Bar graph for Genre
data['Genre'].value_counts().plot(kind='barh', figsize=(10,10))
plt.grid(b=True, which='both')

# %%
##Pie chart for Genre
plt.rcParams['figure.figsize'] = (9, 9)
labels=['Non-Fiction', 'Fiction']
plt.pie(data['Genre'].value_counts(), explode=(0,0.1), labels=labels,autopct='%1.1f%%', shadow=True)
plt.title('Book Type ', fontsize = 20)
plt.axis('off')
plt.legend()
plt.show()
