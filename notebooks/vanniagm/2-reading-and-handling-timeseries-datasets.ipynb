# %%
# %matplotlib inline 
import matplotlib.pylab
import pandas as pd
import numpy as np

# %%
with open('../input/ao-monthly/ao_monthly.txt') as f:
    for x in range(5):
        print(next(f))

# %%
data = pd.read_fwf('../input/ao-monthly/ao_monthly.txt', header = None)

# %%
# Not so great
data.head()

# %% [markdown]
# ### Look at the options for read_fwf...what looks relevant?

# %%
# %load snippets/readtime.py
data = pd.read_fwf('../input/ao-monthly/ao_monthly.txt', header = None, index_col = 0, parse_dates = [[0, 1]], infer_datetime_format = True)

# %%
data.head()

# %%
data.index

# %%
data.index.names = ['Month']
data.columns = ['Value']
data.head()

# %% [markdown]
# ### What is the empirical range of dates?

# %% [markdown]
# ### How can we convert to actual representation (year and month)?

# %% [markdown]
# ### More about reading in data
#
# When reading in dates with a pd.read function, you have several time-related parameters you can adjust:
# parse_dates, infer_datetime_format, date_parser
#
# Experiment with these using %timeit to see if there are performance differences
#
# Hint:
# infer_datetime_format = True, no date parser provided.
# What other combos can you come up with?

# %%
# First, let's see how to use a date_parser:
dateparse = lambda x, y: pd.datetime.strptime('%s-%s'%(x,y), '%Y-%m')

# %timeit data = pd.read_fwf('../input/ao-monthly/ao_monthly.txt', header = None, index_col = 0, parse_dates = [[0, 1]], date_parser = dateparse)

# %%
data.head()

# %%
# %timeit data = pd.read_fwf('../input/ao-monthly/ao_monthly.txt', header = None, index_col = 0, parse_dates = [[0, 1]])

# %%
# %timeit data = pd.read_fwf('../input/ao-monthly/ao_monthly.txt', header = None, index_col = 0, parse_dates = [[0, 1]], infer_datetime_format = True)

# %% [markdown]
# ### You can also extract datetimes from existing Data Frame columns

# %%
# new in pandas 0.18
df = pd.DataFrame({'year':[2015, 2016], 'month':[2,3], 'day':[4,5], 'hour':[12, 13], 'value': [2,3]})
df

# %%
pd.to_datetime(df[['year','month','day','hour']])

# %% [markdown]
# ### Truncating

# %%
ts = pd.Series(range(10), index = pd.date_range('7/31/15', freq = 'M', periods = 10))
ts

# %%
# truncating preserves frequency
ts.truncate(before = '10/31/2015', after = '12/31/2015')

# %%
# You can truncate in a way that does not preserve frequency
ts[[1, 6, 7]].index

# %%
# But Pandas will try to preserve frequency automatically whenever possible/logical
ts[0:10:2]

# %% [markdown]
# ### Reading CSV files

# %%
air_passengers = pd.read_csv("../input/air-passengers/AirPassengers.csv")

# %%
air_passengers.head()

# %%
air_passengers.info()

# %%
air_passengers = pd.read_csv("../input/air-passengers/AirPassengers.csv", header = 0, parse_dates = [0], names = ['Month', '#Passengers'], index_col = 0)

# %%
air_passengers.head()

# %%
air_passengers.info()

# %%
air_passengers.plot()
