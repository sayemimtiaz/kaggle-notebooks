# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os
os.chdir("../input")

# %%
print(os.listdir("../input"))

# %%
data_path = "../input/housing/housing.csv"

# %%
housing=pd.read_csv(data_path)

# %%
housing.shape

# %%
housing.head()

# %%
housing.info()

# %%
pd.isnull(housing).sum()

# %%
housing.describe()

# %%
housing.boxplot(["median_house_value"], figsize=(5,5))

# %%
housing.hist(bins=50,figsize=(15,15))

# %%
housing['ocean_proximity'].value_counts()

# %%
op_count=housing['ocean_proximity'].value_counts()
plt.figure(figsize=(10,5))
sns.barplot(op_count.index,op_count.values,alpha=0.7)
plt.title('Ocean Proximity Summary')
plt.ylabel("Number of Occurences",fontsize=12)
plt.xlabel("Ocean Proximity",fontsize=12)
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.hist(housing[housing['total_bedrooms'].notnull()]['total_bedrooms'],bins=30,color='purple')
plt.title("Histogram")
plt.xlabel("Total Bedrooms")
plt.ylabel("Frequency")

# %%
plt.figure(figsize=(15,5))
sns.boxplot(y='total_bedrooms',data=housing,orient='h',palette='plasma')
plt.plot

# %%
housing['total_bedrooms']=housing['total_bedrooms'].fillna((housing['total_bedrooms'].median()))

# %%
plt.figure(figsize=(20,5))
sns.set_color_codes(palette='bright')
sns.distplot(housing['median_house_value'],color='b')

# %%
housing[housing['median_house_value']>300000]['median_house_value'].value_counts().head(10)
housing1=housing.loc[housing['median_house_value']<500001,:]

# %%
plt.figure(figsize=(20,5))
sns.set_color_codes(palette="bright")
sns.distplot(housing1['median_house_value'],color='g')

# %%
housing1.hist(bins=50,figsize=(10,10))

# %%
plt.figure(figsize=(10,5))
plt.scatter(housing1['longitude'],housing1['latitude'],c=housing1['median_house_value'],s=housing1['population']/50,alpha=0.1,
cmap="Oranges")
plt.colorbar()
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title('House Price basis on Geographical Co-ordinates')

# %%
housing1['total rooms per households']=housing1['total_rooms']/housing1['households']

# %%
housing1.head()

# %%
housing1.drop('total_rooms', axis=1, inplace=True)

# %%
housing1.head()

# %%
plt.figure(figsize=(15,7))
sns.countplot(data=housing1,x='ocean_proximity',palette='rainbow_r')

# %%
#Rearranging the data for splitting it conviently
housing1=housing1[['longitude','latitude','housing_median_age','total_bedrooms','population','households','median_income',
                   'ocean_proximity','total rooms per households','median_house_value']]

# %%
housing1.head()

# %%
## Splitting the Data
x=housing1.iloc[:,0:9]
y=housing1.iloc[:,9]

# %%
x=pd.get_dummies(x)

# %%
x.head()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
##Feature Scaling/ Normalization
from sklearn.preprocessing import StandardScaler
scale  = StandardScaler()
x_train=scale.fit_transform(x_train)
x_test=scale.fit_transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
lin_reg.fit(x_train,y_train)

# %%
## model for future prediciton
y_pred=lin_reg.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
rmse=np.sqrt(mean_squared_error(y_test, y_pred))

# %%
score = lin_reg.score(x_test, y_test)

# %%
score

# %%
test = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
fig= plt.figure(figsize=(16,8))
test = test.reset_index()
test = test.drop(['index'],axis=1)
plt.plot(test[:80])
plt.legend(['Actual','Predicted'])
sns.jointplot(x='Actual',y='Predicted',data=test,kind='reg',color="grey")
