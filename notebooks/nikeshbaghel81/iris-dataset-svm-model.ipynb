# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
os.chdir("../input/iris-flower-dataset")

# %%
data = pd.read_csv("IRIS.csv")

# %%
data.head()

# %%
data.info()

# %%
data.shape

# %%
data.describe()

# %%
data.hist(edgecolor = 'black', linewidth=1.2, figsize=(15,5))

# %%
data.boxplot(by="species",figsize=(15,10))

# %%
sns.pairplot(data, hue="species")

# %%
X = data[["sepal_length","sepal_width","petal_length"]]

# %%
Y = data["species"]

# %%
y = Y.values

# %%
x = X.values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=0)

# %%
from sklearn.svm import SVC

clf = SVC(kernel = 'linear').fit(x_train,y_train)

# %%
clf.score(x_test,y_test)

# %%
#BY USING SUPPORT VECTOR MACHINES WE GET A SCORE OF 97%
