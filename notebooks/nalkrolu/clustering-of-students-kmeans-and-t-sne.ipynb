# %% [markdown]
#  <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:LightSlateGray;
#            font-size:150%;
#            text-align:center;
#            letter-spacing:0.5px">
#     Clustering of Students
# </div>

# %% [markdown]
# <center><img src="https://www.eff.org/files/issues/student-privacy4.jpg"></center>

# %% [markdown]
#  <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:LightSlateGray;
#            font-size:150%;
#            text-align:center;
#            letter-spacing:0.5px">
#     Context
# </div>

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            background-color:Beige;
#            font-size:110%;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#               color:black;">
#     Marks secured by the students
# </p>
# </div>

# %% [markdown]
#  <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:LightSlateGray;
#            font-size:150%;
#            text-align:center;
#            letter-spacing:0.5px">
#     Content
# </div>

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            background-color:Beige;
#            font-size:110%;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#               color:black;">
#     This data set consists of the marks secured by the students in various subjects.
# </p>
# </div>

# %% [markdown]
#  <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:LightSlateGray;
#            font-size:150%;
#            text-align:center;
#            letter-spacing:0.5px">
#     Acknowledgements
# </div>

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            background-color:Beige;
#            font-size:110%;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#               color:black;">
#     http://roycekimmons.com/tools/generated_data/exams
# </p>
# </div>

# %% [markdown]
#  <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:LightSlateGray;
#            font-size:150%;
#            text-align:center;
#            letter-spacing:0.5px">
#     Inspiration
# </div>

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            background-color:Beige;
#            font-size:110%;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#               color:black;">
#     To understand the influence of the parents background, test preparation etc on students performance
# </p>
# </div>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore')

# %%
plt.style.use('ggplot')

orange_black = ['#fdc029', '#df861d', 'FF6347', '#aa3d01',
                '#a30e15', '#800000', '#171820']

plt.rcParams['figure.figsize'] = (10,5) 
plt.rcParams['figure.facecolor'] = '#FFFACD' 
plt.rcParams['axes.facecolor'] = 'FFFFE0' 
plt.rcParams['axes.grid'] = True 
plt.rcParams['grid.color'] = orange_black[3]
plt.rcParams['grid.linestyle'] = '--'

# %%
url = '/kaggle/input/students-performance-in-exams/StudentsPerformance.csv'
df = pd.read_csv(url)
df.head()

# %%
df.shape

# %%
df.describe().T

# %%
df.info()

# %%
numeric = ['math score','reading score','writing score']
categorical = ['gender','race/ethnicity','parental level of education','lunch','test preparation course']

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            background-color:Beige;
#            font-size:110%;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#               color:black;">
#     📌 We have 1000 rows and 8 columns in our dataset.<br>
#     📌 There are 3 numerical and 5 categorical variables in the data set.<br>
# </p>
# </div>

# %% [markdown]
# ## Pie Charts

# %%
plt.figure(figsize=(15,30))
for i in range(1,6):
    plt.subplot(5,1,i)
    labels = df[categorical[i-1]].value_counts().index
    sizes = df[categorical[i-1]].value_counts().values

    #colors = ["#ffb3b3",'#c78d8d',"#C2C4E2",'#8082a8']
    plt.pie(sizes, autopct='%1.1f%%', shadow=True,
            startangle=90, textprops={"fontsize":12, 'fontfamily':'monospace'})
    plt.legend(labels,
               loc='center left',
               title="{}".format(categorical[i-1].upper()),
               bbox_to_anchor=(1, 0, 0.5, 1))

# %% [markdown]
# # Count Plots

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=df, hue='gender', x='race/ethnicity')
plt.title("Count Plot for Gender/Race/Ethnicity" , size=18, fontweight='bold', fontfamily='monospace')
plt.xlabel("Race/Ethnicity", size=13, fontweight='light', fontfamily='monospace')
plt.ylabel("Count", size=13, fontweight='light', fontfamily='monospace')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=df, hue='gender', x='parental level of education')
plt.title("Count Plot for Gender/Parental Level of Education" , size=18, fontweight='bold', fontfamily='monospace')
plt.xlabel("Parental Level of Education", size=13, fontweight='light', fontfamily='monospace')
plt.ylabel("Count", size=13, fontweight='light', fontfamily='monospace')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=df, hue='gender', x='lunch')
plt.title("Count Plot for Gender/Lunch" , size=18, fontweight='bold', fontfamily='monospace')
plt.xlabel("Lunch", size=13, fontweight='light', fontfamily='monospace')
plt.ylabel("Count", size=13, fontweight='light', fontfamily='monospace')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=df, hue='gender', x='test preparation course')
plt.title("Count Plot for Gender/Test Preparation Course" , size=18, fontweight='bold', fontfamily='monospace')
plt.xlabel("Test Preparation Course", size=13, fontweight='light', fontfamily='monospace')
plt.ylabel("Count", size=13, fontweight='light', fontfamily='monospace')
plt.show()

# %%
categorical

# %%
df.groupby(['gender'])['math score','reading score','writing score'].mean().style.background_gradient("Reds")

# %%
df.groupby(['race/ethnicity'])['math score','reading score','writing score'].mean().style.background_gradient("Reds")

# %%
df.groupby(['parental level of education'])['math score','reading score','writing score'].mean().style.background_gradient("Reds")

# %%
df.groupby(['lunch'])['math score','reading score','writing score'].mean().style.background_gradient("Reds")

# %%
df.groupby(['test preparation course'])['math score','reading score','writing score'].mean().style.background_gradient("Reds")

# %%
plt.figure(figsize=(15,5))
sns.swarmplot(data=df, x='gender', y='math score')
plt.title("Swarm Plot for Math Score" , size=18, fontweight='bold', fontfamily='monospace')
plt.xlabel("Gender", size=13, fontweight='light', fontfamily='monospace')
plt.ylabel("", size=13, fontweight='light', fontfamily='monospace')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.swarmplot(data=df, x='gender', y='reading score')
plt.title("Swarm Plot for Reading Score" , size=18, fontweight='bold', fontfamily='monospace')
plt.xlabel("Gender", size=13, fontweight='light', fontfamily='monospace')
plt.ylabel("", size=13, fontweight='light', fontfamily='monospace')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.swarmplot(data=df, x='gender', y='writing score')
plt.title("Swarm Plot for Writing Score" , size=18, fontweight='bold', fontfamily='monospace')
plt.xlabel("Gender", size=13, fontweight='light', fontfamily='monospace')
plt.ylabel("", size=13, fontweight='light', fontfamily='monospace')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.scatterplot(data=df, x='writing score', y='reading score', hue='race/ethnicity')
plt.title("Scatter Plot for Writing Score" , size=18, fontweight='bold', fontfamily='monospace')
plt.xlabel("Writing Score", size=13, fontweight='light', fontfamily='monospace')
plt.ylabel("Reading Score", size=13, fontweight='light', fontfamily='monospace')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.scatterplot(data=df, x='math score', y='reading score', hue='race/ethnicity')
plt.title("Scatter Plot for Writing Score" , size=18, fontweight='bold', fontfamily='monospace')
plt.xlabel("Math Score", size=13, fontweight='light', fontfamily='monospace')
plt.ylabel("Reading Score", size=13, fontweight='light', fontfamily='monospace')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.scatterplot(data=df, x='math score', y='writing score', hue='race/ethnicity')
plt.title("Scatter Plot for Writing Score" , size=18, fontweight='bold', fontfamily='monospace')
plt.xlabel("Math Score", size=13, fontweight='light', fontfamily='monospace')
plt.ylabel("Writing Score", size=13, fontweight='light', fontfamily='monospace')
plt.show()

# %% [markdown]
# # Clustering

# %%
from sklearn.preprocessing import scale
from sklearn.manifold import TSNE

from sklearn.cluster import KMeans

# %%
data = {}
X_df = df[numeric]
for col in categorical:
    data[col] = pd.get_dummies(df[col])
    X_df = pd.concat([X_df, data[col]],axis=1)
X_df.head()

# %%
X = scale(X_df)

# %%
tsne = TSNE(verbose=1, perplexity=100, random_state=42)
X_embedded = tsne.fit_transform(X)

# %%
plt.figure(figsize=(15,5))
sns.scatterplot(X_embedded[:,0], X_embedded[:,1])
plt.title('t-SNE with no Labels' , size=18, fontweight='bold', fontfamily='monospace')
plt.show()

# %%
cluster = KMeans(n_clusters=10)
cluster.fit(X)
y_pred = cluster.predict(X)

# %%
palette = sns.hls_palette(10, l=.4, s=.9)
plt.figure(figsize=(15,5))
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], hue=y_pred, palette=palette)
plt.title('t-SNE with no Labels' , size=18, fontweight='bold', fontfamily='monospace')
plt.show()

# %%
df['cluster'] = y_pred
df.head()

# %%
df.groupby('cluster')['math score','reading score','writing score'].mean().style.background_gradient("Reds")

# %%
plt.figure(figsize=(15,5))
sns.swarmplot(data=df, x='cluster', y='reading score')
plt.title("Swarm Plot for Reading Score" , size=18, fontweight='bold', fontfamily='monospace')
plt.xlabel("Cluster", size=13, fontweight='light', fontfamily='monospace')
plt.ylabel("", size=13, fontweight='light', fontfamily='monospace')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.swarmplot(data=df, x='cluster', y='math score')
plt.title("Swarm Plot for Math Score" , size=18, fontweight='bold', fontfamily='monospace')
plt.xlabel("Cluster", size=13, fontweight='light', fontfamily='monospace')
plt.ylabel("", size=13, fontweight='light', fontfamily='monospace')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.swarmplot(data=df, x='cluster', y='writing score')
plt.title("Swarm Plot for Writing Score" , size=18, fontweight='bold', fontfamily='monospace')
plt.xlabel("Cluster", size=13, fontweight='light', fontfamily='monospace')
plt.ylabel("", size=13, fontweight='light', fontfamily='monospace')
plt.show()
