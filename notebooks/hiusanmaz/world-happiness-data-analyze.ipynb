# %% [markdown]
# # World Happiness Data's
#
# * Version 1
#
# # Goals ;
#
# * Using importpant libraries for Data Science in Pyhton (Numpy,Pandas,Seaborn,Matplotlib)
#
# * Trying to analye the dataset +
#
# * Visualize the important observations +
#
# * Predict some features like (Trust,Freedom,Score etc.) using Machine Learning.

# %% [markdown]
# # About Dataset
#
# # World Happiness Dataset

# %% [markdown]
# Context
# The World Happiness Report is a landmark survey of the state of global happiness. The first report was published in 2012, the second in 2013, the third in 2015, and the fourth in the 2016 Update. The World Happiness 2017, which ranks 155 countries by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March 20th. The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.
#
# Content
# The happiness scores and rankings use data from the Gallup World Poll. The scores are based on answers to the main life evaluation question asked in the poll. This question, known as the Cantril ladder, asks respondents to think of a ladder with the best possible life for them being a 10 and the worst possible life being a 0 and to rate their own current lives on that scale. The scores are from nationally representative samples for the years 2013-2016 and use the Gallup weights to make the estimates representative. The columns following the happiness score estimate the extent to which each of six factors – economic production, social support, life expectancy, freedom, absence of corruption, and generosity – contribute to making life evaluations higher in each country than they are in Dystopia, a hypothetical country that has values equal to the world’s lowest national averages for each of the six factors. They have no impact on the total score reported for each country, but they do explain why some countries rank higher than others.
#
# Inspiration
# What countries or regions rank the highest in overall happiness and each of the six factors contributing to happiness? How did country ranks or scores change between the 2015 and 2016 as well as the 2016 and 2017 reports? Did any country experience a significant increase or decrease in happiness?
#
# What is Dystopia?
#
# Dystopia is an imaginary country that has the world’s least-happy people. The purpose in establishing Dystopia is to have a benchmark against which all countries can be favorably compared (no country performs more poorly than Dystopia) in terms of each of the six key variables, thus allowing each sub-bar to be of positive width. The lowest scores observed for the six key variables, therefore, characterize Dystopia. Since life would be very unpleasant in a country with the world’s lowest incomes, lowest life expectancy, lowest generosity, most corruption, least freedom and least social support, it is referred to as “Dystopia,” in contrast to Utopia.
#
# What are the residuals?
#
# The residuals, or unexplained components, differ for each country, reflecting the extent to which the six variables either over- or under-explain average 2014-2016 life evaluations. These residuals have an average value of approximately zero over the whole set of countries. Figure 2.2 shows the average residual for each country when the equation in Table 2.1 is applied to average 2014- 2016 data for the six variables in that country. We combine these residuals with the estimate for life evaluations in Dystopia so that the combined bar will always have positive values. As can be seen in Figure 2.2, although some life evaluation residuals are quite large, occasionally exceeding one point on the scale from 0 to 10, they are always much smaller than the calculated value in Dystopia, where the average life is rated at 1.85 on the 0 to 10 scale.
#
# What do the columns succeeding the Happiness Score(like Family, Generosity, etc.) describe?
#
# The following columns: GDP per Capita, Family, Life Expectancy, Freedom, Generosity, Trust Government Corruption describe the extent to which these factors contribute in evaluating the happiness in each country. The Dystopia Residual metric actually is the Dystopia Happiness Score(1.85) + the Residual value or the unexplained value for each country as stated in the previous answer.
#
# If you add all these factors up, you get the happiness score so it might be un-reliable to model them to predict Happiness Scores.

# %% [markdown]
# * CountryName of the country.
# * RegionRegion the country belongs to.
# * Happiness RankRank of the country based on the Happiness Score.
# * Happiness ScoreA metric measured in 2015 by asking the sampled people the question: "How would you rate your happiness on a scale of 0 to 10 where 10 is the happiest."
# * Standard ErrorThe standard error of the happiness score.
# * Economy (GDP per Capita)The extent to which GDP contributes to the calculation of the Happiness Score.
# * FamilyThe extent to which Family contributes to the calculation of the Happiness Score
# * Health (Life Expectancy)The extent to which Life expectancy contributed to the calculation of the Happiness Score
# * FreedomThe extent to which Freedom contributed to the calculation of the Happiness Score.
# * Trust (Government Corruption)The extent to which Perception of Corruption contributes to Happiness Score.
# * GenerosityThe extent to which Generosity contributed to the calculation of the Happiness Score.
# * Dystopia ResidualThe extent to which Dystopia Residual contributed to the calculation of the Happiness Score.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns 
import matplotlib.pyplot as plt
import plotly.express as px
import time
import warnings
warnings.filterwarnings('ignore')

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
happy15 = pd.read_csv("/kaggle/input/world-happiness/2015.csv")

# %%
happy15.head()

# %%
# Renaming columns for avoid complexity

# %%
cols_ = {"Happiness Score":"Score","Happiness Rank":"Rank","Economy (GDP per Capita)":"GDP","Trust (Government Corruption)":"Trust","Dystopia Residual":"Dystopia","Health (Life Expectancy)":"LifeExpectancy"}

# %%
happy15.rename(columns = cols_,inplace=True)

# %%
happy15.info()

# %%
happy15.describe().T

# %%
# Correlations between columns 
happy15.corr()

# %%
#  Because of the inverse proportion ,there will be negative correlation between rank and the other categories.

plt.figure(figsize=(15,15))
sns.heatmap(happy15.corr(), annot = True,linewidths = 1,fmt=".2f",cmap="YlGnBu",cbar_kws={"shrink": 0.5},square=True)
plt.xticks(rotation = 90,fontsize = 20)
plt.yticks(rotation = 0,fontsize = 20)
plt.show()

# %%
# Regression between Score and other columns like (GDP,Freedom etc.)
sns.pairplot(data=happy15,kind="reg",x_vars=["Score"],y_vars=["GDP","LifeExpectancy","Freedom","Trust","Generosity"])
plt.show();

# %%
# Relations between Freedom,Trust and GDP

# %%
sns.set(style="darkgrid")
sns.set(rc={'figure.figsize':(17,9)})
ax=sns.regplot(data=happy15, x='Freedom', y='Trust', x_jitter=0.1, order=30, x_bins=10)
plt.xlabel("Freedom",fontsize= 22)
plt.ylabel("Trust",fontsize = 22)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.suptitle("Relation between Freedom and Trust",fontsize=20);
plt.show()

# %%
ax=sns.regplot(data=happy15, x='Freedom', y='GDP', x_jitter=0.1, order=30, x_bins=10)
plt.xlabel("Freedom",fontsize= 22)
plt.ylabel("GDP",fontsize = 22)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.suptitle("Relation between Freedom and GDP",fontsize=20)
plt.show()

# %%
ax=sns.regplot(data=happy15, x='Trust', y='GDP', x_jitter=0.1, order=30, x_bins=10)
plt.suptitle("Relation between Trust and GDP",fontsize=20)
plt.xlabel("Trust",fontsize= 22)
plt.ylabel("GDP",fontsize = 22)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.show()

# %%
ax=sns.regplot(data=happy15, x='Freedom', y='LifeExpectancy', x_jitter=0.1, order=30, x_bins=10)
plt.suptitle("Relation between Freedom and Life Expectancy",fontsize=20)
plt.xlabel("Freedom",fontsize= 22)
plt.ylabel("LifeExpectancy",fontsize = 22)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.show()

# %%
# Country count by regions.
plt.figure(figsize=(10,10))
plt.suptitle('Country Count by Regions', fontsize=20)
happy15.Region.value_counts().plot.bar(fontsize=15,grid=True)
plt.xticks(rotation = 80,fontsize = 20)
plt.yticks(fontsize = 20)
plt.show()

# %%
#sample code for groupby
#df.groupby(['VAR1','VAR2'])['VAR3'].sum()
world_avg =happy15.groupby(["Region"])["Score"].sum() / happy15["Region"].value_counts()
world_avg.plot(kind="bar",fontsize=17,figsize=(10,10),grid=True)
plt.xticks(rotation = 80,fontsize = 20)
plt.yticks(fontsize = 20)
plt.suptitle("Happiness Scores by Region",fontsize=20)

# %%
# "Happiest"Countries Top 20 
top20 = happy15[happy15.Rank <= 20 ]
top20
fig = px.bar(top20,x="Country",y="Score",hover_data=["LifeExpectancy","GDP"],color="Rank",height=500,)

fig.update_layout(title="Happiest 20 Country")
fig.update_xaxes(showgrid=True, gridwidth=.5)
fig.update_yaxes(showgrid=True, gridwidth=.5)

fig.show()

# %%
worst20 = happy15.tail(20)
worst20
fig = px.bar(worst20,x="Country",y="Score",hover_data=["LifeExpectancy","GDP"],color="Score",height=500,)

fig.update_layout(title="Last 20 Countries")
fig.update_xaxes(showgrid=True, gridwidth=.5)
fig.update_yaxes(showgrid=True, gridwidth=.5)

fig.show()

# %%
# We're going to plot data with Plotly Choropleth Map  
# In order to do this we need data of the countries which is country codes.

# %%
# Importing data from this link
geo_data =  pd.read_csv("/kaggle/input/countrycodes/countrycodes.csv")
geo_data.head()

# %%
# We need to columns..
# Country --> Country
# Code --> Code of the country

country_= geo_data.COUNTRY
list(country_)

# %%
code_ = geo_data.CODE
list(code_)

# %%
# We're going to use (ZIP) function to get a dictionary instead of a list..

country_codes= dict(zip(list(country_),list(code_))

# %%
# Creating new column for country_codes
happy15["Code"] = happy15["Country"]

# %%
happy15.Code.replace(country_codes,inplace = True)

# %% [markdown]
# # There are some countries that Country Code not exist in the list.
# # We're going to add or change it by manually.

# %%
other_countries = {"Ivory Coast":"CI","Congo (Kinshasa)":"CD","Somalia":"SO","Myanmar":"MM"}

# %%
happy15["Code"].replace(other_countries,inplace=True)

# %% [markdown]
# # Choropleth World Map by Happiness Score

# %%
fig = px.choropleth(data_frame=happy15, locations="Code",
                    color="Score", # lifeExp is a column of gapminder
                    hover_name="Country", # column to add to hover information
                    color_continuous_scale=px.colors.sequential.Emrld)
fig.show()
