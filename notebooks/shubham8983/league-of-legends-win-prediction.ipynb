# %%
# import library
import numpy as np 
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers

# %%
# load the dataset
df = pd.read_csv("../input/league-of-legends-diamond-ranked-games-10-min/high_diamond_ranked_10min.csv")
df.head()

# %%
df.shape

# %%
df.describe()

# %%
df.info()

# %%
df.isnull().sum()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df.drop('gameId',axis=1,inplace=True)

# %%
df.head(10)

# %%
df.columns

# %%
df['blueTotalGold'].value_counts()

# %%
df['blueTotalGold'].hist()

# %%
df['redTotalGold'].hist()

# %%
df['blueAssists'].hist()

# %%
df['blueDeaths'].hist()

# %%
df['redDeaths'].hist()

# %%
df['blueKills'].hist()

# %%
df['redKills'].hist()

# %%
df['blueWardsPlaced'].hist()

# %%
df['redWardsPlaced'].hist()

# %%
df['blueWardsDestroyed'].hist()

# %%
df['redWardsDestroyed'].hist()

# %%
df['blueFirstBlood'].value_counts()

# %%
df['blueEliteMonsters'].value_counts()

# %%
sns.countplot(df['blueDragons'])

# %%
sns.countplot(df['blueTowersDestroyed'])

# %%
sns.countplot(df['blueEliteMonsters'])

# %%
sns.countplot(df['blueFirstBlood'])

# %%
sns.distplot(df['blueAvgLevel'])

# %%
sns.distplot(df['blueCSPerMin'])

# %%
sns.distplot(df['blueGoldPerMin'])

# %%
sns.distplot(df['redAvgLevel'])

# %%
df['blueWins'].value_counts()

# %%
plt.figure(figsize=(17,15))
sns.heatmap(df.corr(),annot=True)

# %%
X = df.drop('blueWins',axis=1)
y = df['blueWins']

# %%
X.head()

# %%
y.head()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train.shape

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()

# %%
LR.fit(X_train,y_train)

# %%
y_pred = LR.predict(X_test)

# %%
LR.score(X_test,y_test)

# %%
from sklearn.metrics import f1_score,confusion_matrix,classification_report

# %%
# print(f1_score(y_test,y_pred))
# print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
# RN = RandomForestClassifier()
EC = ExtraTreesClassifier()

# %%
# RN.fit(X_train,y_train)
EC.fit(X_train,y_train)

# %%
# y_predR = RN.predict(X_test)
y_predE = RN.predict(X_test)

# %%
print("score :=",f1_score(y_test,y_predE),"\n")
print("Confusion matrix:= \n",confusion_matrix(y_test,y_predE),"\n")
print("report:=\n",classification_report(y_test,y_predE))

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

# %%
classifier = Sequential()
classifier.add(Dense(units=10,kernel_initializer='he_uniform',activation='relu',input_dim=38))
classifier.add(Dense(units=16,kernel_initializer='he_uniform',activation='relu'))
classifier.add(Dense(units=16,kernel_initializer='he_uniform',activation='relu'))
classifier.add(Dense(units=1,kernel_initializer='glorot_uniform',activation='sigmoid'))
classifier.compile(optimizer = 'adam',loss = 'binary_crossentropy',metrics=['accuracy'])

# %%
model_history = classifier.fit(X_train,y_train,validation_split=0.2,batch_size=32,epochs=300)

# %%
y_predCL = classifier.predict(X_test)
y_predC = (y_predCL > 0.5)

# %%
confusion_matrix(y_test,y_predC)

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(y_predC,y_test)
score

# %%
accuracy_score(y_pred,y_test)

# %%
loss, accuracy = classifier.evaluate(X_test,y_test)
