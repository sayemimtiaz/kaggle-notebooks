# %% [markdown]
# **このノートブックは[Introduction to Machine Learning](https://www.kaggle.com/learn/intro-to-machine-learning)のコースです。 このノートのチュートリアルはこちら-> [this link](https://www.kaggle.com/dansbecker/random-forests).**
#
# ---

# %% [markdown]
# ## Recap
# これまでに書いたコードを紹介します。

# %%
# Cデータの読み込みに使用したことのあるコード
import pandas as pd
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor


# ファイルの読み込み
iowa_file_path = '../input/home-data-for-ml-course/train.csv'

home_data = pd.read_csv(iowa_file_path)
# 目的変数 y
y = home_data.SalePrice
# X を作成
features = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']
X = home_data[features]

# trainingデータを作成（分割）
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)

# モデルの作成
iowa_model = DecisionTreeRegressor(random_state=1)
# モデルを実行するため、fitする
iowa_model.fit(train_X, train_y)

# 検証予測を行い、平均絶対誤差を算出
val_predictions = iowa_model.predict(val_X)
val_mae = mean_absolute_error(val_predictions, val_y)
print("Validation MAE when not specifying max_leaf_nodes: {:,.0f}".format(val_mae))

# max_leaf_nodesに最適な値を使用する
iowa_model = DecisionTreeRegressor(max_leaf_nodes=100, random_state=1)
iowa_model.fit(train_X, train_y)
val_predictions = iowa_model.predict(val_X)
val_mae = mean_absolute_error(val_predictions, val_y)
print("Validation MAE for best value of max_leaf_nodes: {:,.0f}".format(val_mae))


# チェック用のコード
from learntools.core import binder
binder.bind(globals())
from learntools.machine_learning.ex6 import *
print("\nSetup complete")

# %% [markdown]
# # Exercises
# データサイエンスはいつもこんなに簡単ではありません。しかし、決定木をランダムフォレストに置き換えれば、簡単に勝てるようになります。

# %% [markdown]
# ## Step 1: Random Forestを使おう

# %%
from sklearn.ensemble import RandomForestRegressor

# モデルを定義して、random_stateを１にする
rf_model = ____

# モデルをfitする
____

# 検証データに対するランダムフォレストモデルの平均絶対誤差を計算します。
rf_val_mae = ____

print("Validation MAE for Random Forest Model: {}".format(rf_val_mae))

# 答え合わせをする
step_1.check()

# %%
# 以下の行がヒントやソリューションコードになります。（ヒントを見たい場合は.hint()の行をコメントアウト、答えを見る場合は.solutionの行をコメントアウトしてください。
# step_1.hint() 
# step_1.solution()

# %% [markdown]
# これまで、あなたはプロジェクトの各ステップで特定の指示に従ってきました。これにより、重要なアイデアを学び、最初のモデルを構築することができましたが、今では、自分自身で物事を試すのに十分な知識を持っています。
#
# 機械学習コンテストは、自分のアイデアを試し、機械学習プロジェクトを自主的に進めながらより多くのことを学ぶことができる素晴らしい方法です。
#
# # Keep Going
#
# 次のレッスンはこちら **[Machine Learning Competitions](https://www.kaggle.com/alexisbcook/machine-learning-competitions).**

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [Learn Discussion forum](https://www.kaggle.com/learn-forum/161285) to chat with other Learners.*
