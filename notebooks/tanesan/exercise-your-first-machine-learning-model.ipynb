# %% [markdown]
# **このノートブックは[Introduction to Machine Learning](https://www.kaggle.com/learn/intro-to-machine-learning)のコースです。 このノートのチュートリアルはこちら->[this link](https://www.kaggle.com/dansbecker/your-first-machine-learning-model).**
#
# ---

# %% [markdown]
# ## Recap
# 以前までのノートブックで、データを読み込み、以下のコードで確認しました。この前と同じで、この下のコードを先に実行してください。

# %%
# データの読み取りのために使うコード
import pandas as pd

# 読み取り用ファイル
iowa_file_path = '../input/home-data-for-ml-course/train.csv'

home_data = pd.read_csv(iowa_file_path)

# チェックの用意
from learntools.core import binder
binder.bind(globals())
from learntools.machine_learning.ex3 import *

print("Setup Complete")

# %% [markdown]
# # Exercises
#
# ## Step 1: 予測対象の指定
# 販売価格に対応する目的変数を選択します。これを`y`という新しい変数に保存します。必要な列の名前を見つけるには、列のリストをprintする必要があります。

# %%
# 予測対象(y 目的変数)の名前を見つけるために、データセットの列のリストを表示します。

# %%
y = ____

# あっているかどうか確認するコードです。
step_1.check()

# %%
# 以下の行がヒントやソリューションコードになります。（ヒントを見たい場合は.hint()の行をコメントアウト、答えを見る場合は.solutionの行をコメントアウトしてください。
# step_1.hint() 
# step_1.solution()

# %% [markdown]
# ## Step 2: X を作ろう
# ここで、予測特徴量の`X`というDataFrameを作成します。
#
# 元のデータから一部の列だけを取り出したいので、まず`X`に入れたい列の名前をリストにします。
#
# リストでは、以下の列だけを使用します（リスト全体をコピー＆ペーストすることで、入力の手間を省くことができますが、引用符を追加する必要があります）。
#     * LotArea
#     * YearBuilt
#     * 1stFlrSF
#     * 2ndFlrSF
#     * FullBath
#     * BedroomAbvGr
#     * TotRmsAbvGrd
#
#
# これらのリストを作成し、DataFrameを作成します。

# %%
# 以下の特徴(Xにいれるものの列名）の名前のリストを作成
feature_names = ___

# feature_namesで指定した列名に対応するデータを選択する
X = ____

# 答えを確認する
step_2.check()

# %%
# step_2.hint()
# step_2.solution()

# %% [markdown]
# ## データを確認する
# モデルを構築する前に、**X**を見て、それが正しいかどうか確認してください。

# %%
# 確認する
# X の概要、統計量を出力してください
#print(_)

# Dataframeの上から数個のデータを出力してください。
#print(_)

# %% [markdown]
# ## Step 3: モデルの指定とフィット（分析しやすいように綺麗にする)
# `DecisionTreeRegressor`というモデルを作成し、iowa_modelとして保存します。このコマンドを実行するために、sklearnからのインポートが適切に行われていることを確認してください。
#
# 次に、上で保存した `X` と `y` のデータを使って、作成したモデルをfitさせます。

# %%
# from _ import _
#モデルを指定します
#モデルの再現性を高めるために、モデルを指定する際にrandom_stateに数値を設定します。
iowa_model = ____

# モデルをfitする
____

#　答えを確認する
step_3.check()

# %%
# step_3.hint()
# step_3.solution()

# %% [markdown]
# ## Step 4: 予測をする
# モデルの `predict` コマンドを使って、`X` をデータとして使って予測を行います。その結果を `predictions` という名前の変数に保存します。

# %%
predictions = ____
print(predictions)

# 答えをチェックする
step_4.check()

# %%
# step_4.hint()
# step_4.solution()

# %% [markdown]
# ## 君の作った答えについて考えてみよう
#
# `head`メソッドを使って、上位数件の予測値と、それらの同じ住宅の実際の住宅価格（`y`）を比較します。何か驚くようなことはありましたか？

# %%
# このセルにコードを書いてみてください。

# %% [markdown]
# モデルの予測精度はどの程度なのか、どうすればそれを改善できるのか、と考えるのは当然のことでしょう。それが次のステップになるでしょう。
#
# # Keep Going
#
# 次のステップはこちらです。　**[Model Validation](https://www.kaggle.com/dansbecker/model-validation).**

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [Learn Discussion forum](https://www.kaggle.com/learn-forum/161285) to chat with other Learners.*
