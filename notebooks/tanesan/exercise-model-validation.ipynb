# %% [markdown]
# **このノートブックは[Introduction to Machine Learning](https://www.kaggle.com/learn/intro-to-machine-learning)のコースです。 このノートのチュートリアルはこちら-> [this link](https://www.kaggle.com/dansbecker/model-validation).**
#
# ---

# %% [markdown]
# ## Recap
# あなたはモデルを作りました。このエクササイズでは、あなたのモデルがどれだけ優れているかをテストします。
#
# 以下のセルを実行して、前の演習が終了したところでコーディング環境を設定します。

# %%
# データの読み込みに使用したことのあるコード
import pandas as pd
from sklearn.tree import DecisionTreeRegressor

# ファイルの読み込み
iowa_file_path = '../input/home-data-for-ml-course/train.csv'

home_data = pd.read_csv(iowa_file_path)
y = home_data.SalePrice
feature_columns = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']
X = home_data[feature_columns]

# モデルの定義
iowa_model = DecisionTreeRegressor()
# fit.機械学習を実行するメソッド
iowa_model.fit(X, y)

print("First in-sample predictions:", iowa_model.predict(X.head()))
print("Actual target values for those homes:", y.head().tolist())

# コードチェック
from learntools.core import binder
binder.bind(globals())
from learntools.machine_learning.ex4 import *
print("Setup Complete")

# %% [markdown]
# # Exercises
#
# ## Step 1: 訓練データとテスト用データにデータを分割してみよう
# データを分割するには、`train_test_split`関数を使います。
#
# この関数には引数として `random_state=1` を与えてください。
#
# 特徴量はデータフレーム**X**に設定され、ターゲット(目的変数のリスト)は**y**に設定されていることを思い出してください。

# %%
# train_test_splitのライブラリをインストールするため、この下の行のコメントアウト消して書いてください。
# from _ import _

# この下の行のコメントアウト消して書いてください。
# train_X, val_X, train_y, val_y = ____

# 答えを確認しよう
step_1.check()

# %%
# 以下の行がヒントやソリューションコードになります。（ヒントを見たい場合は.hint()の行をコメントアウト、答えを見る場合は.solutionの行をコメントアウトしてください。
# step_1.hint() 
# step_1.solution()

# %% [markdown]
# ## Step 2: モデルの指定と適合
#
# `DecisionTreeRegressor`モデルを作成して、関連するデータにフィットさせます。
# モデルを作成する際には、`random_state`を再び1に設定します。

# %%
# 前回の練習ではDecisionTreeRegressorをインポートしましたが、そのコードが上記のセットアップコードにコピーされています。そのため、以下のimportをする必要はありません。
# import it again

# モデル
iowa_model = ____

# iowa_modelを学習データに適合させます。
____

# 答えを確認する
step_2.check()

# %%
# step_2.hint()
# step_2.solution()

# %% [markdown]
# ## Step 3: バリデーションデータで予測する

# %%
# すべての検証用(train)データを使って予測する
val_predictions = ____

# 答えを確認する
step_3.check()

# %%
# step_3.hint()
# step_3.solution()

# %% [markdown]
# 予測値と実際の値を検証データから比べる

# %%
# 検証結果の上位数名の予測値を表示
print(____)
# 検証データから実際の価格の上位数名を表示する
print(____)

# %% [markdown]
# サンプル内予測（このページの一番上のコードセルの後にprintされています）で見たものとは違うことに気がつきましたか？
#
# 検証用の予測値がサンプル内（またはトレーニング）の予測値と異なる理由を覚えていますか？これは、前回のレッスンでの重要な内容です。
#
# ## Step 4: バリデーションデータの平均誤差(MAE)の算出

# %%
from sklearn.metrics import mean_absolute_error
val_mae = ____

# validation_maeを見るには、以下の行をコメントアウトしてください。
#print(val_mae)

# 答えを確認してください。
step_4.check()

# %%
# step_4.hint()
# step_4.solution()

# %% [markdown]
# そのMAEの値はどうですか？ どのような値が良いのか、アプリケーション全体に適用できる一般的なルールはありません。しかし、次のステップでは、この数値をどのように使うか（改善するか）を見ていきます。
# # Keep Going
#
# 次のコース **[Underfitting and Overfitting](https://www.kaggle.com/dansbecker/underfitting-and-overfitting).**

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [Learn Discussion forum](https://www.kaggle.com/learn-forum/161285) to chat with other Learners.*
