# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# *Importing Libraries*

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px

# %% [markdown]
# **Reading Dataset**

# %%
df = pd.read_csv('../input/women-entrepreneurship-and-labor-force/Dataset3.csv', delimiter=";")
df.head()

# %% [markdown]
# **Getting basic info about Dataset**

# %%
df.shape

# %%
df.info()

# %%
df.describe()

# %%
df.Country.value_counts()

# %%
df.sample(5)

# %% [markdown]
# **Checking in which country the Female Labour Force Prticipation is more**

# %%
fig, ax = plt.subplots(1,1, figsize=(12,6))
ax.bar(df.Country.sample(15), df['Female Labor Force Participation Rate'].sample(15), width=0.8, color='r')

# %% [markdown]
# **Checking how Entrepreneurship Index is distributed**

# %%
sns.distplot(df['Entrepreneurship Index'], bins=30)

# %%
df.Currency.unique()

# %% [markdown]
# # Checking the proportion of Currency

# %%
plt.figure(figsize=(6,6))
px.pie(df.Currency, values=df.Currency.value_counts().values, labels = df.Currency.value_counts().index)

# %% [markdown]
# # Checking in which country Women Entrereneurship Index is high

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(df['Country'].sample(25), df['Women Entrepreneurship Index'].sample(25), data=df, marker='+')

# %%
df['Inflation rate'].plot.hist(bins=50)

# %%
plt.figure(figsize=(12,6))
df['Female Labor Force Participation Rate'].plot.bar()

# %% [markdown]
# # Dropping country

# %%
df.drop(['Country'],axis=1,inplace =True)
df.head()

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(), annot=True)

# %%
df=df[['Entrepreneurship Index','Women Entrepreneurship Index']]

# %%
sns.heatmap(df.corr(), annot =True, cmap='viridis')

# %% [markdown]
# # Choosing X and y

# %%
X = df.iloc[:,:-1]
y = df.iloc[:, -1]

# %% [markdown]
# # Train Test Split Method

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.25, random_state=0)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)
y_pred

# %%
from sklearn.metrics import r2_score
print('r2 score: ', r2_score(y_test, y_pred))

# %%
sns.regplot(x='Entrepreneurship Index', y='Women Entrepreneurship Index', data=df)
