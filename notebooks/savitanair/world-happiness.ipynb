# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('../input/world-happiness/2019.csv')
df.head()

# %%
df.shape

# %%
df.info()

# %%
df.describe()

# %%
df = df.set_index(df['Overall rank'])

# %%
df = df.drop('Overall rank', axis=1)

# %%
df.head()

# %%
df.isnull().sum()

# %% [markdown]
# # EDA

# %%
sns.pairplot(df)

# %%
sns.distplot(df['Generosity'])

# %%
sns.relplot('Social support', 'Generosity', data=df)

# %%
sns.boxplot('Score', data=df)

# %%
score = df.Score.value_counts().head(10)
score

# %%
px.pie(score, score.index)

# %%
px.bar(df['Country or region'], df['Score'])

# %%
df.columns

# %%
sns.regplot(df['Freedom to make life choices'], df['Score'])

# %%
sns.barplot(df['Healthy life expectancy'].head(10), df['Score'].head(10))

# %%
df['Country or region'].unique()
