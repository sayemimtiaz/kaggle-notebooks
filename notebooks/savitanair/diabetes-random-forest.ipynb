# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../input/pima-indians-diabetes-database/diabetes.csv')

# %%
df.head()

# %%
sns.distplot(df.Age)

# %%
df.info()

# %%
df.isnull().any()

# %%
sns.boxplot(df.Pregnancies)

# %%
min_thresold, max_thresold = df.Pregnancies.quantile([0.001, 0.999])
min_thresold, max_thresold

# %%
df[df.Pregnancies > max_thresold]

# %%
df = df[(df.Pregnancies<max_thresold) & (df.Pregnancies>min_thresold)]
df.shape

# %%
sns.boxplot(df.BloodPressure)

# %%
sns.distplot(df.BMI)

# %%
plt.figure(figsize=(15,6))
sns.barplot(df.Age, df.BMI)

# %%
print(f'The total number of patients are {len(df)}')

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(df.Age, df.BloodPressure)

# %%
X = df.iloc[:,:8]
y = df.iloc[:,8]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=20, random_state=0)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(accuracy_score(y_test, y_pred))
