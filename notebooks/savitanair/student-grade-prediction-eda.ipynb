# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('../input/student-grade-prediction/student-mat.csv')
df.head()

# %%
df.shape

# %%
df.info()

# %%
df.columns

# %%
l=['address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'paid', 'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc']
df.drop(l, axis=1, inplace=True)

# %%
df.head()

# %%
df.school.unique()

# %%
sch = df.school.value_counts().to_dict()
plt.figure(figsize=(10,10))
plt.pie(x=sch.values(), labels=sch.keys(), autopct='%1.1f%%')
plt.show()

# %%
s = df.sex.value_counts().to_dict()
plt.figure(figsize=(8,8))
plt.pie(x=s.values(), labels=s.keys(), autopct='%1.1f%%')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.set(style='darkgrid')
sns.countplot(df.age)

# %%
plt.figure(figsize=(12,6))
sns.set(style='darkgrid')
sns.countplot(df['traveltime'])

# %%
plt.figure(figsize=(12,6))
sns.set(style='darkgrid')
sns.countplot(df.studytime)

# %%
schup = df.schoolsup.value_counts().to_dict()
plt.figure(figsize=(10,10))
plt.pie(x=schup.values(), labels=schup.keys(), autopct='%1.1f%%')
plt.show()

# %%
fup = df.famsup.value_counts().to_dict()
plt.figure(figsize=(10,10))
plt.pie(x=fup.values(), labels=fup.keys(), autopct='%1.1f%%')
plt.show()

# %%
act = df.activities.value_counts().to_dict()
plt.figure(figsize=(10,10))
plt.pie(x=act.values(), labels=act.keys(), autopct='%1.1f%%')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.set(style='darkgrid')
sns.countplot(df['health'])

# %%
plt.figure(figsize=(12,6))
sns.set(style='darkgrid')
sns.distplot(df['traveltime'])

# %%
sns.barplot(df.G1, df.G2, df.G3)
