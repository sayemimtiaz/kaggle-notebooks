# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('../input/suicide-rates-overview-1985-to-2016/master.csv')

# %%
df.iloc[:,9] = df.iloc[:,9].str.replace(',','').astype(int)

# %%
df.info()

# %%
df.describe()

# %%
df['HDI for year'] = df['HDI for year'].fillna(np.mean(df['HDI for year']))

# %%
df.isnull().sum()

# %%
df.drop('country-year', axis=1, inplace=True)

# %%
df.head()

# %%
sns.countplot(df.sex, color='r')

# %%
plt.figure(figsize=(12,6))
sns.countplot(df.year, color='y')
plt.xticks(rotation=45)
plt.show()

# %%
year_list=list(df.year.unique())
year_suicide_ratio=[]
for i in year_list:
    a=df[df['year']==i]
    year_suicide_rate=sum(a['suicides/100k pop'])/len(a)
    year_suicide_ratio.append(year_suicide_rate)
data=pd.DataFrame({'year_list':year_list,'year_suicide_ratio':year_suicide_ratio})
new_index=(data['year_suicide_ratio'].sort_values(ascending=True)).index.values
sorted_data=data.reindex(new_index)


# visualization
plt.figure(figsize=(15,10))
sns.barplot(x=sorted_data['year_list'],y=sorted_data['year_suicide_ratio'])
plt.xticks(rotation=90)
plt.xlabel('Years')
plt.ylabel('Suicides')
plt.title('Which year did the most suicides occour')
plt.show()

# %%
df[['age', 'suicides/100k pop']].groupby('age').mean().sort_values(by='suicides/100k pop',
                                                                   ascending=False)

# %%
df[['sex', 'suicides/100k pop']].groupby('sex').mean().sort_values(by='suicides/100k pop',
                                                                   ascending=False)

# %%
plt.figure(figsize=(8,4))
sns.barplot(x=df['sex'],y=df['suicides/100k pop'])
plt.xticks(rotation=90)
plt.xlabel("Sex")
plt.ylabel("Suicide Rate")
plt.title("Gender ratio of those who committed suicide")
plt.show()

# %%
df[['generation', 'suicides/100k pop']].groupby('generation').mean().sort_values(by='suicides/100k pop',
                                                                   ascending=False)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df['generation'],y=df['suicides/100k pop'])
plt.xticks(rotation=90)
plt.xlabel("Generations")
plt.ylabel("Suicides Rates")
plt.title("Suicide rate of generations")
plt.show()
