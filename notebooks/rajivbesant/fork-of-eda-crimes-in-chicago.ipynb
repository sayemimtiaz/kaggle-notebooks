# %%
# importing the dataset and putting it into a dataframe 
import pandas as pd 
url = "../input/Chicago_Crimes_2012_to_2017.csv"
df = pd.read_csv(url)

# %%
# importing different libraries for math and plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('whitegrid')

# %%
# Understanding how many rows and columns this data has
df.shape

# %%
# Exploring the data

df.head()

# %%
#checking the datatypes of all the columns
df.dtypes

# Here we noticed that the datatype for the year and the data are "object" 
# where else they should be "datetime64", so this is something we have to keep in mind
# during our analysis

# %%
#Checking the statistics of all the columns

df.describe(include ="all")

# %%
# This graph shows the different categories of crimes that took place betweeen 2012 to 2016
# this is plotted against the number of times they have occurced
# there also is a hue that shows, the people number of people that were arrested for that particular 
# kind of crime

g = sns.factorplot(y="Primary Type", hue="Arrest", kind="count",
                   data=df,size=10)
g.set_ylabels("Different Crime Categories")

# %%
    
        
        # here we are creating a dataframe that groups crime by the location desccription

crime_location = pd.DataFrame(df.groupby('Location Description').size().sort_values(ascending=False).rename('Count').reset_index())
crime_location.head()

# %%
# this graph shows the number of crimes that occur in the top 5 "crime locations" 
    
crime_location[:5].plot(x='Location Description',y='Count',kind='bar')

# %%
url = "../input/Chicago_Crimes_2012_to_2017.csv"
df_test = pd.read_csv(url)

# %%
#Predective Analysis
df.head()

# %%
# converting the primary type to numerical type


from sklearn.preprocessing import LabelEncoder,OneHotEncoder

labelEnc=LabelEncoder()

cat_vars=['Primary Type','Description']
for col in cat_vars:
    df[col]=labelEnc.fit_transform(df[col])
    df_test[col]=labelEnc.fit_transform(df_test[col])

df.head()

# %%
#importing all the required ML packages
from sklearn.linear_model import LogisticRegression #logistic regression
from sklearn import svm #support vector Machine
from sklearn.ensemble import RandomForestClassifier #Random Forest
from sklearn.neighbors import KNeighborsClassifier #KNN
from sklearn.naive_bayes import GaussianNB #Naive bayes
from sklearn.tree import DecisionTreeClassifier #Decision Tree
from sklearn.model_selection import train_test_split #training and testing data split

# %%
train,test=train_test_split(df,test_size=0.3,random_state=0,stratify=df['Primary Type'])
train_X=train[train.columns[1:]]
train_Y=train[train.columns[:1]]
test_X=test[test.columns[1:]]
test_Y=test[test.columns[:1]]
X=df[df.columns[1:]]
Y=df['Primary Type']

# %%
model=svm.SVC(kernel='rbf',C=1,gamma=0.1)
model.fit(train_X,train_Y)
prediction1=model.predict(test_X)
print('Accuracy for rbf SVM is ',metrics.accuracy_score(prediction1,test_Y))
