# %% [markdown]
# # Create a global map for COVID Vaccinations (Percentage of the population that are fully vaccinated).

# %%
import pandas as pd
import numpy as np 
import plotly.express as px
import plotly

df = pd.read_csv('../input/d/gpreda/covid-world-vaccination-progress/country_vaccinations.csv',header=0)
df.index = pd.to_datetime(df['date'])
df = df.sort_index()
print(df.columns)
#print(df)
fig = px.choropleth(df,locations='country',locationmode='country names',color='people_fully_vaccinated_per_hundred',hover_name='country',animation_frame='date',color_continuous_scale='rainbow',range_color=(0.0,30.0))
fig.update_layout(title_text="Percentage of the country's total population that are fully vaccinated",title_x=0.42)
fig.show()

plotly.offline.plot(fig,filename='vaccinations.html')

# %% [markdown]
# # Create a global map of earthquake occurrences worldwide.

# %% [markdown]
# 'vaccinations.html'

# %%
df = pd.read_csv('../input/smatra-earthquake-2004122620041231/query (3).csv',header=0)
#print(df.columns)

df.index = pd.to_datetime(df['time'])
#print(df['time'])
#print(df.index)

df['time'] = df.index.strftime('%Y-$m-%d %H:00:00')
#print(df['time'])
df = df.sort_index()
fig = px.scatter_geo(df,lat='latitude',lon='longitude',color='mag',animation_frame='time',color_continuous_scale='rainbow',range_color=(1.0,7.0))
fig.show()

# %% [markdown]
# ## Cite the news articles and Discussion
#
# (reference article: https://www.jiji.com/jc/v2?id=sufferings_09)
# I focused on "Smatra earthquake" occurred in near Indonesia, December 24, 2004.
# It occurred in the morning, one day after Christmas.
# The magnitude is over 9.3. This is higher than 3.11 in 2011, East-Japan one.
# The number of death is almost 220 thousand people. But the most harmful reason is not earthquake but the tsunami occurred from the earthquake.
# This tragedy is bad the season or day that is one day after Christmas day. In this article, the victims are included tourists.
# 40 Japanese tourists are also killed by this disaster.
# Considering the occurences map above, a number of earthquakes happened in the east side of Indian Ocean after the Smatra earthquake.
# Additionaly, it brought out the earthquakes far away area, south-west Japan in 6p.m. in 29.
# This said the Smatra earthquake had so much energy and influence for earth surface.
