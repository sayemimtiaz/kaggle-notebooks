# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns 
import matplotlib.pyplot as plt 

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['avocado.csv']

# %% [markdown]
# # Avocado prices in the USA

# %%
df = pd.read_csv('../input/avocado.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice   ...            type  year  region
# 0           0  2015-12-27          1.33   ...    conventional  2015  Albany
# 1           1  2015-12-20          1.35   ...    conventional  2015  Albany
# 2           2  2015-12-13          0.93   ...    conventional  2015  Albany
# 3           3  2015-12-06          1.08   ...    conventional  2015  Albany
# 4           4  2015-11-29          1.28   ...    conventional  2015  Albany
#
# [5 rows x 14 columns]

# %%
df['region'].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
df['year'].unique()
# Out:
# array([2015, 2016, 2017, 2018])

# %%
df['type'].unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
df.tail()
# Out:
#        Unnamed: 0        Date        ...         year            region
# 18244           7  2018-02-04        ...         2018  WestTexNewMexico
# 18245           8  2018-01-28        ...         2018  WestTexNewMexico
# 18246           9  2018-01-21        ...         2018  WestTexNewMexico
# 18247          10  2018-01-14        ...         2018  WestTexNewMexico
# 18248          11  2018-01-07        ...         2018  WestTexNewMexico
#
# [5 rows x 14 columns]

# %% [markdown]
# ## Houston:

# %% [markdown]
# When I moved from Texas to Indiana, I noticed the prices for avocados were higher in Indiana. Let's see if this data set supports my experience.

# %%
hou = df.loc[df['region']=='Houston',]

# %%
hou.head()
# Out:
#      Unnamed: 0        Date  AveragePrice   ...             type  year   region
# 936           0  2015-12-27          0.78   ...     conventional  2015  Houston
# 937           1  2015-12-20          0.75   ...     conventional  2015  Houston
# 938           2  2015-12-13          0.73   ...     conventional  2015  Houston
# 939           3  2015-12-06          0.74   ...     conventional  2015  Houston
# 940           4  2015-11-29          0.79   ...     conventional  2015  Houston
#
# [5 rows x 14 columns]

# %%
g = sns.catplot(data=hou, kind='box', x='year', y='AveragePrice', palette='winter')
g.fig.suptitle("Houston: Avocado prices")
# Out:
# Text(0.5, 0.98, 'Houston: Avocado prices')

# %%
g = sns.catplot(data=hou, kind='swarm', x='year', y='AveragePrice', hue='type', palette='winter')
g.fig.suptitle("Houston: Average avocado prices")
# Out:
# Text(0.5, 0.98, 'Houston: Average avocado prices')

# %%
g = sns.catplot(data=hou, kind='swarm', palette='hls', x='type', y='AveragePrice', hue='year')
g.fig.suptitle("Houston: Average Avocado prices")
# Out:
# Text(0.5, 0.98, 'Houston: Average Avocado prices')

# %% [markdown]
# ## Indianapolis:

# %%
indy = df.loc[df['region']=='Indianapolis',]

# %%
indy.head()
# Out:
#      Unnamed: 0        Date      ...       year        region
# 988           0  2015-12-27      ...       2015  Indianapolis
# 989           1  2015-12-20      ...       2015  Indianapolis
# 990           2  2015-12-13      ...       2015  Indianapolis
# 991           3  2015-12-06      ...       2015  Indianapolis
# 992           4  2015-11-29      ...       2015  Indianapolis
#
# [5 rows x 14 columns]

# %%
g = sns.catplot(data=indy, kind='box', x='year', y='AveragePrice', palette='winter')
g.fig.suptitle("Indianapolis: Avocado prices")
# Out:
# Text(0.5, 0.98, 'Indianapolis: Avocado prices')

# %%
g = sns.catplot(data=indy, kind='swarm', x='year', y='AveragePrice', hue='type', palette='winter')
g.fig.suptitle("Indianapolis: Average avocado price")
# Out:
# Text(0.5, 0.98, 'Indianapolis: Average avocado price')

# %%
g = sns.catplot(data=indy, kind='swarm', palette='hls', x='type', y='AveragePrice', hue='year')
g.fig.suptitle("Indianapolis: Average avocado price")
# Out:
# Text(0.5, 0.98, 'Indianapolis: Average avocado price')

# %% [markdown]
# Since I actually live in northwest Indiana I wanted to check a couple of nearby cities and see how the prices compare.

# %% [markdown]
# ## Chicago:

# %%
chicago = df.loc[df['region']=="Chicago",]
chicago.head()
# Out:
#      Unnamed: 0        Date  AveragePrice   ...             type  year   region
# 416           0  2015-12-27          0.93   ...     conventional  2015  Chicago
# 417           1  2015-12-20          0.91   ...     conventional  2015  Chicago
# 418           2  2015-12-13          1.07   ...     conventional  2015  Chicago
# 419           3  2015-12-06          1.14   ...     conventional  2015  Chicago
# 420           4  2015-11-29          1.11   ...     conventional  2015  Chicago
#
# [5 rows x 14 columns]

# %%
g = sns.catplot(data=chicago, kind='box', x='year', y='AveragePrice', palette='winter')
g.fig.suptitle("Chicago: Avocado prices")
# Out:
# Text(0.5, 0.98, 'Chicago: Avocado prices')

# %%
g = sns.catplot(data=chicago, kind='swarm', x='year', y='AveragePrice', hue='type', palette='winter')
g.fig.suptitle("Chicago: Average avocado price")
# Out:
# Text(0.5, 0.98, 'Chicago: Average avocado price')

# %%
g = sns.catplot(data=chicago, kind='swarm', palette='hls', x='type', y='AveragePrice', hue='year')
g.fig.suptitle("Chicago: Average avocado price")
# Out:
# Text(0.5, 0.98, 'Chicago: Average avocado price')

# %% [markdown]
# ## Grand Rapids:

# %%
GrandRapids = df.loc[df['region']=="GrandRapids",]
GrandRapids.head()
# Out:
#      Unnamed: 0        Date     ...       year       region
# 728           0  2015-12-27     ...       2015  GrandRapids
# 729           1  2015-12-20     ...       2015  GrandRapids
# 730           2  2015-12-13     ...       2015  GrandRapids
# 731           3  2015-12-06     ...       2015  GrandRapids
# 732           4  2015-11-29     ...       2015  GrandRapids
#
# [5 rows x 14 columns]

# %%
g = sns.catplot(data=GrandRapids, kind='box', x='year', y='AveragePrice', palette='winter')
g.fig.suptitle("Grand Rapids: Avocado prices")
# Out:
# Text(0.5, 0.98, 'Grand Rapids: Avocado prices')

# %%
g = sns.catplot(data=GrandRapids, kind='swarm', x='year', y='AveragePrice', hue='type', palette='winter')
g.fig.suptitle("Grand Rapids: Average avocado price")
# Out:
# Text(0.5, 0.98, 'Grand Rapids: Average avocado price')

# %%
g = sns.catplot(data=GrandRapids, kind='swarm', palette='hls', x='type', y='AveragePrice', hue='year')
g.fig.suptitle("Grand Rapids: average avocado price")
# Out:
# Text(0.5, 0.98, 'Grand Rapids: average avocado price')

# %% [markdown]
# - This data supports my experience that I was paying more for avocados in Indiana than I was in Texas.
# - A quick Google search reveals 2017 experienced an avocado shortage, although the price increase appears to have hit some areas harder than others.

# %% [markdown]
# # 2017 data:

# %%
yr2017 = df.loc[df['year'].isin(['2017'])]
yr2017.head()
# Out:
#       Unnamed: 0        Date  AveragePrice   ...            type  year  region
# 5616           0  2017-12-31          1.47   ...    conventional  2017  Albany
# 5617           1  2017-12-24          1.45   ...    conventional  2017  Albany
# 5618           2  2017-12-17          1.43   ...    conventional  2017  Albany
# 5619           3  2017-12-10          1.29   ...    conventional  2017  Albany
# 5620           4  2017-12-03          1.39   ...    conventional  2017  Albany
#
# [5 rows x 14 columns]

# %%
g = sns.catplot(data=yr2017, kind='swarm', palette='magma', x='type', y='AveragePrice', hue='region')

# %% [markdown]
# ## Total US:

# %%
totalUS = df.loc[df['region'].isin(['TotalUS'])]
totalUS.head()
# Out:
#       Unnamed: 0        Date  AveragePrice   ...             type  year   region
# 2652           0  2015-12-27          0.95   ...     conventional  2015  TotalUS
# 2653           1  2015-12-20          0.98   ...     conventional  2015  TotalUS
# 2654           2  2015-12-13          0.93   ...     conventional  2015  TotalUS
# 2655           3  2015-12-06          0.89   ...     conventional  2015  TotalUS
# 2656           4  2015-11-29          0.99   ...     conventional  2015  TotalUS
#
# [5 rows x 14 columns]

# %%
g = sns.catplot(data=totalUS, kind='box', x='year', y='AveragePrice', palette='winter')
g.fig.suptitle("Total US: Avocado prices")
# Out:
# Text(0.5, 0.98, 'Total US: Avocado prices')

# %%
g = sns.catplot(data=totalUS, kind='swarm', x='year', y='AveragePrice', hue='type', palette='winter')
g.fig.suptitle("Total US: Average avocado price")
# Out:
# Text(0.5, 0.98, 'Total US: Average avocado price')

# %%
g = sns.catplot(data=totalUS, kind='swarm', palette='hls', x='type', y='AveragePrice', hue='year')
g.fig.suptitle("Total US: average avocado price")
# Out:
# Text(0.5, 0.98, 'Total US: average avocado price')
