# %% [markdown]
# # Detecting Bankruptcy,
#
# A finacial problem that can hold major significance in the world of equities and trading. This sheet will be using information and other tools from other kernals in this dataset. The idea here is to hone my skill of the ***process and approach*** data analytics should take when given a set of data.
#
# ## The Goal.
#
# We will want to provide a method of predicting if a company is at risk of going bankrupt given a set of information.
# I have seen another kernal that states one approach to this is by not only making a model that can:
# * Detect a company going bankrupt
# * Classify the Parameters and variables that contribute the most to this bankruptcy, This can help detect the bankruptcy but also help provide an insight into the ways a company can "fail" so-to-speak.

# %% [markdown]
# ## Please note, I used [this](https://www.kaggle.com/marto24/bankruptcy-detection) notebook for inspiration, this work below can't be considered my own as I use fairly similar features/techniques used by that notebook, please sent credit to user [Marto93](https://www.kaggle.com/marto24)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

input_data = "/kaggle/input/company-bankruptcy-prediction/data.csv"

# %%
data = pd.read_csv(input_data)
#Input data first

# %%
data.info()
#Before we work with the data, we want to know more information about it.
#Are any values missing? Are any catagorical?

# %% [markdown]
# We can see the total number of rows, columns and the amount of distinct datatypes. Here it is only floating points and integers. Therefore we dont need any one-hot encoders.

# %%
data.isnull().sum().sum()
# With 6819 values, we have 0 null points of data, 95 Columns of full information

# %% [markdown]
# So, I am a computer science graduate with not much background knowledge on how these companies work or how they function. I could lookup the individual 94 features and research how much i think they impact the probability of bankruptcy... or ask someone who does have knowledge to help me find out.
#
# I think a better way is attempting to analyse correlation between data and see if there are emerging patterns that we can take advantage of, In this case maybe even drop some labels that do not help us.

# %%
data.hist(figsize=(20,20), bins = 30)
plt.show()

# %% [markdown]
# Below is a correlation heatmap on the values within the dataset,

# %%
Correlation = data.corr()[['Bankrupt?']]
plt.subplots(figsize=(30,30))
sns.heatmap(Correlation,square=True,fmt="",cmap="RdYlGn")

plt.show()

# %%
Correlation.info()
Correlation.sort_values(by=['Bankrupt?'],ascending=False)

# %% [markdown]
# So we can see, Debt ratio, Current liability to assests and the borrowing dependancy etc all have the higher end correlations for a company to go bankrupt.

# %% [markdown]
# How many of these companies are bankrupt?
# 1 is bankrupt and 0 isn't

# %%
print(data['Bankrupt?'].value_counts())

# %%
labels = 'Not Bankrupt','Bankrupt'
sizes = [data['Bankrupt?'].value_counts()[0],data['Bankrupt?'].value_counts()[1]]

fig1,ax1 = plt.subplots()
plt.figure(figsize=(20,20))
ax1.pie(sizes,labels = labels,autopct="%1.1f%%",startangle=90)
ax1.axis('equal')
plt.show()

# %% [markdown]
# # [Imbalanced Classification Problems](https://machinelearningmastery.com/what-is-imbalanced-classification/)
#
# The above pie chart introduces a severe problem with out analysis. The Dataset is obviously skewed with more **Non-bankrupt** companies than **bankrupt** ones. For binary classification our models need to have a better balance of data to have better performance rankings later on (essentially be better at classifying data).

# %% [markdown]
# >  "An imbalance occurs when one or more classes have very low proportions in the training data as compared to the other classes."

# %% [markdown]
# This imbalance is shown with the minority class being the bankrupt companies and the majority class being the non-bankrupt companies. On a ratio of 220:6599 this shows that without adjustment the learning rate of models may suffer.
#
# ## Why is it a problem though, Surely we can still distinguish the companies that are at risk to the ones that aren't?
#
# Many classification algorithms rely on assuming (naively) that the distribution of both classes is near equal. This means with a large majority of one class, the algorithm will learn the characteristics of only that class and nothing about the minority class that is more significant.
#
# > … the learning process of most classification algorithms is often biased toward the majority class examples, so that minority ones are not well modeled into the final system.
