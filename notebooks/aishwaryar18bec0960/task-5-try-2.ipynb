# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Reading file

# %%
df_test = pd.read_csv("../input/covid19-in-india/StatewiseTestingDetails.csv")  
print("Successfully imported data into console" )
df_test.head()

# %% [markdown]
# Cleaning the Data

# %%
df_test = df_test.drop(['Negative'], axis = 1)
df_test

# %%
df_test.dropna(inplace = True)
df_test

# %%
df_test1 = df_test.copy()
df_test1

# %%
#df_test2 = df_test.copy()
#df_test2['Positive'] = df_test2['Positive'].fillna(df_test2.groupby('State')['Positive'].transform('mean'))

# %%
#df_test2 = df_test.copy()
#df_test2['Positive'] = df_test2['Positive'].fillna(df_test2.groupby('State')['Positive'].transform('mean'))

# %%
#df_test2 = df_test.copy()
#df_test2['Positive'] = df_test2['Positive'].fillna(df_test2.groupby('State')['Positive'].transform('mean'))

# %%
df_test2 = df_test.copy()

# %%
df_test3 = df_test2.groupby('Date').sum()
df_test3.reset_index(inplace = True, drop = False)
df_test3

# %%
df_test1 = df_test2.groupby('Date').sum()
df_test1.reset_index(inplace = True, drop = False)
df_test1

# %%
fig = plt.figure(figsize=(18, 6))
plt.plot(df_test1.Date,df_test1.Positive)

# %%
df_test1['Date'] = pd.to_datetime(df_test1['Date'])
df_test1 = df_test1.groupby(df_test1['Date'].dt.strftime('%B'))['TotalSamples','Positive'].sum().sort_values('Date')

# %%
df_test1.reset_index(inplace = True, drop = False)
df_test1

# %%
fig = plt.figure(figsize=(18, 6))
#ax = df_test1.plot.bar(x='Date', y='Positive', rot=0)
plt.bar(df_test1.Date,df_test1.Positive)
plt.show()

# %%
fig = plt.figure(figsize=(18, 6))
plt.xlab = 'Total Samples'
plt.ylab = 'Postive Samples'
plt.title = 'Infection rate'
l1 = list(df_test3.TotalSamples)
l2 = list(df_test3.Positive)
d = {}
for i in range(len(l1)):
    d[l1[i]] = l2[i]
d2 = sorted(d.items())
x, y = zip(*d2) # unpack a list of pairs into two tuples

plt.plot(x, y)
plt.show()
#plt.plot(df_test3.TotalSamples,df_test3.Positive, '.')

# %%
df_test3['Rate'] = (df_test3['Positive'])/(df_test3['TotalSamples'])*100
df_test3

# %%
df_test3.Rate.max()

# %% [markdown]
# DATA SET 2

# %%
ind = pd.read_csv("../input/covid19-in-india/covid_19_india.csv")  
print("Successfully imported data into console" )
ind.head()

# %%
ind = ind.drop(['ConfirmedIndianNational','ConfirmedForeignNational'],axis = 1)
ind

# %%
ind = ind.drop(['Sno','Time'],axis = 1)
ind

# %%
ind = ind.drop(['State/UnionTerritory','Cured','Confirmed'], axis = 1)
ind

# %%
ind.dropna(inplace = True)
ind

# %%
ind1 = ind.groupby('Date').sum()
ind1.reset_index(inplace = True, drop = False)
ind1

# %%
fig = plt.figure(figsize=(18, 6))
plt.plot(ind1.Date,ind1.Deaths)

# %% [markdown]
# US DATA SET

# %% [markdown]
# Cleaning the Data

# %%
df_us = pd.read_csv("../input/covid19-in-usa/us_states_covid19_daily.csv")  
print("Successfully imported data into console" )
df_us.head()

# %%
df_us = df_us.drop(['totalTestResultsSource','hospitalizedCurrently','hospitalizedCumulative'], axis = 1)
df_us

# %%
df_us = df_us.drop(['inIcuCurrently','inIcuCumulative','onVentilatorCurrently','posNeg','hospitalizedIncrease'], axis = 1)
df_us

# %%
df_us = df_us.drop(['probableCases','onVentilatorCumulative','recovered','dataQualityGrade','totalTestResultsIncrease','pending'], axis = 1)
df_us

# %%
df_us = df_us.drop(['lastUpdateEt','dateModified','checkTimeEt','hospitalized','negativeIncrease','deathIncrease'], axis = 1)
df_us

# %%
df_us = df_us.drop(['dateChecked','totalTestsViral','positiveTestsViral','negativeTestsViral','fips','positiveIncrease'], axis = 1)
df_us

# %%
df_us = df_us.drop(['positiveCasesViral','deathConfirmed','deathProbable','totalTestEncountersViral','totalTestsAntigen','positiveTestsAntigen','hash','commercialScore','negativeRegularScore','negativeScore','positiveScore','score','grade'], axis = 1)
df_us

# %%
df_us = df_us.drop(['totalTestsPeopleViral','totalTestsAntibody','positiveTestsAntibody','negativeTestsAntibody','totalTestsPeopleAntibody','positiveTestsPeopleAntibody','negativeTestsPeopleAntibody','totalTestsPeopleAntigen','positiveTestsPeopleAntigen'], axis = 1)
df_us

# %% [markdown]
# Make copies

# %%
df_us1 = df_us.copy()
df_us1

# %% [markdown]
# Drop empty values

# %%
df_us1.dropna(inplace = True)

# %%
df_us1

# %% [markdown]
# Plotting
