# %% [markdown]
# # Machine Learning Algorithm - Regression(SLR)1

# %% [markdown]
# #### Implementation using Python (NumPy, Pandas, Matplotlib, Seaborn & Scikit-Learn)

# %% [markdown]
# #### 1- import libraries

# %%
import numpy as np 
import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))


        
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib as pl
import sklearn

from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %% [markdown]
# #### 2- import dataset

# %%
dataset = pd.read_csv('/kaggle/input/headbrain/headbrain.csv')

# %%
dataset.shape

# %%
dataset.head()

# %%
dataset.tail()

# %%
# Checking for null values
# ------------------------

dataset.isnull().sum()

# %%
dataset['Age Range'].max()

# %%
dataset['Age Range'].min()

# %%
sns.scatterplot( data = dataset, x="Head Size(cm^3)", y="Brain Weight(grams)")
plt.show()

# %%
sns.lmplot(x='Head Size(cm^3)', y='Brain Weight(grams)', hue = 'Gender', data = dataset)
plt.show()

# %%
sns.lmplot(x='Head Size(cm^3)', y= 'Brain Weight(grams)', hue= 'Age Range', data= dataset)
plt.show()

# %%
sns.regplot(x=dataset['Head Size(cm^3)'], y=dataset['Brain Weight(grams)'])
plt.show()

# %%
dataset.describe()

# %%
dataset.info()

# %%
X = dataset.iloc[: ,2].values   #Features
y = dataset.iloc[: ,3].values   #Targets

# %%
# plot the imput data
# -------------------


plt.scatter(X,y, color = 'purple', label = 'Data Points')
plt.xlabel('Head size in cm3')
plt.ylabel('Brain Weight weight in grams')
plt.legend()


plt.show()

# %%
# from sklearn.linear_model import LinearRegression

# %%
# Simple Linear Regression using Sklearn
# --------------------------------------

model = LinearRegression()

# %% [markdown]
# ##### Link: https://scikit-learn.org/stable/modules/linear_model.html#ordinary-least-squares

# %%
X.shape

# %%
X = X.reshape(len(X), 1)     # We cannot use rank 1 matrices in sklearn so we have to reshape

# %%
X.shape

# %%
# model Fting 
# -----------

model.fit(X,y)

# %%
model.coef_

# %%
model.intercept_

# %%
# Model Prediction
# ----------------

y_pred = model.predict(X)

# %%
# y_pred

# %%
# Visualising: Plotting Values and Regression Line
# -------------------------------------------------
# Ploting Values 
plt.scatter(X, y, color='green', label='Scatter Points')


# Ploting Regression Line 
plt.plot(X, y_pred,  color = 'blue', label = 'Regression Kine')

plt.title('Head Size VS Brain Weight')
plt.xlabel('Head Size(cm^3)')
plt.ylabel('Bran Weight(grams)')
plt.legend()
plt.show()

# %% [markdown]
# #### R–squared value is the statistical measure to show how close the data are to the fitted regression line.

# %%
model.score(X,y)

# %%
# from sklearn.metrics import r2_score

# %%
# Model Evaluation
# ................

r_squared_score = r2_score(y, y_pred)   # R2 (Coefficient of Sata Matrics) regression score function

# %%
print((r_squared_score * 100).round(2), "%")
