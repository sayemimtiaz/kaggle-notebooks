# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('../input/water-potability/water_potability.csv')

# %%
df.head(5)

# %%
df.isnull().sum()

# %%
df['ph']=df['ph'].replace(np.NaN , df['ph'].mean())

# %%
df.head()

# %%
df.isnull().sum()

# %%
df['Sulfate']=df['Sulfate'].replace(np.NaN , df['Sulfate'].mean())

# %%
df['Trihalomethanes']=df['Trihalomethanes'].replace(np.NaN , df['Trihalomethanes'].mean())

# %%
df.head(25)

# %%
df.isnull().sum()

# %%
df['ph']=df['ph'].apply(lambda num : round(num,3))
df['Hardness']=df['Hardness'].apply(lambda num : round(num,3))
df['Solids']=df['Solids'].apply(lambda num : round(num,3))
df['Chloramines']=df['Chloramines'].apply(lambda num : round(num,3))
df['Sulfate']=df['Sulfate'].apply(lambda num : round(num,3))
df['Conductivity']=df['Conductivity'].apply(lambda num : round(num,3))
df['Organic_carbon']=df['Organic_carbon'].apply(lambda num : round(num,3))
df['Trihalomethanes']=df['Trihalomethanes'].apply(lambda num : round(num,3))
df['Turbidity']=df['Turbidity'].apply(lambda num : round(num,3))

# %%
df[-10:]

# %%
Y=df['Potability']

# %%
df=df.drop('Potability',axis=1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df, Y, test_size=0.3, random_state=0)
lr = LogisticRegression()
lr.fit(X_train, y_train)

# %% [markdown]
# .score(X_val, y_val)

# %%
y_pred = lr.predict(X_test)
print('Accuracy of logistic regression classifie: {:.2f}'.format(lr.score(X_test, y_test)))

# %%
import pickle
with open('water.pickle','wb') as f:
    pickle.dump(lr,f)

# %%
t=lr.predict([[7.081,204.890,20791.319,7.300,368.516,564.309,10.380,86.991,2.963]])
print(t)

# %%
t=lr.predict([[4.373,200.087,17622.745,17.548,333.776,464.526,11.083,55.435,4.906]])
print(t)

# %%
t=lr.predict([[3.809,13.553,1732.802,6.061,33.776,32.450,19.903,66.396,2.798]])
print(t)

# %%
import xgboost

# %%
np.random.seed(42)
xg = xgboost.XGBClassifier()
xg.fit(X_train, y_train)
y_preds = xg.predict(X_test)
y_preds

xg.score(X_test, y_test)

# %%
xf=np.array([3.809,13.553,1732.802,6.061,33.776,32.450,19.903,66.396,2.798]).reshape((1,-1))
t=xg.predict(xf)
print(t)

# %% [markdown]
# 7.875,195.102,17404.177,7.509,333.776,327.460,16.140,78.698,2.309

# %%
xf=np.array([7.875,195.102,17404.177,7.509,333.776,327.460,16.140,78.698,2.309]).reshape((1,-1))
t=xg.predict(xf)
print(t)

# %%
import pickle
with open('waterxgb.pickle','wb') as f:
    pickle.dump(xg,f)

# %%
df.columns
