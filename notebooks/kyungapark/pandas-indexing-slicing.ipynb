# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('../input/ibm-watson-marketing-customer-value-data/WA_Fn-UseC_-Marketing-Customer-Value-Analysis.csv')

# %%
df

# %% [markdown]
# 9134 행 × 24 열을 가진 데이터 프레임으로, 원본 데이터는 행 인덱스가 없으나 데이터프레임으로 불러오니 자동으로 정수형 인덱스가 생겼다.

# %% [markdown]
# # 데이터프레임 정보 확인하기

# %%
# 맨 위 5줄을 보여줌
df.head()

# %%
# 맨 아래 5줄을 보여줌
df.tail()

# %%
# 컬럼명 확인
df.columns

# %%
#인덱스 확인
df.index

# %%
# 데이터프레임의 데이터 유형(종류) 확인
df.dtypes

# %% [markdown]
# object(문자열 등 객체) 16개, float64(실수형) 2개, int(정수형) 6개이다.

# %%
# 빈값이 있는 지 확인하기
df.isnull()

# %% [markdown]
# isnull은 빈값을 보여주는 함수이다. 만약 빈값이 있다면 True를 반환한다.

# %%
df.notnull()

# %%
# 컬럼명, 컬럼개수, 빈값, 데이터 타입 등 데이터 프레임에 대한 전반적인 정보
df.info()

# %%
# 숫자형 데이터(컬럼)들의 기본통계
df.describe()

# %% [markdown]
# 숫자형 데이터들의 수(카운트), 평균, 표준편차, 최소값, 최대값 등 기본적인 데이터를 확인할 수 있다. 물론 개별 컬럼들에 대해 통계를 구하는 것도 가능하다.

# %%
# 개별 컬럼의 기본 통계
df['Customer Lifetime Value'].describe()

# %%
# 개별 컬럼의 평균
df['Customer Lifetime Value'].mean()

# %%
# 컬럼별 유니크값 종류  --> 보험증서를 1개 가진 경우부터 9개까지 가진 경우가 있다
df['Number of Policies'].unique()

# %%
# 컬럼별 유니크값 개수
df['Number of Policies'].nunique()

# %%
# 개별 컬럼의 유니크값을 종류별로 세기 --> 보험증서를 1~3를 가진 경우가 가장 많다. 
df['Number of Policies'].value_counts()

# %% [markdown]
# # 고급 인덱싱 & 슬라이싱

# %%
# 인덱스가 3인 행 출력
df.loc[3]

# %%
# 인덱스가 3인 행의 Gender 값
df.loc[3, 'Gender']

# %%
# 전체 행에서 Months Since Policy Inception에서부터 Total Claim Amount까지
df.loc[:, 'Months Since Policy Inception':'Total Claim Amount']

# %%
# 전체 행에서 State, Gender, Education 값
df.loc[:, ['State', 'Gender', 'Education']]

# %%
# 앞에서 1000개 행 출력  ---> 0부터 999행까지 출력
df.iloc[0:1000]

# %%
#전체 행에서 첫 번째 열의 값
df.iloc[:, 0]
