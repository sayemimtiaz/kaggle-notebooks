# %%
from shutil import copyfile

# Just copy over a .wav file from the input to the output to see if we can play it.
audio_file_src = '../input/birdsong-resampled-train-audio-00/aldfly/XC154310.wav'
audio_file_dest = '../working/test.wav'
copyfile(audio_file_src, audio_file_dest)
