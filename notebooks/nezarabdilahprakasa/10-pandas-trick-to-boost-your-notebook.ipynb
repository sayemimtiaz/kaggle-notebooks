# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Import Module

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1.Version Check

# %%
pd.__version__

# %%
pd.show_versions()

# %% [markdown]
# # 2. Create Data Frame

# %%
data=pd.DataFrame({'col_1':[100,200,121],'col_2':[200,430,210]})
data

# %%
data1=pd.DataFrame(np.random.rand(4,10))
data1

# %%
data1=pd.DataFrame(np.random.rand(4,10), columns=list('abcdefghij'))
data1

# %% [markdown]
# # 3. Rename Columns

# %%
data

# %%
data.rename({'col_1':'Tinggi', 'col_2':'Berat'}, axis=1)

# %%
data.columns=['Rasa','Bau']
data

# %%
data.add_prefix('Test_')

# %%
data.add_suffix("_Hop")

# %% [markdown]
# # 4. Reverse Row Order

# %%
data=pd.read_csv("../input/happiness-and-alcohol-consumption/HappinessAlcoholConsumption.csv")
data

# %%
data.loc[::-1].head(10)

# %%
data.loc[::-1].reset_index(drop=True).head()   #To reset index

# %% [markdown]
# # 5. Reverse Column

# %%
data.loc[:,::-1].head()

# %% [markdown]
# # 6. Select Columns by Data Type

# %%
data.dtypes

# %%
data.select_dtypes(include='number').head()

# %%
data.select_dtypes(include='object').head()

# %%
data.select_dtypes(include=['number','object','category','datetime']).head()

# %%
data.select_dtypes(exclude='number').head()

# %% [markdown]
# # 7. Convert String to Numbers

# %%
df=pd.DataFrame({'col_one':['1.1','2.2','3.2'], 'col_two':['2.1','2.5','0']})
df

# %%
df.dtypes

# %%
df.astype({'col_one' : 'float', 'col_two':'float'}).info()

# %%
 pd.to_numeric(df.col_two, errors='coerce').fillna(1) #If wanna finalna  using 1

# %% [markdown]
# # 8. Filter Data by Multiple Categories

# %%
data.head()

# %%
data.Country.unique()

# %%
data[(data.Country=='Benin')| (data.Country=='Syria')|(data.Country=='Madagascar')|(data.Hemisphere=="south")].head()

# %%
#Using is in
data[data.Country.isin(['Chile','Uruguay'])].head()

# %%
#Inverse
data[~data.Country.isin(['Argentina','Australia'])].head()

# %% [markdown]
# # 9. Split String into Multiple Columns

# %%
df=pd.DataFrame({'name':['Roberth Jonshon Do','Alan Karcia'], 'location':['Jakarta Barat','Ci Rebon']})
df

# %%
df.name.str.split(' ', expand=True)

# %%
df[['First','Second','Tree']]=df.name.str.split(' ', expand=True)
df

# %%
df['city']=df.location.str.split(' ', expand=True)[0]
df

# %% [markdown]
# # 10. Agregate by Multipe functions

# %%
data

# %%
data[data.Country=='Syria'].HDI.sum()

# %%
data.groupby('Hemisphere').HDI.sum()

# %%
data.groupby('Hemisphere').HDI.agg(['sum','count','min','max']).head()

# %% [markdown]
# # 11. Pivot Tabel

# %%
data.pivot_table(index='Hemisphere',columns='Country', values='Beer_PerCapita', aggfunc='count').T

# %%
data.pivot_table(index='Hemisphere',columns='Country', values='Beer_PerCapita', aggfunc='mean').T
