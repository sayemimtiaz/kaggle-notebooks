# %% [markdown]
# In this experiment I will try to find the most aggressive kinds of dogs in the top 5 color categories

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

# Any results you write to the current directory are saved as output.

data = pd.read_csv('../input/Health_AnimalBites.csv') 

colorData = data.color.value_counts()

print(colorData[0:5])

# %% [markdown]
# Well,Now I will explore these 5 categories and see which species are more dominant

# %%
proc_data = data[data.color=='BLACK'].BreedIDDesc.value_counts()

dogSpecies = list(proc_data.keys())

corrCount = list(proc_data[proc_data.keys()])

dogSpecies = dogSpecies[0:5]
corrCount = corrCount[0:5]

y_pos = np.arange(len(dogSpecies))

plt.bar(y_pos,corrCount)

plt.xticks(y_pos,dogSpecies)

plt.show()

# %% [markdown]
# I Guess this goes to show that in Dogs of the black color,Labrador retrievers are more aggressive than pitbulls

# %%
proc_data = data[data.color=='BROWN'].BreedIDDesc.value_counts()

dogSpecies = list(proc_data.keys())

corrCount = list(proc_data[proc_data.keys()])

dogSpecies = dogSpecies[0:5]
corrCount = corrCount[0:5]

y_pos = np.arange(len(dogSpecies))

plt.bar(y_pos,corrCount)

plt.xticks(y_pos,dogSpecies)

plt.show()

# %% [markdown]
# In the brown colored category,pitbulls win by a huge margin over the others

# %%
proc_data = data[data.color=='WHITE'].BreedIDDesc.value_counts()

dogSpecies = list(proc_data.keys())

corrCount = list(proc_data[proc_data.keys()])

dogSpecies = dogSpecies[0:5]
corrCount = corrCount[0:5]

y_pos = np.arange(len(dogSpecies))

plt.bar(y_pos,corrCount)

plt.xticks(y_pos,dogSpecies)

plt.show()

# %% [markdown]
# While Labrador retrievers are nowhere to be seen in this case, we see the shih tzu, but its still losing by a large margin to the all so aggressive pitbull

# %%
proc_data = data[data.color=='BLK WHT'].BreedIDDesc.value_counts()

dogSpecies = list(proc_data.keys())

corrCount = list(proc_data[proc_data.keys()])

dogSpecies = dogSpecies[0:5]
corrCount = corrCount[0:5]

y_pos = np.arange(len(dogSpecies))

plt.bar(y_pos,corrCount)

plt.xticks(y_pos,dogSpecies)

plt.show()

# %% [markdown]
# Well, return of the labrador retriver.
# I will make a wild assumption that there are no labrador retrievers that have white fur.I will verify this later.

# %%
proc_data = data[data.color=='TAN'].BreedIDDesc.value_counts()

dogSpecies = list(proc_data.keys())

corrCount = list(proc_data[proc_data.keys()])

dogSpecies = dogSpecies[0:5]
corrCount = corrCount[0:5]

y_pos = np.arange(len(dogSpecies))

plt.bar(y_pos,corrCount)

plt.xticks(y_pos,dogSpecies)

plt.show()

# %% [markdown]
# The chichauhua suddenly comes in the second place.
#
# So,we can see that, only black labrador retrievers ar more aggressive than black pitbulls, whereas pitbulls have the majority win in all the other cases
