# %% [markdown]
# Importing the libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# Importing the dataset

# %%
dataset = pd.read_csv('../input/red-wine-dataset/wineQualityReds.csv')
# Removing the unnecessary column
dataset.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %% [markdown]
# Seprating the dataset into independent and dependent variables

# %%
X = X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1:].values

# %% [markdown]
# Spliting the dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test  = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# Applying the feature scaling

# %%
from sklearn.preprocessing import StandardScaler
X_sc = StandardScaler()
y_sc = StandardScaler()
X_train = X_sc.fit_transform(X_train)
y_train = y_sc.fit_transform(y_train)

# %% [markdown]
# Training the dataset

# %%
from sklearn.svm import SVR
regrassor = SVR(kernel = 'rbf')
regrassor.fit(X_train, y_train)

# %% [markdown]
# Predicting the result

# %%
y_pred = regrassor.predict(X_sc.transform(X_test))
y_pred = y_sc.inverse_transform(y_pred)

# %%
y_test = y_test.flatten()

# %% [markdown]
# Visualizing the result

# %%
df = pd.DataFrame({'Predicted value': y_pred, 'Real Value': y_test})
df
