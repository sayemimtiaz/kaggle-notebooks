# %% [markdown]
# # Introduction
# This dataset includes student's gender, which kind of lunch they have before exam, if they preparing the exam, which level of education their parents have, their grops where they belongs, math's scores, writing's scores and reading's scores. I created this notebook for try to unravel the link between these features.
#
#  <font color = "blue">
#  Content:
#
#  1. [Load and check data](#1)
#  2. [Variable Descriprion](#2)
#     * [Numerical Variable ](#3)
#         * [Math Scores](#4)
#         * [Reading Score](#5)
#         * [Writing Score](#6)
#     * [Categorical Variable](#7)
#         * [Race/ethnicity](#8)
#         * [Gender](#9)
#         * [Lunch](#10)
#         * [Parental Level of Education](#11)
#         * [Test Preparation Course](#12)
#  3. [Introduction Step to Feature Engineering](#13)
#     * [Change Columns Name](#14)
#     * [Add New Gender Values](#15)
#     * [Add New Lunch Column](#16)
#     * [Add New Preparation Column](#17)
#     * [Add New Parent's Education Column](#18)
#     * [Add New Group Values](#19)
#  4. [Basic Data Analysis](#20)
#  5. [Outlier Detection](#21)
#  6. [Missing Value](#22)
#  7. [Visualization](#23)
#     * [Correlation and HeatMap](#24)
#     * [Reading and Writing Score Line Plot](#25)
#     * [Reading and Math Score Line Plot](#26)
#     * [Math and Writing Score Line Plot](#27)
#     * [Reading and Math Score Scatter Plot](#28)
#     * [Writing and Math Score Scatter Plot](#29)
#     * [Reading and Writing Score Scatter Plot](#30)
#     * [Math Scores Histogram](#31)
#     * [Reading Scores Histogram](#32)
#     * [Writing Scores Histogram](#33)
#     * [Math Score BoxPlot](#34)
#     * [Reading Score BoxPlot](#35)
#     * [Writing Score BoxPlot](#36)

# %% [markdown]
# <a id="1"> </a><br>
# ## Load and Check Data

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
data = pd.read_csv('/kaggle/input/students-performance-in-exams/StudentsPerformance.csv')

# %%
data.columns

# %%
data.head()

# %%
data.describe()

# %% [markdown]
# <a id="2"> </a><br>
# ## Variable Descriprion
# * math Score
# * reading Score
# * writing Score
# * gender
# * race/ethnicity
# * parental level of education
# * lunch
# * test preparation course

# %%
data.info()

# %% [markdown]
# * int64(3): mathScore, readingScore, writingScore
# * object(5): gender, group, parentEdu, lunch, prep

# %% [markdown]
# <a id="3"> </a><br>
# ## Numerical Variable

# %% [markdown]
# <a id="4"> </a><br>
# ****
# ### There is Math Scores Histogram

# %%
data['math score'].plot(kind='hist',bins = 50,figsize = (8,8))
plt.show()

# %% [markdown]
# ****
# <a id="5"> </a><br>
# ### There is Reading Scores Histogram

# %%
data['reading score'].plot(kind = 'hist',bins = 50,figsize = (8,8), color='red')
plt.show()

# %% [markdown]
# ****
# <a id="6"> </a><br>
# ### There is Writing Scores Histogram

# %%
data['writing score'].plot(kind = 'hist',bins = 50,figsize = (8,8), color='g')
plt.show()

# %% [markdown]
# <a id="7"> </a><br>
# ## Categorical Variable

# %% [markdown]
# ****
# <a id="8"> </a><br>
# ### There is Race/ethnicity

# %%
print(data['race/ethnicity'].value_counts(dropna=False))
sns.countplot(x="race/ethnicity", data = data)
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# ****
# <a id="9"> </a><br>
# ### There is Gender

# %%
print(data['gender'].value_counts(dropna=False))
sns.countplot(x="gender", data = data)
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# ****
# <a id="10"> </a><br>
# ### There is Lunch

# %%
print(data['lunch'].value_counts(dropna=False))
sns.countplot(x="lunch", data = data)
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# ****
# <a id="11"> </a><br>
# ### There is Parental Level of Education

# %%
print(data['parental level of education'].value_counts(dropna=False))
sns.countplot(x="parental level of education", data = data)
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# ****
# <a id="12"> </a><br>
# ### There is Test Preparation Course

# %%
print(data['test preparation course'].value_counts(dropna=False))
sns.countplot(x="test preparation course", data = data)
plt.xticks(rotation = 60)
plt.show()

# %%
data.corr()

# %% [markdown]
# * In this correlation, lunch or preparation to exam etc. are not shown.
# * In the next step, I will do feature engineering so that we will get a more comprehensive correlation.

# %% [markdown]
# <a id="13"> </a><br>
# ## Feature Engineering

# %%
data.head()

# %% [markdown]
# <a id="14"> </a><br>
# ### Change columns name for easier coding

# %%
data = data.rename(columns={"math score": "mathScore", "reading score": "readingScore", "writing score": "writingScore"})
data = data.rename(columns={"race/ethnicity": "group", "test preparation course": "prep"})
data = data.rename(columns={"parental level of education": "parentEdu"})
data.head(10)

# %% [markdown]
# The Columns's Changes:
#
# * race/ethnicity => group
# * parental level of education => parentEdu
# * test preparation course => prep
# ****

# %% [markdown]
# <a id="15"> </a><br>
# ### Add New Gender Columns for easier corr

# %%
data['newGender'] = data['gender'].apply(lambda x: 0 if x == 'male' else 1)
data.head(10)

# %% [markdown]
# The Gender's Changes:
#
# * male => 0
# * female => 1
# ****

# %% [markdown]
# <a id="16"> </a><br>
# ### Add New Lunch Column for easier corr

# %%
sns.countplot(x="lunch", data = data)
plt.xticks(rotation = 60)
plt.show()

# %%
data['newLunch'] = data['lunch'].apply(lambda x: 0 if x == 'standard' else 1)
data.head(10)

# %% [markdown]
# The Lunch's Changes:
#
# * standard => 0
# * free => 1
# ****

# %% [markdown]
# <a id="17"> </a><br>
# ### Add New Prep Column for easier corr

# %%
sns.countplot(x="prep", data = data)
plt.xticks(rotation = 60)
plt.show()

# %%
data['newPrep'] = data['prep'].apply(lambda x: 0 if x == 'none' else 1)
data.head(10)

# %% [markdown]
# The Lunch's Changes:
#
# * none => 0
# * completed => 1
# ****

# %% [markdown]
# <a id="18"> </a><br>
# ### Add New ParentEdu Column for easier corr

# %%
sns.countplot(x="parentEdu", data = data)
plt.xticks(rotation = 60)
plt.show()

# %%
ax = sns.pointplot(x="readingScore", y="parentEdu",data=data)

# %%
ax = sns.pointplot(x="writingScore", y="parentEdu",data=data)

# %%
ax = sns.pointplot(x="mathScore", y="parentEdu",data=data)

# %%
def flag_df(df):

    if (df['parentEdu'] =='some high school') or (df['parentEdu'] =='high school'):
        return 0
    elif (df['parentEdu'] =="associate's degree") or (df['parentEdu'] =='some college'):
        return 1
    elif (df['parentEdu'] =="bachelor's degree"):
        return 2
    elif (df['parentEdu']=="master's degree"):
        return 3

# %%
data['newParentEdu'] = data.apply(flag_df, axis = 1)

data.head(10)

# %% [markdown]
# The New Column "ParentEduNew":
#
# * some high school or high school => 0
# * associate's degree or some college => 1
# * bachelor's degree => 2
# * master's degree => 3
#
# ****

# %% [markdown]
# <a id="19"> </a><br>
# ### Add New Group Columns for easier corr

# %%
sns.countplot(x="group", data = data)
plt.xticks(rotation = 60)
plt.show()

# %%
def group_df(df):

    if (df['group'] =='group A'):
        return '0'
    elif (df['group'] =='group B'):
        return '1'
    elif (df['group'] =='group C'):
        return '2'
    elif (df['group']=='group D'):
        return '3'
    elif (df['group']=='group E') :
        return '4'

# %%
data['newGroup'] = data.apply(group_df, axis = 1)

data.head(10)

# %% [markdown]
# The Group's Changes:
#
# * group A => 0
# * group B => 1
# * group C => 2
# * group D => 3
# * group E => 4
# ****

# %%
data.info()

# %% [markdown]
# <a id="20"> </a><br>
# ## BASIC DATA ANALYSIS
# ****
# * Gender - MathScore
# * Gender - ReadingScore
# * Gender - WritingScore
# ****
# * Group  - WritingScore
# * Group  - ReadingScore
# * Group  - MathScore
# ****
# * ParentEdu - MathScore
# * ParentEdu - ReadingScore
# * ParentEdu - WritingScore
# ****
# * Prep - WritingScore
# * Prep - ReadingScore
# * Prep - MathScore
# ****
# * Lunch - MathScore
# * Lunch - ReadingScore
# * Lunch - WritingScore
# ****

# %%
data[["gender","mathScore"]].groupby(["gender"], as_index = False).mean().sort_values(by="mathScore",ascending = False)

# %%
data[["gender","readingScore"]].groupby(["gender"], as_index = False).mean().sort_values(by="readingScore",ascending = False)

# %%
data[["gender","writingScore"]].groupby(["gender"], as_index = False).mean().sort_values(by="writingScore",ascending = False)

# %% [markdown]
# ****

# %%
data[["group","writingScore"]].groupby(["group"], as_index = False).mean().sort_values(by="writingScore",ascending = False)

# %%
data[["group","readingScore"]].groupby(["group"], as_index = False).mean().sort_values(by="readingScore",ascending = False)

# %%
data[["group","mathScore"]].groupby(["group"], as_index = False).mean().sort_values(by="mathScore",ascending = False)

# %% [markdown]
# *****

# %%
data[["parentEdu","mathScore"]].groupby(["parentEdu"], as_index = False).mean().sort_values(by="mathScore",ascending = False)

# %%
data[["parentEdu","readingScore"]].groupby(["parentEdu"], as_index = False).mean().sort_values(by="readingScore",ascending = False)

# %%
data[["parentEdu","writingScore"]].groupby(["parentEdu"], as_index = False).mean().sort_values(by="writingScore",ascending = False)

# %% [markdown]
# ****

# %%
data[["prep","writingScore"]].groupby(["prep"], as_index = False).mean().sort_values(by="writingScore",ascending = False)

# %%
data[["prep","readingScore"]].groupby(["prep"], as_index = False).mean().sort_values(by="readingScore",ascending = False)

# %%
data[["prep","mathScore"]].groupby(["prep"], as_index = False).mean().sort_values(by="mathScore",ascending = False)

# %% [markdown]
# ****

# %%
data[["lunch","mathScore"]].groupby(["lunch"], as_index = False).mean().sort_values(by="mathScore",ascending = False)

# %%
data[["lunch","readingScore"]].groupby(["lunch"], as_index = False).mean().sort_values(by="readingScore",ascending = False)

# %%
data[["lunch","readingScore"]].groupby(["lunch"], as_index = False).mean().sort_values(by="readingScore",ascending = False)

# %% [markdown]
# ****

# %% [markdown]
# <a id="21"> </a><br>
#
# ## Outlier Detection

# %%
def detect_outliers(df,features):
    outlier_indices = []
    
    for c in features:
        # 1st quartile
        Q1 = np.percentile(df[c],25)
        # 3rd quartile
        Q3 = np.percentile(df[c],75)
        # IQR
        IQR = Q3 - Q1
        # Outlier step
        outlier_step = IQR * 1.5
        # detect outlier and their indeces
        outlier_list_col = df[(df[c] < Q1 - outlier_step) | (df[c] > Q3 + outlier_step)].index
        # store indeces
        outlier_indices.extend(outlier_list_col)
    
    outlier_indices = Counter(outlier_indices)
    multiple_outliers = (i for i, v in outlier_indices.items() if v > 2)
    
    return multiple_outliers

# %%
data.loc[detect_outliers(data,["mathScore","writingScore","readingScore"])]

# %%
data = data.drop(detect_outliers(data,["mathScore","writingScore","readingScore"]),axis = 0).reset_index(drop = True)
data.loc[detect_outliers(data,["mathScore","writingScore","readingScore"])]

# %% [markdown]
# <a id="22"> </a><br>
# ## Missing Value

# %%
data.columns[data.isnull().any()]

# %%
data.isnull().sum()

# %% [markdown]
# <a id="23"> </a><br>
# ## VIS

# %% [markdown]
# ****
# <a id="24"> </a><br>
# #### Correlation and HeatMap

# %%
data.corr()

# %%
f,ax = plt.subplots(figsize=(13, 13))
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %%
list = ['mathScore','readingScore','writingScore','gender','group']
f,ax = plt.subplots(figsize=(8,8))
sns.heatmap(data[list].corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %% [markdown]
# * As seen as from the heatmap; we could say that "gender", "parent's educ. situt", "preapering to exam" and "type of the lunch" do not affect math, reading or writing score too much.
# ****

# %% [markdown]
# <a id="25"> </a><br>
# #### Reading and Writing Score Line Plot

# %%
data.readingScore.plot(kind = 'line', color = 'red',label = 'Reading Score',linewidth=1,alpha = 1,grid = True,linestyle = ':')
data.writingScore.plot(color='g', label='Writing Score',linewidth=1,alpha=0.5,grid=True,linestyle='-.')
plt.legend(loc='upper right')    
plt.xlabel('x axis')    
plt.ylabel('y axis')
plt.title('Line Plot between Reading and Writing Score') 
plt.show()

# %% [markdown]
# ****
# <a id="26"> </a><br>
# #### Reading and Math Score Line Plot

# %%
data.readingScore.plot(kind = 'line', color = 'red',label = 'Reading Score',linewidth=1,alpha = 2,grid = True,linestyle = ':')
data.mathScore.plot(color='blue', label='Math Score',linewidth=1,alpha=0.5,grid=True,linestyle='-.')
plt.legend(loc='upper right')    
plt.xlabel('x axis')    
plt.ylabel('y axis')
plt.title('Line Plot between Reading and Math Score') 
plt.show()

# %% [markdown]
# ****

# %% [markdown]
# <a id="27"> </a><br>
# #### Math and Writing Score Line Plot

# %%
data.mathScore.plot(kind = 'line', color = 'blue',label = 'Math Score',linewidth=1,alpha = 1,grid = True,linestyle = ':')
data.writingScore.plot(color='g', label='Writing Score',linewidth=1,alpha=0.5,grid=True,linestyle='-.')
plt.legend(loc='upper right')    
plt.xlabel('x axis')    
plt.ylabel('y axis')
plt.title('Line Plot between Math and Writing Score') 
plt.show()

# %% [markdown]
# ****

# %% [markdown]
# Let's Try preparation and writingScore

# %%
data.plot(kind='scatter', x='writingScore', y='newPrep',alpha = 0.5,color = 'red')
plt.xlabel('Writing Score')             
plt.ylabel('Prep')
plt.title('Writing and Prep Scatter Plot')
plt.show()

# %% [markdown]
# ****

# %% [markdown]
# <a id="28"> </a><br>
# #### Reading Score & Math Score Scatter Plot

# %%
data.plot(kind='scatter', x='readingScore', y='mathScore',alpha = 0.5,color = 'purple')
plt.xlabel('Reading Score')              
plt.ylabel('Math Score')
plt.title('Reading and Math Scatter Plot')
plt.show()

# %% [markdown]
# ****

# %% [markdown]
# <a id="29"> </a><br>
# #### Writing Score & Math Score Scatter Plot

# %%
data.plot(kind='scatter', x='writingScore', y='mathScore',alpha = 0.5,color = 'cyan')
plt.xlabel('Writing Score')             
plt.ylabel('Math Score')
plt.title('Writing and Math Scatter Plot')
plt.show()

# %% [markdown]
# ****

# %% [markdown]
# <a id="30"> </a><br>
# #### Reading Score & Writing Score Scatter Plot

# %%
data.plot(kind='scatter', x='readingScore', y='writingScore',alpha = 0.5,color = 'brown')
plt.xlabel('Reading Score')              
plt.ylabel('Writing Score')
plt.title('Writing and Reading Scatter Plot')
plt.show()

# %% [markdown]
# <a id="31"> </a><br>
# ****
# #### Math Score BoxPlot

# %%
data.boxplot(column='mathScore',by = 'gender')
plt.show()

# %% [markdown]
# * gender 0 is male, 1 is female

# %%
data.boxplot(column='mathScore',by = 'lunch')
plt.show()

# %%
data.boxplot(column='mathScore',by = 'newParentEdu')
plt.show()

# %%
data.boxplot(column='mathScore',by = 'parentEdu')
plt.show()

# %%
data.boxplot(column='mathScore',by = 'prep')
plt.show()

# %% [markdown]
# <a id="32"> </a><br>
# ****
# #### Reading Score BoxPlot

# %%
data.boxplot(column='readingScore',by='gender')
plt.show()

# %%
data.boxplot(column='readingScore',by='lunch')
plt.show()

# %%
data.boxplot(column='readingScore',by='newParentEdu')
plt.show()

# %%
data.boxplot(column='readingScore',by='parentEdu')
plt.show()

# %%
data.boxplot(column='readingScore',by='prep')
plt.show()

# %% [markdown]
# <a id="33"> </a><br>
# ****
# #### Writing Score BoxPlot

# %%
data.boxplot(column='writingScore',by='gender')
plt.show()

# %%
data.boxplot(column='writingScore',by='lunch')
plt.show()

# %%
data.boxplot(column='writingScore',by='newParentEdu')
plt.show()

# %%
data.boxplot(column='writingScore',by='parentEdu')
plt.show()

# %%
data.boxplot(column='writingScore',by='prep')
plt.show()

# %% [markdown]
# ****

# %% [markdown]
# <a id="26"> </a><br>
# ### CONCATENATING DATA

# %%
data1 = data['mathScore'].head()
data2= data['readingScore'].head()
data3= data['writingScore'].head()
conc_data_col = pd.concat([data1,data2,data3],axis =1) # axis = 1 : adds dataframes in column
conc_data_col
