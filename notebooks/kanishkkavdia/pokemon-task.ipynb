# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('../input/pokemon/Pokemon.csv')
# df.head(5)
# df.tail(5)
df.describe()
print(df.iloc[0:4])

# %% [raw]
# Strongest  Legendary Pokemons

# %%
df.sort_values(['Legendary','Total'],ascending=False).head(5)

# %% [markdown]
# Strongest Non Legendary Pokemons

# %%
df.sort_values(['Legendary','Total'],ascending=[1,0]).head(5)

# %% [markdown]
# Total Types of Pokemon

# %%
df['Type 1'].unique()

# %% [markdown]
# Total types of fighting pattern

# %%
df['Type 2'].unique()

# %%
# df.groupby(['Type 1','Type 2']).count()
df.groupby(['Type 1','Type 2'])['Total'].describe()

# %% [markdown]
# Strongest Type of Pokemons
# Water has the best Total as well as it has most legendaries.

# %%
new_data=df.groupby(['Type 1']).count()
plot1=new_data.sort_values(['Total'],ascending=False)
print(plot1)
sns.barplot(plot1['#'],plot1.index)

# %% [markdown]
# Best Fighting Style

# %%
new_data2=df.groupby(['Type 2']).count()
plot2=new_data2.sort_values(['Total'],ascending=False)
print(plot2)
sns.barplot(plot2['#'],plot2.index)
