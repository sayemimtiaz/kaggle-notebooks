# %% [markdown]
# This is just attempt to find any correlation between IMDB rating, Gross and Duration of Movies.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

# Any results you write to the current directory are saved as output.

# %%
data = pd.read_csv("../input/movie_metadata.csv")
data.head()

# %%
new_data = pd.DataFrame({'IMDB' : []})

# %%
new_data.IMDB = data.imdb_score

# %%
import matplotlib.pyplot as  plt

# %matplotlib inline

# %%
 new_data.plot.hist()

# %%
new_data = pd.DataFrame({'IMDB' : [], 'Duration' :[], 'Gross' :[]})

# %%
new_data.IMDB = data.imdb_score
new_data.Duration = data.duration
plt.scatter( new_data.Duration, new_data.IMDB)
plt.ylabel('IMDB RATING')
plt.xlabel('Duration of Movie (in sec)')

# %%
import seaborn as sns
sns.regplot( new_data.Duration, new_data.IMDB)

# %%
max_duration =max(new_data.Duration)
max_duration

# %%
new_data['Gross'] = data.gross

# %%
sns.regplot(new_data.Gross, new_data.Duration)

# %%
new_data.fillna(0)

# %%
sns.jointplot("imdb_score","gross",data=data, kind='kde')

# %%
sns.jointplot("duration","imdb_score", data=data, kind='kde')

# %%
sns.jointplot("gross","duration", data= data, kind='kde')

# %%
sns.set(style="ticks")
g = sns.factorplot(x="title_year", y="gross", hue="language", data=data)

# %% [markdown]
# The below trying to analyze data, time vs language and country.

# %%
sns.stripplot(x="title_year", y="language", data=data)

# %%
sns.stripplot(x="title_year", y="country", data=data);

# %% [markdown]
# will continue the analysis further...
