# %% [markdown]
# # I made my project on Google colab. You can see detailed results on __[my GitHub](https://github.com/NikitaBezukhov/Pneumonia_classifier_ResNet18)__.
# # Hope you like it!)
# # Training result weill be presented below:

# %% [markdown]
# ![Screenshot_1.png](attachment:5f595d51-aeeb-4847-917b-b95921ea57ea.png)
# ![Screenshot_6.png](attachment:e2c4378c-5521-4237-849d-16f4436e5f3e.png)
# ![Screenshot_2.png](attachment:9e9e793d-405c-448f-a01f-c24b4ec80533.png)
# ![Screenshot_3.png](attachment:2784cc2a-552b-4a12-bebd-5ffec1d57495.png)

# %% [markdown]
# ## AUC = 97.64, which is a pretty good result. ROC lets us choose different desicion boundary thresholds depending on how many False positives we can afford. But we can also calculate the best threshold as argmin(TPR-(1-FPR)). It will be:
# ![Screenshot_5.png](attachment:fce3e00c-49fa-4215-8ea5-167cf3147352.png)
# ## Metrics with a new threshold:
# ![Screenshot_4.png](attachment:4b37c4de-2717-429f-8857-339b47e8c903.png)
