# %% [markdown]
# ***Name: Shivalika Singh / Enrolment No.: E19CSE420 / Batch: EB01***
# # Lab Assignment 1

# %% [markdown]
# # ***CSV Format***

# %%
import numpy as np 
import pandas as pd

data = pd.read_csv("../input/videogamesales/vgsales.csv")

# %%
print("Type: ",type(data),"\n\n")
print("First 10 entries:\n",data.head(10),"\n\n")
print("Headers: ",data.columns,"\n\n")
print("Data rows: ",data.size,"\n\n")
print("Data types: ",data.dtypes,"\n\n")

# %%
import matplotlib.pyplot as plt

plt.style.use('classic')

plt.hist(data.Year,bins=20)

# %%
plt.hist(data.Genre,bins=20)

# %%
plt.hist(data.Platform,bins=20)

# %% [markdown]
# # ***PKL Format***

# %%
import pickle

file = open("../input/mnistpkl/mnist.pkl",'rb')

train,test,val = pickle.load(file,encoding='bytes')

train_x = pd.DataFrame(train[0])
train_y = pd.DataFrame(train[1])
print(train_x.head,train_y.head)

test_x = pd.DataFrame(test[0])
test_y = pd.DataFrame(test[1])
print(test_x.head,test_y.head)

val_x = pd.DataFrame(val[0])
val_y = pd.DataFrame(val[1])
print(val_x.head,val_y.head)

# %% [markdown]
# # ***Image Format***

# %%
import cv2

image = cv2.cvtColor(cv2.imread('../input/images/img6.jpg'), cv2.COLOR_BGR2RGB)

plt.imshow(image)
plt.show()

# %%
image = cv2.cvtColor(cv2.imread('../input/images/img9.jpg'), cv2.COLOR_BGR2RGB)

plt.imshow(image)
plt.show()

# %% [markdown]
# # ***Video Format***

# %%
import IPython

IPython.display.Video("../input/video1/video.mp4")

# %% [markdown]
# # ***Audio Format***

# %%
import IPython
IPython.display.Audio("../input/audio1/part-2 Audio Extracted.wav")

# %%
# !pip install PyPDF2

# %% [markdown]
# # ***Document Format***

# %%
import PyPDF2
 
file = open('../input/document/Shivalika_E19CSE420(1).pdf', 'rb')
r = PyPDF2.PdfFileReader(file)

for i in range(r.numPages):
    p = r.getPage(i)
    print(p.extractText())
    
file.close()
