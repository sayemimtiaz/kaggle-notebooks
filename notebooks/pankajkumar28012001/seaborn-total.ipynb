# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
iris=sns.load_dataset("iris")
sns.stripplot(x="species",y="petal_length",data=iris)

# %%
df1=pd.read_csv("../input/world-happiness/2015.csv")

# %%
sns.stripplot(x="Family",y="Freedom",data=df1)

# %%
sns.swarmplot(x="Family",y="Generosity",data=df1)

# %%
sns.barplot(x="Family",y="Happiness Score",data=df1)

# %%
sns.countplot(x="Family",data=df1)

# %%
sns.pointplot(x="Family",y="Happiness Score",data=df1)

# %%
df2=df1[0:10]
sns.boxplot(x="Happiness Rank",y="Happiness Score",data=df2)

# %%
sns.violinplot(x="Family",y="Happiness Score",data=df2)

# %%
df3=df2[0:5]

# %%
h=sns.FacetGrid(df3,col="Family",row="Happiness Score")
h

# %%
h.map(plt.hist,"Family")

# %%
sns.lmplot(x="Happiness Score",y="Family",hue="Region",data=df2)

# %%
h2=sns.PairGrid(df3)
h2.map(plt.scatter)

# %%
sns.pairplot(df3)

# %%
i=sns.JointGrid(x="Family",y="Happiness Score",data=df2)
i.plot(sns.regplot,sns.distplot)

# %%
sns.jointplot("Family","Happiness Score",data=df2)

# %%
sns.regplot(x="Happiness Rank",y="Happiness Score",data=df2)

# %%
sns.distplot(df2.Family)

# %%
import numpy as np
uniform_data = np.random.rand(10,10)
ax = sns.heatmap(uniform_data)

# %%
q=sns.barplot(x="Family",y="Happiness Score",data=df2)

# %%
sns.lmplot(x="Happiness Score",y="Family",hue="Region",data=df2)

# %%
q=sns.lmplot(x="Happiness Score",y="Family",hue="Region",data=df2)
q.despine(left=True)

# %%
w=sns.lmplot(x="Happiness Score",y="Family",hue="Region",data=df2)
w.set_ylabels("yy")

# %%
e=sns.lmplot(x="Happiness Score",y="Family",hue="Region",data=df2)
e.set_xlabels("x-axis")

# %%
r=sns.lmplot(x="Happiness Score",y="Family",hue="Region",data=df2)
r.set_xticklabels(rotation=100)

# %%
t=sns.lmplot(x="Happiness Score",y="Family",hue="Region",data=df2)
t.set_axis_labels("x-val","y_val")

# %%
u=sns.lmplot(x="Happiness Score",y="Family",hue="Region",data=df2)
u.set(xlim=(0,10),ylim=(1.2,2))

# %%
sns.lmplot(x="Happiness Score",y="Family",hue="Region",data=df2)
plt.title("title")
plt.ylabel("ylabel")
plt.xlabel("xlabel")
plt.ylim(1,2)
plt.xlim(7,8)
#plt.tight_layout()

# %%
sns.lmplot(x="Happiness Score",y="Family",hue="Region",data=df2)
plt.title("title")
plt.ylabel("ylabel")
plt.xlabel("xlabel")
plt.ylim(1,2)
plt.xlim(7,8)
plt.tight_layout()
plt.show()

# %%
x=np.array([1,2,3,4])
y=np.array([100,200,350,400])
sns.stripplot(x,y)

# %%
x=np.array([1,2,3,4])
y=np.array([100,200,350,400])
sns.set()
sns.stripplot(x,y)

# %%
x=np.array([1,2,3,4])
y=np.array([100,200,350,400])
sns.set_style("whitegrid")
sns.stripplot(x,y)

# %%
x=np.array([1,2,3,4])
y=np.array([100,200,350,400])
sns.set_style("ticks",{"xtick.major.size":10,"ytick.major.size":10})
sns.stripplot(x,y)

# %%
x=np.array([1,2,3,4])
y=np.array([100,200,350,400])
sns.axes_style("whitegrid")
sns.set_style("ticks",{"xtick.major.size":10,"ytick.major.size":10})
sns.stripplot(x,y)

# %%
q=np.array([2,3,4,5])
w=np.array([100,120,130,140])
sns.swarmplot(x,y)
sns.set_context("talk")

# %%
q=np.array([2,3,4,5])
w=np.array([100,120,130,140])
sns.swarmplot(x,y)
sns.set_context("notebook",font_scale=1.5)
