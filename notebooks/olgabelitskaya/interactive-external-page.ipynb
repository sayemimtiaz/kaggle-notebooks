# %%
# %run ../input/python-recipes/cidhtml.py
idhtml('✒️ Interactive Page with Editable Code Lines')

# %%
# %%html
# <div id='smpage' style='border:double slategray;
#      width:710px; height:720px; overflow:auto;
#      padding:10px; background-color:ghostwhite'>
# <iframe id='if2'
# src='https://olgabelitskaya.gitlab.io/deep_learning_projects/DL_PP0_0_SMC.html'
# width='680' height='680'/></div>

# %%
# %run ../input/python-recipes/sage_call.py
idhtml('✒️ Interactive Cells with Editable Code Lines')

# %%
# %sage_coderun 620 200
