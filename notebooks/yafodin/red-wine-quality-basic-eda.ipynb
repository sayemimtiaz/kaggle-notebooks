# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#sklearn packages
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.preprocessing import MinMaxScaler,StandardScaler,LabelEncoder

import warnings 
warnings.filterwarnings("ignore")
#from sklearn grid search cv

# %%
#read the csv file
train=pd.read_csv("/kaggle/input/red-wine-quality-cortez-et-al-2009/winequality-red.csv")
train.head()

# %%
train.info()

# %%
train.columns

# %%
train.isnull().any()

# %%
#now we check how the differnt features impact 
#we check fixid acidy does not help to classify the qulaity
plt.figure(figsize=(16,7))
sns.barplot(x="quality",y="fixed acidity",data=train)

# %%
#now we check how volatile_acidty helps to classify the quality
plt.figure(figsize=(16,7))
sns.barplot(x="quality",y="volatile acidity",data=train)
#so we check the  by increasing the volatile acidity quality decreases

# %%
#now we check the citric acid how it classify the quality
plt.figure(figsize=(16,7))
sns.barplot(x="quality",y="citric acid",data=train)
#as we seen below  by increasing the citric acid qulaity of wine will increase

# %%
#residual sugar  dosen't impact on quality
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'residual sugar', data = train)

# %%
#Composition of chloride also go down as we go higher in the quality of the wine
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'chlorides', data = train)

# %%
#sulfer dioxide
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'free sulfur dioxide', data = train)

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'total sulfur dioxide', data = train)

# %%
#by increasing the amount of sulphates quality increases
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'sulphates', data = train)

# %%
#Alcohol level also goes higher as te quality of wine increases
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'alcohol', data =train)

# %%
sns.boxplot(x="quality",y="citric acid",data=train)

# %%
sns.heatmap(train.corr(),cmap='BuPu')

# %%
train.describe()

# %%
#Preprocessing Data for performing Machine learning algorithms
bins=(2,6.5,8)
groups=["bad","good"]
train['quality']=pd.cut(train["quality"],bins=bins,labels=groups)

# %%
label=LabelEncoder()

# %%
train["quality"]=label.fit_transform(train["quality"])

# %%
train["quality"].value_counts()

# %%
sns.countplot(train["quality"])

# %%
#Now seperate the dataset as response variable and feature variabes
x = train.drop('quality', axis = 1)
y = train['quality']

# %%
x_train,y_train,x_test,y_test=train_test_split(x,y,random_state=4,test_size=0.2)

# %%
#Applying Standard scaling to get optimized result
sc = StandardScaler()
