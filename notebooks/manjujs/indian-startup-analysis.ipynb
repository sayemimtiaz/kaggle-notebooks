# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.

# %%
data=pd.read_csv('../input/startup_funding.csv')
data.head(10)

# %%
data.info()

# %%
data.describe(include='all')

# %%
data.dtypes

# %%
def temp(v):
    try:
        pd.to_datetime(v)
    except:
        print(v)
data['Date'].apply(lambda v:temp(v))

# %%
def temp(v):
    try:
        return pd.to_datetime(v.replace('.','/').replace('//','/'))
    except:
        print(v)
data['Date']=data['Date'].apply(lambda v:temp(v))
data['month_year']=data['Date'].dt.strftime('%Y-%m')
print(data[['Date','month_year']].head())

# %%
data['amount']=data['AmountInUSD'].str.replace(',','').astype(float)

# %%
#Missing values

# %%
import missingno
missingno.matrix(data)

# %%
pd.isnull(data).sum()

# %%
pd.isnull(data).sum()/data.shape[0]*100

# %%
#Outliers
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
q1=data['amount'].quantile(0.25)
q3=data['amount'].quantile(0.75)
iqr=q3-q1
iqr

# %%
lw=q1-1.5*iqr
uw=q3+1.5*iqr
print(lw,uw)

# %%
data.groupby(['month_year']).size().plot.bar(figsize=(12,5),color='steelblue')

# %%
len(data['IndustryVertical'].unique())

# %%
data['IndustryVertical'].value_counts().head(20)

# %%
data['IndustryVertical'].value_counts().head(10).plot.bar(figsize=(15,5),color='steelblue')

# %%
#ConsumerInternet vertical is the vertical with highest number of start ups followed by Technology,eCommerce.Surprisingly there are lesser in fields of e-commerce,healthcare etc.

# %%
len(data['CityLocation'].unique())

# %%
x=data['CityLocation'].value_counts()/data.shape[0]*100
x.head(10).plot.bar(figsize=(15,5),color='steelblue')

# %%
#In 72 cities startups are operating.Bangalore is the hub for start ups as expected followed by Mmbai,New Delhi,Gurgaon.Ahmedabad and Jaipur 
#seems to be not ideal for startups.

# %%
x=data['InvestorsName'].value_counts()/data.shape[0]*100
x.head(10).plot.bar(figsize=(15,5),color='steelblue')

# %%
#Undisclosed investors have made the highest number of invetments.

# %%
len(data['SubVertical'].unique())

# %%
data['SubVertical'].value_counts().head(20)

# %%
x=data['SubVertical'].value_counts()/data.shape[0]*100
x.head(10).plot.bar(figsize=(15,5),color='steelblue')

# %%
#Online pharmacy and food delivery platforms hod the highest count among the sub-verticals.Data analytics platform 
#which is relatively new ,holds relatively good position in the market.

# %%
data['amount'].max()

# %%
data[data.amount==1400000000]

# %%
#From the figure, it is clear that maximum investment happened in 2017 March and May.It was in 2017 March that 
#Industry giants Micrsoft,ebay,Tencent holdings made a whopping investment of 1400000000 USD for e-commerce startup Flipkart.Paytm was also funded during this time.
#There ia decrease during Nov 2016 to July 2017 which may be attributed to demonitisation.

# %%
data['amount'].min()

# %%
data[data['amount']==16000]

# %%
The minimum investment of 16000 was made by Hyderabad Angels(at Startup Heroes event).
