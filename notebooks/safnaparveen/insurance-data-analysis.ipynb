# %% [markdown]
# **Importing libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sn
import sklearn.metrics as sm

# %% [markdown]
# **Reading the insurance file**

# %%
file = pd.read_csv("../input/insurance/insurance.csv")

# %%
file.head()

# %% [markdown]
# ***Checking the null values***

# %%
file.isnull()

# %%
file.isnull().sum()

# %% [markdown]
# [There are no null values, hence searching for outliers](http://)

# %%
file.describe()

# %%
file.dtypes

# %% [markdown]
# > **Finding whether it is symmetrical or skewed and analysing the data**
# *UNIVARIATE ANALYSIS*

# %%
file["age"].plot.hist()

# %%
file["sex"].value_counts().plot.bar()

# %%
file["bmi"].plot.hist()

# %%
file["children"].plot.hist()

# %%
file["smoker"].value_counts().plot.bar()

# %%
file["region"].value_counts().plot.bar()

# %%
file["charges"].plot.hist() # left skewed

# %%
np.log(file["charges"]).plot.hist() # has a symmetrical value *** Using log in calculation

# %% [markdown]
# *analysing the outliers*

# %%
file["bmi"].plot.box()

# %% [markdown]
# *BIVARIATE ANALYSIS*

# %%
corr = file[["age","bmi","children","charges"]].corr()
mask = np.array(corr)
mask[np.tril_indices_from(mask)] = False
fig,ax= plt.subplots()
fig.set_size_inches(20,10)
sn.heatmap(corr, mask=mask,vmax=.9, square=True,annot=True, cmap="YlGnBu")

# %%
file=pd.get_dummies(file)

# %%
x = file.drop("charges",axis=1)

# %%
y = np.log(file["charges"])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.20,random_state = 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)

# %%
predictions = lr.predict(x_test)

# %%
print(predictions)

# %%
r2_value = round(sm.r2_score(y_test, predictions), 2)

# %%
print("R2 score = ",r2_value)
