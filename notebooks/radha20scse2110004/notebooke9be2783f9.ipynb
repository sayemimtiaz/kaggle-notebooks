# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
y=['A','B','C']
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
y=LE.fit_transform(y)

y

# %%
import pandas as pd
dataframe = pd.DataFrame()

dataframe['Name'] = ['Jacky Jackson', 'Steven Stevenson']
dataframe['Age'] = [38, 25]
dataframe['Driver'] = [True, False]

dataframe

# %%
import pandas as pd
train_df = pd.DataFrame()

train_df['Degree'] = ['High School','Masters','Diploma','Bachelors','Phd']

train_df

# %%
import category_encoders as ce
encoder = ce.OrdinalEncoder(cols=['Degree'],return_df=True,mapping=[{'col':'Degree','mapping':{'None':0,'High School':1,'Masters':2,'Bachelors':3,'Diploma':4,'Phd':5}}])
df_train_transformed = encoder.fit_transform(train_df)

df_train_transformed

# %%
scale_mapper = {'None':0,'High School':1,'Diploma':2,'Bachelors':3,'Masters':4,'Phd':5}

train_df.replace(scale_mapper)

# %%
import category_encoders as ce
import pandas as pd
train_df = pd.DataFrame()

train_df['city'] = ['Delhi','Mumbai','Hyderabad','Chennai','Banglore','Chennai','Banglore']

train_df

encoder = ce.OneHotEncoder(cols='city',handle_unknown='return_nan',return_df=True,use_cat_names=True)

train_df

# %%
data_encoded = encoder.fit_transform(train_df)

data_encoded

# %%
data_encoded = pd.get_dummies(data=train_df,drop_first=True)

data_encoded

# %%
import pandas as pd
import numpy as np

df=pd.read_csv('/kaggle/input/glass/glass.csv')

# %%
df.head()

# %%
df.info()

# %%
df.shape

# %%
df.describe()

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x.head()

# %%
y.head()

# %%
y.unique()

# %%
y.value_counts()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,stratify=y, test_size=0.25)

# %%
from sklearn import tree

dtc=tree.DecisionTreeClassifier(random_state=0)
dtc.fit(x_train,y_train)

# %%
dtc.score(x_test,y_test)

# %%
y_test.value_counts()

# %%
sn=[]
score=[]
for i in range(1,100):
    x_train,x_test,y_train,y_test = train_test_split(x,y,stratify=y, test_size=0.25)
    dtc=tree.DecisionTreeClassifier(random_state=0)
    dtc.fit(x_train,y_train)
    sn.append(i)
    score.append(dtc.score(x_test,y_test))
    
result=pd.DataFrame()
result["SN"]=sn
result["Score"]=score

# %%
result

# %%
result.describe()

# %%
result.to_csv("r1.csv")
