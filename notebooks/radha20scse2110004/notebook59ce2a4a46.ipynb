# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
url = pd.read_csv('/kaggle/input/test-file/tested.csv')

url.head()

url.info()

# %%
url['Sex'] = url['Sex'].replace('male', NaN)

# %%
import numpy as np

url[url['Age'].isnull()].head()

# %%
url['Sex'] = url['Sex'].replace('male', np.nan)

url.head()

# %%
url = pd.read_csv('/kaggle/input/test-file/tested.csv', na_values=[np.nan, 'NONE', -999])

url.head()

# %%
url.drop('Age', axis=1).head(2)

url.drop(['Age', 'Sex'], axis=1).head(2)

url.drop(url.columns[1], axis=1).head(2)

# %%
url[url['Sex'] != 'male'].head(2)

url[url['Name'] != 'Allison, Miss Helen Loraine'].head(2)

url[url.index != 0].head(2)

# %%
duplicate = url[url.duplicated()]

duplicate

# %%
url.drop_duplicates().head(2)

print("Number Of Rows In The Original DataFrame:", len(url))
print("Number Of Rows After Deduping:", len(url.drop_duplicates()))

# %%
url.drop_duplicates(subset=['Sex'])

# %%
print("Number Of Rows In The Original DataFrame:", len(url))
print("Number Of Rows After Deduping:", len(url.drop_duplicates()))

# %%
url.drop_duplicates(subset=['Sex'], keep='last')

# %%
url.groupby('Sex').mean()

url.groupby('Sex')

url.groupby('Survived')['Name'].count()

url.groupby(['Sex','Survived'])['Age'].mean()

# %%
time_index = pd.date_range('06/06/2017', periods=100000, freq='30S')
url = pd.DataFrame(index=time_index)
url['Sale_Amount'] = np.random.randint(1, 10, 100000)
url.resample('W').sum()

url.head(3)
url.resample('2W').mean()
url.resample('M').count()
url.resample('M', label='left').count()

# %%
import pandas as pd

url=pd.read_csv('/kaggle/input/test-file/tested.csv')

url.head()

# %%
def uppercase(x):
    return x.upper()

url.head()

url['Name'].apply(uppercase)[0:2]

# %%
url.groupby('Sex').apply(lambda x: x.count())

# %%
url.iloc[0:10, :]
first=url.iloc[0:10, :]
dataframe_first = pd.DataFrame(first, columns = ['Age','Name'])
dataframe_first.head()

# %%
url.tail()
url.iloc[407:417, :]
second=url.iloc[407:417, :]
dataframe_second = pd.DataFrame(second, columns = ['Age','Sex'])

dataframe_second.head()

# %%
pd.merge(dataframe_first, dataframe_second, on='Age')
