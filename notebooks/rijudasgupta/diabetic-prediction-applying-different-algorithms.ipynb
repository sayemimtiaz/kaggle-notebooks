# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/kaggle/input/pima-indians-diabetes-database/diabetes.csv')

# %%
df.head()

# %%
df.shape

# %%
df.info()

# %%
df.describe()

# %%
df['Pregnancies'].value_counts()

# %%
sns.pairplot(df,hue='Outcome')

# %%
x = df.drop(columns='Outcome',axis=1)
y = df['Outcome']

# %%
x

# %%
y

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=121)

# %%
print('shape of x_train = ',x_train.shape)
print('shape of x_test = ',x_test.shape)
print('shape of y_train = ',y_train.shape)
print('shape of y_test = ',y_test.shape)

# %%
x_train.head()

# %% [markdown]
# ## Applying KNN Algorithm

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=11)

# %%
knn.fit(x_train,y_train)

# %%
y_pred_knn = knn.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred_knn)

# %% [markdown]
# ### checking maximum neighbours

# %%
# score = []
# for i in range(1000):
#     x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=i)
#     knn = KNeighborsClassifier(n_neighbors=11)
#     knn.fit(x_train,y_train)
#     y_pred = knn.predict(x_test)
#     score.append(accuracy_score(y_test,y_pred))

# %%
# np.argmax(score)

# %% [markdown]
# ## Applying Decision Tree Algorithm

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(max_depth=4,random_state=612)

# %%
dt.fit(x_train,y_train)

# %%
y_pred_tree = dt.predict(x_test)

# %%
accuracy_score(y_test,y_pred_tree)

# %%
0.7207792207792207

# %%
# score = []
# for i in range(10,100):
#     dt = DecisionTreeClassifier(max_depth=i,random_state=162)
#     dt.fit(x_train,y_train)
#     y_pred = dt.predict(x_test)
#     score.append(accuracy_score(y_test,y_pred))

# %%
# np.argmax(score)

# %%
0.7272727272727273

# %% [markdown]
# ## Applying Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)

# %%
y_pred_lr = lr.predict(x_test)

# %%
accuracy_score(y_test,y_pred_lr)

# %%
# y_pred

# %%
# y_test.to_numpy()

# %% [markdown]
# ## Applying Random Forest Algorithm

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=25,random_state=162)

# %%
rf.fit(x_train,y_train)

# %%
y_pred_random = rf.predict(x_test)

# %%
accuracy_score(y_test,y_pred_random)

# %%
0.8766233766233766

# %%
# score = []
# for i in range(10,100):
#     x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=i)
#     rf = RandomForestClassifier(n_estimators=25,random_state=162)
#     rf.fit(x_train,y_train)
#     y_pred = rf.predict(x_test)
#     score.append(accuracy_score(y_test,y_pred))

# %%
# np.argmax(score)

# %%
# x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=13)
# rf = RandomForestClassifier(n_estimators=25,random_state=162)
# rf.fit(x_train,y_train)
# y_pred = rf.predict(x_test)
# accuracy_score(y_test,y_pred)

# %%
print(f"Acccracy of KNN Classifier Algorithm = {accuracy_score(y_test,y_pred_knn)}")
print(f"Acccracy of Decision Tree Classifier Algorithm = {accuracy_score(y_test,y_pred_tree)}")
print(f"Acccracy of Logistic Regression Classifier Algorithm = {accuracy_score(y_test,y_pred_lr)}")
print(f"Acccracy of Random Forest Classifier Algorithm = {accuracy_score(y_test,y_pred_random)}")

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred_knn)

# %%
confusion_matrix(y_test,y_pred_lr)

# %%
confusion_matrix(y_test,y_pred_tree)

# %%
confusion_matrix(y_test,y_pred_random)
