# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_bcell = pd.read_csv("../input/epitope-prediction/input_bcell.csv")
data_covid = pd.read_csv("../input/epitope-prediction/input_covid.csv")
data_sars = pd.read_csv("../input/epitope-prediction/input_sars.csv")

# %%
data_bcell.info()

# %%
data_bcell.head()

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
target = sns.countplot(x='target',data=data_bcell,palette='husl')

# %%
data_bcell['length'] = data_bcell['end_position']-data_bcell['start_position']
data_bcell.head()

# %%
fig = sns.countplot(x="length",  data=data_bcell)

# %%
cols = ['chou_fasman','emini','kolaskar_tongaonkar','parker','isoelectric_point','aromaticity','hydrophobicity','stability']
fig, axs = plt.subplots(2,4)

# Configurando o gráfico
fig.set_figheight(10)
fig.set_figwidth(20)
sns.set(font_scale=1)

for i, col in enumerate(cols):
    sns.histplot(data_bcell[col], ax=axs[i//4,i%4], kde=True, palette='husl')
    axs[i//4,i%4].set_ylabel('')
