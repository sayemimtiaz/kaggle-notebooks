# %% [markdown]
# # Report for Lecture 7
# # 21M51757 Akihiro NAKASHIMA

# %% [markdown]
# # [In class] Create a global map for COVID Vaccinations (Percentage of the population that are fully vaccinated).

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly

df = pd.read_csv('../input/covid-world-vaccination-progress/country_vaccinations.csv',header=0)
df.index = pd.to_datetime(df['date'])
df = df.sort_index()
print(df.columns)
#print(df)
fig = px.choropleth(df,locations='country',locationmode='country names',color='people_fully_vaccinated_per_hundred',hover_name='country',animation_frame='date',color_continuous_scale='rainbow',range_color=(0.0,40.0))
fig.update_layout(title_text="Percentage of the country's total population that are fully vaccinated",title_x=0.5)
fig.show()

plotly.offline.plot(fig,filename='vaccinations.html')

# %% [markdown]
# # [By myself] Create a global map for COVID Vaccinations (daily vaccinations per million).¶
# I focused on daily vaccinations per million in order to visualize that speed of vaccinations is slowing down in vaccination-advanced countries such as the US. In the US, since late April, speed of vaccinations has been slowing down. It is said that's because some people are wondering whether vaccines are truly safe and effective. To overcome this situation, government or other stakeholders have begun some campaigns. For example, a baseball stadium started vaccinations to audience or a hamburger shop presents hamburgers to those who are vaccinated.
#
# The source is here (https://www3.nhk.or.jp/news/html/20210503/k10013011681000.html, https://www3.nhk.or.jp/news/html/20210429/k10013004371000.html).

# %%
df = pd.read_csv('../input/covid-world-vaccination-progress/country_vaccinations.csv',header=0)
df.index = pd.to_datetime(df['date'])
df = df.sort_index()
print(df.columns)
#print(df)
#fig = px.choropleth(df,locations='country',locationmode='country names',color='vaccines',hover_name='country',animation_frame='date',color_continuous_scale='rainbow') #,range_color=(0.0,10000.0)
#fig = px.choropleth(df,locations='country',locationmode='country names',color='people_fully_vaccinated_per_hundred',hover_name='country',animation_frame='date',color_continuous_scale='rainbow',range_color=(0.0,40.0))
fig = px.choropleth(df,locations='country',locationmode='country names',color='daily_vaccinations_per_million',hover_name='country',animation_frame='date',color_continuous_scale='rainbow',range_color=(0.0,11000.0))
fig.update_layout(title_text="Daily vaccinations per million people",title_x=0.5)
fig.show()

#plotly.offline.plot(fig,filename='vaccinations.html')

# %% [markdown]
# # [In class] Create a global map of earthquake occurences worldwide.

# %%
df = pd.read_csv('../input/202105-recent-earthquake/query.csv',header=0)
#print(df.columns)
df.index = pd.to_datetime(df['time'])
#print(df.index)
#print(df['time'])
df['time'] = df.index.strftime('%Y-%m-%d %H:00:00')
df = df.sort_index()
#print(df['time'])
fig = px.scatter_geo(df,lat='latitude',lon='longitude',color='mag',animation_frame='time',color_continuous_scale='rainbow',range_color=(1.0,3.0))
fig.show()

# %% [markdown]
# # [By myself] Create a global map of earthquake occurences worldwide.
# I focused on the earthquake that happened in Qinghai, China (35.7°N, 96.4°E) at 3:04JST on May 22nd (at 18:00 on May 21st in the bar below). The magnitude was 7.4, said in a news article. Before and after that, some great earthquakes frequently happened around Qinghai.
#
# The source is here (https://weathernews.jp/s/topics/202105/220005/,  https://weathernews.jp/s/topics/202105/230065/).

# %%
df = pd.read_csv('../input/earthquake/query(1).csv',header=0)
print(df.columns)
df.index = pd.to_datetime(df['time'])
#print(df.index)
#print(df['time'])
df['time'] = df.index.strftime('%Y-%m-%d %H:00:00')
df = df.sort_index()
#print(df['time'])
fig = px.scatter_geo(df,lat='latitude',lon='longitude',color='mag',animation_frame='time',color_continuous_scale='rainbow',range_color=(1.0,3.0))
fig.show()
