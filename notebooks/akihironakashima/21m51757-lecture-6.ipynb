# %% [markdown]
# # 21M51757 Akihiro NAKASHIMA
# # Lecture 6 Assignment (Due date: May 28th, 2021)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

selected_country_1 = 'UK'
selected_country_2 = 'United Kingdom'

df1 = pd.read_csv('../input/covid19-global-dataset/worldometer_coronavirus_daily_data.csv',header=0)
df1 = df1[df1['country']==selected_country_1]
df2 = pd.read_csv('../input/covid-world-vaccination-progress/country_vaccinations.csv',header=0)
df2 = df2[df2['country']==selected_country_2]
df1.index = pd.to_datetime(df1['date'])
df2.index = pd.to_datetime(df2['date'])
#print(df2)

# %% [markdown]
# # Analysis
#
# From here, I will analyze the data that was loaded as an dataframe object.

# %%
print(df1.columns)
print(df2.columns)

# %%
print(np.unique(df2['country']))

# %%
fig,ax = plt.subplots(figsize=(10,5))
plt.plot(df1.index,df1['daily_new_cases'])
ax1 = ax.twinx()
ax1.plot(df2.index,df2['daily_vaccinations'],'r')
plt.show()

# %% [markdown]
# # Improved visualization
#
# From here, we will be using the modules iplot and plotly to make better visualozations.

# %%
from plotly.offline import iplot
import plotly.graph_objs as go

daily_new_cases = go.Scatter(x=df1.index,y=df1['daily_new_cases'],yaxis='y1',name='Daily confirmed cases')
daily_vaccinations = go.Scatter(x=df2.index,y=df2['daily_vaccinations'],yaxis='y2',name='Daily vaccinations')


layout_obj = go.Layout(title='COVID vs. Vaccines',xaxis=dict(title='Date'),yaxis=dict(title='Daily cases'),yaxis2=dict(title='Vaccinations',side='right',overlaying='y'))
fig = go.Figure(data=[daily_new_cases,daily_vaccinations],layout=layout_obj)
iplot(fig)
fig.write_html('outocome.html')

# %% [markdown]
# # Discussion regarding the graph above
#
# In November, corona variant (N501Y) was spreading in the UK. We can find a big wave in November in the graph above.
#
# In January, the variant attacked people again. We can find there a bigger wave than that in November. Then, the British government took a policy of lockdown again followed by lockdown in Christmas.
#
# Also, vaccinations have begun since December and January. Thanks to vaccinations, for now, corona cases seems to be under control.

# %% [markdown]
# # Colored tables
#
# Create colored tables

# %%
style_object = df1.style.background_gradient(cmap='jet').highlight_max('daily_new_cases').set_caption('Daily cases')
display(style_object)

# %%
style_object = df2.style.background_gradient(cmap='jet').highlight_max('daily_vaccinations').set_caption('Daily vaccinations')
display(style_object)

# %% [markdown]
# # Where does the UK rank?
# In terms of cumulative total cases, the UK ranks 7th in the world.
# This means the UK has many corona positive cases.
#
# In terms of vaccination progress, the UK ranks 21st in the world.
# This means the UK proceed vacctinations at a high pace.

# %%
df1 = pd.read_csv('../input/covid19-global-dataset/worldometer_coronavirus_daily_data.csv',header=0)
df1 = df1.groupby('country').sum()['daily_new_cases'].sort_values(ascending=False)[0:10]
print(df1)
df2 = pd.read_csv('../input/covid-world-vaccination-progress/country_vaccinations.csv',header=0)
df2 = df2.groupby('country').max()['people_fully_vaccinated_per_hundred'].sort_values(ascending=False)
print(df2.to_string())
