# %% [markdown]
# # Corona Analysis

# %% [markdown]
# * This study is a data analysis study conducted to inform about the situation of the rapidly spreading coronavirus in Turkey and in the world.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

import matplotlib.pyplot as plt
import seaborn as sns

# %%
confirmed_df = pd.read_csv("/kaggle/input/novel-corona-virus-2019-dataset/time_series_covid_19_confirmed.csv")
deaths_df = pd.read_csv("/kaggle/input/novel-corona-virus-2019-dataset/time_series_covid_19_deaths.csv")
recovered_df = pd.read_csv("/kaggle/input/novel-corona-virus-2019-dataset/time_series_covid_19_recovered.csv")

# %%
confirmed_df

# %%
deaths_df

# %%
recovered_df

# %%
recovered_df.info()

# %%
cols = recovered_df.columns
cols

# %%
confirmed = confirmed_df.loc[:, cols[4]:cols[-1]]
deaths = deaths_df.loc[:, cols[4]:cols[-1]]
recovered = recovered_df.loc[:, cols[4]:cols[-1]]

# %%
world_cases = []
total_deaths = [] 
mortality_rate = []
recovery_rate = [] 
total_recovered = [] 
total_active = []

# %%
turkey_cases = []
china_cases = [] 
italy_cases = []
us_cases = [] 
spain_cases = [] 
france_cases = [] 
germany_cases = [] 
uk_cases = [] 
russia_cases = [] 
brazil_cases = []
india_cases = []

# %%
turkey_deaths = []
china_deaths = [] 
italy_deaths = []
us_deaths = [] 
spain_deaths = [] 
france_deaths = [] 
germany_deaths = [] 
uk_deaths = [] 
russia_deaths = []
brazil_deaths = [] 
india_deaths = []

# %%
turkey_recoveries = []
china_recoveries = [] 
italy_recoveries = []
us_recoveries = [] 
spain_recoveries = [] 
france_recoveries = [] 
germany_recoveries = [] 
uk_recoveries = [] 
russia_recoveries = [] 
brazil_recoveries = [] 
india_recoveries = []

# %%
dates = confirmed.columns
dates

# %%
for i in dates:
    world_cases.append(confirmed[i].sum())
    total_deaths.append(deaths[i].sum())
    total_recovered.append(recovered[i].sum())
    
    total_active.append(confirmed[i].sum() - deaths[i].sum() - recovered[i].sum())
    mortality_rate.append(deaths[i].sum() / confirmed[i].sum())
    recovery_rate.append(recovered[i].sum() / confirmed[i].sum())
    
    turkey_cases.append(confirmed_df[confirmed_df["Country/Region"] == "Turkey"][i].sum())
    china_cases.append(confirmed_df[confirmed_df['Country/Region']=='China'][i].sum())
    italy_cases.append(confirmed_df[confirmed_df['Country/Region']=='Italy'][i].sum())
    us_cases.append(confirmed_df[confirmed_df['Country/Region']=='US'][i].sum())
    spain_cases.append(confirmed_df[confirmed_df['Country/Region']=='Spain'][i].sum())
    france_cases.append(confirmed_df[confirmed_df['Country/Region']=='France'][i].sum())
    germany_cases.append(confirmed_df[confirmed_df['Country/Region']=='Germany'][i].sum())
    uk_cases.append(confirmed_df[confirmed_df['Country/Region']=='United Kingdom'][i].sum())
    russia_cases.append(confirmed_df[confirmed_df['Country/Region']=='Russia'][i].sum())
    brazil_cases.append(confirmed_df[confirmed_df['Country/Region']=='Brazil'][i].sum())
    india_cases.append(confirmed_df[confirmed_df['Country/Region']=='India'][i].sum())
    
    turkey_deaths.append(deaths_df[deaths_df['Country/Region']=='Turkey'][i].sum())
    china_deaths.append(deaths_df[deaths_df['Country/Region']=='China'][i].sum())
    italy_deaths.append(deaths_df[deaths_df['Country/Region']=='Italy'][i].sum())
    us_deaths.append(deaths_df[deaths_df['Country/Region']=='US'][i].sum())
    spain_deaths.append(deaths_df[deaths_df['Country/Region']=='Spain'][i].sum())
    france_deaths.append(deaths_df[deaths_df['Country/Region']=='France'][i].sum())
    germany_deaths.append(deaths_df[deaths_df['Country/Region']=='Germany'][i].sum())
    uk_deaths.append(deaths_df[deaths_df['Country/Region']=='United Kingdom'][i].sum())
    russia_deaths.append(deaths_df[deaths_df['Country/Region']=='Russia'][i].sum())
    brazil_deaths.append(deaths_df[deaths_df['Country/Region']=='Brazil'][i].sum())
    india_deaths.append(deaths_df[deaths_df['Country/Region']=='India'][i].sum())
    
    turkey_recoveries.append(recovered_df[recovered_df['Country/Region']=='Turkey'][i].sum())
    china_recoveries.append(recovered_df[recovered_df['Country/Region']=='China'][i].sum())
    italy_recoveries.append(recovered_df[recovered_df['Country/Region']=='Italy'][i].sum())
    us_recoveries.append(recovered_df[recovered_df['Country/Region']=='US'][i].sum())
    spain_recoveries.append(recovered_df[recovered_df['Country/Region']=='Spain'][i].sum())
    france_recoveries.append(recovered_df[recovered_df['Country/Region']=='France'][i].sum())
    germany_recoveries.append(recovered_df[recovered_df['Country/Region']=='Germany'][i].sum())
    uk_recoveries.append(recovered_df[recovered_df['Country/Region']=='United Kingdom'][i].sum())
    russia_recoveries.append(recovered_df[recovered_df['Country/Region']=='Russia'][i].sum())
    brazil_recoveries.append(recovered_df[recovered_df['Country/Region']=='Brazil'][i].sum())
    india_recoveries.append(recovered_df[recovered_df['Country/Region']=='India'][i].sum())

# %%
turkey_cases

# %%
china_recoveries

# %%
world_cases

# %%
confirmed_df

# %%
confirmed_df[confirmed_df["Country/Region"] == "Turkey"]

# %%
confirmed_df[confirmed_df["Country/Region"] == "China"]["1/22/20"].sum()

# %%
def daily_increase(data):
    
    liste = []
    
    for i in range(len(data)):
        
        if i == 0:
            
            liste.append(data[0])
            
        else:
            
            liste.append(data[i] - data[i-1])
            
            
    return liste

# %%
world_daily_increase = daily_increase(world_cases)
turkey_daily_increase = daily_increase(turkey_cases)
china_daily_increase = daily_increase(china_cases)
italy_daily_increase = daily_increase(italy_cases)
us_daily_increase = daily_increase(us_cases)
spain_daily_increase = daily_increase(spain_cases)
france_daily_increase = daily_increase(france_cases)
germany_daily_increase = daily_increase(germany_cases)
uk_daily_increase = daily_increase(uk_cases)
russia_daily_increase = daily_increase(russia_cases)
brazil_daily_increase = daily_increase(brazil_cases)
india_daily_increase = daily_increase(india_cases)

# %%
world_daily_death = daily_increase(total_deaths)
turkey_daily_death = daily_increase(turkey_deaths)
china_daily_death = daily_increase(china_deaths)
italy_daily_death = daily_increase(italy_deaths)
us_daily_death = daily_increase(us_deaths)
spain_daily_death = daily_increase(spain_deaths)
france_daily_death = daily_increase(france_deaths)
germany_daily_death = daily_increase(germany_deaths)
uk_daily_death = daily_increase(uk_deaths)
russia_daily_death = daily_increase(russia_deaths)
brazil_daily_death = daily_increase(brazil_deaths)

# %%
world_daily_recovery = daily_increase(total_recovered)
turkey_daily_recovery = daily_increase(turkey_recoveries)
china_daily_recovery = daily_increase(china_recoveries)
italy_daily_recovery = daily_increase(italy_recoveries)
us_daily_recovery = daily_increase(us_recoveries)
spain_daily_recovery = daily_increase(spain_recoveries)
france_daily_recovery = daily_increase(france_recoveries)
germany_daily_recovery = daily_increase(germany_recoveries)
uk_daily_recovery = daily_increase(uk_recoveries)
russia_daily_recovery = daily_increase(russia_recoveries)
brazil_daily_recovery = daily_increase(brazil_recoveries)
india_daily_recovery = daily_increase(india_recoveries)

# %%
turkey_daily_increase

# %%
days_since_1_22 = [i for i in range(len(dates))]
days_since_1_22

# %%
plt.figure(figsize = (7, 5))
plt.plot(days_since_1_22, world_cases)
plt.title("Toplam vaka sayisi", size = 10)
plt.xlabel("days_since_1_22", size = 10)
plt.ylabel("vaka sayisi", size = 10)
plt.xticks(size = 10)
plt.yticks(size = 10)
plt.show()

plt.figure(figsize = (7, 5))
plt.plot(days_since_1_22, total_deaths)
plt.title("Toplam ölüm sayisi", size = 10)
plt.xlabel("days_since_1_22", size = 10)
plt.ylabel("ölüm sayisi", size = 10)
plt.xticks(size = 10)
plt.yticks(size = 10)
plt.show()

# %%
plt.figure(figsize = (7, 5))
plt.plot(days_since_1_22, total_recovered)
plt.title("Toplam kurtulma sayisi", size = 10)
plt.xlabel("days_since_1_22", size = 10)
plt.ylabel("kurtulma sayisi", size = 10)
plt.xticks(size = 10)
plt.yticks(size = 10)
plt.show()

plt.figure(figsize = (7, 5))
plt.plot(days_since_1_22, total_active)
plt.title("Toplam aktif sayisi", size = 10)
plt.xlabel("days_since_1_22", size = 10)
plt.ylabel("aktif sayisi", size = 10)
plt.xticks(size = 10)
plt.yticks(size = 10)
plt.show()

# %%
plt.figure(figsize = (7, 5))
plt.plot(days_since_1_22, world_daily_increase)
plt.title("Günlük vaka sayisi", size = 10)
plt.xlabel("days_since_1_22", size = 10)
plt.ylabel("Günlük vaka sayisi", size = 10)
plt.xticks(size = 10)
plt.yticks(size = 10)
plt.show()

plt.figure(figsize = (7, 5))
plt.plot(days_since_1_22, world_daily_death)
plt.title("Günlük ölüm sayisi", size = 10)
plt.xlabel("days_since_1_22", size = 10)
plt.ylabel("Günlük ölüm sayisi", size = 10)
plt.xticks(size = 10)
plt.yticks(size = 10)
plt.show()

plt.figure(figsize = (7, 5))
plt.plot(days_since_1_22, world_daily_recovery)
plt.title("Günlük kurtulma sayisi", size = 10)
plt.xlabel("days_since_1_22", size = 10)
plt.ylabel("Günlük kurtulma sayisi", size = 10)
plt.xticks(size = 10)
plt.yticks(size = 10)
plt.show()

# %%
def country_plot(days_since_1_22, country_cases, 
                 country_daily_increase, country_daily_death, 
                 country_daily_recovery, country):
    
    
    plt.figure(figsize = (7, 5))
    plt.plot(days_since_1_22, country_cases)
    plt.title("{}'nin vaka sayisi".format(country) ,size = 10)
    plt.xlabel("days_since_1_22", size = 10)
    plt.ylabel("vaka sayisi", size = 10)
    plt.xticks(size = 10)
    plt.yticks(size = 10)
    plt.show()
    
    plt.figure(figsize = (7, 5))
    plt.bar(days_since_1_22, country_daily_increase)
    plt.title("{}'nin Günlük vaka sayisi".format(country), size = 10)
    plt.xlabel("days_since_1_22", size = 10)
    plt.ylabel("Günlük vaka sayisi", size = 10)
    plt.xticks(size = 10)
    plt.yticks(size = 10)
    plt.show()
    
    plt.figure(figsize = (7, 5))
    plt.bar(days_since_1_22, country_daily_death)
    plt.title("{}'nin Günlük ölüm sayisi".format(country), size = 10)
    plt.xlabel("days_since_1_22", size = 10)
    plt.ylabel("Günlük ölüm sayisi", size = 10)
    plt.xticks(size = 10)
    plt.yticks(size = 10)
    plt.show()
    
    plt.figure(figsize = (7, 5))
    plt.bar(days_since_1_22, country_daily_recovery)
    plt.title("{}'nin Günlük kurtulma sayisi".format(country),size = 10)
    plt.xlabel("days_since_1_22", size = 10)
    plt.ylabel("Günlük kurtulma sayisi", size = 10)
    plt.xticks(size = 10)
    plt.yticks(size = 10)
    plt.show()

# %%
country_plot(days_since_1_22, china_cases, china_daily_increase, china_daily_death, china_daily_recovery, "China")

# %%
country_plot(days_since_1_22, turkey_cases, turkey_daily_increase, turkey_daily_death, turkey_daily_recovery, "Turkey")

# %%
country_plot(days_since_1_22, italy_cases, italy_daily_increase, italy_daily_death, italy_daily_recovery, 'Italy')

# %%
country_plot(days_since_1_22, us_cases, us_daily_increase, us_daily_death, us_daily_recovery, 'United States')

# %%
country_plot(days_since_1_22, russia_cases, russia_daily_increase, russia_daily_death, russia_daily_recovery, 'Russia')

# %%
#ülke karşılaştırma
plt.figure(figsize = (12,7))
plt.plot(days_since_1_22, china_cases)
plt.plot(days_since_1_22, turkey_cases)
plt.plot(days_since_1_22, italy_cases)
plt.plot(days_since_1_22, us_cases)
plt.plot(days_since_1_22, russia_cases)
plt.title("Ülkelerin vaka sayisi", size = 15)
plt.xlabel("days_since_1_22", size = 15)
plt.ylabel("vaka sayisi", size = 15)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.legend(["China", "Turkey", "Italy", "Usa", "Russian"], prop = {"size":15})
plt.show()

plt.figure(figsize=(12, 7))
plt.plot(days_since_1_22, china_deaths)
plt.plot(days_since_1_22, turkey_deaths)
plt.plot(days_since_1_22, italy_deaths)
plt.plot(days_since_1_22, us_deaths)
plt.plot(days_since_1_22, russia_deaths)

plt.title('Ülkelerin Ölüm Sayisi', size=15)
plt.xlabel('days_since_1_22', size=15)
plt.ylabel('Ölüm Sayisi', size=15)
plt.legend(["China", "Turkey", "Italy", "Usa", "Russian"], prop={'size': 15})
plt.xticks(size=15)
plt.yticks(size=15)
plt.show()

plt.figure(figsize=(12, 7))
plt.plot(days_since_1_22, china_recoveries)
plt.plot(days_since_1_22, turkey_recoveries)
plt.plot(days_since_1_22, italy_recoveries)
plt.plot(days_since_1_22, us_recoveries)
plt.plot(days_since_1_22, russia_recoveries)
plt.title('Ülkelerin Kurtulma Sayisi', size=15)
plt.xlabel('days_since_1_22', size=15)
plt.ylabel('Kurtulma Sayisi', size=15)
plt.legend(["China", "Turkey", "Italy", "Usa", "Russian"], prop={'size': 15})
plt.xticks(size=15)
plt.yticks(size=15)
plt.show()

# %%
#ölüm oranı
plt.plot(days_since_1_22, mortality_rate)

# %%
#kurtulma oranı
plt.plot(days_since_1_22, recovery_rate)

# %%
#Ölüm-Kurtulma oranları karşılaştırması
plt.figure(figsize=(12, 7))
plt.plot(days_since_1_22, mortality_rate)
plt.plot(days_since_1_22, recovery_rate)
plt.title('Ölüm-Kurtulma', size=10)
plt.xlabel('days_since_1_22', size=10)
plt.ylabel('Ölüm-Kurtulma Oranı', size=10)
plt.legend(["mortality_rate", "recovery_rate"], prop={'size': 10})
plt.xticks(size=10)
plt.yticks(size=10)
plt.show()

# %%
plt.plot(days_since_1_22, total_deaths)

# %%
plt.plot(days_since_1_22, total_active)

# %%
plt.plot(days_since_1_22, total_recovered)

# %%
plt.figure(figsize=(12, 7))
plt.plot(days_since_1_22, total_deaths)
plt.plot(days_since_1_22, total_active)
plt.plot(days_since_1_22, total_recovered)
plt.title('Ölüm-Kurtulma-Aktif', size=10)
plt.xlabel('days_since_1_22', size=10)
plt.ylabel('Ölüm-Kurtulma-Aktif Sayisi', size=10)
plt.legend(["total_deaths", "total_active","total_recovered"], prop={'size': 10})
plt.xticks(size=10)
plt.yticks(size=10)
plt.show()

# %%
#Turkiye korona analizi
sns.jointplot(days_since_1_22, turkey_cases, kind = "hex")
sns.jointplot(days_since_1_22, turkey_deaths, kind = "hex")
sns.jointplot(days_since_1_22, turkey_recoveries, kind = "hex")

# %%
turky_mortality_rate = []
turkey_recovery_rate = []
turkey_total_active  = []

# %%
for i in days_since_1_22:
    
    turky_mortality_rate.append(turkey_deaths[i] / turkey_cases[i])
    turkey_recovery_rate.append(turkey_recoveries[i] / turkey_cases[i])
    turkey_total_active.append(turkey_cases[i] - turkey_deaths[i] - turkey_recoveries[i])

# %%
turky_mortality_rate

# %%
plt.figure(figsize=(12, 7))
plt.plot(days_since_1_22, turkey_deaths)
plt.plot(days_since_1_22, turkey_total_active)
plt.plot(days_since_1_22, turkey_recoveries)
plt.title('Ölüm-Kurtulma-Aktif', size=10)
plt.xlabel('days_since_1_22', size=10)
plt.ylabel('Ölüm-Kurtulma-Aktif Sayisi', size=10)
plt.legend(["turkey_deaths", "turkey_total_active","turkey_recoveries"], prop={'size': 10})
plt.xticks(size=10)
plt.yticks(size=10)
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.plot(days_since_1_22, turky_mortality_rate)
plt.plot(days_since_1_22, turkey_recovery_rate)
plt.title('Ölüm-Kurtulma', size=10)
plt.xlabel('days_since_1_22', size=10)
plt.ylabel('Ölüm-Kurtulma Oranı', size=10)
plt.legend(["turkey_mortality_rate", "turkey_recovery_rate"], prop={'size': 10})
plt.xticks(size=10)
plt.yticks(size=10)
plt.show()
