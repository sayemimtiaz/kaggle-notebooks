# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
countries_df = pd.read_csv("/kaggle/input/countries-of-the-world/countries of the world.csv")

# %%
df = pd.read_csv("/kaggle/input/co2-ghg-emissionsdata/co2_emission.csv")

# %%
df.head()

# %%
df.describe()

# %%
recent_df = df[df["Year"] == 2017]

# %%
recent_df.head()

# %%
df = df.rename(columns={"Annual CO₂ emissions (tonnes )": "Co2"})

# %%
recent_df = df[df["Year"] == 2017]

# %%
df["Co2"]

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(df["Co2"], vert=False)

# %%
bins = []

# %%
descr = df["Co2"].describe()

# %%
max_co2 = descr["max"]

# %%
min_co2 = descr["min"]

# %%
min_co2

# %%
step = int(max_co2 / 20)

# %%
bins = list([i for i in range(0, int(max_co2), step)])

# %%
plt.hist(df["Co2"], bins, rwidth=0.9, log=True)

# %%
def log_bins(x):
    return 10**x

# %%
bins = list([log_bins(i) for i in range(10)])

# %%
recent_df.head()

# %%
recent_df_sorted = recent_df.sort_values("Co2", ascending=False)

# %%
recent_df_sorted.head()

# %%
countries_co2 = list(recent_df_sorted[["Entity", "Co2"]].values)[:5]

# %%
countries, co2 = zip(*countries_co2)

# %%
countries = list(countries)
co2 = list(co2)

# %%
rest = co2[0] - sum(co2[1:5])

# %%
rest

# %%
co2[0]

# %%
countries.append("Rest of the world")
co2.append(rest)

# %%
countries.pop(0)
co2.pop(0)

# %%
countries

# %%
colors = ["red", "blue", "green", "blue", "grey"]

# %%
plt.pie(co2, labels=countries, colors=colors)

# %%
recent_2years = df[df["Year"] > 2015]

# %%
recent_2years.head()

# %%
recent_2years["LastYearCo2"] = [0 for i in range(444)]

# %%
recent_2years.head()

# %%
"""

for code in list(recent_2years["Code"].unique()):
    code_df = recent_2years[recent_2years["Code"] == code]
    last_year = code_df[code_df["Year" == 2016]]
    recent_2years.where(recent_2years["Code"] == code and recent_2years["Year"] == 2017)["LastYearCo2"] = last_year
    
"""

# %%
values_last_year = []
for i in range(1, len(recent_2years)):
    last_year = recent_2years.values[i-1][3]
    values_last_year.append(last_year)

# %%
recent_2years["LastYearCo2"] = [0] + values_last_year

# %%
recent_2years.head()

# %%
year_change = recent_2years[recent_2years["Year"] == 2017]

# %%
year_change

# %%
percent_change = []
for i in range(len(year_change)):
    current = list(year_change["Co2"])[i]
    last = list(year_change["LastYearCo2"])[i]
    percent_change.append((current / last - 1) * 100)

# %%
percent_change = list(map(lambda x : round(x, 2), percent_change))

# %%
year_change["Percent Change"] = percent_change

# %%
year_change.head()

# %%
plt.boxplot(year_change["Percent Change"])

# %%
countries_df.head()

# %%
year_change.rename(columns = {'Entity':'Country'}, inplace = True)

# %%
year_change.head()

# %%
countries = list(countries_df["Country"])

# %%
countries = list(map(lambda x: x.strip(),countries))

# %%
countries_df["Country"] = countries

# %%
merged_df = pd.merge(year_change, countries_df, on="Country")

# %%
merged_df.head()

# %%
countries_df.head()

# %%
merged_df.head()

# %%
for co2_row in year_change.values:
    columns = year_change.columns
    co2_row
    row_values = {k:v for k, v in zip(columns, co2_row)}
    
    country_data = countries_df[countries_df["Country"] == row_values["Country"]]
    if len(country_data.values) > 0:
        country_data_row = list(country_data.values[0])
        country_columns = country_data.columns
        country_data_row_dict = {k:v for k, v in zip(country_columns, country_data_row)}
        new_row = dict(row_values, **country_data_row_dict)
    else:
        new_row = row_values
        co_columns = countries_df.columns
        co_data = {c: None for c in co_columns}
        new_row = dict(new_row, **co_data)
    merged_df = merged_df.append(new_row, ignore_index=True)
    print("lol")

# %%
merged_df.head(20)

# %%
year_change.head()

# %%
merged_df.columns

# %%
populations = merged_df["Population"]
country_names = merged_df["Country"]
co2_values = merged_df["Co2"]

# %%
populations

# %%
co2_per_capita = []
for i in range(len(populations)):
    try:
        co2_per_capita.append(co2_values[i] / populations[i])
    except TypeError:
        co2_per_capita.append(np.nan)

# %%
merged_df["Co2 per Capita"] = co2_per_capita

# %%
mean_co2 = merged_df["Co2 per Capita"].mean()

# %%
import random

# %%
random.random()

# %%
mean_co2

# %%
fig, ax = plt.subplots(figsize=(16,9))
colors = []
sizes = []
countries_diagramm = []
ax.set_yscale('log')


for x, y, label in zip(populations, co2_values, country_names):
    if type(x) == float and type(y) == float:
        if y > 500_000_000 or (y / x) > 100 or y / x < 0.1:

            # this method is called for each point
            ax.annotate(label, # this is the text
                         (x,y), # this is the point to label
                         textcoords="offset points", # how to position the text
                         xytext=(random.randint(-5, 5),random.randint(0, 15)), # distance from text to points (x,y)
                         ha='center')
            countries_diagramm.append(label)
        

colors, sizes ,x , y , _ = zip(*list(map(lambda x: ["red", 4] + list(x) if x[2] in countries_diagramm else ["blue", 0.8] + list(x), filter(lambda x: x[2] in countries_diagramm or random.random() > 0.8, zip(populations, co2_values, country_names)))))
ax.scatter(x, y, s=sizes, c=colors)

regression_xs = list([i for i in range(1, int(1.4 * 10**9), 10**6)])
def get_regr_y(x):
    return x * mean_co2
regression_ys = list(map(get_regr_y ,regression_xs))
ax.plot(regression_xs, regression_ys, label="best fit line")
ax.legend()

# %%
import numpy as np

# %%
merged_df.head()

# %%
merged_df.columns

# %%
gdp = merged_df["GDP ($ per capita)"]

# %%
plt.scatter(gdp, co2_per_capita, s=2)

# %%
gdp, co2_per_capita = zip(*list(filter(lambda x: type(x[0]) == float, zip(gdp, co2_per_capita))))

# %%
r = np.corrcoef(gdp, co2_per_capita)

# %%
merged_df.isnull().sum()

# %%
from copy import copy

# %%
merged_df_cor = merged_df.copy()

# %%
merged_df_cor["Region"].replace(np.nan, "", inplace=True)

# %%
merged_df_cor["Population"].replace(np.nan, , inplace=True)

# %%
merged_df_cor.isnull().sum()

# %%
merged_df.head()

# %%
merged_df.cov()

# %%
for column in merged_df.columns:
    new_df = merged_df[["Co2 per Capita", column]]
    new_df.dropna(inplace=True)
    co2 = list(new_df["Co2 per Capita"])
    other_column = list(new_df[column])
    try:
        r = np.corrcoef(co2, other_column)[0][1]
        print(f"{column}: {r}")
    except:
        pass

# %% [markdown]
# # Mehr Geld mehr Co2
