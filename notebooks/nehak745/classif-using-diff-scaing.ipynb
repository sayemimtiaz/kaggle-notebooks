# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# %config Completer.use_jedi=False
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
df = pd.read_csv("/kaggle/input/glass/glass.csv")
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %% [markdown]
# ### Running loop

# %%
sn = []
score = []
model = DecisionTreeClassifier()
for i in range(1,101):
    X_train , X_test, y_train, y_test = train_test_split(X,y,stratify=y,test_size=.25)
    model.fit(X_train,y_train)
    sn.append(i)
    score.append(model.score(X_test,y_test))
result = pd.DataFrame()
result['sn']=sn
result['score'] = score

# %%
print("{:.2f} %".format(result.score.mean()*100))

# %%
result.to_csv('tree_scores_without_Scaling.csv')

# %% [markdown]
# ### use minmax scaler and classify

# %%
minmax = MinMaxScaler()
x_minscaled = minmax.fit_transform(X)
x_minscaled

# %%
sn = []
score = []
for i in range(1,101):
    X_train , X_test, y_train, y_test = train_test_split(x_minscaled,y,stratify=y,test_size=.25)
    model.fit(X_train,y_train)
    sn.append(i)
    score.append(model.score(X_test,y_test))
result = pd.DataFrame()
result['sn']=sn
result['score'] = score

# %%
print("{:.2f} %".format(result.score.mean()*100))

# %%
result.to_csv('tree_scores_with_MinMaxScaler.csv')

# %% [markdown]
# ### use standard scaler and classify

# %%
stan = StandardScaler()
x_stanscaled = stan.fit_transform(X)

# %%
sn = []
score = []
for i in range(1,101):
    X_train , X_test, y_train, y_test = train_test_split(x_stanscaled,y,stratify=y,test_size=.25)
    model.fit(X_train,y_train)
    sn.append(i)
    score.append(model.score(X_test,y_test))
result = pd.DataFrame()
result['sn']=sn
result['score'] = score

# %%
print("{:.2f} %".format(result.score.mean()*100))

# %%
result.to_csv('tree_scores_with_StandardScaler.csv')
