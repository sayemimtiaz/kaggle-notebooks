# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input/nih-deeplesion-subset/minideeplesion/000001_01_01'):
    for filename in filenames:
        img = mpimg.imread(os.path.join(dirname, filename))
        plt.imshow(img)
        plt.show()


temp = np.zeros((5,5), dtype = int)
cols = ['first', 'second', 'third', 
                'fourth', 'fifth']
df = pd.DataFrame(data = temp,    
                  columns = cols) 
df.to_csv('sample_out.csv')

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
dl_info = pd.read_csv('/kaggle/input/nih-deeplesion-subset/DL_info.csv')

# %%
# dl_info = pd.read_csv('/kaggle/input/nih-deeplesion-subset/DL_info.csv')
# dl_info = dl_info.assign(DIR_NAME=lambda x: (x['File_name']))
# dl_info = dl_info.assign(DIRF=lambda x: (x['DIR_NAME'][:-8]))
# # df = df.assign(Product=lambda x: (x['Field_1'] * x['Field_2'] * x['Field_3'])) 
# dl_info.head()
# dir_name=dl_info['DIR_NAME']
# dir_name

# %%
dir_name = list(map(lambda i: i[ : -8], dl_info['File_name']))
dir_name

# %%
dl_info.loc[dl_info['File_name']=='002533_01_01_049.png']
# 002533_08_01

# %%
# %matplotlib notebook
import matplotlib
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import ipywidgets as widgets
from IPython.display import display
from datetime import datetime

from matplotlib.widgets import Button, TextBox
from numpy import random

from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import os
import glob

# %%
dir_name = dl_info.apply(lambda c_row: os.path.join(
        '{Patient_index:06d}_{Study_index:02d}_{Series_ID:02d}'.format(**c_row)), 1)
dir_name = list(set(dir_name))

# %%
print(len(dir_name))
filenames = glob.glob("/kaggle/input/nih-deeplesion-subset/minideeplesion/"+"002533_08_01"+"/*.png")
filenames

# %%
import pandas as pd
dl_info = pd.read_csv('/kaggle/input/nih-deeplesion-subset/DL_info.csv')
Measurement_coordinates = dl_info['Measurement_coordinates'][0]
Measurement_coordinates = Measurement_coordinates.split(",")
Measurement_coordinates = [float(i) for i in Measurement_coordinates]
print("Measurement_coordinates", Measurement_coordinates)

Bounding_boxes = dl_info['Bounding_boxes'][0]
Bounding_boxes = Bounding_boxes.split(",")
Bounding_boxes = [float(i) for i in Bounding_boxes]
print("Bounding_boxes", Bounding_boxes)

Lesion_diameters_Pixel_ = dl_info['Lesion_diameters_Pixel_'][0]
Lesion_diameters_Pixel_ = Lesion_diameters_Pixel_.split(",")
Lesion_diameters_Pixel_ = [float(i) for i in Lesion_diameters_Pixel_]
print("Lesion_diameters_Pixel_", Lesion_diameters_Pixel_)

Normalized_lesion_location = dl_info['Normalized_lesion_location'][0]
Normalized_lesion_location = Normalized_lesion_location.split(",")
Normalized_lesion_location = [float(i) for i in Normalized_lesion_location]
print("Normalized_lesion_location", Normalized_lesion_location)

Slice_range = dl_info['Slice_range'][0]
Slice_range = Slice_range.split(",")
Slice_range = [float(i) for i in Slice_range]
print("Slice_range", Slice_range)

Spacing_mm_px_ = dl_info['Spacing_mm_px_'][0]
Spacing_mm_px_ = Spacing_mm_px_.split(",")
Spacing_mm_px_ = [float(i) for i in Spacing_mm_px_]
print("Spacing_mm_px_", Spacing_mm_px_)

DICOM_windows = dl_info['DICOM_windows'][0]
DICOM_windows = DICOM_windows.split(",")
DICOM_windows = [float(i) for i in DICOM_windows]
print("DICOM_windows", DICOM_windows)

# %%
def showImage(val) :
    data = mpimg.imread('/kaggle/input/nih-deeplesion-subset/minideeplesion/000001_01_01/'+str(val)+'.png')
    img = plt.imshow(data)
#     return img

# %%
# %matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

def viewPNG(study, image):
    dirname = dir_name[study]
#     dirname = '000001_01_01'
    filenames = glob.glob("/kaggle/input/nih-deeplesion-subset/minideeplesion/"+str(dirname)+"/*.png")
#     try:
    print("Max No. of images in "+dirname+" study are: "+str(len(filenames)))
    if len(filenames)>0:
        if image>=len(filenames):
            image = 0
        data = mpimg.imread(filenames[image])
        img = plt.imshow(data)
    else :
        print("Study does not have any images")
#     except Exception as e:
#         print('Maximum files inside studies are :'+ len(filenames) )
    
# def viewPNG(val,dir_index) :
#     index = dir_name[dir_index]
#     print
# #     data = mpimg.imread('/kaggle/input/nih-deeplesion-subset/minideeplesion/000001_01_01/'+str(val)+'.png')
# #     img = plt.imshow(data)
plt.figure(0)
interactive_plot = interactive(viewPNG, study=(0,len(dir_name),1), image=(0,50,1))
output = interactive_plot.children[-1]
output.layout.height = '300px'
interactive_plot

# %%
# fig, ax = plt.subplots()
showImage('103')
interact(showImage, val=widgets.IntSlider(min=103, max=115, step=1, value=109), )

# %%
# a = ['000001_01_01','000001_02_01']
# def myfun(x):
#     print(x)
    
# interact(myfun, x =a)

# %%
def myfun(x,y):
    print(x,y)
print_myfun = interactive(myfun, x=(-2.0, 2.0), y=(-3, 3, 0.5))

# %%
# print(glob.glob("/kaggle/input/nih-deeplesion-subset/minideeplesion/000001_01_01/*.png")[0])

# %%
fig, ax = plt.subplots()

# %%
fig, ax = plt.subplots()
data = (random.random((5,5)) * 20).astype(np.uint8)
img = plt.imshow(data, cmap='tab20', vmin=0, vmax=20)


fig.subplots_adjust(bottom=0.5)
plt.axis('off')

class Index(object):
    ind = 0

    def b1(self, event):
        global img 
        data[0,0] = np.random.randint(20)
        img.set_data(data)
        plt.draw()

    def b2(self, event):
        global img 
        data[0,1] = np.random.randint(20)
        img.set_data(data)
        plt.draw()
    def b3(self, event):
        global img 
        data[0,2] = np.random.randint(20)
        img.set_data(data)
        plt.draw()
    def b4(self, event):
        global img 
        data[0,3] = np.random.randint(20)
        img.set_data(data)
        plt.draw()

callback = Index()
axprev = plt.axes([0.7, 0.05, 0.1, 0.075])
axnext = plt.axes([0.81, 0.05, 0.1, 0.075])
ax3 = plt.axes([0.5, 0.05, 0.1, 0.075])
ax4 = plt.axes([0.0, 0.05, 0.1, 0.075])
bnext = Button(axnext, 'b1')
bnext.on_clicked(callback.b1)
bprev = Button(axprev, 'b2')
bprev.on_clicked(callback.b2)
bprev2 = Button(ax3, 'b3')
bprev2.on_clicked(callback.b3)
bprev3 = Button(ax4, 'b4')
bprev3.on_clicked(callback.b4)
def submit(text):
    print(text)

axbox = plt.axes([0.1, 0.2, 0.8, 0.075])
text_box = TextBox(axbox, 'Evaluate', initial='hello')
text_box.on_submit(submit)
# display(fig)

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

def f(x):
    return x

def g(x, y):
    return re.search(y, x)

interact(f, x=10, )

# %%
# Create an simple IntSlider widget
demo_IntSlider_1 = widgets.IntSlider(
    min=1,                      # The minimum value
    max=100,                    # The maximum value
    description='Int Slider 1', # Label
    value=53,                   # Default value
)

# Display the widget
display(demo_IntSlider_1)

# %%
def f(x):
    return x
import re
def g(x, y):
    return re.search(y, x)
i2 = interact(g, x='Hi there!', y='(\w+)\s+(\w+)');
