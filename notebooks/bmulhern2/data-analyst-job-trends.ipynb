# %% [markdown]
# #Read the Full Analysis Here: https://bmulhern09.medium.com/data-analyst-job-trends-5b0e476c0eec

# %%
import pandas as pd

# %%
data = pd.read_csv("../input/data-analyst-jobs/DataAnalyst.csv")
df = data
df2 = data

# %%
df.groupby("Location").size().sort_values(ascending=False)

# %%
ny = df[df['Location'] == 'New York, NY']

# %%
ny.groupby("Salary Estimate").size().sort_values(ascending=False)

# %%
chi = data[data['Location'] == 'Chicago, IL']
chi

# %%
chi.groupby("Salary Estimate").size().sort_values(ascending=False)

# %%
SF = data[data['Location'] == 'San Francisco, CA']

# %%
SF.groupby("Salary Estimate").size().sort_values(ascending=False)

# %%
TX = data[data['Location'] == 'Austin, TX']

# %%
TX.groupby("Salary Estimate").size().sort_values(ascending=False)

# %%
la = data[data["Location"] == 'Los Angeles, CA']

# %%
la.groupby("Salary Estimate").size().sort_values(ascending=False)
