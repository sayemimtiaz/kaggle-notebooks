# %% [markdown]
# 1.Go through the concept in pandas
# 2.Create our own data frame
# 3.Numpy and matplotlib

# %%
#pandas
#dataframe is standard structure object of pandas to represent data in rows and column format
#2dimensional data structure

# %%
import pandas as pd

# %%
#read csv file and convert it into dataframe
df = pd.read_csv('../input/solar-power-generation-data/Plant_1_Generation_Data.csv')

# %%
df

# %%
df.info()   #summary of the data

# %%
type(df)

# %%
#display first 10 rows
df.head(10)

# %%
#display last 10 rows
df.tail(10)

# %%
#Pandas describe() is used to view some basic statistical details like percentile, mean, std etc. of a data frame or a series of numeric values. 
df.describe()

# %%
#While analyzing the data, many times we wants to see the unique values in a particular column, which can be done using Pandas unique() function.
df['SOURCE_KEY'].unique()

# %%
len(df['SOURCE_KEY'].unique())

# %%
df['SOURCE_KEY'].nunique()

# %% [markdown]
# AC_Power ,DC_power

# %% [markdown]
# 68878

# %%
#no of times unique values are repeated in that column
df['SOURCE_KEY'].value_counts()

# %%
# ?pd.unique

# %% [markdown]
# Statistical methods: min,max ,mean

# %%
df['DC_POWER'].max()    # to get max value in DC Power

# %%
df['DC_POWER'].min()   # to get min value in DC Power

# %%
df['DC_POWER'].mean()  # to get mean

# %%
df['AC_POWER']      #to display one column

# %%
df['AC_POWER'].to_frame()   #To display one column with tag

# %%
df[['AC_POWER','DC_POWER','DATE_TIME']]

# %%
df.nunique()

# %% [markdown]
# LOC and ILOC
# LOC : Location of index (fancy indexing)
# ILOC : index of location

# %%
power = df.iloc[:,4]    # Display the 4th column
power

# %%
power = df.iloc[:,4].values    # Display the 4th column in array
power

# %%
power = df.iloc[20:30,4]
power

# %%
df['AC_POWER'][30000:60116]

# %%
df['AC_POWER'].sort_values()

# %%
df

# %%
df.sort_values(by = 'SOURCE_KEY')

# %%
df['SOURCE_KEY']== '1BY6WEcLGh8j5v7'

# %%
df[df['SOURCE_KEY']== '1BY6WEcLGh8j5v7'].sum()

# %%
df[df['SOURCE_KEY']== '1BY6WEcLGh8j5v7'].sum()['DAILY_YIELD']

# %% [markdown]
# Creation dataframe with list

# %%
list = [[2,3,'a'],[34,67]]

# %%
var = pd.DataFrame(list)
var

# %%
type(var)

# %%
var.info()

# %%
#Attribute
var.ndim    #ndimension

# %%
#to know the range of rows
var.index

# %%
#to know the range of columns
var.columns

# %%
var.columns = ['apple','banana','mango']

# %%
var

# %%
var.index = ['count','value']

# %%
var

# %% [markdown]
# Creation dataframe with dictionary

# %%
d ={"name":['Ami','Anu'],"age":[25,32]}
d

# %%
type(d)

# %%
var1 = pd.DataFrame(d)
var1

# %%
type(var1)
