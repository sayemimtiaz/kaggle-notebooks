# %% [markdown]
#  # LIFE EXPECTANCY ANALYSIS

# %%
import pandas as pd
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# %%
life = pd.read_csv('../input/life-expectancy-who/Life Expectancy Data.csv')

# %%
life.head()

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
life.describe()

# %%
life.info()

# %%
life.isnull().sum()

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='median')
imputer.fit(life.iloc[:, 3:])
life.iloc[:, 3:]=imputer.transform(life.iloc[:, 3:])

# %%
life.isnull().sum()

# %%
life.describe()

# %%
life.head()

# %%
life.drop_duplicates(inplace = True)

# %%
life.columns

# %%
a = life[['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
       'infant deaths']]

# %%
sns.pairplot(a)

# %%
b = life[['Alcohol', 'percentage expenditure', 'Hepatitis B',
       'Measles ', ' BMI ', 'under-five deaths ', 'Life expectancy ']]

# %%
sns.pairplot(b)

# %%
c = life[[ 'Polio', 'Total expenditure','Diphtheria ', ' HIV/AIDS', 'GDP', 'Life expectancy ']]

# %%
sns.pairplot(c)

# %%
e = life[['Population',
       ' thinness  1-19 years', ' thinness 5-9 years',
       'Income composition of resources', 'Schooling','Life expectancy ']]

# %%
sns.pairplot(e)

# %%
plt.figure(figsize=(16, 6))
sns.heatmap(life.corr(), annot= True)

# %% [markdown]
# # Below are all the questions with answers on this Dataset

# %% [markdown]
# # 1. Predicting variables actually affecting the life expectancy

# %% [markdown]
#  - Schooling(+0.71)
#  - Income composition of resources(+0.69)
#  - HIV/AIDS(-0.56)
#  - Adult mortality(-0.7)
#  - BMI(+0.56)
#  - thinness 1-19years(-0.47)
#  - thiness 5-9years(-0.46)
#  - GDP(+0.43)
#  - Diphtheria(+0.47)
#  - Polio(+0.46)

# %%
life['percentage expenditure'].median()

# %%
o = life.loc[life['Life expectancy '] <65]

# %%
o.head()

# %%
o.describe()

# %%
life.describe()

# %% [markdown]
# # 2. Should a country having a lower life expectancy value(<65) increase its healthcare expenditure in order to improve its average lifespan?

# %% [markdown]
#  If we increase our 'percentage expenditure' means the expenditure on health as a percentage of Gross Domestic Product per capita(%) then we can say that our life expantancy can increase. But if we see 'Total expenditure' column, it tells us the total expendicture done by the country.
# There is not so much of a difference if we increases the healtcare expenditure for life expectancy

# %% [markdown]
# # 3. How does Infant and Adult mortality rates affect life expectancy?

# %% [markdown]
# Adult mortality rate affect more than infant mortality rate on life expectancy.
# - Correlation of infant mortality and life expectancy = -0.2
# - Correlation of adult mortality and life expectancy = -0.7

# %% [markdown]
# # 4. Does Life Expectancy has positive or negative correlation with eating habits, lifestyle, exercise, smoking, drinking alcohol etc.

# %% [markdown]
# - BMI index is called as body mass index, which means people are fit as there eating habits, lifestyle, exercise have a good impact on daily life. Also, BMI index has a positive corrrelation with life expectancy.
# - Alcohol has a positive correlation on life expectancy.
# - For smoking, there is no data given but for a thumb rule i can say that smoking may has a negetive correlation on life expectancy.

# %% [markdown]
# # 5. What is the impact of schooling on the lifespan of humans?

# %% [markdown]
# Schooling has a postive impact on the lifespan of the humans. There is a positive correlation of 0.71

# %% [markdown]
# # 6. Does Life Expectancy have positive or negative relationship with drinking alcohol?

# %% [markdown]
# Alcohol has a positive correlation on life expectancy. There is apositive correlation of 0.4

# %% [markdown]
# # 7. What is the impact of Immunization coverage on life Expectancy?

# %% [markdown]
# There is a positive correlation between immunization and life expentancy.

# %% [markdown]
# # 8. Do densely populated countries tend to have lower life expectancy?

# %% [markdown]
# Yes, there is a negative correlation between population and life expectancy. As, the population increases life expectancy decreases because everyone in that country will not be able to get the medical benefits from the govt.
