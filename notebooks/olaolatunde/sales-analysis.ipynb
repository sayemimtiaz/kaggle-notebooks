# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
dt=pd.read_csv('../input/sample-sales-data/sales_data_sample.csv')
dt.head(5)

# %%
dt.shape

# %%
dt.columns

# %%
import plotly.express as px

# %%
fig=px.box(dt,y=['productline1', 'sales', 'priceeach', 'productcode', 'ordernumber'])
fig.show()

# %%
dt.skew()

# %%
dt.dtypes

# %%
dt.hist(figsize=(20,20))

# %%
import seaborn as sns

# %%
sns.distplot(dt['QUANTITYORDERED'])

# %%
dt['QUANTITYORDERED'].mean()

# %%
Negative_exp=dt[dt['QUANTITYORDERED']<15]
Negative_exp.head(10)

# %%
Positive_exp=dt[dt['QUANTITYORDERED']>20]
Positive_exp.head(10)
