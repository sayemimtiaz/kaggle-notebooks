# %% [markdown]
# # **Simple Linear Regression**

# %% [markdown]
#  # **Importing The libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# # **Importing The Dataset**

# %%
dataset = pd.read_csv('../input/salary-data-simple-linear-regression/Salary_Data.csv')
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# %%
dataset.head() #Looking at first 5 values of the dataset

# %%
dataset.info() #Providing some info regarding the columns of the dataset

# %%
dataset.describe() #Describing some of the stats of the data

# %% [markdown]
# # **Splitting the Dataset into Training Set and Test Set**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# # **Traing the Model**

# %%
reg = LinearRegression()
reg.fit(X_train, y_train)

# %% [markdown]
# # **Predicting Test Set Results**

# %%
y_pred = reg.predict(X_test)

# %% [markdown]
# # **Visualising the Training Set Results**

# %%
plt.scatter(X_train, y_train, color='green')
plt.plot(X_train, reg.predict(X_train), color='blue')
plt.title('Experience Vs Salary (Training Set)', size=18)
plt.xlabel('Years of Experience', size=15)
plt.ylabel('Salary', size=15)
plt.show()

# %% [markdown]
# # **Visualising the Test Set Results**

# %%
plt.scatter(X_test, y_test, color='green')
plt.plot(X_train, reg.predict(X_train), color='blue')
plt.title('Experience Vs Salary (Test Set)', size=18)
plt.xlabel('Years of Experience', size=15)
plt.ylabel('Salary', size=15)
plt.show()

# %% [markdown]
# # **Evaluation of Model**

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
#Calculating mean square error
mean_sq_er = mean_squared_error(y_test, y_pred)
#calculating R Square
r2_sr = r2_score(y_test, y_pred)

# %%
print('Mean Squared Error : ', mean_sq_er)
print('R Square : ', r2_sr)

# %% [markdown]
# # **Final linear regression equation with the values of the coefficients**

# %%
print(reg.coef_)
print(reg.intercept_)

# %% [markdown]
# So the Final equation is :

# %% [markdown]
# # **y = 9312.58*X + 26780.10**
#
# where y = Salary
#       X = Years of Experience
