# %%
import numpy as np
import pandas as pd
import torch as tr

# %% [markdown]
# Подключаем данные, исключая строки с label==unsup

# %%
imdb = pd.read_csv('../input/imdb_master.csv', encoding='ISO-8859-1')
dev_df = imdb[(imdb.type == 'train') & (imdb.label != 'unsup')]

test_df = imdb[(imdb.type == 'test')]

# %% [markdown]
# Разделяем данные на тренировочные и проверочные

# %%
from sklearn import model_selection
train_df, val_df = model_selection.train_test_split(dev_df, test_size=0.1, stratify=dev_df.label)

# %% [markdown]
# Функция **word_extraction**
# * Исключает стоп слова из текст отзыва (например ‘the’, ‘is’, ‘are’), так как они не придают смысла отзыву
# * Разделяет отзыв на массив из слов
# * Преобразует слова в нижний регистр
# * Удаляет из отзыва цифры

# %%
import re
from nltk.corpus import stopwords 
    
def word_extraction(sentence):   
    ignore = stopwords.words('english')
    words = re.sub("[^\w]", " ", sentence).split()    
    cleaned_text = [w.lower() for w in words if w not in ignore and not w.isdigit()]   
    return cleaned_text

# %% [markdown]
# **build_vocab** создает словарь из ключей (слов) и их количества в отзывах**

# %%
def build_vocab(sentences):    
    for i, sentence in enumerate(sentences):
        words = word_extraction(sentence)
        for w in words:
            if w in vocab:
                vocab[w] = vocab[w]+1
            else:
                vocab[w] = 1
            
    return vocab

# %% [markdown]
# **get_max_seq_len** находит максимальную длину массива из слов, которые были выбраны в word_extraction

# %%
def get_max_seq_len(train_data, val_data, test_data):
    maxl = 0
    for sentence in train_data:  
        words = word_extraction(sentence)
        if maxl<len(words):
            maxl = len(words)
            
    for sentence in val_data:  
        words = word_extraction(sentence)
        if maxl<len(words):
            maxl = len(words)
            
    for sentence in test_data:  
        words = word_extraction(sentence)
        if maxl<len(words):
            maxl = len(words)
    
    return maxl

# %% [markdown]
# **generate_bow** Преобразует массив слов в массив цифр, используя индексы из vocab

# %%
def generate_bow(t_vocab, allsentences):
    vocab_vector = list()
    size = len(allsentences)
    for cur_i, sentence in enumerate(allsentences):  
        if cur_i % 2000==0:
            print(cur_i,"/",size)
        cur_i += 1
        words = word_extraction(sentence)
        #print(words)
        bag_vector = np.full((2000), 0)
        for i, word in enumerate(words):
            try:
                v_i = vocab.index(word)
            except:
                v_i = 0
            #print(word,"-",int(v_i), "-", i)
            bag_vector[i] = v_i
        #print(bag_vector.tolist())
        vocab_vector.append(bag_vector)
    return vocab_vector

# %% [markdown]
# Находим массив vocab, затем оставляем только слова с частой более 80

# %%
vocab = {".":1}
vocab_dic = build_vocab(train_df["review"])
print("Vocabulary with words count length ", len(vocab_dic.keys()))
#print(vocab_dic)

delete = [key for key, value in vocab_dic.items() if value < 80 and key!='.'] 
for key in delete: del vocab_dic[key] 

vocab = [key for key in vocab_dic.keys()]
print("Vocabulary length ", len(vocab))
#print(vocab)
# Out:
# Vocabulary with words count length  71965
# Vocabulary length  4658

# %% [markdown]
# Преобразуем каждый отзыв в массив из индексов

# %%
print("train_data")
train_data = generate_bow(vocab, train_df["review"])
print("val_data")
val_data = generate_bow(vocab, val_df["review"])
print("test_data")
test_data = generate_bow(vocab, test_df["review"])
# Out:
# train_data
# 0 / 22500
# 2000 / 22500
# 4000 / 22500
# 6000 / 22500
# 8000 / 22500
# 10000 / 22500
# 12000 / 22500
# 14000 / 22500
# 16000 / 22500
# 18000 / 22500
# 20000 / 22500
# 22000 / 22500
# val_data
# 0 / 2500
# 2000 / 2500
# test_data
# 0 / 25000
# 2000 / 25000
# 4000 / 25000
# 6000 / 25000
# 8000 / 25000
# 10000 / 25000
# 12000 / 25000
# 14000 / 25000
# 16000 / 25000
# 18000 / 25000
# 20000 / 25000
# 22000 / 25000
# 24000 / 25000

# %% [markdown]
# Подготавливаем данные, создавая DataLoader'ы

# %%
from torch.utils.data import TensorDataset,DataLoader
from torch.utils import data

def build_features(token_ids, label, max_seq_len, pad_index, label_encoding):
    if len(token_ids) >= max_seq_len:
        ids = token_ids[:max_seq_len]
    else:
        ids = token_ids + [0 for _ in range(max_seq_len - len(token_ids))]
    return [ids, [i for i,el in enumerate(label_encoding) if el == label][0]]

def features_to_tensor(list_of_features):
    text_tensor = tr.tensor([example[0] for example in list_of_features], dtype=tr.long)
    labels_tensor = tr.tensor([example[1] for example in list_of_features], dtype=tr.long)
    return text_tensor, labels_tensor
    
classes = ['neg', 'pos']

max_seq_len = get_max_seq_len(train_df["review"], val_df["review"], test_df["review"])

train_features = [build_features(review.tolist(), label, max_seq_len, 0, classes) for review, label in zip(train_data, train_df['label'])]
val_features = [build_features(review.tolist(), label, max_seq_len, 0, classes) for review, label in zip(val_data, val_df['label'])]
test_features = [build_features(review.tolist(), label, max_seq_len, 0, classes) for review, label in zip(test_data, test_df['label'])]

train_tensor, train_labels = features_to_tensor(train_features)
val_tensor, val_labels = features_to_tensor(val_features)
test_tensor, test_labels = features_to_tensor(test_features)

batch_size = 128
train_loader = DataLoader(TensorDataset(train_tensor, train_labels), batch_size = batch_size)
val_loader = DataLoader(TensorDataset(val_tensor, val_labels), batch_size = batch_size)
test_loader = DataLoader(TensorDataset(test_tensor, test_labels), batch_size = batch_size, shuffle=True)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data
from sklearn import metrics

class TextClassifier(nn.Module):
    def __init__(self, vocab_size, emb_size, num_filters, num_classes):
        super(TextClassifier, self).__init__()

        self.embedding = nn.Embedding(vocab_size, emb_size)
        self.dropout_big = tr.nn.Dropout(p = 0.4)
        self.dropout_small = tr.nn.Dropout(p = 0.05)

        self.convs = nn.ModuleList([
            nn.Conv1d(1, num_filters, [3, emb_size], padding = (2, 0)),
            nn.Conv1d(1, num_filters, [4, emb_size], padding = (3, 0)),
            nn.Conv1d(1, num_filters, [5, emb_size], padding = (4, 0)),
        ])

        self.fc = nn.Linear(num_filters * 3, num_classes)

    def forward(self, x):
        x = self.embedding(x)
        x = self.dropout_big(x)

        x = tr.unsqueeze(x, 1)
        xs = []
        for i in range(len(self.convs)):
            conv = self.convs[i]
            
            x2 = F.relu(conv(x))
            x2 = tr.squeeze(x2, -1)
            x2 = F.max_pool1d(x2, x2.size(2))
            
            if i == 1:
                x2 = self.dropout_small(x2)
            
            xs.append(x2)
        x = tr.cat(xs, 2)

        x = x.view(x.size(0), -1)
        logits = self.fc(x)
        
        return logits

# %% [markdown]
# Тренируем модель

# %%
def train(conv, loader, val_loader, epochs):
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(conv.parameters(), lr = 0.001)

    for epoch in range(epochs):
        r_loss = 0.0
        for i, data in enumerate(loader, 0):
            inputs, labels = data

            optimizer.zero_grad()

            outputs = conv(inputs.cuda())
            loss = criterion(outputs, labels.cuda())
            loss.backward()
            optimizer.step()

            r_loss += loss.item()
            
            every_n = 100
            if i % every_n == every_n - 1:
                validation_loss = get_validation_loss(conv, val_loader)
                print('Epoch %d: loss: %.3f, validation loss: %.3f' %
                      (epoch + 1, r_loss / every_n, validation_loss))
                r_loss = 0.0

# %%
def get_validation_loss(conv, val_loader):
    criterion = nn.CrossEntropyLoss()
    
    validation_loss = 0.0
    for i, data in enumerate(val_loader, 0):
        inputs, labels = data

        outputs = conv(inputs.cuda())
        loss = criterion(outputs, labels.cuda())

        validation_loss += loss.item()
    
    return validation_loss / len(val_loader)

# %% [markdown]
# **test_predictions** Сравнивает предсказанные классы с классами из data_loader'а

# %%
def test_predictions(conv, data_loader):
    y_true = []
    y_pred = []
    
    for data in data_loader:
        d, labels = data
        d = d.cuda()
        labels = labels.cuda()
        
        outputs = conv(d)
        _, predicted = tr.max(outputs.data, 1)
        y_true += labels.tolist()
        y_pred += predicted.tolist()
    
    return [y_true, y_pred]

# %%
def get_metrics(conv, test_loader, classes):
    y_true, y_pred = test_predictions(conv, test_loader)
    
    classification = metrics.classification_report(y_true, y_pred, target_names = classes)
    
    y_true = [classes[a] for a in y_true]
    y_pred = [classes[a] for a in y_pred]
    
    confusion = metrics.confusion_matrix(y_true, y_pred, labels = classes)
    return [classification, confusion]

# %% [markdown]
# **validate** Считает процент правильных предсказаний

# %%
def validate(conv, test_loader):
    y_true, y_pred = test_predictions(conv, test_loader)
    
    correct = (np.array(y_true) == np.array(y_pred)).sum()
    total = len(y_true)
    validation = correct / total
    
    return validation

# %% [markdown]
# **test** Выводит 10 преобразованных отзывов, предсказанный класс и действительный класс

# %%
def test(conv, test_loader):
    dataiter = iter(test_loader)

    for i in range(10):
        review, labels = next(dataiter)
        outputs = conv(review.cuda())
        _, predicteds = tr.max(outputs, 1)
        predicted = classes[predicteds[0]]
        groundtruth = classes[labels[0]]
        
        words = []
        for x in review[0]:
            if vocab[x]!=".":
                words.append(vocab[x])
            
        print()
        print(words)
        print("Prediction: {}".format(predicted))
        print("Real: {}".format(groundtruth))

# %%
emb_size = 100
num_filters = 500
num_classes = 2

len_vocab = len(vocab)
tc = TextClassifier(len_vocab, emb_size, num_filters, num_classes)
tc.cuda()

print('Train')
train(tc, train_loader, val_loader, 5)
# Out:
# Train
# Epoch 1: loss: 0.771, validation loss: 0.573
# Epoch 2: loss: 0.446, validation loss: 0.408
# Epoch 3: loss: 0.361, validation loss: 0.379
# Epoch 4: loss: 0.311, validation loss: 0.349
# Epoch 5: loss: 0.267, validation loss: 0.349

# %%
classification, confusion = get_metrics(tc, test_loader, classes)

print()
print('Classification report:')
print(classification)

print()
print('Confusion report:')
print(confusion)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#          neg       0.82      0.88      0.85     12500
#          pos       0.87      0.80      0.84     12500
#
#    micro avg       0.84      0.84      0.84     25000
#    macro avg       0.84      0.84      0.84     25000
# weighted avg       0.84      0.84      0.84     25000
#
#
# Confusion report:
# [[11001  1499]
#  [ 2465 10035]]

# %%
print()
print("Test")
test(tc, test_loader)
# Out:
# Test
#
# ['in', 'village', 'middle', 'nowhere', 'son', 'mother', 'cried', 'five', 'years', 'when', 'young', 'man', 'falls', 'love', 'years', 'old', 'teenager', 'dreams', 'see', 'world', 'becomes', 'actress', 'bring', 'world', 'de', 'television', 'show', 'travel', 'years', 'ahead', 'future', 'die', 'love', 'deadly', 'machine', 'years', 'later', 'tries', 'fix', 'wrong', 'travel', 'br', 'br', 'a', 'one', 'best', 'movies', 'i', 'recently', 'seen', 'the', 'refreshing', 'original', 'story', 'poetic', 'magic', 'love', 'certainly', 'thrill', 'tough', 'viewer', 'unique', 'romance', 'the', 'direction', 'excellent', 'screenplay', 'awesome', 'cinematography', 'colors', 'magnificent', 'cast', 'fantastic', 'marvelous', 'lines', 'soundtrack', 'beautiful', 'songs', 'if', 'movie', 'please', 'rent', 'buy', 'dvd', 'i', 'bet', 'love', 'story', 'bring', 'tears', 'my', 'vote', 'nine', 'br', 'br', 'title', 'brazil', 'a', 'â', 'o', 'the', 'machine', 'â', 'the', 'love']
# Prediction: pos
# Real: pos
#
# ['i', 'must', 'say', 'this', 'is', 'the', 'best', 'movie', 'i', 'have', 'ever', 'seen', 'know', 'website', 'received', 'negative', 'reviews', 'i', 'like', 'good', 'person', 'gives', 'worlds', 'best', 'movie', 'good', 'review', 'find', 'movie', 'extremely', 'funny', 'perfect', 'mix', 'everything', 'makes', 'feel', 'sorts', 'emotions', 'watch', 'i', 'get', 'enough', 'brilliant', 'i', 'love', 'it', 'understand', 'people', 'may', 'love', 'much', 'i', 'i', 'understand', 'people', 'could', 'hate', 'the', 'movie', 'brilliance', 'amazing', 'never', 'movies', 'could', 'good', 'also', 'never', 'i', 'could', 'watch', 'one', 'movie', 'many', 'times', 'single', 'day', 'without', 'getting', 'sick', 'think', 'everybody', 'watch', 'whether', 'get', 'feel', 'life', 'like', 'younger', 'days', 'see', 'reach', 'end', 'year']
# Prediction: pos
# Real: pos
#
# ['the', 'slasher', 'sub', 'genre', 'pretty', 'much', 'fact', 'even', 'one', 'year', 'supposed', 'first', 'slasher', 'halloween', 'released', 'seven', 'years', 'bay', 'blood', 'released', 'sub', 'genre', 'far', 'trap', 'represents', 'one', 'original', 'the', 'film', 'follows', 'basic', 'formula', 'e', 'murders', 'load', 'kids', 'draws', 'originality', 'fact', 'shown', 'beginning', 'opposed', 'man', 'mask', 'actually', 'get', 'insight', 'character', 'the', 'fact', 'killer', 'also', 'abilities', 'including', 'able', 'control', 'fill', 'house', 'adds', 'originality', 'we', 'kick', 'great', 'opening', 'sequence', 'sees', 'young', 'man', 'fall', 'foul', 'flat', 'finding', 'gas', 'station', 'terror', 'the', 'scene', 'amazingly', 'creepy', 'things', 'fly', 'gives', 'audience', 'great', 'insight', 'come', 'namely', 'creepy', 'horror', 'film', 'br', 'br', 'the', 'acting', 'credibility', 'non', 'existent', 'would', 'expect', 'seventies', 'slasher', 'honest', 'bad', 'the', 'girls', 'look', 'hot', 'boys', 'really', 'matter', 'chuck', 'creepy', 'role', 'psycho', 'he', 'exactly', 'anthony', 'still', 'good', 'enough', 'it', 'acting', 'star', 'show', 'however', 'might', 'expect', 'creepy', 'atmosphere', 'takes', 'prize', 'models', 'proved', 'likes', 'house', 'vincent', 'price', 'version', 'creepy', 'film', 'makes', 'best', 'use', 'fact', 'there', 'things', 'cinema', 'frightening', 'simply', 'definitely', 'one', 'things', 'the', 'killer', 'special', 'ability', 'could', 'easy', 'gotten', 'way', 'atmosphere', 'film', 'makes', 'best', 'use', 'fact', 'even', 'various', 'things', 'fly', 'goes', 'well', 'rest', 'movie', 'on', 'whole', 'good', 'film', 'while', 'trap', 'might', 'absolutely', 'essential', 'viewing', 'well', 'worth', 'seeing', 'i', 'recommend']
# Prediction: pos
# Real: pos
#
# ['the', 'andrew', 'davies', 'adaptation', 'sarah', 'waters', 'novel', 'excellent', 'the', 'characters', 'superbly', 'portrayed', 'the', 'whole', 'series', 'total', 'joy', 'watch', 'it', 'caught', 'imagination', 'everyone', 'across', 'board', 'whether', 'straight', 'gay', 'i', 'wish', 'could', 'sequel']
# Prediction: pos
# Real: pos
#
# ['following', 'little', 'known', 'british', 'film', 'made', 'budget', 'â', 'running', 'time', 'minutes', 'when', 'watching', 'never', 'expect', 'director', 'go', 'make', 'hollywood', 'become', 'one', 'directors', 'century', 'â', 'well', 'everybody', 'start', 'somewhere', 'i', 'suppose', 'br', 'br', 'the', 'director', 'following', 'probably', 'already', 'know', 'christopher', 'directly', 'following', 'would', 'go', 'direct', 'independent', 'film', 'years', 'later', 'would', 'hired', 'warner', 'direct', 'new', 'batman', 'series', 'brought', 'forth', 'my', 'point', 'everybody', 'start', 'somewhere', 'â', 'even', 'debut', 'â', 'christopher', 'introduces', 'world', 'following', 'br', 'br', 'when', 'watching', 'i', 'help', 'draw', 'another', 'directorial', 'debut', 'david', 'lynch', 'following', 'psychological', 'horror', 'film', 'sense', 'similarities', 'notable', 'shot', 'black', 'white', 'atmosphere', 'makes', 'unique', 'it', 'hard', 'describe', 'words', 'loosely', 'resembles', 'atmosphere', 'find', 'film', 'old', 'hence', 'said', 'following', 'contemporary', 'film', 'noir', 'neo', 'noir', 'overall', 'psychological', 'thriller', 'story', 'appropriate', 'two', 'genres', 'br', 'br', 'the', 'main', 'character', 'movie', 'title', 'early', 'possessed', 'â', 'picking', 'people', 'street', 'following', 'sometimes', 'even', 'hours', 'end', 'during', 'one', 'main', 'character', 'becomes', 'noticed', 'one', 'people', 'following', 'turns', 'man', 'willing', 'narrator', 'introduces', 'name', 'narrator', 'follow', 'br', 'br', 'from', 'main', 'character', 'becomes', 'world', 'becomes', 'crime', 'passion', 'violence', 'gets', 'intimate', 'following', 'much', 'character', 'study', 'instead', 'film', 'follows', 'relationship', 'two', 'main', 'characters', 'narrator', 'succeeds', 'making', 'film', 'film', 'noir', 'atmosphere', 'well', 'br', 'br', 'as', 'thriller', 'following', 'atmospheric', 'however', 'film', 'general', 'somewhat', 'disappointment', 'if', 'one', 'could', 'definitely', 'call', 'the', 'entire', 'film', 'shot', 'non', 'non', 'fashion', 'makes', 'story', 'film', 'experience', 'unique', 'extent', 'â', 'style', 'done', 'many', 'times', 'almost', 'technique', 'â', 'story', 'unique', 'extent', 'br', 'br', 'however', 'following', 'ultimately', 'entire', 'film', 'the', 'story', 'calls', 'â', 'action', 'suspense', 'thrills', 'â', 'becomes', 'storyline', 'instead', 'focuses', 'creating', 'story', 'following', 'succeed', 'without', 'elements', 'film', 'noir', 'quite', 'work', 'got', 'sense', 'enormous', 'still', 'nonetheless', 'furthermore', 'film', 'shocking', 'revelation', 'end', 'â', 'almost', 'film', 'â', 'one', 'makes', 'us', 'feel', 'comes', 'nowhere', 'relation', 'story', 'disappointing', 'essentially', 'makes', 'scenes', 'entire', 'film', 'seem', 'like', 'enormous', 'waste', 'time', 'br', 'br', 'but', 'far', 'end', 'following', 'turns', 'flawed', 'satisfying', 'film', 'yes', 'everybody', 'start', 'somewhere', 'christopher', 'following', 'fine', 'manner', 'a', 'quiet', 'fine', 'manner', 'it', 'movie', 'quite', 'worthy', 'director', 'would', 'go', 'receive', 'following', 'decade', 'still', 'good', 'film', 'nonetheless', 'when', 'following', 'find', 'well', 'made', 'atmospheric', 'thriller', 'one', 'lacks', 'innovative', 'style', 'still', 'manages', 'audiences', 'nonetheless']
# Prediction: neg
# Real: pos
#
# ['i', 'admit', 'i', 'one', 'hype', 'i', 'stop', 'consider', 'one', 'best', 'indie', 'exploitation', 'flicks', 'year', 'shocking', 'must', 'br', 'br', 'well', 'i', 'wasted', 'money', 'but', 'bad', 'movie', 'they', 'least', 'got', 'gore', 'right', 'well', 'unique', 'murder', 'seen', 'long', 'time', 'there', 'even', 'storyline', 'kinda', 'br', 'br', 'but', 'exploitation', 'film', 'surprising', 'amount', 'content', 'we', 'get', 'gay', 'sex', 'we', 'racial', 'maybe', 'we', 'psychotic', 'nice', 'back', 'sex', 'ok', 'made', 'female', 'version', 'gene', 'i', 'get', 'part', 'we', 'honest', 'goodness', 'among', 'best', 'actors', 'film', 'and', 'finally', 'government', 'conspiracy', 'thrown', 'i', 'know', 'try', 'connect', 'random', 'theme', 'killing', 'jimmy', 'boy', 'make', 'psycho', 'seem', 'if', 'nothing', 'else', 'movie', 'proves', 'americans', 'type', 'movie', 'the', 'make', 'crap', 'well', 'rest', 'kudos', 'goes', 'anyone', 'involved', 'made', 'career']
# Prediction: neg
# Real: neg
#
# ['i', 'seen', 'films', 'come', 'go', 'years', 'see', 'disaster', 'film', 'keep', 'hoping', 'wont', 'disappointed', 'and', 'one', 'least', 'the', 'story', 'whole', 'country', 'ocean', 'great', 'concept', 'written', 'intense', 'earth', 'going', 'the', 'characters', 'top', 'notch', 'even', 'though', 'japanese', 'need', 'give', 'idea', 'people', 'desperate', 'needs', 'come', 'together', 'common', 'good', 'the', 'special', 'effects', 'blew', 'away', 'literally', 'edge', 'seat', 'watching', 'waves', 'land', 'explosions', 'must', 'taken', 'months', 'work', 'perfect', 'as', 'acting', 'thought', 'yes', 'acting', 'best', 'emotions', 'run', 'throughout', 'film', 'cried', 'severe', 'scenes', 'for', 'movie', 'alike', 'need', 'speak', 'understand', 'japanese', 'watch', 'film', 'get', 'idea', 'feeling', 'person', 'character', 'understand', 'well', 'follow', 'along', 'like', 'my', 'directing', 'hope', 'work', 'another', 'mind', 'blowing', 'experience', 'as', 'said', 'fantastic', 'film']
# Prediction: pos
# Real: pos
# ['basically', 'version', 'early', 'creature', 'feature', 'favorite', 'the', 'centers', 'nasty', 'monster', 'makes', 'instant', 'unfortunate', 'souls', 'enough', 'go', 'around', 'limits', 'gold', 'spike', 'mine', 'your', 'standard', 'issue', 'hard', 'mine', 'boss', 'cute', 'blonde', 'babe', 'lady', 'old', 'mine', 'hand', 'guy', 'arguably', 'annoying', 'character', 'irritating', 'bunch', 'writer', 'speaking', 'melodramatic', 'trek', 'dark', 'cave', 'search', 'gold', 'naturally', 'discover', 'abandoned', 'mine', 'home', 'deadly', 'ugly', 'multi', 'beast', 'time', 'b', 'flick', 'fashion', 'bag', 'group', 'one', 'time', 'directed', 'co', 'written', 'co', 'produced', 'co', 'edited', 'anne', 'acted', 'rank', 'name', 'cast', 'pacing', 'narrative', 'lit', 'eye', 'cinematography', 'pseudo', 'john', 'carpenter', 'score', 'stop', 'motion', 'animation', 'quickly', 'end', 'movie', 'extremely', 'amateurish', 'hence', 'quite', 'dreadful', 'would', 'necessary', 'bad', 'film', 'real', 'four', 'star']
# Prediction: neg
# Real: pos
#
# ['one', 'films', 'i', 'happened', 'across', 'the', 'collection', 'usual', 'change', 'pace', 'that', 'turned', 'great', 'decision', 'i', 'almost', 'quality', 'film', 'story', 'told', 'way', 'told', 'the', 'almost', 'feel', 'film', 'dialogue', 'almost', 'constant', 'music', 'added', 'whole', 'level', 'film', 'this', 'really', 'superb', 'film', 'spend', 'time', 'enjoy']
# Prediction: pos
# Real: pos
#
# ['i', 'movie', 'i', 'seen', 'times', 'every', 'time', 'i', 'still', 'get', 'its', 'great', 'love', 'story', 'surprises', 'feel', 'chemistry', 'i', 'give', 'movie', 'perfect', 'i', 'recommend', 'anyone']
# Prediction: pos
# Real: pos

# %%
tc_validation = validate(tc, val_loader)
print('Validation score')
print(tc_validation)
# Out:
# Validation score
# 0.8408
