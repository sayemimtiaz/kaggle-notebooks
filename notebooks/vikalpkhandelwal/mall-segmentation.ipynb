# %% [markdown]
# > # About Data
# >  This data contain informations about customers of a Mall. There is 200 Observations of 5 Variables and the Variables are:-'CustomerID' 'Gender' 'Age' 'Annual.Income..k..' 'Spending.Score..1.100.' DataTypes of Datas are Integer or Factor.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import cufflinks as cf

# %%
df = pd.read_csv("../input/customer-segmentation-tutorial-in-python/Mall_Customers.csv")

# %%
df.head()

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# > #   Pair plot of Data(differentiate by Gender)

# %%
sns.pairplot(df, hue='Gender')

# %% [markdown]
# > # Distribution plot of spending score

# %%
df["Spending Score (1-100)"].describe()

# %%
plt.figure(figsize=(12,6))
sns.distplot(df['Spending Score (1-100)'], kde=False,bins=30)
sns.despine()

# %% [markdown]
# > # Bar plot of spending score(differentiate by Gender)

# %% [markdown]
# **Observations:**
#
# Here we can see that the spending score of Females is more than the spending score of Males.

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Gender',y='Spending Score (1-100)',data=df)
sns.despine()

# %% [markdown]
# > # Count plot of Gender

# %% [markdown]
# **Observations:**
#
# Here we can see that the Females custumers  are more than Male custumers.

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Gender',data=df,palette="vlag")
sns.despine()

# %% [markdown]
# > # Box plot( Gender vs Annual Income)

# %%
plt.figure(figsize=(12,10))
sns.boxplot(x="Gender", y="Annual Income (k$)",data=df, palette="mako")

# %% [markdown]
# > # Box plot( Gender vs Spending score)

# %%
plt.figure(figsize=(12,10))
sns.boxplot(x="Gender", y="Spending Score (1-100)",data=df, palette="icefire")

# %% [markdown]
# > # Correlation Between Data

# %%
x = df.corr()
x

# %% [markdown]
# > # Matrix plot of data

# %%
plt.figure(figsize=(12,6))
sns.heatmap(x,cmap='coolwarm',annot=True,linecolor='white',linewidths=1)

# %% [markdown]
# > # Hist plot of Age

# %% [markdown]
# **Observations:**
#
# Here we can see that the highest custumers are from 30-34 age group.

# %%
plt.figure(figsize=(12,6))
plt.hist(df['Age'])
sns.despine()

# %% [markdown]
# > # Analysis of Annual Income

# %%
df["Annual Income (k$)"].describe()

# %% [markdown]
# > # Density plot of Annual Income

# %%
plt.figure(figsize=(8,5))
df['Annual Income (k$)'].plot.density()

# %% [markdown]
# > # Hist plot of Annual Income

# %%
plt.figure(figsize=(8,5))
df['Annual Income (k$)'].plot(kind='hist')
sns.despine()

# %% [markdown]
# > # lmplot (Age vs Annual Income)

# %%
sns.lmplot(x='Age', y='Annual Income (k$)', data=df, col='Gender', palette='pastel')

# %% [markdown]
# > # lmplot (Age vs Spending score)

# %%
sns.lmplot(x='Age', y='Spending Score (1-100)', data=df, col='Gender', palette='pastel')

# %% [markdown]
# > # lineplot (Annual Income vs Spending score)

# %%
df.plot.line(x='Annual Income (k$)',y='Spending Score (1-100)',figsize=(12,3),lw=1)

# %% [markdown]
# > # Scatterplot (Annual Income vs Spending score)

# %%
df.plot.scatter(x='Annual Income (k$)',y='Spending Score (1-100)')

# %% [markdown]
# > #  Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
df = pd.get_dummies(df, drop_first = True)
df.head()

# %%
X = df.drop('Spending Score (1-100)', axis=1)
y = df['Spending Score (1-100)']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# > # Creating and Training the Model

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)

# %% [markdown]
# >  # Predictions from our Model

# %%
predictions = model.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
sns.distplot((y_test-predictions),bins=30);

# %% [markdown]
# >  # Regression Evaluation Metrics

# %%
from sklearn import metrics

# %% [markdown]
# **Observations:**
#
# Here we can see the different errors between True value and
# predicted value.

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))

# %% [markdown]
# # THANK YOU
