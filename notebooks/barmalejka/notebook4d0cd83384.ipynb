# %%
import pandas as pd
import numpy as np

from transformers import MarianTokenizer, MarianMTModel, pipeline
from typing import List
import torch

from tqdm.autonotebook import  tqdm

pd.set_option('display.max_colwidth', -1)

# %%
# df = pd.read_csv('../input/twitter-airline-sentiment/Tweets.csv')
# src = 'en'  # source language
# trg = 'de'  # target language
# mname = f'Helsinki-NLP/opus-mt-{src}-{trg}'
# model = MarianMTModel.from_pretrained(mname)
# tok = MarianTokenizer.from_pretrained(mname)
# modl = pipeline(task=f'translation_{src}_to_{trg}', model=model, tokenizer=tok, device=0)
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# model.to(device)
# trs = []
# for i in tqdm(range(len(df))):
#     tr = modl(df['text'][i])
