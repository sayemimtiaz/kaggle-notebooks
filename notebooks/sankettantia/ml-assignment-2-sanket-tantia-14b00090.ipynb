# %% [markdown]
# **
#
# Classification between poisonous and edible mushrooms
# -----------------------------------------------------
#
# **

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv("../input/mushrooms.csv")
data.head(10)

# %%
labelEncoder = preprocessing.LabelEncoder()
for col in data.columns:
    data[col] = labelEncoder.fit_transform(data[col])
    
#print(data)

# Splitting test train set, with 40% of the data as the validation set
train, test = train_test_split(data, test_size = 0.6)

# %% [markdown]
# Support Vector Machine is a classifier which separates the data set using a hyper plane.  It selects the optimal hyper plane which maximizes the distance between the two data set. It uses a pre-formatted labelled data to give an output.

# %% [markdown]
# **Support Vector Machines**
# ---------------------------
#
# The SVM is a classifier model which calculates a hyperplane to separate the data.
# It chooses the most optimal hyperplane by maxmizing the distance between the data points.

# %%
# Train set
train_y = train['class']
train_x = train[[x for x in train.columns if 'class' not in x]]
# Test/Validation set
test_y = test['class']
test_x = test[[x for x in test.columns if 'class' not in x]]

model = svm.SVC()
model.fit(train_x, train_y)
print ('The accurancy of SVM is ' + str(accuracy_score(test_y, model.predict(test_x))))

# %% [markdown]
# The decision tree classifiers organizes a series of conditions (features) in a tree like structure. In a decision tree the leaf nodes are the final classification labels where as the non leaf nodes are test and branch nodes are the output on the test. While traversing the tree

# %% [markdown]
# **
# Decision Tree Classifier
# ------------------------
# **
# The decision tree classifiers organizes a series of conditions (features) in a tree like structure. In a decision tree the leaf nodes are the final classification labels where as the non leaf nodes are test conditions and branch nodes are the output on the test conditions.

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(train_x, train_y)

print ('The accurancy of Decision tree classifier  is ' + str(accuracy_score(test_y, model.predict(test_x))))

# %% [markdown]
# **
# Linear Discriminant Analysis
# ----------------------------
# **
# It is a method of finding a linear combination of variables which best separates two or more classes. LDA is not a classification algorithm, although it makes use of class labels. However, the LDA result is mostly used as part of a linear classifier.

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
model = LinearDiscriminantAnalysis()
model.fit(train_x, train_y)
print ('The accurancy of Linear Discriminant Analysis  is ' + str(accuracy_score(test_y, model.predict(test_x))))
