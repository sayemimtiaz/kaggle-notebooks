# %% [markdown]
# # Read the Data

# %%
import pandas as pd

data = pd.read_csv("../input/mushroom-classification/mushrooms.csv")

# %% [markdown]
# # Show the Head and Tail of the Dataset

# %%
data.head()

# %%
data.tail()

# %% [markdown]
# # Edible - Poisonous Distribution

# %%
import seaborn as sns

sns.countplot(data["class"])

# %% [markdown]
# # Data Digitizing with Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for i in data.columns:
    data[i] = le.fit_transform(data[i])

# %% [markdown]
# # Correlation Map for Attributes of the Dataset

# %%
sns.heatmap(data.corr())

# %% [markdown]
# # Input/Output Assignment and Attribute Drop

# %%
X = data.drop(["class","stalk-surface-below-ring","stalk-color-below-ring","gill-attachment","gill-color", "stalk-shape"], axis = 1)
y = data["class"]

# %% [markdown]
# # RandomForestClassifier and Cross Validation

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, cross_val_predict

rfc = RandomForestClassifier()
score = cross_val_score(rfc, X, y, cv=20)
pred = cross_val_predict(rfc, X, y, cv=20)

print((sum(score)/20)*100)

# %% [markdown]
# # Ordinary Least Square(OLS) Module for Backward Elimination

# %%
import statsmodels.api as sm

model = sm.OLS(pred, X).fit()
print(model.summary())

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y, pred)
sns.heatmap(cm, annot = True, cmap = "rocket_r", fmt='g')

# %% [markdown]
# # Classification Report

# %%
from sklearn.metrics import classification_report

print(classification_report(y, pred))
