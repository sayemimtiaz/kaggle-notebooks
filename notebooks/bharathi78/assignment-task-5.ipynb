# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # **1) Load the IMDb Dataset and read**

# %%
data = pd.read_csv("/kaggle/input/imdb-data/IMDB-Movie-Data.csv")
data.head(5)

# %% [markdown]
# # **2)View the dataset**

# %%
# To View the dataset info  

# DType - denots the data type w.r.t to columns

data.info()

# %%
#To get the Stats of the data 

data.describe()

# %%
#Head -> View Top of the Data
data.head(5)

# %%
#tail -> To  View Tail of the Data 
data.tail(5)

# %%
#To View Randomly  -> Unsorrted order 
data.sample(5)

# %% [markdown]
# # **3) Understand some basic information about the dataset and Inspect the dataframe Inspect the dataframe's columns, shapes, variable types etc.**

# %% [markdown]
# # variable types
#
# > Data can be classified into three types:
#
# * Numerical
# * categorical [Objects]
# * Free Type

# %%
# To get the colums

data_columns_name = data.columns
print("\n Columns Name:", data_columns_name)
print("\n Columns Count", len(data_columns_name))

# %%
# To Find the Shape -> .shape()

print("Data Shape",data.shape)

# %% [markdown]
# # 4) Data Selection – Indexing and Slicing data

# %%
data.columns

# %%
#Index

rank = data['Rank']
rank.head(5)

# %%
title = data['Title']
title.head(5)

# %%
#Mutliple Index

new_data = data[['Title','Rank']]
print(new_data)
print(type(new_data))

# %%
#Slicing on rank column
rank[:5]

# %%
# Data Reverse using Slicing
data[::-1]

# %%
#Rank index from 100 to 105
rank[100:105]

# %% [markdown]
# # 5) Data Selection – Based on Conditional filtering

# %%
temp_data = data.copy()

# %%
temp_data = temp_data[temp_data['Rating'] > 8]
print("Movie that have Rating Above 8: ",len(temp_data))

# %%
temp_data_2 = data.copy()
temp_data_2 = temp_data_2[temp_data_2['Rating'] < 2]
print("Movie that have Rating Below 2 ",len(temp_data_2))
temp_data_2['Title']

# %% [markdown]
# > From the above analysis we found that Disaster Movie is the one the worst movie to watch

# %% [markdown]
# # To Find movie with high rating

# %%
max(temp_data['Rating'])

# %%
temp_data_9 = temp_data.copy()
temp_data_9 = temp_data_9[temp_data_9['Rating'] >= 9.0]
temp_data_9

# %% [markdown]
# # The Dark Knight	 is the highest rated movie ever

# %% [markdown]
# # 6)  Groupby operations

# %%
# Lets group the Movies of Director

# %%
director = data.groupby('Director').groups

# director_details = pd.DataFrame(director.items(), columns=['Name', 'Movie Count'])
# director_details
director

# %% [markdown]
# # To Find the Movies released @2015

# %%
grouped = data.groupby('Year')

for name,group in grouped:
   if name == 2015:
       print(name)
       print(group)

# %% [markdown]
# # 7) Sorting operation

# %%
#Sorting Based on Rating -> # Asecnding

data.sort_values('Rating').head(5)

# %%
#Descending Sort 
data.sort_values('Rating',ascending=False).head(5)

# %%
#Descending Sort 
data.sort_values(by = ['Rating','Revenue (Millions)'],ascending=False).head(5)

# %%
#Descending Sort 
data.sort_values(by = ['Rating','Revenue (Millions)']).head(5)

# %% [markdown]
# # 8) Dealing with missing values

# %%
data1 = data.copy()

# %%
#Getting the Null Details

data1.isnull()

# %%
data1.info()

# %%
# data1 = data1.fillna(0)
# data1.info()

# %%
data1 = data1.fillna(method ='pad')
data1.head(1)

# %% [markdown]
# # **9) Dropping columns and null values**

# %%
# Let's Drop the Metascore from our datafarme

data2 = data.copy()
print("Before Deleting", data2.columns)

# %%
data2 = data2.drop('Metascore',axis = 1)
print("After Deleting",data2.columns)

# %% [markdown]
# **Metascore got removed**

# %% [markdown]
# # 10)   Apply( ) functions

# %%
# Adding Sqrt for Rating
data3 = data.copy()
data3['Rating Square'] = data3['Rating'].apply(np.sqrt)
data3
