# %% [markdown]
# Hello Folks,
#
# Due to shortage of GPU on kaggle I could not run on it. I have ran it on Google Colab and imported the dataset as well. Following is the URL of the notebook:
#
# https://colab.research.google.com/drive/1qOkazyNQbFaIrn_mWvSh5LsiUOW5at2w?usp=sharing
#
#
# Also to not disconnect the session I had included javascript code so you may see many New Section cells so you can kindly ignore.
