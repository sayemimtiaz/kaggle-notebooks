# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from matplotlib import pyplot as plt

# %%
fire_nrt_m6 = pd.read_csv('../input/fires-from-space-australia-and-new-zeland/fire_nrt_M6_96619.csv')
fire_nrt_v1 = pd.read_csv('../input/fires-from-space-australia-and-new-zeland/fire_nrt_V1_96617.csv')
fire_archive_m6 = pd.read_csv('../input/fires-from-space-australia-and-new-zeland/fire_archive_M6_96619.csv')
fire_archive_v1 = pd.read_csv('../input/fires-from-space-australia-and-new-zeland/fire_archive_V1_96617.csv')

# %%
fire_archive_m6.head()

# %%
percent_brightness = (fire_nrt_v1['bright_ti5']/fire_nrt_v1['bright_ti4'])*100

# %%
plt.scatter(fire_nrt_v1['longitude'],fire_nrt_v1['latitude'],s = percent_brightness,cmap='viridis',alpha=0.3)
plt.show()

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "https://www.freeworldmaps.net/australia/australia-map.png")

# %% [markdown]
# Following conclusions can be drawn from the near real time visualization of scatter plot :
# 1. South Australia was the least affected with less than 50% of the area infected by forest fires.
# 2. Island region of tasmania was also affected with the forest fire.
# 3. Central region of South Australia is not nearly affected by this visualization.

# %%
percent_brightness_m6 = (fire_nrt_m6['brightness']/fire_nrt_m6['bright_t31'])*100

# %%
plt.scatter(fire_nrt_m6['longitude'],fire_nrt_m6['latitude'],s = percent_brightness_m6,cmap='viridis',alpha=0.3)
plt.show()

# %% [markdown]
# Using the M6 nrt version data the plot can be interpreted as follows:
# 1. 25% of Queensland and close to 75% of South Australia seems to be safe as per this satellite distribution.
# 2. More of the central section of South Australia shown to be safe as compared to V1 NRT version.

# %%
percent_brightness_m6_archive = (fire_archive_m6['brightness']/fire_archive_m6['bright_t31'])*100

# %%
plt.scatter(fire_archive_m6['longitude'],fire_archive_m6['latitude'],s = percent_brightness_m6_archive,cmap='viridis',alpha=0.3)
plt.show()

# %% [markdown]
# Compared to Near Real Time (NRT) Imagery , the archive version of M6 satellite imagery tells us the following:
# 1. New South Wales and Victoria are still unsafe and more prone to forest fires , given the data that we have.
# 2. Forest Fires of October left a bigger destruction trail than the August one.
# 3. Coastal areas of Queensland , whole of Tasmania , south west of Western Australia and north of Northern Australia still a risky place to live in.
# 4. Central region of South Australia , still a safe place.

# %%
percent_brightness_v1_archive = (fire_archive_v1['bright_ti5']/fire_archive_v1['bright_ti4'])*100

# %%
plt.scatter(fire_archive_v1['longitude'],fire_archive_v1['latitude'],s = percent_brightness_v1_archive,cmap='viridis',alpha=0.3)
plt.show()

# %% [markdown]
# Almost similar conclusions can be derived from the V1 archive similar to the M6 archive, except for one which wasn't added in the previous conclusion:
# 1. Coastal region of Southern Australia was less impacted in both archive data of forest fire spread in Oct 2019

# %%
Image(url= "https://www.anbg.gov.au/aust-veg/aust-veg-map.gif")

# %% [markdown]
# Following are the reasons for forest fires:
# Link referred : https://www.vox.com/science-and-health/2020/1/8/21055228/australia-fires-map-animals-koalas-wildlife-smoke-donate
#
# 1. Climate change in recent years contributing to rise in temperature contributing to this phenomenon.
# 2. Lightnings or by accidental sperkings
# 3. There are also instances of deliberate firegeneration by humans which also adds fuel to the fire.

# %% [markdown]
# The trend in forest fires has been on the rise as seen by the archived data and the near real time data (Both of 2019)
# Few points to note:
# 1. The area affected in forest/bush fires in Australia is on the rise and in 2020 this has gone worse.
# 2. This in turn affect the flora and fauna of the given country that is well known for kangaroos and koalas and different species of reptiles , insects and plant species.
# 3. Government needs to step up action on controlling the deliberate action from human population in contributing to the forest fire scenario.
# 4. Doing this might not reduce the case , however it can reduce the people from destroying the resource intensiveness that this country is known for.
# 5. Wildlife can be relocated to safe areas , if the authorities are able to pinpoint the occurence of fires in the affected region.
# 6. Dry lightnings pose a challenge to detect.
# 7. Global warming is a threat that everyone across the world are trying to solve , which if not taken care of seriouslt will affect a country that is near to the equator , ie Australia.
