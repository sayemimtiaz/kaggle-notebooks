# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
import matplotlib.pyplot as plt
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.

# %%
iris = pd.read_csv('../input/iris-flower-dataset/IRIS.csv', names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'])
iris.head()

# %%
fig, ax = plt.subplots()
ax.scatter(iris['sepal_length'], iris['sepal_width'])
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')

# %%
colors = {'Iris-setosa':'r', 'Iris-versicolor':'g', 'Iris-virginica':'b'}
fig, ax = plt.subplots()
for i in range(1,len(iris['sepal_length'])):
    ax.scatter(iris['sepal_length'][i], iris['sepal_width'][i],color=colors[iris['class'][i]])
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')

# %%
# get columns to plot
columns = iris.columns.drop(['class'])
# create x data
x_data = range(0, iris.shape[0])
# create figure and axis
fig, ax = plt.subplots()
# plot each column
for column in columns:
    ax.plot(x_data, iris[column])
# set title and legend
ax.set_title('Iris Dataset')
ax.legend()

# %%
wine_reviews = pd.read_csv('../input/wine-reviews/winemag-data-130k-v2.csv', index_col=0)
sorted(wine_reviews['points'].unique())

# %%
a = iris[1:][iris[1:]['class']=='Iris-setosa']
a.head()

# %%
fig, ax = plt.subplots()
# plot histogram
ax.hist(wine_reviews['points'])
# set title and labels
ax.set_title('Wine Review Scores')
ax.set_xlabel('Points')
ax.set_ylabel('Frequency')

# %%
wine_reviews['points'].value_counts().sort_index().plot.barh()

# %%
wine_reviews['points'].value_counts().sort_index().plot.bar()

# %%
wine_label = wine_reviews['points'].value_counts().sort_index().index.tolist()
wine_size = wine_reviews['points'].value_counts().sort_index().tolist()

# %%
a['sepal_length'].value_counts().sort_index().plot.bar()

# %%
import matplotlib.pyplot as plt
import squarify    
 
squarify.plot(sizes=wine_size[0:10], label=wine_label[0:10],alpha=.7)
plt.axis('off')
plt.show()

# %%
import seaborn as sns
a=iris.head()

# %%
a = iris[1:][iris[1:]['class']=='Iris-virginica']
a[a['sepal_length'] >= '7']

# %%
g = sns.FacetGrid(iris[1:], col='class')
g = g.map(sns.kdeplot, 'sepal_length')

# %%
df_can = pd.read_excel('../input/canadian-immigration-from-1980-to-2013/Canada.xlsx',
                       sheet_name='Canada by Citizenship',
                       skiprows=range(20),
                       skip_footer=2)
df_can

# %%
a = df_can[[i for i in range(1980,2014)]].sum(axis=1)
Total = pd.concat([df_can['OdName'].to_frame(),a.to_frame()],axis=1)
Total.sort_values(by=0,ascending=False, axis=0, inplace=True)
df_top5_country = Total.head(5)
country=df_top5_country['OdName'].unique()
country

# %%
df_top5 = df_can[df_can['OdName'].isin(country) ]
df_top5

# %%
df_top5 = df_top5[[i for i in range(1980,2014)]].transpose()
df_top5.index = df_top5.index.map(int)
df_top5.columns = country
df_top5.plot(kind='area', figsize=(14,8))
 
plt.title('Immigration Trend of Top 5 Countries')
plt.ylabel('Number of Immigration')
plt.xlabel('Years')
plt.show()

# %%
df_top5.plot(kind='line', figsize=(14,8))
 
plt.title('Immigration Trend of Top 5 Countries')
plt.ylabel('Number of Immigration')
plt.xlabel('Years')
plt.show()

# %%
t = pd.concat([df_can[['OdName','AreaName']],a.to_frame()],axis=1)
data_5 = t.groupby(by='AreaName').sum()
data_5

# %%
data_5[0].plot(kind='pie',
                            figsize=(16, 5),
                            autopct='%1.1f%%', # add in percentages
                            startangle=90,     # start angle 90° (Africa)
                            shadow=True,       # add shadow      
                            )
 
plt.title('Immigration to Canada by Continent [1980 - 2013]')

plt.axis('equal') # Sets the pie chart to look like a circle.
plt.legend(labels=data_5.index) 
plt.show()

# %%
colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']
explode_list = [0.1, 0, 0, 0, 0.1, 0.1] # ratio for each continent with which to offset each wedge.
 
data_5[0].plot(kind='pie',
                            figsize=(15, 6),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None,         # turn off labels on pie chart
                            pctdistance=1.12,    # the ratio between the center of each pie slice and the start of the text generated by autopct 
                            colors=colors_list,  # add custom colors
                            explode=explode_list # 'explode' lowest 3 continents
                            )
 
# scale the title up by 12% to match pctdistance
plt.title('Immigration to Canada by Continent [1980 - 2013]', y=1.12) 
 
plt.axis('equal') 
 
# add legend
plt.legend(labels=data_5.index) 
 
plt.show()

# %%
# !wget --quiet https://ibm.box.com/shared/static/m54sjtrshpt5su20dzesl5en9xa5vfz1.txt -O alice_novel.txt
# !ls

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
alice_novel = open('alice_novel.txt', 'r').read()
 
stopwords = set(STOPWORDS)
stopwords

# %%
alice_wc = WordCloud(
    background_color='white',
    max_words=2000,
    stopwords=stopwords
)
alice_wc.generate(alice_novel)
print(alice_wc)
fig = plt.figure()
fig.set_figwidth(14)
fig.set_figheight(18)
 
plt.imshow(alice_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
df_tot = pd.DataFrame(df_can[[i for i in range(1980,2014)]].sum(axis=0))

df_tot.index = map(float,df_tot.index)
 
df_tot.reset_index(inplace = True)
df_tot.columns = ['year', 'total']
import seaborn as sns
ax = sns.regplot(x='year', y='total', data=df_tot)

# %%
fig, ax = plt.subplots(round(6 / 3), 3, figsize = (18, 12))
for i,ax in enumerate(fig.axes):
    print(i,ax)

# %%
import seaborn as sns

df_tot = pd.DataFrame(df_can[[i for i in range(1980,2014)]])

df_tot1 = df_tot.transpose()
fig, ax = plt.subplots(round(6 / 3), 3, figsize = (18, 12))
for i,ax in enumerate(fig.axes):
    df_tot = pd.DataFrame(df_tot1[i])
    df_tot.index = map(float,df_tot.index)
    df_tot.reset_index(inplace = True)
    df_tot.columns = ['year', df_can[['OdName']].iat[i,0]]
    sns.regplot(x='year', y= df_tot.columns[1], data=df_tot,ax=ax)

# %%
print(__doc__)

# Author: Kemal Eren <kemal@kemaleren.com>
# License: BSD 3 clause

import numpy as np
from matplotlib import pyplot as plt

from sklearn.datasets import make_biclusters
from sklearn.datasets import samples_generator as sg
from sklearn.cluster.bicluster import SpectralCoclustering
from sklearn.metrics import consensus_score

data, rows, columns = make_biclusters(
    shape=(300, 300), n_clusters=5, noise=5,
    shuffle=False, random_state=0)

plt.matshow(data, cmap=plt.cm.Blues)
plt.title("Original dataset")

data, row_idx, col_idx = sg._shuffle(data, random_state=0)
plt.matshow(data, cmap=plt.cm.Blues)
plt.title("Shuffled dataset")

model = SpectralCoclustering(n_clusters=5, random_state=0)
model.fit(data)
score = consensus_score(model.biclusters_,
                        (rows[:, row_idx], columns[:, col_idx]))

print("consensus score: {:.3f}".format(score))

fit_data = data[np.argsort(model.row_labels_)]
fit_data = fit_data[:, np.argsort(model.column_labels_)]
plt.matshow(fit_data, cmap=plt.cm.Blues)
plt.title("After biclustering; rearranged to show biclusters")

plt.show()

# %%
df = pd.read_csv('../input/avocado-prices/avocado.csv')
df.head()

# %%
df.corr()

# %%
df.corr()
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True,cmap="Blues")

# %%
from bokeh.io import show, output_notebook
from bokeh.palettes import PuBu4
from bokeh.plotting import figure
from bokeh.models import Label
output_notebook()
data= [("John Smith", 105, 120),
       ("Jane Jones", 99, 110),
       ("Fred Flintstone", 109, 125),
       ("Barney Rubble", 135, 123),
       ("Mr T", 45, 105)]

limits = [0, 20, 60, 100, 160]
labels = ["Poor", "OK", "Good", "Excellent"]
cats = [x[0] for x in data]

p=figure(title="Sales Rep Performance", plot_height=350, plot_width=800, y_range=cats)
p.x_range.range_padding = 0
p.grid.grid_line_color = None
p.xaxis[0].ticker.num_minor_ticks = 0

# %%
zip(limits[:-1], limits[1:], PuBu4[::-1])

# %%
for left, right, color in zip(limits[:-1], limits[1:], PuBu4[::-1]):
    p.hbar(y=cats, left=left, right=right, height=0.8, color=color)

# %%
perf = [x[1] for x in data]
p.hbar(y=cats, left=0, right=perf, height=0.3, color="black")

# %%
comp = [x[2]for x in data]
p.segment(x0=comp, y0=[(x, -0.5) for x in cats], x1=comp,
          y1=[(x, 0.5) for x in cats], color="white", line_width=2)

# %%
data = [np.random.normal(0,i,100) for i in range(1,5)]
plt.boxplot(data, vert=True,patch_artist=True)

# %%
giapschool = pd.read_csv('../input/giapschool/courses.csv', names=['course_id','course_name','teacher_id','category_id','status','lesson_id','lesson_name'])
giapschool.head(10)

# %%
giapschool['course_name'].value_counts().head()

# %%
giapschool['course_name'].value_counts().sort_index().plot.bar(figsize=(,6))
print("Thong ke so bai hoc trong khoa hoc")

# %%
giapschool['status'].value_counts().sort_index().plot.bar()

# %%
iss_teacher = pd.read_csv('../input/issdata/teachers.csv', names=['id','user_id','title','degree','professor_title','resume','created_time','modified_time'])
iss_teacher.head()

# %%
iss_teacher = iss_teacher.replace('Tiến sỹ', 'Tiến sĩ')
iss_teacher = iss_teacher.replace('Cử nhân ', 'Cử nhân')
iss_teacher['degree'].value_counts()

# %%
temp = pd.Series(iss_teacher['degree'].isnull().sum(), index=['null'])
a = iss_teacher['degree'].value_counts().append(temp)
a.sort_index().plot(kind='pie',
                            figsize=(10, 5),
                            autopct='%1.1f%%', # add in percentages
                            startangle=90,     # start angle 90° (Africa)
                            shadow=True,       # add shadow      
                            )

plt.title('Trình độ của giáo viên trong iss')

plt.axis('equal') # Sets the pie chart to look like a circle.
plt.legend(labels=a.sort_index().index) 
plt.show()

# %%
iss_teacher_sub = pd.read_csv('../input/issdata/teacher_subjects.csv', names=['id','teacher_id','subject_id','created_time','modified_time'])
iss_teacher_sub.head()

# %%
iss_subject = pd.read_csv('../input/issdata/subjects.csv', names=['id','parent_id','name','short_name','url','code','ordering','removable','created_time','modified_time'])
iss_subject.head()

# %%
subjects = iss_subject['name'].tolist()
total_teacher_per_sub = iss_teacher_sub['subject_id'].value_counts().sort_index()
total_teacher_per_sub

# %%
teachers_id = iss_teacher_sub[iss_teacher_sub['subject_id']==1]
teachers_id = teachers_id['teacher_id'].tolist()

# %%
degree = iss_teacher['degree'].value_counts().sort_index()
degree[[i for i in range(len(degree))]] = 0
degree = degree.append(pd.Series(0,index=['null']))
degree

# %%
degree_teachers= iss_teacher[iss_teacher['id'].isin(teachers_id)]
degree_teachers = degree_teachers['degree']
temp = pd.Series(degree_teachers.isnull().sum(), index=['null'])
total_degree = degree_teachers.value_counts().append(temp)

# %%
total_degree

# %%
degree[[total_degree.index[i] for i in range(len(total_degree))]] = total_degree.tolist()
degree

# %%
raw_data = {}
for i in range(len(degree)):
    raw_data[degree.index[i]] = []
raw_data

# %%
for sub in range(1,len(total_teacher_per_sub)+1):
    #filter teachers_id each subject
    teachers_id = iss_teacher_sub[iss_teacher_sub['subject_id']==sub]
    teachers_id = teachers_id['teacher_id'].tolist()
    
    #filter degree of teacher each subject
    degree_teachers= iss_teacher[iss_teacher['id'].isin(teachers_id)]
    degree_teachers = degree_teachers['degree']
    temp = pd.Series(degree_teachers.isnull().sum(), index=['null'])
    total_degree = degree_teachers.value_counts().append(temp)
    
    degree = iss_teacher['degree'].value_counts().sort_index()
    degree[[i for i in range(len(degree))]] = 0
    degree = degree.append(pd.Series(0,index=['null']))

    degree[[total_degree.index[i] for i in range(len(total_degree))]] = total_degree.tolist()
    for i in range(len(degree)):
        raw_data[degree.index[i]].append(degree[i])
raw_data

# %%
# Data
r = [i for i in range(len(total_teacher_per_sub))]
df = pd.DataFrame(raw_data)
 
# From raw value to percentage
totals = [i+j+k+l for i,j,k,l in zip(df['Cử nhân'], df['Thạc sĩ'], df['Tiến sĩ'],df['null'])]
greenBars = [i / j * 100 for i,j in zip(df['Cử nhân'], totals)]
print(greenBars)
orangeBars = [i / j * 100 for i,j in zip(df['Thạc sĩ'], totals)]
print(orangeBars)
if df['Tiến sĩ'].sum() == 0:
    blueBars = [0 for i in range(len(total_teacher_per_sub))]
else:
    blueBars = [i / j * 100 for i,j in zip(df['Tiến sĩ'], totals)]
print(blueBars)
blackBars = [i / j * 100 for i,j in zip(df['null'], totals)]
print(blackBars)

# plot
barWidth = 0.85
names = subjects[0:8]
plt.figure(figsize=(12,6))
# Create green Bars
plt.bar(r, greenBars, color='r', edgecolor='white', width=barWidth)
# Create orange Bars
plt.bar(r, orangeBars, bottom=greenBars, color='b', edgecolor='white', width=barWidth)
# Create blue Bars
plt.bar(r, blueBars, bottom=[i+j for i,j in zip(greenBars, orangeBars)], color='#000000',
        edgecolor='white', width=barWidth)
plt.bar(r, blackBars, bottom=[i+j+k for i,j,k in zip(greenBars, orangeBars,blueBars)], color='g',
        edgecolor='white', width=barWidth)
 
# Custom x axis
plt.xticks(r, names)
plt.xlabel("Trình độ của các giáo viên trong từng môn học (dữ liệu iss)")
plt.legend(labels=df.columns) 
# Show graphic
plt.show()
