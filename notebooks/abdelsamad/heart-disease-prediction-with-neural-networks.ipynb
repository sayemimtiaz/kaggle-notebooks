# %% [markdown]
# **Heart Disease Prediction with Neural Networks**
#
# I chose this to be my very first Kernel on Kaggle, as in fact I quite enjoy the applications of Machine learning and how it impacts our lives. I am an *absolute beginner* as well and just breaking into the field. Thus, this kernel is more focused for learning purposes and exploration. Please feel free to give advice, recommendations/ better approaches or whatsover on the code below.
#
# The heart disease data-set is a quite small dataset with today's modern standards. In this kernel first, I'll do a small bit of data exploration then, I try to create a very simple and straightforward model. That we analyze later, and try to improve its performance.
#
# First of all, lets add all packages that we will use.

# %%
# Import packages that we will be working with.
import os
import numpy as np
import pandas as pd
from keras.layers import Dense
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense
from tensorflow.python.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

print(os.listdir("../input"))
np.random.seed(10)
# Out:
# ['heart.csv']

# %% [markdown]
# **Dataset**
#
# Lets load the dataset, and check its components.

# %%
# Load the dataset, and view couple of the first rows.
data = pd.read_csv("../input/heart.csv")
print(data.head(3))

# Check the datatypes
print(data.dtypes)
# Out:
#    age  sex  cp  trestbps  chol   ...    oldpeak  slope  ca  thal  target
# 0   63    1   3       145   233   ...        2.3      0   0     1       1
# 1   37    1   2       130   250   ...        3.5      0   0     2       1
# 2   41    0   1       130   204   ...        1.4      2   0     2       1
#
# [3 rows x 14 columns]
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %% [markdown]
# So far we have a dataframe that containts all of our data. However we need to split to training data and target labels for learning. Then split the dataset into a train/test sets.
#
# We do that in the following block of code.

# %%
# At this moment we have a dataframe that contains all of the heart.csv data. However we need to
# Separate them to [X, Y]. Where our target labels are 'Y', and 'X' is our training data.
Y = data.target.values
X = data.drop(['target'], axis=1)

# Now split to train/test with 80% training data, and 20% test data.
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Check dimensions of both sets.
print("Train Features Size:", X_train.shape)
print("Test Features Size:", X_test.shape)
print("Train Labels Size:", Y_train.shape)
print("Test Labels Size:", Y_test.shape)
# Out:
# Train Features Size: (242, 13)
# Test Features Size: (61, 13)
# Train Labels Size: (242,)
# Test Labels Size: (61,)

# %% [markdown]
# **Neural Network Model**
#
# Lets create a function that we can call later that builds our Neural Network model, and takes in the learning rate as a parameter. The architecture of the Neural Network that we're going to implement is detailed in the below illustration.
# ![](https://raw.githubusercontent.com/3absamad/machine-learning/master/Kaggle/imgs/Kaggle_heart_disease_NN_model.png)
# In our model, we use `Adam` (Adaptive Momentum) as our optimization algorithm, and set our metrics to `accuracy`. Furthermore, I have used the loss function to be `sparse_categorical_crossentropy` because our traget labels are *integers* and not one hot encoded.

# %%
# Define a Neural Network Model

def NN_model(learning_rate):
    model = Sequential()
    model.add(Dense(32, input_dim=13, kernel_initializer='normal', activation='relu'))
    model.add(Dense(16, kernel_initializer='normal', activation='relu'))
    model.add(Dense(2, activation='softmax'))
    Adam(lr=learning_rate)
    model.compile(loss='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
    return model

# %% [markdown]
# Now lets build the NN-model and start training. I chose `learning_rate=0.01`, `epochs=100`, and `batch_size=16`.
#
# Training the model for 100 epochs, seems to be pretty fine in order to avoid overfitting. I already performed training with 1000 epochs and around 100 epochs was the reasonable number of epochs for early stopping.
#
# Lets take a look at our model summary.

# %%
# Build a NN-model, and start training
learning_rate = 0.01
model = NN_model(learning_rate)
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             (None, 32)                448
# _________________________________________________________________
# dense_25 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_26 (Dense)             (None, 2)                 34
# =================================================================
# Total params: 1,010
# Trainable params: 1,010
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Now we train the network.

# %%
history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=100, batch_size=16, verbose=2)
# Out:
# Train on 242 samples, validate on 61 samples
# Epoch 1/100
#  - 0s - loss: 0.7842 - acc: 0.5537 - val_loss: 0.7240 - val_acc: 0.5902
# Epoch 2/100
#  - 0s - loss: 0.6798 - acc: 0.6157 - val_loss: 0.5780 - val_acc: 0.7213
# Epoch 3/100
#  - 0s - loss: 0.6311 - acc: 0.6281 - val_loss: 0.5302 - val_acc: 0.8033
# Epoch 4/100
#  - 0s - loss: 0.6147 - acc: 0.6488 - val_loss: 0.5421 - val_acc: 0.7541
# Epoch 5/100
#  - 0s - loss: 0.6033 - acc: 0.6901 - val_loss: 0.5108 - val_acc: 0.8033
# Epoch 6/100
#  - 0s - loss: 0.5826 - acc: 0.6818 - val_loss: 0.4953 - val_acc: 0.8197
# Epoch 7/100
#  - 0s - loss: 0.6077 - acc: 0.6570 - val_loss: 0.4939 - val_acc: 0.8197
# Epoch 8/100
#  - 0s - loss: 0.5690 - acc: 0.7107 - val_loss: 0.4800 - val_acc: 0.8197
# Epoch 9/100
#  - 0s - loss: 0.5599 - acc: 0.7025 - val_loss: 0.5558 - val_acc: 0.7213
# Epoch 10/100
#  - 0s - loss: 0.5817 - acc: 0.6818 - val_loss: 0.5005 - val_acc: 0.7869
# Epoch 11/100
#  - 0s - loss: 0.5566 - acc: 0.6942 - val_loss: 0.5232 - val_acc: 0.7377
# Epoch 12/100
#  - 0s - loss: 0.6341 - acc: 0.6446 - val_loss: 0.4672 - val_acc: 0.8197
# Epoch 13/100
#  - 0s - loss: 0.5431 - acc: 0.7190 - val_loss: 0.4583 - val_acc: 0.8361
# Epoch 14/100
#  - 0s - loss: 0.5545 - acc: 0.7190 - val_loss: 0.4440 - val_acc: 0.8361
# Epoch 15/100
#  - 0s - loss: 0.5227 - acc: 0.7190 - val_loss: 0.4383 - val_acc: 0.8361
# Epoch 16/100
#  - 0s - loss: 0.5411 - acc: 0.7066 - val_loss: 0.4406 - val_acc: 0.8361
# Epoch 17/100
#  - 0s - loss: 0.5249 - acc: 0.7149 - val_loss: 0.4543 - val_acc: 0.8033
# Epoch 18/100
#  - 0s - loss: 0.5505 - acc: 0.7066 - val_loss: 0.4633 - val_acc: 0.7869
# Epoch 19/100
#  - 0s - loss: 0.6190 - acc: 0.6736 - val_loss: 0.4346 - val_acc: 0.8361
# Epoch 20/100
#  - 0s - loss: 0.5276 - acc: 0.7397 - val_loss: 0.4365 - val_acc: 0.8197
# Epoch 21/100
#  - 0s - loss: 0.5012 - acc: 0.7521 - val_loss: 0.4204 - val_acc: 0.8689
# Epoch 22/100
#  - 0s - loss: 0.4913 - acc: 0.7603 - val_loss: 0.4152 - val_acc: 0.8361
# Epoch 23/100
#  - 0s - loss: 0.4807 - acc: 0.7686 - val_loss: 0.4375 - val_acc: 0.8033
# Epoch 24/100
#  - 0s - loss: 0.4904 - acc: 0.7686 - val_loss: 0.3997 - val_acc: 0.8525
# Epoch 25/100
#  - 0s - loss: 0.4840 - acc: 0.7769 - val_loss: 0.3953 - val_acc: 0.8525
# Epoch 26/100
#  - 0s - loss: 0.5536 - acc: 0.7025 - val_loss: 0.4259 - val_acc: 0.8197
# Epoch 27/100
#  - 0s - loss: 0.4920 - acc: 0.7645 - val_loss: 0.3765 - val_acc: 0.8525
# Epoch 28/100
#  - 0s - loss: 0.4643 - acc: 0.7686 - val_loss: 0.3826 - val_acc: 0.8361
# Epoch 29/100
#  - 0s - loss: 0.4691 - acc: 0.7645 - val_loss: 0.4787 - val_acc: 0.7705
# Epoch 30/100
#  - 0s - loss: 0.4989 - acc: 0.7562 - val_loss: 0.3887 - val_acc: 0.8689
# Epoch 31/100
#  - 0s - loss: 0.4328 - acc: 0.8264 - val_loss: 0.3937 - val_acc: 0.8689
# Epoch 32/100
#  - 0s - loss: 0.4598 - acc: 0.7810 - val_loss: 0.3740 - val_acc: 0.8689
# Epoch 33/100
#  - 0s - loss: 0.4676 - acc: 0.7934 - val_loss: 0.3940 - val_acc: 0.8361
# Epoch 34/100
#  - 0s - loss: 0.5224 - acc: 0.7397 - val_loss: 0.3727 - val_acc: 0.8689
# Epoch 35/100
#  - 0s - loss: 0.4459 - acc: 0.8058 - val_loss: 0.3621 - val_acc: 0.8525
# Epoch 36/100
#  - 0s - loss: 0.4168 - acc: 0.8306 - val_loss: 0.3560 - val_acc: 0.8525
# Epoch 37/100
#  - 0s - loss: 0.4240 - acc: 0.8182 - val_loss: 0.3522 - val_acc: 0.8689
# Epoch 38/100
#  - 0s - loss: 0.4756 - acc: 0.7397 - val_loss: 0.3651 - val_acc: 0.8689
# Epoch 39/100
#  - 0s - loss: 0.4323 - acc: 0.8223 - val_loss: 0.3565 - val_acc: 0.8852
# Epoch 40/100
#  - 0s - loss: 0.3968 - acc: 0.8430 - val_loss: 0.3502 - val_acc: 0.8689
# Epoch 41/100
#  - 0s - loss: 0.3986 - acc: 0.8347 - val_loss: 0.3540 - val_acc: 0.8689
# Epoch 42/100
#  - 0s - loss: 0.3957 - acc: 0.8182 - val_loss: 0.4208 - val_acc: 0.8197
# Epoch 43/100
#  - 0s - loss: 0.3997 - acc: 0.8223 - val_loss: 0.3375 - val_acc: 0.8852
# Epoch 44/100
#  - 0s - loss: 0.4052 - acc: 0.8264 - val_loss: 0.3395 - val_acc: 0.8852
# Epoch 45/100
#  - 0s - loss: 0.3950 - acc: 0.8471 - val_loss: 0.4490 - val_acc: 0.7705
# Epoch 46/100
#  - 0s - loss: 0.4094 - acc: 0.8017 - val_loss: 0.3918 - val_acc: 0.8197
# Epoch 47/100
#  - 0s - loss: 0.3932 - acc: 0.8471 - val_loss: 0.3983 - val_acc: 0.8197
# Epoch 48/100
#  - 0s - loss: 0.4839 - acc: 0.7562 - val_loss: 0.3948 - val_acc: 0.8197
# Epoch 49/100
#  - 0s - loss: 0.4886 - acc: 0.7727 - val_loss: 0.3519 - val_acc: 0.8852
# Epoch 50/100
#  - 0s - loss: 0.4014 - acc: 0.8347 - val_loss: 0.3442 - val_acc: 0.8689
# Epoch 51/100
#  - 0s - loss: 0.3925 - acc: 0.8182 - val_loss: 0.4118 - val_acc: 0.8197
# Epoch 52/100
#  - 0s - loss: 0.3749 - acc: 0.8554 - val_loss: 0.3482 - val_acc: 0.8852
# Epoch 53/100
#  - 0s - loss: 0.3819 - acc: 0.8264 - val_loss: 0.4204 - val_acc: 0.7869
# Epoch 54/100
#  - 0s - loss: 0.3800 - acc: 0.8347 - val_loss: 0.6048 - val_acc: 0.7377
# Epoch 55/100
#  - 0s - loss: 0.4653 - acc: 0.7851 - val_loss: 0.4006 - val_acc: 0.8197
# Epoch 56/100
#  - 0s - loss: 0.3783 - acc: 0.8430 - val_loss: 0.3793 - val_acc: 0.8525
# Epoch 57/100
#  - 0s - loss: 0.3650 - acc: 0.8636 - val_loss: 0.3706 - val_acc: 0.8525
# Epoch 58/100
#  - 0s - loss: 0.3749 - acc: 0.8430 - val_loss: 0.3719 - val_acc: 0.8689
# Epoch 59/100
#  - 0s - loss: 0.3787 - acc: 0.8306 - val_loss: 0.3876 - val_acc: 0.8361
# Epoch 60/100
#  - 0s - loss: 0.3849 - acc: 0.8388 - val_loss: 0.3428 - val_acc: 0.8852
# Epoch 61/100
#  - 0s - loss: 0.3837 - acc: 0.8388 - val_loss: 0.4211 - val_acc: 0.7869
# Epoch 62/100
#  - 0s - loss: 0.3653 - acc: 0.8430 - val_loss: 0.3637 - val_acc: 0.8689
# Epoch 63/100
#  - 0s - loss: 0.3925 - acc: 0.8512 - val_loss: 0.3902 - val_acc: 0.8361
# Epoch 64/100
#  - 0s - loss: 0.3730 - acc: 0.8306 - val_loss: 0.3456 - val_acc: 0.8852
# Epoch 65/100
#  - 0s - loss: 0.3989 - acc: 0.8099 - val_loss: 0.3525 - val_acc: 0.8689
# Epoch 66/100
#  - 0s - loss: 0.3649 - acc: 0.8554 - val_loss: 0.3692 - val_acc: 0.8689
# Epoch 67/100
#  - 0s - loss: 0.3697 - acc: 0.8554 - val_loss: 0.3739 - val_acc: 0.8689
# Epoch 68/100
#  - 0s - loss: 0.3629 - acc: 0.8471 - val_loss: 0.3786 - val_acc: 0.8525
# Epoch 69/100
#  - 0s - loss: 0.3623 - acc: 0.8595 - val_loss: 0.4123 - val_acc: 0.8033
# Epoch 70/100
#  - 0s - loss: 0.3612 - acc: 0.8554 - val_loss: 0.3810 - val_acc: 0.8525
# Epoch 71/100
#  - 0s - loss: 0.3747 - acc: 0.8347 - val_loss: 0.4385 - val_acc: 0.7869
# Epoch 72/100
#  - 0s - loss: 0.3735 - acc: 0.8223 - val_loss: 0.3974 - val_acc: 0.8361
# Epoch 73/100
#  - 0s - loss: 0.3918 - acc: 0.8223 - val_loss: 0.4389 - val_acc: 0.8033
# Epoch 74/100
#  - 0s - loss: 0.3665 - acc: 0.8554 - val_loss: 0.3695 - val_acc: 0.8689
# Epoch 75/100
#  - 0s - loss: 0.3625 - acc: 0.8554 - val_loss: 0.3667 - val_acc: 0.8689
# Epoch 76/100
#  - 0s - loss: 0.4179 - acc: 0.8017 - val_loss: 0.3426 - val_acc: 0.8852
# Epoch 77/100
#  - 0s - loss: 0.3698 - acc: 0.8554 - val_loss: 0.3604 - val_acc: 0.8852
# Epoch 78/100
#  - 0s - loss: 0.3790 - acc: 0.8388 - val_loss: 0.4066 - val_acc: 0.8197
# Epoch 79/100
#  - 0s - loss: 0.3757 - acc: 0.8512 - val_loss: 0.4789 - val_acc: 0.7541
# Epoch 80/100
#  - 0s - loss: 0.3960 - acc: 0.8140 - val_loss: 0.3911 - val_acc: 0.8525
# Epoch 81/100
#  - 0s - loss: 0.3805 - acc: 0.8306 - val_loss: 0.3527 - val_acc: 0.8689
# Epoch 82/100
#  - 0s - loss: 0.4277 - acc: 0.7769 - val_loss: 0.4306 - val_acc: 0.8197
# Epoch 83/100
#  - 0s - loss: 0.3716 - acc: 0.8512 - val_loss: 0.3700 - val_acc: 0.8689
# Epoch 84/100
#  - 0s - loss: 0.3547 - acc: 0.8512 - val_loss: 0.3825 - val_acc: 0.8689
# Epoch 85/100
#  - 0s - loss: 0.3488 - acc: 0.8636 - val_loss: 0.3519 - val_acc: 0.8852
# Epoch 86/100
#  - 0s - loss: 0.3644 - acc: 0.8430 - val_loss: 0.3897 - val_acc: 0.8525
# Epoch 87/100
#  - 0s - loss: 0.3522 - acc: 0.8554 - val_loss: 0.4080 - val_acc: 0.8361
# Epoch 88/100
#  - 0s - loss: 0.3877 - acc: 0.8306 - val_loss: 0.4287 - val_acc: 0.8361
# Epoch 89/100
#  - 0s - loss: 0.4257 - acc: 0.8058 - val_loss: 0.6183 - val_acc: 0.7541
# Epoch 90/100
#  - 0s - loss: 0.4798 - acc: 0.7810 - val_loss: 0.3923 - val_acc: 0.8361
# Epoch 91/100
#  - 0s - loss: 0.3752 - acc: 0.8430 - val_loss: 0.3431 - val_acc: 0.8852
# Epoch 92/100
#  - 0s - loss: 0.3931 - acc: 0.8264 - val_loss: 0.3406 - val_acc: 0.8852
# Epoch 93/100
#  - 0s - loss: 0.3606 - acc: 0.8182 - val_loss: 0.4025 - val_acc: 0.8361
# Epoch 94/100
#  - 0s - loss: 0.3599 - acc: 0.8512 - val_loss: 0.4227 - val_acc: 0.8361
# Epoch 95/100
#  - 0s - loss: 0.3587 - acc: 0.8554 - val_loss: 0.3558 - val_acc: 0.8689
# Epoch 96/100
#  - 0s - loss: 0.3597 - acc: 0.8471 - val_loss: 0.3546 - val_acc: 0.8852
# Epoch 97/100
#  - 0s - loss: 0.3443 - acc: 0.8430 - val_loss: 0.4277 - val_acc: 0.8197
# Epoch 98/100
#  - 0s - loss: 0.3528 - acc: 0.8512 - val_loss: 0.3887 - val_acc: 0.8197
# Epoch 99/100
#  - 0s - loss: 0.3482 - acc: 0.8595 - val_loss: 0.4292 - val_acc: 0.8197
# Epoch 100/100
#  - 0s - loss: 0.3716 - acc: 0.8223 - val_loss: 0.3466 - val_acc: 0.8852

# %% [markdown]
# We plot the `Model Accuracy`, and `Model Loss`  vs. the number of `Epochs`.

# %%
# Plot the model accuracy vs. number of Epochs
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Test'])
plt.show()

# Plot the Loss function vs. number of Epochs
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Test'])
plt.show()

# %% [markdown]
# Evaluating our model's performance, we define the f1 score to be:
#
# $$f1 = \frac{precision^{-1} + recall^{-1}}{2}$$
#
#
# $$precision = \frac{\textit{true positives}}{\textit{true positives} + \textit{false positives}}$$
#
# $$recall = \frac{\textit{true positives}}{\textit{true positives} + \textit{false negatives}}$$
#
# Check this [Wikipedia](http://https://en.wikipedia.org/wiki/Precision_and_recall) page for more details on precision and recall.
#
# We compute our model's predictions on the test set `X_test` and print a `classfication_report` from the imported package `sklearn.metrics`.

# %%
predictions = np.argmax(model.predict(X_test), axis=1)
model_accuracy = accuracy_score(Y_test, predictions)*100
print("Model Accracy:", model_accuracy,"%")
print(classification_report(Y_test, predictions))
# Out:
# Model Accracy: 88.52459016393442 %
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.88        29
#            1       0.88      0.91      0.89        32
#
#    micro avg       0.89      0.89      0.89        61
#    macro avg       0.89      0.88      0.88        61
# weighted avg       0.89      0.89      0.89        61

# %% [markdown]
# With a model accuracy of around 88% and very similar $f1$ score, we have a very good performing model that generalizes well to the test set.
