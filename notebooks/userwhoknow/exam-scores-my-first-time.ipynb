# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.

# %%
import pandas as pd
import matplotlib as plt
data = pd.read_csv("../input/StudentsPerformance.csv")
data = data.rename(columns={'math score': 'mathscore', 'reading score': 'readingscore'})
data.mathscore.plot( color = 'b',linewidth=1,label = "math",alpha = 0.5,grid = True)
data.readingscore.plot(color = 'y',linewidth=1,label = "reading", alpha = 0.5,grid = True)
#plt.title("READİNG AND MATH RESULTS") #WYH THİS COD İS NOT WORKİNG  CAN HELP ME ? 
plt.legend(loc='upper right')     # legend = puts label into plot
plt.xlabel('x axis')              # label = name of label
plt.ylabel('y axis')
plt.title('READİNG AND MATH RESULTS')            # title = title of plot
plt.show()
plt.show()

#THERE ARE A LOT OF LABELS WHİCH ARE DOESN'T WORK ......

# %% [markdown]
# **As you see , math and reading scores has same  result... ** but I have problems with code. There are a lot of problems and I researched them but I couldn't solve them. Have you any suggest for me ?

# %%
data.head()

# %%
print(data['parental level of education'].value_counts(dropna =True))

# %%
data.boxplot(column='mathscore',by = 'parental level of education',figsize=(12,12))

# %% [markdown]
# now comparing time for same level school's while studying vs. degree

# %%
filtredx = data["parental level of education"] == "bachelor's degree"
filtrewx = data["parental level of education"] == "some college"
filtred = data[filtredx]
filtrew = data[filtrewx]
karısım = pd.concat([filtred,filtrew],axis=0,ignore_index=True)
#karısım.plot(kind = "scatter",x = "some college",y ="bachelor's degree") and this is not working :/
karısım.mathscore.plot( color = 'b',linewidth =1,label = "math",alpha = 0.5,grid = True)

# %%
filtref= data.gender == "female"
filtrem = data.gender == "male"
datafemale = data[filtref]
datamale = data[filtrem]
datafemale.plot(kind = "scatter",grid = True,x ="mathscore",y ="readingscore")
#plt.title("Female ") this code is not working .... You can say why ?
datamale.plot(kind = "scatter",grid = True,x ="mathscore",y ="readingscore")
#plt.title("Male ") same as to

# %%
data.plot(kind = "scatter",datafemale.mathscore,datamale.mathscore,alpha = 0.5 , color = "red")# this is not working and I am got used to that.However can you explain me if there is anyone there :D 
plt.show()

# %% [markdown]
# I wanted to compare two different data source but I could not . if you know can you explain to me .
