# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df=pd.read_csv("../input/summer-products-and-sales-in-ecommerce-wish/summer-products-with-rating-and-performance_2020-08.csv",encoding='ISO-8859-1')
df=df.drop(["merchant_profile_picture","urgency_text","has_urgency_banner"],axis=1)
df
newdf=df[(df['product_variation_size_id'] == 'L') | (df['product_variation_size_id'] == 'M') | (df['product_variation_size_id'] == 'S') | (df['product_variation_size_id'] == 'XS') | (df['product_variation_size_id'] == 'XXS') | (df['product_variation_size_id'] == 'XL') | (df['product_variation_size_id'] == 'XXL') | (df['product_variation_size_id'] == 'XXXL') | (df['product_variation_size_id'] == 'XXXXL')]
newdf
newdf['product_variation_size_id']
df.dropna(subset=['product_color','product_variation_size_id','merchant_info_subtitle','merchant_name','origin_country','rating_one_count','rating_two_count','rating_three_count','rating_four_count','rating_five_count'], inplace=True)
df
df.boxplot(column=['rating'])
df
df.hist(column='price')
df

# %%
import matplotlib.pyplot as plt
df.hist(column='rating')

# %%
df.dropna(subset=['product_variation_size_id'],inplace=True)
df

# %%
newdf=df[(df['product_variation_size_id'] == 'L') | (df['product_variation_size_id'] == 'M') | (df['product_variation_size_id'] == 'S') | (df['product_variation_size_id'] == 'XS') | (df['product_variation_size_id'] == 'XXS') | (df['product_variation_size_id'] == 'XL') | (df['product_variation_size_id'] == 'XXL') | (df['product_variation_size_id'] == 'XXXL') | (df['product_variation_size_id'] == 'XXXXL')]
newdf

# %%
newdf['product_variation_size_id']

# %%
df.dropna(subset=['product_color','product_variation_size_id','merchant_info_subtitle','merchant_name','origin_country','rating_one_count','rating_two_count','rating_three_count','rating_four_count','rating_five_count'], inplace=True)
df

# %%
import matplotlib.pyplot as plt
df.boxplot(column=['rating'])
df

# %%
import matplotlib.pyplot as plt
df.hist(column='price')
df

# %%
import matplotlib.pyplot as pl
newdf.product_variation_size_id.value_counts().plot(kind='bar')
plt.show()

# %%
df.head()

# %%
df.columns

# %%
X_Data=df
X_Data=Data[['price', 'retail_price','units_sold', 'uses_ad_boosts', 'rating', 'rating_count',
       'rating_five_count', 'rating_four_count', 'rating_three_count',
       'rating_two_count', 'rating_one_count','merchant_rating_count', 'merchant_rating',
       'merchant_id', 'merchant_has_profile_picture', 'product_url',
       ]]

# %%
X_Data=X_Data.apply(lambda x:(x - x.min(axis=0))/(x.max(axis=0)-x.min(axis=0)))

# %%
X_Data
