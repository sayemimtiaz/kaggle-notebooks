# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import xgboost as xgb

# %%
data=pd.read_csv('../input/heart-disease-uci/heart.csv')

# %%
data.head()

# %%
data.isna().sum()

# %%
sns.pairplot(data=data,hue='target')

# %%
plt.xlabel('Gender')
plt.ylabel('frequency')
data['sex'].value_counts().plot.bar()

# %%
sns.relplot(x='chol',y='age',data=data,hue='sex')

# %%
sns.lmplot(x='thal',y='target',data=data)

# %%
sns.displot(x='age',data=data,kde=True)

# %%
sns.displot(x='trestbps',data=data,kde=True)

# %%
sns.displot(x='thal',data=data,kde=True)

# %%
data.columns

# %%
data[data.columns[0:]].corr()['target'][:].sort_values(ascending=False)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data.corr(),annot=True)

# %%
x=data[['age','sex','trestbps','chol','thalach','exang','oldpeak','slope','ca','thal']]
y=data['target']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
#model=RandomForestClassifier(n_estimators=100)
#model=xgb.XGBClassifier(n_estimators=200)
model=LogisticRegression()

# %%
model.fit(x_train,y_train)

# %%
prediction=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,r2_score,confusion_matrix

# %%
accuracy_score(y_test,prediction)

# %%
confusion_matrix(y_test,prediction)

# %%
confusion_matrix=pd.crosstab(y_test,prediction,rownames=['actual'],colnames=['predicted'])
sns.heatmap(confusion_matrix,annot=True)

# %%
y_test.values[0:10]

# %%
prediction[0:10]
