# %% [markdown]
# > Firstly, there should be imported libraries to work. In order to do this, we should write code below.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt 
import seaborn as sns #visualization tool

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# > One of imported libraries which is "pandas" helps us to read datas.

# %%
data = pd.read_csv('../input/pokemon-challenge/pokemon.csv')     #This provides us to read data.

# %% [markdown]
# > After reading datas, learning features about datas would be good.

# %%
data.info()           #This gives us features of datas.

# %% [markdown]
# > Features were learned. Now, relationships between features can be checked.

# %%
data.corr()                          #This gives us "correlation between features".

# %% [markdown]
# > Visualization is better way to see relationship between feature, after obtaining table above.

# %%
#correlation map
f,ax = plt.subplots(figsize=(18,18))
sns.heatmap(data.corr(), annot=True, linewidth=1, fmt= '.2f', ax=ax)       #heatmap (Visualization function from "seaborn" library)
plt.show()

# %% [markdown]
# > Also, there can be seen more details about datas.

# %%
data.head(10)                   #This gives us first 10 Pokemons.

# %%
data.columns                     #This gives us columns seperately.

# %% [markdown]
# > There can be plotted selected variables which can be seen below using line plot.

# %%
data.Speed.plot(kind='line', color='g', linewidth='3', label='Speed', alpha=0.5, grid=True, linestyle='-',figsize=(10,10))
data.Defense.plot(color='r', linewidth='3', legend='Defence', grid=True, linestyle=':')
plt.legend(loc='upper right')    #put label into plot
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Line Plot')
plt.show()

# %% [markdown]
# >There is code to find relationships between Attack and Defense variables. To observe better, there is a scatter plot. As a result, when attack value increases, defense value also increase.

# %%
data.plot(kind='scatter', x='Attack', y='Defense', label='Attack&Speed Relation', alpha=0.5, color='g', figsize=(10,10))
plt.xlabel('Attack')
plt.ylabel('Defense')
plt.legend(loc='upper left')
plt.title('Scatter Plot')
plt.show()

# %% [markdown]
# > For example, i want to know number of pokemons whose speed is 50. So, there can be used histogram plot for this.

# %%
data.Speed.plot(kind='hist', bins=50, figsize=(10,10), color='b', grid=True)
plt.xlabel('Speed of Pokemons')
plt.ylabel('Number of Pokemons')
plt.show()

# %%
#plt.clf()                  We can not see plot due to clf(). (It clears.)
