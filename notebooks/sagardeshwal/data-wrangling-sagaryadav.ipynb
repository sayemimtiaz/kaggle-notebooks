# %%
41# This Python 3 environment comes with many helpful analytics libraries installed
# I0t is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd

url ='/kaggle/input/test-file/tested.csv'

dataframe = pd.read_csv(url)
dataframe.head(6)

# %% [markdown]
# **describes the data******

# %%
dataframe.shape

# %%
dataframe.info()

# %%
dataframe.info()

# %%
dataframe['PassengerId']

# %%
dataframe['PassengerId'].unique()

# %%
dataframe['Embarked'].unique()

# %%
dataframe['Sex'].value_counts()

# %%
dataframe[dataframe['Age'].isnull()]

# %%
dataframe.iloc[0]

# %%
dataframe.iloc[6]

# %%
df.iloc[400:]

# %%
dataframe.iloc[0:10]

# %%
df=dataframe
df.iloc[:7]

# %%
df2=df.iloc[400:]

# %%
df2

# %% [markdown]
# #select rows based condn.

# %%
df[df['Sex']=='female']

# %%
df[(df['Sex']=='female')&(df['Age']>65)]

# %%
df[(df['Sex']=='female')&(df['Embarked']=='S')]

# %%
df[(df['Sex']=='female')&(df['Age']>40)&(df['Survived']==1)]

# %% [markdown]
# **Replacing values**

# %%
dataframe['Sex'].replace("female","Woman").head(2)

# %% [markdown]
# ****Renaming column ****

# %%
dataframe.rename(columns={'PClass':'Passenger Class','Sex':'Gender'}).head(2)

# %% [markdown]
# **Finding the Minimum,Maximum,Sum,Average,and Count**

# %%
print('Maximum:',dataframe['Age'].max())
print('Mminimum:',dataframe['Age'].min())
print('Mean:',dataframe['Age'].mean())
print('Sum:',dataframe['Age'].sum())
print('Count:',dataframe['Age'].count())

# %% [markdown]
# **Finding the Unique value**

# %%
dataframe['Sex'].unique ()

# %%
dataframe['Sex'].value_counts ()

# %% [markdown]
# **Handing Missing File**

# %%
dataframe[dataframe['Age'].isnull()].head(2)

# %%
import numpy as np
dataframe['Sex']=dataframe['Sex'].replace('male',np.nan)

# %% [markdown]
# # **Deleting Column**

# %%
dataframe.drop(['Age', 'Sex'], axis=1).head(2)

# %% [markdown]
# # **# Deleting Rows**

# %%
dataframe[dataframe['Sex']!='male'].head(2)

# %% [markdown]
# # **Grouping Rows by Values**

# %%
dataframe.groupby('Sex').mean()

# %%
dataframe.groupby('Sex').count()

# %% [markdown]
# # **Grouping Rows by Time**

# %%
import pandas as pd
import numpy as np
time_index = pd.date_range('06/06/2017',periods=100000, freq='30S')
dataframe=pd.DataFrame(index=time_index)
dataframe['Sale_Amount']=np.random.randint(1,10,100000)
dataframe.resample('W').sum()

# %% [markdown]
# # **Applying a Function over all element in a Column**

# %%
def uppercase(x):
    return x.upper()

dataframe['Name'].apply(uppercase)[0:2]
