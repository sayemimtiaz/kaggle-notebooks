# %% [markdown]
# **In this kernal, I will make a simplified analysis of happiness in Egypt, and I will clarify it through drawing and by showing the proportions on it in order to clarify some important things that are important to every person interested in these ratios.**
#
# ![image](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRq1Ahs9NDT-dJMQ3Ne8xeOT05QVrBEfFqisA&usqp=CAU)

# %% [markdown]
# **The World Happiness Report is a landmark survey of the state of global happiness . The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import matplotlib.gridspec as gs
from wordcloud import WordCloud
import warnings
import math
warnings.filterwarnings("ignore")
# %matplotlib inline
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)
plt.style.use('seaborn')
import matplotlib.colors as mcolors
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
plt.style.use('fivethirtyeight')
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
w_df=pd.read_csv('../input/world-happiness-report-2021/world-happiness-report-2021.csv')
wo_df=pd.read_csv('../input/world-happiness-report-2021/world-happiness-report.csv')

# %%
print("Shape of the dataset is {} Rows and {} Columns" .format(len(w_df), len(wo_df.columns)))

# %%
w_df.head(10)

# %%
wo_df.head(10)

# %%
wo_df.shape

# %%
dtypes=pd.DataFrame(w_df.dtypes,columns=["Data Types"])
dtypes

# %%
dtypes=pd.DataFrame(wo_df.dtypes,columns=["Data Types"])
dtypes

# %%
w_df.describe()

# %%
wo_df.describe()

# %%
w_df.describe().T

# %%
wo_df.describe().T

# %%
w_df.info()

# %%
wo_df.info()

# %% [markdown]
# # Egypt from 2006 to 2020

# %%
Egypt=wo_df[wo_df['Country name']=='Egypt']

# %%
Egypt

# %%
Egypt.shape

# %%
(w_df["Regional indicator"].value_counts()).plot.pie(autopct="%.1f%%", shadow=True,rotatelabels=True, wedgeprops={'linewidth': 6}, radius=2)
plt.show()

# %%
Egypt.isnull()

# %%
Egypt.info()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=Egypt,x="year",y="Life Ladder",marker='o')
plt.title("Life Ladder")
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=Egypt,x="year",y="Log GDP per capita",marker='o')
plt.title("Log GDP per capita")
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=Egypt,x="year",y="Social support",marker='o')
plt.title("Social support")
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=Egypt,x="year",y="Healthy life expectancy at birth",marker='o')
plt.title("Healthy life expectancy at birth")
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=Egypt,x="year",y="Freedom to make life choices",marker='o')
plt.title("Freedom to make life choices")
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=Egypt,x="year",y="Generosity",marker='o')
plt.title("Generosity")
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=Egypt,x="year",y="Perceptions of corruption",marker='o')
plt.title("Perceptions of corruption")
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=Egypt,x="year",y="Negative affect",marker='o')
plt.title("Negative affect")
plt.show()

# %% [markdown]
# # Egypt in Africa

# %%
plt.figure(figsize=(35,10))
sns.barplot(data=w_df,x="Country name",y="Ladder score")
plt.xticks(rotation=90) 
plt.show()
