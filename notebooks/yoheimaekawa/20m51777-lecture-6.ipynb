# %% [markdown]
# # This is mission of lecture 6 (20M51777)
#
# I look at Corona cases for **Germany**.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
np.set_printoptions(threshold=np.Inf)

selected_country='Germany'
df = pd.read_csv('../input/novel-corona-virus-2019-dataset/covid_19_data.csv',header=0)
df = df[df['Country/Region']==selected_country]
df = df.groupby('ObservationDate').sum()
print(df)

# %%
df['daily_confirmed'] = df['Confirmed'].diff()
df['daily_deaths'] = df['Deaths'].diff()
df['daily_recoveries'] = df['Recovered'].diff()
df['daily_confirmed'].plot()
df['daily_deaths'].plot()
df['daily_recoveries'].plot()

plt.show()

# %% [markdown]
# # Interactive chart of Germany daily cases
#
# Accroding to the following chart, we know that number of 'confirmed people' is the most largest from March,28 to April,2 in Germany. And then, we can see that 'confirmed people' is guradually decreasing to now.
#
# Interesting for me, the number of 'recoveried people' is very sharply increasing at April,8. I guess that this is because the people with confirmed COVID-19 infection from March,28 to April,2 was completely cured about 2 weeks.

# %%
from plotly.offline import iplot
import plotly.graph_objs as go

daily_confirmed_object = go.Scatter(x=df.index,y=df['daily_confirmed'].values,name='Daily confirmed')
daily_deaths_object = go.Scatter(x=df.index,y=df['daily_deaths'].values,name='Daily deaths')
daily_recoveries_object = go.Scatter(x=df.index,y=df['daily_recoveries'].values,name='Daily recovery')

layout_object = go.Layout(title='Germany daily cases 20M51777',xaxis=dict(title='Date'),yaxis=dict(title='Number of people'))
fig = go.Figure(data=[daily_confirmed_object,daily_deaths_object,daily_recoveries_object],layout=layout_object)
iplot(fig)
fig.write_html('Germany_cases_20M51777.html')

# %% [markdown]
# # Interactive table of Germany daily cases

# %%
df1 = df#[['daily_confirmed']]
df1 = df1.fillna(0.)
styled_object = df1.style.background_gradient(cmap='gist_ncar').highlight_max('daily_confirmed').set_caption('Daily Summaries')
display(styled_object)
#f = open('table_20M51777.html','w')
#f.write(styled_object)

# %% [markdown]
#  # What about global ranking of Germany?

# %%
df = pd.read_csv('../input/novel-corona-virus-2019-dataset/covid_19_data.csv',header=0)
df1 = df[df.index=='06/08/2020']
df1 = df.groupby('Country/Region').sum()
df1 = df.sort_values(by='Confirmed',ascending=False).reset_index()

print('Ranking of Germany: ', df1[df1['Country/Region']=='Germany'].index.values[0]+1)

# %% [markdown]
# # The mesurement of government in Germany against COVID-19
# Below is the list to the past trends in Germany COVID-19 policy.
#
#  **-The list of regulation against COVID-19 infection by Germany government-**
# 1.  March,9 2020:  First dead in Germany due to COVID-19,the number of infected people exceeds 1500.
#
# 2. March,22 2020: Germany government implement '**Lockdown**' (close restaurants or no contact with anyone                     other than family members) for 2 weeks to prevent the spread of infection. (Due to the ongoing spread of COVID-19 infections, Lockdown was extended until May,3.)
# 3. May,4 2020:    Deregulation　of Lockdown by Germany government(Reopening playgrounds, museums and churches                   but continue to stay away from others but cafes, restaurants, bars, department stores and                     shopping malls cannot continue to operate).
#
# *(Source;
# https://www.bundesregierung.de/breg-en/news/guidelines-to-slow-the-spread-of-the-coronavirus-1731708
# http://koshaken.pmssi.co.jp/coronapolicy_Germany.html)*

# %% [markdown]
# # Why is the death ratio of people confirmed COVID-19 in Germany lower than any other EU countries??
#
#  The number of people confirmed COVID-19 infection in Germany is not really difference compared to other EU countries. However, the number of dead people by this virus in Germany is much smaller than any other EU countries. (The death ratio (='Daeth people'/'Confrimed people') in Germany is only 4%, whereas the death ratio in other EU countries is more than 10%.)
#
#  So, why is the death ratio of people confirmed COVID-19 in Germany lower than any other EU countries??
#
#  I guess that it is because  **speed of inspection system against COVID-19** in Germany.
#
#  At first, Germany is the world's earliest and has expanded the testing system such as PCR testing to reduce the death rate to the lowest level among major EU countries.　In Germany, nearly 900,000 new coronavi tests can be performed per week.
#
#  And Germany had more inspections early than other countries. By mid-February, PCR tests for COVID-19 were available at university hospitals across Germany despite being not implemented in most countries in the world.
#
#  Finally,unlike Japan, German health authorities have taken the strategy of conducting PCR tests on as many citizens as possible and isolating infected and contact persons from their homes.　In Germany, nearly 900,000 PCR tests can be performed per week.
#
#  I think that by these implementation the German government can control the death people.
#
#  (Reference;https://business.nikkei.com/atcl/seminar/19/00023/060300171/?P=2
#  https://www.afpbb.com/articles/-/3281152)
