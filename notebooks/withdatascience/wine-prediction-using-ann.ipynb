# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from keras.models import Sequential
from keras.layers import Dense,Dropout
import os,warnings
warnings.filterwarnings('ignore')
from keras.utils import to_categorical
from sklearn.metrics import confusion_matrix,classification_report

# %%
path='../input/red-wine-quality-cortez-et-al-2009'
filename=os.path.join(path,'winequality-red.csv')
df=pd.read_csv(filename)

# %%
df.head()

# %%
df.info()

# %% [markdown]
# ***Thankfully there are no null values***

# %%
sns.countplot(df['quality'])

# %%
df.describe().T

# %%
y=df['quality']
X=df.drop(['quality'],axis=1)
print(X.shape)
X_cols=X.columns

# %%
print(y.shape)

# %%
y=to_categorical(y)

# %%
num_classes=print(y.shape[1])

# %% [markdown]
# ***Scaling the Data***

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_transformed=sc.fit_transform(X)
X_transformed_df=pd.DataFrame(X_transformed,columns=X_cols)

# %% [markdown]
# ***Splitting the dataset***

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_transformed,y,test_size=0.15,stratify=y)

# %%
print(X_train.shape)
print(y_train.shape)

# %% [markdown]
# ***Modelling the data using ANN***

# %%
model=Sequential()
model.add(Dense(256,activation='relu'))
model.add(Dense(512,activation='relu'))
model.add(Dense(1024,activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(9,activation='softmax'))
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(X_train,y_train,batch_size=50,epochs=100,verbose=2)

# %%
y_preds=model.predict_classes(X_test)
#y_preds=np.argmax(y_preds,axis=1)

# %%
y_preds

# %%
y_test

# %%
y_test.shape

# %%
actual_preds=np.argmax(y_test,axis=1)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(actual_preds,y_preds))
