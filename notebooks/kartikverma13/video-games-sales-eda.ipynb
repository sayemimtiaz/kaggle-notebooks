# %% [markdown]
# **IMPORTING THE LIBRARIES AND DATSET**

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv("../input/videogamesales/vgsales.csv")

# %%
df.head()

# %% [markdown]
# **LET'S TAKE A QUICK OVERVIEW OF DATA**

# %%
from pandas_profiling import ProfileReport
profile = ProfileReport(df);

# %%
profile.to_widgets()

# %%
df.shape

# %%
df.isnull().sum()

# %% [markdown]
# Since we are not implementing any model for this dataset so we can ignore the missing values also the number of missing values are less that will not hinder us in EDA.

# %%
sns.pairplot(df)

# %%
df["Platform"].value_counts()

# %%
df["Genre"].value_counts()

# %% [markdown]
# **NUMBER OF VIDEO GAMES RELEASES EVERY YEAR**

# %%
plt.figure(figsize=(23,10))
sns.countplot("Year", data=df)
plt.show()

# %% [markdown]
# **SALES DONE GLOBALLY(in millions) EVERY YEAR**

# %%
plt.figure(figsize=(20,10))
sns.barplot(x="Year", y="Global_Sales", data=df)
plt.show()

# %% [markdown]
# **NUMBER OF GAMES PRODUCED IN EACH GENRE**

# %%
plt.figure(figsize=(10,8))
sns.countplot("Genre", data=df)
plt.show()

# %% [markdown]
# **TYPES OF VIDEO GAMES MAJORLY SELLED IN NORTH AMERICA, EUROPE, JAPAN AND GLOBALLY**

# %%
plt.figure(figsize=(10,8))
sns.barplot(x="Genre", y="NA_Sales", data=df)

# %%
sns.barplot(x="Genre", y="EU_Sales", data=df)

# %%
sns.barplot(x="Genre", y="JP_Sales", data=df)

# %%
sns.barplot(x="Genre", y="Global_Sales", data=df)

# %%
plt.figure(figsize=(18,4))
sns.countplot(x="Platform", data=df)
plt.show()

# %% [markdown]
# **PLATFORM THAT YIELDS MAXIMUM REVENUE**

# %% [markdown]
# The target platform for publishers must be the one which has earned them the maximum profit globally

# %%
plt.figure(figsize=(18,4))
sns.barplot(x="Platform", y="Global_Sales", data=df)
plt.show()

# %% [markdown]
# **YEARS WITH MAXIMUM AND MINIMUM PRODUCTION **

# %%
plt.figure(figsize=(20,10))
sns.countplot("Year", data=df)
plt.show()

# %%
 df.dtypes

# %% [markdown]
# **DISTRIBUTION OF TOP 10 PLATFORMS CONSIDERED BY PUBLISHERS**

# %%
df["Platform"].value_counts().head(10)

# %%
Tasks = [2163,2161,1329,1325,1265,1213,1196,960,824,822]
my_labels = 'ds','ps2','ps3','wii','x360','psp','ps','pc','xb','gba'
plt.figure(figsize=(7,7))
plt.pie(Tasks,labels=my_labels,autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %% [markdown]
# **CHANGE IN THE SALES OF VIDEO GAMES OVER THE YEARS**

# %%
plt.figure(figsize=(30,10))
sns.barplot(x="Year", y="Global_Sales", data=df)
plt.show()

# %% [markdown]
# **RLATION BETWEEN PLATFORM AND GENRE**

# %%
platGenre = pd.crosstab(df.Platform,df.Genre)
platGenreTotal = platGenre.sum(axis=1).sort_values(ascending = False)
plt.figure(figsize=(8,6))
sns.barplot(y = platGenreTotal.index, x = platGenreTotal.values, orient='h')
plt.ylabel = "Platform"
plt.xlabel = "The amount of games"
plt.show()

# %% [markdown]
# **COMPARATION OF EACH AREA IN EACH GENRE**

# %%
GenreGroup = df.groupby(['Genre']).sum().loc[:, 'NA_Sales':'Global_Sales']
plt.figure(figsize=(15, 15))
sns.set(font_scale=0.7)
sns.heatmap(GenreGroup, annot=True, fmt = '.1f')
