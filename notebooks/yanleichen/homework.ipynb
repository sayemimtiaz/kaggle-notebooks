# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

selected_country_1= 'Brazil'
selected_country_2= 'Brazil'

df1 = pd.read_csv('../input/covid19-global-dataset/worldometer_coronavirus_daily_data.csv', header = 0)
df1 = df1[df1['country'] == selected_country_1]
df2 = pd.read_csv('../input/covid-world-vaccination-progress/country_vaccinations.csv', header = 0)
df2 = df2[df2['country'] == selected_country_2]
df1.index = pd.to_datetime(df1['date'])
df2.index = pd.to_datetime(df2['date'])

# %%
print(df1.columns)
print(df2.columns)

# %%
print(np.unique((df1['country'])))
print(np.unique((df2['country'])))

# %% [markdown]
# # Analysis
# From here, I will analyze the data that was loaded as an dataframe object.

# %%
plt.plot(df1.index,df1['daily_new_cases'],'black')
plt.plot(df2.index,df2['daily_vaccinations'],'r')
plt.show()

# %%
fig,ax = plt.subplots(figsize = (10,5))
ax.plot(df1.index,df1['daily_new_cases'],'black')
ax1 = ax.twinx()
ax1.plot(df2.index,df2['daily_vaccinations'],'r')
plt.show()

# %% [markdown]
# # improved visualization
# From here, we will be using the modules iplot and plotly to make better visualizations.

# %%
from plotly.offline import iplot 
import plotly.graph_objs as go

daily_new_cases = go.Scatter(x = df1.index,y = df1['daily_new_cases'],yaxis = 'y1',name = 'Daily Confirmed Cases')
daily_vaccinations = go.Scatter(x = df2.index,y = df2['daily_vaccinations'],yaxis = 'y2',name = 'Daily Vaccinations')

layout_obj = go.Layout(title = 'Covid vs Vaccines',xaxis = dict(title = 'Date'),yaxis = dict(title = 'Date cases'),yaxis2 = dict(title = 'Vaccinations',side = 'right',overlaying = 'y'))
fig = go.Figure(data = [daily_new_cases,daily_vaccinations],layout = layout_obj)
iplot(fig)

fig.write_html('outcome.html')

# %% [markdown]
# ## colored tables
# create colored tables

# %%
style_object = df1.style.background_gradient(cmap = 'jet').highlight_max('daily_new_cases').set_caption('Daily cases')
display(style_object)

# %%
df1 = pd.read_csv('../input/covid19-global-dataset/worldometer_coronavirus_daily_data.csv', header = 0)
df1 = df1.groupby('country').max()['cumulative_total_cases'].sort_values(ascending=False)
print(df1.to_string())
df2 = pd.read_csv('../input/covid-world-vaccination-progress/country_vaccinations.csv', header = 0)
df2 = df2.groupby('country').max()['people_vaccinated_per_hundred'].sort_values(ascending=False)
print(df2.to_string())

# %% [markdown]
# Discussion
# 1.The total cases of Brazil will be ranked in top3 among other countries.（about 16083573.0 cases)
# 2.The people vaccinated per hundred in Brazil is 17.58 ( Still has a huge potential to improve the vaccination scale)
# 3.Inspect the daily vaccinations and COVID-19 cases of the country.Discuss how the national government of the country is addressing the issue by summarizing from the news. Or using the news to explain the patterns you see.
#
# I noticed that the daily vaccination will be decreased periodically from the figure Covid vs Vaccines. Since the period will be a week, I surmised the decrease reason will be that the vaccination activity will hugely stagnate in weekend or the vaccination supply will be delivered in once a week usually. Becausre the dates of the amount of vaccination droped in 2021 were monday mostly, I guess the later one will be the reason for the drop of the amount of daily vaccination. Unfortunately, I did not find relevant news reports or official instructions.
