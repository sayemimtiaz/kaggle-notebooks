# %% [markdown]
# The dataset is about WWII weather in various stations that illustrates the min and max daily temperature around the world.
# what my goal is predicting average temperature during 1942-1945 by employing linear regression.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os # accessing directory structure
print(os.listdir("../input"))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# To begin, I started with importing data to my notebook

# %%
df = pd.read_csv("../input/weatherww2/Summary of Weather.csv")

# %%
df.head(10) #for showing csv file

# %%
df.describe()  #an overall analysis on the file

# %%
df.plot(x='MinTemp', y='MaxTemp', style='o')  
plt.title('MinTemp vs MaxTemp')  
plt.xlabel('MinTemp')  
plt.ylabel('MaxTemp')  
plt.show()

# %%
#plt.figure(figsize=(15,10))
#plt.tight_layout()
#seabornInstance.distplot(df['MaxTemp'])

# %%
#reshape to convert from 1D array to 2D array 
#because sklearn expects a 2D array as input
X = df['MinTemp'].values.reshape(-1,1)
y = df['MaxTemp'].values.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# %%
m, b = np.polyfit(X, y, 1)

# %%
#To retrieve the intercept:
print(regressor.intercept_)

#For retrieving the slope:
print(regressor.coef_) 
#This means that for every one unit of change in Min temperature, 
#the change in the Max temperature is about 0.92

# %%
dff = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
dff
