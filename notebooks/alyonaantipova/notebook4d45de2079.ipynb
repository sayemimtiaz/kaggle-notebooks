# %%
import pandas as pd #подключаем библиотеку

#прочитаем файл kc_house_data.csv и сохраним его в переменной df.
df = pd.read_csv('../input/housesalesprediction/kc_house_data.csv', index_col=0)

df.head(10) #получаем первые 10 строк таблицы

# %%
df.info() #общая информация о данных таблицы df

# %%
df.duplicated().sum() #проверим наличие дубликатов

# %%
df.sort_values (by='price', ascending=False).head(21613)
df=df[df['price']<=1920000]

# %%
df.groupby('price')['sqft_living'].mean()

# %%
df.groupby('price')['sqft_lot'].mean()

# %%
df.groupby('yr_built')['price'].mean()

# %%
def find_bedrooms(df. bed):
    bedrooms_list = df[(df['bedrooms'] == bed)]
    bedrooms_count = bedrooms_list['bedrooms'].count()
    return bedrooms_count

find_bedrooms(df,1)

# %%
df[df['bedrooms'] == 0]
