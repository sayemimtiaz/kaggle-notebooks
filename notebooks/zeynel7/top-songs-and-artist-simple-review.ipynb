# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            background-color:#0A02ED;
#            font-size:140%;
#            font-family:Cambria;
#            letter-spacing:0.5px">
#
# <p style="padding: 15px;
#               color:white;"> Content
# </p>
# </div>
#
# <font color = 'blue'>
#
# * [The most featured artists on the list](#1)
# * [The most listened songs](#2)
# * [Which song of which artist on the list is the most liked](#3)
# * [Most streamed artists by years](#4)

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import os
import warnings
warnings.filterwarnings("ignore") 
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv("/kaggle/input/billboard-the-hot-100-songs/charts.csv")  
df = df.fillna(0)
df.tail()

# %% [markdown]
# <a id = "1"></a><br>
# # The most featured artists on the list

# %%
artistdf = df['artist'].value_counts().head(10)
print(artistdf)

# %% [markdown]
# <a id = "2"></a><br>
# # The most listened songs

# %%
songdf = df['song'].value_counts().head(10)
print(songdf)

# %% [markdown]
# <a id = "3"></a><br>
# # Which song of which artist on the list is the most liked

# %%
print(df[["artist", "song", "peak-rank"]].value_counts().head(10))

# %% [markdown]
# <a id = "4"></a><br>
# # Most-streamed artists by years

# %%
df['date'] = df['date'].apply(pd.to_datetime)
df.set_index('date', inplace=True)
df.head()

# %% [markdown]
# **We can obtain the time interval we want to see by using these codes**
#
#     H >> hourly frequency
#     D >> daily frequency
#     W >> weekly frequency
#     M >> monthly frequency
#     A >> yearly frequency

# %%
# df.resample('A')['artist'].agg(['first','last']) # It can be used to find the most and least listened ones.
df.resample('A').first()

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#A2CB9A;
#            font-size:150%;
#            font-family:Cambria;
#            letter-spacing:0.5px">
#
# <p style="padding: 20px;
#               color:black;">🎼 Thanks for your time 🎼
# </p>
# </div>
