# %%
import pandas as pd
import numpy as np
import cufflinks as cf
cf.go_offline()

# %%
tnc = pd.read_csv("../input/titanicdataset-traincsv/train.csv")

# %%
tnc.shape

# %%
tnc.head()

# %%
tnc.info()

# %%
tnc.describe()

# %%
tnc.corr()

# %%
tnc = tnc.drop(["Name","Ticket",'PassengerId'],axis=1)

# %%
tnc

# %%
tnc.iplot(kind="scatter",mode=' markers+text')

# %%
tnc.iplot(x='Pclass',y='Age',kind="box",boxpoints="suspectedoutliers")
tnc.iplot(x='Pclass',y='Age',kind="bar",barmode="overlay")

# %%
tnc.isnull().sum()

# %%
tnc.isnull().sum().iplot(kind="line",mode="lines+markers")

# %%
tnc["Survived"].value_counts()

# %%
tnc['Survived'][tnc['Sex']== 'male'].value_counts()

# %%
tnc['Survived'][tnc['Sex']== 'male'].value_counts().iplot(kind="bar",xTitle='survied',yTitle='male count')

# %%
tnc['Survived'][tnc['Sex']=="female"].value_counts(normalize=True)

# %%
tnc['Survived'][tnc['Sex']=="female"].value_counts(normalize=True).iplot(kind="bar",xTitle='survied',yTitle='female percent')

# %%
survived_sex = tnc[tnc['Survived']==1]['Sex'].value_counts()
dead_sex = tnc[tnc['Survived']==0]['Sex'].value_counts()
tnc1 = pd.DataFrame([survived_sex,dead_sex])
tnc1.index = ['Survived','Dead']
tnc1.iplot(kind='bar',barmode='stack', title='Survival by the Sex')

# %% [markdown]
# pandas.pivot(index, columns, values) function produces pivot table based on 3 columns of the DataFrame. Uses unique values from index / columns and fills with values.
#
# Parameters:
# index[ndarray] : Labels to use to make new frame’s index
# columns[ndarray] : Labels to use to make new frame’s columns
# values[ndarray] : Values to use for populating new frame’s values
#
# Returns: Reshaped DataFrame
# Exception: ValueError raised if there are any duplicates.

# %%
tnc.pivot(columns='Pclass',values='Age').iplot(kind='box')

# %%
def impute_age(cols):
    Age=cols[0]
    Pclass=cols[1]
    if pd.isnull(Age):
        if Pclass == 1:
            return 37
        elif Pclass == 2:
            return 29
        else:
            return 24
    else:
        return Age

# %%
tnc['Age']=tnc[["Age",'Pclass']].apply(impute_age,axis=1)

# %%
tnc["Age"].isnull().sum()

# %%
Sex=pd.get_dummies(data=tnc['Sex'],drop_first=True)

# %%
Sex

# %%
tnc=tnc.drop('Sex',axis=1)

# %%
tnc

# %%
tnc=pd.concat([tnc,Sex],axis=1)

# %%
tnc

# %%
tnc = tnc.dropna(subset=['Embarked'])
code = pd.get_dummies(tnc['Embarked'], prefix='Embarked')
tnc = pd.concat([tnc, code], axis=1)
tnc.head()

# %%
tnc['Cabin'] = tnc['Cabin'].fillna('U')
tnc['Cabin'] = tnc['Cabin'].apply(lambda x: x[0])
code = pd.get_dummies(tnc['Cabin'], prefix='Cabin')
tnc = pd.concat([tnc, code], axis=1)
tnc.head()

# %%
tnc = tnc.drop(['Cabin'],axis=1)

# %%
tnc = tnc.drop(['Embarked'],axis=1)

# %%
tnc.head()
