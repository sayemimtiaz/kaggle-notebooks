# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
print(os.listdir('../input/bike-sharing-dataset'))
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # ****Read the training data

# %%
bk_sh = pd.read_csv('../input/bike-sharing-dataset/day.csv')

# %%
bk_sh

# %% [markdown]
# # #getting data****

# %%
bk_sh.head(4)

# %%
bk_sh.tail(7)

# %% [markdown]
# # data type****

# %%
bk_sh.dtypes

# %% [markdown]
# # shape****

# %%
bk_sh.shape

# %%
bk_sh['season']

# %%
bk_sh.columns

# %%
bk_sh[2:5]

# %%
bk_sh.axes

# %%
bk_sh.loc[2:4,['instant']]

# %%
bk_sh.sort_values(by =['dteday','weekday'],ascending = [True ,False])
bk_sh.head()

# %%
bk_sh.isnull().sum()>0

# %%
bk_sh =bk_sh.fillna(0)
bk_sh.head(3)

# %%
bk_sh.isnull().sum()>0

# %%
weekday_group= bk_sh.groupby('temp')[['weekday']].mean()

# %%
bk_sh.to_csv('bk_sh_updated.csv' , index=False)

# %% [markdown]
# # #Visulize Data ****

# %% [markdown]
# # univariate pd (D1)****

# %%
#Bar
plt.figure(figsize = (3,5))
bk_sh['weekday'].value_counts().sort_index().plot.bar()
plt.show()

# %%
#line
plt.figure(figsize = (3,5))
bk_sh['mnth'].value_counts().sort_index().plot.line()
plt.show()

# %%
#histogram
plt.figure(figsize =(3,5))
bk_sh['cnt'].hist()
plt.show()

# %% [markdown]
# # Bivariate pd (2D)****

# %%
#SCATTER PLOT
plt.figure(figsize =(4,5))
bk_sh.plot.scatter(x='cnt', y='temp')
plt.show()

# %%
#SCATTER PLOT
plt.figure(figsize =(4,3))
bk_sh.plot.scatter(x='windspeed', y='temp')
plt.show()

# %%
#HEXPLOT
plt.figure(figsize =(3,4))
bk_sh.plot.hexbin(x='cnt', y='hum' ,gridsize = 10)
plt.show()

# %% [markdown]
# # Multivariate (3D)****

# %%
#Multivariate scatter plots
sns.lmplot(x='mnth',y='atemp' ,hue = 'yr' ,data=bk_sh , fit_reg=False)
plt.show()

# %%
bk_sh

# %% [markdown]
# # Correlation Heatmap****

# %%
plt.figure(figsize = (10,10))
sns.heatmap(bk_sh.corr() , annot=True)
plt.show()

# %%
plt.figure(figsize = (10,10))
sns.barplot(data = bk_sh , x='holiday' , y= 'cnt' , hue='season')
plt.show()

# %% [markdown]
# # statistical analysis****

# %%
#maen,median
plt.figure(figsize=(5,5))
bk_sh.mnth.plot.hist()
plt.show()

# %%
print('mean',bk_sh.mnth.mean(),'median',bk_sh.mnth.median())

# %%
#upper_lower_outlier
desc=bk_sh.hum.describe()
Q1=desc[4]
Q2=desc[5]
Q3=desc[6]
print('Q1=',Q1,'Q2=',Q2,'Q3=',Q3)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print("Anything outside this range is outlier:(",lower_bound,",",upper_bound,")")
bk_sh[bk_sh.yr<lower_bound].hum
print("outliers:",bk_sh[(bk_sh.hum<lower_bound)|(bk_sh.hum>upper_bound)].hum.values)

# %%
bk_sh.describe()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
bk_sh.boxplot(column='mnth')
plt.show()

# %%
fig,ax=plt.subplots(figsize=(10,5))
sns.boxplot(data=bk_sh[['season','mnth','yr']])
ax.set_title('season_mnth_yr_outliers')
plt.show()

# %% [markdown]
# # modle data****

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
model=LinearRegression()
print(bk_sh.shape,bk_sh.values.reshape(-1,1).shape)
x=bk_sh.values.reshape(-1,1)#as xexpected to bd toble rows & columns
y=bk_sh #.values.reshape(-1,1) 
y

# %%
#train
from sklearn import tree
X_bk_sh=pd.DataFrame()
X_bk_sh['x']=[1,1,0,1]
X_bk_sh['y']=[1,1,1,0]
X_bk_sh['z']=[1,0,1,0]

Y_bk_sh=['I','I','II','II']
clf=tree.DecisionTreeClassifier()
clf=bk_sh.fit(bk_sh,bk_sh)

X_bk_sh['c']=Y_bk_sh
X_bk_sh

# %%
#Accurcy
X_bk_sh=pd.DataFrame()
Y_bk_sh=pd.DataFrame()
X_bk_sh['x']=[0,1,0,1]
X_bk_sh['y']=[1,1,1,1]
X_bk_sh["z"]=[1,0,0,0]
Y_bk_sh=clf.score(X_bk_sh,Y_bk_sh)

print('Accurcy:',score)

# %%
#metrics
from sklearn.metrics import bk_sh
bk_sh=bk_sh(Y_test,y_predict)
bk_sh

# %%
model.coef_

print("mnth of determination:",r_sq)
print("intercept:",model.intercapt_)
print("slop",model.cpef_[0])

# %%
import matplotlip.pyplot as plt
bk_sh.plot.scatter(x="weekday",y="holiday")
intercept= model.intercept_
slop=model.coer_[0]
#approach1
y1=0*slope+intercept
y2=500*slope+intercept

print(y1)
print(y2)

plt.plot([0,500],[y1,y2],"-r")
plt.show()

# %%
y=model.predict(x)

# %%
y

# %%
x=bk_sh.trestbds.values.reshape(-1,1)
y=bk_sh['mnth']
model.fit(x,y)
print("holiday",model.score(x,y))

y_pre=model.predict(x)
compare=pd.DataFrame()
compare['predicted']=y_pre
compare['Actual']=y
compare.plot.scatter(x='Actual',y='predicted')

# %%
bk_sh['predicted']=compare['predicted']

# %%
bh_sh

# %%
import matplotlib.pyplot as plt

bk_sh.plot.scatter(x='mnth',y='weekday')
mnth= bk_sh.month.values.reshape(-1,1)
plt.plot(bk_sh,model.predict(mnth), color='blue')

plt.show()
