# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
#  # Plant 1 Power generation and Weather sensor data

# %% [markdown]
# # LOADING THE DATASETS

# %%
df_pgen1 = pd.read_csv('../input/solar-power-generation-data/Plant_1_Generation_Data.csv')
df_wtsen1 = pd.read_csv('../input/solar-power-generation-data/Plant_1_Weather_Sensor_Data.csv')

# %% [markdown]
# 1. df_pgen1-dataframe of power generation data from plant 1
# 2. df_wtsen1-dataframe of weather sensor data from plant1
# #Module function

# %%
df_pgen1

# %%
df_wtsen1

# %% [markdown]
# # Type of dataframe

# %%
type(df_pgen1)

# %%
type(df_wtsen1)

# %%
df_pgen1.columns

# %%
df_wtsen1.columns

# %% [markdown]
# # DATASET OVERVIEW

# %%
df_pgen1.info()

# %%
df_wtsen1.info()

# %% [markdown]
# # EXPLORING THE DATASETS

# %%
df_pgen1.describe()

# %%
df_wtsen1.describe()

# %% [markdown]
# # Mean Daily Yield

# %%
df_pgen1['DAILY_YIELD'].mean()

# %% [markdown]
# # Total Irradiation

# %%
df_wtsen1['IRRADIATION'].count()

# %% [markdown]
# #You can also use .sum

# %% [markdown]
# # Maximum Ambient and Module temperature

# %%
df_wtsen1[['AMBIENT_TEMPERATURE','MODULE_TEMPERATURE']].max()

# %% [markdown]
# # Number of Inverters in each Plant

# %%
df_pgen1['SOURCE_KEY'].unique()

# %%
len(df_pgen1['SOURCE_KEY'].unique())

# %% [markdown]
# # Maximum and Minimum value of AC/DC Power generated

# %%
df_pgen1[['DC_POWER','AC_POWER']].max()

# %%
df_pgen1[['DC_POWER','AC_POWER']].min()

# %% [markdown]
# # Inverter with Maximum AC/DC Power

# %%
df_pgen1[['AC_POWER','DC_POWER']].idxmax()

# %%
df_pgen1['SOURCE_KEY'][61624]

# %% [markdown]
# Inverter with maximum AC/DC power generation is wCURE6d3bPkepu2

# %% [markdown]
# # Missing Data

# %%
df_pgen1.isnull()

# %%
df_wtsen1.isnull()

# %% [markdown]
# #  Since all coloumns show false,there is no missing data

# %% [markdown]
# # Plant 2 Power generation and Weather Sensor data

# %% [markdown]
# # Loading the Datasets

# %%
df_pgen2 = pd.read_csv('../input/solar-power-generation-data/Plant_2_Generation_Data.csv')
df_wtsen2 = pd.read_csv('../input/solar-power-generation-data/Plant_2_Weather_Sensor_Data.csv')

# %% [markdown]
# 1. df_pgen2-dataframe of power generation data from plant 2
# 2. df_wtsen2-dataframe of weather sensor data from plant2

# %%
df_pgen2

# %%
df_wtsen2

# %% [markdown]
# # Type of dataframe

# %%
type(df_pgen2)

# %%
type(df_wtsen2)

# %% [markdown]
# # DATASET OVERVIEW

# %%
df_pgen2.info()

# %%
df_wtsen2.info()

# %% [markdown]
# # EXPLORING THE DATASETS

# %%
df_pgen2.describe()

# %%
df_wtsen2.describe()

# %% [markdown]
# # Mean Daily yield

# %%
df_pgen2['DAILY_YIELD'].mean()

# %% [markdown]
# # Total Irradiation

# %%
df_wtsen2['IRRADIATION'].count()

# %% [markdown]
# # Maximum Ambient and Module Temperature

# %%
df_wtsen2[['AMBIENT_TEMPERATURE','MODULE_TEMPERATURE']].max()

# %% [markdown]
# # Number of Inverters in each Plant

# %%
df_pgen2['SOURCE_KEY'].unique()

# %%
len(df_pgen2['SOURCE_KEY'].unique())

# %% [markdown]
# # Maximum and Minimum value of AC/DC Power generated

# %%
df_pgen2[['DC_POWER','AC_POWER']].max()

# %%
df_pgen2[['DC_POWER','AC_POWER']].min()

# %% [markdown]
# # Inverter with Maximum AC/DC Power

# %%
df_pgen2[['AC_POWER','DC_POWER']].idxmax()

# %%
df_pgen1['SOURCE_KEY'][41423]

# %% [markdown]
# Inverter with maximum AC/DC power generation is ZoEaEvLYb1n2sOq

# %% [markdown]
# # Missing Data

# %%
df_pgen2.isnull()

# %%
df_wtsen2.isnull()

# %% [markdown]
# #  Since all coloumns show false,there is no missing data
