# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('../input/titanicdataset-traincsv/train.csv')
df.head()

# %%
df.describe()

# %%
df.shape

# %%
df.dtypes

# %%
df.describe(include="O")

# %%
df.describe(include="all")

# %%
df.isnull().sum()

# %%
df['Age'].mode()

# %%
df['Age'] = df['Age'].fillna(24)

# %%
df['Age'].isnull().sum()

# %%
df['Cabin'][:10]

# %%
df['Cabin'].mode()

# %%
df['Cabin'].unique()

# %%
df['Cabin'].count()

# %%
df['Cabin'].value_counts()

# %%
 df.shape

# %%
df['Cabin'].drop

# %%
#axis for rows and columns 
df.drop(['Cabin'], axis= 1)

# %%
# Important for permanent delete
df.drop(['Cabin'], axis = 1, inplace=True)

# %%
df.columns

# %%
df.shape

# %%
df.isnull()

# %%
df.isnull().sum()

# %%
df['Embarked'].mode()

# %%
df['Embarked'] = df['Embarked'].fillna('S')

# %%
df['Embarked'].unique()

# %%
# df['Embarked'].replace(to_replace = np.nan, value = 'S')

# %%
# df['Embarked'].replace('s', 'S', inplace=True)

# %%
df.corr()

# %%
df.drop(['PassengerId', 'Name', 'Ticket'], axis = 1, inplace = True)

# %%
df['Survived'].count()

# %%
df.groupby('Survived').size()

# %%
sns.barplot(x = df['Survived'], y = df['Pclass'])

# %%
sns.countplot(x='Sex', hue='Pclass', data=df);

# %%
sns.countplot(x='Sex', hue='SibSp', data=df);

# %%
df.head()

# %%
sns.countplot(x='Survived', hue='Fare', data=df);

# %%
sns.countplot(x='Survived', hue='Sex', data=df);

# %%
plt.scatter(x= df['Fare'], y = df['Survived'], marker = '.')

# %%
sns.boxplot(x=df['Pclass'], y= df['Fare'], hue = df['Age'] )

# %%
sns.barplot(x=df['Survived'], y = df['SibSp'])

# %%
plt.scatter(x = df['Pclass'], y= df['Fare'])

# %%
sns.lineplot(x= df['Age'],  y =df['Pclass'])
sns.lineplot(subplots = True)

# %%
sns.barplot(x=df['Age'], y = df['Sex'])

# %%
sns.countplot(x='Age', hue='Sex', data=df);

# %%
sns.countplot(x='Pclass', hue='Survived', data=df);

# %%
sns.factorplot(x='Sex', col='Pclass', hue='Survived', data=df, kind='count');

# %%
cor = df.corr()
plt.figure(figsize=(20,8))
sns.heatmap(cor, annot=True);

# %%
df.dtypes

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df['Sex']=le.fit_transform(df['Sex'])

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df['Embarked']=le.fit_transform(df['Embarked'])

# %%
df['Embarked']

# %%
df.head()

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df['Embarked'] = le.fit_transform(df['Embarked'])

# %%
X = df.drop('Survived', axis = 1)
X

# %%
Y = df['Survived']
Y

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)

# %%
pred=knn.predict(X_test)

# %%
np.where(np.isnan(X))
df.head(153)
df.fillna(0, inplace=True)

# %%
df['Fare']= df['Fare'].apply(pd.to_numeric)

# %%
X

# %%
df.dtypes

# %%
df['Fare'] = df['Fare'].fillna(23)

# %%
df['Fare'].isnull().sum()

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(pred, y_test)*100

#aaccuracy_score(y_true, y_pred, normalize=False)

# %%
print("Accuracy =",accuracy)
