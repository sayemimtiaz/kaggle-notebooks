# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing

# %%
data_dic = pd.read_excel('../input/healthcare-analytics/Train/Data_Dictionary.xlsx')
camp = pd.read_csv('../input/healthcare-analytics/Train/Health_Camp_Detail.csv')
one_camp = pd.read_csv('../input/healthcare-analytics/Train/First_Health_Camp_Attended.csv')
profiles = pd.read_csv('../input/healthcare-analytics/Train/Patient_Profile.csv')
two_camp = pd.read_csv('../input/healthcare-analytics/Train/Second_Health_Camp_Attended.csv')
three_camp = pd.read_csv('../input/healthcare-analytics/Train/Third_Health_Camp_Attended.csv')
train = pd.read_csv('../input/healthcare-analytics/Train/Train.csv')

# %% [markdown]
# # Health Score [one_camp ,two_camp]

# %%
one_camp.columns = ['Patient_ID', 'Health_Camp_ID', 'Donation', 'Health Score','Unnamed: 4']

# %%
camp_one = one_camp.groupby('Health_Camp_ID',as_index = False).sum()

# %%
one_two = one_camp.merge(two_camp,on = 'Patient_ID')
one_two = one_two.drop(['Unnamed: 4'],axis = 1)

# %%
one_two['score'] = one_two['Health Score_x'] + one_two['Health Score_y']
one_two = one_two.drop(['Health Score_x','Health Score_y'],axis = 1)

# %%
one_two = one_two.groupby('Patient_ID',as_index = False).sum()

# %%
one_two.columns

# %%
corr = one_two.corr()

# %%
# corr = musk.corr()
cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "7pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]

corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())

# %% [markdown]
# ## Normalizing

# %%
one_two.columns

# %%
x = one_two.drop('Patient_ID',axis = 1)
nor = preprocessing.MinMaxScaler()
one_two_norm = nor.fit_transform(x)
norm1_2 = pd.DataFrame(one_two_norm)

# %%
norm1_2.columns = ['Health_Camp_ID_x', 'Donation', 'Health_Camp_ID_y','score']

# %%
norm1_2['Patient_ID'] = one_two['Patient_ID']

# %%
norm1_2.head()

# %%
corr = norm1_2.corr()

# %%
# corr = musk.corr()
cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "7pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]

corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())

# %%
norm1_2 = norm1_2.drop('Health_Camp_ID_y',axis = 1)

# %%
norm1_2.columns = ['Health_Camp_ID', 'Donation','score','Patient_ID']

# %%
norm1_2.head()

# %%
plt.scatter(norm1_2['score'],norm1_2['Donation'])

# %% [markdown]
# ## Higher the donation , higher are their healthscores

# %%
plt.scatter(norm1_2['score'],norm1_2['Health_Camp_ID'])

# %% [markdown]
# ## Higher HealthCamp means that the patient has visited more health camps, Thus more the patient visited healthcamps , more was their Healthscore

# %% [markdown]
# ## Profiles + Camp1 and Camp2 (normalised)

# %%
pro_12 = norm1_2.merge(profiles,on = 'Patient_ID')

# %%
pro_12.head()

# %%
pro_12.isnull().sum()

# %%
pro_12.columns

# %%
pro_12['SM'] = pro_12['Online_Follower']+pro_12['LinkedIn_Shared']+pro_12['Twitter_Shared']+pro_12['Facebook_Shared']
# Social media together

# %%
pro_12 = pro_12.drop(['City_Type','Employer_Category','Education_Score','First_Interaction','Income','Age','Online_Follower',
       'LinkedIn_Shared', 'Twitter_Shared', 'Facebook_Shared'],axis = 1)

# %%
x = pro_12.drop(['Patient_ID','Health_Camp_ID','Donation','score'],axis = 1)
nor2 = preprocessing.MinMaxScaler()
one_two_norm = nor2.fit_transform(x)
x = pd.DataFrame(one_two_norm)

# %%
x.columns

# %%
x.head()

# %%
x.columns = ['SM']

# %%
pro_12 = pro_12.drop('SM',axis =1)

# %%
pro_12 = pd.concat([pro_12,x],axis = 1)

# %%
pro_12.head()

# %%
corr2 = pro_12.corr()

# %%
# corr = musk.corr()
cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "7pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]

corr2.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())

# %%
plt.scatter(pro_12['score'],pro_12['SM'])

# %% [markdown]
# # Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X = pro_12.drop(['score','Patient_ID'],axis = 1)
y = pro_12['score']

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %%
y_train.head()

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)

# %%
lr.score(x_test,y_test)

# %%
print('zero sm - ' ,len(pro_12[pro_12['SM']== 0]) ,'\none sm - ' , len(pro_12[pro_12['SM']== 1]) , '\ntwo sm - ' , len(pro_12[pro_12['SM']== 2]) ,'\nthree sm - ' , len(pro_12[pro_12['SM']== 3]),'\nfour sm - ' , len(pro_12[pro_12['SM']== 4]))

# %% [markdown]
# # Conclusion : Health Score Probablilty Increaser - TASK 1

# %% [markdown]
# ## The 3 Factors that can increase the Health score of a Patient

# %% [markdown]
#  ### Health_Camp_ID	- The more the number of times a patient is made to visit a health camp , more is his/her healtscore
#  ### Donation - The amount of donation is directly proportional to his/her health score , so patients who donate more are given a higher health score
#
# ### SM - The lesser the patient is into Socail media , more is his/her Health score .
