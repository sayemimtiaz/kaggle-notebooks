# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # This notebook uses a set of data that takes 500 games and compares their ESRB ratings. The ESRB is an official organization that rates video games based on their content. The possible ratings a game may receive are: RP(Rating Pending), EC(Early Childhood), E(Everyone), E10(Everyone 10+), T(Teen), M(Mature 17+), and A(Adults Only, 18+). Because EC, RP and A are extremely rare, this data set only examines games that received E, E10, T and M ratings.

# %% [markdown]
# # This data set uses binary code.
# # 1 = Yes.
# # 0 = No.

# %%
data=pd.read_csv('/kaggle/input/video-games-rating-by-esrb/test_esrb.csv')
data

# %% [markdown]
# # To filter data, we can single out titles or specific columns.

# %%
data.title.head()

# %%
data['title'][3]

# %%
data.iloc[3]

# %%
data.set_index('title')

# %% [markdown]
# # We can also filter data by coding the data to only show video games that fit certain descriptions. For example, the following piece of data only shows games rated M or T.

# %%
data.loc[(data.esrb_rating == 'M') | (data.esrb_rating == 'T')]

# %%
data.loc[data.esrb_rating.isin(['E','ET'])]

# %% [markdown]
# # Based on this data set, we can learn that a slight majority of games are rated T or M. In this data set, 55% of games were T or M rated, while 45% of games were rated E or E10.

# %% [markdown]
# # We can also use python and data sets to answer questions. For example, the ESRB can mark a game for having blood, or specifically blood and gore. I wanted to know if a game could be marked for both blood and blood and gore, so I ran a search and found that a game can't be marked for blood and blood and gore at the same time.

# %%
data_filtered = data.loc [(data.blood == 1) & (data.blood_and_gore == 1)]
data_filtered

# %%
data_filtered = data.loc [((data.esrb_rating == 'ET') | (data.esrb_rating == 'E')) & ((data.simulated_gambling == 1) | (data.alcohol_reference == 1)),['title','esrb_rating','simulated_gambling','alcohol_reference']]
data_filtered

# %%
data_filtered = data.loc [(data.esrb_rating == 'T') & ((data.sexual_content == 1) | (data.sexual_themes == 1)), ['title','esrb_rating','sexual_content','sexual_themes']]
data_filtered

# %%
feature_count = {}
M_rated_games = data.loc[data.esrb_rating=='M']
for col in e_rated_games:
    if col != 'title' and col != 'esrb_rating' and col != 'price' and col != 'console':
        feature_count[col] = M_rated_games[col].sum()
        
feature_count
