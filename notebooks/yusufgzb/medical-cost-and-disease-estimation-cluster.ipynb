# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import sys

from sklearn.cluster import KMeans

from scipy.cluster.hierarchy import linkage , dendrogram
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df=pd.read_csv("/kaggle/input/insurance/insurance.csv")
df.columns

# %%
df.head()

# %%
df.info()

# %%
df.describe()

# %%
df.corr()

# %%
filter1=df[(df["age"]>30) &(df["children"]>0) ]
filter1

# %%
filter1["smoker"].value_counts()

# %%
def smoker(x):
    if x=="yes":
        return "1"
    else:
        return "0"

filter1["smoker"]=filter1["smoker"].apply(smoker)
filter1.head(25)

# %%
filter1.info()

# %%
filter1["smoker"] = filter1.smoker.astype(float)
filter1.info()

# %%
disease=[]
for i in filter1.bmi:
    if  i > 30:
        disease.append(1)
    else :
        disease.append(0)


filter1["dangerous risk"]=disease

# %%
filter1.corr()

# %% [markdown]
# newly added column reveals the interconnection of other columns

# %%
filter1.drop(["region"],axis=1,inplace=True)
filter1.drop(["sex"],axis=1,inplace=True)

y=filter1['charges']
x=filter1.drop(['charges'],axis=1)

# %%
filter1.info()

# %%
k_fit=KMeans(n_clusters=4 ).fit(filter1)
print(k_fit.n_clusters)

print(k_fit.cluster_centers_)
print(k_fit.labels_)

merkezler=kmeans.cluster_centers_
kümeler=kmeans.labels_

# %%
plt.scatter(merkezler[:,0],merkezler[:,1],c="black",s=200,alpha=0.5)
plt.scatter(filter1.iloc[:,0],filter1.iloc[:,1],c=kümeler,s=50,cmap="viridis")

# %%
hc_complate=linkage(filter1,"complete")
hc_average=linkage(filter1,"average")

plt.figure(figsize=(15,5))
dendrogram(hc_complate,leaf_font_size=10);
