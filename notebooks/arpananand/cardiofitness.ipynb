# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("/kaggle/input/cardiogoodfitness/CardioGoodFitness.csv")

# %%
df.head()

# %%
df.info()

# %%
df.describe()

# %%
#Trying to figure out what are the unique values present in the columns to understand the data more acurately.
Col_list = ['Product','MaritalStatus','Usage','Fitness','Education']
for col in Col_list:
    print('{} : {}'.format(col.upper(),df[col].unique()))

# %% [markdown]
# ### UnderStanding The Dataset
# <ul>
#     <li>Dataset is about 3 products.</li>
#     <li>Used by customers who are both married and unmarried.</li>
#     <li>
#         Here, Usage, Fitness, Education is measured in numbers and are present inside a range
#         <ul>
#             <li>Like Fitness is scored btwn 1-5</li>
#             <li>Education lies btwn 12-21 years</li>
#             <li>Usage lies in the range 2-7 days/week</li>
#         </ul>
#     </li>
# </ul>

# %% [markdown]
# ### Visulaization

# %%
sns.countplot(x='Product',data=df)

# %%
sns.countplot(x='Fitness',data=df)

# %%
sns.countplot(x='Gender',data=df)

# %%
sns.countplot(x='Usage',data=df)

# %%
sns.countplot(x='Education',data=df)

# %%
df['Income'].hist(bins=50, figsize=(10,5))

# %%
df['Miles'].hist(bins=50, figsize=(10,5))

# %% [markdown]
# ### Finding Relations

# %%
sns.countplot(x='Fitness',data=df,hue='Gender')

# %% [markdown]
# This shows that men buy more product than women.<br/>
# This shows that men find themshelves more fit than women feel about themselves.

# %%
sns.countplot(x='Fitness',data=df,hue='Product')

# %% [markdown]
# We can see that **TM195** is a popular choice for people with average fitness where as **TM798** is a more popular choice with more fit people.

# %%
sns.countplot(x='Fitness',data=df,hue='MaritalStatus')

# %% [markdown]
# Married people find themselves more fit averagely than single people do.

# %%
sns.countplot(x='Fitness',data=df,hue='Usage')

# %% [markdown]
# It can be seen that people who access themselves a score of 3 in Fitness generally use the product 3-4 days.<br/>
# And the usage grows with the Fitness level.

# %%
plt.scatter(x=df['Fitness'],y=df['Miles'])

# %% [markdown]
# The more miles you run the more fit u get

# %%
plt.scatter(x=df['Product'],y=df['Miles'])

# %% [markdown]
# Product **TM798** offers better performance than the other 2, which can be assessed the reason of it beign more famous with more fit people.

# %%
plt.scatter(x=df['Fitness'],y=df['Income'])

# %%
plt.scatter(x=df['MaritalStatus'],y=df['Income'])

# %%
plt.scatter(x=df['Product'],y=df['Income'])

# %%
plt.scatter(x=df['Usage'],y=df['Income'])

# %%
plt.scatter(x=df['Product'],y=df['Usage'])

# %%
plt.scatter(x=df['Product'],y=df['Age'])

# %%
plt.scatter(x=df['Fitness'],y=df['Age'])

# %% [markdown]
# From the above it can be infered that,<br/>
# Since the product **TM798** provides better performance it is more popular and have a little high price than other products, which restrict it's market to people with more income and since married people have their income combined they have more money availing them to buy this product relative to single people. This inturn results in their fitness.
# <br/><br/>
# Though the sales of **TM195** is highest among the three products.
