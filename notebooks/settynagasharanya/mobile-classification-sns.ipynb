# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns   ## importing libraries

# %%
sadata = pd.read_csv('/kaggle/input/mobile-price-classification/train.csv')
tadata = pd.read_csv('/kaggle/input/mobile-price-classification/test.csv') ##loading the data set

# %%
sadata.head()

# %%
sadata.tail() ## last rows in data set

# %%
clock = sadata['int_memory']
type(clock)                  
             ## tells the data type

# %%
clock.head() ## first 5 rows

# %%
sadata.info() ## information

# %%
clocks = sadata['clock_speed']
sim = sadata['dual_sim']

# %%
clocks.value_counts().sort_index()

# %%
sim.describe() ## calculates mean,sstandard deviation and other parameters

# %%
clock.describe()

# %%
plt.hist(clock.dropna(),bins=20)
plt.xlabel('memory')
plt.show() 
## plot of memory values

# %%
core = sadata['n_cores']
plt.hist(core,bins=20)
plt.show()

# %%
power=sadata['battery_power']<1000
power.tail(15)

# %%
power.sum()
## sum of the battery_power

# %%
lclk = clocks < 1.5
lclk.mean()

# %%
hclk = ~lclk
hclk.mean()

# %%
sns.kdeplot(core)

# %%
plt.hist(core.dropna(),label="n_cores")
plt.show()

# %%
plt.plot(core,clocks,'o')
plt.xlabel("Number of cores")
plt.ylabel("Clock Speed")
plt.show()
## plotting n_cores graph

# %%
plt.plot(core,clocks,'o',alpha=0.02)
plt.show()

# %%
plt.plot(power,clocks,'o',alpha=0.02)
plt.show()

# %%
data = brfss.dropna(subset=['n_cores','clock_speed'])
sns.violinplot(x='n_cores',y='clock_speed',data=data,inner=None)
plt.show()

# %%
sadata.isnull().sum() #checking for total null values

# %%
plt.figure(figsize=(10,6))
sadata['fc'].hist(alpha=0.5,color='blue',label='Front camera')
sadata['pc'].hist(alpha=0.5,color='red',label='Primary camera')
plt.legend();
plt.xlabel('MegaPixels')

# %%
d1=sadata.copy() ## Copying the data frame

# %%
d1.corr()['price_range']

# %%
for col in d1.columns: 
    sns.boxplot(x=d1[col])
    print(col) 
    plt.show()  
##  boxplot in order to detect outliers

# %%
sns.boxplot(x=sadata['price_range'])

# %%
# Finding the relations between the variables.
plt.figure(figsize=(20,10))
c= sadata.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c

# %%
# Plotting a scatter plot
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(sadata['battery_power'], sadata['mobile_wt'])
ax.set_xlabel("Battery")
ax.set_ylabel("Weight")
plt.show()

# %%
# Plotting a scatter plot bet
fig, ax = plt.subplots(figsize=(14,12))
ax.scatter(sadata['px_height'], sadata['px_width'])
ax.set_xlabel("Height")
ax.set_ylabel("Width")
plt.show()

# %%
# Plotting a scatter plot
fig, ax = plt.subplots(figsize=(10,12))
ax.scatter(sadata['ram'], sadata['int_memory'])
ax.set_xlabel("RAM")
ax.set_ylabel("Memory")
plt.show()

# %%
# Plotting a scatter plot
fig, ax = plt.subplots(figsize=(4,4))
ax.scatter(sadata['three_g'], sadata['four_g'])
ax.set_xlabel("3G")
ax.set_ylabel("4G")
plt.show()

# %%
# Plotting a scatter plot
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(sadata['sc_h'], sadata['sc_w'])
ax.set_xlabel("sch")
ax.set_ylabel("scw")
plt.show()

# %%
fig, ax = plt.subplots(figsize =(5, 6)) 
sns.violinplot(ax = ax, x = sadata['wifi'], y = sadata['n_cores'] )

# %%
fig, ax = plt.subplots(figsize =(9, 7)) 
sns.violinplot(ax = ax, x = sadata['touch_screen'], y = sadata['four_g'] )

# %%
fig, ax = plt.subplots(figsize =(9, 7)) 
sns.violinplot(ax = ax, x = sadata['three_g'], y = sadata['four_g'] )

# %%
fig, ax = plt.subplots(figsize =(9, 7)) 
sns.violinplot(ax = ax, x = sadata['talk_time'], y = sadata['three_g'] )

# %%
sns.boxplot(sadata['fc'],sadata['price_range'])
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import sklearn.metrics as metrics

# %%
# Set variables for the targets and features
Y = sadata['price_range']
X = sadata.drop('price_range', axis=1)

# Split the data into training and validation sets
train_X, val_X, train_Y, val_Y = train_test_split(X, Y, random_state=6)

# %%
# Create the classifier and fit it to our training data
model = RandomForestClassifier(random_state=7, n_estimators=100)
model.fit(train_X, train_Y)
# Predict classes given the validation features
pred_y = model.predict(val_X)

# Calculate the accuracy as our performance metric
accuracy = metrics.accuracy_score(val_Y, pred_y)
print("Accuracy: ", accuracy)

# %%
#Support Vector Machine

from sklearn.svm import SVC
model = SVC()
x = sadata.drop('price_range',axis=1)
y = sadata['price_range']
model.fit(train_X,train_Y)
y_train_pred = model.predict(train_X)
y_test_pred = model.predict(val_X)


print("Train Set Accuracy:"+str(accuracy_score(y_train_pred,train_Y)*100))
print("Test Set Accuracy:"+str(accuracy_score(y_test_pred,val_Y)*100))
print("\nConfusion Matrix:\n%s"%confusion_matrix(y_test_pred,val_Y))
print("\nClassificationReport:\n%s"%classification_report(y_test_pred,val_Y))

# %%
#Logistic Regression

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report


model = LogisticRegression()
model.fit(train_X,train_Y)
y_train_pred = model.predict(train_X)
y_test_pred = model.predict(val_X)


print("Train Set Accuracy:"+str(accuracy_score(y_train_pred,train_Y)*100))
print("Test Set Accuracy:"+str(accuracy_score(y_test_pred,val_Y)*100))
print("\nConfusion Matrix:\n%s"%confusion_matrix(y_test_pred,val_Y))
print("\nClassification Report:\n%s"%classification_report(y_test_pred,val_Y))

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error
xg_reg = xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10, n_estimators = 10)
xg_reg.fit(train_X,train_Y)

preds = xg_reg.predict(val_X)
rmse = np.sqrt(mean_squared_error(val_Y, preds))
print("RMSE: %f" % (rmse))
