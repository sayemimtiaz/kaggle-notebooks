# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns  # visualization tool

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
data=pd.read_csv('../input/netflix-shows/netflix_titles.csv')
data.columns

# %%
data.head(5)

# %%
data.describe()

# %%
data.info()

# %%
print(data['country'].value_counts(dropna=False))

# %% [markdown]
# There are 476 NaN value

# %%
#data.boxplot(column='type',by ='release_year')

# %%
data.boxplot(column='show_id',by = 'release_year')

# %% [markdown]
# Boxplot takes 2 parameters but those should have type int

# %%
#TIDY DATA
data1=data.head()
data1

# %%
meltfonk=pd.melt(frame=data1,id_vars='title',value_vars=['country','release_year'])
meltfonk

# %%
#PIVOTING DATA

meltfonk.pivot(index='title',columns='variable',values='value')

# %%
#CONCATENATING DATA

D1=data.head(3)
D2=data.tail(3)

Concat_data=pd.concat([D1,D2],axis=0,ignore_index=True)
Concat_data

# %%
data.dtypes

# %%
data['rating']=data['rating'].astype('category')
#------
data.dtypes

# %%
data['rating']=data['rating'].astype('object')
data.dtypes

# %%
#MISSING DATA and TESTING WITH ASSERT

data['director'].value_counts(dropna=False)

# %%
#Drop nan values

data=data1

data1['director'].dropna(inplace=True)

# %%
data['title'].value_counts(dropna=True)

# %%
assert data['title'].notnull().all()

# %%
data['director'].fillna('empty',inplace=True)

# %%
data['director'].head()
