# %%
pip install us

# %%
pip install calmap

# %%
pip install pycountry_convert

# %%
pip install plotly

# %%
# import libraries 

import math                          
# math problems 
import random                        
# generate random no.s
import json                          
# load json files 
from datetime import timedelta        
#for date and time 
from urllib.request import urlopen   
# for getting the web contents
import numpy as np                   
# linear algebra 
import pandas as pd                  
# to create visual graphics 
import matplotlib.pyplot as plt      
# for basic visualisation 
import seaborn as sns                
# advanced plotting 

# for interactive visualization
import plotly.express as px 
import plotly.graph_objs as go
from plotly.subplots import make_subplots
from plotly.offline import plot, iplot, init_notebook_mode

# %%
cnf, dth, rec, act= "#f37121", "#d92027", "#438a5e", "#ea907a"

# %%
full_data=pd.read_csv("../input/corona-virus-report/covid_19_clean_complete.csv")

# %%
full_data.head()

# %%
full_data.tail()

# %%
full_grouped=pd.read_csv('../input/corona-virus-report/full_grouped.csv')
full_grouped['Date']=pd.to_datetime(full_grouped['Date'])

# %%
day_wise=pd.read_csv("../input/corona-virus-report/day_wise.csv")
day_wise['Date']=pd.to_datetime(day_wise['Date'])

# %%
country_wise=pd.read_csv('../input/corona-virus-report/country_wise_latest.csv')
country_wise=country_wise.replace('', np.nan).fillna(0)

# %%
temp=day_wise[['Date', 'Deaths', 'Recovered', 'Active']].tail(1)
temp=temp.melt(id_vars="Date", value_vars=["Active", "Deaths", "Recovered"])
fig=px.treemap(temp, path=["variable"], values="value", height=250, color_discrete_sequence=[act, rec, dth])
fig.data[0].textinfo='label+text+value'
fig.show()

# %%
#function to draw heat map

def plot_map(df, col, pal):
    df = df[df[col]>0]
    fig = px.choropleth(df, locations="Country/Region", locationmode="country names",
                       color=col, hover_name="Country/Region",
                      title=col, hover_data=[col], color_continuous_scale=pal)
    fig.show()

# %%
plot_map(country_wise, 'Confirmed', 'matter')

# %%
plot_map(country_wise, 'Deaths', 'matter')

# %%
plot_map(country_wise, 'Active', 'matter')

# %%
fig=px.choropleth(full_grouped, locations="Country/Region",
                 color=np.log(full_grouped["Confirmed"]),
                 locationmode='country names', hover_name="Country/Region",
                 animation_frame=full_grouped["Date"].dt.strftime('%y-%m-%d'),
                 title='Cases over time', color_continuous_scale=px.colors.sequential.matter)

fig.update(layout_coloraxis_showscale=False)
fig.show()

# %%
# spotting top 15 countries

def plot_hbar(df, col, n, hover_data=[]):
    fig = px.bar(df.sort_values(col).tail(n), 
                x=col, y="Country/Region", color="WHO Region", 
                 text=col, orientation='h', width=700, hover_data=hover_data,
                 color_discrete_sequence=px.colors.qualitative.Dark2)
    
    
    fig.update_layout(title=col, xaxis_title="", yaxis_title="",
                     yaxis_categoryorder="total ascending", uniformtext_minsize=8, uniformtext_mode='hide')
    
    fig.show()

# %%
plot_hbar(country_wise, "Confirmed", 15)

# %%
plot_hbar(country_wise, "Deaths", 15)

# %%
plot_hbar(country_wise, "Active", 15)
