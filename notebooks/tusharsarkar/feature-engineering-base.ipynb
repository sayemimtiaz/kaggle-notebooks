# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns

# %%
train_raw2 = pd.read_csv("../input/label-encoded-data/Label_Encoded_Train.csv")
train_raw2

# %%
test = pd.read_csv("../input/label-encoded-data/Label_Encoded_Test.csv")
test

# %%
#plt.scatter(train_raw2.Age,train_raw2['Visitors with Patient'])
#sns.barplot(x= "Age",y= "Type of Admission", data = train_raw2)
sns.barplot(x= "Severity of Illness",y= "Stay", data = train_raw2)

# %%
sns.barplot(x= "Type of Admission",y= "Stay", data = train_raw2)

# %%
#patient count
count = train_raw2.pivot_table(index=['patientid'],aggfunc='size')
c1= count.to_dict()

# %%
#patient count
train_raw2['patient_count'] = train_raw2['patientid'].apply(lambda x: c1.get(x))
train_raw2

# %%
#patient count
count = test.pivot_table(index=['patientid'],aggfunc='size')
c1= count.to_dict()
#patient count
test['patient_count'] = test['patientid'].apply(lambda x: c1.get(x))
test

# %%
train_raw2[train_raw2['Available Extra Rooms in Hospital'] == 0]

# %%
def new_features():
    l = ['Hospital_code','Hospital_type_code','Hospital_region_code','Department', 'Ward_Facility_Code','Bed Grade',
        'Type of Admission','Severity of Illness','Visitors with Patient','Age']
    for i in l:
        count = test.pivot_table(index=[i],aggfunc='size')
        c1 = count.to_dict()
        test[i +'_count'] = test[i].apply(lambda x: c1.get(x))
new_features()
test

# %%
def new_features():
    l = ['Hospital_code','Hospital_type_code','Hospital_region_code','Department', 'Ward_Facility_Code','Bed Grade',
        'Type of Admission','Severity of Illness','Visitors with Patient','Age']
    for i in l:
        count = train_raw2.pivot_table(index=[i],aggfunc='size')
        c1 = count.to_dict()
        train_raw2[i +'_count'] = train_raw2[i].apply(lambda x: c1.get(x))
new_features()

# %%
train_raw2

# %%
test_raw3 = test.groupby(by=['City_Code_Hospital','Hospital_region_code'])
count1 = test.pivot_table(index=['City_Code_Hospital','Hospital_region_code'],aggfunc= np.mean)["Hospital_type_code"]
g1 = count1.to_dict()
def f(x,y):
    return g1.get((x,y))
test['Hospital_type_code_mean'] = test[['City_Code_Hospital','Hospital_region_code']].apply(lambda x: f(*x),axis = 1)

# %%
train_raw3 = train_raw2.groupby(by=['City_Code_Hospital','Hospital_region_code'])
count1 = train_raw2.pivot_table(index=['City_Code_Hospital','Hospital_region_code'],aggfunc= np.mean)["Hospital_type_code"]

# c11= count1.to_dict()
# train12 = []
# for i in train_raw2.City_Code_Hospital.values:
#     for j in train_raw2.Hospital_region_code.values:
#         train12.append(c11.get((i,j)))
# train12       
#train_raw12 = train_raw2[['City_Code_Hospital','Hospital_region_code']].map(c11)
#c11
#train_raw4 = pd.DataFrame(train_raw3)
g1 = count1.to_dict()
def f(x,y):
    return g1.get((x,y))
train_raw2['Hospital_type_code_mean'] = train_raw2[['City_Code_Hospital','Hospital_region_code']].apply(lambda x: f(*x),axis = 1)

# %%
count2 = test.pivot_table(index=['City_Code_Hospital','Hospital_region_code'],aggfunc= np.mean)["Visitors with Patient"]
g2 = count2.to_dict()
def f(x,y):
    return g2.get((x,y))
test['Visitors_mean'] = test[['City_Code_Hospital','Hospital_region_code']].apply(lambda x: f(*x),axis = 1)

# %%
count2 = train_raw2.pivot_table(index=['City_Code_Hospital','Hospital_region_code'],aggfunc= np.mean)["Visitors with Patient"]
g2 = count2.to_dict()
def f(x,y):
    return g2.get((x,y))
train_raw2['Visitors_mean'] = train_raw2[['City_Code_Hospital','Hospital_region_code']].apply(lambda x: f(*x),axis = 1)

# %%
count3 = test.pivot_table(index=['City_Code_Hospital','Hospital_region_code'],aggfunc= np.mean)["Admission_Deposit"]
g3 = count3.to_dict()
def f(x,y):
    return g3.get((x,y))
test['Admission_Deposit_mean'] = test[['City_Code_Hospital','Hospital_region_code']].apply(lambda x: f(*x),axis = 1)

# %%
count3 = train_raw2.pivot_table(index=['City_Code_Hospital','Hospital_region_code'],aggfunc= np.mean)["Admission_Deposit"]
g3 = count3.to_dict()
def f(x,y):
    return g3.get((x,y))
train_raw2['Admission_Deposit_mean'] = train_raw2[['City_Code_Hospital','Hospital_region_code']].apply(lambda x: f(*x),axis = 1)

# %%
count4 = test.pivot_table(index=['City_Code_Hospital','Hospital_region_code'],aggfunc= np.max)["Admission_Deposit"]
g4 = count4.to_dict()
def f(x,y):
    return g4.get((x,y))
test['Admission_Deposit_max'] = test[['City_Code_Hospital','Hospital_region_code']].apply(lambda x: f(*x),axis = 1)

# %%
count4 = train_raw2.pivot_table(index=['City_Code_Hospital','Hospital_region_code'],aggfunc= np.max)["Admission_Deposit"]
g4 = count4.to_dict()
def f(x,y):
    return g4.get((x,y))
train_raw2['Admission_Deposit_max'] = train_raw2[['City_Code_Hospital','Hospital_region_code']].apply(lambda x: f(*x),axis = 1)

# %%
count5 = test.pivot_table(index=['City_Code_Hospital','Hospital_region_code'],aggfunc= np.min)["Admission_Deposit"]
g5 = count5.to_dict()
def f(x,y):
    return g5.get((x,y))
test['Admission_Deposit_min'] = test[['City_Code_Hospital','Hospital_region_code']].apply(lambda x: f(*x),axis = 1)

# %%
count5 = train_raw2.pivot_table(index=['City_Code_Hospital','Hospital_region_code'],aggfunc= np.min)["Admission_Deposit"]
g5 = count5.to_dict()
def f(x,y):
    return g5.get((x,y))
train_raw2['Admission_Deposit_min'] = train_raw2[['City_Code_Hospital','Hospital_region_code']].apply(lambda x: f(*x),axis = 1)

# %%
train_raw2['Admission_Deposit_min']

# %%
train_raw_6['Hospital_type_code_mean']

# %%
 train_raw3.get_group((0, 0)).Hospital_type_code.shape[0]

# %%
train_raw4[0].values

# %%
# def Hospital_type_code_mean():
#     htcm = []
#     for a in train_raw4[0].values:
#         m = train_raw3.get_group(a).Hospital_type_code.mean
#         for i in range(train_raw3.get_group(a).Hospital_type_code.shape[0]):
#             htcm.append(m)
#     return htcm
# htcm = Hospital_type_code_mean()

# %%
# def visitors_mean():
#     vm = []
#     for a in train_raw4[0].values:
#         m = train_raw3.get_group(a)['Visitors with Patient'].mean()
#         for i in range(train_raw3.get_group(a)['Visitors with Patient'].shape[0]):
#             vm.append(m)
#     return vm
# vm = visitors_mean()

# %%
# def admission_deposit_mean():
#     adm = []
#     ad_max  = []
#     ad_min = []
#     for a in train_raw4[0].values:
#         m = train_raw3.get_group(a)['Admission_Deposit'].mean()
#         m1 = train_raw3.get_group(a)['Admission_Deposit'].max()
#         m2  = train_raw3.get_group(a)['Admission_Deposit'].min()
#         for i in range(train_raw3.get_group(a)['Admission_Deposit'].shape[0]):
#             adm.append(m)
#             ad_max.append(m1)
#             ad_min.append(m2)
#     return adm,ad_max,ad_min
# adm,ad_max,ad_min = admission_deposit_mean()

# %%
# len(ad_min)

# %%
# train_raw2['Hospital_type_code_mean'] = np.array(htcm)

# %%
# train_raw2['Visitors_mean'] = np.array(vm)
# train_raw2['Admission_deposit_mean'] = np.array(adm)
# train_raw2['Admission_deposit_max'] = np.array(ad_max)
# train_raw2['Admission_deposit_min'] = np.array(ad_min)

# %%
test

# %%
train_raw2

# %%
test['Severity_and_Admission'] = test['Type of Admission'] + test['Severity of Illness']

# %%
train_raw2['Severity_and_Admission'] = train_raw2['Type of Admission'] + train_raw2['Severity of Illness']

# %%
train_raw2
train_raw2.Admission_Deposit

# %%
test['Admission_Deposit'] = np.log(test['Admission_Deposit'])
test.Admission_Deposit

# %%
train_raw2['Admission_Deposit'] = np.log(train_raw2['Admission_Deposit'])
train_raw2.Admission_Deposit

# %%
test["is_patient_admitted_in_same_city_hospital"] = np.where(test["City_Code_Patient"] == test["City_Code_Hospital"], 1, 0)

# %%
train_raw2["is_patient_admitted_in_same_city_hospital"] = np.where(train_raw2["City_Code_Patient"] == train_raw2["City_Code_Hospital"], 1, 0)

# %%
test['visitors_flag'] = test['Visitors with Patient'].apply(lambda x: 1 if x>17 else 0)

# %%
train_raw2['visitors_flag'] = train_raw2['Visitors with Patient'].apply(lambda x: 1 if x>17 else 0)

# %%
train_raw2

# %%
test['rooms_flag'] = test['Visitors with Patient'].apply(lambda x: 1 if x in [13,20,21] else 0)

# %%
test['rooms_flag'] = test['Visitors with Patient'].apply(lambda x: 1 if x in [13,20,21] else 0)

# %%
test['visitors_flag'] = test['Visitors with Patient'].apply(lambda x: 1 if x>17 else 0)

# %%
# t = train_raw_6.groupby(by = ["patientid","Hospital_code"])
# tr = pd.DataFrame(t)

# %%
# tr[0].values #.get_group((2,10))

# %%
count12 = test.pivot_table(index=["patientid","Hospital_code"],aggfunc= "size")
g12 = count12.to_dict()
def f(x,y):
    return g12.get((x,y))
test['Patient_Hospital'] = test[["patientid","Hospital_code"]].apply(lambda x: f(*x),axis = 1)
test['Patient_Hospital']

# %%
count12 = train_raw2.pivot_table(index=["patientid","Hospital_code"],aggfunc= "size")
g12 = count12.to_dict()
def f(x,y):
    return g12.get((x,y))
train_raw2['Patient_Hospital'] = train_raw2[["patientid","Hospital_code"]].apply(lambda x: f(*x),axis = 1)
train_raw2['Patient_Hospital']

# %%
count13 = test.pivot_table(index="patientid",aggfunc= np.max)["Hospital_code"]
g13 = count13.to_dict()
def f(x,y):
    return g13.get(x)
test['Hospital_mean'] = test["patientid"].apply(lambda x:  g13.get(x) )
test

# %%
count13 = train_raw2.pivot_table(index="patientid",aggfunc= np.max)["Hospital_code"]
g13 = count13.to_dict()
def f(x,y):
    return g13.get(x)
train_raw2['Hospital_mean'] = train_raw2["patientid"].apply(lambda x:  g13.get(x) )
train_raw2['Hospital_mean']

# %%
train_raw2['Hospital_mean'].nunique()

# %%
train_raw2.columns

# %%
train_raw2_beta = train_raw2

# %%
train_raw2.to_csv("Feature_Corrected_Train.csv",index=False)

# %%
from sklearn import linear_model
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier
rg = RandomForestClassifier()
xg = XGBClassifier()
ad = AdaBoostClassifier()
lr = linear_model.LinearRegression()
ad.fit(train_raw2[['Hospital_code', 'Hospital_type_code', 'City_Code_Hospital',
       'Hospital_region_code', 'Available Extra Rooms in Hospital',
       'Department', 'Ward_Type', 'Ward_Facility_Code', 'Bed Grade',
        'City_Code_Patient', 'Type of Admission',
       'Severity of Illness', 'Visitors with Patient', 'Age',
       'Admission_Deposit', 'patient_count', 'Hospital_code_count',
       'Hospital_type_code_count', 'Hospital_region_code_count',
       'Department_count', 'Ward_Facility_Code_count', 'Bed Grade_count',
       'Type of Admission_count', 'Severity of Illness_count',
       'Visitors with Patient_count', 'Age_count', 'Hospital_type_code_mean',
       'Visitors_mean', 'Admission_deposit_mean', 'Admission_deposit_max',
       'Admission_deposit_min', 'Severity_and_Admission','is_patient_admitted_in_same_city_hospital', 'visitors_flag',
       'rooms_flag']][-200000:],train_raw2['Stay'][-200000:])

ad.score(train_raw2[['Hospital_code', 'Hospital_type_code', 'City_Code_Hospital',
       'Hospital_region_code', 'Available Extra Rooms in Hospital',
       'Department', 'Ward_Type', 'Ward_Facility_Code', 'Bed Grade',
        'City_Code_Patient', 'Type of Admission',
       'Severity of Illness', 'Visitors with Patient', 'Age',
       'Admission_Deposit', 'patient_count', 'Hospital_code_count',
       'Hospital_type_code_count', 'Hospital_region_code_count',
       'Department_count', 'Ward_Facility_Code_count', 'Bed Grade_count',
       'Type of Admission_count', 'Severity of Illness_count',
       'Visitors with Patient_count', 'Age_count', 'Hospital_type_code_mean',
       'Visitors_mean', 'Admission_deposit_mean', 'Admission_deposit_max',
       'Admission_deposit_min', 'Severity_and_Admission','is_patient_admitted_in_same_city_hospital', 'visitors_flag',
       'rooms_flag']][-200000:],train_raw2['Stay'][-200000:])

# %%
ad.score(train_raw2[['Hospital_code', 'Hospital_type_code', 'City_Code_Hospital',
       'Hospital_region_code', 'Available Extra Rooms in Hospital',
       'Department', 'Ward_Type', 'Ward_Facility_Code', 'Bed Grade',
        'City_Code_Patient', 'Type of Admission',
       'Severity of Illness', 'Visitors with Patient', 'Age',
       'Admission_Deposit', 'patient_count', 'Hospital_code_count',
       'Hospital_type_code_count', 'Hospital_region_code_count',
       'Department_count', 'Ward_Facility_Code_count', 'Bed Grade_count',
       'Type of Admission_count', 'Severity of Illness_count',
       'Visitors with Patient_count', 'Age_count', 'Hospital_type_code_mean',
       'Visitors_mean', 'Admission_deposit_mean', 'Admission_deposit_max',
       'Admission_deposit_min', 'Severity_and_Admission','is_patient_admitted_in_same_city_hospital', 'visitors_flag',
       'rooms_flag']][:-200000],train_raw2['Stay'][:-200000:])

# %%
plt.plot(xg.feature_importances_)

# %%
plt.plot(rg.feature_importances_)

# %%
plt.plot(ad.feature_importances_)

# %%
train_raw2.corr()

# %%
sns.heatmap(train_raw2.corr())

# %%
train_raw_6 = pd.read_csv("Feature_Corrected_Train.csv")
train_raw_6.Admission_Deposit

# %%
train_raw_6.drop("City_Hospital_region_code",axis=1,inplace=True)
train_raw_6

# %%
train_raw_6.to_csv("Feature_Corrected_Train.csv",index= False)

# %%
test.to_csv("Feature_Corrected_Test.csv",index=False)

# %%
test.columns

# %%
col = ['Hospital_code', 'Hospital_type_code', 'City_Code_Hospital',
       'Hospital_region_code', 'Available Extra Rooms in Hospital',
       'Department', 'Ward_Type', 'Ward_Facility_Code', 'Bed Grade',
       'patientid', 'City_Code_Patient', 'Type of Admission',
       'Severity of Illness', 'Visitors with Patient', 'Age']

# %%
from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()
enc.fit_transform(np.array(train_raw_6.Hospital_code).reshape(1,-1))

# %%
train_raw_6
