# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

# Any results you write to the current directory are saved as output.

# %%
zika = pd.read_csv("../input/cdc_zika.csv")

# %%
zika.head()

# %%
zika.isnull().sum()

# %%
zika.shape

# %%
zika.data_field.value_counts()

# %%
zika.location_type.unique()

# %%
zika.location_type.value_counts()

# %%
zika.head()

# %%
zika.location.str.split("-").apply(lambda x =  )

# %%
zika.location[107594]

# %%
s = ['0-1']
a,b = s[0].split('-')
a, "foo", b
a

# %%
def split(s):
    s = str(s)
    a, b = s.split()
    return a, b

# %%
zika["country"], zika["city"] = zika.location.apply(lambda x:split(x) )

# %%
zika['location'].str[1:-1].str.split('-').apply(pd.Series).astype(float)

# %%
zika.location[0]

# %%
location_df = zika['location'].astype(str).apply(lambda x: pd.Series(x.split('-')))

# %%
from pandas import DataFrame
DataFrame([zika.location.str.split("-")[0:], zika.location.str.split("-")[1:], columns = ["country", "city"])

# %%
zika["country"], zika["area"] = zika.location.str.split("-")[0], zika.location.str.split("-")[1]
zika.head()

# %%
zika.location.value_counts()

# %%
zika.columns

# %%
zika[["location", "location_type"]].groupby(location).agg(["count","mean"])

# %%
zika.location_type.unique()

# %%
zika.groupby(zika.location_type=="state", zika.department==["location_type", "location"]).count()
