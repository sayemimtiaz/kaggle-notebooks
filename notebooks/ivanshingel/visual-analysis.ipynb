# %%
import pandas as pd
import seaborn as sns
import missingno as msno
import os
data = pd.read_csv('../input/drug-classification/drug200.csv')
data.head()

# %%
data.Drug = data.Drug.replace('DrugY', 'drugY')

# %%
data.BP.unique()

# %%
data.Cholesterol.unique()

# %%
data.Drug.unique()

# %%
data.Sex.unique()

# %%
msno.matrix(df=data)

# %%
sns.pairplot(data=data, hue='Sex')

# %%
sns.pairplot(data=data, hue='Drug')

# %%
sns.heatmap(data.corr(), annot=True)

# %%
sns.relplot(data=data, x="Na_to_K", y="Age", col="Drug")

# %%
sns.catplot(x='Drug', y='Age', hue='Sex', data=data)

# %%
sns.boxplot(x= 'BP', y= 'Age', data= data, hue= 'Drug')

# %%
sns.boxplot(x= 'Cholesterol', y= 'Age', data= data, hue= 'Drug')

# %%
sns.countplot(data= data, x= 'BP', hue= 'Drug')

# %%
sns.countplot(data= data, x= 'Cholesterol', hue= 'Drug')

# %%
sns.countplot(data= data, x= 'Sex', hue= 'Drug')

# %%
sns.barplot(data= data, x= 'Drug', y= 'Na_to_K')

# %%
sns.boxplot(x= 'Sex', y= 'Na_to_K', data= data, hue= 'Drug')
