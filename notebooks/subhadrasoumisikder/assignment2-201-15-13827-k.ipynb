# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
pip install numpy

# %%
import numpy
arr = numpy.array([1,3,4,5])
arr

# %%
import numpy as nm
arr = nm.array([1,3,4,5])
type(arr)

# %%
import numpy as nm
arr=nm.array([ [1,2,3] , [1,6,4] ])
arr.ndim

# %%
arr=nm.array([1],ndmin=6)
arr

# %%
arr=nm.array([12,45,67])
arr[2]

# %%
arr=nm.array([ [1,2,3] , [2,6,4] ])
arr[0,0]

# %%
arr=nm.array([[ [1,2,3] , [9,6,4] , [45,67,89]] ,[ [2,4,5],[45,78,89],[56,87,65]] ])
arr[0,1,2]

# %%
arr=nm.array([[ [1,2,3] , [9,6,4] , [45,67,89]] ,[ [2,4,5],[45,78,89],[56,87,65]] ])
arr[-1,-1]

# %%
arr=nm.array([1,2,3,6,7])
arr[:-2]

# %%
arr=nm.array([23,45,56,1,2,3,6,7])
arr[1:3:5]

# %%
arr=nm.array([ [1,2,3,6,7] , [2,6,4,56,45] ])
arr[1,1:4] # for accessing 1 index

# %%
arr=nm.array([ [1,2,3,6,7] , [2,6,4,56,45] ])
arr[0:3,2:4] #for range of two

# %%
arr=nm.array([[ [1,2,3] , [9,6,4] , [45,67,89]] ,[ [2,4,5],[45,78,89],[56,87,65]] ])
arr.shape

# %%
arr=nm.array([[ [1,2,3] , [9,6,4] , [45,67,89]] ,[ [2,4,5],[45,78,89],[56,87,65]] ])
narr=arr.reshape(3,6)
narr

# %%
arr=nm.array([[ [1,2,3] , [9,6,4] , [45,67,89]] ,[ [2,4,5],[45,78,89],[56,87,65]] ])
narr=arr.reshape(-1)
narr

# %%
arr=nm.array([[ [1,2,3] , [9,6,4] , [45,67,89]] ,[ [2,4,5],[45,78,89],[56,87,65]] ])
narr=arr.reshape(-1)
nnarr=narr.reshape(3,6)
nnarr

# %%
arr=nm.array([ [1,2,3] , [2,6,4] ])
for x in arr:
    for y in x:
        print(y)

# %%
arr=nm.array([ [1,2,3] , [2,6,4] ])
for x in nm.nditer(arr):
    print(x)

# %%
arr=nm.array([ [1,2,3] , [9,6,4] , [45,67,89] , [2,4,5],[45,78,89],[56,87,65] ])
nrr=nm.array_split(arr,3)
nrr

# %%
arr=nm.array([ [1,2,3] , [9,6,4] , [45,67,89] , [2,4,5],[45,78,89],[56,87,65] ])
x=nm.where(arr==4)
x

# %%
arr=nm.array([ [1,2,3] , [9,6,4] , [45,67,89] , [2,4,5],[45,78,89],[56,87,65] ])
x=nm.where(arr%2==0)
x

# %%
arr=nm.array([1,2,3,6,7])
nm.searchsorted(arr,90)

# %%
arr=nm.array([13,21,3,6,7])
print(nm.sort(arr))

# %%
from numpy import random
x = random.randint(10)
x

# %%
from numpy import random
x = random.rand()
x

# %%
from numpy import random
x = random.randint(100,size=(4))
x

# %%
from numpy import random
x = random.randint(100,size=(4,4))
x

# %%
x = random.choice([5,67,89,34],size=(4,5))
x

# %%
pip install pandas

# %%
import pandas as pd

# %%
mydataset = {
    'Cars':[ "Mitsubishi" , "BMW" , "Ferrary"],
    'Number':[2,3,5]
}
var = pd.DataFrame(mydataset)
var

# %%
series= [1,2,3,4]
s=pd.Series(series)
s

# %%
series= [1,2,3,4]
s=pd.Series(series)
s[2]

# %%
series= [1,2,3,4]
s=pd.Series(series,index=["Rose","Tulip","Night Queen","Lily"])
s

# %%
series= [1,2,3,4]
s=pd.DataFrame(series,index=["Rose","Tulip","Night Queen","Lily"])
s

# %%
import pandas as pd
df = pd.read_csv("../input/netflix-shows/netflix_titles.csv")
df

# %%
import pandas as pd
df = pd.read_csv("../input/netflix-shows/netflix_titles.csv")
df.to_string()
print(df.to_string())

# %%
import pandas as pd
df = pd.read_csv("../input/netflix-shows/netflix_titles.csv")
df.head(2)

# %%
import pandas as pd
df = pd.read_csv("../input/netflix-shows/netflix_titles.csv")
df.tail(4)

# %%
df.info()

# %%
df = df.dropna()
df

# %%
df.fillna(100,inplace=True)
df

# %%
import pandas as pd
df = pd.read_csv("../input/netflix-shows/netflix_titles.csv")
df["type"].fillna(100,inplace = True)
df

# %%
import pandas as pd
df = pd.read_csv("../input/netflix-shows/netflix_titles.csv")
x = df["release_year"].mean()
df["type"].fillna(x,inplace = True)
df

# %%
import pandas as pd
df = pd.read_csv("../input/netflix-shows/netflix_titles.csv")
x = df["release_year"].mode(1)
df["type"].fillna(x,inplace = True)
df
