# %%
import pandas as pd


input_data = pd.read_csv("../input/heart-disease-uci/heart.csv")
data = pd.DataFrame(data=input_data)
data

# %%
import pandas as pd


input_data = pd.read_csv("../input/heart-disease-uci/heart.csv")
data = pd.DataFrame(data=input_data)
data.head(5)

# %%
import pandas as pd


input_data = pd.read_csv("../input/heart-disease-uci/heart.csv")
data = pd.DataFrame(data=input_data)
data.at[4, "sex"]

# %%
import pandas as pd


input_data = pd.read_csv("../input/heart-disease-uci/heart.csv")
data = pd.DataFrame(data=input_data)
data.tail(3)

# %%
import pandas as pd


input_data = pd.read_csv("../input/heart-disease-uci/heart.csv")
data = pd.DataFrame(data=input_data)
data.iat[1,4]

# %%
import pandas as pd


input_data = pd.read_csv("../input/heart-disease-uci/heart.csv")
data = pd.DataFrame(data=input_data)
data.keys()

# %%
import pandas as pd


input_data = pd.read_csv("../input/heart-disease-uci/heart.csv")
data = pd.DataFrame(data=input_data)
test_data = data.tail(3)
test_data.insert(0, "new_col", [1, 2, 3])
test_data

# %%
import pandas as pd


input_data = pd.read_csv("../input/heart-disease-uci/heart.csv")
data = pd.DataFrame(data=input_data)
data.pop("age")

# %%
import pandas as pd


input_data = pd.read_csv("../input/heart-disease-uci/heart.csv")
data = pd.DataFrame(data=input_data)
data.isin([0, 1])

# %%
import pandas as pd


input_data = pd.read_csv("../input/heart-disease-uci/heart.csv")
data = pd.DataFrame(data=input_data)
test_data = data.tail(3)
test_data.rename(columns={"age": "a", "cp": "CP"})

# %%
import pandas as pd


input_data = pd.read_csv("../input/heart-disease-uci/heart.csv")
data = pd.DataFrame(data=input_data)
data.rename_axis("types", axis="columns")

# %%
import pandas as pd


input_data = pd.read_csv("../input/heart-disease-uci/heart.csv")
data = pd.DataFrame(data=input_data)
data.sort_values(by="age")

# %%
import pandas as pd


input_data = pd.read_csv("../input/heart-disease-uci/heart.csv")
data = pd.DataFrame(data=input_data)
data.sort_index(ascending=False)

# %%
import pandas as pd


input_data = pd.read_csv("../input/heart-disease-uci/heart.csv")
data = pd.DataFrame(data=input_data)
test_data = data.head(3)
test_data_2 = data.tail(3)
test_data = test_data.merge(test_data_2, how='cross')
test_data

# %%
import pandas as pd
import numpy as np


input_data = pd.read_csv("../input/heart-disease-uci/heart.csv")
data = pd.DataFrame(data=input_data)
data = data.replace(1,np.NaN)
data.dropna()

# %%
import pandas as pd
import numpy as np


input_data = pd.read_csv("../input/heart-disease-uci/heart.csv")
data = pd.DataFrame(data=input_data)
data = data.replace(1,np.NaN)
data.fillna(0)

# %%
import pandas as pd
import numpy as np


input_data = pd.read_csv("../input/heart-disease-uci/heart.csv")
data = pd.DataFrame(data=input_data)
data = data.replace(1,np.NaN)
data.replace(np.NaN, 6)

# %%
import pandas as pd


input_data = pd.read_csv("../input/heart-disease-uci/heart.csv")
data = pd.DataFrame(data=input_data)
data = data.pop("age")
data.plot.hist()

# %%
import pandas as pd


input_data = pd.read_csv("../input/heart-disease-uci/heart.csv")
data = pd.DataFrame(data=input_data)
data.plot.box()
