# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import confusion_matrix, precision_score, recall_score
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder, StandardScaler

# %%
df = pd.read_csv('../input/mushroom-classification/mushrooms.csv')

# %%
train_df = df['class']
pred_df = df.drop('class',axis=1)

# %%
le = LabelEncoder()
data_x = le.fit_transform(train_df)

# %%
pred_df = pd.get_dummies(pred_df, prefix='', prefix_sep='')

# %%
y = data_x
x = pred_df.values

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=10)

# %%
model = Sequential()
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(1,activation="sigmoid"))

# %%
model.compile(optimizer="adam",loss="mse",metrics=['accuracy'])
model.fit(x=x_train, y = y_train,validation_data=(x_test,y_test),batch_size=250,epochs=190)

# %%
history = pd.DataFrame(model.history.history)
import matplotlib.pyplot as plt
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
pred_df.shape

# %%
predict = scaler.transform( pred_df.iloc[:].values.reshape(-1,117))
y_pred = model.predict(predict)

# %%
last_pred = []
for i in y_pred:
    if i > 0.5:
        last_pred.append(1)
    else:
        last_pred.append(0)

# %%
last_pred
