# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# %matplotlib inline
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
mcq=pd.read_csv('../input/kaggle-survey-2017/multipleChoiceResponses.csv',encoding='ISO-8859-1',low_memory=False)

# %%
mcq.columns

# %%
sns.countplot(y='LanguageRecommendationSelect',data=mcq)

# %%
sns.countplot(y='CurrentJobTitleSelect',data=mcq)

# %%
sns.countplot(y=mcq['CurrentJobTitleSelect'])

# %%
# 현재 하고 있는 일에 대한 전체 응답수
mcq[mcq['CurrentJobTitleSelect'].notnull()]['CurrentJobTitleSelect'].shape

# %%
mcq['CurrentJobTitleSelect'].shape

# %%
# 현재 하고있는 일에 대한 응답을 해준 사람중   Python과 R을 사용하는 사람
# 응답자들이 실제 업무에서 어떤 언어를 주로 사용하는지 볼 수 있다.

data=mcq[(mcq['CurrentJobTitleSelect'].notnull())& 
         ((mcq['LanguageRecommendationSelect']=='Python') | 
         (mcq['LanguageRecommendationSelect']=='R'))]

# %%
data

# %% [markdown]
# pd.read_csv 는 mcq안에 참거짓문을 넣을떄 괄호를 같이 껴서 넣어준다.
#
# &
#
# |
#
# 각 한번만 쓴다.

# %%
print(data.shape)

# %%
plt.figure(figsize=(8,10))
sns.countplot(y='CurrentJobTitleSelect',
                hue='LanguageRecommendationSelect',
                 data=data)

# %% [markdown]
# hue:각 y label에서 어떤 column을 출력할건가.
#
# y:y레이블
# x:그에 해당하는 값

# %% [markdown]
# 데이터 사이언티스트들은 Pyhon을 주로 사용하지만R을 사용하는 직업군도 제법된다.

# %%
mcq_ml_tool_count = pd.DataFrame(
    mcq['MLToolNextYearSelect'].value_counts())

mcq_ml_tool_percent=pd.DataFrame(
    mcq['MLToolNextYearSelect'].value_counts(normalize=True))

mcq_ml_tool_df= mcq_ml_tool_count.merge(
    mcq_ml_tool_percent ,
    left_index=True,
    right_index=True).head(20)

mcq_ml_tool_df.columns= ['응답수','비율']
mcq_ml_tool_df

# %% [markdown]
# .columns  : columns을 예쁘게 지정

# %%
# data=mcq['MLToolNextYearSelect'].value_counts().head(20)
# data=mcq['MLToolNextYearSelect'].head(20)
data=mcq
# data.columns
# data
plt.figure(figsize=(8,10))
# data.plot.barh()
sns.countplot(y="MLToolNextYearSelect",data=data)
# data.head(20)

# %%
data=mcq['MLToolNextYearSelect'].value_counts().head(20)

# sns.countplot('MLToolNex')
# sns.barplot(y=data.index,x=data)

# %% [markdown]
# Tool선택수를 시각화 하고 싶다.
# x축이든 y축에는  index
# 다른 한쪽은 그 개수
# countplot을 사용하게 되면 ,
# 한쪽 축만 설정하고 , 나머지 축은 그 개수를 세게됨
# data를 그대로 mcq로 받아서 countplot출력을 하게되면  모든 항목(Tool)에 대해서 출력.
# 항목수가 적으면 상관 없지만  , 만약   정렬해서 시각화를 하게되면
# 하지만, 우리가 만약 상위 여러개의 데이터에 대해서만 궁금하다.
#
# 따라서 , 우리는 value_counts메소드를 사용해야한다.
#
# countplot을 value_counts 한것에 사용하게 되면
# value_counts의 data값은 숫자이므로 축에 숫자가 출력된다.
# 우리가 원하는 것은 Tool 이름을 한축(y축)에 설정하고, 다른축(x축)에 그 갯수를 출력하는 것이다.
# 따라서, value_counts한것을 그냥 사용하면 안된다.   \
#
# 1.plot.bar ,plot.barh 를 사용
# 이렇게 되면 단색으로 표현가능
#
#
# 2.barplot을 사용
# x축,y축을 내가 원하는 값으로 지정 가능하다.
# index, data값을 축으로 지정한다.

# %%
data= mcq['MLMethodNextYearSelect'].value_counts().head(15)

sns.barplot(y=data.index,x=data)

# %% [markdown]
# ML메소드 를 상위 15개만 출력을 하고싶다.
# value_counts().head(15)로 data를 색인해준다.
# 그 다음에 barplot으로 y,x축을 지정해준다.

# %%
data=mcq['LearningPlatformSelect'].value_counts().head(15)
sns.barplot(y=data.index,x=data)

# %%
mcq['LearningPlatformSelect'] = mcq['LearningPlatformSelect'].astype('str')
# mcq.shape
# s = mcq['LearningPlatformSelect'].head()
mcq['LearningPlatformSelect']


s= pd.Series(mcq['LearningPlatformSelect'])
s.name = 'platform'
# s= mcq.apply(
#     lambda x : pd.Series(x['LearningPlatformSelect']),
#     axis = 1)
# s= mcq.apply(
#     lambda x : pd.Series(x['LearningPlatformSelect']),
#     axis = 1).stack()
# s= mcq.apply(
#     lambda x : pd.Series(x['LearningPlatformSelect']),
#     axis = 1).stack().reset_index(level=1,drop=True)

s

# %% [markdown]
# axis=1  행 에데해서
# axis = 0 열에 대해서
# level -> int,str,tuple,list가 인자로  올 수 있다.
#         multilevel_index인 경우 지정해준 인덱스를 컬럼으로 올린다.
#
# level1 index가 0,0, ... 이렇게 이어지는 쓸모없는 정보이므로 이 index를 column으로 올리고  drop 해준다.

# %% [markdown]
# LearnigPlatformSelect는 응답당 복수응답이다.
#
# # 그리고 왜 굳이 lambda를 썻는지 이해 안됨

# %%
plt.figure(figsize=(6,8))
data = s[s!='nan'].value_counts().head(15)
sns.barplot(x=data,y=data.index)

# %% [markdown]
# # 보고싶은거: 플랫폼 상위 15개 선택의 개수
#  단, 결측치는 빼준다.(nan)
#  따라서, pandas에서의 index를 해주면 원하는 데이터만 색인이 되므로 , index에 조건을 넣어준다.
#  그리고, 개수가 보고싶으므로 ,value_counts,
#  상위 15개이므로 head()
#  1.단색으로 그냥 표현하고 싶으면 plot.bar  ,plot.barh
# 2. 알록닭록 , barplot

# %%
# 설문 내용과 누구에게 물어봤는지를 찾아봄
question = pd.read_csv('../input/kaggle-survey-2017/schema.csv')
# qc = question.loc[question['Column'].str.contains('LearningCategory')]
qc=question[question['Column'].str.contains('LearningCategory')]
qc

# %% [markdown]
# ** LOC을 인자 하나만 주면 그냥 index할떄 조건을 넣어주는것과 같음

# %% [markdown]
# # 학습플랫폼들과 유용함에 대한 연관성

# %%
use_features = [x for x in mcq.columns if x.find(
    'LearningPlatformUsefulness') != -1]
use_features

# %%
fdf ={}

for feature in use_features :
        a=mcq[feature].value_counts()
        a= a/a.sum()
        fdf[feature[len('LearningPlatformUsefulness'):]] = a

        
# fdf = pd.DataFrame(fdf)
fdf = pd.DataFrame(fdf).transpose().sort_values(
        'Very useful' ,ascending=False)
plt.figure(figsize=(10,10))
sns.heatmap(
    fdf , annot=True
    )
# fdf['Very useful']
# sns.barplot(y=fdf.index,x=fdf['Very useful'])

# %% [markdown]
# **python에서 문자열을 부분출력할떄 index해서 출력하면됨
# value_counts를 하면 나온 값들의 개수를 센다.
# DataFrame은 2차원 행렬 데이터에 index를 붙인것
# Series 는 1차원 행렬 에 index를 붙인것
#
# ***여기선 응답 개수가 여러개이고 , 항목도 여러개이므로 2차원 행렬 데이터라 볼 수 있다.
# *** 따라서 여기선 DataFrame을 쓰는것이 맞다.
# DataFrame에 인자로 딕셔너리를 넘겨주면  key가 컬럼으로 value가 행으로 가게된다.
# 자세한 설명은 안적혀 있는데 , value가 Dataframe이면 Dataframe의 index가 자동으로 index가 되는듯 하다.
#
# 여기서 key값은 응답 이고 , value가 Platform이다.
# 우리는 platform을 기준으로 정렬하고 싶으므로 transpose해준다.
# 그리고 , 'Very useful'한 항목을 보고싶으므로 이를 기준으로 정렬해준ㄷ.ㅏ
# ascending = false , 면 내림차순으로 정렬
# 상관관계가 변인들간의 관계를 분석하는건데 출력을 왜 상관관계라 설명할까요>>

# %%
fdf.plot(kind='bar' , figsize=(20,8) ,
            title = "Usefullness of Learning Platforms")

# %% [markdown]
# # 학습방법(LearningCategory)를 분석해보자

# %%
cdf={}
cat_features = [x for x in mcq.columns if x.find(
    'LearningCategory') != -1]
# cat_features
for feature in cat_features:
    cdf[feature[len('LearningCategory'): ]]=mcq[feature].mean()
# cdf
# cdf = pd.DataFrame(cdf , index =range(0,1) )  
cdf = pd.Series(cdf)  
plt.pie(cdf , labels= cdf.index,autopct='%1.1f%%',shadow= True,
          startangle=140 )
plt.title("Contribution of each Platform to Learning")
plt.show()
# cdf
# cdf.memory_usage()

# %% [markdown]
# 1차원 행렬(벡터) 데이터 이기 때문에 series를 써도 된다.
# 메모리는 DataFrame보다 dataseries가 더 작다.
# 씨본에서는 piechart없기 때문에 , plot을 사용하엿다.

# %%
# cdf={}
# mcq['LearningCategorySelftTaught']
# for feature in cat_features :
#     cdf[feature[len('LearningCategory'):]] =mcq[feature].mean()

plt.pie(cdf,labels=cdf.index, )

# %% [markdown]
# LearningCategory항목은 개인 당 총합 100점을 분산해서 주는 항목이다.(항목당 사용하는 비율, 혹은 기여도)
# 우리의 목적은 사람들이 주로 사용하는 학습방법이 무엇인가이다.
# 주로 사용하는건 각 항목당 개수를 세서 , 비율화(개수/전체개수) 시키면 편함
#
# 각 항목의 평균의 합이 100점임으로 원모양의 차트를 그릴수있게된다??(원모양의 차트는 100프로를 비율별로 나눠서 설명할 떄 쓰임)
# ㅇ

# %% [markdown]
# # 복수응답인데 여기서 주로 사용하는 경우(다수결) 을 정하면 곤란한 경우
#
# 선거를 예시를들자,한명이 1표부터 천만표 까지를 행사할 수 있다고 치자.
# 그럼, 한명이 천만표 행사하고 나머지 3천만 국민이 1표씩 행사하고 여기서 최다득표자를 정하면 이건 공정하다 볼 수 있는가
# 여기서 주로 사용하는 방법을 선택 할 수 있는 이유는 한명당 행사할 수있는 표(전체응답에서의 비율)이 동일 하기 때문에 사용가능하다.
# 선택권을 줬는데 기권을 한경우->이경우도 공정하다 본다.

# %% [markdown]
# ## 데이터 과확을 위해 높은 사양의 컴퓨터가 필요한가요

# %% [markdown]
# 높은 사양이란 무엇일까

# %%
qc = question.loc[
    question['Column'].str.contains('HardwarePersonalProjectsSelect')]
qc

# %%
mcq[mcq['HardwarePersonalProjectsSelect'].notnull()][    
    'HardwarePersonalProjectsSelect'].shape
mcq[mcq['HardwarePersonalProjectsSelect'].notnull()]['HardwarePersonalProjectsSelect']

# %% [markdown]
# 응답은 주관식(?) 같음

# %%
mcq['HardwarePersonalProjectsSelect'
   ] = mcq['HardwarePersonalProjectsSelect'
    ].astype('str').apply(lambda x:
                          x.split(','))
s = mcq.apply(lambda x: 
              pd.Series(x['HardwarePersonalProjectsSelect']), 
                        axis =1).stack().reset_index(level=1, drop=True)

s.name = 'hardware'   

s

# %%
s = s[s !='nan']
s
pd.DataFrame(s.value_counts())

# %% [markdown]
# 시각화가 의미없는 경우???

# %% [markdown]
# # Q5. Datascience 공부에 얼마나  많은 시간을 투자하는가

# %%
plt.figure(figsize=(10,8))
data = mcq['TimeSpentStudying'].value_counts()
data
sns.countplot(y='TimeSpentStudying',
            data=mcq,
              hue='EmploymentStatus'
             ).legend(loc='upper right',
                     bbox_to_anchor=(1.05,0.5))

# %% [markdown]
#  직업군 별 , 공부 시간투자
#  변수가 여러개
#  ,개수 순으로 정렬해서 시각화 하고싶으면 value_counts를 사용하고 , barplot을 사용하면 되지만,
#  다른 변인들에대한 관계도 보고싶으면 mcq를 그대로 사용하여야 한다.
#  value_counts를 사용하지 못한다.
#  그냥 mcq를 사용해야 한다. mcq의 TimeSpentStudying의 개수를 출력하면 , 그냥 countplot만 사용하면되지만,
#  또다른 변인인 Employmentstatus를 추가할 것이다.

# %% [markdown]
# 풀타임으로 일하는 사람들은 2~10시간 공부하는 비율이 높으며,풀타임으로 일하는 사람보다 일을찾고있는 사람들이 더 많은 시간을 공부하는 편이다.
# 하지만, 응답자중 대부분이 풀타임으로 일하고 있는 사람들이라는 것을 고려할 필요가 있따.
# 응답자비율이 , 풀타임 일하고잇는사람, 구직중인 사람이 높으므로 이둘에대해서 따로 시각화하겟다

# %% [markdown]
# 범례; legend로
# bbox_to_anchor를 사용하면 상하좌우가바뀌는듯
# 아래가 위로, 위가 아래로, 왼쪽이 오른쪽으로 ,오른쪽이 왼쪽으로

# %%
full_time = mcq.loc[(mcq['EmploymentStatus'] == 'Employed full-time')]

looking_for_job= mcq.loc[(mcq['EmploymentStatus'] ==
                         'Not employed, but looking for work')]
print(full_time.shape)
looking_for_job.shape

# %%
figure , (ax1, ax2) = plt.subplots(ncols=2)

figure.set_size_inches(12,5)

sns.countplot(x='TimeSpentStudying',
             data=full_time ,
             hue = 'EmploymentStatus', 
              ax=ax1)

sns.countplot(x='TimeSpentStudying' ,
             data=looking_for_job,
             hue = 'EmploymentStatus', 
              ax= ax2)
