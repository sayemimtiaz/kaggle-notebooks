# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("../input/insurance/insurance.csv")
dataset.shape

# %%
dataset.head()

# %%
dataset.info()

# %%
#so we have 3 categorical variables are 'sex,smoker,region' which we will have to encode

dataset.describe()

# %%
dataset.corr()

# %%
dataset.cov()

# %% [markdown]
# we are analysing the dataset with each column vs****

# %%
import seaborn as sns
sns.set(style = 'whitegrid')
plt.figure(figsize = (6,6))
plt.title("Age Distribution")
sns.distplot(dataset['age'])

#get the counts as well

#print(dataset['age'].value_counts())

# %%
plt.figure(figsize = (6,6))
plt.title("sex column Distribution")

#since sex is categorical variable we have to use counter plot

sns.countplot(dataset['sex'])

#get the counts as well

print(dataset['sex'].value_counts())

# %%
plt.figure(figsize = (6,6))
plt.title("bmi column Distribution")


sns.distplot(dataset['bmi'])

#get the counts as well

print(dataset['bmi'].value_counts())

# %%
dataset['bmi'].describe()

# %%
plt.figure(figsize = (6,6))
plt.title("children column Distribution")


sns.countplot(dataset['children'])

#get the counts as well

print(dataset['children'].value_counts())

# %%
plt.figure(figsize = (6,6))
plt.title("smoker column Distribution")


sns.countplot(dataset['smoker'])

#get the counts as well

print(dataset['smoker'].value_counts())

# %%
plt.figure(figsize = (6,6))
plt.title("region column Distribution")


sns.countplot(dataset['region'])

#get the counts as well

print(dataset['region'].value_counts())

# %% [markdown]
# # **data preprocessing**

# %%
# convert the categorical values to int

#convert sex column to male=0,female=1

dataset.replace({'sex':{'male':0, 'female':1}},inplace=True)

# %%
dataset.replace({'smoker':{'yes':0, 'no':1}},inplace=True)
dataset.replace({'region':{'southwest':0, 'southeast':1,'northwest':2,'northeast':3}},inplace=True)

# %%
dataset.head()

# %%
18,0,33.770,1,1,1

# %%
dataset.info()

# %%
dataset.describe()

# %%
#remove the charges column as Target column Y and dependent columns as X

X = dataset.drop(columns = 'charges')
Y = dataset['charges']

# %%
Y.head()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y,test_size = 0.2, random_state = 3)

# %%
X_train.head()

# %%
Y_train.head()

# %%
Y_train.loc[502]

# %% [markdown]
# # train the model

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,Y_train)

# %% [markdown]
# # model evaluation

# %%
#train data prediction

prediction = model.predict(X_train)

# %%
from sklearn.metrics import r2_score

optimization = r2_score(Y_train, prediction)

# %%
optimization

# %%
#test data prediction
predict_test = model.predict(X_test)

# %%
X_test.shape

# %%
opti_test = r2_score(Y_test, predict_test)
print(opti_test)

# %%
18,0,33.770,1,1,1

# %%
test_random_data = np.asarray((18,0,33.77,1,1,1))

test = test_random_data.reshape(1,-1)

test.shape

# %%
X_train.shape

# %%
#test_value = X_train.loc [502]
#test_value_1 = np.array(test_value, dtype=np.float32)

# %%
#test_value_1.reshape(1,-1)

# %%
#arr_2d = np.reshape(test_value_1, (1, 6))

# %%
#arr_2d.shape

# %% [markdown]
# # bulding predict system

# %%
predicted_charge_for_test_value = model.predict(test)

# %%
predicted_charge_for_test_value.shape

# %%
#opti_test = r2_score(predicted_charge_for_test_value, predict_test)
#print(opti_test)

# %%
print(predicted_charge_for_test_value)
