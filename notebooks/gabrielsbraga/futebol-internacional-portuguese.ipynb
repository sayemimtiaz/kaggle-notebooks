# %% [markdown]
# Primeiro Dataset: Informacoes de jogos internacionais de futebol.
#
# Objetivo:
#
# * Trabalhar conceitos basicos de EDA (Exploratory Data Analysis)
# * Uso da biblioteca Pandas
# * Visualizacao de Dados Simples
#
# Enredo:
#
# Quais paises jogaram mais jogos internacionais?
# O que acontece com a media de gols ao longo dos anos?

# %% [markdown]
# **Primeiro passo:** Importando bibliotecas

# %%
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt

# %% [markdown]
# Leio o dataset com os resultados e olhada inicial

# %%
df = pd.read_csv("../input/results.csv") #Leio o arquivo com os resultados
df.head() #Visualizacao inicial
# Out:
#          date home_team away_team   ...       city   country neutral
# 0  1872-11-30  Scotland   England   ...    Glasgow  Scotland   False
# 1  1873-03-08   England  Scotland   ...     London   England   False
# 2  1874-03-07  Scotland   England   ...    Glasgow  Scotland   False
# 3  1875-03-06   England  Scotland   ...     London   England   False
# 4  1876-03-04  Scotland   England   ...    Glasgow  Scotland   False
#
# [5 rows x 9 columns]

# %% [markdown]
# Crio uma feature porque quero analisar a quantidade total de gols nas partidas

# %%
df["total_goals"] = df["home_score"] + df["away_score"] #Crio uma feature com o total de gols na partida
df = df[['date', 'home_team', 'away_team', 'home_score', 'away_score', 'total_goals', 'tournament', 'city', 'country', 'neutral' ]] #ajusto as colunas do meu dataset
df.head() #Resultado
# Out:
#          date home_team away_team   ...        city   country  neutral
# 0  1872-11-30  Scotland   England   ...     Glasgow  Scotland    False
# 1  1873-03-08   England  Scotland   ...      London   England    False
# 2  1874-03-07  Scotland   England   ...     Glasgow  Scotland    False
# 3  1875-03-06   England  Scotland   ...      London   England    False
# 4  1876-03-04  Scotland   England   ...     Glasgow  Scotland    False
#
# [5 rows x 10 columns]

# %% [markdown]
# **Segundo passo**: Analise da frequencia de jogos e quais paises jogaram mais jogos

# %%
df1 = df.groupby("away_team").size() + df.groupby("home_team").size() #Quero ver o quanto os paises jogaram
df1
# Out:
# Abkhazia                      21.0
# Afghanistan                  105.0
# Albania                      324.0
# Alderney                      16.0
# Algeria                      488.0
# American Samoa                42.0
# Andorra                      156.0
# Angola                       336.0
# Anguilla                      52.0
# Antigua and Barbuda          184.0
# Arameans Suryoye              10.0
# Argentina                    965.0
# Armenia                      202.0
# Artsakh                        4.0
# Aruba                        110.0
# Australia                    512.0
# Austria                      770.0
# Azerbaijan                   237.0
# Bahamas                       28.0
# Bahrain                      472.0
# Bangladesh                   200.0
# Barawa                         NaN
# Barbados                     251.0
# Belarus                      242.0
# Belgium                      760.0
# Belize                        67.0
# Benin                        244.0
# Bermuda                      139.0
# Bhutan                        77.0
# Bolivia                      449.0
#                              ...
# Turks and Caicos Islands      19.0
# Tuvalu                        29.0
# Two Sicilies                   NaN
# USA                          672.0
# Uganda                       603.0
# Ukraine                      259.0
# United Arab Emirates         505.0
# United Koreans in Japan       11.0
# Uruguay                      870.0
# Uzbekistan                   265.0
# Vanuatu                      159.0
# Vatican                        NaN
# Venezuela                    365.0
# Vietnam                      197.0
# Vietnam Republic             153.0
# Virgin Islands                44.0
# Wales                        645.0
# Wallis Islands and Futuna     22.0
# Western Armenia               11.0
# Western Australia              NaN
# Western Isles                 24.0
# Western Sahara                 5.0
# Yemen                        218.0
# Yemen DPR                     24.0
# Ynys Môn                      55.0
# Yugoslavia                   478.0
# Zambia                       697.0
# Zanzibar                     205.0
# Zimbabwe                     438.0
# Åland Islands                 46.0
# Length: 296, dtype: float64

# %%
df1 = df1.dropna() #Tiro os paises sem algum jogo ou com numero desconhecidos
df1 = df1.sort_values(ascending=False) #Ordeno os paises decrescente
df1
# Out:
# Sweden                     1008.0
# England                     992.0
# Brazil                      965.0
# Argentina                   965.0
# Germany                     941.0
# Hungary                     920.0
# Uruguay                     870.0
# Korea Republic              851.0
# Mexico                      849.0
# France                      828.0
# Poland                      803.0
# Norway                      794.0
# Italy                       793.0
# Switzerland                 789.0
# Denmark                     786.0
# Netherlands                 776.0
# Austria                     770.0
# Scotland                    769.0
# Belgium                     760.0
# Chile                       748.0
# Finland                     736.0
# Paraguay                    703.0
# Zambia                      697.0
# Romania                     686.0
# Russia                      683.0
# Spain                       682.0
# USA                         672.0
# Bulgaria                    661.0
# Trinidad and Tobago         650.0
# Wales                       645.0
#                             ...
# Bonaire                      13.0
# Panjab                       11.0
# Western Armenia              11.0
# Kiribati                     11.0
# United Koreans in Japan      11.0
# Monaco                       10.0
# Arameans Suryoye             10.0
# Kárpátalja                   10.0
# Saarland                      9.0
# Myanmar                       9.0
# South Ossetia                 9.0
# County of Nice                9.0
# Felvidék                      8.0
# Raetia                        8.0
# Micronesia FS                 7.0
# St. Pierre & Miquelon         7.0
# Darfur                        7.0
# Timor-Leste                   7.0
# Cascadia                      6.0
# Kabylia                       6.0
# Gozo                          6.0
# Crimea                        5.0
# Matabeleland                  5.0
# Western Sahara                5.0
# Artsakh                       4.0
# Chagos Islands                4.0
# Somaliland                    4.0
# Sark                          4.0
# Romani people                 3.0
# Manchukuo                     3.0
# Length: 288, dtype: float64

# %%
df1 = df1.iloc[:10] #Seleciono os 10 primeiros paises da lista
df1
# Out:
# Sweden            1008.0
# England            992.0
# Brazil             965.0
# Argentina          965.0
# Germany            941.0
# Hungary            920.0
# Uruguay            870.0
# Korea Republic     851.0
# Mexico             849.0
# France             828.0
# dtype: float64

# %%
ax = df1.plot(kind='bar',title="Top 10 Numero de Jogos Internacionais",ylim=[800,1000],color='red') 
ax.set(xlabel="Paises", ylabel="Numero de Jogos") #Plot do Grafico de barras e funcao auxiliar pra colocar os labels
# Out:
# [Text(0, 0.5, 'Numero de Jogos'), Text(0.5, 0, 'Paises')]

# %% [markdown]
# **Terceiro passo:** Media de Gols ao longo das decadas

# %%
df = df.set_index("date") #Trocando o indice
df.drop(["city","country","neutral","tournament"], axis=1)  #Retirando colunas do dataframe
# Out:
#                        home_team     ...     total_goals
# date                                 ...
# 1872-11-30              Scotland     ...               0
# 1873-03-08               England     ...               6
# 1874-03-07              Scotland     ...               3
# 1875-03-06               England     ...               4
# 1876-03-04              Scotland     ...               3
# 1876-03-25              Scotland     ...               4
# 1877-03-03               England     ...               4
# 1877-03-05                 Wales     ...               2
# 1878-03-02              Scotland     ...               9
# 1878-03-23              Scotland     ...               9
# 1879-01-18               England     ...               3
# 1879-04-05               England     ...               9
# 1879-04-07                 Wales     ...               3
# 1880-03-13              Scotland     ...               9
# 1880-03-15                 Wales     ...               5
# 1880-03-27              Scotland     ...               6
# 1881-02-26               England     ...               1
# 1881-03-12               England     ...               7
# 1881-03-14                 Wales     ...               6
# 1882-02-18      Northern Ireland     ...              13
# 1882-02-25                 Wales     ...               8
# 1882-03-11              Scotland     ...               6
# 1882-03-13                 Wales     ...               8
# 1882-03-25              Scotland     ...               5
# 1883-02-03               England     ...               5
# 1883-02-24               England     ...               7
# 1883-03-10               England     ...               5
# 1883-03-12                 Wales     ...               3
# 1883-03-17      Northern Ireland     ...               2
# 1884-01-26      Northern Ireland     ...               5
# ...                          ...     ...             ...
# 2019-03-25              Portugal     ...               2
# 2019-03-25            Luxembourg     ...               3
# 2019-03-25                Turkey     ...               4
# 2019-03-25               Andorra     ...               3
# 2019-03-25                France     ...               4
# 2019-03-26               Algeria     ...               1
# 2019-03-26            Costa Rica     ...               1
# 2019-03-26        Czech Republic     ...               4
# 2019-03-26                 Ghana     ...               4
# 2019-03-26             Gibraltar     ...               1
# 2019-03-26              Honduras     ...               0
# 2019-03-26           Ivory Coast     ...               1
# 2019-03-26                 Japan     ...               1
# 2019-03-26        Korea Republic     ...               3
# 2019-03-26               Morocco     ...               1
# 2019-03-26             Nicaragua     ...               1
# 2019-03-26               Nigeria     ...               1
# 2019-03-26              Paraguay     ...               6
# 2019-03-26                  Peru     ...               2
# 2019-03-26               Senegal     ...               3
# 2019-03-26  United Arab Emirates     ...               0
# 2019-03-26                   USA     ...               2
# 2019-03-26               Ireland     ...               1
# 2019-03-26           Switzerland     ...               6
# 2019-03-26                 Malta     ...               2
# 2019-03-26                Norway     ...               6
# 2019-03-26               Romania     ...               5
# 2019-03-26    Bosnia-Herzegovina     ...               4
# 2019-03-26                 Italy     ...               6
# 2019-03-26               Armenia     ...               2
#
# [40262 rows x 5 columns]

# %%
dec50 = df.loc["1950-01-01":"1959-12-31"] #Separo os datasets por decadas
dec60 = df.loc["1960-01-01":"1969-12-31"]
dec70 = df.loc["1970-01-01":"1979-12-31"]
dec80 = df.loc["1980-01-01":"1989-12-31"]
dec90 = df.loc["1990-01-01":"1999-12-31"]
dec00 = df.loc["2000-01-01":"2009-12-31"]
dec10 = df.loc["2010-01-01":"2019-12-31"]

# %%
media50 = dec50.total_goals.mean() #armazeno a media de gols de cada media em variaveis para imprimir depois
media60 = dec60.total_goals.mean() 
media70 = dec70.total_goals.mean() 
media80 = dec80.total_goals.mean() 
media90 = dec90.total_goals.mean()
media00 = dec00.total_goals.mean() 
media10 = dec10.total_goals.mean()
aumento = media10/media50 * 100
print("SEGUNDO PASSO: MEDIA DE GOLS AO LONGO DAS DECADAS \n50: %f \n60: %f \n70: %f \n80: %f \n90: %f \n00: %f \n10: %f\n" % (media50,media60,media70,media80,media90,media00,media10))
print("A media de gols diminuiu %f por cento desde 1950 ate hoje"% (aumento))
# Out:
# SEGUNDO PASSO: MEDIA DE GOLS AO LONGO DAS DECADAS
# 50: 3.979644
# 60: 3.469410
# 70: 2.931210
# 80: 2.485553
# 90: 2.734566
# 00: 2.792076
# 10: 2.666199
#
# A media de gols diminuiu 66.995933 por cento desde 1950 ate hoje

# %%
Medias = [media50, media60, media70, media80, media90, media00, media10] #Armazeno as variaveis criadas em um vetor
df_Medias = pd.DataFrame(Medias) #Crio um dataframe a partir do vetor
df_Medias.columns = ["Media de Gols"] #renomeio coluna
df_Medias.rename(index = {0: "Anos 50",  #renomeando linhas
                     1:"Anos 60",
                         2:"Anos 70",
                         3:"Anos 80",
                         4:"Anos 90",
                         5:"Anos 00",
                         6:"Anos 10"}, 
                                 inplace = True)
df_Medias
# Out:
#          Media de Gols
# Anos 50       3.979644
# Anos 60       3.469410
# Anos 70       2.931210
# Anos 80       2.485553
# Anos 90       2.734566
# Anos 00       2.792076
# Anos 10       2.666199

# %%
ax2 = df_Medias.plot(kind='bar',title="Media de Gols ao Longo das Decadas",color='blue') 
ax2.set(xlabel="Decadas", ylabel="Media de Gols") #Plot do Grafico de barras e funcao auxiliar pra colocar os labels
# Out:
# [Text(0, 0.5, 'Media de Gols'), Text(0.5, 0, 'Decadas')]

# %% [markdown]
# **Obrigado por visualizarem meu primeiro kernel :) Aberto a sugestoes :) **
