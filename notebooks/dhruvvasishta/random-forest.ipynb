# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('data.csv')

# %%
df.head()

# %%
df.isnull().sum()

# %%
df.columns

# %%
final_dataset=df[[ 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
       'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
       'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
       'fractal_dimension_se', 'radius_worst', 'texture_worst',
       'perimeter_worst', 'area_worst', 'smoothness_worst',
       'compactness_worst', 'concavity_worst', 'concave points_worst',
       'symmetry_worst', 'fractal_dimension_worst']]

# %%
final_dataset.describe()

# %%
final_dataset.info()

# %%
final_dataset=pd.get_dummies(final_dataset,drop_first=True)

# %%
final_dataset.head()

# %%
import seaborn as sns

# %%
final_dataset.corr()

# %%
df_corr=final_dataset.corr()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(20,20))       
sns.heatmap(final_dataset.corr(),annot=True,ax=ax)

# %%
final_dataset.columns

# %%
data_set=final_dataset.drop([ 'perimeter_mean', 'area_mean','concave points_mean', 'compactness_mean','radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
       'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
       'fractal_dimension_se', 'radius_worst', 'texture_worst',
       'perimeter_worst', 'area_worst', 'smoothness_worst',
       'compactness_worst', 'concavity_worst', 'concave points_worst',
       'symmetry_worst', 'fractal_dimension_worst'],axis=1)

# %%
data_set.corr()

# %%
sns.heatmap(data_set.corr(),annot=True)

# %%
data_set.head()
data_set.columns

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler= StandardScaler()

# %%
scaler.fit(data_set.drop('diagnosis_M',axis=1))

# %%
scaled_features=scaler.transform(data_set.drop('diagnosis_M',axis=1))

# %%
df_feat=pd.DataFrame(scaled_features,columns=data_set.columns[:-1])

# %%
from sklearn.model_selection  import train_test_split

# %%
X=df_feat
y=final_dataset[['diagnosis_M']]
train_test_split= X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel=LogisticRegression()
logmodel.fit(X_train,y_train)

# %%
predictions=logmodel.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(classification_report(y_test,predictions))
print(confusion_matrix(y_test,predictions))

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree=DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)

# %%
predictions=dtree.predict(X_test)

# %%
print(classification_report(y_test,predictions))
print(confusion_matrix(y_test,predictions))

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rforest=RandomForestClassifier()

# %%
rforest.fit(X_test,y_test)

# %%
predictions=rforest.predict(X_test)

# %%
print(classification_report(y_test,predictions))
print(confusion_matrix(y_test,predictions))
