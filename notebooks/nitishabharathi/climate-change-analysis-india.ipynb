# %% [markdown]
# GLOBAL warming has emerged as one of the most important
# environmental issues ever to confront humanity. This concern arises
# from the fact that our everyday activities may be leading to changes
# in the earth’s atmosphere that have the potential to significantly
# alter the planet’s heat and radiation balance. It could lead to a
# warmer climate in the next century and thereafter, portending a
# potpourri of possible effects – mostly adverse.
#
# ![](https://qrius.com/wp-content/uploads/2014/03/New-IPCC-report-disproves-its-own-predictions-on-global-warming.jpg)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

data = pd.read_csv('../input/daily-temperature-of-major-cities/city_temperature.csv')
data_india = data[data['Country'] == 'India']
data_india = data_india[data_india['Year'] <2020]

# %% [markdown]
# # Air Temperature - India

# %% [markdown]
# 2020 is not considered

# %%
data_india = data[data['Country'] == 'India']
data_india = data_india[data_india['Year'] <2020]

# %% [markdown]
# Converting to celsius for easy understanding

# %%
def to_celsius(F):
    return round(5/9*(F - 32),1)

data_india['AvgTemperature'] = data_india['AvgTemperature'].apply(to_celsius)

# %%
plt.figure(figsize= (15,10))
sns.pointplot(x='Year', y='AvgTemperature', data=data_india);
plt.title('Average Temperature India - Yearly Trend',fontsize=20);

# %%
plt.figure(figsize= (15,10))
sns.pointplot(x='Month', y='AvgTemperature', data=data_india);
plt.title('Average Temperature India - Monthly Trend',fontsize=20);

# %% [markdown]
# The monthly trend is pretty obvious, as we all know the diverse seasons in India

# %%
plt.figure(figsize= (15,10))
sns.pointplot(x='Year', y='AvgTemperature', data=data_india,hue='City');
plt.title('Average Temperature India - Yearly Trend',fontsize=20);

# %% [markdown]
# Throughout Chennai being the hottest city(among the 4 cities in the dataset) followed by Mumbai

# %%
plt.figure(figsize= (15,10))
sns.pointplot(x='Month', y='AvgTemperature', data=data_india,hue='City');
plt.title('Average Temperature India - Monthly Trend',fontsize=20);

# %% [markdown]
# Interesting insight here is during summer Delhi shows the maximum temperature and during winter Delhi again shows minimum temperature. Delhi shows both extremes which balances its average temperature!
