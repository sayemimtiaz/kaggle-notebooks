# %%
# import libary
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot

# %%
# dataset loding

# %%
can=pd.read_csv('../input/heart-attack-analysis-prediction-dataset/heart.csv')

# %%
can.head()

# %%
can.tail()

# %%
can.info()
