# %% [markdown]
# # ** The situation of the COVID-19 vaccine in ASEAN **
#
# Right now the CV-19 situaltion in 2021 since Jan is likely too soar much.
#
#
# Officially of the Association of Sounteast Asia nations, is an economic union
#
# comprising 10 member states with Population (FY2020) of almost 10% of world share.

# %% [markdown]
# # **Content:**
#
# * **Country** - this is the country for which the vaccination information is provided;
# * **Country ISO Code**- ISO code for the country;
# * **Date** - date for the data entry; for some of the dates we have only the daily vaccinations, for others, only the (cumulative) total;
# * **Total number of vaccinations** - this is the absolute number of total immunizations in the country;
# * **Total number of people vaccinated** - a person, depending on the immunization scheme, will receive one or more (typically 2) vaccines; at a certain moment, the number of vaccination might be larger than the number of people;
# * **Total number of people fully vaccinated** - this is the number of people that received the entire set of immunization according to the immunization scheme (typically 2); at a certain moment in time, there might be a certain number of people that received one vaccine and another number (smaller) of people that received all vaccines in the scheme;
# * **Daily vaccinations (raw)** - for a certain data entry, the number of vaccination for that date/country;
# * **Daily vaccinations** - for a certain data entry, the number of vaccination for that date/country;
# * **Total vaccinations per hundred** - ratio (in percent) between vaccination number and total population up to the date in the country;
# * **Total number of people vaccinated per hundred** - ratio (in percent) between population immunized and total population up to the date in the country;
# * **Total number of people fully vaccinated per hundred** - ratio (in percent) between population fully immunized and total population up to the date in the country;
# * **Number of vaccinations per day** - number of daily vaccination for that day and country;
# * **Daily vaccinations per million** - ratio (in ppm) between vaccination number and total population for the current date in the country;
# * **Vaccines used in the country** - total number of vaccines used in the country (up to date);
# * **Source name** - source of the information (national authority, international organization, local organization etc.);
# * **Source website** - website of the source of information;

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mlt
import pycountry 
import geopandas as gpd
import plotly.graph_objects as go
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv('/kaggle/input/covid-world-vaccination-progress/country_vaccinations.csv')
df_wdailyCV19 =pd.read_csv('/kaggle/input/covid19-global-dataset/worldometer_coronavirus_daily_data.csv')
df_pop = pd.read_csv('/kaggle/input/population-by-country-2020/population_by_country_2020.csv')
df_gdp = pd.read_csv('/kaggle/input/impact-of-covid19-pandemic-on-the-global-economy/raw_data.csv')

df['date'] = pd.to_datetime(df['date'])
df_gdp['date']  = pd.to_datetime(df_gdp['date'])
df_wdailyCV19['date'] = pd.to_datetime(df_wdailyCV19['date'])

# %%
df_pop_asean = df_pop[(df_pop['Country (or dependency)']=='Thailand')|
              (df_pop['Country (or dependency)']=='Singapore')| 
              (df_pop['Country (or dependency)']=='Laos')|
              (df_pop['Country (or dependency)']=='Myanmar')|   
              (df_pop['Country (or dependency)']=='Vietnam')|
              (df_pop['Country (or dependency)']=='Malaysia')|
              (df_pop['Country (or dependency)']=='Brunei')|  
              (df_pop['Country (or dependency)']=='Indonesia')|     
              (df_pop['Country (or dependency)']=='Philippines')|
              (df_pop['Country (or dependency)']=='Cambodia')              
              ]

# %%
fig = go.Figure(data=go.Choropleth(locations = df_pop_asean['Country (or dependency)'],
                            locationmode='country names',
                            z = df_pop_asean['Population (2020)'],
                            text = df_pop_asean['Country (or dependency)'],       
                            colorscale = 'Reds',
                            autocolorscale=False,
                            marker_line_color='darkgray',
                            marker_line_width=0.5,
                        
                          ))

fig.update_layout(
    title_text='ASEAN',
    geo=dict(
        showframe=False,
        showcoastlines=False,
        projection_type='equirectangular'
    ))
fig.show()

# %% [markdown]
# # Right now the CV-19 situaltion in 2021 since Jan is likely too soar much.

# %%
daily_tha = df_wdailyCV19[df_wdailyCV19['country'] == 'Thailand']
daily_sgp = df_wdailyCV19[df_wdailyCV19['country'] == 'Singapore']
daily_lao = df_wdailyCV19[df_wdailyCV19['country'] == 'Laos']
daily_mmr = df_wdailyCV19[df_wdailyCV19['country'] == 'Myanmar']
daily_vnm = df_wdailyCV19[df_wdailyCV19['country'] == 'Viet Nam']
daily_mys = df_wdailyCV19[df_wdailyCV19['country'] == 'Malaysia']
daily_brn = df_wdailyCV19[df_wdailyCV19['country'] == 'Brunei Darussalam']
daily_idn = df_wdailyCV19[df_wdailyCV19['country'] == 'Indonesia']
daily_phl =  df_wdailyCV19[df_wdailyCV19['country'] == 'Philippines']
daily_khm =  df_wdailyCV19[df_wdailyCV19['country'] == 'Cambodia']


fig, ax = plt.subplots( 1,1,figsize=(15,6))

tha_plot = sns.lineplot(x = daily_tha['date'], y = daily_tha['daily_new_cases'].values, color ='blue')
lao_plot = sns.lineplot(x = daily_lao['date'], y = daily_lao['daily_new_cases'].values, color = 'red')
sgp_plot = sns.lineplot(x = daily_sgp['date'], y = daily_sgp['daily_new_cases'].values, color = 'yellow')
mmr_plot = sns.lineplot(x = daily_mmr['date'], y = daily_mmr['daily_new_cases'].values, color ='brown')
vnm_plot = sns.lineplot(x = daily_vnm['date'], y = daily_vnm['daily_new_cases'].values, color='orange' )
mys_plot = sns.lineplot(x = daily_mys['date'], y = daily_mys['daily_new_cases'].values, color ='maroon')
brn_plot = sns.lineplot(x =daily_brn['date'], y =daily_brn['daily_new_cases'].values, color = 'purple')
idn_plot = sns.lineplot(x = daily_idn['date'], y = daily_idn['daily_new_cases'].values, color ='violet')
phl_plot = sns.lineplot(x = daily_phl['date'], y = daily_phl['daily_new_cases'].values, color ='pink')
khm_plot = sns.lineplot(x = daily_khm['date'], y = daily_khm['daily_new_cases'].values, color ='green')

for i in ['top', 'left', 'right','bottom']:
    ax.spines[i].set_visible(False)
   
    
fig.text(0.1, 0.9, 'Daily new cases', 
       fontsize=20, fontweight='bold', fontfamily='serif',color='black')
fig.text(0.1, 0.8, 'Thailand', 
       fontsize=14, fontweight='bold', fontfamily='serif',color='blue')
fig.text(0.2, 0.8, 'Laos', 
       fontsize=14, fontweight='bold', fontfamily='serif',color='red')
fig.text(0.3, 0.8, 'Singapore', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'yellow')
fig.text(0.4, 0.8, 'Myanmar', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'brown')#crimson
fig.text(0.5, 0.8, 'Vietnum', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'orange') #purple
fig.text(0.1, 0.7, 'Malaysia', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'maroon')
fig.text(0.2, 0.7, 'Brunei', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'purple')
fig.text(0.3, 0.7, 'Indonesia', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'violet')
fig.text(0.4, 0.7, 'Philippines', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'pink')
fig.text(0.5, 0.7, 'Cambodia', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'green')

ax.yaxis.tick_right()
ax.tick_params(length=0)
plt.xticks(rotation=45)
plt.ylabel('COUNT')

# %%
fig, ax = plt.subplots( 1,1,figsize=(15,6))

tha_plot = sns.lineplot(x = daily_tha['date'], y = daily_tha['daily_new_deaths'].values, color ='blue')
lao_plot = sns.lineplot(x = daily_lao['date'], y = daily_lao['daily_new_deaths'].values, color = 'red')
sgp_plot = sns.lineplot(x = daily_sgp['date'], y = daily_sgp['daily_new_deaths'].values, color = 'yellow')
mmr_plot = sns.lineplot(x = daily_mmr['date'], y = daily_mmr['daily_new_deaths'].values, color ='brown')
vnm_plot = sns.lineplot(x = daily_vnm['date'], y = daily_vnm['daily_new_deaths'].values, color='orange' )
mys_plot = sns.lineplot(x = daily_mys['date'], y = daily_mys['daily_new_deaths'].values, color ='maroon')
brn_plot = sns.lineplot(x =daily_brn['date'], y =daily_brn['daily_new_deaths'].values, color = 'purple')
idn_plot = sns.lineplot(x = daily_idn['date'], y = daily_idn['daily_new_deaths'].values, color ='violet')
phl_plot = sns.lineplot(x = daily_phl['date'], y = daily_phl['daily_new_deaths'].values, color ='pink')
khm_plot = sns.lineplot(x = daily_khm['date'], y = daily_khm['daily_new_deaths'].values, color ='green')

for i in ['top', 'left', 'right','bottom']:
    ax.spines[i].set_visible(False)
   
    
fig.text(0.1, 0.9, 'Daily_new_deaths', 
       fontsize=20, fontweight='bold', fontfamily='serif',color='black')
fig.text(0.1, 0.8, 'Thailand', 
       fontsize=14, fontweight='bold', fontfamily='serif',color='blue')
fig.text(0.2, 0.8, 'Laos', 
       fontsize=14, fontweight='bold', fontfamily='serif',color='red')
fig.text(0.3, 0.8, 'Singapore', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'yellow')
fig.text(0.4, 0.8, 'Myanmar', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'brown')#crimson
fig.text(0.5, 0.8, 'Vietnum', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'orange') #purple
fig.text(0.1, 0.7, 'Malaysia', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'maroon')
fig.text(0.2, 0.7, 'Brunei', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'purple')
fig.text(0.3, 0.7, 'Indonesia', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'violet')
fig.text(0.4, 0.7, 'Philippines', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'pink')
fig.text(0.5, 0.7, 'Cambodia', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'green')

ax.yaxis.tick_right()
ax.tick_params(length=0)
plt.xticks(rotation=45)
plt.ylabel('COUNT')

# %% [markdown]
# # FY2020 Population of each countries in ASEAN

# %%
fig, ax = plt.subplots(1,1,figsize=(15,6))
ax = sns.barplot(x = 'Population (2020)', y = 'Country (or dependency)', data=df_pop_asean)

# %% [markdown]
# # GDP per Capita of each states of ASEAN.

# %%
gdp_tha = df_gdp[df_gdp['location'] == 'Thailand']
gdp_sgp = df_gdp[df_gdp['location'] == 'Singapore']
gdp_lao = df_gdp[df_gdp['location'] == 'Laos']
gdp_mmr = df_gdp[df_gdp['location'] == 'Myanmar']
gdp_vnm = df_gdp[df_gdp['location'] == 'Vietnam']
gdp_mys = df_gdp[df_gdp['location'] == 'Malaysia']
gdp_brn = df_gdp[df_gdp['location'] == 'Brunei']
gdp_idn = df_gdp[df_gdp['location'] == 'Indonesia']
gdp_phl =  df_gdp[df_gdp['location'] == 'Philippines']
gdp_khm =  df_gdp[df_gdp['location'] == 'Cambodia']

asean_gdp = pd.DataFrame([gdp_tha['gdp_per_capita'].unique(), 
                      gdp_sgp['gdp_per_capita'].unique(),
                      gdp_lao['gdp_per_capita'].unique(),
                      gdp_mmr['gdp_per_capita'].unique(),
                      gdp_vnm['gdp_per_capita'].unique(),
                      gdp_mys['gdp_per_capita'].unique(),
                      gdp_brn['gdp_per_capita'].unique(),
                      gdp_idn['gdp_per_capita'].unique(),
                      gdp_phl['gdp_per_capita'].unique(),
                      gdp_khm['gdp_per_capita'].unique()             
                    
                    ],
                      columns = ['gdp_per_capita'],
                      index = ['Thailand', 'Singapore', 'Laos', 'Myanmar', 'Vietnam', 'Malaysia', 'Brunei', 'Indonesia', 'Philippines', 'Cambodia']
                      )

asean_gdp.plot.bar(figsize = (15,6), color = 'Green', title='GDP per Capita baseon 19th October 2020')

# %% [markdown]
# # HDI: Human Development Index

# %%
gdp_tha = df_gdp[df_gdp['location'] == 'Thailand']
gdp_sgp = df_gdp[df_gdp['location'] == 'Singapore']
gdp_lao = df_gdp[df_gdp['location'] == 'Laos']
gdp_mmr = df_gdp[df_gdp['location'] == 'Myanmar']
gdp_vnm = df_gdp[df_gdp['location'] == 'Vietnam']
gdp_mys = df_gdp[df_gdp['location'] == 'Malaysia']
gdp_brn = df_gdp[df_gdp['location'] == 'Brunei']
gdp_idn = df_gdp[df_gdp['location'] == 'Indonesia']
gdp_phl =  df_gdp[df_gdp['location'] == 'Philippines']
gdp_khm =  df_gdp[df_gdp['location'] == 'Cambodia']

asean_hdi = pd.DataFrame([gdp_tha['human_development_index'].unique(), 
                      gdp_sgp['human_development_index'].unique(),
                      gdp_lao['human_development_index'].unique(),
                      gdp_mmr['human_development_index'].unique(),
                      gdp_vnm['human_development_index'].unique(),
                      gdp_mys['human_development_index'].unique(),
                      gdp_brn['human_development_index'].unique(),
                      gdp_idn['human_development_index'].unique(),
                      gdp_phl['human_development_index'].unique(),
                      gdp_khm['human_development_index'].unique()             
                    
                    ],
                      columns = ['HDI'],
                      index = ['Thailand', 'Singapore', 'Laos', 'Myanmar', 'Vietnam', 'Malaysia', 'Brunei', 'Indonesia', 'Philippines', 'Cambodia']
                      )

asean_hdi.plot.bar(figsize = (15,6), color = 'maroon', title='HDI baseon 19th October 2020')

# %% [markdown]
# **Human Development Index categories base on 2018 data, published in 2019:**
#
# *   0.800 - 1.000 (very high)
# *   0.700 - 0.799 (high)
# *   0.550 - 0.699 (medium)
# *   0.350 - 0.549 (low)
# * less than 0.349 (Data unavailable)

# %% [markdown]
# #  Vaccine type of each Country in ASEAN

# %%
df_tha = df[df['country'] == 'Thailand']
df_sgp = df[df['country'] == 'Singapore']
df_lao = df[df['country'] == 'Laos']
df_mmr = df[df['country'] == 'Myanmar']
df_vnm = df[df['country'] == 'Vietnam']
df_mys = df[df['country'] == 'Malaysia']
df_brn = df[df['country'] == 'Brunei']
df_idn = df[df['country'] == 'Indonesia']
df_phl =  df[df['country'] == 'Philippines']
df_khm =  df[df['country'] == 'Cambodia']

asean = pd.DataFrame([df_tha['vaccines'].unique(), 
                      df_sgp['vaccines'].unique(),
                      df_lao['vaccines'].unique(),
                      df_mmr['vaccines'].unique(),
                      df_vnm['vaccines'].unique(),
                      df_mys['vaccines'].unique(),
                      df_brn['vaccines'].unique(),
                      df_idn['vaccines'].unique(),
                      df_phl['vaccines'].unique(),
                      df_khm['vaccines'].unique()             
                    
                    ],
                      columns = ['Vaccine'],
                      index = ['Thailand', 'Singapore', 'Laos', 'Myanmar', 'Vietnam', 'Malaysia', 'Brunei', 'Indonesia', 'Philippines', 'Cambodia']
                      )
#read full text
pd.set_option('display.max_colwidth',-1)
asean

# %% [markdown]
# # **Total Vaccinations Ratio**
#
#  - ratio (in percent) between vaccination number and total population up to the date in the country

# %%
fig, ax = plt.subplots( 1,1,figsize=(15,6))

tha_plot = sns.lineplot(x = df_tha['date'], y = df_tha['total_vaccinations_per_hundred'], color ='blue')
lao_plot = sns.lineplot(x = df_lao['date'], y = df_lao['total_vaccinations_per_hundred'], color = 'red')
sgp_plot = sns.lineplot(x = df_sgp['date'], y = df_sgp['total_vaccinations_per_hundred'], color = 'yellow')
mmr_plot = sns.lineplot(x = df_mmr['date'], y = df_mmr['total_vaccinations_per_hundred'], color ='brown')
vnm_plot = sns.lineplot(x = df_vnm['date'], y = df_vnm['total_vaccinations_per_hundred'], color='orange' )
mys_plot = sns.lineplot(x = df_mys['date'], y = df_mys['total_vaccinations_per_hundred'], color ='maroon')
brn_plot = sns.lineplot(x = df_brn['date'], y = df_brn['total_vaccinations_per_hundred'], color = 'purple')
idn_plot = sns.lineplot(x = df_idn['date'], y = df_idn['total_vaccinations_per_hundred'], color ='violet')
phl_plot = sns.lineplot(x = df_phl['date'], y = df_phl['total_vaccinations_per_hundred'], color ='pink')
khm_plot = sns.lineplot(x = df_khm['date'], y = df_khm['total_vaccinations_per_hundred'], color ='green')

for i in ['top', 'left', 'right','bottom']:
    ax.spines[i].set_visible(False)
   
    
fig.text(0.1, 0.9, 'Total vaccinations per hundred', 
       fontsize=20, fontweight='bold', fontfamily='serif',color='black')
fig.text(0.1, 0.8, 'Thailand', 
       fontsize=14, fontweight='bold', fontfamily='serif',color='blue')
fig.text(0.2, 0.8, 'Laos', 
       fontsize=14, fontweight='bold', fontfamily='serif',color='red')
fig.text(0.3, 0.8, 'Singapore', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'yellow')
fig.text(0.4, 0.8, 'Myanmar', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'brown')#crimson
fig.text(0.5, 0.8, 'Vietnum', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'orange') #purple
fig.text(0.1, 0.7, 'Malaysia', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'maroon')
fig.text(0.2, 0.7, 'Brunei', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'purple')
fig.text(0.3, 0.7, 'Indonesia', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'violet')
fig.text(0.4, 0.7, 'Philippines', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'pink')
fig.text(0.5, 0.7, 'Cambodia', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'green')

ax.yaxis.tick_right()
ax.tick_params(length=0)
plt.xticks(rotation=45)
plt.xlabel('')
plt.ylabel('%Percentage')

# %% [markdown]
# ** when I consider from GDP per capita of each countries. I will seperate Singapore. I review lineplot, again

# %%
fig, ax = plt.subplots( 1,1,figsize=(15,6))

tha_plot = sns.lineplot(x = df_tha['date'], y = df_tha['total_vaccinations_per_hundred'], color ='blue')
lao_plot = sns.lineplot(x = df_lao['date'], y = df_lao['total_vaccinations_per_hundred'], color = 'red')
#sgp_plot = sns.lineplot(x = df_sgp['date'], y = df_sgp['total_vaccinations_per_hundred'], color = 'yellow')
mmr_plot = sns.lineplot(x = df_mmr['date'], y = df_mmr['total_vaccinations_per_hundred'], color ='brown')
vnm_plot = sns.lineplot(x = df_vnm['date'], y = df_vnm['total_vaccinations_per_hundred'], color='orange' )
mys_plot = sns.lineplot(x = df_mys['date'], y = df_mys['total_vaccinations_per_hundred'], color ='maroon')
#brn_plot = sns.lineplot(x = df_brn['date'], y = df_brn['total_vaccinations_per_hundred'], color = 'purple')
idn_plot = sns.lineplot(x = df_idn['date'], y = df_idn['total_vaccinations_per_hundred'], color ='violet')
phl_plot = sns.lineplot(x = df_phl['date'], y = df_phl['total_vaccinations_per_hundred'], color ='pink')
khm_plot = sns.lineplot(x = df_khm['date'], y = df_khm['total_vaccinations_per_hundred'], color ='green')

for i in ['top', 'left', 'right','bottom']:
    ax.spines[i].set_visible(False)
   
  #Total vaccinations per hundred
fig.text(0.1, 0.9, 'Total vaccinations per hundred ', 
       fontsize=20, fontweight='bold', fontfamily='serif',color='black')
fig.text(0.1, 0.8, 'Thailand', 
       fontsize=14, fontweight='bold', fontfamily='serif',color='blue')
fig.text(0.2, 0.8, 'Laos', 
       fontsize=14, fontweight='bold', fontfamily='serif',color='red')
#fig.text(0.3, 0.8, 'Singapore', 
#       fontsize=14, fontweight='bold', fontfamily='serif', color = 'yellow')
fig.text(0.3, 0.8, 'Myanmar', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'brown')#crimson
fig.text(0.4, 0.8, 'Vietnum', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'orange') #purple
fig.text(0.1, 0.7, 'Malaysia', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'maroon')
#fig.text(0.2, 0.7, 'Brunei', 
#       fontsize=14, fontweight='bold', fontfamily='serif', color = 'purple')
fig.text(0.2, 0.7, 'Indonesia', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'violet')
fig.text(0.3, 0.7, 'Philippines', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'pink')
fig.text(0.4, 0.7, 'Cambodia', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'green')

ax.yaxis.tick_right()
ax.tick_params(length=0)
plt.xticks(rotation=45)
plt.xlabel('')
plt.ylabel('%Percantage')

# %% [markdown]
# # **Total number of people vaccinated per hundred**
#
# - ratio (in percent) between population immunized and total population up to the date in the country;

# %%
#Total number of people vaccinated per hundred 

fig, ax = plt.subplots( 1,1,figsize=(15,6))

tha_plot = sns.lineplot(x = df_tha['date'], y = df_tha['people_vaccinated_per_hundred'], color ='blue')
lao_plot = sns.lineplot(x = df_lao['date'], y = df_lao['people_vaccinated_per_hundred'], color = 'red')
#sgp_plot = sns.lineplot(x = df_sgp['date'], y = df_sgp['people_vaccinated_per_hundred'], color = 'yellow')
mmr_plot = sns.lineplot(x = df_mmr['date'], y = df_mmr['people_vaccinated_per_hundred'], color ='brown')
vnm_plot = sns.lineplot(x = df_vnm['date'], y = df_vnm['people_vaccinated_per_hundred'], color='orange' )
mys_plot = sns.lineplot(x = df_mys['date'], y = df_mys['people_vaccinated_per_hundred'], color ='maroon')
#brn_plot = sns.lineplot(x = df_brn['date'], y = df_brn['people_vaccinated_per_hundred'], color = 'purple')
idn_plot = sns.lineplot(x = df_idn['date'], y = df_idn['people_vaccinated_per_hundred'], color ='violet')
phl_plot = sns.lineplot(x = df_phl['date'], y = df_phl['people_vaccinated_per_hundred'], color ='pink')
khm_plot = sns.lineplot(x = df_khm['date'], y = df_khm['people_vaccinated_per_hundred'], color ='green')

for i in ['top', 'left', 'right','bottom']:
    ax.spines[i].set_visible(False)
   
  #Total vaccinations per hundred
fig.text(0.1, 0.9, '% people vaccinated ', 
       fontsize=20, fontweight='bold', fontfamily='serif',color='black')
fig.text(0.1, 0.8, 'Thailand', 
       fontsize=14, fontweight='bold', fontfamily='serif',color='blue')
fig.text(0.2, 0.8, 'Laos', 
       fontsize=14, fontweight='bold', fontfamily='serif',color='red')
#fig.text(0.3, 0.8, 'Singapore', 
#       fontsize=14, fontweight='bold', fontfamily='serif', color = 'yellow')
fig.text(0.3, 0.8, 'Myanmar', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'brown')#crimson
fig.text(0.4, 0.8, 'Vietnum', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'orange') #purple
fig.text(0.1, 0.7, 'Malaysia', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'maroon')
#fig.text(0.2, 0.7, 'Brunei', 
#       fontsize=14, fontweight='bold', fontfamily='serif', color = 'purple')
fig.text(0.2, 0.7, 'Indonesia', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'violet')
fig.text(0.3, 0.7, 'Philippines', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'pink')
fig.text(0.4, 0.7, 'Cambodia', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'green')

ax.yaxis.tick_right()
ax.tick_params(length=0)
plt.xticks(rotation=45)
plt.xlabel('')
plt.ylabel('%Percantage')

# %% [markdown]
# # **Total number of people fully vaccinated per hundred**
#
# - ratio (in percent) between population fully immunized and total population up to the date in the country;

# %%
#Total number of people fully vaccinated per hundred

fig, ax = plt.subplots( 1,1,figsize=(15,6))

tha_plot = sns.lineplot(x = df_tha['date'], y = df_tha['people_fully_vaccinated_per_hundred'], color ='blue')
lao_plot = sns.lineplot(x = df_lao['date'], y = df_lao['people_fully_vaccinated_per_hundred'], color = 'red')
#sgp_plot = sns.lineplot(x = df_sgp['date'], y = df_sgp['people_fully_vaccinated_per_hundred'], color = 'yellow')
mmr_plot = sns.lineplot(x = df_mmr['date'], y = df_mmr['people_fully_vaccinated_per_hundred'], color ='brown')
vnm_plot = sns.lineplot(x = df_vnm['date'], y = df_vnm['people_fully_vaccinated_per_hundred'], color='orange' )
mys_plot = sns.lineplot(x = df_mys['date'], y = df_mys['people_fully_vaccinated_per_hundred'], color ='maroon')
#brn_plot = sns.lineplot(x = df_brn['date'], y = df_brn['people_fully_vaccinated_per_hundred'], color = 'purple')
idn_plot = sns.lineplot(x = df_idn['date'], y = df_idn['people_fully_vaccinated_per_hundred'], color ='violet')
phl_plot = sns.lineplot(x = df_phl['date'], y = df_phl['people_fully_vaccinated_per_hundred'], color ='pink')
khm_plot = sns.lineplot(x = df_khm['date'], y = df_khm['people_fully_vaccinated_per_hundred'], color ='green')

for i in ['top', 'left', 'right','bottom']:
    ax.spines[i].set_visible(False)
   
  #Total vaccinations per hundred
fig.text(0.1, 0.9, '% people fully vaccinated ', 
       fontsize=20, fontweight='bold', fontfamily='serif',color='black')
fig.text(0.1, 0.8, 'Thailand', 
       fontsize=14, fontweight='bold', fontfamily='serif',color='blue')
fig.text(0.2, 0.8, 'Laos', 
       fontsize=14, fontweight='bold', fontfamily='serif',color='red')
#fig.text(0.3, 0.8, 'Singapore', 
#       fontsize=14, fontweight='bold', fontfamily='serif', color = 'yellow')
fig.text(0.3, 0.8, 'Myanmar', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'brown')#crimson
fig.text(0.4, 0.8, 'Vietnum', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'orange') #purple
fig.text(0.1, 0.7, 'Malaysia', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'maroon')
#fig.text(0.2, 0.7, 'Brunei', 
#       fontsize=14, fontweight='bold', fontfamily='serif', color = 'purple')
fig.text(0.2, 0.7, 'Indonesia', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'violet')
fig.text(0.3, 0.7, 'Philippines', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'pink')
fig.text(0.4, 0.7, 'Cambodia', 
       fontsize=14, fontweight='bold', fontfamily='serif', color = 'green')

ax.yaxis.tick_right()
ax.tick_params(length=0)
plt.xticks(rotation=45)
plt.xlabel('')
plt.ylabel('%Percantage')

# %% [markdown]
# I know the current situation with the COVID-19 vaccine in scarce in many countries.
#
# Hoarding of CV-19 vaccine in many countriees has prevented many countries from recovery from the outbreake.
