# %% [markdown]
# # Introduction
# Tableau is a very smart software, which is used for data visualization. Information of an entire dataset can be represented for visualization with the help of the amazing features in Tableau. In this work, I have shared some projects as well as the related datasets, which I have done on Tableau Public.

# %% [markdown]
# # Example 1: Association of Tennis Professionals:
# In this Tableau project, I have done some graphical representations on the "ATP Men's Tour" dataset. It is an amazing dataset and many interesting works can be done using this dataset. Please visit the link to see the Tableau project: https://public.tableau.com/profile/maliha.momtaz#!/vizhome/AssociationofTennisProfessionals_16148108599690/Overallview

# %%
from IPython.display import Image
#!ls ../input/images
Image("../input/images/Tennis.JPG")

# %% [markdown]
# # Example 2: CIVID-19 USA:
# In this project, I have shown detailed information about USA COVID-19 data for the year 2020. I have chosen the "COVID-19 in USA" dataset for this project. Please visit the link to see the Tableau project: https://public.tableau.com/profile/maliha.momtaz#!/vizhome/COVID-19USA_16142099828340/StateDetails

# %%
from IPython.display import Image
#!ls ../input/images
Image("../input/images/COVID-19 USA.JPG")

# %% [markdown]
# # Example 3: World GDP Record:
# This Tableau project shows the GDPs of many countries in different years. The "World_GDP_Records" dataset has been chosen for this project. Please visit the link to see the Tableau project: https://public.tableau.com/profile/maliha.momtaz#!/vizhome/WorldGDPrecord/WorldGDPrecord

# %%
from IPython.display import Image
#!ls ../input/images
Image("../input/images/World GDP.JPG")

# %% [markdown]
# # Example 4: IMDB Movie Details:
# In this Tableau project, I have shown some detailed information about IMDB movies. I have used "IMDB Movies Dataset" for this project. Please visit the link to see the project itself: https://public.tableau.com/profile/maliha.momtaz#!/vizhome/IMDBmoviedetails/IMDBmoviesdetails

# %%
from IPython.display import Image
#!ls ../input/images
Image("../input/images/IMDB.JPG")

# %% [markdown]
# # Example 5: USA Cars' Details:
# In this project, I have represented some detailed information about cars in the USA with the help of Tableau. "US Cars Dataset" has been used for this project. Please visit the link to see the project: https://public.tableau.com/profile/maliha.momtaz#!/vizhome/USA_cars_details/USA_cars_details

# %%
from IPython.display import Image
#!ls ../input/images
Image("../input/images/USA cars details.JPG")

# %% [markdown]
# # Example 6: Walmart Store Sales:
# In this project, I have shown sales information for different Walmart stores. "Retail Analysis with Walmart Data" dataset has been used for this project. Please visit the link to see the project: https://public.tableau.com/profile/maliha.momtaz#!/vizhome/WalmartStoreSales/WalmartStoreSales

# %%
from IPython.display import Image
#!ls ../input/images
Image("../input/images/Walmart store sales.JPG")

# %% [markdown]
# # Example 7: Good Read Books:
# In this project, I have represented some details (title, author, language, publisher, publication date, average rating, number of pages, rating count and text reviews count) about some books graphically with the help of Tableau. "Goodreads-books" dataset has been used for this project. Please visit the link to see the project: https://public.tableau.com/profile/maliha.momtaz#!/vizhome/GoodReadBooks_16147792481990/GoodReadBooks

# %%
from IPython.display import Image
#!ls ../input/images
Image("../input/images/Good read books.JPG")

# %% [markdown]
# # Example 8: Disneyland Ratings:
# In this Tableau project, I have represented the ratings for some Disneyland parks. "Disneyland Reviews" dataset has been used for this project. Here is the link for this project: https://public.tableau.com/profile/maliha.momtaz#!/vizhome/DisneylandRatings/DisneylandReviewsandRatings

# %%
from IPython.display import Image
#!ls ../input/images
Image("../input/images/Disneyland Reviews.JPG")

# %% [markdown]
# # Example 9: Video Games Sales:
# In this project, I have shown some general details and sales details of some video games. I have chosen the "Video Game Sales" dataset for this project. Here is the link for the actual project: https://public.tableau.com/profile/maliha.momtaz#!/vizhome/VideoGamesSales_16149045453200/VideoGameSales

# %%
from IPython.display import Image
#!ls ../input/images
Image("../input/images/video games sales.JPG")

# %% [markdown]
# # Example 10: Disney Movies:
# In this Tableau project, I have done some graphical representations in details about Disney movies with the help of the amazing features of Tableau. "Disney Movies and Films Dataset" has been chosen for this project. Please visit the link to see the actual project: https://public.tableau.com/profile/maliha.momtaz#!/vizhome/DisneyMovies_16147213546350/DisneyMovies

# %%
from IPython.display import Image
#!ls ../input/images
Image("../input/images/Disney movies.JPG")

# %% [markdown]
# # If you like this kernel greatly appreciate to UPVOTE .Thank you!!!
