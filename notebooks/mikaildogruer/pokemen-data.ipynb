# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
data = pd.read_csv("/kaggle/input/pokemon-challenge/pokemon.csv")
data.head()

# %%
data.info()

# %%
#iki tane feagure arasında korelasyon 1 ise bunlar birbiriyle doğru orantılıdır
data.corr()

# %%
#correlation map #

f,ax = plt.subplots(figsize=(18, 18)) # 
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %% [markdown]
# # data fream da olan heatmap corr() içine alıyor
# # annot=True sayıların gözükmesini sağlıyor
# # linewidths=.5 grafiğin arasında ki kalınlık
# #  fmt= '.1f 0 dan sonra yazdıracağı değeri

# %%
data.head(10)

# %%
data.columns

# %%
#Kind= türü
# Line bir tür ve : ise türünü belli ediyor

data.Speed.plot(kind = 'line', color = 'g',label = 'Speed',linewidth=1,alpha =0.5,grid = True,linestyle = ':') 
data.Defense.plot(color = 'r',label = 'Defense',linewidth=1, alpha = 0.5,grid = True,linestyle = '-.')
plt.legend(loc='upper right')     # legend = puts label into plot
plt.xlabel('pokemonlar')              #  pokemonlar
plt.ylabel('pokemon özellik')              # pokemonların gücü
plt.title('Line Plot')            # title = title of plot
plt.show()

# %%
#Scatter plot
# x = attack, y = defense

data.plot(kind='scatter', x='Attack', y='Defense',alpha = 0.5,color = 'red') # rastgele x ve y belirlenmedi datanın içindeki x ve y labelleri Birebir aynı olmalıdır
plt.xlabel('Attack')             
plt.ylabel('Defence')
plt.title('Attack Defense Scatter Plot') 
plt.show()

# %%
# Histogram
# bins = number of bar in figure
data.Speed.plot(kind = 'hist',bins = 50,figsize = (12,12)) # pokemonların hız değerleri bins = kaç tane bar olacağı 
plt.xlabel("Pokemonların sayısı")
plt.ylabel("Hızına sahip pokemonlar")
plt.title("Pokemon hız ölçütü")
plt.show()

# %%
data.Speed.plot(kind = 'hist',bins = 50)
plt.clf() # eğer bunu çalıştırırsak yukarıda oluşturulan grafiği siler

# %% [markdown]
# # Pandas series and data_frame creating

# %%
series = data['Defense']        # data['Defense'] = series 
print(type(series))
data_frame = data[['Defense']]  # data[['Defense']] = data frame  
print(type(data_frame))

# %% [markdown]
# # filtreleme ve mantık

# %%
x = data["Defense"] >200  # defansı 200 den büyük olanları x değişkenine at
data[x]

# %%
data[np.logical_and(data['Defense']>200, data['Attack']>100 )] # logical_and kullanınca iki değerde doğru olanları gösterir
