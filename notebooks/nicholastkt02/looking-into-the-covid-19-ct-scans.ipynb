# %% [markdown]
# # Hi guys, so what I am attempting to do here is to try and apply a ML model, onto the dataset COVID-19 CT scans. I am still trying to work my way around the data and still unsure what model I should be using (AlexNet/VGG potentially), so feel free to drop any recommendations and advice in the comments, it would mean alot! Thank you!

# %%
import pandas as pd
import numpy as np
from glob import glob

from nilearn import image, plotting
import nibabel as nib

# %%
import warnings
warnings.filterwarnings("ignore")
from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

# %%
metadata_df_path = "../input/covid19-ct-scans/metadata.csv"
metadata_df = pd.read_csv(metadata_df_path)
metadata_df.head()

# %%
len(metadata_df.ct_scan.unique())

# %% [markdown]
# From the output below, we can know that the metadata is simply just a dataframe of the name of the paths to the images, i.e. Nii files.

# %%
metadata_df.ct_scan[0]
ct_scan_ex_img = metadata_df.ct_scan[0]

# %%
ct_scan_example_img = image.smooth_img(ct_scan_ex_img, fwhm = 3)

# %%
print("ct_scans directory example image")
plotting.plot_img(ct_scan_example_img)

# %%
infect_mask = metadata_df.infection_mask[0]
infect_mask

# %%
infect_mask = image.smooth_img(infect_mask, fwhm = 3)
plotting.plot_img(infect_mask)

# %%
lung_infec_mask = metadata_df.lung_and_infection_mask[0]
lung_infec_mask

# %%
lung_infec_mask_img = image.smooth_img(lung_infec_mask, fwhm = 3)
plotting.plot_img(lung_infec_mask_img)

# %%
lung_mask = metadata_df.lung_mask[0]
lung_mask
lung_mask_img = image.smooth_img(lung_mask, fwhm = 3)
plotting.plot_img(lung_mask_img)

# %% [markdown]
# From the current looks, the most reliable image dataset to work on is arguably the ct_scan image folder. Now I'll try to access only the third scan, which is the rightmost scan, since I wish to work only on that kind of scan, which is an Axial scan-type

# %%
test_path = metadata_df.ct_scan[10]
test_path_img = nib.load(test_path)
test_array2 = test_path_img.get_data()
test_array = np.array(test_path_img)
test_array
plotting.plot_img(test_path_img)

# %% [markdown]
# From the above output, it seems that even within the ct_scan folder, images are inconsistent, the ct-scan above looks like it is flipped upside down
# The color of the ct scans aare inconsistent as well, although we can turn them into grayscale later.

# %%
test_array2.shape

# %% [markdown]
# Here, I took a step back and look at the dataset again, and found that the data is pretty small, and the issue with it being non-labelled is quite hard to work with. I could download the data and work in my own environment but the idea of having to label them manually is very offputting and I'm not a radiologist myself, I just have some experience with thoracic CT scans, so my labels may be highly prone to error. I'll stop here and hopefully be able to come up with an alternate solution soon.
