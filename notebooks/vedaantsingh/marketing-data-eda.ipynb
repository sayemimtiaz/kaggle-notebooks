# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ## **Importing the Libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ## **Data Wrangling**

# %%
data_set = pd.read_csv("/kaggle/input/marketing-data/marketing_data.csv")
data_set.head(5)

# %%
data_set.shape

# %%
data_set.describe(include = 'all')

# %%
data_set.info()

# %%
data_set.isnull().sum()

# %% [markdown]
# 'Income' columnn has 24 Null values

# %% [markdown]
# ### Removing the Null values and Filling them with the Mean values instead

# %%
data_set[' Income '] = data_set[' Income '].str.replace('$', '')
data_set[' Income '] = data_set[' Income '].str.replace(',', '')
data_set.head(5)

# %%
data_set[' Income '] = data_set[' Income '].astype(float)
data_set[' Income '].fillna((data_set[' Income '].mean()), inplace = True)

# %%
data_set.head(5)

# %%
data_set.isnull().sum()

# %% [markdown]
# ## **Exploratory Data Analysis**

# %%
plt.figure(figsize = (12, 15))
sns.countplot(y = data_set['Year_Birth'], data = data_set)
plt.title("Birth Year", fontdict = {'fontsize': 15})
plt.show()

# %%
fig = px.pie(data_frame = data_set, names='Marital_Status', title = 'Marital Status', hole = 0.2)
fig.show()

# %%
plt.figure(figsize = (12, 8))
sns.countplot(x = data_set['Education'], data = data_set)
plt.title("Education", fontdict = {'fontsize': 15})
plt.show()

# %%
plt.figure(figsize = (12, 8))
sns.boxenplot(y = data_set[' Income '], data = data_set)
plt.show()

# %%
fig = px.pie(data_frame = data_set, names = 'Country', title = 'Country', hole = 0.2)
fig.show()

# %%
plt.figure(figsize = (12, 8))
sns.countplot(x = data_set['NumWebVisitsMonth'], data = data_set)
plt.title("Visits per month", fontdict = {'fontsize': 15})
plt.show()

# %%
plt.figure(figsize = (12, 8))
sns.countplot(x = data_set['NumCatalogPurchases'], data = data_set)
plt.title("Number of Catalog Purchases", fontdict = {'fontsize': 15})
plt.show()

# %%
plt.figure(figsize = (12, 8))
sns.countplot(x = data_set['NumDealsPurchases'], data = data_set)
plt.title("Number of Deals", fontdict = {'fontsize': 15})
plt.show()

# %%
plt.figure(figsize = (12, 8))
sns.countplot(x = data_set['NumStorePurchases'], data = data_set)
plt.title("Store Purchases", fontdict = {'fontsize': 15})
plt.show()

# %%
plt.figure(figsize = (12, 8))
sns.countplot(x = data_set['NumWebPurchases'], data = data_set)
plt.title("Web Purchases", fontdict = {'fontsize': 15})
plt.show()

# %%
plt.figure(figsize = (12, 8))
data_set.sort_values('Dt_Customer', inplace = True)
data_set['Dt_Customer'] = data_set['Dt_Customer'][:20, ]
sns.countplot(y = data_set['Dt_Customer'], data = data_set)
plt.title("Date", fontdict = {'fontsize': 15})
plt.show()

# %%
fig, (axes_1,axes_2) = plt.subplots(1,2,figsize=(20,10))

labels = data_set['Kidhome'].unique()
values = data_set['Kidhome'].value_counts()
axes_1.pie(values, labels = labels, autopct = '%1.1f%%') #plot first pie


labels = data_set['Teenhome'].unique()
values = data_set['Teenhome'].value_counts()
axes_2.pie(values, labels = labels, autopct = '%1.1f%%') #plot second pie

axes_1.set(aspect="equal", title='With kids')
axes_2.set(aspect="equal", title='With teens')
plt.show()

# %%
plt.figure(figsize = (12, 8))
corr = data_set.corr()
sns.heatmap(corr, linecolor = 'white', linewidths = 1, cmap = 'coolwarm')
plt.show()

# %%
fig = px.pie(data_frame = data_set, names = 'AcceptedCmp1', title = 'Campaign 1', hole = 0.2)
fig1 = px.pie(data_frame = data_set, names = 'AcceptedCmp2', title = 'Campaign 2', hole = 0.2)
fig2 = px.pie(data_frame = data_set, names = 'AcceptedCmp3', title = 'Campaign 3', hole = 0.2)
fig3 = px.pie(data_frame = data_set, names = 'AcceptedCmp4', title = 'Campaign 4', hole = 0.2)
fig4 = px.pie(data_frame = data_set, names = 'AcceptedCmp5', title = 'Campaign 5', hole = 0.2)
fig.show()
fig1.show()
fig2.show()
fig3.show()
fig4.show()

# %%
import pandas_profiling
profile = pandas_profiling.ProfileReport(data_set)

# %%
profile

# %%
data_set['Satisfaction'] = ''
for i in range(0, len(data_set)):
    
    if data_set['Complain'].all() > 0:
        data_set['Satisfaction'][i] = 'Not Satisfied'
    else:
        data_set['Satisfaction'][i] = 'Satisfied'

# %%
data_set.head(5)

# %%
data_set['Satisfaction'].value_counts()

# %% [markdown]
# No Complains

# %% [markdown]
# That is all for today 😊
#
# Feel free to explore the dataset further.
