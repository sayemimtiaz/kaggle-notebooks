# %% [markdown]
# # Abgabe-Template
# Dies ist ein Template für eure Abgabe am Ende des Kurses. Ihr könnt es verwenden oder verändern wie Ihr wollt, oder euer eigenes erstellen. Wichtig ist am Ende eine stringente und sinnvolle Struktur im Notebook zu haben.
#
# Euer Datensatz enthält Geographische Daten. Diese könenn oft für beeindruckende Darstellungen verwendet werden. Das kann aber knifflig sein. Wenn Ihr es wagen wollt, findet ihr [hier](https://matplotlib.org/basemap/users/examples.html) ein paar Tipps.

# %% [markdown]
# ## Eure Aufgabe:
# Die US Behörde für Verkehrssicherheit plagt sich mit der Anzahl von Verkehrsunfällen, die jährlich auftreten. Bis autonomes Fahren eine breite Masse an Verkehrsteilnehmern erreicht wird es ebenfalls noch Jahre dauern. Die Behörde möchte dennoch die Bemühungen verstärken Unfälle zu verhindern. Aber wo anfangen?
#
# Die Behörde hat euch damit beauftragt ihre Aufzeichnungen über Verkehrsunfälle zu untersuchen und herauszufinden welche Unfälle besonders häufig vorkommen und was diese gemeinsam haben. Am Ende möchte das Unternehmen einen Aspekt des Straßenverkehrs mit einem neuen Gesetz verbessern. Es liegt an euch herauszufinden, was dieser Aspekt ist.
#
# Tipp: Weitere Infos zu euren Daten findet Ihr hier: https://www.kaggle.com/sobhanmoosavi/us-accidents
#
# Euer Datensatz hat viele Spalten. Ihr solltet schauen, dass Ihr alle unwichtigen Daten entfernt bevor ihr große Analysen fahrt.

# %% [markdown]
# ## Euer Team:
# Gebt Hier bitte eure Namen ein und shared das Dokument mit mir. Macht euer eigenes Dokument bitte nicht öffetnlich!
# - Name1
# - Name2
# - ...

# %% [markdown]
# # 1. Fragen stellen
# Welche Fragen habe ich? Was möchte ich mithilfe der Daten herausfinden?

# %% [markdown]
# Q1: ...
#
# Q2: ...
#
# ...

# %% [markdown]
# # 2. Daten explorieren
# Zuallererst die Daten importieren und zur Modelierung aufbereiten.
# Schaut euch an wie die Daten aussehen, wie viele es sind und welche features es gibt.

# %% [markdown]
# ## 0.0 Imports

# %%
import pandas as pd

# %% [markdown]
# ## 2.1 Daten importieren

# %%
data = pd.read_csv("../input/us-accidents/US_Accidents_Dec19.csv")

# %% [markdown]
# ## 2.2 Daten und schema betrachten

# %% [markdown]
# ## 2.3 Daten untersuchen (sample)

# %% [markdown]
# ## 2.4 Daten untersuchen (statistisch)

# %% [markdown]
# # 3. Daten aufbereiten
# Bereitet die Daten für die Analyse vor. Was kann weg, was ist kaputt und welche Features kann ich noch extrahieren?

# %% [markdown]
# ## 3.1 Daten säubern

# %% [markdown]
# ## 3.2 Features Extrahieren

# %% [markdown]
# # 4. Daten Analysieren
# Analysiert die Daten. Gibt es etwas interessantes zu sehen? Behaltet ruhig auch Beispiele von Plots die nichts gebracht haben (auch das ist eine Erkenntnis). Wenn ihr merkt, dass die Daten nicht passen, dann schaut doch nochmal zu Punkt 3.

# %% [markdown]
# ## 4.1 Graphen erstellen

# %% [markdown]
# ## 4.2 Ergebnisse interpretieren

# %% [markdown]
# # 5. Ergebnisse kommunizieren
# Ihr habt die Daten visualisiert und interpretiert. Nun diskutiert eure Ergebnisse und leitet eure Entscheidung her. Eventuell wollt ihr hier einen wichtigen Plot von 4. nochmal darstellen.

# %% [markdown]
# ## 5.1 Ergebnisse diskutieren

# %% [markdown]
# ## 5.2 Entscheidung treffen
