# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
data = pd.read_csv("../input/weather-dataset/weatherHistory.csv")
data

# %%
data.head()

# %%
data.shape

# %%
data.index

# %%
data.columns

# %%
data.groupby('Temperature (C)').mean()

# %%
data.dtypes

# %%
data['Wind Speed (km/h)'].unique()

# %%
data.nunique()

# %%
data.count()

# %%
data['Wind Speed (km/h)'].value_counts()

# %%
data.info()

# %%
# to finding unique values

# %%
data.head(2)

# %%
data.nunique()

# %%
data['Wind Speed (km/h)'].nunique()

# %%
data['Wind Speed (km/h)'].unique()

# %%
# to finding Partly Cloudy Weather from Summary

# %%
data.head(2)

# %%
data[data.Summary == 'Partly Cloudy']

# %%
# find null values

# %%
data.isnull().sum()

# %%
data.notnull().sum()

# %%
#change the name of column

# %%
data.head(2)

# %%
data.rename(columns = {'Wind Speed (km/h)':'Windspeed'})

# %%
data['Wind Speed (km/h)'].value_counts()

# %%
 data[data['Wind Speed (km/h)']== '11.270']

# %%
# to find contains from tail side(bottom)

# %%
data[data['Summary'].str.contains('Partly Cloudy')].tail(50)

# %%
#find the data from head (top)

# %%
data[data['Summary'].str.contains('Partly Cloudy')].head(50)

# %%
# to find mean value of each column against any one of column

# %%
data.head(2)

# %%
data.groupby('Wind Speed (km/h)').mean()

# %%
# find the wind speed exactly 10.0947

# %%
data[data['Wind Speed (km/h)'] == 10.0947]

# %%
#find the mean of any data

# %%
data['Wind Speed (km/h)'].mean()

# %%
# variance of any data

# %%
data['Wind Speed (km/h)'].var()

# %%
# to  find the greater than less than values

# %%
data[data['Wind Speed (km/h)'] > 10]

# %%
data.groupby('Formatted Date').min()

# %%
data.groupby('Formatted Date').max()
