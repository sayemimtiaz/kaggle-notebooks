# %%
import numpy as np # linear algebra
import pandas as pd
import os
print(os.listdir("../input/siim"))
from glob import glob
import keras.backend as K
from pydicom import read_file
from keras.layers import Input, Activation, Conv2D, MaxPool2D
from keras.utils import Sequence

# %%
# !ls ../input/siim/dicom-images-train | wc -l

# %%
# !ls ../input/siim/dicom-images-test | wc -l

# %%
rle_df = pd.read_csv('../input/siim/train-rle.csv')
rle_df.to_csv('stage1-train-rle.csv')

rle_df.head(10)

# %%
rle_df.shape

# %%
all_train_fns = glob('../input/siim/dicom-images-train/*/*/*.*')

# %%
all_train_fns[0]

# %%
class DataGenrator(Sequence):
    def __init__(self, file_names, shuffle = True, bs= 32):
        self.file_names = file_names
        self.bs = bs
        self.shuffle = shuffle
        self.on_epoch_end()
        
    def on_epoch_end(self):
        self.indexes = np.arange(len(self.file_names))
        if self.shuffle = True:
            np.random.shuffle(self.indexes)
    def __len__(self):
        return np.ceil(len(self.file_names)/self.bs)
    
    def __getitem__(self, index):
        self.batch_indexes = range(index*bs:(index+1)*bs
        X = [read_file.imread(x).as_array for x in self.file_names[batch_indexes]]
        mask =  file_name.split('/')[-1][:-4]                         
        [rle_df.loc[file_name.split('/')[-1][:-4], ' EncodedPixels'] if for file_name in file_names[batch_indexes]]
        for file_name in file_names[batch_indexes]:

# %%
for file_name in file_names[]:

# %%
batch_indexes = self.file_names[self.index*bs:(index+1)*bs]
