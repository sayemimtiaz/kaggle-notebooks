# %% [markdown]
# # **QUESTION 5 CAT 3 **

# %% [markdown]
# # * **ADDING THE DATA SET**

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # **READING THE DATA SET OF YEAR 2019**

# %%
import pandas as pd

df= pd.read_csv("/kaggle/input/world-happiness/2019.csv")
df

# %% [markdown]
# # **A BRIEF DESCRIPTION OF ALL THE COLUMNS AND THIER VALUES**

# %%
print(df.describe(include='all'))

# %% [markdown]
# # **SELECTING ONLY COLUMNS TO WHICH SCORE AND HAPPINESS DEPENDS**

# %%
df1=df[['Country or region','Score','Social support','Healthy life expectancy','Generosity','Freedom to make life choices']]
df1

# %% [markdown]
# # **MEAN OF ALL THE COLUMNS**
#
# * *USED GROUPBY TO KNOW WHETHER THERE IS ANOTHER ENTRY OF ANY COUNTRY OR NOT*

# %%
df2 = df.groupby('Country or region').mean()
df2

# %% [markdown]
# # **MEDIAN OF ALL THE COLUMNS**
#
#
# * *USED GROUPBY TO KNOW WHETHER THERE IS ANOTHER ENTRY OF ANY COUNTRY OR NOT*

# %%
df4 = df.groupby('Country or region').median()
df4

# %% [markdown]
# # **MODE OF ALL THE COLUMNS**

# %%
df3 = df.mode()
df3

# %% [markdown]
# # **LIST OF ALL THE CLOUMNS WHICH HAVE NUMERIC DATA**

# %%
numeric_data = list(df._get_numeric_data().columns)
numeric_data

# %% [markdown]
# # **LIST OF ALL THE CLOUMNS WHICH HAVE CATEGORIAL DATA**

# %%
categorical_data = list(set(df.columns) - set(df._get_numeric_data().columns))
categorical_data

# %% [markdown]
# # **GRAPH OF COUNTRY WITH RESPECT TO SCORE (TOP 20 COUNTIRES WITH HIGH SCORE VALUE)**

# %%
import matplotlib.pyplot as plot
df1=df[['Country or region','Score']]

df2 = df1.groupby('Country or region').mean()

df3=df2.sort_values(by=['Score'],ascending=False, na_position='first')
df4=df3.head(20)
df4
df4.T.plot(kind='bar')

# %% [markdown]
# # **GRAPH OF COUNTRY WITH RESPECT TO SCORE (LAST 20 COUNTIRES WITH LOW SCORE VALUE)**

# %%
import matplotlib.pyplot as plot
df1=df[['Country or region','Score']]

df2 = df1.groupby('Country or region').mean()

df3=df2.sort_values(by=['Score'],ascending=True, na_position='first')
df4=df3.head(20)
df4
df4.T.plot(kind='bar')

# %% [markdown]
# # **GRAPH OF COUNTRY WITH RESPECT TO SOCIAL SUPPORT (TOP 20 COUNTIRES WITH HIGH SOCIAL SUPPORT VALUE)**

# %%
import matplotlib.pyplot as plot
df1=df[['Country or region','Social support']]
df2 = df1.groupby('Country or region').mean()
df3=df2.sort_values(by=['Social support'],ascending=False, na_position='first')
df4=df3.head(20)
df4.T.plot(kind='bar')

# %% [markdown]
# # **# **GRAPH OF COUNTRY WITH RESPECT TO SOCIAL SUPPORT (LAST 20 COUNTIRES WITH LOW SOCIAL SUPPORT VALUE)****

# %%
import matplotlib.pyplot as plot
df1=df[['Country or region','Social support']]
df2 = df1.groupby('Country or region').mean()
df3=df2.sort_values(by=['Social support'],ascending=True, na_position='first')
df4=df3.head(20)
df4.T.plot(kind='bar')

# %% [markdown]
# # **GRAPH OF COUNTRY WITH RESPECT TO Healthy life expectancy (TOP 20 COUNTIRES WITH HIGH Healthy life expectancy VALUE)**

# %%
import matplotlib.pyplot as plot
df1=df[['Country or region','Healthy life expectancy']]
df2 = df1.groupby('Country or region').mean()
df3=df2.sort_values(by=['Healthy life expectancy'],ascending=False, na_position='first')
df4=df3.head(20)
df4.T.plot(kind='bar')

# %% [markdown]
# # **GRAPH OF COUNTRY WITH RESPECT TO Healthy life expectancy (LAST 20 COUNTIRES WITH LOW Healthy life expectancy VALUE)**

# %%
import matplotlib.pyplot as plot
df1=df[['Country or region','Healthy life expectancy']]
df2 = df1.groupby('Country or region').mean()
df3=df2.sort_values(by=['Healthy life expectancy'],ascending=True, na_position='first')
df4=df3.head(20)
df4.T.plot(kind='bar')

# %% [markdown]
# # **CORRELATION OF THE SCORE WITH RESPECT TO HEALTHY LIFE EXPECTANCY**

# %%
column_1 = df["Score"]
column_2 = df["Healthy life expectancy"]
correlation = column_1.corr(column_2)
correlation

# %% [markdown]
# # **CORRELATION OF THE SCORE WITH RESPECT TO SOCIAL SUPPORT**

# %%
column_1 = df["Score"]
column_2 = df["Social support"]
correlation = column_1.corr(column_2)
correlation

# %% [markdown]
# # **CORRELATION OF THE SCORE WITH RESPECT TO FREEDOM TO MAKE LIFE CHOICES**

# %%
column_1 = df["Score"]
column_2 = df["Freedom to make life choices"]
correlation = column_1.corr(column_2)
correlation

# %% [markdown]
# # **CORRELATION OF THE SCORE WITH RESPECT TO GENEROSITY**

# %%
column_1 = df["Score"]
column_2 = df["Generosity"]
correlation = column_1.corr(column_2)
correlation

# %% [markdown]
# # **CORRELATION OF THE SCORE WITH RESPECT TO PERCEPTION OF CORRUPTION**

# %%
column_1 = df["Score"]
column_2 = df["Perceptions of corruption"]
correlation = column_1.corr(column_2)
correlation

# %% [markdown]
# # **CORRELATION OF ALL COLUMNS VALUES WITH RESPECT TO EACH OTHER **

# %%
df1=df.head(20)

correlation_df1 = df1.corr()
correlation_df1

# %% [markdown]
# # **COLUMN ENTRIES WHICH ARE NOT REALTED TO EACH OTHER **

# %%
import seaborn as sns
plot.figure(figsize=(20,20))
sns.heatmap(correlation_df1, annot=True, cmap="Reds")
plot.title('Correlation Heatmap', fontsize=20)

# %% [markdown]
# # **THE OVERALL CONCLUSION AND IMPORTANT FACTORS WHICH CAME OUT OF THE VISION BY THE DATASET ARE;-**

# %% [markdown]
# # **ACCORDING TO THE DATA SET :-**
# * HAPPINESS do not depend on a single factor
# * Countries having DECENT GDP per capita are having more SCORE for happiness.( Rich folks are more happy)
# * Countries having DECENT SCORE VALUE are have more freedom to make their choices.
# * Countries having low SOCIAL SUPPORT FOR ONE ANOTHER  do not have a good life span period.
# * Countries having DECENT GDP per capita are having more rate of corruption.
# * Countries having more CDP per capita are having better RANKS in the comparison.
# * SCORE dosnt play a important role in the LIFE SPAN OF ANY individual, to live a more years others factors are also important.

# %% [markdown]
# # **Is any supervised machine learning possible? if yes explain**.
# Answer
# Acording to me there is supervised machine learning is possible as "Supervised learning" is where you have input variables (x) and an output variable (Y) and you use an algorithm to learn the mapping function from the input to the output.
#
# Y = f(X)
#
# The goal is to approximate the mapping function so well that when you have new input data (x) that you can predict the output variables (Y) for that data.
#
# It is called supervised learning because the process of an algorithm learning from the training dataset can be thought of as a teacher supervising the learning process. We know the correct answers, the algorithm iteratively makes predictions on the training data and is corrected by the teacher. Learning stops when the algorithm achieves an acceptable level of performance.
#
#     > FINAL PREDICTIONS FROM THE DATA SET ARE;-
#     -----Countries having DECENT GDP per capita are having more SCORE for happiness.( Rich folks are more happy).
#     -----Countries having low SOCIAL SUPPORT FOR ONE ANOTHER do not have a good life span period.
#     -----Countries having DECENT GDP per capita are having more rate of corruption.
#     -----Countries having more CDP per capita are having better RANKS in the comparison.
# RICH COUNTIRES HAVE MORE CORRUPTION AND PEOPLE THEIR ARE HAVING MORE RIGHTS TO MAKE THIER CHOICES ,NOT EVEN THIS THE RICH COUNTIRES HAD MADE TO THE TOP OF THE TALLY AND HOLD MORE RANKS.
# WHERE PEOPLE DONT COMMUNICATE OR HAVE VERY LESS SOCIAL RELATIONSHIPS , THEY ARE NOT HAPPY AND HENCE THEIR LIFE SPAN IS SLIGHTLY LOW AS COMPARED TO THE COUNTIRES WHERE SOCIAL RELATIONS ARE MORE PREFERRED
#
# # ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# CREATED By;- HRITIK CHAUAHN {18SCSE1140026}
#              CNCS
#              DATA SCIENCE
#              CAT 3
#              ACTIVITY 5
#              GROUP 4
# **
# # ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------**
