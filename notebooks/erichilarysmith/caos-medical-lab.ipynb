# %%
# curl -L https://github.com/airplanedev/cli/releases/latest/download/install.sh | sh
# airplane login

# %%
# airplane init --slug=caosreaxson_ubw

# %%
#airplane deploy YOUR_TASK_FILE

# %%
# !pip install pymongo
# !pip install dnspython

# %%
import os

os.environ["ACCEPT"]
os.environ["INT"]
os.environ["TEXT"]
os.environ["URL"]
os.environ["DOPPLER_PROJECT"]
os.environ["DOPPLER_ENVIRONMENT"]

# %%
# !ls /datasets/caos

# %%
# !ls /datasets/caos1

# %%
# !ls /datasets/rasa-aphid

# %%
# !ls /datasets/rasa-aphid-1

# %%
import os

os.environ["DOPPLER_CONFIG"]

# %%
# !ls /datasets/paleos1

# %%
# !ls /datasets/paleos2

# %%
# !ls /datasets/nutritionix

# %%
# !ls /datasets/paleos3

# %%
# !ls /datasets/paleos4

# %%
# !ls /datasets/paleos5

# %%
# !ls /datasets/paleos6

# %%
# !ls /datasets/paleos7

# %%
# !ls /datasets/paleos8

# %%
df_1 = _deepnote_execute_sql("""SELECT * FROM "FoodDrinkMeasurementsUrineSamples"
""", 'SQL_99938535_F250_438A_AF62_1C3F300DDA67')
df_1

# %%
_deepnote_run_altair(df_1, """{"$schema":"https://vega.github.io/schema/vega-lite/v4.json","mark":{"type":"point","tooltip":{"content":"data"}},"height":220,"autosize":{"type":"fit"},"data":{"name":"placeholder"},"encoding":{"x":{"field":"Water","type":"nominal","sort":null,"scale":{"type":"linear","zero":false}},"y":{"field":"PH_avg","type":"nominal","sort":null,"scale":{"type":"linear","zero":false}},"color":{"field":"Water","type":"nominal","sort":null,"scale":{"type":"linear","zero":false}}}}""")

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=0ff117c7-d167-4ae0-9a82-d4fc840c4737' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
