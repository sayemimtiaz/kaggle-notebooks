# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df1 = pd.read_csv('/kaggle/input/amazon-top-50-bestselling-books-2009-2019/bestsellers with categories.csv')
df = pd.read_csv('/kaggle/input/amazon-top-50-bestselling-books-2009-2019/bestsellers with categories.csv')
df1.head(5)

# %%
df.value_counts()

# %%
df.info

# %%
df.info()

# %%
df= df.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=True)
#didn´t make any difference?

# %%
df1.value_counts()

# %%
df.info()

# %%
df1.describe()

# %%
Fiction = df1[(df1['Genre']=="Fiction")]#& (df['Reviews']> 5000)]
              #(df1['Year']>2015)]
Fiction.info()
Fiction.head(10)
dff = Fiction.sort_values(by=['Reviews'], ascending=False)
dff.head(10)

# %%
dfmean= dff['Reviews'].mean()
print(dfmean)
median= dff['Reviews'].median()
print(median)
#dff['Reviews'].
#dff['Reviews'].

# %%
fyear = Fiction.groupby('Year').count()
fyear['Name'].head(10)

# %%
preise = df1.loc[df1.Reviews > 20000]
#preise-fertig = df1.loc[df1.Reviews]== preise]
preise = preise.drop(labels='Year', axis=1)
preise.drop_duplicates()
preise.head(9)

# %%
preise = preise.head(10)
#plt.plot(preise['Reviews'], preise['Author'],kind=bar)
plt.bar(preise['User Rating'], preise['Author'], alpha=0.5)
plt.show()
#unsinnig

# %%
Richtung = df.groupby('Author').count()
Richtung.sort_values(by=['Name'], ascending=False)
Richtung
#unsinnig

# %%
fict.groupby

# %%
df09= df[df['Year']== 2009]
df09
df09nf = df09[df09['Genre']=='Non Fiction']
df09nf.shape
#df09nf.info
#df = df09nf.drop(labels=['User Rating', 'Genre'], axis=1)
#df.sort_values(by='Reviews', ascending=False)
#df09nf

# %%
#Die beliebtesten Authoren
author_count = []
author_name = {}
for row in df:
    author_count.append()
    if df.loc[row]['Author']
#to be continued
