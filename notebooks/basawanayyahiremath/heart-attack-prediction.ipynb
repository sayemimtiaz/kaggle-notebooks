# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report,confusion_matrix

# %%
he = pd.read_csv('../input/heart-attack-analysis-prediction-dataset/heart.csv')

# %%
he.head()

# %%
sns.heatmap(he.isnull())

# %%
he.info()

# %%
he.shape

# %%
x=he.iloc[:,0:13]
y=he['output']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
for i in range(1,51,2):
    regressor=KNeighborsClassifier(n_neighbors=i)
    regressor.fit(x_train,y_train)
    pred_knn = regressor.predict(x_test)
    print("Accuracy:",accuracy_score(y_test, pred_knn), "for ",i)

# %%
from sklearn.ensemble import RandomForestClassifier
ran = RandomForestClassifier(n_estimators = 10, random_state = 10)
  
ran.fit(x, y)

# %%
Y_pred = ran.predict(x_test)

# %%
Random=accuracy_score(y_test,Y_pred)

# %%
print("Accuracy  :",Random)

# %%
print(confusion_matrix(y_test,Y_pred))

# %%
from sklearn.model_selection import GridSearchCV
param={'n_neighbors':[13]}
est=KNeighborsClassifier()

ht=GridSearchCV(estimator=est, param_grid=param, cv=100)

# %%
ht.fit(x_train,y_train)

# %%
pred_cv = ht.predict(x_test)

# %%
CV_pred=accuracy_score(y_test, pred_cv)

# %%
print("Accuracy of GridSearchCV : ",CV_pred)

# %%
print(confusion_matrix(y_test,pred_cv))

# %%
print("Accuracy of Random Forest: ",Random)
print("Accuracy of Grid Search CV: ",CV_pred)

# %%
my_dict = {'Random Forest': '0.9836065573770492', 'Grid Search CV':'0.6229508196721312'}
perc =  [float(i[:-1]) for i in my_dict.values()]
sns.barplot(x=list(my_dict.keys()),y=perc)

# %%
output = pd.DataFrame({'Actully' : y_test,'Output': Random})
output.to_csv('submission.csv', index=False)
