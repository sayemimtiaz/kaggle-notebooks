# %% [markdown]
# # Word Cloud in Python
#
# **Learn more about Word Clouds on: https://www.analyticsvidhya.com/blog/2021/05/how-to-build-word-cloud-in-python/**

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud

# %% [markdown]
# ### Importing Dataset

# %%
df = pd.read_csv("../input/top-play-store-games/android-games.csv")

# %% [markdown]
# ### Checking the Data

# %%
df.head()

# %% [markdown]
# ### Checking for NaN values

# %%
df.isna().sum()

# %% [markdown]
# ### Removing NaN Values

# %%
#df.dropna(inplace = True)

# %% [markdown]
# ### Creating the text variable

# %%
text = " ".join(cat.split()[1] for cat in df.category)

# %% [markdown]
# ### Creating word_cloud with text as argument in .generate() method

# %%
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(text)

# %% [markdown]
# ### Display the generated Word Cloud

# %%
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### Word Cloud for Title Column

# %%
#Creating the text variable
text2 = " ".join(title for title in df.title)

# Creating word_cloud with text as argument in .generate() method
word_cloud2 = WordCloud(collocations = False, background_color = 'white').generate(text2)

# Display the generated Word Cloud
plt.imshow(word_cloud2, interpolation='bilinear')
plt.axis("off")
plt.show()
