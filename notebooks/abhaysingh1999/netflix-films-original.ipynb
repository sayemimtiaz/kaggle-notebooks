# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv("../input/netflix-original-films-imdb-scores/NetflixOriginals.csv")

# %%
data.head()

# %%
data.describe()

# %%
#to check if there are any null values
data.isnull().sum().to_frame()

# %%
# now we use info function to check dtype of features in the dataset
data.info()

# %%
# As we can see that Premiere is Date dtype and it is classified as object so we will change it
data["Premiere"] = pd.to_datetime(data["Premiere"])

# %%
# Now checking
data.info()

# %%
data.head()

# %%
# Now we will see a pair plot graph of this dataset
sns.pairplot(data)

# %%
data["Genre"].value_counts().plot(kind = "bar")

# %%
import datetime as dt

# %%
data["Year"] = data["Premiere"].dt.year

# %%
data.head()

# %%
data["Year"].value_counts().plot(kind = "barh")

# %%
data["Language"].value_counts().plot(kind = "bar")

# %%
# checking is their any correlation between runtime and IMDb rating
data[["Runtime","IMDB Score"]].corr()
# almost negligable relationship

# %%
data.groupby("Year")["IMDB Score"].mean()

# %%
data["Year"].sort_values(ascending = False).value_counts().plot(kind = "bar")

# %%
sns.lineplot(x = "Year",y = "IMDB Score",data = data,ci = None)

# %%
sns.scatterplot(x = 'Runtime' , y='IMDB Score' , data = data)

# %%
data.groupby(by=["Genre"] , sort =True).sum()
