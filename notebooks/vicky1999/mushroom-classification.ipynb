# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %% [markdown]
# # MUSHROOM CLASSIFIER
#    Mushroom classifier is a Machine Learning model which is used to predict whether a mushroom is edible or not.  The model which is used here is a Logistic Regression model. The data is taken from https://www.kaggle.com/uciml/mushroom-classification. The dataset consists of 22 features and one target label.

# %% [markdown]
# # READING DATA

# %%
data=pd.read_csv('../input/mushroom-classification/mushrooms.csv')
data.head()

# %% [markdown]
# # GETTING TARGET LABEL
#    The target label used in the dataset is **class**.  This contains the data about whether a mushroom is edible or not.  The target label is stored in another variable and is dropped from the dataframe.

# %%
labels=data['class']
data=data.drop('class',axis=1)
labels.head()

# %%
data.head()

# %% [markdown]
# # ENCODING DATA
#   Since, the data is of object type, It is not possible to make prediction.  So, we need a way to convert the data to either an integer type or a float type.  To do this, we need to encode the data.  Here, **Label Encoder** is used to encode the data.

# %%
data.dtypes

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
data.columns

# %%
for i in data.columns:
    data[i]=encoder.fit_transform(data[i])

# %%
data.head()

# %% [markdown]
# Now, all the characters has been converted to integers.

# %%
data.dtypes

# %% [markdown]
# # MODEL CREATION

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %% [markdown]
# # DATA SPLIT
#   Here, the train_test_split() will split the data into training and testing data.  The training data will contain 70% of the actual data and the testing data will contain 30% of the data.

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(data,labels,test_size=0.3,random_state=40)

# %% [markdown]
# # MODEL TRAINING

# %%
model.fit(X_train,y_train)

# %% [markdown]
# # PREDICTION ON THE TESTING DATA

# %%
predictions=model.predict(X_test)

# %% [markdown]
# # ACCURACY OF THE MODEL
#   The accuracy_score() is used to find the accuracy of the model.  Using Logistic Regression, the accuracy obtained is 94%

# %%
from sklearn.metrics import accuracy_score
print("Accuracy : "+str(accuracy_score(y_test,predictions)))
