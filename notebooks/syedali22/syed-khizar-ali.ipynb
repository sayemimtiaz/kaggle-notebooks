# %%
import pandas as pd
import numpy as np
import os
for dirname, _, filenames in os.walk('/kaggle/input'):

    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df=pd.read_csv("../input/pakistans-largest-ecommerce-dataset/Pakistan Largest Ecommerce Dataset.csv")

# %%
df.head()

# %%
df.isnull().sum()

# %%
df.drop(['sales_commission_code','Customer ID','Unnamed: 21','Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25'],axis=1,inplace=True)

# %%
df=df[:584524]
(df.shape)

# %%
df.isna().sum()

# %%
df=df.dropna()
df.isna().sum()

# %% [markdown]
# # most selling   categories

# %%
import seaborn as sns

# %%
vals=df['category_name_1'].value_counts().values
cats=df['category_name_1'].value_counts().index

# %%
sns.barplot(x=vals,y=cats,data=df)

# %% [markdown]
# # Payment Method and Status Co-relation and  visualization

# %%
pay_method= df['payment_method'].value_counts()
pay_method

# %%
cats_method= df['payment_method'].value_counts().index

# %%
sns.barplot(x=pay_method,y=cats_method,data=df)

# %%
status_counts = df['status'].value_counts()
status_counts

# %%
index_y=df['status'].value_counts().index

# %%
sns.barplot(x=status_counts,y=index_y,data=df)

# %%
corr=df.corr()
sns.heatmap(corr,annot=True,cmap='coolwarm')
