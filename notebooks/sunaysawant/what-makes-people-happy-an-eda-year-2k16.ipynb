# %% [markdown]
# # World Happiness :)

# %% [markdown]
# ![](https://image.freepik.com/free-vector/smiley-face-concept-illustration_114360-1296.jpg)
#
# The World Happiness Report is a publication of the United Nations Sustainable Development Solutions Network. It contains articles and rankings of national happiness, based on respondent ratings of their own lives, which the report also correlates with various (quality of) life factors.
#
# In this dataset we are going to analyze different factors that affect happiness.

# %% [markdown]
# Load the important required libraries.

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('dark')

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Let us load the data set.

# %%
happy2015 = pd.read_csv('../input/world-happiness/2015.csv')
happy2016 = pd.read_csv('../input/world-happiness/2016.csv')
happy2017 = pd.read_csv('../input/world-happiness/2017.csv')
happy2018 = pd.read_csv('../input/world-happiness/2018.csv')
happy2019 = pd.read_csv('../input/world-happiness/2019.csv')

# %% [markdown]
# # 2015 :)
# ## <a href="https://www.kaggle.com/sunaysawant/what-makes-people-happy-an-eda-year-2k15">Analysis On 2015 World Happiness Data</a>

# %% [markdown]
# # 2016 :)

# %% [markdown]
# ## Data Analysis On 2016 World Happiness Dataset

# %% [markdown]
# Checking first 5 and last 5 records from the datasets

# %%
happy2016.head(5)

# %%
happy2016.tail(5)

# %% [markdown]
# Let's check the duplicate data in data set.

# %%
happy2016.duplicated().sum()

# %%
happy2016.shape

# %%
happy2016.info()

# %%
happy2016.isnull().sum()

# %% [markdown]
# * There are total 158 rows/countries and 13 columns/features.
# * Also there are no duplicates and null values are present.
#
# Looks like good to go ahead.

# %% [markdown]
# ***
# #### Understand The Dataset
#
# The World Happiness Report is a survey of the state of global happiness. The happiness scores (0-10) are based on answers to the main life evaluation question asked in the poll.
#
# Happiness Score Columns:
#
# * GDP per Capita
# * Confidence Interval (Upper & Lower)
# * Family - Social Support
# * Health Life Expectancy
# * Freedom
# * Generosity
# * Trust (Government Corruption)
# * Distopya Residual Metric (Dystopia Happiness Score (1.85) + Residual Value
#
# If we add all these factors up, we will get the happiness score so it might be un-reliable to model them to predict Hapiness Scores.
#
# Our main goal is to do an exploratory analysis of the factors that make people happy.
# ***

# %% [markdown]
# ### EDA - 2016 World Happiness Dataset

# %% [markdown]
# ### Top 10 Happiest Countries - 2016

# %%
happy2016_top10 = happy2016.groupby('Country')['Happiness Score'].max().sort_values(ascending=False).head(10).reset_index()
happy2016_top10.columns = ['Country','Score']
happy2016_top10

# %%
plt.figure(figsize=(10,7))
sns.barplot(y=happy2016_top10['Country'], x=happy2016_top10['Score'], palette='twilight', orient='h')
plt.title('Top 10 Happiest Country', fontsize=15)
plt.xlabel('Happiness Score', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 8)

# %% [markdown]
# ### Top 10 Saddest Countries - 2016

# %%
happy2016_bot10 = happy2016.groupby('Country')['Happiness Score'].max().sort_values(ascending=False).tail(10).reset_index()
happy2016_bot10.columns = ['Country','Score']
happy2016_bot10

# %%
plt.figure(figsize=(10,7))
sns.barplot(y=happy2016_bot10['Country'], x=happy2016_bot10['Score'], palette='twilight', orient='h')
plt.title('Top 10 Saddest Country', fontsize=15)
plt.xlabel('Happiness Score', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 4)

# %% [markdown]
# ### Top 10 Countries With Highest Upper Confidence Interval - 2016

# %%
happy2016_uc_top10 = happy2016.groupby('Country')['Upper Confidence Interval'].max().sort_values(ascending=False).head(10).reset_index()
happy2016_uc_top10.columns = ['Country','Upper Confidence Interval']
happy2016_uc_top10

# %%
plt.figure(figsize=(10,7))
sns.barplot(y=happy2016_uc_top10['Country'], x=happy2016_uc_top10['Upper Confidence Interval'], palette='PuBu_r', orient='h')
plt.title('Top 10 Countries With Highest Upper Confidence Interval', fontsize=15)
plt.xlabel('Upper Confidence Interval', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 8)

# %% [markdown]
# ### Top 10 Countries With Lowest Upper Confidence Interval - 2016

# %%
happy2016_uc_bot10 = happy2016.groupby('Country')['Upper Confidence Interval'].max().sort_values(ascending=False).tail(10).reset_index()
happy2016_uc_bot10.columns = ['Country','Upper Confidence Interval']
happy2016_uc_bot10

# %%
plt.figure(figsize=(10,7))
sns.barplot(y=happy2016_uc_bot10['Country'], x=happy2016_uc_bot10['Upper Confidence Interval'], palette='PuBu_r', orient='h')
plt.title('Top 10 Countries With Lowest Upper Confidence Interval', fontsize=15)
plt.xlabel('Upper Confidence Interval', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 4)

# %% [markdown]
# ### Upper & Lower Confidence Interval vs Country - 2016

# %% [markdown]
# **Since the data is already arranged in ascending order of Happiness Score, let's see how top 20 Countries are distributed WRT Upper & Lower Confidence Level.**

# %%
fig, ax = plt.subplots(figsize=(12, 7))
sns.lineplot(happy2016['Upper Confidence Interval'].head(20), happy2016['Country'], linestyle='--',marker='H', label='Upper Confidence Interval')
sns.lineplot(happy2016['Lower Confidence Interval'].head(20), happy2016['Country'], linestyle=':',marker='p', label='Lower Confidence Interval')
plt.title('Confidence Interval vs Country', fontsize=15)
plt.xlabel('Confidence Interval', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.legend()
plt.show()

# %% [markdown]
# ### Top 10 Countries With Highest GDP Per Capita - 2016

# %%
happy2016_gdp_top10 = happy2016.groupby('Country')['Economy (GDP per Capita)'].max().sort_values(ascending=False).head(10).reset_index()
happy2016_gdp_top10.columns = ['Country','GDP']
happy2016_gdp_top10

# %%
plt.figure(figsize=(10,7))
sns.barplot(y=happy2016_gdp_top10['Country'], x=happy2016_gdp_top10['GDP'], palette='mako', orient='h')
plt.title('Top 10 Countries With Highest GDP', fontsize=15)
plt.xlabel('GDP', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 2)

# %% [markdown]
# ### Top 10 Countries With Lowest GDP Per Capita - 2016

# %%
happy2016_gdp_bot10 = happy2016.groupby('Country')['Economy (GDP per Capita)'].max().sort_values(ascending=False).tail(10).reset_index()
happy2016_gdp_bot10.columns = ['Country','GDP']
happy2016_gdp_bot10

# %%
plt.figure(figsize=(10,7))
sns.barplot(y=happy2016_gdp_bot10['Country'], x=happy2016_gdp_bot10['GDP'], palette='mako', orient='h')
plt.title('Top 10 Countries With Lowest GDP', fontsize=15)
plt.xlabel('GDP', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 0.3)

# %% [markdown]
# ### Top 10 Countries With Highest Family-Social Support - 2016

# %%
happy2016_social_top10 = happy2016.groupby('Country')['Family'].max().sort_values(ascending=False).head(10).reset_index()
happy2016_social_top10.columns = ['Country','Family Support']
happy2016_social_top10

# %%
plt.figure(figsize=(10,7))
sns.barplot(y=happy2016_social_top10['Country'], x=happy2016_social_top10['Family Support'], palette='inferno', orient='h')
plt.title('Top 10 Countries With Highest Family Social Support', fontsize=15)
plt.xlabel('Family Social Support', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 1.5)

# %% [markdown]
# ### Top 10 Countries With Lowest Family-Social Support - 2016

# %%
happy2016_social_bot10 = happy2016.groupby('Country')['Family'].max().sort_values(ascending=False).tail(10).reset_index()
happy2016_social_bot10.columns = ['Country','Family Support']
happy2016_social_bot10

# %%
plt.figure(figsize=(10,7))
sns.barplot(y=happy2016_social_bot10['Country'], x=happy2016_social_bot10['Family Support'], palette='inferno', orient='h')
plt.title('Top 10 Countries With Lowest Family Social Support', fontsize=15)
plt.xlabel('Family Social Support', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 0.3)

# %% [markdown]
# ### Top 10 Countries With Highest Healthy Life Expectancy - 2016

# %%
happy2016_healthy_top10 = happy2016.groupby('Country')['Health (Life Expectancy)'].max().sort_values(ascending=False).head(10).reset_index()
happy2016_healthy_top10.columns = ['Country','Health']
happy2016_healthy_top10

# %%
plt.figure(figsize=(10,7))
sns.barplot(y=happy2016_healthy_top10['Country'], x=happy2016_healthy_top10['Health'], palette='flare', orient='h')
plt.title('Top 10 Countries With Highest Healthy Life Expectancy', fontsize=15)
plt.xlabel('Health (Life Expectancy)')
plt.ylabel('Country')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 1)

# %% [markdown]
# ### Top 10 Countries With Lowest Healthy Life Expectancy - 2016

# %%
happy2016_healthy_bot10 = happy2016.groupby('Country')['Health (Life Expectancy)'].max().sort_values(ascending=False).tail(10).reset_index()
happy2016_healthy_bot10.columns = ['Country','Health']
happy2016_healthy_bot10

# %%
plt.figure(figsize=(10,7))
sns.barplot(y=happy2016_healthy_bot10['Country'], x=happy2016_healthy_bot10['Health'], palette='flare', orient='h')
plt.title('Top 10 Countries With Lowest Healthy Life Expectancy', fontsize=15)
plt.xlabel('Health (Life Expectancy)', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 0.17)

# %% [markdown]
# ### Top 10 Countries With Highest Freedom To Make Life Choices - 2016

# %%
happy2016_freedom_top10 = happy2016.groupby('Country')['Freedom'].max().sort_values(ascending=False).head(10).reset_index()
happy2016_freedom_top10.columns = ['Country','Freedom']
happy2016_freedom_top10

# %%
plt.figure(figsize=(10,7))
sns.barplot(y=happy2016_freedom_top10['Country'], x=happy2016_freedom_top10['Freedom'], palette='copper', orient='h')
plt.title('Top 10 Countries With Highest Freedom To Make Life Choices', fontsize=15)
plt.xlabel('Freedom', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 0.65)

# %% [markdown]
# ### Top 10 Countries With Lowest Freedom To Make Life Choices - 2016

# %%
happy2016_freedom_bot10 = happy2016.groupby('Country')['Freedom'].max().sort_values(ascending=False).tail(10).reset_index()
happy2016_freedom_bot10.columns = ['Country','Freedom']
happy2016_freedom_bot10

# %%
plt.figure(figsize=(10,7))
sns.barplot(y=happy2016_freedom_bot10['Country'], x=happy2016_freedom_bot10['Freedom'], palette='copper', orient='h')
plt.title('Top 10 Countries With Lowest Freedom To Make Life Choices', fontsize=15)
plt.xlabel('Freedom', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 0.14)

# %% [markdown]
# ### Top 10 Countries With Highest Perceptions Of Corruption- Trust - 2016

# %%
happy2016_trust_top10 = happy2016.groupby('Country')['Trust (Government Corruption)'].max().sort_values(ascending=False).head(10).reset_index()
happy2016_trust_top10.columns = ['Country','Trust']
happy2016_trust_top10

# %%
plt.figure(figsize=(10,7))
sns.barplot(y=happy2016_trust_top10['Country'], x=happy2016_trust_top10['Trust'], palette='cividis', orient='h')
plt.title('Top 10 Countries With Highest Perceptions Of Corruption- Trust', fontsize=15)
plt.xlabel('Perception Of Corruption', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 0.6)

# %% [markdown]
# ### Top 10 Countries With Lowest Perceptions Of Corruption- Trust - 2016

# %%
happy2016_trust_bot10 = happy2016.groupby('Country')['Trust (Government Corruption)'].max().sort_values(ascending=False).tail(10).reset_index()
happy2016_trust_bot10.columns = ['Country','Trust']
happy2016_trust_bot10

# %%
plt.figure(figsize=(10,7))
sns.barplot(y=happy2016_trust_bot10['Country'], x=happy2016_trust_bot10['Trust'], palette='cividis', orient='h')
plt.title('Top 10 Countries With Lowest Perceptions Of Corruption- Trust', fontsize=15)
plt.xlabel('Perceptions Of Corruption', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 0.03)

# %% [markdown]
# ### Top 10 Countries With Highest Generosity - 2016

# %%
happy2016_gen_top10 = happy2016.groupby('Country')['Generosity'].max().sort_values(ascending=False).head(10).reset_index()
happy2016_gen_top10.columns = ['Country','Generosity']
happy2016_gen_top10

# %%
plt.figure(figsize=(10,7))
sns.barplot(y=happy2016_gen_top10['Country'], x=happy2016_gen_top10['Generosity'], palette='icefire', orient='h')
plt.title('Top 10 Countries With Highest Generosity', fontsize=15)
plt.xlabel('Generosity', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 0.9)

# %% [markdown]
# ### Top 10 Countries With Lowest Generosity - 2016

# %%
happy2016_gen_bot10 = happy2016.groupby('Country')['Generosity'].max().sort_values(ascending=False).tail(10).reset_index()
happy2016_gen_bot10.columns = ['Country','Generosity']
happy2016_gen_bot10

# %%
plt.figure(figsize=(10,7))
sns.barplot(y=happy2016_gen_bot10['Country'], x=happy2016_gen_bot10['Generosity'], palette='icefire', orient='h')
plt.title('Top 10 Countries With Lowest Generosity', fontsize=15)
plt.xlabel('Generosity', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 0.07)

# %% [markdown]
# ### Top 10 Countries With Highest Dystopia Residual - 2016

# %%
happy2016_dr_top10 = happy2016.groupby('Country')['Dystopia Residual'].max().sort_values(ascending=False).head(10).reset_index()
happy2016_dr_top10.columns = ['Country','Dystopia Residual']
happy2016_dr_top10

# %%
plt.figure(figsize=(10,7))
sns.barplot(y=happy2016_dr_top10['Country'], x=happy2016_dr_top10['Dystopia Residual'], palette='Greens_r', orient='h')
plt.title('Top 10 Countries With Highest Dystopia Residual', fontsize=15)
plt.xlabel('Dystopia Residual', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 3.9)

# %% [markdown]
# ### Top 10 Countries With Lowest Dystopia Residual - 2016

# %%
happy2016_dr_bot10 = happy2016.groupby('Country')['Dystopia Residual'].max().sort_values(ascending=False).tail(10).reset_index()
happy2016_dr_bot10.columns = ['Country','Dystopia Residual']
happy2016_dr_bot10

# %%
plt.figure(figsize=(10,7))
sns.barplot(y=happy2016_dr_bot10['Country'], x=happy2016_dr_bot10['Dystopia Residual'], palette='Greens_r', orient='h')
plt.title('Top 10 Countries With Lowest Dystopia Residual', fontsize=15)
plt.xlabel('Dystopia Residual', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(0, 1.6)

# %% [markdown]
# ### Let's see what makes the people happy

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(12, 6), sharey='row', sharex='row')

axes[0, 0].scatter(x=happy2016['Economy (GDP per Capita)'], y=happy2016['Happiness Score'], color="#9933CC")
axes[0, 0].set_xlabel('Economy (GDP per Capita)')
axes[0, 0].set_ylabel('Happiness Score')

axes[0, 1].scatter(x=happy2016['Family'], y=happy2016['Happiness Score'], color="#9933CC")
axes[0, 1].set_xlabel('Family-Social Support')
axes[0, 1].set_ylabel('Happiness Score')

axes[1, 0].scatter(x=happy2016['Health (Life Expectancy)'], y=happy2016['Happiness Score'], color="#9933CC")
axes[1, 0].set_xlabel('Health (Life Expectancy)')
axes[1, 0].set_ylabel('Happiness Score')

axes[1, 1].scatter(x=happy2016['Freedom'], y=happy2016['Happiness Score'], color="#9933CC")
axes[1, 1].set_xlabel('Freedom To Make Life Choices')
axes[1, 1].set_ylabel('Happiness Score')

axes[2, 0].scatter(x=happy2016['Trust (Government Corruption)'],y=happy2016['Happiness Score'], color="#9933CC")
axes[2, 0].set_xlabel('Perceptions of Corruption')
axes[2, 0].set_ylabel('Happiness Score')

axes[2, 1].scatter(x=happy2016['Generosity'], y=happy2016['Happiness Score'], color="#9933CC")
axes[2, 1].set_xlabel('Generosity')
axes[2, 1].set_ylabel('Happiness Score')

fig.tight_layout()

# %% [markdown]
# # Conclusion - World Happiness Data Set - 2016
#
# 1. From above scatter plot, we can see that, except Perception Of Corruption every other thing like Economy (GDP Per Capita), Family Social Support, Health (Life Expectancy), Freedom To Choose Thing & Generosity makes people happy.
# 2. Top Countries In The World By Happiness Factors As:
#     * Happiest Country - Denmark
#     * Highest Upper Confidence Interval - Iceland
#     * Highest GDP Per Capita (Economy) - Qatar
#     * Highest Family Social Supported - Iceland
#     * High Healthy Life Expectancy Country - Hong Kong
#     * Highest Freedom To Choose Life Country - Uzbekistan
#     * Highest Perception of Corruption - Rwanda
#     * Highest Generosity - Myanmar

# %% [markdown]
# **In the next notebook we will see analysis on 2017 dataset.**
