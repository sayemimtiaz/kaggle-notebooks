# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from warnings import filterwarnings 
filterwarnings("ignore")

# %%
customer_data= pd.read_csv('/kaggle/input/customer-segmentation-tutorial-in-python/Mall_Customers.csv')

# %%
df=customer_data.copy()

# %%
df.head()

# %%
df.index=df["CustomerID"]

# %%
df.head()

# %%
df=df.iloc[:,1:]

# %%
df.index.rename('', inplace=True)

# %%
df.head()

# %%
df.isnull().sum()

# %%
df.info()

# %%
df.describe().T

# %%
df.plot.kde();

# %%
fig,axes=plt.subplots(1,2, figsize=(7,7))
sns.distplot(df["Age"],ax=axes[0])

sns.distplot(df["Annual Income (k$)"],ax=axes[1])

plt.show();

# %%
sns.distplot(df["Spending Score (1-100)"]);

# %%
sns.catplot(x="Gender", kind="count", data=df).set_titles(["Men", "Women"])

# %%
sns.pairplot(df,kind="reg");

# %%
dff=df.drop(["Gender"],axis=1)

# %%
dff.head()

# %%
from sklearn.cluster import KMeans

# %%
kmeans=KMeans(n_clusters=4)

# %%
k_fit=kmeans.fit(dff)

# %%
k_fit.n_clusters

# %%
k_fit.cluster_centers_

# %%
k_fit.labels_

# %%
kmeans=KMeans(n_clusters=2)

# %%
k_fit=kmeans.fit(dff)

# %%
clusters=k_fit.labels_

# %%
# Age and Spending Score
plt.scatter(dff.iloc[:,0],dff.iloc[:,2],c=clusters,s=50);

# %%
centers=k_fit.cluster_centers_

# %%
centers=k_fit.cluster_centers_

plt.scatter(dff.iloc[:,0],dff.iloc[:,2],c=clusters,s=50);

plt.scatter(centers[:,0], centers[:,2],c="black", s=200, alpha=0.5);

# %%
centers[:,0]

# %%
# Annual Income and Spending Score
plt.scatter(dff.iloc[:,1],dff.iloc[:,2],c=clusters,s=50);

# %%
centers=k_fit.cluster_centers_

# %%
centers=k_fit.cluster_centers_

plt.scatter(dff.iloc[:,1],dff.iloc[:,2],c=clusters,s=50);

plt.scatter(centers[:,1], centers[:,2], c="black", s=200, alpha=0.5);

# %%
centers[:,1]

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
kmeans=KMeans(n_clusters=3)

# %%
k_fit=kmeans.fit(dff)

# %%
clusters=k_fit.labels_

# %%
centers=kmeans.cluster_centers_

# %%
plt.rcParams["figure.figsize"]=(16,9)
fig=plt.figure()
ax=Axes3D(fig)
ax.scatter(dff.iloc[:,0], dff.iloc[:,1], dff.iloc[0:,2]);

# %%
fig=plt.figure()
ax=Axes3D(fig)
ax.scatter(dff.iloc[:,0], dff.iloc[:,1], dff.iloc[0:,2], c=clusters)
ax.scatter(centers[:,0], centers[:,1], centers[:,2], marker="X",c="#050505", s=1000);

# %%
kmeans=KMeans(n_clusters=4)

# %%
k_fit=kmeans.fit(dff)

# %%
clusters=k_fit.labels_

# %%
pd.DataFrame({"CustomerID": df.index, "Clusters": clusters})[0:10]

# %%
df["cluster_no"]=clusters

# %%
df.head()

# %%
from yellowbrick.cluster import KElbowVisualizer

# %%
kmeans=KMeans()

# %%
visualizer=KElbowVisualizer(kmeans,k=(2,20))

# %%
visualizer.fit(dff)
visualizer.poof()
