# %% [markdown]
# **<h1 align='center'>Amazon Top 50 Bestselling Books 2009 - 2019</h1>**

# %% [markdown]
# ## EDA on user rating/review

# %%
#IMPORTING REQUIRED LIBRARIES

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

palette = ['#F5DF4D', '#939597', '#0F4C81', '#FF6F61', '#5F4B8B', '#88B04B', '#92A8D1', '#F7CAC9', '#955251',\
           '#B163A3', '#009473']
palette.reverse()

# %%
#IMPORTING DATA

df = pd.read_csv('../input/amazon-top-50-bestselling-books-2009-2019/bestsellers with categories.csv')
df.head()

# %%
df.tail()

# %%
#VIEWING BASIC PROPERTIES

df.describe()

# %%
df.dtypes #viewing data types of different features

# %%
df.isnull().sum() #counting number of missing values in each feature

# %%
df['Year'] =  pd.to_datetime(df['Year'], format='%Y') #changing 'year' data type to date_time64

# %%
#VISUALISATION

# Set figure size (width, height) in inches
plt.figure(figsize = (16, 8))

years = np.sort(df['Year'].dt.year.unique())
for i, year in enumerate(years):
    # Plot histogram using Seaborn
    sns.histplot(df.loc[df['Year'] == str(year)]['User Rating'], stat='density', binwidth=0.1, color=palette[i], alpha=0.5) 

# Create plot legend
plt.legend(labels=years)

# Set label for x-axis
plt.xlabel( "User Rating (Bin Size = 0.1)" , size=16)
  
# Set label for y-axis
plt.ylabel( "% per User Rating" , size=16)
  
# Set title for figure
plt.title( "Amazon Best Sellers User Ratings by Year" , size=24);

# %%
# Set figure size (width, height) in inches
plt.figure(figsize = (16, 8))

# Plot histogram using Seaborn
sns.histplot(df.loc[df['Genre'] == 'Fiction']['User Rating'], stat='density', binwidth=0.1, color='c')
sns.histplot(df.loc[df['Genre'] == 'Non Fiction']['User Rating'], stat='density', binwidth=0.1, color='cyan') 

# Create plot legend
plt.legend(labels=['Fiction', 'Non Fiction'])

# Set label for x-axis
plt.xlabel( "User Rating (Bin Size = 0.1)" , size=16)
  
# Set label for y-axis
plt.ylabel( "% per User Rating" , size=16)
  
# Set title for figure
plt.title( "Amazon Best Sellers User Ratings by Genre" , size=24);

# %%
# Set figure size (width, height) in inches
plt.figure(figsize = (16, 8))

# Plot histogram using Seaborn
sns.histplot(df['User Rating'], stat='density', binwidth=0.1, color='lime')
  
# Set label for x-axis
plt.xlabel( "User Rating (Bin Size = 0.1)" , size=14)
  
# Set label for y-axis
plt.ylabel( "% per User Rating" , size=14)
  
# Set title for figure
plt.title( "Amazon Best Sellers User Ratings" , size=24);

# %%
# Set figure size (width, height) in inches
plt.figure(figsize = (16, 8))

years = np.sort(df['Year'].dt.year.unique())
for i, year in enumerate(years):
    # Plot histogram using Seaborn
    if i in range(6):
        sns.histplot(df.loc[df['Year'] == str(year)]['User Rating'], stat='density', binwidth=0.1, color=palette[i]) 

# Create plot legend
plt.legend(labels=years[0:6])

# Set label for x-axis
plt.xlabel( "User Rating (Bin Size = 0.1)" , size=14)
  
# Set label for y-axis
plt.ylabel( "% per User Rating" , size=14)
  
# Set title for figure
plt.title( "Amazon Best Sellers User Ratings by Year 2009-2014" , size=24);

# %%
# Set figure size (width, height) in inches
plt.figure(figsize = (16, 8))

years = np.sort(df['Year'].dt.year.unique())
for i, year in enumerate(years):
    # Plot histogram using Seaborn
    if i in range(6,12):
        sns.histplot(df.loc[df['Year'] == str(year)]['User Rating'], stat='density', binwidth=0.1, color=palette[i]) 

# Create plot legend
plt.legend(labels=years[6:12])

# Set label for x-axis
plt.xlabel( "User Rating (Bin Size = 0.1)" , size=14)
  
# Set label for y-axis
plt.ylabel( "% per User Rating" , size=14)
  
# Set title for figure
plt.title( "Amazon Best Sellers User Ratings by Year 2015-2019" , size=24);

# %%
df['Price Quantile'] = pd.qcut(df['Price'], 4, labels=False)

# Set figure size (width, height) in inches
plt.figure(figsize = (16, 8))

prices = np.sort(df['Price Quantile'].unique())
for i, price in enumerate(prices):
    # Plot histogram using Seaborn
    sns.histplot(df.loc[df['Price Quantile'] == price]['User Rating'], stat='density', binwidth=0.1, color=palette[i]) 

# Create plot legend
plt.legend(labels=prices)

# Set label for x-axis
plt.xlabel( "User Rating (Bin Size = 0.1)" , size=14)
  
# Set label for y-axis
plt.ylabel( "% per User Rating" , size=14)
  
# Set title for figure
plt.title( "Amazon Best Sellers User Ratings by Price Quantile" , size=24);

# %%
df['Reviews Quantile'] = pd.qcut(df['Reviews'], 4, labels=False)

# Set figure size (width, height) in inches
plt.figure(figsize = (16, 8))

reviews = np.sort(df['Reviews Quantile'].unique())
for i, review in enumerate(reviews):
    # Plot histogram using Seaborn
    sns.histplot(df.loc[df['Reviews Quantile'] == review]['User Rating'], stat='density', binwidth=0.1, color=palette[i]) 

# Create plot legend
plt.legend(labels=reviews)

# Set label for x-axis
plt.xlabel( "User Rating (Bin Size = 0.1)" , size=14)
  
# Set label for y-axis
plt.ylabel( "% per User Rating" , size=14)
  
# Set title for figure
plt.title( "Amazon Best Sellers User Ratings by Review Quantile" , size=24);

# %%
ax = df.boxplot('User Rating', 'Genre', figsize=(16,8), fontsize=12)
ax.set_ylabel('User Rating')
ax.set_title('');

# %%
ax = df.boxplot('User Rating', 'Year', figsize=(16,8), fontsize=16, rot=35)
ax.set_ylabel('User Rating')
ax.set_title('');

# %%
ax = df.boxplot('User Rating', 'Price Quantile', figsize=(16,8), fontsize=16, rot=35)
ax.set_ylabel('User Rating')
ax.set_title('');

# %%
ax = df.boxplot('User Rating', 'Reviews Quantile', figsize=(16,8), fontsize=16, rot=35)
ax.set_ylabel('User Rating')
ax.set_title('');

# %% [markdown]
# ## Upvote if you love it. Best of luck!
