# %% [markdown]
# 1.
# ## Air Quality in India, EDA using Tableau
# <div class="list-group" id="list-tab" role="tablist">
#   <h3 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home">Table of Contents</h3>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#uncle" role="tab" aria-controls="profile">Uncle, click here<span class="badge badge-primary badge-pill">1</span></a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#dev" role="tab" aria-controls="messages">Notes to ChaiEDA group to think on<span class="badge badge-primary badge-pill">2</span></a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#tableau" role="tab" aria-controls="profile">Tableau Visualizations<span class="badge badge-primary badge-pill">3</span></a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#stat" role="tab" aria-controls="messages">How is my wife's family doing during COVID?<span class="badge badge-primary badge-pill">4</span></a>

# %% [markdown]
# When analyzing data, I typically like to make sure I am thinking of a few questions.  Not having specific questions can be great because you can explore, but it can be easy for you to meander.  So **be purposeful in your questions that you are trying to answer and be sure to keep your your audience in mind.**
#
# In this notebook, as part of the #chaiEDA group, we are acting on this task: https://www.kaggle.com/rohanrao/air-quality-data-in-india/tasks?taskId=1877
#
# **Task:** Unfortunately, your uncle's wife recently died due to severe air pollution. Your uncle is super rich and he misses his wife very much. He calls you, knowing that you love data. You pick up and he immediately says, "In 2 weeks, tell me which city to invest in to improve air pollution for the long run. You'll have the $ for 3 years. Then, if you are successful, I will give same amount for 2 more cities. Please provide a rough plan to convince me of which geographical city / area to focus on, why that city, briefly on how you will make improvements, and how you will track progress. Thanks." Then he says that he hopes your family is doing well and that he will call back in 15 days and then abruptly hangs up before you can say anything.
#
# I will use the following tools to tell this story:
#
#     1) Tableau -- I love using tableau to help discover the way in which I will tell a story
#     2) Powerpoint -- Powerpoint gives me the flexibility to message things properly.
#
# In summary, I used **Tableau Desktop --> screenshots into Powerpoint --> storytelling in Powerpoint**.

# %% [markdown]
# # <a id='uncle'>Uncle, click here</a>
# 1. Uncle, I know you like things simple, so here we go...

# %% [markdown]
# <img src="https://i.imgur.com/jPgoJYR.png">

# %% [markdown]
# <img src="https://i.imgur.com/ofFjf3Y.png">

# %% [markdown]
# # <a id='dev'>Notes to ChaiEDA group to think on</a>

# %% [markdown]
# Uncle, you don't need to keep reading.  Let's talk soon though on how to get started on Ahmedabad.  :)

# %% [markdown]
# <img src="https://i.imgur.com/SLYw2MV.png">

# %% [markdown]
# <img src="https://i.imgur.com/q1qpoWo.png">

# %% [markdown]
# In the following images, I am showing different ways of cutting the data, with some notes/ thoughts attached to each... these are intended to get you thinking about the right things regarding this data set.

# %% [markdown]
# <img src="https://i.imgur.com/HTcq2iK.png">

# %% [markdown]
# <img src="https://i.imgur.com/Wj0lffN.png">

# %% [markdown]
# <img src="https://i.imgur.com/F7WPcMX.png">

# %% [markdown]
# # <a id='tableau'>2. Tableau Visualizations</a>
# Be sure to click on the GRAY tabs on the tab.  You'll toggle through many of the visualizations.  I don't like how you have to scroll along the bottom to see the full viz.  Ughh.
#
# I am not HUGE fan of displaying Tableau using the Story feature in a Kaggle Notebook.  The main reason I like it is because it is easier for me to put the vizs in one place.  Most of my storytelling and convincing of my uncle has already happend above, so I will do it here.

# %%
# %%HTML
# <div class='tableauPlaceholder' id='viz1599306491019' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;D6&#47;D6ZHWDHMG&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='path' value='shared&#47;D6ZHWDHMG' /> <param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;D6&#47;D6ZHWDHMG&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1599306491019');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='800px';vizElement.style.height='991px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %% [markdown]
# # <a id='stat'>3. How is my wife's family doing in Hyderabad?</a>
# My wife's parents are from Hyderabad, India.  I initially wanted to know how the air quality is in Hyderbad.

# %% [markdown]
# Using the AQI Index, I will use the year/week/day of week groupings to show easily show the trend for Hyderabad.  Week nbr on the left and year and day of week along the top.  This is a great way to visualize a large trend in a condensed amount of space.

# %%
# %%HTML
# <div class='tableauPlaceholder' id='viz1598703100699' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ai&#47;AirQualityDatainIndia&#47;Hyderabad1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='AirQualityDatainIndia&#47;Hyderabad1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ai&#47;AirQualityDatainIndia&#47;Hyderabad1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1598703100699');                    var vizElement = divElement.getElementsByTagName('object')[0];                    if ( divElement.offsetWidth > 800 ) { vizElement.style.width='800px';vizElement.style.height='827px';} else if ( divElement.offsetWidth > 500 ) { vizElement.style.width='800px';vizElement.style.height='827px';} else { vizElement.style.width='100%';vizElement.style.height='727px';}                     var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %% [markdown]
# It looks like things have improved a lot in Hyderabad.  That is a relief.

# %%
# %%HTML
# <div class='tableauPlaceholder' id='viz1598703130256' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ai&#47;AirQualityDatainIndia&#47;6maincities&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='AirQualityDatainIndia&#47;6maincities' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Ai&#47;AirQualityDatainIndia&#47;6maincities&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1598703130256');                    var vizElement = divElement.getElementsByTagName('object')[0];                    if ( divElement.offsetWidth > 800 ) { vizElement.style.width='800px';vizElement.style.height='1127px';} else if ( divElement.offsetWidth > 500 ) { vizElement.style.width='800px';vizElement.style.height='1127px';} else { vizElement.style.width='100%';vizElement.style.height='727px';}                     var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %% [markdown]
# I am using the same type of trend chart.  While I am not super thrilled about the formatting, I can see that Ahmedabad has benefitted the most from COVID.  I can also see the Delhi has improved a lot too.  (will add little light bulb later)
