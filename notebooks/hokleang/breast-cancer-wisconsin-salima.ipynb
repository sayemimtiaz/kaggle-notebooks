# %% [markdown]
# ## Breast Cancer Analysis

# %% [markdown]
# <img src="https://images.theconversation.com/files/154957/original/image-20170131-13238-b00n65.jpg?ixlib=rb-1.1.0&q=45&auto=format&w=926&fit=clip" width="800px">

# %% [markdown]
# **Installing the libraries**

# %%
# for basic operations
import numpy as np
import pandas as pd

# for visualizations
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# for interactive visualizations
import plotly.offline as py
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objs as go
from plotly import tools
init_notebook_mode(connected = True)

# for providing path
import os
print(os.listdir('../input'))

# %% [markdown]
# **Importing the dataset**

# %%
data = pd.read_csv('../input/data.csv')

# getting the shape
print(data.shape)

# %%
data.columns

# %%
data.shape

# %%
data.head()

# %%
data.diagnosis.value_counts()

# %%
malin=data.diagnosis=='M'
benin=data.diagnosis=='B'

# %%
data.diagnosis.value_counts()

# %%
sns.jointplot("perimeter_worst", "area_worst",data,kind='kde');

# %%
plt.figure(figsize=(12,12))
sns.kdeplot(data.perimeter_worst, data.area_worst,  shade=True)

# %%
#plt.figure(figsize=(12,12))
sns.kdeplot(data[malin].perimeter_worst, data[malin].area_worst, cmap="Reds",  shade=True, alpha=0.3, shade_lowest=False)
sns.kdeplot(data[benin].perimeter_worst, data[benin].area_worst, cmap="Greens", shade=True, alpha=0.3, shade_lowest=False)
