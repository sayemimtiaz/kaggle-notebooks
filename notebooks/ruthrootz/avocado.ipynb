# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
prices = pd.read_csv('../input/avocado-prices/avocado.csv', index_col = 'Date', parse_dates = True)

# %%
prices.info()

# %%
prices.head()

# %%
plt.figure(figsize = (14, 6))
plt.title('average price for an avocado over time')
sns.lineplot(data = prices.AveragePrice)

# %% [markdown]
# # view avocado spending by region

# %% [markdown]
# ### average price for each region over time

# %%
region_data = prices.groupby(['region']).AveragePrice.plot(legend = True, figsize = (30, 10))

# %% [markdown]
# ### total sales by region

# %%
# total_sales_by_region = prices[prices.region != 'TotalUS'].groupby(['region'])['Total Volume'].apply(lambda x : x.astype(int).sum())
# total_sales

filtered_regions = prices[prices.region != 'TotalUS']
plt.figure(figsize = (100, 10))
plt.title('total sales by region')
sns.barplot(x = filtered_regions.region, y = filtered_regions['Total Volume'])

# %%
filtered_regions = prices[prices.region != 'TotalUS'].groupby(['region'])['Total Volume'].apply(lambda x : x.astype(int).sum())
filtered_regions.plot.pie(x = 'region', y = 'Total Volume', figsize = (10, 10))
