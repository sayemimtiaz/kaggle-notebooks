# %% [markdown]
# # Importing Libraries and Dataset

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv("/kaggle/input/students-performance-in-exams/StudentsPerformance.csv")

# %%
df.head()

# %%
df.tail()

# %% [markdown]
# # Correlation Plots

# %%
df.corr()

# %%
fig_dims = (15, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.heatmap(data=df.corr(),annot=True).set_title('Correlation between Scores')

# %% [markdown]
# # Score Distribution

# %%
fig_dims = (15, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot(data=df)

# %% [markdown]
# # Correlation between Gender and Score

# %%
df['total score']=df['math score']+df['reading score']+df['writing score'] #Calculating total score

# %%
fig_dims = (15, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot(x=df['gender'],y=df['total score']).set_title('Male vs Female Score')

# %% [markdown]
# Lets have a closer look at the math scores

# %%
fig_dims = (15, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot(x=df['gender'],y=df['math score']).set_title('Male vs Female Score')

# %% [markdown]
# # Correlation between Race and Scores

# %%
fig_dims = (15, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot(x=df['race/ethnicity'],y=df['total score']).set_title('Race-wise Score')

# %% [markdown]
# # Correlation between Scores and Parental-Education

# %%
fig_dims = (15, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot(x=df['parental level of education'],y=df['total score'])

# %% [markdown]
# # Correlation between Lunch-Type and Scores

# %%
fig_dims = (15, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot(x=df['lunch'],y=df['total score'])

# %% [markdown]
# # Correlation between Test-Prep and Scores

# %%
fig_dims = (15, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.boxplot(x=df['test preparation course'],y=df['total score'])

# %% [markdown]
# Hope you liked it! Please comment any suggestions you feel can help me.
# Thanks for reading :)
