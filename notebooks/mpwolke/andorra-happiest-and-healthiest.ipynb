# %% [markdown]
# The tiny principality of Andorra is located in the high mountains of the Pyrenees between France and Spain.
#
# The mainstay of the highly-prosperous economy is tourism, accounting for about 80% of GDP. An estimated 10 million people visit each year, drawn by winter sports, a warm summer climate and duty-free goods.https://www.bbc.com/news/world-europe-17028050#:~:text=The%20tiny%20principality%20of%20Andorra,for%20about%2080%25%20of%20GDP.

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRT1qorSzFj1PeVK2hWySZObo1tHxqoqM8wYg&usqp=CAU)pt.slideshare.net

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.offline as py
import plotly.graph_objs as go
import plotly.offline as py
import plotly.express as px

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# #Why is Andorra rich? By Steve Morris
#
# Andorra has one of the longest life expectancies in the world (somewhere in the top 4, depending on which source you believe). It's also the 23rd richest country in the world, measured by per capita income – ahead of countries like Germany, France and the UK.
#
# Firstly, note that Andorra is one of the smallest countries in the world with almost no usable land and no natural resources of any kind. It’s just mountains. It doesn’t have enough agricultural land to feed its tiny population of just 86,000. It doesn’t even have an airport.
#
# You might have thought that a lack of resources would be a problem, but no. By contrast with the Central African Republic with its diamonds, Niger with its reserves of oil, gold and uranium, and Afghanistan, which grows almost the entire world’s heroin crop, and which are three of the world’s poorest countries, Andorra has nothing that it can dig up, chop down or otherwise exploit. So lesson number one is that wealth isn’t something that nature provides. It’s something that people create for themselves, literally out of thin air.
#
# Andorra knows that it can’t grow its own food, generate its own electricity or defend its own borders from attack. So it doesn’t try to do any of those things. Instead it focuses on creating the wealth it needs to pay for everything it lacks.
#
# Andorra imposes few restrictions on immigration. That’s why the vast majority of the population are not Andorran citizens. Do these immigrants cause unemployment? No. Andorra has virtually no unemployment (0 per cent until the global financial crisis hit in 2008). Yes – zero percent.
#
# Because the country needs to import so many goods, it imposes no import/export duties. It also imposes little or no taxes on its population and businesses, so people can just get on with working and creating employment. The population grew from 10,000 in the 1960s to 80,000 today – not through a high birth rate, but by creating jobs and allowing people to come and work in the country.https://blogbloggerbloggest.com/2013/08/29/why-is-andorra-rich

# %% [markdown]
# #Just Breathe, it's another day in the Mountains.
#
# ![](https://jaserodley.com/wp-content/uploads/2016/10/living-in-the-mountains-of-andorra-768x768.jpg)
# https://jaserodley.com/living-in-andorra/

# %%
ls ../input/hackathon/task_1-google_search_txt_files_v2/AD/

# %%
Andorra = '../input/hackathon/task_1-google_search_txt_files_v2/AD/Andorra-ca-result-3.txt'

# %%
text = open(Andorra, 'r',encoding='utf-8',
                 errors='ignore').read()

# %% [markdown]
# #What do people in Andorra actually do?
#
# I hope that you’ll realize by now that what they do isn’t really very important. What matters is that they have an economic framework that removes barriers to wealth creation and that allows individuals to do whatever they believe their skills and time are best spent on. People in Andorra do all kinds of interesting things, and not only are they some of the richest people in the world but they are also some of the happiest and healthiest.https://blogbloggerbloggest.com/2013/08/29/why-is-andorra-rich/

# %%
print(text[:1500])

# %%
#Codes from Paul Mooney (visualization of most common words)

# %matplotlib inline
def plotWordFrequency(input):
    f = open(Andorra,'r')
    words = [x for y in [l.split() for l in f.readlines()] for x in y]
    data = sorted([(w, words.count(w)) for w in set(words)], key = lambda x:x[1], reverse=True)[:40] 
    most_words = [x[0] for x in data]
    times_used = [int(x[1]) for x in data]
    plt.figure(figsize=(20,10))
    plt.bar(x=sorted(most_words), height=times_used, color = 'blue', edgecolor = 'black',  width=.5)
    plt.xticks(rotation=45, fontsize=18)
    plt.yticks(rotation=0, fontsize=18)
    plt.xlabel('Most Common Words:', fontsize=18)
    plt.ylabel('Number of Occurences:', fontsize=18)
    plt.title('Most Commonly Used Words: %s' % (Andorra), fontsize=24)
    plt.show()

# %%
Andorra = '../input/hackathon/task_1-google_search_txt_files_v2/AD/Andorra-ca-result-3.txt'
plotWordFrequency(Andorra)

# %%
df1 = pd.read_csv('../input/hackathon/BCG_world_atlas_data-2020.csv')
df1.head()

# %%
andorra1 = df1[(df1['Contry Name (Mandatory field)']=='Andorra')].reset_index(drop=True)
andorra1.head()

# %% [markdown]
# #Ending the TB epidemic.
#
# Andorra has no information on both files BCG World Atlas and Tuberculosis Infection Estimates.
#
# Globally, TB incidence is falling at about 2 per cent/year. This needs to accelerate to a 4–5 per cent/annual decline to reach the 2020 milestones of the End TB Strategy.
#
# Ending the TB epidemic by 2030 is among the health targets of the Sustainable Development Goals.https://www.who.int/news-room/fact-sheets/detail/tuberculosis

# %%
df2 = pd.read_csv('../input/hackathon/task_2-owid_covid_data-21_June_2020.csv')
df2.head()

# %% [markdown]
# #Andorra says it does not have any more cases of coronavirus
#
# Since the first infection in the country, in March, there have been a total of 855 cases and 52 deaths, and since June 18 there has been no contagion.
#
# The Andorran government confirmed on Thursday that there are no more patients with coronavirus in the country after four months of the pandemic outbreak.
#
# Andorra's Minister of Health, Joan Martínez Benazet, confirmed this data after the results of the latest PCR / TMA tests performed on the last infected patient confirmed that person's recovery, as reported by the Andorra News Agency on Thursday. (A-N-A).
#
# Since the first coronavirus case in the country, in March, there have been a total of 855 cases and 52 deaths, and since June 18 there has been no new detection.
#
# In early May, the Andorran government launched a population screening operation in the face of the coronavirus crisis, in which more than 60,000 people from a total of 77,796 inhabitants in the Pyrenees participated.https://translate.google.com.br/translate?hl=en&sl=pt&u=https://noticias.r7.com/internacional/andorra-afirma-que-nao-possui-mais-nenhum-caso-de-coronavirus-09072020&prev=search&pto=aue

# %%
andorra = df2[(df2['location']=='Andorra')].reset_index(drop=True)
andorra.head()

# %%
fig = px.bar(andorra, 
             x='date', y='total_cases', color_discrete_sequence=['#4263f5'],template='plotly_dark', 
             title='Andorra Covid-19 Total Cases', text='total_cases_per_million')
fig.show()

# %%
fig = px.bar(andorra, 
             x='date', y='new_cases', color_discrete_sequence=['#f54266'], template='plotly_dark',
             title='Andorra Covid-19 New Cases', text='new_cases_per_million')
fig.show()

# %%
fig = px.bar(andorra, 
             x='date', y='total_deaths', color_discrete_sequence=['#B6E880'],template='plotly_dark',
             title='Andorra Total Deaths by Covid-19', text='cvd_death_rate')
fig.show()

# %%
fig = px.bar(andorra,
             y='date',
             x='total_cases',
             orientation='h',
             color='total_cases_per_million',
             title='Andorra Covid-19 Total Cases',
             opacity=0.8,
             color_discrete_sequence=px.colors.diverging.Temps,
             template='plotly_white'
            )
fig.update_xaxes(range=[0,35])
fig.show()

# %%
fig = px.line(andorra, x="date", y="total_cases", color_discrete_sequence=['darksalmon'], template='plotly_dark',
              title="Andorra Covid-19 Total Cases")
fig.show()

# %%
fig, ax = plt.subplots(1,3, figsize = (20,6), sharex=True)
sns.countplot(x='total_cases',data=andorra, palette="copper", ax=ax[0])
sns.countplot(x='total_cases',hue='cvd_death_rate', palette="ocean", data=andorra,ax=ax[1])
sns.countplot(x='total_cases',hue='life_expectancy', palette="flag", data=andorra,ax=ax[2])
ax[0].title.set_text('Andorra Covid19 totalCases')
ax[1].title.set_text('Andorra Covid19 Cases Vs Death Rate')
ax[2].title.set_text('Andorra Covid19 Cases Vs Life Expectancy')
plt.xticks(rotation=45)
plt.show()

# %%
fig = px.scatter(andorra, x="date", y="total_cases",color_discrete_sequence=['#4257f5'],template='plotly_dark', title="Andorra Covid19 Total Cases" )
fig.show()

# %%
sns.countplot(x="life_expectancy",data=andorra,palette="flag",edgecolor="black")
plt.title('Andorra Life Expectancy', weight='bold')
plt.xticks(rotation=45)
plt.yticks(rotation=45)
# changing the font size
sns.set(font_scale=1)

# %%
sns.countplot(x="cvd_death_rate",data=andorra,palette="ocean",edgecolor="black")
plt.title('Andorra Covid19 Death Rate', weight='bold')
plt.xticks(rotation=45)
plt.yticks(rotation=45)
# changing the font size
sns.set(font_scale=1)

# %% [markdown]
# Covid-19 doesn't discriminate whealthy or poor Nations.

# %%
#word cloud
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in andorra.location)
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200,colormap='Set2', background_color="black").generate(text)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='Bilinear')
plt.axis("off")
plt.figure(1,figsize=(12, 12))
plt.show()

# %% [markdown]
# Das War's Kaggle Notebook Runner: Marília Prata  @mpwolke
