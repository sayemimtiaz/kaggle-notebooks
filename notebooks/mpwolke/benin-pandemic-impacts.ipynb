# %% [markdown]
# #Benin goes on digital offensive against COVID-19 - 09 april 2020
#
# Cotonou – After the first case of COVID-19 was announced in Benin on the 16 March, within four days, the West African nation had set up a range of digital platforms to help combat both the spread of the disease and what the World Health Organization (WHO) has called “infodemic” of misinformation around it.
#
# Spearheaded by Wilfried Léandre Houngbédji, a former journalist, supported by well-known Beninese social media expert, Stévy Wallace, a state-appointed team of around 15 people is using WHO guidelines to disseminate information on prevention and highlight the actions being taken by health authorities to deal with the unfolding crisis.
#
# In addition to a centralized official government platform that is freely accessible to all mobile phone users in Benin and provides frequent updates, the digital strategy team has put out several radio inserts in around 15 local languages and a range of awareness videos and press releases across different social networks. An interactive WhatsApp messaging system has also been set up and helps the new team to communicate directly with citizens both in Benin and the diaspora.https://www.afro.who.int/news/benin-goes-digital-offensive-against-covid-19

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRhdGfTyJCoBmneiu8q8zz0d4JvX4QJwx33BQ&usqp=CAU)pt-br.facebook.com

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline
import plotly.express as px
import plotly.graph_objects as go
import plotly.offline as py
import plotly.express as px

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# #Official Information
#
# “The official information is being very well relayed on social networks,” “Internet users are interacting expansively with the channels through questions, comments, contributions and criticism.”
#
# On the official pandemic website, the most visited portal, up to 16,000 hits are being registered per day. The website also has a COVID-19 ‘flash news’ function for near instantaneous response to fake news.
#
# "The big challenge for them is that they cannot reach certain sections of the population who do not have internet access or who are illiterate,” “So they need each internet user to pass on the correct information in their homes, their neighbourhood, their community. The cause must be a common one.”
#
# As COVID-19 cases continue to increase exponentially throughout Africa, with more than 10,000 people now infected across 52 countries, widely-accessible, responsive mobile and online communication platforms and messaging are a critical part of efforts to curb the spread of the virus.
#
# With the help of WHO’s guidelines, the team has rapidly grown the state’s online presence since the start of the outbreak, and the Beninese public has taken note. “They react very quickly to questions,"
#
# “It makes them feel closer,”  “ They feel that they are really being listened to. ”https://www.afro.who.int/news/benin-goes-digital-offensive-against-covid-19

# %%
df = pd.read_excel('../input/impact-of-covid19-subsaharan-africa/geopoll-coronavirus-round2-data_weighted_2020-04-30_final.xlsx')
df.head()

# %%
plt.figure(figsize=(20,4))
plt.subplot(131)
sns.countplot(x= 'MediaConsumption', data = df, palette="GnBu_d",edgecolor="black")
plt.subplot(132)
sns.countplot(x= 'SocialMedia', data = df, palette="flag",edgecolor="black")
plt.xticks(rotation=45)
plt.subplot(133)
sns.countplot(x= 'InformationSources: TV', data = df, palette="Greens_r",edgecolor="black")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(20,4))
plt.subplot(131)
sns.countplot(x= 'InformationSources: Friends/family', data = df, palette="RdBu",edgecolor="black")
plt.subplot(132)
sns.countplot(x= 'InformationSources: Government messages', data = df, palette="ocean",edgecolor="black")
plt.xticks(rotation=45)
plt.subplot(133)
sns.countplot(x= 'InformationSources: Newspapers', data = df, palette="bone",edgecolor="black")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(20,4))
plt.subplot(131)
sns.countplot(x= 'Foodworry', data = df, palette="PuRd",edgecolor="black")
plt.subplot(132)
sns.countplot(x= 'BrandPurchase', data = df, palette="cividis",edgecolor="black")
plt.xticks(rotation=45)
plt.subplot(133)
sns.countplot(x= 'NonEssentialItems', data = df, palette="viridis",edgecolor="black")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(20,4))
plt.subplot(131)
sns.countplot(x= 'FoodLocations2', data = df, palette="PuRd",edgecolor="black")
plt.xticks(rotation=45)
plt.subplot(132)
sns.countplot(x= 'FoodShopping', data = df, palette="Set2",edgecolor="black")
plt.xticks(rotation=45)
plt.subplot(133)
sns.countplot(x= 'FoodAmount', data = df, palette="Set3",edgecolor="black")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(20,4))
plt.subplot(131)
sns.countplot(x= 'EconomicImpact', data = df, palette="rocket",edgecolor="black")
plt.xticks(rotation=45)
plt.subplot(132)
sns.countplot(x= 'HealthBehavior', data = df, palette="mako",edgecolor="black")
plt.xticks(rotation=45)
plt.subplot(133)
sns.countplot(x= 'SocialDistancing', data = df, palette="rainbow",edgecolor="black")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(20,4))
plt.subplot(131)
sns.countplot(x= 'RiskAwareness', data = df, palette="binary",edgecolor="black")
plt.xticks(rotation=45)
plt.subplot(132)
sns.countplot(x= 'VirusPrevention', data = df, palette="Spectral",edgecolor="black")
plt.xticks(rotation=45)
plt.subplot(133)
sns.countplot(x= 'HandWashing', data = df, palette="Wistia",edgecolor="black")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQQuQxme_LaF4Y6exNhJsLWalnSc6rFbzR6PQ&usqp=CAU)pt.wikipedia.org

# %%
plt.figure(figsize=(20,4))
plt.subplot(131)
sns.countplot(x= 'Urban/Rural', data = df, palette="gist_stern",edgecolor="black")
plt.xticks(rotation=45)
plt.subplot(132)
sns.countplot(x= 'Tested', data = df, palette="gnuplot",edgecolor="black")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(20,4))
plt.subplot(131)
sns.countplot(x= 'PreventativeMeasures: Avoiding public places', data = df, palette="gist_stern",edgecolor="black")
plt.xticks(rotation=45)
plt.subplot(132)
sns.countplot(x= 'PreventativeMeasures: Avoiding public transport', data = df, palette="gnuplot",edgecolor="black")
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(x="PreventativeMeasures: Working from home",data=df,palette="GnBu_d",edgecolor="black")
plt.title('PreventativeMeasures: Working from home', weight='bold')
plt.xticks(rotation=45)
plt.yticks(rotation=45)
# changing the font size
sns.set(font_scale=1)

# %%
StayPositive = df[(df['StayPositive']=='Family, friends')].reset_index(drop=True)
StayPositive.head()

# %%
benin = df[(df['Country']=='Benin')].reset_index(drop=True)
benin.head()

# %%
plt.figure(figsize=(20, 12))
plt.subplot(121)
sns.boxplot(x = 'Gender.Weights', y = 'SocialMedia', data = benin)
plt.subplot(122)
sns.boxplot(x = 'Gender.Weights', y = 'MediaConsumption', data = benin)
plt.show()

# %%
ls ../input/hackathon/task_1-google_search_txt_files_v2/BJ/

# %%
Benin= '../input/hackathon/task_1-google_search_txt_files_v2/BJ/Benin-fr-result-13.txt'

# %%
text = open(Benin, 'r',encoding='utf-8',
                 errors='ignore').read()

# %%
print(text[:2000])

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTPFy-R9cN9duAamSeLbsUpXdeGrgt-Z8mwAw&usqp=CAU)sticna.org

# %%
#word cloud
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in StayPositive.StayPositive)
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200,colormap='Set2', background_color="black").generate(text)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='Bilinear')
plt.axis("off")
plt.figure(1,figsize=(12, 12))
plt.show()

# %%
#word cloud
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in benin.Country)
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200,colormap='Set2', background_color="black").generate(text)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='Bilinear')
plt.axis("off")
plt.figure(1,figsize=(12, 12))
plt.show()

# %% [markdown]
# Das War's Kaggle Notebook Runner: Marília Prata  @mpwolke
