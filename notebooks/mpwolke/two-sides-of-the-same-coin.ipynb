# %%
#Code by Olga Belitskaya https://www.kaggle.com/olgabelitskaya/sequential-data/comments
from IPython.display import display,HTML
c1,c2,f1,f2,fs1,fs2=\
'#3486eb','#3437eb','Akronim','Smokum',30,15
def dhtml(string,fontcolor=c1,font=f1,fontsize=fs1):
    display(HTML("""<style>
    @import 'https://fonts.googleapis.com/css?family="""\
    +font+"""&effect=3d-float';</style>
    <h1 class='font-effect-3d-float' style='font-family:"""+\
    font+"""; color:"""+fontcolor+"""; font-size:"""+\
    str(fontsize)+"""px;'>%s</h1>"""%string))
    
    
dhtml('This Kaggle Notebook is dedicated to health workers, scientists, volunteers, whose lives have been devoted to vaccine development, immunization, some of whom have lost their lives during the Covid-19 Pandemic' )

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcS7qm_11NiJGSBsT3UJk9nxYoPfmzl9Cw1DHw&usqp=CAU)publications.europa.eu

# %% [markdown]
# #Coping capacity and Vulnerabilities during the Covid-19 Pandemic, Two sides of the Same Coin.
#
# Vulnerability and Lack of Coping Capacity are relevant to COVID-19 and parts of the INFORM Covid-19 risk index.
#
# Higher Vulnerability and poorer Coping Capacity are associated with poorer control.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import plotly.graph_objects as go
import plotly.offline as py

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
df = pd.read_csv('../input/cusersmarildownloadsvulnerabilitycsv/vulnerability.csv', delimiter=';', encoding = "ISO-8859-1", nrows = nRowsRead)
df.dataframeName = 'vulnerability.csv'
nRow, nCol = df.shape
print(f'There are {nRow} rows and {nCol} columns')
df.head()

# %% [markdown]
# #Vulnerability and Coping Capacity: Two Sides of the Same Coin.
#
# ![](https://ars.els-cdn.com/content/image/1-s2.0-S2211464512000565-gr1.jpg)sciencedirect.com

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
df1 = pd.read_csv('../input/cusersmarildownloadslackcsv/lack.csv', delimiter=';', encoding = "ISO-8859-1", nrows = nRowsRead)
df1.dataframeName = 'lack.csv'
nRow, nCol = df1.shape
print(f'There are {nRow} rows and {nCol} columns')
df1.head()

# %%
plt.figure(figsize = (10,6))
sns.lineplot(data=df, x="Total_public_Aid_M_Usdollars", y="Public_Aid_per_capita_US", color='r', marker='*')
plt.title("Public Aid per capita US$",fontweight='bold',size=20)
plt.xlabel('Total_public_Aid_M_Usdollars',size=15)
plt.ylabel('Public_Aid_per_capita_US',size=15)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #INFORM Vulnerability: Socio-Economic Vulnerability and Vulnerable Groups
#
# SOCIO-ECONOMIC VULNERABILITY
#
# Development & Deprivation: Human Development Index and Multidimensional Poverty Index.
#
# Inequality: Gender Inequality Index and Gini Index.
#
# Economic Dependency Index: Public Aid per capita (US$);; Net ODA received (percent of GNI);; Volume of remittances.
#
# VULNERABLE GROUPS
#
# Uprooted people
#
# Health Conditions: HIV;; Incidence of Tuberculosis;; Malaria incidence per 1,000 population at risk;; People requiring interventions against neglected tropical diseases.
#
# Food Security: Food Availability Score and Food Utilization Score.
#
# https://reliefweb.int/sites/reliefweb.int/files/resources/INFORM%20COVID%20Risk%20Index%20V012%20Report.pdf

# %%
fig = px.bar(df1, 
             x='Covid19_Lack_of_coping_capacity', y='Immunization_coverage', color_discrete_sequence=['#27F1E7'],
             title='Covid19 Lack of Coping Capacity & Immunization', text='Government Effectiveness')
fig.show()

# %%
fig = px.bar(df, 
             x='Covid_19_Vulnerability', y='Incidence_of_Tuberculosis', color_discrete_sequence=['crimson'],
             title='Covid-19 Vulnerability & Tuberculosis', text='Health Conditions')
fig.show()

# %%
fig = px.bar(df, 
             x='Covid_19_Vulnerability', y='HIV', color_discrete_sequence=['#2B3A67'],
             title='Covid-19 Vulnerability & HIV', text='Number_of_new_HIV_infections_per_1000_uninfected_population')
fig.show()

# %% [markdown]
# #The meaning of Vulnerabilities
#
# Analysis of the INFORM COVID Risk Index suggests that factors that make individuals vulnerable to COVID-19, like age and specific pre-existing conditions,drive vulnerability and risk in higher income countries. However, in countries with the highest risk of humanitarian crisis as a result of COVID-19, which are overwhelmingly low and lower-middle income countries, factors of vulnerability that are highly specific to COVID-19 are less important than broader socio-economic factors or those associated with vulnerable groups like the food insecure, people in poor health and displaced persons.
#
# Although this conclusion partly arrives from the way risk index is conceptualised, it suggests that at least in the preparedness and early response phase of the pandemic in countries at high risk of humanitarian crisis risk can be reduced by addressing broader vulnerabilities through ‘no regrets’ type interventions.
#
# This is also important because impacts on humanitarian operations and the secondary impacts of the pandemic are also likely to have wide ranging humanitarian consequences beyond the direct health impacts of the disease. https://reliefweb.int/sites/reliefweb.int/files/resources/INFORM%20COVID%20Risk%20Index%20V012%20Report.pdf

# %%
px.bar(df, x = 'Covid_19_Vulnerability', y = 'Demographic_and_Co_morbidities', color = 'Access_to_Cities',orientation='h' , title='Covid-19 Vulnerability & Comorbidities',  height = 500 )

# %%
px.bar(df, x = 'Covid_19_Vulnerability', y = 'Proportion of ever-partnered women and girls subjected to physical and/or sexual violence by a current or former intimate partner in the previous 12 months (18-49)', color = 'Attitudes_towards_violence',orientation='h' , title='Covid-19 Vulnerability & Violence against Women',  height = 500 )

# %%
fig = px.bar(df1, 
             x='Covid19_Lack_of_coping_capacity', y='Maternal_Mortality_ratio', color_discrete_sequence=['darksalmon'],
             title='Covid19 Lack of Coping Capacity & Maternal Mortality', text='Health system capacity')
fig.show()

# %% [markdown]
# #Covid-19 Vulnerability: Movement (25%), Behaviour (25%), Demographic and Comorbidities (50%).
#
# MOVEMENT (25%)
#
# International movement: Air transport, passengers carried;; International tourism, number of arrivals;; Point of entry.
#
# Internal movement: Access to Cities;; Road density.
#
# BEHAVIOUR (25%)
#
# Awareness: Adult literacy rate;; Mobile cellular subscriptions;; Internet users.
#
# Trust
#
# DEMOGRAPHIC AND COMORBIDITIES (50%)
#
# Proportion of the population at increased risk of severe COVID-19 disease: 1+ underlying conditions plus 0 conditions (65+ yrs). https://reliefweb.int/sites/reliefweb.int/files/resources/INFORM%20COVID%20Risk%20Index%20V012%20Report.pdf

# %%
plt.figure(figsize=(20,4))
plt.subplot(131)
sns.countplot(x= 'Air_transport_passengers_carried', data = df, palette="GnBu_d",edgecolor="black")
plt.subplot(132)
sns.countplot(x= 'Point_of_entry', data = df, palette="flag",edgecolor="black")
plt.xticks(rotation=45)
plt.subplot(133)
sns.countplot(x= 'Road_density', data = df, palette="Greens_r",edgecolor="black")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(20,4))
plt.subplot(131)
sns.countplot(x= 'Adult_literacy_rate', data = df, palette="PuRd",edgecolor="black")
plt.subplot(132)
sns.countplot(x= 'Mobile_cellular_subscriptions', data = df, palette="cividis",edgecolor="black")
plt.xticks(rotation=45)
plt.subplot(133)
sns.countplot(x= 'Internet_usres', data = df, palette="rainbow",edgecolor="black")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #Vulnerability in countries from different income groups
#
# The Vulnerability dimension of the INFORM COVID Risk Index requires a specific analysis.
#
# The two sub-dimensions, COVID-specific vulnerability (e.g. age, comorbidities, movement) and hazard-independent vulnerability (broad vulnerability to all hazards e.g. poverty, inequality, food insecurity, insecure living conditions) are negatively correlated (cc -0.7). In other words, countries with high COVID-specific vulnerability generally have low broader vulnerability.
#
# COVID-specific vulnerability and hazard-independent Vulnerability contribute similarly to the overall Vulnerability (cc 0.31 vs 0.44). But when you look at income groups or regions the results are different.
#
# For High income countries and Europe only the COVID-specific vulnerability is important (cc 0.95, cc 0.97), while in Lower and Lower-middle Income countries and Africa, the opposite is true (cc 0.11, cc 0.01).
# https://reliefweb.int/sites/reliefweb.int/files/resources/INFORM%20COVID%20Risk%20Index%20V012%20Report.pdf

# %%
plt.figure(figsize=(20,4))
plt.subplot(131)
sns.countplot(x= 'Gini_Index', data = df, palette="binary",edgecolor="black")
plt.xticks(rotation=45)
plt.subplot(132)
sns.countplot(x= 'Inequality', data = df, palette="Spectral",edgecolor="black")
plt.xticks(rotation=45)
plt.subplot(133)
sns.countplot(x= 'Food Security', data = df, palette="Wistia",edgecolor="black")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #The impact of Covid-19 on people experiencing poverty and vulnerability, study conducted by Graciela Malgesini
#
# EAPN EU Inclusion Strategies Group/EAPN ES, with the participation of 25 national networks (AT, BE, HR, CZ, DK, FI, FR, DE, EL, HU, IC, IE, IT, LT, NL, MA, NO, PL, PT, SB, SE, SK, SL, ES, UK) and 3 European Organisations (SMES, IFSW and Age-Platform).
#
# SHORT-TERM RECOMMENDATIONS
#
# Urgent and coordinated health action, Urgent action to protect workers and ensure adequate income for all, Urgent action to protect people at risk of poverty, Action to mitigate the social impact of containment measures on social isolation and loneliness.
#
# MID-TERM RECOMMENDATIONS
#
# Embed poverty and social impact assessment, Reinforce quality public health and social care services;; Prioritise adequate minimum income and social protection;; Protect employment, prevent precarious work and revalue front-line work;; Ensure that poor and vulnerable groups do not pay through austerity measures.
#
# LONG-TERM RECOMMENDATIONS - an EU Action for a Social and Green Recovery
#
# Adopt an overarching EU social and sustainable strategy, with ending poverty a pre-requisite.;; Agree an integrated EU antipoverty strategy, as goal and framework for the European Pillar of Social Rights Action Plan;; Implement a comprehensive assessment of the impact of COVID-19 on poverty and equality in the EU, with guidance for MS Establish “strong and balanced” coordination throughout the European Semester.;; Make progress on obligatory rights and the European commitment to guarantee adequate income.;; Ensure that the EU recovery plan benefits the poor and vulnerable, with 30% of ESF+ ;; Ensure meaningful participation of people experiencing poverty and civil society organisations, implementing these changes in the Employment Guidelines.;; End the era of austerity in Europe, and use taxation to help pay the costs of rescue and recovery packages. https://www.eapn.eu/the-impact-of-covid-19-on-people-experiencing-poverty-and-vulnerability-eapn-report/

# %%
fig = px.bar(df1, 
             x='Covid19_Lack_of_coping_capacity', y='Corruption_Perception_Index', color_discrete_sequence=['darkseagreen'],
             title='Covid19 Lack of Coping Capacity & Corruption', text='Governance')
fig.show()

# %% [markdown]
# #Categorical features(handling missing data)

# %%
# categorical features
categorical_feat = [feature for feature in df1.columns if df1[feature].dtypes=='O']
print('Total categorical features: ', len(categorical_feat))
print('\n',categorical_feat)

# %% [markdown]
# #The potential impact of vulnerability and coping capacity on the pandemic control of COVID-19
#
# Authors: Martin CS Wong; Jeremy YC Teoh;; Junjie Huang;; Sunny H Wong.
#
# Published:May 28, 2020     DOI:https://doi.org/10.1016/j.jinf.2020.05.060
#
#
#
# #Reducing vulnerability and enhancing capacity to cope
#
# Findings imply that reducing vulnerability and enhancing capacity to cope could potentially mitigate the COVID-19 pandemic. Since the components of the two predictor variables are modifiable, countries that aim to increase their capability to combat the COVID-19 pandemics could make reference to the detailed subcategories under these two dimensions.
#
# The government could consider to take active steps in enhancing the resilience of the society and availability of measures that could protect the vulnerable population. Limitations of the study: There may be other confounders that could not be controlled for, including personal behaviour and the stringency of Governmental policies, such as measures related to social distancing, school closure, supply of personal protective equipment (PPE), as well as quarantine and containment strategies.
#
# In addition, the COVID-19 vulnerability used was developed in 2018, and they assumed that the index of each country did not change before the beginning of the pandemic in 2019. Also, the authors emphasized that these are preliminary findings, and the cause-and-effect relationships are yet to be further examined by larger-scale studies. https://www.journalofinfection.com/article/S0163-4453(20)30337-6/fulltext

# %%
# categorical features with missing values
categorical_nan = [feature for feature in df1.columns if df1[feature].isna().sum()>1 and df1[feature].dtypes=='O']
print(categorical_nan)

# %%
df1[categorical_nan].isna().sum()

# %%
# replacing missing values in categorical features
for feature in categorical_nan:
    df1[feature] = df1[feature].fillna('None')

# %% [markdown]
# #Vulnerability, Risk, Resilience and Coping Capacity - Authors: B. Sungay, E. Cakti & M. Erdik
#
# Those terms have been used in a variety of manners in literature.
# In their Pressure and Release Model that has first been introduced in 1994, Wisner et al (2004) suggest to interpret risk as a function of hazards and vulnerability that is caused by various conditions authors present. In this model, lack of conditions that build resiliency is also taken into consideration besides conditions that increase vulnerability. Authors underline the need of a multidisciplinary evaluation of the term risk, and suggest to cover socio-economic fragility and lack of resilience as aggravating factors besides physical risk.
#
# Billing and Madengruber (2006) mention that coping capacity is a key concept in vulnerability assessments. They relate vulnerability and coping capacity as two sides of the same coin. They developed a model to compare coping capacity of the countries. The index they propose, consist of four main indicators; the level of institutional preparedness, level of mitigation measures taken, number of IFRC volunteers, and modified UNDP Disaster Risk Index as a composite indicator, for each country. https://www.iitk.ac.in/nicee/wcee/article/WCEE2012_2508.pdf

# %%
df1[categorical_nan].isna().sum()

# %% [markdown]
# #Label Encoding & Hot Encode (dummies)

# %%
from sklearn.preprocessing import LabelEncoder
categorical_col = ('COUNTRY', 'ISO3', 'Corruption_Perception_Index', 'Government Effectiveness', 'Governance', 'INFORM Institutional', 'Physicians Density', 'Hospital bed', 'Health system capacity', 'Proportion of the target population with access to 3 doses of diphtheria-tetanus-pertussis (DTP3) (%)', 'Proportion of the target population with access to measles-containing-vaccine second-dose (MCV2) (%)', 'Proportion of the target population with access to pneumococcal conjugate 3rd dose (PCV3) (%)', 'Immunization_coverage', 'per capita public and private expenditure on health care', 'Maternal_Mortality_ratio', 'Access to health care Index', 'INFORM Infrastructure', 'IHR', 'Operational readiness index', 'Health_capacity_specific_to_Covid19', 'Covid19_Lack_of_coping_capacity')
        
        
for col in categorical_col:
    label = LabelEncoder() 
    label.fit(list(df1[col].values)) 
    df1[col] = label.transform(list(df1[col].values))

print('Shape all_data: {}'.format(df1.shape))

# %%
# Hot-Encode Categorical features
df1 = pd.get_dummies(df1)

# %%
plt.figure(figsize = (10,6))
sns.lineplot(data=df1, x="Covid19_Lack_of_coping_capacity", y="IHR", color='r', marker='*')
plt.title("Covid19 Lack of Coping Capacity & IHR",fontweight='bold',size=20)
plt.xlabel('Covid19_Lack_of_coping_capacity',size=15)
plt.ylabel('International Health Regulations (IHR)',size=15)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize = (10,6))
sns.lineplot(data=df1, x="Covid19_Lack_of_coping_capacity", y="Immunization_coverage", color='b', marker='*')
plt.title("Covid19 Lack of Coping Capacity & Immunization",fontweight='bold',size=20)
plt.xlabel('Covid19_Lack_of_coping_capacity',size=15)
plt.ylabel('Immunization Coverage',size=15)
plt.xticks(rotation=45)
plt.show()

# %%
#Let's visualise immunization
immunization = df1.groupby('Immunization_coverage').sum()[['Proportion of the target population with access to pneumococcal conjugate 3rd dose (PCV3) (%)', 'Proportion of the target population with access to measles-containing-vaccine second-dose (MCV2) (%)', 'Proportion of the target population with access to 3 doses of diphtheria-tetanus-pertussis (DTP3) (%)']]
#evolution['Expiration Rate'] = (evolution['Expired'] / evolution['Cumulative']) * 100
#evolution['Discharging Rate'] = (evolution['Discharged'] / evolution['Cumulative']) * 100
immunization.head()

# %%
plt.figure(figsize=(20,7))
plt.plot(immunization['Proportion of the target population with access to pneumococcal conjugate 3rd dose (PCV3) (%)'], label='Proportion of the target population with access to pneumococcal conjugate 3rd dose (PCV3) (%)')
plt.plot(immunization['Proportion of the target population with access to measles-containing-vaccine second-dose (MCV2) (%)'], label='Proportion of the target population with access to measles-containing-vaccine second-dose (MCV2) (%)')
plt.plot(immunization['Proportion of the target population with access to 3 doses of diphtheria-tetanus-pertussis (DTP3) (%)'], label='Proportion of the target population with access to 3 doses of diphtheria-tetanus-pertussis (DTP3) (%)')
plt.legend()
#plt.grid()
plt.title('Immunization coverage')
plt.xticks(immunization.index,rotation=45)
plt.xlabel('Immunization Coverage')
plt.ylabel('Count')
plt.show()

# %%
#What about immunization
plt.figure(figsize=(20,7))
plt.plot(immunization['Proportion of the target population with access to 3 doses of diphtheria-tetanus-pertussis (DTP3) (%)'], label='Proportion of the target population with access to 3 doses of diphtheria-tetanus-pertussis (DTP3) (%)')
plt.legend()
#plt.grid()
plt.title('Immunization Coverage')
plt.xticks(immunization.index,rotation=45)
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #Code by Ashaab Rizvi https://www.kaggle.com/ashaabrizvi/fifa-eda-seaborn/notebook

# %%
#Code by Ashaab Rizvi https://www.kaggle.com/ashaabrizvi/fifa-eda-seaborn/notebook

plt.figure(dpi=125)
x=df1.head(20)['Covid19_Lack_of_coping_capacity']
y=df1.head(20)['Government Effectiveness']

sns.regplot(x,y)
plt.title('Covid19 Lack of Coping Capacity Vs Government Effectiveness')
plt.xlabel('Covid19 Lack of Coping Capacity')
plt.ylabel('Government Effectiveness')
plt.show()

# %%
#Code by Ashaab Rizvi https://www.kaggle.com/ashaabrizvi/covid-19-plotly-tutorial
# Scatter Plot in Plotly
fig = go.Figure(data=go.Scatter(x=df1['Covid19_Lack_of_coping_capacity'],y=df1['per capita public and private expenditure on health care'],mode='markers',marker=dict(size=10,color=df1['IHR'],showscale=True),text=df1['Government Effectiveness']))
fig.update_layout(title='Covid19 Coping Capacity & Expenditure on Health Care',xaxis_title='Covid19 Lack of Coping Capacity',yaxis_title='Expenditure on Health Care')

fig.show()

# %%
#Code by Ashaab Rizvi https://www.kaggle.com/ashaabrizvi/fifa-eda-seaborn/notebook

sns.relplot(x='Covid19_Lack_of_coping_capacity',y='Government Effectiveness',hue='Corruption_Perception_Index',palette = 'viridis',size="Health system capacity", sizes=(15, 200),aspect=2.5,data=df1)
plt.title('Covid19 Lack of Coping Capacity & Government Effectiveness',fontsize = 20)
plt.xlabel('Covid19 Lack of Coping Capacity')
plt.ylabel('Government Effectiveness')
plt.show()

# %%
#Code by anmorgul https://www.kaggle.com/anmorgul/strange-pattern-cottonwood-willow
for i in range(4,5):
    fig = px.scatter_3d(df1[df1['Covid19_Lack_of_coping_capacity'] == i], x='Proportion of the target population with access to 3 doses of diphtheria-tetanus-pertussis (DTP3) (%)', y='Proportion of the target population with access to measles-containing-vaccine second-dose (MCV2) (%)', z='Proportion of the target population with access to pneumococcal conjugate 3rd dose (PCV3) (%)',
                  color='Immunization_coverage', size_max=8, size='IHR', width=1000, height=800, opacity=0.9, template="plotly_dark")
    fig.update_layout(title="Covid19 Lack of Coping Capacity",font_size=16, legend_font_size=16,)
    fig.show()

# %%
x = df1.drop(['per capita public and private expenditure on health care', 'Health_capacity_specific_to_Covid19'], axis=1)
x.fillna(999999, inplace=True)
y = df1['Health_capacity_specific_to_Covid19']

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from graphviz import Source

dt = DecisionTreeClassifier(max_depth=3)

# %%
dt.fit(x, y)

# %%
dt_feat = pd.DataFrame(dt.feature_importances_, index=x.columns, columns=['feat_importance'])
dt_feat.sort_values('feat_importance').tail(8).plot.barh()
plt.show()

# %%
from IPython.display import SVG
os.environ["PATH"] += os.pathsep + 'C:/Program Files (x86)/Graphviz2.38/bin/'

graph = Source(export_graphviz(dt, out_file=None, feature_names=x.columns, filled = True))
display(SVG(graph.pipe(format='svg')))

# %% [markdown]
# #Conclusions
#
# VULNERABILITY AND CAPACITY TO COPE
#
# They are identified as two important aspects in the face of an infectious disease pandemic, and they bear a potential impact to mitigate the COVID-19 pandemic. Future studies should evaluate the specific components of these indices that exert the greatest impact on pandemic control. https://www.journalofinfection.com/article/S0163-4453(20)30337-6/fulltext
#
# IMMUNIZATIONS
#
# The essence of routine immunization is to prevent vaccine-preventable diseases. If you focus solely on COVID-19 and forget about other diseases, you create opportunities for more outbreaks to emerge" "The moment you lose sight of routine immunization you create serious problems in the health system"- Emmanuel Lansana. Read the interview here: https://bit.ly/3e8kiT9
#
# COVID-19 A NEW TB?
#
# It's a cruel silent violence that doesn't shock any more. There is no blood (like Ebola) and no corpses in front of us. The numbers grow steady and slowly. When it arrived to the poor communities the society loses interest in it. That's one reason for high income countries don't have any BCG policy or have immunization as mandatory, since they don't have many (or any) cases. And those are restrict to people in vulnerable conditions.

# %%
#Code by Olga Belitskaya https://www.kaggle.com/olgabelitskaya/sequential-data/comments
from IPython.display import display,HTML
c1,c2,f1,f2,fs1,fs2=\
'#3486eb','#3437eb','Akronim','Smokum',30,15
def dhtml(string,fontcolor=c1,font=f1,fontsize=fs1):
    display(HTML("""<style>
    @import 'https://fonts.googleapis.com/css?family="""\
    +font+"""&effect=3d-float';</style>
    <h1 class='font-effect-3d-float' style='font-family:"""+\
    font+"""; color:"""+fontcolor+"""; font-size:"""+\
    str(fontsize)+"""px;'>%s</h1>"""%string))
    
    
dhtml('Kaggle Notebook Runner: Marília Prata    @mpwolke' )
