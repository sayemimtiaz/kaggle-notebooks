# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSYkj7K3s8Zp0_i9UKBpbIMYvrp7M5lSWuUUI9AMx0u6nrDKu_O',width=400,height=400)

# %% [markdown]
# Image engadget.com - HDMI 2.1 is here with 10K and Dynamic HDR support

# %% [markdown]
# The sound is compressions and rarefactions in the air that an ear will pick up. The sound is a movement of air. Often expressed in a waveform, which shows what’s happening to air particles, moving back and forth over time. The vertical axis shows how the air is moving either backwards or forwards with respect to a zero position. The horizontal axis shows time. Explaining sound, sampling, Nyquist Theorem. The waveform of a sound looks like it’s moving up and down, but it’s moving back and forth. What am I missing? To be honest, I spent quite some time here to get my head around. It might be elementary Physics, but I didn’t pay much attention to Physics classes during my school years. I never imagined this will come back to haunt me. https://towardsdatascience.com/urban-sound-classification-part-1-99137c6335f9

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# Image medium.com

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
# UrbanSound8K.csv may have more rows in reality, but we are only loading/previewing the first 1000 rows
df = pd.read_csv('/kaggle/input/urbansound8k/UrbanSound8K.csv', delimiter=',', nrows = nRowsRead)
df.dataframeName = 'UrbanSound8K.csv'
nRow, nCol = df.shape
print(f'There are {nRow} rows and {nCol} columns')

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# Image github.com - Sound Classification using Neural Networks - https://github.com/AmritK10/Urban-Sound-Classification

# %%
df.head()

# %%
df.dtypes

# %%
appended = []
for i in range(1,11):
    appended.append(df[df.fold == i]['class'].value_counts())
    
class_distribution = pd.DataFrame(appended)
class_distribution = class_distribution.reset_index()
class_distribution['index'] = ["fold"+str(x) for x in range(1,11)]
class_distribution

# %%
df['class'].value_counts(normalize=True)

# %%
import os

import struct

from scipy.io import wavfile as wav

import matplotlib.pyplot as plt

import IPython.display as ipd



def path_class(filename):

    excerpt = df[df['slice_file_name'] == filename]

    path_name = os.path.join('UrbanSound8K/audio', 'fold'+str(excerpt.fold.values[0]), filename)

    return path_name, excerpt['class'].values[0]



def wav_plotter(full_path, class_label):   

    rate, wav_sample = wav.read(full_path)

    wave_file = open(full_path,"rb")

    riff_fmt = wave_file.read(36)

    bit_depth_string = riff_fmt[-2:]

    bit_depth = struct.unpack("H",bit_depth_string)[0]

    print('sampling rate: ',rate,'Hz')

    print('bit depth: ',bit_depth)

    print('number of channels: ',wav_sample.shape[1])

    print('duration: ',wav_sample.shape[0]/rate,' second')

    print('number of samples: ',len(wav_sample))

    print('class: ',class_label)

    plt.figure(figsize=(12, 4))

    plt.plot(wav_sample) 

    return ipd.Audio(full_path)

# %%
#fullpath, label = path_class('kaggle/input/urbansound8k/fold4/131428-9-1-19.wav')
#wav_plotter(fullpath,label)

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/png;base64,...',width=400,height=400)

# %% [markdown]
# Image towardsdatascience.com - Urban Sound Classification — Part 1: sound wave, digital audio signal - https://towardsdatascience.com/urban-sound-classification-part-1-99137c6335f9

# %%
df["salience"].plot.hist()
plt.show()

# %%
df["classID"].plot.box()
plt.show()

# %%
sns.pairplot(df, x_vars=['classID'], y_vars='salience', markers="+", size=4)
plt.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRvBRM08JJ_S3T3fbLR4GqMVyOInv2Uk6NZVRUf1GCTpC2XDQwH',width=400,height=400)

# %% [markdown]
# Image morioh.com

# %%
dfcorr=df.corr()
dfcorr

# %%
sns.heatmap(dfcorr,annot=True,cmap='winter')
plt.show()

# %%
# Importing requests, BeautifulSoup and nltk
import requests
from bs4 import BeautifulSoup
import nltk
from nltk.stem import WordNetLemmatizer 
print('Done!')

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/png;base64,...',width=400,height=400)

# %% [markdown]
# Image researchgate.net - Accuracy (%) results for the Urban Sounds 8k dataset with random CNN feature vectors of length ≈ 120.

# %%
import codecs

wav = codecs.open("../input/urbansound8k/fold10/73524-0-0-5.wav", 'r', 'utf-8')
print('Done!')

# %% [markdown]
# I'm DONE!  Not this Kaggle Notebook.

# %%
sub = pd.read_csv('/kaggle/input/urbansound8k/UrbanSound8K.csv', delimiter=',', nrows = nRowsRead)
sub.to_csv('sub.csv', index = False)

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcT3_mxZPIY-wpXXODorwYu_M4sDjTAf0B2nTZ_pjWgGH4XGgcW8',width=400,height=400)

# %% [markdown]
# # Codes by Ricky Kim
# The Rickest Ricky. Love data, beer, coffee, and good memes in no particular order.https://towardsdatascience.com/urban-sound-classification-part-1-99137c6335f9

# %% [markdown]
# Kaggle Notebook Runner: Marília Prata  @mpwolke
