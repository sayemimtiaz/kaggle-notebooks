# %% [markdown]
# #Nepal reports its fifth Covid-19 death and 156 new cases; national tally crosses 1,000
#
#
# Nepal on Thursday confirmed its fifth Covid-19 death and 156 new cases. The country’s Covid-19 tally now has reached 1,042.
#
# “The patient was admitted to the hospital on May 24,2020 and tested positive for the coronavirus the following day,” “The patient was suffering from liver disease.” The ministry also said 156 new cases were confirmed in 19 districts.
#
# According to the ministry, samples of 29 individuals from Dhanusha, 25 from Jhapa, 20 from Rautahat, 17 from Mahottari, 14 each from Saptari Surkhet, eight from Dailekh, seven from Sarlahi, six from Siraha, three each from Syangja and Bardiya, two each from Dolakha Kailali and one each from Nawalparasi (East), Solukhumbu, Darchula, Makwanpur, Bajhanag and Banke tested positive for Covid-19.
# Nepal recorded 114 new Covid-19 cases on Wednesday, 90 cases on Tuesday and 79 cases Monday.
# According to the Health Ministry, the coronavirus infection has so far been reported in 51 districts. https://kathmandupost.com/national/2020/05/28/nepal-reports-its-fifth-covid-19-death-and-156-new-cases-national-tally-crosses-1-000

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSo-KT7jvmZ207b8_Mo7n7pko50Hcz991weog&usqp=CAU)
#
# reliefweb.int

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('../input/hackathon/task_2-COVID-19-death_cases_per_country_after_fifth_death-till_26_June.csv')
df.tail()

# %% [markdown]
# #Code from Niraj https://www.kaggle.com/nirajpoudel/how-has-nepal-been-using-fertilizers/notebook

# %%
data_nepal = df[(df['country_name']=='Nepal')].reset_index(drop=True)
data_nepal.head()

# %%
fig = go.Figure(data=[go.Bar(
            x=df['date_fifth_death'][0:10], y=df['country_name'][0:10],
            text=df['country_name'][0:10],
            textposition='auto',
            marker_color='red',
 
        )])
fig.update_layout(
    title='Date 5th Covid19 death case',
    xaxis_title="date_fifth_death",
    yaxis_title="Country",
    template='plotly_dark'
)
fig.show()

# %% [markdown]
# #Codes from Siddharth Agarwal  https://www.kaggle.com/siddharth2000/indiafertilizeruse

# %%
plt.style.use('fivethirtyeight')
df.plot(subplots=True, figsize=(4, 4), sharex=False, sharey=False)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.lineplot(x='date_fifth_death', y='deaths_per_million_85_days_after_fifth_death', data=df)

# %%
plt.figure(figsize=(6,6))
sns.lineplot(x='date_fifth_death', y='deaths_per_million_60_days_after_fifth_death', data=df)

# %%
plt.figure(figsize=(6,6))
sns.lineplot(x='date_fifth_death', y='deaths_per_million_40_days_after_fifth_death', data=df)

# %%
plt.figure(figsize=(4,4))
sns.lineplot(x='date_fifth_death', y='deaths_per_million_25_days_after_fifth_death', data=data_nepal)

# %%
plt.figure(figsize=(8,8))
plot = sns.barplot(x="deaths_per_million_25_days_after_fifth_death", y="date_fifth_death", data=df)
plot.set_xticklabels(plot.get_xticklabels(), rotation=90, horizontalalignment='center')
plot.plot()

# %%
ls ../input/hackathon/task_1-google_search_txt_files_v2/NP/

# %%
nepal = pd.read_table("../input/hackathon/task_1-google_search_txt_files_v2/NP/Nepal-en-result-110-original.txt")

# %%
nepal.head()

# %%
nepal = nepal.rename(columns={'Nepal: WHO and UNICEF estimates of immunization coverage: 2018 revision':'immunization'})

# %%
lookup_name = dict(zip(nepal.immunization.unique(),nepal.immunization.unique()))

# %%
lookup_name

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQm2vOQn7t-1rGBRRdn4ZugnUQ8RLTvtLF5wQ&usqp=CAU)
#
# youtube.com

# %% [markdown]
# Das War's Kaggle Notebook Runner: Marília Prata @mpwolke
