# %% [markdown]
# #Туберкульоз (лат. tuberculosis; або ТБ - скорочення від туберкульозна бактерія; заст. сухоти; рос. чахотка)
#
# поширене і у багатьох випадках летальне інфекційне захворювання з хронічним перебігом і частою багатосистемністю уражень. Трапляється як серед людей, так і серед тварин. Його спричинюють різні види мікобактерій, частіше за все Mycobacterium tuberculosis. Найчастіше патологічний процес локалізується в легенях (легеневий туберкульоз), також може уражати інші органи тіла (позалегеневий туберкульоз) — мозкові оболони, нирки, печінка, кістки, шкіра тощо. Передається повітряно-крапельним механізмом передачі інфекції, коли хворі на активний легеневий або гортанний туберкульоз кашляють, чхають або іншим чином виділяють слину у повітря. Велика частка випадків хвороби є субклінічними і латентними. Приблизно кожна 10-та латентна інфекція прогресує до активного процесу. https://uk.wikipedia.org/wiki/Туберкульоз

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTjcjUnj346Z0powOd3uoRHcCso9I0ujR3JkHRCbf9izoibQ7JV&usqp=CAU',width=400,height=400)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
ls ../input/hackathon/task_1-google_search_txt_files_v2/UA/

# %% [markdown]
# #Codes from Igor Krasovskiy  https://www.kaggle.com/mykras/marking-up-for-ukrainian/notebook

# %%
files = ['/kaggle/input/hackathon/task_1-google_search_txt_files_v2/out/txt/UA/Ukraine-uk-result-6.txt']
files

# %%
# !pip install tokenize_uk
# !pip install utils
# !pip install colorama
# !pip install pigeon-jupyter

# %%
import tokenize_uk
for src_file in files:
    with open(src_file, 'rb') as f:
        data = f.read()
    text = data.decode('utf-8')
    tokens_text = tokenize_uk.tokenize_sents(text)
tokens_text

# %%
len(tokens_text)

# %%
tokens_text[:5]

# %% [markdown]
# I don't know ukrainian, therefore I choose a word that seems to be TB (tuberculosis). Туберкульоз (лат. tuberculosis)

# %%
#
from pigeon import annotate
annotations = annotate(
tokens_text[:25],
options=['туберкульоз', 'tuberculosis']
)

# %%
df = pd.DataFrame(annotations, columns=['UA', 'tuberculosis'])
df

# %%
def clean_text(text):
  text = str(text)
  text = re.sub(r'[0-9"]', '', text)
  text = re.sub(r'#[\S]+\b', '', text)
  text = re.sub(r'@[\S]+\b', '', text)
  text = re.sub(r'https?\S+', '', text)
  text = re.sub(r'\s+', ' ', text)
  return text.strip()
df['UA'] = df['UA'].apply(lambda x: clean_text(x))
df

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQKgigWSUzwIPwRpqDrNYcobcM7p-X3xwEwneFfNRuV9D5Z0VlS&usqp=CAU',width=400,height=400)

# %% [markdown]
# World Health Organization Ukraine - 18 de setembro de 2019
# ·
# The bacteria that cause tuberculosis can develop resistance to the antimicrobial drugs used to cure the disease. Multidrug-resistant TB is TB that does not respond to at least isoniazid and rifampicin, two most powerful anti-TB drugs.
#
# Ukraine ranks fourth in the world in the number of cases of multidrug-resistant tuberculosis. According to WHO, 28% of new cases and 48% of tuberculosis re-treatment cases in Ukraine are found to be resistant to anti-TB drugs. https://www.facebook.com/WHOUkraine/photos/a.282367355213296/2415402068576470/?type=3

# %% [markdown]
# Kaggle Notebook Runner: Marília Prata  @mpwolke
