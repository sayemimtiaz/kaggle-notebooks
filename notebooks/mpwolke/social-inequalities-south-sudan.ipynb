# %% [markdown]
# #The State must play a bigger role than before the pandemic, by Ruan de Sousa Gabriel
#
# The economist Branko Milanovic notes that the health crisis exposed the inability of governments to help the poorest populations.
#
# One of the most respected scholars of inequality and income distribution in the world, the Serbian Branko Milanović author of: "Capitalism without rivals: the future of the world-dominating system", In this interview, Milanović says that while globalization may be affected by the coronavirus pandemic, capitalism's development trends tend to continue. It also notes that the crisis caused by the disease has increased social inequalities, exposing the inability of governments to help the poorest populations. The moment, he believes,it offers an opportunity for the left, "because it is necessary for the state to play a greater role than before".
#
# #What have we learned from the pandemic?
#
# We are still learning, because the pandemic is not over yet. We learned that most countries - rich and poor - were unprepared to face the pandemic. The United States reacted especially badly. Virtually all Asian countries - democratic and non-democratic - have done a much better job than European countries. No one died of coronavirus in Vietnam. There have been very few deaths in Thailand. Taiwan, Japan and South Korea did very well. We must ask ourselves if there is anything we can learn from Asian countries. The pandemic also showed and has been showing that health systems were not prepared for the pandemic after so much austerity, lack of investment and privatization.
#
# #Why were Asian countries better prepared?
#
# Hard to know. One reason is perhaps because they had to deal with the SARS (Severe Acute Respiratory Syndrome) epidemic, which did not affect Western countries much. Asian governments, those that are and those that are not democratic, tend to be more technocratic and act more quickly. The Asian population also trusts governments more and is more willing to follow the guidelines of social isolation. A disciplined population helps.
#
# #Will the pandemic make the world even more unequal?
#
# As the pandemic started in China six months ago, we already know that it mainly affected the poorest and the essential workers, who are most exposed to contamination. In the USA, it is very clear how the poorest people are most affected. In fact, one of the effects of the pandemic is an increase in inequality, which can easily continue to increase in the coming months, because most of the people who lost their jobs were already less skilled and low-income.https://translate.google.com.br/translate?hl=en&sl=pt&u=https://oglobo.globo.com/mundo/india-tem-quase-700-mil-casos-da-covid-19-e-terceiro-pais-mais-afetado-do-mundo-1-24518158&prev=search&pto=aue

# %% [markdown]
# ![](https://ogimg.infoglobo.com.br/in/24513143-f15-1d4/FT1086A/652/x88480642_Children-from-a-slum-stand-in-queue-to-get-free-food-after-the-government-eased-anati.jpg.pagespeed.ic.d47uZv2Ne-.jpg)
# Children from a slum in New Delhi, India, line up to receive food: pandemic deepened social inequalities around the world Photo: PRAKASH SINGH / AFP

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.offline as py
import plotly.graph_objs as go
import plotly.offline as py
import plotly.express as px

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
ls ../input/hackathon/task_1-google_search_txt_files_v2/SS/

# %%
df1 = pd.read_table("/kaggle/input/hackathon/task_1-google_search_txt_files_v2/SS/South Sudan-en-result-117-original.txt",header=None)
df1.head()

# %%
print(df1[:2500])

# %%
df = pd.read_csv('../input/hackathon/task_2-Tuberculosis_infection_estimates_for_2018.csv', encoding='utf8')
df.head()

# %%
sudan = df[(df['country']=='South Sudan')].reset_index(drop=True)
sudan.head()

# %% [markdown]
# #TB Preventive Therapy
#
# The Use of Preventive Therapy for Tuberculous Infection in the United States Recommendations of the Advisory Committee for Elimination of Tuberculosis
#
# The appropriate use of preventive therapy played a crucial role in efforts to eliminate tuberculosis in the United States by the year 2010. When taken as prescribed, isoniazid preventive therapy is highly effective in preventing latent tuberculous infection from progressing to clinically apparent disease. In controlled trials conducted by the Public Health Service in ordinary clinical and public health settings, isoniazid preventive therapy reduced the incidence of disease by 54 per cent-88 per cent. The main reason for the variation in efficacy appears to have been the amount of medication actually taken during the year in which isoniazid was prescribed. In a trial conducted in eastern Europe among infected adults with abnormal chest radiographs, a 12-month course of isoniazid preventive therapy was 75 per cent effective among all persons assigned to the regimen and 93 per cent effective among those who were compliant with therapy. Similarly, isoniazid preventive therapy was estimated to be 98 per cent effective among children in Houston and in recently infected nursing home patients who were compliant with therapy. Isoniazid preventive therapy has been shown to be effective for long periods and to be reasonably cost-effective. https://www.cdc.gov/mmwr/preview/mmwrhtml/00001643.htm

# %%
ax = sudan['e_prevtx_eligible'].value_counts().plot.barh(figsize=(14, 6))
ax.set_title('TB Preventive Therapy', size=18)
ax.set_ylabel('e_prevtx_eligible', size=14)  
ax.set_xlabel('count', size=14)

# %% [markdown]
# #Why is Isoniazid prescribed?
#
# Isoniazid is used with other drugs to treat tuberculosis (TB; a serious infection that affects the lungs and sometimes other parts of the body). Isoniazid is also used with other drugs to treat people with latent (resting or nongrowing) TB including those in close contact with people who have active TB, a positive tuberculin skin test, human immunodeficiency virus (HIV), and those with pulmonary fibrosis (scarring of the lungs with an unknown cause). Isoniazid is in a class of medications called antituberculosis agents. It works by killing the bacteria that cause tuberculosis.https://medlineplus.gov/druginfo/meds/a682401.html

# %%
df2 = pd.read_csv('../input/hackathon/task_2-owid_covid_data-21_June_2020.csv')
df2.head()

# %%
Sudan = df2[(df2['location']=='South Sudan')].reset_index(drop=True)
Sudan.head()

# %% [markdown]
# #The 20 countries with the lowest gross domestic product (GDP) per capita in 2019 - Published by H. Plecher, Jun 2, 2020
#
# In 2019, `South Sudan once again reported the lowest per-capita GDP ever`, closely-followed by Burundi and Malawi. All three countries struggle economically, because of poorly developed infrastructure and a low standard of living.
#
#
# #GDP per capita as an indicator
#
# A country’s gross domestic product, often referred to as GDP for short, is a means to measure the market value of goods and services a country has produced over a certain period of time. It is an important key indicator for a country’s economic status and development. GDP per capita is the breakdown of GDP to the country’s total population, showing how much each of the inhabitants have theoretically obtained. GDP per capita is a popular measure of the standard of living, prosperity, and overall well-being in a country. A high GDP per capita indicates a high standard of living, a low one indicates that a country is struggling to supply its inhabitants with everything they need. https://www.statista.com/statistics/256547/the-20-countries-with-the-lowest-gdp-per-capita/

# %%
ax = Sudan['gdp_per_capita'].value_counts().plot.barh(figsize=(14, 6))
ax.set_title('GDP per capita', size=18)
ax.set_ylabel('gdp_per_capita', size=14)  
ax.set_xlabel('count', size=14)

# %% [markdown]
# #GDP per capita in South Sudan
#
# South Sudan’s 13 million inhabitants have been struggling with severe poverty, high death rates, civil wars, and violence for years now, and their standard of living is respectively low. Today, the country relies heavily on agriculture with the majority living in rural areas, but violence, the lack of food, and inefficient water supply often cause famine and illnesses. Since South Sudan thus cannot produce and export goods efficiently and sufficiently, GDP per capita does not even reach four-figure levels, despite a quite low number of inhabitants. NGOs and government agencies are trying to improve their situation by offering funding and education, but significant improvement has yet to be seen. https://www.statista.com/statistics/256547/the-20-countries-with-the-lowest-gdp-per-capita/

# %%
fig = px.bar(Sudan, 
             x='gdp_per_capita', y='life_expectancy', color_discrete_sequence=['#27F1E7'],
             title='South Sudan GDP per capita vs. Life expectancy', text='total_cases')
fig.show()

# %% [markdown]
# #Country profile: The impact of COVID-19 on stability and the peace process in South Sudan, by Neyma Mildred Mahomed Ali
#
# The first confirmed case of COVID-19 was recorded on 5 April 2020. Two months later, there are 1 604 confirmed cases, with 15 recovered and 19 deaths. In response to the first case, a COVID-19 National Task Force was established to coordinate a government-wide response to the pandemic. A nationwide curfew was put in place, the borders were closed and restrictions were imposed on interstate travel.
#
# One of the ways in which COVID-19 had a negative impact on the implementation of the peace process was felt when the government decided to suspend the training of the unified forces as a precautionary measure – a decision that affected 29 000 combatants.
#
# One of the challenges facing South Sudan in its efforts to contain the spread of COVID-19 is its porous borders. Cross-border control and surveillance mechanisms have been increased in an attempt to reduce the illegal crossing of traders, especially along the country’s borders with the Democratic Republic of the Congo (DRC) and Uganda. Isolation centres have been established to quarantine those found to have illegally crossed the border. Instability in neighbouring countries is also resulting in refugees moving into South Sudan.https://www.accord.org.za/analysis/impact-of-covid-19-on-stability-and-the-peace-process-in-south-sudan/

# %%
fig = px.bar(Sudan, 
             x='gdp_per_capita', y='cvd_death_rate', color_discrete_sequence=['crimson'],
             title='Covid19 Death Rate vs. GDP per Capita', text='life_expectancy')
fig.show()

# %% [markdown]
# The spread of COVID-19 in South Sudan is adding further stress to existing humanitarian challenges. Before the advent of COVID-19, the sub-region suffered from an invasion of locusts, and projections then were that 5.5 million South Sudanese would go hungry without humanitarian assistance. The situation is compounded by the escalation of local community violence in certain parts of the country, with 450 incidents recorded between January and May 2020. The closing of borders to stem the spread of the virus has also created shortages of basic goods in some border areas between South Sudan and Sudan.
#
# As a result of these shortages, and with South Sudan being a landlocked country, the government decided to reopen the country’s airspace. The economic outlook was worsened by the drop in global crude oil prices, which is the biggest generator of revenue for the government, accounting for 98 per cent of the state’s budget. However, the World Bank last month approved a grant of USD40 million to provide income security to the most vulnerable households. https://www.accord.org.za/analysis/impact-of-covid-19-on-stability-and-the-peace-process-in-south-sudan/

# %%
fig = px.line(Sudan, x="gdp_per_capita", y="total_cases_per_million", color_discrete_sequence=['darkseagreen'], 
              title="GDP per Capita vs. Total Cases per Million")
fig.show()

# %% [markdown]
# Although the overall number of confirmed cases is still relatively low, the spread of COVID-19 in South Sudan is raising concerns because of limited public health facilities, an already dire humanitarian situation, an increase in communal clashes and a fragile peace process. On the other hand, a youthful population and limited movement inside the country due to poor infrastructure may slow down and limit the spread of the disease. The city of Juba and other areas where people are living in close proximity, such as the POC sites administered by the UN, are high-risk areas that require heightened quarantine measures.https://www.accord.org.za/analysis/impact-of-covid-19-on-stability-and-the-peace-process-in-south-sudan/

# %% [markdown]
# ![](https://www.accord.org.za/wp-content/uploads/2020/06/accord-covid-19-infographic-10-jun-2020_4.png)
# Country profile: The impact of COVID-19 on stability and the peace process in South Sudan, by Neyma Mildred Mahomed Ali -
# accord.org.za https://www.accord.org.za/analysis/impact-of-covid-19-on-stability-and-the-peace-process-in-south-sudan/

# %% [markdown]
# Das War's Kaggle Notebook Runner: Marília Prata  @mpwolke
