# %% [markdown]
# Mike Honey: Cloned from [this notebook](https://www.kaggle.com/danielwolffram/cord-19-create-dataframe).
#
# Crashing with memory errors, so breaking into separate notebooks.  This one will just merge the pdf_json and metadata input data and write out the results.

# %% [markdown]
# # Load Packages

# %%
import numpy as np 
import pandas as pd

import gc
import json

# %% [markdown]
# # Load and Prepare Data

# %%
papers = pd.read_csv('../input/cord-19-create-dataframe-step-1-pdf-json-prep/pdf_json_df.csv')

# %%
root_path = '/kaggle/input/CORD-19-research-challenge/'
metadata_path = f'{root_path}/metadata.csv'
meta_df = pd.read_csv(metadata_path, dtype={
    'pubmed_id': str,
    'Microsoft Academic Paper ID': str, 
    'doi': str
})
meta_df.head(2)

# %%
df = pd.merge(papers, meta_df, left_on='paper_id', right_on='sha', how='right').drop('sha', axis=1)
del papers
del meta_df
gc.collect()

# %%
df.columns

# %% [markdown]
# # Export as .csv

# %%
df.to_csv('pdf_metadata_df.csv', index=False)
