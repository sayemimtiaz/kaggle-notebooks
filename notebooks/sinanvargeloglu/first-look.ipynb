# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
data1 = pd.read_csv("../input/tmdb-movie-metadata/tmdb_5000_credits.csv")
data2 = pd.read_csv("../input/tmdb-movie-metadata/tmdb_5000_movies.csv")

# %%
data1.info()

# %% [markdown]
# In order to make a first look about Data1, we performed the command data1.info. We were able to see the number of columns, headings, number of rows and data types.

# %%
data2.info()

# %% [markdown]
# This time we performed the command data1.info to get a first look at Data1. We were able to see the number of columns, headings, number of rows and data types.

# %%
data1.columns

# %%
data1.head(5)

# %% [markdown]
# We have seen the features of Data1 and the first 5 values. So I wanted to see if there was anything we could analyze.

# %%
data2.columns

# %%
data2.head(5)

# %% [markdown]
# I didn't get the headers I wanted from Data1. I did the same for Data2. When I'm reviewing what I can do for analysis, I assumed that vote_average, revenue, popularity and budget are good for analysis. This assumption was also important to see that there was a certain change in my review.

# %%
data2.corr()

# %% [markdown]
# I used it to make a clearer decision on our assumptions by looking at the correlation of Data2. As a result, the relationships between
#
# revenue - vote_count ;
# revenue - popularity ;
# revenue - budget ;
# popularity - vote_count
#
# should be examined.

# %%
data2.describe()

# %% [markdown]
# New production should be in the best quarter to be a good place in the eyes of the audience. So vote_average should be 6.8+.

# %%
plt.subplots(figsize=(15,12))
plt.scatter(data2.revenue,data2.vote_count,color='red')
plt.ylabel('Vote Count')             
plt.xlabel('Revenue')
plt.title('Revenue - Vote Count Plot')

# %% [markdown]
# In general, there is a correlation between the two values as it appears in the correlation. In general, as revenue increases, vote_count increases.

# %%
plt.subplots(figsize=(15,12))
plt.scatter(data2.revenue,data2.popularity,color='green')
plt.xlabel('Revenue')             
plt.ylabel('Popularity')
plt.title('Revenue - Popularity Plot')

# %% [markdown]
# In general, there is a correlation between the two values as it appears in the correlation. In general, as revenue increases, vote_count popularity.

# %%
plt.subplots(figsize=(15,12))
plt.scatter(data2.vote_count,data2.popularity,color='blue')
plt.xlabel('Vote Count')             
plt.ylabel('Popularity')
plt.title('Vote Count - Popularity Plot')

# %% [markdown]
# When we see the distribution between popularity and vote count values by taking out the value of revenue, it turns out that the two values usually affect each other. As the series become popular, the voting rate increases.

# %%
plt.subplots(figsize=(15,12))
plt.scatter(data2.revenue,data2.budget,color='purple')
plt.xlabel('Revenue')             
plt.ylabel('Budget')
plt.title('Revenue - Budget Plot')

# %% [markdown]
# It turns out that the amount invested in the relationship between Revenue and Budget is an important element of revenue.

# %% [markdown]
# **When we look at the correlation, it was seen that these factors were not sufficiently effective on the audience scores. First, let's look at the distribution of audience points.**

# %%
plt.subplots(figsize=(15,8))
plt.hist(data2.vote_average,bins = 100)
plt.ylabel('Frequency')
plt.xlabel('Vote Average')
plt.title('Vote Average Graphic Distribution')
plt.show()

# %% [markdown]
# When we examine the graph, we see that the movies averages are generally between 4.5-8.5.

# %% [markdown]
# **In the next series, we will analyze with vote average in order to remove the elements that need special attention.**

# %%
plt.subplots(figsize=(10,8))
plt.scatter(data2.vote_average,data2.budget,color='red')
plt.xlabel('Vote Average')             
plt.ylabel('Budget')
plt.title('Vote Average - Budget Plot')
plt.show()

# %% [markdown]
# The graph shows that the movies with a budget over 1.5 million are on the general voting scale of the users.

# %%
x = data2['budget']>3000000
data2[x]
#plt.scatter(data2.vote_average,x,color='blue')

# %% [markdown]
# When analyzed specifically, our assumption appears to be correct.

# %%
plt.subplots(figsize=(20,16))
plt.scatter(data2.vote_average,data2.revenue,color='green')
plt.xlabel('Vote Average')             
plt.ylabel('Revenue')
plt.title('Vote Average - Revenue')
plt.show()

# %% [markdown]
# In this analysis, it is not possible to decide exactly which value to target for increasing earnings.

# %% [markdown]
# **As a result, it is seen that as the amount of investment increases, income generally increases. Popularity is an important short. With popularity, people's rating rates increase. It is generally seen that earnings increase with increasing popularity. Popular production should be preferred instead of successful production. Investment-earnings and popularity should be considered in new movies.**
