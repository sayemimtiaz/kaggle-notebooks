# %%
# SEC 201 : Notebook d'Andrés Delgado
# ML Anomaly Detection

# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Le TP commence ici
# 4. Data Set Observation
df = pd.read_csv('../input/unsw-nb15/UNSW_NB15_training-set.csv')

#print('Column number : ' + str(df.columns.size))
#print('Column names : ')
#print(df.columns)
#print('Column types:')
#print(df.dtypes)
#print('Size of the data set :' + str(len(df)))

# 5. Look at the file head : on voit les 5 premières lignes du fichier, avec toutes ses colonnes
## C'est ici qu'on peut apprécier les caractéristiques du CSV et commencer à le caractériser

#df.head();

#6. Les colonnes de type 'categories'
#print(df.dtypes[df.dtypes == 'object'].index)

# Les colonnes de type categorie sont
#'proto', 
#'service',
#'state',
#'attack_cat'

# Ce code sert à extraire les données uniques des categories, 
# Sans pour autant les avoir par ligne.

#for category in df.dtypes[df.dtypes == 'object'].index:
#    print(category)
#    print(list(set(df[category])))

# 7. Numeric data columns
# newdf = df._get_numeric_data()
# print(newdf.columns)
# Numeric columns
# Index(['id', 'dur', 'spkts', 'dpkts', 'sbytes', 'dbytes', 'rate', 'sttl',
#       'dttl', 'sload', 'dload', 'sloss', 'dloss', 'sinpkt', 'dinpkt', 'sjit',
#       'djit', 'swin', 'stcpb', 'dtcpb', 'dwin', 'tcprtt', 'synack', 'ackdat',
#       'smean', 'dmean', 'trans_depth', 'response_body_len', 'ct_srv_src',
#       'ct_state_ttl', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm',
#       'ct_dst_src_ltm', 'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd',
#       'ct_src_ltm', 'ct_srv_dst', 'is_sm_ips_ports', 'label'],
#      dtype='object')

#for category in newdf.columns:
#    print('>> '+ category)
#    print('min : ' + str(min(df[category])))
#    print('max : ' + str(max(df[category])))
#    print('mean : ' + str(np.mean(df[category])))
#    print('median : ' + str(np.median(df[category])))
#    print('std : ' + str(np.std(df[category])))

# Analysis Goal
# 8.1
## Le but de cette analyse est de pouvoir établir les profils d'attaques subies et en sortir leurs caractéristiques.
## Pour ce faire, on extrait les informations les plus utiles de la capture réseau
# 8.2
##  # 'id'
    # 'proto', 
    # 'service',
    # 'state',
    # 'attack_cat'
    # 'state'
    #  'label'
    ### 'd'autres' à rajouter  (les champs en ct)

# 9.Evaluation of the training dataset

print(df(1))

    #if cat['label'] == 1 :
    #    print(cat['attack_cat'])
#for category in newdf.columns:
#    print('>> '+ category)
#    print('min : ' + str(min(df[category])))
#    print('max : ' + str(max(df[category])))
#    print('mean : ' + str(np.mean(df[category])))
#    print('median : ' + str(np.median(df[category])))
#    print('std : ' + str(np.std(df[category])))
