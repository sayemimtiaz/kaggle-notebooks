# %% [markdown]
# # In this notebook, I will classify spam emails with four methods
# 1) Bag of Words
#
# 2) TFIDF
#
# 3) N-grams
#
# 4 ) lemmatization¶
#
# Result: Simple logistic regression implemented classified ham for 100% accuracy and spam for 89% accuacy
#
# See this notebook for details : (I got many warnings in this Kaggle kernel so complete code is in URL below) https://nbviewer.jupyter.org/gist/Juice178/6f5040fe6afc542c8db87ca865d2f21c
