# %% [markdown]
# I choose the total number of people fully vaccinated per hundred, which is the ratio (in percent) between population fully immunized and total
# population up to the date in the country.
# This index describe the size of immunity group in the country, which can decrease the spread rate of Covid-19.
#
# According to the animation, the first indose of vaccine was on Dec. 27, 2020 in Germany. Then the large-size of vaccination is followed by
# countries in Europe and North American, then South America and South East Asia. When it came to Mar. 2021, most of countries in the world has
# started the vaccination. What needs to mention is that, first, United States alway keep the largest ratio of vaccination, second, relatively
# poor area, like Africa, still has no access to vaccination.

# %%
#create a global map for COVID vaccination (Percentage of the population that are fully vaccinated)

import pandas as pd
import numpy as np
import plotly.express as px
import plotly

df = pd.read_csv('../input/covid-world-vaccination-progress/country_vaccinations.csv',header=0)
df.index = pd.to_datetime(df['date'])
df = df.sort_index()
print(df.columns)
fig = px.choropleth(df,locations='country',locationmode='country names',color='people_fully_vaccinated_per_hundred',hover_name='country',animation_frame='date',color_continuous_scale='rainbow',range_color=(0.0,40.0))
fig.update_layout(title_text="Percentage of the country's total fully vaccinated",title_x=0.5)
fig.show()

# %% [markdown]
# For example, the latest earthquake happened in this dataset was the one on 00:00 May. 29 2021 near Japan with 36.314°N 142.001°E.
# The related report can be found on this:
# https://earthquake.usgs.gov/earthquakes/eventpage/us6000efpu/executive
#
#
# According to the animation, most of the earthquake in this Month concentrated along the west coast of United States, which is also called
# Circum-Pacific seismic zone. Some also happend on Japan and South East Asia.

# %%
#create a global map for earthquake occurrences worldwide.

df = pd.read_csv('../input/202105-recent-earthquake/query.csv',header=0)
df.index = pd.to_datetime(df['time'])
df['time'] = df.index.strftime('%Y-%m-%d %H:00:00')
df = df.sort_index()
fig = px.scatter_geo(df,lat='latitude',lon='longitude',color='mag',animation_frame='time',color_continuous_scale='rainbow',range_color=(1.0,3.0))
fig.show()
