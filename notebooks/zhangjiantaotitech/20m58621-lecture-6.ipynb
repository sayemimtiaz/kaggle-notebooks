# %% [markdown]
# Assignment for lecture 6 May 21
#
# The country selected for the analyze with over 100 current cases of Corona is Japan.
#
# The time-series and colored tables of daily COVID-19 cases and daily vaccinations are exhibited below.
#
# With the global ranking the top10 countries in terms of the total number of cases and the total vaccinations per number of people are shown below,
#
# Top10 countries (Total number of cases)
# USA        33747424.0
# India      25227967.0
# Brazil     15661105.0
# France      5881125.0
# Turkey      5127545.0
# Russia      4949571.0
# UK          4452747.0
# Italy       4162573.0
# Spain       3615150.0
# Germany     3608276.0
#
# Top10 countries (Total vaccinations per number of people)
# country
# Gibraltar               107.62
# Seychelles               62.67
# Israel                   59.00
# Saint Helena             58.11
# San Marino               54.79
# Cayman Islands           52.20
# Falkland Islands         50.96
# Bermuda                  50.18
# Chile                    39.69
# United Arab Emirates     38.79
#
# The cases in Japan have three periods, and now they are in the fourth one with no sign of droping.
# While the number of vaccination goes with a continuous rising.
#
# Part of the reason for Japanses government's so called "soft lockdown" is buried in constitution of Japan.
# (https://www.japantimes.co.jp/opinion/2020/04/14/commentary/japan-commentary/coronavirus-japans-constitution/)
#
# Also, economic situation is also a concern for such a "soft lockdown", in opposite, which might cause an
# irreversible depression of this country's macro-economy.
# (https://www.japantimes.co.jp/news/2021/05/08/business/economy-business/japanese-economy-coronavirus-emergency/)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

selected_country_1= 'Japan'
selected_country_2= 'Japan'

df1 = pd.read_csv('../input/covid19-global-dataset/worldometer_coronavirus_daily_data.csv',header=0)
df1 = df1[df1['country']==selected_country_1]
df2 = pd.read_csv('../input/covid-world-vaccination-progress/country_vaccinations.csv',header=0)
df2 = df2[df2['country']==selected_country_2]
df1.index = pd.to_datetime(df1['date'])
df2.index = pd.to_datetime(df2['date'])
#print(df2)


#analyses
#from here data will be analysed

fig,ax = plt.subplots(figsize=(10,5))

ax.plot(df1.index,df1['daily_new_cases'])
ax1 = ax.twinx()
ax1.plot(df2.index,df2['daily_vaccinations'],'r')
plt.show()

# %%
# improve visualization

from plotly.offline import iplot
import plotly.graph_objs as go

daily_new_cases = go.Scatter(x=df1.index,y=df1['daily_new_cases'],yaxis='y1',name='Daily confirmed cases')
daily_vaccination = go.Scatter(x=df2.index,y=df2['daily_vaccinations'],yaxis='y2',name='Daily vaccinations')

layout_obj = go.Layout(title='COVID vs. Vaccines', xaxis=dict(title='Date'),yaxis=dict(title='Daily cases'),yaxis2=dict(title='Vaccinations',side='right',overlaying='y'))
fig = go.Figure(data=[daily_new_cases,daily_vaccination],layout=layout_obj)
iplot(fig)
fig.write_html('outcome.html')

# %%
#colored table

style_object = df1.style.background_gradient(cmap='jet').highlight_max('daily_new_cases').set_caption('Daily cases')
display(style_object)

# %%
#Ranking 

df1 = pd.read_csv('../input/covid19-global-dataset/worldometer_coronavirus_daily_data.csv',header=0)
df1 = df1.groupby('country').sum()['daily_new_cases'].sort_values(ascending=False)[0:10]
print(df1)
df2 = pd.read_csv('../input/covid-world-vaccination-progress/country_vaccinations.csv',header=0)
df2 = df2.groupby('country').max()['people_fully_vaccinated_per_hundred'].sort_values(ascending=False)[0:10]
print(df2.to_string())
