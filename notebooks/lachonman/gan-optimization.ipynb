# %%
# !git clone https://gitlab.com/korzeniowski.renard/gan-optimization.git

# %%
# !python gan-optimization/run_experiemnts.py

# import os
# os.chdir("/kaggle/working/gan-optimization")

# import experiments
# import hparams

# exp_params = experiments.get_exp_params(hparams)
# experiments.run_experiments(params=exp_params, hparams=hparams)

# %%
# import os
# os.chdir("/kaggle/working/gan-optimization")

# from functools import partial

# import torch

# from DCGAN import pipeline
# import experiments
# import hparams

# # hyperparameters you want to overwrite
# hparams.log_interval = 1
# hparams.loader_type = "FMNIST"
# hparams.data_path = "./"
# hparams.in_channels = 1
# hparams.epochs = 40
# hparams.gen_lr = 0.0001
# hparams.disc_lr = 0.001


# hparams.gen_channels_shapes = [hparams.latent_shape, 512, 256, 128, 64, hparams.in_channels]
# hparams.disc_channels_shapes = [hparams.in_channels, 64, 128, 256, 512, 1]

# # experiemnt setup
# exp_params = {
#     "optimizer_fns": (
#         partial(torch.optim.Adam, lr=hparams.gen_lr, betas=hparams.betas),
#         # partial(torch.optim.RMSprop, lr=hparams.gen_lr),
#     ),
#     "gan_type_sn": (
#         # (pipeline.DCGAN, False, True, 1), # 2 gen step
#         # (pipeline.DCGAN, True, False, 4), # 1 gen 4 disc step
#         # (pipeline.WGAN, False, True, 4), # 1 gen 5 disc step
#         (experiments.pipeline.WGANGP, False, False, 8), # 1 gen 5 disc step
#     ),
#     "seeds": (1, ),
# }

# experiments.run_experiments(params=exp_params, hparams=hparams)
