# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df=pd.read_csv("../input/cardiogoodfitness/CardioGoodFitness.csv")

# %%
df.head()  # to check the header of the file

# %%
df.shape # to check the size of data

# %%
df.info() # to check the type of variable and we can also check the null value in the data

# %% [markdown]
# 1.Fitness is in the numerical varaible but the data present in the columns seems to be categorical

# %%
df['Fitness'].value_counts() # to check the categorical variable and their counts

# %%
df.describe(include='all') # for the summary statistics

# %% [markdown]
# For numerical varaible the uniquness top and frequency doesnot say much about the data
# 1. we can check the median,mean,standard deviation and IQR can be seen to see what is the central tendency and measure of dispersion for the numerical categories

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

df.hist(figsize=(15,15)) # to get the visualizing part how the data is spread

# %%
import seaborn as sns
sns.boxplot(df['Gender'],df['Age'])

# %% [markdown]
# We can see the median of both the category and can also see the presence of outliers in the female gender

# %%
pd.crosstab(df['Product'],df['Gender'])

# %%
sns.boxplot(df['Product'],df['Age'])

# %%
pd.crosstab(df['Product'],df['MaritalStatus'])

# %%
sns.countplot(df['Product'],hue=df['MaritalStatus'])

# %%
sns.countplot(df['Product'],hue=df["Gender"])

# %%
pd.pivot_table(df,index=['Product','Gender'],columns=['MaritalStatus'],aggfunc=sum)

# %%
sns.pairplot(df,diag_kind='kde')

# %%
df['Age'].std()

# %%
df['Age'].mean()

# %%
sns.distplot(df['Age'])

# %%
sns.histplot(df['Age'],kde=True)

# %%
df.hist(by='Gender',column='Income')

# %%
corr=df.corr()
corr

# %%
sns.heatmap(corr,annot=True)
