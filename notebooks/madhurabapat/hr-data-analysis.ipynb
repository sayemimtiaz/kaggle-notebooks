# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# Read Data.

# %%
df = pd.read_csv('../input/ibm-hr-analytics-attrition-dataset/WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
df.head()

# %% [markdown]
# Check for missing values.

# %%
df.info()

# %%
df.describe()

# %%
df.std()

# %% [markdown]
# Correlation

# %%
df.corr()

# %%
plt.figure(figsize=(14,14))
sns.heatmap(df.corr())

# %% [markdown]
# Attrition Analysis.

# %%
df["Attrition"].value_counts()

# %%
sns.countplot(df['Attrition'])
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Attrition')

# %%
fig, ax = plt.subplots()
ax.pie(df["Attrition"].value_counts() ,labels=["No","Yes"],
       autopct='%1.1f%%',
        shadow=True, startangle=90)
ax.axis('equal')
plt.show()

# %% [markdown]
# Atrrition against different parameters.

# %%
g1 = sns.countplot(x="BusinessTravel", hue="Attrition",data = df)

# %%
g2 = sns.countplot(x="Gender", hue="Attrition",data = df)

# %%
g3 = sns.countplot(x="Department", hue="Attrition",data = df)

# %%
g4 = sns.countplot(x="EducationField", hue="Attrition",data = df)

# %%
g5 = sns.countplot(x="JobSatisfaction", hue="Attrition",data = df)

# %%
g6 = sns.countplot(x="OverTime", hue="Attrition",data = df)

# %%
g6 = sns.countplot(x="EnvironmentSatisfaction", hue="Attrition",data = df)

# %%
g8 = sns.countplot(x="RelationshipSatisfaction", hue="Attrition",data = df)

# %%
g9 = sns.countplot(x="YearsSinceLastPromotion", hue="Attrition",data = df)

# %%
plt.figure(figsize=(20,10))
g10 = sns.countplot(x="JobRole", hue="Attrition",data = df)

# %%
ax1 = sns.boxplot(x="Attrition", y="Age", data=df)

# %%
ax2 = sns.boxplot(x="Attrition", y="DistanceFromHome", data=df)

# %%
ax2 = sns.stripplot(x="Attrition", y="MonthlyIncome", data=df)
