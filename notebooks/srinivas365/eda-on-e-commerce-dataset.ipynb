# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input/"))
import matplotlib.pyplot as plt
# %matplotlib inline

# Any results you write to the current directory are saved as output.
# Out:
# ['data.csv']

# %% [markdown]
# **To get a brief overview, this notebook is dedicated to 5 sections as follows**
# 1. Context of dataset
# 2. Data cleaning
# 3. EDA
# 4. Results
# 5. Conclusion

# %% [markdown]
# **Loading the dataset into pandas dataframe**

# %%
df=pd.read_csv('../input/data.csv',encoding='unicode_escape')

# %%
df.head()
# Out:
#   InvoiceNo StockCode       ...       CustomerID         Country
# 0    536365    85123A       ...          17850.0  United Kingdom
# 1    536365     71053       ...          17850.0  United Kingdom
# 2    536365    84406B       ...          17850.0  United Kingdom
# 3    536365    84029G       ...          17850.0  United Kingdom
# 4    536365    84029E       ...          17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %% [markdown]
# **Column names of dataset**

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %% [markdown]
# **Check the number of rows and columns**

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.Country.value_counts()
# Out:
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              30
# Bahrain                     19
# Saudi Arabia                10
# Name: Country, dtype: int64

# %% [markdown]
# ****

# %% [markdown]
# **Before dealing with dataset first we need to understand the dataset.Let's try to understand what it is about to give us a better understanding of its context**
#
# *The summarized information on the dataset is as follows:*
# 1. Most of the companies are country United Kingdom based
# 2. Transcational Period - 1st Dec 2010–9th Dec 2011 (One year)

# %% [markdown]
# **Data cleaning**
#
# - check if any NA's are present

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# CustomerID     135080
# Description      1454
# Country             0
# UnitPrice           0
# InvoiceDate         0
# Quantity            0
# StockCode           0
# InvoiceNo           0
# dtype: int64

# %%
df.drop(['CustomerID'],axis=1,inplace=True)

# %% [markdown]
# **Removing the NA's in the dataset row-wise**

# %%
df.dropna(inplace=True)

# %% [markdown]
# **Cross checking there doesn't exist a NA's present**

# %%
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# Country        0
# dtype: int64

# %% [markdown]
# **Understanding the dataset in more descriptive manner**

# %%
df.describe()
# Out:
#             Quantity      UnitPrice
# count  540455.000000  540455.000000
# mean        9.603129       4.623519
# std       218.007598      96.889628
# min    -80995.000000  -11062.060000
# 25%         1.000000       1.250000
# 50%         3.000000       2.080000
# 75%        10.000000       4.130000
# max     80995.000000   38970.000000

# %% [markdown]
# **From the above table we can see that minimum value of product's quantity is negative and it's not possible**

# %%
df[(df['Quantity']<=0) | (df['UnitPrice']<0)].count()
# Out:
# InvoiceNo      9764
# StockCode      9764
# Description    9764
# Quantity       9764
# InvoiceDate    9764
# UnitPrice      9764
# Country        9764
# dtype: int64

# %% [markdown]
# **8905 rows have negative quantity values and In the dataset of 5 lakh rows we can remove these rows**

# %%
df=df[df['Quantity']>0]

# %%
df=df[df['UnitPrice']>=0]

# %%
df.shape
# Out:
# (530691, 7)

# %% [markdown]
# **Let's check the categorical attributes description**

# %%
df.describe(include=[np.object])
# Out:
#        InvoiceNo StockCode       ...             InvoiceDate         Country
# count     530691    530691       ...                  530691          530691
# unique     20134      3925       ...                   18639              38
# top       573585    85123A       ...        10/31/2011 14:41  United Kingdom
# freq        1114      2270       ...                    1114          485692
#
# [4 rows x 5 columns]

# %% [markdown]
# **Let's find out the total amount spent on each transcations**
#
# tot_amount=quantity*unit_price

# %%
df.head()
# Out:
#   InvoiceNo StockCode       ...       UnitPrice         Country
# 0    536365    85123A       ...            2.55  United Kingdom
# 1    536365     71053       ...            3.39  United Kingdom
# 2    536365    84406B       ...            2.75  United Kingdom
# 3    536365    84029G       ...            3.39  United Kingdom
# 4    536365    84029E       ...            3.39  United Kingdom
#
# [5 rows x 7 columns]

# %%
df['total_amount']=df['Quantity']*df['UnitPrice']

# %%
df.head()
# Out:
#   InvoiceNo StockCode      ...              Country  total_amount
# 0    536365    85123A      ...       United Kingdom         15.30
# 1    536365     71053      ...       United Kingdom         20.34
# 2    536365    84406B      ...       United Kingdom         22.00
# 3    536365    84029G      ...       United Kingdom         20.34
# 4    536365    84029E      ...       United Kingdom         20.34
#
# [5 rows x 8 columns]

# %%
from datetime import datetime
def toDtObject(value):
    return datetime.strptime(value,'%m/%d/%Y %H:%M')

# %% [markdown]
# **InvoiceDate column is in the string format converting into Datetime object**

# %%
df['InvoiceDate']=df['InvoiceDate'].apply(toDtObject)

# %%
df.head()
# Out:
#   InvoiceNo StockCode      ...              Country  total_amount
# 0    536365    85123A      ...       United Kingdom         15.30
# 1    536365     71053      ...       United Kingdom         20.34
# 2    536365    84406B      ...       United Kingdom         22.00
# 3    536365    84029G      ...       United Kingdom         20.34
# 4    536365    84029E      ...       United Kingdom         20.34
#
# [5 rows x 8 columns]

# %%
def getMonth(value):
    return int(value.strftime('%m'))
def getDay(value):
    return int(value.strftime('%d'))
def getYear(value):
    return int(value.strftime('%Y'))
def getHour(value):
    return int(value.strftime('%H'))

# %% [markdown]
# **Creating a seperate month,day and year columns**

# %%
df['month']=df['InvoiceDate'].apply(getMonth)
df['day']=df['InvoiceDate'].apply(getDay)
df['year']=df['InvoiceDate'].apply(getYear)
df['hour']=df['InvoiceDate'].apply(getHour)

# %%
df.head()
# Out:
#   InvoiceNo StockCode  ...   year  hour
# 0    536365    85123A  ...   2010     8
# 1    536365     71053  ...   2010     8
# 2    536365    84406B  ...   2010     8
# 3    536365    84029G  ...   2010     8
# 4    536365    84029E  ...   2010     8
#
# [5 rows x 12 columns]

# %%
df['year'].value_counts()
# Out:
# 2011    489071
# 2010     41620
# Name: year, dtype: int64

# %%
df.InvoiceDate.describe()
# Out:
# count                  530691
# unique                  18639
# top       2011-10-31 14:41:00
# freq                     1114
# first     2010-12-01 08:26:00
# last      2011-12-09 12:50:00
# Name: InvoiceDate, dtype: object

# %%
df.month.value_counts().plot(kind='bar')

# %% [markdown]
# **From the above graph we can conclude that most of sales happended in the last quarter of year**

# %%
df.day.value_counts(ascending=True).plot(kind='bar')

# %% [markdown]
# **Top 10 items most sales**

# %%
df.Description.value_counts()[:10]
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER    2327
# JUMBO BAG RED RETROSPOT               2115
# REGENCY CAKESTAND 3 TIER              2019
# PARTY BUNTING                         1707
# LUNCH BAG RED RETROSPOT               1594
# ASSORTED COLOUR BIRD ORNAMENT         1489
# SET OF 3 CAKE TINS PANTRY DESIGN      1399
# PACK OF 72 RETROSPOT CAKE CASES       1370
# LUNCH BAG  BLACK SKULL.               1328
# NATURAL SLATE HEART CHALKBOARD        1263
# Name: Description, dtype: int64

# %%
df.groupby(['Description']).describe().transpose()
# Out:
# Description          4 PURPLE FLOCK DINNER CANDLES              ...               wrongly sold (22719) barcode
# Quantity     count                       41.000000              ...                                        1.0
#              mean                         3.512195              ...                                      170.0
#              std                          3.834853              ...                                        NaN
#              min                          1.000000              ...                                      170.0
#              25%                          1.000000              ...                                      170.0
#              50%                          2.000000              ...                                      170.0
#              75%                          4.000000              ...                                      170.0
#              max                         12.000000              ...                                      170.0
# UnitPrice    count                       41.000000              ...                                        1.0
#              mean                         2.455366              ...                                        0.0
#              std                          0.825061              ...                                        NaN
#              min                          0.790000              ...                                        0.0
#              25%                          2.550000              ...                                        0.0
#              50%                          2.550000              ...                                        0.0
#              75%                          2.550000              ...                                        0.0
#              max                          5.060000              ...                                        0.0
# day          count                       41.000000              ...                                        1.0
#              mean                        14.365854              ...                                       11.0
#              std                          8.884695              ...                                        NaN
#              min                          1.000000              ...                                       11.0
#              25%                          7.000000              ...                                       11.0
#              50%                         15.000000              ...                                       11.0
#              75%                         20.000000              ...                                       11.0
#              max                         30.000000              ...                                       11.0
# hour         count                       41.000000              ...                                        1.0
#              mean                        12.829268              ...                                       16.0
#              std                          1.842586              ...                                        NaN
#              min                          9.000000              ...                                       16.0
#              25%                         12.000000              ...                                       16.0
#              50%                         13.000000              ...                                       16.0
#              75%                         14.000000              ...                                       16.0
#              max                         16.000000              ...                                       16.0
# month        count                       41.000000              ...                                        1.0
#              mean                         8.902439              ...                                        3.0
#              std                          3.382343              ...                                        NaN
#              min                          1.000000              ...                                        3.0
#              25%                          7.000000              ...                                        3.0
#              50%                         11.000000              ...                                        3.0
#              75%                         11.000000              ...                                        3.0
#              max                         12.000000              ...                                        3.0
# total_amount count                       41.000000              ...                                        1.0
#              mean                         7.092683              ...                                        0.0
#              std                          6.723367              ...                                        NaN
#              min                          0.790000              ...                                        0.0
#              25%                          2.550000              ...                                        0.0
#              50%                          5.100000              ...                                        0.0
#              75%                          9.480000              ...                                        0.0
#              max                         30.600000              ...                                        0.0
# year         count                       41.000000              ...                                        1.0
#              mean                      2010.926829              ...                                     2011.0
#              std                          0.263652              ...                                        NaN
#              min                       2010.000000              ...                                     2011.0
#              25%                       2011.000000              ...                                     2011.0
#              50%                       2011.000000              ...                                     2011.0
#              75%                       2011.000000              ...                                     2011.0
#              max                       2011.000000              ...                                     2011.0
#
# [56 rows x 4077 columns]

# %%
df.Country.value_counts().plot(kind='bar')

# %%
df['hour'].value_counts().plot(kind='bar')

# %%
df[df['month']==11].groupby(['Description']).sum().sort_values(by='total_amount',ascending=False)[:5]
# Out:
#                                     Quantity  UnitPrice  ...      year  hour
# Description                                              ...
# DOTCOM POSTAGE                            47   36905.40  ...     94517   662
# RABBIT NIGHT LIGHT                     14954    1144.78  ...   1039687  6690
# PAPER CHAIN KIT 50'S CHRISTMAS          7908    1309.74  ...    816466  5240
# WHITE HANGING HEART T-LIGHT HOLDER      4944     884.06  ...    540959  3436
# POPCORN HOLDER                         12460     254.52  ...    514816  3281
#
# [5 rows x 7 columns]

# %% [markdown]
# ### Conclusion

# %% [markdown]
# - **United Kindom has most number of sales and remaining countries sales are very far less than it**
# - **WHITE HANGING HEART T-LIGHT HOLDER and JUMBO BAG RED RETROSPOT product are in top positions**
# - **Most sales happended in November month**
# - **First week of every month has good sales count**
# - **Huge sales are happening around 12 PM everyday**
# - **Most sales happedned in the end of year and maybe it's because of christmas**
# - **In those months christmas gifts related products should have more stock**
