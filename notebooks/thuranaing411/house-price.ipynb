# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")

# %%
from learntools.core import binder
binder.bind(globals())
from learntools.data_viz_to_coder.ex7 import *
print("Setup Complete")

# %%
test_filepath = "../input/house-price-prediction-challenge/test.csv"
train_filepath = "../input/house-price-prediction-challenge/train.csv"
test_data = pd.read_csv(test_filepath)

# %%
test_data.head()

# %%
train_data = pd.read_csv(train_filepath)

# %%
train_data.head()

# %%
import sklearn
import numpy as np
import os
import seaborn as sns
import pandas as pd# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
X = train_data[['UNDER_CONSTRUCTION','RERA','SQUARE_FT','READY_TO_MOVE','RESALE','LONGITUDE','LATITUDE']]
Y = train_data['TARGET(PRICE_IN_LACS)']
X_TEST = test_data[['UNDER_CONSTRUCTION','RERA','SQUARE_FT','READY_TO_MOVE','RESALE','LONGITUDE','LATITUDE']]
Y_TEST = train_data['TARGET(PRICE_IN_LACS)']
reg = LinearRegression().fit(X,Y)

# %%
print(reg.intercept_)

# %%
coeff_df = pd.DataFrame(reg.coef_, X.columns, columns=['Coefficient'])
coeff_df

# %%
pred = reg.predict(X)

# %%
plt.scatter(Y, pred)
