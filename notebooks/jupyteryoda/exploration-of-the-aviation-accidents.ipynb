# %% [markdown]
# # Summary
# This is an exploration of the aviation incidents data set.  This is my first exploration into the Kaggle datasets and my dive into data exploration and analysis with Python.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

## input data
df = pd.read_csv('../input/AviationDataUP.csv')
df.head()

# %%
for i in df:
    print(df[i].value_counts())
