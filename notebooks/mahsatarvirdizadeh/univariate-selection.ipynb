# %%
import pandas as pd
from numpy import set_printoptions
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
myfilename = '../input/pimaindiansdiabetescsv/pima-indians-diabetes.csv'
names=['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age','Outcome']
mydata=pd.read_csv(myfilename, names=names)
data=mydata.values
X=data[:,0:8]
Y=data[:,8]
#feature extraction
myFeature =SelectKBest(score_func=chi2,k=4)  #k is numberof top feature to select
fit=myFeature.fit(X,Y)
#summarize scores
set_printoptions(precision=3)
print(fit.scores_)
