# %% [markdown]
# # Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Model
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from keras.optimizers import RMSprop
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
# %matplotlib inline

# %% [markdown]
# ### Load the data into Pandas dataframe

# %%
df = pd.read_csv('../input/hatesp/german hatespeech refugees.csv',delimiter=',',encoding='UTF-8')
df.head()

# %% [markdown]
# Drop the columns that are not required for the neural network.

# %%
df.drop(['HatespeechOrNot (Expert 2)', 'Hatespeech Rating (Expert 2)'],axis=1,inplace=True)
df.info()

# %% [markdown]
# Understand the distribution better.

# %%
sns.countplot(df.Tweet)
plt.xlabel('Label')
plt.title('Hate or No Hate')

# %% [markdown]
# * Create input and output vectors.
# * Process the labels.

# %%
df = df.rename(columns={'HatespeechOrNot (Expert 1)': 'HatespeechOrNot'})
X = df.Tweet
Y = df.HatespeechOrNot
le = LabelEncoder()
Y = le.fit_transform(Y)
Y = Y.reshape(-1,1)
df.head()

# %% [markdown]
# Split into training and test data.

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.15)

# %% [markdown]
# ### Process the data
# * Tokenize the data and convert the text to sequences.
# * Add padding to ensure that all the sequences have the same shape.
# * There are many ways of taking the *max_len* and here an arbitrary length of 150 is chosen.

# %%
max_words = 1000
max_len = 150
tok = Tokenizer(num_words=max_words)
tok.fit_on_texts(X_train)
sequences = tok.texts_to_sequences(X_train)
sequences_matrix = sequence.pad_sequences(sequences,maxlen=max_len)

# %% [markdown]
# ### RNN
# Define the RNN structure.

# %%
def RNN():
    inputs = Input(name='inputs',shape=[max_len])
    layer = Embedding(max_words,50,input_length=max_len)(inputs)
    layer = LSTM(64)(layer)
    layer = Dense(256,name='FC1')(layer)
    layer = Activation('relu')(layer)
    layer = Dropout(0.2)(layer)
    layer = Dense(1,name='out_layer')(layer)
    layer = Activation('sigmoid')(layer)
    model = Model(inputs=inputs,outputs=layer)
    return model

# %% [markdown]
# Call the function and compile the model.

# %%
model = RNN()
model.summary()
model.compile(loss='mean_squared_error',optimizer=RMSprop(),metrics=['accuracy'])

# %% [markdown]
# Fit on the training data.

# %%
model.fit(sequences_matrix,Y_train,batch_size=128,epochs=10,
          validation_split=0.2)

# %% [markdown]
# The model performs well on the validation set and this configuration is chosen as the final model.

# %% [markdown]
# Process the test set data.

# %%
test_sequences = tok.texts_to_sequences(X_test)
test_sequences_matrix = sequence.pad_sequences(test_sequences,maxlen=max_len)

# %% [markdown]
# Evaluate the model on the test set.

# %%
accr = model.evaluate(test_sequences_matrix,Y_test)

# %%
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(accr[0],accr[1]))

# %%
sample_texts = ["Ich liebe die welt"]

txts = tok.texts_to_sequences(sample_texts)
txts = sequence.pad_sequences(txts, maxlen=max_len)
preds = model.predict(txts)
print(preds)
if preds > 0.5:
    prediction = 'Hate'
else:
    prediction = 'No Hate!'
print(prediction)
