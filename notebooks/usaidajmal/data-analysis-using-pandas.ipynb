# %%
import numpy as np
import pandas as pd 
import os
import warnings
warnings.filterwarnings('ignore')
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename)) #Let's first import the pandas and numpy libraries for basic data analysis.

# %%
data=pd.read_csv('/kaggle/input/women-representation-in-city-property-sanfrancisco/WomenRepresentaionInCityProperty-SanFrancisco.csv')

# %%
data.head(3)

# %%
data.info() #Basic information about the Data that we have imported

# %%
data.columns

# %%
data['Gender'].value_counts() # Through this line of code we can check that how many males and females are represented in this Dataset

# %%
data[data['Department/Source']=='Administrator'].count() # Check the no. of administrators in this data.

# %%
data[(data['Gender']=='F') & (data['Department/Source']=='Administrator')] #The no. of women that are administrators in their departments

# %%
data[(data['Gender']=='M') & (data['Department/Source']=='Administrator')] #The no. of men that are administrators

# %%
data['Department/Source'].value_counts().head(5) #The top 5 job roles in the Data set
