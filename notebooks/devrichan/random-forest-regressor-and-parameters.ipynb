# %% [markdown]
# ## Machine Learning I
# - Using 5 algorithms, namely: Linear Regression, Ridge Regression and Lasso Regression, Decision Tree, and Random Forest

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.linear_model import Lasso, Ridge
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
dftmp=pd.read_csv('../input/lianjia/new.csv')
df = pd.read_csv('../input/new-data-clean/clean_data')
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.head()

# %%
sns.distplot(df['totalPrice'])

# %%
fig = px.box(df, y="totalPrice")
fig.show()

# %%
df.describe()

# %% [markdown]
# ## II. Feature Engineering I

# %%
df.info()

# %% [markdown]
# ### II.1 Unused variable

# %% [markdown]
# Unused variables are variables that don't need to be inputted.
# - url
# - id
# - Ex
# - Lng
# - Cid
# - tradeTime
# - DOM
# - followers
# - communityAverage
# - fiveYearsProperty

# %%
df.drop(['url','id','Lat','Lng','Cid','tradeTime','DOM','followers','communityAverage','fiveYearsProperty'],inplace=True,axis=1)

# %%
df['constructionTime'] = df['constructionTime'].astype('object')

# %%
df.info()

# %% [markdown]
# ### II.2 Standarisasi Nilai

# %%
from sklearn.preprocessing import RobustScaler

# %%
robust = RobustScaler()

# %% [markdown]
# ### III. Making Machine Learning Models

# %% [markdown]
# #### III.1 Linear Regression Default Parameter

# %%
## Setting features and target
features = df.drop('totalPrice',axis=1)
features = pd.get_dummies(features,drop_first=True)
## Lanjutan standarisasi nilai
robust.fit(features)
robust_data = robust.transform(features)
features = pd.DataFrame(robust_data,columns=features.columns)
target = df['totalPrice']

# %%
features

# %%
## Train test split
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.10, random_state=101)

# %%
## Creating and Training the Model
lm = LinearRegression()

# %%
lm.fit(x_train,y_train)

# %%
# Prediction with data train
predictions_train = lm.predict(x_train)
print('RMSE : ', np.sqrt(metrics.mean_squared_error(y_train,predictions_train)))
print('R2 Score : ', r2_score(y_train,predictions_train))
f, axes = plt.subplots(1,2,figsize=(20,10))
sns.regplot(x = y_train, y = predictions_train,ax = axes[0])
sns.distplot((y_train-predictions_train),ax = axes[1])

# %%
# Prediction with data test
predictions_test = lm.predict(x_test)
print('RMSE : ', np.sqrt(metrics.mean_squared_error(y_test,predictions_test)))
print('R2 Score : ', r2_score(y_test,predictions_test))
f, axes = plt.subplots(1,2,figsize=(20,10))
sns.regplot(x = y_test, y = predictions_test,ax = axes[0])
sns.distplot((y_test-predictions_test),ax = axes[1])

# %% [markdown]
# #### III.2 Ridge Regression Default

# %%
## Setting features and target
features = df.drop('totalPrice',axis=1)
features = pd.get_dummies(features,drop_first=True)
## Lanjutan standarisasi nilai
robust.fit(features)
robust_data = robust.transform(features)
features = pd.DataFrame(robust_data,columns=features.columns)
target = df['totalPrice']

# %%
## Train test split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.1, random_state=101)

# %%
rid = Ridge()

# %%
rid.fit(x_train,y_train)

# %%
# Prediction with data train
predictions_train = rid.predict(x_train)
print('RMSE : ', np.sqrt(metrics.mean_squared_error(y_train,predictions_train)))
print('R2 Score : ', r2_score(y_train,predictions_train))
f, axes = plt.subplots(1,2,figsize=(20,10))
sns.regplot(x = y_train, y = predictions_train,ax = axes[0])
sns.distplot((y_train-predictions_train),ax = axes[1])

# %%
# Prediction with data test
predictions_test = rid.predict(x_test)
print('RMSE : ', np.sqrt(metrics.mean_squared_error(y_test,predictions_test)))
print('R2 Score : ', r2_score(y_test,predictions_test))
f, axes = plt.subplots(1,2,figsize=(20,10))
sns.regplot(x = y_test, y = predictions_test,ax = axes[0])
sns.distplot((y_test-predictions_test),ax = axes[1])

# %% [markdown]
# #### III.3 Lasso Regression Default

# %%
## Setting features and target
features = df.drop('totalPrice',axis=1)
features = pd.get_dummies(features,drop_first=True)
## Lanjutan standarisasi nilai
robust.fit(features)
robust_data = robust.transform(features)
features = pd.DataFrame(robust_data,columns=features.columns)
target = df['totalPrice']

# %%
## Train test split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.1, random_state=101)

# %%
las = Lasso()

# %%
las.fit(x_train,y_train)

# %%
# Prediction with data train
predictions_train = las.predict(x_train)
print('RMSE : ', np.sqrt(metrics.mean_squared_error(y_train,predictions_train)))
print('R2 Score : ', r2_score(y_train,predictions_train))
f, axes = plt.subplots(1,2,figsize=(20,10))
sns.regplot(x = y_train, y = predictions_train,ax = axes[0])
sns.distplot((y_train-predictions_train),ax = axes[1])

# %%
# Prediction with data test
predictions_test = las.predict(x_test)
print('RMSE : ', np.sqrt(metrics.mean_squared_error(y_test,predictions_test)))
print('R2 Score : ', r2_score(y_test,predictions_test))
f, axes = plt.subplots(1,2,figsize=(20,10))
sns.regplot(x = y_test, y = predictions_test,ax = axes[0])
sns.distplot((y_test-predictions_test),ax = axes[1])

# %% [markdown]
# #### III.3 Lasso Regression with Parameter Tuning

# %%
## Setting features and target
features = df.drop('totalPrice',axis=1)
features = pd.get_dummies(features,drop_first=True)
## Lanjutan standarisasi nilai
robust.fit(features)
robust_data = robust.transform(features)
features = pd.DataFrame(robust_data,columns=features.columns)
target = df['totalPrice']

# %%
## Train test split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.1, random_state=101)

# %%
las2 = Lasso()

# %%
param_grid = {
    'alpha': [0.0001, 0.001, 0.01,0.1, 0.5, 1],
}

# %%
lasso_cv = GridSearchCV(las2, param_grid,cv=5)

# %%
lasso_cv.fit(x_train, y_train)

# %%
# Prediction with data train
predictions_train = lasso_cv.predict(x_train)
print('RMSE : ', np.sqrt(metrics.mean_squared_error(y_train,predictions_train)))
print('R2 Score : ', r2_score(y_train,predictions_train))
f, axes = plt.subplots(1,2,figsize=(20,10))
sns.regplot(x = y_train, y = predictions_train,ax = axes[0])
sns.distplot((y_train-predictions_train),ax = axes[1])

# %%
# Prediction with data test
predictions_test = lasso_cv.predict(x_test)
print('RMSE : ', np.sqrt(metrics.mean_squared_error(y_test,predictions_test)))
print('R2 Score : ', r2_score(y_test,predictions_test))
f, axes = plt.subplots(1,2,figsize=(20,10))
sns.regplot(x = y_test, y = predictions_test,ax = axes[0])
sns.distplot((y_test-predictions_test),ax = axes[1])

# %% [markdown]
# #### III.4 Decison Tree Regressor

# %%
## Setting features and target
features = df.drop('totalPrice',axis=1)
features = pd.get_dummies(features,drop_first=True)
## Lanjutan standarisasi nilai
robust.fit(features)
robust_data = robust.transform(features)
features = pd.DataFrame(robust_data,columns=features.columns)
target = df['totalPrice']

# %%
## Train test split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.1, random_state=101)

# %%
dtree = DecisionTreeRegressor(random_state=101)

# %%
dtree.fit(x_train,y_train)

# %%
# Prediction with data train
predictions_train = dtree.predict(x_train)
print('RMSE : ', np.sqrt(metrics.mean_squared_error(y_train,predictions_train)))
print('R2 Score : ', r2_score(y_train,predictions_train))
f, axes = plt.subplots(1,2,figsize=(20,10))
sns.regplot(x = y_train, y = predictions_train,ax = axes[0])
sns.distplot((y_train-predictions_train),ax = axes[1])

# %%
# Prediction with data test
predictions_test = dtree.predict(x_test)
print('RMSE : ', np.sqrt(metrics.mean_squared_error(y_test,predictions_test)))
print('R2 Score : ', r2_score(y_test,predictions_test))
f, axes = plt.subplots(1,2,figsize=(20,10))
sns.regplot(x = y_test, y = predictions_test,ax = axes[0])
sns.distplot((y_test-predictions_test),ax = axes[1])

# %% [markdown]
# #### III.5 Decison Tree Regressor with Parameter

# %%
## Setting features and target
features = df.drop('totalPrice',axis=1)
features = pd.get_dummies(features,drop_first=True)
## Lanjutan standarisasi nilai
robust.fit(features)
robust_data = robust.transform(features)
features = pd.DataFrame(robust_data,columns=features.columns)
target = df['totalPrice']

# %%
## Train test split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.1, random_state=101)

# %%
dtree2 = DecisionTreeRegressor(random_state=101)

# %%
parameters = {
    'max_depth' : [4,5,6,7,None],
    'min_samples_split' : [2,5,8,10,15],
    'min_samples_leaf' : [1,2,3,4],
}

# %%
grid_dtree = GridSearchCV(estimator = dtree2,
                        param_grid = parameters,
                        scoring='neg_root_mean_squared_error',cv=4,n_jobs=-1
                       )

# %%
grid_dtree.fit(x_train,y_train)

# %%
# Prediction with data train
predictions_train = grid_dtree.predict(x_train)
print('RMSE : ', np.sqrt(metrics.mean_squared_error(y_train,predictions_train)))
print('R2 Score : ', r2_score(y_train,predictions_train))
f, axes = plt.subplots(1,2,figsize=(20,10))
sns.regplot(x = y_train, y = predictions_train,ax = axes[0])
sns.distplot((y_train-predictions_train),ax = axes[1])

# %%
# Prediction with data test
predictions_test = grid_dtree.predict(x_test)
print('RMSE : ', np.sqrt(metrics.mean_squared_error(y_test,predictions_test)))
print('R2 Score : ', r2_score(y_test,predictions_test))
f, axes = plt.subplots(1,2,figsize=(20,10))
sns.regplot(x = y_test, y = predictions_test,ax = axes[0])
sns.distplot((y_test-predictions_test),ax = axes[1])

# %% [markdown]
# #### III.6 Random Forest Regressor

# %%
## Setting features and target
features = df.drop('totalPrice',axis=1)
features = pd.get_dummies(features,drop_first=True)
## Lanjutan standarisasi nilai
robust.fit(features)
robust_data = robust.transform(features)
features = pd.DataFrame(robust_data,columns=features.columns)
target = df['totalPrice']

# %%
## Train test split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.1, random_state=101)

# %%
rf = RandomForestRegressor(random_state=101)

# %%
rf.fit(x_train,y_train)

# %%
# Prediction with data train
predictions_train = rf.predict(x_train)
print('RMSE : ', np.sqrt(metrics.mean_squared_error(y_train,predictions_train)))
print('R2 Score : ', r2_score(y_train,predictions_train))
f, axes = plt.subplots(1,2,figsize=(20,10))
sns.regplot(x = y_train, y = predictions_train,ax = axes[0])
sns.distplot((y_train-predictions_train),ax = axes[1])

# %%
# Prediction with data test
predictions_test = rf.predict(x_test)
print('RMSE : ', np.sqrt(metrics.mean_squared_error(y_test,predictions_test)))
print('R2 Score : ', r2_score(y_test,predictions_test))
f, axes = plt.subplots(1,2,figsize=(20,10))
sns.regplot(x = y_test, y = predictions_test,ax = axes[0])
sns.distplot((y_test-predictions_test),ax = axes[1])

# %% [markdown]
# #### III.7 Random Forest Regressor with Parameter I

# %%
## Setting features and target
features = df.drop('totalPrice',axis=1)
features = pd.get_dummies(features,drop_first=True)
## Lanjutan standarisasi nilai
robust.fit(features)
robust_data = robust.transform(features)
features = pd.DataFrame(robust_data,columns=features.columns)
target = df['totalPrice']

# %%
## Train test split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.1, random_state=101)

# %%
parameters = {
    'max_depth' : [5,6,None],
    'min_samples_split' : [2,4],
    'min_samples_leaf' : [1,2],
    'n_estimators' : [100]
}

# %%
rf = RandomForestRegressor(random_state=101)

# %%
grid_rfc = GridSearchCV(estimator = rf,
                        param_grid = parameters,
                        scoring='neg_root_mean_squared_error',cv=4,n_jobs=-1
                       )

# %%
grid_rfc.fit(x_train,y_train)

# %%
# Prediction with data train
predictions_train = grid_rfc.predict(x_train)
print('RMSE : ', np.sqrt(metrics.mean_squared_error(y_train,predictions_train)))
print('R2 Score : ', r2_score(y_train,predictions_train))
f, axes = plt.subplots(1,2,figsize=(20,10))
sns.regplot(x = y_train, y = predictions_train,ax = axes[0])
sns.distplot((y_train-predictions_train),ax = axes[1])

# %%
# Prediction with data test
predictions_test = grid_rfc.predict(x_test)
print('RMSE : ', np.sqrt(metrics.mean_squared_error(y_test,predictions_test)))
print('R2 Score : ', r2_score(y_test,predictions_test))
f, axes = plt.subplots(1,2,figsize=(20,10))
sns.regplot(x = y_test, y = predictions_test,ax = axes[0])
sns.distplot((y_test-predictions_test),ax = axes[1])

# %%
grid_rfc.best_params_

# %% [markdown]
# III.8 Random Forest Regressor with Parameter II

# %%
## Setting features and target
features = df.drop('totalPrice',axis=1)
features = pd.get_dummies(features,drop_first=True)
## Lanjutan standarisasi nilai
robust.fit(features)
robust_data = robust.transform(features)
features = pd.DataFrame(robust_data,columns=features.columns)
target = df['totalPrice']

# %%
## Train test split
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.1, random_state=101)

# %%
parameters = {
    'max_depth' : [None],
    'min_samples_split' : [6],
    'min_samples_leaf' : [5],
    'n_estimators' : [120]
}

# %%
rf = RandomForestRegressor(random_state=101)

# %%
grid_rf = GridSearchCV(estimator = rf,
                        param_grid = parameters,
                        scoring='neg_root_mean_squared_error',cv=4,n_jobs=-1
                       )

# %%
grid_rf.fit(x_train,y_train)

# %%
# Prediction with data train
predictions_train = grid_rf.predict(x_train)
print('RMSE : ', np.sqrt(metrics.mean_squared_error(y_train,predictions_train)))
print('R2 Score : ', r2_score(y_train,predictions_train))
f, axes = plt.subplots(1,2,figsize=(20,10))
sns.regplot(x = y_train, y = predictions_train,ax = axes[0])
sns.distplot((y_train-predictions_train),ax = axes[1])

# %%
# Prediction with data test
predictions_test = grid_rf.predict(x_test)
print('RMSE : ', np.sqrt(metrics.mean_squared_error(y_test,predictions_test)))
print('R2 Score : ', r2_score(y_test,predictions_test))
f, axes = plt.subplots(1,2,figsize=(20,10))
sns.regplot(x = y_test, y = predictions_test,ax = axes[0])
sns.distplot((y_test-predictions_test),ax = axes[1])

# %%
grid_rf.best_params_

# %% [markdown]
# III.8 Random Forest Regressor with Parameter III

# %%
## Setting features and target
features = df.drop('totalPrice',axis=1)
features = pd.get_dummies(features,drop_first=True)
## Lanjutan standarisasi nilai
robust.fit(features)
robust_data = robust.transform(features)
features = pd.DataFrame(robust_data,columns=features.columns)
target = df['totalPrice']

# %%
## Train test split
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.1, random_state=101)

# %%
parameters = {
    'max_depth' : [None],
    'min_samples_split' : [10],
    'min_samples_leaf' : [7],
    'n_estimators' : [150]
}

# %%
rf = RandomForestRegressor(random_state=101)

# %%
grid_rf = GridSearchCV(estimator = rf,
                        param_grid = parameters,
                        scoring='neg_root_mean_squared_error',cv=5,n_jobs=-1
                       )

# %%
grid_rf.fit(x_train,y_train)

# %%
# Prediction with data train
predictions_train = grid_rf.predict(x_train)
print('RMSE : ', np.sqrt(metrics.mean_squared_error(y_train,predictions_train)))
print('R2 Score : ', r2_score(y_train,predictions_train))
f, axes = plt.subplots(1,2,figsize=(20,10))
sns.regplot(x = y_train, y = predictions_train,ax = axes[0])
sns.distplot((y_train-predictions_train),ax = axes[1])

# %%
# Prediction with data test
predictions_test = grid_rf.predict(x_test)
print('RMSE : ', np.sqrt(metrics.mean_squared_error(y_test,predictions_test)))
print('R2 Score : ', r2_score(y_test,predictions_test))
f, axes = plt.subplots(1,2,figsize=(20,10))
sns.regplot(x = y_test, y = predictions_test,ax = axes[0])
sns.distplot((y_test-predictions_test),ax = axes[1])

# %%
grid_rf.best_params_

# %% [markdown]
# ================================================================================================================================

# %% [markdown]
# With the results of the training model above, the best model is ** III.8 Random Forest Regressor with Parameter II ** with the lowest RMSE value of 124.3104488455155 than the other models.
#
# Details of model training
# - Amount of data: 316448
# - Data Train: 90%
# - Test data: 10%
# - Algorithm: Random Forest Regressor
# - Standardized Value: Robust Scaller
# - The training method used: GridSearch CV
# - Best parameter: ('max_depth': None,
#   'min_samples_leaf': 5,
#   'min_samples_split': 6,
#   'n_estimators': 120}
