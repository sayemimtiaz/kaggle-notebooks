# %%
import pandas as pd

totalTable = pd.read_csv("/kaggle/input/weather-dataset-rattle-package/weatherAUS.csv")
mainTable = totalTable[["Date", "Rainfall"]]

RainFallMax = mainTable["Rainfall"].max()
Date = mainTable.loc[RainFallMax, "Date"]


tableDateRainFallMax = pd.DataFrame({
    'Date': Date,
    'RainFall': RainFallMax
}, index=[0])

display(tableDateRainFallMax)

# %% [markdown]
# -  In date 2009-12-07 was rain 371 mm on Australia, the biggest registry of rain of coutry;
