# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("../input/credit-card-customers/BankChurners.csv")

# %%
df.head(25)

# %%
df["Attrition_Flag"].value_counts().plot.bar()

# %% [markdown]
# # Existing Customer

# %%
df2 = df[(df['Attrition_Flag'] == 'Existing Customer')]
df2.head()

# %%
df2["Customer_Age"].value_counts().reset_index()

# %%
plt.figure(figsize=(10,5))
df2["Customer_Age"].value_counts().plot.bar()

# %%
df2["Gender"].value_counts().reset_index()

# %%
df2["Gender"].value_counts().plot.pie()

# %%
df2["Dependent_count"].value_counts().reset_index()

# %%
df2["Dependent_count"].value_counts().plot.pie()

# %%
df2["Education_Level"].value_counts().reset_index()

# %%
df2["Education_Level"].value_counts().plot.bar()

# %%
df2["Marital_Status"].value_counts().reset_index()

# %%
df2["Marital_Status"].value_counts().plot.bar()

# %%
df2["Income_Category"].value_counts().reset_index()

# %%
plt.figure(figsize=(10,5))
df2["Income_Category"].value_counts().plot.line()

# %%
df2["Card_Category"].value_counts().reset_index()

# %%
df2["Card_Category"].value_counts().plot.line()

# %% [markdown]
# # Attrited Customer

# %%
df3 = df[(df['Attrition_Flag'] == 'Attrited Customer')]
df3.head()

# %%
df3["Customer_Age"].value_counts().reset_index()

# %%
plt.figure(figsize=(10,5))
df3["Customer_Age"].value_counts().plot.bar()

# %%
df3["Gender"].value_counts().reset_index()

# %%
df3["Gender"].value_counts().plot.pie()

# %%
df3["Dependent_count"].value_counts().reset_index()

# %%
df3["Dependent_count"].value_counts().plot.pie()

# %%
df3["Education_Level"].value_counts().reset_index()

# %%
df3["Education_Level"].value_counts().plot.bar()

# %%
df3["Marital_Status"].value_counts().reset_index()

# %%
df3["Marital_Status"].value_counts().plot.bar()

# %%
df3["Income_Category"].value_counts().reset_index()

# %%
plt.figure(figsize=(10,5))
df3["Income_Category"].value_counts().plot.line()

# %%
df3["Card_Category"].value_counts().reset_index()

# %%
df3["Card_Category"].value_counts().plot.line()

# %% [markdown]
# #  Exploratory Data Analysis

# %%
import seaborn as sns

# %%
plt.subplots(figsize=(20,5))
sns.scatterplot(data=df,y="Total_Trans_Ct",x="Total_Trans_Amt",hue="Attrition_Flag")

# %%
plt.subplots(figsize=(20,5))
sns.scatterplot(data=df,y="Total_Trans_Ct",x="Months_Inactive_12_mon",hue="Attrition_Flag")

# %%
plt.subplots(figsize=(20,5))
sns.scatterplot(data=df,y="Total_Trans_Ct",x="Credit_Limit",hue="Attrition_Flag")

# %%
plt.subplots(figsize=(20,5))
sns.scatterplot(data=df,y="Total_Trans_Ct",x="Customer_Age",hue="Attrition_Flag")
