# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_2015 = pd.read_csv('../input/world-happiness/2015.csv')
data_2016 = pd.read_csv('../input/world-happiness/2016.csv')
data_2017 = pd.read_csv('../input/world-happiness/2017.csv')
data_2018 = pd.read_csv('../input/world-happiness/2018.csv')
data_2019 = pd.read_csv('../input/world-happiness/2019.csv')

# %%
data_2015.head()

# %%
data_2015.info()

# %%
data_2016.head()

# %%
data_2016.info()

# %%
data_2017.head()

# %%
data_2017.info()

# %%
data_2018.head()

# %%
data_2018.info()

# %%
data_2019.head()

# %%
data_2019.info()

# %% [markdown]
# # 2015

# %%
df_2015 = data_2015[(data_2015["Country"]=="Bhutan") |(data_2015["Country"]=="China")|(data_2015["Country"]=='Nepal') |(data_2015["Country"]=='Afghanistan')|(data_2015["Country"]=='India')|(data_2015["Country"]=='Pakistan')|(data_2015["Country"]=='Bangladesh')|(data_2015["Country"]=='Myanmar')]

# %%
df_2015

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df_2015,x="Country",y="Health (Life Expectancy)",marker='o')
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df_2015,x="Country",y="Economy (GDP per Capita)",marker='o')
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df_2015,x="Country",y="Freedom",marker='o')
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df_2015,x="Country",y="Trust (Government Corruption)",marker='o')
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df_2015,x="Country",y="Generosity",marker='o')
plt.show()

# %% [markdown]
# # 2016

# %%
df_2016 = data_2016[(data_2016["Country"]=="Bhutan") |(data_2016["Country"]=="China")|(data_2016["Country"]=='Nepal') |(data_2016["Country"]=='Afghanistan')|(data_2016["Country"]=='India')|(data_2016["Country"]=='Pakistan')|(data_2016["Country"]=='Bangladesh')|(data_2016["Country"]=='Myanmar')]

# %%
df_2016

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df_2016,x="Country",y="Health (Life Expectancy)",marker='o')
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df_2016,x="Country",y="Economy (GDP per Capita)",marker='o')
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df_2016,x="Country",y="Freedom",marker='o')
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df_2016,x="Country",y="Trust (Government Corruption)",marker='o')
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df_2016,x="Country",y="Generosity",marker='o')
plt.show()

# %% [markdown]
# # 2017

# %%
df_2017 = data_2017[(data_2017["Country"]=="Bhutan") |(data_2017["Country"]=="China")|(data_2017["Country"]=='Nepal') |(data_2017["Country"]=='Afghanistan')|(data_2017["Country"]=='India')|(data_2017["Country"]=='Pakistan')|(data_2017["Country"]=='Bangladesh')|(data_2017["Country"]=='Myanmar')]

# %%
df_2017

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df_2017,x="Country",y="Health..Life.Expectancy.",marker='o')
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df_2017,x="Country",y="Economy..GDP.per.Capita.",marker='o')
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df_2017,x="Country",y="Freedom",marker='o')
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df_2017,x="Country",y="Trust..Government.Corruption.",marker='o')
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df_2017,x="Country",y="Generosity",marker='o')
plt.show()

# %% [markdown]
# # 2018

# %%
df_2018 = data_2018[(data_2018["Country or region"]=="Bhutan") |(data_2018["Country or region"]=="China")|(data_2018["Country or region"]=='Nepal') |(data_2018["Country or region"]=='Afghanistan')|(data_2018["Country or region"]=='India')|(data_2018["Country or region"]=='Pakistan')|(data_2018["Country or region"]=='Bangladesh')|(data_2018["Country or region"]=='Myanmar')]

# %%
df_2018

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df_2018,x="Country or region",y="Healthy life expectancy",marker='o')
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df_2018,x="Country or region",y="GDP per capita",marker='o')
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df_2018,x="Country or region",y="Freedom to make life choices",marker='o')
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df_2018,x="Country or region",y="Perceptions of corruption",marker='o')
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df_2018,x="Country or region",y="Generosity",marker='o')
plt.show()

# %% [markdown]
# # 2019

# %%
df_2019 = data_2019[(data_2019["Country or region"]=="Bhutan") |(data_2019["Country or region"]=="China")|(data_2019["Country or region"]=='Nepal') |(data_2019["Country or region"]=='Afghanistan')|(data_2019["Country or region"]=='India')|(data_2019["Country or region"]=='Pakistan')|(data_2019["Country or region"]=='Bangladesh')|(data_2019["Country or region"]=='Myanmar')]

# %%
df_2019

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df_2019,x="Country or region",y="Healthy life expectancy",marker='o')
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df_2019,x="Country or region",y="GDP per capita",marker='o')
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df_2019,x="Country or region",y="Freedom to make life choices",marker='o')
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df_2019,x="Country or region",y="Perceptions of corruption",marker='o')
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df_2019,x="Country or region",y="Generosity",marker='o')
plt.show()
