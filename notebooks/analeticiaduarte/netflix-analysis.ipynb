# %% [markdown]
# * First we import the libraries witch tools we are going to use:

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# After that, we import our csv table which is here in the diretory of kaggle:

# %%
netflix_movies_file = '../input/netflix-shows/netflix_titles.csv'

# %%
netflix_movies = pd.read_csv(netflix_movies_file)

# %% [markdown]
# After that, we add the following line to see the firts 5 rows of the table:

# %%
netflix_movies.head()

# %% [markdown]
# To make the correct use of the data we call the attribute dtypes, and se what kinds of data are we dealing with

# %%
netflix_movies.dtypes

# %% [markdown]
# To dissmiss the missing values, we call the function dropna()

# %%
netflix_mdata = netflix_movies.dropna()

# %%
netflix_mdata.isnull().sum()

# %% [markdown]
# Here, we are sure that there is no row w/ missing values in the dataframe

# %%
netflix_mdata.describe()

# %% [markdown]
# As we saw in outline 17, the only variables who got numerical values are 'show_id' and 'release_year'. In the out 20 we got the descriptive statistics from both.

# %%
sns.boxplot(x="type", y="release_year", data=netflix_mdata)

# %% [markdown]
# > With this boxplot we can see that Netflix is a stream that hasn't TV shows of the eighties and back, so if you are an old school style that are looking for some old vintage series, Netflix may not be the best stream for you.

# %%
netflix_mdata['type'].value_counts().to_frame()

# %% [markdown]
# As netflix has a very different number of films and TV shows, to analyze genres and nationalities, we will create new dataframes for each of the types

# %%
movies_filter = netflix_mdata['type'] == 'Movie'
tvshow_filter = netflix_mdata['type'] == 'TV Show'
movies_netflix = netflix_mdata[movies_filter]
tvshows_netflix = netflix_mdata[tvshow_filter]

# %%
movies_netflix.head()

# %%
from collections import Counter
genre_1 = movies_netflix['listed_in']
genre_count = pd.Series(dict(Counter(','.join(genre_1).replace(' ,',',').replace(', ',',')
                                       .split(',')))).sort_values(ascending=False)

genre_count

# %%
geners = list(genre_count.keys())
numbers = list(genre_count)

# %%
plt.barh(geners,numbers,color='Purple')
plt.ylabel('Tags of netflix')
plt.xlabel('Number of films w/ the tag')
plt.title('Number of films per gender netflix')
plt.figure(figsize=(20,12))

# %%
genre_1 = tvshows_netflix['']
genre_count = pd.Series(dict(Counter(','.join(genre_1).replace(' ,',',').replace(', ',',')
                                       .split(',')))).sort_values(ascending=False)

genre_count
