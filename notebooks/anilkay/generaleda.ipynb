# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt #import plotting modules
import seaborn as sns
# %matplotlib inline
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.

# %%
data=pd.read_csv("../input/master.csv")
data.head()

# %%
data["generation"].groupby(data["generation"]).count()

# %% [markdown]
# Generation is commit most suicides between this years. Millenials and Silent also have higher suicide rates

# %%
 sns.countplot(x="sex",data=data,palette="Greens_d")

# %% [markdown]
# Males is equal female and it's interesting.

# %%
 sns.countplot(x="age",data=data)

# %% [markdown]
# ages range also have same values and this is also interesting.

# %%
pd.DataFrame(data["suicides/100k pop"]).describe()

# %% [markdown]
# it is interesting data.

# %%
sns.lmplot(data=data,x="population",y="suicides/100k pop")

# %% [markdown]
# This plot is very ugly because population is too bigger than suicides 100k pop

# %%
fgrid = sns.lmplot(data=data,x="population",y="suicides/100k pop")
ax = fgrid.axes[0][0]
ax.set_xscale('log')
ax

# %% [markdown]
# Scale with log but too much data point in this data and it's problem.

# %%
#gdp_per_capita ($)
sns.lmplot(data=data,x="gdp_per_capita ($)",y="suicides/100k pop")

# %% [markdown]
# We see outlier values suicide suicides/100k pops outlier values is bigger than 150

# %%
withoutoutlier=data[data["suicides/100k pop"]<=150]
sns.lmplot(data=withoutoutlier,x="gdp_per_capita ($)",y="suicides/100k pop")

# %% [markdown]
# More clear plot. gdp per capita also has outlier values .

# %%
withoutoutlier=data[data["suicides/100k pop"]<=150]
withoutoutlier=withoutoutlier[data["gdp_per_capita ($)"]<=60000]
sns.lmplot(data=withoutoutlier,x="gdp_per_capita ($)",y="suicides/100k pop")

# %% [markdown]
# This dataset has too many values and because of this plotting can't work fine

# %%
data["suicides/100k pop"].groupby(data["generation"]).mean()

# %% [markdown]
# This aggeragation is more clear. GI and SİLent has more suicide rates

# %%
data["suicides/100k pop"].groupby(data["sex"]).mean()

# %% [markdown]
# İnteresting

# %%
plt.figure(figsize=(15,4)) 
sns.countplot(x="year",data=data)
plt.show()

# %% [markdown]
# 2000s has more suicides. One of the Most suicides is 2009 and it's economic cris years. 2015 is look so good.
