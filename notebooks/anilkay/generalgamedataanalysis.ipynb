# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
data=pd.read_csv("/kaggle/input/videogamesales/vgsales.csv")
data.head()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.figure(figsize=(20,15))
sns.countplot(data=data,x="Platform")

# %% [markdown]
# Ps2 and Ds has leads all conssole. I remember WiiU failure, Every tech journalist say Nintende is near to end. Nintendo Switch rules the consoles.

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=data,x="Genre")

# %% [markdown]
# Interesting shooter is less than Sports.

# %%
data.sort_values(by="Global_Sales",ascending=False)[["Name","Global_Sales"]][0:20]

# %% [markdown]
# Nearly All game is Nintendo or Nintendo only games. GTA's also here.

# %%
data.groupby(by="Name").sum()["Global_Sales"].sort_values(ascending=False)[0:21]

# %% [markdown]
# Multiplatform games is can't pass Wii Sports. Hovewer we see Call of Duties.

# %%
data.groupby(by="Name").sum()["Global_Sales"].sort_values(ascending=False)[21:40]

# %% [markdown]
# Fifa's here.

# %%
data.groupby(by="Name").sum()["Global_Sales"].sort_values(ascending=False)[40:51]

# %% [markdown]
# Which game is best selling games for each console?

# %%
maxlist=[]
for i in list(data.groupby(by="Platform")[["Global_Sales"]].idxmax().values):
    maxlist.append(int(i))
data.loc[maxlist][["Platform","Name","Global_Sales"]]

# %% [markdown]
# * Psp's most saled game is Gta Liberty City Stories. İt is interesting, It's hard to play 3d Gta in PSP (Only 1 Analog).
# * Ps3 GTA 5
# * Pokemon games is also shining
# * The Sims 3 leads PC. I think Counter Strike has more PC users than Sİms 3

# %% [markdown]
# Which Genre has most Saled?

# %%
data.groupby(by="Genre")["Global_Sales"].sum().sort_values(ascending=False)

# %%
data.groupby(by=["Genre","Year"])["Global_Sales"].sum().sort_values(ascending=False)[0:25]

# %%
data.groupby(by="Year")["Global_Sales"].sum().sort_values(ascending=False)

# %% [markdown]
# ## 2007-2011 best years of human history!!!

# %%
data.groupby(by="Publisher").count().sort_values(by="Name",ascending=False)["Rank"][0:25]

# %% [markdown]
# Codemasters is good firm.

# %%
data.groupby(by="Publisher")["Global_Sales"].sum().sort_values(ascending=False)[0:25]

# %% [markdown]
# Where is PES games?

# %%
data[data["Name"].str.contains("Pro Ev")].groupby(by="Name").sum()

# %% [markdown]
# Pes game is not saled much. İt is interesting.

# %% [markdown]
# Where is the NBA games

# %%
data[data["Name"].str.contains("NBA")].groupby(by="Name").sum().sort_values(by="Global_Sales"
,ascending=False).iloc[:,2:][0:20]

# %% [markdown]
# 2k10 has only 2.92 and famous Jordan game 2k11 make the leap 5.42. After 2k11 eleven there is no competition.Story Matters.

# %% [markdown]
# What about NFS (Need For Speed) games?

# %%
data[data["Name"].str.contains("Need")].groupby(by="Name").sum().sort_values(by="Global_Sales"
,ascending=False).iloc[:,2:][0:20]

# %% [markdown]
# 2 Most Wanted game. Most Wanted is saled most because of 2 release.
# Underground 2 and Underground is one of the best games.

# %% [markdown]
# Most Selling Games by Genre:

# %%
maxlist=[]
for i in list(data.groupby(by="Genre")[["Global_Sales"]].idxmax().values):
    maxlist.append(int(i))
data.loc[maxlist][["Genre","Name","Global_Sales"]]

# %% [markdown]
# Most Selling Racing game is Mario Kart??? İt is interesting. Duck Hunt is most selling Shooter.

# %%
data[data["Genre"]=="Racing"].groupby(by="Name").sum().sort_values(by="Global_Sales",ascending=False)[0:10]

# %%
for genre in set(data["Genre"]):
    print(genre,": ",end="")
    temp=data[data["Genre"]==genre].groupby(by="Name").sum().sort_values(by="Global_Sales"
             ,ascending=False)[["Global_Sales"]][0:1]
    print(temp[0:1].index[0],end=" ")
    print(temp[0:1].values[0][0])

# %% [markdown]
# Most Selling Shooter is Call Of Duty Blackops. Mario Kart is most selling racing game. GTA 5 most selling action game. Wii is a very succesful console.

# %% [markdown]
# ### Also GTA 5 sells more than Tetris it is also interesting. Everybody plays Tetris but GTA needs certain hardware requirement

# %% [markdown]
# Age of Series:

# %%
data[(data["Name"].str.contains("Age of Emp"))|(data["Name"].str.contains("Age of Myt"))].sort_values(
    by="Global_Sales",ascending=False)

# %% [markdown]
# İn My Gebze Days Everybody plays Age Of Mythology. Probably Only Gebze residents play Mythology game :)
# Or Pirating.

# %% [markdown]
# Most Saled Pc Strategy Games:

# %%
data[(data["Genre"]=="Strategy")&(data["Platform"]=="PC")].sort_values(by="Global_Sales"
                                                  ,ascending=False)[["Name","Year","Global_Sales"]][0:20]

# %% [markdown]
# Command and Conquer. Spore is very good game but it's not a pure Strategy Game. Total War Games is hard to play for newcomers.
