# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

selected_country_1 = 'New Zealand'
selected_country_2 = 'New Zealand'

df1 = pd.read_csv('../input/covid19-global-dataset/worldometer_coronavirus_daily_data.csv', header = 0)
df1 = df1[df1['country']==selected_country_1]
df2 = pd.read_csv('../input/covid-world-vaccination-progress/country_vaccinations.csv', header = 0)
df2 = df2[df2['country']==selected_country_2]
df1.index = pd.to_datetime(df1['date'])
df2.index = pd.to_datetime(df2['date'])
print (df2)

# %% [markdown]
# ## COUNTRY SELECTION
#
# I have selected New Zealand as a case study of this Assignment 6. It reports 2667 total cases.
# New Zealand takes early and hard action to tackle COVID-19.

# %%
print(df1.columns)
print(df2.columns)

# %%
print(np.unique(df1['country']))
print(np.unique(df2['country']))

# %%
fig,ax = plt.subplots(figsize=(10,5))
ax.plot(df1.index,df1['daily_new_cases'])
ax1 = ax.twinx()
ax1.plot(df2.index,df2['daily_vaccinations'], 'r')
ax1.legend()
plt.show()

# %% [markdown]
# # Improved Time-series Visualization
# From here, we will be suing the modules iplot and plotly to make better visualizations.
#
# Time-series and colored tables for Daily COVID-19 cases and Daily vaccinations

# %%
from plotly.offline import iplot
import plotly.graph_objs as go

daily_new_cases = go.Scatter(x=df1.index, y=df1['daily_new_cases'], yaxis='y1', name='Daily Confirmed Cases')
daily_vaccinations = go.Scatter(x=df2.index, y=df2['daily_vaccinations'], yaxis='y2', name='Daily Vaccinations')

layout_obj = go.Layout(title='COVID vs. Vaccines', xaxis=dict(title='Date'), yaxis=dict(title='Daily cases'), yaxis2=dict(title='Vaccinations', side='right',overlaying='y'))
fig = go.Figure(data=[daily_new_cases,daily_vaccinations], layout=layout_obj)
iplot(fig)
fig.write_html ('outcome.html')

# %% [markdown]
# ## Inspection and Discussion of COVID 19 cases and Vaccinations
#
#
# The time series colored plots have been drawn for Daily COVID-19 cases and Daily vaccinations at New Zealand. From the figure, we can observe that initially in March, 2020 and April, 2020 - the cases were high in New Zealand. However, later due to border restriction and proper measure help the country to curb further Covid 19 Peaks. Also, The vaccination here started from February, 2021 and now it is at its peak for vaccination at the country. Vaccination per 100 in New Zealand is 3.96
#
# The global ranking of New Zealand in terms of the total number of cases from the least side is 41.
# The global ranking of New Zealand in terms of  total vaccinations per hundred is 75 from the least side.
#
# ## Governement Initiatives
#
# Newspaper link:
#
# https://www.bbc.com/news/world-asia-53274085
#
# https://www.who.int/westernpacific/news/feature-stories/detail/new-zealand-takes-early-and-hard-action-to-tackle-covid-19
#
# Both of the links explain how New Zealand become Covid-19 free.

# %% [markdown]
# ## Colored Tables
#
# Create colored tables.

# %%
style_object=df1.style.background_gradient (cmap= 'jet').highlight_max('daily_new_cases').set_caption('Daily Cases')
display(style_object)

# %% [markdown]
# ## Ranking
#
# Ranking of the country based on vaccination data

# %%
df1 = pd.read_csv('../input/covid19-global-dataset/worldometer_coronavirus_daily_data.csv', header = 0)
df1 = df1.groupby('country').sum()['daily_new_cases'].sort_values(ascending=True)[0:200]
df2 = pd.read_csv('../input/covid-world-vaccination-progress/country_vaccinations.csv', header = 0)
df2 = df2.groupby('country').max()['people_fully_vaccinated_per_hundred'].sort_values(ascending=False)
print(df1.to_string())
print(df2.to_string())

# %% [markdown]
# ## Ranking
#
# The global ranking of New Zealand in terms of the total number of cases from the least side is 41.
# The global ranking of New Zealand in terms of  total vaccinations per hundred is 75 from the least side.
