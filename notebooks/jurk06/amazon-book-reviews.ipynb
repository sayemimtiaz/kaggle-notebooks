# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np
#plotly
import seaborn as sns
import matplotlib.pyplot as plt

from pandas import plotting
#plotly
import plotly.offline as py
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
init_notebook_mode(connected=True)
import plotly.figure_factory as ff
import plotly.express as px

# %%
df=pd.read_csv('../input/amazon-top-50-bestselling-books-2009-2019/bestsellers with categories.csv')
df.head()

# %%
df.isnull().sum()

# %% [markdown]
# # Count of Genre

# %%
df['Genre'].value_counts().plot(kind='barh', figsize=(10,10))
plt.grid(b=True, which='both')

# %%
dat=ff.create_table(df.head(10))
py.iplot(dat)

# %%
# checks if there is any null value or not
df.isnull().any().any()

# %%
plt.rcParams['figure.figsize'] = (9, 9)
labels=['Non-Fiction', 'Fiction']
plt.pie(df['Genre'].value_counts(), explode=(0,0.1), labels=labels,autopct='%1.1f%%', shadow=True)
plt.title('Type ', fontsize = 20)
plt.axis('off')
plt.legend()
plt.show()

# %%
col = "Genre"
grouped = df[col].value_counts().reset_index()
grouped = grouped.rename(columns = {col : "count", "index" : col})

## plot
trace = go.Pie(labels=grouped[col], values=grouped['count'], pull=[0.05, 0], marker=dict(colors=["#6ad49b", "#a678de"]))
layout = go.Layout(title="", height=600, legend=dict(x=0.1, y=1.1))
fig = go.Figure(data = [trace], layout = layout)
iplot(fig)

# %%
col = "Year"
grouped = df[col].value_counts().reset_index()
grouped = grouped.rename(columns = {col : "count", "index" : col})

## plot
plt.figure(figsize=(10,10))
trace = go.Pie(labels=grouped[col], values=grouped['count'], pull=[0.05, 0], marker=dict(colors=["#6ad49b", "#a678de"]))
layout = go.Layout(title="", height=800, legend=dict(x=0.1, y=1.1))
fig = go.Figure(data = [trace], layout = layout)
iplot(fig)

# %%
df['Genre'].value_counts().plot(kind='barh')

# %% [markdown]
# **Obs**
# * The data is equally distributed
# * It can be seen that the data well separated

# %%
d1 = df[df["Genre"] == "Fiction"]
d2 = df[df["Genre"] == "Non Fiction"]

col = "Year"

vc1 = d1[col].value_counts().reset_index()
vc1 = vc1.rename(columns = {col : "count", "index" : col})
vc1['percent'] = vc1['count'].apply(lambda x : 100*x/sum(vc1['count']))
vc1 = vc1.sort_values(col)

vc2 = d2[col].value_counts().reset_index()
vc2 = vc2.rename(columns = {col : "count", "index" : col})
vc2['percent'] = vc2['count'].apply(lambda x : 100*x/sum(vc2['count']))
vc2 = vc2.sort_values(col)

trace1 = go.Scatter(x=vc1[col], y=vc1["count"], name="Fiction", marker=dict(color="#a678de"))
trace2 = go.Scatter(x=vc2[col], y=vc2["count"], name="Non Fiction", marker=dict(color="#6ad49b"))
data = [trace1, trace2]
layout = go.Layout(title="Content added over the years", legend=dict(x=0.1, y=1.1, orientation="h"))
fig = go.Figure(data, layout=layout)
fig.show()

# %%
df.head()

# %%
d1 = df[df["Genre"] == "Fiction"]
d2 = df[df["Genre"] == "Non Fiction"]

col = "Year"

vc1 = d1[col].value_counts().reset_index()
vc1 = vc1.rename(columns = {col : "count", "index" : col})
vc1['percent'] = vc1['count'].apply(lambda x : 100*x/sum(vc1['count']))
vc1 = vc1.sort_values(col)

vc2 = d2[col].value_counts().reset_index()
vc2 = vc2.rename(columns = {col : "count", "index" : col})
vc2['percent'] = vc2['count'].apply(lambda x : 100*x/sum(vc2['count']))
vc2 = vc2.sort_values(col)

trace1 = go.Bar(x=vc1[col], y=vc1["count"], name="Fiction", marker=dict(color="#a678de"))
trace2 = go.Bar(x=vc2[col], y=vc2["count"], name="Non Fiction", marker=dict(color="#6ad49b"))
data = [trace1, trace2]
layout = go.Layout(title="Content added over the years", legend=dict(x=0.1, y=1.1, orientation="h"))
fig = go.Figure(data, layout=layout)
fig.show()

# %%
d1 = df[df["Genre"] == "Fiction"]
d2 = df[df["Genre"] == "Non Fiction"]

col = "Genre"

vc1 = d1[col].value_counts().reset_index()
vc1 = vc1.rename(columns = {col : "count", "index" : col})
vc1['percent'] = vc1['count'].apply(lambda x : 100*x/sum(vc1['count']))
vc1 = vc1.sort_values(col)

vc2 = d2[col].value_counts().reset_index()
vc2 = vc2.rename(columns = {col : "count", "index" : col})
vc2['percent'] = vc2['count'].apply(lambda x : 100*x/sum(vc2['count']))
vc2 = vc2.sort_values(col)

trace1 = go.Bar(x=vc1[col], y=vc1["count"], name="Fiction", marker=dict(color="#a678de"))
trace2 = go.Bar(x=vc2[col], y=vc2["count"], name="Non Fiction", marker=dict(color="#6ad49b"))
data = [trace1, trace2]
layout = go.Layout(title="Content added over the years", legend=dict(x=0.1, y=1.1, orientation="h"))
fig = go.Figure(data, layout=layout)
fig.show()

# %%
df.columns

# %%
df['User Rating'].sort_values(ascending=False).iloc[1:21].plot(kind='barh', figsize=(15,15))
plt.grid(b=True)
plt.show()

# %%
df['Reviews'].sort_values(ascending=False).iloc[1:21].plot(kind='barh', figsize=(15,15))
plt.grid(b=True)
plt.show()

# %%
col = "User Rating"

vc1 = d1[col].value_counts().reset_index()
vc1 = vc1.rename(columns = {col : "count", "index" : col})
vc1['percent'] = vc1['count'].apply(lambda x : 100*x/sum(vc1['count']))
vc1 = vc1.sort_values(col)

vc2 = d2[col].value_counts().reset_index()
vc2 = vc2.rename(columns = {col : "count", "index" : col})
vc2['percent'] = vc2['count'].apply(lambda x : 100*x/sum(vc2['count']))
vc2 = vc2.sort_values(col)

trace1 = go.Bar(x=vc1[col], y=vc1["count"], name="Fiction", marker=dict(color="#a678de"))
trace2 = go.Bar(x=vc2[col], y=vc2["count"], name="Non-Fiction", marker=dict(color="#6ad49b"))
data = [trace1, trace2]
layout = go.Layout(title="Rating count of Fiction and Non-Fiction show", legend=dict(x=0.1, y=1.1, orientation="h"))
fig = go.Figure(data, layout=layout)
fig.show()

# %%
df.columns

# %%
col = "Author"

vc1 = d1[col].value_counts().reset_index()
vc1 = vc1.rename(columns = {col : "count", "index" : col})
vc1['percent'] = vc1['count'].apply(lambda x : 100*x/sum(vc1['count']))
vc1 = vc1.sort_values(col)

vc2 = d2[col].value_counts().reset_index()
vc2 = vc2.rename(columns = {col : "count", "index" : col})
vc2['percent'] = vc2['count'].apply(lambda x : 100*x/sum(vc2['count']))
vc2 = vc2.sort_values(col)

trace1 = go.Bar(x=vc1[col], y=vc1["count"], name="Fiction", marker=dict(color="#a678de"))
trace2 = go.Bar(x=vc2[col], y=vc2["count"], name="Non-Fiction", marker=dict(color="#6ad49b"))
data = [trace1, trace2]
layout = go.Layout(title="Rating count of Fiction and Non-Fiction show", legend=dict(x=0.1, y=1.1, orientation="h"))
fig = go.Figure(data, layout=layout)
fig.show()

# %%
df['Author'].value_counts().sort_values(ascending=False).iloc[1:21].plot(kind='barh', figsize=(15,15))
plt.grid(b=True)
plt.show()

# %%
df['Author'].value_counts().sort_values(ascending=False).iloc[1:51].plot(kind='barh', figsize=(15,15))
plt.grid(b=True)
plt.show()

# %%
df.head()

# %%
df.shape

# %%
for i in df.columns:
    null_rate=df[i].isnull().sum()/len(df)*100
    if null_rate>0:
        print("{} 's null rate {}%".format(i, round(null_rate,2)))

# %% [markdown]
# **Obs**
# * There is no null value

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

x = df['Year']
y = df['User Rating']
z = df['Reviews']

ax.set_xlabel("Year")
ax.set_ylabel("User Review")
ax.set_zlabel("Ratings")

ax.scatter(x, y, z)

plt.show()

# %%
df.columns

# %%
import plotly.express as px
fig = px.scatter_3d(df, x='Year', y='Reviews', z='User Rating',
              color='Genre')
fig.show()

# %%
import plotly.express as px
fig = px.scatter(y=df['User Rating'], x=df['Reviews'])
fig.show()

# %%
df.columns

# %% [markdown]
# # Word cloud of the Fiction Book's Author

# %%
from wordcloud import WordCloud,STOPWORDS

text=' '.join(d1['Author'])

plt.rcParams['figure.figsize']=(15,15)
wordcloud=WordCloud(background_color='black', colormap='vlag', width=1200, height=1200, max_words=121).generate(text)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# # Word cloud of the Non-Fiction Book's Author

# %%
text=' '.join(d2['Author'])

plt.rcParams['figure.figsize']=(15,15)
wordcloud=WordCloud(background_color='black', colormap='vlag', width=1200, height=1200, max_words=121).generate(text)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
Ratings = df['User Rating'].value_counts()
Visualization = px.funnel(Ratings,title='Types of Rating on Netflix')

Visualization.show()
