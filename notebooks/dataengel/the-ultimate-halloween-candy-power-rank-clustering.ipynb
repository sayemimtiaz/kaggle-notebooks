# %%
# Import the libraries

import pandas as pd
import matplotlib as plt 

from sklearn.cluster import MeanShift

# %%
# Load and show the dataset 

df_candy = pd.read_csv('../input/the-ultimate-halloween-candy-power-ranking/candy-data.csv')
df_candy.head()

# %%
# We gonna drop the string colum

X = df_candy.drop('competitorname', axis=1)

# %%
# We gonna fit the model

meanshift = MeanShift().fit(X)

# %%
# The algoritm return the nums of clusters

max(meanshift.labels_)

# %%
# We gonna show the location of the centers that you put on our data

meanshift.cluster_centers_

# %%
# And like the last one, we gonna add the location of centens in the original dataset 

df_candy['meanshift'] = meanshift.labels_
df_candy.head()

# %%
# Import MiniBatchKMeans 

from sklearn.cluster import MiniBatchKMeans

# %%
# We group in 4, by groups of 8 

kmeans = MiniBatchKMeans(n_clusters=4, batch_size=8).fit(X)

# %%
# We show the total of centers 

len(kmeans.cluster_centers_)

# %%
# Return an array with every category of candies 

kmeans.predict(X)

# %%
# Adding the groups results in the original dataset

df_candy['MiniBatchKMeans'] = kmeans.predict(X)
df_candy
