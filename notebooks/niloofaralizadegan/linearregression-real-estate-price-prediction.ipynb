# %% [markdown]
# **Linear Regression**
# > is a linear approach for modelling the relationship between a scalar response and one or more explanatory variables (also known as dependent and independent variables).

# %% [markdown]
# > In linear regression, the relationships are modeled using linear predictor functions whose unknown model parameters are estimated from the data. Such models are called linear models

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('../input/real-estate-price-prediction/Real estate.csv')

# %% [markdown]
# **an overview on data frame**

# %%
df.head()

# %%
df.info()

# %%
df.shape

# %% [markdown]
# **EDA: the more EDA you do, the information you get from dataset**

# %%
sns.pairplot(df,diag_kind='kde')

# %% [markdown]
# **it shows the correlation between variables. Note: if some variables have almost 0 corr. we can drop them**

# %%
df.corr()

# %% [markdown]
# **linear regression steps**

# %%
#1:determine features and labels(Target variable)
X=df.drop('Y house price of unit area', axis=1)
y=df['Y house price of unit area']

# %%
X

# %%
y

# %%
#2:split dataset to train and test(using sickit learn)
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.25, random_state=101)

# %%
X_train.shape

# %%
X_test.shape

# %% [markdown]
# **3:Train the model**

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_regression_model= LinearRegression()

# %%
linear_regression_model.fit(X_train,y_train)

# %%
linear_regression_model.coef_ #Betas

# %%
pd.DataFrame(linear_regression_model.coef_ ,X.columns, columns=["coeficients"])

# %% [markdown]
# **prediction(Test)**

# %%
y_pred=linear_regression_model.predict(X_test)

# %% [markdown]
# **Evaluating the model**

# %%
from sklearn import metrics
MAE=metrics.mean_absolute_error(y_test,y_pred)
MSE=metrics.mean_squared_error(y_test,y_pred)
RMSE=np.sqrt(MSE)

pd.DataFrame([MAE,MSE,RMSE],index=['MAE','MSE','RMSE'],columns=['metrics'])

# %%
#compare the metrics to the mean of terget variable
df['Y house price of unit area'].mean() #ssssooooooo bad

# %% [markdown]
# **Residuals**

# %%
test_residual = y_test - y_pred

# %%
sns.displot(test_residual, bins=25,kde=True)

# %%
sns.scatterplot(x=y_test,y=test_residual) #i think it has pattern
plt.axhline(y=0, color='red', ls='--')
