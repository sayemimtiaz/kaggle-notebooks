# %% [markdown]
# # Summer Product Sale Rating

# %% [markdown]
# Guys, welcome to my notebook. This notebook is basiaclly based on the dataset link here : [DATASET](https://www.kaggle.com/jmmvutu/summer-products-and-sales-in-ecommerce-wish) . Hope you guys love it. SO lets get started

# %% [markdown]
# This dataset contains product listings as well as products ratings and sales performance.
#
# With this, you can finally start to look for correlations and patterns regarding the success of a product and the various components.

# %% [markdown]
# ![](https://www.google.com/url?sa=i&url=https%3A%2F%2Funsplash.com%2Fwallpapers%2Fnature%2Fsummer&psig=AOvVaw2etGpaKyLC_8EYSikOlBwC&ust=1600102975664000&source=images&cd=vfe&ved=0CAIQjRxqFwoTCOCbt6TO5usCFQAAAAAdAAAAABAD)

# %% [markdown]
# These datasets contain all data of product like rating, rating count, tag etc.

# %% [markdown]
# Import some essential libraries :

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Datsets :
# * Summer Product Rating Sale
# * Unique Catgories
# * Unique Categories sorted acc to their count

# %% [markdown]
# Hope you guys have a basic idea of these datasets.

# %%
data_summer_rating =  pd.read_csv('../input/summer-products-and-sales-in-ecommerce-wish/summer-products-with-rating-and-performance_2020-08.csv')

# %% [markdown]
# Look our first dataset :

# %%
data_summer_rating.head()

# %%
data_summer_rating.info()

# %% [markdown]
# **HeatMap of any dataset give us an idea of our dataset which has more importance something like that.**

# %%
plt.figure(figsize = (20, 10))
sns.heatmap(data_summer_rating.corr(), annot = True, cmap = 'coolwarm', center = 0)
plt.show()

# %% [markdown]
# Next Dataset is just for Tags so let's import this one too and look at this.

# %%
data_categories = pd.read_csv('../input/summer-products-and-sales-in-ecommerce-wish/unique-categories.csv')

# %% [markdown]
# See here :

# %%
data_categories.head()

# %%
data_categories.info()

# %% [markdown]
# In the pervious dataset, there are only tags but this contains the unique values or categories in sorted form. have a look at this too.

# %%
data_categories_sorted = pd.read_csv('../input/summer-products-and-sales-in-ecommerce-wish/unique-categories.sorted-by-count.csv')

# %%
data_categories_sorted.head()

# %%
data_categories_sorted.info()

# %% [markdown]
# Hope you like this journey. Thanks for reading.

# %% [markdown]
# Give **Upvote** if you like.
