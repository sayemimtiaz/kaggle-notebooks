# %% [markdown]
# # Google Data Analytics Professional
# **Case Study Capstone**
# Ben Felder
# *September 17, 2021*

# %% [markdown]
# ## Case Study 2:  Bellabeat

# %% [markdown]
# **Introduction**
#
# Welcome to the Bellabeat data analysis case study! In this case study, you will perform many real-world tasks of a junior data
# analyst. You will imagine you are working for Bellabeat, a high-tech manufacturer of health-focused products for women, and
# meet different characters and team members. In order to answer the key business questions, you will follow the steps of the
# data analysis process: ask, prepare, process, analyze, share, and act. Along the way, the Case Study Roadmap tables —
# including guiding questions and key tasks — will help you stay on the right path.
# By the end of this lesson, you will have a portfolio-ready case study. Download the packet and reference the details of this case
# study anytime. Then, when you begin your job hunt, your case study will be a tangible way to demonstrate your knowledge
# and skills to potential employers.
#
# [Bellabeat Case Study](https://d18ky98rnyall9.cloudfront.net/QWpX1RwgS1CqV9UcILtQQA_76f613fdf2844940b0b31f8f0bb1b83f_Case-Study-2-_-How-can-a-wellness-technology-company-play-it-smart.pdf?Expires=1632009600&Signature=P72eSLdL-fOJ5VEPzgN5IQx6bIrNrFOFOZujvgMvNSUt8-RoYlb33-6sKQp8QSKNzp5So4umvv102d7~jSXdqxVeVwPy3o7Gvv9CYI-e8o8bgruHaNZgOt1HMbnSB62WwkF2OnJ888qjl-VvJa1Zie4HCD23NPCVi~lCQiTyOvk_&Key-Pair-Id=APKAJLTNE6QMUY6HBC5A)

# %% [markdown]
# **Senario**
#
# You are a junior data analyst working on the marketing analyst team at Bellabeat, a high-tech manufacturer of health-focused
# products for women. Bellabeat is a successful small company, but they have the potential to become a larger player in the
# global smart device market. Urška Sršen, cofounder and Chief Creative Officer of Bellabeat, believes that analyzing smart
# device fitness data could help unlock new growth opportunities for the company. You have been asked to focus on one of
# Bellabeat’s products and analyze smart device data to gain insight into how consumers are using their smart devices. The
# insights you discover will then help guide marketing strategy for the company.
# **You will present your analysis to the Bellabeat executive team along with your high-level recommendations for Bellabeat’s marketing strategy.**

# %% [markdown]
# # Ask
# Sršen asks you to analyze smart device usage data in order to gain insight into how consumers use non-Bellabeat smart
# devices. She then wants you to select one Bellabeat product to apply these insights to in your presentation. These questions
# will guide your analysis:
# 1. What are some trends in smart device usage?
# 2. How could these trends apply to Bellabeat customers?
# 3. How could these trends help influence Bellabeat marketing strategy?

# %% [markdown]
# ### Stakeholders
# 1.  *Urška Sršen:* Cofounder and Chief Creative Officer at Bellabeat
# 2.  *Sando Mur:* Cofounder and Executive at Bellabeat
# 3.  *Marketing Analytics Team:* Team of analysts and marketing strategy at Bellabeat.
#
# #### Products
# 1.  *Bellabeat app:* The Bellabeat app provides users with health data related to their activity, sleep, stress,
# menstrual cycle, and mindfulness habits. This data can help users better understand their current habits and
# make healthy decisions. The Bellabeat app connects to their line of smart wellness products.
# 2.  *Leaf:* Bellabeat’s classic wellness tracker can be worn as a bracelet, necklace, or clip. The Leaf tracker connects
# to the Bellabeat app to track activity, sleep, and stress.
# 3.  *Time:* This wellness watch combines the timeless look of a classic timepiece with smart technology to track user
# activity, sleep, and stress. The Time watch connects to the Bellabeat app to provide you with insights into your
# daily wellness.
# 4.  *Spring:* This is a water bottle that tracks daily water intake using smart technology to ensure that you are
# appropriately hydrated throughout the day. The Spring bottle connects to the Bellabeat app to track your
# hydration levels.

# %% [markdown]
# ### Business Task:
# Identify potential opportunities for growth and recommendations for the Bellabeat marketing strategy improvement based on trends in smart device usage.

# %% [markdown]
# ### Deliverables:
# 1. A clear summary of the business task
# 2. A description of all data sources used
# 3. Documentation of any cleaning or manipulation of data
# 4. A summary of your analysis
# 5. Supporting visualizations and key findings
# 6. Your top high-level content recommendations based on your analysis

# %% [markdown]
# # Prepare

# %% [markdown]
# ## Dataset
#
# Dataset Name: FitBit Fitness Tracker Data
#
# Dataset Description: *These datasets were generated by respondents to a distributed survey via Amazon Mechanical Turk between 03.12.2016-05.12.2016. Thirty eligible Fitbit users consented to the submission of personal tracker data, including minute-level output for physical activity, heart rate, and sleep monitoring. Individual reports can be parsed by export session ID (column A) or timestamp (column B). Variation between output represents use of different types of Fitbit trackers and individual tracking behaviors / preferences. *
#
# Dataset Source: Kaggle
#
# Dataset Link: https://www.kaggle.com/arashnic/fitbit
#
# ***Acknowledgements***
# *Furberg, Robert; Brinton, Julia; Keating, Michael ; Ortiz, Alexa
# https://zenodo.org/record/53894#.YMoUpnVKiP9*

# %% [markdown]
# ### Dataset Integrity Assessment
# 1.  Where is your data stored? Data is stored publicly on Kaggle.com among other websites
# 2.  How is the data organized? Is it in long or wide format? Data is organized in CSV format, both narrow and wide-format included
# 3.  Are there issues with bias or credibility in this data?  Data is biased, credibility is not high as is crowd-sourced and small population
# 4.  How are you addressing licensing, privacy, security, and accessibility? License is CCO: Public Domain, privacy and security are handled by Kaggle Private notebook settings
# 5.  How did you verify the data’s integrity? Data integrity will be handled during EDA phase in Python
# 6.  How does it help you answer your question? Identify trends and usage statistics of smart devices, trends for potential Bellabeat customers, trends to influencev marketing strategy
# 7.  Are there any problems with the data?  Low sample size will not give highest degree of certainty or results of analysis, further analysis with larger dataset would better identify potential growth opportunities

# %% [markdown]
# ### Dataset ROCCC Assessment
# 1.  Reliable - MED - Dataset obtained via Kaggle Public Datasets, external data source, accuracy unknown, biased yes, leading unknown.  CC0: Public Domain, dataset made available through Mobius.
# 2.  Original - MED - Dataset original source not internal data source.
# 3.  Comprehensive - LOW - Dataset shows 30 elibible users submitted personal tracker data.  This is a very small sample size of overal female population and Fitbit userbase. There are 18 CSV files tracking minute-by-minute data on activity, steps, heart rate, intensity, and sleep.
# 4.  Current - LOW - Dataset is current as of April 12, 2016 - May 12, 2016.  Dataset is relevant to EDA.
# 5.  Cited - MED - Source has been cited in the Kaggle Acknowledgements section, crowd-sourced, but unvetted.

# %% [markdown]
# ### Datasources Used
# Outlined in step 2.3.1

# %% [markdown]
# # Process

# %% [markdown]
# 1.  What tools are you choosing and why? Python in Kaggle Notebook.  Easy, safe, secure, markdown shows documentation along with code for future use, adjustments
# 2.  Have you ensured your data’s integrity? Integrity will take place during Step 3 - Data Exploration
# 3.  What steps have you taken to ensure that your data is clean? Cleaning will take place during Step 3 - Data Exploration
# 4.  How can you verify that your data is clean and ready to analyze? Cleaning will take place during Step 3 - Data Exploration
# 5.  Have you documented your cleaning process so you can review and share those results?  Cleaning will take place during Step 3 - Data Exploration

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Importing libraries

# %% [markdown]
# Below are the libraries that are used in order to perform EDA (Exploratory Data Analysis).

# %% [markdown]
# *Pathlib* - Object-oriented filesystem paths
# *Sys* - System-specific parameters and functions
# *OS* - Operating system dependent functionality
# *Pandas* - Data analysis and manipulation tool
# *Numpy* - Multi-dimensional arrays and matrices, and high-level mathematical functions
# *Seaborn* - Statistical data visualizations
# *Matplotlib* - Plotting visualizations

# %%
# Infrastructure
from pathlib import Path
import sys
import os

# Science and Data
import pandas as pd  
import numpy as np

# Plotting Tools
import seaborn as sns
import matplotlib.pyplot as plt

print('Import Libraries Complete')

# %% [markdown]
# Pandas and Plotting Setup Options

# %%
# Pandas
pd.set_option('display.max_rows', 100)
pd.options.display.float_format = "{:,.2f}".format

# Matplotlib
# %matplotlib inline
plt.rcParams['figure.figsize'] = (20, 10)
plt.rcParams['axes.spines.left'] = False
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.bottom'] = False
plt.rcParams['xtick.bottom'] = False
plt.rcParams['xtick.labelbottom'] = True
plt.rcParams['ytick.labelleft'] = True
plt.rcParams.update({'font.size': 18})

print('Library Setup Options Complete')

# %% [markdown]
# Machine Learning using Scikit-Learn
#
# Python Data Science Handbook
# Introducing SciKit-Learn for Google Colab
# [Link](
# https://colab.research.google.com/github/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/05.02-Introducing-Scikit-Learn.ipynb#scrollTo=cXpxypZgp8xH)

# %%
'''
import sklearn as sk

print('Machine Learning Library Complete')
'''

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Downloading files

# %% [markdown]
# Loading the data into the pandas data frame is certainly one of the most important steps in EDA, as we can see that the value from the data set is comma-separated. So all we have to do is to just read the CSV into a data frame and pandas data frame does the job for us.

# %% [markdown]
# External Data Sources
# Local files: [Link](https://colab.research.google.com/notebooks/io.ipynb)
# Google Drive: [Link](https://colab.research.google.com/notebooks/io.ipynb#scrollTo=c2W5A2px3doP)
# Kaggle: [Link](https://colab.research.google.com/github/corrieann/kaggle/blob/master/kaggle_api_in_colab.ipynb#scrollTo=DsyV01gDaxls)
# Github: [Link](https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb)
#   *Github requires use or raw.githubusercontent.com url*

# %% [markdown]
# ### 2.1. Local files

# %%
'''
df = pd.read_csv(' ')
print('Import Data Complete')
'''

# %% [markdown]
# ### 2.2. URL files

# %%
'''
url = (' ')
df = pd.read_csv(url)
print('Import Data Complete')
'''

# %% [markdown]
# ### 2.3. Kaggle files

# %% [markdown]
# #### 2.3.1. Downloading a dataset

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
activities = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/dailyActivity_merged.csv')
#calories = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/dailyCalories_merged.csv')
#intensities = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/dailyIntensities_merged.csv')
sleep = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/sleepDay_merged.csv')
weight = pd.read_csv('/kaggle/input/fitbit/Fitabase Data 4.12.16-5.12.16/weightLogInfo_merged.csv')

print('Import Data Complete')

# %% [markdown]
# ### 2.4. Github files

# %%
'''
url = ('https://raw.githubusercontent.com/bentegviz/data_analyst_portfolio_project/main/data/interim/movies_dataset.csv')
df = pd.read_csv(url)

print('Import Data Complete')
'''

# %% [markdown]
# ## 3. Data Exploration

# %% [markdown]
# ### 3.1. Exploring the data frames first 5 samples

# %%
# To display the top 5 rows
activities.head(5)

# %%
sleep.head(5)

# %%
weight.head(5)

# %% [markdown]
# ---

# %% [markdown]
# ### 3.1.1 Merging Datasets

# %% [markdown]
# Merging activities, sleep, and weight datasets
# Other datasets are included in activities

# %%
#To merge activities dataframe with sleep dataframe into df
df = activities.merge(sleep[['Id', 'TotalSleepRecords','TotalMinutesAsleep','TotalTimeInBed']],
               on = 'Id',
               how='left'
              )

# %%
#To merge weight dataframe with df
df = df.merge(weight[['Id','WeightKg','WeightPounds','Fat','BMI','IsManualReport']],
              on = 'Id',
              how = 'left'
             )

# %%
df.head(5)

# %% [markdown]
# ### 3.2. Checking the types of data

# %% [markdown]
# Check for the datatypes to ensure proper usage of *string* (object), *int* (int64), and *float* (float64).

# %%
# To display the data types
df.dtypes

# %% [markdown]
# 'ActivityDate' column is object, could be changed to date
# 'SleepDay' column is object, could be changed to date
# 'IsManualReport' column is object, could be changed to boolean

# %% [markdown]
# #### 3.2.1. Ensure dates are type *date*, numerical data is type *int* or *float*

# %%
# To convert ActivityDate and SleepDay to type date
df['ActivityDate'] = pd.to_datetime(df['ActivityDate'])

# To convert IsManualReport to type bool
df['IsManualReport'] = df['IsManualReport'].astype(bool)

# %%
# To display the data types
df.dtypes

# %% [markdown]
# ### 3.3. Exploring data frame info

# %%
# To display the info
df.info()

# %% [markdown]
# 'Fat' contains many null values, will probably be deleted for analysis
# 'WeightKG, WeightPounds, BMI, and IsManualReport' null values will be discarded during cleaning

# %% [markdown]
# ### 3.4. Exploring data frame description
# Basic statistical details: count, mean, std, min, max, quartiles

# %%
# To display the statistical description
df.describe()

# %% [markdown]
# #### 3.4.1. Ensure the *min*, *max*, and *mean* values make sense for the dataset

# %% [markdown]
# 1.  TotalSteps mean is 9373, max is 36019, min is 0
# 2.  TotalDistance mean is 6.42, max is 28.03, min is 0
# 3.  SedentaryActiveDistance showing values near 0
# 4.  TotalSleepRecords showing values near 1
# 5.  TotalMinutesAsleep mean is 433.9 (or 7.216 hours) , max is 796 (or 13.26 hours), min is 58
# 6.  WeightKG, WeightPounds, Fat, and BMI are all within normal levels

# %% [markdown]
# #### 3.4.2. Sorting values

# %% [markdown]
# Will use Pivot Tables later in analysis

# %% [markdown]
# ---

# %% [markdown]
# ### 3.5. Exploring data frame column names

# %%
# To display the column names
df.columns

# %% [markdown]
# ### 3.6. Summarizing data

# %% [markdown]
# #### 3.6.1 Average Active time

# %%
df_pivot = pd.pivot_table(df, index=['Id'],
                          values=['VeryActiveMinutes',
                                  'FairlyActiveMinutes',
                                  'LightlyActiveMinutes',
                                  'SedentaryMinutes'
                                 ],
                          aggfunc='mean')

df_pivot = df_pivot.reindex(df_pivot['SedentaryMinutes'].sort_values(ascending=True).index)

print(df_pivot)

# %% [markdown]
# 1.  VeryActiveMinutes average from 87 minutes less than 1 minute
# 2.  FairlyActiveMinutes average from 61 minutes less than 1 minutes
# 3.  LightlyActiveMinutes average from 329 minutes less than 38 minutes
# 4.  SedentaryMinutes average from 1317 minutes less than 662 minutes
#
# User 6962181067 appears to lead an *active* lifestyle
# User 1927972279 appears to lead an *inactive* lifestyle

# %% [markdown]
# #### 3.6.2 Average Distance

# %%
df_pivot = pd.pivot_table(df, index=['Id'],
                          values=['TotalSteps', 
                                  'TotalDistance',
                                  'Calories'
                                 ],
                          aggfunc='mean')

df_pivot = df_pivot.reindex(df_pivot['TotalDistance'].sort_values( ascending=False).index)

print(df_pivot)

# %% [markdown]
# User 8877689391 averages the *most* steps
# User 1927972279 averages the *least* steps
# *Highest* Steps does not directly correlate to *highest* Calories
# *TotalDistance* correlates to *higher* Calories

# %% [markdown]
# #### 3.6.3 Sleep

# %%
df_pivot = pd.pivot_table(df, index=['Id'],
                          values=['TotalMinutesAsleep', 
                                  'TotalDistance',
                                  'WeightPounds',
                                  'BMI'
                                 ],
                          aggfunc='mean')

df_pivot = df_pivot.reindex(df_pivot['TotalMinutesAsleep'].sort_values(ascending=False).index)

print(df_pivot)

# %% [markdown]
# TotalMinutesAsleep does not show much in relationships

# %% [markdown]
# ## 4. Data Cleaning

# %% [markdown]
# ### 4.1. Dropping columns

# %% [markdown]
# Check columns that can be ommitted from the dataset

# %%
# To drop columns
df = df.drop(['ActivityDate','Fat','IsManualReport'], axis=1)

df.head(5)

# %% [markdown]
# Removed 'Fat' column since it has many null values
# Removed 'IsManualReport' column since it holds little value

# %% [markdown]
# ---

# %% [markdown]
# ### 4.2. Renaming columns

# %% [markdown]
# Check the readability of the remaining column names, improving the readability of the data set.

# %%
'''
# To rename the columns
df = df.rename(columns={"Engine HP": "HP", "Engine Cylinders": "Cylinders", "Transmission Type": "Transmission", "Driven_Wheels": "Drive Mode","highway MPG": "MPG-H", "city mpg": "MPG-C", "MSRP": "Price" })
# To check the new column names
df.head(5)
'''

# %% [markdown]
# ---

# %% [markdown]
# ### 4.3. Dropping duplicate rows

# %% [markdown]
# Check the instance of duplicated data within the dataset.  Generally, the larger the dataset, the higher probability of having duplicates.

# %% [markdown]
# #### 4.3.1 Finding unique values

# %%
pd.unique(df['Id'].values.ravel())

# %%
df['Id'].nunique()

# %% [markdown]
# Since there are only 33 unique values or IDs, we will not be dropping any data later

# %%
# To display dataset (rows, columns)
df.shape

# %%
'''# To display the duplicate rows as a new data frame
duplicate_rows_df = df[df.duplicated()]
print("Number of duplicate rows: ", duplicate_rows_df.shape)'''

# %% [markdown]
# Remove the duplicate rows if they exist and can be removed.

# %%
# To display the number of rows
df.count()

# %% [markdown]
# The display above indicates ______ rows and removing _____ rows of duplicate data.

# %%
'''# To drop the duplicated data
df = df.drop_duplicates()
df.head(5)'''

# %%
'''# To count the number of rows after dropping duplicates 
df.count()'''

# %% [markdown]
# ---

# %% [markdown]
# ### 4.4. Dropping missing or null values.

# %% [markdown]
# This is similar to the previous step except the missing values are detected and dropped later. In this case, we will drop the missing values instead of imputing values to the nulls because there are only 6,000 rows.

# %%
'''# To display total null values per column
print(df.isnull().sum())'''

# %%
'''# To display percentage of column that is null values
for col in df.columns:
  pct_missing = np.mean(df[col].isnull())
  print('{} - {}%'.format(col, pct_missing))'''

# %%
'''# To drop the null values
df = df.dropna()
df.count()'''

# %%
'''# To display the null values after dropping
print(df.isnull().sum())'''

# %% [markdown]
# Leaving columns that contain null values to keep integrity of dataset

# %%
df.count()

# %% [markdown]
# ---

# %% [markdown]
# ### 4.5. Converting Date from String to Datetime

# %%
'''
# To convert dates from string to datetime
df['released'] = pd.to_datetime(df['released'], format='%Y%m%d')
'''

# %% [markdown]
# Done in previous step

# %% [markdown]
# ### 4.6. Sorting Data

# %%
'''
# To sort values by specific column name
df.sort_values(by=['gross'], inplace=False, ascending=False)
'''

# %% [markdown]
# Pivot Table will come later in analysis

# %% [markdown]
# # Analyze

# %% [markdown]
# ## 5. Model Building

# %% [markdown]
# **Detecting Outliers and Correlations**

# %% [markdown]
# ### 5.1. Detecting Outliers with Boxplots

# %% [markdown]
# Use box plots to detect data value outliers.

# %%
# To display box plots for all columns
for column in df:
    plt.figure()
    sns.boxplot(x = df[column])

# %%
'''
# To display box plot for specific column
sns.boxplot(x=df['column_name'])
'''

# %% [markdown]
# ### 5.2. Quantile

# %% [markdown]
# Outliers are a point or set of points that are different from other points, sometimes they can *be* very high or very low.  Outliers are one of the primary reasons for resulting in a less accurate model we are going to remove them using the IQR score technique.  Outliers can be seen with visualizations using a Box Plot.
# IQR score technique from [Towards Data Science](https://towardsdatascience.com/ways-to-detect-and-remove-the-outliers-404d16608dba).

# %%
# To display Quantile for IQR score
q1 = df.quantile(0.25)
q3 = df.quantile(0.75)
iqr_score = q3 - q1
print(iqr_score)

# %%
# To find the quantiles over the index axis
df.quantile([.25, .5, .75], axis = 0)

# %%
df.count()

# %% [markdown]
# ---

# %% [markdown]
# ### 5.3. Distribution with Histograms
#
# Use histogram display the frequency of occurrence of variables in an interval.

# %%
# To display histograms for all columns
for i, col in enumerate(df.columns):
    plt.figure(i)
    sns.distplot(df[col])

# %%
'''
# To display histogram for specific column
df.Economy.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("Number of cars by make")
plt.ylabel('Number of cars')
plt.xlabel('Make');
'''

# %% [markdown]
# ### 5.3. Heat Maps
#
# Use heat maps to find the dependent variables.

# %%
# To calculate the correlation coefficient matrix
df_corr = df.corr()

# To plot the Heat Map
ax = sns.heatmap(df_corr, vmin = -1, vmax = 1, square = True)

# To show correlation matrix
df_corr

# %% [markdown]
# SedentaryMinutes has a *negative* correlation on many other variables
# BMI has a *negative* correlation on many other variables
# *High* ActiveMinutes categories have a *positive* correlation on many other variables

# %% [markdown]
# ### 5.4. Plotting Correlation with Scatterplots
#
# Use scatter plots to find the correlation between two variables.

# %%
'''
# To chart scatterplots for all columns
for i, col in enumerate(df.columns):
    plt.figure(i)
    sns.scatterplot(df[col])
'''

# %%
'''# To display scatter plot using seaborn
sns.scatterplot(data=df, x='SedentaryMinutes', y='BMI')
plt.xlabel('Sedentary Minutes')
plt.ylabel('Weight')
plt.title('Sedentary Minutes versus Weight')
plt.show'''

# %% [markdown]
# ### 5.5. Regression plots

# %% [markdown]
# Use regression plots to analyze two variables.
# *regplot()* or *lmplot()*

# %%
'''
# To display regression plot
sns.regplot(x='column_name_a', y='column_name_b', data=df)
'''

# %%
# To display regression plot
sns.regplot(x='WeightPounds', y='TotalSteps', data=df, line_kws={'color':'black'})
plt.xlabel('Weight')
plt.ylabel('Steps')
plt.title('Weight versus Steps')
plt.show

# %%
# To display regression plot using seaborn
sns.regplot(x='BMI', y='TotalDistance', data=df, line_kws={'color':'black'})
plt.xlabel('BMI')
plt.ylabel('Distance')
plt.title('BMI versus Distance Walked')
plt.show

# %%
# To display regression plot using seaborn
sns.regplot(x='Calories', y='SedentaryMinutes', data=df, line_kws={'color':'black'})
plt.xlabel('Calories')
plt.ylabel('Sedentary Minutes')
plt.title('Calories versus Sedentary Minutes')
plt.show

# %%
# To display regression plot using seaborn
sns.regplot(x='Calories', y='LightlyActiveMinutes', data=df, line_kws={'color':'black'})
plt.xlabel('Calories')
plt.ylabel('Lightly Active Minutes')
plt.title('Calories versus Lightly Active Minutes')
plt.show

# %%
# To display regression plot using seaborn
sns.regplot(x='Calories', y='FairlyActiveMinutes', data=df, line_kws={'color':'black'})
plt.xlabel('Calories')
plt.ylabel('Fairly Active Minutes')
plt.title('Calories versus Fairly Active Minutes')
plt.show

# %%
# To display regression plot using seaborn
sns.regplot(x='Calories', y='VeryActiveMinutes', data=df, line_kws={'color':'black'})
plt.xlabel('Calories')
plt.ylabel('Very Active Minutes')
plt.title('Calories versus Very Active Minutes')
plt.show

# %%
# To display regression plot using seaborn
sns.regplot(x='Calories', y='TotalDistance', data=df, line_kws={'color':'black'})
plt.xlabel('Calories')
plt.ylabel('Distance')
plt.title('Calories versus Distance Walked')
plt.show

# %%
# To display regression plot using seaborn
sns.regplot(x='Calories', y='TotalSteps', data=df, line_kws={'color':'black'})
plt.xlabel('Calories')
plt.ylabel('Steps')
plt.title('Calories versus Steps')
plt.show

# %%
'''
# To display regression plot with hue
sns.lmplot(x='column_name_a', y='column_name_b', cue='column_hue' data=df)
'''

# %% [markdown]
# ## 6. DataPrep Report

# %% [markdown]
# DataPrep lets you prepare your data using a single library with a few lines of code.
# https://docs.dataprep.ai/index.html#
#
# DataPrep EDA
# Introduction to Exploratory Data Analysis and dataprep.eda
#
# Exploratory Data Analysis (EDA) is the process of exploring a dataset and getting an understanding of its main characteristics. The dataprep.eda package simplifies this process by allowing the user to explore important characteristics with simple APIs. Each API allows the user to analyze the dataset from a high level to a low level, and from different perspectives. Specifically, dataprep.eda provides the following functionality:
#
# https://docs.dataprep.ai/user_guide/eda/introduction.html

# %%
'''# To pip install dataprep and import create_report
# !pip install dataprep
from dataprep.eda import create_report'''

# %%
'''# To use DataPrep package to create interactive report on pandas dataframe
create_report(df)'''

# %% [markdown]
# ## 7. Present Results

# %% [markdown]
# ### 7.1. Data analysis observations

# %% [markdown]
# 1.   Users with higher reported BMI report less TotalDistance
# 2.   Users with higher reported WeightPounds report less TotalSteps
# 3.   Users with higher SedentaryMinutes do not report more TotalSteps
# 4.   Users with higher Light, Fairly, and VeryActiveMinutes report higher Calories
# 5.   Users with higher TotalSteps report higher Calories

# %% [markdown]
# ### 7.2. Data analysis conclusions

# %% [markdown]
# 1. What are some trends in smart device usage? Monitoring steps, distance, various activity levels, sedentary levels, sleep, weight, bmi
# 2. How could these trends apply to Bellabeat customers? Ensure the Bellabeat app, Leaf, and Time devices are able to accomodate these functions of tracking.  With a high finding of sedentary minutes, a feature to remind users to become or remain active.
# 3. How could these trends help influence Bellabeat marketing strategy?  Ensure the Bellabeat app, Leaf, and Time devices are able to accomodate these tracking functions required by the customer.
