# %% [markdown]
# # I'm a newbie with Python and data analysis, please help me discover more/better ways to preprocess my data. Thanks!
#
# * What else should I regularly do to clean and preprocess data like this?
#
# * How can I improve these methods to make them faster?
#
# * What else should I do to prep this data for analysis?

# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd

# %%
pip install pyjanitor

# %%
import janitor

# %% [markdown]
# # Inspect the Data

# %%
min_wage = pd.read_csv("../input/us-minimum-wage-by-state-from-1968-to-2017/Minimum Wage Data.csv")
min_wage.head()

# %%
min_wage.info()

# %%
min_wage.columns

# %%
min_wage = min_wage.clean_names()
min_wage = min_wage.remove_empty()

# %%
min_wage.columns

# %%
min_wage.head(80)

# %% [markdown]
# # Exploratory Visualizations

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
fig = plt.gcf()
fig.set_size_inches(12, 8)
min_wage_scatter = sns.scatterplot(data=min_wage, x="year", y="state_minimum_wage_2020_dollars", hue="state")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)

# %% [markdown]
# # Export to explore further in SQL

# %%
min_wage.to_csv("min_wage_cleaned.csv")
