# %% [markdown]
# Import pandas library
# read scrubbed data from UFO Sightings data set

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
UFO_data = pd.read_csv('../input/scrubbed.csv')

# %% [markdown]
# Summarizing data

# %%
UFO_data.head()
UFO_data.describe()
