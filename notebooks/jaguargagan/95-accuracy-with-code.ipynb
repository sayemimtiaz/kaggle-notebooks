# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/kaggle/input/stroke-prediction-dataset/healthcare-dataset-stroke-data.csv")

# %%
df

# %%
df.head()

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# # Null values

# %%
df.isnull().sum()

# %%
import missingno as mn

# %%
mn.matrix(df)

# %%
df=df.dropna(how='any',axis=0)

# %%
df.shape

# %%
df.isnull().sum()

# %%
df.corr()

# %%
plt.rcParams['figure.figsize']=12,12
sns.heatmap(df.corr(),annot=True)

# %%
from pandas_profiling import ProfileReport

# %%
df.profile_report()

# %%
sns.countplot(x='stroke',data=df,palette='YlGnBu')

# %%
def encoding(df):
    code = {
        'Male':0,
        'Female':1,
        'Other':2,
        'Yes':1,
        'No':0,
        'Private':0,
        'Self-employed':1,
        'Govt_job':2,
        'children':3,
        'Never_worked':4,
        'Urban':0,
        'Rural':1,
        'formerly smoked':0,
        'never smoked':1,
        'smokes':2
           }
    for col in df.select_dtypes('object'):
        df.loc[:,col]=df[col].map(code)
        
    return df

# %%
df= encoding(df)

# %%
df = df.dropna(axis=0)

# %%
df

# %%
sns.pairplot(df,hue='stroke')

# %%
coorr2=df.corr()[['stroke']].sort_values(by=['stroke'],ascending=False)
coorr2.style.background_gradient(cmap='coolwarm').set_precision(2)

# %%
sns.barplot(x='ever_married',y="stroke",data=df)

# %%
sns.barplot(x='work_type',y="stroke",data=df)

# %%
x=df.drop(columns='stroke')

# %%
y=df['stroke']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.2,random_state=3)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier()

# %%
np.any(np.isnan(df))
np.all(np.isfinite(df))

# %%
knn.fit(x_train,y_train)

# %%
y_pred=knn.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy=accuracy_score(y_pred,y_test)

# %%
accuracy

# %%
from sklearn.svm import SVC

# %%
svc=SVC()

# %%
svc.fit(x_train,y_train)

# %%
y_pred2=svc.predict(x_test)

# %%
accuracy2=accuracy_score(y_pred2,y_test)

# %%
accuracy2

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier()

# %%
rfc.fit(x_train,y_train)

# %%
pred_rfc=rfc.predict(x_test)

# %%
accuracy3=accuracy_score(pred_rfc,y_test)

# %%
accuracy3
