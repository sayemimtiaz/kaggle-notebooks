# %%
import IPython.display as ipd

# %% [markdown]
# This module will help us to listen sounds

# %% [markdown]
# let us listen some sound waves

# %%
ipd.Audio('../input/urbansound8k/fold2/100652-3-0-3.wav')

# %%
ipd.Audio('../input/urbansound8k/fold2/102871-8-0-5.wav')

# %%
ipd.Audio('../input/urbansound8k/fold10/101382-2-0-12.wav')

# %% [markdown]
# Now Let us discuss how waves are distributed so that we can visualise how data is sampled and see some properties

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('../input/urbansound8k/UrbanSound8K.csv')

# %%
df.head()

# %%
df['class'].value_counts()

# %%
df[df['class']=='air_conditioner'].head(2)

# %%
# Class: Air Conditioner

filename = '../input/urbansound8k/fold5/100852-0-0-0.wav'
plt.figure(figsize=(12,4))
data,sample_rate = librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
ipd.Audio(filename)

# %%
df[df['class']=='jackhammer'].head(2)

# %%
#class jackhammer
filename = '../input/urbansound8k/fold1/103074-7-0-0.wav'
plt.figure(figsize=(12,4))
data,sample_rate = librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
ipd.Audio(filename)

# %%
df[df['class']=='engine_idling'].head(2)

# %%
#class jackhammer
filename = '../input/urbansound8k/fold10/102857-5-0-0.wav'
plt.figure(figsize=(12,4))
data,sample_rate = librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
ipd.Audio(filename)

# %%
df[df['class']=='street_music'].head(2)

# %%
#class streetmusic
filename = '../input/urbansound8k/fold7/101848-9-0-0.wav'
plt.figure(figsize=(12,4))
data,sample_rate = librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
ipd.Audio(filename)

# %%
df[df['class']=='drilling'].head(2)

# %%
#class drilling
filename = '../input/urbansound8k/fold3/103199-4-0-0.wav'
plt.figure(figsize=(12,4))
data,sample_rate = librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
ipd.Audio(filename)

# %%
df[df['class']=='children_playing'].head(2)

# %%
#class children playing
filename = '../input/urbansound8k/fold5/100263-2-0-117.wav'
plt.figure(figsize=(12,4))
data,sample_rate = librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
ipd.Audio(filename)

# %%
df[df['class']=='dog_bark'].head(2)

# %%
#class dog bark
filename = '../input/urbansound8k/fold5/100032-3-0-0.wav'
plt.figure(figsize=(12,4))
data,sample_rate = librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
ipd.Audio(filename)

# %%
df[df['class']=='siren'].head(2)

# %%
#class siren
filename = '../input/urbansound8k/fold7/102853-8-0-0.wav'
plt.figure(figsize=(12,4))
data,sample_rate = librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
ipd.Audio(filename)

# %%
df[df['class']=='car_horn'].head(2)

# %%
#class car horn
filename = '../input/urbansound8k/fold10/100648-1-0-0.wav'
plt.figure(figsize=(12,4))
data,sample_rate = librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
ipd.Audio(filename)

# %%
df[df['class']=='gun_shot'].head(2)

# %%
#class gunshot
filename = '../input/urbansound8k/fold1/102305-6-0-0.wav'
plt.figure(figsize=(12,4))
data,sample_rate = librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
ipd.Audio(filename)

# %% [markdown]
# Observations
# From a visual inspection we can see that it is tricky to visualise the difference between some of the classes.
#
# Particularly, the waveforms for reptitive sounds for air conditioner, drilling, engine idling and jackhammer are similar in shape.
#
# Likewise the peak in the dog barking sample is simmilar in shape to the gun shot sample (albeit the samples differ in that there are two peaks for two gunshots compared to the one peak for one dog bark). Also, the car horn is similar too.
#
# There are also similarities between the children playing and street music.
#
# The human ear can naturally detect the difference between the harmonics, it will be interesting to see how well a deep learning model will be able to extract the necessary features to distinguish between these classes.
#
# However, it is easy to differentiate from the waveform shape, the difference between certain classes such as dog barking and jackhammer.
