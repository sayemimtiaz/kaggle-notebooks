# %%
import pandas as pd
import numpy as np

# %%
metadata = pd.read_csv('../input/heartbeat-sounds/set_a.csv')

# %%
metadata.head()

# %%
metadata['label'].value_counts()

# %%
df = pd.read_csv('../input/heartbeat-sounds/set_b.csv')
df.head()

# %%
df['label'].value_counts()

# %% [markdown]
# SO BASICALLAY THERE ARE 7 DIFFERENT TYPE OF HEART BEATS IN OUR DATASET
#
# let's listen these and understand what each means

# %% [markdown]
# 1. NORMAL HEARTBEATS

# %%
import librosa
import librosa.display
import IPython.display as ipd

# %%
ipd.Audio('../input/heartbeat-sounds/set_a/normal__201102201230.wav')

# %%
import librosa 
import numpy as np
from scipy.io import wavfile as wav

# %%
audio,sr = librosa.load('../input/heartbeat-sounds/set_a/normal__201102201230.wav')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,4))
plt.plot(audio)

# %%
audio

# %% [markdown]
# MURMUR AUDIO

# %%
ipd.Audio('../input/heartbeat-sounds/set_a/murmur__201108222258.wav')

# %%
audio,sr = librosa.load('../input/heartbeat-sounds/set_a/murmur__201108222258.wav')
plt.figure(figsize=(12,4))
plt.plot(audio)

# %% [markdown]
# # Artifact

# %%
ipd.Audio('../input/heartbeat-sounds/set_a/artifact__201106061233.wav')

# %%
audio,sr = librosa.load('../input/heartbeat-sounds/set_a/artifact__201106061233.wav')

# %%
plt.figure(figsize=(14,5))
plt.plot(audio)
