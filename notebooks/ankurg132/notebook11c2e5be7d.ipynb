# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.read_csv("../input/world-happiness/2019.csv") 
#This will read the data from the happiness report of 2019

# %%
df = pd.read_csv("../input/world-happiness/2019.csv")
df.head()
#Shows top 5 happiest countries

# %%
df.tail()
#Shows least five happiest countries

# %%
inp = int(input("Enter number of rows to search from top: "))
pd.read_csv("../input/world-happiness/2019.csv",nrows=inp)

#Shows top n countries

# %%
head = df.head()
country = head["Country or region"]
gdp = head["GDP per capita"]
plt.plot(country,gdp)
plt.xlabel('Country')
plt.ylabel('GDP')
plt.show()
#This will read the data of top 5 countries from the happiness report of 2019 and compare their GDP's
