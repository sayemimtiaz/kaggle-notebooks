# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys

from scipy.stats import pearsonr
import collections
from scipy.stats import linregress

import datetime
import json
