# %%
import numpy as np
import pandas as pd

# %%
heart = pd.read_csv('../input/heart-disease-uci/heart.csv')

# %%
heart.head()

# %%
heart.info()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.countplot(x='sex',hue='target',data=heart)
#1=Male 0=Female

# %%
plt.subplot(1,2,1)
sns.scatterplot(x='age',y='chol',hue='sex',data=heart)
plt.subplot(1,2,2)
sns.scatterplot(x='age',y='chol',hue='target',data=heart)

# %%
sns.boxplot(x='target',y='age',hue='sex',data=heart)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import train_test_split

# %%
target = heart['target']
detail = heart.drop('target',axis=1)

# %%
target.head()

# %%
detail.head()

# %%
X_train, X_test, y_train, y_test = train_test_split(detail, target, test_size=0.3)

# %% [markdown]
# # LogisticRegression

# %%
LR=LogisticRegression()
LR.fit(X_train,y_train)
Prediction1=LR.predict(X_test)

# %%
np.array(y_test)

# %%
Prediction1

# %%
print(classification_report(y_test,Prediction1))

# %%
print(confusion_matrix(y_test,Prediction1))

# %% [markdown]
# # RandomForest

# %% [markdown]
# Before Standardize

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RFC=RandomForestClassifier()
RFC.fit(X_train,y_train)
Prediction2=RFC.predict(X_test)

# %%
np.array(y_test)

# %%
Prediction2

# %%
print(classification_report(y_test,Prediction2))

# %%
print(confusion_matrix(y_test,Prediction2))

# %% [markdown]
# After Standardize

# %%
from sklearn.preprocessing import StandardScaler

# %%
SC=StandardScaler()
SC.fit(detail)
stdetail=SC.transform(detail)

# %%
stdetails=pd.DataFrame(stdetail)
stdetails.columns=detail.columns

# %%
stdetails.head()

# %%
X_train, X_test, y_train, y_test = train_test_split(stdetails, target, test_size=0.3)

# %%
RFC=RandomForestClassifier()
RFC.fit(X_train,y_train)
Prediction3=RFC.predict(X_test)

# %%
np.array(y_test)

# %%
Prediction3

# %%
print(classification_report(y_test,Prediction3))

# %%
print(confusion_matrix(y_test,Prediction2))

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# %%
X_train, X_test, y_train, y_test = train_test_split(detail, target, test_size=0.3)

# %%
grid={'C':[1,10,100,1000,10000,100000,1000000],'gamma':[0.0000001,0.000001,0.00001,0.0001,0.001,.01,0.1,1]}

# %%
g=GridSearchCV(SVC(),grid,verbose=2)

# %%
g.fit(X_train,y_train)

# %%
g.best_estimator_

# %%
Prediction4=g.predict(X_test)

# %%
np.array(y_test)

# %%
Prediction4

# %%
print(classification_report(y_test,Prediction4))

# %%
print(confusion_matrix(y_test,Prediction4))
