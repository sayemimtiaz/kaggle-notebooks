# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
heart=pd.read_csv('../input/heart-attack-analysis-prediction-dataset/heart.csv')

# %%
heart.head()

# %%
heart.info()

# %% [markdown]
# # Data Distribution

# %%
plt.figure(figsize=(18,10))
plt.subplot(2,5,1)
sns.histplot(heart['age'],kde=True)
plt.subplot(2,5,6)
sns.boxplot(heart['age'])
plt.subplot(2,5,2)
sns.histplot(heart['trtbps'],kde=True)
plt.subplot(2,5,7)
sns.boxplot(heart['trtbps'])
plt.subplot(2,5,3)
sns.histplot(heart['chol'],kde=True)
plt.subplot(2,5,8)
sns.boxplot(heart['chol'])
plt.subplot(2,5,4)
sns.histplot(heart['thalachh'],kde=True)
plt.subplot(2,5,9)
sns.boxplot(heart['thalachh'])
plt.subplot(2,5,5)
sns.histplot(heart['oldpeak'],kde=True)
plt.subplot(2,5,10)
sns.boxplot(heart['oldpeak'])

# %% [markdown]
# ### Outliers are present in resting blood pressure, cholestoral, maximum heart rate and Previous peak

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,4,1)
sns.countplot(x='sex', data=heart)
plt.subplot(2,4,2)
sns.countplot(x='cp', data=heart)
plt.subplot(2,4,3)
sns.countplot(x='fbs', data=heart)
plt.subplot(2,4,4)
sns.countplot(x='restecg', data=heart)
plt.subplot(2,4,5)
sns.countplot(x='exng', data=heart)
plt.subplot(2,4,6)
sns.countplot(x='slp', data=heart)
plt.subplot(2,4,7)
sns.countplot(x='caa', data=heart)
plt.subplot(2,4,8)
sns.countplot(x='thall', data=heart)
plt.tight_layout()

# %%
plt.figure(figsize=(8,4))
sns.countplot(x='output', data=heart)

# %% [markdown]
# # Data Correlation

# %%
plt.figure(figsize=(12,10))
sns.heatmap(heart.corr(),annot=True)

# %%
sns.pairplot(heart[['age','trtbps','chol','thalachh','oldpeak','output']],hue='output')

# %% [markdown]
# # Model Creation and Prediction

# %% [markdown]
# ### After using multiple Model came up with RandomForest returning the best predictions

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,confusion_matrix

# %%
target=heart['output']
data=heart.drop('output',axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.25)

# %%
rfc=RandomForestClassifier()

# %%
rfc.fit(X_train,y_train)

# %%
prediction=rfc.predict(X_test)

# %%
print(classification_report(y_test,prediction))

# %%
print(confusion_matrix(y_test,prediction))

# %%
result=pd.DataFrame(y_test)
result['prediction']=prediction

# %%
result
