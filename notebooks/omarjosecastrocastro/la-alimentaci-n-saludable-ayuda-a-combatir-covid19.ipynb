# %% [markdown]
#           **QUE IMPACTO TIENE UN ESTILO DE DIETA SALUDABLE DE UN PAIS FRENTE AL COVID-19**
#
#                                             Erika Daza
#                                            Omar Castro
#
# Introducción:
#
# En los últimos meses, hemos sido testigos de que médicos, enfermeras, paramédicos y miles de trabajadores médicos pusieron sus vidas en primera línea para salvar a los pacientes infectados. Y a medida que continúa la batalla con COVID-19, todos deberíamos preguntarnos: ¿qué debemos hacer para ayudar? ¿Qué podemos hacer para proteger a nuestros seres queridos, a los que se sacrifican por nosotros y a nosotros mismos de esta pandemia?
#
# El Centro para la Política y Promoción de Nutrición del USDA recomienda una guía de ingesta diaria muy simple: 30% de granos, 40% de verduras, 10% de frutas y 20% de proteínas, pero ¿estamos realmente comiendo en el estilo de alimentación saludable recomendado por estas divisiones de alimentos?
#
# En este conjunto de datos, se han combinado datos de diferentes tipos de alimentos, la obesidad de la población mundial y la tasa de desnutrición, y los casos globales de COVID-19 en todo el mundo para aprender más sobre cómo un estilo de alimentación saludable que podría ayudar a combatir el COVID-19. Y a partir del conjunto de datos, podemos recopilar información sobre los patrones de dieta de países con una tasa de infección y muertes más baja y una tasa de recuperación más alta en el COVID-19, y ajustar nuestra propia dieta para tener una mejor respuesta o futuros virus.
#
#
# •	Preocupación:
# ¿Cómo identificar si una correcta alimentación puede ayudar a combatir el covid-19?
#
# •	Objetivos de análisis: Lograr identificar en que tanto influye la alimentación de un país ante la pandemia del COVID-19.
#
# •	Identificación de interesados:
#
# Ciudadanía ->
# ¿Qué tan buena es mi alimentación?
# ¿Qué tan vulnerable soy al COVID-19 con la alimentación que llevo?
#
# Por qué:
#
# Quiero saber si mi alimentación es la adecuada.
# Quiero saber que tan vulnerable soy ante el COVID-19 debido a mi alimentación.
#
# Qué:
#
# Que mi alimentación sea la adecuada.
# Que tenga una mayor probabilidad de sobrevivir si me contagio de COVID-19.
#
# Objetivo:
# Tener una alimentación adecuada para tener una mayor probabilidad de sobrevivir si me contagio de COVID-19.
#
# Decisiones:
# ¿Tener conocimiento de que alimentos son adecuados para consumir?
#
# Gobierno ->
# ¿Qué tan buena es la alimentación de los ciudadanos?
#
# Por qué:
# Quiero saber si los ciudadanos tienen una buena alimentación.
# Quiero que tan vulnerable es la ciudadanía ante el COVID-19.
#
# Qué:
# Que la alimentación de los ciudadanos sea la correcta.
# Que los ciudadanos tengan una mayor probabilidad de sobrevivir si son contagiados por COVID-19.
#
# Objetivo: 	Conocer que tan buena es la alimentación de los Ciudadanos
#
# Decisiones:
# ¿Es buena la alimentación de los ciudadanos?
# ¿Se debe crear campañas para que el ciudadano tenga una mejor alimentación?
#
# •	Preguntas iniciales de análisis que pueden apoyar el objetivo y las decisiones
# Descriptivas
#
#     ¿Cuál es la cantidad de alcohol consumido (kg) por país?
#     ¿Cuál es la cantidad de productos animal consumido (kg) por país?
#     ¿Cuál es la cantidad de grasa animal consumida (kg) por país?
#     ¿Cuál es la cantidad de productos acuáticos consumido (kg) por país?
#     ¿Cuál es la cantidad de cereales-excluyendo la cerveza consumido (kg) por país?
#     ¿Cuál es la cantidad de pescado y mariscos consumido (kg) por país?
#     ¿Cuál es la cantidad de productos animal consumido (kg) por país?
#     ¿Cuál es la cantidad de frutas-excluyendo el vino consumido (kg) por país?
#     ¿Cuál es la cantidad de productos animal consumido (kg) por país?
#     ¿Cuál es la cantidad de carne consumida (kg) por país?
#     ¿Cuál es la cantidad de leche-excluyendo la mantequilla consumida (kg) por país?
#     ¿Cuál es la cantidad de cultivos oleaginosos consumido (kg) por país?
#     ¿Cuál es la cantidad de raíces amiláceas consumida (kg) por país?
#     ¿Cuál es la cantidad de especias consumidas (kg) por país?
#     ¿Cuál es la cantidad de estimulantes consumidos (kg) por país?
#     ¿Cuál es la cantidad de azúcar y edulcorantes consumidos (kg) por país?
#     ¿Cuál es la cantidad de productos vegetales consumidos (kg) por país?
#     ¿Cuál es la cantidad de aceites vegetales consumidos (kg) por país?
#     ¿Cuál es la cantidad de verduras consumidas (kg) por país?
#     ¿Cuál es el porcentaje de obesidad por país?
#     ¿Cuál es el porcentaje de desnutrición por país?
#     ¿Cuál es el porcentaje de casos infectados de COVID-19 por país?
#     ¿Cuál es el porcentaje de casos fallecidos de COVID-19 por país?
#     ¿Cuál es el porcentaje de casos recuperados de COVID-19 por país?
#     ¿Cuál es la población por país?
#
# Diagnosticas
#
#     ¿Tiene alguna relación el alto consumo de grasas con los fallecidos por COVID-19?
#     ¿Tiene alguna relación el alto consumo de bebidas alcohólicas con los fallecidos por COVID-19
#     ¿Tiene alguna relación el alto consumo de azúcar y edulcorantes con los fallecidos por COVID-19?
#     ¿Tiene alguna relación la obesidad con los fallecidos por COVID-19?
#     ¿Tiene alguna relación la desnutrición con los fallecidos por COVID-19?
#     ¿Tiene alguna relación los estimulantes con los fallecidos por COVID-19?
#     ¿Tiene alguna relación el alto consumo de vegetales con los recuperados por COVID-19?
#
# Predictivas
#
#     ¿Cuál es la probabilidad de recuperarse del COVID-19 con una buena alimentación?
#     ¿Cuál es la probabilidad de recuperarse del COVID-19 en un país con un bajo porcentaje de obesidad?
#     ¿Cuál es la probabilidad de recuperarse del COVID-19 en un país con un bajo porcentaje de desnutrición?

# %%
# SE IMPORTAN LOS DATOS DE LA CANTIDAD DE SUMINISTRO DE ALIMENTOS (En KG)

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # importar biblioteca de visualización de datos de Python basada en matplotlib. 
import operator
import missingno #libreria usada para graficar la completitud de los datos
import statsmodels.api as sm


# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
train = pd.read_csv("../input/dieta-covid19-8-2/Dieta_Covid19_8_2.csv") # Asignación de a la variable el .csv

# %%
# se revisa los primeros 5 registros de la data para ver los datos
train.head()

# %%
#Validamos la completitud de los datos

missingno.matrix (train, figsize = (30,10))

# %%
#Se elimino la columna Unit ya que todos los registros decian %
#Se realizó el cambio de puntos por comas
#se ajustan los porcentajes a 6 pociciones decimales y se multiplican por 100
#se solucionaron problemas de valores nulos y datos atipicos

# %%
#Datos basicos del archivo
print('Cantidad de Filas y columnas:',train.shape)
print('Nombre columnas:',train.columns)

# %%
# vemos los tipos de cada uno de los datos y se valida si son nulos o no. 
train.info()

# %%
# Se busca los tipos de datos numéricos que se tiene en el dataset

list(set(train.dtypes.tolist()))

# %%
#como ya se tienen los datos numéricos  se muestran los campos que son numéricos 

train_num = train.select_dtypes(include = ['float64', 'int64'])
train_num.head()

# %%
# Se realiza una descripción estadística de los datos numéricos
train_num.describe()

# %%
#Verificamos si hay correlacion entre las variables principales
corr = train.set_index('Deaths').corr()
sm.graphics.plot_corr(corr, xnames=list(corr.columns))
plt.figure(figsize=(1000,900))

# %%
#Verificamos si hay correlacion entre los datos
corr = train.set_index('Obesity').corr()
sm.graphics.plot_corr(corr, xnames=list(corr.columns))
plt.figure(figsize=(1000,900))

# %%
#Verificamos si hay correlacion entre los datos
corr = train.set_index('Recovered').corr()
sm.graphics.plot_corr(corr, xnames=list(corr.columns))
plt.figure(figsize=(1000,900))

# %%
# Se grafica todos los campos de tipos numéricos. 
train_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)

# %%
#Ahora intentaremos encontrar qué características están cocorrelacionadas con los fallecidos. 
#Los almacenaremos en una var llamada relacionfallecidos .

train_num_corr = train_num.corr()['Deaths'][:-1] # -1 because the latest row is Age
relacionfallecidos = train_num_corr[abs(train_num_corr) > 0.1].sort_values(ascending=False)
print("Hay {} valores correlacionados con fallecidos:\n{}".format(len(relacionfallecidos), relacionfallecidos))

# %%
#Ahora intentaremos encontrar qué características están cocorrelacionadas con la obesidad. 
#Los almacenaremos en una var llamada relacionobesidad .

train_num_corr = train_num.corr()['Obesity'][:-1] # -1 because the latest row is Age
relacionobesidad = train_num_corr[abs(train_num_corr) > 0.1].sort_values(ascending=False)
print("Hay {} valores correlacionados con Obesidad:\n{}".format(len(relacionobesidad), relacionobesidad))

# %%
#Ahora intentaremos encontrar qué características están corelacionadas con los recuperados. 
#Los almacenaremos en una var llamada relacionrecuperados .

train_num_corr = train_num.corr()['Recovered'][:-1] # -1 because the latest row is Recovered
relacionrecuperados = train_num_corr[abs(train_num_corr) > 0.1].sort_values(ascending=False)
print("Hay {} valores correlacionados con recuperados:\n{}".format(len(relacionrecuperados), relacionrecuperados))

# %%
#Ahora intentaremos encontrar qué características están correlacionadas con los obesos. 
#Los almacenaremos en una var llamada relacionobesos .

train_num_corr = train_num.corr()['Obesity'][:-1] # -1 because the latest row is Obesity
relacionobesos = train_num_corr[abs(train_num_corr) > 0.1].sort_values(ascending=False)
print("Hay {} valores correlacionados con obesos:\n{}".format(len(relacionobesos), relacionobesos))

# %%
#Ahora intentaremos encontrar qué características están correlacionadas con las personas con desnutricion. 
#Los almacenaremos en una var llamada relaciondesnutricion .

train_num_corr = train_num.corr()['Undernourished'][:-1] # -1 because the latest row is Undernourished
relaciondesnutricion = train_num_corr[abs(train_num_corr) > 0.1].sort_values(ascending=False)
print("Hay {} valores correlacionados con desnutricion:\n{}".format(len(relaciondesnutricion), relaciondesnutricion))

# %%
# Se relaciona el campo Muerte con los otros campos numéricos. 

for i in range(0, len(train_num.columns), 5):
    sns.pairplot(data=train_num,
                x_vars=train_num.columns[i:i+5],
                y_vars=['Deaths'])

# %%
# Se relaciona el campo recuperados con los otros campos numéricos. 

for i in range(0, len(train_num.columns), 5):
    sns.pairplot(data=train_num,
                x_vars=train_num.columns[i:i+5],
                y_vars=['Recovered'])

# %%
# Se relaciona el campo obecidad con los otros campos numéricos. 

for i in range(0, len(train_num.columns), 5):
    sns.pairplot(data=train_num,
                x_vars=train_num.columns[i:i+5],
                y_vars=['Obesity'])

# %%
# Se relaciona el campo desnutricion con los otros campos numéricos. 

for i in range(0, len(train_num.columns), 5):
    sns.pairplot(data=train_num,
                x_vars=train_num.columns[i:i+5],
                y_vars=['Undernourished'])

# %%
corr = train_num.drop('Deaths', axis=1).corr() # We already examined Deaths correlations
plt.figure(figsize=(12, 10))

sns.heatmap(corr[(corr >= 0.1) | (corr <= -0.4)], 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 8}, square=True);

# %%
corr = train_num.drop('Recovered', axis=1).corr() # We already examined Recovered correlations
plt.figure(figsize=(12, 10))

sns.heatmap(corr[(corr >= 0.5) | (corr <= -0.4)], 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 8}, square=True);

# %%
corr = train_num.drop('Obesity', axis=1).corr() # We already examined Obesity correlations
plt.figure(figsize=(12, 10))

sns.heatmap(corr[(corr >= 0.5) | (corr <= -0.4)], 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 8}, square=True);

# %% [markdown]
# PLANTEAMIENTO DE HIPOTESIS
# 1.	¿Tiene alguna relación el alto consumo de grasas con los fallecidos por COVID-19?
# •	Hipótesis nula Ho: No hay relación alguna entre el consumo de grasas y los fallecidos por COVID-19
# •	Hipótesis alternativa Ha: Existe una alta relación entre el consumo de grasas y los fallecidos por COVID-19
# Se tiene evidencia estadística de que no hay una alta correlación entre las variables por lo tanto se acepta la hipótesis nula.
# 2.	¿Tiene alguna relación el alto consumo de grasas con los recuperados por COVID-19?
# •	Hipótesis nula Ho: No hay relación entre el consumo de grasas y los recuperados por COVID-19
# •	Hipótesis alternativa Ha: Existe una alta relación entre el consumo de grasas y los recuperados por COVID-19
# Se tiene evidencia estadística de que hay muy poca correlación entre las variables, por lo tanto, se rechaza la hipótesis nula y asi misma la hipótesis alternativa ya que la relación que existe es bastante baja.
#
# 3.	¿Tiene alguna relación el consumo de azúcar/edulcorantes con los fallecidos por COVID-19?
# •	Hipótesis nula Ho: No hay relación entre el consumo de azúcar/edulcorantes y los fallecidos por COVID-19
# •	Hipótesis alternativa Ha: Existe relación entre el consumo de azúcar/edulcorantes y los fallecidos por COVID-19
# Se tiene evidencia estadística de que no hay una alta correlación entre las variables por lo tanto se acepta la hipótesis nula.
#
# 4.	¿Tiene alguna relación la obesidad con los fallecidos por COVID-19?
# •	Hipótesis nula Ho: No hay relación entre la obesidad y los fallecidos por COVID-19
# •	Hipótesis alternativa Ha: Existe alta elación entre la obesidad y los fallecidos por COVID-19
# Se tiene evidencia estadística de que hay muy poca correlación entre las variables, por lo tanto, se rechaza la hipótesis nula y asi misma la hipótesis alternativa ya que la relación que existe es bastante baja.
#
# 5.	¿Tiene alguna relación la obesidad con los recuperados de por COVID-19?
# •	Hipótesis nula Ho: No hay relación entre la obesidad y los fallecidos por COVID-19
# •	Hipótesis alternativa Ha: Existe relación entre la obesidad y los fallecidos por COVID-19
# Se tiene evidencia estadística de que hay muy poca correlación entre las variables, por lo tanto, se rechaza la hipótesis nula y asi misma la hipótesis alternativa ya que la relación que existe es bastante baja.
#
# 6.	¿Tiene alguna relación la desnutrición con los fallecidos por COVID-19?
# •	Hipótesis nula Ho: No hay relación entre la desnutrición y los fallecidos por COVID-19
# •	Hipótesis alternativa Ha: Existe relación entre la desnutrición y los fallecidos por COVID-19
# Se tiene evidencia estadística de que no hay una alta correlación entre las variables por lo tanto se acepta la hipótesis nula
# 7.	¿Tiene alguna relación el consumo de vegetales con los recuperados por COVID-19?
# a.	Hipótesis nula Ho: No hay relación entre el consumo de vegetales y los fallecidos por COVID-19
# b.	Hipótesis alternativa Ha: Existe relación entre el consumo de vegetales y los fallecidos por COVID-19
# Se tiene evidencia estadística de que no hay una alta correlación entre las variables por lo tanto se acepta la hipótesis nula

# %%
dataX =train[['Deaths']]
X_train = np.array(dataX)
y_train = train['Confirmed'].values

# Creamos el objeto de Regresión Linear
from sklearn import linear_model
regr = linear_model.LinearRegression()

# Entrenamos nuestro modelo
regr.fit(X_train, y_train)

# Hacemos las predicciones que en definitiva una línea (en este caso, al ser 2D)
y_pred = regr.predict(X_train)

# Veamos los coeficienetes obtenidos, En nuestro caso, serán la Tangente
print('Coefficients: \n', regr.coef_)
# Este es el valor donde corta el eje Y (en X=0)
print('Independent term: \n', regr.intercept_)
# Error Cuadrado Medio
print("Mean squared error: %.2f" % mean_squared_error(y_train, y_pred))
# Puntaje de Varianza. El mejor puntaje es un 1.0
print('Variance score: %.2f' % r2_score(y_train, y_pred))

# %%
colores=['orange','blue']
tamanios=[30,60]

f1 = train['Deaths'].values
f2 = train['Confirmed'].values

asignar=[]
for index, row in train.iterrows():
    if(row['Deaths']>1):
        asignar.append(colores[0])
    else:
        asignar.append(colores[1])
    
plt.scatter(f1, f2, c=asignar, s=tamanios[0])
plt.show()

#Eje y se muestran los confirmados 
#Eje x se muestran los Muertos

# %%
import numpy
from matplotlib import pyplot
x = numpy.linspace(0, 2 * numpy.pi, 100)
f3 = pyplot.plot(x, (8.3532)*x+(2.966))
pyplot.plot(x, (8.3532)*x+(2.966))
pyplot.show()

# %%
import numpy
from matplotlib import pyplot

colores=['orange','blue']
tamanios=[30,60]

f1 = train['Deaths'].values
f2 = train['Confirmed'].values

asignar=[]
for index, row in train.iterrows():
    if(row['Deaths']>1):
        asignar.append(colores[0])
    else:
        asignar.append(colores[1])

x = numpy.linspace(0, 2 * numpy.pi, 100)
pyplot.plot(x, (8.3532)*x+(2.966), Color = 'Red')
plt.scatter(f1, f2, c=asignar, s=tamanios[0])
plt.show()
pyplot.show()



#Eje y se muestran los confirmados 
#Eje x se muestran los Muertos

# %%
## Predicción Si hay 2000 muerte cuantos contagiados se espera tener ? 
y_Dosmil = regr.predict([[2000]])
print(int(y_Dosmil))

# %% [markdown]
# CONCLUSIONES
# Aunque se encontró baja correlación entre la alimentación y los diagnósticos de recuperados y fallecidos de COVID.19, no se recomienda a la ciudadanía estar en sobrepeso ya que esta es la variable es la que tiene mayor relación de datos.
