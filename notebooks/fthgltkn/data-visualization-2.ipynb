# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['NBA_player_of_the_week.csv']

# %%
NBA_player_of_week=pd.read_csv('../input/NBA_player_of_the_week.csv')
#NBA_player_of_week=pd.DataFrame(NBA_player_of_week)

# %%
NBA_player_of_week.head()
# Out:
#    Active season                  Player    ...     Season short Real_value
# 0              0  Micheal Ray Richardson    ...             1985        1.0
# 1              0             Derek Smith    ...             1985        1.0
# 2              0             Calvin Natt    ...             1985        1.0
# 3              0     Kareem Abdul-Jabbar    ...             1985        1.0
# 4              0              Larry Bird    ...             1985        1.0
#
# [5 rows x 14 columns]

# %%
player_frequency=NBA_player_of_week.Player.value_counts()
player_frequency
#NBA_player_of_week.Player.unique()
# Out:
# LeBron James           61
# Kobe Bryant            33
# Kevin Durant           26
# Michael Jordan         25
# Tim Duncan             23
# Karl Malone            23
# Allen Iverson          23
# James Harden           22
# Kevin Garnett          20
# Shaquille O'Neal       20
# Dwyane Wade            19
# Dwight Howard          18
# Carmelo Anthony        18
# Russell Westbrook      18
# Paul Pierce            17
# Jason Kidd             17
# Dirk Nowitzki          16
# David Robinson         15
# Stephen Curry          14
# Chris Paul             13
# Hakeem Olajuwon        12
# Magic Johnson          12
# Patrick Ewing          12
# Tracy McGrady          12
# Vince Carter           11
# Charles Barkley        11
# Clyde Drexler          11
# LaMarcus Aldridge      10
# DeMar DeRozan          10
# Chris Bosh              9
#                        ..
# Markieff Morris         1
# Kristaps Porzingis      1
# Kenneth Faried          1
# Jamal Mashburn          1
# C.J. McCollum           1
# Kenny Anderson          1
# Arvydas Sabonis         1
# Zydrunas Ilgauskas      1
# Ersan Ilyasova          1
# Dennis Rodman           1
# Sleepy Floyd            1
# Cliff Robinson          1
# Nikola Pekovic          1
# Al Harrington           1
# Caron Butler            1
# Steve Smith             1
# Chris Gatling           1
# Wesley Person           1
# Rajon Rondo             1
# Buck Williams           1
# Drazen Petrovic         1
# Adrian Dantley          1
# Hassan Whiteside        1
# Mookie Blaylock         1
# Kenyon Martin           1
# Byron Scott             1
# Pascal Siakam           1
# Kareem Abdul-Jabbar     1
# Trae Young              1
# Vern Fleming            1
# Name: Player, Length: 282, dtype: int64

# %%
data=pd.DataFrame({'NBA_player_of_week.Player':NBA_player_of_week.Player.unique(),'player_frequency.values':player_frequency.values})
new_index=(data['player_frequency.values'].value_counts(ascending=False)).index.values
sorted_data1=data.reindex(new_index)
sorted_data1.head(10)
# Out:
#    NBA_player_of_week.Player  player_frequency.values
# 1                Derek Smith                       33
# 2                Calvin Natt                       26
# 3        Kareem Abdul-Jabbar                       25
# 4                 Larry Bird                       23
# 6               Sleepy Floyd                       23
# 5           Darrell Griffith                       23
# 7               Mark Aguirre                       22
# 8              Magic Johnson                       20
# 9          Dominique Wilkins                       20
# 12             World B. Free                       18

# %%
sns.barplot(y=sorted_data1['NBA_player_of_week.Player'],x=sorted_data1['player_frequency.values'])
#plt.figure(figsize=(25,25))
plt.xlabel('player')
plt.ylabel('values')
plt.xticks(rotation=0)
plt.title('week of player values')
plt.show()

# %%
NBA_player_of_week.corr()
# Out:
#                    Active season    Weight     ...      Season short  Real_value
# Active season           1.000000 -0.008064     ...          0.283139   -0.132443
# Weight                 -0.008064  1.000000     ...          0.047097   -0.014718
# Age                    -0.027882 -0.029477     ...         -0.035639    0.088359
# Draft Year              0.280871  0.029320     ...          0.942251   -0.804611
# Seasons in league       0.007381  0.046699     ...          0.196038   -0.158019
# Season short            0.283139  0.047097     ...          1.000000   -0.849350
# Real_value             -0.132443 -0.014718     ...         -0.849350    1.000000
#
# [7 rows x 7 columns]

# %%
f,ax=plt.subplots(figsize=(15,10))
sns.heatmap(NBA_player_of_week.corr(),annot=True)
plt.show()

# %%
NBA_player_of_week.columns
# Out:
# Index(['Active season', 'Player', 'Team', 'Conference', 'Date', 'Position',
#        'Height', 'Weight', 'Age', 'Draft Year', 'Seasons in league', 'Season',
#        'Season short', 'Real_value'],
#       dtype='object')

# %%
NBA_player_of_week['Seasons in league'].plot(kind='line',color='blue',label='Seasons in league',grid='True',linestyle=':',alpha=0.5)
NBA_player_of_week['Age'].plot(kind='line',color='green',label='Age',grid='True',linestyle='-.',alpha=0.5)
plt.legend(loc='upper right')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Line Plot')
plt.show()
# Out:
# /opt/conda/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "
# /opt/conda/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "
