# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Comp 4304 Assignment 10; Due: Dec 11
#
# This assignment is for students who have been approved for alternative evaluation to replace another assignment.
#
# ## Submission
#
# Create your own kaggle notebook with your solution and share it with the course instuctor as collaborator (kaggle user: edbrown) using the action sequence
#
#         share->add collaborators-> search for users -> edbrown -> save
#
# Once you've added me as a collaborator I will be able to examine your notebook.
#
# Email me (the instructor) with a link to your notebook, and include information about the assignment you are replacing and reason for replacement.
#
#
# ## Instructions
#
# Consider the file *president_county_candidate.csv* from the dataset at https://www.kaggle.com/unanimad/us-election-2020.
#
# Using plotly, pandas and this data file, create a chart (such as a bar chart or something else appropriate) comparing the total popular vote for the two leading candidates in each state. Use some channel on your plot to indicate which candidate won each state. Your solution could look something like this:
#
# ![newplot.png](attachment:newplot.png)
#
# # Don't forget an attribution section in your notebook.

# %% [markdown]
# You'll need to import plotly

# %%
import plotly
import plotly.express as ex

# %% [markdown]
# You can read the data set into a panda dataframe as follows, but you are not required to use pandas for this assignment if you want to do something else.

# %%
prdf = pd.read_csv("../input/us-election-2020/president_county_candidate.csv")
prdf.head(10)
