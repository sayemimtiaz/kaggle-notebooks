# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Comp 4304 Assignment 11; Due: Dec 11
#
# This assignment is for students who have been approved for alternative evaluation to replace another assignment.
#
# ## Submission
#
# Create your own kaggle notebook with your solution and share it with the course instuctor as collaborator (kaggle user: edbrown) using the action sequence
#
#         share->add collaborators-> search for users -> edbrown -> save
#
# Once you've added me as a collaborator I will be able to examine your notebook.
#
# Email me (the instructor) with a link to your notebook, and include information about the assignment you are replacing and reason for replacement.
#
# ## Instructions
#
# Consider the World University Rankings dataset at https://www.kaggle.com/mylesoneill/world-university-rankings
#
# This data is four years old, but still provide a good design exercise, and there are over 400 notebooks referencing the dataset.
#
# Using plotly, pandas and one or more of the data files from the World University Rankings dataset at https://www.kaggle.com/mylesoneill/world-university-rankings, create a sunburst diagram (as shown at https://plotly.com/python/sunburst-charts/).  The first (inner) level of the sunburst should be the country; the next level should be each university, with slice sizes depending on some measure of the university's quality.
#
# Consider the objective of exploring which countries have the best universities.
#
# Identify (and discuss)  a design problem with the sunburst idiom for this objective. Implement a better visualization based on your identified design problem.
#
#
# # Don't forget an attribution section in your notebook.

# %%
import plotly
import plotly.express as px

# %%
# Load data that we will use.
timesData = pd.read_csv("../input/world-university-rankings/timesData.csv")

# %%
# information about timesData
timesData.info()

# %%
timesData.head(10)
