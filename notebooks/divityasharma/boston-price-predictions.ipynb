# %% [markdown]
# # BOSTON HOUSING  PROJECT

# %% [markdown]
# The Boston Housing dataset contains information about various houses in Boston through different parameters.
# This data was originally a part of UCI Machine Learning Repository and has been removed now. There are 506 samples
# and 13 feature variables in this dataset.
# The objective is to predict the value of prices of the house using the given features.

# %%
 # Start by importing some libraries:
import pandas as pd


# Visualization

import matplotlib.pyplot as plt
import seaborn as sns

#To plot the graph embedded in the notebook
# %matplotlib inline

# %%
# from sklearn library:

from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error

# %%
# Loading data:
from sklearn.datasets import load_boston
boston=load_boston()
boston

# %%
dir(boston)

# %%
print(boston.data.shape)

# %% [markdown]
# As ,we can see from above 2 statements that there are 5 keys in the
# bunch ['DESCR', 'data', 'feature_names', 'filename', 'target'].
# The data has 506 rows and 13 feature variable.

# %% [markdown]
# Now we will create a dataset which has column name as feature_names and for target attribute
# we create another dataset

# %%
df_x=pd.DataFrame(boston.data,columns=boston.feature_names)

# %%
df_x.head()

# %%
df_y=pd.DataFrame(boston.target)

# %%
df_y.head()

# %% [markdown]
# After Loading data we should check for missing data

# %%
df_x.isnull().sum()

# %%
df_y.isnull().sum()

# %% [markdown]
# Pandas describe() is used to view some basic statistical details of a data frame or a series of numeric values.

# %%
df_x.describe()

# %% [markdown]
# Print a histogram of the quantity to predict: price(which is our target attribute)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(4, 3))
plt.hist(boston.target)
plt.xlabel('price ($1000s)')
plt.ylabel('count')
plt.tight_layout()

# %% [markdown]
# Now, we will use visualizations to understand the relationship of the target variable with other features:

# %%
for index, feature_name in enumerate(boston.feature_names):
    plt.figure(figsize=(4, 3))
    plt.scatter(boston.data[:, index], boston.target)
    plt.ylabel('Price', size=15)
    plt.xlabel(feature_name, size=15)
    plt.tight_layout()

# %% [markdown]
# Next, we split 70% of the data to the training set while 20% of the data to test set using below code.

# %% [markdown]
# After splitting the data into training and testing sets, finally,
# the time is to train our algorithm. For that, we need to import LinearRegression class,
# instantiate it, and call the fit() method along with our training data.

# %%
x_train,x_test,y_train,y_test=train_test_split(df_x,df_y,test_size=0.3,random_state=0)
reg.fit(x_train,y_train)

# %%
reg=LinearRegression()
reg.fit(x_train, y_train)

# %% [markdown]
# Now after training our algorithm its time to make predictions. To do so, we will use our test data and see how accurately our algorithm predicts the percentage score.

# %%
y_predicted=reg.predict(x_test)

# %%
y_predicted

# %%
# Plot a graph between Y_predicted and y_test values:

# %%
plt.figure(figsize=(4, 3))
plt.scatter(y_test, y_predicted)
plt.plot([0, 50], [0, 50])
plt.axis('tight')
plt.xlabel('True price ($1000s)')
plt.ylabel('Predicted price ($1000s)')
plt.tight_layout()

# %% [markdown]
#  Now we will see difference in y_test and y_predicted value

# %%
y_predicted[0]

# %%
y_test[0]

# %% [markdown]
# #Mean Square Error::The Mean Squared Error (MSE) or Mean Squared Deviation (MSD)
# of an estimator measures the average of error squares i.e. the average squared difference between the
# estimated values and true value.

# %%
# for Mean Square Error we have to import numpy Library

import numpy as np

np.mean((y_predicted-y_test)**2)
