# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np

# %%
#1. creating Numpy Arrays

#a. np.array()
arr1 = np.array([1,2,3])

#b. np.arange()
arr2 = np.arange(10)

#c. np.linspace()
arr3 = np.linspace(-10,10,10)

#d. np.ones()/np.zeros()/np.random()
arr4 = np.zeros((3,3))

arr5 = np.ones((3,3))

arr6 = np.random.random((3,3))
arr6
#e. np.identity()
arr7 = np.identity(3)
arr7

# %%
# Numpy Attributes
arr8 = np.array([[[1,2,0],[3,4,6]],[[5,6,7],[7,8,9]]])
#a. shape
arr8.shape
#b. ndim
arr8.ndim
#c. size
arr8.size
#d. dtype
arr7.dtype
#d. itemsize
arr.itemsize

# %%
# Reshape
arr10 = np.arange(24).reshape(3,2,4)
arr10

# %%
arr11= np.arange(24).reshape(4,6)

arr2

# %%
arr2[-1]

# %%
arr2[7:]

# %%
arr([2:5])

# %%
arr2[2:5]

# %%
arr11

# %%
arr11[0,0]

# %%
arr11[0]

# %%
arr[-1]

# %%
arr11[1:]

# %%
arr1[:,0]

# %%
arr11[:0]

# %%
arr11[:,0]

# %%
arr11

# %%
arr11[1:3,2:4]

# %%
arr11[2:,4:]

# %%
arr11[1::2,1:4:2]

# %%
arr10

# %%
arr10[0,0]

# %%
arr10[0,1,:]

# %%
arr10[:,1]

# %%
arr11

# %%
arr10

# %%
arr[:,1,-1]

# %%
arr10[:,1,-1]

# %%
#array operations
arr11

# %%
arr13= np.arange(24,48).reshape(4,6)

# %%
arr13

# %%
arr11*2

# %%
arr11* -2

# %%
arr11 % 2

# %%
arr11 + arr12

# %%
arr11 + arr13

# %%
arr11

# %%
arr13

# %%
arr11 % arr13

# %%
arr11 > 4

# %%
arr11

# %%
arr11.min()

# %%
arr11.max()

# %%
arr11.mean()

# %%
arr11.std

# %%
arr11.std()

# %%
arr11.min(axis=0)

# %%
arr11

# %%
arr11.min(axis=1)

# %%
np.log(arr11)

# %%
np.sin(arr11)

# %%
arr11.dot(arr13)

# %%
arr11

# %%
arr13

# %%
np.dot(arr11,arr13)

# %%
np.dot(arr11,arr13.reshape(6,4))

# %%
x = np.linspace(-10,10,100)

# %%
x

# %%
y = x * x

# %%
y

# %%
y.shape

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)

# %%
y= np.sin(x)

# %%
plt.plot(x,y)

# %%
y = np.sin(x) + x*x

# %%
plt.plot(x,y)

# %%
y= np.log(x)

# %%
plt.plot(x,y)

# %%
y= np.sin(x) + np.log(x)

# %%
plt.plot(x,y)
