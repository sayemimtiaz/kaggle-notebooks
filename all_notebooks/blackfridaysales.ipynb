# %%
import pandas as pd
import numpy as np

df=pd.read_csv('../input/black-friday-sales-prediction/train_oSwQCTC (1)/train.csv')

df.head(3)

# %%
df.columns

# %%
df.drop(['User_ID','Product_ID'], axis=1, inplace=True)

# %%
df.isnull().sum()

# %%
df.isnull().mean()

# %%
df.dtypes

# %%
df.columns

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

plt.style.use('seaborn-darkgrid')

# %%
print('The Unique element present in Gender')
print(df['Gender'].unique())
sns.countplot(df['Gender'])
plt.show()
import collections
c=collections.Counter(df['Gender'])
print('The count of Each unique element')
print(c)

# %%
print('The Unique element present in Age')
print(df['Age'].unique())
plt.figure(figsize=(10,5))
sns.countplot(df['Age'])
plt.show()
print('The count of Each unique element')
print(df['Age'].value_counts())
df['Age'].value_counts(normalize = True).plot.bar(title = 'Age')

# %%
df['Age']=df['Age'].replace('55+','55')
print(df['Age'].unique())

# %%
print('The Unique element present in Occupation')
print(df['Occupation'].unique())
plt.figure(figsize=(10,5))
sns.countplot(df['Occupation'])
plt.show()
print('The count of Each unique element')
print(df['Occupation'].value_counts())
plt.figure(figsize=(10,5))
df['Occupation'].value_counts(normalize = True).plot.bar(title = 'Occupation')

# %%
df.columns

# %%
print('The Unique element present in City_Category')
print(df['City_Category'].unique())
#plt.figure(figsize=(10,5))
sns.countplot(df['City_Category'])
plt.show()
print('The count of Each unique element')
print(df['City_Category'].value_counts())
df['City_Category'].value_counts(normalize = True).plot.bar(title = 'City_Category')

# %%
print('The Unique element present in Stay_In_Current_City_Years')
print(df['Stay_In_Current_City_Years'].unique())
plt.figure(figsize=(10,5))
sns.countplot(df['Stay_In_Current_City_Years'])
plt.show()
print('The count of Each unique element')
print(df['Stay_In_Current_City_Years'].value_counts())
plt.figure(figsize=(10,5))
df['Stay_In_Current_City_Years'].value_counts(normalize = True).plot.bar(title = 'Stay_In_Current_City_Years')

# %%
df['Stay_In_Current_City_Years']=df['Stay_In_Current_City_Years'].replace('4+','4')

print('The Unique element present in Stay_In_Current_City_Years')
print(df['Stay_In_Current_City_Years'].unique())

# %%
print('The Unique element present in Marital_Status')
print(df['Marital_Status'].unique())
#plt.figure(figsize=(10,5))
sns.countplot(df['Marital_Status'])
plt.show()
print('The count of Each unique element')
print(df['Marital_Status'].value_counts())
df['Marital_Status'].value_counts(normalize = True).plot.bar(title = 'Marital_Status')
plt.show()
plt.figure(figsize = (10, 5))
sns.violinplot(x = 'City_Category', y = 'Purchase', hue = 'Marital_Status', data = df)

# %%
print('The Unique element present in Product_Category_1')
print(df['Product_Category_1'].unique())
plt.figure(figsize=(10,5))
sns.countplot(df['Product_Category_1'])
plt.show()
print('The count of Each unique element')
print(df['Product_Category_1'].value_counts())
plt.figure(figsize=(10,5))
df['Product_Category_1'].value_counts(normalize = True).plot.bar(title = 'Product_Category_1')

# %%
print('The Unique element present in Product_Category_2')
print(df['Product_Category_2'].unique())
plt.figure(figsize=(10,5))
sns.countplot(df['Product_Category_2'])
plt.show()
print('The count of Each unique element')
print(df['Product_Category_2'].value_counts())
plt.figure(figsize=(10,5))
df['Product_Category_2'].value_counts(normalize = True).plot.bar(title = 'Product_Category_2')

# %%
print('The Unique element present in Product_Category_1')
print(df['Product_Category_3'].unique())
plt.figure(figsize=(10,5))
sns.countplot(df['Product_Category_3'])
plt.show()
print('The count of Each unique element')
print(df['Product_Category_3'].value_counts())
plt.figure(figsize=(10,5))
df['Product_Category_3'].value_counts(normalize = True).plot.bar(title = 'Product_Category_3')

# %%
df.describe().T

# %%
df.corr()

# %%
df['Product_Category_3'].isnull().mean()

# %%
df.drop(['Product_Category_3'], axis=1, inplace=True)

# %%
df.columns

# %%
df.isnull().mean()

# %%
df1=df.copy()

# %%
df1.dropna(inplace=True)

# %%
df1.isnull().mean()

# %%
from scipy.stats import norm
plt.figure(figsize=(10,5))
sns.distplot(df1['Purchase'], color='maroon', fit=norm, kde=False)
plt.show()

sns.boxplot(df1['Purchase'])
plt.show()

# %%
df1.dtypes

# %%
df1['Occupation']=df1['Occupation'].astype('object')

# %%
df1['Occupation'].dtypes, df1['Age'].dtypes

# %%
df1.dtypes

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
df1['Gender']=l.fit_transform(df1['Gender'])
df1['Age']=l.fit_transform(df1['Age'])
df1['Occupation']=l.fit_transform(df1['Occupation'])
df1['City_Category']=l.fit_transform(df1['City_Category'])
df1['Stay_In_Current_City_Years']=l.fit_transform(df1['Stay_In_Current_City_Years'])

# %%
df1.head()

# %%
df1['Occupation'].unique()

# %%
df1['Product_Category_2']=df1['Product_Category_2'].astype('int64')

# %%
df1.head(1)

# %%
X=df1.drop(['Purchase'], axis=True)
y=df1['Purchase']

# %%
X.head(1)

# %%
from sklearn.preprocessing import MinMaxScaler
df_num_scl=MinMaxScaler()
x=df_num_scl.fit_transform(X)

# %%
x[:1]

# %%
x=pd.DataFrame(data=x, columns=X.columns)

# %%
x.head(1)

# %%
X_d=x[['Product_Category_1']]
X_d[:5]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape

# %%
#Linear Regression
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
model=lr.fit(X_train, y_train)

# %%
model.score(X_test,y_test)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

# %%
import xgboost as xg
from sklearn.metrics import mean_squared_error as MSE
xgb_r = xg.XGBRegressor(n_estimators=500,learning_rate=0.2,gamma=0,min_child_weight=10,
                           subsample=0.8,colsample_bytree=1,max_depth=7)
xgb_r.fit(X_train, y_train)

# %%
xgb_r.score(X_test,y_test)

# %%
xgb=cross_val_score(xg.XGBRegressor(n_estimators=500,learning_rate=0.2,gamma=0,min_child_weight=10,
                           subsample=0.8,colsample_bytree=1,max_depth=7),X_train, y_train, cv=5)
print(xgb)

print('The mean Score', np.mean(xgb))

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
y_pred = xgb_r.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_pred, y_test))
print("RMSE : ", rmse)
print("R2 score:", r2_score(y_test,y_pred))

# %% [markdown]
# ## Test data

# %%
df = pd.read_csv('../input/black-friday-sales-prediction/test_HujdGe7 (1)/test.csv')

# %%
df.head()

# %%
df.columns

# %%
df.drop(['User_ID','Product_ID'], axis=1, inplace=True)

# %%
df.isnull().sum()

# %%
df.isnull().mean()

# %%
df.dtypes

# %%
df.columns

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
print('The Unique element present in Gender')
print(df['Gender'].unique())
sns.countplot(df['Gender'])
plt.show()
import collections
c=collections.Counter(df['Gender'])
print('The count of Each unique element')
print(c)

# %%
print('The Unique element present in Age')
print(df['Age'].unique())
plt.figure(figsize=(10,5))
sns.countplot(df['Age'])
plt.show()
print('The count of Each unique element')
print(df['Age'].value_counts())

# %%
df['Age']=df['Age'].replace('55+','55')
print(df['Age'].unique())

# %%
print('The Unique element present in Occupation')
print(df['Occupation'].unique())
plt.figure(figsize=(10,5))
sns.countplot(df['Occupation'])
plt.show()
print('The count of Each unique element')
print(df['Occupation'].value_counts())

# %%
df.columns

# %%
print('The Unique element present in City_Category')
print(df['City_Category'].unique())
#plt.figure(figsize=(10,5))
sns.countplot(df['City_Category'])
plt.show()
print('The count of Each unique element')
print(df['City_Category'].value_counts())

# %%
print('The Unique element present in Stay_In_Current_City_Years')
print(df['Stay_In_Current_City_Years'].unique())
plt.figure(figsize=(10,5))
sns.countplot(df['Stay_In_Current_City_Years'])
plt.show()
print('The count of Each unique element')
print(df['Stay_In_Current_City_Years'].value_counts())

# %%
df['Stay_In_Current_City_Years']=df['Stay_In_Current_City_Years'].replace('4+','4')

print('The Unique element present in Stay_In_Current_City_Years')
print(df['Stay_In_Current_City_Years'].unique())

# %%
print('The Unique element present in Marital_Status')
print(df['Marital_Status'].unique())
#plt.figure(figsize=(10,5))
sns.countplot(df['Marital_Status'])
plt.show()
print('The count of Each unique element')
print(df['Marital_Status'].value_counts())

# %%
print('The Unique element present in Product_Category_1')
print(df['Product_Category_1'].unique())
plt.figure(figsize=(10,5))
sns.countplot(df['Product_Category_1'])
plt.show()
print('The count of Each unique element')
print(df['Product_Category_1'].value_counts())

# %%
print('The Unique element present in Product_Category_2')
print(df['Product_Category_2'].unique())
plt.figure(figsize=(10,5))
sns.countplot(df['Product_Category_2'])
plt.show()
print('The count of Each unique element')
print(df['Product_Category_2'].value_counts())

# %%
print('The Unique element present in Product_Category_1')
print(df['Product_Category_3'].unique())
plt.figure(figsize=(10,5))
sns.countplot(df['Product_Category_3'])
plt.show()
print('The count of Each unique element')
print(df['Product_Category_3'].value_counts())

# %%
df['Product_Category_3'].isnull().mean()

# %%
df.columns

# %%
df.isnull().mean()

# %%
df['Product_Category_2']=df['Product_Category_2'].fillna(df['Product_Category_2'].mean())
df['Product_Category_3']=df['Product_Category_3'].fillna(df['Product_Category_3'].mean())

# %%
df.isnull().mean()

# %%
df['Occupation']=df['Occupation'].astype('object')

# %%
df['Occupation'].dtypes, df['Age'].dtypes

# %%
df.dtypes

# %%
df1=df.copy()

# %%
df1.head(3)

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
df1['Gender']=l.fit_transform(df1['Gender'])
df1['Age']=l.fit_transform(df1['Age'])
df1['Occupation']=l.fit_transform(df1['Occupation'])
df1['City_Category']=l.fit_transform(df1['City_Category'])
df1['Stay_In_Current_City_Years']=l.fit_transform(df1['Stay_In_Current_City_Years'])

# %%
df1.head()

# %%
df1['Occupation'].unique()

# %%
df1['Product_Category_2']=df1['Product_Category_2'].astype('int64')

# %%
from sklearn.preprocessing import MinMaxScaler
df_num_scl=MinMaxScaler()
x=df_num_scl.fit_transform(df1)

# %%
x=pd.DataFrame(data=x, columns=df1.columns)

# %%
x.head(3)

# %%
x.drop(['Product_Category_3'], axis=1, inplace=True)

# %%
# Test data prediction!

# %%
Test_predict_value=xgb_r.predict(x)

# %%
submission=pd.read_csv('/kaggle/input/black-friday-sales-prediction/sample_submission_V9Inaty.csv')

# %%
submission.head(2)

# %%
submission.drop(['Purchase'], axis=1, inplace=True)

# %%
submission.head(2)

# %%
submission['Purchase']=Test_predict_value

# %%
submission.head(1)

# %%
submission.shape

# %%
submission.to_csv('submission.csv',index=False)

# %%
from IPython.display import HTML
import pandas as pd
import numpy as np
import base64

# function that takes in a dataframe and creates a text link to  

def create_download_link(df, title = "Download CSV file", filename = "data.csv"):  
    csv = df.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

create_download_link(submission)
