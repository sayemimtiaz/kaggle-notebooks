# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('../input/height-prediction-dataset'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
INCHES_MULTIPLIER = 2.54
POUND_MULTIPLIER = 2.20462262


def inches_to_cm(value):
    return value * INCHES_MULTIPLIER


def kg_to_pounds(value):
    return value * POUND_MULTIPLIER


data = pd.read_csv("../input/height-prediction-dataset/hw_25000.csv", index_col=0)
melbourne_data = data.dropna(axis=0)
y = data.Height
features = ['Weight']
X = data[features]
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)
height_model = DecisionTreeRegressor(max_leaf_nodes=100, random_state=1)
height_model.fit(train_X, train_y)
val_pred = height_model.predict(val_X)
print("MAE:",mean_absolute_error(val_pred, val_y))

# %%
weight = kg_to_pounds(70)
weight = pd.DataFrame({0: weight}, index=['Index'])
pred_height = height_model.predict(weight)
pred_height = inches_to_cm(pred_height)
print(f'Your height is probably around {round(pred_height[0],2)}cm')
