# %% [markdown]
# While words and phrases such as “robot,” “self-driving car,” and “artificial intelligence” are in fairly wide use these days, it’s much less common to come across the term “autonomous system.” And yet, robots and self-driving cars are both autonomous systems, and artificial intelligence is a big part of what makes them possible. So why is “autonomous system” not a more familiar term?
# Part of it may have to do with the history of the term itself. When we trace it back in time, we find multiple origins, with the term being previously used in arenas such as mathematics and networking. To make matters more confusing, its present usage is still evolving as well. The term “autonomous systems” is actually still a relatively new term, and it continues to take on new dimensions as new technologies and applications emerge.
# Let’s consider the term’s history first. One key usage comes to us from the realm of mathematics. As described in the Encyclopedia of Mathematics, the term “autonomous system” is synonymous with “autonomous differential equation,” and an autonomous system in this context can be defined as, “A system of ordinary differential equations which does not explicitly contain the independent variable (time).” A parallel historical usage can be found in networking, where an autonomous system is understood to be  a collection of Internet Protocol routing prefixes controlled by one or more network operators.
# https://blog.udacity.com/2018/09/what-is-an-autonomous-system.html

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# Image youtube.com
# * MACHINE TEACHING: How people’s expertise makes AI even more powerful
# * Machine teaching seeks to gain knowledge from people rather than extracting knowledge from data alone. A person who understands the task at hand — whether how to decide which department in a company should receive an incoming email or how to automatically position wind turbines to generate more energy — would first decompose that problem into smaller parts. Then they would provide a limited number of examples, or the equivalent of lesson plans, to help the machine learning algorithms solve it.
# * In supervised learning scenarios, machine teaching is particularly useful when little or no labeled training data exists for the machine learning algorithms because an industry or company’s needs are so specific. https://blogs.microsoft.com/ai/machine-teaching/

# %% [markdown]
# <iframe width="951" height="535" src="https://www.youtube.com/embed/-trd_f6j3eI" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# Jared gets stuck in driverless car - Silicon Valley comedy series HBO

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import cv2

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %% [markdown]
# Fig.6.1a.png   There is no legend for that map below (in the AI Report 2019).

# %%
#codes from Endi Niu @niuddd
img = cv2.imread('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/Graphics/Chapter 6. Autonomous Systems/Fig. 6.1a..png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
fig = plt.figure(figsize=(8,8))
plt.imshow(img)

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSbUfIJxFbPOT-OTs9T_oC1Dj7NbpaoJjzUOa46O2BjeFJMSMY67A&s',width=400,height=400)

# %% [markdown]
# Image meetup.com
# * Artificial Intelligence and Autonomous Systems are the main driving forces behind the new fourth industrial revolution – a silent revolution that is already happening around all of us, changing the way we talk, shop, and perceive the world. This talk will give you an “in a nutshell”-insight into the latest developments of these technologies, how they work and where we are today.https://www.meetup.com/pt-BR/Glasgow-skeptics/events/264448947/

# %% [markdown]
# Below: Fig.6.1b.legend.png and Fig.6.1.png (world map)
# * Pilot Area tags.

# %%
#codes from Endi Niu @niuddd
img = cv2.imread('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/Graphics/Chapter 6. Autonomous Systems/Fig. 6.1b..png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
fig = plt.figure(figsize=(8,8))
plt.imshow(img)

# %%
#codes from Endi Niu @niuddd
img = cv2.imread('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/Graphics/Chapter 6. Autonomous Systems/Fig. 6.1b. legend.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
fig = plt.figure(figsize=(8,8))
plt.imshow(img)

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQex2i0vtMRPKc3I_a2NvxJ4d4UI90qiVo5m5uJidPCvvfEtYjl&s',width=400,height=400)

# %% [markdown]
# Image above  drivinglaws.aaa.com
# * Below: Fig.6.2.legend.png and Fig.6.2.png - World Map.
# * LAW GROUP

# %%
img = cv2.imread('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/Graphics/Chapter 6. Autonomous Systems/Fig. 6.2. legend.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
fig = plt.figure(figsize=(8,8))
plt.imshow(img)

# %%
#codes from Endi Niu @niuddd
img = cv2.imread('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/Graphics/Chapter 6. Autonomous Systems/Fig. 6.2..png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
fig = plt.figure(figsize=(8,8))
plt.imshow(img)

# %% [markdown]
# Below: Fig.6.3.png
# * Total number of AV companies and Vehicles testing in California.

# %%
#codes from Endi Niu @niuddd
img = cv2.imread('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/Graphics/Chapter 6. Autonomous Systems/Fig. 6.3..png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
fig = plt.figure(figsize=(8,8))
plt.imshow(img)

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSsgd7Y6A1opyvEkI47LxCyiuDOmVPCBOfImjGJdQ3BZ4FtDhDv&s',width=400,height=400)

# %% [markdown]
# Image above fortune.com
# * Below: Fig.6.4.png
# * Total number of AV driven in California

# %%
#codes from Endi Niu @niuddd
img = cv2.imread('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/Graphics/Chapter 6. Autonomous Systems/Fig. 6.4..png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
fig = plt.figure(figsize=(8,8))
plt.imshow(img)

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSevIP3z9NYOU2Pk9-71Gt6xMSB8bE1WcpziQWXm3Ehm1z-YGNNVQ&s',width=400,height=400)

# %% [markdown]
# Image above shutterstock.com
# * Below: Fig.6.5.png
# * California coded autonomous crashes per autonomous mile 2015-2018

# %%
#codes from Endi Niu @niuddd
img = cv2.imread('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/Graphics/Chapter 6. Autonomous Systems/FIg. 6.5..png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
fig = plt.figure(figsize=(8,8))
plt.imshow(img)

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSpBQejoV1cyzCRdENRoderdlxxZUi1ndjQSkwNgB2XArov-gvo0A&s',width=400,height=400)

# %% [markdown]
# Image tech.co
# * These self-driving cars are supposed to be more efficient than human drivers, not to mention safer. However, according to the records from the California Department of Motor Vehicles (DMV) we can observe that, well, autonomous cars crash. A lot https://tech.co/news/mapping-driverless-car-crash-california-2018-10

# %%
#codes from Endi Niu @niuddd
img = cv2.imread('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/Graphics/Chapter 6. Autonomous Systems/Fig. 6.7a.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
fig = plt.figure(figsize=(8,8))
plt.imshow(img)

# %% [markdown]
# Above Fig.6.7a.png
# * Autonomous Military Systems Developed Worldwide, 1970-2016.

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSPpHl3rvN-5pYS5OQ6wVLCZ3GOXh0dJuH_0bZsnIpofh66ZAxzAw&s',width=400,height=400)

# %% [markdown]
# Image asianmilitaryreview.com
# * The UK MoD has recognised the potential of Robotic and Autonomous Systems (RAS), with a new multi-million-pound Transformation Fund to fast-track military robotic projects onto the battlefield this year. Enhanced RAS systems enable militaries to see more, understand more, cover a greater area and be more lethal, these game-changing capabilities are increasingly important in today’s digital battlespace.https://asianmilitaryreview.com/events/military-robotics-and-autonomous-systems-2020/

# %%
#codes from Endi Niu @niuddd
img = cv2.imread('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/Graphics/Chapter 6. Autonomous Systems/Fig. 6.7b.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
fig = plt.figure(figsize=(8,8))
plt.imshow(img)

# %% [markdown]
# Above Fig.6.7b.png
# * Number of Autonomous Military Systems Developed, 1950-2017.

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRF29HsNurE4r9it_dkf-S4vY9GMk8SWDzAugqoefRIfkCylRCfBw&s',width=400,height=400)

# %% [markdown]
# Image army.mil
# * Imagine a small U.S. Special Forces team conducting covert operations in a hostile territory. The mission requires the team be limited in size, but able to carry extensive equipment, both explosive and inert, in order to execute the mission. What makes this team so unique? It consists of both Soldiers and robots as team members. https://www.army.mil/article/226976/army_research_advances_autonomous_systems

# %% [markdown]
# <iframe width="724" height="407" src="https://www.youtube.com/embed/Tb627xDlqBs" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# The Big Bang Theory / Howard Wolowitz - Robotic Hand
# * Conclusion: If you build a Robot don't slip and fall. Otherwise the robot hand can stick on some part of your body. Where's the rest of the robot? He only built the arm, because that's all he needed
# * Best quote on that scene "You do what you want I'm not touching another man's honey tree". Spoiler alert: "Winnie the Pooh could get out of the honey tree!"
# * In my defense, Stephen Hawking, Steve Wozniak, Neil deGrasse Tyson, Buzz Aldrin, Bill Nye and Elon Musk participated on that show. Not on the honey tree, of course.

# %% [markdown]
# Kaggle Notebook Runner: Marília Prata @mpwolke
