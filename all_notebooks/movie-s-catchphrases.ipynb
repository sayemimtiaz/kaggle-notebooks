# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS6Uezk6SoZdDd7v_Mb3M-kZ42l6Twpu-SdGA&usqp=CAU)weareteachers.com

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('../input/150-famous-movie-catchphrases-with-context/Catchphrase.csv', encoding='ISO-8859-2')
df.head()

# %% [markdown]
# #YOLO predicts several bounding boxes. Hakuna Matata Yolo!
#
# ![](https://images-wixmp-ed30a86b8c4ca887773594c2.wixmp.com/f/bf2c5b15-591e-4e52-9f29-9080e6589898/ddsyo94-d70a80a5-a67a-4ffc-930f-ed4d18672c1c.jpg?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJ1cm46YXBwOiIsImlzcyI6InVybjphcHA6Iiwib2JqIjpbW3sicGF0aCI6IlwvZlwvYmYyYzViMTUtNTkxZS00ZTUyLTlmMjktOTA4MGU2NTg5ODk4XC9kZHN5bzk0LWQ3MGE4MGE1LWE2N2EtNGZmYy05MzBmLWVkNGQxODY3MmMxYy5qcGcifV1dLCJhdWQiOlsidXJuOnNlcnZpY2U6ZmlsZS5kb3dubG9hZCJdfQ.odKh94BM4jx37gYDsEHE3RUHwie_YCBigzm280Ryq44)deviantart.com

# %%
#1st column, Catchphrase, 136th Row

df.iloc[136,0]

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTJrdh_S8G5C5hruIVo5dhRQxYF6shlrzOCiQ&usqp=CAU)memegenerator.net

# %%
#1st column, Catchphrase, 111th Row

df.iloc[111,0]

# %% [markdown]
# #Instead of beggging: "please..." Be innovative, by writing: "Force help, Master is In".
#
# #Even Masters need support.
#
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQuuWc8KZhkG5_xmwggSAuSBQGWVKkmqzfCnQ&usqp=CAU)drparsoncarson.wordpress

# %%
#1st column, Catchphrase, 144th Row

df.iloc[144,0]

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSVZ4saUSepv32TLYAg7zGVmFfNlOmuYwa69Q&usqp=CAU)me.me

# %%
#1st column, Catchphrase, 14th Row

df.iloc[14,0]

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSxqHGQh6sOy62-TIM_1YSb0O7q0O8oquIAmw&usqp=CAU)memegenerator.net

# %%
#1st column, Catchphrase, 136th Row

df.iloc[139,0]

# %% [markdown]
# ![](https://i.chzbgr.com/original/6769920256/h0BE780EE/nerds-you-shall-not-pass-lady-6769920256)memebase.cheezburger.com

# %%
#1st column, Catchphrase, 33rd Row

df.iloc[33,0]

# %% [markdown]
# #Even Horatio Caine (CSI Miami), he doesn't give a damm. Cause he had The Who (Won't Get Fooled Again -Yeeaaaahh!).
#
# ![](https://lh3.googleusercontent.com/proxy/yFPQsBMRyjqObbOP0WO9a2A_CrguRxJrVwPAQtvPbF6YJomVb117yvE5VJlKum2Kcn9HXi4qjFaoACCTJMFn5c1fIqwYCaytxoZToYU-vRI9ExMg5v649xk1YoIxqP7cqinUd5a6CgyVY-R3wiH1xtB-ZeK8sBqh9Ek)quickmeme.com

# %% [markdown]
# #Better build an Algorithm: The IDGD, a.k.a. I don't give a Damm algorithm. Now, I'm a "developer".

# %%
#!pip install IDGD

# %%
#from IDGD.viz import IDontGiveaDamm

# %%
#Ignore_chart(df=None, col='Ignore', colors=no_clue)
print('I don t give a Damm. Yeeaaaahh!')
print('Next')

# %%
#1st column, Catchphrase, 106th Row

df.iloc[106,0]

# %% [markdown]
# #LeaderBoard Shake up.
#
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTP7GMtiyaeSNQ3RFx5sqhGZQPqdNTzaKUvyg&usqp=CAU)wallpapersafari.com

# %%
#1st column, Catchphrase, 34th Row

df.iloc[34,0]

# %% [markdown]
# #Live Long and Prosper BRIC's Greeting
#
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ9YW89bYggbHUsZumF5PefNGST6-0cnU71VA&usqp=CAU)memeguy.com

# %%
#1st column, Catchphrase, 143th Row

df.iloc[143,0]

# %% [markdown]
# #Good for NLP sentiment analysis. Could you tell what's positive, neutral or negative?
#
# #Spoiler alert: Negativity detected by the voice modulation.
#
# ![](https://www.sharecopia.com/upload/images1/woman-space.jpg)sharecopia.com

# %%
#1st column, Catchphrase, 36th Row

df.iloc[36,0]

# %% [markdown]
# ![](https://pics.esmemes.com/andere-am-letzten-schultag-stra-oh-nein-ich-werde-euch-23380167.png)esmemes.com

# %%
#1st column, Catchphrase, 145th Row

df.iloc[145,0]

# %% [markdown]
# ![](https://i.pinimg.com/736x/dd/c5/23/ddc5231d293679c5085a9da454a0ae17.jpg)pinterest.com

# %%
#1st column, Catchphrase, 148th Row

df.iloc[148,0]

# %% [markdown]
# #Competitors "In the Money" (zone).
#
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS6yvKKW5wkYBfpRDfHkPL1Gibyzg6msqmX7g&usqp=CAU)makeameme.org

# %%
#1st column, Catchphrase, 58th Row

df.iloc[58,0]

# %% [markdown]
# ![](https://i.pinimg.com/originals/bd/49/ec/bd49ec0b0188eab381e62fd9e49f4a76.jpg)pinterest.dk

# %%
#1st column, Catchphrase, 52nd Row

df.iloc[52,0]
