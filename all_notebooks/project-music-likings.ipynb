# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load


import pandas as pd 
df = pd.read_csv('../input/project-vgsales/vgsales.csv')
df

# %%
df.shape
df.describe()

# %%
df.values

# %%
import pandas as pd 
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score



af = pd.read_csv('../input/project-musiclikings/music.csv')
af
D = af.drop(columns=['genre'])
D

# %%
Y = af ['genre']
Y
D_train, D_test, Y_train, Y_test = train_test_split(D,Y, test_size = 0.2)

# %%
import pandas as pd 
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

model = DecisionTreeClassifier()
model.fit(D_train,Y_train)
af

# %%
predictions = model.predict(D_test)
predictions


score = accuracy_score(Y_test, predictions)
score
