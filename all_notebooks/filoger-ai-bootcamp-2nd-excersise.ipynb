# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Part1

# %%
df=pd.read_csv('../input/hotel-booking/hotel_booking.csv')

# %%
df.head(3)

# %%
df.columns

# %% [markdown]
# # Part2

# %%
df.shape

# %%
df.describe()

# %% [markdown]
# # Part3

# %%
print("The total number of dataset's raw is{}".format(len(df)))

# %% [markdown]
# # Part4

# %%
s=df.isnull().sum()
print("max missing data is in columns {}".format(s.idxmax()))

# %% [markdown]
# # Part5

# %%
df_2=df.drop('company',axis=1)

# %%
df_2.head(3)

# %% [markdown]
# # Part6

# %%
count_numbers=df['country'].value_counts()
count_numbers.sort_values
count_numbers[:5]

# %% [markdown]
# # Part7,8 and 9

# %%
print("The highest adr paid person is  {}".format(df.name[df['adr'].idxmax()]))
print("who paid {} USD".format(df['adr'].max()))

# %%
round(df['adr'].mean(),2)

# %%
round(df[['stays_in_week_nights']+['stays_in_weekend_nights']].mean(),2)

# %% [markdown]
# # Part 10

# %%
df3=df[df['total_of_special_requests']==5]

# %%
df4=df3[['name', 'email','total_of_special_requests']]
df4

# %%
df4.shape

# %% [markdown]
# # Part 11

# %%
df5=df.loc[df['name'].str.split().str.len() == 2, 'last name'] = df['name'].str.split().str[-1]

# %%
count_numbers=df5.value_counts()
count_numbers.sort_values
count_numbers[:5]

# %% [markdown]
# # Part 12

# %%
print("the person who reserved hotel with highest children number is mr.  {}".format(df.name[df['children'].idxmax()]))
print("whith {} numbers of childrens".format(df['children'].max()))
print("the person who reserved hotel with highest babies number is mr.  {}".format(df.name[df['babies'].idxmax()]))
print("whith {} numbers of babies".format(df['babies'].max()))
