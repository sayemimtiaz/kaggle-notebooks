# %% [markdown]
# <h1  style="font-family:verdana; color:#159364;"> <center>📚 Create Better EDA and Analysis Report  📚</center> </h1>
# <p><center style="color:color:#159364; font-family:cursive;">Keep learning</center></p>
#
# ***

# %% [markdown]
# ![](https://miro.medium.com/max/1000/0*hUeopQVbu6SL50Oc.png)

# %% [markdown]
# <font size="+2" color=black ><b> <left>So firstly what is EDA??? </left></b></font><br><a id="top"></a>
# - So `Exploratory Data Analysis` is process of initial investigations
# on data in order to discover patterns,to spot anomalies,to test hypothesis
# and to check assumptions with the help of summary statistics and graphical representations.
# - In this Kernel we are going to see differnt ways to produce an EDA on any kind of data
# 1. [SweetViz](https://pypi.org/project/sweetviz/)
# 2. [PandasProfiling](https://github.com/pandas-profiling/pandas-profiling)
# 3. [AutoViz](https://github.com/AutoViML/AutoViz)
# 4. [D-tale]()

# %%
import pandas as pd
import numpy as np

## importing the HrAnalysis data to generate reports
train=pd.read_csv('../input/hranalysis/train.csv')

# %%
# How the data looks like 
train.head()

# %%
# Dropping the NULL values
train.dropna()

# %% [markdown]
# *****

# %% [markdown]
# # <font size="+3" color=#159364 ><b> <left>1.SweetViz One line EDA </left></b></font><br><a id="top"></a>
# It is a python library that generates beautiful, high-density visualizations to start your EDA.
#
# Let us explore Sweetviz in detail.

# %% [markdown]
# ![](https://miro.medium.com/max/2696/1*gzjihqg1TQuJpkNvBCoiOQ.png)

# %%
# Installing the sweetviz library
# !pip install sweetviz

# %%
import sweetviz

# %%
Report=sweetviz.analyze([train,"train"],"is_promoted")

# %%
Report.show_html()

# %% [markdown]
# ##### 📌 The report is saved in the output folder and you can check out the report

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#159364;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#         <p style="padding: 10px;
#               color:white;">
#             🎉🎉🎉 Here is your complete report using SweetViz.
#         </p>
#     </div>

# %% [markdown]
# *****

# %% [markdown]
# # <font size="+3" color=#159364 ><b> <left>2.Pandas Profiling </left></b></font><br><a id="top"></a>

# %% [markdown]
# ![](https://camo.githubusercontent.com/8a45c0936d6113b12b7b32942f448270eda8f714665ba8629f36c291f0ccd5fd/68747470733a2f2f70616e6461732d70726f66696c696e672e6769746875622e696f2f70616e6461732d70726f66696c696e672f646f63732f6173736574732f6c6f676f5f6865616465722e706e67)

# %% [markdown]
# Generates profile reports from a pandas DataFrame. The pandas `df.describe()` function is great but a little basic for serious exploratory data analysis. `pandas_profiling` extends the pandas DataFrame with `df.profile_report()` for quick data analysis.

# %%
import pandas_profiling as pp

# %%
pp.ProfileReport(train)

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#159364;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#         <p style="padding: 10px;
#               color:white;">
#             🎉🎉🎉 Here is your complete report using Pandas-Profiling.
#         </p>
#     </div>

# %% [markdown]
# *****

# %% [markdown]
# # <font size="+3" color=#159364 ><b> <left>3.AutoViz </left></b></font><br><a id="top"></a>
# **Autoviz is an open-source python library that mainly works on visualizing the relationship of the data, it can find the most impactful features and plot creative visualization in just one line of code. Autoviz is incredibly fast and highly useful.**

# %%
# !pip install autoviz

# %%
# !pip install xlrd

# %%
from autoviz.AutoViz_Class import AutoViz_Class
Av = AutoViz_Class()

# %%
train = Av.AutoViz("../input/hranalysis/train.csv")

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#159364;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#         <p style="padding: 10px;
#               color:white;">
#             🎉🎉🎉 Here is your complete report using <span style="color:white;">Autoviz</span> .
#         </p>
#     </div>

# %% [markdown]
# *****

# %% [markdown]
# # <font size="+3" color=#159364 ><b> <left>4.Dtale </left></b></font><br><a id="top"></a>

# %% [markdown]
# **D-Tale is an open-source python auto-visualization library. It is one of the best auto data-visualization libraries. D-Tale helps you to get a detailed EDA of the data. It also has a feature of code export, for every plot or analysis in the report.**

# %% [markdown]
# ![](data:image/jpeg;base64,...)

# %%
# !pip install dtale

# %%
import dtale
import dtale.app as dtale_app

dtale_app.USE_NGROK = True

d=dtale.show(train)

# %%
d.main_url()

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#159364;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#         <p style="padding: 10px;
#               color:white;">
#             🎉🎉🎉 Here is your complete report using <span style="color:white;">D-Tale</span> just click the url .
#         </p>
#     </div>

# %% [markdown]
# *****

# %% [markdown]
# <center style="font-family:cursive; font-size:30px; color:#159364;">Keep creating meaningful notebooks, and do not forget to Upvote and  comment your views.</center>

# %% [markdown]
# ## HOPE YOU LIKE THIS KERNEL
