# %%
# !pip install lazypredict
# !pip install pandas --upgrade

import numpy as np
import pandas as pd 
from lazypredict.Supervised import LazyRegressor
from sklearn.model_selection import train_test_split

# %%
# Importing the dataset
data = pd.read_csv('_____')
# Displaying the first 5 rows
data.head()

# %%
# Encoding the categorical variables if any
data=pd.get_dummies(_____)

# %%
# Set the column you want to predict 
target = "_____"

X = data.drop(target,axis = 1) 
y = data[target]

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()

# Preparing the model for our dataset 
X = scale.fit_transform(_____)

# %%
# Splitting our dataset for training and testing
X_train, X_test, y_train, y_test = train_test_split(__, __, test_size=0.3)

# %%
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)

# Using our model to make predictions 
models,predictions = clf.fit(_____, _____, _____, _____)

# %%
models
