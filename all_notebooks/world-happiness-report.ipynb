# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import plotly.express as px

# %%
df  =  pd.read_csv('../input/world-happiness-report-2021/world-happiness-report.csv')
df.head()

# %%
df.shape

# %%
df.isnull().sum()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.isnull(),cmap='viridis')
plt.show()

# %%
df.columns

# %%
px.scatter(df,x='Country name',y='Freedom to make life choices',color='year')

# %% [markdown]
# ##### From the above graph we can see over the year freedom to make life choices increased, however in some country it decreased below 0.4 like in afghanistan where as in norway having 96 percent

# %%
px.scatter(df,x='Country name',y='Log GDP per capita',color='year')

# %% [markdown]
# ##### From the above graph we can see Luxemborg has almost consistent  Log GDP per capita from 2009 to 2020 which is highest among other.
#
# #### Top 5 GDP country wise Luxemborg, Singapore, Qatar, Kuwait, Ireland
# #### Bottom GDP country wise Afganistan, Burkina Faso, Ethiopia, Sierra,Mali

# %%
px.scatter(df,x='Country name',y='Perceptions of corruption',color='year')

# %% [markdown]
# ##### From the above graph we can say that
# #### Singapore is the least corrupt country in world
# #### Bonsia and Herzegovina is the most corrupt country in world

# %%
px.scatter(df,x='Country name',y='Healthy life expectancy at birth',color='year')

# %%
px.scatter(df,x='Country name',y='Social support',color='year')

# %%
px.scatter(df,x='Country name',y='Generosity',color='year')

# %%
px.scatter(df,x='Freedom to make life choices',y='Healthy life expectancy at birth',color='Country name')

# %%
px.scatter(df,x='Freedom to make life choices',y='Generosity',color='Country name')

# %%
px.scatter(df,x='Freedom to make life choices',y='Social support',color='Country name')

# %% [markdown]
# # This Notebook is in progress....................
