# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv("../input/tips-bootcamp/tips.csv")

# %%
df.shape

# %%
df.columns

# %%
df.info()

# %%
df.head()

# %%
df.tail()

# %%
df.describe()

# %%
df[['total_bill', 'tip']]

# %%
df['tip_percentage']=100*(df['tip']/df['total_bill'])

# %%
df['tip_percentage']=np.round(df['tip_percentage'],2)

# %%
df[['total_bill', 'tip','tip_percentage']]

# %%
'tip percentage min :{} and tip percentage max:{} '.format(df['tip_percentage'].min(),df['tip_percentage'].max())

# %%
df[(df['tip_percentage']==df['tip_percentage'].max()) | (df['tip_percentage']==df['tip_percentage'].min()) | (df['tip']==df['tip'].max()) ]

# %%
df.head()

# %%
df = df.set_index('Payer Name')

# %%
df.head()

# %%
df.loc['Larry White']

# %%
df[df['total_bill']>45]

# %%
df[df['sex']=='Male'].describe()

# %%
df[df['sex']=='Female'].describe()

# %%
df[(df['day']=='Sun') | (df['day']=='Sat')]

# %%
df[(df['day']=='Sun') | (df['day']=='Sat')].describe()

# %%
df[(df['day']!='Sun') & (df['day']!='Sat')].describe()

# %%
df['time'].unique()

# %%
df[df['time'].isin(['Dinner'])].count()

# %%
df[df['time'].isin(['Lunch'])].count()

# %%
df['day'].unique()
