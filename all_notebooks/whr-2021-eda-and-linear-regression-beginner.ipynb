# %% [markdown]
# # <font color='blue' style='font-size: 30px;'>World Happiness Report 2021</font>
# <hr style='border: 2px solid blue;'>

# %% [markdown]
# > **This is my first job using Python to do data analysis! I hope I keep learning more and more! Please, if you can, comment, criticize for us to grow together!**
#
#
# > *Get vaccinated and be happy!*

# %% [markdown]
# ### WHR:
#
# <p style='font-size: 18px; line-height: 2; margin: 10px 50px; text-align: justify;'>O Relatório de Felicidade Mundial é uma pesquisa histórica sobre o estado de felicidade global. O relatório continua a ganhar reconhecimento global à medida que governos, organizações e sociedade civil usam cada vez mais os indicadores de felicidade para informar suas decisões de formulação de políticas. Os principais especialistas em todos os campos - economia, psicologia, análise de pesquisas, estatísticas nacionais, saúde, políticas públicas e muito mais - descrevem como as medições de bem-estar podem ser usadas de forma eficaz para avaliar o progresso das nações. Os relatórios analisam o estado da felicidade no mundo hoje e mostram como a nova ciência da felicidade explica as variações pessoais e nacionais da felicidade.</p>
#
#
# ### As variáveis explicativas são:
#
#
# <ul style='font-size: 18px; line-height: 2; text-align: justify;'>
# <li><b>The statistics of GDP per capita</b>
# <li><b>Healthy Life Expectancy (HLE)</b>
# <li><b>Social support</b>
# <li><b>Freedom to make life choices</b>
# <li><b>Generosity</b>
# <li><b>Corruption Perception</b>
#  </ul>

# %% [markdown]
# ## Importando bibliotecas

# %%
## importando bibliotecas

import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline

import warnings

warnings.filterwarnings('ignore') # ou warnings.filterwarnings(action='once')

# %%
# palette -> Accent, Accent_r, Blues, Blues_r, BrBG, BrBG_r, BuGn, BuGn_r, BuPu, BuPu_r, CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, Greys_r, OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r, Paired, Paired_r, Pastel1, Pastel1_r, Pastel2, Pastel2_r, PiYG, PiYG_r, PuBu, PuBuGn, PuBuGn_r, PuBu_r, PuOr, PuOr_r, PuRd, PuRd_r, Purples, Purples_r, RdBu, RdBu_r, RdGy, RdGy_r, RdPu, RdPu_r, RdYlBu, RdYlBu_r, RdYlGn, RdYlGn_r, Reds, Reds_r, Set1, Set1_r, Set2, Set2_r, Set3, Set3_r, Spectral, Spectral_r, Wistia, Wistia_r, YlGn, YlGnBu, YlGnBu_r, YlGn_r, YlOrBr, YlOrBr_r, YlOrRd, YlOrRd_r, afmhot, afmhot_r, autumn, autumn_r, binary, binary_r, bone, bone_r, brg, brg_r, bwr, bwr_r, cividis, cividis_r, cool, cool_r, coolwarm, coolwarm_r, copper, copper_r, cubehelix, cubehelix_r, flag, flag_r, gist_earth, gist_earth_r, gist_gray, gist_gray_r, gist_heat, gist_heat_r, gist_ncar, gist_ncar_r, gist_rainbow, gist_rainbow_r, gist_stern, gist_stern_r, gist_yarg, gist_yarg_r, gnuplot, gnuplot2, gnuplot2_r, gnuplot_r, gray, gray_r, hot, hot_r, hsv, hsv_r, icefire, icefire_r, inferno, inferno_r, jet, jet_r, magma, magma_r, mako, mako_r, nipy_spectral, nipy_spectral_r, ocean, ocean_r, pink, pink_r, plasma, plasma_r, prism, prism_r, rainbow, rainbow_r, rocket, rocket_r, seismic, seismic_r, spring, spring_r, summer, summer_r, tab10, tab10_r, tab20, tab20_r, tab20b, tab20b_r, tab20c, tab20c_r, terrain, terrain_r, viridis, viridis_r, vlag, vlag_r, winter, winter_r
sns.set_palette("Accent")

# style -> white, dark, whitegrid, darkgrid, ticks
sns.set_style("darkgrid")

# %% [markdown]
# # <font color='blue' style='font-size: 30px;'>Conhecendo o Dataset:</font>
# <hr style='border: 2px solid black;'>

# %% [markdown]
# ## Leitura dos dados

# %%
## importando o dataset

tabela_2021 = pd.read_csv('../input/world-happiness-report-2021/world-happiness-report-2021.csv')
tabela_2021.head(10)

# %% [markdown]
# ## Importando o DataFrame e criando um DataFrame apenas com as variáveis de estudo

# %%
# Formando o dataframe com as variáveis de estudo

tabela_2021 = tabela_2021[['Country name', 'Regional indicator', 'Ladder score',
       'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']]
tabela_2021

# %% [markdown]
# ## Checando valores nulos

# %%
tabela_2021.info()

# %% [markdown]
# ## Tamanho do dataset

# %%
tabela_2021.shape

# %% [markdown]
# ## Quantos países e de quais regiões são esses países?

# %%
regioes = pd.DataFrame(tabela_2021['Regional indicator'].value_counts())
regioes

# %% [markdown]
# # <font color='blue' style='font-size: 30px;'>Análises Preliminares:</font>
# <hr style='border: 2px solid black;'>

# %% [markdown]
# ## Quadro das principais estatísticas sobre o Dataset

# %%
describe = tabela_2021.describe().round(2).transpose()
describe

# %% [markdown]
# ## Analisando a relação entre média e mediana

# %%
describe[['mean', '50%']]

# %% [markdown]
# ### Observações
# <ul style='font-size: 18px; line-height: 2; text-align: justify;'>
#
# Rápidas considerações sobre o quadro de estatísticas:
#
# - A média do Ladder score é igual a sua mediana.
# - A média de felicidade é de 5,53, em uma escala que vai até 10.
# - 50% dos países tem seu Ladder score até 5,53

# %% [markdown]
# ##  Analisando a distribuição do 'índice de Felicidade'

# %%
ax1 = sns.distplot(tabela_2021['Ladder score'], norm_hist=True)
ax1.figure.set_size_inches(16, 8)
ax1.set_title('Distribuição de Frequências - Ladder', fontsize=18,)
ax1.set_xlabel('Indice de felicidade', fontsize=14)
ax1=0

# %% [markdown]
# ### Observações
# <ul style='font-size: 18px; line-height: 2; text-align: justify;'>
#
# - A distribuição dos índices de felicidade por países se assemelha a uma curva normal

# %% [markdown]
# ## Observando o Boxplot

# %%
fig = sns.boxplot(data=tabela_2021['Ladder score'], orient='h')
fig.figure.set_size_inches(14, 6)
fig.set_title('Box plot - Ladder', fontsize=18,)
fig.set_xlabel('Indice de felicidade', fontsize=14)
fig

# %% [markdown]
# ## Fazendo o boxplot interativo com o Plotly

# %%
import plotly.express as px

fig = px.box(tabela_2021, x='Ladder score', orientation= 'h',  title= 'Boxplor do Indice de felicidade')
fig.show()

# %% [markdown]
# ### Observações
# <ul style='font-size: 18px; line-height: 2; text-align: justify;'>
#
# - Pelo boxplot é possível detectar que há um outlier na amostra, no caso, esse outlier é o Afeganistão com Ladder score de 2,523.

# %% [markdown]
# ## Analisando a correlação entre as variáveis

# %%
cor =tabela_2021.corr().round(2)
cor

# %% [markdown]
# ### Observações
# <ul style='font-size: 18px; line-height: 2; text-align: justify;'>
#
# - Primeiro: Analisar linha 1 do Data Frame, é nela que poderemos observar o índice de correlação da variável dependente(Ladder score) com as variáveis explicativas.
#
# - Segundo: Importante observar a correlação entre as variáveis explicativas para futuras modelagens de regressão e analises mais aprofundadas.
#
# - A variável explicativa "Generosity" aparenta não está correlacionada com o Ladder Score. Curioso o fato da percepção da generosidade não está correlacionada com felicidade. Dois sentimentos genuínos aparentemente não estão correlacionados

# %% [markdown]
# ## Elaborando heatmap para melhor vizualisar as estatísticas de correlação

# %%
plt.figure(figsize=(20,8))
sub = np.triu(tabela_2021.corr())
sns.heatmap(cor, annot=True, linewidths=0.2, cmap='coolwarm', square=True, mask=sub)

# %% [markdown]
# ## Matriz de correlação
#
# <p style='font-size: 18px; line-height: 2; margin: 10px 50px; text-align: justify;'>O <b>coeficiente de correlação</b> é uma medida de associação linear entre duas variáveis e situa-se entre <b>-1</b> e <b>+1</b> sendo que <b>-1</b> indica associação negativa perfeita e <b>+1</b> indica associação positiva perfeita.</p>

# %%
cor['Ladder score']

# %% [markdown]
# ### Observações
# <ul style='font-size: 18px; line-height: 2; text-align: justify;'>
#
# - Todas as variáveis, com exceção de Generosity, está bem correlacionada com o índice de felicidade
#
# - As 3 variáveis com maior correlação direta são: PIB per capita, Social support, Healthy life expectancy
#
# - Perceptions of corruption apresenta uma correlação inversa de -0,42, em uma escala que vai de '-1 a 1'
#
# Generosity, aparenta não ter correlação com o índice de felicidade

# %% [markdown]
# ## Laço para criar gráficos de dispersão entre as 6 váriaveis que compõe o Indice de Felicidade

# %%
for coluna in tabela_2021[['Logged GDP per capita', 'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']]:
    
    plot = sns.jointplot(x = coluna,
                         y = 'Ladder score',
                         data = tabela_2021,
                         hue = 'Regional indicator',
                         height= 10)
                         

    plot

# %% [markdown]
# ### Observações
# <ul style='font-size: 18px; line-height: 2; text-align: justify;'>
#
# - Nos gráficos de dispersão acima é possível observar como há clara correlação positiva entre o Ladder Score e  PIB per capita, Social support, Healthy life expectancy e Freedom to make life choices
#
# - Na variável Generosity percebe-se que não há correlação, é necessário fazer outros testes para se aferir melhor a relação desta variável explicativa com o Índice de felicidade.
#
# - A variável de Perceptions of corruption apresenta uma correlação inversa com o índice de felicidade. Assume uma tendência de quanto menor a percepção de corrupção, maior o índice de felicidade.

# %% [markdown]
# ## Como o Ladder score se comporta por região?

# %%
## Agrupando as regiões para conhecer as métricas estatísticas

tabela_regioes = tabela_2021.groupby('Regional indicator')
tabela_regioes

# %%
df_media = tabela_regioes.mean().sort_values('Ladder score')

# %%
df_media

# %%
fig = px.bar(df_media, x= 'Ladder score', y= df_media.index, orientation='h',
                 labels={'Ladder score':'Indice de felicidade'},
                 height=500, color_continuous_scale= 'deep')
fig.show()

# %% [markdown]
# ## Plotando um gráfico de barras de acordo com as 6 variáveis explicativas

# %%
import plotly.express as px

for coluna in tabela_2021[['Logged GDP per capita', 'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']]:


    fig = px.bar(df_media, x= 'Ladder score', y= df_media.index, orientation='h',
                 labels={'Ladder score':'Indice de felicidade'},
                 height=400, color = coluna, color_continuous_scale= 'deep')
    fig.show()

# %% [markdown]
# ## Plotando um gráfico de disperção entre o Ladder Score e as  6 variáveis explicativas

# %%
for coluna in tabela_2021[['Logged GDP per capita', 'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']]:

    fig1 = sns.relplot(
        data = tabela_2021,
        x= coluna, y="Ladder score",
        hue="Regional indicator")
    fig1=0

# %% [markdown]
# ### Observações
# <ul style='font-size: 18px; line-height: 2; text-align: justify;'>
#
# - Comentar aqui sobre os gráficos

# %% [markdown]
# # Analise dos 20 mais e menos felizes

# %%
## Selecionando os 20 mais felizes e menos felizes

ladder_score = tabela_2021.sort_values("Ladder score",ascending=False)

# %%
mais_felizes =ladder_score.head(20)
mais_felizes

# %%
menos_felizes =ladder_score.tail(20)
menos_felizes.sort_values("Ladder score",ascending=True)

# %%
mais_felizes.describe().round(2)

# %%
menos_felizes.describe().round(2)

# %%
tabela_2021.describe().round(2)

# %% [markdown]
# ## Distribuição do Ladder Score nas duas seleções

# %%
ax1 = sns.distplot(mais_felizes['Ladder score'], norm_hist=True)
ax1.figure.set_size_inches(14, 6)
ax1.set_title('Distribuição de Frequências - Ladder', fontsize=18,)
ax1.set_xlabel('Indice de felicidade', fontsize=14)
ax1=0

# %%
ax1 = sns.distplot(menos_felizes['Ladder score'], norm_hist=True)
ax1.figure.set_size_inches(14, 6)
ax1.set_title('Distribuição de Frequências - Ladder', fontsize=18,)
ax1.set_xlabel('Indice de felicidade', fontsize=14)


ax1=0

# %%
mais_felizes['Regional indicator'].value_counts(normalize=True*100)

# %%
menos_felizes['Regional indicator'].value_counts(normalize=True*100)

# %%
#Top 5 de cada Varivável explicativa

ladder_score = tabela_2021.sort_values("Ladder score",ascending=False)
GDP = tabela_2021.sort_values("Logged GDP per capita",ascending=False)
social = tabela_2021.sort_values("Social support",ascending=False)
Healthy = tabela_2021.sort_values("Healthy life expectancy",ascending=False)
Freedom = tabela_2021.sort_values('Freedom to make life choices',ascending=False)
Generosity = tabela_2021.sort_values('Generosity',ascending=False)

# %%
fig = px.bar(mais_felizes, y= 'Ladder score', x= 'Country name', orientation='v', color ='Country name',
                 labels={'Ladder score':'Indice de felicidade'},
                 height=600)
fig.show()

# %%
fig = px.bar(menos_felizes, y= 'Ladder score', x= 'Country name', orientation='v', color ='Country name',
                 labels={'Ladder score':'Indice de felicidade'},
                 height=600)
fig.show()

# %%
fig = px.box(mais_felizes, x='Ladder score', orientation= 'h',  title= 'Boxplor do Indice de felicidade')
fig.show()

# %%
fig = px.box(menos_felizes, x='Ladder score', orientation= 'h',  title= 'Boxplor do Indice de felicidade')
fig.show()

# %%
menos_felizes['Regional indicator'].value_counts()

# %% [markdown]
# ### Observações
# <ul style='font-size: 18px; line-height: 2; text-align: justify;'>
#
# - Dos 20 países menos felizes, 17 estão no continente africano
# - 2 estão na ásia e 1 na América Latina

# %%
mais_felizes['Regional indicator'].value_counts()

# %% [markdown]
# ### Observações
# <ul style='font-size: 18px; line-height: 2; text-align: justify;'>
#
# - Dos 20 mais felizes 18 estão no norte geográgico do planeta
# - 14 estão na Europa e 4 estão na América do Norte
# - 1 está na América Latina e 1 está na África

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gs
import seaborn as sns

color=["#f94144","#f3722c","#f8961e","#f9c74f","#90be6d","#43aa8b","#577590"]
sns.palplot(color)

# %%
fig=plt.figure(figsize=(15,8))
plt.title("Ladder score distribution by Regional indicator",family='Serif', weight='bold', size=20)
sns.kdeplot(tabela_2021['Ladder score'], fill=True, hue=tabela_2021['Regional indicator'], color=color, shade=True, linewidth=2, edgecolor='gray', multiple='layer')
plt.axvline(tabela_2021['Ladder score'].mean(), c='black',ls='--')
plt.text(x=tabela_2021['Ladder score'].mean(),y=-0.01,s='Population mean', size=15)
for s in ['left','right','top','bottom']:
    plt.gca().spines[s].set_visible(False)

# %%
regions = tabela_2021.groupby('Regional indicator').mean().sort_values('Ladder score', ascending=False).reset_index()
regions

# %%
fig=plt.figure(figsize=(15,8))
fig = sns.barplot(x = 'Ladder score', y = 'Regional indicator', data = regions, palette = 'deep')
fig=0

# %% [markdown]
# # <font color='blue' style='font-size: 30px;'>Estimando um modelo de regressão linear:</font>
# <hr style='border: 2px solid black;'>

# %% [markdown]
# # Regresão Linear
# <hr>
#
# <p style='font-size: 20px; line-height: 2; margin: 10px 50px; text-align: justify;'>A análise de regressão diz respeito ao estudo da dependência de uma variável (a variável <b>dependente</b>) em relação a uma ou mais variáveis, as variáveis explanatórias, visando estimar e/ou prever o valor médio da primeira em termos dos valores conhecidos ou fixados das segundas.</p>

# %% [markdown]
# ## importando Sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
y = tabela_2021['Ladder score']

# %%
X = tabela_2021[['Logged GDP per capita', 'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']]

# %% [markdown]
# ### Separando o Dataset de treino e de teste:

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.shape

# %%
X_test.shape

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# ### Instanciando a classe LinearRegression ( )

# %%
modelo = LinearRegression()

# %% [markdown]
# ### Utilizando o método *fit()* do objeto "modelo" para estimar nosso modelo linear utilizando os dados de treino (y_train e X_train)

# %%
modelo.fit(X_train, y_train)

# %% [markdown]
# ### Obtendo o coeficiente de determinação (R²) do modelo estimado com os dados de treino

# %%
print('R² = {}'.format(modelo.score(X_train, y_train).round(2)))

# %% [markdown]
# ### Observações
# <ul style='font-size: 18px; line-height: 2; text-align: justify;'>
#
#
#
# - O R² vai de 0 a 1, e é uma métrica para verificar quanto o modelo é explicado pelas variáveis
# - O R² do modelo mostra que 78% é explicavel pelas variáveis, entretanto é necessário outros testes para avaliar a significancia do modelo e das variáveis

# %% [markdown]
# ## Fazendo previsões

# %%
y_previsto = modelo.predict(X_test)

# %%
print('R² = %s' % metrics.r2_score(y_test, y_previsto).round(2))

# %%
entrada = X_test[0:1]
modelo.predict(entrada)[0]

# %%
entrada

# %% [markdown]
# ### Coeficientes do modelo

# %%
modelo.coef_
X.columns

# %%
index=['Intercepto', 'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']

# %%
pd.DataFrame(data= np.append(modelo.intercept_, modelo.coef_), index= index, columns=['Parametros'])

# %%
y_previsto_train = modelo.predict(X_train)

# %% [markdown]
# ### Calculando o resíduo

# %%
residuo = y_train - y_previsto_train
residuo

# %%
ax = sns.scatterplot(x=y_train, y= y_previsto_train)

# %%
ax = sns.scatterplot(x=y_previsto_train, y= residuo)

# %% [markdown]
# ## Analisando com stats model as métricas

# %%
import statsmodels.api as sm

# %% [markdown]
# ### Adicionando constante para rodar o modelo com statsmodel

# %%
X_train_com_constante = sm.add_constant(X_train)

# %%
modelo_statsmodels = sm.OLS(y_train, X_train_com_constante, hasconst = True).fit()

# %% [markdown]
# ### Sumário estatístico do Statsmodels

# %%
print(modelo_statsmodels.summary())

# %%
pd.DataFrame(data= np.append(modelo.intercept_, modelo.coef_), index= index, columns=['Parametros'])

# %% [markdown]
# ### Observações
# <ul style='font-size: 18px; line-height: 2; text-align: justify;'>
#
# -Comentar aqui o resultado

# %% [markdown]
# # <font color='blue' style='font-size: 30px;'> Os 20 mais felizes e os 20 menos felizes:</font>
# <hr style='border: 2px solid black;'>

# %%
ladder_score = tabela_2021.sort_values("Ladder score",ascending=False)

# %%
mais_felizes =ladder_score.head(20)
menos_felizes =ladder_score.tail(20)
menos_felizes.sort_values("Ladder score",ascending=True)

# %%
mais_felizes.describe().round(2)

# %%
menos_felizes.describe().round(2)

# %%
tabela_2021.describe().round(2)

# %% [markdown]
# ## Distribuição do Ladder Score nas duas seleções

# %%
ax1 = sns.distplot(mais_felizes['Ladder score'], norm_hist=True)
ax1.figure.set_size_inches(14, 6)
ax1.set_title('Distribuição de Frequências - Ladder', fontsize=18,)
ax1.set_xlabel('Indice de felicidade', fontsize=14)
ax1=0

# %%
ax1 = sns.distplot(menos_felizes['Ladder score'], norm_hist=True)
ax1.figure.set_size_inches(14, 6)
ax1.set_title('Distribuição de Frequências - Ladder', fontsize=18,)
ax1.set_xlabel('Indice de felicidade', fontsize=14)


ax1=0

# %% [markdown]
# ## Gráfico de barras do Ladder Score com a Percepção de corrupção destacado

# %%
fig = px.bar(mais_felizes, x='Country name', y='Ladder score', color ='Perceptions of corruption',
            title = 'Mais felizes')
fig.show()

# %%
fig = px.bar(menos_felizes, x='Country name', y='Ladder score', color ='Perceptions of corruption',
            title = 'Menos felizes')
fig.show()

# %% [markdown]
# ### Observações
# <ul style='font-size: 18px; line-height: 2; text-align: justify;'>
#
# - Os gráficos mostram que os 20 países menos felizes possuem um nível de Percepção de corrupçao bem alto
#
# - Por outro lado, nos países mais felizes a percepção de corrupção é bastante baixa
#
# - Os 20 países menos felizes tem um Ladder score menor do que a média mundial

# %% [markdown]
# ## Distribuição da percepção de corrupção

# %%
ax = sns.distplot(tabela_2021['Perceptions of corruption'], bins=30)
ax.figure.set_size_inches(12, 6)
ax.set_title('Distrubuição de Frequências percepcao de corrupcao', fontsize=20)

ax=0

# %% [markdown]
# ## Quais regiões estão presente nos 20 mais e menos felizes?

# %%
mais_felizes['Regional indicator'].value_counts()

# %%
menos_felizes['Regional indicator'].value_counts()

# %% [markdown]
# ### Observações
# <ul style='font-size: 18px; line-height: 2; text-align: justify;'>
#
# - 85% dos países mais felizes estão na Europa e na América do Norte.
#
# - A África é o continente mais presente nos 20 últimos.
#
# - Não há nenhum países europeu e da américa do norte entre os menos felizes

# %% [markdown]
# ## Serie temporal do WHR o que aconteceu com Portugal e Brasil?

# %% [markdown]
# ### Importando o Dataset

# %%
tabela = pd.read_csv('../input/world-happiness-report-2021/world-happiness-report.csv')
tabela

# %% [markdown]
# ### Verificando números nulos

# %%
tabela.isna().sum()

# %% [markdown]
# ### Agrupando por ano e tirando a média da felicidade por ano

# %%
tabela_por_ano = tabela.groupby('year').mean()
tabela_por_ano

# %% [markdown]
# ### Selecionando apenas Portugal na série histórica

# %%
tabela_portugal = tabela.set_index('Country name').loc['Portugal']
tabela_portugal = tabela_portugal.set_index('year')
tabela_portugal

# %% [markdown]
# ### Selecionando apenas o Brasil na série histórica

# %%
tabela_brasil = tabela.set_index('Country name').loc['Brazil']
tabela_brasil = tabela_brasil.set_index('year')
tabela_brasil

# %% [markdown]
# ## Juntando a tabela de felicidade do Brasil com a de Portugal

# %%
nova_tabela = tabela_brasil.join(tabela_portugal, lsuffix='_Brasil',
    rsuffix='_Portugal')
nova_tabela

# %% [markdown]
# ## Agrupando por ano e tirando a média da felicidade por ano

# %%
tabela_por_ano = tabela.groupby('year').mean()
tabela_por_ano_nova = tabela_por_ano[['Life Ladder','Perceptions of corruption','Social support']]
tabela_por_ano_nova

# %% [markdown]
# ## Construindo DataFrame com as variáveis de estudo de Portugal e Brasil e com a média do Mundo

# %%
nova_outra_tabela = tabela_por_ano_nova.join(nova_tabela, lsuffix='_Brasil',
    rsuffix='_Portugal' )

nova_outra_tabela

# %%
nova_outra_tabela.columns

# %%
colunas_selecionadas = ['Life Ladder','Life Ladder_Portugal','Life Ladder_Brasil',
'Perceptions of corruption', 'Perceptions of corruption_Portugal','Perceptions of corruption_Brasil',
'Social support','Social support_Portugal', 'Social support_Brasil']

# %%
felicidade = nova_outra_tabela.filter(items = colunas_selecionadas)
felicidade

# %%
felicidade.isna().sum()

# %% [markdown]
# ## Preenchendo dados faltantes com os números seguintes

# %%
felicidade.fillna(method='bfill')

# %%
fig = plt.figure(figsize=(20,10))
ax = felicidade[['Life Ladder', 'Life Ladder_Portugal', 'Life Ladder_Brasil']].fillna(method='bfill').plot()
plt.title("Serie histórica do Ladder Score: Portugal, Brasil e média mundial)", pad=10)
ax.set_ylabel("Life Ladder")
ax.set_xlabel("Anos da série histórica", labelpad=10)
plt.ylim(2, 10)
ax=0
plt.show()

# %% [markdown]
# ## Estatísticas de Felicidade

# %%
felicidade.describe().T

# %% [markdown]
# ### Observações
# <ul style='font-size: 18px; line-height: 2; text-align: justify;'>
#
# - Apesar de Portugal obter níveis maiores de IDH e bem estar social, o índice de felicidade em Portugal na série histórica
# sempre esteve abaixo dos níveis de felicidade no Brasil
#
# - O maior índice de feliciade em portugal, 6,09 em 2019, não é maior do que o menor índice de felicidade do Brasil na serie histórica estudada
#
# - Portugal apresenta ser um país onde seus moradores são bastante rigorosos nas suas percepções sobre felicidade, corrupção,
# suporte social.
#
# - Os brasileiros são mais otimistas e os portugueses são mais pessimistas? Uns tem o samba, outros o fado.
