# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import dates

from pylab import rcParams
import statsmodels.api as sm

import warnings
warnings.simplefilter(action='ignore', category=Warning)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ![](https://i.pinimg.com/originals/44/11/fc/4411fc37e9f1680cc4a86ebafe9e5bba.jpg)pinterest.com

# %% [markdown]
# #Install RemixAutoML via:
#
# devtools::install_github('AdrianAntico/RemixAutoML', upgrade = FALSE, dependencies = FALSE, force = TRUE)
#
# Oh No! It's a R package! No pip. No package. That's my AutoCarmaML. Carma of the copy cats
#
# The other CARMA stands for Calendar, Autoregressive, Moving Average.
#
# From RemixInstitute: Models: there are eight CARMA functions and each use a different algorithm for the model fitting. The models used to fit the time series data come from RemixAutoML and include:
#
# AutoCatBoostRegression()
#
# AutoXGBoostRegression()
#
# AutoLightGBMRegression()
#
# AutoH2oDRFRegression()
#
# AutoH2oGBMRegression()
#
# AutoH2oGLMRegression()
#
# AutoH2oGAMRegression()
#
# AutoH2oAutoMLRegression()
#
# https://github.com/AdrianAntico/RemixAutoML
#
# https://www.rdocumentation.org/packages/RemixAutoML/versions/0.5.0
#
# https://website.informer.com/remixinstitute.com

# %%
df = pd.read_csv('../input/aapl-stock-historical-data/AAPL.csv')
df.tail().style.set_properties(**{'background-color':'purple',
                                     'color': 'white'})

# %%
df.isnull().sum()

# %% [markdown]
# #Code by Varshini PJ https://www.kaggle.com/varshinipj/amazon-stock-trends?utm_medium=email&utm_source=gamma&utm_campaign=kernel-discovery-time-series-analysis

# %%
#Code by Varshini PJ https://www.kaggle.com/varshinipj/amazon-stock-trends?utm_medium=email&utm_source=gamma&utm_campaign=kernel-discovery-time-series-analysis


df['Volume'].plot(figsize=(10,6));

# %%
#Code by Varshini PJ https://www.kaggle.com/varshinipj/amazon-stock-trends?utm_medium=email&utm_source=gamma&utm_campaign=kernel-discovery-time-series-analysis


df.plot(subplots=True, figsize=(10,12));

# %% [markdown]
# #SHIFT:
#
#
# The shift function shifts the data before or after the specified amount of time. It will shift the data by one day by default. That means you will get the previous day's data. In financial data like this one, it is helpful to see previous day data and today's data side by side.
#
# #Code by Varshini PJ https://www.kaggle.com/varshinipj/amazon-stock-trends?utm_medium=email&utm_source=gamma&utm_campaign=kernel-discovery-time-series-analysis

# %%
#Code by Varshini PJ https://www.kaggle.com/varshinipj/amazon-stock-trends?utm_medium=email&utm_source=gamma&utm_campaign=kernel-discovery-time-series-analysis


df['Change'] = df.Close.div(df.Close.shift())
df['Change'].plot(figsize=(20, 8), fontsize = 16);

# %% [markdown]
# #The original code returned date (year) on x-axis.

# %% [markdown]
# #DIFFERENCING:
#
#
# Differencing takes the difference in values of a specified distance.It is a popular method to remove the trend in the data. The trend is not good for forecasting or modeling.
#
# We've used expanding window,an another way of transformation. It keeps adding the cumulative. For example, if you add an expanding function to the ‘High’ column first element remains the same. The second element becomes cumulative of the first and second element, the third element becomes cumulative of the first, second, and third element, and so on. You can use aggregate functions like mean, median, standard deviation, etc. on it too
#
# #Code by Varshini PJ https://www.kaggle.com/varshinipj/amazon-stock-trends?utm_medium=email&utm_source=gamma&utm_campaign=kernel-discovery-time-series-analysis

# %%
#Code by Varshini PJ https://www.kaggle.com/varshinipj/amazon-stock-trends?utm_medium=email&utm_source=gamma&utm_campaign=kernel-discovery-time-series-analysis

fig, ax = plt.subplots(figsize=(20, 8))
ax = df.High.plot(label='High')
ax = df.High.expanding().mean().plot(label='High expanding mean')
ax = df.High.expanding().std().plot(label='High expanding std')
ax.legend();

# %% [markdown]
# #Code by Ritik P. Nayak https://www.kaggle.com/ritikpnayak/vaccine?utm_medium=email&utm_source=gamma&utm_campaign=kernel-discovery-time-series-analysis

# %%
import matplotlib.pyplot as plt
from matplotlib import style

style.use('fivethirtyeight')

font = {'family': 'serif',
        'weight': 'bold',
        'size': 20}
plt.rc('font', **font)

from datetime import date
import matplotlib.dates as mdates
import datetime as dt

# %%
#Code by Ritik P. Nayak https://www.kaggle.com/ritikpnayak/vaccine?utm_medium=email&utm_source=gamma&utm_campaign=kernel-discovery-time-series-analysis

df[['Date', 'Volume']].set_index(['Date']).plot(figsize = (15, 8))
plt.axhline(10 ** 6, color = 'maroon', linestyle = ':')
plt.xticks(rotation = 90)
plt.show()

# %%
#Code by Ritik P. Nayak https://www.kaggle.com/ritikpnayak/vaccine?utm_medium=email&utm_source=gamma&utm_campaign=kernel-discovery-time-series-analysis


roll = df['Volume'].rolling(10, min_periods = 10).mean()
roll[9]

# %%
#Code by Ritik P. Nayak https://www.kaggle.com/ritikpnayak/vaccine?utm_medium=email&utm_source=gamma&utm_campaign=kernel-discovery-time-series-analysis


roll[9:].plot(figsize = (15, 8));

# %%
days = pd.to_datetime(df['Date'], dayfirst = True)
days

# %%
#Code by Ritik P. Nayak https://www.kaggle.com/ritikpnayak/vaccine?utm_medium=email&utm_source=gamma&utm_campaign=kernel-discovery-time-series-analysis


df2 = pd.concat([days, roll], 1)[9:].set_index(['Date'])
df2.plot(figsize = (15, 8), linestyle = '--')
plt.vlines(['2021-05-01 00:00:00', '2021-06-21 00:00:00'], ymin = 0.03, ymax = 120000)
#plt.axvline('2021-06-21 00:00:00')
plt.axvspan('2021-05-01 00:00:00', '2021-06-21 00:00:00', color = 'maroon', alpha = 0.3, ymin = 0.04, ymax = 110000)

plt.legend(["Aapl Historical", "Stock Historical data", "1980 till 2021"]);

# %% [markdown]
# #The legends above aren't correct, except date. Though I don't know what is suppose to be written.

# %%
df3 = df.iloc[:, 1:37] - df.iloc[:, 1:37].shift(1).fillna(0.0)

# %%
#Code by Ritik P. Nayak https://www.kaggle.com/ritikpnayak/vaccine?utm_medium=email&utm_source=gamma&utm_campaign=kernel-discovery-time-series-analysis


(pd.concat([days, df3], 1).set_index(['Date']) / 10 ** 2).plot(legend = False, figsize = (15, 8), color = '#d9d2d0')
plt.plot(days.values, df['Volume'].values / 10 ** 2, color = '#0b032b')
plt.title('Aapl Stock 1980-2021 data');

# %%
from datetime import date
import matplotlib.dates as mdates
import datetime as dt

# %%
#Code by Ritik P. Nayak https://www.kaggle.com/ritikpnayak/vaccine?utm_medium=email&utm_source=gamma&utm_campaign=kernel-discovery-time-series-analysis


df4 = df3.rolling(10, min_periods = 10).mean()
temp = pd.concat([days[9:], df4[9:]], 1).set_index(['Date'])

string = """Dire performance of 
        Aapl Stock data
        from 1980 till 2021 is portrayed 
        from its rolling mean"""

plt.figure(figsize = (15, 8))

plt.plot(days[9:].values, temp.values, color = '#d9d2d0')
plt.plot(days[9:].values, roll[9:].values, color = '#0b032b')

plt.annotate(string, xy = (mdates.date2num(dt.datetime(2021, 3, 1)), 7057.4),
                     xytext = (mdates.date2num(dt.datetime(2021, 1, 30)), 400000),
                     arrowprops = dict(arrowstyle = 'fancy',
                                       color = 'black'),
                     bbox = dict(boxstyle = 'round',
                                 color = 'gray',
                                 alpha = 0.5))

plt.show()

# %% [markdown]
# #Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

# %%
#Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

import matplotlib
import matplotlib.pyplot as plt
import statsmodels.tsa.api as tsa

# %matplotlib inline

matplotlib.style.use("Solarize_Light2")

    
def create_us_season(source_df, target_df, feature_name):
    """
    Winter: December - February (12. 1, 2)
    Spring: March - May (3. 4, 5)
    Summer: June - August [6, 7, 8]
    Fall: September - November (9, 10, 11)
    """
    month_to_season_map = {
        1: "winter",
        2: "winter",
        3: "spring",
        4: "spring",
        5: "spring",
        6: "summer",
        7: "summer",
        8: "summer",
        9: "fall",
        10: "fall",
        11: "fall",
        12: "winter",
    }
    target_df.loc[:, "us_season"] = source_df.loc[:, feature_name].dt.month.map(
        month_to_season_map
    )
    return target_df

# %%
#Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

def create_date_features(source_df, target_df, feature_name):
    """
    Create new features related to dates

    source_df : DataFrame consisting of the timestamp related feature
    target_df : DataFrame where new features will be added
    feature_name : Name of the feature of date type which needs to be decomposed.
    """
    target_df.loc[:, "year"] = source_df.loc[:, feature_name].dt.year.astype("uint16")
    target_df.loc[:, "month"] = source_df.loc[:, feature_name].dt.month.astype("uint8")
    target_df.loc[:, "quarter"] = source_df.loc[:, feature_name].dt.quarter.astype(
        "uint8"
    )
    target_df.loc[:, "weekofyear"] = (
        source_df.loc[:, feature_name].dt.isocalendar().week.astype("uint8")
    )
    target_df.loc[:, "hour"] = source_df.loc[:, feature_name].dt.hour.astype("uint8")

    target_df.loc[:, "day"] = source_df.loc[:, feature_name].dt.day.astype("uint8")
    target_df.loc[:, "day_name"] = source_df.loc[:, feature_name].dt.day_name()
    target_df.loc[:, "dayofweek"] = source_df.loc[:, feature_name].dt.dayofweek.astype(
        "uint8"
    )

    target_df.loc[:, "day_type"] = np.where(
        source_df.loc[:, feature_name].dt.dayofweek < 5, "week_day", "week_end"
    )
    target_df.loc[:, "dayofyear"] = source_df.loc[:, feature_name].dt.dayofyear.astype(
        "uint8"
    )
    target_df.loc[:, "is_month_start"] = source_df.loc[
        :, feature_name
    ].dt.is_month_start
    target_df.loc[:, "is_month_end"] = source_df.loc[:, feature_name].dt.is_month_end
    target_df.loc[:, "is_quarter_start"] = source_df.loc[
        :, feature_name
    ].dt.is_quarter_start
    target_df.loc[:, "is_quarter_end"] = source_df.loc[
        :, feature_name
    ].dt.is_quarter_end
    target_df.loc[:, "is_year_start"] = source_df.loc[:, feature_name].dt.is_year_start
    target_df.loc[:, "is_year_end"] = source_df.loc[:, feature_name].dt.is_year_end

    # This is of type object
    target_df.loc[:, "month_year"] = source_df.loc[:, feature_name].dt.to_period("M")

    return target_df

# %%
#Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

def plt_seasonal_decomposition(df, feature, freq, freq_type="daily", model="additive", figsize=(20, 10)):
    plt.rcParams["figure.figsize"] = figsize
    decomposition = tsa.seasonal_decompose(df[feature], model=model, period=freq)
    decomposition.plot()
    plt.title(f"{model} {freq_type} seasonal decomposition of {feature}")
    plt.show()

# %%
#Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

def plt_seasonality(df, feature, freq, freq_type="daily", model="additive", figsize=(20, 10)):
    plt.rcParams["figure.figsize"] = figsize
    decomposition = tsa.seasonal_decompose(df[feature], model=model, period=freq)
    decomposition.seasonal.plot(color="blue", linewidth=0.5)
    plt.title(f"{model} {freq_type} seasonality of {feature}")
    plt.show()

# %%
#Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

def plot_trend(df, feature, freq, freq_type="daily", model="additive", figsize=(20, 10)):
    plt.rcParams["figure.figsize"] = figsize
    decomposition = tsa.seasonal_decompose(df[feature], model=model, period=freq)
    decomposition.trend.plot(color="blue", linewidth=0.5)
    plt.title(f"{model} {freq_type} seasonality of {feature}")
    plt.show()

# %%
#Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

def plot_ts_line_groupby(df, ts_index_feature, groupby_feature, value_feature, title, xlabel, ylabel, figsize=(15, 8)):
    fig, ax = plt.subplots(figsize=figsize)
    for label, df in df.groupby(groupby_feature):
        df.set_index(ts_index_feature)[value_feature].plot(
            kind="line", alpha=0.3, ax=ax, color="blue", linewidth=0.5)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

# %%
#Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

def plot_multiple_seasonalities(df, feature_name, figsize=(20, 6)):
    period_names = ["daily", "weekly", "monthly", "quarterly"]
    periods = [24, 24*7, 24*30, 24*90]

    for name, period in zip(period_names, periods):
        plt_seasonality(df.set_index("Date")[0: period*3], feature=feature_name, freq=period, freq_type=name, figsize=(20, 6))


def plot_boxh_groupby(df, feature_name, by):
    """
    Box plot with groupby feature
    """
    df.boxplot(column=feature_name, by=by, vert=False, figsize=(10, 6), color="blue")
    plt.title(f"Distribution of {feature_name} by {by}")
    plt.show()

# %%
#Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

DATA_DIR = "/kaggle/input/aapl-stock-historical-data/"
train_df = pd.read_csv(f"{DATA_DIR}/AAPL.csv", parse_dates=["Date"])
test_df = pd.read_csv(f"{DATA_DIR}/AAPL.csv", parse_dates=["Date"])

train_df = train_df.sort_values(by="Date")

test_df = test_df.sort_values(by="Date")

train_df = create_date_features(train_df, train_df, "Date")
train_df = create_date_features(train_df, train_df, "Date")
train_df = create_us_season(train_df, train_df, "Date")

# %% [markdown]
# #Understanding Seasonality without Statistics

# %%
#Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

plot_ts_line_groupby(
    train_df, 
    ts_index_feature="month",
    groupby_feature="year",
    value_feature="Volume",
    title="Volume vs month of the year",
    xlabel="Months",
    ylabel="Volume"
)

# %%
#Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

plot_ts_line_groupby(
    train_df, 
    ts_index_feature="day",
    groupby_feature="month",
    value_feature="High",
    title="High Stock vs day of the month",
    xlabel="Day of the month",
    ylabel="High Stock"
)

# %%
#Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

plot_ts_line_groupby(
    train_df, 
    ts_index_feature="year",
    groupby_feature="month",
    value_feature="Close",
    title="Stocks Close vs day of the month",
    xlabel="Year",
    ylabel="Stocks Close"
)

# %%
#Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

plot_ts_line_groupby(
    train_df, 
    ts_index_feature="year",
    groupby_feature="month",
    value_feature="Volume",
    title="Volume of Stocks vs day of the month",
    xlabel="Year",
    ylabel="Volume of Stocks"
)

# %% [markdown]
# #Understanding Seasonality with Statistical Decomposition
#
#
# To understand seasonality using statistical decomposition, Pick up one the variables.
#
# Following is the seasonal decomposition plot where Volume is broken down into trend, seasonality and residuals.
#
# #Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

# %%
#Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

plt_seasonal_decomposition(train_df.set_index("Date"), feature="Volume", freq=24, freq_type="daily", figsize=(15, 6), model="additive")

# %%
#Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

plt_seasonality(train_df.set_index("Date"), feature="Close", freq=24, freq_type="daily", figsize=(20, 6), model="additive")

# %% [markdown]
# The plot below clearly shows a repetitive pattern indicating daily seasonality. However, the pattern is not clear enough. Let's zoom in. Pick up only 4 days data to understand how data repeats itself.

# %%
#Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

plt_seasonality(train_df.set_index("Date")[0:24*4], feature="Volume", freq=24, freq_type="daily", figsize=(20, 6), model="additive")

# %% [markdown]
# Above code frequency type is daily, though x-axis show year 1981 (jan-may)months????

# %% [markdown]
# #Check if there is weekly (year??) seasonality in Volume

# %%
#Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

plt_seasonality(train_df.set_index("Date"), feature="Volume", freq=24*7, freq_type="weekly", figsize=(20, 6), model="additive")

# %% [markdown]
# #The plot below clearly shows a repetitive pattern indicating weekly seasonality. To understand it better: Pick up only 2 weeks (I think it's months x-axis) of data.
#
# The code frequency type is weekly, though x-axis show years????

# %%
#Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

plt_seasonality(train_df.set_index("Date")[0:24*7*2], feature="Volume", freq=24*7, freq_type="weekly", figsize=(20, 6), model="additive")

# %% [markdown]
# #Check if there is monthly seasonality in Volume (years in x-axis??)
#
# The code frequency type is weekly, though x-axis show years????

# %%
#Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

plt_seasonality(train_df.set_index("Date"), feature="Volume", freq=24*30, freq_type="monthly", figsize=(20, 6), model="additive")

# %% [markdown]
# #The plot below clearly shows a repetitive pattern indicating monthly seasonality. Pick up only 2 months (below is year?) of data.
#
# The code frequency type is monthly, though x-axis show years????

# %%
#Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

plt_seasonality(train_df.set_index("Date")[0:24*30*3], feature="Volume", freq=24*30, freq_type="monthly", figsize=(20, 6), model="additive")

# %%
#Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

plt_seasonality(train_df.set_index("Date"), feature="Volume", freq=24*90, freq_type="quarterly", figsize=(20, 6), model="additive")

# %% [markdown]
# #Seasonality for Volume

# %%
#Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

plot_multiple_seasonalities(train_df, feature_name="Volume")

# %%
#Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

plot_multiple_seasonalities(train_df, feature_name="Open")

# %%
#Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

plot_multiple_seasonalities(train_df, feature_name="High")

# %% [markdown]
# #Variation of Volume

# %%
#Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

periods = ["day_name", "day_type", "weekofyear", "month", "quarter", "us_season"]
for period in periods:
    plot_boxh_groupby(df=train_df, feature_name="Volume", by=period)

# %% [markdown]
# #Variation of Close (stocks)

# %%
#Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

periods = ["day_name", "day_type", "weekofyear", "month", "quarter", "us_season"]

for period in periods:
    plot_boxh_groupby(df=train_df, feature_name="Close", by=period)

# %% [markdown]
# #Variation of Low (stocks).

# %%
#Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv

periods = ["day_name", "day_type", "weekofyear", "month", "quarter", "us_season"]

for period in periods:
    plot_boxh_groupby(df=train_df, feature_name="Low", by=period)

# %% [markdown]
# #Time has changed. Probably, some inconsistency that I made in the code.
#
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQI4D81Nd6Dtyz09e2gbPTIZgkmBhKlvxt93A&usqp=CAU)soundcloud.com

# %% [markdown]
# #Thanks to Varshini (varshinipj), Ritik (ritikpnayak) and Arnab (arnabbiswas1).
#
#
# Code by Varshini PJ https://www.kaggle.com/varshinipj/amazon-stock-trends?utm_medium=email&utm_source=gamma&utm_campaign=kernel-discovery-time-series-analysis
#
# Code by Ritik P. Nayak https://www.kaggle.com/ritikpnayak/vaccine?utm_medium=email&utm_source=gamma&utm_campaign=kernel-discovery-time-series-analysis
#
#
# Code by Arnab https://www.kaggle.com/arnabbiswas1/visualizing-seasonality-with-w-o-statistics/data?scriptVersionId=68298463&select=train.csv
