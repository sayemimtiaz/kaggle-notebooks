# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
pip install bar-chart-race

# %%
import bar_chart_race as bcr

# %%
population = pd.read_csv("/kaggle/input/worldbank-data-on-gdp-population-and-military/API_SP.POP.TOTL_DS2_en_csv_v2_511378.csv")

# %%
population.head()

# %%
population.shape

# %%
population['Country Name'].value_counts()

# %%
population.info()

# %%
population_trans = population.copy()

# %%
population_trans.isnull().sum()

# %%
population_trans.select_dtypes(['object']).columns

# %%
drop_col=['Country Name','Country Code', 'Indicator Name', 'Indicator Code','2019','Unnamed: 64']

# %%
population_trans.drop(drop_col,axis=1,inplace=True)

# %%
population_trans=population_trans.T

# %%
population_trans.shape

# %%
population_trans.head()

# %%
population_trans.columns = population['Country Name']

# %%
population_trans.tail()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
'IDA & IBRD total' in population_trans.columns

# %%
# ?bcr.bar_chart_race

# %%
bcr.bar_chart_race(population_trans,n_bars=10,steps_per_period=50)
