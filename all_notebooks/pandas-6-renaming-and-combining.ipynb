# %% [markdown]
# # 介绍
#
# 运行以下单元格以加载数据和一些实用程序函数。

# %%
import pandas as pd

reviews = pd.read_csv("../input/wine-reviews/winemag-data-130k-v2.csv", index_col=0)

from learntools.core import binder; binder.bind(globals())
from learntools.pandas.renaming_and_combining import *
print("Setup complete.")

# %% [markdown]
# # Exercises
#
# 通过运行下面的单元格查看数据的前几行:

# %%
reviews.head()

# %% [markdown]
# ## 1.
# 对于数据集中的locale列，“region_1”和“region_2”是相当没有信息的名称。创建“reviews”的副本，将这些列分别重命名为“region”和“locale”。

# %%
# Your code here
renamed = ____

# Check your answer
q1.check()

# %%
#q1.hint()
#q1.solution()

# %% [markdown]
# ## 2.
# 将数据集中的索引名称设置为“wines”。

# %%
reindexed = ____

# Check your answer
q2.check()

# %%
#q2.hint()
#q2.solution()

# %% [markdown]
# ## 3.
# (https://www.kaggle.com/residentmario/things-onreddit/data)数据集包括reddit.com上一些顶级论坛的产品链接。运行下面的单元格来加载*/r/gaming* subreddit上提到的产品的数据列表和*r//movies* subreddit上提到的产品的另一个数据列表。

# %%
gaming_products = pd.read_csv("../input/things-on-reddit/top-things/top-things/reddits/g/gaming.csv")
gaming_products['subreddit'] = "r/gaming"
movie_products = pd.read_csv("../input/things-on-reddit/top-things/top-things/reddits/m/movies.csv")
movie_products['subreddit'] = "r/movies"

# %% [markdown]
# 创建一个在reddit上提到的产品的“数据列表”。

# %%
combined_products = ____

# Check your answer
q3.check()

# %%
#q3.hint()
#q3.solution()

# %% [markdown]
# ## 4.
# 关于Kaggle的[power举数据库](https://www.kaggle.com/open powerlifting/powerlifting- Database)数据集包括一个用于举重比赛的CSV表和一个单独的用于举重比赛的CSV表。运行下面的单元格将这些数据集加载到dataframes中:

# %%
powerlifting_meets = pd.read_csv("../input/powerlifting-database/meets.csv")
powerlifting_competitors = pd.read_csv("../input/powerlifting-database/openpowerlifting.csv")

# %% [markdown]
# 两个表都包含了一个“MeetID”的引用，一个唯一的键为每一场比赛包括在数据库中。使用此方法生成一个数据集，并将这两个表合并为一个表。

# %%
powerlifting_combined = ____

# Check your answer
q4.check()

# %%
#q4.hint()
#q4.solution()

# %% [markdown]
# # Congratulations!
#
# 你已经完成了熊猫微课程。许多数据科学家认为，效率是他们拥有的最有用和最实用的技能，因为它让你在任何项目中快速进展。
#
# 如果您想将您的新技能应用到地理空间数据的检查中，我们鼓励您查看我们的**[地理空间分析](https://www.kaggle.com/learn/geospatial-analysis)**微课程。
#
# 您也可以通过参加一个**[Kaggle竞赛](https://www.kaggle.com/datasets)**来利用您的Pandas技能，或者通过使用**[Kaggle Datasets](https://www.kaggle.com/datasets)**来回答您感兴趣的问题。

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [Learn Discussion forum](https://www.kaggle.com/learn-forum/161299) to chat with other Learners.*
