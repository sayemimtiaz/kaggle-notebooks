# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv("../input/chocolate-bar-2020/chocolate.csv")
df.drop('Unnamed: 0',axis = 1)
df.head()

# %%
dfn = df.drop(['ref', 'Unnamed: 0','company'], axis = 1)

# %%
dfn.head()

# %%
dfn.to_csv()

# %%
from pandas_profiling import ProfileReport
pr = ProfileReport(dfn)

pr.to_file(output_file="pandas_profiling1.html") 
pr

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(dfn, test_size=0.3)

# %%
# !pip install sweetviz
import sweetviz as sv
sweetviz_report = sv.analyze([dfn,"data"],target_feat='rating')
sweetviz_report.show_html('viz.html')
# you can see the report in data section (output section) download it and view it

# %%
df1 = sv.compare(train, test)
df1.show_html('Compare.html')

# %%
#AutoViz can be implemented in 4 simple steps:

# !pip install autoviz
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
dft = AV.AutoViz(filename = "", sep= ',' , depVar='rating', dfte= dfn, header=0, verbose=2, lowess=False, chart_format="svg", max_rows_analyzed=2500, max_cols_analyzed=5)

dft.to_file(output_file="autoviz_profiling.html")

# %%
# !pip install pandas_ui


from pandas_ui import *

pdf =pandas_ui("../input/chocolate-bar-2020/chocolate.csv")

pdf.to_file(output_file="pandas_ui1.html") 



get_df() # to get the dataframe

#get_meltdf() or get_pivotdf() # to get melt or pivot dataframes if you have created any.

# %%
a = get_df()
a
a.shape

# %%
sns.pairplot(df)

# %%
df.isnull().sum()

# %%
df.shape

# %%
df.info()

# %%
sns.countplot(df['company'])

# %%
sns.countplot(df['company_location'])

# %%
sns.countplot(df['review_date'])

# %%
sns.countplot(df['country_of_bean_origin'])

# %%
sns.countplot(df['specific_bean_origin_or_bar_name'])

# %%
sns.countplot(df['cocoa_percent'])

# %%
sns.countplot(df['rating'])

# %%
sns.countplot(df['counts_of_ingredients'])

# %%
sns.countplot(df['beans'])

# %%
sns.countplot(df['cocoa_butter'])

# %%
sns.countplot(df['vanilla'])

# %%
sns.countplot(df['lecithin'])

# %%
sns.countplot(df['salt'])

# %%
sns.countplot(df['sugar'])

# %%
sns.countplot(df['sweetener_without_sugar'])

# %%
sns.countplot(df['first_taste'])

# %%
sns.countplot(df['second_taste'])

# %%
sns.countplot(df['third_taste'])

# %%
sns.countplot(df['fourth_taste'])

# %%
sns.distplot(df['rating'])
plt.show()

# %%
rating_gen = df.groupby(["counts_of_ingredients"])[["rating"]].mean().reset_index()
rating_gen

# %%
import plotly.express as px
fig = px.bar(rating_gen,x='counts_of_ingredients',y='rating',color='counts_of_ingredients',template='ggplot2')
fig.show()

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(),annot=True,cmap="YlGnBu",linewidth=0.3)
plt.show()

# %%
grouped = df.groupby(["counts_of_ingredients",'salt'])[["rating"]].mean().reset_index().sort_values(by='rating',ascending=True)
grouped
px.bar(grouped,x='counts_of_ingredients',y='salt',color='rating')

# %%
grouped_sugar = df.groupby(["counts_of_ingredients",'sugar'])[["rating"]].mean().reset_index().sort_values(by='rating',ascending=True)
grouped_sugar
px.bar(grouped_sugar,x='counts_of_ingredients',y='sugar',color='rating')

# %%
grouped_sweetner = df.groupby(["counts_of_ingredients",'sweetener_without_sugar'])[["rating"]].mean().reset_index().sort_values(by='rating',ascending=True)
grouped_sweetner
px.bar(grouped_sweetner,x='counts_of_ingredients',y='sweetener_without_sugar',color='rating')

# %%
grouped = df.groupby(["gender",'specialisation'])[["salary"]].mean().reset_index().sort_values(by='salary',ascending=True)
px.bar(grouped,x='gender',y='salary',color='specialisation',barmode='group')

# %%
px.histogram(df,x='counts_of_ingredients',y='salt',color='rating')

# %%
px.density_heatmap(df,x='salt',y='rating',marginal_x='box',marginal_y='histogram')

# %%
px.density_heatmap(df,x='counts_of_ingredients',y='rating',facet_row="salt", facet_col="sugar")

# %%
df.head(2)

# %%
px.histogram(df,"sugar",'salt',color='rating',marginal='violin')

# %%
px.histogram(df,"sugar",'salt',color='rating',marginal='box')

# %%
sns.relplot(data=df,x='sugar',y='rating',hue='salt',palette='gnuplot')

# %%
df.head(2)

# %%
group = df.groupby(['sugar'])[['rating']].mean().reset_index()
fig = px.pie(group,values='rating',names='rating')
fig.update_traces(rotation=90, pull=0.02, textinfo="percent+label")
fig.show()

# %%
df.head(2)

# %%
sns.catplot(x='sugar',y='rating',data=df)

# %%
sns.catplot(x='salt',y='rating',data=df)

# %%
sns.violinplot(x='cocoa_butter',y='rating',data=df)

# %%
sns.violinplot(x='vanilla',y='rating',data=df)

# %%
sns.violinplot(x='country_of_bean_origin',y='rating',data=df)

# %%
sns.catplot(x='counts_of_ingredients',y='rating',data=df)

# %%
sns.stripplot(x='salt',y='rating',data=df)
sns.violinplot(x='sugar',y='rating',data=df)

# %%
sns.boxplot(x='salt',y='rating',data=df)

# %%
sns.boxplot(x='sugar',y='rating',data=df)

# %%
sns.boxplot(x='counts_of_ingredients',y='rating',data=df)

# %%
sns.boxplot(x='vanilla',y='rating',data=df)

# %%
sns.boxplot(x='cocoa_percent',y='rating',data=df)

# %%
sns.boxplot(x='country_of_bean_origin',y='rating',data=df)

# %%
sns.stripplot(x='counts_of_ingredients',y='rating',data=df)
sns.boxplot(x='country_of_bean_origin',y='rating',data=df)

# %%
sns.swarmplot(x='sugar',y='rating',data=df)

# %%
sns.clustermap(df.corr(),linewidth=0.3,cmap='summer',annot=True)

# %%
cor = df.loc[:,['sugar','cocoa_percent','rating']]
sns.clustermap(cor.corr(),annot=True,linewidth=0.6)

# %%
plt.figure(figsize=(10,6))
import plotly.express as px
ms = df.sort_values(by=['rating'],ascending=False)
px.funnel(ms,'sugar','cocoa_percent')

# %%
ms = df.sort_values(by=['rating'],ascending=False)
px.funnel(ms,'salt','sugar')

# %%
ms = df.sort_values(by=['rating'],ascending=False)
px.funnel(ms,'rating','counts_of_ingredients','sugar')

# %%
# plt.figure(figsize=(10,6))
# sns.set_style("darkgrid")
# sns.jointplot(x=df["counts_of_ingredients"], y=df["rating"], kind='scatter')

# plt.figure(figsize=(10,6))
# sns.set_style("darkgrid")
# sns.jointplot(x=df["counts_of_ingredients"], y=df["rating"], kind='resid')

plt.figure(figsize=(10,6))
sns.set_style("darkgrid")
sns.jointplot(x=df["counts_of_ingredients"], y=df["rating"], kind='hex',color='g')

# plt.figure(figsize=(10,6))
# sns.set_style("darkgrid")
# sns.jointplot(x=df["counts_of_ingredients"], y=df["rating"], kind='kde')

# %%
plt.figure(figsize=(16,6))
sns.violinplot(x="counts_of_ingredients", y="sugar", hue="rating",data=df)
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.violinplot(x="counts_of_ingredients", y="vanilla", hue="rating",data=df)
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.boxenplot(data=df,x='counts_of_ingredients',y='vanilla',hue='rating')
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.boxenplot(data=df,x='cocoa_percent',y='vanilla',hue='rating')
plt.show()

# %%
 px.box(df,x="counts_of_ingredients", y="rating",color = "sugar")

# %%
 px.box(df,x="counts_of_ingredients", y="sugar",color = "rating")

# %%
 px.box(df,x="vanilla", y="rating",color = "sugar",notched=True)

# %%
# !pip install bubbly
# !pip install chart_studio
from bubbly.bubbly import bubbleplot
from plotly.offline import iplot
import chart_studio.plotly as py

# %%
iplot(bubbleplot(df,x_column='counts_of_ingredients',y_column='cocoa_percent',bubble_column='rating'))

# %%
plt.figure(figsize=(20,7))
sns.lmplot(data=df,x='cocoa_percent',y='rating')
plt.show()

# %%
xyz = df
xyz.dropna(inplace=True)

# %%
fig = bubbleplot(xyz,x_column='cocoa_percent',y_column='rating',bubble_column='vanilla',size_column='rating', color_column='sugar',x_logscale=True, scale_bubble=iplot(fig))

# %%
fig = bubbleplot(xyz,x_column='ssc_p',y_column='salary',bubble_column='ssc_b',size_column='salary', color_column='degree_t',x_logscale=True, scale_bubble=2)
iplot(fig)

# %%
fig = px.scatter_ternary(df, a="sugar", b="cocoa_percent",c="salt",color = "rating")
fig.show()

# %%
plt.figure(figsize=(10,7))
sns.residplot(data=df,x='cocoa_percent',y='rating')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.residplot(data=df,x='rating',y='cocoa_percent')
plt.show()

# %%
df.plot.area(y=['sugar','rating','vanilla'],alpha=0.6,figsize=(20, 6))

# %%
df.plot.area(y=['sugar','salt','cocoa_percent'],alpha=0.6,figsize=(20, 6))

# %%
px.scatter(df, x="cocoa_percent", y="sugar", color="rating")

# %%
px.scatter(df, x="rating", y="cocoa_percent", color="sugar")

# %%
# !pip install jovian --upgrade

# %%
import jovian

# %%
jovian.commit(project='EDA 2020')
