# %% [markdown]
# ![gfn](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS57TC8XwqcivUB3oBXmFzm9WgoT9F3PKf01Q&usqp=CAU)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df=pd.read_csv('../input/german-credit-data-with-risk/german_credit_data.csv')
df.head(10)

# %%
# just how much data did we lose?
print("Row in original dataset: %d \n" % df.shape[0])
print("Columns in original dataset: %d" % df.shape[1])

# %% [markdown]
# # •Missing values

# %%
#get the number of missing data points per column
missing_values_count = df.isnull().sum()
missing_values_count

# %%
df.dropna( axis=1, inplace=False)

# %%
df.columns

# %%
df.describe()

# %%
df.drop(['Sex','Housing','Purpose','Risk','Saving accounts','Checking account'],
          axis=1,inplace=True)
df

# %%
fig, ax = plt.subplots(1,2)
sns.distplot(df, ax=ax[0])
ax[0].set_title("Original Data")
sns.distplot(df, ax=ax[1])
ax[1].set_title("Scaled data")

# %% [markdown]
# # Visualization Data

# %%
df.plot.line(title='df Dataset')

# %%
df['Job'].plot.hist()

# %%
df['Age'].plot.hist()

# %%
df['Duration'].plot.hist()

# %%
sns.countplot(df['Duration'])

# %%
sns.countplot(df['Age'])

# %%
sns.pairplot(df)

# %%
sns.pairplot(data=df)
plt.show()

# %%
ax = sns.displot(df, x='Age', hue='Duration', kind='kde', fill=True, common_norm=False)
ax.set(title='Age Density Plot per Duration')

# %%
import plotly.express as px

# %%
fig = px.scatter_3d(df.iloc[:500], x='Age', y='Job', z='Duration',
                    color='Age')
fig.show()

# %%
plt.figure(figsize=(7,4)) 
sns.heatmap(df.corr(),annot=True,cmap='cubehelix_r') #draws  heatmap with input as the correlation matrix calculted by(iris.corr())
plt.show()

# %%
fig = px.scatter(df, y="Age", x="Duration")
fig.show()

# %%
sns.distplot(df['Age'], color = 'r', label = 'target distribution')

# %%
sns.distplot(df['Age'], color = 'y', label = 'time distribution')

# %%
sns.distplot(df['Duration'], color = 'y', label = 'time distribution')

# %%
import matplotlib as mpl
# %matplotlib inline

df.hist(figsize=(18,10))
plt.show()

# %%
plt.hist(df["Age"], bins = 30)

# %%
plt.hist(df["Duration"], bins = 30)

# %%
plt.hist(df['Age'], color = 'm')

# %%
plt.hist(df['Duration'], color = 'b')

# %% [markdown]
# # K-Means Algorithm

# %%
from sklearn.cluster import KMeans
K_clusters = range(1,8)
kmeans = [KMeans(n_clusters=i) for i in K_clusters]
Y_axis = df[['Age']]
X_axis = df[['Job']]
score = [kmeans[i].fit(Y_axis).score(Y_axis) for i in range(len(kmeans))]
plt.plot(K_clusters, score)
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.show()
