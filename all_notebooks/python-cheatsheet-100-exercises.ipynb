# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <a id="top"></a>
#
# <div class="list-group" id="list-tab" role="tablist">
#
# <font color="teal" size=+1><b>Content List</b></font>
#
# * [01. Multiple arguments](#01)
# * [02. Article Reader](#02)
# * [03. Add Padding Around String](#03)
# * [04. Class 2 JSON](#04)
# * [05. Collections Counter](#05)
# * [06. Compress Image](#06)
# * [07. Compress Image CV2](#07)
# * [08. Copy List](#08)
# * [09. Current Directory](#09)
# * [10. DNS Lookup](#10)
# * [11. Date Util](#11)
# * [12. Date Util 2](#12)
# * [13. Default Dict](#13)
# * [14. Enumerate](#14)
# * [15. Enumerate with index](#15)
# * [16. Enumerate List](#16)
# * [17. Fibonacci](#17)
# * [18. Fibonacci in Generator](#18)
# * [19. Fibonacci Lambda](#19)
# * [20. Find Domain](#20)
# * [21. Find Domain without prefix](#21)
# * [22. Find Python/Conda Env Location](#22)
# * [23. Function With Return Type](#23)
# * [24. Geo Location 1](#24)
# * [25. Geo Location by Geocoder](#25)
# * [26. Get System Attribute](#26)
# * [27. Get Default Encoding](#27)
# * [28. TBW](#28)
# * [29. IP Whois Simple](#29)
# * [30. IP To Long](#30)
# * [31. JSON to XML](#31)
# * [32. Lambda Custom](#32)
# * [33. Lambda Function: Odd](#33)
# * [34. Square calculation by Lambda](#34)
# * [35. Linear Search](#35)
# * [36. List Operations](#36)
# * [37. Loop a Dictioary](#37)
# * [38. Class with Magicattr](#38)
# * [39. Modify String in Place](#39)
# * [40. More Itertools](#40)
# * [41. Named Arguments in Format](#41)
# * [42. Python Path](#42)
# * [43. Quick Sorting](#43)
# * [44. Random Binary](#44)
# * [45. Random Timestamp](#45)
# * [46. Range with Intervals](#46)
# * [47. Read GitHub CSV](#47)
# * [48. Read GitLab CSV](#48)
# * [49. Read JSON Online](#49)
# * [50. Read Online CSV](#50)
# * [51. Read Online CSV with Unicode Escape](#51)
# * [52. Reduce](#52)
# * [53. Reduce Advanced](#53)
# * [54. Sum with Reducers](#54)
# * [55. Remove Item from list](#55)
# * [56. Remove Item on Loop](#56)
# * [57. Remove Item with filterfalse](#57)
# * [58. Remove Item with Short form](#58)
# * [59. Remove th From Date](#59)
# * [60. Sort Dictionary By Value](#60)
# * [61. Dictionary sort with collections](#61)
# * [62. Sort Map By Key](#62)
# * [63. Sort Map by Value](#63)
# * [64. Split with Multiple](#64)
# * [65. Static on the fly](#65)
# * [66. Statistics Simple](#66)
# * [67. String Startswith](#67)
# * [68. Sys Version](#68)
# * [69. Text Diff](#69)
# * [70. Text Similarity](#70)
# * [71. Timeit Simple](#71)
# * [72. Timeit Simple 2](#72)
# * [73. Try Catch with Custom Error](#73)
# * [74. Try Catch with Raise Error](#74)
# * [75. Letter Match](#75)
# * [76. Regex Simple Match](#76)
# * [77. Regex and Index](#77)
# * [78. Compile Expressions](#78)
# * [79. Regex - Find Multiple Whitespace](#79)
# * [80. Regex - Find Two Digits with Spaces](#80)
# * [81. Regex - Get Full Matches](#81)
# * [82. Regex - Get Specific Contents](#82)
# * [83. Regex - Ontario Postal Code](#83)
# * [84. Regex - Remove Numbers](#84)
# * [85. Regex - Remove Numbers 2](#85)
# * [86. Regex - Remove Symbols](#86)
# * [87. Regex - Search](#87)
# * [88. Class Basics](#88)
# * [89. Sort by Attrgetter](#89)
# * [90. Fuzzy String Ratio](#90)
# * [91. List Op - sublist from to](#91)
# * [92. List Op - Get first 4](#92)
# * [93. List Op - from index to last](#93)
# * [94. List Op - Get all as subset](#94)
# * [95. List Op - Get last item](#95)
# * [96. List Op - Get last second item](#96)
# * [97. List Op - Get last 2 items](#97)
# * [98. List Op - Get every items except last 2 items](#98)
# * [99. List Op - Get all item reversed](#99)
# * [100. List Op - Get first 2 items reversed](#100)
# * [101. List Op - Get first 3 items reversed](#101)
# * [102. List Op - Get all items reversed and ignore the last item](#102)
# * [103. List Op - Remove last 2 item, reverse the rest](#103)
# * [104. List Op - Get last item reversed](#104)
# * [105. List Op - Everything except the last 3 items, reversed](#105)

# %% [markdown]
# **Note:**
#
# * This is not a production ready code.
# * This is only for educaiton purposes and no performance involved with it.
# * Some snippets are collected from various forums.

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="01"></a>
#         <font><b>Task 01:</b></font>
#         <br><br>
#         Multiple arguments
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 01. Multiple arguments

def print_everything(*args):
    for index, item in enumerate(args):
        print(f'{index}. {item}')
        
print_everything('Toronto', 'Montreal', 'New York', 'Waterloo')

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="02"></a>
#         <font><b>Task 02:</b></font>
#         <br><br>
#         Article Reader
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 02. Article Reader

import requests
from bs4 import BeautifulSoup

# Collect and parse first page
page = requests.get('https://www.wired.com/story/inside-twitter-hack-election-plan/')
soup = BeautifulSoup(page.text, 'html.parser') 

content = soup.select('div.article__body')[0]

print(content.get_text()[:100])

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="03"></a>
#         <font><b>Task 03:</b></font>
#         <br><br>
#         Add Padding Around String
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 03. Add Padding Around String

text = 'Hey Kaggle'

# Add Spaces Of Padding To The Left
print('\n', format(text, '>40'))

# Add Spaces Of Padding To The Right
print('\n', format(text, '<40'))

# Add Spaces Of Padding On Each Side
print('\n', format(text, '^40'))

# Add * Of Padding On Each Side
print('\n', format(text, '*^40'))

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="04"></a>
#         <font><b>Task 04:</b></font>
#         <br><br>
#         Class 2 JSON
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 04. Class 2 JSON

import json

class City:
    def toJSON(self):
        return json.dumps(self, default = lambda o: o.__dict__, sort_keys = True, indent = 4)
    
me = City()
me.name = "Toronto"
me.id = 102

print(me.toJSON())

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="05"></a>
#         <font><b>Task 05:</b></font>
#         <br><br>
#         Collections Counter
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 05. Collections Counter

from collections import Counter

cnt = Counter()

for word in ['Toronto', 'Montreal', 'Montreal', 'Waterloo', 'Toronto', 'Toronto']:
    cnt[word] += 1
    
print(cnt)

print(type(cnt))

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="06"></a>
#         <font><b>Task 06:</b></font>
#         <br><br>
#         Compress Image
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 06. Compress Image

from PIL import Image

# Open the image
im = Image.open("/kaggle/input/numpy-cheatsheet/cn_tower.jpg")

# im.save("/kaggle/input/numpy-cheatsheet/cn_tower_1.jpg", format = "JPEG", quality = 70) # This will save

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="07"></a>
#         <font><b>Task 07:</b></font>
#         <br><br>
#         Compress Image CV2
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 07. Compress Image CV2

from PIL import Image
import cv2

# Open the image
img = cv2.imread('/kaggle/input/numpy-cheatsheet/cn_tower.jpg')

# save image with lower quality—smaller file size
# cv2.imwrite('/kaggle/input/numpy-cheatsheet/cn_tower_1.jpg', img, [cv2.IMWRITE_JPEG_QUALITY, 0])

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="08"></a>
#         <font><b>Task 08:</b></font>
#         <br><br>
#         Copy List
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 08. Copy List

import copy

a = [1, 2, 3]
print(a)

b = copy.copy(a)
print(b)

b.append(4)
print(b)

c = copy.deepcopy(a)
print(c)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="08"></a>
#         <font><b>Task 08:</b></font>
#         <br><br>
#         Current Directory
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 09. Current Directory

import os

dirpath = os.getcwd()
print("current directory is : " + dirpath)

foldername = os.path.basename(dirpath)
print("Directory name is : " + foldername)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="10"></a>
#         <font><b>Task 10:</b></font>
#         <br><br>
#         DNS Lookup
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 10. DNS Lookup

import socket

addr1 = socket.gethostbyname('google.com')
addr2 = socket.gethostbyname('yahoo.com')

print('google.com : ', addr1)
print('yahoo.com  : ', addr2)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="11"></a>
#         <font><b>Task 11:</b></font>
#         <br><br>
#         Date Util
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 11. Date Util

import datetime

now = datetime.datetime.now()

print('now.year : ', now.year)

print ('now.strftime("%y") : ', now.strftime("%y"))

print ('now.strftime("%d") : ', now.strftime("%d"))

print ('now.strftime("%m") : ', now.strftime("%m"))

print('datetime.datetime.today() : ', datetime.datetime.today())

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="12"></a>
#         <font><b>Task 12:</b></font>
#         <br><br>
#         Date Util 2
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 12. Date Util 2

import datetime

cur_date = datetime.date.today()
current_year = cur_date.year # Extract current year only
current_month = cur_date.month # Extract current month only
current_day = cur_date.day # Extract current day only

print('current date : ', cur_date)

print('current month : ', current_month)

print('current day : ', current_day)

current_date = cur_date.strftime("%d-%m-%Y")
print('current date with format : ', current_date)

current_date = cur_date.strftime("%d-%B-%Y")
print('current date with format 2 : ', current_date)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="13"></a>
#         <font><b>Task 13:</b></font>
#         <br><br>
#         Default Dict
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 13. Default Dict

from collections import defaultdict

user = defaultdict(lambda: 'Kevin')

print('Default Dictionary : ')
print(user)

print('\nDictionary by random key : ')
print(user['abc'])

print('\nDictionary by another random key : ')
print(user['country'])

user['name'] = 'Peter'
user['age']  = 21
user['city'] = 'Toronto'

print('\nDictionary after assigning value : ')
print(user)

print('\nDictionary by available key (city) : ')
print(user['city'])

# iterate dictionary
print('\nIterating Default dictionary')
for k, v in user.items():
    print(k, "==>", v)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="14"></a>
#         <font><b>Task 14:</b></font>
#         <br><br>
#         Enumerate
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 14. Enumerate

data = ['Toronto', 'Montreal', 'Waterloo', 'Chennai', 'Bangalore', 123, ['One', 'Two', 'Three']]

for x in enumerate(data):
    print(x)
    
for i, x in enumerate(data):
    print(i, "==>", x)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="15"></a>
#         <font><b>Task 15:</b></font>
#         <br><br>
#         Enumerate with index
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 15. Enumerate with index

# start the index from 200
for i, x in enumerate(data, 200):
    print(i, "==>", x)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="16"></a>
#         <font><b>Task 16:</b></font>
#         <br><br>
#         Enumerate List
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 16. Enumerate List

animals = ['cat', 'dog', 'monkey']

print('enumerate with string:')
for idx, animal in enumerate(animals):
    print ('#%d: %s' % (idx , animal))
    
print('\nenumerate with f-strings:')
for idx, animal in enumerate(animals):
    print (f'#{idx}: {animal}')

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id=17""></a>
#         <font><b>Task 17:</b></font>
#         <br><br>
#         Fibonacci
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 17. Fibonacci

def fib(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    else:
        return fib(n-1) + fib(n-2)
    
print(fib(8))
print(fib(13))

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="18"></a>
#         <font><b>Task 18:</b></font>
#         <br><br>
#         Fibonacci in Generator
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 18. Fibonacci in Generator

def fibonacci(n):
    a = b = 1
    
    for i in range(n):
        yield a
        a, b = b, a+b
    
for x in fibonacci(10):
    print(x)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="19"></a>
#         <font><b>Task 19:</b></font>
#         <br><br>
#         Fibonacci Lambda
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 19. Fibonacci Lambda

def print_fibo(number):
    print(list(map(lambda x, f = lambda x, f : (f(x-1,f) + f(x-2,f)) if x > 1 else 1: f(x,f), range(number))))
    
print_fibo(6)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="20"></a>
#         <font><b>Task 20:</b></font>
#         <br><br>
#         Find Domain
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 20. Find Domain

def get_domain(url):
    spltAr = url.split("://")
    i = (0,1)[len(spltAr)>1]
    dm = spltAr[i].split("?")[0].split('/')[0].split(':')[0].lower()
    
    #print(dm)
    return dm

print(get_domain('http://www.oreilly.com/people/adam-michael-wood'))

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="21"></a>
#         <font><b>Task 21:</b></font>
#         <br><br>
#         Find Domain without prefix
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 21. Find Domain without prefix

def get_domain_without_prefix(url):
    spltAr = url.split("://")
    i = (0,1)[len(spltAr)>1]
    dm = spltAr[i].split("?")[0].split('/')[0].split(':')[0].lower()
    
    if("www." in dm):
        dm = dm.replace("www.", "")
    
    return dm

print(get_domain_without_prefix('https://javabeat.net/introduction-to-hibernate-caching/'))

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="22"></a>
#         <font><b>Task 22:</b></font>
#         <br><br>
#         Find Python/Conda Env Location
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 22. Find Python/Conda Env Location

import sys

print(sys.executable)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="23"></a>
#         <font><b>Task 23:</b></font>
#         <br><br>
#         Function With Return Type
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 23. Function With Return Type

def square(a:int) -> int:
    return a * a

print(square(4))

def square_1(a:int) -> str:
    return a * a

print(type(square_1(15))) # this is not working as expected. Need to verify this again

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="24"></a>
#         <font><b>Task 24:</b></font>
#         <br><br>
#         Geo Location 1
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 24. Geo Location 1

import requests
import json 

send_url = 'http://api.ipstack.com/50.100.30.136?access_key=49ad529d309a09477749245782d260b8&format=1'

r = requests.get(send_url)
j = json.loads(r.text)

lat = j['latitude']
lon = j['longitude']

print(lat)
print(lon)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="25"></a>
#         <font><b>Task 25:</b></font>
#         <br><br>
#         Geo Location by Geocoder
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# !pip install geocoder

# %%
# 25. Geo Location by Geocoder

import geocoder

# g = geocoder.ip('me')
# print(g.latlng)  # this will show the current user ip

test_location = geocoder.ip('151.101.1.69')
print(test_location.latlng)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="26"></a>
#         <font><b>Task 26:</b></font>
#         <br><br>
#         Get System Attribute
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 26. Get System Attribute

import sys

print(getattr(sys, 'version'))

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="27"></a>
#         <font><b>Task 27:</b></font>
#         <br><br>
#         Get Default Encoding
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 27. Get Default Encoding

import sys

print(sys.getdefaultencoding())

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="28"></a>
#         <font><b>Task 28:</b></font>
#         <br><br>
#         TBW
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 28. TBW

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="29"></a>
#         <font><b>Task 29:</b></font>
#         <br><br>
#         IP Whois Simple
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# !pip install ipwhois

# %%
# 29. IP Whois Simple

from ipwhois import IPWhois
from pprint import pprint

obj = IPWhois('133.1.2.5')
results = obj.lookup_whois(inc_nir = True)

pprint(results)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="30"></a>
#         <font><b>Task 30:</b></font>
#         <br><br>
#         IP To Long
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 30. IP To Long

import math

class AuthException(Exception):
    pass

def ip_to_long(ip_address):
    
    if(ip_address == '0:0:0:0:0:0:0:1'):
        ip_address = '127.0.0.1'
        
    ip_address_array = ip_address.split('.')
    
    if(len(ip_address_array) != 4):    
        raise AuthException('Invalid Ip')
    
    #print(ip_address_array[1])
    
    num = 0
    for i in range(len(ip_address_array)):
        #print(ip_address_array[i])
        power = 3 - i
        num = num + ( (int(ip_address_array[i]) % 256 * int(math.pow(256, power)) ))
    
    return num

ip_long = ip_to_long('10.3.81.34')        
print(ip_long)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="31"></a>
#         <font><b>Task 31:</b></font>
#         <br><br>
#         JSON to XML
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# !pip install xmltodict

# %%
# 31. JSON to XML

import xmltodict

content = {
  "note" : {
    "to" : "Tove",
    "from" : "Jani",
    "heading" : "Reminder",
    "body" : "Don't forget me this weekend!"
  }
}

print(content)

xml = xmltodict.unparse(content, pretty=True)

print(xml)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="32"></a>
#         <font><b>Task 32:</b></font>
#         <br><br>
#         Lambda Custom
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 32. Lambda Custom

def is_south_indian_city(city):
    if city == 'chennai' or city == 'madurai' or city == 'bengaluru':
        return True
    
    return False

cities = [
    'chennai', 'delhi', 'madurai', 'pune', 'bengaluru'
]

new_list = list(filter(lambda x: is_south_indian_city(x) , cities))
print(new_list)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="33"></a>
#         <font><b>Task 33:</b></font>
#         <br><br>
#         Lambda Function: Odd
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 33. Lambda Function: Odd

def is_odd(digit):
    if digit % 2 != 0:
        return True
    
    return False 

digits = [
    1, 7, 18, 2, 4, 2, 8, 5, 3
]

new_list = list(filter(lambda x: is_odd(x) , digits))

print(new_list)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="34"></a>
#         <font><b>Task 34:</b></font>
#         <br><br>
#         Square calculation by Lambda
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 34. Square calculation by Lambda

squares = list(map(lambda x: x**2, range(10)))

print(squares)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="35"></a>
#         <font><b>Task 35:</b></font>
#         <br><br>
#         Linear Search
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 35. Linear Search

def linear_search(lys, element):  
    for i in range (len(lys)):
        if lys[i] == element:
            return i
    return -1

list = [1, 2, 5, 6]

print(linear_search(list, 5))

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="36"></a>
#         <font><b>Task 36:</b></font>
#         <br><br>
#         List Operations
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 36. List Operations

list = [
    "AB", 
    "CD"
]

print('Basic list:')
print(list)

# append to list
list.append("ABC")
print('\nafter appending ABC:')
print(list)

list.extend(["EFG", "IJK", "LMN"])
print('\nafter extending 3 string list:')
print(list)

list.extend(("OPQ", "RST"))
print('\nafter extending tuple:')
print(list)

list.extend(range(1, 5))
print('\nextending range:')
print(list)

list2 = ["One", "Two"]
print(list2)

list.append(list2)
print('\nafter appending list:')
print(list)

list3 = ["Four", "Five"]

list += list3
print('\nconcat list:')
print(list)

print(list.pop(len(list)-1))
print('\nafter popping last element:')
print(list)

list.remove('AB')
print('\nafter remving a string:')
print(list)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="37"></a>
#         <font><b>Task 37:</b></font>
#         <br><br>
#         Loop a Dictioary
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 37. Loop a Dictioary

a_dict = {'person': 2, 'cat': 4, 'spider': 8}

for animal in a_dict:
    legs = a_dict[animal]
    print ('A %s has %d legs' % (animal, legs))

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="38"></a>
#         <font><b>Task 38:</b></font>
#         <br><br>
#         Class with Magicattr
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# !pip install magicattr

# %%
# 38. Class with Magicattr

import magicattr

class City:
        
    def __init__(self, name, country):
        self.name = name
        self.country = country
        
to = City('Toronto', 'Canada')
ch = City('Chennai', 'India')

print(to)

print(magicattr.get(to, 'country'))

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="39"></a>
#         <font><b>Task 39:</b></font>
#         <br><br>
#         Modify String in Place
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 39. Modify String in Place

import io

s = "Toronto is awesome"

sio = io.StringIO(s)
print(sio.getvalue())

sio.seek(11)
print(sio.write("Wonderful"))

print(sio.getvalue())

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="40"></a>
#         <font><b>Task 40:</b></font>
#         <br><br>
#         More Itertools
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 40. More Itertools

import itertools as it
import more_itertools as mit

a = it.count(0, 2)
mit.take(10, a)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="41"></a>
#         <font><b>Task 41:</b></font>
#         <br><br>
#         Named Arguments in Format
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 41. Named Arguments in Format

print("{greeting!r:20}".format(greeting = "Hello"))

print("{one} {two!r}".format(one = "ten", two = "twenty"))

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="42"></a>
#         <font><b>Task 42:</b></font>
#         <br><br>
#         Python Path
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 42. Python Path

import sys

print(sys.path)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="43"></a>
#         <font><b>Task 43:</b></font>
#         <br><br>
#         Quick Sorting
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 43. Quick Sorting

def quicksort(arr):
    
    if len(arr) <= 1:
        return arr
    
    pivot  = arr[len(arr) // 2]
    left   = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right  = [x for x in arr if x > pivot]
    
    return quicksort(left) + middle + quicksort(right)

print(quicksort([3,6,8,10,1,2,1]))

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="44"></a>
#         <font><b>Task 44:</b></font>
#         <br><br>
#         Random Binary
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 44. Random Binary

import random

MAX = 5

for x in range(MAX):
    val = random.randint(0, 1)
    print(val)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="45"></a>
#         <font><b>Task 45:</b></font>
#         <br><br>
#         Random Timestamp
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 45. Random Timestamp

from random import randrange
import datetime

def random_date(start, l):
    
    current = start
    
    while l >= 0:
        curr = current + datetime.timedelta(minutes=randrange(60))
        yield curr
        l -= 1
    
def get_random_timestamp(max):
    
    startDate = datetime.datetime(2013, 9, 20,13, 0)

    for x in random_date(startDate, max-1):
        print(x.strftime("%d/%m/%y %H:%M"))

        print(x)
        
        timestamp = datetime.datetime.timestamp(x)
        print(int(timestamp))
        
        print('-' * 20)
        
get_random_timestamp(3)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="46"></a>
#         <font><b>Task 46:</b></font>
#         <br><br>
#         Range with Intervals
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 46 Range with Intervals

for x in range(0, 10, 2):
    print(x)
    
print('-' * 10)
    
for x in range(0, 100, 10):
    print(x)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="47"></a>
#         <font><b>Task 47:</b></font>
#         <br><br>
#         Read GitHub CSV
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 47. Read GitHub CSV

from io import BytesIO
import requests
import pandas as pd

FILEPATH = 'https://raw.githubusercontent.com/rajacsp/public-dataset/master/zynicide-wine-reviews/winemag-data-130k-v2.csv'

r = requests.get(FILEPATH)
data = r.content

onlinedata = BytesIO(data)

df = pd.read_csv(onlinedata, index_col=0)

df.head()

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="48"></a>
#         <font><b>Task 48:</b></font>
#         <br><br>
#         Read GitLab CSV
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 48. Read GitLab CSV

from io import BytesIO
import requests
import pandas as pd

filename = 'https://gitlab.com/rajacsp/datasets/raw/master/FEELI%20SONG%20LIST%20-%20Songs.csv'

r = requests.get(filename)
data = r.content

df = pd.read_csv(BytesIO(data), index_col=0)

df.head()

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="49"></a>
#         <font><b>Task 49:</b></font>
#         <br><br>
#         Read JSON Online
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 49. Read JSON Online

import urllib.request, json

with urllib.request.urlopen("https://jsonplaceholder.typicode.com/todos/1") as url:
    data = json.loads(url.read().decode())
#     print(data['tweets'][0])
    print(data)
    print(data['userId'])

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="50"></a>
#         <font><b>Task 50:</b></font>
#         <br><br>
#         Read Online CSV
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 50. Read Online CSV

from io import BytesIO
import requests
import pandas as pd

filename = 'https://gitlab.com/rajacsp/datasets/raw/master/amazon_co_ecommerce_sample.csv'

r = requests.get(filename)
data = r.content

df = pd.read_csv(BytesIO(data), index_col=0)

df.head()

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="51"></a>
#         <font><b>Task 51:</b></font>
#         <br><br>
#         Read Online CSV with Unicode Escape
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 51. Read Online CSV with Unicode Escape

from io import BytesIO
import requests
import pandas as pd


filename = 'https://www.sample-videos.com/csv/Sample-Spreadsheet-10-rows.csv'

r = requests.get(filename)
data = r.content

df = pd.read_csv(BytesIO(data), index_col = 0, encoding = 'unicode_escape')

df.head()

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="52"></a>
#         <font><b>Task 52:</b></font>
#         <br><br>
#         Reduce
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 52. Reduce

from functools import reduce

def add(a, b): 
    return a + b

# add(10, 15)

reduce(add, [10, 20, 30, 40])

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="53"></a>
#         <font><b>Task 53:</b></font>
#         <br><br>
#         Reduce Advanced
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 53. Reduce Advanced

from functools import reduce

def do_magic(a, b): 
    
    if((a % 2 == 1) & (b % 2 == 1) ):
        return a * b
    
    return a + b

reduce(do_magic, [10, 20, 30, 40])

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="54"></a>
#         <font><b>Task 54:</b></font>
#         <br><br>
#         Sum with Reducers
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 54. Sum with Reducers

import functools as fnt

def get_sum(list):
    return fnt.reduce(lambda x,y : x+y, list)

list = [10, 40, 20, 50, 30, 90]

print(get_sum(list))

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="55"></a>
#         <font><b>Task 55:</b></font>
#         <br><br>
#         Remove Item from list
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 55. Remove Item from list

names = [
    "Kevin",
    "Peter",
    "John"
]

print(names)

names.pop(0)

print(names)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="56"></a>
#         <font><b>Task 56:</b></font>
#         <br><br>
#         Remove Item on Loop
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 56. Remove Item on Loop

list = [
    1, 2, 3, 4, 5, 6
]

for i, j in enumerate(list):
    if(j % 2 == 0):
        del list[i]
        
print(list)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="57"></a>
#         <font><b>Task 57:</b></font>
#         <br><br>
#         Remove Item with filterfalse
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 57. Remove Item with filterfalse

list = [1, 2, 3, 4, 5, 6, 7, 8]
from itertools import filterfalse

list[:] = filterfalse((lambda x: x%3), list)
print(list)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="58"></a>
#         <font><b>Task 58:</b></font>
#         <br><br>
#         Remove Item with Short form
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 58. Remove Item with Short form

list = [1, 2, 3, 4, 5, 6, 7, 8]
new_list = [x for x in list if x % 2 == 1]

print(new_list)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="59"></a>
#         <font><b>Task 59:</b></font>
#         <br><br>
#         Remove th From Date
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 59. Remove th From Date

from datetime import datetime
import re

content = 'Sunday, May 18th, 2019'

d = datetime.strptime(re.sub('(\d+)(st|nd|rd|th)', '\g<1>', content), '%A, %B %d, %Y')

print(d)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="60"></a>
#         <font><b>Task 60:</b></font>
#         <br><br>
#         Sort Dictionary By Value
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 60. Sort Dictionary By Value

dict = {
    'one' : 8,
    'two' : 1,
    'three' : 12
}

print(dict)

import operator

sorted_x = sorted(dict.items(), key=operator.itemgetter(1))

print(sorted_x)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="61"></a>
#         <font><b>Task 61:</b></font>
#         <br><br>
#         Dictionary sort with collections
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 61. Dictionary sort with collections

import collections

sorted_dict = collections.OrderedDict(dict)

# Reverse sort
reverse_dict= sorted(dict.items(), key=lambda x: x[1], reverse=True)

print(reverse_dict)

for x in reverse_dict:
    print(x[0], "==>", x[1])

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="62"></a>
#         <font><b>Task 62:</b></font>
#         <br><br>
#         Sort Map By Key
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 62. Sort Map By Key

def sort_by_key(dict):
    
    for key in sorted(dict.keys()):
        print("%s: %s" % (key, dict[key]))
    
    return None

age = {
    'carl':40,
    'alan':2,
    'bob':1,
    'danny':3
}

sort_by_key(age)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="63"></a>
#         <font><b>Task 63:</b></font>
#         <br><br>
#         Sort Map by Value
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 63. Sort Map by Value

def sort_by_value(dict):

    age_sorted = sorted(dict.items(), key=lambda x:x[1])
       
    return age_sorted

age = {
    'carl':40,
    'alan':2,
    'bob':1,
    'danny':3
}

age_sorted = sort_by_value(age)

print(age_sorted)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="64"></a>
#         <font><b>Task 64:</b></font>
#         <br><br>
#         Split with Multiple
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 64. Split with Multiple

import re

content = "Hey, you - what are you doing here!?"

contents = re.findall(r"[\w']+", content)

for c in contents:
    print(c)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="65"></a>
#         <font><b>Task 65:</b></font>
#         <br><br>
#         Static on the fly
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 65. Static on the fly

class Mathematics:

    def addNumbers(x, y):
        return x + y
    
# create addNumbers static method
Mathematics.add = staticmethod(Mathematics.addNumbers)

print('The sum is:', Mathematics.add(5, 10))

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="66"></a>
#         <font><b>Task 66:</b></font>
#         <br><br>
#         Statistics Simple
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 66. Statistics Simple

import statistics

data = [2.75, 1.75, 1.25, 0.25, 0.5, 1.25, 3.5]

print(statistics.mean(data))

print(statistics.median(data))

print(statistics.variance(data))

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="67"></a>
#         <font><b>Task 67:</b></font>
#         <br><br>
#         String Startswith
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 67. String Startswith

content = "Toronto is awesome"

print(content.startswith("Toronto"))

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="68"></a>
#         <font><b>Task 68:</b></font>
#         <br><br>
#         Sys Version
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 68. Sys Version

import sys

print(sys.version)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="69"></a>
#         <font><b>Task 69:</b></font>
#         <br><br>
#         Text Diff
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 69. Text Diff

import difflib

str1 = "I understand how customers do their choice. Difference"
str2 = "I understand how customers do their choice."

seq = difflib.SequenceMatcher(None, str1, str2)

d = seq.ratio() * 100
print(d)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="70"></a>
#         <font><b>Task 70:</b></font>
#         <br><br>
#         Text Similarity
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 70. Text Similarity

def get_similarity(str1, str2):
    seq = difflib.SequenceMatcher(None, str1, str2)
    d = seq.ratio()*100
    return d

get_similarity("Toronto is nice", "Toronto is looking nice")

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="71"></a>
#         <font><b>Task 71:</b></font>
#         <br><br>
#         Timeit Simple
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 71. Timeit Simple

import timeit
import numpy as np

def add(x, y):
    return x + y

repeat_number = 100000
e = timeit.repeat(
    stmt='''add(a, b)''', 
    setup='''a=2; b=3;from __main__ import add''', 
    repeat=3,
    number=repeat_number
)

print('Method: {}, Avg.: {:.6f}'.format("eta", np.array(e).mean()))

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="72"></a>
#         <font><b>Task 72:</b></font>
#         <br><br>
#         Timeit Simple 2
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 72. Timeit Simple 2

import timeit

def some_function():
    return map(lambda x: x^2, range(10))

time1 = timeit.timeit(some_function)
print(time1)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="73"></a>
#         <font><b>Task 73:</b></font>
#         <br><br>
#         Try Catch with Custom Error
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 73. Try Catch with Custom Error

class NegativeMarksError(Exception):
   pass

def check_marks(mark):
    try:
        
        if(mark < 0):
            raise NegativeMarksError
        
        if(mark > 50):
            print('pass')
        else:
            print('fail')
    except ValueError:
        print('ValueError: Some value error')
    except TypeError:
        print('TypeError: Cannot convert into int')
    except NegativeMarksError:
        print('Negative Marks are not allowed')
        
check_marks(10)

check_marks('10')

check_marks(-10)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="74"></a>
#         <font><b>Task 74:</b></font>
#         <br><br>
#         Try Catch with Raise Error
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 74. Try Catch with Raise Error

def check_marks(mark):
    try:
        
        if(mark < 0):
            raise ValueError
        
        if(mark > 50):
            print('pass')
        else:
            print('fail')
    except ValueError:
        print('ValueError: Some value error')
    except TypeError:
        print('TypeError: Cannot convert into int')
        
check_marks('10')

check_marks(-10)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="75"></a>
#         <font><b>Task 75:</b></font>
#         <br><br>
#         Letter Match
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 75. Letter Match

import re

contents = [
    "AB23",
    "A2B3", 
    "DE09",
    "MN90",
    "XYi9",
    "XY90"
]

for content in contents:
    
    regex_pattern = "(?:AB|DE|XY)\d+" 
    # starts with AB or DE; should contain one or more number

    m = re.match(regex_pattern, content)

    if(m):
        print('matched : '+content)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="76"></a>
#         <font><b>Task 76:</b></font>
#         <br><br>
#         Regex Simple Match
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 76. Regex Simple Match

import re

content = "Eminem means positive"

a = re.search('^Em.*ve$', content)

if(a):
    print('matched')
else:
    print('not matched')

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="77"></a>
#         <font><b>Task 77:</b></font>
#         <br><br>
#         Regex and Index
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 77. Regex and Index

import re

pattern = 'awesome'

content = 'Duckduck go is awesome and it is getting better everyday'

match = re.search(pattern, content)

#print(match)

start = match.start()
end = match.end()

# print(match.string)

print(start, end)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="78"></a>
#         <font><b>Task 78:</b></font>
#         <br><br>
#         Compile Expressions
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 78. Compile Expressions

import re

# precompile regex patterns
regex_entries = [
    re.compile(p)
    for p in ['awesome', 'ocean']
]

content = 'Duckduck go is awesome and it is getting better everyday'

print('Text : {!r}'.format(content))

for regex in regex_entries:
    print('Finding  {} -> '.format(regex.pattern), end = ' ')

    if(regex.search(content)):
        print('matched')
    else:
        print('not matched')

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="79"></a>
#         <font><b>Task 79:</b></font>
#         <br><br>
#         Regex - Find Multiple Whitespace
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 79. Regex - Find Multiple Whitespace

import re

print(re.split(r'\s{2,}', "2012.03.04       check everything      status: OK"))


content = "2012.03.04       check everything      status: OK"

list = re.split(r'\s{2,}', content)

for a in list:
    print(a)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id=80""></a>
#         <font><b>Task 80:</b></font>
#         <br><br>
#         Regex - Find Two Digits with Spaces
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 80. Regex - Find Two Digits with Spaces

import re

text = "It happened on Feb 21 at 3:30"

answer= re.findall(r'\b\d{2}\b', text)
print(answer)

# To match only two digits with spaces
answers = re.findall(r'\s\d{2}\s', text)

for a in answers:
    print(a.strip())

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="81"></a>
#         <font><b>Task 81:</b></font>
#         <br><br>
#         Regex - Get Full Matches
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 81. Regex - Get Full Matches

import re
from typing import List

_RGX = re.compile(r'(.)\1*')
def long_repeat(string: str) -> List[str]:
    return [m.group(0) for m in _RGX.finditer(string)]

print(long_repeat('devvvvveeeeeeeeeeeloooooooooper'))

print(long_repeat('country'))

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="82"></a>
#         <font><b>Task 82:</b></font>
#         <br><br>
#         Regex - Get Specific Contents
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 82. Regex - Get Specific Contents

content = """<!DOCTYPE html>

  <!-- The following setting enables collapsible lists -->
  <p>
  <a href="#human">Human</a></p>

  <p class="collapse-section">
  <a class="collapsed collapse-toggle" data-toggle="collapse" 
  href=#mammals>Mammals</a>
  <div class="collapse" id="mammals">
  <ul>
  <li><a href="#alpaca">Alpaca</a>
  <li><a href="#armadillo">Armadillo</a>
  <li><a href="#sequence_only">Armadillo</a> (sequence only)
  <li><a href="#baboon">Baboon</a>
  <li><a href="#bison">Bison</a>
  <li><a href="#bonobo">Bonobo</a>
  <li><a href="#brown_kiwi">Brown kiwi</a>
  <li><a href="#bushbaby">Bushbaby</a>
  <li><a href="#sequence_only">Bushbaby</a> (sequence only)
  <li><a href="#cat">Cat</a>
  <li><a href="#chimp">Chimpanzee</a>
  <li><a href="#chinese_hamster">Chinese hamster</a>
  <li><a href="#chinese_pangolin">Chinese pangolin</a>
  <li><a href="#cow">Cow</a>
  <li><a href="#crab-eating_macaque">Crab-eating_macaque</a>
  <div class="gbFooterCopyright">
  &copy; 2017 The Regents of the University of California. All 
  Rights Reserved.
  <br>
  <a href="https://genome.ucsc.edu/conditions.html">Conditions of 
  Use</a>
  </div>"""

import re

regex = r"<li.+?#[^s].+?>(.+)?<\/.+>"

find_matches = re.findall(regex, content)
for matches in find_matches:
    print(matches)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="83"></a>
#         <font><b>Task 83:</b></font>
#         <br><br>
#         Regex - Ontario Postal Code
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 83. Regex - Ontario Postal Code

import re

names = ['M2N1H5', 'M2N 1H5', 'M882J8']

regex_patten = "^[A-Z]\d[A-Z]\s*\d[A-Z]\d"
# starts with Capital letter; it can have zero or one space

for name in names:
    m = re.match(regex_patten, name)

    if(m):
        #print(m.groups())
        print('matched : ', name)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="84"></a>
#         <font><b>Task 84:</b></font>
#         <br><br>
#         Regex - Remove Numbers
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 84. Regex - Remove Numbers

import re

content = '15. TFRecord in Tensorflow'

result = re.sub(r'\d+\.', '', content)

print(result.strip())

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="85"></a>
#         <font><b>Task 85:</b></font>
#         <br><br>
#         Regex - Remove Numbers 2
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 85. Regex - Remove Numbers 2

content2 = """1. Cross Entropy Loss Derivation

2. How to split a tensorflow model into two parts?

3. RNN Text Generation with Eager Execution

4. Softmax activation in Tensor"""

result2 = re.sub(r'\d+\.', '', content2)

# result2.strip()

for c in result2.strip().split('\n'):
    print(c.strip())

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="86"></a>
#         <font><b>Task 86:</b></font>
#         <br><br>
#         Regex - Remove Symbols
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 86. Regex - Remove Symbols

import re

content = "This device is costing only 12.89$. This is fantastic!"

result = re.sub(r'[^\w]', ' ', content)

print(result)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="87"></a>
#         <font><b>Task 87:</b></font>
#         <br><br>
#         Regex - Search
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 87. Regex - Search

import re

data = [
    "name['toronto'] = 'One'",
    "state['ontario'] = 'Two'",
    "country['canada']['ca'] = 'Three'",
    "extra['maple'] = 'Four'"
]

REGEX = re.compile(r"\['(?P<word>.*?)'\]")

for line in data:
    found = REGEX.search(line)
    if found:
        print(found.group('word'))

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="88"></a>
#         <font><b>Task 88:</b></font>
#         <br><br>
#         Class Basics
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 88. Class Basics

class Employee:
    def __init__(self, name, age, salary):
        self.name = name
        self.age = age
        self.salary = salary
        
    def __repr__(self):
        return repr((self.name, self.age, self.salary))
    
employees = [
    Employee('Peter', 21, 6),
    Employee('Kevin', 22, 4),
    Employee('Simon', 21, 8)
]

print(employees)

# sorting
print(sorted(employees, key = lambda e: e.salary))

print(sorted(employees, key = lambda e: -e.salary))

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="89"></a>
#         <font><b>Task 89:</b></font>
#         <br><br>
#         Sort by Attrgetter
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 89. Sort by Attrgetter

from operator import itemgetter, attrgetter

print(sorted(employees, key=attrgetter('age')))

young_employees = sorted(employees, key=attrgetter('age'), reverse=False)
print(young_employees)

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="90"></a>
#         <font><b>Task 90:</b></font>
#         <br><br>
#         Fuzzy String Ratio
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 90. Fuzzy String Ratio

from fuzzywuzzy import fuzz

print(fuzz.ratio("this is a test", "this is a test!"))

print(fuzz.ratio("this is a cup", "this is a world cup"))

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="91"></a>
#         <font><b>Task 91:</b></font>
#         <br><br>
#         List Op - sublist from to
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 91. List Op - sublist from to

a = [
    10, 20, 30, 40, 50, 60, 70, 80, 90
]

print(a[4:8])

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="92"></a>
#         <font><b>Task 92:</b></font>
#         <br><br>
#         List Op - Get first 4
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 92. List Op - Get first 4

a = [
    10, 20, 30, 40, 50, 60, 70, 80, 90
]

print(a[:4])

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="93"></a>
#         <font><b>Task 93:</b></font>
#         <br><br>
#         List Op - from index to last
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 93. List Op - from index to last

a = [
    10, 20, 30, 40, 50, 60, 70, 80, 90
]

print(a[4:])

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="94"></a>
#         <font><b>Task 94:</b></font>
#         <br><br>
#         List Op - Get all as subset
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 94. List Op - Get all as subset

a = [
    10, 20, 30, 40, 50, 60, 70, 80, 90
]

print(a[:])

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="95"></a>
#         <font><b>Task 95:</b></font>
#         <br><br>
#         List Op - Get last item
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 95. List Op - Get last item

a = [
    10, 20, 30, 40, 50, 60, 70, 80, 90
]

print(a[-1])

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="96"></a>
#         <font><b>Task 96:</b></font>
#         <br><br>
#         List Op - Get last second item
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 96. List Op - Get last second item

a = [
    10, 20, 30, 40, 50, 60, 70, 80, 90
]

print(a[-2])

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="97"></a>
#         <font><b>Task 97:</b></font>
#         <br><br>
#         List Op - Get last 2 items
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 97. List Op - Get last 2 items

a = [
    10, 20, 30, 40, 50, 60, 70, 80, 90
]

# get last 2 items
print(a[-2:])

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="98"></a>
#         <font><b>Task 98:</b></font>
#         <br><br>
#         List Op - Get every items except last 2 items
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 98. List Op - Get every items except last 2 items

a = [
    10, 20, 30, 40, 50, 60, 70, 80, 90
]

# every except last 2 iteme
print(a[:-2])

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="99"></a>
#         <font><b>Task 99:</b></font>
#         <br><br>
#         List Op - Get all item reversed
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 99. List Op - Get all item reversed

a = [
    10, 20, 30, 40, 50, 60, 70, 80, 90
]

# all items reverse
print(a[::-1])

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="100"></a>
#         <font><b>Task 100:</b></font>
#         <br><br>
#         List Op - Get first 2 items reversed
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 100. List Op - Get first 2 items reversed

a = [
    10, 20, 30, 40, 50, 60, 70, 80, 90
]

print(a[1::-1])

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="101"></a>
#         <font><b>Task 101:</b></font>
#         <br><br>
#         List Op - Get first 3 items reversed
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 101. List Op - Get first 3 items reversed

a = [
    10, 20, 30, 40, 50, 60, 70, 80, 90
]

# get the first three items reversed
print(a[2::-1])

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="102"></a>
#         <font><b>Task 102:</b></font>
#         <br><br>
#         List Op - Get all items reversed and ignore the last item
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 102. List Op - Get all items reversed and ignore the last item

a = [
    10, 20, 30, 40, 50, 60, 70, 80, 90
]

# all items eversed and ignore the last item
print(a[-2::-1])

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="103"></a>
#         <font><b>Task 103:</b></font>
#         <br><br>
#         List Op - Remove last 2 item, reverse the rest
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 103. List Op - Remove last 2 item, reverse the rest

a = [
    10, 20, 30, 40, 50, 60, 70, 80, 90
]

# Remove last 2 items, reverse all the rest of the items
print(a[-3::-1])

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="104"></a>
#         <font><b>Task 104:</b></font>
#         <br><br>
#         List Op - Get last item reversed
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 104. List Op - Get last item reversed

a = [
    10, 20, 30, 40, 50, 60, 70, 80, 90
]

# last two items reversed
print(a[:-3:-1])

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="105"></a>
#         <font><b>Task 105:</b></font>
#         <br><br>
#         List Op - Everything except the last 3 items, reversed
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %%
# 105. List Op - Everything except the last 3 items, reversed

a = [
    10, 20, 30, 40, 50, 60, 70, 80, 90
]

# Everything except the last 3 items, reversed
print(a[-4::-1])

# %%
# 105. String format

a = "x{} y{} z{}"

b = a.format(10, 20, 30)

print(b)

# %%
# 106. Unpack tuple in String format

a = "x{} y{} z{}"
b_tuple = (11, 21, 31)

c = a.format(*b_tuple)

print(c)

# Caution
# d = a.format(b_tuple) ==> This will throw :: IndexError: tuple index out of range

# %%
# 107. Unpack list in String format

a = "x{} y{} z{}"
b_list = [11, 21, 31]

# print(type(b_list))

c = a.format(*b_list)

print(c)

# Caution
# d = a.format(b_tuple) ==> This will throw :: IndexError: tuple index out of range

# %%
# 107. Unpack list in String format

a = "x{} y{} z{}"
b_dict = {
    'a' : 10,
    'b' : 20
}

# c = a.format(*b_dict) # This will throw IndexError: tuple index out of range

# %%
# 108. Get the second slowest number in the list

a = [1, 23, 23, 1, 89, 55, 78, 23, 12, 17, 17, 34, 34, 6]

print('Original list:')
print(a)

b = sorted(set(a))[1]
print('\nSecond smallest number : ')
print(b)

# %%
# 109. Combine list elements by index

import itertools

a = [10, 20, 30]
b = [1, 2, 3]
c = [19, 29, 39]

print('Original:')
print('\na:')
print(a)
print('\nb:')
print(b)
print('\nc:')
print(c)

d = []
for x,y,z in zip(a,b,c):
    d.extend((x,y,z))

print('\nCombined list:')
print(d)

# %%
# 110. Find in JSON String

import json

jsonString ='''[{"city":"Toronto","result":{"dummy":"twenty","_code":"to"}},
{"city":"Montreal","result":{"dummy":"one","_code":"mo"}},
{"city":"New York","result":{"dummy":"elevel","_code":"ny"}}]'''

json_content = json.loads(jsonString)
print('Original:')
print(json_content)

print('\nFind _code:')
for index in range(len(json_content)):
    content = json_content[index]["result"]['_code']
    print(content)

# %%
# 111. Word to Chars

word = "Toronto"

letters = list(word)

for l in letters:
    print(l)

# %%
# !pip install phonenumbers

# %%
# 112. Get Region Code for phone numbers

import phonenumbers

from phonenumbers.phonenumberutil import (
    region_code_for_country_code,
    region_code_for_number,
    country_code_for_region
)

pn = phonenumbers.parse('+1 647 898 3434')
print('Region code for Phone Number +1 647 898 3434:')
print(region_code_for_number(pn))

print('\nRegion Code for Country Code 91:')
print(region_code_for_country_code(91))

print('\nCountry Code for Region:')
print(country_code_for_region('IN'))

# %%
# 113. Get Country and Codes

import pycountry

canada = pycountry.countries.get(alpha_2='CA')

print('Canada:')
print(canada)
print(canada.name)

us = pycountry.countries.get(alpha_2 = 'US')
print('\nUSA:')
print(us)

# %%
# 114. Number counter with defaultdict

from collections import defaultdict

counter = defaultdict(int)

content = "one 2 1 three 4 2 1 7 6 six 8 9 8"

for c in content.split(' '):
    if(c.isdigit()):
        counter[c] += 1
    
for k, v in counter.items():
    print(k, "==>", v)

# %%
# 115. 

class Person:  

    def __init__(self, name, job, pay):
        self.job  = job
        self.pay  = pay

    def giveRaise(self, percent):
        self.pay = int(self.pay + (self.pay * percent)/100)
        
mark = Person('Mark', 'developer', 100000)
print('Pay before raise:')
print(mark.pay)

mark.giveRaise(5)

print('\nPay after raise:')
print(mark.pay)

# %%
# 116. Locals of Function

def myFunc():
    print("hello")
    
fname = "myFunc"

f = locals()[fname]
f()

f = eval(fname)
f()

# %%
# 117. Modify String in Place

import io

content = "Toronto is awesome"

content_io = io.StringIO(content)
print(content_io.getvalue())

content_io.seek(11)
content_io.write("Wonderful")

print(content_io.getvalue())

# %% [markdown]
# **Note:**
#
# * Need to clean up print options
# * Need to update the documentation
# * Add trendy snippets

# %% [markdown]
# **Final Notes:**
#
# I am adding things still. You can come back and check for more information.
#
# Also, if you **like my notebook**, <font style="color:blue;size:14px;">please upvote it</font> as it will motivate me to come up with better approach in the upcoming notebooks.

# %% [markdown]
# <font color="blue" size=+1.5><b>Check out my other kernels</b></font>
#
# <table style="font-family: 'Trebuchet MS', Arial, Helvetica, sans-serif;border-collapse: collapse;width: 100%;">
#   <tr>
#     <th style="border: 1px solid #ddd;padding: 8px; padding-top: 12px;padding-bottom: 12px;text-align: left;background-color: #2987E7;color: white;">Notebook</th>
#     <th style="border: 1px solid #ddd;padding: 8px; padding-top: 12px;padding-bottom: 12px;text-align: left;background-color: #2987E7;color: white;">Tags</th>
#   </tr>
#   <tr>
#     <td style="text-align: left"><a href="https://www.kaggle.com/rajacsp/reviews-with-nlp-wip">Amazon Alexa Reviews with NLP</a> </td>
#     <td style="text-align: left">NLP, Spacy</td>
#   </tr>
#   <tr>
#     <td style="text-align: left"><a href="https://www.kaggle.com/rajacsp/sof-questions-eda-and-visual">SOF Questions - EDA and Visual</a> </td>
#     <td style="text-align: left">Data Visual, Plotly</td>
#   </tr>
#   <tr>
#     <td style="background-color: #f2f2f2;text-align: left"><a href="https://www.kaggle.com/rajacsp/netflix-visualization-plotly-plots-treemap">Netflix - Visualization, Plotly, Plots, and Treemap</a> </td>
#     <td style="background-color: #f2f2f2;text-align: left">Data Visual, Data Cleaning, Plotly</td>
#   </tr>
#   <tr>
#     <td style="text-align: left"><a href="https://www.kaggle.com/rajacsp/prediction-with-various-algorithms">Prediction with various Algorithms</a> </td>
#     <td style="text-align: left">Random Forest, Logistic Regression</td>
#   </tr>
#   <tr>
#     <td style="background-color: #f2f2f2;text-align: left"><a href="https://www.kaggle.com/rajacsp/eda-and-visualization">EDA and Visualization</a> </td>
#     <td style="background-color: #f2f2f2;text-align: left">Data Cleaning, Data Visual</td>
#   </tr>
#   <tr>
#     <td style="text-align: left"><a href="https://www.kaggle.com/rajacsp/job-analysis-eda-visual">Job Analysis - EDA and Visual</a> </td>
#     <td style="text-align: left">Data Visual, EDA, Plotly</td>
#   </tr>
#   <tr>
#     <td style="background-color: #f2f2f2;text-align: left"><a href="https://www.kaggle.com/rajacsp/estonia-disaster-visualization">Estonia Disaster - Visualization</a> </td>
#     <td style="background-color: #f2f2f2;text-align: left">Data Visual, EDA, Data Cleaning</td>
#   </tr>
#
#   <tr>
#     <td style="text-align: left"><a href="https://www.kaggle.com/rajacsp/pandas-dundas-challenge-100" >Pandas 100+ exercises collection</a></td>
#     <td style="text-align: left">Pandas, Data Manipulation</td>
#   </tr>
#   <tr>
#     <td style="background-color: #f2f2f2;text-align: left"><a href="https://www.kaggle.com/rajacsp/prediction-with-various-algorithms">Credit Card Fraud - Prediction with various algorithms</a></td>
#     <td style="background-color: #f2f2f2;text-align: left">Various ML Algorithms</td>
#   </tr>
#   <tr>
#     <td style="text-align: left"><a href="https://www.kaggle.com/rajacsp/linear-equations-real-time">Linear Equations - Real Time</a> </td>
#     <td style="text-align: left">Linear Equation</td>
#   </tr>
# </table>
