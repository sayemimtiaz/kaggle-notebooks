# %%
import pandas as pd

# %%
data=pd.read_csv('../input/corona-virus-report/worldometer_data.csv')
data.head()

# %%
data.shape

# %%
data.describe()

# %%
data.info()

# %%
data.isnull().sum()

# %%
data.groupby('Country/Region').sum()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))
plt.bar(data['Country/Region'],data['TotalDeaths'])

# %%
top10=data.iloc[:10,0:10]
top10

# %%
serious=data['Serious,Critical'].sum()
serious

# %%
population=data['Population'].sum()
population

# %%
newcases=data['NewCases'].sum()
newcases

# %%
plt.figure(figsize=(10,5))
plt.bar(top10['Country/Region'],top10['TotalDeaths'])
