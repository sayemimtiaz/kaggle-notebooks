# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd  
from sklearn.model_selection import train_test_split

fruits = pd.read_csv('../input/fruit-data-with-colours/fruit_data_with_colours.csv') 

fruits.head()

# %%
fruits.shape

# %%
X= fruits[['mass','width','height']] 
y = fruits[['fruit_label']]
X_train , X_test , y_train , y_test = train_test_split(X,y,random_state=2,test_size=0.21)

# %%
X_train.describe()

# %%
X_test.describe()

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier 
knn = KNeighborsClassifier(n_neighbors=5, p=2, metric='euclidean')

# %%
knn.fit(X_train,np.ravel(y_train))

# %%
knn.score(X_test,y_test)
