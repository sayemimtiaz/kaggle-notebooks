# %% [markdown]
# # Number of infected people in Brazil and more ...
# 20M51790
# Mizuochi Takumi
# mizuochi.t.aa@m.titech.ac.jp

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from plotly.offline import iplot
import plotly.graph_objs as go
np.set_printoptions(threshold=np.inf)

selected_country = 'Brazil'
df = pd.read_csv('../input/novel-corona-virus-2019-dataset/covid_19_data.csv',header=0)
#print(np.unique(df['Country/Region'].values))
df = df[df['Country/Region']==selected_country]

df = df.groupby('ObservationDate').sum()
df['daily_confirmed'] = df['Confirmed'].diff()
df['daily_deaths'] = df['Deaths'].diff()
df['daily_recoveries'] = df['Recovered'].diff()

daily_confirmed_object = go.Scatter(x=df.index,y=df['daily_confirmed'].values,name='Daily confirmed')
daily_deaths_object = go.Scatter(x=df.index,y=df['daily_deaths'].values,name='Daily deaths')
daily_recoveries_object = go.Scatter(x=df.index,y=df['daily_recoveries'].values,name='Daily recoveries')
layout_object = go.Layout(title='Brazil daily cases 20M51790',xaxis=dict(title='Date'),yaxis=dict(title='Number of people'))
fig = go.Figure(data=[daily_confirmed_object,daily_deaths_object,daily_recoveries_object],layout=layout_object)
iplot(fig)
fig.write_html('Brazil_daily_cases_20M51790.html')

# %%
df1 = df#[['daily_confirmed']]
df1 = df1.fillna(0.)
styled_object = df1.style.background_gradient(cmap='gist_ncar').highlight_max('daily_confirmed').set_caption('Daily Summaries')
display(styled_object)
f = open('table_20M51790.html','w')
f.write(styled_object.render())

# %%
df = pd.read_csv('../input/novel-corona-virus-2019-dataset/covid_19_data.csv',header=0)
df = df.groupby(['ObservationDate','Country/Region'],as_index=False).sum()
df = df[df['ObservationDate']=='06/10/2020'].sort_values(by=['Confirmed'],ascending=False).reset_index()
print('Grobal Rankign of '+ selected_country +':',df[df['Country/Region']==selected_country].index.values[0]+1)

# %% [markdown]
# # Analysis
# To see the Daily confirmed number, it is expected to increase in the future. In addition, even under these circumstances, the Brazilian government has failed to take effective containment measures for fear of negative effects on the economy. To see the number of people in recovery, it exploded on June 8, and this result suggests that the "recovery" definition may have changed that Brazilian government had been using. And, in fact, the president has made it clear on Twitter that he has changed his statistical methods. All in all, it's clear that the number of cases in Brazil is only going to increase future.

# %% [markdown]
# # How the Brazilian government is addressing the issue
# The Brazilian government has not taken any lockdowns or other measures throughout the country and has asked state governors to determine the details of the restrictions.  D In the state of São Paulo, all but the most essential facilities for life have been closed by order of the state governor. Th country seems to be focusing more on economic measures than on infectious diseases.

# %% [markdown]
# # Reference news
# * https://brazilian.report/coronavirus-brazil-live-blog/2020/04/23/why-reporting-recovered-covid-19-cases-tricky-brazil/
# * https://www.nikkei.com/article/DGXMZO60081590X00C20A6000000/
# * https://www.jetro.go.jp/biz/areareports/2020/70ccddedf3ec38ed.html
