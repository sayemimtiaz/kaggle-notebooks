# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
COLUMNS = ['CRIM','ZN','INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        df = pd.read_csv(os.path.join(dirname, filename),delim_whitespace = True,header= None,names=COLUMNS)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Data checking

# %%
df

# %%
df.describe()

# %%
df.dropna()

# %% [markdown]
# # Data Visualisation
#
# Visulising the data that how the data is in corelated with the target variable

# %%
import seaborn as sbn
import matplotlib.pyplot as plt

# %%
plt.scatter(df['CRIM'],df['MEDV'])
plt.xlabel('CRIM')
plt.ylabel('MEDV')

# %%
plt.scatter(df['ZN'],df['MEDV'])
plt.xlabel('ZN')
plt.ylabel('MEDV')

# %%
sbn.pairplot(df)

# %%
sbn.heatmap(df.corr(),annot=True)

# %%
df.corr()

# %% [markdown]
# # Data preprocessing and Model training
#
# We are getting from 1 parameter to 8 parameter and finding which model has less amount of error and we use that for the predicting the values

# %%
MSE = []

# %%
X = df[['CRIM','ZN','INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']]
y = df['MEDV']

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA


ss = StandardScaler()
ss.fit(X)
data = ss.transform(X)

data.shape

pca = PCA(n_components=1)

data = pca.fit_transform(X)

data.shape

pd.DataFrame(data)

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression


x_train,x_test,y_train,y_test = train_test_split(data,y,test_size=0.3)

lr = LinearRegression()
model1 = lr.fit(x_train,y_train)

predicted = model1.predict(x_test)

from sklearn.metrics import mean_absolute_error, mean_squared_error

print("MAE: ", mean_absolute_error(y_test,predicted))
print("MSE: ", mean_squared_error(y_test,predicted))

MSE.append(mean_squared_error(y_test,predicted))

# %%
X = df[['CRIM','ZN','INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']]
y = df['MEDV']

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA


ss = StandardScaler()
ss.fit(X)
data = ss.transform(X)

data.shape

pca = PCA(n_components=2)

data = pca.fit_transform(X)

data.shape

pd.DataFrame(data)

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression


x_train,x_test,y_train,y_test = train_test_split(data,y,test_size=0.3)

lr = LinearRegression()
model2 = lr.fit(x_train,y_train)

predicted = model2.predict(x_test)

from sklearn.metrics import mean_absolute_error, mean_squared_error

print("MAE: ", mean_absolute_error(y_test,predicted))
print("MSE: ", mean_squared_error(y_test,predicted))
MSE.append(mean_squared_error(y_test,predicted))

# %%
X = df[['CRIM','ZN','INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']]
y = df['MEDV']

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA


ss = StandardScaler()
ss.fit(X)
data = ss.transform(X)

data.shape

pca = PCA(n_components=3)

data = pca.fit_transform(X)

data.shape

pd.DataFrame(data)

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression


x_train,x_test,y_train,y_test = train_test_split(data,y,test_size=0.3)

lr = LinearRegression()
model3 = lr.fit(x_train,y_train)

predicted = model3.predict(x_test)

from sklearn.metrics import mean_absolute_error, mean_squared_error

print("MAE: ", mean_absolute_error(y_test,predicted))
print("MSE: ", mean_squared_error(y_test,predicted))
MSE.append(mean_squared_error(y_test,predicted))

# %%
X = df[['CRIM','ZN','INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']]
y = df['MEDV']

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA


ss = StandardScaler()
ss.fit(X)
data = ss.transform(X)

data.shape

pca = PCA(n_components=4)

data = pca.fit_transform(X)

data.shape

pd.DataFrame(data)

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression


x_train,x_test,y_train,y_test = train_test_split(data,y,test_size=0.3)

lr = LinearRegression()
model4 = lr.fit(x_train,y_train)

predicted = model4.predict(x_test)

from sklearn.metrics import mean_absolute_error, mean_squared_error

print("MAE: ", mean_absolute_error(y_test,predicted))
print("MSE: ", mean_squared_error(y_test,predicted))
MSE.append(mean_squared_error(y_test,predicted))

# %%
X = df[['CRIM','ZN','INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']]
y = df['MEDV']

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA


ss = StandardScaler()
ss.fit(X)
data = ss.transform(X)

data.shape

pca = PCA(n_components=5)

data = pca.fit_transform(X)

data.shape

pd.DataFrame(data)

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression


x_train,x_test,y_train,y_test = train_test_split(data,y,test_size=0.3)

lr = LinearRegression()
model5 = lr.fit(x_train,y_train)

predicted = model5.predict(x_test)

from sklearn.metrics import mean_absolute_error, mean_squared_error

print("MAE: ", mean_absolute_error(y_test,predicted))
print("MSE: ", mean_squared_error(y_test,predicted))
MSE.append(mean_squared_error(y_test,predicted))

# %%
X = df[['CRIM','ZN','INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']]
y = df['MEDV']

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA


ss = StandardScaler()
ss.fit(X)
data = ss.transform(X)

data.shape

pca = PCA(n_components=6)

data = pca.fit_transform(X)

data.shape

pd.DataFrame(data)

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression


x_train,x_test,y_train,y_test = train_test_split(data,y,test_size=0.3)

lr = LinearRegression()
model6 = lr.fit(x_train,y_train)

predicted = model6.predict(x_test)

from sklearn.metrics import mean_absolute_error, mean_squared_error

print("MAE: ", mean_absolute_error(y_test,predicted))
print("MSE: ", mean_squared_error(y_test,predicted))
MSE.append(mean_squared_error(y_test,predicted))

# %%
X = df[['CRIM','ZN','INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']]
y = df['MEDV']

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA


ss = StandardScaler()
ss.fit(X)
data = ss.transform(X)

data.shape

pca = PCA(n_components=7)

data = pca.fit_transform(X)

data.shape

pd.DataFrame(data)

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression


x_train,x_test,y_train,y_test = train_test_split(data,y,test_size=0.3)

lr = LinearRegression()
model7 = lr.fit(x_train,y_train)

predicted = model7.predict(x_test)

from sklearn.metrics import mean_absolute_error, mean_squared_error

print("MAE: ", mean_absolute_error(y_test,predicted))
print("MSE: ", mean_squared_error(y_test,predicted))
MSE.append(mean_squared_error(y_test,predicted))

# %%
X = df[['CRIM','ZN','INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']]
y = df['MEDV']

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA


ss = StandardScaler()
ss.fit(X)
data = ss.transform(X)

data.shape

pca = PCA(n_components=8)

data = pca.fit_transform(X)

data.shape

pd.DataFrame(data)

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression


x_train,x_test,y_train,y_test = train_test_split(data,y,test_size=0.3)

lr = LinearRegression()
model8 = lr.fit(x_train,y_train)

predicted = model8.predict(x_test)

from sklearn.metrics import mean_absolute_error, mean_squared_error

print("MAE: ", mean_absolute_error(y_test,predicted))
print("MSE: ", mean_squared_error(y_test,predicted))
MSE.append(mean_squared_error(y_test,predicted))

# %%
plt.bar([1,2,3,4,5,6,7,8],MSE)
plt.xlabel('no.of features')
plt.ylabel('Mean squared error')

# %% [markdown]
# # Data intrepretation
#
# **Model 8** has good MSE
# According to this data it's good to have the 8 parameters each of them serves someting to the data so that our **Mean squared error** got increased.....
#
# Our coefficients are:

# %%
model8.coef_
