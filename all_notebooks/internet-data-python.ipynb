# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# https://www.kaggle.com/wefann/region
data = pd.read_csv('/kaggle/input/region/inf_data.csv', index_col=0)

# %%
data

# %%
data.shape

# %%
data.describe()

# %%
data.index

# %%
data.columns

# %%
sns.barplot(data['Широкополосный доступ 2019'], data.index)

# %%
part = data.T.iloc[:3, :5]
part

# %%
part.plot(kind='barh')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# %%
part.plot(style='o-')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# %%
sns.distplot(data['Доступ к Интернет 2019'], kde=False)

# %%
sns.distplot(data['Мобильный интернет 2015'], label='Мобильный интернет 2015', kde=False)
sns.distplot(data['Мобильный интернет 2019'], label='Мобильный интернет 2019', kde=False)
plt.xlabel('Динамика')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# %%
sns.jointplot(data["Мобильный интернет 2019"], data["Доступ к Интернет 2019"], kind="reg")

# %%
sns.boxplot(data['Доступ к Интернет 2019'])

# %%
sns.boxplot(data['Мобильный интернет 2019'])

# %%
sns.boxplot(data['Широкополосный доступ 2019'])
