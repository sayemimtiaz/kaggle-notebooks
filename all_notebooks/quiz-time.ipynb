# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# 1) Load the data.
# Sort the data by total SAT scores in descending order to show the highest scoring states first.

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('/kaggle/input/sat-score-data-by-state/Guber1999data.csv')
df = df.sort_values('SATT', ascending = False)
print(df)

# %% [markdown]
# 2) State a logical conclusion, based on the data you see not on your own opinions of the states, that may explain why certain states may have higher average scores than other states which may have nothing to do with the quality of the students' ability in general.

# %%
#States with lower income and an impovershed community tend to have lower SAT scores because access to study materials is less availible.

#I came back to this question after doing 5 and I realized, that the highest SAT score states are coorelated with a small percentage actually taking them.
#This means, only the top percentage of students must take them and have very little deviation.

# %% [markdown]
# 3) Use a scatter plot to plot the salary as the independent variable and total SAT score as the dependent variable.

# %%
df.plot.scatter(x = 'Salary', y = 'SATT')

# %% [markdown]
# 4) Make a conjecture about what this graph (#3) means about salary and SAT scores. Explain why you came up with this conjecture based off of the graph.

# %%
#There seems to be no coorelation between salary and SAT score because there is no clear trend to the data.

# %% [markdown]
# 5) Make a box plot using both the SAT Verbal scores and the SAT Math scores.

# %%
df.boxplot(column=['SATV', 'SATM'])

# %% [markdown]
# 6)
# a. Describe what information you can easily see by using a box plot (do not talk about your graph directly).
# b. Using only your box plot graph, what could you say about a state who has an average Math SAT score of 460?

# %% [markdown]
# a) By using a box plot you can easily see the highest and lowest scores, along with the average and a few standard deviations up and a few standard deviationds down. By using a box plot, you can predict where a majority of students will land

# %% [markdown]
# b) A Mat SAT Score of 460 would be in the lower 25% of all students.

# %% [markdown]
# 7) Display a histogram with 25 bins of the percent of students who take the exam in each state.

# %%
df.hist(column= 'PrcntTake', bins = 25)

# %% [markdown]
# 8) Describe what a 'bin' is.

# %%
#The amount of bins are the amount of intervals the histogram is broken up into

# %% [markdown]
# 9) Sort the data by the SAT Verbal scores, then create a regular line graph that graphs the Verbal scores vs the Math scores.

# %%
print( df.sort_values('SATV', ascending = True).plot(x = 'SATV', y = 'SATM') )

# %% [markdown]
# 10) Why is it a good idea to first sort the values by your indepedent variable before doing a line graph?

# %%
#The graph will increase and show you any trends (easier to visualize the mean average).
