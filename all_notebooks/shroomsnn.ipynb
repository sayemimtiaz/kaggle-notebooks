# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.neural_network import MLPClassifier

# %%
data = pd.read_csv('../input/mushroom-classification/mushrooms.csv')
data.describe()

# %%
data = data.drop('veil-type', axis=1)

# %%
# на графике видно, что пропусков в данных нет
sns.heatmap(data.isna())

# %%
classes = data.columns
for i in classes:
    data[i] = LabelEncoder().fit_transform(data[i])
data.describe()

# %%
print(classes)
data.head()

# %%
# Диаграмма корреляции используется для визуального просмотра метрики
# корреляции между всеми возможными парами числовых переменных в данном наборе данных
plt.figure(figsize=(15,12), dpi= 90)
sns.heatmap(data.corr(), cmap='RdYlGn', center=0, annot=True)

# %%
X = data.drop('class', axis=1)
Y = data['class']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.5)

# %%
mlp1 = MLPClassifier().fit(X_train, Y_train)

# %%
sum(Y_test == mlp1.predict(X_test))/len(Y_test)

# %%
print(classification_report(mlp1.predict(X_test), Y_test))
