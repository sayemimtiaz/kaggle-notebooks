# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

# %matplotlib inline
pd.set_option('display.max_rows', 100)

df = pd.read_csv("../input/2017.csv")

#siit algab
import seaborn as sns 
import matplotlib as mpl 
import plotly.graph_objs as go 
from plotly.graph_objs import *
from matplotlib import pyplot as plt 
from plotly.offline import iplot, init_notebook_mode


sns.set(style="whitegrid", palette="muted")
current_palette = sns.color_palette()
init_notebook_mode(connected=True)
# %matplotlib inline

# %%
df

# %%
df.info()

# %%
df.tail(3)

# %%
df.head(100)

# %%
df[df.Country].plot(x='Happiness.Score', y='Economy..GDP.per.Capita.');

# %%
df[["Country","Happiness.Rank" ,"Freedom","Economy..GDP.per.Capita."]]

# %%
print("Keskmine õnnelikuse indeks:", df["Happiness.Rank"].mean())
print("Maksimaalne õnnelikuse indeks:", df["Happiness.Rank"].max())
print("Minimaalne õnnelikuse indeks:", df["Happiness.Rank"].min())
print("Midagi " , df["Happiness.Rank"].describe())

# %%
print("Midagi " , df["Happiness.Score"].value_counts())

# %%
df["Happiness.Score"].plot.hist()

# %%
df.Family.plot.hist()

# %%
df.["Happiness.Score"].plot.hist()

# %%
df.plot.scatter("Freedom", "Happiness.Rank", alpha=0.2, color="Red");

# %%
df.plot.scatter("Economy..GDP.per.Capita.", "Happiness.Rank", alpha=0.2, color="Red");

# %%
df.groupby("Economy..GDP.per.Capita.")["Family"].mean()

# %%
# choropleth map across all countries 
scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
            [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]

data = dict(
    type='choropleth',
    colorscale = scl,
    autocolorscale = False,
    locations = ['Country'],
    locationmode = 'country names',
    z = ['Happiness Score'],
    text = ['Country'],
    colorbar = {'title':'Happiness Score'}
)

layout = dict(
    title = 'Global Happiness Score',
    geo = dict(
        showframe = False,
        showcoastlines = False,
        projection = {'type':'Mercator'}
    )
)

cmap = go.Figure(data=[data], layout=layout)
iplot(cmap)

# %% [markdown]
# <div>
#     <a href="https://plot.ly/~jaak.ungro/1/?share_key=g5Q9gl6WBevnuB7fekOkjk" target="_blank" title="Plot 1" style="display: block; text-align: center;"><img src="https://plot.ly/~jaak.ungro/1.png?share_key=g5Q9gl6WBevnuB7fekOkjk" alt="Plot 1" style="max-width: 100%;width: 1000px;"  width="1000" onerror="this.onerror=null;this.src='https://plot.ly/404.png';" /></a>
#     <script data-plotly="jaak.ungro:1" sharekey-plotly="g5Q9gl6WBevnuB7fekOkjk" src="https://plot.ly/embed.js" async></script>
# </div>

# %% [markdown]
# As of 2015, the average GDP per capita (PPP) of all of the countries of the world is USD $15,800
