# %%
import pandas as pd
d=[50,40,30,20,10]
di={"id":5,"name":"Deepak","age":26}
s=pd.Series(data=d)
s2=pd.Series(data=di)

# %%
s2

# %%
s

# %%
import numpy as np
d2=np.random.randint(10,size=(5,5))
df=pd.DataFrame(data=d2,index=['a','b','c','d','e'],
                columns=['ind','aus','sri','can','uk'])

# %%
df

# %%
df.shape

# %%
df.index

# %%
df.columns

# %%
df.info()

# %%
df.describe()

# %%
df.head(2)

# %%
df.tail(2)

# %%
df.count()

# %%
df.sum(axis=1)

# %%
df.sum(axis=0)

# %%
df.min()

# %%
df.max()

# %%
df.mean()

# %%
df.median()

# %%
df.idxmin()

# %%
df.idxmax()

# %%
df.sort_index(axis=1)

# %%
df.sort_index(ascending=False,axis=1)

# %%
df.sort_index(ascending=True,axis=0)

# %%
df.sort_values(by="a",axis=1)

# %%
df.sort_values(by="ind")

# %%
df.sort_values(by="aus")

# %%
df

# %%
df.drop('a')

# %%
df.drop("aus",axis=1)

# %%
df.drop(columns='ind',index='a')

# %%
df.drop('a')

# %%
def here(x):
    return x**2
df.apply(here)

# %%
def here(x):
    return x**2
df['sri']=df['sri'].apply(here)

# %%
df

# %%
df['sri']=df['sri'].apply(lambda x:x**2)
