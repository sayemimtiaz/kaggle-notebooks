# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
from pandas_profiling import ProfileReport

# %%
data79_21=pd.read_csv("../input/monthly-gold-prices/1979-2021.csv")

# %% [markdown]
# #File Price Gold 1979 to 2021 , include price Gold 1990 to 2021

# %%
data79_21.head()

# %%
data79_21.info()

# %%
data79_21['Date']=pd.to_datetime(data79_21['Date'])

# %%
data79_21.describe()

# %%
sns.heatmap(data79_21.isna())

# %% [markdown]
# Visualisations in US Currency

# %%
plt.style.use("dark_background")
plt.figure(figsize=(20,10))
sns.lineplot(x='Date', y='United States(USD)',data=data79_21)

# %%
df=ProfileReport(data79_21)

# %%
df
