# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
train_data = pd.read_csv("/kaggle/input/digit-recognizer/train.csv")

# %%
train_data.shape

# %%
train_data.info()

# %%
full_y = train_data.loc[:,"label"]

full_X = train_data.drop("label",axis=1)

# %%
# !pip3 install pillow

import PIL

# %%
X_train.shape

# %%
X_train.head()

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(full_X, full_y, test_size = 0.2, random_state = 5)

# %%
full_X.isna().sum().sum()

# %%
((full_X < 0) | (full_X > 255)).any().sum()

# %%
from sklearn.linear_model import LogisticRegression


lm_bench = LogisticRegression(max_iter=200,)

lm_bench.fit(X_train,y_train)

# %%
lm_bench.score(X_valid,y_valid)

# %%
X_test = pd.read_csv("/kaggle/input/digit-recognizer/test.csv")

# %%
output = pd.DataFrame(lm_bench.predict(X_test),columns = ["Label"])

# %%
X_test.head()

# %%
output["ImageId"] = np.arange(1, output.size+1)

# %%
output = output[["ImageId","Label"]]

# %%
output.to_csv("submission.csv",index=False)

# %%
output

# %%
import matplotlib.pyplot as plt

plt.imshow(X_train.iloc[0,:].values.reshape(28,28))

# %%
y_train.iloc[0]

# %%
X_train.shape

# %%
from sklearn.decomposition import PCA

pca = PCA(7) 
projected = pca.fit_transform(X_train)
print(X_train.shape)
print(projected.shape)

# %%
pca.explained_variance_

# %%
projected

# %%
fig, ax = plt.subplots(1,1,figsize=(25,25))

g = ax.scatter(projected[:, 0], projected[:, 1],
            c=y_train, edgecolor='none', alpha=0.5,
            cmap=plt.cm.get_cmap('terrain', 10))
ax.set_xlabel('component 1')
ax.set_ylabel('component 2')
fig.colorbar(g);

# %%
fig, ax = plt.subplots(1,1,figsize=(25,25))

g = ax.scatter(projected[:, 1], projected[:, 2],
            c=y_train, edgecolor='none', alpha=0.5,
            cmap=plt.cm.get_cmap('terrain', 10))
ax.set_xlabel('component 1')
ax.set_ylabel('component 2')
fig.colorbar(g);

# %%
principal_components_tb = pca.components_

# %%
principal_components_tb[0,:]

# %%
fig, ax = plt.subplots(1,1,figsize=(15,15))

ax.stem(principal_components_tb[0,:])

# %%
from sklearn.linear_model import LogisticRegression

lm_pca = LogisticRegression(max_iter=10000)

lm_pca.fit(projected,y_train)

# %%
pca.explained_variance_

# %%
projected_validation = pca.transform(X_valid)

# %%
projected_validation.shape

# %%
lm_pca.score(projected_validation,y_valid)

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier

rf = RandomForestClassifier()

ad = AdaBoostClassifier(DecisionTree())

# %%
rf.fit(X_train,y_train)

# %%
rf.score(X_valid,y_valid)

# %%
ad.fit(X_train,y_train)

# %%
ad.score(X_valid,y_valid)

# %%
LogisticRegression()

# %%
# Stacking


from sklearn.naive_bayes import CategoricalNB
from sklearn.ensemble import StackingClassifier

estimator_list = [
    
    
    ("lr",LogisticRegression(max_iter=10000)),
    ("rf",RandomForest()),
    ("nb",CategoriclNB()),
    
    
]

stack = StackingClassifier(estimator_list, final_estimator=RandomForest())

stack.fit(X_train,y_train)

# %%
stack.score(X_valid,y_valid)
