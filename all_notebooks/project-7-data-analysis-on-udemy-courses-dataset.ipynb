# %% [markdown]
# # Greetings!! This notebook is to do EDA and to solve questions on Udemy Courses dataset....

# %% [markdown]
# ![](https://s3.amazonaws.com/media.al-fanarmedia.org/wp-content/uploads/2020/04/17090134/udemy.jpg)

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
df = pd.read_csv("../input/udemy-courses-dataset/Udemy Courses Data.csv")
df.head(2)

# %%
df.tail(2)

# %%
df.index

# %%
df.columns

# %%
df.nunique()

# %%
df["is_paid"].unique()

# %%
df["level"].unique()

# %%
df["subject"].unique()

# %%
df["price"].unique()

# %%
df["content_duration"].unique()

# %%
df["num_lectures"].unique()

# %%
df["num_reviews"].unique()

# %%
df["num_reviews"].unique()

# %%
df[df.duplicated()]

# %%
df.drop_duplicates(inplace =True)

# %%
df[df.duplicated()]

# %%
df.isnull().sum()

# %% [markdown]
# # Questions:-
# # 1.How will you hide the indexes of the DataFrame?

# %%
df.head(2)

# %%
df.style.hide_index()

# %% [markdown]
# # 2.How can we set the caption / heading on the DataFrame?

# %%
df.style.set_caption("Udemy Courses dataset")

# %% [markdown]
# # 3.What are all different subjects for which udemy is offering courses?

# %%
df.head(2)

# %%
df["subject"].unique()

# %% [markdown]
# # 4.Which subject has the maximum no. of courses?

# %%
df["subject"].value_counts()

# %%
df["subject"].max()

# %% [markdown]
# # 5.Show all the courses which are free of cost?

# %%
df.head(2)

# %%
df["is_paid"].unique()

# %%
df["is_paid"].dtype

# %%
df[df["is_paid"]==False].head(5)

# %% [markdown]
# # 6.Show all the courses which are Paid?

# %%
df.head(2)

# %%
df[df["is_paid"]==True].head()

# %% [markdown]
# # 7.Which are Top selling courses?

# %%
df.head(2)

# %%
df.sort_values(by = "num_subscribers",ascending = False ).head()

# %% [markdown]
# # 8.Which are Least selling courses?

# %%
df.sort_values(by = "num_subscribers",ascending = True ).head()

# %% [markdown]
# # 9.Show all courses of "Graphic design" where the price is below 100?

# %%
df.head(2)

# %%
df.info()

# %%
df["price"].unique()

# %%
df["price"].replace({"Free":0},inplace = True)

# %%
df["price"].unique()

# %%
df["price"]=pd.to_numeric(df["price"])

# %%
df["subject"].unique()

# %%
df[(df["subject"]=="Graphic Design")&(df["price"]<100)].head()

# %% [markdown]
# # 10.What are courses that published in year 2015?

# %%
df.head(2)

# %%
df["published_timestamp"].dtypes

# %%
df["published_timestamp"]=pd.to_datetime(df["published_timestamp"])

# %%
df["Year"]=df["published_timestamp"].dt.year

# %%
df.head(2)

# %%
df[df["Year"]==2015].head()

# %% [markdown]
# # 11.What are the maximum no. of subsribers for each level of courses?

# %%
df.head(2)

# %%
df.groupby("subject").num_subscribers.max()

# %% [markdown]
# # Please feel free to comment and take a moment to vote up.
# # Thanks for your support.
# # Happy learning......

# %% [markdown]
# ![](https://i.gifer.com/1B4T.gif)
