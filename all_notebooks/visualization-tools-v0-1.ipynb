# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
ShareRaceByCity_df = pd.read_csv("/kaggle/input/fatal-police-shootings-in-the-us/ShareRaceByCity.csv",encoding = "windows-1252")
PercentagePeopleBelowPovertyLevel_df = pd.read_csv("/kaggle/input/fatal-police-shootings-in-the-us/PercentagePeopleBelowPovertyLevel.csv",encoding = "windows-1252")
MedianHouseholdIncome2015_df = pd.read_csv("/kaggle/input/fatal-police-shootings-in-the-us/MedianHouseholdIncome2015.csv",encoding = "windows-1252")
PoliceKillingsUS_df = pd.read_csv("/kaggle/input/fatal-police-shootings-in-the-us/PoliceKillingsUS.csv",encoding = "windows-1252")
PercentOver25CompletedHighSchool_df = pd.read_csv("/kaggle/input/fatal-police-shootings-in-the-us/PercentOver25CompletedHighSchool.csv",encoding = "windows-1252")

# %%
PercentagePeopleBelowPovertyLevel_df.head()

# %%
PercentagePeopleBelowPovertyLevel_df.info()

# %%
PercentagePeopleBelowPovertyLevel_df.poverty_rate.value_counts()

# %% [markdown]
# # Bar Plot

# %%
# poverty rate of each state

PercentagePeopleBelowPovertyLevel_df.poverty_rate.replace(["-"],0.0,inplace = True) # verinin içindeki - değerlerini 0.0 ile değiştirir.
PercentagePeopleBelowPovertyLevel_df.poverty_rate = PercentagePeopleBelowPovertyLevel_df.poverty_rate.astype(float)

area_list = list(PercentagePeopleBelowPovertyLevel_df["Geographic Area"].unique()) # unique eyaletler (her eyalatten birden fazla olabileceği için unique() fonksiyonu ile sadece 1 tanesi alınır.)
area_poverty_ratio = []

for i in area_list:
    x = PercentagePeopleBelowPovertyLevel_df[PercentagePeopleBelowPovertyLevel_df["Geographic Area"] == i]
    area_poverty_rate = sum(x.poverty_rate)/len(x)
    area_poverty_ratio.append(area_poverty_rate)

data = pd.DataFrame({'area_list': area_list,'area_poverty_ratio':area_poverty_ratio})
new_index = (data['area_poverty_ratio'].sort_values(ascending=False)).index.values
sorted_data = data.reindex(new_index)
# visualization

plt.figure(figsize = (15,12))
sns.barplot(x = sorted_data["area_list"],y = sorted_data["area_poverty_ratio"])
plt.xticks(rotation = 90)
plt.xlabel("States")
plt.ylabel("Poverty Rate")
plt.title("Poverty Rate given states")

# %%
PoliceKillingsUS_df.head()

# %%
PoliceKillingsUS_df.name.value_counts()

# %%
seperate = PoliceKillingsUS_df.name[PoliceKillingsUS_df.name != "TK TK"].str.split()
a,b = zip(*seperate)
name_list = a+b
name_count = Counter(name_list)
most_common_names = name_count.most_common(15)
x,y = zip(*most_common_names)
x,y = list(x),list(y)

# visualization

plt.figure(figsize = (15,12))
sns.barplot(x = x ,y = y,palette = sns.cubehelix_palette(len(x)))
plt.xlabel("Name or Surname killed people")
plt.ylabel("Frequency")
plt.title("Most Common 15 name or surname of killed people")

# %%
PercentOver25CompletedHighSchool_df.head()

# %%
PercentOver25CompletedHighSchool_df.percent_completed_hs.value_counts()

# %%
PercentOver25CompletedHighSchool_df.percent_completed_hs.replace(["-"],0.0,inplace = True)
PercentOver25CompletedHighSchool_df.percent_completed_hs = PercentOver25CompletedHighSchool_df.percent_completed_hs.astype(float)

area_list2 = list(PercentOver25CompletedHighSchool_df["Geographic Area"].unique())
area_highschool = []

for i in area_list2:
    
    x2 = PercentOver25CompletedHighSchool_df[PercentOver25CompletedHighSchool_df["Geographic Area"] == i]
    area_highschool_rate = sum(x2.percent_completed_hs)/len(x2)
    area_highschool.append(area_highschool_rate)

data = pd.DataFrame({"area_list": area_list2, "area_highschool_ratio": area_highschool})
new_index = (data["area_highschool_ratio"].sort_values(ascending = False)).index.values
sorted_data2 = data.reindex(new_index)

# visualization

plt.figure(figsize = (15,12))
sns.barplot(x =sorted_data2["area_list"], y = sorted_data2["area_highschool_ratio"])
plt.xticks(rotation = 90)
plt.xlabel("States")
plt.ylabel("Frequency")
plt.title("Highschool graduate ratio to States")
plt.show()

# %%
ShareRaceByCity_df.head()

# %%
ShareRaceByCity_df.info()

# %%
ShareRaceByCity_df.replace(["-"],0.0,inplace = True)
ShareRaceByCity_df.replace(["(X)"],0.0,inplace = True)
area_list = list(ShareRaceByCity_df["Geographic area"].unique())
ShareRaceByCity_df.loc[:,['share_white','share_black','share_native_american','share_asian','share_hispanic']] = ShareRaceByCity_df.loc[:,['share_white','share_black','share_native_american','share_asian','share_hispanic']].astype(float)
ShareRaceByCity_df.info()

share_white = []
share_black = []
share_native = []
share_asian = []
share_hispanic = []

for i in area_list:
    
    x = ShareRaceByCity_df[ShareRaceByCity_df["Geographic area"] == i]
    share_white.append(sum(x.share_white)/len(x))
    share_black.append(sum(x.share_black)/len(x))
    share_native.append(sum(x.share_native_american)/len(x))
    share_asian.append(sum(x.share_asian)/len(x))
    share_hispanic.append(sum(x.share_hispanic)/len(x))
    

# visualization
f,ax = plt.subplots(figsize = (15,12))
sns.barplot(x = share_white, y = area_list,color = "green",alpha = 0.5, label = "White")
sns.barplot(x = share_black, y = area_list, color = "blue", alpha = 0.7, label = "African American")
sns.barplot(x = share_native, y = area_list, color = "cyan", alpha = 0.6, label = "Native American")
sns.barplot(x = share_asian, y = area_list, color = "yellow", alpha = 0.6, label = "Asian")
sns.barplot(x = share_hispanic, y = area_list, color = "red", alpha = 0.6, label = "Hispanic")

ax.legend(loc="lower right",frameon = True)
ax.set(xlabel = "Percentage of races", ylabel = "States", title = "Percentage of State's Population According to Races")

# %% [markdown]
# # Point Plot

# %%
# high school graduation rate vs poverty rate of each state

sorted_data["area_poverty_ratio"] = sorted_data["area_poverty_ratio"]/max(sorted_data["area_poverty_ratio"])
sorted_data2["area_highschool_ratio"] = sorted_data2["area_highschool_ratio"]/max(sorted_data2["area_highschool_ratio"])

data = pd.concat([sorted_data,sorted_data2["area_highschool_ratio"]],axis = 1)
data.sort_values("area_poverty_ratio", inplace = True)

#visualization

f,ax1 = plt.subplots(figsize =(20,10))
sns.pointplot(x='area_list',y='area_poverty_ratio',data=data,color='lime',alpha=0.8)
sns.pointplot(x='area_list',y='area_highschool_ratio',data=data,color='red',alpha=0.8)
plt.text(40,0.6,'high school graduate ratio',color='red',fontsize = 17,style = 'italic')
plt.text(40,0.55,'poverty ratio',color='lime',fontsize = 18,style = 'italic')
plt.xlabel('States',fontsize = 15,color='blue')
plt.ylabel('Values',fontsize = 15,color='blue')
plt.title('High School Graduate  VS  Poverty Rate',fontsize = 20,color='blue')
plt.grid()

# %% [markdown]
# # Joint Plot

# %%
data.head()

# %%
g = sns.jointplot(data.area_poverty_ratio,data.area_highschool_ratio, kind = "kde", size =7)
plt.show()

# %%
g1 = sns.jointplot("area_poverty_ratio","area_highschool_ratio",data = data, size = 5, ratio = 3, color = "red")
plt.show()

# %%
PoliceKillingsUS_df.race.dropna(inplace = True)
labels = PoliceKillingsUS_df.race.value_counts().index
colors = ['grey','blue','red','yellow','green','brown']
explode = [0,0,0,0,0,0]
sizes = PoliceKillingsUS_df.race.value_counts().values

#visualization

plt.figure(figsize = (7,7))
plt.pie(sizes, explode = explode, labels = labels, colors = colors, autopct='%1.1f%%')
plt.title('Killed People According to Races',color = 'blue',fontsize = 15)

# %% [markdown]
# # Lm Plot

# %%
a = sns.lmplot("area_poverty_ratio","area_highschool_ratio",data = data)
plt.show()

# %% [markdown]
# # Heatmap
# * correlation visualization

# %%
data.head()

# %%
data.corr()

# %%
f,ax = plt.subplots(figsize = (5,5))
sns.heatmap(data.corr(), annot = True, linewidths = .5, linecolor = "red", fmt = ".2f" , ax = ax)
plt.show()

# %% [markdown]
# # Box Plot
# * Outlier visualization

# %%
PoliceKillingsUS_df.manner_of_death.unique()

# %%
PoliceKillingsUS_df.gender.unique()

# %%
sns.boxplot(x = "gender", y = "age", hue = "manner_of_death", data = PoliceKillingsUS_df, palette = "PRGn") # hue = class
plt.show()

# %% [markdown]
# # Swarm Plot

# %%
PoliceKillingsUS_df.head()

# %%
sns.swarmplot(x = "gender", y = "age", hue = "manner_of_death", data = PoliceKillingsUS_df)
plt.show()

# %% [markdown]
# # Count Plot

# %%
PoliceKillingsUS_df.head()

# %%
PoliceKillingsUS_df.manner_of_death.value_counts()

# %%
PoliceKillingsUS_df.gender.value_counts()

# %%
sns.countplot(PoliceKillingsUS_df.gender)
#sns.countplot(PoliceKillingsUS_df.manner_of_death)
plt.title("gender",color = "blue",fontsize = 15)
plt.show()

# %%
armed = PoliceKillingsUS_df.armed.value_counts()
plt.figure(figsize = (7,7))
sns.barplot(x = armed[:7].index, y = armed[:7].values)
plt.xticks(rotation = 90)
plt.ylabel("Number of weapon")
plt.xlabel("Weapon types")
plt.show()
