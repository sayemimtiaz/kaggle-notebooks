# %% [markdown]
# How much days the patient stays in a hospital in corona pandemic

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df_train=pd.read_csv('../input/av-healthcare-analytics-ii/healthcare/train_data.csv')
df_train_dict=pd.read_csv('../input/av-healthcare-analytics-ii/healthcare/train_data_dictionary.csv')
df_test=pd.read_csv('../input/av-healthcare-analytics-ii/healthcare/test_data.csv')
df_samp=pd.read_csv('../input/av-healthcare-analytics-ii/healthcare/sample_sub.csv')

# %%
df_train.head()

# %%
df_train['Stay'].value_counts()

# %%
df_train.isnull().sum()

# %% [markdown]
# In train dataset there are 113 null values in Bed Grade column and 4532 null values in City_code_patient.

# %%
df_test.isnull().sum()

# %% [markdown]
# In test dataset there are 35 null values in Bed Grade column and 2157 null values in City_code_patient.

# %% [markdown]
# So we have to data cleaning steps by substituting the null values with some other values.

# %%
df_train.shape ,df_test.shape

# %%
df_train['Stay'].unique()

# %% [markdown]
# So we are going to use Label encoder as it helps to assign unique labels to unique values.
# We are applying it on Stay column as we have to find patient stay in hospital during covid pandemic.
# Labelling starts from 0 onwards.

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df_train['Stay']=le.fit_transform(df_train['Stay'])

# %%
df_train['Stay'].value_counts()

# %%
cols=df_train.columns
for col in cols:
    print('Number of unique categories for',col,'are:',df_train[col].nunique())

# %%
df_train.isna().sum()

# %%
df_train.drop(['case_id','patientid'],axis=1,inplace=True)

# %%
df_train['Bed Grade']=np.where(df_train['Bed Grade'].isna(),1.0,df_train['Bed Grade'])

# %%
df_train['City_Code_Patient']=np.where(df_train['City_Code_Patient'].isna(),0.0,df_train['City_Code_Patient'])

# %%
df_train['Bed Grade']=df_train['Bed Grade'].astype(int)
df_train['City_Code_Patient']=df_train['City_Code_Patient'].astype(int)
df_train['Admission_Deposit']=df_train['Admission_Deposit'].astype(int)

# %%
df_train['Bed Grade'].value_counts()

# %% [markdown]
# 2  -  87491;
# 1  -  78139;
# 3  -  55159;
# 5  -  35018;
# 0  -  23604;
# 4  -  11743;
# 7  -  10254;
# 10 -   6683;
# 8  -   4838;
# 9  -   2765;
# 6  -   2744;

# %% [markdown]
# 21-30;
# 11-20;
# 31-40;
# 51-60;
# 0-10;
# 41-50;
# 71-80;
# More than 100 Days;
# 81-90;
# 91-100;
# 61-70;

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize=(15,4))
import seaborn as sns 
sns.countplot(x='Stay',hue='Age',data=df_train)

# %% [markdown]
# In 2->21-30 days above age groups 31-40(green), 41-50(red), 51-60(blue) are mostly kept. Basically in all slot of days the age groups 41-50 and 31-40 have been kept more.

# %%
plt.subplots(figsize=(15,4))
sns.countplot(x='Bed Grade',hue='Type of Admission',data=df_train)

# %% [markdown]
# Type of Admission: Urgent<Emergency<Trauma
# Trauma patients are been atttend first as it is the most urgent case. In below graph we can see trauma patients are kept
# for in high numbers for most days.

# %%
plt.subplots(figsize=(15,4))
sns.countplot(x='Stay',hue='Type of Admission',data=df_train)

# %% [markdown]
# Severity of illness: Minor <Moderate<Extreme
# So in below graph we can see that moderate are kept more as they need treatment plus they can harm less to covid patients
# Minor are allowed to go home. Extreme are not kept because they can get harm by covid.

# %%
plt.subplots(figsize=(15,4))
sns.countplot(x='Stay',hue='Severity of Illness',data=df_train)

# %%
plt.subplots(figsize=(15,4))
sns.countplot(x='Stay',hue='Department',data=df_train)

# %% [markdown]
# array(['0-10', '41-50', '31-40', '11-20', '51-60', '21-30', '71-80',
#        'More than 100 Days', '81-90', '61-70', '91-100'], dtype=object)

# %% [markdown]
# 21-30                 87491;
# 11-20                 78139;
# 31-40                 55159;
# 51-60                 35018;
# 0-10                  23604;
# 41-50                 11743;
# 71-80                 10254;
# More than 100 Days     6683;
# 81-90                  4838;
# 91-100                 2765;
# 61-70                  2744;

# %% [markdown]
# 2  -   87491;
# 1  -  78139;
# 3  -  55159;
# 5  -  35018;
# 0  -  23604;
# 4  -  11743;
# 7  -  10254;
# 10 -   6683;
# 8  -   4838;
# 9  -   2765;
# 6  -   2744;

# %%
df_train['Bed Grade'].value_counts()

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize=(15,4))
import seaborn as sns 
sns.countplot(x='Stay',hue='Age',data=df_train)

# %%
plt.subplots(figsize=(15,4))
sns.countplot(x='Bed Grade',hue='Type of Admission',data=df_train)

# %%
plt.subplots(figsize=(15,4))
sns.countplot(x='Stay',hue='Type of Admission',data=df_train)

# %%
plt.subplots(figsize=(15,4))
sns.countplot(x='Stay',hue='Severity of Illness',data=df_train)

# %% [markdown]
# df=pd.DataFrame({'Age':[10,20,30],'Stay':[10,20,50]})
# ax=df.plot.barh(stacked=True

# %%
df_train['Department'].unique()

# %%
plt.subplots(figsize=(15,4))
sns.countplot(x='Stay',hue='Department',data=df_train)

# %%
import plotly.graph_objects as go
import plotly.express as px

# %%
df_train['train_flag']=1

# %%
df_hos_code=df_train.groupby('Hospital_type_code')['train_flag'].sum().reset_index().sort_values(by='train_flag',ascending=False)

# %%
fig1=px.bar(df_hos_code,x='Hospital_type_code',y='train_flag',color='train_flag',labels={'Hospital_type_code':'Hospital Type Code','train_flag':'Number of patients'})
fig1.update_layout(title='Patient distribution per hospital type code',title_x=0.5,template='plotly_dark')
fig1.show()

# %% [markdown]
# As we can see, the hospital type A has a much higher patient case load when in comparison any of the other hospital codes. Hospital type G has the least case load. Hence, hospital type A has a much higher likelihood of running out of patient beds while G has the least

# %%
fig2=px.sunburst(df_train,path=['Hospital_region_code','Hospital_type_code'])
fig2.update_layout(title='Hospital region case load distribution',title_x=0.5)
fig2.show()

# %% [markdown]
# As we can see from the above sunburst plot, the case loads in hospital region X is marginally higher than hospital region Y and the least in region Z . For region X, the hospital type A had highest case load while it was more equally balanced between a and b in region Y. For region Z, highest case loads were in hospital type C. Hospitals in region X seem to show better distribution amogst all the hospital types.
#
# For region Y, distribution between A and B is ideal but f,d and g have been under utilised. For Z, cases in hospital c were easily the highest but a and d are extremely under utilised.

# %%
fig3=px.histogram(df_train,x='Available Extra Rooms in Hospital',marginal='box',color_discrete_sequence=['orange'],opacity=0.7)
fig3.update_layout(template='plotly_dark',title='Number of hospitals with extra rooms',title_x=0.5)
fig3.show()

# %% [markdown]
# As we can see from the above histogram, majority of hospitals have extra rooms in the size of 2,3 or 4 rooms. The median extra rooms is 3

# %%
df_beds=df_train[['Hospital_code','Available Extra Rooms in Hospital','Hospital_region_code']]
df_beds['Hospital_region_code']=df_beds['Hospital_region_code'].map({'X':1,'Y':2,'Z':3})
df_beds_grouped=df_beds.groupby('Hospital_code')[['Available Extra Rooms in Hospital','Hospital_region_code']].median().reset_index()

# %%
df_beds_grouped['Hospital_region_code']=df_beds_grouped['Hospital_region_code'].map({1:'X',2:'Y',3:'Z'})
df_beds_grouped.head()

# %%
df_beds_1=df_beds_grouped.groupby('Hospital_region_code')['Available Extra Rooms in Hospital'].sum().reset_index()
fig4=px.pie(df_beds_1,values='Available Extra Rooms in Hospital',names='Hospital_region_code',hole=0.4)
fig4.update_layout(title='Number of extra rooms in each region code',title_x=0.5)
fig4.update_traces(textinfo='percent+label')

# %% [markdown]
# From the above pie chart, we see that the number of extra available rooms are almost equally distributed amongst the three region codes. This is an ideal scenario.

# %%
df_dept=df_train.groupby('Department')['train_flag'].sum().reset_index().sort_values(by='train_flag',ascending=False)

# %%
fig5=px.bar(df_dept,x='Department',y='train_flag',color='Department',labels={'train_flag':'Number of patients'})
fig5.update_layout(title='Case load distribution per department',title_x=0.5,template='plotly_dark')
fig5.show()

# %% [markdown]
# From the above bar plot, we see that majority of the patients register themselves at the gynecology department. Surgery department has the least number of case loads. This is expected as daily birth cases are far higher than daily surgeries

# %%
df_sev=df_train.groupby('Severity of Illness')['train_flag'].sum().reset_index().sort_values(by='train_flag',ascending=False)
fig6=px.funnel(df_sev,x='train_flag',y='Severity of Illness',labels={'train_flag':'Number of patients'},color='train_flag')
fig6.update_layout(title='Case load depending upon severity of illness',title_x=0.5,template='plotly_dark')
fig6.show()

# %% [markdown]
# From the above funnel plot, we see that most number of cases are moderate in nature followed by minor and then, extreme.

# %%
fig7=px.sunburst(df_train,path=['Age','Severity of Illness'])
fig7.update_layout(title='Age (in years) and Severity of Illness',title_x=0.5)
fig7.show()

# %% [markdown]
# As we can see from the sunburst plot above, extreme cases are least for each age group. However, the extreme cases in relation to the moderate and minor cases seem to increase with higher age groups.

# %%
df_train.columns

# %%
#data['Stay'].isnull().sum()

# %%
fig8=px.sunburst(df_train,path=['Stay','Severity of Illness'])
fig8.update_layout(title='Stay period (in days) vs Severity of illness',title_x=0.5)
fig8.show()

# %% [markdown]
# From the above plot, it is seen that generally for lower stay duration(upto 20 days), the severity of illness is majorly minor or moderate. For higher stay duration, the extreme severity cases start rising.
#
# 21-30 days and 11-20 days are the most common stay periods across the hospitals.

# %%
#data.shape

# %%
#data.columns

# %%
'''cat=data.select_dtypes(['object']).columns
cat
'''

# %%
#cat=cat[:-1]
#cat

# %%
#data=pd.get_dummies(data=data,columns=['Hospital_type_code', 'Hospital_region_code', 'Department', 'Ward_Type',
#       'Ward_Facility_Code', 'Type of Admission', 'Severity of Illness','Age'])

# %%
#data.shape

# %%
#data.dtypes

# %%
#df_train,df_test=data[data.train_flag==1], data[data.train_flag==0]

# %%
#df_train.drop(['train_flag'],inplace=True,axis=1)
#df_test.drop(['train_flag'],inplace=True,axis=1)
#df_test.drop(['Stay'],inplace=True,axis=1)

# %%
#print(df_train.shape,df_test.shape)

# %%
#del data

# %%
#df_train['Stay']=df_train['Stay'].astype(int)

# %%
#from sklearn.model_selection import train_test_split
#df_train, df_eval=train_test_split(df_train, test_size=0.30, random_state=42, shuffle=True, stratify=df_train['Stay'])

# %%
#feature_cols=df_train.columns.tolist()
#feature_cols.remove('Stay')
#label_col='Stay'
#print(feature_cols)

# %%
#cat_cols=feature_cols
#cat_cols.remove('Admission_Deposit')
#cat_cols

# %%
#train.corr()

# %%
#import matplotlib.pyplot as plt
#import seaborn as sns
#plt.figure(figsize=(14,14))
#sns.heatmap(train.corr(),annot=True,fmt='.0%')

# %%
#train['Department'].unique()

# %%
#train['Severity of Illness'].unique()
