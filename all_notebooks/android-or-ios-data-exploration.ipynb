# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %%
train = pd.read_csv('/kaggle/input/question-classification-android-or-ios/train.csv')

# %%
train.head()

# %%
px.pie(train, 'Label')

# %%
px.histogram(train, x='Score', range_x=[-5, 50], color='Label')

# %%
px.scatter(train, x='Score', y='ViewCount', color='Label', log_y=True, marginal_y='box', range_x=[-20, 200])
