# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

        

import yfinance as yf
tickers = ['^GSPC','^DJI']

#^NSEI. , ^NSEBANK


for ticker in tickers:
    data = yf.download(tickers, start ='2021-5-24',end='2021-5-28', interval = '1m' )

data_csv = data.to_csv("tickers_1min_24_28_Mayl21.csv")

        
        
        
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# https://github.com/mayank-quant/options_and_python/blob/master/options_pricing_using_python.ipynb

# %%
# !pip install yfinance
import yfinance as yf

# %%
tickers = ['^NSEI','^NSEBANK','HDFCBANK.NS','ICICIBANK.NS','RELIANCE.NS','TCS.NS','KOTAKBANK.NS','SBIN.NS','HINDUNILVR.NS','INFY.NS','HDFC.NS']




for ticker in tickers:
    data = yf.download(tickers, start ='2021-5-24',end='2021-5-28', interval = '1m' )

data_csv = data.to_csv("N10ticker_1min_24_28_May21.csv")

# %% [markdown]
# # > > ****Natural Gas 1min data

# %%
start = '2021-4-26'
end = '2021-4-30'

# %%
ng = yf.download(tickers = 'NG=F', start='2021-5-24'
                                        , end = '2021-5-28',interval='1m')
ng = ng.to_csv("NG_24_28May21.csv")
ng

# %%
DowF = yf.download(tickers = 'YM=F', start='2021-4-1'
                                        , end = '2021-4-30',interval='5m')
#ng = ng.to_csv("NG_April21.csv")
DowF

# %% [markdown]
# > # Brent****

# %%
brent = yf.download(tickers = 'BZ=F', start='2021-5-24' , end = '2021-5-28',interval='1m')

brent = brent.to_csv("brent1m_24_28May21.csv")
brent

# %% [markdown]
# # VIX_CBOE 1min Data> ****

# %%
vix_cboe = yf.download(tickers = '^vvix', start='2021-4-1' , end = '2021-4-30',interval='5m')

#vix_cboe = vix_cboe.to_csv("vix_cboe_5min_April_21.csv")
vix_cboe

# %%
data
