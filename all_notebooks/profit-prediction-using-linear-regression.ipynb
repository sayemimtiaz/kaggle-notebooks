# %% [markdown]
# # Imports Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Import Dataset

# %%
df = pd.read_csv('../input/profit-prediction/Profit Prediction using Linear Regression.csv')

# %%
df

# %% [markdown]
# # Check Null Value

# %%
df.isnull().sum()

# %%
df.shape

# %% [markdown]
# # Separate dependent and independent variable

# %%
x = df.drop(['Profit'],axis = 1)
x

# %%
y = df['Profit']
y

# %% [markdown]
# # One hot encoding

# %%
city = pd.get_dummies(df['Area'])
city

# %%
merged = pd.concat([df,city],axis=1)
merged

# %%
 final = merged.drop(['Area'],axis=1)
 final

# %%
x = final.drop(['Profit'],axis=1)
x

# %% [markdown]
# # Split Data set

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.30,random_state=0)

# %%
xtest

# %%
ytest

# %% [markdown]
# # Fitting Multiple Linear Regression to the Training set

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

# %%
reg.fit(xtrain,ytrain)

# %%
ytest

# %%
pred = reg.predict(xtest)
pred

# %% [markdown]
# # Score

# %%
reg.score(xtest,ytest)

# %% [markdown]
# # R-Squared Value

# %%
from sklearn.metrics import r2_score
score = r2_score(ytest,pred)
score

# %%
diff = pd.DataFrame({'Actual Value':ytest,'Predict Value':pred,'Diffirence':ytest-pred})
diff
