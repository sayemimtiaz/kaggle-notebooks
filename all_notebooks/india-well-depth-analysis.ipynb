# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib import cm
from matplotlib.dates import date2num
from mpl_toolkits.basemap import Basemap

# %%
df=pd.read_csv('../input/ataljalyojana/Atal Jal 31 March 2021 .xlsx - Sheet1.csv')
df.head()

# %%
df.shape

# %%
df.State=df['State'].str.lower()

# %% [markdown]
# # VIsualising The Missing values using the histogram

# %%
df.isna().sum().plot(kind='bar',figsize=(15,10))

# %%
len(df.isna().sum())

# %% [markdown]
# # Other way to visualize the missing value are as

# %% [markdown]
# # Missingno - great tool to visualize the missing data

# %%
pip install missingno

# %%
import missingno as msno

# %% [markdown]
# # Matrix
# * the white lines indicate the missing values in each column.

# %%
msno.matrix(df)

# %%
msno.bar(df)

# %% [markdown]
# # Heatmap-
# * A value near -1 means if one variable appears then the other variable is very likely to be missing.
# * A value near 0 means there is no dependence between the occurrence of missing values of two variables.
# * A value near 1 means if one variable appears then the other variable is very likely to be present.

# %%
msno.heatmap(df)

# %%
df.describe()

# %% [markdown]
# * We can see that there are columns that have a minimum value of zero (0). On some columns, a value of zero does not make sense and indicates an invalid or missing value.
# * Missing values are frequently indicated by out-of-range entries; perhaps a negative number (e.g., -1) in a numeric field that is normally only positive, or a 0 in a numeric field that can never normally be 0.

# %%
df.isna().sum()

# %%
df.isna().sum().plot(kind='hist',figsize=(15,10))

# %%
df.isna().sum().plot(kind='pie',figsize=(15,15))

# %%
df.isna().sum().plot(kind='area', subplots=True,figsize=(15,10), legend=True, sort_columns=True)

# %%
df.isna().sum().plot(kind='hist',title="Missing value plots", subplots=True,figsize=(15,10), legend=True, stacked=True, sort_columns=True)

# %%
df.columns

# %% [markdown]
# # Linear Discrimant Analysis
# >Assumption
# * That your data is Gaussian, that each variable is is shaped like a bell curve when plotted.
# * That each attribute has the same variance, that values of each variable vary around the mean by the same amount on average.

# %%
plt.figure(figsize=(15,5))
df[['Pre_2015', 'Pst_2015']].plot.density()
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.histplot(x=df['Pre_2015'], stat="count", cumulative=False, common_bins=True, element="bars", bins=100
            ,kde=True)
plt.title("Pre_2015")

plt.subplot(2,1,2)
sns.histplot(x=df['Pst_2015'], stat="count", cumulative=False, common_bins=True, element="bars", bins=100
            ,kde=True)
plt.title("Pst_2015")

plt.show()

# %%
df.columns

# %%
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.kdeplot(x=df['Pre_2015'], hue=df['State'], shade=True)
            
plt.title("Pre_2015")

plt.subplot(2,1,2)
sns.kdeplot(x=df['Pst_2015'], hue=df['State'], shade=True)
            
plt.title("Pst_2015")

plt.show()

# %%
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.kdeplot(x=df['Pre_2016'], hue=df['State'], shade=True)
            
plt.title("Pre_2016")

plt.subplot(2,1,2)
sns.kdeplot(x=df['Pst_2016'], hue=df['State'], shade=True)
            
plt.title("Pst_2016")

plt.show()

# %%
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.kdeplot(x=df['Pre_2017'], hue=df['State'], shade=True)
            
plt.title("Pre_2017")

plt.subplot(2,1,2)
sns.kdeplot(x=df['Pst_2017'], hue=df['State'], shade=True)
            
plt.title("Pst_2017")

plt.show()

# %%
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.kdeplot(x=df['Pre_2018'], hue=df['State'], shade=True)
            
plt.title("Pre_2018")

plt.subplot(2,1,2)
sns.kdeplot(x=df['Pst_2018'], hue=df['State'], shade=True)
            
plt.title("Pst_2018")

plt.show()

# %%
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
sns.kdeplot(x=df['Pre_2019'], hue=df['State'], shade=True)
plt.grid(b=True, which='both', color='black')

            
plt.title("Pre_2019")

plt.subplot(2,1,2)
sns.kdeplot(x=df['Pst_2019'], hue=df['State'], shade=True)
plt.grid(b=True, which='both', color='black')

            
plt.title("Pst_2019")

plt.show()

# %%
df['State'].value_counts().plot(kind='bar', figsize=(10,10))
plt.grid(b=True, which='both', color='black')

# %%
df.loc[df.duplicated()]

# %%
df['State'].value_counts()

# %%
x=['maharashtra', 'haryana','rajasthan','karnataka','gujarat','uttar pradesh','madhya pradesh']
y=[699,614,387,299,272,198,187]
plt.figure(figsize=(10,10))
plt.barh(x, y)
plt.grid(b=True, which='both', color='black')

for index, value in enumerate(y):
    plt.text(value, index, str(value))

# %%
df.columns

# %%
df['District'].value_counts()

# %%
df_district_name=df.groupby('State')['District'].nunique()

# %%
df_district_name.plot(kind='bar', title="District counts in state", figsize=(10,10))
plt.grid(b=True, which='both', color='black')

# %%
df_district_name.sort_values()

# %%
x=['maharashtra', 'haryana','rajasthan','karnataka','gujarat','uttar pradesh','madhya pradesh']
y=[13,14,17,14,7,9,5]
plt.figure(figsize=(10,10))
plt.barh(x, y)
plt.grid(b=True, which='both', color='black')

for index, value in enumerate(y):
    plt.text(value, index, str(value))

# %%
df.columns

# %%
df_block_name=df.groupby(['State', 'District'], sort=True)['Block'].nunique()

# %%
df_water_table=df.groupby('State')['Well Depth'].value_counts()

# %%
fig = plt.figure(figsize=(10,10))
states=df.groupby('State')['Well Depth'].count().sort_values(ascending=True)
states.plot(kind='barh', fontsize=20)
plt.grid(b=True, which='both', color='black')
plt.xlabel("No of well cpunt in state")
plt.ylabel("State Name")
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
df_block_distric=df.groupby('State', sort=True)['Block'].count().sort_values(ascending=True)
df_block_distric.plot(kind='barh', fontsize=20)
plt.grid(b=True, which='both', color='black')
plt.xlabel("No of block count in state")
plt.ylabel("State Name")
plt.show()

# %%
from mpl_toolkits.basemap import Basemap
from numpy import array

# %%
df['Well Depth']=df['Well Depth'].replace(np.nan, 0)

# %%
df['Well Depth'].isnull().value_counts()

# %%
plt.subplots(figsize=(20, 15))
map = Basemap(width=1200000,height=900000,projection='lcc',resolution='l',
                    llcrnrlon=67,llcrnrlat=5,urcrnrlon=99,urcrnrlat=37,lat_0=28,lon_0=77)

map.drawmapboundary ()
map.drawcountries ()
map.drawcoastlines ()

lg=array(df['Longitude'])
lt=array(df['Latitude'])
pt=array(df['Well Depth'])
nc=array(df['State'])

x, y = map(lg, lt)
well_depth = df['Well Depth'].apply(lambda x: int(x))
#plt.scatter(x, y, s=well_depth, marker="o", c=population_sizes ,cmap=cm.Dark2, alpha=0.7)
plt.scatter(x, y,marker='o')

for ncs, xpt, ypt in zip(nc, x, y):
    plt.text(xpt+60000, ypt+30000, ncs, fontsize=10, fontweight='bold')

plt.title('Indian State with water table',fontsize=20)

# %%
plt.subplots(figsize=(20, 15))
map = Basemap(width=1200000,height=900000,projection='lcc',resolution='l',
                    llcrnrlon=67,llcrnrlat=5,urcrnrlon=99,urcrnrlat=37,lat_0=28,lon_0=77)
map.drawmapboundary ()
map.drawcountries ()
map.drawcoastlines ()


lg=array(df['Longitude'])
lt=array(df['Latitude'])
pt=array(df['Well Depth'])

x, y = map(lg, lt)
well_depth = df['Well Depth'].apply(lambda x: int(x))
plt.scatter(x, y,s=well_depth,marker='o', cmap=cm.Dark2_r)

for pts, xpt, ypt in zip(x, y):
    plt.text(xpt+60000, ypt+30000, fontsize=10, fontweight='bold')

# %%
plt.subplots(figsize=(20, 15))
map = Basemap(width=1200000,height=900000,projection='lcc',resolution='l',
                    llcrnrlon=67,llcrnrlat=5,urcrnrlon=99,urcrnrlat=37,lat_0=28,lon_0=77)
map.drawmapboundary ()
map.drawcountries ()
map.drawcoastlines ()


lg=array(df['Longitude'])
lt=array(df['Latitude'])
pt=array(df['Well Depth'])

x, y = map(lg, lt)
well_depth = df['Well Depth'].apply(lambda x: int(x))
plt.scatter(x, y,s=well_depth,marker='*', cmap=cm.Dark2, linewidths=3)
plt.title("Map of India with Longitute and Latitude ")

# %%
import plotly.express as px

# %%
plt.subplots(figsize=(20, 15))
map = Basemap(width=1200000,height=900000,projection='lcc',resolution='l',
                    llcrnrlon=67,llcrnrlat=5,urcrnrlon=99,urcrnrlat=37,lat_0=28,lon_0=77)
map.drawmapboundary ()
map.drawcountries ()
map.drawcoastlines ()


lg=array(df['Longitude'])
lt=array(df['Latitude'])
pt=array(df['Well Depth'])

x, y = map(lg, lt)

#fig=px.scatter(x=x, y=y)
fig=px.scatter_3d()
fig.show()

# %%
plt.subplots(figsize=(20, 15))
map = Basemap(width=1200000,height=900000,projection='lcc',resolution='l',
                    llcrnrlon=67,llcrnrlat=5,urcrnrlon=99,urcrnrlat=37,lat_0=28,lon_0=77)
map.drawmapboundary ()
map.drawcountries ()
map.drawcoastlines ()

plt.scatter(x=df['Longitude'], y=df['Latitude'])
plt.show()

# %%
df.info()

# %%
print("The Top 10 Cities sorted according to the Total Population (Descending Order)")
top_pop_cities = df.sort_values(by='Well Depth',ascending=False)
top10_pop_village=df.head(10)
top10_pop_village

# %%
plt.subplots(figsize=(20, 15))
map = Basemap(width=1200000,height=900000,projection='lcc',resolution='l',
                    llcrnrlon=67,llcrnrlat=5,urcrnrlon=99,urcrnrlat=37,lat_0=28,lon_0=77)

map.drawmapboundary ()
map.drawcountries ()
map.drawcoastlines ()

lg=array(top10_pop_village['Longitude'])
lt=array(top10_pop_village['Latitude'])
pt=array(top10_pop_village['Well Depth'])
#nc=array(top10_pop_cities['name_of_city'])

x, y = map(lg, lt)
well_depth = top10_pop_village["Well Depth"].apply(lambda x: int(x))
plt.scatter(x, y, s=well_depth, marker="o")

# %%
df['State'].value_counts()

# %% [markdown]
# # PLotting Location of Well of Gujrat on Map

# %%
df_gujrat=df[df['State']=='gujarat']

# %%
plt.subplots(figsize=(20, 15))
map = Basemap(width=1200000,height=900000,projection='lcc',resolution='l',
                    llcrnrlon=67,llcrnrlat=5,urcrnrlon=99,urcrnrlat=37,lat_0=28,lon_0=77)

map.drawmapboundary ()
map.drawcountries ()
map.drawcoastlines ()

lg=array(df_gujrat['Longitude'])
lt=array(df_gujrat['Latitude'])
pt=array(df_gujrat['Well Depth'])
#nc=array(top10_pop_cities['name_of_city'])

x, y = map(lg, lt)
well_depth = df_gujrat["Well Depth"].apply(lambda x: int(x))
plt.scatter(x, y, s=well_depth, marker="o")

# %%
plt.subplots(figsize=(20, 20))
map = Basemap(width=1200000,height=900000,projection='lcc',resolution='l',
                    llcrnrlon=67,llcrnrlat=5,urcrnrlon=99,urcrnrlat=37,lat_0=28,lon_0=77)

map.drawmapboundary ()
map.drawcountries ()
map.drawcoastlines ()

lg=array(df_gujrat['Longitude'])
lt=array(df_gujrat['Latitude'])
pt=array(df_gujrat['Well Depth'])
#nc=array(top10_pop_cities['name_of_city'])

x, y = map(lg, lt)
well_depth = df_gujrat["Well Depth"].apply(lambda x: int(x))
plt.scatter(x, y, s=well_depth, marker="o", cmap='Reds', linewidths=1) 
plt.title("Well Location on Gujrat")
plt.show()

# %% [markdown]
# # PLotting Location of Well of Maharastra on Map

# %%
df_maharastra=df[df['State']=='maharashtra']

# %%
plt.subplots(figsize=(20, 20))
map = Basemap(width=1200000,height=900000,projection='lcc',resolution='l',
                    llcrnrlon=67,llcrnrlat=5,urcrnrlon=99,urcrnrlat=37,lat_0=28,lon_0=77)

map.drawmapboundary ()
map.drawcountries ()
map.drawcoastlines ()

lg=array(df_maharastra['Longitude'])
lt=array(df_maharastra['Latitude'])
pt=array(df_maharastra['Well Depth'])
#nc=array(top10_pop_cities['name_of_city'])

x, y = map(lg, lt)
well_depth = df_maharastra["Well Depth"].apply(lambda x: int(x))
plt.scatter(x, y, s=well_depth, marker="o", cmap='Reds', linewidths=1) 
plt.title("Well Location on Maharatrs")
plt.show()

# %% [markdown]
# # PLotting Location of Well of Rajasthan on Map

# %%
df_rajasthan=df[df['State']=='rajasthan']

# %%
plt.subplots(figsize=(20, 20))
map = Basemap(width=1200000,height=900000,projection='lcc',resolution='l',
                    llcrnrlon=67,llcrnrlat=5,urcrnrlon=99,urcrnrlat=37,lat_0=28,lon_0=77)

map.drawmapboundary ()
map.drawcountries ()
map.drawcoastlines ()

lg=array(df_rajasthan['Longitude'])
lt=array(df_rajasthan['Latitude'])
pt=array(df_rajasthan['Well Depth'])
#nc=array(top10_pop_cities['name_of_city'])

x, y = map(lg, lt)
well_depth = df_rajasthan["Well Depth"].apply(lambda x: int(x))
plt.scatter(x, y, s=well_depth, marker="o", cmap='Reds', linewidths=1) 
plt.title("Well Location on Rajastan")
plt.show()

# %% [markdown]
# # PLotting Location of Well of U.P on Map

# %%
df_up=df[df['State']=='uttar pradesh']

# %%
plt.subplots(figsize=(20, 20))
map = Basemap(width=1200000,height=900000,projection='lcc',resolution='l',
                    llcrnrlon=67,llcrnrlat=5,urcrnrlon=99,urcrnrlat=37,lat_0=28,lon_0=77)

map.drawmapboundary ()
map.drawcountries ()
map.drawcoastlines ()

lg=array(df_up['Longitude'])
lt=array(df_up['Latitude'])
pt=array(df_up['Well Depth'])
#nc=array(top10_pop_cities['name_of_city'])

x, y = map(lg, lt)
well_depth = df_up["Well Depth"].apply(lambda x: int(x))
plt.scatter(x, y, s=well_depth, marker="o", cmap='Reds', linewidths=1) 
plt.title("Well Location on U.P")
plt.show()

# %%
df['State'].value_counts()

# %% [markdown]
# # Well depth Analysing M.P

# %%
df_mp=df[df['State']=='madhya pradesh']

# %%
plt.subplots(figsize=(20, 20))
map = Basemap(width=1200000,height=900000,projection='lcc',resolution='l',
                    llcrnrlon=67,llcrnrlat=5,urcrnrlon=99,urcrnrlat=37,lat_0=28,lon_0=77)

map.drawmapboundary ()
map.drawcountries ()
map.drawcoastlines ()

lg=array(df_mp['Longitude'])
lt=array(df_mp['Latitude'])
pt=array(df_mp['Well Depth'])
#nc=array(top10_pop_cities['name_of_city'])

x, y = map(lg, lt)
well_depth = df_mp["Well Depth"].apply(lambda x: int(x))
plt.scatter(x, y, s=well_depth, marker="o", cmap='Reds', linewidths=1) 
plt.title("Well Location on M.P")
plt.show()

# %% [markdown]
# # Well depth Analysis of Karnataka

# %%
df_kar=df[df['State']=='karnataka']

# %%
plt.subplots(figsize=(20, 20))
map = Basemap(width=1200000,height=900000,projection='lcc',resolution='l',
                    llcrnrlon=67,llcrnrlat=5,urcrnrlon=99,urcrnrlat=37,lat_0=28,lon_0=77)

map.drawmapboundary ()
map.drawcountries ()
map.drawcoastlines ()

lg=array(df_kar['Longitude'])
lt=array(df_kar['Latitude'])
pt=array(df_kar['Well Depth'])
#nc=array(top10_pop_cities['name_of_city'])

x, y = map(lg, lt)
well_depth = df_kar["Well Depth"].apply(lambda x: int(x))
plt.scatter(x, y, s=well_depth, marker="o", cmap='Reds', linewidths=1) 
plt.title("Well Location on Kernataka")
plt.show()

# %% [markdown]
# # Well depth analysis for all state in India

# %%
def plot_map(sizes, colorbarValue):

    plt.figure(figsize=(19,20))
    f, ax = plt.subplots(figsize=(19, 20))

    # Setting up Basemap
    map = Basemap(width=5000000, height=3500000, resolution='l', projection='aea', llcrnrlon=69,
                  llcrnrlat=6, urcrnrlon=99, urcrnrlat=36, lon_0=78, lat_0=20, ax=ax)
                  
    # draw map boundaries
    map.drawmapboundary()
    map.drawcountries()
    map.drawcoastlines()

    # plotting cities on map using previously derived coordinates
    x, y = map(array(df["Longitude"]), array(df["Latitude"]))
    cs = map.scatter(x, y, s=sizes, marker="o" ,c=sizes, cmap=cm.Dark2, alpha=0.5)

    # adding colorbar
    cbar = map.colorbar(cs, location='right',pad="5%")
    cbar.ax.set_yticklabels(colorbarValue)

    plt.show()

# %%
well_sizes = df["Well Depth"].apply(lambda x: int(x))
colorbarValue = np.linspace(df["Well Depth"].min(), df["Well Depth"].max(), 
                            num=10)
colorbarValue = colorbarValue.astype(int)

plot_map(well_sizes, colorbarValue)

# %% [markdown]
# # Well Depth Analysis of Maharastra state

# %%
len(df_maharastra)

# %%
def plot_map(sizes, colorbarValue):

    plt.figure(figsize=(19,20))
    f, ax = plt.subplots(figsize=(19, 20))

    # Setting up Basemap
    map = Basemap(width=5000000, height=3500000, resolution='l', projection='aea', llcrnrlon=69,
                  llcrnrlat=6, urcrnrlon=99, urcrnrlat=36, lon_0=78, lat_0=20, ax=ax)
                  
    # draw map boundaries
    map.drawmapboundary()
    map.drawcountries()
    map.drawcoastlines()

    # plotting cities on map using previously derived coordinates
    x, y = map(array(df_maharastra["Longitude"]), array(df_maharastra["Latitude"]))
    cs = map.scatter(x, y, s=sizes, marker="o" ,c=sizes, cmap=cm.Dark2, alpha=0.5)

    # adding colorbar
    cbar = map.colorbar(cs, location='right',pad="5%")
    cbar.ax.set_yticklabels(colorbarValue)

    plt.show()

# %%
well_sizes = df_maharastra["Well Depth"].apply(lambda x: int(x))
colorbarValue = np.linspace(df_maharastra["Well Depth"].min(), df_maharastra["Well Depth"].max(), 
                            num=10)
colorbarValue = colorbarValue.astype(int)

plot_map(well_sizes, colorbarValue)

# %% [markdown]
# # Well Depth Analysis of Gujarat

# %%
def plot_map(sizes, colorbarValue):

    plt.figure(figsize=(19,20))
    f, ax = plt.subplots(figsize=(19, 20))

    # Setting up Basemap
    map = Basemap(width=5000000, height=3500000, resolution='l', projection='aea', llcrnrlon=69,
                  llcrnrlat=6, urcrnrlon=99, urcrnrlat=36, lon_0=78, lat_0=20, ax=ax)
                  
    # draw map boundaries
    map.drawmapboundary()
    map.drawcountries()
    map.drawcoastlines()

    # plotting cities on map using previously derived coordinates
    x, y = map(array(df_gujrat["Longitude"]), array(df_gujrat["Latitude"]))
    cs = map.scatter(x, y, s=sizes, marker="o" ,c=sizes, cmap=cm.Dark2, alpha=0.5)

    # adding colorbar
    cbar = map.colorbar(cs, location='right',pad="5%")
    cbar.ax.set_yticklabels(colorbarValue)

    plt.show()

# %%
well_sizes = df_gujrat["Well Depth"].apply(lambda x: int(x))
colorbarValue = np.linspace(df_gujrat["Well Depth"].min(), df_gujrat["Well Depth"].max(), 
                            num=10)
colorbarValue = colorbarValue.astype(int)

plot_map(well_sizes, colorbarValue)

# %% [markdown]
# # Well Depth Analysis of UP

# %%
def plot_map(sizes, colorbarValue):

    plt.figure(figsize=(19,20))
    f, ax = plt.subplots(figsize=(19, 20))

    # Setting up Basemap
    map = Basemap(width=5000000, height=3500000, resolution='l', projection='aea', llcrnrlon=69,
                  llcrnrlat=6, urcrnrlon=99, urcrnrlat=36, lon_0=78, lat_0=20, ax=ax)
                  
    # draw map boundaries
    map.drawmapboundary()
    map.drawcountries()
    map.drawcoastlines()

    # plotting cities on map using previously derived coordinates
    x, y = map(array(df_up["Longitude"]), array(df_up["Latitude"]))
    cs = map.scatter(x, y, s=sizes, marker="o" ,c=sizes, cmap=cm.Dark2, alpha=0.5)

    # adding colorbar
    cbar = map.colorbar(cs, location='right',pad="5%")
    cbar.ax.set_yticklabels(colorbarValue)

    plt.show()

# %%
well_sizes = df_up["Well Depth"].apply(lambda x: int(x))
colorbarValue = np.linspace(df_up["Well Depth"].min(), df_up["Well Depth"].max(), 
                            num=10)
colorbarValue = colorbarValue.astype(int)

plot_map(well_sizes, colorbarValue)

# %% [markdown]
# # Well Depth Analysis of MP

# %%
def plot_map(sizes, colorbarValue):

    plt.figure(figsize=(19,20))
    f, ax = plt.subplots(figsize=(19, 20))

    # Setting up Basemap
    map = Basemap(width=5000000, height=3500000, resolution='l', projection='aea', llcrnrlon=69,
                  llcrnrlat=6, urcrnrlon=99, urcrnrlat=36, lon_0=78, lat_0=20, ax=ax)
                  
    # draw map boundaries
    map.drawmapboundary()
    map.drawcountries()
    map.drawcoastlines()

    # plotting cities on map using previously derived coordinates
    x, y = map(array(df_mp["Longitude"]), array(df_mp["Latitude"]))
    cs = map.scatter(x, y, s=sizes, marker="o" ,c=sizes, cmap=cm.Dark2, alpha=0.5)

    # adding colorbar
    cbar = map.colorbar(cs, location='right',pad="5%")
    cbar.ax.set_yticklabels(colorbarValue)

    plt.show()

# %%
well_sizes = df_mp["Well Depth"].apply(lambda x: int(x))
colorbarValue = np.linspace(df_mp["Well Depth"].min(), df_mp["Well Depth"].max(), 
                            num=10)
colorbarValue = colorbarValue.astype(int)

plot_map(well_sizes, colorbarValue)

# %% [markdown]
# # Well Depth Analysis of Karnataka

# %%
def plot_map(sizes, colorbarValue):

    plt.figure(figsize=(19,20))
    f, ax = plt.subplots(figsize=(19, 20))

    # Setting up Basemap
    map = Basemap(width=5000000, height=3500000, resolution='l', projection='aea', llcrnrlon=69,
                  llcrnrlat=6, urcrnrlon=99, urcrnrlat=36, lon_0=78, lat_0=20, ax=ax)
                  
    # draw map boundaries
    map.drawmapboundary()
    map.drawcountries()
    map.drawcoastlines()

    # plotting cities on map using previously derived coordinates
    x, y = map(array(df_kar["Longitude"]), array(df_kar["Latitude"]))
    cs = map.scatter(x, y, s=sizes, marker="o" ,c=sizes, cmap=cm.Dark2, alpha=0.5)

    # adding colorbar
    cbar = map.colorbar(cs, location='right',pad="5%")
    cbar.ax.set_yticklabels(colorbarValue)

    plt.show()

# %%
well_sizes = df_kar["Well Depth"].apply(lambda x: int(x))
colorbarValue = np.linspace(df_kar["Well Depth"].min(), df_kar["Well Depth"].max(), 
                            num=10)
colorbarValue = colorbarValue.astype(int)

plot_map(well_sizes, colorbarValue)

# %% [markdown]
# # Well Depth Analysis of Haryana

# %%
df_har=df[df['State']=='haryana']

# %%
def plot_map(sizes, colorbarValue):

    plt.figure(figsize=(19,20))
    f, ax = plt.subplots(figsize=(19, 20))

    # Setting up Basemap
    map = Basemap(width=5000000, height=3500000, resolution='l', projection='aea', llcrnrlon=69,
                  llcrnrlat=6, urcrnrlon=99, urcrnrlat=36, lon_0=78, lat_0=20, ax=ax)
                  
    # draw map boundaries
    map.drawmapboundary()
    map.drawcountries()
    map.drawcoastlines()

    # plotting cities on map using previously derived coordinates
    x, y = map(array(df_har["Longitude"]), array(df_har["Latitude"]))
    cs = map.scatter(x, y, s=sizes, marker="o" ,c=sizes, cmap=cm.Dark2, alpha=0.5)

    # adding colorbar
    cbar = map.colorbar(cs, location='right',pad="5%")
    cbar.ax.set_yticklabels(colorbarValue)

    plt.show()

# %%
well_sizes = df_har["Well Depth"].apply(lambda x: int(x))
colorbarValue = np.linspace(df_har["Well Depth"].min(), df_har["Well Depth"].max(), 
                            num=10)
colorbarValue = colorbarValue.astype(int)

plot_map(well_sizes, colorbarValue)
