# %% [markdown]
# # Fake or Not
# ![](https://insights.ehotelier.com/wp-content/uploads/sites/6/2018/05/Real-not-fake.jpg)
#
# This Notebook will Classify Whether News Is Fake Or Not Using Diffrent Techniques

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree

# %% [markdown]
# # Reading Data

# %%
path1="../input/fake-and-real-news-dataset/Fake.csv"
path2="../input/fake-and-real-news-dataset/True.csv"

# %%
df=pd.read_csv(path1,encoding='latin')

# %% [markdown]
# Let's create a new column Named Class which is fake news and target is 0

# %%
df['class']=0

# %%
df

# %%
df1=pd.read_csv(path2,encoding='latin')
df1

# %% [markdown]
# Let's create a new column Named Class which is real news and target is 1

# %%
df1['class']=1

# %%
df1

# %% [markdown]
# Now merging two dataframes both fake and real

# %%
data=pd.concat([df1,df],axis=0)

# %%
data

# %% [markdown]
# We Don't Need title ,subject ,date as we need to keep our input simple

# %%
data=data.drop(['title','subject','date'],axis=1)

# %%
data

# %% [markdown]
# Let's Find wether our dataframe contains any null values or not?

# %%
data.isnull().sum()

# %%
sns.countplot(data['class'])

# %% [markdown]
# So,Our DataSet is Balanced

# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
import re
import string

# %% [markdown]
# # DATA CLEANING

# %% [markdown]
# **This is an function which will convert word in lower case, get rid of extra spaces, and url links**

# %%
def wordopt(text):
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub("\\W"," ",text) # remove special chars
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    
    return text

# %%
data['text']=data['text'].apply(wordopt)

# %%
data

# %%
x=data['text']

# %%
df=data

# %%
y=data['class']

# %% [markdown]
# # Splitting Our Data

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %% [markdown]
# # Converting text to vectors

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
xv_train = vectorizer.fit_transform(x_train)
xv_test=vectorizer.transform(x_test)

# %% [markdown]
# # Applying Logistic Regression

# %%
LR=LogisticRegression()

# %%
LR.fit(xv_train,y_train)

# %%
pred=LR.predict(xv_test)

# %%
LR.score(xv_test,y_test)

# %% [markdown]
# **For Logistic Regression ,We get Accuracy of 98%**

# %% [markdown]
# # Applying Decision Tree Classification

# %%
DTC = tree.DecisionTreeClassifier()
DTC.fit(xv_train, y_train)

# %%
DTC.score(xv_test,y_test)

# %% [markdown]
# **For Logistic Regression ,We get Accuracy of 99%**
