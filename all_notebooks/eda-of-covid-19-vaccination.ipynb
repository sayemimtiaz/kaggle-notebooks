# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../input/covid-world-vaccination-progress/country_vaccinations.csv')
df

# %%
df.shape

# %%
df.isnull().sum()

# %%
#dropping the unnecessary columns
df.drop(['iso_code','source_name','source_website'],  axis='columns' ,inplace=True)

# %%
df.columns

# %%
df.info()

# %%
#filling the nan value with 0(Zero)
df.fillna(0, inplace=True)

# %%
#checking is there is any nan vlaue
df.isnull().sum()

# %%
df.head()

# %%
df['date']=pd.to_datetime(df['date'], format = '%Y-%m-%d')

# %%
df.info()

# %%
df['vaccines'].unique()

# %%
df['vaccines'].nunique()

# %% [markdown]
# That means there are 24 different type of vaccine used in this dataset in different country.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.figure(figsize=(25,25))
sns.barplot(df['total_vaccinations'],df['country'])
plt.title('Country VS Total Vaccination', fontsize=20)
plt.xlabel('Total Vaccination', fontsize=20)
plt.ylabel('Country', fontsize=20)

# %% [markdown]
# # which vaccine in which country and some statistical data for each vaccine.

# %% [markdown]
# ## Pfizer/BioNTech

# %%
df_Pfizer_BioNTech=df[df['vaccines']=='Pfizer/BioNTech']

# %%
df_Pfizer_BioNTech.shape[0]

# %%
df_Pfizer_BioNTech['vaccines'].unique()

# %%
df_Pfizer_BioNTech=df_Pfizer_BioNTech.sort_values(by='total_vaccinations', ascending=False)
df_Pfizer_BioNTech.head(10)

# %%
df_Pfizer_BioNTech.groupby(['country']).agg(['max','min','mean'])

# %%
plt.figure(figsize=(25,25))
sns.barplot(df_Pfizer_BioNTech['total_vaccinations'],df_Pfizer_BioNTech['country'])
plt.title('Country VS Total Vaccination', fontsize=20)
plt.xlabel('Total Vaccination', fontsize=20)
plt.ylabel('Country', fontsize=20)

# %%
plt.figure(figsize=(25,25))
sns.barplot(df_Pfizer_BioNTech['people_vaccinated'],df_Pfizer_BioNTech['country'])
plt.title('Country VS People Vaccinated', fontsize=20)
plt.xlabel('People Vaccinated', fontsize=20)
plt.ylabel('Country', fontsize=20)

# %%
plt.figure(figsize=(25,25))
sns.barplot(df_Pfizer_BioNTech['people_fully_vaccinated'],df_Pfizer_BioNTech['country'])
plt.title('Country VS People Fully Vaccinated', fontsize=20)
plt.xlabel('People Fully Vaccinated', fontsize=20)
plt.ylabel('Country', fontsize=20)

# %%
plt.figure(figsize=(25,25))
sns.barplot(df_Pfizer_BioNTech['daily_vaccinations_raw'],df_Pfizer_BioNTech['country'])
plt.title('Country VS Daily Vaccinations Raw', fontsize=20)
plt.xlabel('Daily Vaccinations Raw', fontsize=20)
plt.ylabel('Country', fontsize=20)

# %%
plt.figure(figsize=(25,25))
sns.barplot(df_Pfizer_BioNTech['daily_vaccinations'],df_Pfizer_BioNTech['country'])
plt.title('Country VS daily_vaccinations', fontsize=20)
plt.xlabel('daily_vaccinations', fontsize=20)
plt.ylabel('Country', fontsize=20)

# %%
plt.figure(figsize=(25,25))
sns.barplot(df_Pfizer_BioNTech['total_vaccinations_per_hundred'],df_Pfizer_BioNTech['country'])
plt.title('Country VS total_vaccinations_per_hundred', fontsize=20)
plt.xlabel('total_vaccinations_per_hundred', fontsize=20)
plt.ylabel('Country', fontsize=20)

# %%
plt.figure(figsize=(25,25))
sns.barplot(df_Pfizer_BioNTech['people_vaccinated_per_hundred'],df_Pfizer_BioNTech['country'])
plt.title('Country VS people_vaccinated_per_hundred', fontsize=20)
plt.xlabel('people_vaccinated_per_hundred', fontsize=20)
plt.ylabel('Country', fontsize=20)

# %%
plt.figure(figsize=(25,25))
sns.barplot(df_Pfizer_BioNTech['people_fully_vaccinated_per_hundred'],df_Pfizer_BioNTech['country'])
plt.title('Country VS people_fully_vaccinated_per_hundred', fontsize=20)
plt.xlabel('people_fully_vaccinated_per_hundred', fontsize=20)
plt.ylabel('Country', fontsize=20)

# %%
plt.figure(figsize=(25,25))
sns.barplot(df_Pfizer_BioNTech['daily_vaccinations_per_million'],df_Pfizer_BioNTech['country'])
plt.title('Country VS daily_vaccinations_per_million', fontsize=20)
plt.xlabel('daily_vaccinations_per_million', fontsize=20)
plt.ylabel('Country', fontsize=20)

# %% [markdown]
# ## Sputnik V

# %%
df_Sputnik_V=df[df['vaccines']=='Sputnik V']
df_Sputnik_V.shape[0]

# %%
df_Sputnik_V['vaccines'].unique()

# %%
df_Sputnik_V=df_Sputnik_V.sort_values(by='total_vaccinations', ascending=False)
df_Sputnik_V.head(10)

# %%
df_Sputnik_V.groupby('country').agg(['max','min','mean'])

# %%
plt.figure(figsize=(10,5))
sns.barplot(df_Sputnik_V['total_vaccinations'],df_Sputnik_V['country'])
plt.title('Country VS Total Vaccination', fontsize=20)
plt.xlabel('Total Vaccination', fontsize=20)
plt.ylabel('Country', fontsize=20)

# %%
plt.figure(figsize=(10,5))
sns.barplot(df_Sputnik_V['people_vaccinated'],df_Sputnik_V['country'])
plt.title('Country VS People Vaccinated', fontsize=20)
plt.xlabel('People Vaccinated', fontsize=20)
plt.ylabel('Country', fontsize=20)

# %%
plt.figure(figsize=(10,5))
sns.barplot(df_Sputnik_V['people_fully_vaccinated'],df_Sputnik_V['country'])
plt.title('Country VS People Fully Vaccinated', fontsize=20)
plt.xlabel('People Fully Vaccinated', fontsize=20)
plt.ylabel('Country', fontsize=20)

# %%
plt.figure(figsize=(10,5))
sns.barplot(df_Sputnik_V['daily_vaccinations_raw'],df_Sputnik_V['country'])
plt.title('Country VS Daily Vaccinations Raw', fontsize=20)
plt.xlabel('Daily Vaccinations Raw', fontsize=20)
plt.ylabel('Country', fontsize=20)

# %%
plt.figure(figsize=(10,5))
sns.barplot(df_Sputnik_V['daily_vaccinations'],df_Sputnik_V['country'])
plt.title('Country VS daily_vaccinations', fontsize=20)
plt.xlabel('daily_vaccinations', fontsize=20)
plt.ylabel('Country', fontsize=20)

# %%
plt.figure(figsize=(10,5))
sns.barplot(df_Sputnik_V['total_vaccinations_per_hundred'],df_Sputnik_V['country'])
plt.title('Country VS total_vaccinations_per_hundred', fontsize=20)
plt.xlabel('total_vaccinations_per_hundred', fontsize=20)
plt.ylabel('Country', fontsize=20)

# %%
plt.figure(figsize=(10,5))
sns.barplot(df_Sputnik_V['people_vaccinated_per_hundred'],df_Sputnik_V['country'])
plt.title('Country VS people_vaccinated_per_hundred', fontsize=20)
plt.xlabel('people_vaccinated_per_hundred', fontsize=20)
plt.ylabel('Country', fontsize=20)

# %%
plt.figure(figsize=(10,5))
sns.barplot(df_Sputnik_V['people_fully_vaccinated_per_hundred'],df_Sputnik_V['country'])
plt.title('Country VS people_fully_vaccinated_per_hundred', fontsize=20)
plt.xlabel('people_fully_vaccinated_per_hundred', fontsize=20)
plt.ylabel('Country', fontsize=20)

# %%
plt.figure(figsize=(10,5))
sns.barplot(df_Sputnik_V['daily_vaccinations_per_million'],df_Sputnik_V['country'])
plt.title('Country VS daily_vaccinations_per_million', fontsize=20)
plt.xlabel('daily_vaccinations_per_million', fontsize=20)
plt.ylabel('Country', fontsize=20)

# %% [markdown]
# ## Oxford/AstraZeneca

# %%
df_Oxford_AstraZeneca=df[df['vaccines']=='Oxford/AstraZeneca']
df_Oxford_AstraZeneca.shape[0]

# %%
df_Oxford_AstraZeneca['vaccines'].unique()

# %%
df_Oxford_AstraZeneca=df_Oxford_AstraZeneca.sort_values(by='total_vaccinations', ascending=False)
df_Oxford_AstraZeneca.head(10)

# %%
df_Oxford_AstraZeneca.groupby('country').agg(['max','min','mean'])

# %%
plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca['total_vaccinations'],df_Oxford_AstraZeneca['country'])
plt.title('Country VS Total Vaccination', fontsize=20)
plt.xlabel('Total Vaccination', fontsize=20)
plt.ylabel('Country', fontsize=20)

# %%
plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca['people_vaccinated'],df_Oxford_AstraZeneca['country'])
plt.title('Country VS People Vaccinated', fontsize=20)
plt.xlabel('People Vaccinated', fontsize=20)
plt.ylabel('Country', fontsize=20)

# %%
plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca['people_fully_vaccinated'],df_Oxford_AstraZeneca['country'])
plt.title('Country VS People Fully Vaccinated', fontsize=20)
plt.xlabel('People Fully Vaccinated', fontsize=20)
plt.ylabel('Country', fontsize=20)

# %%
plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca['daily_vaccinations_raw'],df_Oxford_AstraZeneca['country'])
plt.title('Country VS Daily Vaccinations Raw', fontsize=20)
plt.xlabel('Daily Vaccinations Raw', fontsize=20)
plt.ylabel('Country', fontsize=20)

# %%
plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca['daily_vaccinations'],df_Oxford_AstraZeneca['country'])
plt.title('Country VS daily_vaccinations', fontsize=20)
plt.xlabel('daily_vaccinations', fontsize=20)
plt.ylabel('Country', fontsize=20)

# %%
plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca['total_vaccinations_per_hundred'],df_Oxford_AstraZeneca['country'])
plt.title('Country VS total_vaccinations_per_hundred', fontsize=20)
plt.xlabel('total_vaccinations_per_hundred', fontsize=20)
plt.ylabel('Country', fontsize=20)

# %%
plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca['people_vaccinated_per_hundred'],df_Oxford_AstraZeneca['country'])
plt.title('Country VS people_vaccinated_per_hundred', fontsize=20)
plt.xlabel('people_vaccinated_per_hundred', fontsize=20)
plt.ylabel('Country', fontsize=20)

# %%
plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca['people_fully_vaccinated_per_hundred'],df_Oxford_AstraZeneca['country'])
plt.title('Country VS people_fully_vaccinated_per_hundred', fontsize=20)
plt.xlabel('people_fully_vaccinated_per_hundred', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca['daily_vaccinations_per_million'],df_Oxford_AstraZeneca['country'])
plt.title('Country VS daily_vaccinations_per_million', fontsize=20)
plt.xlabel('daily_vaccinations_per_million', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()

# %% [markdown]
# ## Moderna, Oxford/AstraZeneca, Pfizer/BioNTech

# %%
df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech=df[df['vaccines']=='Moderna, Oxford/AstraZeneca, Pfizer/BioNTech']
df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech.shape[0]

# %%
df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech['vaccines'].unique()

# %%
df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech=df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech.sort_values(by='total_vaccinations', ascending=False)
df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech.head(10)

# %%
df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech.groupby('country').agg(['max','min','mean'])

# %%
plt.figure(figsize=(10,5))
sns.barplot(df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech['total_vaccinations'],df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech['country'])
plt.title('Country VS Total Vaccination', fontsize=20)
plt.xlabel('Total Vaccination', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech['people_vaccinated'],df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech['country'])
plt.title('Country VS People Vaccinated', fontsize=20)
plt.xlabel('People Vaccinated', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()



plt.figure(figsize=(10,5))
sns.barplot(df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech['people_fully_vaccinated'],df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech['country'])
plt.title('Country VS People Fully Vaccinated', fontsize=20)
plt.xlabel('People Fully Vaccinated', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech['daily_vaccinations_raw'],df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech['country'])
plt.title('Country VS Daily Vaccinations Raw', fontsize=20)
plt.xlabel('Daily Vaccinations Raw', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech['daily_vaccinations'],df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech['country'])
plt.title('Country VS daily_vaccinations', fontsize=20)
plt.xlabel('daily_vaccinations', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()



plt.figure(figsize=(10,5))
sns.barplot(df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech['total_vaccinations_per_hundred'],df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech['country'])
plt.title('Country VS total_vaccinations_per_hundred', fontsize=20)
plt.xlabel('total_vaccinations_per_hundred', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech['people_vaccinated_per_hundred'],df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech['country'])
plt.title('Country VS people_vaccinated_per_hundred', fontsize=20)
plt.xlabel('people_vaccinated_per_hundred', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech['people_fully_vaccinated_per_hundred'],df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech['country'])
plt.title('Country VS people_fully_vaccinated_per_hundred', fontsize=20)
plt.xlabel('people_fully_vaccinated_per_hundred', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech['daily_vaccinations_per_million'],df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech['country'])
plt.title('Country VS daily_vaccinations_per_million', fontsize=20)
plt.xlabel('daily_vaccinations_per_million', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()

# %% [markdown]
# ## Oxford/AstraZeneca, Pfizer/BioNTech

# %%
df_Oxford_AstraZeneca_Sputnik_V=df[df['vaccines']=='Oxford/AstraZeneca, Pfizer/BioNTech']
df_Oxford_AstraZeneca_Sputnik_V.shape[0]

# %%
df_Oxford_AstraZeneca_Sputnik_V['vaccines'].unique()

# %%
df_Oxford_AstraZeneca_Sputnik_V=df_Oxford_AstraZeneca_Sputnik_V.sort_values(by='total_vaccinations', ascending=False)
df_Oxford_AstraZeneca_Sputnik_V.head(10)

# %%
df_Oxford_AstraZeneca_Sputnik_V.groupby('country').agg(['max','min','mean'])

# %%
#plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca_Sputnik_V['total_vaccinations'],df_Oxford_AstraZeneca_Sputnik_V['country'])
plt.title('Country VS Total Vaccination')
plt.xlabel('Total Vaccination')
plt.ylabel('Country')
plt.show()

#plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca_Sputnik_V['people_vaccinated'],df_Oxford_AstraZeneca_Sputnik_V['country'])
plt.title('Country VS People Vaccinated')
plt.xlabel('People Vaccinated')
plt.ylabel('Country')
plt.show()

#plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca_Sputnik_V['people_fully_vaccinated'],df_Oxford_AstraZeneca_Sputnik_V['country'])
plt.title('Country VS People Fully Vaccinated')
plt.xlabel('People Fully Vaccinated')
plt.ylabel('Country')
plt.show()

#plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca_Sputnik_V['daily_vaccinations_raw'],df_Oxford_AstraZeneca_Sputnik_V['country'])
plt.title('Country VS Daily Vaccinations Raw')
plt.xlabel('Daily Vaccinations Raw')
plt.ylabel('Country')
plt.show()

#plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca_Sputnik_V['daily_vaccinations'],df_Oxford_AstraZeneca_Sputnik_V['country'])
plt.title('Country VS daily_vaccinations')
plt.xlabel('daily_vaccinations')
plt.ylabel('Country')
plt.show()

#plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca_Sputnik_V['total_vaccinations_per_hundred'],df_Oxford_AstraZeneca_Sputnik_V['country'])
plt.title('Country VS total_vaccinations_per_hundred')
plt.xlabel('total_vaccinations_per_hundred')
plt.ylabel('Country')
plt.show()

#plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca_Sputnik_V['people_vaccinated_per_hundred'],df_Oxford_AstraZeneca_Sputnik_V['country'])
plt.title('Country VS people_vaccinated_per_hundred')
plt.xlabel('people_vaccinated_per_hundred')
plt.ylabel('Country')
plt.show()

#plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca_Sputnik_V['people_fully_vaccinated_per_hundred'],df_Oxford_AstraZeneca_Sputnik_V['country'])
plt.title('Country VS people_fully_vaccinated_per_hundred')
plt.xlabel('people_fully_vaccinated_per_hundred')
plt.ylabel('Country')
plt.show()

#plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca_Sputnik_V['daily_vaccinations_per_million'],df_Oxford_AstraZeneca_Sputnik_V['country'])
plt.title('Country VS daily_vaccinations_per_million')
plt.xlabel('daily_vaccinations_per_million')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# ## Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V

# %%
df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V=df[df['vaccines']=='Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V']
df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V.shape[0]

# %%
df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['vaccines'].unique()

# %%
df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V=df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V.sort_values(by='total_vaccinations', ascending=False)
df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V.head(10)

# %%
df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V.groupby('country').agg(['max','min','mean'])

# %%
sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['total_vaccinations'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['country'])
plt.title('Country VS Total Vaccination')
plt.xlabel('Total Vaccination')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['people_vaccinated'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['country'])
plt.title('Country VS People Vaccinated')
plt.xlabel('People Vaccinated')
plt.ylabel('Country')
plt.show()




sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['people_fully_vaccinated'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['country'])
plt.title('Country VS People Fully Vaccinated')
plt.xlabel('People Fully Vaccinated')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['daily_vaccinations_raw'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['country'])
plt.title('Country VS Daily Vaccinations Raw')
plt.xlabel('Daily Vaccinations Raw')
plt.ylabel('Country')
plt.show()


sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['daily_vaccinations'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['country'])
plt.title('Country VS daily_vaccinations')
plt.xlabel('daily_vaccinations')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['total_vaccinations_per_hundred'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['country'])
plt.title('Country VS total_vaccinations_per_hundred')
plt.xlabel('total_vaccinations_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['people_vaccinated_per_hundred'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['country'])
plt.title('Country VS people_vaccinated_per_hundred')
plt.xlabel('people_vaccinated_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['people_fully_vaccinated_per_hundred'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['country'])
plt.title('Country VS people_fully_vaccinated_per_hundred')
plt.xlabel('people_fully_vaccinated_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['daily_vaccinations_per_million'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['country'])
plt.title('Country VS daily_vaccinations_per_million')
plt.xlabel('daily_vaccinations_per_million')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# ## Oxford/AstraZeneca, Sinovac

# %%
df_Oxford_AstraZeneca_Sinovac=df[df['vaccines']=='Oxford/AstraZeneca, Sinovac']
df_Oxford_AstraZeneca_Sinovac.shape[0]

# %%
df_Oxford_AstraZeneca_Sinovac['vaccines'].unique()

# %%
df_Oxford_AstraZeneca_Sinovac=df_Oxford_AstraZeneca_Sinovac.sort_values(by='total_vaccinations', ascending=False)
df_Oxford_AstraZeneca_Sinovac.head(10)

# %%
df_Oxford_AstraZeneca_Sinovac.groupby('country').agg(['max','min','mean'])

# %%
sns.barplot(df_Oxford_AstraZeneca_Sinovac['total_vaccinations'],df_Oxford_AstraZeneca_Sinovac['country'])
plt.title('Country VS Total Vaccination')
plt.xlabel('Total Vaccination')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Sinovac['people_vaccinated'],df_Oxford_AstraZeneca_Sinovac['country'])
plt.title('Country VS People Vaccinated')
plt.xlabel('People Vaccinated')
plt.ylabel('Country')
plt.show()




sns.barplot(df_Oxford_AstraZeneca_Sinovac['people_fully_vaccinated'],df_Oxford_AstraZeneca_Sinovac['country'])
plt.title('Country VS People Fully Vaccinated')
plt.xlabel('People Fully Vaccinated')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Sinovac['daily_vaccinations_raw'],df_Oxford_AstraZeneca_Sinovac['country'])
plt.title('Country VS Daily Vaccinations Raw')
plt.xlabel('Daily Vaccinations Raw')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Sinovac['daily_vaccinations'],df_Oxford_AstraZeneca_Sinovac['country'])
plt.title('Country VS daily_vaccinations')
plt.xlabel('daily_vaccinations')
plt.ylabel('Country')
plt.show()




sns.barplot(df_Oxford_AstraZeneca_Sinovac['total_vaccinations_per_hundred'],df_Oxford_AstraZeneca_Sinovac['country'])
plt.title('Country VS total_vaccinations_per_hundred')
plt.xlabel('total_vaccinations_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Sinovac['people_vaccinated_per_hundred'],df_Oxford_AstraZeneca_Sinovac['country'])
plt.title('Country VS people_vaccinated_per_hundred')
plt.xlabel('people_vaccinated_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Sinovac['people_fully_vaccinated_per_hundred'],df_Oxford_AstraZeneca_Sinovac['country'])
plt.title('Country VS people_fully_vaccinated_per_hundred')
plt.xlabel('people_fully_vaccinated_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Sinovac['daily_vaccinations_per_million'],df_Oxford_AstraZeneca_Sinovac['country'])
plt.title('Country VS daily_vaccinations_per_million')
plt.xlabel('daily_vaccinations_per_million')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# ## Sinopharm/Beijing

# %%
df_Sinopharm_Beijing=df[df['vaccines']=='Sinopharm/Beijing']
print(df_Sinopharm_Beijing.shape[0])

print(df_Sinopharm_Beijing['vaccines'].unique())

# %%
df_Sinopharm_Beijing=df_Sinopharm_Beijing.sort_values(by='total_vaccinations', ascending=False)
df_Sinopharm_Beijing.head(10)

# %%
df_Sinopharm_Beijing.groupby('country').agg(['max','min','mean'])

# %%
plt.figure(figsize=(10,5))
sns.barplot(df_Sinopharm_Beijing['total_vaccinations'],df_Sinopharm_Beijing['country'])
plt.title('Country VS Total Vaccination', fontsize=20)
plt.xlabel('Total Vaccination', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Sinopharm_Beijing['people_vaccinated'],df_Sinopharm_Beijing['country'])
plt.title('Country VS People Vaccinated', fontsize=20)
plt.xlabel('People Vaccinated', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()



plt.figure(figsize=(10,5))
sns.barplot(df_Sinopharm_Beijing['people_fully_vaccinated'],df_Sinopharm_Beijing['country'])
plt.title('Country VS People Fully Vaccinated', fontsize=20)
plt.xlabel('People Fully Vaccinated', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Sinopharm_Beijing['daily_vaccinations_raw'],df_Sinopharm_Beijing['country'])
plt.title('Country VS Daily Vaccinations Raw', fontsize=20)
plt.xlabel('Daily Vaccinations Raw', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Sinopharm_Beijing['daily_vaccinations'],df_Sinopharm_Beijing['country'])
plt.title('Country VS daily_vaccinations', fontsize=20)
plt.xlabel('daily_vaccinations', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()



plt.figure(figsize=(10,5))
sns.barplot(df_Sinopharm_Beijing['total_vaccinations_per_hundred'],df_Sinopharm_Beijing['country'])
plt.title('Country VS total_vaccinations_per_hundred', fontsize=20)
plt.xlabel('total_vaccinations_per_hundred', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Sinopharm_Beijing['people_vaccinated_per_hundred'],df_Sinopharm_Beijing['country'])
plt.title('Country VS people_vaccinated_per_hundred', fontsize=20)
plt.xlabel('people_vaccinated_per_hundred', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Sinopharm_Beijing['people_fully_vaccinated_per_hundred'],df_Sinopharm_Beijing['country'])
plt.title('Country VS people_fully_vaccinated_per_hundred', fontsize=20)
plt.xlabel('people_fully_vaccinated_per_hundred', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Sinopharm_Beijing['daily_vaccinations_per_million'],df_Sinopharm_Beijing['country'])
plt.title('Country VS daily_vaccinations_per_million', fontsize=20)
plt.xlabel('daily_vaccinations_per_million', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()

# %% [markdown]
# ## Moderna, Pfizer/BioNTech

# %%
df_Moderna_Pfizer_BioNTech=df[df['vaccines']=='Moderna, Pfizer/BioNTech']
print(df_Moderna_Pfizer_BioNTech.shape[0])

print(df_Moderna_Pfizer_BioNTech['vaccines'].unique())

# %%
df_Moderna_Pfizer_BioNTech=df_Moderna_Pfizer_BioNTech.sort_values(by='total_vaccinations', ascending=False)
df_Moderna_Pfizer_BioNTech.head(10)

# %%
df_Moderna_Pfizer_BioNTech.groupby('country').agg(['max','min','mean'])

# %%
plt.figure(figsize=(10,5))
sns.barplot(df_Moderna_Pfizer_BioNTech['total_vaccinations'],df_Moderna_Pfizer_BioNTech['country'])
plt.title('Country VS Total Vaccination', fontsize=20)
plt.xlabel('Total Vaccination', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Moderna_Pfizer_BioNTech['people_vaccinated'],df_Moderna_Pfizer_BioNTech['country'])
plt.title('Country VS People Vaccinated', fontsize=20)
plt.xlabel('People Vaccinated', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()



plt.figure(figsize=(10,5))
sns.barplot(df_Moderna_Pfizer_BioNTech['people_fully_vaccinated'],df_Moderna_Pfizer_BioNTech['country'])
plt.title('Country VS People Fully Vaccinated', fontsize=20)
plt.xlabel('People Fully Vaccinated', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Moderna_Pfizer_BioNTech['daily_vaccinations_raw'],df_Moderna_Pfizer_BioNTech['country'])
plt.title('Country VS Daily Vaccinations Raw', fontsize=20)
plt.xlabel('Daily Vaccinations Raw', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Moderna_Pfizer_BioNTech['daily_vaccinations'],df_Moderna_Pfizer_BioNTech['country'])
plt.title('Country VS daily_vaccinations', fontsize=20)
plt.xlabel('daily_vaccinations', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()



plt.figure(figsize=(10,5))
sns.barplot(df_Moderna_Pfizer_BioNTech['total_vaccinations_per_hundred'],df_Moderna_Pfizer_BioNTech['country'])
plt.title('Country VS total_vaccinations_per_hundred', fontsize=20)
plt.xlabel('total_vaccinations_per_hundred', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Moderna_Pfizer_BioNTech['people_vaccinated_per_hundred'],df_Moderna_Pfizer_BioNTech['country'])
plt.title('Country VS people_vaccinated_per_hundred', fontsize=20)
plt.xlabel('people_vaccinated_per_hundred', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Moderna_Pfizer_BioNTech['people_fully_vaccinated_per_hundred'],df_Moderna_Pfizer_BioNTech['country'])
plt.title('Country VS people_fully_vaccinated_per_hundred', fontsize=20)
plt.xlabel('people_fully_vaccinated_per_hundred', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Moderna_Pfizer_BioNTech['daily_vaccinations_per_million'],df_Moderna_Pfizer_BioNTech['country'])
plt.title('Country VS daily_vaccinations_per_million', fontsize=20)
plt.xlabel('daily_vaccinations_per_million', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()

# %% [markdown]
# ## Pfizer/BioNTech, Sinovac

# %%
df_Pfizer_BioNTech_Sinovac=df[df['vaccines']=='Pfizer/BioNTech, Sinovac']
print(df_Pfizer_BioNTech_Sinovac.shape[0])

print(df_Pfizer_BioNTech_Sinovac['vaccines'].unique())

# %%
df_Pfizer_BioNTech_Sinovac=df_Pfizer_BioNTech_Sinovac.sort_values(by='total_vaccinations', ascending=False)
df_Pfizer_BioNTech_Sinovac.head(10)

# %%
df_Pfizer_BioNTech_Sinovac.groupby('country').agg(['max','min','mean'])

# %%
sns.barplot(df_Pfizer_BioNTech_Sinovac['total_vaccinations'],df_Pfizer_BioNTech_Sinovac['country'])
plt.title('Country VS Total Vaccination')
plt.xlabel('Total Vaccination')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Pfizer_BioNTech_Sinovac['people_vaccinated'],df_Pfizer_BioNTech_Sinovac['country'])
plt.title('Country VS People Vaccinated')
plt.xlabel('People Vaccinated')
plt.ylabel('Country')
plt.show()




sns.barplot(df_Pfizer_BioNTech_Sinovac['people_fully_vaccinated'],df_Pfizer_BioNTech_Sinovac['country'])
plt.title('Country VS People Fully Vaccinated')
plt.xlabel('People Fully Vaccinated')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Pfizer_BioNTech_Sinovac['daily_vaccinations_raw'],df_Pfizer_BioNTech_Sinovac['country'])
plt.title('Country VS Daily Vaccinations Raw')
plt.xlabel('Daily Vaccinations Raw')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Pfizer_BioNTech_Sinovac['daily_vaccinations'],df_Pfizer_BioNTech_Sinovac['country'])
plt.title('Country VS daily_vaccinations')
plt.xlabel('daily_vaccinations')
plt.ylabel('Country')
plt.show()




sns.barplot(df_Pfizer_BioNTech_Sinovac['total_vaccinations_per_hundred'],df_Pfizer_BioNTech_Sinovac['country'])
plt.title('Country VS total_vaccinations_per_hundred')
plt.xlabel('total_vaccinations_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Pfizer_BioNTech_Sinovac['people_vaccinated_per_hundred'],df_Pfizer_BioNTech_Sinovac['country'])
plt.title('Country VS people_vaccinated_per_hundred')
plt.xlabel('people_vaccinated_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Pfizer_BioNTech_Sinovac['people_fully_vaccinated_per_hundred'],df_Pfizer_BioNTech_Sinovac['country'])
plt.title('Country VS people_fully_vaccinated_per_hundred')
plt.xlabel('people_fully_vaccinated_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Pfizer_BioNTech_Sinovac['daily_vaccinations_per_million'],df_Pfizer_BioNTech_Sinovac['country'])
plt.title('Country VS daily_vaccinations_per_million')
plt.xlabel('daily_vaccinations_per_million')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# ## Sinopharm/Beijing, Sinopharm/Wuhan, Sinovac

# %%
df_Sinopharm_Beijing_Sinopharm_Wuhan_Sinovac=df[df['vaccines']=='Sinopharm/Beijing, Sinopharm/Wuhan, Sinovac']
print(df_Sinopharm_Beijing_Sinopharm_Wuhan_Sinovac.shape[0])

print(df_Sinopharm_Beijing_Sinopharm_Wuhan_Sinovac['vaccines'].unique())

# %%
df_Sinopharm_Beijing_Sinopharm_Wuhan_Sinovac=df_Sinopharm_Beijing_Sinopharm_Wuhan_Sinovac.sort_values(by='total_vaccinations', ascending=False)
df_Sinopharm_Beijing_Sinopharm_Wuhan_Sinovac.head(10)

# %%
df_Sinopharm_Beijing_Sinopharm_Wuhan_Sinovac.groupby('country').agg(['max','min','mean'])

# %%
sns.barplot(df_Sinopharm_Beijing_Sinopharm_Wuhan_Sinovac['total_vaccinations'],df_Sinopharm_Beijing_Sinopharm_Wuhan_Sinovac['country'])
plt.title('Country VS Total Vaccination')
plt.xlabel('Total Vaccination')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Sinopharm_Beijing_Sinopharm_Wuhan_Sinovac['people_vaccinated'],df_Sinopharm_Beijing_Sinopharm_Wuhan_Sinovac['country'])
plt.title('Country VS People Vaccinated')
plt.xlabel('People Vaccinated')
plt.ylabel('Country')
plt.show()




sns.barplot(df_Sinopharm_Beijing_Sinopharm_Wuhan_Sinovac['people_fully_vaccinated'],df_Sinopharm_Beijing_Sinopharm_Wuhan_Sinovac['country'])
plt.title('Country VS People Fully Vaccinated')
plt.xlabel('People Fully Vaccinated')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Sinopharm_Beijing_Sinopharm_Wuhan_Sinovac['daily_vaccinations_raw'],df_Sinopharm_Beijing_Sinopharm_Wuhan_Sinovac['country'])
plt.title('Country VS Daily Vaccinations Raw')
plt.xlabel('Daily Vaccinations Raw')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Sinopharm_Beijing_Sinopharm_Wuhan_Sinovac['daily_vaccinations'],df_Sinopharm_Beijing_Sinopharm_Wuhan_Sinovac['country'])
plt.title('Country VS daily_vaccinations')
plt.xlabel('daily_vaccinations')
plt.ylabel('Country')
plt.show()




sns.barplot(df_Sinopharm_Beijing_Sinopharm_Wuhan_Sinovac['total_vaccinations_per_hundred'],df_Sinopharm_Beijing_Sinopharm_Wuhan_Sinovac['country'])
plt.title('Country VS total_vaccinations_per_hundred')
plt.xlabel('total_vaccinations_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Sinopharm_Beijing_Sinopharm_Wuhan_Sinovac['people_vaccinated_per_hundred'],df_Sinopharm_Beijing_Sinopharm_Wuhan_Sinovac['country'])
plt.title('Country VS people_vaccinated_per_hundred')
plt.xlabel('people_vaccinated_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Sinopharm_Beijing_Sinopharm_Wuhan_Sinovac['people_fully_vaccinated_per_hundred'],df_Sinopharm_Beijing_Sinopharm_Wuhan_Sinovac['country'])
plt.title('Country VS people_fully_vaccinated_per_hundred')
plt.xlabel('people_fully_vaccinated_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Sinopharm_Beijing_Sinopharm_Wuhan_Sinovac['daily_vaccinations_per_million'],df_Sinopharm_Beijing_Sinopharm_Wuhan_Sinovac['country'])
plt.title('Country VS daily_vaccinations_per_million')
plt.xlabel('daily_vaccinations_per_million')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# ## Oxford/AstraZeneca, Pfizer/BioNTech

# %%
df_Oxford_AstraZeneca_Pfizer_BioNTech=df[df['vaccines']=='Oxford/AstraZeneca, Pfizer/BioNTech']
print(df_Oxford_AstraZeneca_Pfizer_BioNTech.shape[0])

print(df_Oxford_AstraZeneca_Pfizer_BioNTech['vaccines'].unique())

# %%
df_Oxford_AstraZeneca_Pfizer_BioNTech=df_Oxford_AstraZeneca_Pfizer_BioNTech.sort_values(by='total_vaccinations', ascending=False)
df_Oxford_AstraZeneca_Pfizer_BioNTech.head(10)

# %%
df_Oxford_AstraZeneca_Pfizer_BioNTech.groupby('country').agg(['max','min','mean'])

# %%
plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech['total_vaccinations'],df_Oxford_AstraZeneca_Pfizer_BioNTech['country'])
plt.title('Country VS Total Vaccination', fontsize=20)
plt.xlabel('Total Vaccination', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech['people_vaccinated'],df_Oxford_AstraZeneca_Pfizer_BioNTech['country'])
plt.title('Country VS People Vaccinated', fontsize=20)
plt.xlabel('People Vaccinated', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()



plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech['people_fully_vaccinated'],df_Oxford_AstraZeneca_Pfizer_BioNTech['country'])
plt.title('Country VS People Fully Vaccinated', fontsize=20)
plt.xlabel('People Fully Vaccinated', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech['daily_vaccinations_raw'],df_Oxford_AstraZeneca_Pfizer_BioNTech['country'])
plt.title('Country VS Daily Vaccinations Raw', fontsize=20)
plt.xlabel('Daily Vaccinations Raw', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech['daily_vaccinations'],df_Oxford_AstraZeneca_Pfizer_BioNTech['country'])
plt.title('Country VS daily_vaccinations', fontsize=20)
plt.xlabel('daily_vaccinations', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()



plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech['total_vaccinations_per_hundred'],df_Oxford_AstraZeneca_Pfizer_BioNTech['country'])
plt.title('Country VS total_vaccinations_per_hundred', fontsize=20)
plt.xlabel('total_vaccinations_per_hundred', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech['people_vaccinated_per_hundred'],df_Oxford_AstraZeneca_Pfizer_BioNTech['country'])
plt.title('Country VS people_vaccinated_per_hundred', fontsize=20)
plt.xlabel('people_vaccinated_per_hundred', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech['people_fully_vaccinated_per_hundred'],df_Oxford_AstraZeneca_Pfizer_BioNTech['country'])
plt.title('Country VS people_fully_vaccinated_per_hundred', fontsize=20)
plt.xlabel('people_fully_vaccinated_per_hundred', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech['daily_vaccinations_per_million'],df_Oxford_AstraZeneca_Pfizer_BioNTech['country'])
plt.title('Country VS daily_vaccinations_per_million', fontsize=20)
plt.xlabel('daily_vaccinations_per_million', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()

# %% [markdown]
# ## Sinovac

# %%
df_Sinovac=df[df['vaccines']=='Sinovac']
print(df_Sinovac.shape[0])

print(df_Sinovac['vaccines'].unique())

# %%
df_Sinovac=df_Sinovac.sort_values(by='total_vaccinations', ascending=False)
df_Sinovac.head(10)

# %%
df_Sinovac.groupby('country').agg(['max','min','mean'])

# %%
plt.figure(figsize=(10,5))
sns.barplot(df_Sinovac['total_vaccinations'],df_Sinovac['country'])
plt.title('Country VS Total Vaccination', fontsize=20)
plt.xlabel('Total Vaccination', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Sinovac['people_vaccinated'],df_Sinovac['country'])
plt.title('Country VS People Vaccinated', fontsize=20)
plt.xlabel('People Vaccinated', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()



plt.figure(figsize=(10,5))
sns.barplot(df_Sinovac['people_fully_vaccinated'],df_Sinovac['country'])
plt.title('Country VS People Fully Vaccinated', fontsize=20)
plt.xlabel('People Fully Vaccinated', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Sinovac['daily_vaccinations_raw'],df_Sinovac['country'])
plt.title('Country VS Daily Vaccinations Raw', fontsize=20)
plt.xlabel('Daily Vaccinations Raw', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Sinovac['daily_vaccinations'],df_Sinovac['country'])
plt.title('Country VS daily_vaccinations', fontsize=20)
plt.xlabel('daily_vaccinations', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()



plt.figure(figsize=(10,5))
sns.barplot(df_Sinovac['total_vaccinations_per_hundred'],df_Sinovac['country'])
plt.title('Country VS total_vaccinations_per_hundred', fontsize=20)
plt.xlabel('total_vaccinations_per_hundred', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Sinovac['people_vaccinated_per_hundred'],df_Sinovac['country'])
plt.title('Country VS people_vaccinated_per_hundred', fontsize=20)
plt.xlabel('people_vaccinated_per_hundred', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Sinovac['people_fully_vaccinated_per_hundred'],df_Sinovac['country'])
plt.title('Country VS people_fully_vaccinated_per_hundred', fontsize=20)
plt.xlabel('people_fully_vaccinated_per_hundred', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()


plt.figure(figsize=(10,5))
sns.barplot(df_Sinovac['daily_vaccinations_per_million'],df_Sinovac['country'])
plt.title('Country VS daily_vaccinations_per_million', fontsize=20)
plt.xlabel('daily_vaccinations_per_million', fontsize=20)
plt.ylabel('Country', fontsize=20)
plt.show()

# %% [markdown]
# ## Moderna

# %%
df_Moderna=df[df['vaccines']=='Moderna']
print(df_Moderna.shape[0])

print(df_Moderna['vaccines'].unique())

# %%
df_Moderna=df_Moderna.sort_values(by='total_vaccinations', ascending=False)
df_Moderna

# %%
df_Moderna.groupby('country').agg(['max','min','mean'])

# %%
sns.barplot(df_Moderna['total_vaccinations'],df_Moderna['country'])
plt.title('Country VS Total Vaccination')
plt.xlabel('Total Vaccination')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Moderna['people_vaccinated'],df_Moderna['country'])
plt.title('Country VS People Vaccinated')
plt.xlabel('People Vaccinated')
plt.ylabel('Country')
plt.show()




sns.barplot(df_Moderna['people_fully_vaccinated'],df_Moderna['country'])
plt.title('Country VS People Fully Vaccinated')
plt.xlabel('People Fully Vaccinated')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Moderna['daily_vaccinations_raw'],df_Moderna['country'])
plt.title('Country VS Daily Vaccinations Raw')
plt.xlabel('Daily Vaccinations Raw')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Moderna['daily_vaccinations'],df_Moderna['country'])
plt.title('Country VS daily_vaccinations')
plt.xlabel('daily_vaccinations')
plt.ylabel('Country')
plt.show()




sns.barplot(df_Moderna['total_vaccinations_per_hundred'],df_Moderna['country'])
plt.title('Country VS total_vaccinations_per_hundred')
plt.xlabel('total_vaccinations_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Moderna['people_vaccinated_per_hundred'],df_Moderna['country'])
plt.title('Country VS people_vaccinated_per_hundred')
plt.xlabel('people_vaccinated_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Moderna['people_fully_vaccinated_per_hundred'],df_Moderna['country'])
plt.title('Country VS people_fully_vaccinated_per_hundred')
plt.xlabel('people_fully_vaccinated_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Moderna['daily_vaccinations_per_million'],df_Moderna['country'])
plt.title('Country VS daily_vaccinations_per_million')
plt.xlabel('daily_vaccinations_per_million')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# ## Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V

# %%
df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V=df[df['vaccines']=='Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V']
print(df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V.shape[0])

print(df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['vaccines'].unique())

# %%
df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V=df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V.sort_values(by='total_vaccinations', ascending=False)
df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V.head(10)

# %%
df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V.groupby('country').agg(['max','min','mean'])

# %%
sns.barplot(df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['total_vaccinations'],df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['country'])
plt.title('Country VS Total Vaccination')
plt.xlabel('Total Vaccination')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['people_vaccinated'],df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['country'])
plt.title('Country VS People Vaccinated')
plt.xlabel('People Vaccinated')
plt.ylabel('Country')
plt.show()




sns.barplot(df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['people_fully_vaccinated'],df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['country'])
plt.title('Country VS People Fully Vaccinated')
plt.xlabel('People Fully Vaccinated')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['daily_vaccinations_raw'],df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['country'])
plt.title('Country VS Daily Vaccinations Raw')
plt.xlabel('Daily Vaccinations Raw')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['daily_vaccinations'],df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['country'])
plt.title('Country VS daily_vaccinations')
plt.xlabel('daily_vaccinations')
plt.ylabel('Country')
plt.show()




sns.barplot(df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['total_vaccinations_per_hundred'],df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['country'])
plt.title('Country VS total_vaccinations_per_hundred')
plt.xlabel('total_vaccinations_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['people_vaccinated_per_hundred'],df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['country'])
plt.title('Country VS people_vaccinated_per_hundred')
plt.xlabel('people_vaccinated_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['people_fully_vaccinated_per_hundred'],df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['country'])
plt.title('Country VS people_fully_vaccinated_per_hundred')
plt.xlabel('people_fully_vaccinated_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['daily_vaccinations_per_million'],df_Moderna_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sputnik_V['country'])
plt.title('Country VS daily_vaccinations_per_million')
plt.xlabel('daily_vaccinations_per_million')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# ## Covaxin, Oxford/AstraZeneca

# %%
df_Covaxin_Oxford_AstraZeneca=df[df['vaccines']=='Covaxin, Oxford/AstraZeneca']
print(df_Covaxin_Oxford_AstraZeneca.shape[0])

print(df_Covaxin_Oxford_AstraZeneca['vaccines'].unique())

# %%
df_Covaxin_Oxford_AstraZeneca=df_Covaxin_Oxford_AstraZeneca.sort_values(by='total_vaccinations', ascending=False)
df_Covaxin_Oxford_AstraZeneca.head(10)

# %%
df_Covaxin_Oxford_AstraZeneca.groupby('country').agg(['max','min','mean'])

# %%
sns.barplot(df_Covaxin_Oxford_AstraZeneca['total_vaccinations'],df_Covaxin_Oxford_AstraZeneca['country'])
plt.title('Country VS Total Vaccination')
plt.xlabel('Total Vaccination')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Covaxin_Oxford_AstraZeneca['people_vaccinated'],df_Covaxin_Oxford_AstraZeneca['country'])
plt.title('Country VS People Vaccinated')
plt.xlabel('People Vaccinated')
plt.ylabel('Country')
plt.show()




sns.barplot(df_Covaxin_Oxford_AstraZeneca['people_fully_vaccinated'],df_Covaxin_Oxford_AstraZeneca['country'])
plt.title('Country VS People Fully Vaccinated')
plt.xlabel('People Fully Vaccinated')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Covaxin_Oxford_AstraZeneca['daily_vaccinations_raw'],df_Covaxin_Oxford_AstraZeneca['country'])
plt.title('Country VS Daily Vaccinations Raw')
plt.xlabel('Daily Vaccinations Raw')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Covaxin_Oxford_AstraZeneca['daily_vaccinations'],df_Covaxin_Oxford_AstraZeneca['country'])
plt.title('Country VS daily_vaccinations')
plt.xlabel('daily_vaccinations')
plt.ylabel('Country')
plt.show()




sns.barplot(df_Covaxin_Oxford_AstraZeneca['total_vaccinations_per_hundred'],df_Covaxin_Oxford_AstraZeneca['country'])
plt.title('Country VS total_vaccinations_per_hundred')
plt.xlabel('total_vaccinations_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Covaxin_Oxford_AstraZeneca['people_vaccinated_per_hundred'],df_Covaxin_Oxford_AstraZeneca['country'])
plt.title('Country VS people_vaccinated_per_hundred')
plt.xlabel('people_vaccinated_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Covaxin_Oxford_AstraZeneca['people_fully_vaccinated_per_hundred'],df_Covaxin_Oxford_AstraZeneca['country'])
plt.title('Country VS people_fully_vaccinated_per_hundred')
plt.xlabel('people_fully_vaccinated_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Covaxin_Oxford_AstraZeneca['daily_vaccinations_per_million'],df_Covaxin_Oxford_AstraZeneca['country'])
plt.title('Country VS daily_vaccinations_per_million')
plt.xlabel('daily_vaccinations_per_million')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# ## Pfizer/BioNTech, Sinopharm/Beijing

# %%
df_Pfizer_BioNTech_Sinopharm_Beijing=df[df['vaccines']=='Pfizer/BioNTech, Sinopharm/Beijing']
print(df_Pfizer_BioNTech_Sinopharm_Beijing.shape[0])

print(df_Pfizer_BioNTech_Sinopharm_Beijing['vaccines'].unique())

# %%
df_Pfizer_BioNTech_Sinopharm_Beijing=df_Pfizer_BioNTech_Sinopharm_Beijing.sort_values(by='total_vaccinations', ascending=False)
df_Pfizer_BioNTech_Sinopharm_Beijing.head(10)

# %%
df_Pfizer_BioNTech_Sinopharm_Beijing.groupby('country').agg(['max','min','mean'])

# %%
sns.barplot(df_Pfizer_BioNTech_Sinopharm_Beijing['total_vaccinations'],df_Pfizer_BioNTech_Sinopharm_Beijing['country'])
plt.title('Country VS Total Vaccination')
plt.xlabel('Total Vaccination')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Pfizer_BioNTech_Sinopharm_Beijing['people_vaccinated'],df_Pfizer_BioNTech_Sinopharm_Beijing['country'])
plt.title('Country VS People Vaccinated')
plt.xlabel('People Vaccinated')
plt.ylabel('Country')
plt.show()




sns.barplot(df_Pfizer_BioNTech_Sinopharm_Beijing['people_fully_vaccinated'],df_Pfizer_BioNTech_Sinopharm_Beijing['country'])
plt.title('Country VS People Fully Vaccinated')
plt.xlabel('People Fully Vaccinated')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Pfizer_BioNTech_Sinopharm_Beijing['daily_vaccinations_raw'],df_Pfizer_BioNTech_Sinopharm_Beijing['country'])
plt.title('Country VS Daily Vaccinations Raw')
plt.xlabel('Daily Vaccinations Raw')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Pfizer_BioNTech_Sinopharm_Beijing['daily_vaccinations'],df_Pfizer_BioNTech_Sinopharm_Beijing['country'])
plt.title('Country VS daily_vaccinations')
plt.xlabel('daily_vaccinations')
plt.ylabel('Country')
plt.show()




sns.barplot(df_Pfizer_BioNTech_Sinopharm_Beijing['total_vaccinations_per_hundred'],df_Pfizer_BioNTech_Sinopharm_Beijing['country'])
plt.title('Country VS total_vaccinations_per_hundred')
plt.xlabel('total_vaccinations_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Pfizer_BioNTech_Sinopharm_Beijing['people_vaccinated_per_hundred'],df_Pfizer_BioNTech_Sinopharm_Beijing['country'])
plt.title('Country VS people_vaccinated_per_hundred')
plt.xlabel('people_vaccinated_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Pfizer_BioNTech_Sinopharm_Beijing['people_fully_vaccinated_per_hundred'],df_Pfizer_BioNTech_Sinopharm_Beijing['country'])
plt.title('Country VS people_fully_vaccinated_per_hundred')
plt.xlabel('people_fully_vaccinated_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Pfizer_BioNTech_Sinopharm_Beijing['daily_vaccinations_per_million'],df_Pfizer_BioNTech_Sinopharm_Beijing['country'])
plt.title('Country VS daily_vaccinations_per_million')
plt.xlabel('daily_vaccinations_per_million')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# ## Oxford/AstraZeneca, Pfizer/BioNTech, Sputnik V

# %%
df_Oxford_AstraZeneca_Pfizer_BioNTech_Sputnik_V=df[df['vaccines']=='Oxford/AstraZeneca, Pfizer/BioNTech, Sputnik V']
print(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sputnik_V.shape[0])

print(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sputnik_V['vaccines'].unique())

# %%
df_Oxford_AstraZeneca_Pfizer_BioNTech_Sputnik_V=df_Oxford_AstraZeneca_Pfizer_BioNTech_Sputnik_V.sort_values(by='total_vaccinations', ascending=False)
df_Oxford_AstraZeneca_Pfizer_BioNTech_Sputnik_V.head(10)

# %%
df_Oxford_AstraZeneca_Pfizer_BioNTech_Sputnik_V.groupby('country').agg(['max','min','mean'])

# %%
sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sputnik_V['total_vaccinations'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sputnik_V['country'])
plt.title('Country VS Total Vaccination')
plt.xlabel('Total Vaccination')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sputnik_V['people_vaccinated'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sputnik_V['country'])
plt.title('Country VS People Vaccinated')
plt.xlabel('People Vaccinated')
plt.ylabel('Country')
plt.show()




sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sputnik_V['people_fully_vaccinated'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sputnik_V['country'])
plt.title('Country VS People Fully Vaccinated')
plt.xlabel('People Fully Vaccinated')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sputnik_V['daily_vaccinations_raw'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sputnik_V['country'])
plt.title('Country VS Daily Vaccinations Raw')
plt.xlabel('Daily Vaccinations Raw')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sputnik_V['daily_vaccinations'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sputnik_V['country'])
plt.title('Country VS daily_vaccinations')
plt.xlabel('daily_vaccinations')
plt.ylabel('Country')
plt.show()




sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sputnik_V['total_vaccinations_per_hundred'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sputnik_V['country'])
plt.title('Country VS total_vaccinations_per_hundred')
plt.xlabel('total_vaccinations_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sputnik_V['people_vaccinated_per_hundred'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sputnik_V['country'])
plt.title('Country VS people_vaccinated_per_hundred')
plt.xlabel('people_vaccinated_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sputnik_V['people_fully_vaccinated_per_hundred'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sputnik_V['country'])
plt.title('Country VS people_fully_vaccinated_per_hundred')
plt.xlabel('people_fully_vaccinated_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sputnik_V['daily_vaccinations_per_million'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sputnik_V['country'])
plt.title('Country VS daily_vaccinations_per_million')
plt.xlabel('daily_vaccinations_per_million')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# ## Oxford/AstraZeneca, Sinopharm/Beijing

# %%
df_Oxford_AstraZeneca_Sinopharm_Beijing=df[df['vaccines']=='Oxford/AstraZeneca, Sinopharm/Beijing']
print(df_Oxford_AstraZeneca_Sinopharm_Beijing.shape[0])

print(df_Oxford_AstraZeneca_Sinopharm_Beijing['vaccines'].unique())

# %%
df_Oxford_AstraZeneca_Sinopharm_Beijing=df_Oxford_AstraZeneca_Sinopharm_Beijing.sort_values(by='total_vaccinations', ascending=False)
df_Oxford_AstraZeneca_Sinopharm_Beijing.head(10)

# %%
df_Oxford_AstraZeneca_Sinopharm_Beijing.groupby('country').agg(['max','min','mean'])

# %%
sns.barplot(df_Oxford_AstraZeneca_Sinopharm_Beijing['total_vaccinations'],df_Oxford_AstraZeneca_Sinopharm_Beijing['country'])
plt.title('Country VS Total Vaccination')
plt.xlabel('Total Vaccination')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Sinopharm_Beijing['people_vaccinated'],df_Oxford_AstraZeneca_Sinopharm_Beijing['country'])
plt.title('Country VS People Vaccinated')
plt.xlabel('People Vaccinated')
plt.ylabel('Country')
plt.show()




sns.barplot(df_Oxford_AstraZeneca_Sinopharm_Beijing['people_fully_vaccinated'],df_Oxford_AstraZeneca_Sinopharm_Beijing['country'])
plt.title('Country VS People Fully Vaccinated')
plt.xlabel('People Fully Vaccinated')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Sinopharm_Beijing['daily_vaccinations_raw'],df_Oxford_AstraZeneca_Sinopharm_Beijing['country'])
plt.title('Country VS Daily Vaccinations Raw')
plt.xlabel('Daily Vaccinations Raw')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Sinopharm_Beijing['daily_vaccinations'],df_Oxford_AstraZeneca_Sinopharm_Beijing['country'])
plt.title('Country VS daily_vaccinations')
plt.xlabel('daily_vaccinations')
plt.ylabel('Country')
plt.show()




sns.barplot(df_Oxford_AstraZeneca_Sinopharm_Beijing['total_vaccinations_per_hundred'],df_Oxford_AstraZeneca_Sinopharm_Beijing['country'])
plt.title('Country VS total_vaccinations_per_hundred')
plt.xlabel('total_vaccinations_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Sinopharm_Beijing['people_vaccinated_per_hundred'],df_Oxford_AstraZeneca_Sinopharm_Beijing['country'])
plt.title('Country VS people_vaccinated_per_hundred')
plt.xlabel('people_vaccinated_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Sinopharm_Beijing['people_fully_vaccinated_per_hundred'],df_Oxford_AstraZeneca_Sinopharm_Beijing['country'])
plt.title('Country VS people_fully_vaccinated_per_hundred')
plt.xlabel('people_fully_vaccinated_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Sinopharm_Beijing['daily_vaccinations_per_million'],df_Oxford_AstraZeneca_Sinopharm_Beijing['country'])
plt.title('Country VS daily_vaccinations_per_million')
plt.xlabel('daily_vaccinations_per_million')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# ## Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinopharm/Wuhan, Sputnik V

# %%
df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sinopharm_Wuhan_Sputnik_V=df[df['vaccines']=='Oxford/AstraZeneca, Pfizer/BioNTech, Sputnik V']
print(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sinopharm_Wuhan_Sputnik_V.shape[0])

print(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sinopharm_Wuhan_Sputnik_V['vaccines'].unique())

# %%
df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sinopharm_Wuhan_Sputnik_V=df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sinopharm_Wuhan_Sputnik_V.sort_values(by='total_vaccinations', ascending=False)
df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sinopharm_Wuhan_Sputnik_V.head(10)

# %%
df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sinopharm_Wuhan_Sputnik_V.groupby('country').agg(['max','min','mean'])

# %%
sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sinopharm_Wuhan_Sputnik_V['total_vaccinations'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sinopharm_Wuhan_Sputnik_V['country'])
plt.title('Country VS Total Vaccination')
plt.xlabel('Total Vaccination')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sinopharm_Wuhan_Sputnik_V['people_vaccinated'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sinopharm_Wuhan_Sputnik_V['country'])
plt.title('Country VS People Vaccinated')
plt.xlabel('People Vaccinated')
plt.ylabel('Country')
plt.show()




sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sinopharm_Wuhan_Sputnik_V['people_fully_vaccinated'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sinopharm_Wuhan_Sputnik_V['country'])
plt.title('Country VS People Fully Vaccinated')
plt.xlabel('People Fully Vaccinated')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sinopharm_Wuhan_Sputnik_V['daily_vaccinations_raw'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sinopharm_Wuhan_Sputnik_V['country'])
plt.title('Country VS Daily Vaccinations Raw')
plt.xlabel('Daily Vaccinations Raw')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sinopharm_Wuhan_Sputnik_V['daily_vaccinations'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sinopharm_Wuhan_Sputnik_V['country'])
plt.title('Country VS daily_vaccinations')
plt.xlabel('daily_vaccinations')
plt.ylabel('Country')
plt.show()




sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sinopharm_Wuhan_Sputnik_V['total_vaccinations_per_hundred'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sinopharm_Wuhan_Sputnik_V['country'])
plt.title('Country VS total_vaccinations_per_hundred')
plt.xlabel('total_vaccinations_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sinopharm_Wuhan_Sputnik_V['people_vaccinated_per_hundred'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sinopharm_Wuhan_Sputnik_V['country'])
plt.title('Country VS people_vaccinated_per_hundred')
plt.xlabel('people_vaccinated_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sinopharm_Wuhan_Sputnik_V['people_fully_vaccinated_per_hundred'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sinopharm_Wuhan_Sputnik_V['country'])
plt.title('Country VS people_fully_vaccinated_per_hundred')
plt.xlabel('people_fully_vaccinated_per_hundred')
plt.ylabel('Country')
plt.show()



sns.barplot(df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sinopharm_Wuhan_Sputnik_V['daily_vaccinations_per_million'],df_Oxford_AstraZeneca_Pfizer_BioNTech_Sinopharm_Beijing_Sinopharm_Wuhan_Sputnik_V['country'])
plt.title('Country VS daily_vaccinations_per_million')
plt.xlabel('daily_vaccinations_per_million')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# # Tracking the rate of vaccination in the basis of Month and Year

# %%
df["day"] = df["date"].dt.day
df["month"] =df["date"].dt.month
df["year"] = df["date"].dt.year

# %%
plt.figure(figsize=(10,5))
plt.plot(df["month"], df["people_vaccinated"])

plt.title("Monthly people_vaccinated")
plt.xlabel("Month")
plt.ylabel("people_vaccinated")

# %%
plt.figure(figsize=(10,5))
plt.plot(df["year"], df["people_vaccinated"])

plt.title("Seasonal people_vaccinated")
plt.xlabel("year")
plt.ylabel("people_vaccinated")

# %%
plt.figure(figsize=(10,5))
plt.plot(df["year"], df["people_fully_vaccinated"])

plt.title("Seasonal people_fully_vaccinated")
plt.xlabel("year")
plt.ylabel("people_fully_vaccinated")

# %%
plt.figure(figsize=(10,5))
plt.plot(df["month"], df["people_fully_vaccinated"])

plt.title("Seasonal people_fully_vaccinated")
plt.xlabel("month")
plt.ylabel("people_fully_vaccinated")

# %%
plt.figure(figsize=(10,5))
plt.plot(df["year"], df["daily_vaccinations_raw"])

plt.title("Seasonal daily_vaccinations_raw")
plt.xlabel("year")
plt.ylabel("daily_vaccinations_raw")
plt.show()


plt.figure(figsize=(10,5))
plt.plot(df["month"], df["daily_vaccinations_raw"])

plt.title("Seasonal daily_vaccinations_raw")
plt.xlabel("month")
plt.ylabel("daily_vaccinations_raw")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df["year"], df["daily_vaccinations"])

plt.title("Seasonal daily_vaccinations")
plt.xlabel("year")
plt.ylabel("daily_vaccinations")
plt.show()


plt.figure(figsize=(10,5))
plt.plot(df["month"], df["daily_vaccinations"])

plt.title("Seasonal daily_vaccinations")
plt.xlabel("month")
plt.ylabel("daily_vaccinations")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df["year"], df["total_vaccinations_per_hundred"])

plt.title("Seasonal total_vaccinations_per_hundred")
plt.xlabel("year")
plt.ylabel("total_vaccinations_per_hundred")
plt.show()


plt.figure(figsize=(10,5))
plt.plot(df["month"], df["total_vaccinations_per_hundred"])

plt.title("Seasonal total_vaccinations_per_hundred")
plt.xlabel("month")
plt.ylabel("total_vaccinations_per_hundred")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df["year"], df["people_vaccinated_per_hundred"])

plt.title("Seasonal people_vaccinated_per_hundred")
plt.xlabel("year")
plt.ylabel("people_vaccinated_per_hundred")
plt.show()


plt.figure(figsize=(10,5))
plt.plot(df["month"], df["people_vaccinated_per_hundred"])

plt.title("Seasonal people_vaccinated_per_hundred")
plt.xlabel("month")
plt.ylabel("people_vaccinated_per_hundred")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df["year"], df["people_fully_vaccinated_per_hundred"])

plt.title("Seasonal people_fully_vaccinated_per_hundred")
plt.xlabel("year")
plt.ylabel("people_fully_vaccinated_per_hundred")
plt.show()


plt.figure(figsize=(10,5))
plt.plot(df["month"], df["people_fully_vaccinated_per_hundred"])

plt.title("Seasonal people_fully_vaccinated_per_hundred")
plt.xlabel("month")
plt.ylabel("people_fully_vaccinated_per_hundred")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df["year"], df["daily_vaccinations_per_million"])

plt.title("Seasonal daily_vaccinations_per_million")
plt.xlabel("year")
plt.ylabel("daily_vaccinations_per_million")
plt.show()


plt.figure(figsize=(10,5))
plt.plot(df["month"], df["daily_vaccinations_per_million"])

plt.title("Seasonal daily_vaccinations_per_million")
plt.xlabel("month")
plt.ylabel("daily_vaccinations_per_million")
plt.show()

# %% [markdown]
# ## Please do upvote and comment if you finds informative in this notebook.
