# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import missingno as mion
import os

# %%
data=pd.read_csv("../input/parking/Parking Data.csv")

# %%
data.head()

# %%
data.info()

# %%
data.describe()

# %%
data['Bldg City'].value_counts()

# %%
plt.figure(figsize=(20,7))
sns.countplot(data['Bldg State'])

# %%
sns.countplot(data['Bldg Status'])

# %%
sns.countplot(data['Property Type'])

# %%
sns.countplot(data['Owned/Leased'])

# %%
data.groupby('Bldg City').sum()

# %%
data.groupby('Bldg State').sum().plot(figsize=(12,7))

# %%
data.groupby('Bldg Status').sum().plot(figsize=(12,7))

# %%
data.groupby('Property Type').sum().plot(figsize=(12,7))

# %%
data.groupby('Owned/Leased').sum().plot(figsize=(12,7))

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(20,10))
sns.lineplot(x='Bldg State',y='Total Parking Spaces',data=data)

# %%
plt.style.use('ggplot')
sns.lineplot(x='Bldg Status',y='Total Parking Spaces',data=data)

# %%
plt.style.use('ggplot')
sns.lineplot(x='Property Type',y='Total Parking Spaces',data=data)

# %%
plt.style.use('ggplot')
sns.lineplot(x='Owned/Leased',y='Total Parking Spaces',data=data)

# %%
hightotal=data.sort_values(by="Total Parking Spaces",ascending=False).head(10)

# %%
hightotal.style.highlight_max('Total Parking Spaces',color='red')

# %%
hightotal.style.highlight_min('Total Parking Spaces',color='green')

# %%
hightotal.style.background_gradient(subset='Total Parking Spaces')

# %%
less=data.sort_values(by="Total Parking Spaces",ascending=True).head(20)

# %%
less.style.background_gradient(subset='Total Parking Spaces')

# %%
from pandas_profiling import ProfileReport

# %%
to=ProfileReport(data)

# %%
to
