# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("../input/wine-reviews/winemag-data_first150k.csv")

data.head()
# Out:
#    Unnamed: 0           ...                              winery
# 0           0           ...                               Heitz
# 1           1           ...             Bodega Carmen Rodríguez
# 2           2           ...                            Macauley
# 3           3           ...                               Ponzi
# 4           4           ...                Domaine de la Bégude
#
# [5 rows x 11 columns]

# %%
data.isnull().sum()
# Out:
# Unnamed: 0         0
# country            5
# description        0
# designation    45735
# points             0
# price          13695
# province           5
# region_1       25060
# region_2       89977
# variety            0
# winery             0
# dtype: int64

# %%
data.describe()
# Out:
#           Unnamed: 0         points          price
# count  150930.000000  150930.000000  137235.000000
# mean    75464.500000      87.888418      33.131482
# std     43569.882402       3.222392      36.322536
# min         0.000000      80.000000       4.000000
# 25%     37732.250000      86.000000      16.000000
# 50%     75464.500000      88.000000      24.000000
# 75%    113196.750000      90.000000      40.000000
# max    150929.000000     100.000000    2300.000000

# %%
data['province'].value_counts()
# Out:
# California                                44508
# Washington                                 9750
# Tuscany                                    7281
# Bordeaux                                   6111
# Northern Spain                             4892
# Mendoza Province                           4742
# Oregon                                     4589
# Burgundy                                   4308
# Piedmont                                   4093
# Veneto                                     3962
# South Australia                            3004
# Sicily & Sardinia                          2545
# New York                                   2428
# Northeastern Italy                         1982
# Loire Valley                               1786
# Alsace                                     1680
# Marlborough                                1655
# Southwest France                           1601
# Central Italy                              1530
# Southern Italy                             1439
# Champagne                                  1370
# Catalonia                                  1352
# Rhône Valley                               1318
# Colchagua Valley                           1201
# Languedoc-Roussillon                       1082
# Douro                                      1075
# Provence                                   1021
# Port                                        903
# Maipo Valley                                895
# Other                                       889
#                                           ...
# Zitsa                                         1
# Viile Carasului                               1
# Nevada                                        1
# Pannon                                        1
# Morocco                                       1
# Central Greece                                1
# Beni M'Tir                                    1
# Maipo Valley-Colchagua Valley                 1
# Ella Valley                                   1
# Santa Barbara County-Condrieu                 1
# Douro Superior                                1
# Elim                                          1
# Lemnos                                        1
# Vino da Tavola della Svizzera Italiana        1
# Valais                                        1
# Langenlois                                    1
# Vale Trentino                                 1
# Ticino                                        1
# Rose Valley                                   1
# Pocerina                                      1
# Colares                                       1
# Dalmatian Coast                               1
# Malgas                                        1
# Stirling                                      1
# Slovenska Istra                               1
# Sterea Ellada                                 1
# Waitaki Valley                                1
# Krania Olympus                                1
# Serra do Sudeste                              1
# Limnos                                        1
# Name: province, Length: 455, dtype: int64

# %%
info = data['province'].value_counts().head(10)/len(data)

fig,ax = plt.subplots(figsize = (12,6))

ax = plt.bar(info.keys(),info, width=.8)

plt.xlabel("Province")
plt.ylabel("Count")

fig.autofmt_xdate()
plt.show()

# %%
(data['province'].value_counts().head(10)/len(data)).plot.bar()

# %%
info = data['points'].value_counts()

fig,ax = plt.subplots(figsize = (12,6))

ax = plt.bar(info.keys(),info, alpha=.4, color='g')

plt.show()

# %%
data['points'].value_counts().sort_index().plot.line()

# %%
data['points'].value_counts().sort_index().plot.area()

# %%
data[data['price']<200]['price'].plot.hist()

# %%
data['price'].plot.hist()

# %%
data[data['price']>1500]
# Out:
#        Unnamed: 0       ...                  winery
# 13318       13318       ...                   Blair
# 34920       34920       ...          Château Latour
# 34922       34922       ...         Château Margaux
#
# [3 rows x 11 columns]

# %%
data['points'].plot.hist()

# %%
data[data['price']<100].sample(100).plot.scatter(x='price' , y='points')

# %%
data[data['price']<100].plot.hexbin(x='price',y='points', gridsize=15)

# %%
data = pd.read_csv("../input/most-common-wine-scores/top-five-wine-score-counts.csv")

data.head()
# Out:
#    points  Bordeaux-style Red Blend    ...      Pinot Noir  Red Blend
# 0      80                       5.0    ...            36.0       72.0
# 1      81                      18.0    ...            83.0      107.0
# 2      82                      72.0    ...           295.0      223.0
# 3      83                      95.0    ...           346.0      364.0
# 4      84                     268.0    ...           733.0      602.0
#
# [5 rows x 6 columns]

# %%
data.set_index('points',inplace=True)

# %%
data
# Out:
#         Bordeaux-style Red Blend    ...      Red Blend
# points                              ...
# 80                           5.0    ...           72.0
# 81                          18.0    ...          107.0
# 82                          72.0    ...          223.0
# 83                          95.0    ...          364.0
# 84                         268.0    ...          602.0
# 85                         310.0    ...          587.0
# 86                         354.0    ...          871.0
# 87                         510.0    ...         1233.0
# 88                         498.0    ...         1260.0
# 89                         433.0    ...          928.0
# 90                         557.0    ...         1049.0
# 91                         429.0    ...          820.0
# 92                         386.0    ...          555.0
# 93                         250.0    ...          370.0
# 94                         179.0    ...          184.0
# 95                         102.0    ...           85.0
# 96                          37.0    ...           30.0
# 97                          30.0    ...           27.0
# 98                          11.0    ...            4.0
# 99                           1.0    ...            5.0
# 100                          NaN    ...            2.0
#
# [21 rows x 5 columns]

# %%
data.plot.bar(stacked=True,figsize = (12,6))

# %%
data.plot.area()

# %%
data.plot.line()
