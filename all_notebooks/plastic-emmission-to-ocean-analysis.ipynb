# %% [markdown]
# ![](https://images.unsplash.com/photo-1605027538720-37afa8b9fc39?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=750&q=80)

# %% [markdown]
# # Importing Packages and Loading Data

# %%
import numpy as np 
import pandas as pd 
import plotly.express as px

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
path = '/kaggle/input/plastic-input-into-worlds-oceans/plastics-top-rivers.csv'
df = pd.read_csv(path)   #loading the data and converting it to a dataframe

# %% [markdown]
# # Understanding the Data

# %%
df.info()               #Gives info on dataframe about Column Names, Object Type

# %%
df.shape   #3 columns, 50 rows

# %%
df.head(2)

# %%
df.rename(columns={"Entity":"River","sharePlastics":"Plastic_percent"},inplace=True)
df.columns

# %% [markdown]
# This dataset contains percentage of plastic emmssion from 50 rivers to the ocean.

# %%
df.head()

# %%
df.tail()

# %%
df.isna().sum()    #checking for NaN values in dataframe

# %%
df.describe()

# %%
df.describe(include="all")    #describe function for non-numeric columns

# %% [markdown]
# # Visualizing Country vs River

# %%
rivers = df['Country'].value_counts()
River_Total = pd.DataFrame(rivers)
River_Total.head(2)

# %%
River_Total.rename(columns={'Country':'river_total'},inplace=True)
River_Total

# %%
River_Total['river_total'].sum()

# %%
fig = px.bar(River_Total, x=River_Total.index, y="river_total")
fig.show()

# %% [markdown]
# # Analyzing River vs Plastic Share

# %%
fig = px.bar(df,x='River',y='Plastic_percent',color='Country')
fig.show()

# %%
fig = px.scatter(df,x='River',y='Plastic_percent',color='Country')
fig.show()

# %% [markdown]
# ## Treemap

# %%
fig = px.treemap(df, path=['Country','River'], color='Plastic_percent',)
fig.show()

# %%
df['Plastic_percent'].sum()

# %% [markdown]
# # Conclusion
#
# In this notebook, we analyzed a dataset containing 50 rivers vs plastic shares information. Most of them belonging to the continent of Asia. We can conclude easily that only these 50 rivers contibute to approximately **26.99%** of plastic deposition in the Oceans of our planets.
#
# More than 1000 rivers account for 80% of global riverine plastic emmissions into the oceans.[Source](https://advances.sciencemag.org/content/7/18/eaaz5803)
#
# This data may be old. But still this gives us an idea about the water pollution we humans cause. We all know that things are getting out of control.
#
# **WE HAVE ONE PLANET. IT'S OUR RESPONSIBILITY TO SAVE HER!**
