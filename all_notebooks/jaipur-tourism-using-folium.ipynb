# %% [markdown]
# <html>
# <body>
#
# <h1 style="background-color:lightblue;""font-size:300%;">JAIPUR TOURISM GUIDE</h1>
# </body>
# </html>

# %% [markdown]
# <img src="https://wallpapercave.com/wp/wp4917314.jpg" width="2000"/>

# %% [markdown]
# <html>
# <body>
#
# <h1 style="background-color:lightblue;">JAIPUR:</h1>
# <p style="font-family:verdana;">Jaipur, popularly known as the “Pink City”, and “Paris of India”, is the capital of Rajasthan state, India. Jaipur is worldwide famous for unique Architecture, Vastu, Astrology, Forts, Monuments, Palaces, Art and Craft, Culture and last but not least for unique Food.Heritage of year 1727 is still alive in Jaipur which is the main attraction of Jaipur tour.Jaipur is renowned on international tourism map as one vertex of Golden Triangle of Indian tourism. Many scripts and poems have been written on the beauty of Jaipur city by domestic tourists as well as foreign tourists. Countless documentary movies have been made on Jaipur in last 250 years.Main attractions of Jaipur tour are Amber fort, Nahargarh Fort, Jaigarh Fort, Jal Mahal, Hawa Mahal, City Palace, Galta temple, Birla temple, Govind dev ji temple and Albert hall museum for sight seeing.In addition to this, it is best to always check the schedules of fairs and festivals of Jaipur at the time of planning your Jaipur tour so that you can witness colorful fairs and festivals of Jaipur.</p>
# </body>
# </html>

# %% [markdown]
# <html>
# <body>
#
# <h1 style="background-color:beige;">NOTE: This whole notebook is going to be done using the folium library. The tile chosen is OPEN STREET STYLE because its easy to navigate between sites. HOVER DATA has also been added, to check, click on the icon. I've used custom icons also so check out the whole notebook.</h1>
# </body>
# </html>

# %% [markdown]
# <html>
# <body>
#
# <h1 style="background-color:lightblue;">Import necessary packages</h1>
# </body>
# </html>

# %%
import pandas as pd
import folium

# %% [markdown]
# <html>
# <body>
#
# <h1 style="background-color:lightblue;">Reading the data:</h1>
# </body>
# </html>

# %%
hotels = pd.read_csv("../input/jaipur-attractions-and-hotels/Hotels.csv")
places = pd.read_csv("../input/jaipur-attractions-and-hotels/Places.csv")
types = pd.read_csv("../input/jaipur-attractions-and-hotels/Types.csv")

# %% [markdown]
# <html>
# <body>
#
# <h1 style="background-color:pink;">HOTEL RECOMMENDATIONS:</h1>
# </body>
# </html>

# %%
hotels.head()

# %% [markdown]
# **We're going to consider price and the reviews columns for the recommendation. Both the features are going to be categorized into 3 categories based on quantiles.**

# %%
cut_labels = ['Low','Moderate','High']
hotels['Budget'] = pd.qcut(hotels['PRICE_RUPEES'][hotels['PRICE_RUPEES']>0],q=[0,.25, .75, 1], labels=cut_labels).astype("object")
hotels['Popularity'] = pd.qcut(hotels['NUMBER_OF_REVIEWS'][hotels['NUMBER_OF_REVIEWS']>0],q=[0,.25, .75, 1], labels=cut_labels).astype("object")

# %%
hotels.head()

# %%
hotels['Budget'].value_counts()

# %% [markdown]
# <html>
# <body>
#
# <h1 style="background-color:lightblue;">Recommending Low budget Hotels:</h1>
# </body>
# </html>

# %%
print("You can refer and type the budget levels from above!")
p = str(input("Enter your budget: "))
    
data = hotels[hotels['Budget'] == p]

jaipur_map = folium.Map(location=[26.9124, 75.7873], zoom_start=12,tiles='openstreetmap')
for lat, lon, name, price, popularity in zip(data['Lat'], data['Lng'], data['HOTEL'],data['PRICE_RUPEES'],data['Popularity']):

    folium.Marker([lat, lon],
                        radius=10,
                        popup = ('<strong>Hotel</strong>: ' + str(name) + '<br>'
                                '<strong>Price</strong>: ' + str(price) + '<br>'
                                '<strong>Popularity</strong>: ' + str(popularity) + '<br>'),
                     icon=folium.Icon(color="red",icon="hotel", prefix='fa')).add_to(jaipur_map)
jaipur_map

# %% [markdown]
# <html>
# <body>
#
# <h1 style="background-color:lightblue;">Recommending Moderate budget Hotels:</h1>
# </body>
# </html>

# %%
print("You can refer and type the budget levels from above!")
p = str(input("Enter your budget: "))
    
data = hotels[hotels['Budget'] == p]

jaipur_map = folium.Map(location=[26.9124, 75.7873], zoom_start=12,tiles='openstreetmap')
for lat, lon, name, price, popularity in zip(data['Lat'], data['Lng'], data['HOTEL'],data['PRICE_RUPEES'],data['Popularity']):

    folium.Marker([lat, lon],
                        radius=10,
                        popup = ('<strong>Hotel</strong>: ' + str(name) + '<br>'
                                '<strong>Price</strong>: ' + str(price) + '<br>'
                                '<strong>Popularity</strong>: ' + str(popularity) + '<br>'),
                     icon=folium.Icon(color="blue",icon="cutlery", prefix='fa')).add_to(jaipur_map)
jaipur_map

# %% [markdown]
# <html>
# <body>
#
# <h1 style="background-color:lightblue;">Recommending High Budget Hotels:</h1>
# </body>
# </html>

# %%
print("You can refer and type the budget levels from above!")
p = str(input("Enter your budget: "))
    
data = hotels[hotels['Budget'] == p]

jaipur_map = folium.Map(location=[26.9124, 75.7873], zoom_start=12,tiles='openstreetmap')
for lat, lon, name, price, popularity in zip(data['Lat'], data['Lng'], data['HOTEL'],data['PRICE_RUPEES'],data['Popularity']):

    folium.Marker([lat, lon],
                        radius=10,
                        popup = ('<strong>Hotel</strong>: ' + str(name) + '<br>'
                                '<strong>Price</strong>: ' + str(price) + '<br>'
                                '<strong>Popularity</strong>: ' + str(popularity) + '<br>'),
                     icon=folium.Icon(color='purple',icon="glass", prefix='fa')).add_to(jaipur_map)
jaipur_map

# %% [markdown]
# **The same code can be used for recommending hotels based on popularity**

# %% [markdown]
# <html>
# <body>
# ​
# <h1 style="background-color:lightblue;">SYMBOLS USED:</h1>
# </body>
# </html>

# %% [markdown]
# [https://fontawesome.com/v4.7/icons/](http://)

# %% [markdown]
# <html>
# <body>
#
# <h1 style="background-color:pink;">TOURIST SPOTS RECOMMENDATIONS:</h1>
# </body>
# </html>

# %%
df =  pd.merge(places, types , on=["PID",'POIs'])
df.head()

# %%
df['PRIORITY_1'].value_counts()

# %% [markdown]
# **THE FOLLOWING VISUALIZATIONS ARE ONLY BASED ON MY PRIORITIES**

# %% [markdown]
# <html>
# <body>
#
# <h1 style="background-color:lightblue;">FIRST PRIORITY:</h1>
# </body>
# </html>

# %% [markdown]
# <img src="https://navbharattimes.indiatimes.com/photo/msid-84289295,imgsize-123/pic.jpg" width="2000"/>

# %%
print("You can refer and type the priorities from above!")
p = str(input("Enter your priority: "))
    
data = df[df['PRIORITY_1'] == p]


logo_url = 'https://www.makemytrip.com/travel-guide/media/dg_image/jaipur/thumb/Paragliding_425791_14_jaipur_218_168.jpg'
jaipur_map = folium.Map(location=[26.9124, 75.7873], zoom_start=12,tiles='openstreetmap')
for lat, lon, name, intime1, outtime1,intime2, outtime2 in zip(data['LATITUDE'], data['LONGITUDE'], data['POIs'],data['IN-TIME1'],data['OUT-TIME1'],data['IN-TIME2'],data['OUT-TIME2']):
    icon = folium.features.CustomIcon(logo_url,\
                                  icon_size=(50,50))

    folium.Marker([lat, lon],
                        radius=10,
                        popup = ('<strong>Place</strong>: ' + str(name) + '<br>'
                                '<strong>In Time 1</strong>: ' + str(intime1) + '<br>'
                                '<strong>Out Time 1</strong>: ' + str(outtime1) + '<br>'
                                '<strong>In Time 2</strong>: ' + str(intime2) + '<br>'
                                '<strong>Out Time 2</strong>: ' + str(outtime2) + '<br>'),
                     icon= icon).add_to(jaipur_map)
jaipur_map

# %% [markdown]
# <html>
# <body>
#
# <h1 style="background-color:lightblue;">SECOND PRIORITY:</h1>
# </body>
# </html>

# %% [markdown]
# <img src="https://www.holidify.com/images/cmsuploads/compressed/shutterstock_1031572588_20200219165610_20200219165630.jpg" width="2000"/>

# %%
print("You can refer and type the priorities from above!")
p = str(input("Enter your priority: "))
    
data = df[df['PRIORITY_2'] == p]


logo_url = 'https://lh3.googleusercontent.com/proxy/kBrclZFYSEe9xHOK5dUktAdNe4l1swJyGmf-kh0UeaP-aMUUsp-SY94wFBbQcQsTga-R4qCwjfN6WtrhfCDJVqhSL69N39jQWyDn'
jaipur_map = folium.Map(location=[26.9124, 75.7873], zoom_start=12,tiles='openstreetmap')
for lat, lon, name, intime1, outtime1,intime2, outtime2 in zip(data['LATITUDE'], data['LONGITUDE'], data['POIs'],data['IN-TIME1'],data['OUT-TIME1'],data['IN-TIME2'],data['OUT-TIME2']):
    icon = folium.features.CustomIcon(logo_url,\
                                  icon_size=(50,50))

    folium.Marker([lat, lon],
                        radius=10,
                        popup = ('<strong>Place</strong>: ' + str(name) + '<br>'
                                '<strong>In Time 1</strong>: ' + str(intime1) + '<br>'
                                '<strong>Out Time 1</strong>: ' + str(outtime1) + '<br>'
                                '<strong>In Time 2</strong>: ' + str(intime2) + '<br>'
                                '<strong>Out Time 2</strong>: ' + str(outtime2) + '<br>'),
                     icon= icon).add_to(jaipur_map)
jaipur_map

# %% [markdown]
# <html>
# <body>
#
# <h1 style="background-color:lightblue;">THIRD PRIORITY:</h1>
# </body>
# </html>

# %% [markdown]
# <img src="https://k6u8v6y8.stackpathcdn.com/blog/wp-content/uploads/2017/12/Johari-Market-Jaipur.jpg" width="2000"/>

# %%
print("You can refer and type the priorities from above!")
p = str(input("Enter your priority: "))
    
data = df[df['PRIORITY_3'] == p]


logo_url = 'https://i.pinimg.com/originals/ff/da/81/ffda81a5c2d5ff9ec4ff367e19b4dcff.png'
jaipur_map = folium.Map(location=[26.9124, 75.7873], zoom_start=12,tiles='openstreetmap')
for lat, lon, name, intime1, outtime1,intime2, outtime2 in zip(data['LATITUDE'], data['LONGITUDE'], data['POIs'],data['IN-TIME1'],data['OUT-TIME1'],data['IN-TIME2'],data['OUT-TIME2']):
    icon = folium.features.CustomIcon(logo_url,\
                                  icon_size=(50,50))

    folium.Marker([lat, lon],
                        radius=10,
                        popup = ('<strong>Place</strong>: ' + str(name) + '<br>'
                                '<strong>In Time 1</strong>: ' + str(intime1) + '<br>'
                                '<strong>Out Time 1</strong>: ' + str(outtime1) + '<br>'
                                '<strong>In Time 2</strong>: ' + str(intime2) + '<br>'
                                '<strong>Out Time 2</strong>: ' + str(outtime2) + '<br>'),
                     icon= icon).add_to(jaipur_map)
jaipur_map

# %% [markdown]
# <html>
# <body>
#
# <h1 style="background-color:lightblue;">FOURTH PRIORITY: </h1>
# </body>
# </html>

# %% [markdown]
# <img src="https://www.tripsavvy.com/thmb/fl8wMHV9O6s3nxYvpc8vvzj56X0=/950x0/filters:no_upscale():max_bytes(150000):strip_icc():format(webp)/GettyImages-1020911848-ed965f07c858439d8cfb33c461ac104b.jpg" width="2000"/>

# %%
print("You can refer and type the priorities from above!")
p = str(input("Enter your priority: "))
    
data = df[df['PRIORITY_4'] == p]


logo_url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRErpg_T34TMB3Gaslge6ALFa9z70TKKlz9Mg&usqp=CAU'
jaipur_map = folium.Map(location=[26.9124, 75.7873], zoom_start=12,tiles='openstreetmap')
for lat, lon, name, intime1, outtime1,intime2, outtime2 in zip(data['LATITUDE'], data['LONGITUDE'], data['POIs'],data['IN-TIME1'],data['OUT-TIME1'],data['IN-TIME2'],data['OUT-TIME2']):
    icon = folium.features.CustomIcon(logo_url,\
                                  icon_size=(50,50))

    folium.Marker([lat, lon],
                        radius=10,
                        popup = ('<strong>Place</strong>: ' + str(name) + '<br>'
                                '<strong>In Time 1</strong>: ' + str(intime1) + '<br>'
                                '<strong>Out Time 1</strong>: ' + str(outtime1) + '<br>'
                                '<strong>In Time 2</strong>: ' + str(intime2) + '<br>'
                                '<strong>Out Time 2</strong>: ' + str(outtime2) + '<br>'),
                     icon= icon).add_to(jaipur_map)
jaipur_map

# %% [markdown]
# <html>
# <body>
#
# <h1 style="background-color:lightblue;">FIFTH PRIORITY:</h1>
# </body>
# </html>

# %% [markdown]
# <img src="https://www.jaipurcityblog.com/wp-content/uploads/2020/07/600x400-17-1280x720.jpg" width="2000"/>

# %%
print("You can refer and type the priorities from above!")
p = str(input("Enter your priority: "))
    
data = df[df['PRIORITY_5'] == p]


logo_url = 'https://hips.hearstapps.com/delish/assets/17/31/1501791674-delish-chicken-curry-horizontal.jpg'
jaipur_map = folium.Map(location=[26.9124, 75.7873], zoom_start=12,tiles='openstreetmap')
for lat, lon, name, intime1, outtime1,intime2, outtime2 in zip(data['LATITUDE'], data['LONGITUDE'], data['POIs'],data['IN-TIME1'],data['OUT-TIME1'],data['IN-TIME2'],data['OUT-TIME2']):
    icon = folium.features.CustomIcon(logo_url,\
                                  icon_size=(50,50))
    folium.Marker([lat, lon],
                        radius=10,
                        popup = ('<strong>Place</strong>: ' + str(name) + '<br>'
                                '<strong>In Time 1</strong>: ' + str(intime1) + '<br>'
                                '<strong>Out Time 1</strong>: ' + str(outtime1) + '<br>'
                                '<strong>In Time 2</strong>: ' + str(intime2) + '<br>'
                                '<strong>Out Time 2</strong>: ' + str(outtime2) + '<br>'),
                     icon= icon).add_to(jaipur_map)
jaipur_map

# %% [markdown]
# <html>
# <body>
# ​
# <h1 style="background-color:lightblue;">CREDITS TO ALL THE OWNERS OF THE PICTURES USED IN THIS NOTEBOOK. PICTURES TAKEN FROM GOOGLE</h1>
# </body>
# </html>
