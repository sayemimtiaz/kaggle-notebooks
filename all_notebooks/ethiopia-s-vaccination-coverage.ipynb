# %% [markdown]
# #Determinants of BCG vaccination coverage in Ethiopia: a cross-sectional survey.
#
# Authors: Tsehay, Asmamaw Ketemaw; Worku, Getasew Tadesse; Alemu, Yihun Mulugeta.
# BMJ Open ; 9(2): e023634, 2019 02 21.
#
# RESULT:
#
# Out of the study participants (n=5304), the majority were in between 20 and 34 years of age (73.8 per cent). The median age of the respondents was 28.4 (SD=±6.5) years old. Prevalence of BCG vaccination was 63.6 per cent (n=3373) and BCG vaccination coverage in urban residents was higher (88 per cent) than rural residents (57.3 per cent). Mothers' age between 20 up to 34 (Adjusted odds ratio (AOR)=1.48; 95 per cent CI 1.13 to 1.93) and between 35 up to 49 (AOR=1.83; 95 per cent CI 1.35 to 2.46) were more likely to vaccinate their child's than those mothers' age less than 20. Mothers settled in urban areas were two times more likely to vaccinate their child's than those living in rural areas (AOR=1.94; 95 per cent CI 1.45 to 2.60). Mothers with greater antenatal visits show higher BCG vaccination, Antenatal Care (ANC) 4 and above (AOR=3.48; 95 per cent CI 2.91 to 4.15). BCG vaccination is higher for mothers delivered at non-governmental organisation health facility than home (AOR=2.9; 95 per cent CI 1.69 to 4.96). Maternal occupation and wealth index also had a significant association with BCG vaccination.
#
# CONCLUSION:
#
# BCG vaccination coverage, in this study, was lower and determinant factors for BCG vaccination were residence, mother's age, place of delivery, mother's antenatal visit, wealth index and mother's occupation.https://pesquisa.bvsalud.org/portal/resource/pt/mdl-30796120

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSuMrlQ9BrZEmA57v2jjlnRF_MK5wiq4NdwCw&usqp=CAU)
# slideserve.com

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# #Deaths in protests over singer death in Ethiopia. Military personnel are sent to the capital.
#
# Among the victims are agents of the security forces; some protesters started to circulate armed.Updated 03/07/2020
#
# ADIS ABEBA - More than 80 people died during the demonstrations in the Oromia region of Ethiopia after the murder of singer and songwriter Haacaaluu Hundeessaa. He is the author of songs that formed the soundtrack to the protests that toppled the former government in 2018. With the new government, there is more political freedom and the country's prime minister, Abiy Ahmed received the Nobel Peace Prize in 2019 for ending the war with neighboring Eritrea.
#
# Political tension has also increased with the postponement to 2021 of the elections scheduled for this year, due to the Covid-19 pandemic.https://translate.google.com.br/translate?hl=en&sl=pt&u=https://oglobo.globo.com/mundo/mortos-em-protestos-pela-morte-de-cantor-na-etiopia-passam-de-80-militares-sao-enviados-capital-24509146&prev=search&pto=aue

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTJvvWeZ1oX4OQSliCh9wTg2iaiGzcAfkl0tA&usqp=CAU)bbc.com
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQIKQuc1avcFEIRLJZPyoQ-F8hE37ob4neIrg&usqp=CAU)kichuu.com

# %%
ls ../input/hackathon/task_1-google_search_txt_files_v2/ET/

# %%
df1 = pd.read_table("/kaggle/input/hackathon/task_1-google_search_txt_files_v2/ET/Ethiopia-en-result-109-original.txt",header=None)
df1.head()

# %%
print(df1[:2500])

# %%
df = pd.read_csv('../input/hackathon/task_2-Tuberculosis_infection_estimates_for_2018.csv', encoding='utf8')
df.head()

# %%
ethiopia = df[(df['country']=='Ethiopia')].reset_index(drop=True)
ethiopia.head()

# %%
ethiopia.columns.tolist()

# %%
ax = ethiopia['e_prevtx_kids_pct_hi'].value_counts().plot.barh(figsize=(14, 6))
ax.set_title('Ethiopian Kids High Procalcitonin Levels', size=18)
ax.set_ylabel('e_prevtx_kids_pct_hi', size=14)  
ax.set_xlabel('count', size=14)

# %% [markdown]
# #Use of Procalcitonin (PCT) in the Diagnosis of Tuberculosis in Infants and Preschool Children
#
# Authors: Eneritz Velasco-Arnaiz, Esther Pérez, Desirée Henares , Anna Fernández-López, Anna Valls, Pedro Brotons , Clàudia Fortuny, Antoni Noguera-Julian - PMID:29374831 DOI: 10.1007/s00431-018-3099-9
#
# Normal procalcitonin (PCT) levels have been reported in adult pulmonary tuberculosis (TB) but have not been previously investigated in children. They aimed to assess PCT levels at diagnosis of TB in young children in a low-burden setting. In a cross-sectional observational study,they assessed the value of PCT and other inflammatory markers (leucocyte counts, C-reactive protein, and erythrocyte sedimentation rate) in the diagnosis of TB in pre-school children (< 6 years at diagnosis, n = 45), as compared with two control groups (pneumococcal pneumonia, n = 25; and healthy controls, n = 49).
#
# Normal PCT levels were observed at diagnosis of TB in most cases, while C-reactive protein values and leucocyte counts were slightly elevated when compared to healthy controls. All three inflammatory biomarkers were significantly higher in children with pneumococcal pneumonia.
#
# Conclusions: In their study, PCT was not a useful diagnostic test for TB in young children. In a low-burden TB setting, PCT may be of some value in distinguishing pulmonary TB from pneumococcal pneumonia. What is Known: Diagnosis of pediatric tuberculosis on clinical evidence is difficult, particularly in infants and small children;;; Studies in adults with tuberculosis have mostly reported normal procalcitonin levels at diagnosis. What is New: • In pre-scholars with tuberculosis, erythrocyte sedimentation rate and white blood cell counts were higher than in healthy controls, but procalcitonin was not. • Procalcitonin may be useful in the differential diagnosis of intrathoracic tuberculosis and pneumococcal pneumonia.https://pubmed.ncbi.nlm.nih.gov/29374831/

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(x="prevtx_data_available",data=ethiopia,palette="GnBu_d",edgecolor="black")
plt.xticks(rotation=45)
plt.yticks(rotation=45)
# changing the font size
sns.set(font_scale=1)

# %%
sns.countplot(ethiopia['e_prevtx_eligible_hi'],linewidth=3,palette="Set2",edgecolor='black')
plt.xticks(rotation=45)
plt.show()

# %%
df2 = pd.read_csv('../input/hackathon/BCG_world_atlas_data-2020.csv')
df2.head()

# %%
Ethiopia = df2[(df2['Contry Name (Mandatory field)']=='Ethiopia')].reset_index(drop=True)
Ethiopia.head()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(x="Vaccination Timing (age)",data=Ethiopia,palette="binary",edgecolor="black")
plt.xticks(rotation=45)
plt.yticks(rotation=45)
# changing the font size
sns.set(font_scale=1)

# %%
sns.countplot(Ethiopia['Are/were revaccinations (boosters) recommended?'],linewidth=3,palette="Wistia",edgecolor='black')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #Tuberculin Survey in Ethiopia, by M Azbite -PMID: 1405182
#
# For planning and implementation of effective national tuberculosis control programme (NTP) in Ethiopia, it is essential to know the real magnitude of tuberculosis problem. Previous tuberculin survey carried out during the period from 1953 to 1955 revealed the annual risk of infection 3.0 per cent, and since then, there has been no survey. A new tuberculin survey was thus conducted during the period from December 1987 to April 1990. In order to get a sample of 47 previously BCG unvaccinated children, aged 6 to 10 years, selected from each 480 representative clusters of randomly selected 16 Woredas (districts), a total of 26,529 children, approximately 55 in each cluster, were given tuberculin intradermal injection, and the reaction was read in 26,269 children (99.0 per cent). A scar survey was done, and 23,695 had no BCG scar, while 2,574 (10.1 per cent) had BCG scar. Out of the former, 2,503 children (10.6 per cent) were positive, and the annual risk of infection thus calculated was 1.4 per cent. Out of the latter, 591 (23.0 per cent) were positive. The results of these two surveys indicate that tuberculosis showed decline in the past 37 years with the annual reduction rate of 2.2 per cent, however, the trend might change in the future due to present pandemic of HIV infection.
#
# PIP: Between December 1987 and April 1990, health workers administered a tuberculin test to 26,529 6-to-10-year-old children in 16 districts (Woredas) of Ethiopia to obtain a sample of 47 children who had not received a BCG vaccination earlier. They were able to read the reaction in 99 per cent of the children. 2574 (10.1 per cent) children had a BCG scar and 591 (23 per cent) of them tested positive for tuberculosis. 2503 (10.6 per cent) of the 23,695 children who did not have a BCG scar tested positive for tuberculosis. Tuberculin positivity was highest in Deder Woreda (Harrarghe Region) and lowest in Wuchale Woreda (Shoa Region) (27.9 per cent vs. 2 per cent). In fact, prevalence was higher in urban areas than rural areas, suggesting overcrowding's effect on transmission. The last tuberculin survey in Ethiopia occurred in 1953-1955, at which time the prevalence was much higher than in 1988-1990 (30 per cent vs. 10.6 per cent). In addition, the annual risk of infection was higher (3 per cent vs. 1.4 per cent). Between the 2 surveys the prevalence of tuberculosis fell at a rate of 2.2 per cent/year. Yet, the HIV infection pandemic in Ethiopia threatened that downward trend. The cost of chemoprophylactic drugs and lack of sufficient laboratory facilities posed a problem for Ethiopia's National Tuberculosis Control Programme.https://pubmed.ncbi.nlm.nih.gov/1405182/

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcR7pg6lctOmgZ4PohlXRydAraV6XNqO_6idmA&usqp=CAU)
# tbhivfoundation.org

# %% [markdown]
# Das War's Kaggle Notebook Runner: Marília Prata @mpwolke
