# %% [markdown]
# My inspiration was the movie/documentary: "This Changes Everything" where gender disparity was the debated topic. Many celebrities use their voices to talk about inequality in Hollywood. And "The Geena Davis Institute on Gender in Media - See Jane" https://seejane.org

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTB-xgjxl7byNUrjOCPGtG7AVX2hC33-5hwin0i35srIahqE76Ldg&s',width=400,height=400)

# %% [markdown]
# Image cannypic.com

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/png;base64,...',width=400,height=400)

# %% [markdown]
# Image media-marketing.com

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
df = pd.read_csv('../input/cusersmarildownloadscinemacsv/cinema.csv', delimiter=';', encoding = "ISO-8859-1", nrows = nRowsRead)
df.dataframeName = 'cinema.csv'
nRow, nCol = df.shape
print(f'There are {nRow} rows and {nCol} columns')

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/png;base64,...',width=400,height=400)

# %% [markdown]
# Image GeenaDavisInstitute on twitter. https://seejane.org

# %%
df.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://assets.b9.com.br/wp-content/uploads/2019/06/nick-law2-cannes-2019.jpg',width=400,height=400)

# %% [markdown]
# **THE NEW GRAMMAR**
# * "When did creative people stop leading? The internet has been creating formats of mediums and doing innovations and it is the creative people who should have been mastering these mediums.  It’s a whole new grammar and we should be leading it. Creative people should be mastering all forms of media.  Both the operational and creative people should work in collaboration.” https://bestmediainfo.com/2019/06/cannes-lions-2019-nick-law-on-why-separation-of-media-and-creative-was-industry-s-biggest-original-sin/

# %%
df.info()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://assets.b9.com.br/wp-content/uploads/2019/06/disney-bp.jpg',width=400,height=400)

# %% [markdown]
# Image Plano estrutural da Disney 1957.

# %%
categorical_cols = [cname for cname in df.columns if
                    df[cname].nunique() < 10 and 
                    df[cname].dtype == "object"]


# Select numerical columns
numerical_cols = [cname for cname in df.columns if 
                df[cname].dtype in ['int64', 'float64']]

# %%
print(numerical_cols)

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# Image techcrunch.com

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSVX7orNLnNni1XAaR3YSzP8JczHWVcTp8ZOffENN3Du2FFBY1BuA&s',width=400,height=400)

# %% [markdown]
# Image crello.com

# %%
# Number of each type of column
df.dtypes.value_counts()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSmalT-ZdKlUU18OooLBzLSKf7nWcr_xGrqNdXCPsSqaXgfUl5AcQ&s',width=400,height=400)

# %% [markdown]
# Image panoramaaudiovisual.com

# %%
import plotly.offline as pyo
import plotly.graph_objs as go
lowerdf1 = df.groupby('total').size()/df['EUA'].count()*100
labels = lowerdf1.index
values = lowerdf1.values

# Use `hole` to create a donut-like pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=.6)])
fig.show()

# %%
plt.figure(figsize=(16,10))
sns.scatterplot(x='year',y='Portugal',data=df)
plt.xticks(rotation=90)
plt.yticks(rotation=45)
plt.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSzy27uiWnDJUvpzOUfh9XImNAKRb4rMbrV8Xy22-7KSpcsm7BJAg&s',width=400,height=400)

# %% [markdown]
# Image en.wikipedia.org

# %%
sns.countplot(df["Spain"])
plt.xticks(rotation=90)
plt.show()

# %%
labels1=df.EUA.value_counts().index
sizes1=df.EUA.value_counts().values
plt.figure(figsize=(11,11))
plt.pie(sizes1,labels=labels1,autopct="%1.1f%%")
plt.title("EUA",size=15)
plt.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR0Z4uD0gEtJ7F3zkBc7rB2QinTU1jwFRRhMJXlzhIboTHpu-3voQ&s',width=400,height=400)

# %% [markdown]
# Image eeas.europa.eu

# %%
subject = 'total','UK'
perc = [100-((96/303)*100),(96/303)*100]
explode = (0,0.1)
plt.pie(perc,explode=explode,labels=subject,autopct='%1.2f%%',shadow=True)
plt.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSW5rMAPGzTidYE9jjmXJQ96aqIfIaP-jdbE5BH7qP51PM_EqY&s',width=400,height=400)

# %% [markdown]
# Image adassoc.org.uk

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSHYyePaCOnyCq4DrrH7KQ00s9DVNJLCZtr3Ds4iEu8BO7YjW4l&s',width=400,height=400)

# %% [markdown]
# Image editorial.rottentomatoes.com
# * What about my Notebook Jaws 2020? After predicting "Chrissy's last swim" and vectorizing Shark+Tornado, not bad. https://www.kaggle.com/mpwolke/jaws-2020

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ8rO75KIBaoAzB6LfrsjJwKfHahbFlJkCeRDNGL1HIjATtY7OD&s',width=400,height=400)

# %% [markdown]
# Image sputniknews.com
# * Guess Who Won the Golden Raspberry Award This Time?
# Founded nearly four decades ago by John J. B. Wilson and Mo Murphy, the Golden Raspberry Awards (also known as Razzies and Razzie Awards) is a mock award in recognition of the worst in film. With the first ceremony held on March 31, 1981, the Razzie Awards are presented annually in Los Angeles, preceding the corresponding Academy Awards ceremony by one day. https://sputniknews.com/viral/201803031062192960-movies-mock-award-presentation/
# * Razzies nominees. Worst Kaggle Notebook: "Competitions are Rock'n'Roll". https://www.kaggle.com/mpwolke/competitions-are-rock-n-roll It was an optimization competition! What kind of optimization was that? Worst supporting Kaggle user: Marília Prata aka mpwolke. She is a DDS not a DS.

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTUkPePjY_3Iza-uI2758eZiZqgDWd1erlqeblO7HZyO2f_eFlwhw&s',width=400,height=400)

# %% [markdown]
# Image rga.com

# %% [markdown]
# Kaggle Notebook Runner: Marília Prata  @mpwolke
