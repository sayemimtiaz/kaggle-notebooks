# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline
import random
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.colors import n_colors
from plotly.subplots import make_subplots
init_notebook_mode(connected=True)
import cufflinks as cf
cf.go_offline()
from wordcloud import WordCloud , ImageColorGenerator
from PIL import Image

# %% [markdown]
# # QUESTION 2 AND 4.

# %%
df=pd.read_csv('/kaggle/input/indian-food-101/indian_food.csv')
df

# %% [markdown]
# # Find the number of dishes based on regions. Draw histogram to represent the same.

# %%
reg_df = df.region.value_counts().reset_index()
reg_df.columns = ['region','count']
reg_df = reg_df.sample(frac=1)
fig = px.bar(reg_df,x='region',y='count',title=' dishes based on regions',
             color_discrete_sequence=['#316394'])
fig.show()

# %% [markdown]
# # #Identify proportion of flavor. Represent using pie chart.

# %%
pie_df = df.flavor_profile.value_counts().reset_index()
pie_df.columns = ['flavor','count']
fig = px.pie(pie_df, values='count', names='flavor', title='Proportion of Flavor Profiles',
             color_discrete_sequence=['#FF7F0E', '#00B5F7','#AB63FA','#00CC96'])
fig.show()
