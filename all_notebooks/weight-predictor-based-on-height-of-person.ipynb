# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Weight predictor by Vikram Jeet Singh

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
url='/kaggle/input/heights-and-weights/data.csv'
data=pd.read_csv(url)
data

# %%
data.describe()

# %%
x=data['Height'].to_numpy()
y=data['Weight'].to_numpy()
x=x.reshape(-1,1)
y=y.reshape(-1,1)
y

# %%
plt.plot(x,y)
plt.xlabel('Height')
plt.ylabel('Weight')
plt.title('Height vs Weight')

# %% [markdown]
# From here we can see that there is a direct relationship between the height and weight, so let's use this data and create a machine learning model from this.

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
print('Model Trained')

# %%
line=model.coef_*x+model.intercept_
plt.plot(x,line)
plt.scatter(x,y)
plt.xlabel('Height')
plt.ylabel('Weight')
plt.title('Height vs Weight')
plt.show()

# %% [markdown]
# From here we can obsserve that our model is somewhat correct in representing the data, except a little noise, which is always there in ML models.

# %%
y_test

# %%
y_pred=model.predict(x_test)
y_pred

# %%
df=pd.DataFrame(data={'Actual Values':y_test.flatten(),'Predicted Values':y_pred.flatten()})
df

# %% [markdown]
# As we can see that the predicted values are almost equal to the actual values, with a very small deflection, so lets check now how much these values are different from the actual values. Let's calculate MAE(Mean Absolute Error)

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test,y_pred)
print(mae)

# %% [markdown]
# From here we can see that the mean absolute error is very less and our model was successful.

# %% [markdown]
# We can use this model to predict the weight of any height and it will predict the weight based on that height.
# Lets try an example.

# %%
target=[[1.778]] #let us assume that a person's height is this and let's predict the weight.
pred=model.predict(target)
print('The predicted weight is ',pred)

# %% [markdown]
# ## Hence, the precicted weight for a person whose height is 1.778 meters is 69.7556965 Kg.

# %% [markdown]
# # You can use this model to predict the approximate weight of any person based on the height of the person.
