# %% [markdown]
# # Practice:

# %% [markdown]
# Being a very simple , small , and a highly descriptive dataset this is a very good place to start practising your data skills that you have picked up recently , this dataset is a ver good asset to practice your skills as it is a real world dataset with minimal data cleaning tasks.

# %% [markdown]
# # EXAMPLE :

# %% [markdown]
# > This is a very basic notebook writen to just serve as a basic rudimentary example on some use cases of the dataset

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
data =pd.read_csv("../input/uk-fuel-price-weekly-statistics20032020/fuel price.csv")
data

# %%
data.drop(columns = "Unnamed: 0",inplace=True)

# %%
data.describe()

# %% [markdown]
# as you can observe that std dev of ULSD > ULSP , from this we can understand that ULSP is more prone to change than the price of ULSD.
