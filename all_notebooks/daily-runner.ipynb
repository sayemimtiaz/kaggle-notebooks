# %%
# !pip install torchsummary
# !pip install xlrd==1.2.0

# %%
# !cp -r ../input/thesis-v2/run/* ./
# !cp -r ../input/fix-st/* ./pytorch/
# !cp ../input/data1409/SEIRD_data_12_7_2021.xlsx ./COVID-19/HCM

# %%
# %cd ./pytorch

# %%
#xuat ket qua ngay 11/9: 107 102 
# !bash run.sh 109 104
