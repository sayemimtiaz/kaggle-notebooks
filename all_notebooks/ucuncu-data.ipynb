# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pnd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.

# %%
data1 = pnd.read_csv('../input/game.csv')
data2 = pnd.read_csv('../input/team_info.csv')
data3 = pnd.read_csv('../input/game_plays.csv')
data4 = pnd.read_csv('../input/player_info.csv')
data5 = pnd.read_csv('../input/game_teams_stats.csv')

# %%
data1.head()

# %%
data1.corr()

# %%
data1.columns

# %%
data1.info()

# %%
f,ax = plt.subplots(figsize=(20,10))
sns.heatmap(data1.corr(), annot=True, linewidths=.5, fmt='.1f',ax=ax)
plt.show()

# %%
data1.home_team_id.plot(kind = 'line', color = 'g',label = 'home_team_id', linewidth = 1, alpha = 0.5, grid = True, linestyle = ':')
data1.home_goals.plot(color='r',label = 'home_goals', linewidth= 1, alpha = 0.5, grid = True, Linestyle='-.')
plt.legend(loc='upper right')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Line Plot')#doğru sütunları alabilmek için daha fazla bilgi ve tecrübe edinmemiz gerekiyor.

# %%
plt.scatter(data1.away_team_id,data1.away_goals,color='r')

# %%
data1.home_goals.plot(kind = 'hist', bins = 50, figsize= (15,15), color = 'b')

# %%
data2.head()#üçüncü deneme de aklımıza geldi diğer csv dosyalarına bakmak.+exp

# %%
data2.info()

# %%
data2.columns

# %%
data2.corr()

# %%
f,ax = plt.subplots(figsize=(20,10))
sns.heatmap(data2.corr(), annot=True, linewidths=.5, fmt='.1f',ax=ax)
plt.show()

# %%
plt.scatter(data2.team_id,data2.franchiseId,color='green')

# %%
data2.franchiseId.plot(kind = 'hist', bins = 75, figsize= (15,15), color = 'm')

# %%
data3.head(10)

# %%
data3.info()

# %%
data3.columns

# %%
f,ax = plt.subplots(figsize=(25,15))
sns.heatmap(data3.corr(), annot=True, linewidths=.5, fmt='.1f',ax=ax)
plt.show()

# %%
data4.head()

# %%
data4.info()

# %%
data4.corr()

# %%
data4.columns

# %%
f,ax = plt.subplots(figsize=(20,10))
sns.heatmap(data4.corr(), annot=True, linewidths=.5, fmt='.1f',ax=ax)
plt.show()

# %%
data5.head()

# %%
f,ax = plt.subplots(figsize=(20,10))
sns.heatmap(data5.corr(), annot=True, linewidths=.5, fmt='.1f',ax=ax)
plt.show()

# %%
data5.corr()

# %%
data5.head()

# %%
data5.info()

# %%
data5.columns

# %%
data5.shots.plot(kind = 'line', color = 'g',label = 'shots', linewidth = 1, alpha = 0.5, grid = True, linestyle = ':')
data5.hits.plot(color='r',label='hits',linewidth= 1, alpha = 0.5, grid = True, Linestyle='-.')
plt.legend(loc='upper right')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Line Plot')

# %%
data5.plot(kind = 'scatter',x = 'shots', y = 'hits', color = 'g',label = 'shots', linewidth = 1, alpha = 0.5, grid = True, linestyle = ':')
plt.xlabel('shots')
plt.ylabel('hits')
plt.title('Scatter Learning')

# %%
plt.scatter(data5.shots,data5.hits)

# %%
data5.shots.plot(kind = 'hist', bins = 150, figsize= (15,15), color = 'y')

# %%
ne öğrendiysem mantıksal sezgisel denemeye çalıştım olduğu kadar olmadığı kader:)
