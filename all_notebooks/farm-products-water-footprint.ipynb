# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import pandas
import plotly.express as px
import plotly.graph_objs as go
from plotly.offline import plot, iplot, init_notebook_mode

import plotly

# warning library
import warnings
warnings.filterwarnings("ignore")

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# #Water footprints of farm animals and animal products (1996-2005)
#
#
# Reference: Mekonnen, M.M. & Hoekstra, A.Y. (2012) A global assessment of the water footprint of farm animal products, Ecosystems, 15(3): 401–415.

# %% [markdown]
# ![](https://www.greeneatz.com/wp-content/uploads/2014/03/green-blog-water-footprint-2.jpg)https://www.greeneatz.com/1/post/2014/03/foods-water-footprint.html

# %% [markdown]
# <center style="font-family:verdana;"><h1 style="font-size:200%; padding: 20px; background: #001f3f;"><i><b style="color:orange;">Blue Water. Green Water. Grey Water Footprints</b></i></h1></center>
#
#
# <h1 style="font-size:180%; color:orange;"><i><b>A Global Assessment of the Water Footprint of Farm Animal Products.</b></i></h1>
#
#
# Authors: Mesfin Mergia Mekonnen, Arjen Hoekstra - Ecosystems ISSN 1432-9840 Volume 15 Number 3 Ecosystems (2012) 15:401-415DOI 10.1007/s10021-011-9517-8
#
# "The projected increase in the production and consumption of animal products is likely to put further pressure on the globe’s freshwater resources. The size and characteristics of the water footprint vary across animal types and production systems. This study provides a comprehensive account of the global GREEN, BLUE and GREY WATER FOOTPRINTS of different sorts of farm animals and animal products, distinguishing between different production systems and considering the conditions in all countries of the world separately."
#
# "The following animal categories were considered: beef cattle, dairy cattle, pig, sheep, goat, broiler chicken, layer chicken and horses. The study shows that the water footprint of meat from beef cattle (15400 m3/ton as a global average) is much larger than the footprints of meat from sheep (10400 m3/ton), pig (6000 m3/ton), goat (5500 m3/ton) or chicken (4300 m3/ton). The global average water footprint of chicken egg is 3300 m3/ton, while the water footprint of cow milk amounts to 1000 m3/ton."
#
# "Per ton of product, animal products generally have a larger water footprint than crop products. The same is true when we look at the water footprint per calorie. The average water footprint per calorie for beef is twenty times larger than for cereals and starchy roots. When we look at the water requirements for protein, we find that the water footprint per gram of protein for milk, eggs and chicken meat is about 1.5 times larger than for pulses. For beef, the water footprint per gram of protein is 6 times larger than for pulses. In the case of fat, they find that butter has a relatively small water footprint per gram of fat, even lower than for oil crops. All other animal products, however, have larger water footprints per gram of fat when compared to oil crops."
#
# "The study shows that from a freshwater resource perspective, it is more efficient to obtain calories, protein and fat through crop products than animal products."
#
# https://www.researchgate.net/publication/254859487_The_green_blue_and_grey_water_footprint_of_farm_animals_and_animal_products

# %%
df = pandas.read_csv('/kaggle/input/cusersmarildownloadsfarmcsv/farm.csv',  delimiter=';')

df.head().style.set_properties(**{'background-color':'Aqua',
                                     'color': 'purple'})

# %% [markdown]
# #Remove the 1st Row: skiprows=[1] With brackets. If you write skiprows=1 It will remove the columns name

# %%
df1 = pandas.read_csv('/kaggle/input/cusersmarildownloadsfarmcsv/farm.csv',  delimiter=';', skiprows=[1])

df1.head().style.set_properties(**{'background-color':'#90EE90',
                                     'color': 'purple'})

# %% [markdown]
# #Columns Unnamed 10/11/12 refers to World Average. Like in countries Afghanistan.1/Afghanistan.2/Afghanistan.3 are just #Afghanistan and so on.  They are divided in: Grazing/Mixed/Industrial/Weighted Average.

# %%
df.isnull().sum()

# %% [markdown]
# #Harmonized System (HS) Codes

# %%
df['product_discription_HS'].value_counts()[:20].plot.barh(title='Products: Harmonized System Codes (HS)', figsize=(8,6),color= 'r');

# %% [markdown]
# #The Standard international trade classification, abbreviated as SITC

# %%
df['product_description_SITC'].value_counts()[:20].plot.barh(title='Products: Standard International Trade Classification', figsize=(8,6),color= 'b');

# %%
#Code by Lucas Abrahão https://www.kaggle.com/lucasabrahao/trabalho-manufatura-an-lise-de-dados-no-brasil

df["production_system"].value_counts().plot.bar(color=['#008000', '#A9A9A9', 'blue', '#f5005a'], title='Green, Grey & Blue Water Footprint',);

# %% [markdown]
# ![](https://buddhajeans.com/wp-content/uploads/2016/08/water-footprint-what-is-it-1024-595.png)buddhajeans.com

# %%
#Code by Siti K https://www.kaggle.com/khotijahs1/2020-indonesia-university-rank/comments

#Farm Products Water Footprint codes
farm_footprint = df1.sort_values(by='HS_PC_TAS_code', ascending=True)[:10]
figure = plt.figure(figsize=(10,6))
sns.barplot(y=farm_footprint.Brazil, x=farm_footprint.HS_PC_TAS_code)
plt.xticks()
plt.xlabel('Grazing Farm Products')
plt.ylabel('Count')
plt.title('Brazilian Water Footprint of Farm Grazing Products')
plt.show()

# %%
#Code by Siti K https://www.kaggle.com/khotijahs1/2020-indonesia-university-rank/comments

#Farm Products Water Footprint codes
farm_footprint = df1.sort_values(by='HS_PC_TAS_code', ascending=True)[:10]
figure = plt.figure(figsize=(10,6))
sns.barplot(y=farm_footprint.India, x=farm_footprint.HS_PC_TAS_code)
plt.xticks()
plt.xlabel('Grazing Farm Products')
plt.ylabel('Count')
plt.title('Indian Water Footprint of Farm Grazing Products')
plt.show()

# %%
#Code by Siti K https://www.kaggle.com/khotijahs1/2020-indonesia-university-rank/comments

#Farm Products Water Footprint codes
farm_footprint = df1.sort_values(by='HS_PC_TAS_code', ascending=True)[:10]
figure = plt.figure(figsize=(10,6))
sns.barplot(y=farm_footprint.Germany, x=farm_footprint.HS_PC_TAS_code)
plt.xticks()
plt.xlabel('Grazing Farm Products')
plt.ylabel('Count')
plt.title('Germany Water Footprint of Farm Grazing Products')
plt.show()

# %%
fig = px.bar(df, 
             x='product_discription_HS', y='rootproduct_HS', color_discrete_sequence=['#DC143C'],
             title='Water Footprint Grazing Animal Products', text='production_system')
fig.show()

# %% [markdown]
# #We don't have Blue or Grey Water Footprint in product_description_SITC or product_discription_HS because Grey and Blue are the NaN rows.

# %%
#World_average means Industrial. I had issues to clean/download the Dataset.

fig = px.bar(df, 
             x='production_system', y='Brazil.2', color_discrete_sequence=['Aqua'],
             title='Brazilian Industrial Farm Products', text='product_discription_HS')
fig.show()

# %% [markdown]
# #If we don't include showfliers=False the boxes would be smashed/small (almost one line).
#
# #Include palette otherwise the boxes would be green/grey/blue (instead of green/blue/grey).

# %%
fig, axes = plt.subplots(1, 1, figsize=(14, 6))

#sns.boxplot(x='production_system', y='Brazil.2', data=df1, showfliers=False);

sns.boxplot(x="production_system", y="Brazil.2", data=df1, palette=['#008000', 'blue', '#A9A9A9'],showfliers=False )
plt.title('Brazilian Farm Industrial Production Water Footprint');

# %%
fig, axes = plt.subplots(1, 1, figsize=(14, 6))
sns.boxplot(x='rootproduct_HS', y='Brazil.3', data=df1, showfliers=False)
plt.xticks(rotation=45)
plt.title('Brazilian Weighted Average Rootproduct(HS)');

# %%
g = sns.jointplot(x="Brazil.1", y="HS_PC_TAS_code", data=df1, kind="kde", color="m")
g.plot_joint(plt.scatter, c="w", s=30, linewidth=1, marker="+")
g.ax_joint.collections[0].set_alpha(0)
g.set_axis_labels("Brazil.1", "HS_PC_TAS_code");
#plt.title('Brazilian Mixed Farm Products (HS code)');

# %%
fig=sns.lmplot(x="Brazil.3", y="HS_PC_TAS_code",data=df1)

# %%
bra = df1.groupby(["product_discription_HS","rootproduct_HS", "Brazil"])[["Brazil.1","Brazil.2","Brazil.3"]].sum().reset_index()
bra.head()

# %%
import plotly.express as px

fig = px.scatter(bra, x="Brazil", y="rootproduct_HS", color="product_discription_HS", title='Brazilian Grazing Farm Products')
fig.show()

# %%
fig = px.scatter(bra, x="product_discription_HS", y="Brazil.1", color="product_discription_HS", title='Brazilian Grazing Farm Products')
fig.show()

# %% [markdown]
# <center style="font-family:verdana;"><h1 style="font-size:200%; padding: 20px; background: #001f3f;"><i><b style="color:orange;">Wasted Food. Wasted Resources. How big is Our Water Footprint?</b></i></h1></center>
#
#
# "Because it takes so much water to produce food, food waste has some pretty big implications. According to the NRDC (The Natural Resources Defense Council), “forty percent of the food in the United States is never eaten."
#
# "Wasted food means wasted resources, including water. This is why work is being done at every level – from local to federal – to reduce food waste. Activities like taking a refrigerator inventory before you shop, meal planning, using leftovers and composting can make a huge dent in the amount of food (and water) that is wasted on a daily basis."
#
# "How Big Should My Food Water Footprint Be? Nobody will have a water footprint of zero from food because everybody has to eat. Still, choices about how and what to eat can help reduce daily water impacts from your diet."
#
# https://www.watercalculator.org/footprint/foods-big-water-footprint/
