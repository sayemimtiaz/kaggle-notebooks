# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# # Data

# %%
df=pd.read_csv('../input/menu-satis/train.csv')

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.columns

# %%
df['Food and drink']

# %%
df.shape

# %%
df.info()

# %%
df.describe()

# %%
df.isnull

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr())

# %%
gen= pd.get_dummies(df['Gender'], drop_first= True)

# %%
gen

# %%
df.drop('Gender', axis=1, inplace=True)

# %%
df.columns

# %%
dfn=pd.concat([df,gen], axis=1)
dfn.rename(columns={"male": "gen"}, inplace= True)
dfn.head()

# %%
sns.pairplot(dfn['Food and drink'] )

# %%
sns.boxplot(x='Food and drink', y='Age', data=dfn)

# %%
sns.boxplot(x='Food and drink', y='Flight Distance', data=dfn)

# %%
sns.boxplot(x='Food and drink', y='Online boarding', data=dfn)

# %%
sns.boxplot(x='Food and drink', y='Inflight entertainment', data=dfn)

# %%
sns.boxplot(x='Food and drink', y='Inflight service', data=dfn)

# %%
from sklearn.decomposition import PCA
