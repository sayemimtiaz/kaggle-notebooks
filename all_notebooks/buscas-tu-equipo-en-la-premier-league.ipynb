# %% [markdown]
# **Tu equipo en la Premier League**
#
#
#
# La English Premier League está catalogada como la mejor liga de futbol a nivel mundial por su velocidad, fortaleza fisica y sobre todo mentalidad competitiva lo que hace que cada uno de sus partidos parezca una final del mundo.
#
# Ya que la gran mayoría de futboleros en latinoamerica no tienen un equipo predilecto para apoyar en la liga te ayudaremos a encontrar tu equipo, tenemos las siguientes categorías:
#
# -Si para ti lo más importante es ganar.
#
# -Disfrutas de celebrar muchos goles.
#
# -Siempre pierdes por tu defensa/arquero.
#
# -Tu equipo es el que toca el balón.
#
# -Si lo tuyo es sufrir.
#
# -La suerte no es tu amiga.
#
# **Iniciemos!**

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt 
import seaborn as sns
import pandas_profiling 

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os

# Any results you write to the current directory are saved as output.

# %%
stats = pd.read_csv("../input/stats.csv")

# %% [markdown]
# **¿Qué datos tenemos?**

# %%
stats.head()

# %%
stats.info()

# %% [markdown]
# Fuente: https://seaborn.pydata.org/generated/seaborn.barplot.html
#
# Revisemos cuales son los equipos que más temporadas han jugado en la Premier desde 2006.

# %%
plt.figure(figsize=(16,6))
Equipos = stats['team'].value_counts()
plt.title('Más participaciones en la liga desde el 2006')
sns.barplot(x=Equipos[:10].keys(), y=Equipos[:10].values, color="Salmon", orient="v")

# %% [markdown]
# Asumiré que nadie se quiere ir a la B así que filtraré el set de datos con los únicos 7 equipos que no han descendido de la Premier League en los últimos años.

# %%
continents = ['Tottenham Hotspur','Manchester United', 'Liverpool', 'Manchester City', 'Everton', 'Arsenal', 'Chelsea']
stats1 = stats[stats.team.isin(continents)]

# %%
pandas_profiling.ProfileReport(stats1)

# %% [markdown]
# **-Si para ti lo más importante es ganar:** Equipo con más victorias registradas.

# %%
plt.figure(figsize=(16,6))
Equipos =  stats1.groupby('team')['wins'].sum()
plt.title('Más victorias en liga')
sns.barplot(x=Equipos[:10].keys(), y=Equipos[:10].values, color="seagreen")

# %% [markdown]
# **MANCHESTER UNITED o el CHELSEA** son tus mejores opciones!
# ![](https://fatbuzz.com/wp-content/uploads/2014/10/manu-logo.png) ![](http://www.logospng.com/images/212/fifa-editor-2007-escudos-212665.png)

# %% [markdown]
# **- Si disfrutas de celebrar muchos goles:** Equipos con mayor número de goles anotados.

# %%
plt.figure(figsize=(16,6))
Equipos =  stats1.groupby('team')['goals'].sum()
plt.title('Más goles anotados en liga')
sns.barplot(x=Equipos[:10].keys(), y=Equipos[:10].values, color="lightgreen")

# %% [markdown]
# Con más de 800 goles en las 12 temporadas tenemos varios candidados:
# * Manchester United (867)
# * Manchester City (866)
# * Arsenal (861)
# * Chelsea (859)
# * Liverpool (817)

# %% [markdown]
# **-Si siempre pierdes por tu defensa/arquero:** Equipo con más goles recibidos.

# %%
plt.figure(figsize=(16,6))
Equipos =  stats1.groupby('team')['goals_conceded'].sum()
plt.title('Menos goles recibidos')
sns.barplot(x=Equipos[:10].keys(), y=Equipos[:10].values, color="orange")

# %% [markdown]
# **Everton** o **Tottenham Hotspur** son los equipos ideales para ti!
# ![](http://aux2.iconspalace.com/uploads/tottenham-hotspur-logo-icon-256.png)
# ![](https://3.bp.blogspot.com/-WRwr4i-MkFs/WVLqAPzc35I/AAAAAAABJ-E/xEs__Zdmt50RgnSxhuov8b2CiUIZUaypgCLcBGAs/s1600/Everton%2BFC256x.png)

# %% [markdown]
# **Si tu equipo es el que toca el balón:** Equipo con mayor número de pases.

# %%
plt.figure(figsize=(16,6))
Equipos =  stats1.groupby('team')['total_pass'].sum()
plt.title('Con más pases en liga')
sns.barplot(x=Equipos[:10].keys(), y=Equipos[:10].values, color="silver")

# %% [markdown]
# **ARSENAL** es tu equipo en la Premier League!
# ![](https://karllusbec.files.wordpress.com/2011/06/arsenal-fc-logo.png?w=748)

# %% [markdown]
# **-Si lo tuyo es sufrir:** Equipo que concede más penalties.

# %%
plt.figure(figsize=(16,6))
Equipos =  stats1.groupby('team')['penalty_conceded'].sum()
plt.title('Con más penales en contra')
sns.barplot(x=Equipos[:10].keys(), y=Equipos[:10].values, color="slateblue")

# %% [markdown]
# **ARSENAL** es tu equipo en la Premier League!
# ![](https://karllusbec.files.wordpress.com/2011/06/arsenal-fc-logo.png?w=748)

# %% [markdown]
# **-La suerte no es tu amiga:** Equipo con mayor número de autogoles.

# %%
plt.figure(figsize=(16,6))
Equipos =  stats1.groupby('team')['own_goals'].sum()
plt.title('Con más goles en contra')
sns.barplot(x=Equipos[:10].keys(), y=Equipos[:10].values, color="yellow")

# %% [markdown]
# **Liverpool** o **Everton** es tu equipo ideal!
# ![](https://3.bp.blogspot.com/-bjorOjEiCU8/WVLrXoDaddI/AAAAAAABJ-s/-a2xpJtXMyEPDckJh-3bmlBJGNxxv1_sACLcBGAs/s1600/Liverpool%2BFC256x.png)
# ![](https://3.bp.blogspot.com/-WRwr4i-MkFs/WVLqAPzc35I/AAAAAAABJ-E/xEs__Zdmt50RgnSxhuov8b2CiUIZUaypgCLcBGAs/s1600/Everton%2BFC256x.png)
