# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv('/kaggle/input/medical-insurance-premium-prediction/Medicalpremium.csv')
df.head()

# %% [markdown]
# # EDA

# %%
colors_blue = ["#132C33", "#264D58", '#17869E', '#51C4D3', '#B4DBE9']
colors_dark = ["#1F1F1F", "#313131", '#636363', '#AEAEAE', '#DADADA']
colors_green = ['#01411C','#4B6F44','#4F7942','#74C365','#D0F0C0']
sns.palplot(colors_blue)
sns.palplot(colors_green)
sns.palplot(colors_dark)

# %%
fig=px.pie(df,names=['Not Diabetic','Diabetic'],values=df.Diabetes.value_counts(),color_discrete_sequence=[colors_blue[3],colors_green[3]],
      hole=0.5,opacity=0.7)
fig.add_annotation(text='Diabetes',x=0.5,y=0.5,showarrow=False)
fig.update_layout(font_family='monospace',
                  title=dict(text='How many people are Diabetic',x=0.5,y=0.97,font=dict(color=colors_dark[2],size=20)),
                  legend=dict(x=0.37,y=-0.05,orientation='h',traceorder='reversed'),
                  bargap=0.3)
fig.update_traces(textposition='outside',textinfo='percent+label')

# %%
fig=px.pie(df,names=['No','Yes'],values=df.BloodPressureProblems.value_counts(),color_discrete_sequence=[colors_blue[3],colors_green[3]],
      hole=0.5,opacity=0.7)
fig.add_annotation(text='Blood Pressure <br> Problems?',x=0.5,y=0.5,showarrow=False)
fig.update_layout(font_family='monospace',
                  title=dict(text='How many people have Blood Pressure Problems',x=0.5,y=0.97,font=dict(color=colors_dark[2],size=20)),
                  legend=dict(x=0.37,y=-0.05,orientation='h',traceorder='reversed'),
                  bargap=0.3)
fig.update_traces(textposition='outside',textinfo='percent+label')

# %%
fig=px.pie(df,names=['No','Yes'],values=df.AnyTransplants.value_counts(),color_discrete_sequence=[colors_blue[3],colors_green[3]],
      hole=0.4,opacity=0.7)
fig.add_annotation(text='Any Transplants ? ',x=0.5,y=0.5,showarrow=False)
fig.update_layout(font_family='monospace',
                  title=dict(text='How many people have atleast one Transplant ',x=0.5,y=0.97,font=dict(color=colors_dark[2],size=20)),
                  bargap=0.3)
fig.update_traces(textposition='outside',textinfo='percent+label')

# %%
fig=px.pie(df,names=['No','Yes'],values=df.Diabetes.value_counts(),color_discrete_sequence=[colors_blue[3],colors_green[3]],
      hole=0.4,opacity=0.7)
fig.add_annotation(text='Any Chronic <br> Diseases?',x=0.5,y=0.5,showarrow=False)
fig.update_layout(font_family='monospace',
                  title=dict(text='How many people have atleast one chronic disease ',x=0.5,y=0.97,font=dict(color=colors_dark[2],size=20)),
                  legend=dict(x=0.37,y=-0.05,orientation='h',traceorder='reversed'),
                  bargap=0.3)
fig.update_traces(textposition='outside',textinfo='percent+label')

# %%
fig=px.pie(df,names=['No','Yes'],values=df.KnownAllergies.value_counts(),color_discrete_sequence=[colors_blue[3],colors_green[3]],
      hole=0.4,opacity=0.7)
fig.add_annotation(text='Any Known <br> Allergy?',x=0.5,y=0.5,showarrow=False)
fig.update_layout(font_family='monospace',
                  title=dict(text='How many people have Allergies ',x=0.5,y=0.97,font=dict(color=colors_dark[2],size=20)),
                  bargap=0.3)
fig.update_traces(textposition='outside',textinfo='percent+label')

# %%
fig=px.pie(df,names=['No','Yes'],values=df.HistoryOfCancerInFamily.value_counts(),color_discrete_sequence=[colors_blue[3],colors_green[3]],
      hole=0.4,opacity=0.7)
fig.add_annotation(text='History of Cancer <br> in Family',x=0.5,y=0.5,showarrow=False)
fig.update_layout(font_family='monospace',
                  title=dict(text='How many people have History Of Caner in Family',x=0.5,y=0.97,font=dict(color=colors_dark[2],size=20)),
                  bargap=0.3)
fig.update_traces(textposition='outside',textinfo='percent+label')

# %%
fig=px.pie(df,names=['Zero','One','Two','Three'],values=df.NumberOfMajorSurgeries.value_counts(),color_discrete_sequence=[colors_green[3],colors_green[2],colors_green[1],colors_green[0]],
      hole=0.4,opacity=0.7)
fig.add_annotation(text='Number of Major <br> Surgeries',x=0.5,y=0.5,showarrow=False)
fig.update_layout(font_family='monospace',
                  title=dict(text='How many people have had Major Surgeries',x=0.5,y=0.97,font=dict(color=colors_dark[2],size=20)),
                  bargap=0.3)
fig.update_traces(textposition='outside',textinfo='percent+label')

# %%
sns.set_style('darkgrid')
plt.rcParams['font.size']=17
plt.figure(figsize=(10,6))
df.groupby('Diabetes')['PremiumPrice'].mean().plot.bar(width=0.35,color=[colors_green[2],colors_blue[2]]);
plt.xticks([0,1],['No','Yes'],rotation=0);
plt.title('Effect Of Diabetes On Premium Price');

# %%
plt.figure(figsize=(10,6))
df.groupby('BloodPressureProblems')['PremiumPrice'].mean().plot.bar(width=0.35,color=[colors_green[2],colors_blue[2]]);
plt.xticks([0,1],['No','Yes'],rotation=0);
plt.xlabel('Blood Pressure Problems')
plt.title('Effect Of Blood Pressure On Premium Price');

# %%
plt.figure(figsize=(10,6))
df.groupby('AnyTransplants')['PremiumPrice'].mean().plot.bar(width=0.35,color=[colors_green[2],colors_blue[2]]);
plt.xticks([0,1],['No','Yes'],rotation=0);
plt.xlabel('Any Transplants')
plt.title('Effect Of Transplants On Premium Price');

# %%
plt.figure(figsize=(10,6))
df.groupby('AnyChronicDiseases')['PremiumPrice'].mean().plot.bar(width=0.35,color=[colors_green[2],colors_blue[2]]);
plt.xticks([0,1],['No','Yes'],rotation=0);
plt.xlabel('Chronic Diseases')
plt.title('Effect Of Chronic Diseases On Premium Price');

# %%
plt.figure(figsize=(10,6))
df.groupby('KnownAllergies')['PremiumPrice'].mean().plot.bar(width=0.35,color=[colors_green[2],colors_blue[2]]);
plt.xticks([0,1],['No','Yes'],rotation=0);
plt.xlabel('Any Allergy')
plt.title('Effect Of Allergies On Premium Price');

# %%
plt.figure(figsize=(10,6))
df.groupby('HistoryOfCancerInFamily')['PremiumPrice'].mean().plot.bar(width=0.35,color=[colors_green[2],colors_blue[2]]);
plt.xticks([0,1],['No','Yes'],rotation=0);
plt.xlabel(' History Of Cancer in Family')
plt.title('Effect Of History Of Cancer In Family On Premium Price');

# %%
plt.figure(figsize=(10,6))
df.groupby('NumberOfMajorSurgeries')['PremiumPrice'].mean().plot.bar(width=0.35,color=[colors_green[3],colors_green[2],colors_green[1],colors_green[0]]);
plt.xticks([0,1,2,3],['Zero','One','Two','Three'],rotation=0);
plt.xlabel('Number Of Surgeries')
plt.title('Effect Of Surgeries On Premium Price');

# %%
cor=df.corr()
fig=px.imshow(cor,height=700,width=900,color_continuous_scale=colors_blue,template='plotly_white')
fig.update_layout(font_family='monospace',title=dict(text='CORRELATION HEATMAP',x=0.5,y=0.98,
                                                     font=dict(color=colors_dark[2],size=20)),coloraxis_colorbar=dict(len=0.85,x=1.05))

# %% [markdown]
# # SCALING AND SPLITTING

# %%
numeric_cols=['Age','Height','Weight']
categorical_cols=[feature for feature in df.columns if feature not in numeric_cols][:-1]

x=df[numeric_cols+categorical_cols].copy()
y=df['PremiumPrice'].copy()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler().fit(x[numeric_cols])
x[numeric_cols]=scaler.transform(x[numeric_cols])

# %%
from sklearn.preprocessing import OneHotEncoder
encoder=OneHotEncoder(sparse=False).fit(x[categorical_cols])
encoded_cols=encoder.get_feature_names(categorical_cols).tolist()
x[encoded_cols]=encoder.transform(x[categorical_cols])

# %%
x=x[encoded_cols+numeric_cols]

# %% [markdown]
# # MODEL TRAINING AND SELECTION

# %%
from sklearn.linear_model import Ridge,Lasso,LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV,RepeatedStratifiedKFold
from xgboost import XGBRegressor
from sklearn.metrics import explained_variance_score

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
models=[('LR',LinearRegression()),('DT',DecisionTreeRegressor()),('RF',RandomForestRegressor()),('XGB',XGBRegressor())
        ,('SVR',SVR()),('Ridge',Ridge()),('Lasso',Lasso())]
scores=[]

for name,model in models:
    model.fit(x_train,y_train)
    preds=model.predict(x_test)
    score=explained_variance_score(preds,y_test)
    scores.append([name,model,score])

# %%
scores_df=pd.DataFrame(scores,columns=['Name','Model','Score'])
scores_df.sort_values('Score',ascending=False)
