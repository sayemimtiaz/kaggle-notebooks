# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.

# %% [markdown]
# <h1> Problem Statement </h1>
#
# Inspired by Tinder, Match.com, and a plethora of other dating platforms, you and your friend have decided to create a new dating app. Your friend, who has had a few rough dates in the past, has decided that the best brand positioning for your new platform would be a high-quality match experience. This includes a more selective match process based on over 20 criteria, a higher percentage of continued dates, and a higher overall satisfaction rating.
#
# In order to ensure the quality of matches, your friend decides that employing more advanced machine learning algorithms would be beneficial. Prior to building a predictive model, you warn your friend that he will need to clean the data to avoid unsubstantiated matches.

# %%
df = pd.read_csv('../input/StudentsPerformance.csv')

# %%
df.head()

# %%
df['math score'].hist()

# %% [markdown]
# <h3> 1. One major problem that you notice right away is participants opting out of providing their age. Assuming that the percentage of total entries with the “age” field missing is relatively small (~20% of total entries), and that there are no erroneous or extreme (effectively non-sensical) values for the “age” field, which of the following would be the BEST way to deal with the missing entries? </h3>
#
# * Remove all occurrences where age is not given
# * For every occurrence where age is not given, substitute in the mean age of the entire dataset
# * For every occurrence where age is not given, substitute in the median age of the entire dataset
# * For every occurrence where age is not given, use a linear regression model based on other data in the set to provide an age estimate
# * None of the above are reasonable ways of dealing with the missing entries
