# %% [markdown]
#  # install pandas if not installed

# %%
# ! pip install pandas

# %% [markdown]
# # import pandas

# %%
import pandas as pd

# %% [markdown]
# # create pandas Dataframe

# %%
# data = {
#     'col1': [],
#     'col2': [], 
#     ......
# }

# %%
data = {
    'name': ['Ahmed', 'Majdi', 'George'],
    'age': [25, 29, 37]
}

# %%
df = pd.DataFrame(data)

# %%
df

# %%
df['dept'] = ['Bio', 'AI', 'AI']

# %%
df

# %% [markdown]
# # music data

# %%
music_data = {
    'Artist': ['Billie Holiday','Jimi Hendrix', 'Miles Davis', 'SIA'],
    'Genre': ['Jazz', 'Rock', 'Jazz', 'Pop'],
    'Listeners': [1300000, 2700000, 1500000, 2000000],
    'Plays': [27000000, 70000000, 48000000, 74000000]
}

# %%
music_df = pd.DataFrame(music_data)
music_df

# %%
jazz_music = music_df[music_df['Genre'] == 'Jazz']
jazz_music

# %%
jazz_music.to_excel('jazz_music.xlsx')

# %%
music_df['Artist']

# %%
music_df[1:3]

# %%
music_df.loc[1:3, ['Artist']]

# %%
music_df[1:3]['Artist']

# %%
music_df.Genre

# %%
music_df['Genre']

# %%
data = {
    'apples': [3, 2, 0, 1], 
    'oranges': [0, 3, 7, 2]
}

# %%
df = pd.DataFrame(data)
df

# %%
type(df)

# %%
data = {
    'apples': [3, 2, 0, 1], 
}

# %%
df = pd.Series(data)
df

# %%
type(df)

# %% [markdown]
# # EC data

# %%
ec_df = pd.read_csv('../input/ecommerce-data/data.csv', header=0,encoding="ISO-8859-1",engine='c')
ec_df

# %% [markdown]
# # flight data

# %%
flight_df = pd.read_csv('../input/flight-delays/flights.csv')
flight_df

# %%
corona_df = pd.read_excel('../input/covid19geographicdisbtributionworldwide/COVID-19-geographic-disbtribution-worldwide.xlsx')
corona_df

# %%
corona_df2 = pd.read_excel('https://www.ecdc.europa.eu/sites/default/files/documents/COVID-19-geographic-disbtribution-worldwide.xlsx')
corona_df2

# %%
! wget 'https://www.ecdc.europa.eu/sites/default/files/documents/COVID-19-geographic-disbtribution-worldwide.xlsx'

# %%
corona_df3 = pd.read_excel('./COVID-19-geographic-disbtribution-worldwide.xlsx')
corona_df3

# %% [markdown]
# # load JSON

# %%
pakistan_df = pd.read_json('../input/pakistan-elections-2018/cleaned_twitter_elections_data.json')
pakistan_df

# %% [markdown]
# # Summary
#
# * pandas deals with dictionary data
# * load data from different sources (xlsx, csv, json, .....)
# * play with data
# * write data to differnt formats (xls, .......)
