# %%
import pandas

# %%
df = pandas.read_csv('/kaggle/input/cricket-indian-premier-league/ipl.csv',
                     dtype={'season': 'string', 'innings': 'uint8', 'batting_team': 'string', 'bowling_team': 'string',
                            'start_date': 'string', 'venue': 'string', 'striker': 'string', 'non_striker': 'string', 'bowler': 'string',
                            'wides': 'object', 'noballs': 'object', 'byes': 'object', 'legbyes': 'object',
                            'penalty': 'object', 'other_wicket_type': 'object', 'other_player_dismissed': 'object'})

# %%
df

# %%
df.describe(include='all')
