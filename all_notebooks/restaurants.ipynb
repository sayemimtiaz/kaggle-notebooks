# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# importing pandas library
import pandas as pd

# %%
#Importing Data (reading csv file)
df = pd.read_csv('../input/riyadhvenues/riyadh_venues.csv')
#df_heart = pd.read_csv('../input/heart-disease/heart.csv')

# %% [markdown]
# # Dataframes and its operations

# %%
# Pandas Data Structures
df.head()

# %%
#list the types of the columns

df.dtypes

# %%
# list the column names
# Way 1
df.columns

# %%
# Way 2
list(df.columns)

# %%
# Way 3
for column in df.columns:
    print(column)

# %%
# list the row labels and column names

df.axes

# %%
# number of dimensions

df.ndim

# %%
# number of elements 

df.size

# %%
# return a tuple representing the dimensionality 

df.shape

# %%
# numpy representation of the data

df.values

# %%
df.head()

# %%
df.tail()

# %%
df.info()

# %%
df.describe()

# %%
# Using value_counts for knowing columns that contain strings / count of different values within a column
#df['price'].value_counts()

# %% [markdown]
# # Data Frames: Slicing

# %%
#If we need to select a range of rows 
#Data Frames: Selecting rows (#Select rows by their position)
df[2:4]

# %%
#Selecting a column in a Data Frame (the resulting object will be  a Series)
df['name']

# %%
df.name

# %%
#Selecting a column in a Data Frame (the resulting object will be  a Series)
s_name = df['name']

# %%
s_name

# %%
# Converting a series to DataFrame
df_name = pd.DataFrame(s_name)

# %%
df_name

# %%
#Selecting a column in a Data Frame (the resulting object will be  a datafrme)
df[['name']]

# %%
#content of first 5 values of column 'name'
df[['name']][:5]

# %%
# to select more than one column and/or make the output to be a DataFrame, we should use double brackets
df[['name', 'categories']].head()

# %% [markdown]
# # Data Frame: filtering

# %%
df.rating>7

# %%
df[df.rating>7].head()

# %% [markdown]
# # Data Frames: method loc

# %%
#Data Frames: method loc
#Select rows by their labels:
df.loc[2:4]

# %%
# Data Frames: method iloc
# #Select rows by their poisitions:
df.iloc[2:4]

# %%
#Select rows by their labels:
df.loc[0:1, ['name', 'categories']]

# %%
df.iloc[0:2, [0, 1]]

# %%
# Data Frames: method iloc
# #Select rows by their poisitions:
df.iloc[0:2, 0:2]

# %%
df.iloc[1:5, [0,1,5]]

# %%
df.loc[1:4, ['name','categories','users']]

# %%
## iloc[row slicing, column slicing] (1st and 6th rows and 2nd and 4th columns)
df.iloc[[0,5], [0,4]]

# %%
# First 2 column
df.iloc[:, 0:2]

# %%
#First row of a data frame
df.iloc[0:1]

# %%
#First row of a data frame
df.iloc[0]

# %% [markdown]
# # Data Frame: filtering

# %% [markdown]
# Finding best restaurant in Riyadh

# %%
df['users'].max()

# %%
max(df['users'])

# %%
max_users = df[df['users'] == df['users'].max()]

# %%
max_users

# %%
df['rating'].max()

# %%
best_restaurant = df[df['rating'] == df['rating'].max()]

# %%
best_restaurant

# %%
#Be Careful 
df['rating'] == df['rating'].max()

# %%
# Best five restaurants in Riyadh
df.sort_values('rating', ascending = False).head(5)

# %%
#Data Frames: Sorting
df_sorted = df.sort_values(by= 'rating')
df_sorted.head()

# %%
biggest_checkins = df[df['checkins']==67445]
biggest_checkins

# %%
biggest_checkins['name']

# %%
biggest_checkins['name'].iloc[0]

# %%
df[df['rating']> 8]

# %%
# Most common resturant 
df['categories'].value_counts()

# %%
# generate new Dataframe for 'categories'
categories= pd.DataFrame(df.categories.value_counts())
categories

# %%
categories= pd.DataFrame(df.categories.value_counts().reset_index())
#categories = ['categories', 'count']
categories.rename(columns={'index':'categories', 'categories': 'numbers' })

# %%
# Common Restaurant based on price 
df[df['price']== 'Cheap']['categories'].value_counts().head(10)

# %%
# Common Cheap Restaurant with hight rating
df[(df['rating']> 6) & (df['price'] == 'Cheap')].head()

# %% [markdown]
# # Bar charts

# %%
df.head(3)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,5))
df['users'].value_counts().plot.bar()
plt.show()

# %%
plt.figure(figsize=(6,5))
df['price'].value_counts().plot.bar()
plt.xlabel("Price types") 
plt.ylabel("Frequencies of each category") 
plt.title("Restaurants in Riyadh based on price")
plt.show()

# %%
#users =df['price']
users =df['price'].value_counts()
users.plot(kind = 'bar')
plt.show()

# %%
#To get horizontal bar plots, use the barh method 
users =df['price'].value_counts()
users.plot(kind = 'barh')
plt.show()

# %% [markdown]
# # Line chart

# %%
df['rating'].value_counts()

# %%
df['rating'].value_counts().sort_index()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,5))
df['rating'].value_counts().sort_index().plot.line()
plt.show()

# %%
plt.figure(figsize=(6,5))
li = df['rating'].value_counts().sort_index()
li.plot()
plt.show()

# %%
li

# %% [markdown]
# import matplotlib.pyplot as plt
#
# Year = [1920,1930,1940,1950,1960,1970,1980,1990,2000,2010]
# Unemployment_Rate = [9.8,12,8,7.2,6.9,7,6.5,6.2,5.5,6.3]
#
# plt.plot(Year, Unemployment_Rate)
# plt.title('Unemployment Rate Vs Year')
# plt.xlabel('Year')
# plt.ylabel('Unemployment Rate')
# plt.show()

# %% [markdown]
# # Histogram

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,6))
h = df['rating']
h.hist()
plt.show()

# %%
# Bar plots for (Rating)
users =df['rating'].head(50)
users.plot(kind = 'bar')
plt.show()

# %% [markdown]
# # Scatter plot

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,5))
df.plot.scatter(x='users', y='rating')
plt.show()

# %%
# Hexplot

# %%
import matplotlib.pyplot as plt
plt.figure(figsize= (6,5))
df.plot.hexbin(x='users', y='rating', gridsize= 20)
plt.show()

# %% [markdown]
# import matplotlib.pyplot as plt
# plt.figure(figsize= (6,5))
# df_heart.plot.hexbin(x='age', y='chol', gridsize= 20)
# plt.show()

# %% [markdown]
# # Area plot

# %% [markdown]
# An area plot displays quantitative data visually.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize= (6,5))
df_heart.plot.area()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize= (6,5))
df_heart.plot.area(stacked=False)
plt.show()

# %% [markdown]
# # Box Plots

# %% [markdown]
# A Box Plot is also known as Whisker plot is created to display the summary of the set of data values having properties like minimum, first quartile, median, third quartile and maximum

# %%
import matplotlib.pyplot as plt
plt.figure(figsize= (6,5))
df.rating.plot.box()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize= (6,5))
df_heart.plot.box()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize= (6,5))
df_heart.plot.box(vert = True)
plt.show()

# %% [markdown]
# # Pie Chart Diagrams

# %%
df.price.value_counts()

# %%
import matplotlib.pyplot as plt
df.price.value_counts().plot.pie(figsize= (6,5))
plt.show()

# %% [markdown]
# # Density plot

# %% [markdown]
# Kernel Density Estimate is like a smoothened counterpart of a histogram without the line of histogram intervals and their end-points.

# %%
plt.figure(figsize=(6,5))
df.rating.value_counts().sort_index().plot.bar()
plt.show()

# %%
plt.figure(figsize=(6,5))
df.rating.plot.kde()
plt.show()

# %% [markdown]
# # Distplot

# %% [markdown]
# Seaborn distplot lets you show a histogram with a line on it.

# %%
import seaborn as sns
sns.distplot(df.rating)
plt.show()
