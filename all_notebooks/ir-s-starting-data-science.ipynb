# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [raw]
# Kaggle'ın verdiği kod bloğu çalıştırılıp,çıktı olarak gelen uzantı csv dosyasının okunması için read_csv içerisine '' içerisinde yazılır

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# Data(csv dosyası halindeki data) artık iris_df içerisindedir ve pandas ile işlem yapılabilir şeklindedir.

# %%
iris_df=pd.read_csv('/kaggle/input/iris-flower-dataset/IRIS.csv')

# %% [markdown]
# Data setinin sütun adlarını verir

# %%
iris_df.columns

# %% [markdown]
# * info() = Dataframe için genel bilgileri verir.
# * describe() = Data setinin sayısal verilerindeki matematiksel tanımlamalar

# %%
iris_df.info()
iris_df.describe()

# %% [raw]
# Veri setinin Species sütununun türleri verdiği bilindiğinden ordaki feature'ları görmek yararlı olacaktır.

# %%
print(iris_df.species)

# %% [markdown]
# Sütundaki unique olan verileri verir.

# %%
iris_df.species.unique()

# %% [markdown]
# Çiçek türlerine göre 3 ayrı veri seti oluşturup,özelliklerini karşılaştırmak daha kolay olacak.

# %%
setosa_df=iris_df[iris_df.species=="Iris-setosa"]
versicolor_df=iris_df[iris_df.species=="Iris-versicolor"]
virginica_df=iris_df[iris_df.species=="Iris-virginica"]

# %%
setosa_df.describe()

# %%
setosa_df.plot()

# %%
versicolor_df.describe()

# %%
virginica_df.describe()
