# %% [markdown]
# # Greetings!! This notebook is to do EDA and to solve questions on India Census dataset

# %% [markdown]
# ![](https://im.rediff.com/news/2004/sep/15census.gif)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv("../input/india-census-dataset/India Census 2011 Data.csv")
df.head(5)

# %%
df.shape

# %%
df.index

# %%
df.columns

# %%
#check if any duplicate row is there in dataset or not?
df[df.duplicated()]

# %% [markdown]
# No dulipcate records

# %%
df.head(4)

# %%
df["State_name"].unique()

# %%
df["District_name"].unique()

# %% [markdown]
# # Questions:-

# %% [markdown]
# # 1.How will you hide the indexes of the DataFrame?

# %%
df.style.hide_index()

# %% [markdown]
# # 2.How can we set the caption / heading on the DataFrame?

# %%
#Its note working on kaggle but it will defintely work on you jupyter notebook...
df.style.set_caption("India Census Dataset")

# %% [markdown]
# # 3.Show the records related with the districts-New delhi,Lucknow,Jaipur?

# %%
df[df["District_name"].isin(["New delhi","Lucknow","Jaipur"])]

# %% [markdown]
# # 4.Calculate State-wise:-
#
#   a)Total no. of population.

# %%
df.head(2)

# %%
df.groupby("State_name")["Population"].sum().sort_values(ascending = False)

# %% [markdown]
#   b)Total no. of population with different religions?

# %%
df.columns

# %%
df.groupby("State_name")['Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains'].sum()

# %% [markdown]
# # 5.How many male workers were there in "Maharastra" state?

# %%
df[df["State_name"]=="MAHARASHTRA"]["Male"].sum()

# %% [markdown]
# # 6.How to set a column as index of the DataFrame?

# %%
df.set_index("District_code")

# %% [markdown]
# # 7.a)Add a suffix to the column's names?

# %%
df.add_suffix("_suffix")

# %% [markdown]
# # b)Add a Preffix to the column's names?

# %%
df.add_prefix("Preffix_")

# %% [markdown]
# # Hope you like this simple and starightforward analysis on India census dataset.
# # Make sure you vote up and Leave a comment as your feedback...

# %% [markdown]
# ![](https://i.gifer.com/1B4T.gif)
