# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
source_metadata = pd.read_csv('../input/crime.csv')
source_metadata.head()

# %% [markdown]
# When was crime more frequent in Vancouver?
# a.)Year
# b.)Month

# %% [markdown]
# a.)Year

# %%
df = pd.DataFrame([source_metadata['YEAR'], source_metadata['TYPE']]).T
df.head()

# %%
dataTotal = df.groupby(['YEAR']).count().reset_index()
dataTotal.columns = ['Year','Total']
dataTotal

# %%
plt.plot(dataTotal['Year'], dataTotal['Total'])
plt.title('Total No. of Occurences Crime in Vancouver per Year')
plt.xlabel('Year')
plt.ylabel('Total No. of Occurences Crime')
plt.show()

# %% [markdown]
# Crime has generally decreased in Vancouver from 2003-2017. Although it slowly began to increase from 2013-2016 but it dramatically drops by 2017. Possible reasons for the general decrease in cime includes:

# %% [markdown]
# * Gentrification
# * Improvement in lifestyle
# * Progress and development

# %% [markdown]
# a.) Month

# %%
df2 = pd.DataFrame([source_metadata['YEAR'], source_metadata['MONTH'], source_metadata['TYPE']]).T
df2.head()

# %%
df2.sort_values(by=['MONTH'])

# %%
dataAveMon = df2.groupby(['YEAR','MONTH']).count().reset_index()
dataAveMon.head()

# %%
dataAveMon.drop('YEAR', axis = 1)

# %%
dataAveMon = dataAveMon.groupby(['MONTH'])['TYPE'].mean().reset_index()

# %%
dataAveMon.columns = ['Month','Ave']
dataAveMon

# %%
plt.plot(dataAveMon['Month'], dataAveMon['Ave'])
plt.title('Average No. of Occurences Crime in Vancouver per Month')
plt.xlabel('Month')
plt.ylabel('Average No. of Occurences Crime')
plt.show()

# %% [markdown]
# In average, crime occurs less on February. While crime spikes  up the most on August. Further research is needed to investigate for the possible cause of this results

# %%
df3 = pd.DataFrame(source_metadata['TYPE'])
df3.head()

# %%
dataCrime = df3['TYPE'].value_counts()
dataCrime

# %%
c = dataCrime.plot(kind = 'bar')

# %% [markdown]
# The most grevious crime that involves death are the least common crimes. While theft from vehicle is a more common crime. This may because criminals have been more clever and strategic in stealing items from vehicles. They may have figured out how to beat the vechicle's security system.

# %% [markdown]
# Which neighborhood has the most crime occurences?

# %%
df5 = pd.DataFrame([source_metadata['YEAR'], source_metadata['NEIGHBOURHOOD'], source_metadata['TYPE']]).T

# %%
df5.head()

# %%
dataAveCrime = df5.groupby(['YEAR','NEIGHBOURHOOD']).count().reset_index()
dataAveCrime.head()

# %%
dataAveCrime = dataAveCrime.drop('YEAR', axis = 1)

# %%
dataAveCrime.columns = ["Neighborhood", "Ave"]

# %%
dataAveCrime = dataAveCrime.groupby(['Neighborhood'])['Ave'].mean()

# %%
dataAveCrime.head()

# %%
cr = dataAveCrime.plot(kind = 'bar')

# %% [markdown]
# Central Business District has the most number of average crimes. But Central Business Districts are densely populated area so it may not be that more crime occurs but rather it is proportioned to the number of populants. This is also possibly be why Musqueam has the least number of average crimes. Musqeam is located at the outermost area in Vancouver. It is a smaller community compared to the Central Business District. The number of crimes may have a correlation with popoulation number but the dataset do not contain that data so further research may be done.
