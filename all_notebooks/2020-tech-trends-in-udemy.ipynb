# %% [markdown]
# ## Easy-easy Examples for this udemy-courses-dataset

# %%
import pandas as pd
import os

# %%
os.listdir('../input')

# %%
os.listdir('../input/2020-udemy-courses-dataset')

# %%
df = pd.read_csv('../input/2020-udemy-courses-dataset/udemy_tech.csv')

# %%
# see - data
df.head()

# %%
df.info()

# %%
from matplotlib import pyplot as plt
# import matplotlib.pyplot as plt

# %%
plt.style.use(['dark_background'])

# %%
# distrubution of enrollment - 9963 courses
plt.plot(df['Enrollment'])

# %%
# distrubution of enrollment - top 100 courses
plt.plot(df['Enrollment'][:100])

# %%
# distrubution of enrollment - top 10 courses
plt.plot(df['Enrollment'][:10])

# %%
# sum of enrollments - top 100
sum(df['Enrollment'][:100])

# %%
# sum of enrollments - the residue (not top 100)
sum(df['Enrollment'][100:])

# %%
# the ratio of top 100 - num of enrollments(sum)
sum(df['Enrollment'][:100])/sum(df['Enrollment'])

# %% [markdown]
# ### Summary I - We can found the ratio of top 100 in 9963 courses : 20%

# %%
# ook. let's see courses for some keywords
# 1st. python - top 5
py_courses = df[df['Title'].str.contains('Python|python')==True]
py_courses.head()

# %%
# Machine Learning - top 5
ml_courses = df[df['Title'].str.contains('Machine|machine')==True]
ml_courses.head()

# %%
# Deep Learning - top 5
dl_courses = df[df['Title'].str.contains('Deep Learning|deep learning')==True]
dl_courses.head()

# %%
# Reinforcement Learning - top 5
reinf_courses = df[df['Title'].str.contains('Reinforcement')==True]
reinf_courses.head()

# %%
# R - top 5
r_courses = df[df['Title'].str.contains(' R ')==True]
r_courses.head()

# %% [markdown]
# ### Summary II. We looked at popular lectures Through the five representative keywords
# ------------------------
# 1. Python | 1st - 1,100,093 enrolled
# 2. Machine Learning | 1st - 692,812 enrolled
# 3. Deep Learning | 1st - 278,698 enrolled
# 4. Reinforcement Learning | 1st - 39,105 enrolled
# 5. R | 2st - 188,765 (1st = Machine Learning)
