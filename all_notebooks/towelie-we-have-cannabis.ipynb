# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# Image youtube.com

# %% [markdown]
# My inspiration was Mr. Randy Marsh from South Park sitcom (Comedy Central) and his Tegridy Farms. Towelie (in the title) is a talking towel who was genetically engineered by Tynacorp, in order to allow him to make people as dry as necessary depending on the situation.

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://upload.wikimedia.org/wikipedia/commons/e/e4/La_Roche_Jagu_chanvre_1.JPG',width=400,height=400)

# %% [markdown]
# By Barbetorte - Own work, CC BY-SA 3.0, https://commons.wikimedia.org/w/index.php?curid=7558724
# A hemp field in Côtes-d'Armor, Brittany, France (Europe's largest hemp producer)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
df = pd.read_csv('../input/cusersmarildownloadshempcsv/hemp.csv', delimiter=';', encoding = "ISO-8859-1", nrows = nRowsRead)
df.dataframeName = 'hemp.csv'
nRow, nCol = df.shape
print(f'There are {nRow} rows and {nCol} columns')

# %%
df.head()

# %%
df.info()

# %%
categorical_cols = [cname for cname in df.columns if
                    df[cname].nunique() < 10 and 
                    df[cname].dtype == "object"]


# Select numerical columns
numerical_cols = [cname for cname in df.columns if 
                df[cname].dtype in ['int64', 'float64']]

# %%
print(categorical_cols)

# %% [markdown]
# I didn't know that there were so many Unnamed columns. Maybe it's the hemp effect in the kernel.

# %%
print(numerical_cols)

# %%
#Missing values. Codes from my friend Caesar Lupum @caesarlupum
total = df.isnull().sum().sort_values(ascending = False)
percent = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending = False)
missing_data  = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(8)

# %%
# Number of each type of column
df.dtypes.value_counts()

# %%
corrs = df.corr()
corrs

# %% [markdown]
# EDA

# %% [markdown]
# codes from Baval @bavalpreet26

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.scatterplot(x='class_code',y='class_desc',data=df)

# %%
sns.countplot(df["class_code"])

# %%
import plotly.offline as pyo
import plotly.graph_objs as go
lowerdf = df.groupby('class_code').size()/df['class_desc'].count()*100
labels = lowerdf.index
values = lowerdf.values

# Use `hole` to create a donut-like pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=.6)])
fig.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# That's TOWELIE from the title. Image pinterest.com

# %%
import plotly.offline as pyo
import plotly.graph_objs as go
lowerdf = df.groupby('class_code').size()/df['class_desc'].count()*100
labels = lowerdf.index
values = lowerdf.values

# Use `hole` to create a donut-like pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=.6)])
fig.show()

# %%
labels1=df.class_code.value_counts().index
sizes1=df.class_code.value_counts().values
plt.figure(figsize=(11,11))
plt.pie(sizes1,labels=labels1,autopct="%1.1f%%")
plt.title("class_code",size=25)
plt.show()

# %%
ng = df[df.class_code <250]
plt.figure(figsize=(10,6))
sns.boxplot(y="class_code",x ='class_desc' ,data = ng)
plt.title("class_code & class_desc < 250")
plt.show()

# %% [markdown]
# These boxplots above were smashed.

# %%
#catplot room type and price
plt.figure(figsize=(10,6))
sns.catplot(x="class_code", y="class_desc", data=df);
plt.ioff()

# %% [markdown]
# Obtaining the center of a WKT polygon.
# How to create features from geometries in WKT (Well Known Text) format? If somebody knows please tell me how to do it.
# https://stackoverflow.com/questions/46391692/obtaining-the-center-of-a-wkt-polygon  Answered by Mike T.

# %%
from shapely import wkt
g = wkt.loads(
    'POLYGON ((-58.4932 -34.5810,-58.4925 -34.5815,-58.4924 -34.5817,-58.4932 -34.5810))')
print(g.centroid)  # POINT (-58.49270000000001 -34.5814)
print(g.centroid.coords[0])  # (-58.492700000000006, -34.581399999999995)

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# You want to get high SCORES! Image youtube.com

# %% [markdown]
# * K-Notebook Runner: Marília Prata @mpwolke
# * Executive Producer: Marília Prata @mpwolke

# %% [markdown]
# [](http://schema.org/WebPage)

# %% [markdown]
# ![](http://schema.org/WebPage)

# %% [markdown]
# ![](http://schema.org/WebPage)
