# %% [markdown]
# <center><h1 style="color:blueviolet"><b>Loan Approval Predict: Analysis and Model Building Using Decision Tree</b></h1></center>

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Uploading data

# %%
df = pd.read_csv("../input/loan-approval-prediction/Decision_Tree_Dataset.csv")

# %%
df.head()

# %%
len(df)

# %%
df.shape

# %%
df.describe()

# %%
df.dtypes

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# ##### Checking for missing values

# %%
df.isnull().sum()

# %% [markdown]
# Data is clean with no presence of null values. ALso, we can see that there are no formatting issues either in this data.

# %% [markdown]
# ### Analysis and Visualization
#
# Since there is no preprocessing to be done, let us go on and do the analysis and Visualization of the data

# %%
sns.pairplot(df, hue="Result")

# %%
(df.Result.value_counts()*100)/len(df)

# %% [markdown]
# This shows that 52.1 percent of the loan applications are rejected and 47.9 percent is accepted. Let us represent this data graphically

# %%
ax = sns.countplot(x="Result", data=df)
for p in ax.patches:
    ax.annotate('{:.2f}%'.format(100*p.get_height()/len(df)), (p.get_x()+0.1, p.get_height()+5))
plt.show()

# %% [markdown]
# Let us now plot each and every variable to see the relation between each variable to our Result variable.

# %%
sns.boxenplot(data=df, x='Result', y = 'Initial Payment')
plt.show()

# %% [markdown]
# The boxen plot shows that there are no outliers in the Initial payment column. Also, other than the median values, the range of values of both the customers who loan was approved and rejected are the same.

# %%
sns.boxplot(data=df, x='Result', y = 'Last Payment')
plt.show()

# %% [markdown]
# We can see a clear difference in the range of values of of the rejected and approved groups. This shows that Last payment amount has an effect on the loan approval.

# %%
sns.boxplot(data=df, x='Result', y = 'Credit Score')
plt.show()

# %% [markdown]
# This variable does not seem to have muchh affect either. Though the credit score is higher, the loan seems to get rejected. Hence we can disregard thsi variable.
# We are not doing the analysis on House number as it does not have any weightage on the loan approval decision.

# %% [markdown]
# After this analysis, we can conclude that Last Payment Amount is the only variable that has any effect of the loan approval decision.

# %% [markdown]
# ### Model Building

# %%
#Separating the target variable
X = df.values[:,1:5]
Y = df.values[:,0]

# %%
#Splitting dataset inot train and test data
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3, random_state=100)

# %%
dtc = DecisionTreeClassifier(criterion="entropy", random_state =100, max_depth=3, min_samples_leaf=5)
dtc.fit(X_train,Y_train)

# %%
#Function to make predictions
y_pred = dtc.predict(X_test)
y_pred

# %%
accuracy_score(Y_test,y_pred)*100
