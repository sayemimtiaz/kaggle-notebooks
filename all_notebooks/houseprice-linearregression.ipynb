# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df= pd.read_csv('../input/usa-housing/USA_Housing.csv')

# %%
df.info()

# %%
df.head()

# %%
df.tail()

# %%
df.describe()

# %%
df.shape

# %%
sns.heatmap(df.corr(), annot=True,cmap='Reds')

# %%
sns.pairplot(df)

# %%
adrs=df['Address']
adrs

# %%
df.drop( 'Address' , inplace=True , axis=1)
df.info()

# %%
x = df.drop('Price', axis=1)
y= df['Price']

# %%
x.info()

# %%
df['Address']=adrs
df.info()

# %%
x.columns

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)

# %%
pd.DataFrame(model.coef_, x.columns, columns=['Coefs'])

# %%
y_pred = model.predict(x_test)

# %%
test_residuals=y_test-y_pred

# %%
from sklearn import metrics

# %%
from sklearn import metrics
MAE= metrics.mean_absolute_error(y_test, y_pred)
MSE= metrics.mean_squared_error(y_test, y_pred)
RMSE=np.sqrt(MSE)

pd.DataFrame([MAE, MSE, RMSE ], index=['MAE', 'MSE', 'RMSE'], columns=['Metrics'])

# %%
'mean of yTest : {} mean of yPredict : {} and mean : {}'.format(y_test.mean() , y_pred.mean() , df['Price'].mean())

# %%
sns.scatterplot( x=y_test , y=y_pred)
plt.xlabel('y_test')
plt.ylabel('y_predict')

# %%
sns.scatterplot(x=y_test, y=test_residuals)
plt.axhline(y=0, color='r', ls='--')

# %%
sns.distplot(test_residuals, bins=100, kde=True)

# %%
from joblib import dump,load

# %%
dump(model, 'Price')

# %%
load_model = load('Price')

# %%
#Avg. Area Income :100000  Avg. Area House Age:3  Avg. Area Number of Rooms :4    Avg. Area Number of Bedrooms: 2   Area Population: 20000
Campaign=[[100000 , 3 , 4 , 2 , 20000]]

# %%
load_model.predict(Campaign)
