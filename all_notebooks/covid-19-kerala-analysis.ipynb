# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
eda= pd.read_csv("/kaggle/input/covid19-india-statewise-reported-cases-timeseries/covid19-india-statewise-timeseries.csv", index_col=0, parse_dates=True)

# %%
eda.head()

# %%
eda.tail()

# %%
neweda = eda[(eda.State=="Kerala")]

# %%
neweda

# %%
import matplotlib.ticker as ticker
plt.figure(figsize=(15,8))
neweda['Month'] = neweda.index.month
plt.bar(neweda['Month'],neweda['Total Confirmed Cases'])
plt.xlabel('Month')
plt.ylabel('Total Confirmed Cases')
plt.title('Analysis of Cases')

# %%
import matplotlib.ticker as ticker
plt.figure(figsize=(15,8))
neweda['Month'] = neweda.index.month
plt.bar(neweda['Month'],neweda['Death'])
plt.xlabel('Month')
plt.ylabel('Deaths')
plt.title('Analysis of Deaths')

# %%
import matplotlib.ticker as ticker
plt.figure(figsize=(15,8))
neweda['Month'] = neweda.index.month
plt.bar(neweda['Month'],neweda['Cured/Discharged/Migrated'])
plt.xlabel('Month')
plt.ylabel('Recovered')
plt.title('Analysis of Recovery')

# %%
from sklearn.preprocessing import LabelEncoder
import random
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
cols=neweda.columns
cols=['Total Confirmed Cases','Cured/Discharged/Migrated','Death']

# %%
neweda = neweda[cols]
neweda

# %%
final = neweda.fillna(0)

# %%
X = final.iloc[:,:-1].values
Y = final.iloc[:,-1].values

# %%
X

# %%
Y

# %%
X.shape

# %%
Y.shape

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.25,random_state=0)

# %%
X_train.shape

# %%
X_test.shape

# %%
Y_train.shape

# %%
Y_test.shape

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train,Y_train)

# %%
Y_pred = lr.predict(X_test)

# %%
Y_test

# %%
Y_pred

# %%
from sklearn.metrics import confusion_matrix
confusion = confusion_matrix(Y_test, Y_pred)
print(confusion)

# %%
TN = confusion [0,0] #True Negative
FP = confusion [0,1] #False Positive
FN = confusion [1,0] #False Negative
TP = confusion [1,1] #True Positive

# %%
print(confusion)
print ("TN: ", TN)
print ("FP: ", FP)
print ("FN: ", FN)
print ("TP: ", TP)
