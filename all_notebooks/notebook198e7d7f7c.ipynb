# %%
import pandas as pd
import numba as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
data=pd.read_csv("../input/employee-salary-dataset/Employee_Salary_Dataset.csv")

# %%
data.head()

# %%
data.info()

# %%
data.describe()

# %%
plt.figure(figsize=(10,7))
plt.style.use('fivethirtyeight')
sns.lineplot(x='Experience_Years',y="Salary",data=data)

# %%
plt.figure(figsize=(10,7))
plt.style.use('ggplot')
sns.lineplot(x='Age',y="Salary",data=data)

# %%
plt.figure(figsize=(10,7))
plt.style.use('ggplot')
sns.barplot(x='Gender',y='Salary',data=data)

# %%
from pandas_profiling import ProfileReport

# %%
x=ProfileReport(data)

# %%
x
