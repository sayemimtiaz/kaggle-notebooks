# %% [markdown]
# ### This dataset is small contribute to all Indian Women. <a href="https://www.kaggle.com/imoore/7k-indian-famous-women">Read More</a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

df = pd.read_csv('../input/7k-indian-famous-women/data.csv')
df

# %%
print('<<Column Name>>              <<Unique Values>>\t<<Non-NaN Rows>>')
print('='*70)
for col in df.columns:
    print(col.ljust(30,' '), len(df[col].unique()),'\t\t', df[col].count())
