# %% [markdown]
# #  All about Accuracy, Recall, Precision, F-Score & Specificity
# ## which one to Choose?

# %% [markdown]
# Many of us participate in alot of competitions on various platforms and these competitions always comeup with some different *Evaluation Metrics* or *Evaluation Criteria*. Only half of the people check for the evaluation metrics and of them only few are aware of these all Metrics. The main aim of this Notebook is to serve some basic overview about Basic metrics that every Competitor should know about.

# %% [markdown]
# With out wasting some more time lets just dive into the topic.

# %% [markdown]
# **Lets go :**

# %% [markdown]
# Let us suppose that we are dealing with any classification problem and where the outcome is all about whether a patient has Cancer or not.
# This is a very basic kind of classification problem where we have to answer in Yes or No (Binary Classification).
# Now lets suppose that we have actually created a *Machine Learning Model* how would we decide whether our model is good or bad ?
# For answering this question we first need to look at all the possible outcomes that our model can predict. Lets have a look at all the Possible outcomes:
# 1. A person has Cancer and we predicted it correctly.
# 2. A person doesn't have cancer and We predicted it correctly again. But things always don't go in right directions...
# 3. A person donot have Cancer and we have predicted that he is suffering from it. This would be bad as the patient would go in depression about a disease that he never really have.
# 4. A person have cancer and we have predicted that he is safe and This is the most risky thing for the patient as he would never really go through the treatment as he always trusted upon us where the Model actually broke his trust.
#
# So these four cases are called as **True Positive(TP), True Negative(TP), False Positive(FP), False Negative(FN)** respectively.

# %% [markdown]
# The Last outcome would be the worst possible outcome even if our model comes up with 98% of Accuracy...
# Wait! Does it mean that a model with 98% accuracy is Bad? It is not but still failed to diagnose the outcome correctly.'
# Then what is the solution for it? And the Answer for this is **Recall, Precision, F-Score & Specificity**.
# I know the answer is bit of confusing lets firstly understand them and then we can come to the conclusion behind this answer.

# %% [markdown]
# # 1. Precision:

# %% [markdown]
# It is the ratio of **correctly predicted Positives** to the **All positives**. This simply means the ratio of **True Positives** over all the **predicted true positives** in our Dataset
#
# **Precision=(TP)/(TP+FP)**
#
# **When to use Precision ?**
#
# It is useful to know How many of those who we labeled as having Cancer did actually have Cancer?

# %% [markdown]
# # 2. Recall or Sensitivity:

# %% [markdown]
# It is same as the precision but the only difference is that precision is the count of all True Positives over all True Positive Predictions where as **Recall** is the **count of True Positives** over **all True positives.**
#
# **Recall=(TP)/(TP+FN)**
#
# **When to use Recall ?**
#
# It is useful to know of all the people who had Cancer, how many of those we correctly predict ?

# %% [markdown]
# # 3. F-Score or F1-Score or F-Measure:

# %% [markdown]
# F1 Score considers both precision and recall.
# It is the harmonic mean(average) of the precision and recall.
# F1 Score is best if there is some sort of balance between precision (p) & recall (r) in the system. Oppositely F1 Score isn’t so high if one measure is improved at the expense of the other.
#
# **F-Score=2*(Recall * Precision) / (Recall + Precision)**

# %% [markdown]
# # 4. Specificity:

# %% [markdown]
# It is the opposite of what recall does as it is the ratio of correctly predicted Negatives over all Negatives.
#
# **Specificity=TN/(TN+FP)**
#
# **When is Specificity useful ?**
#
# It is useful to know of all the people who donot have Cancer, how many of those did we correctly predict ?

# %% [markdown]
# # 5. Accuracy:

# %% [markdown]
# This score is for overall review of our model. It is the ratio of all correct predictions to the all data points.
#
# **Accuracy=(TP+TN)/(TP+FP+FN+TN)**
#
# It doesn't care about the predictions that went right in any of the specific caegory. Its the the Correct Prediction and These Correct Predictions can be about Whether the Patient had or didnot had Cancer.

# %% [markdown]
# # Now the question is which one should be our choice for evaluation ????
# # And the Answer is Precison because it reduces the wrong predictions about a person not having Cancer as this would be the worst possible case.

# %% [markdown]
# Thats all about these basic metrcis if you really enjoyed this read please give it an upvote and that would encourage me to write conepts in a Simplified model to serve the Learners
# **Thanks alot for reading**
