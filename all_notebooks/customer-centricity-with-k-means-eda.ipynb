# %% [markdown]
# # 1.Importing and Exploring Data

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.

# %% [markdown]
# **Importing the Python modules**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
import warnings 
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
warnings.filterwarnings('ignore')
plt.style.use('ggplot')

# %% [markdown]
# **Importing the dataset**

# %%
df = pd.read_csv('../input/Mall_Customers.csv')
df.head(5)

# %%
df.describe().T

# %% [markdown]
# 1. Mean Age of the customer is 38.85
# 2. Mean Annual income $200
# 3. Mean Spending Score (1-100) is 50.20

# %% [markdown]
# # 2.Data Vsualizations

# %% [markdown]
# **Histogram**

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1,)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.hist(df.Age,bins=30)

plt.subplot(1,3,2)
plt.title('Annual Income Distribution')
plt.xlabel('Annual Income in k$')
plt.ylabel('Count')
plt.hist(df['Annual Income (k$)'],bins=30)

plt.subplot(1,3,3)
plt.title('Spending Score Distribution')
plt.xlabel('Spending Score')
plt.ylabel('Count')
plt.hist(df['Spending Score (1-100)'],bins=30)

plt.tight_layout()

pass

# %% [markdown]
# **Observations**
# 1. More people are in age group 30-35
# 2. More people have income in range 60K-80K $
# 3. Spending score is in the range 40 - 60

# %% [markdown]
# **Distribution**

# %%
plt.figure(1, figsize=(15,6))
n=0
for x in ['Age','Annual Income (k$)','Spending Score (1-100)']:
    n+=1
    plt.subplot(1,3,n)
    plt.subplots_adjust(hspace=0.5, wspace = 0.5)
    sns.distplot(df[x],bins = 20)
    plt.title('Distplot of {}'.format(x))
plt.show()

# %% [markdown]
# Age, Annual income and spending Score are Normally Distributed

# %% [markdown]
# Scatter Plot

# %%
plt.figure(figsize=(15,7))
plt.subplot(1,3,1,)
plt.title('Age Vs Spening Score')
plt.xlabel('Age')
plt.ylabel('Spending Score')
plt.scatter(df['Age'],df['Spending Score (1-100)'],s=100,c='g')

plt.subplot(1,3,2)
plt.title('Annual Income Vs Spending Score')
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.scatter(df['Annual Income (k$)'],df['Spending Score (1-100)'],s=100,c='b')

colors = ['g','r','m','b']

plt.subplot(1,3,3,)
plt.title('Gender Vs Spending Score')
plt.xlabel('Gender')
plt.ylabel('Spending Score')
cat_list=df['Gender'].unique()
cat_average=df.groupby('Gender').mean()['Spending Score (1-100)']
plt.bar(cat_list,cat_average,color=colors)

plt.tight_layout()

pass

# %% [markdown]
# * Annual income gives a better clustering of the dataset
# * People of age group 20-40 spend more the older age group.
# * There are 5 diffrent clusters in income
# * Men spend more then women

# %% [markdown]
# **Relation between Age, Annual income and Spending Score**

# %%
plt.figure(1,figsize=(15,7))
n=0
for x in ['Age','Annual Income (k$)','Spending Score (1-100)']:
    for y in ['Age','Annual Income (k$)','Spending Score (1-100)']:
        n+=1
        plt.subplot(3,3,n)
        plt.subplots_adjust(hspace = 0.5, wspace= 0.5)
        sns.regplot(x=x,y=y,data = df)
        plt.ylabel(y.split()[0]+''+y.split()[1] if len(y.split())> 1 else y)
plt.show()

# %% [markdown]
# **Observations**
# * With age increses spending scores reduces. This is beacause of peole grow older they have reduces the spending as their execive need reduces
# * People in age group 30-40 earn more. This is beacuse of in this age range most people reach their peak of income
# * There is a relation between annual income and spending score. This will be helpfull during doing the clustering on the data

# %% [markdown]
# # 3. K Means Clustring

# %% [markdown]
# **Matrix of Features**

# %%
X = df.iloc[:,[3,4]].values

# %% [markdown]
# **Elbow Curve**

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i, init = 'k-means++', max_iter = 300, n_init = 10, random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('Wcss')
plt.show()

# %% [markdown]
# With this elbow graph we can see that the optimal value for the K will be 5. Bacause after point 5 we can see that the drop is minimal.

# %% [markdown]
# **K Means Clusters**

# %%
kmeans= KMeans(n_clusters=5, init = 'k-means++', max_iter= 300, n_init = 10, random_state=0)
y_kmeans = kmeans.fit_predict(X)

# %%
plt.scatter(X[y_kmeans == 0,0],X[y_kmeans==0,1], s= 100, c='magenta', label = 'Careful')
plt.scatter(X[y_kmeans == 1,0],X[y_kmeans==1,1], s= 100, c='yellow', label = 'Standard')
plt.scatter(X[y_kmeans == 2,0],X[y_kmeans==2,1], s= 100, c='green', label = 'Target')
plt.scatter(X[y_kmeans == 3,0],X[y_kmeans==3,1], s= 100, c='cyan', label = 'careless')
plt.scatter(X[y_kmeans == 4,0],X[y_kmeans==4,1], s= 100, c='burlywood', label = 'Sensible')
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1],s = 300, c='red', label ='Centroids')
plt.title('Cluster of Clients')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show
pass

# %% [markdown]
# * Cluster 1 - High income low spending = Carefull
# * Cluster 2 - medium income medium spending = Standerd
# * Cluster 3 - High income high spending = Target
# * Cluster 4 - Low income high spending = Careless
# * Cluster 5 - low income high spending = Sensible

# %% [markdown]
# # 4.Relation Between Age & Spending Score

# %% [markdown]
# **Matrix of Features**

# %%
X1 = df.iloc[:,[2,4]].values

# %% [markdown]
# **Elbow Curve**

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i, init = 'k-means++', max_iter = 300, n_init = 10, random_state=0)
    kmeans.fit(X1)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('Wcss')
plt.show()

# %% [markdown]
# With this elbow graph we can see that the optimal value for the K will be 4. Bacause after point 5 we can see that the drop is minimal.

# %% [markdown]
# **Applying K means to the Dataset**

# %%
plt.scatter(X1[y_kmeans==0,0],X1[y_kmeans==0,1],s=100,c='magenta',label='Low spenders ')
plt.scatter(X1[y_kmeans==1,0],X1[y_kmeans==1,1],s=100,c='blue',label='Young High Spenders')
plt.scatter(X1[y_kmeans==2,0],X1[y_kmeans==2,1],s=100,c='green',label='Young Average Spenders')
plt.scatter(X1[y_kmeans==3,0],X1[y_kmeans==3,1],s=100,c='cyan',label='Old Average Spenders')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=300,c='red',label='Centroids')
plt.title('Cluster of Clients')
plt.xlabel('Age')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.ioff()
plt.show
pass

# %% [markdown]
# * Cluster 1 - Low Spenders
# * Cluster 2 - young High Spenders
# * Cluster 3 - Young AVG. Spenders
# * Cluster 4 - Old AVG. Spenders
#
# *We can see that only young age goroup is high spenders. as age increses they fall into AVG. and low spender group*

# %% [markdown]
# # 5. Compare Given VS Predicted  Annual Income

# %% [markdown]
# Goal of this section is to predict annual income with the given age segments and relate the scenario and observe if any changes heppen or not.

# %% [markdown]
# **Given Age Vs Annual Income**

# %%
plt.plot(df['Annual Income (k$)'],df['Age'])
plt.title('Age vs Annual Income')
plt.xlabel('Annual Income')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# Let's start predict the annual income according to customers given age.

# %% [markdown]
# First, need to select one dependent variable and one independent variable to start the process. Here is Age is the independent variable and Annual inocome is the dependent variable. As we want to predict Annual Income on the base of Age

# %%
X = df['Age'].values
y = df['Annual Income (k$)'].values
X = X.reshape(-1, 1)
y = y.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test = train_test_split(X,y, test_size = 1/2, random_state= 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# %%
y_pred = regressor.predict(X_test)

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.scatter(X_test, regressor.predict(y_test), color= 'blue')
plt.title('Age Vs Annual Income')
plt.xlabel('Age')
plt.ylabel('Annual Income')
plt.show()
