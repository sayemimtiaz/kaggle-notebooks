# %% [markdown]
# # Introduction
#
# In this mini tutorial series, I will guide you through the data journalism workflow I use for my **analytics competitions** entries. You will see behind the scenes of exploratory data analysis  and how messy it is in the works. But you will also learn how to clean up these messes and create comprehensive visualizations to tell a story with your data. For this tutorial, we will using the popular [Netflix Movies and TV Shows](https://www.kaggle.com/shivamb/netflix-shows) dataset.
#
# <div class="alert alert-block alert-warning">
# <b>Note:</b> The original notebook was split into a series of multiple notebooks from revision 7 on to break down each topic and make it easier to understand.
# </div>
#
#
# # Prerequisites
#
# From the information I have gathered if you are looking for a career in data journalism, you should be able to work with **R and ggplot (and also Adobe Illustrator)** since established data journalists at *The Economist, The Guardian, and BBC* are all using R. Also, some of the best Kagglers in the notebooks category also use R, such as [Michal Bogacz in "Why is Israel a leader in vaccination? 💉 "](https://www.kaggle.com/michau96/why-is-israel-a-leader-in-vaccination) or [Heads or Tails in "Back to (predict) the future - Interactive M5 EDA"](https://www.kaggle.com/headsortails/back-to-predict-the-future-interactive-m5-eda). However, I will be using **Python with matplotlib and seaborn** in this notebook because at the time of this writing I have yet to get started with R.
#
#
# # Workflow Overview
# The data journalism workflow I follow is depicted as follows.
# Before we begin with any exploration or visualizations of the data, we first have to collect, clean and preprocess the data (see [Lesson 1: Data Preparation](https://www.kaggle.com/iamleonie/data-journalism-data-preparation-1-5)).
# Then we get knee deep into the data and explore it (see [Lesson 2: Exploratory Data Analysis](https://www.kaggle.com/iamleonie/data-journalism-exploratory-data-analysis-2-5)).
# Once we are done with our research, we have gathered a lot of unstructured information which we will order into a story concept (see [Lesson 3: Story Concept](http://www.kaggle.com/iamleonie/data-journalism-story-concept-3-5)).
# Next we will create the matching visualization to the message or story we want to convey to our audience (see [Lesson 4: Visualization & Storytelling](https://www.kaggle.com/iamleonie/data-journalism-visualization-storytelling-4-5)).
# Finally, we will put it all together to a comprehensive analytics report (see the [final result](https://www.kaggle.com/iamleonie/data-journalism-visualization-storytelling-4-5/))
#
# ![Screenshot%202021-03-23%20at%2013.28.49.png](attachment:Screenshot%202021-03-23%20at%2013.28.49.png)
#
# # Get Started
# 🚀Let's begin with the [first lesson on data preparation](https://www.kaggle.com/iamleonie/data-journalism-data-preparation-1-5).
#
# # References and Further Ressources
# [1] [Kaggle Learn: Data Visualization](https://www.kaggle.com/learn/data-visualization)
#
# [2] [The Guardian: Data journalism broken down: what we do to the data before you see it](https://www.theguardian.com/news/datablog/2011/apr/07/data-journalism-workflow)
#
# [3] [Nussbaumer Knaflic, C. (2015). Storytelling with data](https://www.storytellingwithdata.com/)
#
# [4] [Andrew Flowers: "The Six Types of Data Journalism Stories"](https://www.youtube.com/watch?v=4zLo12JdeOA)
#
# [5] [Sarah Leo in The Economist on Medium: Mistakes, we’ve drawn a few](https://medium.economist.com/mistakes-weve-drawn-a-few-8cdd8a42d368)
#
# # References Specific to the Domain of Netflix TV Shows
# [A] https://en.wikipedia.org/wiki/TV_Parental_Guidelines
#
# [B] https://screenrant.com/netflix-movies-release-dates-wednesday-not-friday-reason/
#
# [C] https://about.netflix.com/en
