# %% [markdown]
# ## **<center>Best Data Science YouTube Channels</center>**
# If you decided to learn data science by you own, you can learn through many resources which are available on the internet. Many online courses, articles and YouTube channels which provides you datascience training. Videos are one of the great learning tool. There is lot of content related to datascience is available on YouTube. So it is difficult for a beginners to discover quality content. Before start learning data science on YouTube, you must choose best youtube channels because there are a lot of low quality or simply wrong data science tutorials out there. And even if they are free, you’ll still have to pay for them with your time.
#
# So in this Notebook I am going to share with you some best datascience YouTube channels, which will be helpful for you to start learning datascience easily without struggling in looking for quality content.
#
#
# **Tip:**
#  ><i>Remember only watching tutorials is not enough, you have to practice the concept for atleast 2 to 3 hours after watching tutorial.</i>

# %% [markdown]
# ### **Importing required libraries**

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

sns.set(style='darkgrid')


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
file_path = "/kaggle/input/data-science-youtube-channel-collection-to-learn/YouTube_Data_Science_Channels.csv"

# %%
data = pd.read_csv(file_path)

# %%
data.head(10)

# %% [markdown]
# ### **Checking meta information about dataframe**

# %%
print(f"Shape of dataframe is: {data.shape}")

# %%
data.describe()   # statistical information of data

# %%
data.info()

# %% [markdown]
# ### **Checking for NaN values**

# %%
data.isnull().sum()

# %% [markdown]
# **No NaN value found**

# %% [markdown]
# ### **Sorting a data from highest Subscribers channel to lowest**

# %%
data.sort_values("Appx_Actual_Subscribers", ascending=False, inplace=True)

# %%
data[['YouTube Channel Name',
      'Appx_Actual_Subscribers',
      'YouTube_Channel_Link']].head(10)

# %% [markdown]
# ### **Reseting index of dataframe**

# %%
data.reset_index(inplace = True)

# %%
data.head()

# %% [markdown]
# ### **Dropping some unnecessary columns**

# %%
data.drop(['index', "ID"], axis=1, inplace=True)

# %%
data.columns

# %% [markdown]
# ### **Checking statistical information of `Appx_Actual_Subscribers`**

# %%
pd.DataFrame(data['Appx_Actual_Subscribers'].describe())

# %% [markdown]
# ### **Top Data Science YouTube channels**

# %%
plt.figure(figsize = (7,6))
plt.title("Top 20 Best Data Science Youtube Channels\n", size = 15);
sns.barplot(y = "YouTube Channel Name", x = "Appx_Actual_Subscribers",
            data = data.head(20), palette="dark");

# %%
plt.figure(figsize = (7,6))

plt.title("Top 20 Best Data Science Youtube Channels\n\n", size = 15);

sns.barplot(y = "YouTube Channel Name", x = "Appx_Actual_Subscribers",
            data = data.head(20), palette="bright")

plt.axvline(data['Appx_Actual_Subscribers'].mean(),
            linestyle = '--',
            color = 'k',
            linewidth = 2)

plt.text(13,-1, "Average Subscribers", fontsize = 13);

# %% [markdown]
# **It seems like top 4 channels has great content, Therefore they has very large numbers of subscribers**
#
# **Also top 14 channels has subscribers above average**

# %% [markdown]
# ### **Declaring a function that convert links to clickable**

# %%
def clickable(path):    
    # returns the final component of a url
    final_url = os.path.basename(path)
      
    # convert the url into link
    return f'<a href="{path}">{final_url}</a>'

# %% [markdown]
# ### **YouTube channels which has subscribers above 1M**

# %%
above_1M = data[data['Above_1m'] == 1]

# %% [markdown]
# **Only 4 channels has subscribers above 1M**

# %%
plt.figure(figsize=(9,5))

plt.title("YT channels whose subscribers is above 1M\n", size = 15)
plots = sns.barplot(x = 'YouTube Channel Name',
                 y = 'Appx_Actual_Subscribers',
                 data = above_1M)

for bar in plots.patches:
    _ = plots.annotate(format(bar.get_height(), '.2f'), 
                       (bar.get_x() + bar.get_width() / 2, 
                        bar.get_height() - (bar.get_height()-3.1) / 2),
                        ha='center',
                        va='center',
                        size=15, xytext=(0, 0),
                        bbox=dict(boxstyle="round4, pad=0.6", fc="w", ec="k", lw=2),
                        textcoords='offset points')


plt.ylabel("Subscriber (in Million)")
plots.set_xticklabels(plots.get_xticklabels(),rotation = 30);

# %%
above_1M[['YouTube Channel Name','YouTube_Channel_Link']].style.format({'YouTube_Channel_Link' : clickable})

# %% [markdown]
# #### **Click on above links to visit channel**

# %% [markdown]
# ---
# ### **YouTube channels which has subscribers between 200k and 1M**

# %%
bw_200k_and_1m = data[data['Between_200k_1m'] == 1]

# %%
plt.figure(figsize=(10,6))

plt.title("YT channels whose subscribers is b/w 200k and 1M\n", size = 15)
plots = sns.barplot(y = 'YouTube Channel Name',
                 x = 'Appx_Actual_Subscribers',
                 data = bw_200k_and_1m)

for bar in plots.patches:
        _ = plots.annotate(format(bar.get_width(), '.0f'), 
               (bar.get_width() / 2, 
                bar.get_y() + bar.get_height() / 2), ha='center', va='center',
               size=10, xytext=(0, 0),bbox=dict(fc="w", ec="k", lw=2),
               textcoords='offset points')

plt.ylabel("Channel Name")
plt.xlabel("\nSubscribers");

# %%
bw_200k_and_1m[['YouTube Channel Name','YouTube_Channel_Link']].style.format({'YouTube_Channel_Link' : clickable})

# %% [markdown]
# #### **Click on above links to visit channel**

# %% [markdown]
# ---
# ### **YouTube channels which has subscribers between 150k and 200k**

# %%
bw_150k_and_200k = data[data['Between_150k_200k'] == 1]

# %%
bw_150k_and_200k

# %% [markdown]
# **Only 1 channel has subscribers between 150k and 200k**

# %%
bw_150k_and_200k[['YouTube Channel Name','YouTube_Channel_Link']].style.format({'YouTube_Channel_Link' : clickable})

# %% [markdown]
# #### **Click on above links to visit channel**

# %% [markdown]
# ---
# ### **YouTube channels which has subscribers between 100k and 150k**

# %%
bw_100k_and_150k = data[data['Between_100k_150k'] == 1]

# %%
plt.figure(figsize=(10,5))

plt.title("YT channels whose subscribers is b/w 100k and 150k\n", size = 15)
plots = sns.barplot(x = 'YouTube Channel Name',
                 y = 'Appx_Actual_Subscribers',
                 data = bw_100k_and_150k)

for bar in plots.patches:
    _ = plots.annotate(format(bar.get_height(), '.2f'), 
                   (bar.get_x() + bar.get_width() / 2, 
                    bar.get_height() - (bar.get_height()-3.1)/2), ha='center', va='center',
                   size=15, xytext=(0, 0),bbox=dict(boxstyle="round4,pad=0.6", fc="w", ec="black", lw=2),
                   textcoords='offset points')

plt.ylabel("Subscribers")
plots.set_xticklabels(plots.get_xticklabels(),rotation = 30);

# %%
bw_100k_and_150k[['YouTube Channel Name','YouTube_Channel_Link']].style.format({'YouTube_Channel_Link' : clickable})

# %% [markdown]
# #### **Click on links to visit channel**

# %% [markdown]
# ---
# ### **YouTube channels which has subscribers between 50k and 100k**

# %%
bw_50k_and_100k = data[data['Between_50k_100k'] == 1]

# %%
plt.figure(figsize=(10,6))

plt.title("YT channels whose subscribers is b/w 50k and 100k\n", size = 15)
plots = sns.barplot(y = 'YouTube Channel Name',
                 x = 'Appx_Actual_Subscribers',
                 data = bw_50k_and_100k,
                palette = 'gnuplot')

for bar in plots.patches:
        _ = plots.annotate(format(bar.get_width(), '.0f'), 
               (bar.get_width() / 2, 
                bar.get_y() + bar.get_height() / 2), ha='center', va='center',
               size=10, xytext=(0, 0),bbox=dict(fc="w", ec="k", lw=2),
               textcoords='offset points')

plt.ylabel("Channel Name")
plt.xlabel("\nSubscribers");

# %%
bw_50k_and_100k[['YouTube Channel Name','YouTube_Channel_Link']].style.format({'YouTube_Channel_Link' : clickable})

# %% [markdown]
# ---
# ### **YouTube channels which has subscribers between 25k and 50k**

# %%
bw_25k_and_50k = data[data['Between_25k_50k'] == 1]

# %%
plt.figure(figsize=(10,5))

plt.title("YT channels whose subscribers is b/w 25k and 50k\n", size = 15)
plots = sns.barplot(x = 'YouTube Channel Name',
                 y = 'Appx_Actual_Subscribers',
                 data = bw_25k_and_50k)

for bar in plots.patches:
    _ = plots.annotate(format(bar.get_height(), '.2f'), 
                   (bar.get_x() + bar.get_width() / 2,                    
                    bar.get_height() - (bar.get_height()-3.1)/2),
                    ha='center',
                    va='center',
                    size=15,
                    xytext=(0, 0),
                    bbox=dict(boxstyle="round4,pad=0.6", fc="w", ec="k", lw=2),
                    textcoords='offset points')

plt.ylabel("Subscribers")
plots.set_xticklabels(plots.get_xticklabels(),rotation = 30);

# %%
bw_25k_and_50k[['YouTube Channel Name','YouTube_Channel_Link']].style.format({'YouTube_Channel_Link' : clickable})

# %% [markdown]
# ---
# ### **YouTube channels which has subscribers between 10k and 25k**

# %%
bw_10k_and_25k = data[data['Between_10k_25k'] == 1]

# %%
plt.figure(figsize=(10,5))

plt.title("YT channels whose subscribers is b/w 10k and 25k\n", size = 15)
plots = sns.barplot(y = 'YouTube Channel Name',
                 x = 'Appx_Actual_Subscribers',
                 data = bw_10k_and_25k)

for bar in plots.patches:
        _ = plots.annotate(format(bar.get_width(), '.0f'), 
               (bar.get_width() / 2, 
                bar.get_y() + bar.get_height() / 2),
                ha='center',
                va='center',
               size=10,
               xytext=(0, 0),
               bbox=dict(fc="w", ec="k", lw=2),
               textcoords='offset points')


plt.xlabel("Subscribers")
plots.set_xticklabels(plots.get_xticklabels(),rotation = 30);

# %%
bw_10k_and_25k[['YouTube Channel Name','YouTube_Channel_Link']].style.format({'YouTube_Channel_Link' : clickable})

# %% [markdown]
# ---
# ### **YouTube channels which has subscribers between 5k and 10k**

# %%
bw_5k_and_10k = data[data['Between_5k_10k'] == 1]

# %%
plt.figure(figsize=(7,5))

plt.title("YT channels whose subscribers is b/w 5k and 10k\n", size = 15)
plots = sns.barplot(x = 'YouTube Channel Name',
                 y = 'Appx_Actual_Subscribers',
                 data = bw_5k_and_10k)

for bar in plots.patches:
    _ = plots.annotate(format(bar.get_height(), '.2f'), 
                   (bar.get_x() + bar.get_width() / 2,                    
                    bar.get_height() - (bar.get_height()-3.1)/2),
                    ha='center',
                    va='center',
                    size=15,
                    xytext=(0, 0),
                    bbox=dict(boxstyle="round4,pad=0.6", fc="w", ec="k", lw=2),
                    textcoords='offset points')


plt.ylabel("Subscribers")
plots.set_xticklabels(plots.get_xticklabels(),rotation = 30);

# %%
bw_5k_and_10k[['YouTube Channel Name','YouTube_Channel_Link']].style.format({'YouTube_Channel_Link' : clickable})

# %% [markdown]
# ---
# ### **YouTube channels which has subscribers between 1k and 5k**

# %%
bw_1k_and_5k = data[data['Between_1k_5k'] == 1]

# %%
plt.figure(figsize=(12,5))

plt.title("YT channels whose subscribers is b/w 1k and 5k\n", size = 15)
plots = sns.barplot(x = 'YouTube Channel Name',
                 y = 'Appx_Actual_Subscribers',
                 data = bw_1k_and_5k)

for bar in plots.patches:
    _ = plots.annotate(format(bar.get_height(), '.0f'), 
                   (bar.get_x() + bar.get_width() / 2,                    
                    bar.get_height() - (bar.get_height()-3.1)/2),
                    ha='center',
                    va='center',
                    size=15,
                    xytext=(0, 0),
                    bbox=dict(boxstyle="round4,pad=0.6", fc="w", ec="k", lw=2),
                    textcoords='offset points')




plt.ylabel("Subscribers")
plots.set_xticklabels(plots.get_xticklabels(),rotation = 30);

# %%
bw_1k_and_5k[['YouTube Channel Name','YouTube_Channel_Link']].style.format({'YouTube_Channel_Link' : clickable})

# %% [markdown]
# #### **Click on links to visit channel**

# %% [markdown]
# ---
# ### **YouTube channels which has subscribers below 1k**

# %%
below_1k = data[data['Below_1k'] == 1]

# %%
below_1k

# %% [markdown]
# **Only 1 YT channel in the list has subscriber below 1k, and now at the time of writting this notebook, this channel has 1.87k subscribers**

# %%
below_1k[['YouTube Channel Name','YouTube_Channel_Link']].style.format({'YouTube_Channel_Link' : clickable})

# %% [markdown]
# #### **Click on above link to visit channel**

# %% [markdown]
# ##### **Adding column in dataframe by taking log of `Appx_Actual_Subscribers` because some large numbers are present in`Appx_Actual_Subscribers` which squeezes the lowest on.**

# %%
data["log_Appx_Actual_Subscribers"] = np.log(data['Appx_Actual_Subscribers'])

# %% [markdown]
# **From this dataset, most of the datascience Youtube channels has subscribers between 200k and 1M, which can also be shown below graph**

# %%
plt.rcParams["figure.figsize"] = [15, 20]


plt.title("Average subscribers of Data Science Channels on Youtube \n", size = 25);

sns.barplot(y = "YouTube Channel Name", x = "log_Appx_Actual_Subscribers",
            data = data, palette="cool_r")

plt.axvline(data['log_Appx_Actual_Subscribers'].mean(),
            linestyle = '--',
            color = 'k',
            linewidth = 2);
