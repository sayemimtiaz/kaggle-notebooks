# %%
import pandas as pd
import numpy as np
import seaborn as sbn
import matplotlib.pyplot as plt
veri = pd.read_csv("../input/dogecoin-data/DOGE-USD.csv")
veri

# %%
veri.describe()

# %%
veri.describe().Volume.div(100)

# %%
veri.corr()

# %%
veri.info()

# %%
veri = veri.dropna()

# %%
sbn.pairplot(veri);
sbn.despine(bottom=True,left=True);

# %%
plt.subplots(figsize=(40,10));
sbn.lineplot(x=veri["Date"],y=veri["Close"]);
sbn.lineplot(x=veri["Date"],y=veri["Open"]);
sbn.despine(bottom=True,left=True);
plt.xticks(rotation=90);

# %%
fig,ax = plt.subplots(2,1,figsize=(30,10))
veri["Volume"] = veri["Volume"].div(1000)
sbn.lineplot(x=veri["Date"],y=veri["Close"],ax=ax[0]);
sbn.boxplot(x=veri["Date"],y=veri["High"],ax=ax[0]);
sbn.boxplot(x=veri["Date"],y=veri["Low"],ax=ax[0]);
sbn.lineplot(x=veri["Date"],y=veri["Volume"],ax=ax[1]);
sbn.despine(bottom=True,left=True);
sbn.despine(bottom=True,left=True);

# %%
from sklearn.ensemble import BaggingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
from warnings import filterwarnings
filterwarnings('ignore')
x = veri[["Open","High","Low","Close"]]
y = veri["Volume"]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=42)
bag_model = BaggingRegressor(bootstrap_features = True)
bag_model.fit(x_train, y_train)
y_pred = bag_model.predict(x_test)
mean_squared_error(y_test, y_pred)

# %%
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
from warnings import filterwarnings
filterwarnings('ignore')
x = veri[["Open","High","Low","Close"]]
y = veri["Volume"] 
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=42)
enet_model = ElasticNet().fit(x_train, y_train)
enet_model.predict(x_test)
mean_squared_error(y_test,enet_model.predict(x_test))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
from warnings import filterwarnings
filterwarnings('ignore')
x = veri[["Open","High","Low","Close"]]
y = veri["Volume"] 
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,
                                                 random_state=42)
model = LinearRegression().fit(x_train,y_train)
#model.score(x_train,y_train)
#model.predict(x_test)
mean_squared_error(y_test,model.predict(x_test))

# %% [markdown]
# mse neden bu kadar yüksek çıktı?
# why is mse so high?
