# %%
# !pip install autoviz

# %%
# !pip install xlrd

# %%
import numpy as np
import pandas as pd
import os
import xlrd
from autoviz.AutoViz_Class import AutoViz_Class

# %%
df1 = pd.read_csv('../input/fetal-health-classification/fetal_health.csv')
df1

# %%
AV = AutoViz_Class()
target = 'fetal_health'
dft = AV.AutoViz(filename='',sep=',',depVar=target,dfte=df1,header=0,verbose=1)
