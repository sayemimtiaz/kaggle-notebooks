# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv('../input/palestine/Palestine.csv')
df

df=df.ffill()
df=df.fillna(0)
df

X=df[['Palestinians Injuries','Israelis Injuries','Palestinians Killed','Israelis Killed']]
Y=df.Year

# %%
A=df['Year']
B=df['Palestinians Killed']
A

# %%
plt.bar(df['Year'],df['Palestinians Injuries'],color="r",label='Palestinians Injuries')
plt.bar(df['Year']-0.2,df['Israelis Injuries'],color="b",width=0.8,label='Israelis Injuries')
plt.bar(df['Year']-0.24,df['Palestinians Killed'],color="y",label='Palestinians Killed')
plt.bar(df['Year']-0.3,df['Israelis Killed'],color="g",label='Israelis Killed')
plt.xlim(2002,2021)
plt.xlabel("Year")
plt.ylabel("Casualties")

plt.legend()

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(df[['Year']],df['Palestinians Killed'])

# %%
model.predict([[2015]])
