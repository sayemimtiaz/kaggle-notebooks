# %%
from IPython.display import Image
from IPython.core.display import HTML 
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import tree
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.decomposition import KernelPCA
from sklearn.cluster import KMeans
from sklearn.metrics import f1_score
from sklearn.metrics import plot_confusion_matrix
import seaborn as sns # Library for Plotting
sns.set # make plots look nicer
sns.set_palette("husl")

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
def plot_results(X_test, y_test, clf):
    transformer = KernelPCA(n_components=2, kernel='linear')
    X_transformed = transformer.fit_transform(X_test)
    X_transformed = pd.DataFrame(X_transformed)
    X_transformed["pred"] = clf.predict(X_test)
    X_transformed["Outcome"] = y_test.values
    X_transformed["correct"] = X_transformed["pred"] == X_transformed["Outcome"] 
    score = f1_score(X_transformed["Outcome"], X_transformed["pred"], average='macro')
    print("You have achieved an f1 score of: ", score)
    print("This is your confusion matrix:")
    plot_confusion_matrix(clf, X_test, y_test, normalize = "true")
    print("Here is the plot of your prediction:")
    fig, ax = plt.subplots(figsize=(25, 10)) # Size of Plot
    ax = sns.scatterplot(x=0, y=1, data=X_transformed, hue="pred", style = "Outcome") # Makes a LinePlot
    plt.rcParams.update({'font.size': 32})
    plt.show()

# %% [markdown]
# # Use Case: Saving Lives with Data
#
# Du bist Wissenschaftler bei der WHO und stößt auf einen Datensatz der vor zwei Jahren in Indien erhoben wurde.
# Dort wurde bei einigen Testpatienten ein professioneller Test auf Lebererkrankungen durchgeführt.
# Du weisst, dass die ländliche Bevölkerung in Indien nur selten über die Mittel für einen professionellen Test verfügt, da dieser eine Leberbiopsie erfordert.
# Die gemessenen Werte lassen sich hingegen auf sehr einfache und kostengünstige Weise durch Blutentnahme erheben.
#
# Wenn du eine sichere Methode findest um Diabetes vorauszusagen, könntest du damit etliche Leben retten oder zumindest verlängern!
#
# Sofort machst du dich an die Arbeit!

# %%
# Read in Data
data = pd.read_csv("/kaggle/input/indian-liver-patient-records/indian_liver_patient.csv")
data["Gender"] = np.where(data['Gender'] == "Female", 1, 0)
data["Dataset"] = np.where(data['Dataset'] == 1, 1, 0)
data = data.rename(columns={"Dataset": "Outcome", "Gender" : "Female"})
data = data.dropna()

data.head()

# %%
data.Outcome.value_counts()

# %% [markdown]
# ## Aufgabe 1
#
# Als erstes schaust du dir ein paar statistische Merkmale an.
# Das hast du schon viele male gemacht und bist dir sicher, dadurch mehr über den Datensatz zu erfahren.
#
# Schaue dir die Statistiken zu den einzelnen features an.

# %%
# Describe the data

# %% [markdown]
# ## Aufgabe 2
#
# Als nächstes willst du dir ein paar correlationen anschauen.
# Vielleicht findest du damit heraus, welche Werte relevant sind.
# Vielleicht kannst du damit schon eine saubere Hypothese aufstellen.
#
# Plotte eine Korrelationsmatrix zum Datensatz.

# %%
# Plot a correlation matrix

# %% [markdown]
# ## Aufgabe 3:
# Du hast gesehen, dass einige Werte wichtiger sind als andere.
# Du denkst, dass du vermutlich einiges herausfinden kannst, in den du Muster in den Features findest.
#
# Plotte mindestestens zwei Feature Kombinationen aus deinen Erkenntnissen aus der Korrelationsmatrix.
# Markiere das Auftreten von Diabetes farblich.

# %%
# Plot two important features Kombinations and highlight the data with diabetes

# %% [markdown]
# ## Aufgabe 4:
# Manche Werte scheinen deutlich aufschlussreicher als Andere.
# Du siehst ein starkes Muster bei Direct_Bilirubin.
# Vielleicht ist das schon alles was es braucht?
#
# Füge ein neues Feature an den Datensatz an, bei dem du ein threshold für Glucose setzt und für jedes Datum prüfst ob der Wert dadrüber oder dadrunter liegt.
# Prüfe wie viele der Outcomes du damit richtig und falsch vorhersagst.
#
# Tipp:
# ```
# # Set true and false values for condition
# data["new_col"] = np.where(data['col'] > X, "Value if true", "Value if false")
#
# # Get the counts of unique values
# data["feature"].value_counts()
# ```

# %%
# Define a threshold
threshold = 0

# Add a new column that is 1 if the patients Glucose is above the Threshold and 0 otherwise


# Add another column that describes if your threshold prediction is the same as Outcome


# Read out how many

# %% [markdown]
# ## Aufgabe 5:
#
# Naja, das hat nur bedingt gut funktioniert. Du bist kein Experte in Medizin und weißt gar nicht so richtig was die Werte bedeuten.
# Aber dafür hast du ja machine learning!
#
# Du hast nicht wirklich viel Zeit, aber zwei Algorithmen willst du zumindest mal anwenden.
# Als erstes den Decision Tree. Der ist gut lesbar und macht am meisten Sinn.
# Den anderen Algorithmus musst du dir noch überlegen.
#
#
# Als allererstes musst du die spalten aus dem letzten Versuch wieder löschen. Diese könnten das Ergebnis verfälschen.
# Dann musst du die Daten in Trainingsdatensatz und Testdatensatz aufteilen.
# Den Code dafür hast du dir schon aufgeschrieben:
# ```
# X_train, X_test, y_train, y_test = train_test_split(data.drop(["Outcome"], axis = 1), data["Outcome"], test_size=.25, random_state=42, stratify=data['Outcome'])
# ```
#
# Schau dir an, wie viele Daten du in den Datensätzen jeweils hast

# %%
# Read in Data again:
# Read in Data
data = pd.read_csv("/kaggle/input/indian-liver-patient-records/indian_liver_patient.csv")
data["Gender"] = np.where(data['Gender'] == "Female", 1, 0)
data["Dataset"] = np.where(data['Dataset'] == 1, 1, 0)
data = data.rename(columns={"Dataset": "Outcome", "Gender" : "Female"})
data = data.dropna()

# Split the data in train and test set


# Print size of each Dataset

# %% [markdown]
# ## Aufgabe 6:
#
# Als nächstes willst du den Decision Tree ausprobieren.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html#sklearn.tree.DecisionTreeClassifier
#
#
# Das Muster hast du dir schon rausgesucht:
# ```
# clf = AlgorithmName(random_state=42)
# clf.fit(train_data, train_labels)
# plot_results(test_data, test_labels, clf)
# ```
#
# P.s.: Den Random state brauchen wir um gleiche Ergebnisse zu bekommen. Diesen immer auf 42 setzen.

# %%
# Set clf to the Decision Tree Clasiifier


# fit the classifier with your train data


# plot your test data with "plot_results"

# %% [markdown]
# ## Aufgabe 7:
# Da Ergebnis ist gar nicht mal so schlecht.
# Du errinerst dich, dass einer der Vorteile des Decision Tree ist, dass man ihn gut auslesen kann.
#
# Dafür kannst du folgenden Code verwenden:
# ```
# fig, ax = plt.subplots(figsize=(35, 20))
# tree.plot_tree(clf, filled=True, ax = ax, fontsize = 15)
# plt.show()
# ```
#
# Welche sind die ersten beiden Werte nach denen der Baum entscheidet?

# %%
# Plot the Tree layout

# %% [markdown]
# ## Aufgabe 8:
# Du bist mit den Ergebnissen schon recht zufrieden.
# Aber du hast ein großes Repertoire an Machine Learning modellen die dir helfen könnten. Du hast sogar noch ein paar Merkkarten aus deinem Studum gefunden.
#
# Vielleicht lässt sich das noch verbessern.
# Du willst noch einen anderen Algorithmus probieren.
#
# Du denkst einer der folgenden sollte gut funktionieren:
#
# [Support Vector Machine](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html#sklearn.svm.SVC)
#
# [K-Nearest-Neighbors](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html#sklearn.neighbors.KNeighborsClassifier)
#
# [Neural Net](https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html#sklearn.neural_network.MLPClassifier)
#
# [Random Forest](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html#sklearn.ensemble.RandomForestClassifier)
#
# Vielleicht traust du es dir ja zu noch die Parameter zu optimieren?
#
#
# ![Families of Machine Learning Algorithms](https://storage.googleapis.com/kagglesdsdata/datasets%2F705343%2F1231895%2Ffamilies.png?GoogleAccessId=databundle-worker-v2@kaggle-161607.iam.gserviceaccount.com&Expires=1591955852&Signature=KdLHhH0F70q%2BpluYbIkLmTAnfWKpvPbMjyvcmDc4xUJx3tuNKptPQn%2BXBAS4PoRyqcDMOgbWcm2kJRqihQlC1zOghiq1JhPhq3HdZavycHTQM5zE1zSEgjFEnQmJeGGI1nMGAlKQFziQoa9VrrLfriGpUTaEeVh8s7nW9PjvZb5B21ali3PBKLiYmQCudsWe0wj4T%2BmEXwOBNAIs5QdxepoHv%2F%2BXmGa25FtxGuzPLjuhqQq6DtAfqAefT6FJImN47OeFhRMzoIOlHjfVDDlQkLHh1FNIk4vYjRTBgccOLjxOT4HROu1E0d%2BkBV9ccdsN6nlCJdfnjaZREWDRGjKiZg%3D%3D)

# %%
# Apply a second algorithm of your choice

# %% [markdown]
# ## Aufgabe 9:
#
# Als letztes willst du noch probieren das Ergebnis zu verbessern.
# Wähle die Features aus, die du als wichtig erachtest, vielleicht schaust du dazu nochmal auf deine Korrelationsmatrix.
# Dann lasse deinen gewählten Algorithmus nochmal laufen. Konntest du das Ergebnis verbessern?

# %%
# Select important features
selected_features = []

# Generate new train and test data
X_train, X_test, y_train, y_test = train_test_split(data[selected_features], data["Outcome"], test_size=.25, random_state=42, stratify=data['Outcome'])

# run your algorithm

# %% [markdown]
# ## Aufgabe 10:
#
# Du hast dein Modell und weißt wie genau es ist.
# Du weißt. dass in Indien das durchschnittliche Einkommen nur ca. 130€ pro Jahr beträgt.
# Eine überprüfung der Leberwerte mit anschließender Diagnose vom Arzt kann aber leicht ein ganzes Monatsgehalt kosten.
#
# Wirst du empfehlen dein Modell in den Zentren der WHO in Indien einzusetzen?
# Jeder Erkrankte der durch den Test erkannt wird, kann gut behandelt werden und lange leben.
# Ein gesunder Mensch verliert durch eine Fehldiagnose aber sein gesamtes Monatsgehalt.
#
# Wie ist deine Entscheidung?
