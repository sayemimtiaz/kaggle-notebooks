# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Reading in the data
# * To the right, under "Data", then under "input", click "novel-corona-virus-2019-dataset"
# * Under this now appears a list of files, click the "covid_19_data.csv" file
# * Below appears the dataset, at the top, highlight and copy the path to the file, the close the file
# * Paste the filepath inside the function below and in **quotations**
# * After defining the dataset, type out the name of the dataset you have just defined in order to output the datset.

# %%
# paste the copied filepath inside the function below to read in the csv file
covid_data = pd.read_csv("_____", 
                         index_col='SNo', parse_dates=True)
# We can change the index column to the first column by setting index_col = "first_column_name"
# parse_dates lets the notebook understand each row that contains a date

covid_data

# %%
covid_data.isnull().sum()

# %%
# Use the .head() function to retreive the first 5 rows of the datset
covid_data.head()

# %% [markdown]
# * We can retrieve a single column of the data by putting the name of the column in quotations inside brackets, or using the dot method, for example: covid_data['Confirmed'], or covid_data.Confirmed
# * We can see how many unique countries/regions where there have been confirmed coronavirus cases using the function **nunique()**, and we can see which countries/regions these are using the **unique()** function.

# %%
covid_data['Confirmed']
# Comment out the above and uncomment below and run the code to see that these acheive the same output
#covid_data.Confirmed

# %%
covid_data['Country/Region'].nunique()

# %%
covid_data['Country/Region'].unique()

# %% [markdown]
# From the above we can tell that the coronavirus has affected 223 countries/regions

# %% [markdown]
# Next, we can figure out the total number of deaths in these 223 countries/regions by summing over the 'Deaths' column. This will give us the number of deaths from 1/22/2020 until present.

# %%
covid_data['Deaths'].sum()

# %% [markdown]
# Similarly we can sum over the 'Confirmed' column to retrieve the total number of cases and 'Recovered' column to retrieve the number of those recovered

# %%
# sum the number of Confirmed cases below

# %%
# sum the number of Recovered cases below

# %% [markdown]
# How many cases are existing right now that have yet to recover? This can be answered with a simple line of code.

# %%
# Using the sum() function, write a basic arithmetic function to calculate the number of active cases

# %% [markdown]
# We can use the max() function to retreive what the highest number of confirmed cases is during a certain time. We can then use this information to retrieve the entire row which wil give us further information.

# %%
covid_data['Confirmed'].max()

# %%
# Using this method, you can retreive the entire row that corresponds to the value 
# that the Confirmed column takes on here
covid_data[covid_data['Confirmed'] == covid_data['Confirmed'].max()]

# %% [markdown]
# Now we can tell that this information is not necessarily accurate since the total number of confirmed cases has been growing exponentially, so the highest number of cases is always going to be the present number. Rather we should get the number of confirmed cases presently by adding a new column where we subtract deaths and recovered from the number of confirmed cases.

# %%
# Easy way to add a new column, displayed below
covid_data['Present_Confirmed'] = ____
covid_data

# %%
# Use code to answer the question: What is the biggest number of active cases right now?
_____
# covid_data['Present_Confirmed'].max()

# %%
# Use a method from above to retreive the row that corresponds to the biggest number of active cases
_____
# covid_data[covid_data['Present_Confirmed'] == covid_data['Present_Confirmed'].max()]

# %% [markdown]
# We can also get a subset of the data by indicating what kind of data we would like. For example, we can attempt to get data for all of Mainland China or all of the US by using the method we used above, shown below:

# %%
# Use similar method to retrieve all the data from Mainland China
_____

# china_data = covid_data[covid_data['Country/Region'] == 'Mainland China']

# %% [markdown]
# In order to do anything with this data alone, we define it, giving it a meaningful name, so that we can more easily reference it.
