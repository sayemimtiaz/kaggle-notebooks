# %% [markdown]
# # Spotify data analysis by year

# %% [markdown]
# ###  The music's characteristics chaged so many, I will analysis the Music's characteristics by year

# %% [markdown]
# ![](https://storage.googleapis.com/pr-newsroom-wp/1/2020/03/Header.png)

# %% [markdown]
#  ## 1. Import and load datasets

# %% [markdown]
# ### Import the library

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
import plotly.io as pio
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots
from plotly.validators.scatter.marker import SymbolValidator

import plotly.offline as pyo
pyo.init_notebook_mode()

# %% [markdown]
# ### Load datasets that Spotify Dataset 1921 - 2020, 160+ Tracks (Audio features of 175k+ songs released in between 1921 and 2021 (UPDATED))
#
# Primary:
# - id (Id of track generated by Spotify)
# Numerical:
# - acousticness (Ranges from 0 to 1)
# - danceability (Ranges from 0 to 1)
# - energy (Ranges from 0 to 1)
# - duration_ms (Integer typically ranging from 200k to 300k)
# - instrumentalness (Ranges from 0 to 1)
# - valence (Ranges from 0 to 1)
# - popularity (Ranges from 0 to 100)
# - tempo (Float typically ranging from 50 to 150)
# - liveness (Ranges from 0 to 1)
# - loudness (Float typically ranging from -60 to 0)
# - speechiness (Ranges from 0 to 1)
# - year (Ranges from 1921 to 2020)
# Dummy:
# - mode (0 = Minor, 1 = Major)
# - explicit (0 = No explicit content, 1 = Explicit content)
# Categorical:
# - key (All keys on octave encoded as values ranging from 0 to 11, starting on C as 0, C# as 1 and so on…)
# - artists (List of artists mentioned)
# - release_date (Date of release mostly in yyyy-mm-dd format, however precision of date may vary)
# - name (Name of the song)

# %%
df = pd.read_csv("../input/spotify-dataset-19212020-160k-tracks/data.csv")
df.drop(["id","release_date"],axis=1,inplace=True)

df_year = pd.read_csv("../input/spotify-dataset-19212020-160k-tracks/data_by_year.csv")
df_w = pd.read_csv("../input/spotify-dataset-19212020-160k-tracks/data_w_genres.csv")
df_genre = pd.read_csv("../input/spotify-dataset-19212020-160k-tracks/data_by_genres.csv")
df_year = df_year[:101]

# %% [markdown]
# ## 2. Analysis the Music's characteristics movements by years

# %% [markdown]
# ### I will use 11 data that acousticness, danceability, energy, instrumentalness, liveness, speechiness, valence, duration_ms, tempo, loudness, and popularity
#
# ### They have other range each others, so It have to control the range and analysis the data
#
# ### I want to control range(0 - 1), and then compare them
#
# ### But, before, changing the range, I will check the characteristics changing first

# %%
fig =go.Figure()
fig.add_trace(go.Scatter(x=df_year['year'], y=df_year['acousticness'], mode='markers + lines',name="acousticness",showlegend=True))
fig.update_layout(title='Acousticness',height=300)
fig.show()

# %% [markdown]
# ### Acousticness had big Fluctuation width before 1950, After decrease steadily

# %%
fig =go.Figure()
fig.add_trace(go.Scatter(x=df_year['year'], y=df_year['danceability'], mode='markers + lines',name="danceability",showlegend=True))
fig.add_trace(go.Scatter(x=df_year['year'], y=df_year['energy'], mode='markers + lines',name="energy"))
fig.update_layout(title='Danceability and Energy',height=300)
fig.show()

# %% [markdown]
# ### Danceability is also have big Fluctuation width, but increase after 1953
# ### Energy is increase after 1946

# %%
fig =go.Figure()
fig.add_trace(go.Scatter(x=df_year['year'], y=df_year['tempo'],mode='markers + lines',name="tempo",showlegend=True))
fig.update_layout(title="Tempo",height=300)
fig.show()

# %% [markdown]
# ### Tempo is similar with energy graph, it is increase after 1946

# %%
fig =go.Figure()
fig.add_trace(go.Scatter(x=df_year['year'], y=df_year['instrumentalness'], mode='markers + lines',name="instrumentalness",showlegend=True))
fig.update_layout(title='Instrumentalness',height=300)
fig.show()

# %% [markdown]
# ### Instrumentalness is also have big Fluctuation width. after 1960, it has very low values, and after 2007 increase little

# %%
fig =go.Figure()
fig.add_trace(go.Scatter(x=df_year['year'], y=df_year['liveness'], mode='markers + lines',name="liveness",showlegend=True))
fig.update_layout(title="Liveness",height=300)
fig.show()

# %% [markdown]
# ### Liveness is also have big Fluctuation width

# %%
fig =go.Figure()
fig.add_trace(go.Scatter(x=df_year['year'], y=df_year['speechiness'], mode='markers + lines',name="speechiness",showlegend=True))
fig.update_layout(title="Speechiness",height=300)
fig.show()

# %%
fig =go.Figure()
fig.add_trace(go.Scatter(x=df_year['year'], y=df_year['loudness'], mode='markers + lines',name="loudness",showlegend=True))
fig.update_layout(title='Loudness',height=300)
fig.show()

# %% [markdown]
# ### Naturally, speechiness and loudness have opposite graph, after 1960, speechiness has low values, loudness has high values

# %%
fig =go.Figure()
fig.add_trace(go.Scatter(x=df_year['year'], y=df_year['valence'], mode='markers + lines',name="valence",showlegend=True))
fig.update_layout(title="Valence",height=300)
fig.show()

# %% [markdown]
# ### Valence have big fluctuation width, after 1953, increase and then, after 1979 decrease

# %%
fig =go.Figure()
fig.add_trace(go.Scatter(x=df_year['year'], y=df_year['duration_ms'],mode='markers + lines',name="duration_ms",showlegend=True))
fig.update_layout(title='Duration_ms',height=300)
fig.show()

# %% [markdown]
# ### Duration have also big fluctuation width until 1967, after it has similar values

# %%
fig =go.Figure()
fig.add_trace(go.Scatter(x=df_year['year'], y=df_year['popularity'], mode='markers + lines',name="popularity",showlegend=True))
fig.update_layout(title='Popularity',height=300)
fig.show()

# %% [markdown]
# ### Popularity have increase graph. But after 2000, it decrease

# %% [markdown]
# ## 3. Change the range and compare wtih (Scailing)

# %% [markdown]
# ### As you know, they have other range each others, so, I will control them
# ### 1. If the data have minus value [ loudness case ] -> value / min()
# ### 2. else ->  value / max()

# %%
df_year_control = df_year.copy()
df_year_control['acousticness'] = df_year_control['acousticness'] / df_year_control['acousticness'].max()
df_year_control['danceability'] = df_year_control['danceability'] / df_year_control['danceability'].max()
df_year_control['duration_ms'] = df_year_control['duration_ms'] / df_year_control['duration_ms'].max()
df_year_control['energy'] = df_year_control['energy'] / df_year_control['energy'].max()
df_year_control['instrumentalness'] = df_year_control['instrumentalness'] / df_year_control['instrumentalness'].max()
df_year_control['liveness'] = df_year_control['liveness'] / df_year_control['liveness'].max()
df_year_control['speechiness'] = df_year_control['speechiness'] / df_year_control['speechiness'].max()
df_year_control['tempo'] = df_year_control['tempo'] / df_year_control['tempo'].max()
df_year_control['valence'] = df_year_control['valence'] / df_year_control['valence'].max()
df_year_control['popularity'] = df_year_control['popularity'] / df_year_control['popularity'].max()
df_year_control['loudness'] = df_year_control['loudness'] / df_year_control['loudness'].min()
df_year_control['year'] = df_year_control['year'].astype(str)
df_year_control.describe()

# %% [markdown]
# ### Now we have the range, (0 ~ 1) It mean, the data's max value is 1 , but, data's min value is not 0
# ### We will compare the characteristics of music every 10 years.

# %%
df_year_control.drop(["key","mode"],axis=1,inplace=True)
df_year_control = df_year_control.melt("year")

# %%
fig = px.line_polar(df_year_control, r="value",theta="variable",line_close=True,
             animation_frame="year",template="plotly_dark",range_r = (0,1))
fig.update_traces(fill='toself')
fig.update_layout(font_size=15)
fig.show()
