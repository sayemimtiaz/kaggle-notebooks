# %% [markdown]
# # <span style='color:Red'><span style='font-family:Georgia'> <span style='text-align:center'>Analysis of Indian Food</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Importing Required libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Reading the dataset

# %%
df=pd.read_csv(r"../input/indian-food-101/indian_food.csv")
df.index
df.head()

# %% [markdown]
# ## Understanding the data

# %%
df.shape

# %%
df.dropna()

# %%
df.isnull().sum()

# %%
df.dtypes

# %%
df.isna().sum()

# %%
df.describe

# %% [markdown]
# ## 1.Interpreting the taste palette

# %%
df['flavor_profile']=df['flavor_profile'].replace(['-1'],'tasteless')
plt.figure(figsize=(15,5))
plt.title("Taste palette")
sns.countplot(df['flavor_profile'])
plt.show()

# %% [markdown]
# ## 2. Vegetarians Or Non-Vegeterians??

# %%
plt.figure(figsize=(15,5))
plt.title("Veg/Non-veg")
sns.countplot(df['diet'],color='maroon')
plt.show()

# %% [markdown]
# ## 3. Preparation time Vs Courses

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=df['course'], hue=df['cook_time'], dodge=True)

# %% [markdown]
# ## 4. Regional Flavors and their cooking time.

# %%
sns.catplot(x ='region', y ='cook_time', data = df, hue='diet', col='flavor_profile', kind="bar",
                height=10, aspect=0.6)

# %% [markdown]
# ## Inferences-
# ### <span style='color:Green'> 1. Indians love spicy food.</span>
# ### <span style='color:Green'> 2. Most of the people, prefer Vegetarian food.</span>
# ### <span style='color:Green'> 3. Main course dishes, take the maximum time in cooking.</span>
# ### <span style='color:Green'> 4. Non-Vegetarian dishes are generally spicy.</span>
# ### <span style='color:Green'> 5. People from east, south and central India don't prefer bitter or sour taste .</span>
