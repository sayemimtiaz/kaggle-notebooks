# %%
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df = pd.read_csv('/kaggle/input/ecommerce-purchase-history-from-electronics-store/kz.csv', delimiter=',')
df.dataframeName = 'Purchases'
nRow, nCol = df.shape
print(f'There are {nRow} rows and {nCol} columns')

# %% [markdown]
# Let's take a quick look at what the data looks like:

# %%
df.head(5)

# %% [markdown]
# Distribution graphs of purchases by categories:

# %%
# Select only purchases with defined category label
by_categories = df
by_categories = by_categories.dropna(subset=['category_code'])
by_categories

# TODO: draw chart

# %% [markdown]
# Most popular categories by month:

# %%
# TODO

# %% [markdown]
# Distribution of SKUs per order by month

# %%
# TODO

# %% [markdown]
# Distribution of average order value per category per month

# %%
# TODO
