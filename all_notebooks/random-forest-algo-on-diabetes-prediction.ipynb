# %%
# Following notebook includes Random Forest algorithm on the dataset just to calculate the accuracy based on training and testing the values.
# here additional mean square root is calculated at last to verify what will be the mean value.
# starting with the columns from pregnancies to age:

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import numpy as np

df=pd.read_csv("../input/diabetes-prediction/Diabetespred.csv")
print(df)

X=df.loc[:,'Pregnancies':'Age']
Y=df['Outcome']

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.30,random_state=0)

model=RandomForestRegressor(n_estimators=500, oob_score=True, random_state=100)
model.fit(X_train,Y_train)
print(model.score(X_test,Y_test))
predicted=model.predict(X_test)
print(Y_test)
print(predicted)
print(np.sqrt(mean_squared_error(Y_test,predicted)))

# %%
# continued for columns from pregnancies to BMI:

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import numpy as np

df=pd.read_csv("../input/diabetes-prediction/Diabetespred.csv")
print(df)

X=df.loc[:,'Pregnancies':'BMI']
Y=df['Outcome']

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.30,random_state=0)

model=RandomForestRegressor(n_estimators=500, oob_score=True, random_state=100)
model.fit(X_train,Y_train)
print(model.score(X_test,Y_test))
predicted=model.predict(X_test)
print(Y_test)
print(predicted)
print(np.sqrt(mean_squared_error(Y_test,predicted)))

# %%
# then we tried reducing the columns to check accuracy from pregnancies to insulin: 

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import numpy as np

df=pd.read_csv("../input/diabetes-prediction/Diabetespred.csv")
print(df)

X=df.loc[:,'Pregnancies':'Insulin']
Y=df['Outcome']

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.30,random_state=0)

model=RandomForestRegressor(n_estimators=500, oob_score=True, random_state=100)
model.fit(X_train,Y_train)
print(model.score(X_test,Y_test))
predicted=model.predict(X_test)
print(Y_test)
print(predicted)
print(np.sqrt(mean_squared_error(Y_test,predicted)))

# %%
# at last only four columns to verify whether accuracy is max or min from pregnancies to skin thickness:

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import numpy as np

df=pd.read_csv("../input/diabetes-prediction/Diabetespred.csv")
print(df)

X=df.loc[:,'Pregnancies':'SkinThickness']
Y=df['Outcome']

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.30,random_state=0)

model=RandomForestRegressor(n_estimators=500, oob_score=True, random_state=100)
model.fit(X_train,Y_train)
print(model.score(X_test,Y_test))
predicted=model.predict(X_test)
print(Y_test)
print(predicted)
print(np.sqrt(mean_squared_error(Y_test,predicted)))
