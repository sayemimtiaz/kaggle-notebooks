# %%
# !pip install japanize-matplotlib

# %%
# %matplotlib inline
from IPython.display import SVG, Image
from keras.utils.vis_utils import model_to_dot

import random

import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn import preprocessing
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use('seaborn')
# %config InlineBackend.figure_format = 'retina'

# %%
import japanize_matplotlib
plt.rcParams['font.family']

# %%
img_cnt = 0

# %%
def save_img():
    global img_cnt
    img_cnt += 1
    img_name = 'img_{0:03}.png'.format(img_cnt)
    print(img_name)
    plt.savefig(img_name)

# %%
def hexbin(x, y, color, **kwargs):
    cmap = sns.light_palette(color, as_cmap=True)
    plt.hexbin(x, y, cmap=cmap, **kwargs)
def scatter(x, y, color, **kwargs):
    plt.scatter(x, y, marker='.')

# %%
X_df = pd.read_csv('../input/sample-data-wordanddoc2vec/actual_survey_data_jp.csv', index_col=0)
X_df.head()

# %%
df_out_wgt_user = pd.read_csv('../input/lowcol-actual-survey-data-fet12-randinit01/out_user.csv', index_col=0)
X_df_user = df_out_wgt_user
wgt_user = df_out_wgt_user.values
df_out_wgt_user.head()

# %%
df_out_wgt_col = pd.read_csv('../input/lowcol-actual-survey-data-fet12-randinit01/out_col.csv', index_col=0)
X_df_col = df_out_wgt_col
wgt_prod = df_out_wgt_col.values
df_out_wgt_col.head()

# %%
sommap_out_user = pd.read_csv('../input/lowcol-actual-survey-data-fet12-randinit01-sommap/sommap_out_user.csv', index_col=0)
sommap_out_col = pd.read_csv('../input/lowcol-actual-survey-data-fet12-randinit01-sommap/sommap_out_col.csv', index_col=0)
sommap_out_user.head()

# %%
som_out_user = pd.read_csv('../input/lowcol-actual-survey-data-fet12-randinit01-somcls/som_out_user.csv', index_col=0)
som_out_col = pd.read_csv('../input/lowcol-actual-survey-data-fet12-randinit01-somcls/som_out_col.csv', index_col=0)
som_out_user.head()

# %%
k_dim1 = 40

# %%
som_xy = []
for ii, c in enumerate(sommap_out_user['sommap_cls'].values):
    b, a = divmod(c, k_dim1)
    som_xy.append((b, a))
som_xy = np.array(som_xy)

# %%
target_cls = 0
idx = som_out_user['cls'].values == target_cls

plt.figure(figsize=(13,9))
ax = sns.kdeplot(som_xy[:,1], som_xy[:,0],
                 cmap="Blues", shade=True, thresh=0.05)


for ii, c in enumerate(sommap_out_col['sommap_cls'].values):
    colname = X_df_col.index.values[ii]
    text = colname
    b, a = divmod(c, k_dim1)
    xy = (a, b)
    ax.scatter(a, b, c='darkgreen', s=200, marker='x')
    ax.annotate(text, xy=xy, size=15)
for ii, c in enumerate(sommap_out_user['sommap_cls'].values[idx]):
    b, a = divmod(c, k_dim1)
    xy = (a, b)
    ax.scatter(a, b, c='yellow', s=50, marker='s')
save_img()

# %%
target_cls = 1
idx = som_out_user['cls'].values == target_cls

plt.figure(figsize=(13,9))
ax = sns.kdeplot(som_xy[:,1], som_xy[:,0],
                 cmap="Blues", shade=True, thresh=0.05)


for ii, c in enumerate(sommap_out_col['sommap_cls'].values):
    colname = X_df_col.index.values[ii]
    text = colname
    b, a = divmod(c, k_dim1)
    xy = (a, b)
    ax.scatter(a, b, c='darkgreen', s=200, marker='x')
    ax.annotate(text, xy=xy, size=15)
for ii, c in enumerate(sommap_out_user['sommap_cls'].values[idx]):
    b, a = divmod(c, k_dim1)
    xy = (a, b)
    ax.scatter(a, b, c='yellow', s=50, marker='s')
save_img()

# %%
target_cls = 2
idx = som_out_user['cls'].values == target_cls

plt.figure(figsize=(13,9))
ax = sns.kdeplot(som_xy[:,1], som_xy[:,0],
                 cmap="Blues", shade=True, thresh=0.05)


for ii, c in enumerate(sommap_out_col['sommap_cls'].values):
    colname = X_df_col.index.values[ii]
    text = colname
    b, a = divmod(c, k_dim1)
    xy = (a, b)
    ax.scatter(a, b, c='darkgreen', s=200, marker='x')
    ax.annotate(text, xy=xy, size=15)
for ii, c in enumerate(sommap_out_user['sommap_cls'].values[idx]):
    b, a = divmod(c, k_dim1)
    xy = (a, b)
    ax.scatter(a, b, c='yellow', s=50, marker='s')
save_img()

# %%
target_cls = 3
idx = som_out_user['cls'].values == target_cls

plt.figure(figsize=(13,9))
ax = sns.kdeplot(som_xy[:,1], som_xy[:,0],
                 cmap="Blues", shade=True, thresh=0.05)


for ii, c in enumerate(sommap_out_col['sommap_cls'].values):
    colname = X_df_col.index.values[ii]
    text = colname
    b, a = divmod(c, k_dim1)
    xy = (a, b)
    ax.scatter(a, b, c='darkgreen', s=200, marker='x')
    ax.annotate(text, xy=xy, size=15)
for ii, c in enumerate(sommap_out_user['sommap_cls'].values[idx]):
    b, a = divmod(c, k_dim1)
    xy = (a, b)
    ax.scatter(a, b, c='yellow', s=50, marker='s')
save_img()

# %%
target_cls = 7
idx = som_out_user['cls'].values == target_cls

plt.figure(figsize=(13,9))
ax = sns.kdeplot(som_xy[:,1], som_xy[:,0],
                 cmap="Blues", shade=True, thresh=0.05)


for ii, c in enumerate(sommap_out_col['sommap_cls'].values):
    colname = X_df_col.index.values[ii]
    text = colname
    b, a = divmod(c, k_dim1)
    xy = (a, b)
    ax.scatter(a, b, c='darkgreen', s=200, marker='x')
    ax.annotate(text, xy=xy, size=15)
for ii, c in enumerate(sommap_out_user['sommap_cls'].values[idx]):
    b, a = divmod(c, k_dim1)
    xy = (a, b)
    ax.scatter(a, b, c='yellow', s=50, marker='s')
save_img()

# %%
df_som_xy = pd.DataFrame(som_xy, columns=['0', '1'])
df_som_xy['cls'] = som_out_user['cls'].values

# %%
plt.figure(figsize=(13,9))
ax = sns.kdeplot(data=df_som_xy, x='1', y='0',
                 shade=True, thresh=0.05, hue='cls',
                 palette=sns.color_palette("pastel", n_colors=12),
                 alpha=.5)
for ii, c in enumerate(sommap_out_col['sommap_cls'].values):
    colname = X_df_col.index.values[ii]
    text = colname
    b, a = divmod(c, k_dim1)
    xy = (a, b)
    ax.scatter(a, b, c='darkgreen', s=200, marker='x')
    ax.annotate(text, xy=xy, size=12)
save_img()

# %%
g = sns.lmplot(data=df_som_xy, x='1', y='0', hue='cls',
               palette=sns.color_palette("pastel", n_colors=12), markers='s', fit_reg=False,
               scatter_kws={'s': 400, 'alpha': 1})
ax = g.ax
ax.figure.set_figheight(10.4)
ax.figure.set_figwidth(15.9)
for ii, c in enumerate(sommap_out_col['sommap_cls'].values):
    colname = X_df_col.index.values[ii]
    text = colname
    b, a = divmod(c, k_dim1)
    xy = (a, b)
    ax.scatter(a, b, c='darkgreen', s=150, marker='x')
    ax.annotate(text, xy=xy, size=15)
save_img()
