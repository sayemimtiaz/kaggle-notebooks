# %% [markdown]
# # IBM_HR_Analytics_Employee_Attrition_Performance
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ### The dataset is about employee attrition. This analysis can discover if any particular factors or patterns that lead to attrition. If so, employers can take certain precausion to prevent attrition which in employer of view, employee attrition is a loss to company, in both monetary and non-monetary.

# %% [markdown]
# ### **Importing the packages**

# %%
##Importing the packages
#Data processing packages
import numpy as np 
import pandas as pd 

#Visualization packages
import matplotlib.pyplot as plt 
import seaborn as sns 

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### **Importing the data**

# %%
#Add the dataset IBM HR Analytics Employee Attrition & Performance - Predict attrition of your valuable employees
#data=pd.read_csv('../input/employee-atrition/employee_attrition_data.csv')

# %% [markdown]
# ### **Basic Analysis**

# %%
#Find the size of the data Rows x Columns
#data.________

# %% [markdown]
# **COMMENTS:** ???

# %%
#Display first 5 rows of Employee Attrition data
#data.________()

# %%
#Find Basic Statistics like count, mean, standard deviation, min, max etc.
#data.___________(include='all')

# %% [markdown]
# **COMMENTS:**
# 1.
# 2.
# 3.
# 4.

# %%
#Find the the information about the fields, field datatypes and Null values
data.________

# %% [markdown]
# **COMMENTS:**

# %% [markdown]
# **Category Columns**

# %%
#cat_cols contains names of category columns
cat_cols = data.columns[data.dtypes=='object']

#data_cat contains category column data
#data_cat = data[_________]

# %%
#Print category column names (cat_cols)
#print(________)

# %%
#Display first 5 rows of category column data
data_cat._______

# %% [markdown]
# **Numerical Columns**

# %%
#num_cols contains names of numerical columns
num_cols = data.columns[data.dtypes!='object']

#data_num contains numerical column data
#data_num = data[_________]

# %%
#Print numerical column names (num_cols)
#print(________)

# %%
#Display first 5 rows of numerical column data
#data_num._______

# %%
#Plot the Pairplot for numerical columns from 'Age' to 'DistanceFromHome'
#g = sns.pairplot(data_num.loc[:,'___':'______________']); g.fig.set_size_inches(15,15)

# %%
#Plot the Pairplot for numerical columns from 'Education' to 'HourlyRate'
#g = sns.pairplot(data_num.loc[:,'___':'______________']); g.fig.set_size_inches(15,15)

# %%
#Plot the Pairplot for numerical columns from 'JobInvolvement' to 'MontlyRate'
#g = sns.pairplot(data_num.loc[:,'___':'______________']); g.fig.set_size_inches(15,15)

# %%
#Plot the Pairplot for numerical columns from 'NumCompaniesWorked' to 'StandardHours'
#g = sns.pairplot(data_num.loc[:,'___':'______________']); g.fig.set_size_inches(15,15)

# %%
#Plot the Pairplot for numerical columns from 'StockOptionLevel' to 'YearsAtCompany'
#g = sns.pairplot(data_num.loc[:,'___':'______________']); g.fig.set_size_inches(15,15)

# %%
#Plot the Pairplot for numerical columns from 'YearsInCurrentRole' to 'YearsWithCurrManager'
#g = sns.pairplot(data_num.loc[:,'___':'______________']); g.fig.set_size_inches(15,15)

# %%
#Plot the Pairplot for all the numerical columns
#g = sns.pairplot(_______); g.fig.set_size_inches(15,15)

# %%
#Plot the Histogram for all the numerical columns
________.hist(layout = (9, 3), figsize=(24, 48), color='blue', grid=False, bins=15)

# %% [markdown]
# ### **Visualizing the impact of Categorical Features on the Target**

# %%
#Find attrition size (Values)
#data['________'].value_counts()

# %% [markdown]
# **COMMENTS:**  237 employees left the company out of total 1470 employees

# %%
#Compare BusinessTravel with Attrition using crosstab
#pd.crosstab(data.__________, data._________, margins=True, normalize='index').round(2).style.background_gradient(cmap='autumn_r')

# %% [markdown]
# **COMMENTS:**  Frequent travelers  are more likely(25%) to leave the company as compared to Non Travellers

# %%
#Compare Department with Attrition using crosstab
#pd.crosstab(data.__________, data._________, margins=True, normalize='index').round(2).style.background_gradient(cmap='autumn_r')

# %% [markdown]
# **COMMENTS:**  The employees in "Sales" department are more likely(21%) to leave the company as compared to the employees of other department

# %%
#Compare Department with Attrition using crosstab
#pd.crosstab(data.__________, data._________, margins=True, normalize='index').round(2).style.background_gradient(cmap='autumn_r')

# %% [markdown]
# **COMMENTS:**  The employees who are least educated are more likely(18%) to leave the company and the employees who are highly qualified are less likely (10%) to leave the company.

# %%
#Compare Department with Attrition using crosstab
#pd.crosstab(data.__________, data._________, margins=True, normalize='index').round(2).style.background_gradient(cmap='autumn_r')

# %% [markdown]
# **COMMENTS:**  The employees in "Human Resource" education field are more likely(26%) to leave the company.  Next in the line are from the "Technical" field.

# %%
#Compare Department with Attrition using crosstab
#pd.crosstab(data.__________, data._________, margins=True, normalize='index').round(2).style.background_gradient(cmap='autumn_r')

# %% [markdown]
# **COMMENTS:**  Lower the "Environment Satisfaction" higher the attrition rate(25%)

# %%
#Compare Gender with Attrition using crosstab
#pd.crosstab(data.__________, data._________, margins=True, normalize='index').round(2).style.background_gradient(cmap='autumn_r')

# %% [markdown]
# **COMMENTS:**  Male employees have slightly higher attrition rate (17%) as compared to female employees.

# %%
#Compare JobInvolvement with Attrition using crosstab
#pd.crosstab(data.__________, data._________, margins=True, normalize='index').round(2).style.background_gradient(cmap='autumn_r')

# %% [markdown]
# **COMMENTS:**  Lower the "JobInvolvement", higher the Attrition rate (34%)

# %%
#Compare JobLevel with Attrition using crosstab
#pd.crosstab(data.__________, data._________, margins=True, normalize='index').round(2).style.background_gradient(cmap='autumn_r')')

# %% [markdown]
# **COMMENTS:**  Lower the "JobLevel", higher the Attrition rate (26%)

# %%
#Compare JobRole with Attrition using crosstab
#pd.crosstab(data.__________, data._________, margins=True, normalize='index').round(2).style.background_gradient(cmap='autumn_r')

# %% [markdown]
# **COMMENTS:**  Employees with with "Sales Representative" JobRole have the higher attrition rate (40%) as compared to others.

# %%
#Compare JobSatisfaction with Attrition using crosstab
#pd.crosstab(data.__________, data._________, margins=True, normalize='index').round(2).style.background_gradient(cmap='autumn_r')

# %% [markdown]
# **COMMENTS:**  Lower the "Job Satisfaction" higher the attrition rate(23%)

# %%
#Compare MaritalStatus with Attrition using crosstab
#pd.crosstab(data.__________, data._________, margins=True, normalize='index').round(2).style.background_gradient(cmap='autumn_r')

# %% [markdown]
# **COMMENTS:**  Employees who are Single have significantly higher attrition rate(26%)

# %%
#Compare OverTime with Attrition using crosstab
#pd.crosstab(data.__________, data._________, margins=True, normalize='index').round(2).style.background_gradient(cmap='autumn_r')

# %% [markdown]
# **COMMENTS:**  Employees who do "OverTime" have significantly higher attrition rate(31%)

# %%
#Compare PerformanceRating with Attrition using crosstab
#pd.crosstab(data.__________, data._________, margins=True, normalize='index').round(2).style.background_gradient(cmap='autumn_r')

# %% [markdown]
# **COMMENTS:**  Performance Rating has no effect on the Attrition rate.

# %%
#Compare RelationshipSatisfaction with Attrition using crosstab
#pd.crosstab(data.__________, data._________, margins=True, normalize='index').round(2).style.background_gradient(cmap='autumn_r')

# %% [markdown]
# **COMMENTS:**  Employees with less Relationship Satisfaction are more likely to leave the company (21%)

# %%
#Compare StockOptionLevel with Attrition using crosstab
#pd.crosstab(data.__________, data._________, margins=True, normalize='index').round(2).style.background_gradient(cmap='autumn_r')

# %% [markdown]
# **COMMENTS:**  Employees who are NOT given "Stock Option" are more likely(24%) to leave the company

# %%
#Compare WorkLifeBalance with Attrition using crosstab
#pd.crosstab(data.__________, data._________, margins=True, normalize='index').round(2).style.background_gradient(cmap='autumn_r')

# %% [markdown]
# **COMMENTS:**  Employees with less "Work Life Balance" are more likely (31%) to leave the company.

# %%
#A lambda function can take any number of arguments, but can only have one expression.
#Change the Attrition from Yes/No to binary 1/0
#data['_________']=data['__________'].apply(lambda x : 1 if x=='Yes' else 0)

# %% [markdown]
# ### **Visualizing the impact of Numerical Features on the Target**

# %%
#Comparing the numeric fields agains Attrition using boxplots
#plt.figure(figsize=(24,12))
#plt.subplot(231)  ; sns.boxplot(x='---------',y='----',data=data) # Attrition vs Age
#plt.subplot(232)  ; sns.boxplot(x='---------',y='----',data=data) # Attrition vs DailyRate
#plt.subplot(233)  ; sns.boxplot(x='---------',y='----',data=data) # Attrition vs DistanceFromHome
#plt.subplot(234)  ; sns.boxplot(x='---------',y='----',data=data) # Attrition vs HourlyRate
#plt.subplot(235)  ; sns.boxplot(x='---------',y='----',data=data) # Attrition vs MonthlyIncome
#plt.subplot(236)  ; sns.boxplot(x='---------',y='----',data=data) # Attrition vs PercentSalaryHike

# %%
#Comparing the numeric fields agains Attrition using boxplots
#plt.figure(figsize=(24,12))
#plt.subplot(231)  ; sns.boxplot(x='---------',y='----',data=data) # Attrition vs MonthlyRate
#plt.subplot(232)  ; sns.boxplot(x='---------',y='----',data=data) # Attrition vs NumCompaniesWorked
#plt.subplot(233)  ; sns.boxplot(x='---------',y='----',data=data) # Attrition vs TotalWorkingYears
#plt.subplot(234)  ; sns.boxplot(x='---------',y='----',data=data) # Attrition vs TrainingTimesLastYear
#plt.subplot(235)  ; sns.boxplot(x='---------',y='----',data=data) # Attrition vs YearsAtCompany
#plt.subplot(236)  ; sns.boxplot(x='---------',y='----',data=data) # Attrition vs YearsInCurrentRole

# %%
#Comparing the numeric fields agains Attrition using boxplots
#plt.figure(figsize=(24,6))
#plt.subplot(121)  ; sns.boxplot(x='---------',y='----',data=data) # Attrition vs YearsSinceLastPromotion
#plt.subplot(122)  ; sns.boxplot(x='---------',y='----',data=data) # Attrition vs YearsWithCurrManager

# %%
#Correlation plot to find interelationship of the features (data)
#plt.figure(figsize=(20, 20))
#sns.heatmap(______.corr(), annot=True)

# %%
#sns.pairplot(data['BusinessTravel','Gender','Attrition'], hue='Attrition')
#sns.pairplot(data, vars=["Gender", "Attrition"])
