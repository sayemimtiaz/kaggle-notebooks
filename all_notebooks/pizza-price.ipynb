# %%
import pandas as pd
import numpy as np
import seaborn as sb
import missingno as msno
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn import tree
from sklearn.metrics import accuracy_score,classification_report

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../input/predict-pizza-price/Pizza-Price.csv')
df

# %%
df.isnull().sum()

# %%
df.describe().T.style.bar(subset=['mean'], color='gray').background_gradient(subset=['std'], cmap='YlOrBr').background_gradient(subset=['50%'], cmap='RdBu_r')

# %%
msno.matrix(df, figsize=(12,8))

# %%
plt.figure(figsize=(12,8))
sb.heatmap(df.corr(), annot = True, cmap='PuBu_r', linewidths=1.5)

# %% [markdown]
# **Data Preprocessing**

# %%
x = df.iloc[:,:-1]
x

# %%
y = df.iloc[:,5]
y

# %% [markdown]
# **Label Encoding**

# %%
label = LabelEncoder()

# %%
x = x.apply(LabelEncoder().fit_transform)
x

# %% [markdown]
# **Decision Tree**

# %%
classify = tree.DecisionTreeClassifier()

# %%
classify = classify.fit(x,y)
predict = classify.predict([[5,0,1,2,1]])
predict
