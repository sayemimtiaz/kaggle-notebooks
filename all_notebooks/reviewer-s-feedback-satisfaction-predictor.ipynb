# %% [markdown]
# <a name="top"></a>
# <h1>Reviewer's Feedback Satisfaction Predictor<br>
# ตัวพยากรณ์ความพึงพอใจจากคำวิจารณ์ของลูกค้า</h1><br><b>Thanapat Pitchayarat (ธนภัทร พิชญรัตน์)</b>

# %% [markdown]
# <a name="abstract"></a>
# <h2>Abstract</h2>
# <p>Nowadays, customer and reviewer feedback affect further purchase transactions of those reviewers and new customers. Preventing negative feedback is one of the primary processes to keeping customers with entrepreneurs, but a problem of improving business with feedback is to understand the true meaning of those reviews, with human sentiment is quite sensitive and need a lot of time for an entrepreneur to make consider. Developer wants to create this Reviewer's Feedback Satisfaction Predictor to classify feedback into two classes: positive feedback and negative feedback for reducing the time resource spent on determining how satisfaction is on each feedback. An entrepreneur will benefit from direct access to a keyword of each review to discover what they must do. This predictor has eighty-seven percentage accuracy from testing with this validation set.</p>
# <p>ปฏิเสธไม่ได้เลยว่าคำวิจารณ์และความคิดเห็นหลังการขายนั้นค่อนข้างมีผลต่อการตัดสินใจของการสั่งซื้อครั้งต่อไปของผู้วิจารณ์และลูกค้ารายใหม่ ปัญหาของการนำคำวิจารณ์ไปแก้ไขก็คือความหลากหลายของความหมายของข้อความและการประเมินอารมณ์ที่อาจจะมีผลต่อความหมายของคำวิจารณ์ รวมถึงปริมานของคำวิจารณ์จากนักวิจารณ์แต่ละคนที่มีจำนวนมากและมากขึ้นอีกตามความเติบโตของกลุ่มลูกค้าของผู้ขาย ผู้พัฒนาจึงเล็งเห็นว่าการสร้างตัวพยากรณ์ความพึงพอใจของผู้วิจารณ์โดยการพิจารณาจากคำวิจารณ์ที่ลูกค้าแสดงความคิดเห็น แบ่งกลุ่มออกเป็นสองกลุ่มคำวิจารณ์ได้แก่ คำวิจารณ์เชิงบวก และ คำวิจารณ์เชิงลบ เพื่อเป็นการลดทอนเวลาที่ผู้ประกอบการจะต้องสูญเสียไปกับการจัดประเภทว่าเป็นความคิดเห็นเชิงพึงพอใจหรือไม่ และช่วยให้สามารถทำการเข้าถึงคำสำคัญของคำวิจารณ์นั้น ๆ อย่างตรงไปตรงมาไม่อ้อมค้อม เพื่อใช้ในการปรับปรุงกับการขายของผู้ประกอบการได้ทันที โดยตัวพยากรณ์นี้ได้ให้ผลลัพธ์สูงถึงร้อยละแปดสิบเจ็ดจากชุดข้อมูลทดสอบนี้</p>
#
# <p>Keywords: Netural Language Processing, Sentiment Analysis, spaCy</p>
#
# <p>คำสำคัญ: การประมวลผลภาษาธรรมชาติ, การวิเคราะห์ความรู้สึก, spaCy</p>

# %% [markdown]
# //This notebook is writen with deep explaination and wiki like embeded and still is not considered as academic article or publication.

# %% [markdown]
# <a name="task"></a>
# <h1>Task</h1>
#
# <p>Amazon Musical Instruments Reviews Dataset<br>
# This dataset contain feedback of reviewer who bought musical intruments from Amazon online more than 1,000 records.</p>
#
# <p>You have to perform Sentimental Analysis for this data. Help the organization to understand better about their customer feedback's So that they can concentrate on those issues customer's are facing. Build the model which has highest accuracy in classifying the feedback as positive,Negative and neutral.</p>
#
# > <p>I have personal opinion that neutral feedback is more fit on negative way than classified it as neutral class for this business insight, because the neutral feedbacks were already explained that we failed to apply the best of their need when compare with their feeling, and we also have no clue from this feedback to improve. Continue studying neutral feedback may bring alot of unnecessary cost. </p>
# > <p>ผู้พัฒนาได้เล็งเห็นว่า คำวิจารณ์สินค้าประเภทเครื่องดนตรี ไม่มีความจำเป็นต้องจัดประเภทให้อยู่ในกลุ่ม "เป็นกลาง" เนื่องจากไม่สามารถนำข้อมูลดังกล่าวไปปรับใช้ให้เกิดประโยชน์เพิ่มเติมได้มากนัก และเล็งเห็นว่าคำวิจารณ์ที่เป็นกลางสำหรับงานนี้นั้นมีความหมายใกล้เคียงกับ คำวิจารณ์เชิงลบ จึงได้ทำการจัดให้คำวิจารณ์ที่เป็นกลางนั้นเข้าไปเป็นส่วนของคำวิจารณ์เชิงลบ </p>
#
# Task :1<br>
# You have to categorize opinions expressed in feedback forums<br><br>
# Todo:<br>
# 1) Categorize review satisfaction. <br>#จัดประเภทคำวิจารณ์ทั้งหมดออกเป็นสองกลุ่ม ได้แก่ วิจารณ์อย่างพึงพอใจ และ วิจารณ์อย่างไม่พึงพอใจ<br><br>
# 2) Create NLP model that predict another musical instrument feedback satisfaction. <br>#สร้างโมเดล NLP เพื่อใช้พยากรณ์ความพึงพอใจจากคำวิจารณ์เครื่องดนตรีอื่นๆ

# %% [markdown]
# <a name="setup"></a>
# <h2>Setup</h2>
# <p>This section contain pre-made and pre-requirement background funtion working, please comeback to learn how each backend function doing later after you explored how this predictor process flowing was.</p>
# <p>ในส่วนนี้ประกอบไปด้วยชุดคำสั่งและเครื่องมือที่ใช้สร้างสภาพแวดล้อมให้กับตัวพยากรณ์อย่างละเอียด, แนะนำให้ข้ามไปทำความรู้จักกับกระบวนการไหลของโปรแกรมก่อนแล้วจึงค่อยกลับมาดูการทำงานของฟังก์ชั่นแต่ละส่วน</p>
#
# > [Click Here](#implement) to jump down into implementation.<br><br>
# > [กดตรงนี้](#implement) เพื่อข้ามไปยังส่วนขั้นตอนการทำงานของตัวพยากรณ์<br>

# %%
import numpy as np
import pandas as pd
import spacy
from spacy.util import minibatch
import random

# %% [markdown]
# <p>This section also consider as predictor wiki too, you can learn more on each funtion parameter and its working process.<br>
# There are two function purpose explained in this wiki, there are <a href=#main_function>Main Function</a> and <a href=#debuging_tool>Debuging Tool</a></p>
# <p>และในส่วนนี้ยังถือว่าเป็นส่วนของคู่มือโปรแกรมอีกด้วย, ผู้อ่านสามารถเข้าถึงคำอธิบายของการทำงานแต่ละฟังก์ชั่นได้ในส่วนนี้<br>
# ภายในคู่มือนี้เนื้อหาจะถูกแบ่งออกเป็นสองส่วนได้แก่ ส่วนของ <a href=#main_function>Main Function</a> และ <a href=#debuging_tool>Debuging Tool</a></p>

# %% [markdown]
# <a name="main_function"></a>
# <h3>Main Function</h3>
# <p>This section contain core function that use to make the predictor from scratch and will not working properly if missing some of function.</p>
# <p>ในส่วนนี้จะประกอบไปด้วยชุดคำสั่งสำคัญของโปรแกรม ที่ทำให้ตัวพยากรณ์เริ่มต้นเรียนรู้จากศูนย์ ตัวพยากรณ์จะทำงานได้อย่างไม่ถูกต้องทันทีหากขาดฟังก์ชั่นบางอย่างในส่วนนี้ไป</p>

# %% [markdown]
# <a name="def_measure"></a>
# <h4>measure(measurement, dataframe, targetcolumn)</h4>
# <p>Do measure on target column of dataframe with selected measurement</p>
# <p>ทำการวัดผลไปยังแถวข้อมูลที่เลือกไว้จากชุดข้อมูล โดยทำการวัดผลตามเครื่องวัดผลที่เลือกไว้</p>

# %%
def measure(measurement, dataframe, targetcolumn):
    if 'measured_rate' in dataframe:
        overiding = 1
    else:
        overiding = 0
    dataframe['measured_rate'] = dataframe.apply (lambda row: measurement(row, targetcolumn), axis=1)
    if overiding == 1:
        result = "Measured complete and did overided"
    elif overiding == 0:
        result = "Measured complete"
    if -1 in dataframe['measured_rate'].unique():
        result = "Some or all record of this dataframe cannot be measure with this measurement, or user may make an incorrect call"
        del dataframe['measured_rate']
    return print(result)

# %% [markdown]
# <a name="def_satisfaction"></a>
# <h4>satisfaction(row, targetcolumn)</h4>
# <p>Is part of measurement, use to measure satisfaction of review.</p>
# <p>เป็นหนึ่งในกลุ่มของเครื่องวัดผล, ใช้เพื่อวัดผลความพึงพอใจของคำวิจารณ์</p>

# %%
def satisfaction(row, targetcolumn):
    if (row[targetcolumn] > 0) and (row[targetcolumn] < 4):
        return 0
    if (row[targetcolumn] > 3) and (row[targetcolumn] <= 5):
        return 1
    return -1

# %% [markdown]
# <a name="def_split_satisfaction_dataframe"></a>
# <h4>split_satisfaction_dataframe(dataframe, textcolumn)</h4>
# <p>Divide satisfaction dataframe into train and test set.</p>
# <p>แบ่งส่วนชุดข้อมูลความพึงพอใจออกเป็น train และ test เซ็ต</p>

# %%
# Modified from https://www.kaggle.com/matleonard/text-classification exercise
def split_satisfaction_dataframe(dataframe, textcolumn, ratecolumn = "measured_rate", split = 0.7):
    #By default: ratecolumn will aim to "measured_rate" column in case of renamed from measure() process -> user must input new name, also as split rate by default was 70% : 30% | Train : Val
    data = dataframe
    
    # Shuffle data
    train_data = data.sample(frac=1, random_state=7) #frac=1 is return full amount of input size
    
    texts = train_data[textcolumn].values
    labels = [{"POSITIVE": bool(y), "NEGATIVE": not bool(y)} #Class name UPPERCASE sensitivity.
              for y in train_data[ratecolumn].values]
    split = int(len(train_data) * split)
    
    train_labels = [{"cats": labels} for labels in labels[:split]] #"cats" is fixed for further use, do not change.
    val_labels = [{"cats": labels} for labels in labels[split:]]
    
    return texts[:split], train_labels, texts[split:], val_labels

# %% [markdown]
# <a name="def_train"></a>
# <h4>train(model, train_data, optimizer)</h4>
# <p>Train model with selected data and optimizer</p>
# <p>Train โมเดลด้วยชุดข้อมูลและ Optimizer ที่เลือกไว้</p>

# %%
def train(model, train_data, optimizer):
    losses = {}
    random.seed(1)
    random.shuffle(train_data)
    
    # Learn more about batch size at: https://arxiv.org/abs/1711.00489
    batches = minibatch(train_data, size=16)
    
    for batch in batches:
        # train_data is a list of tuples [(text0, label0), (text1, label1), ...]
        # Split batch into texts and labels
        texts, labels = zip(*batch)
        
        # Update model with texts and labels
        model.update(texts, labels, sgd=optimizer, losses=losses)
        
    return losses

# %% [markdown]
# <a name="def_predict"></a>
# <h4>predict(model, texts)</h4>
# <p>Predict document or texts with selected model.</p>
# <p>ทำการพยากรณ์ข้อความที่เลือกไว้ด้วยโมเดลที่ต้องการใช้</p>

# %%
def predict(model, texts): 
    # Use the model's tokenizer to tokenize each input text
    docs = [model.tokenizer(text) for text in texts]
    
    # Use textcat to get the scores for each doc
    textcat = model.get_pipe('textcat')
    scores, _ = textcat.predict(docs)
    
    # From the scores, find the class with the highest score/probability
    predicted_class = scores.argmax(axis=1)
    
    return predicted_class

# %% [markdown]
# <a name="def_evaluate"></a>
# <h4>evaluate(model, texts, labels)</h4>

# %%
def evaluate(model, texts, labels):
    # Returns the accuracy of a TextCategorizer model. 
    # Get predictions from textcat model (using your predict method)
    predicted_class = predict(model, texts)
    
    # From labels, get the true class as a list of integers (POSITIVE -> 1, NEGATIVE -> 0)
    true_class = [int(each['cats']['POSITIVE']) for each in labels]
    
    # A boolean or int array indicating correct predictions
    correct_predictions = predicted_class == true_class
    
    # The accuracy, number of correct predictions divided by all predictions
    accuracy = correct_predictions.mean()
    
    return accuracy

# %% [markdown]
# <a name="def_benchmark"></a>
# <h4>benchmark(model, optimizer, train_data, val_texts, val_labels)</h4>
# <p>Benchmark the model performance with selected data and optimizer</p>
# <p>ทำการทดสอบประสิทธิภาพของโมเดลด้วยชุดข้อมูลและ Optimizer ที่เลือกไว้</p>

# %%
def benchmark(model, optimizer, train_data, val_texts, val_labels, n_iters=10):
    sum_losses = 0
    sum_accuracy = 0
    for i in range(n_iters):
        losses = train(model, train_data, optimizer)
        sum_losses = sum_losses + losses['textcat']
        accuracy = evaluate(model, val_texts, val_labels)
        sum_accuracy = sum_accuracy + accuracy
        print(f"Loss: {losses['textcat']:.3f} \t Accuracy: {accuracy:.3f}")
    avg_losses = sum_losses / n_iters
    avg_accuracy = sum_accuracy / n_iters
    return print(f"---Average---\nLoss: {avg_losses:.3f} \t Accuracy: {avg_accuracy:.3f}")

# %% [markdown]
# <a name="debuging_tool"></a>
# <h3>Debuging Tool Function </h3>
# <p>This section contain additional of function which is not part of model creation but is useful in coding process. Concept of this section is function that will not edit any data in dataset or model's learning performance.<br> Debuging tool was seperate into two propose: <a href=#inspect_tool>Inspect Tool</a> and <a href=#test_tool>Test Tool</a></p>
# <p>ในส่วนนี้จะประกอบไปด้วยชุดคำสั่งเพิ่มเติม ที่ไม่ใช่เป็นส่วนหนึ่งในการสร้างและสอนโมเดล ซึ่งถูกสร้างขึ้นเพื่อใช้ในระหว่างกระบวนการพัฒนา แนวคิดหลักของชุดคำสั่งภายในส่วนนี้นั้นคือ ฟังก์ชั่นดังกล่าวจะไม่ส่งผลต่อการเรียนรู้ของโมเดลและเปลี่ยนแปลงค่าของข้อมูล<br>ส่วนของ Debuging tool จะถูกแบ่งออกตามวัตถุประสงค์การใช้งานเป็นสองส่วนได้แก่: <a href=#inspect_tool>Inspect Tool</a> และ <a href=#test_tool>Test Tool</a></p>

# %% [markdown]
# <a name="inspect_tool"></a>
# <h4>Inspect Tool</h4>
# <p>Use to display the value.</p>
# <p>ใช้ในการแสดงค่าข้อมูล</p>

# %% [markdown]
# <a name="def_inspect_txtlbl"></a>
# <h5>inspect_txtlbl(train_texts, train_labels)</h5>

# %%
#debuging tool - inspect to data record about its text and labeling
def inspect_txtlbl(train_texts, train_labels):
    print('Texts from training data\n------')
    print(train_texts[:2])
    print('\nLabels from training data\n------')
    print(train_labels[:2])

# %% [markdown]
# <a name="test_tool"></a>
# <h4>Test Tool</h4>
# <p>Use on experiment, but mostly is experiment report generator.</p>
# <p>ใช้ในการทดลอง แต่ส่วนมากแล้วจะเป็นเครื่องมือใช้ในการสร้างรายงานผลการทดลอง</p>

# %% [markdown]
# <a name="def_lbl_prob"></a>
# <h5>lbl_prob(text, model)</h5>

# %%
#Test Tool - Display label probability
#text = "If you are not use to using a large sustaining pedal while playing the piano, it may appear little awkward."
def lbl_prob(text, model):
    doc = model(text)
    return print(doc.cats)

# %% [markdown]
# <a name="def_predict"></a>
# <h5>val_predict(val_texts, model)</h5>

# %%
#test tool - Do predict from validation set.
def val_predict(val_texts, model):
    texts = val_texts[10:15]
    predictions = predict(satisfaction_nlp, texts)
    for p, t in zip(predictions, texts):
        print(f"{textcat.labels[p]}: {t} \n")

# %% [markdown]
# <a name="def_demo"></a>
# <h5>demo(test_text, model)</h5>

# %%
#test tool - Demonstration
def demo(test_text, model):
    #test_text = "The guitar wouldn’t stay in tune for longer than 2 minutes. I tuned it string by string as soon as it arrived and then went back to the first string to make sure everything was fine but they were all out of tune again as if they were slowly slipping flat. Dont buy."
    # From real review that's not exist in dataset: https://www.amazon.com/gp/customer-reviews/RHQYAO44BFGOH/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07NVWXTQQ
    test_data = {'text': test_text}
    test_df = pd.DataFrame(data=[test_data])
    test_subject = test_df[0:1].text.values
    text_predictions = predict(model, test_subject)
    for p, t in zip(text_predictions, test_subject):
        print(f"{textcat.labels[p]}: {t}")

# %% [markdown]
# <a name="implement"></a>
# <h2>Implement</h2>
# <p>Before doing experimental, experimentalist should get to know with dataset structure before.</p>
# <p>ก่อนลงมือทดลอง ผู้ลงมือทำควรทำความเข้าใจกับข้อมูลก่อน</p>

# %%
#Uncomment below if - Loading from Kaggle notebook editor
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
df = pd.read_csv("../input/amazon-music-reviews/Musical_instruments_reviews.csv")

#Uncomment and change directory if - Loading from your environment
#df = pd.read_csv("input/Musical_instruments_reviews.csv")

# %%
df.head()

# %%
df.info()

# %% [markdown]
# <a name="task0"></a>
# <h3>Task 0: Preprocessing</h3>
# <p>Preprocessing is process to make sure that dataset is already ready to use. Now time for check dataset completeness.</p>
# <p>สำหรับการประมวลผลขั้นแรกนั้น คือการประมวลผลเพื่อสร้างความพร้อมให้กับชุดข้อมูลให้อยู่ในสภาวะพร้อมใช้งานมากที่สุด โดยจะทำการตรวจสอบถึงความสมบูรณ์ของชุดข้อมูล</p>

# %%
df.isna().sum()

# %% [markdown]
# <p>Result from validation with <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.isna.html">.isna()</a> found that,</p>
# <p>จากการตรวจสอบความสมบูรณ์ด้วย <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.isna.html">.isna()</a> ได้พบว่า</p>
#
# > <p><u><b>It's incomplete dataset.</b></u></p>
# > <p><u><b>ชุดข้อมูลมีความไม่สมบูรณ์ของข้อมูล</b></u></p>
# <p>For this case, I decide to fill blank data into empty tuple.</p>
# <p>ในกรณีนี้ผู้พัฒนาเลือกใช้วิธีแก้ไขด้วยการเติมค่าว่างลงไปแทน</p>

# %%
df = df.fillna("")

# %% [markdown]
# <a name="task1"></a>
# <h3>Task 1: Categorize Feedback</h3>
# <p>Get into real job, The process will be two part that is determine the satisfaction, and training model.</p>
# <p>เริ่มเข้าสู่กระบวนการวิเคราะห์จริง จะพบว่าส่วนของการทำงานจะแบ่งออกเป็นส่วนกำหนดหลักการประเมิณความพึงพอใจ กับส่วนการสร้างแผนการสอนให้กับนักพยากรณ์</p>

# %% [markdown]
# <a name="todo1"></a>
# <h4>Todo 1) Categorize review satisfaction.</h4>
# <p>Begin analysis by start with looking into both two "reviewText" and "overall" to determine relation of each word in review and human sentiment.</p>
# <p>การวิเคราะห์เริ่มจากการใช้ประโยชน์จากข้อมูลสองอย่างนี้คือ คำวิจารณ์ และ คะแนนโดยรวม เพื่อวิเคราะห์ความเกี่ยวข้องกันว่า ข้อความวิจารณ์แต่ละคำนั้นมีความหมายอย่างไรกับความรู้สึก</p>

# %%
t1df = df[['reviewText','overall']]

# %%
t1df.head()

# %% [markdown]
# <p>Start with classify satisfaction from each feedback by assign the rating between 1 - 3 as unsatisfied and 4 - 5 as satisfied. We will do classify with <a href=#def_measure>measure()</a> pre-made function and use <a href=#def_satisfaction>satisfaction()</a> pre-made function as measurement. </p>
# <p>เริ่มจัดประเภทคำวิจารณ์ก่อนว่า ผู้วิจารณ์แต่ละคนนั้นได้ให้คำวิจารณ์ที่พึงพอใจหรือไม่ โดยกำหนดให้ถ้าคะแนนดาวอยู่ที่ 1 - 3 จะถือว่าผู้วิจารณ์นั้นยังมีความไม่พึงพอใจ แต่หากมีคะแนนดาวอยู่ที่ 4 - 5 จึงจะถือว่าผู้วิจารณ์นั้นมีความพึงพอใจแล้ว โดยจะทำการให้คะแนนด้วยฟังก์ชั่น <a href=#def_measure>measure()</a> กับฟังก์ชั่นเครื่องวัดผล "ความพึงพอใจ" <a href=#def_satisfaction>satisfaction()</a> </p>

# %%
measure(satisfaction, t1df, "overall")

# %% [markdown]
# <p>Let's see changed.</p>
# <p>ทำการตรวจสอบชุดข้อมูล เพื่อดูความเปลี่ยนแปลง</p>

# %%
t1df.head()

# %% [markdown]
# <p>There is new column "Measured_Rate"</p>
# <p>จะเห็นว่ามีคอลั่มน์ข้อมูลชื่อ "Measured_Rate" โผล่ขึ้นมา</p>

# %% [markdown]
# //buging tool - Adding noise

# %%
#buging tool - Adding noise
bugdf = pd.DataFrame([["Text0", 0], ["Text1", 0]], columns=['reviewText','overall'])
t1df = t1df.append(bugdf, ignore_index=True)
print("Noise Added")

# %%
t1df.tail()

# %% [markdown]
# //debuging tool - Removing noise

# %%
#debuging tool - Removing noise
bugdf = pd.DataFrame([["Text0", 0], ["Text1", 0]], columns=['reviewText','overall'])
#Modified from original's one, Thank you code from https://datascience.stackexchange.com/posts/37229/revisions
cond = t1df['reviewText'].isin(bugdf['reviewText'])
t1df.drop(t1df[cond].index, inplace = True)
print("Clear! Its noise free now.")

# %%
t1df.tail()

# %% [markdown]
# <a name="todo2"></a>
# <h4>Todo 2) Create NLP model that predict another musical instrument feedback statisfaction.</h4>

# %% [markdown]
# > Most of code and process come from [Kaggle's NLP course](https://www.kaggle.com/matleonard/text-classification) that I trying to start learning from tutorial,<br> You may want to learn more about how code working and was deeply introduced on [Kaggle's NLP course](https://www.kaggle.com/matleonard/text-classification).

# %% [markdown]
# <p>Perform split data for training and validating with <a href=#def_split_satisfaction_dataframe>split_satisfaction_dataframe()</a> pre-made function</p>
#
# <p>ทำการแบ่งชุดข้อมูลเพื่อใช้สำหรับฝึกสอนโมเดลและทดสอบความแม่นยำด้วยฟังก์ชั่น <a href=#def_split_satisfaction_dataframe>split_satisfaction_dataframe()</a> </p>

# %%
train_texts, train_labels, val_texts, val_labels = split_satisfaction_dataframe(t1df, "reviewText")

# %% [markdown]
# <p>Try look into result with <a href=#def_inspect_txtlbl>inspect_txtlbl()</a> pre-made function.</p>
#
# <p>ลองตรวจสอบผลลัพธ์ได้ด้วยฟังก์ชั่น <a href=#def_inspect_txtlbl>inspect_txtlbl()</a> </p>

# %%
inspect_txtlbl(train_texts, train_labels)

# %% [markdown]
# <p>Create model for training. (Learn more at <a href="https://www.kaggle.com/matleonard/text-classification">Kaggle's NLP course</a>)</p>
# <p>สร้างโมเดลสำหรับการเรียนรู้ (อ่านเพิ่มเติมได้ที่ <a href="https://www.kaggle.com/matleonard/text-classification">Kaggle's NLP course</a>) </p>

# %%
# Create an empty model
satisfaction_nlp = spacy.blank("en")

# Create the TextCategorizer with exclusive classes and "bow" architecture
textcat = satisfaction_nlp.create_pipe(
              "textcat",
              config={
                "exclusive_classes": True,
                "architecture": "bow"})

# Add the TextCategorizer to the empty model
satisfaction_nlp.add_pipe(textcat)

# Add labels to text classifier
textcat.add_label("NEGATIVE") #Class name UPPERCASE sensitivity.
textcat.add_label("POSITIVE") #Class name UPPERCASE sensitivity.

# %%
# Fix seed for reproducibility
spacy.util.fix_random_seed(1)
random.seed(1)

# %% [markdown]
# <p>Train model with prepared data with <a href=#def_train>train()</a> pre-made function.</p>
#
# <p>ทำการฝึกสอนโมเดลด้วยข้อมูลที่แบ่งเตรียมไว้แล้วด้วยฟังก์ชั่น <a href=#def_train>train()</a> </p>

# %%
# This may take a while to run!
optimizer = satisfaction_nlp.begin_training()
train_data = list(zip(train_texts, train_labels))
losses = train(satisfaction_nlp, train_data, optimizer)
print(losses['textcat'])

# %% [markdown]
# <p>Try look into result with <a href=#def_lbl_prob>lbl_prob()</a> pre-made function.</p>
#
# <p>ลองตรวจสอบผลลัพธ์ได้ด้วยฟังก์ชั่น <a href=#def_lbl_prob>lbl_prob()</a> </p>

# %%
text = "If you are not use to using a large sustaining pedal while playing the piano, it may appear little awkward."
lbl_prob(text, satisfaction_nlp)

# %% [markdown]
# <p>We finished training model and ready to use, now try make prediction on validation set with <a href=#def_val_predict>val_predict()</a> pre-made function which working with <a href=#def_predict>predict()</a> again.</p>
#
# <p>เมื่อทำการฝึกสอนโมเดลสำเร็จ ตอนนี้มาลองทดสอบพยากรณ์ด้วยฟังก์ชั่น <a href=#def_val_predict>val_predict()</a> โดยฟังก์ชั่นนี้จะทำงานร่วมกับฟังก์ชั่น <a href=#def_predict>predict()</a> อีกที </p>

# %%
val_predict(val_texts, satisfaction_nlp)

# %% [markdown]
# <p>Prediction look good! Now let's evaluate model to see how acceptable of accuracy with <a href=#def_evaluate>evaluate()</a> pre-made function.</p>
#
# <p>ผลการพยากรณ์ค่อนข้างดูดีมาก ตอนนี้ลองมาประเมิณผลดูว่าความแม่นยำนั้นอยู่ในระดับที่น่าพอใจไหม ด้วยฟังก์ชั่น <a href=#def_evaluate>evaluate()</a> </p>

# %%
accuracy = evaluate(satisfaction_nlp, val_texts, val_labels)
print(f"Accuracy: {accuracy:.4f}")

# %% [markdown]
# <a name="result"></a>
# <h4>Result</h4>

# %% [markdown]
# <p>Last step is benchmarking the model to find average value of model accuracy with <a href=#def_benchmark>benchmark()</a> pre-made function</p>
#
# <p>ขั้นตอนสุดท้ายคือการทดสอบประสิทธิ์ภาพด้วยการทดสอบจำนวน n ครั้ง และหาค่าเฉลี่ยของความแม่นยำในโมเดลด้วยฟังก์ชั่น <a href=#def_benchmark>benchmark()</a> </p>

# %%
benchmark(satisfaction_nlp, optimizer, train_data, val_texts, val_labels, n_iters=10)

# %% [markdown]
# Now let's our predictor try predict something that was not on dataset.

# %% [markdown]
# <a name="demo"></a>
# <h2>Demo</h2>

# %% [markdown]
# <p>Let's use newly created predictor by input review text that is not exist in dataset and perform with <a href=#def_demo>demo()</a> pre-made function</p>
#
# <p>มาทดลองใช้งานตัวพยากรณ์ที่เพิ่งสร้างเสร็จกัน โดยการกำหนดรีวิวที่ไม่ได้ปรากฏอยู่ในชุดข้อมูลมาก่อนดู แล้วใช้ฟังก์ชั่น <a href=#def_demo>demo()</a> ในการพยากรณ์ผลลัพธ์ </p>

# %%
input_text = "The guitar wouldn’t stay in tune for longer than 2 minutes. I tuned it string by string as soon as it arrived and then went back to the first string to make sure everything was fine but they were all out of tune again as if they were slowly slipping flat. Dont buy."
#This is real negative review that's not exist in dataset: https://www.amazon.com/gp/customer-reviews/RHQYAO44BFGOH/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&ASIN=B07NVWXTQQ

test_text = input_text
demo(test_text, satisfaction_nlp)

# %% [markdown]
# Your turn:<br>
# Now you can try make your own review on product, and predictor will told if it is positive review or negative.

# %%
input_text = "*Edit your lovely review here!*"

test_text = input_text
demo(test_text, satisfaction_nlp)

# %% [markdown]
# <a name="comment"></a>
# <h2>Comment</h2>

# %% [markdown]
# > I apologize if there are any errors. Feel glad for let me know to edit something that went wrong .
