# %% [markdown]
# <font size ="13">**Color Detection- OpenCV**
#
# <font size="5">**Problem Statement:-**
#     Build an application through which you can automatically get the name of the color by clicking on them
#
# <font size ="5">**Prerequisites**
#
# * <font size='3'>**Dataset:-**: CSV FILE
#     Colors are made up of 3 primary colors; red, green, and blue. In computers, we define each color value within a range of 0 to 255. So in how many ways we can define a color? The answer is 256*256*256 = 16,581,375. There are approximately 16.5 million different ways to represent a color. In our dataset, we need to map each color’s values with their corresponding names. We used dataset that contains RGB values with their corresponding names.
# The colors.csv file includes 865 color names along with their RGB and hex values.
#
# * <font size='3'>**Libraries:-**:
#
#     OpenCV, Pandas are the Python packages that are necessary for this project in Python.
# pandas is used for listing the data of the dataset.
# OpenCV is the huge open-source library for the computer vision, machine learning, and image processing and now it plays a major role in real-time operation which is very important in today's systems
#
# * <font size='3'>**Images:-**:
#
#     We used three images for testing this project.

# %%
import pandas as pd
import cv2

# %% [markdown]
# <font size= '5'>**Creating Variables:-**
#      We create two variables, one for storing path of the image and other for the path of the csv file.

# %%
img_path = '../input/detection/Color detection/pic2.jpg'
csv_path = '../input/detection/Color detection/colors.csv'

# %% [markdown]
# <font size='5'> **Reading data using Pandas:-**
#     We use pandas read_csv function to read the csv file in python and pandas DataFrame method to convert file into the data frame and gives names to each column.

# %%
index = ['color', 'color_name', 'hex', 'R', 'G', 'B']
df = pd.read_csv(csv_path, names=index, header=None)
print(df.head(5))

# %% [markdown]
# <font size='5'>**For printing total numbers of rows and columns of our dataset**

# %%
df.shape

# %% [markdown]
# <font size='5'> **Printing particular row:-**
#     For extracting the particular row or column from the dataset.

# %%
print(df.loc[1])

# %% [markdown]
# <font size='5'>**Reading Image with opencv**

# %%
img = cv2.imread(img_path)
print(img)

# %% [markdown]
# <font size='5'>**Resize:-**
#     We resized the image so it'll be completely visible on our screen.

# %%
img = cv2.resize(img,(800,600))

# %% [markdown]
# <font size='5'>**Creating variables:-**
#     when we have not clicked anywhere yet and thus intialized the variables equal to 0 that is, R,G,B,X-position,Y-  position

# %%
# it means that we have not double clicked left button until now 
clicked= False
r=g=b= xpos = ypos = 0

# %% [markdown]
# <font size='5'>**Getting color name:**
#     The basic concept used in this is that we found the absolute diffrence of each values with the values stored in the csv file, and when the absolute value is minimum that will be our color name

# %%
def get_color_name(R,G,B):
    minnimum=1000
    for i in range(len(df)):
        d = abs(R-int(df.loc[i, 'R'])) +  abs(G-int(df.loc[i, 'G'])) + abs(B-int(df.loc[i, 'B'])) 
        if d<= minimum:
            minimum = d
            cname =df.loc[i,'color_name']
            return cname

# %% [markdown]
# <font size ='5'>**Creating Function:-**
#     We created a function for getting the co-ordinates position of the cursor at the particular point on the image.

# %%
def draw_function(event, x, y, flags, params):
    #it check e=whether we have clicked lef button or not
    if event == cv2.EVENT_LBUTTONDBLCLK:
        # this function is used to make change appear outside the function by making variable global
         global clicked,r,g,b,xpos,ypos
        
        clicked=True
        xpos = x
        ypos = y
        #As we knkow that the opencv stores the value in BGR format instead of RGB format
        #This function is used for getting the values of that particular location 
        b,g,r =img[y,x]
        b=int(b)
        g=int(g)
        r=int(r)

# %% [markdown]
# <font size='5'>**Creating Window:-**
#     For displaying the image

# %%
cv2.namedWindow('picture')

# %% [markdown]
# <font size='5'>**Creating function**:-
#     For binding the position co-ordinates of cursor with mouse

# %%
cv2.setMouseCallback('image',draw_function)

# %%
# it is used so that our program keep on running
while True:
    cv2.imshow('image',img)
    if clicked:
        # this coding is used to make rectangle in which our colour name is showed
        cv2.rectangle(img,(20,20),(600,600),(b,g,r),-1)
        text = get_color_name(r,g,b) + ' R=' + str(r) + ' G=' + str(g) + ' B=' + str(b)
        
        # to put text in rectangle
        cv2.putText(img,text,(50,50),2,0.8,(255,255,255),2,cv2.LINE_AA)
        
        # if colour is light 
    if r+g+b >=600:
        cv2.putText(img,text,(50,50),2,0.8,(0,0,0),2,cv2.LINE_AA)
        # if after 20 seconds there is no double click than it close the window
    if cv2.waitKey(20) & 0xFF == 27:
        break

cv2.destroyAllWindows()

# %%
<font size='5'>**Creating function**:-

# %%
import cv2
import pandas as pd

# --------------------------------------------------------------------------

img_path = '../input/detection/Color detection/pic2.jpg'
csv_path = '../input/detection/Color detection/colors.csv'

# reading csv file
index = ['color', 'color_name', 'hex', 'R', 'G', 'B']
df = pd.read_csv(csv_path, names=index, header=None)

# reading image
img = cv2.imread(img_path)
img = cv2.resize(img, (800,600))

#declaring global variables
clicked = False
r = g = b = xpos = ypos = 0

#function to calculate minimum distance from all colors and get the most matching color
def get_color_name(R,G,B):
	minimum = 1000
	for i in range(len(df)):
		d = abs(R - int(df.loc[i,'R'])) + abs(G - int(df.loc[i,'G'])) + abs(B - int(df.loc[i,'B']))
		if d <= minimum:
			minimum = d
			cname = df.loc[i, 'color_name']

	return cname

#function to get x,y coordinates of mouse double click
def draw_function(event, x, y, flags, params):
	if event == cv2.EVENT_LBUTTONDBLCLK:
		global b, g, r, xpos, ypos, clicked
		clicked = True
		xpos = x
		ypos = y
		b,g,r = img[y,x]
		b = int(b)
		g = int(g)
		r = int(r)

# creating window
cv2.namedWindow('image')
cv2.setMouseCallback('image', draw_function)

while True:
	cv2.imshow('image', img)
	if clicked:
		#cv2.rectangle(image, startpoint, endpoint, color, thickness)-1 fills entire rectangle 
		cv2.rectangle(img, (20,20), (600,60), (b,g,r), -1)

		#Creating text string to display( Color name and RGB values )
		text = get_color_name(r,g,b) + ' R=' + str(r) + ' G=' + str(g) + ' B=' + str(b)
		#cv2.putText(img,text,start,font(0-7),fontScale,color,thickness,lineType )
		cv2.putText(img, text, (50,50), 2,0.8, (255,255,255),2,cv2.LINE_AA)

# %% [markdown]
# <font size="14">**Summary**
#
#  we learned about colors and how we can extract color RGB values and the color name of a pixel. We learned how to handle events like double-clicking on the window and saw how to read CSV files with pandas and perform operations on data. This is used in numerous image editing and drawing apps.
