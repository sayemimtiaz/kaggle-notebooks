# %% [markdown]
# # Python  Data Science Tutorial using IRIS dataset part1
# ## By Sheikh Islam

# %% [markdown]
# ###  Introduction
#
# Machine learning is a subfield of artificial intelligence. This  is the  learning algorithms to make decision-based on those data and try to behave like a human being.

# %% [markdown]
# ### Dataset
#
# You will find many machine learing dataset from here.</br>
# https://archive.ics.uci.edu/ml/index.php .</br>
#
# If you do not have this Iris dataset,download from the path </br>
# http://archive.ics.uci.edu/ml/machine-learning-databases/iris/</br>

# %% [markdown]
# ### Load libraries
# Matplotlib – a plotting library ,</br>
#
# NumPy – Handling n-dimensional array</br>
#
# Pandas – Data structures tools</br>
#
# Scikit Learn – a machine learning library that we use it to teach our computer and make prediction</br>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#from sklearn import model_selection
#from sklearn.metrics import accuracy_score
#from sklearn.linear_model import LogisticRegression
#from sklearn.linear_model import LinearRegression
#from sklearn.ensemble import RandomForestClassifier
#from sklearn.neighbors import KNeighborsClassifier
#from sklearn.svm import SVC

# %% [markdown]
# ###  Load and understanding data
#
# You can load the data directly from the UCI Machine Learning repository. you can download the iris.csv file into your working directory and load it using the same method, changing URL to the local file name.

# %%
df = pd.read_csv("../input/iris-flower-dataset/IRIS.csv")

# %%
df.head(5)

# %%
df.info()

# %% [markdown]
# ### Dimensions of Dataset

# %%
df.shape

# %%
df.describe()

# %% [markdown]
# ### Data Visualization
# We now have a basic idea about the data. We need to extend that with some visualizations.

# %%
df.plot(kind='box', subplots=True, layout=(2,2), sharex=False, sharey=False)

plt.show()

# %% [markdown]
# #### Histograms

# %%
df.hist()
plt.show()

# %% [markdown]
# #### Scatter plot matrix

# %% [markdown]
# #### Multivariate Plots
# Now we can look at the interactions between the variables.

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df)
plt.show()

# %% [markdown]
# #### Summarizing the missing values.
# We will display how many missing values are present in each column.

# %%
df.isnull().sum()

# %%
df.isnull()

# %% [markdown]
# #####  Correlation:
#  Correlation is used to determine pairwise correlation of all the columns of the dataset.
#  The missing values are excluded and non-numeric columns are also ignored.

# %%
df.corr(method='pearson')
