# %%
import numpy as np 
import pandas as pd 

df_noble = pd.read_csv("../input/nobel-prize-from-1901-till-2020/nobel_final.csv")
#display(df.head())
display(df_noble.columns)

max_age = df_noble.age.max()
min_age = df_noble.age.min()
print("Oldest Noble Prize winner:", max_age)
print("Youngest Noble Prize winner:", min_age)

uni_state = df_noble.city_of_university[-2]

us_winners = df_noble[(df_noble.born_country_code == "US")]
#yale_winners = df_noble[(df_noble.city_of_university[-2] == "CT")]
display(us_winners)

# %%
import numpy as np 
import pandas as pd 

df_noble = pd.read_csv("../input/nobel-prize-from-1901-till-2020/nobel_final.csv")
#display(df.head())
display(df_noble.columns)

# %%
max_age = df_noble.age.max()
min_age = df_noble.age.min()
print("Oldest Noble Prize winner:", max_age)
print("Youngest Noble Prize winner:", min_age)
