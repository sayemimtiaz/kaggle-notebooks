# %% [markdown]
# #Ça va sans dire

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQmo1qrsrdHjAV3W_Fsc1eW3cvic4KQL6Uje1W_CycLT8twa3uY&usqp=CAU',width=400,height=400)

# %% [markdown]
# dreamstime.com

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/png;base64,...',width=400,height=400)

# %% [markdown]
# pt.wikipedia.org

# %%
df = pd.read_csv('../input/uncover/github/covid19-epidemic-french-national-data.csv', encoding='ISO-8859-2')

df.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcR7Jq4MvK3kyVJciwU5VlxtrEGq6M-i0lxsG3XCL3o2K8i8WqJb&usqp=CAU',width=400,height=400)

# %% [markdown]
# stock.adobe.com

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# lesechos.fr

# %% [markdown]
# #Codes from Arpita Gupta https://www.kaggle.com/arpita28/global-spread-analysis/comments
#
# People that teach us, with their Public work are the teachers that we choose. That's my 1st Map out of Kaggle mini-course.

# %%
import plotly.express as px
plot_map=df.groupby(['date','maille_nom']).sum().reset_index()
names=plot_map['maille_nom']
values=plot_map['deces']
fig = px.choropleth(plot_map, locations=names,
                    locationmode='country names',
                    color=values)
fig.update_layout(title="Décès Progression")
fig.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcS4caXwQT7McNfOBRwK2RUEnTNEY-UYxxnes4B2jgXegPoANXV9&usqp=CAU',width=400,height=400)

# %% [markdown]
# slideserve.com

# %%
import plotly.graph_objects as go
import plotly.offline as py
import plotly.figure_factory as ff
py.init_notebook_mode(connected=True)
from bokeh.io import output_file, output_notebook
from bokeh.plotting import figure, show, reset_output
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.layouts import row, column, gridplot
from bokeh.models.widgets import Tabs, Panel
import bokeh.palettes
from bokeh.transform import cumsum

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTTvPPWQme3NJRluFbgtfHWmXBoyHWShCSOz8Rtg4Q4I_oytej_&usqp=CAU',width=400,height=400)

# %% [markdown]
# fr.wikipedia.org

# %%
est=df[df['maille_nom']=='Grand Est']
est

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcROzGsT6XuhIdsvnUZsN1DJ8wqeMPyi0s2ELg7xCcS_5GrRFema&usqp=CAU',width=400,height=400)

# %% [markdown]
# mice-occitanie.com

# %%
haut=df[df['maille_nom']=='Haut-de-France']
haut

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRFDwbXDXzZhAoTxsxk84TWlamBOADdybNZWuqoPXH8iOJIujg6&usqp=CAU',width=400,height=400)

# %% [markdown]
# france3-regions.francetvinfo.fr

# %%
output_notebook()
fig = figure(x_axis_type='datetime',
             plot_height=500, plot_width=700,background_fill_color='grey',
             title='Comparison in spread of virus in Grand Est and Haute-de France ',
             x_axis_label='date', y_axis_label='cas_confirmes',
             toolbar_location='right')
fig.step('date', 'cas_confirmes', 
         color='white', legend_label='Haut-de-France et Grand Est', 
         source=est)
fig.step('date', 'cas_confirmes', 
         color='red', legend_label='Grand Est et Haute-de-France', 
         source=haut)
fig.legend.location = 'top_left'
show(fig)

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQHhkQq18_JDVU3AnjpjPTnpKK1Ft6Xi8gA8J8369khgilvs5fC&usqp=CAU',width=400,height=400)

# %% [markdown]
# amazon.com.br

# %%
maille = df[df['maille_nom'].isin(['Bretagne', 'Normandie', 'Hauts-de-France','Grand Est','Pays de la Loire','Nouvelle-Aquitaine','Corse','Mayotte','Centre-Val de Loire'])].reset_index()
maille = maille.groupby('maille_nom')['maille_nom','date', 'cas_confirmes', 'deces'].sum().reset_index()
maille

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# drapeau-shop.com

# %% [markdown]
# Merci Arpita Gupta https://www.kaggle.com/arpita28/global-spread-analysis/comments  Mon premier Bokeh chart.

# %%
fig = go.Figure(data=[
      go.Bar(name='cas_confirmes', x=maille['maille_nom'], y=maille['cas_confirmes'],marker_color='blue'),
      go.Bar(name='deces', x=maille['maille_nom'], y=maille['deces'],marker_color='yellow')
      ],layout=go.Layout(
      title=go.layout.Title(text="Confirmed cases and dead in France")
      ))
template='plotly_dark'
fig.update_layout(template=template)
fig.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQqzDKlZ_W15wkh1jIt9KwDwORvMb942UV2S_6zPj7BlULYm8aw&usqp=CAU',width=400,height=400)

# %% [markdown]
# youtube.com

# %%
total_cas_confirmes=df.groupby('date')['maille_nom','date','cas_confirmes','deces'].sum().reset_index()
total_cas_confirmes

# %%
fig=go.Figure(data=[
    go.Scatter(x=total_cas_confirmes['date'],
    y=total_cas_confirmes['cas_confirmes'],marker_color='pink')]
)
fig.update_layout(title='Confirmed cases over time',font_size=16,yaxis_type='log',template='plotly_dark')
fig.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# about-france.com

# %% [markdown]
# France is so oddsome that I decided to include more Regions and less disease codes (Covid-19 viruses).

# %% [markdown]
# Kaggle Notebook Runner: Marília Prata @mpwolke
