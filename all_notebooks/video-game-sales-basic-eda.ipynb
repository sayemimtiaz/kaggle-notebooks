# %% [markdown]
# # Introduction & Objectives
#
# This Video Game Sales data consists of few parameters and to summarize it the data is showing the ranking of the games from 1990s to 2020 (around).
# The sales includes Europe, Japan, North America and Others. Based on these datas, I will just do a basic EDA on how and what these data and relaying in a more visual way with description.
# ALso to learn about the history or transformation of gaming industry in a swallow way.

# %% [markdown]
# # I. Data Loading & Libraries Usage

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

df = pd.read_csv("/kaggle/input/videogamesales/vgsales.csv")
# %config InlineBackend.figure_format = 'retina'
df.head(5)

# %%
df.describe()

# %% [markdown]
# # II. Basic Information Interpretation:
#     You can see that the highest sales in the past is 82.74mil where the lowest is roughly 0.01mil in total.
#     North America will contribute the most Global Sales (averagely) of all the across all type of games.

# %%
fig, axs = plt.subplots(1, 3, sharey=True);
gh1 = df.plot(kind='scatter', x='Year', y='Global_Sales',ax = axs[0], figsize=(22, 6));
gh2 = df.plot(kind='scatter', x='Genre', y='Global_Sales',ax = axs[1], figsize=(22, 6));
gh3 = df.plot(kind='scatter', x='Platform', y='Global_Sales', ax = axs[2], figsize=(22, 6));
gh2.tick_params(labelrotation=45)
gh3.tick_params(labelrotation=90)

# %% [markdown]
# **Scatter Chart**
# **From above scatter chart, we can see that:**
# - Peak Global Sales @ 2006(around) - Sports from Wii.
# - High Individual Platform Sales @ Wii, NES, GB and DS.
# - High Individual Genre Sales @ Sports, Platform and Racing.

# %% [markdown]
# # III. Detail Analysis

# %%
GR1 = df.groupby(["Genre","Year"]).sum().reset_index()
GR2 = df.groupby(["Genre","Year"]).size().reset_index(name = 'Frequency')
PR1 = df.groupby(['Platform','Year']).sum().reset_index()
PR2 = df.groupby(['Platform','Year']).size().reset_index(name = 'Frequency')
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
fs = plt.figure(figsize=(14,7))
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2,figsize=(20,20) )
sns.lineplot(x='Year',y='Global_Sales',  hue = 'Genre', ax=ax1, palette="gist_rainbow",  data=GR1)
sns.lineplot(x='Year',y='Frequency',  hue = 'Genre', ax=ax2, palette="gist_rainbow", data=GR2)
sns.lineplot(x='Year',y='Global_Sales',  hue = 'Platform', ax=ax3, palette="gist_ncar_r",  data=PR1)
sns.lineplot(x='Year',y='Frequency',  hue = 'Platform', ax=ax4, palette="gist_ncar_r",  data=PR2)

# %% [markdown]
# **Game industry rises exponentially around 1995 - 2020 whereby the starting point is:**
# 1. PS Platform Introduced (1995 - 1996) Famous Games Like:
#     - Crash Bandicoot (Global_Sales: **6.82mil**) {Genre: **Platform**}
#     - Tekken 2 (Global_Sales: **5.43mil**) {Genre: **Fighting**}
# ![Play Station 1](https://upload.wikimedia.org/wikipedia/commons/3/39/PSX-Console-wController.jpg)
# 2. N64 Platform Introduced (1996 - 1997) Famous Games Like:
#     - Super Mario 64 (Global_Sales: **11.9mil**) {Genre: **Platform**}
#     - Mario Kart 64 (Global_Sales: **9.87mil**) {Genre: **Racing**}
# ![Nintendo 64](https://upload.wikimedia.org/wikipedia/commons/1/11/N64-Console-Set.jpg)
#
# **Global Sales Peak Point in these recent years is between 2005 - 2008 whereby the main contributor are:**
# 1. Sports Genre Top Sales in 2005
#     - Wii Sports (Global_Sales: **82.74mil**) {Platform: **Wii**}
#     - Madden NFL 06 (Global_Sales: **4.91mil**) {Platform: **PS2**}
# ![Wii SPorts](https://upload.wikimedia.org/wikipedia/en/e/e0/Wii_Sports_Europe.jpg)
#                     Wii SPorts (High in Demand due to the Interaction of Body and Game)
# 2. Action Genre Top Sales
#     - Grand Theft Auto: Liberty City Stories (Global_Sales: **7.72mil**) {Platform: **PSP**}
#     - The Legend of Zelda: Twilight Princess (Global_Sales: **7.32mil**) {Platform: **Wii**}

# %%
PuR1 = df.groupby(["Publisher","Year"]).sum().reset_index()
PuR2 = df.groupby(["Publisher","Year"]).size().reset_index(name = 'Frequency')
Frequency = PuR2['Frequency']
PuR1 = PuR1.join(Frequency)
PuR3 = PuR1.sort_values('Global_Sales',ascending = False)
PuR3 = PuR3.head(100)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

plt.figure(figsize=(20,13))
ax = sns.scatterplot(x="Year", y="Frequency",hue="Publisher", size="Global_Sales", sizes = (100,800), palette="gist_rainbow",data=PuR3)

# %% [markdown]
# **I analyse the Global Sales of the top 100 Publisher throughout the year and seeing the impact of "How Many Games was Release (Frequency)" against "the Total Sales Generated by the Publisher" at each year.**
#
# 1. Nintendo have been conquering the video games sales market 1985.
#     * Sales kicked off at 2005 - 2010 where the highest sales was  205.16mil.
#     * Their sales was high (Circle Size is Big) when only limited games was released.
# 2. Electronic Arts is doing well but not as good as Nintendo but they also release a lot of games for each year.
#     * The Sales hit off around 2003 - 2011 where the highest sales was 86.2mil.
#     * This might be due to the high game release that reflects the high global sales.

# %%
SR1 = df.groupby('Year').sum().reset_index()
#SR1 = SR1.melt('Year', var_name=['NA_Sales','EU_Sales','JP_Sales','Other_Sales'],  value_name='vals')
#plt.figure(figsize=(16,9))
#d = sns.factorplot(x="Year", y="vals", hue=['NA_Sales','EU_Sales','JP_Sales','Other_Sales'], data=SR1)
SR1 = pd.melt(SR1, id_vars=['Year'], value_vars=['NA_Sales', 'JP_Sales','EU_Sales','Other_Sales'])
SR1 = SR1.groupby(['variable','Year']).sum().reset_index()
#SR1 = SR1.sort_values('Year',ascending=True)
plt.figure(figsize=(16,9))
ax = sns.lineplot(x='Year',y='value',  hue = 'variable', palette="gist_rainbow",  data=SR1)

# %% [markdown]
# **By transposing the sales row, the graph shows the sales in each country by year and how the strong the gaming market penetrates into these places.**
#
# 1. NA sales has the highest overall sales since 1980.
#     * During 1980 to 1982, NA is the only place where sales hit at least 1mil.
#     * The highest sales is at 2009 which it peaked to 350mil in total.
# 2. EU sales started going up at 1997.
#     * During 1996 where PS1 and NE64 became very popular thus the rise in EU Sales.
#     * Peak sales was at 2009 where it was 191.59mil.

# %% [markdown]
# **EDA Conclusion**
# 1. Sports generates one of the best Sales along but better than Action genre when Freqeuncy is taken into account.
# 2. PS2 and Wii have the highest sales due to the action games PS2 and also the sports genre in Wii.
# 3. Nintendo generates the Highest Sales among all the publisher but Electronic Arts generates high sales due to the high game releases.
# 4. Lastly, most of the sales were generated in NA especially during 2009 - 2010.
