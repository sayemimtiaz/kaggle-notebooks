# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import plotly.express as px
import plotly.graph_objects as go
import plotly.subplots as subplots
import plotly as py
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)

# %%
def plot_chart(df,metric_dict,title,subtitle=None):
    fig = go.Figure()
    
    line_color = ['#008abc','#96508e','#4fcb93','#f86e35','#ddaa18','#20beff']

        
    count = 0
    for m in metric_dict:
        fig.add_trace(go.Scatter(x=df.index, y=df[m], name=metric_dict[m],
                         line=dict(color=line_color[count], width=4)))
        count += 1
    

    fig.update_layout(title=title,
                       xaxis_title='Date',
                       yaxis_title='',
                       yaxis = dict(rangemode = 'tozero'))

    if subtitle is not None:
        fig.update_layout(annotations=[dict(x=-.014,y=1.12,text=subtitle,showarrow = False,xref='paper', yref='paper')])

    
    return fig

# %%
df_us = pd.read_csv('../input/us-eia-hourly-electricity-consumption/data/U.S./United States Lower 48 (US48).csv',index_col=[0],parse_dates=[0])

# %%
metric_dict = dict()
metric_dict['EBA.US48-ALL.D.H'] = 'EBA.US48-ALL.D.H'


plot_chart(df_us,metric_dict,'EBA.US48-ALL.D.H')

# %%
df_texas = pd.read_csv('../input/us-eia-hourly-electricity-consumption/data/Regions/Texas (TEX).csv',index_col=[0],parse_dates=[0])

# %%
metric_dict = dict()
metric_dict['EBA.TEX-ALL.NG.H'] = 'EBA.TEX-ALL.NG.H'


plot_chart(df_texas,metric_dict,'EBA.TEX-ALL.NG.H')
