# %%
import numpy as np
import pandas as pd
import os
import folium
from folium import plugins
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
data0=pd.read_csv('../input/278k-us-wildfires-due-to-lightning-2004-2015/US_Lightning_Forest_Fires.csv')
data0

# %%
print(data0.columns.tolist())

# %%
fig,ax = plt.subplots(figsize=(6,6))
ax.set_title('Fire size vs Continue time',fontsize=20)
ax.set_ylabel('FIRE_SIZE',fontsize=12)
ax.set_xlabel('CONT_TIME',fontsize=12)
ax.scatter(data0['CONT_TIME'],data0['FIRE_SIZE'])

# %%
data1=data0[data0['FIRE_SIZE']>200000]
data1[-5:]

# %%
data2=data1[['LATITUDE','LONGITUDE']]
data2=data2.fillna('N')
data2

# %%
eq_map = folium.Map(location=[42,-110],tiles='Stamen Terrain',zoom_start=4.0,min_zoom=2.0)
eq_map.add_child(plugins.HeatMap(data2))
eq_map
