# %%
import pandas as pd 
import numpy as np

# %%
dados = pd.read_csv("../input/world-population-by-year/WorldPopulation.csv")

# %%
dados

# %%
type(dados)

# %%
dados.index

# %%
dados.columns

# %%
dados['Year']

# %%
dados.head(8)

# %%
dados.tail(10)

# %%
dados.columns

# %%
dados2 = dados[['Year', 'Population', 'ChangePerc', 'NetChange', 'Density']]

# %%
dados2.head()

# %%
dados2.to_csv('dadospopulacaomundial.csv',index = False)

# %%
dados2 = pd.read_csv('dadospopulacaomundial.csv')
dados2.head()
