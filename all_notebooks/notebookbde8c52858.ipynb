# %%
import pandas as pd
import numba as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
data=pd.read_csv("../input/pakistan-food-prices/Pakistan_Food_Price.csv")

# %%
data.head()

# %%
data.info()

# %%
data.shape

# %%
data.describe()

# %%
data['date']=pd.to_datetime(data['date'])

# %%
plt.figure(figsize=(12,7))
plt.style.use('ggplot')
sns.lineplot(x='date',y='price',data=data , hue='unit')

# %%
plt.figure(figsize=(20,7))
plt.style.use('ggplot')
sns.lineplot(x='date',y='price',data=data , hue='category')

# %%
plt.figure(figsize=(20,7))
plt.style.use('ggplot')
sns.lineplot(x='date',y='price',data=data , hue='admname')

# %%
plt.figure(figsize=(20,7))
plt.style.use('ggplot')
sns.lineplot(x='date',y='price',data=data , hue='mktname')

# %%
plt.figure(figsize=(20,7))
plt.style.use('fivethirtyeight')
sns.lineplot(x='date',y='mktid',data=data )

# %%
plt.figure(figsize=(20,7))
plt.style.use('fivethirtyeight')
sns.lineplot(x='date',y='cmid',data=data )

# %%
plt.figure(figsize=(20,7))
plt.style.use('fivethirtyeight')
sns.lineplot(x='date',y='umid',data=data )

# %%
plt.figure(figsize=(20,7))
plt.style.use('fivethirtyeight')
sns.lineplot(x='date',y='catid',data=data )

# %%
sns.pairplot(data=data)

# %%
data['Day']=data['date'].dt.day_name()

# %%
plt.figure(figsize=(12,7))
sns.lineplot(x='Day',y='price',data=data )

# %% [markdown]
# # high price in Monday and less price in Thursday

# %%
from pandas_profiling import ProfileReport
a=ProfileReport(data)

# %%
a
