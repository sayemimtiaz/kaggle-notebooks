# %% [markdown]
# # **Pre requisits**

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/kaggle/input/car-salescsv/1.04. Real-life example.csv')

# %%
df.shape

# %%
df.head(10)

# %% [markdown]
# # **Cleaning The data**

# %%
# dropping Engine Version columan becasue we wont be using it and it has a lot of noisy data
df=df.drop(['EngineV'], axis = 1)

# %%
df.head()

# %%
df.isnull().sum()

# %%
df=df.fillna(df['Price'].mean(skipna=True))

# %%
df[df['Mileage']==0]

# %%
df['Mileage']=df['Mileage'].mask(df.Mileage==0,df['Mileage'].mean(skipna=True))

# %%
#check duplicate values
df.duplicated().sum()

# %%
df.drop_duplicates(keep='first',inplace=True)

# %%
df = df[df['Mileage']>100] 
df = df[df['Mileage']<400]

# %%
sns.distplot(df['Mileage'])

# %% [markdown]
# # **Data Analysis**
# Exporing the dataset

# %% [markdown]
# **Insight one**

# %%
# Each brand has listed these many cars uptil now since 1970s
dfa=df.Brand.value_counts()
dfa

# %%
fig, ax = plt.subplots(figsize = (12,6))
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['text.color'] = 	'#696969'
plt.rcParams['axes.labelcolor']= 	'#696969'
plt.rcParams['xtick.color'] = '#696969'
plt.rcParams['ytick.color'] = '#696969'
plt.rcParams['font.size']=12
color_palette_list = ['#009ACD', '#ADD8E6', '#63D1F4', '#0EBFE9',   
                      '#C1F0F6', '#0099CC']
ind = np.arange(len(dfa))
bars1 = ax.bar(dfa.index, dfa, 
        color = color_palette_list, 
        label=dfa.index)
ax.set_title("Number of car models realsed till 2016 per brand")
ax.set_ylabel('Number of car models realsed till 2016')


ax.set_xticklabels(dfa.index, rotation=70)
ax.set_xlabel("Car Brands")

# %% [markdown]
# **Insight two**

# %%
sns.distplot(df['Price'])

# %%
df.sort_values('Year')

# %%
Year1= df['Year'].unique()
Year1.sort()
len(Year1)

# %%
from statistics import median

# %%
median_per_year = []
for i in Year1:
    df0 = df[df['Year']==i]
    a = median(df0['Price'])
    median_per_year.append(a)

len(median_per_year)

# %%
# Median explains the approximate value each brand generally makes cars for. We can see that no car barnd creates cars for 300000 becase that is more expensive.   
sns.lineplot(Year1,median_per_year)
plt.title("Prefered Price range per year")

# %% [markdown]
# **Insight Three**

# %%
sns.lineplot(df['Year'],df['Price'])
plt.title("Price range per year")

# %%
len(df['Model'].unique())

# %% [markdown]
# **Insight Four**

# %%
sns.lineplot(df['Year'],df['Mileage'])
plt.title("Mileage trends since 1970s till 2016")

# %%
dfz= df[df['Year']==2016]
dfz['Mileage'].mean()

# %%
dfy= df[df['Year']==1990]
dfy['Mileage'].mean()

# %% [markdown]
# Best time to buy cars was in early 1970s. Highest mileage for the lowest pirce. This can be futher analysed by ratio of price/mileage

# %% [markdown]
# **Insight 5**
# Which brands launched how many new car models in each year.

# %%
New_models_per_year = []
New_models_per_model_per_year = []
for i in Year1:
    df1= df[df['Year']==i].groupby("Brand").count()
    
    New_models_per_model_per_year.append(df1)

New_models_per_model_per_year

# %%
df1 = df[df['Year']<2000].groupby("Brand")['Year'].count()
df2 = df[df['Year']>=2000].groupby("Brand")['Year'].count()

# %%
df1

# %%
df2

# %%
fig, ax = plt.subplots(figsize = (12,6))
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['text.color'] = 	'#696969'
plt.rcParams['axes.labelcolor']= 	'#696969'
plt.rcParams['xtick.color'] = '#696969'
plt.rcParams['ytick.color'] = '#696969'
plt.rcParams['font.size']=12
color_palette_list = ['#009ACD', '#ADD8E6', '#63D1F4', '#0EBFE9',   
                      '#C1F0F6', '#0099CC']
ind = np.arange(len(df1))
bars1 = ax.bar(df1.index, df1, 
        color = color_palette_list, 
        label=df1.index)
ax.set_title("Number of car models realsed beafore 2002 per brand")
ax.set_ylabel('Number of car models realsed beafore 2002')


ax.set_xticklabels(df1.index, rotation=70)
ax.set_xlabel("Car Brands")

# %%
fig, ax = plt.subplots(figsize = (12,6))
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['text.color'] = 	'#696969'
plt.rcParams['axes.labelcolor']= 	'#696969'
plt.rcParams['xtick.color'] = '#696969'
plt.rcParams['ytick.color'] = '#696969'
plt.rcParams['font.size']=12
color_palette_list = ['#009ACD', '#ADD8E6', '#63D1F4', '#0EBFE9',   
                      '#C1F0F6', '#0099CC']
ind = np.arange(len(df2))
bars1 = ax.bar(df2.index, df2, 
        color = color_palette_list, 
        label=df2.index)
ax.set_title("Number of car models realsed after 2002 per brand")
ax.set_ylabel('Number of car models realsed after 2002')


ax.set_xticklabels(df1.index, rotation=70)
ax.set_xlabel("Car Brands")

# %% [markdown]
# **Insight 6**

# %%
df1= df[df['Year']==2016]
df2=df1.groupby("Brand")['Price'].mean()
df2

# %%
fig, ax = plt.subplots(figsize = (12,6))
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['text.color'] = 	'#696969'
plt.rcParams['axes.labelcolor']= 	'#696969'
plt.rcParams['xtick.color'] = '#696969'
plt.rcParams['ytick.color'] = '#696969'
plt.rcParams['font.size']=12
color_palette_list = ['#009ACD', '#ADD8E6', '#63D1F4', '#0EBFE9',   
                      '#C1F0F6', '#0099CC']
ind = np.arange(len(df2))
bars1 = ax.bar(df2.index, df2, 
        color = color_palette_list, 
        label=df2.index)
ax.set_title("Number of car models ")
ax.set_ylabel('Number of car models')


ax.set_xticklabels(df2.index, rotation=70)
ax.set_xlabel("Car Brands")
plt.title("AVegarge car price per brand in 2016")
plt.show()

# %%
df4=df[['Brand','Body']]
df4=df4.groupby('Body')['Brand'].count()
print(df4)

# %%
fig, ax = plt.subplots(figsize = (12,6))
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['text.color'] = 	'#696969'
plt.rcParams['axes.labelcolor']= 	'#696969'
plt.rcParams['xtick.color'] = '#696969'
plt.rcParams['ytick.color'] = '#696969'
plt.rcParams['font.size']=12
color_palette_list = ['#009ACD', '#ADD8E6', '#63D1F4', '#0EBFE9',   
                      '#C1F0F6', '#0099CC']
ind = np.arange(len(df4))
bars1 = ax.bar(df4.index, df4, 
        color = color_palette_list, 
        label=df4.index)
ax.set_title("Number of car models ")
ax.set_ylabel('Number of car models')


ax.set_xticklabels(df4.index, rotation=70)
ax.set_xlabel("Car body type")
plt.title("Number of car body types  since 1970s") 
plt.show()

# %%
ET = df.groupby('Engine Type')['Price'].count()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(ET.index,ET)
plt.title("Number of car type models created since 1970s")
plt.show()

# %%
ET = df0.groupby('Engine Type')['Price'].count()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(ET.index,ET)
plt.title("Number of car types produced in 2016") # produced does not feel right. As they are new car model nos and not the no of cars manifarured.
plt.show()

# %%
X = df4.index
Diesel=[]
Petrol=[]
for i in X:
    dfx=df[df['Body']==i]
    a=dfx.groupby('Engine Type')['Body'].count()
    Diesel.append(a['Diesel'])
    Petrol.append(a['Petrol'])

# %%
X_axis = np.arange(len(X))
plt.xticks(X_axis, X)
plt.bar(X_axis - 0.2,Diesel, 0.4, label = 'Diesel')
plt.bar(X_axis + 0.2,Petrol, 0.4, label = 'Petrol')
plt.xlabel("Car Body types")
plt.ylabel("Count")
plt.title("Car engine type distribution since 1970s")
plt.legend()
plt.show()

# %%
# calculating price to mileage ratio per type best mileage konti gadi type dete kamit kami kimti madhe
ratio1 = df['Price']/df['Mileage']
df['Price/Mileage'] =ratio1
sns.distplot(df['Price/Mileage'])

# %%
median(df['Price/Mileage'])

# %% [markdown]
# Ratio above 200 signify luxury cars!! Best ratio to look for is 55.55! Which means cars that survive longer with cheaper price!
