# %%
# !pip install dataprep by

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from warnings import filterwarnings
from datetime import datetime
from mpl_toolkits.mplot3d import Axes3D
import statsmodels.api as sm
import missingno as msno
import statsmodels.stats.api as sms
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.neighbors import LocalOutlierFactor
from scipy.stats import levene
from scipy.stats import shapiro
from scipy.stats.stats import pearsonr
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from sklearn.preprocessing import scale
from sklearn.model_selection import ShuffleSplit, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import model_selection
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import BaggingRegressor
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LinearRegression
from sklearn.cross_decomposition import PLSRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import LassoCV
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import ElasticNetCV
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
import xgboost as xgb
from xgboost import XGBRegressor, XGBClassifier
from lightgbm import LGBMRegressor, LGBMClassifier
from catboost import CatBoostRegressor, CatBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn import tree
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, roc_auc_score, roc_curve
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans
from sklearn.pipeline import Pipeline
from sklearn.manifold import Isomap,TSNE
from sklearn.feature_selection import mutual_info_classif
from tqdm.notebook import tqdm
from scipy.stats import ttest_ind
import plotly.offline as pyo
import scipy.stats as stats
import pymc3 as pm
from dataprep.eda import *
from dataprep.eda import plot
from dataprep.eda import plot_diff
from dataprep.eda import plot_correlation
from dataprep.eda import plot_missing
import plotly.figure_factory as ff
from collections import Counter
import pandas_profiling as pp
from mpl_toolkits.basemap import Basemap
import datetime as dt
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import folium
from folium import plugins

# %% [markdown]
# ### MAIN READING

# %%
GREECE_MAIN = pd.read_csv("../input/2000-2021-tunisiaisraelgreeceitaly-nasa/2000_2021_PICK_COUNTRIES/GREECE_2000_2021 - fire_archive_M-C61_214279.csv",low_memory=False)
ISRAEL_MAIN = pd.read_csv("../input/2000-2021-tunisiaisraelgreeceitaly-nasa/2000_2021_PICK_COUNTRIES/ISRAEL_2000_2021 - fire_archive_M-C61_214285.csv",low_memory=False)
ITALY_MAIN = pd.read_csv("../input/2000-2021-tunisiaisraelgreeceitaly-nasa/2000_2021_PICK_COUNTRIES/ITALY_2000_2021 - fire_archive_M-C61_214280.csv",low_memory=False)
TUNISIA_MAIN = pd.read_csv("../input/2000-2021-tunisiaisraelgreeceitaly-nasa/2000_2021_PICK_COUNTRIES/TUNISIA_2000_2021_M-C61_214281.csv",low_memory=False)

# %%
GREECE_MAIN.fillna(0,inplace=True)
ISRAEL_MAIN.fillna(0,inplace=True)
ITALY_MAIN.fillna(0,inplace=True)
TUNISIA_MAIN.fillna(0,inplace=True)

# %%
GREECE_MAIN

# %%
ISRAEL_MAIN

# %%
ITALY_MAIN

# %%
TUNISIA_MAIN

# %%
ZERO_GREECE = GREECE_MAIN[GREECE_MAIN["type"] == 0]
ZERO_GREECE.sort_values(by=["acq_date"],inplace=True)
ZERO_GREECE.reset_index(drop=True,inplace=True)

ZERO_ISRAEL = ISRAEL_MAIN[ISRAEL_MAIN["type"] == 0]
ZERO_ISRAEL.sort_values(by=["acq_date"],inplace=True)
ZERO_ISRAEL.reset_index(drop=True,inplace=True)

ZERO_ITALY = ITALY_MAIN[ITALY_MAIN["type"] == 0]
ZERO_ITALY.sort_values(by=["acq_date"],inplace=True)
ZERO_ITALY.reset_index(drop=True,inplace=True)

ZERO_TUNISIA = TUNISIA_MAIN[TUNISIA_MAIN["type"] == 0]
ZERO_TUNISIA.sort_values(by=["acq_date"],inplace=True)
ZERO_TUNISIA.reset_index(drop=True,inplace=True)

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=ZERO_GREECE["acq_date"],y=ZERO_GREECE["bright_t31"],title="DATE-KELVIN")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=ZERO_ISRAEL["acq_date"],y=ZERO_ISRAEL["bright_t31"],title="DATE-KELVIN")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=ZERO_ITALY["acq_date"],y=ZERO_ITALY["bright_t31"],title="DATE-KELVIN")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=ZERO_TUNISIA["acq_date"],y=ZERO_TUNISIA["bright_t31"],title="DATE-KELVIN")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=ZERO_GREECE["acq_date"],y=ZERO_GREECE["frp"],title="DATE-FRP")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=ZERO_ISRAEL["acq_date"],y=ZERO_ISRAEL["frp"],title="DATE-FRP")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=ZERO_ITALY["acq_date"],y=ZERO_ITALY["frp"],title="DATE-FRP")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=ZERO_TUNISIA["acq_date"],y=ZERO_TUNISIA["frp"],title="DATE-FRP")
fig_plot.show()

# %% [markdown]
# ### SPECIAL DAYS FOR COUNTRIES BASED ON KELVIN

# %% [markdown]
# #### GREECE

# %%
AUG_26_2002_GREECE = ZERO_GREECE[ZERO_GREECE["acq_date"] == "2002-08-26"]

AUG_26_2002_GREECE.sort_values(by=["acq_time"],inplace=True)
AUG_26_2002_GREECE.reset_index(drop=True,inplace=True)

# %%
JUN_28_2007_GREECE = ZERO_GREECE[ZERO_GREECE["acq_date"] == "2007-06-28"]

JUN_28_2007_GREECE.sort_values(by=["acq_time"],inplace=True)
JUN_28_2007_GREECE.reset_index(drop=True,inplace=True)

# %%
JUL_16_2007_GREECE = ZERO_GREECE[ZERO_GREECE["acq_date"] == "2007-07-16"]

JUL_16_2007_GREECE.sort_values(by=["acq_time"],inplace=True)
JUL_16_2007_GREECE.reset_index(drop=True,inplace=True)

# %%
AUG_24_2007_GREECE = ZERO_GREECE[ZERO_GREECE["acq_date"] == "2007-08-24"]

AUG_24_2007_GREECE.sort_values(by=["acq_time"],inplace=True)
AUG_24_2007_GREECE.reset_index(drop=True,inplace=True)

# %%
AUG_25_2007_GREECE = ZERO_GREECE[ZERO_GREECE["acq_date"] == "2007-08-25"]

AUG_25_2007_GREECE.sort_values(by=["acq_time"],inplace=True)
AUG_25_2007_GREECE.reset_index(drop=True,inplace=True)

# %%
AUG_26_2007_GREECE = ZERO_GREECE[ZERO_GREECE["acq_date"] == "2007-08-26"]

AUG_26_2007_GREECE.sort_values(by=["acq_time"],inplace=True)
AUG_26_2007_GREECE.reset_index(drop=True,inplace=True)

# %%
AUG_22_2009_GREECE = ZERO_GREECE[ZERO_GREECE["acq_date"] == "2009-08-22"]

AUG_22_2009_GREECE.sort_values(by=["acq_time"],inplace=True)
AUG_22_2009_GREECE.reset_index(drop=True,inplace=True)

# %%
JUL_17_2010_GREECE = ZERO_GREECE[ZERO_GREECE["acq_date"] == "2010-07-17"]

JUL_17_2010_GREECE.sort_values(by=["acq_time"],inplace=True)
JUL_17_2010_GREECE.reset_index(drop=True,inplace=True)

# %%
AUG_28_2012_GREECE = ZERO_GREECE[ZERO_GREECE["acq_date"] == "2012-08-28"]

AUG_28_2012_GREECE.sort_values(by=["acq_time"],inplace=True)
AUG_28_2012_GREECE.reset_index(drop=True,inplace=True)

# %%
AUG_30_2015_GREECE = ZERO_GREECE[ZERO_GREECE["acq_date"] == "2015-08-30"]

AUG_30_2015_GREECE.sort_values(by=["acq_time"],inplace=True)
AUG_30_2015_GREECE.reset_index(drop=True,inplace=True)

# %%
JUN_18_2016_GREECE = ZERO_GREECE[ZERO_GREECE["acq_date"] == "2016-06-18"]

JUN_18_2016_GREECE.sort_values(by=["acq_time"],inplace=True)
JUN_18_2016_GREECE.reset_index(drop=True,inplace=True)

# %%
AUG_05_2017_GREECE = ZERO_GREECE[ZERO_GREECE["acq_date"] == "2017-08-05"]

AUG_05_2017_GREECE.sort_values(by=["acq_time"],inplace=True)
AUG_05_2017_GREECE.reset_index(drop=True,inplace=True)

# %%
JUL_24_2020_GREECE = ZERO_GREECE[ZERO_GREECE["acq_date"] == "2020-07-24"]

JUL_24_2020_GREECE.sort_values(by=["acq_time"],inplace=True)
JUL_24_2020_GREECE.reset_index(drop=True,inplace=True)

# %%
JUL_02_2021_GREECE = ZERO_GREECE[ZERO_GREECE["acq_date"] == "2021-07-02"]

JUL_02_2021_GREECE.sort_values(by=["acq_time"],inplace=True)
JUL_02_2021_GREECE.reset_index(drop=True,inplace=True)

# %%
AUG_03_2021_GREECE = ZERO_GREECE[ZERO_GREECE["acq_date"] == "2021-08-03"]

AUG_03_2021_GREECE.sort_values(by=["acq_time"],inplace=True)
AUG_03_2021_GREECE.reset_index(drop=True,inplace=True)

# %%
AUG_05_2021_GREECE = ZERO_GREECE[ZERO_GREECE["acq_date"] == "2021-08-05"]

AUG_05_2021_GREECE.sort_values(by=["acq_time"],inplace=True)
AUG_05_2021_GREECE.reset_index(drop=True,inplace=True)

# %%
AUG_10_2021_GREECE = ZERO_GREECE[ZERO_GREECE["acq_date"] == "2021-08-10"]

AUG_10_2021_GREECE.sort_values(by=["acq_time"],inplace=True)
AUG_10_2021_GREECE.reset_index(drop=True,inplace=True)

# %% [markdown]
# #### ISRAEL

# %%
APR_29_2013_ISRAEL = ZERO_ISRAEL[ZERO_ISRAEL["acq_date"] == "2013-04-29"]

APR_29_2013_ISRAEL.sort_values(by=["acq_time"],inplace=True)
APR_29_2013_ISRAEL.reset_index(drop=True,inplace=True)

# %% [markdown]
# #### ITALY

# %%
SEP_25_2003_ITALY = ZERO_ITALY[ZERO_ITALY["acq_date"] == "2003-09-25"]

SEP_25_2003_ITALY.sort_values(by=["acq_time"],inplace=True)
SEP_25_2003_ITALY.reset_index(drop=True,inplace=True)

# %%
JUL_24_2007_ITALY = ZERO_ITALY[ZERO_ITALY["acq_date"] == "2007-07-24"]

JUL_24_2007_ITALY.sort_values(by=["acq_time"],inplace=True)
JUL_24_2007_ITALY.reset_index(drop=True,inplace=True)

# %%
JUL_23_2009_ITALY = ZERO_ITALY[ZERO_ITALY["acq_date"] == "2009-07-23"]

JUL_23_2009_ITALY.sort_values(by=["acq_time"],inplace=True)
JUL_23_2009_ITALY.reset_index(drop=True,inplace=True)

# %% [markdown]
# #### TUNISIA

# %%
AUG_04_2017_TUNISIA = ZERO_TUNISIA[ZERO_TUNISIA["acq_date"] == "2017-08-04"]

AUG_04_2017_TUNISIA.sort_values(by=["acq_time"],inplace=True)
AUG_04_2017_TUNISIA.reset_index(drop=True,inplace=True)

# %% [markdown]
# ### PLOT KELVIN

# %% [markdown]
# #### GREECE

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=AUG_26_2002_GREECE["acq_time"],y=AUG_26_2002_GREECE["bright_t31"],title="DATE-KELVIN/AUG_26_2002_GREECE")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=JUN_28_2007_GREECE["acq_time"],y=JUN_28_2007_GREECE["bright_t31"],title="DATE-KELVIN/JUN_28_2007_GREECE")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=JUL_16_2007_GREECE["acq_time"],y=JUL_16_2007_GREECE["bright_t31"],title="DATE-KELVIN/JUL_16_2007_GREECE")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=AUG_24_2007_GREECE["acq_time"],y=AUG_24_2007_GREECE["bright_t31"],title="DATE-KELVIN/AUG_24_2007_GREECE")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=AUG_25_2007_GREECE["acq_time"],y=AUG_25_2007_GREECE["bright_t31"],title="DATE-KELVIN/AUG_25_2007_GREECE")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=AUG_26_2007_GREECE["acq_time"],y=AUG_26_2007_GREECE["bright_t31"],title="DATE-KELVIN/AUG_26_2007_GREECE")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=AUG_22_2009_GREECE["acq_time"],y=AUG_22_2009_GREECE["bright_t31"],title="DATE-KELVIN/AUG_22_2009_GREECE")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=JUL_17_2010_GREECE["acq_time"],y=JUL_17_2010_GREECE["bright_t31"],title="DATE-KELVIN/JUL_17_2010_GREECE")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=AUG_28_2012_GREECE["acq_time"],y=AUG_28_2012_GREECE["bright_t31"],title="DATE-KELVIN/AUG_28_2012_GREECE")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=AUG_30_2015_GREECE["acq_time"],y=AUG_30_2015_GREECE["bright_t31"],title="DATE-KELVIN/AUG_30_2015_GREECE")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=JUN_18_2016_GREECE["acq_time"],y=JUN_18_2016_GREECE["bright_t31"],title="DATE-KELVIN/JUN_18_2016_GREECE")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=AUG_05_2017_GREECE["acq_time"],y=AUG_05_2017_GREECE["bright_t31"],title="DATE-KELVIN/AUG_05_2017_GREECE")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=JUL_24_2020_GREECE["acq_time"],y=JUL_24_2020_GREECE["bright_t31"],title="DATE-KELVIN/JUL_24_2020_GREECE")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=JUL_02_2021_GREECE["acq_time"],y=JUL_02_2021_GREECE["bright_t31"],title="DATE-KELVIN/JUL_02_2021_GREECE")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=AUG_03_2021_GREECE["acq_time"],y=AUG_03_2021_GREECE["bright_t31"],title="DATE-KELVIN/AUG_03_2021_GREECE")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=AUG_05_2021_GREECE["acq_time"],y=AUG_05_2021_GREECE["bright_t31"],title="DATE-KELVIN/AUG_05_2021_GREECE")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=AUG_10_2021_GREECE["acq_time"],y=AUG_10_2021_GREECE["bright_t31"],title="DATE-KELVIN/AUG_10_2021_GREECE")
fig_plot.show()

# %% [markdown]
# #### ITALY

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=SEP_25_2003_ITALY["acq_time"],y=SEP_25_2003_ITALY["bright_t31"],title="DATE-KELVIN/SEP_25_2003_ITALY")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=JUL_24_2007_ITALY["acq_time"],y=JUL_24_2007_ITALY["bright_t31"],title="DATE-KELVIN/JUL_24_2007_ITALY")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=JUL_23_2009_ITALY["acq_time"],y=JUL_23_2009_ITALY["bright_t31"],title="DATE-KELVIN/JUL_23_2009_ITALY")
fig_plot.show()

# %% [markdown]
# #### ISRAEL

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=APR_29_2013_ISRAEL["acq_time"],y=APR_29_2013_ISRAEL["bright_t31"],title="DATE-KELVIN/APR_29_2013_ISRAEL")
fig_plot.show()

# %% [markdown]
# #### TUNISIA

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=AUG_04_2017_TUNISIA["acq_time"],y=AUG_04_2017_TUNISIA["bright_t31"],title="DATE-KELVIN/AUG_04_2017_TUNISIA")
fig_plot.show()

# %% [markdown]
# ### PLOT FRP-BRIGHTNESS

# %% [markdown]
# #### GREECE

# %%
GREECE_DATE_LIST = [AUG_26_2002_GREECE,JUN_28_2007_GREECE,JUL_16_2007_GREECE,AUG_24_2007_GREECE,
                    AUG_25_2007_GREECE,AUG_26_2007_GREECE,AUG_22_2009_GREECE,JUL_17_2010_GREECE,
                    AUG_28_2012_GREECE,AUG_30_2015_GREECE,JUN_18_2016_GREECE,AUG_05_2017_GREECE,
                    JUL_24_2020_GREECE,JUL_02_2021_GREECE,AUG_03_2021_GREECE,AUG_05_2021_GREECE,
                    AUG_10_2021_GREECE]

# %%
for x_greece_date in GREECE_DATE_LIST:
    figure = plt.figure(figsize=(20,7))
    fig_plot = px.line(x=x_greece_date["acq_time"],y=x_greece_date["frp"],title="DATE-FRP")
    fig_plot.show()
    plt.show()

# %%
for x_greece_date in GREECE_DATE_LIST:
    figure = plt.figure(figsize=(20,7))
    fig_plot = px.line(x=x_greece_date["acq_time"],y=x_greece_date["brightness"],title="DATE-BRIGHTNESS")
    fig_plot.show()
    plt.show()

# %% [markdown]
# #### ITALY

# %%
ITALY_DATE_LIST = [SEP_25_2003_ITALY,JUL_24_2007_ITALY,JUL_23_2009_ITALY]

# %%
for x_italy_date in ITALY_DATE_LIST:
    figure = plt.figure(figsize=(20,7))
    fig_plot = px.line(x=x_italy_date["acq_time"],y=x_italy_date["frp"],title="DATE-FRP")
    fig_plot.show()
    plt.show()

# %%
for x_italy_date in ITALY_DATE_LIST:
    figure = plt.figure(figsize=(20,7))
    fig_plot = px.line(x=x_italy_date["acq_time"],y=x_italy_date["brightness"],title="DATE-BRIGHTNESS")
    fig_plot.show()
    plt.show()

# %% [markdown]
# #### ISRAEL

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=APR_29_2013_ISRAEL["acq_time"],y=APR_29_2013_ISRAEL["frp"],title="DATE-FRP")
fig_plot.show()

# %% [markdown]
# #### TUNISIA

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=AUG_04_2017_TUNISIA["acq_time"],y=AUG_04_2017_TUNISIA["frp"],title="DATE-FRP")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=AUG_04_2017_TUNISIA["acq_time"],y=AUG_04_2017_TUNISIA["brightness"],title="DATE-BRIGHTNESS")
fig_plot.show()

# %% [markdown]
# ### INFORMATION FOR GREECE

# %%
for x_greece_date in GREECE_DATE_LIST:
    print(x_greece_date.describe().T)
    print("----"*10)
    print("\n")

# %%
for x_greece_date in GREECE_DATE_LIST:
    print(x_greece_date["bright_t31"].mean())
    print("----"*10)
    print("\n")

# %%
for x_greece_date in GREECE_DATE_LIST:
    print(x_greece_date["frp"].mean())
    print("----"*10)
    print("\n")

# %%
for x_greece_date in GREECE_DATE_LIST:
    print(x_greece_date["brightness"].mean())
    print("----"*10)
    print("\n")

# %% [markdown]
# ### 2021 TYPE ZERO ANALYSIS FOR COUNTRIES

# %% [markdown]
# #### GREECE

# %%
GREECE_2021 = ZERO_GREECE[-2047:-1]

GREECE_2021.sort_values(by=["acq_date"],inplace=True)
GREECE_2021.reset_index(drop=True,inplace=True)

GREECE_2021

# %% [markdown]
# #### ITALY

# %%
ITALY_2021 = ZERO_ITALY[-4196:-1]

ITALY_2021.sort_values(by=["acq_date"],inplace=True)
ITALY_2021.reset_index(drop=True,inplace=True)

ITALY_2021

# %% [markdown]
# #### TUNISIA

# %%
TUNISIA_2021 = ZERO_TUNISIA[-435:-1]

TUNISIA_2021.sort_values(by=["acq_date"],inplace=True)
TUNISIA_2021.reset_index(drop=True,inplace=True)

TUNISIA_2021

# %% [markdown]
# #### ISRAEL

# %%
ISRAEL_2021 = ZERO_ISRAEL[-101:-1]

ISRAEL_2021.sort_values(by=["acq_date"],inplace=True)
ISRAEL_2021.reset_index(drop=True,inplace=True)

ISRAEL_2021

# %% [markdown]
# ### PLOT COMPARING FOR 2021

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=GREECE_2021["acq_date"],y=GREECE_2021["bright_t31"],title="DATE-KELVIN/GREECE")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=ITALY_2021["acq_date"],y=ITALY_2021["bright_t31"],title="DATE-KELVIN/ITALY")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=TUNISIA_2021["acq_date"],y=TUNISIA_2021["bright_t31"],title="DATE-KELVIN/TUNISIA")
fig_plot.show()

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=ISRAEL_2021["acq_date"],y=ISRAEL_2021["bright_t31"],title="DATE-KELVIN/ISRAEL")
fig_plot.show()

# %% [markdown]
# ### TURKEY 2021

# %%
READING_TURKEY_CSV = pd.read_csv("../input/20002021-turkey-fire-points-single-csv-nasa/2000-2021 SINGLE TURKEY FIRE_M-C61_214067.csv",low_memory=False)

# %%
READING_TURKEY_CSV.fillna(0,inplace=True)

# %%
READING_TURKEY_CSV

# %%
ZERO_TURKEY = READING_TURKEY_CSV[READING_TURKEY_CSV["type"] == 0]

ZERO_TURKEY.sort_values(by=["acq_date"],inplace=True)
ZERO_TURKEY.reset_index(drop=True,inplace=True)

ZERO_TURKEY

# %%
TURKEY_2021 = ZERO_TURKEY[-6228:-1]

TURKEY_2021.sort_values(by=["acq_date"],inplace=True)
TURKEY_2021.reset_index(drop=True,inplace=True)

TURKEY_2021

# %%
figure = plt.figure(figsize=(20,7))
fig_plot = px.line(x=TURKEY_2021["acq_date"],y=TURKEY_2021["bright_t31"],title="DATE-KELVIN/TURKEY")
fig_plot.show()
