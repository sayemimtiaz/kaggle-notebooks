# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from pandas import DataFrame
import matplotlib.pyplot as plt

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
filename = "/kaggle/input/covid19-data-from-john-hopkins-university/CONVENIENT_global_confirmed_cases.csv"
df = pd.read_csv(filename).drop([0]).rename(columns={"Country/Region": "Date"})
df.head()

# %%
HF_file = "/kaggle/input/human-freedom-index-2019/human-freedom-index-2019.csv"
df2 = pd.read_csv(HF_file)
df2 = df2.loc[df2['year'] == 2017]
df2

# %%
hf_asc = df2[["countries", "hf_score"]].sort_values(by=["hf_score"])
hf_asc.head(10)

# %%
# Graph for Syria
graph = DataFrame(df[["Date", "Syria"]],columns=['Date','Syria'])
graph.plot(x='Date', y='Syria', kind='line')
plt.show()

# %%
# Graph for Venezuela
graph = DataFrame(df[["Date", "Venezuela"]],columns=['Date','Venezuela'])
graph.plot(x='Date', y='Venezuela', kind='line')
plt.show()

# %%
# Graph for Yemen
graph = DataFrame(df[["Date", "Yemen"]],columns=['Date','Yemen'])
graph.plot(x='Date', y='Yemen', kind='line')
plt.show()

# %%
# Graph for Sudan
graph = DataFrame(df[["Date", "Sudan"]],columns=['Date','Sudan'])
graph.plot(x='Date', y='Sudan', kind='line')
plt.show()

# %%
hf_desc = df2[["countries", "hf_score"]].sort_values(by=["hf_score"], ascending=False)
hf_desc.head(10)

# %%
# Graph for New Zealand
graph = DataFrame(df[["Date", "New Zealand"]],columns=['Date','New Zealand'])
graph.plot(x='Date', y='New Zealand', kind='line')
plt.show()

# %%
# Graph for Switzerland
graph = DataFrame(df[["Date", "Switzerland"]],columns=['Date','Switzerland'])
graph.plot(x='Date', y='Switzerland', kind='line')
plt.show()

# %%
# Graph for Germany
graph = DataFrame(df[["Date", "Germany"]],columns=['Date','Germany'])
graph.plot(x='Date', y='Germany', kind='line')
plt.show()

# %%
# Graph for Ireland
graph = DataFrame(df[["Date", "Ireland"]],columns=['Date','Ireland'])
graph.plot(x='Date', y='Ireland', kind='line')
plt.show()
