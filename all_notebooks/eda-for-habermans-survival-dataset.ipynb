# %% [markdown]
# **Exploratory data analysis (EDA) for habermans survival dataset**

# %% [markdown]
# **Objective: Is to  predict whether the patient will  died within 5 year after operation or will the patient survived 5 years or longer**

# %% [markdown]
# ****Required packages:****

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
#Load haberman.csv into a pandas dataFrame
feaures_name = ['age','year','axil_nodes','Surv_status']
df = pd.read_csv('../input/haberman.csv',names=feaures_name)

#Verify the data that has been loaded
df.head(12)

# %% [markdown]
# ****Make Target Feature Meaningful ****

# %%
#print the unique values of the target column

print(df['Surv_status'].unique())

# %%
df.Surv_status.replace([1, 2], ['Survived', 'Not Survived'], inplace = True)
df.head(12)

# %%
# number of data-points and features?
print (df.shape)

# %% [markdown]
# ****Observations :****
# *  Number of data-points (instances) are 306
# *  Number of features are 4

# %%
#data points for each class (label)
print(df['Surv_status'].value_counts())

# %% [markdown]
# ****Observations :****
# Because the number of survived label is greater than not survived label, the habermans survival dataset is imbalanced

# %%
#scatter plot for age and year
sb.set_style("whitegrid");
sb.FacetGrid(df, hue="Surv_status", size=4) \
   .map(plt.scatter, "age", "year") \
   .add_legend();
plt.show();

# %% [markdown]
# ****Observations :****
# The Survived and Not Survived labels can not be separated linearly using age and year features

# %%
#scatter plot for age and axil_nodes
sb.set_style("whitegrid");
sb.FacetGrid(df, hue="Surv_status", size=4) \
   .map(plt.scatter, "age", "axil_nodes") \
   .add_legend();
plt.show();

# %% [markdown]
# ****Observations :****
# The Survived and Not Survived labels can not be separated linearly using age and axil_nodes features

# %%
#scatter plot for year and axil_nodes
sb.set_style("whitegrid");
sb.FacetGrid(df, hue="Surv_status", size=4) \
   .map(plt.scatter, "year", "axil_nodes") \
   .add_legend();
plt.show();

# %% [markdown]
# ****Observations :****
# The Survived and Not Survived labels can not be separated linearly using year and axil_nodes features

# %%
#pair plot
plt.close();
sb.set_style("whitegrid");
sb.pairplot(df, hue="Surv_status", size=3);
plt.show()

# %%
#Probability Density Functions (PDF) for age
survived = df.loc[df["Surv_status"] == "Survived"];
not_survived = df.loc[df["Surv_status"] == "Not Survived"];

sb.FacetGrid(df, hue="Surv_status", size=5) \
   .map(sb.distplot, "age") \
   .add_legend();
plt.show();

# %%
#Probability Density Functions (PDF) for year
sb.FacetGrid(df, hue="Surv_status", size=5) \
   .map(sb.distplot, "year") \
   .add_legend();
plt.show();

# %%
#Probability Density Functions (PDF) for axil_nodes 
sb.FacetGrid(df, hue="Surv_status", size=5) \
   .map(sb.distplot, "axil_nodes") \
   .add_legend();
plt.show();

# %% [markdown]
#  ****Univariant analysis using Probability Density Functions (PDF), Cumulative Distribution Function (CDF)****

# %%
counts, bin_edges = np.histogram(survived['age'], bins=10, 
                                 density = True)

pdf = counts/(sum(counts))
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf,label='survived pdf')
plt.plot(bin_edges[1:], cdf,label='survived cdf')
plt.legend()

counts, bin_edges = np.histogram(not_survived['age'], bins=10, 
                                 density = True)

pdf = counts/(sum(counts))
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf,label='not survived pdf')
plt.plot(bin_edges[1:], cdf,label='not survived cdf')
plt.legend()

plt.xlabel("age")
plt.show()

# %%
counts, bin_edges = np.histogram(survived['year'], bins=10, 
                                 density = True)

pdf = counts/(sum(counts))
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf,label='survived pdf')
plt.plot(bin_edges[1:], cdf,label='survived cdf')
plt.legend()

counts, bin_edges = np.histogram(not_survived['year'], bins=10, 
                                 density = True)

pdf = counts/(sum(counts))
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf,label='not survived pdf')
plt.plot(bin_edges[1:], cdf,label='not survived cdf')
plt.legend()

plt.xlabel("year")
plt.show()

# %%
counts, bin_edges = np.histogram(survived['axil_nodes'], bins=10, 
                                 density = True)

pdf = counts/(sum(counts))
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf,label='survived pdf')
plt.plot(bin_edges[1:], cdf,label='survived cdf')
plt.legend()

counts, bin_edges = np.histogram(not_survived['axil_nodes'], bins=10, 
                                 density = True)

pdf = counts/(sum(counts))
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf,label='not survived pdf')
plt.plot(bin_edges[1:], cdf,label='not survived cdf')
plt.legend()

plt.xlabel("axil_nodes")
plt.show()

# %% [markdown]
#  ****Univariant analysis using  Whiskers plots****

# %%
sb.boxplot(x='Surv_status',y='age', data=df)
plt.show()

# %%
sb.boxplot(x='Surv_status',y='year', data=df)
plt.show()

# %%
sb.boxplot(x='Surv_status',y='axil_nodes', data=df)
plt.show()

# %% [markdown]
#  **Univariant analysis using Violin plots :**

# %%
sb.violinplot(x="Surv_status", y="age", data=df, size=8)
plt.show()

# %%
sb.violinplot(x="Surv_status", y="year", data=df, size=8)
plt.show()

# %%
sb.violinplot(x="Surv_status", y="axil_nodes", data=df, size=8)
plt.show()

# %% [markdown]
# ****Observations: ****
# All above univariant analysis using Probability Density Functions (PDF), Cumulative Distribution Function (CDF) , Whiskers plots, and Violin plots show that the survived and not survived can be discriminated using axil_nodes
