# %%
# %config Completer.use_jedi = False
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
pathTrain = "/kaggle/input/house-price-prediction-challenge-machine-hack/Train.csv"
pathTest = "/kaggle/input/house-price-prediction-challenge-machine-hack/Test.csv"
trdf = pd.read_csv(pathTrain)
ttdf = pd.read_csv(pathTest)

# %%
trdf.columns

# %%
trdf.head()

# %%
trdf.count()

# %%
trdf.info()

# %%
trdf.describe()

# %% [markdown]
# # Separate numerical columns

# %%
subDF = trdf.select_dtypes(["int64","float64"])

# %% [markdown]
# # finding minimum maximum sum average and count of numerical columns

# %%
subDF.min()

# %%
subDF.max()

# %%
subDF.sum()

# %%
subDF.mean()

# %%
subDF.count()

# %% [markdown]
# # finding standard deviation kurtosis skewness standard error mode median of numerical columns.¶

# %%
subDF.skew()

# %%
subDF.kurt()

# %%
subDF.std()

# %%
# fiding the standard error
subDF.sem()

# %%
subDF.median()

# %%
subDF.mode()

# %% [markdown]
# # execute the code for navigating data frames.

# %%
# showing any three columns using iloc
trdf.iloc[:,:3]

# %%
# selecting any columns using iloc
trdf.iloc[:,[0,3,5]]

# %%
# selecting column range as index using loc
trdf.loc[:,"UNDER_CONSTRUCTION":"SQUARE_FT"]

# %% [markdown]
# # Renaming columns

# %%
trdf.rename(columns={'UNDER_CONSTRUCTION': 'ConstProgress' , "LATITUDE":"LAT" }).head(10)

# %% [markdown]
# # select the rows based on different conditions. (5 different conditions of your choice)

# %%
trdf[trdf.UNDER_CONSTRUCTION == 1]

# %%
trdf[trdf.READY_TO_MOVE !=0]

# %%
trdf[(trdf.READY_TO_MOVE !=0) & (trdf.POSTED_BY == "Dealer")]

# %%
trdf[(trdf.SQUARE_FT <896)]

# %%
trdf[trdf.SQUARE_FT.isna()]

# %% [markdown]
# # replacing values of data with new values (5 replacements of your choice)

# %%
# To have full functionality with NaN we need to import the NumPy library first:

trdf['SQUARE_FT'] = trdf['SQUARE_FT'].replace(trdf.SQUARE_FT.mean(), np.nan)

# %%
# Applying a Function Over All Elements in a Column¶
def lowcase(x):
    return x.lower()
# Apply function, show two rows
trdf['ADDRESS'].apply(lowcase)[0:4]

# %%
trdf.replace(1, "One").head(10)

# %%
trdf.replace(0, "Zero").head(10)

# %%
trdf.replace(['Owner', 'Dealer', 'Builder'],[0,1,2]).head(10)
