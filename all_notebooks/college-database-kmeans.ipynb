# %% [markdown]
# # K Means Clustering
# It is one of the unsupervised techinques, i.e, the result is not known to us. We try to combine the data in such a way that fimilar data points form one set/ cluster.

# %% [markdown]
# # Context
# Statistics for a large number of US Colleges from the 1995 issue of US News and World Report.
# # [Content](https://www.kaggle.com/flyingwombat/us-news-and-world-reports-college-data)
#
# * Private A factor with levels No and Yes indicating private or public university.
#
# Which is already given and will not be considered in the beginning of the project.

# %%
## Importing the required Libraries
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
## Reading the Data into the enviroment
df = pd.read_csv('../input/us-news-and-world-reports-college-data/College.csv', 
                 index_col=0)
# Making column 1 as index

# %%
## Previewing the data
df.head()

# %%
## Information regarding the data base
df.info()

# %%
## For further ananlysis
df.describe()

# %% [markdown]
# # Exploratory Data Analysis(E.D.A.)
# Data Visualizations
#
# Room.Board where the points are colored by the Private column.

# %%
## Room board and Grad Rate as per Private colleges
sns.lmplot(x= 'Room.Board',y='Grad.Rate',data=df, hue='Private',
           fit_reg=False,palette='coolwarm',size=6,aspect=1)

# %% [markdown]
# **Outstate where the points are colored by the Private column.**

# %%
## Outstate and Undergrad with Private
sns.lmplot(x= 'Outstate',y='F.Undergrad',data=df, hue='Private',
           palette='coolwarm',size=6,aspect=1,fit_reg=False)

# %%
## Outstate based on the Private Column
g = sns.FacetGrid(df, hue = 'Private', palette = 'coolwarm',
                 size = 6, aspect = 2)
g = g.map(plt.hist,'Outstate',bins = 25, alpha = 0.6)

# %%
## Outstate based on the Private Column
g = sns.FacetGrid(df, hue = 'Private', palette = 'coolwarm',
                 size = 6, aspect = 2)
g = g.map(plt.hist,'Grad.Rate',bins = 25, alpha = 0.6)
# Do notice we have an outlier of 120 in Grad.Rate Column
# As grad rate cannot be more than 100

# %%
## Checking which data point is having Grad.Rate more than 100
df[df['Grad.Rate']>100]
# We need to change that from 118% to 100%

# %%
## Changing the Grad.Rate to 100
df['Grad.Rate']['Cazenovia College'] = 100
# It may give you a warning but no error

# %%
## Checking if data point is having Grad.Rate more than 100 is replaced or not
df[df['Grad.Rate']>100]

# %% [markdown]
# # K-Means Classifier
# An unsupervised learning algorithm which either combines or seperates two data points on the basics of distance.

# %%
## calling the kmeans from sklearn
from sklearn.cluster import KMeans

# %%
## Giving no of cluster as  we already know 
## The outcome have only two catogeries
kmeans = KMeans(n_clusters=2)

# %% [markdown]
# As you can see our Data set contain Private column in advance, we need to drop it before/ while fitting the model

# %%
## Fitting the model on whole data
## As it is supervised learning with no target splitting is unnecessary
kmeans.fit(df.drop('Private',axis=1))

# %%
## Cluster centers
kmeans.cluster_centers_

# %% [markdown]
# **Convert Count Function:**
#
# The Private column is a catogerical column we need to convert it into numerical column.There are several ways to do the following.
#
# we are going to define a function to return 1 & 0

# %%
## Convert Count Function:
def converter(private):
    if private=='Yes':
        return 1
    else:
        return 0

# %%
## Applying the convert count function to our Private column &
## Creating Cluster column
df['Cluster'] = df['Private'].apply(converter)

# %%
## Checking the dataframe
df.head()

# %% [markdown]
# # Accuracy
#
# We cannot check the accuracy of a unsupervised machine learning, but in our case we do have outcome to check how our model performed.
#
# Let's Check how our Model performed.

# %%
## Confusion Matrix & Classification report
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(df['Cluster'],kmeans.labels_))
print(classification_report(df['Cluster'],kmeans.labels_))

# %% [markdown]
# # Conclusion
# As you can see our model didn't perform that well, but again this is unsupervised learning so the results did not matter.
#
# If you Like my Work
#
# Please UPVOTE 💥
# & check out my other work on [Kaggle](https://www.kaggle.com/adarshsambare/notebooks)
