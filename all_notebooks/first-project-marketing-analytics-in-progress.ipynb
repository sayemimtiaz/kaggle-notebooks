# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # **Getting to know our dataset**

# %% [markdown]
# Let's read our csv and create a dataframe using pandas.
# Then, print the first 10 rows of the dataframe.

# %%
path="/kaggle/input/marketing-data/marketing_data.csv"
df=pd.read_csv(path)
df.head(10)

# %% [markdown]
# We should have a look before moving to the questions of the task.

# %%
df.dtypes

# %%
df.describe()

# %%
df.describe(include='object')

# %% [markdown]
# By getting a closer look to our data we already notice some problems.
# Column Income has a total of 2216 values and it's format is object possibly due to missing values.
# Column Dt_Customer has a format of object while it shoud be a date.
#
# Let´s start to answer the questions of the task.

# %% [markdown]
# ## **Section 01: Exploratory Data Analysis**
#
# *     Are there any null values or outliers? How will you wrangle/handle them?
# *     Are there any variables that warrant transformations?
# *     Are there any useful variables that you can engineer with the given data?
# *     Do you notice any patterns or anomalies in the data? Can you plot them?

# %% [markdown]
# Are there any null values or outliers? How will you wrangle/handle them?
#
# Firstly, we identify them.

# %%
missing_data=df.isnull()
missing_data.head()

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print(missing_data[column].value_counts())
    print("")

# %%
for col in df.columns:
    print(col)

# %%
df[' Income '].head()

# %% [markdown]
# That's it. So, we rename it. I don't like Dt_Customer either.

# %%
df=df.rename(columns={" Income ":"Income",
                   "Dt_Customer":"Date_of_Enrollment"})
df.head()

# %%
df['Income'].head()

# %% [markdown]
# We see that 24 observations of Income feature are null.
#
# Now we have to decide how are we going to deal with them.
#
# I choose to replace the missing values of Income feature using the mean function.

# %%
df['Income'] = df['Income'].str.replace('$', '')
df['Income'] = df['Income'].str.replace(',', '')
df['Income'].head()

# %%
avg_income=df['Income'].astype('float').mean()
print("The mean of Income column is:",avg_income)

# %% [markdown]
# Replace the empty values with the mean of column.

# %%
df["Income"].replace(np.nan,avg_income,inplace=True)

# %% [markdown]
# Then we check out.

# %%
missing_data2=df['Income'].isnull()
missing_data2.value_counts()

# %%
Seems we good.
