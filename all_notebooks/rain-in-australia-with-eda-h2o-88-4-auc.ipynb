# %% [markdown]
#  <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:LightSlateGray;
#            font-size:150%;
#            text-align:center;
#            letter-spacing:0.5px">
#
#      Welcome
# </div>

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            background-color:Beige;
#            font-size:110%;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#               color:black;">
#
# Hello Kagglers, <br>
#
# In this notebook, I am going to predict whether it is going to rain in australia. But, first I am going to do deal with missing values in the dataset and then perform exploratory data analysis and learn more about the features. Then, I am going to use H2O classification models on our dataset and select the best performing one. <br>
#     So, let's get started.
# </p>
# </div>

# %% [markdown]
# ### **Table of Contents:**
# 1. [Importing Libraries](#1)<a href='1' ></a> <br>
# 2. [Importing Dataset](#2)<a href='2' ></a> <br>
# 3. [Taking care of Missing Values](#3)<a href='3' ></a> <br>
#     3.1. [Visualizing Missing Values](#3.1)<a href='3.1' ></a> <br>
#     3.2. [Categorical Data](#3.2)<a href='3.2' ></a> <br>
#     3.3. [Numerical Data](#3.3)<a href='3.3' ></a> <br>
# 4. [Data Visualization and Analysis](#4)<a href='4' ></a> <br>
#     4.1. [Heat Map Correlation](#4.1)<a href='4.1' ></a> <br>
#     4.2. [Distribution Plot](#4.2)<a href='4.2' ></a> <br>
#     4.3. [Date Plot](#4.3)<a href='4.3' ></a> <br>
#     &nbsp;&nbsp;&nbsp;&nbsp; a. [MinTemp and MaxTemp](#4.3.1)<a href='4.3.1' ></a> <br>
#     &nbsp;&nbsp;&nbsp;&nbsp; b. [Rainfall](#4.3.2)<a href='4.3.2' ></a> <br>
#     &nbsp;&nbsp;&nbsp;&nbsp; c. [WindGustSpeed](#4.3.3)<a href='4.3.3' ></a> <br>
#     &nbsp;&nbsp;&nbsp;&nbsp; d. [WindSpeed9am and WindSpeed3pm](#4.3.4)<a href='4.3.4' ></a> <br>
#     &nbsp;&nbsp;&nbsp;&nbsp; e. [Humidity9am and Humidity3pm](#4.3.5)<a href='4.3.5' ></a> <br>
#     &nbsp;&nbsp;&nbsp;&nbsp; f. &nbsp;[Pressure9am and Pressure3am](#4.3.6)<a href='4.3.6' ></a> <br>
#     &nbsp;&nbsp;&nbsp;&nbsp; g. [Cloud9am and Cloud3am](#4.3.7)<a href='4.3.7' ></a> <br>
#     &nbsp;&nbsp;&nbsp;&nbsp; h. [Temp9am and Temp3pm](#4.3.8)<a href='4.3.8' ></a> <br>
#     4.4. [Outliers](#4.4)<a href='4.4' ></a> <br>
#     &nbsp;&nbsp;&nbsp;&nbsp; a. [Detection](#4.4.1)<a href='4.4.1' ></a> <br>
#     &nbsp;&nbsp;&nbsp;&nbsp; b. [Removal](#4.4.2)<a href='4.4.2' ></a> <br>
#     4.5. [Pair Plot](#4.5)<a href='4.5' ></a> <br>
# 5. [Data Preprocessing](#5)<a href='5' ></a> <br>
#     5.1. [Label Encoding](#5.1)<a href='5.1' ></a> <br>
#     5.2. [Splitting data into Train and Test Set](#5.2)<a href='5.2' ></a> <br>
#     5.3. [BorderlineSMOTE and RandomUnderSampler](#5.3)<a href='5.3' ></a> <br>
# 6. [H2O](#6)<a href='6' ></a> <br>
#     6.1. [H2OGeneralizedLinearEstimator](#6.1)<a href='6.1' ></a> <br>
#     6.2. [H2ORandomForestEstimator](#6.2)<a href='6.2' ></a> <br>
#     6.3. [H2OGradientBoostingEstimator](#6.3)<a href='6.3' ></a> <br>
#     6.4. [H2ODeepLearningEstimator](#6.4)<a href='6.4' ></a> <br>
#     6.5. [H2OStackedEnsembleEstimator](#6.5)<a href='6.5' ></a> <br>
# 7. [Conclusion](#7)<a href='7' ></a> <br>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:LightSlateGray;
#            font-size:150%;
#            text-align:center;
#             letter-spacing:0.5px"> <a id='1'></a>
#
#     Importing Libraries
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd

import seaborn as sns
sns.set_theme(style="darkgrid")

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:LightSlateGray;
#            font-size:150%;
#            text-align:center;
#            letter-spacing:0.5px"> <a id = '2'></a>
#
#     Importing Dataset
# </div>

# %%
dataset = pd.read_csv('/kaggle/input/weather-dataset-rattle-package/weatherAUS.csv')

# %%
dataset

# %%
dataset.info()

# %% [markdown]
# 📌 We have 145460 rows and 23 columns in our dataset. <br>
# 📌 We can see that the dataset contains mixture of *categorical* and *numerical* variables. <br>
# 📌 Also, there are some missing values in the dataset. Let's check it out.

# %%
dataset.isnull().sum()

# %% [markdown]
# 📌 Wow! There are lot of missing values in our dataset.

# %%
dataset.describe()

# %% [markdown]
# 📌 The above command *df.describe()* helps us to view the statistical properties of numerical variables. It excludes character variables.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:LightSlateGray;
#            font-size:150%;
#            text-align:center;
#            letter-spacing:0.5px"> <a id = '3'></a>
#
#     Taking care of Missing Values
# </div>

# %% [markdown]
# ## **Visualizing Missing Values** <a id='3.1' ></a>

# %%
import missingno as msno
msno.matrix(dataset)

# %%
msno.bar(dataset, sort= 'descending')

# %% [markdown]
# 📌 From the above plot, we can see that *Cloud9am*, *Cloud3pm*, *Evaporation*, and *Sunshine* have a lot of missing values.

# %% [markdown]
# 📌 Splitting our dataset in Categorical and Numerical values.

# %%
categorical = [i for i in dataset.columns if dataset[i].dtype=='object']
categorical

# %%
numerical = [i for i in dataset.columns if dataset[i].dtype=='float64']
numerical

# %%
dataset[categorical].isnull().sum()

# %% [markdown]
# ## **Categorical Data** <a id='3.2' ></a>

# %% [markdown]
# ### Date

# %% [markdown]
# 📌 Converting Date into datetime and then splitting it into Day, Month and Year columns.

# %%
dataset['Date'] = pd.to_datetime(dataset['Date'])

# %%
dataset['Day'] = dataset['Date'].dt.day
dataset.Day

# %%
dataset['Month'] = dataset['Date'].dt.month
dataset.Month

# %%
dataset['Year'] = dataset['Date'].dt.year
dataset.Year

# %%
dataset.head()

# %% [markdown]
# ### Location

# %% [markdown]
# 📌 There are no missing values in Location but let's visualize the unique values in it.

# %%
dataset.Location.unique()

# %%
dataset.Location.nunique()

# %% [markdown]
# 📌 We can see that the number of unique values in Location variable is 49.

# %%
dataset.Location.value_counts()

# %%
plt.style.use("classic")
sns.countplot(data=dataset, x="Location")
plt.grid(linewidth = 0.7)
plt.show()

# %% [markdown]
# ### WindGustDir

# %%
dataset.WindGustDir.unique()

# %% [markdown]
# 📌 We can see that the number of unique values in WindGustDir variable is 16 and NaN values.

# %%
dataset.WindGustDir.value_counts()

# %% [markdown]
# 📌 Replacing the missing values with the most frequent values.

# %%
dataset['WindGustDir'].fillna(dataset['WindGustDir'].mode()[0], inplace=True)

# %%
dataset.WindGustDir.isnull().sum()

# %%
plt.style.use("classic")
sns.countplot(data=dataset, x="WindGustDir")
plt.grid(linewidth = 0.7)
plt.show()

# %% [markdown]
# ### WindDir9am

# %%
dataset.WindDir9am.unique()

# %% [markdown]
# 📌 We can see that the number of unique values in WindDir9am variable is 16 and NaN values.

# %%
dataset.WindDir9am.value_counts()

# %% [markdown]
# 📌 Replacing the missing values with the most frequent values.

# %%
dataset['WindDir9am'].fillna(dataset['WindDir9am'].mode()[0], inplace=True)

# %%
dataset.WindDir9am.isnull().sum()

# %%
plt.style.use("classic")
sns.countplot(data=dataset, x="WindDir9am")
plt.grid(linewidth = 0.7)
plt.show()

# %% [markdown]
# ### WindDir3pm

# %%
dataset.WindDir3pm.unique()

# %% [markdown]
# 📌 We can see that the number of unique values in WindDir3pm variable is 16 and NaN values.

# %%
dataset.WindDir3pm.value_counts()

# %% [markdown]
# 📌 Replacing the missing values with the most frequent values.

# %%
dataset['WindDir3pm'].fillna(dataset['WindDir3pm'].mode()[0], inplace=True)

# %%
dataset.WindDir3pm.isnull().sum()

# %%
plt.style.use("classic")
sns.countplot(data=dataset, x="WindDir3pm")
plt.grid(linewidth = 0.7)
plt.show()

# %% [markdown]
# ### RainToday

# %%
dataset.RainToday.unique()

# %% [markdown]
# 📌 We can see that the number of unique values in RainToday variable is 2 and NaN values.

# %%
dataset.RainToday.value_counts()

# %% [markdown]
# 📌 Replacing the missing values with the most frequent values.

# %%
dataset['RainToday'].fillna(dataset['RainToday'].mode()[0], inplace=True)

# %%
dataset.RainToday.isnull().sum()

# %%
plt.style.use("classic")
sns.countplot(data=dataset, x="RainToday")
plt.grid(linewidth = 0.7)
plt.show()

# %% [markdown]
# ### RainTomorrow

# %%
dataset.RainTomorrow.unique()

# %% [markdown]
# 📌 We can see that the number of unique values in RainTomorrow variable is 2 and NaN values.

# %%
dataset.RainTomorrow.value_counts()

# %% [markdown]
# 📌 Replacing the missing values with the most frequent values.

# %%
dataset['RainTomorrow'].fillna(dataset['RainTomorrow'].mode()[0], inplace=True)

# %%
dataset.RainTomorrow.isnull().sum()

# %%
plt.style.use("classic")
sns.countplot(data=dataset, x="RainTomorrow")
plt.grid(linewidth = 0.7)
plt.show()

# %% [markdown]
# 📌 Above plot shows that our data seems imbalance. We will take care of it later.

# %%
dataset[categorical].isnull().sum()

# %% [markdown]
# 📌 As you can see there are no missing values now.

# %% [markdown]
# ## **Numerical Data** <a id='3.2' ></a>

# %% [markdown]
# 📌 Missing values in numerical data.

# %%
dataset[numerical].isnull().sum()

# %% [markdown]
# 📌 Imputing missing values in numerical data with the median.

# %%
for i in dataset:
    if dataset[i].dtype=='float64':
        dataset[i].replace(to_replace=np.nan, value=dataset[i].median(), inplace=True)
    else:
        continue

# %%
dataset.isnull().sum()

# %% [markdown]
# 📌 We can see that there are no missing values present now in our dataset.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:LightSlateGray;
#            font-size:150%;
#            text-align:center;
#             letter-spacing:0.5px"> <a id='4'></a>
#
#     Data Visualization and Analysis
# </div>

# %% [markdown]
# ## **Heat Map Correlation** <a id='4.1' ></a>

# %%
 plt.style.use('fivethirtyeight')
# Compute the correlation matrix
corr = dataset.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8, 8))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
plt.figure(figsize=(14,12))
ax = sns.heatmap(corr, square=True, annot=True, fmt='.2f')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)          
plt.show()

# %% [markdown]
# From above correlation map we can see that: <br>
# 📌 *MinTemp* and *MaxTemp* features are highly correlated (correlation coefficient = 0.73). <br>
# 📌 *MinTemp* and *Temp9am* features are highly correlated (correlation coefficient = 0.90). <br>
# 📌 *MinTemp* and *Temp3pm* features are highly correlated (correlation coefficient = 0.70). <br>
# 📌 *MaxTemp* and *Temp9am* features are highly correlated (correlation coefficient = 0.88). <br>
# 📌 *MaxTemp* and *Temp3pm* features are highly correlated (correlation coefficient = 0.97). <br>
# 📌 *Pressure9am* and *Pressure3pm* features are highly correlated (correlation coefficient = 0.96). <br>
# 📌 *Temp9am* and *Temp3pm* features are highly correlated (correlation coefficient = 0.85).

# %% [markdown]
# ## **Distribution Plot** <a id='4.2' ></a>

# %%
#  plot Numerical Data
a = 4  # number of rows
b = 4  # number of columns
c = 1  # initialize plot counter
fig = plt.figure(figsize=(35,32))
for i in dataset:
    if dataset[i].dtype=='float64':
        plt.subplot(a, b, c)
        sns.distplot(dataset[i])
        c = c+1
    else:
        continue
plt.tight_layout()
plt.show()

# %% [markdown]
# 📌 From above distribution plot, we can see that certain features are same around few parts of x-axis like WindSpeed9am and WindSpeed3pm is same at 15-20 etc.  <br>

# %% [markdown]
# ## **Date Plot** <a id='4.3' ></a>

# %% [markdown]
# 📌 We are going to plot features with datetime. Here, I am going to use date from last 3 years.

# %% [markdown]
# ### MinTemp and MaxTemp <a id='4.3.1' ></a>

# %%
#Soure: https://www.kaggle.com/momincks/rain-tomorrow-in-aus-by-xgboostclassifier : Do check him out.

df_dateplot = dataset.iloc[-950:,:]
plt.figure(figsize=[20,5])
plt.plot(df_dateplot['Date'],df_dateplot['MinTemp'],color='blue',linewidth=1, label= 'MinTemp')
plt.plot(df_dateplot['Date'],df_dateplot['MaxTemp'],color='red',linewidth=1, label= 'MaxTemp')
plt.fill_between(df_dateplot['Date'],df_dateplot['MinTemp'],df_dateplot['MaxTemp'], facecolor = '#EBF78F')
plt.title('MinTemp vs MaxTemp by Date')
plt.legend(loc='lower left', frameon=False)
plt.show()

# %% [markdown]
# 📌 Above plot shows that the *MinTemp* and *MaxTemp* relatively increases and decreases every year. <br>
# 📌 The weather conditions are always opposite in the two hemispheres. As, the Australia is situated in the southern hemisphere. The seasons are bit different. <br>
# 📌 As you can see that, December to February is summer; March to May is autumn; June to August is winter; and September to November is spring.

# %% [markdown]
# ### Rainfall <a id='4.3.2' ></a>

# %%
df_dateplot = dataset.iloc[-950:,:]
plt.figure(figsize=[20,5])
plt.plot(df_dateplot['Date'],df_dateplot['Rainfall'],color='violet', linewidth=2, label= 'Rainfall')
plt.legend(loc='upper left', frameon=False)
plt.title('Rainfall by Date')
plt.show()

# %% [markdown]
# 📌 Being situated in southern hemisphere, the majority of rainfall occurs between December and March. <br>
# 📌 As you can see from above plot, we can see that Dec-Jan does get a lot of rainfall but there are months like Jun-Jul when rainfall occurs too.

# %% [markdown]
# ### WindGustSpeed <a id='4.3.3' ></a>

# %%
df_dateplot = dataset.iloc[-950:,:]
plt.figure(figsize=[20,5])
plt.plot(df_dateplot['Date'],df_dateplot['WindGustSpeed'],color='violet', linewidth=2, label= 'WindGustSpeed')
plt.legend(loc='upper left', frameon=False)
plt.title('WindGustSpeed by Date')
plt.show()

# %% [markdown]
# 📌 In Australia, wind speed is usually moderate. But, from above plot we can see that Dec-Feb is the windiest months.

# %% [markdown]
# ### WindSpeed9am and WindSpeed3pm <a id='4.3.4' ></a>

# %%
df_dateplot = dataset.iloc[-950:,:]
plt.figure(figsize=[20,5])
plt.plot(df_dateplot['Date'],df_dateplot['WindSpeed9am'],color='blue', linewidth=2, label= 'WindSpeed9am')
plt.plot(df_dateplot['Date'],df_dateplot['WindSpeed3pm'],color='green', linewidth=2, label= 'WindSpeed3pm')
plt.legend(loc='upper left', frameon=False)
plt.title('WindSpeed9am vs WindSpeed3pm by Date')
plt.show()

# %% [markdown]
# 📌 *WindSpeed9am* and *WindSpeed3pm* are relatively same around certain months.

# %% [markdown]
# ### Humidity9am and Humidity3pm <a id='4.3.5' ></a>

# %%
df_dateplot = dataset.iloc[-950:,:]
plt.figure(figsize=[20,5])
plt.plot(df_dateplot['Date'],df_dateplot['Humidity9am'],color='blue', linewidth=2, label= 'Humidity9am')
plt.plot(df_dateplot['Date'],df_dateplot['Humidity3pm'],color='green', linewidth=2, label= 'Humidity3pm')
plt.legend(loc='upper left', frameon=False)
plt.title('Humidity9am vs Humidity3pm by Date')
plt.show()

# %% [markdown]
# 📌 From above plot we can see that the Humidity is high around Jun-Jul and also during that time, there is good difference between humidity around 9am and 3pm.

# %% [markdown]
# ### Pressure9am and Pressure3am <a id='4.3.6' ></a>

# %%
df_dateplot = dataset.iloc[-950:,:]
plt.figure(figsize=[20,5])
plt.plot(df_dateplot['Date'],df_dateplot['Pressure9am'],color='blue', linewidth=2, label= 'Pressure9am')
plt.plot(df_dateplot['Date'],df_dateplot['Pressure3pm'],color='green', linewidth=2, label= 'Pressure3pm')
plt.legend(loc='upper left', frameon=False)
plt.title('Pressure9am vs Pressure3pm by Date')
plt.show()

# %% [markdown]
# 📌 Pressure is high around the months of Jun-Aug and around Dec-Jan you can see that the pressure is low. <br>
# 📌 In a low pressure area the rising air cools and this is likely to condense water vapour and form clouds, and consequently rain. <br>

# %% [markdown]
# ### Cloud9am and Cloud3am <a id='4.3.7' ></a>

# %%
df_dateplot = dataset.iloc[-950:,:]
plt.figure(figsize=[20,5])
plt.plot(df_dateplot['Date'],df_dateplot['Cloud9am'],color='blue', linewidth=2, label= 'Cloud9am')
plt.plot(df_dateplot['Date'],df_dateplot['Cloud3pm'],color='green', linewidth=2, label= 'Cloud3pm')
plt.legend(loc='upper left', frameon=False)
plt.title('Cloud9am vs Cloud3pm by Date')
plt.show()

# %% [markdown]
# 📌 Cloud is the same at 5 all-around years but, there are certain months when it falls or rises.

# %% [markdown]
# ### Temp9am and Temp3pm <a id='4.3.8' ></a>

# %%
df_dateplot = dataset.iloc[-950:,:]
plt.figure(figsize=[20,5])
plt.plot(df_dateplot['Date'],df_dateplot['Temp9am'],color='blue', linewidth=2, label= 'Temp9am')
plt.plot(df_dateplot['Date'],df_dateplot['Temp3pm'],color='green', linewidth=2, label= 'Temp3pm')
plt.legend(loc='lower left', frameon=False)
plt.title('Temp9am vs Temp3pm by Date')
plt.show()

# %% [markdown]
# 📌 As I mentioned in the above plots, that Dec-Jan are months when the temperature is high but these are the months when the difference between temperature around 9am and 3pm is less as compare to the months of Jun-Aug when the difference is high.

# %%
dataset.drop(['Date'], axis=1, inplace=True)
categorical.remove('Date')

# %% [markdown]
# ## **Outliers** <a id='4.4' ></a>

# %% [markdown]
# 📌 An outlier is an observation that lies an abnormal distance from other values in a random sample from a population.

# %% [markdown]
# ### Detection <a id='4.4.1' ></a>

# %% [markdown]
# 📌 In this notebook, we are using Box Plot to detect the outliers of each features in our dataset, where any point above or below the whiskers represent an outlier. This is also known as “Univariate method” as here we are using one variable outlier analysis. <br>

# %%
plt.figure(figsize=[25,15])
dataset.boxplot(column= ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Removal <a id='4.4.2' ></a>

# %% [markdown]
# 📌 After detecting, we are using Median Imputation to take care of outliers. In this technique, we replace the extreme values with median values. <br>
# 📌 It is represented by the formula IQR = Q3 − Q1. The lines of code below calculate and print the interquartile range for each of the variables in the dataset. <br>
# 📌 It is advised to not use mean values as they are affected by outliers.

# %%
for i in dataset:
    if dataset[i].dtype=='float64':
        q1 = dataset[i].quantile(0.25)
        q3 = dataset[i].quantile(0.75)
        iqr = q3-q1
        Lower_tail = q1 - 1.5 * iqr
        Upper_tail = q3 + 1.5 * iqr
        med = np.median(dataset[i])
        for j in dataset[i]:
            if j > Upper_tail or j < Lower_tail:
                dataset[i] = dataset[i].replace(j, med)
    else:
        continue

# %%
plt.figure(figsize=[25,15])
dataset.boxplot(column= ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Pair Plot <a id='4.5' ></a>

# %%
sns.pairplot(data=dataset)
plt.show()

# %% [markdown]
# 📌 From the above graphs, we can see that the outliers in our dataset have been taken care of.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:LightSlateGray;
#            font-size:150%;
#            text-align:center;
#            letter-spacing:0.5px"> <a id = '5'></a>
#
#     Data Preprocessing
# </div>

# %% [markdown]
# ## **Label Encoding** <a id='5.1'></a>

# %% [markdown]
# 📌 Now, I am going to encode categorical data. Label encode will convert target labels with value between 0 and n_classes-1.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le =  LabelEncoder()
for i in dataset:
    if dataset[i].dtype=='object':
        dataset[i] = le.fit_transform(dataset[i])
    else:
        continue

# %%
dataset.info()

# %% [markdown]
# 📌 As you can see, *object* data type is converted to *int64* data type.

# %%
dataset.head()

# %% [markdown]
# ## **Splitting data into Train and Test Set** <a id='5.2'></a>

# %%
x = dataset.drop('RainTomorrow', axis=1).values
y = dataset['RainTomorrow']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=0)

# %% [markdown]
# ## **BorderlineSMOTE and RandomUnderSampler** <a id='5.3'></a>

# %% [markdown]
# 📌 BorderlineSMOTE is a popular extension to SMOTE involves selecting those instances of the minority class that are misclassified, such as with a k-nearest neighbor classification model. <br>
# 📌 Instead of generating new synthetic examples for the minority class blindly, we would expect the Borderline-SMOTE method to only create synthetic examples along the decision boundary between the two classes.

# %% [markdown]
# 📌 Random undersampling involves randomly selecting examples from the majority class to delete from the training dataset. <br>
# 📌 This has the effect of reducing the number of examples in the majority class in the transformed version of the training dataset. This process can be repeated until the desired class distribution is achieved, such as an equal number of examples for each class.

# %%
from imblearn.over_sampling import BorderlineSMOTE
from imblearn.under_sampling import RandomUnderSampler

from imblearn.pipeline import Pipeline

from collections import Counter

# %%
over = BorderlineSMOTE(sampling_strategy=0.3)
under = RandomUnderSampler(sampling_strategy=0.6)

steps = [('o', over), ('u', under)]

# %%
pipeline = Pipeline(steps=steps)

# transform the dataset
x_sm, y_sm = pipeline.fit_resample(x_train, y_train)

print(Counter(y_train))
print(Counter(y_sm))

# %%
# Names of the independent variables
feature_names = list(dataset.drop('RainTomorrow', axis=1).columns)

# Concatenate resampling train sets and test sets to build the new dataframe 
new_x = np.concatenate((x_sm, x_test))
new_y = np.concatenate((y_sm, y_test))

#New DataFrame with sampling data
sm_dataset = pd.DataFrame(np.column_stack([new_y, new_x]), columns=['RainTomorrow'] + feature_names)
sm_dataset.head()

# %% [markdown]
# 📌 From the above dataset, we can see that our Encoded features have become float type. Let's convert them into int type.

# %%
cols = ['Location','WindGustDir','WindDir9am','WindDir3pm','RainToday','RainTomorrow','Day','Month','Year']
for i in cols:
    sm_dataset[i] = sm_dataset[i].astype(int)
sm_dataset.head()

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:LightSlateGray;
#            font-size:150%;
#            text-align:center;
#            letter-spacing:0.5px"> <a id = '6'></a>
#
#     H2O
# </div>

# %% [markdown]
# 📌 H2O from Python is a tool for rapidly turning over models, doing data munging, and building applications in a fast, scalable environment without any of the mental anguish about parallelism and distribution of work.

# %%
# Start and connect to a local H2O cluster
import h2o
h2o.init(nthreads = -1)

# %%
weather = h2o.H2OFrame(sm_dataset)

# %%
weather

# %%
#Convert 'Location','WindGustDir','WindDir9am','WindDir3pm','RainToday' and 'RainTomorrow' to categorical values
weather['Location'] = weather['Location'].asfactor()
weather['WindGustDir'] = weather['WindGustDir'].asfactor()
weather['WindDir9am'] = weather['WindDir9am'].asfactor()
weather['WindDir3pm'] = weather['WindDir3pm'].asfactor()
weather['RainToday'] = weather['RainToday'].asfactor()
weather['RainTomorrow'] = weather['RainTomorrow'].asfactor()

# %%
# Define features (or predictors) manually
features = ['Location','MinTemp','MaxTemp','Rainfall','Evaporation','Sunshine','WindGustDir','WindGustSpeed','WindDir9am','WindDir3pm','WindSpeed9am','WindSpeed3pm','Humidity9am','Humidity3pm','Pressure9am','Pressure3pm','Cloud9am','Cloud3pm','Temp9am','Temp3pm','RainToday','Day','Month','Year']

# %%
# Split the H2O data frame into training/test sets
# so we can evaluate out-of-bag performance
weather_split = weather.split_frame(ratios = [0.8], seed = 1234)

weather_train = weather_split[0] # using 80% for training
weather_test = weather_split[1]  # using the rest 20% for out-of-bag evaluation

# %%
weather_train.shape

# %%
weather_test.shape

# %% [markdown]
# ## **H2OGeneralizedLinearEstimator** <a id = '6.1'></a>

# %% [markdown]
# 📌 Build a Generalized Linear Model Fit a generalized linear model, specified by a response variable, a set of predictors, and a description of the error distribution.

# %%
# Build a Generalized Linear Model (GLM) with default settings

# Import the function for GLM
from h2o.estimators.glm import H2OGeneralizedLinearEstimator

# Set up GLM for binary classification
glm_default = H2OGeneralizedLinearEstimator(family = 'binomial', model_id = 'glm_default', keep_cross_validation_predictions = True, nfolds =5, fold_assignment = "stratified", balance_classes=True)

# Use .train() to build the model
glm_default.train(x = features, 
                  y = 'RainTomorrow', 
                  training_frame = weather_train)

# %%
# Check the model performance on training dataset
glm_default

# %%
plt.figure(figsize=(5,5))
variable = glm_default.varimp_plot()
plt.show()

# %%
performace = glm_default.model_performance(train=True)
performace.plot()

# %%
coef = glm_default.std_coef_plot()
plt.yticks(size=6)
plt.tight_layout()
plt.show()

# %%
# Check the model performance on test dataset
glm_default.model_performance(weather_test)

# %%
performace = glm_default.model_performance(weather_test)
performace.plot()

# %%
# Use GLM model to make predictions
yhat_test_glm = glm_default.predict(weather_test)
yhat_test_glm.head(5)

# %% [markdown]
# ## **H2ORandomForestEstimator** <a id = '6.2'></a>

# %% [markdown]
# 📌 Builds a Random Forest Model on an H2OFrame.

# %%
# Build a Distributed Random Forest (DRF) model with default settings

# Import the function for DRF
from h2o.estimators.random_forest import H2ORandomForestEstimator

# Set up DRF for classification
# Add a seed for reproducibility
drf_default = H2ORandomForestEstimator(model_id = 'drf_default', seed = 1234, keep_cross_validation_predictions = True, nfolds =5, fold_assignment = "stratified", balance_classes=True)

# Use .train() to build the model
drf_default.train(x = features, 
                  y = 'RainTomorrow', 
                  training_frame = weather_train)

# %%
# Check the DRF model summary
drf_default

# %%
plt.figure(figsize=(5,5))
variable = drf_default.varimp_plot()
plt.show()

# %%
performace = drf_default.model_performance(train=True)
performace.plot()

# %%
# Check the model performance on test dataset
drf_default.model_performance(weather_test)

# %%
performace = drf_default.model_performance(weather_test)
performace.plot()

# %%
# Use DRF model to make predictions
yhat_test_drf = drf_default.predict(weather_test)
yhat_test_drf.head(5)

# %% [markdown]
# ## **H2OGradientBoostingEstimator** <a id = '6.3'></a>

# %% [markdown]
# 📌 Builds gradient boosted classification trees, and gradient boosted regression trees on a parsed data set. The default distribution function will guess the model type based on the response column type run properly the response column must be an numeric for “gaussian” or an enum for “bernoulli” or “multinomial”.

# %%
# Build a Gradient Boosting Machines (GBM) model with default settings

# Import the function for GBM
from h2o.estimators.gbm import H2OGradientBoostingEstimator

# Set up GBM for classification
# Add a seed for reproducibility
gbm_default = H2OGradientBoostingEstimator(model_id = 'gbm_default', seed = 1234, keep_cross_validation_predictions = True, nfolds =5, fold_assignment = "stratified", balance_classes=True)

# Use .train() to build the model
gbm_default.train(x = features, 
                  y = 'RainTomorrow', 
                  training_frame = weather_train)

# %%
# Check the GBM model summary
gbm_default

# %%
plt.figure(figsize=(5,5))
variable = gbm_default.varimp_plot()
plt.show()

# %%
performace = gbm_default.model_performance(train=True)
performace.plot()

# %%
# Check the model performance on test dataset
gbm_default.model_performance(weather_test)

# %%
performace = gbm_default.model_performance(weather_test)
performace.plot()

# %%
# Use GBM model to make predictions
yhat_test_gbm = gbm_default.predict(weather_test)
yhat_test_gbm.head(5)

# %% [markdown]
# ## **H2ODeepLearningEstimator** <a id = '6.4'></a>

# %% [markdown]
# 📌 Build a supervised Deep Neural Network model Builds a feed-forward multilayer artificial neural network on an H2OFrame.

# %%
# Build a Deep Learning (Deep Neural Networks, DNN) model with default settings

# Import the function for DNN
from h2o.estimators.deeplearning import H2ODeepLearningEstimator

# Set up DNN for regression
dnn_default = H2ODeepLearningEstimator(model_id = 'dnn_default', keep_cross_validation_predictions = True, nfolds =5,fold_assignment='stratified', balance_classes=True)

# (not run) Change 'reproducible' to True if you want to reproduce the results
# The model will be built using a single thread (could be very slow)
# dnn_default = H2ODeepLearningEstimator(model_id = 'dnn_default', reproducible = True)

# Use .train() to build the model
dnn_default.train(x = features, 
                  y = 'RainTomorrow', 
                  training_frame = weather_train)

# %%
# Check the DNN model summary
dnn_default

# %%
plt.figure(figsize=(5,5))
variable = dnn_default.varimp_plot()
plt.show()

# %%
performace = dnn_default.model_performance(train=True)
performace.plot()

# %%
# Check the model performance on test dataset
dnn_default.model_performance(weather_test)

# %%
performace = dnn_default.model_performance(weather_test)
performace.plot()

# %%
# Use DNN model to make predictions
yhat_test_dnn = dnn_default.predict(weather_test)
yhat_test_dnn.head(5)

# %% [markdown]
# ## **H2OStackedEnsembleEstimator** <a id = '6.5'></a>

# %% [markdown]
# 📌 Builds a stacked ensemble (aka “super learner”) machine learning method that uses two or more H2O learning algorithms to improve predictive performance. It is a loss-based supervised learning method that finds the optimal combination of a collection of prediction algorithms.This method supports regression and binary classification.

# %%
# Import the function for StackedEnsemble
from h2o.estimators.stackedensemble import H2OStackedEnsembleEstimator

# Set up Stacked Ensemble
ensemble = H2OStackedEnsembleEstimator(model_id = "my_ensemble",
                                       base_models = [glm_default, drf_default, gbm_default, dnn_default])

# use .train to start model stacking
# GLM as the default metalearner
ensemble.train(x = features, 
               y = 'RainTomorrow', 
               training_frame = weather_train)

# %%
# Check the Stacked model summary
ensemble

# %%
# Check the model performance on test dataset
ensemble.model_performance(weather_test)

# %%
performace = ensemble.model_performance(weather_test)
performace.plot()

# %%
# Use Stacked Ensemble to make predictions
yhat_test_ensemble = ensemble.predict(weather_test)
yhat_test_ensemble.head(5)

# %% [markdown]
# 📌 Comparison of Model Performance on Test Data

# %%
print('GLM model (AUC) : ', glm_default.model_performance(weather_test).auc())
print('DRF model (AUC) : ', drf_default.model_performance(weather_test).auc())
print('GBM model (AUC) : ', gbm_default.model_performance(weather_test).auc())
print('DNN model (AUC) : ', dnn_default.model_performance(weather_test).auc())
print('Stacked Ensembles (AUC) : ', ensemble.model_performance(weather_test).auc())

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:LightSlateGray;
#            font-size:150%;
#            text-align:center;
#            letter-spacing:0.5px"> <a id = '7'></a>
#
#     Conclusion
# </div>

# %% [markdown]
# 📌 After dealing with missing values in the dataset and extensive data analysis of the features. I got to know more about how features are correlated to each other. <br>
# 📌 I implemented BorderlineSMOTE and RandomUnderSampler techniques on our features to deal with the imbalance data. <br>
# 📌 Then, I used different classification models from H2O to see how it performs on the dataset. I got pretty good results with AUC, precision, and recall score. <br>
# 📌 With that, I concluded that the Stacked Ensembles model is the best fit for our dataset. But, as I have used default parameters for our models. So, the other models could be tuned and make the other models better.

# %% [markdown]
# <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            border:2px solid DodgerBlue;
#            background-color:white;
#            font-size:150%;
#            text-align:center;
#            letter-spacing:0.5px">
#
#     Thank You!
# </div>
