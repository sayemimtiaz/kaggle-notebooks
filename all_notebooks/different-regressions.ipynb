# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.datasets import load_boston
import seaborn as sns

# %%
dataset = load_boston()

# %%
print("First X =", dataset.data[1], '\n')
print("First Y =", dataset.target[1])

# %%
data = pd.DataFrame(dataset.data)
data.columns = dataset.feature_names
data['Price'] = boston.target

# %%
data.head()

# %%
plt.rcParams['figure.figsize'] = (15, 10)
plt.style.use('ggplot')

sns.heatmap(data.corr(), annot=True)
plt.title('Correlation Plot', fontsize = 20)
plt.show()

# %%
X, y = data.iloc[:,:-1],data.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
print(X_train.shape[0], "training samples.")
print(X_test.shape[0], "test samples.")

# %% [markdown]
# # Linear model

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression(n_jobs = 10)
model.fit(X_train, y_train)

# %%
model.score(X_test, y_test)

# %%
model.coef_

# %%
y_pred = model.predict(X_test)
print(y_pred[:10])

# %%
x_ax = range(len(X_test))
plt.scatter(x_ax, y_test, s=5, color="blue", label="actual")
plt.plot(x_ax, y_pred, lw=0.8, color="red", label="predicted")
plt.legend()
plt.show()

# %%
print('Mean Squared Error:', mean_squared_error(y_test, y_pred)) 
print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))

# %% [markdown]
# # SVM Regression

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR

# %%
regression = make_pipeline(StandardScaler(), SVR(C=20.0, epsilon=0.2))
regression.fit(X, y)

# %%
regression.score(X_test, y_test)

# %%
y_pred = regression.predict(X_test)

# %%
y_pred[:10]

# %%
x_ax = range(len(X_test))
plt.scatter(x_ax, y_test, s=5, color="blue", label="actual")
plt.plot(x_ax, y_pred, lw=0.8, color="red", label="predicted")
plt.legend()
plt.show()

# %%
print('Mean Squared Error:', mean_squared_error(y_test, y_pred)) 
print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))

# %% [markdown]
# # Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor(n_estimators=25, max_depth=15)
model.fit(X_train,y_train)

# %%
model.score(X_test, y_test)

# %%
predictions = model.predict(X_test)
predictions[:10]

# %%
x_ax = range(len(X_test))
plt.scatter(x_ax, y_test, s=5, color="blue", label="actual")
plt.plot(x_ax, predictions, lw=0.8, color="red", label="predicted")
plt.legend()
plt.show()

# %%
print('Mean Squared Error:', mean_squared_error(y_test, predictions)) 
print('Mean Absolute Error:', mean_absolute_error(y_test, predictions))

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
regressor = DecisionTreeRegressor(criterion = "mse", min_samples_leaf = 15, random_state = 1)
regressor.fit(X_train, y_train)

# %%
regressor.score(X_test, y_test)

# %%
predictions = regressor.predict(X_test)
predictions[:10]

# %%
x_ax = range(len(X_test))
plt.scatter(x_ax, y_test, s=5, color="blue", label="actual")
plt.plot(x_ax, predictions, lw=0.8, color="red", label="predicted")
plt.legend()
plt.show()

# %%
print('Mean Squared Error:', mean_squared_error(y_test, predictions)) 
print('Mean Absolute Error:', mean_absolute_error(y_test, predictions))
