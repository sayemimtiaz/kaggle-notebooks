# %% [markdown]
# # Configuration and Utilities

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from datetime import datetime
from matplotlib.dates import date2num
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_squared_error
from tensorflow import keras

import re
import math

# %%
# Date parsing
def dateparse (time_in_secs):    
    return datetime.fromtimestamp(float(time_in_secs))

# %%
def highlights_attacks (df, attacks, ax):
  for index, row in attacks.iterrows():
    start = datetime.fromtimestamp(row['start'])
    end = datetime.fromtimestamp(row['end'])

    period = df[(df.index > start) & (df.index <= end)].index

    ax.axvspan(start, end, facecolor='pink', edgecolor='none', alpha=.4)

# %%
def clean_header (header_name, label):
    x = re.match(r"\(\'value\',\s\'((?:[0-9]{1,3}\.){3}[0-9]{1,3}):[0-9]{4}\'\)", header_name)
    if x == None:
        return header_name
    return x.group(1) + '-' + label

# %%
def create_dataset(X, y, time_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        v = X.iloc[i:(i + time_steps)].values
        Xs.append(v)
        ys.append(y.iloc[i + time_steps])
    return np.array(Xs).astype('float32'), np.array(ys).astype('float32')

# %%
def return_rmse(test, predicted, model):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error for {} model is {}.".format(model, rmse))
    return rmse

# %%
attacks = pd.DataFrame(
    {
        "name": ['First Attack'],
        "start" : [1619499815],
        "end" : [1619499840]
    }
)

# %% [markdown]
# # Fetching datasets

# %% [markdown]
# ## Node Traffic Dataset

# %% [markdown]
# ### Node Traffic read and clean

# %%
node_traffic = pd.read_csv('/kaggle/input/chaosml/node_traffic.csv', parse_dates=['timestamp'], date_parser=dateparse)
node_traffic.head()

# %%
node_traffic_pivoted = pd.pivot_table(data=node_traffic,index=['timestamp'], columns=['instance'])
node_traffic_pivoted.head()

# %%
node_traffic_flattened = pd.DataFrame(node_traffic_pivoted.to_records())
node_traffic_flattened.columns = [clean_header(hdr,'traffic') for hdr in node_traffic_flattened.columns]
node_traffic_flattened.head()

# %%
# may move after merge
node_traffic_flattened['attack'] = False

for index, row in attacks.iterrows():
  start = datetime.fromtimestamp(row['start'])
  end = datetime.fromtimestamp(row['end'])
  node_traffic_flattened.loc[(node_traffic_flattened['timestamp'] > start) & (node_traffic_flattened['timestamp'] <= end), 'attack'] = True

node_traffic_flattened.head()

# %% [markdown]
# ### Container Traffic Plot

# %%
indexed_node_traffic_flattened = node_traffic_flattened
indexed_node_traffic_flattened.set_index('timestamp', inplace=True)

# %%
ax = indexed_node_traffic_flattened.plot()

highlights_attacks (indexed_node_traffic_flattened, attacks, ax)

# %% [markdown]
# ## Node Satauration Dataset

# %% [markdown]
# ### Node Saturation read and clean

# %%
node_saturation = pd.read_csv('/kaggle/input/chaosml/node_saturation.csv', parse_dates=['timestamp'], date_parser=dateparse)
node_saturation = node_saturation.rename(columns={'value': 'saturation_cpu'})
node_saturation.head()

# %% [markdown]
# ### Node Saturation CPU Plot

# %%
indexed_node_saturation_flattened = node_saturation
indexed_node_saturation_flattened.set_index('timestamp', inplace=True)

# %%
ax = indexed_node_saturation_flattened.plot()

highlights_attacks (indexed_node_saturation_flattened, attacks, ax)

# %% [markdown]
# # Merge Datasets
#
# Documentation about `merge_asof` function may be found [here](https://towardsdatascience.com/how-to-merge-not-matching-time-series-with-pandas-7993fcbce063)

# %%
merged_traffic_and_cpu = pd.merge_asof (node_traffic_flattened, node_saturation, on='timestamp', tolerance=pd.Timedelta('1s'))
merged_traffic_and_cpu.head()

# %%
merged_traffic_and_cpu.describe().transpose()

# %% [markdown]
# ## Replace Missing Values

# %%
# replace with last value

colums_to_replace_with_last_value = ['saturation_cpu']

for column in colums_to_replace_with_last_value:
    merged_traffic_and_cpu[column].replace(np.nan, merged_traffic_and_cpu[column].mean(), inplace=True)

    
# replace with max value

columns_to_replace_with_max_val = []

for column in columns_to_replace_with_max_val:
    merged_traffic_and_cpu[column].replace(np.nan, merged_traffic_and_cpu[column].max(), inplace=True)

# %%
merged_traffic_and_cpu.isnull().sum(axis = 0)

# %% [markdown]
# ### Merge Plot

# %%
indexed_merge = merged_traffic_and_cpu
indexed_merge.set_index('timestamp', inplace=True)

# %%
indexed_merge.plot(subplots=True, y=['192.168.33.56-traffic', 'saturation_cpu'])

# %% [markdown]
# # Train a model

# %%
f_predicted = 'saturation_cpu'

# %% [markdown]
# ## Pre processing
#
# We’ll use the last 10% of the data for testing:

# %%
train_size = int(len(indexed_merge) * 0.9)
test_size = len(indexed_merge) - train_size

train, test = indexed_merge.iloc[0:train_size], indexed_merge.iloc[train_size:len(indexed_merge)]

print(len(train), len(test))

# %% [markdown]
# We’ll scale some of the features we’re using for our modeling:

# %%
f_columns = indexed_merge.columns.to_list()
f_columns.remove('attack')
f_columns.remove(f_predicted)

f_transformer = RobustScaler()
saturation_cpu_transformer = RobustScaler()

f_transformer = f_transformer.fit(train[f_columns].to_numpy())
saturation_cpu_transformer = saturation_cpu_transformer.fit(train[[f_predicted]])

train.loc[:, f_columns] = f_transformer.transform(
  train[f_columns].to_numpy()
)
train[f_predicted] = saturation_cpu_transformer.transform(train[[f_predicted]])

test.loc[:, f_columns] = f_transformer.transform(
  test[f_columns].to_numpy()
)
test[f_predicted] = saturation_cpu_transformer.transform(test[[f_predicted]])

print(len(train), len(test))
print(train.shape, test.shape)

# %%
time_steps = 10

# reshape to [samples, time_steps, n_features]

X_train, y_train = create_dataset(train, train[f_predicted], time_steps)
X_test, y_test = create_dataset(test, test[f_predicted], time_steps)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

# %% [markdown]
# ## Prediction with LSTM

# %%
model_lstm = keras.Sequential()

# First LSTM layer with Dropout regularisation
model_lstm.add(keras.layers.LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model_lstm.add(keras.layers.Dropout(0.2))
# Second LSTM layer
model_lstm.add(
  keras.layers.LSTM(
    units=128,
    input_shape=(X_train.shape[1], X_train.shape[2])
  )
)
model_lstm.add(keras.layers.Dropout(rate=0.2))
# The output layer
model_lstm.add(keras.layers.Dense(units=1))

model_lstm.compile(optimizer='rmsprop',loss='mean_squared_error')

# %%
history_lstm = model_lstm.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.1,
    shuffle=False
)

# %%
model_lstm.summary()

# %%
y_pred_lstm = model_lstm.predict(X_test)
y_pred_lstm.shape

# %%
y_train_inv_lstm = saturation_cpu_transformer.inverse_transform(y_train.reshape(1, -1))
y_test_inv_lstm = saturation_cpu_transformer.inverse_transform(y_test.reshape(1, -1))
y_pred_inv_lstm = saturation_cpu_transformer.inverse_transform(y_pred_lstm)

# %%
plt.plot(np.arange(0, len(y_train)), y_train_inv_lstm.flatten(), 'g', label="history")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_test_inv_lstm.flatten(), label="true")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_pred_inv_lstm.flatten(), 'r', label="prediction")
plt.ylabel('FrontEnd CPU')
plt.xlabel('Time Step')
plt.title('LSTM')
plt.legend()
plt.show();

# %%
rmse_lstm = return_rmse(y_test,y_pred_inv_lstm,'LSTM')

# %% [markdown]
# ## Prediction with Bidirectional LSTM with a Dropout layer

# %%
model_lstm_bidirectional = keras.Sequential()

# First LSTM layer with Dropout regularisation
model_lstm_bidirectional.add(keras.layers.LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model_lstm_bidirectional.add(keras.layers.Dropout(0.2))
# Second LSTM layer
model_lstm_bidirectional.add(
  keras.layers.Bidirectional(
    keras.layers.LSTM(
      units=50,
      input_shape=(X_train.shape[1], X_train.shape[2])
    )
  )
)
model_lstm_bidirectional.add(keras.layers.Dropout(rate=0.2))
# The output layer
model_lstm_bidirectional.add(keras.layers.Dense(units=1))

model_lstm_bidirectional.compile(optimizer='rmsprop',loss='mean_squared_error')

# %%
history_1 = model_lstm_bidirectional.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.1,
    shuffle=False
)

# %%
model_lstm_bidirectional.summary()

# %%
y_pred = model_lstm_bidirectional.predict(X_test)
y_pred.shape

# %% [markdown]
# Reverse scaling

# %%
y_train_inv = saturation_cpu_transformer.inverse_transform(y_train.reshape(1, -1))
y_test_inv = saturation_cpu_transformer.inverse_transform(y_test.reshape(1, -1))
y_pred_inv = saturation_cpu_transformer.inverse_transform(y_pred)

# %%
plt.plot(np.arange(0, len(y_train)), y_train_inv.flatten(), 'g', label="history")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_test_inv.flatten(), label="true")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_pred_inv.flatten(), 'r', label="prediction")
plt.ylabel('FrontEnd CPU')
plt.xlabel('Time Step')
plt.title('Bidirectional LSTM')
plt.legend()
plt.show();

# %%
rmse_bi_lstm = return_rmse(y_test,y_pred_inv,'Bidirectional LSTM')

# %% [markdown]
# ## Prediction with GRU

# %%
model_gru = keras.Sequential()

# First GRU layer with Dropout regularisation
model_gru.add(keras.layers.GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2]), activation='tanh'))
model_gru.add(keras.layers.Dropout(0.2))
# Second LSTM layer
model_gru.add(
  keras.layers.GRU(
    units=128,
    input_shape=(X_train.shape[1], X_train.shape[2]),
    activation='tanh'
  )
)
model_gru.add(keras.layers.Dropout(rate=0.2))
# The output layer
model_gru.add(keras.layers.Dense(units=1))

model_gru.compile(optimizer=keras.optimizers.SGD(lr=0.01, decay=1e-7, momentum=0.9, nesterov=False), loss='mean_squared_error')

# %%
history_gru = model_lstm_bidirectional.fit(
    X_train, y_train,
    epochs=50,
    batch_size=150,
    shuffle=False
)

# %%
model_gru.summary()

# %%
y_pred_gru = model_gru.predict(X_test)
y_pred_gru.shape

# %%
y_train_inv_gru = saturation_cpu_transformer.inverse_transform(y_train.reshape(1, -1))
y_test_inv_gru = saturation_cpu_transformer.inverse_transform(y_test.reshape(1, -1))
y_pred_inv_gru = saturation_cpu_transformer.inverse_transform(y_pred_gru)

# %%
plt.plot(np.arange(0, len(y_train)), y_train_inv_gru.flatten(), 'g', label="history")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_test_inv_gru.flatten(), label="true")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_pred_inv_gru.flatten(), 'r', label="prediction")
plt.ylabel('FrontEnd CPU')
plt.xlabel('Time Step')
plt.title('GRU')
plt.legend()
plt.show();

# %%
rmse_gru = return_rmse(y_test,y_pred_inv_gru,'GRU')

# %% [markdown]
# ## Compare Performance

# %%
rmse_df = pd.DataFrame({'Model':['LSTM', 'Bidirectional LSTM', 'GRU'], 'RMSE':[rmse_lstm, rmse_bi_lstm, rmse_gru]})
ax = rmse_df.plot.bar(x='Model', y='RMSE', rot=0, color = ['green','blue', 'orange'])

for p in ax.patches:
    b = p.get_bbox()
    val = "{:.2f}".format(b.y1 + b.y0)        
    ax.annotate(val, ((b.x0 + b.x1)/2 - 0.07, b.y1 + 0.005))
