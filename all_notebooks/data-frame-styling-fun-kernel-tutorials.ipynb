# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Have you ever thought of makinf fun and interesting kernerls?
#  Then have a look here , it is interesting with lost of coloring and I call this as full kernels.

# %%
from IPython.display import Image
Image('../input/minions/minions.jpg')

# %% [markdown]
# # Let's color our kernels

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import array
#base map
from mpl_toolkits.basemap import Basemap
from matplotlib import cm
from matplotlib.dates import date2num

# %%
def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'red' if val < 0 else 'black'
    return 'color: %s' % color

# %%
np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[0, 2] = np.nan

# %%
df.style

# %%
def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'red' if val < 0 else 'black'
    return 'color: %s' % color

# %%
s = df.style.applymap(color_negative_red)
s

# %%
def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

# %%
df.style.apply(highlight_max)

# %%
df.head().style

# %%
df.head().style.applymap(color_negative_red)

# %%
df.head().style.apply(highlight_max)

# %%
def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['background-color: green' if v else '' for v in is_max]

# %%
df.head().style.apply(highlight_max)

# %%
def highlight_min(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_min = s == s.min()
    return ['background-color: green' if v else '' for v in is_min]

# %%
df.head().style.apply(highlight_min, axis=0)

# %%
df.head().style.apply(highlight_min, axis=1)

# %%
df.style.apply(highlight_max, subset=['B', 'C', 'D'])

# %%
df.head().style.apply(highlight_max, subset=['A', 'C', 'D'])

# %%
df.style.\
    applymap(color_negative_red).\
    apply(highlight_max)

# %%
df.head().style.\
    applymap(color_negative_red).\
    apply(highlight_max)

# %%
df.style.format("{:.3%}")

# %%
df.head().style.highlight_null(null_color='pink')

# %%
import seaborn as sns

cm = sns.light_palette("green", as_cmap=True)

s = df.style.background_gradient(cmap=cm)
s

# %%
import seaborn as sns

cm = sns.light_palette("blue", as_cmap=True)

s = df.style.background_gradient(cmap=cm)
s

# %%
import seaborn as sns

cm = sns.light_palette("pink", as_cmap=True)

s = df.style.background_gradient(cmap=cm)
s

# %%
df.loc[:4].style.background_gradient(cmap='viridis')

# %%
df.head().style.background_gradient(cmap='viridis')

# %%
df.style.set_properties(**{'background-color': 'black',
                           'color': 'lawngreen',
                           'border-color': 'white'})

# %%
df.head().style.set_properties(**{'background-color': 'black',
                           'color': 'lawngreen',
                           'border-color': 'white'})

# %%
df.style.bar(subset=['A', 'B'], color='#d65f5f')

# %%
df.head().style.bar(subset=['A', 'B','C'], color='#d65f5f')

# %%
df.style.bar(subset=['A', 'B'], align='mid', color=['#d65f5f', '#5fba7d'])

# %%
df.head().style.bar(subset=['A', 'B','C','D'], align='mid', color=['#d65f5f', '#5fba7d'])

# %%
from IPython.html import widgets
@widgets.interact
def f(h_neg=(0, 359, 1), h_pos=(0, 359), s=(0., 99.9), l=(0., 99.9)):
    return df.style.background_gradient(
        cmap=sns.palettes.diverging_palette(h_neg=h_neg, h_pos=h_pos, s=s, l=l,
                                            as_cmap=True)
    )

# %%
df.describe().T.style.bar()

# %% [markdown]
# # Style to Atal Jal

# %%
#reading the data frame
df=pd.read_csv('../input/ataljalyojana/Atal Jal 31 March 2021 .xlsx - Sheet1.csv')
df.head()

# %%
df.head().style.apply(highlight_max)

# %%
df.head().style

# %%
df.head().style.apply(highlight_min)

# %%
df.head().style.apply(highlight_min, axis=0)

# %%
df.head().style.apply(highlight_max, subset=['State','Well Depth'])

# %%
df.head().style.highlight_null(null_color='pink')

# %%
import seaborn as sns

cm = sns.light_palette("green", as_cmap=True)

s = df.head().style.background_gradient(cmap=cm)
s

# %%
import seaborn as sns

cm = sns.light_palette("blue", as_cmap=True)

s = df.head().style.background_gradient(cmap=cm)
s

# %%
df.loc[:4].style.background_gradient(cmap='viridis')

# %%
df.head(10).style.background_gradient(cmap='viridis')

# %%
df.head().style.set_properties(**{'background-color': 'black',
                           'color': 'lawngreen',
                           'border-color': 'white'})

# %%
df.head().style.bar(subset=['Well Depth', 'Pre_2015'], color='#d65f5f')

# %%
df.describe().T.style.bar(color="yellow")

# %%
from IPython.html import widgets
@widgets.interact
def f(h_neg=(0, 359, 1), h_pos=(0, 359), s=(0., 99.9), l=(0., 99.9)):
    return df.head().style.background_gradient(
        cmap=sns.palettes.diverging_palette(h_neg=h_neg, h_pos=h_pos, s=s, l=l,
                                            as_cmap=True)
    )

# %% [markdown]
# # Thank you
# * Up-votes and comments
# * I ll keep bringing the change
# * Here it is

# %%
Image('../input/thank-you/download.jpg', width=800, height=600)
