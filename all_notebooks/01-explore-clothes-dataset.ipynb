# %% [markdown]
# # Get Started with Clothes Dataset

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
DATA_DIR = "../input/clothing-dataset-full/images_original"
DATA_RAW = "../input/clothing-dataset-full/images.csv"
WORK_DIR = "../"

# %% [markdown]
# ## Import data

# %%
data = pd.read_csv(DATA_RAW)
data.head(10)

# %% [markdown]
# ## Exploration

# %%
data.info()

# %% [markdown]
# There is no missing values in the dataset

# %%
data["sender_id"].nunique()

# %% [markdown]
# Image come from `351` contributors

# %%
plt.figure(figsize=(12, 4))
data["label"].value_counts(sort=True).plot(kind="bar")
plt.show()

# %% [markdown]
# As the dataset is unbalanced, this should be taken into account when sampling.

# %%
plt.figure(figsize=(8, 8))
data["kids"].value_counts(sort=True).plot(kind="pie", autopct="%0.2f")
plt.show()

# %% [markdown]
# ## Let's take a look

# %%
fig = plt.figure(figsize=(16, 12))
for i in range(12):
    fig.add_subplot(3, 4, i+1)
    image = plt.imread(os.path.join(DATA_DIR, data["image"][i]+".jpg"))
    plt.imshow(image)
plt.show()

# %% [markdown]
# ## Sampling

# %%
train , test = train_test_split(data, stratify=data["label"], test_size=0.2, shuffle=True, random_state=42)
train.to_csv(os.path.join(WORK_DIR, "train.csv"), index=False)
test.to_csv(os.path.join(WORK_DIR, "test.csv"), index=False)
