# %% [markdown]
# 5 Day Challenge: Day 1
# Importing the UFO Database and saving it into a variable named df

# %%
import pandas as pd
df = pd.read_csv("../input/scrubbed.csv")

# %% [markdown]
# Describe the Dataset

# %%
df.describe()
