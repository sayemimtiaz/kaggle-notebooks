# %%
import numpy as np # 数组常用库
import pandas as pd # 读入csv常用库
from sklearn.linear_model import LinearRegression # sk-learn库Linear Regression模型
from sklearn.model_selection import train_test_split # sk-learn库训练与测试
from sklearn import metrics # 生成各项测试指标库
import matplotlib.pyplot as plt # 画图常用库
import math #数学库

# %% [markdown]
# 读取数据

# %%
data = pd.read_csv('../input/kc_house_data.csv')

# %%
data.dtypes

# %%
X = data[['bedrooms','bathrooms','sqft_living','floors']]
Y = data['price']

# %% [markdown]
# 获得2:1的训练：测试数据比例

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X, Y, test_size = 1/3, random_state = 0)

# %%
xtrain = np.asmatrix(xtrain)
xtest = np.asmatrix(xtest)
ytrain = np.ravel(ytrain)
ytest = np.ravel(ytest)

# %% [markdown]
# 观察房价和生活面积的关系

# %%
plt.scatter(X['sqft_living'], Y)
plt.show()

# %% [markdown]
# 观察生活面积分布

# %%
X['sqft_living'].hist()
plt.show()

# %% [markdown]
# 用xtrain和ytrain训练模型

# %%
model = LinearRegression()
model.fit(xtrain, ytrain)

# %%
pd.DataFrame(list(zip(X.columns, np.transpose(model.coef_))))

# %%
model.intercept_

# %%
pred = model.predict(xtrain)

# %% [markdown]
# 训练集上的均方差MSE (mse on training set)

# %%
sum((pred-ytrain)**2)/len(ytrain)

# %% [markdown]
# 平均相对误差 (average relative error)

# %%
sum(abs(pred-ytrain)/ytrain)/len(ytrain)

# %% [markdown]
# 测试集上mse (mse on test set)

# %%
predtest = model.predict(xtest)
sum((predtest-ytest)**2)/len(ytest)

# %%
sum(abs(predtest-ytest)/ytest)/len(ytest)
