# %% [markdown]
# ![](https://img.hankyung.com/photo/202101/01.25027701.1.jpg)

# %% [markdown]
# **The 2020 Summer Olympics officially the Games of the XXXII Olympiad and branded as Tokyo 2020 (東京2020), was an international multi-sport event held from 23 July to 8 August 2021 in Tokyo.**

# %% [markdown]
# # Table of Contents
# <a id="table-of-contents"></a>
# - [1 Introduction of Tableau](#1)
#
# - [2 Who is The First?](#2)
#
# - [3 Total Medal with Bubble Chart](#3)
#
# - [4 Medal Number & Gold Medal](#4)
#
# - [5 Silver Medal & Bronze Medal](#5)

# %% [markdown]
# [back to top](#table-of-contents)
# <a id="1"></a>
# # 1 Introduction of Tableau

# %% [markdown]
# ![](https://www.zdnet.de/wp-content/uploads/2016/03/tableau-logo.jpg)

# %% [markdown]
# Tableau is a Business Intelligence tool for visually analyzing the data. Users can create and distribute an interactive and shareable dashboard, which depict the trends, variations, and density of the data in the form of graphs and charts. Tableau can connect to files, relational and Big Data sources to acquire and process data. The software allows data blending and real-time collaboration, which makes it very unique. It is used by businesses, academic researchers, and many government organizations for visual data analysis.
# ​
# **Furthermore, It has more visualization power than R and Python, So If you learned this tools, you can easily show your insight and perspective.**

# %% [markdown]
# [back to top](#table-of-contents)
# <a id="2"></a>
# # 2 Who is the First?

# %% [markdown]
# <div class='tableauPlaceholder' id='viz1630319553146' style='position: relative'><noscript><a href='#'><img alt='대시보드 4 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;3_&#47;3_16303193559450&#47;4&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='3_16303193559450&#47;4' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;3_&#47;3_16303193559450&#47;4&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='ko-KR' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1630319553146');                    var vizElement = divElement.getElementsByTagName('object')[0];                    if ( divElement.offsetWidth > 800 ) { vizElement.style.width='1000px';vizElement.style.height='827px';} else if ( divElement.offsetWidth > 500 ) { vizElement.style.width='1000px';vizElement.style.height='827px';} else { vizElement.style.width='100%';vizElement.style.height='727px';}                     var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %% [markdown]
# **The United States of America has won the game and China(People's Republic of China) is second, And Russia(ROC) is third.😁**

# %% [markdown]
# [back to top](#table-of-contents)
# <a id="3"></a>
# # 3 Total Medal with Bubbe Chart

# %% [markdown]
# <div class='tableauPlaceholder' id='viz1630319610790' style='position: relative'><noscript><a href='#'><img alt='&lt;Total Medal with Bubble Chart&gt; ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;2_&#47;2_16303104678480&#47;5&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='2_16303104678480&#47;5' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;2_&#47;2_16303104678480&#47;5&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='ko-KR' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1630319610790');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %% [markdown]
# You can feel that most of medals is centerd the certain nations, espacially, USA, China, ROC. then **We can think that Is olympic race is fair?** , **It has no relation the power of nation?**,**It is sure that the grade of nation is only reflected the efforts of players?**.

# %% [markdown]
# [back to top](#table-of-contents)
# <a id="4"></a>
# # 4 Medal Number & Gold Medal

# %% [markdown]
# <div class='tableauPlaceholder' id='viz1630319769278' style='position: relative'><noscript><a href='#'><img alt='대시보드 2 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;4_&#47;4_16303195888270&#47;2&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='4_16303195888270&#47;2' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;4_&#47;4_16303195888270&#47;2&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='ko-KR' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1630319769278');                    var vizElement = divElement.getElementsByTagName('object')[0];                    if ( divElement.offsetWidth > 800 ) { vizElement.style.width='800px';vizElement.style.height='827px';} else if ( divElement.offsetWidth > 500 ) { vizElement.style.width='800px';vizElement.style.height='827px';} else { vizElement.style.width='100%';vizElement.style.height='877px';}                     var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %% [markdown]
# This **bar chart** shows us the number of each medal by nations more easily. And the below map is used **GIS(geographic information system) charts** for viewing regional characteristics.

# %% [markdown]
# [back to top](#table-of-contents)
# <a id="5"></a>
# # 5 Silver Medal & Bronze Medal

# %% [markdown]
# <div class='tableauPlaceholder' id='viz1630319899740' style='position: relative'><noscript><a href='#'><img alt='대시보드 1 (2) ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;CQ&#47;CQTQDMJ6S&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='path' value='shared&#47;CQTQDMJ6S' /> <param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;CQ&#47;CQTQDMJ6S&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='ko-KR' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1630319899740');                    var vizElement = divElement.getElementsByTagName('object')[0];                    if ( divElement.offsetWidth > 800 ) { vizElement.style.width='800px';vizElement.style.height='827px';} else if ( divElement.offsetWidth > 500 ) { vizElement.style.width='800px';vizElement.style.height='827px';} else { vizElement.style.width='100%';vizElement.style.height='977px';}                     var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %% [markdown]
# This charts show us **the number of Silver medal and bronze medal** by countries. You can easily see that There is a **phenomenon that countries with medals have more.**

# %% [markdown]
# [back to top](#table-of-contents)
# <a id="6"></a>
# # 6 Result
# **Despite the corona virus**, this Olympics was a success due to the sacrifice of many people. Also, in spite of the difficult situation, people wept and cried over the sweat of the players.
# **All the players who participated this time worked hard regardless of their performance**. However, when we analyzed the data, we found that medals were **heavily biased by the strength**, population, and economic level of each country, rather than the effort of the athletes.Therefore, the next EDA will be used together with other data to analyze the correlation.
# If you are interested, please keep looking at my **NOTEBOOK(☞ﾟヮﾟ)☞**.

# %% [markdown]
# **It's late, but all the players did a great job.**

# %% [markdown]
# ![](https://t1.daumcdn.net/cfile/tistory/99304B3359F0F25627)
