# %%
#Import Libs
from pyspark.sql import SparkSession 
from pyspark.ml import Pipeline
from pyspark.ml.regression import RandomForestRegressor
from pyspark.ml.feature import VectorAssembler, StringIndexer, VectorIndexer, MinMaxScaler

# %%
#Create a SparkSession

spark=SparkSession.builder.appName('Cement-Regression').getOrCreate()

# %%
#Read data
df=spark.read.csv('../input/yeh-concret-data/Concrete_Data_Yeh.csv',inferSchema=True,header=True) 
df.show(10)

# %%
#schema of RDD
df.printSchema()

# %%
#Find columns in dataset
df.columns

# %%
# run a sample selection
df.select( 'slag','flyash').show(10)

# %% [markdown]
# ## Visualizations in PYSPARK

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pandas_df = df.toPandas()

# %%
plt.figure(figsize=(10,5))
plt.title('Age distribution')
sns.distplot(pandas_df['age'])

# %% [markdown]
# # Checking For Null Values

# %%
from pyspark.sql.functions import isnan, when, count, col
df.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in df.columns]).show()

# %%
feature = VectorAssembler(inputCols = df.columns[:],outputCol="features")
feature_vector= feature.transform(df)
feature_vector.limit(3).toPandas()

# %%
(train_df, test_df) = feature_vector.randomSplit([0.8, 0.2],seed = 42)

# %%
train_df.printSchema()
