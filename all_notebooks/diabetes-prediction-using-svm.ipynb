# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %% [markdown]
# # 1.  IMPORT DIABETS DATASET

# %%
df=pd.read_csv('../input/diabetes/diabetes.csv')
df.head()

# %% [markdown]
# # Data visualization

# %%
df.info()

# %%
df.shape

# %%
df.describe()

# %%
import missingno as msno
msno.bar(df)

# %%
df['Outcome'].value_counts()

# %%
corr=df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr,square=True,annot=True)

# %%
sns.countplot(df['Outcome'])
plt.figure(figsize=(20,10))
sns.set()

# %%
df.hist(figsize=(20,10))
plt.show()

# %% [markdown]
# 1.  Most of the person have Glucose range between(100-125)
#
# 2.  Most of the person have BloodPressure range between(60-80)
#
# 3.  Most of the person have  BMI between(30-40)
#
# 4.  Most of the person have insulin between(0-100)
#
# 5.  Most of the person have Age range between(20-25)

# %% [markdown]
# # * now lets cover the relationship between different functions

# %%
sns.pairplot(df)

# %%
sns.stripplot(df['Outcome'],df['Glucose'])

plt.show()

# %%
sns.stripplot(df['Outcome'],df['BMI'])
sns.set_theme(style='whitegrid')
plt.show()

# %%
sns.stripplot(df['Outcome'],df['Insulin'])
sns.set_theme(style='whitegrid')
plt.show()

# %%
sns.stripplot(df['Outcome'],df['SkinThickness'])
sns.set_theme(style='whitegrid')
plt.show()

# %%
df['Pregnancies'].unique()

# %%
plt.figure(figsize=(16,8))
sns.stripplot(df['Pregnancies'], df['Outcome'],  palette='pastel', size = 17, linewidth=1,jitter=0.2)

# %% [markdown]
# # Model Working

# %%
input1=df.drop('Outcome',axis='columns')
target=df.Outcome

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(input1,target)

# %%
# scaling the data 

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
print(len(x_train))
print(len(x_test))

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(x_train,y_train)

# %%
model.score(x_test,y_test)

# %%
from sklearn.tree import DecisionTreeClassifier
reg=DecisionTreeClassifier()

# %%
reg.fit(x_train,y_train)

# %%
reg.score(x_test,y_test)

# %%
from sklearn.svm import SVC
ref=SVC()

# %%
ref.fit(x_train,y_train)

# %%
ref.score(x_train,y_train)

# %%
Y_PREDICTED=ref.predict(x_test)
Y_PREDICTED

# %%
data={
    'Algorithm':['logisticregression','DecisionTree','SVM'],
    'Score':[model.score(x_test,y_test),reg.score(x_test,y_test),0.8472222222222222]
}
cnn=pd.DataFrame(data)
cnn

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,Y_PREDICTED)
