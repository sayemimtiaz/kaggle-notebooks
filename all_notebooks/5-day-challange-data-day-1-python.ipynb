# %% [markdown]
# Öncelikler Pandas kütüphanesini eklemeiz (import) gerekiyor ki ilgili kütüphaneyi kullanaiblelim.

# %%
import numpy as np # linear algebra

# %%
pd.read_csv("../input/80-cereals/cereal.csv")

# %% [markdown]
# Notlar Yazmak için kullanıyoruz.

# %%
data = pd.read_csv("../input/80-cereals/cereal.csv")
data.describe()
# data.describe().transpose()
