# %%
import pandas as pd
import numpy as np
import os

# %%
image_list = os.listdir('../input/mendeley-leaves/mendeley_leaf_data/')
print(len(image_list))

# %%
df = pd.read_csv('/kaggle/input/mendeley-leaves/mendeley_leaf_data.csv')
df['source'] = 4
df.head()

# %%
mapping = {'healthy':  4,
           'diseased': 3}

df['label'] = df['label'].map(mapping) 
df['label'].value_counts()

# %%
from sklearn.model_selection import KFold, StratifiedKFold

df['fold'] = -1
skf = StratifiedKFold(n_splits = 5, random_state = 23, shuffle = True)
for fold, (trn_idx, val_idx) in enumerate(skf.split(df, df['label'])):
    df.loc[val_idx, 'fold'] = fold

# %%
# !zip -q -r images.zip ../input/mendeley-leaves/mendeley_leaf_data/*

# %%
df.to_csv('df_4.csv', index = False)
