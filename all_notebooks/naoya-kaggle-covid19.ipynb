# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


selected_country_1 = 'Sri Lanka'
selected_country_2 = 'Sri Lanka'

df1 = pd.read_csv('../input/covid19-global-dataset/worldometer_coronavirus_daily_data.csv',header=0)
df1 = df1[df1['country']==selected_country_1]
df2 = pd.read_csv('../input/covid-world-vaccination-progress/country_vaccinations.csv',header=0)
df2 = df2[df2['country']==selected_country_2]
df1.index = pd.to_datetime(df1['date'])
df2.index = pd.to_datetime(df2['date'])

# %%
print(df1.columns)
print(df2.columns)

# %%
print(np.unique(df1['country']))
print(np.unique(df2['country']))

# %% [markdown]
# # Analysis
#
# From here, I will analyze the data that was loaded as an dataframe object.

# %%
fig,ax = plt.subplots(figsize=(10,5))
plt.plot(df1.index,df1['daily_new_cases'],label='Cases')
ax1 = ax.twinx()
#plt.plot(df2.index,df2['daily_vaccinations'],'r')
ax1.plot(df2.index,df2['daily_vaccinations'],'r',label='Vaccinations')
ax1.legend()
ax.legend()
plt.show()

# %% [markdown]
# # Improved visualization
# From here, we will be using the modules iplot and plotly to make better visualiazation.

# %%
from plotly.offline import iplot #1:20:00辺りから再開
import plotly.graph_objs as go

daily_new_cases = go.Scatter(x=df1.index,y=df1['daily_new_cases'],yaxis='y1',name='Daily confirmed cases')
daily_vaccinations = go.Scatter(x=df2.index,y=df2['daily_vaccinations'],yaxis='y2',name='Daily vaccinations')

layout_obj = go.Layout(title='COVID vs. Vaccines',xaxis=dict(title='Date'),yaxis=dict(title='Daily cases'),yaxis2=dict(title='Vaccinations',side='right',overlaying='y'))
fig = go.Figure(data=[daily_new_cases,daily_vaccinations],layout=layout_obj)
iplot(fig)
fig.write_html('outcome.html')

# %% [markdown]
# ## Colored tables
# ​
# Create colored tables

# %%
style_object = df1.style.background_gradient(cmap='jet').highlight_max('daily_new_cases').set_caption('Daily cases')
display(style_object)

# %%
df1 = pd.read_csv('../input/covid19-global-dataset/worldometer_coronavirus_daily_data.csv',header=0)
df1 = df1.groupby('country').sum()['daily_new_cases'].sort_values(ascending=False)
rank1 = df1.index.get_loc(selected_country_1)+1
#print(df1)
print('the rank of Sri Lanka about daily new cases')
print(rank1)
df2 = pd.read_csv('../input/covid-world-vaccination-progress/country_vaccinations.csv',header=0)
df2 = df2.groupby('country').max()['people_fully_vaccinated_per_hundred'].sort_values(ascending=False)
rank2 = df2.index.get_loc(selected_country_1)+1
#print(df2)
print('the rank of Sri Lanka about people fully vaccinated per hundred')
print(rank2)

# %% [markdown]
# ## Discussion how the Sri Lanka national government is addressing the issue
#
# (ref:https://www.tokutenryoko.com/news/passage/12945)
# I'm sorry but this article written in Japanese...
#
# From the figure about the number moving, it is increasing so much in Sri Lanka nowadays. In April 23, the Sri Lanka Ministry of Public Health showed the movement regulations under 3rd level of alert. In addition, they suggested them that the ministry banned whole events for two weeks from May 3, this article says.
# Considering this information, the government should be now high cautious to COVID-19. It is because recently increasing of number should affect them to behave strictly.
