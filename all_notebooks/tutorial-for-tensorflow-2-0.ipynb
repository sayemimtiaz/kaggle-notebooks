# %% [markdown]
# ![](https://camo.githubusercontent.com/0905c7d634421f8aa4ab3ddf19a582572df568e1/68747470733a2f2f7777772e74656e736f72666c6f772e6f72672f696d616765732f74665f6c6f676f5f736f6369616c2e706e67)

# %% [markdown]
# # Available Frame Work's
# ## 1) [Keras](https://keras.io/)
# ## 2) [Tensorflow](https://www.tensorflow.org/guide)
# ## 3) [Pytorch](https://pytorch.org/docs/stable/index.html)
# ## 4) [Theano](http://deeplearning.net/software/theano/)

# %% [markdown]
# # Pytorch Tutorial For Image Classification ([Leaf Diseas](https://www.kaggle.com/kdnishanth/pytorch-cnn-tutorial-in-gpu))

# %% [markdown]
# # Keras Vs Tensorflow VS PyTorch

# %% [markdown]
# ![](https://lh4.googleusercontent.com/n6a_nlPtqLb5EQ567fSQm3Ohq5LStNWDI4mJyv1kSrQoPNPQZw0Tg8fql5q2TLlaJXtMiQ0qSasBnyHb1k3425dQfu7v9avUqbTrxxBn1_31-JJCjh6h_vFC85CMPV1Jn80PBYgi_xTv-O039w)

# %% [markdown]
# # Tensorflow Fasion-MNIST

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib as pt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print("Tensorflow: " + tf.__version__)
print("-------------------------------\n")
print("Numpy: " + np.__version__)
print("-------------------------------\n")
print("Matplotlib: " + pt.__version__)
print("-------------------------------")

# %% [markdown]
# ## Totaly there are 10 Class for the Fashion MNIST Dataset

# %% [markdown]
# ![](https://miro.medium.com/max/875/1*-kpgaee9X9Gm-SrQKdk_og.png)

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat','Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# ## We are loading the dataset from the keras library for Fashion MNIST and we are spliting the dataset from the Fashion MNIST

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
print("The pixcel size for the each image in Fashion MNIST is: 28 x 28 ")
print("-----------------------------------------------------------------\n")

print("Total number of the training dataset and the pixel size: " + str(len(train_images)))
print("-----------------------------------------------------------------\n")

print("Total number of the testing dataset and the pixel size: " + str(len(test_images)))
print("-----------------------------------------------------------------")

# %% [markdown]
# ## Dataset Image's

# %%
plt.figure(figsize=(15, 10))
for i in range(20):
    plt.subplot(5, 5, i + 1)
    plt.grid(False)
    plt.imshow(train_images[i])
plt.show()

# %% [markdown]
# ## we are converting the image to binary

# %%
plt.figure(figsize=(15, 10))
for i in range(20):
    plt.subplot(5, 5, i + 1)
    plt.grid(False)
    plt.imshow(train_images[i], cmap = plt.cm.binary)
plt.show()

# %% [markdown]
# ## The image value is are in 255 but we want only in the term of 0 or 1 so for that we are going to divide by 255

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %% [markdown]
# ## We are creating the layer for predicting the model and by using the model.summary() function we will tell about the summary of our model as what are all the layers are used in this model

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10)
])
model.summary()

# %% [markdown]
# ## we are using the ['adam' optimizer](https://machinelearningmastery.com/adam-optimization-algorithm-for-deep-learning/#:~:text=What%20is%20the%20Adam%20optimization,iterative%20based%20in%20training%20data.) for updating the weight in the layer

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ## By using model.fit() model we are going to train the model and we can save the model by using the model.save function()

# %%
model.fit(train_images, train_labels, epochs=10)

test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

model.save("Fashion-MNIST.h5")

print('\nTest accuracy:', test_acc)

# %% [markdown]
# # Predicting the model

# %%
prediction = model.predict([test_images])
plt.figure(figsize=(15, 19))
for i in range(30):
    plt.subplot(5, 6, i + 1)
    plt.grid(False)
    plt.imshow(test_images[i],cmap = plt.cm.binary)
    plt.title("prediction: "+ class_names[np.argmax(prediction[i])] +"\n-----------\n" +"Actual: " + class_names[test_labels[i]])
plt.show()

# %% [markdown]
# # Number of Papers Published

# %% [markdown]
# ![](https://miro.medium.com/max/1000/1*4YokbagxkDkolJqWaW_7OA.png)
