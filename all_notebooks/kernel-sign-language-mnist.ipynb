# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# ### Loading data from workspace

# %%
train_data = pd.read_csv('../input/sign_mnist_train.csv') 
train_data.head()
# Out:
#    label  pixel1  pixel2    ...     pixel782  pixel783  pixel784
# 0      3     107     118    ...          204       203       202
# 1      6     155     157    ...          103       135       149
# 2      2     187     188    ...          195       194       195
# 3      2     211     211    ...          222       229       163
# 4     13     164     167    ...          163       164       179
#
# [5 rows x 785 columns]

# %%
test_data = pd.read_csv('../input/sign_mnist_test.csv') 
test_data.head()
# Out:
#    label  pixel1  pixel2    ...     pixel782  pixel783  pixel784
# 0      6     149     149    ...          112       120       107
# 1      5     126     128    ...          184       182       180
# 2     10      85      88    ...          225       224       222
# 3      0     203     205    ...          240       253       255
# 4      3     188     191    ...           46        46        53
#
# [5 rows x 785 columns]

# %% [markdown]
# ### Creating data-sets

# %%
X_train = train_data.drop(columns='label').values
y_train = train_data['label'].values

# %%
X_test = test_data.drop(columns='label').values
y_test = test_data['label'].values

# %%
X_train = X_train.reshape(len(X_train),28,28,1)
X_test = X_test.reshape(len(X_test),28,28,1)

# %%
# data normalization

X_train = X_train / 255.
X_test = X_test / 255.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.imshow(X_train[0].reshape(28,28))

# %%
from tensorflow import keras
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
# one-hot encode target column
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
# define some callbacks

from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

class my_max_acc_callback(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('acc')>0.99):
      print("\nReached 99% accuracy so cancelling training!")
      self.model.stop_training = True

# my max accuracy callback
my_mxaccb = my_max_acc_callback()

# checkpoint for best weights
filepath='model-best-weights.hdf5'
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='auto')

# early stopping
earlyStopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='auto', restore_best_weights=True)

# reducing_Learning_Rate
reduce_lr_loss = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=7, verbose=1, min_delta=1e-4, mode='auto')

#collecting all callbacks
callbacks_list = [my_mxaccb, checkpoint, earlyStopping, reduce_lr_loss]

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout

# create model
model = Sequential()

#add model layers
model.add(Conv2D(64, kernel_size=3, activation='relu', input_shape=(28,28,1)))
model.add(MaxPooling2D(2,2))
#
model.add(Conv2D(64, kernel_size=3, activation='relu'))
model.add(MaxPooling2D(2,2))
#
model.add(Dense(256,activation='relu'))
#
model.add(Conv2D(64, kernel_size=3, activation='relu'))
model.add(MaxPooling2D(2,2))
#
model.add(Flatten())
model.add(Dropout(0.2))
#
model.add(Dense(256,activation='relu'))
model.add(Dense(25, activation='softmax'))

model.summary()

model.compile(
    loss = 'categorical_crossentropy', 
    optimizer='adam', 
    metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 26, 26, 64)        640
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# dense_4 (Dense)              (None, 5, 5, 256)         16640
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 3, 3, 64)          147520
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 1, 1, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               16640
# _________________________________________________________________
# dense_6 (Dense)              (None, 25)                6425
# =================================================================
# Total params: 224,793
# Trainable params: 224,793
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    X_train, 
    y_train,
    validation_split=0.3,
    epochs=50,
    verbose=1,
    callbacks=callbacks_list)
# Out:
# Train on 19218 samples, validate on 8237 samples
# Epoch 1/50
# 19218/19218 [==============================] - 5s 250us/step - loss: 2.0508 - acc: 0.3405 - val_loss: 0.8336 - val_acc: 0.7410
#
# Epoch 00001: val_acc improved from -inf to 0.74105, saving model to model-best-weights.hdf5
# Epoch 2/50
# 19218/19218 [==============================] - 4s 214us/step - loss: 0.8453 - acc: 0.7097 - val_loss: 0.4801 - val_acc: 0.8354
#
# Epoch 00002: val_acc improved from 0.74105 to 0.83538, saving model to model-best-weights.hdf5
# Epoch 3/50
# 19218/19218 [==============================] - 4s 213us/step - loss: 0.5322 - acc: 0.8172 - val_loss: 0.2124 - val_acc: 0.9523
#
# Epoch 00003: val_acc improved from 0.83538 to 0.95229, saving model to model-best-weights.hdf5
# Epoch 4/50
# 19218/19218 [==============================] - 4s 216us/step - loss: 0.3886 - acc: 0.8665 - val_loss: 0.1151 - val_acc: 0.9744
#
# Epoch 00004: val_acc improved from 0.95229 to 0.97438, saving model to model-best-weights.hdf5
# Epoch 5/50
# 19218/19218 [==============================] - 4s 214us/step - loss: 0.2789 - acc: 0.9045 - val_loss: 0.0830 - val_acc: 0.9809
#
# Epoch 00005: val_acc improved from 0.97438 to 0.98094, saving model to model-best-weights.hdf5
# Epoch 6/50
# 19218/19218 [==============================] - 4s 214us/step - loss: 0.2211 - acc: 0.9270 - val_loss: 0.0513 - val_acc: 0.9896
#
# Epoch 00006: val_acc improved from 0.98094 to 0.98956, saving model to model-best-weights.hdf5
# Epoch 7/50
# 19218/19218 [==============================] - 4s 215us/step - loss: 0.1879 - acc: 0.9395 - val_loss: 0.0540 - val_acc: 0.9911
#
# Epoch 00007: val_acc improved from 0.98956 to 0.99114, saving model to model-best-weights.hdf5
# Epoch 8/50
# 19218/19218 [==============================] - 4s 214us/step - loss: 0.1533 - acc: 0.9490 - val_loss: 0.0287 - val_acc: 0.9943
#
# Epoch 00008: val_acc improved from 0.99114 to 0.99429, saving model to model-best-weights.hdf5
# Epoch 9/50
# 19218/19218 [==============================] - 4s 214us/step - loss: 0.1364 - acc: 0.9563 - val_loss: 0.0327 - val_acc: 0.9915
#
# Epoch 00009: val_acc did not improve from 0.99429
# Epoch 10/50
# 19218/19218 [==============================] - 5s 246us/step - loss: 0.1221 - acc: 0.9616 - val_loss: 0.0175 - val_acc: 0.9977
#
# Epoch 00010: val_acc improved from 0.99429 to 0.99769, saving model to model-best-weights.hdf5
# Epoch 11/50
# 19218/19218 [==============================] - 5s 248us/step - loss: 0.1039 - acc: 0.9666 - val_loss: 0.0181 - val_acc: 0.9964
#
# Epoch 00011: val_acc did not improve from 0.99769
# Epoch 12/50
# 19218/19218 [==============================] - 4s 220us/step - loss: 0.0975 - acc: 0.9686 - val_loss: 0.0137 - val_acc: 0.9977
#
# Epoch 00012: val_acc did not improve from 0.99769
# Epoch 13/50
# 19218/19218 [==============================] - 4s 233us/step - loss: 0.0968 - acc: 0.9688 - val_loss: 0.0099 - val_acc: 0.9973
#
# Epoch 00013: val_acc did not improve from 0.99769
# Epoch 14/50
# 19218/19218 [==============================] - 5s 237us/step - loss: 0.0865 - acc: 0.9713 - val_loss: 0.0213 - val_acc: 0.9954
#
# Epoch 00014: val_acc did not improve from 0.99769
# Epoch 15/50
# 19218/19218 [==============================] - 4s 224us/step - loss: 0.0829 - acc: 0.9733 - val_loss: 0.0138 - val_acc: 0.9966
#
# Epoch 00015: val_acc did not improve from 0.99769
# Epoch 16/50
# 19218/19218 [==============================] - 4s 214us/step - loss: 0.0697 - acc: 0.9779 - val_loss: 0.0060 - val_acc: 0.9995
#
# Epoch 00016: val_acc improved from 0.99769 to 0.99951, saving model to model-best-weights.hdf5
# Epoch 17/50
# 19218/19218 [==============================] - 4s 214us/step - loss: 0.0693 - acc: 0.9787 - val_loss: 0.0058 - val_acc: 0.9993
#
# Epoch 00017: val_acc did not improve from 0.99951
# Epoch 18/50
# 19218/19218 [==============================] - 4s 216us/step - loss: 0.0620 - acc: 0.9803 - val_loss: 0.0168 - val_acc: 0.9965
#
# Epoch 00018: val_acc did not improve from 0.99951
# Epoch 19/50
# 19218/19218 [==============================] - 4s 214us/step - loss: 0.0685 - acc: 0.9788 - val_loss: 0.0051 - val_acc: 0.9994
#
# Epoch 00019: val_acc did not improve from 0.99951
# Epoch 20/50
# 19218/19218 [==============================] - 4s 214us/step - loss: 0.0613 - acc: 0.9810 - val_loss: 0.0094 - val_acc: 0.9981
#
# Epoch 00020: val_acc did not improve from 0.99951
# Epoch 21/50
# 19218/19218 [==============================] - 4s 214us/step - loss: 0.0536 - acc: 0.9841 - val_loss: 0.0103 - val_acc: 0.9984
#
# Epoch 00021: val_acc did not improve from 0.99951
# Epoch 22/50
# 19218/19218 [==============================] - 4s 214us/step - loss: 0.0573 - acc: 0.9819 - val_loss: 0.0042 - val_acc: 0.9992
#
# Epoch 00022: val_acc did not improve from 0.99951
# Epoch 23/50
# 19218/19218 [==============================] - 4s 214us/step - loss: 0.0545 - acc: 0.9829 - val_loss: 0.0051 - val_acc: 0.9992
#
# Epoch 00023: val_acc did not improve from 0.99951
# Epoch 24/50
# 19218/19218 [==============================] - 4s 214us/step - loss: 0.0583 - acc: 0.9827 - val_loss: 0.0137 - val_acc: 0.9964
#
# Epoch 00024: val_acc did not improve from 0.99951
# Epoch 25/50
# 19218/19218 [==============================] - 4s 214us/step - loss: 0.0403 - acc: 0.9871 - val_loss: 0.0021 - val_acc: 0.9999
#
# Epoch 00025: val_acc improved from 0.99951 to 0.99988, saving model to model-best-weights.hdf5
# Epoch 26/50
# 19218/19218 [==============================] - 4s 214us/step - loss: 0.0484 - acc: 0.9847 - val_loss: 0.0071 - val_acc: 0.9978
#
# Epoch 00026: val_acc did not improve from 0.99988
# Epoch 27/50
# 19218/19218 [==============================] - 4s 214us/step - loss: 0.0517 - acc: 0.9832 - val_loss: 0.0038 - val_acc: 0.9995
#
# Epoch 00027: val_acc did not improve from 0.99988
# Epoch 28/50
# 19218/19218 [==============================] - 4s 214us/step - loss: 0.0422 - acc: 0.9867 - val_loss: 0.0072 - val_acc: 0.9989
#
# Epoch 00028: val_acc did not improve from 0.99988
# Epoch 29/50
# 19218/19218 [==============================] - 4s 214us/step - loss: 0.0397 - acc: 0.9862 - val_loss: 0.0024 - val_acc: 0.9998
#
# Epoch 00029: val_acc did not improve from 0.99988
# Epoch 30/50
# 19218/19218 [==============================] - 4s 215us/step - loss: 0.0429 - acc: 0.9863 - val_loss: 0.0024 - val_acc: 0.9995
#
# Epoch 00030: val_acc did not improve from 0.99988
# Epoch 31/50
# 19218/19218 [==============================] - 4s 214us/step - loss: 0.0372 - acc: 0.9877 - val_loss: 0.0045 - val_acc: 0.9992
#
# Epoch 00031: val_acc did not improve from 0.99988
# Epoch 32/50
# 19218/19218 [==============================] - 4s 229us/step - loss: 0.0347 - acc: 0.9895 - val_loss: 0.0123 - val_acc: 0.9965
#
# Epoch 00032: val_acc did not improve from 0.99988
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 33/50
# 19218/19218 [==============================] - 5s 236us/step - loss: 0.0226 - acc: 0.9926 - val_loss: 0.0018 - val_acc: 0.9998
#
# Reached 99% accuracy so cancelling training!
#
# Epoch 00033: val_acc did not improve from 0.99988

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'ro-', label='Training accuracy')
plt.plot(epochs, val_acc, 'bo-', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()

# %%
plt.plot(epochs, loss, 'go-', label='Training loss')
plt.plot(epochs, val_loss, 'yo-', label='Validation loss')
plt.title('Training and validation loss')
plt.legend(loc=0)
plt.figure()

# %%
# testing model on test set
test_loss = model.evaluate(X_test, y_test)
print(model.metrics_names)
print(test_loss)
# Out:
# 7172/7172 [==============================] - 1s 74us/step
# ['loss', 'acc']
# [0.25022199526632727, 0.9307027328499721]
