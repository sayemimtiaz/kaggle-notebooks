# %% [markdown]
# # Data Analyst Job : Analyze and Visualization

# %% [markdown]
# In this notebook, I analyze the dataset and then I visualize the dataset. In this dataset as we can see there are different countries having Data Analyst Jobs. So we analyze the dataset for perfect visualizatin. The dataset has following colmns :
# *     Unnamed: 0
# *     Job Title
# *     Salary Estimate
# *    Job Description
# *     Rating
# *     Company Name
# *     Location
# *     Headquarters
# *     Size
# *    Founded
# *    Type of ownership
# *   Industry
# *    Sector
# *    Revenue
# *    Competitors
# *    Easy Apply

# %% [markdown]
# First we import some necessary libraries like we have numpy, pandas, matplotlib, Plotly.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# %%
data = pd.read_csv('../input/data-analyst-jobs/DataAnalyst.csv')

# %% [markdown]
# Before we start analyzing have a look at the dataset.

# %%
data.head()

# %%
data.info()

# %%
data.isnull().sum()

# %% [markdown]
# Guys we have to clean our dataset because it has some text value in it.

# %% [markdown]
# **Data Cleaning**

# %% [markdown]
# Info method shows that there are no null value but if we observe the dataset heading and tail we will come to know that instead of null value they have put -1 so lets do one thing we will replace -1 with np.nan so we can calculate the missing values in dataset for better observation.

# %%
data.replace(to_replace =-1 , value=np.nan,inplace=True)

# %%
data.replace(to_replace ='-1' , value=np.nan,inplace=True)

# %%
data.replace(to_replace =-1.0 , value=np.nan,inplace=True)

# %%
data.info()

# %%
def FindingMissingValues(dataFrame):
    for col in dataFrame.columns:
        print('{0:.2f}% or {1} values are Missing in {2} Column'.format(dataFrame[col].isna().sum()/len(dataFrame)*100,dataFrame[col].isna().sum(),col),end='\n\n')

FindingMissingValues(data)

# %% [markdown]
# 96.45% or 2173 values are Missing in Easy Apply Column
#
# 76.88% or 1732 values are Missing in Competitors Column
#
# There are more than 50% values are missing in these 2 Column
#
# so we will simply drop the Column becaue there are not enough data to do Forward,Backward, Mean, Median , Mode or Imputer Fill

# %%
data.drop(['Easy Apply','Competitors'],1,inplace = True)

# %% [markdown]
# Job Description Column have huge amount of text data which is not required for this EDA so we will drop this column (But we will use this in next Version)
#
# And we also know that If a Person is Appointed as Data Analyst or for any Job Role then he or she must have great idea about that role

# %%
data.drop('Job Description',1,inplace=True)

# %%
import re

# %% [markdown]
# In Company Column we can see that data have \n3.8 as suffix where 3.8 is rating of company and we will eliminate this and only keep the Company name in that column because we already have a seprate Rating Column.

# %%
data['Company Name'] = data['Company Name'].apply(lambda x: re.sub(r'\n.*','',str(x)))

# %% [markdown]
# We have Successfully cleaned the data now we can remove some column
#
# * Job Title
# * Salary Estimate
# * Size
# * Revenue
# because we have successfully extracted usefull data

# %%
data.drop(['Job Title','Salary Estimate','Size','Revenue'],1,inplace = True)
data.head(10)

# %% [markdown]
# **Let's do some visualizations.**

# %%
import plotly.express as px
import seaborn as sns

# %% [markdown]
# **HeatMap Visualization**

# %%
sns.heatmap(data.corr(), annot =True)

# %%
data.info()

# %% [markdown]
# **Plot - 1**

# %%
fig = px.scatter(data, x="Rating", y="Company Name", 
                 color="Rating", 
                 hover_data=['Headquarters','Location', 'Type of ownership', 'Industry', 'Sector'], 
                 title = "Data Analyst jobs")
fig.show()

# %% [markdown]
# **Plot - 2**

# %%
import plotly.graph_objects as go
fig2 = go.Figure(data=go.Scatter(
    y = data['Location'],
    mode='markers',
    marker=dict(
        size=16,
        color=data['Rating'], #set color equal to a variable
        colorscale='Viridis', # one of plotly colorscales
        showscale=True
    )
))
fig2.update_layout(title='Data Analyst Jobs',
                  yaxis_title="Location")
fig2.show()

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# **Plot - 3**

# %%
fig2 = go.Figure(data=go.Scatter(x=data['Headquarters'],
                                y=data['Company Name'],
                                mode='markers',
                                marker_color=data['Rating'],
                                )) 
fig2.update_layout(title='Data Analyst Jobs',
                  xaxis_title="Headquaters",
                  yaxis_title="Company Name")
fig2.show()

# %% [markdown]
# Guys, hope you like these visualization please upvote.
# Thanks for reading this.

# %% [markdown]
# Till then **Enjoy Machine Learning**
