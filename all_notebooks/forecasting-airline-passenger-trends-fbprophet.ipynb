# %%
import numpy as np
import pandas as pd
import os
for dirname, _, filenames in os.walk('/kaggle/input/airlines-passenger-data'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv('/kaggle/input/airlines-passenger-data/international-airline-passengers.csv')

# %%
df.head()

# %%
df.columns

# %%
df.rename(columns = {'International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60':'Passengers (in thousands)'}, inplace = True)

# %%
df.head()

# %%
import fbprophet
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.tail()

# %%
df.plot()

# %%
#Changing the column names because FBprophet requires the date feature to be 'ds' and output to be 'y'
df.columns =  ['ds','y']
df.head()

# %%
df.ds.unique()

# %%
df.drop(144, axis = 0, inplace = True)

# %%
df.iloc[144]

# %%
df.iloc[143]

# %%
df['ds'] = pd.to_datetime(df['ds'])

# %%
df.head()

# %%
df.dtypes

# %%
from fbprophet import Prophet
dir(Prophet)

# %%
model = Prophet()

# %%
model.fit(df)

# %%
model.component_modes

# %%
model.plot_components

# %%
df.tail()

# %%
#Creating future dates for the following year
future_dates = model.make_future_dataframe(periods=365)

# %%
future_dates.tail()

# %%
prediction = model.predict(future_dates)
prediction.head()

# %%
model.plot(prediction)

# %%
#Yearly projections
model.plot_components(prediction)

# %%
'''
Training set 
1960-1961
Testing set 
1961-1962
Validation set
1962-1963
'''

# %%
from fbprophet.diagnostics import cross_validation
df_cv = cross_validation(model, initial = '730 days', period = '180 days', horizon = '365 days')
df_cv.head()

# %%
from fbprophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv)
df_p.head()

# %%
from fbprophet.plot import plot_cross_validation_metric
fig = plot_cross_validation_metric(df_cv, metric = 'rmse')

# %%
df_p
