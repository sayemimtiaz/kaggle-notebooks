# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import csv
import random
import math
import operator
import pandas as pd
import numpy as np

class Dataloader:
    def __init__(self, path):
        self.data = pd.read_csv(path)
        self.length = len(self.data)
        #print(self.data.head())
        #self.drop_address()
        #self.feature, self.label = self.get_feature_label()
        #self.normalize()
        #self.bias()

# %% [markdown]
# # Case: 2 datapoints X:[number of rooms] Y:[Price]
#
# y = ax+b
# cost = sum(y'-ax-b)^2
#
# To find the parameters we need to minimize the cost for best fit line
#
# Taking partial derivatives d(cost)/da = 0 and d(cost)/db = 0
#
# -2(y'-ax-b) = 0
#
# a = (y'_mean - b*x_mean)
#
# b = sum(x*y - x*y_mean)/ sum(x^2 - x*x_mean)
#
# # Case multivariate regression
#
# The parameter estimation can be extended to other features since partial derivation will treat other parameters as constant.

# %%
class LinearRegression:
    def __init__(self, path='../input/usa-housingcsv/USA_Housing.csv'):
        self.dataloader = Dataloader(path)
        self.data = pd.read_csv(path)
        #self.train, self.val = self.dataloader.train_val_split
        
    def basic_two_datapoints(self):
        self.datapoints = self.data[:2]
        #Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
        #'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address']
        Y_datapoints = self.datapoints['Price']
        X_datapoints = self.datapoints['Avg. Area Number of Rooms']
        print(X_datapoints,Y_datapoints)
        print(np.mean(X_datapoints))
        
        # Y = a + BX
        #parameter estimation a = y_mean - b*x_mean
        # b = sum(xy - xy_mean)/ sum(x^2 - x*x_mean)
        b_n,b_d = 0,0
        
        for i in range(len(self.datapoints)):
            b_n += (X_datapoints[i] - np.mean(X_datapoints))*(Y_datapoints[i] - np.mean(Y_datapoints))
            b_d += (X_datapoints[i] - np.mean(X_datapoints))**2
        
        b = b_n/b_d
        
        a = np.mean(Y_datapoints) - b*np.mean((X_datapoints))
        
        #testing for error
        print("error + {error}".format(error = a + b*np.mean(X_datapoints) - np.mean(Y_datapoints)))
        
        
    def fit(self):
        #taking whole data into account for multivariate regression
        #finding parameters = len(self.data.columns)
        parametercount = 0
        for i in range (len(self.data.columns)):
            b_n,b_d = 0,0
        
            for i in range(len(self.datapoints)):
                b_n += (X_datapoints[i] - np.mean(X_datapoints))*(Y_datapoints[i] - np.mean(Y_datapoints))
                b_d += (X_datapoints[i] - np.mean(X_datapoints))**2
        
            b_dict[parametercount] = b_n/b_d
            parametercount += 1
        print(b_dict)
            
    
    def get_mse(self):
        #difference in predicted value and labeled value
        errorsum = 0
        for i in range(len(testdata)):
            errorsum += (y_pred - y_labeled)**2
        return errorsum/len(testdata)

# %%
if __name__ == '__main__':
    lr = LinearRegression()
    lr.basic_two_datapoints()
    lr.fit()
    #print('MSE:', lr.get_mse())
