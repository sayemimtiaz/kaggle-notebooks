# %% [markdown]
# Importing required Libraries

# %%
import numpy as np
import pandas as pd 

from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import os
print(os.listdir("../input"))

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# ['Library Collection Inventory FAQs.pdf', 'library-collection-inventory.csv', 'socrata_metadata.json']

# %% [markdown]
# Readying the data for analysis (as per Kaggle bot Introductory kernel)

# %%
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = (nCol + nGraphPerRow - 1) / nGraphPerRow
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# %%
# Correlation matrix
def plotCorrelationMatrix(df, graphWidth):
    filename = df.dataframeName
    df = df.dropna('columns') # drop columns with NaN
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    if df.shape[1] < 2:
        print(f'No correlation plots shown: The number of non-NaN or constant columns ({df.shape[1]}) is less than 2')
        return
    corr = df.corr()
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title(f'Correlation Matrix for {filename}', fontsize=15)
    plt.show()

# %%
#Scatter and density plots
def plotScatterMatrix(df, plotSize, textSize):
    df = df.select_dtypes(include =[np.number]) # keep only numerical columns
    # Remove rows and columns that would lead to df being singular
    df = df.dropna('columns')
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    columnNames = list(df)
    if len(columnNames) > 10: # reduce the number of columns for matrix inversion of kernel density plots
        columnNames = columnNames[:10]
    df = df[columnNames]
    ax = pd.plotting.scatter_matrix(df, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = df.corr().values
    for i, j in zip(*plt.np.triu_indices_from(ax, k = 1)):
        ax[i, j].annotate('Corr. coef = %.3f' % corrs[i, j], (0.8, 0.2), xycoords='axes fraction', ha='center', va='center', size=textSize)
    plt.suptitle('Scatter and Density Plot')
    plt.show()

# %% [markdown]
# Readying in the data from the csv file

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
# library-collection-inventory.csv has 26817320 rows in reality, but we are only loading/previewing the first 1000 rows
df1 = pd.read_csv('../input/library-collection-inventory.csv', delimiter=',', nrows = nRowsRead)
df1.dataframeName = 'library-collection-inventory.csv'
nRow, nCol = df1.shape

# %% [markdown]
# First five rows of the dataset

# %%
df1.head()
# Out:
#     BibNum    ...    ItemCount
# 0  3011076    ...            1
# 1  2248846    ...            1
# 2  3209270    ...            1
# 3  1907265    ...            1
# 4  1644616    ...            1
#
# [5 rows x 13 columns]

# %% [markdown]
# Checking missing values

# %%
df1.isnull().sum()
# Out:
# BibNum               0
# Title               12
# Author             175
# ISBN               233
# PublicationYear     20
# Publisher           20
# Subjects            40
# ItemType             0
# ItemCollection       0
# FloatingItem       850
# ItemLocation         0
# ReportDate           0
# ItemCount            0
# dtype: int64

# %% [markdown]
# Looking at the missing vales in detail

# %%
row = df1.isnull().any(axis = 1)
column = df1.isnull().any(axis = 0)
df1.loc[row,column]
# Out:
#                                                  Title     ...      FloatingItem
# 1    Naruto. Vol. 1, Uzumaki Naruto / story and art...     ...               NaN
# 2    Peace, love & Wi-Fi : a ZITS treasury / by Jer...     ...               NaN
# 3       The Paris pilgrims : a novel / Clancy Carlile.     ...               NaN
# 4    Erotic by nature : a celebration of life, of l...     ...               NaN
# 5    Children of Cambodia's killing fields : memoir...     ...               NaN
# 6    Anti-Zionism : analytical reflections / editor...     ...               NaN
# 7              Hard-hearted Highlander / Julia London.     ...               NaN
# 8                 The Sandcastle Empire / Kayla Olson.     ...               NaN
# 9    Doctor Who. The return of Doctor Mysterio / BB...     ...          Floating
# 10   Burnt toast makes you sing good : a memoir of ...     ...               NaN
# 11   Barbie & her sisters in the great puppy advent...     ...          Floating
# 12   Stop bullying now! [videorecording] : Take a s...     ...               NaN
# 13            The only child : a novel / Andrew Pyper.     ...               NaN
# 14   The Jolley-Rogers and the monster's gold / Jon...     ...               NaN
# 15   Duke in his own words : John Wayne's life in l...     ...               NaN
# 16           The Alchemists' Council / Cynthea Masson.     ...               NaN
# 17   Parrots of the wild : a natural history of the...     ...               NaN
# 18   The aromatherapy garden : growing fragrant pla...     ...               NaN
# 19   The walking dead. Volume 8, Made to suffer / [...     ...               NaN
# 20                           Naked '76 / Kevin Brooks.     ...               NaN
# 21            Abakada ng pag-ibig : Paula / Maia Jose.     ...               NaN
# 22            Broadcasting yearbook--marketbook issue.     ...               NaN
# 23                     House of dreams / Brenda Joyce.     ...               NaN
# 24   Recentering the universe : the radical theorie...     ...               NaN
# 25   Take a bow-wow / by Kristin Earhart ; illustra...     ...               NaN
# 26   Everyday [videorecording] / Sundance Selects ;...     ...          Floating
# 27   Morningstar guide to mutual funds : five-star ...     ...               NaN
# 28   The great powers outage / William Boniface ; i...     ...               NaN
# 29                   Last day, hooray! / Nancy Poydar.     ...               NaN
# 30   My old lady [videorecording] / Universal ; Coh...     ...          Floating
# ..                                                 ...     ...               ...
# 969  A lady cyclist's guide to Kashgar [text (large...     ...               NaN
# 970                 I love vacations / by Anna Walker.     ...               NaN
# 971  Wench [text (large print)] / Dolen Perkins-Val...     ...               NaN
# 972  The Red Skelton show. The best of the early ye...     ...          Floating
# 973  The talented Clementine / Sara Pennypacker ; p...     ...               NaN
# 974                             Witness / Karen Hesse.     ...               NaN
# 975                  West and east / Harry Turtledove.     ...               NaN
# 976  Mighty Jack. Book one / Ben Hatke ; color by A...     ...               NaN
# 977  Bublik dl︠i︡a gumanoida / Valentina Dëgteva ; ...     ...               NaN
# 978  I scream, you scream : a mystery à la mode / W...     ...               NaN
# 979  Painting the picture : imagery and description...     ...               NaN
# 980  The Missouri breaks [videorecording] / Metro G...     ...          Floating
# 981                                                NaN     ...               NaN
# 982           I'll give you the sun / by Jandy Nelson.     ...               NaN
# 983  The English origin of John Ogle, first of the ...     ...               NaN
# 984  My just desire : the life of Bess Ralegh, wife...     ...               NaN
# 985  Wild crush : a wild cards novel / Simone Elkeles.     ...               NaN
# 986  Gabe : a story of me, my dog, and the 1970s / ...     ...               NaN
# 987  Your power to heal : resolving psychological b...     ...               NaN
# 988  OMG [videorecording] : oh my God! / Spice Stud...     ...               NaN
# 990            Rock or bust [sound recording] / AC/DC.     ...          Floating
# 991  Buddy and Earl go exploring / Maureen Fergus ;...     ...               NaN
# 992    Pacific Northwest road trip / Allison Williams.     ...               NaN
# 993  Marriages of Bute and Warren Counties, North C...     ...               NaN
# 994  All paws on deck / by Jessica Young ; illustra...     ...               NaN
# 995  The amazing Spider-man. Renew your vows / writ...     ...               NaN
# 996  Twentieth-century Spanish American fiction / N...     ...               NaN
# 997  Suicide squads, W.W. II : Axis and Allied spec...     ...               NaN
# 998  Word like a bell : John Keats, music and the r...     ...               NaN
# 999                Making a comeback / by Julie Blair.     ...               NaN
#
# [959 rows x 7 columns]

# %% [markdown]
# Entries with missing Title of the Book

# %%
df1[df1['Title'].isnull()].index.tolist()
# Out:
# [64, 68, 97, 129, 149, 241, 466, 628, 787, 798, 902, 981]

# %% [markdown]
# Dropping all the 12 entries with missing title

# %%
df1.drop(index = [64, 68, 97, 129, 149, 241, 466, 628, 787, 798, 902, 981], inplace = True)

# %% [markdown]
# Imputing missing values for the remaining columns

# %%
df1['FloatingItem'].fillna('Not Applicable', inplace = True)

df1['Publisher'].fillna('Unknown', inplace = True)
df1['Author'].fillna('Unknown', inplace = True)
df1['Subjects'].fillna('Unknown', inplace = True)

df1['ISBN'].fillna(0, inplace = True)
df1['PublicationYear'].fillna(0, inplace = True)

# %% [markdown]
# Checking for missing values after imputation

# %%
df1.isnull().sum()
# Out:
# BibNum             0
# Title              0
# Author             0
# ISBN               0
# PublicationYear    0
# Publisher          0
# Subjects           0
# ItemType           0
# ItemCollection     0
# FloatingItem       0
# ItemLocation       0
# ReportDate         0
# ItemCount          0
# dtype: int64

# %% [markdown]
# Unique item types, item collections and Reporting Dates

# %%
print('Item collections : {}'.format(df1['ItemCollection'].nunique()))
print('Item types : {}'.format(df1['ItemType'].nunique()))
print('Report Dates(unique) : {}'.format(df1['ReportDate'].nunique()))
# Out:
# Item collections : 95
# Item types : 10
# Report Dates(unique) : 1

# %% [markdown]
# All the data has been reported on a single date

# %% [markdown]
# **Analyzing data by Publishing date**

# %% [markdown]
# Slicing out the required data for 2014

# %%
df_2014 = df1.ix[df1['PublicationYear'] == '2014.',[0,1,5]] 
df_2014
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#       BibNum                        ...                                                                  Publisher
# 0    3011076                        ...                                                           Simon Spotlight,
# 2    3209270                        ...                                                 Andrews McMeel Publishing,
# 10   3018388                        ...                                                                    Viking,
# 34   2963138                        ...                                                          Simon & Schuster,
# 57   2987954                        ...                                                        St. Martin's Press,
# 102  3032381                        ...                                                          Simon & Schuster,
# 105  2973939                        ...                                            Algonquin Books of Chapel Hill,
# 116  3044157                        ...                                     Thomas Dunne Books/St. Martin's Press,
# 134  3056858                        ...                          Thorndike Press, a part of Gale, Cengage Learn...
# 303  2953046                        ...                                                                    Viking,
# 319  2939806                        ...                           Children's Press, an imprint of Scholastic Inc.,
# 340  3042829                        ...                                                                  Oneworld,
# 393  3023581                        ...                                                        G.P. Putnam's Sons,
# 403  3102181                        ...                                                Dorling Kindersley Limited,
# 440  3056034                        ...                                           Archie Comic Publications, Inc.,
# 449  3019396                        ...                                                             DK Publishing,
# 484  2947343                        ...                                                           Alfred A. Knopf,
# 492  3027924                        ...                                                         The Penguin Press,
# 519  2994958                        ...                                                             Dk Publishing,
# 552  3014868                        ...                                                          Fair Winds Press,
# 553  3023025                        ...                                                          Scholastic Press,
# 555  3046449                        ...                                                          Candlewick Press,
# 574  2954461                        ...                                                           Alfred A. Knopf,
# 585  2994581                        ...                                                          Simon & Schuster,
# 632  2969813                        ...                                                           Thorndike Press,
# 646  3038689                        ...                                                                     Forge,
# 650  2987844                        ...                                                                   Redhook,
# 679  3043055                        ...                                              Victory Belt Publishing Inc.,
# 744  2982143                        ...                                                               Atria Books,
# 863  2973424                        ...                                                                  Immedium,
# 871  3034313                        ...                                                         Milkweed Editions,
# 873  3011130                        ...                                                        Threshold Editions,
# 927  3042073                        ...                                                             Pegasus Crime,
#
# [33 rows x 3 columns]

# %% [markdown]
# Books published in 2014 and no. of distinct publishers in the same year

# %%
print('Books Published in 2014 : {}'.format(df_2014['BibNum'].count()))
print('Unique publishers of books in 2014 : {}'.format(df_2014['Publisher'].count()))
# Out:
# Books Published in 2014 : 33
# Unique publishers of books in 2014 : 33

# %% [markdown]
# All the books have been published by different publishers

# %% [markdown]
# Slicing the data for the year 2016

# %%
df_2016 = df1.ix[df1['PublicationYear'] == '2016.',[0,1,5]] 
df_2016
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#       BibNum                        ...                                                                  Publisher
# 16   3167678                        ...                                                                 ECW Press,
# 18   3165211                        ...                                                              Timber Press,
# 20   3199800                        ...                                                           Carolrhoda Labs,
# 44   3259688                        ...                                                       Sandstone Press Ltd,
# 50   3160162                        ...                                                                   Aladdin,
# 59   3167001                        ...                                                               Atria Books,
# 70   3220551                        ...                                                           Xiao lu wen hua,
# 182  3146689                        ...                                                                       Tor,
# 185  3170881                        ...                                                          Scholastic Press,
# 187  3199176                        ...                                                              Puffin Books,
# 193  3204834                        ...                                                              Little Simon,
# 207  3193472                        ...                                                         Drawn & Quarterly,
# 214  3246869                        ...                                                           Tate Publishing,
# 226  3181971                        ...                                                        St. Martin's Press,
# 244  3165397                        ...                                                    Henry Holt and Company,
# 259  3168600                        ...                          BOOM! Box, a division of Boom Entertainment, I...
# 273  3170624                        ...                                               Thorndike Press Large Print,
# 345  3168770                        ...                                                           Disney Hyperion,
# 347  3165478                        ...                                                      Dalkey Archive Press,
# 419  3268926                        ...                                                            AmazonCrossing,
# 434  3203911                        ...                                                                    Harper,
# 476  3213833                        ...                                                          Nhà xuất bản Trẻ,
# 494  3144505                        ...                                                           Alfred A. Knopf,
# 554  3195564                        ...                                                           Scholastic Inc.,
# 571  3181879                        ...                                                                 Papercutz,
# 610  3149293                        ...                                                               Titan Books,
# 622  3164969                        ...                                                          Candlewick Press,
# 634  3155194                        ...                                          Atheneum Books for Young Readers,
# 642  3184743                        ...                                                       National Geographic,
# 659  3174948                        ...                                                           Simon Spotlight,
# 702  3219307                        ...                          Published by Ka-BOOM!, a division of Boom Ente...
# 725  3278114                        ...                                                            Joe Books Ltd.,
# 807  3184599                        ...                                                       Nhà xuất bản Phụ nữ,
# 848  3220882                        ...                                                   Severn House Publishers,
# 865  3207321                        ...                                                          Nhà xuất bản Trẻ,
# 885  3162232                        ...                                                           Disney*Hyperion,
# 893  3177627                        ...                                            University of Notre Dame Press,
# 904  3213704                        ...                                                            Pavilion Books,
# 914  3223334                        ...                                                           Simon Spotlight,
# 915  3215464                        ...                                                      Enchanted Lion Books,
# 926  3181802                        ...                                     Universal Pictures Home Entertainment,
# 938  3229614                        ...                                                 Little, Brown and Company,
# 953  3175171                        ...                          Howard Books, an imprint of Simon & Schuster, ...
# 966  3148764                        ...                                                          Simon & Schuster,
# 976  3190736                        ...                          First Second, an imprint of Roaring Brook Pres...
# 986  3170486                        ...                                                             Charlesbridge,
# 991  3162168                        ...                                  Groundwood Books : House of Anansi Press,
#
# [47 rows x 3 columns]

# %%
print('Books Published in 2016 : {}'.format(df_2016['BibNum'].count()))
print('Unique publishers of books in 2016 : {}'.format(df_2016['Publisher'].count()))
# Out:
# Books Published in 2016 : 47
# Unique publishers of books in 2016 : 47

# %% [markdown]
# **Analyzing the data by item types**

# %%
df1['ItemType'].value_counts()
# Out:
# acbk     464
# jcbk     258
# arbk      88
# accd      79
# acdvd     63
# jcdvd     20
# acmus     11
# jccd       3
# acmap      1
# armus      1
# Name: ItemType, dtype: int64

# %% [markdown]
# ItemType is a code from the catalog record that describes the type of item. Some of the more common codes are: acbk (adult book), acdvd (adult DVD), jcbk (children's book), accd (adult CD)

# %% [markdown]
# Slicing out the data for the adult book item from the item type column

# %%
adult_book = df1.ix[df1['ItemType'] == 'acbk',[1,2,4,5,6,8]]
adult_book
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#                                                  Title      ...       ItemCollection
# 1    Naruto. Vol. 1, Uzumaki Naruto / story and art...      ...              nycomic
# 2    Peace, love & Wi-Fi : a ZITS treasury / by Jer...      ...              nycomic
# 3       The Paris pilgrims : a novel / Clancy Carlile.      ...                cafic
# 4    Erotic by nature : a celebration of life, of l...      ...                 canf
# 5    Children of Cambodia's killing fields : memoir...      ...                 canf
# 6    Anti-Zionism : analytical reflections / editor...      ...                 canf
# 7              Hard-hearted Highlander / Julia London.      ...                nanew
# 8                 The Sandcastle Empire / Kayla Olson.      ...                nynew
# 10   Burnt toast makes you sing good : a memoir of ...      ...                 nanf
# 13            The only child : a novel / Andrew Pyper.      ...                cafic
# 15   Duke in his own words : John Wayne's life in l...      ...                 nanf
# 16           The Alchemists' Council / Cynthea Masson.      ...                nafic
# 17   Parrots of the wild : a natural history of the...      ...                 nanf
# 18   The aromatherapy garden : growing fragrant pla...      ...                 nanf
# 19   The walking dead. Volume 8, Made to suffer / [...      ...              nacomic
# 20                           Naked '76 / Kevin Brooks.      ...                nyfic
# 21            Abakada ng pag-ibig : Paula / Maia Jose.      ...                 caln
# 23                     House of dreams / Brenda Joyce.      ...              cs1malf
# 24   Recentering the universe : the radical theorie...      ...                 nynf
# 27   Morningstar guide to mutual funds : five-star ...      ...                 canf
# 31      Lone wolf [text (large print)] / Jodi Picoult.      ...              nalpfic
# 34   Promise land : my journey through America's se...      ...                 nanf
# 35                 A small hotel / Robert Olen Butler.      ...                nafic
# 37   You're doing it wrong! : how to improve your l...      ...                 nanf
# 38   Mirror to the American past; a survey of Ameri...      ...                 canf
# 40                                         Glove toys.      ...                 canf
# 41   Back and deader than ever / a novel by Lisi Ha...      ...                nyfic
# 43   Japan took the J.A.P. out of me : [a memoir] /...      ...                 canf
# 44                The English daughter / Maggie Wadey.      ...                 canf
# 46   Acid precipitation : hearings before the Subco...      ...                 canf
# ..                                                 ...      ...                  ...
# 937  Staten Island : a blue guide travel monograph ...      ...                 canf
# 938   Bullseye / James Patterson and Michael Ledwidge.      ...              calpfic
# 939  The Ulysses theme; a study in the adaptability...      ...                 canf
# 940  The big disconnect : protecting childhood and ...      ...                 nanf
# 943  From here to enlightenment : an introduction t...      ...                 nanf
# 947  Will Eisner : champion of the graphic novel / ...      ...                 nanf
# 950                       The sixth idea / P.J. Tracy.      ...                camys
# 952  Religion : a discovery in comics / Margreet de...      ...                 canf
# 953  Think big : overcoming obstacles with optimism...      ...                 nanf
# 954  One Islam, many Muslim worlds : spirituality, ...      ...                 canf
# 960                        Frames / Loren D. Estleman.      ...                namys
# 961  Opera 101 : a complete guide to learning and l...      ...                 canf
# 966  The fat artist : and other stories / Benjamin ...      ...                nanew
# 968  NYX : the complete collection / written by Joe...      ...              cycomic
# 969  A lady cyclist's guide to Kashgar [text (large...      ...              calpfic
# 971  Wench [text (large print)] / Dolen Perkins-Val...      ...              calpfic
# 974                             Witness / Karen Hesse.      ...                nyfic
# 975                  West and east / Harry Turtledove.      ...                 nasf
# 978  I scream, you scream : a mystery à la mode / W...      ...                camys
# 979  Painting the picture : imagery and description...      ...                 nynf
# 982           I'll give you the sun / by Jandy Nelson.      ...                nyfic
# 984  My just desire : the life of Bess Ralegh, wife...      ...                  cab
# 985  Wild crush : a wild cards novel / Simone Elkeles.      ...                nyfic
# 987  Your power to heal : resolving psychological b...      ...                canew
# 992    Pacific Northwest road trip / Allison Williams.      ...                 nanf
# 995  The amazing Spider-man. Renew your vows / writ...      ...              cycomic
# 996  Twentieth-century Spanish American fiction / N...      ...                 canf
# 997  Suicide squads, W.W. II : Axis and Allied spec...      ...                 canf
# 998  Word like a bell : John Keats, music and the r...      ...                 canf
# 999                Making a comeback / by Julie Blair.      ...                cafic
#
# [464 rows x 6 columns]

# %% [markdown]
# Most books published and printed in this item type are during the years 2011 to 2017

# %%
adult_book['PublicationYear'].value_counts().sort_values(ascending = False).head(10)
# Out:
# [2016]    25
# 2015.     24
# 2016.     23
# 2014.     23
# 2017.     18
# c2010.    17
# [2015]    16
# c2011.    15
# 2013.     15
# [2017]    14
# Name: PublicationYear, dtype: int64

# %% [markdown]
# "ItemCollection" is a collection code from the catalog record which describes the item. Here are some common examples: nanf (adult non-fiction), nafic(adult fiction), ncpic(children's picture book),  nycomic (Young adult comic books).

# %% [markdown]
# Types of collection in the adult books category

# %%
adult_book['ItemCollection'].value_counts().head(10)
# Out:
# canf       151
# nanf        93
# nafic       46
# cafic       26
# caln        18
# nanew       12
# nyfic       12
# camys       11
# nycomic     11
# namys        9
# Name: ItemCollection, dtype: int64

# %% [markdown]
# Publisher with the most number of publications in this item category

# %%
adult_book['Publisher'].value_counts().head()
# Out:
# Random House,               8
# Thorndike Press,            8
# St. Martin's Press,         8
# Oxford University Press,    6
# Simon & Schuster,           5
# Name: Publisher, dtype: int64

# %% [markdown]
# Excluding the unknown counts (where the subject of the book is unknown or belong to multipe categories). Leadership , Short stories and domestic fiction and art have 2 publictions each in the adult book item type

# %%
adult_book['Subjects'].value_counts().head()
# Out:
# Unknown                                                                                                           19
# Leadership                                                                                                         2
# Short stories                                                                                                      2
# Sisters Fiction, Domestic fiction                                                                                  2
# Art Study and teaching Higher United States, Chicago Judy 1939 Themes motives, Artists United States Biography     2
# Name: Subjects, dtype: int64

# %% [markdown]
# Total Books in the category and unique books in the category

# %%
print('Total books in the category : {}'.format(adult_book['Title'].count()))
print('Unique books in this category : {}'.format(adult_book['Title'].nunique()))
# Out:
# Total books in the category : 464
# Unique books in this category : 463

# %% [markdown]
# A book with the same title has two entries

# %% [markdown]
# Distinct authors and no. of publications

# %%
adult_book['Author'].value_counts().head()
# Out:
# Unknown                    41
# Patterson, James, 1947-     2
# Chicago, Judy, 1939-        2
# Wolfe, Ethan J.             1
# Hrachovec, Anna             1
# Name: Author, dtype: int64

# %% [markdown]
# Two authors with more than one publications

# %%
adult_book.loc[adult_book['Author'] == 'Chicago, Judy, 1939-']
# Out:
#                                                  Title      ...       ItemCollection
# 295  Institutional time : a critique of studio art ...      ...                 nanf
# 460  Institutional time : a critique of studio art ...      ...                 canf
#
# [2 rows x 6 columns]

# %% [markdown]
# Coincidentally it is Chicago, Judy's 1939 book 'Institutional time' that has two entries both under different collection type

# %%
adult_book.loc[adult_book['Author'] == 'Patterson, James, 1947-']
# Out:
#                                                  Title      ...       ItemCollection
# 416  The black book / James Patterson and David Ellis.      ...                cafic
# 938   Bullseye / James Patterson and Michael Ledwidge.      ...              calpfic
#
# [2 rows x 6 columns]

# %% [markdown]
# So, James Patterson is the only one to have authored two books in this item type in the collection.

# %% [markdown]
# This was just introductory exploratory analysis and some data cleaning. More to come in this kernel with time.
# Any suggestions or questions regarding the code are welcome!
# Happy Kaggling..
