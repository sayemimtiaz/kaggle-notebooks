# %%
import pandas as pd

# %%
df=pd.read_csv('../input/cardekhocar-price-prediction/datasets_33080_43333_car data.csv')

# %%
df.head()

# %%
df.info()

# %%
df.describe()

# %%
df_num=df.describe().columns

# %%
df_num

# %%
type(df_num)

# %%
df.shape

# %%
df.info()

# %%
cat=['Car_Name','Fuel_Type','Seller_Type','Transmission']

# %%
pd.set_option('display.max_rows',50)

# %%
df['Car_Name'].value_counts()

# %%
df['Car_Name'].unique()

# %%
df['Fuel_Type'].value_counts()

# %%
df['Seller_Type'].value_counts()

# %%
df['Seller_Type'].unique()

# %%
df['Transmission'].value_counts()

# %%
df.isnull().sum()

# %%
df.columns

# %%
final_df=df[['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven','Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']]

# %%
final_df.head()

# %%
final_df['no_of_year']=final_df['Year'].apply(lambda x:2020-x)

# %%
final_df.head()

# %%
final_df.drop(['Year'],axis=1,inplace=True) 
### without inplace=True the default is False and the column is 
###not permanently gone and is back in the next line

# %%
final_df.head()

# %%
final_df=pd.get_dummies(final_df,drop_first=True) ## a dataframe is provided and if no column is not provided then it will encode all the dtype columns

# %%
final_df.head(50)

# %%
final_df.corr()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
sns.pairplot(final_df)

# %%
corrmat=final_df.corr() 
top_corr_features=corrmat.index
plt.figure(figsize=(20,20)) 
#plot heat map 
g=sns.heatmap(final_df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
top_corr_features

# %%
print(final_df.corr().Selling_Price)

# %%
final_df.head()

# %%
X=final_df.iloc[:,1:]
y=final_df.iloc[:,0]

# %%
X.head()

# %%
y.head()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train.shape

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor()

# %%
##hyperparameters
n_estimators=[int(x) for x in np.linspace(start=100,stop=1200,num=12)]## linspace numbers with equal space btween them and num= number of values

# %%
print(n_estimators)

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
##hyperparameters
n_estimators=[int(x) for x in np.linspace(start=100,stop=1200,num=12)]## linspace numbers with equal space btween them and num= number of values
max_features=['auto','sqrt']
max_depth=[int(x) for x in np.linspace(5,10,num=6)]
min_samples_split = [2, 5, 10, 15, 100]

#Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# %%
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)

# %%
# Use the random grid to search for best hyperparameters
# First create the base model to tune
rf = RandomForestRegressor()

# %%
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42, n_jobs = -1)

# %%
rf_random.fit(X_train,y_train)

# %%
rf_random.best_params_

# %%
rf_random.best_score_

# %%
predictions=rf_random.predict(X_test)

# %%
predictions

# %%
y_test

# %%
sns.distplot(y_test-predictions)

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
