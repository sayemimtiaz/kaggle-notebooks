# %%
# %matplotlib inline
from IPython.display import SVG, Image

import os.path
import sys
import re
import itertools
import csv
import datetime
import pickle
import random
from collections import defaultdict, Counter
import gc

import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import seaborn as sns
import pandas as pd
import numpy as np
import scipy
import gensim
from sklearn.metrics import f1_score, classification_report, confusion_matrix, log_loss
from sklearn.model_selection import train_test_split
import gensim
from keras.preprocessing.sequence import skipgrams
import tensorflow as tf

# %% [markdown]
# # 2020 Kaggle Machine Learning & Data Science Survey
# * [memo WordAndDoc2vec_lowcol 2020 Kaggle MLDS Survey](https://www.kaggle.com/wordroid/memo-wordanddoc2vec-lowcol-2020-kaggle-mlds-survey)

# %% [markdown]
# # Actual Survey Data
# * [memo WordAndDoc2vec_lowcol Actual Survey Data](https://www.kaggle.com/wordroid/memo-wordanddoc2vec-lowcol-actual-survey-data) (private)

# %% [markdown]
# # sample007
# ---
# * [memo sample007](https://www.kaggle.com/wordroid/memo-sample007)

# %%
df_org = pd.read_csv('../input/sample-data-wordanddoc2vec/sample007.csv', index_col=0)
print(df_org.shape)

plt.figure(figsize=(20, 20))
plt.imshow(df_org.values.T)

# %% [markdown]
# # sample002
# ---
# * sample007となっているが、sample002
# * [memo sample002](https://www.kaggle.com/wordroid/memo-sample002)

# %%
df_org = pd.read_csv('../input/sample-data-wordanddoc2vec/sample002.csv', index_col=0)
print(df_org.shape)

plt.figure(figsize=(20, 20))
plt.imshow(df_org.values.T)

# %% [markdown]
# # sample010
# ---
# * グループ間に重なりがあるケース
# * [memo sample010](https://www.kaggle.com/wordroid/memo-sample010)

# %%
df_org = pd.read_csv('../input/sample-data-wordanddoc2vec/sample010.csv', index_col=0)
print(df_org.shape)

plt.figure(figsize=(20, 20))
plt.imshow(df_org.values.T)

# %% [markdown]
# # sample011
# ---
# * グループ間に重なりがあるケース
# * [memo sample011](https://www.kaggle.com/wordroid/memo-sample011)

# %%
df_org = pd.read_csv('../input/sample-data-wordanddoc2vec/sample011.csv', index_col=0)
print(df_org.shape)

plt.figure(figsize=(20, 20))
plt.imshow(df_org.values.T)

# %% [markdown]
# # sample012
# ---
# * グループ間に重なりがあるケース
# * [memo sample012](https://www.kaggle.com/wordroid/memo-sample012)
# * 相関行列がランク落ちする

# %%
df_org = pd.read_csv('../input/memo-sample012/sample_data.csv', index_col=0)
print(df_org.shape)

plt.figure(figsize=(20, 20))
plt.imshow(df_org.values.T)

# %% [markdown]
# # sample014
# ---
# * グループ間に重なりがあるケース
# * [memo sample014](https://www.kaggle.com/wordroid/memo-sample014)
# * 相関行列がランク落ちする
#   * faを使う

# %%
df_org = pd.read_csv('../input/memo-sample014/sample_data.csv', index_col=0)
print(df_org.shape)

plt.figure(figsize=(20, 20))
plt.imshow(df_org.values.T)

# %% [markdown]
# # sample004
# ---
# * [memo sample004](https://www.kaggle.com/wordroid/memo-sample004)

# %%
df_org = pd.read_csv('../input/sample-data-wordanddoc2vec/sample004.csv', index_col=0)
print(df_org.shape)

plt.figure(figsize=(20, 20))
plt.imshow(df_org.values.T)
