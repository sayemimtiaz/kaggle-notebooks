# %% [markdown]
# # KIVA DATA ANALYSIS + INDIA'S STORY WITH NEIGHBOURS

# %% [markdown]
# <img src='https://drive.google.com/uc?id=1x9xLpLMbMDwInwoaeiE977Jd3VJXZ65K' width=1000 >

# %% [markdown]
# # About Notebook:-
# #### In this notebook I'm analysising Kiva Dataset. Kiva.org is an online crowdfunding platform to extend financial services to  poor and financially excluded people around the world. Kiva lenders have provided over 1 billion dollars in loans to over 2 million people. In order to set investment priorities, help inform lenders, and understand their target communities, knowing the level of poverty of each borrower is critical. However, this requires inference based on a limited set of information for each borrower.
# #### There are some questions, which I'm analysising, are given below:-
#
# * Q1). Top 10 Countires that got maximum number of times Loan.
# * Q2). Let's create wordcloud for the countries according to the number of times they got loan.
# * Q3). Top 10 Countries that got maximum amount of total loan.
# * Q4). Top 10 Sectors that got maximum amount of total loan.
# * Q5). Top 10 Activity that got maximum amount of total loan.
# * Q6). Loan Amount Distribution.
# * Q7). Let's get insight about the Repayment interval of loans.
# * Q8). Let's get information about the lender count.
# * Q9). Gender Distribution of Borrower.
# * Q10). For which durations(month) maximum number of loans are there.
# * Q11). Top 10 Countries with highest MPI (Multidimentional Poverty Index).
# * Q12). Top 10 Countries with low MPI (Multidimentional Poverty Index).
# * Q13). MPI on World Map.
# * Q14). Time Series Analysis of funded amount.
# * Q15). India's Loan distribution with neighbour countries.
# * Q16). Top 10 sectors , that got maximum amount of loan in India.
# * Q17). Top 10 Activities , that got maximum amount of loan in India.
# * Q18). Top 10 Cities , that got maximum amount of loan in India.
# * Q19). Gender Distribution for borrower in India.
# * Q20). Number of Times Loans were given to India and it's neighbour.
# * Q21). Repayment Interval of Loans to India.
# * Q22). Top 10 Cities that got maximum number of times loan from India and it's neighbour.
# * Q23). Regions of India that got loans, Ploting on map.

# %%
# Importing the necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from plotly.offline import download_plotlyjs, iplot, init_notebook_mode
import plotly.graph_objs as go
import plotly.plotly as py
import cufflinks as cf
init_notebook_mode(connected=True)
cf.go_offline()

# %matplotlib inline
plt.style.use('ggplot')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Let's see the number of dataset and their name we have
try:
    dataset = os.listdir('input')
    for var in dataset:
        print(var)
except Exception as e :
    dataset = os.listdir('../input')
    for var in dataset:
        print(var)
# Out:
# kiva_mpi_region_locations.csv
# loan_themes_by_region.csv
# loan_theme_ids.csv
# kiva_loans.csv

# %%
# loading datasets

try:
    df_kiva_loans = pd.read_csv('input/kiva_loans.csv')
    df_kiva_mpi = pd.read_csv('input/kiva_mpi_region_locations.csv')
    df_loan_region = pd.read_csv('input/loan_themes_by_region.csv')
    df_loan_ids = pd.read_csv('input/loan_theme_ids.csv')

except Exception as e:
    df_kiva_loans = pd.read_csv('../input/kiva_loans.csv')
    df_kiva_mpi = pd.read_csv('../input/kiva_mpi_region_locations.csv')
    df_loan_region = pd.read_csv('../input/loan_themes_by_region.csv')
    df_loan_ids = pd.read_csv('../input/loan_theme_ids.csv')

# %%
# let's see the kiva_loan dataset.
df_kiva_loans.head()
# Out:
#        id  funded_amount     ...      repayment_interval        date
# 0  653051          300.0     ...               irregular  2014-01-01
# 1  653053          575.0     ...               irregular  2014-01-01
# 2  653068          150.0     ...                  bullet  2014-01-01
# 3  653063          200.0     ...               irregular  2014-01-01
# 4  653084          400.0     ...                 monthly  2014-01-01
#
# [5 rows x 20 columns]

# %%
# let's see the kiva_mpi_region_location dataset.
df_kiva_mpi.head()
# Out:
#               LocationName  ISO    ...            lat        lon
# 0  Badakhshan, Afghanistan  AFG    ...      36.734772  70.811995
# 1     Badghis, Afghanistan  AFG    ...      35.167134  63.769538
# 2     Baghlan, Afghanistan  AFG    ...      35.804295  69.287754
# 3       Balkh, Afghanistan  AFG    ...      36.755060  66.897537
# 4      Bamyan, Afghanistan  AFG    ...      34.810007  67.821210
#
# [5 rows x 9 columns]

# %%
# let's see the kiva_loan_theme_id dataset.
df_loan_ids.head()
# Out:
#        id    Loan Theme ID          Loan Theme Type  Partner ID
# 0  638631  a1050000000skGl                  General       151.0
# 1  640322  a1050000000skGl                  General       151.0
# 2  641006  a1050000002X1ij         Higher Education       160.0
# 3  641019  a1050000002X1ij         Higher Education       160.0
# 4  641594  a1050000002VbsW  Subsistence Agriculture       336.0

# %%
# let's see the kiva_loan_theme_by_region dataset.

df_loan_region.head()
# Out:
#    Partner ID    ...    rural_pct
# 0           9    ...         90.0
# 1           9    ...         90.0
# 2           9    ...         90.0
# 3           9    ...         90.0
# 4           9    ...         90.0
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Let's see the statistical information about numerical values

# %%
df_kiva_loans.describe()
# Out:
#                  id  funded_amount      ...        term_in_months   lender_count
# count  6.712050e+05  671205.000000      ...         671205.000000  671205.000000
# mean   9.932486e+05     785.995061      ...             13.739022      20.590922
# std    1.966113e+05    1130.398941      ...              8.598919      28.459551
# min    6.530470e+05       0.000000      ...              1.000000       0.000000
# 25%    8.230720e+05     250.000000      ...              8.000000       7.000000
# 50%    9.927800e+05     450.000000      ...             13.000000      13.000000
# 75%    1.163653e+06     900.000000      ...             14.000000      24.000000
# max    1.340339e+06  100000.000000      ...            158.000000    2986.000000
#
# [8 rows x 6 columns]

# %% [markdown]
# #### Let's see the statistical information about categorical values

# %%
df_kiva_loans.describe(include=[np.object])
# Out:
#        activity       sector     ...     repayment_interval        date
# count    671205       671205     ...                 671205      671205
# unique      163           15     ...                      4        1298
# top     Farming  Agriculture     ...                monthly  2017-03-20
# freq      72955       180302     ...                 342717        1308
#
# [4 rows x 14 columns]

# %% [markdown]
# #### Let's get the information about the missing values.

# %%
null = df_kiva_loans.isnull().sum()
null_per = (null/len(df_kiva_loans))*100
null_per = pd.DataFrame(data={'Columns':null.index,'Number of Null values':null.values, 'Percentage of null value':null_per.values})
null_per
# Out:
#                Columns            ...             Percentage of null value
# 0                   id            ...                             0.000000
# 1        funded_amount            ...                             0.000000
# 2          loan_amount            ...                             0.000000
# 3             activity            ...                             0.000000
# 4               sector            ...                             0.000000
# 5                  use            ...                             0.630508
# 6         country_code            ...                             0.001192
# 7              country            ...                             0.000000
# 8               region            ...                             8.462392
# 9             currency            ...                             0.000000
# 10          partner_id            ...                             2.012351
# 11         posted_time            ...                             0.000000
# 12      disbursed_time            ...                             0.356970
# 13         funded_time            ...                             7.200632
# 14      term_in_months            ...                             0.000000
# 15        lender_count            ...                             0.000000
# 16                tags            ...                            25.538546
# 17    borrower_genders            ...                             0.628869
# 18  repayment_interval            ...                             0.000000
# 19                date            ...                             0.000000
#
# [20 rows x 3 columns]

# %% [markdown]
# * As one can see 25% null values, which is maximum, is in tags column.
# * Other columns have less than 10% null values.
# * No need to remove null values.

# %% [markdown]
# #### =====================================================================================================

# %% [markdown]
# # LOAN ANALYSIS

# %% [markdown]
# ### Q1). Top 10 Countires that got maximum number of times Loan.

# %%
df_kiva_loans['country'].value_counts()[:10].plot(kind='bar', figsize=(11,6))
plt.title('Top 10 Countires that got maximum number of times Loan')
plt.xlabel('Country')
plt.ylabel('Number of Times')
plt.show()

# %% [markdown]
# * As one can see Philippines got maximum number of times loan followed by Kenya and then by El Salvador.
# * India's neighbourer Pakisthan is also in the list at 5th position.

# %% [markdown]
# #### =====================================================================================================

# %% [markdown]
# ### Q2). Let's create wordcloud for the countries according to the number of times they got loan.

# %%
from wordcloud import WordCloud

names = df_kiva_loans['country'][pd.notnull(df_kiva_loans['country'])]
wc = WordCloud(width=600, height=400, max_font_size=50).generate(' '.join(names))
plt.figure(figsize=(16,8))
plt.title('Wordcloud for Countries', fontsize=35)
plt.imshow(wc)
plt.axis('off')
plt.show()

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# ### Q3). Top 10 Countries that got maximum amount of total loan.

# %%
# Using groupby function here.
country = df_kiva_loans.groupby('country')['funded_amount'].sum().reset_index()
country.sort_values('funded_amount',ascending=False, inplace=True)
country = country[:10]
country.set_index('country', drop=True, inplace=True,)

country.plot(kind='bar', figsize=(12,6), title='Top 10 countries that got maximum amount of total Loan')

plt.show()

# %% [markdown]
# #### ==================================================================================================

# %% [markdown]
# ### Q4). Top 10 Sectors that got maximum amount of total loan.

# %%
# Using groupby function here.

sector = df_kiva_loans.groupby('sector')['funded_amount'].sum().reset_index()
sector.sort_values('funded_amount',ascending=False, inplace=True)
sector = sector[:10]
sector.set_index('sector', drop=True, inplace=True,)


sector.plot(kind='bar',title='Top 10 Sectors that got maximum amount of total loan.', figsize=(12,6))
plt.show()
sector.plot(kind='pie',title='Top 10 Sectors that got maximum amount of total loan.',subplots=True, 
            figsize=(12,6), autopct='%.f%%') 
plt.show()

# %% [markdown]
# <img src='https://drive.google.com/uc?id=1MKwL5jSoIEkCe1wS-hUCtgBmv97OckY7' width=700>

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# ### Q5). Top 10 Activity that got maximum amount of total loan.

# %%
# Using groupby function here.

activity = df_kiva_loans.groupby('activity')['funded_amount'].sum().reset_index()
activity.sort_values('funded_amount',ascending=False, inplace=True)
activity = activity[:10]

# iplot for interactive plots.
activity.iplot(kind='bar',x='activity', y='funded_amount',
             title='Top 10 activity that got maximum amount of total loan.', xTitle='activity', yTitle='Amount' )
plt.show()
activity.iplot(kind='pie',title='Top 10 activity that got maximum amount of total loan.',
             labels='activity', values='funded_amount', pull=0.2, hole=0.2) 
plt.show()
# Out:
# <div>
#
#
#             <div id="ba1737f1-276d-407d-8ff4-6876d60ffad2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ba1737f1-276d-407d-8ff4-6876d60ffad2")) {
#                     Plotly.newPlot(
#                         'ba1737f1-276d-407d-8ff4-6876d60ffad2',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "funded_amount", "orientation": "v", "text": "", "type": "bar", "uid": "9a98543a-0c33-4704-bb00-7fe53a9f45b5", "x": ["Farming", "General Store", "Agriculture", "Food Production/Sales", "Retail", "Clothing Sales", "Personal Housing Expenses", "Higher education costs", "Grocery Store", "Livestock"], "y": [47900500.0, 35555135.0, 25530735.0, 24326140.0, 23911950.0, 22569725.0, 20166525.0, 19012400.0, 14299895.0, 13699275.0]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Top 10 activity that got maximum amount of total loan."}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "activity"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Amount"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('ba1737f1-276d-407d-8ff4-6876d60ffad2');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# <div>
#
#
#             <div id="c2a3e342-11a7-47dd-8189-7e196448410a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c2a3e342-11a7-47dd-8189-7e196448410a")) {
#                     Plotly.newPlot(
#                         'c2a3e342-11a7-47dd-8189-7e196448410a',
#                         [{"hole": 0.2, "labels": ["Farming", "General Store", "Agriculture", "Food Production/Sales", "Retail", "Clothing Sales", "Personal Housing Expenses", "Higher education costs", "Grocery Store", "Livestock"], "marker": {"colors": ["rgba(255, 153, 51, 1.0)", "rgba(55, 128, 191, 1.0)", "rgba(50, 171, 96, 1.0)", "rgba(128, 0, 128, 1.0)", "rgba(219, 64, 82, 1.0)", "rgba(0, 128, 128, 1.0)", "rgba(255, 255, 51, 1.0)", "rgba(128, 128, 0, 1.0)", "rgba(251, 128, 114, 1.0)", "rgba(128, 177, 211, 1.0)"]}, "name": "", "pull": 0.2, "type": "pie", "uid": "048ef872-a657-4f8c-936a-c4a78203eff3", "values": [47900500.0, 35555135.0, 25530735.0, 24326140.0, 23911950.0, 22569725.0, 20166525.0, 19012400.0, 14299895.0, 13699275.0]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Top 10 activity that got maximum amount of total loan."}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('c2a3e342-11a7-47dd-8189-7e196448410a');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# * Maximum number of activities are related to farming and agriculture.

# %% [markdown]
# #### =====================================================================================================

# %% [markdown]
# ### Q6). Loan Amount Distribution.

# %%
df_kiva_loans['funded_amount'].plot(kind='hist', bins=50, figsize=(12,6))
plt.xlabel('Funded Amount')
plt.title('Funded Amount Distribution')
plt.show()

# %% [markdown]
# #### The conclusions from the graph:-
# * As one can see there are some outliers in the distribution of funded amount.
# * First we will remove this outliers.
# * We will take funded amount in the range of 0 to 10000 dollar to see the distribution of funded amount.

# %%
temp_df = df_kiva_loans[df_kiva_loans['funded_amount']<10000]
temp_df['funded_amount'].plot(kind='hist', figsize=(12,6), bins=55)
plt.xlabel('Funded Amount')
plt.title('Loan Amount Distribution')
plt.show()

# %% [markdown]
# * From this interactive graph one can say maximum number of times loans are in the range of 200 to 300 dollars.

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# ### 7). Let's get insight about the Repayment interval of loans.

# %%
new_df = df_kiva_loans['repayment_interval'].value_counts().reset_index()
new_df.set_index('index', inplace=True, drop=True)
new_df.plot(kind='pie', subplots=True, title='Repayment Interval', autopct='%.f%%', figsize=(12,6))
plt.show()

# %% [markdown]
# * 51% are related to monthlt interval followed by 38% from irregular.

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# ### Q8). Let's get information about the lender count.
# #### lender count = number of lender giving loan to a borrower.

# %% [markdown]
# * Maximum number of lenders are in the range of 0 to 200, so I am only checking the distribution of those only.
# * Others may be treated as outliers.

# %%
lender = df_kiva_loans[df_kiva_loans['lender_count']<200]
lender['lender_count'].plot(kind='box', figsize=(12,6), title='Lender count Distribution')
plt.show()

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# ### Q9). Gender Distribution of Borrower.

# %%
gender = df_kiva_loans['borrower_genders'].value_counts()[:2].reset_index()
gender.iplot(kind='pie', labels='index', values='borrower_genders', title='Gender Distribution of Borrower')
plt.show()
# Out:
# <div>
#
#
#             <div id="2f2829fc-4893-4b20-8d31-0e4c2ffcafe2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("2f2829fc-4893-4b20-8d31-0e4c2ffcafe2")) {
#                     Plotly.newPlot(
#                         '2f2829fc-4893-4b20-8d31-0e4c2ffcafe2',
#                         [{"labels": ["female", "male"], "marker": {"colors": ["rgba(255, 153, 51, 1.0)", "rgba(55, 128, 191, 1.0)"]}, "name": "", "type": "pie", "uid": "6e2cdb1b-7564-4236-a291-ebb6b385be99", "values": [426502, 134710]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Gender Distribution of Borrower"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('2f2829fc-4893-4b20-8d31-0e4c2ffcafe2');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# * Participation of females much higher than males.
# * Female with 76% and male with 24%

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# ### Q10). For which durations(month) maximum number of loans are there.

# %%
months = df_kiva_loans['term_in_months'].value_counts()[:10].reset_index()
 
months.columns = ['Terms in Months','Frequency']
months.iplot(kind='bar', x='Terms in Months', y= 'Frequency', title='Terms of Months', 
             xTitle='Terms of Month', yTitle='Number of times')
# Out:
# <div>
#
#
#             <div id="05c5be61-3358-43b9-b02f-0b9a0f149812" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("05c5be61-3358-43b9-b02f-0b9a0f149812")) {
#                     Plotly.newPlot(
#                         '05c5be61-3358-43b9-b02f-0b9a0f149812',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Frequency", "orientation": "v", "text": "", "type": "bar", "uid": "f789827d-f309-4434-841b-7fae229db775", "x": [14.0, 8.0, 11.0, 7.0, 13.0, 20.0, 6.0, 12.0, 15.0, 26.0, 10.0], "y": [166750, 143042, 40694, 32847, 30501, 28483, 26039, 25700, 25255, 23431, 19782]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Terms of Months"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Terms of Month"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Number of times"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('05c5be61-3358-43b9-b02f-0b9a0f149812');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# * Maximum Number of times terms of loan is 14 or 8 in months.
# * Approximately for 1 year.

# %% [markdown]
# #### ===================================================================================================

# %% [markdown]
# # MPI ANALYSIS

# %% [markdown]
# ### Q11). Top 10 Countries with highest MPI (Multidimentional Poverty Index).

# %%
high_mpi = df_kiva_mpi.sort_values('MPI', ascending=False)[:10]
high_mpi.iplot(kind='bar', x='LocationName', y='MPI', title='Top 10 Countries with highest MPI', 
              xTitle='Country', yTitle='MPI')
# Out:
# <div>
#
#
#             <div id="1d743f05-993c-4415-8244-78efc1c7a832" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("1d743f05-993c-4415-8244-78efc1c7a832")) {
#                     Plotly.newPlot(
#                         '1d743f05-993c-4415-8244-78efc1c7a832',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "MPI", "orientation": "v", "text": "", "type": "bar", "uid": "28d7b395-79e8-4e7f-9bc1-73f67e07e918", "x": ["Lac, Chad", "Wadi Fira, Chad", "Est, Burkina Faso", "Sila, Chad", "Kanem, Chad", "Sahel, Burkina Faso", "Ouadda\u00f0, Chad", "Salamat, Chad", "Maradi, Niger", "Affar, Ethiopia"], "y": [0.7440000000000001, 0.7090000000000001, 0.698, 0.6970000000000001, 0.696, 0.69, 0.6829999999999999, 0.6779999999999999, 0.664, 0.6629999999999999]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Top 10 Countries with highest MPI"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Country"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "MPI"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('1d743f05-993c-4415-8244-78efc1c7a832');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# * High MPI means high Poverty.
# * 6 regions from Chad are in high MPI means they are highly poor regions.

# %% [markdown]
# #### =====================================================================================================

# %% [markdown]
# ### Q12). Top 10 Countries with low MPI (Multidimentional Poverty Index).

# %%
low_mpi = df_kiva_mpi.sort_values('MPI', )[:10]
low_mpi.iplot(kind='bar', x='LocationName', y='MPI', title='Top 10 Countries with Low MPI', 
              xTitle='Country', yTitle='MPI')
# Out:
# <div>
#
#
#             <div id="78eacbbb-7c24-41f0-ab66-a4047545630d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("78eacbbb-7c24-41f0-ab66-a4047545630d")) {
#                     Plotly.newPlot(
#                         '78eacbbb-7c24-41f0-ab66-a4047545630d',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "MPI", "orientation": "v", "text": "", "type": "bar", "uid": "c7292e14-f393-4317-940f-ccaf8740edfc", "x": ["Callao, Peru", "Tortous, Syrian Arab Republic", "Tashkent, Uzbekistan", "As-swidaa, Syrian Arab Republic", "Bogota, Colombia", "New Valley, Egypt", "Damascus, Syrian Arab Republic", "Port Said, Egypt", "Galapagos Island, Ecuador", "Grand Casablanca, Morocco"], "y": [0.0, 0.0, 0.001, 0.002, 0.003, 0.003, 0.003, 0.003, 0.003, 0.003]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Top 10 Countries with Low MPI"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Country"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "MPI"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('78eacbbb-7c24-41f0-ab66-a4047545630d');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# ### Q13). MPI on World Map.

# %%
data = [{'lat': df_kiva_mpi['lat'] ,
  'lon': df_kiva_mpi['lon'] ,       
  'marker': {'color': df_kiva_mpi['MPI'] ,
   'line': {'color': 'rgb(40,40,40)', 'width': 0.5},
   'size': 5,
   'sizemode': 'diameter',
    'colorbar': dict(
            title = 'MPI', 
            thickness = 10,           
            outlinecolor = "rgba(68, 68, 68, 0)",            
            ticklen = 3,                       
            dtick = 0.1      )        },
  'text': df_kiva_mpi['LocationName'].astype(str) + '  ->  ' + df_kiva_mpi['MPI'].astype(str) + '  MPI' ,
  'type': 'scattergeo',
  
      }]


layout = go.Layout(
    title = 'MPI',
    showlegend = True,
    geo = dict(
            scope='world',
            projection=dict( type = 'natural earth'),
            showland = True,
            landcolor = 'rgb(217, 217, 217)',
            subunitwidth=1,
            countrywidth=1,
            subunitcolor="rgb(255, 255, 255)",
            countrycolor="rgb(255, 255, 255)"
        ),)

fig =  go.Figure(layout=layout, data=data)
iplot( fig, validate=False)
# Out:
# <div>
#
#
#             <div id="091dcbe3-ff00-4af0-9c8e-8551d6cb356e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("091dcbe3-ff00-4af0-9c8e-8551d6cb356e")) {
#                     Plotly.newPlot(
#                         '091dcbe3-ff00-4af0-9c8e-8551d6cb356e',
#                         [{"lat": [36.7347725, 35.167133899999996, 35.80429470000001, 36.7550603, 34.8100067, 33.669495, 32.4464635, 36.079561299999995, 33.5450587, 34.0995776, 31.363647399999998, 11.6155109, 36.8969692, 34.5553494, 31.628871000000004, 34.9810572, 33.3338472, 34.8465893, 36.7285907, 34.6897687, 34.0145518, 34.171831299999994, 31.0261488, 35.3250223, 32.2645386, 33.706199, 35.50257720000001, 34.9630977, 35.98072960000001, 35.6707473, 36.669801299999996, 32.927128700000004, 34.351349400000004, 32.1918782, null, null, null, -3.4146958, -3.3730559999999996, 9.0630743, -3.3730559999999996, 14.609053699999999, 10.9681093, 10.7954931, 6.6588391000000025, 9.5340864, 13.718252, 7.003589400000001, 9.7191867, 6.3806973, 6.6607182, null, 7.3445141000000005, 7.3469267999999985, 8.8556838, 10.4072992, 12.3425897, 11.5247674, 13.1724464, 11.8798466, 11.522891099999999, 12.4365526, 11.494200300000001, null, 12.2537648, 14.1000865, 10.4231493, 22.7029212, 22.3475365, 23.810332, 22.845641, 24.363588600000003, 25.7438916, 24.904539, null, 18.403080199999998, 18.084247199999997, 30.732662199999996, 16.811663100000004, 16.2491923, 17.0984445, 17.489131699999998, -20.024914399999997, -16.489689000000002, -17.4139766, 26.937304100000002, null, -21.5213825, -17.8145819, -14.3782747, -10.7988901, -9.0237964, -9.571305800000001, null, -3.4168427, -12.579738, -21.3223397, -15.7997654, null, null, -8.722408399999999, -12.6818712, -20.7722295, -18.512178, null, null, null, -8.8137173, null, -5.402580299999999, -30.0346316, -22.9068467, -17.8251657, 2.7375971000000003, -27.2423392, -10.5740934, -23.5671844, -10.17528, null, 27.641839, 27.078430400000002, 27.032286100000004, 27.2651669, 27.8264989, 27.26170590000001, 27.428684000000004, 27.98785, 27.5920869, 26.803568199999997, 27.0291832, -2.5546618, 27.4727924, 27.332501399999998, -20.3446313, 27.500226899999998, 27.032207, 27.4879018, 27.076975, 5.1188825, 4.3525981, 8.154077000000001, null, 15.341806, null, 7.0909109999999975, null, null, 6.316821599999999, 7.7964379, 8.2733455, 4.8719319, 5.356142699999999, 6.2537134000000005, 4.3946735, 42.4708101, 29.705340000000003, 35.86166, -8.6529334, null, 13.4540922, null, 5.3618440000000005, 5.3086129999999985, 7.702782699999997, 7.5399889999999985, null, 4.7459773, 5.3428333, 6.9181954, null, 4.0510564, 3.950512799999999, null, 4.0134386, 8.580901299999999, 6.4703738999999985, 5.4638158, 2.7202832000000003, 5.1573493, null, -4.4419311, -4.163679, -5.2365685, null, null, null, -8.8851145, -3.0730929, null, 1.6406296000000002, -3.011658, -4.1428413, 5.430892099999999, null, null, -3.7762627999999996, -2.0680088, -0.2877446, 0.144755, 1.4662328000000002, 2.043924000000001, 18.867934899999998, -4.7691623, 10.7582091, 11.004107199999998, 12.545015300000001, 8.5705151, 6.6437076, 17.231756100000002, 6.244203, 6.244203, null, null, 3.4516467000000004, null, null, 5.2954172, 13.4595508, 49.26474810000001, 13.492917199999999, null, -17.1927361, 11.825138, null, null, 4.695135, 18.867934899999998, 18.867934899999998, 18.429661199999998, 18.977164300000002, 18.478796399999997, 18.490165100000002, 18.4870314, 18.41386, null, -1.4693018, 34.352865, -3.4653053, -0.20517249999999998, 30.0444196, 31.2000924, 10.9691601, 29.9668343, 31.41753880000001, 31.0832017, null, 30.3292368, 31.106319800000005, 10.911057000000001, 41.26666669999999, 30.848098600000004, 30.5964923, 30.0130557, 29.0661274, 29.308402100000002, 28.0870967, 27.1783117, 26.559073699999995, 26.155061, 24.088938, 25.6872431, 25.1076838, 24.5455638, 6.829501899999999, 14.032333600000001, 11.755938800000001, 11.349424699999998, 7.5460376999999985, 6.6612293000000005, 10.7802889, 6.515691099999999, 8.2471899, 9.314866, 8.9806034, 9.600874699999999, 0.456963, 0.456963, null, null, null, -2.8821033, null, null, null, null, 6.7470436000000005, 7.9559247000000015, 5.5607846, 31.2652893, 5.8142835999999996, 9.5439269, 10.7082499, 10.2529757, 6.578137299999999, 5.3901977999999975, null, 9.6411855, 10.045 ...

# %% [markdown]
# #### ===================================================================================================

# %% [markdown]
# # TIME ANALYSIS

# %% [markdown]
# ### Q 14). Time Series Analysis of funded amount.

# %%
df_kiva_loans['date'] = pd.to_datetime(df_kiva_loans['date'])
temp_df = df_kiva_loans[['date','funded_amount']]
temp_df.set_index('date', drop=True, inplace=True)
temp_df.plot(figsize=(15,6))
plt.show()

# %% [markdown]
# #### =====================================================================================================

# %% [markdown]
# # INDIA AND IT'S NEIGHBOURS ANALYSIS

# %% [markdown]
# #### Creating new DataFrame which only contains data of India and it's neighbour.

# %%
neighbour = ['India' ,'Pakistan', 'China', 'Nepal', 'Bangladesh', 'Bhutan', 'Myanmar (Burma)', 'Afghanistan', 'Sri Lanka', ]
df_india = df_kiva_loans[df_kiva_loans['country'].isin(neighbour)]
print(df_india['country'].unique())
print("The data of Sri Lanka and Bangladesh is not there in kiva's dataset.")
# Out:
# ['Pakistan' 'India' 'Nepal' 'Myanmar (Burma)' 'China' 'Afghanistan'
#  'Bhutan']
# The data of Sri Lanka and Bangladesh is not there in kiva's dataset.

# %% [markdown]
# ### Q15). India's Loan distribution with neighbour countries.

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=df_india, x='country', y='funded_amount')
plt.xlabel('Country', fontsize=25)
plt.show()

# %% [markdown]
# #### ==================================================================================================

# %% [markdown]
# ### Q16). Top 10 sectors , that got maximum amount of loan in India.

# %%
temp_df = df_india[df_india['country']=='India']
temp_df = temp_df['sector'].value_counts().reset_index()[:10]
temp_df.iplot(kind='pie', labels='index', values='sector', hole=0.2, pull=0.2, title='Top 10 Sectors')
plt.show()
# Out:
# <div>
#
#
#             <div id="2cb4ee40-126a-4c20-b298-43364923a5b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("2cb4ee40-126a-4c20-b298-43364923a5b5")) {
#                     Plotly.newPlot(
#                         '2cb4ee40-126a-4c20-b298-43364923a5b5',
#                         [{"hole": 0.2, "labels": ["Agriculture", "Food", "Housing", "Services", "Arts", "Retail", "Education", "Clothing", "Personal Use", "Manufacturing"], "marker": {"colors": ["rgba(255, 153, 51, 1.0)", "rgba(55, 128, 191, 1.0)", "rgba(50, 171, 96, 1.0)", "rgba(128, 0, 128, 1.0)", "rgba(219, 64, 82, 1.0)", "rgba(0, 128, 128, 1.0)", "rgba(255, 255, 51, 1.0)", "rgba(128, 128, 0, 1.0)", "rgba(251, 128, 114, 1.0)", "rgba(128, 177, 211, 1.0)"]}, "name": "", "pull": 0.2, "type": "pie", "uid": "519d5f81-6966-4203-b22e-7d15ce46db26", "values": [3416, 1944, 1295, 1053, 791, 695, 560, 524, 315, 289]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Top 10 Sectors"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('2cb4ee40-126a-4c20-b298-43364923a5b5');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# * It's good to see agriculture sector and food sector on top 10, means they are getting good quantity of loan.
# * Farmers can opt this method also to get loan.

# %% [markdown]
# #### =====================================================================================================

# %% [markdown]
# ### Q17). Top 10 Activities , that got maximum amount of loan in India.

# %%
activity = df_india[df_india['country']=='India']
activity = activity['activity'].value_counts().reset_index()[:10]
activity.iplot(kind='pie', labels='index', values='activity', hole=0.2, pull=0.2, title='Top1 10 Activity')
plt.show()
# Out:
# <div>
#
#
#             <div id="62dd22b3-c38f-494b-9b88-05db02186ffc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("62dd22b3-c38f-494b-9b88-05db02186ffc")) {
#                     Plotly.newPlot(
#                         '62dd22b3-c38f-494b-9b88-05db02186ffc',
#                         [{"hole": 0.2, "labels": ["Farming", "Personal Housing Expenses", "Dairy", "Tailoring", "Grocery Store", "Clothing Sales", "Weaving", "Food Production/Sales", "Fruits & Vegetables", "Higher education costs"], "marker": {"colors": ["rgba(255, 153, 51, 1.0)", "rgba(55, 128, 191, 1.0)", "rgba(50, 171, 96, 1.0)", "rgba(128, 0, 128, 1.0)", "rgba(219, 64, 82, 1.0)", "rgba(0, 128, 128, 1.0)", "rgba(255, 255, 51, 1.0)", "rgba(128, 128, 0, 1.0)", "rgba(251, 128, 114, 1.0)", "rgba(128, 177, 211, 1.0)"]}, "name": "", "pull": 0.2, "type": "pie", "uid": "4024f7a1-c2ca-4c95-b82e-fd59e350ec67", "values": [1631, 1294, 1238, 699, 689, 491, 432, 394, 333, 298]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Top1 10 Activity"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('62dd22b3-c38f-494b-9b88-05db02186ffc');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# ### Q18). Top 10 Cities , that got maximum amount of loan in India.

# %%
cities = df_india[df_india['country']=='India']
cities = cities['region'].value_counts().reset_index()[:10]
cities.iplot(kind='pie', labels='index', values='region', hole=0.2, pull=0.2, title='Top 10 City in India')
plt.show()
# Out:
# <div>
#
#
#             <div id="f0ad9671-37dc-4f87-9212-6101029a3285" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f0ad9671-37dc-4f87-9212-6101029a3285")) {
#                     Plotly.newPlot(
#                         'f0ad9671-37dc-4f87-9212-6101029a3285',
#                         [{"hole": 0.2, "labels": ["Dhupguri", "Falakata", "Maynaguri", "Jeypore, Odisha", "Khurda", "Kandi", "Surendranagar", "Dahod", "Jhabua", "Jaipur"], "marker": {"colors": ["rgba(255, 153, 51, 1.0)", "rgba(55, 128, 191, 1.0)", "rgba(50, 171, 96, 1.0)", "rgba(128, 0, 128, 1.0)", "rgba(219, 64, 82, 1.0)", "rgba(0, 128, 128, 1.0)", "rgba(255, 255, 51, 1.0)", "rgba(128, 128, 0, 1.0)", "rgba(251, 128, 114, 1.0)", "rgba(128, 177, 211, 1.0)"]}, "name": "", "pull": 0.2, "type": "pie", "uid": "76f99d7d-d4f8-4280-8692-b457b96ba8ee", "values": [998, 845, 585, 444, 373, 332, 323, 244, 235, 231]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Top 10 City in India"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('f0ad9671-37dc-4f87-9212-6101029a3285');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### Let's plot them on India's map

# %%
top_cities = cities['index']
top_cities = top_cities.values
top_cities
new_df = df_loan_region[df_loan_region['region'].isin(top_cities)]
new_df['region'].unique()
lon = new_df['lon'].unique()
lon = np.append(lon,88.8215)
lat = new_df['lat'].unique()
lat = np.append(lat,26.5738)
names = new_df['region'].unique()
data = [{'lat': lat ,
  'lon': lon , 
  'locationmode':'country names' ,      
  'marker': {
   'line': {'color': 'rgb(40,40,40)', 'width': 0.5},
   'size': 5,
   'sizemode': 'diameter',
            },
  'text': names ,
  'type': 'scattergeo',
  
      }]


layout = go.Layout(
    title = 'Top 10 City in India',
    showlegend = True,
    geo = dict(
            scope='asia' ,
            projection=dict( type = 'natural earth'),
            showland = True,
            landcolor = 'rgb(217, 217, 217)',
            subunitwidth=1,
            countrywidth=1,
            subunitcolor="rgb(255, 255, 255)",
            countrycolor="rgb(255, 255, 255)"
        ),)

fig =  go.Figure(layout=layout, data=data)
iplot( fig, validate=False)
# Out:
# <div>
#
#
#             <div id="95d194d6-be63-481a-842a-c30c5b5f5679" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("95d194d6-be63-481a-842a-c30c5b5f5679")) {
#                     Plotly.newPlot(
#                         '95d194d6-be63-481a-842a-c30c5b5f5679',
#                         [{"lat": [26.9124336, 18.860612600000003, 26.5821321, 26.517485999999998, 23.946800500000002, 22.8379314, 22.769666, 20.1934552, 22.7738938, 26.5738], "locationmode": "country names", "lon": [75.78727090000002, 82.5510469, 89.0051441, 89.2039195, 88.04971450000002, 74.2531465, 74.5920921, 85.6332093, 71.66733520000002, 88.8215], "marker": {"line": {"color": "rgb(40,40,40)", "width": 0.5}, "size": 5, "sizemode": "diameter"}, "text": ["Jaipur", "Jeypore, Odisha", "Dhupguri", "Falakata", "Kandi", "Dahod", "Jhabua", "Khurda", "Surendranagar"], "type": "scattergeo", "uid": "904ef6ae-8fff-4c1f-b697-9981ff872607"}],
#                         {"geo": {"countrycolor": "rgb(255, 255, 255)", "countrywidth": 1, "landcolor": "rgb(217, 217, 217)", "projection": {"type": "natural earth"}, "scope": "asia", "showland": true, "subunitcolor": "rgb(255, 255, 255)", "subunitwidth": 1}, "showlegend": true, "title": {"text": "Top 10 City in India"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('95d194d6-be63-481a-842a-c30c5b5f5679');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### ===================================================================================================

# %% [markdown]
# ### Q 19). Gender Distribution for borrower in India.

# %%
temp_df = df_india[df_india['country']=='India']
temp_df = temp_df[temp_df['borrower_genders'].isin(['female', 'male']) ]
temp_df = temp_df['borrower_genders'].value_counts().reset_index()
temp_df.iplot(kind='pie', labels='index', values='borrower_genders', 
              hole=0.2, pull=0.2, title='Gender Distribution of India')
plt.show()
# Out:
# <div>
#
#
#             <div id="f4c5ecd9-152e-4dbe-80c4-3e094e76c68a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f4c5ecd9-152e-4dbe-80c4-3e094e76c68a")) {
#                     Plotly.newPlot(
#                         'f4c5ecd9-152e-4dbe-80c4-3e094e76c68a',
#                         [{"hole": 0.2, "labels": ["female", "male"], "marker": {"colors": ["rgba(255, 153, 51, 1.0)", "rgba(55, 128, 191, 1.0)"]}, "name": "", "pull": 0.2, "type": "pie", "uid": "daac1afe-5029-4af5-9907-98f5bd16da04", "values": [7562, 197]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Gender Distribution of India"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('f4c5ecd9-152e-4dbe-80c4-3e094e76c68a');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### The conclusions from graph:-
# * 97% are female from India.
# * Female participation is high in India.
# * Beti Bachao Beti Padhao.

# %% [markdown]
# <img src='https://drive.google.com/uc?id=114MGjz5H6M5ABY2zIq4LxWQVX2aXvVbN' width=500>

# %% [markdown]
# #### ==================================================================================================

# %% [markdown]
# ### Q 20). Number of Times Loans were given to India and it's neighbour.

# %%
count = df_india['country'].value_counts().reset_index()
count.iplot(kind='pie', labels='index', values='country', pull=0.2, hole=0.2,
            title="Frequency of Loan to India and it's neighbour")
plt.show()
# Out:
# <div>
#
#
#             <div id="4e184dff-c93c-4b54-adae-1c82bf76b385" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4e184dff-c93c-4b54-adae-1c82bf76b385")) {
#                     Plotly.newPlot(
#                         '4e184dff-c93c-4b54-adae-1c82bf76b385',
#                         [{"hole": 0.2, "labels": ["Pakistan", "India", "Myanmar (Burma)", "Nepal", "China", "Afghanistan", "Bhutan"], "marker": {"colors": ["rgba(255, 153, 51, 1.0)", "rgba(55, 128, 191, 1.0)", "rgba(50, 171, 96, 1.0)", "rgba(128, 0, 128, 1.0)", "rgba(219, 64, 82, 1.0)", "rgba(0, 128, 128, 1.0)", "rgba(255, 255, 51, 1.0)"]}, "name": "", "pull": 0.2, "type": "pie", "uid": "94568432-3a35-4b5c-bfda-2c7272a23159", "values": [26857, 11237, 1870, 717, 134, 2, 2]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Frequency of Loan to India and it's neighbour"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('4e184dff-c93c-4b54-adae-1c82bf76b385');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### The conclusions from graph:-
# * Pakistan got maximum number of times loan followed by India.
# * China got very less number of times loan.
# * People from Pakistan and India are giving more participation in their economy.

# %% [markdown]
# #### ===================================================================================================

# %% [markdown]
# ### Q 21). Repayment Interval of Loans of  India.

# %%
rep_pay = df_india[df_india['country']=='India']
rep_pay = rep_pay['repayment_interval'].value_counts().reset_index()
rep_pay.iplot(kind='pie', labels='index', values='repayment_interval', pull=0.2, hole=0.2, 
             title='Repayment Interval of Loan of India')
# Out:
# <div>
#
#
#             <div id="07d808d1-1149-4f53-b4d5-a2f06f571afd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("07d808d1-1149-4f53-b4d5-a2f06f571afd")) {
#                     Plotly.newPlot(
#                         '07d808d1-1149-4f53-b4d5-a2f06f571afd',
#                         [{"hole": 0.2, "labels": ["bullet", "monthly", "irregular"], "marker": {"colors": ["rgba(255, 153, 51, 1.0)", "rgba(55, 128, 191, 1.0)", "rgba(50, 171, 96, 1.0)"]}, "name": "", "pull": 0.2, "type": "pie", "uid": "9d18dffc-a16a-479a-a4c6-708b920f58f8", "values": [6575, 4652, 10]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Repayment Interval of Loan of India"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('07d808d1-1149-4f53-b4d5-a2f06f571afd');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### =====================================================================================================

# %% [markdown]
# ### Q 22). Top 10 Cities that got maximum number of times loan from India and it's neighbour.

# %%
region = df_india['region'].value_counts().reset_index()[:10]
region.iplot(kind='bar', x='index', y='region', title='Top 10 Region',
             xTitle='Region', yTitle='Number of times they got Loan')
# Out:
# <div>
#
#
#             <div id="ec85a288-9812-4e08-b352-fc54867c23a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ec85a288-9812-4e08-b352-fc54867c23a4")) {
#                     Plotly.newPlot(
#                         'ec85a288-9812-4e08-b352-fc54867c23a4',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "region", "orientation": "v", "text": "", "type": "bar", "uid": "f2d0df54-7e5f-421e-84fb-d37a760a7dc8", "x": ["Lahore", "Rawalpindi", "Multan", "Gujranwala", "Haripur", "Dhupguri", "Abbottabad", "Falakata", "Gujrat", "Sialkot"], "y": [7178, 4496, 2526, 1466, 1186, 998, 893, 845, 814, 733]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Top 10 Region"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Region"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Number of times they got Loan"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('ec85a288-9812-4e08-b352-fc54867c23a4');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### ==================================================================================================

# %% [markdown]
# ### Q23). Regions of India that got loans, Ploting on map.

# %%
india = df_india[df_india['country']=='India']
region = india['region'].unique()
temp_df = df_loan_region[df_loan_region['region'].isin(region)]

# Getting latitude, longitude and names of regions
lat = temp_df['lat'].unique()
lon = temp_df['lon'].unique()
names = temp_df['region'].unique()

# Ploting India's map
data = [{'lat': lat ,
  'lon': lon , 
  'locationmode':'country names' ,      
  'marker': {
   'line': {'color': 'rgb(40,40,40)', 'width': 0.5},
   'size': 5,
   'sizemode': 'diameter',
            },
  'text': names ,
  'type': 'scattergeo',
  
      }]


layout = go.Layout(
    title = 'Regions of India',
    showlegend = True,
    geo = dict(
            scope='asia' ,
            projection=dict( type = 'natural earth'),
            showland = True,
            landcolor = 'rgb(217, 217, 217)',
            subunitwidth=1,
            countrywidth=1,
            subunitcolor="rgb(255, 255, 255)",
            countrycolor="rgb(255, 255, 255)"
        ),)

fig =  go.Figure(layout=layout, data=data)
iplot( fig, validate=False)
# Out:
# <div>
#
#
#             <div id="8a4767a1-75d3-40b5-a731-8a6fc991650d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8a4767a1-75d3-40b5-a731-8a6fc991650d")) {
#                     Plotly.newPlot(
#                         '8a4767a1-75d3-40b5-a731-8a6fc991650d',
#                         [{"lat": [27.1766701, 29.058775699999998, 26.9124336, 28.6139391, 23.0678795, 24.2993576, 24.7806536, 25.0577509, 21.214848800000002, 20.8444033, 20.1995085, 20.1783322, 20.851409, 20.3949879, 21.342583899999997, 21.932233800000002, 21.2777569, 20.2022439, 21.0582737, 19.9358071, 21.1938475, 20.922309100000003, 20.7074234, 21.820617000000002, 20.6607447, 22.0649923, 20.709961800000002, 19.3512086, 20.5260174, 20.3356444, 21.3934955, 20.2934656, 22.744107999999997, 19.4712491, 18.860612600000003, 21.8554375, 21.628933, 20.1850477, 20.130141000000002, 22.3594501, 19.1404296, 21.742757100000002, 20.2511789, 20.463451, 20.1654348, 20.0159313, 22.2375766, 20.712702800000002, 20.4797108, 21.2525223, 22.270932199999997, 22.190196, 29.4464076, 21.0741608, 20.484348999999998, 18.711169899999998, 20.8480141, 21.2879184, 19.9246059, 20.28709, 21.5771624, 19.664737, 20.8420718, 21.369030399999996, 20.834101899999997, 19.9074279, 20.4267068, 19.075464800000002, null, 20.075245000000002, 20.194032999999997, 19.621150399999998, 20.4273843, 19.171209, 20.0987823, 26.5821321, 26.517485999999998, 23.946800500000002, 26.3504353, 19.0759837, 23.1683667, 23.022505, 26.4918891, 22.3059709, 23.113460500000002, 20.2561729, 22.0363157, 21.4869337, 20.3765951, 23.2930388, 27.216981, 20.2960587, 23.232421399999996, 22.535657399999998, 23.1115671, 26.1889622, 26.335686100000004, 20.462521, 22.8379314, 23.164267300000002, 22.6012922, 22.983224800000002, 27.566417100000002, 11.1522657, 23.075297, 23.2156354, 25.40091, 22.6803614, 20.4923018, 20.7652197, 26.543477199999998, 22.769666, 19.9137363, 23.2248593, 26.316081899999997, 20.0029267, 10.9600778, 20.584832100000003, 20.1934552, 22.2068295, 10.937347, 23.7337326, 26.1416733, 22.5663018, 24.663717300000002, 11.059875300000002, 22.8119895, 10.9548837, 23.470965600000003, 11.2194391, 24.7130843, 22.6168099, 25.98103930000001, 20.5070532, 18.5204303, 23.0122956, 10.379663, 19.8133822, 18.6600475, 25.6185295, 25.447017600000002, 20.303366600000004, 23.346613199999997, 23.2645399, 25.371530800000002, 22.9501776, 20.933811300000002, 22.7738938, 25.4939548, 10.786999400000001, 11.121961099999998, 24.644924300000003, 11.1414545, 10.790483300000002, 25.7557523, 22.711454, 23.0981684], "locationmode": "country names", "lon": [78.0080745, 76.085601, 75.78727090000002, 77.20902120000002, 87.31652220000002, 93.2583626, 93.9674371, 94.0296354, 86.12489670000002, 85.1510818, 85.9595797, 85.11292359999999, 85.2135931, 85.8537418, 83.624201, 86.7516942, 82.8236678, 85.4517403, 86.4958396, 84.582481, 81.3509416, 84.7485315, 83.4842725, 84.951573, 84.14351359999998, 85.6666046, 86.0988253, 84.9869547, 85.9077675, 84.8489739, 85.8930285, 85.841589, 77.736967, 82.8068156, 82.5510469, 84.0061661, 85.58168470000003, 83.2104426, 85.47880649999998, 82.75005949999998, 82.318057, 84.34894670000001, 74.43660159999997, 85.0837293, 85.02334599999998, 84.8033402, 83.13809549999998, 84.2331485, 82.5158778, 86.17008940000002, 84.5798623, 79.5596415, 84.34105859999998, 86.1191966, 82.850778, 83.8950042, 86.6913222, 85.3966448, 83.1466077, 86.5653087, 82.2121421, 79.32610840000002, 83.775678, 86.3326058, 83.16415620000002, 82.700989, 83.8128265, null, 82.7258705, 83.5169613, 83.4987493, 82.7171792, 83.41632259999999, 82.64699379999998, 89.0051441, 89.2039195, 88.04971450000002, 89.44348620000002, 72.87765590000002, 72.57815450000002, 72.57136209999999, 89.52710259999998, 74.35581479999998, 70.0260132, 85.780109, 74.903339, 86.9246005, 85.52903609999998, 70.339045, 77.489515, 85.8245398, 87.8614793, 74.3323529, 72.57276209999998, 91.77290129999999, 89.445851, 85.88298950000002, 74.2531465, 72.8101887, 75.3024655, 71.474461, 95.5551652, 78.2988637, 70.133673, 72.6369415, 88.53236059999998, 74.278819, 85.9457837, 86.17517590000001, 88.72052559999999, 74.5920921, 83.1649001, 88.3482188, 91.5983959, 85.64926740000001, 78.0766036, 86.6611083, 85.6332093, 74.7556518, 78.4211897, 69.8597406, 91.7453642, 71.7963228, 93.9062 ...
#                         {"geo": {"countrycolor": "rgb(255

# %% [markdown]
# #### ===================================================================================================
# #### ===================================================================================================
# #### ===================================================================================================
# #### ===================================================================================================

# %% [markdown]
# # -> If you this kernel is useful, then Please UPVOTE
# <img src='https://drive.google.com/uc?id=1TEz_J-UVI5oqOtSk7ykwX5TBHE3R043T' width=600>
