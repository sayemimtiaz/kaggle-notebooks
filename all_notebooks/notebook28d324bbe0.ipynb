# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as mons
import plotly.express as px
import plotly.graph_objects as go
import os

# %%
data=pd.read_csv("../input/forbes-billionaires-of-2021-20/forbes_billionaires.csv")

# %%
data.head()

# %%
mons.bar(data)

# %% [markdown]
# # Missing data in Children & Education & Sataus

# %%
data.info()

# %%
data.describe()

# %%
data.head()

# %%
plt.figure(figsize=(30,10))
sns.countplot(x='Country', data=data)
plt.xticks(rotation=90)
plt.show()

# %%
data['Source'].value_counts()

# %%
sns.histplot(data=data,x='Age')

# %%
plt.figure(figsize=(14,10))
sns.countplot(x='Status', data=data)
plt.show()

# %%
data['NetWorth'].sort_values()

# %%
top_20=data[ :20]

# %% [markdown]
# # This 20 Top

# %%
top_20.head()

# %%
plt.figure(figsize=(10,15))
sns.barplot(data=top_20, x='Name', y ="NetWorth")
plt.xticks(rotation=90)
plt.show()

# %%
fig , axis =plt.subplots(2,2,figsize=(20,20))
sns.barplot(data=top_20, x='Country', y ="NetWorth", ax=axis[0,0])
sns.barplot(data=top_20, x='Age', y ="NetWorth", ax=axis[0,1])
sns.barplot(data=top_20, x='NetWorth', y ="Source", ax=axis[1,0] )
sns.barplot(data=top_20, x='Status', y ="NetWorth", ax=axis[1,1])

plt.show()
