# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")

# %%
# Fill in the line below: Specify the path of the CSV file to read
my_filepath = "../input/body-weight-and-fat-percentage/Body weight and fat percentage.csv"

# Fill in the line below: Read the file into a variable my_data
my_data = pd.read_csv(my_filepath, index_col="Date", parse_dates=True)

# Print the first five rows of the data
my_data.head()

# %%
# Create a plot
plt.figure(figsize=(16,6)) # Your code here
sns.set_style("darkgrid")

# Plot daily data
sns.lineplot(x=my_data.index,y=my_data['Weight (kg)']) 

# Plot weekly data for every Mon
# sns.lineplot(x=my_data[my_data['Day of Week']=="Mon"].index, 
#              y=my_data[my_data['Day of Week']=="Mon"]['Weight (kg)'])
