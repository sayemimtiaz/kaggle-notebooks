# %%
# !apt-get update
# !apt-get install pspp -y

# %%
# !ls ../input/narcissism-ingroup-satisfaction

# %%
# !pspp-convert ../input/narcissism-ingroup-satisfaction/CN_emotionality_Study1a.sav CN_emotionality_Study1a.csv
# !pspp-convert ../input/narcissism-ingroup-satisfaction/CN_emotionality_Study1b.sav CN_emotionality_Study1b.csv
# !pspp-convert ../input/narcissism-ingroup-satisfaction/CN_emotionality_Study2.sav CN_emotionality_Study2.csv
# !pspp-convert ../input/narcissism-ingroup-satisfaction/CN_emotions_Study3.sav CN_emotions_Study3.csv
