# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading the Dataset

# %%
store=pd.read_csv("../input/superstore-sales-dataset/SuperStore_Orders.csv")
store.head()

# %%
store.shape

# %%
store.isnull()

# %% [markdown]
# # DATA Cleaning

# %%
store.info()

# %%
sns.heatmap(store.isnull(),yticklabels=False,cbar=False)

# %% [markdown]
# # Looks like Our Data has no null values, lets analyze our data

# %%
store.describe()

# %%
store["country"].value_counts()[0:10]

# %% [markdown]
# # Top 10 consumer countries

# %%
L1=["United States","Australia","France","Mexico","Germany","China","United Kingdom","Brazil","India","Indonesia"]
L2=[9994,2837,2827,2644,2065,1880,1633,1599,1555,1390]
sns.barplot(x=L2,y=L1)
sns.set_theme(style="darkgrid")
plt.title("Top 10 consumer countries in world")
plt.xlabel("count")
plt.ylabel("countries")

# %% [markdown]
# # Analyzing top 10 counsumer countries orders as per categories and sub-categories

# %%
#As we can see US is the largest consumer in world
Store_US=store[store["country"]=="United States"]
Store_Aus=store[store["country"]=="Australia"]
Store_FR=store[store["country"]=="France"]
Store_Mex=store[store["country"]=="Mexico"]
Store_Ger=store[store["country"]=="Germany"]
Store_Chi=store[store["country"]=="China"]
Store_UK=store[store["country"]=="United Kingdom"]
Store_Braz=store[store["country"]=="Brazil"]
Store_Ind=store[store["country"]=="India"]
Store_Indo=store[store["country"]=="Indonesia"]

# %%
#Products by Categories consumed by Top 10 countries
plt.figure(figsize=(15,10))
plt.title("United States")
sns.set_theme(style="darkgrid")
sns.countplot(x=Store_US["category"],hue=Store_US["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("Australia")
sns.set_theme(style="darkgrid")
sns.countplot(x=Store_Aus["category"],hue=Store_Aus["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("France")
sns.set_theme(style="darkgrid")
sns.countplot(x=Store_FR["category"],hue=Store_FR["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("Mexico")
sns.set_theme(style="darkgrid")
sns.countplot(x=Store_Mex["category"],hue=Store_Mex["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("Germany")
sns.set_theme(style="darkgrid")
sns.countplot(x=Store_Ger["category"],hue=Store_Ger["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("China")
sns.set_theme(style="darkgrid")
sns.countplot(x=Store_Chi["category"],hue=Store_Chi["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("Brazil")
sns.set_theme(style="darkgrid")
sns.countplot(x=Store_UK["category"],hue=Store_UK["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("United States")
sns.set_theme(style="darkgrid")
sns.countplot(x=Store_Braz["category"],hue=Store_Braz["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("India")
sns.set_theme(style="darkgrid")
sns.countplot(x=Store_Ind["category"],hue=Store_Ind["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("Indonesia")
sns.set_theme(style="darkgrid")
sns.countplot(x=Store_Indo["category"],hue=Store_Indo["sub_category"])

# %%
store.head(1)

# %%
store["segment"].value_counts()

# %% [markdown]
# # Analyzing the product needs of Top 10 countries as per Coustomer Segment

# %%
#Products by Categories consumed by Top 10 countries
plt.figure(figsize=(15,10))
plt.title("United States")
sns.set_theme(style="darkgrid")
sns.countplot(x=Store_US["segment"],hue=Store_US["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("Australia")
sns.set_theme(style="darkgrid")
sns.countplot(x=Store_Aus["segment"],hue=Store_Aus["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("France")
sns.set_theme(style="darkgrid")
sns.countplot(x=Store_FR["segment"],hue=Store_FR["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("Mexico")
sns.set_theme(style="darkgrid")
sns.countplot(x=Store_Mex["segment"],hue=Store_Mex["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("Germany")
sns.set_theme(style="darkgrid")
sns.countplot(x=Store_Ger["segment"],hue=Store_Ger["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("China")
sns.set_theme(style="darkgrid")
sns.countplot(x=Store_Chi["segment"],hue=Store_Chi["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("Brazil")
sns.set_theme(style="darkgrid")
sns.countplot(x=Store_UK["segment"],hue=Store_UK["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("United States")
sns.set_theme(style="darkgrid")
sns.countplot(x=Store_Braz["segment"],hue=Store_Braz["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("India")
sns.set_theme(style="darkgrid")
sns.countplot(x=Store_Ind["segment"],hue=Store_Ind["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("Indonesia")
sns.set_theme(style="darkgrid")
sns.countplot(x=Store_Indo["segment"],hue=Store_Indo["sub_category"])

# %% [markdown]
# # So as we can see almost in every top 10 consumer countries, consumer segment is highly contributing in store sale than corporate segment and home office segment

# %%
store.head(5)

# %%
plt.figure(figsize=(15,10))
plt.pie(store['sub_category'].value_counts(),labels=store["sub_category"].value_counts().keys(),autopct="%0.1f%%")
plt.show()

# %% [markdown]
# # Growth of Super-store over years 2011-2014

# %%
store["year"].value_counts()

# %%
store["sales"]=store["sales"].str.replace(',',"")
store["sales"]=pd.to_numeric(store["sales"])
store_1=store.sort_values(by=["year"],ascending=True)
store_1.head()

# %%
store_2011=store_1[store_1["year"]==2011]
store_2011["quantity"].sum()

# %%
store_2012=store_1[store_1["year"]==2012]
store_2012["quantity"].sum()

# %%
store_2013=store_1[store_1["year"]==2013]
store_2013["quantity"].sum()

# %%
store_2014=store_1[store_1["year"]==2014]
store_2014["quantity"].sum()

# %%
S1=[2011,2012,2013,2014]
S2=[31443,38111,48136,60622]
sns.barplot(x=S1,y=S2)
plt.xlabel("Years")
plt.ylabel("growth in sales of products")
plt.title("Growth of US Store")

# %% [markdown]
# # SALES vs. PROFITS

# %%
value = store.groupby('year').sum()[['sales','profit']]
value.plot(kind='bar',figsize=(16,5))
plt.title("Sales vs. Profits")
plt.ylabel("In Lakhs")

# %% [markdown]
# # Analyzing shiping mode for each category in Super-store

# %%
store.head()

# %%
store["ship_mode"].value_counts()

# %%
plt.figure(figsize=(10,7))
sns.countplot(x=store["category"],hue=store["ship_mode"])

# %%
store.head(1)

# %%
store["market"].value_counts()

# %% [markdown]
# # Checking the concentration of customer segment in each market

# %%
store_apac=store[store["market"]=="APAC"]
store_Lat=store[store["market"]=="LATAM"]
store_eu=store[store["market"]=="EU"]
store_us=store[store["market"]=="US"]
store_Emea=store[store["market"]=="EMEA"]
store_af=store[store["market"]=="Africa"]
store_can=store[store["market"]=="Canada"]

# %%
plt.title("APAC market")
sns.countplot(x=store_apac["segment"],hue=store_apac["category"])
plt.show()
##################################################################
plt.title("LATAM market")
sns.countplot(x=store_Lat["segment"],hue=store_Lat["category"])
plt.show()
##################################################################
plt.title("EU market")
sns.countplot(x=store_eu["segment"],hue=store_eu["category"])
plt.show()
##################################################################
plt.title("US market")
sns.countplot(x=store_us["segment"],hue=store_us["category"])
plt.show()
##################################################################
plt.title("EMEA market")
sns.countplot(x=store_apac["segment"],hue=store_apac["category"])
plt.show()
##################################################################
plt.title("Africa market")
sns.countplot(x=store_af["segment"],hue=store_af["category"])
plt.show()
##################################################################
plt.title("Canada market")
sns.countplot(x=store_can["segment"],hue=store_can["category"])
plt.show()

# %% [markdown]
# # In above Visuals we can see the spread of Office Supplies, Furniture, Technology requirements in each markets of world

# %%
store.head(2)

# %% [markdown]
# # Analyzing profits from each Category

# %%
categorical_profits = store.groupby('category').sum()[['sales','profit']]
categorical_profits.plot(kind='bar',figsize=(16,5))
plt.ylabel("In millions")

# %% [markdown]
# # So from the above visuals we can see that Office Supplies is most profitable than other categories

# %%
store.head(2)

# %% [markdown]
# # Analyzing profits from each Market in world

# %%
Regional_profits = store.groupby('market').sum()[['sales','profit']]
Regional_profits.plot(kind='bar',figsize=(16,5))
plt.ylabel("In millions")

# %% [markdown]
# # From above visual we can easily conclude that most of sales and profits coming from APAC market followed by EU, US and LATAM markets
