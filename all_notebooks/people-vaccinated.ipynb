# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df=pd.read_csv("../input/covid-vaccination-india-district-wise-data/vaccine_doses_statewise.csv")

# %%
df

# %% [markdown]
# # **India**

# %%
import matplotlib.pyplot as plt

# %%
df=df.rename(columns={'10/07/2021':'Total vaccinated'})

# %%
df=df.drop(36,axis=0)

# %%
#population of each state
Population=[420000,54400000,1592000,36000000,127000000,1169000,29800000,620000,19000000,1600000,64300000,28500000,7500000,13800000,39200000,68300000,36000000,290000,74151,87000000,124300000,3200000,3400000,1255000,2300000,46900000,1432000,30000000,82500000,700000,78500000,39800000,4200000,240000000,11400000,100000000,1386452151]

# %%
df['Total Population']=Population

# %%
df['%age Vaccinated']=(df['Total vaccinated'] / df['Total Population']) * 100

# %%
Vaccination=df[['State','%age Vaccinated']].drop(37)

# %%
Total=df[['State','%age Vaccinated']]
Total=Total.loc[Total.State=='Total']

# %% [markdown]
# **%age of people vaccinated in india**

# %%
plt.figure(figsize=(15,8))
plt.bar(Vaccination['State'],Vaccination['%age Vaccinated'],color=(Vaccination.State=='Punjab').map({True:'#8C000F',False:'#929591'}))
plt.axhline(Total['%age Vaccinated'].values, color = '#008000', ls = '--', lw = 5,label ='Total %age vaccinated in India')
plt.xlabel('States')
plt.ylabel('Percentage')
plt.title('%age of people vaccinated in each state')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # **States**

# %%
df = df.set_index(['State'])

# %%
df=df.rename(columns={'Total vaccinated':'10/07/2021'})

# %%
df=df.drop(['Total Population','%age Vaccinated'], axis = 1)

# %%
df = df.T.reset_index()

# %%
df=df.drop(['Total'], axis = 1)

# %% [markdown]
# **states with nearly same population**

# %%
df[['index', 'Punjab','Chhattisgarh','Haryana']].set_index(['index']).plot(figsize = (15, 8))
#plt.axhline(10 ** 6, color = 'maroon', linestyle = ':')
plt.xticks(rotation = 90)
plt.show()

# %%
df[['index', 'Assam','Kerala']].set_index(['index']).plot(figsize = (15, 8))
#plt.axhline(10 ** 6, color = 'maroon', linestyle = ':')
plt.xticks(rotation = 90)
plt.show()

# %%
df[['index', 'Telangana','Jharkhand']].set_index(['index']).plot(figsize = (15, 8))
#plt.axhline(10 ** 6, color = 'maroon', linestyle = ':')
plt.xticks(rotation = 90)
plt.show()

# %%
df[['index', 'Karnataka','Gujarat']].set_index(['index']).plot(figsize = (15, 8))
#plt.axhline(10 ** 6, color = 'maroon', linestyle = ':')
plt.xticks(rotation = 90)
plt.show()

# %%
df[['index', 'Madhya Pradesh','Rajasthan']].set_index(['index']).plot(figsize = (15, 8))
#plt.axhline(10 ** 6, color = 'maroon', linestyle = ':')
plt.xticks(rotation = 90)
plt.show()

# %%
df[['index', 'Jammu and Kashmir','Uttarakhand']].set_index(['index']).plot(figsize = (15, 8))
#plt.axhline(10 ** 6, color = 'maroon', linestyle = ':')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # **Punjab**

# %%
df[['index', 'Punjab']].set_index(['index']).plot(figsize = (15, 8))
plt.xticks(rotation = 90)
plt.show()

# %%
df['Punjab'].head()

# %%
df['dailyPunjab'] = df['Punjab'] - df['Punjab'].shift(1).fillna(0)

# %% [markdown]
# **daily people vaccinated**

# %%
df[['index', 'dailyPunjab']].set_index(['index']).plot(figsize = (15, 8))
plt.xticks(rotation = 90)
plt.show()
