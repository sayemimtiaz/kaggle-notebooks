# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd

url=pd.read_csv('/kaggle/input/house-price-prediction-challenge-machine-hack/Train.csv')
url.head()

url.shape

url.describe()

# %%
url.iloc[0]

url.iloc[1:4]

url.iloc[:4]

url = url.set_index(url['POSTED_BY'])

url=url.delete(url['POSTED_BY'])

url.loc['Owner']

# %%
url[url['POSTED_BY'] == 'Dealer'].head(2)

url[(url['POSTED_BY'] == 'Dealer') & (url['BHK_NO.'] >= 2)]

url[(url['POSTED_BY'] == 'Dealer') & (url['BHK_NO.'] >= 2) & (url['LATITUDE'] > 70)]

url[(url['POSTED_BY'] == 'Owner') & (url['BHK_NO.'] >= 2) & (url['LATITUDE'] < 70)]

url[(url['POSTED_BY'] == 'Owner') & (url['BHK_NO.'] >= 2) & (url['LATITUDE'] > 70) & (url['LONGITUDE'] >= 30)]

# %%
url['BHK_OR_RK'].replace("BHK", "bhk").head(2)

url['POSTED_BY'].replace(["Dealer", "Owner"], ["dealer", "owner"]).head(5)

url.replace(1, "One").head(2)

url['BHK_NO.'].replace(2, "Two").head(2)

url.replace(0, "Zero").head(2)

url.head()



#url.replace(r"1st", "First", regex=True).head(2)

# %%
url.rename(columns={'POSTED_BY': 'Post_ed_by'}).head(2)

url.rename(columns={'UNDER_CONSTRUCTION': 'under_cons', 'READY_TO_MOVE': 'R_T_M'}).head(2)

import collections

column_names = collections.defaultdict(str)

   for name in url.columns:column_names[name]

column_names

url.head()

# %%
url.info()

print('Maximum:', url['UNDER_CONSTRUCTION'].max())
print('Minimum:', url['TARGET(PRICE_IN_LACS)'].min())
print('Mean:', url['SQUARE_FT'].mean())
print('Sum:', url['BHK_NO.'].sum())
print('Count:', url['RERA'].count())

# %%
url.std()

# %%
print(url.loc[:,'SQUARE_FT'].std())
print(url.loc[:,'TARGET(PRICE_IN_LACS)'].std())

#calculate the standard deviation of the first five rows 
url.std(axis = 1)[0:5]

# %%
url.var()

# %%
from scipy.stats import iqr
iqr(url['LONGITUDE'])

# %%
print(url.skew())
