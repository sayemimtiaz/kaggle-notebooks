# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.

# %% [markdown]
# **Use Cases:**
# * Who is more likely to commit suicide(Male or Female)
# * Which Age segment is most susceptible to suicide
# * Does year in consideration play a imporatant role in suicide
# * Predicting the sex of the suicide based on Age, Year and Country.
# * Developed countries vs Non Developed Countries(Need to tag all countries as Developed and Non Developed)

# %%
import seaborn as sns
import numpy as np
df = pd.read_csv(r"../input/who_suicide_statistics.csv")
df.head()

# %%
#Converting Population to in Lacs
df.population = df.apply(lambda x:x['population']/100000,axis=1)
df.head()

# %%
df.isna().any()

# %%
#No of Null values in population
df.population.isnull().count()-df.population.count()

# %%
import missingno as msno
msno.matrix(df)

# %% [markdown]
# **It Seems like population data of certain countries during certain years are missing and Suicide Nos is showing null instead of zero **

# %% [markdown]
# **Replacing Suicide Nos Null values with zero and changing it to a Integer value**

# %%
df['suicides_no'].fillna(value=0,inplace=True)
df['suicides_no'] = df['suicides_no'].astype(int)
df.head()

# %% [markdown]
# **Droppin Population Column**

# %%
df.drop(['population'],axis=1,inplace = True)

# %%
df['country'].value_counts().sort_values().head(30).plot.bar(figsize  = (17,9), title = "Suicide Amount for 30 Countries(Ascending)")

# %% [markdown]
# <H2>No of Countries in the list</H2>

# %%
len(df['country'].unique())

# %% [markdown]
# <H2> Years in Consideration</H2>

# %%
print(min(df.year))
print(max(df.year))

# %% [markdown]
# <H2>The data shows that males are more susceptible to suicide than Females</H2>

# %%
print(df.groupby('sex')['suicides_no'].sum())
df.groupby('sex')['suicides_no'].sum().plot.bar(figsize=(12,7),title = "Male vs Female Overall Suicide comparison")

# %%
#understanding Age bins
df.age.unique()

# %%
print(df.groupby('age')['suicides_no'].sum())
df.groupby('age')['suicides_no'].sum().sort_index().plot.bar(figsize=(15,7),title = "Agewise Suicide comparison")

# %% [markdown]
# <H2> Binning Data into a interval of 10 years</H2>

# %%
bins = [1978,1988,1998,2008,2016]
df['binned'] = pd.cut(df['year'], bins)
df.head()

# %% [markdown]
# **Interestingly Most suicides happened during 1999-2008**

# %%
print(df.groupby('binned')['suicides_no'].sum())
df.groupby('binned')['suicides_no'].sum().sort_index().plot.bar(figsize=(15,8),title = "Suicide comparison for 10 Yr Intervals")

# %%
#sns.barplot(x=df['binned'], y = )
data = df.groupby('binned')['suicides_no'].sum()
data

# %%
sns.barplot(x=data.index,y=data)

# %%
print(df[df.sex=='female'].groupby('binned')['suicides_no'].sum())
print(df[df.sex=='male'].groupby('binned')['suicides_no'].sum())

# %% [markdown]
# ![](https://imgur.com/a/uamJrA2.jpg)

# %% [markdown]
# **Male Vs Female Ratio at over these periods. The exact values are in the above print**

# %% [markdown]
# <a href="http://imgbox.com/haHvbm27" target="_blank"><img src="https://images2.imgbox.com/46/fb/haHvbm27_o.png" alt="image host"/></a>

# %% [markdown]
# 1. Hmm... It seems the ratio seems constant over all these periods(75%±2% Male and 25±2%Females). Not that big deviation in my opinion. A really interesting takeaway.
# 2. It seems the year in consideration doesn't play a significant role atleast when the comparison is between Male and Female.Considering the fact the Female-Male actual population ratio is 1:1 approx.

# %% [markdown]
# **Now lets see a Male vs Female (Stacked Age Bar Comparison)**

# %%
df.groupby(['sex','age','binned'], as_index=False)['suicides_no'].sum().head()

# %% [markdown]
# <a href="http://imgbox.com/X2V9w8DB" target="_blank"><img src="https://images2.imgbox.com/ea/70/X2V9w8DB_o.png" alt="image host"/></a>

# %% [markdown]
# Here some Observation that can be made are:
# 1. At Age 15-24 the ratio is around 12.5% for both Male and Female. This shows tha tcollege period of life amounts to same level of stress
# 2. At the age of 25-34 Male suicide 6%  higher than female[Work Stress] which gradually reduces through the timeline    signifying the equal employment leading to same level of stress.
# 3. A similar scenario signifying the share of strees as time progresses.
# 4. It seems like at old ages women feel more lonely since their male counterparts die sooner. Hence higher suicide rate.
# 5. Age of 5-14 is most probaly an accident or an extreme conditions caused by abuse/peer pressure. It is very small to make an effective analysis
# 6. Overall the highest amount of death occurs at the age group of 35-54 years. Mostly during the working, married, child rearing phases of their life.
