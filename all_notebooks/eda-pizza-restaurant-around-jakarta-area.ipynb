# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load



import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(10, 8)});

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# Read The Data

# %%
pizza = pd.read_csv('/kaggle/input/pizza-sushi-restaurant-around-jakarta-area/Pizza Around Jakarta Area.csv')
pizza.head()

# %% [markdown]
# Make Column Name Easy to Process

# %%
pizza.columns = ['rest_name', 'rest_zone','rating','review','rest_address','rest_type','rest_cost','rest_time']
pizza.head()

# %% [raw]
# View some basic statistical

# %%
pizza.describe()

# %% [markdown]
# Check Missing Value

# %%
pizza.isnull()

# %% [markdown]
# Let’s print the full summary of the dataframe.

# %%
pizza.info()

# %%
pizza['rest_zone'].value_counts()

# %% [markdown]
# Show Rating by Zone

# %%
pizza.groupby('rest_zone')['rating'].mean()

# %%
pizza.groupby('rest_zone')['rating'].mean().plot(kind='bar')
plt.ylabel('Average Rating') 
plt.show();

# %%
pizza.groupby('rest_type')['rating'].mean().plot(kind='bar')
plt.ylabel('Average Rating') 
plt.show();
