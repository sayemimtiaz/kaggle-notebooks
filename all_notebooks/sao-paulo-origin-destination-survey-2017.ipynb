# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

pd.set_option("display.precision", 2)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv("../input/origindestination-sao-paulo/od_2017_header.csv")

df.head()

# %%
sorted(list(df.columns))

# %%
df.index

# %%
df.Renda_Individual.mean()

# %%
df.values

# %%
df.Renda_Individual.describe()

# %%
import matplotlib.pyplot as plt

import seaborn as sns

# %%
#histogram
plt.figure(figsize=(12,6))
sns.distplot(a=df['Municipio_de_Domicilio'], kde=False)

# %%
plt.figure(figsize=(12,6))
sns.kdeplot(data=df['Municipio_de_Domicilio'], shade=True, )

# %%
plt.figure(figsize=(12,6))
sns.jointplot(x=df['Municipio_de_Origem'], y=df['Municipio_de_Destino'], kind = 'kde')

# %%
#Zonas Origem
plt.figure(figsize=(12,6))
sns.distplot(a=df['Zona_de_Origem'], kde=False)

# %%
#Zonas Origem
plt.figure(figsize=(12,6))
sns.kdeplot(data=df['Zona_de_Origem'], shade=True)

# %%
subdf = df[(df.Municipio_de_Origem != 36)]

# %%
plt.figure(figsize=(12,6))
sns.kdeplot(data=subdf['Municipio_de_Origem'], shade=True, )

# %%
plt.figure(figsize=(12,6))
sns.jointplot(x=subdf['Municipio_de_Origem'], y=subdf['Municipio_de_Destino'], kind = 'kde')

# %%
plt.figure(figsize=(12,6))
sns.jointplot(x=subdf['Municipio_de_Origem'], y=subdf['Municipio_de_Destino'], kind = 'hex')

# %%
plt.figure(figsize=(12,6))
sns.kdeplot(data=subdf['Municipio_de_Origem'], shade=True, )

# %%
plt.figure(figsize=(12,6))
sns.set_style("dark")
sns.distplot(a=subdf['Municipio_de_Origem'])

# %% [markdown]
# Informações sobre Localização
# Municipio Origem
# Municipio Destino

# %%
plt.figure(figsize=(12,6))
sns.jointplot(x=df['Municipio_de_Origem'], y=df['Municipio_de_Destino'], kind = 'kde')

# %% [markdown]
# # Informações Socio Economicas
# **Renda Individual
# Renda Familia**

# %%
#Renda Individual
plt.figure(figsize=(12,6))
sns.distplot(a=df['Renda_Individual'])

# %%
#Renda Familiar
plt.figure(figsize=(12,6))
sns.distplot(a=df['Renda_Familiar_Mensal'])

# %% [markdown]
# # Modal transporte

# %%
#Modal Transporte Principal
plt.figure(figsize=(12,6))
sns.distplot(a=df['Modo_Principal'])

# %%
Motivo deslocamento

# %%
#Motivo deslocamento
plt.figure(figsize=(12,6))
sns.distplot(a=df['Motivo_no_Destino'])
