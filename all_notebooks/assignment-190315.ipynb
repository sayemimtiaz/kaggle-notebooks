# %%
import pandas as pd

# %%
df = pd.read_csv('../input/up-crime-data-year-2019/MR data - Compiled Data Set.csv')
df.head()

# %%
df = df.drop(['Title'], axis=1)
df = df.drop(['Text'], axis=1)
df.head(10)

# %%
df = df.fillna(0)
col = df.columns
df.columns = [i for i in range(0,len(df.columns))]

# %%
df.head(15)

# %%
dict={0:0,'Property Disputes':1,'Family Dispute':2,'Petty Quarrels':3,'Money Disputes':4, 'Personal Vendetta':5, 'Love Affairs':6, 'Casteism':7,'Unknown reasons':8}

# %%
df[1]=df[1].apply(lambda x : dict[x])
df.head()

# %%
df[11]=0
df[12]=0
for i in range(0,len(df)):
    #print(df.iloc[i,8])
    if ',' in str(df.iloc[i,8]):
        cl=df.iloc[i,8].split(',')
        df.iloc[i,8]=int(cl[0])
        df.iloc[i,11]=int(cl[1])
        if len(cl)>2:
            df.iloc[i,12]=int(cl[2])
    elif int(df.iloc[i,8])>100:
        df.iloc[i,11]=int(df.iloc[i,8])%100
        df.iloc[i,8]=int(df.iloc[i,8])//100

# %%
df.head()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
df.groupby(by=1).sum()

# %%
df[1].value_counts()

# %%
arr3 = np.array(df[1].value_counts()*(df.groupby(by=1).sum()[2] + df.groupby(by=1).sum()[3] + df.groupby(by=1).sum()[4]+df.groupby(by=1).sum()[5]+df.groupby(by=1).sum()[6]+df.groupby(by=1).sum()[7]+df.groupby(by=1).sum()[9]+df.groupby(by=1).sum()[10]))

# %%
arr3

# %%
# crime #6 is affecting society much greater than remaining crimes(excluding crime #0 ans crime#8)

# %%
arr1 = np.array(df[11])

# %%
plt.hist(arr1)

# %%
arr2 = np.array(df[12])
plt.hist(arr2)

# %%
# as it can be seen from the histogram that crimes #10 ,#8, #6 do not occurs alone
