# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import plotly.offline as py
import plotly.express as px

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ![](https://www.99images.com/photos/quotes/freedom-quotes/short-freedom-image-quotes-for-whatsapp-dp-status-instagram-wz4i.png?v=1583756809)99images.com

# %% [markdown]
# #Political systems (or regimes )
#
# "Authoritarianism is one of the three main types of political systems (or regimes ), democracy and totalitarianism being the other two. Scholars also increasingly recognize a hybrid between authoritarianism and democracy as forming its own ideal type regime, generally called either semi-authoritarian or semi-democratic systems."
#
# https://www.encyclopedia.com/social-sciences-and-law/sociology-and-social-reform/sociology-general-terms-and-concepts/authoritarianism
#
# #Authoritarianism
#
# "Principle of blind submission to authority, as opposed to individual freedom of thought and action. In government, authoritarianism denotes any political system that concentrates power in the hands of a leader or a small elite that is not constitutionally responsible to the body of the people. Authoritarian leaders often exercise power arbitrarily and without regard to existing bodies of law, and they usually cannot be replaced by citizens choosing freely among various competitors in elections. The freedom to create opposition political parties or other alternative political groupings with which to compete for power with the ruling group is either limited or nonexistent in authoritarian regimes."
#
# https://www.britannica.com/topic/authoritarianism

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
df = pd.read_csv('../input/cusersmarildownloadsallcsv/all.csv', delimiter=';', encoding = "ISO-8859-2", nrows = nRowsRead)
df.dataframeName = 'all.csv'
nRow, nCol = df.shape
print(f'There are {nRow} rows and {nCol} columns')
df.head().style.set_properties(**{'background-color':'LightPink',
                                     'color': 'purple'})

# %% [markdown]
# #TYPES OF AUTHORITARIANISM
#
# "Just as social scientists identify various types of democratic systems, scholars highlight three types of authoritarianism. A military authoritarian system is one in which the military is not only privileged—as it typically is in all authoritarian systems—but actually in control of all major aspects of government decision-making."
#
# "In party authoritarian systems, on the other hand, a single political party dominates the system. Though this is also true of totalitarian systems, party authoritarian systems penetrate into society less than totalitarian systems. Party authoritarian systems may even tolerate small opposition parties and use mechanisms of democracy like elections in an effort to increase their legitimacy with the public."
#
# "Bureaucratic authoritarian systems are run by the military but rely heavily on experts in the fields of economics and other policy areas, often allowing them significant autonomy to set and oversee government policy. Social scientists often label these officials technocrats. Military leaders point to the technical expertise of these bureaucrats as a key component of their economic modernization policies, which are introduced under harsh authoritarian conditions to prevent opposition to economic reforms."
#
# https://www.encyclopedia.com/social-sciences-and-law/sociology-and-social-reform/sociology-general-terms-and-concepts/authoritarianism

# %%
df.isnull().sum()

# %% [markdown]
# #Status: F: Free; PF: Partly Free; NF: Not Free

# %%
df["edition"].value_counts()

# %%
#Code by Lucas Abrahão https://www.kaggle.com/lucasabrahao/trabalho-manufatura-an-lise-de-dados-no-brasil

df["status"].value_counts().plot.barh(color=['blue', '#f5005a', 'chartreuse'], title='Freedom Status',);

# %%
#Code by Lucas Abrahão https://www.kaggle.com/lucasabrahao/trabalho-manufatura-an-lise-de-dados-no-brasil

df["edition"].value_counts().plot.bar(color=['blue', '#f5005a', 'chartreuse', 'Lightcoral', 'DarkOrchid'], title='Freedom Editions',);

# %%
#Code by Lucas Abrahão https://www.kaggle.com/lucasabrahao/trabalho-manufatura-an-lise-de-dados-no-brasil

df["PR_rating"].value_counts().plot.barh(color=['DarkOrange', '#f5005a', 'chartreuse', 'LightCoral', 'DarkOrchid', 'DodgerBlue', 'DarkRed'], title='Political Rights Rating',);

# %%
#Code by Lucas Abrahão https://www.kaggle.com/lucasabrahao/trabalho-manufatura-an-lise-de-dados-no-brasil

df["CL_rating"].value_counts().plot.barh(color=['blue', '#f5005a', 'chartreuse', 'LightCoral', 'DarkOrchid', 'DodgerBlue', 'DeepPink'], title='Civil  Rights Rating',);

# %%
#Code by Lucas Abrahão https://www.kaggle.com/lucasabrahao/trabalho-manufatura-an-lise-de-dados-no-brasil

df["Add_Q"].value_counts().plot.barh(color=['blue', '#f5005a', 'chartreuse', 'DarkOrchid', 'ForestGreen'], title='Additional Discretionary Question',);

# %%
fig = px.pie(df, values='edition', names='status', title= 'Country Freedom Status')
fig.show()

# %% [markdown]
# #Brazil Status: Free

# %%
bra = df[(df['country_territory']=='Brazil')].reset_index(drop=True)
bra.head()

# %%
fig = px.bar(bra, 
             x='edition', y='CL_rating', color_discrete_sequence=['#DC143C'],
             title='Brazil Civil Liberties Rating', text='status')
fig.show()

# %% [markdown]
# #What about Belarus?

# %%
bel = df[(df['country_territory']=='Belarus')].reset_index(drop=True)
bel.head()

# %%
fig = px.bar(bel, 
             x='edition', y='PR_rating', color_discrete_sequence=['#2B3A67'],
             title='Belarus Political Rights Rating', text='status')
fig.show()

# %%
fig = px.bar(bel, 
             x='edition', y='CL_rating', color_discrete_sequence=['Cyan'],
             title='Belarus Civil Liberties Rating', text='status')
fig.show()

# %%
hun = df[(df['country_territory']=='Hungary')].reset_index(drop=True)
hun.head()

# %% [markdown]
# #Hungary Status: Free till 2018. Since 2019 charts show that's Partly Free.

# %%
fig = px.bar(hun, 
             x='edition', y='PR_rating', color_discrete_sequence=['#8A2BE2'],
             title='Hungary Political Rights Rating', text='status')
fig.show()

# %%
fig = px.bar(hun, 
             x='edition', y='CL_rating', color_discrete_sequence=['#FF7F50'],
             title='Hungary Civil Liberties Rating', text='status')
fig.show()

# %% [markdown]
# #Sri Lanka Status

# %%
sri = df[(df['country_territory']=='Sri Lanka')].reset_index(drop=True)
sri.head()

# %%
fig = px.bar(sri, 
             x='edition', y='PR_rating', color_discrete_sequence=['#F08080'],
             title='Sri Lanka Political Rights Rating', text='status')
fig.show()

# %%
fig = px.bar(sri, 
             x='edition', y='CL_rating', color_discrete_sequence=['#20B2AA'],
             title='Sri Lanka Civil Liberties Rating', text='status')
fig.show()

# %% [markdown]
# #Turkey Status

# %%
tur = df[(df['country_territory']=='Turkey')].reset_index(drop=True)
tur.head()

# %%
fig = px.bar(tur, 
             x='edition', y='PR_rating', color_discrete_sequence=['crimson'],
             title='Turkey Political Rights Rating', text='status')
fig.show()

# %%
fig = px.bar(tur, 
             x='edition', y='CL_rating', color_discrete_sequence=['#D3D3D3'],
             title='Turkey Civil Liberties Rating', text='status')
fig.show()

# %% [markdown]
# #Sweden Status

# %%
swe = df[(df['country_territory']=='Sweden')].reset_index(drop=True)
swe.head()

# %%
fig = px.bar(swe, 
             x='edition', y='PR_rating', color_discrete_sequence=['#7CFC00'],
             title='Sweden Political Rights Rating', text='status')
fig.show()

# %%
fig = px.bar(swe, 
             x='edition', y='CL_rating', color_discrete_sequence=['#FFD700'],
             title='Sweden Civil Liberties Rating', text='status')
fig.show()

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQE03ar2gII5z8B6Op4qtlfdPlv9yVXpZ4QuKm6C8EXXbMTAti6QBosYcaT4NzY2XMeG80&usqp=CAU)statusmind.com
