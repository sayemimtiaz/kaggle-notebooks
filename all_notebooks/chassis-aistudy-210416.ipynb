# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt

# %%
model = VGG16(weights='imagenet')

# %%
image = load_img('../input/aistudy-210416/Wheel2.jpg', target_size=(224,224) )
image

# %%
xhat = preprocess_input(xhat)
xhat = xhat.reshape((1, xhat.shape[0], xhat.shape[1], xhat.shape[2]))
yhat = model.predict(xhat)

# %%
label = decode_predictions(yhat)
label1 = label[0][0]
label2 = label[0][1]
#print('%s(%.2f%%)'% (label[1], label[2]*100))

print(  f'{label1[1]}({label1[2]*100:.2f}%)' )
print(  f'{label2[1]}({label2[2]*100:.2f}%)' )

plt.imshow(image)

# %%
#image = load_img('../input/aistudy-210416/Maltese.jpg', target_size=(224,224) )
#image = load_img('../input/aistudy-210416/Bulldog.jpg', target_size=(224,224) )
#image = load_img('../input/aistudy-210416/Malamute.jpg', target_size=(224,224) )
#image = load_img('../input/aistudy-210416/Wheel.jpg', target_size=(224,224) )
image = load_img('../input/aistudy-210416/Wheel2.jpg', target_size=(224,224) )
#image = load_img('../input/aistudy-210416/Trod_end.jpg', target_size=(224,224) )
