# %% [markdown]
# # Heart Failure Project
# ### Xinzhe Qi, Jason Chen, Orianne Luo

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
heart = pd.read_csv("../input/heart-failure/heart_failure.csv")
heart.shape

# %%
heart.head()

# %%
heart.info()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(heart.corr(),annot=True)

# %%
sns.countplot(x='anaemia', hue='DEATH_EVENT', data=heart)

# %%
sns.countplot(x='diabetes', hue='DEATH_EVENT', data=heart)

# %%
sns.countplot(x='high_blood_pressure', hue='DEATH_EVENT', data=heart)

# %%
sns.countplot(x='smoking', hue='DEATH_EVENT', data=heart)

# %%
from statsmodels.graphics.mosaicplot import mosaic
mosaic(heart, ['smoking', 'high_blood_pressure'])
