# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
dataFrame = pd.read_csv('../input/netflix-shows/netflix_titles.csv')
print(dataFrame.describe())

# %%
dataFrame.head()

# %%
dataFrame.columns

# %%
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#       'release_year', 'rating', 'duration', 'listed_in', 'description'],
#      dtype='object')
# date_added  == release_yer ??
# type = movie ? tv_Show

# %%
type(dataFrame.release_year.unique())

# %%
show_id_size = len(dataFrame.show_id.unique())
year_size = len(dataFrame.release_year.unique())
director_size = len(dataFrame.director.unique())

print('Show size : ', show_id_size)
print('Director size : ', director_size)

# %%
dataFrameTV = dataFrame[(dataFrame['type'] == 'TV Show')]
dataFrameMV = dataFrame[(dataFrame['type'] == 'Movie')]

# %%
#dataFrameTV #dataFrameMV
dataFrameTVTr = dataFrameTV[(dataFrame['country'] == 'Turkey')]
Tr_year = dataFrameTVTr.release_year.unique()
plt.bar(Tr_year, )

# %%
# for i in dataFrameTVTr:
#     print(i)
# for index,value in dataFrameTVTr[['title']].iterrows():
#     print(index, ' : ', value)
    
uniqDuration = dataFrameTVTr.duration.unique()

    
# dataFrameTVTr.cast
dataFrameTVTr.duration.unique()

# %%
dataFrameTVTr_1 = dataFrameTVTr[dataFrame['duration'] == '1 Season']
int1 = dataFrameTVTr_1.count()
dataFrameTVTr_2 = dataFrameTVTr[dataFrame['duration'] == '2 Seasons']
int2 = dataFrameTVTr_2.count()
dataFrameTVTr_3 = dataFrameTVTr[dataFrame['duration'] == '3 Seasons']
int3 = dataFrameTVTr_3.count()
dataFrameTVTr_4 = dataFrameTVTr[dataFrame['duration'] == '4 Seasons']
int4 = dataFrameTVTr_4.count()
dataFrameTVTr_5 = dataFrameTVTr[dataFrame['duration'] == '5 Seasons']
int5 = dataFrameTVTr_5.count()
print("1 sezon : ", int1.show_id)
print("2 sezon : ", int2.show_id)
print("3 sezon : ", int3.show_id)
print("4 sezon : ", int4.show_id)
print("5 sezon : ", int5.show_id)

# %%
forBar = [int1.show_id, int2.show_id, int3.show_id, int5.show_id, int4.show_id]
plt.bar(dataFrameTVTr.duration.unique(), forBar)
plt.show()

# %%
plt.hist(dataFrameTVTr.release_year, bins=50)
plt.xlabel('Years')
plt.show()

# %%
dataFrameTVTr.head()

# %%
str2 = 'July 1, 2017'
a = str2.split(',')
a = int(a[1])
#print(a)

dataFrameTVTr['adding'] = [True if int(each['date_added'].split(',')[1])==int(each['release_year']) else False for index, each in dataFrameTVTr.iterrows() ]
print(len(dataFrameTVTr[dataFrameTVTr['adding'] == True]))
print(len(dataFrameTVTr[dataFrameTVTr['adding'] == False]))
# for index, value in dataFrameTVTr.iterrows():
#     print(value['date_added'])
#     print(value['release_year'])

# %%
for index, value in dataFrameTVTr.iterrows():
    result = [x.strip() for x in value['cast'].split(',')]
#     print(result)
    if any("Serkan Keskin" in s for s in result):
        #print(result)
        ddf =  dataFrameTVTr[dataFrameTVTr.index == index]
        print('title : ',ddf['title'])
       
#         print('Cast  : ', result)
    # result = [x.strip() for x in my_string.split(',')]
#dataFrameTVTr[dataFrameTVTr['cast']]

# %%
dataFrameTVTr.head()
