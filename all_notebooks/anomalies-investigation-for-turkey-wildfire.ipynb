# %% [markdown]
# # HISTORY
#
# #### INVESTIGATIVE WILDFIRE DATA FOR TURKEY/ NASA
#
# * BE CAREFUL OF THE FILE NAMES.
#
# * IT CONTAINS THE DATA NEEDED TO RESEARCH LATEST FOREST FIRES IN TURKEY.
#
# * PAY ATTENTION TO THE DATE INTERVALS.
#
# * THESE ARE 7-11 DAILY DATA OF LAST TIMES.
#
# fire _ nrt _ M _ C61 _ 212465 _ all _ countries.csv
#
# * This file is important for all countries becuase it contains fire data of last 11 days for all around the world
#
# #### Content
#
# * Data on recent forest fires in Turkey, published with permission from NASA Portal.
# * The data was created based on the hotspots and obtained from the satellite.
#
# #### 3 SEPARATE SATELLITE DATA:
#
# * MODIS C6.1
# * SUOMI VIIRS C2
# * J1 VIIRS C1
#
# #### GENERAL ATTRIBUTES
#
# * Latitude
#
# Center of nominal 375 m fire pixel
#
# * Longitude
#
# Center of nominal 375 m fire pixel
#
# * Bright_ti4
#
# (Brightness temperature I-4)
#
# VIIRS I-4: channel brightness temperature of the fire pixel measured in Kelvin.
#
# * Scan
#
# (Along Scan pixel size)
#
# The algorithm produces approximately 375 m pixels at nadir. Scan and track reflect actual pixel size.
#
# * Track
#
# (Along Track pixel size)
#
# The algorithm produces approximately 375 m pixels at nadir. Scan and track reflect actual pixel size.
#
# * Acq_Date
#
# (Acquisition Date)
#
# Date of VIIRS acquisition.
#
# * Acq_Time
#
# (Acquisition Time)
#
# Time of acquisition/overpass of the satellite (in UTC).
#
# * Satellite
#
# N Suomi National Polar-orbiting Partnership (Suomi NPP)
#
# * Confidence
#
# This value is based on a collection of intermediate algorithm quantities used in the detection process. It is intended to help users gauge the quality of individual hotspot/fire pixels. Confidence values are set to low, nominal and high. Low confidence daytime fire pixels are typically associated with areas of sun glint and lower relative temperature anomaly (15K) temperature anomaly in either day or nighttime data. High confidence fire pixels are associated with day or nighttime saturated pixels.
#
# #### Please note:
#
# Low confidence nighttime pixels occur only over the geographic area extending from 11° E to 110° W and 7° N to 55° S. This area describes the region of influence of the South Atlantic Magnetic Anomaly which can cause spurious brightness temperatures in the mid-infrared channel I4 leading to potential false positive alarms. These have been removed from the NRT data distributed by FIRMS.
#
# * Version
#
# Version identifies the collection (e.g. VIIRS Collection 1) and source of data processing: Near Real-Time (NRT suffix added to collection) or Standard Processing (collection only).
#
# "1.0NRT" - Collection 1 NRT processing.
#
# "1.0" - Collection 1 Standard processing.
#
# * Bright_ti5
#
# (Brightness temperature I-5)
#
# I-5 Channel brightness temperature of the fire pixel measured in Kelvin.
#
# * FRP
#
# (Fire Radiative Power)
#
# FRP depicts the pixel-integrated fire radiative power in MW (megawatts). Given the unique spatial and spectral resolution of the data, the VIIRS 375 m fire detection algorithm was customized and tuned in order to optimize its response over small fires while balancing the occurrence of false alarms. Frequent saturation of the mid-infrared I4 channel (3.55-3.93 µm) driving the detection of active fires requires additional tests and procedures to avoid pixel classification errors. As a result, sub-pixel fire characterization (e.g., fire radiative power [FRP] retrieval) is only viable across small and/or low-intensity fires. Systematic FRP retrievals are based on a hybrid approach combining 375 and 750 m data. In fact, starting in 2015 the algorithm incorporated additional VIIRS channel M13 (3.973-4.128 µm) 750 m data in both aggregated and unaggregated format.
#
#
# Satellite measurements of fire radiative power (FRP) are increasingly used to estimate the contribution of biomass burning to local and global carbon budgets. Without an associated uncertainty, however, FRP-based biomass burning estimates cannot be confidently compared across space and time, or against estimates derived from alternative methodologies. Differences in the per-pixel FRP measured near-simultaneously in consecutive MODIS scans are approximately normally distributed with a standard deviation (ση) of 26.6%. Simulations demonstrate that this uncertainty decreases to less than ~5% (at ±1 ση) for aggregations larger than ~50 MODIS active fire pixels. Although FRP uncertainties limit the confidence in flux estimates on a per-pixel basis, the sensitivity of biomass burning estimates to FRP uncertainties can be mitigated by conducting inventories at coarser spatiotemporal resolutions.
#
# http://cedadocs.ceda.ac.uk/770/1/SEVIRI_FRP_documentdesc.pdf
#
# * Type
#
# (Inferred hot spot type)
#
# 0 = presumed vegetation fire
#
# 1 = active volcano
#
# 2 = other static land source
#
# 3 = offshore detection (includes all detections over water)
#
# * DayNight
#
# (Day or Night)
#
# D= Daytime fire
#
# N= Nighttime fire

# %% [markdown]
# #### WHAT IS LONGITUDE AND LATITUDE
#
# * Latitude and longitude are a system of lines used to describe the location of any place on Earth. Lines of latitude run in an east-west direction across Earth. Lines of longitude run in a north-south direction. Although these are only imaginary lines, they appear on maps and globes as if they actually existed.
#
# #### ACQUISITION TIME EXAMPLE
#
# Based on UTC time. You have to think in decimal.
#
# GOING FROM AM TO PM
#
# FOR EXAMPLE
#
# * 911 = 9.11
# * 1032 = 10.32
# * 0034 = 00.34

# %% [markdown]
# # AREA OF INTEREST
#
# * 40.25528   38.01956,
#
# * 38.89297   38.50296,
#
# * 36.82755   38.54691,
#
# * 35.06973   38.41507,
#
# * 33.75137   37.75589,
#
# * 32.91641   37.22855,
#
# * 30.85098   37.668,
#
# * 29.66446   38.01956,
#
# * 28.08243   37.93167,
#
# * 27.11563   37.84378,
#
# * 25.79727   37.668,
#
# * 25.09415   38.23929,
#
# * 24.1713   38.98636,
#
# * 22.32559   38.85452,
#
# * 19.82071   38.37112,
#
# * 18.41446   37.88773,
#
# * 16.65665   38.23929,
#
# * 14.98672   38.6348,
#
# * 13.14102   38.72269,
#
# * 10.76797   38.32718,
#
# * 8.83438   37.88773,
#
# * 8.30704   36.92093,
#
# * 8.13126   35.77835,
#
# * 8.61465   35.07523,
#
# * 8.6586   33.49319,
#
# * 9.18594   32.61429,
#
# * 10.89981   31.95511,
#
# * 12.8334   31.60355,
#
# * 14.15176   30.98831,
#
# * 15.86563   30.54886,
#
# * 17.75528   29.93362,
#
# * 18.76602   29.49417,
#
# * 20.30411   29.66995,
#
# * 21.18301   30.32913,
#
# * 21.7543   30.98831,
#
# * 23.11661   31.25198,
#
# * 24.34708   31.12015,
#
# * 25.0502   31.60355,
#
# * 27.07169   30.68069,
#
# * 28.47794   30.02151,
#
# * 30.54337   29.84573,
#
# * 32.78458   29.14261,
#
# * 34.89395   29.7139,
#
# * 35.64102   30.94437,
#
# * 35.11368   32.30667,
#
# * 35.59708   33.36136,
#
# * 35.77286   34.32816,
#
# * 36.25626   35.42679,
#
# * 37.57462   35.73441,
#
# * 38.89297   35.60257,
#
# * 40.69473   35.38284,
#
# * 41.39786   36.61331,
#
# * 41.79337   37.36038,
#
# * 40.25528   38.01956

# %% [markdown]
# # PACKAGES AND LIBRARIES

# %%
# !pip install dataprep by

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from warnings import filterwarnings
from mpl_toolkits.mplot3d import Axes3D
import statsmodels.api as sm
import missingno as msno
import statsmodels.stats.api as sms
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.neighbors import LocalOutlierFactor
from scipy.stats import levene
from scipy.stats import shapiro
from scipy.stats.stats import pearsonr
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from sklearn.preprocessing import scale
from sklearn.model_selection import ShuffleSplit, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import model_selection
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import BaggingRegressor
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LinearRegression
from sklearn.cross_decomposition import PLSRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import LassoCV
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import ElasticNetCV
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
import xgboost as xgb
from xgboost import XGBRegressor, XGBClassifier
from lightgbm import LGBMRegressor, LGBMClassifier
from catboost import CatBoostRegressor, CatBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn import tree
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, roc_auc_score, roc_curve
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans
from sklearn.pipeline import Pipeline
from sklearn.manifold import Isomap,TSNE
from sklearn.feature_selection import mutual_info_classif
from tqdm.notebook import tqdm
from scipy.stats import ttest_ind
import plotly.offline as pyo
import scipy.stats as stats
import pymc3 as pm
from dataprep.eda import *
from dataprep.eda import plot
from dataprep.eda import plot_diff
from dataprep.eda import plot_correlation
from dataprep.eda import plot_missing
import plotly.figure_factory as ff
from collections import Counter
import pandas_profiling as pp
from mpl_toolkits.basemap import Basemap
import datetime as dt
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import folium
from folium import plugins

filterwarnings("ignore", category=DeprecationWarning) 
filterwarnings("ignore", category=FutureWarning) 
filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# # INVESTIGATION FOR SPECIFIC AREA

# %% [markdown]
# ### DATA READING & CONTROL

# %%
SV_C2_READING = pd.read_csv("../input/investigative-wildfire-data-for-turkey-nasa/INVESTIGATIVE WILDFIRE DATA FOR TURKEY_NASA/SPECIFIC COORDINATES/fire_nrt_SV-C2_212464.csv")

Data = SV_C2_READING.copy()

# %%
SV_C2_READING

# %%
Data.drop(["satellite","instrument","version"],inplace=True,axis=1)

Data["confidence"].replace({"n":"nominal","l":"low","h":"high"},inplace=True)
Data["daynight"].replace({"N":"Nighttime","D":"Daytime "},inplace=True)

# %%
Data

# %%
SORTED_DATA = Data.copy()

SORTED_DATA.sort_values(by=["acq_date"],ascending=False,inplace=True)
SORTED_DATA = SORTED_DATA.reset_index(drop=True)

SORTED_DATA

# %% [markdown]
# #### **ATTENTION**
#
# * PLEASE CHECK OUR WORK ON THIS LINK FOR DATA INFORMATION AND REVIEW.
# * THE VALUES ARE RELIABLE, BECAUSE THE SOURCE WE GET THE DATA IS THE SAME.
#
#
# * https://www.kaggle.com/brsdincer/turkey-recent-wildfire-analysis-investigation

# %%
print("DESCRIBE:\n")
print(Data.describe().T)

# %% [markdown]
# * DATA IS AT THE LAST 11 DAYS.

# %% [markdown]
# * THE BRIGHTNESS VALUE GIVES US THE STRENGTH OF THE POINTS MARKED AS THE HOTSPOT.
# * IF VALUE IS HIGH, FIRE IS STRONG.

# %% [markdown]
# #### **ATTENTION**
# * 11 DAYS AVERAGE BRIGHTNESS: 335
# * THE VALUES IN THE MOST OF THE DATA ARE MORE THAN AVERAGE. THIS SITUATION INDICATES THAT HIGHLY STRONG POINTS HAVE BEEN RECORDED IN THE LAST 11 DAYS DATA.

# %%
print("BASIC CORRELATION:\n")
print(Data.corr())

# %%
print("BASIC COVARIANCE:\n")
print(Data.cov())

# %%
print("NAN VALUES:\n")
print(Data.isna().sum())

# %% [markdown]
# ### VALUE CONTROL

# %%
print("VALUES:\n")
print(Data["acq_date"].value_counts())

# %% [markdown]
# #### **ATTENTION**
# * MOSTLY HOTSPOT DATA WAS RECORDED AFTER JULY 28 IN THE SPECIAL LOCATION WE ARE ANALYZING.
# * THIS IS THE FIRST START TIME OF FIRES IN TURKEY.
# * AFTER JULY 28, THE DIFFERENCE BETWEEN OTHER DAYS HAS INCREASED QUICKLY.

# %%
print("VALUES:\n")
print(Data["acq_time"].value_counts())

# %% [markdown]
# #### **ATTENTION**
# * UTC TIME IS 3 HOURS BACK TO TURKEY TIME.
# * HOTSPOT DATA WAS RECORDED AT 20:00 AT THE MOST.

# %%
print("VALUES:\n")
print(Data["daynight"].value_counts())

# %% [markdown]
# #### **ATTENTION**
# * HOTSPOT DATA WAS RECORDED AT NIGHT TIME RANGE AT THE MOST.

# %% [markdown]
# ### GROUPBY MEANING

# %%
print("INFO:\n")
print(Data.info())

# %%
print("MAXIMUM COUNT DATE:\n")
print(Data["acq_date"].max())

# %%
print("MAXIMUM FRP:\n")
print(Data["frp"].max())

# %%
print("MAXIMUM BRIGHTNESS:\n")
print(Data["brightness"].max())

# %%
print("DATE-BRIGHTNESS MAX\n")
print(Data.groupby(["acq_date"])["brightness"].max())
print("\n")
print("CONFIDENCE-FRP MIN\n")
print(Data.groupby(["acq_date"])["brightness"].min())

# %% [markdown]
# #### **ATTENTION**
# * THE HIGHEST BRIGHTNESS VALUE WAS DETECTED IN ALL 11 DAYS.

# %%
print("DATE-FRP MAX\n")
print(Data.groupby(["acq_date"])["frp"].max())
print("\n")
print("DATE-FRP MIN\n")
print(Data.groupby(["acq_date"])["frp"].min())

# %% [markdown]
# #### **ATTENTION**
# * THE HIGHEST FRP VALUES WERE DETECTED IN JULY 28,29.
# * THIS IS THE FIRST 2 DAYS OF START OF WILDFIRE IN TURKEY.

# %%
print(Data[Data["frp"] == Data["frp"].max()])

# %% [markdown]
# #### **ATTENTION**
# * THE HIGHEST FRP VALUE LATITUDE: 36.95595
# * THE HIGHEST FRP VALUE LONGITUDE: 31.4881
# * THE HIGHEST FRP VALUE DATE: 2021-07-29
# * THE HIGHEST FRP VALUE TIME: 20.03 FOR TURKEY

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='openstreetmap',
                  zoom_start=6.4)

folium.CircleMarker(
    location=[36.95595,31.4881],
    radius=20,
    popup="<b>MAXIMUM FRP (FOR ALL 11 DAYS)<b>",
    tooltip="Click me",
    color='#2F4F4F',
    fill=True,
    fill_color='#00000',
).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### **ATTENTION**
# * HERE IS ANTALYA - MANAVGAT
# * THE STRONGEST FRP WAS SEEN IN ANTALYA IN THE LAST 11 DAYS.

# %% [markdown]
# ### MAXIMUM BRIGHTNESS DATA

# %%
MAX_BRIGHTNESS_DATA = Data[Data["brightness"] == Data["brightness"].max()]

MAX_BRIGHTNESS_DATA = MAX_BRIGHTNESS_DATA.reset_index(drop=True)

MAX_BRIGHTNESS_DATA

# %%
LAT_LONG_MAX_BRIGHTNESS = MAX_BRIGHTNESS_DATA[["latitude","longitude"]]

LAT_LONG_MAX_BRIGHTNESS.latitude = LAT_LONG_MAX_BRIGHTNESS.latitude.astype(float)
LAT_LONG_MAX_BRIGHTNESS.longitude = LAT_LONG_MAX_BRIGHTNESS.longitude.astype(float)

HEAT_MAX_BRIGHTNESS = list(zip(LAT_LONG_MAX_BRIGHTNESS.latitude,LAT_LONG_MAX_BRIGHTNESS.longitude))

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,30.2433],
                  tiles='Stamen Terrain',
                  zoom_start=4.5)

plugins.MarkerCluster(LAT_LONG_MAX_BRIGHTNESS).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### **ATTENTION**
# * THE STRONGEST BRIGHTNESS VALUES WERE SEEN IN TURKEY (MEDITERRANEAN FIELD) IN THE LAST 11 DAYS.
# * THIS MAY BE AN INDICATOR THAT THERE WAS NO ANOMALY IN THIS REGION.
#
# #### **ATTENTION**
#
# * ANTALYA HAS MORE HOTSPOT RECORDED THAN OTHER POINTS.
# * ADANA AND MERSİN HAVE ALMOST SAME NUMBER WITH THE ISLAND OF ITALY.
#
# #### **ATTENTION**
# * USE THE INTERACTIVE MAP. CLOSE TO THE REGIONS.
# * THE HIGHEST NUMBER CAN SHOW WHERE THE FIRE STARTED FIRST IN THAT AREA.

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,30.2433],
                  tiles='Stamen Terrain',
                  zoom_start=4.2)

plugins.HeatMap(HEAT_MAX_BRIGHTNESS).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %%
print(MAX_BRIGHTNESS_DATA[MAX_BRIGHTNESS_DATA["bright_t31"] == MAX_BRIGHTNESS_DATA["bright_t31"].max()])

# %% [markdown]
# #### ATTENTION
# * THE POINT WITH THE BRIGHT T31 (STRONGEST FIRE SIGNAL) AT THE HIGHEST VALUES LATITUDE: 36.82831
# * THE POINT WITH THE BRIGHT T31 (STRONGEST FIRE SIGNAL) AT THE HIGHEST VALUES LONGITUDE: 28.23372
# * THE POINT WITH THE BRIGHT T31 (STRONGEST FIRE SIGNAL) AT THE HIGHEST VALUES DATE: 2021-07-29
# * THE POINT WITH THE BRIGHT T31 (STRONGEST FIRE SIGNAL) AT THE HIGHEST VALUES TIME: 07.43 FOR TURKEY

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='openstreetmap',
                  zoom_start=6.4)

folium.CircleMarker(
    location=[36.82831,28.23372],
    radius=20,
    popup="<b>STRONGEST FIRE SIGNAL (FOR ALL 11 DAYS)<b>",
    tooltip="Click me",
    color='#2F4F4F',
    fill=True,
    fill_color='#00000',
).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### ATTENTION
# * HERE IS MUGLA

# %%
print(MAX_BRIGHTNESS_DATA[MAX_BRIGHTNESS_DATA["frp"] == MAX_BRIGHTNESS_DATA["frp"].max()])

# %% [markdown]
# #### **ATTENTION**
# * THE POINT WITH FRP LATITUDE: 36.95595
# * THE POINT WITH FRP LONGITUDE: 31.4881
# * THE POINT WITH FRP DATE: 2021-07-29
# * THE POINT WITH FRP TIME: 20.03 FOR TURKEY

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='openstreetmap',
                  zoom_start=6.4)

folium.CircleMarker(
    location=[36.95595,31.4881],
    radius=20,
    popup="<b>STRONGEST FRP (FOR ALL 11 DAYS)<b>",
    tooltip="Click me",
    color='#2F4F4F',
    fill=True,
    fill_color='#00000',
).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### **ATTENTION**
# * HERE IS ANTALYA

# %% [markdown]
# ### DATE BASED ANALYSIS

# %%
JULY_28 = Data[Data["acq_date"] == "2021-07-28"]
JULY_29 = Data[Data["acq_date"] == "2021-07-29"]
JULY_30 = Data[Data["acq_date"] == "2021-07-30"]

JULY_28 = JULY_28.reset_index(drop=True)
JULY_29 = JULY_29.reset_index(drop=True)
JULY_30 = JULY_30.reset_index(drop=True)

# %%
LAT_LONG_28 = JULY_28[["latitude","longitude"]]
LAT_LONG_29 = JULY_29[["latitude","longitude"]]
LAT_LONG_30 = JULY_30[["latitude","longitude"]]

# %%
LAT_LONG_28.latitude = LAT_LONG_28.latitude.astype(float)
LAT_LONG_28.longitude = LAT_LONG_28.longitude.astype(float)

LAT_LONG_29.latitude = LAT_LONG_29.latitude.astype(float)
LAT_LONG_29.longitude = LAT_LONG_29.longitude.astype(float)

LAT_LONG_30.latitude = LAT_LONG_30.latitude.astype(float)
LAT_LONG_30.longitude = LAT_LONG_30.longitude.astype(float)

HEAT_J_28 = list(zip(LAT_LONG_28.latitude,LAT_LONG_28.longitude))
HEAT_J_29 = list(zip(LAT_LONG_29.latitude,LAT_LONG_29.longitude))
HEAT_J_30 = list(zip(LAT_LONG_30.latitude,LAT_LONG_30.longitude))

# %% [markdown]
# #### JULY 28

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,30.2433],
                  tiles='Stamen Terrain',
                  zoom_start=3.5)

plugins.MarkerCluster(LAT_LONG_28).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### **ATTENTION**
# * SHARP INCREASES ARE OBSERVED ONLY IN TURKEY

# %% [markdown]
# #### JULY 29

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,30.2433],
                  tiles='Stamen Terrain',
                  zoom_start=3.5)

plugins.MarkerCluster(LAT_LONG_29).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### **ATTENTION**
# * SHARP INCREASES ARE OBSERVED ONLY IN TURKEY

# %% [markdown]
# #### JULY 30

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,30.2433],
                  tiles='Stamen Terrain',
                  zoom_start=3.5)

plugins.MarkerCluster(LAT_LONG_30).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### **ATTENTION**
# * SHARP INCREASES ARE OBSERVED ONLY IN TURKEY

# %% [markdown]
# # INVESTIGATION FOR ALL COUNTRIES

# %% [markdown]
# ### READING

# %%
Fire_NRT_READING = pd.read_csv("../input/investigative-wildfire-data-for-turkey-nasa/INVESTIGATIVE WILDFIRE DATA FOR TURKEY_NASA/LAST YEARS ALL COUNTRIES/fire_nrt_M_C61_212465_all_countries.csv")

Data_GLOBAL = Fire_NRT_READING.copy()

# %%
Fire_NRT_READING

# %% [markdown]
# ### ANALYSIS

# %%
TERRA_DATA = Data_GLOBAL[Data_GLOBAL["satellite"] == "Terra"]

TERRA_DATA = TERRA_DATA.reset_index(drop=True)

TERRA_DATA

# %%
AQUA_DATA = Data_GLOBAL[Data_GLOBAL["satellite"] == "Aqua"]

AQUA_DATA = AQUA_DATA.reset_index(drop=True)

AQUA_DATA

# %%
SORTED_DATA = Data_GLOBAL.copy()

SORTED_DATA.sort_values(by=["acq_date"],ascending=False,inplace=True)
SORTED_DATA = SORTED_DATA.reset_index(drop=True)

SORTED_DATA

# %%
print(Data_GLOBAL["acq_date"].max())

# %% [markdown]
# #### **ATTENTION**
# * DATA WAS RECORDED ON AUGUST 1 AT THE MOST AS HISTORICAL RECORD.

# %%
print(Data_GLOBAL[Data_GLOBAL["frp"] == Data_GLOBAL["frp"].max()])

# %% [markdown]
# #### **ATTENTION**
# * THE POINT WITH FRP LATITUDE: 40.024
# * THE POINT WITH FRP LONGITUDE: -120.914
# * THE POINT WITH FRP DATE: 2021-07-23
# * THE POINT WITH FRP TIME: 18.55 FOR TURKEY

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,10.2433],
                  tiles='openstreetmap',
                  zoom_start=2.4)

folium.CircleMarker(
    location=[40.024,-120.914],
    radius=20,
    popup="<b>STRONGEST FRP (FOR ALL 11 DAYS)<b>",
    tooltip="Click me",
    color='#2F4F4F',
    fill=True,
    fill_color='#00000',
).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### **ATTENTION**
#
# * HERE IS CHICO
# * THE HIGHEST VALUE IN THE WORLD WAS IN THE AMERICA
# * THIS SITUATION MAY PROVE THAT THERE IS NO ANOMALY IN THE MEDITERRANEAN LOCAL

# %%
print(Data_GLOBAL[Data_GLOBAL["brightness"] == Data_GLOBAL["brightness"].max()])

# %% [markdown]
# #### **ATTENTION**
# * THE FIRST POINT WITH BRIGHTNESS LATITUDE: 40.042
# * THE FIRST POINT WITH BRIGHTNESS LONGITUDE: -121.383
# * THE FIRST POINT WITH BRIGHTNESS DATE: 2021-07-20
# * THE FIRST POINT WITH BRIGHTNESS TIME: 18.25 FOR TURKEY
#
#
#
# * THE SECOND POINT WITH BRIGHTNESS LATITUDE: 40.044
# * THE SECOND POINT WITH BRIGHTNESS LONGITUDE: -121.369
# * THE SECOND POINT WITH BRIGHTNESS DATE: 2021-07-20
# * THE SECOND POINT WITH BRIGHTNESS TIME: 18.25 FOR TURKEY

# %%
MAP_FUNCTION = folium.Map(location=[40.024,-120.914],
                  tiles='openstreetmap',
                  zoom_start=10.4)

folium.CircleMarker(
    location=[40.042,-121.383],
    radius=20,
    popup="<b>STRONGEST FIRST FIRE SIGNAL (FOR ALL 11 DAYS)<b>",
    tooltip="Click me",
    color='#2F4F4F',
    fill=True,
    fill_color='#00000',
).add_to(MAP_FUNCTION)

folium.CircleMarker(
    location=[40.044,-121.369],
    radius=20,
    popup="<b>STRONGEST SECOND FIRE SIGNAL (FOR ALL 11 DAYS)<b>",
    tooltip="Click me",
    color='#2F4F4F',
    fill=True,
    fill_color='#FF0000',
).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### **ATTENTION**
# * HERE IS CHICO
# * THE HIGHEST VALUE IN THE WORLD WAS IN THE AMERICA
# * THIS SITUATION MAY PROVE THAT THERE IS NO ANOMALY IN THE MEDITERRANEAN LOCAL

# %%
BRIGHTNESS_MAX_GLOBAL = Data_GLOBAL[Data_GLOBAL["bright_t31"] == Data_GLOBAL["bright_t31"].max()]

BRIGHTNESS_MAX_GLOBAL = BRIGHTNESS_MAX_GLOBAL.reset_index(drop=True)

BRIGHTNESS_MAX_GLOBAL

# %%
LAT_LONG_MAX_GLOB_BRIGHTNESS = BRIGHTNESS_MAX_GLOBAL[["latitude","longitude"]]

LAT_LONG_MAX_GLOB_BRIGHTNESS.latitude = LAT_LONG_MAX_GLOB_BRIGHTNESS.latitude.astype(float)
LAT_LONG_MAX_GLOB_BRIGHTNESS.longitude = LAT_LONG_MAX_GLOB_BRIGHTNESS.longitude.astype(float)

HEAT_MAX_GLOB_BRIGHTNESS = list(zip(LAT_LONG_MAX_GLOB_BRIGHTNESS.latitude,LAT_LONG_MAX_GLOB_BRIGHTNESS.longitude))

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,20.2433],
                  tiles='Stamen Terrain',
                  zoom_start=1.5)

plugins.MarkerCluster(LAT_LONG_MAX_GLOB_BRIGHTNESS).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### **ATTENTION**
# * NONE OF THE HIGHEST VALUES HOTSPOTS ARE IN TURKEY.
# * THE HIGHEST VALUE IN THE WORLD WAS IN THE AMERICA.
# * THIS SITUATION MAY PROVE THAT THERE IS NO ANOMALY IN THE MEDITERRANEAN LOCAL

# %%
print(TERRA_DATA[TERRA_DATA["frp"] == TERRA_DATA["frp"].max()])

# %% [markdown]
# #### **ATTENTION**
# * THE POINT WITH FRP LATITUDE: 40.057
# * THE POINT WITH FRP LONGITUDE: -121.374
# * THE POINT WITH FRP DATE: 2021-07-20
# * THE POINT WITH FRP TIME: 16.40 FOR TURKEY

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,10.2433],
                  tiles='openstreetmap',
                  zoom_start=2.4)

folium.CircleMarker(
    location=[40.057,-121.374],
    radius=20,
    popup="<b>STRONGEST FRP (FOR ALL 11 DAYS)<b>",
    tooltip="Click me",
    color='#2F4F4F',
    fill=True,
    fill_color='#00000',
).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### **ATTENTION**
#
# * HERE IS CHICO
# * THE HIGHEST VALUE IN THE WORLD WAS IN THE AMERICA
# * THIS SITUATION MAY PROVE THAT THERE IS NO ANOMALY IN THE MEDITERRANEAN LOCAL

# %%
print(AQUA_DATA[AQUA_DATA["brightness"] == AQUA_DATA["brightness"].max()])

# %% [markdown]
# #### **ATTENTION**
#
# * THE FIRST POINT WITH BRIGHTNESS LATITUDE: 40.042
# * THE FIRST POINT WITH BRIGHTNESS LONGITUDE: -121.383
# * THE FIRST POINT WITH BRIGHTNESS DATE: 2021-07-20
# * THE FIRST POINT WITH BRIGHTNESS TIME: 18.25 FOR TURKEY
#
#
# * THE SECOND POINT WITH BRIGHTNESS LATITUDE: 40.044
# * THE SECOND POINT WITH BRIGHTNESS LONGITUDE: -121.369
# * THE SECOND POINT WITH BRIGHTNESS DATE: 2021-07-20
# * THE SECOND POINT WITH BRIGHTNESS TIME: 18.25 FOR TURKEY
#
#
# * AQUA DATA VALUES SAME AS MAIN DATA

# %% [markdown]
# ### GENERAL MAPS

# %%
LAT_LONG_MAX_WORLD = Data_GLOBAL[["latitude","longitude"]]

LAT_LONG_MAX_WORLD.latitude = LAT_LONG_MAX_WORLD.latitude.astype(float)
LAT_LONG_MAX_WORLD.longitude = LAT_LONG_MAX_WORLD.longitude.astype(float)

HEAT_MAX_WORLD = list(zip(LAT_LONG_MAX_WORLD.latitude,LAT_LONG_MAX_WORLD.longitude))

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,20.2433],
                  tiles='Stamen Terrain',
                  zoom_start=1.5)

plugins.MarkerCluster(LAT_LONG_MAX_WORLD).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### **ATTENTION**
# * AT LOCAL BASIS, TURKEY HAS THE HIGHEST VALUE IN THE MEDITERRANEAN REGION.
# * IT MAY BE AN INDICATOR THAT THERE IS NOT A REGIONAL ANOMALY.

# %% [markdown]
# #### **ATTENTION**
#
# * TURKEY'S VALUES ARE HIGH IN TERRA DATA.

# %% [markdown]
# #### **ATTENTION**
# * TURKEY'S VALUES ARE HIGH IN AQUA DATA

# %% [markdown]
# #### **ATTENTION**
#
# PLEASE REVIEW THE RESEARCH DONE BEFORE THIS RESEARCH.
#
# * www.kaggle.com/brsdincer/turkey-recent-wildfire-analysis-investigation
