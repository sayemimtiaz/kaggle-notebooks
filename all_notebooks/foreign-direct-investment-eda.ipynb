# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# I use Python for Data Cleaning and Tableau for Data Visualiztaion

# %%
data=pd.read_csv('/kaggle/input/fdicasestudy/FDI Case Study.csv')
data.head(20)

# %%
data.columns

# %%
data.info

# %% [markdown]
# # Data Cleaning

# %%
data.drop([data.index[0],data.index[1]])

# %%
data.dropna(how='any')

# %%
data.rename(columns={'Unnamed: 1':'Year','Unnamed: 2':'Year','Unnamed: 3':'Year','Unnamed: 4':'Year','Unnamed: 5':'Year',
                    'Unnamed: 6':'Year','Unnamed: 7':'Year','Unnamed: 8':'Year','Unnamed: 9':'Year','Unnamed: 10':'Year','Unnamed: 11':'Year',
                     'Unnamed: 12':'Year','Unnamed: 13':'Year','Unnamed: 14':'Year','Unnamed: 15':'Year','Unnamed: 16':'Year','Unnamed: 17':'Year'
                    },inplace=True)

# %% [markdown]
# # Data Visualization Using Tableau

# %%
from PIL import Image
pic1=Image.open('/kaggle/input/fdi-tableau-files/pic-1.PNG')
pic1

# %%
pic2=Image.open('/kaggle/input/fdi-tableau-files/pic-2.PNG')
pic2

# %%
pic3=Image.open('/kaggle/input/fdi-tableau-files/pic-3.PNG')
pic3

# %%
pic4=Image.open('/kaggle/input/fdi-tableau-files/pic-4.PNG')
pic4

# %%
pic5=Image.open('/kaggle/input/fdi-tableau-files/pic-5.PNG')
pic5

# %%
pic6=Image.open('/kaggle/input/fdi-tableau-files/pic-6.PNG')
pic6

# %%
pic7=Image.open('/kaggle/input/fdi-tableau-files/pic-7.PNG')
pic7

# %%
pic8=Image.open('/kaggle/input/fdi-tableau-files/pic-8.PNG')
pic8

# %%
pic9=Image.open('/kaggle/input/fdi-tableau-files/pic-9.PNG')
pic9
