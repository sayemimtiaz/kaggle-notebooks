# %% [markdown]
# # Introduction
#
# Hi everyone!
#
# Just trying out writing kernels for the first to help beginners; and to see how good it fares and improve my skills!
# I decided to learn python exactly three months back and so, although I am not an expert, or even intermedaite for that matter, I think I did encounter many useful tools and tricks along the way.
#
# So, here's to helping all those starting out!
#
# I decided to add some memes, just to make reading this kernel a bit humorous. Really curious to see how it goes!
# I'll link down the resouces, sites and discussions that helped me compile this kernel up at the end.
#
# So pick up the pencil, note down and Hope you enjoy this!
#
# ![](https://i.imgur.com/pk4IZSb.png)

# %% [markdown]
# # John Wick Chapter 1 : Easy
#
# Legends speak of a man named John Wick. As the story goes, he was not a normal coder; the most brutal of them all.
#
# But John had humble beginings. He started like all of us; a mere mortal.
#
# Made popular only by the power of his pencil; taking notes one tip at a time, till he became the most feared.

# %% [markdown]
# ### 1. In-Place Swapping Of Two Numbers.
#
# Unlike C++, python supports a one-liner to swap the numebers without using any temp varible.

# %%
Name, Title = 'John', 'Wick'
print(Name, Title) 
Name, Title = Title, Name 
print(Name, Title)

# %% [markdown]
# ### 2. Reversing a string in Python
#
# There is also a function reversed(), but this is the most common way I've seen people reverse not only strings, but also lists

# %%
arr2 = "John Wick's Name shall not be reversed!"
print("Reverse is : ")
print(arr2[::-1])

# %% [markdown]
# ### 3. Create a single string
# This is a popular trick to combine all strings in a list into a single string type.

# %%
arr3 = ["John", "Wasn't", "Exactly","The","Boogeyman"] 

print("Result 1")
print(" ".join(arr3))
print()
print("Result 2")
print("".join(arr3))

# %% [markdown]
# ### 4. Getting min/max from a list
# The classic min() and max() function; works on sets and tuples too!

# %%
arr4 = [1, 2, -3]

print(max(arr4))
print(min(arr4))

# %% [markdown]
# ### 5. Chaining Of Comparison Operators
# Shorten your code instead of using two comparators and joining them with "and"

# %%
num = 10

result = (1 < num < 20)
print(result) 

result = (1 > num <= 9)
print(result)

# %% [markdown]
# ### 6. Find The Most Frequent Value In A List
# A quick way to find the most repeating element in a list.

# %%
arr6 = [1, 2, 3, 4, 2, 2, 3, 1, 4, 4, 4] 
print(max(set(arr6), key = arr6.count))

# %% [markdown]
# ### 7. Print string N times.
#
# We've done 3 examples so far without any referecne of John Wick. I don't think he's happy about it.
#
# ![](https://i.imgur.com/KojKXtK.jpg)

# %%
n = 4
arr7 = "John Wick is disapponited he has not come in any example so far \n"
print(arr7 * n)

# %% [markdown]
# ### 8. Storing elements of a list into new variables.

# %%
JohnWicksWeapon = ['Pencil','Gun maybe?']
weapon1, weapon2 = JohnWicksWeapon

print(weapon1 + "\n" + weapon2)

# %% [markdown]
# ### 9. Format a decimal to always show 2 decimal places

# %%
pistolClipType = float(5.5600)
print('{0:.2f}'.format(pistolClipType))

# %% [markdown]
# ### 10. Use of Ternary operator for conditional assignment.
#
# Ever wondered who would in a fight between Vegeta and John Wick?
#
# ![](https://i.imgur.com/Vc3NK5m.png)

# %%
JohnWicksPower = float("inf")

DidJohnWin = True if (JohnWicksPower > 9000) else False

print(DidJohnWin)

# %% [markdown]
# ### 11. Multiple "or" condition checks!
#
# Instead of extending conditions with or, like, `if m==1 or m==3 or m==5 or m==7`, use `in` keyword!

# %%
JohnsTarget = 'Russian Guy'
if JohnsTarget in ['US Gangster', 'Russian Guy', 'Big Boy Tony', 'Don Corleone']:
    print("John's target is the Russian Guy who killed his pet dog!")
    print("John found his farget")

print()
JohnsNewTarget = 'Vegeta'
if JohnsNewTarget in ['US Gangster', 'Russian Guy', 'Big Boy Tony', 'Don Corleone']:
    print("John found his farget")
else:
    print("John's new target is Vegeta")
    print("John hasn't found his target.... YET!")

# %% [markdown]
# ### 12. List Comprehension for inputing an array separated by any number of spaces

# %%
string = "Turns out John Wick is a good hitman, but he probably isn't a coder maybe 😢"

arr = [str(num) for num in string.strip().split()]
print(arr)

# %% [markdown]
# ### 13. Measure the time elapsed to execute your code in Python
# So, it's been all over the news that John maybe wasn't that good of a coder. But he's still efficient at killing!

# %%
import time

startTime = time.time()

JohnsKillCount = 0
# write your code or functions calls
for i in range(20000000):
    JohnsKillCount+=1

endTime = time.time()
totalTime = endTime - startTime

print("John killed",JohnsKillCount,"in" , totalTime,"seconds")
print()

#Using the decimal precision format
print('John killed {0} in {1:.2f} seconds'.format(JohnsKillCount,totalTime))

# %% [markdown]
# ### 14. Play with enumeration.
# Enumerations are great if you want to remember the index number as you iterate. Beginners remember this keyword from the dreaded wine review excercise!

# %%
JohnWickMoviesYear = [2014, 2017, 2019]

for order, yearReleased in enumerate(JohnWickMoviesYear):
    print(order, ': ', yearReleased)

# %% [markdown]
# ### 15. Get the difference between the two Lists

# %%
JohnWickEnemy = ['Probably Vegeta', 'Russian Guy', 'Tarasov', 'Winston', 'Viggo']
JohnWickKilled = ['Russian Guy', 'Tarasov', 'Viggo']

set1 = set(JohnWickEnemy)
set2 = set(JohnWickKilled)

list3 = list(set1.symmetric_difference(set2))
print("People who are still alive after crossing John Wick")
print(list3)

# %% [markdown]
# ### 16. Check the data type of a varible

# %%
string = 'John Wick'
kills = 20000
AmmoType = 5.56

print("Is name a string?\t",isinstance(string,str))
print("Is kill count a number?\t",isinstance(kills,int))
print("Is Ammo type in float?\t",isinstance(AmmoType,float))

# %% [markdown]
# ### 17. How to efficiently compare two unordered lists

# %%
from collections import Counter

JohnWickSkills = ["Kills with pencil", "John knows Python", "John will come and get you", "Ohhh"]
JohnWickSkillsRandom = [ "John knows Python", "Kills with pencil","Ohhh","John will come and get you"]

print("Are the two skills equal?", Counter(JohnWickSkills) == Counter(JohnWickSkillsRandom))

# %% [markdown]
# ### 18. Global vs Local
#
# Global variables are the one that are defined and declared outside a function and we need to use them inside a function. We only need to use the global keyword in a function if we want to do assignments / change them. global is not needed for printing and accessing.
#
# John Wick knew this. That's why he was able to beat the Boogeyman. Boogeyman didn't know it.
#
# ![](https://i.imgur.com/Cyyxwc4.png)

# %%
#Error because BestHitman is being assigned a value but was never defined as global

BestHitman = 'Boggeyman'

def whoIsBestHitman():
    
    print("Best hitman was ",BestHitman)
    BestHitman = 'John Wick' 
    print("But now it is ",BestHitman)
    
whoIsBestHitman()

# %%
BestHitman = 'Boggeyman'

def whoIsBestHitman():
    
    global BestHitman
    
    print("Best hitman was ",BestHitman)
    BestHitman = 'John Wick' 
    print("But now it is ",BestHitman)
    
whoIsBestHitman()

# %% [markdown]
# ### 19. Convert hex to int

# %%
hexNumber = "0x7DE"

print("John Wick 1 was released in ", int(hexNumber, 0))

# %% [markdown]
# ### 19. Convert binary to decimal and decimal to binary

# %%
num = 2014
binary = bin(num)

print("John Wick 1 release Year in binary is",binary)
print("But, you already knew before the year was",int(binary,2))

# %% [markdown]
# ### 20. Given each iterable we construct a tuple by adding an index.

# %%
a = ['John Wick 1', 'John Wick 2', 'John Wick 3']
list(enumerate(a))

# %% [markdown]
# ### 21. Sorting a simple list by absolute value.

# %%
arr = [1,2,3,-4,5]

print("Normal sort is\t\t\t",sorted(arr))
print("Sorting by absolute value\t",sorted(arr,key = abs))

# %% [markdown]
# ### 22. Splitting a single string to list.

# %%
s = "John,Wick,Examples,Will,Be,Diminishing,Slowly"
s.split(",")

# %% [markdown]
# ### 23. Initializing a list filled with some repetitive number.
#
# ![](https://i.imgur.com/VOoB06f.png)

# %%
PencilArr = ["Pencil"]*10
PencilArr

# %% [markdown]
# ### 24. List tricks

# %%
a = [1,2,3]
b = [5,6,7]

print("Before append",a)
a.append(4)

print("After append",a)
a.extend(b)

print("After extend",a)

# %% [markdown]
# ### 25. Dictionary Update

# %%
a = {"John Wick 1":2014, "John Wick 2":2017}
b = {"John Wick 3":2019, "John Wick 4":2021}

print("Before update",a)
a.update(b)
print()
print("After update",a)

# %% [markdown]
# # John Wick Chapter 2 : Medium
#
# Now we can start learning some tips that Wick finds useful every now and then.

# %% [markdown]
# ### 26. Removing useless characters on the end/start/both of your string.
#
# This is as inspired from this [discussion](https://www.kaggle.com/questions-and-answers/148444#832902), this can be useful in cleaning Datasets too!

# %%
name = "///////John / Wick///"

print("Right strip is\t\t",name.rstrip("/"))
print("Left strip is\t\t",name.lstrip("/"))

print("Strip is\t\t",name.strip("/"))

# %% [markdown]
# ### 27. Unpack variables from iterable without indicating all elements.

# %%
>>> Name, *Weapons, ActorName = ['JohnWick', 'Pencil', 'Handgun', 'Knife', 'Keanu Reeves']
print("Name\t",Name)
print("Weapons\t",Weapons)
print("Actor\t",ActorName)

# %% [markdown]
# ### 28. Dictionary/Set comprehensions.

# %%
testDict = {i: i * i for i in range(10)} 
testSet = {i * 2 for i in range(10)}

print(testSet)
print(testDict)

# %% [markdown]
# ### 29. Merge two dictionaries in a single expression

# %%
JohnsFavWeaponsinPart1 = {1: 'Pencil', 2: "Knife", 3:"Pistol"}
JohnsFavWeaponsinPart2  = {1: 'Pencil', 4: "SMG"}

allWeapons = {**JohnsFavWeaponsinPart1, **JohnsFavWeaponsinPart2}
print(allWeapons)

# %% [markdown]
# ### 30. Check the memory usage of an object.

# %%
import sys
print(sys.getsizeof(testSet))
print(sys.getsizeof(testDict))
print(sys.getsizeof(allWeapons))

# %% [markdown]
# ### 31. Form a unified list without using any loops.

# %%
import itertools
test = [[-1, -2], [30, 40], [25, 35]]
print(list(itertools.chain.from_iterable(test)))

import more_itertools

test = [[-1, -2], [1, 2, 3, [4, (5, [6, 7])]], (30, 40), [25, 35]]

print(list(more_itertools.collapse(test)))

#-> [-1, -2, 30, 40, 25, 35]

# %% [markdown]
# ### 32. Transposing a Matrix in numpy
#
# ![](https://i.imgur.com/JCBLzjk.png)

# %%
import numpy as np

mat = np.array([[1, 2, 3], [4, 5, 6]])
transposed = mat.T

transposed

# %% [markdown]
# ### 33. In line search for multiple prefixes in a string.

# %%
print("John Wick Chapter 1".startswith(("John", "JohnWick")))
print("John Wick learns Python at kaggle.com".endswith((".com", ".co.in")))

# %% [markdown]
# ### 34. Cumulative summing a sequence of numbers / Rolling window sum
#
# This was inspired by this [discussion](https://www.kaggle.com/questions-and-answers/147980#830628) right here, where I learnt about expanding functions. This is a trick to achieve kind of pretty similar results.

# %%
#Original Array without cumsum is [0,2,4,6,8]

import numpy as np
res = list(np.cumsum(range(0,10,2)))
res

# %% [markdown]
# ### 35. Depict where there is a change in min/max from left to right

# %%
import itertools
min_change = list(itertools.accumulate([9, 21, 17, 5, 11, 12, 2, 34], min))
max_change = list(itertools.accumulate([9, 21, 17, 5, 11, 12, 2, 34], max))

print("Min changes are ",min_change)
print("Max changes are ",max_change)

# %% [markdown]
# ### 36. DeafultDict() from collections
# The functionality of both dictionaries and defualtdict are almost same except for the fact that defualtdict never raises a KeyError. It provides a default value for the key that does not exists.

# %%
from collections import defaultdict 
  
# Function to return a default 
# values for keys that is not 
# present 
def def_value(): 
    return "Not Present"
      
# Defining the dict 
d = defaultdict(def_value) 
d["a"] = 1
d["b"] = 2
  
print(d["a"]) 
print(d["b"]) 
print(d["c"])

# %% [markdown]
# ### 37. Ordered Dictionary from collections
# OrderedDict preserves the order in which the keys are inserted. A regular dict doesn’t track the insertion order, and iterating it gives the values in an arbitrary order and won't give ordered representation everytime. This is noticeable when the dict size is large.
#
# ![](https://i.imgur.com/YXdHQAk.png)

# %%
# A Python program to demonstrate working of OrderedDict 
from collections import OrderedDict 
    
print("This is an Ordered Dict:\n") 
od = OrderedDict() 

od = {i : i for i in range(10)}

for key, value in od.items(): 
    print(key, value)

# %% [markdown]
# ### 38. DataFrame from scratch

# %%
import pandas as pd

df = pd.DataFrame({
    'Name' : ['John','Iosef'],
    'Last' : ['Wick','Tarasov'],
    'Trait': ['Man of sheer will','Not so much sheer will']
})

df

# %% [markdown]
# ### 39. Numpy Array from Scratch

# %%
import numpy as np

release_years = np.array([2014,2017,2019,2021])
release_years

# %% [markdown]
# ### 39. Pandas DataFrames from dictionaries

# %%
dict1 = {'Name' : ['John','Iosef'],
    'Last' : ['Wick','Tarasov'],
    'Trait': ['Man of sheer will','Not so much sheer will']}

df1 = pd.DataFrame.from_dict(dict1)
df1

# %% [markdown]
# ### 40. Numpy array from other data

# %%
release_year_list = [2014,2017,2019,2021]
numpy_array = np.asarray(release_year_list)

numpy_array

# %% [markdown]
# # John Wick Chapter 3 : Practical usages

# %% [markdown]
# Now that John Wick has learnt of the basics, it's 3rd chapter; end to an epic trilogy. He needs to gear up some tips in his notes for some practical uses. No more John Wick examples - but something different. Something out of his domain expertise. How about a random dataset from Kaggle itself?
#
# John Wick choose the "Stack Overflow Developer Survey", because... Ummm, well, because he's John Wick - he can do whatever he wants!
#
# ![](https://i.imgur.com/htMmE2F.png)

# %%
so_data = pd.read_csv('../input/stack-overflow-2018-developer-survey/survey_results_public.csv')
so_schema = pd.read_csv('../input/stack-overflow-2018-developer-survey/survey_results_schema.csv')

# %% [markdown]
# `so_data` contains the actual survey and each column is briefly described in `so_schema`

# %%
so_data.head(2)

# %%
so_schema.head(2)

# %% [markdown]
# ### 41. Display truncated columns
#
# When we view the tables above, not all the 129 columns are shown. This can be changed using `pd.options`.
# While the number of rows that are shown are also truncated, it's a wise idea not to display all of them because it'll clog up the notebook.

# %%
print("The number of columns present are actually",so_data.shape[1],"and rows are",so_data.shape[0])
so_data.head(3)

# %%
import pandas as pd 
pd.options.display.max_columns = so_data.shape[1]  # None -> No Restrictions
pd.options.display.max_rows = 200    # None -> Be careful with this, not gonna do this here. Will cover up the entire notebook
pd.options.display.max_colwidth = 100
pd.options.display.precision = 3

so_data.head(3)

# %% [markdown]
# ### 42. Sum of Two Numbers, is key to everything!
#
# Just a funny note. Many people use random_state = 42 in thier code when choosing a seed value. The reason is [here](https://www.independent.co.uk/life-style/history/42-the-answer-to-life-the-universe-and-everything-2205734.html), and is pretty out of context.

# %%
random_state = 42

print("Well that did nothing")

# %% [markdown]
# ### 43. Highlight all negative values in a dataframe
#
# Let's try to change text colors in DataFrame using a snapshot of `so_data`. We'll highlight negative numbers.
# As there are no negative numbers in the survey anywhere (I checked them), we'll create some artificial errors and highlight them with red color.
#
# **Let's choose by randomly selecting the first 10 people who work with python.**

# %%
col_choose = ['Respondent','Salary','LanguageWorkedWith','AdBlocker']

so_python_sample = so_data.loc[so_data['LanguageWorkedWith']=='Python']
so_python_sample = so_python_sample[col_choose].head(10)     #or use [:10]. Both will work

so_python_sample

# %%
#Let's make some articial changes that would've been wrong
so_python_sample['Salary'][1062] = -9000

# %%
import pandas as pd
def color_negative_red(val):
    
    #print(type(val),val)
    color = 'red' if isinstance(val,int) and val < 0 else 'black'
    return 'color: %s' % color

so_python_sample.style.applymap(color_negative_red)

# %% [markdown]
# We'll use this snapshot called `so_python_sample` in later examples. This dataframe contists of the first 10 people who said they use python in the survey.

# %% [markdown]
# ### 44. Check equality of Series / Dataframes
#
# While `==` is used everywhere for comparisions, it's not suitable for dataframes. We'll use the `equals()` method. It works on both Dataframes as well as Series.

# %%
so_python_sample == so_data

# %%
print("For the dataframes\t",so_python_sample.equals(so_data))

series1 = so_python_sample['Salary']
series2 = so_python_sample['Salary']

print("For series\t\t",series1.equals(series2))

# %% [markdown]
# ### 44. Add row total and column total to a numerical dataframe
#
# We'll try to append a column which has cumulative sum of a numerical row, and a row that has sum of numerical columns.
# This can be useful for calculating overall scores, grades, etc. Although not very useful in this context, this dataset has enough numerical coulms for the sake of practice.

# %%
so_schema.head(3)

# %%
so_schema.set_index('Column', inplace = True) #Setting the "Column" column as index instead of numerical values
so_schema.loc['AssessJob1']

# %% [markdown]
# Let's select the specific column for the row `AssessJob1` to read this full text. The column we need for the row `AssessJob1` is `QuestionText`

# %%
so_schema.loc['AssessJob1']['QuestionText']

# %% [markdown]
# **Let's check the Response for the `AssessJob` questions for the 10 people we choose above who use python. We'll use thier index values to help us filter them from the other responses.**

# %%
col_to_choose = ['AssessJob'+str(i+1) for i in range(10)] #Choosing all AssessJob columns

numerical_df = so_data[col_to_choose]

numerical_df.loc[so_python_sample.index]

# %%
numerical_df = numerical_df.loc[so_python_sample.index]

numerical_df['col_total'] = numerical_df.apply(lambda x: x.sum(), axis=1)
numerical_df.loc['row_total'] = numerical_df.apply(lambda x: x.sum())

numerical_df

# %% [markdown]
# We've added `col_total` and `row_total` and formed this dataframe snapshot called `numerical_df`, for the 10 people using python.

# %% [markdown]
# ### 45. Merge Dataframe based on common value
#
# Let's merge the `so_python_sample` and `numerical_df` together. I've decided to use the common index, but you can use common columns too as [discussed](https://www.kaggle.com/c/competitive-data-science-predict-future-sales/discussion/148486#832981) here

# %%
df_combined = pd.merge(so_python_sample, numerical_df ,right_index = True,left_index = True)

df_combined

# %% [markdown]
# NOTE : that there is no row_total, because in the criteria section we macthed them by thier index. However, since `row_total` was arbitraty row created only in `numerical_df`, it's been left out. This is not the case with `col_total`

# %% [markdown]
# ### 46. Crosstabs

# %% [markdown]
# The crosstab() function is used to compute a simple cross tabulation of two (or more) factors. They help us to view relationship between any two columns that share common values.

# %%
so_schema.loc['AssessJob4']['QuestionText']

# %%
pd.crosstab(df_combined['AssessJob4'],df_combined['AdBlocker'])

# %% [markdown]
# Hence, for the first 10 people using python, we can see that users with 9.0 rating (who don't feel the language, frameworks are important for a job opportunity) use adblockers.

# %% [markdown]
# ### 47. Check worth of info

# %% [markdown]
# This is rather a very interesting topic I discovered when I was reading materials online to answer a [discussion](https://www.kaggle.com/learn-forum/148901#835928) question.
# As the name suggests, this is a hack to find a quantitative value of how much of information is generated by 'n' columns that are highly corelated.

# %%
corr_list = list(so_schema.loc[col_to_choose]['QuestionText'])

print("The whole text is \n" + corr_list[0])
print()
print("Trimmed text \n" + corr_list[0][240:])

# %%
corr_list = [("AssessJob"+str(i+1)+" : "+corr_list[i][240:]) for i in range(10)]
corr_list

# %%
df_combined[col_to_choose].corr()

# %%
df_combined[['AssessJob1','AssessJob9']].corr()

# %%
cols_selected_squared = 4 #Because we are choosing two columns, 2^2 = 4

info_worth = cols_selected_squared/(df_combined[['AssessJob1','AssessJob9']].corr()**2).sum().sum()
print("The two columns have given you {0:.2f} columns worth of info".format(info_worth))

# %%
info_worth = cols_selected_squared/(df_combined[['AssessJob1','AssessJob1']].corr()**2).sum().sum()
print("The two columns have given you {0:.2f} columns worth of info".format(info_worth))

# %% [markdown]
# ### 48. Load Data From the Clipboard
#
# You can copy paste the text below and use `pd.read_clipboard()` method to instantly get dataFrames.
# Although, it's not supported in Kaggle notebooks, it works flawlessly on jupyter.
#
# As seen in the screenshot below, the dataframe was defined only using `pd.read_clipboard()`

# %% [markdown]
#     bar	foo
# 0	4	1
#
# 1	5	2
#
# 2	6	3
#
#
# ![](https://i.imgur.com/NJz98qm.png)

# %% [markdown]
# ### 49. Wide Dataframe to Long Dataframe
#
# I came to learn this trick from the discussion [here](https://www.kaggle.com/questions-and-answers/147178#826823).

# %%
df_combined.melt(id_vars = ['Respondent'])

# %% [markdown]
# # Movie Credits
#
# [John Wick](https://johnwick.fandom.com/wiki/John_Wick)
#
# [GeeksForGeeks](https://www.geeksforgeeks.org/)
#
# [DataSchool](https://www.dataschool.io/python-pandas-tips-and-tricks/)
#
# [Real Python](https://realpython.com/python-pandas-tricks/)
#
# [Kaggle Discussions](https://www.kaggle.com/discussion)

# %% [markdown]
# # Thank you for reading!
#
# Well, theres goes my first kernel!
#
# I don't know how this will turn out. It has been some really dark days; internships getting cancelled, staring the screen, staying at home.
#
# I decided to learn Python about 3 months back, and this lockdown has left me mentally exhausted to code and learn; so much so that I often end up compairing myself to other better Kagglers and pondering that I'ce probably not achieved much in life.
#
# I had always heard everyone say, consistency and practice is all that matters, and I can clearly see why it's the hardest thing to do. Anyway, even though I was reluctant, I decided it's better to slow down instead of stopping, so even though reluctant, I tried switching to writing kernels just to ease things off.
#
# **If you found this kernel helpful please consider upvoting it!**
#
# ![](https://i.imgur.com/PcPq7a9.png)
