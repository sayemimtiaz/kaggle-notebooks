# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#Reading the data

df = pd.read_csv('/kaggle/input/epl-players-deep-stats-20192020/epl_players_stats.csv')

# %%
#Getting first five rows of data 

df.head().T

# %%
#Getting data information

df.info()

# %% [markdown]
# - 5 columns with object datatype.
# - 14 columns with integer datatype.
# - 22 columns with float datatype.

# %%
#Getting the details of null values
df.isnull().sum()

# %% [markdown]
# Here only the nationality data column has 8 null rows

# %%
#Getting data description for detailed insights

df.describe()

# %% [markdown]
#  Through above table we get to know mean, min and max of each numerical column, we can get usefull insights from it as follows :
#
# - The average age of EPL player is 26 ,while the min is 17 and max is 39.
# - Instrestingly there are players whos height and weights are 0 assumed to be unknown .
# - On average a player get to to play 20 games, and each player has atleast played one game.
# - On average a player playes 1440 mins whole season .
# - Average rating for players in EPL is 6.6 which from claculated to max i.e 7.97 gives that most of the players perfforms very well in the matches.
# - The goals scored by players has mean of 1.91 close to 2 but has standard deviation of 3.5 approx which is large and the maximum goals scored by player is 23.
#
# Further on we will get the detailed insights of each features and good presentation through graphs to understand the insights effectively.

# %%
#Getting the most rated player

df[df['rating_m']==df['rating_m'].max()]['name']

# %%
#Top 10 most rated player

rating_sort = df.sort_values('rating_m',ascending=False)

rating_sort.head(10)['name']

# %% [markdown]
# - Intrestingly the dataframe is sorted on the values of rating_m initially

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
 #Getting the most aged player rating

df[df['age']==df['age'].max()][['rating_m','name','position','age','team','games']]

# %% [markdown]
# Top 10 players with assists.

# %%
df1 =  df.sort_values('assists',ascending=False).head(10)
plt.barh(df1['name'],df1['assists'])

plt.show()

# %% [markdown]
# Getting top 10 players based on goals scored

# %%
df1=df.sort_values('goals',ascending=False).head(10)
plt.barh(df1['name'],df1['goals'])

plt.show()

# %% [markdown]
# Teams with most goals scored

# %%
df.groupby(['team'])['goals'].sum().sort_values(ascending=False).head(10)

# %% [markdown]
# Top 10 players who got red cards

# %%
df1=df.sort_values('red_cards',ascending=False).head(10)
plt.barh(df1['name'],df1['red_cards'])

plt.show()

# %% [markdown]
# Players with most yellow cards

# %%
df1=df.sort_values('yel_cards',ascending=False).head(10)
plt.barh(df1['name'],df1['yel_cards'])

plt.show()

# %% [markdown]
# Teams penalised with most yellow cards .

# %%
df.groupby(['team'])['yel_cards'].sum().sort_values(ascending=False).head(10)

# %% [markdown]
# Teams penalised with most red cards .

# %%
df.groupby(['team'])['red_cards'].sum().sort_values(ascending=False).head(10)

# %% [markdown]
# Top teams shots per match.

# %%
df.groupby(['team'])['shots_m'].sum().sort_values(ascending=False).head(10)

# %% [markdown]
# Top teams aerials won per match

# %%
df.groupby(['team'])['aerials_won_m'].sum().sort_values(ascending=False).head(10)

# %% [markdown]
# Team with most man of the match awarded.

# %%
df.groupby(['team'])['motm'].sum().sort_values(ascending=False).head(10)

# %% [markdown]
# Teams with most passes.

# %%
df.groupby(['team'])['passes_m'].sum().sort_values(ascending=False).head(10)

# %% [markdown]
# Players with most successful passes percentage with atleast 1200 min played.

# %%
df1=df[df['minutes']>1200].sort_values('successful_passes_pt',ascending=False).head(10)
plt.barh(df1['name'],df1['successful_passes_pt'])

plt.show()

# %% [markdown]
# Team with most key passes.

# %%
df.groupby(['team'])['key_passes_m'].sum().sort_values(ascending=False).head(10)

# %% [markdown]
# Players with most dribbles won playing atleast 1200 mins in the season.

# %%
df1=df[df['minutes']>1200].sort_values('dribbles_won_m',ascending=False).head(10)
plt.barh(df1['name'],df1['dribbles_won_m'])

plt.show()

# %% [markdown]
# Players with most dribbles won playing atmost 500 mins in the season.

# %%
df1=df[df['minutes']<500].sort_values('dribbles_won_m',ascending=False).head(10)
plt.barh(df1['name'],df1['dribbles_won_m'])

plt.show()

# %% [markdown]
# Teams with most dribbles won per match

# %%
df.groupby(['team'])['dribbles_won_m'].sum().sort_values(ascending=False).head(10)

# %% [markdown]
# Teams with most fouls given.

# %%
df.groupby(['team'])['fouls_given_m'].sum().sort_values(ascending=False).head(10)

# %% [markdown]
# Team with most accurate crosses.

# %%
df.groupby(['team'])['accurate_crosses_m'].sum().sort_values(ascending=False).head(10)

# %% [markdown]
# Players with most accurate crosses won playing atleast 1200 mins in the season.

# %%
df1=df[df['minutes']>1200].sort_values('accurate_crosses_m',ascending=False).head(10)
plt.barh(df1['name'],df1['accurate_crosses_m'])

plt.show()

# %% [markdown]
# Players with most accurate crosses won playing atmost 500 mins in the season.

# %%
df1=df[df['minutes']<500].sort_values('accurate_crosses_m',ascending=False).head(10)
plt.barh(df1['name'],df1['accurate_crosses_m'])

plt.show()

# %%
df.columns

# %% [markdown]
# Team with most accurate long passes.

# %%
df.groupby(['team'])['accurate_long_passes_m'].sum().sort_values(ascending=False).head(10)

# %% [markdown]
# Players with most accurate long passes per match played atleast 1200 mins.

# %%
df1=df[df['minutes']>1200].sort_values('accurate_long_passes_m',ascending=False).head(10)
plt.barh(df1['name'],df1['accurate_long_passes_m'])

plt.show()

# %% [markdown]
# Players with most accurate long passes per match played atmost 500 mins.

# %%
df1=df[df['minutes']<500].sort_values('accurate_long_passes_m',ascending=False).head(10)
plt.barh(df1['name'],df1['accurate_long_passes_m'])

plt.show()

# %% [markdown]
# Team with most accurate through passes.

# %%
df.groupby(['team'])['accurate_through_passes_m'].sum().sort_values(ascending=False).head(10)

# %% [markdown]
# Players with most accurate through passes played atleast 1200 mins in whole season.

# %%
df1=df[df['minutes']>1200].sort_values('accurate_through_passes_m',ascending=False).head(10)
plt.barh(df1['name'],df1['accurate_through_passes_m'])

plt.show()

# %% [markdown]
# Players with most accurate through passes played atmost 500 mins in whole season.

# %%
df1=df[df['minutes']<500].sort_values('accurate_through_passes_m',ascending=False).head(10)
plt.barh(df1['name'],df1['accurate_through_passes_m'])

plt.show()

# %% [markdown]
# Teams with best tackles per match

# %%
df.groupby(['team'])['tackles_m'].sum().sort_values(ascending=False).head(10)

# %% [markdown]
# Players with most tackles per match with atleast 1200 mins played.

# %%
df1=df[df['minutes']>1200].sort_values('tackles_m',ascending=False).head(10)
plt.barh(df1['name'],df1['tackles_m'])

plt.show()

# %% [markdown]
# Players with most tackles per match with atmost 500 mins played.

# %%
df1=df[df['minutes']<500].sort_values('tackles_m',ascending=False).head(10)
plt.barh(df1['name'],df1['tackles_m'])

plt.show()

# %% [markdown]
# Teams with best interceptions.

# %%
df.groupby(['team'])['interceptions_m'].sum().sort_values(ascending=False).head(10)

# %% [markdown]
# Players with most interceptions with atleast 1200 mins played.

# %%
df1=df[df['minutes']>1200].sort_values('interceptions_m',ascending=False).head(10)
plt.barh(df1['name'],df1['interceptions_m'])

plt.show()

# %% [markdown]
# Players with most interceptions with atmost 500 mins played.

# %%
df1=df[df['minutes']<500].sort_values('interceptions_m',ascending=False).head(10)
plt.barh(df1['name'],df1['interceptions_m'])

plt.show()

# %% [markdown]
# Players with most clearances per match

# %%
df1=df.sort_values('clearances_m',ascending=False).head(10)
plt.barh(df1['name'],df1['clearances_m'])

plt.show()

# %% [markdown]
# Top teams having players with most clearances.

# %%
df.groupby(['team'])['clearances_m'].sum().sort_values(ascending=False).head(10)

# %% [markdown]
# Top players with most dribbled past per match.

# %%
df1=df.sort_values('dribbled_past_m',ascending=False).head(10)
plt.barh(df1['name'],df1['dribbled_past_m'])

plt.show()

# %% [markdown]
# Top teams having players which are dribbled past per match.

# %%
df.groupby(['team'])['dribbled_past_m'].sum().sort_values(ascending=False).head(10)

# %%
Top Players who have scored own goals.

# %%
df1=df.sort_values('dribbled_past_m',ascending=False).head(10)
plt.barh(df1['name'],df1['dribbled_past_m'])

plt.show()

# %% [markdown]
# Top goalkeepers who played atleast 1200 min and saved goals per match.

# %%
df1=df[df['minutes']>1200].sort_values('gk_saves_m',ascending=False).head(10)
plt.barh(df1['name'],df1['gk_saves_m'])

plt.show()

# %% [markdown]
# Teams with most goals saved per match.

# %%
df.groupby(['team'])['gk_saves_m'].sum().sort_values(ascending=False).head(10)
