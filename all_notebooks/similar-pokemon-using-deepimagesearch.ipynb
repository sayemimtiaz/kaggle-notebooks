# %%
! pip install DeepImageSearch

# %%
from DeepImageSearch import Index,LoadData,SearchImage

# %%
image_list = LoadData().from_folder(folder_list = ['../input/pokemon-images-and-types/images/images/'])

# %%
Index(image_list).Start()

# %%
image_list[0:4]

# %%
SearchImage().get_similar_images(image_path='../input/pokemon-images-and-types/images/images/abomasnow.png',number_of_images=5)

# %%
SearchImage().plot_similar_images(image_path = '../input/pokemon-images-and-types/images/images/abomasnow.png')
