# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import plotly.offline as py

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# Project description - Author: Doğukan Arslan
#
# #Yorumsepeti: A PACKAGE FOR FETCHING RESTAURANT REVIEWS FROM YEMEKSEPE
#
# Yorumsepeti requires Selenium to run. Do not forget to include Chromedriver.exe in your project file.
#
# https://pypi.org/project/yorumsepeti/

# %%
# !pip install yorumsepeti

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
df = pd.read_csv('../input/yorumsepeti/yorumsepeti.csv', delimiter=';', nrows = nRowsRead)
df.dataframeName = 'yorumsepeti.csv'
nRow, nCol = df.shape
print(f'There are {nRow} rows and {nCol} columns')
df.tail().style.set_properties(**{'background-color':'bisque',
                                     'color': 'purple'})

# %%
df.isnull().sum()

# %%
# !pip install selenium

# %%
from selenium import webdriver

# %% [markdown]
# #Usage

# %%
from yorumsepeti import fetchers  
  
# to get n=100 comments  
fetchers.get_comments(100)

# %% [markdown]
# #WebDriverException: Message: 'chromedriver.exe' executable needs to be in PATH. Please see https://sites.google.com/a/chromium.org/chromedriver/home

# %% [markdown]
# #Since I don't know how to install chromedriver.exe' directly in Kaggle viewer (without downloading then extracting it in my PC), I will wait till anybody make a code with Yorumsepeti.

# %%
##Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

from wordcloud import WordCloud
from wordcloud import STOPWORDS
stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color = 'salmon',
                      height =2000,
                      width = 2000
                     ).generate(str(df["review"]))
plt.rcParams['figure.figsize'] = (12,12)
plt.axis("off")
plt.imshow(wordcloud)
plt.title("Yorumsepeti")
plt.show()

# %%
fig = px.bar(df, 
             x='speed', y='review', color_discrete_sequence=['magenta'],
             title='Yorumsepeti', text='service')
fig.show()

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRoT1oJGtklZq8el06unW3Gpp_FYQNqR71M0A&usqp=CAU)youtube.com

# %%
df['review'].value_counts()[:20].plot.barh(title='Yorumsepeti', figsize=(8,6),color= 'r')

# %%
sns.scatterplot(data = df, x = "speed", y = "flavour",hue = "flavour", color='red');

# %%
fig = px.bar(df, 
             x='review', y='flavour', color_discrete_sequence=['#2B3A67'],
             title='Yorumsepeti', text='service')
fig.show()

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRJzs88zrVvFM2qMuofROtHLGp0yWkaCX6uyQ&usqp=CAU)pinterest.com

# %%
# categorical features with missing values
categorical_nan = [feature for feature in df.columns if df[feature].isna().sum()>0 and df[feature].dtypes=='O']
print(categorical_nan)

# %%
# replacing missing values in categorical features
for feature in categorical_nan:
    df[feature] = df[feature].fillna('None')

# %%
df[categorical_nan].isna().sum()

# %%
df = pd.get_dummies(df)

# %%
x = df.drop(['review_Güzel.'], axis=1)
y = df.iloc[:,0]

# %% [markdown]
# #Code by Parul Khare https://www.kaggle.com/parulkhare26/zomato-restaurant-eda-and-visualization/notebook

# %%
from sklearn.linear_model import LogisticRegression #Logistic Regression is a Machine Learning classification algorithm
from sklearn.linear_model import LinearRegression #Linear Regression is a Machine Learning classification algorithm
from sklearn.model_selection import train_test_split #Splitting of Dataset
from sklearn.metrics import classification_report 
from sklearn.metrics import confusion_matrix
from sklearn.metrics import r2_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.1,random_state=0)

# %%
#x_train.head()

# %% [markdown]
# #Linear Regression

# %%
regressor = LinearRegression()
regressor.fit(x_train, y_train)

# Predicting the Test set results
y_pred = regressor.predict(x_test)

from sklearn.metrics import r2_score
r2_score(y_test,y_pred)

# %% [markdown]
# #Decision Tree Model

# %%
from sklearn.tree import DecisionTreeRegressor
DecTree=DecisionTreeRegressor(min_samples_leaf=.0001)
DecTree.fit(x_train,y_train)
y_predict=DecTree.predict(x_test)

# %%
r2_score(y_test,y_predict)

# %% [markdown]
# #Random Forest Regression Model

# %%
from sklearn.ensemble import RandomForestRegressor
RForest=RandomForestRegressor(n_estimators=5,random_state=329,min_samples_leaf=.0001)
RForest.fit(x_train,y_train)
y_predict1=RForest.predict(x_test)

# %%
r2_score(y_test,y_predict1)

# %%
#Code by Olga Belitskaya https://www.kaggle.com/olgabelitskaya/sequential-data/comments
from IPython.display import display,HTML
c1,c2,f1,f2,fs1,fs2=\
'#eb3434','#eb3446','Akronim','Smokum',30,15
def dhtml(string,fontcolor=c1,font=f1,fontsize=fs1):
    display(HTML("""<style>
    @import 'https://fonts.googleapis.com/css?family="""\
    +font+"""&effect=3d-float';</style>
    <h1 class='font-effect-3d-float' style='font-family:"""+\
    font+"""; color:"""+fontcolor+"""; font-size:"""+\
    str(fontsize)+"""px;'>%s</h1>"""%string))
    
    
dhtml('Yorumsepeti Package by Yemeksepe. Author: Doğukan Arslan')
