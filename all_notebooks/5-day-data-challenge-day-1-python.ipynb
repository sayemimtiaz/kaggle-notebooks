# %% [markdown]
# Importing pandas for reading the .csv file

# %%
import pandas as pd
data = pd.read_csv("../input/archive.csv")
data

# %% [markdown]
# Describe() function for summary of the data.

# %%
data.describe().transpose()
