# %%
from plotly.offline import init_notebook_mode, iplot, plot
import plotly as py
init_notebook_mode(connected=True)
# import chart_studio.plotly
import plotly.graph_objs as go
# from chart_studio.plotly import plot, iplot
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import networkx as nx
# %matplotlib inline 
from IPython.display import display
import seaborn as sns

# %%
df = pd.read_csv('../input/a-lot-of-memes-info-stats/memes_dataset.csv')

# %%
df.head()

# %%
df.info()

# %%
df['date_added'] = pd.to_datetime(df['date_added'])

# %%
df.head()

# %%
fig_dims = (20, 10)
fig, ax = plt.subplots(figsize=fig_dims)
a_plot=sns.scatterplot(data=df, y="comments", x="date_added")
a_plot.set(ylim=(0,100))

# %%
fig_dims = (20, 10)
fig, ax = plt.subplots(figsize=fig_dims)
a_plot=sns.scatterplot(data=df, y="views", x="date_added")
a_plot.set(ylim=(0,10000))

# %%
fig_dims = (20, 10)
fig, ax = plt.subplots(figsize=fig_dims)
a_plot = sns.scatterplot(data=df, y="photos", x="date_added")
a_plot.set(ylim=(0,100))
