# %% [markdown]
# ** Salaries by Region **
#
# I have chosen to use the dataset which analyses salary by region and college.

# %% [markdown]
# Loading the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Reading in the Regional Dataset**

# %%
Region_Data = pd.read_csv('../input/salaries-by-region.csv',encoding='utf-8')
# Checking first 5 rows of the dataset
Region_Data.head(n=5)

# %% [markdown]
# **Summarize the dataset**
# This will help getting the summary stats for each variable in the dataset

# %%
Region_Data.describe()

# %% [markdown]
# I believe the percentiles etc. were not shown, since all the values in this dataset are stored as strings
