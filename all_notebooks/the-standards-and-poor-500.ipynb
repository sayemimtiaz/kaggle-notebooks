# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
S=pd.read_csv("../input/sp-500-companies-with-financial-information/financials.csv")
print(S.shape)
print(S.dtypes)
S.columns = [col.replace(' ', '_').lower() for col in S.columns]
print(S.columns)
S.head(90)
#S.iloc[40:60,[9]

# %%
import matplotlib.pyplot as plt
S.sort_values("symbol", axis = 0, ascending = False, inplace = True, na_position = 'last')
S2=S.loc[(S.market_cap > 1.5*(10**11))]
S2.plot.scatter(x='sector', y= 'price', rot=90)
S.sort_values("symbol", axis = 0, ascending = False, inplace = True, na_position = 'last')
S2=S.loc[(S.market_cap > 1.5*(10**11))]
S2.plot.scatter(x='sector', y= 'price/earnings', rot=90)
S.sort_values("symbol", axis = 0, ascending = False, inplace = True, na_position = 'last')
S2=S.loc[(S.market_cap > 1.5*(10**11))]
S2.plot.scatter(x='sector', y= 'dividend_yield', rot=90)
S.sort_values("symbol", axis = 0, ascending = False, inplace = True, na_position = 'last')
S2=S.loc[(S.market_cap > 1.5*(10**11))]
S2.plot.scatter(x='sector', y= 'earnings/share', rot=90)
S.sort_values("symbol", axis = 0, ascending = False, inplace = True, na_position = 'last')
S2=S.loc[(S.market_cap > 1.5*(10**11))]
S2.plot.scatter(x='sector', y= 'market_cap', rot=90)
S.sort_values("symbol", axis = 0, ascending = False, inplace = True, na_position = 'last')
S2=S.loc[(S.market_cap > 1.5*(10**11))]
S2.plot.scatter(x='sector', y= 'ebitda', rot=90)
S.sort_values("symbol", axis = 0, ascending = False, inplace = True, na_position = 'last')
S2=S.loc[(S.market_cap > 1.5*(10**11))]
S2.plot.scatter(x='sector', y= 'price/sales', rot=90)
S.sort_values("symbol", axis = 0, ascending = False, inplace = True, na_position = 'last')
S2=S.loc[(S.market_cap > 1.5*(10**11))]
S2.plot.scatter(x='sector', y= 'price/book', rot=90)
S.sort_values("symbol", axis = 0, ascending = False, inplace = True, na_position = 'last')
S2=S.loc[(S.market_cap > 1.5*(10**11))]
S.sort_values("symbol", axis = 0, ascending = False, inplace = True, na_position = 'last')
S2=S.loc[(S.market_cap > 1.5*(10**11))]
S2.plot.scatter(x='symbol', y= 'price', rot=90)
S.sort_values("symbol", axis = 0, ascending = False, inplace = True, na_position = 'last')
S2=S.loc[(S.market_cap > 1.5*(10**11))]
S2.plot.scatter(x='symbol', y= 'price/earnings', rot=90)
S.sort_values("symbol", axis = 0, ascending = False, inplace = True, na_position = 'last')
S2=S.loc[(S.market_cap > 1.5*(10**11))]
S2.plot.scatter(x='symbol', y= 'dividend_yield', rot=90)
S.sort_values("symbol", axis = 0, ascending = False, inplace = True, na_position = 'last')
S2=S.loc[(S.market_cap > 1.5*(10**11))]
S2.plot.scatter(x='symbol', y= 'earnings/share', rot=90)
S.sort_values("symbol", axis = 0, ascending = False, inplace = True, na_position = 'last')
S2=S.loc[(S.market_cap > 1.5*(10**11))]
S2.plot.scatter(x='symbol', y= 'market_cap', rot=90)
S.sort_values("symbol", axis = 0, ascending = False, inplace = True, na_position = 'last')
S2=S.loc[(S.market_cap > 1.5*(10**11))]
S2.plot.scatter(x='symbol', y= 'ebitda', rot=90)
S.sort_values("symbol", axis = 0, ascending = False, inplace = True, na_position = 'last')
S2=S.loc[(S.market_cap > 1.5*(10**11))]
S2.plot.scatter(x='symbol', y= 'price/sales', rot=90)
S.sort_values("symbol", axis = 0, ascending = False, inplace = True, na_position = 'last')
S2=S.loc[(S.market_cap > 1.5*(10**11))]
S2.plot.scatter(x='symbol', y= 'price/book', rot=90)
S.sort_values("symbol", axis = 0, ascending = False, inplace = True, na_position = 'last')
S2=S.loc[(S.market_cap > 1.5*(10**11))]

# %%
#S.sort_values("symbol", axis = 0, ascending = False, inplace = True, na_position = 'last')
#S2=S.loc[(S.market_cap > 1.5*(10**11))]
#S2.plot.scatter(x='symbol', y= 'market_cap', rot=90)

# %%
#S.sort_values("symbol", axis = 0, ascending = False, inplace = True, na_position = 'last')
#S2=S.loc[(S.market_cap > 1.5*(10**11))]
#S2.plot.scatter(x='sector', y= 'market_cap', rot=90)

# %%
#S.sort_values("symbol", axis = 0, ascending = False, inplace = True, na_position = 'last')
#S2=S.loc[(S.market_cap > 1.5*(10**11))]
#S2.plot.scatter(x='sector', y= 'price/earnings', rot=90)
