# %% [markdown]
# #Does gender discrimination matter for long-term growth?
#
# A recent study by the OECD Development Centre shows that gender-based discrimination hampers economic growth.
#
# According to does gender discrimination matter for long-term growth? There is a strong negative relationship between gender-based discrimination, and income per capita. Hence, the economic cost of gender-based discrimination in institutions is particularly high. The income loss associated with current levels of gender discrimination could be substantial, estimated at up to USD 12 trillion, 16% of current global GDP. At the same time, reducing gender-based discrimination through the right policy measures could yield huge potential income gains.https://www.wikigender.org/does-gender-discrimination-in-social-institutions-matter-for-long-term-growth-cross-country-evidence/
#
# That introduction refers to Social Institutions, though I think it can be applied in others activities too.

# %% [markdown]
# #Copyright: OECD Development Centre
#
# ![](https://www.wikigender.org/wp-content/uploads/2016/03/Gender-WP-Infog-Final-1.png)https://www.wikigender.org/does-gender-discrimination-in-social-institutions-matter-for-long-term-growth-cross-country-evidence/

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import plotly.express as px
import seaborn as sns
import plotly.graph_objects as go
import plotly.offline as py
import matplotlib.pyplot as plt


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('../input/gender-statistics/Gender_StatsData.csv', encoding='ISO-8859-2')
df.head(2)

# %% [markdown]
# #Copyright: OECD Development Centre
#
# ![](https://www.wikigender.org/wp-content/uploads/2016/03/Gender-WP-Infog-Final-2.png)https://www.wikigender.org/does-gender-discrimination-in-social-institutions-matter-for-long-term-growth-cross-country-evidence/

# %%
df.isnull().sum()

# %%
ZWE = df[(df['ďťż"Country Name"']=='Zimbabwe')].reset_index(drop=True)
ZWE.head(2)

# %%
#Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

color = plt.cm.Set1(np.linspace(0,1,20))
ZWE["Indicator Name"].value_counts().sort_values(ascending=False).head(20).plot.pie(y="2019",colors=color,autopct="%0.1f%%")
plt.title("Zimbabwe Gender Indicators 2019")
plt.axis("off")
plt.show()

# %%
ARB = df[(df['ďťż"Country Name"']=='Arab World')].reset_index(drop=True)
ARB.head(1)

# %%
#Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

color = plt.cm.RdBu(np.linspace(0,1,20))
ARB["Indicator Name"].value_counts().sort_values(ascending=False).head(10).plot.pie(y="2020",colors=color,autopct="%0.1f%%")
plt.title("Arab World Gender Indicators 2020")
plt.axis("off")
plt.show()

# %%
BRA = df[(df['ďťż"Country Name"']=='Brazil')].reset_index(drop=True)
BRA.head(1)

# %%
#Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

color = plt.cm.summer(np.linspace(0,1,20))
ARB["Indicator Name"].value_counts().sort_values(ascending=False).head(10).plot.pie(y="1960",colors=color,autopct="%0.1f%%")
plt.title("Brazilian Gender Indicators 1960")
plt.axis("off")
plt.show()

# %%
#Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

color = plt.cm.winter(np.linspace(0,1,20))
ARB["Indicator Name"].value_counts().sort_values(ascending=False).head(20).plot.pie(y="2020",colors=color,autopct="%0.1f%%")
plt.title("Brazilian Gender Indicators 2020")
plt.axis("off")
plt.show()

# %% [markdown]
# #The percent in Brazil's Pies 1960 and 2020 changed just because I changed head 10 to 20.
#
# And the color of the Pie from summer to winter. Therefore, it's not helping to determine if the conditions remain, are improving or not.

# %%
#Code by Mario Filho https://www.kaggle.com/mariofilho/live26-https-youtu-be-zseefujo0zq

fig,ax = plt.subplots(1,1, figsize=(8,8))
degree = BRA.groupby(['Indicator Name', '2020']).size().unstack()#.fillna(0)
degree = degree.div(degree.sum(axis=1), axis=0)
sns.heatmap(degree, cmap='viridis')

# %%
#Code by Mario Filho https://www.kaggle.com/mariofilho/live26-https-youtu-be-zseefujo0zq
from category_encoders import OneHotEncoder
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.preprocessing import StandardScaler, MinMaxScaler, MaxAbsScaler

cols_selected = ['Indicator Name']
ohe = OneHotEncoder(cols=cols_selected, use_cat_names=True)
df_t = ohe.fit_transform(df[cols_selected+['2020']])

#scaler = MaxAbsScaler()
X = df_t.iloc[:,:-1]
y = df_t.iloc[:, -1].fillna(df_t.iloc[:, -1].mean()) / df_t.iloc[:, -1].max()

mdl = Ridge(alpha=0.1)
mdl.fit(X,y)

pd.Series(mdl.coef_, index=X.columns).sort_values().head(10).plot.barh()

# %%
BRA['2020'].hist(figsize=(10,5), bins=20)

# %%
ax = BRA['Indicator Name'].value_counts().head(10).plot.barh(figsize=(14, 6))
ax.set_title('Brazilian Gender Indicators 2020', size=18)
ax.set_ylabel('Indicator Name', size=14)
ax.set_xlabel('Count', size=14)

# %%
corr = df.corr()
corr.style.background_gradient(cmap = 'coolwarm')

# %%
##Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

from wordcloud import WordCloud
from wordcloud import STOPWORDS
stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color = 'black',
                      height =2000,
                      width = 2000,
                      colormap='ocean',
                     ).generate(str(df["Indicator Name"]))
plt.rcParams['figure.figsize'] = (12,12)
plt.axis("off")
plt.imshow(wordcloud)
plt.title("")
plt.show()

# %% [markdown]
# #The Wordcloud above speaks for itself to illustrate women condition around the World.

# %%
#Code by Olga Belitskaya https://www.kaggle.com/olgabelitskaya/sequential-data/comments
from IPython.display import display,HTML
c1,c2,f1,f2,fs1,fs2=\
'#2B3A67','#42a7f5','Akronim','Smokum',30,15
def dhtml(string,fontcolor=c1,font=f1,fontsize=fs1):
    display(HTML("""<style>
    @import 'https://fonts.googleapis.com/css?family="""\
    +font+"""&effect=3d-float';</style>
    <h1 class='font-effect-3d-float' style='font-family:"""+\
    font+"""; color:"""+fontcolor+"""; font-size:"""+\
    str(fontsize)+"""px;'>%s</h1>"""%string))
    
    
dhtml('Kaggle Notebook Runner: Marília Prata, not a DS. Stick around, I will be right back. @mpwolke' )
