# %%
#Import pandas package as pd
import pandas as pd

# %%
#import matplotlib.pyplot package as plt 
import matplotlib.pyplot as plt

# %% [markdown]
# **Click on the "+Add Dataset" on the top right**
# * Search for **Wine Reviews**
# * Click on **Add** the Wine Reviews dataset which shows 130k wine reviews with variety, location, winery, price, and description
# * Explore the data and copy the path

# %%
#Import the CSV file winemag-data_first150k.csv into wine_data (do not include index column)
#wine_data = pd.read_csv("<Enter the full path here>", index_col=0)
wine_data = pd.read_csv('../input/winemag-data_first150k.csv', index_col=0)

# %%
#Display first 5 lines of wine_data using head() function
wine_data.head()
# Out:
#   country           ...                              winery
# 0      US           ...                               Heitz
# 1   Spain           ...             Bodega Carmen Rodríguez
# 2      US           ...                            Macauley
# 3      US           ...                               Ponzi
# 4  France           ...                Domaine de la Bégude
#
# [5 rows x 10 columns]

# %%
#Find value_counts of province column
#__._____.value_counts()
wine_data.province.value_counts()
# Out:
# California                                44508
# Washington                                 9750
# Tuscany                                    7281
# Bordeaux                                   6111
# Northern Spain                             4892
# Mendoza Province                           4742
# Oregon                                     4589
# Burgundy                                   4308
# Piedmont                                   4093
# Veneto                                     3962
# South Australia                            3004
# Sicily & Sardinia                          2545
# New York                                   2428
# Northeastern Italy                         1982
# Loire Valley                               1786
# Alsace                                     1680
# Marlborough                                1655
# Southwest France                           1601
# Central Italy                              1530
# Southern Italy                             1439
# Champagne                                  1370
# Catalonia                                  1352
# Rhône Valley                               1318
# Colchagua Valley                           1201
# Languedoc-Roussillon                       1082
# Douro                                      1075
# Provence                                   1021
# Port                                        903
# Maipo Valley                                895
# Other                                       889
#                                           ...
# Pocerina                                      1
# Pannon                                        1
# Sterea Ellada                                 1
# Valais                                        1
# Dalmatian Coast                               1
# Morocco                                       1
# Serra do Sudeste                              1
# Viile Timis                                   1
# Slovenska Istra                               1
# Terasele Dunarii                              1
# Viile Carasului                               1
# Limnos                                        1
# Colares                                       1
# Beni M'Tir                                    1
# Ella Valley                                   1
# Ilia                                          1
# Colchagua Costa                               1
# Vino da Tavola della Svizzera Italiana        1
# Rose Valley                                   1
# Santa Barbara County-Condrieu                 1
# Nevada                                        1
# Vale Trentino                                 1
# Douro Superior                                1
# Elim                                          1
# Central Otago-Marlborough                     1
# Central Greece                                1
# Casablanca-Curicó Valley                      1
# Dolenjska                                     1
# Zitsa                                         1
# Ioannina                                      1
# Name: province, Length: 455, dtype: int64

# %%
#Find value_counts() of province column and display first 10 rows using head() function
#__._____.value_counts().head(__)
wine_data.province.value_counts().head(10)
# Out:
# California          44508
# Washington           9750
# Tuscany              7281
# Bordeaux             6111
# Northern Spain       4892
# Mendoza Province     4742
# Oregon               4589
# Burgundy             4308
# Piedmont             4093
# Veneto               3962
# Name: province, dtype: int64

# %%
#Find value_counts() of province column and display first 10 rows using head() function and plot the BAR graph
#__._____.value_counts().head(__).plot.bar()
wine_data.province.value_counts().head(10).plot.bar()

# %%
#Plot the figure in the 18 x 6 inches grid
#plt.figure(figsize=(___,___))
plt.figure(figsize=(18,6)) 
wine_data.province.value_counts().head(10).plot.bar()

# %%
#Find value_counts() of province column and display first 10 rows, normalize the data and plot the BAR graph
#(__._____.value_counts().head(__)/len(wine_data).plot.bar()
plt.figure(figsize=(12,6)) 
(wine_data.province.value_counts().head(10)/len(wine_data)).plot.bar()

# %%
#Find value_counts of points column
#__._____.value_counts()
wine_data.points.value_counts()
# Out:
# 87     20747
# 88     17871
# 90     15973
# 86     15573
# 89     12921
# 85     12411
# 84     10708
# 91     10536
# 92      9241
# 83      6048
# 93      6017
# 82      4041
# 94      3462
# 95      1716
# 81      1502
# 80       898
# 96       695
# 97       365
# 98       131
# 99        50
# 100       24
# Name: points, dtype: int64

# %%
#Find value_counts of points column and sort by index
#__._____.value_counts().sort_index()
wine_data.points.value_counts().sort_index()
# Out:
# 80       898
# 81      1502
# 82      4041
# 83      6048
# 84     10708
# 85     12411
# 86     15573
# 87     20747
# 88     17871
# 89     12921
# 90     15973
# 91     10536
# 92      9241
# 93      6017
# 94      3462
# 95      1716
# 96       695
# 97       365
# 98       131
# 99        50
# 100       24
# Name: points, dtype: int64

# %%
#Find value_counts of points column and sort by index and plot the BAR graph
#__._____.value_counts().sort_index().plot.bar()
wine_data.points.value_counts().sort_index().plot.bar()

# %%
#Find value_counts of points column and sort by index and plot the LINE graph
#__._____.value_counts().sort_index().plot.line()
plt.figure(figsize=(18,6))
wine_data.points.value_counts().sort_index().plot.line()

# %%
#Find value_counts of points column and sort by index and plot the AREA graph
#__._____.value_counts().sort_index().plot.area()
plt.figure(figsize=(18,6))
wine_data.points.value_counts().sort_index().plot.area()

# %%
#Display the rows of wine_data where the price > 200
#__[________['________']>200]
wine_data[wine_data['price'] > 200 ]
# Out:
#           country              ...                                       winery
# 0              US              ...                                        Heitz
# 16             US              ...                                         Hall
# 18         France              ...                           Château Lagrézette
# 22          Spain              ...                                    Numanthia
# 898         Italy              ...                                         Gaja
# 954         Italy              ...                            Tenuta di Trinoro
# 2145       France              ...                           Château Haut-Brion
# 2155       France              ...                              Château Margaux
# 2159       France              ...                           Château Haut-Brion
# 2434       France              ...                Château La Mission Haut-Brion
# 2453        Spain              ...                                 Marco Abella
# 2673       France              ...                   Jean-Luc and Paul Aegerter
# 2733       France              ...                Château La Mission Haut-Brion
# 2742       France              ...                             Château Trotanoy
# 3033    Australia              ...                                     Penfolds
# 3597        Chile              ...                                    Errazuriz
# 5241        Italy              ...                             Domenico Clerico
# 5392        Italy              ...                                 Le Macchiole
# 6302      Germany              ...                                  Robert Weil
# 6323      Germany              ...                                  Dr. Hermann
# 6737        Italy              ...                                 Le Macchiole
# 7299        Spain              ...                                  Emilio Moro
# 7319      Germany              ...                                  Robert Weil
# 7591      Germany              ...                                  Robert Weil
# 7650        Italy              ...                                      Argiano
# 7691        Spain              ...                                 Vega Sicilia
# 7796       France              ...                     Domaine Rossignol-Trapet
# 7798       France              ...                         Bouchard Père & Fils
# 8071       France              ...                             Domaine Faiveley
# 8072       France              ...                                 Louis Latour
# ...           ...              ...                                          ...
# 142304         US              ...                                         BOND
# 142306     France              ...                           Château Haut-Brion
# 142307      Spain              ...                                 Vega Sicilia
# 142310      Spain              ...                                  Viña Sastre
# 142318         US              ...                                         BOND
# 142560         US              ...                                         BOND
# 142565      Spain              ...                            Dominio de Pingus
# 142697         US              ...                                Harlan Estate
# 142707  Australia              ...                                     Penfolds
# 143522         US              ...                                        Sloan
# 143523         US              ...                                Harlan Estate
# 143526    Germany              ...                               Von Othegraven
# 143530         US              ...                              Screaming Eagle
# 143534         US              ...                                         BOND
# 143535         US              ...                                         BOND
# 143536         US              ...                                         BOND
# 143539         US              ...                                       Colgin
# 143543         US              ...                                       Colgin
# 143546      Italy              ...                                         Gaja
# 143548    Germany              ...                                 Georg Breuer
# 143612      Spain              ...                                     Contador
# 143778         US              ...                                       Colgin
# 143941     France              ...                     Veuve Clicquot Ponsardin
# 143953     France              ...                     Veuve Clicquot Ponsardin
# 144225     France              ...                     Veuve Clicquot Ponsardin
# 145422      Italy              ...                              Mastroberardino
# 146767    Germany              ...                            Domdechant Werner
# 149172     France              ...                    Château Lafite Rothschild
# 149173     France              ...                              Château Margaux
# 149187     France              ...                    Château Mouton Rothschild
#
# [775 rows x 10 columns]

# %%
#Display the rows of wine_data where the price > 200.  Display only price column
#__[________['________']>200]['------']
wine_data['price'][wine_data['price'] > 200 ]
# Out:
# 0         235.0
# 16        325.0
# 18        290.0
# 22        220.0
# 898       500.0
# 954       240.0
# 2145      848.0
# 2155      450.0
# 2159      330.0
# 2434      698.0
# 2453      770.0
# 2673      238.0
# 2733      202.0
# 2742      250.0
# 3033      500.0
# 3597      235.0
# 5241      250.0
# 5392      225.0
# 6302      365.0
# 6323      350.0
# 6737      300.0
# 7299      450.0
# 7319      365.0
# 7591      365.0
# 7650      325.0
# 7691      500.0
# 7796      240.0
# 7798      315.0
# 8071      225.0
# 8072      520.0
#           ...
# 142304    210.0
# 142306    240.0
# 142307    325.0
# 142310    395.0
# 142318    210.0
# 142560    210.0
# 142565    320.0
# 142697    300.0
# 142707    225.0
# 143522    245.0
# 143523    245.0
# 143526    250.0
# 143530    500.0
# 143534    225.0
# 143535    225.0
# 143536    225.0
# 143539    225.0
# 143543    225.0
# 143546    224.0
# 143548    283.0
# 143612    354.0
# 143778    250.0
# 143941    280.0
# 143953    250.0
# 144225    235.0
# 145422    217.0
# 146767    227.0
# 149172    345.0
# 149173    360.0
# 149187    260.0
# Name: price, Length: 775, dtype: float64

# %%
#Display the rows of wine_data where the price > 200.  Display only price column and plot the histogram.
#__[________['________']>200]['------'].plot.hist()
wine_data[wine_data['price'] > 200 ]['price'].plot.hist()

# %%
#Display the rows of wine_data where the price > 200.  Plot the histogram of price with 100 bins
#__[________['________']>200]['------'].plot.hist(bins=100)
wine_data[wine_data['price'] > 200 ]['price'].plot.hist(bins=100)

# %%
#Display the rows of wine_data where the price > 1500.  Plot the histogram of price with 100 bins
#__[________['________']>1500]['------'].plot.hist(bins=100)
wine_data['price'][wine_data['price'] > 1500 ].plot.hist(bins=100)

# %%
#Display value_counts() of country in wine_data. Display first 5 rows only.
#__._____.value_counts().head()
wine_data.country.value_counts().head()
# Out:
# US        62397
# Italy     23478
# France    21098
# Spain      8268
# Chile      5816
# Name: country, dtype: int64

# %%
#Display value_counts() of country in wine_data. Display first 5 rows only. Plot the pie chart
#__._____.value_counts().head().plot.pie()
plt.figure(figsize=(9, 9))
wine_data.country.value_counts().head().plot.pie()

# %%
#Display the rows of wine_data where the price < 100.  
#_______[________['________']<100]
wine_data[wine_data['price'] < 100]
# Out:
#             country              ...                                     winery
# 2                US              ...                                   Macauley
# 3                US              ...                                      Ponzi
# 4            France              ...                       Domaine de la Bégude
# 5             Spain              ...                                  Numanthia
# 6             Spain              ...                                   Maurodos
# 8                US              ...                                  Bergström
# 9                US              ...                                  Blue Farm
# 10            Italy              ...                           Borgo del Tiglio
# 11               US              ...                     Patricia Green Cellars
# 12               US              ...                     Patricia Green Cellars
# 13           France              ...                          Vignobles Brumont
# 15               US              ...                                  Bergström
# 17            Spain              ...                                   Valduero
# 19               US              ...                               Gary Farrell
# 20               US              ...                                      Heitz
# 21            Spain              ...                                       Muga
# 23               US              ...                           Center of Effort
# 24               US              ...                                   Comartin
# 25      New Zealand              ...                                Kumeu River
# 26               US              ...                                  Bergström
# 28               US              ...                                       Roar
# 29               US              ...                                     Saviah
# 30         Bulgaria              ...                               Villa Melnik
# 31               US              ...                                   Zepaltas
# 33           France              ...                             Bouvet-Ladubay
# 34               US              ...                                       Buty
# 36           France              ...               Clos de L'Oratoire des Papes
# 37            Italy              ...                                 Avignonesi
# 38            Italy              ...                           Casina di Cornia
# 39            Italy              ...                   Castello di Monterinaldi
# ...             ...              ...                                        ...
# 150899        Chile              ...                                 Santa Rita
# 150900        Chile              ...                                 De Martino
# 150901        Chile              ...                                  Undurraga
# 150902        Chile              ...                                 De Martino
# 150903        Chile              ...                                 Santa Rita
# 150904        Chile              ...                                 De Martino
# 150905        Chile              ...                                 De Martino
# 150906       France              ...                                Michel Gros
# 150907       France              ...                                Daniel Rion
# 150908       France              ...                                Michel Gros
# 150909       France              ...                                Daniel Rion
# 150910       France              ...                                Michel Gros
# 150911       France              ...                                Michel Gros
# 150912       France              ...                                Daniel Rion
# 150913       France              ...                            Le Vieux Donjon
# 150914           US              ...                                    Navarro
# 150915           US              ...                                   Beringer
# 150916           US              ...                                Schramsberg
# 150917       France              ...                                   Jacquart
# 150918       France              ...                                   Jacquart
# 150919       France              ...                                  H.Germain
# 150920        Italy              ...                                    Letrari
# 150921       France              ...                                   Jacquart
# 150923       France              ...                                   Jacquart
# 150924       France              ...                    Heidsieck & Co Monopole
# 150925        Italy              ...                      Feudi di San Gregorio
# 150926       France              ...                                  H.Germain
# 150927        Italy              ...                                  Terredora
# 150928       France              ...                                     Gosset
# 150929        Italy              ...                              Alois Lageder
#
# [133102 rows x 10 columns]

# %%
#Display the rows of wine_data where the price < 100.  Display 50 random samples
#_______[________['________']<100].sample(__)
wine_data[wine_data['price'] <100].sample(50)
# Out:
#             country               ...                                        winery
# 150756       France               ...                  Baron Philippe de Rothschild
# 68275            US               ...                                  Folie à Deux
# 27808         Spain               ...                                  Juvé y Camps
# 80981         Italy               ...                           Domenico Fraccaroli
# 18696            US               ...                                   Arrow Creek
# 71122            US               ...                                   Seven Hills
# 20549         Italy               ...                                 Corte Lenguin
# 88777         Spain               ...                                      Analivia
# 51266         Italy               ...                                     Montezovo
# 118446           US               ...                          Walla Walla Vintners
# 79676        France               ...                Château du Domaine de l'Eglise
# 109871    Argentina               ...                                       Lagarde
# 40761       Austria               ...                                        Loimer
# 140548           US               ...                                        Keenan
# 143901           US               ...                                 Clark-Clauden
# 12179            US               ...                                         Trust
# 87266        France               ...                             Château le Vivier
# 90659            US               ...                                       Stottle
# 32822            US               ...                     Howell Mountain Vineyards
# 66402         Italy               ...                                       Comelli
# 116676        Spain               ...                                   TorresManur
# 109319        Italy               ...                                 Alois Lageder
# 150053           US               ...                                       Arciero
# 104075           US               ...                                    Shalestone
# 13474       Germany               ...                                    Prinz Salm
# 7249         France               ...                               Domaine Brusset
# 6786             US               ...                                      Lakewood
# 145235    Australia               ...                                    De Bortoli
# 116039           US               ...                                         Hogue
# 80823            US               ...                                 Merry Edwards
# 135338           US               ...                                       Reverie
# 127967       Greece               ...                                Ioannis Hatzis
# 39939         Chile               ...                                   O. Fournier
# 115630    Argentina               ...                                 Michel Torino
# 73218            US               ...                                    Sebastiani
# 4289          Italy               ...                                     Belpoggio
# 96716            US               ...                          Santa Barbara Winery
# 78728        France               ...                               Simonnet-Febvre
# 97319        France               ...                           Alain Jaume et Fils
# 83241        France               ...                  Baron Philippe de Rothschild
# 25908   New Zealand               ...                                  Jules Taylor
# 136931        Italy               ...                                    Cantarutti
# 103200    Australia               ...                                      Penfolds
# 33202        France               ...                           Domaine du Tariquet
# 64895            US               ...                                        Arista
# 35041      Portugal               ...                                   Ramos-Pinto
# 71695         Spain               ...                             Pago de la Jaraba
# 101792    Australia               ...                                     Bleasdale
# 60096         Spain               ...                               Vinos Valtuille
# 143719       France               ...                                Clos Floridène
#
# [50 rows x 10 columns]

# %%
#Display the rows of wine_data where the price < 100.  Plot the scatter plot with 'price' on x axis, 'points' on y axis for 50 random samples
#_______[________['________']<100].sample(__).plot.scatter(x='------',y='------')
wine_data[wine_data['price'] < 100].sample(50).plot.scatter(x='price', y='points')

# %%
#Display the rows of wine_data where the price < 100.  Plot the scatter plot with 'price' on x axis, 'points' on y axis for all samples
#_______[________['________']<100].plot.scatter(x='------',y='------')

# %%
#A hex plot aggregates points in space into hexagons, and then colors those hexagons based on the values within them
#Display the rows of wine_data where the price < 100.  Plot the hexplot with 'price' on x axis, 'points' on y axis and gridsize 15.
#reviews[reviews['price'] < 100].plot.hexbin(x='price', y='points', gridsize=15)

# %%
#Display the rows of wine_data where the price > 100.  Plot the histogram of price with 100 bins
#__[________['________']>1500]['------'].plot.hist(bins=100)

# %% [markdown]
# **Click on the "+Add Dataset" on the top right**
# * Search for **Most Common Wine Scores**
# * Click on **Add** the ost Common Wine Scores dataset which shows Review scores for five common wines
# * Explore the data and copy the path

# %%
#Import the CSV file winemag-data_first150k.csv into wine_data (do not include index column)
#wine_data = pd.read_csv("<Enter the full path here>", index_col=0)

# %%
#Display first 5 rows of wine_counts

# %%
#wine_counts counts the number of times each of the possible review scores was received by the five most commonly reviewed types of wines:
#Plot the stacked BAR chart of wine_counts
#_______.plot.bar(stacked=True)

# %%
#Plot the stacked AREA chart of wine_counts
#_______.plot.area(stacked=True)

# %%
#Plot the stacked LINE chart of wine_counts
#_______.plot.line(stacked=True)
