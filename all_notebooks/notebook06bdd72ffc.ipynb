# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'../input/crime-in-india-2019/Corruption 2019.csv')

# %%
df=df.drop(columns=['Category','Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14'])

# %%
df.columns

# %%
df.set_index('State/UT ',inplace=True)

# %%
df.style.background_gradient(cmap='PuRd')
