# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("../input/position-salaries/Position_Salaries.csv")

# %%
data.describe()

# %%
data.info()

# %%
data.head(10)

# %%
x=data.iloc[:,1:2].values                    # x = data.drop('Salary', 1)
y=data.iloc[:,2:].values                     # y = data.Salary

# %%
x

# %%
y

# %%
# y=y.reshape(len(y),1)
# print(y)
#There we go

# %%
from sklearn.preprocessing import StandardScaler
sc_x=StandardScaler()
sc_y=StandardScaler()
x=sc_x.fit_transform(x)                  # X=StandardScaler().fit_transform(x)
y=sc_y.fit_transform(y)                  # Y=StandardScaler().fit_transform(y)

# %%
x

# %%
y

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, y_train, x_test, y_test=train_test_split(x, y, train_size=0.7, random_state=100)
x_train.shape, x_test.shape

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(x, y)

# %%
import matplotlib.pyplot as plt

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.scatter(x,y,color='r')
ax.set_title('Salary_Postion_Level - Data')
ax.set_xlabel(' x - Independent Variabel -->>')
ax.set_ylabel(' y - Dependent Variabel -->>')

# %%
plt.scatter(x,y,color='red')
plt.plot(x, regressor.predict(x), color='blue')
plt.title('Salary_Postion_Level - Data')
plt.xlabel('x - Independent Variabel -->> ')
plt.ylabel('y - Dependent Variabel -->> ')
