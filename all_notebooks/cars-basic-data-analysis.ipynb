# %%
import pandas as pd
import numpy as np
print('Priyatama is Ready!')

# %%
car = pd.read_csv('../input/used-cars-dataset/Cars.csv')

# %%
car.head(3)

# %%
car.shape

# %%
#Q. 1) Find any null value in any column, and fill it with mean of that column.
car.isnull().sum()

# %%
car['Cylinders'].fillna(car['Cylinders'].mean(), inplace = True)
car.isnull().sum()

# %%
#Q. 2) What are the different make in our dataset and what are their occurances?
car['Make'].value_counts()

# %%
#Q. 3) Show all the records where origin is Asia or Europe.
car['Origin'].value_counts()

# %%
car[(car['Origin'] != 'USA')] #Since there are 3 values, and we want data with either of two values so we filtered data in make column != one that we do not want.

# %%
#Q. 4) Remove all data points where weight is above 4000.
car[~(car['Weight'] > 4000)]
#Here, we have filtered data points where Weight is >4000 and put "~" to exclude the data with following filter.

# %%
#Q. 5) Increase all the values of "MPG_City" column by 3.
car.head(3)

# %%
car['MPG_City'] = car['MPG_City'].apply(lambda x:x+3)
car.head(3)
