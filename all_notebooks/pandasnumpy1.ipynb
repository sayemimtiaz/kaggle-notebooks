# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.

# %%
data1 = pd.read_csv('../input/tmdb_5000_credits.csv')

# %%
data2 = pd.read_csv('../input/tmdb_5000_movies.csv')

# %%
data1.info()
data2.info()

# %%
data2.corr() 
#If the popularity increases, the voting rate increases? its true or ID increase affects vote average
# negatively and No Relationship Between  ID and Budget

# %%
f,ax = plt.subplots(figsize=(10,10))
sns.heatmap(data2.corr(), annot=True, linewidths=3, fmt= '.1f')
plt.show() # eliminates the black-white line

# %%
data2.head(2) #show 10 lines from start (default 5)

# %%
#data2.tail(3) #show at the and

# %%
data2.plot(kind='scatter', x='budget', y='revenue', alpha=0.5, color='b')
plt.show()
#plt.title('Budget/Revenue') I got an error 'str' object is not callable
#plt.xlabel('Budget') I got an error 'str' object is not callable
#plt.ylabel('Revenue') I got an error 'str' object is not callable

#Help me pls!

# %%
data2.popularity.plot(kind= 'hist',bins=100,figsize=(10,10))
plt.show()

# %%
data2.popularity.plot(kind= 'hist',bins = 50)

#plt.clf() #delete plot

# %%
series = data2['budget']
print(type(series))
data2_frame=data2[['budget']]
print(type(data2_frame))

#pandas has 3 data type 1-Series 2-DataFrame 3- its not necessary
#Series are vector and series methods different DataFrame methods
x=data2[['budget']] > 100000
data2[x]
#why other colums values are NaN?

# %%
data2[np.logical_and(data2['budget']>1000,data2['vote_count']>1000)]

# %%
hbudget = data2[data2.budget >= 150000000]
#hbudget.info() #(high budget)
lbudget = data2[data2.budget <150000000]
#lbudget.info() (low budget)

# %%
a = hbudget.budget #More than 150.000.000$
#print(a)
b = lbudget.budget #Lower than 150.000.000$
#print(b)

# %%
dataFrame1 = pd.DataFrame(data2)
head = dataFrame1.head()
#print(head)
#print(dataFrame1.budget)
#print(dataFrame1.index[0])
#print(dataFrame1)

# %%
#dataFrame1.info()
#print(dataFrame1.budget[0])
#for i in dataFrame1.budget[i]:
 #   if(dataFrame1.budget[i]>150000000):
 #       print("Expensive")
  #  else:
     #    print("Cheap")
    #i = i + 1
    #ERROR

# %%
filtre1 = dataFrame1.budget >= 150000000
filtre2 = dataFrame1.budget <150000000
filtering_data1 = dataFrame1[filtre1]
filtering_data2 = dataFrame1[filtre2]
#print(filtering_data1)
#print(filtering_data2)

# %%
#print(dataFrame1.popularity[0])
#if dataFrame1.popularity[1] > 140.0:
 #   print("most popularity")
#else:
 #   print("gg")
#print(dataFrame1.popularity[1])

# %%
 i=0
for i in dataFrame1.popularity[i]:
    if dataFrame1.popularity[i] > 140.0:
         print("Most Popularity")
    else:
        print("GG")
    i= i +1
        
    #Why dosent work?
