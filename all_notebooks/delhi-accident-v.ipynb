# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
                                                                                                                                
from pandas import plotting

#plotly 
import plotly.offline as py
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
init_notebook_mode(connected=True)
import plotly.figure_factory as ff
import plotly.express as px
# set style
plt.style.use('fivethirtyeight')

# %%
df=pd.read_csv('../input/delhi-crime-data/Delhi Accident Data.csv')
df.head()

# %%
df=df.drop(["Unnamed: 7","Unnamed: 8","Unnamed: 9"], axis=1)

# %%
df.head()

# %%
victim=['PEDESTRIAN', 'S/C & M/C', 'CAR']
year=[2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]
districts=["SOUTH EAST DELHI",
"NEW DELHI",
"NORTH DELHI(ROHINI)",
"CENTRAL DELHI",
"SOUTH WEST DELHI",
"WEST DELHI",
"NORTH WEST DELHI",
"EAST DELHI",
"SHAHDARA",
"SOUTH DELHI",
"NORTH EAST DELHI",
"UNK",
"OUTER"]
vehichle_at_fault=['PVT CAR', 'UNKNOWN', 'S/C&M/C','HTV/GDS']

# %%
np.sum(df['TYPE OF ACCIDENT'].value_counts())

# %%
x=df[df['DISTRICT']==districts[0]]

x['TYPE OF ACCIDENT'].value_counts()

# %%
x=df[df['DISTRICT']=="SOUTH EAST DELHI"]
print("SOUTH EAST DELHI")
for z in year:
    xx=x[x['YEAR']==z]
    a=xx['TYPE OF ACCIDENT'].value_counts()
    
    print(z)
    print(a)

# %%
x=df[df['DISTRICT']==districts[1]]
print(districts[1])
for z in year:
    xx=x[x['YEAR']==z]
    a=xx['TYPE OF ACCIDENT'].value_counts()
    print(z)
    print(a)

# %%
x=df[df['DISTRICT']==districts[2]]
print(districts[2])
for z in year:
    xx=x[x['YEAR']==z]
    a=xx['TYPE OF ACCIDENT'].value_counts()
    print(z)
    print(a)

# %%
x=df[df['DISTRICT']==districts[3]]
print(districts[3])
for z in year:
    xx=x[x['YEAR']==z]
    a=xx['TYPE OF ACCIDENT'].value_counts()
    print(z)
    print(a)

# %%
x=df[df['DISTRICT']==districts[4]]
print(districts[4])
for z in year:
    xx=x[x['YEAR']==z]
    a=xx['TYPE OF ACCIDENT'].value_counts()
    print(z)
    print(a)

# %%
x=df[df['DISTRICT']==districts[5]]
print(districts[5])
for z in year:
    xx=x[x['YEAR']==z]
    a=xx['TYPE OF ACCIDENT'].value_counts()
    print(z)
    print(a)

# %%
x=df[df['DISTRICT']==districts[6]]
print(districts[6])
for z in year:
    xx=x[x['YEAR']==z]
    a=xx['TYPE OF ACCIDENT'].value_counts()
    print(z)
    print(a)

# %%
x=df[df['DISTRICT']==districts[7]]
print(districts[7])
for z in year:
    xx=x[x['YEAR']==z]
    a=xx['TYPE OF ACCIDENT'].value_counts()
    print(z)
    print(a)

# %%
x=df[df['DISTRICT']==districts[8]]
print(districts[8])
for z in year:
    xx=x[x['YEAR']==z]
    a=xx['TYPE OF ACCIDENT'].value_counts()
    print(z)
    print(a)

# %%
x=df[df['DISTRICT']==districts[9]]
print(districts[9])
for z in year:
    xx=x[x['YEAR']==z]
    a=xx['TYPE OF ACCIDENT'].value_counts()
    print(z)
    print(a)

# %%
x=df[df['DISTRICT']==districts[10]]
print(districts[10])
for z in year:
    xx=x[x['YEAR']==z]
    a=xx['TYPE OF ACCIDENT'].value_counts()
    print(z)
    print(a)

# %%
x=df[df['DISTRICT']==districts[11]]
print(districts[11])
for z in year:
    xx=x[x['YEAR']==z]
    a=x['TYPE OF ACCIDENT'].value_counts()
    print(z)
    print(a)

# %%
ft_rate=pd.read_csv('../input/delhi-vaaccident/delhi-V(a) - Sheet1.csv')
ft_rate.head()

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["SOUTH EAST DELHI"], name="SOUTH EAST DELHI", line=dict(color='firebrick', width=1,dash='dash')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["NEW DELHI"], name="NEW DELHI", line=dict(color='#FF97FF', width=1,dash='dot')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["NORTH DELHI(ROHINI)"], name="NORTH DELHI(ROHINI)", line=dict(color='blue', width=1, dash='dashdot')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["CENTRAL DELHI"], name="CENTRAL DELHI", line=dict(color='#FF6692', width=1,dash='dash')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["SOUTH WEST DELHI"], name="SOUTH WEST DELHI", line=dict(color='#19D3F3', width=1,dash='dot')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["WEST DELHI"], name="WEST DELHI", line=dict(color='#FFA15A', width=1, dash='dashdot')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["NORTH WEST DELHI"], name="NORTH WEST DELHI", line=dict(color='#AB63FA', width=1, dash='dash')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["EAST DELHI"], name="EAST DELHI", line=dict(color='#00CC96', width=1,dash='dot')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["SHAHDARA"], name="SHAHDARA", line=dict(color='#EF553B', width=1,dash='dashdot')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["SOUTH DELHI"], name="SOUTH DELHI", line=dict(color='#636EFA', width=1, dash='dash')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["NORTH EAST DELHI"], name="NORTH EAST DELHI", line=dict(color='#636EFA', width=1, dash='dash')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["AVERAGE"], name="AVERAGE", line=dict(color='black', width=4)))


fig.update_layout(title='Fatality rate across the different Districts across the different Year',
                   xaxis_title='Districts',
                   yaxis_title='Probability of Fality')

fig.show()

# %%
ft_rate=pd.read_csv('../input/delhivcar/delhi-V-car - Sheet1.csv')
ft_rate.head()

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["SOUTH EAST DELHI"], name="SOUTH EAST DELHI", line=dict(color='firebrick', width=1,dash='dash')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["NEW DELHI"], name="NEW DELHI", line=dict(color='#FF97FF', width=1,dash='dot')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["NORTH DELHI(ROHINI)"], name="NORTH DELHI(ROHINI)", line=dict(color='blue', width=1, dash='dashdot')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["CENTRAL DELHI"], name="CENTRAL DELHI", line=dict(color='#FF6692', width=1,dash='dash')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["SOUTH WEST DELHI"], name="SOUTH WEST DELHI", line=dict(color='#19D3F3', width=1,dash='dot')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["WEST DELHI"], name="WEST DELHI", line=dict(color='#FFA15A', width=1, dash='dashdot')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["NORTH WEST DELHI"], name="NORTH WEST DELHI", line=dict(color='#AB63FA', width=1, dash='dash')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["EAST DELHI"], name="EAST DELHI", line=dict(color='#00CC96', width=1,dash='dot')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["SHAHDARA"], name="SHAHDARA", line=dict(color='#EF553B', width=1,dash='dashdot')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["SOUTH DELHI"], name="SOUTH DELHI", line=dict(color='#636EFA', width=1, dash='dash')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["NORTH EAST DELHI"], name="NORTH EAST DELHI", line=dict(color='#636EFA', width=1, dash='dash')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["AVERAGE"], name="AVERAGE", line=dict(color='black', width=4)))


fig.update_layout(title='Fatality rate across the different Districts across the different Year Given Victim- CAR',
                   xaxis_title='Districts',
                   yaxis_title='Probability of Fality')

fig.show()

# %%
ft_rate=pd.read_csv('../input/delhivscmc/delhi-V-S_C and M_C - Sheet1.csv')
ft_rate.head()

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["SOUTH EAST DELHI"], name="SOUTH EAST DELHI", line=dict(color='firebrick', width=1,dash='dash')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["NEW DELHI"], name="NEW DELHI", line=dict(color='#FF97FF', width=1,dash='dot')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["NORTH DELHI(ROHINI)"], name="NORTH DELHI(ROHINI)", line=dict(color='blue', width=1, dash='dashdot')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["CENTRAL DELHI"], name="CENTRAL DELHI", line=dict(color='#FF6692', width=1,dash='dash')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["SOUTH WEST DELHI"], name="SOUTH WEST DELHI", line=dict(color='#19D3F3', width=1,dash='dot')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["WEST DELHI"], name="WEST DELHI", line=dict(color='#FFA15A', width=1, dash='dashdot')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["NORTH WEST DELHI"], name="NORTH WEST DELHI", line=dict(color='#AB63FA', width=1, dash='dash')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["EAST DELHI"], name="EAST DELHI", line=dict(color='#00CC96', width=1,dash='dot')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["SHAHDARA"], name="SHAHDARA", line=dict(color='#EF553B', width=1,dash='dashdot')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["SOUTH DELHI"], name="SOUTH DELHI", line=dict(color='#636EFA', width=1, dash='dash')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["NORTH EAST DELHI"], name="NORTH EAST DELHI", line=dict(color='#636EFA', width=1, dash='dash')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["AVERAGE"], name="AVERAGE", line=dict(color='black', width=4)))


fig.update_layout(title='Fatality rate across the different Districts across the different Year Given Victim- S\C % M\C',
                   xaxis_title='Districts',
                   yaxis_title='Probability of Fality')

fig.show()

# %%
ft_rate=pd.read_csv('../input/delhi-v-0pedestrain/delhi-V-Pedestrain - Sheet1.csv')
ft_rate.head()

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["SOUTH EAST DELHI"], name="SOUTH EAST DELHI", line=dict(color='firebrick', width=1,dash='dash')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["NEW DELHI"], name="NEW DELHI", line=dict(color='#FF97FF', width=1,dash='dot')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["NORTH DELHI(ROHINI)"], name="NORTH DELHI(ROHINI)", line=dict(color='blue', width=1, dash='dashdot')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["CENTRAL DELHI"], name="CENTRAL DELHI", line=dict(color='#FF6692', width=1,dash='dash')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["SOUTH WEST DELHI"], name="SOUTH WEST DELHI", line=dict(color='#19D3F3', width=1,dash='dot')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["WEST DELHI"], name="WEST DELHI", line=dict(color='#FFA15A', width=1, dash='dashdot')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["NORTH WEST DELHI"], name="NORTH WEST DELHI", line=dict(color='#AB63FA', width=1, dash='dash')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["EAST DELHI"], name="EAST DELHI", line=dict(color='#00CC96', width=1,dash='dot')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["SHAHDARA"], name="SHAHDARA", line=dict(color='#EF553B', width=1,dash='dashdot')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["SOUTH DELHI"], name="SOUTH DELHI", line=dict(color='#636EFA', width=1, dash='dash')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["NORTH EAST DELHI"], name="NORTH EAST DELHI", line=dict(color='#636EFA', width=1, dash='dash')))
fig.add_trace(go.Scatter(x=ft_rate['Year'], y=ft_rate["AVERAGE"], name="AVERAGE", line=dict(color='black', width=4)))


fig.update_layout(title='Fatality rate across the different Districts across the different Year Given Victim- Pedestrain',
                   xaxis_title='Districts',
                   yaxis_title='Probability of Fality')

fig.show()

# %%
victim=['PEDESTRIAN', 'S/C & M/C', 'CAR']

# %%
x=df[df['DISTRICT']==districts[0]]
print(districts[0])
for z in victim:
    xx=x[x['VICTIM']==z]
    print(z)
    for i in year:
        y=xx[xx['YEAR']==i]
        a=y['TYPE OF ACCIDENT'].value_counts()
        print(i)
        print(a)

# %%
x=df[df['DISTRICT']==districts[1]]
print(districts[1])
for z in victim:
    xx=x[x['VICTIM']==z]
    print(z)
    for i in year:
        y=xx[xx['YEAR']==i]
        a=y['TYPE OF ACCIDENT'].value_counts()
        print(i)
        print(a)

# %%
x=df[df['DISTRICT']==districts[2]]
print(districts[2])
for z in victim:
    xx=x[x['VICTIM']==z]
    print(z)
    for i in year:
        y=xx[xx['YEAR']==i]
        a=y['TYPE OF ACCIDENT'].value_counts()
        print(i)
        print(a)

# %%
x=df[df['DISTRICT']==districts[3]]
print(districts[3])
for z in victim:
    xx=x[x['VICTIM']==z]
    print(z)
    for i in year:
        y=xx[xx['YEAR']==i]
        a=y['TYPE OF ACCIDENT'].value_counts()
        print(i)
        print(a)

# %%
x=df[df['DISTRICT']==districts[4]]
print(districts[4])
for z in victim:
    xx=x[x['VICTIM']==z]
    print(z)
    for i in year:
        y=xx[xx['YEAR']==i]
        a=y['TYPE OF ACCIDENT'].value_counts()
        print(i)
        print(a)

# %%
x=df[df['DISTRICT']==districts[5]]
print(districts[5])
for z in victim:
    xx=x[x['VICTIM']==z]
    print(z)
    for i in year:
        y=xx[xx['YEAR']==i]
        a=y['TYPE OF ACCIDENT'].value_counts()
        print(i)
        print(a)

# %%
x=df[df['DISTRICT']==districts[6]]
print(districts[6])
for z in victim:
    xx=x[x['VICTIM']==z]
    print(z)
    for i in year:
        y=xx[xx['YEAR']==i]
        a=y['TYPE OF ACCIDENT'].value_counts()
        print(i)
        print(a)

# %%
x=df[df['DISTRICT']==districts[7]]
print(districts[7])
for z in victim:
    xx=x[x['VICTIM']==z]
    print(z)
    for i in year:
        y=xx[xx['YEAR']==i]
        a=y['TYPE OF ACCIDENT'].value_counts()
        print(i)
        print(a)

# %%
x=df[df['DISTRICT']==districts[8]]
print(districts[8])
for z in victim:
    xx=x[x['VICTIM']==z]
    print(z)
    for i in year:
        y=xx[xx['YEAR']==i]
        a=y['TYPE OF ACCIDENT'].value_counts()
        print(i)
        print(a)

# %%
x=df[df['DISTRICT']==districts[9]]
print(districts[9])
for z in victim:
    xx=x[x['VICTIM']==z]
    print(z)
    for i in year:
        y=xx[xx['YEAR']==i]
        a=y['TYPE OF ACCIDENT'].value_counts()
        print(i)
        print(a)

# %%
x=df[df['DISTRICT']==districts[10]]
print(districts[10])
for z in victim:
    xx=x[x['VICTIM']==z]
    print(z)
    for i in year:
        y=xx[xx['YEAR']==i]
        a=y['TYPE OF ACCIDENT'].value_counts()
        print(i)
        print(a)

# %%
x=df[df['DISTRICT']==districts[11]]
print(districts[11])
for z in victim:
    xx=x[x['VICTIM']==z]
    print(z)
    for i in year:
        y=xx[xx['YEAR']==i]
        a=y['TYPE OF ACCIDENT'].value_counts()
        print(i)
        print(a)

# %%
vehichle_at_fault=['PVT CAR', 'UNKNOWN', 'S/C&M/C','HTV/GDS']

# %%
x=df[df['DISTRICT']==districts[11]]
print(districts[11])
for z in victim:
    xx=x[x['VICTIM']==z]
    print(z)
    for i in year:
        y=xx[xx['YEAR']==i]
        a=y['TYPE OF ACCIDENT'].value_counts()
        print(i)
        print(a)
