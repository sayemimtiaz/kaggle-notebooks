# %% [markdown]
# # What is about ?
#
# Conversion to h5ad format (anndata class) of various datasets
#
# Versions
#
# 2 Same GSE but from other source - GSE72857 CSV data from KrishnaswamyLab to h5ad - strangely enough it seems cutted version of GEO data file. See for data source and around  https://nbviewer.jupyter.org/github/KrishnaswamyLab/MAGIC/blob/master/python/tutorial_notebooks/bonemarrow_tutorial.ipynb
#
#
# 1 GSE72857 TXT data from GEO to h5ad https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE72857

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import time
t0 = time.time()

fn = '/kaggle/input/scrnaseq-bone-marrow-collection-of-datasets/GSE72857_Paul_Amit_2015_CSVdataFromKrishnaswamyLab/BMMC_myeloid.csv'
df = pd.read_csv(fn, index_col=0)# 'https://github.com/KrishnaswamyLab/PHATE/raw/master/data/BMMC_myeloid.csv.gz')
# , delimiter = '\t'

print(np.round(time.time()-t0,1) , 'seconds passed')

df

# %%
ll = [t.split(';')[0] for t in df.columns]
print(ll[:4])
df_genes = pd.DataFrame(index = ll)
df_genes['Multiple Names'] = list(df.columns)
df_genes

# %%
# !pip install scanpy
import scanpy as sc
import anndata

import scipy 


import time
t0start = time.time()

import pandas as pd
import numpy as np
import os
import sys

# %%
obs = pd.DataFrame(data = df.index , columns = ['Well_ID'])

obs

# %%
adata = anndata.AnnData(X = df.values, var = df_genes, obs = obs  )
adata

# %%
f = 'GSE72857_Mouse_BoneMarrow_Lin-cKit+Sca1-MyeloidProgenitors_Y2015_2730Cells_KrishnaswamyLab_counts_Paul_Amit'
adata.write_h5ad(f+'.h5ad',compression='gzip')
