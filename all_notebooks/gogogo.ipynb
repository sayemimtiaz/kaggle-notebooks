# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# # **Importing libraries**

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, 
import matplotlib.pyplot as plt # this is used for the plot the graph 
import seaborn as sns # used for plot interactive graph.
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split 
from sklearn.naive_bayes import GaussianNB
import pandas_profiling as pp
from sklearn.metrics import accuracy_score

# %% [markdown]
# # **Data**

# %%
data = pd.read_csv('../input/heart-disease-uci/heart.csv')

# %%
data.head()

# %% [markdown]
# # **Preprocessing**

# %%
y = data["target"]
X = data.drop('target',axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state = 3)
                                                                     # 20% test :)

# %% [markdown]
# #  тут дописать 3 строчки в каждом блоке  удачи

# %% [markdown]
# # **RandomForestClassifier**

# %% [markdown]
# привет ты должна написать случайный лес класификатор
# с колличеством 60 деревьев  random_state=12 и максимальной глубиной 5 ))))) удачи
# а конкретно ты должна обучить модель и сделать предсказание код я не стал весь убирать так как это вывод результата  просто убери ######

# %%
#rf_acc_score = accuracy_score(y_test, rf_predicted)
#print("Accuracy of Random Forest:",rf_acc_score*100,'\n')

# %% [markdown]
# # **KNeighborsClassifier**

# %% [markdown]
# привки тута тебе надо нужно реалтзовать это прикол с параметром  7 -количество ближайших соседей (переводи на англ или ищи в документац склерна)
# как и с форестом обучить предсказать

# %%
#KneiCl_acc_score = accuracy_score(y_test, KneiCl_predicted)
#print("Accuracy of K-NeighborsClassifier:",KneiCl_acc_score*100,'\n')
