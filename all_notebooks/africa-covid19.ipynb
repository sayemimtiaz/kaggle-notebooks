# %% [markdown]
# Recently, the WHO Regional Office for Africa was represented at an emergency meeting of the Minsters of Health in the Economic Community of West African States (ECOWAS) on 14 February.  Ministers resolved to strengthen coordination and cooperation among Member States, enhance surveillance measures at points of entry, increase public awareness efforts, and to develop a regional preparedness plan.
#
# The Egyptian Ministry of Health and Population has confirmed the first case of COVID-19 in Africa to the WHO Regional Office for the Eastern Mediterranean.   While so far there have been no confirmed cases reported of the coronavirus disease among the 47 member states in the WHO African Region, fragile health systems and links between China and the African continent mean that the threat posed by this new virus is considerable.
#
# The WHO Regional Office for Africa is supporting Member States prepare for a potential case of COVID-19 in a number of ways.  WHO has dispatched experts to countries believed to be at higher risk of an outbreak of coronavirus to assist in areas including case management, surveillance and early detection.  Across the continent, WHO is working to increase the capacity of national laboratories to detect COVID-19 by supplying reagents, testing equipment and training for staff.  Essential personal protective equipment has also been dispatched by WHO to some countries in Africa.https://www.afro.who.int/health-topics/coronavirus-covid-19

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcR5toh6nFzlspObtWshsPQVvjZ5x_B5YM3ema0IgAdZYzGG1SR9',width=400,height=400)

# %% [markdown]
# trendsmap.com

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import feature_extraction, linear_model, model_selection, preprocessing
import plotly.graph_objs as go
import plotly.offline as py
import plotly.express as px
from plotly.offline import iplot
import plotly.express as px

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
df = pd.read_csv("../input/africa-coronavirus-covid19-cases-dataset/AfricaCovid-9cases.csv")

# %% [markdown]
# #Code from @devonc  https://www.kaggle.com/devonc/coronavirus-covid-19-pandemic-visualizations

# %%
#df.head(n=5)
df.style.background_gradient(subset=['Total cases'], cmap='Blues', axis=None)\
        .background_gradient(subset=['Death'], cmap='Reds', axis=None)\
        .background_gradient(subset=['Total recovered'], cmap='Greens', axis=None)\
        .background_gradient(subset=['Crital conditions'], cmap='PuRd', axis=None)

# %%
df.dtypes

# %% [markdown]
# Check null values with the help of heatmap. Check the less useful columns (yellow color indicates null values) Code from PrashantSri12 https://www.kaggle.com/prashanthsri12/startups-data-eda-basics

# %%
fig,axes = plt.subplots(1,1,figsize=(20,5))
sns.heatmap(df.isna(),yticklabels=False,cbar=False,cmap='viridis')
plt.show()

# %%
df.dropna(how = 'all',inplace = True)
df.drop(['Active cases'],axis=1,inplace = True)
df.shape

# %%
sns.pairplot(df, x_vars=['Total cases'], y_vars='Total recovered', markers="+", size=4)
plt.show()

# %%
df.corr()
plt.figure(figsize=(10,4))
sns.heatmap(df.corr(),annot=True,cmap='RdYlBu')
plt.show()

# %%
fig=sns.jointplot(x='Total cases',y='Total recovered',kind='hex',data=df)

# %% [markdown]
# #codes from Thor God of Thunder

# %%
cat = []
num = []
for col in df.columns:
    if df[col].dtype=='O':
        cat.append(col)
    else:
        num.append(col)  
        
        
num

# %%
plt.style.use('dark_background')
for col in df[num].drop(['Total cases'],axis=1):
    plt.figure(figsize=(8,5))
    plt.plot(df[col].value_counts(),color='Red')
    plt.xlabel(col)
    plt.ylabel('Total recovered')
    plt.tight_layout()
    plt.show()

# %%
for col in df.columns:
    plt.figure(figsize=(18,9))
    sns.barplot(x=col,y='Total cases',data=df)
    sns.pointplot(x=col,y='Total cases',data=df,color='Black')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #Fatih Bilgin codes

# %%
trace1 = go.Box(
    y=df["Total cases"],
    name = 'Total cases',
    marker = dict(color = 'rgb(0,145,119)')
)

trace2 = go.Box(
    y=df["Total recovered"],
    name = 'Total recovered',
    marker = dict(color = 'rgb(5, 79, 174)')
)

data = [trace1, trace2]
layout = dict(autosize=False, width=700,height=500, title='Africa Covid19', paper_bgcolor='rgb(243, 243, 243)', 
              plot_bgcolor='rgb(243, 243, 243)', margin=dict(l=40,r=30,b=80,t=100,))

fig = dict(data=data, layout=layout)
iplot(fig)

# %%
fig = px.histogram(df[df.Death.notna()],x="Death",marginal="box",nbins=10)
fig.update_layout(
    title = "Africa Covid19",
    xaxis_title="Death",
    yaxis_title="Total cases",
    barmode="group",
    bargap=0.1,
    xaxis = dict(
        tickmode = 'linear',
        tick0 = 0,
        dtick = 10),
    font=dict(
        family="Arial, monospace",
        size=15,
        color="#7f7f7f"
    )
    )
py.iplot(fig)

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcS0hMEtNR3ENIyAvpshG1AnSTNHEmUbJk9s45e0gRfuAsZpRxTS',width=400,height=400)

# %% [markdown]
# alerrt.tghn.org

# %% [markdown]
# Kaggle Notebook Runner: Marília Prata   @mpwolke
