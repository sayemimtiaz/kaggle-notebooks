# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/toshihiroryuu/Examples/main/advertising.csv")
df.head(5)

# %%
# identify the size of data frame
print("Size of the data frame is",df.size)

# identify the shape of the data frame 
print("Shape of the data frame is",df.shape)
print("No of Rows = ", df.shape[0])
print("No of Columns = ", df.shape[1])
  
# identify the number of dimensions of your df
print("Dimentions(axis) of the data frame is",df.ndim)

# %% [markdown]
# ## Preprocessing

# %%
df = df.drop(['Unnamed: 0'], axis=1)
df = df.drop(['Unnamed: 0.1'], axis=1)
df.head()

# %% [markdown]
# ## Hnadle Missing Values

# %%
import missingno as msno

missing_bar  = msno.bar(df, figsize=(12, 6), fontsize=12, color='steelblue')

print(missing_bar)

# %%
miss_count = df.isnull().sum().sum()

print("No of missing values is",miss_count)

# %% [markdown]
# No missing values in this dataset.

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn-whitegrid')

plt.title("TV vs Sales")
plt.xlabel('TV')
plt.ylabel('Sales')

plt.scatter("TV", "Sales", data = df, c='orange')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn-whitegrid')

plt.title("Radio vs Sales")
plt.xlabel('Radio')
plt.ylabel('Sales')

plt.scatter("Radio", "Sales", data = df, color = "magenta")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn-whitegrid')

plt.title("Newspaper vs Sales")
plt.xlabel('Newspaper')
plt.ylabel('Sales')

plt.scatter("Newspaper", "Sales", data = df, color = "green")
plt.show()

# %%
import seaborn as sns

print(sns.pairplot(df))

# %% [markdown]
# ## (a)  Assess the correlation between each and sales.

# %%
corr = df.corr()
corr

# %%
sns.set()
fig, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(df.corr(), linewidths=.5, ax=ax, cmap='Blues')
plt.show()

# %% [markdown]
# #### Sales depend on TV, Radio and Newspaper.
# #### TV has a strong positive correlation with sales.
# #### Radio has medium positive correlation with sales.
# #### Newspaper has lesser positive correlation with sales.

# %% [markdown]
# ### That is, TV, Radio, Newspaper has hight correlation(dependence) with sales.

# %% [markdown]
# ## (b) Employ Simple Linear Regression to analyse the effect of each of them on sales.

# %% [markdown]
# #### Linear Regression Model with 'TV','Radio','Newspaper' as data points and Sales as Target variable.

# %%
from sklearn.model_selection import train_test_split

x = df[['TV','Radio','Newspaper']]
y = df['Sales']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 40)

# %%
print("Training dataset X shape:", x_train.shape)
print("Training dataset Y shape:",y_train.shape)
print("Testing dataset X shape:",x_test.shape)
print("Testing dataset Y shape:",y_test.shape)

# %%
from sklearn.linear_model import LinearRegression

linear = LinearRegression()
linear.fit(x_train, y_train)

# %%
score = []

from sklearn.metrics import r2_score

y_predict = linear.predict(x_test)
score0 = r2_score(y_test, y_predict)
score.append(score0)
score0

# %%
print("The linear model is: Y = ",linear.intercept_, "+", linear.coef_[0], "X1 + ", linear.coef_[1], "X2 + ", linear.coef_[2], "X3")

# %% [markdown]
# ### Linear Model with TV vs Sales

# %%
from sklearn.model_selection import train_test_split

x = df[['TV']]
y = df['Sales']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 40)

# %%
print("Training dataset X shape:", x_train.shape)
print("Training dataset Y shape:",y_train.shape)
print("Testing dataset X shape:",x_test.shape)
print("Testing dataset Y shape:",y_test.shape)

# %%
from sklearn.linear_model import LinearRegression

linear1 = LinearRegression()
linear1.fit(x_train, y_train)

# %%
from sklearn.metrics import r2_score

y_predict = linear1.predict(x_test)
score1 = r2_score(y_test, y_predict)
score.append(score1)
score1

# %% [markdown]
# #### Scatter Plot TV vs Sales

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn-whitegrid')

plt.title("TV vs Sales")
plt.xlabel('TV')
plt.ylabel('Sales')

plt.scatter("TV", "Sales", data = df, c='orange')
plt.show()

# %% [markdown]
# #### Regression Line TV vs Sales

# %%
print("The linear model is: Y = ",linear1.intercept_, "+", linear1.coef_[0], "X ")

# %%
predictions = linear1.predict(x)

plt.scatter(df['TV'], df['Sales'], c='orange')
plt.plot(df['TV'], predictions,  c='blue', linewidth=2)
plt.xlabel("TV")
plt.ylabel("Sales")
plt.show()

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 

sns.residplot(x = "TV", 
              y = "Sales", 
              data = df, 
              lowess = True) 
  
plt.show()

# %%
from sklearn.metrics import r2_score
import statsmodels.api as sm

x = df['TV']
y = df['Sales']

x2 = sm.add_constant(x)

est = sm.OLS(y, x2)

est2 = est.fit()
print(est2.summary())

# %% [markdown]
# P value is very low. This means that there is a strong correlation between these coefficients and the target.

# %% [markdown]
# The R² value is 0.612. Therefore, about 61.2% of the variability of Sales is explained by the TV advertisement. This is a satisfactory result for prediction.

# %% [markdown]
# ### Linear Model with Radio vs Sales

# %%
from sklearn.model_selection import train_test_split

x = df[['Radio']]
y = df['Sales']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 40)

# %%
print("Training dataset X shape:", x_train.shape)
print("Training dataset Y shape:",y_train.shape)
print("Testing dataset X shape:",x_test.shape)
print("Testing dataset Y shape:",y_test.shape)

# %%
from sklearn.linear_model import LinearRegression

linear2 = LinearRegression()
linear2.fit(x_train, y_train)

# %%
from sklearn.metrics import r2_score

y_predict = linear2.predict(x_test)
score2 = r2_score(y_test, y_predict)
score.append(score2)
score2

# %% [markdown]
# #### Scatter Plot Radio vs Sales

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn-whitegrid')

plt.title("Radio vs Sales")
plt.xlabel('Radio')
plt.ylabel('Sales')

plt.scatter("Radio", "Sales", data = df, color = "magenta")
plt.show()

# %% [markdown]
# #### Regression Line Radio vs Sales

# %%
print("The linear model is: Y = ",linear1.intercept_, "+", linear1.coef_[0], "X ")

# %%
predictions = linear1.predict(x)

plt.scatter(df['Radio'], df['Sales'], c='magenta')
plt.plot(df['Radio'], predictions,  c='blue', linewidth=2)
plt.xlabel("Radio")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# The regression line fails fit the data points perfectly.

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 

sns.residplot(x = "Radio", 
              y = "Sales", 
              data = df, 
              lowess = True) 
  
plt.show()

# %%
from sklearn.metrics import r2_score
import statsmodels.api as sm

x = df['Radio']
y = df['Sales']

x2 = sm.add_constant(x)

est = sm.OLS(y, x2)

est2 = est.fit()
print(est2.summary())

# %% [markdown]
# P value is very low. This means that there is a strong correlation between these coefficients and the target.

# %% [markdown]
# The R² value is 0.332. Therefore, about 33.2% of the variability of Sales is explained by the radio advertisement. This is definitely not a satisfactory result for prediction.

# %% [markdown]
# ### Linear Model with Newspaper vs Sales

# %%
from sklearn.model_selection import train_test_split

x = df[['Newspaper']]
y = df['Sales']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 40)

# %%
print("Training dataset X shape:", x_train.shape)
print("Training dataset Y shape:",y_train.shape)
print("Testing dataset X shape:",x_test.shape)
print("Testing dataset Y shape:",y_test.shape)

# %%
from sklearn.linear_model import LinearRegression

linear3 = LinearRegression()
linear3.fit(x_train, y_train)

# %%
from sklearn.metrics import r2_score

y_predict = linear3.predict(x_test)
score3 = r2_score(y_test, y_predict)
score.append(score3)
score3

# %% [markdown]
# #### Scatter Plot Newspaper vs Sales

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn-whitegrid')

plt.title("Newspaper vs Sales")
plt.xlabel('Newspaper')
plt.ylabel('Sales')

plt.scatter("Newspaper", "Sales", data = df, color = "green")
plt.show()

# %% [markdown]
# #### Regression Line Newspaper vs Sales

# %%
print("The linear model is: Y = ",linear1.intercept_, "+", linear1.coef_[0], "X ")

# %%
predictions = linear1.predict(x)

plt.scatter(df['Newspaper'], df['Sales'], c='green')
plt.plot(df['Newspaper'], predictions,  c='blue', linewidth=2)
plt.xlabel("Newspaper")
plt.ylabel("Sales")
plt.show()

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 

sns.residplot(x = "Newspaper", 
              y = "Sales", 
              data = df, 
              lowess = True) 
  
plt.show()

# %% [markdown]
# The regression line fails to fit the data points correctly.

# %%
from sklearn.metrics import r2_score
import statsmodels.api as sm

x = df['Newspaper']
y = df['Sales']

x2 = sm.add_constant(x)

est = sm.OLS(y, x2)

est2 = est.fit()
print(est2.summary())

# %% [markdown]
# P value is very low. This means that there is a strong correlation between these coefficients and the target.

# %% [markdown]
# The R² value is 0.052. Therefore, about 5.20% of the variability of Sales is explained by the Newspaper advertisement. This is definitely NOT a satisfactory result for prediction.

# %% [markdown]
# ## R2 SCORE COMPARISON

# %%
listt = ["TV + Radio + Newspaper", "TV", "Radio", "Newspaper"]
plt.bar(listt, score)
plt.title("Models VS R2 Score")
plt.xlabel("Models")
plt.ylabel("R2 Score")
plt.show()

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# 1. TV, Newspaper and radio advertising affect the target variable Sales. The order of correlation with sales given by TV AdV> Radio Adv> Newspaper Adv.
# 2. The linear model created with TV, Newspaper and radio as input varaible and Sales as Target variable gave the higher r2score.
# 3. The linear model created with TV as input varaible and Sales as Target variable gave the second highest r2score.
# 4. The linear models created with Radio and Newspapaer as input varaibles and Sales as Target variable has very less r2 score.
# 5. Therefore inorder to create a suitable model which approxiamates the scenario correctly, we need to use the combination of TV, Radio and Newspapaer as target variable.
# 6. It is clear from the model and correlation matrix that Amount spend on TV ads direclty impact the Sales of a particular product.
# 7. we can conclude from the R2 value that only input variable TV advertsisements provides a satisfactory result.
