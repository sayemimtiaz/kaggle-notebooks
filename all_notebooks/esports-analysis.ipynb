# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from sklearn.linear_model import LinearRegression
# %matplotlib inline
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
Highest_Earning_Players = pd.read_csv ('../input/esports-earnings-for-players-teams-by-game/highest_earning_players.csv')
Highest_Earning_Teams = pd.read_csv ('../input/esports-earnings-for-players-teams-by-game/highest_earning_teams.csv')
Country_Codes = pd.read_csv ('../input/esports-earnings-for-players-teams-by-game/country-and-continent-codes-list.csv')

# %%
print(Highest_Earning_Players.dtypes)

#Checking to make sure the data has proper types for analyzing later

# %%
print(Highest_Earning_Players.columns)

#Making sure the index names are properly spelled capitalized etc.

# %%
print(Highest_Earning_Teams.dtypes)

#Checking to make sure the data has proper types for analyzing later

# %%
print(Highest_Earning_Teams.columns)

#Making sure the index names are properly spelled capitalized etc.

# %% [markdown]
# ***Highest Earning Players***

# %%
Highest_Earning_Players.head(11)

#Taking a first glance at what kind of data I will be dealing with.

# %%
Highest_Earning_Players.describe()

#Looking at base numeric data values to get a good inference on what outcome to expect from the numbers

# %%
Highest_Earning_Players.nlargest(10, 'TotalUSDPrize')

#Sorted by revenue made. These are the top 10 players.

# %%
plt.figure (figsize = (15, 15))

sns.barplot (x = Highest_Earning_Players ["CountryCode"], y = Highest_Earning_Players ['TotalUSDPrize'])

#Highest earning for players by country

# %%
plt.figure (figsize = (20, 10))

Genre_Prize_Players = sns.barplot (x = Highest_Earning_Players ['Genre'], y = Highest_Earning_Players ['TotalUSDPrize'])

#Highest Earning Geanre by Players

# %% [markdown]
# ***Highest Earning Teams***

# %%
Highest_Earning_Teams.head(11)

#Taking a first glance at what kind of data I will be dealing with.

# %%
Highest_Earning_Teams.describe()

#Looking at base numeric data values to get a good inference on what outcome to expect from the numbers

# %%
plt.figure (figsize = (15,15))

sns.barplot (x = Highest_Earning_Teams['Genre'], y = Highest_Earning_Teams ['TotalUSDPrize'])

#Highest Earning genre by Total USD Prize for teams

# %%
plt.figure (figsize = (20,10))

Game_Tournaments = sns.barplot (x = Highest_Earning_Teams ['Game'], y = Highest_Earning_Teams ['TotalTournaments'])

#Most tournaments played by GAME

# %% [markdown]
# ***QUESTIONS***

# %% [markdown]
# ***Who are the top 10 players? Where are they from?:***
# 1. JerAx from fi
#
# 2. Topson from fi
#
# 3. Matumbaman from fi
#
# 4. N0tail from dk
#
# 5. ana from au
#
# 6. Ceb from fr
#
# 7. KuroKy from de
#
# 8. Miracle- from jo
#
# 9. MinD_ContRoL from bg
#
# 10. GH from lb
#
#
#
# ****Which country or continent has most player earnings?****
# 1. lb
# 2. pk
# 3. jo
# 4. ee
# 5. au
#
#
# ****What is the proportion of earnings per genre for the top 10 games in terms of both teams and players?****
# 1. For PLAYERS it is moba games that give quite a big portion of revenue.
# 2. For TEAMS Strategy games seem to be the highest earning genre
#
# ****Which game is most popular in terms of number of tournaments?****
# 1. Starcraft II exceedingly has more tournament plays than other games
