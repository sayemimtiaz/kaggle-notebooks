# %%
import numpy as np 
import pandas as pd 
import os


paths = []
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        dr = '..'+dirname[7:]
        paths.append(os.path.join(dr, filename))
paths

# %% [markdown]
# ### Reading the Data

# %%
import chardet

texts = []
encodes = []
for i, path in enumerate(paths,1):
    file = open(path, 'rb')
    encodes.append(chardet.detect(file.read(50000)))
    texts.append(file.read())
    

print(encodes)

# %% [markdown]
# ### Creating a function

# %%
def ch_enc(paths, n_char=20000):
    import chardet
    import re
    texts = []
    results = {}
    for path in paths:
        name = os.path.basename(path)
        file = open(path, 'rb')
        enc_info = chardet.detect(file.read(n_char))
        enc_info['bytes'] = file
        results[name] = enc_info
    return results

# %%
ch_enc(paths=paths)
