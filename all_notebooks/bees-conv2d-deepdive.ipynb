# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
IMAGE_NAME = '../input/beeslittledataset/antproblems/013_008.png'

# %%
image = plt.imread(IMAGE_NAME)

# %%
image.shape

# %%
image[:,:,0].shape

# %%
image_1_channel = image[:,:,0]

# %%
plt.imshow(image_1_channel)

# %%
image_1_channel_10pix = image[:10,:10,0]

# %%
plt.imshow(image_1_channel_10pix)

# %%
image_1_channel_10pix.shape

# %%
image_1_channel_10pix

# %%
m = nn.Conv2d(in_channels = 1, out_channels = 1, kernel_size = 2, stride=1)

# %%
m.weight , m.bias

# %%
image_1_channel_10pix[np.newaxis,np.newaxis,...]

# %%
output = m(torch.tensor(image_1_channel_10pix[np.newaxis,np.newaxis,...]))

# %% [markdown]
# # 1st position

# %%
output[0][0][0][0]

# %%
image_1_channel_10pix[:2,:2]

# %%
a = image_1_channel_10pix[0][0]
b = image_1_channel_10pix[0][1]
c = image_1_channel_10pix[1][0]
d = image_1_channel_10pix[1][1]
print(a,b,c,d)

# %%
m.weight.shape

# %%
w0 = m.weight[0][0][0][0]
w1 = m.weight[0][0][0][1]
w2 = m.weight[0][0][1][0]
w3 = m.weight[0][0][1][1]
bias = m.bias

# %%
(a*w0 + b*w1 + c*w2 + d*w3 + bias).detach().numpy() , output[0][0][0][0].detach().numpy()

# %% [markdown]
# # 2nd position

# %%
a = image_1_channel_10pix[0][1]
b = image_1_channel_10pix[0][2]
c = image_1_channel_10pix[1][1]
d = image_1_channel_10pix[1][2]
print(a,b,c,d)

# %%
(a*w0 + b*w1 + c*w2 + d*w3 + bias).detach().numpy() , output[0][0][0][1].detach().numpy()

# %% [markdown]
# # 3rd position

# %%
a = image_1_channel_10pix[0][2]
b = image_1_channel_10pix[0][3]
c = image_1_channel_10pix[1][2]
d = image_1_channel_10pix[1][3]
print(a,b,c,d)

# %%
(a*w0 + b*w1 + c*w2 + d*w3 + bias).detach().numpy() , output[0][0][0][2].detach().numpy()
