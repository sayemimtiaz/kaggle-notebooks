# %%
import pandas as pd
import numpy as np
import seaborn as sbn
import matplotlib.pyplot as plt
import missingno as msno
veri = pd.read_csv("../input/calories-burned-during-exercise-and-activities/exercise_dataset.csv")

# %%
veri.describe()

# %%
veri.corr()

# %%
veri.info()

# %%
veri["Activity, Exercise or Sport (1 hour)"].unique().shape

# %%
sbn.countplot(veri["Activity, Exercise or Sport (1 hour)"]);
sbn.despine(bottom=True,left=True);

# %%
veeri = veri.sort_values("Calories per kg",ascending=False);
plt.subplots(figsize=(20,10))
sbn.barplot(x=veeri["Activity, Exercise or Sport (1 hour)"],y=veeri["Calories per kg"]);
sbn.despine(bottom=True,left=True);
plt.xticks(rotation=90);
