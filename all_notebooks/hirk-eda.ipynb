# %% [markdown]
# # Data Analysis on Alpine Trails

# %% [markdown]
# ## About the mountains
#
# ### Schuhflicker
# Schuhflicker is a mountain in Austria, with an elevation of 2199 metres (7215 ft) and a prominence of 203 metres (666 ft) in the Ankogel Group.
#
# ### Remsteinkopf
#
# ### Cima d'Erbea
# Cima d'Erbea Occidentale is a mountain in Switzerland, with an elevation of 2329 metres (7641 ft) and a prominence of 59 metres (194 ft) in the Tessiner Alpen.
#
# ### Gaggio
# Gaggio is a 317 m less popular blue singletrack trail located near Rocca di Papa. This mountain bike primary trail can be used downhill primary and has a moderate overall physical rating. On average it takes 2 minutes to complete this trail.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('../input/gpx-hike-tracks/gpx-tracks-from-hikr.org.csv')
df.head()

# %%
df.shape

# %%
df['name'].unique()
