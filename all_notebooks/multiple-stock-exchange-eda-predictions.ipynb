# %%
import math
import pandas_datareader as web
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
import plotly.graph_objects as go
plt.style.use ('fivethirtyeight')
import plotly.express as px

# %%
df = pd.read_csv('../input/stock-exchange-data/indexData.csv')
df = df.set_index('Date')
df

# %%
df = df.dropna()
df.Index.unique()

# %%
index = df.groupby(df.Index)
NYA = index.get_group("NYA")
IXIC = index.get_group("IXIC")
HSI = index.get_group("HSI")
SS = index.get_group("000001.SS")
GSPTSE = index.get_group("GSPTSE")
SZ = index.get_group("399001.SZ")
NSEI = index.get_group("NSEI")
GDAXI = index.get_group("GDAXI")
KS11 = index.get_group("KS11")
SSMI = index.get_group("SSMI")
TWII = index.get_group("TWII")
J203_JO = index.get_group("J203.JO")
N225 = index.get_group("N225")
N100 = index.get_group("N100")

# %%
data1 = NYA.filter(['Close'])
dataset1 = data1.values
training_data_len1 = math.ceil(len(dataset1) * .8)

data2 = IXIC.filter(['Close'])
dataset2 = data2.values
training_data_len2 = math.ceil(len(dataset2) * .8)

data3 = HSI.filter(['Close'])
dataset3 = data3.values
training_data_len3 = math.ceil(len(dataset3) * .8)

data4 = SS.filter(['Close'])
dataset4 = data4.values
training_data_len4 = math.ceil(len(dataset4) * .8)

data5 = GSPTSE.filter(['Close'])
dataset5 = data5.values
training_data_len5 = math.ceil(len(dataset5) * .8)

data6 = SZ.filter(['Close'])
dataset6 = data6.values
training_data_len6 = math.ceil(len(dataset6) * .8)

data7 = NSEI.filter(['Close'])
dataset7 = data7.values
training_data_len7 = math.ceil(len(dataset7) * .8)

data8 = GDAXI.filter(['Close'])
dataset8 = data8.values
training_data_len8 = math.ceil(len(dataset8) * .8)

data9 = KS11.filter(['Close'])
dataset9 = data9.values
training_data_len9 = math.ceil(len(dataset9) * .8)

data10 = SSMI.filter(['Close'])
dataset10 = data10.values
training_data_len10 = math.ceil(len(dataset10) * .8)

data11 = TWII.filter(['Close'])
dataset11 = data11.values
training_data_len11 = math.ceil(len(dataset11) * .8)

data12 = J203_JO.filter(['Close'])
dataset12 = data12.values
training_data_len12 = math.ceil(len(dataset12) * .8)

data13 = N225.filter(['Close'])
dataset13 = data13.values
training_data_len13 = math.ceil(len(dataset13) * .8)

data14 = N100.filter(['Close'])
dataset14 = data14.values
training_data_len14 = math.ceil(len(dataset14) * .8)

# %%
scaler1 = MinMaxScaler(feature_range=(0,1))
scaled_data1 = scaler1.fit_transform(dataset1)
scaler2 = MinMaxScaler(feature_range=(0,1))
scaled_data2 = scaler2.fit_transform(dataset2)
scaler3 = MinMaxScaler(feature_range=(0,1))
scaled_data3 = scaler3.fit_transform(dataset3)
scaler4 = MinMaxScaler(feature_range=(0,1))
scaled_data4 = scaler4.fit_transform(dataset4)
scaler5 = MinMaxScaler(feature_range=(0,1))
scaled_data5 = scaler5.fit_transform(dataset5)
scaler6 = MinMaxScaler(feature_range=(0,1))
scaled_data6 = scaler6.fit_transform(dataset6)
scaler7 = MinMaxScaler(feature_range=(0,1))
scaled_data7 = scaler7.fit_transform(dataset7)
scaler8 = MinMaxScaler(feature_range=(0,1))
scaled_data8 = scaler8.fit_transform(dataset8)
scaler9 = MinMaxScaler(feature_range=(0,1))
scaled_data9 = scaler9.fit_transform(dataset9)
scaler10 = MinMaxScaler(feature_range=(0,1))
scaled_data10 = scaler10.fit_transform(dataset10)
scaler11 = MinMaxScaler(feature_range=(0,1))
scaled_data11 = scaler11.fit_transform(dataset11)
scaler12 = MinMaxScaler(feature_range=(0,1))
scaled_data12 = scaler12.fit_transform(dataset12)
scaler13 = MinMaxScaler(feature_range=(0,1))
scaled_data13 = scaler13.fit_transform(dataset13)
scaler14 = MinMaxScaler(feature_range=(0,1))
scaled_data14 = scaler14.fit_transform(dataset14)

# %%
train_data1 = scaled_data1[0:training_data_len1, :]
train_data2 = scaled_data2[0:training_data_len2, :]
train_data3 = scaled_data3[0:training_data_len3, :]
train_data4 = scaled_data4[0:training_data_len4, :]
train_data5 = scaled_data5[0:training_data_len5, :]
train_data6 = scaled_data6[0:training_data_len6, :]
train_data7 = scaled_data7[0:training_data_len7, :]
train_data8 = scaled_data8[0:training_data_len8, :]
train_data9 = scaled_data9[0:training_data_len9, :]
train_data10 = scaled_data10[0:training_data_len10, :]
train_data11 = scaled_data11[0:training_data_len11, :]
train_data12 = scaled_data12[0:training_data_len12, :]
train_data13 = scaled_data13[0:training_data_len13, :]
train_data14 = scaled_data14[0:training_data_len14, :]

x_train1 = []
y_train1 = []
x_train2 = []
y_train2 = []
x_train3 = []
y_train3 = []
x_train4 = []
y_train4 = []
x_train5 = []
y_train5 = []
x_train6 = []
y_train6 = []
x_train7 = []
y_train7 = []
x_train8 = []
y_train8 = []
x_train9 = []
y_train9 = []
x_train10 = []
y_train10 = []
x_train11 = []
y_train11 = []
x_train12 = []
y_train12 = []
x_train13 = []
y_train13 = []
x_train14 = []
y_train14 = []

for i in range(60, len(train_data1)):
    x_train1.append(train_data1[i-60:i, 0])
    y_train1.append(train_data1[i, 0])
    if i <= 61:
        print(x_train1)
        print(y_train1)
        print()
        
for i in range(60, len(train_data2)):
    x_train2.append(train_data2[i-60:i, 0])
    y_train2.append(train_data2[i, 0])
    if i <= 61:
        print(x_train2)
        print(y_train2)
        print()
        
for i in range(60, len(train_data3)):
    x_train3.append(train_data3[i-60:i, 0])
    y_train3.append(train_data3[i, 0])
    if i <= 61:
        print(x_train3)
        print(y_train3)
        print()
        
for i in range(60, len(train_data4)):
    x_train4.append(train_data4[i-60:i, 0])
    y_train4.append(train_data4[i, 0])
    if i <= 61:
        print(x_train4)
        print(y_train4)
        print()
        
for i in range(60, len(train_data5)):
    x_train5.append(train_data5[i-60:i, 0])
    y_train5.append(train_data5[i, 0])
    if i <= 61:
        print(x_train5)
        print(y_train5)
        print()
        
for i in range(60, len(train_data6)):
    x_train6.append(train_data6[i-60:i, 0])
    y_train6.append(train_data6[i, 0])
    if i <= 61:
        print(x_train6)
        print(y_train6)
        print()
        
for i in range(60, len(train_data7)):
    x_train7.append(train_data7[i-60:i, 0])
    y_train7.append(train_data7[i, 0])
    if i <= 61:
        print(x_train7)
        print(y_train7)
        print()
        
for i in range(60, len(train_data8)):
    x_train8.append(train_data8[i-60:i, 0])
    y_train8.append(train_data8[i, 0])
    if i <= 61:
        print(x_train8)
        print(y_train8)
        print()
        
for i in range(60, len(train_data9)):
    x_train9.append(train_data9[i-60:i, 0])
    y_train9.append(train_data9[i, 0])
    if i <= 61:
        print(x_train9)
        print(y_train9)
        print()
        
for i in range(60, len(train_data10)):
    x_train10.append(train_data10[i-60:i, 0])
    y_train10.append(train_data10[i, 0])
    if i <= 61:
        print(x_train10)
        print(y_train10)
        print()
        
for i in range(60, len(train_data11)):
    x_train11.append(train_data11[i-60:i, 0])
    y_train11.append(train_data11[i, 0])
    if i <= 61:
        print(x_train11)
        print(y_train11)
        print()
        
for i in range(60, len(train_data12)):
    x_train12.append(train_data12[i-60:i, 0])
    y_train12.append(train_data12[i, 0])
    if i <= 61:
        print(x_train12)
        print(y_train12)
        print()
        
for i in range(60, len(train_data13)):
    x_train13.append(train_data13[i-60:i, 0])
    y_train13.append(train_data13[i, 0])
    if i <= 61:
        print(x_train13)
        print(y_train13)
        print()
        
for i in range(60, len(train_data14)):
    x_train14.append(train_data14[i-60:i, 0])
    y_train14.append(train_data14[i, 0])
    if i <= 61:
        print(x_train14)
        print(y_train14)
        print()

# %%
x_train1, y_train1 = np.array(x_train1), np.array(y_train1)
x_train1 = np.reshape(x_train1, (x_train1.shape[0], x_train1.shape[1], 1))

x_train2, y_train2 = np.array(x_train2), np.array(y_train2)
x_train2 = np.reshape(x_train2, (x_train2.shape[0], x_train2.shape[1], 1))

x_train3, y_train3 = np.array(x_train3), np.array(y_train3)
x_train3 = np.reshape(x_train3, (x_train3.shape[0], x_train3.shape[1], 1))

x_train4, y_train4 = np.array(x_train4), np.array(y_train4)
x_train4 = np.reshape(x_train4, (x_train4.shape[0], x_train4.shape[1], 1))

x_train5, y_train5 = np.array(x_train5), np.array(y_train5)
x_train5 = np.reshape(x_train5, (x_train5.shape[0], x_train5.shape[1], 1))

x_train6, y_train6 = np.array(x_train6), np.array(y_train6)
x_train6 = np.reshape(x_train6, (x_train6.shape[0], x_train6.shape[1], 1))

x_train7, y_train7 = np.array(x_train7), np.array(y_train7)
x_train7 = np.reshape(x_train7, (x_train7.shape[0], x_train7.shape[1], 1))

x_train8, y_train8 = np.array(x_train8), np.array(y_train8)
x_train8 = np.reshape(x_train8, (x_train8.shape[0], x_train8.shape[1], 1))

x_train9, y_train9 = np.array(x_train9), np.array(y_train9)
x_train9 = np.reshape(x_train9, (x_train9.shape[0], x_train9.shape[1], 1))

x_train10, y_train10 = np.array(x_train10), np.array(y_train10)
x_train10 = np.reshape(x_train10, (x_train10.shape[0], x_train10.shape[1], 1))

x_train11, y_train11 = np.array(x_train11), np.array(y_train11)
x_train11 = np.reshape(x_train11, (x_train11.shape[0], x_train11.shape[1], 1))

x_train12, y_train12 = np.array(x_train12), np.array(y_train12)
x_train12 = np.reshape(x_train12, (x_train12.shape[0], x_train12.shape[1], 1))

x_train13, y_train13 = np.array(x_train13), np.array(y_train13)
x_train13 = np.reshape(x_train13, (x_train13.shape[0], x_train13.shape[1], 1))

x_train14, y_train14 = np.array(x_train14), np.array(y_train14)
x_train14 = np.reshape(x_train14, (x_train14.shape[0], x_train14.shape[1], 1))

# %%
model1 = Sequential()
model1.add(LSTM(50, return_sequences = True, input_shape = (x_train1.shape[1], 1)))
model1.add(LSTM(50, return_sequences = False))
model1.add(Dense(25))
model1.add(Dense(1))
model1.compile(optimizer = 'adam', loss = 'mean_squared_error')
model1.fit(x_train1, y_train1, batch_size = 1, epochs = 1)

# %%
model2 = Sequential()
model2.add(LSTM(50, return_sequences = True, input_shape = (x_train2.shape[1], 1)))
model2.add(LSTM(50, return_sequences = False))
model2.add(Dense(25))
model2.add(Dense(1))
model2.compile(optimizer = 'adam', loss = 'mean_squared_error')
model2.fit(x_train2, y_train2, batch_size = 1, epochs = 1)

# %%
model3 = Sequential()
model3.add(LSTM(50, return_sequences = True, input_shape = (x_train3.shape[1], 1)))
model3.add(LSTM(50, return_sequences = False))
model3.add(Dense(25))
model3.add(Dense(1))
model3.compile(optimizer = 'adam', loss = 'mean_squared_error')
model3.fit(x_train3, y_train3, batch_size = 1, epochs = 1)

# %%
model4 = Sequential()
model4.add(LSTM(50, return_sequences = True, input_shape = (x_train4.shape[1], 1)))
model4.add(LSTM(50, return_sequences = False))
model4.add(Dense(25))
model4.add(Dense(1))
model4.compile(optimizer = 'adam', loss = 'mean_squared_error')
model4.fit(x_train4, y_train4, batch_size = 1, epochs = 1)

# %%
model5 = Sequential()
model5.add(LSTM(50, return_sequences = True, input_shape = (x_train5.shape[1], 1)))
model5.add(LSTM(50, return_sequences = False))
model5.add(Dense(25))
model5.add(Dense(1))
model5.compile(optimizer = 'adam', loss = 'mean_squared_error')
model5.fit(x_train5, y_train5, batch_size = 1, epochs = 1)

# %%
model6 = Sequential()
model6.add(LSTM(50, return_sequences = True, input_shape = (x_train6.shape[1], 1)))
model6.add(LSTM(50, return_sequences = False))
model6.add(Dense(25))
model6.add(Dense(1))
model6.compile(optimizer = 'adam', loss = 'mean_squared_error')
model6.fit(x_train6, y_train6, batch_size = 1, epochs = 1)

# %%
model7 = Sequential()
model7.add(LSTM(50, return_sequences = True, input_shape = (x_train7.shape[1], 1)))
model7.add(LSTM(50, return_sequences = False))
model7.add(Dense(25))
model7.add(Dense(1))
model7.compile(optimizer = 'adam', loss = 'mean_squared_error')
model7.fit(x_train7, y_train7, batch_size = 1, epochs = 1)

# %%
model8 = Sequential()
model8.add(LSTM(50, return_sequences = True, input_shape = (x_train8.shape[1], 1)))
model8.add(LSTM(50, return_sequences = False))
model8.add(Dense(25))
model8.add(Dense(1))
model8.compile(optimizer = 'adam', loss = 'mean_squared_error')
model8.fit(x_train8, y_train8, batch_size = 1, epochs = 1)

# %%
model9 = Sequential()
model9.add(LSTM(50, return_sequences = True, input_shape = (x_train9.shape[1], 1)))
model9.add(LSTM(50, return_sequences = False))
model9.add(Dense(25))
model9.add(Dense(1))
model9.compile(optimizer = 'adam', loss = 'mean_squared_error')
model9.fit(x_train9, y_train9, batch_size = 1, epochs = 1)

# %%
model10 = Sequential()
model10.add(LSTM(50, return_sequences = True, input_shape = (x_train10.shape[1], 1)))
model10.add(LSTM(50, return_sequences = False))
model10.add(Dense(25))
model10.add(Dense(1))
model10.compile(optimizer = 'adam', loss = 'mean_squared_error')
model10.fit(x_train10, y_train10, batch_size = 1, epochs = 1)

# %%
model11 = Sequential()
model11.add(LSTM(50, return_sequences = True, input_shape = (x_train11.shape[1], 1)))
model11.add(LSTM(50, return_sequences = False))
model11.add(Dense(25))
model11.add(Dense(1))
model11.compile(optimizer = 'adam', loss = 'mean_squared_error')
model11.fit(x_train11, y_train11, batch_size = 1, epochs = 1)

# %%
model12 = Sequential()
model12.add(LSTM(50, return_sequences = True, input_shape = (x_train12.shape[1], 1)))
model12.add(LSTM(50, return_sequences = False))
model12.add(Dense(25))
model12.add(Dense(1))
model12.compile(optimizer = 'adam', loss = 'mean_squared_error')
model12.fit(x_train12, y_train12, batch_size = 1, epochs = 1)

# %%
model13 = Sequential()
model13.add(LSTM(50, return_sequences = True, input_shape = (x_train13.shape[1], 1)))
model13.add(LSTM(50, return_sequences = False))
model13.add(Dense(25))
model13.add(Dense(1))
model13.compile(optimizer = 'adam', loss = 'mean_squared_error')
model13.fit(x_train13, y_train13, batch_size = 1, epochs = 1)

# %%
model14 = Sequential()
model14.add(LSTM(50, return_sequences = True, input_shape = (x_train14.shape[1], 1)))
model14.add(LSTM(50, return_sequences = False))
model14.add(Dense(25))
model14.add(Dense(1))
model14.compile(optimizer = 'adam', loss = 'mean_squared_error')
model14.fit(x_train14, y_train14, batch_size = 1, epochs = 1)

# %%
print("Click on the bottom right menu to show or hide the legend lines")

fig = go.Figure()
fig.add_trace(go.Scatter(x = NYA.index, y = NYA.High,
                    mode='lines',
                    name='High',
                    marker_color = '#2CA02C',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = NYA.index, y = NYA.Low,
                    mode='lines',
                    name='Low',
                    marker_color = '#D62728',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = NYA.index, y = NYA.Open,
                    mode='lines',
                    name='Open',
                    marker_color = '#FF7F0E',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = NYA.index, y = NYA.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))

fig.update_layout(
    title='1. Price history of New York Stock Exchange',
    titlefont_size = 28,
    
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Price in USD ($)',
        titlefont_size=16,
        tickfont_size=14),
    
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
print("Click on the bottom right menu to show or hide the legend lines")

fig = go.Figure()
fig.add_trace(go.Scatter(x = IXIC.index, y = IXIC.High,
                    mode='lines',
                    name='High',
                    marker_color = '#2CA02C',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = IXIC.index, y = IXIC.Low,
                    mode='lines',
                    name='Low',
                    marker_color = '#D62728',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = IXIC.index, y = IXIC.Open,
                    mode='lines',
                    name='Open',
                    marker_color = '#FF7F0E',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = IXIC.index, y = IXIC.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))

fig.update_layout(
    title='2. Price history of NASDAQ',
    titlefont_size = 28,
    
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Price in USD ($)',
        titlefont_size=16,
        tickfont_size=14),
    
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
print("Click on the bottom right menu to show or hide the legend lines")

fig = go.Figure()
fig.add_trace(go.Scatter(x = HSI.index, y = HSI.High,
                    mode='lines',
                    name='High',
                    marker_color = '#2CA02C',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = HSI.index, y = HSI.Low,
                    mode='lines',
                    name='Low',
                    marker_color = '#D62728',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = HSI.index, y = HSI.Open,
                    mode='lines',
                    name='Open',
                    marker_color = '#FF7F0E',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = HSI.index, y = HSI.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))

fig.update_layout(
    title='3. Price history of Hong Kong Stock Exchange',
    titlefont_size = 28,
    
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Price in HKD (HK$)',
        titlefont_size=16,
        tickfont_size=14),
    
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
print("Click on the bottom right menu to show or hide the legend lines")

fig = go.Figure()
fig.add_trace(go.Scatter(x = SS.index, y = SS.High,
                    mode='lines',
                    name='High',
                    marker_color = '#2CA02C',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = SS.index, y = SS.Low,
                    mode='lines',
                    name='Low',
                    marker_color = '#D62728',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = SS.index, y = SS.Open,
                    mode='lines',
                    name='Open',
                    marker_color = '#FF7F0E',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = SS.index, y = SS.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))

fig.update_layout(
    title='4. Price history of Shanghai Stock Exchange',
    titlefont_size = 28,
    
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Price in CNY (¥)',
        titlefont_size=16,
        tickfont_size=14),
    
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
print("Click on the bottom right menu to show or hide the legend lines")

fig = go.Figure()
fig.add_trace(go.Scatter(x = GSPTSE.index, y = GSPTSE.High,
                    mode='lines',
                    name='High',
                    marker_color = '#2CA02C',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = GSPTSE.index, y = GSPTSE.Low,
                    mode='lines',
                    name='Low',
                    marker_color = '#D62728',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = GSPTSE.index, y = GSPTSE.Open,
                    mode='lines',
                    name='Open',
                    marker_color = '#FF7F0E',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = GSPTSE.index, y = GSPTSE.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))

fig.update_layout(
    title='5. Price history of Toronto Stock Exchange',
    titlefont_size = 28,
    
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Price in CAD (CA$)',
        titlefont_size=16,
        tickfont_size=14),
    
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
print("Click on the bottom right menu to show or hide the legend lines")

fig = go.Figure()
fig.add_trace(go.Scatter(x = SZ.index, y = SZ.High,
                    mode='lines',
                    name='High',
                    marker_color = '#2CA02C',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = SZ.index, y = SZ.Low,
                    mode='lines',
                    name='Low',
                    marker_color = '#D62728',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = SZ.index, y = SZ.Open,
                    mode='lines',
                    name='Open',
                    marker_color = '#FF7F0E',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = SZ.index, y = SZ.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))

fig.update_layout(
    title='6. Price history of Shenzhen Stock Exchange',
    titlefont_size = 28,
    
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Price in CNY (¥)',
        titlefont_size=16,
        tickfont_size=14),
    
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
print("Click on the bottom right menu to show or hide the legend lines")

fig = go.Figure()
fig.add_trace(go.Scatter(x = NSEI.index, y = NSEI.High,
                    mode='lines',
                    name='High',
                    marker_color = '#2CA02C',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = NSEI.index, y = NSEI.Low,
                    mode='lines',
                    name='Low',
                    marker_color = '#D62728',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = NSEI.index, y = NSEI.Open,
                    mode='lines',
                    name='Open',
                    marker_color = '#FF7F0E',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = NSEI.index, y = NSEI.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))

fig.update_layout(
    title='7. Price history of National Stock Exchange of India',
    titlefont_size = 28,
    
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Price in INR (₹)',
        titlefont_size=16,
        tickfont_size=14),
    
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
print("Click on the bottom right menu to show or hide the legend lines")

fig = go.Figure()
fig.add_trace(go.Scatter(x = GDAXI.index, y = GDAXI.High,
                    mode='lines',
                    name='High',
                    marker_color = '#2CA02C',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = GDAXI.index, y = GDAXI.Low,
                    mode='lines',
                    name='Low',
                    marker_color = '#D62728',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = GDAXI.index, y = GDAXI.Open,
                    mode='lines',
                    name='Open',
                    marker_color = '#FF7F0E',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = GDAXI.index, y = GDAXI.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))

fig.update_layout(
    title='8. Price history of Frankfurt Stock Exchange',
    titlefont_size = 28,
    
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Price in EUR (€)',
        titlefont_size=16,
        tickfont_size=14),
    
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
print("Click on the bottom right menu to show or hide the legend lines")

fig = go.Figure()
fig.add_trace(go.Scatter(x = KS11.index, y = KS11.High,
                    mode='lines',
                    name='High',
                    marker_color = '#2CA02C',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = KS11.index, y = KS11.Low,
                    mode='lines',
                    name='Low',
                    marker_color = '#D62728',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = KS11.index, y = KS11.Open,
                    mode='lines',
                    name='Open',
                    marker_color = '#FF7F0E',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = KS11.index, y = KS11.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))

fig.update_layout(
    title='9. Price history of Korea Exchange',
    titlefont_size = 28,
    
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Price in KRW (₩)',
        titlefont_size=16,
        tickfont_size=14),
    
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
print("Click on the bottom right menu to show or hide the legend lines")

fig = go.Figure()
fig.add_trace(go.Scatter(x = SSMI.index, y = SSMI.High,
                    mode='lines',
                    name='High',
                    marker_color = '#2CA02C',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = SSMI.index, y = SSMI.Low,
                    mode='lines',
                    name='Low',
                    marker_color = '#D62728',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = SSMI.index, y = SSMI.Open,
                    mode='lines',
                    name='Open',
                    marker_color = '#FF7F0E',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = SSMI.index, y = SSMI.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))

fig.update_layout(
    title='10. Price history of SIX Swiss Exchange',
    titlefont_size = 28,
    
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Price in CHF (CHF)',
        titlefont_size=16,
        tickfont_size=14),
    
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
print("Click on the bottom right menu to show or hide the legend lines")

fig = go.Figure()
fig.add_trace(go.Scatter(x = TWII.index, y = TWII.High,
                    mode='lines',
                    name='High',
                    marker_color = '#2CA02C',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = TWII.index, y = TWII.Low,
                    mode='lines',
                    name='Low',
                    marker_color = '#D62728',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = TWII.index, y = TWII.Open,
                    mode='lines',
                    name='Open',
                    marker_color = '#FF7F0E',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = TWII.index, y = TWII.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))

fig.update_layout(
    title='11. Price history of Taiwan Stock Exchange',
    titlefont_size = 28,
    
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Price in TWD (NT$)',
        titlefont_size=16,
        tickfont_size=14),
    
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
print("Click on the bottom right menu to show or hide the legend lines")

fig = go.Figure()
fig.add_trace(go.Scatter(x = J203_JO.index, y = J203_JO.High,
                    mode='lines',
                    name='High',
                    marker_color = '#2CA02C',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = J203_JO.index, y = J203_JO.Low,
                    mode='lines',
                    name='Low',
                    marker_color = '#D62728',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = J203_JO.index, y = J203_JO.Open,
                    mode='lines',
                    name='Open',
                    marker_color = '#FF7F0E',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = J203_JO.index, y = J203_JO.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))

fig.update_layout(
    title='12. Price history of Johannesburg Stock Exchange',
    titlefont_size = 28,
    
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Price in ZAR (R)',
        titlefont_size=16,
        tickfont_size=14),
    
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
print("Click on the bottom right menu to show or hide the legend lines")

fig = go.Figure()
fig.add_trace(go.Scatter(x = N225.index, y = N225.High,
                    mode='lines',
                    name='High',
                    marker_color = '#2CA02C',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = N225.index, y = N225.Low,
                    mode='lines',
                    name='Low',
                    marker_color = '#D62728',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = N225.index, y = N225.Open,
                    mode='lines',
                    name='Open',
                    marker_color = '#FF7F0E',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = N225.index, y = N225.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))

fig.update_layout(
    title='13. Price history of Tokyo Stock Exchange',
    titlefont_size = 28,
    
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Price in JPY (¥)',
        titlefont_size=16,
        tickfont_size=14),
    
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
print("Click on the bottom right menu to show or hide the legend lines")

fig = go.Figure()
fig.add_trace(go.Scatter(x = N100.index, y = N100.High,
                    mode='lines',
                    name='High',
                    marker_color = '#2CA02C',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = N100.index, y = N100.Low,
                    mode='lines',
                    name='Low',
                    marker_color = '#D62728',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = N100.index, y = N100.Open,
                    mode='lines',
                    name='Open',
                    marker_color = '#FF7F0E',
                    visible = "legendonly"))
fig.add_trace(go.Scatter(x = N100.index, y = N100.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))

fig.update_layout(
    title='14. Price history of Euronext',
    titlefont_size = 28,
    
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Price in EUR (€)',
        titlefont_size=16,
        tickfont_size=14),
    
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
test_data1 = scaled_data1[training_data_len1 - 60: , :]
test_data2 = scaled_data2[training_data_len2 - 60: , :]
test_data3 = scaled_data3[training_data_len3 - 60: , :]
test_data4 = scaled_data4[training_data_len4 - 60: , :]
test_data5 = scaled_data5[training_data_len5 - 60: , :]
test_data6 = scaled_data6[training_data_len6 - 60: , :]
test_data7 = scaled_data7[training_data_len7 - 60: , :]
test_data8 = scaled_data8[training_data_len8 - 60: , :]
test_data9 = scaled_data9[training_data_len9 - 60: , :]
test_data10 = scaled_data10[training_data_len10 - 60: , :]
test_data11 = scaled_data11[training_data_len11 - 60: , :]
test_data12 = scaled_data12[training_data_len12 - 60: , :]
test_data13 = scaled_data13[training_data_len13 - 60: , :]
test_data14 = scaled_data14[training_data_len14 - 60: , :]


x_test1 = []
y_test1 = dataset1[training_data_len1:, :]
x_test2 = []
y_test2 = dataset2[training_data_len2:, :]
x_test3 = []
y_test3 = dataset3[training_data_len3:, :]
x_test4 = []
y_test4 = dataset4[training_data_len4:, :]
x_test5 = []
y_test5 = dataset5[training_data_len5:, :]
x_test6 = []
y_test6 = dataset6[training_data_len6:, :]
x_test7 = []
y_test7 = dataset7[training_data_len7:, :]
x_test8 = []
y_test8 = dataset8[training_data_len8:, :]
x_test9 = []
y_test9 = dataset9[training_data_len9:, :]
x_test10 = []
y_test10 = dataset10[training_data_len10:, :]
x_test11 = []
y_test11 = dataset11[training_data_len11:, :]
x_test12 = []
y_test12 = dataset12[training_data_len12:, :]
x_test13 = []
y_test13 = dataset13[training_data_len13:, :]
x_test14 = []
y_test14 = dataset14[training_data_len14:, :]


for i in range (60, len(test_data1)):
    x_test1.append(test_data1[i - 60:i, 0])
for i in range (60, len(test_data2)):
    x_test2.append(test_data2[i - 60:i, 0])
for i in range (60, len(test_data3)):
    x_test3.append(test_data3[i - 60:i, 0])
for i in range (60, len(test_data4)):
    x_test4.append(test_data4[i - 60:i, 0])
for i in range (60, len(test_data5)):
    x_test5.append(test_data5[i - 60:i, 0])
for i in range (60, len(test_data6)):
    x_test6.append(test_data6[i - 60:i, 0])
for i in range (60, len(test_data7)):
    x_test7.append(test_data7[i - 60:i, 0])
for i in range (60, len(test_data8)):
    x_test8.append(test_data8[i - 60:i, 0])
for i in range (60, len(test_data9)):
    x_test9.append(test_data9[i - 60:i, 0])
for i in range (60, len(test_data10)):
    x_test10.append(test_data10[i - 60:i, 0])
for i in range (60, len(test_data11)):
    x_test11.append(test_data11[i - 60:i, 0])
for i in range (60, len(test_data12)):
    x_test12.append(test_data12[i - 60:i, 0])
for i in range (60, len(test_data13)):
    x_test13.append(test_data13[i - 60:i, 0])
for i in range (60, len(test_data14)):
    x_test14.append(test_data14[i - 60:i, 0])

    
x_test1 = np.array(x_test1)
x_test1 = np.reshape(x_test1, (x_test1.shape[0], x_test1.shape[1], 1))
x_test2 = np.array(x_test2)
x_test2 = np.reshape(x_test2, (x_test2.shape[0], x_test2.shape[1], 1))
x_test3 = np.array(x_test3)
x_test3 = np.reshape(x_test3, (x_test3.shape[0], x_test3.shape[1], 1))
x_test4 = np.array(x_test4)
x_test4 = np.reshape(x_test4, (x_test4.shape[0], x_test4.shape[1], 1))
x_test5 = np.array(x_test5)
x_test5 = np.reshape(x_test5, (x_test5.shape[0], x_test5.shape[1], 1))
x_test6 = np.array(x_test6)
x_test6 = np.reshape(x_test6, (x_test6.shape[0], x_test6.shape[1], 1))
x_test7 = np.array(x_test7)
x_test7 = np.reshape(x_test7, (x_test7.shape[0], x_test7.shape[1], 1))
x_test8 = np.array(x_test8)
x_test8 = np.reshape(x_test8, (x_test8.shape[0], x_test8.shape[1], 1))
x_test9 = np.array(x_test9)
x_test9 = np.reshape(x_test9, (x_test9.shape[0], x_test9.shape[1], 1))
x_test10 = np.array(x_test10)
x_test10 = np.reshape(x_test10, (x_test10.shape[0], x_test10.shape[1], 1))
x_test11 = np.array(x_test11)
x_test11 = np.reshape(x_test11, (x_test11.shape[0], x_test11.shape[1], 1))
x_test12 = np.array(x_test12)
x_test12 = np.reshape(x_test12, (x_test12.shape[0], x_test12.shape[1], 1))
x_test13 = np.array(x_test13)
x_test13 = np.reshape(x_test13, (x_test13.shape[0], x_test13.shape[1], 1))
x_test14 = np.array(x_test14)
x_test14 = np.reshape(x_test14, (x_test14.shape[0], x_test14.shape[1], 1))


predictions1 = model1.predict(x_test1)
predictions1 = scaler1.inverse_transform(predictions1)
predictions2 = model2.predict(x_test2)
predictions2 = scaler2.inverse_transform(predictions2)
predictions3 = model3.predict(x_test3)
predictions3 = scaler3.inverse_transform(predictions3)
predictions4 = model4.predict(x_test4)
predictions4 = scaler4.inverse_transform(predictions4)
predictions5 = model5.predict(x_test5)
predictions5 = scaler5.inverse_transform(predictions5)
predictions6 = model6.predict(x_test6)
predictions6 = scaler6.inverse_transform(predictions6)
predictions7 = model7.predict(x_test7)
predictions7 = scaler7.inverse_transform(predictions7)
predictions8 = model8.predict(x_test8)
predictions8 = scaler8.inverse_transform(predictions8)
predictions9 = model9.predict(x_test9)
predictions9 = scaler9.inverse_transform(predictions9)
predictions10 = model10.predict(x_test10)
predictions10 = scaler10.inverse_transform(predictions10)
predictions11 = model11.predict(x_test11)
predictions11 = scaler11.inverse_transform(predictions11)
predictions12 = model12.predict(x_test12)
predictions12 = scaler12.inverse_transform(predictions12)
predictions13 = model13.predict(x_test13)
predictions13 = scaler13.inverse_transform(predictions13)
predictions14 = model14.predict(x_test14)
predictions14 = scaler14.inverse_transform(predictions14)


rsme1 = np.sqrt(np.mean(predictions1 - y_test1) ** 2)
rsme2 = np.sqrt(np.mean(predictions2 - y_test2) ** 2)
rsme3 = np.sqrt(np.mean(predictions3 - y_test3) ** 2)
rsme4 = np.sqrt(np.mean(predictions4 - y_test4) ** 2)
rsme5 = np.sqrt(np.mean(predictions5 - y_test5) ** 2)
rsme6 = np.sqrt(np.mean(predictions6 - y_test6) ** 2)
rsme7 = np.sqrt(np.mean(predictions7 - y_test7) ** 2)
rsme8 = np.sqrt(np.mean(predictions8 - y_test8) ** 2)
rsme9 = np.sqrt(np.mean(predictions9 - y_test9) ** 2)
rsme10 = np.sqrt(np.mean(predictions10 - y_test10) ** 2)
rsme11 = np.sqrt(np.mean(predictions11 - y_test11) ** 2)
rsme12 = np.sqrt(np.mean(predictions12 - y_test12) ** 2)
rsme13 = np.sqrt(np.mean(predictions13 - y_test13) ** 2)
rsme14 = np.sqrt(np.mean(predictions14 - y_test14) ** 2)

# %%
print('New York Stock Exchange')
print(rsme1)
print()
print('NASDAQ')
print(rsme2)
print()
print('Hong Kong Stock Exchange')
print(rsme3)
print()
print('Shanghai Stock Exchange')
print(rsme4)
print()
print('Toronto Stock Exchange')
print(rsme5)
print()
print('Shenzhen Stock Exchange')
print(rsme6)
print()
print('National Stock Exchange of India')
print(rsme7)
print()
print('Frankfurt Stock Exchange')
print(rsme8)
print()
print('Korea Exchange')
print(rsme9)
print()
print('SIX Swiss Exchange')
print(rsme10)
print()
print('Taiwan Stock Exchange')
print(rsme11)
print()
print('Johannesburg Stock Exchange')
print(rsme12)
print()
print('Tokyo Stock Exchange')
print(rsme13)
print()
print('Euronext')
print(rsme14)

# %%
train1 = data1[:training_data_len1]
valid1 = data1[training_data_len1:]
valid1['Predictions'] = predictions1
train2 = data2[:training_data_len2]
valid2 = data2[training_data_len2:]
valid2['Predictions'] = predictions2
train3 = data3[:training_data_len3]
valid3 = data3[training_data_len3:]
valid3['Predictions'] = predictions3
train4 = data4[:training_data_len4]
valid4 = data4[training_data_len4:]
valid4['Predictions'] = predictions4
train5 = data5[:training_data_len5]
valid5 = data5[training_data_len5:]
valid5['Predictions'] = predictions5
train6 = data6[:training_data_len6]
valid6 = data6[training_data_len6:]
valid6['Predictions'] = predictions6
train7 = data7[:training_data_len7]
valid7 = data7[training_data_len7:]
valid7['Predictions'] = predictions7
train8 = data8[:training_data_len8]
valid8 = data8[training_data_len8:]
valid8['Predictions'] = predictions8
train9 = data9[:training_data_len9]
valid9 = data9[training_data_len9:]
valid9['Predictions'] = predictions9
train10 = data10[:training_data_len10]
valid10 = data10[training_data_len10:]
valid10['Predictions'] = predictions10
train11 = data11[:training_data_len11]
valid11 = data11[training_data_len11:]
valid11['Predictions'] = predictions11
train12 = data12[:training_data_len12]
valid12 = data12[training_data_len12:]
valid12['Predictions'] = predictions12
train13 = data13[:training_data_len13]
valid13 = data13[training_data_len13:]
valid13['Predictions'] = predictions13
train14 = data14[:training_data_len14]
valid14 = data14[training_data_len14:]
valid14['Predictions'] = predictions14

# %%
print("Click and drag on the plot to zoom in, you can reset using the top right option")

fig = go.Figure()
fig.add_trace(go.Scatter(x = train1.index, y = train1.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))
fig.add_trace(go.Scatter(x = valid1.index, y = valid1.Close,
                    mode='lines',
                    name='Val',
                    marker_color = '#FF7F0E'))
fig.add_trace(go.Scatter(x = valid1.index, y = valid1.Predictions,
                    mode='lines',
                    name='Predictions',
                    marker_color = '#2CA02C'))

fig.update_layout(
    title='1. Model of New York Stock Exchange',
    titlefont_size = 28,
    hovermode = 'x',
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Close price in USD ($)',
        titlefont_size=16,
        tickfont_size=14),
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
print("Click and drag on the plot to zoom in, you can reset using the top right option")

fig = go.Figure()
fig.add_trace(go.Scatter(x = train2.index, y = train2.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))
fig.add_trace(go.Scatter(x = valid2.index, y = valid2.Close,
                    mode='lines',
                    name='Val',
                    marker_color = '#FF7F0E'))
fig.add_trace(go.Scatter(x = valid2.index, y = valid2.Predictions,
                    mode='lines',
                    name='Predictions',
                    marker_color = '#2CA02C'))

fig.update_layout(
    title='2. Model of NASDAQ',
    titlefont_size = 28,
    hovermode = 'x',
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Close price in USD ($)',
        titlefont_size=16,
        tickfont_size=14),
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
print("Click and drag on the plot to zoom in, you can reset using the top right option")

fig = go.Figure()
fig.add_trace(go.Scatter(x = train3.index, y = train3.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))
fig.add_trace(go.Scatter(x = valid3.index, y = valid3.Close,
                    mode='lines',
                    name='Val',
                    marker_color = '#FF7F0E'))
fig.add_trace(go.Scatter(x = valid3.index, y = valid3.Predictions,
                    mode='lines',
                    name='Predictions',
                    marker_color = '#2CA02C'))

fig.update_layout(
    title='3. Model of Hong Kong Stock Exchange',
    titlefont_size = 28,
    hovermode = 'x',
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Close price in HKD (HK$)',
        titlefont_size=16,
        tickfont_size=14),
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
print("Click and drag on the plot to zoom in, you can reset using the top right option")

fig = go.Figure()
fig.add_trace(go.Scatter(x = train4.index, y = train4.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))
fig.add_trace(go.Scatter(x = valid4.index, y = valid4.Close,
                    mode='lines',
                    name='Val',
                    marker_color = '#FF7F0E'))
fig.add_trace(go.Scatter(x = valid4.index, y = valid4.Predictions,
                    mode='lines',
                    name='Predictions',
                    marker_color = '#2CA02C'))

fig.update_layout(
    title='4. Model of Shanghai Stock Exchange',
    titlefont_size = 28,
    hovermode = 'x',
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Close price in CNY (¥)',
        titlefont_size=16,
        tickfont_size=14),
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
print("Click and drag on the plot to zoom in, you can reset using the top right option")

fig = go.Figure()
fig.add_trace(go.Scatter(x = train5.index, y = train5.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))
fig.add_trace(go.Scatter(x = valid5.index, y = valid5.Close,
                    mode='lines',
                    name='Val',
                    marker_color = '#FF7F0E'))
fig.add_trace(go.Scatter(x = valid5.index, y = valid5.Predictions,
                    mode='lines',
                    name='Predictions',
                    marker_color = '#2CA02C'))

fig.update_layout(
    title='5. Model of Toronto Stock Exchange',
    titlefont_size = 28,
    hovermode = 'x',
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Close price in CAD (CA$)',
        titlefont_size=16,
        tickfont_size=14),
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
print("Click and drag on the plot to zoom in, you can reset using the top right option")

fig = go.Figure()
fig.add_trace(go.Scatter(x = train6.index, y = train6.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))
fig.add_trace(go.Scatter(x = valid6.index, y = valid6.Close,
                    mode='lines',
                    name='Val',
                    marker_color = '#FF7F0E'))
fig.add_trace(go.Scatter(x = valid6.index, y = valid6.Predictions,
                    mode='lines',
                    name='Predictions',
                    marker_color = '#2CA02C'))

fig.update_layout(
    title='6. Model of Shenzhen Stock Exchange',
    titlefont_size = 28,
    hovermode = 'x',
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Close price in CNY (¥)',
        titlefont_size=16,
        tickfont_size=14),
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
print("Click and drag on the plot to zoom in, you can reset using the top right option")

fig = go.Figure()
fig.add_trace(go.Scatter(x = train7.index, y = train7.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))
fig.add_trace(go.Scatter(x = valid7.index, y = valid7.Close,
                    mode='lines',
                    name='Val',
                    marker_color = '#FF7F0E'))
fig.add_trace(go.Scatter(x = valid7.index, y = valid7.Predictions,
                    mode='lines',
                    name='Predictions',
                    marker_color = '#2CA02C'))

fig.update_layout(
    title='7. Model of National Stock Exchange of India',
    titlefont_size = 28,
    hovermode = 'x',
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Close price in INR (₹)',
        titlefont_size=16,
        tickfont_size=14),
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
print("Click and drag on the plot to zoom in, you can reset using the top right option")

fig = go.Figure()
fig.add_trace(go.Scatter(x = train8.index, y = train8.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))
fig.add_trace(go.Scatter(x = valid8.index, y = valid8.Close,
                    mode='lines',
                    name='Val',
                    marker_color = '#FF7F0E'))
fig.add_trace(go.Scatter(x = valid8.index, y = valid8.Predictions,
                    mode='lines',
                    name='Predictions',
                    marker_color = '#2CA02C'))

fig.update_layout(
    title='8. Model of Frankfurt Stock Exchange',
    titlefont_size = 28,
    hovermode = 'x',
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Close price in EUR (€)',
        titlefont_size=16,
        tickfont_size=14),
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
print("Click and drag on the plot to zoom in, you can reset using the top right option")

fig = go.Figure()
fig.add_trace(go.Scatter(x = train9.index, y = train9.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))
fig.add_trace(go.Scatter(x = valid9.index, y = valid9.Close,
                    mode='lines',
                    name='Val',
                    marker_color = '#FF7F0E'))
fig.add_trace(go.Scatter(x = valid9.index, y = valid9.Predictions,
                    mode='lines',
                    name='Predictions',
                    marker_color = '#2CA02C'))

fig.update_layout(
    title='9. Model of Korea Exchange',
    titlefont_size = 28,
    hovermode = 'x',
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Close price in KRW (₩)',
        titlefont_size=16,
        tickfont_size=14),
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
print("Click and drag on the plot to zoom in, you can reset using the top right option")

fig = go.Figure()
fig.add_trace(go.Scatter(x = train10.index, y = train10.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))
fig.add_trace(go.Scatter(x = valid10.index, y = valid10.Close,
                    mode='lines',
                    name='Val',
                    marker_color = '#FF7F0E'))
fig.add_trace(go.Scatter(x = valid10.index, y = valid10.Predictions,
                    mode='lines',
                    name='Predictions',
                    marker_color = '#2CA02C'))

fig.update_layout(
    title='10. Model of SIX Swiss Exchange',
    titlefont_size = 28,
    hovermode = 'x',
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Close price in CHF (CHF)',
        titlefont_size=16,
        tickfont_size=14),
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
print("Click and drag on the plot to zoom in, you can reset using the top right option")

fig = go.Figure()
fig.add_trace(go.Scatter(x = train11.index, y = train11.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))
fig.add_trace(go.Scatter(x = valid11.index, y = valid11.Close,
                    mode='lines',
                    name='Val',
                    marker_color = '#FF7F0E'))
fig.add_trace(go.Scatter(x = valid11.index, y = valid11.Predictions,
                    mode='lines',
                    name='Predictions',
                    marker_color = '#2CA02C'))

fig.update_layout(
    title='11. Model of Taiwan Stock Exchange',
    titlefont_size = 28,
    hovermode = 'x',
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Close price in TWD (NT$)',
        titlefont_size=16,
        tickfont_size=14),
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
print("Click and drag on the plot to zoom in, you can reset using the top right option")

fig = go.Figure()
fig.add_trace(go.Scatter(x = train12.index, y = train12.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))
fig.add_trace(go.Scatter(x = valid12.index, y = valid12.Close,
                    mode='lines',
                    name='Val',
                    marker_color = '#FF7F0E'))
fig.add_trace(go.Scatter(x = valid12.index, y = valid12.Predictions,
                    mode='lines',
                    name='Predictions',
                    marker_color = '#2CA02C'))

fig.update_layout(
    title='12. Model of Johannesburg Stock Exchange',
    titlefont_size = 28,
    hovermode = 'x',
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Close price in ZAR (R)',
        titlefont_size=16,
        tickfont_size=14),
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
print("Click and drag on the plot to zoom in, you can reset using the top right option")

fig = go.Figure()
fig.add_trace(go.Scatter(x = train13.index, y = train13.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))
fig.add_trace(go.Scatter(x = valid13.index, y = valid13.Close,
                    mode='lines',
                    name='Val',
                    marker_color = '#FF7F0E'))
fig.add_trace(go.Scatter(x = valid13.index, y = valid13.Predictions,
                    mode='lines',
                    name='Predictions',
                    marker_color = '#2CA02C'))

fig.update_layout(
    title='13. Model of Tokyo Stock Exchange',
    titlefont_size = 28,
    hovermode = 'x',
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Close price in JPY (¥)',
        titlefont_size=16,
        tickfont_size=14),
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()

# %%
print("Click and drag on the plot to zoom in, you can reset using the top right option")

fig = go.Figure()
fig.add_trace(go.Scatter(x = train14.index, y = train14.Close,
                    mode='lines',
                    name='Close',
                    marker_color = '#1F77B4'))
fig.add_trace(go.Scatter(x = valid14.index, y = valid14.Close,
                    mode='lines',
                    name='Val',
                    marker_color = '#FF7F0E'))
fig.add_trace(go.Scatter(x = valid14.index, y = valid14.Predictions,
                    mode='lines',
                    name='Predictions',
                    marker_color = '#2CA02C'))

fig.update_layout(
    title='14. Model of Euronext',
    titlefont_size = 28,
    hovermode = 'x',
    xaxis = dict(
        title='Date',
        titlefont_size=16,
        tickfont_size=14),
    
    height = 800,
    
    yaxis=dict(
        title='Close price in EUR (€)',
        titlefont_size=16,
        tickfont_size=14),
    legend=dict(
        y=0,
        x=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'))

fig.show()
