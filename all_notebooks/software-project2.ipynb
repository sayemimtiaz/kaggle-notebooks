# %%
import matplotlib as plt       #import pandas laibary
import pandas as pd

# %%
df=pd.read_csv('../input/airline-dataset/new airline.csv') #import data

# %%
df

# %%
df['incidents2000to2014'].fillna(0,inplace=True)

# %%
df

# %%
df.columns   #show columns name

# %%
df.index   #show the index range

# %%
df.info()   #show the information of eatch column

# %%
df["fatalities1985to1999"].sum()    #Total fatalities of 1985-1999

# %%
pd.crosstab(df.airline,df.incidents1985to1999)    ###cross tab data###

# %%
plt.style.use('classic')
df.plot(x='airline',y='fatalities2000to2014',kind="bar") #bar chart#

# %%
plt.style.available

# %%
plt.style.use('ggplot')
df['fatal_accidents1985to1999'].plot()     ###plotting data###

# %%
df.loc[8]      ###show the data of index-5###

# %%
df.loc[[3,7,10]]             ###show the data of multiple index###

# %%
df["fatalities1985to1999"].hist()
