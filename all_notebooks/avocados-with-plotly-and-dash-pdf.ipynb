# %%
# !pip install pdfkit

# %%
# !apt-get install -y wkhtmltopdf

# %%
# !pip install dash

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.graph_objs as go
import pandas as pd

app = dash.Dash()
server = app.server

app.layout = html.Div([
    html.H1('AVOCADOS!')], style={'padding':10, 'className':'dark-table'})


if __name__ == '__main__':
    app.run_server()

# %%
# !apt-get install xvfb 
# !pip install pyvirtualdisplay

# %%
from pyvirtualdisplay import Display
import pdfkit

with Display():
    pdfkit.from_url('www.google.ca', 'out.pdf')    # pdfkit.from_url(input_url, output_file_path)
