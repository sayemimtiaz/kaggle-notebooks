# %% [markdown]
# <h1>Домашнє завдання №1. Варіант 2</h1>
# <h1>Аналіз даних доходу населення UCI Adult</h1>

# %% [markdown]
# <p style="font-size: 16px;text-align: justify">У завданні пропонується за допомогою Pandas відповісти на кілька запитань за даними сховища UCI [Adult](https://archive.ics.uci.edu/ml/datasets/Adult) (завантажувати дані не треба - вони вже є в репозиторії). Для відправки розв'язків використовуйте [систему Moodle](https://eln.stu.cn.ua/course/view.php?id=2994).</p>

# %% [markdown]
# <p style="font-size: 16px">Унікальні значення ознак ([більше інформації за посиланням](https://archive.ics.uci.edu/ml/datasets/Adult)):</p>
#
# * age: continuous (вік).
# * workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked (Тип робочої діяльності).
# * fnlwgt: continuous.
# * education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool. (Освіта).
# * education-num: continuous.
# * marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse (Сімейний статус).
# * occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces. (Вид діяльності).
# * relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried. (Сімейні відносини).
# * race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black. (Раса).
# * sex: Female, Male. (Стать).
# * capital-gain: continuous.
# * capital-loss: continuous.
# * hours-per-week: continuous. (Кількість робочих годин на тиждень).
# * native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands. (Країна проживання).
# * salary: >50K,<=50K (Заробітна плата, бінарний показник, більше 59 тисяч або менше дорівнює 50 тисяч).

# %%
# Імпорт Pandas і Numpy
import numpy as np
import pandas as pd

#Вхідні дані доступні в "../input/"
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Будь-які результати доступні у папці "../output/kaggle/working"

# %%
data = pd.read_csv("../input/uci-adult/adult.data.csv")

# %%
data.shape

# %%
data.head()

# %% [markdown]
# <p style="font-size: 16px;text-align: justify"> 1. Визначити кількість жінок (ознака sex) у відсотках в цьому наборі.</p>

# %%
# Ваш код тут

# %% [markdown]
# <p style="font-size: 16px;text-align: justify"> 2. Визначити середній вік жінок (ознаки sex, age) в цьому наборі.</p>

# %%
# Ваш код тут

# %% [markdown]
# <p style="font-size: 16px;text-align: justify"> 3. Визначити відсоток жінок (ознаки sex, workclass), які мають workclass - Private.</p>

# %%
# Ваш код тут

# %% [markdown]
# <p style="font-size: 16px;text-align: justify"> 4. Обчислити середнє та середньоквадратичне відхилення віку тих, хто заробляє багато (ознаки age, salary).</p>

# %%
# Ваш код тут

# %% [markdown]
# <p style="font-size: 16px;text-align: justify"> 5. Визначити моду віку тих чоловіків, хто заробляє багато (ознаки age, salary, sex).</p>

# %%
# Ваш код тут

# %% [markdown]
# <p style="font-size: 16px;text-align: justify"> 6. Визначити, чи правда, що люди які багато заробляють мають як мінімум вищу освіту (ознаки education, salary). Ознака education дорівнює Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters чи Doctorate. </p>

# %%
# Ваш код тут

# %% [markdown]
# <p style="font-size: 16px;text-align: justify"> 7. Чоловіки білошкірої чи чорношкірої раси є більш освіченими і на скільки відсотків (ознаки race, education, sex)? Освіченість визначається відсотком чоловіків з вищою освітою до всіх чоловіків цієї раси.</p>

# %%
# Ваш код тут

# %% [markdown]
# <p style="font-size: 16px;text-align: justify"> 8. Визначити, серед яких чоловіків доля з великою зарплатою більша, серед одружених чи ні (ознаки salary, marital-status, sex)? Ознака marital-status для одружених дорівнює Married-civ-spouse, Married-spouse-absent чи Married-AF-spouse).</p>

# %%
# Ваш код тут

# %% [markdown]
# <p style="font-size: 16px;text-align: justify"> 9. Визначити, для якого виду діяльності люди в середньому працюють найбільшу кількість годин на тиждень (ознака occupation) і визначити відсоток людей зайнятих у цій спеціальності.</p>

# %%
# Ваш код тут

# %% [markdown]
# <p style="font-size: 16px;text-align: justify"> 10. Обчислити середній час роботи людей на тиждень з малою та великою зарплатою в Японії (ознаки hours-per-week, native-country).</p>

# %%
# Ваш код тут

# %% [markdown]
# <p style="font-size: 16px;text-align: justify"> 11. Обчислити число унікальних значень ознаки occupation.</p>

# %%
# Ваш код тут

# %% [markdown]
# <p style="font-size: 16px;text-align: justify"> 12. Визначити назву країни та вік для 1305 запису (ознаки native-country, age).</p>

# %%
# Ваш код тут
