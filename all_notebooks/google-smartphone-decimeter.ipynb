# %%
from IPython.display import Image
Image("../input/imgdir/pixel4a.png")

# %% [markdown]
# `# version: 0.0.1`

# %% [markdown]
# $\mathrm{LC}|\mathrm{Workout}$
#
# Workout 0.001
#
# Workout 1 milliseconds
#
# Why it is not working.
#
# Workout 0.00101
#
# Workout 0.00102
#
# Workout 0.00103
#
# Workout 1.0.4
#
# All my mountains are exploding.
#
# Let's get onto 1.0.5
#
# Larboard Canada
#
# I am your treadmill.
#
#
# ## TABLE OF CONTENTS <a class="anchor" id="TOC"></a>
#
#    * [1. Make It Pixel](#Section1)
#    * [2. Surface Drop](#Section2)
#    * [3. Line Align](#Section3)
#    * [4. Submission](#Section4)
#    * [5. G Centric Model](#Section5)
#    * [6. Voxel Estimation Chart](#Section6)
#    * [7. Elastic Crescent](#Section7)
#    * [8. Usain Earth](#Section8)

# %% [markdown]
# ## 1. Make It Pixel <a class="anchor" id="Section1"></a>

# %% [markdown]
# `Panda, pathlib, and '\n'`
#
# `Let's get it to roll roll~`
#
# `Challenge`

# %%
import pandas as pd
from pathlib import Path
input_dir = Path('../input/google-smartphone-decimeter-challenge')
submission = Path('submission.csv')

print('\n', '*', '\n')
# !ls '../input/google-smartphone-decimeter-challenge'
print('\n', "#", '\n')
# !ls '../input/google-smartphone-decimeter-challenge' |grep -v / | wc -l
print('\n', 'Smartphone Decimeter', '\n')
print('0101a101010l1010010p10001h1010a100', '\n')
print('010101001b100010a01010100t10101001', '\n')

print('\n', 'Challenge', '\n',)

# %% [markdown]
# ## 2. Surface Drop <a class="anchor" id="Section2"></a>
#
# legoristic replace, layeristic merge, ray split

# %% [markdown]
# `drop rain, not fire`

# %%
train = Path('../input/google-smartphone-decimeter-challenge/baseline_locations_train.csv')
ssub = Path('../input/google-smartphone-decimeter-challenge/sample_submission.csv')
test = Path('../input/google-smartphone-decimeter-challenge/baseline_locations_test.csv')
df_train = pd.read_csv(train)
df_ssub = pd.read_csv(ssub)
df_test = pd.read_csv(test)
df_test.columns

# %%
pd.read_csv(train)

# %%
df_test.isna().any()

# %% [markdown]
# `M`

# %%
df_touch = ['heightAboveWgs84EllipsoidM']
df_test[df_touch].to_csv('M.csv', index=False)
mountains = pd.read_csv('M.csv')
mountains

# %% [markdown]
# it seems all my muscles are disappearing

# %% [markdown]
# https://www.mathworks.com/help/map/ref/wgs84ellipsoid.html

# %% [markdown]
# ## 3. Line Align <a class="anchor" id="Section3"></a>

# %% [markdown]
# `panda read subm path csv is df[]`

# %%
columns = ['phone', 'millisSinceGpsEpoch', 'latDeg', 'lngDeg']
df_test[columns].to_csv('submission.csv', index=False)
submission = pd.read_csv('submission.csv')
submission.columns

# %% [markdown]
# ## 4. Submission <a class="anchor" id="Section4"></a>

# %% [markdown]
# epoch = 🛰️
#
# 37.42790979744899, -122.16998695932323

# %%
submission

# %% [markdown]
# it's because we only moved to 37.33 -121.89

# %% [markdown]
# https://www.google.ca/maps/place/37%C2%B024'51.8%22N+122%C2%B004'38.7%22W

# %% [markdown]
# ## 5. G Centric Model <a class="anchor" id="Section5"></a>

# %%
df_watch = ['millisSinceGpsEpoch']
df_test[df_watch].to_csv('W.csv', index=False)
watch = pd.read_csv('W.csv')
watch

# %% [markdown]
# 1,273,608,785,432 milliseconds \
# 1,273,608,785 seconds \
# 353780 hours \
# 14741 days \
# 484.6 months \
# 40.38 years
#
# Tuesday May 11, 2010 13:13:05 (pm) \
# Monday April 25, 2011 13:26:29 (pm)

# %% [markdown]
# I think I missed some workout sessions. Hey, Google. What's the temperature?

# %% [markdown]
# 1.608E+12

# %% [markdown]
# ## 6. Voxel Estimation Chart <a class="anchor" id="Section6"></a>

# %%
# !ls

# %%
# !rm append.csv
# !touch append.csv
log_head = ['x', 'y', 'z']
log_line = ['1', '2', '3']

import csv
with open('append.csv', 'r') as f:
    logcsv = [line for line in csv.reader(f)]

logcsv.append(log_head)
logcsv.append(log_line)

with open('append.csv', 'w') as f:
    csv.writer(f).writerows(logcsv)

pd.read_csv('append.csv')

# %% [markdown]
# ## 7. Elastic Crescent <a class="anchor" id="Section7"></a>

# %% [markdown]
# 23 hours, 59 minutes, 59.9989491 -1.0509 milliseconds
#
# 23 hours, 59 minutes, 59.9989396 -1.0604 milliseconds

# %% [markdown]
# hr, min, milliseconds, target \
# 23, 59, 59998, 945

# %% [markdown]
# Let's get this to work.

# %%
# !rm workout.csv
# !touch workout.csv
schedule = ['hours', 'minutes', 'milliseconds', 'target']
adjustment = [23, 59, 59998, 945]

import csv
with open('workout.csv', 'r') as f:
    logcsv = [line for line in csv.reader(f)]

logcsv.append(schedule)
logcsv.append(adjustment)

with open('workout.csv', 'w') as f:
    csv.writer(f).writerows(logcsv)

pd.read_csv('workout.csv')

# %% [markdown]
# ## 8. Usain Earth <a class="anchor" id="Section8"></a>

# %% [markdown]
# Urusa 1.0.8
#
# Let's do this!

# %%
# !rm spacetime.csv
from csv import writer
from csv import reader

recordtime = 'spacetime'

with open('workout.csv', 'r') as read_obj, \
        open('spacetime.csv', 'w', newline='') as write_obj:

    csv_reader = reader(read_obj)
    csv_writer = writer(write_obj)
    
    for row in csv_reader:
        
        row.append(recordtime)
        csv_writer.writerow(row)

pd.read_csv('spacetime.csv')

# %%
extracolumn = ['23', '59', '59998', '945', '8/8/2021']

import csv
with open('spacetime.csv', 'r') as f:
    logcsv = [line for line in csv.reader(f)]

logcsv.append(extracolumn)

with open('spacetime.csv', 'w') as f:
    csv.writer(f).writerows(logcsv)

pd.read_csv('spacetime.csv')

# %%
text = open("spacetime.csv", "r")
text = ''.join([i for i in text]) \
    .replace("spacetime", "dayone")
x = open("spacetime.csv","w")
x.writelines(text)
x.close()

pd.read_csv('spacetime.csv')
