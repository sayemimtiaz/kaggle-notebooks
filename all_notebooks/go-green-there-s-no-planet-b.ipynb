# %% [markdown]
# -------------------------------------------------
#
# ***“The forest is a peculiar organism of unlimited kindness and benevolence that makes no demands for its sustenance and extends generously the products of its life activity; it affords protection to all beings, offering shade even to the axe-man who destroys it.”***
#
# *-Gautama Buddha*
#
# -------------------------------------------------

# %% [markdown]
# ### Let's look through the years how the countries across the world are risking it all to *deforestation*
#
# We would observe the trends from 1990 to 2015 of the net change in forest cover across the world - visually depicting whether or not the countries able to regrow forest faster than they are losing it or are losing more than they're able to restore in terms of net forest change.
#
# > ***Net Forest Change***<br>The net change in forest cover measures any gains in forest cover – either through natural forest expansion or afforestation through tree-planting – minus deforestation

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# ### Loading the dataset

# %%
annualChangeForestArea = pd.read_csv('/kaggle/input/deforestation-and-forest-loss/annual-change-forest-area.csv')
display(annualChangeForestArea.head())
display(annualChangeForestArea.shape)

# %% [markdown]
# ### Function to plot Net Forest Conversion over geographical map

# %%
def plot_net_conv(scope,title):
    fig = px.choropleth(
        annualChangeForestArea,
        locations ="Code",
        color ="Net forest conversion",
        hover_name ="Entity",
        scope=scope,
        color_continuous_scale='RdYlGn',
        animation_frame ="Year")
    
    fig.update_layout(title_text=title,
        font_family="Rockwell",
        title_font_size=20,
        coloraxis_colorbar=dict(
            title='Net Forest Conversion'))
    
    fig.show()

# %% [markdown]
# ## Glance at the net change in forest cover across the world through more than two decades (1990-2015)

# %%
plot_net_conv('world','Net Forest Conversion across the world from 1990 to 2015')

# %% [markdown]
# ## Glimpse of Net Forest Conversion across different continents

# %% [markdown]
# ### Asia
# **Overview**
# * Medium to high population density,
# * Low to rapid population growth,
# * Low to high climate impacts, and
# * Low to large growth in planted forest area,
#
# **Focus**
# * Increasing productivity from existing resource,
# * Adaptation to extreme climate impacts, and
# * Adaptation to drought and health risks

# %%
plot_net_conv('asia','Net Forest Conversion across the Asia from 1990 to 2015')

# %% [markdown]
# ### Africa
# **Overview**
# * Low to medium population density,
# * Medium to high population growth,
# * Medium to high loss of natural forest,
# * Low to high increase in planted forest area
# * Low to medium climate impacts, and
# * Low to high health impacts
#
# **Focus**
# * Expanding planted forest area,
# * Adaptation to drought and health risks, and
# * Forest health management

# %%
plot_net_conv('africa','Net Forest Conversion across the Africa from 1990 to 2015')

# %% [markdown]
# ### Europe
#
# **Overview**
# * Medium density but stable population,
# * Stable natural forest,
# * Low planted forest expansion,
# * Medium climate impacts, and
# * High disease impacts.
#
# **Focus**
# * Climate adaptation, and
# * Forest health management to maintain status

# %%
plot_net_conv('europe','Net Forest Conversion across the Europe from 1990 to 2015')

# %% [markdown]
# ### North America
#
# **Overview**
# * Low population density,
# * Low population growth,
# * Stable natural forest,
# * High increase in planted forests,
# * Medium climate impacts,
# * High health impacts.
#
# **Focus**
# * Health management, and
# * Adaptation to extreme climate impacts

# %%
plot_net_conv('north america','Net Forest Conversion across the North America from 1990 to 2015')

# %% [markdown]
# ### South America
#
# **Overview**
# * Low population density,
# * Medium population growth,
# * Medium loss of natural forest,
# * High increase in planted forest area,
# * Low climate and health impacts.
#
# **Focus**
# * Increasing planted forest area,
# * Adaptation to extreme climate impacts

# %%
plot_net_conv('south america','Net Forest Conversion across the South America from 1990 to 2015')

# %% [markdown]
# ## References
# * https://ourworldindata.org/deforestation
# * http://www.fao.org/3/i4895e/i4895e06.pdf

# %% [markdown]
# ## Feel free to Upvote and give Feedback.
