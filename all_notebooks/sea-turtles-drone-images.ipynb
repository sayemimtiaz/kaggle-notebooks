# %% [markdown]
# #Photo By Tanguy Sauvin Unsplash
#
# ![](https://images.unsplash.com/photo-1416138645715-930585fe4ce2?ixlib=rb-1.2.1&ixid=eyJhcHBfaWQiOjEyMDd9&auto=format&fit=crop&w=500&q=60)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# #Since Fastai v2 was launched, "My"  tfms = `get_transforms`(max_rotate=25) is returning an error. Consequently, I couldn't make the #visualizations that I used to appreciate. Many New Notebooks are about classification, loss, training, but few visualizations.

# %%
from fastai.vision.all import *
from fastai.imports import *
from fastai.vision.data import *
from fastai import *

import fastai
import matplotlib.pyplot as plt

# %%
path = Path("/kaggle/input/sea-turtles-in-drone-imagery/duke_turtles_r1/duke_turtles_r1/8Aug20158Aug20158RioBeach3KMLanePM20150807cr5surprisebeach3kmlaneimg_20150808_011710_to_20150808_012603/")
path.ls()

# %%
np.random.seed(42)
data = ImageDataLoaders.from_folder(path, train=".", valid_pct=0.2, item_tfms=RandomResizedCrop(512, min_scale=0.75),
                                    bs=32,batch_tfms=[*aug_transforms(size=256, max_warp=0), Normalize.from_stats(*imagenet_stats)],num_workers=0)

# %%
data.show_batch(nrows=3, figsize=(7,8))

# %%
data.show_batch(nrows=2, figsize=(12,10))

# %%
data.show_batch(nrows=1, figsize=(8,6))

# %% [markdown]
# #Where are my Turtles?
#
# ![](https://media0.giphy.com/media/NRajNYtMjmKjdfz9uq/200w.webp?cid=ecf05e47516mvvuv6jto02xwvnuroqf97nayytjgo6schjqr&rid=200w.webp)

# %% [markdown]
# #Codes from Salman Ibne Eunus https://www.kaggle.com/salmaneunus/mechanical-tools-image-basic-eda-using-matplotlib/notebook

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('../input/sea-turtles-in-drone-imagery/duke_turtles_r1/duke_turtles_r1/8Aug20158Aug20158RioBeach3KMLanePM20150807cr5surprisebeach3kmlaneimg_20150808_011710_to_20150808_012603/8Aug20158Aug20158RioBeach3KMLanePM20150807cr5surprisebeach3kmlaneimg_20150808_012231_IMG_6146_NIR.jpg')
print(img)

# %%
implot = plt.imshow(img)

# %% [markdown]
# ![](https://media2.giphy.com/media/h8CijQ4ve4A2G77QrJ/200w.webp?cid=ecf05e475fsdgs2x5pc79rqo3thr7quyqvav0u0ei0xhxwaw&rid=200w.webp)

# %%
#Code by Olga Belitskaya https://www.kaggle.com/olgabelitskaya/sequential-data/comments
from IPython.display import display,HTML
c1,c2,f1,f2,fs1,fs2=\
'#eb3434','#eb3446','Akronim','Smokum',30,15
def dhtml(string,fontcolor=c1,font=f1,fontsize=fs1):
    display(HTML("""<style>
    @import 'https://fonts.googleapis.com/css?family="""\
    +font+"""&effect=3d-float';</style>
    <h1 class='font-effect-3d-float' style='font-family:"""+\
    font+"""; color:"""+fontcolor+"""; font-size:"""+\
    str(fontsize)+"""px;'>%s</h1>"""%string))
    
    
dhtml('Kaggle Notebook Runner: Marília Prata, not a DS. Stick around, I will be right back. @mpwolke' )
