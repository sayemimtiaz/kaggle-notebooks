# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('/kaggle/input/montcoalert/911.csv')

# %%
df.head()

# %%
df.head(10)

# %%
df.info()

# %%
df['lat'].mean()

# %%
df['lat'].max()

# %%
df.head()

# %%
df['zip'].count()

# %%
df.groupby('title').mean('lat')

# %%
sns.pairplot(zip)
