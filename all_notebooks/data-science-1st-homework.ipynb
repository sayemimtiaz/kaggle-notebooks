# %% [markdown]
# **1.** age of patient
#
# **2.** sex of patient (0 = Female, 1 = Male)
#
# **3. cp :** type of pain in the patient's chest (4 types: 1= typical angina,2= atypical angina,3= non-anginal pain,
#                                                           4= asymptomatic)
#
# **4. tresbps:** patient's resting blood pressure (mm Hg)
#
# **5. chol:** patient's serum cholestoral in mg/dl
#
# **6. fbs:** patient's fasting blood sugar > 120 mg/dl (True = 1, False = 0)
#
# **7.restecg:** patient's resting electrocardiographic measurementresting electrocardiographic results (3 types: 0 = normal,                1 = having ST-T wave abnormality, 2 = showing probable or definite left ventricular hypertrophy by Estes'                  criteria)
#
# **8. thalach:** patient's maximum heart rate achieved (bps)
#
# **9. exang:** exercise induced angina (Yes(1) or no(0))
#
# **10. oldpeak:** ST depression induced by exercise relative to rest
#
# **11. slope:** the slope of the peak exercise ST segment (3 types of slope: 1= upsloping, 2= flat, 3= downsloping)
#
# **12. ca:** number of major vessels (0-3)
#
# **13. thal:** 3 = normal; 6 = fixed defect; 7 = reversable defect
#
# **14. target:** had a heart disease? (1 = Yes, 0 = No)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns #data visualization tool

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
data = pd.read_csv('/kaggle/input/heart-disease-uci/heart.csv') #read the data
data.head()     #checking data and see first 5 outputs

# %%
data.columns  #see all the columns of data

# %%
data.info()  #checking data's types

# %%
data.corr()  #compare datas if close to 1 its positive correlation 
                          # if close to -1 its negative correlation

# %%
#correlation map
f,ax = plt.subplots(figsize = (12,12))
sns.heatmap(data.corr(), annot = True, linewidths =.5, fmt = '.2f',ax=ax)
plt.show()

# %% [markdown]
# # 1- MATPLOTLIB

# %%
#1- Line plot
# color = color, label = label, linewidth = width of line, alpha = opacity, grid = grid, linestyle = style of lines
data.slope.plot(kind = 'line', color = 'purple', label = 'slope', linewidth = 1, alpha = .9, grid = True, linestyle = '-.')
data.oldpeak.plot(color = 'green', label = 'oldpeak', linewidth = 1, alpha =.9, grid = True, linestyle = ':' )
plt.xlabel('slope axis')
plt.ylabel('oldpeak axis')
plt.title('Line Plot')
plt.show()

# %% [markdown]
# Correlation value which between slope and oldpeak is -0.58. As you can see those values has kind of negative correlation.

# %%
#2- Scatter plot
plt.scatter(data.cp,data.thalach,color='purple',alpha = .7)
plt.xlabel('Chest Pain Type')
plt.ylabel('Maximum Heart Rate Achieved')
plt.title('Scatter Plot')

# %%
#3- Histogram
data.trestbps.plot(kind = 'hist',bins= 50, figsize =(15,15))
plt.show()

# %% [markdown]
# # 2- PANDAS

# %%
data = pd.read_csv('/kaggle/input/heart-disease-uci/heart.csv') #read the data

# %%
# 1 - Filtering Pandas data frame
data[data['trestbps']> 170]   # There are only 9 patients who have higher resting blood pressure (mm Hg) value than 170

# %%
# 2 - Filtering pandas with logical_and
data[(data['trestbps']>170) & (data['thalach']>160)] # There are only 3 patient who have higher resting blood pressure (mm Hg) value than 170 AND
                                                     #who have higher maximum heart rate achieved value than 160 bps
