# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ### Importing data

# %%
iris = pd.read_csv("/kaggle/input/iris-flower-dataset/IRIS.csv") #load dataset
df = iris.copy() #create a copy of the actual dataset

# %% [markdown]
# ### Displaying data

# %%
#first 5 observation of the dataset
df.head()

# %%
# Quick check: No Nan value, dataset includes only float and categorical values
df.info()

# %% [markdown]
# ### Scan for range of the numeric values

# %%
df.describe().T

# %% [markdown]
# ### Frequencies of length and width shows us how the values distributed

# %%
import matplotlib.pyplot as plt
df.hist(edgecolor = "black", linewidth = 1.5)
fig = plt.gcf()
fig.set_size_inches(14,7)
#plt.show()

# %%
df["species"].value_counts()

# %% [markdown]
# #### This dataset have 3 variables as target values

# %%
import seaborn as sns
sns.boxplot(x = df.sepal_width)
# Some outliers observed

# %% [markdown]
# ### Relationships between length and width

# %%
sns.scatterplot(x = "petal_length", y = "petal_width", hue = "species", data = df)

# %%
sns.scatterplot(x = "sepal_length", y = "sepal_width", hue = "species", data = df)

# %% [markdown]
# ### Densities of variables

# %%
plt.figure(figsize=(12,10))
plt.subplot(2,2,1)
sns.violinplot(x = "species",y= "petal_length",data=iris);
plt.subplot(2,2,2)
sns.violinplot(x = "species",y= "petal_width",data=iris);
plt.subplot(2,2,3)
sns.violinplot(x = "species",y= "sepal_length",data=iris);
plt.subplot(2,2,4)
sns.violinplot(x = "species",y= "sepal_width",data=iris);

# %% [markdown]
# #### Inference : petal_length and petal_width are more distincive values for classification of the target value

# %%
sns.pairplot(df, hue = "species");
