# %%
import pandas as pd
train = pd.read_csv('../input/step2-zte/train_step2.csv')
train.head()

# %%
data = pd.DataFrame()
for i in list(train.groupby('id')):
    #num = train[train['id']==i[1]['id'].unique()[0]]['value'].median()
    data = data.append(i[1][-5:])
    #data['value'] = data['value'].fillna(num)

# %%
x = data.groupby('id').median('value')

# %%
test = pd.read_csv('../input/step2-zte/test_step2.csv')
x=x[x.index.isin(test['id'].unique())]

# %%
df = pd.DataFrame(x)
l = list(df['value'])

# %%
value = [val for val in l for j in range(91)]

# %%
test['value'] = value
test['value'] = test['value']*1.025
test['value'] = test['value'].fillna('nan')

# %%
test.to_csv('sub.txt', sep=',',index=False, header=True)
