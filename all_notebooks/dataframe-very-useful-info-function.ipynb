# %%
# !pip install fast_ml --upgrade

# %%
import numpy as np 
import pandas as pd 
pd.set_option('display.max_columns',1000)


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv('/kaggle/input/analytics-vidhya-job-a-thon-may-2021/train_s3TEQDk.csv')
print('Dataframe shape:', df.shape)
df.head()

# %% [markdown]
# # Powerful Dataframe Info Function from `fast_ml`
#
# ## This function provides several useful information about dataset --
# 1. Data Type of variables
# 1. Cardinality info
# 1. Quick view on the values for each variable
# 1. Missing info

# %%
from fast_ml import eda
from fast_ml.utilities import display_all

# %%
df_summary = eda.df_info(df)
display_all(df_summary)
