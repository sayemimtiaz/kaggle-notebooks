# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
data=pd.read_csv("../input/clothessizeprediction/final_test.csv")
data.head()

# %%
data.index

# %%
data.columns

# %%
data.shape

# %%
data.size

# %%
data.memory_usage()

# %%
data.ndim

# %%
data.dtypes

# %%
data.isnull().sum()

# %%
data["age"].fillna(data["age"].mean(),inplace=True)
data["height"].fillna(data["height"].mean(),inplace=True)

# %%
data.isnull().sum()

# %%
import matplotlib.pyplot as plp
import seaborn as sns

# %%
sns.histplot(data["age"],bins=25)

# %%
sns.jointplot(x="age",y="height",data=data,kind='reg')

# %%
#sns.pairplot(data,hue="size",palette="cividis_r")

# %%
sns.barplot(x="size",y="height",data=data)

# %%
sns.boxplot(x="size",y="weight",data=data)

# %%
sns.violinplot(x="size",y="height",data=data,split=True)

# %%
sns.kdeplot(data["weight"])

# %%
plp.figure(figsize=(8,6))
sns.set_context('paper',font_scale=1.4)
data2=data.corr()
sns.heatmap(data2,cmap="icefire")

# %%
data["age"]=data["age"].astype(float)

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

# %%
x=data.drop(["size"],axis=1)
y = data['size'].values

# %%
encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)
y_encoded = to_categorical(y_encoded)
y_encoded

# %%
from sklearn.model_selection import train_test_split

x_train, x_test,y_train,y_test = train_test_split(x,y,test_size=0.33, random_state=8)

# %%
from sklearn.ensemble import ExtraTreesClassifier
rrc=ExtraTreesClassifier(n_estimators=10,criterion='entropy')
rrc.fit(x_train,y_train)

# %%
y_pred=rrc.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy_score= accuracy_score(y_test,y_pred,3)

# %%
accuracy_score

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential([
    Dense(10, activation='relu', input_shape=(3,)),
    Dense(1,activation="sigmoid")
])

# %%
model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
#model.fit(x_train,y_train,epochs=100)

# %%
#model.evaluate(x_test,y_test)[1]

# %%
# !conda update numpy
