# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# **Import Data**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Read Data**

# %%
df = pd.read_csv("/kaggle/input/insurance-prediction/insurance.csv")
new_df = df.copy()

# %% [markdown]
# **EDA**

# %%
df.sample(5)

# %%
df.columns

# %%
df.isna().sum()

# %%
df.head()

# %%
df.info()

# %%
df['smoker'].unique()

# %%
df['sex'].unique()

# %%
df['children'].unique()

# %%
df['region'].unique()

# %%
num_feau = ['age','bmi','children','region']
cat_feau = ['sex','smoker']

# %%
target = df['charges']

# %%
target.plot.hist(bins = 80)

# %%
target.describe()

# %%
sns.histplot(target,kde=True)

# %%
sns.histplot(target,kde=True,log_scale=True)

# %%
sns.heatmap(df.corr())

# %%
df.corr()

# %%
new_df = df[['age','sex','bmi','children','smoker','region']]

# %%
sns.catplot(x="smoker", y='charges', kind="box", data=df)

# %%
plt.scatter(x=new_df['age'],y=target)

# %%
plt.scatter(x=new_df['bmi'],y=target)

# %% [markdown]
# **Modeling**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
import numpy as np

# %%
target = np.log(target)

# %%
x_train, x_test, y_train, y_test = train_test_split(new_df,target, test_size=0.3)

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)

# %%
 y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
import numpy as np

# %%
np.sqrt(mean_squared_error(y_test,y_pred))

# %%
len(y_test)

# %%
r2_score(y_test,y_pred)
