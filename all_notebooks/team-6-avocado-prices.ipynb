# %% [markdown]
# ## MINI PROJECT
# Arin Supaorasa 1600902355
#
# Saharat Sawangcharoen 1600900961

# %% [markdown]
# ## Question And Problem Definition
#
# สำรวจราคาของอโวคาโดทั้ง2ชนิดในแต่ละภูมิภาคของ US ตั้งแต่ปี 2015-2018
#
# เพื่อนำมาวิเคราะห์และคาดการณ์ราคาอโวคาโดให้ลูกค้าที่สนใจอยากจะลงทุนทำการเกษตรหรือค้าขายว่ามีสถิติเป็นอย่างไร

# %% [markdown]
# ## Acquire training and testing data.

# %%
import pandas as pd
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from fbprophet import Prophet


avocados = pd.read_csv(
    '../input/avocado.csv',
    index_col=0,
)

# %%
avocados['Date'] = pd.to_datetime(avocados['Date'])
avocados.head()

# %% [markdown]
# ## Feature Descriptions:
# Date - The date of the observation
#
# AveragePrice - the average price of a single avocado
#
# type - conventional or organic
#
# year - the year
#
# Region - the city or region of the observation
#
# Total Volume - Total number of avocados sold
#
# 4046 - Total number of avocados with PLU 4046 sold
#
# 4225 - Total number of avocados with PLU 4225 sold
#
# 4770 - Total number of avocados with PLU 4770 sold

# %% [markdown]
# ## Wrangle, Prepare, Cleanse The Data

# %%
listdate  = avocados["Date"]
print(listdate)

# %%
avocados.Date.value_counts()

# %%
avocados.region.value_counts()

# %%
avocados["AveragePrice"].max()

# %% [markdown]
# ราคาเฉลี่ยสูงสุดของอโวคาโด จากชุดข้อมูลที่นำมาใช้

# %%
avocados["AveragePrice"].min()

# %% [markdown]
# ราคาเฉลี่ยต่ำสุดของอโวคาโด จากชุดข้อมูลที่นำมาใช้

# %%
avocados.groupby('year')['Total Volume'].max()

# %% [markdown]
# จำนวนอโวคาโดทั้งหมดในแต่ละปี

# %%
avocados.groupby('year')['AveragePrice'].max()

# %% [markdown]
# ราคาเฉลี่ยอโวคาโดในแต่ละปีที่ผ่านมา

# %%
avocados.groupby('region')['AveragePrice'].max()

# %% [markdown]
# ราคาเฉลี่ยสูงสุดของอโวคาโดในแต่ละภูมิภาค

# %%
avocados.groupby('region')['AveragePrice'].min()

# %% [markdown]
# ราคาเฉลี่ยต่ำสุดของอโวคาโดในแต่ละภูมิภาค

# %% [markdown]
# ## Analyze, identify patterns, and explore the data

# %% [markdown]
# สร้างกราฟดูการกระจายของค่าเฉลี่ย

# %%
# set the size of the figure
plt.figure(figsize=(16,8))
# set the title
plt.title("Distribution of the Average Price")
# plot the distribution
ax = sns.distplot(avocados["AveragePrice"])

# %%
# set the size of the figure
plt.figure(figsize=(16,8))
# set the title
plt.title("BoxPlot of AveragePrice")
# plot the boxplot
ax = sns.boxplot(avocados["AveragePrice"])

# %%
# set the size of the figure
plt.figure(figsize=(16,8))
# set the title
plt.title("Type v.s. AveragePrice")
# plot Type v.s. AveragePrice
ax = sns.boxplot(y="type", x="AveragePrice", data=avocados, palette = 'pink')

# %% [markdown]
# สร้างกราฟเพื่อดูราคาเฉลี่ยอโวคาโดประเภท organic

# %%
sns.set_style('white')

# %%
mask = avocados['type']=='organic'
g = sns.factorplot('AveragePrice','region',data=avocados[mask],
                   hue='year',
                   size=8,
                   aspect=0.6,
                   palette='Blues',
                   join=False,
              )

# %% [markdown]
# สร้างกราฟเพื่อดูราคาเฉลี่ยอโวคาโดประเภท conventional

# %%
mask = avocados['type']=='conventional'
g = sns.factorplot('AveragePrice','region',data=avocados[mask],
                   hue='year',
                   size=8,
                   aspect=0.6,
                   palette='Blues',
                   join=False,
              )

# %% [markdown]
# จากกราฟด้านบน
#
# จะเป็นการแสดงราคาเฉลี่ยของอโวคาโดทั้งสองชนิดในแต่ละภูมิภาคตั้งแต่ปี 2015-2018

# %% [markdown]
# ทำการจัดเรียงโดยใช้ราคาเฉลี่ย

# %%
order = (
    avocados[mask & (avocados['year']==2018)]
    .groupby('region')['AveragePrice']
    .mean()
    .sort_values()
    .index
)

# %%
g = sns.factorplot('AveragePrice','region',data=avocados[mask],
                   hue='year',
                   size=8,
                   aspect=0.6,
                   palette='Blues',
                   order=order,
                   join=False,
              )

# %% [markdown]
# จากกราฟด้านบน
#
# จะแสดงให้เห็นว่าภูมิภาค Phoenix Tucson มีราคาเฉลี่ยของอโวคาโดถูกที่สุดและภูมิภาค chicago มีราคาเฉลี่ยอโวคาโดเเพงที่สุด
#
# เราจะทำการเปรียบเทียบราคาอโวคาโดในแต่ละปีระหว่าง Chicago และ Phoenix Tucson อย่างละเอียด

# %%
regions = ['PhoenixTucson', 'Chicago']

# %%
mask = (
    avocados['region'].isin(regions)
    & (avocados['type']=='conventional')
)

# %% [markdown]
# เราจะทำการสร้างคอลัมน์ เดือน เพิ่มขึ้นมาแยกจาก วันที่

# %%
avocados['Month'] = avocados['Date'].dt.month
avocados[mask].head()

# %%
g = sns.factorplot('Month','AveragePrice',data=avocados[mask],
               hue='year',
               row='region',
               aspect=2,
               palette='Blues',
              )

# %% [markdown]
# กราฟแสดงการเปรียบเทียบราคาเฉลี่ยของอโวคาโดในแต่ละเดือนตั้งแต่ปี 2015-2018 ระหว่าง Chicago และ Phoenix Tucson

# %% [markdown]
# สร้างกราฟเพื่อดูราคาเฉลี่ยอโวคาโดทั้งสองชนิดในปี 2015-2018 โดยแยกเป็นกราฟละหนึ่งปี

# %% [markdown]
# กราฟราคาเฉลี่ยของปี 2015

# %%
yr2015 = avocados.loc[avocados['year'].isin(['2015'])]
yr2015.head()

# %%
g = sns.factorplot(data=yr2015, kind='swarm', palette='magma', x='type', y='AveragePrice', hue='region')

# %% [markdown]
# กราฟราคาเฉลี่ยของปี 2016

# %%
yr2016 = avocados.loc[avocados['year'].isin(['2016'])]
yr2016.head()

# %%
g = sns.factorplot(data=yr2016, kind='swarm', palette='magma', x='type', y='AveragePrice', hue='region')

# %% [markdown]
# กราฟราคาเฉลี่ยของปี 2017

# %%
yr2017 = avocados.loc[avocados['year'].isin(['2017'])]
yr2017.head()

# %%
g = sns.factorplot(data=yr2017, kind='swarm', palette='magma', x='type', y='AveragePrice', hue='region')

# %% [markdown]
# กราฟราคาเฉลี่ยของปี 2018

# %%
yr2018 = avocados.loc[avocados['year'].isin(['2018'])]
yr2018.head()

# %%
g = sns.factorplot(data=yr2018, kind='swarm', palette='magma', x='type', y='AveragePrice', hue='region')

# %% [markdown]
# สร้างกราฟเปรียบเทียบราคาระหว่างทั้ง2ชนิด โดยเทียบจากวันที่และราคาเฉลี่ย

# %%
# plt date vs. AveragePrice
# set the size of the figure
plt.figure(figsize=(16,8))
# set the title
plt.title("Date v.s. AveragePrice")

ax = sns.tsplot(data=avocados, time="Date", unit="region",condition="type", value="AveragePrice")

# %% [markdown]
# Total US ใช้เพื่ออ้างอิงความถูกต้องของการคาดการณ์

# %%
totalUS = avocados.loc[avocados['region'].isin(['TotalUS'])]
totalUS.head()

# %%
g = sns.factorplot(data=totalUS, kind='box', x='year', y='AveragePrice', palette='winter')
g.fig.suptitle("Total US: Avocado prices")

# %%
g = sns.factorplot(data=totalUS, kind='swarm', x='year', y='AveragePrice', hue='type', palette='winter')
g.fig.suptitle("Total US: Average avocado price")

# %%
g = sns.factorplot(data=totalUS, kind='swarm', palette='hls', x='type', y='AveragePrice', hue='year')
g.fig.suptitle("Total US: average avocado price")

# %% [markdown]
# ## Predicting Avocado Prices By Region

# %%
avocados.groupby('type').groups

# %% [markdown]
# จากข้อมูลเราได้อโวคาโด 2 ประเภทเพื่อนำมาวิเคราะห์

# %% [markdown]
# เลือกอโวคาโดชนิด organic เพื่อทำการคาดการณ์

# %%
#ทำแยกแล้ว error จึงใช้การพิมเพื่อเปลี่ยนชนิดของอโวคาโดแทน (organic,coventional)
PREDICTION_TYPE = 'organic'
avocados = avocados[avocados.type == PREDICTION_TYPE]

# %%
avocados['Date'] = pd.to_datetime(avocados['Date'])

# %% [markdown]
# ตรวจสอบว่ามีกี่ภูมิภาคที่แตกต่างกันและมีจำนวนเท่าใด

# %%
regions = avocados.groupby(avocados.region)
print("Total regions :", len(regions))
print("-------------")
for name, group in regions:
    print(name, " : ", len(group))

# %% [markdown]
# แต่ละภูมิภาคมีรายการ 169 รายการ ขั้นตอนต่อไปคือการเลือกภูมิภาคซึ่งเราต้องการคาดการณ์ราคาในอนาคต

# %% [markdown]
# เลือกภูมิภาคที่จะทำการคาดการณ์

# %%
PREDICTING_FOR = "TotalUS"

# %% [markdown]
# สร้างกราฟคาดการณ์ราคาเฉลี่ยในแต่ละวัน

# %%
date_price = regions.get_group(PREDICTING_FOR)[['Date', 'AveragePrice']].reset_index(drop=True)

# %%
date_price.plot(x='Date', y='AveragePrice', kind="line")
