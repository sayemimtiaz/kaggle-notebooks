# %% [markdown]
# สึนามิ

# %% [markdown]
# 1. Question or problem definition.
#
#
# สึนามิ คือ ภัยพิบัติที่เกิดขึ้นทางธรรมชาติ และมีการเกิดขึ้นหลายครั้งทั่วโลก ซึ่งเป็นภัยที่เกิดขึ้นแบบไม่มีการเตือนภัยล่วงหน้าและเกิดการสูญเสียอย่างหนัก
#
# จึงเป็นที่มาของการเก็บสถิติของการเกิดสึนามิ เพื่อเป็นข้อมูลที่เป็นประโยชน์ให้แก่นักพัฒนาสิ่งแวดล้อมหรือผู้ที่เกี่ยวข้องได้ทำการศึกษาแนวโน้มในการเกิดเพื่อทำการวิจัยว่าเหตุใดถึงเกิดขึ้น และ ประเทศใดเกิดขึ้นเยอะที่สุด เพราะอะไร หรือมีปัจจัยใดที่ทำให้เกิด และเราจะสามารถลดหรือช่วยกันได้อย่างไร ถ้าไม่มี ก็อาจจะเป็นการทำสร้างเทคโนโลยีขึ้นเพื่อเตือนภัยที่จุดนั้นได้เพื่อให้เกิดการเคลื่อนย้ายได้ทันเวลา

# %% [markdown]
# 2. Acquire training and testing data.
#
# #เอาข้อมูล import ของข้อมูลใส่ในตาราง
# #นำข้อมูล นำเข้าใส่ตารางมีข้อมูลดังนี้
#
# YEAR ปีที่เกิด
# MONTH เดือนที่เกิด
# DAY วันที่เกิด
# HOUR เกิดระยะเวลากี่ชั่วโมง
# MINUTE เกิดระยะเวลากี่นาที
# CAUSE เป็นเหตุการณ์แบบไหน
# VALIDITY เหตุผลที่เกิด
# FOCAL_DEPTH ความลึกของสึนามี
# PRIMARY_MAGNITUDE การเกิดความแรงในขั้นแรก
# REGION_CODE เกิดขึ้นบริเวณใด
# ALL_INJURIES การบาดเจ็บทั้งหมด
# INJURY_TOTAL ยอดรวมของการบาดเจ็บ
# ALL_FATALITIES เสียชีวิต
# FATALITY_TOTAL อุบัติเหตุ
# ALL_DAMAGE_MILLIONS ความเสียหายทั้งหมด
# DAMAGE_TOTAL ความเสียหายทั้งหมด
# ALL_HOUSES_DAMAGED บ้านเรือนทั้งหมดที่ถูกทำลาย
# HOUSE_DAMAGE_TOTAL จำนวนบ้านที่ได้รับความเสียหาย
# ALL_HOUSES_DESTROYED HOUSE_DESTRUCTION_TOTAL

# %%
import numpy as np # ใส่ค่าimport จากข้อมูลที่มี
import pandas as pd # ประมวลผลข้อมูลdata , CSV file I/O (e.g. pd.read_csv)

#อ่านไฟล์
tsunami_data = pd.read_csv('../input/sources.csv', sep=",", header=0, index_col=0)
tsunami_data.head()

# %% [markdown]
# 3. Wrangle, prepare, cleanse the data.
#
# ใส่แยกข้อมูลที่ต้องการจะใช้

# %%
# ตรวจสอบข้อมูล ID, ไม่มี correlatives. 
# แล้วจัดทำข้อมูล reset_index ถูกต้อง

tsunami_data.reset_index(drop=True, inplace=True)
tsunami_data.head()

# %%
#ค่าซ้ำและ NaN
#ตรวจสอบหมายเลขของแถว
print("Before cleaning: ",tsunami_data.index)

#Drop and clean row to duplicates
tsunami_data.dropna()
tsunami_data.drop_duplicates()

print("After cleaning: ",tsunami_data.index)

#ไม่มีแถวซ้ำกัน.

# %% [markdown]
# ### Group by Countries
#
# ญี่ปุ่นเป็นที่รู้จักในเรื่องของจำนวนสึนามิในช่วงประวัติศาสตร์ปัจจุบันทุกวันนี้มีชื่อเสียงที่น่าเศร้าเนื่องจากสึนามิในปี 2554

# %% [markdown]
# 4. Analyze, identify patterns, and explore the data.
#
# วิเคราะห์ข้อมูลที่เลือกมา ข้อมูลที่ใช้คือข้อมูลการเกิดสึนามิแต่ละประเทศเป็นความถี่ที่เกิดขึ้น

# %%
#จัดกลุ่มตามประเทศ
tsunami_data['COUNTRY_FRECUENCY'] = tsunami_data.groupby(tsunami_data.COUNTRY)['COUNTRY'].transform('count')

# %%
#ข้อมูลสึนามิจากหลายประเทศ
tsunami_data.COUNTRY[tsunami_data.COUNTRY_FRECUENCY > 50].value_counts().plot(kind='bar',
                                             legend=False,
                                             figsize=(12,5),
                                             title="Tsunamis frecuency by countries > 50",
                                             fontsize=12,
                                             alpha=0.5
                                            );

# %% [markdown]
# ความถี่ในการเกิดสึนามิมากกว่า 50 ครั้ง ของในแต่ละประเทศ
# ซึ่งมี
#
# ประเทศญี่ปุ่น (Japan) เกิดประมาณ 350
# ประเทศสหรัฐอเมริกา (USA) เกิดประมาณ 250
# ประเทศอินโดนีเซีย (Indonesia) เกิดประมาณ 240
# ประเทศกรีซ (greece) เกิดประมาณ 160
# ประเทศชิลี (chile) เกิดประมาณ 155
# ประเทศอิตาลี (italy) เกิดประมาณ 150
# ประเทศรัสเซีย (russia) เกิดประมาณ 100
# ปรเทศฟิลิปปินส์ (philippines) เกิดประมาณ 95
# ประเทศนิวซีแลนด์ (new zealand) เกิดประมาณ 90
# ประเทศปาปัวนิวกินี (papua new guinea) เกิดประมาณ 80
# ประเทศเปรู (peru) เกิดประมาณ 70
# ประเทศตุรกี (turkey) เกิดประมาณ 60
# ประเทศเม็กซิโก (mexioc) เกิดประมาณ 50

# %%
#Tsunamis ความถี่ (year > 1950)
tsunami_data.COUNTRY[(tsunami_data.YEAR >= 1950) & (tsunami_data.COUNTRY_FRECUENCY > 50)].value_counts().plot(kind='bar',
                                             legend=False,
                                             figsize=(12,5),
                                             title="Tsunamis frecuency by countries (Year >= 1950)",
                                             fontsize=12,
                                             alpha=0.5
                                            );

# %% [markdown]
# ความถี่ในการเกิดสึนามิในช่วงปี 1950 เป็นต้นมา ของในแต่ละประเทศ
# ซึ่งมี
#
# ประเทศญี่ปุ่น (Japan) เกิดประมาณ 100 ขึ้นไป
# ประเทศสหรัฐอเมริกา (USA) เกิดประมาณ 65
# ประเทศอินโดนีเซีย (Indonesia) เกิดประมาณ 60
# ประเทศรัสเซีย (russia) เกิดประมาณ 55
# ประเทศชิลี (chile) เกิดประมาณ 50
# ประเทศปาปัวนิวกินี (papua new guinea) เกิดประมาณ 35
# ประเทศกรีซ (greece) เกิดประมาณ 30
# ปรเทศฟิลิปปินส์ (philippines) เกิดประมาณ 28
# ประเทศนิวซีแลนด์ (new zealand) เกิดประมาณ 25
# ประเทศเปรู (peru) เกิดประมาณ 20
# ประเทศเม็กซิโก (mexioc) เกิดประมาณ 20
# ประเทศอิตาลี (italy) เกิดประมาณ 10
# ประเทศตุรกี (turkey) เกิดประมาณ 5

# %% [markdown]
# ### จัดกลุ่มตามภูมิภาค
#
# ชุดข้อมูลนี้แบ่งสึนามิตามภูมิภาค เรากำลังจะพบสิ่งที่อยากรู้อยากเห็นมีภูมิภาคที่มีสึนามิบันทึกไว้มากกว่าญี่ปุ่นตามประวัติศาสตร์

# %% [markdown]
# 5. Model, predict and solve the problem.

# %%
#การทำแผนที่ภูมิภาคที่แตกต่าง
regions = {77:'West Coast of Africa',
            78:'Central Africa',
            73:'Northeast Atlantic Ocean',
            72:'Northwest Atlantic Ocean',
            70:'Southeast Atlantic Ocean',
            71:'Southwest Atlantic Ocean',
            75:'E. Coast USA and Canada, St Pierre and Miquelon',
            76:'Gulf of Mexico',
            74:'Caribbean Sea',
            40:'Black Sea and Caspian Sea',
            50:'Mediterranean Sea',
            30:'Red Sea and Persian Gulf',
            60:'Indian Ocean (including west coast of Australia)',
            87:'Alaska (including Aleutian Islands)',
            84:'China, North and South Korea, Philippines, Taiwan',
            81:'E. Coast Australia, New Zealand, South Pacific Is.',
            80:'Hawaii, Johnston Atoll, Midway I',
            83:'E. Indonesia (Pacific Ocean) and Malaysia',
            82:'New Caledonia, New Guinea, Solomon Is., Vanuatu',
            86:'Kamchatka and Kuril Islands',
            85:'Japan',
            88:'West Coast of North and Central America',
            89:'West Coast of South America'}


tsunami_data['REGIONS'] = tsunami_data['REGION_CODE'].map(regions)

#จัดกลุ่มตามภูมิภาค
tsunami_data['REGIONS_FRECUENCY'] = tsunami_data.groupby(tsunami_data.REGIONS)['REGIONS'].transform('count')

# %%
#ความถี่ทางภูมิภาค(ความสูงของคลื่น) ที่สูงกว่า100 โดยใช้ค่า REGIONS มาคำนวน
tsunami_data.REGIONS[tsunami_data.REGIONS_FRECUENCY > 100].value_counts().plot(kind='barh',
                                              legend=False,
                                              figsize=(8,7),
                                              title="Tsunamis by Regions",
                                              alpha=0.5);

# %% [markdown]
# ความสูงของคลื่น(เมตร)ในแต่ละภูมิภาคที่มีความรุ่นแรง
#
# Caribbean Sea (ทะเลแคริเบียน) 120
# Northeast Atlantic Ocean (มหาสมุทรแอตแลนติกตะวันออกเฉียงเหนือ) 120
# E. Indonesia (Pacific Ocean) and Malaysia (อินโดนีเซีย (มหาสมุทรแปซิฟิก) และมาเลเซีย) 130
# Indian Ocean (including west coast of Australia (มหาสมุทรอินเดีย (รวมถึงชายฝั่งตะวันตกของออสเตรเลีย) 150
# New Caledonia, New Guinea, Solomon Is., Vanuatu (นิวแคลิโดเนียนิวกินีเกาะโซโลมอนคือวานูอาตู) 160
# E. Coast Australia, New Zealand, South Pacific Is (ชายฝั่งออสเตรเลีย, นิวซีแลนด์, แปซิฟิกใต้) 165
# China, North and South Korea, Philippines, Taiwan (จีน, เกาหลีเหนือและเกาหลีใต้, ฟิลิปปินส์, ไต้หวัน) 170
# West Coast of North and Central America (ชายฝั่งตะวันตกของอเมริกาเหนือและอเมริกากลาง) 200
# West Coast of South America (ชายฝั่งตะวันตกของอเมริกาใต้) 250
# Japan (เกาะญี่ปุ่น) 360
# Mediterranean Sea (ทะเลเมดิเตอร์เรเนียน) มากว่า400

# %%
#ความถี่ที่เกิดขึ้นต่อปีที่มีความรุ่นแรงที่ค่ามากกว่า 100 โดยใช้ค่า YEAR มาคำนวน
tsunami_data.REGIONS[(tsunami_data.YEAR >= 1916) & (tsunami_data.REGIONS_FRECUENCY > 100)].value_counts().plot(kind='barh',
                                              legend=False,
                                              figsize=(8,7),                                                                                                               
                                              title="Tsunamis by Regions (Year >= 1916)",
                                              alpha=0.5);

# %% [markdown]
# ความแรงของสึนามิต่อปี ในแต่ละภูมิภาคความถี่ที่เกิดขึ้น
#
# Northeast Atlantic Ocean (มหาสมุทรแอตแลนติกตะวันออกเฉียงเหนือ) 30
# Caribbean Sea (ทะเลแคริเบียน)  80
# E. Indonesia (Pacific Ocean) and Malaysia (อินโดนีเซีย (มหาสมุทรแปซิฟิก) และมาเลเซีย) 45
# Indian Ocean (including west coast of Australia (มหาสมุทรอินเดีย (รวมถึงชายฝั่งตะวันตกของออสเตรเลีย) 75
# E. Coast Australia, New Zealand, South Pacific Is (ชายฝั่งออสเตรเลีย, นิวซีแลนด์, แปซิฟิกใต้ 78
# Mediterranean Sea (ทะเลเมดิเตอร์เรเนียน) 80
# China, North and South Korea, Philippines, Taiwan (จีน, เกาหลีเหนือและเกาหลีใต้, ฟิลิปปินส์, ไต้หวัน) 80
# West Coast of North and Central America (ชายฝั่งตะวันตกของอเมริกาเหนือและอเมริกากลาง) 90
# West Coast of South America (ชายฝั่งตะวันตกของอเมริกาใต้) 110
# New Caledonia, New Guinea, Solomon Is., Vanuatu (นิวแคลิโดเนียนิวกินีเกาะโซโลมอนคือวานูอาตู) 125
# Japan (เกาะญี่ปุ่น) มากกว่า 140

# %%
#การศึกษาจากประเทศตัวอย่างของ(USA) โดยใช้ค่า REGIONS มาคำนวน
tsunami_data.REGIONS[(tsunami_data.COUNTRY == 'USA')].value_counts().plot(kind='pie',
                                            legend=False,
                                            figsize=(8,7),
                                            title="Tsunamis by Regions (USA)",
                                            autopct='%.1f%%');

# %% [markdown]
# ### Group by Causes
#
# ชุดข้อมูลนี้แบ่งสึนามิตามสาเหตุ ของ USA เกิดขึ้นได้หลายที่คาบสมุด คิดเป็นเปอร์เซ็นต์
#
# West Coast of North and Central America (ชายฝั่งตะวันตกของอเมริกาเหนือและอเมริกากลาง) 35.5%
# Alaska (มลรัฐอะแลสกา) 31.2%
# Guif of Mexico (อ่าวเม็กซิโก) 0.4%
# เกาะHawaii, เกาะjohnston Atoii ,เกาะMidway 17.2%
# Coast USA and Canada , St Pierre and Miquelon (ชายฝั่งสหรัฐอเมริกาและแคนาดาเซนต์ปิแอร์และมีเกอลง) 15.6%

# %% [markdown]
# 6. Visualize, report, and present the problem solving steps and final solution.

# %%
#ใส่สาเหตุการเกิดสึนามิที่แตกต่างกัน (0-11) 
causes = {0:'Unknown',
          1:'Earthquake',
          2:'Questionable Earthquake',
          3:'Earthquake and Landslide',
          4:'Volcano and Earthquake',
          5:'Volcano, Earthquake, and Landslide',
          6:'Volcano',
          7:'Volcano and Landslide',
          8:'Landslide',
          9:'Meteorological',
          10:'Explosion',
          11:'Astronomical Tide'}

tsunami_data['CAUSES'] = tsunami_data['CAUSE'].map(causes)

#จัดกลุ่มตามสาเหตุ
tsunami_data['CAUSES_FRECUENCY'] = tsunami_data.groupby(tsunami_data.CAUSES)['CAUSES'].transform('count')

# %%
#สาเหตุของสึนามิ โดยใช้ค่า CAUSES มาคำนวน ที่ค่ามากกว่าหรือเท่ากับ 50
tsunami_data.CAUSES[tsunami_data.CAUSES_FRECUENCY >= 50].value_counts().plot(kind='pie',
                                            legend=False,
                                            figsize=(8,7),
                                            title="Causes of tsunamis",
                                            autopct='%.1f%%');

# %% [markdown]
# สาเหตุของการเกิดสึนามิส่วนใหญ่ล้วนเกิดจาก
#
# Landslide (แผ่นดินถล่ม) 3.5%
# Earthquake and Landslide (แผ่นดินไหวและดินถล่ม) 3.7%
# Meteorological (การเคลื่อนตัวของเปลือกโลก) 3.7%
# Volcano (ภูเขาไฟ) 4.7%
# Unknown (ไม่ทราบ) 10.7%
# Earthquake (แผ่นดินไหวให้น้ำ) 73.7%

# %%
#คลื่นสึนามิของปีตั้งแต่ (year > 1950) โดยใช้ค่า CAUSES ,YEAR ที่เป็นตัวเลขมาคำนวน ตั้งแต่ปี 1950 เป็นต้นไป
tsunami_data.COUNTRY[(tsunami_data.YEAR >= 1950) & (tsunami_data.COUNTRY_FRECUENCY > 50)].value_counts().plot(kind='bar',
                                            legend=False,
                                            figsize=(12,5),
                                            title="Tsunamis frecuency by countries (Year >= 1950)",
                                            fontsize=12,
                                            alpha=0.5
                                            );

# %% [markdown]
# ความถี่จากการเกิดสึนามิในประเทศที่มีโอกาศเกิดขึ้นสูงในประเทศตัวอย่าง เรียงลำดับ
#
# ประเทศญี่ปุ่น (Japan) โอกาสเกิดประมาณ 100 ขึ้นไป
# ประเทศสหรัฐอเมริกา (USA) โอกาสเกิดประมาณ 65
# ประเทศอินโดนีเซีย (Indonesia) โอกาสเกิดประมาณ 62
# ประเทศรัสเซีย (russia) โอกาสเกิดประมาณ 60
# ประเทศชิลี (chile) โอกาสเกิดประมาณ 50
# ประเทศปาปัวนิวกินี (papua new guinea) โอกาสเกิดประมาณ 40
# ประเทศกรีซ (greece) โอกาสเกิดประมาณ 30
# ปรเทศฟิลิปปินส์ (philippines) โอกาสเกิดประมาณ 28
# ประเทศนิวซีแลนด์ (new zealand) โอกาสเกิดประมาณ 25
# ประเทศเปรู (peru) โอกาสเกิดประมาณ 20
# ประเทศเม็กซิโก (mexioc) โอกาสเกิดประมาณ 20
# ประเทศอิตาลี (italy) โอกาสเกิดประมาณ 10
# ประเทศตุรกี (turkey) โอกาสเกิดประมาณ 5

# %%
#ค่าการคำนวนของการเกิดสาตุที่ได้มาทำเป็นความถี่ที่มาจากสาตุ ที่มีค่าเท่ากับ50 (แต่ละประเทศ)
tsunami_region_mediterranean = tsunami_data[tsunami_data['REGION_CODE'] == 50]
tsunami_region_mediterranean_no_unknown = tsunami_region_mediterranean[(tsunami_region_mediterranean['CAUSES'] != 'Unknown')
                                                                       & (tsunami_region_mediterranean['VALIDITY'] >= 3.0)]
tsunami_mediterranean_cause_group = tsunami_region_mediterranean_no_unknown.groupby(['COUNTRY','CAUSES'])

add_counts = tsunami_mediterranean_cause_group.size().unstack().fillna(0)
normed_subnet = add_counts.div(add_counts.sum(1), axis=0)
add_counts.plot(kind='barh', legend=True, figsize=(11,7), stacked=True);

# %% [markdown]
# การเกิดสึนามิในแต่ละประเทศมีความแตกต่างจากสาเหตุที่แตกต่างกันไป และความเสียหายที่ประเมินค่าไม่ได้จากสึนามิ
# ซึ่งจากกราฟพบว่าส่วนใหญ่ล้วนเกิดจากสาเหตุแผ่นดินไหวเป็นหลัก โดยประเทศที่มีอัตราการเกิดแผ่นดินไหวก่อนสึนามี คือ กรีซ,อิตาลี และ ตุรกี ตามลำดับ

# %%
#ใช้ค่าปีมาคำนวนด้วยกับค่าที่ได้จากสาเหตุ คำนวนจะได้ค่าที่เป็นความถี่ที่เป็นปี ที่เริ่มตั้งแต่ปี 1800 ขึ้นไป
tsunami_region_mediterranean_no_unknown_1800 = tsunami_region_mediterranean_no_unknown[(tsunami_region_mediterranean_no_unknown['YEAR'] >= 1800)
                                                                                      & (tsunami_region_mediterranean_no_unknown['VALIDITY'] >= 3.0)]
tsunami_region_mediterranean_no_unknown_1800_group = tsunami_region_mediterranean_no_unknown_1800.groupby(['COUNTRY','CAUSES'])

add_counts = tsunami_region_mediterranean_no_unknown_1800_group.size().unstack().fillna(0)
normed_subnet = add_counts.div(add_counts.sum(1), axis=0)
add_counts.plot(kind='barh', legend=True, figsize=(11,7), stacked=True);

# %% [markdown]
# ข้อมูลกราฟสึนามิในแต่ละปีโดยเริ่มต้นที่ปี 1800 ไปเรื่อยๆ
# การเกิดสึนามิในแต่ละประเทศมีความแตกต่างจากสาเหตุที่แตกต่างกันไปในแต่ละปี และความเสียหายที่ประเมินค่าไม่ได้จากสึนามิ ซึ่งจากกราฟพบว่าส่วนใหญ่ล้วนเกิดจากสาเหตุแผ่นดินไหวเป็นหลัก โดยประเทศที่มีอัตราการเกิดแผ่นดินไหวก่อนสึนามี คือ สเปน และ ตุรกี ตามลำดับ

# %% [markdown]
# 7. Supply or submit the results.

# %%
#สรุป แสองข้อมูลที่ได้จากการคำนวนทั้งหมด ที่เป็นค่าความถี่ที่เกิดสินามิทั้งหมด
tsunami_region_japan_1700 = tsunami_data[(tsunami_data['YEAR'] >= 1700) 
                                         & (tsunami_data['REGION_CODE'] == 85) 
                                         & (tsunami_data['CAUSES'] != 'Unknown')
                                         & (tsunami_data['VALIDITY'] >= 3.0)]
tsunami_region_japan_1700.count()
tsunami_region_japan_1700_group = tsunami_region_japan_1700.groupby(['DAMAGE_TOTAL','CAUSES'])

add_counts = tsunami_region_japan_1700_group.size().unstack().fillna(0)
normed_subnet = add_counts.div(add_counts.sum(1), axis=0)
add_counts.plot(kind='bar', legend=True, figsize=(11,7), stacked=True);

# %% [markdown]
# ข้อมูลชุดนี้จะเป็นประโยชน์แก่นักพัฒนาสิ่งแวดล้อมในการศึกษาและวิจัยการการสึนามิ โดยผลที่เกิดจากสึนามิล้วนมาจาก (คลื่นสึนามิเกิดขึ้นจากการกระทบกระเทือนที่ทำให้น้ำปริมาณมากเกิดการเคลื่อนตัว เช่น แผ่นดินไหว แผ่นดินถล่ม หรืออุกกาบาตพุ่งชน
# เมื่อแผ่นดินใต้ทะเลเกิดการเปลี่ยนรูปร่างอย่างกะทันหัน จะทำให้น้ำทะเลเกิดเคลื่อนตัวเพื่อปรับระดับให้เข้าสู่จุดสมดุลและจะก่อให้เกิดคลื่นสึนามิ การเปลี่ยนรูปร่างของพื้นทะเลมักเกิดขึ้นเมื่อเกิดแผ่นดินไหวเนื่องจากการขยับตัวของเปลือกโลก ซึ่งจะเกิดบริเวณที่ขอบของเปลือกโลกหลายแผ่นเชื่อมต่อกันที่เรียกว่า รอยเลื่อน (fault) เช่น บริเวณขอบของมหาสมุทรแปซิฟิก นอกจากแผ่นดินไหวแล้ว ดินถล่มใต้น้ำที่มักเกิดร่วมกับแผ่นดินไหวสามารถทำให้เกิดคลื่นสึนามิได้เช่นกันนอกจากการกระทบกระเทือนที่เกิดใต้น้ำแล้ว การที่พื้นดินขนาดใหญ่ถล่มลงทะเล หรือการตกกระทบพื้นน้ำของวัตถุ ก็สามารถทำให้เกิดคลื่นได้ คลื่นสึนามิที่เกิดในรูปแบบนี้จะลดขนาดลงอย่างรวดเร็วและไม่มีผลกระทบต่อชายฝั่งที่อยู่ห่างไกลมากนัก อย่างไรก็ตาม ถ้าแผ่นดินมีขนาดใหญ่มากพอ อาจทำให้เกิด เมกะสึนามิ ซึ่งอาจมีความสูงร่วมร้อยเมตรได้ และประเทศที่ได้รับความเสียหายมักเป็นประเทศ ชายฝั่งแปซิฟิกโทโฮ ญี่ปุ่น  11 มีนาคม 2011 คลื่นสึนามิความเร็ว 800 กิโลเมตรต่อขั่วโมง ความสูง 10 เมตร เข้าถาโถมกลืนกินชายฝั่งทางตะวันออกของญี่ปุ่น ส่งผลให้มีผู้เสียชีวิตมากกว่า 18,000 คน สึนามิในครั้งนั้นเกิดขึ้นจากเหตุแผ่นดินไหวขนาด 9 แมกนิจูด ที่ระดับความลึก 24.4 กิโลเมตร นับเป็นแผ่นดินไหวที่มีความรุนแรงมากเป็นอันดับ 4 เท่าที่เคยมีบันทึกมา ซึ่งนอกเหนือจากความเสียหายต่อชีวิตและทรัพย์สินแล้ว คลื่นสึนามิยังพัดถล่มโรงไฟฟ้านิวเคลียร์ฟูกูชิมะส่งผลให้แกนปฏิกรณ์ปรมาณูหลอมละลาย ชาวญี่ปุ่นนับแสนคนต้องอพยพจากที่อยู่อาศัย และปัจจุบันพื้นที่ดังกล่าวก็ยังไม่สามารถเข้าอยู่ได้เนื่องจากมีการรั่วไหลของรังสี

# %%
#tsunami_data.EVENT_VALIDITY.value_counts()
