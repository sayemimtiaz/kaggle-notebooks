# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ##Codes from Aleksey Bilogur https://www.kaggle.com/residentmario/250-segmented-bob-ross-paintings-starter-kernel/notebook

# %% [markdown]
# #Data exploration

# %%
import os
os.listdir('../input/goblin-portraits/images/')[:5]

# %%
from PIL import Image

# %%
imgs_dir = '../input/goblin-portraits/images/'
Image.open(imgs_dir + '00e67f01bb81bea81b8e.jpg')

# %%
Image.open(imgs_dir + '0430395cd38013467a15.jpg')

# %%
len(os.listdir('../input/goblin-portraits/images/'))

# %%
Image.open(imgs_dir + '0551372bdc314dd9feed.jpg')

# %%
import numpy as np
segmaps_dir = '../input/goblin-portraits/images/'
segmap = np.array(Image.open(segmaps_dir + '0430395cd38013467a15.jpg'))
segmap

# %%
np.unique(segmap)

# %%
np.array(Image.open(imgs_dir + '0430395cd38013467a15.jpg')).shape

# %%
np.array(Image.open(imgs_dir + '0551372bdc314dd9feed.jpg')).shape

# %%
import matplotlib.pyplot as plt
fig, axarr = plt.subplots(1, 2, figsize=(12, 4))
axarr[0].imshow(np.array(Image.open(imgs_dir + '0430395cd38013467a15.jpg')))
axarr[1].imshow(np.array(Image.open(segmaps_dir + '0430395cd38013467a15.jpg')))

# %%
fig, axarr = plt.subplots(1, 2, figsize=(12, 4))
axarr[0].imshow(np.array(Image.open(imgs_dir + '0551372bdc314dd9feed.jpg')))
axarr[1].imshow(np.array(Image.open(segmaps_dir + '0551372bdc314dd9feed.jpg')))

# %%
# %ls ../input/goblin-portraits/

# %%
import matplotlib.pyplot as plt
fig, axarr = plt.subplots(1, 2, figsize=(12, 4))
axarr[0].imshow(np.array(Image.open(imgs_dir + '0551372bdc314dd9feed.jpg')))
axarr[1].imshow(np.array(Image.open('../input/goblin-portraits/images/0551372bdc314dd9feed.jpg')))

# %% [markdown]
# It didn't worked for me. See the original from Aleksey Bilogur on the link below.

# %% [markdown]
# #Codes from Aleksey Bilogur  https://www.kaggle.com/residentmario/250-segmented-bob-ross-paintings-starter-kernel/notebook

# %% [markdown]
# Stick around, I will be right back    @mpwolke
