# %% [markdown]
# Hi,
# I used your dataset to filter out the global and country data via BigQuery. Then I exported the data to a csv and used tableau maps to show the monthwise status of each state. I just need to figureour how to fix the tableau maps to a regional setting as the tableau public doesn't represent Jammu and Leh properly. Any suggestions are welcome. Here's the link to the viz: https://public.tableau.com/app/profile/pratik.pattanaik/viz/CovidCasesIndia_16299790478570/CovidCasesIndia?publish=yes
