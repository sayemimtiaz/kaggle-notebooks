# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Importing functions for Map & Reduce

from itertools import groupby
from functools import reduce

print("Functions imported!")

# %%
# Reading from CSV file

df1 = pd.read_csv('/kaggle/input/audio-features-and-lyrics-of-spotify-songs/spotify_songs.csv')
df1.dataframeName = 'spotify_songs.csv'

# Printing the data

print(df1.sample(n=10))

# %%
# Intializing score variable

df1["Score"] = (2*df1["acousticness"] + 5*df1["liveness"] +  3*df1["instrumentalness"] + 3*df1["tempo"])/13
    
print(df1.head())

# %%
# Using Map, Shuffling and Reducing

songIndex = 1000

randomIndexSong = random.randint(1500, 1700)

for song in range(randomIndexSong, randomIndexSong + 1):
    
    # Selecting lyrics for the current song
    
    lyric = df1["lyrics"][song].split(" ")
    
    # Using Map function on lyric
    
    print("Strarting Map Function")
    
    mapping = list(map((lambda x : (x, 1)), lyric))
    
    print(mapping)
   
    # Using Sort function on lyric
    
    print("Strarting Sort Function")

    sorted_mapping = sorted(mapping)
    
    print(sorted_mapping)
    
    # Using Reduce function on lyric
    
    print("Strarting Reduce Function")
    
    grouper = groupby(sorted_mapping, lambda p:p[0])
    
    reducefn = list(map(lambda l: (l[0], reduce(lambda x, y: x + y, map(lambda p:p[1], l[1]))), grouper))
    
    print(reducefn)

# %%
import random
import re

# Defining a benchmark song

# Retrieving the score for our benchmark song

benchmarkIndex = random.randint(500, 700)

benchmarkScore = df1["Score"][benchmarkIndex]

print(benchmarkScore)

# Using Map, Shuffling and Reducing for Benchmark song
    
lyric = df1["lyrics"][song].split(" ")
    
# Using Map function on lyric
    
print("Strarting Map Function")
    
mapping = list(map((lambda x : (x, 1)), lyric))
    
print(mapping)
   
# Using Sort function on lyric
    
print("Strarting Sort Function")

sorted_mapping = sorted(mapping)
    
print(sorted_mapping)
    
# Using Reduce function on lyric
    
print("Strarting Reduce Function")
    
grouper = groupby(sorted_mapping, lambda p:p[0])
    
reducefn = list(map(lambda l: (l[0], reduce(lambda x, y: x + y, map(lambda p:p[1], l[1]))), grouper))

benchmarkList = []

for j in range(len(reducefn)):
    print(reducefn[j][0])
    benchmarkList.append(reducefn[j][0])

# %%
# Selecting top 25 songs using score

songIndex = 0
inner = 0
topList = []

for index in range(random.randint(100, 1000), random.randint(1000, 2000)):
    
    # Score for current song
    
    curScore = df1["Score"][index]
    trackName =  df1["track_name"][index]

    if(curScore > 0.9*benchmarkScore and curScore < 1.1*benchmarkScore):
        #print(str(trackName))
        
        songIndex += 1
        
            
        # Selecting lyrics for the current song
        try:
            lyric = df1["lyrics"][index].split(" ")
        except AttributeError:
            pass
    
        # Using Map function on lyric
    
        print("Starting Map Function")
    
        mapping = list(map((lambda x : (x, 1)), lyric))
    
        print(mapping)
   
        # Using Sort function on lyric
    
        print("Starting Sort Function")

        sorted_mapping = sorted(mapping)
    
        print(sorted_mapping)
    
        # Using Reduce function on lyric
    
        print("Starting Reduce Function")
    
        grouper = groupby(sorted_mapping, lambda p:p[0])
    
        reducefn = list(map(lambda l: (l[0], reduce(lambda x, y: x + y, map(lambda p:p[1], l[1]))), grouper))
    
        print(reducefn)
        
        currentList = []

        for j in range(len(reducefn)):
            print(reducefn[j][0])
            currentList.append(reducefn[j][0])
        
        newSet = set(currentList).intersection(benchmarkList)
        
        if(len(newSet)>10):
                print(df1["track_name"][inner])
                topList.append(df1["track_name"][inner])
                inner += 1
            
        if(inner==10):
            break
        
    
    if(songIndex == 1000):
        break

# %%
print("Top Songs - ")
print(topList)
