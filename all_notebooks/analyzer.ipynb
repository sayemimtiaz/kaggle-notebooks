# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Why this error comes ????????**
#
#
# I know Why But it's an assignment You people like. Please help me then I will do this complete.
#
#
# Thanks in advance.

# %%
data = pd.read_csv(r'../input/pulitzer-circulation-data.csv')
