# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import math

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
songs = pd.read_csv('/kaggle/input/spotify-12m-songs/tracks_features.csv')

# %% [markdown]
# ## List of songs & getting an idea of the data

# %%
songs

# %% [markdown]
# ## Data types of each column

# %%
songs.dtypes

# %% [markdown]
# ## Artists with most number of songs

# %%
songs['artists'].value_counts().head(10)

# %% [markdown]
# ## Division of explicit vs non explicit songs

# %%
print('Explicit lyrics songs:')
print(songs['explicit'].value_counts(normalize=True).mul(100).round(2).astype(str) + '%')
songs['explicit'].value_counts().plot.pie()

# %% [markdown]
# ## Song duration mean / median / mode

# %%
song_duration_mean = songs['duration_ms'].mean()
seconds=math.floor(song_duration_mean/1000)%60
if seconds < 10:
    seconds = '0' + str(seconds)
minutes=(song_duration_mean/(1000*60))%60
print ("The duration mean of songs: %d:%s" % (minutes, seconds))
# print(str(round(song_duration_mean / 60000)) + ': ' + str(song_duration_mean / 60000))

# %%
song_duration_median = songs['duration_ms'].median()
seconds=math.floor(song_duration_median/1000)%60
if seconds < 10:
    seconds = '0' + str(seconds)
minutes=(song_duration_median/(1000*60))%60
print ("The duration median of songs: %d:%s" % (minutes, seconds))

# %%
song_duration_mode = songs['duration_ms'].mode()
seconds=math.floor(song_duration_mode/1000)%60
if seconds < 10:
    seconds = '0' + str(seconds)
minutes=(song_duration_mode/(1000*60))%60
print ("The duration mode of songs: %d:%s" % (minutes, seconds))

# %% [markdown]
# ## Songs with most tempo

# %%
songs[['name', 'album', 'artists', 'tempo']].sort_values('tempo', ascending=False).head(10)

# %% [markdown]
# ## Most danceable songs

# %%
songs[['name', 'album', 'artists', 'danceability']].sort_values('danceability', ascending=False).head(10)

# %% [markdown]
# ## Oldest songs (according to release date)

# %%
# Some songs whose release date is unknown are simply marked with '0000' or '1900-01-01' or something similar, so we need to filter those out
songs[['name', 'album', 'artists', 'release_date']].loc[~songs['release_date'].isin(['0000', '1900-01-01', '1908-08-01'])].sort_values('release_date').head(10)

# %% [markdown]
# ## Oldest albums (according to release date)

# %%
# Some albums whose release date is unknown are simply marked with '0000' or '1900-01-01' or something similar, so we need to filter those out
songs[['album', 'artists', 'release_date']].drop_duplicates('album').loc[~songs['release_date'].isin(['0000', '1900-01-01', '1908-08-01'])].sort_values('release_date', ascending=True).head(10)
