# %% [markdown]
# ### Introduction
#
# This dataset is from UCI Machine Learning Repository. This dataset focuses on 14 attribute. To learn more about this dataset look at https://archive.ics.uci.edu/ml/datasets/Heart+Disease
#
# ### Motivation
# 1. EDA
# 2. multiple model to predict Heart Attack

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset

# %%
df= pd.read_csv("../input/heart-attack-analysis-prediction-dataset/heart.csv")
df.head()

# %% [markdown]
# ####         Attribute information
# *  age: age in years
# *  sex: sex (1 = male; 0 = female)
# *  cp: chest pain type
#   *   1: typical angina
#   *   2: atypical angina
#   *   3: non-anginal pain
#   *   4: asymptomatic
# * tretbps: resting blood pressure (in mm Hg on admission to the hospital)
# * chol: serum cholestoral in mg/dl
# * fbs: (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
# * restecg: resting electrocardiographic results
#  * 0: normal
#  * 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
#  * 2: showing probable or definite left ventricular hypertrophy by Estes' criteria
# * thalachh: maximum heart rate achieved
# * exang: exercise induced angina (1 = yes; 0 = no)
# * oldpeak = ST depression induced by exercise relative to rest
# * slope: the slope of the peak exercise ST segment
#  * 1: upsloping
#  * 2: flat
#  * 3: downsloping
# * ca: number of major vessels (0-3) colored by flourosopy
# * thal: 3 = normal; 6 = fixed defect; 7 = reversable defect
# * output: Target Value

# %%
df.describe()

# %% [markdown]
# ### Missing Values

# %%
df.isnull().sum()

# %% [markdown]
# #### Categorial Variables:
#  1.    sex
#  2.    cp
#  3.   fbs
#  4.    restcg
#  5.    exng
#  6.    slp
#  7.   caa
#  8.    thall
# #### Continous Variables:
#  1. age
#  2. trtbps
#  3. chol
#  4. thalachh
#  5. oldpeak

# %%
sns.set(style="darkgrid")
age_target = sns.boxplot(x='output',y='age',data=df)

# %%
sns.set(style="darkgrid")
chol_target = sns.boxplot(x='output',y='chol',data=df)

# %%
sns.set(style="darkgrid")
trtbps_target = sns.boxplot(x='output',y='trtbps',data=df)

# %%
sns.set(style="darkgrid")
thalachh_target = sns.boxplot(x='output',y='thalachh',data=df)

# %%
sns.set(style="darkgrid")
oldpeak_target = sns.boxplot(x='output',y='oldpeak',data=df)

# %%
sns.set(style="darkgrid")
sns.pairplot(df,hue='output')

# %%
cat_cols = ['sex','exng','caa','cp','fbs','restecg','slp','thall']
con_cols = ["age","trtbps","chol","thalachh","oldpeak"]
target_col = ["output"]
sns.heatmap(df[con_cols].corr(),annot=True)
