# %% [markdown]
# <div>
#     <center><img src="https://i.imgur.com/EIQsWaZ.jpg"> </center>
#     <center><h1>♫ Song Lyrics Starter Notebook ♫</h1> </center>
# </div>

# %%
import numpy as np
import pandas as pd
import string
import json

# %%
with open('../input/song-lyrics-dataset/json files/Lyrics_ArianaGrande.json') as f:
  aux = json.load(f)

# %%
for (k, v) in aux.items():
   print(k)

# %%
titles=[song['title'] for song in aux['songs']]
lyrics=[song['lyrics'] for song in aux['songs']]
rd=[song['release_date'] for song in aux['songs']]


T=[]
L=[]
r=[]
al=[]


for i in range(0,308):
    T.append(titles[i])
    L.append(lyrics[i])
    r.append(rd[i])
   



df = pd.DataFrame()
df['Titles']=T
df['Lyrics']=L
df['Release Date']=r

# %%
df.head(5)

# %%
dfa=pd.read_csv('../input/song-lyrics-dataset/csv/ArianaGrande.csv')
dfa.head(5)

# %%
dfa=dfa.rename(str.lower, axis='columns')

# %%
def create_decades(df):

  y=[]
  value=0
  x=1111
  years = []
  decades = []
  df['date'].fillna(0)
  df['date'] = df['date'].astype("str")
  for i in df.index:
    years.append(df['date'].str.split("-")[i][0])
  
  for year in df['year']:
    if year == 'None':
      y.append(x)
    elif year == 'nan':
      y.append(x)  
    else:
      value=int(year)
      y.append(value)

  
  for x in y:
    if x == 1111:
        decades.append("None")
    elif 1970 <= x < 1980:
        decades.append("70s")
    elif 1980 <= x < 1990:
        decades.append("80s")
    elif 1990 <= x < 2000:
        decades.append("90s")
    elif 2000 <= x < 2010:
        decades.append("00s")
    elif 2010 <= x < 2020:
        decades.append("10s")
    elif 2020 <= x < 2030:
        decades.append("20s")
    
  
  df['decade'] = decades
  df = df[['artist','title','album','decade','year','date','lyric']]
  return df

# %%
def cleaning(df):
    a=[]
    i=0
    df1=df
    title = df['title']
    for t in df['title']:
        r=Re=l=Li=c=m=V=ve=D=rs=0
        r=t.find('remix')
        Re=t.find('Remix')
        l=t.find('live')
        Li=t.find('Live')
        V=t.find('Version')
        ve=t.find('version')
        D=t.find('Demo ')
        D=t.find('Demo')
        rs=t.find('Reprise')
        c=t.find('COPY')
        m=t.find('Mix')
        if r != -1:
            a.append(t)
        elif Re != -1:
            a.append(t)
        elif l != -1:
            a.append(t)
        elif Li != -1:
            a.append(t)
        elif V != -1:
            a.append(t)
        elif ve != -1:
            a.append(t)
        elif D != -1:
            a.append(t)
        elif rs != -1:
            a.append(t)
        elif c != -1:
            a.append(t)
        elif m != -1:
            a.append(t)
    
    for t1 in df['title']:
        for t2 in a:
            if t1 == t2:
                df1=df1.drop(i)
        i=i+1
    
    df1.dropna(subset = ["title"], inplace=True)
    df1.dropna(subset = ["lyric"], inplace=True)
    df1.drop_duplicates(subset ="title",keep = False, inplace = True)
    df1.drop_duplicates(subset ="lyric",keep = False, inplace = True)    
    
    return df1

# %%
dfa=create_decades(dfa)
dfa.head(5)

# %%
dfa.shape

# %%
df_clean=cleaning(dfa)
df_clean.head(5)

# %%
df_clean.shape
