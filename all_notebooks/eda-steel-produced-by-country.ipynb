# %%
# Import required librarriws
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
db = pd.read_csv("../input/steeldataedited/b1.csv")

# %%
# check the columns
db.columns

# %%
#check the datat type and null values
db.info()

# %%
# how big is the data
db.shape

# %%
#how many data
db.size

# %%
#data types
db.dtypes

# %%
# see first 10 records
db.head(10)

# %%
# any null value  
db.isnull()

# %%
# any null value  
db.isna()

# %%
# any null value  
db.isnull().any()

# %%
# any null value  
db.isnull().any().any()

# %%
# any null value  
db.isnull().sum()

# %%
# any null value  
db.isnull().sum().sum()

# %%
# any null value  
nan_rows = db[db['2015 Ranking'].isnull()]
nan_rows

# %%
# any null value  
db['2015 Ranking'].isnull()

# %%
# simple EDA 
db.describe()

# %%
db['2011 Tonnage (Millions)'].sum()

# %%
#Sort  based on values
db.sort_values(['2011 Tonnage (Millions)'],ascending=False)

# %%
# how many producer in each country
db.Headquarters.value_counts()

# %%
# how many unique country
db.Headquarters.unique()

# %%
# country production
country_production=db.groupby(db.Headquarters)["2011 Tonnage (Millions)"].sum()
country_production

# %%
db

# %%
# remove ranking from data 
a=db.groupby(db.Headquarters).agg(sum)
b=pd.DataFrame(a)

# %%
c=b.iloc[:,[0,1,2,3,4,5]].copy()
c

# %%
 # add average column
 c['ave_production']=c.mean(axis=1)

# %%
 # add sum column
c['sum production']=c.iloc[:,[1,2,3,4,5,6]].sum(axis=1)

# %%
c.sort_values(['ave_production'],ascending=False,inplace=True)

# %%
c.head()

# %%
c.head()

# %%
plt.figure(figsize=(15, 3))
plt.plot(c.index, c.ave_production,'bx--', label='line chart ',)  # Plot some data on the (implicit) axes.
plt.xlabel('Head Quarters')
plt.ylabel('Average Steel Production /million Tonnage ')
plt.title("Top 100 Steel producer")
plt.xticks(rotation=30, fontsize='small')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 6))

plt.subplot(211)
plt.bar(c.index, c.ave_production)
plt.xticks(rotation=30, fontsize='small')

plt.subplot(212)
plt.scatter(c.index, c.ave_production)
plt.xticks(rotation=30, fontsize='small')

plt.show()

# %%
d=c.iloc[:,0:5].copy()
d.plot.bar(stacked=True, alpha=0.5)

# %%
e=c.iloc[:,6].copy()
e.head()

# %%
# from sklearn import preprocessing

# x=e.reshape(1-,1)
# min_max_scaler = preprocessing.MinMaxScaler()
# x_scaled = min_max_scaler.fit_transform(x)
# df = pd.DataFrame(x_scaled)

# %%
normalized_df=(e-e.min())/(e.max()-e.min())

# %%
normalized_df

# %%
normalized_df.plot.bar()

# %%
e.iloc[:10].plot.pie(figsize=(10, 10), autopct='%1.0f%%')

# %%
import seaborn as sns

# %%
d.head()

# %%
sns.barplot( data=d, orient='h')

# %%
p=db.iloc[:,[0,1,2,3,4,5,6]].copy()
p.head()

# %%
p.pivot_table(index=p.Headquarters,margins=True,aggfunc='sum')

# %%
pd.crosstab(p.Companies,p.Headquarters, margins=True)
