# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline
sns.set_style(style = 'darkgrid')

# %%
data = pd.read_csv('../input/mushroom-classification/mushrooms.csv')

# %%
data.head()

# %%
data.describe()

# %%
data.info()

# %%
data.columns

# %%
# Checking for null values
plt.figure(figsize = (10,7))
sns.heatmap(data.isnull(), yticklabels= False, cmap = 'viridis', cbar = False)

# %%
print('No null values')

# %%
print('Changing categorical values to numerical values')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
columns = data.columns.values
for column in columns:
    lab_enc = LabelEncoder()
    data[column] = lab_enc.fit_transform(data[column])
data.head()

# %%
data.describe()

# %%
data.info()

# %%
plt.figure(figsize= (16,11))
sns.heatmap(data.corr(), cmap = 'YlOrBr', annot= True, yticklabels= False)

# %%
print('Choosing relevant columns for the model')

# %%
X = data.drop(['class','population', 'stalk-shape', 'cap-shape', 'veil-type', 'stalk-color-below-ring'], axis = 1)
y = data['class']

# %%
X = data.drop('class', axis = 1)
y = data['class']

# %%
# Removing columns with p>|t|
import statsmodels.api as sm
regressor_OLS = sm.OLS(endog = y, exog = X).fit()
regressor_OLS.summary()

# %%
X = data.drop(['class','population'], axis = 1)
y = data['class']

# %%
regressor_OLS = sm.OLS(endog = y, exog = X).fit()
regressor_OLS.summary()

# %%
X = data.drop(['class','population', 'stalk-shape'], axis = 1)
y = data['class']

# %%
regressor_OLS = sm.OLS(endog = y, exog = X).fit()
regressor_OLS.summary()

# %%
X = data.drop(['class','population', 'stalk-shape', 'cap-shape'], axis = 1)
y = data['class']

# %%
regressor_OLS = sm.OLS(endog = y, exog = X).fit()
regressor_OLS.summary()

# %%
X = data.drop(['class','population', 'stalk-shape', 'cap-shape', 'veil-type'], axis = 1)
y = data['class']

# %%
regressor_OLS = sm.OLS(endog = y, exog = X).fit()
regressor_OLS.summary()

# %%
X = data.drop(['class','population', 'stalk-shape', 'cap-shape', 'veil-type', 'stalk-color-below-ring'], axis = 1)
y = data['class']

# %%
regressor_OLS = sm.OLS(endog = y, exog = X).fit()
regressor_OLS.summary()

# %%
# Importing train test split
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
# Importing Random Forest Classifer
from sklearn.ensemble import RandomForestClassifier

# %%
clas = RandomForestClassifier()
clas.fit(X_train, y_train)
pred = clas.predict(X_test)

# %%
# Checking model accuracy
from sklearn.metrics import confusion_matrix, classification_report

# %%
print(confusion_matrix(y_test, pred))
sns.heatmap(confusion_matrix(y_test, pred), cmap= 'Greys', annot = True, yticklabels= False)

# %%
print(classification_report(y_test, pred))
