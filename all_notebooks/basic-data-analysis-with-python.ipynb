# %%
import pandas as pd 
import numpy as np # Import the pandas and  numpy libraries for the basic data analysis.....

# %%
data=pd.read_csv('../input/sf-salaries/Salaries.csv')

# %%
data.head() #To check the head of the Data ( the first four rows)

# %%
data.info() #check the dataframe information

# %%
data.columns

# %%
del data['Notes'] #Delete the column "Notes"

# %%
data.iloc[data['TotalPayBenefits'].argmax()]['EmployeeName']  #The employee name with highest 'Total Pay Beneifts'

# %%
data.iloc[data['TotalPayBenefits'].argmin()]['EmployeeName']  #The employee name with lowest 'Total Pay Beneifts'

# %%
len(data[data['OvertimePay']==0]) #To check the no. of employees that don't have the Overtime pay

# %%
def find(title):
    if 'chief' in title.lower().split():
        return True
    else:
        None 
data['JobTitle'].apply(lambda x: find(x)).count() # Chek that how many Employees have the rank as a 'Chief'

# %%
data['JobTitle'].value_counts().head() #To chek the top 5 jobs acquired by the Employees in the list

# %%
data.groupby('Year').mean() #Check the average Total pay and total pay benefits per year.....
