# %%
import pandas as pd
import numba as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import missingno as mosa

# %%
data=pd.read_csv("../input/10k-snapchat-reviews/Snapchat_app_store_reviews.csv")

# %%
data.head()

# %%
data.info()

# %%
data.describe()

# %%
mosa.bar(data)

# %%
data['isEdited'].value_counts()

# %%
sns.countplot(data['rating'])

# %%
data.groupby("rating").count()

# %%
x= df[(df["rating"]==1) |(df["rating"]==2)|(df["rating"]==3) |(df["rating"]==4)|(df["rating"]==5)]

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df,x="date",y="rating",marker='o',hue="rating")
plt.show()
