# %% [markdown]
# ***About this Dataset***
#
# I'll try to make a dashboard of the data "Startup Investments" avaliable on Kaggle with PowerBI, to answer some questions!
#
# So, my first questions are:
#
# 1 - Which markets gets the most funds?
#
# 2 - If i wanna open a Startup, which places are most likely to get more fund? (Seed stage)
#
# 3 - How many of then are currently operating? (Remember this dataset was made in 2014)
#
# 4 - Is there any criteria of the given variables that make a StartUp to recieve more founds? And what about being operative/closed or acquired?
#
# 5 - Is there any way to predict how much time Startup will last? (With the given dataset?)
#
# 6 - And if i wanna to build one to sell it as fast as i can? how long it will take?

# %% [markdown]
# **#Cleaning the data!!**
#
# I've excluded the columns that has no category nor market filled, because for this analysis the qualitative variables in these columns are important.
#
# Another thing i've changed is the dataset was the column for "Funding_Total_USD", because it was in a weird notation to work in powerbi.
#
# There is 54.294 lines in this dataset, which 8.824 are blank in the column "Market", which is a important variable in our dataset, so we will clean that and we work with 45.470 lines. I've excluded the incomplete data in the dataset.
#
# We still have some litter to clean, as the dataset dont have incomplete information from cities.

# %% [markdown]
# Trying to answer the questions based on my results on Power BI:

# %% [markdown]
# 1 - The top 5 markets with most funds are:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 2 - The top 5 Startups funds at the Seed Stage:
#
# • San Francisco
#
# • New York
#
# • London
#
# • Palo Alto
#
# • Austin
#
# ![image.png](attachment:image.png)
#
# We still have some litter to clean on this dataset, because we dont have all cities classified.
#
# 2 - The top 5 places where you have more chances to get more fund (All stages):
#
# • New York
#
# • San Francisco
#
# • Beijing
#
# • Palo Alto
#
# • Cambridge

# %% [markdown]
# 3 -  Startup Status:
#
# • Operating: 82,27%
#
# • Acquired: 12,98%
#
# • Closed: 3,07%
#
# • No-data: 1,68%
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 4 - Let's find out!

# %% [markdown]
# Link for the Pbix: https://github.com/Alexandre-Turatto/Laboratorio_DataScience/tree/master/DataViz/StartupsDataset
