# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
from pandas_profiling import ProfileReport

# %%
data=pd.read_csv("../input/us-birch-tree-inventory-20052018/AnnualBirchTreeRecords-US(2005-2018).csv")

# %%
data.info()

# %%
data.head()

# %%
data.describe()

# %%
sns.heatmap(data.isna())

# %%
plt.figure(figsize=(20,7))
plt.style.use("fivethirtyeight")
sns.lineplot(x='InventoryYear',y='Live',data=data,hue="CommonName")

# %%
plt.figure(figsize=(20,7))
plt.style.use("fivethirtyeight")
sns.lineplot(x='InventoryYear',y='Dead',data=data,hue="CommonName")

# %%
plt.figure(figsize=(20,7))
plt.style.use("fivethirtyeight")
sns.lineplot(x='InventoryYear',y='Removed',data=data,hue="CommonName")

# %%
plt.style.use("ggplot")
plt.figure(figsize=(25,7))
sns.lineplot(x='State',y='Live',data=data,hue="InventoryYear")
plt.xticks(rotation=90)
plt.show()

# %%
sns.pairplot(data,hue='InventoryYear')

# %%
x=ProfileReport(data)

# %%
x
