# %%
from pandas_profiling import ProfileReport
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("../input/sales-store-product-details/Salesstore.csv")

# %%
data.head()

# %%
data.info()

# %%
data.describe()

# %%
sns.heatmap(data.isnull())

# %%
sns.countplot(data['Ship_Mode'])

# %%
sns.countplot(data['Order_Priority'])

# %%
plt.figure(figsize=(10,7))
sns.countplot(data['Region'])

# %%
sns.countplot(data['Product_Category'])

# %%
sns.countplot(data['Product_Container'])

# %%
plt.figure(figsize=(10,7))
sns.lineplot(x='Order_Quantity',y='Sales',data=data)

# %%
plt.figure(figsize=(10,7))
sns.lineplot(x='Order_Quantity',y='Profit',data=data)

# %%
sns.pairplot(data, hue="Order_Priority")

# %%
sns.pairplot(data, hue="Ship_Mode")

# %%
sns.pairplot(data, hue="Region")

# %%
sns.pairplot(data, hue="Customer_Segment")

# %%
sns.pairplot(data, hue="Product_Category")

# %%
sns.pairplot(data, hue="Product_Container")

# %%
df=ProfileReport(data)

# %%
df
