# %% [markdown]
# **Basic EDA**
# Performed following steps -
#     1.  Import Dataset
#     2. Find unique coutries in dataset
#     3. Find timeframe of dataset
#     4. Find which country has highest suicides numbers
#     5. Plot graph of year vs suicide numbers
#     6. Find out why the suicide rate increase in a particular timeframe

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_style('darkgrid')

# %%
df = pd.read_csv('../input/who_suicide_statistics.csv')

# %%
df.info()

# %%
df.head()

# %%
df['country'].unique()

# %%
df['year'].unique()

# %%
# counrty with highest suicide rate from 1979 to 2016
df.groupby('country')['suicides_no'].sum().idxmax()

# %% [markdown]
# Russian Federation has the higest suicide numbers from 1979 to 2016

# %%
# suicides rates in russian federation from 1979 to 2016
rus_1979_2016 = df[df['country']=='Russian Federation'][(df['year']>=1979) & (df['year']<=2016)]
plt.figure(figsize=(14,8))
plt.title('suicides rates in russian federation from 1979 to 2016')
sns.lineplot(x=rus_1979_2016['year'], y=rus_1979_2016['suicides_no'])

# %% [markdown]
# There was an increase in 'Russian Federation' suicide rate from 1990 to 1995

# %%
rus_1990_1995 = rus_1979_2016[(rus_1979_2016['year']>=1990) & (rus_1979_2016['year']<=1995)]
plt.figure(figsize=(14,8))
plt.title('suicides rates in russian federation from 1990 to 1995')
sns.lineplot(x=rus_1990_1995['year'], y=rus_1990_1995['suicides_no'])

# %%
rus_1990_1995 = rus_1979_2016[(rus_1979_2016['year']>=1990) & (rus_1979_2016['year']<=1995)]
plt.figure(figsize=(8,7))
plt.title('gender distribution suicides rates in russian federation from 1990 to 1995')
sns.countplot(rus_1990_1995['sex'], palette='Set1')

# %% [markdown]
# # Why suicide rates increased in Russian Federation from 1990 to 1995?

# %% [markdown]
# According to the article in this link - https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1642767/

# %% [markdown]
# Heavy Drinking and Suicide in Russia
#
#
# Rates of alcohol consumption and suicide in Russia were high before the dissolution of the Soviet Union, rose sharply during the early 1990s, and are currently among the highest in the world. Annual alcohol consumption in Russia is estimated to be nearly 15 liters per person (Nemtsov 2000, Treml 1997) compared to average rates of about 10 and 7 liters per person in the European Union and the United States, respectively (World Advertising Research Center 2002). The age-standardized suicide rate in Russia in 2000 of about 38 per 100,000 persons was second only to Lithuania and was two to three times higher than the European Union average and in the United States. Violent death, including suicide, was also one of the leading causes of the Russian mortality crisis during the 1990s, especially for males (Notzon et al. 1998, Shkolnikov and Meslé 1996).

# %% [markdown]
# **The dissolution of the Soviet Union occurred on 26 December 1991**
