# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
from pandas_profiling import ProfileReport

# %%
data=pd.read_csv("../input/toronto-subway-delay-data/Toronto-Subway-Delay-Jan-2014-Jun-2021.csv")

# %%
data.head()

# %%
data.info()

# %%
sns.heatmap(data.isna())

# %%
data['Date']=pd.to_datetime(data['Date'])

# %%
data.describe()

# %%
plt.figure(figsize=(15,7))
plt.style.use("fivethirtyeight")
sns.lineplot(x='Date',y='Min Delay',data=data)

# %%
plt.figure(figsize=(15,7))
plt.style.use("fivethirtyeight")
sns.lineplot(x='Date',y='Min Gap',data=data)

# %%
plt.figure(figsize=(15,7))
plt.style.use("fivethirtyeight")
sns.lineplot(x='Day',y='Min Delay',data=data)

# %% [markdown]
# # high Delay in Saturday , probability because start weekend

# %%
plt.figure(figsize=(15,7))
plt.style.use("fivethirtyeight")
sns.lineplot(x='Day',y='Min Gap',data=data)

# %%
plt.figure(figsize=(25,7))
plt.style.use("fivethirtyeight")
sns.lineplot(x='Vehicle',y='Min Gap',data=data)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(25,7))
plt.style.use("fivethirtyeight")
sns.lineplot(x='Vehicle',y='Min Delay',data=data)
plt.xticks(rotation=90)
plt.show()

# %%
data[['Station','Min Delay','Min Gap']].sort_values(by='Min Delay',ascending=False).head(10)

# %%
data[['Station','Min Delay','Min Gap']].sort_values(by='Min Gap',ascending=False).head(10)

# %%
sns.pairplot(data,hue='Day')

# %%
df=ProfileReport(data)

# %%
df
