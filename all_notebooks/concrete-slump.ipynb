# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# %%
data = pd.read_csv('../input/real-estate-price-prediction/Real estate.csv')
data = data.drop(['No'], axis = 1)

# %%
data.head()

# %%
def rmse(targets, predictions):
    return np.sqrt(((predictions - targets) ** 2).mean())

# %%
data.corr()

# %%
x = data.drop(['Y house price of unit area'], axis=1)
y = data['Y house price of unit area']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state = 157)

# %% [markdown]
# # Simple Linear Regression

# %%
x_train = X_train['X3 distance to the nearest MRT station']
x_test = X_test['X3 distance to the nearest MRT station']

# %%
x_train_expanded = np.expand_dims(x_train, axis=1)
x_test_expanded = np.expand_dims(x_test, axis=1)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train_expanded, y_train)

# %%
regressor.coef_

# %%
predictions = regressor.predict(x_test_expanded)

# %%
print(f'The R2 score is: {r2_score(y_test, predictions)}')
print(f'The RMSE score is {rmse(y_test, predictions)}')

# %%
plt.scatter(x_train_expanded, y_train, color = 'red')
plt.plot(x_train_expanded, regressor.predict(x_train_expanded), color = 'blue')
plt.title('Distance vs Price (Training set)')
plt.xlabel('Distance (X)')
plt.ylabel('Price(Y)')

plt.show()

# %%
plt.scatter(x_test_expanded, y_test, color = 'red')
plt.plot(x_test_expanded, regressor.predict(x_test_expanded), color = 'blue')
plt.title('Distance vs Price (Test set)')
plt.xlabel('Distance (X)')
plt.ylabel('Price(Y)')

plt.show()

# %% [markdown]
# # Multiple Linear Regression

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
predictions = regressor.predict(X_test)

# %%
print(f'The R2 score is: {r2_score(y_test, predictions)}')
print(f'The RMSE score is {rmse(y_test, predictions)}')

# %%
regressor.coef_

# %%
plt.scatter(y_train, regressor.predict(X_train))
plt.title('Predictions vs True Values (Training)')
plt.xlabel('True Values')
plt.ylabel('Prediction')

# %%
plt.scatter(y_test, regressor.predict(X_test))
plt.title('Predictions vs True Values (Test)')
plt.xlabel('True Values')
plt.ylabel('Prediction')

# %% [markdown]
# # Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = Polynomifrom sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
predictions = regressor.predict(X_test)alFeatures(degree = 2)
x_train_poly = poly_reg.fit_transform(X_train)
x_test_poly = poly_reg.transform(X_test)
regressor = LinearRegression()
regressor.fit(x_train_poly, y_train)

# %%
predictions = regressor.predict(x_test_poly)

# %%
regressor.coef_

# %%
predictions = regressor.predict(x_test_poly)
print(f'The R2 score is: {r2_score(y_test, predictions)}')
print(f'The RMSE score is {rmse(y_test, predictions)}')

# %%
plt.scatter(y_train, regressor.predict(x_train_poly))
plt.title('Predictions vs True Values (Training)')
plt.xlabel('True Values')
plt.ylabel('Prediction')

# %%
plt.scatter(y_test, regressor.predict(x_test_poly))
plt.title('Predictions vs True Values (Test)')
plt.xlabel('True Values')
plt.ylabel('Prediction')

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Ridge
regressor = Ridge()
regressor.fit(X_train, y_train)
predictions = regressor.predict(X_test)

# %%
print(f'The R2 score is: {r2_score(y_test, predictions)}')
print(f'The RMSE score is {rmse(y_test, predictions)}')

# %%
regressor.coef_

# %%
plt.scatter(y_train, regressor.predict(X_train))
plt.title('Predictions vs True Values (Training)')
plt.xlabel('True Values')
plt.ylabel('Prediction')

# %%
plt.scatter(y_test, regressor.predict(X_test))
plt.title('Predictions vs True Values (Test)')
plt.xlabel('True Values')
plt.ylabel('Prediction')

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso
regressor = Lasso()
regressor.fit(X_train, y_train)
predictions = regressor.predict(X_test)

# %%
print(f'The R2 score is: {r2_score(y_test, predictions)}')
print(f'The RMSE score is {rmse(y_test, predictions)}')

# %%
regressor.coef_

# %%
plt.scatter(y_train, regressor.predict(X_train))
plt.title('Predictions vs True Values (Training)')
plt.xlabel('True Values')
plt.ylabel('Prediction')

# %%
plt.scatter(y_test, regressor.predict(X_test))
plt.title('Predictions vs True Values (Test)')
plt.xlabel('True Values')
plt.ylabel('Prediction')

# %% [markdown]
# # Elastic Net Regression

# %%
from sklearn.linear_model import ElasticNet
regressor = ElasticNet()
regressor.fit(X_train, y_train)
predictions = regressor.predict(X_test)

# %%
print(f'The R2 score is: {r2_score(y_test, predictions)}')
print(f'The RMSE score is {rmse(y_test, predictions)}')

# %%
regressor.coef_

# %%
plt.scatter(y_train, regressor.predict(X_train))
plt.title('Predictions vs True Values (Training)')
plt.xlabel('True Values')
plt.ylabel('Prediction')

# %%
plt.scatter(y_test, regressor.predict(X_test))
plt.title('Predictions vs True Values (Test)')
plt.xlabel('True Values')
plt.ylabel('Prediction')

# %% [markdown]
# # Bridge Regression

# %%
from sklearn.linear_model import BayesianRidge
regressor = BayesianRidge()
regressor.fit(X_train, y_train)
predictions = regressor.predict(X_test)

# %%
print(f'The R2 score is: {r2_score(y_test, predictions)}')
print(f'The RMSE score is {rmse(y_test, predictions)}')

# %%
regressor.coef_

# %%
plt.scatter(y_train, regressor.predict(X_train))
plt.title('Predictions vs True Values (Training)')
plt.xlabel('True Values')
plt.ylabel('Prediction')

# %%
plt.scatter(y_test, regressor.predict(X_test))
plt.title('Predictions vs True Values (Test)')
plt.xlabel('True Values')
plt.ylabel('Prediction')
