# %% [markdown]
# Importar Librerías

# %%
import numpy as n
import pandas as pd

# %% [markdown]
# Levantar la base (read_csv)

# %%
base = pd.read_csv("../input/titanic/train_data.csv")

# %% [markdown]
# Ver los tipos de datos levantados (info)

# %% [markdown]
# Exlorar las primeras lineas (head)

# %% [markdown]
# Ver el tamaño de la base (shape)

# %% [markdown]
# Ver el nombre de las columnas (columns)

# %% [markdown]
# Ver las caracteríticas de las variables numericas (describe)

# %% [markdown]
# Ver valores unicos en alguna variable descriptiva (unique)

# %% [markdown]
# Filtrar la base para ver solo algunas columnas o filas

# %% [markdown]
# Hacer agrupamientos por alguna variable categórica (group by)

# %% [markdown]
# Explorar algunos gráficos
