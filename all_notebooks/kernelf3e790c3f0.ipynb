# %%
import pandas as pd 
import matplotlib.pylab as plt
import seaborn as sns

# %%
data= pd.read_csv("../input/2017.csv")
data.head()

# %%
 sns.regplot(data=data, x="Freedom", y="Happiness.Score", fit_reg=False, marker="o", color="green")

# %%
sns.regplot(data=data, x="Economy..GDP.per.Capita.", y="Happiness.Score", fit_reg=False, marker="o", color="blue")

# %%
sns.regplot(data=data, x="Family", y="Happiness.Score", fit_reg=False, marker="o", color="purple")

# %%
sns.regplot(data=data, x="Economy..GDP.per.Capita.", y="Health..Life.Expectancy.", fit_reg=False, marker="o", color="red")
