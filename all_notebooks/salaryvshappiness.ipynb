# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train = pd.read_csv("../input/regressiondata/income_data.csv")

# %%
train.shape

# %%
train=train.iloc[:,1:]

# %%
train, test = train_test_split(train, test_size=0.2, random_state=42, shuffle=True)
#test_main = test

# %%
#train, test = train_test_split(train, test_size=0.2, random_state=42, shuffle=True)
#validation = test
#test=test_main

# %%
train.shape

# %%
train.head()

# %%
train.describe()

# %%
train.plot(x='income', y='happiness', style='o')
plt.title('Salary Vs Happiness')
plt.xlabel('Salary')
plt.ylabel('Happiness')
plt.show()

# %%
X_train = train.iloc[:, :-1].values
y_train = train.iloc[:, 1].values

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# %%
print(regressor.intercept_)

# %%
print(regressor.coef_)

# %%
X_test = test.iloc[:, :-1].values
y_test = test.iloc[:, 1].values

# %%
y_pred = regressor.predict(X_test)

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df

# %% [markdown]
# **Evaluating the model**

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# %% [markdown]
# You can see that the value of root mean squared error is 0.7682098634564949, which is more than 20% of the mean value of the percentages of all the happiness i.e. 3.38. This means that our algorithm didn't perform a decent job.

# %%
x_plot = np.linspace(0,6,100)
y_plot = np.linspace(0,6,100)
df.plot(x='Actual', y='Predicted', style='o')
plt.plot(x_plot, y_plot, color="black")
plt.title('Actual Vs Predicted')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()
