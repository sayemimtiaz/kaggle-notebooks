# %% [markdown]
# <center>
#     <h1 style = "color:  #931a25; letter-spacing: 1px; " > 🏆 IPL Scoring  Data  🏆 </h1>
# <img src = "https://i.pinimg.com/564x/e4/8c/31/e48c31b73077a15b39adba1457fcee53.jpg" />

# %% [markdown]
# <center>
# <p style  = "color: #515070; font-size: 20px;" >
# Throughout this notebook we will take a look at the several aspects of the scoring patterns, dismissals, top scorer, average and many more thing regarding the scoring of the players in the IPL. Upto this IPL, the batsman's are always  dominating the game. The player which are explosive while batting are tends to do more with their abilities and also the match finishers like MSD is also doing the grate work by his blade
# So let's start

# %%
#load libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as ws
ws.filterwarnings("ignore")

# %% [markdown]
# <div style ="color:; background-color: white; font-size: 20px;">
#     <br>
# <center> <p> &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; Lets take a look at Data </p></center>
#     <br>

# %%
df = pd.read_csv("../input/ipl-2020-data/2008-2019 IPL data/2008-2019 IPL data/most_runs_average_strikerate_2008_to_2019.csv")
df.head()

# %%
# EDA Starts

# %% [markdown]
# <div style ="background-color: white; font-size: 20px;">
#     <br>
# <center> <p> &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; Top 10 run getters in IPL</p></center>
#     <br>

# %%
# Top 10 run scorer's in the the IPL
sns.set()
fig,ax = plt.subplots(figsize =(15,6))
top = df.sort_values(by="total_runs", ascending  =False).head(10)[["batsman", "total_runs"]]
sns.barplot(x = top["batsman"], y = top["total_runs"], palette="magma", ax=ax)
ax.set(title  ="Top 10 Scoring batsman in IPL")
plt.xticks(rotation =  30)
plt.show()

# %% [markdown]
# <b style ="color: #e11d74; font-size: 20px"> Inference </b>
# <p style ="font-size: 18px"> In top 10 high scoring batsman the top 3 Indian Batsman (May be after this IPL KL Rahul will be the member in the LIST )

# %% [markdown]
# <div style =" background-color: whte; font-size: 20px;">
#     <br>
# <center> <p> &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; Top 10  highly dimissed  batsman in IPL</p></center>
#     <br>

# %%
# Top 10 run Dismissed batsman in the the IPL
sns.set()
fig,ax = plt.subplots(figsize =(15,6))
dismissed = df.sort_values(by="out", ascending  =False).head(10)[["batsman", "out"]]
sns.barplot(x = dismissed["batsman"], y = dismissed["out"], palette="inferno", ax=ax)
ax.set(title  ="Top 10 Dismissed batsman in IPL")
plt.xticks(rotation =  30)
plt.show()

# %% [markdown]
# <b style ="color: #e11d74; font-size: 20px"> Inference </b>
#
#
# <p style ="font-size: 18px">
#
# All are Indians :)--------------
#
#
# The Indian players are extensively playing the IPL from the 2008 onwards hence the most dimissals were done to the indian players. Regarding players the RG Sharma (hitman) was featured in this list due to his presence in the DECCAN CHARGERS and also the all of them are either openers in the innings except Mahi (MSD)
#
# (Another  is most of then are right handers)
#
# Hence, we can infer that the rate of dismissals is more  in the openers. there can be certain reasons of it. like
#
# 1. Teams need explosive start and hence they have to hit shots.
# 2. they face the fresh bowling attacks with the players like Mich Stark, Deal Steyn and Trent Boultwho are left arm seamers who bowl the right handers just outside the offstumps and due to inswing the dismisses the right handers.

# %% [markdown]
# <div style ="font-size: 20px;">
#     <br>
# <center> <p> &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; Top 10 Highest averaging batsman in IPL</p></center>
#     <br>

# %%
# Top 10 high Averaged players
sns.set()
fig,ax = plt.subplots(figsize =(15,6))
top_avg = df.sort_values(by="average", ascending  =False).head(10)[["batsman", "average", "total_runs"]].sort_values(by ="total_runs", ascending = False).head(5)
sns.barplot(x = top_avg["batsman"], y = top_avg["average"], palette="inferno", ax=ax)
ax.set(title  ="Top 10 high averaging batsman in IPL")
plt.xticks(rotation =  30)
plt.show()

# %% [markdown]
# <b style ="color: #e11d74; font-size: 20px"> Inference </b>
# <p style ="font-size: 18px"> Highest averaging batsman is MR. 360 [ABD].

# %% [markdown]
# <div style =" font-size: 20px;">
#     <br>
# <center> <p> &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; Top 10 Runs / balls ratio bearing batsman</p></center>
#     <br>

# %%
temp = df.sort_values(by="numberofballs", ascending  =False).head(10)[["batsman","total_runs", "numberofballs"]]
temp["avg"] = temp["total_runs"] /  temp["numberofballs"]

# %%
sns.set()
fig,ax = plt.subplots(figsize =(15,6))
sns.barplot(x = temp["batsman"], y = temp["avg"], palette="rainbow", ax=ax)
ax.set(title  ="Balls / Run Ratio")
plt.xticks(rotation =  30)
plt.show()

# %% [markdown]
# <b style ="color: #e11d74; font-size: 20px"> Inference </b>
# <p style ="font-size: 18px"> Chris Gayl Bears the Highest ball per runs ratio followed by David Warner and  "*THALA and CHINNA*"  (MSD and SK Raina)

# %% [markdown]
# <div style ="font-size: 20px;">
#     <br>
# <center> <p> &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; Top 10 Strike Rate holders in IPL</p></center>
#     <br>

# %%
# Top 10 Strike Rate holders in IPL
averaging = df.sort_values(by= "strikerate", ascending = False)

# %% [markdown]
# <div style =" font-size: 20px;">
#     <br>
# <center> <p>&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; Highest Strike Rat bearing batsman upto 2000 Runs
# </p></center>
#     <br>

# %%
sns.set()
fig,ax = plt.subplots(figsize =(15,6))
strike_2000 = averaging[averaging["total_runs"] > 2000].head(10)
sns.barplot(x=strike_2000["batsman"], y =strike_2000["strikerate"], palette="mako")
ax.set(title= "Top 10 Strike rate holders (UPTO 2000 Runs)")
plt.show()

# %% [markdown]
# <b style ="color: #e11d74; font-size: 20px"> Inference </b>
# <p style ="font-size: 18px">         Nawad of NAJAFGADH is always the Best striker of the cricket ball followed by Chris Gayle and then MR. 360

# %% [markdown]
# <div style ="font-size: 20px;">
#     <br>
# <center> <p> &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; Highest Strike Rat bearing batsman upto 3000 Runs
# </p></center>
#     <br>

# %%
# Highest averaging batsman upto 3000 Runs are
sns.set()
fig,ax = plt.subplots(figsize =(15,6))
strike_3000 = averaging[averaging["total_runs"] > 3000].head(10)
sns.barplot(x=strike_3000["batsman"], y =strike_3000["strikerate"], palette="Purples_r")
ax.set(title= "Top 10 Strike rate holders (UPTO 3000 Runs)")
plt.show()

# %% [markdown]
# <b style ="color: #e11d74; font-size: 20px"> Inference </b>
# <p style ="font-size: 18px">Story Changes and Chris gayle is now the top strike rate holder and Yusuf pathan is introduced

# %% [markdown]
# <div style ="font-size: 20px;">
#     <br>
# <center> <p> &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; Highest Strike Rat bearing batsman upto 4000 Runs
# </p></center>
#     <br>

# %%
# Highest averaging batsman upto 4000 Runs are
sns.set()
fig,ax = plt.subplots(figsize =(15,6))
strike_4000 = averaging[averaging["total_runs"] > 4000].head(10)
sns.barplot(x=strike_4000["batsman"], y =strike_4000["strikerate"], palette="Spectral_r")
ax.set(title= "Top 10 Strike rate holders (UPTO 4000 Runs)")
plt.show()

# %% [markdown]
# <b style ="color: #e11d74; font-size: 20px"> Inference </b>
# <p style ="font-size: 18px">Story Changes a little bit David WAarner  is introduced as he is the CAPTAIN of SRH he is playing extremely well and Chris gayle is the top strike rate holder Followed  by AB

# %% [markdown]
# <div style ="font-size: 20px;">
#     <br>
# <center> <p> &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; Highest Strike Rat bearing batsman upto 💫 5000 💫 Runs
# </p></center>
#     <br>

# %%
# Highest averaging batsman upto 5000 Runs are
sns.set()
fig,ax = plt.subplots(figsize =(15,6))
strike_5000 = averaging[averaging["total_runs"] > 5000].head(10)
sns.barplot(x=strike_5000["batsman"], y =strike_5000["strikerate"], palette="Spectral_r")
ax.set(title= "Top 10 Strike rate holders (UPTO 5000 Runs)")
plt.show()

# %% [markdown]
# <b style ="color: #e11d74; font-size: 20px"> Inference </b>
# <p style ="font-size: 18px">As it comes to 5000 There are only two kings

# %% [markdown]
# <center>
#
# <div>
#     <i> <h1 style ="color: #776d8a"> Virat Kohli </h1> </i>
#     <img src = "https://i.pinimg.com/564x/70/da/e2/70dae20d400a2219bbaf29556c5f5a05.jpg" alt ="virat" height = 300 width = 300 />
#     </div>

# %% [markdown]
# <center>
#
# <div>
#     <i> <h1 style ="color: #776d8a">  Suresh Raina (CHINNA) </h1> </i>
#     <img src = "https://i.pinimg.com/236x/54/0c/f3/540cf31cbbaa09e87ec6df9f4583f23f.jpg" alt ="virat" height = 300 width = 300 />
#     </div>

# %% [markdown]
# <div style ="font-size: 20px;">
#     <br>
# <center> <p> &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; Highest Run scorer per inning
# </p></center>
#     <br>

# %%
# Runs per out
runs_per_innings = df.sort_values(by="total_runs", ascending  =False).head(10)[["batsman", "total_runs", "out"]]
runs_per_innings["runs_per_inn"]=  runs_per_innings["total_runs"] / runs_per_innings["out"]
sns.set()
fig,ax = plt.subplots(figsize =(15,6))
sns.barplot(x=runs_per_innings["batsman"], y =runs_per_innings["runs_per_inn"], palette="Spectral_r")
ax.set(title= "Runs / innings by the top Scoring batsman")
plt.show()

# %% [markdown]
# <b style ="color: #e11d74; font-size: 20px"> Inference </b>
# <p style ="font-size: 18px">RCB's one man ARMY ABD is averaging the highest runs per innings
#    <center>
#     <h1> ABD </h1>
#    <img src = "https://i.pinimg.com/236x/8e/86/aa/8e86aa9dbdd18701a1ed9f28caf32c3d.jpg" height = 400  width = 400 />

# %% [markdown]
# <div style =" font-size: 30px;">
#     <br>
# <center> <p> &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;  ❤️️ UPVOTE IT ❤️️ <br> <br>  &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;if you find it useful and do checkout more stuff <a href = "https://www.kaggle.com/sudarshanpatil"> here </a>
