# %% [markdown]
# #**Plastics in the oceans**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../input/plastic-input-into-worlds-oceans/plastics-top-rivers.csv')

# %%
df.head()

# %%
df.shape

# %%
df.columns

# %%
df.isnull().sum()

# %% [markdown]
# # # Countries Sharing the plastics into oceans****

# %%
sns.barplot(x = 'sharePlastics', y ='Country',data=df)

# %%
sns.boxplot(x = 'sharePlastics',y='Country',data=df)

# %%
df.sort_index()

# %%
df.plot.scatter(x='sharePlastics',y='Country')
