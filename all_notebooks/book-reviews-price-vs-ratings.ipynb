# %%
import numpy as np
import pandas as pd

df = pd.read_csv('/kaggle/input/amazon-top-50-bestselling-books-2009-2019/bestsellers with categories.csv')

# %%
df.head()

# %%
df.describe()

# %%
X = df['Price']
y = df['User Rating']

import seaborn as sns

# %%
sns.jointplot(kind='reg', data=df, x='Price', y='User Rating')

# %% [raw]
# Price vs User Rating would suggest a lower rating the more money a book costs.

# %%
df2 = df.copy()

# %%
high_df = df2.loc[df.Price > 30]
low_df = df2.loc[df.Price < 30]

# %%
sns.jointplot(kind='reg', data=high_df, x='Price', y='User Rating')

# %% [markdown]
# Books greater then $30 trend in the opposite direction.

# %%
sns.jointplot(kind='reg', data=low_df, x='Price', y='User Rating')

# %% [markdown]
# Books less then $30. This trend line might be because readers apply the rating value proportionally to the price paid.
