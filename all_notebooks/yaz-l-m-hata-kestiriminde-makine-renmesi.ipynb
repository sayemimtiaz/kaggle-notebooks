# %% [markdown]
# * **Yazılım Hata Kestiriminde Makine Öğrenmesi**
# * Nasa data programındaki kod metriklerini içeren bir datasetimiz bulunmaktadır.
# * **Amaç**
# * Bu data setinden makine öğrenmesi algoritmlarını karşılaştıracağız.
# * Bulduğumuz sonuçlara göre kod metriklerinden yazılım hata kestirimini yapılabildiğini sağlamak.
# * **Çıkarımlar**
# * Naive Bayes ve Decision Tree Algoritmaları ile modelleme
# * Test-Train ve Cross Validation Karşılaştırması

# %% [markdown]
# **Gerekli kütüphanelerin eklenmesi**

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import os
print(os.listdir("../input"))

# %% [markdown]
# **Datasetimizi okuyoruz.**

# %%
datapath = "../input/jm1.csv"
df=pd.read_csv(datapath,sep=",",encoding = 'latin')

# %% [markdown]
# **Datasetimizin ilk 5 datasını görüyoruz.**

# %%
df.head()

# %% [markdown]
# **Datasetimizin son 5 datamızı görüyoruz.**

# %%
df.tail()

# %% [markdown]
# **Datasetimizin bellek kullanımını ve öz nitelikleri veri türleri**

# %%
df.info()

# %% [markdown]
# **Datasetimizin veri türlerini incelediğimizde "uniq_Op, uniq_Opnd, total_0p, total_Opnd, branchCount" özniteliklerinin object olduğunu görüyoruz. Fakat datasetimiz numeric değerlerden oluştuğunu bildiğimiz için bu değerleri object veri türü olmaması lazım**

# %%
df.loc[df['uniq_Op'] == "?"]

# %% [markdown]
# **Gördüğümüz gibi datasetimizde "?" bir öz nitelik içerisinde hem "numeric" hemde "string" değer içerdiği için "df.info()" bize öznitelikleri "object" olarak gösteriyor. Bu dataları şimdi datasetimizden çıkaralım.**

# %%
df = df.drop([143,358,1598,4214,8279])

# %%
df.info()

# %% [markdown]
# **Datamızın büyüklüğü ve öz niteliklerimizin sayısı**

# %%
print(df.shape)

# %% [markdown]
# **Datamızın Maksimum, Minumum, Ortalama, Standart Sapma gibi verilerin hakkında bilgiler**

# %%
df.describe()

# %% [markdown]
# **Korelasyon Matrisimiz**

# %%
ozNitelikler = df.iloc[:, :-7].values
np.corrcoef(ozNitelikler)

# %% [markdown]
# **Histogramımız**

# %% [markdown]
# df.hist(bins=3)

# %%
p = sns.countplot(x="loc", data = df, palette="muted")
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %%
df['Loc_Pass'] = np.where(df['loc']<10, 'F', 'P')
df.Loc_Pass.value_counts()

# %%
p = sns.countplot(x='loc', data = df, hue='Loc_Pass', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %% [markdown]
# 1. **Datasetimizin Naive Bayes Modeli ile Eğitilmesi**
# * Datasetimizi test ve train olarak parçalara ayırıyoruz

# %%
x = df.drop(["defects","branchCount","total_Opnd","total_Op","uniq_Opnd","uniq_Op","Loc_Pass"],axis=1)
x.head()

# %%
y = df[["defects"]]
y.head()

# %% [markdown]
# **Dataların ayrılması**

# %% [markdown]
# **Test Train ile Eğitme**

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
x_train.shape, y_train.shape

# %%
x_test.shape, y_test.shape

# %% [markdown]
# **Naive Bayes **

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score

# %%
naive_bayes_model = GaussianNB()

# %%
naive_bayes_model.fit(x_train,y_train)

# %%
naive_bayes_pred = naive_bayes_model.predict(x_test)

# %%
naive_bayes_score = accuracy_score(naive_bayes_pred,y_test)*100

# %%
naive_bayes_score

# %%
k_fold = KFold(n_splits=10, shuffle=True, random_state=0)
naive_bayes_cv_model = GaussianNB()

# %% [markdown]
# **Cross Validation İle Eğitme**

# %%
naive_bayes_cv_score = cross_val_score(naive_bayes_cv_model,x,y,cv=k_fold,scoring = 'accuracy')*100

# %%
naive_bayes_cv_score.mean()

# %%
naive_bayes_cv_model.fit(x,y)

# %%
naive_bayes_cv_pred = naive_bayes_cv_model.predict(x)

# %%
naive_bayes_cv_score = accuracy_score(naive_bayes_cv_pred,y)*100

# %%
naive_bayes_cv_score

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.5, random_state = 0)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_train)
cm

# %% [markdown]
# **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree_model = DecisionTreeClassifier()

# %%
tree_cv_score = cross_val_score(tree_model,x,y,cv=k_fold,scoring = 'accuracy')*100

# %%
tree_cv_score

# %%
tree_cv_score.mean()

# %% [markdown]
# **SONUÇLAR**
# * Naive Bayes - Cross Validation %80.51 başarı
# * Naive Bayes - Test-Train %80.53 başarı
# * Decision Tree - Cross Validation %75.62 başarı
