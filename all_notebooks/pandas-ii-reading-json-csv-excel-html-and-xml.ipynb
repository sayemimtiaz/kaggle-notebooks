# %% [markdown]
# # Import Relevant Libraries

# %%
import pandas as pd
import json

# %% [markdown]
# # Loading CSV Files
# * Step 1 : Look for a suitable dataset. Click on the '+ Add data' button on the top right side of the page
# * Step 2 : After selecting a dataset, find it in the file tree on the right, click on the 'copy file path' of the csv file
# * Step 4 : Name the dataframe where you want to load the data intuitively so that it is easier to remember what that data frame is about e.g. raw_csv_data,  this name just shows that the dataframe contains unprodessed csv data
# * Step 5 : use the read_csv() function from pandas to load the csv file as shown below

# %%
raw_csv_data = pd.read_csv('../input/netflix-shows/netflix_titles.csv')

# %% [markdown]
# ### Displaying the csv Dataframe

# %%
raw_csv_data

# %% [markdown]
# ### Descriptive Statistics of the CSV Data Frame

# %%
raw_csv_data.describe(include = 'all')

# %% [markdown]
# ### Delete Rows with NULL or NaN(Not a Number) Values

# %% [markdown]
# ### Checking for Null Values in the Dataframe Method 1

# %%
raw_csv_data.isna().sum()

# %% [markdown]
# * Here you observe that there are 1969 null/NaN values in the column called 'director'

# %% [markdown]
# ### Checking for Null Values in the Dataframe Method 2

# %%
raw_csv_data.info()

# %% [markdown]
# * Here we see the number of 'Non- Null' cells

# %% [markdown]
# # Loading JSON Files

# %%
with open('../input/CORD-19-research-challenge/document_parses/pdf_json/000ed27575c028d3173a3fd59be053446454f985.json') as f:
  raw_json_data = json.load(f)

# Output:
print(raw_json_data)

# %% [markdown]
# # Loading Excel Files

# %%
raw_xlsx_data = pd.read_excel (r'../input/CORD-19-research-challenge/Kaggle/target_tables/0_table_formats_and_column_definitions/column_definitions_extended.xlsx')
print (raw_xlsx_data)

# %% [markdown]
# # Perform these tasks in ront of the kid and then ask the kid to share their screen and perfrom the same.
