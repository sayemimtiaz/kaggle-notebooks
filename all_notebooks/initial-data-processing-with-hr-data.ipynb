# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sn 
import matplotlib.pyplot as plt
import pandas_profiling
import math 
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install pandas-profiling

# %%
train_set = pd.read_csv("/kaggle/input/hr-data-processing/train_set.csv")
test_set = pd.read_csv("/kaggle/input/hr-data-processing/test_set.csv")

# %%
train_set
test_set

# %%
test_set.info()

# %%
train_set.info()

# %%
train_set.shape

# %%
test_set.shape

# %%
train_set.head()

# %%
test_set.head()

# %%
train_set.tail()

# %%
test_set.tail()

# %%
test_set

# %%
train_set[train_set["fnlwgt"].isnull()]

# %%
X_train=train_set.copy()

# %%
X_test=test_set.copy()

# %%
print(dir(pd.concat))

# %%
Sample=pd.concat([X_train,X_test])

# %%
Sample

# %%
Sample.shape

# %%
Sample=X_train.append(X_test)

# %%
Sample

# %%
Sample.info()

# %%
Sample["workclass"].unique()

# %%
from numpy import arange

# %%
Sample["workclass"].value_counts()

# %%
train_set = train_set.apply(lambda x : x.replace(' ?',np.nan))
test_set = test_set.apply(lambda x : x.replace(' ?',np.nan))

# %%
train_set

# %%
train_set.isnull().sum()

# %%
test_set.isnull().sum()

# %%
train_set.dropna(inplace = True)

# %%
test_set.dropna(inplace = True)

# %%
train_set.isnull().sum()

# %%
test_set.isnull().sum()

# %%
Sample.info()

# %%
Sample['sex'].unique()

# %%
dict_sex = {}
count = 0
for i in X_train.sex.unique():
    dict_sex[i] = count
    count +=1
dict_sex

# %%
dict_workclass = {}
count = 0
for i in X_train.workclass.unique():
    dict_workclass[i] = count
    count +=1
dict_workclass

# %%
dict_education = {}
count = 0
for i in X_train.education.unique():
    dict_education[i] = count
    count +=1
dict_education

# %%
dict_marital_status = {}
count = 0
for i in X_train.marital_status.unique():
    dict_marital_status[i] = count
    count +=1
dict_marital_status

# %%
dict_occupation = {}
count = 0
for i in X_train.occupation.unique():
    dict_occupation[i] = count
    count +=1
dict_occupation

# %%
dict_relationship = {}
count = 0
for i in X_train.relationship.unique():
    dict_relationship[i] = count
    count +=1
dict_relationship

# %%
dict_race = {}
count = 0
for i in X_train.race.unique():
    dict_race[i] = count
    count +=1
dict_race

# %%
dict_native_country = {}
count = 0
for i in X_train.native_country.unique():
    dict_native_country[i] = count
    count +=1
dict_native_country

# %%
dict_wage_class = {}
count = 0
for i in X_train.wage_class.unique():
    dict_wage_class[i] = count
    count +=1
dict_wage_class

# %%
Sample.info()

# %%
Sample.columns

# %%
col = ['workclass','education','marital_status', 'occupation', 'relationship', 'race','sex','native_country', 'wage_class']

# %%
abc = Sample[col]

# %%
abc.head()

# %%
X_train['sex'] = X_train['sex'].map(dict_sex)

# %%
X_train

# %%
X_train["native_country"] = X_train["native_country"].map(dict_native_country)

# %%
X_train["wage_class"] = X_train["wage_class"].map(dict_wage_class)

# %%
X_train["race"] = X_train["race"].map(dict_race)

# %%
X_train["relationship"] = X_train["relationship"].map(dict_relationship)

# %%
X_train["occupation"] = X_train["occupation"].map(dict_occupation)

# %%
X_train["marital_status"] = X_train["marital_status"].map(dict_marital_status)

# %%
X_train["education"] = X_train["education"].map(dict_education)

# %%
X_train["workclass"] = X_train["workclass"].map(dict_workclass)

# %%
X_train

# %%
dict_workclass = {}
count = 0
for i in X_test.workclass.unique():
    dict_workclass[i] = count
    count +=1
dict_workclass

# %%
X_test.info()

# %%
dict_education = {}
count = 0
for i in X_test.education.unique():
    dict_education[i] = count
    count +=1
dict_education

# %%
dict_occupation = {}
count = 0
for i in X_test.occupation.unique():
    dict_occupation[i] = count
    count +=1
dict_occupation

# %%
dict_marital_status= {}
count = 0
for i in X_test.marital_status.unique():
    dict_marital_status[i] = count
    count +=1
dict_marital_status

# %%
dict_relationship = {}
count = 0
for i in X_test.relationship.unique():
    dict_relationship[i] = count
    count +=1
dict_relationship

# %%
dict_race = {}
count = 0
for i in X_test.race.unique():
    dict_race[i] = count
    count +=1
dict_race

# %%
dict_sex = {}
count = 0
for i in X_test.sex.unique():
    dict_sex[i] = count
    count +=1
dict_sex

# %%
dict_native_country = {}
count = 0
for i in X_test.native_country.unique():
    dict_native_country[i] = count
    count +=1
dict_native_country

# %%
dict_wage_class = {}
count = 0
for i in X_test.wage_class.unique():
    dict_wage_class[i] = count
    count +=1
dict_wage_class

# %%
X_test["native_country"] = X_test["native_country"].map(dict_native_country)

# %%
X_test["race"] = X_test["race"].map(dict_race)

# %%
X_test["relationship"] = X_test["relationship"].map(dict_relationship)

# %%
X_test["occupation"] = X_test["occupation"].map(dict_occupation)

# %%
X_test["marital_status"] = X_test["marital_status"].map(dict_marital_status)

# %%
X_test["education"] = X_test["education"].map(dict_education)

# %%
X_test["workclass"] = X_test["workclass"].map(dict_workclass)

# %%
X_test["sex"] = X_test["sex"].map(dict_sex)

# %%
X_test["wage_class"] = X_test["wage_class"].map(dict_wage_class)

# %%
X_test

# %%
Sample1=X_train.append(X_test)

# %%
Sample1

# %%
sn.countplot(x="workclass",hue="wage_class",data=X_train)

# %%
sn.countplot(x="sex",hue="wage_class",data=X_test)

# %%
g=sn.countplot(x="workclass",hue="wage_class",data=X_train)
g.set_xticklabels(labels="workclass",fontsize=6,)

# %%
sn.countplot(x="workclass",hue="wage_class",data=X_test)
plt.savefig("X_test.png")

# %%
wagecount=sn.countplot(x="wage_class",data=X_test)

# %%
wagecount=sn.countplot(x="wage_class",data=X_train)
plt.savefig("wagecount.pdf")
