# %% [markdown]
# ## Setup
#
# Codeblock ausgeführen.

# %%
# Code you have previously used to load data
import pandas as pd
from sklearn.tree import DecisionTreeRegressor

# Path of the file to read
iowa_file_path = '../input/home-data-for-ml-course/train.csv'

home_data = pd.read_csv(iowa_file_path)
y = home_data.SalePrice
feature_columns = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']
X = home_data[feature_columns]

# Specify Model
iowa_model = DecisionTreeRegressor()
# Fit Model
iowa_model.fit(X, y)

print("First in-sample predictions:", iowa_model.predict(X.head()))
print("Actual target values for those homes:", y.head().tolist())

# Set up code checking
from learntools.core import binder
binder.bind(globals())
from learntools.machine_learning.ex4 import *
print("Setup Complete")

# %% [markdown]
# # Übung
#
# ## Schritt 1: Daten aufteilen
#
# Teile die Daten auf mit `random_state=1` sodass die `check` deinen Code bewerten kann.

# %%
# Import the train_test_split function and uncomment
# from _ import _

# fill in and uncomment
# train_X, val_X, train_y, val_y = ____

# Check your answer
step_1.check()

# %%
# The lines below will show you a hint or the solution.
# step_1.hint() 
# step_1.solution()

# %% [markdown]
# ## Schritt 2: Modell auswählen und anpassen
#
# Verwende ein `DecisionTreeRegressor`, lass es mit den Testdaten anpassen.
# `random_state` wieder auf 1 setzen.

# %%
# Modell auswählen
iowa_model = ____

# Modell anpassen
____

# Antwort prüfen
step_2.check()

# %%
# step_2.hint()
# step_2.solution()

# %% [markdown]
# ## Step 3: Make Predictions with Validation data

# %%
# Vorhersage mit den Validierungsdaten
val_predictions = ____

# Antwort prüfen
step_3.check()

# %%
# step_3.hint()
# step_3.solution()

# %% [markdown]
# Betrachte die Vorhersage und die echten Werte der Validierungsdaten.

# %%
# Zeige die ersten Einträge der Vorhersage
print(____)
# Zeige die ersten Einträge der echten Werte
print(____)

# %% [markdown]
# ## Schritt 4: MAE für die Validierungsdaten berechnen

# %%
from sklearn.metrics import mean_absolute_error
val_mae = ____

# # entfernen um die validation_mae zu sehen
#print(val_mae)

# Check your answer
step_4.check()

# %%
# step_4.hint()
# step_4.solution()

# %% [markdown]
# **Aufgabe:** Ist der MAE Wert gut oder schlecht?
#
# # Fortsetzung
#
# Weiter mit **[Über- und Unteranpassung](https://www.kaggle.com/infvogel/8-ber-und-unteranpassung/).**

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [Learn Discussion forum](https://www.kaggle.com/learn-forum/161285) to chat with other Learners.*
