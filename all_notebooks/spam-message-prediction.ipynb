# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('../input/spam-text-message-classification/SPAM text message 20170820 - Data.csv')
df.head()

# %%
df['Category'].value_counts()

# %%
df['Category'].value_counts(normalize=True)

# %%
df['Category'] = df['Category'].map({'ham':0,'spam':1})

# %%
df.head()

# %%
y=df['Category']
X=df['Message']
print(y.shape,X.shape)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Vectorizing the Messages

# %%
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer(stop_words='english')

# %%
vect.fit(X_train)
X_traint= vect.transform(X_train)
X_testt= vect.transform(X_test)

# %%
X_traint.shape

# %% [raw]
# There are 7003 features (words) in the object vect, it will count how many times each feature occurs in one sentence and fills that row. This is done for all 3900 rows.

# %%
vect.get_stop_words()

# %% [markdown]
# ## Naive Bayes Classification Model

# %%
from sklearn.metrics import accuracy_score,roc_auc_score,confusion_matrix,roc_curve

# %%
from sklearn.naive_bayes import MultinomialNB
mnb= MultinomialNB()

# %%
mnb.fit(X_traint,y_train)

y_train_pred=mnb.predict(X_traint)
y_train_prob=mnb.predict_proba(X_traint)[:,1]

print('Train')
print('Confusion Matrix:\n',confusion_matrix(y_train,y_train_pred))
print('\nAccuracy Score:',accuracy_score(y_train,y_train_pred))
print('AUC:',roc_auc_score(y_train,y_train_prob))

# %%
y_test_pred=mnb.predict(X_testt)
y_test_prob=mnb.predict_proba(X_testt)[:,1]

print('Test')
print('Confusion Matrix:\n',confusion_matrix(y_test,y_test_pred))
print('\nAccuracy Score:',accuracy_score(y_test,y_test_pred))
print('AUC:',roc_auc_score(y_test,y_test_prob))

# %%
fpr,tpr,thresholds = roc_curve(y_test,y_test_prob)

# %%
thresholds[0]=thresholds[0]-1

# %%
plt.plot(fpr,tpr,"b")
plt.plot(fpr,fpr,"g")
plt.plot(fpr,thresholds,'r')
plt.show()

# %%
spm = pd.DataFrame({'fpr':fpr,'tpr':tpr,'thresholds':thresholds})
spm.head()

# %%
spm[spm['fpr']==0]

# %%
spm[(spm['fpr']==0) & (spm['tpr']>0.5)]

# %% [markdown]
# So here if the probability of the mail being a spam is greater than 0.986659, it will be classified as spam else it will be ham.
