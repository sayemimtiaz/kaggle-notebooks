# %%
import pandas as pd
pd.set_option('display.max_columns', None)
promo=pd.read_csv('../input/promo-abuse-detection-for-payment-apps/Promo_Abuse_Detection_Dataset.csv')
promo.head()

# %% [markdown]
# There are few considerations , we are working with.
# - A device can be use once
# - Cashback to same account more than once is an abuse
# - Name with same email ID is an abuse

# %%
promo.nunique().sort_values(ascending=False)

# %%
promo['UserId'].value_counts().sort_values(ascending=False)[:1] #abuse detected

# %%
promo[promo['UserId']==13341428].head()

# %%
promo.loc[promo['Unnamed: 0'] == 16, "Target"] = 0
promo.loc[promo['Unnamed: 0'] == 17, "Target"] = 1
promo[promo['UserId']==13341428].head()

# %%
promo['Device Id'].value_counts().sort_values(ascending=False)[:1]#abuse detected

# %%
fix=promo[promo['Device Id']=='iosvd:++djsadjscior34728128MSASCDMVERww38rmbe8=:2537']
fix.head()

# %%
i=sorted(fix['Unnamed: 0'].unique().tolist(),reverse=True)[:-1]
i

# %%
promo.loc[promo['Unnamed: 0'] == 950, "Target"] = 0
for j in i:
    promo.loc[promo['Unnamed: 0'] == j, "Target"] = 1
promo[promo['Device Id']=='iosvd:++djsadjscior34728128MSASCDMVERww38rmbe8=:2537']

# %%
promo['Ref PC AC Number'].value_counts().sort_values(ascending=False)[:6]#abuse detected

# %%
fix=promo[promo['Ref PC AC Number']=='IN312XXXXX1298']
fix.head()

# %%
i=sorted(fix['Unnamed: 0'].unique().tolist(),reverse=True)[:-1]
i

# %%
promo.loc[promo['Unnamed: 0'] == 656, "Target"] = 0
for j in i:
    promo.loc[promo['Unnamed: 0'] == j, "Target"] = 1
promo[promo['Ref PC AC Number']=='IN312XXXXX1298']

# %%
fix=promo[promo['Ref PC AC Number']=='IN312XXXXX1299']
fix.head()

# %%
i=sorted(fix['Unnamed: 0'].unique().tolist(),reverse=True)[:-1]
i

# %%
promo.loc[promo['Unnamed: 0'] == 666, "Target"] = 0
for j in i:
    promo.loc[promo['Unnamed: 0'] == j, "Target"] = 1
promo[promo['Ref PC AC Number']=='IN312XXXXX1299']

# %%
fix=promo[promo['Ref PC AC Number']=='IN012XXXXX1188']
fix.head()

# %%
i=sorted(fix['Unnamed: 0'].unique().tolist(),reverse=True)[:-1]
i

# %%
promo.loc[promo['Unnamed: 0'] == 19, "Target"] = 0
for j in i:
    promo.loc[promo['Unnamed: 0'] == j, "Target"] = 1
promo[promo['Ref PC AC Number']=='IN012XXXXX1188']

# %%
fix=promo[promo['Ref PC AC Number']=='IN012XXXXX1190']
fix.head()

# %%
i=sorted(fix['Unnamed: 0'].unique().tolist(),reverse=True)[:-1]
i

# %%
promo.loc[promo['Unnamed: 0'] == 678, "Target"] = 0
for j in i:
    promo.loc[promo['Unnamed: 0'] == j, "Target"] = 1
promo[promo['Ref PC AC Number']=='IN012XXXXX1190']

# %%
fix=promo[promo['Ref PC AC Number']=='IN012XXXXX1186']
fix.head()

# %%
i=sorted(fix['Unnamed: 0'].unique().tolist(),reverse=True)[:-1]
i

# %%
promo.loc[promo['Unnamed: 0'] == 18, "Target"] = 0
for j in i:
    promo.loc[promo['Unnamed: 0'] == j, "Target"] = 1
promo[promo['Ref PC AC Number']=='IN012XXXXX1186']

# %%
fix=promo[promo['Ref PC AC Number']=='IN012XXXXX1185']
fix.head()

# %%
i=sorted(fix['Unnamed: 0'].unique().tolist(),reverse=True)[:-1]
i

# %%
promo.loc[promo['Unnamed: 0'] == 658, "Target"] = 0
for j in i:
    promo.loc[promo['Unnamed: 0'] == j, "Target"] = 1
promo[promo['Ref PC AC Number']=='IN012XXXXX1185']

# %%
promo['Name']=promo['FirstName']+' '+promo['LastName']
promo.nunique().sort_values(ascending=False)

# %%
promo=promo.drop(['FirstName','LastName'],axis=1)
promo.head()

# %%
promo['Name'].value_counts().sort_values(ascending=False)[:6]#abuse detected

# %%
fix=promo[promo['Name']=='amit kumar']
fix.head()

# %%
i=sorted(fix['Unnamed: 0'].unique().tolist(),reverse=True)[:-1]
i

# %%
promo.loc[promo['Unnamed: 0'] == 595, "Target"] = 0
for j in i:
    promo.loc[promo['Unnamed: 0'] == j, "Target"] = 1
promo[promo['Name']=='amit kumar']

# %%
fix=promo[promo['Name']=='akash gupta']
fix.head()

# %%
i=sorted(fix['Unnamed: 0'].unique().tolist(),reverse=True)[:-1]
i

# %%
promo.loc[promo['Unnamed: 0'] == 822, "Target"] = 0
for j in i:
    promo.loc[promo['Unnamed: 0'] == j, "Target"] = 1
promo[promo['Name']=='akash gupta']

# %%
fix=promo[promo['Name']=='rohit kumar']
fix.head()

# %%
i=sorted(fix['Unnamed: 0'].unique().tolist(),reverse=True)[:-1]
i

# %%
promo.loc[promo['Unnamed: 0'] == 886, "Target"] = 0
for j in i:
    promo.loc[promo['Unnamed: 0'] == j, "Target"] = 1
promo[promo['Name']=='rohit kumar']

# %%
fix=promo[promo['Name']=='raman ralhan']
fix.head()

# %%
i=sorted(fix['Unnamed: 0'].unique().tolist(),reverse=True)[:-1]
i

# %%
promo.loc[promo['Unnamed: 0'] == 456, "Target"] = 0
for j in i:
    promo.loc[promo['Unnamed: 0'] == j, "Target"] = 1
promo[promo['Name']=='raman ralhan']

# %%
fix=promo[promo['Name']=='sunil kumar']
fix.head()

# %%
i=sorted(fix['Unnamed: 0'].unique().tolist(),reverse=True)[:-1]
i

# %%
promo.loc[promo['Unnamed: 0'] == 490, "Target"] = 0
for j in i:
    promo.loc[promo['Unnamed: 0'] == j, "Target"] = 1
promo[promo['Name']=='sunil kumar']

# %%
round(promo.Name.isnull().sum()*100/len(promo),2)

# %%
promo[['Name']]=promo[['Name']].fillna('Unknown')
fix=promo[promo['Name']=='Unknown']#abuse detected as posssibility of hacker expected.
fix.head()

# %%
i=sorted(fix['Unnamed: 0'].unique().tolist(),reverse=True)
len(i)

# %%
for j in i:
    promo.loc[promo['Unnamed: 0'] == j, "Target"] = 1
promo.head()

# %%
round(promo.Target.isnull().sum()*100/len(promo),2)

# %%
promo.Target=promo.Target.fillna(0)
round(promo.Target.value_counts()*100/len(promo),2)

# %%
promo[['Sim_OS','Sim_Info','Sim_User']] = promo['Sim Id'].str.split(':',expand=True)
promo.head()

# %%
promo[['Device_OS','Device_Info','Device_User']] = promo['Device Id'].str.split(':',expand=True)
promo.head()

# %%
promo=promo.drop(['Device Id','Sim Id'],axis=1)
promo.head()

# %%
promo[['LastLoginTime','PresentLoginTime']].info()

# %%
promo['LastLoginTime']=promo['LastLoginTime'].replace('01-01-1900 00:00','00:00:00')
promo['LastLoginTime'].unique()

# %%
promo[['LastLoginTime_HH','LastLoginTime_MM','LastLoginTime_SS']] = promo['LastLoginTime'].str.split(':',expand=True)
promo.head()

# %%
promo[['PresentLoginTime_HH','PresentLoginTime_MM','PresentLoginTime_SS']] = promo['PresentLoginTime'].str.split(':',expand=True)
promo.head()

# %%
promo=promo.drop(['LastLoginTime','PresentLoginTime'],axis=1)
promo.head()

# %%
promo[['Meta Data_1','Meta Data_2','Meta Data_3','Meta Data_4']] =promo['Meta Data'].str.split('-',expand=True)
promo.head()

# %%
promo[['Email_user','Email_Domain']] =promo['Email'].str.split('@',expand=True)
promo.head()

# %%
promo=promo.drop(['Email','Meta Data'],axis=1)
promo.head()

# %%
promo[['Reg Client IP_1','Reg Client IP_2','Reg Client IP_3','Reg Client IP_4']] =promo['Reg Client IP'].str.split('.',expand=True)
promo.head()

# %%
promo=promo.drop(['Unnamed: 0','Reg Client IP'],axis=1)
promo.head()

# %%
promo.nunique().sort_values(ascending=False)

# %%
promo=promo.drop(['ProgramId','ProgramName','Meta Data_1','Meta Data_3','Status','Email_Domain','BadTryCount'],axis=1)
promo.head()

# %%
promo['Reg Referral Code']=promo['Reg Referral Code'].str.strip().str[-3:]
promo['Reg Referral Code'].head()

# %%
promo['RegisteredOn']=pd.to_datetime(promo['RegisteredOn'])
promo['Dob']=pd.to_datetime(promo['Dob'])
promo.head()

# %%
promo.info()

# %%
promo[['UserId','Mobile','PostalCode']]=promo[['UserId','Mobile','PostalCode']].astype(object)
promo.info()

# %%
promo.nunique().sort_values(ascending=False)

# %%
promo.columns

# %%
promo.info()

# %%
(promo.isnull().sum()*100/len(promo)).sort_values(ascending=False)

# %%
promo[['Reg Referral Code','Reg Referral Prefix']]=promo[['Reg Referral Code',
                                                                 'Reg Referral Prefix']].fillna('Unknown')
(promo.isnull().sum()*100/len(promo)).sort_values(ascending=False)

# %%
promo.Gender.value_counts()

# %%
promo['Gender']=promo['Gender'].fillna('U')
(promo.isnull().sum()*100/len(promo)).sort_values(ascending=False)

# %%
promo.nunique().sort_values(ascending=False)

# %%
promo.Name.value_counts()[:5]

# %%
# !pip install pycaret

# %%
promo.nunique().sort_values(ascending=False)*100/len(promo)

# %%
promo.columns

# %%
promo.info()

# %%
promo.nunique().sort_values(ascending=False)

# %%
# !pip install pandas-profiling

# %%
from pandas_profiling import ProfileReport
ProfileReport(promo, title="EDA Report")

# %%
data = promo.sample(frac=0.8, random_state=42)
data_unseen = promo.drop(data.index)
data.reset_index(inplace=True, drop=True)
data_unseen.reset_index(inplace=True, drop=True)
print('Data for Modeling: ' + str(data.shape))

# %%
print('Unseen Data For Predictions: ' + str(data_unseen.shape))

# %%
from pycaret.classification import *
promo= setup(data =data, session_id=42,
             target = 'Target',
                  normalize = True, 
                  transformation = True, 
                  log_experiment = True,
                  remove_multicollinearity = True, #rop one of the two features that are highly correlated with each other
                  date_features=['RegisteredOn','Dob'],
            categorical_features=[ 'Gender', 'UserId', 'Mobile', 'PostalCode',
       'OS Type', 'Reg Referral Code', 'Reg Referral Prefix',
       'Ref PC AC Number', 'Name', 'Sim_OS', 'Sim_Info', 'Sim_User',
       'Device_OS', 'Device_Info', 'Device_User', 'LastLoginTime_HH',
       'LastLoginTime_MM', 'LastLoginTime_SS', 'PresentLoginTime_HH',
       'PresentLoginTime_MM', 'PresentLoginTime_SS', 'Meta Data_2',
       'Meta Data_4', 'Email_user', 'Reg Client IP_1', 'Reg Client IP_2',
       'Reg Client IP_3', 'Reg Client IP_4'],
            high_cardinality_features =[ 'UserId', 'Mobile', 'PostalCode',
       'OS Type', 'Reg Referral Code',
       'Ref PC AC Number', 'Name', 'Sim_User',
        'Device_User', 'LastLoginTime_HH',
       'LastLoginTime_MM', 'LastLoginTime_SS', 'PresentLoginTime_HH',
       'PresentLoginTime_MM', 'PresentLoginTime_SS',
       'Meta Data_4', 'Email_user', 'Reg Client IP_1', 'Reg Client IP_2',
       'Reg Client IP_3', 'Reg Client IP_4']  ,         
            train_size = 0.8)

# %%
catboost = create_model('catboost')

# %%
print(catboost)

# %%
tuned_catboost = tune_model(catboost,optimize = 'AUC')

# %%
plot_model(tuned_catboost, plot = 'auc')

# %%
plot_model(tuned_catboost, plot = 'pr')

# %%
plot_model(tuned_catboost, plot='feature')

# %%
plot_model(tuned_catboost, plot = 'confusion_matrix')

# %%
evaluate_model(tuned_catboost)

# %%
predict_model(tuned_catboost)

# %%
unseen_predictions = predict_model(tuned_catboost, data=data_unseen)
unseen_predictions.head()

# %%
print("Confidence Score :   {}".format(round(unseen_predictions.Score.mean(),2)))#Confidence Score
