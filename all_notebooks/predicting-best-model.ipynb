# %% [markdown]
# ### Importing Libraries

# %%
# !pip install pycaret

# %%
import pandas as pd
from pycaret.classification import *

# %%
data = pd.read_csv("../input/pima-indians-diabetes-database/diabetes.csv")
data.head()

# %%
Setup = setup(data= data, target='Outcome',remove_outliers=True,normalize=True)

# %%
compare_models()

# %%
lr = create_model('lr')

# %% [markdown]
# ### Logistic Regression give better accuracy compare to other model.
# **Thank You.Please Upvote if it is helpful.**
