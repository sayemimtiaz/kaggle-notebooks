# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# <img src="https://wallpaperaccess.com/full/164886.jpg">

# %% [markdown]
# <h1><span style = "font-family: fantasy;background-color:#D2AD62;">Dataset : Hollywood Most Profitable Stories</span></h1>
#
# <h3><span style = "font-family: fantasy;background-color:#D2AD62;">Let's import the data</span></h3>

# %%
# importing the data 

data = pd.read_csv('/kaggle/input/hollywood-most-profitable-stories/HollywoodsMostProfitableStories.csv')

# first 5 rows 
data.head()

# %% [markdown]
# <h2><span style = "font-family: fantasy;background-color:#D2AD62;">Data Description</span></h2>

# %%
print(f'Shape of the data is {data.shape} as rows and columns respectively')
print('\n\nInfo of the data:')
print(data.info())

# %%
data.describe(include='all')

# %% [markdown]
# <h2><span style = "font-family: fantasy;background-color:#D2AD62;">Columns Description</span></h2>

# %% [markdown]
# - Film : Name of film
# - Genre : Genre of the movie
# - Lead Studio : Name of the lead studio
# - Audience Score :  The Audience Score, denoted by a popcorn bucket, is the percentage of users who have rated the movie or TV Show positively. For films to which we can verify users have bought tickets, the Audience Score is made up of Verified Ratings
# - Profitability : % of profit (need to verify)
# - Rotten Tomatoes % : The percentage is based on the film's reviews aggregated by the website and assessed as positive or negative, and when all aggregated reviews are positive, the film has a 100% rating
# - Worldwide Gross : Number of tickets sold x ticket price. It's the total amount generated by a movie at. ticket counters
# - Year : Year of release

# %% [markdown]
# <h1><span style = "font-family: fantasy;background-color:#D2AD62;">Checking: missing values</span></h1>

# %%
import missingno

missingno.bar(data, color="dodgerblue", sort="ascending", figsize=(10,5), fontsize=12);

# %%
missingno.matrix(data, sparkline=False, figsize=(10,5), fontsize=12, color=(0.27, 0.52, 1.0));

# %%
missingno.heatmap(data, figsize=(10,5), fontsize=12);

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['axes.facecolor'] = 'gray'

# %%
fig = plt.figure(figsize=(15,7))

ax1 = fig.add_subplot(1,2,1)
missingno.dendrogram(data, orientation="right", method="centroid", fontsize=12, ax=ax1);

ax2 = fig.add_subplot(1,2,2)
missingno.dendrogram(data, orientation="top", method="ward", fontsize=12, ax=ax2);

plt.tight_layout()

# %% [markdown]
# <h1><span style = "font-family: fantasy;background-color:#D2AD62;">Let's explore the particular Columns</span></h1>

# %%
data.head(2)

# %% [markdown]
# <h1><span style = "font-family: fantasy;background-color:#D2AD62;">Genre</span></h1>

# %%
fig, ax = plt.subplots(1, 1, figsize=(17, 8))
data.Genre.value_counts().plot(kind='barh', color='white')
plt.title('Genre', size=22)
plt.show()

# %% [markdown]
# <h1><span style = "font-family: fantasy;background-color:#D2AD62;">STUDIO</span></h1>

# %% [markdown]
# <img src="https://www.studiobabelsberg.com/fileadmin/a/sb/dateien/bilder/15x7/studios/Studio-1-3-stage-Filmkulisse-film-set-Studio-Babelsberg-d.jpg">

# %%
fig, ax = plt.subplots(1, 1, figsize=(17, 8))
data['Lead Studio'].value_counts().plot(kind='bar', color='white')
plt.title('Lead Studios', size=22)
plt.show()

# %% [markdown]
# <h1><span style = "font-family: fantasy;background-color:#D2AD62;">Worldwide Gross</span></h1>

# %%
fig, ax = plt.subplots(1, 1, figsize=(17, 8))

sns.distplot(data['Worldwide Gross'], kde=True, bins=20, color='white')
plt.title('WorldWide Gross', size=22)
ax.set_xlabel('WorldWide Gross', size=15)


plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(17, 8))

plt.hist(data['Worldwide Gross'], bins=10, color='white')
ax.set_xlabel('WorldWide Gross', size=15)
plt.title('WorldWide Gross', size=22)
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(17, 8))
plt.title('WorldWide Gross', size=22)


sns.boxplot(x='Worldwide Gross', data=data, color='white')
plt.show()

# %%
print('Lets see the values in Millions ')
print('Mean : ',data['Worldwide Gross'].mean())
print('Standard Deviation',data['Worldwide Gross'].std())
print('Max :',max(data['Worldwide Gross']))
print('Minimum',min(data['Worldwide Gross']))

# %% [markdown]
# <h1><span style = "font-family: fantasy;background-color:#D2AD62;">Film</span></h1>

# %%
print(data['Film'].values.tolist())

# %% [markdown]
# ### After looking for like 5 mins I found the movie I liked. and its
# <h2><span style = "font-family: fantasy;background-color:#FDD0AD;"> WALL-E...........................................................................................................................................</span></h2>
#
# <img src = 'https://media1.giphy.com/media/ZTN7U4ipOXPaw/200.gif' width=1000>
# <p><span style = "font-family: fantasy;background-color:#DDDDD;">This Movie is just beautiful:<br>
#     WALL-E (stylized with an interpunct as WALL·E) is a 2008 American computer-animated science fiction romantic comedy film produced by Pixar Animation Studios and released by Walt Disney Pictures. It was directed and co-written by Andrew Stanton, produced by Jim Morris, and co-written by Jim Reardon. It stars the voices of Ben Burtt, Elissa Knight, Jeff Garlin, John Ratzenberger, Kathy Najimy and Sigourney Weaver, with Fred Willard in the film's (and Pixar's) only prominent live-action role. The overall ninth feature film produced by the company, WALL-E follows a solitary robot on a future, uninhabitable, deserted Earth, left to clean up garbage. However, he is visited by a probe sent by the starship Axiom, a robot called EVE, with whom he falls in love and pursues across the galaxy</span></p>

# %% [markdown]
# <h1><span style = "font-family: fantasy;background-color:#D2AD62;"> Year </span></h1>

# %%
fig, ax = plt.subplots(1, 1, figsize=(17, 8))
data['Year'].value_counts().plot(kind='bar', color='white')
plt.title('Year', size=22)
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(17, 8))

sns.lineplot(data=data, x='Year', y='Worldwide Gross', color='white')
plt.show()

# %% [markdown]
# <h1><span style = "font-family: fantasy;background-color:#D2AD62;">Worldwide Gross by Year</span></h1>

# %%
fig, ax = plt.subplots(1, 1, figsize=(17, 8))

sns.violinplot(data=data, y='Worldwide Gross', x='Year')
plt.show()

# %% [markdown]
# <h1><span style = "font-family: fantasy;background-color:#D2AD62;">Pair plot</span></h1>

# %%
sns.pairplot(data)
plt.show()
