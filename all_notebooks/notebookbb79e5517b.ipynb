# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../input/credit-card-customers/BankChurners.csv')

# %%
df

# %%
df.tail()

# %%
df.info()

# %%
df = df[['Attrition_Flag', 'Customer_Age', 'Gender',
       'Dependent_count', 'Education_Level', 'Marital_Status',
       'Income_Category', 'Card_Category', 'Months_on_book',
       'Total_Relationship_Count', 'Months_Inactive_12_mon',
       'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
       'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
       'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio']]

# %%
df.head()

# %%
# print the first 10 rows
df.head(10)

# %%
df.info()

# %%
df.describe()

# %%
# checking for nul value
df.isnull().sum()

# %%
# check for duplcate data
df1 = df.duplicated() 
df1.sum()

# %%
#
df["Attrition_Flag"].value_counts()

# %%
df.groupby(['Customer_Age', 'Gender'])['Credit_Limit'].mean()

# %%
# visualise data
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# bar chart
plt.figure(figsize=(7,4))
sns.set_context(context='notebook',font_scale=1.3)
sns.set_style('darkgrid')
sns.countplot(df['Gender'],palette='rainbow');
plt.title('Number customer by gender');

# %%
df1 = df['Card_Category'].value_counts()

# %%
# Create a scatter plot
df.plot(kind='scatter', x ='Dependent_count', y='Total_Trans_Amt')
