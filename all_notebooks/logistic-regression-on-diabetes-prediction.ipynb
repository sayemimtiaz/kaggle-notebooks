# %%
# The following Notebook shows the application of logistic regression on a dataset. Various modules are used here specially model_selection which helps in applying the linear regression.
# Here after reading the dataset u need to alocate the independent columns to a variable and a dependent column to another variable.
# Hence after you have to use train_test_split for training and testing the dataset and finally obtain the predicted values.
# eg: here dependent column is Outcome and rest are independent.

import pandas as pd
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

df=pd.read_csv("../input/diabetes-prediction/Diabetespred.csv")
print(df)

x=df.loc[:,'Pregnancies':'Age']
y=df['Outcome']

X_train,X_test,Y_train,Y_test=model_selection.train_test_split(x,y,random_state=3,test_size=0.30)
data=sm.Logit(Y_train,X_train)
result=data.fit()
pred=result.predict(X_test)
print(pred)
print(Y_test)

# %%
# here prediction is done from pregnancies to insulin.

import pandas as pd
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

df=pd.read_csv("../input/diabetes-prediction/Diabetespred.csv")
print(df)

x=df.loc[:,'Pregnancies':'Insulin']
y=df['Outcome']

X_train,X_test,Y_train,Y_test=model_selection.train_test_split(x,y,random_state=3,test_size=0.30)
data=sm.Logit(Y_train,X_train)
result=data.fit()
pred=result.predict(X_test)
print(pred)
print(Y_test)

# %%
# checking out prediction from glucose to insulin.

import pandas as pd
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

df=pd.read_csv("../input/diabetes-prediction/Diabetespred.csv")
print(df)

x=df.loc[:,'Glucose':'Insulin']
y=df['Outcome']

X_train,X_test,Y_train,Y_test=model_selection.train_test_split(x,y,random_state=3,test_size=0.30)
data=sm.Logit(Y_train,X_train)
result=data.fit()
pred=result.predict(X_test)
print(pred)
print(Y_test)

# %%
# we tried out testing from blood pressure to diabetes pedigree function.

import pandas as pd
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

df=pd.read_csv("../input/diabetes-prediction/Diabetespred.csv")
print(df)

x=df.loc[:,'BloodPressure':'DiabetesPedigreeFunction']
y=df['Outcome']

X_train,X_test,Y_train,Y_test=model_selection.train_test_split(x,y,random_state=3,test_size=0.30)
data=sm.Logit(Y_train,X_train)
result=data.fit()
pred=result.predict(X_test)
print(pred)
print(Y_test)

# %%
# here lets try out from pregnancies to BMI.

import pandas as pd
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

df=pd.read_csv("../input/diabetes-prediction/Diabetespred.csv")
print(df)

x=df.loc[:,'Pregnancies':'BMI']
y=df['Outcome']

X_train,X_test,Y_train,Y_test=model_selection.train_test_split(x,y,random_state=3,test_size=0.30)
data=sm.Logit(Y_train,X_train)
result=data.fit()
pred=result.predict(X_test)
print(pred)
print(Y_test)

# %%
# finally lets test from pregnancies to skin thickness.

import pandas as pd
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

df=pd.read_csv("../input/diabetes-prediction/Diabetespred.csv")
print(df)

x=df.loc[:,'Pregnancies':'SkinThickness']
y=df['Outcome']

X_train,X_test,Y_train,Y_test=model_selection.train_test_split(x,y,random_state=3,test_size=0.30)
data=sm.Logit(Y_train,X_train)
result=data.fit()
pred=result.predict(X_test)
print(pred)
print(Y_test)
