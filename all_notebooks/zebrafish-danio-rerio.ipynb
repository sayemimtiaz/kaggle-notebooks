# %% [markdown]
# #Re-Identification of Zebrafish using Metric Learning
#
# Zebrafish are commonly used by biologists to test and analyze different drugs, group behaviors and much more. The movement pattern of zebrafish is, however, highly erratic and therefore hard to track. Re-identification is therefore an essential step in the tracking pipeline, in order to connect the generated tracklets. Tracking of zebrafish has traditionally been conducted with a top-view focused approach, discarding the visually rich side-view perspective. https://www.kaggle.com/aalborguniversity/aau-zebrafish-reid#Vid1_0001.png

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSyDFbd3XRG9SrYB95RJTpI11D7ChCMFY5EuIOa6h5hN7pJqHtH',width=400,height=400)

# %% [markdown]
# Image youtube.com

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import cv2
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# Image amazon.com.br
# #Zebrafish (Danio rerio)
#
# They are small freshwater fish that are commonly used in scientific research. They are considered to be a vertebrate “model organism,” with several characteristics that are desirable in a research environment.

# %%
#codes from Endi Niu @niuddd
img = cv2.imread('/kaggle/input/aau-zebrafish-reid/data/Vid1_1086.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
fig = plt.figure(figsize=(8,8))
plt.imshow(img)

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
zebrafish = pd.read_csv('../input/aau-zebrafish-reid/annotations.csv', delimiter=';', encoding = "ISO-8859-1", nrows = nRowsRead)
zebrafish.dataframeName = 'annotations.csv'
nRow, nCol = zebrafish.shape
print(f'There are {nRow} rows and {nCol} columns')

# %%
#codes from Endi Niu @niuddd
img = cv2.imread('/kaggle/input/aau-zebrafish-reid/data/Vid2_0184.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
fig = plt.figure(figsize=(8,8))
plt.imshow(img)

# %%
zebrafish.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# Image Sketching Science on Twitter - Vectorizing Zebra + Fish = Zebrafish.

# %%
zebrafish.dtypes

# %%
zebrafish["Upper left corner X"].plot.hist()
plt.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcT-yQPeGW2tNuqZC_HHvvioFMUwW_qmog3_mm7DoBPuu-osnF0f',width=400,height=400)

# %% [markdown]
# Image noldus.com - Zebrafish provide key insights into alcohol addiction by Guest Blogger. Noldus Information Technology. https://www.noldus.com/blog/zebrafish-insights-alcohol-addiction

# %%
zebrafish["Upper left corner Y"].plot.box()
plt.show()

# %%
sns.pairplot(zebrafish, x_vars=['Upper left corner X', 'Upper left corner Y', 'Lower right corner X'], y_vars='Lower right corner Y', markers="+", size=4)
plt.show()

# %%
zebrafishcorr=zebrafish.corr()
zebrafishcorr

# %%
sns.heatmap(zebrafishcorr,annot=True,cmap='Pastel1')
plt.show()

# %%
fig, axes = plt.subplots(1, 1, figsize=(14, 6))
sns.boxplot(x='Upper left corner X', y='Object ID', data=zebrafish, showfliers=False);

# %% [markdown]
# It was suppose to be some boxplot. However, I got Zebra style lines.

# %%
# Necessary Functions: 
def pie_plot(labels, values, colors, title):
    fig = {
      "data": [
        {
          "values": values,
          "labels": labels,
          "domain": {"x": [0, .48]},
          "name": "Job Type",
          "sort": False,
          "marker": {'colors': colors},
          "textinfo":"percent+label+value",
          "textfont": {'color': '#FFFFFF', 'size': 10},
          "hole": .6,
          "type": "pie"
        } ],
        "layout": {
            "title":title,
            "annotations": [
                {
                    "font": {
                        "size": 25,

                    },
                    "showarrow": False,
                    "text": ""

                }
            ]
        }
    }
    return fig

# %%
import plotly.offline as py
value_counts = zebrafish['Upper left corner X'].value_counts()
labels = value_counts.index.tolist()
py.iplot(pie_plot(labels, value_counts,['#1B9E77', '#7570B3'], "Upper left corner X"))

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# Image serious-science.org - Zebrafish Embryo

# %% [markdown]
# Codes from Andre Sionek @andresionek

# %%
import plotly.express as px

# Grouping it by corner
plot_data = zebrafish.groupby(['Upper left corner X', 'Lower right corner X'], as_index=False).Buffer.sum()

fig = px.line_polar(plot_data, theta='Upper left corner X', r='Buffer', color='Lower right corner X')
fig.update_layout(
    title_text='Zebrafish',
    height=500, width=1000)
fig.show()

# %% [markdown]
# Zebrafish Adjust Their Behavior in Response to an Interactive Robotic Predator https://www.frontiersin.org/articles/10.3389/frobt.2019.00038/full
#
# Zebrafish: the fish that is conquering laboratories  https://www.ufrgs.br/secom/ciencia/zebrafish-o-peixe-que-esta-conquistando-os-laboratorios
#
# The Zebrafish Information Network (ZFIN). https://zfin.org/
#
# The use of zebrafish (Danio rerio) as biomedical models https://academic.oup.com/af/article/9/3/68/5522877
#
# Zebrafish used to help save 10-year-old boy with rare genetic condition https://6abc.com/5712443/

# %%
import plotly.express as px

# Grouping it by corner
plot_data = zebrafish.groupby(['Upper left corner X', 'Object ID', 'Upper left corner Y', 'Lower right corner X', 'Lower right corner Y'], as_index=False).Buffer.sum()

fig = px.bar(plot_data, x='Upper left corner X', y='Buffer', color='Object ID')
fig.update_layout(
    title_text='Zebrafish',
    height=500, width=1000)
fig.show()

# %% [markdown]
# #My Aquarium is empty. No sign of Danio rerio aka Zebrafish.

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTfjL1dUUo8e8nWAya4vNlBxAwb653BE3PZIA0DqEEVGgui9ws2',width=400,height=400)

# %% [markdown]
# Image twitter.com - Zebrafish Rock!

# %% [markdown]
# #Re-Identification of Zebrafish using Metric Learning
#
# `@InProceedings{Haurum_2020_WACV_Workshops,
#     author = {Haurum, Joakim Bruslund and Karpova, Anastasija and Pedersen, Malte and Bengtson, Stefan Hein and Moeslund, Thomas B.},
#     booktitle = {The IEEE Winter Conference on Applications of Computer Vision (WACV) Workshops},
#     title = {Re-Identification of Zebrafish using Metric Learning},
#     month = {March},
#     year = {2020}
# }`

# %% [markdown]
# Kaggle Notebook Runner: Marília Prata @mpwolke.
