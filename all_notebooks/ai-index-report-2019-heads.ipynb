# %% [markdown]
#  "The annual rundown of ML data points is in its 3rd year. The AI world is booming in a range of metrics: research, education, and technical achievements. The AI Index covers a lot of ground. They have released two new tools. One for AI research papers and the other for investigating country-level data on research and investment. To save you from having to trudge through its 290 pages, here are some of the points: AI research is rocketing. AI education is equally popular. ML courses in universities and online continues to rise. The US is still the global leader. AI algorithms are becoming faster and cheaper to train. Autonomous vehicles received more private investment than any AI field." https://www.theverge.com/2019/12/12/21010671/ai-index-report-2019-machine-learning-artificial-intelligence-data-progress
# * The Report has many works. Choose one. Pick one. It's up to you. I just printed the heads of some of the files.

# %% [markdown]
# 1. R&D
#    (arXiv; Github; MAG; NESTA; Scopus.)
# 2. Conferences
#    (Ethics at AI Conference)
# 3. Technical Performance
#    (Compute Economics; Language; Omniglot; Summary; Vision)
# 4. The Economy
#    (Jobs; Investment; Corporate Activity)
# 5. Education
#    (AI Brain Drain; Course Enrollment; Coursera; CRA; Faculty Diversity; Udacity)
# 6. Autonomous Vehicles
#    (Bloomberg Philanthropy; Collision, Disengagement Report and Data, State Law)
# 7. Perception
#    (Authenticity; Campaign to Stop Killer Robots; Congress Mentions-BloombergGov; GDELT and Google Search; Mckinsey     Government Mention; News and Web Search; Prattle; SIPRI)
# 8. Societal
#    (Mckinsey; PwC; Quid)
# 9. Composite Measure
#    (Global AI Vibrancy; NAISR)

# %% [markdown]
# *  Human Predictions
# *  Graphics

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/png;base64,...',width=400,height=400)

# %% [markdown]
# Image hai.stanford.edu

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score,accuracy_score,confusion_matrix
# %matplotlib inline

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/6. Autonomous Vehicles/Bloomberg Philanthropy/Countries Testing AVs.xlsx')
df.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/png;base64,...',width=400,height=400)

# %% [markdown]
# Image payforsuccess.org

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/9. Composite Measure/Global AI Vibrancy/Raw Data/29. CAPIQ, CB, Quid_ Number of AI Startups Funded (num_AIstartups).xlsx')
df.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/png;base64,...',width=400,height=400)

# %% [markdown]
# Image startup.farm

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/4. The Economy/4.1. Jobs/Burning Glass/US State Data.xlsx')
df.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/png;base64,...',width=400,height=400)

# %% [markdown]
# Image burning-glass.com

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/1. R_D/arXiv/arXiv AI Categories 2019.xlsx')
df.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/png;base64,...',width=400,height=400)

# %% [markdown]
# Image meta.stackexchange.com

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/4. The Economy/4.1. Jobs/Indeed/Indeed State AI.xlsx')
df.head()

# %%
sns.distplot(df['portion_of_ai_jobs_us'])

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRzbkfOEEKOWzG3qCq3bbQmmlrrgBV4ydDyxA5MOLhDGpU4MqlZ&s',width=400,height=400)

# %% [markdown]
# Image readwrite.com

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/6. Autonomous Vehicles/Collision, Disengagement Report and Data/Miles and Number of Companies.xlsx')
df.head()

# %%
subject = 'miles','Miles Driven with AVs'
perc = [100-((96/303)*100),(96/303)*100]
explode = (0,0.1)
plt.pie(perc,explode=explode,labels=subject,autopct='%1.2f%%',shadow=True)
plt.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR8oURdeQrEJBCR45sE_3c9TpWs8FzvcaRhaq2Si4UVt5x5-vxpNg&s',width=400,height=400)

# %% [markdown]
# Image investors.com

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/1. R_D/NESTA/Deep Learning arXiv/RCA.xlsx')
df.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# Image eciaplatform.eu

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/7. Perception/GDELT and Google Search/GDELT and Web Search.xlsx')
df.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# Image youtube.com

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/1. R_D/NESTA/Women in AI/Women_in_ai_country_data.xlsx')
df.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTv4SKdsV53gDkyBOeKxyKH1Pzmr__9ZC_SqLhIebI_FlRcf-CDAw&s',width=400,height=400)

# %% [markdown]
# Image linkedin.com

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/7. Perception/Campaign to Stop Killer Robots/IPSOS tables (Autonomous Weapons - December 2018).xlsx')
df.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT8hQoFPMFVitFOsS-lbhYXIzsVPcAK1YOGNZ9GGuwPF1qGaRLu&s',width=400,height=400)

# %% [markdown]
# Image routledge.com

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/1. R_D/Github/Cumulative Github stars - AI libraries.xlsx')
df.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# Image techtudo.com.br

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/3. Technical Performance/Compute Economics/STANFORD DAWN/SQuAD.xlsx')
df.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/png;base64,...',width=400,height=400)

# %% [markdown]
# Image dawn.cs.stanford.edu

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/3. Technical Performance/Vision/Image Classification/ImageNet/ImageNet Training and Inference_ Time and Costs.xlsx')
df.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS-35sjMhjesLdBHviKcT6V3Nq792PAGAiPkqqSCX3OGpfLj_ARrA&s',width=400,height=400)

# %% [markdown]
# Image Kaggle.com

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/3. Technical Performance/Vision/COCO/COCO Leaderboard.xlsx')
df.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# Image slideshare.net

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/5. Education/AI Brain Drain/AI_Index.xlsx')
df.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/png;base64,...',width=400,height=400)

# %% [markdown]
# Image biztechclub.com

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/1. R_D/MAG/Citation/regional_pairwise_citations.xlsx')
df.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTie2OP0MO1lJzJ3cijNx51h9G_7sg81d_zUsvCVOWplSCjbbG57A&s',width=400,height=400)

# %% [markdown]
# Image semanticscholar.org

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/5. Education/Coursera/Coursera AI GSI Percentile and Category.xls')
df.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQK4mAQmu-1gYIc2OhYLZsABhdDjud1U9py5dzDbjqPonfKGQRd&s',width=400,height=400)

# %% [markdown]
# Image ilovephd.com

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# Image elsevier.com

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/1. R_D/Scopus/All Datasets.xlsx')
df.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRC-5JGtx6V02TTezuPLl1qPEt6ZNJGPTbqC8iUq0OjBaOA9Iri&s',width=400,height=400)

# %% [markdown]
# Image websiteplanet.com

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/5. Education/Udacity/Copy of Copy of Data to Share with Stanford, SG.xlsx')
df.head()

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/9. Composite Measure/Global AI Vibrancy/Raw Data/31. IFR and World Robotics_ Robot Installations (robot).xlsx')
df.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRa0ZVNbFqGMdr0ngjLUo8m9jslcgvNKg_ySrAJLbv3OZ4HOXPk&s',width=400,height=400)

# %% [markdown]
# Image mobile-industrial-robots.com

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/9. Composite Measure/Global AI Vibrancy/Raw Data/1, 7, 13. MAG Volume_ AI Journals, Conference Publications and Patents (num_AIconf_papers, num_AIjournal_papers, num_AIpatents).xlsx')
df.head()

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/9. Composite Measure/Global AI Vibrancy/Raw Data/34, 36. LinkedIn_ Male AI Skill Penetration and Male number of AI occupations (male_ai_skill_penetration, num_AIocc_male).xlsx')
df.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSvKJSaraC6-9poERPdfUXD9arG9Wz-5fHXJPpyxS5N5YRh-imM&s',width=400,height=400)

# %% [markdown]
# Image cbinsights.com   - 100 startups in different stages of R&D

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/9. Composite Measure/Global AI Vibrancy/Raw Data/32. NESTA arXiv_ Female AI authors (female_ai_authors).xlsx')
df.head()

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/Human Predictions/AI Index Questions on Metaculus.xlsx')
df.head()

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/5. Education/CRA/CRA Taulbee Survey - AI.xlsx')
df.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRTRLMGFjMDSI1I06Vlak8n_m5MEzvArJq79G60Rm3CiJqieGlW&s',width=400,height=400)

# %% [markdown]
# Image cra.org

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/2. Conferences/WiML.xlsx')
df.head()

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/8. Societal/McKinsey/AI for social good.xlsx')
df.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# Image healthcareimagined.net

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/2. Conferences/Ethics at AI conference/conf_matches_aggregated.xlsx')
df.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTqJH6AzAyLT4nAd4YOHDULoJJgZlhneu7YSs_mPZrvGRX0bnRk&s',width=400,height=400)

# %% [markdown]
# Image academyforlife.va

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ4DNQQRTtDYKb4UkzYtBwP4nEepk4iRAhPANMTjws_aENbfdV6sQ&s',width=400,height=400)

# %% [markdown]
# Image conference-board.org

# %% [markdown]
# * Artificial Intelligence Index Report 2019
# * Raymond Perrault, Yoav Shoham, Erik Brynjolfsson, Jack Clark, John Etchemendy, Barbara Grosz, Terah Lyons, James Manyika, Saurabh
# Mishra, and Juan Carlos Niebles, “The AI Index 2019 Annual Report”, AI Index Steering Committee, Human-Centered AI Institute,
# Stanford University, Stanford, CA, December 2019.
# * (c) 2019 by Stanford University, “The AI Index 2019 Annual Report” is made available under a Creative Commons AttributionNoDerivatives 4.0 License (International)
# https://creativecommons.org/licenses/by-nd/4.0/legalcode
# * The AI Index is as an independent initiative at Stanford University’s Human-Centered Artificial Intelligence Institute (HAI).

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/png;base64,...',width=400,height=400)

# %% [markdown]
# Image hai.stanford.edu

# %% [markdown]
# * Kaggle Notebook Runner: Marília Prata @mpwolke
