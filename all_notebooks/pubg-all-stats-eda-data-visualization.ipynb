# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df1=pd.read_csv(r'/kaggle/input/pubg-weapon-stats/pubg-weapon-stats.csv')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df1

# %%
df1.head()

# %%
df1.tail()

# %%
df1.info()

# %%
df1.describe()

# %%
df1.dropna(axis=0,inplace=True)

# %% [markdown]
# # Dropped all the rows containing null values because it effects Data cleaning process due to more Null values present in small DataSet.

# %%
df1

# %% [markdown]
# # Weapons are classified into Different Types.
# # Grouping that Data of Weapon Type and Analyzing the Data to better extent on the first go, based on Weapon Type vs Different Categories.

# %%
df1.groupby('Weapon Type').mean()

# %%
df1.groupby('Weapon Type')['Damage'].count()

# %% [markdown]
# # Weapons are classified into different types.
# # The following Plot shows different types of Weapons And Frequency of their availability : From the Plot we can say Assualt Riffles are more Frequently available.

# %%
plt.figure(figsize=(15,5))
plt.hist(df1['Weapon Type'],bins=15,color='lightgreen')
plt.xlabel('Weapon Type')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.grid(True)

# %% [markdown]
# # The following Plot shows the Magazine Capacity of each Weapon Type : From the Plot we can analyze 30 Magazine Guns are more in number.

# %%
plt.figure(figsize=(15,5))
plt.hist(df1['Magazine Capacity'],bins=20,color='b')
plt.xlabel('Magazine Capacity')
plt.ylabel('No. of Guns')
plt.title('Histogram')
plt.grid(True)

# %% [markdown]
# # Weapon Type Vs It's Range in Meters(i.e., How far the Bullet Travels).

# %%
plt.figure(figsize=(15,5))
sns.barplot(x = 'Weapon Type', y = 'Range', data = pd.read_csv(r'/kaggle/input/pubg-weapon-stats/pubg-weapon-stats.csv'))

# %% [markdown]
# # The following Plot shows the comparision between Range and Damage of different Weapon Type (HeadDamage without Helmet) :
# # Long Range and High Damage Guns are more Efficient and are used more Frequently : From this we can visualize Assault Riffle is more Consistent and used more Frequently.

# %%
plt.figure(figsize=(15,5))
plt.bar(df1['Weapon Type'], df1['Range'], label='Range', color='g')
plt.bar(df1['Weapon Type'], df1['HDMG_0'], label='Damage', color='r')
plt.xlabel('Weapon Type')
plt.ylabel('Range & Head Damage')
plt.title('Bar Chart')
plt.legend()
plt.grid(True)

# %% [markdown]
# # First for Weapon Type we Visualize each of the following individually :
# # 1) Damage
# # 2) Range
# # 3) Bullet Speed
# # 4) Rate of Fire
# # Then we Visualize any Two Categories of Weapon Types which are more Efficient.

# %% [markdown]
# # 1) Weapon Type vs Damage

# %%
df2=df1.groupby('Weapon Type')['Damage'].mean().reset_index()
df2

# %%
plt.figure(figsize=(7,7))
sns.barplot(y = 'Weapon Type', x = 'Damage', data = df2)

# %% [markdown]
# # 2) Weapon Type vs Range

# %%
df3=df1.groupby('Weapon Type')['Range'].mean().reset_index()
df3

# %%
plt.figure(figsize=(7,7))
sns.barplot(y = 'Weapon Type', x = 'Range', data = df3)

# %% [markdown]
# # 3) Weapon Type vs Bullet Speed

# %%
df4=df1.groupby('Weapon Type')['Bullet Speed'].mean().reset_index()
df4

# %%
plt.figure(figsize=(7,7))
sns.barplot(y = 'Weapon Type', x = 'Bullet Speed', data = df4)

# %% [markdown]
# # 4) Weapon Type vs Rate of Fire

# %%
df5=df1.groupby('Weapon Type')['Rate of Fire'].mean().reset_index()
df5

# %%
plt.figure(figsize=(7,7))
sns.barplot(y = 'Weapon Type', x = 'Rate of Fire', data = df5)

# %% [markdown]
# # By Comparing all four Categories together, from all the above Analysis and Visualization we can say that :
# # Assualt Rifle + Sniper Rifle is the Best Combo of Guns and is more Efficient. So lets Visualize them Individually for the same 4 different Categories.

# %% [markdown]
# # 1) DAMAGE :
# # a) Assualt Rifle Visualization:

# %%
df6 = df1[df1["Weapon Type"] == "Assault Rifle"][["Weapon Name","Damage"]].sort_values("Damage",ascending=False)
df6

# %%
plt.figure(figsize=(7,7))
sns.barplot(y = 'Weapon Name', x = 'Damage', data = df6)

# %% [markdown]
# # b) Sniper Rifle Visualization:

# %%
df7 = df1[df1["Weapon Type"] == "Sniper Rifle"][["Weapon Name","Damage"]].sort_values("Damage",ascending=False)
df7

# %%
plt.figure(figsize=(12,6))
sns.barplot(y = 'Weapon Name', x = 'Damage', data = df7)

# %% [markdown]
# # 2) Range :

# %% [markdown]
# # a) Assualt Rifle Visualization :

# %%
df8 = df1[df1["Weapon Type"] == "Assault Rifle"][["Weapon Name","Range"]].sort_values("Range",ascending=False)
df8

# %%
plt.figure(figsize=(7,7))
sns.barplot(y = 'Weapon Name', x = 'Range', data = df8)

# %% [markdown]
# # b) Sniper Rifle Visualization :

# %%
df9 = df1[df1["Weapon Type"] == "Sniper Rifle"][["Weapon Name","Range"]].sort_values("Range",ascending=False)
df9

# %%
plt.figure(figsize=(12,6))
sns.barplot(y = 'Weapon Name', x = 'Range', data = df9)

# %% [markdown]
# # 3) Bullet Speed

# %% [markdown]
# # a) Assault Rifle Visualization :

# %%
df10 = df1[df1["Weapon Type"] == "Assault Rifle"][["Weapon Name","Bullet Speed"]].sort_values("Bullet Speed",ascending=False)
df10

# %%
plt.figure(figsize=(7,7))
sns.barplot(y = 'Weapon Name', x = 'Bullet Speed', data = df10)

# %% [markdown]
# # b) Sniper Rifle Visualization :

# %%
df11 = df1[df1["Weapon Type"] == "Sniper Rifle"][["Weapon Name","Bullet Speed"]].sort_values("Bullet Speed",ascending=False)
df11

# %%
plt.figure(figsize=(12,6))
sns.barplot(y = 'Weapon Name', x = 'Bullet Speed', data = df11)

# %% [markdown]
# # 4) Rate of Fire

# %% [markdown]
# # a) Assualt Rifle Visualization :

# %%
df12 = df1[df1["Weapon Type"] == "Assault Rifle"][["Weapon Name","Rate of Fire"]].sort_values("Rate of Fire",ascending=False)
df12

# %%
plt.figure(figsize=(7,7))
sns.barplot(y = 'Weapon Name', x = 'Rate of Fire', data = df12)

# %% [markdown]
# # b) Sniper Rifle Visualization :

# %%
df13 = df1[df1["Weapon Type"] == "Sniper Rifle"][["Weapon Name","Rate of Fire"]].sort_values("Rate of Fire",ascending=False)
df13

# %%
plt.figure(figsize=(12,6))
sns.barplot(y = 'Weapon Name', x = 'Rate of Fire', data = df13)

# %% [markdown]
# # These are the Analysis and Visualization on different Categories with respect to Weapon Type.
# # From Above Individual Analysis of Every Weapon Name of Assualt and Sniper Rifles, we Conclude that Groza + AWM is the Beast Combination. M249 gives tough competition with Groza, either of them can be used,it's upto player wish.

# %% [markdown]
# # Hope you liked it, Upvote if Liked it.
