# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.cluster.hierarchy import linkage, dendrogram
from sklearn.cluster import KMeans, AgglomerativeClustering, AffinityPropagation
from sklearn.mixture import GaussianMixture 
import os
import cv2
import random

# %%
data = pd.read_csv("../input/pokemons-and-there-stats/pokemon_df.csv")
data[0:10]

# %%
data.info()

# %%
data2=data[['Attack','Defence']]

# %%
def doAgglomerative(X, nclust=2):
    model = AgglomerativeClustering(n_clusters=nclust,affinity='euclidean',linkage='ward')
    clust_labels1 = model.fit_predict(X)
    return (clust_labels1)

clust_labels1 = doAgglomerative(data2,20)
agglomerative = pd.DataFrame(clust_labels1)
data2.insert((data2.shape[1]),'agglomerative',agglomerative)

# %%
data3=data2
data3['Name']=data['Name']
data3

# %%
for i in range(20):
    names0=data3[data3['agglomerative']==i]['Name'] 
    print('[ Agglomerative '+str(i)+' ]')
    print(list(set(names0)))
    print()

# %%
data2.groupby('agglomerative').mean()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
scatter = ax.scatter(data2['Attack'],data2['Defence'],c=agglomerative[0],s=50)
ax.set_title('Agglomerative Clustering')
ax.set_xlabel('Attack')
ax.set_ylabel('Defence')
plt.rcParams['figure.figsize'] = (6,5)
plt.colorbar(scatter)

# %% [markdown]
# ### Group of attack ability max

# %%
Names=data2[data2['agglomerative']==6]['Name']
print(list(Names))

# %%
files=[]
for item in set(Names):
    files+=[item.lower()+'.png']
print(files)
print(len(files))

# %%
img_dir='../input/pokemon-images-and-types/images/images'

# %%
i=random.randrange(16)
f, axarr = plt.subplots(1,1,figsize=(5,5))
img1 = cv2.imread(os.path.join(img_dir,files[i]))
axarr.imshow(img1)
axarr.set_xticks([])
axarr.set_yticks([])
axarr.set_title(files[i])

# %% [markdown]
# ### Group of attack ability min

# %%
Names2=data2[data2['agglomerative']==17]['Name']
print(list(Names2))

# %%
files2=[]
for item in set(Names2):
    files2+=[item.lower()+'.png']
print(files2)
print(len(files2))

# %%
i=random.randrange(41)
f, axarr = plt.subplots(1,1,figsize=(5,5))
img2 = cv2.imread(os.path.join(img_dir,files2[i]))
axarr.imshow(img2)
axarr.set_xticks([])
axarr.set_yticks([])
axarr.set_title(files2[i])
