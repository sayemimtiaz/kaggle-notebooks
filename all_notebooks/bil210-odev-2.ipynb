# %%
import numpy as np 
import pandas as pd 
import seaborn as sns  # görsel

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../input/iris-flower-dataset/IRIS.csv')

# %%
df.head(7) #veri setinin ilk 7 değeri

# %%
df.isna().sum() #Veri Sorgulama NaN değeri aranır

# %%
df["sepal_length"].unique() #NaN değeri dışındaki de tespit etmek istersek, her bir veri seti değişkeninde sorguladık

# %%
df["sepal_width"].unique()

# %%
df["petal_length"].unique()

# %%
df["petal_width"].unique()

# %%
df["sepal_length"].nunique() # unique değerlerinin sayısını öğrenebiliriz

# %%
df["species"].nunique() # daha anlamlı bir gösterim olması için "species"te nunique fonksiyonunu tekrar kullandım.

# %%
df["sepal_length"].std()#veri setindeki tüm çiçeklerin sepal_lenght değerinin standart sapması

# %%
df["sepal_width"].mean()#Ortalama

# %%
df["petal_length"].median()#medyan

# %%
df.describe().T #Bu fonksiyon sadece sayısal verilerin dağılımı olduğu için species kolonu gösterilmemiştir

# %%
df[(df['species'])== "Iris-setosa"].std()

# %% [markdown]
# # **Görselleştirme çalışmaları

# %%
sns.heatmap(df.corr(), annot=True, linewidths=.5) #Korelasyon kat sayısı

# %%
sns.scatterplot(x='sepal_width', y='sepal_length',data=df[(df['species'])== "Iris-setosa"])

# %%
sns.jointplot(x='sepal_width', y='sepal_length', data=df)

# %%
sns.violinplot(y = "sepal_width", data=df);
# Keman grafiği

# %%
sns.jointplot(x = df["sepal_length"], y = df["sepal_width"] , kind ="kde", shade = "True");

# %%
sns.violinplot(x='species', y='sepal_length', data=df) #Keman grafiğinin türler arası karşılaştırmalı çizimi

# %%
sns.scatterplot(x = "petal_length", y = "petal_width", hue = "species", data = df);

# %%
sns.countplot('species',data=df)
plt.show()

# %%
sns.FacetGrid(df,hue="species",height=5).map(sns.distplot,"sepal_width").add_legend();

# %%
plt.figure(figsize=(7,7))
sns.set_style('whitegrid')
sns.pairplot(data=df, hue='species', palette=['green','red', 'blue'])
