# %% [markdown]
# On March 13, 2020, 13 new cases of coronavirus (COVID-19) were confirmed in Poland. Thus, since March 4 2020, the total number of cases in the country reached 64. However, over 14.8 thousand people were under epidemiological supervision. On 12 March, the first fatalities were recorded, a 56-year-old female patient from Poznań. According to the Minister of Health, the patient had serious health problems before the infection. https://www.statista.com/statistics/1102374/poland-coronavirus-covid-19-new-cases-by-date/
#
#
# The Polish government has decided to introduce health checks at the main border crossings as part of measures to prevent the unrestricted spread of coronavirus in Poland. We would ask all passengers, for the sake of their own health, to complete the forms honestly and we would ask carriers and travel operators to distribute the forms as early as possible to passengers so that border checks can be quick and efficient.https://www.poland.travel/en/travel-inspirations/safety-advice-for-travellers-concerning-the-covid-19-epidemic

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRysQxVz6zhd-o6tt0M-bc6aSApAaJCW0g9-9ulyOIKDkJFqEqu',width=400,height=400)

# %% [markdown]
# dreamstime.com - Respirator mask with flag of Poland - Coronavirus COVID-19 epidemic concept.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import feature_extraction, linear_model, model_selection, preprocessing
import plotly.graph_objs as go
import plotly.offline as py
import plotly.express as px
from plotly.offline import iplot
import plotly.express as px

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
df = pd.read_csv("../input/covid19-in-poland-dataset/2020-03-15.csv")

# %% [markdown]
# #Code from @devonc https://www.kaggle.com/devonc/coronavirus-covid-19-pandemic-visualizations

# %%
#df.head(n=5)
df.style.background_gradient(subset=['Confirmed'], cmap='Reds', axis=None)\
        .background_gradient(subset=['Deaths'], cmap='Blues', axis=None)

# %%
df.dtypes

# %%
sns.distplot(df["Confirmed"].apply(lambda x: x**4))
plt.show()

# %%
sns.countplot(df["Confirmed"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #Codes from Tawej https://www.kaggle.com/tawejssh/covid-19

# %% [markdown]
# In the 3rd line it was suppose to be evolution[Recovered]/evolution[Confirmed]  However this Dataset doesn't have Recovered column. So I repeated Confirmed, to keep the code.

# %%
#Let's visualise the evolution of results
evolution = df.groupby('Last Update').sum()[['Confirmed', 'Deaths']]
evolution['Deaths Rate'] = (evolution['Deaths'] / evolution['Confirmed']) * 100
evolution['Confirmed Rate'] = (evolution['Confirmed'] / evolution['Confirmed']) * 100
evolution.head()

# %%
plt.figure(figsize=(20,7))
plt.plot(evolution['Confirmed'], label='Confirmed')
plt.plot(evolution['Deaths'], label='Deaths')
#plt.plot(evolution['Recovered'], label='Recovered')
plt.legend()
plt.grid()
plt.title('Evolution of COVID-19 Results')
plt.xticks(evolution.index,rotation=45)
plt.xlabel('Observation Date')
plt.ylabel('Number of Cases')
plt.show()

# %% [markdown]
# #Codes fromThor God of Thunder

# %%
cat = []
num = []
for col in df.columns:
    if df[col].dtype=='O':
        cat.append(col)
    else:
        num.append(col)  
        
        
num

# %%
plt.style.use('dark_background')
for col in df[num].drop(['Confirmed'],axis=1):
    plt.figure(figsize=(8,5))
    plt.plot(df[col].value_counts(),color='Red')
    plt.xlabel(col)
    plt.ylabel('Confirmed')
    plt.tight_layout()
    plt.show()

# %%
for col in df.columns:
    plt.figure(figsize=(18,9))
    sns.factorplot(x=col,y='Confirmed',data=df)
    plt.tight_layout()
    plt.show()

# %%
for col in df.columns:
    plt.figure(figsize=(18,9))
    sns.barplot(x=col,y='Deaths',data=df)
    sns.pointplot(x=col,y='Deaths',data=df,color='Black')
    plt.tight_layout()
    plt.show()

# %%
#word cloud
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in df.Voivodeship)
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200,colormap='Set3', background_color="black").generate(text)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='Bilinear')
plt.axis("off")
plt.figure(1,figsize=(12, 12))
plt.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTJINVJ52dPQ2LthcBjTNNaaIXBI5tJKR21z3MNcZPjrkltKXHw',width=400,height=400)

# %% [markdown]
# alamy.com

# %% [markdown]
# Kaggle Notebook Runner: Marília Prata  @mpwolke
