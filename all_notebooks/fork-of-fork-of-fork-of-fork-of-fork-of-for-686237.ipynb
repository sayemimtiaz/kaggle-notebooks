# %% [markdown]
# # true pi=3,14159265358979324

# %% [markdown]
# #=

# %% [markdown]
# # true 3,14159265358979324

# %% [markdown]
# #*
# #true (13.500.000.000.000.000.000.000)

# %% [markdown]
# #%
# #=

# %% [markdown]
# #true Y1
# #falseY2

# %% [markdown]
# <#100%=1#99%=2#98%=3#97%=4#96%=5#95%=6#94%=7#93%=8#92%=9#91%=10#90%=11#89%=12#88%=13
# #87%=14#86%=15#85%=16#84%=17#83%=18#82%=19#81%=20#80%=21#79%=22#78%=23#77%=24#76%=25
# #75%=26#74%=27#73%=28#72%=29#71%=30#70%=31#69%=32#68%=33#67%=34#66%=35#67%=36#66%=37
# #65%=38#64%=39#63%=40#62%=41#61%=42#60%=43#59%=44#58%=45#57%=46#56%=47#55%=48
#
# #54%=49#53%=50#52%=51#51%=52#50%=53#49%=54#48%=55#47%=56#46%=57#45%=58#44%=59#43%=60
# #42%=61#41%=62#40%=63#39%=64#38%=65#37%=66#36%=67#35%=68#34%=69#33%=70#32%=71#31%=72
# #30%=73#29%=74#28%=75
# #27%=76
# #26%=77
# #25%=78
# #24%=79
# #23%=80
# #22%=81
# #21%=82
# #20%=83
# #19%=84
# #18%=85
# #17%=86
# #16%=87
# #15%=88
# #14%=89
# #13%=90
# #12%=91
# #11%=92
# #10%=93
# #9%=94
# #8%=95
# #7%=96
# #6%=97
# #5%=98
# #4%=99
# #3%=100
# #2%=101
# #1%=102>

# %% [markdown]
# > #Y1=1
# #Y2=0

# %% [markdown]
# #[pi^360](6,447)=0,0000000000000001
