# %%
# DISPLAYING THE HEART_DISEASE_PATIENTS_DETAILS TABLE

import pandas as pd

df=pd.read_csv('../input/heart-disease-patients-details/heart_disease.csv')
df

# %%
# WAP TO OBTAIN HISTOGRAM OF 'resting_blood_pressure' COLUMN

import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('../input/heart-disease-patients-details/heart_disease.csv')

df['resting_blood_pressure'].hist(figsize=(12,10))
plt.title('Resting_blood_pressure')
plt.ylabel('Observation')
plt.xlabel('Range')

# %%
# WAP TO OBTAIN HISTOGRAM OF 'serum_cholestoral' COLUMN

import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('../input/heart-disease-patients-details/heart_disease.csv')

df['serum_cholestoral'].hist(figsize=(12,10),color='yellow')
plt.title('Serum_cholestoral')
plt.ylabel('Observation')
plt.xlabel('Range')

# %%
# WAP TO OBTAIN HISTOGRAM OF 'resting_electrocardiographic_results' COLUMN

import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('../input/heart-disease-patients-details/heart_disease.csv')

df['resting_electrocardiographic_results'].hist(figsize=(12,10),color='red')
plt.title('Resting_electrocardiographic_results')
plt.ylabel('Observation')
plt.xlabel('Range')

# %%
# WAP TO OBTAIN HISTOGRAM OF 'maximum_heart_rate_achieved' COLUMN

import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('../input/heart-disease-patients-details/heart_disease.csv')

df['maximum_heart_rate_achieved'].hist(figsize=(12,10),color='pink')
plt.title('Maximum_heart_rate_achieved')
plt.ylabel('Observation')
plt.xlabel('Range')

# %%
# WAP TO OBTAIN HISTOGRAM OF 'result' COLUMN

import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('../input/heart-disease-patients-details/heart_disease.csv')

df['result'].hist(figsize=(12,10),color='purple')
plt.title('Result')
plt.ylabel('Observation')
plt.xlabel('Range')

# %%
# WAP TO OBTAIN HISTOGRAM OF 'thal' COLUMN

import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('../input/heart-disease-patients-details/heart_disease.csv')

df['thal'].hist(figsize=(12,10),color='crimson')
plt.title('Thal')
plt.ylabel('Observation')
plt.xlabel('Range')

# %%
# WAP TO OBTAIN HISTOGRAM OF 'number_of_major_vessels' COLUMN

import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('../input/heart-disease-patients-details/heart_disease.csv')

df['number_of_major_vessels'].hist(figsize=(12,10),color='black')
plt.title('Number_of_major_vessels')
plt.ylabel('Observation')
plt.xlabel('Range')

# %%
# WAP TO OBTAIN HISTOGRAM OF 'slope' COLUMN

import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('../input/heart-disease-patients-details/heart_disease.csv')

df['slope'].hist(figsize=(12,10),color='gray')
plt.title('Slope')
plt.ylabel('Observation')
plt.xlabel('Range')

# %%
# WAP TO OBTAIN HISTOGRAM OF 'exercise_induced_angina' COLUMN

import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('../input/heart-disease-patients-details/heart_disease.csv')

df['exercise_induced_angina'].hist(figsize=(12,10),color='violet')
plt.title('Exercise_induced_angina')
plt.ylabel('Observation')
plt.xlabel('Range')

# %%
# WAP TO OBTAIN HISTOGRAM OF 'fasting_blood_sugar' COLUMN

import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('../input/heart-disease-patients-details/heart_disease.csv')

df['fasting_blood_sugar'].hist(figsize=(12,10),color='indigo')
plt.title('Fasting_blood_sugar')
plt.ylabel('Observation')
plt.xlabel('Range')

# %%
# WAP TO OBTAIN HISTOGRAM OF 'resting_electrocardiographic_results' COLUMN

import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('../input/heart-disease-patients-details/heart_disease.csv')

df['resting_electrocardiographic_results'].hist(figsize=(12,10),color='green')
plt.title('Resting_electrocardiographic_results')
plt.ylabel('Observation')
plt.xlabel('Range')

# %%
# WAP TO OBTAIN HISTOGRAM OF 'chest' COLUMN

import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('../input/heart-disease-patients-details/heart_disease.csv')

df['chest'].hist(figsize=(12,10),color='red')
plt.title('Chest')
plt.ylabel('Observation')
plt.xlabel('Range')

# %%
# WAP TO OBTAIN HISTOGRAM OF 'sex' COLUMN

import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('../input/heart-disease-patients-details/heart_disease.csv')

df['sex'].hist(figsize=(12,10),color='pink')
plt.title('Sex')
plt.ylabel('Observation')
plt.xlabel('Range')

# %%
# WAP TO OBTAIN HISTOGRAM OF 'age' COLUMN

import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('../input/heart-disease-patients-details/heart_disease.csv')

df['age'].hist(figsize=(12,10),color='yellow')
plt.title('Age')
plt.ylabel('Observation')
plt.xlabel('Range')

# %%
# WAP TO OBTAIN HISTOGRAM OF ALL COLUMNS

import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('../input/heart-disease-patients-details/heart_disease.csv')

df.hist(figsize=(20,15),color='Green')
