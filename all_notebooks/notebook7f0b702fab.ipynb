# %%
from pandas_profiling import ProfileReport
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv("../input/historical-bitcoin-data/Bitcoin Historical Data - In Rupees.csv")

# %%
data.head()

# %%
data.info()

# %%
data['Date']=pd.to_datetime(data['Date'])

# %%
data['Open'] = pd.to_numeric(data['Open'],errors = 'coerce')

# %%
data['Price'] = pd.to_numeric(data['Price'],errors = 'coerce')

# %%
data['High'] = pd.to_numeric(data['High'],errors = 'coerce')

# %%
data['Low'] = pd.to_numeric(data['Low'],errors = 'coerce')

# %%
data['Vol.'] = pd.to_numeric(data['Vol.'],errors = 'coerce')

# %%
data['Change %'] = pd.to_numeric(data['Change %'],errors = 'coerce')

# %%
data.info()

# %%
data.describe()

# %%
sns.heatmap(data.isna())

# %%
data['Day']=data['Date'].dt.day_name()

# %%
data.head()

# %%
data['Day'].value_counts(normalize=True)

# %%
plt.style.use("fivethirtyeight")
plt.figure(figsize=(15,7))
sns.lineplot(x='Date',y='Price',data=data,hue="Day")
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.lineplot(x='Date',y='Open',data=data,hue="Day")

# %%
plt.figure(figsize=(15,7))
sns.lineplot(x='Date',y='High',data=data,hue="Day")

# %%
plt.figure(figsize=(15,7))
sns.lineplot(x='Date',y='Low',data=data,hue="Day")

# %%
sns.pairplot(data,hue='Day')

# %%
x=ProfileReport(data)

# %%
x
