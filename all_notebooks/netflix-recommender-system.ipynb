# %% [markdown]
# # Table of Content:-
# * **Panda**
# * **Nump**y
# * **Matplotlib**
# * **Seaborn**
# * **Plotly**
# * **Recomender System**
# * **Conclusion**

# %% [markdown]
# # Dataset -Description
# * **show_id** - numeric Value of Shows available in Netflix
# * **type** - Type of show avilable on Netflix - Movie and TV show
# * **title**- Title of show avilable on Netflix
# * **director**- Direcots listed in Movie and TV show
# * **cast** - Actor and Actress
# * **country**-  Origin country of the show
# * **date_added** -Year when conted added to Netflux
# * **release_year** - Relase year of the Show
# * **rating** - Rating given by the users
# * **duration** - Duration of the show avilable on Netflix
# * **listed_in**-  When the show avilable on netflix
# * **description**- - Decription given by Usera

# %%
from IPython.display import Image
Image("../input/netflix/thibault-penin-AWOl7qqsffM-unsplash-scaled.jpg")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from pandas import plotting

#plotly 
import plotly.offline as py
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
init_notebook_mode(connected=True)
import plotly.figure_factory as ff
import plotly.express as px

# %%
df=pd.read_csv('../input/netflix-shows/netflix_titles.csv')
df.head()

# %% [markdown]
# # Visualizing the percentage missing value from dataset

# %%
((df.isnull().sum()/len(df))*100).sort_values(ascending=True).plot(kind='barh',figsize=(10,10))
plt.grid(b=True, which='both')

# %% [markdown]
# # Count of type
# * Movie and TV show counts
# * As we can see maximu is Movie
# * 70% Movies and 30% TV shows

# %%
df['type'].value_counts().plot(kind='barh', figsize=(10,10))
plt.grid(b=True, which='both')

# %%
((df['type'].value_counts()/len(df))*100).plot(kind='barh', figsize=(10,10))
plt.grid(b=True, which='both')

# %% [markdown]
# # Reading the dataset

# %%
dat=ff.create_table(df.head(10))
py.iplot(dat)

# %%
# checks if there is any null value or not
df.isnull().any().any()

# %% [markdown]
# **Obs** :-As we can see that there is null value

# %% [markdown]
# # PLotting the different rating in dataset

# %%
df['rating'].value_counts()

# %% [markdown]
# # Plotting the different ratings from the dataset

# %%
df['rating'].value_counts().plot(kind='barh', figsize=(10,10))
plt.grid()
plt.title("PLotting the rating curve ")
plt.show()

# %% [markdown]
# **Inference**
# * There are only 14 different rating in datasdt
# * Maximum rating is "TV-MA" ,its couunts is more 2863
# * Then -TV-14 - count is 1931
# * Least is NC-17 , count is 3

# %%
x=df['type'].value_counts()
x

# %% [markdown]
# # Pie Chart for the Type of Genre

# %%
plt.rcParams['figure.figsize'] = (9, 9)
labels=['Movie', 'Tv']
plt.pie(x, explode=(0,0.1), labels=labels,autopct='%1.1f%%', shadow=True)
plt.title('Type ', fontsize = 20)
plt.axis('off')
plt.legend()
plt.show()

# %%
df.columns

# %%
col = "type"
grouped = df[col].value_counts().reset_index()
grouped = grouped.rename(columns = {col : "count", "index" : col})

## plot
trace = go.Pie(labels=grouped[col], values=grouped['count'], pull=[0.05, 0], marker=dict(colors=["#6ad49b", "#a678de"]))
layout = go.Layout(title="", height=600, legend=dict(x=0.1, y=1.1))
fig = go.Figure(data = [trace], layout = layout)
iplot(fig)

# %%
col = "rating"
grouped = df[col].value_counts().reset_index()
grouped = grouped.rename(columns = {col : "count", "index" : col})

## plot
plt.figure(figsize=(10,10))
trace = go.Pie(labels=grouped[col], values=grouped['count'], pull=[0.05, 0], marker=dict(colors=["#6ad49b", "#a678de"]))
layout = go.Layout(title="", height=800, legend=dict(x=0.1, y=1.1))
fig = go.Figure(data = [trace], layout = layout)
iplot(fig)

# %%
d1 = df[df["type"] == "TV Show"]
d2 = df[df["type"] == "Movie"]

col = "date_added"

vc1 = d1[col].value_counts().reset_index()
vc1 = vc1.rename(columns = {col : "count", "index" : col})
vc1['percent'] = vc1['count'].apply(lambda x : 100*x/sum(vc1['count']))
vc1 = vc1.sort_values(col)

vc2 = d2[col].value_counts().reset_index()
vc2 = vc2.rename(columns = {col : "count", "index" : col})
vc2['percent'] = vc2['count'].apply(lambda x : 100*x/sum(vc2['count']))
vc2 = vc2.sort_values(col)

trace1 = go.Scatter(x=vc1[col], y=vc1["count"], name="TV Shows", marker=dict(color="#a678de"))
trace2 = go.Scatter(x=vc2[col], y=vc2["count"], name="Movies", marker=dict(color="#6ad49b"))
data = [trace1, trace2]
layout = go.Layout(title="Content added over the years", legend=dict(x=0.1, y=1.1, orientation="h"))
fig = go.Figure(data, layout=layout)
fig.show()

# %%
df.columns

# %%
df.info()

# %%
df['date_added']=pd.to_datetime(df['date_added'])
df['year_added']=df['date_added'].dt.year
df['month_added']=df['date_added'].dt.month

# %%
df['season_counts']=df.apply(lambda x: x['duration'].split(" ")[0] if "Season" in x['duration'] else "", axis=1)
df['duration']=df.apply(lambda x: x['duration'].split(" ")[0] if "Season" in x['duration'] else "", axis=1)
df.head()

# %%
df.info()

# %% [markdown]
# # Content added over the year
# * As we can see the curve
# * Movie was popular once, but the popularity starts decrease
# * Tv show on the other hand starts incfreasing with the timming

# %%
d1 = df[df["type"] == "TV Show"]
d2 = df[df["type"] == "Movie"]

col = "year_added"

vc1 = d1[col].value_counts().reset_index()
vc1 = vc1.rename(columns = {col : "count", "index" : col})
vc1['percent'] = vc1['count'].apply(lambda x : 100*x/sum(vc1['count']))
vc1 = vc1.sort_values(col)

vc2 = d2[col].value_counts().reset_index()
vc2 = vc2.rename(columns = {col : "count", "index" : col})
vc2['percent'] = vc2['count'].apply(lambda x : 100*x/sum(vc2['count']))
vc2 = vc2.sort_values(col)

trace1 = go.Scatter(x=vc1[col], y=vc1["count"], name="TV Shows", marker=dict(color="#a678de"))
trace2 = go.Scatter(x=vc2[col], y=vc2["count"], name="Movies", marker=dict(color="#6ad49b"))
data = [trace1, trace2]
layout = go.Layout(title="Content Release years", legend=dict(x=0.1, y=1.1, orientation="h"))
fig = go.Figure(data, layout=layout)
fig.show()

# %% [markdown]
# # Content Realease date over the period

# %%
d1 = df[df["type"] == "TV Show"]
d2 = df[df["type"] == "Movie"]

col = "release_year"

vc1 = d1[col].value_counts().reset_index()
vc1 = vc1.rename(columns = {col : "count", "index" : col})
vc1['percent'] = vc1['count'].apply(lambda x : 100*x/sum(vc1['count']))
vc1 = vc1.sort_values(col)

vc2 = d2[col].value_counts().reset_index()
vc2 = vc2.rename(columns = {col : "count", "index" : col})
vc2['percent'] = vc2['count'].apply(lambda x : 100*x/sum(vc2['count']))
vc2 = vc2.sort_values(col)

trace1 = go.Bar(x=vc1[col], y=vc1["count"], name="TV Shows", marker=dict(color="#a678de"))
trace2 = go.Bar(x=vc2[col], y=vc2["count"], name="Movies", marker=dict(color="#6ad49b"))
data = [trace1, trace2]
layout = go.Layout(title="Content Release years", legend=dict(x=0.1, y=1.1, orientation="h"))
fig = go.Figure(data, layout=layout)
fig.show()

# %% [markdown]
# **Obs**:-
# * it is obious from the plot
# * Movie release date is decreases
# * Tv show is getting much popular

# %% [markdown]
# # Content added over the month

# %%
col = "month_added"

vc1 = d1[col].value_counts().reset_index()
vc1 = vc1.rename(columns = {col : "count", "index" : col})
vc1['percent'] = vc1['count'].apply(lambda x : 100*x/sum(vc1['count']))
vc1 = vc1.sort_values(col)

vc2 = d2[col].value_counts().reset_index()
vc2 = vc2.rename(columns = {col : "count", "index" : col})
vc2['percent'] = vc2['count'].apply(lambda x : 100*x/sum(vc2['count']))
vc2 = vc2.sort_values(col)

trace1 = go.Bar(x=vc1[col], y=vc1["count"], name="TV Shows", marker=dict(color="#a678de"))
trace2 = go.Bar(x=vc2[col], y=vc2["count"], name="Movies", marker=dict(color="#6ad49b"))
data = [trace1, trace2]
layout = go.Layout(title="Content Release years", legend=dict(x=0.1, y=1.1, orientation="h"))
fig = go.Figure(data, layout=layout)
fig.show()

# %% [markdown]
# **Obs**
# * As we can see that content added over the month
# * DUring january the movie added is most
# * During the december the Tv show added is more

# %%
df.columns

# %%
small = df.sort_values("release_year", ascending = True)
small = small[small['season_counts'] != ""]
small[['title', "release_year"]][:15]

# %% [markdown]
# # Oldest Release

# %%
small = df.sort_values("release_year", ascending = True)
small = small[small['release_year'] != ""]
small[['title', "release_year"]][:15]

# %% [markdown]
# # Oldest Moview Relase with year

# %%
small = d1.sort_values("release_year", ascending = True)
small = small[small['release_year'] != ""]
small[['title', "release_year"]][:15]

# %% [markdown]
# # Oldest TV show Relase with year

# %%
small = d2.sort_values("release_year", ascending = True)
small = small[small['release_year'] != ""]
small[['title', "release_year"]][:15]

# %%
df.columns

# %%
plt.figure(figsize=(10,10))
sns.displot(df['duration'],bins=100, kde=True)
plt.show()

# %%
df.columns

# %% [markdown]
# # Season counts

# %%
col = "season_counts"

vc1 = d1[col].value_counts().reset_index()
vc1 = vc1.rename(columns = {col : "count", "index" : col})
vc1['percent'] = vc1['count'].apply(lambda x : 100*x/sum(vc1['count']))
vc1 = vc1.sort_values(col)

vc2 = d2[col].value_counts().reset_index()
vc2 = vc2.rename(columns = {col : "count", "index" : col})
vc2['percent'] = vc2['count'].apply(lambda x : 100*x/sum(vc2['count']))
vc2 = vc2.sort_values(col)

trace1 = go.Bar(x=vc1[col], y=vc1["count"], name="TV Shows", marker=dict(color="#a678de"))
trace2 = go.Bar(x=vc2[col], y=vc2["count"], name="Movies", marker=dict(color="#6ad49b"))
data = [trace1, trace2]
layout = go.Layout(title="Season counts of show", legend=dict(x=0.1, y=1.1, orientation="h"))
fig = go.Figure(data, layout=layout)
fig.show()

# %%
col = "season_counts"

vc1 = d1[col].value_counts().reset_index()
vc1 = vc1.rename(columns = {col : "count", "index" : col})
vc1['percent'] = vc1['count'].apply(lambda x : 100*x/sum(vc1['count']))
vc1 = vc1.sort_values(col)

trace1 = go.Bar(x=vc1[col], y=vc1["count"], name="TV Shows", marker=dict(color="#a678de"))

data = [trace1]
layout = go.Layout(title="Season counts of Movies", legend=dict(x=0.1, y=1.1, orientation="h"))
fig = go.Figure(data, layout=layout)
fig.show()

# %%
vc2 = d2[col].value_counts().reset_index()
vc2 = vc2.rename(columns = {col : "count", "index" : col})
vc2['percent'] = vc2['count'].apply(lambda x : 100*x/sum(vc2['count']))
vc2 = vc2.sort_values(col)
trace2 = go.Bar(x=vc2[col], y=vc2["count"], name="Movies", marker=dict(color="#6ad49b"))
data = [trace1]
layout = go.Layout(title="Season counts of Tv Series", legend=dict(x=0.1, y=1.1, orientation="h"))
fig = go.Figure(data, layout=layout)
fig.show()

# %% [markdown]
# # Rating counts of the Movie and TV show

# %%
col = "rating"

vc1 = d1[col].value_counts().reset_index()
vc1 = vc1.rename(columns = {col : "count", "index" : col})
vc1['percent'] = vc1['count'].apply(lambda x : 100*x/sum(vc1['count']))
vc1 = vc1.sort_values(col)

vc2 = d2[col].value_counts().reset_index()
vc2 = vc2.rename(columns = {col : "count", "index" : col})
vc2['percent'] = vc2['count'].apply(lambda x : 100*x/sum(vc2['count']))
vc2 = vc2.sort_values(col)

trace1 = go.Bar(x=vc1[col], y=vc1["count"], name="TV Shows", marker=dict(color="#a678de"))
trace2 = go.Bar(x=vc2[col], y=vc2["count"], name="Movies", marker=dict(color="#6ad49b"))
data = [trace1, trace2]
layout = go.Layout(title="Rating count of MOvie and TV show", legend=dict(x=0.1, y=1.1, orientation="h"))
fig = go.Figure(data, layout=layout)
fig.show()

# %%
df.columns

# %%
col = "listed_in"

vc1 = d1[col].value_counts().reset_index()
vc1 = vc1.rename(columns = {col : "count", "index" : col})
vc1['percent'] = vc1['count'].apply(lambda x : 100*x/sum(vc1['count']))
vc1 = vc1.sort_values(col)

vc2 = d2[col].value_counts().reset_index()
vc2 = vc2.rename(columns = {col : "count", "index" : col})
vc2['percent'] = vc2['count'].apply(lambda x : 100*x/sum(vc2['count']))
vc2 = vc2.sort_values(col)

trace1 = go.Bar(x=vc1[col], y=vc1["count"], name="TV Shows", marker=dict(color="#a678de"))
trace2 = go.Bar(x=vc2[col], y=vc2["count"], name="Movies", marker=dict(color="#6ad49b"))
data = [trace1, trace2]
layout = go.Layout(title="Rating count of MOvie and TV show", legend=dict(x=0.1, y=1.1, orientation="h"))
fig = go.Figure(data, layout=layout)
fig.show()

# %% [markdown]
# **Obs**
# * Not a very good insight
# * Need alternative method to plot the curve

# %% [markdown]
# # Top 20 Plotting the list of top Genres that are avilable in Netflix

# %%
df['listed_in'].value_counts().sort_values(ascending=False).iloc[1:21].plot(kind='barh', figsize=(15,15))
plt.grid()
plt.show()

# %% [markdown]
# **Inference**
# * List of top 20 geners
# * Stand up-comedy is quite popular, Most Popular one
# * Then Drama , internation Movie
# * Like wise we can see list of the number

# %% [markdown]
# # Top 50 % of Plotting the list of top Genres that are avilable in Netflix

# %%
((df['listed_in'].value_counts()/len(df))*100).sort_values(ascending=False).iloc[1:51].plot(kind='barh', figsize=(15,15))
plt.grid()
plt.show()

# %%
((df['listed_in'].value_counts()/len(df))*100).sort_values(ascending=False).iloc[1:21].plot(kind='barh', figsize=(15,15))
plt.grid()
plt.show()

# %% [markdown]
# **inference**
# * As we can see that Stand up comedy and Drama are almost same popular
# * The differece between Stand up comedy and Drama is not that big

# %%
df['listed_in'].head()

# %% [markdown]
# # Content from top 20 country

# %%
df['country'].value_counts().sort_values(ascending=False).iloc[1:21].plot(kind='barh', figsize=(15,15))
plt.grid()
plt.show()

# %%
df.columns

# %%
df[df['country']=="India"]['cast'].value_counts().sort_values(ascending=False).iloc[1:21].plot(kind='barh', figsize=(15,15))

# %%
from collections import Counter
def country_trace(country, flag = "movie"):
    df["from_us"] = df['country'].fillna("").apply(lambda x : 1 if country.lower() in x.lower() else 0)
    small = df[df["from_us"] == 1]
    if flag == "movie":
        small = small[small["duration"] != ""]
    else:
        small = small[small["season_count"] != ""]
    cast = ", ".join(small['cast'].fillna("")).split(", ")
    tags = Counter(cast).most_common(25)
    tags = [_ for _ in tags if "" != _[0]]

    labels, values = [_[0]+"  " for _ in tags], [_[1] for _ in tags]
    trace = go.Bar(y=labels[::-1], x=values[::-1], orientation="h", name="", marker=dict(color="#a678de"))
    return trace

from plotly.subplots import make_subplots
traces = []
titles = ["United States", "","India","", "United Kingdom", "Canada","", "Spain","", "Japan"]
for title in titles:
    if title != "":
        traces.append(country_trace(title))

fig = make_subplots(rows=2, cols=5, subplot_titles=titles)
fig.add_trace(traces[0], 1,1)
fig.add_trace(traces[1], 1,3)
fig.add_trace(traces[2], 1,5)
fig.add_trace(traces[3], 2,1)
fig.add_trace(traces[4], 2,3)
fig.add_trace(traces[5], 2,5)

fig.update_layout(height=1200, showlegend=False)
fig.show()

# %% [markdown]
# # Content added over the time

# %%
col = "listed_in"
categories = ", ".join(d2['listed_in']).split(", ")
counter_list = Counter(categories).most_common(50)
labels = [_[0] for _ in counter_list][::-1]
values = [_[1] for _ in counter_list][::-1]
trace1 = go.Bar(y=labels, x=values, orientation="h", name="TV Shows", marker=dict(color="#a678de"))

data = [trace1]
layout = go.Layout(title="Content added over the years", legend=dict(x=0.1, y=1.1, orientation="h"))
fig = go.Figure(data, layout=layout)
fig.show()

# %%
df.isnull().sum()

# %%
for i in df.columns:
    null_rate=df[i].isnull().sum()/len(df)*100
    if null_rate>0:
        print("{} 's null rate {}%".format(i, round(null_rate,2)))

# %%
df.nunique()

# %%
df.notna().sum().plot(kind='barh', figsize=(15,15))
plt.grid()
plt.show()

# %%
rating_replacements = {
    67: 'TV-PG',
    2359: 'TV-14',
    3660: 'TV-MA',
    3736: 'TV-MA',
    3737: 'NR',
    3738: 'TV-MA',
    4323: 'TV-MA '
}

for id, rate in rating_replacements.items():
    df.iloc[id, 8] = rate
    
df['rating'].isnull().sum()

# %% [markdown]
# # Taking the only Non-Null columns from the dataset

# %%
df=df[df["date_added"].notna()]

# %%
df.isnull().sum()

# %% [markdown]
# # Filling the country column with Most common country

# %%
df['country'] = df['country'].fillna(df['country'].mode()[0])

# %%
df.isnull().sum()

# %%
df['country'].nunique()

# %% [markdown]
# **Obs**
# * There are 681 unique country in dataset

# %%
df['Principal_country']=df['country'].apply(lambda x: x.split(",")[0])
df['Principal_country'].head()

# %%
df.head()

# %%
df['Principal_country'].nunique()

# %% [markdown]
# **Obs**
# * Now there are only 81 unique country

# %%
df.isnull().sum()

# %%
ratings_ages = {
    'TV-PG': 'Older Kids',
    'TV-MA': 'Adults',
    'TV-Y7-FV': 'Older Kids',
    'TV-Y7': 'Older Kids',
    'TV-14': 'Teens',
    'R': 'Adults',
    'TV-Y': 'Kids',
    'NR': 'Adults',
    'PG-13': 'Teens',
    'TV-G': 'Kids',
    'PG': 'Older Kids',
    'G': 'Kids',
    'UR': 'Adults',
    'NC-17': 'Adults'
}
df['target_ages'] = df['rating'].replace(ratings_ages)
df['target_ages'].unique()

# %%
country_data = df['country']
country_count = pd.Series(dict(Counter(','.join(country_data).replace(' ,',',').replace(
    ', ',',').split(',')))).sort_values(ascending=False)
top20country = country_count.head(20)
plt.figure(figsize=(15,5))
sns.barplot(x= top20country.index, y=top20country, palette="pastel")
plt.xticks(rotation=50)
plt.title('Top 20 countries with most contents', fontsize=15, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.countplot(x=df['target_ages'],hue=df['type'])
plt.grid()
plt.show()

# %% [markdown]
# # Word cloud of the Movie added over the period

# %%
from wordcloud import WordCloud,STOPWORDS

text=' '.join(d1['listed_in'])

plt.rcParams['figure.figsize']=(15,15)
wordcloud=WordCloud(background_color='black', colormap='vlag', width=1200, height=1200, max_words=121).generate(text)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# #  Word cloud of the Tv Show added over the period

# %%
text=' '.join(d2['listed_in'])

plt.rcParams['figure.figsize']=(15,15)
wordcloud=WordCloud(background_color='lightblue', colormap='vlag', width=1200, height=1200, max_words=121).generate(text)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# # Visualization of the Ratings

# %%
Ratings = df['rating'].value_counts()

# %%
Visualization = px.funnel(Ratings,title='Types of Rating on Netflix')

Visualization.show()

# %% [markdown]
# # Visualizing the Rating Target

# %%
Ratings = df['target_ages'].value_counts()
Visualization = px.funnel(Ratings,title='Types of Target Audience on Netflix')

Visualization.show()

# %%
Ratings = df['country'].value_counts().iloc[1:20]
Visualization = px.funnel(Ratings,title='Top Country on Netflix')

Visualization.show()

# %%
df.columns

# %%
df.info()

# %% [markdown]
# # Word Cloud of the top title of Movie on Netflix

# %%
text=' '.join(d1['title'])

plt.rcParams['figure.figsize']=(15,15)
wordcloud=WordCloud(background_color='black', colormap='vlag', width=1200, height=1200, max_words=121).generate(text)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# # Word Cloud of the top title of TV show on Netflix

# %%
text=' '.join(d2['title'])

plt.rcParams['figure.figsize']=(15,15)
wordcloud=WordCloud(background_color='lightblue', colormap='vlag', width=1200, height=1200, max_words=121).generate(text)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
df_country = df['country'].value_counts()

iplot([go.Choropleth(
    locationmode='country names',
    locations=df_country.index.values,
    text=df.index,
    z=df.values,
)])

# %% [markdown]
# # Recommendations
# * Here we are going  to recommend content base recommendation
# * We have the required columns as type, casting , rating, target_ratings, etc

# %%
! pip install rake_nltk
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from rake_nltk import Rake

# %%
df.columns

# %%
df_new=df[['title','director','cast','listed_in', 'description']]
df_new.head()

# %%
df_new['director']=df_new['director'].fillna(' ')
df_new['director']=df_new['director'].astype('str')

# %%
df_new['cast']=df_new['cast'].fillna(' ')
df_new['cast']=df_new['cast'].astype('str')

# %%
df_new['bag_of_word']= ''
for index,row in df_new.iterrows():
    plot = row['description']
    r = Rake()
    r.extract_keywords_from_text(plot)
    keyword_score = r.get_word_degrees()
    g = ''.join(row['listed_in'].split(',')).lower()
    d = ''.join(row['director'].replace(' ','').split(',')).lower()
    a = ' '.join(row['cast'].replace(' ','').split(',')).lower()
    k = ' '.join(list(keyword_score.keys()))
    row['bag_of_word'] = g + ' ' + ' ' + d + ' ' + a + ' ' + k

mydf = df_new[['title','bag_of_word']]
mydf.head()

# %%
c = CountVectorizer()
count_mat = c.fit_transform(mydf['bag_of_word'])
cosine_sim = cosine_similarity(count_mat,count_mat)
print(cosine_sim)

# %% [markdown]
# # Recommending Top 10 content from Netflix

# %%
indices = pd.Series(mydf['title'])
def recommend_movie(name):
    movie=[]
    idx = indices[indices == name].index[0]
    sort_index = pd.Series(cosine_sim[idx]).sort_values(ascending = False)
    top_10 = sort_index.iloc[1:11]
    for i in top_10.index:
        movie.append(indices[i])
    return movie

# %%
recommend_movie('Transformers Prime')

# %%
df['title'].head(20)

# %%
recommend_movie('1983')

# %% [markdown]
# # Conclusion
# 1. Recommender systems are used in a variety of areas, with commonly recognised examples taking the form of playlist generators for video and music services, product recommenders for online stores, or content recommenders for social media platforms and open web content recommenders
# 2. It is great way of recommending the Best content of Top Netflix content
# 3. Next update will be done and soon
# 4. If you like you can follow and review my other kernels. Here is my profile
# [Rabi SIngh](https://www.kaggle.com/jurk06)

# %%
from IPython.display import Image
Image("../input/thank-you/download.jpg", width=1000, height=1000)
