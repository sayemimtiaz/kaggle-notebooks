# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# i use output of this notebook(../input/3-house-price-imputation-miss-values-r) for decrease usage

# %%
df_impu= pd.read_csv('../input/3-house-price-imputation-miss-values-r/df_imputation.csv')

# %%
df_impu.head()

# %%
df_impu.drop('X',axis =1 ,inplace =True)

# %% [markdown]
# # Usage_Memory is 821.4 KB

# %%
df_impu.info()

# %%
category_var = df_impu.select_dtypes(include = 'object')
num_var = df_impu.select_dtypes(exclude = 'object')

print("Number of categorical features are: ", category_var.shape[1])
print("Number of numerical features are: ", num_var.shape[1])

# %%
# lists=num_var.columns
num_var.describe()
# num_var.drop('YearBuilt',axis=1)

# %%
num_var.drop(['YearBuilt','LotArea','YearRemodAdd','YrSold','SalePrice','X1stFlrSF','TotalBsmtSF'],axis =1 ,inplace =True )

# %%
num_var.describe()

# %%
for i in num_var:
    df_impu[i]=df_impu[i].astype(np.int16)
df_impu.info()

# %% [markdown]
# # Our Memory Usage is:  590.4+ KB

# %%
df_impu.describe()

# %%
list2 = ['YearBuilt','LotArea','YearRemodAdd','YrSold','SalePrice','X1stFlrSF','TotalBsmtSF']
for i in list2:
    df_impu[i]=df_impu[i].astype(np.int32)
df_impu.describe()

# %% [markdown]
# # memory usage: 557.0+ KB

# %%
df_impu.info()

# %%
df_impu.to_csv('df_usage_me.csv',index =False)
# pd.write
