# %% [markdown]
# An Analysis of Journalists Killed Worldwide Since 1992

# %% [markdown]
# I've created and loaded a visualisation of the data on Tableau Public. This is my first, so pease do let me know your thoughts and bear with me!
#
# https://public.tableau.com/shared/YQQK493PS?:toolbar=no&:display_count=yes
