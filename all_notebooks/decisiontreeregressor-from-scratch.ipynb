# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
house_data = pd.read_csv('../input/home-data-for-ml-course/train.csv')
print(house_data.describe())

# %%
class DT_Node:
    # tree node object
    def __init__(self, feature=None, left_node=None, right_node=None, leaf=None, threshhold=None, info_gain=None):
        self.feature = freature
        self.left_node=left_node
        self.right_node =left_node
        self.leaf = leaf
        self.threshold=threshhold
        self.info_gain =info_gain

class CustomisedDecisionTreeRegressor():
    def __init__(self, X,Y,min_tree_depth=2,max_tree_depth=2):
        self.train_x= X
        self.train_y=Y
        self.maxium_tree_depth = max_tree_depth
        self.minimum_tree_depth = min_tree_depth
        
    #calculate information gain in each splitting    
    def information_gain(self, parent, left_child,right_child):
        w_left = len(left_child)/len(parent)
        w_right = len(right_child)/len(parent)
        info_gain = np.var(parent)- (w_left*np.var(left_child)+w_right*np.var(right_child))
        return info_gain
    
    #tree split function
    def split_feature(self, feature, threshold):
        left_child = [val for val in feature if val<=threshold]
        right_child = [val for val in feature if val>threshold]
        return left_child, right_child
    
    #find the best/optimal splitting point
    def update_split(self, featureset):
        split_point={}
        ref_info_gain =-flot("inf")
        for feature_id in featureset:
            threshold_unique = np.unique(featureset[feature_id])
            for threshold in threshold_unique:
                left_child, right_child = self.split_feature(featureset[feature_id],threshold)
                info_gain =information_gain(featureset[feature_id],left_child,right_child)
                if info_gain>ref_info_gain:
                    
                    split_point["splitting_feature"] =feature_id
                    split_point['Threshold'] =threshold
                    split_point["Left_node"] =left_child
                    split_point["Right_node"] =right_child
                    split_point["Information_gain"] =info_gain
                    
                    ref_info_gain=info_gain
        return split_point
    
    
    def tree_construction(self,X,Y,depth):
        pass
