# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df_train = pd.read_csv('../input/harga-real-estate/harga_real_estate.csv')

# %%
df_train.columns

# %%
df_train['Y_harga_unit'].describe()

# %%
sns.distplot(df_train['Y_harga_unit']);

# %%
print("Skewness: %f" % df_train['Y_harga_unit'].skew())
print("Kurtosis: %f" % df_train['Y_harga_unit'].kurt())

# %%
var = 'X1_Usia_Rumah'
data = pd.concat([df_train['Y_harga_unit'], df_train[var]], axis=1)
data.head()

# %%
data.plot.scatter(x=var, y='Y_harga_unit', ylim=(0,120))

# %%
sns.lmplot(var, 'Y_harga_unit', df_train)

# %%
sns.lmplot(var, 'Y_harga_unit', df_train, order=2)

# %%
var = 'X3_jumlah_toko'
data = pd.concat([df_train['Y_harga_unit'], df_train[var]], axis=1)
data.plot.scatter(x=var, y='Y_harga_unit', ylim=(0,120))

# %%
sns.lmplot(var, 'Y_harga_unit', df_train)

# %%
var = 'X2_jarak_MRT'
data = pd.concat([df_train['Y_harga_unit'], df_train[var]], axis=1)
data.plot.scatter(x=var, y='Y_harga_unit', ylim=(0,120))

# %%
sns.lmplot(var, 'Y_harga_unit', df_train)

# %%
var = 'X2_jarak_MRT'
data = pd.concat([df_train['Y_harga_unit'], df_train[var]], axis=1)

f, ax = plt.subplots(figsize=(8,6))
fig = sns.boxplot(x=var, y='Y_harga_unit', data=data)
fig.axis(ymin=0, ymax=120)

# %%
var = 'X1_Usia_Rumah'
data = pd.concat([df_train['Y_harga_unit'], df_train[var]], axis=1)

f, ax = plt.subplots(figsize=(8,6))
fig = sns.boxplot(x=var, y='Y_harga_unit', data=data)
fig.axis(ymin=0, ymax=120)

# %%
var = 'X1_Usia_Rumah'
data = pd.concat([df_train['Y_harga_unit'], df_train[var]], axis=1)
f, ax = plt.subplots(figsize=(16,8))
fig = sns.boxplot(x=var, y='Y_harga_unit', data=data)
fig.axis(ymin=0, ymax=120)
plt.xticks(rotation=90)

# %%
corrmat = df_train.corr()
f, ax = plt.subplots(figsize=(10,9))

sns.heatmap(corrmat, vmax=.8, square=True)

# %%
k = 10 

cols = corrmat.nlargest(k, 'Y_harga_unit')['Y_harga_unit'].index

cm = np.corrcoef(df_train[cols].values.T)
cm

# %%
cm2 = np.corrcoef(df_train[cols].values)
cm2

# %%
df_train[cols].values

# %%
sns.set(font_scale=1.25)

hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, 
                yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
sns.set()
cols = ['X1_Usia_Rumah', 'X2_jarak_MRT', 'X3_jumlah_toko', 'Y_harga_unit']
sns.pairplot(df_train[cols], size=2.5)
plt.show()

# %%
total = df_train.isnull().sum().sort_values(ascending=False)

percent = (df_train.isnull().sum()/df_train.isnull().count()).sort_values(ascending=False)

missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)

# %%
sns.distplot(df_train['Y_harga_unit'], fit=norm)

fig = plt.figure()
res = stats.probplot(df_train['Y_harga_unit'], plot=plt)

# %%
df_train = pd.get_dummies(df_train)

# %%
df_train
