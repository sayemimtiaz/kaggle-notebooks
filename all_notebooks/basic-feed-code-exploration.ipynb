# %% [markdown]
# Exploration of the data using basic Bash commands only.
#
# The number of lines in any file can be counted by the 'wc -l filepath' command on a unix terminal.
#
# The first two code blocks summarise the daily article count for both weekly files using the 'awk' command.

# %%
# !cat ../input/news-week-17aug24.csv | cut -d"," -f1 | awk '{print substr($1,1,8)}' | sort -n | uniq -c

# %%
# !cat ../input/news-week-18aug24.csv | cut -d"," -f1 | awk '{print substr($1,1,8)}' | sort -n | uniq -c

# %% [markdown]
# Highly active Feeds with more than 500 articles a published within a week.
#
# The number of unique feed_code values encountered for the Year 2017 vs 2018 is equal to **20873** & **19238** respectively.

# %%
# !cat ../input/news-week-17aug24.csv | cut -d"," -f2 | sort | uniq -c | sort -nr | head -499

# %%
# !cat ../input/news-week-18aug24.csv | cut -d"," -f2 | sort | uniq -c | sort -nr | head -499

# %% [markdown]
# Another internal timekeeping metric I call the *pratieadhravya-thalakhathara* (Samskrit).
#
# This format groups by day:hour which is convenient for the exceedingly rare case of weekly bulk stream files.
#
# This structure can be represented by the matrix pd(24x31), the concatenation of whose padded index positions read as integers yield one hundred and six primes.

# %%
# !cat ../input/news-week-17aug24.csv ../input/news-week-18aug24.csv | cut -d"," -f1 | awk '{print substr($1,7,4)}' | sort -n | uniq -c
