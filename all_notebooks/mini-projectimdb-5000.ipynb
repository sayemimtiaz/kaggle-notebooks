# %% [markdown]
# ดิอินเทอร์เน็ตมูวีเดตาเบส (อังกฤษ: The Internet Movie Database หรือ IMDb) เป็นฐานข้อมูลออนไลน์รวบรวมเกี่ยวกับเรื่องราวของ นักแสดง ผู้กำกับ และบุคคลที่เกี่ยวข้องในวงการภาพยนตร์ IMDb เปิดให้บริการตั้งแต่ปี พ.ศ. 2533 และกลายเป็นส่วนหนึ่งของ Amazon.com ตั้งแต่ปี พ.ศ. 2541 นอกจากข้อมูลแล้ว IMDb ยังเป็นศูนย์รวมของคนดูภาพยนตร์ เพราะนอกจากข้อมูลของภาพยนตร์, ประวัตินักแสดง-ผู้กำกับภาพยนตร์-ทีมงานภาพยนตร์แล้ว ยังได้รวบรวมคลิปของตัวอย่างภาพยนตร์เรื่องต่าง ๆ ไว้ และยังเปิดโอกาสให้ผู้ชมได้แสดงความเห็นเกี่ยวกับภาพยนตร์เรื่องต่าง ๆ ด้วยการให้คะแนนอีกด้วย

# %% [markdown]
# 1 การนำเข้าข้อมูล โดย import และประกาศค่าตัวแปรต่างๆ

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
df_movie = pd.read_csv('../input/tmdb-movie-metadata/tmdb_5000_movies.csv')
df_credit = pd.read_csv('../input/tmdb-movie-metadata/tmdb_5000_credits.csv')

# %% [markdown]
# 1. Question or problem definition
#
# เนื่องจากในปัจจุบันหนังต่างๆเป็นที่นิยมมากและทำให้เกิดประเภทของหนังและนักแสดงมากมาย ผู้กำกับและค่ายหนังส่วนใหญ่จึงจำเป็นต้องใช้ข้อมูลจากผลการวิจัยในนี้ Research เพื่อหาผลรวบรวมข้อมูลอันดับประเภทของหนังและนักแสดงต่างๆเพื่อประกอบการสร้างหนัง ข้อมูลนี้จึงเป็นสิ่งที่สำคัญมากสำหรับผู้กำกับและค่ายหนังต่างๆเพื่อทำให้หนังประสบความสำเร็จมากที่สุด เช่น ประเภทหนัง นักแสดง เพื่อหาข้อมูลว่าแท้จริงแล้วคนสนใจในการดูหนังประเภทไหนนักแสดงคนได้ทีคนชอบเยอะและแนวพอตเรื่องของหนังแนวหนัง เพื่อทำการสร้างหนังหรือหานักแสดงเพื่อให้หนังมีความนิยมและรายได้ให้เยอะที่สุด โดยต้องการข้อมูล 2 กลุ่มตัวอย่าง

# %% [markdown]
# 2. Acquire training and testing data.
# จากปัญหาที่พบเราจึงนำผลลัพธ์ของข้อมูลประเภทหนังที่ติดอันดับ บริทั้งหมดในทุกๆ 10ปี มาใช้ในการทำงาน โดยการนำเข้า(import) ข้อมูล ดังนี้
#
# **หมวดหมู่ที่เขียนด้วยข้อความเพื่อใช้ในการนำข้อมูลเข้า (input)**
#
# 1. Movie_id : ไอดีหนังแต่ละเรื่อง
# 2.  Title : ชื่อของหนัง
# 3.  Cast : ข้อมูลนักแสดง
# 5.  Crew : จำนวนผู้ชม
# 6.  Keywords : ข้อมูลรวมทั้งหมดของข้อมูล
# 8.  Genres : บอกประเภทของหนัง
# 9.  Homepage : ข้อมูลเว็ปไซต์ของหนัง
# 10. Original_language : ความจุของเพลง
# 11. Original_title : ความสั้น-ยาวของดนตรี (มีหน่วยเป็น ”วินาที (s)”)
# 12. Overview : อารมณ์ของเพลง
# 13. Production_companies : จับเฉพาะเสียงคนพูด หรือ Rap
# 14. Production_countries : ความนิยมของหนังเมื่อเทียบกับจำนวนประชากร
# 15. Spoken_languages: บทวิจารภาพยนต์
# 16. Status: สถานะหนังแต่ละเรื่อง
# 17. Tagline: สโลแกนหนัง
#
# **หมวดหมู่ที่เขียนด้วยตัวเลขเพื่อใช้ในการนำข้อมูลเข้า (input)**
#
# 1. budget: งบประมาณ
# 2. popularity: ค่าความนิยมของหนัง
# 3. release_date: ปีที่ติดอันดับ (หน่วยเป็น “ปี”)
# 4. revenue: รายได้ของหนัง
# 5. runtime: ความยาวของหนัง
# 6. vote_average:การนับค่าเฉลี่ย
# 7. vote_count:ผลการนับโหวด

# %% [markdown]
# การแสดงข้อมูลทั้งหมด 4803 ข้อมูลของหนังทั้งหมดในข้อมูลทำการแสดงข้อมูลโดยประกอบด้วย งบประมาณ ,ประเภท,เว็บที่อยู่,รหัส,ข้อความที่สำคัญ,ภาษา,ชื่อเรื่อง,ภาพรวม,คะแนนความนิยม,ชื่อบริษัท,ชื่อประเทศ,วัน/เดือน/ปี,รายได้,เวลา,ซับหนัง,สถานะของหนังว่าฉายหรือยัง,ลักษณะ,ชื่อเรื่อง,คะแนนเฉลี่ยของ Movie

# %%
df_movie

# %% [markdown]
# # 3. Wrangle, prepare, cleanse the data.
#
# ขั้นตอนนี้เราจะเช็คข้อมูลว่ามีข้อมูลอะไรเสียหายไหมและนำข้อมูลที่ไม่ได้ใช้ออกไปเพื่อให้ชุดข้อมูลนี้ถูกต้องที่สุด

# %%
df_movie.columns

# %% [markdown]
# นี้เป็นการโชว์กราฟที่จะแสดงข้อมูลเพื่อเช็คขอมูลก่อนที่จะเคลียข้อมูลเพื่อให้ถูกต้องที่สุด

# %%
df_movie.head()

# %%
#จากนั้นเราจะใช้คำสั้ง isnull เพื่อเช็คการเคลียร์ของขอมูลว่ามีข้อมูลใดบ้างที่ต้องทำการเคลียร์
df_movie.isnull().any()

# %%
#ทำการเช็คข้อมูลว่าถ้าเกิดว่ามีค่า null ขึ้นมาจะทำการเปลี่ยนให้เป็น False
df_movie = df_movie.fillna(value=0, axis=1)

# %%
#ทำการเช็คข้อมูลอีกที่ว่าทำการเคลียร์ของมูลครบถ้วนรึยัง
#ถ้าเกิดชุดข้อมูลขึ้นFalse แปลว่าถูกเคลียร์แล้ว
df_movie.isnull().any()

# %%
#คำสั่งเรียกข้อมูลประเภทหนังทั้งหมดเพราะเราต้องการดูประเภทของหนังทั้งหมด
df_movie.genres

# %%
# เนื่องจากมีการกำหนดประเภทในรูปแบบต่างๆมากเราจึงต้องแยกค่าแรกจากแต่ละประเภทโดยการแยกแยกประเภทของหนังออกมาเป็นรูปแบบ(Str)
df_movie.genres = df_movie.genres.str.split(",",n=2,expand=True)[1]
df_movie.genres

# %%
#ตรวจสอบการจำนวนข้อมูลการผิดพลาด หลังจากแยก
df_movie.genres.isnull().sum()

# %%
#1.ทำการทิ้ง (Drop) ข้อมูลที่ไม่เกี่ยวข้องออก Columns
df_movie.genres.dropna(inplace=True)

# %%
# ยืนยันว่าค่า Null ทั้งหมดถูกเติมด้วย 0
df_movie.genres.isnull().sum()

# %%
df_movie['genres'] = df_movie['genres'].apply(lambda x: x.split('"name"')[1])

# %% [markdown]
# Ep2

# %% [markdown]
# #  เราจะมาหาชุดข้อมูลต่อไปนั้นก็คือนักแสดงคนใดที่ได้รับความนิยมสูงสุดในแต่ละปี

# %%
df_credit

# %%
# ทำความสะอาดชุดข้อมูลก่อนโดยเฉพาะคอลัมน์นักแสดงแยกข้อมูลนักแสดงมาในรูปแบบ (Str) 
df_credit['cast'] = df_credit['cast'].str.split(":",n=6,expand=True)[6]
df_credit['cast'] = df_credit['cast'].str.split(",",n=0,expand=True)[0]
df_credit['cast']

# %% [markdown]
# # 4. Analyze, identify patterns, and explore the data.

# %%
#เมื่อเราทำการเคลียร์ข้อมูลเสร็จขั้นตอนนี้เราจะหาว่าจากปัญหาที่เราได้ทำการเขียนไว้เราต้องการชุดข้อมูลอะไรบ้างและชุดข้อมูลที่ใช้ก็จะมีอะไรบ้าง
# 1.   ชุดข้อมูลที่สรุปประเภทหนังว่า3อันดับแรกหนังประเภทไหนมาแรง
# 2.   นักแสดงที่ได้รับความนิยมมากสุด

# %% [markdown]
# # ทำการดึงชุดข้อมูลของประเภทหนัง

# %%
# ลบอักขระพิเศษ ทั้งหมดออกจากข้อมูลประเภทหนัง
df_movie['genres'] =  df_movie['genres'].str.replace('"', '')
df_movie['genres'] =  df_movie['genres'].str.replace(':', '')
df_movie['genres'] =  df_movie['genres'].str.replace(']', '')
df_movie['genres'] =  df_movie['genres'].str.replace('}', '')

# %%
#ลบ white space ออกประเภทหนัง
df_movie['genres'] = df_movie['genres'].str.strip()

# %%
# ยืนยันค่าทั้งหมดว่าเหมาะสมในการใช้ข้อมูลแล้ว
df_movie['genres']

# %%
# แยกปีจากวันที่เผยแพร่
df_movie['release_date'] = pd.to_datetime(df_movie['release_date'])
df_movie['year'] = df_movie['release_date'].dt.year
df_movie.year = df_movie.year.fillna(0).astype(int)

# %%
# ยืนยันว่าคอลัมน์ ปี มีค่าที่เหมาะสม
df_movie.year

# %%
#เราใช้คำสั่งนี้เพื่อหาแค่อันดับของประเภทหนังที่ดีที่สุดมา3อันดับ
# 1.Action  2.Adventure 3.Drama
df_movie.groupby('genres').revenue.sum().nlargest(3)

# %% [markdown]
# # เมื่อเราหาประเภทหนังที่ดีที่สุดได้แล้วต่อไปเราไปหานักแสดงกันต่อว่าใครเป็นที่นิยมมากที่สุด

# %%
# ทำการเปลียนข้อมูลเคดิดตัวเลขเป็นข้อมูลตัอักษร
df_credit['cast'] =  df_credit['cast'].str.replace('"', '')
df_credit['cast'] = df_credit['cast'].str.strip()

# %%
# รวมรายชื่อนักแสดงกับidหนังเพื่อดูว่าใครแสดงหนังเรื่องอะไร
df_combined = df_credit.merge(df_movie, left_on='movie_id', right_on='id', how='inner')

# %%
# ทำการรวมผลข้อมูลนักแสดงปีและผลคะแนนเข้าด้วยกัน
df_cast = df_combined[['cast','year','revenue']]

# %%
# โชว์ตารางผลคะแนนของนักแสดงทั้งหมด
df_combined

# %% [markdown]
# # 5. Model, predict and solve the problem.
# จากการวิเคราะห์ข้อมูลเรียบร้อยแล้วเราจะได้ข้อมูล 2 กลุ่มและนำข้อมูลมา clustering เพิ่อให้ได้ชุดข้อมูลที่ต้องการ

# %% [markdown]
# นี้คือโมเดลของประเภทหนังTOP3 ทั้งหมดในที่เราทำการหามา

# %%
# ทำการเรียกดูอันดับของหนังแอคชันในทุกๆ 10 ปี ว่าติดอันดับใดบ้างในแต่ละปี
df_action = df_movie.query('genres == "Action"').groupby('year').revenue.sum()
df_action = df_action.rolling(window=10).mean()
df_action

# %%
#  ทำการเรียกดูอันดับของหนังผจญภัยชันในทุกๆ 10 ปี ว่าติดอันดับใดบ้างในแต่ละปี
df_adventure = df_movie.query('genres == "Adventure"').groupby('year').revenue.sum()
df_adventure = df_adventure.rolling(window=10).mean()
df_adventure

# %%
 #ทำการเรียกดูอันดับของหนังเศร้าในทุกๆ 10 ปี ว่าติดอันดับใดบ้างในแต่ละปี
df_drama = df_movie.query('genres == "Drama"').groupby('year').revenue.sum()
df_drama = df_drama.rolling(window=10).mean()
df_drama

# %% [markdown]
# # ต่อมาคือรายชื่อนักแสดงที่เป็นที่นิยม

# %%
#ทำการรวมข้อมูลของหนังแสดง กับ ปีของข้อมูลเพื่อดูว่าปีไหนนักแสดงคนไหนเป็นที่นิยม
df_cast = df_cast.ix[df_cast.groupby(['year']).revenue.idxmax()]

# %%
#เรียกดูรายชื่อนักแสดง ที่ทำการคลีนข้อมูลแล้ว
df_cast

# %%
# เรียกข้อมูลของนักแสดงทีได้รับความนิยมมากที่สุด10 อันดับแรก โดยการร่วมค่านักแสดงกับ ปี
df_cast = df_cast.groupby('cast').year.count()
df_cast  = df_cast [df_cast >1]
df_cast

# %% [markdown]
# # 6 Visualize, report, and present the problem solving steps and final solution.
# จากที่ทำการวิเคราะห์ข้อมูลเสร็จเรียบร้อยแล้ว จึงทำการสรุปผลข้อมูลออกมา เพื่อแบ่งคนออกเป็น 2 กลุ่ม และแสดงออกมาเป็นกราฟเพื่อบงบอกข้อมูลที่เราหามาได้เพื่อให้ผู้สร้างภาพยนตร์ หรือ ผู้กำกับภาพยนตร์ว่าจะสร้างหนังอะไร แนวไหน เพื่อที่จะให้ตอบโจทย์ความต้องการของผู้คนที่ชอบดูภาพยนตร์ เพื่อให้สามารถสร้างรายได้มหาศาล ถ้าเรารู้ว่าผู้คนชอบดูหนังแนวไหนและนักแสดงคนใดโดยข้อมูลจะมีกราฟบอกอย่างชัดเจน

# %%
# โชว์กราฟโชว์ค่าเฉลี่ยของประเภทหนัง Top3 ในทุกๆ ปี ก็จะมี Action , Adventure , Drama
df_action.dropna(inplace=True)
plt.subplots(figsize=(10, 6))
plt.bar(df_adventure .index, df_adventure )
plt.title('10 Years moving average for category - Action')
plt.xlabel('Year')
plt.ylabel('Moving average');
df_adventure .dropna(inplace=True)
plt.subplots(figsize=(10, 6))
plt.bar(df_adventure .index, df_adventure )
plt.title('10 Years moving average for category Adventure')
plt.xlabel('Year')
plt.ylabel('Moving average');
df_drama.dropna(inplace=True)
plt.subplots(figsize=(10, 6))
plt.bar(df_drama.index, df_drama)
plt.title('10 Years moving average for category Drama')
plt.xlabel('Year')
plt.ylabel('Moving average');
plt.style.use('ggplot');

# %%
# โชว์กราฟค่าความนิยมของนักแสดงที่นิยมมากสุด10อันดับ
df_cast.plot(kind='bar', stacked=True, colormap='PiYG')

# %% [markdown]
# # 7. Supply or submit the results.

# %% [markdown]
# **สรุปการทำชุดข้อมูลคือเราได้รู้ประเภทของหนังในทุกๆปีว่าคนส่วนใหญ่สนใจแนวหนังประเภทอะไรโดยผลสรุปออกมาคือคนส่วนใหญ่นั้นชอบ แนว ผจญภัยมาเป็นอับ1ส่วนแอคชันมาเป็นอันดับ2 และ ดราม่ามาเป็นอันดับ 3 ส่วนหนักแสดงที่นิยมมากก็คือ Sean Connery เมื่อทางผู้กำกับและค่ายภาพยนตร์เห็นชุดข้อมูลนี้ก็จะสามารถนำการวิเคราะห์จากดาต้าไปประกอบการสร้างภาพยนตร์ให้เป็นที่นิยมและมีรายได้มากยิ่งจากการสำราจชุดข้อมูลเพื่อตัดสินใจเลือกนักแสดงและแนวหนังก่อนที่จะสร้างภาพยนตร์**
