# %% [markdown]
# # <p style="background-color:skyblue; font-family:newtimeroman; font-size:180%; text-align:center"> Pokemon Go Unown Letters: Starter Kit 📊 </p>

# %% [markdown]
# ## <p style="background-color:skyblue; font-family:newtimeroman; font-size:120%; text-align:center">Table of Content</p>
#
# * [1. Import Libs](#1)
# * [2. Open Description](#2)
# * [3. What is the Pokemon name?](#3)
# * [4. What is the img name?](#4)
# * [5. HI Example](#5)
# * [6. Decode the letter!](#6)
# * [7. Thanks!](#7)

# %% [markdown]
# <a id='1'></a>
# # <p style="background-color:skyblue; font-family:newtimeroman; font-size:150%; text-align:center">1. Import Libs </p>

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 
from PIL import Image

import numpy as np
import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# <a id='2'></a>
# # <p style="background-color:skyblue; font-family:newtimeroman; font-size:150%; text-align:center">2. Open Description</p>

# %%
INPUT_PATH = '/kaggle/input/pokemon-go-unown-letters/'

# %%
df = pd.read_csv(INPUT_PATH + 'description.csv')

# %%
df.head()

# %% [markdown]
# <a id='3'></a>
# # <p style="background-color:skyblue; font-family:newtimeroman; font-size:150%; text-align:center">3. What is the Pokemon name?</p>

# %% [markdown]
# ## What is the name of the Pokemon Unown Letter A?

# %%
print(df[df['letter'] == 'A']['pokemon_name'].values[0])

# %% [markdown]
# <a id='4'></a>
# # <p style="background-color:skyblue; font-family:newtimeroman; font-size:150%; text-align:center">4. What is the img name?</p>

# %% [markdown]
# ## What is img name of the Pokemon Unown Letter A?

# %%
print(df[df['letter'] == 'A']['img_name'].values[0])

# %% [markdown]
# <a id='5'></a>
# # <p style="background-color:skyblue; font-family:newtimeroman; font-size:150%; text-align:center">5. HI Example</p>

# %% [markdown]
# ## Could you say 'hi' for the Kaggle Community?

# %%
df[(df['letter'] == 'H') |  (df['letter'] == 'I')]

# %%
img_h = Image.open(INPUT_PATH + "H.png")
img_i = Image.open(INPUT_PATH + "I.png")

img_h = img_h.resize((50,50), Image.ANTIALIAS)
img_i = img_i.resize((50,50), Image.ANTIALIAS)

# %%
plt.figure(figsize=(3,3))
plt.subplot(1,2,1) 
plt.imshow(img_h)
plt.axis('off')
plt.subplot(1,2,2)
plt.imshow(img_i)
plt.axis('off')
plt.show()

# %% [markdown]
# <a id='6'></a>
# # <p style="background-color:skyblue; font-family:newtimeroman; font-size:150%; text-align:center">6. Decode the letter!</p>

# %% [markdown]
# # You received a letter: "Keep Angry Give Give Laugh Engage!", Could you decode it and show for us?

# %%
letter = "Keep Angry Give Give Laugh Engage!"

# %%
exc = letter[-1]

# %%
letter = letter[0:-1]

# %%
letter

# %%
exc

# %%
words = letter.split(' ')

# %%
decode = ''
for word in words:
    decode+=(df[df['pokemon_name'] == word]['letter'].values[0])
decode+=exc

# %%
decode

# %% [markdown]
# ## Let's visualize the decoded letter

# %%
decode_imgs_path = []
for word in words:
    decode_imgs_path.append(df[df['pokemon_name'] == word]['img_name'].values[0])
decode_imgs_path.append(df[df['letter'] == exc]['img_name'].values[0])

# %%
decode_imgs_path

# %%
imgs = [Image.open(INPUT_PATH + img).resize((100,100), Image.ANTIALIAS)
        for img in decode_imgs_path]

# %%
n_imgs = len(imgs)

# %%
print(n_imgs)

# %%
plt.figure(figsize=(10,10))

for i in range(0, n_imgs):

    plt.subplot(1, n_imgs, i+1) 
    plt.imshow(imgs[i])
    plt.axis('off')
    
plt.show()

# %% [markdown]
# <a id='7'></a>
# # <p style="background-color:skyblue; font-family:newtimeroman; font-size:150%; text-align:center">7. Thanks!</p>

# %%
letter = "Thanks!"
letter = letter.upper()
word = letter[0:-1]
exc = letter[-1]

decode_imgs_path = []
for each_letter in word:
    print(each_letter)
    decode_imgs_path.append(df[df['letter'] == each_letter]['img_name'].values[0])
decode_imgs_path.append(df[df['letter'] == exc]['img_name'].values[0])

imgs = [Image.open(INPUT_PATH + img).resize((100,100), Image.ANTIALIAS)
        for img in decode_imgs_path]

plt.figure(figsize=(10,10))

for i in range(0, n_imgs):

    plt.subplot(1, n_imgs, i+1) 
    plt.imshow(imgs[i])
    plt.axis('off')
    
plt.show()
