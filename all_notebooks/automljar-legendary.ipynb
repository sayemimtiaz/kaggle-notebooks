# %% [markdown]
# #Codes by Piotr https://www.kaggle.com/mt77pp/mljar-autoeda-automl-prediction

# %% [markdown]
# ![](https://media4.giphy.com/media/BMfB5NqJ9JDvs6PJcp/200w.webp?cid=ecf05e47jr4zfc1yaui6q8rxjtlqo8ve27v7rxlxsb5zrep1&rid=200w.webp)

# %% [markdown]
# <a id="1.1"></a>
# <h3 style="background-color:skyblue;font-family:newtimeroman;font-size:200%;text-align:center">MLJAR AutoML</h3>
#
#
# MLJAR AutoML can work in three different modes:
#
# <font color="#EC7063">Explain for data explorations</font>
#
# The Explain mode is suitable for data exploration. The Automatic EDA report is created. The extensive explanations for models are computed.
#
# <font color="#EC7063">Perform for production-ready ML models</font>
#
#
# <font color="#EC7063">Compete for top performance ML models </font>
#
# The Compete mode is perfect for data competitions. Many algorithms are tuned, stacked and ensembled. Golden Features and Features Selection are performed.
#
# Visit MLJAR AutoML  in GitHub and give them a star
#
# https://github.com/mljar/mljar-supervised

# %%
# !pip install -U git+https://github.com/mljar/mljar-supervised.git@dev

# %%
# !pip install -q -U matplotlib==3.1.3

# %%
from supervised.automl import AutoML # mljar-supervised

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# #Features are `x_cols`

# %%
# load data
train_data = pd.read_csv('../input/pokemon-datasets-for-ml/train_pokemon.csv')
test_data  = pd.read_csv('../input/pokemon-datasets-for-ml/train_pokemon.csv')
x_cols = ['Number', 'Name', 'Total', 'HP', 'Sp_Atk', 'Sp_Def', 'Speed', 'Generation','Color', 'hasGender', 'Egg_Group_1', 'hasMegaEvolution','Height_m', 'Weight_kg', 'Body_Style', 'shuffle']

# %% [markdown]
# #Explain Mode: for data exploration.The Automatic EDA report is created. Extensive explanations for models are computed.

# %%
automl = AutoML(mode="Explain")
automl.fit(train_data[x_cols], train_data["isLegendary"])

# %%
# check AutoML models
# you can click on links!
automl.report()

# %% [markdown]
# #COMPETE MODE - Golden Features and Features Selection are performed. Many algorithms are tuned, stacked and ensembled.

# %%
automl = AutoML(mode="Compete", total_time_limit=4*3600)
automl.fit(train_data[x_cols], train_data["isLegendary"])

# %%
# check AutoML models
# you can click on links!
automl.report()

# %%
#Code by Olga Belitskaya https://www.kaggle.com/olgabelitskaya/sequential-data/comments
from IPython.display import display,HTML
c1,c2,f1,f2,fs1,fs2=\
'#eb3434','#eb3446','Akronim','Smokum',30,15
def dhtml(string,fontcolor=c1,font=f1,fontsize=fs1):
    display(HTML("""<style>
    @import 'https://fonts.googleapis.com/css?family="""\
    +font+"""&effect=3d-float';</style>
    <h1 class='font-effect-3d-float' style='font-family:"""+\
    font+"""; color:"""+fontcolor+"""; font-size:"""+\
    str(fontsize)+"""px;'>%s</h1>"""%string))
    
    
dhtml('Be patient. Marília Prata, @mpwolke was here' )
