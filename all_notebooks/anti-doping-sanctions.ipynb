# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from matplotlib import dates

import matplotlib

# %matplotlib inline

matplotlib.style.use("Solarize_Light2")

from pylab import rcParams
import statsmodels.api as sm

import warnings
warnings.simplefilter(action='ignore', category=Warning)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# <center style="font-family:verdana;"><h1 style="font-size:200%; padding: 10px; background: #001f3f;"><b style="color:#DC143C;">Anti-doping Policies</b></h1></center>
#
# "Athletes received sanctions for a doping violation under the World Anti-Doping Code, the athlete’s International Federation rules, and/or the United States Olympic & Paralympic Anti-Doping Policies, as well as the UFC Anti-Doping Program. The release date listed corresponds to the date the sanction was publicly announced."
#
# https://www.usada.org/news/sanctions/

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRWGzjt52Q84ZMbR8F8pJ5k1hYGEqcyS66o0A&usqp=CAU)facebook.com

# %%
import holoviews as hv
from holoviews import opts
hv.extension('bokeh')

# %%
df = pd.read_csv("/kaggle/input/cusersmarildownloadssanctioncsv/sanction.csv", delimiter=';', encoding='ISO-8859-2')
df.head()

# %%
df.isnull().sum()

# %%
df["sport"].value_counts()

# %%
#Code by Kohei-mu https://www.kaggle.com/koheimuramatsu/industrial-accident-causal-analysis/notebook

#Fixed by Des desalegngeb https://www.kaggle.com/desalegngeb
#https://www.kaggle.com/desalegngeb/bokeh-visualization-library-guide-for-beginners

sport_cnt = np.round((df['sport'].value_counts(normalize=True) *100).head()) 
hv.Bars(sport_cnt).opts(title="Doping Violation by Sport", color="red", xlabel="Sport", ylabel="Percentage", yformatter='%d%%')\
                .opts(opts.Bars(width=500, height=300,tools=['hover'],show_grid=True)).opts(xrotation=45)

# %% [markdown]
# #To avoid clumsy plotting, select a few columns

# %%
ax = sns.countplot(x = 'sport',data=df,order=['Track and Field','Cycling', 'Mixed Martial Arts','Weightlifting', 'Swimming'])
for p in ax.patches:
        ax.annotate(format(p.get_height()), (p.get_x()+0.2, p.get_height()))
plt.xticks(rotation=45)
plt.title('Doping Violations by Sport');

# %%
#Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

color = plt.cm.Reds(np.linspace(0,1,20))
df["sport"].value_counts().sort_values(ascending=False).head(10).plot.pie(y="sanction_announced",colors=color,autopct="%0.1f%%")
plt.title("Doping Violation by Sports")
plt.axis("off")
plt.show()

# %%
#word cloud
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in df.sport)
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200,colormap='Set2', background_color="Red").generate(text)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='Bilinear')
plt.axis("off")
plt.figure(1,figsize=(12, 12))
plt.show()

# %%
df["substance_reason"].value_counts()

# %%
#Code by Kohei-mu https://www.kaggle.com/koheimuramatsu/industrial-accident-causal-analysis/notebook

#Fixed by Des desalegngeb https://www.kaggle.com/desalegngeb
#https://www.kaggle.com/desalegngeb/bokeh-visualization-library-guide-for-beginners

substance_cnt = np.round((df['substance_reason'].value_counts(normalize=True) *100).head()) 
hv.Bars(substance_cnt).opts(title="Doping Violation by Substance", color="yellow", xlabel="Substance of the Doping", ylabel="Percentage", yformatter='%d%%')\
                .opts(opts.Bars(width=500, height=300,tools=['hover'],show_grid=True)).opts(xrotation=45)

# %%
#Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

color = plt.cm.summer(np.linspace(0,1,20))
df["substance_reason"].value_counts().sort_values(ascending=False).head(10).plot.pie(y="sanction_announced",colors=color,autopct="%0.1f%%")
plt.title("Doping Violation by Substances")
plt.axis("off")
plt.show()

# %%
#word cloud
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in df.substance_reason)
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200,colormap='Set2', background_color="yellow").generate(text)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='Bilinear')
plt.axis("off")
plt.figure(1,figsize=(12, 12))
plt.show()

# %%
ax = sns.countplot(x = 'substance_reason',data=df,order=['Cannabinoids','Androgenic Anabolic Steroid', 'Non-Analytical: Refusal to Submit to Sample Collection','Ostarine', 'Non-Analytical: 3 Whereabouts Failures'])
for p in ax.patches:
        ax.annotate(format(p.get_height()), (p.get_x()+0.2, p.get_height()))
plt.xticks(rotation=45)
plt.title('Doping Violations by Substances');

# %%
df["sanction_terms"].value_counts()

# %%
#Code by Kohei-mu https://www.kaggle.com/koheimuramatsu/industrial-accident-causal-analysis/notebook

#Fixed by Des https://www.kaggle.com/desalegngeb/bokeh-visualization-library-guide-for-beginners

term_cnt = np.round((df['sanction_terms'].value_counts(normalize=True) *100).head())
hv.Bars(term_cnt[::-1]).opts(title="Doping Violation Sanction Terms", color="cyan", xlabel="Sanction Terms", ylabel="Percentage", xformatter='%d%%')\
                .opts(opts.Bars(width=600, height=600,tools=['hover'],show_grid=True,invert_axes=True))

# %%
#Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

color = plt.cm.Blues(np.linspace(0,1,20))
df["sanction_terms"].value_counts().sort_values(ascending=False).head(10).plot.pie(y="sanction_announced",colors=color,autopct="%0.1f%%")
plt.title("Doping Violations Sanctions Terms")
plt.axis("off")
plt.show()

# %%
ax = sns.countplot(x = 'sanction_terms',data=df,order=['2-Year Suspension - Loss of Results','4-Year Suspension - Loss of Results', '1-Year Suspension - Loss of Results','Public Warning - Loss of Results', '4-Year Suspension; Loss of Results'])
for p in ax.patches:
        ax.annotate(format(p.get_height()), (p.get_x()+0.2, p.get_height()))
plt.xticks(rotation=45)
plt.title('Doping Violations by Sanction Terms');

# %% [markdown]
# #Above, I don't know what is the difference between 4-Year Suspension - Loss of Results and 4-Year Suspension; Loss of Results.
#
# On the first one (suspension and loss) are separated by a dash (50 entries). On the 2nd they are separated by a semi-colon (39 entries).

# %%
df["sanction_announced"].value_counts()

# %%
#Code by Kohei-mu https://www.kaggle.com/koheimuramatsu/industrial-accident-causal-analysis/notebook

#Fixed by Des https://www.kaggle.com/desalegngeb/bokeh-visualization-library-guide-for-beginners

announc_cnt = np.round((df['sanction_announced'].value_counts(normalize=True) *100).head())
hv.Bars(announc_cnt[::-1]).opts(title="Sanction Announcements", color="purple", xlabel="Sanctions announcements", ylabel="Percentage", xformatter='%d%%')\
                .opts(opts.Bars(width=600, height=600,tools=['hover'],show_grid=True,invert_axes=True))

# %%
#Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

color = plt.cm.Purples(np.linspace(0,1,20))
df["sanction_announced"].value_counts().sort_values(ascending=False).head(10).plot.pie(y="sanction_announced",colors=color,autopct="%0.1f%%")
plt.title("Doping Violation by Sanction Announcements")
plt.axis("off")
plt.show()

# %%
#word cloud
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in df.sanction_terms)
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200,colormap='Set2', background_color="blue").generate(text)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='Bilinear')
plt.axis("off")
plt.figure(1,figsize=(12, 12))
plt.show()

# %% [markdown]
# "All athletes need to be proactive in asking questions so they don’t jeopardize their sporting careers. If you have a question - ASK! If you cannot be 100% sure of the ingredients or don’t know the status of a substance – DON’T TAKE IT!"
#
# "There is no limit to the number of times an athlete can be tested each year including in-competition, out of competition, random and target testing."
#
# "Refusing to submit to doping control can carry the same sanction as a positive test. If an athlete refuses to take a test when notified, he/she must provide an explanation for the refusal on the relevant form and inform his/her governing body as soon as possible."
#
# "Hard-work, dedication, and learning from set-backs are essential to become the best athlete of a sport. However, winning at all costs with no respect for health, fellowcompetitors, or the rules goes against the spirit of sport."
#
# "When an athlete cheats, they take themselves out of the game, stop competing in the spirit of sport, and there is no longer a fair contest. Also, violating anti-doping rules is the same as violating competition rules, which all athletes accept as a condition to participate and compete fairly."
#
# "Remember a positive test is a positive test."
#
# https://www.wada-ama.org/sites/default/files/resources/files/pt_quiz_english_0.pdf
