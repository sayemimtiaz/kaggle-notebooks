# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import cv2
import matplotlib.pyplot as plt
img=cv2.imread('../input/natural-images/natural_images/flower/flower_0004.jpg')
plt.imshow(img)
plt.show()

# %%
img[100,100]

# %%
img[100,100,0]

# %%
img[120:200,120:240]=[255,200,190]
plt.imshow(img)

# %%
img.item(10,100,1),img[10,100]

# %%
img.shape

# %%
img.size

# %%
img.dtype

# %%
img=cv2.imread('../input/natural-images/natural_images/flower/flower_0004.jpg')
plt.imshow(img)
plt.show()

# %%
imgcrop=img[100:300,20:350]
plt.imshow(imgcrop)

# %%
b,g,r=cv2.split(img)
b

# %%
border=cv2.copyMakeBorder(img,10,200,10,200,cv2.BORDER_REPLICATE)
plt.imshow(border)

# %%
border=cv2.copyMakeBorder(img,10,200,10,200,cv2.BORDER_CONSTANT)
plt.imshow(border)

# %%
border=cv2.copyMakeBorder(img,10,200,10,200,cv2.BORDER_REFLECT)
plt.imshow(border)

# %%
border=cv2.copyMakeBorder(img,10,200,10,200,cv2.BORDER_REFLECT_101)
plt.imshow(border)

# %%
border=cv2.copyMakeBorder(img,10,200,10,200,cv2.BORDER_WRAP)
plt.imshow(border)

# %%
addimg=cv2.add(img,100)
plt.imshow(addimg)

# %%
img2=cv2.imread('../input/natural-images/natural_images/flower/flower_0010.jpg')
plt.imshow(img2)
plt.show()

# %%
dst=cv2.addWeighted(img,0.1,img,0.3,0)
plt.imshow(dst)

# %%
plt.imshow(img)

# %%
kernel=np.ones((10,10))
erosion=cv2.erode(img,kernel,iterations=1)
plt.imshow(erosion)

# %%
kernel=np.ones((5,5))
dilate=cv2.dilate(img,kernel,iterations=1)
plt.imshow(dilate)

# %%
b=cv2.morphologyEx(img,cv2.MORPH_OPEN,kernel)
plt.imshow(b)

# %%
b=cv2.morphologyEx(img,cv2.MORPH_CLOSE,kernel)
plt.imshow(b)

# %%
b=cv2.morphologyEx(img,cv2.MORPH_GRADIENT,kernel)
plt.imshow(b)

# %%
b=cv2.morphologyEx(img,cv2.MORPH_TOPHAT,kernel)
plt.imshow(b)

# %%
b=cv2.morphologyEx(img,cv2.MORPH_BLACKHAT,kernel)
plt.imshow(b)

# %%
b=cv2.getStructuringElement(cv2.MORPH_RECT,(2,2))
plt.imshow(b)

# %%
b=cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(2,2))
plt.imshow(b)

# %%
b=cv2.getStructuringElement(cv2.MORPH_CROSS,(2,2))
plt.imshow(b)

# %%
e1=cv2.getTickCount()
e2=cv2.getTickCount()
e1,e2

# %%
cv2.getTickFrequency()

# %%
cv2.setUseOptimized(True)

# %%
plt.imshow(img2)

# %%
res=cv2.resize(img2,(100,100),interpolation=cv2.INTER_CUBIC)
plt.imshow(res)

# %%
res=cv2.resize(img2,(100,100),interpolation=cv2.INTER_AREA)
plt.imshow(res)

# %%
res=cv2.resize(img2,(100,100),interpolation=cv2.INTER_LINEAR)
plt.imshow(res)

# %%
h,w = img.shape[:2]
qh,qw=h/4,w/4
M = np.float32([[1,0,qh],[0,1,qw]])
dst = cv2.warpAffine(img,M,(h,w))
plt.imshow(dst)

# %%
M = cv2.getRotationMatrix2D((qw,qh),90,1)
dst = cv2.warpAffine(img,M,(h,w))
plt.imshow(dst)

# %%
points_A = np.float32([[320,15], [700,215], [85,610]])
points_B = np.float32([[0,0], [420,0], [0,594]])   
M = cv2.getAffineTransform(points_A, points_B)
warped = cv2.warpAffine(img, M, (420,594))
plt.imshow(warped)

# %%
points_A = np.float32([[320,15], [700,215], [85,610], [530,780]])
points_B = np.float32([[0,0], [420,0], [0,594], [420,594]])   
M = cv2.getPerspectiveTransform(points_A, points_B)
warped = cv2.warpPerspective(img, M, (420,594))
plt.imshow(warped)

# %%
edges=cv2.Canny(img,100,200)
plt.imshow(edges)

# %%
l_r=cv2.pyrDown(img2)
plt.imshow(l_r)

# %%
h_r=cv2.pyrUp(img2)
plt.imshow(h_r)

# %%
C=cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
plt.imshow(C)

# %%
C=cv2.cvtColor(img2,cv2.COLOR_BGR2HSV)
plt.imshow(C)

# %%
r,sh=cv2.threshold(img2,127,255,cv2.THRESH_BINARY)
plt.imshow(sh)

# %%
r,sh=cv2.threshold(img2,127,255,cv2.THRESH_BINARY_INV)
plt.imshow(sh)

# %%
r,sh=cv2.threshold(img2,127,255,cv2.THRESH_TRUNC)
plt.imshow(sh)

# %%
r,sh=cv2.threshold(img2,127,255,cv2.THRESH_TOZERO)
plt.imshow(sh)

# %%
r,sh=cv2.threshold(img2,127,255,cv2.THRESH_TOZERO_INV)
plt.imshow(sh)

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,8)
plt.imshow(th2)

# %%
th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,8)
plt.imshow(th3)

# %%
img=cv2.imread('../input/natural-images/natural_images/flower/flower_0004.jpg')
plt.imshow(img)

# %%
kernel = np.array([[-1,-1,-1], 
                              [-1,9,-1], 
                              [-1,-1,-1]])
dst=cv2.filter2D(img,-1,kernel)
plt.imshow(dst)

# %%
blur=cv2.blur(img,(5,5))
plt.imshow(blur)

# %%
blur=cv2.GaussianBlur(img,(5,5),0)
plt.imshow(blur)

# %%
blur=cv2.medianBlur(img,5)
plt.imshow(blur)

# %%
blur=cv2.bilateralFilter(img,9,75,75)
plt.imshow(blur)

# %%
sobel=cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
plt.imshow(sobel)

# %%
lap=cv2.Laplacian(img,cv2.CV_64F)
plt.imshow(lap)
