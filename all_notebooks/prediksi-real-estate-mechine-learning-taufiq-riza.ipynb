# %% [markdown]
# **Nama : Muhamad Taufiq Riza
# NIM  : 402019611021**

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
filecsv = "/kaggle/input/harga-real-estate/harga_real_estate.csv"
df = pd.read_csv(filecsv, usecols=['X1_Usia_Rumah','X2_jarak_MRT','X3_jumlah_toko','Y_harga_unit'])

# %%
df.head()

# %%
df.shape

# %%
df.info

# %%
df.describe()

# %%
df.isnull().sum()

# %%
f = plt.figure(figsize=(12,4))

f.add_subplot(1,2,1)
sns.countplot(df['X3_jumlah_toko'])

f.add_subplot(1,2,2)
plt.boxplot(df['X3_jumlah_toko'])
plt.show()

# %%
f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
df['X1_Usia_Rumah'].plot(kind='kde')

f.add_subplot(1,2,2)
plt.boxplot(df['X1_Usia_Rumah'])
plt.show()

# %%
f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
df['Y_harga_unit'].plot(kind='kde')

f.add_subplot(1,2,2)
plt.boxplot(df['Y_harga_unit'])
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.pairplot(data=df, x_vars=['X1_Usia_Rumah','X2_jarak_MRT','X3_jumlah_toko'], y_vars=['Y_harga_unit'], size=5, aspect=0.75)
plt.show()

# %%
sns.violinplot(data=df, x='Y_harga_unit')

# %%
df.corr().style.background_gradient().set_precision(2)

# %%
df.head()

# %%
df = pd.read_csv(filecsv, usecols=['X1_Usia_Rumah','X2_jarak_MRT','X3_jumlah_toko','Y_harga_unit'])
x = df.drop(columns='Y_harga_unit')
y = df['Y_harga_unit']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=1)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(x_train.shape)

# %%
lin_reg = LinearRegression()

# %%
lin_reg.fit(x_train, y_train)

# %%
print(lin_reg.coef_)
print(lin_reg.intercept_)

# %%
coef_dict = {
    'Fitur' : x.columns,
    'Nilai Korelasi' : lin_reg.coef_
}
coef = pd.DataFrame(coef_dict, columns=['Fitur', 'Nilai Korelasi'])
coef

# %%
y_pred = lin_reg.predict(x_test)

# %%
lin_reg.score(x_test, y_test)

# %% [markdown]
# Akurasi = 70%
