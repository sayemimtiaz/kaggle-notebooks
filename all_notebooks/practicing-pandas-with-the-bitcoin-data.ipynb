# %%
## practicing the Pandas package 
import pandas as pd
import numpy as np
import os

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
data=pd.read_csv('/kaggle/input/bitcoin/btc_data.csv')
data.head(5)

# %%
data.dtypes

# %%
data.isna().sum()

# %%
data.fillna(0, inplace=True) ## if there are any null values, we replace null values with 0

# %%
data["Date"][data["size"]>600]
## Dates where the size of bitcoins was more than 600

# %%
data["size"].max() ## maximum size

# %%
data["transactions"].mean() ## mean

# %%
data.shape

# %%
rows, columns=data.shape

# %%
rows

# %%
columns

# %%
data.tail()

# %%
data.head()

# %%
data[2:5] ## returns rows with the index 2 - 4

# %%
data.columns

# %%
data.priceUSD

# %%
data["priceUSD"]

# %%
type(data["Date"])

# %%
data[["transactions"]]

# %%
data[["transactions", "difficulty", "size"]]

# %%
data.describe()

# %%
data[data["size"]>600]

# %%
data[data["size"]==data["size"].max()]

# %%
data[["Date", "size"]][data["size"]==data["size"].max()]

# %%
data.index

# %%
data.set_index("Date", inplace=True)

# %%
data.loc["2010/07/17"]

# %%
data.reset_index(inplace=True)
data

# %%
data["Size"]=np.where(data["size"]>10000, "Large", "Small")

# %%
data

# %%
test_data=pd.read_csv('btc_data.csv', nrows=3, na_values=[0])
test_data

# %%
test_data.to_csv("test_dataset2.csv", columns=["Date", "transactions", "size"])
