# %% [markdown]
# India has one of the largest numbers of engineers in the world. In India, there are numerous engineering colleges imparting undergraduate and graduate courses in engineering, applied engineering and sciences. The Indian Institutes of Technology (IITs) and National Institutes of Technology (NITs) are autonomous public technical and research universities located in India.
#
# The Indian Institutes of Technology (IITs) has 23 centers located in Bhubaneswar, Bombay, Delhi, Gandhinagar, Guwahati, Hyderabad, Indore, Jodhpur, Kanpur, Kharagpur, Madras, Mandi, Patna, Roorkee, Ropar, Dhanbad, Palakkad, Tirupati, Bhilai, Goa, Jammu, Dharwad and Varanasi. All IITs enjoy the status of the Institutes of National Importance and are autonomous universities that draft their own curricula. Many IITs are members of LAOTSE, an international network of universities in Europe and Asia. LAOTSE membership allows the IITs to exchange students and senior scholars with universities in other countries.
# https://en.wikipedia.org/wiki/Engineering_education_in_India

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ4ncKyJd8gFHsrHl5s_nFgEsl6yARgO0dljA&usqp=CAU)apnaahangout.com

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import plotly.offline as py
import plotly.express as px

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('../input/engineering-colleges-in-india/engineering colleges in India.csv', encoding='utf8')
df.head()

# %%
df.isnull().sum()

# %%
#Code from Gabriel Preda
#plt.style.use('dark_background')
def plot_count(feature, title, df, size=1):
    f, ax = plt.subplots(1,1, figsize=(4*size,4))
    total = float(len(df))
    g = sns.countplot(df[feature], order = df[feature].value_counts().index[:20], palette='Oranges')
    g.set_title("Number and percentage of {}".format(title))
    if(size > 2):
        plt.xticks(rotation=90, size=8)
    for p in ax.patches:
        height = p.get_height()
        ax.text(p.get_x()+p.get_width()/2.,
                height + 3,
                '{:1.2f}%'.format(100*height/total),
                ha="center") 
    plt.show()

# %%
plot_count("Genders Accepted", "Genders Accepted", df,4)

# %%
plot_count("Total Student Enrollments", "Total Student Enrollments", df,4)

# %%
plot_count("Courses", "Courses", df,4)

# %%
plot_count("Facilities", "Facilities", df,4)

# %%
plot_count("College Type", "College Type", df,4)

# %%
plot_count("Average Fees", "Average Fees", df,4)

# %%
#Code by Olga Belitskaya https://www.kaggle.com/olgabelitskaya/parts-of-speech

plt.figure(figsize=(10,5))
sns.countplot(y="Genders Accepted",data=df,
             facecolor=(0,0,0,0),linewidth=5,
             edgecolor=sns.color_palette("Oranges"))
plt.title('Genders Accepted', color='green',
         fontsize=15);

# %%
#Code by Olga Belitskaya https://www.kaggle.com/olgabelitskaya/parts-of-speech

plt.figure(figsize=(10,5))
sns.countplot(y="College Type",data=df,
             facecolor=(0,0,0,0),linewidth=5,
             edgecolor=sns.color_palette("Greens"))
plt.title('College Type', color='orange',
         fontsize=15);

# %%
ax = df['College Type'].value_counts().plot.barh(figsize=(14, 6), color='orange')
ax.set_title('College Type Distribution',color='green', size=18)
ax.set_ylabel('College Type', size=14)
ax.set_xlabel('Count', size=14)

# %%
ax = df['State'].value_counts().plot.barh(figsize=(16, 8), color='green')
ax.set_title('State', size=18, color='orange')
ax.set_ylabel('State', size=10)
ax.set_xlabel('Count', size=10)

# %%
plt.figure(figsize=(15, 10))
ax=sns.countplot(x="Genders Accepted", data=df,palette="Oranges",edgecolor="black", order = df['Genders Accepted'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Genders Accepted', color='green')
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x()+0.25, p.get_height()+1), va='bottom',
                    color= 'black')
plt.show()

# %%
plt.figure(figsize=(15, 10))
ax=sns.countplot(x="College Type", data=df,palette="Greens",edgecolor="black", order = df['College Type'].value_counts().index)
plt.xticks(rotation=90)
plt.title('College Type', color='orange')
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x()+0.25, p.get_height()+1), va='bottom',
                    color= 'black')
plt.show()

# %%
#Codes by Pooja Jain https://www.kaggle.com/jainpooja/av-guided-hackathon-predict-youtube-likes/notebook

text_cols = ['Courses', 'Facilities', 'State']

from wordcloud import WordCloud, STOPWORDS

wc = WordCloud(stopwords = set(list(STOPWORDS) + ['|']),colormap='Oranges', background_color="Green", random_state = 42)
fig, axes = plt.subplots(2, 2, figsize=(20, 12))
axes = [ax for axes_row in axes for ax in axes_row]

for i, c in enumerate(text_cols):
  op = wc.generate(str(df[c]))
  _ = axes[i].imshow(op)
  _ = axes[i].set_title(c.upper(), fontsize=24)
  _ = axes[i].axis('off')

_ = fig.delaxes(axes[3])

# %%
# Count Plot
plt.style.use("classic")
plt.figure(figsize=(6, 4))
sns.countplot(df['College Type'], palette='Oranges', **{'hatch':'/','linewidth':3})
plt.xlabel("College Type")
plt.ylabel("Count")
plt.title("College Type")
plt.xticks(rotation=45, fontsize=8)
plt.show()

# %%
# Count Plot
plt.style.use("classic")
plt.figure(figsize=(6, 4))
sns.countplot(df['Genders Accepted'], palette='Greens', **{'hatch':'/','linewidth':3})
plt.xlabel("Genders Accepted")
plt.ylabel("Count")
plt.title("Genders Accepted")
plt.xticks(rotation=45, fontsize=8)
plt.show()

# %%
#Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

color = plt.cm.Oranges(np.linspace(0,1,20))
df["Courses"].value_counts().sort_values(ascending=False).head(10).plot.pie(y="weight",colors=color,autopct="%0.1f%%")
plt.title("Indian Engineering Colleges Courses")
plt.axis("off")
plt.show()

# %%
px.bar(df, x = 'Rating', y = 'College Type', color = 'State',orientation='h' , title='Rating by College Type',  height = 500 )

# %%
df = df.rename(columns={'College Name':'college_name'})

# %%
#word cloud
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in df.college_name)
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200,colormap='Greens', background_color="orange").generate(text)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='Bilinear')
plt.axis("off")
plt.figure(1,figsize=(12, 12))
plt.show()

# %%
#word cloud
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in df.Courses)
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200,colormap='Oranges', background_color="green").generate(text)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='Bilinear')
plt.axis("off")
plt.figure(1,figsize=(12, 12))
plt.show()

# %%
# categorical features with missing values
categorical_nan = [feature for feature in df.columns if df[feature].isna().sum()>0 and df[feature].dtypes=='O']
print(categorical_nan)

# %%
# replacing missing values in categorical features
for feature in categorical_nan:
    df[feature] = df[feature].fillna('None')

# %%
df[categorical_nan].isna().sum()

# %%
fig = px.bar(df[['State','College Type']].sort_values('College Type', ascending=False), 
                        y = "College Type", x= "State", color='College Type', template='ggplot2')
fig.update_xaxes(tickangle=45, tickfont=dict(family='Rockwell', color='crimson', size=14))
fig.update_layout(title_text="States College Types")

fig.show()

# %%
fig = px.bar(df[['State','Genders Accepted']].sort_values('Genders Accepted', ascending=False), 
                        y = "Genders Accepted", x= "State", color='Genders Accepted', template='ggplot2')
fig.update_xaxes(tickangle=45, tickfont=dict(family='Rockwell', color='crimson', size=14))
fig.update_layout(title_text="States by Genders Accepted")

fig.show()

# %%
#Code by Siti K https://www.kaggle.com/khotijahs1/2020-indonesia-university-rank/comments

#The Best 10 Indian Engineering Colleges by Rating
top_college = df.sort_values(by='Rating', ascending=True)[:10]
figure = plt.figure(figsize=(10,6))
sns.barplot(y=top_college.college_name, x=top_college.Rating)
plt.xticks()
plt.xlabel('Rating')
plt.ylabel('College Name')
plt.title('The Best 10 Indian Engineering Colleges by Rating')
plt.show()

# %%
#Code by Siti K https://www.kaggle.com/khotijahs1/2020-indonesia-university-rank/comments

#The Best 25 Indian Engineering Colleges by Rating
top_college = df.sort_values(by='Rating', ascending=True)[:25]
figure = plt.figure(figsize=(10,6))
sns.barplot(y=top_college.college_name, x=top_college.Rating)
plt.xticks()
plt.xlabel('Rating')
plt.ylabel('College Name')
plt.title('The Best 10 Indian Engineering Colleges by Rating')
plt.show()

# %%
#Code by Olga Belitskaya https://www.kaggle.com/olgabelitskaya/sequential-data/comments
from IPython.display import display,HTML
c1,c2,f1,f2,fs1,fs2=\
'#eb3434','#eb3446','Akronim','Smokum',30,15
def dhtml(string,fontcolor=c1,font=f1,fontsize=fs1):
    display(HTML("""<style>
    @import 'https://fonts.googleapis.com/css?family="""\
    +font+"""&effect=3d-float';</style>
    <h1 class='font-effect-3d-float' style='font-family:"""+\
    font+"""; color:"""+fontcolor+"""; font-size:"""+\
    str(fontsize)+"""px;'>%s</h1>"""%string))
    
    
dhtml('Marília Prata, @mpwolke Was here' )
