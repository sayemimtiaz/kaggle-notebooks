# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)
from sklearn.model_selection import train_test_split,cross_val_predict
from sklearn.linear_model import LogisticRegression
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, \
    roc_auc_score, confusion_matrix, classification_report, plot_roc_curve

# %%
df = pd.read_csv("../input/cardiovascular-disease-dataset/cardio_train.csv", sep = ";")

# %%
df.head()

# %%
 del df['id']

# %%
df.isnull().any()

# %%
# Checking for missing values
df.isnull().any().any()

# %%
# Checking for missing values
df.isna().any().any()

# %%
df['age'].isna()

# %%
df['age'].head()

# %%
df['age'].mean()

# %%
#Converting age into accurate values
df['age'] = df['age']/365

# %%
df.gender.head()

# %%
df.gender.values

# %%
gender_n = df['gender'].values
gender_n

# %%
df['gender'] = df['gender'] - 1

# %%
#Convert gender into binary as 0 Male and 1 Female
df.gender.values

# %%
display(df.describe())

# distribution of response variable
import seaborn 
display(pd.DataFrame(df['cardio'].value_counts()))

# %%
import seaborn 

plt.figure(figsize=(8, 8))
seaborn.heatmap(df.corr(), annot=True, fmt='.3f',cmap='coolwarm')

# %%
df.describe()

# %%
df.head()

# %%
df['alco'].values

# %%
df.head()

# %%
df = df.drop(columns = ['height'])

# %%
x = df.drop(columns = ['cardio'])

# response variable
y = df['cardio']

# %%
# split data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, random_state=0)

# %%
from sklearn.metrics import confusion_matrix

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(max_depth=2).fit(X_train, y_train)
tree_predicted = dt.predict(X_test)
confusion = confusion_matrix(y_test, tree_predicted)

print('Decision tree classifier (max_depth = 2)\n', confusion)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
# Accuracy = TP + TN / (TP + TN + FP + FN)
# Precision = TP / (TP + FP)
# Recall = TP / (TP + FN)  Also known as sensitivity, or True Positive Rate
# F1 = 2 * Precision * Recall / (Precision + Recall) 
print('Accuracy: {:.2f}'.format(accuracy_score(y_test, tree_predicted)))
print('Precision: {:.2f}'.format(precision_score(y_test, tree_predicted)))
print('Recall: {:.2f}'.format(recall_score(y_test, tree_predicted)))
print('F1: {:.2f}'.format(f1_score(y_test, tree_predicted)))

# %%
# Combined report with all above metrics
from sklearn.metrics import classification_report

print(classification_report(y_test, tree_predicted, target_names=['not_Cardic', 'Cardic']))

# %%
# Combined report with all above metrics
from sklearn.metrics import classification_report

print(classification_report(y_test, tree_predicted, target_names=['not_Cardic', 'Cardic']))

# %%
df.head()

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
knn = KNeighborsClassifier()
tree = DecisionTreeClassifier()
nb = GaussianNB()
lr= LogisticRegression()
#SVM gets stuck
#svm=SVC(kernel="linear", C=0.025)

# %%
classifiers = [tree, knn, nb]
names = ["DT", "KNN","NB"]
         
from sklearn.model_selection import cross_validate
from sklearn import metrics  as m


i = 0;
#print(y_train)
for classifier in classifiers:
   
    """Forward Feature Selection ******"""
    """sfs = SequentialFeatureSelector(classifier, n_features_to_select=5,direction='forward',scoring="roc_auc")
    sfs.fit(X, np.ravel(y))
    
    print("Selected Features",X.columns[sfs.get_support()])
    Xt = X[X.columns[sfs.get_support()]]
    """
   
    X_train, X_test, y_train, y_test= train_test_split(x,y, test_size=0.3, random_state=0)
    classifier.fit(X_train, y_train)
    name = names[i]
    i = i+1
    print(" ------------------------ ", name,"----------------------------\n\n")
    y_pred = classifier.predict(X_test)
    mat = m.confusion_matrix(y_test, y_pred)
    print(mat)
    
    print(" Accuracy", m.accuracy_score(y_test, y_pred))
    print(" Recall", m.recall_score(y_test,y_pred))
    print(" AUC" ,m.roc_auc_score(y_test, y_pred))
    print(" F1 SCore",m.f1_score(y_test, y_pred))

# %%
model = LogisticRegression(solver='liblinear')

# %%
model.fit(X_train,y_train)

# %%
model.score(X_train,y_train)

# %%
model.score(X_test,y_test)
