# %% [markdown]
# # Hello!
# Here this is not going to be an Analysis, but here I will demonstrate how to deal with overlapping categories...

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv("../input/imdb-data/IMDB-Movie-Data.csv")
df.head()

# %%
df.Genre = df.Genre.apply(lambda x: ', '.join(map(str.strip, x.split(","))))

# %%
df.sample(4)

# %% [markdown]
# ## Here I will demonstrate - How to solve overlapping genres per movie and how to get set of movies when given a single genre.

# %%
# Create a unique set, so it becomes clear 
genres = set()
for gen in df.Genre:
    for single_gen in map(str.strip, gen.split(",")):
        genres.add(single_gen)

# %%
genres

# %% [markdown]
# #

# %%
# Create dict to store ids of that category
genre_ids = dict()
for gen in genres:
    genre_ids[gen] = []
    
genre_ids

# %% [markdown]
# #

# %%
# Then iterate over 'mixed' category column and save id there
for movie in df.iterrows():
    for gen in genre_ids.keys():
        if gen in movie[1]['Genre']:
            genre_ids[gen].append(movie[0])

# %%
for gen in genre_ids.keys():
    print(gen, ":", len(genre_ids[gen]))

# %% [markdown]
# ### Now, on top of that, we can build our logic and do more stuff more easily!

# %% [markdown]
# #

# %% [markdown]
# ### Example: *If I want to see all movies on 'Action' then I can directly get them...*

# %%
# Simple, isn't it?
df.iloc[genre_ids['Action']]
