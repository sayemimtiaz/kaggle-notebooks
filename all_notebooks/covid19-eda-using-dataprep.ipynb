# %%
# !pip install dataprep

# %%
import pandas as pd
from dataprep.eda import plot, plot_correlation, create_report, plot_missing

# %%
covid_df = pd.read_csv("../input/covid-world-vaccination-progress/country_vaccinations.csv")

# %%
create_report(covid_df)
