# %% [markdown]
# # Doğrusal Regresyon Egzersizleri

# %% [markdown]
# 50 adet Startup'ın araştırma ve geliştirmeye yönelik harcaması, yönetime yönelik harcaması, pazarlama harcaması, kazandıkları kar miktarı ve kuruldukları lokasyon bilgisi bulunmaktadır. Amaç kar miktarını tahmin etmektir. Bu bir sayısal tahmin problemidir ve bağımlı değişkenimiz "Profit".

# %% [markdown]
# Numpy, matplotlib.pyplot, pandas ve seaborn kütüphanelerini çekirdeğe dahil edelim.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Dizinde bulunan veri çerçevemizi startups değişkenine atayalım. startups değişkenini df değişkenine kopyalayarak kullanmaya başlayalım.

# %%
startups  = pd.read_csv("../input/50-startups/50_Startups.csv")
df = startups.copy()

# %% [markdown]
# İlk 5 gözlemini yazdıralım.

# %%
df.head(5)

# %% [markdown]
# Veri çerçevesinin bilgilerini görüntüleyelim.

# %%
df.info()

# %% [markdown]
# Kaç gözlem ve öznitelikten oluştuğunu görüntüleyelim.

# %%
df.shape

# %% [markdown]
# veri setimiz 50 gözlem ve 5 öznitelikten oluşmaktadır.

# %% [markdown]
# Eksik verileri kontrol edelim.

# %%
df.isnull().sum()

# %% [markdown]
# Veri setimizde eksik gözlem bulunmamaktadır.

# %% [markdown]
# Korelasyon matrisi çizdirelim.

# %%
df.corr()

# %% [markdown]
# * Korelasyon katsayısı yorumu: İki değer arasındaki ilişki **Korelasyon** "1" değerine yaklaştıkça artar ve güçlenir.
# * Bu bilgiler ile veri setimizin "1" e yakın olup pozitif değere sahip olan değerlerimiz 0.972900 korelasyon katsayısı ile "R&D Spend" ve "Profit" değeridir.

# %% [markdown]
# Seaborn ile korelasyon matrisinin ısı haritasını çizdirelim.

# %%
sns.heatmap(df.corr());

# %% [markdown]
# * Isı haritasını kullanmamızın sebebi renklendirme ile daha rahat korelasyon yorumu yapabildiğimizdir.
# * Koyu renkler: Korelasyon düşük yani sıfıra yakın değerler. Mesela: "Administration" ve "Marketing Spend"
# * Açık renkler: Korelasyon yüksek yani bire yakın değerler. Mesela: "R&D Spend" ve "Profit"

# %% [markdown]
# R&D Spend ve Profit arasındaki korelasyonu daha iyi görebilmek için scatterplot çizdirelim.

# %%
sns.scatterplot(x = "R&D Spend", y = "Profit", data = df);

# %% [markdown]
# * Grafiğe bakıldığında sonlara doğru doğrusal bir artış olduğu söz konusudur.

# %% [markdown]
# Sayısal değişkenlerin dağılımını görmek için df üzerinden histogram çizdirelim.

# %%
df.hist(figsize =(13,10))
plt.show()

# %% [markdown]
# * Histogram grafikleri genelde dağılıma bakmak için kullanılır.
# * figsize:Grafiğin boyutunu belirler. Parantez içinde yazılan ilk değer grafiğin enini, ikincisi boyutunu belirtir.

# %% [markdown]
# Veri çerçevesinin temel istatistik değerlerini görüntüleyelim.

# %%
df.describe().T

# %% [markdown]
# * Eğer bir veri ortalamaya yakın ise Standart Sapma'da düşük olacaktır. Eğer ortalamaya uzakta bir yaygın dağılım söz konusuysa standart sapma değeri de büyük olacaktır. Standart sapma varyansın kare kökü olduğundan dolayı ortalamaları ve standart sapma değerleri ile **Varyans** yorumu yapabiliriz.
# * Standart sapması en yüksek olan değer "Marketing Spend" dir. Bu yüzden **en yüksek varyansa** sahiptir.
# * Standart sapması en düşük değer ise "Administration" dir. Bu yüzden **en küçük varyans** değerine sahiptir.

# %% [markdown]
# State'a ait benzersiz değerleri görüntüleyelim.

# %%
df["State"].unique()

# %% [markdown]
# get_dummies yardımıyla State'a dair kategorik öznitelik çıkarımlarında bulunalım. Çünkü State'ların birbirine üstünlüğü yok, nominaller. Ordinal değil.

# %%
df_State = pd.get_dummies(df["State"])

# %% [markdown]
# pd.get_dummies () , veri işleme için kullanılır. Kategorik verileri kukla veya gösterge değişkenlere dönüştürür.

# %%
df_State.head(5)
# ilk 5 gözlemi listeleyerek kontrol edelim.

# %%
df_State.columns = ['California','Florida','New York']

# %%
df_State.head(5)

# %% [markdown]
# State özniteliğini silip dummy olarak yaratılan State'lardan da birisini hariç tutarak veri çerçevemizi güncelleyelim.

# %%
df.drop(["State"], axis=1 , inplace =True)
df=pd.concat([df,df_State],axis=1)

# %%
df.head(5)

# %%
df.drop(["California"], axis=1, inplace = True)
df.head()

# %% [markdown]
# Veri çerçevemizi bağımlı ve bağımsız değişkenler olmak üzere bölütleyelim.

# %%
X = df.drop("Profit", axis = 1) #bağımsız değişkenler 
y = df["Profit"] #bağımlı değişkenler

# %% [markdown]
# Bağımlı ve bağımsız değişkenleri kontrol edelim.

# %%
X #bağımsız değişkenimiz

# %%
y #bağımlı değişkenimiz

# %% [markdown]
# Bu bağımlı ve bağımsız değişkenlerden train ve test olmak üzere 4 parça oluşturalım. Bunu yapmak için train_test_split kullanalım.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %% [markdown]
# * Train - Test modellerini oluştumak için sklearn.model_selection kütüphanesini import ediyoruz.
# * Train ve Test için veri setimizi böldük.

# %% [markdown]
# 4 parça değişkeni kontrol edelim.

# %%
X_train

# %%
X_test

# %%
y_train

# %%
y_test

# %% [markdown]
# LinearRegression'u çekirdeğe dahil edip modeli inşa edelim.

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

# %% [markdown]
# Lineer(Doğrusal) regresyonu kullanmak için sklearn.linear_model kütüphanesini import ediyoruz.

# %% [markdown]
# Modeli eğitmek için bağımlı bağımsız değişkenlerden oluşturulan eğitim verilerini verelim.

# %%
lm.fit(X_train, y_train)

# %% [markdown]
# Modele daha önce görmediği bağımlı test değişkenini tahmin ettirelim. Bu tahmin değerlerimizi y_pred değişkenine atayalım.

# %%
y_pred=lm.predict(X_test) #predic = tahmin işlemini gerçekleştirir
y_pred

# %% [markdown]
# Tahminleri ve gerçek değerleri bir veri çerçevesinde toplayıp üzerinde göz gezdirelim.

# %%
df = pd.DataFrame({"Gerçek veriler" : y_test, "Tahmin edilen veriler" : y_pred,"Hata payı sonucu" : abs(y_test - y_pred)})
df

# %% [markdown]
# Gerçek verilerimiz ile tahmin verilerimizin arsındaki farkların mutlak değerlerini alıyoruz.

# %% [markdown]
# sklearn bünyesinde barınan metrics'i çekirdeğe dahil edelim ve MAE, MSE, RMSE değerlerini görüntüleyelim.

# %%
import sklearn.metrics as metrics
import math

mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
rmse = math.sqrt(mse)

print("Hata Mutlak Ortalama Degeri(MAE):",mae) 
print("Hata Kareler Ortalaması Degeri(MSE):", mse) 
print("Hata Kareler Ortalamasının Karekök Degeri(RMSE):", rmse)

# %% [markdown]
# Modelin R Squared değerini eğitim verileri üzerinden yazdıralım.

# %%
print("R Squared=", lm.score(X_train, y_train))

# %% [markdown]
# * R^2 ifademiz 1 e yaklaştıkca modelimizin doğruluğu artmaktadır.  0.9537019995248526 R^2 ifademizin doğruluk oranı yüksektir diyebiliriz.

# %% [markdown]
# Dileyenler statsmodel kullanarak hangi özniteliklerin model için %95 güvenilirlikle ne kadar anlamlı olup olmadığına da bakabilir. Modelde bazı feature selection işlemleri yaparak tekrardan eğitip yeni sonuçlar mukayese edilebilir.

# %%
import statsmodels.api as sm
sttmodel = sm.OLS(y, X).fit()
sttmodel.summary()

# %% [markdown]
# R^2 ifadesi: bağımsız değişkenlerin bağımlı değişkendeki değişikliği açıklama yüzdesidir. 0.988 oldukça yüksek bir rakam.  R^2 ne kadar değişken eklenirse o kadar şişmektedir. Şişmenin önüne geçmek için düzeltilmiş R^2 değeri ortaya çıkar. Daha sağlıklı bir açıklanabilirlik oranı vermektedir. F-statistic: modelin anlamlılığını test etmek için kullanılan istatistiktir. Prob(F- statistic: 0.05 den oldukça küçük bir değere sahip. Bu yüzden modelin anlamlı olduğu bilgisini bize veriyor. (modelin anlamlılığıyla ilgili bize bilgi veriyor.)

# %% [markdown]
# coef: bağımsız değişkenlerin katsayılarını ifade ediyor. (b1, b2, b3 katsayılarını ifade ediyor.) std err: bağımsız değişkenlerin standart hata değeridir. t istatistiği anlamlılığı ifade eder. P>t modellemek için kullandığımız bütün değişkenler anlamlıdır. 0.05 ten küçük değerler elde ettiğimiz sürece anlamlı değişkenler olur. coef katsayısı yorumu: örn: R&D Spend e 1 birimlik yatırım yapıldığı zaman 0.7182 bir artış söz konusu olacaktır.
