# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns

# %%
data = pd.read_csv("../input/predicting-student-grades/AllResults.csv")

# stolen cleaning code
data['Ma'] = data['Ma'].str.lower()
data = data.dropna()
data['MaN'] = data['Ma'].map({'n': 6, 'w': 1, '1': 2, '2': 3, '3a': 4, '3b': 4, '3c': 4,'4c': 5, '4a': 6, '4b': 6, '5b': 7, '5c': 7, '5a': 8, '6a': 9, '6b': 9, '6c': 9})
data = data[data['Att8Act'] > 0]
data.tail()

# %%
data['MaN'].hist()

# %%
sns.regplot(x=data["MaN"], y=data["MathsAct"])
