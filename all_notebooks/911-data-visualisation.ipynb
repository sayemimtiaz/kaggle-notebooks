# %%
### 1) Q : max(Ems,Fire,Traffic)
### 2) Q : timestamp max(year),max(month),max(day),max(hours)
### 3) Q : Folium Library ((pie chart:ems,fire,traffic)100 data points)
### 4) Q :

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns

# %%
data = pd.read_csv("../input/911.csv")
data.head()
# Out:
#          lat        lng ...                        addr  e
# 0  40.297876 -75.581294 ...      REINDEER CT & DEAD END  1
# 1  40.258061 -75.264680 ...  BRIAR PATH & WHITEMARSH LN  1
# 2  40.121182 -75.351975 ...                    HAWS AVE  1
# 3  40.116153 -75.343513 ...          AIRY ST & SWEDE ST  1
# 4  40.251492 -75.603350 ...    CHERRYWOOD CT & DEAD END  1
#
# [5 rows x 9 columns]

# %%
data.shape
# Out:
# (423909, 9)

# %%
data.columns
# Out:
# Index(['lat', 'lng', 'desc', 'zip', 'title', 'timeStamp', 'twp', 'addr', 'e'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423909 entries, 0 to 423908
# Data columns (total 9 columns):
# lat          423909 non-null float64
# lng          423909 non-null float64
# desc         423909 non-null object
# zip          371780 non-null float64
# title        423909 non-null object
# timeStamp    423909 non-null object
# twp          423750 non-null object
# addr         423909 non-null object
# e            423909 non-null int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 29.1+ MB

# %%
data['timeStamp'] = pd.to_datetime(data['timeStamp'])
data.head(5)
# Out:
#          lat        lng ...                        addr  e
# 0  40.297876 -75.581294 ...      REINDEER CT & DEAD END  1
# 1  40.258061 -75.264680 ...  BRIAR PATH & WHITEMARSH LN  1
# 2  40.121182 -75.351975 ...                    HAWS AVE  1
# 3  40.116153 -75.343513 ...          AIRY ST & SWEDE ST  1
# 4  40.251492 -75.603350 ...    CHERRYWOOD CT & DEAD END  1
#
# [5 rows x 9 columns]

# %%
import re
def type_reason(x):
    x = str(x)
    if (re.search("EMS", x)):
        return "EMS"
    
    elif (re.search("Traffic", x)):
        return "Traffic"
    else:
        return "Fire"

# %%
data["call_type"] = data["title"].apply(type_reason)
data.head()
# Out:
#          lat        lng    ...      e  call_type
# 0  40.297876 -75.581294    ...      1        EMS
# 1  40.258061 -75.264680    ...      1        EMS
# 2  40.121182 -75.351975    ...      1       Fire
# 3  40.116153 -75.343513    ...      1        EMS
# 4  40.251492 -75.603350    ...      1        EMS
#
# [5 rows x 10 columns]

# %% [markdown]
# ### Which type of call is maximum

# %%
datax_major_type=data["call_type"].value_counts()

# %%
datax_major_type = pd.Series(datax_major_type)
datax_major_type
# Out:
# EMS        208682
# Traffic    151458
# Fire        63769
# Name: call_type, dtype: int64

# %%
font ={
    "size" :20
}
plt.figure(figsize=(8,6))
datax_major_type.plot(kind="bar")
plt.xticks(rotation=30)
plt.xlabel("Types of Calls",fontdict=font)
plt.ylabel("No. of Calls",fontdict=font)
plt.title("Types of Calls Vs No. of Calls",fontdict=font)
plt.savefig("Types-of-Calls-vs-No-of-Calls.png")

# %%
data['Year'] = data['timeStamp'].dt.year
data.head()
# Out:
#          lat        lng  ...  call_type  Year
# 0  40.297876 -75.581294  ...        EMS  2015
# 1  40.258061 -75.264680  ...        EMS  2015
# 2  40.121182 -75.351975  ...       Fire  2015
# 3  40.116153 -75.343513  ...        EMS  2015
# 4  40.251492 -75.603350  ...        EMS  2015
#
# [5 rows x 11 columns]

# %%
data['Month'] = data['timeStamp'].dt.month_name()
data.head()
# Out:
#          lat        lng    ...     Year     Month
# 0  40.297876 -75.581294    ...     2015  December
# 1  40.258061 -75.264680    ...     2015  December
# 2  40.121182 -75.351975    ...     2015  December
# 3  40.116153 -75.343513    ...     2015  December
# 4  40.251492 -75.603350    ...     2015  December
#
# [5 rows x 12 columns]

# %%
data["Day"] = data['timeStamp'].dt.day_name()
data.head()
# Out:
#          lat        lng    ...        Month       Day
# 0  40.297876 -75.581294    ...     December  Thursday
# 1  40.258061 -75.264680    ...     December  Thursday
# 2  40.121182 -75.351975    ...     December  Thursday
# 3  40.116153 -75.343513    ...     December  Thursday
# 4  40.251492 -75.603350    ...     December  Thursday
#
# [5 rows x 13 columns]

# %%
data["Hour"] = data['timeStamp'].dt.hour
data.head()
# Out:
#          lat        lng  ...        Day  Hour
# 0  40.297876 -75.581294  ...   Thursday    17
# 1  40.258061 -75.264680  ...   Thursday    17
# 2  40.121182 -75.351975  ...   Thursday    14
# 3  40.116153 -75.343513  ...   Thursday    16
# 4  40.251492 -75.603350  ...   Thursday    16
#
# [5 rows x 14 columns]

# %%
def actual_type_call(x):
    x= x.split(':')
    return x[1]

# %%
data["emergency_reason"] = data["title"].apply(actual_type_call)
data.head()
# Out:
#          lat        lng         ...          Hour     emergency_reason
# 0  40.297876 -75.581294         ...            17    BACK PAINS/INJURY
# 1  40.258061 -75.264680         ...            17   DIABETIC EMERGENCY
# 2  40.121182 -75.351975         ...            14        GAS-ODOR/LEAK
# 3  40.116153 -75.343513         ...            16    CARDIAC EMERGENCY
# 4  40.251492 -75.603350         ...            16            DIZZINESS
#
# [5 rows x 15 columns]

# %% [markdown]
# ### Ems First 7 seven pie data plot

# %%
ems_data = data.copy(deep=True)

# %%
ems_data.query('call_type == "EMS"',inplace = True)
ems_data.head()
# Out:
#          lat        lng         ...          Hour     emergency_reason
# 0  40.297876 -75.581294         ...            17    BACK PAINS/INJURY
# 1  40.258061 -75.264680         ...            17   DIABETIC EMERGENCY
# 3  40.116153 -75.343513         ...            16    CARDIAC EMERGENCY
# 4  40.251492 -75.603350         ...            16            DIZZINESS
# 5  40.253473 -75.283245         ...            15          HEAD INJURY
#
# [5 rows x 15 columns]

# %%
count_ems = ems_data['emergency_reason'].value_counts()

# %%
plt.figsize=(15,10)
plt.pie(count_ems.values[:7],labels=count_ems.index[:7],autopct="%.2f")
plt.savefig("Types-of-EMS-Calls-vs-No-of-Calls.png")

# %%
### Fire Data first 7 pie plot

# %%
fire_data = data.copy(deep = True)

# %%
fire_data.query('call_type == "Fire"',inplace = True)
fire_data.head(2)
# Out:
#           lat        lng        ...        Hour  emergency_reason
# 2   40.121182 -75.351975        ...          14     GAS-ODOR/LEAK
# 22  40.199006 -75.300058        ...          17    APPLIANCE FIRE
#
# [2 rows x 15 columns]

# %%
fire_data['emergency_reason'].nunique()
# Out:
# 53

# %%
count_fire = fire_data['emergency_reason'].value_counts()
count_fire.head(2)
# Out:
#  FIRE ALARM          24380
#  VEHICLE ACCIDENT     7153
# Name: emergency_reason, dtype: int64

# %%
plt.figsize=(15,10)
plt.pie(count_fire.values[:7],labels=count_fire.index[:7],autopct="%.2f")
plt.savefig("Types-of-fire-Calls-vs-No-of-Calls.png")

# %%
### Traffic Pie Chart

# %%
traffic_data = data.copy(deep=True)

# %%
traffic_data.query('call_type == "Traffic"',inplace =True)
traffic_data.head(2)
# Out:
#           lat        lng         ...          Hour     emergency_reason
# 9   40.102398 -75.291458         ...            17   VEHICLE ACCIDENT -
# 10  40.231990 -75.251891         ...            17   VEHICLE ACCIDENT -
#
# [2 rows x 15 columns]

# %%
traffic_data['emergency_reason'].nunique()
# Out:
# 7

# %%
count_traffic = traffic_data['emergency_reason'].value_counts()
count_traffic.head(7)
# Out:
#  VEHICLE ACCIDENT -             98401
#  DISABLED VEHICLE -             31871
#  ROAD OBSTRUCTION -             14134
#  HAZARDOUS ROAD CONDITIONS -     4395
#  VEHICLE FIRE -                  2286
#  VEHICLE LEAKING FUEL -           232
#  DEBRIS/FLUIDS ON HIGHWAY -       139
# Name: emergency_reason, dtype: int64

# %%
plt.figsize=(15,10)
plt.pie(count_traffic.values[:5],labels=count_traffic[:5].index,autopct="%.2f")
plt.savefig("Types-of-traffic-Calls-vs-No-of-Calls.png")

# %% [markdown]
# ### Plotting using Time stamp

# %% [markdown]
# ## Data Monthly

# %%
calls_data = data.groupby(["Month","call_type"])["call_type"].count()
calls_data.head()
# Out:
# Month   call_type
# April   EMS          17256
#         Fire          4982
#         Traffic      11345
# August  EMS          17965
#         Fire          5717
# Name: call_type, dtype: int64

# %%
calls_percentage = calls_data.groupby(level=0).apply(lambda x:round(100*x/x.sum()) )
calls_percentage.head()
# Out:
# Month   call_type
# April   EMS          51.0
#         Fire         15.0
#         Traffic      34.0
# August  EMS          50.0
#         Fire         16.0
# Name: call_type, dtype: float64

# %%
month_order =  ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# %%
calls_percentage = calls_percentage.reindex(month_order, level=0)
calls_percentage.head()
# Out:
# Month     call_type
# January   EMS          49.0
#           Fire         15.0
#           Traffic      36.0
# February  EMS          51.0
#           Fire         15.0
# Name: call_type, dtype: float64

# %%
sns.set(rc={'figure.figsize':(12, 8)})
calls_percentage.unstack().plot(kind='bar')
plt.xlabel('Name of the Month', fontdict=font)
plt.ylabel('Percentage of Calls', fontdict=font)
plt.xticks(rotation=0)
plt.title('Calls Per Month', fontdict=font)
plt.savefig("Calls-per-Month.png")

# %% [markdown]
# ## Per Day

# %%
calls_data = data.groupby(["Day","call_type"])["call_type"].count()
calls_data.head()
# Out:
# Day     call_type
# Friday  EMS          31010
#         Fire          9683
#         Traffic      25058
# Monday  EMS          30431
#         Fire          9292
# Name: call_type, dtype: int64

# %%
day_order= ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']

# %%
calls_percentage = calls_data.groupby(level=0).apply(lambda x:round(100*x/x.sum()) )
calls_percentage.head()
# Out:
# Day     call_type
# Friday  EMS          47.0
#         Fire         15.0
#         Traffic      38.0
# Monday  EMS          50.0
#         Fire         15.0
# Name: call_type, dtype: float64

# %%
calls_percentage = calls_percentage.reindex(day_order, level=0)
calls_percentage.head()
# Out:
# Day      call_type
# Monday   EMS          50.0
#          Fire         15.0
#          Traffic      35.0
# Tuesday  EMS          48.0
#          Fire         15.0
# Name: call_type, dtype: float64

# %%
sns.set(rc={'figure.figsize':(12, 8)})
calls_percentage.unstack().plot(kind='bar')
plt.xlabel('Name of the Day', fontdict=font)
plt.ylabel('Percentage of Calls', fontdict=font)
plt.xticks(rotation=0)
plt.title('Calls Per Day', fontdict=font)
plt.savefig("Calls-per-Day.png")

# %% [markdown]
# ## Data Hourly

# %%
calls_data = data.groupby(["Hour","call_type"])["call_type"].count()
calls_data.head()
# Out:
# Hour  call_type
# 0     EMS          5263
#       Fire         1341
#       Traffic      2046
# 1     EMS          4711
#       Fire         1104
# Name: call_type, dtype: int64

# %%
calls_percentage = calls_data.groupby(level=0).apply(lambda x:round(100*x/x.sum()) )
calls_percentage.head()
# Out:
# Hour  call_type
# 0     EMS          61.0
#       Fire         16.0
#       Traffic      24.0
# 1     EMS          64.0
#       Fire         15.0
# Name: call_type, dtype: float64

# %%
sns.set(rc={'figure.figsize':(12, 8)})
calls_percentage.unstack().plot(kind='bar')
plt.xlabel('Name of the Hour', fontdict=font)
plt.ylabel('Percentage of Calls', fontdict=font)
plt.xticks(rotation=0)
plt.title('Calls Per Hour', fontdict=font)
plt.savefig("Call-per-Hour.png")
