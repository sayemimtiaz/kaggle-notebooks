# %% [markdown]
# # Reading images in Python
# 1. There are plenty of way of reading image
# *  Here We will discuss those method in order to read image file
# * IPython - it is on the way that is done below

# %% [markdown]
# # IPython
# * Great Library to read and explore image
# * Here is the [Link](https://ipython.readthedocs.io/en/stable/api/generated/IPython.display.html)
# * Check out and Learn the tutorial from the above link

# %%
from IPython.display import Image
Image("../input/kaggle-logo/Kaggle_logo.png")

# %%
from IPython.display import Image
Image("../input/netflix/thibault-penin-AWOl7qqsffM-unsplash-scaled.jpg", width=500, height=200)

# %%
images=['../input/netflix/thibault-penin-AWOl7qqsffM-unsplash-scaled.jpg','../input/thank-you/download.jpg']
for imageName in images:
    display(Image(filename=imageName))

# %% [markdown]
# # Matpltlib

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline
  
# Read Images
img = mpimg.imread('../input/kaggle-logo/Kaggle_logo.png')
  
# Output Images
plt.imshow(img)

# %%
imgplot = plt.imshow(img)

# %% [markdown]
# # Playing with different color

# %%
lum_img = img[:, :, 0]

# This is array slicing.  You can read more in the `Numpy tutorial
# <https://docs.scipy.org/doc/numpy/user/quickstart.html>`_.

plt.imshow(lum_img)

# %%
plt.imshow(lum_img, cmap="hot")

# %%
imgplot = plt.imshow(lum_img)
imgplot.set_cmap('nipy_spectral')

# %% [markdown]
# # Color scale reference

# %%
imgplot = plt.imshow(lum_img)
plt.colorbar()

# %%
plt.hist(lum_img.ravel(), bins=256, range=(0.0, 1.0), fc='k', ec='k')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 2, 1)
imgplot = plt.imshow(lum_img)
ax.set_title('Before')
plt.colorbar(ticks=[0.1, 0.3, 0.5, 0.7], orientation='horizontal')
ax = fig.add_subplot(1, 2, 2)
imgplot = plt.imshow(lum_img)
imgplot.set_clim(0.0, 0.7)
ax.set_title('After')
plt.colorbar(ticks=[0.1, 0.3, 0.5, 0.7], orientation='horizontal')

# %%
from PIL import Image

img = Image.open('../input/kaggle-logo/Kaggle_logo.png')
img.thumbnail((64, 64), Image.ANTIALIAS)  # resizes image in-place
imgplot = plt.imshow(img)

# %%
imgplot = plt.imshow(img, interpolation="nearest")

# %% [markdown]
# # Netflix Image

# %%
img = mpimg.imread('../input/netflix/thibault-penin-AWOl7qqsffM-unsplash-scaled.jpg')
  
# Output Images
plt.imshow(img)

# %%
plt.imshow(img, cmap="hot")

# %% [markdown]
# # Obs
# * SImmilar code as done above
# * Plenetly of resources are avilable in google
# * for the refferece I will pin some of the resources below
# # References
# > * [Link1](https://matplotlib.org/stable/tutorials/introductory/images.html#sphx-glr-tutorials-introductory-images-py)
# > * [Link2](https://www.geeksforgeeks.org/reading-images-in-python/)
# > * [My Profile ](https://www.kaggle.com/jurk06)

# %%
from IPython.display import Image
Image("../input/thank-you/download.jpg", width=500, height=200)
