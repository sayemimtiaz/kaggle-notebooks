# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

 # linear algebra
 # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#import libraries
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <a id="top"></a>
#
# <div class="list-group" id="list-tab" role="tablist">
#
# <font color="teal" size=+1><b>Content List</b></font>
#
# * [1. Student Marks (Pass or Fail)](#47)
# * [2. Get passed grades](#48)
# * [3. Students passed in Language and Math](#49)
# * [4. Students passed in Language and Science](#50)
# * [5. Students passed in Language or Science (any one subject)](#62)
# * [6. possible errors: TypeError: 'Series' objects are mutable, thus they cannot be hashed](#63)
# * [7. Drop duplicates](#81)
# * [8. Selecting multiple columns](#82)
# * [9. Selecting multiple columns](#83)
# * [10. Row and Column Slicing](#84)
# * [11. Iterating rows](#85)
# * [12. Iterating tuples](#86)
# * [13. Iterating rows and columns](#87)

# %%
import pandas
import pandas as pd
import numpy
import numpy as np
import random as rn
import functools
import re

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="47"></a>
#         <font><b>Task 1:</b></font>
#         <br><br>
#         Student Marks (Pass or Fail)
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="48"></a>
#         <font><b>Task 2:</b></font>
#         <br><br>
#         Get passed grades
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="49"></a>
#         <font><b>Task 3:</b></font>
#         <br><br>
#         Students passed in Language and Math
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="50"></a>
#         <font><b>Task 4:</b></font>
#         <br><br>
#         Students passed in Language and Science
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="62"></a>
#         <font><b>Task 5:</b></font>
#         <br><br>
#         Students passed in Language or Science (any one subject)
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id=""></a>
#         <font><b>Task 6:</b></font>
#         <br><br>
#         possible errors:
#         <br>TypeError: 'Series' objects are mutable, thus they cannot be hashed
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="81"></a>
#         <font><b>Task 7:</b></font>
#         <br><br>
#         Drop duplicates
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="82"></a>
#         <font><b>Task 8:</b></font>
#         <br><br>
#         Selecting multiple columns
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="83"></a>
#         <font><b>Task 9:</b></font>
#         <br><br>
#         Selecting multiple columns
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="84"></a>
#         <font><b>Task 10:</b></font>
#         <br><br>
#         Row and Column Slicing
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="85"></a>
#         <font><b>Task 11:</b></font>
#         <br><br>
#         Iterating rows
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="86"></a>
#         <font><b>Task 12:</b></font>
#         <br><br>
#         Iterating tuples
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>

# %% [markdown]
# <div style="">
#     <div style="float: left; width: 80%;">
#         <a id="87"></a>
#         <font><b>Task 13:</b></font>
#         <br><br>
#         Iterating rows and columns
#     </div>
#     <div style="float: right;">
#         <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Top">Go to Top</a>
#     </div>
#     <br style="clear: left;" />
# </div>
