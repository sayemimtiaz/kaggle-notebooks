# %% [markdown]
# <h1>Домашнє завдання №1. Варіант 1</h1>
# <h1>Аналіз даних доходу населення UCI Adult</h1>

# %% [markdown]
# <p style="font-size: 16px;text-align: justify">У завданні пропонується за допомогою Pandas відповісти на кілька запитань за даними сховища UCI [Adult](https://archive.ics.uci.edu/ml/datasets/Adult) (завантажувати дані не треба - вони вже є в репозиторії). Для відправки розв'язків використовується [система Moodle](https://eln.stu.cn.ua/course/view.php?id=2994).</p>

# %% [markdown]
# <p style="font-size: 16px">Унікальні значення ознак ([більше інформації за посиланням](https://archive.ics.uci.edu/ml/datasets/Adult)):</p>
#
# * age: continuous (вік).
# * workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked (Тип робочої діяльності).
# * fnlwgt: continuous.
# * education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool. (Освіта).
# * education-num: continuous.
# * marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse (Сімейний статус).
# * occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces. (Вид діяльності).
# * relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried. (Сімейні відносини).
# * race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black. (Раса).
# * sex: Female, Male. (Стать).
# * capital-gain: continuous.
# * capital-loss: continuous.
# * hours-per-week: continuous. (Кількість робочих годин на тиждень).
# * native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands. (Країна проживання).
# * salary: >50K,<=50K (Заробітна плата, бінарний показник, більше 59 тисяч або менше дорівнює 50 тисяч).

# %%
# Імпорт Pandas і Numpy
import numpy as np
import pandas as pd

#Вхідні дані доступні в "../input/"
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Будь-які результати доступні у папці "../output/kaggle/working"

# %%
data = pd.read_csv("/kaggle/input/uci-adult/adult.data.csv")

# %%
data.shape

# %%
data.head()

# %% [markdown]
# <p style="font-size: 16px;text-align: justify"> 1. Визначити кількість жінок (ознака sex) у цьому наборі.</p>

# %%
# Ваш код тут

# %% [markdown]
# <p style="font-size: 16px;text-align: justify"> 2. Визначити, який максимальний вік (ознаки sex, age) чоловіків у цьому наборі.</p>

# %%
# Ваш код тут

# %% [markdown]
# <p style="font-size: 16px;text-align: justify"> 3. Визначити відсоток жінок для яких США - рідна країна (ознаки sex, native-country).</p>

# %%
# Ваш код тут

# %% [markdown]
# <p style="font-size: 16px;text-align: justify"> 4. Визначити різницю між 0.95 квантилем і 0.15 квантилем для ознаки age.</p>

# %%
# Ваш код тут

# %% [markdown]
# <p style="font-size: 16px;text-align: justify"> 5. Обчислити середнє та середньоквадратичне відхилення віку тих, хто заробляє мало (ознаки age, salary).</p>

# %%
# Ваш код тут

# %% [markdown]
# <p style="font-size: 16px;text-align: justify"> 6. Визначити, чи правда, що вік всіх людей, які заробляють багато більше 40 (ознаки age, salary).</p>

# %%
# Ваш код тут

# %% [markdown]
# <p style="font-size: 16px;text-align: justify"> 7. Обчислити максимальний вік чоловіків раси Amer-Indian-Eskimo (ознаки age, race, sex).</p>

# %%
# Ваш код тут

# %% [markdown]
# <p style="font-size: 16px;text-align: justify"> 8. Визначити на скільки відсотків кількість холостих чоловіків у Японії більше чи менше, ніж у США (ознаки native-country, sex, marital-status). Marital-status для одружених чоловіків дорівнює Married-civ-spouse, Married-spouse-absent чи Married-AF-spouse.</p>

# %%
# Ваш код тут

# %% [markdown]
# <p style="font-size: 16px;text-align: justify"> 9. Обчислити максимальну кількість годин праці людей за тиждень, кількість людей з максимальною кількістю годин та серед них процент тих, хто заробляє багато (ознаки hours-per-week, salary).</p>

# %%
# Ваш код тут

# %% [markdown]
# <p style="font-size: 16px;text-align: justify"> 10. Обчислити максимальну кількість годин праці людей за тиждень серед тих, хто заробляє багато для всіх рас. У відповідь записати середнє значення з отриманого переліку (ознаки hours-per-week, salary, race).</p>

# %%
# Ваш код тут

# %% [markdown]
# <p style="font-size: 16px;text-align: justify"> 11. Обчислити число унікальних значень ознаки race.</p>

# %%
# Ваш код тут

# %% [markdown]
# <p style="font-size: 16px;text-align: justify"> 12. Визначити назву країни та вік для 603 запису (ознаки native-country, age).</p>

# %%
# Ваш код тут
