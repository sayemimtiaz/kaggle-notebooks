# %%
import pandas as pd
import numpy as np
import missingno as mons
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("../input/car-purchasing-model/Car_Purchasing_Data.csv")

# %%
data.head()

# %%
mons.bar(data)

# %% [markdown]
# No Missing value

# %%
data['Country'].value_counts()

# %%
data['Gender'].value_counts()

# %%
sns.distplot(data['Age'])

# %%
data.info()

# %%
data.describe()

# %%
sns.distplot(data['Annual Salary'])

# %%
sns.pairplot(data)

# %%
data.head()

# %%
sns.scatterplot(data['Age'], data['Annual Salary'],color ="red" )

# %%
plt.figure(figsize=(10,10))
data[data['Gender']==1]['Age'].hist()
data[data['Gender']==0]['Age'].hist()
plt.legend([1,0])

# %%
plt.figure(figsize=(10,10))
data[data['Gender']==1]['Annual Salary'].hist()
data[data['Gender']==0]['Annual Salary'].hist()
plt.legend([1,0])
