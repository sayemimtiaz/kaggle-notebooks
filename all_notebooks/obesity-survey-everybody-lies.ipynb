# %% [markdown]
# ![](https://i.pinimg.com/originals/bb/d9/dd/bbd9dd409255221e82ac0d36eb6cd75a.jpg)pinterest.com

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

#Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('../input/a-survey-on-obesity/obesity.csv', encoding='utf8')
pd.set_option('display.max_columns', None)
df.head()

# %%
df.isnull().sum()

# %% [markdown]
# #Codes by Mario Filho https://www.kaggle.com/mariofilho/live26-https-youtu-be-zseefujo0zq

# %% [markdown]
# <font color="#EC7063">Number of Participants By Gender</font>

# %%
df["What is your gender ?"].value_counts()

# %% [markdown]
# #Codes by Lucas Abrahão https://www.kaggle.com/lucasabrahao/trabalho-manufatura-an-lise-de-dados-no-brasil

# %%
#Code by Lucas Abrahão https://www.kaggle.com/lucasabrahao/trabalho-manufatura-an-lise-de-dados-no-brasil

df["What is your gender ?"].value_counts().plot.bar(color=['blue', '#f5005a'], title='Participants Gender',)

# %%
# !pip install pywaffle

# %% [markdown]
# #Codes by ask9 https://www.kaggle.com/arbazkhan971/indians-vs-world/notebook

# %%
#Codes by ask9 https://www.kaggle.com/arbazkhan971/indians-vs-world/notebook

def random_colors(number_of_colors):
    color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
                 for i in range(number_of_colors)]
    return color

# %%
from pywaffle import Waffle
import random

gender = df["What is your gender ?"].value_counts()

fig = plt.figure(
    FigureClass=Waffle,
    rows=5,
    columns=20,
    values=gender,
    colors = random_colors(len(gender)),
    title={'label': 'Gender Distribution', 'loc': 'left'},
    labels=["{}({})".format(a, b) for a, b in zip(gender.index, gender) ],
    legend={'loc': 'lower left', 'bbox_to_anchor': (0, -0.4), 'ncol': len(df.groupby("Select your age group ?").get_group('20- 30 years old .')), 'framealpha': 0},
    font_size=30, 
    icons = 'child',
    figsize=(12, 5),  
    icon_legend=True
)

# %% [markdown]
# ### <b><mark style="background-color: #EC7063"><font color="white">A Basic Pywaffle</font></mark></b>
#
# https://www.programmersought.com/article/58954918714/

# %%
plt.figure(
    FigureClass=Waffle,
    rows=5,
    columns=10,
    values=gender,
    title={'label': 'Gender Distribution', 'loc': 'left'},
    labels=["{}({})".format(a, b) for a, b in zip(gender.index, gender) ],
    # Set the position of the legend
    legend={'loc': 'upper left', 'bbox_to_anchor': (1, 1)},
    dpi=100
)
plt.show()

# %% [markdown]
# ### <b><mark style="background-color: #EC7063"><font color="white">Or changing the background color</font></mark></b>

# %%
sns.set(style="ticks", context="talk", font_scale=1.5)
plt.style.use("dark_background")

# %%
#Codes by Alexander Filin https://www.kaggle.com/infamous25700/pornactors-are-among-us-18

from pywaffle import Waffle

gender = df["What is your gender ?"].value_counts()

plt.figure(
    FigureClass=Waffle,
    rows=5,
    columns=10,
    values=gender,
    title={'label': 'Gender Distribution', 'loc': 'left'},
    labels=["{}({})".format(a, b) for a, b in zip(gender.index, gender) ],
    # Set the position of the legend
    legend={'loc': 'upper left', 'bbox_to_anchor': (1, 1)},
    dpi=100,
    colors = ["#ffa31a", "#D17200"]
    #colors = ["#ffa31a", "#D17200", "#9c5400", "#763f00", "#422400"]
)
plt.show()

# %% [markdown]
# #It's a pity that we have only two Genders. I have more colors to apply in the chart.

# %%
df["Select your age group ?"].value_counts()

# %%
#Code by Lucas Abrahão https://www.kaggle.com/lucasabrahao/trabalho-manufatura-an-lise-de-dados-no-brasil

df["Select your age group ?"].value_counts().plot.barh(color=['blue', 'red','lime','purple','teal','cyan'], title='Age Group',)

# %%
#Codes by Alexander Filin https://www.kaggle.com/infamous25700/pornactors-are-among-us-18

from pywaffle import Waffle

age = df["Select your age group ?"].value_counts()

plt.figure(
    FigureClass=Waffle,
    rows=5,
    columns=10,
    values=age,
    title={'label': 'Age Distribution', 'loc': 'left'},
    labels=["{}({})".format(a, b) for a, b in zip(age.index, age) ],
    # Set the position of the legend
    legend={'loc': 'upper left', 'bbox_to_anchor': (1, 1)},
    dpi=100,
    colors = ["#ffa31a", "#D17200", "#9c5400", "#763f00", "#422400", "#a88732"]
)
plt.show()

# %% [markdown]
# #Now I could apply more colors to the Waffle

# %%
df["Do you try to maintain balance diet ?"].value_counts()

# %%
df["Do you try to maintain balance diet ?"].value_counts().nlargest(4).plot.bar(color=['green','blue','red'])

# %%
df["Do you try to maintain balance diet ?"].value_counts().plot.barh(figsize = (8,6))

# %%
df["Select the weight category you belong to ?"].value_counts()

# %%
df["Select the weight category you belong to ?"].value_counts().plot.barh(color=['blue', 'red','lime','purple','teal','cyan'], title='Weight Category',)

# %%
df["How often you take alcoholic beverages ?"].value_counts()

# %%
df["How often you take alcoholic beverages ?"].value_counts().plot.barh(title='Alcohol Consumption', color='black')

# %%
df["How often you eat fruits and salad ?"].value_counts()

# %%
df["How often do you eat junk food at your home or your workplace ?"].value_counts()

# %%
fig,ax = plt.subplots(1,1, figsize=(20,10))
plot = sns.barplot(x="Select your age group ?", y="Pizza,Burger,fries,cold drink.", data=df)
plot.set_xticklabels(plot.get_xticklabels(), rotation=90)

# %%
fig,ax = plt.subplots(1,1, figsize=(20,10))
plot = sns.barplot(x="What is your gender ?", y="Which of the following meals,you are most likely to have after busy day schedule ?Rate from 1-5 (with 1 being least likely and 5 being most).\n\nChapati,Dal,Rice, vegetables.", data=df)
plot.set_xticklabels(plot.get_xticklabels(), rotation=90)

# %%
fig,ax = plt.subplots(1,1, figsize=(20,10))
plot = sns.barplot(x="Do you try to maintain balance diet ?", y="Non- vegetarian meal.", data=df)
plot.set_xticklabels(plot.get_xticklabels(), rotation=90)

# %%
ds = df[df["What is your gender ?"] == 'Female']
fig,ax = plt.subplots(1,1, figsize=(15,5))
plt.hist(ds["Pizza,Burger,fries,cold drink."], bins=7)
plt.axvline(ds['Pizza,Burger,fries,cold drink.'].mean(), color='k', linewidth=5)
plt.axvline(ds['Pizza,Burger,fries,cold drink.'].median(), color='g', linewidth=5)

# %%
ds = df[df["Select the weight category you belong to ?"] == 'Obese']
fig,ax = plt.subplots(1,1, figsize=(15,5))
plt.hist(ds["How likely are you to spread Awareness that Genes play Important role in Obesity?"], bins=7)
plt.axvline(ds['How likely are you to spread Awareness that Genes play Important role in Obesity?'].mean(), color='k', linewidth=5)
plt.axvline(ds['How likely are you to spread Awareness that Genes play Important role in Obesity?'].median(), color='g', linewidth=5)

# %%
fig,ax = plt.subplots(1,1, figsize=(8,8))
degree = df.groupby(["Select your age group ?", "Select the weight category you belong to ?"]).size().unstack()#.fillna(0)
degree = degree.div(degree.sum(axis=1), axis=0)
sns.heatmap(degree, cmap='Spectral_r')

# %%
from category_encoders import OneHotEncoder
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.preprocessing import StandardScaler, MinMaxScaler, MaxAbsScaler

cols_selected = ["How likely are you to spread Awareness that Genes play Important role in Obesity?"]
ohe = OneHotEncoder(cols=cols_selected, use_cat_names=True)
df_t = ohe.fit_transform(df[cols_selected+['ID']])

#scaler = MaxAbsScaler()
X = df_t.iloc[:,:-1]
y = df_t.iloc[:, -1].fillna(df_t.iloc[:, -1].mean()) / df_t.iloc[:, -1].max()

mdl = Ridge(alpha=0.1)
mdl.fit(X,y)

pd.Series(mdl.coef_, index=X.columns).sort_values().head(10).plot.barh()

# %%
from category_encoders import OneHotEncoder

#scaler = MaxAbsScaler()
X = df[df.filter(regex='How likely are you to spread Awareness that Genes play Important role in Obesity?', axis=1).columns]
y = df.iloc[:, -1].fillna(df.iloc[:, -1].mean()) / df.iloc[:, -1].max()

mdl = Ridge(alpha=0.1)
mdl.fit(X,y)

pd.Series(mdl.coef_, index=X.columns).sort_values().head(10).plot.barh()

# %%
col_ad = "Select the weight category you belong to ?"
df.loc[df[col_ad] == 'Overweight', col_ad] = 'overweight'

men = df[df.loc[:, "What is your gender ?"] == 'Male'] #Linhas com sexo Masculino
men_state_mean = men.groupby("Are you aware that genes play a role in Obesity ?")['How likely are you to spread Awareness that Genes play Important role in Obesity?'].mean() #Média Masculina por região

woman = df[df.loc[:, "What is your gender ?"] == 'Female'] #Linhas com sexo Feminino
woman_state_mean = woman.groupby("Are you aware that genes play a role in Obesity ?")['How likely are you to spread Awareness that Genes play Important role in Obesity?'].mean() #Média Feminina por região

menxp = men.groupby("What do you think,which of the following cause Obesity?\n(Select all options that apply)")['How likely are you to spread Awareness that Genes play Important role in Obesity?'].mean()
womanxp = woman.groupby("What do you think,which of the following cause Obesity?\n(Select all options that apply)")['How likely are you to spread Awareness that Genes play Important role in Obesity?'].mean()

# %%
plt.barh(men_state_mean.index, men_state_mean.values, color='blue')
plt.barh(woman_state_mean.index, woman_state_mean.values, color='#f5005a')

plt.xlabel("How likely are you to spread Awareness that Genes play Important role in Obesity?")
plt.ylabel("Are you aware that genes play a role in Obesity ?")

plt.title("Obesity Survey")

plt.legend(['Male', 'Female'])

# %% [markdown]
# I'm missing something because it was suppose to have MALE (stacked)barhs. Though Male appeared only in the legends. Something went wrong while I was adapting salary to obesity.

# %%
plt.barh(menxp.index, menxp.values, color='blue')
plt.barh(womanxp.index, womanxp.values, color='#f5005a')

plt.xlabel("What do you think,which of the following cause Obesity?\n(Select all options that apply)")
plt.ylabel("How likely are you to spread Awareness that Genes play Important role in Obesity?")
plt.legend(['Male', 'Female'])

plt.title("Obesity Survey")

# %% [markdown]
# No Male data again. Only in the legends.

# %%
#Code by Olga Belitskaya https://www.kaggle.com/olgabelitskaya/sequential-data/comments
from IPython.display import display,HTML
c1,c2,f1,f2,fs1,fs2=\
'#eb3434','#eb3446','Akronim','Smokum',30,15
def dhtml(string,fontcolor=c1,font=f1,fontsize=fs1):
    display(HTML("""<style>
    @import 'https://fonts.googleapis.com/css?family="""\
    +font+"""&effect=3d-float';</style>
    <h1 class='font-effect-3d-float' style='font-family:"""+\
    font+"""; color:"""+fontcolor+"""; font-size:"""+\
    str(fontsize)+"""px;'>%s</h1>"""%string))
    
    
dhtml('Be patient. Marília Prata, @mpwolke was Here.' )
