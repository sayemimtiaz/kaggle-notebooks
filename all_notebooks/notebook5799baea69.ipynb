# %%
import pandas as pd

chicago = pd.read_csv("../input/crimes-in-chicago/Chicago_Crimes_2012_to_2017.csv")
sf = pd.read_csv("../input/san-francisco-crime-classification/train.csv")

# %%
chicago.groupby("Primary Type")["Primary Type"].count().sort_values(ascending=False)

# %%
sf.groupby("Category")["Category"].count().sort_values(ascending=False)
