# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('../input/kemdikbud-bos-laporan-penyaluran/kemdikbud-bos-laporan-penyaluran.csv')
df

# %%
print(df['tahun'].unique())
print(df['Jenjang'].unique())
print(df['tahap'].unique())
print(df['jenis'].unique())

# %%
df_pivot = pd.pivot_table(df.loc[(df['tahun']==2021)&(df['tahap']==1)],values=['Dana BOS Salur','Jumlah Siswa'], index=['Provinsi'
                                                                             , 'Kabupaten/Kota'
                                                                            ], aggfunc=np.sum)
# df_pivot = df_pivot.sort_values(by='Dana BOS Salur', ascending=False)
df_pivot = df_pivot.nlargest(10,'Dana BOS Salur')
# df_pivot = df_pivot.nsmallest(10,'Dana BOS Salur')
df_pivot

# %%
df_pivot.plot.bar(y='Dana BOS Salur', color=[colors[i] for i in df['group']])
