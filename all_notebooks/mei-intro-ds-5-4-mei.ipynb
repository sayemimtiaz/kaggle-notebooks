# %% [markdown]
# # MEI Introduction to Data Science
# # Lesson 5 - Activity 2 (MEI)
# This activity is an opportunity to practise the methods covered in this lesson on the MEI large data set (4).
#
# You used the following code to produce scatters diagrams in activity 1:
#
# `# Plot a scatter diagram
# cars_data.plot.scatter(x='EngineSize', y='CO2')
# plt.show()`
#
# `# plot CO2 against mass with the colour determined by the engine size
# cars_data.plot.scatter(x='Mass', y='CO2', c='EngineSize', figsize=(10,10), sharex=False)
# plt.show()`
#
# `# plot CO2 against mass with the size determined by the engine size
# cars_data.plot.scatter(x='Mass', y='CO2', s=cars_data['EngineSize']/50, figsize=(10,10))
# plt.show()`
#
# `# create a mapping for the colours
# cmap = {'Petrol': 'red', 'Diesel': 'blue'}'
# '# plot the scatter diagram with the colour set by the mapping
# cars_data.plot.scatter(x='Mass', y='CO2', figsize=(10,10),  c=[cmap.get(c, 'black') for c in cars_data.PropulsionTypeId])
# plt.show()`

# %% [markdown]
# ## Problem
# > Which of the factors in the dataset are linked to higher life expectancy?
#
# You could explore the following fields and their impact on the life expectancy for 2010:
# * birth rate per 1000
# * unemployment
# * GDP per capita
# * physician density
# * Health expenditure

# %% [markdown]
# ## Getting the data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# importing the data
country_data=pd.read_csv('../input/meilds4/mei-lds-4.csv')

# inspecting the dataset to check that it has imported correctly
country_data.head()

# %% [markdown]
# ## Exploring the data

# %%
# check the datatypes

# use describe and/or boxplots for any fields you are going to investigate and filter out or replace any unusable values

# %% [markdown]
# ## Analysing the data

# %%
# create scatter diagrams for various fields plotted against systolic blood pressure

# create scatter diagrams for various fields plotted against systolic blood pressure with a further field controlling the size or colour

# %% [markdown]
# ## Communicating the result

# %%
## communicate the result
