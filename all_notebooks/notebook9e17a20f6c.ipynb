# %%
import numba as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as mosn

# %%
df=pd.read_csv("../input/phishing-detection-dataset/fixed_values_ds.csv")

# %%
df.head()

# %%
df.info()

# %%
df.describe()

# %%
mosn.bar(df)

# %%
df.shape

# %%
sns.countplot(x="length_of_url", data=df)

# %%
sns.countplot(x="result", data=df)

# %%
plt.figure(figsize=(10,10))
sns.barplot(data=df , x= "https",y="result")

# %%
sns.lineplot(x= "length_of_url",y="result",data=df ,markers='o')
