# %%
import pandas as pd
import numpy as np
import seaborn as sns
import missingno as miso
import matplotlib.pyplot as plt
import os

# %%
data1=pd.read_csv("../input/tamil-nadu-2021-state-elections/Tamil_Nadu_State_Elections_2021_Alliance.csv")

# %%
data2=pd.read_csv("../input/tamil-nadu-2021-state-elections/Tamil_Nadu_State_Elections_2021_Constituency_Metadata.csv")

# %%
data3=pd.read_csv("../input/tamil-nadu-2021-state-elections/Tamil_Nadu_State_Elections_2021_Details.csv")

# %%
data1.head()

# %%
miso.bar(data1)

# %%
data1['PARTY_FULL_NAME'].value_counts()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x="ALLIANCE_NAME", data=data1)

# %%
plt.figure(figsize=(30,10))
sns.countplot(x="PARTY_ABBR", data=data1)

# %%
plt.figure(figsize=(20,10))
sns.lineplot(data=data1 , x='PARTY_FULL_NAME',y='Total_Constituency')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=data1 , x='ALLIANCE_NAME', y='Total_Constituency')

# %%
data2.head()

# %%
data2.describe()

# %%
miso.bar(data2)

# %%
data2.dropna()

# %%
data2['State_Name'].value_counts()

# %%
plt.figure(figsize=(20,10))
sns.countplot(x="District", data=data2)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x="Reserved", data=data2)

# %%
plt.figure(figsize=(30,15))
sns.countplot(x="Lok_sabha_constituency", data=data2)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(data=data2 , x='Tot_Constituency_votes_polled',y='Cons_vote_pct')
plt.show()

# %%
plt.figure(figsize=(30,10))
sns.barplot(data=data2 , x='District',y='Cons_vote_pct')
plt.xticks(rotation=90)
plt.show()

# %%
data3.head()

# %%
miso.bar(data3)

# %%
data3.describe()

# %%
data3['Win_Lost_Flag'].value_counts()

# %%
plt.figure(figsize=(30,10))
sns.barplot(data=data3 , x='Party',y='EVM_Votes')
plt.xticks(rotation=90)
plt.show()
