# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sklearn 
import plotly.express as px
import plotly.graph_objects as go
from mpl_toolkits.axes_grid import ImageGrid
plt.style.use("dark_background")
from mpl_toolkits.mplot3d import Axes3D

# %%
df = pd.read_csv("../input/customer-segmentation-tutorial-in-python/Mall_Customers.csv")
df.head()

# %%
sns.heatmap(df.isnull())

# %%
df['CustomerID'] = df['CustomerID'].astype(object)

# %%
df.describe()

# %%
df.info()

# %%
sns.heatmap(df.corr(),annot=True,cmap='viridis')

# %%
px.histogram(df['Age'],title='Age Distribution',template='plotly_dark')

# %%
px.histogram(df['Annual Income (k$)'],title='Annual Income Distribution',template='plotly_dark')

# %%
px.histogram(df['Spending Score (1-100)'],title='Spending Score (1-100)',template='plotly_dark')

# %%
df.head()

# %%
gender = df['Gender'].value_counts().to_frame().reset_index().rename(columns={'index':'Gender','Gender':'Count'})


px.bar(data_frame=gender,x='Gender',y='Count',color='Gender',color_discrete_sequence=['pink','royalblue'],title='Count of Gender',template='plotly_dark',
      text='Count')

# %%
fig = go.Figure(data=go.Scatter(x=df['Age'],
                                y=df['Annual Income (k$)'],
                                mode='markers',
                                marker=dict(
                                size=14,
                                color=df['Annual Income (k$)'], 
                                colorscale='rainbow', 
                                showscale=True),
                               ))

fig.update_layout(title='Age v/s Annual Salary (k$)',xaxis_title='Age',yaxis_title='Annual Income (k$)',template='plotly_dark')
fig.show()

# %%
px.scatter(data_frame=df,x='Age',y='Annual Income (k$)',color='Gender',size='Annual Income (k$)',title='Age v/s Annual Income by Gender',template='plotly_dark',
          color_discrete_sequence=['royalblue','pink'])

# %%
df.head(2)

# %%
fig = go.Figure(data=go.Scatter(x=df['Age'],
                                y=df['Spending Score (1-100)'],
                                mode='markers',
                                marker=dict(
                                size=16,
                                color=df['Spending Score (1-100)'], 
                                colorscale='Viridis', 
                                showscale=True),
                               ))

fig.update_layout(title='Age v/s Spending Score (1-100))',xaxis_title='Age',yaxis_title='Spending Score (1-100)',template='plotly_dark')
fig.show()

# %%
px.scatter(data_frame=df,x='Age',y='Spending Score (1-100)',color='Gender',size='Spending Score (1-100)',title='Age v/s Spending Score (1-100) by Gender',
          color_discrete_sequence=['royalblue','pink'],template='plotly_dark')

# %%
df.head()

# %%
fig = go.Figure(data=go.Scatter(
                x = df['Spending Score (1-100)'],
                y = df['Annual Income (k$)'],
                mode = 'markers',
                marker = dict(size=14,color=df['CustomerID'],
                colorscale='Spectral',
                showscale=True)))

fig.update_layout(title="Spending Score v/s Annual Income by Customer Id",xaxis_title='Spending Score (1-100)',yaxis_title = 'Annual Income (k$)',
                 template='plotly_dark')
fig.show()

# %%
px.scatter(data_frame=df,x='Spending Score (1-100)',y='Annual Income (k$)',color='Gender',size='Annual Income (k$)',
           title='Spending Score (1-100) v/s Annual Income (k$) by Gender',
          color_discrete_sequence=['royalblue','pink'],template='plotly_dark')

# %%
df.head()

# %%
px.scatter_3d(data_frame=df,x='Annual Income (k$)',y='Spending Score (1-100)',z='Age',color='Gender',template='plotly_dark',
             title='3D Scatter plot for KMeans Clusters')

# %%
group = df.groupby('CustomerID')['Spending Score (1-100)'].sum().reset_index().sort_values(by='Spending Score (1-100)',ascending=False).head(10)
group

# %%
fig = go.Figure(data=[go.Pie(labels=group['CustomerID'],
                             values=group['Spending Score (1-100)'])])
fig.update_traces(hoverinfo='label+percent', textinfo='percent', textfont_size=20,
                  marker=dict(line=dict(color='#ffffff', width=2)))

fig.update_layout(title="Top 10 Customers by Spending Score",template='plotly_dark')
fig.show()



# px.pie(data_frame=group,values='Spending Score (1-100)',names='CustomerID',template='plotly_dark',color_discrete_sequence=px.colors.sequential.Greens)

# %%
group = df.groupby('Gender')['Annual Income (k$)'].mean().reset_index().sort_values(by='Annual Income (k$)',ascending=False)
group

# %%
colors = ['royalblue','pink']
fig = go.Figure(data=[go.Pie(labels=group['Gender'],
                             values=group['Annual Income (k$)'],hole=0.3)])
fig.update_traces(hoverinfo='label+percent', textinfo='value', textfont_size=20,
                  marker=dict(colors=colors, line=dict(color='#ffffff', width=2)))

fig.update_layout(title="Gender by Average Income",template='plotly_dark')
fig.show()

# %%
px.box(data_frame=df,x='Gender',y='Annual Income (k$)',points='all',color='Gender',color_discrete_sequence=['royalblue','pink'],template='plotly_dark',
      title="Box Plot for Annual Income (k$) for Gender")

# %%
px.box(data_frame=df,x='Gender',y='Spending Score (1-100)',notched=True,color='Gender',color_discrete_sequence=['royalblue','pink'],template='plotly_dark',
      title="Box Plot for Spending Score (1-100) for Gender")

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Box(
    x=df['Gender'],y=df['Spending Score (1-100)'],
    name='Mean & SD',
    boxmean='sd'
))

fig.update_layout(template='plotly_dark',title="Box Plot for Spending Score v/s Gender")
fig.show()

# %%
df['Age'].describe()

# %%
df['Age Category'] = pd.cut(x=df['Age'], bins=[15,30,45,60,75])

# %%
df.head()

# %%
agecount = df['Age Category'].value_counts().to_frame().reset_index().rename(columns= {"index":"Age Category","Age Category":"Count"})
agecount['Age Category'] = agecount['Age Category'].astype(object)

# %%
agecount

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=agecount,x='Age Category',y='Count')
plt.title("Count of Customers belonging to each age category",size=16)
plt.show()

# %%
mygroup = df.groupby(['Age Category','Gender'])['Annual Income (k$)'].mean().reset_index()
mygroup

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=mygroup,x='Age Category',y='Annual Income (k$)',hue='Gender',palette=['#0066ff','#cc66ff'],edgecolor='black')
plt.title("Average Annual Income (k$) by Gender belonging to each age category",size=14)
plt.show()

# %%
mygroup = df.groupby(['Age Category','Gender'])['Spending Score (1-100)'].mean().reset_index()


plt.figure(figsize=(10,6))
sns.barplot(data=mygroup,x='Age Category',y='Spending Score (1-100)',hue='Gender',palette=['#0066ff','#cc66ff'],edgecolor='black')
plt.title("Average Spending Score (1-100) by Gender belonging to each age category",size=14)
plt.show()

# %% [markdown]
# # KMeans Clustering

# %%
# df.drop(columns=['Age Category'],inplace=True,axis=1)

# from sklearn.preprocessing import LabelEncoder
# enc = LabelEncoder()
# df['Gender'] = enc.fit_transform(df['Gender'])

# %%
df = df[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']]
df.head()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
dfscaled = scaler.fit_transform(df)

# %%
dfscaled[:5]

# %%
from sklearn.cluster import KMeans
sumofsq = {}
for k in range(1,15):
    km = KMeans(n_clusters=k,init='k-means++',max_iter=1000)
    km = km.fit(dfscaled)
    sumofsq[k] = km.inertia_

# %%
plt.figure(figsize=(14,8))
plt.xlabel('Number of Clusters(k)')
plt.ylabel('Sum of Square Distances')
plt.title('Elbow Method For Optimal number of Clusters')
sns.pointplot(x=list(sumofsq.keys()),y=list(sumofsq.values()),color='royalblue')
plt.show()

# %%
kmeansmodel = KMeans(n_clusters=6, init= 'k-means++', max_iter= 1000)
kmeansmodel.fit_transform(dfscaled)

Kmeansdf = df.copy()
Kmeansdf['Cluster_by_KMeans'] = kmeansmodel.labels_
Kmeansdf["Cluster_by_KMeans"] = Kmeansdf["Cluster_by_KMeans"].astype(str)

# %%
px.scatter(data_frame=Kmeansdf,x='Spending Score (1-100)',y='Annual Income (k$)',color='Cluster_by_KMeans',template='plotly_dark',
          title='Spending Score (1-100) v/s Annual Income (k$) by KMeans Clusters')

# %%
Kmeansdf.head()

# %%
px.scatter(data_frame=Kmeansdf,x='Age',y='Annual Income (k$)',color='Cluster_by_KMeans',template='plotly_dark',
          title='Age v/s Annual Income (k$) by KMeans Clusters')

# %%
px.scatter(data_frame=Kmeansdf,x='Age',y='Spending Score (1-100)',color='Cluster_by_KMeans',template='plotly_dark',
          title='Age v/s Spending Score (1-100) by KMeans Clusters')

# %%
sns.countplot(Kmeansdf['Cluster_by_KMeans'])

# %%
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.cm as cm

range_n_clusters = [2, 3, 4, 5, 6,7,8,9,10]
X = dfscaled.copy()

for n_clusters in range_n_clusters:
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)
    ax1.set_xlim([-0.1, 1])
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X)
    silhouette_avg = silhouette_score(X, cluster_labels)
    print("For n_clusters =", n_clusters,"The average silhouette_score is :", silhouette_avg)
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        y_lower = y_upper + 10  

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
    colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
    ax2.scatter(X[:, 0], X[:, 1], marker='.', s=30, lw=0, alpha=0.7,
                c=colors, edgecolor='k')

    centers = clusterer.cluster_centers_
    ax2.scatter(centers[:, 0], centers[:, 1], marker='o',
                c="white", alpha=1, s=200, edgecolor='k')

    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker='$%d$' % i, alpha=1,
                    s=50, edgecolor='k')

    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature space for the 1st feature")
    ax2.set_ylabel("Feature space for the 2nd feature")

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')

plt.show()

# %%
range_n_clusters = [2, 3, 4, 5, 6,7,8,9,10]
silscore = []
X = dfscaled.copy()

for n_clusters in range_n_clusters:
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X)
    silhouette_avg = silhouette_score(X, cluster_labels)
    silscore.append(silhouette_avg)
    print("For n_clusters =", n_clusters,"The average silhouette_score is :", silhouette_avg)
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

# %%
plt.figure(figsize=(14,8))
plt.xlabel('Number of Clusters(k)')
plt.ylabel('Average Silhouette Score')
plt.title('Silhouette Analysis For Optimal number of Clusters')
sns.pointplot(x=range_n_clusters,y=silscore,color='royalblue')
plt.show()

# %% [markdown]
# # Optimal Clusters according to both Elbow method and Silhouette Analysis is 6.

# %%
clustercount = Kmeansdf['Cluster_by_KMeans'].value_counts().to_frame().reset_index().rename(columns={"index":"Cluster","Cluster_by_KMeans":"Count"}).sort_values(by='Cluster',
ascending=True)
clustercount

# %%
# clustercount.set_index("Cluster")

# %%
Kmeansdf.head()

# %%
Kmeansdf.dtypes

# %%
px.scatter_3d(data_frame=Kmeansdf,x='Annual Income (k$)',y='Spending Score (1-100)',z='Age',color='Cluster_by_KMeans',template='plotly_dark',
             title='3D Scatter plot for KMeans Clusters')

# %% [markdown]
# # DBSCAN CLUSTERING

# %%
from sklearn.cluster import DBSCAN

# %%
dfscaled[:5]

# %%
from sklearn.neighbors import NearestNeighbors

neigh = NearestNeighbors()
nbrs = neigh.fit(dfscaled)
distances, indices = nbrs.kneighbors(dfscaled)

# %% [markdown]
# # The optimal value for epsilon will be found at the point of maximum curvature.**

# %%
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.plot(distances)

# %%
clustering = DBSCAN(eps=0.4).fit(dfscaled)
clustering.labels_

# %%
Kmeansdf["DBSCAN_clusters"] = clustering.labels_
Kmeansdf.head()

# %%
Kmeansdf['DBSCAN_clusters'] = Kmeansdf['DBSCAN_clusters'].astype("str")

# %%
px.scatter_3d(data_frame=Kmeansdf,x='Annual Income (k$)',y='Spending Score (1-100)',z='Age',color='DBSCAN_clusters',template='plotly_dark',
             title='3D Scatter plot for DBSCAN Clusters')

# %%
Kmeansdf.head()

# %%
px.scatter(data_frame=Kmeansdf,x='Age',y='Spending Score (1-100)',color='DBSCAN_clusters',template='plotly_dark',
          title='Age v/s Spending Score (1-100) by DBSCAN Clusters')

# %%
px.scatter(data_frame=Kmeansdf,x='Age',y='Annual Income (k$)',color='DBSCAN_clusters',template='plotly_dark',
          title='Age v/s Annual Income (k$) by DBSCAN Clusters')

# %%
px.scatter(data_frame=Kmeansdf,x='Spending Score (1-100)',y='Annual Income (k$)',color='DBSCAN_clusters',template='plotly_dark',
          title='Spending Score (1-100) v/s Annual Income (k$) by DBSCAN Clusters')

# %% [markdown]
# # Affinity Clustering

# %%
from sklearn.cluster import AffinityPropagation
from sklearn import metrics

# %%
af = AffinityPropagation(preference =-50).fit(dfscaled) 
cluster_centers_indices = af.cluster_centers_indices_ 
labels = af.labels_ 
  
n_clusters_ = len(cluster_centers_indices)

print(n_clusters)

# %%
from itertools import cycle 
  
plt.close('all') 
plt.figure(1) 
plt.clf() 
  
colors = cycle('bgrcmykbgrcmykbgrcmykbgrcmyk') 
  
for k, col in zip(range(n_clusters_), colors): 
    class_members = labels == k 
    cluster_center = dfscaled[cluster_centers_indices[k]] 
    plt.plot(dfscaled[class_members, 0], dfscaled[class_members, 1], col + '.') 
    plt.plot(cluster_center[0], cluster_center[1], 'o', 
             markerfacecolor = col, markeredgecolor ='k', 
             markersize = 14) 
  
    for x in dfscaled[class_members]: 
        plt.plot([cluster_center[0], x[0]],  
                 [cluster_center[1], x[1]], col) 
  
plt.title('Estimated number of clusters: % d' % n_clusters_) 
plt.show()
