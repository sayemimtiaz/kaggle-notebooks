# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
import itertools
import re
from operator import itemgetter

nlp = en_core_web_sm.load()

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))
# Any results you write to the current directory are saved as output.
# Out:
# ['hillary-clinton-emails', 'englishnames3']

# %% [markdown]
# # Named Entity Recognition
#
# *Daan van Kooten 10-2018
# *
#
# **This Kernel consists of:**
# 1. A first try to find all NE's in an examplestring from the Clinton Mails using spacy.
# 2. Replace all names and organisation in the body text of the e-mails by 'Name' or 'Organisation'

# %%
data_mail = pd.read_csv('../input/hillary-clinton-emails/Emails.csv', header=0)
data_mail.head(5)
# Out:
#    Id                        ...                                                                    RawText
# 0   1                        ...                          UNCLASSIFIED\nU.S. Department of State\nCase N...
# 1   2                        ...                          UNCLASSIFIED\nU.S. Department of State\nCase N...
# 2   3                        ...                          UNCLASSIFIED\nU.S. Department of State\nCase N...
# 3   4                        ...                          UNCLASSIFIED\nU.S. Department of State\nCase N...
# 4   5                        ...                          B6\nUNCLASSIFIED\nU.S. Department of State\nCa...
#
# [5 rows x 22 columns]

# %% [markdown]
# ## 1. A first try to find all NE's in an examplestring from the Clinton Mails.

# %% [markdown]
# Example sentence from clinton mails:

# %%
BodyText = data_mail.ExtractedBodyText
ex = BodyText[1398]
print(ex)
# Out:
# Dear Secretary Clinton,
# I am seeing Michelle on Tuesday at 3 pm. Thank you very much for making this happen, and I will let you know how the
# meeting goes.
# Congratulations on all the glowing first 100 days reviews. Hope your testimony yesterday went well. Mine is attached,
# fyi.
# All best, and thank you again, Jackie
# Jacqueline Newmyer
# President, Long Term Strategy Group
# 12 Eliot St., Cambridge, MA 02138
# B6
# 617-661-1626 (fax)
# www.ltstrategy.com

# %% [markdown]
# Apply word tokenization and part-of-speech tagging to the sentence.

# %%
doc = nlp(ex)
doc
# Out:
# Dear Secretary Clinton,
# I am seeing Michelle on Tuesday at 3 pm. Thank you very much for making this happen, and I will let you know how the
# meeting goes.
# Congratulations on all the glowing first 100 days reviews. Hope your testimony yesterday went well. Mine is attached,
# fyi.
# All best, and thank you again, Jackie
# Jacqueline Newmyer
# President, Long Term Strategy Group
# 12 Eliot St., Cambridge, MA 02138
# B6
# 617-661-1626 (fax)
# www.ltstrategy.com

# %%
print([(X.text, X.label_) for X in doc.ents])
# Out:
# [('Clinton', 'PERSON'), ('Michelle', 'PERSON'), ('Tuesday', 'DATE'), ('3 pm', 'TIME'), ('first 100 days', 'DATE'), ('yesterday', 'DATE'), ('Jackie', 'PERSON'), ('Jacqueline Newmyer', 'PERSON'), ('Long Term Strategy Group', 'ORG'), ('12', 'CARDINAL'), ('Cambridge', 'GPE'), ('02138', 'CARDINAL')]

# %%
displacy.render(nlp(ex), jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">Dear Secretary
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Clinton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,</br>I am seeing
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Michelle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  at
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     3 pm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# . Thank you very much for making this happen, and I will let you know how the</br>meeting goes.</br>Congratulations on all the glowing
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     first 100 days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  reviews. Hope your testimony
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     yesterday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  went well. Mine is attached,</br>fyi.</br>All best, and thank you again,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Jackie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Jacqueline Newmyer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>President,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Long Term Strategy Group
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     12
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  Eliot St.,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Cambridge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , MA
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     02138
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# B6
# 617-661-1626 (fax)
# www.ltstrategy.com</div>

# %%
displacy.render(nlp(ex), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="60bb180393564a44a5fbdc284dbd4134-0" class="displacy" width="10370" height="677.0" direction="ltr" style="max-width: none; height: 677.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Dear</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Secretary</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">Clinton,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">am</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">seeing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">Michelle</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">Tuesday</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">3</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">pm.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">Thank</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">very</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">much</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">making</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">happen,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">will</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">let</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">know</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">how</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="3530">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3530">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">meeting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">NOUN</tspan>
# </text>
#
# <text class="displa

# %% [markdown]
# ## 2.  Remove NER in dataset:
#
# - Remove names and organisations based on Spacy NER
# - Remove names based on large list of common English names
# - Remove all mailaddresses

# %%
def dicReplace(words, replacements, string):
    #string = ex
    #words = entityArray
    #replacements = mailMatch
    if words.size > 0:
        dic_NER = dict(zip(words, replacements))
        rep = dic_NER
        # use these three lines to do the replacement
        rep = dict((re.escape(k), v) for k, v in rep.items())
        pattern = re.compile("|".join(rep.keys()))
        string = pattern.sub(lambda m: rep[re.escape(m.group(0))], string)
        transformedString = pattern.sub(lambda m: rep[re.escape(m.group(0))], string)
    else: transformedString = string
    return(transformedString)

# %%
def NERTransformer(string):
    ent_list = [(X.text, X.label_) for X in nlp(ex).ents]  
    entityArray= np.array([item[1] for item in  ent_list]) 
    wordArray = np.array([item[0] for item in  ent_list])
    poIndex = [(entityArray == 'ORG') | (entityArray == 'PERSON')]
    entityArray2 = entityArray[tuple(poIndex)]
    wordArray2 = wordArray[tuple(poIndex)]
    transformedString= dicReplace(wordArray2, entityArray2, string)
    return(transformedString)

# %%
data_names= pd.read_csv('../input/englishnames3/englishNames.csv', header=0)
data_names['Name'] = ' ' + data_names['Name'].astype(str) + ' ' #add spaces 
data_names['Entity'] = ' ' + data_names['Entity'].astype(str) + ' ' #add spaces 
data_names
# Out:
#                Name    Entity
# 0            Aabha    PERSON
# 1            Aadam    PERSON
# 2            Aaden    PERSON
# 3           Aadhan    PERSON
# 4          Aadhith    PERSON
# 5         Aadhrith    PERSON
# 6           Aadhya    PERSON
# 7          Aadhyaa    PERSON
# 8             Aadi    PERSON
# 9            Aadia    PERSON
# 10           Aadil    PERSON
# 11        Aadirath    PERSON
# 12         Aadrith    PERSON
# 13         Aadvika    PERSON
# 14           Aahil    PERSON
# 15        Aahliyah    PERSON
# 16           Aaida    PERSON
# 17           Aaila    PERSON
# 18          Aailah    PERSON
# 19          Aairah    PERSON
# 20         Aaishah    PERSON
# 21         Aaiylah    PERSON
# 22           Aaiza    PERSON
# 23          Aakifa    PERSON
# 24           Aakin    PERSON
# 25         Aalayah    PERSON
# 26          Aaleen    PERSON
# 27         Aaleyah    PERSON
# 28           Aalia    PERSON
# 29          Aaliya    PERSON
# ...             ...       ...
# 7855        Zinnia    PERSON
# 7856         Zirou    PERSON
# 7857         Zirwa    PERSON
# 7858          Ziva    PERSON
# 7859          Zixi    PERSON
# 7860        Zixian    PERSON
# 7861        Zixuan    PERSON
# 7862           Zoe    PERSON
# 7863      Zoe-Joan    PERSON
# 7864   Zoe-Kirstin    PERSON
# 7865          Zoey    PERSON
# 7866         Zoeya    PERSON
# 7867     Zoey-Jane    PERSON
# 7868         Zofia    PERSON
# 7869          Zoha    PERSON
# 7870        Zohaib    PERSON
# 7871         Zohan    PERSON
# 7872          Zoie    PERSON
# 7873          Zoja    PERSON
# 7874         Zooey    PERSON
# 7875          Zora    PERSON
# 7876         Zosha    PERSON
# 7877         Zosia    PERSON
# 7878          Zoya    PERSON
# 7879         Zoyar    PERSON
# 7880       Zunaira    PERSON
# 7881          Zuri    PERSON
# 7882        Zuriel    PERSON
# 7883       Zuzanna    PERSON
# 7884       Zygmunt    PERSON
#
# [7885 rows x 2 columns]

# %%
def NamesTransformer(string):
    transformedString = dicReplace(data_names['Name'], data_names['Entity'], string)
    return(transformedString)

# %%
def EmailTransformer(string):
    mailMatch = re.findall(r'[\w\.-]+@[\w\.-]+\.\w+', string)
    mailMatch = np.array(mailMatch)
    entityArray = np.repeat('EMAILADDRESS', len(mailMatch))
    transformedString = dicReplace(mailMatch,entityArray, string)
    return(transformedString)

# %%
def anonymous(string):
    stringAno1 = NERTransformer(string)
    stringAno2 = NamesTransformer(stringAno1)
    stringAno3 = EmailTransformer(stringAno2)
    return(stringAno3)

# %%
anonymous(ex)
# Out:
# 'Dear Secretary PERSON,\nI am seeing PERSON on Tuesday at 3 pm. Thank you very much for making this happen, and I will let you know how the\nmeeting goes.\nCongratulations on all the glowing first 100 days reviews. PERSON your testimony yesterday went well. Mine is attached,\nfyi.\nAll best, and thank you again, PERSON\nPERSON\nPresident, ORG\n12 PERSON St., Cambridge, MA 02138\nB6\n617-661-1626 (fax)\nwww.ltstrategy.com'

# %%
#BodyText2 = BodyText[~BodyText.isnull()] #remove nans
#anonymous(BodyText2[2556])
#BodyText2.apply(anonymous)
