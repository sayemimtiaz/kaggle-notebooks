# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from pandas_profiling import ProfileReport

# %%
data=pd.read_csv("../input/the-most-expensive-football-transfers/football_players.csv")

# %%
data.head()

# %%
data.info()

# %%
data.describe()

# %%
sns.heatmap(data.isna())

# %%
plt.figure(figsize=(25,10))
sns.countplot(data['Origin'])

# %%
plt.figure(figsize=(15,7))
sns.countplot(data['From(Country)'])

# %%
plt.figure(figsize=(25,10))
sns.countplot(data['From(Club)'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(data['To(Country)'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(data['Position'])

# %%
plt.style.use("fivethirtyeight")
plt.figure(figsize=(20,7))
sns.lineplot(x='Origin',y='Fee(€ mln)',data=data)
plt.xticks(rotation=90)
plt.show()

# %%
sns.lineplot(x='Position',y='Fee(€ mln)',data=data)

# %%
plt.style.use("ggplot")
fig,axis=plt.subplots(2,2 , figsize=(25,10))
sns.lineplot(x='From(Country)',y='Fee(€ mln)',data=data,ax=axis[0,0])
sns.lineplot(x='To(Country)',y='Fee(€ mln)',data=data,ax=axis[0,1])
sns.lineplot(x='To(Club)',y='Fee(€ mln)',data=data,ax=axis[1,0],)
sns.lineplot(x='From(Club)',y='Fee(€ mln)',data=data,ax=axis[1,1])
plt.xticks(rotation=90)
plt.show()

# %%
plt.style.use("dark_background")
plt.figure(figsize=(15,7))
sns.lineplot(x="Year",y="Fee(€ mln)",data=data)

# %%
plt.style.use("dark_background")
plt.figure(figsize=(15,7))
sns.lineplot(x="Born",y="Fee(€ mln)",data=data)

# %%
plt.style.use("ggplot")
plt.figure(figsize=(20,7))
sns.lineplot(x='Player',y='Fee(€ mln)',data=data)
plt.xticks(rotation=90)
plt.show()

# %%
x=ProfileReport(data)

# %%
x
