# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib
import seaborn as sns
import os
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')



# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
df = pd.read_csv("/kaggle/input/top50spotify2019/top50.csv", encoding='ISO-8859-1')
df.head()

# %% [markdown]
# From what I see, the first column is very not meaningful, so I get rid of it.

# %%
df = df.drop(columns=['Unnamed: 0'])
df.shape

# %% [markdown]
# If the end goal is to be 'popular', then why not try to understand if we can catch a connection between features from this tiny data. For this purpose a scatter plot, or a correlation plot could help. Instead of doing this one by one, I will do for all and then focus on pairs if necessary.

# %%
corr = df.corr()
sb.heatmap(corr)

# %%
sns.pairplot(df, kind='reg')

# %% [markdown]
# It seems there is, although weak, a connection between "Speechiness." and "Beats.Per.Minute". I think this makes sense. Higher the beat -> more of rapping. There is also a correlation between "Loudness..dB.." and "Energy". I think some of these features are hard to understand, what they actually mean. Anyways. Now I am curious if Speechiness and BeatsPerMinute are really about genre of the song.

# %%
sns.lmplot( x="Beats.Per.Minute", y="Speechiness.", data=df, fit_reg=False, hue='Genre', legend=True)
autopct=('%1.1f%%')

# %% [markdown]
# Actually, not so many hiphop/rap songs in the df, so this theory of mine is inconclusive.

# %%
labels=df["Genre"].value_counts().index
sizes=df["Genre"].value_counts().values
plt.figure(figsize = (10,10))
plt.pie(sizes, labels=labels)
autopct=('%1.1f%%')

# %% [markdown]
# I will stop here as I do not see enough data worth digging further. Im happy to do more if anybody has a reasonable direction to dig.
