# %% [markdown]
# # Predicting Myers-Briggs-Type-Indicator with RNN

# %% [markdown]
# ## [Dataset](https://www.kaggle.com/datasnaek/mbti-type)
# The Myers Briggs Type Indicator (or MBTI for short) is a personality type system that <br>
# divides everyone into 16 distinct personality types across 4 axis:<br>
#
# >      Introversion (I) – Extroversion (E)
# >      Intuition (N) – Sensing (S)
# >      Thinking (T) – Feeling (F)
# >      Judging (J) – Perceiving (P)

# %% [markdown]
# ## Repro [Github](https://github.com/ianscottknight/Predicting-Myers-Briggs-Type-Indicator-with-Recurrent-Neural-Networks)

# %%
#!git clone https://github.com/ianscottknight/Predicting-Myers-Briggs-Type-Indicator-with-Recurrent-Neural-Networks
# !git clone https://github.com/rkuo2000/Predicting-Myers-Briggs-Type-Indicator-with-Recurrent-Neural-Networks
# %cd Predicting-Myers-Briggs-Type-Indicator-with-Recurrent-Neural-Networks

# %% [markdown]
# ## Prepare Dataset

# %% [markdown]
# ### seperate clean and unclean data

# %%
# !python separate_clean_and_unclean.py

# %% [markdown]
# ### make training dataset

# %%
# !python make_training_set.py

# %% [markdown]
# ### make test dataset

# %%
# !python make_test_set.py

# %% [markdown]
# ## Train Model

# %%
# !python rnn.py

# %% [markdown]
# ## Evaluate Model

# %%
# !python average_prob_predictor.py

# %% [markdown]
# ## Predict Trump's Tweets

# %%
# !cp "trump prediction"/trumptweets.csv .

# %%
# !python "trump prediction"/predictor.py
