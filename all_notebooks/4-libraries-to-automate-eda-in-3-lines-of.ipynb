# %% [markdown]
# <h1 style="font-family:verdana;"> <center>🔍 4 Libraries to Automate Exploratory Data Analysis : A Little Demo 📊</center> </h1>
# <p><center style="color:#159364; font-family:cursive; font-size:18px">Sometimes we search for the right piece of dataset or (maybe hundreds of datasets!) and we just wanna look at some of the characteristics of the dataset. These four libraries can come really handy on this kind of occasions.</center></p>
#
# ***

# %% [markdown]
# <h2 style="font-family:verdana;"> <left> Install the Libraries and Dependencies </center> </h2>

# %%
# !pip install dataprep
# !pip install sweetviz
# !pip install autoviz
# !pip install xlrd
# !pip install pandas-profiling

# %% [markdown]
# <img src= "https://warehouse-camo.ingress.cmh1.psfhosted.org/0fabcfe7686849b102fbe784f9e6313ec2543ce0/68747470733a2f2f6769746875622e636f6d2f7366752d64622f64617461707265702f7261772f646576656c6f702f6173736574732f6c6f676f2e706e67" alt ="Titanic" style='width: 600px;'>

# %%
from dataprep.eda import create_report
import pandas as pd

df = pd.read_csv("../input/los-angeles-crime-data-20102020/Crime_Data_from_2020_to_Present.csv")
create_report(df)

# %% [markdown]
# <img src= "https://sweetviz.fbdesignpro.com/uploads/default/original/1X/d9d7b9c937a88efc6bf0b725d31ba516146a4875.png" alt ="Titanic" style='width: 600px;'>

# %%
import sweetviz as sv

# EDA using Sweetviz
sweet_report = sv.analyze(pd.read_csv("../input/los-angeles-crime-data-20102020/Crime_Data_from_2020_to_Present.csv"))

# Shohwing the results
sweet_report.show_notebook(w="100%", h="full")

# %% [markdown]
# <img src= "https://raw.githubusercontent.com/AutoViML/AutoViz/master/logo.png" alt ="Titanic" style='width: 500px;'>

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
df_viz = AV.AutoViz('../input/los-angeles-crime-data-20102020/Crime_Data_from_2010_to_2019.csv')

# %% [markdown]
# <img src= "https://camo.githubusercontent.com/8a45c0936d6113b12b7b32942f448270eda8f714665ba8629f36c291f0ccd5fd/68747470733a2f2f70616e6461732d70726f66696c696e672e6769746875622e696f2f70616e6461732d70726f66696c696e672f646f63732f6173736574732f6c6f676f5f6865616465722e706e67" alt ="Titanic" style='width: 500px;'>

# %%
# importing required packages
import pandas_profiling

#importing the data
df = pd.read_csv('../input/los-angeles-crime-data-20102020/Crime_Data_from_2020_to_Present.csv')

#descriptive statistics
pandas_profiling.ProfileReport(df)

# %% [markdown]
#  <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#159364;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.8px">
#         <p style="padding: 10px;
#               color:white;">
#            References!
#         </p>
#     </div>
#
#  *A lot of thanks to the authors of these packages to make our lives easier when its needed!*
#
# * [dataprep 0.3.0](https://pypi.org/project/dataprep/)
# * [autoviz 0.0.81](https://pypi.org/project/autoviz/#usage)
# * [sweetviz 2.1.2](https://pypi.org/project/sweetviz/)
# * [pandas-profiling 3.0.0](https://pypi.org/project/pandas-profiling/)
#
# <center style="font-family:cursive; font-size:18px; color:#159364;">Please let me know what you think about this notebook & upvote if you like it! -- <b>THANKS</b> a bunch for Looking! 😊</center>
