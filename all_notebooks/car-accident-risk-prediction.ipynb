# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('../input/car-risk-analysis/car.csv')

# %%
df

# %%
##Now handle the null value
df['Experience'].median()

# %%
df['Experience']=df['Experience'].fillna(5)

# %%
df

# %%
##Train The Model

##Create Linear Regression Object

lg=LinearRegression()

# %%
lg

# %%
##Fit the model to train

df

# %%
lg.fit(df[['Speed','Car_age','Experience']],df.Risk)

# %%
result=lg.predict([[120,2,2]])

# %%
print("Car risk is" ,result,"%")

# %%
#Now check to manually if the model properly work or not
#Risk=m*Speed+m*Car_age+m*Experience+C

lg.coef_

# %%
lg.intercept_

# %%
 0.33059217*120+2* 1.61053246-6.20772074*2+33.410000910435905

# %%
##Boom! Model Work Perfectly
