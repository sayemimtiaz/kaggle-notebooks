# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as slt
from matplotlib import pyplot as  plt


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input/'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # **READNING DATA BASE **

# %%
var1=pd.read_csv("/kaggle/input/students-performance-in-exams/StudentsPerformance.csv")
var1.head()

# %% [markdown]
# **FIND THE SHAPE OF THE DATA SET **

# %%
var1.shape

# %% [markdown]
# **VIEW LAST RECOREDS**

# %%
var1.tail()

# %% [markdown]
# **DESCRIBE THE DATA  IN STATICAL FORMAT USING describe method **   find the mean ,median,mode,std,count,max valeus

# %%
var1.describe()

# %% [markdown]
# **VIEW THE COLUMNS** find the all colum name

# %%
var1.columns

# %% [markdown]
# find the all unique values and find the total unique values  using unique function

# %%
var1.nunique()

# %% [markdown]
# and analyis the data set and find the unique value  gender 2 unique value ,race 5 unique value,parental level of education6 unique values ,lunch 2 unique values ,test prepartation course 2 unique values,math score 81 unique values,readding unique 72 values ,writing score 77

# %% [markdown]
# find the unique values in particulaer colum

# %%
var1["gender"].unique()

# %%
var1["race/ethnicity"].unique()

# %%
var1["parental level of education"].unique()

# %%
var1["lunch"].unique()

# %%
var1["test preparation course"].unique()

# %%
var1["math score"].unique()

# %%
var1["reading score"].unique()

# %%
var1["writing score"].unique()

# %% [markdown]
# **DATA CLEANING**

# %%
var1.isnull().sum()

# %% [markdown]
# here is a zero  null value

# %% [markdown]
# after drop a catogrical colum

# %%
var2=var1.drop(["race/ethnicity","parental level of education"],axis=1)
var2.head()

# %% [markdown]
# find the corelation of our data set

# %%
var3=var1.corr()

# %%
plt.figure(figsize=(16,7))
slt.heatmap(var3,xticklabels=var3.columns,yticklabels=var3.columns,annot=True)

# %% [markdown]
# define pair plot

# %%
slt.pairplot(var1)
plt.figure(figsize=(12,9))

# %% [markdown]
# find  the reletationn  beetween maths score and reading score

# %%
slt.relplot(x="math score",y="reading score",hue="gender",data=var1)

# %% [markdown]
# create a histogram

# %%
slt.distplot(var1["writing score"]) 
plt.figure(figsize=(14,9))

# %% [markdown]
# create a scatter plot

# %%
slt.scatterplot(x="gender",y="math score",data=var1)

# %%
slt.scatterplot(x="lunch",y="math score",data=var1)

# %%
slt.scatterplot(x="test preparation course",y="math score",data=var1)

# %% [markdown]
# create a pie  chart

# %% [markdown]
# bcreate a bar plot

# %%
x=var1["math score"]
y=var1["writing score"]
x1=list(x)
x2=list(y)
plt.bar(x1,x2,label="gender",width=0.9)
plt.show()
