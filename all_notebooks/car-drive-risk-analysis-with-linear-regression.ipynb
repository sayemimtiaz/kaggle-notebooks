# %% [markdown]
# # Importing library

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

# %% [markdown]
# # Importing the dataset

# %%
df = pd.read_csv('../input/car-drive-risk-analysis-multiple-dataset/Car_Drive_Analysis_multiple_data.csv')

# %%
df

# %% [markdown]
# # Check How many null have in dataset

# %%
df.isnull().any()

# %%
df.isnull().sum()

# %%
df.experience

# %% [markdown]
# # Fill null data

# %%
df.experience.mean()

# %%
exp_fit = df.experience.median( )
exp_fit

# %%
df.experience = df.experience.fillna(exp_fit)

# %%
df.experience

# %% [markdown]
# # New dataset

# %%
df

# %%
df.shape

# %% [markdown]
# # Separate dependent and independent variable

# %%
x =df[['speed','car_age','experience']]
y=df['risk']

# %%
x

# %%
y

# %% [markdown]
# # Create object of LinearRegression

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[['speed','car_age','experience']],df.risk)

# %% [markdown]
# # Predict risk for random value

# %%
reg.predict([[160,10,5]])

# %% [markdown]
# # Calculate Coefficient

# %%
reg.coef_

# %% [markdown]
# # Calculate Intercept

# %%
reg.intercept_

# %% [markdown]
# # Test with Linear Formula y = mx + c

# %%
#y = (m1*speed +m2*car_age + m3*experience) + c(coefficient)
y = (0.33059217*160 +1.61053246*10 +5*-6.20772074) + 33.4100009104359
y
