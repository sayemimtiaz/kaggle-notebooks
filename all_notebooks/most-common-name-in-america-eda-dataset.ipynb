# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
adjusted_name_combinations_matrix = pd.read_csv('/kaggle/input/most-common-name-in-america/adjusted-name-combinations-matrix.csv')
adjusted_name_combinations_list = pd.read_csv('/kaggle/input/most-common-name-in-america/adjusted-name-combinations-list.csv')
independent_name_combinations_by_pop = pd.read_csv('/kaggle/input/most-common-name-in-america/independent-name-combinations-by-pop.csv')
new_top_firstNames = pd.read_csv('/kaggle/input/most-common-name-in-america/new-top-firstNames.csv')
aging_curve = pd.read_csv('/kaggle/input/most-common-name-in-america/aging-curve.csv')
adjustments = pd.read_csv('/kaggle/input/most-common-name-in-america/adjustments.csv')
new_top_surnames = pd.read_csv('/kaggle/input/most-common-name-in-america/new-top-surnames.csv')

# %%
adjusted_name_combinations_matrix.head()

# %%
adjusted_name_combinations_list.head()

# %%
independent_name_combinations_by_pop.head()

# %%
new_top_firstNames.head()

# %%
aging_curve.head()

# %%
adjustments.head()

# %%
new_top_surnames.head()

# %%
adjusted_name_combinations_matrix.describe()

# %%
adjusted_name_combinations_list.describe()

# %%
independent_name_combinations_by_pop.describe()

# %%
new_top_firstNames.describe()

# %%
aging_curve.describe()

# %%
adjustments.describe()

# %%
new_top_surnames.describe()
