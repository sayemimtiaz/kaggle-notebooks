# %%
import pandas as pd

# %%
df=pd.read_csv('../input/data-science-day1-titanic/DSB_Day1_Titanic_train.csv',usecols=['Sex'])

# %%
df.head()

# %%
pd.get_dummies(df,drop_first=True).head()

# %%
df=pd.read_csv('../input/data-science-day1-titanic/DSB_Day1_Titanic_train.csv',usecols=['Embarked'])

# %%
df['Embarked'].unique()

# %%
df.dropna(inplace=True)

# %%
pd.get_dummies(df,drop_first=True).head()

# %%
df=pd.read_csv('../input/mercedesbenz-greener-manufacturing/train.csv',usecols=["X0","X1","X2","X3","X4","X5","X6"])

# %%
df.head()

# %%
for i in df.columns:
    print(len(df[i].unique()))

# %%
df.X1.value_counts().sort_values(ascending=False).head(10)

# %%
lst_10=df.X1.value_counts().sort_values(ascending=False).head(10).index
lst_10=list(lst_10)

# %%
lst_10

# %%
import numpy as np
for categories in lst_10:
    df[categories]=np.where(df['X1']==categories,1,0)

# %%
lst_10.append('X1')

# %%
df[lst_10]

# %% [markdown]
# # Ordinal Encoding

# %%
df=pd.read_csv('../input/data-science-day1-titanic/DSB_Day1_Titanic_train.csv', usecols=['Cabin','Survived'])
df.head()

# %%
df['Cabin'].fillna('Missing',inplace=True)

# %%
df['Cabin']=df['Cabin'].astype(str).str[0]

# %%
df.head()

# %%
df.Cabin.unique()

# %%
df.groupby(['Cabin'])['Survived'].mean()

# %%
df.groupby(['Cabin'])['Survived'].mean().sort_values().index

# %%
ordinal_labels=df.groupby(['Cabin'])['Survived'].mean().sort_values().index
ordinal_labels

# %%
enumerate(ordinal_labels,0)

# %%
ordinal_labels2={k:i for i,k in enumerate(ordinal_labels,0)}
ordinal_labels2

# %%
df['Cabin_ordinal_labels']=df['Cabin'].map(ordinal_labels2)
df.head()
