# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
Students = ['Alice', 'Jack', 'Molly']
pd.Series(Students)

# %%
numbers = [1,2,3]
pd.Series(numbers)

# %%
Students = ['Alice', 'Jack', None]
pd.Series(Students)

# %%
numbers = [1,2,None]
pd.Series(numbers)

# %%
np.nan == None

# %%
np.nan == np.nan

# %%
np.isnan(np.nan)

# %%
students_score = {'Alice' : 'physics',
                 'jack' : 'chemistry',
                 'molly' : 'english'}
s = pd.Series(students_score)
s

# %%
s.index

# %%
students = [('Alice','Brown'), ('Jack','White'),('Molly','Green')]
pd.Series(students)

# %%
s = pd.Series(['physics','chemistry','english'], index = ['Alice','Jack','Molly'])
s

# %%
students_score = {'Alice' : 'physics',
                 'Jack' : 'chemistry',
                 'Molly' : 'english'}
pd.Series(students_score, index = ['Alice','Molly','Sam'])

# %%
students_classes = {'Alice' : 'physics',
                 'Jack' : 'chemistry',
                 'Molly' : 'english',
                   'Sam' : 'math'}
s = pd.Series(students_classes)
s

# %%
s.iloc[3]

# %%
s.loc['Molly']

# %%
s[3]

# %%
s['Molly']

# %%
a = {'Sushil':'Narayan, More'}

# %%
s

# %%
a

# %%
pd.Series(a)

# %%
class_code = {99 : 'Physics',
             100 : 'Chemistry',
             101 : 'English',
             102 : 'History'}
s = pd.Series(class_code)

# %%
s.iloc[0]

# %%
s.loc[99]

# %%
grades = pd.Series([90, 80, 70, 60])
total = 0
for grade in grades:
    total += grade
print(total/len(grades))

# %%
total = np.sum(grades)
print(total/len(grades))

# %%
numbers = pd.Series(np.random.randint(0, 1000, 10000))
numbers.head()

# %%
len(numbers)

# %%
# %%timeit -n 100
total = 0
for number in numbers:
    total+=number
total/len(numbers)

# %%
# %%timeit -n 100
total = np.sum(numbers)
total/len(numbers)

# %%
numbers.head()

# %%
numbers+=2
numbers.head()

# %%
# %%timeit -n 10
s = pd.Series(np.random.randint(0,1000,1000))
for label, value in s.iteritems():
    s.loc[label] = value+2

# %%
# %%timeit -n 10
s = pd.Series(np.random.randint(0,1000,1000))
s+=2

# %%
s = pd.Series([1, 2, 3])
s.loc['History'] = 102
s

# %%
record1 = pd.Series({'Name' : 'Alice',
                    'Class' : 'Physics',
                    'Score' : 85} )
record2 = pd.Series({'Name' : 'Jack',
                    'Class' : 'Chemistry',
                    'Score' : 82} )
record3 = pd.Series({'Name' : 'Helen',
                    'Class' : 'Biology',
                    'Score' : 98} )

# %%
df = pd.DataFrame([record1, record2, record3], index = ['School1','School2','School1'])
df

# %%
students = [{'Name' : 'Alice',
             'Class' : 'Physics',
             'Score' : 85},
            {'Name' : 'Jack',
             'Class' : 'Chemistry',
             'Score' : 82},
            {'Name' : 'Helen',
             'Class' : 'Biology',
             'Score' : 98}]
df = pd.DataFrame(students, index = ['School1','School2','School1'])

# %%
df

# %%
df.loc['School2']

# %%
type(df.loc['School2'])

# %%
df.iloc[0,1]

# %%
df.T

# %%
df.T.loc['Name']

# %%
df['Name']

# %%
df.loc['School1']['Name']

# %%
print(type(df.loc['School1']['Name']))
print(type(df.loc['School1']))

# %%
df.loc[:,['Name', 'Score']]

# %%
# !cat datasets/Admissions_predict.csv

# %%
import pandas as pd

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv('/kaggle/input/admission-prediction-data/Admission_Predict.csv', index_col = 'Serial No.')

# %%
df

# %%
# !cat /kaggle/input/admission-prediction-data/Admission_Predict.csv

# %%
df.head()

# %%
new_df = df.rename(columns = {'GRE Score':'GRE Score', 'TOEFL Score':'TOEFL Score', 'University Rating':'University Rating', 'SOP':'Statement of Purpose', 'LOR ':'Letter of Recommendation', 'CGPA':'CGPA',
       'Research':'Research', 'Chance of Admit ':'Chance of Admit '})
new_df.head()

# %%
df.columns

# %%
cols = list(new_df.columns)

# %%
df

# %%
admist_mask = df['Chance of Admit '] > 0.7

# %%
admist_mask

# %%
df.where(admist_mask).head()

# %%
df.where(admist_mask).dropna().head()

# %%
df[df['Chance of Admit '] > 0.7].head()

# %%
df['GRE Score'].head()

# %%
df[['GRE Score','TOEFL Score']].head()

# %%
df[(df['Chance of Admit '] > 0.7)].head()

# %%
df[(df['GRE Score']) >320 & (df['Chance of Admit '] > 0.7)].head()

# %%
df[(df['GRE Score'].gt(320)) & (df['Chance of Admit '].lt(0.7))].head()

# %% [markdown]
# # Hello World !!!

# %%
df.head()

# %%
df["Serial Number"] = df.index

# %%
df = df.set_index('Chance of Admit ')

# %%
df.head()

# %%
df = df.reset_index()

# %%
df.head()

# %%
census = pd.read_csv('/kaggle/input/census/census.csv')
census.head()

# %%
census['SUMLEV'].unique()

# %%
census = census[census['SUMLEV'] ==50]
census.head()

# %%
list(census.columns)

# %%
columns_to_keep = ['STNAME', 'CTYNAME', 'CENSUS2010POP', 'ESTIMATESBASE2010',
                   'POPESTIMATE2010', 'POPESTIMATE2011', 'POPESTIMATE2012', 
                   'POPESTIMATE2013', 'POPESTIMATE2014', 'POPESTIMATE2015',
                   'BIRTHS2010', 'BIRTHS2011', 'BIRTHS2012', 'BIRTHS2013', 'BIRTHS2014',
                   'BIRTHS2015']

# %%
df = census[columns_to_keep]
df.head()

# %%
df = df.set_index(['STNAME','CTYNAME'])
df.head()

# %%
df.loc[[('Tennessee', 'Shelby County'),
        ('New Jersey', 'Hudson County')]].T

# %%
df = pd.read_csv('/kaggle/input/log-data/log.csv')
df.head()

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv('/kaggle/input/class-grades/class_grades.csv')

# %%
df.head()

# %%
mask = df.isnull()
mask.head()

# %%
df.dropna().head(10)

# %%
df.fillna(0, inplace = True)

# %%
df.head(10)

# %%
df = pd.read_csv('/kaggle/input/log-data/log.csv')
df

# %%
df = df.set_index(['time', 'user'])
df

# %%
df = df.fillna(method = 'ffill')
df.head()

# %%
df = pd.read_csv('/kaggle/input/presidents/presidents.csv')

# %%
df.head()

# %%
df['First'] = df['President']

# %%
df['First'] = df['First'].replace("[ ].*", "", regex = True)

# %%
del(df['First'])

# %%
def splitname(row):
    row['First'] = row['President'].split(' ')[0]
    row['Last'] = row ['President'].split(' ')[-1]
    return row

# %%
df = df.apply(splitname, axis = 'columns')
df.head()

# %%
df.head()

# %%
df['First'] = df['President']

# %%
del(df['First'])

# %% [raw]
# pattern = '(^[\w]

# %%
pattern = "(^[\w]*)(?:.* )([\w]*$)"

# %%
df['President'].str.extract(pattern).head()

# %%
pattern = "(?P<First>^[\w]*)(?:.* )(?P<Last>[\w]*$)"

# %%
names = df["President"].str.extract(pattern).head()
names

# %%
df['First'] = names['First']
df["Last"] = names["Last"]
df.head()

# %%
df["Born"] = df["Born"].str.extract("([\w]{3} [\w]{1,2}, [\w]{4})")
df["Born"].head()

# %%
df["Born"] = pd.to_datetime(df["Born"])
df["Born"].head()

# %%
import pandas as pd
import numpy as np
import timeit

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv('/kaggle/input/census/census.csv')
df.head()

# %%
(df.where(df['SUMLEV'] == 50)
     .dropna()
     .set_index(['STNAME','CTYNAME'])
     .rename(columns = {"CENSUS2010POP" : "CENSUS 2010 POP"}))

# %%
df.head()

# %%
States = sorted(list(df['STNAME'].unique()))

# %%
for i in sorted((list(df.REGION.unique()))):
    print((list(df.where(df['REGION'] == i)
     .dropna()
     .STNAME.unique())))

# %%
sorted((list(df.REGION.unique())))

# %%
df = df[df['SUMLEV'] == 50]
df.head()

# %%
# %%timeit -n 3

for state in df['STNAME'].unique():
    avg = np.average(df.where(df['STNAME'] == state).dropna()['CENSUS2010POP'])
    
    print('Counties in state '+state+' have an average of '+str(avg))

# %%
# %%timeit -n 3

for group, frame in df.groupby('STNAME'):
    
    avg = np.average(frame['CENSUS2010POP'])
    
    print('Counties in state '+group+' have an average of '+str(avg))

# %%
df = df.set_index('STNAME')

def set_batch_number(item):
    if item[0] < 'M':
        return 0
    if item[0] < "Q":
        return 1
    return 2

for group, frame, in df.groupby(set_batch_number):
    print('There are '+str(len(frame))+' records in group '+str(group)+' for processing')

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv('/kaggle/input/boston/listings.csv')

# %%
df.head()

# %%
(sorted(list(df.columns)))

# %%
df = df.set_index(['cancellation_policy', 'review_scores_value'])
df.head()

# %%
for group, frame in df.groupby(level = (0,1)):
    print(group)

# %%
def grouping_fun(item):
    if item[1] == 10.0:
        return (item[0], '10,0')
    else:
        return (item[0], 'not 10.0')
for group, frame in df.groupby(by = grouping_fun):
    print(group)

# %%
df.head()

# %%
df= df.reset_index()

# %%
df.head()

# %%
import numpy as np
df.groupby('cancellation_policy').agg({'review_scores_value' : np.average})

# %%
df.groupby('cancellation_policy').agg({'review_scores_value' : np.nanmean})

# %%
df.groupby('cancellation_policy').agg({'review_scores_value' : (np.nanmean, np.nanstd), 'reviews_per_month' : np.nanmean})

# %% [markdown]
# # Transformation

# %%
cols = ['cancellation_policy', 'review_scores_value']
transform_df = df[cols].groupby('cancellation_policy').transform(np.nanmean)
transform_df.head()

# %%
transform_df.rename({'review_scores_value' : 'mean_review_score'}, axis = 'columns', inplace = True)
df = df.merge(transform_df, left_index= True, right_index= True)
df.head()

# %%
df['mean_diff'] = np.absolute(df['review_scores_value'] - df['mean_review_score'])
df.head()

# %% [markdown]
# # Filtering

# %%
df.groupby('cancellation_policy').filter(lambda x : np.nanmean(x['review_scores_value'])>9.2)

# %% [markdown]
# # Applying

# %%
df = pd.read_csv('/kaggle/input/boston/listings.csv')
df.head()

# %%
df = df[cols]

# %%
df.head()

# %%
def calc_mean_review_scores(group):
    avg=np.nanmean(group['review_scores_value'])
    group['review_scores_value'] = np.abs(avg-group['review_scores_value'])
    return group

df.groupby('cancellation_policy').apply(calc_mean_review_scores).head()

# %%
import numpy as np
import pandas as pd
from scipy import stats

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv('/kaggle/input/grades/grades.csv')
df.head()

# %%
print('there are {} rows and {} columns'.format(df.shape[0], df.shape[1]))

# %%
early_finishers = df[pd.to_datetime(df['assignment1_submission']) < '2016']
early_finishers.head()

# %%
late_finishers = df[~df.index.isin(early_finishers.index)]
late_finishers.head()

# %%
print(early_finishers['assignment1_grade'].mean())
print(late_finishers['assignment1_grade'].mean())

# %%
from scipy.stats import ttest_ind
ttest_ind(early_finishers['assignment1_grade'], late_finishers['assignment1_grade'])

# %%
print(ttest_ind(early_finishers['assignment2_grade'], late_finishers['assignment2_grade']))
print(ttest_ind(early_finishers['assignment3_grade'], late_finishers['assignment3_grade']))
print(ttest_ind(early_finishers['assignment4_grade'], late_finishers['assignment4_grade']))
print(ttest_ind(early_finishers['assignment5_grade'], late_finishers['assignment5_grade']))
print(ttest_ind(early_finishers['assignment6_grade'], late_finishers['assignment6_grade']))

# %%
df1 = pd.DataFrame([np.random.random(100) for x in range(100)])

# %%
df1

# %%
df2 = pd.DataFrame([np.random.random(100) for x in range(100)])
df2

# %%
def test_columns(alpha = 0.1):
    num_diff = 0
    for col in df1.columns:
        teststat, pval = ttest_ind(df1[col], df2[col])
        if pval <= alpha:
            print('col {} is statitstically significantly different at alpha = {}, pval = {}'.format(col, alpha, pval))
    print('total number different was {}, which is {}%'.format(num_diff, float(num_diff)/len(df1.columns)*100))
test_columns()

# %%
import re
def names():
    simple_string = """Amy is 5 years old, and her sister Mary is 2 years old. 
    Ruth and Peter, their parents, have 3 kids."""

    # YOUR CODE HERE
    return print(re.findall([a-zA-Z], simple_string))
    raise NotImplementedError()

# %%
import re
def names():
    simple_string = """Amy is 5 years old, and her sister Mary is 2 years old. 
    Ruth and Peter, their parents, have 3 kids."""
    words_pattern = '[A-Z][a-z]+'
    return print(re.findall(words_pattern, simple_string))
    raise NotImplementedError()

# %%
assert len(names()) == 4, "There are four names in the simple_string"

# %%
import re
text = "Amy is 5 years old, and her sister Mary is 2 years old. Ruth and Peter, their parents, have 3 kids."

# %%
words_pattern = '[A-Z][a-z]+'

# %%
re.findall(words_pattern, text)

# %%
names()

# %%
import re
def grades():
    with open ("assets/grades.txt", "r") as file:
        grades = file.read()

    # YOUR CODE HERE
    raise NotImplementedError()

# %%
Ronald Mayr: A
Bell Kassulke: B
Jacqueline Rupp: A 
Alexander Zeller: C
Valentina Denk: C 
Simon Loidl: B 
Elias Jovanovic: B 
Stefanie Weninger: A 
Fabian Peer: C 
Hakim Botros: B
Emilie Lorentsen: B
Herman Karlsen: C
Nathalie Delacruz: C
Casey Hartman: C
Lily Walker : A
Gerard Wang: C
Tony Mcdowell: C
Jake Wood: B
Fatemeh Akhtar: B
Kim Weston: B
Nicholas Beatty: A
Kirsten Williams: C
Vaishali Surana: C
Coby Mccormack: C
Yasmin Dar: B
Romy Donnelly: A
Viswamitra Upandhye: B
Kendrick Hilpert: A
Killian Kaufman: B
Elwood Page: B
Mukti Patel: A
Emily Lesch: C
Elodie Booker: B
Jedd Kim: A
Annabel Davies: A
Adnan Chen: B
Jonathan Berg: C
Hank Spinka: B
Agnes Schneider: C
Kimberly Green: A
Lola-Rose Coates: C
Rose Christiansen: C
Shirley Hintz: C
Hannah Bayer: B

# %%
import re
def grades():
    with open ("/kaggle/input/asset-data/New Text Document.txt", "r") as file:
        grades = file.read()

    # YOUR CODE HERE
    raise NotImplementedError()

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
words_pattern = '[A-Z][a-z]+'

# %%
with open ("/kaggle/input/asset-data/New Text Document.txt", "r") as file:
        grades = file.read()

# %%
grades

# %%
words_pattern = ': (B)'
re.findall(words_pattern, grades)

# %%
import re
def logs():
    with open("/kaggle/input/logdata/logdata.txt", "r") as file:
        logdata = file.read()
    
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
with open("/kaggle/input/logdata/logdata.txt", "r") as file:
        logdata = file.read()

# %%
host_pattern = '([\d]+[\.]+[\d]+[\.]+[\d]+[\.]+[\d]+)'
re.findall(host_pattern,logdata)

# %%
txt = """146.204.224.152 - feest6811 [21/Jun/2019:15:45:24 -0700] "POST /incentivize HTTP/1.1" 302 4622"""
#host_pattern = '^([\d]+[\.]+[\d]+[\.]+[\d]+[\.]+[\d]+)'
user_pattern = ' - (.*[A-Za-z]+[\d]+) - (.*) '
dat_pattern = '' 
#print(re.findall(host_pattern,txt))
print(re.findall(user_pattern,txt))
#^[^`~!@#$%^&*()_+={}\[\]|\\:;“’<,>.?๐฿]*$

# %%
import re
#user_pattern = ' - ([A-Za-z]+[\d]+)'
#re.findall(user_pattern,logdata)
#(re.findall('- ([A-Za-z]+[\d]+)', logdata))

# %%
#user_pattern = ' -'+' - '
#(re.findall(user_pattern,logdata))

# %%
s = "ftp://www.somewhere.com/over/the/rainbow/image.jpg"

re.match(r'^(ftp|http)://.*\.(jpg|png)$', s)

# %%
#re.findall(user_pattern,logdata)
l1 = ((re.findall(' - '+'(.*/)'+'.*/', logdata)))

# %%
((re.findall(' - '+'(.*/)', logdata)))

# %%
with open("/kaggle/input/logdata/logdata.txt", "r") as file:
        logdata = file.read()
df = pd.read_csv("/kaggle/input/logdata/logdata.txt", header = None)
df

# %%
df['host'] = re.findall('([\d]+[\.]+[\d]+[\.]+[\d]+[\.]+[\d]+)',str(df))

# %%
host_pattern = '([\d]+[\.]+[\d]+[\.]+[\d]+[\.]+[\d]+)'
df['Host'] = re.findall(host_pattern,logdata)

# %%
df

# %%
txt = """13.112.8.80 - rau5026 [21/Jun/2019:15:46:09 -0700] "HEAD /ubiquitous/transparent HTTP/1.1" 200 16928
159.253.153.40 - - [21/Jun/2019:15:46:10 -0700] "POST /e-business HTTP/1.0" 504 19845
136.195.158.6 - feeney9464 [21/Jun/2019:15:46:11 -0700] "HEAD /open-source/markets HTTP/2.0" 204 21149
219.194.113.255 - - [21/Jun/2019:15:46:12 -0700] "PATCH /next-generation/niches/mindshare HTTP/1.0" 503 20246
59.101.239.174 - brekke3293 [21/Jun/2019:15:46:13 -0700] "DELETE /ubiquitous/seize/web-enabled HTTP/2.0" 302 14017
233.187.15.207 - - [21/Jun/2019:15:46:14 -0700] "GET /harness/intuitive HTTP/1.0" 304 21006
62.79.96.179 - mayer1069 [21/Jun/2019:15:46:15 -0700] "HEAD /facilitate HTTP/1.0" 404 7905
217.70.194.150 - batz2602 [21/Jun/2019:15:46:16 -0700] "PUT /functionalities/channels/productize/mission-critical HTTP/2.0" 404 23186
161.242.130.180 - - [21/Jun/2019:15:46:17 -0700] "DELETE /methodologies/experiences HTTP/2.0" 100 25437
155.127.24.96 - - [21/Jun/2019:15:46:18 -0700] "POST /mindshare/optimize/vertical HTTP/2.0" 500 6154
63.208.115.205 - - [21/Jun/2019:15:46:19 -0700] "PATCH /revolutionize HTTP/1.0" 404 4283"""

# %%
ptn_host= r'([\d]+[\.?]+[\d]+[\.?]+[\d]+[\.?]+[\d]+) -'
re.findall(ptn_host, txt)

# %%
ptn_user = r' - ([A-Za-z]+[\d]+) | - -'
re.findall(ptn_user, txt)

# %%
ptn_time = '\[(.*)\]'
re.findall(ptn_time, txt)

# %%
ptn_req = '\"(.*)\"'
re.findall(ptn_req, txt)

# %%
re.sub("- -", "-", txt)

# %%
txt

# %%
ptn_user = r' - ([A-Za-z]+[\d]+) | - -'
ptn_req = r'\"(.*)\"'
ptn_time = r'\[(.*)\]'
ptn_host= r'([\d]+[\.?]+[\d]+[\.?]+[\d]+[\.?]+[\d]+) -'
example_dict = {"host":str(re.findall(ptn_host, logdata)), 
                "user_name":re.findall(ptn_user, logdata), 
                "time":re.findall(ptn_time, logdata),
                "request":re.findall(ptn_req, logdata)}

# %%
df1 = pd.DataFrame(example_dict)
#df1.where(df1['user_name'] == ' ').replace(to_replace=' ', value='-', inplace=True)
df1.where(df1['user_name'] == '').replace(to_replace='', value='-', inplace=True)

# %%
df1['user_name'][1]

# %%
    ptn_user = r' - ([A-Za-z]+[\d]+) | - -'
    ptn_req = r'\"(.*)\"'
    ptn_time = r'\[(.*)\]'
    ptn_host = r'([\d]+[\.?]+[\d]+[\.?]+[\d]+[\.?]+[\d]+) -'
    dict1 = {"host":re.findall(ptn_host, logdata), 
            "user_name":re.findall(ptn_user, logdata), 
            "time":re.findall(ptn_time, logdata),
            "request":re.findall(ptn_req, logdata)}

# %%
import re
def logs():
    with open("/kaggle/input/logdata/logdata.txt", "r") as file:
        logdata = file.read()
    ptn_user = ' - ([A-Za-z]+[\d]+) | - -'
    ptn_req = '\"(.*)\"'
    ptn_time = '\[(.*)\]'
    ptn_host = '([\d]+[\.?]+[\d]+[\.?]+[\d]+[\.?]+[\d]+) -'
    log = {"host":[re.findall(ptn_host, logdata)], 
            "user_name":[re.findall(ptn_user, logdata)], 
            "time":[re.findall(ptn_time, logdata)],
            "request":[re.findall(ptn_req, logdata)]}
    raise NotImplementedError()
#===============================================================
assert len(logs()) == 979

one_item={'host': '146.204.224.152',
  'user_name': 'feest6811',
  'time': '21/Jun/2019:15:45:24 -0700',
  'request': 'POST /incentivize HTTP/1.1'}
assert one_item in logs()

# %%
import re
with open("/kaggle/input/logdata/logdata.txt", "r") as file:
    logdata = file.read()
    logsdict = []
    pattern = """
    (?P<host>.*)
    (\ -\ )
    (?P<usr_name>.*)
    (\ \[)
    (?P<time>.*)
    (\]\ ")
    (?P<request>.*)
    (\" )
    """
for item in re.finditer(pattern, logdata, re.VERBOSE):
    logsdict.append(item.groupdict())

# %%
print(logsdict)

# %%
#log
one_item={'host': '146.204.224.152',
  'user_name': 'feest6811',
  'time': '21/Jun/2019:15:45:24 -0700',
  'request': 'POST /incentivize HTTP/1.1'}
#assert one_item in logs()
one_item in log

# %%
pd.DataFrame(log)

# %%
zipbObj = zip(listOfStr, listOfInt)

# %%
ptn_user = ' - ([A-Za-z]+[\d]+) | - -'
ptn_req = '\"(.*)\"'
ptn_time = '\[(.*)\]'
ptn_host = '([\d]+[\.?]+[\d]+[\.?]+[\d]+[\.?]+[\d]+) -'
host = re.findall(str(ptn_host), logdata)
user_name = re.findall(ptn_user, logdata) 
time = re.findall(ptn_time, logdata)
request = re.findall(ptn_req, logdata)
log = [{'host': host, 'user_name': user_name, 'time' : time, 'request': request} for host, user_name, time, request in zip(host, user_name, time, request)]
log
#one_item in log

# %%
#list_of_lists = [host, user_name, time, request]
#{z[0]: list(z[1:]) for z in zip(*list_of_lists)}

# %%
#[{'host': host, 'user_name': user_name, 'request': request} for host, user_name, time, request in zip(host, user_name, time, request)]

# %%
type(log)

# %%
# Python3 code to demonstrate working of 
# Convert list of dictionaries to Dictionary Value list
# Using loop
from collections import defaultdict
  
# initializing lists
test_list = [{"Gfg" : 6, "is" : 9, "best" : 10}, 
             {"Gfg" : 8, "is" : 11, "best" : 19},
             {"Gfg" : 2, "is" : 16, "best" : 10},
             {"Gfg" : 12, "is" : 1, "best" : 8},
             {"Gfg" : 22, "is" : 6, "best" : 8}]
  
# printing original list
#print("The original list : " + str(test_list))
  
# using loop to get dictionaries
# defaultdict used to make default empty list 
# for each key
res = defaultdict(list)
for sub in log:
    for key in sub:
        res[key].append(sub[key])
      
# printing result 
#print("The extracted dictionary : " + str(dict(res)))

# %%
#res
one_item in res

# %%
re.findall('([\d]+[\.][\d]+[\.][\d]+[\.][\d]+) \- ([A-Za-z]+[\d]+)|- -',logdata)

# %%
    with open("assets/logdata.txt", "r") as file:
        logdata = file.read()
    logsdict = []
    pattern = """   (?P<host>.*)
                    (\ -\ )
                    (?P<usr_name>.*)
                    (\ \[)
                    (?P<time>.*)
                    (\] \")
                    (?P<request>.*)
                    (\" )             """
    for item in re.finditer(pattern, logdata, re.VERBOSE):
        logsdict.append(item.groupdict())
    return logsdict

# %%
    simple_string = """Amy is 5 years old, and her sister Mary is 2 years old. 
    Ruth and Peter, their parents, have 3 kids."""
    words_pattern = '[A-Z]+[a-z]+'
    re.findall(words_pattern, simple_string)

# %%
with open ("/kaggle/input/asset-data/New Text Document.txt", "r") as file:
        grades = file.read()
student_with_B_grades = []
pattern_for_Searching_B_grades = """
(?P<name>.*)(\: B)
"""
for item in re.finditer(pattern_for_Searching_B_grades, grades):
    student_with_B_grades.append(item.group('name'))

# %%
student_with_B_grades

# %%
import pandas as pd
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj1 = pd.Series(sdata)
states = ['California', 'Ohio', 'Oregon', 'Texas']
obj2 = pd.Series(sdata, index=states)
obj3 = pd.isnull(obj2)

# %%
obj2['California'] == None

# %%
import pandas as pd
d = {'1': 'Alice','2': 'Bob','3': 'Rita','4': 'Molly','5': 'Ryan'}
S = pd.Series(d)

# %%
#S.loc[0:2]
S.iloc[0:2]
#S.loc[0:3]
#S.iloc[0:3]

# %%
import pandas as pd
s1 = pd.Series({1: 'Alice', 2: 'Jack', 3: 'Molly'})
s2 = pd.Series({'Alice': 1, 'Jack': 2, 'Molly': 3})

# %%
#s2[1]
#s2.loc[1]
#s1.loc[1]
s2.iloc[1]

# %%
import pandas as pd
d = {'1': 'Alice','2': 'Bob','3': 'Rita','4': 'Molly','5': 'Ryan'}
S = pd.Series(d)

# %%
S.iloc[0:2]
