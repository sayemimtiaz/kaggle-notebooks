# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
# Data Management
from dateutil import relativedelta as rd
import numpy as np # linear algebra
import seaborn as sns #import seaborn library
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# %matplotlib inline

import plotly.express as px
import plotly.graph_objects as go
import plotly.offline as pyo
pyo.init_notebook_mode()

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#DataSet5
df=pd.read_csv('/kaggle/input/corona-virus-report/country_wise_latest.csv')
df.info()

# %%
df.head()

# %%
df

# %%
confirmed=df['Confirmed'].sum()

# %%
confirmed

# %%
deaths=df['Deaths'].sum()

# %%
deaths

# %%
recovered=df['Recovered'].sum()

# %%
recovered

# %%
active=df['Active'].sum()

# %%
active

# %%
newcases=df['New cases'].sum()

# %%
newcases

# %%
newdeaths=df['New deaths'].sum()

# %%
newdeaths

# %%
newrecovered=df['New recovered'].sum()

# %%
newrecovered

# %%
#Death Per 100 cases
deathper100cases=df['Deaths / 100 Cases'].mean()

# %%
deathper100cases

# %%
#Recovered Per 100 Cases
recoveredper100cases=df['Recovered / 100 Cases'].mean()

# %%
recoveredper100cases

# %%
#Total Confirmed Last Week
confirmedlastweek=df['Confirmed last week'].sum()

# %%
confirmedlastweek

# %%
oneweekchange=df['1 week change'].mean()

# %%
oneweekchange

# %%
oneweekpercentincrease=df['1 week % increase'].mean()

# %%
oneweekpercentincrease

# %%
#Total Confirmed,Deaths.Recovered and Active Cases for Afganisthan
columns=['Country/Region','Confirmed','Deaths','Recovered','Active']
index=[0]
data1=df.loc[index,columns]
data1

# %%
data1.plot.bar()

# %%
cols=['Deaths / 100 Cases','Recovered / 100 Cases','1 week % increase']
index=[0]
data2=df.loc[index,cols]
data2

# %%
#Percentage of Death,Recoveryand 1 week % increase
data2.plot.bar()

# %%
#Differenciation between first 3 countries in dataset(Afganistan,Albania,Algeria)
columns=['Confirmed','Deaths','Recovered','Active']
data3=df.loc[0:2,columns]
data3

# %%
data3.plot.bar()

# %%
#Differentiation between percentage of deaths,recovered and 1 week % increase between first 3 countries in dataset(Afganisthan,Albania,Algeria)
columns=['Deaths / 100 Cases','Recovered / 100 Cases','1 week % increase']
data4=df.loc[0:2,columns]
data4

# %%
data4.plot.bar()

# %%
#DataSet 6
df1=pd.read_csv('/kaggle/input/corona-virus-report/full_grouped.csv')
df1.info()

# %%
df1

# %%
df1['Confirmed'].sum()

# %%
df1['Deaths'].sum()

# %%
df1['Recovered'].sum()

# %%
df1['Active'].sum()

# %%
df1['New cases'].sum()

# %%
df1['New deaths'].sum()

# %%
df1['New recovered'].sum()

# %%
df1['Date'].min()

# %%
df1['Date'].max()

# %%
#DataSet 3
df2=pd.read_csv('/kaggle/input/corona-virus-report/day_wise.csv')
df2.info()

# %%
df2.head()

# %%
df2

# %%
df2['Confirmed'].sum()

# %%
df2['Deaths'].sum()

# %%
df2['Recovered'].sum()

# %%
df2['Active'].sum()

# %%
df2['New cases'].sum()

# %%
df2['New recovered'].sum()

# %%
df2['Deaths / 100 Cases'].mean()

# %%
df2['Recovered / 100 Cases'].mean()

# %%
df2['Deaths / 100 Recovered'].mean()

# %%
df2['Date'].min()

# %%
df2['Date'].max()

# %%
#Data Analysis of random total six countries at index 0
columns=['Confirmed','Deaths','Recovered','Active','New cases','New deaths','New recovered','Deaths / 100 Cases','Recovered / 100 Cases','Deaths / 100 Recovered','No. of countries']
sixcountries=df2.loc[0,columns]
sixcountries

# %%
sixcountries.plot.bar()

# %%
#Data Analysis of random total six countries at index 1
columns=['Confirmed','Deaths','Recovered','Active','New cases','New deaths','New recovered','Deaths / 100 Cases','Recovered / 100 Cases','Deaths / 100 Recovered','No. of countries']
eightcountries=df2.loc[1,columns]
eightcountries

# %%
eightcountries.plot.bar()

# %%
#DataSet2
df3=pd.read_csv('/kaggle/input/corona-virus-report/worldometer_data.csv')
df3.info()

# %%
#Total Population
df3['Population'].sum()

# %%
#Total Corona Cases
df3['TotalCases'].sum()

# %%
#Total New Cases
df3['NewCases'].sum()

# %%
#Total Deaths
df3['TotalDeaths'].sum()

# %%
#Total New Deaths
df3['NewDeaths'].sum()

# %%
#Total Recovered
df3['TotalRecovered'].sum()

# %%
#Total Newly Recovered
df3['NewRecovered'].sum()

# %%
#Total Active Cases
df3['ActiveCases'].sum()

# %%
#Total Serious Critical Cases
df3['Serious,Critical'].sum()

# %%
#Average Cases per one million population
df3['Tot Cases/1M pop'].mean()

# %%
#Average Deaths per one million population
df3['Deaths/1M pop'].mean()

# %%
#Total Number Of Tests
df3['TotalTests'].sum()

# %%
#Average Number Of Tests in 1 million population
df3['Tests/1M pop'].mean()

# %%
#Difference of Population Between India And USA
columns=['Country/Region','Population']
index=[0,2]
population=df3.loc[index,columns]
population

# %%
ratio=df3['Population'][2]/df3['Population'][0]

# %%
ratio

# %%
#USA=0 India=2
population.plot.bar()
#According to  Data Analysis India's Population is 4.170751196572275 times more than USA

# %%
#Difference of Total Cases Between India And USA
columns=['Country/Region','TotalCases']
index=[0,2]
TotalCases=df3.loc[index,columns]
TotalCases

# %%
ratio=df3['TotalCases'][0]/df3['TotalCases'][2]

# %%
ratio

# %%
#USA=0 #India=2
TotalCases.plot.bar()
#According to data analysis Total Cases of USA are 2.4845248539924527 times more than India

# %%
#Difference Between Total Deaths in India And USA
columns=['Country/Region','TotalDeaths']
index=[0,2]
TotalDeaths=df3.loc[index,columns]
TotalDeaths

# %%
ratio=df3['TotalDeaths'][0]/df3['TotalDeaths'][2]

# %%
ratio

# %%
#USA=0 #India=2
TotalDeaths.plot.bar()
#According to data analysis Total Deaths of USA are 3.9099860704164464 times more than India

# %%
#Difference Between New Deaths in India And USA
columns=['Country/Region','NewDeaths']
index=[0,2]
NewDeaths=df3.loc[index,columns]
NewDeaths

# %%
ratio=df3['TotalDeaths'][0]/df3['TotalDeaths'][2]

# %%
#Difference Between New Deaths in India And USA
columns=['Country/Region','NewDeaths']
index=[0,2]
NewDeaths=df3.loc[index,columns]
NewDeaths

# %%
#Difference Between Total Recovered in India And USA
columns=['Country/Region','TotalRecovered']
index=[0,2]
TotalRecovered=df3.loc[index,columns]
TotalRecovered

# %%
ratio=df3['TotalRecovered'][0]/df3['TotalRecovered'][2]

# %%
ratio

# %%
#USA=0 #India=2
TotalRecovered.plot.bar()
# According to data analysis Total COVID19 Patients Recovered are 1.8706969153119246 more in USA than India

# %%
#Difference Between Newly Recovered in India And USA
columns=['Country/Region','NewRecovered']
index=[0,2]
NewRecovered=df3.loc[index,columns]
NewRecovered

# %%
#Difference Between ActiveCases in India And USA
columns=['Country/Region','ActiveCases']
index=[0,2]
ActiveCases=df3.loc[index,columns]
ActiveCases

# %%
ratio=df3['ActiveCases'][0]/df3['ActiveCases'][2]

# %%
ratio

# %%
#USA=0 #India=2
ActiveCases.plot.bar()
#According to Data Analysis Total COVID19 Active Patients are 3.7809303299707944 more in USA than India

# %%
#Difference Between Total Recovered in India And USA
columns=['Country/Region','Serious,Critical']
index=[0,2]
SeriousCriticalCases=df3.loc[index,columns]
SeriousCriticalCases

# %%
ratio=df3['Serious,Critical'][0]/df3['Serious,Critical'][2]

# %%
ratio

# %%
#Difference of Population Between India And USA
columns=['Country/Region','Tot Cases/1M pop']
index=[0,2]
TotalCasesIn1MillionPopulation=df3.loc[index,columns]
TotalCasesIn1MillionPopulation

# %%
ratio=df3['Tot Cases/1M pop'][0]/df3['Tot Cases/1M pop'][2]

# %%
ratio

# %%
#USA=0 India=2
TotalCasesIn1MillionPopulation.plot.bar()
#According to Data Analysis Total COVID19 Active Patients are 10.36425648021828 more in USA than India

# %%
#Difference of  Between India And USA
columns=['Country/Region','Deaths/1M pop']
index=[0,2]
DeathCasesIn1MillionPopulation=df3.loc[index,columns]
DeathCasesIn1MillionPopulation

# %%
ratio=df3['Deaths/1M pop'][0]/df3['Deaths/1M pop'][2]

# %%
ratio

# %%
#USA=0 India=2
DeathCasesIn1MillionPopulation.plot.bar()
#According to Data Analysis Total COVID19 Patients DeathCases in 1 Million Poplation are 16.4 more in USA than India

# %%
#Difference of Total Deaths In India In Between India And USA
columns=['Country/Region','Deaths/1M pop']
index=[0,2]
TotalDeathsIn1MillionPopulation=df3.loc[index,columns]
TotalDeathsIn1MillionPopulation

# %%
ratio=df3['Deaths/1M pop'][0]/df3['Deaths/1M pop'][2]

# %%
ratio

# %%
#USA=0 India=2
TotalDeathsIn1MillionPopulation.plot.bar()
#According to Data Analysis Total COVID19 Patients DeathCases in 1 Million Poplation are 11.888992828188337 more in USA than India

# %%
#Difference of  Between India And USA
columns=['Country/Region','Tests/1M pop']
index=[0,2]
TotalTests=df3.loc[index,columns]
TotalTests

# %%
ratio=df3['TotalTests'][0]/df3['TotalTests'][2]

# %%
ratio

# %%
#USA=0 India=2
TotalTests.plot.bar()
#According to Data Analysis Total COVID19 Patient Cases in  are 2.8506300252318906 more in USA than India

# %%
#Difference of  Between India And USA
columns=['Country/Region','Tests/1M pop']
index=[0,2]
TotalTestsIn1MillionPopulation=df3.loc[index,columns]
TotalTestsIn1MillionPopulation

# %%
ratio=df3['Tests/1M pop'][0]/df3['Tests/1M pop'][2]

# %%
ratio

# %%
#USA=0 India=2
TotalTestsIn1MillionPopulation.plot.bar()
#According to Data Analysis Total COVID19 Patient Test Cases are 11.888992828188337 more in USA than India

# %%
#DataSet5
df5=pd.read_csv('/kaggle/input/corona-virus-report/country_wise_latest.csv')
df5

# %%
df5['Confirmed'].sum()

# %%
df5['Deaths'].sum()

# %%
df5['Recovered'].sum()

# %%
df5['Active'].sum()

# %%
df5['New cases'].sum()

# %%
df5['New deaths'].sum()

# %%
df5['New recovered'].sum()

# %%
df5['Deaths / 100 Cases'].mean()

# %%
df5['Recovered / 100 Cases'].mean()

# %%
df5['Deaths / 100 Recovered'].mean()

# %%
df5['Confirmed last week'].sum()

# %%
df5['1 week change'].sum()

# %%
df5['1 week % increase'].mean()

# %%
#DataSet 6
df6=pd.read_csv('/kaggle/input/corona-virus-report/full_grouped.csv')
df6.info()

# %%
df6['Date'].min()

# %%
df6['Date'].max()

# %%
df6['Confirmed'].sum()

# %%
df6['Deaths'].sum()

# %%
df6['Recovered'].sum()

# %%
df6['Active'].sum()

# %%
df6['New cases'].sum()

# %%
df6['New deaths'].sum()

# %%
df6['New recovered'].sum()

# %%
#DataSet1
df7=pd.read_csv('/kaggle/input/corona-virus-report/covid_19_clean_complete.csv')
df7.info()

# %%
df7['Date'].min()

# %%
df7['Date'].max()

# %%
df7['Country/Region'][49064]

# %%
df7['Date'][49064]

# %%
columns=['Lat','Long','Confirmed','Deaths','Recovered','Active']
Yemen=df7.loc[49064,columns]
Yemen

# %%
Yemen.plot.bar()

# %%
#DataSet1
df8=pd.read_csv('/kaggle/input/corona-virus-report/usa_county_wise.csv')
df8.info()

# %%
#USA COVID19 DataSet
df8

# %%
df8['Date'].min()

# %%
df8['Date'].max()

# %%
df8['Confirmed'].sum()

# %%
df8['Deaths'].sum()

# %%
#Data Analysis of random total six countries at index 0
columns=['Confirmed','Deaths']
SouthwestUtah=df8.loc[627917,columns]
SouthwestUtah

# %%
ratio=SouthwestUtah['Confirmed']/SouthwestUtah['Deaths']

# %%
ratio

# %%
SouthwestUtah.plot.bar()
#Confirmed Cases are 120.91304347826087 times in SouthWest Utha in USA

# %%
#DataSet4
df8=pd.read_csv('/kaggle/input/corona-virus-report/day_wise.csv')
df8.info()

# %%
#Updated
dataset=pd.read_csv('/kaggle/input/corona-virus-report/worldometer_data.csv')
dataset

# %%
#Display Number of Rows and Columns
dataset.info()

# %%
#Statistical Information Of the DataSet
dataset.describe()

# %%
#Display the Column Names of DataSet
dataset.columns

# %%
#Using Seaborn Pairplot for showing not just histograms but also all correlations between the dataset
sns.pairplot(dataset)

# %%
#Shows the average total cases between 2 and 3(2.5)
sns.distplot(dataset['TotalCases'])

# %%
#Shows correlation between different columns
dataset.corr()

# %%
#Data Corelation Representation of DataSet
sns.heatmap(dataset.corr(),annot=True)

# %%
#False=NULL Values
dataset.isnull()

# %%
#Here Yellow represents True(Information Available)  
sns.heatmap(dataset.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
sns.set_style('whitegrid')

# %%
sns.distplot(dataset['TotalDeaths'].dropna(),kde=False,bins=30)

# %%
sns.distplot(dataset['NewCases'].dropna(),kde=False,bins=30)

# %%
sns.distplot(dataset['TotalDeaths'].dropna(),kde=False,bins=30)

# %%
sns.distplot(dataset['NewCases'].dropna(),kde=False,bins=30)

# %%
sns.distplot(dataset['NewDeaths'].dropna(),kde=False,bins=30)

# %%
sns.distplot(dataset['TotalRecovered'].dropna(),kde=False,bins=30)

# %%
sns.distplot(dataset['NewRecovered'].dropna(),kde=False,bins=30)

# %%
sns.distplot(dataset['ActiveCases'].dropna(),kde=False,bins=30)

# %%
sns.distplot(dataset['Serious,Critical'].dropna(),kde=False,bins=30)

# %%
sns.distplot(dataset['Tot Cases/1M pop'].dropna(),kde=False,bins=30)

# %%
sns.distplot(dataset['Deaths/1M pop'].dropna(),kde=False,bins=30)

# %%
sns.distplot(dataset['TotalTests'].dropna(),kde=False,bins=30)

# %%
dataset['TotalTests'].hist()

# %%
import cufflinks as cf

# %%
cf.go_offline()

# %%
dataset['TotalTests'].iplot(kind='hist',bins=50)

# %%
from sklearn import linear_model

# %%
#Load DataSet
dataset=pd.read_csv('/kaggle/input/corona-virus-report/worldometer_data.csv')
dataset

# %%
#After dropping Categorical(non-numerical data)
dataset1=dataset.drop(['Country/Region','Continent','WHO Region'],axis=1)

# %%
#After dropping Categorical(non-numerical data)
dataset1

# %%
#After dropping categorical(non-numerical data)
dataset1.head()

# %%
dataset1.shape

# %%
dataset1.plot(kind='scatter',x='TotalCases',y='TotalDeaths')
plt.show()

# %%
dataset1.plot(kind='box',x='Population',y='TotalDeaths')
plt.show()

# %%
#Change to DataFrame Variables
#Variable X
TotalDeaths=pd.DataFrame(dataset1['TotalDeaths'])

# %%
TotalDeaths

# %%
#Change to DataFrame Variables
#Variable Y
NewDeaths=pd.DataFrame(dataset1['NewDeaths'])

# %%
NewDeaths

# %%
datast12=dataset1.plot(kind='scatter',x='TotalDeaths',y='NewDeaths')
