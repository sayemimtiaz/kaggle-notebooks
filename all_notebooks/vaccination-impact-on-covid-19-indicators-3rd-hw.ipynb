# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
data = pd.read_csv('../input/vaccination-impact-on-covid19-indicators/Vaccine consequences on reproductibility.csv')

# %%
data.head(10)
# tx_incid is the incidence rate corresponds to the people who tested positive
# R is the average number of people an infected person can infect
# taux_occupation_sae is the level of demand for resuscitation but also the level of stress on hospital resuscitation capacities
# tx_pos is the positivity rate corresponds to the number of people tested positive 
# n_complet is the Number of complete coverage granted this day (1 dose for J&J - 2 doses for Pfitzer/AstraZenecca/Mod
# n_cum_dose1 is the cumulated number of 1st doses administered
# n_cum_complet is the cumulated number of complete coverages

# %%
data.tail()

# %%
data.shape  # shape gives us the number of rows and columns, respectively

# %%
data.info

# %%
data.describe()

# %%
# visualization of what we learned about the data in the previous cell
data.boxplot(column = 'taux_occupation_sae')
plt.show()

# %%
data.boxplot(column = 'taux_occupation_sae', by = 'n_dose1')
plt.show()

# %%
new_data = data.tail()
new_data

# %%
melted = pd.melt(frame = new_data, id_vars = 'extract_date', value_vars = ['taux_occupation_sae', 'n_complet'])
melted

# %%
# pivoting example, which is the reverse of melting
melted.pivot(index = 'extract_date', columns = 'variable', values = 'value')

# %%
# concatenating data
data1 = data.head()
data2 = data.tail()
concatenated_data = pd.concat([data1, data2], axis = 0, ignore_index = True)
concatenated_data

# %%
data3 = data['n_dose1'].head()
data4 = data['n_cum_dose1'].head()
concatenated_data2 = pd.concat([data3,data4], axis = 1)
concatenated_data2

# %%
# to learn about the data types we have in the data set
data.dtypes

# %%
# to change n_dose1 from integer to float
data['n_dose1'] = data['n_dose1'].astype('float')

# %%
# let's see if we converted the data type of n_dose1 or not
data.dtypes

# %%
data.info

# %%
data5 = data
data5['R'].value_counts(dropna = False)

# %%
data['R'].dropna(inplace = True)

# %%
assert data['R'].notnull().all()

# %%
data['R'].fillna('empty', inplace = True)

# %%
assert data['R'].notnull().all
