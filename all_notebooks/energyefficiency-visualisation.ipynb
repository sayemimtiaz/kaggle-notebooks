# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
from scipy.stats import chi2_contingency 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
energy= pd.read_csv("../input/eergy-efficiency-dataset/ENB2012_data.csv")
energy.head()

# %%
#X1 Relative Compactness
#X2 Surface Area
#X3 Wall Area
#X4 Roof Area
#X5 Overall Height
#X6 Orientation
#X7 Glazing Area
#X8 Glazing Area Distribution
#y1 Heating Load
#y2 Cooling Load

# %%
energy.describe()

# %%
corr = energy.corr()
f, ax = plt.subplots(figsize = (20, 9))
sns.heatmap(corr, vmax = 8, annot = True);

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
 
text=("Energy Efficiency Relative Compactness Surface Area Wall Area Roof Area Overall Height Orientation Glazing Area Glazing Area Distribution Heating Load Cooling Load")
 
wordcloud = WordCloud(width=900, height=700, margin=0).generate(text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
#ScatterPlot Matrix
import plotly.express as px
fig = px.scatter_matrix(energy)
fig.show()

# %%
#boxplot
energy.plot(kind = 'box', subplots = True, layout = (4, 4), sharex = False, sharey = False, figsize = (12, 12));

# %%
#densityPlot
energy.plot(kind = 'density', subplots= True, layout = (4,4), sharex =False, figsize = (12, 12));

# %%
numbers = pd.Series(energy.columns)
energy[numbers].hist(figsize = (12, 12))
plt.show();

# %%
#Surface Area Vs Wall Area
fig = px.density_heatmap(energy, x="X2", y="X3", marginal_x="box", marginal_y="violin", title = "Surface Area Vs Wall Area")
fig.show()

# %%
#Surface Area Vs Roof Area
fig = px.density_heatmap(energy, x="X2", y="X4", marginal_x="box", marginal_y="violin")
fig.show()

# %%
#Surface Area Vs Overall height
fig = px.density_heatmap(energy, x="X2", y="X5", marginal_x="box", marginal_y="violin")
fig.show()

# %%
#Glazing area Vs Glazing Area distribution
fig = px.density_heatmap(energy, x="X7", y="X8", marginal_x="box", marginal_y="violin")
fig.show()

# %%
#Heating Load Vs Cooling Load 
fig = px.density_heatmap(energy, x="Y1", y="Y2", marginal_x="box", marginal_y="violin")
fig.show()

# %%
#BarPlot (Surface area, wall area, roof area)
fig = px.bar(energy, x="X2", y="X3", color="X4", barmode="group")
fig.show()

# %%
#Principal Components Analysis
import plotly.express as px

features = ["X2", "X3", "X4", "X5"]

fig = px.scatter_matrix(
    energy,
    dimensions=features,
    color="Y1"
)
fig.update_traces(diagonal_visible=False)
fig.show()

# %%
import plotly.express as px


features = ["X3", "X4", "X5", "X6"]

fig = px.scatter_matrix(
    energy,
    dimensions=features,
    color="Y1"
)
fig.update_traces(diagonal_visible=False)
fig.show()

# %%
import plotly.express as px


features = ["X3", "X4", "Y1", "Y2"]

fig = px.scatter_matrix(
    energy,
    dimensions=features,
    color="Y1"
)
fig.update_traces(diagonal_visible=False)
fig.show()

# %%
import plotly.express as px


features = ["X4", "X5", "Y1", "Y2"]

fig = px.scatter_matrix(
    energy,
    dimensions=features,
    color="Y1"
)
fig.update_traces(diagonal_visible=False)
fig.show()

# %%
import plotly.express as px


features = ["X4", "X5", "X6", "X7"]

fig = px.scatter_matrix(
    energy,
    dimensions=features,
    color="Y1"
)
fig.update_traces(diagonal_visible=False)
fig.show()

# %%
import plotly.express as px


features = ["X6", "X7", "Y1", "Y2"]

fig = px.scatter_matrix(
    energy,
    dimensions=features,
    color="Y1"
)
fig.update_traces(diagonal_visible=False)
fig.show()

# %%
energy.tail()

# %%
import plotly.express as px
fig = px.strip(energy, x='Y1', y='Y2')
fig.show()

# %%
sns.pairplot(energy, x_vars=["X2", "X5", "X6"], y_vars=["X1"],
              height=5, aspect=.8, kind="reg");

# %%
sns.jointplot(x="Y1", y="Y2", data= energy, kind="reg");

# %%
plt.plot( 'Y1', 'Y2', data=energy, marker='o', color='green')
plt.show()

# %%
#References
#https://plotly.com/python/
