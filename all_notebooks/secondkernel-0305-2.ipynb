# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.

# %%
data=pd.read_csv('../input/NBA_player_of_the_week.csv')
data.head()

# %%
data.tail()

# %%
data.info()

# %%
print(data['Team'].value_counts(dropna='False'))

# %%
data.describe()

# %%
data.boxplot(column='Weight',by='Age')

# %%
data_new=data.head()
data_new

# %%
melted=pd.melt(frame=data_new,id_vars='Player',value_vars=['Age','Weight'])
melted

# %%
melted.pivot(index='Player',columns='variable',values='value')

# %%
data1=data.head()
data2=data.tail()
conc_datarow=pd.concat([data1,data2],axis=0,ignore_index=True)
conc_datarow

# %%
data1=data['Age'].head()
data2=data['Weight'].head()
conc_datacol=pd.concat([data1,data2],axis=1)
conc_datacol

# %%
data.dtypes

# %%
data['Team']=data['Team'].astype('category')
data['Age']=data['Age'].astype('float')

# %%
data.dtypes

# %%
data.info()

# %%
data['Team'].value_counts(dropna=False)

# %%
data1=data
data1['Team'].dropna(inplace=True)

# %%
assert 1==1

# %%
assert data['Team'].notnull().all()

# %%
country=["spain","germany"]
population=["60","80"]
list_label=["country","population"]
list_col=[country,population]
zipped=list(zip(list_label,list_col))
data_dict=dict(zipped)
df=pd.DataFrame(data_dict)
df

# %%
df["capital"]=["madrid","berlin"]
df

# %%
df["income"]=0
df

# %%
data1=data.loc[:,["Age","Weight"]]
data1.plot()

# %%
data1.plot(subplots=True)
plt.show()

# %%
data1.plot(kind="scatter",x="Age",y="Weight")
plt.show()

# %%
data1.plot(kind="hist",y="Weight",bins=50,range=(0,250),normed=True)

# %%
fig,axes=plt.subplots(nrows=2,ncols=1)
data1.plot(kind="hist",y="Weight",bins=50,range=(0,250),normed=True,ax=axes[0])
data1.plot(kind="hist",y="Weight",bins=50,range=(0,250),normed=True,ax=axes[1],cumulative=True)
plt.savefig('graph.png')
plt

# %%
data.describe()

# %%
time_list = ["1992-03-08","1992-04-12"]
print(type(time_list[1])) 
datetime_object = pd.to_datetime(time_list)
print(type(datetime_object))

# %%
import warnings
warnings.filterwarnings("ignore")
data2 = data.head()
date_list = ["2001-01-10","2002-02-10","2002-03-10","2004-03-15","2005-03-16"]
datetime_object = pd.to_datetime(date_list)
data2["date"] = datetime_object
# lets make date as index
data2= data2.set_index("date")
data2

# %%
print(data2.loc["2001-01-10"])
print(data2.loc["2001-01-10":"2004-03-15"])

# %%
data2.resample("A").mean()

# %%
data2.resample("M").mean()

# %%
data2.resample("M").first().interpolate("linear")

# %%
data2.resample("M").mean().interpolate("linear")

# %%
data = pd.read_csv('../input/NBA_player_of_the_week.csv')
data= data.set_index("Age")
data.head()

# %%
data["Weight"][37]

# %%
data.Weight[37]

# %%
data.loc[37,["Weight"]]

# %%
data[["Weight","Real_value"]]

# %%
print(type(data["Weight"]))     print(type(data["Weight"]))     
print(type(data[["Weight"]]))

# %%
def div(n):
    return n/2
data.Weight.apply(div)

# %%
data.Weight.apply(lambda n:n/2)

# %%
data["year_what"]= data.Weight-data.Real_value
data.head()
