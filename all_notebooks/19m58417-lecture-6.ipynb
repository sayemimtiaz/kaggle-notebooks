# %% [markdown]
# # Exercice 6 - 19M58417 CHEN Tong
# in this exercise, I am going to review the Covid-19 situation in South Korea.

# %% [markdown]
# 1. At first, we need to import data of covid-19 cases, and select South Korea.
# 2. I used groupby function to sum up cases in each observation day. DateFrame df_korea contains the sum of cases each day.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

selected_country = 'South Korea'

df = pd.read_csv("../input/novel-corona-virus-2019-dataset/covid_19_data.csv", header = 0)
#print(np.unique(df['Country/Region'].values))
df_korea = df[df['Country/Region'] == selected_country]
df_korea = df_korea.groupby('ObservationDate').sum()

# %% [markdown]
# 3. In this step, we used diff function to get cases added in each day

# %%
df_korea['daily_confirmed'] = df_korea['Confirmed'].diff()
df_korea['daily_deaths'] = df_korea['Deaths'].diff()
df_korea['daily_recovered'] = df_korea['Recovered'].diff()

# %% [markdown]
# 4.we are going to make a time-series interactive chart by plotly, and save it into "SouthKorea_daily_cases_figure_19M58417.html"

# %%
from plotly.offline import iplot,init_notebook_mode
import plotly.graph_objs as go
import plotly as py

init_notebook_mode(connected=True) 

daily_confirmed_object = go.Scatter(x = df_korea.index, y = df_korea['daily_confirmed'].values, name = 'Daily confirmed')
daily_deaths_object = go.Scatter(x = df_korea.index, y = df_korea['daily_deaths'].values, name = 'Daily deaths')
daily_recovered_object = go.Scatter(x = df_korea.index, y = df_korea['daily_recovered'].values, name = 'Daily recovered')

layout = go.Layout(title = "Covid-19 Cases in Sorth Korea", xaxis = dict(title = 'Date'), yaxis = dict(title = 'Case Number') )
figure = go.Figure(data = [daily_confirmed_object, daily_deaths_object, daily_recovered_object], layout = layout)
py.offline.iplot(figure)

figure.write_html("SouthKorea_daily_cases_figure_19M58417.html")

# %% [markdown]
# 5. Now we are going to Make an informative table, and saved as "SouthKorea_daily_cases_table_19M58417.html"

# %%
df_korea_copy = df_korea
df_korea_copy = df_korea_copy.fillna(0.)
styled_object = df_korea_copy.style.background_gradient(cmap = 'gist_ncar').highlight_max('daily_confirmed').set_caption('Daily Summaries')
display(styled_object)
file = open('SouthKorea_daily_cases_table_19M58417.html', 'w')
file.write(styled_object.render())

# %% [markdown]
# 6. In this step, we hope to know the ranking of South Korea in terms of the number of cases. And from the result, we know South Korea's ranking is **54**.

# %%
df = pd.read_csv("../input/novel-corona-virus-2019-dataset/covid_19_data.csv", header = 0)
df_country = df[df['ObservationDate'] == '06/06/2020']
df_country = df_country.groupby(['Country/Region']).sum().sort_values(by='Confirmed',ascending=False).reset_index()
print(df_country[df_country['Country/Region'] == 'South Korea'].index.values[0] + 1)

# %% [markdown]
# # Conclusion of Analysis
# 1. Through our calculation, the global ranking of South Korea in terms of the number of cases is 54.
# 2. Through the time series chart we have made, we find out that the number of new cases per day in South Korea began to decrease after 03 / 03 / 2020. In addition, we can find out that the day with the largest daily cases is 03 / 03 / 2020, during which 851 851 cases is increased.

# %% [markdown]
# # South Korea's Method against Covid-19
# 1. The covid-19 in South Korea began to break out on 02 / 20 / 2020. It was first spread through the “Shincheonji Church of Jesus”. It was also the most serious epidemic area in early Asia except China. But South Korea controlled the outbreak on March 3, and the number of new cases per day began to decline, only taking 14 days. It can be said that the performance of the Korean government is relatively excellent, so why?
# 2. The most important point is that South Korea has greatly improved the virus detection efficiency, reaching 20000 every day. So that Korea can quickly and accurately detect. At the same time, South Korea began to conduct free testing for the public very early, so the number of tests completed in South Korea every day is many times that of other countries.
# 3. March 23, Covid-19 alert level was raised to the highest level only 2 days after the outbreak, and the largest blockade was imposed on Daegu and Gyeongbuk. The strict blockade system will prevent the epidemic from spreading throughout the country.
# 4. After controlling the epidemic situation, South Korea did not relax its vigilance and took measures to prohibit the entry of foreign personnel or quarantine them for 14 days.
