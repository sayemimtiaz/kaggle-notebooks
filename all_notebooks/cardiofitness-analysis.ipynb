# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
#pip install scipy

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv('/kaggle/input/cardiogoodfitness/CardioGoodFitness.csv', delimiter=',', nrows = 1000)
df.dataframeName = 'CardioGoodFitness.csv'
nRow, nCol = df.shape
print(f'There are {nRow} rows and {nCol} columns')

# %%
df

# %%
df.describe(include="all")

# %%
df.hist(figsize=(20,30))

# %%
import seaborn as sns

# %%
sns.boxplot(x="Gender",y="Age",palette="pastel",data=df)

# %% [markdown]
# #is there difference in preference of Man and woman in products

# %%
pd.crosstab(df['Product'],df['Gender'])

# %%
pd.crosstab(df['Product'],df['MaritalStatus'])

# %%
sns.countplot(x="Product",hue="Gender",data=df)

# %%
pd.pivot_table(df,index=["Product","Gender"],columns=["MaritalStatus"],aggfunc=len)

# %%
sns.pairplot(df)

# %%
sns.distplot(df['Age'])

# %%
df['Age'].mean()

# %%
import statistics as st
st.stdev(df['Age'])

# %%
df.hist(by="Gender",column="Age")

# %%
 df.corr()

# %%
sns.heatmap(df.corr(),annot=True)

# %%
from sklearn import linear_model
regr=linear_model.LinearRegression()
y=df['Miles']
x=df[['Usage','Fitness']]
regr.fit(x,y)

# %%
regr.coef_

# %%
regr.intercept_

# %%
#MilesPredicted=20.21486334*Usage+27.20649954*Fitness -56.74288178464862

# %%
df.cov()
