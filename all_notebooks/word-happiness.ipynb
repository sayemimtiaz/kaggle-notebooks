# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns # visualization tools

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
data5=pd.read_csv("/kaggle/input/world-happiness/2015.csv") # all imported .csv data 
data6=pd.read_csv("/kaggle/input/world-happiness/2016.csv")
data7=pd.read_csv("/kaggle/input/world-happiness/2017.csv")
data8=pd.read_csv("/kaggle/input/world-happiness/2018.csv")
data9=pd.read_csv("/kaggle/input/world-happiness/2019.csv")

# %%
data5.head()  # ı saw content to data

# %%
data5[data5["Country"]=="Turkey"]

# %% [markdown]
# I want to see the change in happiness values of countries according to years.
#
# For this I will only keep the happiness score and delete other data.

# %%
data5.columns

# %%
data5.drop(['Happiness Rank','Region','Standard Error', 'Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
       'Generosity', 'Dystopia Residual'],axis=1,inplace=True)
# ı deleted the other columns

# %%
data5.head()

# %%
data6.columns

# %%
data6.drop(['Happiness Rank','Region','Lower Confidence Interval', 'Upper Confidence Interval',
       'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
       'Freedom', 'Trust (Government Corruption)', 'Generosity',
       'Dystopia Residual'],axis=1,inplace=True)

# %%
data6.head()

# %%
data7.columns

# %%
data7.drop(['Happiness.Rank','Whisker.high',
       'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
       'Health..Life.Expectancy.', 'Freedom', 'Generosity',
       'Trust..Government.Corruption.', 'Dystopia.Residual'],axis=1,inplace=True)

# %%
data7.head()

# %%
data8.columns

# %%
data8.drop(['Overall rank','GDP per capita',
       'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption'],axis=1,inplace=True)

# %%
data8.head()

# %%
data9.columns

# %%
data9.drop(['Overall rank','GDP per capita',
       'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption'],axis=1,inplace=True)

# %%
data8.head()

# %%
data5.columns=[i.replace(" ","_") for i in data5.columns]
data6.columns=[i.replace(" ","_") for i in data6.columns]
data7.columns=[i.replace(".","_") for i in data7.columns]
data8.columns=[i.replace(" ","_") for i in data8.columns]
data9.columns=[i.replace(" ","_") for i in data9.columns]
# I replace the spaces in the column names with underscores in order to operate on the data.

# %%
data8.rename(columns={"Country_or_region":"Country","Score":"Happiness_Score","Overall_rank":"Happiness_Rank"},inplace=True)
data9.rename(columns={"Country_or_region":"Country","Score":"Happiness_Score","Overall_rank":"Happiness_Rank"},inplace=True)

# we have synchronized all columns names

# %%
data5.info # have 158 rows in data5

# %%
# data5["Year"]=[2015 for i in range(1,159)]
# data6["Year"]=[2016 for i in range(1,158)]
# data7["Year"]=[2017 for i in range(1,156)]
# data8["Year"]=[2018 for i in range(1,157)]
# data9["Year"]=[2019 for i in range(1,157)]

# add new column in data it is name is year

# %%
data5_filter=data5.index<101
data6_filter=data6.index<101
data7_filter=data7.index<101
data8_filter=data8.index<101
data9_filter=data9.index<101

#apply filter

# %%
data5.columns

# %%
new_data=pd.merge(data5[data5_filter],data6[data6_filter],right_index=True,left_index=True,suffixes=('_2015','_2016'))

new_data1=pd.merge(data7[data7_filter],data8[data8_filter],right_index=True,left_index=True,suffixes=("_2017","_2018"))

new_data_end=pd.merge(new_data,new_data1,right_index=True,left_index=True,suffixes=("",""))

# %%
new_data_end[60:80]

# %%
new_data_end.describe()
