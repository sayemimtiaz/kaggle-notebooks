# %%
import pandas as pd
import numpy as np

# %%
covid=pd.read_csv("../input/coronavirusdataset/Case.csv")

# %%
patient=pd.read_csv("../input/coronavirusdataset/PatientInfo.csv")

# %%
Policy=pd.read_csv("../input/coronavirusdataset/Policy.csv")

# %%
region=pd.read_csv("../input/coronavirusdataset/Region.csv")

# %%
SearchTrend=pd.read_csv("../input/coronavirusdataset/SeoulFloating.csv")

# %%
time=pd.read_csv("../input/coronavirusdataset/Time.csv")

# %%
timeage=pd.read_csv("../input/coronavirusdataset/TimeAge.csv")

# %%
timegender=pd.read_csv("../input/coronavirusdataset/TimeGender.csv")

# %%
timeprovince=pd.read_csv("../input/coronavirusdataset/TimeProvince.csv")

# %%
weather=pd.read_csv("../input/coronavirusdataset/Weather.csv")

# %%
region.head()

# %%
Patientinfo.head()

# %%
np.where(np.isnan(infection))

# %%
np.isnan(patient['infection_case'])

# %%
patient = patient[patient['infection_case'].notna()]

# %%
for i in patient['infection_case']:
    print(i)

# %%
for i in patient['infection_case']:
    if "Church" in i:
        i="Church"
        print(i)
    else:
        i="Not Church"
        print(i)

# %%
def church(x):
    if "Church" in x:
        x="Church"
        return x
    elif "etc" in x:
        x="etc"
    else:
        x="Not Church"
        return x

# %%
patient['infection_church']=patient['infection_case'].apply(church)

# %%
patient.head()

# %%
x=patient.groupby("infection_church").count()['patient_id']

# %%
x[1]

# %%
import seaborn as sns

# %%
sns.countplot(x="infection_church",data=patient)

# %%
church= Patientinfo['patient_id'].groupby(Patientinfo['infection_case'])

# %%
church

# %%
infection=church.count()

# %%
Patientinfo.info()

# %%
import matplotlib as plt

# %%
plt.
