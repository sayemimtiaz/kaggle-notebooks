# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv("/kaggle/input/character-encoding-examples/file_guide.csv")
df

# %%
df['File'][0]

# %%
"/kaggle/input/character-encoding-examples/" + df['File'][0]

# %%
# !ls -l /kaggle/input/character-encoding-examples/

# %%
import chardet

with open("/kaggle/input/character-encoding-examples/die_ISO-8859-1.txt", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(83418))
result

# %%
with open("/kaggle/input/character-encoding-examples/die_ISO-8859-1.txt", 'rb') as rawdata:
    with open("utf8-die_ISO-8859-1.txt", "wb") as file:
        file.write(rawdata.read(83418).decode('ISO-8859-1').encode())

# %%
# !ls -l /kaggle/working/

# %%
df['File'][1]

# %%
# !ls -l /kaggle/input/character-encoding-examples/harpers_ASCII.txt

# %%
with open("/kaggle/input/character-encoding-examples/harpers_ASCII.txt", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(173439))
result

# %%
with open("/kaggle/input/character-encoding-examples/harpers_ASCII.txt", 'rb') as rawdata:
    with open("utf8-harpers_ASCII.txt", "wb") as file:
        file.write(rawdata.read(173439).decode('ascii').encode())
# !ls -l /kaggle/working/utf8-harpers_ASCII.txt

# %%
df['File'][2]

# %%
# !ls -l /kaggle/input/character-encoding-examples/olaf_Windows-1251.txt

# %%
with open("/kaggle/input/character-encoding-examples/olaf_Windows-1251.txt", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(29512))
result

# %%
with open("/kaggle/input/character-encoding-examples/olaf_Windows-1251.txt", 'rb') as rawdata:
    with open("utf8-olaf_Windows-1251.txt", "wb") as file:
        file.write(rawdata.read(29512).decode('windows-1251').encode())
# !ls -l /kaggle/working/utf8-olaf_Windows-1251.txt

# %%
df['File'][3]

# %%
# !ls -l /kaggle/input/character-encoding-examples/portugal_ISO-8859-1.txt

# %%
with open("/kaggle/input/character-encoding-examples/portugal_ISO-8859-1.txt", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(93567))
result

# %%
with open("/kaggle/input/character-encoding-examples/portugal_ISO-8859-1.txt", 'rb') as rawdata:
    with open("utf8-portugal_ISO-8859-1.txt", "wb") as file:
        file.write(rawdata.read(93567).decode('windows-1251').encode())
# !ls -l /kaggle/working/utf8-portugal_ISO-8859-1.txt

# %%
df['File'][4]

# %%
# !ls -l /kaggle/input/character-encoding-examples/shisei_UTF-8.txt

# %%
with open("/kaggle/input/character-encoding-examples/shisei_UTF-8.txt", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(564876))
result

# %%
with open("/kaggle/input/character-encoding-examples/shisei_UTF-8.txt", 'rb') as rawdata:
    with open("utf8-shisei_UTF-8.txt", "wb") as file:
        file.write(rawdata.read(564876).decode('UTF-8-SIG').encode())
# !ls -l /kaggle/working/utf8-shisei_UTF-8.txt

# %%
df['File'][5]

# %%
# !ls -l /kaggle/input/character-encoding-examples/yan_BIG-5.txt

# %%
with open("/kaggle/input/character-encoding-examples/yan_BIG-5.txt", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(24785))
result

# %%
with open("/kaggle/input/character-encoding-examples/yan_BIG-5.txt", 'rb') as rawdata:
    with open("utf8-yan_BIG-5.txt", "wb") as file:
        file.write(rawdata.read(24785).decode('Big5').encode())
# !ls -l /kaggle/working/utf8-yan_BIG-5.txt

# %%
# !ls -l /kaggle/input/character-encoding-examples/*txt

# %%
# !ls -l /kaggle/working/*txt

# %%
# !wc -l /kaggle/input/character-encoding-examples/*txt

# %%
# !wc -l /kaggle/working/*txt

# %%
# !tail /kaggle/input/character-encoding-examples/harpers_ASCII.txt

# %%
# !tail /kaggle/working/utf8-harpers_ASCII.txt

# %%
# !ls -l /kaggle/input/character-encoding-examples/shisei_UTF-8.txt /kaggle/working/utf8-shisei_UTF-8.txt

# %%
# !diff /kaggle/input/character-encoding-examples/shisei_UTF-8.txt /kaggle/working/utf8-shisei_UTF-8.txt
