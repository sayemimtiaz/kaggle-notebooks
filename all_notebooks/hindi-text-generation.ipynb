# %%
# !pip install torch==1.3.1+cpu -f https://download.pytorch.org/whl/torch_stable.html
# !pip install inltk

# %%
import numpy as np 
import pandas as pd
from inltk.inltk import setup

# %%
data = pd.read_csv('../input/hindienglish-corpora/Hindi_English_Truncated_Corpus.csv')
data.head()

# %% [markdown]
# **Downloading the model**

# %%
# Ignore the error
setup("hi")

# %%
text = data.hindi_sentence[1]
text

# %% [markdown]
# **Tokenize**

# %%
from inltk.inltk import tokenize
tokenize(data.hindi_sentence[1],"hi")

# %% [markdown]
# **Generating Sentence Generation**

# %%
from inltk.inltk import get_similar_sentences

get_similar_sentences(text, 3, 'hi', degree_of_aug = 0.1)
