# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import numpy as np
import matplotlib.pyplot as plt

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

from sklearn.ensemble import BaggingRegressor, RandomForestRegressor

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import seaborn as se
df = pd.read_csv('/kaggle/input/titanic/train.csv')
dft = pd.read_csv('/kaggle/input/titanic/test.csv')

# %%
df

# %%
dft

# %%
df.Sex = df.Sex.replace({'male':0,'female':1}) # мужчины - 0, женщины - 1

# %%
df[['Sex','Pclass','Survived', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']].corr()

# %%
se.heatmap(data = df[['Sex','Pclass','Survived', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']].corr())

# %%
df.nunique()

# %%
df.info()

# %%
titles = df.Name.apply(lambda name: name.split(',')[1].split('.')[0].strip()) 
print(titles.unique())

# %%
titles = dft.Name.apply(lambda name: name.split(',')[1].split('.')[0].strip()) # уникальный титул - Dona
print(titles.unique())

# %%
df.Embarked.fillna(df.Embarked.mode()[0], inplace = True)

# %%
df.Age.fillna(df.Age.mean(), inplace=True)

# %%
df.Embarked = df.Embarked.replace({'Q':0,'S':1,'C':2})

# %%
X = df[['Pclass', 'Sex', 'Age', 'Fare', 'Embarked']]
y = df.Survived

# %%
X.shape, y.shape

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = DecisionTreeRegressor(min_samples_leaf=2).fit(X,y)

# %%
model.fit(X,y)

# %%
X.values[10]

# %%
dft.Sex = dft.Sex.replace({'male':0, 'female':1})
dft.Embarked = dft.Embarked.replace({'Q':0,'S':1,'C':2})
df.Embarked.fillna(df.Embarked.mode()[0], inplace = True)
dft.Age.fillna(dft.Age.mean(), inplace=True)
dft.Fare.fillna(dft.Fare.mean(), inplace=True)

# %%
X_test = dft[['Pclass', 'Sex', 'Age', 'Fare', 'Embarked']]

# %%
X_test.shape

# %%
result = np.around(model.predict(X_test).astype(np.int64))

# %%
result

# %%
df_result = pd.DataFrame({'PassengerId':dft.PassengerId, 'Survived':result})

# %%
df_result

# %%
df_result.to_csv('submission.csv', index=False, header=True)
