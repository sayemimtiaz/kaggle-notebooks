# %% [markdown]
# # ***Analysis of "us_covid19_daily***

# %%
# %matplotlib inline
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings

# %%
dataset= pd.read_csv("../input/covid19-in-usa/us_covid19_daily.csv")

# %%
dataset

# %%
type(dataset)

# %%
dataset.shape

# %%
dataset.columns

# %%
dataset.dtypes

# %%
dataset.info()

# %%
# Check the NULL VAlues
dataset.isnull().sum()

# %%
dataset.describe()

# %%
dataset['Month'] = dataset.date.astype(str).str[4:6].astype(float)
dataset['day'] = dataset.date.astype(str).str[6:8].astype(float)

# %%
dataset.drop(["date"], axis = 1, inplace = True)
dataset

# %%
sns.displot(x = "Month", y = "totalTestResults", data = dataset)

# %%
sns.catplot(x = "Month", y = "totalTestResults" , data = dataset)

# %%
# Fillna solution with the purpose of dealing with missing values
dataset_fillna = dataset.copy()
dataset_fillna.fillna(dataset_fillna.mean(), inplace = True)
df = dataset_fillna

# %%
df.isnull().sum()

# %%
X = df[["positive", "pending","inIcuCurrently","Month"]].values
y = df[["totalTestResults"]].values

# %%
X

# %%
y

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state= 26)

# %%
print(X_test)

# %%
print(X_train)

# %%
y_train

# %%
y_test

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
y_train = sc.fit_transform(y_train)
y_test = sc.transform(y_test)

# %%
X_test

# %%
y_test

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# %%
predictions2=regressor.predict(X_train)

# %%
predictions=regressor.predict(X_test)

# %%
sns.histplot(y_test-predictions)

# %%
print('Training , Mean Squared Error:', metrics.mean_squared_error(y_train, predictions2)) 
print('Mean Squared Error:', metrics.mean_squared_error(y_test, predictions))

# %%
sns.displot(dataset, x="totalTestResults",bins=6)

# %%
sns.displot(dataset, x="states",kind="kde")

# %%
sns.displot(dataset, x="death",kind="kde", fill="True")

# %%
sns.catplot(x="Month", y="death", data=dataset,kind="swarm")

# %%
sns.relplot(x="Month", y="death", hue="total", data=dataset)
