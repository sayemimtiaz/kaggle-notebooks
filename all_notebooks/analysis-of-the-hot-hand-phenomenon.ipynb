# %% [markdown]
# # Analysis of the Hot Hand Phenomenon in the 2014-2015 NBA season

# %% [markdown]
# by Jason Bedford http://jbedford.net/

# %% [markdown]
# ### Introduction
# After reading this article in The Economist http://www.economist.com/blogs/gametheory/2015/06/hot-streaks-basketball I wanted to do a very simple experiment to see for me self.
#
# ### The Data
# I got the data from here: https://www.kaggle.com/dansbecker/nba-shot-logs

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("../input/shot_logs.csv")

# %%
df.columns

# %% [markdown]
# Note that the data does not include free throws. Here we're interested in the SHOT_RESULT column. First let's take a look at the SHOT_RESULTs for all shots in the season

# %%
df['SHOT_RESULT'].value_counts()

# %%
57905/(70164.+57905.)

# %% [markdown]
# So %45 of all shots taken were made (I'm going to call this the made percentage from now on). Not what we're going to do it is ast the qustion: Given that a player has made the previous n shots what is his made percentage for the current shot.

# %% [markdown]
# ### Restructuring the dataframe.
# I would like for each row to be one player in one game and the columns to be the results fo the shots taken in that game. This can be made by:

# %%
df = df.set_index(['player_name','MATCHUP','SHOT_NUMBER'])\
.sort_index()['SHOT_RESULT'].unstack()

# %%
df.index = df.index.droplevel()
df.fillna(value=np.nan, inplace=True)

# %%
df.head()

# %% [markdown]
# So the most shots taken by a player in a single game is 38. Most players take fewer and therfore have some NaN values.

# %%
from operator import add

for jj in range(1,8):# number of consecutive shots 
    total = 0
    made = 0
    for ii in range(1,38-jj+1):# shots taken (for a player in a game)
        total += (df[list(map(add, [ii-1]*(jj+1), range(1,(jj+1))))]=='made').all(axis=1).sum()
        made +=  (df[list(map(add, [ii-1]*(jj+1), range(1,(jj+2))))]=='made').all(axis=1).sum()
    print('---n = ',jj)
    print('make percentage: ',made/float(total))
    print('n shots were consecutively: ',total)

# %% [markdown]
# Interesting it looks like the make percentage starts off by decreasing before bouncing back up to where it starts. Note that the whole time it's still less that the season average make percentage. There is a problem with this analysis .... and that is that I don't know what make percentages would lead me to rejecting the null-hypothesis (that there is no 'hot hand')

# %% [markdown]
# ### Next up...
#
# I Really should be using the geometric distribution... stay tuned.
