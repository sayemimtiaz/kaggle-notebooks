# %% [markdown]
# ### Country-wise Analytics & Visualization Using Tableau-Public On Last 20 Years Of Tennis Data.

# %%
# %%html
# <img src="https://miro.medium.com/max/3840/1*I0kll37TSf-dCX73M_0tVg.jpeg">

# %% [markdown]
# ### | “The Big 3 are not chasing history, they are just chasing each other”
# Vijay Amritraj said this in an interview post corona virus lockdown which actually changed the way we watch sports these days, with all the empty stadiums to all the fake audience voices — we have come to a very dark place at the moment! I’ve been a huge tennis fan since the last decade or so, recently getting into data science has made me love tennis even more! I’ve been experimenting my so called “data skills” which I have acquired in these last 6 months on this beautiful sport “Tennis” kind of helping me understand the sport as well as the whole “data science” picture as I’ve been studying this subject and implementing it on something which is soo close to my heart gives me another aspect of looking at things which I actually wasn’t really able to while practicing my skills!

# %% [markdown]
# #### Introduction:
#
# So, this analysis is basically a country wise analysis of tennis data set which is publicly available on GitHub.
# The huge 20 years dataset prepared by Jeff Sackmann contains information on every single match played since 2000. with details on every match’s date, location, tournament type, surface, winner and loser, games/sets played, duration and additional statistics such as players’ rankings, players’ age and height, aces, double faults, break points faced and saved, service points among other helpful stats for both players of the match.

# %% [markdown]
# ...
# This is my first Tableau Representation and an article, i think will help people getting into this on their own, this will basically cover the basic Jupyter EDA and Visualizations.
# the basic goal of the analysis is to check out which part of the world is following the tennis world better and obviously looking at the big three which cannot actually be ignored if we talk about this sport!

# %% [markdown]
# - “Roger Federer”
# - “Novak Djokovic”
# - “Rafael Nadal”
#
# and to see how amazingly well they have dominated the whole sport for the last 2 DECADES, but first let’s do some basic EDA about the top countries as well as their top player first!

# %% [markdown]
# #### Loading The Basic Libraries:

# %%
from IPython.display import Image
from IPython.core.display import HTML
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import xticks
from scipy.stats import skew
import seaborn as sns
import os
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %% [markdown]
# #### Creating Columns for the data set which can be taken from the dictionary available:

# %%
cols = [
    'tourney_id', 
    'tourney_name', 
    'surface', 
    'draw_size', 
    'tourney_level',
    'tourney_date', 
    'match_num', 
    'winner_id', 
    'winner_seed', 
    'winner_entry',
    'winner_name',
    'winner_hand', 
    'winner_ht', 
    'winner_ioc', 
    'winner_age', 
    'winner_rank', 
    'winner_rank_points', 
    'loser_id',
    'loser_seed',
    'loser_entry',
    'loser_name',
    'loser_hand',
    'loser_ht',
    'loser_ioc',
    'loser_age',
    'loser_rank',
    'loser_rank_points',
    'score',
    'best_of', 
    'round',
    'minutes', 
    'w_ace', 
    'w_df', 
    'w_svpt',
    'w_1stIn', 
    'w_1stWon', 
    'w_2ndWon',
    'w_SvGms', 
    'w_bpSaved', 
    'w_bpFaced',
    'l_ace',
    'l_df',
    'l_svpt',
    'l_1stIn',
    'l_1stWon',
    'l_2ndWon',
    'l_SvGms',
    'l_bpSaved',
    'l_bpFaced'
]

# %% [markdown]
# #### As we have all the separate 20 years worth of data, we will have to load it in a single dataframe by using the “pd.concat” function which will combine all of these in 1:

# %%
ltennis = pd.concat([
    pd.read_csv('../input/atp-masters-tennis-dataset/atp_matches_2000.csv', usecols=cols),
    pd.read_csv('../input/atp-masters-tennis-dataset/atp_matches_2001.csv', usecols=cols),
    pd.read_csv('../input/atp-masters-tennis-dataset/atp_matches_2002.csv', usecols=cols),
    pd.read_csv('../input/atp-masters-tennis-dataset/atp_matches_2003.csv', usecols=cols),
    pd.read_csv('../input/atp-masters-tennis-dataset/atp_matches_2004.csv', usecols=cols),
    pd.read_csv('../input/atp-masters-tennis-dataset/atp_matches_2005.csv', usecols=cols),
    pd.read_csv('../input/atp-masters-tennis-dataset/atp_matches_2006.csv', usecols=cols),
    pd.read_csv('../input/atp-masters-tennis-dataset/atp_matches_2007.csv', usecols=cols),
    pd.read_csv('../input/atp-masters-tennis-dataset/atp_matches_2008.csv', usecols=cols),
    pd.read_csv('../input/atp-masters-tennis-dataset/atp_matches_2009.csv', usecols=cols),
    pd.read_csv('../input/atp-masters-tennis-dataset/atp_matches_2010.csv', usecols=cols),
    pd.read_csv('../input/atp-masters-tennis-dataset/atp_matches_2011.csv', usecols=cols),
    pd.read_csv('../input/atp-masters-tennis-dataset/atp_matches_2012.csv', usecols=cols),
    pd.read_csv('../input/atp-masters-tennis-dataset/atp_matches_2013.csv', usecols=cols),
    pd.read_csv('../input/atp-masters-tennis-dataset/atp_matches_2014.csv', usecols=cols),
    pd.read_csv('../input/atp-masters-tennis-dataset/atp_matches_2015.csv', usecols=cols),
    pd.read_csv('../input/atp-masters-tennis-dataset/atp_matches_2016.csv', usecols=cols),
    pd.read_csv('../input/atp-masters-tennis-dataset/atp_matches_2017.csv', usecols=cols),
    pd.read_csv('../input/atp-masters-tennis-dataset/atp_matches_2018.csv', usecols=cols),
    pd.read_csv('../input/atp-masters-tennis-dataset/atp_matches_2019.csv', usecols=cols),
    pd.read_csv('../input/atp-masters-tennis-dataset/atp_matches_2020.csv', usecols=cols),
    pd.read_csv('../input/atp-masters-tennis-dataset/atp_matches_2021.csv', usecols=cols),

],ignore_index=True) #have to make sure that the index will not be duplicated

ltennis.tail()

# %%
ltennis.info()

# %% [markdown]
# #### Arranging time and date

# %%
ltennis['tourney_date'] = pd.to_datetime(ltennis.tourney_date, format='%Y%m%d')
ltennis = ltennis.sort_values(['tourney_date'])

# %%
ltennis['tourney_yearmonth'] = ltennis.tourney_date.astype(str).str[:6]
ltennis['tourney_year'] = ltennis.tourney_date.astype(str).str[:4]
ltennis['tourney_year'] = ltennis['tourney_year'].astype(int)

# %% [markdown]
# #### Country Wise Analysis:

# %%
ltennis_country= ltennis[['winner_ioc','tourney_level','round']]

# %%
ltennis_country = ltennis_country[(ltennis_country.tourney_level == 'G')]

# %%
ltennis_country.count()

# %%
plt.figure(figsize=(200, 5))

plt.subplot(1,9,1)
plt1 = ltennis_country.winner_ioc.value_counts()[:-10].plot(kind='bar')
plt.title('TOTAL GRAND SLAM MATCH WINS')
plt1.set(xlabel = 'Country', ylabel='Wins')

# %% [markdown]
# #### Top 5 Countries with the most tennis wins are:
# 1. Spain
# 2. France
# 3. USA
# 4. Argentina
# 5. Switzerland

# %%
ltennis_countryl= ltennis[['loser_ioc','tourney_level','round']]

# %%
ltennis_countryl = ltennis_countryl[(ltennis_countryl.tourney_level == 'G')]

# %%
ltennis_countryl.head()

# %%
plt.figure(figsize=(200, 5))

plt.subplot(1,9,1)
plt1 = ltennis_countryl.loser_ioc.value_counts()[:-10].plot(kind='bar')
plt.title('TOTAL GRAND SLAM MATCH LOSSES')
plt1.set(xlabel = 'Country', ylabel='Wins')

# %% [markdown]
# #### Top 5 Countries with the most tennis losses are:
# 1. France
# 2. Spain
# 3. USA
# 4. Germany
# 5. Australia

# %%
count4 = ltennis_country.winner_ioc.value_counts()

# %%
count4.head()

# %%
count4.to_csv('winsings.csv')

# %% [markdown]
# ### Let's analyse the top 5 countries and their top 5 players!

# %% [markdown]
# #### Doing for Spain

# %%
esp = ltennis[['winner_ioc','tourney_level','winner_name']]

# %%
esp = esp[(esp.tourney_level == 'G') & (esp.winner_ioc == 'ESP')]

# %%
esp.head()

# %%
count5 = esp.winner_name.value_counts()

# %%
count5.head()

# %%
count5.to_csv('esptop.csv')

# %% [markdown]
# #### For France:

# %%
fra = ltennis[['winner_ioc','tourney_level','winner_name','round']]

# %%
fra = fra[(fra.tourney_level == 'G') & (fra.winner_ioc == 'FRA')]

# %%
fra.head()

# %%
count6 = fra.winner_name.value_counts()

# %%
count6.to_csv('fratop.csv')

# %%
fra.head()

# %% [markdown]
# #### For USA

# %%
usa = ltennis[['winner_ioc','tourney_level','winner_name']]

# %%
usa = usa[(usa.tourney_level == 'G') & (usa.winner_ioc == 'USA')]

# %%
usa.head()

# %%
count7 = usa.winner_name.value_counts()

# %%
count7.to_csv('usatop.csv')

# %% [markdown]
# #### For Argentina:

# %%
arg = ltennis[['winner_ioc','tourney_level','winner_name']]

# %%
arg = arg[(arg.tourney_level == 'G') & (arg.winner_ioc == 'ARG')]

# %%
arg.head()

# %%
count8 = arg.winner_name.value_counts()

# %%
count8.to_csv('argtop.csv')

# %% [markdown]
# #### For Switzerland:

# %%
sui = ltennis[['winner_ioc','tourney_level','winner_name']]

# %%
sui = sui[(sui.tourney_level == 'G') & (sui.winner_ioc == 'SUI')]

# %%
sui.head()

# %%
count9 = sui.winner_name.value_counts()

# %%
count9.to_csv('suitop.csv')

# %% [markdown]
# #### For further analysis we will have to import all the data frames to csv as we will be able to visualize them in tableau.

# %%
ltennis_country.to_csv('ltennis_country.csv')

# %%
asd1 = pd.read_csv('ltennis_country.csv')

# %%
asd1.head()

# %%
asd1.count()

# %%
plt.figure(figsize=(100, 5))

plt.subplot(1,9,1)
plt1 = asd1.winner_ioc.value_counts().plot(kind='bar')
plt.title('TOTAL GRAND SLAM WINS')
plt1.set(xlabel = 'Country', ylabel='Wins')

# %%
asd1.to_csv('topcgs.csv')

# %%
ltennis.to_csv('ltennis.csv')

# %%
indv1 = pd.read_csv('../input/modifiedatp/ltennisindv.csv')

# %%
indv2 = indv1[['winner_ioc','winner_name','tourney_level','Round']]

# %%
indv2 = indv2[(indv2.tourney_level == 'G') & (indv2.Round == 'F')]

# %%
indv2.head()

# %%
indv2.count()

# %%
plt.figure(figsize=(100, 5))

plt.subplot(1,9,1)
plt1 = indv2.winner_name.value_counts().plot(kind='bar')
plt.title('TOTAL GRAND SLAM WINS Player Wise')
plt1.set(xlabel = 'Country', ylabel='Wins')

# %%
indv2.to_csv('indv2.csv')

# %%
indv3 = indv1[['winner_ioc','winner_name','tourney_level','Round','tourney_name']]

# %%
indv3 = indv3[(indv3.tourney_level == 'G') & (indv3.Round == 'F')]

# %%
indv3.head()

# %%
indv3.to_csv('indv3.csv')

# %% [markdown]
# ### Visualizations:

# %% [markdown]
# #### matplotlib graphs aren’t really aesthetic to be shown soo all the graphs can be made better in Tableau:

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1622025550982' style='position: relative'><noscript><a href='#'><img alt='Dashboard 1 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;wi&#47;winsandlosses_16219327589030&#47;Dashboard1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='winsandlosses_16219327589030&#47;Dashboard1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;wi&#47;winsandlosses_16219327589030&#47;Dashboard1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1622025550982');                    var vizElement = divElement.getElementsByTagName('object')[0];                    if ( divElement.offsetWidth > 800 ) { vizElement.style.width='1000px';vizElement.style.height='827px';} else if ( divElement.offsetWidth > 500 ) { vizElement.style.width='1000px';vizElement.style.height='827px';} else { vizElement.style.width='100%';vizElement.style.height='1277px';}                     var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %% [markdown]
# #### As we can see the Top Countries Were (Wins):
# - Spain
# - France
# - USA
# - Argentina
# - Switzerland
#
# #### Also, According To losses:
# - France
# - Spain
# - USA
# - Germany
# - Australia
#
#
# Now Let’s Plot the Top Players from the top countries we have determined!

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1622025743727' style='position: relative'><noscript><a href='#'><img alt='Top Players in Spain With Most Victories in a Grand Slam ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;to&#47;topplayersSP&#47;Sheet1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='topplayersSP&#47;Sheet1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;to&#47;topplayersSP&#47;Sheet1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1622025743727');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1622025797527' style='position: relative'><noscript><a href='#'><img alt='Top Players in France With Most Victories in a Grand Slam ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;to&#47;topplayersFRANCE&#47;Sheet2&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='topplayersFRANCE&#47;Sheet2' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;to&#47;topplayersFRANCE&#47;Sheet2&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1622025797527');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1622025826934' style='position: relative'><noscript><a href='#'><img alt='Top Players in USA With Most Victories in a Grand Slam ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;to&#47;topplayersusa&#47;Sheet3&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='topplayersusa&#47;Sheet3' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;to&#47;topplayersusa&#47;Sheet3&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1622025826934');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1622025854855' style='position: relative'><noscript><a href='#'><img alt='Top Players in Argentina With Most Victories in a Grand Slam ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;to&#47;topplayersarg&#47;Sheet4&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='topplayersarg&#47;Sheet4' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;to&#47;topplayersarg&#47;Sheet4&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1622025854855');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %% [markdown]
# #### We can clearly see the BIG 3 domination here as well!
# Now Lets Plot some Country + Player combined graphs:

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1622025917551' style='position: relative'><noscript><a href='#'><img alt='Grandslam Wins By Individual Countries With Players: ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;to&#47;totalgswinsbyindv&#47;Sheet7&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='totalgswinsbyindv&#47;Sheet7' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;to&#47;totalgswinsbyindv&#47;Sheet7&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1622025917551');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1622025959274' style='position: relative'><noscript><a href='#'><img alt='Dashboard 1 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;da&#47;dashboard2_16219550770200&#47;Dashboard1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='dashboard2_16219550770200&#47;Dashboard1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;da&#47;dashboard2_16219550770200&#47;Dashboard1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1622025959274');                    var vizElement = divElement.getElementsByTagName('object')[0];                    if ( divElement.offsetWidth > 800 ) { vizElement.style.width='1000px';vizElement.style.height='827px';} else if ( divElement.offsetWidth > 500 ) { vizElement.style.width='1000px';vizElement.style.height='827px';} else { vizElement.style.width='100%';vizElement.style.height='777px';}                     var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %% [markdown]
# #### It’s been 20 years of pure dominance by the Big 3.
# Roger Federer, the record-holder for ATP Major Championships won and resident tennis maestro, leads the 3 with 20 major championships, including 8 Wimbledon Championships. Rafael Nadal, the undisputed King of Clay, holds 12 French Open Championships and 19 major wins overall.

# %% [markdown]
#  To round out the 3, Novak Djokovic collected 17 major championships over a dominating span of fewer than 11 years. To top it all off, the Big 3 have collected 56 of the 67 major championships held since Federer’s first title in 2003.

# %% [markdown]
# Even more so, they’ve gone on streaks of 18 and 11 straight wins without an outsider winning one (in 2005–2009 and 2010–2012), not to mention a current streak of 13.

# %% [markdown]
# one who have watched this unprecedented run wonder if the younger players are weaker than usual.
# More likely, three all-time-great champions — Federer, Nadal and Djokovic — have randomly risen up in the same era.
# They’re likely to be motivated by their rivals’ achievements, using the others’ wins as inspiration to improve their tactics.
#
# But don’t be too surprised if this continues for a while, even another year, as long as Federer, Nadal and Djokovic remain healthy. Djokovic, who has won the Australian Open six times, will be the favorite there in January, and Nadal might well be in shape for his 14th French Open title. That would bring this wild period of 30s dominance to 11 straight majors. But whatever happens, the chance of any generation matching this accomplishment in the future is slim perhaps kind of impossible!
