# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('../input/advertising-dataset/advertising.csv')

# %%
df.head()

# %%
df.shape

# %%
df.info()

# %%
sns.pairplot(df,diag_kind='kde')

# %%
df.corr()

# %%
sns.heatmap(df.corr(),cmap='Greens')

# %%
X=df.drop('Sales',axis=1)
y=df['Sales']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
X_train.shape

# %%
from sklearn.linear_model import LinearRegression
LinearModel = LinearRegression()
LinearModel.fit(X_train,y_train)

# %%
pd.DataFrame(LinearModel.coef_,X.columns,columns=['coeficient'])

# %%
y_pred = LinearModel.predict(X_test)

# %%
from sklearn import metrics
MAE = metrics.mean_absolute_error(y_test,y_pred)
MSE = metrics.mean_squared_error(y_test,y_pred)
RMSE = np.sqrt(MSE)

# %%
pd.DataFrame([MAE,MSE,RMSE],index = ['MAE','MSE','RMSE'],columns=['Metrics'])

# %%
df['Sales'].mean()

# %%
TestResiduals=y_test - y_pred
sns.scatterplot(x=y_test,y=y_pred)
plt.xlabel('Y_Test')
plt.ylabel('Y_Pred')

# %%
sns.distplot(TestResiduals,bins=25,kde=True)

# %%
sns.scatterplot(x=y_test,y=TestResiduals)
plt.axhline(y=0,color='r',ls='--')
