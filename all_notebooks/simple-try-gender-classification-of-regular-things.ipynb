# %% [markdown]
# # ***GENDER CLASSIFICATION***

# %% [markdown]
# import neccessary library

# %%
import pandas as pd
import numpy as np

# %%
#read the files
data = pd.read_csv("../input/gender-classification/Transformed Data Set - Sheet1.csv")

# %%
data.tail() #visual the tail end

# %% [markdown]
# Visualize the gender

# %%
import seaborn as sns
from sklearn import model_selection
b = sns.countplot(x='Gender', data=data)
b.set_xlabel("labels", fontsize=20)
b.set_ylabel("count", fontsize=20)

# %%
data.info()

# %%
data.isnull().sum()

# %%
#fetch the datatype in all features then its small data
objfeatures = data.select_dtypes(include = 'object').columns

# %%
type(data)

# %% [markdown]
# # **Ordinal encoding for feature engineering process**
# #preprocessing the process and choose label encoder

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
for feature in objfeatures:
    data[feature] = le.fit_transform(data[feature].astype(str))
    data.info()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot('Favorite Color', hue='Gender', data=data, palette='Reds')

# %% [markdown]
# # Visualize the every feature(Compare to gender VS other features)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot('Favorite Beverage', hue='Gender', data=data, palette='Reds')

# %%
sns.countplot('Favorite Soft Drink', hue='Gender', data=data, palette='Reds')

# %%
sns.countplot('Favorite Music Genre', hue='Gender', data=data, palette='Reds')

# %% [markdown]
# # feature selection

# %%
X = data.drop(['Gender'], axis = 1)
y = data.Gender

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# This below function identify the score and roc

# %%
def clf_scores(clf, y_predicted):
    # Accuracy
    acc_train = clf.score(X_train, y_train)*100
    acc_test = clf.score(X_test, y_test)*100
    
    roc = roc_auc_score(y_test, y_predicted)*100 
    tn, fp, fn, tp = confusion_matrix(y_test, y_predicted).ravel()
    cm = confusion_matrix(y_test, y_predicted)
    correct = tp + tn
    incorrect = fp + fn
    
    return acc_train, acc_test, roc, correct, incorrect, cm

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

from sklearn.linear_model import LogisticRegression
clf_lr = LogisticRegression()
clf_lr.fit(X_train, y_train)

Y_pred_lr = clf_lr.predict(X_test)
print(clf_scores(clf_lr, Y_pred_lr))

# %%
y= clf_lr.score(X_test,y_test)*100
y

# %%
from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier(n_neighbors = 5)
clf.fit(X_train,y_train)

# %%
preds = clf.predict(X_test)
print(clf_scores(clf,preds))

# %%
from sklearn.ensemble import RandomForestClassifier

clf_rfc = RandomForestClassifier(max_depth=50, random_state=42)
clf_rfc.fit(X_train, y_train)

Y_pred_rfc = clf_rfc.predict(X_test)
print(clf_scores(clf_rfc, Y_pred_rfc))

# %%
from sklearn.ensemble import GradientBoostingClassifier

clf_gbc = GradientBoostingClassifier(random_state=42)
clf_gbc.fit(X_train, y_train)

Y_pred_gbc = clf_gbc.predict(X_test)
print(clf_scores(clf_gbc, Y_pred_gbc))

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %%
from xgboost import XGBClassifier
xgboost = XGBClassifier(n_estimators=1000)
xgboost.fit(X_train,y_train)

# %%
Y_pred_xg = xgboost.predict(X_test)
print(clf_scores(xgboost, Y_pred_xg))
