# %% [markdown]
# ## Import libraries!

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import data set

# %%
df=pd.read_csv("/kaggle/input/world-happiness-report-2021/world-happiness-report.csv")

# %% [markdown]
# ### Get the basic information about data-set

# %%
df.head()

# %%
df.shape

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# ## 01. Check the Missing Values!

# %%
df.isna().sum()

# %% [markdown]
# ### There are some missing values in the most of the columns:
#    - lets check the percentage of Each:

# %%
per=df.isna().sum()/len(df)*100
per

# %% [markdown]
# ## 02. Clean the data:

# %% [markdown]
# 1st of all we will check the type of each column:

# %%
df.dtypes

# %% [markdown]
# ### let's Impute the missing values:

# %%
df["Social support"]=df["Social support"].fillna(df["Social support"].mean())
df["Healthy life expectancy at birth"]=df["Healthy life expectancy at birth"].fillna(df["Healthy life expectancy at birth"].mean())
df["Freedom to make life choices"]=df["Freedom to make life choices"].fillna(df["Freedom to make life choices"].mean())
df["Generosity"]=df["Generosity"].fillna(df["Generosity"].mean())
df["Perceptions of corruption"]=df["Perceptions of corruption"].fillna(df["Perceptions of corruption"].mean())
df["Positive affect"]=df["Positive affect"].fillna(df["Positive affect"].mean())
df["Negative affect"]=df["Negative affect"].fillna(df["Negative affect"].mean())
df["Log GDP per capita"]=df["Log GDP per capita"].fillna(df["Log GDP per capita"].mean())

# %%
df.isna().sum()

# %% [markdown]
# ### So our data is now clean:
# ### Lets do some analysis:

# %% [markdown]
# ## HAPINESS REPORT OF INDIA:

# %%
df=df.rename(columns={"Country name":"country"})
india=df[df["country"]=="India"]

# %%
india.dtypes

# %%
india

# %%
import plotly.graph_objects as go

# %%
ll

# %%
ll=india[["year","Life Ladder"]].sort_values("year")
fig=go.Figure(go.Bar(x=ll["year"],y=ll["Life Ladder"],marker_color = ['#00296f']* 10))
fig.update_layout(title_text='LIFE LADDER OVER THE YEARS',xaxis_title='YEAR')
fig.show()

# %%
plt.figure(figsize=(8,8))
sns.pointplot(x="year",y="Log GDP per capita",data=india)
plt.title("Log GDP per capita")
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.pointplot(x="year",y="Social support",data=india)
plt.title("Social support")
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.pointplot(x="year",y="Healthy life expectancy at birth",data=india)
plt.title("Healthy life expectancy at birth")
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.pointplot(x="year",y="Freedom to make life choices",data=india)
plt.title("Freedom to make life choices")
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.pointplot(x="year",y="Generosity",data=india)
plt.title("Generosity")
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.pointplot(x="year",y="Social support",data=india)
plt.title("Social support")
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.pointplot(x="year",y="Perceptions of corruption",data=india)
plt.title("Perceptions of corruption")
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.pointplot(x="year",y="Positive affect",data=india)
plt.title("Positive affect")
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.pointplot(x="year",y="Negative affect",data=india)
plt.title("Negative affect ")
plt.show()

# %%
df.head()

# %% [markdown]
# ## HAPINESS REPORT WITH RESPECTIVE NEIGBOURING COUNTRIES:

# %%
neighb= df[(df["country"]=="Bhutan") |(df["country"]=="China")|(df["country"]=='Nepal') |(df["country"]=='Afghanistan')|(df["country"]=='India')|(df["country"]=='Pakistan')|(df["country"]=='Bangladesh')|(df["country"]=='Myanmar')]

# %%
neighb.head(2)

# %%
neighb.dtypes

# %%
len(neighb)

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x="country",y="Life Ladder",data=neighb)

# %%
#plt.figure(figsize=(8,8))
#sns.barplot(x="country",y="Life Ladder",data=neighb)
fig=go.Figure(go.Bar(x=neighb["country"],y=neighb["Life Ladder"]))
fig.update_layout(title_text='NEIGHBOURING COUNTRIES WITH LIFE LADDER',xaxis_title='COUNTRIES',yaxis_title="LIFE LADDER")
fig.show()

# %%
neighbbour

# %%
df

# %%
top=df.groupby(df["country"])["Life Ladder"].sum().sort_values()[-20:].reset_index()
fig=go.Figure(go.Bar(x=top["country"],y=top["Life Ladder"]))
fig.update_layout(title_text="TOP 20 COUNTRIES WITH HIGEST LIFE LADDER")
fig.show()
