# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
heart=pd.read_csv('/kaggle/input/heart-disease-uci/heart.csv')

# %%
heart.head()

# %%
heart.info()

# %%
df1=heart.copy()
columns=list(df1.columns)
print(columns)

# %%
columns2=['age','sex','chest_pain_type','resting_blood_pressure','serum_cholestoral','fasting_blood_sugar',
     'resting_electrocardiographic_results','max_heart_rate','exercise_induced_angina','oldpeak','st_slope']+columns[11:]
#oldpeak= ST depression induced by exercise relative to rest
#'the slope of the peak exercise ST segment'
#'number of major vessels (0-3) colored by flourosopy'
#'thal'

# %%
print(columns2)

# %%
df1.columns=columns2

# %%
df1.head()

# %% [markdown]
# ## Univariate

# %%
sns.countplot(df1.st_slope)
#df1['st_slope'] = df1['st_slope'].map({0:'upsloping',1:'flat',2:'downsloping'})

# %%
sns.countplot(df1.resting_electrocardiographic_results)

#df1['rest_ecg'] = df1['rest_ecg'].map({0:'normal',1:'ST-T_wave_abnormality',2:'left_ventricular_hypertrophy'})

# %%
sns.countplot(df1.chest_pain_type)
#df1['chest_pain_type'] = df1['chest_pain_type'].map({3:'asymptomatic', 1:'atypical_angina', 2:'non_anginal_pain', 0:'typical_angina'})

# %%
sns.countplot(df1.fasting_blood_sugar)
#df1['fasting_blood_sugar'] = df1['fasting_blood_sugar'].map({0:'less_than_120mg/ml',1:'greater_than_120mg/ml'})

# %% [markdown]
# #### max_heart rate

# %%
sns.distplot(df1.max_heart_rate)
plt.axvline(df1.max_heart_rate.mean(),label='mean',color='red')
plt.axvline(df1.max_heart_rate.median(),label='median',color='yellow')
plt.legend()

# %%
sns.boxplot(df1.max_heart_rate)

# %%
df1.max_heart_rate.mean()

# %%
df1.max_heart_rate.median()

# %% [markdown]
# #### serum cholestrol

# %%
df1.serum_cholestoral.mean()

# %%
df1.serum_cholestoral.median()

# %%
sns.distplot(df1.serum_cholestoral)
plt.axvline(df1.serum_cholestoral.mean(),label='mean',color='red')
plt.axvline(df1.serum_cholestoral.median(),label='median',color='yellow')
plt.legend()

# %%
sns.boxplot(df1.serum_cholestoral)

# %% [markdown]
# #### age

# %%
plt.rcParams['figure.figsize']=[14,7]

# %%
sns.distplot(df1.age)
plt.axvline(df1.age.mean(),label='mean',color='red')
plt.axvline(df1.age.median(),label='median',color='yellow')
plt.legend()

# %%
df1.age.mean()

# %%
df1.age.median()

# %% [markdown]
# #### resting blood pressure

# %%
df1.resting_blood_pressure.mean()

# %%
df1.resting_blood_pressure.median()

# %%
sns.distplot(df1.resting_blood_pressure)
plt.axvline(df1.resting_blood_pressure.mean(),label='mean',color='red')
plt.axvline(df1.resting_blood_pressure.median(),label='median',color='yellow')
plt.legend()

# %%
sns.boxplot(df1.resting_blood_pressure)

# %% [markdown]
# #### sex

# %%
sns.countplot(df1.sex)

# %% [markdown]
# ## multivariate

# %%
sns.heatmap(df1.corr(),annot=True)

# %%
df1.head()

# %%
sns.pairplot(data=df1[['age', 'sex', 'chest_pain_type', 'resting_blood_pressure', 'serum_cholestoral', 'fasting_blood_sugar', 'resting_electrocardiographic_results', 'max_heart_rate', 'exercise_induced_angina', 'oldpeak', 'st_slope', 'ca', 'thal']])

# %%
sns.boxplot(x=df1['chest_pain_type'],y=df1['max_heart_rate'],data=df1)

# %%
sns.distplot(df1[(df1.chest_pain_type==0) & (df1.fasting_blood_sugar==1)]['max_heart_rate'],label='blood sugar>120typical_angina')
sns.distplot(df1[(df1.chest_pain_type==0) & (df1.fasting_blood_sugar==0)]['max_heart_rate'],label='bloodsugar<12typical_angina')
#sns.distplot(df1[df1.chest_pain_type==2]['max_heart_rate'],label='non_anginal_pain')
plt.legend()
#df1['chest_pain_type'] = df1['chest_pain_type'].map({3:'asymptomatic', 1:'atypical_angina', 2:'non_anginal_pain', 0:'typical_angina'})
#sns.distplot(df1[df1.chest_pain_type==4]['serum_cholestoral'])

# %%
sns.distplot(df1[(df1.chest_pain_type==0) & (df1.fasting_blood_sugar==1)]['max_heart_rate'],label='typical_angina')
sns.distplot(df1[(df1.chest_pain_type==1) & (df1.fasting_blood_sugar==1)]['max_heart_rate'],label='atypical_angina')
#sns.distplot(df1[df1.chest_pain_type==2]['max_heart_rate'],label='non_anginal_pain')
plt.legend()
#df1['chest_pain_type'] = df1['chest_pain_type'].map({3:'asymptomatic', 1:'atypical_angina', 2:'non_anginal_pain', 0:'typical_angina'})
#sns.distplot(df1[df1.chest_pain_type==4]['serum_cholestoral'])

# %%
sns.distplot(df1[(df1.chest_pain_type==0) & (df1.fasting_blood_sugar==0)]['max_heart_rate'],label='typical_angina')
sns.distplot(df1[(df1.chest_pain_type==1) & (df1.fasting_blood_sugar==0)]['max_heart_rate'],label='atypical_angina')
#sns.distplot(df1[df1.chest_pain_type==2]['max_heart_rate'],label='non_anginal_pain')
plt.legend()
#df1['chest_pain_type'] = df1['chest_pain_type'].map({3:'asymptomatic', 1:'atypical_angina', 2:'non_anginal_pain', 0:'typical_angina'})
#sns.distplot(df1[df1.chest_pain_type==4]['serum_cholestoral'])

# %%
sns.distplot(df1[df1.chest_pain_type==0]['max_heart_rate'],label='typical_angina')
sns.distplot(df1[df1.chest_pain_type==1]['max_heart_rate'],label='atypical_angina')
#sns.distplot(df1[df1.chest_pain_type==2]['max_heart_rate'],label='non_anginal_pain')
plt.legend()
#df1['chest_pain_type'] = df1['chest_pain_type'].map({3:'asymptomatic', 1:'atypical_angina', 2:'non_anginal_pain', 0:'typical_angina'})
#sns.distplot(df1[df1.chest_pain_type==4]['serum_cholestoral'])

# %%
sns.distplot(df1[df1.chest_pain_type==0]['serum_cholestoral'],label='typical_angina')
sns.distplot(df1[df1.chest_pain_type==1]['serum_cholestoral'],label='atypical_angina')
#sns.distplot(df1[df1.chest_pain_type==2]['serum_cholestoral'],label='non_anginal_pain')
plt.legend()
#df1['chest_pain_type'] = df1['chest_pain_type'].map({3:'asymptomatic', 1:'atypical_angina', 2:'non_anginal_pain', 0:'typical_angina'})
#sns.distplot(df1[df1.chest_pain_type==4]['serum_cholestoral'])

# %%
sns.swarmplot(x=df1.chest_pain_type,y=df1.resting_electrocardiographic_results)

# %%
sns.boxplot(x=df1['chest_pain_type'],y=df1['serum_cholestoral'],data=df1,hue=df1.fasting_blood_sugar)

# %%
sns.boxplot(x=df1['fasting_blood_sugar'],y=df1['max_heart_rate'],data=df1)

# %%
sns.boxplot(x=df1['chest_pain_type'],y=df1['resting_blood_pressure'],data=df1)

# %%
sns.boxplot(x=df1['fasting_blood_sugar'],y=df1['resting_blood_pressure'],data=df1)

# %%
sns.scatterplot(x=df1['age'],y=df1['serum_cholestoral'],data=df1)

# %%
sns.scatterplot(x=df1['age'],y=df1['resting_blood_pressure'],data=df1)

# %%
sns.scatterplot(df1.age,df1.max_heart_rate,data=df1)
plt.grid()

# %%
sns.swarmplot(df1.sex,df1.max_heart_rate,data=df1)
plt.grid()

# %%
sns.swarmplot(df1.sex,df1.resting_blood_pressure,data=df1)
