# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# **1. Load Libraries**

# %%
import pandas as pd
from pandas import DataFrame, Series
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LinearRegression

import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 2. Data Mining & Inspection

# %%
train = pd.read_csv('../input/loan-sanction-amount-prediction-data/train.csv',na_values=['?'])

# %%
test = pd.read_csv('../input/loan-sanction-amount-prediction-data/test.csv', na_values=['?'])

# %%
train.head()

# %% [markdown]
# ****

# %%
test.head()

# %%
train.shape

# %%
test.shape

# %%
print(train.info())
print('***********************************************')
print(test.info())

# %%
train.describe().T

# %%
test.describe().T

# %%
train.isnull().sum()/train.shape[0] *100

# %%
test.isnull().sum()/train.shape[0] *100

# %%
print(train.isnull().sum())
print('\n', test.isnull().sum())

# %%
train.head()

# %%
train["Income Stability"].value_counts()

# %%
train["Income Stability"].unique()

# %%
train["Type of Employment"].value_counts()

# %%
#Current Loan Expenses (USD)
train["Current Loan Expenses (USD)"].value_counts()

# %%
train["Expense Type 2"].value_counts()

# %%
train["Dependents"].value_counts()

# %%
train["Credit Score"].value_counts()

# %%
train["Has Active Credit Card"].value_counts()

# %%
train["Property Age"].value_counts()

# %%
train["Property Location"].value_counts()

# %%
train["Name"].unique()

# %%
train["Name"].value_counts()

# %%
train["Income (USD)"].value_counts()

# %%
train["Income (USD)"].value_counts()

# %% [markdown]
# ### 3. Data Cleaning

# %%
print(train.isnull().sum())
print('\n',test.isnull().sum())

# %% [markdown]
# As we can see that there are so many null values in dataset
# so now we can fill it with different methods of central tendency to fill null values

# %%
#On Training Dataset
train['Gender']= train['Gender'].fillna(train['Gender'].mode()[0])
train['Income (USD)']= train['Income (USD)'].fillna(train['Income (USD)'].mode()[0])
train['Income Stability']= train['Income Stability'].fillna(train['Income Stability'].mode()[0])
train['Type of Employment']= train['Type of Employment'].fillna(train['Type of Employment'].mode()[0])
train['Current Loan Expenses (USD)']= train['Current Loan Expenses (USD)'].fillna(train['Current Loan Expenses (USD)'].mode()[0])
train['Dependents']= train['Dependents'].fillna(train['Dependents'].mode()[0])
train['Credit Score']= train['Credit Score'].fillna(train['Credit Score'].mode()[0])
train['Has Active Credit Card']= train['Has Active Credit Card'].fillna(train['Has Active Credit Card'].mode()[0])
train['Property Age']= train['Property Age'].fillna(train['Property Age'].mode()[0])
train['Property Location']= train['Property Location'].fillna(train['Property Location'].mode()[0])
train['Loan Sanction Amount (USD)']= train['Loan Sanction Amount (USD)'].fillna(train['Loan Sanction Amount (USD)'].mode()[0])

# %%
#On Testing Dataset
test['Gender']= test['Gender'].fillna(test['Gender'].mode()[0])
test['Income (USD)']= test['Income (USD)'].fillna(test['Income (USD)'].mode()[0])
test['Income Stability']= test['Income Stability'].fillna(test['Income Stability'].mode()[0])
test['Type of Employment']= test['Type of Employment'].fillna(test['Type of Employment'].mode()[0])
test['Current Loan Expenses (USD)']= test['Current Loan Expenses (USD)'].fillna(test['Current Loan Expenses (USD)'].mode()[0])
test['Dependents']= test['Dependents'].fillna(test['Dependents'].mode()[0])
test['Credit Score']= test['Credit Score'].fillna(test['Credit Score'].mode()[0])
test['Has Active Credit Card']= test['Has Active Credit Card'].fillna(test['Has Active Credit Card'].mode()[0])
test['Property Age']= test['Property Age'].fillna(test['Property Age'].mode()[0])
test['Property Location']= test['Property Location'].fillna(test['Property Location'].mode()[0])
test['Co-Applicant']= test['Co-Applicant'].fillna(test['Co-Applicant'].mode()[0])
test['Property Price']= test['Property Price'].fillna(test['Property Price'].mode()[0])

# %%
print(train.isnull().sum())
print('\n',test.isnull().sum())

# %% [markdown]
# ### 4. Exploratory Data Analysis

# %%
train.head()

# %%
train["Profession"].value_counts()

# %%
train.hist(figsize=(20,10))
plt.show()

# %%
# Write code and Observation here.
fig = plt.figure(figsize =(15,6))

sns.barplot( x = 'Profession',y = 'Loan Sanction Amount (USD)',hue = 'Gender',  data = train)

plt.title('Barplot', fontsize = 18, fontweight = 'bold')
plt.xlabel('Gender', fontsize = 10, fontweight = 'bold')
plt.ylabel('Loan Sanction Amount (USD)', fontsize = 10, fontweight = 'bold')
plt.legend()


plt.show()

# %%
plt.figure(figsize=(12,4))
sns.countplot('Profession', data=train, palette='ocean')
plt.show()

# %%
sns.barplot(x='Property Location',y='Property Price',data=train)
plt.show()

# %%
plt.pie(train.Gender.value_counts(), autopct="%.1f%%", radius=1.5, labels=['Female','Male'])
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot('Property Location',hue = 'Location', data=train, palette='twilight')
plt.show()

# %%
sns.barplot(x='Profession',y='Income (USD)',hue='Income Stability',data=train)
plt.xticks(rotation=90,fontsize=10)
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.countplot('Dependents', data=train, palette='ocean')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot('Property Location', data=train, palette='Set3')
plt.show()

# %%
sns.scatterplot(x='Credit Score',y='Loan Sanction Amount (USD)',data=train)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.heatmap(data = train.corr(), cmap='coolwarm', annot=True, fmt=".2f")
plt.show()

# %% [markdown]
# ### 5.Data Preprocessing

# %% [markdown]
# The machine learning models are based on mathematical equations & can operate only on numeric values.
# so, need to transform these categorical data into numerical values

# %%
#Preprocessing on Income Stability Column by using Replace Function

train['Income Stability'].replace({'Low': 0, 'High': 1}, inplace = True)
test['Income Stability'].replace({'Low': 0, 'High': 1}, inplace = True)

# %%
train["Location"].unique()

# %%
train["Expense Type 2"].value_counts()

# %%
from sklearn.preprocessing import LabelEncoder
col = ['Customer ID', 'Name', 'Gender','Profession', 'Type of Employment', 'Location','Expense Type 1','Expense Type 2','Has Active Credit Card','Property Location']
le = LabelEncoder()
for LE in col:
    train[LE] = le.fit_transform(train[LE])

# %%
from sklearn.preprocessing import LabelEncoder
col = ['Customer ID','Name', 'Gender','Profession', 'Type of Employment', 'Location','Expense Type 1','Expense Type 2','Has Active Credit Card','Property Location']
le = LabelEncoder()
for LE in col:
    test[LE] = le.fit_transform(test[LE])

# %%
train.head()

# %%
test.head()

# %% [markdown]
# ### 6.Data Scaling & Data Splitting

# %%
#dependent and independent variables

X=train.drop(['Loan Sanction Amount (USD)'],axis=1)      #independent variable

y=train['Loan Sanction Amount (USD)']                    #dependent variable

X.head()

# %%
X.info()

# %%
#Scaling the independent variable to bring data in one range 

from sklearn.preprocessing import StandardScaler
SS=StandardScaler()

# %%
X=SS.fit_transform(X)
X

# %%
test["Co-Applicant"].unique()

# %%
#Sacling Of Test DataSet

X1 = SS.fit_transform(test)

# %%
#splitting the data into train(75%) and test(25%) for model

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %% [markdown]
# ### 7. Machine Learning Model

# %% [markdown]
# * ***1. Linear Regression***

# %%
from sklearn.linear_model import LinearRegression

# %%
LR = LinearRegression()

# %%
LR.fit(X_train, y_train)

# %%
y_predict = LR.predict(X_test)
y_predict

# %%
from sklearn import metrics

# %%
R2_score = metrics.r2_score(y_test, y_predict)
R2_score

# %% [markdown]
# * ***2. Decision Tree Regressor***

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
Regressor  = DecisionTreeRegressor(max_depth= 6, min_samples_leaf= 13)

# %%
Regressor.fit(X_train, y_train)

# %%
from sklearn import tree

# %%
repres = tree.export_text(Regressor)

# %%
Regressor.score(X_test, y_test)

# %% [markdown]
# * ***3. Bagging Regressor***

# %%
from sklearn.ensemble import BaggingRegressor

# %%
model1 = BaggingRegressor(tree.DecisionTreeRegressor())

# %%
model1.fit(X_train,y_train)

# %%
y_predict1 = model1.predict(X_test)
y_predict1

# %%
R2_score1 = metrics.r2_score(y_test, y_predict1)
R2_score1

# %% [markdown]
# * ***4. Random Forest Regressor***

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
RF  = RandomForestRegressor(n_estimators= 48, random_state=1)

# %%
RF.fit(X_train,y_train)

# %%
y_predict1 = RF.predict(X_test)
y_predict1

# %%
R2_score2 = metrics.r2_score(y_test, y_predict1)
R2_score2

# %% [markdown]
# #### As we had inferred above, we can see that linear regression is not giving good results.
# #### We can conclude that RandomForestRegressor is the best model as it has good accuracy as compared to other models.

# %% [markdown]
# ****
