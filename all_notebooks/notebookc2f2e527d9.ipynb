# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as mons
import os

# %%
data=pd.read_csv("../input/new-york-city-daily-temperature-18692021/nyc_temp_1869_2021.csv")

# %%
data.head()

# %%
data.info()

# %%
data.describe()

# %%
mons.bar(data)

# %%
data.sort_values(['TMIN'])

# %%
sns.lineplot(x="YEAR", y="TMAX",data=data)

# %%
sns.lineplot(x="YEAR", y="TMIN",data=data)

# %%
sns.scatterplot(x="YEAR", y="TMAX",data=data)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig=plt.figure(figsize=(10,10))
ax=Axes3D(fig)
ax.scatter(data['YEAR'],data['TMAX'],data['TMIN'])
plt.xlabel("Year")
plt.ylabel("Max")
plt.show()

# %%
data.head()

# %%
data.drop(["MM/DD/YYYY"],axis=1,inplace=True)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data=data.corr() , annot=True)
