# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
import warnings
warnings.filterwarnings("ignore")

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df=pd.read_csv("/kaggle/input/students-performance-in-exams/StudentsPerformance.csv")

# %%
df.head()

# %%
df.shape

# %%
df.tail()

# %%
df.isna().sum()

# %%
df.describe()

# %%
df.columns

# %%
df.nunique()

# %%
data=df.drop(["race/ethnicity","parental level of education"],axis=1)

# %%
data.head()

# %% [markdown]
# Label Encoding refers to converting the labels into numeric form so as to convert it into the machine-readable form. Machine learning algorithms can then decide in a better way on how those labels must be operated. It is an important pre-processing step for the structured dataset in supervised learning.
#
# We can do label Encoding From LabelEncoder of scikit-Learn but to do so first we have to impute missing values in data

# %%
from sklearn.preprocessing import LabelEncoder
data["gender"].value_counts()

# %%
# initialize LabelEncoder
lbl_enc = LabelEncoder()

# fit label encoder and transform values on ord_2 column
data.loc[:, "gender"] = lbl_enc.fit_transform(data['gender'].values)

data['gender'].value_counts()

# %%
data["test preparation course"].value_counts()

# %%
# initialize LabelEncoder
lbl_enc = LabelEncoder()

# fit label encoder and transform values on ord_2 column
data.loc[:, "test preparation course"] = lbl_enc.fit_transform(data['test preparation course'].values)

data['test preparation course'].value_counts()

# %%
data["lunch"].value_counts()

# %%
lbl_enc=LabelEncoder()
data.loc[:,"lunch"]=lbl_enc.fit_transform(data["lunch"].values)
data["lunch"].value_counts()

# %%
data.head()

# %%
corelation=data.corr()

# %%
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True,cmap='coolwarm')

# %%
sns.relplot(x="math score",y="reading score",hue="gender",data=data)

# %%
sns.relplot(x="math score",y="reading score",hue="test preparation course",data=data)

# %%
sns.relplot(x="math score",y="reading score",hue="lunch",data=data)

# %%
sns.distplot(data["math score"])

# %%
sns.distplot(data["reading score"])

# %%
sns.distplot(data["writing score"])

# %%
sns.catplot("math score",kind='box',data=data)

# %%
sns.catplot("reading score",kind='box',data=data)

# %%
sns.catplot("writing score",kind='box',data=data)
