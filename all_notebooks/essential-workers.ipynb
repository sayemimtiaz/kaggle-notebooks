# %% [markdown]
# COVID-19 is a genuine shock to daily life. Typical activities—sitting down at a restaurant, meeting with colleagues, hugging a friend—are suddenly foreign and deeply missed. From coast to coast, mayors and governors have wisely recommended residents to keep physically apart, all to minimize a massive wave of infections and give our health care systems a chance to mitigate the virus.https://www.brookings.edu/research/how-to-protect-essential-workers-during-covid-19/

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# pt.postermywall.com

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import feature_extraction, linear_model, model_selection, preprocessing
import plotly.graph_objs as go
import plotly.offline as py

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://i1.wp.com/www.brookings.edu/wp-content/uploads/2020/03/2020.03.31_BrookingsMetro_COVID-workforce-01.png?w=768&crop=0%2C0px%2C100%2C9999px&ssl=1',width=400,height=400)

# %% [markdown]
# Brookings.edu  https://www.brookings.edu/research/how-to-protect-essential-workers-during-covid-19/

# %% [markdown]
# #The Salt of the Earth: Essential Workers
#
# The Department of Homeland Security uses a sweeping definition of such essential industries, which collectively employed anywhere from 49 to 62 million workers prior to the COVID-19 outbreak according to our highest estimates. Many of these essential industries will see continued demand for their products and services, the inverse of other industries that cannot operate during a period of social distancing.
#
# A portion of these essential workers will continue to report to their jobs at health care facilities, grocery stores, water utilities, and other work sites—all to ensure the rest of the country can maintain some semblance of a typical life during this health crisis
#
# Since many of these workers risk their lives to protect ours, the nation has a responsibility to protect the health and financial stability of these individuals and their families. https://www.brookings.edu/research/how-to-protect-essential-workers-during-covid-19/

# %% [markdown]
# <iframe width="951" height="535" src="https://www.youtube.com/embed/eOiLH-2hTPQ" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# The Rolling Stones - Salt Of The Earth (Official Lyric Video)
#
# Let's drink to the hard working people/Let's drink to the lowly of birth/Raise your glass to the good and the evil/Let's drink to the salt of the earth/Say a prayer for the common foot soldier/Spare a thought for his back breaking work/Say a prayer for his wife and his children/Who burn the fires and who still till the earth/And when I search a faceless crowd/A swirling mass of gray and/Black and white/They don't look real to me/In fact, they look so strange/Raise your glass to the hard working people/Let's drink to the uncounted heads/Let's think of the wavering millions/Who need leaders but get gamblers instead/Spare a thought for the stay-at-home voter/His empty eyes gaze at strange beauty shows/And a parade of the gray suited grafters/A choice of cancer or polio/And when I look in the faceless crowd/A swirling mass of grays and
# Black and white/They don't look real to me/Or don't they look so strange/Let's drink to the hard working people/Let's think of the lowly of birth/Spare a thought for the rag taggy people/Let's drink to the salt of the earth/Let's drink to the hard working people/Let's drink to the salt of the earth/Let's drink to the two thousand million/Let's think of the humble of birth/
#
# Fonte: LyricFind
#
# Compositores: Keith Richards / Mick Jagger - Lyrics  Salt Of The Earth © Abkco Music, Inc

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRWq2-qWiDwimVot6Eu44UUynyLdim1D37ifNQPBveJlyEHY6Mi&usqp=CAU',width=400,height=400)

# %% [markdown]
# tsu.edu

# %%
df = pd.read_csv('../input/uncover/UNCOVER/HDE_update/HDE/global-school-closures-covid-19.csv', encoding='ISO-8859-2')
df.head()

# %% [markdown]
# In South Korea, the government of President Moon Jae-In, started taking action in February, closing schools, for example. That month, Korea had more cases than Italy.
#
# Yesterday afternoon (08/april/2020), according to data from Johns Hopkins University, Italy had 139,422 cases, with 17,669 deaths, a lethality of 12.6%. In Korea, 10,384 cases, with 200 fatalities, lethality below 2%. In the USA, lethality is 4%.
#
# The Korean government quickly adopted the World Health Organization rule: test, test, test. And not just sick or symptomatic, as is done almost everywhere in the world. By random samples, it was as if they had tested the entire population (as in election polls, for example).
#
# Once an infected person is found, it is about following people who have been in contact with the patient - by the geographic location of cell phones, for example, with government applications. And quarantine everyone.
# https://translate.google.com.br/translate?hl=en&sl=pt&u=https://oglobo.globo.com/opiniao/falhas-de-governo-24360148&prev=search

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# katc.com

# %%
import plotly.offline as pyo
import plotly.graph_objs as go
lowerdf1 = df.groupby('country').size()/df['scale'].count()*100
labels = lowerdf1.index
values = lowerdf1.values

# Use `hole` to create a donut-like pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=.6)])
fig.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ2HINTCIrDYl1JzM7wzKW3H5wFPAPErjyvTyQFMbA8cw4YAbSc&usqp=CAU',width=400,height=400)

# %% [markdown]
# joplinmo.org

# %%
df.sample(10).T

# %%
plt.style.use('dark_background')
plt.figure(figsize=(8,6))
sns.countplot(df["date"])
plt.xticks(rotation=90)
plt.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQL5y4fnCtxXDwr-KHOsNVcheQeT7c156fUN6uzGAmStgglUTkU&usqp=CAU',width=400,height=400)

# %% [markdown]
# unric.org

# %%
df1 = pd.read_csv('../input/uncover/UNCOVER/OpenTable/restaurant-performance.csv', encoding='ISO-8859-2')
df1.head()

# %%
df1.sample(8).T

# %%
plt.style.use('dark_background')
sns.distplot(df1.percent_yoy_change)

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRjLfTbk47AkU49tdn-FzJgB7syCbAp5BUsf3P5ZwiAgyvjjv7O&usqp=CAU',width=400,height=400)

# %% [markdown]
# latinamerica.uitp.org

# %%
plt.style.use('dark_background')
sns.scatterplot(x="percent_yoy_change", y="region_type",
                      hue="country",
                      data=df1)

# %%
plt.style.use('dark_background')
import plotly.offline as pyo
import plotly.graph_objs as go
lowerdf1 = df1.groupby('percent_yoy_change').size()/df1['country'].count()*100
labels = lowerdf1.index
values = lowerdf1.values

# Use `hole` to create a donut-like pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=.6)])
fig.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSf1U1e9-ho02LypCiOuHFx_yXoiyr7ffOQq9oMuK2v7XIZYRBA&usqp=CAU',width=400,height=400)

# %% [markdown]
# dribbble.com - Sometimes things are "fucked" so let's fork and optimize someone's work or ourselves work. Life isn't what we choose. It's what we make with our dices or our data.

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcS_P_zS2d4dDoyuuBV0AU3LqtRRX8UABjpgvtRFXZce3fO4vsKM&usqp=CAU',width=400,height=400)

# %% [markdown]
# 6abc.com

# %%
df2 = pd.read_csv('../input/uncover/UNCOVER/hifld/hifld/aircraft-landing-facilities.csv', encoding='ISO-8859-2')
df2.head()

# %% [markdown]
# #Counting the flights, Counting Covid-19 spread.
#
# A visit to any real-time flight app, such as “Live Planes,” can give a good clue. In Brazil, yesterday (08/april/2020), at 12:34 pm, there were 18 planes flying. In India, four airplanes occupied the airspace. In Italy, there were two, in France, seven. And nine were flying over England. In the United States, it was impossible to count, because they numbered hundreds.
# https://translate.google.com.br/translate?hl=en&sl=pt&u=https://oglobo.globo.com/opiniao/malditas-redes-1-24360113&prev=search

# %%
df2.sample(3).T

# %%
plt.style.use('dark_background')
df2.query('objectid==400').plot.scatter(x='passengers', y='enplanemen')

# %%
plt.style.use('dark_background')
sns.lineplot(data=df2.query('objectid==400'), x='passengers', y='enplanemen')

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTzQbf5AUfq94TkVC6FXUNm8d24OGHLSAvUjzEK4m7Pi4oiP_KK&usqp=CAU',width=400,height=400)

# %% [markdown]
# insider.com

# %%
total_passengers=df2.groupby('type')['objectid', 'enplanemen','passengers'].sum().reset_index()
total_passengers

# %%
fig=go.Figure(data=[
    go.Scatter(x=total_passengers['enplanemen'],
    y=total_passengers['passengers'],marker_color='pink')]
)
fig.update_layout(title='Enplanement by Passengers',font_size=16,yaxis_type='log',template='plotly_dark')
fig.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSLADAZtVN1tqkH63dGF8l7gz2emEkF1Q79qZXdomYJ166EQ-7_&usqp=CAU',width=400,height=400)

# %% [markdown]
# businessinsider.com

# %%
df3 = pd.read_csv('../input/uncover/UNCOVER/google_mobility/us-mobility.csv', encoding='ISO-8859-2')
df3.head()

# %% [markdown]
# #The commerce, services and tourism sector has the greatest potential for negative impact.
#
# The economic activities that comprise it depend on the circulation of goods and consumers. Especially in tourism, which is directly affected by the impossibility of travel, reservations and visits, action necessary to prevent the new virus. The impact on the trade segment will be felt with a slightly greater lag.
# https://translate.google.com.br/translate?hl=en&sl=pt&u=https://economia.uol.com.br/noticias/redacao/2020/03/19/coronavirus-provoca-perdas-de-r-22-bi-no-turismo-brasileiro-diz-cnc.htm&prev=search

# %%
df3.sample(7).T

# %%
plt.style.use('dark_background')
plt.figure(figsize=(8,6))
sns.countplot(df3["retail_recreation"])
plt.xticks(rotation=90)
plt.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQLS9XFj8wWd5i8Sm9tbNNl4mwPRHyvHrnf3yIkFYi7qx9g8DUb&usqp=CAU',width=400,height=400)

# %% [markdown]
# istockphoto.com

# %%
plt.style.use('dark_background')
plt.figure(figsize=(8,6))
sns.countplot(df3["workplaces"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# After data from the Monthly Survey of Commerce (PMC), from the Brazilian Institute of Geography and Statistics (IBGE), point to a 1.2% increase in retail sales in February compared to January, without the effects of covid-19 , the National Confederation of Trade in Goods, Services and Tourism (CNC) estimated a loss of R $ 53.3 billion in sales revenue since the pandemic was consolidated in the country, compared to last year.

# %%
plt.style.use('dark_background')
plt.figure(figsize=(8,6))
sns.countplot(df3["residential"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# There was no record of a drastic interruption in commercial activities as the one that the sector has experienced since the increase in the number of cases of Covid-19 in Brazil. Given the escalation in the number of cases of contagion of the new coronavirus, the issue of regional decrees determining the closure of commercial establishments in compliance with social isolation measures has intensified in Brazil, says the report.
#
# CNC's estimate for March signals a 46.1% drop in retail sales revenue since the introduction of restrictive measures until this Tuesday (07/april/2020), in comparison with the same period in 2019. The projection considered data from ten states, responsible for 72.5% of the national retail sales volume.
# https://translate.google.com.br/translate?hl=en&sl=pt&u=https://revistapegn.globo.com/Noticias/noticia/2020/04/covid-19-faz-comercio-perder-r-533-bi-em-faturamento-ante-2019-diz-cnc.html&prev=search

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSFtsYLu4UDKtBKNDXlUc8i1Op_MZd2qmFQ7mpiNBlyrUjnWNR0&usqp=CAU',width=400,height=400)

# %% [markdown]
# news.mak.ac.ug

# %%
df4 = pd.read_csv('../input/uncover/UNCOVER/ihme/2020_03_30/Hospitalization_all_locs.csv', encoding='ISO-8859-2')
df4.head()

# %% [markdown]
# #Not only Health Care Professionals should go to work.However they must follow protective protocols.
#
# Transport workers 'must not work' without measures. Nine bus workers have died in the capital after contracting coronavirus, while at least three have died elsewhere in the UK including two in the North West and one in the South West, according to the Unite union.
#
# Policemen should wear masks and gloves. So do doormen and all essential workers.

# %% [markdown]
# #Codes from Tawej https://www.kaggle.com/tawejssh/covid-19

# %%
#Let's visualise the evolution of results
hospital = df4.groupby('location').sum()[['allbed_mean', 'ICUbed_mean', 'InvVen_mean']]
#evolution['Expiration Rate'] = (evolution['Expired'] / evolution['Cumulative']) * 100
#evolution['Discharging Rate'] = (evolution['Discharged'] / evolution['Cumulative']) * 100
hospital.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://i0.wp.com/www.brookings.edu/wp-content/uploads/2020/03/2020.03.31_BrookingsMetro_COVID-workforce-OtherFigures.png?w=768&crop=0%2C0px%2C100%2C9999px&ssl=1',width=400,height=400)

# %% [markdown]
# #Essential infrastructure workers
#
# Who “protect their communities, while ensuring continuity of functions critical to public health and safety, as well as economic and national security.
#
# On average, 85% of these workers are frequently in close proximity to others, 79% are frequently exposed to disease, and 89% have frequent face-to-face interactions. It’s harder to precisely measure the risks that workers face in grocery stores, trade and logistics, and other establishments, but it’s clear that many could potentially be exposed to COVID-19 and will require closer monitoring.
#
# #Essential workers are not equally prepared for personal health impacts
#
# Not all essential workers are equally prepared to manage coronavirus-related health impacts in their own lives. Income levels, health care benefits, and life insurance rates vary considerably across this wide set of workers.Although millions of nurses, therapists, and health care practitioners are earning higher wages, millions of other essential workers do not.
#
# Disease exposure also tends to be higher for lower-wage workers.

# %%
plt.style.use('dark_background')
plt.figure(figsize=(20,7))
plt.plot(hospital['allbed_mean'], label='allbed_mean')
#plt.plot(hospital['CN_Onset_WHO'], label='CN_Onset_WHO')
plt.plot(hospital['ICUbed_mean'], label='ICUbed_mean')
plt.legend()
#plt.grid()
plt.title('Hospital beds including ICU beds ')
plt.xticks(hospital.index,rotation=45)
plt.xlabel('All Beds')
plt.ylabel('ICU beds')
plt.show()

# %% [markdown]
# #A new platform to protect essential workers
#
# The federal government has a moral and economic responsibility to protect essential workers during the COVID-19 pandemic—particularly those that must continue to work outside the home.
#
# Morally, it’s unconscionable to ask people to show up for work, knowing they will put themselves and their loved ones at greater risk, and offer no benefit for their public service.
#
# Economically, it’s imperative that certain essential workers continue to work or report to their workplaces if they can’t telework, so the entire economy does not shrink even further.
# https://www.brookings.edu/research/how-to-protect-essential-workers-during-covid-19/

# %%
plt.style.use('dark_background')
#What about the evolution of China Diagnosed Worldometer rate ?
plt.figure(figsize=(20,7))
plt.plot(hospital['InvVen_mean'], label='Ventilators mean')
plt.legend()
#plt.grid()
plt.title('Ventilators by US States')
plt.xticks(hospital.index,rotation=45)
plt.ylabel('Rate %')
plt.show()

# %% [markdown]
# #Three fundamental truths in a wartime economy:
#
# Many essential workers are more likely to get sick or die due to their service, so there is a need to protect their family’s financial future; and
#
# Many essential workers are more likely to contract COVID-19 due to activities at the job site and traveling to it, so there is a need to keep the worker and their families healthy; and
#
# Many essential workers face new hazardous duties, so there is a need to compensate workers for their exposure to COVID-19 and incentivize their continued work within essential industries.
# https://www.brookings.edu/research/how-to-protect-essential-workers-during-covid-19/

# %%
plt.style.use('dark_background')
#This is another way of visualizing the evolution: plotting the increase evolution (difference from day to day)
diff_hospital = hospital.diff().iloc[1:]
plt.figure(figsize=(20,7))
plt.plot(diff_hospital['allbed_mean'], label='All Beds Mean')
plt.legend()
plt.grid()
plt.title('Hospital Beds by US States')
plt.xticks(hospital.index,rotation=45)
plt.ylabel('Rate %')
plt.show()

# %% [markdown]
# Protecting public health and the economy during the COVID-19 pandemic demands that residents stay as far away from each other as possible. Yet to make this collective response possible, tens of millions of people must continue to work, often outside the home. The country has a moral responsibility to protect these worker’s health, to create financial security for their loved ones, and to offer peace of mind during a time of heightened physical and emotional stress. Providing free life and health insurance to essential workers who must leave their homes to continue working is an honorable and affordable policy.https://www.brookings.edu/research/how-to-protect-essential-workers-during-covid-19/

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSz-ry_7cyoTRylxdmIAV9EftsplR3t6Nke_tDmpygKSE37MdYf&usqp=CAU',width=400,height=400)

# %% [markdown]
# southernnevadahealthdistric.org

# %% [markdown]
# Kaggle Notebook Runner: Marília Prata @mpwolke
