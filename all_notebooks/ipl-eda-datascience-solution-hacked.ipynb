# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv("/kaggle/input/ipl-data-set/matches.csv")

# %%
df.head()

# %%
df.shape

# %%
df.team1.unique()

# %%
df.columns

# %%
df.info()

# %%
df.isnull().sum()

# %%
df.city.isnull().sum()

# %%
df=df.drop(["umpire1","umpire2","umpire3"],axis=1)

# %%
df.describe(include="all")

# %%
df['date']= pd.to_datetime(df['date'])

# %%
df

# %%
PLAYERSNAMES = df.groupby(by=['team1', 'player_of_match']).player_of_match.count()

# %%
PLAYERSNAMES.head(60)

# %%
player= df[['Season', 'player_of_match']]

# %%
player

# %%
no_of_player_of_match = df[['Season', 'player_of_match']]
no_of_player_of_match.shape

# %%
no_of_player_of_matchs = no_of_player_of_match.groupby(by=['Season', 'player_of_match']).player_of_match.count()

# %%
highest_no_of_player_of_match = no_of_player_of_match['player_of_match'].value_counts()[0:10]

# %%
key = list(highest_no_of_player_of_match.keys())

# %%
plt.figure(figsize=(15, 6))
plt.bar(key, highest_no_of_player_of_match, color = 'green')
plt.show()

# %%
plt.figure(figsize = (15,8))
plt.bar(list(df['winner'].value_counts().keys()), df['winner'].value_counts())
plt.ylabel("No. of Matchs")
plt.title("No. of matches won by each Teams")
plt.xticks(rotation=50)
plt.show()

# %%
fig=plt.gcf()
fig.set_size_inches(18.5,8)
sns.countplot(df['city'],order=df['city'].value_counts().index,palette='Set2',hue=df['toss_decision'])
plt.title('matches',fontsize=15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15,rotation=90)
plt.xlabel('Venue',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.legend(loc=5,fontsize=10)
plt.show()

# %%
plt.xticks(rotation=90)
sns.countplot(df['toss_winner'])

# %%
plt.subplots(figsize=(12,6))
df['city'].value_counts().plot.bar(width=0.9,color="pink",alpha=0.75)

# %%
df5 = pd.get_dummies(df['Season'])
df5.head()

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop('winner',axis='columns')
x

# %%
y=df['winner']

# %%
reg = linear_model.LinearRegression()

# %%
df['winner'].value_counts().sort_index().plot.area()
plt.xticks(rotation=90,color = 'black')

# %%
plt.subplots(figsize=(10,6))
plt.xticks(rotation=90)
sns.countplot(x='Season',hue='toss_decision',data=df,palette=sns.color_palette('bright',20,))
plt.title("decision to field or bat across seasons ")
plt.show()

# %%
df.info

# %%
df["result"].unique()

# %%
df=df.drop(["date","dl_applied","result"],axis=1)

# %%
df

# %%
df.describe(include="all")

# %%
sns.distplot(df["win_by_runs"])

# %%
df=df.dropna(axis=0)

# %%
df.isnull().sum()

# %%
df["team1"].unique()

# %%
df.head()

# %%
df=df.drop(["Season","player_of_match","win_by_runs","win_by_wickets"],axis=1)

# %%
df.head()

# %%
lb=LabelEncoder()

# %%
df["city"]=lb.fit_transform(df["city"])
df["team1"]=lb.fit_transform(df["team1"])
df["team2"]=lb.fit_transform(df["team2"])
df["winner"]=lb.fit_transform(df["winner"])
df["toss_winner"]=lb.fit_transform(df["toss_winner"])
df["toss_decision"]=lb.fit_transform(df["toss_decision"])
df["venue"]=lb.fit_transform(df["venue"])

# %%
df.head()

# %%
df.describe(include="all")

# %%
df=df.drop(["id"],axis=1)

# %%
df.head()

# %%
final_data=df.reset_index(drop=True)

# %%
final_data.head()

# %%
y=final_data["winner"]
x=final_data.drop(["winner"],axis=1)

# %%
y.shape

# %%
x.shape

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=20)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)

# %%
y_pred=model.predict(x_test)

# %%
score=model.score(x_train,y_train)

# %%
x_test

# %%
y_test
