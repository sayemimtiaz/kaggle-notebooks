# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns  # visualization tool

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

import os
for dirname, _, filenames in os.walk("/kaggle/input"):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
data = pd.read_csv('/kaggle/input/diamonds/diamonds.csv')
data.head(200)
#data.info()

# %%
#Plotting all data
data1 = data.loc[:,["x","y","z"]]
data1.plot()

# %%
# Subplots
data1.plot(subplots= True)
plt.show()

# %%
# Scatter Plot
data1.plot(kind= "scatter", x="x", y = "y")
plt.show()

# %%
# Hist Plot
data1.plot(kind = "hist", y = "y", bins= 50, range= (0,50), density = True)

# %%
# histogram subplot with non cumulative and cumulative
fig, axes = plt.subplots(nrows=2,ncols=1)
data1.plot(kind ="hist", y= "y", bins = 50,range= (0,50),density = True, ax= axes[0])
data1.plot(kind ="hist", y= "y", bins = 50,range= (0,50),density = True, ax= axes[1],cumulative = True)
plt.savefig('graph.png')
plt

# %%
data.head()

# %%
# İndexing Pandas Time Series
time_list= ["1992-03-08","1992-04-12"]
print(type(time_list)) # string
datetime_object = pd.to_datetime(time_list)
print(type(datetime_object))

# %%
data2 = data.head()
datetime = ["1992-01-10","1992-02-10","1992-03-10","1993-03-15","1993-03-16"]
datetime_object = pd.to_datetime(datetime)
data2["datetime"] = datetime_object

#lets make date as index
data2 = data2.set_index("datetime")
data2

# %% [markdown]
# # Manıpulating Data Frames With Pandas

# %%
# read data
#data = pd.read_csv('/kaggle/input/diamonds/diamonds.csv')
#data= data.set_index('index_name')
data.head()

# %%
# İndexing using square brackets
data["clarity"][1]

# %%
#Using column attribute and row label
data.clarity[1]

# %%
#Using loc accessor
data["clarity"][1]

# %%
#Selecting only some columns
data[["clarity","carat"]]

# %% [markdown]
# # Slicing data frame

# %%
#Diffirent between selecting columns : series and dataframes
print(type(data["clarity"]))     #series
print(type([["clarity"]]))       #data frames

# %%
# Slicing and indexing series
data.loc[1:10,"carat":"clarity"]

# %%
#Reverse slicing
data.loc[10:1:-1,"carat":"clarity"]

# %%
#From something to end
data.loc[1:10,"clarity":]

# %% [markdown]
# # Filtering data frames

# %%
#Creating boolean series
boolean =data.carat < 0.23
data[boolean]

# %%
### Combinin filters
first_filter = data.carat < 0.23
second_filter = data.price < 350
data[first_filter & second_filter]

# %%
# Filtering column based others
data.carat[data.price <350]

# %% [markdown]
# # Transforming data

# %%
#plain python functions
def div (n):
    return n/2
data.carat.apply(div)

# %%
#Or we can use lambda function
data.carat.apply(lambda n : n/2)

# %%
# Defining colmn using other columns
# data = data.drop ("x.y",1) # Sutun silme komutu
data["x+y"] =data.x + data.y
data.head()

# %% [markdown]
# # Index object and labeled data

# %%
# Our index name is this:

#print(data.index.name)
# Lets change it

#data.index.name= "index_name"
data.head()

# %%
data.head()
# first copy of our data to data5 then change index
data5 = data.copy()
#lets make index start from 150. It is nıt remarkable change but it is just example
#data5.index_name = range(150,800,1)
data5.head()

# %%
# We can make one of the column as index. I actuallly did it at the beginning of manipulating data frames with pandas section
#It was like this
#data= data.set_index("#")
#alse you can use
#data.index = data("#")

# %% [markdown]
# # Hierarchical Indexing

# %%
# lets read data frame one more time to start from beginning
data = pd.read_csv('/kaggle/input/diamonds/diamonds.csv')
data.head()

# %%
# Setting index : color is outer cut is inner index
data1 = data.set_index (["color","cut"])
data1.head(100)
#data1.loc["clarity","carat"] # how to indexes

# %% [markdown]
# # Pivoting Data Frames

# %%
dic = {"treatment":["A","A","B","B"], "gender":["F","M","F","M"],"response":[10,45,5,9],"age":[15,4,72,65]}
df = pd.DataFrame(dic)
df

# %%
#pivoting
df.pivot(index = "treatment",columns = "gender", values= "response")

# %% [markdown]
# # Stacking and Unstaking Dataframe

# %%
df1 = df.set_index(["treatment","gender"])
df1
#lets unstack it

# %%
# level determines indexes
df1.unstack(level=0)

# %%
 df1.unstack(level=1)

# %%
# change inner and outer level index position
df2 = df1.swaplevel(0,1)
df2

# %% [markdown]
# # Melting Data Frames

# %%
df

# %%
# df.pivot(index="treatment",columns ="gender",values = "response")
pd.melt(df,id_vars="treatment",value_vars=["age","response"])

# %% [markdown]
# # Categoricals and Groupby

# %%
# We will use df
df

# %%
# according to treatment make means of other features
df.groupby("treatment").mean() # mean is aggregation / reduction method
#there are other methods like sum, std, max or min

# %%
# we can only choose one of the feature
df.groupby("treatment").age.max()

# %%
# Or we can choose multipe feature
df.groupby("treatment")[["age","response"]].min()

# %%
df.info()
# as you can see gender is object
#However if we use groupby , we can convert it categorical data.
# Because categorical data uses less memory, speed up operations like groupby
#df["gender"] = df["gender"].astype("category")
#df["treatment"] = df["treatment"].astype("category")
#df.info()
