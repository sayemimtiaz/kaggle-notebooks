# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import missingno as mion
import os

# %%
data=pd.read_csv("../input/breaking-bad-tv-show-all-seasons-episodes-data/breaking_bad.csv")

# %%
data.head()

# %%
data.info()

# %%
data['Date']=pd.to_datetime(data['Date'])

# %%
data.describe()

# %%
mion.bar(data)

# %%
data.groupby("Title").mean()

# %%
plt.figure(figsize=(12,7))
plt.style.use("seaborn")
sns.lineplot(x='Date',y='U.S. viewers_million',data=data)

# %%
plt.figure(figsize=(12,7))
sns.countplot(data['Directed by'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,7))
plt.style.use("fivethirtyeight")
sns.lineplot(x='Date',y='Rating_IMDB',data=data)

# %%
plt.figure(figsize=(25,7))
plt.style.use("ggplot")
sns.lineplot(x='Title',y='Rating_IMDB',data=data)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(25,7))
plt.style.use("ggplot")
sns.lineplot(x='Written by',y='Rating_IMDB',data=data)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(25,7))
plt.style.use("ggplot")
sns.lineplot(x='Written by',y='U.S. viewers_million',data=data)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(25,7))
plt.style.use("ggplot")
sns.lineplot(x='Title',y='U.S. viewers_million',data=data)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=data,x="Date",y="U.S. viewers_million",marker='o',hue="Season")
plt.show()

# %%
plt.figure(figsize=(12,7))
plt.style.use("seaborn")
sns.lineplot(x='Duration_mins',y='U.S. viewers_million',data=data)

# %%
plt.figure(figsize=(12,7))
plt.style.use("seaborn")
sns.lineplot(x='Duration_mins',y='Rating_IMDB',data=data)

# %%
from pandas_profiling import ProfileReport
x=ProfileReport(data)

# %%
x
