# %% [markdown]
# # Merging and Reshaping Exercises: Harvard Tuition versus GDP
#
# The following exercises were created as a lab for the Python class I am teaching. It contains several applications of the split-apply-combine operations. (For teaching purposes, solutions are not provided.)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %% [markdown]
# ## Datasets
#
# The goal of this analysis is to understand the extent in which tuition has grown over the years for Harvard graduate schools.
#
# In this analysis, we will be using two datasets:
# - Graduate school tuition, from the Harvard Tuition dataset;
# - GDP per capita in the US.
#
# Load the two datasets and display the first 5 rows.

# %%
tuition = pd.read_csv('/kaggle/input/harvard-tuition/tuition_graduate.csv')
tuition.head()

# %%
gdp = pd.read_csv('/kaggle/input/usa-gdp-per-capita/usa_gdp_per_capita.csv')
gdp.head()

# %% [markdown]
# ## 1. Tuition over the years
#
# First, we investigate the absolute dollar amount of tuition over the years, for each graduate school.
#
# Reshape the `tuition` DataFrame into wide format, with the academic year as the row index and the school as the column name.
#
# Save the results as a DataFrame named `tuition_wide` and display the first 5 rows.

# %% [markdown]
# Create a line plot that illustrates the tuition over the years for each school.

# %% [markdown]
# ## 2. Tuition versus GDP
#
# Next, we explore the affordability of tuition relative to the GDP per capita, which is a proxy for the economy and the financial capabilities of the people.
#
# There are three intermediate steps to achieve this. After each step, save the results as a DataFrame named `tuition_long` and display the first 5 rows.
#
# 1. Keeping only representative rows corresponding to the years 1987 and 2017, reshape the dataset into long format, so that each row contains the cost of tuition for a specific year and school.

# %% [markdown]
# 2. Merge the data for GDP per capita into the DataFrame.

# %% [markdown]
# 3. Create a new column that contains the ratio of the cost of tuition versus the GDP per capita.

# %% [markdown]
# ## Tuition versus GDP comparison between schools
#
# Finally, we make a comparison of the tuition-GDP ratio between schools.
#
# Reshape `tuition_long` into wide format, with the school as the row index, the academic year as the column name, and the tuition-GDP ratio as the values.
#
# Save the results as a DataFrame named `ratio_by_school` and display the entire dataset.

# %% [markdown]
# Create a horizontal bar plot of the tuition-GDP ratio in 1987 and 2017, with the schools ordered from top to bottom in descending order of the 2017 ratio.

# %% [markdown]
# What observations can be made from the table and figure above? Write a short paragraph summarizing your findings in "news article style" (i.e., as if you are a reporter writing for the newspapers).
