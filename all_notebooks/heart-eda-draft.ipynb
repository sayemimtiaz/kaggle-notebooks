# %% [markdown]
# This notebook is not yet finalized. I just feel like I have to show this to the public. If you have comments feel free to do so!

# %% [markdown]
# **I. Importing libraries**

# %%
#imports for data analysis and wrangling
import pandas as pd
import numpy as np

#visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Importing data
heart = pd.read_csv('../input/heart-attack-analysis-prediction-dataset/heart.csv')

# %% [markdown]
# **II. Analyze by describing the data**

# %% [markdown]
# Variables:
# 1. age - age in years
#
# 2. sex - sex (1 = male; 0 = female)
#
# 3. cp - chest pain type (1 = typical angina; 2 = atypical angina; 3 = non-anginal pain; 0 = asymptomatic)
#
# 4. trtbps - resting blood pressure (in mm Hg on admission to the hospital)
#
# 5. chol - serum cholestoral in mg/dl fetched via BMI sensor
#
# 6. fbs - fasting blood sugar > 120 mg/dl (1 = true; 0 = false)
#
# 7. restecg - resting electrocardiographic results (1 = normal; 2 = having ST-T wave abnormality; 0 = hypertrophy)
#
# 8. thalachh - maximum heart rate achieved
#
# 9. exng - exercise induced angina (1 = yes; 0 = no)
#
# 10. oldpeak - ST depression induced by exercise relative to rest
#
# 11. slp - the slope of the peak exercise ST segment (2 = upsloping; 1 = flat; 0 = downsloping)
#
# 12. caa - number of major vessels (0-3) colored by flourosopy #change 4 to null
#
# 13. thall - 2 = normal; 1 = fixed defect; 3 = reversable defect #change 0 to null
#
# 14. output - the predicted attribute - diagnosis of heart disease (angiographic disease status) (Value 0 = < diameter narrowing; Value 1 = > 50% diameter narrowing)
# #1- the patient is more prone to having a heart disease while if it is 0, the situation of the patient is not that critical
#
# Shout out to https://www.kaggle.com/rashikrahmanpritom/heart-attack-analysis-prediction-dataset/discussion/234843
# for providing the features

# %%
#Getting all the features
print(heart.columns.values)

# %%
#Exxamining the first 5 observations
heart.head()

# %%
#Examining the last 5 ibservations
heart.tail()

# %%
#Getting the number of rows and columns of the table
heart.shape

# %%
#Checking for null values
heart.isnull().sum()

# %%
#Examining the data types of various features
heart.info()

# %%
#Summary statistics of the features
heart.describe()

# %% [markdown]
# **III. Preparing the data**

# %% [markdown]
# **A. Changing the considered null values to the most common occurrence**
#
#
# As stated in https://www.kaggle.com/rashikrahmanpritom/heart-attack-analysis-prediction-dataset/discussion/234843A. caa and thall have null values. We will change the null values by the most common occurrence in caa and thall.

# %%
#Checking the most common occurrence in caa
sns.countplot(x = "caa", data = heart)
plt.show()

# %%
#Replacing 4(null) to 0 (most common occurrence)
heart['caa'] = heart['caa'].replace({4:0})

# %%
#New set of observations in caa
sns.countplot(x = "caa", data = heart)
plt.show()

# %%
#Checking the most common occurrence in thall
sns.countplot(x = "thall", data = heart)

# %%
#Replacing 9(null) to 2 (most common occurrence)
heart['thall'] = heart['thall'].replace({0:2})

# %%
#New set of observations in thall
sns.countplot(x = "thall", data = heart)

# %% [markdown]
# **B. Replacing the values of categorical features for visualization purposes**

# %%
heart['sex'] = heart['sex'].replace({0:'Female', 1:'Male'})
heart['cp'] = heart['cp'].replace({0:"Asymptomatic",1:'Typical Angina', 
                                   2:'Atypical Angina', 3: "Non-Anginal Pain"})
heart['fbs'] = heart['fbs'].replace({0:"False", 1:"True"})
heart['restecg'] = heart['restecg'].replace({0: "Hypertrophy",1:"Normal", 
                                             2:"ST-T Wave Abnormality"})
heart['exng'] = heart['exng'].replace({0:"No", 1:"Yes"})
heart['slp'] = heart['slp'].replace({0: "downsloping", 1: "flat", 2: "upsloping"})
heart['thall'] = heart['thall'].replace({1:"Fixed Defect", 2: "Normal", 3:"Reversible Defect"})
heart["output"] = heart["output"].replace({1:"Prone to Having a Heart Disease", 0: "Not Prone"})

# %%
#Checking new data
heart.head()

# %% [markdown]
# **IV. Analyze by visualizing data**

# %% [markdown]
# **A. Visualizing Categorical Variables**

# %%
sns.catplot(x = "sex",data = heart, kind = "count", hue = "output")
sns.catplot(x = "cp",data = heart, kind = "count", hue = "output")
sns.catplot(x = "fbs",data = heart, kind = "count", hue = "output")
sns.catplot(x = "restecg",data = heart, kind = "count", hue = "output")
sns.catplot(x = "exng", data = heart, kind = "count", hue = "output")
sns.catplot(x = "slp", data = heart, kind = "count", hue = "output")
sns.catplot(x = "caa", data = heart, kind = "count", hue = "output")
sns.catplot(x = "thall", data = heart, kind = "count", hue = "output")

# %% [markdown]
# **B. Visualizing Numerical Data**

# %%
sns.catplot(x = "output", y = "age", data = heart, kind = "box")
sns.catplot(x = "output", y = "trtbps", data = heart, kind = "box")
sns.catplot(x = "output", y = "chol", data = heart, kind = "box")
sns.catplot(x = "output", y = "thalachh", data = heart, kind = "box")
sns.catplot(x = "output", y = "oldpeak", data = heart, kind = "box")
