# %% [markdown]
# # Parallel KFold training on TPU using Pytorch Lightning
# This kernel demonstrates training K instances of a model parallely on each TPU core.

# %% [markdown]
# ### Install XLA
# XLA powers the TPU support for PyTorch

# %%
# !curl https://raw.githubusercontent.com/pytorch/xla/master/contrib/scripts/env-setup.py -o pytorch-xla-env-setup.py
# !python pytorch-xla-env-setup.py --version nightly --apt-packages libomp5 libopenblas-dev

# %%
# !git clone https://github.com/lezwon/pytorch-lightning.git

# %%
# !cd pytorch-lightning && git pull origin 1246_tpu_tests && git checkout 1246_tpu_tests

# %%
# !pip install -r pytorch-lightning/tests/requirements.txt

# %%
# !pytest pytorch-lightning/tests/models/test_tpu.py

# %%
# !pytest pytorch-lightning/tests/trainer/test_trainer.py::test_tpu_choice
