# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt   #Data Visualisation
import seaborn as sns

# %%
#Import file into notebook 
data = pd.read_csv('../input/stroke-prediction-dataset/healthcare-dataset-stroke-data.csv')
#First view of data set
data.head()

# %% [markdown]
# Explore more about Data available

# %%
data.count()

# %% [markdown]
# Here I found some null values in "bmi".

# %%
data.describe()

# %%
sns.boxplot(x='gender',y='age',data=data,palette='BuPu',order=['Female','Male'],hue='stroke')

# %% [markdown]
# This boxplot shows most of stroke patients belongs to more than 55 years age group.

# %%
print(data['stroke'].value_counts())

# %%
sns.countplot(x='stroke',hue='gender',data=data)

# %%
sns.distplot(data['avg_glucose_level'].dropna(),label='avg_glucose_level',color='darkred',bins=30)
plt.legend()

# %%
sns.distplot(data['bmi'],label='bmi')
plt.legend()

# %%
sns.countplot(x='stroke',hue='ever_married',data=data)

# %%
sns.catplot(data=data, kind="bar", x="smoking_status", y="stroke", hue="smoking_status")
