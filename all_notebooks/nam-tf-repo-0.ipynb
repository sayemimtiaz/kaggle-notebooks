# %%
# !git clone "https://github.com/PRATEEKKUMARAGNIHOTRI/google-research.git"
# %cd './google-research/neural_additive_models/'
# !pip uninstall tensorflow -y
# !pip -qq install tensorflow==1.15

# %%
# !mkdir /kaggle/working/logs
# !python nam_train.py --dataset_name='Housing'\
                     --logdir='/kaggle/working/logs'\
                     --training_epochs=20\
                     --regression=True\
                     --shallow=True\
                     --save_checkpoint_every_n_epochs=1\
                     --dropout=0.1\
                     --decay_rate=0.9\
                     --learning_rate=1e-3\
                     --num_basis_functions=512\
                     --units_multiplier=6\
                     --tf_seed=1\
                     --batch_size=4096
