# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_csv("../input/loan-predication/train_u6lujuX_CVtuZ9i (1).csv")
data.head(10)

# %%
X = data.drop(['Loan_ID','Loan_Status'],axis = 1)
y = data['Loan_Status']

# %%
data.info()

# %%
encoded_data = pd.get_dummies(X,drop_first = True)

# %%
X = encoded_data
X

# %%
y = pd.get_dummies(y, drop_first =True)

# %%
from sklearn.preprocessing import StandardScaler


scaler = StandardScaler(copy=True, with_mean=True, with_std=True)
X = scaler.fit_transform(X)

# %%
encoded_data.isnull().sum()

# %%
encoded_data['LoanAmount'].fillna(encoded_data['LoanAmount'].median(), inplace =True)
encoded_data['Loan_Amount_Term'].fillna(encoded_data['Loan_Amount_Term'].median(), inplace =True)
encoded_data['Credit_History'].fillna(encoded_data['Credit_History'].median(), inplace =True)

# %%
encoded_data.isnull().sum()

# %%
X=encoded_data
X

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=44, shuffle =True)

# %%
from xgboost import XGBClassifier
model= XGBClassifier(n_estimators =600, max_depth = 1,learning_rate = 0.005)
model.fit(X_train, y_train)


#finding important features
feature_rank = pd.DataFrame({'feature': X_train.columns,
                            'importance':model.feature_importances_})
feature_rank = feature_rank.sort_values('importance', ascending = False)
feature_rank

# %%
X_new = ['Credit_History','Property_Area_Semiurban','ApplicantIncome','LoanAmount','CoapplicantIncome']

# %%
X =encoded_data[X_new]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=44, shuffle =True)

# %%
from xgboost import XGBClassifier
model= XGBClassifier(n_estimators =600, max_depth = 1,learning_rate = 0.005)
model.fit(X_train, y_train)

# %%
pred= model.predict(X_test)

# %%
pred

# %%
print("Accuracy on training set: {:.2f}".format(model.score(X_train,y_train)))
print("Accuracy on testing set: {:.2f}".format(model.score(X_test,y_test)))

# %%
pred_prob = model.predict_proba(X_test)
from sklearn.metrics import roc_auc_score
roc_auc_score = roc_auc_score(y_test,pred_prob[:,1])
roc_auc_score

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score,f1_score
def scores(y_test,pred):
    acc = accuracy_score(y_test, pred)
    recall = recall_score(y_test,pred)
    f1 = f1_score(y_test,pred)
    precision = precision_score(y_test,pred)
    
    metric_evaluation = {'accuracy': round(acc,2),
                        'recall': round(recall,2),
                         'F1 score': round(f1,2),
                        'precision': round(precision,2)
                        }
    return print(metric_evaluation)

# %%
scores(y_test,pred)
