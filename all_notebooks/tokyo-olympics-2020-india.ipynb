# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd

# %% [markdown]
# # Import the data set by using pandas

# %%
data=pd.read_csv('/kaggle/input/2021-olympics-medals-in-tokyo/Tokyo Medals 2021.csv')

# %%
data.head()

# %%
data.shape

# %% [markdown]
# # Now let's check do we have null value or not

# %%
data.isnull().sum()

# %% [markdown]
# # Draw the heat map for the null values

# %%
#we know that we don't have null value so we will get plane heatmap
import seaborn as sns

# %%
sns.heatmap(data.isnull())

# %% [markdown]
# # Plot a bar graph of total medal vs the country name of top 10 country

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
sns.barplot(x=data['Total'][:10],y=data['Country'][:10])

# %%
df1=data

# %%
df1.head()

# %% [markdown]
# # Let's explore for india

# %%
data

# %%
data.Country=="India"

# %%
data.set_index("Country", inplace = True)

# %%
data.head()

# %%
result=data.loc["India"]

# %%
result

# %% [markdown]
# # If u see the india row number then it will be 47

# %%
df=data.iloc[[47]]

# %%
df

# %% [markdown]
# # Let's see the medal counts of india

# %%
df['Gold Medal']

# %%
df['Silver Medal']

# %%
df['Bronze Medal']

# %% [markdown]
# # let's check for maximum gold medal

# %%
df1['Gold Medal']

# %% [markdown]
# # Plot the country name vs Gold medal they won of top 10 country

# %%
oly=pd.read_csv('../input/2021-olympics-medals-in-tokyo/Tokyo Medals 2021.csv')

# %%
sns.barplot(x=oly['Gold Medal'][:10],y=oly['Country'][:10])

# %%
oly.head()

# %% [markdown]
# # Plot the country name vs Silver medal they won of top 10 country

# %%
sns.barplot(x=oly['Silver Medal'][:10],y=oly['Country'][:10])

# %% [markdown]
# # Plot the country name vs Bronze medal they won of top 10 country

# %%
sns.barplot(x=oly['Bronze Medal'][:10],y=oly['Country'][:10])
