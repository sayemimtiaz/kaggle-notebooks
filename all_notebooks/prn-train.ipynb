# %%
# !cp -r ../input/prn-aflw2000/SourceCode ./SourceCode

# %%
cd ./SourceCode

# %%
pip install imutils

# %%
# !python train_model.py --hdf5dir /kaggle/input/prn-aflw2000 --epochs 50 --learningrate 0.5 --lossfunct wmsela

# %%
# !ls ./output
# !zip -r /kaggle/working/output.zip ./output

# %%
import os
#os.chdir(r'/kaggle/working')
from IPython.display import FileLink
FileLink(r'../output.zip')
