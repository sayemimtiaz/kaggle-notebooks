# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-pastel')

# %%
df = pd.read_csv('/kaggle/input/twewy-game-script/twewy-name-line-full.csv')

# %%
len(df) # number of lines

# %%
len(df[df.name == 'Neku']) # number of lines of the given character

# %%
df.sample(10)

# %%
df.name.value_counts().plot.pie()

# %%
df = pd.read_csv('/kaggle/input/twewy-game-script/twewy-name-line-main-game.csv')

# %%
len(df)

# %%
df.name.value_counts().plot.pie()
