# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # 1-The project description:

# %% [markdown]
# *Information about the project(project name, dataset, data source,
# what does it contain and how it will be usefull)

# %% [raw]
# -Project name: Country_vaccinations explanatory data analysis
# -Dataset: Country_vaccinations
# -Data source: Kaggle
# -What it contains: Information about Covid-19 vaccinations
# -How it will be useful: To know the most used vaccines and the country with biggest number of vaccinated people.

# %% [markdown]
# # 2-Questions to be answered

# %% [raw]
# 1-Which vaccines are mostly used ?
# 2-Which country has the biggest number of vaccinated people ?

# %% [markdown]
# # 3-Data preperation and looking at some information:

# %% [raw]
# -Importing the libiraries
# -Reading the data
# -looking at some information about the data
# -Knowing the number of missing data
# -Choosing some columns to be analysed

# %% [markdown]
# # 4-Cleaning and processing the missing data:

# %% [markdown]
# ## Answering the questions by analysing the choosen columns

# %% [markdown]
# # 5-Summary and conclusion:

# %% [markdown]
# @@@@@@@@@@   @@@@@@@@@@@@   @@@@@@@@@@@@@@@   @@@@@@@@@@@@@@   @@@@@@@@@@@@

# %% [markdown]
# ## Data preperation and cleaning:

# %% [markdown]
# 1-Importing the necessery libiraries

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
import numpy as np

# %% [markdown]
# ##### Reading the data

# %%
df = pd.read_csv("/kaggle/input/country-vaccination/country_vaccinations.csv")

# %% [markdown]
# 2-Looking at some information about the data

# %%
df.shape

# %%
df.info

# %%
df.size

# %%
df.describe()

# %%
df.head(20)

# %%
df.tail(10)

# %%
df.mean()

# %%
list(df.columns)

# %%
df.country.describe()

# %%
df.vaccines.unique().size

# %%
df['country'].head(20)  # Prints the first 10 eliments of the column1. Darray

# %%
df[['country', 'vaccines', 'people_fully_vaccinated']].head(100) # Prints the first 10 eliments of the columns. DF

# %%
list(df['country'].unique()) # It ge/'ts the unique values of the whole column, in a list

# %%
df.iloc[:20]      # Will Show the values in a specefic row or rows (horizontaly).

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64'] # The numeric columns
numeric_df = df.select_dtypes(include=numerics)

# %%
len(numeric_df.columns)  # Shows the number fo numeric columns

# %%
list(numeric_df.columns)

# %% [markdown]
# 3-Knowing the number of missing data

# %%
df.isnull().sum().sort_values(ascending=False) #Columns with missing values

# %%
df.vaccines.count()

# %% [markdown]
# ##### 4-Percentage of missing values per column

# %%
df.isnull().sum().sort_values(ascending=False)/len(df)

# %%
missing_percentages = df.isna().sum().sort_values(ascending=True)/len(df)
missing_percentages

# %%
missing_percentages[missing_percentages != 0].sort_values(ascending=False).plot(kind='barh')

# %%
sns.distplot(missing_percentages[missing_percentages != 0].sort_values(ascending=False))

# %% [markdown]
# ###### Cleaning and processing the missing data:

# %%
df.dtypes

# %%
list(df.columns)

# %%
df['total_vaccinations'] = df['total_vaccinations'].astype(float)

# %% [markdown]
# 5-Choosing some columns to be analysed

# %% [raw]
# *country
# *vaccines
# *total_vaccinations

# %% [markdown]
# @@@@@@@@@@   @@@@@@@@@@@@   @@@@@@@@@@@@@@@   @@@@@@@@@@@@@@   @@@@@@@@@@@@

# %% [markdown]
# ## Answering the questions by analysing the choosen columns:

# %% [raw]
# 1-Which vaccines are mostly used ?

# %%
vaccines_uniques = df.vaccines.unique()
list(vaccines_uniques)

# %%
vaccine_values = df.vaccines.value_counts()
vaccine_values[:7]

# %%
# Plotting the vaccines to know the most used ones.
df.groupby('vaccines').size().plot(kind='bar')

# %% [markdown]
# ##### 2-Which country has the biggest percentage or number of vaccinated people ?

# %%
df.total_vaccinations.max()

# %%
total_vaccinations_max = df[df['total_vaccinations']>110000000]
total_vaccinations_max[:5]

# %% [raw]
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
df.daily_vaccinations.max()

# %%
d_v = df[df['daily_vaccinations']>2541000]
d_v[:5]

# %%
total_vaccinations_max = df[df['total_vaccinations']>0]
total_vaccinations_max[:10]

# %%
df["min_value"] = df[['total_vaccinations']].min(axis=1)
df["min_value"]

# %% [markdown]
# @@@@@@@@@@   @@@@@@@@@@@@   @@@@@@@@@@@@@@@   @@@@@@@@@@@@@@   @@@@@@@@@@@@

# %% [markdown]
# # 2-Answering the questions:

# %% [raw]
# 1-Which vaccines are mostly used ?
# -The mostly used vaccines are Moderna, Oxford/AstraZeneca and Pfizer/BioNTech.

# %% [raw]
# 2-Which country has the biggest number of vaccinated people ?
# -It is United States of America

# %% [markdown]
# @@@@@@@@@@   @@@@@@@@@@@@   @@@@@@@@@@@@@@@   @@@@@@@@@@@@@@   @@@@@@@@@@@@

# %% [markdown]
# # 6-The summary and conclusion:

# %% [raw]
# -137 is the number of countries contained in the dataset.
# -The minimum number of total_vaccinations with Pfizer/BioNTech was 128 people in Albania.
# -The maximum number of daily_vaccinations is 2541597 people in USA with Johnson&Johnson, Moderna and Pfizer/BioNTech.
