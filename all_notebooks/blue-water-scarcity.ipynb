# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import pandas
import plotly.express as px
import plotly.graph_objs as go

import plotly

# warning library
import warnings
warnings.filterwarnings("ignore")

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# #Water scarcity statistics
#
#
# Unique dataset showing blue water scarcity in the world on a monthly basis, both at 30x30 arc minute resolution and per river basin.
#
# https://waterfootprint.org/en/resources/waterstat/

# %% [markdown]
# ![](https://slideplayer.com/slide/5955745/20/images/41/2.+Which+locations+in+the+world+are+facing+water+shortage.jpg)slideplayer.com

# %% [markdown]
# <center style="font-family:verdana;"><h1 style="font-size:200%; padding: 20px; background: #001f3f;"><i><b style="color:orange;">Water Stress and Water Scarcity</b></i></h1></center>
#
# Future Transboundary Water Stress and Its Drivers Under Climate Change: A Global Study
#
# Authors: Hafsa Ahmed Munia, Joseph H. A. Guillaume, Yoshihide Wada, Ted Veldkamp, Vili Virkki, Matti Kummu
# 25 May 2020 https://doi.org/10.1029/2019EF001321
#
# "Various transboundary river basins are facing increased pressure on water resources in near future. However, little is known about the future drivers globally, namely, changes in natural local runoff and natural inflows from upstream parts of a basin, as well as local and upstream water consumption."
#
# "The results show that population under water stress is expected to increase by 50% under a low population growth and emissions scenario and double under a high population growth and emission scenario, compared to the year 2010. As changes in water availability have a smaller effect when water is not yet scarce, changes in water stress globally are dominated by local water consumption—managing local demand is thus necessary in order to avoid future stress."
#
# "Focusing then on the role of upstream changes, the authors identified upstream availability (i.e., less natural runoff or increased water consumption) as the dominant driver of changes in net water availability in most downstream areas. Moreover, an increased number of people will be living in areas dependent on upstream originating water in 2050. International water treaties and management will therefore have an increasingly crucial role in these hot spot regions to ensure fair management of transboundary water resources."
#
# https://agupubs.onlinelibrary.wiley.com/doi/10.1029/2019EF001321

# %%
df = pandas.read_csv('/kaggle/input/cusersmarildownloadsscarcitycsv/scarcity.csv',  delimiter=';')

df.head().style.set_properties(**{'background-color':'Aqua',
                                     'color': 'purple'})

# %% [markdown]
# ![](https://slidetodoc.com/presentation_image/aa98f7a30619bdb49bec0e8477a27b1b/image-10.jpg)slidetodoc.com

# %%
df.isnull().sum()

# %% [markdown]
# ##Code by Tejashvi14 https://www.kaggle.com/tejashvi14/storytelling-through-eda-asia-tour/notebook

# %% [markdown]
# #Ten Highest Population (Near River Basins)

# %%
#Code by Tejashvi14 https://www.kaggle.com/tejashvi14/storytelling-through-eda-asia-tour/comments

dfPop=df.sort_values(by='population',ascending=False)
dfPop.head(10)

# %%
#Code by Tejashvi14 https://www.kaggle.com/tejashvi14/storytelling-through-eda-asia-tour/notebook

sns.catplot(x="basin_name", y="population", kind="bar", data=dfPop.head(10),height=5, aspect=27/9,)
plt.title('River Basins & 10 Highest Populations');

# %% [markdown]
# #Low Water Scarcity

# %%
#Code by Tejashvi14 https://www.kaggle.com/tejashvi14/storytelling-through-eda-asia-tour/comments

dfLow=df.sort_values(by='low',ascending=False)
dfLow.head()

# %%
#Code by Tejashvi14 https://www.kaggle.com/tejashvi14/storytelling-through-eda-asia-tour/notebook

sns.catplot(x="low", y="population", kind="bar", data=dfPop.head(10),height=5, aspect=27/9,)
plt.title('Low Water Scarcity & Populations');

# %% [markdown]
# #Moderate Water Scarcity

# %%
#Code by Tejashvi14 https://www.kaggle.com/tejashvi14/storytelling-through-eda-asia-tour/comments

dfMod=df.sort_values(by='moderate',ascending=False)
dfMod.head()

# %%
#Code by Tejashvi14 https://www.kaggle.com/tejashvi14/storytelling-through-eda-asia-tour/notebook

sns.catplot(x="moderate", y="population", kind="bar", data=dfPop.head(10),height=5, aspect=27/9,)
plt.title('Moderate Water Scarcity & Populations');

# %% [markdown]
# #Severe Water Scarcity

# %%
#Code by Tejashvi14 https://www.kaggle.com/tejashvi14/storytelling-through-eda-asia-tour/comments

dfSev=df.sort_values(by='severe',ascending=False)
dfSev.head()

# %%
#Code by Tejashvi14 https://www.kaggle.com/tejashvi14/storytelling-through-eda-asia-tour/notebook

sns.catplot(x="basin_name", y="severe", kind="bar", data=dfSev.head(10),height=5, aspect=27/9,)
plt.title('Severe Water Scarcity in River Basins');

# %% [markdown]
# #It was not very good since all have the same Severe Water Scarcity value (12)

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis

sns.distplot(df['low'])
plt.axvline(df['low'].values.mean(), color='red', linestyle='dashed', linewidth=1)
plt.title('Low Water Scarcity Distribution');

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis

sns.distplot(df['severe'])
plt.axvline(df['severe'].values.mean(), color='red', linestyle='dashed', linewidth=1)
plt.title('Severe Water Scarcity Distribution');

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis

sns.distplot(df['moderate'])
plt.axvline(df['moderate'].values.mean(), color='red', linestyle='dashed', linewidth=1)
plt.title('Moderate Water Scarcity Distribution');

# %%
#Code by Puru Behl https://www.kaggle.com/accountstatus/mt-cars-data-analysis

sns.distplot(df['significant'])
plt.axvline(df['significant'].values.mean(), color='red', linestyle='dashed', linewidth=1)
plt.title('Significant Water Scarcity Distribution');

# %% [markdown]
# #Bigger Basins, Low Water Scarcity (till now).

# %%
amazonas = df[(df['basin_name']=='Amazonas')].reset_index(drop=True)
amazonas.head()

# %%
nile = df[(df['basin_name']=='Nile')].reset_index(drop=True)
nile.head()

# %%
#Code by Tejashvi14 https://www.kaggle.com/tejashvi14/storytelling-through-eda-asia-tour/notebook

sns.catplot(x="significant", y="population", kind="bar", data=dfPop.head(10),height=5, aspect=27/9,)
plt.title('Significant Water Scarcity & Populations');

# %% [markdown]
# #Nile basin shows Low and Severe Scarcity

# %%
#It requires an space after Mississippi

mississippi = df[(df['basin_name']=='Mississippi ')].reset_index(drop=True)
mississippi.head()

# %% [markdown]
# #It's interesting to read that Mississippi has 3 different values of Water Scarcity

# %%
congo = df[(df['basin_name']=='Congo')].reset_index(drop=True)
congo.head()

# %%
#Code by Tejashvi14 https://www.kaggle.com/tejashvi14/storytelling-through-eda-asia-tour/notebook

sns.catplot(x="severe", y="population", kind="bar", data=dfPop.head(10),height=5, aspect=27/9,)
plt.title('Severe Water Scarcity & Populations');

# %%
#Make a New Dataframe with some that you choose (Amazonas, Nile, Mississippi, Lake Chad, Lake Mar Chiquita)

#Code by Tejashvi14 https://www.kaggle.com/tejashvi14/storytelling-through-eda-asia-tour/notebook

df1=df.iloc[[258,193,121,355, 394],:]
df1

# %%
#Code by Tejashvi14 https://www.kaggle.com/tejashvi14/storytelling-through-eda-asia-tour/notebook

sns.catplot(x="basin_name", y="low", kind="bar", data=df1,height=5, aspect=27/9,)
plt.title('Low Water Scarcity in River Basins');

# %%
#Code by Tejashvi14 https://www.kaggle.com/tejashvi14/storytelling-through-eda-asia-tour/notebook

sns.catplot(x="basin_name", y="severe", kind="bar", data=df1,height=5, aspect=27/9,)
plt.title('Severe Water Scarcity in River Basins');

# %%
#Code by Tejashvi14 https://www.kaggle.com/tejashvi14/storytelling-through-eda-asia-tour/notebook

sns.catplot(x="moderate", y="basin_name", kind="bar", data=df1,height=5, aspect=27/9,)
plt.title('Moderate Water Scarcity in River Basins');

# %%
fig = px.bar(df1, 
             x='basin_name', y='population', color_discrete_sequence=['cyan'],
             title='Low Water Scarcity & Populations', text='low')
fig.show()

# %%
fig = px.bar(df1, 
             x='severe', y='population', color_discrete_sequence=['Aqua'],
             title='Severe Water Scarcity in River Basins', text='basin_name')
fig.show()

# %%
fig = px.bar(df1, 
             x='basin_name', y='moderate', color_discrete_sequence=['#00FFFF'],
             title='Moderate Water Scarcity & River Basins', text='population')
fig.show()

# %%
fig = px.bar(df1, 
             x='basin_name', y='average', color_discrete_sequence=['#00FFFF'],
             title='Average of Water Scarcity & Populations', text='population')
fig.show()

# %%
#word cloud
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in df1.basin_name)
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200,colormap='GnBu', background_color="Aqua").generate(text)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='Bilinear')
plt.axis("off")
plt.figure(1,figsize=(12, 12))
plt.show()

# %%
#Code by Olga Belitskaya https://www.kaggle.com/olgabelitskaya/sequential-data/comments
from IPython.display import display,HTML
c1,c2,f1,f2,fs1,fs2=\
'#eb3434','#eb3446','Akronim','Smokum',30,15
def dhtml(string,fontcolor=c1,font=f1,fontsize=fs1):
    display(HTML("""<style>
    @import 'https://fonts.googleapis.com/css?family="""\
    +font+"""&effect=3d-float';</style>
    <h1 class='font-effect-3d-float' style='font-family:"""+\
    font+"""; color:"""+fontcolor+"""; font-size:"""+\
    str(fontsize)+"""px;'>%s</h1>"""%string))
    
    
dhtml('Thank you again Tejashvi 14' )
