# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# Exercise 1 - Part 1

# %%
S=pd.Series(np.array([10,11,12,3,4,5,7,9,15,20]), index=[10,21,33,36,40,45,52,61,76,96])

# %%
S

# %% [markdown]
# Function deleting index numbers non divisible by 3

# %%
def ex1(S):
      v=S.index
      w=v[v%3==0] 
      return S[w]

# %%
ex1(S)

# %% [markdown]
# Part II - Exercise 1 - Life Expectancy

# %%
df=pd.read_csv('../input/datasetexam2/Group2.csv')

# %%
df.head(15)

# %% [markdown]
# Droping all the NA values of the data frame

# %%
df1=df.dropna()

# %%
from sklearn.model_selection import train_test_split

# %%
df1.corr()

# %%
df1.corr()['Life_expectancy']['Adult_Mortality']

# %%
df1.corr()['Life_expectancy']['infant_deaths']

# %%
df1.corr()['Life_expectancy']['Total expenditure']

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
df1.hist()

# %%
X=df1[[ 'Adult_Mortality','GDP','Income_composition_of_resources','Schooling']]

# %% [markdown]
# Determining the variables used in our model in link with the correlation with life expectancy.

# %%
X.corr()

# %%
Y=df1['Life_expectancy']

# %%
Y

# %%
X

# %%
Y.fillna(Y.mean())

# %% [markdown]
# Testing the linear regression for our model

# %%
result=train_test_split(X,Y,test_size=0.02)

# %%
X_train = result[0] 
X_test  = result[1]
Y_train = result[2]
Y_test  = result[3]

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
X_train.head(15)

# %%
Y_train.head(15)

# %% [markdown]
# Fitting our model to the data used

# %%
Y_train

# %%
Y_train.fillna(Y_train.mean())

# %%
lr.fit(X_train,Y_train)

# %%
Ypred=lr.predict(X_test)

# %%
Ypred-Y_test

# %%
np.linalg.norm(Y_test-Ypred)/np.linalg.norm(Y_test)

# %% [markdown]
# The relative error is of 6.5% which is quit good! Let's try by droping or adding another variable

# %% [markdown]
# Deleting Adult mortality of our model as the corrélation is lower than the others with life expectancy

# %%
X2=df1[['GDP','Income_composition_of_resources','Schooling']]

# %%
Y2=df1['Life_expectancy']

# %%
result=train_test_split(X2,Y2,test_size=0.02)

# %%
X2_train = result[0] 
X2_test  = result[1]
Y2_train = result[2]
Y2_test  = result[3]

# %%
lr.fit(X2_train,Y2_train)

# %%
Y2pred=lr.predict(X2_test)

# %%
Y2pred-Y2_test

# %%
np.linalg.norm(Y2_test-Y2pred)/np.linalg.norm(Y2_test)

# %% [markdown]
# The relative error went from 6.5% to 5.9%, By dropping the adult mortality, with have ameliorate our model.
