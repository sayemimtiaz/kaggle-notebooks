# %%
from IPython import display
newtree = display.HTML(url="https://docs.google.com/document/d/e/2PACX-1vRwLhnZ-o-An5q5fxv0w2TJ5X578VCVc4o9kN0HdiZY76fJSR0pZGJA0uv14F4xDaZ592NbhaBpnLhI/pub")
display.display(newtree)
