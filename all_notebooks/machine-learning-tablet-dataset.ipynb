# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("../input/bakircayd2do-tabletdataset/tablet.csv")
df = dataset.copy()
df

# %%
df.head()

# %%
df.info()

# %%
df.isna().sum()

# %%
df.shape

# %%
df.describe().T
