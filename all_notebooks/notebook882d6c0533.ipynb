# %%
import numpy as np
import pandas as pd
import seaborn as sns
import missingno as mosn
import matplotlib.pyplot as plt
import os

# %%
data=pd.read_csv("../input/customer-clustering/segmentation data.csv")

# %%
data.head()

# %%
data.info()

# %% [markdown]
# data.describe()

# %%
mosn.bar(data)

# %% [markdown]
# # No Missing Data

# %%
plt.figure(figsize=(12,12))
sns.heatmap(data=data.corr() , annot=True)

# %%
data.head()

# %%
sns.countplot(x=data['Sex'], hue=data['Marital status'])

# %%
sns.countplot(x=data['Sex'], hue=data['Education'])

# %%
data['Income'].hist()

# %%
data['Age'].hist()

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=data , x="Age", y="Income",markers="o",color='red')

# %%
sns.barplot(data=data,x='Education',y='Income')

# %%
top_income=data[data['Income']>250000]

# %%
top_income

# %%
sns.lineplot(x='Age', y='Income', data=top_income)

# %%
sns.barplot(x='Education', y='Income', data=top_income)
