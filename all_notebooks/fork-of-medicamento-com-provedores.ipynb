# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %% [markdown]
# # Lista de medicamentos e seus provedores

# %%
drugs=pd.read_csv('/kaggle/input/drugs-prescriptions-with-providers/medicine_prescription_records.csv')

# %% [markdown]
# # 5 Primeiros medicamentos mais indicados por provedores

# %%
drugs.sort_values("specialty").head()

# %% [markdown]
# # Contabilizando valores não em branco

# %%
drugs.sort_values("specialty", ascending= False).count()

# %% [markdown]
# # Descrição Geral diante especialidades

# %%
drugs.sort_values("specialty", ascending= False).describe()

# %% [markdown]
# # Número de colunas e linhas

# %%
drugs.shape

# %% [markdown]
# # Tabela com numeros verdadeiros de acordo com a especialidades indicadas por provedores

# %%
drugs.sample(5).T

# %% [markdown]
# # Média entre a duração de anos diante as indicações de medicamentos feita por provedores

# %%
drugs['years_practicing'].mean()

# %% [markdown]
# # Histograma

# %% [markdown]
# # Gráfico de especialidades de acordo com a indicação feita por provedores

# %%
ind_des=drugs['specialty']

# %%
ind_des[0:10].value_counts().plot.bar()
