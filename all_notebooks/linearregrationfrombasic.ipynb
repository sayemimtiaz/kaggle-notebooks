# %% [markdown]
# I will implement code to model linear regration for predicting house price. in this model i will use california housing price data.

# %%
import numpy as np
import pandas as pd

# %%
dataset=pd.read_csv('../input/california-housing-prices/housing.csv')

# %%
dataset.head()

# %% [markdown]
# **cost function**:regularized linear regression has the following cost function:
# !(http://)![image.png](attachment:image.png)

# %%
def costFun(x,y,theta,lamb):
    h=np.dot(theta,x.T)
    J=(1/(2*len(x)))*np.sum(np.square(h-y))+(lamb/(2*len(x)))*np.sum(np.square(theta[1:]))
    return J

# %% [markdown]
# **Regularized linear regression gradient**
# the partial derivative of regularized linear regression's cost for  is defined as:
#
#
#    ![image.png](attachment:image.png)

# %% [markdown]
# **Fitting linear regression**:
# Once my cost function and gradient are working correctly, the code in this section will run the code in training linear ligration to compute the optimal values of theta

# %%
def gradient_decent(x,y,theta,alpha,total_iter,lamb):
    m=len(x)
    for i in range(0,total_iter):
        h=np.dot(theta,x.T)
        theta[0]-=(alpha/m)*np.sum((h-y)*x.iloc[:,0])
        for j in range(1,len(x.columns)):
            theta[j]-=((alpha/m)*(np.sum((h-y)*x.iloc[:,j])+(lamb)*theta[j]))
    return theta

# %% [markdown]
# **Data preprocessing**

# %%
X=dataset.drop(columns=["ocean_proximity","median_house_value"])
Y=dataset["median_house_value"]
for i in range(0,len(X.columns)):
    X.iloc[:,i]=(X.iloc[:,i]-min(X.iloc[:,i]))/((max(X.iloc[:,i])-min(X.iloc[:,i])))
Y=(Y-min(Y))/(max(Y)-min(Y))

# %%
X = pd.concat([pd.Series(1, index = X.index, name = '00'), X], axis=1)

# %%
def predictHousePrice(x,alpha,theta,num_iter,lamb):
   
    predict_price=np.dot(theta,x.T)
    return predict_price

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=123)

# %%
alpha=.001
lamb=1
total_iter=5000

train_theta= gradient_decent(x_train,y_train,[.5]*len(X.columns),alpha,total_iter,lamb)
cost=costFun(x_test,y_test,train_theta,lamb)
print(cost)

# %% [markdown]
# afer taking 5000 nomber of iteration and learning rate 0.001, and setting regularization coefficient=1, i calculated cost function that is .02325... which is acceptable.

# %% [markdown]
# main motive behinde this implementation of code was  to learn basic of linear regration algorithm.

# %% [markdown]
# plzz..do some comment on my work that i can improve and gain confident.
