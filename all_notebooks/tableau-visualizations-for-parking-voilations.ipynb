# %% [markdown]
# Created below dashboard using Tableau public. You can filter by Voilation Description or by Day of Week. Click on any block or bar to view Map, I suggest using below tableau public link for viewing properly.  Please provide your feedback.
#
# Original Link: https://public.tableau.com/profile/mohit5191#!/vizhome/ColumbiaDistrictDec2015ParkingVoilations/Dashboard1

# %%
from IPython.display import IFrame
IFrame('https://public.tableau.com/shared/MQMXRKDNP?:display_count=yes', width=1000, height=900)
