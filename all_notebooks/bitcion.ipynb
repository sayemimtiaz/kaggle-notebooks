# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install --upgrade mplfinance

from datetime import datetime

import mplfinance as mpf

# %%
# config 
DATASET_DIR = "../input/btcusd/"
SYMBOL = "BTCUSD"

# %%
def get_prices(START, STOP):
    DataName = SYMBOL+"_"+str(PERIOD)+'.csv'
    prices = pd.read_csv(DATASET_DIR + DataName)
    prices['time'] = pd.to_datetime(prices['time'])
    prices = prices.set_index("time")
    prices = prices.rename(columns={'tick_volume':'volume'})
    prices = prices[START < prices.index]
    prices = prices[STOP > prices.index]
    return prices


PERIOD = 60

START_DATE = datetime(2011, 1, 1)
STOP_DATE = datetime(2021, 6, 1)

df = get_prices(START_DATE,STOP_DATE)

print(df.head())

mpf.plot(df,type='line')

# %%
PERIOD = 1440

START_DATE = datetime(2021, 5, 1)
STOP_DATE = datetime(2021, 6, 1)

df = get_prices(START_DATE,STOP_DATE)

mpf.plot(df,type='candle',mav=(5,10,13))

# %%
PERIOD = 30

START_DATE = datetime(2021, 5, 30)
STOP_DATE = datetime(2021, 6, 1)

df = get_prices(START_DATE,STOP_DATE)

mpf.plot(df,type='ohlc',mav=(5,10,13),volume=True)

# %%
PERIOD = 1

START_DATE = datetime(2021, 5, 31, 15)
STOP_DATE = datetime(2021, 6, 1)

df = get_prices(START_DATE,STOP_DATE)

mpf.plot(df,type='renko',mav=(5,10,13),volume=True)
