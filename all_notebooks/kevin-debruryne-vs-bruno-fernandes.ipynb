# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
players=pd.read_csv('/kaggle/input/epl-stats-20192020/players_1920_fin.csv')
players.head()

# %%
players.info()

# %% [markdown]
# so no null values !!!
# NOW lets compare most trending players for fierce rivals i.e ManCity vs Manutd
# > **> arguably the best player in premier league :**Kevin De Bruyne** vs ManUtd winter Signing **Bruno Fernandes**
# now we are gonna compare them and so who did better this season
# > **STATS DONT LIE**

# %% [markdown]
# **LETS IMPORT BOTH THIER RESPECTIVE DATA**

# %%
debru=players[players['full']=='Kevin De Bruyne']
bruno=players[players['full']=='Bruno Miguel Borges Fernandes']

# %%
plt.subplot(1,2,1)
sns.countplot(x='assists',data=debru).set_title('DE BRUYNE') # More on color options later
plt.subplot(1,2,2)
sns.countplot(x='assists',data=bruno).set_title('BRUNO FERNANDES')

# %%
plt.subplot(1,2,1)
sns.boxplot(debru['assists'].value_counts()/38).set_title('DE BRUYNE')
plt.subplot(1,2,2)
sns.boxplot(bruno['assists'].value_counts()/14).set_title('BRUNO FERNANDES')

# %% [markdown]
# **AS COUNTING ASSITS WILL BE OF NO USE BECAUSE FERNANDES JOINED MID SEASON, BUT WE CAN SEE THAT THE PATTERNS OF ASSISTING IS SUPRISINGLY SIMILAR BETWEEN BOTH THE TWO** HOW EVER AT PER GAME BRUNO SUPRSINGLY AHEAD OF DEBRUYNE

# %%
plt.subplot(1,2,1)
sns.countplot(x='bonus',data=debru).set_title('DE BRUYNE') # More on color options later
plt.subplot(1,2,2)
sns.countplot(x='bonus',data=bruno).set_title('BRUNO FERNANDES')

# %% [markdown]
# > **THE APPRECIATION SHOWN BY THIER RESPECTIVE CLUBS IN THE WAY OF BONUSES CAN BE SEEN ABOVE WHILE DEBRYNE WAS BETTER THROUGHOUT THE BONUSES WITH THIER RELATIVE  MATCHES BUT BRUNO FERNANDES DID AMAZING AS WELL FOR HIS FIRST SEASON**

# %%
sns.boxplot(debru['bonus'].value_counts()/38)

# %%
sns.boxplot(bruno['bonus'].value_counts()/14)

# %% [markdown]
#     # > however as game per bonus we can see that we can see that **BRUNO FERNANDES
#     ** is just edge past **Debruyne**

# %%
g = sns.FacetGrid(data=debru,col='was_home')
g.map(plt.hist,'minutes')

# %%
g = sns.FacetGrid(data=bruno,col='was_home')
g.map(plt.hist,'minutes')

# %% [markdown]
# > as we can *minutes* are well given to both the players we can see debuyne have some less minutes in some matches but since as long season this season was.. and playing 38 matches as whole we can see he getting less minutes as for bruno he played more than 60 minutes every time whether home or away

# %%
plt.subplot(1,2,1)
sns.countplot(x='assists',data=debru,hue='was_home').set_title('DE BRUYNE') # More on color options later
plt.subplot(1,2,2)
sns.countplot(x='assists',data=bruno,hue='was_home').set_title('BRUNO FERNANDES')

# %% [markdown]
# > debruyne assists in home game stas are pretty ridiculous more frequently having an assist rather than not one
# > bruno fernandes home record is pretty extraordinary too

# %%
plt.subplot(1,2,1)
sns.countplot(x='goals_scored',data=debru,hue='was_home').set_title('DE BRUYNE')
plt.subplot(1,2,2)
sns.countplot(x='goals_scored',data=bruno,hue='was_home').set_title('BRUNO FERNANDES')

# %%
plt.subplot(1,2,1)
sns.boxplot(debru['goals_scored'].value_counts()/38).set_title('DE BRUYNE')
plt.subplot(1,2,2)
sns.boxplot(bruno['goals_scored'].value_counts()/14).set_title('BRUNO FERNANDES')

# %% [markdown]
# > > > AS WE CAN CLEARY SEE BOTH PERFORMED TREMENDOUSLY THROUGHOUT THE SEASON IN TERMS OF GOALS AS A MIDFIELDER HOWEVER THIS NEEDS TO BE TAKEN INTO FACT THAT BRUNO FERNANDES IS A PENALTY TAKER FOR THE TEAM AND HERE WE CAN SEE THAT**BRUNO** HAS A BETTER GOAL SCORING SEASON.

# %% [markdown]
# > SO WE CAN FARELY CONCLUDE THAT BRUNO MAY HAVE A BETTER IN GAME SEASON THAN KEVIN DEBRUYNE HOWEVER WE CANT ARGUE THAT HE PLAYED THROUGHOUT THE SEASON AND AGAINST BIG TEAMS WHICH FEERNANDES DIDNT

# %% [markdown]
# SO THIS CAN BE ONLY COMPLETE FAIR ANALYSIS  WHEN THEY PLAY THOUGHOUT THE SEASON THAT IS NEXT SEASON !!!!

# %%
debru['opponent_team'].unique()

# %%
bruno['opponent_team'].unique()
