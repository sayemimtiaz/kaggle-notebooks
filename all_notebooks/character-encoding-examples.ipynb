# %%
import pandas as pd
import numpy as np
import chardet

# %%
with open ('../input/character-encoding-examples/die_ISO-8859-1.txt','rb') as x:
    result=chardet.detect(x.read(100000))
print(result)

# %%
file1=pd.read_table('../input/character-encoding-examples/die_ISO-8859-1.txt',encoding='ISO-8859-1')
file1.to_csv('die_ISO-8859-2.txt',header=False,index=False,mode='a',sep=' ')
file1

# %%
with open('../input/character-encoding-examples/file_guide.csv','rb') as x:
    
    print(chardet.detect(x.read(10000)))

# %%
with open('../input/character-encoding-examples/harpers_ASCII.txt','rb') as x:
    print(chardet.detect(x.read(100000)))

# %%
file2=pd.read_table('../input/character-encoding-examples/harpers_ASCII.txt',encoding='ascii')
file2.to_csv('harpers_ASCII.txt',header=False,index=False,mode='a',sep=' ')
file2.head()

# %%
file3=pd.read_table('../input/character-encoding-examples/olaf_Windows-1251.txt',encoding='Windows-1251')
file3.to_csv('olaf_Windows-1251.txt',header=False,index=False,mode='a',sep=' ')
file3.head()

# %%
file4=pd.read_table('../input/character-encoding-examples/portugal_ISO-8859-1.txt',encoding='ISO-8859-1')
file4.to_csv('portugal_ISO-8859-1.txt',header=False,index=False,mode='a',sep=' ')
file4.head()

# %%
file5=pd.read_table('../input/character-encoding-examples/shisei_UTF-8.txt',encoding='UTF-8')
file5.to_csv('shisei_UTF-8.txt',header=False,index=False,mode='a',sep=' ')
file5.head()

# %%
with open('../input/character-encoding-examples/yan_BIG-5.txt','rb') as x:
    print(chardet.detect(x.read(100000)))
file6=pd.read_table('../input/character-encoding-examples/yan_BIG-5.txt',encoding='Big5')
file6.to_csv('yan_BIG-5.txt',header=False,index=False,mode='a',sep=' ')
file6.head()
