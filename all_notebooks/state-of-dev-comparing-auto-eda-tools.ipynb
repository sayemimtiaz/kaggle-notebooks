# %% [markdown]
# ## Trying to explore the different tools of doing Automated EDA, and demonstrating them on the [State of Dev](https://www.kaggle.com/amr009/state-of-dev-mrocco-2020) dataset

# %%
import numpy as np 
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from pandas_profiling import ProfileReport

import gc
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('max_rows', 300)


pd.set_option('display.max_columns', 300)
np.random.seed(566)
pd.set_option('display.max_rows', 200)
pd.set_option('display.width', 1000)
pd.set_option('display.float_format', '{:20,.2f}'.format)
pd.set_option('display.max_colwidth', -1)

# %%
df = pd.read_csv("../input/state-of-dev-mrocco-2020/results_preprocessed.csv")
print(df.shape)

# %% [markdown]
# ### Pandas_Profile:
# Pandas_Profiling extends the pandas DataFrame with df.profile_report() for quick data analysis. Missing values, cardinality, distributions, .... all in a single call function.
#
# - Check the github repository and examples: https://github.com/pandas-profiling/pandas-profiling

# %%
trainprofile = ProfileReport(df,'EDA')

# %%
trainprofile

# %% [markdown]
# ### Sweetviz:
# Sweetviz is an open-source Python library that generates beautiful, high-density visualizations to kickstart EDA (Exploratory Data Analysis) with a single line of code. The output is a fully self-contained HTML application. The system is built around quickly visualizing target values and comparing datasets. Its goal is to help quick analysis of target characteristics, training vs testing data, and other such data characterization tasks.
#
# - Read more about it here: https://pypi.org/project/sweetviz/

# %%
# !pip install sweetviz
import sweetviz as sv
#analyzing the dataset
data_report = sv.analyze(df)

# %%
#Display the output in notebook
data_report.show_notebook()

# %% [markdown]
# ### Dabl: the Data Analysis Baseline Library
# dabl has several tools that make it easy to clean and inspect your data, and create strong baseline models.
#
# - Official Documentation : https://amueller.github.io/dabl/dev/quick_start.html

# %%
# !pip install dabl

# %% [markdown]
# #### Data Cleaning

# %%
import dabl
dabl.clean(df)

# %%
dabl.plot(df, "Immigration_Plans")

# %% [markdown]
# ### **If you like this notebook, please upvote and share your feedback :)**
# ##### More updates to come!!
