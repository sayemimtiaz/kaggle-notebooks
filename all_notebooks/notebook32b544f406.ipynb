# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#data_path='../input/holiday-package-purchase-prediction/Travel.csv'
#df=pd.read_csv(data_path)

df = pd.read_csv('../input/holiday-package-purchase-prediction/Travel.csv')
df

# %%
df.info()

# %%
df.isna().sum()

# %%
df['Gender'].replace(to_replace='Fe Male',value='Female')
df['Gender'].value_counts()

# %%
Taken=df[df['ProdTaken']==1]['Gender'].value_counts()
Not_Taken=df[df['ProdTaken']==0]['Gender'].value_counts()
Gendervise=pd.DataFrame([Taken,Not_Taken])
Gendervise.index=['Taken','Not_taken']
Gendervise.plot(kind='bar')

# %%
df['Age']=df['Age'].fillna(value=df['Age'].mean())

# %%
df.isna().sum()

# %%
Taken=df[df['ProdTaken']==1]['Age'].value_counts()
Not_Taken=df[df['ProdTaken']==0]['Age'].value_counts()
Gendervise=pd.DataFrame([Taken,Not_Taken])
Gendervise.index=['Taken','Not_taken']
Gendervise.plot(kind='bar')

# %%
Taken=df[df['ProdTaken']==1]['Age'].value_counts()
#Not_Taken=df[df['ProdTaken']==0]['Age'].value_counts()
Gendervise=pd.DataFrame([Taken])
Gendervise.index=['Taken']
Gendervise.plot(kind='bar')

# %%
Not_Taken=df[df['ProdTaken']==0]['Age'].value_counts()
Gendervise=pd.DataFrame([Not_Taken])
Gendervise.index=['Not_Taken']
Gendervise.plot(kind='bar')

# %%
df['CityTier'].value_counts().sort_values(ascending=False)

# %%
Taken=df[df['ProdTaken']==1]['CityTier'].value_counts()
Not_Taken=df[df['ProdTaken']==0]['CityTier'].value_counts()
Gendervise=pd.DataFrame([Taken,Not_Taken])
Gendervise.index=['Taken','Not_taken']
Gendervise.plot(kind='bar')

# %%
df.hist(figsize=(18,15))  # all graphs together
plt.show()

# %%
City_1=df[df['CityTier']==1]['MonthlyIncome'].mean()
City_2=df[df['CityTier']==2]['MonthlyIncome'].mean()
City_3=df[df['CityTier']==3]['MonthlyIncome'].mean()
Cityvise=pd.DataFrame([[City_1],[City_2],[City_3]])
Cityvise
#Cityvise.index=['City_1','City_2','City_3']
Cityvise.plot(kind='bar')

# %%
Taken_City_1=df[(df['ProdTaken']==1) & (df['CityTier']==1)]['Designation'].value_counts()
Taken_City_2=df[(df['ProdTaken']==1) & (df['CityTier']==2)]['Designation'].value_counts()
Taken_City_3=df[(df['ProdTaken']==1) & (df['CityTier']==3)]['Designation'].value_counts()
NotTaken_City_1=df[(df['ProdTaken']==0) & (df['CityTier']==1)]['Designation'].value_counts()
NotTaken_City_2=df[(df['ProdTaken']==0) & (df['CityTier']==2)]['Designation'].value_counts()
NotTaken_City_3=df[(df['ProdTaken']==0) & (df['CityTier']==3)]['Designation'].value_counts()
Gendervise=pd.DataFrame([Taken_City_1,Taken_City_2,Taken_City_3,NotTaken_City_1,NotTaken_City_2,NotTaken_City_3])
Gendervise.index=['Taken_City_1','Taken_City_2','Taken_City_3','NotTaken_City_1','NotTaken_City_2','NotTaken_City_3']
Gendervise.plot(kind='bar',figsize=(10,5))

# %%
Taken=df[df['ProdTaken']==1]['Occupation'].value_counts()
Not_Taken=df[df['ProdTaken']==0]['Occupation'].value_counts()
Occupationvise=pd.DataFrame([Taken,Not_Taken])
Occupationvise.index=['Taken','Not_taken']
Occupationvise.plot(kind='bar')

# %%
Taken=df[df['ProdTaken']==1]['MaritalStatus'].value_counts()
Not_Taken=df[df['ProdTaken']==0]['MaritalStatus'].value_counts()
MaritalStatusvise=pd.DataFrame([Taken,Not_Taken])
MaritalStatusvise.index=['Taken','Not_taken']
MaritalStatusvise.plot(kind='bar')

# %%
Taken_Passport=df[(df['ProdTaken']==1) & (df['Passport']==1)]['Designation'].value_counts()
Taken_NoPassport=df[(df['ProdTaken']==1) & (df['Passport']==0)]['Designation'].value_counts()
NotTaken_Passport=df[(df['ProdTaken']==0) & (df['Passport']==1)]['Designation'].value_counts()
NotTaken_NoPassport=df[(df['ProdTaken']==0) & (df['Passport']==0)]['Designation'].value_counts()
Passportvise=pd.DataFrame([Taken_Passport,Taken_NoPassport,NotTaken_Passport,NotTaken_NoPassport])
Passportvise.index=['Taken_Passport','Taken_NoPassport','NotTaken_Passport','NotTaken_NoPassport']
Passportvise.plot(kind='bar',stacked=True, figsize=(10,5))

# %%
Taken_Passport=df[(df['ProdTaken']==1) & (df['Passport']==1)]['CityTier'].value_counts()
Taken_NoPassport=df[(df['ProdTaken']==1) & (df['Passport']==0)]['CityTier'].value_counts()
NotTaken_Passport=df[(df['ProdTaken']==0) & (df['Passport']==1)]['CityTier'].value_counts()
NotTaken_NoPassport=df[(df['ProdTaken']==0) & (df['Passport']==0)]['CityTier'].value_counts()
Passportvise=pd.DataFrame([Taken_Passport,Taken_NoPassport,NotTaken_Passport,NotTaken_NoPassport])
Passportvise.index=['Taken_Passport','Taken_NoPassport','NotTaken_Passport','NotTaken_NoPassport']
Passportvise.plot(kind='bar',stacked=True, figsize=(10,5))

# %%
Taken=df[df['ProdTaken']==1]['MonthlyIncome'].value_counts()
Not_Taken=df[df['ProdTaken']==0]['MonthlyIncome'].value_counts()
Incomevise=pd.DataFrame([Taken,Not_Taken])
Incomevise.index=['Taken','Not_taken']
Incomevise.plot(kind='bar')

# %%
df.head(5)

# %%
Y=df.iloc[:,1].values
Y

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df.Occupation=encoder.fit_transform(df.Occupation)
df.Gender=encoder.fit_transform(df.Gender)
df.MaritalStatus=encoder.fit_transform(df.MaritalStatus)
df.Designation=encoder.fit_transform(df.Designation)
df.head(5)

# %%
X=df.drop(['CustomerID','TypeofContact','DurationOfPitch','NumberOfPersonVisiting','NumberOfFollowups','ProductPitched','PreferredPropertyStar','NumberOfTrips','PitchSatisfactionScore','OwnCar','NumberOfChildrenVisiting'],axis=1,inplace=True)

# %%
df.isna().sum()

# %%
df['MonthlyIncome']=df['MonthlyIncome'].fillna(value=df['MonthlyIncome'].mean())

# %%
X=df.drop(['ProdTaken'],axis=1,inplace=True)

# %%
X=df.iloc[:,:].values

# %%
X

# %%
X.shape,Y.shape

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=7)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
model=LogisticRegression()
model.fit(X_train,Y_train)
Y_pred=model.predict(X_test)
Logi_acc=accuracy_score(Y_test,Y_pred)*100
print(Logi_acc)

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=3)
model.fit(X_train,Y_train)
Y_pred=model.predict(X_test)
KNN_acc=accuracy_score(Y_test,Y_pred)*100

# %%
#Naive bayes
from sklearn.naive_bayes import GaussianNB
model= GaussianNB()
model.fit(X_train,Y_train)
Y_pred= model.predict(X_test)
NB_acc=accuracy_score(Y_test,Y_pred)*100

# %%
#SVM
from sklearn.svm import SVC
model=SVC(kernel="linear")  #sometimes kernal= poly or "rbf"
model.fit(X_train,Y_train)
Y_pred= model.predict(X_test)
SVC_acc=accuracy_score(Y_test,Y_pred)*100

# %%
#RandomForest
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(n_estimators=100)
model.fit(X_train,Y_train)
Y_pred= model.predict(X_test)
RandFor_acc=accuracy_score(Y_test,Y_pred)*100

# %%
#decision tree
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(X_train,Y_train)
Y_pred= model.predict(X_test)
DeciTr_acc=accuracy_score(Y_test,Y_pred)*100

# %%
# all models with accuracy score

models=pd.DataFrame({'Models':['Logistic Regression','KNeighbor Classifier','GaussianNB','Supprt Vectro Machine','Random-Forest Classifier','DecisionTreeClassifier'],
                     'Accuracy score':[Logi_acc,KNN_acc,NB_acc,SVC_acc,RandFor_acc,DeciTr_acc]})
models.sort_values(by="Accuracy score",ascending=False)
