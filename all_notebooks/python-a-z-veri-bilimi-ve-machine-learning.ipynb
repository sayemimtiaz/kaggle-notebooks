# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Neden Numpy

# %%
a = [1,2,3,4]
b = [2,3,4,5]

# %%
ab = []
for i in range(0, len(a)):
    ab.append(a[i]*b[i])
ab

# %% [markdown]
# yukarıda matris çarpımı yapılmıştır. Bunun kolayını numpy ile yapabiliriz

# %%
import numpy as np

# %%
a = np.array([1,2,3,4])
b = np.array([2,3,4,5])

# %%
a*b

# %% [markdown]
# # Numpy Array'i Oluşturmak

# %%
np.array([1,2,3,4,5])

# %%
a = np.array([1,2,3,4,5])
type(a)

# %%
np.array([3.14,4,2,13],dtype = int)

# %% [markdown]
# dtype o arraydeki değişken tipini seçmemize yarar

# %% [markdown]
# sıfırlardan array oluşturma

# %%
np.zeros(10, dtype=int)

# %% [markdown]
# birlerden array oluşurma

# %%
np.ones((3,5),dtype = int)

# %% [markdown]
# belli bir sayıdan oluşan array

# %%
np.full((6,5),4)

# %% [markdown]
# doğrusal bir dizi oluşurma örneğin 0 31 arası 3er artan bir dizi

# %%
np.arange(0,31,3)

# %% [markdown]
# iki sayı arasında x tane değer oluşturan array tipi

# %%
np.linspace(0,1,10)

# %% [markdown]
# normal dağılıma uygun ortalama ve standart sapmasına benim karar verdiğim tek ya da çift boyutlu array oluşturma
# (tek boyutlu array vektör, 2 boyutlu matristir

# %%
np.random.normal(10,4,(3,4))#normal-dağılım, 10-ortalama, 4-stdsapma, (3,4)-array boyutu

# %% [markdown]
# Random integer array oluşturma

# %%
np.random.randint(0,10,(3,3))

# %% [markdown]
# # Numpy Array Özellikleri
# * ndim:boyut sayısı
# * shape:boyut bilgisi
# * size: toplam eleman sayısı
# * dtype: array veri tipi

# %%
np.random.randint(10,size=10)
a = np.random.randint(10,size=10)

# %%
a.ndim

# %%
a.shape

# %%
a.size

# %%
a.dtype

# %%
b = np.random.randint(10,size = (3,5))

# %%
b.ndim

# %%
b.shape

# %%
b.size

# %%
b.dtype

# %% [markdown]
# # Reshaping

# %%
np.arange(1,10)

# %%
np.arange(1,10).reshape((3,3))

# %%
a=np.arange(1,10)

# %%
a.ndim

# %%
b= a.reshape((1,9))

# %%
b.ndim

# %% [markdown]
# # Concatenation (Array Birleştirme

# %%
x = np.array([1,2,3])
y = np.array([4,5,6])

# %%
np.concatenate([x,y])

# %%
z = np.array([7,8,9])

# %%
np.concatenate([x,y,z])

# %% [markdown]
# İki boyut

# %%
a = np.array([[1,2,3,],
             [4,5,6]])

# %%
np.concatenate([a,a])#burada axis 0dır

# %%
np.concatenate([a,a],axis=1)

# %% [markdown]
# # Splitting Array Ayırma

# %%
x = np.array([1,2,3,99,99,3,2,1])

# %%
np.split(x,[3,5])

# %%
a,b,c = np.split(x,[3,5])

# %%
b

# %% [markdown]
# İki boyutlu ayırma

# %%
m = np.arange(16).reshape(4,4)
m

# %%
np.vsplit(m,[2])

# %%
ust,alt = np.vsplit(m,[2])

# %%
alt

# %%
m

# %%
np.hsplit(m,[2])

# %%
sag,sol=np.hsplit(m,[2])

# %%
sol

# %% [markdown]
# # Sorting (sıralama)

# %%
v = np.array([2,1,3,5,7,9,8,])

# %%
v

# %%
np.sort(v)#vyi sıraladı ancak kalıcı olarak değil

# %%
v #vyi sıraladı ancak kalıcı olarak değil orijinal yapısı bozulmadı

# %%
v.sort()#vyi olarak kalıcı sıraladı yapısı değişti yani

# %%
v

# %% [markdown]
# İki boyutlu

# %%
m = np.random.normal(20,5,(3,3))

# %%
m

# %%
np.sort(m, axis=1) #satırları küçükten büyüğe sıralama

# %%
np.sort(m, axis=0) #sütunları küçükten büyüğe sıralama

# %% [markdown]
# # Index İle Elemanlara Erişmek

# %%
a = np.random.randint(10, size=10)
a

# %%
a[0]

# %%
a[-1] #tersten 1. eleman

# %%
a[0]=100

# %%
a

# %%
m = np.random.randint(10, size=(3,5))
m

# %%
m[0,0]

# %%
m[1,1]

# %%
m[2,3]

# %%
m[2,3]=33
m

# %% [markdown]
# # Slicing ( Array Alt Kümelerine Erişmek)

# %%
a=np.arange(20,30)
a

# %%
a[0:3]

# %%
a[1::2]#1. indexten sonra 2şerli alarak git

# %% [markdown]
# İki boyutlu slice işlemleri

# %%
m = np.random.randint(10,size= (5,5))
m

# %%
m[:,0] #ilk sütun yani tüm satırlar ve 0. sütunun kesişimi

# %%
m[0,:] #ilk satır yani 0 satır ve tüm sütunların kesişimi

# %% [markdown]
# # Alt Küme Üzerinde İşlem Yapmak
# Al küme üzerindeki işlemlerin tüm arrayi etkilememesi amaç

# %%
a = np.random.randint(10,size = (5,5))
a

# %%
alt_a = a[0:3,0:2]
alt_a

# %%
alt_a[0,0]=99999
alt_a[1,1]=888
alt_a

# %%
a #arrayin kendi de değişti

# %%
m = np.random.randint(10,size = (5,5))
m

# %%
alt_b = m[0:3,0:2].copy() #copy methodu ile alt kümenin kopyasını oluşturduk artık ana array etkilenmeyecek
alt_b

# %% [markdown]
# # Fancy Index ile Elemanlara Erişmek

# %%
v= np.arange(0,30,3)
v

# %%
[v[1],v[3],v[5]]

# %%
al_getir=[1,3,5]

# %%
v[al_getir] #fancy index

# %% [markdown]
# İki boyutta fancy index

# %%
m=np.arange(9).reshape(3,3)
m

# %%
satir = np.array([0,1])
sutun = np.array([1,2])

# %%
m[satir,sutun] #iki boyutta fancy index

# %% [markdown]
# basit index ile fancy index

# %%
m

# %%
m[0,[1,2]] #fancy ile basit index bir arada

# %% [markdown]
# slice ile fancy bir arada

# %%
m[0:,[1,2]]

# %% [markdown]
# # Koşullu Eleman İşlemleri

# %%
v = np.array([1,2,3,4,5])

# %%
v < 3

# %%
v[v<3] #fancyden yardım aldık

# %%
v*3

# %%
v/5

# %% [markdown]
# # Matematiksel İşlemler
# ufunc ile fonksiyon ile çalışıyor

# %%
v = np.array([1,2,3,4,5])
v

# %%
np.subtract(v,1) #her elemandan 1 çıkart

# %%
np.add(v,1) #her elemana 1 ekle

# %%
np.multiply(v,2)#her elemanı 2 ile çarp

# %%
np.divide(v,3)#her elemanı 3e böl

# %%
np.power(v,3) #her elemanın küpünü almak

# %%
np.mod(v,2)#her elemanın ikiye bölümünden kalanı verir

# %%
np.absolute(np.array([-3])) #mutlak değer alma fonksiyonu

# %%
np.sin(360)

# %%
np.cos(180)

# %%
c = np.array([1,2,3])

# %%
np.log(c) #logaritma alma

# %%
np.log2(c) #2. dereceden logaritmasını almak

# %% [markdown]
# numpy mathematics **cheatsheet** (cheatsheet uzantısı tüm fonksiyonları derli topluca verir)

# %% [markdown]
# # Numpy ile İki Bilinmeyenli Denklem Çözümü

# %% [markdown]
# 5*x0+x1=12
# x0+3*x1=10 problemimiz

# %%
import numpy as np

# %%
a = np.array([[5,1],[1,3]])
b = np.array([12,10])

# %%
a

# %%
b

# %%
x = np.linalg.solve(a,b) #lineer cebir çözümü sağlayan özel fonksiyon
x

# %% [markdown]
# # Pandas #

# %% [markdown]
# # Pandas serisi oluşturma

# %%
import pandas as pd
pd.Series([1,2,3,4,5])

# %%
seri = pd.Series([1,2,3,4,5])
type(seri)

# %% [raw]
# seri.axes #serinin içeriği hakkında bilgi verir 5 elemanlı 1 den başyalıp 5e kadar 1er 1er artmış

# %%
seri.dtype #serinin elemanlarının değişken tipini verir

# %%
seri.size #serinin boyutunu verir

# %%
seri.ndim #boyut bilgisi

# %%
seri.values #serinin içindeki değerleri verir bize index numaraları olmakasızın

# %%
seri.head #serinin ilk 5 değeri

# %% [markdown]
# İndex İsimlendirmesi

# %%
pd.Series([99,33,66,44,22,5])

# %%
pd.Series([99,33,66,44,22,5], index = ["a","b","c","d","e","f"]) #ya da sayı da olabilir
#slice işlemleri yani alt küme şekilinde de ayrılabilir seri["a":"c"] şeklinde

# %%
sozluk = pd.Series({"reg":10, "log":11, "cart":12}) #şeklinde yapılabilir 
sozluk

#sozluk = {"reg":10, "log":11, "cart":12}
#seri = pd.Series (sozluk) şeklinde de sözlük oluşuturulabilir bu yöntem daha şık

# %%
pd.concat([seri,seri]) #alt alta birşletirme

# %% [markdown]
# # Eleman İşlemleri

# %%
import numpy as np
a =np.array([1,2,33,444,75])
seri = pd.Series(a)
seri

# %% [markdown]
# # Pandas DataFrame Oluşturma

# %%
l = [1,2,39,67,90]
l

# %%
m= np.arange(1,10).reshape(3,3)
m

# %%
pd.DataFrame(m, columns= ["var1","var2","var3"])

# %% [markdown]
# dataframe (df) isimlendirme

# %%
df = pd.DataFrame(m, columns = ["va1","var2","var3"])
df.head #ilk 3 satırı verir
df.tail #son üç satırı veriri

# %%
df.columns = ("deg1","deg2","deg3") #yeniden atama yapmadan değişken ismi değiştirme
df

# %%
df.axes

# %% [markdown]
# Pandas data frame eleman işlemleri

# %%
s1 = np.random.randint(10, size=5)
s2 = np.random.randint(10, size=5)
s3 = np.random.randint(10, size=5)

# %%
sozluk = {"var1":s1, "var2":s2, "var3":s3}
sozluk

# %%
df = pd.DataFrame(sozluk)
df

# %% [markdown]
# silme

# %%
#df.drop(1, axis=0 # ,inplace = True) #ana data frame değişmez
#diez işaretinden sonrki argümanı yazarsak ana data frame de değişir

# %% [markdown]
# fancy ile silme

# %%
l= [2,4]

# %%
df.drop(l,axis=0)

# %% [markdown]
# değişkenler içim

# %%
"var1" in df #var1 df içinde var mı yok mu kontrol ettik

# %%
l = ["var1","var2","var3"]

# %%
for i in l:
    print(i in df)

# %%
df["var4"] = df["var1"]/df["var2"] #4.bir variable oluşturmak
df

# %% [markdown]
# değişken silmek

# %%
df.drop("var4",axis=1, inplace = True)
df

# %% [markdown]
# # Gözlem ve değişken seçimi: loc&iloc

# %%
m = np.random.randint(1,30, size = (10,3))
df = pd.DataFrame(m,columns = ["var1","var2","var3"])
df

# %% [markdown]
# loc: tanımlandığı şekliyle seçim yapmak için kullanılır

# %%
df.loc[0:3] #0dan 3e dahil olmak üzere seçim yaptı [0,3]

# %% [markdown]
# iloc: alışık olduğumuz indexleme mantığı ile seçim yapar

# %%
df.iloc[0:3] #0dan 3e kadar eçim yaptı [0,3)

# %%
df.iloc[:3,:2]

# %%
df.loc[0:3,"var3"]

# %%
#df.iloc[0:3,"var3"] hata verir

# %% [markdown]
# # Koşullu Eleman İşemleri

# %%
m = np.random.randint(1,30, size = (10,3))
df = pd.DataFrame(m,columns = ["var1","var2","var3"])
df

# %%
df["var1"][0:2]

# %%
df[df.var1>10] #10dan büyük değerleri gözlemlemek

# %%
df[(df.var1>10) & (df.var3<5) ]

# %% [markdown]
# # Birleştirme (Join) İşlemleri

# %%
import pandas as pd

# %%
m = np.random.randint(1,30, size = (5,3))
df1 = pd.DataFrame(m,columns = ["var1","var2","var3"])
df1

# %%
df2 = df1+ 99
df2

# %%
pd.concat([df1,df2],ignore_index=True)

# %%
df1.columns

# %%
df2.columns

# %%
df2.columns = ["var1","var2","deg3"]
df2

# %%
pd.concat([df1,df2]) #deg3 iki veri setinde olmadığından hata verebilir

# %%
pd.concat([df1,df2],join="inner")#hata vermemesi için join="inner" kullanıldı kesişimlerindeki değişkenleri aldı sadece

# %%
#pd.concat([df1,df2], join_axes = [df2.columns],ignore_index=True)#df1deki kolonlardaki bilgilere göre birleştirildi

# %% [markdown]
# # İleri birleştirme işlemleri

# %% [markdown]
# Birebir birleştirme

# %%
df1 = pd.DataFrame({"calisanlar":["ali","veli","ayse","fatma"],
                   "grup" :["muhasebe","muhendislik","muhendislik","ik"]})
df1

# %%
df2 = pd.DataFrame({"calisanlar":["ali","veli","ayse","fatma"],
                   "ilk_giris":[2009,2014,2010,2019]})
df2

# %%
pd.merge(df1,df2)

# %%
pd.merge(df1,df2,on = "calisanlar") #on calisanlar çalışanlar değişkeni üzerinde birleştir demek

# %% [markdown]
# çokta teke

# %%
df3 = pd.merge(df1,df2)
df3

# %%
df4 = pd.DataFrame({"grup":["muhasebe","muhendislik","ik"],
                   "mudur":["caner","mustafa","berkcan"]})
df4

# %%
pd.merge(df3,df4)

# %% [markdown]
# coktan coka

# %%
df5=pd.DataFrame({"grup":["muhasebe","muhasebe","muhendislik","muhendislik","ik","ik"],
                 "yetenekler":["matematik","excel","kodlama","linux","excel","yonetim"]})
df5

# %%
pd.merge(df1,df5)

# %% [markdown]
# # Aggregation and Grouping (toplulaştırma ve gruplama)
# Basit toplulaştırma fonksiyonları:
# * Count()
# * first()
# * last()
# * mean()
# * median()
# * min()
# * max()
# * std()
# * var()
# * sum()

# %%
import seaborn as sns

# %%
# ?sns.load_dataset

# %%
df = sns.load_dataset("planets")
df.head()

# %%
df.shape

# %%
df["mass"].mean()

# %%
df["mass"].count()

# %%
df["mass"].min()

# %%
df["mass"].max()

# %%
df["mass"].sum()

# %%
df["mass"].std()

# %%
df["mass"].var()

# %%
df.describe().T

# %%
df.dropna().describe().T #boş hücreleri görmezden gelerek inceleme

# %% [markdown]
# # Gruplama işlemleri

# %%
df = pd.DataFrame({"gruplar":["A","B","C","A","B","C"],
                  "veri":[10,11,52,23,43,55]},columns=["gruplar","veri"])
df
