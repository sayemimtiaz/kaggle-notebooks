# %% [markdown]
# Angepasst von **[Machine Learning Course Home Page](https://www.kaggle.com/learn/machine-learning)**
#
# ---

# %% [markdown]
# Im Beispiel wurden die Daten von Melbourne benutzt. In dieser Übungs sollen nun die ML-Techniken auf Preise aus Iowa angewandt werden.
#
# Diese Aufgabe benutzt das "notebook" als Programmierumgebung. Dabei werden Phyton-Programme in die Codeabschnitte eingetragen und durch den **Play-Button** bzw. **STRG+ENTER** ausgeführt.
# Erklärvideo für das "notebook" auf Englisch [90-second intro video](https://www.youtube.com/watch?v=4C2qMnaIKL4).
#
# # Übung
#
# Folgenden Code ausführen, damit dein späterer Code auf Richtigkeit geprüft werden kann.

# %%
# Set up code checking
from learntools.core import binder
binder.bind(globals())
from learntools.machine_learning.ex2 import *
print("Setup Complete")

# %% [markdown]
# ## Schritt 1: Daten laden
# Lies die Iowa-Daten in eine Pandas-Tabelle mit Namen `home_data`.

# %%
import pandas as pd

# Path of the file to read
iowa_file_path = '../input/home-data-for-ml-course/train.csv'

# Fill in the ____ below to read the file into a variable home_data
home_data = ____

# Call line below with no argument to check that you've loaded the data correctly
step_1.check()

# %%
# Lines below will give you a hint or solution code
#step_1.hint()
#step_1.solution()

# %% [markdown]
# ## Schritt 2: Daten betrachten
# Benutzt Python um die Statistik der Daten anzuzeigen und die folgenden Variablen mit den richtigen Antworten zu verknüpfen.

# %%
# ____ muss ersetzt werden
# Print summary statistics in next line
____

# %%
# What is the average lot size (rounded to nearest integer)?
avg_lot_size = ____

# As of today, how old is the newest home (current year - the date in which it was built)
newest_home_age = ____

# Checks your answers
step_2.check()

# %%
#step_2.hint()
#step_2.solution()

# %% [markdown]
# ## Daten betrachten
#
# Das neuste Haus in der Datenbank ist nicht besonders neu. Gib zwei mögliche Erklärungen an (==> **AB**)
#
# Überlege inwieweit deine Erklärungen das Vertrauen in ein mögliches Modell, basierend auf diesen Daten, beeinflußt!
#
# Gibt es eine Möglichkeit die Erklärungen mit Hilfe des Daten zu untermauern?
#
#
# # Fortsetzung
#
# Bereit für das **[erstes ML-Modell](https://www.kaggle.com/infvogel/4-erstes-ml-modell).**

# %% [markdown]
# ---
# **[Machine Learning Course Home Page](https://www.kaggle.com/learn/machine-learning)**
