# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

# Any results you write to the current directory are saved as output.

# %%
imdb_df = pd.read_csv('../input/movie_metadata.csv')

# %%
pd.set_option('display.max_columns', None)
imdb_df.head()

# %% [markdown]
# Since the order of the columns is very weird, let's reorder that first:

# %%
cols = list(imdb_df.columns.values)
cols

# %%
df = imdb_df[['movie_title','title_year','duration','genres','imdb_score','num_voted_users',
              'movie_facebook_likes','director_name','director_facebook_likes','actor_1_name',
              'actor_1_facebook_likes','actor_2_name','actor_2_facebook_likes',
              'actor_3_name','actor_3_facebook_likes','cast_total_facebook_likes',
              'num_critic_for_reviews','num_user_for_reviews','gross','budget',
              'language','country','content_rating','aspect_ratio','plot_keywords',
              'color','facenumber_in_poster','movie_imdb_link']]

# %%
df.head()

# %% [markdown]
# All right, so how reliable is this data? Pirates of the caribbean has Johnny Depp and Orlando Bloom as actor 1 and 2. They've got 40,000 and 5,000 facebook likes respectively. However, this means that the imdb-pages of these actors have got these amounts of likes. The facebook-pages of Johnny Depp has got about 700.000 llikes, where Orlando Bloom's page exceeds 1 million.

# %%
df.tail()

# %% [markdown]
# At first we want to get an overview of our dataframe. We'll describe what the data looks like and we'll try to find related columns:
#
# Columns of which I'm uncertain about their meaning:
# - **Color**: is the movie in color or black/white?
# - **num_critic_for_reviews**: probably has something to do with 'professional' reviews.
# - **num_user_for_reviews**: amount of user reviews?
# - **aspect_ratio**: the ratio in the screen?
# **num_voted_users**: the amount of imdb users that rated the movie?
#
# ------------
# The name of the director is mentioned, together with the amount of facebook likes the director has. This also holds for the three main actors in the movie. Also the amount of facebook likes the cast has is mentioned.
#
# The duration of the movie is mentioned and so are the genre and the language. It might be important to find out whether the country refers to which country 'owns' the movie, or in which country it has been shot, my guess is the former.
#
# Every movie of course has a budget and a revenue (gross). When analyzing these variables, take note of note 6 and 7 in the description. Currency and inflation haven't been taken into account.
#
# Every movie has a year of release, an imdb score and a number of facebook-likes for the movie.
#
# Also the amount of faces on the poster is mentioned, there are plot keywords and a link to the imdb page of the movie is provided.
#
# ---------
#
# Let's divide these variables in categorical and numerical features:
#
# - **Categorical:** Color, Genres (because every movie contains multiple genres, this gives us MANY categories),
# language and country. Aspect_ratio and content_rating can also be seen as categorical variables.
# - Note that Aspect_ratio and content_rating are a mix of numeric and alphanumeric data types
# - **Continuous**:

# %% [markdown]
# Let's get more information about the dataframe by checking which columns contain null-values:

# %%
df.loc[:, imdb_df.isnull().any()].head()

# %% [markdown]
# **So there are 21 out of 28 columns with null-values.**

# %%
(df.info())

# %% [markdown]
# So most of the variables which contain null values, only contain a few. Out of 28 columns and 5043 entries, only 9 variables contain less than 5000 non-null entries. (So more than 43 null-entries).
#
# ----------------
#
# Let's check some basic facts about our dataframe:

# %%
df.describe().round()

# %% [markdown]
# - I still don't quite get the 'num_critic_for_reviews' variable, so I won't draw conclusions for this one.
# - The average duration of a movie in the data frame is 107 minutes, while the shortest and longest movie are 7 and 511 minutes respectively.
# - Actor 1 has an average of 6560 facebook likes, with a maximum of 640,000 likes. The average of actor 2 is 1652, with a maximum of 137,000. Actor 3 gets even less with an average of 645 and a maximum of 23,000. With an average of 687 and also a maximum of 23,000, the director is more popular than actor 3 (Since the percentiles are way better distributed for actor 3, this is not entirely true).
# - If we compare the gross column to the list of highest-grossing movies (https://en.wikipedia.org/wiki/List_of_highest-grossing_films), our intuition tells us this variable isn't entirely reliable.
# - On average, there are 83,668 users who rate a movie on imdb (if I'm interpreting 'num_voted_users' correctly). With a maximum of 1,689,764
#
# **Insert more conclusions gotten directly out of the table above**

# %%
df.describe(include=['O'])

# %%
df.sort_values('actor_1_facebook_likes', ascending=False).head(10)
#df.sort_values('imdb_score', ascending=False).head(10)
#df.sort_values('movie_facebook_likes', ascending=False).head(10)
#df.sort_values('cast_total_facebook_likes', ascending=False).head(10)
#df.sort_values('actor_1_facebook_likes', ascending=False).head(10).actor_1_name.unique()
