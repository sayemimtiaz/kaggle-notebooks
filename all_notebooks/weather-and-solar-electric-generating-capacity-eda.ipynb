# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
data0=pd.read_csv('../input/weather-in-kobe/kobe_weather_2020.csv')
data0

# %%
fig=make_subplots(specs=[[{"secondary_y":False}]])
fig.add_trace(go.Scatter(x=data0['Date'],y=data0['Temparature'],name='Temparature'),secondary_y=False,)
fig.update_layout(autosize=False,width=700,height=500,title_text="Temparature in Kobe")
fig.update_xaxes(title_text="Date")
fig.update_yaxes(title_text="°C",secondary_y=False)
fig.show()

# %%
fig=make_subplots(specs=[[{"secondary_y":False}]])
fig.add_trace(go.Scatter(x=data0['Date'],y=data0['Humidity'],name='Humidity'),secondary_y=False,)
fig.update_layout(autosize=False,width=700,height=500,title_text="Humidity in Kobe")
fig.update_xaxes(title_text="Date")
fig.update_yaxes(title_text="%",secondary_y=False)
fig.show()

# %%
fig=make_subplots(specs=[[{"secondary_y":False}]])
fig.add_trace(go.Scatter(x=data0['Date'],y=data0['Daylight Hours'],name='Daylight Hours'),secondary_y=False,)
fig.update_layout(autosize=False,width=700,height=500,title_text="Daylight Hours in Kobe")
fig.update_xaxes(title_text="Date")
fig.update_yaxes(title_text="hours",secondary_y=False)
fig.show()

# %%
fig=make_subplots(specs=[[{"secondary_y":False}]])
fig.add_trace(go.Scatter(x=data0['Date'],y=data0['Precipitation'],name='Precipitation'),secondary_y=False,)
fig.update_layout(autosize=False,width=700,height=500,title_text="Precipitation in Kobe")
fig.update_xaxes(title_text="Date")
fig.update_yaxes(title_text="mm",secondary_y=False)
fig.show()

# %%
fig=make_subplots(specs=[[{"secondary_y":False}]])
fig.add_trace(go.Scatter(x=data0['Date'],y=data0['Wind Speed'],name='Wind Speed'),secondary_y=False,)
fig.update_layout(autosize=False,width=700,height=500,title_text="Wind Speed in Kobe")
fig.update_xaxes(title_text="Date")
fig.update_yaxes(title_text="m/sec",secondary_y=False)
fig.show()

# %%
solar0=pd.read_csv('../input/solar-power-example/kobe_solar_2020.csv')
solar0

# %%
fig=make_subplots(specs=[[{"secondary_y":False}]])
fig.add_trace(go.Scatter(x=solar0['Date'],y=solar0['Electric Generating Capacity'],name='Electric Generating Capacity'),secondary_y=False,)
fig.update_layout(autosize=False,width=700,height=500,title_text="Electric Generating Capacity in Kobe")
fig.update_xaxes(title_text="Date")
fig.update_yaxes(title_text="kWh",secondary_y=False)
fig.show()

# %%
fig,ax = plt.subplots(figsize=(6,6))
ax.set_title('Solar Electric Generating Capacity vs Daylight Hours',fontsize=20)
ax.set_xlabel('Daylight Hours',fontsize=12)
ax.set_ylabel('Electric Generating Capacity',fontsize=12)
ax.scatter(data0['Daylight Hours'],solar0['Electric Generating Capacity'])
