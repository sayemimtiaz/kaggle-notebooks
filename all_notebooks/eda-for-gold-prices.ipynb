# %% [markdown]
# ![gold ](data:image/jpeg;base64,...)

# %% [markdown]
# **Introduction:**
#
#
# **As we all know that gold prices are on an upward trend every day and the change is always interesting, we all see them change every day, without exaggeration, they change from time to time and they always get used to rising because we see the importance of gold and its rotation in that life and always appreciate and appreciate gold in all Its aspects are used in many things such as decoration and important industry. We have seen recently that it is used in food as we have seen in the most famous restaurants, and it is often used for women's decoration and is used in many fields such as medicine and other things, so its prices always rise.**

# %% [markdown]
# **Import some of Libraries**

# %%
import numpy as np 
import pandas as pd 
import os 
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline
import matplotlib.pyplot as mpl
import plotly.express as px
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
df=pd.read_csv('../input/gold-prices/annual_csv.csv')
dfg=pd.read_csv('../input/gold-prices/monthly_csv.csv')

# %%
df.head()

# %% [markdown]
# # Showing the shape of data

# %%
df.shape

# %% [markdown]
# # Showing some inhformation about data

# %%
df.info()

# %%
dfg.head()

# %%
df.isnull()

# %%
df.describe().count()

# %% [markdown]
# **Ploting the data to Showing some of details**

# %% [markdown]
# # Showing ploting for annual data

# %%
df['Price'].plot(kind='hist')
plt.title('Histogram for Date Price for gold')

# %%
df.plot(kind='area')
plt.title('Price of gold')

# %%
df.plot(kind='bar')
plt.title('Price of Gold')

# %%
df['Price'].plot(kind='pie')
plt.title('Price of Gold ')

# %%
fig = px.line(df, x='Date', y="Price")
fig.show()

# %%
plot_acf(df['Price'])
plot_pacf(df['Price'])

# %% [markdown]
# # For Data Montthly

# %%
dfg.plot(kind='area')
plt.title('Price of gold')

# %%
dfg['Price'].plot(kind='hist')
plt.title('Histogram for Date Price for gold')

# %%
plot_acf(dfg['Price'])
plot_pacf(dfg['Price'])

# %%
fig = px.line(dfg, x='Date', y="Price")
fig.show()

# %%
fig = px.line(dfg)
fig.show()
