# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as mons

# %%
data=pd.read_csv("../input/alcohol-consumption/gapminder_alcohol.csv")

# %%
data.head()

# %%
data.info()

# %%
data.describe()

# %%
mons.bar(data)

# %%
plt.figure(figsize=(35,12))
sns.barplot(data=data,x='country', y='alcconsumption')
plt.xticks(rotation=90)
plt.show()

# %%
top20=data.sort_values("alcconsumption",ascending=False).head(20)

# %%
plt.figure(figsize=(25,12))
sns.barplot(data=top20,x='country', y='alcconsumption')
plt.xticks(rotation=90)
plt.show()

# %%
fig, ax1 = plt.subplots(1,1,figsize=(16,7), dpi= 80)
ax1.plot(top20['country'],top20['suicideper100th'],color='tab:red')
ax1.set_xlabel('Country', fontsize=20)
ax1.set_ylabel('Suicideper 100th', color='tab:red', fontsize=20)
ax1.tick_params(axis='x', rotation=90 )
ax2 = ax1.twinx()
ax2.plot(top20['country'],top20['incomeperperson'],color='tab:green')
ax2.set_xlabel('Country', fontsize=20)
ax2.set_ylabel('Income perperson', color='tab:green', fontsize=20)
ax2.tick_params(axis='x', rotation=90 )

plt.show()

# %%
fig, ax1 = plt.subplots(1,1,figsize=(16,7), dpi= 80)
ax1.plot(top20['country'],top20['employrate'],color='tab:blue')
ax1.set_xlabel('Country', fontsize=20)
ax1.set_ylabel('Employ Rate', color='tab:blue', fontsize=20)
ax1.tick_params(axis='x', rotation=90 )
ax2 = ax1.twinx()
ax2.plot(top20['country'],top20['urbanrate'],color='tab:red')
ax2.set_xlabel('Country', fontsize=20)
ax2.set_ylabel('Urban rate', fontsize=20,color='tab:red')
ax2.tick_params(axis='x', rotation=90 )

plt.show()

# %%
less20=data.sort_values("alcconsumption",ascending=True).head(20)

# %%
fig, ax1 = plt.subplots(1,1,figsize=(16,7), dpi= 80)
ax1.plot(less20['country'],less20['suicideper100th'],color='tab:red')
ax1.set_xlabel('Country', fontsize=20)
ax1.set_ylabel('Suicideper 100th', color='tab:red', fontsize=20)
ax1.tick_params(axis='x', rotation=90 )
ax2 = ax1.twinx()
ax2.plot(less20['country'],less20['incomeperperson'],color='tab:green')
ax2.set_xlabel('Country', fontsize=20)
ax2.set_ylabel('Income perperson', color='tab:green', fontsize=20)
ax2.tick_params(axis='x', rotation=90 )

plt.show()

# %%
fig, ax1 = plt.subplots(1,1,figsize=(16,7), dpi= 80)
ax1.plot(less20['country'],less20['employrate'],color='tab:blue')
ax1.set_xlabel('Country', fontsize=20)
ax1.set_ylabel('Employ Rate', color='tab:blue', fontsize=20)
ax1.tick_params(axis='x', rotation=90 )
ax2 = ax1.twinx()
ax2.plot(less20['country'],less20['urbanrate'],color='tab:red')
ax2.set_xlabel('Country', fontsize=20)
ax2.set_ylabel('Urban rate', fontsize=20,color='tab:red')
ax2.tick_params(axis='x', rotation=90 )

plt.show()

# %%
plt.figure(figsize=(25,12))
sns.barplot(data=less20,x='country', y='alcconsumption')
plt.xticks(rotation=90)
plt.show()
