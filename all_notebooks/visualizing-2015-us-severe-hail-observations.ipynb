# %% [markdown]
# Hello,
#
# I have recently began examining 2015 US hail observations provided by the Department of Commerce. While this initial workstream includes observations from one single year, a thorough analysis would require an inclusion of this data set alongside hail observations from other years. A trend analysis of this data significant in that it may be able to discern changing patterns given continued global warming and gradual shifts in climate. I am currently working to ingest this data into Tableau, in attempt to answer the following questions:
#
# 1) Where is severe hail most frequent? With other data sets, do we see a shift in where severe hail is most frequent?
#
# 2) When (in terms of time of year and time of day) is severe hail most frequent? Are some locations prone to experiencing severe hail during certain time frames, while other locations may experience severe hail at a different time? With other data sets, do we see a shift in when severe hail is most frequent?
#
# To answer these questions, it is my intention to create a Tableau dashboard that can be filtered based on state, month, and hour of day. Below I have provided my initial Python script for organizing the data.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

# Any results you write to the current directory are saved as output.
