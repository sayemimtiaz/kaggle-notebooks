# %%
import numpy as np
import pandas as pd
import missingno as mosn
import matplotlib.pyplot as plt
import seaborn as sns
import os
import datetime

# %%
data=pd.read_csv("../input/top-crypto-historical-prices/Binance Coin Historical Data - Investing.com India.csv")

# %%
data.head()

# %%
mosn.bar(data)

# %%
data.info()

# %%
data.describe()

# %%
data.head()

# %%
plt.figure(figsize=(35,10))
data.groupby('Date')
sns.lineplot(x='Open', y= 'Price', data=data)

# %%
# Create figure and plot space
fig, ax = plt.subplots(figsize=(10, 10))

# Add x-axis and y-axis
ax.bar(data.index.values,
        data['Price'],
        color='purple')

# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Price",
       title="Price with Date in 4 years ")

# Rotate tick marks on x-axis
plt.setp(ax.get_xticklabels(), rotation=45)

plt.show()

# %%
data.groupby('Date').count()

# %%
plt.figure(figsize=(35,10))
sns.lineplot(x='Open', y= 'High', data=data)

# %%
plt.figure(figsize=(35,10))
sns.lineplot(x='Open', y= 'Low', data=data)
