# %% [markdown]
# Import pandas library.

# %%
import pandas as pd

# %% [markdown]
# Show data.

# %%
pd.read_csv("../input/archive.csv")

# %% [markdown]
# Summarize and show data.

# %%
data = pd.read_csv("../input/archive.csv")
data.describe()
