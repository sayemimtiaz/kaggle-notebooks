# %%
import numba as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import datetime as dt
import os
from mpl_toolkits.mplot3d import Axes3D

# %%
data1=pd.read_csv('/kaggle/input/heart-attack-analysis-prediction-dataset/o2Saturation.csv')
data2=pd.read_csv('/kaggle/input/heart-attack-analysis-prediction-dataset/heart.csv')

# %%
data1.head()

# %%
msno.bar(data2)

# %% [markdown]
# No Missing Value

# %%
data2.head()

# %%
data2.info()

# %%
sns.countplot(x=data2['output'])

# %%
sns.countplot(x=data2['thall'])

# %%
sns.countplot(x=data2['caa'])

# %%
plt.figure(figsize=(40,7))
sns.countplot(x=data2['oldpeak'])

# %%
sns.countplot(x=data2['exng'])

# %%
plt.figure(figsize=(40,7))
sns.countplot(x=data2['thalachh'])

# %%
sns.countplot(x=data2['restecg'])

# %%
sns.countplot(x=data2['sex'])

# %%
plt.figure(figsize=(40,7))
sns.countplot(x=data2['age'])

# %%
data2.head()

# %%
data2.groupby('age').sum().plot.line()
