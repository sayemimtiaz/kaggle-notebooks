# %% [markdown]
# #Halite AI Challenge
#
# Halite is an artificial intelligence challenge, created by Two Sigma. Participants write bots using the programming language of their choice to compete in an original online multiplayer game.
#
# Since 2016, more than 15,000 people around the world have participated in a Halite challenge, applying advanced algorithms in a dynamic, open source game setting. The strategic depth and immersive, interactive nature of Halite games make each challenge a unique learning environment.https://halite.io/

# %% [markdown]
# #May the Best Bot Win
#
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQEyfUaCNRat7cldX9Jnz7Ql6cTPtHsf4oDtA&usqp=CAU)2016.halite.io

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline
import plotly.express as px
import plotly.graph_objects as go
import plotly.offline as py
import plotly.express as px

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('../input/halite-v31-historical-leaderboard/bq-results-20201003-183459-8lx3tt7l1h69.csv', encoding='ISO-8859-2')
df.head()

# %% [markdown]
# ![](https://stakernotes.files.wordpress.com/2019/01/halite3-architecture-2.png?w=900)stakernotes.com
# https://stakernotes.com/diamond-ranked-ml-for-halite3/

# %%
df.isnull().sum()

# %%
corr = df.corr()
corr.style.background_gradient(cmap = 'coolwarm')

# %% [markdown]
# #A cool minimalist correlation.

# %%
import matplotlib.gridspec as gridspec
from scipy.stats import skew
from sklearn.preprocessing import RobustScaler,MinMaxScaler
from scipy import stats
import matplotlib.style as style
style.use('seaborn-colorblind')

# %% [markdown]
# #Skewness and Kurtosis

# %%
def plotting_3_chart(df, feature): 
    ## Creating a customized chart. and giving in figsize and everything. 
    fig = plt.figure(constrained_layout=True, figsize=(10,6))
    ## crea,ting a grid of 3 cols and 3 rows. 
    grid = gridspec.GridSpec(ncols=3, nrows=3, figure=fig)
    #gs = fig3.add_gridspec(3, 3)

    ## Customizing the histogram grid. 
    ax1 = fig.add_subplot(grid[0, :2])
    ## Set the title. 
    ax1.set_title('Histogram')
    ## plot the histogram. 
    sns.distplot(df.loc[:,feature], norm_hist=True, ax = ax1)

    # customizing the QQ_plot. 
    ax2 = fig.add_subplot(grid[1, :2])
    ## Set the title. 
    ax2.set_title('QQ_plot')
    ## Plotting the QQ_Plot. 
    stats.probplot(df.loc[:,feature], plot = ax2)

    ## Customizing the Box Plot. 
    ax3 = fig.add_subplot(grid[:, 2])
    ## Set title. 
    ax3.set_title('Box Plot')
    ## Plotting the box plot. 
    sns.boxplot(df.loc[:,feature], orient='v', ax = ax3 );
 

print('Skewness: '+ str(df['rank'].skew())) 
print("Kurtosis: " + str(df['rank'].kurt()))
plotting_3_chart(df, 'rank')

# %%
#Code from Gabriel Preda
#plt.style.use('dark_background')
def plot_count(feature, title, df, size=1):
    f, ax = plt.subplots(1,1, figsize=(4*size,4))
    total = float(len(df))
    g = sns.countplot(df[feature], order = df[feature].value_counts().index[:20], palette='Set2')
    g.set_title("Number and percentage of {}".format(title))
    if(size > 2):
        plt.xticks(rotation=90, size=8)
    for p in ax.patches:
        height = p.get_height()
        ax.text(p.get_x()+p.get_width()/2.,
                height + 3,
                '{:1.2f}%'.format(100*height/total),
                ha="center") 
    plt.show()

# %%
plot_count("team_name", "Team Name", df,4)

# %%
ax = df.groupby('rank')['team_id', 'score'].sum().plot(kind='bar', rot=45, figsize=(12,6), logy=True,
                                                                 title='Halite LB')
plt.xlabel('Rank')
plt.ylabel('Count Log')

plt.show()

# %% [markdown]
# #Messy chart

# %%
#Code by Crislânio Macedo, a.k.a. Caesar Lupum 

def plot_dist_col(column):
    pos__df = df[df['rank'] ==1]
    neg__df = df[df['rank'] ==0]

    '''plot dist curves for train and test weather data for the given column name'''
    fig, ax = plt.subplots(figsize=(8, 8))
    sns.distplot(pos__df[column].dropna(), color='green', ax=ax).set_title(column, fontsize=16)
    sns.distplot(neg__df[column].dropna(), color='purple', ax=ax).set_title(column, fontsize=16)
    plt.xlabel(column, fontsize=15)
    plt.legend(['rank', 'score'])
    plt.show()
plot_dist_col('score')

# %%
#Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

color = plt.cm.summer(np.linspace(0,1,20))
df["team_name"].value_counts().sort_values(ascending=False).head(30).plot.pie(y="rank",colors=color,autopct="%0.1f%%")
plt.title("Halite LB")
plt.axis("off")
plt.show()

# %% [markdown]
# #More than 30 would be messy.

# %%
##Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

from wordcloud import WordCloud
from wordcloud import STOPWORDS
stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color = 'yellow',
                      height =2000,
                      width = 2000,
                      colormap='ocean',
                     ).generate(str(df["team_name"]))
plt.rcParams['figure.figsize'] = (12,12)
plt.axis("off")
plt.imshow(wordcloud)
plt.title("")
plt.show()

# %% [markdown]
# #I hope any user can share another Kaggle Notebook. Congrats for ALL in Halite Competition!

# %%
#Code by Olga Belitskaya https://www.kaggle.com/olgabelitskaya/sequential-data/comments
from IPython.display import display,HTML
c1,c2,f1,f2,fs1,fs2=\
'#2B3A67','#42a7f5','Akronim','Smokum',30,15
def dhtml(string,fontcolor=c1,font=f1,fontsize=fs1):
    display(HTML("""<style>
    @import 'https://fonts.googleapis.com/css?family="""\
    +font+"""&effect=3d-float';</style>
    <h1 class='font-effect-3d-float' style='font-family:"""+\
    font+"""; color:"""+fontcolor+"""; font-size:"""+\
    str(fontsize)+"""px;'>%s</h1>"""%string))
    
    
dhtml('Kaggle Notebook Runner: Marília Prata, not a DS. Stick around, I will be right back. @mpwolke' )
