# %% [markdown]
# # Greetings!! This notebook is to do EDA and to solve questions on Covid-19 dataset

# %% [markdown]
# ![](https://padmajahospital.in/wp-content/uploads/2020/03/giphy.gif)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_rows',None)
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv("../input/covid19-dataset/Covid_19 Data.csv")

# %%
df.head()

# %%
df.shape

# %%
df.index

# %%
df.columns

# %%
df.isnull().sum()

# %%
df[df.duplicated()]

# %% [markdown]
# No duplicated records

# %%
df["State"].unique()

# %%
df["Region"].unique()

# %%
df.size

# %%
df.info()

# %%
df.describe(include = 'all')

# %% [markdown]
# # Questions on the dataset:-

# %% [markdown]
# # 1.Find all the null value in the dataset.If there is any value in any column then fill it with the mean of that column?

# %%
df.head(2)

# %%
df.groupby("Region")["Confirmed","Deaths","Recovered"].sum()

# %% [markdown]
# # 2.Remove all the records where "Confirmed" cases is less than 10?******

# %%
df.head(2)

# %%
df.shape

# %%
df = df[~(df["Confirmed"]<10)]

# %%
df.shape

# %% [markdown]
# # 3.In which region,Maximum number of "Confirmed" cases were recorded?

# %%
df.head(2)

# %%
df.groupby("Region").Confirmed.sum().sort_values(ascending = False).head(10)

# %%
df.groupby("Region").Confirmed.sum().max()

# %% [markdown]
# # 4.In which region,Maximum number of "Death" cases were recorded?

# %%
df.groupby("Region").Deaths.sum().sort_values(ascending = False)

# %%
df.groupby("Region").Deaths.sum().max()

# %% [markdown]
# # 5.How many "Confirmed","Death","Recovered" Cases were reported from india till 24 april 2020?

# %%
df.Date.unique()

# %%
df.head(2)

# %%
df[(df["Region"]=="India")]

# %% [markdown]
# # 6.a)Sort the entire data wrt no. of "Confirmed" cases in ascending order?

# %%
df.sort_values(by =["Confirmed"],ascending =True )

# %% [markdown]
# # b)Sort the entire data wrt no. of "Recovered" cases in descending order?

# %%
df.sort_values(by =["Recovered"],ascending =True )

# %% [markdown]
# # Dnt forget to voteup and try to check other projects also..I would be very glad if you leave a comment as feedback..

# %% [markdown]
# ![](https://i.gifer.com/1B4T.gif)
