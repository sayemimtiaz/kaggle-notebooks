# %% [markdown]
# ![](https://ciam.gov.ao/administracao/lib/uploads/publicidade/1584963228_Covid19.jpeg)ciam.gov.ao

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df=pd.read_csv("/kaggle/input/covid19-in-angola/summary.csv")
pd.set_option('display.max_columns', None)
df.tail()

# %%
# !pip install dataprep

# %%
from dataprep.eda import plot, plot_correlation, create_report, plot_missing

# %%
plot_missing(df)

# %%
plot(df)

# %% [markdown]
# #Understand a column with plot(df, x)
#
# #Categorical column, computes statistics, bar chart, pie chart, WordCloud, word frequency
#
# #and word length

# %%
plot(df, "Data")

# %% [markdown]
# #Numerical column, it computes column statistics, and generates a histogram, kde plot, box plot and qq-normal plot

# %%
plot(df, "Total de Casos")

# %%
plot(df, "Total de Óbitos")

# %%
plot(df, "Total de Recuperados")

# %% [markdown]
# #Understand the relationship between two columns with plot(df, x, y)
#
# #When x and y are both numerical columns, it generates a scatter plot, hexbin and box plot.

# %%
plot(df, "Total de Casos","Total de Recuperados")

# %% [markdown]
# #When x and y are both categorical columns, it plots nested bar chart, stacked bar and heat
#
# #map. Since this Dataset has only one categorical column. No examples, for now.

# %% [markdown]
# #If somebody is interested in one or two specific columns, it provides a more detailed plot
#
# #for the specific columns by passing column names as the parameter.

# %%
plot(df, "Novos Óbitos", bins=20)

# %%
#Plot correlation: analyze correlations

plot_correlation(df)

# %%
#Top ‘k’ attributes’ correlation heatmap (here, k=1)

plot_correlation(df, k=1)

# %%
#Correlation of specified element with all other attributes.

plot_correlation(df, "Total de Casos")

# %%
#Correlation between two attributes with line of best fit and most influential points.

plot_correlation(df, x="Total de Casos", y="Total de Óbitos", k=5)

# %%
from dataprep.eda import create_report

df = pd.read_csv("/kaggle/input/covid19-in-angola/summary.csv")
create_report(df)

# %% [markdown]
# DATAPREP: The easiest way to prepare data in Python
#
# DataPrep is free, open-source software released under the MIT license. Anyone can reuse DataPrep code for any purpose.
#
# DataPrep is built using Pandas/Dask DataFrame and can be seamlessly integrated with other Python libraries.
#
# DataPrep is designed for computational notebooks, the most popular environment among data scientists.
#
# Dataprep is an initiative by SFU Data Science Research Group to speed up Data Science.
#
# Acknowlegdements
#
# SFU Data Science Research Group - Simon Fraser University
#
# https://sfu-db.github.io/dataprep/user_guide/eda/plot.html
#
# https://dataprep.ai/
#
# https://towardsdatascience.com/dataprep-eda-accelerate-your-eda-eb845a4088bc

# %%
#Code by Olga Belitskaya https://www.kaggle.com/olgabelitskaya/sequential-data/comments
from IPython.display import display,HTML
c1,c2,f1,f2,fs1,fs2=\
'#2B3A67','#42a7f5','Akronim','Smokum',30,15
def dhtml(string,fontcolor=c1,font=f1,fontsize=fs1):
    display(HTML("""<style>
    @import 'https://fonts.googleapis.com/css?family="""\
    +font+"""&effect=3d-float';</style>
    <h1 class='font-effect-3d-float' style='font-family:"""+\
    font+"""; color:"""+fontcolor+"""; font-size:"""+\
    str(fontsize)+"""px;'>%s</h1>"""%string))
    
    
dhtml('Be patient. Marília Prata, @mpwolke was Here.' )
