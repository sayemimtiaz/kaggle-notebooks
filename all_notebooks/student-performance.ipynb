# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv('../input/studentsperformance/StudentsPerformance.csv')

# %%
df.head()

# %%
df.shape

# %%
df.info()

# %%
df.describe()

# %%
df[df['math score']==100]['gender']

# %%
df[(df['math score']==100) & (df['reading score']==100) & (df['writing score']==100)]

# %%
df['parental level of education'].unique()

# %%
df[df['parental level of education']=='high school'].describe()

# %%
df[(df['parental level of education']=='high school') & (df['gender']=='male') & (df['race/ethnicity']=='group A')]['writing score'].idxmax()

# %%
df.iloc[170]['test preparation course']

# %%
df[(df['parental level of education']=="master's degree") & (df['reading score']>=74) & (df['writing score']<=75)]['lunch']

# %%
a=list([df[(df['parental level of education']=="master's degree") & (df['reading score']>=74) & (df['writing score']<=75)]['math score']])

# %%
i=0
for x in a:
    i=i+1
    
print((x//3))

# %%
def f(x):
    if(x%3)==0:
        return True
    else:
        return False

# %%
sum(df['math score'].apply(lambda x:f(x)))

# %%
df['parental level of education']

# %%
df['parental level of education'].iloc[0]

# %%
x=df['parental level of education'].iloc[0]

# %%
x.split("'s")[1]

# %%
df.head()

# %%
sb.distplot(df['writing score'],bins='auto',hist_kws=dict(edgecolor='lime',linewidth=4))
plt.show()

# %%
sb.kdeplot(df['reading score'])
plt.show()

# %%
sb.scatterplot(data=df,x='reading score',y='math score',hue='gender',style_order='parental level of education',alpha=0.2,s=150)
              
plt.show()

# %%
sb.jointplot(data=df,x='reading score',y='writing score',kind='kde')
plt.show()

# %%
sb.pairplot(df,hue='test preparation course',corner=True)
plt.show()

# %%
sb.barplot(data=df,x='race/ethnicity',y='math score')
plt.show()

# %%
sb.countplot(data=df,x='lunch')
plt.show()

# %%
sb.boxplot(data=df,x='race/ethnicity',y='reading score',hue='gender')
plt.show()

# %%
sb.violinplot(data=df,x='race/ethnicity',y='reading score',hue='gender')
plt.show()

# %%
sb.stripplot(data=df,x='race/ethnicity',y='writing score')
plt.show()

# %%
sb.stripplot(data=df,x='parental level of education',y='writing score')
plt.show()

# %%
df2=df.pivot_table(index='parental level of education',columns='race/ethnicity',values='math score')

# %%
sb.heatmap(df2,cmap='spring')
plt.show()

# %%
sb.clustermap(df2)
plt.show()
