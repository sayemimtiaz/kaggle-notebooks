# %%
import numpy as np
import pandas as pd

data = pd.read_csv("/kaggle/input/pakistan-cities-dialcalling-code-source-ptcl/Pakistan Cities Calling Code.csv")

# %%
data.describe()

# %% [markdown]
# **city**: Name of the city </br></br>
# **area_code**: The dial code

# %%
data.head()
