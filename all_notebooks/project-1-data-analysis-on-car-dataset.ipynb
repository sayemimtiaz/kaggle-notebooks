# %% [markdown]
# # Greetings!! This notebook is to do EDA and to solve questions on car dataset

# %% [markdown]
# ![](https://media3.giphy.com/media/QsaPruMLFHUt5AJM5M/giphy.gif)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_rows',None)
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv("../input/car-dataset/Cars Data.csv")
df.head(5)

# %%
df.tail()

# %%
df.dtypes

# %%
df.shape

# %%
df.info()

# %%
df.columns

# %%
df.index

# %%
df.style.hide_index()

# %%
df.Make.unique()

# %%
df.Type.unique()

# %%
df.Origin.unique()

# %%
df.DriveTrain.unique()

# %%
df.drop(columns = ['Unnamed: 15','Unnamed: 16'],inplace =True)

# %%
df.head(2)

# %%
#Check the duplicates
df[df.duplicated()]

# %% [markdown]
# # Questions on the dataset:-

# %% [markdown]
# # 1.Find all the null value in the dataset.If there is any value in any column then fill it with the mean of that column?

# %%
df.isnull().sum()

# %%
import seaborn as sns
sns.heatmap(df.isnull(),cmap="YlGnBu")

# %%
df['Cylinders'] = df['Cylinders'].fillna(df['Cylinders'].mean())

# %%
import seaborn as sns
sns.heatmap(df.isnull())

# %% [markdown]
# # 2.Check what are the different type of "Make" are there in our dataset.And,what is the count of each make in data?

# %%
df.head(2)

# %%
df['Make'].value_counts()

# %% [markdown]
# # 3.Remove all the records(rows) where "weight"(column) is above 4000?

# %%
df.head(2)

# %%
df[~(df["Weight"]>4000)]

# %% [markdown]
# # 4.Show all the records where "Origin" is "Asia" or "Europe"?

# %%
df.head(2)

# %%
df[(df["Origin"]=="Asia")|(df["Origin"]=="Europe")]

# %% [markdown]
# # 5.Increase all the values of "MPG-City" by "3"?

# %%
df.head(2)

# %%
df["MPG_City"]=df["MPG_City"].apply(lambda x:x+3)

# %%
df.head(2)

# %% [markdown]
# # Finish!!

# %% [markdown]
# # Dnt forget to vote up,it motivates me to make more kernel

# %% [markdown]
# ![](https://i.gifer.com/1B4T.gif)
