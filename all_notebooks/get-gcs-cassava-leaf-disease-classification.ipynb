# %%
from kaggle_datasets import KaggleDatasets

obj = {"base": KaggleDatasets().get_gcs_path("cassava-leaf-disease-classification")}



for WIDTH in [128,256,384,512]:
    center_path = KaggleDatasets().get_gcs_path(f'cassava-leaf-disease-tfrecords-center-{WIDTH}x{WIDTH}')
    path = KaggleDatasets().get_gcs_path(f'cassava-leaf-disease-tfrecords-{WIDTH}x{WIDTH}')
    obj[WIDTH] = {"center":center_path,"all":path}
obj
