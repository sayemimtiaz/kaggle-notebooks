# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from plotly import graph_objs as go
import plotly.express as px
import plotly.figure_factory as ff
from plotly.subplots import make_subplots
from scipy import stats

# %%
df=pd.read_csv('../input/psl-batting-records-20162021/HighestBattingAvgInPSL.csv')

# %%
df.head(10)

# %%
df.shape

# %%
df.isnull().sum()

# %%
df.describe()

# %%
df.drop(['PlayerName','Span','HS'],axis=1,inplace=True)

# %%
df.head(5)

# %%
plt.figure(figsize=(10,10))
sns.countplot("Mat",data=df.head(5),hue="Inns")
#Self_Employed people are mostly from rural background

# %%
#Finding correlation
plt.figure(figsize=(10,5))
ax=sns.heatmap(df.corr(),cmap="Set1",cbar=True,yticklabels=True,annot=True)
bottom,top=ax.get_ylim()
ax.set_ylim(bottom + 0.5,top -0.5)

# %%
sns.barplot("Mat","Inns",data=df.head(10),orient="v")
#thus it can be seen evidently that Loan_Amount increases for those applicants whose dependents are more than 3

# %%
sns.distplot(df["Mat"])

# %%
sns.distplot(df["Inns"])

# %%
sns.distplot(df["Not Outs"])

# %%
#Normalizing the applicant_income data
sns.distplot(np.log(df["Mat"]+2))

# %%
#Normalizing the applicant_income data
sns.distplot(np.log(df["Avg"]+1))

# %%
sns.distplot(np.log(df["SR"]+1))

# %%
sns.distplot(np.log(df["SR"]+1))

# %%
sns.distplot(np.log(df["Balls Faced"]+1))

# %%
fig = px.scatter_3d(df.iloc[:500], x='Mat', y='Inns', z='Not Outs',
                    color='Mat')
fig.show()

# %%
fig = px.scatter_3d(df.iloc[:500], x='Mat', y='Balls Faced', z='Avg',
                    color='Mat')
fig.show()

# %%
fig = px.scatter_3d(df.iloc[:500], x='Mat', y='SR', z='50s',
                    color='Mat')
fig.show()

# %%
fig = px.scatter_3d(df.iloc[:500], x='Mat', y='SR', z='0s',
                    color='Mat')
fig.show()

# %%
fig = px.scatter_3d(df.iloc[:500], x='Mat', y='SR', z='6s',
                    color='Mat')
fig.show()

# %%
x = df['Mat']
plt.figure(figsize=(10,8))
ax = sns.countplot(x,color='#00ffff')
ax.set_xlabel(xlabel = 'Age of the Players', fontsize = 16)
ax.set_title(label = 'Distribution of Age of the Players', fontsize = 20)
plt.show()

# %%
#Calc the man and the mean:
df.drop(columns=['Mat']).describe().T.style.bar(subset=['mean'], color='#606ff2')\
                            .background_gradient(subset=['std'], cmap='magma_r')\
                            .background_gradient(subset=['50%'], cmap='summer')

# %%
sns.heatmap(df.head(10).corr(),annot=True);

# %%
sns.kdeplot(df["Mat"]);

# %%
sns.kdeplot(df["Inns"]);

# %%
sns.kdeplot(df["Avg"]);

# %%
sns.pairplot(df, hue = 'Mat', palette = 'cool_r')
plt.figure(figsize=(100, 100))
plot(orig_emb_tsne, 'TSNE VISUALIZATION OF EMBEDDINGS BEFORE INB',df)
plt.show()

# %%
sns.countplot(data=df, x='Mat')

# %%
sns.pairplot(data=df)
plt.show()

# %%
plt.style.use("classic")
sns.countplot(data=df, x="Mat")
plt.grid(linewidth = 0.7)
plt.show()

# %%
plt.style.use("classic")
sns.countplot(data=df, x="Mat")
plt.grid(linewidth = 0.7)
plt.show()
plt.style.use("classic")
sns.countplot(data=df, x="Inns")
plt.grid(linewidth = 0.7)
plt.show()

# %%
sns.scatterplot(x=df['Mat'], y=df['Not Outs'], hue=df['Inns'])

# %%
sns.swarmplot(x=df['Mat'],
              y=df['Inns'])

# %%
sns.pairplot(df)
