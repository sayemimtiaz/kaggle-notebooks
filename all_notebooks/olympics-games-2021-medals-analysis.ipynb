# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Wlcome to the analysis

# %% [markdown]
# # let us import additional libaeiries

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

plt.style.use("ggplot")

# %% [markdown]
# # loading the data

# %%
df = pd.read_csv('/kaggle/input/olympic-games-2021-medals/Tokyo 2021 dataset.csv')

# %% [markdown]
# # let us understand the data

# %%
#viewing the first 5 rows
df.head(5)

# %%
# how many rows and columns in the data
df.shape

# %%
#there are 93 rows and 8 columns

# %%
#printing all columns names
df.columns

# %%
#let us get info about the data
df.info()

# %%
#is there null values?
df.isnull().sum()

# %%
#is there na values?
df.isna().sum()

# %%
# there is no null nor na values

# %%
#summary statstics of the data
df.describe()

# %% [markdown]
# # let us answer some questions

# %%
#what are the top 5 teams/countries by total medal
total_rank = df.sort_values(by ="Rank by Total", ascending = True )
total_rank.head(5)

# %%
#what are the top 5 teams/countries by gold medal?
#the data is already sorted by gold medal, so we just need to show the first 5 rows
df.head(5)

# %%
#what are the top 5 teams/countries by total then by gold medals?
df_2 = df.sort_values(['Total','Gold Medal'],ascending=[False, True])
df_2.head(5)

# %%
#how many total medals (gold + silver + bronze) awarded in the olympics 2021?
df['Total'].sum()

# %%
#how many gold medals awarded in the olympics2021?
x=df['Gold Medal'].sum()
x

# %%
#how many silver medals awarded in the olympics2021?
df['Silver Medal'].sum()

# %%
#how many bronze medals awarded in the olympics2021?
df['Bronze Medal'].sum()
