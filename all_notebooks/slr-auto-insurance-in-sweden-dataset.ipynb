# %% [markdown]
# # Machine Learning Algorithm - Regression(SLR)

# %% [markdown]
# #### 1- import Libraries

# %%
import numpy as np 
import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
        
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #### 2- import Dataset

# %%
dataset = pd.read_csv('/kaggle/input/auto-insurance-in-sweden-small-dataset/insurance.csv', skiprows=4) 

# ------------------------------------------
# Using "Skiprows" for remove first 4 rows

# %%
dataset.head()

# %%
dataset.rename(columns={'Y = total payment for all the claims in thousands of Swedish Kronor': 'Payments'}, inplace=True)

# %%
dataset.head()

# %%
dataset['Claims'] = dataset.index

# %%
dataset.head()

# %%
dataset.reset_index(drop=True, inplace=True)

# %%
dataset.head()

# %%
X = dataset.iloc[: , -1].values    #Features
y= dataset.iloc[:, 0].values       #Targets

# %%
X = X.reshape(-1, 1)

# %%
# from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)

# %%
model.score(X_test, y_test)

# %%
y_pred = model.predict(X_test)

# %%
y_test.shape

# %%
# Checking For Null Values
# ------------------------
dataset.isnull().sum()

# %%
# dataset = dataset.Columns["108"].ColumnName = ["number of claims"]

# %%
dataset.describe()

# %%
sns.regplot(x=X_train,y=y_train ,)
plt.show()

# %%
plt.scatter(x=X_train, y=y_train)
plt.plot(X_test, y_pred, color="green")
plt.show()

# %%
sns.lmplot(x='Payments', y='Claims', data = dataset)
plt.show()
