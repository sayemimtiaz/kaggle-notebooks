# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRQbzAowHZUu3P3qgDtpREmiydgOWkW5PQ4_g&usqp=CAU)amazon.com

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
plt.style.use('fivethirtyeight')

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv("/kaggle/input/world-of-beers/beer_list.csv",
                  engine="python", sep=",")
df.head()

# %%
df.isnull().sum()

# %%
#Code by Rashik Rahman  https://www.kaggle.com/rashikrahmanpritom/insights-on-disney-movies-gross

# Sort data by Styles in descending order 
Style_desc = df.sort_values(by='Style', ascending=False) 

# Display the top 10 Styles 
Style_desc.head(10)

# %%
#Code by Rashik Rahman https://www.kaggle.com/rashikrahmanpritom/insights-on-disney-movies-gross/notebook

# Extract year from release_date and store it in a new column
df['release_year'] = pd.DatetimeIndex(df['Date']).year

# Compute mean of adjusted gross per genre and per year
group = df.groupby(['Style','release_year']).mean()

# Convert the GroupBy object to a DataFrame
Style_yearly = group.reset_index()

# Inspect genre_yearly 
print(Style_yearly.head())


# Plot the data  

g=sns.relplot(kind='line', x='release_year', y='Catalog', hue='Style', data=Style_yearly)
g.fig.set_size_inches(10,10)
plt.title('Beer Style trend')

# %%
#Let's find 10 beers
print('10 Breweries/beers are:\n\n',df['Style'].value_counts().head(10))

# %%
df['Brewery/Beer'].value_counts().head(10).plot(kind='bar')

# %%
#Code by Muhammad Rizwan Amanat https://www.kaggle.com/muhammadrizwanamanat/top-five

#Top Selling Beers wrt Score
df[['Brewery/Beer', 'Score']].value_counts().head(5)

# %%
#Some Visualization
df[['Style', 'Score']].value_counts().head(5).plot(kind='barh');

# %%
#Some Visualization
df[['Location', 'Score']].value_counts().head(5).plot(kind='barh', color='r');

# %%
#Code by Siti K https://www.kaggle.com/khotijahs1/2020-indonesia-university-rank/comments

#The Best 20 Beer's Style by Score
top_beer = df.sort_values(by='Score', ascending=False)[:20]
figure = plt.figure(figsize=(10,6))
sns.barplot(y=top_beer.Style, x=top_beer.Score)
plt.xticks()
plt.xlabel('Score')
plt.ylabel('Beer Style')
plt.title('Top 20 Styles')
plt.show()

# %%
#Code by Siti K https://www.kaggle.com/khotijahs1/2020-indonesia-university-rank/comments

#The Best 20 Beer's Style by Score
top_beer = df.sort_values(by='Score', ascending=False)[:20]
figure = plt.figure(figsize=(10,6))
sns.barplot(y=top_beer.Location, x=top_beer.Score)
plt.xticks()
plt.xlabel('Score')
plt.ylabel('Location')
plt.title('Top 20 Locations')
plt.show()

# %%
df = df.rename(columns={'Brewery/Beer':'brewery'})

# %%
#Code by Siti K https://www.kaggle.com/khotijahs1/2020-indonesia-university-rank/comments

#The Best 20 Beer's Style by Score
top_beer = df.sort_values(by='Score', ascending=False)[:20]
figure = plt.figure(figsize=(10,6))
sns.barplot(y=top_beer.brewery, x=top_beer.Score)
plt.xticks()
plt.xlabel('Score')
plt.ylabel('Brewery')
plt.title('Top 20 Breweries')
plt.show()

# %%
#word cloud
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in df.brewery)
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200,colormap='Pastel1', background_color="black").generate(text)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='Bilinear')
plt.axis("off")
plt.figure(1,figsize=(12, 12))
plt.show()

# %%
#word cloud
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in df.Location)
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200,colormap='Set2', background_color="white").generate(text)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='Bilinear')
plt.axis("off")
plt.figure(1,figsize=(12, 12))
plt.show()

# %%
#word cloud
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in df.Style)
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200,colormap='Dark2_r', background_color="salmon").generate(text)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='Bilinear')
plt.axis("off")
plt.figure(1,figsize=(12, 12))
plt.show()

# %%
import plotly.express as px

fig = px.scatter(df, x="brewery", y="Score", color="Location", title='Breweries Scores')
fig.show()

# %%
#Code by Olga Belitskaya https://www.kaggle.com/olgabelitskaya/sequential-data/comments
from IPython.display import display,HTML
c1,c2,f1,f2,fs1,fs2=\
'#eb3434','#eb3446','Akronim','Smokum',30,15
def dhtml(string,fontcolor=c1,font=f1,fontsize=fs1):
    display(HTML("""<style>
    @import 'https://fonts.googleapis.com/css?family="""\
    +font+"""&effect=3d-float';</style>
    <h1 class='font-effect-3d-float' style='font-family:"""+\
    font+"""; color:"""+fontcolor+"""; font-size:"""+\
    str(fontsize)+"""px;'>%s</h1>"""%string))
    
    
dhtml('Be patient. Marília Prata, @mpwolke was Here' )
