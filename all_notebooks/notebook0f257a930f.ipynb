# %%
import pandas as pd
import seaborn as sns
import numpy as np
import missingno as mson
import matplotlib.pyplot as plt
import os

# %%
data=pd.read_csv("../input/cricket-headlines/cricinfoNews.csv")

# %%
data.head()

# %%
data.shape

# %%
data.info()

# %%
data.describe()

# %%
mson.bar(data)

# %%
data['category'].value_counts().head(10)
