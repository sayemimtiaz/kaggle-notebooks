# %%
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = (nCol + nGraphPerRow - 1) / nGraphPerRow
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# %% [markdown]
# ### Let's check 1st file: /kaggle/input/England_Regions_COVID_Dataset.csv

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
# England_Regions_COVID_Dataset.csv may have more rows in reality, but we are only loading/previewing the first 1000 rows
df1 = pd.read_csv('/kaggle/input/England_Regions_COVID_Dataset.csv', delimiter=',', nrows = nRowsRead)
df1.dataframeName = 'England_Regions_COVID_Dataset.csv'
nRow, nCol = df1.shape
print(f'There are {nRow} rows and {nCol} columns')

# %% [markdown]
# Let's take a quick look at what the data looks like:

# %%
df1.head(5)

# %% [markdown]
# Distribution graphs (histogram/bar graph) of sampled columns:

# %%
plotPerColumnDistribution(df1, 10, 5)

# %% [markdown]
# ### Let's check 2nd file: /kaggle/input/Populations_for_UK_and_Devolved_Nations.csv

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
# Populations_for_UK_and_Devolved_Nations.csv may have more rows in reality, but we are only loading/previewing the first 1000 rows
df2 = pd.read_csv('/kaggle/input/Populations_for_UK_and_Devolved_Nations.csv', delimiter=',', nrows = nRowsRead)
df2.dataframeName = 'Populations_for_UK_and_Devolved_Nations.csv'
nRow, nCol = df2.shape
print(f'There are {nRow} rows and {nCol} columns')

# %% [markdown]
# Let's take a quick look at what the data looks like:

# %%
df2.head(5)

# %% [markdown]
# Distribution graphs (histogram/bar graph) of sampled columns:

# %%
plotPerColumnDistribution(df2, 10, 5)

# %% [markdown]
# ### Let's check 3rd file: /kaggle/input/UK_Devolved_Nations_COVID_Dataset.csv

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
# UK_Devolved_Nations_COVID_Dataset.csv may have more rows in reality, but we are only loading/previewing the first 1000 rows
df3 = pd.read_csv('/kaggle/input/UK_Devolved_Nations_COVID_Dataset.csv', delimiter=',', nrows = nRowsRead)
df3.dataframeName = 'UK_Devolved_Nations_COVID_Dataset.csv'
nRow, nCol = df3.shape
print(f'There are {nRow} rows and {nCol} columns')

# %% [markdown]
# Let's take a quick look at what the data looks like:

# %%
df3.head(5)

# %% [markdown]
# Distribution graphs (histogram/bar graph) of sampled columns:

# %%
plotPerColumnDistribution(df3, 10, 5)

# %% [markdown]
# ### Let's check 4rd file: /kaggle/input/UK_Local_Authority_UTLA_COVID_Dataset.csv

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
# UK_Local_Authority_UTLA_COVID_Dataset.csv may have more rows in reality, but we are only loading/previewing the first 1000 rows
df4 = pd.read_csv('/kaggle/input/UK_Local_Authority_UTLA_COVID_Dataset.csv', delimiter=',', nrows = nRowsRead)
df4.dataframeName = 'UK_Local_Authority_UTLA_COVID_Dataset.csv'
nRow, nCol = df4.shape
print(f'There are {nRow} rows and {nCol} columns')

# %%
df4.head(5)

# %%
plotPerColumnDistribution(df4, 10, 5)

# %% [markdown]
# ### Let's check 5rd file: /kaggle/input/UK_National_Total_COVID_Dataset.csv

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
# UK_National_Total_COVID_Dataset.csv may have more rows in reality, but we are only loading/previewing the first 1000 rows
df5 = pd.read_csv('/kaggle/input/UK_National_Total_COVID_Dataset.csv', delimiter=',', nrows = nRowsRead)
df5.dataframeName = 'UK_National_Total_COVID_Dataset.csv'
nRow, nCol = df5.shape
print(f'There are {nRow} rows and {nCol} columns')

# %%
df5.head(5)

# %%
plotPerColumnDistribution(df5, 10, 5)
