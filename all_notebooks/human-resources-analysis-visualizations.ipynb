# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../input/human-resources-data-set/HRDataset_v14.csv")

# %%
pd.set_option('display.max_columns',None)

# %%
df.head()

# %%
DeptID = df['DeptID'].value_counts().iloc[:10]

plt.figure(figsize=(10,5))
sns.barplot(x = DeptID.index , y = DeptID.values ,order=DeptID.index, palette='rocket')

plt.title('count employees in each  Department ID' , fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.show()

# %%
PerfScoreID = df['PerfScoreID'].value_counts().iloc[:10]

plt.figure(figsize=(10,5))
sns.barplot(x = PerfScoreID.index , y = PerfScoreID.values ,order=PerfScoreID.index, palette='rocket')

plt.title('sum employees in each Perf Score ID' , fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.show()

# %%
FromDiversity  = df['FromDiversityJobFairID'].value_counts().iloc[:10]

plt.figure(figsize=(10,5))

sns.barplot(x = FromDiversity.index , y = FromDiversity.values , order = FromDiversity.index, palette='rocket')

plt.title('sum employees in each Diversity Job Fair' , fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
Termd = df['Termd'].value_counts().iloc[:10]

plt.figure(figsize=(10,5))

sns.barplot(x = Termd.index , y=Termd.values ,order=Termd.index, palette='rocket')

plt.title('sum of Termd ' , fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.show()

# %%
Sex = df['Sex'].value_counts()

plt.figure(figsize=(10,5))
sns.barplot(x = Sex.index , y=Sex.values , order = Sex.index, palette='rocket')

plt.title(' Sex'  , fontsize=20)

plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.show()

# %%
CitizenDesc = df['CitizenDesc'].value_counts()


plt.figure(figsize=(10,5))

sns.barplot(x = CitizenDesc.index , y=CitizenDesc.values ,order = CitizenDesc.index , palette='rocket')

plt.title('Citizen' , fontsize=20)

plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.show()

# %%
EngagementSurvey = df['EngagementSurvey'].value_counts().iloc[:20]


plt.figure(figsize=(14,5))
sns.barplot(x = EngagementSurvey.index , y=EngagementSurvey.values , order=EngagementSurvey.index , palette='rocket')

plt.title('Engagement Survey ' , fontsize=20)
plt.xticks(fontsize=15)

plt.yticks(fontsize=15)

plt.show()

# %%
EmpSatisfaction = df['EmpSatisfaction'].value_counts()


plt.figure(figsize=(10,5))

sns.barplot(x = EmpSatisfaction.index , y=EmpSatisfaction.values , order = EmpSatisfaction.index, palette='rocket')

plt.title('count of '+i , fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.show()

# %%
Position = df['Position'].value_counts()
plt.figure(figsize=(10,12))

sns.barplot(x = Position.values , y=Position.index , order = Position.index, palette='rocket')

plt.title('count of Position' , fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.show()

# %%
col_bar=['Position' , 'State','MaritalDesc','RaceDesc' , 'TermReason', 'EmploymentStatus', 'Department' ,
         'RecruitmentSource' , 'PerformanceScore']

col = df['State'].value_counts()
plt.figure(figsize=(10,12))

sns.barplot(x = col.values , y=col.index , order = col.index, palette='rocket')

plt.title('State' , fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.show()

# %%
col = df['MaritalDesc'].value_counts()
plt.figure(figsize=(10,12))

sns.barplot(x = col.values , y=col.index , order = col.index, palette='rocket')

plt.title('State' , fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.show()

# %%
col = df['RaceDesc'].value_counts()
plt.figure(figsize=(10,12))

sns.barplot(x = col.values , y=col.index , order = col.index, palette='rocket')

plt.title('RaceDesc' , fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.show()

# %%
col = df['TermReason'].value_counts()
plt.figure(figsize=(10,12))

sns.barplot(x = col.values , y=col.index , order = col.index, palette='rocket')

plt.title('TermReason' , fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.show()

# %%
col = df['EmploymentStatus'].value_counts()
plt.figure(figsize=(10,12))

sns.barplot(x = col.values , y=col.index , order = col.index, palette='rocket')

plt.title('Employment Status' , fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.show()

# %%
col = df['Department'].value_counts()
plt.figure(figsize=(10,12))

sns.barplot(x = col.values , y=col.index , order = col.index, palette='rocket')

plt.title('Department' , fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.show()

# %%
col = df['RecruitmentSource'].value_counts()
plt.figure(figsize=(10,12))

sns.barplot(x = col.values , y=col.index , order = col.index, palette='rocket')

plt.title('Recruitment Source' , fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.show()

# %%
col = df['PerformanceScore'].value_counts()
plt.figure(figsize=(10,12))

sns.barplot(x = col.values , y=col.index , order = col.index, palette='rocket')

plt.title('Performance Score' , fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.show()

# %%
cols = ['Salary','Termd' ,'EngagementSurvey','EmpSatisfaction','SpecialProjectsCount','Absences']

# %%
print('Average of :\n')

for i in cols:
    print(i)
    print(np.around(df[i].mean(),2))
    print('-----------------------')

# %%
print('Minumin of :\n')

for i in cols:
    print(i)
    print(np.around(df[i].min(),2))
    print('-----------------------')

# %%
print('Maxumim of :\n')

for i in cols:
    print(i)
    print(np.around(df[i].max(),2))
    print('-----------------------')

# %%
df.describe().drop(['EmpID','MarriedID','MaritalStatusID','GenderID','EmpStatusID','DeptID','PerfScoreID','FromDiversityJobFairID','PositionID','Zip','ManagerID'],axis=1)

# %%
for i in cols:
    plt.figure(figsize=(5,5))
    sns.boxplot(y=df[i])
    plt.title(i)
    plt.show()

# %%
plt.figure(figsize=(14,8))

corr = df.drop(['EmpID','MarriedID','MaritalStatusID','GenderID','EmpStatusID','DeptID','PerfScoreID','FromDiversityJobFairID','PositionID','Zip','ManagerID'], axis=1).corr()

sns.heatmap(corr ,annot=True)

plt.title('Show The Correlations between Columns', fontsize=20)

plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# *********
#
# # Thanks :)
# **BY : Ahmed Fouad**
