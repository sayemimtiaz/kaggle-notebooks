# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np # linear algebra
import pandas as pd
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
import os
for dirname, _, filenames in os.walk('/kaggle/input/stroke-3'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import ensemble, preprocessing, metrics
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

#Decsision tree

# load dataset
col_names = ['id', 'age', 'hypertension', ' heart_disease', 'avg_glucose_level', 'BMI_1', 'gender_1', 'married', 'work_type_1', 'urbanization', 'smoking', 'label']
stroke_train = pd.read_csv('/kaggle/input/stroke-3/stroke_3.csv', header=0,names=col_names) 
feature_cols = ['age', 'hypertension', ' heart_disease', 'avg_glucose_level', 'BMI_1', 'gender_1', 'married', 'work_type_1', 'urbanization', 'smoking']
target_cols= ['label']
stroke_X = stroke_train [feature_cols] # Features
stroke_y = stroke_train[target_cols]
train_X, test_X, train_y, test_y = train_test_split(stroke_X, stroke_y,
test_size = 0.3,random_state=1)# 70% training and 30% test
clf = DecisionTreeClassifier()
# Train Decision Tree Classifer
clf = clf.fit (train_X,train_y)
#Predict the response for test dataset
y_pred = clf.predict (test_X)
print("Accuracy:",metrics.accuracy_score(test_y, y_pred)) ##Accuracy=0.9119373776908023
#Optimization – Pre-pruning
# Create Decision Tree classifer object
clf = DecisionTreeClassifier(criterion="entropy", max_depth=4)
# Train Decision Tree Classifer
clf = clf.fit (train_X,train_y)
#Predict the response for test dataset
y_pred = clf.predict(test_X)
# Model Accuracy, how often is the classifier correct?
print ("Accuracy:",metrics.accuracy_score(test_y, y_pred)) ##Accuracy=0.9458577951728636

from sklearn.metrics import f1_score
f1_score(test_y, y_pred, average='macro')#F1 score=0.4860878310425746
f1_score(test_y, y_pred, average='micro') #F1 score=0.9458577951728636
f1_score(test_y, y_pred, average=None)#F1 score=array([0.97217566, 0.        ])
f1_score(test_y, y_pred, average='weighted') #F1 score=0.9208082591961099

###random forest
target_cols= ['label']
stroke_X = stroke_train [feature_cols] # Features
stroke_y = stroke_train[target_cols]
train_X, test_X, train_y, test_y = train_test_split(stroke_X, stroke_y,
test_size = 0.3)# 70% training and 30% test


# Random Forest Model
forest = ensemble.RandomForestClassifier(n_estimators = 100)
forest_fit = forest.fit(train_X, train_y)
# Prediction
test_y_predicted = forest.predict(test_X)
# Evaluate
accuracy = metrics.accuracy_score(test_y, test_y_predicted)
print(accuracy)##Accuracy=0.9530332681017613
#F1 score
from sklearn.metrics import f1_score
f1_score(test_y, test_y_predicted, average='macro') #F1 score=0.5004410109796525
f1_score(test_y, test_y_predicted, average='micro') #F1 score=0.9523809523809523
f1_score(test_y, test_y_predicted, average=None)#F1 score=array([0.974908  , 0.02597403])
f1_score(test_y, test_y_predicted, average='weighted')#F1 score=0.9313686835846384




#XGBoot Classifier
target_cols= ['label']
stroke_X = stroke_train [feature_cols] # Features
stroke_y = stroke_train[target_cols]
train_X, test_X, train_y, test_y = train_test_split(stroke_X, stroke_y,
test_size = 0.3,random_state=1)# 70% training and 30% test
from xgboost.sklearn import XGBClassifier
clf = XGBClassifier(
n_estimators=100,
learning_rate= 0.05,
max_depth=6,
subsample=1,
gamma=0,
reg_lambda=1,
max_delta_step=0,
colsample_bytree=1,
min_child_weight=1,
seed=1000
)
clf.fit(train_X,train_y,eval_metric='auc')
y_pred=clf.predict(test_X)
y_true= test_y
print("Accuracy : %.4g" % metrics.accuracy_score(y_true, y_pred)) #Accuracy : 0.9472


#F1 score
from sklearn.metrics import f1_score
f1_score(y_true, y_pred, average='macro') #F1 score=0.4864321608040201
f1_score(y_true, y_pred, average='micro') #F1 score=0.9471624266144814
f1_score(y_true, y_pred, average=None)#F1 score=array([0.97286432, 0.        ])
f1_score(y_true, y_pred, average='weighted') #F1 score=0.9214605316209226


###SVM
stroke_X = stroke_train [feature_cols] # Features
stroke_y = stroke_train[target_cols]
train_X, test_X, train_y, test_y = train_test_split(stroke_X, stroke_y,
test_size = 0.3,random_state=1)# 70% training and 30% test
#split input data into training data and test data
from sklearn.svm import SVC
stroke_svc = SVC()
stroke_svc.fit(train_X,train_y)
y_test_result = stroke_svc.predict(test_X)
# Evaluate
accuracy = metrics.accuracy_score (test_y, y_test_result)
print(accuracy) #accuracy=0.9471624266144814
#F1 score
from sklearn.metrics import f1_score
f1_score(y_true, y_pred, average='macro') #F1 score=0.4864321608040201
f1_score(y_true, y_pred, average='micro') #F1 score=0.9471624266144814
f1_score(y_true, y_pred, average=None)#F1 score=array([0.97286432, 0.        ])
f1_score(y_true, y_pred, average='weighted') #F1 score=0.9214605316209226
