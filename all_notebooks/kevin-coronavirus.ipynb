# %% [markdown]
# **/!\ A titre d'information /!\**
# Les données suivantes peuvent être corrompu, il est probable qu'elles soient fausses.

# %% [markdown]
# Pour commencer on importe le tableau excel comportant les données

# %%
import pandas as pd

data = pd.read_csv("../input/coronavirus-france-dataset/patient.csv")

# %% [markdown]
# Aperçu de quelques lignes du tableau

# %%
data.head()

# %% [markdown]
# Avoir un aperçu du nombre de colonne et de ligne

# %%
data.shape

# %% [markdown]
# Avoir un aperçu des noms de colonne

# %%
data.columns

# %% [markdown]
# On souhaite supprimer des colonnes qui ne me sont pas nécéssaire pour ma recherche

# %%
data = data.drop(['id', 'group', 'infection_reason', 'infection_order', 'infected_by',
       'contact_number', 'confirmed_date', 'released_date', 'deceased_date',
       'status', 'health', 'source', 'comments'], axis=1)

# %%
data.head()

# %% [markdown]
# On souhaite avoir une moyenne d'âge de tout les personnes ayant attrapées la maladie mais problème: il manque des données..

# %%
data.describe()

# %% [markdown]
# On va retirer toute les personnes n'ayant aucune information sur leur âge

# %%
data = data.dropna(axis=0)

# %%
data.shape

# %% [markdown]
# On a l'information sur l'année de naissance de 69 personnes

# %%
data.describe()

# %%
data['birth_year'].hist()

# %% [markdown]
# On a donc la moyenne d'âge qui est 60 ans (mean	1960.057971)

# %% [markdown]
# Maintenant ou voudrait savoir combien d'hommes et de femmes ont attrapé la maladie et avoir la moyenne d'âge des différents sexe

# %%
data['sex'].value_counts().plot.bar()
data.groupby(['sex']).mean()

# %% [markdown]
# On peut appercevoir la moyenne d'âge des hommes et des femmes
# et qu'il y a plus de femme ayant attrapé le covid que d'homme

# %% [markdown]
# Maintenant on souhaite lister le nombre d'habitant dans chaque région et repérer le nombre de d'habitant en Hauts-de-France

# %%
data['region'].value_counts()

# %% [markdown]
# On compte donc 7 habitants qui ont le coronavirus en Hauts-de-France
