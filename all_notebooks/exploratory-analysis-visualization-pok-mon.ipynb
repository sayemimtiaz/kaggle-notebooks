# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Table of Contents
# <a id='toc'></a>
# <a style="font-weight:bold" href='#nbi'>0. Notebook Introduction</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href='#data'>&nbsp;Data</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href='#fet'>&nbsp;Features</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href='#fet'>&nbsp;Basic Information of Dataset</a><br>
# <a style="font-weight:bold" href='#nbi'>1. Stats Analysis</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href='#atk'>&nbsp;Attack</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href='#def'>&nbsp;Defense</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href='#spa'>&nbsp;Special Attack</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href='#spd'>&nbsp;Special Defense</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href='#spe'>&nbsp;Speed</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href='#hp'>&nbsp;HP</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href='#total'>&nbsp;Total</a><br>
# <a style="font-weight:bold" href='#typ'>2. Types Analysis</a><br>
# <a style="font-weight:bold" href='#tpa'>&nbsp;Population Type Analysis</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href='#gra'>&nbsp;Grass | </a><a href='#fir'>&nbsp;Fire | </a><a href='#wat'>&nbsp;Water</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href='#ele'>&nbsp;Electric | </a><a href='#fly'>&nbsp;Flying | </a><a href='#bug'>&nbsp;Bug</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href='#roc'>&nbsp;Rock | </a><a href='#fig'>&nbsp;Fighting | </a><a href='#gro'>&nbsp;Ground</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href='#ice'>&nbsp;Ice | </a><a href='#psy'>&nbsp;Psychic | </a><a href='#gho'>&nbsp;Ghost</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href='#nor'>&nbsp;Normal | </a><a href='#dra'>&nbsp;Dragon | </a><a href='#ste'>&nbsp;Steel</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href='#poi'>&nbsp;Poison | </a><a href='#dark'>&nbsp;Dark | </a><a href='#fai'>&nbsp;Fairy</a><br>

# %% [markdown]
# # Notebook Introduction
# <a id='nbi'></a>
# Hi Kagglers! <br>
# This notebook is my first personal *Exploratory Data Analysis* project, after finishing the data science course.<br>
# I decided to work on this data set as a "re-learn" project with repetitive behavior (as you will see in this notebook),<br> hoping it would help me get used to the python workflow & coding environment.<br>
# (and also, because I am a Pokémon main series games' fan)<br>
# <br>
# As I am aware that using only the stats,<br>
# will not be able to provide us the absolute measurement of how good a Pokémon is in the game,<br>
# considering other factors in the game such as level, movesets, special ability, items and elemental weakness<br>
# that can totally affect how you use Pokémons in the games<br>
# but I will try to approach this project from the perspective of the Pokémon main series players(VGC format)<br>
# To use this data to my advantage in Pokémon Team build and strategic planning.<br>
#
# I will not separate the legendary pokemon and will be using only "Type 1" for the type analysis section.<br>
# As a beginner, your feedback is valuable. If you're so kind to leave me a comment on what I did wrong, whether the area I can improve or the better way to things.

# %% [markdown]
# # Data
# <a id='data'></a>
# The data is downloaded from the Kaggle Datasets by Alberto Barradas!
# https://www.kaggle.com/abcsds/pokemon
# <br>
# > This data set includes 721 Pokemon, including their number, name, first and second type,
# and basic stats: HP, Attack, Defense, Special Attack, Special Defense, and Speed.
# It has been of great use when teaching statistics to kids.
# With certain types you can also give a geeky introduction to machine learning.
#
# This are the raw attributes that are used for calculating how much damage an attack will do in the games.
# This dataset is about the pokemon games (NOT pokemon cards or Pokemon Go).

# %% [markdown]
# # Features
# <a id='fet'></a>
# This data set includes, including their number, name, first and second type, and basic stats:
# HP, Attack, Defense, Special Attack, Special Defense, and Speed.
# It has been of great use when teaching statistics to kids.
# With certain types you can also give a geeky introduction to machine learning.
#
# This are the raw attributes that are used for calculating how much damage an attack will do in the games.
# This dataset is about the pokemon games (NOT pokemon cards or Pokemon Go).
#
# The data for this table has been acquired from several different sites, including:
#
# https://www.pokemon.com/us/pokedex/
# https://pokemondb.net/pokedex
# https://bulbapedia.bulbagarden.net/wiki/List_of_Pok%C3%A9mon_by_National_Pok%C3%A9dex_number
#
# > One question has been answered with this database: The type of a pokemon cannot be inferred only by it's Attack and Deffence.
# It would be worthy to find which two variables can define the type of a pokemon, if any.
# Two variables can be plotted in a 2D space, and used as an example for machine learning.
# This could mean the creation of a visual example any geeky Machine Learning class would love.
#
# **Type, description and sprites**<br>
# Thank you so much pokemondb!<br>
# https://pokemondb.net/type<br>
# https://pokemondb.net/sprites<br>
# https://pokemon.fandom.com/wiki/Statistics#:~:text=Statistics%2C%20also%20known%20as%20Stats,exclusive%20to%20battle%20and%20moves.<br>
#
# **The data as described by Myles O'Neill is:**
#
# > **#**: ID for each pokemon<br>
# > **Name**: Name of each pokemon<br>
# > **Type 1**: Each pokemon has a type, this determines weakness/resistance to attacks<br>
# > **Type 2**: Some pokemon are dual type and have 2<br>
# > **Total**: sum of all stats that come after this, a general guide to how strong a pokemon is<br>
# > **HP**: hit points, or health, defines how much damage a pokemon can withstand before fainting<br>
# > **Attack**: the base modifier for normal attacks (eg. Scratch, Punch)<br>
# > **Defense**: the base damage resistance against normal attacks<br>
# > **SP Atk**: special attack, the base modifier for special attacks (e.g. fire blast, bubble beam)<br>
# > **SP Def**: the base damage resistance against special attacks<br>
# > **Speed**: determines which pokemon attacks first each round<br>

# %% [markdown]
# <a id='bid'></a>
# ## Basic Information of the dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df_1 = pd.read_csv("../input/pokemon/Pokemon.csv")

# %%
df_1.shape
# 800 rows and 13 columns

# %%
df_1.info

# %%
df_1.isna().sum()

# %%
df_1.describe()

# %%
df_1.columns

# %%
# Removing special characters and whitespace.
df_1.columns = df_1.columns.str.strip()     
df_1.columns = df_1.columns.str.replace(' ', '_')         
df_1.columns = df_1.columns.str.replace(r"[^a-zA-Z\d\_]+", "")    
df_1.columns = df_1.columns.str.replace(r"[^a-zA-Z\d\_]+", "")

# %%
df_1.Type_2 = df_1.Type_2.fillna(value='None')

# %%
df_1.columns

# %%
df_1['Type_3'] = df_1['Type_1'] + " - " + df_1['Type_2']

# %%
df_1.Type_1.unique()
# Alternative print(pd.unique(df_1['Type_1']))

# %% [markdown]
# # 1. Stats Analysis
# <a id='sta'></a>
# Statistics, also known as Stats for short, are values that apply to a Pokémon's abilities in battle.<br>
# These values determine such factors as, damage given, damage received, which Pokémon acts first, etc.<br>
# Most stats are affected by the individual Pokémon and their level,<br>
# while others are exclusive to battle and moves.<br>

# %% [markdown]
# <a id='atk'></a>
# ## 1.1 Attack - ATK
# ### The base modifier for normal attacks (eg. Scratch, Punch)
# Wiki - The Attack stat, or informally Physical Attack, partly determines how much damage a Pokémon deals when using a physical move.

# %% [markdown]
# ### Top 10 Attackers (All Types)
# #### Ranking Attackers from every type and combinations with >160 ATK Stat
# ![1](https://lh3.googleusercontent.com/XGyZ_zZG6UyAWcl-YcZZGmlaH-h_1BnK3cplBMYgI2WbKLFtOOtPYpjbo6J7jz-QqBpVmtCave7k6zyC6wYIrFIsnlYWuL73sjKyBts4rtlIfssBqafaky5R4oPQdeSfFz4sgEJFhw=w800)

# %%
df_1.sort_values(['Attack'], ascending=False).head(10)

# %% [markdown]
# ### Results form the Attack Scatter Plot
# 1. **Fighting/Psyhic** type is the 1st highest attacker,
# following by **Bug/Fighting** as a 2nd place, then **Fire/Ground & Dragon/Flying** as a 3rd place from the top
# 2. **Bug/Rock type** has the lowest Attack stats
# 3. Majority of Pokemon with a **Fighting type** as the Type 2 seems to have high ATK stat
# specially beyond **125 ATK**
#
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
sns.set_style("darkgrid")
sns.set(rc={'figure.figsize':(13.5,9)})

# %%
# Attack Scatter Plot
sns.scatterplot(data=df_1, x="Attack", y="Type_1", hue="Type_2",style="Type_2", s=100);

# %% [markdown]
# ### Results form the Attack Distplot & FacetGrid (Type 1)
# 1. **Bug, Normal, Electric, Ghost and Dark** as **Type 1** have high poppulation in the range of **60-70 ATK **
# 2. **Bug, Ground, Psyhic and Dragon** are the best **Type 1** attackers.
# 3. **Fairy** type possess no poppulation in the area further than **59 ATK**
#
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
sns.displot(x="Attack", y="Type_1",data=df_1);

# %%
g = sns.FacetGrid(df_1, col="Type_1")
g.map(sns.histplot, "Attack");

# %% [markdown]
# ### Results form the Attack Distplot & FacetGrid (Type 2)
# 1. **Flying** type possess the high poppulation in the ranges between **40-90 ATK**
# 2. **Flying, Fighting, and Fire** are the highest **Type 2** attackers.
# 3. **Fairy** type possess no poppulation in the area between **70-145 ATK**

# %%
# Creates df_2 for type_2 analysis
df_2 = df_1[df_1["Type_2"] == df_1["Type_2"]]

# %%
sns.displot(x="Attack", y="Type_2",data=df_2);

# %%
g = sns.FacetGrid(df_1, col="Type_2")
g.map(sns.histplot, "Attack");

# %% [markdown]
# <a id='def'></a>
# # 1.2 Defense - DEF
# ## Defense: the base damage resistance against normal attacks
# Wiki - The Defense stat, or informally Physical Defense, partly determines how much damage a Pokémon receives when it is hit with a physical move.

# %% [markdown]
# ### Top 10 Defenders (All Types)
# #### Ranking Defenders from every type and combinations with >150 DEF Stat
# ![1](https://lh3.googleusercontent.com/eWp5toBH2sNVFDZqOWBNHhP3BMPCP7wPjYRZ3t2Do7sbYkG707zWcpuZ3Bkzweo-h-W3-Vy6fYsWtHAqEe1usCig39YrfH29fO-g-TcUiTUEpGxejnHq53yM0Jg29SNNnhXVLpfE5w=w800)

# %%
df_1.sort_values(['Defense'], ascending=False).head(10)

# %% [markdown]
# ### Results form the Defense Scatter Plot
# 1. **Ground/Steel** type has 1st highest defense follwing by **Bug/Rock** type has 2nd best DEF.
# 2. **Normal/Fairy** and **Ice/Psychic** has the lowest Defense stats
# 3. **Fairy/Flying** possess no poppulation in the other area beside, between the range of **80-95 ATK**
#
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
sns.scatterplot(data=df_1, x="Defense", y="Type_1", hue="Type_2",style="Type_2", s=100);

# %% [markdown]
# ### Results form the Defense Distplot & FacetGrid (Type 1)
# 1. **Bug and Steel** as Type 1, have highest defense in the range of **230 DEF**.
# 2. **Bug, Normal and Water** as Type 1, also possess high poppulation in the range of **40-50 ATK**.
# 3. **Fairy** type possess no population in the area further than **100 ATK**.
# 4. **Steel** type is probably the best all Type 1 in terms of defense.
# 5. **Water** type also possess hight population between the range of **50-90 ATK**

# %%
sns.displot(x="Defense", y="Type_1",data=df_1);

# %%
g = sns.FacetGrid(df_1, col="Type_1")
g.map(sns.histplot, "Defense");

# %% [markdown]
# ### Results form the Defense Distplot & FacetGrid (Type 2)
# 1. Majority of Type 2 **Flying** Pokemons are in the range of **40-50 DEF**
# 2. **Ground** as Type 2, also possess high poppulation in the range of **40-50 DEF**
# 3. **Fairy** type possess no poppulation in the area further than **100 DEF**
# 4. **Normal** type as Type 2 only have the DEF stat in the range of **40-70 DEF**

# %%
sns.displot(x="Defense", y="Type_2",data=df_2);

# %%
g = sns.FacetGrid(df_1, col="Type_2")
g.map(sns.histplot, "Defense");

# %% [markdown]
# <a id='spa'></a>
# # 1.3 Special Attack - SPA
# ## Special Attack: special attack, the base modifier for special attacks (e.g. fire blast, bubble beam)
# Wiki - The Special Attack stat, or Sp. Atk, partly determines how much damage a Pokémon deals when using a special move.

# %% [markdown]
# ### Top 10 Special Attackers (All Types)
# #### Ranking Special Attackers from every type and combinations with >150 SPA Stat
# ![1](https://lh3.googleusercontent.com/3XA3TkriezBmZK4meUrSpvdhABEH8jb6RC9z8sOwjZpfVEI4YohCCxHUG2jQ2lUcnSmjCg5GNywxYGcmBbYU1iCWah_WFecPdrhLqABJl1l_quIfyTLFADw3dEHBeBDLGh_ir5zk7g=w800)

# %%
df_1.sort_values(['Sp_Atk'], ascending=False).head(10)

# %% [markdown]
# ### Results form the Special Attack Scatter Plot
# 1. *Rayquaza* from the **Dragon/Flying** has the highest SPA.
# 2. **Ghost/Poision, Dragon/Ice** **,and Psychic/Dark** comes in the 2nd place for the special attack stat.
# 3. **Fairy/Flying** possess no poppulation in the other area beside, between the range of **80-95 ATK**
# 4. If we look closely **Dragon** type has high SPA stat. Starts from **100 SPA** all the way up to **180 SPA**
#
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
sns.scatterplot(data=df_1, x="Sp_Atk", y="Type_1", hue="Type_2",style="Type_2", s=100);

# %% [markdown]
# ### Results form the Defense Distplot & FacetGrid (Type 1)
# 1. Despite the fact that,**Bug and Normal** have a high population as Type 1, have very high density in the population around **40-60 SPA**.
# 2. **Dragon** type, possess wide range of poppulation from the range of **40 SPA** to **180 SPA**
# 3. **Flying** type possess has only small population in the area of than **40 & 90 SPA**.
# 4. **Psychic** type has it own place almost every range, excep **135- 145 SPA**.
# 5. **Water** type population starts getting denser between the range of **55-100 SPA**

# %%
sns.displot(x="Sp_Atk", y="Type_1",data=df_1);

# %%
g = sns.FacetGrid(df_1, col="Type_1")
g.map(sns.histplot, "Sp_Atk");

# %% [markdown]
# ### Results form the Defense Distplot & FacetGrid (Type 2)
# 1. **Flying** as Type 2, has wide range of density in the population around **40-90 SPA**.
# 2. **Dragon** as Type 2, possess wide range of poppulation from the range of **40 SPA** to **180 SPA**
# 3. **Rock** as Type 2, possess no further than in the range after **90 SPA**.
# 4. Beside in the range of **40-49 and 60-69 SPA**, **Bug** as Type 2 has no other population.

# %%
sns.displot(x="Sp_Atk", y="Type_2",data=df_2);

# %%
g = sns.FacetGrid(df_1, col="Type_2")
g.map(sns.histplot, "Sp_Atk");

# %% [markdown]
# <a id='spd'></a>
# # 1.4 Special Defense - SPD
# ## Special Defense: the base damage resistance against special attacks
# Wiki - The Special Defense stat, partly determines how much damage a Pokémon receives when it is hit with a special move.

# %% [markdown]
# ### Top 10 Special Defenders (All Types)
# #### Ranking Special Defenders from every type and combinations with >130 SPD Stat
# ![1](https://lh3.googleusercontent.com/Ie0CWBcfCmJKN9GAqN5FNXWiPD2GEVzVmBfXtIY4vUWomR8F0PyEdASMM7uT4UTVnXZosZ6I6srLUWOBwnryn68MJIE_ahBkCGheUu12ZMkfEvv9w4sBQZDR53WjCUIZrTpPIDvvcw=w800)

# %%
df_1.sort_values(['Sp_Def'], ascending=False).head(10)

# %% [markdown]
# ### Results form the Special Defense Scatter Plot
# 1. Surprisingly *Shuckle* from the **Bug/Rock** type has the highest SPD.
# 2. Lugia from **Psychic/Flying**,and Ho-oh from **Fire/Flying** type comes in the 2nd place for the special defense stat.
# 3. **Flying/Dragon** possess low population and low SPD stat **80-95 SPD**
# 4. **Fighting** doesn't do good in SPD, even in combitation with other type like **Flying,Dark or Psychic**. Fighting seems to be a type that has low SPD
#
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
sns.scatterplot(data=df_1, x="Sp_Def", y="Type_1", hue="Type_2",style="Type_2", s=100);

# %% [markdown]
# ### Results form the Special Defense Distplot & FacetGrid (Type 1)
# 1. **Bug** type possess big population in the area between **50-90 SPD** (specially in 90 SPD).
# 2. **Fire, Rock, Psyhic, Dragon and Steel** have the peak at range of **150 SPD**.
# 3. **Water** type possess population in the areas of **60 & 100 SPD**
# 4. **Ghost** type has high density in population, particulary in **60 SPD**.
# 5. **Fairy** type only has a small population in the area **110-120 SPD**.
# 6. **Fighting** type possess also has only small population in the area of than **40 & 90 SPD**.

# %%
sns.displot(x="Sp_Def", y="Type_1",data=df_1);

# %%
g = sns.FacetGrid(df_1, col="Type_1")
g.map(sns.histplot, "Sp_Def");

# %% [markdown]
# ### Results form the Special Defense Distplot & FacetGrid (Type 2)
# 1. Beside *Shuckle* from the **Bug/Rock** that has the highest SPD at the peak of **230 SPD**, no other types have a SPD stat beyond **150 SPD**,and if we look closely again on the **Rock** type there no other Pokemons after **100 SPD** except *Shuckle*
# 2. **Flying** sames to have a large pool of population with no absence in every areas starting from **40-150 SPD**.<br>
# But, the density of population lies in **40 SPD** as 1st place, **90 SPD** as 2nd, and **60-80 SPD** as the 3rd place.
# 3. **Bug** type also has only small population in the area of **50-60 & 80 SPD**
# 4. **Flying, Fairy, Psyhic, Steel and Ghost** type have the peak of SPD at 150 **SPD**

# %%
sns.displot(x="Sp_Def", y="Type_2",data=df_2);

# %%
g = sns.FacetGrid(df_1, col="Type_2")
g.map(sns.histplot, "Sp_Def");

# %% [markdown]
# <a id='spe'></a>
# # 1.5 Speed - SPE
# ## Speed: determines which pokemon attacks first each round
#  Wiki - The Speed stat determines the order of Pokémon that can act in battle. If Pokémon are moving with the same priority, Pokémon with higher Speed at the start of any turn will generally make a move before ones with lower Speed; in the case that two Pokémon have the same Speed, one of them will randomly go first.

# %% [markdown]
# ### Top 10 Speedsters (All Types)
# #### Ranking Speedsters from every type and combinations with >130 SPD Stat
# ![1](https://lh3.googleusercontent.com/R0876cORDqA6vBMlKHfesG4evT9WWpkyJvG0lynuYfRm39dnj1C3_bRlgjnXHPdNZ56-2Y2wP23kA5qx-vfaCyv_-4E-AWT_4-q9tXNxBtN7b6G7PGzP5Wm1hag_Bju7ARJnq5UKyA=w800)

# %%
df_1.sort_values(['Speed'], ascending=False).head(10)

# %% [markdown]
# ### Results form the Speed Scatter Plot
# 1. *Ninjask* from the **Bug/Flying** type has the highest SPE. Second by **Aerodactyl (Mega)** from the **Rock/Flying** type
# 2. **Fairy/Flying** possess low population,only in the rage of **40 & 80 SPE**
# 3. **Flying/Dragon** also possess low population,only in the rage of **50 & 125 SPE**
#
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
sns.scatterplot(data=df_1, x="Speed", y="Type_1", hue="Type_2",style="Type_2", s=100);

# %% [markdown]
# ### Results form the Speed Distplot & FacetGrid (Type 1)
# 1. **Bug** type possess big population in the area between **50-90 SPE** (specially in 90 SPE).
# 2. **Fire, Rock, Psyhic, Dragon and Steel** have the peak at range of **150 SPE**.
# 3. **Water** type possess population in the areas of **60 & 100 SPE**
# 4. **Ghost** type has high density in population, particulary in **60 SPE**.
# 5. **Fairy** type only has a small population in the area **110-120 SPE**.
# 6. **Fighting** type possess also has only small population in the area of than **40 & 90 SPE**.

# %%
sns.displot(x="Speed", y="Type_1",data=df_1);

# %%
g = sns.FacetGrid(df_1, col="Type_1")
g.map(sns.histplot, "Speed");

# %% [markdown]
# ### Results form the Speed Distplot & FacetGrid (Type 2)
# 1. **Poison** type possess wide range of population in the area between **30-150 SPE**.
# 2. **Flying** as type 2,has high population starting from **50 SPE**, also has the peak at range of **75-115 SPE**.
# 3. **Rock** type possess no population in the areas of **60 SPE** onward.
# 4. **Flying** as type 2, also has a peak in **160 SPE**.
# 5. Beside **Flying** as type 2, other type like **Poison** and **Dragon** comes in the 2nd place at the peak of **150 SPE**.

# %%
sns.displot(x="Speed", y="Type_2",data=df_2);

# %%
g = sns.FacetGrid(df_1, col="Type_2")
g.map(sns.histplot, "Speed");

# %% [markdown]
# <a id='hp'></a>
# # 1.6 Hit Points - HP
# ### HP: hit points, or health, defines how much damage a pokemon can withstand before fainting
# Wiki - The HP determine how much damage a Pokémon can receive before fainting.

# %% [markdown]
# ### Top 10 Tankers (All Types)
# #### Ranking Tankers from every type and combinations with >125 HP Stat
# ![1](https://lh3.googleusercontent.com/jDf_O8HfIPAnlLvkKaEnRkwz_0DeogJIhcyp1t6xMmqFJblJvx0f77RUbgHf4_2HYb8ul-t-t_ZLwYqOMf0VhyD6Fl7bDbgpuY-Ja9uJbv7sUtLdDXObvSaiDTz0r6urYsuVqnzo2A=w800)

# %%
df_1.sort_values(['HP'], ascending=False).head(10)

# %% [markdown]
# ### Results form the Hit Points Scatter Plot
# 1. *Giratina (Altered)* from **Ghost/Dragon**, and Drifblim from **Ghost/Flying** has the highest HP at the peak of **150 HP**.<br>
# Second by *Wigglytuff* from the **Normal/Fairy** type in the range of **140 HP**
# 2. **Fairy/Flying** possess low population,only in the rage of **55 & 90 HP**
# 3. **Flying/Dragon** also possess low population,only in the rage of **40 & 90 HP**
#
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
sns.scatterplot(data=df_1, x="HP", y="Type_1", hue="Type_2",style="Type_2", s=100);

# %% [markdown]
# ### Results form the Hit Points Distplot & FacetGrid (Type 1)
# 1. **Water, Rock, Dragon and Dark** have the peak at range of **120 HP**.
# 2. **Water** type also possess high population in the areas of **90 HP**
# 3. **Bug** type has very high number in population, particulary in **60-70 HP**.
# 4. **Fairy** as Type 1 possess low population,only in the rage of **55 & 90 HP**
# 5. **Flying** as Type 1, as well, possess low population,only in the rage of **30 & 80 HP**

# %%
sns.displot(x="HP", y="Type_1",data=df_1);

# %%
g = sns.FacetGrid(df_1, col="Type_1")
g.map(sns.histplot, "HP");

# %% [markdown]
# ### Results form the Hit Points Distplot & FacetGrid (Type 2)
# 1. **Flying** as type 2,has high population starting from **35 HP**, also has the peak at range of **60-70 HP**.
# 2. **Flying and Dragon** have the peak at range of **120 HP**.
# 3. **Psychic** type also possess high population in the areas of **60-90 HP**.
# 4. **Bug** type has low number in population, in **30,40,75 HP**.
# 5. **Normal** as Type 1 possess low population,only in the rage of **40,60,80 HP**

# %%
sns.displot(x="HP", y="Type_2",data=df_2);

# %%
g = sns.FacetGrid(df_1, col="Type_2")
g.map(sns.histplot, "HP");

# %% [markdown]
# <a id='total'></a>
# # 1.7 Total Stats - Total
# ### Total: sum of all stats that come after this, a general guide to how strong a pokemon is
# *No Wiki data found

# %% [markdown]
# ### Top 10 Total (All Types)
# #### Ranking Total stats from every type and combinations of Pokemon with >700 Total Stat
# ![1](https://lh3.googleusercontent.com/uKAgyF7WZPx-iEQtR_h_lK4dAHsY_OXypBJnDoHzRC48mb_zTghH03A_gOCn_8DW2gw7Uzjb6v8NRyn8tzfZwPZ3oy-PXDS4Rkh9yB7XiNE5UwUPVMQHVKtcDOcoT9mU12LnIWjoyA=w800)

# %%
df_1.sort_values(['Total'], ascending=False).head(10)

# %% [markdown]
# ### Results form the Total Points Scatter Plot
# 1. *Rayquaza (Mega)* from **Dragon/Flying**, and *Mewtwo X (Mega)* from **Psychic/Fighting** has the highest Total at the peak of **780 Total**.<br>
# Second by *Groudon (Primal)* from the **Ground/Fire** type in the range of **770 Total**
# 2. **Normal/Flying** possess high population starts from the rage of **250 Total** all the way up to **500 HP**
# 3. **Grass/Poision** also possess high population,only in the rage of **300 & 400 Total**
#
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
sns.scatterplot(data=df_1, x="Total", y="Type_1", hue="Type_2",style="Type_2", s=100);

# %% [markdown]
# ### Results form the Total Points Distplot & FacetGrid (Type 1)
# 1. While **Ground, Psychic and Dragon** has the peakest range from every type,<br>
# but **Dragon** seems to possess a very strong population scatter across the ragne of **600-770 Total**
# 2. **Water** type also possess large pool of population in the areas of **500-550 Total**
# 3. **Grass** type seems to have the highest population in the range of **500 Total**
# 4. **Rock** and **Ghost** type have particulary high number in population in **500 Total**.
# 5. **Fairy** as Type 1 possess low population,only in the rage of **400, 550 Total**
# 6. **Flying** as Type 1, as well, possess high population,only in the rage of **250 & 550 Total**

# %%
sns.displot(x="Total", y="Type_1",data=df_1);

# %%
g = sns.FacetGrid(df_1, col="Type_1")
g.map(sns.histplot, "Total");

# %% [markdown]
# ### Results form the Total Points Distplot & FacetGrid (Type 2)
# 1. **Flying** as Type 2, possess large number of population starts the rage of **250 - 600 Total**
# 2. **Flying, Fire and Fighting** as Type 2, has the peakest range from **700 Total (up)**
# 3. **Grass, Steel, Dark and Rock** type also possess high number of population in the areas of **500 Total**
# 3. **Poison** type seems to have the majority of population in the range of **400 Total**
# 4. **Bug** and **Normal** type, have small number in population in **300, 350, 500 Total** and have no population in other areas.

# %%
sns.displot(x="Total", y="Type_2",data=df_2);

# %%
g = sns.FacetGrid(df_1, col="Type_2")
g.map(sns.histplot, "Total");

# %% [markdown]
# # 2. Type Analysis
# <a id='typ'></a>
# According to Bulbapedia.net,
# > There are 324 possible ways to assign types to Pokémon (18 single types and 18 * 17 dual types).
#
# From this point beyond,the type analysis will be using only **Type 1** or the **Main type** of Pokemon
#
# ## How many types are there in Pokémon?
# **18 Types consist of**
# <br>
# <img src="https://lh3.googleusercontent.com/TmPEzYj261z4Ye8BmnLOJfdtIrLt3xh6G_SlNDi_H9lizvAh5nGeV-LcZPmYSXPg0IN8qeT_fCw9Dq44op0SbHMGrWErdSw06rkmdPQ2zQNfplHtAB8DDTs6Vl3VHt7PqSZfT0fAHg=w2400" width="500">
# <br>
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
df_1.columns

# %%
def combtype():
    df_1['Type_3'] = df_1['Type_1'] + " - " + df_1['Type_2']
    return df_1['Type_3'].value_counts()
combtype()

# %% [markdown]
# <a id='tpa'></a>
# ## 2.1 Type Population Analysis
# ### Result
# * **Water** is the majority of type 1 with 14.0% of population<br>
# * **Ground, Ghost, and Dragon** have the same population numbers.<br>
# * **Flying** is the majority type as the type 2 with over 20% of population.<br>
# * While in type 1, **Normal** type is around 12.3% of the total population, but as a type 2, it only has 1.0%<br>
# * **Ground, Poison, Psychic** comes as the 2nd place in type 2.<br>
# * **Normal/Flying** type is the most common population for dual types.<br>
# * **Legendary** Pokemon is only 8.1% population of total Pokemon

# %%
# type_1
x = df_1["Type_1"].value_counts()
labels= list(x.index)
colors = ['aqua','limegreen','blue','fuchsia','gray','green',
         'lime','maroon','navy','olive','purple','red',
         'silver','teal','skyblue','yellow','coral','magenta']

# Create a pieplot
plt.pie(x,labels= labels,colors=colors, autopct= "%1.1f%%")

# add a circle & transform it into a donut chart
my_circle=plt.Circle( (0,0), 0.7, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title("Type 1 of Pokémons", fontsize=16)

plt.show()

# %%
sns.set_style("darkgrid")
sns.set(rc={'figure.figsize':(13.5,9)})

t1 = df_1["Type_1"].value_counts()
fig = sns.countplot(x = "Type_1", 
                    data = df_1,
                    color ="c",
                    order = df_1["Type_1"].value_counts().index);

plt.xlabel("Type of Pokémon")
plt.ylabel("Population of Pokémon in the Type")
plt.title("Type 1 of Pokémon")

for i in range(t1.shape[0]):
        fig.text(i, t1.values[i]+1, t1.values[i], horizontalalignment='center')

# plt.tight_layout() - like the look without this for some reasons 
plt.show(fig)

# %%
x = df_1["Type_2"].value_counts()
labels= list(x.index)
colors = ['aqua','limegreen','blue','fuchsia','gray','green',
         'lime','maroon','navy','olive','purple','red',
         'silver','teal','skyblue','yellow','coral','magenta']

# Create a pieplot
plt.pie(x,labels= labels,colors=colors, autopct= "%1.1f%%")

# add a circle & transform it into a donut chart
my_circle = plt.Circle( (0,0), 0.7, color='white')
p = plt.gcf()
p.gca().add_artist(my_circle)
plt.title("Type 2 of Pokémons", fontsize=16)

plt.show()

# %%
sns.set_style("darkgrid")
sns.set(rc={'figure.figsize':(13.5,9)})

t2 = df_1["Type_2"].value_counts()
fig = sns.countplot(x = "Type_2", 
                    data = df_1,
                    color ="tan",
                    order = df_1["Type_2"].value_counts().index);

plt.xlabel("Type of Pokémon")
plt.ylabel("Population of Pokémon in the Type")
plt.title("Type 2 of Pokémon")

for i in range(t2.shape[0]):
        fig.text(i, t2.values[i]+1, t2.values[i], horizontalalignment='center')
        
# plt.tight_layout() - like the look without this for some reasons     
plt.show(fig)

# %%
def stacked():
    t1 = df_1["Type_1"].value_counts()
    t2 = df_1["Type_2"].value_counts()
    
    fig,ax = plt.subplots(figsize=(13.5,9))
    ax.bar(t1.index,t1.values,color='c')
    ax.bar(t2.index,t2.values,color='tan')
    
    ax.set_xlabel('Types of Pokémon')
    ax.set_ylabel('Population of Pokémon in the Type')
    ax.set_title('Total Types of Pokémon')
    
    #plt.tight_layout()
stacked()

# %%
def dualtype():
    dltype = df_1['Type_3'].value_counts()[0:10]
    fig,ax = plt.subplots(figsize=(13.5,9))
    ax.bar(dltype.index,dltype.values,color='k')
    
    for i in range(dltype.shape[0]):
        ax.text(i, dltype.values[i]+1, dltype.values[i], verticalalignment='center')
        
    plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='12') 

    ax.set_xlabel('Top 10 Dual Types')
    ax.set_ylabel('Population in Dual Types')
    ax.set_title('Dual Types of Pokémon')
    #plt.tight_layout()
dualtype()

# %%
x = df_1.Legendary.value_counts()
labels=["Non-Legendary","Legendary"]
colors = ['darkslategray','gold']

plt.pie(x,labels= labels, colors=colors, autopct= "%1.1f%%")
plt.title("Legendary Population", fontsize=16)
plt.show()

# %% [markdown]
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %% [markdown]
# ## 2.2 Single Type Analysis

# %% [markdown]
# <a id='gra'></a>
# # Type 1: Grass
# **Grass is one of the three basic elemental types** along with Fire and Water,
# which constitute the three starter Pokémon. <br>
# This creates a simple triangle to explain the type concept easily to new players.
#
# **Grass is one of the weakest types statistically**, with 5 defensive weaknesses
# and 7 types that are resistant to Grass moves. <br>
# Furthermore, three type combos paired with Grass **have 7 weaknesses: Grass/Psychic, Grass/Ice, and Grass/Dark.**
# <br>
#
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
df_grass = df_1[df_1["Type_1"] == "Grass"]

# %%
fig = df_grass.iloc[:,[2,3,4,5,6,7,8,9,10]].hist(figsize=(13.5,9), 
                                                 xlabelsize=10, 
                                                 ylabelsize=10, 
                                                 color='limegreen', 
                                                 grid=True)
plt.tight_layout()

# %% [markdown]
# >

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/abomasnow"><img src="https://img.pokemondb.net/sprites/x-y/normal/abomasnow-mega.png" alt="Abomasnow"></a>
# <br>
# #### 1. Highest ATK = Abomasnow(Mega) [132 ATK]

# %%
# 1. Highest ATK = Abomasnow(Mega)
df_grass[df_grass['Attack'] == df_grass['Attack'].max()]

# %% [markdown]
# <br>
# <a href="http://pokemondb.net/pokedex/ferrothorn"><img src="https://img.pokemondb.net/sprites/x-y/normal/ferrothorn.png" alt="Ferrothorn"></a>
#
# #### 2. Highest DEF = Ferrothorn [131 DEF]

# %%
# 2. Highest DEF = Ferrothorn
df_grass[df_grass['Defense'] == df_grass['Defense'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/sceptile"><img src="https://img.pokemondb.net/sprites/omega-ruby-alpha-sapphire/dex/normal/sceptile-mega.png" alt="Sceptile"></a>
#
# #### 3. Highest SPA = Sceptile(Mega) [145 SPA]

# %%
# 3. Highest SPA = Sceptile(Mega)
df_grass[df_grass["Sp_Atk"] == df_grass["Sp_Atk"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/virizion"><img src="https://img.pokemondb.net/sprites/x-y/normal/virizion.png" alt="Virizion"></a>
# #### 4. Highest SPD = Virizion [129 SPD]

# %%
# 4. Highest SPE(Sp_Def) = Virizion
df_grass[df_grass["Sp_Def"] == df_grass["Sp_Def"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/sceptile"><img src="https://img.pokemondb.net/sprites/omega-ruby-alpha-sapphire/dex/normal/sceptile-mega.png" alt="Sceptile"></a>
# #### 5. Highest SPE = Sceptile(Mega) [145 SPE]

# %%
# 5. Highest SPD(Speed) = Sceptile(Mega)
df_grass[df_grass["Speed"] == df_grass["Speed"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/gogoat"><img src="https://img.pokemondb.net/sprites/x-y/normal/gogoat.png" alt="Gogoat"></a>
# #### 6. Highest HP = Gogoat [HP]

# %%
# 6. Highest HP = Gogoat
df_grass[df_grass["HP"] == df_grass["HP"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/sceptile"><img src="https://img.pokemondb.net/sprites/omega-ruby-alpha-sapphire/dex/normal/sceptile-mega.png" alt="Sceptile"></a>
#
# #### 7. Highest Total Stats = Sceptile(Mega) [630 Total]

# %%
# 7. Highest Total Stats = Sceptile(Mega) [630 Total]
df_grass[df_grass["Total"] == df_grass["Total"].max()]

# %% [markdown]
# <a id='fir'></a>
# # Type 2: Fire
# Fire is one of the three basic elemental types along with Water and Grass,
# which constitute the three starter Pokémon. <br>
# <br>
# This creates a simple triangle to explain the type concept easily to new players.<br>
# Fire types are notoriously rare in the early stages of the games,
# so choosing the Fire variation starter is often a plus.<br>
# <br>
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
df_fire = df_1[df_1["Type_1"] == "Fire"]

# %%
fig = df_fire.iloc[:,[2,3,4,5,6,7,8,9,10]].hist(figsize=(13.5,9), 
                                                 xlabelsize=10, 
                                                 ylabelsize=10, 
                                                 color='orangered', 
                                                 grid=True)
plt.tight_layout()

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/blaziken"><img src="https://img.pokemondb.net/sprites/omega-ruby-alpha-sapphire/dex/normal/blaziken-mega.png" alt="Blaziken"></a>
# #### 1. Highest ATK = Blaziken(Mega) [160 ATK]

# %%
df_fire[df_fire['Attack'] == df_fire['Attack'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/torkoal"><img src="https://img.pokemondb.net/sprites/x-y/shiny/torkoal.png" alt="Torkoal"></a>
# #### 2. Highest DEF = Torkoal [140 DEF]

# %%
df_fire[df_fire["Defense"] == df_fire["Defense"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/charizard"><img src="https://img.pokemondb.net/sprites/bank/normal/charizard-mega-y.png" alt="Charizard"></a>
# #### 3. Highest SPA = Charizard(Mega Y) [156 SPA]

# %%
df_fire[df_fire["Sp_Atk"] == df_fire["Sp_Atk"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/ho-oh"><img src="https://img.pokemondb.net/sprites/x-y/normal/ho-oh.png" alt="Ho-oh"></a>
# #### 4. Highest SPE = Ho-oh [154 SPE]

# %%
df_fire[df_fire["Sp_Def"] == df_fire["Sp_Def"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/talonflame"><img src="https://img.pokemondb.net/sprites/x-y/shiny/talonflame.png" alt="Talonflame"></a>
# #### 5. Highest SPD = Talonflame [126 SPD]

# %%
df_fire[df_fire["Speed"] == df_fire["Speed"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/entei"><img src="https://img.pokemondb.net/sprites/x-y/shiny/entei.png" alt="Entei"></a>
# #### 6. Highest HP = Entei [280 HP]

# %%
df_fire[df_fire["HP"] == df_fire["HP"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/ho-oh"><img src="https://img.pokemondb.net/sprites/x-y/normal/ho-oh.png" alt="Ho-oh"></a>
# #### 7. Highest Total = Ho-oh [680 Total]

# %%
df_fire[df_fire["Total"] == df_fire["Total"].max()]

# %% [markdown]
# <a id='wat'></a>
# # Type 3: Water
#
# Water is one of the three basic elemental types along with Fire and Grass,<br>
# which constitute the three starter Pokémon. <br>
# This creates a simple triangle to explain the type concept easily to new players.<br>
# Water is the most common type with over 100 Pokémon, <br>
# which are based on a wide variety of fish and other sea-dwelling creatures.<br>
# As of Generation 6, Water has been paired with every other type.<br>
# <br>
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
df_water = df_1[df_1["Type_1"] == "Water"]

# %%
fig = df_water.iloc[:,[2,3,4,5,6,7,8,9,10]].hist(figsize=(13.5,9), 
                                                 xlabelsize=10, 
                                                 ylabelsize=10, 
                                                 color='lightskyblue', 
                                                 grid=True)
plt.tight_layout()

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/gyarados"><img src="https://img.pokemondb.net/sprites/x-y/normal/gyarados-f.png" alt="Gyarados"></a>
# #### 1. Highest ATK = Gyarados(Mega) [155 ATK]

# %%
df_water[df_water['Attack'] == df_water['Attack'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/slowbro"><img src="https://img.pokemondb.net/sprites/bank/normal/slowbro-mega.png" alt="Slowbro"></a>
# #### 2.(1) Highest DEF = Slowbro(Mega) [180 DEF]
#
# <a href="http://pokemondb.net/pokedex/cloyster"><img src="https://img.pokemondb.net/sprites/x-y/shiny/cloyster.png" alt="Cloyster"></a>
# #### 2.(2) Highest DEF = Cloyster [180 DEF]

# %%
df_water[df_water['Defense'] == df_water['Defense'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/kyogre"><img src="https://img.pokemondb.net/sprites/bank/normal/kyogre-primal.png" alt="Kyogre"></a>
# #### 3. Highest SPA = Kyogre(Primal) [180 SPA]

# %%
df_water[df_water['Sp_Atk'] == df_water['Sp_Atk'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/kyogre"><img src="https://img.pokemondb.net/sprites/bank/normal/kyogre-primal.png" alt="Kyogre"></a>
# #### 4. Highest SPD = Kyogre(Primal) [160 SPD]

# %%
df_water[df_water['Sp_Def'] == df_water['Sp_Def'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/greninja"><img src="https://img.pokemondb.net/sprites/x-y/normal/greninja.png" alt="Greninja"></a>
# #### 5. Highest SPE = Greninja [122 SPE]

# %%
df_water[df_water['Speed'] == df_water['Speed'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/wailord"><img src="https://img.pokemondb.net/sprites/x-y/normal/wailord.png" alt="Wailord"></a>
# #### 6. Highest HP = Wailord [170 HP]

# %%
df_water[df_water['HP'] == df_water['HP'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/kyogre"><img src="https://img.pokemondb.net/sprites/bank/normal/kyogre-primal.png" alt="Kyogre"></a>
# #### 7. Highest Total = Kyogre(Primal) [770 Total]

# %%
df_water[df_water['Total'] == df_water['Total'].max()]

# %% [markdown]
# <a id='ele'></a>
# # Type 4: Electric
#
# There are relatively few Electric Pokémon; in fact only four were added in the third generation. <br>
# Most are based on rodents or inanimate objects.
#
# Electric Pokémon are very good defensively, being weak only to Ground moves. <br>
# Eelektross is the only Pokémon to have no type disadvantages due to its ability, Levitate. <br>
# <br>
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
df_elec = df_1[df_1["Type_1"] == "Electric"]

# %%
fig = df_elec.iloc[:,[2,3,4,5,6,7,8,9,10]].hist(figsize=(13.5,9), 
                                                 xlabelsize=10, 
                                                 ylabelsize=10, 
                                                 color='yellow', 
                                                 grid=True)
plt.tight_layout()

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/electivire"><img src="https://img.pokemondb.net/sprites/x-y/normal/electivire.png" alt="Electivire"></a>
# #### 1. Highest ATK = Electrivire [123 ATK]

# %%
df_elec[df_elec['Attack'] == df_elec['Attack'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/magnezone"><img src="https://img.pokemondb.net/sprites/x-y/normal/magnezone.png" alt="Magnezone"></a>
# #### 2. Highest DEF = Magnezone [115 DEF]

# %%
df_elec[df_elec['Defense'] == df_elec['Defense'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/ampharos"><img src="https://img.pokemondb.net/sprites/bank/normal/ampharos-mega.png" alt="Ampharos"></a>
# #### 3. Highest SPA = Ampharos(Mega)  [165 SPA]

# %%
df_elec[df_elec['Sp_Atk'] == df_elec['Sp_Atk'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/ampharos"><img src="https://img.pokemondb.net/sprites/bank/normal/ampharos-mega.png" alt="Ampharos"></a>
# #### 4. Highest SPD = Ampharos(Mega)  [165 SPD]

# %%
df_elec[df_elec['Sp_Def'] == df_elec['Sp_Def'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/electrode"><img src="https://img.pokemondb.net/sprites/x-y/normal/electrode.png" alt="Electrode"></a>
# #### 5. Highest SPE = Electrode  [140 SPE]

# %%
df_elec[df_elec['Speed'] == df_elec['Speed'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/zapdos"><img src="https://img.pokemondb.net/sprites/x-y/normal/zapdos.png" alt="Zapdos"></a>
# <a href="http://pokemondb.net/pokedex/raikou"><img src="https://img.pokemondb.net/sprites/x-y/normal/raikou.png" alt="Raikou"></a>
# <a href="http://pokemondb.net/pokedex/ampharos"><img src="https://img.pokemondb.net/sprites/bank/normal/ampharos.png" alt="Ampharos"></a>
# <a href="http://pokemondb.net/pokedex/ampharos"><img src="https://img.pokemondb.net/sprites/bank/normal/ampharos-mega.png" alt="Ampharos"></a>
# #### 6. Highest HP = [90 HP]
#    ##### 6.1 Zapdos
#    ##### 6.2 Raikou
#    ##### 6.3 Ampharos
#    ##### 6.4 Ampharos(Mega)
#    ##### [90 HP]

# %%
df_elec[df_elec['HP'] == df_elec['HP'].max()]

# %%
df_elec[df_elec['Total'] == df_elec['Total'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/ampharos"><img src="https://img.pokemondb.net/sprites/bank/normal/ampharos-mega.png" alt="Ampharos"></a>
# #### 7. Highest Total = Ampharos(Mega) [610 Total]

# %% [markdown]
# <a id='fly'></a>
# # Type 5: Flying
#
# Most Flying type Pokémon are based on birds or insects, along with some mythical creatures like dragons.<br>
# On average they are faster than any other type.<br>
# <br>
# Nearly every Flying type has Flying as the secondary type, usually with Normal.<br>
# There are only three pure Flying type Pokémon (Tornadus, Rookidee, Corvisquire), <br>
# and four Pokémon with Flying as a primary type (Noibat, Noivern, Corviknight, Cramorant). <br>
# As of Generation 6, the type has also been paired with every other type.<br>
# <br>
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
df_fly = df_1[df_1["Type_1"] == "Flying"]

# %%
fig = df_fly.iloc[:,[2,3,4,5,6,7,8,9,10]].hist(figsize=(13.5,9), 
                                                 xlabelsize=10, 
                                                 ylabelsize=10, 
                                                 color='darkseagreen', 
                                                 grid=True)
plt.tight_layout()

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/tornadus"><img src="https://img.pokemondb.net/sprites/x-y/normal/tornadus-incarnate.png" alt="Tornadus"></a>
# #### 1. Highest ATK = TornadusIncarnate [115 ATK]

# %%
df_fly[df_fly['Attack'] == df_fly['Attack'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/tornadus"><img src="https://img.pokemondb.net/sprites/bank/normal/tornadus-therian.png" alt="Tornadus"></a>
# <a href="http://pokemondb.net/pokedex/noivern"><img src="https://img.pokemondb.net/sprites/x-y/normal/noivern.png" alt="Noivern"></a>
# #### 2. Highest DEF = [80 DEF]
#    ##### 2.1 Tornadus(Incarnate)
#    ##### 2.2 Noivern
#    ##### [80 DEF]

# %%
df_fly[df_fly['Defense'] == df_fly['Defense'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/tornadus"><img src="https://img.pokemondb.net/sprites/x-y/normal/tornadus-incarnate.png" alt="Tornadus"></a>
# #### 3. Highest SPA = Tornadus(Incarnate) [125 SPA]

# %%
df_fly[df_fly['Sp_Atk'] == df_fly['Sp_Atk'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/tornadus"><img src="https://img.pokemondb.net/sprites/bank/normal/tornadus-therian.png" alt="Tornadus"></a>
# #### 4. Highest SPD = Tornadus(Therian) [90 SPD]

# %%
df_fly[df_fly['Sp_Def'] == df_fly['Sp_Def'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/noivern"><img src="https://img.pokemondb.net/sprites/x-y/normal/noivern.png" alt="Noivern"></a>
# #### 5. Highest SPE = Noivern [123 SPE]

# %%
df_fly[df_fly['Speed'] == df_fly['Speed'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/noivern"><img src="https://img.pokemondb.net/sprites/x-y/normal/noivern.png" alt="Noivern"></a>
# #### 6. Highest HP = Noivern [535 HP]

# %%
df_fly[df_fly['HP'] == df_fly['HP'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/tornadus"><img src="https://img.pokemondb.net/sprites/bank/normal/tornadus-therian.png" alt="Tornadus"></a>
# <a href="http://pokemondb.net/pokedex/tornadus"><img src="https://img.pokemondb.net/sprites/x-y/normal/tornadus-incarnate.png" alt="Tornadus"></a>
# #### 7. Highest Total =
#    ###### 7.1 Tornadus(Incarnate) [580 Total]
#    ###### 7.1 Tornadus(Therian) [580 Total]
#    ###### [580 Total]

# %%
df_fly[df_fly['Total'] == df_fly['Total'].max()]

# %% [markdown]
# <a id='bug'></a>
# # Type 6: Bug
#
# Most Bug Pokémon grow quickly and evolve sooner than other types. As a result, they are often very weak.<br>
# In Generation I, bugs were almost useless since the few Bug type moves available were very weak. <br>
# The situation improved in later games with better moves and an advantage against the Dark type.<br>
# <br>
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
df_bug = df_1[df_1["Type_1"] == "Bug"]

# %%
fig = df_bug.iloc[:,[2,3,4,5,6,7,8,9,10]].hist(figsize=(13.5,9), 
                                                 xlabelsize=10, 
                                                 ylabelsize=10, 
                                                 color='darkkhaki', 
                                                 grid=True)
plt.tight_layout()

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/heracross"><img src="https://img.pokemondb.net/sprites/bank/normal/heracross-mega.png" alt="Heracross"></a>
# #### 1. Highest ATK = Heracross(Mega) [185 ATK]

# %%
df_bug[df_bug['Attack'] == df_bug['Attack'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/shuckle"><img src="https://img.pokemondb.net/sprites/x-y/normal/shuckle.png" alt="Shuckle"></a>
# #### 2. Highest DEF = Shuckle [230 DEF]

# %%
df_bug[df_bug['Defense'] == df_bug['Defense'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/volcarona"><img src="https://img.pokemondb.net/sprites/x-y/normal/volcarona.png" alt="Volcarona"></a>
# #### 3. Highest SPA = Volcarona [135 SPA]

# %%
df_bug[df_bug['Sp_Atk'] == df_bug['Sp_Atk'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/shuckle"><img src="https://img.pokemondb.net/sprites/x-y/normal/shuckle.png" alt="Shuckle"></a>
# #### 4. Highest SPD = Shuckle [230 SPD]

# %%
df_bug[df_bug['Sp_Def'] == df_bug['Sp_Def'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/ninjask"><img src="https://img.pokemondb.net/sprites/x-y/normal/ninjask.png" alt="Ninjask"></a>
# #### 5. Highest SPE = Ninjask [160 SPE]

# %%
df_bug[df_bug['Speed'] == df_bug['Speed'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/yanmega"><img src="https://img.pokemondb.net/sprites/x-y/normal/yanmega.png" alt="Yanmega"></a>
# #### 6. Highest HP = Yanmega [86 HP]

# %%
df_bug[df_bug['HP'] == df_bug['HP'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/pinsir"><img src="https://img.pokemondb.net/sprites/omega-ruby-alpha-sapphire/dex/normal/pinsir-mega.png" alt="Pinsir"></a>
# <a href="http://pokemondb.net/pokedex/scizor"><img src="https://img.pokemondb.net/sprites/bank/normal/scizor-mega.png" alt="Scizor"></a>
# <a href="http://pokemondb.net/pokedex/heracross"><img src="https://img.pokemondb.net/sprites/ultra-sun-ultra-moon/normal/heracross-mega.png" alt="Heracross"></a>
# <a href="http://pokemondb.net/pokedex/genesect"><img src="https://img.pokemondb.net/sprites/x-y/normal/genesect.png" alt="Genesect"></a>
# #### 7. Highest Total =
#    ###### 7.1 Pinsir(Mega) [600 Total]
#    ###### 7.2 Scizor(Mega) [600 Total]
#    ###### 7.3 Heracross(Mega) [600 Total]
#    ###### 7.4 Genesect [600 Total]
#    ###### [600 Total]

# %%
df_bug[df_bug['Total'] == df_bug['Total'].max()]

# %% [markdown]
# <a id='roc'></a>
# # Type 7: Rock
# Rock is a solid type as one might expect. Like Steel, Rock Pokémon usually have high defense <br>
# However, since many Rock Pokémon are part Ground they have a 4x weakness to both <br>
# Grass and Water whose moves often come as Special type.<br>
# <br>
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
df_rock = df_1[df_1["Type_1"] == "Rock"]

# %%
fig = df_rock.iloc[:,[2,3,4,5,6,7,8,9,10]].hist(figsize=(13.5,9), 
                                                 xlabelsize=10, 
                                                 ylabelsize=10, 
                                                 color='saddlebrown', 
                                                 grid=True)
plt.tight_layout()

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/rampardos"><img src="https://img.pokemondb.net/sprites/x-y/normal/rampardos.png" alt="Rampardos"></a>
# #### 1. Highest ATK = Rampados [165 SPD]

# %%
df_rock[df_rock['Attack'] == df_rock['Attack'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/regirock"><img src="https://img.pokemondb.net/sprites/x-y/normal/regirock.png" alt="Regirock"></a>
# #### 2. Highest DEF = Regirock [200 DEF]

# %%
df_rock[df_rock['Defense'] == df_rock['Defense'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/diancie"><img src="https://img.pokemondb.net/sprites/bank/normal/diancie-mega.png" alt="Diancie"></a>
# #### 3. Highest SPA = Diancie(Mega) [160 SPA]

# %%
df_rock[df_rock['Sp_Atk'] == df_rock['Sp_Atk'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/probopass"><img src="https://img.pokemondb.net/sprites/x-y/normal/probopass.png" alt="Probopass"></a>
# <a href="http://pokemondb.net/pokedex/carbink"><img src="https://img.pokemondb.net/sprites/x-y/normal/carbink.png" alt="Carbink"></a>
# <a href="http://pokemondb.net/pokedex/diancie"><img src="https://img.pokemondb.net/sprites/bank/normal/diancie.png" alt="Diancie"></a>
# #### 4. Highest Total =
#    ###### 4.1 Probopass [150 SPD]
#    ###### 4.2 Carbink [150 SPD]
#    ###### 4.3 Diancie [150 SPD]
#    ###### [150 SPD]

# %%
df_rock[df_rock['Sp_Def'] == df_rock['Sp_Def'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/aerodactyl"><img src="https://img.pokemondb.net/sprites/x-y/normal/aerodactyl.png" alt="Aerodactyl"></a>
# #### 5. Highest SPE = Aerodactyl [150 SPE]

# %%
df_rock[df_rock['Speed'] == df_rock['Speed'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/aurorus"><img src="https://img.pokemondb.net/sprites/x-y/normal/aurorus.png" alt="Aurorus"></a>
# #### 6. Highest HP = Aurorus [123 HP]

# %%
df_rock[df_rock['HP'] == df_rock['HP'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/tyranitar"><img src="https://img.pokemondb.net/sprites/x-y/normal/tyranitar.png" alt="Tyranitar"></a>
# <a href="http://pokemondb.net/pokedex/diancie"><img src="https://img.pokemondb.net/sprites/bank/normal/diancie-mega.png" alt="Diancie"></a>
# #### 7. Highest Total =
#    ###### 7.1 Tyranitar(Mega) [700 Total]
#    ###### 7.2 Diancie(Mega) [700 Total]
#    ###### [700 Total]

# %%
df_rock[df_rock['Total'] == df_rock['Total'].max()]

# %% [markdown]
# <a id='fig'></a>
# # Type 8: Fighting
#
# Fighting Pokémon are strong and muscle-bound, often based on martial artists. <br>
# Fighting moves are super-effective against five other types (as is Ground),<br>
# making them very good offensively. <br>
# Most Fighting type moves are in the Physical category, for obvious reasons.<br>
# <br>
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
df_fig = df_1[df_1["Type_1"] == "Fighting"]

# %%
fig = df_fig.iloc[:,[2,3,4,5,6,7,8,9,10]].hist(figsize=(13.5,9), 
                                                 xlabelsize=10, 
                                                 ylabelsize=10, 
                                                 color='peru', 
                                                 grid=True)
plt.tight_layout()

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/lucario"><img src="https://img.pokemondb.net/sprites/bank/normal/lucario-mega.png" alt="Lucario"></a>
# #### 1. Highest ATK = Lucario(Mega) [145 ATK]

# %%
df_fig[df_fig['Attack'] == df_fig['Attack'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/hitmontop"><img src="https://img.pokemondb.net/sprites/x-y/normal/hitmontop.png" alt="Hitmontop"></a>
# <a href="http://pokemondb.net/pokedex/conkeldurr"><img src="https://img.pokemondb.net/sprites/x-y/normal/conkeldurr.png" alt="Conkeldurr"></a>
# #### 2. Highest DEF =
# ###### 2.1 Hitmontop [95 DEF]
# ###### 2.1 Conkeldurr [95 DEF]
# ###### [95 DEF]

# %%
df_fig[df_fig['Defense'] == df_fig['Defense'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/lucario"><img src="https://img.pokemondb.net/sprites/bank/normal/lucario-mega.png" alt="Lucario"></a>
# #### 3. Highest SPA = Lucario(Mega) [140 SPA]

# %%
df_fig[df_fig['Sp_Atk'] == df_fig['Sp_Atk'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/hitmonlee"><img src="https://img.pokemondb.net/sprites/bank/normal/hitmonlee.png" alt="Hitmonlee"></a>
# <a href="http://pokemondb.net/pokedex/hitmontop"><img src="https://img.pokemondb.net/sprites/x-y/normal/hitmontop.png" alt="Hitmontop"></a>
# <a href="http://pokemondb.net/pokedex/hitmonchan"><img src="https://img.pokemondb.net/sprites/bank/normal/hitmonchan.png" alt="Hitmonchan"></a>
# #### 4. Highest SPD =
# ###### 4.1 Hitmonlee [110 SPD]
# ###### 4.1 Hitmonchan [110 SPD]
# ###### 4.3 Hitmontop [110 SPD]
# ###### [110 SPD]

# %%
df_fig[df_fig['Sp_Def'] == df_fig['Sp_Def'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/hawlucha"><img src="https://img.pokemondb.net/sprites/x-y/normal/hawlucha.png" alt="Hawlucha"></a>
# #### 5. Highest SPE = Hawlucha [118 SPE]

# %%
df_fig[df_fig['Speed'] == df_fig['Speed'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/hariyama"><img src="https://img.pokemondb.net/sprites/x-y/normal/hariyama.png" alt="Hariyama"></a>
# #### 6. Highest HP = Hariyama [144 HP]

# %%
df_fig[df_fig['HP'] == df_fig['HP'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/lucario"><img src="https://img.pokemondb.net/sprites/bank/normal/lucario-mega.png" alt="Lucario"></a>
# #### 7. Highest Total = Lucario(Mega) [625 Total]

# %%
df_fig[df_fig['Total'] == df_fig['Total'].max()]

# %% [markdown]
# <a id='gro'></a>
# # Type 9: Ground
#
# Ground is one of the strongest types offensively: it is super-effective against five other types (as is Fighting) <br>
# and Earthquake is one of the strongest moves in the game with power and accuracy both 100. <br>
# Unfortunately, many Ground type Pokémon are dual Rock types, lumbering them with 4x Grass and Water disadvantages.<br>
# <br>
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
df_gro = df_1[df_1["Type_1"] == "Ground"]

# %%
fig = df_gro.iloc[:,[2,3,4,5,6,7,8,9,10]].hist(figsize=(13.5,9), 
                                                 xlabelsize=10, 
                                                 ylabelsize=10, 
                                                 color='darkolivegreen', 
                                                 grid=True)
plt.tight_layout()

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/groudon"><img src="https://img.pokemondb.net/sprites/bank/normal/groudon-primal.png" alt="Groudon"></a>
# #### 1. Highest ATK = Groudon(Primal) [180 ATK]

# %%
df_gro[df_gro['Attack'] == df_gro['Attack'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/groudon"><img src="https://img.pokemondb.net/sprites/bank/normal/groudon-primal.png" alt="Groudon"></a>
# #### 2. Highest DEF = Groudon(Primal) [160 DEF]

# %%
df_gro[df_gro['Defense'] == df_gro['Defense'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/groudon"><img src="https://img.pokemondb.net/sprites/bank/normal/groudon-primal.png" alt="Groudon"></a>
# #### 3. Highest SPA = Groudon(Primal) [150 SPA]

# %%
df_gro[df_gro['Sp_Atk'] == df_gro['Sp_Atk'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/claydol"><img src="https://img.pokemondb.net/sprites/x-y/normal/claydol.png" alt="Claydol"></a>
# #### 4. Highest SPD = Claydol [120 SPD]

# %%
df_gro[df_gro['Sp_Def'] == df_gro['Sp_Def'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/dugtrio"><img src="https://img.pokemondb.net/sprites/x-y/normal/dugtrio.png" alt="Dugtrio"></a>
# #### 5. Highest SPE = Dugtrio [120 SPE]

# %%
df_gro[df_gro['Speed'] == df_gro['Speed'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/rhyperior"><img src="https://img.pokemondb.net/sprites/x-y/normal/rhyperior-f.png" alt="Rhyperior"></a>
# #### 6. Highest HP = Rhyperior [115 HP]

# %%
df_gro[df_gro['HP'] == df_gro['HP'].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/groudon"><img src="https://img.pokemondb.net/sprites/bank/normal/groudon-primal.png" alt="Groudon"></a>
# #### 7. Highest Total = Groudon(Primal) [770 Total]

# %%
df_gro[df_gro['Total'] == df_gro['Total'].max()]

# %% [markdown]
# <a id='ice'></a>
# # Type 10: Ice
#
# Ice type Pokémon are now the rarest of all types: there are only around 60 in total <br>
# (depending on how you count alternate forms or mega evolutions). <br>
# They are ranked quite well defensively in terms of stats, <br>
# although multiple type weaknesses let them down.<br>
# Some are based on typical Arctic creatures like seals or yaks, while others are more mythical. <br>
# <br>
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
df_ice = df_1[df_1["Type_1"] == "Ice"]

# %%
fig = df_ice.iloc[:,[2,3,4,5,6,7,8,9,10]].hist(figsize=(13.5,9), 
                                                 xlabelsize=10, 
                                                 ylabelsize=10, 
                                                 color='cyan', 
                                                 grid=True)
plt.tight_layout()

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/mamoswine"><img src="https://img.pokemondb.net/sprites/x-y/normal/mamoswine-f.png" alt="Mamoswine"></a>
# #### 1. Highest ATK = Mamoswine [130 ATK]

# %%
df_ice[df_ice["Attack"] == df_ice["Attack"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/avalugg"><img src="https://img.pokemondb.net/sprites/x-y/normal/avalugg.png" alt="Avalugg"></a>
# #### 2. Highest DEF = Avalugg [184 DEF]

# %%
df_ice[df_ice["Defense"] == df_ice["Defense"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/glaceon"><img src="https://img.pokemondb.net/sprites/x-y/normal/glaceon.png" alt="Glaceon"></a>
# #### 3. Highest SPA = Glaceon [130 SPA]

# %%
df_ice[df_ice["Sp_Atk"] == df_ice["Sp_Atk"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/regice"><img src="https://img.pokemondb.net/sprites/x-y/normal/regice.png" alt="Regice"></a>
# #### 4. Highest SPD = Regice [200 SPD]

# %%
df_ice[df_ice["Sp_Def"] == df_ice["Sp_Def"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/froslass"><img src="https://img.pokemondb.net/sprites/x-y/normal/froslass.png" alt="Froslass"></a>
# #### 5. Highest SPE = Froslass [110 SPE]

# %%
df_ice[df_ice["Speed"] == df_ice["Speed"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/mamoswine"><img src="https://img.pokemondb.net/sprites/x-y/normal/mamoswine-f.png" alt="Mamoswine"></a>
# <a href="http://pokemondb.net/pokedex/walrein"><img src="https://img.pokemondb.net/sprites/x-y/normal/walrein.png" alt="Walrein"></a>
# #### 6. Highest HP =
# ###### 6.1 Walrein [110 HP]
# ###### 6.2 Mamoswine [110 HP]
# ###### [110 HP]

# %%
df_ice[df_ice["HP"] == df_ice["HP"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/articuno"><img src="https://img.pokemondb.net/sprites/x-y/normal/articuno.png" alt="Articuno"></a>
# <a href="http://pokemondb.net/pokedex/glalie"><img src="https://img.pokemondb.net/sprites/bank/normal/glalie-mega.png" alt="Glalie"></a>.
# <a href="http://pokemondb.net/pokedex/regice"><img src="https://img.pokemondb.net/sprites/x-y/normal/regice.png" alt="Regice"></a>.
# #### 7. Highest Total =
# ###### 7.1 Articuno [580 Total]
# ###### 7.2 Glalie(Mega) [580 Total]
# ###### 7.3 Regice [580 Total]
# ###### [580 Total]

# %%
df_ice[df_ice["Total"] == df_ice["Total"].max()]

# %% [markdown]
# <a id='psy'></a>
# # Type 11: Psychic
# The Psychic type has few outright strengths, however, it also has few weaknesses. <br>
# In the first generation it ended up being massively overpowered, <br>
# mainly due to a complete lack of powerful Bug moves, its only weakness. <br>
# Furthermore, a mistake in the game meant that Ghost-type moves had no effect on Psychic<br>
# (although this only affected the low-powered Lick). <br>
# Generation 2 rectified the situation with the addition of the Dark type along<br>
# with better Pokémon and moves of all types.<br>
# <br>
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
df_psy = df_1[df_1["Type_1"] == "Psychic"]

# %%
fig = df_psy.iloc[:,[2,3,4,5,6,7,8,9,10]].hist(figsize=(13.5,9), 
                                                 xlabelsize=10, 
                                                 ylabelsize=10, 
                                                 color='palevioletred', 
                                                 grid=True)
plt.tight_layout()

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/mewtwo"><img src="https://img.pokemondb.net/sprites/bank/normal/mewtwo-mega-x.png" alt="Mewtwo"></a>
# #### 1. Highest ATK = Mewtwo(Mega X) [190 ATK]

# %%
df_psy[df_psy["Attack"] == df_psy["Attack"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/deoxys"><img src="https://img.pokemondb.net/sprites/bank/normal/deoxys-defense.png" alt="Deoxys"></a>
# #### 2. Highest DEF = Deoxys(Defense Form) [160 DEF]

# %%
df_psy[df_psy["Defense"] == df_psy["Defense"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/mewtwo"><img src="https://img.pokemondb.net/sprites/bank/normal/mewtwo-mega-y.png" alt="Mewtwo"></a>
# #### 3. Highest SPA = Mewtwo(Mega Y) [194 SPA]

# %%
df_psy[df_psy["Sp_Atk"] == df_psy["Sp_Atk"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/deoxys"><img src="https://img.pokemondb.net/sprites/bank/normal/deoxys-defense.png" alt="Deoxys"></a>
# #### 4. Highest DEF = Deoxys(Defense Form) [160 SPD]

# %%
df_psy[df_psy["Sp_Def"] == df_psy["Sp_Def"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/deoxys"><img src="https://img.pokemondb.net/sprites/bank/normal/deoxys-speed.png" alt="Deoxys"></a>
# #### 5. Highest SPE = Deoxys(Speed Form) [180 SPE]

# %%
df_psy[df_psy["Speed"] == df_psy["Speed"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/wobbuffet"><img src="https://img.pokemondb.net/sprites/x-y/normal/wobbuffet-f.png" alt="Wobbuffet"></a>
# #### 6. Highest HP = Wobbuffet [190 HP]

# %%
df_psy[df_psy["HP"] == df_psy["HP"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/mewtwo"><img src="https://img.pokemondb.net/sprites/bank/normal/mewtwo-mega-x.png" alt="Mewtwo"></a>
# <a href="http://pokemondb.net/pokedex/mewtwo"><img src="https://img.pokemondb.net/sprites/bank/normal/mewtwo-mega-y.png" alt="Mewtwo"></a>
# #### 7. Highest Total =
# ###### 7.1 Mewtwo (Mega X) [780 Total]
# ###### 7.2 Mewtwo (Mega Y)  [780 Total]
# ###### [780 Total]

# %%
df_psy[df_psy["Total"] == df_psy["Total"].max()]

# %% [markdown]
# <a id='gho'></a>
# # Type 12: Ghost
#
# Ghosts are rare Pokémon, and the only type to have two immunities. <br>
# In total there are just 34 Ghost type Pokémon (not including Megas/Formes), slightly above Ice.<br>
# <br>
# In the first generation, Ghost moves has no effect on Psychic Pokémon, <br>
# however, it was later changed to be super-effective. <br>
# When paired with the Dark type it was the only type combination to have no weaknesses prior to Gen 6.<br>
# <br>
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
df_gho = df_1[df_1["Type_1"] == "Ghost"]

# %%
fig = df_gho.iloc[:,[2,3,4,5,6,7,8,9,10]].hist(figsize=(13.5,9), 
                                                 xlabelsize=10, 
                                                 ylabelsize=10, 
                                                 color='indigo', 
                                                 grid=True)
plt.tight_layout()

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/banette"><img src="https://img.pokemondb.net/sprites/bank/normal/banette-mega.png" alt="Banette"></a>
# #### 1. Highest ATK = Banette (Mega) [165 ATK]

# %%
df_gho[df_gho["Attack"] == df_gho["Attack"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/cofagrigus"><img src="https://img.pokemondb.net/sprites/x-y/normal/cofagrigus.png" alt="Cofagrigus"></a>
# #### 2. Highest DEF = Cofagrigus [145 DEF]

# %%
df_gho[df_gho["Defense"] == df_gho["Defense"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/gengar"><img src="https://img.pokemondb.net/sprites/bank/normal/gengar-mega.png" alt="Gengar"></a>
# #### 3. Highest SPA = Gengar(Mega) [170 SPA]

# %%
df_gho[df_gho["Sp_Atk"] == df_gho["Sp_Atk"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/dusknoir"><img src="https://img.pokemondb.net/sprites/bank/normal/dusknoir.png" alt="Dusknoir"></a>
# #### 4. Highest SPD = Dusknior [135 SPD]

# %%
df_gho[df_gho["Sp_Def"] == df_gho["Sp_Def"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/gengar"><img src="https://img.pokemondb.net/sprites/bank/normal/gengar-mega.png" alt="Gengar"></a>
# #### 5. Highest SPE = Gengar(Mega) [130 SPE]

# %%
df_gho[df_gho["Speed"] == df_gho["Speed"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/giratina"><img src="https://img.pokemondb.net/sprites/bank/normal/giratina-altered.png" alt="Giratina"></a>
# <a href="http://pokemondb.net/pokedex/giratina"><img src="https://img.pokemondb.net/sprites/bank/normal/giratina-origin.png" alt="Giratina"></a>
# #### 7. Highest HP =
# ##### 7.1 Giratina (Altered) [150 HP]
# ##### 7.2 Giratina (Origin) [150 HP]
# ##### [150 HP]

# %%
df_gho[df_gho["HP"] == df_gho["HP"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/giratina"><img src="https://img.pokemondb.net/sprites/bank/normal/giratina-altered.png" alt="Giratina"></a>
# <a href="http://pokemondb.net/pokedex/giratina"><img src="https://img.pokemondb.net/sprites/bank/normal/giratina-origin.png" alt="Giratina"></a>
# #### 7. Highest Total =
# ##### 7.1 Giratina (Altered) [680 Total]
# ##### 7.2 Giratina (Origin) [680 Total]
# ##### [680 Total]

# %%
df_gho[df_gho["Total"] == df_gho["Total"].max()]

# %% [markdown]
# <a id='nor'></a>
# # Type 13: Normal
#
# The Normal type is the most basic type of Pokémon. <br>
# They are very common and appear from the very first route you visit. <br>
# Most Normal Pokémon are single type, <br>
# but there is a large contingent having a second type of Flying.<br>
# Pokémon X/Y add several Normal dual-type Pokémon.<br>
# <br>
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
df_nor = df_1[df_1["Type_1"] == "Normal"]

# %%
fig = df_nor.iloc[:,[2,3,4,5,6,7,8,9,10]].hist(figsize=(13.5,9), 
                                                 xlabelsize=10, 
                                                 ylabelsize=10, 
                                                 color='silver', 
                                                 grid=True)
plt.tight_layout()

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/slaking"><img src="https://img.pokemondb.net/sprites/bank/normal/slaking.png" alt="Slaking"></a>
# <a href="http://pokemondb.net/pokedex/regigigas"><img src="https://img.pokemondb.net/sprites/x-y/normal/regigigas.png" alt="Regigigas"></a>
#
# #### 1. Highest ATK = 160 ATK
# ##### 1.1 Giratina (Altered) [160 ATK]
# ##### 1.2 Giratina (Origin) [160 ATK]
# ##### [160 ATK]

# %%
df_nor[df_nor["Attack"] == df_nor["Attack"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/audino"><img src="https://img.pokemondb.net/sprites/bank/normal/audino-mega.png" alt="Audino"></a>
# #### 2. Highest DEF = Audino (Mega) [126 DEF]

# %%
df_nor[df_nor["Defense"] == df_nor["Defense"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/pidgeot"><img src="https://img.pokemondb.net/sprites/bank/normal/pidgeot-mega.png" alt="Pidgeot"></a>
# <a href="http://pokemondb.net/pokedex/porygon-z"><img src="https://img.pokemondb.net/sprites/bank/normal/porygon-z.png" alt="Porygon-Z"></a>
# #### 3. Highest ATK = 135 SPA
# ##### 3.1 Giratina (Altered) [135 SPA]
# ##### 3.2 Giratina (Origin) [135 SPA]
# ##### [135 SPA]

# %%
df_nor[df_nor["Sp_Atk"] == df_nor["Sp_Atk"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/blissey"><img src="https://img.pokemondb.net/sprites/bank/normal/blissey.png" alt="Blissey"></a>
# #### 4. Highest SPD = Blissey [135 SPD]

# %%
df_nor[df_nor["Sp_Def"] == df_nor["Sp_Def"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/lopunny"><img src="https://img.pokemondb.net/sprites/bank/normal/lopunny-mega.png" alt="Lopunny"></a>
# #### 5. Highest Speed = Lopunny (Mega) [135 SPD]

# %%
df_nor[df_nor["Speed"] == df_nor["Speed"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/blissey"><img src="https://img.pokemondb.net/sprites/bank/normal/blissey.png" alt="Blissey"></a>
# #### 6. Highest HP = Blissey [255 HP]

# %%
df_nor[df_nor["HP"] == df_nor["HP"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/arceus"><img src="https://img.pokemondb.net/sprites/x-y/normal/arceus-normal.png" alt="Arceus"></a>
# #### 7. Highest Total = Arceus [720 Total]

# %%
df_nor[df_nor["Total"] == df_nor["Total"].max()]

# %% [markdown]
# <a id='dra'></a>
# # Type 14: Dragon
#
# Dragons are among the most elusive and powerful of all Pokémon. <br>
# Nine legendary Pokémon are part Dragon type and four have legendary-like stats.<br>
# <br>
# They are notoriously difficult to train due to requiring more EXP points per level<br>
# than most non-legendary Pokémon, and the fact they evolve much later <br>
# and thus are in their weaker forms for longer. <br>
# Interestingly, many final-evolution Dragon types have a 4x weakness to the Ice type.<br>
# <br>
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
df_dra = df_1[df_1["Type_1"] == "Dragon"]

# %%
fig = df_dra.iloc[:,[2,3,4,5,6,7,8,9,10]].hist(figsize=(13.5,9), 
                                                 xlabelsize=10, 
                                                 ylabelsize=10, 
                                                 color='gold', 
                                                 grid=True)
plt.tight_layout()

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/rayquaza"><img src="https://img.pokemondb.net/sprites/bank/normal/rayquaza-mega.png" alt="Rayquaza"></a>
# #### 1. Highest ATK = Rayquaza(Mega) [180 ATK]

# %%
df_dra[df_dra["Attack"] == df_dra["Attack"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/salamence"><img src="https://img.pokemondb.net/sprites/bank/normal/salamence-mega.png" alt="Salamence"></a>
# #### 2. Highest DEF = Salamence(Mega) [130 DEF]

# %%
df_dra[df_dra["Defense"] == df_dra["Defense"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/rayquaza"><img src="https://img.pokemondb.net/sprites/bank/normal/rayquaza-mega.png" alt="Rayquaza"></a>
# #### 3. Highest SPA = Rayquaza(Mega) [180 SPA]

# %%
df_dra[df_dra["Sp_Atk"] == df_dra["Sp_Atk"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/latias"><img src="https://img.pokemondb.net/sprites/bank/normal/latias-mega.png" alt="Latias"></a>
# <a href="http://pokemondb.net/pokedex/goodra"><img src="https://img.pokemondb.net/sprites/x-y/normal/goodra.png" alt="Goodra"></a>
# #### 4. Highest ATK = 135 SPD
# ##### 4.1 Latias (Mega) [150 SPD]
# ##### 4.2 Giratina [150 SPD]
# ##### [150 SPD]

# %%
df_dra[df_dra["Sp_Def"] == df_dra["Sp_Def"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/salamence"><img src="https://img.pokemondb.net/sprites/bank/normal/salamence-mega.png" alt="Salamence"></a>
# #### 5. Highest SPE = Salamence(Mega) [120 SPE]

# %%
df_dra[df_dra["Speed"] == df_dra["Speed"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/kyurem"><img src="https://img.pokemondb.net/sprites/bank/normal/kyurem.png" alt="Kyurem"></a>
# <a href="http://pokemondb.net/pokedex/kyurem"><img src="https://img.pokemondb.net/sprites/bank/normal/kyurem-black.png" alt="Kyurem"></a>
# <a href="http://pokemondb.net/pokedex/kyurem"><img src="https://img.pokemondb.net/sprites/bank/normal/kyurem-white.png" alt="Kyurem"></a>
# #### 6. Highest ATK = 700 HP
# ##### 6.1 Kyurem (Black) [700 HP]
# ##### 6.2 Kyurem (White) [700 HP]
# ##### [700 HP]

# %%
df_dra[df_dra["HP"] == df_dra["HP"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/rayquaza"><img src="https://img.pokemondb.net/sprites/bank/normal/rayquaza-mega.png" alt="Rayquaza"></a>
# #### 7. Highest Total = Rayquaza(Mega) [780 Total]

# %%
df_dra[df_dra["Total"] == df_dra["Total"].max()]

# %% [markdown]
# <a id='ste'></a>
# # Type 15: Steel
#
# The Steel type was introduced in the second generation of Pokémon games. <br>
# It is the strongest type defensively, with 10 types being not very effective <br>
# against it and the Poison type having no effect. <br>
# those types now dealing neutral damage. <br>
# The Steel type also has the highest average Defense stat in the games.<br>
# <br>
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
df_stl = df_1[df_1["Type_1"] == "Steel"]

# %%
fig = df_stl.iloc[:,[2,3,4,5,6,7,8,9,10]].hist(figsize=(13.5,9), 
                                                 xlabelsize=10, 
                                                 ylabelsize=10, 
                                                 color='darkgray', 
                                                 grid=True)
plt.tight_layout()

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/aegislash"><img src="https://img.pokemondb.net/sprites/x-y/normal/aegislash-blade.png" alt="Aegislash"></a>
# #### 1. Highest ATK = Salamence(Mega) [150 ATK]

# %%
df_stl[df_stl["Attack"] == df_stl["Attack"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/steelix"><img src="https://img.pokemondb.net/sprites/bank/normal/steelix-mega.png" alt="Steelix"></a>
# <a href="http://pokemondb.net/pokedex/aggron"><img src="https://img.pokemondb.net/sprites/bank/normal/aggron-mega.png" alt="Aggron"></a>
# #### 2. Highest DEF = 230 DEF
# ##### 2.1 Steelix (Mega) [230 DEF]
# ##### 2.2 Aggron (Mega) [230 DEF]
# ##### [230 DEF]

# %%
df_stl[df_stl["Defense"] == df_stl["Defense"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/dialga"><img src="https://img.pokemondb.net/sprites/bank/normal/dialga.png" alt="Dialga"></a>
# <a href="http://pokemondb.net/pokedex/aegislash"><img src="https://img.pokemondb.net/sprites/x-y/normal/aegislash-blade.png" alt="Aegislash"></a>
# #### 3. Highest SPA = 150 SPA
# ##### 3.1 Dialga [150 SPA]
# ##### 3.2 Aegislash (Blade Forme) [150 SPA]
# ##### [150 SPA]

# %%
df_stl[df_stl["Sp_Atk"] == df_stl["Sp_Atk"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/registeel"><img src="https://img.pokemondb.net/sprites/x-y/normal/registeel.png" alt="Registeel"></a>
# <a href="http://pokemondb.net/pokedex/aegislash"><img src="https://img.pokemondb.net/sprites/x-y/normal/aegislash-shield.png" alt="Aegislash"></a>
# #### 4. Highest SPD = 150 SPD
# ##### 4.1 Registeel [150 SPD]
# ##### 4.2 Aegislash (Shield Forme) [150 SPD]
# ##### [150 SPD]

# %%
df_stl[df_stl["Sp_Def"] == df_stl["Sp_Def"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/metagross"><img src="https://img.pokemondb.net/sprites/omega-ruby-alpha-sapphire/dex/normal/metagross-mega.png" alt="Metagross"></a>
# #### 5. Highest SPE = Metagross(Mega) [110 SPE]

# %%
df_stl[df_stl["Speed"] == df_stl["Speed"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/jirachi"><img src="https://img.pokemondb.net/sprites/x-y/normal/jirachi.png" alt="Jirachi"></a>
# <a href="http://pokemondb.net/pokedex/dialga"><img src="https://img.pokemondb.net/sprites/bank/normal/dialga.png" alt="Dialga"></a>
# #### 6. Highest HP = [600 HP]
# ##### 6.1 Jirachi [600 HP]
# ##### 6.2 Aegislash (Blade Forme) [600 HP]
# ##### [600 HP]

# %%
df_stl[df_stl["HP"] == df_stl["HP"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/metagross"><img src="https://img.pokemondb.net/sprites/omega-ruby-alpha-sapphire/dex/normal/metagross-mega.png" alt="Metagross"></a>
# #### 7. Highest Total = Metagross(Mega) [700 Total]

# %%
df_stl[df_stl["Total"] == df_stl["Total"].max()]

# %% [markdown]
# <a id='poi'></a>
# # Type 16: Poison
#
# The Poison type is regarded as one of the weakest offensively.<br>
# (many of which are dual Poison so neutralizes the effect). <br>
#
# It now has an extra advantage against the new Fairy type. <br>
# In the first generation it was also super-effective against Bug but this was changed. <br>
# It fares a little better defensively but its best advantage is through status moves like Toxic.<br>
# <br>
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
df_poi = df_1[df_1["Type_1"] == "Poison"]

# %%
fig = df_poi.iloc[:,[2,3,4,5,6,7,8,9,10]].hist(figsize=(13.5,9), 
                                                 xlabelsize=10, 
                                                 ylabelsize=10, 
                                                 color='mediumorchid', 
                                                 grid=True)
plt.tight_layout()

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/toxicroak"><img src="https://img.pokemondb.net/sprites/x-y/normal/toxicroak-f.png" alt="Toxicroak"></a>
# #### 1. Highest ATK = Toxicroak [106 ATK]

# %%
df_poi[df_poi["Attack"] == df_poi["Attack"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/weezing"><img src="https://img.pokemondb.net/sprites/x-y/normal/weezing.png" alt="Weezing"></a>
# #### 2. Highest DEF = Weezing [120 DEF]

# %%
df_poi[df_poi["Defense"] == df_poi["Defense"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/seviper"><img src="https://img.pokemondb.net/sprites/x-y/normal/seviper.png" alt="Seviper"></a>
# #### 3. Highest SPA = Seviper [100 SPA]

# %%
df_poi[df_poi["Sp_Atk"] == df_poi["Sp_Atk"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/dragalge"><img src="https://img.pokemondb.net/sprites/x-y/normal/dragalge.png" alt="Dragalge"></a>
# #### 4. Highest SPD = Dragalge [123 SPD]

# %%
df_poi[df_poi["Sp_Def"] == df_poi["Sp_Def"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/crobat"><img src="https://img.pokemondb.net/sprites/bank/normal/crobat.png" alt="Crobat"></a>
# #### 5. Highest SPE = Crobat [130 SPE]

# %%
df_poi[df_poi["Speed"] == df_poi["Speed"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/muk"><img src="https://img.pokemondb.net/sprites/x-y/normal/muk.png" alt="Muk"></a>
# #### 6. Highest HP = Muk [500 HP]

# %%
df_poi[df_poi["HP"] == df_poi["HP"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/crobat"><img src="https://img.pokemondb.net/sprites/bank/normal/crobat.png" alt="Crobat"></a>
# #### 7. Highest Total = Crobat [535 Total]

# %%
df_poi[df_poi["Total"] == df_poi["Total"].max()]

# %% [markdown]
# <a id='dark'></a>
# # Type 17: Dark
# The Dark type was introduced in the second generation of Pokémon games as a measure to balance the types.<br>
# In particular, its resistance to Psychic cut down that type's advantage by a long way. <br>
# When paired with the Ghost type it was the only type combination to have no weaknesses prior to Gen 6.<br>
# <br>
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
df_dark = df_1[df_1["Type_1"] == "Dark"]

# %%
fig = df_dark.iloc[:,[2,3,4,5,6,7,8,9,10]].hist(figsize=(13.5,9), 
                                                 xlabelsize=10, 
                                                 ylabelsize=10, 
                                                 color='darkmagenta', 
                                                 grid=True)
plt.tight_layout()

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/absol"><img src="https://img.pokemondb.net/sprites/bank/normal/absol-mega.png" alt="Absol"></a>
# #### 1. Highest ATK = Absol(Mega) [150 ATK]

# %%
df_dark[df_dark["Attack"] == df_dark["Attack"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/sableye"><img src="https://img.pokemondb.net/sprites/bank/normal/sableye-mega.png" alt="Sableye"></a>
# #### 2. Highest DEF = Sableye(Mega) [680 DEF]

# %%
df_dark[df_dark["Defense"] == df_dark["Defense"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/houndoom"><img src="https://img.pokemondb.net/sprites/bank/normal/houndoom-mega.png" alt="Houndoom"></a>
# #### 3. Highest SPA = Houndoom(Mega) [140 SPA]

# %%
df_dark[df_dark["Sp_Atk"] == df_dark["Sp_Atk"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/umbreon"><img src="https://img.pokemondb.net/sprites/bank/normal/umbreon.png" alt="Umbreon"></a>
# #### 4. Highest SPD = Umbreon [130 SPD]

# %%
df_dark[df_dark["Sp_Def"] == df_dark["Sp_Def"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/weavile"><img src="https://img.pokemondb.net/sprites/bank/normal/weavile.png" alt="Weavile"></a>
# <a href="http://pokemondb.net/pokedex/darkrai"><img src="https://img.pokemondb.net/sprites/x-y/normal/darkrai.png" alt="Darkrai"></a>
# #### 5. Highest Speed = 125 SPE
# ##### 5.1 Weavile [125 SPE]
# ##### 5.2 Darkrai [125 SPE]
# ##### [125 SPE]

# %%
df_dark[df_dark["Speed"] == df_dark["Speed"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/yveltal"><img src="https://img.pokemondb.net/sprites/bank/normal/yveltal.png" alt="Yveltal"></a>
# #### 6. Highest HP = Yvestal [126 HP]

# %%
df_dark[df_dark["HP"] == df_dark["HP"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/yveltal"><img src="https://img.pokemondb.net/sprites/bank/normal/yveltal.png" alt="Yveltal"></a>
# #### 7. Highest Total = Yvestal [680 Total]

# %%
df_dark[df_dark["Total"] == df_dark["Total"].max()]

# %% [markdown]
# <a id='fai'></a>
# # Type 18: Fairy
# The Fairy type was introduced in Generation 6 - the first new type for more than 12 years! <br>
# Its main intention was to balance the type chart by reducing the power of dragons, <br>
# while also giving an offensive boost to the Poison and Steel types. <br>
# Several old Pokémon were retyped and new Pokémon introduced.<br>
# There are only around 60 Fairy type Pokémon <br>
# (depending on how you count alternate forms or mega evolutions), in total slightly above Ice.<br>
# <br>
# <a style="font-weight:bold" href='#toc'>Back to Table of Content</a>

# %%
df_fai = df_1[df_1["Type_1"] == "Fairy"]

# %%
fig = df_fai.iloc[:,[2,3,4,5,6,7,8,9,10]].hist(figsize=(13.5,9), 
                                                 xlabelsize=10, 
                                                 ylabelsize=10, 
                                                 color='plum', 
                                                 grid=True)
plt.tight_layout()

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/xerneas"><img src="https://img.pokemondb.net/sprites/bank/normal/xerneas.png" alt="Xerneas"></a>
# #### 1. Highest ATK = Xerneas [131 ATK]

# %%
df_fai[df_fai["Attack"] == df_fai["Attack"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/togekiss"><img src="https://img.pokemondb.net/sprites/x-y/normal/togekiss.png" alt="Togekiss"></a>
# <a href="http://pokemondb.net/pokedex/xerneas"><img src="https://img.pokemondb.net/sprites/bank/normal/xerneas.png" alt="Xerneas"></a>
# #### 2. Highest DEF = 95 DEF
# ##### 2.1 Togekiss [95 DEF]
# ##### 2.2 Xerneas [95 DEF]
# ##### [95 DEF]

# %%
df_fai[df_fai["Defense"] == df_fai["Defense"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/xerneas"><img src="https://img.pokemondb.net/sprites/bank/normal/xerneas.png" alt="Xerneas"></a>
# #### 3. Highest SPA = Xerneas [131 SPA]

# %%
df_fai[df_fai["Sp_Atk"] == df_fai["Sp_Atk"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/florges"><img src="https://img.pokemondb.net/sprites/x-y/normal/florges-red.png" alt="Florges"></a>
# #### 4. Highest SPD = Florges [154 SPD]

# %%
df_fai[df_fai["Sp_Def"] == df_fai["Sp_Def"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/xerneas"><img src="https://img.pokemondb.net/sprites/bank/normal/xerneas.png" alt="Xerneas"></a>
# #### 5. Highest SPE = Xerneas [99 SPE]

# %%
df_fai[df_fai["Speed"] == df_fai["Speed"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/xerneas"><img src="https://img.pokemondb.net/sprites/bank/normal/xerneas.png" alt="Xerneas"></a>
# #### 6. Highest HP = Xerneas [680 HP]

# %%
df_fai[df_fai["HP"] == df_fai["HP"].max()]

# %% [markdown]
# <a href="http://pokemondb.net/pokedex/xerneas"><img src="https://img.pokemondb.net/sprites/bank/normal/xerneas.png" alt="Xerneas"></a>
# #### 7. Highest Total = Xerneas [680 Total]

# %%
df_fai[df_fai["Total"] == df_fai["Total"].max()]
