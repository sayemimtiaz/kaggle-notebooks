# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
anime=pd.read_csv('../input/anime-dataset/anime.csv')
anime

# %%
anime.isnull().sum().sort_values(ascending=False)

# %%
anime=anime['title','description']

# %%
anime=anime[['title','description']]

# %%
anime.description[0]

# %%
import spacy
import en_core_web_sm
nlp = en_core_web_sm.load()
import time

# %%
def get_vec(x):
  doc = nlp(x)
  return doc.vector

# %%
get_vec(anime.description[0])

# %%
new_dataset=pd.DataFrame()

# %%
# %%time
new_dataset['vec'] = anime[anime['description'].notnull()]['description'].apply(lambda x: get_vec(x))

# %%
new_dataset['title']=anime['title']
new_dataset=new_dataset.drop(['title'],axis=1)

# %%
new_dataset.insert(0,'title',anime['title'])

# %%
new_dataset

# %%
XX = new_dataset['vec'].to_numpy()
XX = XX.reshape(-1,1)

# %%
np.array(new_dataset['vec']).reshape(-1,1)

# %%
xx=np.concatenate(np.concatenate(np.array(new_dataset['vec']).reshape(-1,1),axis = 0),axis = 0).reshape(-1,96)

# %%
xx.shape

# %%
df = pd.DataFrame(data = xx)
df.insert(0,'title',new_dataset['title'])

# %%
df

# %%
from sklearn.manifold import TSNE

# %%
ts=TSNE()
x=ts.fit_transform(df.loc[:, df.columns != 'title'])

# %%
fi=pd.DataFrame(data=x)
fi['title']=new_dataset['title']

# %%
fi.columns = ['x','y','title']
fi

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
# cs=fi.drop(['title'],axis=1)
np.array(cs.iloc[0]).reshape(-1,1)

# %%
from gensim.matutils import softcossim

# %%
cosine_similarity(cs.x,cs.y)

# %%
def cos(x,y):
    cs=x*y/(np.sqrt(sum((x*x)))*sum((y*y)))
    return cs

# %%
cos_sim=pd.DataFrame(data=cos(cs.x,cs.y),columns=['cosin_sim'])

# %%
cos_sim.insert(0,'title',new_dataset['title'])

# %%
cos_sim=cos_sim.sort_values(by='cosin_sim')

# %%
sns.lineplot(x='title',y='cosin_sim',data=cos_sim.sort_values(by='cosin_sim'))

# %%
idx = cos_sim.index.get_loc('')
cos_sim.iloc[idx - 10 : idx + 10]

# %%
idx=cos_sim[cos_sim.title=='Schwarzesmarken'].index.values
# idx=np.concatenate(idx,axis=0);
idx.astype(int)

# %%
cos_sim.iloc[5494 - 5 : 5494 + 5]
