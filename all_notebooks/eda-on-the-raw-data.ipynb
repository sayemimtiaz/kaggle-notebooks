# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns


import os
for dirname, _, filenames in os.walk('/kaggle/input/used-car-prices-in-pakistan-2021/Used_car_prices_in_Pakistan 2021_rawD.csv'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
data = pd.read_csv('/kaggle/input/used-car-prices-in-pakistan-2021/Used_car_prices_in_Pakistan 2021_rawD.csv')

# %%
data.head()

# %%
data.shape

# %%
data.isnull().sum()

# %%
noNullData = data.dropna()

# %%
noNullData.isnull().sum()

# %%
noNullData.shape

# %%
data.shape

# %%
noNullData.describe()

# %%
#Make of Car
print(noNullData.Make.unique())

# %%
#Version of Car
# print(noNullData['Version'].unique())
Version = noNullData.Version.unique()
pd.DataFrame(Version)

# %%
noNullData.shape

# %%
cleanTwo = noNullData[noNullData.Price != 'Call for price' ]
cleanTwo[cleanTwo['Price']=='Call for price'].sum()

# %%
cleanTwo.shape

# %%
cleanTwo[cleanTwo['Price']=='Call for price'].sum()

# %%
cleanTwo

# %%
cleanTwo.dtypes

# %%
cleanTwoPrice=cleanTwo['Price'].astype(float)
cleanTwoPrice.shape
cleanTwoPrice.describe()

# %%
cleanTwo.describe()

# %%
df = []
df = pd.DataFrame(cleanTwo)

# %%
df.head()

# %%
df.pop("Price")

# %%
price = np.asarray(cleanTwoPrice)

# %%
price

# %%
df.head()

# %%
df.insert(3,"Price",price,allow_duplicates=True)

# %%
df

# %%
df.dtypes

# %%
df.columns

# %%
df.describe()

# %%
df['Make'].unique()

# %%
df['Version'].unique()

# %%
df['Price'].hist(bins=200)

# %%
print(df.boxplot(column='Price'))

# %%
sns.countplot(df.Price)

# %%
sns.countplot(df.Make_Year)

# %%
df.to_csv("Used_car_prices_in_Pakistan_cleaned.csv",index=False)
# ./Used_car_prices_in_Pakistan_cleaned.csv
