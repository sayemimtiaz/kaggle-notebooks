# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# Importing the pandas library here and reading the file path with generation of some of the columns

# %%
import pandas as pd
malaria_file_path='../input/malaria-dataset/estimated_numbers.csv'
malaria_data=pd.read_csv(malaria_file_path)
malaria_data.columns

# %%
df = pd.read_csv('../input/malaria-dataset/estimated_numbers.csv', index_col=['Country'])

# %%
df.head(3)

# %% [markdown]
# Indexing single rows

# %%
df.iloc[5]

# %%
df.loc['India']

# %% [markdown]
# Indexing Multiple Rows

# %%
df.loc[['Argentina','Brazil','Costa Rica']]

# %% [markdown]
# **DOUBT**
# Sir why if using iloc, its showing just single data and through loc its showing the data for all years.

# %%
df.iloc[[3,12,24]]

# %% [markdown]
# Slicing

# %%
df[:9]

# %%
df[15:21]

# %% [markdown]
# Indexing Columns

# %%
df['WHO Region'].head(11)

# %%
df.who_region.head(11)

# %%
df.columns = [col.replace(' ', '_').lower() for col in df.columns]
print(df.columns)

# %% [markdown]
# Indexing Columns and Rows

# %%
df[['year', 'who_region']][:7]

# %% [markdown]
# Indexing Scalar Values

# %%
df.who_region.iloc[5]

# %%
df.who_region.iloc[[5]]

# %% [markdown]
# Selecting a subset of the data

# %%
(df.who_region == 'UT').head(5)

# %%
df[df.who_region == 'UT']

# %%
df[(df.year > 2016) | (df.no._of_cases > 10)].head(3)

# %% [markdown]
# **DOUBT**
# Not getting the answer.

# %%
df[df['who_region'].str.split().apply(lambda x: len(x) == 3)].head(3)

# %% [markdown]
# Didn't understood the output at 32 line

# %%
df[df.who_region.isin(['Argentina', 'India', 'Brazil'])].head()
