# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.

# %% [markdown]
# First of all we must read the data we have.

# %%
data = pd.read_csv('../input/2015ddd/2015d.csv')

# %%
data.info()

# %% [markdown]
# We can see the informations in data with data.info(). It shows us entries,columns,types of columns and whether they are non-null or not.

# %%
data.head(20)

# %% [markdown]
# data.head() shows us the first 5(default) rows of the datas.It is important because we should take a look to data before working on data deeply.

# %%
data.tail()

# %%
data.columns

# %% [markdown]
# To see the columns easily use data.columns.

# %%
data.corr()

# %% [markdown]
# data.corr() is essential to see the correlations beetween columns.Also we use data.corr() to map the correlations.

# %%
f,ax = plt.subplots(figsize = (15,15))
sns.heatmap(data.corr(), annot = True, linewidth = 0.5, fmt='.2f', ax=ax)
plt.show()

# %% [markdown]
# Personally I like correlation map because it looks verys elegant :).And of course it helps us to see correlation easily.

# %% [markdown]
# Now it is time to see behaviours of features on graphs.

# %%
data.Economy.plot(kind = 'line', color = 'g', label = 'Economy', linewidth = 1, alpha = 1, grid = True, linestyle= ':')
data.Health.plot(kind = 'line', color = 'b', label = 'Health', linewidth = 1, alpha = 1, grid = True, linestyle = '-.')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.legend()
plt.title('Line plot')
plt.show()

# %% [markdown]
# Line plot is good for observe two columns behaviour together.

# %%
data.plot(kind = 'scatter', x = 'Happiness_Score', y = 'Economy', color = 'b', alpha = 0.5)
plt.xlabel('Happiness Score')
plt.ylabel('Economy')
plt.title('Happiness Score - Economy Scatter Plot ')
plt.show()

# %% [markdown]
# Scatter plot is brilliant way to see correlations or comparing two features.

# %%
plt.bar(data.Country[145:157], data.Happiness_Score[145:157], width =  0.5, color= 'r', alpha = 0.7)
plt.show()

# %% [markdown]
# **--------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %%
def tuple_ex():
    t = (5,6,'a')
    return t    #return defined tuple -t- .
x,y,z = tuple_ex()
print(x,y,z)

# %% [markdown]
# **SCOPE**

# %%
x = 5
def f():
    x = 3
    y = x * 2
    return y
print(x)
print(f())

# %% [markdown]
# * x = 5 is the global that defined main body in script
# * x = 3 is a local that defined in a function
# If there is no local scope, function will use the global scope

# %% [markdown]
# **------------------------**

# %%
def f(a, b = 1, c = 2):
    y = a + b + c
    return y
print(f(1,2,3))

# %% [markdown]
# * b and c are default arguments but a is a flexible arguments that we can assign.

# %%
def f(*args):
    for i in args:
        print(i)
f(1)
f(1,2,3,4,'as',67)

def f(**kwargs):
    for key , value in kwargs.items():
        print(key," ",value)
        
f(country = 'spain', capital = 'madrid' , population = 123421)

# %% [markdown]
# *args can be anything.    **kwargs is a dictionary version of *args.

# %% [markdown]
# We can use **lambda** to write function in a line.

# %%
addition = lambda x,a,b : x+a+b
addition(1,9,3)
square = lambda x : x**2
square(7)

# %% [markdown]
# map(func,list) means, apply the function whole list.

# %%
number_list = [1,2,3]
y = map(lambda x : x**2 , number_list)
print(list(y))

# %%
name = "abdullah"
k = iter(name)
print(next(k))
print(*k)

# %% [markdown]
# k  = iterable
# We iterate the object(iterable) with iterator.

# %% [markdown]
# We can zip list with zip().

# %%
list1 = [1,2,3,4]
list2 = [5,6,'a',8]
z = zip(list1,list2)
print(z)
z_list = list(z)
type(z_list)
print(z_list)

# %% [markdown]
# Also we can unzip the lists that we zipped before.

# %%
un_zip = zip(*z_list)
un_list1 , un_list2 = list(un_zip)
print(un_list1)
print(un_list2)
print(type(un_list2))

# %% [markdown]
# List comprehension is creating a list using for loops in a single line.

# %%
num1 = [1,2,3]
num2 = [i+1 for i in num1]
print(num2)

# %%
num1 = [5,10,15]
num2 = [i-5 if i < 7 else i**2 if i == 10 else i+5 for i in num1]
print(num2)

# %%
#  <6low        >6 high

# %%
data["Happiness_level"] = ["high" if i > 6 else "low" for i in data.Happiness_Score]
data.loc[:10 , ["Country","Happiness_level", "Happiness_Score"]]

# %% [markdown]
# **CLEANING DATA**

# %%
data.head()

# %%
data.tail() #last 5

# %%
data.columns

# %%
data.shape

# %%
data.info()

# %%
print(data['Region'].value_counts(dropna = False)) #count non-null variables too.

# %% [markdown]
# We can see repetitions of entries by using value_counts().

# %%
data.describe() #ignore null entries

# %% [markdown]
# Box plots : visualize basic statistics like outliers,min/max or quantiles

# %%
data.boxplot(column = 'Economy', by = 'Happiness_level')
plt.show()

# %% [markdown]
# * Black line at top is the max value.
# * Blue line at top is the secont quartile (%75)
# * Green line is median (%50)
# * Blue line at bottom is first quartile (%25)
# * Black line at bottom is min value.
# * **Black circle is the outlier !!**

# %% [markdown]
# **Tidy Data:**
# We tidy data with melt().

# %%
data_new = data.head()
data_new

# %% [markdown]
# * frame = source
# * id_vars = unchanging variable
# * value_vars = variables and their values.

# %%
melted = pd.melt(frame = data_new, id_vars = 'Country',value_vars =['Happiness_Rank','Happiness_Score'])
melted

# %% [markdown]
# **Pivoting Data:**Reverse of melting

# %%
melted.pivot(index = 'Country',columns = 'variable',values = 'value')

# %% [markdown]
# **Concatenating Data**

# %% [markdown]
# First concatenate datas in rows. (Means axis = 0)

# %%
data1 = data.head()
data2 = data.tail()
conc_data_row = pd.concat([data1,data2],axis = 0,ignore_index = False) # axis = 0 add in row
conc_data_row

# %%
data0 = data['Country'].head()
data1 = data['Happiness_Score'].head()
data2 = data['Economy'].head()
conc_data_col = pd.concat([data0,data1,data2],axis = 1)
conc_data_col

# %% [markdown]
# If you do axis = 1 it will concat datas with columns

# %% [markdown]
# **DATA TYPES**

# %%
data.dtypes

# %% [markdown]
# Changing the data types may be important some times.And for this purpose we have astype().

# %%
data['Country'] = data['Country'].astype('category')
data['Happiness_Rank'] = data['Happiness_Rank'].astype('float')

# %%
data.dtypes

# %% [markdown]
# **Missing Datas**
# You can do:
# * -leave as it
# * -drop them with dropna()
# * -fill missing value with fillna()
# * -fill missing values with test statistics like mean

# %%
data.info()

# %% [markdown]
# We do not have null entry.All of the entries are non-null.

# %% [markdown]
# We also see this with using value_counts(dropna = False) -means do not drop null entries.-

# %%
data["Region"].value_counts(dropna = False)

# %% [markdown]
# In this data we don't have null entries.But in order to learn what we do with null entries I'd like to share with you dropna().

# %% [markdown]
# To drop null entries we use dropna().

# %%
data["Region"].dropna(inplace = True) #inplace = True means do not assign new variable.

# %% [markdown]
# We check this code with assert.If the sentences that we write next to assert is true then it will return nothing.

# %%
assert data["Region"].notnull().all()

# %% [markdown]
# So it returns nothing, means in the all 'Region' column we do not have null entries, all of the entries are notnull.

# %% [markdown]
# ------**PANDAS FOUNDATİON**------
#
# * Building Data Frames From Scratch
# * Despite the building data frames from csv we can also build data frames from dictionaries via using zip() method.
# zip() method returns a list of tuples.

# %%
#data frame creating from dictionary
mountains = ["Rocky","Everest"]
altitude = ["4401","8848"]
list_label = ["Mountain","Altitude"]
list_col = [mountains,altitude]
zipped = list(zip(list_label,list_col))
data_dict = dict(zipped)
df = pd.DataFrame(data_dict)
df

# %% [markdown]
# As you can see it takes time to create dataframes from dictionary.

# %%
df["Location"] = ["Nort America","Himalayas"]
df

# %% [markdown]
# Adding new features to the data frame is the same as we did before.

# %%
df["broadcasting"] = 0
df

# %% [markdown]
# What we mean broadcasting is adding new column to the data frame and give whole entries a value.

# %% [markdown]
# **VISUAL EXPLORATORY DATA ANALYSIS**

# %% [markdown]
# Let's remind ourselves basic plotting techniques.

# %%
#plotting all data
data1 = data.loc[:,["Happiness_Score","Economy","Health"]]
data1.plot()
plt.show()

# %% [markdown]
# Using subplots we can separate the features.

# %%
#subplots
data1.plot(subplots = True)
plt.show()

# %%
#Scatter plot
data.plot(kind = "scatter",x = "Economy",y = "Happiness_Score")
plt.show()

# %%
#Histogram plot
data1.plot(kind = "hist",y = "Happiness_Score",bins = 50,range = (0,10),normed = True)
plt.show()

# %%
fig,axes = plt.subplots(nrows = 2,ncols = 1)
data1.plot(kind = "hist",y = "Happiness_Score",bins = 50,range = (0,10),normed = True, ax = axes[0])
data1.plot(kind = "hist",y = "Happiness_Score",bins = 50,range = (0,10),normed = True, ax = axes[1]
          ,cumulative = True)
plt.show()

# %% [markdown]
# **INDEXING PANDAS TIME SERIES**

# %% [markdown]
# datatime is an object.

# %%
time_list = ["1981-04-17","1981-03-12"]
print(type(time_list[1]))
datetime_object = pd.to_datetime(time_list)
print(type(datetime_object))

# %% [markdown]
# Now, let's create a datelist then change it's type to datetime (like ı said it is an object) and add it to our dataframe as an index.

# %%
data2 = data.head()
date_list = ["1992-01-10","1992-02-10","1992-03-10","1993-03-15","1993-03-16"]
datetime_object = pd.to_datetime(date_list) #changing type, str to datetime
data2["date"] = datetime_object             #adding to dataframe
data2 = data2.set_index("date")             # as an index !
data2

# %% [markdown]
# We can search a specific data with respect to date.

# %%
print(data2.loc["1993-03-16"])

# %%
print(data2.loc["1992-03-10":"1993-03-16"])

# %% [markdown]
# **RESAMPLING PANDAS TIME SERIES**

# %% [markdown]
# * Now we can resample the dataframe.
# * "A" means with respect to YEAR,
# * "M" means with respect to MONTH

# %% [markdown]
# Resampling by YEAR ("A") with mean.

# %%
data2.resample("A").mean()

# %%
data2.resample("M").mean()

# %% [markdown]
# Resampling by Month ("M") with mean.

# %% [markdown]
# To fill NaN entries we can interpolate linearly.

# %%
data2.resample("M").first().interpolate("linear")

# %% [markdown]
# Also we can interpolate linearly with having same means.

# %%
data2.resample("M").mean().interpolate("linear")

# %% [markdown]
# **MANIPULATİNG DATA FRAMES with PANDAS******

# %% [markdown]
# INDEXING

# %%
data = data.set_index("Happiness_Rank")  #indexing with happiness_rank
data.head()

# %% [markdown]
# To find specific element we have several ways.

# %%
data["Happiness_Score"][1]     #using square brackets

# %%
data.Happiness_Score[1]       #using column attribute and row label

# %%
data.loc[1,["Happiness_Score"]]  #using loc

# %%
data[["Happiness_Score","Economy"]]      #selecting only precise columns

# %% [markdown]
# SLICING DATA FRAME

# %% [markdown]
# We may want to learn features beetween 2 selected columns.For this purpose we use slicing.

# %%
data.loc[1:10,"Region":"Family"]    # ROWS --->  1 TO 10
                                    # COLUMNS -> Region to Family

# %%
data.loc[10:1:-1,"Region":"Family"]    #reverse slicing

# %%
data.loc[1:10,"Economy":]

# %% [markdown]
# FILTERING DATA FRAMES

# %% [markdown]
# Filtering means getting datas for defined interval by creating boolean series.

# %% [markdown]
# This code gives us the entries that only have Happiness Score higher than 6.

# %%
boolean = data.Happiness_Score > 6
data[boolean]

# %% [markdown]
# We can also use more than one filter.

# %%
filt1 = data.Happiness_Score > 6
filt2 = data.Economy > 1.25
data[filt1 & filt2]

# %% [markdown]
# This code will give us the Regions which only has Happiness Score greater than 6.8

# %%
data.Region[data.Happiness_Score > 6.8]

# %% [markdown]
# TRANSFORMING DATA

# %% [markdown]
# We may want to have different kind of our data's values.

# %%
def div(m):
    y = m/2
    return y
data.Happiness_Score.apply(div)

# %% [markdown]
# But we learnt shorter way to write function before.

# %%
data.Happiness_Score.apply(lambda m:m/2)

# %% [markdown]
# We can define a new column by using other columns in the dataframe.

# %%
data["new_column"] = data.Happiness_Score - data.Standard_Error
data.head()

# %% [markdown]
# INDEX OBJECTS AND LABELED DATA

# %%
#We can learn our index name :
print(data.index.name)

# %% [markdown]
# It is also possible to change the name of index.

# %%
data.index.name = "index_name"
data.head()

# %% [markdown]
# We can modify the index.

# %%
data3 = data.copy()
data3.index = range(100,258,1)
data3.head()

# %% [markdown]
# HIERARCHICAL INDEXING

# %% [markdown]
# Region : outer index and Happiness_level: inner index

# %%
data3 = data.set_index(["Region","Happiness_level"])
data3.head(150)

# %% [markdown]
# PIVOTING DATA FRAMES

# %%
dic = {"chemical" : ["X","Y","X","Y"],"reactivity" : ["low","high","low","high"],"price" : [34,14,56,78],
       "config" : [3,7,7,3] }
df = pd.DataFrame(dic)
df

# %%
#pivoting
df.pivot(index = "chemical",columns = "config",values = "price")

# %% [markdown]
# STACKING AND UNSTACKING DATAFRAME

# %%
df1 = df.set_index(["chemical","config"])    
df1

# %% [markdown]
# We can easily unstack the df1

# %%
df1.unstack(level = 0)  #level : position of unstacked index

# %%
df1.unstack(level = 1)

# %% [markdown]
# We are able to change inner and outer level index positions.

# %%
df2 = df1.swaplevel(0,1)
df2

# %% [markdown]
# MELTING

# %%
df

# %%
pd.melt(frame = df,id_vars = "chemical",value_vars = ["reactivity","price"])

# %% [markdown]
# CATEGORICALS AND GROUPBY

# %%
df

# %% [markdown]
# We can group the features according to any feature that we want

# %%
df.groupby("chemical").mean()

# %%
df.groupby("chemical").max()

# %%
df.groupby("chemical").price.max()

# %%
df.groupby("chemical")[["price","reactivity"]].min()
