# %% [markdown]
# # Elementary Statistics and Data Visualization
# Lab Exercises - Week 1
#
# ----------

# %% [markdown]
# ## Instructions for Lab Exercise-1
# Welcome to your first lab on elementary statistics and data visualization. This lab we will focus on generating a plethora of plots that will help you analyze, comprehend and visualize data.
#
# Following are the steps to be taken to complete the lab exercise for week-1:
# 1. Fork the root notebook and create a copy for yourself. The newly created notebook is your working version and will have be submitted at the end of the lab session.
# 2. The data sets required for this lab are available as a part of the "Draft Environment" (visible to the right of the notebook). To ensure all the data sets have been imported, execute cell-4 and the resultant output will be a list view of the files available.
# 3. All questions pertaining to lab-1 have been detailed below. Write your code and execute each cell against the associated question.
# 4. Post the completion of the lab execrcises, commit your notebook and share it with Prof. Karim and Manish Varma. We will review and provide comments if the need be.
#
# P.S : Always ask questions! Incase any of the above steps are not clear do let us and we will help you resolve them.

# %% [markdown]
# ## Introduction to using Kaggle Notebooks
# Notebooks are a handy way to explore data because they combine narrative with live code in an attractive report. Here's how to use a Kaggle Notebook:
#
# 1. You can execute "cells" of Markdown text (like this section) or code. Just select a cell and toggle between "Markdown" an "Python". To execute the code, hit the play button. To add a new cell use the "+" buttons. To delete a chunk click on the red trashcan.
# 2. In the notebook editor, you can inspect the dataset's files by expanding the "Input Files" component at the top of the editor.
# 3. Make sure the notebook is always kept private for the duration of the lab and continually keep commiting your notebook.

# %%
#Cell - 4: Execute code to ensure the data has been imported successfully.
#Output: A list view of the files available.
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display
import seaborn as sns

print(os.listdir("../input"))

# %% [markdown]
# ### Q1 - Using **quakes.csv**, generate a scatter plot for columns "lat" and "long".

# %%
# Write your code for Q1 and execute the cell
q1=pd.read_csv("../input/quakes.csv")
q1.head(10)

# %%
plt.scatter(q1["lat"], q1["long"], alpha=0.50)
plt.show()

# %% [markdown]
# ### Q2 - Print the mean, mode and median for the following list [5,7,2,4,5,6,4,5,6,4,3,5,6,5,3]

# %%
# Write your code for Q2 and execute the cell
d = pd.Series([5,7,2,4,5,6,4,5,6,4,3,5,6,5,3])
print("Mean: ",d.mean())
print("Mode: ", d.mode())
print("Median: ", d.median())

# %% [markdown]
# ### Q3 - Using **chickwits.csv**, print mean, median, 80% quantile value for column "weight". For the column "feed", print proportion and percentage values.

# %%
# Write your code for Q3 and execute the cell
c1 = pd.read_csv("../input/chickwts.csv")
c1.head(10)

# %%
w1 = c1["weight"]
display("Mean: ", w1.mean())
display("Median: ", w1.median())
display("80% value: ", w1.quantile(0.8))
display("Weight description:",w1.describe())

# %%
f1 = c1["feed"]
print("Value Count:\n",f1.value_counts())
print('---------------------------')
print("Proportion:\n",f1.value_counts()/f1.size)
print('---------------------------')
print("Percentages:\n",f1.value_counts()/f1.size*100)

# %%
sns.countplot(f1)

# %% [markdown]
# ### Q4 - Using **quakes.csv**, generate a summary for the column "meg" and the entire dataset.

# %%
# Write your code for Q4 and execute the cell
q1=pd.read_csv("../input/quakes.csv")
print("Summary for column mag:\n", q1["mag"].describe())

# %%
print("Summary for quakes\n",q1.describe())

# %% [markdown]
# ### Q5 - Using **orange.csv**, find the correlation between the columns "age" and "circumference". Also, generate a scatter plot for both the columns mentioned.

# %%
# Write your code for Q5 and execute the cell
o = pd.read_csv("../input/orange.csv")
o1 = o[["age","circumference"]]
print(o1)
print("------------------------")
print("Correlation:\n",o1.corr())

# %%
plt.scatter(o1["age"],o1["circumference"], alpha=0.5)
plt.title('Scatter plot')
plt.xlabel('age')
plt.ylabel('circumference')
plt.show()

# %% [markdown]
# ### Q6 - Using **mtcars.csv**, generate a bar plot for the column "cyl".

# %%
# Write your code for Q6 and execute the cell
m1=pd.read_csv("../input/mtcars.csv")
m1.head()

# %%
cf = m1["cyl"].value_counts()
cd = cf.apply(pd.Series)
cd.columns = ["freq"]
print(cd)

# %%
plt.bar(cd.index,cd["freq"])
plt.show()

# %% [markdown]
# ### Q7 - Using **mtcars.csv**, generate a pie chart for the column "cyl".

# %%
plt.pie(cd["freq"], labels=cd.index, startangle=90)
plt.show()

# %% [markdown]
# ### Q8 - Using **orange.csv**, generate a box plot for the column "age".

# %%
# Write your code for Q8 and execute the cell
o = pd.read_csv("../input/orange.csv")
o1 = o[["age"]]
o1["age"].value_counts()

# %%
plt.boxplot(o1["age"])
plt.show()

# %% [markdown]
# ### Q9 - Using **orange.csv**, generate a box plot to identify the relationship between the columns "age" and "circumference".

# %%
o2 = o[["age","circumference"]]
o2.head()

# %%
sns.boxplot(
    x='age',
    y='circumference',
    data=o2
)

# %% [markdown]
# ****### **Voilà! This is the end of the lab session for week 1.**
# Do not forget to commit your notebook and set the access to private. Share the notebook with Prof. Karim (Kaggle id: karimshaikh) and Manish Varma (Kaggle id: manishvarma).
