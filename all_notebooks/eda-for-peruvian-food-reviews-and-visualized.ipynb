# %% [markdown]
# ![dd](data:image/jpeg;base64,...)

# %% [markdown]
# # استدعاء بعض المكتابات التى تستخدم فى قراءه الببيانات وتحليلها

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import string

# %% [markdown]
# # قراءه البيانات للعمل عليها

# %%
df=pd.read_csv('../input/peruvian-food-reviews/data/reviews.csv')

# %% [markdown]
# # اضهار بعض من محتوى البيانات

# %%
df.head(5)

# %% [markdown]
# # عرض حجم البيانات ومعلومات عنها وقيمها الاحصائحه

# %%
df.shape

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# # عرض اما اذا كانت البيانات تحتوى على بعض البيانات المفقوده ام لا

# %%
df.isnull().sum()

# %%
#df.drop(['score','likes','service','date','id_nick','id_review'],axis=1,inplace=True)

# %%
df['review'].head(10)

# %%
import missingno as msno
msno.matrix(df)

# %%
df['service'].plot.hist()

# %%
df['score'].plot.hist()

# %%
sns.distplot(df['score'], color = 'r', label = 'Solids')

# %%
sns.distplot(df['service'], color = 'r', label = 'Solids')

# %%
plt.hist(df["score"], bins = 30)

# %%
plt.hist(df["service"], bins = 30)

# %%
sns.scatterplot(x='score', y='service', data=df)
