# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

data = pd.read_csv('../input/predicting-student-grades/AllResults.csv')
data['Ma'] = data['Ma'].str.lower()
data = data.dropna()
data['MaN'] = data['Ma'].map({'n': 6, 'W': 1, '1': 2, '2': 3, '3a': 4, '3b': 4, '3c': 4,'4c': 5, '4a': 6, '4b': 6, '5b': 7, '5c': 7, '5a': 8, '6a': 9, '6b': 9, '6c': 9})
data = data[data['Att8Act'] > 0]
data

# %%
data.corr()

# %%
data.plot.scatter(x='EngAct', y='MathsAct')
data['Att8Act'].hist()

# %%
ax = data.plot.scatter(x='MaN', y='Att8Act')
data.plot(x='MaN', y='Att8Act', ax=ax, color='r')

# %%
data.plot.scatter(x='EngAct', y='EngEst')

# %%
import matplotlib.pyplot as plt
import numpy as np

# 100 linearly spaced numbers
x = np.linspace(-5,5,100)

# the function, which is y = x^2 here
y = (x**64)-4

# setting the axes at the centre
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# plot the function
plt.plot(x,y, 'r')

# show the plot
plt.show()
