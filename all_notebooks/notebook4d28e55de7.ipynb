# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pandas_profiling import ProfileReport

# %%
data=pd.read_csv("../input/life-expectancy-at-birth-in-europe/life_expectancy_at_birth.csv")

# %%
data.info()

# %%
data.describe()

# %%
data.head()

# %%
data['unit'].unique()

# %%
data['statinfo'].unique()

# %%
plt.style.use("dark_background")
plt.figure(figsize=(25,7))
sns.lineplot(x="geography",y='value',data=data,hue="sex",marker='o')

# %%
plt.style.use("dark_background")
plt.figure(figsize=(25,7))
sns.lineplot(x="date",y='value',data=data,hue="sex",marker='o')

# %%
sns.pairplot(data=data, hue="sex")

# %%
data.groupby("sex").mean()

# %%
data.groupby("date").mean().sort_values(by="value",ascending=False)

# %%
data.groupby("date").mean().plot()

# %%
ab=ProfileReport(data)

# %%
ab
