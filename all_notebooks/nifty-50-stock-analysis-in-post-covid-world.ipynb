# %% [markdown]
# # NIFTY 50 STOCK MARKET DATA ANALYSIS
#
# TODO - Write some introduction about your project here: describe the dataset, where you got it from, what you're trying to do with it, and which tools & techniques you're using. You can also mention about the course [Data Analysis with Python: Zero to Pandas](zerotopandas.com), and what you've learned from it.

# %%
dataset_url = 'https://www.kaggle.com/rohanrao/nifty50-stock-market-data?select=HCLTECH.csv'

# %%
# !pip install kaggle

# %%
"""Industry wise classification i.e, plot graphs of multiple companies of similar industry in one graph
Plot the data with respect to covid cases and its impact on the company growth
Beneficiaries: Pharma, Information Technology,Banking, FMCG,
Losers: Auto initially but later revives
bottom losers: hotels,hospitality
cipla,dr_reddy's,
"""

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Pharma Companies

# %%
Dr_Reddy_df=pd.read_csv(r'../input/nifty50-stock-market-data/DRREDDY.csv')
Cipla_df=pd.read_csv(r'../input/nifty50-stock-market-data/CIPLA.csv')
Sun_pharma_df=pd.read_csv(r'../input/nifty50-stock-market-data/SUNPHARMA.csv')

# %% [markdown]
# ### IT Companies

# %%
Hcl_tech_df=pd.read_csv(r'../input/nifty50-stock-market-data/HCLTECH.csv')
Infosys_df=pd.read_csv(r'../input/nifty50-stock-market-data/INFY.csv')
Tcs_df=pd.read_csv(r'../input/nifty50-stock-market-data/TCS.csv')
Wipro_df=pd.read_csv(r'../input/nifty50-stock-market-data/WIPRO.csv')
TechMahindra_df=pd.read_csv(r'../input/nifty50-stock-market-data/TECHM.csv')

# %% [markdown]
# ### Auto Sector Companies

# %%
Bajajauto_df=pd.read_csv(r'../input/nifty50-stock-market-data/BAJAJ-AUTO.csv')
Eicher_df=pd.read_csv(r'../input/nifty50-stock-market-data/EICHERMOT.csv')
Hero_motors_df=pd.read_csv(r'../input/nifty50-stock-market-data/HEROMOTOCO.csv')
Maruti_df=pd.read_csv(r'../input/nifty50-stock-market-data/MARUTI.csv')
MM_df=pd.read_csv(r'../input/nifty50-stock-market-data/MM.csv')
Tata_motos_df=pd.read_csv(r'../input/nifty50-stock-market-data/TATAMOTORS.csv')

# %% [markdown]
# ### FMCG Companies

# %%
Asianpaints_df=pd.read_csv(r'../input/nifty50-stock-market-data/ASIANPAINT.csv')
Britannia_df=pd.read_csv(r'../input/nifty50-stock-market-data/BRITANNIA.csv')
HUL_df=pd.read_csv(r'../input/nifty50-stock-market-data/HINDUNILVR.csv')
ITC_df=pd.read_csv(r'../input/nifty50-stock-market-data/ITC.csv')
Nestle_df=pd.read_csv(r'../input/nifty50-stock-market-data/NESTLEIND.csv')

# %% [markdown]
# ### Banks & Finance Companies

# %%
Axisbank_df=pd.read_csv(r'../input/nifty50-stock-market-data/AXISBANK.csv')
Bajajfinsv_df=pd.read_csv(r'../input/nifty50-stock-market-data/BAJAJFINSV.csv')
Bajaj_finance_df=pd.read_csv(r'../input/nifty50-stock-market-data/BAJFINANCE.csv')
Hdfc_df=pd.read_csv(r'../input/nifty50-stock-market-data/HDFC.csv')
Hdfc_bank_df=pd.read_csv(r'../input/nifty50-stock-market-data/HDFCBANK.csv')
Icici_bank_df=pd.read_csv(r'../input/nifty50-stock-market-data/ICICIBANK.csv')
Indusind_bank_df=pd.read_csv(r'../input/nifty50-stock-market-data/INDUSINDBK.csv')
Kotak_bank_df=pd.read_csv(r'../input/nifty50-stock-market-data/KOTAKBANK.csv')

# %% [markdown]
# ### PSU Companies

# %%
BPCL_df=pd.read_csv(r'../input/nifty50-stock-market-data/BPCL.csv')
CoalIndia_df=pd.read_csv(r'../input/nifty50-stock-market-data/COALINDIA.csv')
GAIL_df=pd.read_csv(r'../input/nifty50-stock-market-data/GAIL.csv')
IOC_df=pd.read_csv(r'../input/nifty50-stock-market-data/IOC.csv')
NTPC_df=pd.read_csv(r'../input/nifty50-stock-market-data/NTPC.csv')
ONGC_df=pd.read_csv(r'../input/nifty50-stock-market-data/ONGC.csv')
Powergrid_df=pd.read_csv(r'../input/nifty50-stock-market-data/POWERGRID.csv')

# %%
Dr_Reddy_df

# %%
Dr_Reddy_df.describe()

# %%
Dr_Reddy_df.info()

# %% [markdown]
# ### Pharma Companies

# %%
Dr_Reddy_df['Date']=pd.to_datetime(Dr_Reddy_df['Date'],format='%Y-%m-%d')
Cipla_df['Date']=pd.to_datetime(Cipla_df['Date'],format='%Y-%m-%d')
Sun_pharma_df['Date']=pd.to_datetime(Sun_pharma_df['Date'],format='%Y-%m-%d')

# %% [markdown]
# ### IT Companies

# %%
Hcl_tech_df['Date']=pd.to_datetime(Hcl_tech_df['Date'],format='%Y-%m-%d')
Infosys_df['Date']=pd.to_datetime(Infosys_df['Date'],format='%Y-%m-%d')
Tcs_df['Date']=pd.to_datetime(Tcs_df['Date'],format='%Y-%m-%d')
Wipro_df['Date']=pd.to_datetime(Wipro_df['Date'],format='%Y-%m-%d')
TechMahindra_df['Date']=pd.to_datetime(TechMahindra_df['Date'],format='%Y-%m-%d')

# %% [markdown]
# ### Auto Sector Companies

# %%
Bajajauto_df['Date']=pd.to_datetime(Bajajauto_df['Date'],format='%Y-%m-%d')
Eicher_df['Date']=pd.to_datetime(Eicher_df['Date'],format='%Y-%m-%d')
Hero_motors_df['Date']=pd.to_datetime(Hero_motors_df['Date'],format='%Y-%m-%d')
Maruti_df['Date']=pd.to_datetime(Maruti_df['Date'],format='%Y-%m-%d')
MM_df['Date']=pd.to_datetime(MM_df['Date'],format='%Y-%m-%d')
Tata_motos_df['Date']=pd.to_datetime(Tata_motos_df['Date'],format='%Y-%m-%d')

# %% [markdown]
# ### FMCG Companies

# %%
Asianpaints_df['Date']=pd.to_datetime(Asianpaints_df['Date'],format='%Y-%m-%d')
Britannia_df['Date']=pd.to_datetime(Britannia_df['Date'],format='%Y-%m-%d')
HUL_df['Date']=pd.to_datetime(HUL_df['Date'],format='%Y-%m-%d')
ITC_df['Date']=pd.to_datetime(ITC_df['Date'],format='%Y-%m-%d')
Nestle_df['Date']=pd.to_datetime(Nestle_df['Date'],format='%Y-%m-%d')

# %% [markdown]
# ### Banking and Finance Companies

# %%
Axisbank_df['Date']=pd.to_datetime(Axisbank_df['Date'],format='%Y-%m-%d')
Bajajfinsv_df['Date']=pd.to_datetime(Bajajfinsv_df['Date'],format='%Y-%m-%d')
Bajaj_finance_df['Date']=pd.to_datetime(Bajaj_finance_df['Date'],format='%Y-%m-%d')
Hdfc_df['Date']=pd.to_datetime(Hdfc_df['Date'],format='%Y-%m-%d')
Hdfc_bank_df['Date']=pd.to_datetime(Hdfc_bank_df['Date'],format='%Y-%m-%d')
Icici_bank_df['Date']=pd.to_datetime(Icici_bank_df['Date'],format='%Y-%m-%d')
Indusind_bank_df['Date']=pd.to_datetime(Indusind_bank_df['Date'],format='%Y-%m-%d')
Kotak_bank_df['Date']=pd.to_datetime(Kotak_bank_df['Date'],format='%Y-%m-%d')

# %% [markdown]
# ### PSU's Companies

# %%
BPCL_df['Date']=pd.to_datetime(BPCL_df['Date'],format='%Y-%m-%d')
CoalIndia_df['Date']=pd.to_datetime(CoalIndia_df['Date'],format='%Y-%m-%d')
GAIL_df['Date']=pd.to_datetime(GAIL_df['Date'],format='%Y-%m-%d')
IOC_df['Date']=pd.to_datetime(IOC_df['Date'],format='%Y-%m-%d')
NTPC_df['Date']=pd.to_datetime(NTPC_df['Date'],format='%Y-%m-%d')
ONGC_df['Date']=pd.to_datetime(ONGC_df['Date'],format='%Y-%m-%d')
Powergrid_df['Date']=pd.to_datetime(Powergrid_df['Date'],format='%Y-%m-%d')

# %% [markdown]
# ### MAJORITY OF COMPANIES

# %%
# Pharma Companies
Dr_Reddy_df_20=Dr_Reddy_df.loc[(Dr_Reddy_df['Date']>='2020-03-28')]
Cipla_df_20=Cipla_df.loc[(Cipla_df['Date']>='2020-03-28')]
Sun_pharma_df_20=Sun_pharma_df.loc[(Sun_pharma_df['Date']>='2020-03-28')]

#IT Companies
Hcl_tech_df_20=Hcl_tech_df.loc[(Hcl_tech_df['Date']>='2020-03-28')]
Infosys_df_20=Infosys_df.loc[(Infosys_df['Date']>='2020-03-28')]
Tcs_df_20=Tcs_df.loc[(Tcs_df['Date']>='2020-03-28')]
Wipro_df_20=Wipro_df.loc[(Wipro_df['Date']>='2020-03-28')]
TechMahindra_df_20=TechMahindra_df.loc[(TechMahindra_df['Date']>='2020-03-28')]

#AutoSector
Bajajauto_df_20=Bajajauto_df.loc[(Bajajauto_df['Date']>='2020-03-28')]
Eicher_df_20=Eicher_df.loc[(Eicher_df['Date']>='2020-03-28')]
Hero_motors_df_20=Hero_motors_df.loc[(Hero_motors_df['Date']>='2020-03-28')]
Maruti_df_20=Maruti_df.loc[(Maruti_df['Date']>='2020-03-28')]
MM_df_20=MM_df.loc[(MM_df['Date']>='2020-03-28')]
Tata_motos_df_20=Tata_motos_df.loc[(Tata_motos_df['Date']>='2020-03-28')]

#FMCG Companies
Asianpaints_df_20=Asianpaints_df.loc[(Asianpaints_df['Date']>='2020-03-28')]
Britannia_df_20=Britannia_df.loc[(Britannia_df['Date']>='2020-03-28')]
HUL_df_20=HUL_df.loc[(HUL_df['Date']>='2020-03-28')]
ITC_df_20=ITC_df.loc[(ITC_df['Date']>='2020-03-28')]
Nestle_df_20=Nestle_df.loc[(Nestle_df['Date']>='2020-03-28')]

#Banking and Finance Companies
Axisbank_df_20=Axisbank_df.loc[(Axisbank_df['Date']>='2020-03-28')]
Bajajfinsv_df_20=Bajajfinsv_df.loc[(Bajajfinsv_df['Date']>='2020-03-28')]
Bajaj_finance_df_20=Bajaj_finance_df.loc[(Bajaj_finance_df['Date']>='2020-03-28')]
Hdfc_df_20=Hdfc_df.loc[(Hdfc_df['Date']>='2020-03-28')]
Hdfc_bank_df_20=Hdfc_bank_df.loc[(Hdfc_bank_df['Date']>='2020-03-28')]
Icici_bank_df_20=Icici_bank_df.loc[(Icici_bank_df['Date']>='2020-03-28')]
Indusind_bank_df_20=Indusind_bank_df.loc[(Indusind_bank_df['Date']>='2020-03-28')]
Kotak_bank_df_20=Kotak_bank_df.loc[(Kotak_bank_df['Date']>='2020-03-28')]

#PSU's Companies
BPCL_df_20=BPCL_df.loc[(BPCL_df['Date']>='2020-03-28')]
CoalIndia_df_20=CoalIndia_df.loc[(CoalIndia_df['Date']>='2020-03-28')]
GAIL_df_20=GAIL_df.loc[(GAIL_df['Date']>='2020-03-28')]
IOC_df_20=IOC_df.loc[(IOC_df['Date']>='2020-03-28')]
NTPC_df_20=NTPC_df.loc[(NTPC_df['Date']>='2020-03-28')]
ONGC_df_20=ONGC_df.loc[(ONGC_df['Date']>='2020-03-28')]
Powergrid_df_20=Powergrid_df.loc[(Powergrid_df['Date']>='2020-03-28')]

# %% [markdown]
# ## PLOTTING THE COMPANIES WITH RESPECT TO POST COVID WORLD FROM MARCH 2020
# ### * *How companies had revived across different sectors*
# ### * *Plotted in single Figure*
# ### * *This is very handy to analyze that FMCG, IT, BANKS had performed very well with respect to plotted graphs*
# ### * *Still lot of data left to be analyzed*

# %%
sns.set_style("whitegrid")
fig,axes=plt.subplots(2,3,figsize=(40,24))
# Pharma Companies
axes[0,0].plot(Dr_Reddy_df_20.Date,Dr_Reddy_df_20.Close,'g')
axes[0,0].plot(Cipla_df_20.Date,Cipla_df_20.Close,'r')
axes[0,0].plot(Sun_pharma_df_20.Date,Sun_pharma_df_20.Close,'b')
axes[0,0].set_xlabel("Date")
axes[0,0].set_ylabel("Price")
axes[0,0].set_title("PHARMA COMPANIES")
axes[0,0].legend(["Dr.Reddy's","Cipla","Sun Pharma"])

#IT Companies
axes[0,1].plot(Hcl_tech_df_20.Date,Hcl_tech_df_20.Close,'g')
axes[0,1].plot(Infosys_df_20.Date,Infosys_df_20.Close,'r')
axes[0,1].plot(Tcs_df_20.Date,Tcs_df_20.Close,'b')
axes[0,1].plot(Wipro_df_20.Date,Wipro_df_20.Close,'c')
axes[0,1].plot(TechMahindra_df_20.Date,TechMahindra_df_20.Close,'m')
axes[0,1].set_xlabel("Date")
axes[0,1].set_ylabel("Price")
axes[0,1].set_title("IT Companies/Technology")
axes[0,1].legend(["HCL TECH","INFOSYS","TCS","WIPRO","TECH MAHINDRA"])

#AUTO SECTOR COMPANIES
axes[0,2].plot(Bajajauto_df_20.Date,Bajajauto_df_20.Close,'g')
axes[0,2].plot(Eicher_df_20.Date,Eicher_df_20.Close,'r')
axes[0,2].plot(Hero_motors_df_20.Date,Hero_motors_df_20.Close,'b')
axes[0,2].plot(Maruti_df_20.Date,Maruti_df_20.Close,'c')
axes[0,2].plot(MM_df_20.Date,MM_df_20.Close,'m')
axes[0,2].plot(Tata_motos_df_20.Date,Tata_motos_df_20.Close,'y')
axes[0,2].set_xlabel("Date")
axes[0,2].set_ylabel("Price")
axes[0,2].set_title("AUTOMOBILE COMPANIES")
axes[0,2].legend(["BAJAJ AUTO","EICHER","HERO MOTORS","MARUTI","MM","TATA MOTORS"])

#FMCG Companies
axes[1,0].plot(Asianpaints_df_20.Date,Asianpaints_df_20.Close,'g')
axes[1,0].plot(Britannia_df_20.Date,Britannia_df_20.Close,'r')
axes[1,0].plot(HUL_df_20.Date,HUL_df_20.Close,'b')
axes[1,0].plot(ITC_df_20.Date,ITC_df_20.Close,'c')
axes[1,0].plot(Nestle_df_20.Date,Nestle_df_20.Close,'m')
axes[1,0].set_xlabel("Date")
axes[1,0].set_ylabel("Price")
axes[1,0].set_title("FMCG COMPANIES")
axes[1,0].legend(["Asian Paints","Britannia","HUL","ITC","Nestle"])

#Banking and Finance Companies
axes[1,1].plot(Axisbank_df_20.Date,Axisbank_df_20.Close,'g')
axes[1,1].plot(Bajajfinsv_df_20.Date,Bajajfinsv_df_20.Close,'r')
axes[1,1].plot(Bajaj_finance_df_20.Date,Bajaj_finance_df_20.Close,'b')
axes[1,1].plot(Hdfc_df_20.Date,Hdfc_df_20.Close,'c')
axes[1,1].plot(Hdfc_bank_df_20.Date,Hdfc_bank_df_20.Close,'m')
axes[1,1].plot(Icici_bank_df_20.Date,Icici_bank_df_20.Close,'y')
axes[1,1].plot(Indusind_bank_df_20.Date,Indusind_bank_df_20.Close,'k')
axes[1,1].plot(Kotak_bank_df_20.Date,Kotak_bank_df_20.Close,'tab:orange')
axes[1,1].set_xlabel("Date")
axes[1,1].set_ylabel("Price")
axes[1,1].set_title("BANKING AND FINANCE COMPANIES")
axes[1,1].legend(["Axis Bank","Bajaj Finsv","Bajaj Finance","Hdfc","Hdfc Bank","Icici Bank","IndusInd Bank","Kotak Bank"])

#PSU's Companies
axes[1,2].plot(BPCL_df_20.Date,BPCL_df_20.Close,'g')
axes[1,2].plot(CoalIndia_df_20.Date,CoalIndia_df_20.Close,'r')
axes[1,2].plot(GAIL_df_20.Date,GAIL_df_20.Close,'b')
axes[1,2].plot(IOC_df_20.Date,IOC_df_20.Close,'c')
axes[1,2].plot(NTPC_df_20.Date,NTPC_df_20.Close,'m')
axes[1,2].plot(ONGC_df_20.Date,ONGC_df_20.Close,'y')
axes[1,2].plot(Powergrid_df_20.Date,Powergrid_df_20.Close,'tab:orange')
axes[1,2].set_xlabel("Date")
axes[1,2].set_ylabel("Price")
axes[1,2].set_title("PSU's COMPANIES")
axes[1,2].legend(["BPCL","COALINDIA","GAIL","IOC","NTPC","ONGC","POWERGRID"])
