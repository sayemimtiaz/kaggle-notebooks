# %% [markdown]
#  # **Data Storytelling Project**

# %%
import numpy as np
import pandas as pd

data=pd.read_csv('../input/indian-food-101/indian_food.csv')
data.head()

# %%
data.tail()

# %%
data.shape

# %%
data.info()

# %%
data.isnull().sum()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.heatmap(data.isnull(),yticklabels=False)

# %%
sns.countplot(data.diet)

# %%
sns.countplot(data.flavor_profile)

# %%
sns.countplot(data.course)

# %%
print("Minimum Preperation Time:{}".format(min(data.prep_time)))

# %%
print("Maximum Preperation Time:{}".format(max(data.prep_time)))

# %%
print("Minimum Cooking Time:{}".format(min(data.cook_time)))

# %%
print("Maximum Cooking Time:{}".format(max(data.cook_time)))

# %%
data.cook_time.describe()

# %%
data.prep_time.describe()

# %%
np.unique(data.state)

# %%
np.unique(data.state).size

# %%
data.diet[data.diet=='non vegetarian'].size

# %%
data.diet[data.diet=='vegetarian'].size

# %%
data.name[data.diet=='non vegetarian']

# %%
non_veg=data.name[data.diet=='non vegetarian']
state=data.state[data.diet=='non vegetarian']
print("Non-Veg Food\t\tState\n-------------------------------------")
for i in range(len(veg)):
    print(non_veg.iloc[i]+"\t\t"+state.iloc[i])
