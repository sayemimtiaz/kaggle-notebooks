# %% [markdown]
# <h1 id="heading">
#
# <a class="anchor-link" href="https://www.kaggle.com/deb009/predict-customer-churn/notebook#heading">¶</a>
# </h1>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#pd.set_option('display.max_rows', None)

from pandas_profiling import ProfileReport

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# # Reading the data

# %%
train = pd.read_csv("../input/a-fine-windy-day-hackerearth-ml-challenge/train_data.csv")
test = pd.read_csv("../input/a-fine-windy-day-hackerearth-ml-challenge/test_data.csv")

# %%
train.head()

# %%
test.head()

# %% [markdown]
# # Exploring the data

# %%
train.info()

# %%
train.describe()

# %%
test.describe()

# %% [markdown]
# Target varibale

# %%
train['windmill_generated_power(kW/h)'].describe()

# %%
plt.figure(figsize=(12, 5))
plt.hist(train['windmill_generated_power(kW/h)'].values, bins=200)
plt.title('Histogram cat1 counts in train')
plt.xlabel('windmill_generated_power(kW/h)')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.xlim(0,20)
plt.ylabel('windmill_generated_power(kW/h)')
sns.boxplot(x=train['windmill_generated_power(kW/h)'])
plt.show()

# %% [markdown]
# So, from the above box plot we are able to deduce that there are outliers from 14 to 20.

# %% [markdown]
# Turbine_status

# %%
train['turbine_status'] = train['turbine_status'].astype(str)
plt.figure(figsize=(12, 5))
plt.hist(train['turbine_status'].values, bins=200)
plt.title('Turbine_status counts in train')
plt.xlabel('Turbine Status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# cloud_level

# %%
train['cloud_level'] = train['cloud_level'].astype(str)
plt.figure(figsize=(12, 5))
plt.hist(train['cloud_level'].values)
plt.title('cloud_level counts in train')
plt.xlabel('Cloud level')
plt.ylabel('Count')
plt.show()

# %%
#Converting the datetime column to object type to date time type
train["datetime"] = pd.to_datetime(train["datetime"])
test["datetime"] = pd.to_datetime(test["datetime"])

# %%
train['year'] =train['datetime'].dt.year
train['time'] = train['datetime'].dt.time

test['year'] =test['datetime'].dt.year
test['time'] = test['datetime'].dt.time

# %%
profile = ProfileReport(train)
profile

# %%
profile_test = ProfileReport(test)
profile_test
