# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
medals_file = pd.read_csv("/kaggle/input/tokyo-2020-olympics/medals.csv")

# %%
coaches_file = pd.read_csv("/kaggle/input/tokyo-2020-olympics/coaches.csv")

# %%
#EDA

# %%
medals_file.head()

# %%
medals_file.tail()

# %%
medals_file.columns

# %%
medals_file.describe()

# %%
medals_file.info()

# %%
coaches_file.head()

# %%
coaches_file.tail()

# %%
coaches_file.columns

# %%
coaches_file.describe()

# %%
coaches_file.info()

# %%
technical_officials_file = pd.read_csv("/kaggle/input/tokyo-2020-olympics/technical_officials.csv")

# %%
technical_officials_file.head()

# %%
technical_officials_file.tail()

# %%
technical_officials_file.columns

# %%
technical_officials_file.describe()

# %%
technical_officials_file.info()

# %%
athletes_file = pd.read_csv("/kaggle/input/tokyo-2020-olympics/athletes.csv")

# %%
athletes_file.head()

# %%
athletes_file.tail()

# %%
athletes_file.columns

# %%
athletes_file.describe()

# %%
athletes_file.info()

# %%
medals_total_file = pd.read_csv("/kaggle/input/tokyo-2020-olympics/medals_total.csv")

# %%
medals_total_file.head()

# %%
medals_total_file.tail()

# %%
medals_total_file.columns

# %%
medals_total_file.describe()

# %%
medals_total_file.info()
