# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Import the data.

# %%
df=pd.read_csv('/kaggle/input/telecom-us/telecom_users.csv',na_values=['','   ','  '])

# %% [markdown]
# # Understand the data and explore the data.
# # Clean the data and answer the following questions.

# %%
df

# %%
df.shape

# %%
df.columns

# %% [markdown]
# # Drop unnamed column

# %%
dff=df.drop('Unnamed: 0', axis=1)

# %%
dff

# %% [markdown]
# # Check correlaiton using seaborn

# %%
import seaborn as sns

# %%
sns.heatmap(dff.corr(),annot=True)

# %% [markdown]
# # Check null values

# %%
dff.isnull().sum()

# %% [markdown]
# # Find out the percentage of pensioners who are using fiber optics.

# %% [markdown]
# # 1. using seaborn  .. countplot

# %%
sns.countplot(x='InternetService', data=dff)

# %% [markdown]
# # 2. Using groupby

# %%
dff.groupby('InternetService').count()
v=dff.InternetService.value_counts()
v/v.sum()*100

# %% [markdown]
# # 3. Using Matplot

# %%
import matplotlib.pyplot as plt
plt.pie(v,labels=v.index,autopct='%.2f%%');

# %% [markdown]
#  # What percentages of people prefer phone services?

# %% [markdown]
# # 1. Using seaborn

# %%
sns.countplot(x='PhoneService',data=dff)

# %% [markdown]
# # 2. Using count

# %%
v2=dff.PhoneService.value_counts()
v2/v2.sum()*100

# %% [markdown]
# # Using matplot

# %%
plt.pie(v2,labels=v2.index,autopct='%.2f%%');

# %% [markdown]
# # Is the charges for the services are biased?

# %%
dff.plot(kind='box')

# %%
dff.TotalCharges

# %%
c=0
for i in dff.TotalCharges: 
    try:
        float(i)
        c=c+1
    except Exception as e:
        print(c)
        c=c+1

# %%
dff.iloc[356]

# %% [markdown]
# # using seaborn

# %%
sns.swarmplot(dff.PhoneService,dff.MonthlyCharges)

# %% [markdown]
#  # Who uses internet more? Married or unmarried?

# %% [markdown]
# # partner

# %%
v3=dff.Partner.value_counts()
v3

# %% [markdown]
# # internet service

# %%
v4=dff.InternetService.value_counts()
v4

# %%
x=df.groupby('Partner').apply(lambda x: x[x["InternetService"]==x["InternetService"]].count())
x

# %% [markdown]
# # remove (No) internet users internet service columns

# %%
data = dff.drop(dff.loc[dff.InternetService=='No'].index)
data

# %% [markdown]
# # Using groupby , check which are more using more internet services

# %%
x=data.groupby('Partner').apply(lambda x: x[x["InternetService"]==x["InternetService"]].count())
x

# %% [markdown]
# # Ans. Unmarried
