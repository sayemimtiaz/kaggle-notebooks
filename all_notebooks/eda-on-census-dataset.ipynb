# %% [markdown]
# # SUYASH PRATAP SINGH

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline                            
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#load the dataset
kp = pd.read_csv('/kaggle/input/india-census/india-districts-census-2011.csv')

# %%
#print first five columns
kp.head()

# %%
#print last five columns
kp.tail()

# %%
#print random five column
kp.sample(5)

# %%
#print shape of dataset
kp.shape

# %%
#print column of dataset
kp.columns

# %%
#print datatype of each column
kp.dtypes

# %%
#print index of dataset
kp.index

# %%
kp['State name'].unique()

# %%
kp.nunique()

# %%
#full information of dataset
kp.info()

# %%
#statistical information of dataset
kp.describe()

# %%
kp['State name'].value_counts()

# %%
teju = kp.cov()
teju

# %%
sns.distplot(kp.Cultivator_Workers, color = 'red')

# %%
#heatmap
sns.heatmap(teju,annot=True,vmin=.2,vmax=6)

# %%
#Histogram
kp.plot.hist(x='Male_Literate',y='Female_Literate')
plt.show()

# %%
#Scatterplot
kp.plot.scatter(x='Male_Literate',y='Female_Literate')
plt.show()

# %%
#barplot
kp[['Male_Literate','Female_Literate']].plot.bar()

# %%
#Boxplot
kp.plot.box(x='Male_Literate')
plt.show()

# %%
#print 2nd column of third and fourth row 
kp.iloc[2:4, 1:2]

# %%
#Checking for Null Values
kp.isnull().sum()

# %%
kp.notnull().sum()

# %%
sns.relplot(data = kp, x = "Male_Literate", y = "Female_Literate", color = 'purple')

# %%
sns.jointplot(data = kp, x = "Male_Literate", y = "Female_Literate")

# %%
sns.countplot(data = kp, x = "Male_Literate")

# %%
kp['Population'].plot.hist()

# %%
kp['Literate'].plot.hist(grid=True)

# %%
kp.plot.barh()

# %%
kp.plot.line(y=['Hindus','Christians','Muslims'],figsize=(10,4),lw=4)

# %%
kp.plot.scatter(x='Population',y='Male',c='Female',cmap='coolwarm')

# %%
kp['Workers'].plot.kde()

# %%
kp['Agricultural_Workers'].plot(figsize=(12,5))

# %%
kp['Cultivator_Workers'].plot(figsize=(12,5))
kp.rolling(window=15).mean()['Agricultural_Workers'].plot()

# %%
kp['Graduate_Education'].expanding().mean().plot(figsize=(12,5))

# %%
title = "Higher_Education"
xlabel = 'Male'
ylabel = 'Female'
ax = kp['Higher_Education'].plot.line(figsize=(10,4),ls=':',c='y',lw=3,title=title)
ax.set(xlabel=xlabel, ylabel=ylabel)

# %% [markdown]
# # SOME QUESTIONS:-

# %%
#Q1:How will you hide the indexes of the dataframe?
kp.style.hide_index()

# %%
#Q2:How can we set the caption/heading on the dataframe?
kp.style.set_caption('India Census 2011 dataset')

# %%
#Q3:Show the records related with the districts_New Delhi,Lucknow,Jaipur?
kp[kp['District name'].isin(['New Delhi','Lucknow','Jaipur'])]

# %%
#Q4: Calculate state_wise:-
#a)total number of population

#b)total number of population with different religions

kp.groupby('State name').Population.sum().sort_values(ascending=False)

# %%
kp.groupby('State name')['Hindus','Muslims','Christians','Jains'].sum().sort_values(by='Hindus')

# %%
#Q5:How to set a column as index of the dataframe?
kp.set_index('District code')

# %%
#Q6:Add a suffix to column name?
kp.add_suffix('_rightone')

# %%
#Q7:Add a prefix to column name?
kp.add_prefix('leftone_')

# %% [markdown]
# # THANK YOU
