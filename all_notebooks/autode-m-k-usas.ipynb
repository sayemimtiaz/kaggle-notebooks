# %% [markdown]
# <style>
# aside {
#   font-size: smaller;
#   margin-left:1cm;
# }
# </style>
# Antud tööleht on tehtud Tartu Ülikooli informaatika I kursuse tudengite Martin Suitsu ja William Strausi poolt. Töölehe eesmärgiks on arendada andmetöötlusoskust ja loovat mõtlemist.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# %matplotlib inline
pd.set_option('display.max_rows', 20)


df = pd.read_csv("../input/Car_sales.csv")
df

# %%
print("Keskmine võimsus(hobujõududes):", df["Horsepower"].mean())
print("Maksimaalne võimsus(hobujõududes):", df["Horsepower"].max())
print("Minimaalne võimsus(hobujõududes):", df["Horsepower"].min())

# %% [markdown]
#  **Hajusdiagramm**
# Järgmine hajusdiagramm näitab tabelis olevate autode mootorisuuruste ja võimsuste suhet

# %%
df.plot.scatter("Horsepower", "Engine_size", alpha=0.7);

# %% [markdown]
# Histogramm
#
# Järgmine histogramm näitab autode jaotumist kütusekulu põhjal, kus ühikuks on "miles per gallon", lühendiks "mpg". Kui meile harjumuspäraselt on parem kütusekulu, mida väiksem on see number. 30 mpg on säästlikum kui 15 mpg. 10l /100km on sama mis 23,52 mpg.

# %%
df.Fuel_efficiency.plot.hist(bins=19, grid=False, rwidth=0.90);
