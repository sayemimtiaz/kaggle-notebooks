# %%
li = [1,2,3]
li[0]=0
print(li)

# %%
st = {"a", "b", "c","a"}
print(st)

# %%
tp = (1,2,3,4,5)
print(tp)

# %%
dct = {
  "name": "Ramana",
  "course": "ECE",
  "year": 2022
}
print(dct)

# %%
class Test :
    def method_t(self):
        print("Hi")
  
obj = Test()
obj.method_t()

# %%
def func():
    print("Hi")
func()

# %%
import pandas as pd

# %%
datafile = pd.read_csv("../input/chess/games.csv")
datafile.head()

# %%
datafile.shape

# %%
lst = datafile.columns.values
print(lst)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 10, 100])
plt.plot(x, x, label='IOT Example Plot')
plt.legend()
plt.show()

# %%
xv = np.array([-4, 10, 12, 18])
yv = np.array([3, -8, 1, 10])

plt.plot(xv, yv)
plt.show()

# %%
plt.bar(datafile['winner'], datafile['turns'])
