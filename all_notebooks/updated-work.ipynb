# %%
import numpy as np
import pandas as pd
import plotly.express as px
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# Уберём ограничение на количство колонк при выводе
pd.set_option('display.max_columns', None)

# %%
# Импортируем данные
df = pd.read_csv('../input/credit-card-approval-prediction/application_record.csv')
df

# %%
# Удаляём ID,
df.drop(['ID'], axis=1, inplace=True)
df

# %%
# Выводим размеры датасета
df.shape

# %%
# Выводим информацию (т.к. много колонок, инорфмация выводится немного не в том виде, что надо, поэтому,чтобы получить хоте немного пользы вызовем краткую версию)
df.info(verbose = False)

# %%
# Выведем типы
df.dtypes

# %%
# Проверяем на пустоты
df.isnull().sum()

# %%
# Избавляемся от них
df['OCCUPATION_TYPE'].fillna('None', inplace=True)
df

# %%
# И проверяем ещё раз
df.isnull().sum()

# %%
# Успешно
df

# %%
df.hist(figsize=(14,12))

# %%
df.describe()

# %%
# Выведем корреляцию
df.corr()

# %%
# Выводим количество значений стобца NAME_FAMILY_STATUS
df.NAME_FAMILY_STATUS.value_counts()

# %%
# Преобразуем поля (пол,имеет ли машину,имеет ли недвижимость)
columns=['CODE_GENDER','FLAG_OWN_CAR','FLAG_OWN_REALTY','NAME_INCOME_TYPE','NAME_EDUCATION_TYPE','NAME_FAMILY_STATUS',
         'NAME_HOUSING_TYPE', 'OCCUPATION_TYPE']
df[columns] = df[columns].apply(lambda x: pd.factorize(x)[0])
df

# %%
df.dtypes

# %%
# Попытка вывести матрицу рассеивания через pandas.plotting.scatter_matrix отрабатывает с ошибками, предположительно из-за размера, поэтому используем аналог
fig = px.scatter_matrix(df,width=1500, height=1500)
fig.show()
