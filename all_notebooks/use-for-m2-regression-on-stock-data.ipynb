# %% [markdown]
# # Regression using Libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
import numpy as np
import pandas as pd
import seaborn as seabornInstance 
import matplotlib.pyplot as plt

# %%
dataset_HDFC=pd.read_csv('../input/nifty50-stock-market-data/HDFC.csv')

# %%
dataset_HDFC.describe()

# %% [markdown]
# Declaring values x and y
#
# x has the values that we will need to prdeict the value
#
# y has the value that needs to be predicted

# %%
x=dataset_HDFC[['High','Low','Open','Volume']].values
y=dataset_HDFC[['Close']].values

# %%
dataset_HDFC.plot(x='Date', y='Close', style='o')  
plt.title('Date of Sale vs Closing Price')  
plt.xlabel('Date')  
plt.ylabel('Closing Price')  
plt.show()

# %% [markdown]
# Graph to show maximum closing price

# %%
plt.figure(figsize=(15,10))
plt.tight_layout()
seabornInstance.distplot(dataset_HDFC['Close'])

# %% [markdown]
# Splitting the data into training and testing data

# %% [raw]
# x_test,x_train,y_test,y_train=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
regressor= LinearRegression()

# %% [markdown]
# Training the model

# %%
regressor.fit(x_train,y_train)

# %% [markdown]
# The model has been trained

# %%
print(regressor.coef_)

# %%
print(regressor.intercept_)

# %%
predicted = regressor.predict(x_test)

# %%
dataframe = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': predicted.flatten()})
dataframe

# %%
df1 = dataframe.head(50)
df1.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %% [markdown]
# The final step is to evaluate the performance of the algorithm. This step is particularly important to compare how well different algorithms perform on a particular dataset.

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test,predicted))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test,predicted))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test,predicted)))

# %% [markdown]
# # Regression without using Libraries
