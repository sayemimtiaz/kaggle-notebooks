# %% [markdown]
# # Overview: Players

# %%
# Pandas
import pandas as pd
# Plot
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('seaborn-whitegrid')
# %matplotlib inline

# %% [markdown]
# Read data

# %%
file = 'players.csv'
dataset_folder = '../input'

df = pd.read_csv('%s/%s' % (dataset_folder, file), sep='\t', encoding='utf-8')

# %% [markdown]
# ## Overview

# %%
print('number of players: %d' % (len(df)))
df.head(3)
# Out:
# number of players: 884302
#                id   ...      name
# 0     NolramImpro   ...    Nolram
# 1         SGK2017   ...        しげ
# 2  preamstrikbiz0   ...     primo
#
# [3 rows x 4 columns]

# %% [markdown]
# ### Flags

# %%
flags = df['flag'].value_counts().to_dict()
print('number of nationalities: %d' % (len(flags)))
# Out:
# number of nationalities: 82

# %% [markdown]
# Top-10 nationalities (by number of players)

# %%
# values
top = 10
labels = list(flags.keys())[0:top]
x_axis = range(len(labels))
y_axis = list(flags.values())[0:top]
print(list(zip(labels, y_axis)))

# plot
fig, ax = plt.subplots()
plt.bar(x_axis, y_axis, align='center')
plt.xticks(x_axis, labels, rotation=90)
plt.show()
# Out:
# [('US', 292471), ('JP', 286507), ('FR', 50212), ('DE', 48182), ('CA', 46110), ('GB', 37282), ('MX', 28017), ('ES', 22070), ('AU', 9651), ('NL', 9475)]

# %%
# plot
fig, ax = plt.subplots()
ax.pie(y_axis, labels=labels, autopct='%1.1f%%', shadow=True)
ax.axis('equal')
plt.show()
