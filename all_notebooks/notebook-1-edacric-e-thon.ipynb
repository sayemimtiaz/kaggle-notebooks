# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
match_data = pd.read_csv('/kaggle/input/skillsay-ai-crickethon-dataset/matches.csv')
delivary_data = pd.read_csv('/kaggle/input/skillsay-ai-crickethon-dataset/deliveries.csv')

# %%
match_data.head(10)

# %%
match_data.shape

# %%
match_data.info()

# %%
match_data.describe()

# %%
match_data.columns

# %%
match_data.nunique()    #fro uniue values

# %%
match_data['umpire3'].unique()

# %%
match_data['umpire2'].unique()

# %%
match_data['umpire1'].unique()

# %%
match_data.isnull().sum()   #sum of null values

# %%
match=match_data.drop(['city','umpire3','id'],axis=1)

# %%
match.head()

# %%
corelation=match.corr()

# %%
import seaborn as sns

# %%
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True)

# %%
sns.heatmap(corelation,annot=True)

# %%
sns.distplot(match['win_by_runs'])

# %%
sns.distplot(match['win_by_wickets'])

# %%
sns.catplot(x='win_by_runs',kind='box',data=match)

# %%
sns.countplot(match['winner'])

# %%
delivary_data.head(10)

# %%
delivary_data.tail()

# %%
delivary_data.shape

# %%
delivary_data.info()

# %%
delivary_data.describe()

# %%
delivary_data.nunique()

# %%
delivary_data.isnull().sum()

# %%
delivary_data['player_dismissed'].unique()

# %%
delivary_data['dismissal_kind'].unique()

# %%
delivary_data['fielder'].unique()

# %%
match_status=delivary_data.drop(['fielder','player_dismissed','dismissal_kind'],axis=1)

# %%
match_status.head()

# %%
match_status['is_super_over'].unique()

# %%
match_status['noball_runs'].unique()

# %%
corelation_deli=match_status.corr()

# %%
import seaborn as sns

# %%
sns.heatmap(corelation_deli,annot=True)

# %%
sns.distplot(match_status['total_runs'])

# %%
sns.catplot(x='total_runs',kind='box',data=match_status)

# %%
sns.countplot(match_status['is_super_over'])

# %%
sns.countplot(match_status['noball_runs'])

# %%
sns.countplot(match_status['wide_runs'])
