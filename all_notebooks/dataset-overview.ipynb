# %%
import pandas as pd
import IPython.display as ipd
df = pd.read_csv('../input/audio-dataset/audio_dataset/df.csv')
df.head()

# %%
path = '../input/audio-dataset/audio_dataset/'
i = 12345
display(df.iloc[i])
ipd.Audio(path+df['path'].iloc[i])

# %%
path = '../input/audio-dataset/audio_dataset/'
i = 54321
display(df.iloc[i])
ipd.Audio(path+df['path'].iloc[i])
