# %%
import pandas as pd
import numpy as np
from datetime import datetime
import seaborn as sns
# %matplotlib inline
sns.set_style('whitegrid')

# %%
df = pd.read_csv("../input/WIPRO.csv")

# %%
df.head()

# %%
df.set_index('Date', inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.head()

# %%
df.columns.names = ['Stock Info']

# %%
df.head()

# %%
df=df.drop(columns=['Adj Close'])
df=df.drop(columns=['Volume'])

# %%
list(df)

# %%
#Max Close price throughout the time period

# %%
df['Close'].max()

# %%
returns = pd.DataFrame()

# %%
returns[' Return'] = df['Close'].pct_change()
returns.head()

# %%
import seaborn as sns
sns.pairplot(df)

# %%
#Worst Drop

# %%
returns.idxmin()

# %%
#Best Single Day Gain

# %%
returns.idxmax()

# %%
#Standard deviation of the returns-The riskiest over the entire time period? 
#The riskiest for the year 2017?

# %%
returns.std()

# %%
returns.ix['2017-01-01':'2017-12-31'].std()

# %%
#Distplot using seaborn of the 2017 returns for Wipro

# %%
sns.distplot(returns.ix['2017-01-01':'2017-12-31'],color='green',bins=100)

# %%
#Distplot using seaborn of the 2005 returns for Wipro

# %%
sns.distplot(returns.ix['2005-01-01':'2005-12-31'],color='red',bins=100)

# %%
import matplotlib.pyplot as plt
import plotly
import cufflinks as cf
cf.go_offline()

# %%
#A line plot showing Close price for the entire index of time

# %%
 df['Close'].plot(figsize=(12,4),label='Close')
plt.legend()

# %%
#The rolling 30 day average against the Close Price for the year 2015 & 2017

# %%
plt.figure(figsize=(12,6))
df['Close'].ix['2015-01-01':'2017-01-01'].rolling(window=30).mean().plot(label='30 Day Avg')
df['Close'].ix['2015-01-01':'2017-01-01'].plot(label='Close')
plt.legend()

# %%
#Correlation between the stocks Prices

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(),annot=True)

# %%
 #Clustermap to cluster the correlations together

# %%
sns.clustermap(df.corr(),annot=True)
