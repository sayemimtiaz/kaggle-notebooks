# %%
import pandas as pd
ds = pd.read_csv("../input/cricket-players-faces/players.csv")

print("Number Of Players    : ",ds.player.nunique())
print("Number Of Images     : ",len(ds))

ds['player'].value_counts().plot.bar()
