# %% [markdown]
# # Explore Open Data from Los Angeles City
# # Museums Visitors - Arts & Culture

# %% [markdown]
# **Data Analytics**
# * Whaich museum has more vistors?
# * When should the museum staff additional seasonal employees?
# * Corvid19 impact on vistors numbers 2020/2021

# %% [markdown]
# <table>
# <tr>
# <td><img src="https://i.imgur.com/skaZPhb.png" width="350px"/></td>
# <td><img src="https://i.imgur.com/gaNttYd.png" width="350px"/></td>
# <td><img src="https://i.imgur.com/pampioh.png"/></td>
# <td><img src="https://i.imgur.com/OSbuszd.png"/></td>
#
# <!--<td><img src="https://i.imgur.com/ydaMhT1.png" width="350px"/></td>
# <td><img src="https://i.imgur.com/WLAqDSV.png" width="350px"/></td>
# <td><img src="https://i.imgur.com/Tj2y9gH.png"/></td>
# <td><img src="https://i.imgur.com/X0qXLCu.png"/></td>-->
# </tr>
# <tr>
# <td style="font-weight:bold; font-size:16px; text-align:left">Bar Chat</td>
# <td style="font-weight:bold; font-size:16px; text-align:left">Line Chart</td>
# <td style="font-weight:bold; font-size:16px; text-align:left">Area Chart</td>
# <td style="font-weight:bold; font-size:16px; text-align:left">Histogram</td>
# </tr>
# <tr>
# <td style="text-align:left">df.plot.bar()</td>
# <td style="text-align:left">df.plot.line()</td>
# <td style="text-align:left">df.plot.area()</td>
# <td style="text-align:left">df.plot.hist()</td>
# </tr>
# <tr>
# <td style="text-align:left">Good for nominal and small ordinal categorical data.</td>
# <td style="text-align:left">	Good for ordinal categorical and interval data.</td>
# <td style="text-align:left">Good for ordinal categorical and interval data.</td>
# <td style="text-align:left">Good for interval data.</td>
# </tr>
# </table>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

#================================================
# Add by me (Yasin)
pd.plotting.register_matplotlib_converters()
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# End of Add by me (Yasin)
#================================================

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# # Load Data
# using Month Column as index index_col display top 5 records using head()

# %%
museum_filepath = "/kaggle/input/los-angeles-museum-visitors/museum-visitors.csv"

# load data fom CSV file to variable museum_data

museum_data = pd.read_csv(museum_filepath, index_col="Month", parse_dates=True)
#museum_data = pd.read_csv(museum_filepath)
# replace all empty values NA's with 0
museum_data.head()

# %% [markdown]
# # Corvid19 / 2021 number of vistors !
# * Display last 5 records using tail()
# * Note that there is no visitors on 2021 maybe do to CORVID19 Virus

# %% [markdown]
# # Drop some columns to make it easier

# %%
museum_data = museum_data[['Avila Adobe', 'Chinese American Museum', 'Firehouse Museum',
                           'America Tropical Interpretive Center']]

# %% [markdown]
# # Convince the museum board
# The Firehouse Museum claims they ran an event in 2014 that brought an incredible number of visitors, and that they should get extra budget to run a similar event again. The other museums think these types of events aren't that important, and budgets should be split purely based on recent visitors on an average day.
#
# To show the museum board how the event compared to regular traffic at each museum, create a line chart that shows how the number of visitors to each museum evolved over time. Your figure should have four lines (one for each museum).

# %%
# Line chart showing the number of visitors to each museum over time
museum_data.plot()

# %% [markdown]
# # Plot Bar

# %%
museum_data.plot(kind='bar')
#museum_data['Avila Adobe'].value_counts().sort_values().plot.line()
#museum_data['Avila Adobe'].plot.hist()

# %% [markdown]
# # Plot line
# Create a line chart that shows how the number of visitors to Avila Adobe has evolved over time

# %% [markdown]
# **Plot Line Basic**

# %%
museum_data['Avila Adobe'].plot.line()

# %% [markdown]
# * **Plot Line more features **
# * **Add Title, more information to the above plot line chart**

# %%
# Set the width and height of the figure
plt.figure(figsize=(8,4))
# Add title
plt.title("Monthly / Annual Visitors to Avila Adobe")
# Line chart showing the number of visitors to Avila Adobe over time
sns.lineplot(data=museum_data['Avila Adobe'])
# Add label for horizontal axis
plt.xlabel("Date")

# %% [markdown]
# # Histogram

# %%
#plotHistogram(museum_data, 1, 2)
plt.title("Avila Adobe museum histogram")
museum_data['Avila Adobe'].plot(kind='hist'); 
#museum_data.plot(kind='hist');

# %% [markdown]
# # KDE Charts

# %%
#sns.kdeplot(museum_data['Avila Adobe']);
#museum_data['Avila Adobe'].plot.kde();
museum_data['Avila Adobe'].plot.kde(ind = np.arange(0, museum_data['Avila Adobe'].max()));

# %% [markdown]
# Does Avila Adobe get more visitors:
#
# in September-February (in LA, the fall and winter months), or
# in March-August (in LA, the spring and summer)?
#
# Using this information, when should the museum staff additional seasonal employees?
