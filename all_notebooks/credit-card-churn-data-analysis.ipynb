# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
cc = pd.read_csv('../input/credit-card-customers/BankChurners.csv')

# %%
cc.head()

# %%
cc.info() #This shows that there are no NULL values in the data set

# %%
#Lets analyse the Data
cc['Attrition_Flag'].value_counts()

# %%
cc.columns

# %%
#This will help us know no of males who have Attrited
len(cc[(cc['Attrition_Flag'] == 'Attrited Customer') & (cc['Gender'] == 'M')])

# %%
#This will help us know no of womens who have Attrited
len(cc[(cc['Attrition_Flag'] == 'Attrited Customer') & (cc['Gender'] == 'F')])

# %%
#Looks like more women are Attrited from CC

# %%
men_att = cc[(cc['Attrition_Flag'] == 'Attrited Customer') & (cc['Gender'] == 'M')]

# %%
women_att = cc[(cc['Attrition_Flag'] == 'Attrited Customer') & (cc['Gender'] == 'F')]

# %%
men_att['Education_Level'].value_counts()# Lets check if education is making any difference

# %%
women_att['Education_Level'].value_counts()

# %%
#Lets check martial status
men_att['Marital_Status'].value_counts()

# %%
women_att['Marital_Status'].value_counts()

# %%
#Lets have a look at income category
men_att['Income_Category'].value_counts()

# %%
women_att['Income_Category'].value_counts()

# %%
#Lets have a look at card category
men_att['Card_Category'].value_counts()

# %%
women_att['Card_Category'].value_counts()

# %%
#Lets have a look at inactive months before quitting
men_att['Months_Inactive_12_mon'].value_counts()

# %%
women_att['Months_Inactive_12_mon'].value_counts()

# %%
men_att['Avg_Utilization_Ratio'].value_counts()

# %%
women_att['Avg_Utilization_Ratio'].value_counts()

# %%
#In my point of view the major factor affecting the attrition rate is non usuage of the credit cards
