# %% [markdown]
# <div align="center">
#  <img src="https://raw.githubusercontent.com/matheusmota/dataviz2018/master/resources/images/logo_facens_pos.png" width="150px">
#  <h1> Dataviz - Data Science Specialization Program - FACENS</h1>
# </div>
# <br><br>
# # Aula1 | Exercício 2
# (valendo nota)
#
# * **Data de entrega:** 01/06/2019
# * **Professor:**  Matheus Mota
# * **Aluno:** Gustavo Crepaldi Batista
# * **RA:** 040183

# %% [markdown]
# ## Questão 1
# **Enunciado:**  Este notebook está associado ao *Kaggle Dataset* chamado "Aula1 | Exercício 2". Este *Kaggle Dataset* possui dois arquivos em formato CSV (anv.csv e BR_eleitorado_2016_municipio ). Escolha um dos datasets disponíveis e já conhecidos, a seu critério. Uma vez definido o csv, escolha no mínimo 7 e no máximo 12 variáveis (colunas) que você avalia como sendo relevantes. Para cada uma das suas variáveis escolhidas, forneça:
#
#
# ### Questão 1 - Item A - Classificação das variáveis
#
# Classifique todas as variáveis escolhidas, e construa um dataframe com sua resposta.
# Exemplo:

# %% [markdown]
# ### Questão 1 - Item B - Tabela de frequência
#
# Construa uma tabela de frequência para cada uma das **variáveis qualitativas** que você escolheu (caso não tenha escolhido nenhuma, deixe esta questão em branco). Uma dica: a função *value_counts()* do Pandas pode ser muito útil. =)

# %% [markdown]
# ### Questão 1 - Item C - Representação Gráfica
# Para cada uma das variáveis, produza um ou mais gráficos, usando matplotlib, que descreva seu comportamento / caracteristica. Lembre-se que estes gráficos precisam ser compatíveis com a classificação da variável.

# %% [markdown]
# # Dicas
#
# - Exemplo de acesso aos CSVs disponíveis no dataset
# > df = pd.read_csv('../input/anv.csv', delimiter=',')

# %%
import pandas as pd
import numpy as np

# %%
#Classifique todas as variáveis escolhidas, e construa um dataframe com sua resposta.
resposta = [["uf","Qualitativa Nominal"],["total_eleitores","Quantitativa Discreta"],["gen_feminino","Quantitativa Discreta"],["gen_masculino","Quantitativa Discreta"],["f_sup_79","Quantitativa Discreta"],["f_16","Quantitativa Discreta"],
            ["f_45_59","Quantitativa Discreta"],["f_25_34","Quantitativa Discreta"]]
resposta = pd.DataFrame(resposta, columns=["Variavel", "Classificação"])
resposta
# Out:
#           Variavel          Classificação
# 0               uf    Qualitativa Nominal
# 1  total_eleitores  Quantitativa Discreta
# 2     gen_feminino  Quantitativa Discreta
# 3    gen_masculino  Quantitativa Discreta
# 4         f_sup_79  Quantitativa Discreta
# 5             f_16  Quantitativa Discreta
# 6          f_45_59  Quantitativa Discreta
# 7          f_25_34  Quantitativa Discreta

# %%
# lendo o arquivo csv
df = pd.read_csv('../input/BR_eleitorado_2016_municipio.csv', delimiter=',')
# visualizando alguns dados do dataset
df.head(10)
# Out:
#    cod_municipio_tse  uf        ...         gen_masculino  gen_nao_informado
# 0              16691  RN        ...                  3082                  0
# 1              58033  RJ        ...                 43407                148
# 2              58386  RJ        ...                  3461                 11
# 3               6130  AP        ...                 14135                  0
# 4              91219  MT        ...                  6149                  0
# 5               7633  MA        ...                 29801                  0
# 6              88285  RS        ...                  1405                  0
# 7              75221  PR        ...                  7813                 14
# 8              44032  MG        ...                  4192                  4
# 9              67571  SP        ...                  2562                 11
#
# [10 rows x 17 columns]

# %%
# Analisando dados estatisticos do dataset
df.describe()
# Out:
#        cod_municipio_tse        ...          gen_nao_informado
# count        5568.000000        ...                5568.000000
# mean        51465.073096        ...                  17.101652
# std         29372.607385        ...                 205.704608
# min            19.000000        ...                   0.000000
# 25%         24248.000000        ...                   0.000000
# 50%         51241.500000        ...                   1.000000
# 75%         79202.500000        ...                   7.000000
# max         99074.000000        ...               13271.000000
#
# [8 rows x 15 columns]

# %%
# Analisando os tipos das colunas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5568 entries, 0 to 5567
# Data columns (total 17 columns):
# cod_municipio_tse    5568 non-null int64
# uf                   5568 non-null object
# nome_municipio       5568 non-null object
# total_eleitores      5568 non-null int64
# f_16                 5568 non-null int64
# f_17                 5568 non-null int64
# f_18_20              5568 non-null int64
# f_21_24              5568 non-null int64
# f_25_34              5568 non-null int64
# f_35_44              5568 non-null int64
# f_45_59              5568 non-null int64
# f_60_69              5568 non-null int64
# f_70_79              5568 non-null int64
# f_sup_79             5568 non-null int64
# gen_feminino         5568 non-null int64
# gen_masculino        5568 non-null int64
# gen_nao_informado    5568 non-null int64
# dtypes: int64(15), object(2)
# memory usage: 739.6+ KB

# %%
# verificando se existe campos com nulos
df.isnull().sum()
# Out:
# cod_municipio_tse    0
# uf                   0
# nome_municipio       0
# total_eleitores      0
# f_16                 0
# f_17                 0
# f_18_20              0
# f_21_24              0
# f_25_34              0
# f_35_44              0
# f_45_59              0
# f_60_69              0
# f_70_79              0
# f_sup_79             0
# gen_feminino         0
# gen_masculino        0
# gen_nao_informado    0
# dtype: int64

# %%
# DEixando o dataset somente com as colunas desejadas
df[resposta["Variavel"]]
# Out:
#       uf  total_eleitores  gen_feminino   ...     f_16  f_45_59  f_25_34
# 0     RN             6435          3353   ...      120     1363     1482
# 1     RJ            92990         49435   ...      193    23552    18136
# 2     RJ             7113          3641   ...       88     1646     1533
# 3     AP            27718         13583   ...      509     5343     7041
# 4     MT            11492          5343   ...      111     2754     2433
# 5     MA            65598         35797   ...      790    14752    16185
# 6     RS             2714          1309   ...       38      804      422
# 7     PR            15733          7906   ...      103     3606     3620
# 8     MG             8329          4133   ...       33     1986     1774
# 9     SP             5194          2621   ...       20     1353     1004
# 10    AM             6970          3267   ...      153     1213     1765
# 11    RJ            14272          7473   ...       78     3653     2780
# 12    BA            11656          5741   ...      185     2765     2442
# 13    SP             2664          1303   ...       23      636      519
# 14    MG             5393          2677   ...       45     1398     1064
# 15    SP           256516        136869   ...      282    63510    55040
# 16    RS             2928          1420   ...       26      897      500
# 17    BA            23335         12365   ...      120     4747     5864
# 18    PR             5843          2831   ...       72     1514     1021
# 19    PA            35705         17408   ...      622     6114     8838
# 20    SC             7655          3845   ...       79     2019     1550
# 21    SP             6659          3300   ...       31     1572     1362
# 22    CE             8638          4355   ...      151     2064     1561
# 23    SP            20876         10694   ...       47     5098     4450
# 24    SP            86030         44174   ...      147    22231    19173
# 25    AM            11193          5308   ...      198     1781     2987
# 26    MG             4162          1955   ...       36     1077      925
# 27    SP            24971         12928   ...       55     6183     5311
# 28    PB            19585         10135   ...      159     3921     4934
# 29    RS            27036         14124   ...       52     7234     4994
# ...   ..              ...           ...   ...      ...      ...      ...
# 5538  SP            39237         20345   ...       56     9994     8661
# 5539  MG             6185          2964   ...       95     1349     1436
# 5540  CE            13134          6723   ...      248     3082     2602
# 5541  SP            39847         20276   ...       95     9558     9181
# 5542  PB             4240          2161   ...       77      956     1002
# 5543  GO             8480          4238   ...       69     1780     1940
# 5544  BA             6877          3551   ...       82     1490     1497
# 5545  MG             6773          3205   ...       19     1894     1308
# 5546  SP            26022         13252   ...      112     6525     5508
# 5547  MG             4935          2395   ...       97      942     1147
# 5548  BA             4892          2396   ...       93      974     1198
# 5549  PR             4867          2338   ...       57      990     1141
# 5550  PI            17480          8905   ...      276     3605     4275
# 5551  PB             9299          4782   ...      171     2161     2015
# 5552  PB            14336          7594   ...      184     3033     3188
# 5553  PI             3413          1782   ...       72      669      726
# 5554  MG             9438          4614   ...       63     2228     1924
# 5555  RS            20043         10528   ...       71     5178     3822
# 5556  PB             7958          4058   ...      235     1600     1734
# 5557  MG             7823          3950   ...       60     1913     1573
# 5558  MT            31290         15347   ...      212     7514     6894
# 5559  BA            12172          6272   ...      136     2835     2556
# 5560  SC            21379         11131   ...      131     5375     4748
# 5561  BA            20200          9923   ...      278     3908     5291
# 5562  PA             6094          2867   ...       93     1305     1413
# 5563  AL             9834          4834   ...      265     1880     2353
# 5564  GO             5340          2686   ...      106     1192     1241
# 5565  BA           230598        124387   ...      743    52876    54067
# 5566  SP             7819          3901   ...       21     1968     1690
# 5567  MG            16251          8158   ...       72     4118     3197
#
# [5568 rows x 8 columns]

# %%
# Tabela de frequência da variavel qualitativa
frequencia =  df['uf'].value_counts()
frequencia
# Out:
# MG    853
# SP    645
# RS    497
# BA    417
# PR    399
# SC    295
# GO    246
# PI    224
# PB    223
# MA    217
# CE    184
# PE    184
# RN    167
# PA    144
# MT    141
# TO    139
# AL    102
# RJ     92
# MS     79
# ES     78
# SE     75
# AM     62
# RO     52
# AC     22
# AP     16
# RR     15
# Name: uf, dtype: int64

# %%
#Item C - Representação Gráfica
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#Totalizando a quantidade de eleitores femininas
total_fem = df['gen_feminino'].sum()
#Totalizando a qiuantidade de eleitores masculinos
total_masc = df['gen_masculino'].sum()
# Gerando grafico de pizza
fatias = [total_fem,total_masc]
labels = ['Eleitoras Femininas', 'Eleitores Masculinos']
cores  = ['m', 'b']

plt.title('Eleitores por Gêneros')
 
plt.pie(fatias, labels = labels, autopct='%1.1f%%' ,colors = cores, shadow = False)
 
plt.show()

# %% [markdown]
# ### Podemos observar que o eleitorado femenino é maior que o masculino no Brasil

# %%
# Criando dicionario para receber os dados dos eleitores por estados
dic_estados = {}
# Juntando os eleitores por estados
dic_estados['uf'] = df.groupby(by=['uf'])['total_eleitores'].sum()
# Criando e exibindo o grafico de barras
for i, v in dic_estados['uf'].items():
    plt.bar(i, v)
    plt.text(i, v, v, va='bottom', ha='center')
    
plt.title('Quantidade de Eleitores por Estados ')
plt.xlabel('Estados')
plt.style.use('seaborn')
plt.gca().axes.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# ### No gráfico acima mostra a quantidade de Eleitores por Estados, podemos observar que São Paulo concentra a maior parte do eleitorado brasileiro

# %%
# Grafico com as variaveis Quantitativa Discreta
x, y =["16","35 - 44","45 - 59",">79"], [df['f_16'].sum(), df['f_25_34'].sum(), df['f_45_59'].sum(),df['f_sup_79'].sum()]
# Criando um gráfico
plt.title("Quantidade de Eleitores por Idade")
plt.xticks(rotation='vertical')
plt.xlabel('Idades')
plt.ylabel('Quantidade (Milhões)')

plt.plot(x, y)
plt.show()

# %% [markdown]
# ### Neste grafico podemos observar que a faixa de idades de 45 a 59 anos são as que mais votaram em 2016, a quantidade vai aumentando até o pico maior, e depois tem uma grande queda na faixa de idades que não são obrigatórios a votar
