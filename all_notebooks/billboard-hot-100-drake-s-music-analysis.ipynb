# %% [markdown]
# # **Importing the Libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv('../input/billboard-the-hot-100-songs/charts.csv')

# %%
df.head()

# %%
df.info()

# %%
print("number of unique artists: \t", df['artist'].nunique())
print("number of unique songs: \t", df['song'].nunique())

# %% [markdown]
# #   **Checking the null values**

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df.fillna(0,inplace=True)
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# clearly its is visible that no null value exists, now we can move forward.

# %% [markdown]
# # **Adding year and month Column**

# %%
df['date'] = pd.to_datetime(df['date'])
df['Year'] = df['date'].apply(lambda time: time.year)
df['Month'] = df['date'].apply(lambda time: time.month)
df.head()

# %%
sns.heatmap(df.corr())

# %% [markdown]
# Not so great correlation, it was kind of obvious though🤷🏻

# %% [markdown]
# #  Artist with rank 1 songs who had the most appearances

# %%
a= pd.DataFrame(df[df['rank']==1]['artist'].value_counts().head(15))
a

# %% [markdown]
# # Rank 1 songs that held their 1st position for the longest

# %%
top15= pd.DataFrame(df[df['rank']==1][['song','artist']].value_counts().head(15))
top15

# %% [markdown]
# # **ANALYSIS ON DRAKE!!**
# Now it's time to analyze the career of the multi-talented man known by many names like Champangepapi, Drizzy, The meme-god himself😂

# %% [markdown]
# ![](https://images.complex.com/complex/images/c_fill,dpr_auto,f_auto,q_auto,w_1400/fl_lossy,pg_1/p2vzt3xvcxb8wbfzzdww/drake-top-boy-premiere?fimg-ssr-default)

# %% [markdown]
# # Okay jokes apart, lets begin

# %%
df[df['artist']=='Drake'].head(7) 
# clearly his 1st song on charts was "best i ever had" on 2009-05-23

# %% [markdown]
# # Drake's Music that were rank 1 for the longest

# %%
df[(df['artist']=='Drake') & (df['rank']==1)]['song'].value_counts()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x= df[(df['artist']=='Drake') & (df['rank']==1)]['song'],data=df, palette='viridis')

# %% [markdown]
# # Drake's Music that remained on the chart for the longest

# %%
z= df[df['artist']=='Drake'][['song','weeks-on-board']].groupby('song').max()
z.sort_values(by=['weeks-on-board'], inplace=False, ascending=False).head(15)

# %% [markdown]
# # Time based Analysis of Drake songs
# Based on the above DataFrame i have selected the top 3 songs,
# that are **Hotline Bling**, **God's Plan** and **Controlla**
#
#  I will be plotting each songs with respect to the ranks they had with the passing of the dates.

# %%
hotline_bling= df[(df['artist']=='Drake') & (df['song']=='Hotline Bling')][['date','rank']]
godsplan= df[(df['artist']=='Drake') & (df['song']=="God's Plan")][['date','rank']]
controlla= df[(df['artist']=='Drake') & (df['song']=="Controlla")][['date','rank']]

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 8))

hotline_bling.plot(ax=axes[0],x='date',y='rank',label='hotline bling')
plt.xlabel('Date')
plt.ylabel('rank')
#plt.title('hotline bling')



godsplan.plot(ax=axes[1],x='date',y='rank',label='gods plan', color='r')
plt.xlabel('Date')
plt.ylabel('rank')
#plt.title('gods plan')



controlla.plot(ax=axes[2],x='date',y='rank',label='controlla', color='g')
plt.xlabel('Date')
plt.ylabel('rank')
#plt.title('controlla')
