# %% [markdown]
# ![](https://fontmeme.com/permalink/210320/e05c8ebf977917c038f29cc9eda9247c.png)

# %% [markdown]
# ![](https://documentdesignfall17.files.wordpress.com/2017/08/game-of-thrones-logo.jpg?w=640)

# %% [markdown]
# Game of Thrones is an American fantasy drama television series created by David Benioff and D. B. Weiss for HBO. It is an adaptation of A Song of Ice and Fire, a series of fantasy novels by George R. R. Martin, the first of which is A Game of Thrones. The show was shot in the United Kingdom, Canada, Croatia, Iceland, Malta, Morocco, and Spain. It premiered on HBO in the United States on April 17, 2011, and concluded on May 19, 2019, with 73 episodes broadcast over eight seasons.
#
# Some informaton about GoT
#
# **Episode Count**: 73
#
# **No. Of Seasons**: 8
#
# **Run time**: 50–82 minutes
#
# **First Aired**: April 17, 2011
#
# **Last Aired**: May 19, 2019
#
# **Original Network**: HBO

# %% [markdown]
# ![](https://fontmeme.com/permalink/210320/3edc4869c07afd2b51eca8f2db6411a9.png)

# %% [markdown]
# Load the important required libraries

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ![](https://fontmeme.com/permalink/210320/4722f0b7aaf15fcf330b43e10eb48f90.png)

# %% [markdown]
#                                              Lets Load the Datasets

# %%
got_epi = pd.read_csv("../input/game-of-thrones/GOT_episodes_v4.csv")
got_char = pd.read_csv("../input/game-of-thrones/characters_v4.csv")

# %% [markdown]
# Checking first 5 and last 5 records from the datasets

# %%
got_epi.head(5)

# %%
got_epi.tail(5)

# %% [markdown]
# Let's check the duplicate data in data set

# %%
got_epi.duplicated().sum()

# %%
got_epi.shape

# %%
got_epi.info()

# %% [markdown]
# So, there **73** records in **18** columns. Also, there are no null records as well as duplicate values.

# %% [markdown]
# # Data Analysis On Got Character Data Set

# %% [markdown]
# Checking first 5 and last 5 records from the datasets

# %%
got_char.head(5)

# %%
got_char.tail(5)

# %% [markdown]
# **Let's check the duplicate data in data set.
# **

# %%
got_char.duplicated().sum()

# %%
got_char.shape

# %%
got_char.info()

# %% [markdown]
# So, there **832** records in **5** columns. Also, there are no null records as well as duplicate values.

# %% [markdown]
# # Exploratory Data Analysis - EDA

# %%
got_epi['Season'].value_counts().sort_index()

# %%
plt.figure(figsize=(10,5))
plt.xlabel("Season")
plt.title("Count of episodes")
sns.countplot(x = "Season", data = got_epi, palette='magma')

# %% [markdown]
# From above table and plot, we can observe that from Season 1 to Season 6 there were 10 epiosdes in each season. Season 7 had 7 and Season 8 had 6 episodes respectively.

# %%
got_season_duration = got_epi.groupby('Season').Duration.sum().to_frame().reset_index()
got_season_duration

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=got_season_duration.Season, y=got_season_duration.Duration, palette='GnBu')
plt.title('Total Duration of each Season', fontsize=15)
plt.xlabel('Duration')
plt.ylabel('Season')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.ylim(300, 600)

# %% [markdown]
# From above table and plot, longest season **1** is with **567** mins and shortest season **8** is with **420** mins. Also, not to forget the season 8 had less episodes compared to other seasons.

# %%
got_season_rating = got_epi.groupby('Season').mean().Rating.to_frame().reset_index()
got_season_rating.columns = ['Season','Average Rating']
got_season_rating = got_season_rating.sort_values('Average Rating', ascending=False)
got_season_rating

# %%
plt.figure(figsize=(10,5))
sns.barplot(y=got_season_rating.Season, x=got_season_rating['Average Rating'], palette='Wistia', orient='h')
plt.title('Avg IMDB Rating each Season', fontsize=15)
plt.xlabel('Avg Rating')
plt.ylabel('Season')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(5, 10)

# %% [markdown]
# From above table and plot, it is quite evident that **4th** season has the highest average rating followed by **1st** season while the last 8th season has the lowest average ratings.

# %%
got_season_pop_epi = got_epi[['Season','Title', 'Rating']].sort_values('Rating', ascending=False).head(15).reset_index(drop=True)
got_season_pop_epi

# %%
plt.figure(figsize=(10,5))
sns.barplot(y=got_season_pop_epi.Title, x=got_season_pop_epi.Rating, orient='h', palette='YlGn_r')
plt.title('Top 15 High-Rated Episodes', fontsize=15)
plt.xlabel('Rating')
plt.ylabel('Episodes')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(9, 10)

# %% [markdown]
# From above table and plot, it is quite evident that 4 episodes are rating almost 9.9 out of 10. That's massive. And out of those 4, 2 of them are from Season 6.

# %%
director_count = got_epi.groupby("Director").Title.count().sort_values(ascending=False)
director_count

# %%
director_count.count()

# %%
top10_dir = director_count.head(10).reset_index()
top10_dir

# %%
plt.figure(figsize=(18,5))
sns.barplot(x=top10_dir['Director'], y=top10_dir['Title'], palette='YlGnBu_r')
plt.title('Top 10 High-Rated Episodes', fontsize=15)
plt.xlabel('Directed By')
plt.ylabel('No Of Episodes')

# %% [markdown]
# David Nutter has directed the maximum no of episodes i.e 9.

# %% [markdown]
# Following are the director who directed less than 3 episodes.

# %%
director_les_3 = director_count.reset_index()
director_les_3.columns= ["Director","Episode Count"]

director_les_3 = director_les_3[director_les_3['Episode Count'] < 3]
director_les_3

# %%
director_les_3["Director"].count()

# %% [markdown]
# * So, there are 9 directors who directed less than 3 episodes of Game Of Thrones.

# %%
got_char_pop = got_char[['Character','Episodes_appeared']].sort_values('Episodes_appeared', ascending=False).head(15).reset_index(drop=True)
got_char_pop

# %%
plt.figure(figsize=(10,7))
sns.barplot(y=got_char_pop.Character, x=got_char_pop.Episodes_appeared, palette='afmhot', orient='h')
plt.title('Most Appearance By Character', fontsize=15)
plt.xlabel('Character')
plt.ylabel('Episodes')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# %% [markdown]
# Tyrion has appeared in maximum episodes followed by John, Cersi & Danny.

# %% [markdown]
# ![](https://hips.hearstapps.com/esq.h-cdn.co/assets/cm/15/06/54d41135e6fd5_-_tumblr_n5t3u6jghk1sh0yuao1_500.gif?resize=480:*)
