# %%
import pandas as pd
bank=pd.read_csv("../input/cusersmarildownloadsgermancsv/german.csv",sep=';' )
bank.head()

# %% [markdown]
# # Mapping of values

# %%
bank.info()

# %%
bank.Account_Balance.value_counts()*100 / len(bank)

# %%
bank=bank.replace({'Account_Balance' : { 1 : 'No Account', 2 : 'None',3: 'Below 200 DM',4:'200 DM or Above'}})
bank.Account_Balance.value_counts()*100 / len(bank)

# %%
bank.Payment_Status_of_Previous_Credit.value_counts()*100 / len(bank)

# %%
bank=bank.replace({'Payment_Status_of_Previous_Credit' : {0:'Delayed',1 : 'Other Credits', 2 : 'Paid Up',
                                                          3: 'No Problem with Current Credits',4:'Previous Credits Paid'}})
bank.Payment_Status_of_Previous_Credit.value_counts()*100 / len(bank)

# %%
bank.Value_Savings_Stocks.value_counts()*100 / len(bank)

# %%
bank=bank.replace({'Value_Savings_Stocks' : {1 : 'None', 2 : 'Below 100 DM',
                                                          3: '[100, 500)',4:'[500, 1000)',5:'Above 1000'}})
bank.Value_Savings_Stocks.value_counts()*100 / len(bank)

# %%
bank.Length_of_current_employment.value_counts()*100 / len(bank)

# %%
bank=bank.replace({'Length_of_current_employment' : {1 : 'Unemployed', 2 : '<1 Year',
                                                          3: '[1, 4)',4:'[4, 7)',5:'Above 7'}})
bank.Length_of_current_employment.value_counts()*100 / len(bank)

# %%
bank.Instalment_per_cent.value_counts()*100 / len(bank)

# %%
bank=bank.replace({'Instalment_per_cent' : {1 : 'Above 35%', 2 : '(25%, 35%)',
                                                          3: '[20%, 25%)',4:'Below 20%'}})
bank.Instalment_per_cent.value_counts()*100 / len(bank)

# %%
bank.Occupation.value_counts()*100 / len(bank)

# %%
bank=bank.replace({'Occupation' : {1 : 'Unemployed, unskilled', 2 : 'Unskilled Permanent Resident',
                                                          3: 'Skilled',4:'Executive'}})
bank.Occupation.value_counts()*100 / len(bank)

# %%
bank.Sex_Marital_Status.value_counts()*100 / len(bank)

# %%
bank=bank.replace({'Sex_Marital_Status' : {1 : 'Male, Divorced', 2 : 'Male, Single',
                                                          3: 'Male, Married/Widowed',4:'Female'}})
bank.Sex_Marital_Status.value_counts()*100 / len(bank)

# %%
bank.Duration_in_Current_address.value_counts()*100 / len(bank)

# %%
bank=bank.replace({'Duration_in_Current_address' : {1 : '<1 Year', 2 : '[1, 4)',
                                                          3: '[4, 7)',4:'Above 7'}})
bank.Duration_in_Current_address.value_counts()*100 / len(bank)

# %%
bank.Type_of_apartment.value_counts()*100 / len(bank)

# %%
bank=bank.replace({'Type_of_apartment' : {1 : 'Free', 2 : 'Rented',
                                                          3: 'Owned'}})
bank.Type_of_apartment.value_counts()*100 / len(bank)

# %%
bank.Most_valuable_available_asset.value_counts()*100 / len(bank)

# %%
bank=bank.replace({'Most_valuable_available_asset' : {1 : 'None', 2 : 'Car',
                                                          3: 'Life Insurance',4:'Real Estate'}})
bank.Most_valuable_available_asset.value_counts()*100 / len(bank)

# %%
bank.No_of_Credits_at_this_Bank.value_counts()*100 / len(bank)

# %%
bank=bank.replace({'No_of_Credits_at_this_Bank' : {1 : '1', 2 : '2 or 3',
                                                          3: '4 or 5',4:'Above 6'}})
bank.No_of_Credits_at_this_Bank.value_counts()*100 / len(bank)

# %%
bank.Guarantors.value_counts()*100 / len(bank)

# %%
bank=bank.replace({'Guarantors' : {1 : 'None', 2 : 'Co-applicant',
                                                          3: 'Guarantor'}})
bank.Guarantors.value_counts()*100 / len(bank)

# %%
bank.Concurrent_Credits.value_counts()*100 / len(bank)

# %%
bank=bank.replace({'Concurrent_Credits' : {1 : 'Other Banks', 2 : 'Dept. Store',
                                                          3: 'None'}})
bank.Concurrent_Credits.value_counts()*100 / len(bank)

# %%
bank.No_of_dependents.value_counts()*100 / len(bank)

# %%
bank=bank.replace({'No_of_dependents' : {1 : '3 or More', 2 : 'Less than 3'}})
bank.No_of_dependents.value_counts()*100 / len(bank)

# %%
bank.Telephone.value_counts()*100 / len(bank)

# %%
bank=bank.replace({'Telephone' : {1 : 'No', 2 : 'Yes'}})
bank.Telephone.value_counts()*100 / len(bank)

# %%
bank.Foreign_Worker.value_counts()*100 / len(bank)

# %%
bank=bank.replace({'Foreign_Worker' : {1 : 'No', 2 : 'Yes'}})
bank.Foreign_Worker.value_counts()*100 / len(bank)

# %%
bank.Purpose.value_counts()*100 / len(bank)

# %%
bank=bank.replace({'Purpose' : {0:'Other',1 : 'New Car', 2 : 'Used Car',
                               3:'Furniture',4:'Radio/TV',5:'Appliances',
                               6:'Repair',8:'Vacation',9:'Retraining',10:'Business'}})
bank.Purpose.value_counts()*100 / len(bank)

# %%
bank.info()

# %%
bank.nunique()

# %%
# !pip install pandas-profiling

# %%
from pandas_profiling import ProfileReport
ProfileReport(bank, title="EDA Report")

# %%
data = bank.sample(frac=0.95, random_state=42)
data_unseen = bank.drop(data.index)
data.reset_index(inplace=True, drop=True)
data_unseen.reset_index(inplace=True, drop=True)
print('Data for Modeling: ' + str(data.shape))

# %%
print('Unseen Data For Predictions: ' + str(data_unseen.shape))

# %%
# !pip install pycaret

# %%
from pycaret.classification import *

# %%
data.head()

# %%
def extract_cat_num(data):
    cat_col=[col for col in data.columns if data[col].dtype=='object']
    num_col=[col for col in data.columns if data[col].dtype!='object']
    return cat_col,num_col
cat_col,num_col=extract_cat_num(data)

# %%
for i in cat_col:
    print(i)
    print(data[i].value_counts()*100/len(data))
    print(" ")

# %%
data[cat_col].nunique().sort_values(ascending=False)

# %%
data.Creditability.value_counts()*100/len(data)

# %%
data[num_col].nunique()

# %%
num_col.remove('Creditability')
num_col

# %%
bank = setup(data = data, target = 'Creditability', 
                  normalize = True, 
                  transformation = True,
               train_size = 0.8, # training over 80% of available data
                  handle_unknown_categorical = True, 
                  unknown_categorical_method = 'most_frequent',
                  remove_multicollinearity = True, #rop one of the two features that are highly correlated with each other
                  ignore_low_variance = True,#all categorical features with statistically insignificant variances are removed from the dataset.
                  combine_rare_levels = True,# all levels in categorical features below the threshold defined in rare_level_threshold param are combined together as a single level
                  numeric_imputation='median',
                  categorical_imputation='mode',
            ordinal_features = {'Account_Balance':['No Account','None','Below 200 DM','200 DM or Above'],
                               'Value_Savings_Stocks':['None','Below 100 DM','[100, 500)','[500, 1000)','Above 1000'],
                               'Length_of_current_employment':['Unemployed','<1 Year','[1, 4)','[4, 7)','Above 7'],
                               'Instalment_per_cent':['Below 20%','[20%, 25%)','(25%, 35%)','Above 35%'],
                               'Occupation':['Unemployed, unskilled','Unskilled Permanent Resident','Skilled','Executive'],
                                'No_of_Credits_at_this_Bank':['1','2 or 3','4 or 5','Above 6'],
                                'No_of_dependents':['Less than 3','3 or More']
                               },
            fix_imbalance = True,
            numeric_features=num_col,
             session_id=1,)

# %%
best = compare_models()

# %%
gbc = create_model('gbc')

# %%
print(gbc)

# %%
tuned_gbc = tune_model(gbc,optimize = 'Accuracy')

# %%
plot_model(tuned_gbc, plot = 'auc')

# %%
plot_model(tuned_gbc, plot = 'pr')

# %%
plot_model(tuned_gbc, plot='feature')

# %%
plot_model(tuned_gbc, plot = 'confusion_matrix')

# %%
evaluate_model(tuned_gbc)

# %%
predict_model(tuned_gbc)

# %%
unseen_predictions = predict_model(tuned_gbc, data=data_unseen)
unseen_predictions.head()

# %%
print("Confidence Score :   {}".format(round(unseen_predictions.Score.mean(),2)))#Confidence Score

# %%
from pycaret.utils import check_metric
check_metric(unseen_predictions['Creditability'], unseen_predictions['Label'], metric = 'Accuracy')
