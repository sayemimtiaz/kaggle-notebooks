# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('../input/montcoalert/911.csv')

# %%
df.head()

# %%
df.shape

# %%
df.info()

# %%
df['zip'].value_counts().head(8)

# %%
df['twp'].value_counts().head()

# %%
twp=df['twp'].value_counts()

# %%
twp.sort_values(ascending=False)

# %%
df['title'].nunique()

# %%
df['title'].unique()

# %%
df[df['title']=='EMS: SUBJECT IN PAIN'].count()

# %%
df[df['title']=='EMS: SUBJECT IN PAIN'].count()['title']

# %%
x=df['title'].iloc[0]

# %%
print(x)
x.split(':')[0]

# %%
df['reason']=df['title'].apply(lambda title:title.split(':')[0])

# %%
df.head()

# %%
df['reason']

# %%
df['reason'].value_counts()

# %%
df.groupby('reason').count()

# %%
sns.countplot(data=df,x='reason')

# %%
df['timeStamp']

# %%
df['timeStamp'].iloc[0]

# %%
type(df['timeStamp'].iloc[0])

# %%
 df['timeStamp']=pd.to_datetime(df['timeStamp'])

# %%
type(df['timeStamp'].iloc[0])

# %%
time=df['timeStamp'].iloc[0]

# %%
time

# %%
time.hour

# %%
time.dayofweek

# %%
time.year

# %%
df['Hour']=df['timeStamp'].apply(lambda time:time.hour)
df['Dayofweek']=df['timeStamp'].apply(lambda time:time.dayofweek)
df['Month']=df['timeStamp'].apply(lambda time:time.month)
df['Year']=df['timeStamp'].apply(lambda time:time.year)

# %%
df.head()

# %%
df['Dayofweek'].unique()

# %%
Dic_dayofweek={0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}

# %%
df['Dayofweek']=df['Dayofweek'].map(Dic_dayofweek)

# %%
df.head()

# %%
sns.countplot(data=df,x='Dayofweek',hue='reason')
plt.legend(loc=(1.1,0.75))
