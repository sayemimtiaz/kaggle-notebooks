# %% [markdown]
# Import libraries and data

# %%
import pandas as pd
fraud_data_path = '../input/credit_fraud_sytn.csv'
fraud_data = pd.read_csv(fraud_data_path)
print("Setup Complete")

# %% [markdown]
# To see column names of the dataset

# %%
fraud_data.columns

# %% [markdown]
# See first five column of the data

# %%
fraud_data.head()

# %% [markdown]
# Y is our dependent variable, as we are trying to predict whether a transaction is fraudulent or non-fraudulent we selected isFraudulent variable as dependent variable
#
# X represents our models independent variable(s). We need to interpret the dataset and apply domain knowledge to define independent variables. Which factors are effecting the possiblity of fraud?

# %%
y = fraud_data.isFradulent
feature_names = ["Average Amount/transaction/day", "Transaction_amount", "isForeignTransaction",
                      "isHighRiskCountry"]
X = fraud_data[feature_names]

# %% [markdown]
# Descriptive statistics about independent variables

# %%
X.describe()

# %%
X.head()

# %% [markdown]
# Now we are building our  prediction model
# We are using oython machine learning library

# %%
from sklearn.tree import DecisionTreeRegressor
#specify the model. 
#For model reproducibility, set a numeric value for random_state when specifying the model
fraud_model = DecisionTreeRegressor(random_state=1)
# Fit the model
fraud_model.fit(X, y)

# %% [markdown]
# Finally we are asking for predictions.

# %%
print("Making predictions for the following 5 transactions:")
print(X.head())
print("The predictions are")
print(fraud_model.predict(X.head()))

# %% [markdown]
# Validation

# %%
from sklearn.metrics import mean_absolute_error

predicted_fraud = fraud_model.predict(X)
mean_absolute_error(y, predicted_fraud)

# %%
from sklearn.model_selection import train_test_split

# split data into training and validation data, for both features and target

train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)
# Define model
fraud_model = DecisionTreeRegressor()
# Fit model
fraud_model.fit(train_X, train_y)

# get predicted prices on validation data
val_predictions = fraud_model.predict(val_X)
print(mean_absolute_error(val_y, val_predictions))

# %% [markdown]
# Result looks quit fit.
