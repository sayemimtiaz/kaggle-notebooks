# %% [markdown]
# # Imports

# %% [markdown]
# Defining the problem:-
# predict the house prices based on the data in the USA_housing.csv ?
#
# what type of problem am i facing ?
# it is a regression problem,more specifically this is a linear regression problem
#
# why linear regression problem ?
# the features in the data i.e Avg. Area Income all are directly proportional to the the price of the house

# %%
import pandas as pd
import numpy as np

# %%
df_train=pd.read_csv("../input/usa-housingcsv/USA_Housing.csv")

# %%
df_train.head()

# %% [markdown]
# # exploratory data analysis

# %% [markdown]
# seeing if there is any missing data

# %%
df_train.info()

# %% [markdown]
# want to have a overview of the data ??

# %%
df_train.describe()

# %%
import seaborn as sns

# %% [markdown]
# want to see relation between every quantity in the data set

# %%
sns.pairplot(df_train)

# %% [markdown]
# see the corresponding column and row for insight and see if linear in nature with logic

# %% [markdown]
# # inferences from the graph
#
# how Avg. Area Income	Avg. Area House Age	Avg. Area Number of Rooms	Avg. Area Number of Bedrooms	Area Population are related to price ??
# 1.Avg. Area Income:- seems to be linear as the area increses it is common that the price of the house also increses the houses
#   having the area of 50000-75000 are more in the data set
#
# 2.Avg. Area House Age:- there are a lot of houses that are in range of 4 to 8 years of age in the same city and the houses which are
#   older are more costly
#
# 3.Area Number of Rooms:- there are rooms ranging from 5.0-8.5 beedrooms in houses and it is proportional to price
#
# 4.area population:-people are rich poeple

# %%
sns.distplot(df_train['Price'])

# %%
sns.heatmap(df_train.corr())

# %% [markdown]
# what i understood from correlation:-
#
# Pandas dataframe.corr() is used to find the pairwise correlation of all columns in the dataframe. Any na values are automatically excluded. For any non-numeric data type columns in the dataframe it is ignored.
#
# if the correlation is near to 1 then they are highly related to or proportional
#
# just see the last row u will understand how the price(output) is related to all the other features

# %%
USA_housing=df_train

# %%
X = USA_housing[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
               'Avg. Area Number of Bedrooms', 'Area Population']] # the input features 
y = USA_housing['Price'] # the target or output

# %% [markdown]
# # train test split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101) #validation data is of szie 0.3*total data set
#random state is for getting same output

# %% [markdown]
# We used the random_state parameter for reproducibility of the initial shuffling of training datasets after each epoch. when random_state set to an integer, train_test_split will return same results for each execution. when random_state set to an None, train_test_split will return different results for each execution

# %% [markdown]
# # Creating and Training the Model

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)

# %% [markdown]
# # Predictions

# %%
predictions = lm.predict(X_test)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(y_test,predictions)

# %% [markdown]
# # understanding metrics

# %% [markdown]
# https://towardsdatascience.com/a-beginners-guide-to-linear-regression-in-python-with-scikit-learn-83a8f7ae2b4f

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
