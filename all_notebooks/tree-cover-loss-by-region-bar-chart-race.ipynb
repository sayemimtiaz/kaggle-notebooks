# %% [markdown]
# # Bar Chart Race of Tree Cover Loss by Region
# * cf. https://www.dexplo.org/bar_chart_race/
# * cf. https://github.com/dexplo/bar_chart_race/

# %%
import sys
# !{sys.executable} -m pip install bar_chart_race

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import bar_chart_race as bcr
from IPython.display import HTML
import warnings
warnings.filterwarnings("ignore")
from IPython.display import Video

# %% [markdown]
# # Data preparation

# %%
data = pd.read_csv('../input/tree-cover-loss-20012020/TreeCoverLoss_2001-2020_ByRegion.csv')
data

# %%
data.columns

# %%
#data["date"] = data["date"].apply(pd.to_datetime, dayfirst=True)
data['Year']=data['Year'].apply(lambda x: str(x))
data2=data[['Year','CountryCode','TreeCoverLoss_ha','GrossEmissions_Co2_all_gases_Mg']].copy()
data2

# %% [markdown]
# # Dataframe for Bar Chart Race

# %%
# set double indexes
data2.set_index(['Year','CountryCode'])

# %%
# unstack!!!
data3=data2.set_index(['Year','CountryCode']).unstack()['TreeCoverLoss_ha']
data3

# %%
data4 = data3.fillna(0)
data4

# %% [markdown]
# # Create Bar Chart Race

# %%
df = data4
bcr.bar_chart_race(
    df=df,
    filename='TreeCoverLoss_BarChartRace.mp4',
    orientation='h',
    sort='desc',
    n_bars=10,
    fixed_order=False,
    fixed_max=False,
    steps_per_period=10,
    interpolate_period=False,
    label_bars=True,
    bar_size=.95,
    period_label={'x': .99, 'y': .10, 'ha': 'right', 'va': 'center'},
    #period_fmt='%B %d, %Y',
    period_summary_func=lambda v, r: {'x': .99, 'y': .18,'s': '',
                                      'ha': 'right', 'size': 8, 'family': 'Courier New'},
    perpendicular_bar_func='median',
    period_length=1000,
    figsize=(5, 3),
    dpi=500,
    cmap='dark24',
    title='Tree Cover Loss by Country',
    title_size=10,
    bar_label_size=7,
    tick_label_size=5,
    shared_fontdict={'color' : '.1'},
    scale='linear',
    writer=None,
    fig=None,
    bar_kwargs={'alpha': .7},
    filter_column_colors=True)

# %%
Video("/kaggle/working/TreeCoverLoss_BarChartRace.mp4", width=800, height=600, embed=True)
