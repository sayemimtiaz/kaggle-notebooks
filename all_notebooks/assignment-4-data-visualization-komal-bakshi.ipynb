# %% [markdown]
# # Assignment 4

# %% [markdown]
# **1. Import numpy and pandas**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **2.Import visualization libraries and set %matplotlib inline.**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# **3.Read in the csv file as a dataframe called df**

# %%
df = pd.read_csv('../input/montcoalert/911.csv')
df.drop(labels = 'e',axis=1,inplace=True)

# %% [markdown]
# **4. Check the info() of the df**

# %%
df.info()

# %% [markdown]
# **5.Check the head of df**

# %%
df.head()

# %% [markdown]
# **6.What are the top 5 zipcodes for 911 calls?**

# %%
df['zip'].value_counts().iloc[:5]

# %% [markdown]
# **7.What are the top 5 townships (twp) for 911 calls?**

# %%
df['twp'].value_counts().iloc[:5]

# %% [markdown]
# **8.Take a look at the 'title' column, how many unique title codes are there?**

# %%
df['title'].nunique()

# %% [markdown]
# **9.In the titles column there are "Reasons/Departments" specified before the title code. These are EMS, Fire, and Traffic. Use .apply() with a custom lambda expression to create a new column called "Reason" that contains this string value.**

# %%
df['Reason'] = df['title'].apply(lambda s:s.split(':')[0])
df['Reason'].head()

# %% [markdown]
# **10.What is the most common Reason for a 911 call based off of this new column?**

# %%
df['Reason'].value_counts()

# %% [markdown]
# **11.Now use seaborn to create a countplot of 911 calls by Reason.**

# %%
sns.countplot(x='Reason', data=df)

# %% [markdown]
# **12.
# Now let us begin to focus on time information. What is the data type of the objects in the timeStamp column?**

# %%
type(df['timeStamp'].iloc[0])

# %% [markdown]
# **13.You should have seen that these timestamps are still strings. Use pd.to_datetime to convert the column from strings to DateTime objects.**

# %%
df['timeStamp'] = pd.to_datetime(df['timeStamp'])

# %%
type(df['timeStamp'].iloc[0])

# %% [markdown]
# **14.You can use Jupyter's tab method to explore the various attributes you can call. Now that the timestamp column are actually DateTime objects, use .apply() to create 3 new columns called Hour, Month, and Day of Week**

# %%
time = df['timeStamp'].iloc[0]
time.hour

# %%
df['Hour'] = df['timeStamp'].apply(lambda time:time.hour)
df['Month'] = df['timeStamp'].apply(lambda time:time.month)
df['Year'] = df['timeStamp'].apply(lambda time:time.year)
df['Day of Week'] = df['timeStamp'].apply(lambda time:time.dayofweek)

# %%
df.sample()

# %% [markdown]
# **15.Notice how the Day of Week is an integer 0-6. Use the .map() with this dictionary to map the actual string names to the day of the week:**
#
# dmap = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}

# %%
dmap = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}

# %%
df['Day of Week'] = df['Day of Week'].apply(lambda int : dmap[int])

# %% [markdown]
# **16.Now use seaborn to create a countplot of the Day of Week column with the hue based off of the Reason column.**

# %%
sns.countplot(x='Day of Week', hue='Reason', data=df)
plt.legend(bbox_to_anchor=(1,1))

# %% [markdown]
# **17.Now do the same for Month.**

# %%
sns.countplot(x='Month', hue='Reason', data=df)
plt.legend(bbox_to_anchor=(1,1))

# %% [markdown]
# Some of the months are missing.

# %% [markdown]
# **18.Now create a simple plot off of the dataframe indicating the count of calls per month.**

# %%
byMonth = df.groupby(by='Month').count()
byMonth.head()

# %%
byMonth['lat'].plot()

# %%
sns.pointplot(x=byMonth.index, y = 'lat', data=byMonth, markers='.')

# %% [markdown]
# **19.Now see if you can use seaborn's lmplot() to create a linear fit on the number of calls per month. Keep in mind you may need to reset the index to a column**

# %%
byMonth['Month'] = byMonth.index
byMonth

# %%
sns.lmplot(x='Month', y='lat', data=byMonth)

# %% [markdown]
# * This linear line across our plot is the best available fit for the trend of the latitude usually 911 calls come from give with respect to the Month.
# * We can also see some outliers lying outside the shaded region.
# * The converging of the shaded region indicates the maximum data lies in that region (statistical mean lies in this region)

# %% [markdown]
# **20.Create a new column called 'Date' that contains the date from the timeStamp column. You'll need to use apply along with the .date() method.**

# %%
df['Date'] = df['timeStamp'].apply(lambda time:time.date())
df['Date'].head()

# %% [markdown]
# **21.Now groupby this Date column with the count() aggregate and create a plot of counts of 911 calls.**

# %%
df.groupby(by='Date').count()['lat'].plot()
plt.tight_layout()

# %% [markdown]
# **22.Now recreate this plot but create 3 separate plots with each plot representing a Reason for the 911 call**

# %%
df[df['Reason']=='Traffic'].groupby(by='Date').count()['lat'].plot()
plt.title('Traffic')

# %%
df[df['Reason']=='Fire'].groupby(by='Date').count()['lat'].plot()
plt.title('Fire')

# %%
df[df['Reason']=='EMS'].groupby(by='Date').count()['lat'].plot()
plt.title('EMS')

# %% [markdown]
# **23.Now let's move on to creating heatmaps with seaborn and our data. We'll first need to restructure the dataframe so that the columns become the Hours and the Index becomes the Day of the Week. There are lots of ways to do this, but I would recommend trying to combine groupby with an unstack method. Reference the solutions if you get stuck on this! Create Whisker plot and Histogram on any column in data.**

# %%
dfGrid = df.groupby(by=['Day of Week','Hour']).count()['lat'].unstack()
dfGrid = dfGrid.loc[['Sun','Mon','Tue','Wed','Thu','Fri','Sat']]
dfGrid

# %%
#HeatMap
plt.figure(figsize=(12,6))
sns.heatmap(dfGrid, cmap='viridis',linewidths=1)

# %% [markdown]
# The .clustermap() method uses a hierarchical clusters to order data by similarity. This reorganizes the data for the rows and columns and displays similar content next to one another for even more depth of understanding the data.

# %%
#ClusterMap
sns.clustermap(dfGrid, cmap='viridis',linewidths=1)

# %% [markdown]
# From the above clusterMap we can see that the 15:00-16:00 have the highest figures.

# %% [markdown]
# **Same procedure for Month**

# %%
dfMonth = df.groupby(['Day of Week','Month']).count()['lat'].unstack()
dfMonth = dfMonth.loc[['Sun','Mon','Tue','Wed','Thu','Fri','Sat']]
dfMonth

# %%
#HeatMap
plt.figure(dpi=100)
sns.heatmap(dfMonth, cmap='viridis',linewidths=1)

# %%
plt.figure(dpi=100)
sns.clustermap(dfMonth, cmap='viridis',linewidths=1)

# %% [markdown]
# 911 calls group by reason year wise

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=df['Year'],data=df,hue=df['Reason'],palette='bright')
plt.title("911 calls category groupby reason for year")
plt.legend(loc=2, bbox_to_anchor=(1.05, 1))

# %% [markdown]
# We can see that 2015, cases very low and after 2016 the 911 emergency calls have shot up.
