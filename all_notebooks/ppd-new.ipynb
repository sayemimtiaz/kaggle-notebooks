# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np 
import pandas as pd 
from sklearn.svm import SVC
from time import time  # measure running time
from sklearn.neural_network import MLPClassifier  # neural network
from sklearn.model_selection import train_test_split  # split train test size
from sklearn.naive_bayes import BernoulliNB, GaussianNB  # naive bayesian
from sklearn.metrics import roc_auc_score, accuracy_score, confusion_matrix  # metrics
from sklearn.ensemble import RandomForestClassifier, VotingClassifier  # ensemble methods

# %%
d_train = pd.read_csv('../input/ppd-for-xuecheng/PPDtrain-en.csv')
d_test = pd.read_csv('../input/ppd-for-xuecheng/PPDtrain-en.csv')

# %%
d_train['UserInfo_2']=d_train['UserInfo_2'].replace(['chongqing','shanghai','guangzhou','shenzhen','beijing','tianjin'],1) 
d_train['UserInfo_2']=d_train['UserInfo_2'].replace(['xian', 'fuzhou','foshan', 'haerbin','shijiazhuang','wenzhou' ,'zhengzhou','chengdu' ,'qingdao', 'ningbo','kunming','hangzhou','hefei','xiamen','wuhan' , 'zibo','changchun','shenyang', 'changsha','suzhou' ,'wuxi','jinan','taiyuan','dalian','nanjing','nanchang', 'tangshan','yantai',],2) 
d_train['UserInfo_2']=d_train['UserInfo_2'].replace(['yueyang','liaocheng','binzhou','quanzhou','haikou','baoding','liuzhou','lanzhou','huaian','shaoxing', 'weihai','wuhu', 'zhuhai' , 'jining','jilinshi' , 'yichang','cangzhou', 'jiangmen','daqing' ,'zhanjiang' ,'nanning','mianyang','huizhou','taian','zhongshan','xuzhou','yinchuan','taizhou','nantong','zhangzhou','baotou','yancheng','heze','changzhou','yangzhou','handan','guiyang','jiaxing','changde' ,'linyi', 'jingdezhen','langfang','zhenjiang','weifang','dezhou','xiangyang','wulumuqi','baoji','dongying','xining','huhehaote','maoming','nanyang'],3) 
d_train['UserInfo_2']=d_train['UserInfo_2'].replace([ 'jincheng','jincheng','yiyang','yuncheng','shangqiu', 'jieyang','jingzhou','longyan','xinxiang','xiangtan','qingyuan','yuxi' ,'linfen','ningde' ,'yulin','changzhi','sanming','zhaoqing','nanping', 'panjin','jinzhong','loudi', 'suqian','hulunbeier','anyang','lvliang','xuchang','shaoguan','yongzhou','tongliao' ,'yichun','shangrao','zhoukou','chifeng','jinzhou','nanchong','xianyang','puyang','fuyang','zaozhuang','yangjiang','shantou','zhangjiakou','ganzhou','lianyungang','siping','huzhou','anqing','chuzhou','pingdingshan','guilin','leshan','dazhou','xinyang','qujing' ,'huangshi','putian','tieling', 'chengde','bijie', 'jiujiang','benxi','neijiang','jiaozuo','xingtai','xiaogan','qinhuangdao','luan','weinan','sanmenxia','liaoyang','zunyi','rizhao','tonghua','lishui','kaifeng','huanggang','shuozhou','jingmen','zhuzhou','ziyang','shiyan','songyuan','jian','shaoyang','maanshan','quzhou','yanan','panzhihua','mudanjiang','deyang','luzhou','dandong','zhumadian','zigong','yingkou','suihua','bangbu','datong','hengshui','yibin','chaoyang','fushun'],4) 
d_train['UserInfo_2']=d_train['UserInfo_2'].replace([ 'heyuan', 'changjihuizuzizhizhou','qitaihe', 'zhoushan','xiangfan','tongren','huainan','ezhou', 'xilinguolemeng' ,'dongguan','wuwei','liupanshui','hengyang','tongling', 'shanwei', 'hechi','yangquan', 'huangshan','bazhong','dehongdaizujingpozuzizhizhou' ,'jinhua', 'pingxiang' ,'dingxi' ,'luoyang' ,'xinzhou','baishan','baoshan','jiuquan','xinganmeng','qihaihe','zhaotong','qinzhou','fuxin','qiannan','chuxiongyizuzizhizhou','xishuangbannadaizuzizhizhou' , 'xiangxitujiazumiaozuzizhizhou' ,'anshan','honghehanizuyizuzizhizhou' ,'qiandongnan','daxinganling','yanbianchaoxianzuzizhizhou' ,'lijiang' ,'laiwu','hanzhong','kelamayi', 'xuancheng','huaibei', 'huaihua','chenzhou','chizhou','bozhou','baise','beihai','luohe','qianxinan','linxiahuizuzizhizhou','qiqihaer','chaozhou', 'bayannaodongmeng','anshun','lincang','zhousan','huludao','kashi','lincheng','dongdongdongsi','wuzhong','yunfu','wuhai','tianshui', 'yilihasakezizhizhou','shizuishan', 'bayinguolengmengguzizhizhou' , 'wenshanzhuangzumiaozuzizhizhou','suining' , 'xinyu', 'wuzhou' ,'longnan','xianning','jeyuan','guangyuan','qingyang','zhangjiajie','meizhou','yingtan','shihezi','zhangye','chaohu','heihe','jiayuguan','baiyin' ,'meishan', 'baicheng', 'chongzuo' , 'guangan' ,'yaan', 'hebi', 'shangluo' ,'hegang' ,'fangchenggang' ,'liangshan' ,'hami' ,'tongchuan' ,'akesu', 'dalibaizuzizhizhou' ,'abazangzuqiangzuzizhizhou' ,'ankang', 'suizhou' ,'jiamusi', 'jixi' ,'wulanchabumeng' , 'haibeicangzuzizhizhou' ,'alashanmeng' ,'shuangyashan' ,'pingliang' ,'hezhou', 'shannan' ,'tulufan' ,'dongshi', 'guigang', 'ganzicangzuzizhizhou', 'haiximengguzucangzuzizhizhou', 'bodongtalamengguzizhizhou' ,'guyuan', 'liaoyuan', 'haidong', 'kezilesukedongkezizizhizhou' ,'laibin', 'linzhi' ,'changdu' ,'jinchang', 'lasa', 'hetian' ,'diqingcangzuzizhizhou' ,'jiyuan' ,'gannanzangzuzizhizhou'],5)

# %%
d_test['UserInfo_2']=d_test['UserInfo_2'].replace(['chongqing','shanghai','guangzhou','shenzhen','beijing','tianjin'],1) 
d_test['UserInfo_2']=d_test['UserInfo_2'].replace(['xian', 'fuzhou','foshan', 'haerbin','shijiazhuang','wenzhou' ,'zhengzhou','chengdu' ,'qingdao', 'ningbo','kunming','hangzhou','hefei','xiamen','wuhan' , 'zibo','changchun','shenyang', 'changsha','suzhou' ,'wuxi','jinan','taiyuan','dalian','nanjing','nanchang', 'tangshan','yantai',],2) 
d_test['UserInfo_2']=d_test['UserInfo_2'].replace(['yueyang','liaocheng','binzhou','quanzhou','haikou','baoding','liuzhou','lanzhou','huaian','shaoxing', 'weihai','wuhu', 'zhuhai' , 'jining','jilinshi' , 'yichang','cangzhou', 'jiangmen','daqing' ,'zhanjiang' ,'nanning','mianyang','huizhou','taian','zhongshan','xuzhou','yinchuan','taizhou','nantong','zhangzhou','baotou','yancheng','heze','changzhou','yangzhou','handan','guiyang','jiaxing','changde' ,'linyi', 'jingdezhen','langfang','zhenjiang','weifang','dezhou','xiangyang','wulumuqi','baoji','dongying','xining','huhehaote','maoming','nanyang'],3) 
d_test['UserInfo_2']=d_test['UserInfo_2'].replace([ 'jincheng','jincheng','yiyang','yuncheng','shangqiu', 'jieyang','jingzhou','longyan','xinxiang','xiangtan','qingyuan','yuxi' ,'linfen','ningde' ,'yulin','changzhi','sanming','zhaoqing','nanping', 'panjin','jinzhong','loudi', 'suqian','hulunbeier','anyang','lvliang','xuchang','shaoguan','yongzhou','tongliao' ,'yichun','shangrao','zhoukou','chifeng','jinzhou','nanchong','xianyang','puyang','fuyang','zaozhuang','yangjiang','shantou','zhangjiakou','ganzhou','lianyungang','siping','huzhou','anqing','chuzhou','pingdingshan','guilin','leshan','dazhou','xinyang','qujing' ,'huangshi','putian','tieling', 'chengde','bijie', 'jiujiang','benxi','neijiang','jiaozuo','xingtai','xiaogan','qinhuangdao','luan','weinan','sanmenxia','liaoyang','zunyi','rizhao','tonghua','lishui','kaifeng','huanggang','shuozhou','jingmen','zhuzhou','ziyang','shiyan','songyuan','jian','shaoyang','maanshan','quzhou','yanan','panzhihua','mudanjiang','deyang','luzhou','dandong','zhumadian','zigong','yingkou','suihua','bangbu','datong','hengshui','yibin','chaoyang','fushun'],4) 
d_test['UserInfo_2']=d_test['UserInfo_2'].replace([ 'heyuan', 'changjihuizuzizhizhou','qitaihe', 'zhoushan','xiangfan','tongren','huainan','ezhou', 'xilinguolemeng' ,'dongguan','wuwei','liupanshui','hengyang','tongling', 'shanwei', 'hechi','yangquan', 'huangshan','bazhong','dehongdaizujingpozuzizhizhou' ,'jinhua', 'pingxiang' ,'dingxi' ,'luoyang' ,'xinzhou','baishan','baoshan','jiuquan','xinganmeng','qihaihe','zhaotong','qinzhou','fuxin','qiannan','chuxiongyizuzizhizhou','xishuangbannadaizuzizhizhou' , 'xiangxitujiazumiaozuzizhizhou' ,'anshan','honghehanizuyizuzizhizhou' ,'qiandongnan','daxinganling','yanbianchaoxianzuzizhizhou' ,'lijiang' ,'laiwu','hanzhong','kelamayi', 'xuancheng','huaibei', 'huaihua','chenzhou','chizhou','bozhou','baise','beihai','luohe','qianxinan','linxiahuizuzizhizhou','qiqihaer','chaozhou', 'bayannaodongmeng','anshun','lincang','zhousan','huludao','kashi','lincheng','dongdongdongsi','wuzhong','yunfu','wuhai','tianshui', 'yilihasakezizhizhou','shizuishan', 'bayinguolengmengguzizhizhou' , 'wenshanzhuangzumiaozuzizhizhou','suining' , 'xinyu', 'wuzhou' ,'longnan','xianning','jeyuan','guangyuan','qingyang','zhangjiajie','meizhou','yingtan','shihezi','zhangye','chaohu','heihe','jiayuguan','baiyin' ,'meishan', 'baicheng', 'chongzuo' , 'guangan' ,'yaan', 'hebi', 'shangluo' ,'hegang' ,'fangchenggang' ,'liangshan' ,'hami' ,'tongchuan' ,'akesu', 'dalibaizuzizhizhou' ,'abazangzuqiangzuzizhizhou' ,'ankang', 'suizhou' ,'jiamusi', 'jixi' ,'wulanchabumeng' , 'haibeicangzuzizhizhou' ,'alashanmeng' ,'shuangyashan' ,'pingliang' ,'hezhou', 'shannan' ,'tulufan' ,'dongshi', 'guigang', 'ganzicangzuzizhizhou', 'haiximengguzucangzuzizhizhou', 'bodongtalamengguzizhizhou' ,'guyuan', 'liaoyuan', 'haidong', 'kezilesukedongkezizizhizhou' ,'laibin', 'linzhi' ,'changdu' ,'jinchang', 'lasa', 'hetian' ,'diqingcangzuzizhizhou' ,'jiyuan' ,'gannanzangzuzizhizhou'],5)

# %%
d_train['UserInfo_4']=d_train['UserInfo_4'].replace(['chongqing','shanghai','guangzhou','shenzhen','beijing','tianjin'],1) 
d_train['UserInfo_4']=d_train['UserInfo_4'].replace(['xian', 'fuzhou','foshan', 'haerbin','shijiazhuang','wenzhou' ,'zhengzhou','chengdu' ,'qingdao', 'ningbo','kunming','hangzhou','hefei','xiamen','wuhan' , 'zibo','changchun','shenyang', 'changsha','suzhou' ,'wuxi','jinan','taiyuan','dalian','nanjing','nanchang', 'tangshan','yantai',],2) 
d_train['UserInfo_4']=d_train['UserInfo_4'].replace(['yueyang','liaocheng','binzhou','quanzhou','haikou','baoding','liuzhou','lanzhou','huaian','shaoxing', 'weihai','wuhu', 'zhuhai' , 'jining','jilinshi' , 'yichang','cangzhou', 'jiangmen','daqing' ,'zhanjiang' ,'nanning','mianyang','huizhou','taian','zhongshan','xuzhou','yinchuan','taizhou','nantong','zhangzhou','baotou','yancheng','heze','changzhou','yangzhou','handan','guiyang','jiaxing','changde' ,'linyi', 'jingdezhen','langfang','zhenjiang','weifang','dezhou','xiangyang','wulumuqi','baoji','dongying','xining','huhehaote','maoming','nanyang'],3) 
d_train['UserInfo_4']=d_train['UserInfo_4'].replace([ 'jincheng','jincheng','yiyang','yuncheng','shangqiu', 'jieyang','jingzhou','longyan','xinxiang','xiangtan','qingyuan','yuxi' ,'linfen','ningde' ,'yulin','changzhi','sanming','zhaoqing','nanping', 'panjin','jinzhong','loudi', 'suqian','hulunbeier','anyang','lvliang','xuchang','shaoguan','yongzhou','tongliao' ,'yichun','shangrao','zhoukou','chifeng','jinzhou','nanchong','xianyang','puyang','fuyang','zaozhuang','yangjiang','shantou','zhangjiakou','ganzhou','lianyungang','siping','huzhou','anqing','chuzhou','pingdingshan','guilin','leshan','dazhou','xinyang','qujing' ,'huangshi','putian','tieling', 'chengde','bijie', 'jiujiang','benxi','neijiang','jiaozuo','xingtai','xiaogan','qinhuangdao','luan','weinan','sanmenxia','liaoyang','zunyi','rizhao','tonghua','lishui','kaifeng','huanggang','shuozhou','jingmen','zhuzhou','ziyang','shiyan','songyuan','jian','shaoyang','maanshan','quzhou','yanan','panzhihua','mudanjiang','deyang','luzhou','dandong','zhumadian','zigong','yingkou','suihua','bangbu','datong','hengshui','yibin','chaoyang','fushun'],4) 
d_train['UserInfo_4']=d_train['UserInfo_4'].replace([  'naqu', 'hainanzangzuzizhizhou', 'rikaze','guoluozangzuzizhizhou','heyuan', 'changjihuizuzizhizhou','qitaihe', 'zhoushan','xiangfan','tongren','huainan','ezhou', 'xilinguolemeng' ,'dongguan','wuwei','liupanshui','hengyang','tongling', 'shanwei', 'hechi','yangquan', 'huangshan','bazhong','dehongdaizujingpozuzizhizhou' ,'jinhua', 'pingxiang' ,'dingxi' ,'luoyang' ,'xinzhou','baishan','baoshan','jiuquan','xinganmeng','qihaihe','zhaotong','qinzhou','fuxin','qiannan','chuxiongyizuzizhizhou','xishuangbannadaizuzizhizhou' , 'xiangxitujiazumiaozuzizhizhou' ,'anshan','honghehanizuyizuzizhizhou' ,'qiandongnan','daxinganling','yanbianchaoxianzuzizhizhou' ,'lijiang' ,'laiwu','hanzhong','kelamayi', 'xuancheng','huaibei', 'huaihua','chenzhou','chizhou','bozhou','baise','beihai','luohe','qianxinan','linxiahuizuzizhizhou','qiqihaer','chaozhou', 'bayannaodongmeng','anshun','lincang','zhousan','huludao','kashi','lincheng','dongdongdongsi','wuzhong','yunfu','wuhai','tianshui', 'yilihasakezizhizhou','shizuishan', 'bayinguolengmengguzizhizhou' , 'wenshanzhuangzumiaozuzizhizhou','suining' , 'xinyu', 'wuzhou' ,'longnan','xianning','jeyuan','guangyuan','qingyang','zhangjiajie','meizhou','yingtan','shihezi','zhangye','chaohu','heihe','jiayuguan','baiyin' ,'meishan', 'baicheng', 'chongzuo' , 'guangan' ,'yaan', 'hebi', 'shangluo' ,'hegang' ,'fangchenggang' ,'liangshan' ,'hami' ,'tongchuan' ,'akesu', 'dalibaizuzizhizhou' ,'abazangzuqiangzuzizhizhou' ,'ankang', 'suizhou' ,'jiamusi', 'jixi' ,'wulanchabumeng' , 'haibeicangzuzizhizhou' ,'alashanmeng' ,'shuangyashan' ,'pingliang' ,'hezhou', 'shannan' ,'tulufan' ,'dongshi', 'guigang', 'ganzicangzuzizhizhou', 'haiximengguzucangzuzizhizhou', 'bodongtalamengguzizhizhou' ,'guyuan', 'liaoyuan', 'haidong', 'kezilesukedongkezizizhizhou' ,'laibin', 'linzhi' ,'changdu' ,'jinchang', 'lasa', 'hetian' ,'diqingcangzuzizhizhou' ,'jiyuan' ,'gannanzangzuzizhizhou'],5)

# %%
d_test['UserInfo_4']=d_test['UserInfo_4'].replace(['chongqing','shanghai','guangzhou','shenzhen','beijing','tianjin'],1) 
d_test['UserInfo_4']=d_test['UserInfo_4'].replace(['xian', 'fuzhou','foshan', 'haerbin','shijiazhuang','wenzhou' ,'zhengzhou','chengdu' ,'qingdao', 'ningbo','kunming','hangzhou','hefei','xiamen','wuhan' , 'zibo','changchun','shenyang', 'changsha','suzhou' ,'wuxi','jinan','taiyuan','dalian','nanjing','nanchang', 'tangshan','yantai',],2) 
d_test['UserInfo_4']=d_test['UserInfo_4'].replace(['yueyang','liaocheng','binzhou','quanzhou','haikou','baoding','liuzhou','lanzhou','huaian','shaoxing', 'weihai','wuhu', 'zhuhai' , 'jining','jilinshi' , 'yichang','cangzhou', 'jiangmen','daqing' ,'zhanjiang' ,'nanning','mianyang','huizhou','taian','zhongshan','xuzhou','yinchuan','taizhou','nantong','zhangzhou','baotou','yancheng','heze','changzhou','yangzhou','handan','guiyang','jiaxing','changde' ,'linyi', 'jingdezhen','langfang','zhenjiang','weifang','dezhou','xiangyang','wulumuqi','baoji','dongying','xining','huhehaote','maoming','nanyang'],3) 
d_test['UserInfo_4']=d_test['UserInfo_4'].replace([ 'jincheng','jincheng','yiyang','yuncheng','shangqiu', 'jieyang','jingzhou','longyan','xinxiang','xiangtan','qingyuan','yuxi' ,'linfen','ningde' ,'yulin','changzhi','sanming','zhaoqing','nanping', 'panjin','jinzhong','loudi', 'suqian','hulunbeier','anyang','lvliang','xuchang','shaoguan','yongzhou','tongliao' ,'yichun','shangrao','zhoukou','chifeng','jinzhou','nanchong','xianyang','puyang','fuyang','zaozhuang','yangjiang','shantou','zhangjiakou','ganzhou','lianyungang','siping','huzhou','anqing','chuzhou','pingdingshan','guilin','leshan','dazhou','xinyang','qujing' ,'huangshi','putian','tieling', 'chengde','bijie', 'jiujiang','benxi','neijiang','jiaozuo','xingtai','xiaogan','qinhuangdao','luan','weinan','sanmenxia','liaoyang','zunyi','rizhao','tonghua','lishui','kaifeng','huanggang','shuozhou','jingmen','zhuzhou','ziyang','shiyan','songyuan','jian','shaoyang','maanshan','quzhou','yanan','panzhihua','mudanjiang','deyang','luzhou','dandong','zhumadian','zigong','yingkou','suihua','bangbu','datong','hengshui','yibin','chaoyang','fushun'],4) 
d_test['UserInfo_4']=d_test['UserInfo_4'].replace([  'naqu', 'hainanzangzuzizhizhou', 'rikaze','guoluozangzuzizhizhou','heyuan', 'changjihuizuzizhizhou','qitaihe', 'zhoushan','xiangfan','tongren','huainan','ezhou', 'xilinguolemeng' ,'dongguan','wuwei','liupanshui','hengyang','tongling', 'shanwei', 'hechi','yangquan', 'huangshan','bazhong','dehongdaizujingpozuzizhizhou' ,'jinhua', 'pingxiang' ,'dingxi' ,'luoyang' ,'xinzhou','baishan','baoshan','jiuquan','xinganmeng','qihaihe','zhaotong','qinzhou','fuxin','qiannan','chuxiongyizuzizhizhou','xishuangbannadaizuzizhizhou' , 'xiangxitujiazumiaozuzizhizhou' ,'anshan','honghehanizuyizuzizhizhou' ,'qiandongnan','daxinganling','yanbianchaoxianzuzizhizhou' ,'lijiang' ,'laiwu','hanzhong','kelamayi', 'xuancheng','huaibei', 'huaihua','chenzhou','chizhou','bozhou','baise','beihai','luohe','qianxinan','linxiahuizuzizhizhou','qiqihaer','chaozhou', 'bayannaodongmeng','anshun','lincang','zhousan','huludao','kashi','lincheng','dongdongdongsi','wuzhong','yunfu','wuhai','tianshui', 'yilihasakezizhizhou','shizuishan', 'bayinguolengmengguzizhizhou' , 'wenshanzhuangzumiaozuzizhizhou','suining' , 'xinyu', 'wuzhou' ,'longnan','xianning','jeyuan','guangyuan','qingyang','zhangjiajie','meizhou','yingtan','shihezi','zhangye','chaohu','heihe','jiayuguan','baiyin' ,'meishan', 'baicheng', 'chongzuo' , 'guangan' ,'yaan', 'hebi', 'shangluo' ,'hegang' ,'fangchenggang' ,'liangshan' ,'hami' ,'tongchuan' ,'akesu', 'dalibaizuzizhizhou' ,'abazangzuqiangzuzizhizhou' ,'ankang', 'suizhou' ,'jiamusi', 'jixi' ,'wulanchabumeng' , 'haibeicangzuzizhizhou' ,'alashanmeng' ,'shuangyashan' ,'pingliang' ,'hezhou', 'shannan' ,'tulufan' ,'dongshi', 'guigang', 'ganzicangzuzizhizhou', 'haiximengguzucangzuzizhizhou', 'bodongtalamengguzizhizhou' ,'guyuan', 'liaoyuan', 'haidong', 'kezilesukedongkezizizhizhou' ,'laibin', 'linzhi' ,'changdu' ,'jinchang', 'lasa', 'hetian' ,'diqingcangzuzizhizhou' ,'jiyuan' ,'gannanzangzuzizhizhou'],5)

# %%
d_test['UserInfo_9']=d_test['UserInfo_9'].replace(['chongqing','shanghai','guangzhou','shenzhen','beijing','tianjin'],1) 
d_test['UserInfo_9']=d_test['UserInfo_9'].replace(['xian', 'fuzhou','foshan', 'haerbin','shijiazhuang','wenzhou' ,'zhengzhou','chengdu' ,'qingdao', 'ningbo','kunming','hangzhou','hefei','xiamen','wuhan' , 'zibo','changchun','shenyang', 'changsha','suzhou' ,'wuxi','jinan','taiyuan','dalian','nanjing','nanchang', 'tangshan','yantai',],2) 
d_test['UserInfo_9']=d_test['UserInfo_9'].replace(['yueyang','liaocheng','binzhou','quanzhou','haikou','baoding','liuzhou','lanzhou','huaian','shaoxing', 'weihai','wuhu', 'zhuhai' , 'jining','jilinshi' , 'yichang','cangzhou', 'jiangmen','daqing' ,'zhanjiang' ,'nanning','mianyang','huizhou','taian','zhongshan','xuzhou','yinchuan','taizhou','nantong','zhangzhou','baotou','yancheng','heze','changzhou','yangzhou','handan','guiyang','jiaxing','changde' ,'linyi', 'jingdezhen','langfang','zhenjiang','weifang','dezhou','xiangyang','wulumuqi','baoji','dongying','xining','huhehaote','maoming','nanyang'],3) 
d_test['UserInfo_9']=d_test['UserInfo_9'].replace([ 'jincheng','jincheng','yiyang','yuncheng','shangqiu', 'jieyang','jingzhou','longyan','xinxiang','xiangtan','qingyuan','yuxi' ,'linfen','ningde' ,'yulin','changzhi','sanming','zhaoqing','nanping', 'panjin','jinzhong','loudi', 'suqian','hulunbeier','anyang','lvliang','xuchang','shaoguan','yongzhou','tongliao' ,'yichun','shangrao','zhoukou','chifeng','jinzhou','nanchong','xianyang','puyang','fuyang','zaozhuang','yangjiang','shantou','zhangjiakou','ganzhou','lianyungang','siping','huzhou','anqing','chuzhou','pingdingshan','guilin','leshan','dazhou','xinyang','qujing' ,'huangshi','putian','tieling', 'chengde','bijie', 'jiujiang','benxi','neijiang','jiaozuo','xingtai','xiaogan','qinhuangdao','luan','weinan','sanmenxia','liaoyang','zunyi','rizhao','tonghua','lishui','kaifeng','huanggang','shuozhou','jingmen','zhuzhou','ziyang','shiyan','songyuan','jian','shaoyang','maanshan','quzhou','yanan','panzhihua','mudanjiang','deyang','luzhou','dandong','zhumadian','zigong','yingkou','suihua','bangbu','datong','hengshui','yibin','chaoyang','fushun'],4) 
d_test['UserInfo_9']=d_test['UserInfo_9'].replace([ 'heyuan', 'changjihuizuzizhizhou','qitaihe', 'zhoushan','xiangfan','tongren','huainan','ezhou', 'xilinguolemeng' ,'dongguan','wuwei','liupanshui','hengyang','tongling', 'shanwei', 'hechi','yangquan', 'huangshan','bazhong','dehongdaizujingpozuzizhizhou' ,'jinhua', 'pingxiang' ,'dingxi' ,'luoyang' ,'xinzhou','baishan','baoshan','jiuquan','xinganmeng','qihaihe','zhaotong','qinzhou','fuxin','qiannan','chuxiongyizuzizhizhou','xishuangbannadaizuzizhizhou' , 'xiangxitujiazumiaozuzizhizhou' ,'anshan','honghehanizuyizuzizhizhou' ,'qiandongnan','daxinganling','yanbianchaoxianzuzizhizhou' ,'lijiang' ,'laiwu','hanzhong','kelamayi', 'xuancheng','huaibei', 'huaihua','chenzhou','chizhou','bozhou','baise','beihai','luohe','qianxinan','linxiahuizuzizhizhou','qiqihaer','chaozhou', 'bayannaodongmeng','anshun','lincang','zhousan','huludao','kashi','lincheng','dongdongdongsi','wuzhong','yunfu','wuhai','tianshui', 'yilihasakezizhizhou','shizuishan', 'bayinguolengmengguzizhizhou' , 'wenshanzhuangzumiaozuzizhizhou','suining' , 'xinyu', 'wuzhou' ,'longnan','xianning','jeyuan','guangyuan','qingyang','zhangjiajie','meizhou','yingtan','shihezi','zhangye','chaohu','heihe','jiayuguan','baiyin' ,'meishan', 'baicheng', 'chongzuo' , 'guangan' ,'yaan', 'hebi', 'shangluo' ,'hegang' ,'fangchenggang' ,'liangshan' ,'hami' ,'tongchuan' ,'akesu', 'dalibaizuzizhizhou' ,'abazangzuqiangzuzizhizhou' ,'ankang', 'suizhou' ,'jiamusi', 'jixi' ,'wulanchabumeng' , 'haibeicangzuzizhizhou' ,'alashanmeng' ,'shuangyashan' ,'pingliang' ,'hezhou', 'shannan' ,'tulufan' ,'dongshi', 'guigang', 'ganzicangzuzizhizhou', 'haiximengguzucangzuzizhizhou', 'bodongtalamengguzizhizhou' ,'guyuan', 'liaoyuan', 'haidong', 'kezilesukedongkezizizhizhou' ,'laibin', 'linzhi' ,'changdu' ,'jinchang', 'lasa', 'hetian' ,'diqingcangzuzizhizhou' ,'jiyuan' ,'gannanzangzuzizhizhou'],5)

# %%
d_train['UserInfo_8']=d_train['UserInfo_8'].replace('ChinaUnicom',1)
d_train['UserInfo_8']=d_train['UserInfo_8'].replace( 'ChinaTelecom', 2)
d_train['UserInfo_8']=d_train['UserInfo_8'].replace('ChinaMobile',3)

# %%
d_test['UserInfo_8']=d_test['UserInfo_8'].replace('ChinaUnicom',1)
d_test['UserInfo_8']=d_test['UserInfo_8'].replace( 'ChinaTelecom', 2)
d_test['UserInfo_8']=d_test['UserInfo_8'].replace('ChinaMobile',3)

# %%
d_train['UserInfo_21']=d_train['UserInfo_21'].replace('D',1)
d_train['UserInfo_21']=d_train['UserInfo_21'].replace( 'unmarried',2)
d_train['UserInfo_21']=d_train['UserInfo_21'].replace('married',3)
d_train['UserInfo_21']=d_train['UserInfo_21'].replace('divoreced',4)
d_train['UserInfo_21']=d_train['UserInfo_21'].replace('first-married',5)
d_train['UserInfo_21']=d_train['UserInfo_21'].replace('remarried',6)

# %%
d_test['UserInfo_21']=d_test['UserInfo_21'].replace('D',1)
d_test['UserInfo_21']=d_test['UserInfo_21'].replace( 'unmarried',2)
d_test['UserInfo_21']=d_test['UserInfo_21'].replace('married',3)
d_test['UserInfo_21']=d_test['UserInfo_21'].replace('divoreced',4)
d_test['UserInfo_21']=d_test['UserInfo_21'].replace('first-married',5)
d_test['UserInfo_21']=d_test['UserInfo_21'].replace('remarried',6)

# %%
d_train['Education_Info2']=d_train['Education_Info2'].replace('E',1)
d_train['Education_Info2']=d_train['Education_Info2'].replace('A',2)
d_train['Education_Info2']=d_train['Education_Info2'].replace('AM',3)
d_train['Education_Info2']=d_train['Education_Info2'].replace('AQ',4)
d_train['Education_Info2']=d_train['Education_Info2'].replace('AN',5)
d_train['Education_Info2']=d_train['Education_Info2'].replace('U',6)
d_train['Education_Info2']=d_train['Education_Info2'].replace('B',7)

# %%
d_test['Education_Info2']=d_test['Education_Info2'].replace('E',1)
d_test['Education_Info2']=d_test['Education_Info2'].replace('A',2)
d_test['Education_Info2']=d_test['Education_Info2'].replace('AM',3)
d_test['Education_Info2']=d_test['Education_Info2'].replace('AQ',4)
d_test['Education_Info2']=d_test['Education_Info2'].replace('AN',5)
d_test['Education_Info2']=d_test['Education_Info2'].replace('U',6)
d_test['Education_Info2']=d_test['Education_Info2'].replace('B',7)

# %%
d_train['WeblogInfo_21'].unique()

# %%
d_train['WeblogInfo_19']=d_train['WeblogInfo_19'].replace('I',1)
d_train['WeblogInfo_19']=d_train['WeblogInfo_19'].replace('D',2)
d_train['WeblogInfo_19']=d_train['WeblogInfo_19'].replace('F',3)
d_train['WeblogInfo_19']=d_train['WeblogInfo_19'].replace('G',4)
d_train['WeblogInfo_19']=d_train['WeblogInfo_19'].replace('E',5)
d_train['WeblogInfo_19']=d_train['WeblogInfo_19'].replace('J',6)
d_train['WeblogInfo_19']=d_train['WeblogInfo_19'].replace('H',7)

# %%
d_test['WeblogInfo_19']=d_test['WeblogInfo_19'].replace('I',1)
d_test['WeblogInfo_19']=d_test['WeblogInfo_19'].replace('D',2)
d_test['WeblogInfo_19']=d_test['WeblogInfo_19'].replace('F',3)
d_test['WeblogInfo_19']=d_test['WeblogInfo_19'].replace('G',4)
d_test['WeblogInfo_19']=d_test['WeblogInfo_19'].replace('E',5)
d_test['WeblogInfo_19']=d_test['WeblogInfo_19'].replace('J',6)
d_test['WeblogInfo_19']=d_test['WeblogInfo_19'].replace('H',7)

# %%
d_train['WeblogInfo_21']=d_train['WeblogInfo_21'].replace('A',1)
d_train['WeblogInfo_21']=d_train['WeblogInfo_21'].replace('B',2)
d_train['WeblogInfo_21']=d_train['WeblogInfo_21'].replace('C',3)
d_train['WeblogInfo_21']=d_train['WeblogInfo_21'].replace('D',4)

# %%
d_test['WeblogInfo_21']=d_test['WeblogInfo_21'].replace('A',1)
d_test['WeblogInfo_21']=d_test['WeblogInfo_21'].replace('B',2)
d_test['WeblogInfo_21']=d_test['WeblogInfo_21'].replace('C',3)
d_test['WeblogInfo_21']=d_test['WeblogInfo_21'].replace('D',4)

# %%
# drop non-numerical vars
cate_vars = []
for i in d_train:
    if d_train[i].dtype not in [np.float, np.int]:
        cate_vars.append(i)
print(cate_vars)
train = d_train.drop(cate_vars, 1)
test = d_test.drop(cate_vars, 1)

# %%
# fillna
print(train.isna().mean().mean())
for i in train:
    train[i].fillna(train[i].median(), inplace=True)
    test[i].fillna(test[i].median(), inplace=True)
print(train.isna().mean().mean())

# %%
# pop id var
id_train = train.pop('Idx')
id_test = test.pop('Idx')
# pop Y
Y = 'target'
train_Y = train.pop(Y)
test_Y = test.pop(Y)

# %%
train['WeblogInfo']= train['WeblogInfo_1']+train['WeblogInfo_2']+train['WeblogInfo_3']+train['WeblogInfo_4']+train['WeblogInfo_5']+train['WeblogInfo_6']+train['WeblogInfo_7']+train['WeblogInfo_8']+train['WeblogInfo_9']+train['WeblogInfo_10']+train['WeblogInfo_11']+train['WeblogInfo_12']+train['WeblogInfo_13']+train['WeblogInfo_14']+train['WeblogInfo_15']+train['WeblogInfo_16']+train['WeblogInfo_17']+train['WeblogInfo_18']
train['WeblogInfo']

# %%
# train valid split
np.random.seed(123)
train_X, valid_X, train_Y, valid_Y = train_test_split(train, train_Y, test_size=0.3)
valid_X

# %%
# benchmark
valid_bench = np.zeros(valid_Y.shape)
valid_conf = confusion_matrix(valid_Y,valid_bench)
print(valid_conf)
test_bench = np.zeros(test_Y.shape)
test_conf = confusion_matrix(test_Y,test_bench)
print(valid_conf)

# %%
def roi(conf, ratio=[0.1,-1]):
    return np.mean(conf[:,0] * ratio)
print(roi(valid_conf))
print(roi(test_conf))

# %%
# Naive Bayesian
m = BernoulliNB()
# train and valid
m.fit(train_X, train_Y)
valid_pred = m.predict(valid_X)
valid_conf = confusion_matrix(valid_Y, valid_pred)
print(valid_conf)
print(roi(valid_conf))

# %%
from imblearn.under_sampling import RandomUnderSampler
m_resample = RandomUnderSampler()
train2_X, train2_Y = m_resample.fit_resample(train_X, train_Y)
print(train2_Y.mean())

# %%
# NN
m = MLPClassifier(hidden_layer_sizes =(8,2,4))  # try different hls

# train and valid
m.fit(train2_X, train2_Y)
valid_pred = m.predict(valid_X)
valid_conf = confusion_matrix(valid_Y, valid_pred)
print(valid_conf)
print(roi(valid_conf))

# %%
# SVM
m=SVC()  # try different hls

# train and valid
m.fit(train_X, train_Y)
valid_pred = m.predict(valid_X)
valid_conf = confusion_matrix(valid_Y, valid_pred)
print(valid_conf)
print(roi(valid_conf))

# %%
# voting
# methods for voting
m1 = BernoulliNB()
m2 = GaussianNB()
m3=MLPClassifier(hidden_layer_sizes =(5,4,4))
#m4=SVC()

# init voting class [('label', method)]
m = VotingClassifier(estimators=[('BernoulliNB', m1), 
                                 ('RF', m2),('MLPClassifier',m3)],voting='hard')

# train and valid
m.fit(train_X, train_Y)
valid_pred = m.predict(valid_X)
valid_conf = confusion_matrix(valid_Y, valid_pred)
print(valid_conf)
print(roi(valid_conf))
