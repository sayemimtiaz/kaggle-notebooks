# %% [markdown]
# #Gender Inequality
#
# Gender Inequality is the social process by which men and women are not treated as equals. The treatment may arise from distinctions regarding biology, psychology, or cultural norms. Some of these distinctions are empirically-grounded while others appear to be socially constructed. https://en.wikipedia.org/wiki/Gender_inequality

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTCT29yyEVhTpgT6IrNQceO2hBZtniCDo1mkw&usqp=CAU)opencolleges.edu.au

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.offline as py
import plotly.graph_objs as go
import plotly.offline as py
import plotly.express as px

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('../input/countries-gender-ineq-and-financials-over-time/countries.csv', encoding='utf8')
df.head()

# %% [markdown]
# #No Missing Values

# %%
! pip install -q dabl country_converter

# %%
import dabl
import warnings

import country_converter as coco

import plotly.express as px
import plotly.graph_objs as go
import plotly.figure_factory as ff

warnings.simplefilter('ignore')

# %%
#Code from Gabriel Preda
#plt.style.use('dark_background')
def plot_count(feature, title, df, size=1):
    f, ax = plt.subplots(1,1, figsize=(4*size,4))
    total = float(len(df))
    g = sns.countplot(df[feature], order = df[feature].value_counts().index[:20], palette= ('#32a852', '#a84e32', '#3242a8'))
    g.set_title("Number and percentage of {}".format(title))
    if(size > 2):
        plt.xticks(rotation=90, size=8)
    for p in ax.patches:
        height = p.get_height()
        ax.text(p.get_x()+p.get_width()/2.,
                height + 3,
                '{:1.2f}%'.format(100*height/total),
                ha="center") 
    plt.show()

# %%
plot_count("GII", "Gender Inequality Index", df,4)

# %%
plot_count("FII", "Financial Institutions Index", df,4)

# %%
plot_count("GDI", "Gender Development Index", df,4)

# %%
plt.style.use('classic')
new_df = df[['Unnamed: 0', 'Country Code', 'Date', 'GDI', 'GII', 'FIDI', 'FII', 'FMI', 'FIAI', 'FMDI', 'FMAI', 'FDI', 'FMEI', 'FIEI']]
dabl.plot(new_df, target_col='GII')

# %%
new_df = df[['Unnamed: 0', 'Country Code', 'Date', 'GDI', 'GII', 'FIDI', 'FII', 'FMI', 'FIAI', 'FMDI', 'FMAI', 'FDI', 'FMEI', 'FIEI']]
sns.pairplot(new_df)

# %%
#Code by Olga Belitskaya https://www.kaggle.com/olgabelitskaya/sequential-data/comments
from IPython.display import display,HTML
c1,c2,f1,f2,fs1,fs2=\
'#eb3434','#eb3446','Akronim','Smokum',30,15
def dhtml(string,fontcolor=c1,font=f1,fontsize=fs1):
    display(HTML("""<style>
    @import 'https://fonts.googleapis.com/css?family="""\
    +font+"""&effect=3d-float';</style>
    <h1 class='font-effect-3d-float' style='font-family:"""+\
    font+"""; color:"""+fontcolor+"""; font-size:"""+\
    str(fontsize)+"""px;'>%s</h1>"""%string))
    
    
dhtml('Marília Prata, @mpwolke was here' )
