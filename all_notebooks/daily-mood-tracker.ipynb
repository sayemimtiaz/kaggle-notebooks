# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go
import itertools

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# According to Abid's Daylio Mood Tracker Dataset Description, he is using an app that has made him better by noting down his mood on daily basis and what type of activities affects the most.
#
# In his case, Dota 2 was an anomaly other than that there have been many cases when he looked back at yearly stats and wondered about on how can he get better analysis from his Data. Now he is presenting to our Kaggle community his personal data and wanting that Kagglers to come up with an explanation about what activities effects most and blow his mind.
#
# https://www.kaggle.com/kingabzpro/daylio-mood-tracker

# %% [markdown]
# #Technologies and Sedentarism
#
# Modern Lives and Stone Age Minds: The Ambiguous Rhetoric of Evolutionary Mismatch
#
# ![](https://www.uottawa.ca/alumni/sites/www.uottawa.ca.alumni/files/evolution-of-human-work-silhouettes-e1470228291192.jpg)uottawa.ca

# %%
df = pd.read_csv("/kaggle/input/daylio-mood-tracker/Daylio_Abid.csv", low_memory=False)
print(df.shape)
df.head().style.set_properties(**{'background-color':'LightBlue',
                                     'color': 'purple'})

# %%
df.isnull().sum()

# %%
df["mood"].value_counts()

# %%
#Code by Lucas Abrahão https://www.kaggle.com/lucasabrahao/trabalho-manufatura-an-lise-de-dados-no-brasil

df["mood"].value_counts()[:15].plot.barh(color='blue', title='Abid s Moods');

# %%
#word cloud
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in df.mood)
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200,colormap='GnBu', background_color="black").generate(text)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='Bilinear')
plt.axis("off")
plt.figure(1,figsize=(12, 12))
plt.show()

# %%
#word cloud
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in df.activities)
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200,colormap='Pastel1', background_color="black").generate(text)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='Bilinear')
plt.axis("off")
plt.figure(1,figsize=(12, 12))
plt.show()

# %% [markdown]
# #What about some physical activities? Activities increasing Endorphin production.
#
# "Exercise increases your overall health and your sense of well-being, which puts more pep in your step every day. But exercise also has some direct stress-busting benefits."
#
# "It pumps up your endorphins. Physical activity may help bump up the production of your brain's feel-good neurotransmitters, called endorphins. Although this function is often referred to as a runner's high, any aerobic activity, can contribute to this same feeling."
#
# https://www.mayoclinic.org/healthy-lifestyle/stress-management/in-depth/exercise-and-stress/art-20044469#:~:text=It%20pumps%20up%20your%20endorphins,contribute%20to%20this%20same%20feeling.
#
# I agree with that. If you can Not run, walk or do any other activity that you like.

# %%
#Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

color = plt.cm.RdBu(np.linspace(0,1,20))
df["mood"].value_counts().sort_values(ascending=False).head(20).plot.pie(y="date",colors=color,autopct="%0.1f%%")
plt.title("Moods by date")
plt.axis("off")
plt.show()

# %%
#Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

color = plt.cm.Blues(np.linspace(0,1,20))
df["activities"].value_counts().sort_values(ascending=False).head(10).plot.pie(y="date",colors=color,autopct="%0.1f%%")
plt.title("Activities by date")
plt.axis("off")
plt.show()

# %%
fig = px.bar(df, x= "date", y= "mood", color_discrete_sequence=['crimson'], title="Daily Mood")
fig.show()

# %% [markdown]
# #Human beings are not made to remain still/immovable
#
# ![](https://lh3.googleusercontent.com/proxy/Lizgxo2nbqs-oL6QxsBSARQiOABLQk0pD_k8yhmOHGxkomMmPhsaoUjFG5BOohWd9ZaiRK9ObGY7vie5hirfESahlC_Bnj7E7D3uVwn3kweaPUq7lfgc0gg7pzg8iVhYriX3i-AMsiLvxOaNmSRG_A)lem.seed.pr.gov.br

# %%
fig = px.bar(df, x= "weekday", y= "mood", color_discrete_sequence=['#2B3A67'], title="Mood by Weekday")
fig.show()

# %%
fig = px.bar(df, x= "time", y= "mood", color_discrete_sequence=['#2B3A67'], title="Mood by time")
fig.show()

# %% [markdown]
# #We can do daily-activities to avoid Sedentarism.
#
# ![](https://healthy-ojas.com/sites/default/files/cholesterol/cholesterol-physical-activity.jpg)healthy-ojas.com

# %%
fig = px.bar(df, x= "time", y= "activities", color_discrete_sequence=['darksalmon'], title="Activities by time")
fig.show()

# %%
fig = px.bar(df, x= "weekday", y= "activities", color_discrete_sequence=['darksalmon'], title="Activities by Weekday")
fig.show()

# %% [markdown]
# #Technologies and Sedentarism 2
#
# ![](http://blog.grile-admitere.ro/wp-content/uploads/2019/01/3-funnel-sedentarism-blog.jpg)blog.grile-admitere.ro

# %%
# categorical features with missing values
categorical_nan = [feature for feature in df.columns if df[feature].isna().sum()>0 and df[feature].dtypes=='O']
print(categorical_nan)

# %%
# replacing missing values in categorical features
for feature in categorical_nan:
    df[feature] = df[feature].fillna('None')

# %%
df[categorical_nan].isna().sum()

# %% [markdown]
# ![](https://www.nia.nih.gov/sites/default/files/2020-05/emotional-benefits-of-exercise-thumb.jpg)nia.nih.gov

# %% [markdown]
# #Encoding

# %%
#Code by Bizen https://www.kaggle.com/hiro5299834/tps-apr-2021-deebtables/notebook

TARGET = 'activities' #Target could Not be float otherwise will result in valueError: Unknown label type: 'continuous'. Even after the encoding.

label_cols = ['full_date', 'weekday', 'time', 'mood']
#numerical_cols = ['Altitude', 'Rainfall', 'Frosts', 'Year']

# %%
#Code by Bizen https://www.kaggle.com/hiro5299834/tps-apr-2021-deebtables/notebook

from sklearn.preprocessing import LabelEncoder

def label_encoder(c):
    le = LabelEncoder()
    return le.fit_transform(c)

label_encoded_df = df[label_cols].apply(label_encoder)
#numerical_df = df[numerical_cols]
target_df = df[TARGET]

df = pd.concat([label_encoded_df, target_df], axis=1)

# %%
df.head()

# %%
fig = px.treemap(df, path=['mood'], values='weekday',
                  color='time', hover_data=['activities'],title="Mood Tracker",
                  color_continuous_scale='RdBu')
fig.show()

# %% [markdown]
# #Physical Activities
#
# Though that treemap above is not very clear, as far as we can read from the activities descriptions, We can note a certain lack of Physical Activities. Only WALK. Besides, it was not mentioned. For so long and what distance?
#
# I'd rather not make any ML. Our own choices matter to keep the body and the spiritual health. Medicine has a high-tech component and a high-touch (empathizing with the patient) too. Both are important for the relationship between doctor-patient. Avoiding sedentarism can revert some diseases and change future ones.

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSNpgFsLwmZ5ePszrPB4W0_LowNh5kgoSDaFg&usqp=CAU)123rf.com
