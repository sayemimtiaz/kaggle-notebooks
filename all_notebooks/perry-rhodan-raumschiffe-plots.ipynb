# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import plotly.offline as py
import plotly.graph_objs as go
import plotly

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# "Perry Rhodan a long-running and popular German space opera franchise, named after its hero. It commenced in 1961. Having sold approximately two billion copies (in novella format) worldwide, (including over one billion in Germany alone), it is the most successful science fiction book series ever written. The first billion of worldwide sales was celebrated in 1986. The series has spun off into comic books, audio dramas, video games and the like."https://en.wikipedia.org/wiki/Perry_Rhodan

# %% [markdown]
# ![](https://img.yumpu.com/21586296/1/500x640/perry-rhodan-terranische-raumschiffe-risszeichnungen.jpg)yumpu.com

# %%
df = pd.read_csv("/kaggle/input/perry-rhodan-raumschiffe/perry_ds.csv", low_memory=False)
print(df.shape)
df.head().style.set_properties(**{'background-color':'Aquamarine',
                                     'color': 'purple'})

# %%
df.isnull().sum()

# %%
df["Typ"].value_counts()

# %%
##Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

from wordcloud import WordCloud
from wordcloud import STOPWORDS
stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color = 'Red',
                      height =2000,
                      width = 2000
                     ).generate(str(df["Volk"]))
plt.rcParams['figure.figsize'] = (8,8)
plt.axis("off")
plt.imshow(wordcloud)
plt.title("Volk/People")
plt.show()

# %%
##Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

from wordcloud import WordCloud
from wordcloud import STOPWORDS
stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color = 'Green',
                      height =2000,
                      width = 2000
                     ).generate(str(df["Bauform"]))
plt.rcParams['figure.figsize'] = (8,8)
plt.axis("off")
plt.imshow(wordcloud)
plt.title("Bauform/Design")
plt.show()

# %%
#Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

from wordcloud import WordCloud
from wordcloud import STOPWORDS
stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color = 'skyblue',
                      height =2000,
                      width = 2000
                     ).generate(str(df["Eigner"]))
plt.rcParams['figure.figsize'] = (8,8)
plt.axis("off")
plt.imshow(wordcloud)
plt.title("Eigner/Owner")
plt.show()

# %% [markdown]
# #Code by Nikunj Malpani https://www.kaggle.com/nikunjmalpani/basic-data-capstone-project-1-911-emergency-calls

# %%
# Could be any column: No, only numeric data.
df['Größe'].plot()

# %%
df.groupby('Quellen').count()['Größe'].plot()
plt.tight_layout()

# %%
df.groupby('Quellen_Typ').count()['Größe'].plot()
plt.tight_layout()

# %%
df.groupby('Volk').count()['Größe'].plot()
plt.xticks(rotation=45)
plt.tight_layout()

# %%
df.groupby('Bauform').count()['Größe'].plot()
plt.xticks(rotation=45)
plt.tight_layout()

# %%
df.groupby('Typ').count()['Größe'].plot()
plt.xticks(rotation=45)
plt.tight_layout()

# %%
#Code by Nikunj Malpani https://www.kaggle.com/nikunjmalpani/basic-data-capstone-project-1-911-emergency-calls

df.groupby('Eigner').count()['Größe'].plot()
plt.tight_layout()

# %%
df[df['Typ']=='Ultraschlachtschiff/GALAXIS-Klasse'].groupby('Eigner').count()['Größe'].plot()
plt.title('Ultraschlachtschiff/GALAXIS-Klasse')
plt.tight_layout()

# %%
#Kugelraumer 3% Ein Raumschiff mit der äußeren Form einer Kugel.

df[df['Typ']=='Kugelraumer'].groupby('Eigner').count()['Größe'].plot()
plt.title('Kugelraumer')
plt.tight_layout()

# %%
#Code by Nikunj Malpani https://www.kaggle.com/nikunjmalpani/basic-data-capstone-project-1-911-emergency-calls

df[df['Typ']=='Schlachtkreuzer / SOLAR-Klasse'].groupby('Eigner').count()['Größe'].plot()
plt.title('Schlachtkreuzer / SOLAR-Klasse')
plt.tight_layout()

# %%
#Code by Nikunj Malpani https://www.kaggle.com/nikunjmalpani/basic-data-capstone-project-1-911-emergency-calls

df[df['Quellen']=='Rico'].groupby('Eigner').count()['Größe'].plot()
plt.title('Rico')
plt.tight_layout()

# %%
#Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

color = plt.cm.afmhot(np.linspace(0,1,20))
df["Typ"].value_counts().sort_values(ascending=False).head(20).plot.pie(y="Größe",colors=color,autopct="%0.1f%%")
plt.title("Raumschiffe Typ")
plt.axis("off")
plt.show()

# %%
#Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

color = plt.cm.afmhot(np.linspace(0,1,20))
df["Name"].value_counts().sort_values(ascending=False).head(20).plot.pie(y="Größe",colors=color,autopct="%0.1f%%")
plt.title("Raumschiffe Namen")
plt.axis("off")
plt.show()

# %%
#Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

color = plt.cm.afmhot(np.linspace(0,1,20))
df["Bauform"].value_counts().sort_values(ascending=False).head(20).plot.pie(y="Größe",colors=color,autopct="%0.1f%%")
plt.title("Raumschiffe Bauform")
plt.axis("off")
plt.show()

# %%
# categorical features with missing values
categorical_nan = [feature for feature in df.columns if df[feature].isna().sum()>0 and df[feature].dtypes=='O']
print(categorical_nan)

# %%
# replacing missing values in categorical features
for feature in categorical_nan:
    df[feature] = df[feature].fillna('None')

# %%
df[categorical_nan].isna().sum()

# %%
# Lets handle numerical features with nan value
numerical_nan = [feature for feature in df.columns if df[feature].isna().sum()>1 and df[feature].dtypes!='O']
numerical_nan

# %%
df[numerical_nan].isna().sum()

# %%
## Replacing the numerical Missing Values

for feature in numerical_nan:
    ## We will replace by using median since there are outliers
    median_value=df[feature].median()
    
    df[feature].fillna(median_value,inplace=True)
    
df[numerical_nan].isnull().sum()

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
object_col = [col for col in df.columns if df[col].dtype == 'object']
for col in object_col:
    df[col] = le.fit_transform(df[col])

# %%
df.info()

# %%
#Code by Olga Belitskaya https://www.kaggle.com/olgabelitskaya/sequential-data/comments
from IPython.display import display,HTML
c1,c2,f1,f2,fs1,fs2=\
'#eb3434','#eb3446','Akronim','Smokum',30,15
def dhtml(string,fontcolor=c1,font=f1,fontsize=fs1):
    display(HTML("""<style>
    @import 'https://fonts.googleapis.com/css?family="""\
    +font+"""&effect=3d-float';</style>
    <h1 class='font-effect-3d-float' style='font-family:"""+\
    font+"""; color:"""+fontcolor+"""; font-size:"""+\
    str(fontsize)+"""px;'>%s</h1>"""%string))
    
    
dhtml('Vielen Dank. Das war s. Marília Prata @mpwolke was Hier.' )
