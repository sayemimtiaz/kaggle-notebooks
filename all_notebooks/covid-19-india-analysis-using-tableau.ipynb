# %% [markdown]
# # **Covid 19 India Confirmed , Recovered, Deaths till 26th June'2020**

# %% [markdown]
# Please find the tableau public dashboard link: https://public.tableau.com/views/COVID-19Indiadashboard/covid19withoutanimation?:language=en&:display_count=y&publish=yes&:origin=viz_share_link
#
# Data set used is Covid 19 data published by SRK in kaggle.

# %%
from IPython.display import IFrame
IFrame('https://public.tableau.com/views/COVID-19Indiadashboard/covid19withoutanimation?:language=en&:display_count=y&publish=yes&:origin=viz_share_link&:showVizHome=no&:embed=true',width=1000, height=925)
