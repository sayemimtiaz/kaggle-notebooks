# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df = pd.read_csv('../input/amazon-mobile-dataset/Amazon_Mobile_Data.csv')
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df.head()

# %%
df.columns

# %% [markdown]
# **Taking a Random Row**

# %%
fifth_row = df.iloc[5]

# %%
fifth_row

# %%
fifth_row_reviews = fifth_row.reviews.split('|| ')
fifth_row_review_ratings = fifth_row.reviews_rating.split('|| ')
for review, rating in zip(fifth_row_reviews, fifth_row_review_ratings):
    print(review, '-->', rating)
