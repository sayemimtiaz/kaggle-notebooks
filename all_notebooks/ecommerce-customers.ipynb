# %% [markdown]
# Simple Linear Regression With Python
# We are going to use the We are going to use the . Since house price is a continues variable, this is a regression problem.
# Since house price is a continues variable, this is a regression problem.

# %% [markdown]
# Columns names are:
# Avg. Session Length
# Time on App	Time on Website
# Length of Membership
# Yearly Amount Spent

# %% [markdown]
# **#I hope you find this kernel useful and your UPVOTES would be highly appreciated******

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# * Check out the data

# %%
df = pd.read_csv('../input/ecommerce-customers/Ecommerce Customers.csv')
df.head()

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# # **Exploratory Data Analysis (EDA)¶******
# Let's create some simple plots to check out the data!

# %%
# Pair plot for whole data frame
sns.pairplot(df)

# %% [markdown]
# Joint Plot to compare the time on website and Yearly Amount Spent

# %%
sns.jointplot(data= df, x = 'Time on Website',y='Yearly Amount Spent')

# %% [markdown]
# Time on app vs Yearly amount of time spend

# %%
sns.jointplot(data=df,x='Time on App',y = "Yearly Amount Spent")

# %% [markdown]
# Both the plots are scattered all over the place.
# WIll HAVE DO FURTHER EDA

# %%
sns.jointplot(x='Time on App',y='Length of Membership',kind='hex',data=df)

# %% [markdown]
# ****PAIR PLOT****

# %%
sns.pairplot(df)
# check the most related column with yearly amount spent

# %% [markdown]
# Length of Membership has the most corelation with Yealy Amount Spent

# %% [markdown]
# Creating Linear Model plot of Yearly Amount Spent vs Length of Membership by Seaborn Plots

# %%
sns.lmplot(data=df,x='Length of Membership', y='Yearly Amount Spent')

# %% [markdown]
# ## Training and Testing Data

# %% [markdown]
# Now that we have explored the data, let's split it into training and testing sets.
# #Set a variable X equal to the numerical features of the customers and a variable Y equal to the 'Yearly Amount Spent' column.

# %%
x = df[['Avg. Session Length', 'Time on App','Time on Website', 'Length of Membership']]
y = df['Yearly Amount Spent']

# %% [markdown]
# Use Cross validation from sklearn to split the data into training and testing

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=101)

# %% [markdown]
# ## Training the Model

# %%
import sklearn.linear_model
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %% [markdown]
# Fitting the train data on linear regression model

# %%
lm.fit(x_train,y_train)

# %% [markdown]
# Checking the coefficient of the model

# %%
lm.coef_

# %% [markdown]
# # Predicting on the test data
# On our Model Fit & Evolve the performance by prediciting on test values

# %%
pred = lm.predict(x_test)

# %% [markdown]
# Creating a Scatter plot between Predicted value and Acutal values

# %%
sns.scatterplot(x=pred,y=y_test)
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')

# %% [markdown]
# # Evaluating our Model

# %% [markdown]
# Let's calculate residual sum of squares and the variance score

# %% [markdown]
# Calculating MAE, MSE & RMSE

# %%
from sklearn import metrics

# %%
print('MAE',metrics.mean_absolute_error(y_test,pred))
print('MSE',metrics.mean_squared_error(y_test,pred))
print('RMSE', np.sqrt(metrics.mean_squared_error(y_test,pred)))

# %%
# R SQU
metrics.explained_variance_score(y_test,pred)

# %% [markdown]
# # Residuals

# %%
sns.distplot((y_test-pred),bins=50)

# %% [markdown]
# # Conclusion
# Either to focus on efforts on mobile app or website development.

# %%
cdf = pd.DataFrame(lm.coef_,x.columns,columns=['Coef'])

# %%
cdf

# %% [markdown]
# # We can conclude that Time Spend on App is creating more revenue for the Ecommerce.
