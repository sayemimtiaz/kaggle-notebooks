# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Dataset detais
# * YEAR- it is showing the year when data was recorded
# * DISTRICT- Districts of Delhi
# * VEHICLE AT FAULT-
# * VICTIM- Those whe were hit
# * TYPE OF ACCIDENT- Accident is fata or not
# * No OF INJURED- Number of injuries during the accident
# * NO OF KILLED- Number of persons were killed after the accidents

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from pandas import plotting

#plotly 
import plotly.offline as py
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
init_notebook_mode(connected=True)
import plotly.figure_factory as ff
import plotly.express as px
# Styling 
plt.style.use('fivethirtyeight')

# %%
df=pd.read_csv('../input/delhi-crime-data/Delhi Accident Data.csv')
df.head()

# %%
df=df.drop(["Unnamed: 7","Unnamed: 8","Unnamed: 9"], axis=1)

# %% [markdown]
# # Missing Value

# %%
k= pd.DataFrame()
k['df']= df.isnull().sum()
k.T

# %% [markdown]
# # Obs
# * No missing value we encounter here

# %%
df.shape

# %%
victim=['PEDESTRIAN', 'S/C & M/C', 'CAR']
year=[2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]
districts=["SOUTH EAST DELHI",
"NEW DELHI",
"NORTH DELHI(ROHINI)",
"CENTRAL DELHI",
"SOUTH WEST DELHI",
"WEST DELHI",
"NORTH WEST DELHI",
"EAST DELHI",
"SHAHDARA",
"SOUTH DELHI",
"NORTH EAST DELHI",
"UNK",
"OUTER"]
vehichle_at_fault=['PVT CAR', 'UNKNOWN', 'S/C&M/C','HTV/GDS']

# %%
Probability_of_fatalities=[0.2780847145,0.2798742138,0.3129689175,0.3182332956,0.283847981,0.2616136919,0.1974584555,
0.1856710394,0.2284730195,0.2301480485]

fig = go.Figure()
fig.add_trace(go.Scatter(x=year, y=Probability_of_fatalities, name="NEW DELHI", line=dict(color='firebrick', width=1,dash='dash')))
fig.update_layout(title='Fatality rate across the different Districts across the Given Year Given district',
                   xaxis_title='Years',
                   yaxis_title='Probability of Fality')

fig.show()

# %% [markdown]
# # Explanatory variable
# * VEHICLE AT FAULT and Year are taken as explanatory variables

# %%
x=df[df['VEHICLE AT FAULT']==vehichle_at_fault[0]]
print(vehichle_at_fault[0])
for z in year:
    xx=x[x['YEAR']==z]
    a=xx['TYPE OF ACCIDENT'].value_counts()
    
    print(z)
    print(a)

# %%
Probability_of_fatalities=[0.1049723757,0.1282191781,0.170212766,0.1519486926,0.147183847,0.1167915381,0.1059273423,0.1132145509,0.1140734266,0.1427842937]

fig = go.Figure()
fig.add_trace(go.Scatter(x=year, y=Probability_of_fatalities, name="PVT CAR", line=dict(color='firebrick', width=1,dash='dash')))
fig.update_layout(title='Fatality rate across the different year across the Given Year Given vehicle at fault',
                   xaxis_title='Years',
                   yaxis_title='Probability of Fality')

fig.show()

# %%
Probability_of_fatalities1=[0.2780847145,0.2798742138,0.3129689175,0.3182332956,0.283847981,0.2616136919,0.1974584555,
0.1856710394,0.2284730195,0.2301480485]

# %%
plt.figure(figsize=(10,5))
plt.plot(year, Probability_of_fatalities1, label="District-New delhi")
plt.plot(year, Probability_of_fatalities, label="Vehicle at Fault-PVT Car")
plt.ylabel("Probabilities of Fatalities")
plt.xlabel("Year")
plt.title("Fatality rate across the different year across the Given Year Given vehicle at fault")
plt.legend()
plt.show()

# %%
x=df[df['VICTIM']==victim[0]]
print(victim[0])
for z in year:
    xx=x[x['YEAR']==z]
    a=xx['TYPE OF ACCIDENT'].value_counts()
    
    print(z)
    print(a)

# %%
Probability_of_fatalities2=[0.2697127937,0.3325668295,0.3025936599,0.313965005,0.2822719449,0.2461945731,0.2132183908,0.2073434125,0.2242063492,0.2559328222]

# %%
plt.figure(figsize=(10,5))
plt.plot(year, Probability_of_fatalities1, label="District-New delhi")
plt.plot(year, Probability_of_fatalities, label="Vehicle at Fault-PVT Car")
plt.plot(year, Probability_of_fatalities2, label="Victim-PEDESTRAIN")

plt.ylabel("Probabilities of Fatalities")
plt.xlabel("Year")
plt.title("Fatality rate across the different year across the Given Year Given Condition")
plt.ylim(0.05, 0.7)
plt.legend()
plt.show()

# %% [markdown]
# # Calculating the fatal acident count of different districts
# * Districts- CENTRAL DELHI

# %%
probability_central=[0.277537797,0.3454960091,0.3504273504,0.3268072289,0.2630057803,0.2479041916,0.2022346369,
                     0.1986379115,0.2235142119,0.2190352021]

# %% [markdown]
# # District- SOUTH WEST DELHI

# %%
probability_south=[0.2469470828,0.3323863636,0.2574102964,0.3078101072,0.2693498452,0.2327044025,
0.1848837209,0.2022756005,0.2157360406,0.25066313]

# %% [markdown]
# # District -WEST DELHI

# %%
probability_west=[0.275,0.3136729223,0.3563049853,0.3095577746,0.3369905956,0.2770919067,0.2234299517,
0.2196078431,0.2254098361,0.2666666667]

# %% [markdown]
# # NORTH WEST DELHI

# %%
probability_north=[0.2311435523,0.2968536252,0.2687861272,0.270096463,0.234948605,0.2341325811,
0.1958128079,0.1985185185,0.2260726073,0.2513863216]

# %% [markdown]
# # EAST DELHI

# %%
probility_east=[0.1913875598,0.2347670251,0.1606557377,0.2092257002,0.267961165,0.2209072978,0.1469594595,
0.1658119658,0.1459694989,0.2284382284]

# %% [markdown]
# # SHAHDARA

# %%
prob_sha=[0.1706730769,0.2808716707,0.2480620155,0.2411067194,0.2036199095,0.1669865643,0.1572212066,0.1542857143
,0.1439688716,0.1834170854]

# %% [markdown]
# # SOUTH DELHI

# %%
prob_sou_delhi=[0.2276029056,0.2971246006,0.3315363881,0.2532637076,0.2608695652,0.2206303725,0.1497695853
,0.1266666667,0.1647398844,0.1597444089]

# %% [markdown]
# # NORTH EAST DELHI

# %%
prob_nor_eas_delhi=[0.2382133995,0.3174603175,0.2903225806,0.2204472843,0.2795698925,0.1901639344,0.1445783133
,0.2037037037,0.1719745223,0.1517027864]

# %%
plt.figure(figsize=(15,10))
plt.plot(year, Probability_of_fatalities, label="New delhi")
plt.plot(year, probability_central, label="Central Delhi")
plt.plot(year, probability_south, label="SOuth Delhi")
plt.plot(year, probability_west, label="WEST DELHI")
plt.plot(year, probability_north, label="NORTH WEST DELHI")
plt.plot(year, probility_east, label="EAST DELHI")
plt.plot(year, prob_sha, label="SHAHDARA")
plt.plot(year, prob_sou_delhi, label="SOUTH DELHI")
plt.plot(year, prob_nor_eas_delhi, label="NORTH EAST DELHI")


plt.ylabel("Probabilities of Fatalities")
plt.xlabel("Year")
plt.title("Fatality rate across the different year across the Given Year Given DIstricts")
plt.ylim(0.05, 0.5)
plt.legend()
plt.show()

# %% [markdown]
# # Vehicle at fault

# %%
vehichle_at_fault

# %%
x=df[df['VEHICLE AT FAULT']==vehichle_at_fault[1]]
print(vehichle_at_fault[1])
for z in year:
    xx=x[x['YEAR']==z]
    a=xx['TYPE OF ACCIDENT'].value_counts()
    
    print(z)
    print(a)

# %% [markdown]
# # Vehicle At Fault	UNKNOWN

# %%
pro_unkn=[ 0.3850117096,0.4987277354,0.421107628,0.4549450549,0.3877777778,0.3926585095,0.3007723762,0.314825415,0.3345398139
,0.3878116343]

# %%
x=df[df['VEHICLE AT FAULT']==vehichle_at_fault[2]]
print(vehichle_at_fault[2])
for z in year:
    xx=x[x['YEAR']==z]
    a=xx['TYPE OF ACCIDENT'].value_counts()
    
    print(z)
    print(a)

# %% [markdown]
# # Vehicle At Fault	S/C&M/C

# %%
pro_scmc=[0.1247833622,0.1750245821,0.1552604699,0.1660039761,0.1870428422,0.1450729927,0.1058732612,0.1253776435
,0.1381461676,0.1386138614]

# %%
x=df[df['VEHICLE AT FAULT']==vehichle_at_fault[3]]
print(vehichle_at_fault[3])
for z in year:
    xx=x[x['YEAR']==z]
    a=xx['TYPE OF ACCIDENT'].value_counts()
    
    print(z)
    print(a)

# %% [markdown]
# # Vehicle At Fault	HTV/GDS

# %%
vehichle_at_fault

# %%
pro_htv=[0.4145985401,0.4292929293,0.4295190713,0.460035524,0.4103942652,0.4146730463,0.3542757417,0.3944636678
,0.3588621444,0.3829268293]

# %% [markdown]
# # PLotting the probability fatality of the Vehicle at faults

# %%
plt.figure(figsize=(10,5))
plt.plot(year, Probability_of_fatalities, label="PVT CAR")
plt.plot(year, pro_unkn, label="UNKNOWN")
plt.plot(year, pro_scmc, label="S/C&M/C")
plt.plot(year, pro_htv, label="HTV/GDS")

plt.ylabel("Probabilities of Fatalities")
plt.xlabel("Year")
plt.title("Fatality rate across the different year across the Given Year Given Vehicle at Fault")
plt.ylim(0.05, 0.7)
plt.legend()
plt.show()

# %% [markdown]
# # Victime type

# %%
victim

# %%
x=df[df['VICTIM']==victim[1]]
print(victim[1])
for z in year:
    xx=x[x['YEAR']==z]
    a=xx['TYPE OF ACCIDENT'].value_counts()
    
    print(z)
    print(a)

# %% [markdown]
# # VIctim	S/C & M/C

# %%
pro_vi_scmc=[0.2445956765,0.284556314,0.2835390947,0.2646579805,0.2417962003,0.2216437337,0.1800194616,0.1878583474,0.1959054006
,0.2143134967]

# %%
x=df[df['VICTIM']==victim[2]]
print(victim[2])
for z in year:
    xx=x[x['YEAR']==z]
    a=xx['TYPE OF ACCIDENT'].value_counts()
    
    print(z)
    print(a)

# %% [markdown]
# # VIctim	CAR

# %%
victim

# %%
pro_vi_car=[0.06153846154,0.1451187335,0.1382352941,0.1904761905,0.1478696742,0.1488469602,0.09659090909
,0.129740519,0.1345646438,0.1540785498]

# %%
plt.figure(figsize=(10,5))
plt.plot(year, Probability_of_fatalities2, label="PEDESTRIAN")
plt.plot(year, pro_vi_scmc, label="S/C & M/C")
plt.plot(year, pro_vi_car, label="CAR")

plt.ylabel("Probabilities of Fatalities")
plt.xlabel("Year")
plt.title("Fatality rate across the different year across the Given Year Given Victim")
plt.ylim(0.05, 0.7)
plt.legend()
plt.show()
