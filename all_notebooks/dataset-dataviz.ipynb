# %% [markdown]
# I used [visao-data.com](http://visao-data.com)to create a dataviz for this dataset. Explore lift calculations. [https://visao-data.com/graph_explorer.php?dataset_id=54](http://https://visao-data.com/graph_explorer.php?dataset_id=54)
