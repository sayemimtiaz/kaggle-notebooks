# %% [markdown]
# Jefferson County, is a county located in the U.S. state of Colorado. As of the 2010 census, the population was 534,543, making it the fourth-most populous county in Colorado. The county seat is Golden, and the most populous city is Lakewood.
#
# Jefferson County is included in the Denver-Aurora-Lakewood, CO Metropolitan Statistical Area. Located along the Front Range of the Rocky Mountains, Jefferson County is adjacent to the state capital of Denver.
# https://en.wikipedia.org/wiki/Jefferson_County,_Colorado

# %% [markdown]
# ![](https://www.jeffco.us/ImageRepository/Document?documentID=10064)https://www.jeffco.us/3442/Trails

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import plotly.graph_objects as go
import plotly.offline as py

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
IMG_PATH = "../input/jefferson-county-colorado-open-space-and-trails/Peaks-to-Plains-Trail-Map.jpeg"

imgArray = cv.imread(IMG_PATH)

# %%
plt.imshow(imgArray)

plt.show()

# %%
df = pd.read_csv('../input/jefferson-county-colorado-open-space-and-trails/open_space_trails.csv', encoding='utf8')
pd.set_option('display.max_columns', None)
df.head()

# %%
# !pip install pywaffle

# %%
difficulty = df["TRAIL_DIFFICULTY_RATING"].value_counts()

# %%
from pywaffle import Waffle

plt.figure(
    FigureClass=Waffle,
    rows=5,
    columns=10,
    values=difficulty,
    title={'label': 'Trail Difficulty Distribution', 'loc': 'left'},
    labels=["{}({})".format(a, b) for a, b in zip(difficulty.index, difficulty) ],
    # Set the position of the legend
    legend={'loc': 'upper left', 'bbox_to_anchor': (1, 1)},
    dpi=100
)
plt.show()

# %%
IMG_PATH1 = "../input/jefferson-county-colorado-open-space-and-trails/Windy-Saddle-Park-Map.jpeg"

imgArray1 = cv.imread(IMG_PATH1)

# %%
fig = px.bar(df, 
             x='PARK_NAME', y='MILEAGE', color_discrete_sequence=['#2B3A67'],
             title='Trail Mileage by Park', text='TRAIL_DIFFICULTY_RATING')
fig.show()

# %%
plt.imshow(imgArray1)

plt.show()

# %% [markdown]
#     #PyComp By Thiago Panini  @thiagopanini

# %%
# !pip install pycomp

# %%
# Importing libraries
from pycomp.viz.insights import *

# JP rate
difficulty_colors = ['crimson', 'darkslateblue', 'cyan']
plot_donut_chart(df=df, col='TRAIL_DIFFICULTY_RATING',  colors=difficulty_colors,
                 title='Absolute Total and Percentual Trail Difficulty')

# %% [markdown]
# #That Piechart above with PyComp by Panini, has more details than the chart below, from where I got the inspiration.
#
# ![](https://www.jeffco.us/ImageRepository/Document?documentID=24819)https://insights.arcgis.com/#/view/707fa5ea6ab94691a0edb5460d1d8ba7

# %% [markdown]
# #After I saw that image I remembered that Tables snippets
# #Codes from Preston Fan https://www.kaggle.com/prestonfan/data-visualization-palmer-archipelago-penguins/notebook

# %%
import plotly.figure_factory as ff

head = ff.create_table(df.head())
py.iplot(head)

# %%
describe = ff.create_table(df.describe())
py.iplot(describe)

# %%
missing_count = pd.DataFrame({'missing': df.isnull().sum().sort_values(ascending=False)})

missing_count = ff.create_table(missing_count)
py.iplot(missing_count)

# %% [markdown]
# #Simple Imputer with Table.

# %%
#https://www.kaggle.com/prestonfan/data-visualization-palmer-archipelago-penguins/notebook
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='most_frequent')
df.iloc[:,:] = imputer.fit_transform(df)

head = ff.create_table(df.head())
py.iplot(head)

# %%
missing_count = pd.DataFrame({'missing': df.isnull().sum().sort_values(ascending=False)})

missing_count = ff.create_table(missing_count)
py.iplot(missing_count)

# %%
IMG_PATH2 = "../input/jefferson-county-colorado-open-space-and-trails/apex_designated_trail_use_instructions.jpeg"

imgArray2 = cv.imread(IMG_PATH2)

# %%
df[categorical_nan].isna().sum()

# %%
plt.imshow(imgArray2)

plt.show()

# %%
missing_val_count_by_column = (df.isnull().sum())
print(missing_val_count_by_column[missing_val_count_by_column > 0])

# %%
convertedArray = cv.cvtColor(imgArray, cv.COLOR_BGR2RGB)

plt.subplots(figsize=(15,10))
plt.imshow(convertedArray);plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

#fill in mean for floats
for c in df.columns:
    if df[c].dtype=='float16' or  df[c].dtype=='float32' or  df[c].dtype=='float64':
        df[c].fillna(df[c].mean())

#fill in -999 for categoricals
df = df.fillna(-999)
# Label Encoding
for f in df.columns:
    if df[f].dtype=='object': 
        lbl = LabelEncoder()
        lbl.fit(list(df[f].values))
        df[f] = lbl.transform(list(df[f].values))
        
print('Labelling done.')

# %%
df = pd.get_dummies(df)

# %%
from PIL import Image

img = Image.open("../input/jefferson-county-colorado-open-space-and-trails/apex_designated_trail_use_instructions.jpeg")
img

# %%
from sklearn.impute import SimpleImputer
my_imputer = SimpleImputer()
df_with_imputed_values = my_imputer.fit_transform(df)

# %% [markdown]
# #FeatureWiz Codes by RSESHA https://www.kaggle.com/rsesha/new-featurewiz-demo/notebook

# %%
# !pip install featurewiz

# %%
from featurewiz import featurewiz

# %%
import torch
import fastai
from fastai.tabular.all import *
from fastai.text.all import *
from fastai.vision.all import *

from fastai import *


print(f'Notebook last run on {datetime.fromtimestamp(time.time()).strftime("%Y-%m-%d, %H:%M:%S UTC")}')
print('Using fastai version ',fastai.__version__)
print('And torch version ',torch.__version__)

# %%
TensorTypes = (TensorImage,TensorMask,TensorPoint,TensorBBox)

# %%
timg = TensorImage(image2tensor(img))
tpil = PILImage.create(timg)

# %%
img = PILImage(PILImage.create(timg).resize((600,400)))
img

# %%
target = 'TRAIL_DIFFICULTY_RATING'

# %% [markdown]
# ![](https://www.jeffco.us/ImageRepository/Document?documentID=10281)https://www.jeffco.us/3442/Trails

# %%
tpil.resize((64,64))

# %%
feats = featurewiz(df, target, corr_limit=0.7, verbose=0)
len(feats)

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
#RFC = RandomForestRegressor(n_estimators=200, bootstrap=True,
RFC = RandomForestClassifier(n_estimators=200, bootstrap=True,
                            oob_score=True, random_state=43)

# %%
preds = [x for x in list(df) if x not in [target]]
len(preds)

# %%
from featurewiz import convert_all_object_columns_to_numeric
dfx,_ = convert_all_object_columns_to_numeric(df)
dfx.head()

# %%
X = dfx[preds]
y_map = {'Least Difficult':0,'More Difficult':1}
y = df[target].map(y_map).values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.1,random_state=99)
print(X_train.shape, y_train.shape)

# %%
X_train.head()

# %%
df_without_missing_values = df.dropna(axis=1)

# %%
from sklearn.model_selection import cross_val_score
full = cross_val_score(RFC, X_train, y_train, scoring='accuracy', cv=5, n_jobs=-1, verbose=0)
print('Average Cross Validation Accuracy using full set of variables = %0.1f%%' %(
                        np.mean(full)*100))

# %% [markdown]
# #I made two ways of Imputations, even Kaggle Tutorial. Simply didn't work. From now, I commented the rest of the script.

# %%
convertedArray1 = cv.cvtColor(imgArray1, cv.COLOR_BGR2RGB)

plt.subplots(figsize=(15,10))
plt.imshow(convertedArray1);plt.show()

# %%
#from sklearn.metrics import balanced_accuracy_score
#print('Balanced Accuracy on Held out Test Data:%0.1f%%' %(100*balanced_accuracy_score(y_test,RFC.fit(X_train,y_train).predict(X_test))))

# %%
#Code by Olga Belitskaya https://www.kaggle.com/olgabelitskaya/sequential-data/comments
from IPython.display import display,HTML
c1,c2,f1,f2,fs1,fs2=\
'#4251f5','#42a7f5','Akronim','Smokum',30,15
def dhtml(string,fontcolor=c1,font=f1,fontsize=fs1):
    display(HTML("""<style>
    @import 'https://fonts.googleapis.com/css?family="""\
    +font+"""&effect=3d-float';</style>
    <h1 class='font-effect-3d-float' style='font-family:"""+\
    font+"""; color:"""+fontcolor+"""; font-size:"""+\
    str(fontsize)+"""px;'>%s</h1>"""%string))
    
    
dhtml('Be patient. Marília Prata, @mpwolke was Here.' )
