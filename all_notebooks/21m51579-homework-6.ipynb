# %% [markdown]
# # Homework6
# # 21M51579 Hayato Ishikawa
# In this report, I chose Canada as the research target. The codes to construct a time-series and colored tables are following. The main discussion part is at the end of the page.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

selected_country_1='Canada'
selected_country_2='Canada'

df1 = pd.read_csv('../input/covid19-global-dataset/worldometer_coronavirus_daily_data.csv', header=0)
df1 = df1[df1['country']==selected_country_1]
df2 = pd.read_csv('../input/covid-world-vaccination-progress/country_vaccinations.csv', header=0)
df2 = df2[df2['country']==selected_country_2]
df1.index = pd.to_datetime(df1['date'])
df2.index = pd.to_datetime(df2['date'])

# %%
print(df1.columns)
print(df2.columns)

# %%
print(np.unique(df2['country']))

# %% [markdown]
# # Analyses
#
# From here, I will analyze the date that was loaded as an dataframe object.

# %%
fig,ax = plt.subplots(figsize=(10, 5))
ax.plot(df1.index,df1['daily_new_cases'],'b', label='Cases')
ax1 = ax.twinx()
ax1.plot(df2.index,df2['daily_vaccinations'],'r', label='Vacctinations')
plt.show()

# %% [markdown]
# # Improved visualization (1. of "mission due next week")
# From here, we will be using the modules iplot and plotly to make better visualizations.

# %%
from plotly.offline import iplot
import plotly. graph_objs as go

daily_new_cases = go.Scatter(x=df1.index, y=df1['daily_new_cases'], yaxis='y1', name='Daily confirmed cases')
daily_vaccinations = go.Scatter(x=df2.index, y=df2['daily_vaccinations'], yaxis='y2', name='Daily vacctinations')

layout_obj = go.Layout(title='COVID vs. Vaccines', xaxis=dict(title='Date'), yaxis=dict(title='Daily cases'), yaxis2=dict(title='Vacctinations', side='right', overlaying='y'))
fig = go.Figure(data=[daily_new_cases, daily_vaccinations], layout=layout_obj)
iplot(fig)
fig.write_html('outcome.html')

# %% [markdown]
# # Colored tables (2.)
# Create colored tables

# %%
style_object=df1.style.background_gradient(cmap='jet').highlight_max('daily_new_cases').set_caption('Daily CODID-19 Cases')
display(style_object)
style_object=df2.style.background_gradient(cmap='jet').highlight_max('people_fully_vaccinated_per_hundred').set_caption('Daily Vaccinations')
display(style_object)

# %% [markdown]
# # Global Ranking (3.)

# %%
df1 = pd.read_csv('../input/covid19-global-dataset/worldometer_coronavirus_daily_data.csv', header=0)
df1 = df1.groupby('country').sum()['daily_new_cases'].sort_values(ascending=False)[0:22]
print(df1)
df2 = pd.read_csv('../input/covid-world-vaccination-progress/country_vaccinations.csv', header=0)
df2 = df2.groupby('country').max()['people_fully_vaccinated_per_hundred'].sort_values(ascending=False)[0:97]
print(df2.to_string())

# %% [markdown]
# # Discussion (3. 4. 5.)

# %% [markdown]
# From the ranking tables I made, we can find that Canada is **#22** for the total number of cases and **#97** for the total vaccinations per number of people.
# Many COVID cases are observed in Canada. Canada's population is only about 38 million, 1/10 of the United States. Therefore, it is fair to say the COVID situation in Canada is quite serious.
# Despite the serious situation, the vaccination does not spread enough. The ranking suggests that the total vaccinations per number of people # 97 in the world. It is estimated that Canada is behind the OEDC avarage because most of the developed countries is above Canada's position in the ranking.
#
# According to the dataset, the latest record of COVID-19 (new) cases in Canada is 3,415 on May 23th, 2021. According to Canadian Broadcasting Corporation (CBC) COVID-19 tracker, yesterday (May 26th, 2021) was 2,594. As you can recognize from the graphs which I made, now Canada seems to be at the end of the thrid wave of the infection.
#
# From the comparison with other countries, the vaccination progress seems limited. However, according to CBC "The National," the fragship news program, is pointing out the vaccination policy by the federal government are going well because more than half Canadian are got vaccine shots at least one time. It can confirm from my analysis table, too. Also, the graph I made shows that the third wave is moderated after the vaccination spreads in the larger scale. British Columbia, a western province, decided to loose the resitriction policy this week, according to CBC. But also, some provinces such as Manitoba are under serious medical emergency. According to CBC, there is no ECU bed in Winnipeg, the capital of Manitoba, as for May 26th, 2021. From these data and news, we can guess that the national government is doing their best, and the positive effect are shown some parts of Canada. However, other parts of the country are still under the serious situation and the national government have to support such areas, continuously.
