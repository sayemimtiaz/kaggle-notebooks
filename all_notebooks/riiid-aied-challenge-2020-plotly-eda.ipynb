# %% [markdown]
# # INTRODUCTION
# * In this kernel with Imagining Post-COVID Education with AI, Intermediate visualization we will learn how to use plotly library.
#     * Plotly library: Plotly's Python graphing library makes interactive, publication-quality graphs online. Examples of how to make line plots, scatter plots, area charts, bar charts, error bars, box plots, histograms, heatmaps, subplots, multiple-axes, polar charts, and bubble charts.
#
# <br>Content:
#
# 1. [train.csv](#1)
#     1. [user_id](#2)
#     1. [content_id](#3)
#     1. [task_container_id](#4)
#     1. [content_type_id](#5)
#     1. [answered_correctly](#6)
#     1. [prior_question_elapsed_time](#7)
#     1. [prior_question_had_explanation](#8)
# 1. [questions.csv](#9)
#     1. [correct_answer](#10)
#     1. [part](#11)
#     1. [tags](#12)
# 1. [lectures.csv](#13)
#     1. [type_of](#14)
#     1. [questions-lectures](#15)

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib_venn as venn
# %matplotlib inline


import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.tools as tls
from plotly.subplots import make_subplots

import plotly.express as px
import plotly.figure_factory as ff
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode, iplot
from IPython.display import HTML, Image

# %% [markdown]
# <a id="1"></a>
# # train.csv

# %%
train = pd.read_csv(
    '/kaggle/input/riiid-test-answer-prediction/train.csv', 
    low_memory=False, 
    nrows=10**6, 
    dtype={ 
        'row_id': 'int64', 
        'timestamp': 'int64', 
        'user_id': 'int32', 
        'content_id': 'int16', 
        'content_type_id': 'int8',
        'task_container_id': 'int16', 
        'user_answer': 'int8', 
        'answered_correctly': 'int8', 
        'prior_question_elapsed_time': 'float32', 
        'prior_question_had_explanation': 'boolean'
    }
)

# %%
train.info()

# %% [markdown]
# <a id="2"></a>
# ## user_id

# %%
user_id = train.user_id.value_counts().sample(50)

values=user_id.values
for a in range(0,len(values)):
    for i in range(a+1,len(values)):
         if ((i+1)!=len(values)) and (values[a]<values[(i)]):
            c=values[a]
            values[a]=values[i]
            values[i]=c
values=values
index =  list(range(1,500))

for a in range(0,len(index)):
    for i in range(a+1,len(index)):
         if ((i+1)!=len(index)) and (index[a]<index[(i)]):
            c=index[a]
            index[a]=index[i]
            index[i]=c
trace = go.Bar(
    y=index,
    x=values,
    orientation='h',
    marker=dict(
        color=values,
        colorscale = 'Portland',
        reversescale = True
    ),
)
layout = go.Layout(
    title='user_id',
    template="plotly_white"
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="user_id")

# %% [markdown]
# <a id="3"></a>
# ## content_id

# %%
content_id = train.content_id.value_counts().sample(50)

values=content_id.values
for a in range(0,len(values)):
    for i in range(a+1,len(values)):
         if ((i+1)!=len(values)) and (values[a]<values[(i)]):
            c=values[a]
            values[a]=values[i]
            values[i]=c
values=values
index =  list(range(1,500))

for a in range(0,len(index)):
    for i in range(a+1,len(index)):
         if ((i+1)!=len(index)) and (index[a]<index[(i)]):
            c=index[a]
            index[a]=index[i]
            index[i]=c
trace = go.Bar(
    y=index,
    x=values,
    orientation='h',
    marker=dict(
        color=values,
        colorscale = 'Portland',
        reversescale = True
    ),
)
layout = go.Layout(
    title='content_id',
    template="plotly_white"
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="content_id")

# %% [markdown]
# <a id="4"></a>
# ## task_container_id

# %%
task_container_id = train.task_container_id.value_counts().sample(50)

values=task_container_id.values
for a in range(0,len(values)):
    for i in range(a+1,len(values)):
         if ((i+1)!=len(values)) and (values[a]<values[(i)]):
            c=values[a]
            values[a]=values[i]
            values[i]=c
values=values
index =  list(range(1,500))

for a in range(0,len(index)):
    for i in range(a+1,len(index)):
         if ((i+1)!=len(index)) and (index[a]<index[(i)]):
            c=index[a]
            index[a]=index[i]
            index[i]=c
trace = go.Bar(
    y=index,
    x=values,
    orientation='h',
    marker=dict(
        color=values,
        colorscale = 'Portland',
        reversescale = True
    ),
)
layout = go.Layout(
    title='task_container_id',
    template="plotly_white"
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="task_container_id")

# %% [markdown]
# <a id="5"></a>
# ## content_type_id

# %%
content_type_id = train.content_type_id.value_counts()
trace = go.Bar(
    x=content_type_id.index,
    y=content_type_id.values,
    marker=dict(
        color=content_type_id.values,
        colorscale = 'RdBu',
        reversescale = True
    ),
)

layout = go.Layout(
    title='content_type_id',
    template="plotly_white"
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="content_type_id")

# %%
content_type_id = train.content_type_id.value_counts()
labels = train.content_type_id.unique()
# figure
fig = {
  "data": [
    {
      "values": content_type_id,
      "labels": labels,
      "domain": {"x": [0, .5]},
      "hole": .0,
      "type": "pie"
    },],
  "layout": {
        "title":"content_type_id",
    }
}
iplot(fig)

# %% [markdown]
# <a id="6"></a>
# ## answered_correctly

# %%
train.answered_correctly.value_counts()

# %%
answered_correctly = train.answered_correctly.value_counts()
trace = go.Bar(
    x=answered_correctly.index,
    y=answered_correctly.values,
    marker=dict(
        color=answered_correctly.values,
        colorscale = 'Portland',
        reversescale = True
    ),
)

layout = go.Layout(
    title='answered_correctly',
    template="plotly_white"
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="answered_correctly")

# %%
answered_correctly = train.answered_correctly.value_counts()
labels = train.answered_correctly.unique()
# figure
fig = {
  "data": [
    {
      "values": answered_correctly,
      "labels": labels,
      "domain": {"x": [0, .5]},
      "hole": .0,
      "type": "pie"
    },],
  "layout": {
        "title":"answered_correctly",
    }
}
iplot(fig)

# %% [markdown]
# <a id="7"></a>
# ## prior_question_elapsed_time

# %%
prior_question_elapsed_time = train.prior_question_elapsed_time.value_counts().head(50)
trace = go.Bar(
    x=prior_question_elapsed_time.index,
    y=prior_question_elapsed_time.values,
    marker=dict(
        color=prior_question_elapsed_time.values,
        colorscale = 'RdBu',
        reversescale = True
    ),
)
layout = go.Layout(
    title='prior_question_elapsed_time',
    template="plotly_white"
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="prior_question_elapsed_time")

# %%
prior_question_elapsed_time = train.prior_question_elapsed_time.value_counts().head(50)

values=prior_question_elapsed_time.values
for a in range(0,len(values)):
    for i in range(a+1,len(values)):
         if ((i+1)!=len(values)) and (values[a]<values[(i)]):
            c=values[a]
            values[a]=values[i]
            values[i]=c
values=values[::-1]
index =  list(range(1,500))

for a in range(0,len(index)):
    for i in range(a+1,len(index)):
         if ((i+1)!=len(index)) and (index[a]<index[(i)]):
            c=index[a]
            index[a]=index[i]
            index[i]=c
trace = go.Bar(
    x=index,
    y=values,
    orientation='v',
    marker=dict(
        color=values,
        colorscale = 'Portland',
        reversescale = True
    ),
)
layout = go.Layout(
    title='prior_question_elapsed_time',
    template="plotly_white"
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="prior_question_elapsed_time")

# %%
train.prior_question_elapsed_time.isnull().any()

# %%
prior_question = train.prior_question_elapsed_time.notnull()
prior_question.value_counts().reset_index()

# %%
prior_question_elapsed_time = train.prior_question_elapsed_time.notnull().value_counts()
trace = go.Bar(
    x=prior_question_elapsed_time.index,
    y=prior_question_elapsed_time.values,
    marker=dict(
        color=prior_question_elapsed_time.values,
        colorscale = 'Portland',
        reversescale = True
    ),
)

layout = go.Layout(
    title='prior_question_elapsed_time',
    template="plotly_white"
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="prior_question_elapsed_time")

# %% [markdown]
# <a id="8"></a>
# ## prior_question_had_explanation

# %%
prior_question_had_explanation = train.prior_question_had_explanation.value_counts()
trace = go.Bar(
    x=prior_question_had_explanation.index,
    y=prior_question_had_explanation.values,
    marker=dict(
        color=prior_question_had_explanation.values,
        colorscale = 'Portland',
        reversescale = True
    ),
)

layout = go.Layout(
    title='prior_question_had_explanation',
    template="plotly_white"
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="prior_question_had_explanation")

# %% [markdown]
# <a id="9"></a>
# # questions.csv

# %%
questions = pd.read_csv("../input/riiid-test-answer-prediction/questions.csv")
questions.head()

# %% [markdown]
# <a id="10"></a>
# ## correct_answer

# %%
correct_answer = questions.correct_answer.value_counts()
trace = go.Bar(
    x=correct_answer.index,
    y=correct_answer.values,
    marker=dict(
        color=correct_answer.values,
        colorscale = 'RdBu',
        reversescale = True
    ),
)
layout = go.Layout(
    title='correct_answer',
    template="plotly_white"
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="correct_answer")

# %%
correct_answer = questions.correct_answer.value_counts()
labels = questions.correct_answer.unique()
# figure
fig = {
  "data": [
    {
      "values": correct_answer,
      "labels": labels,
      "domain": {"x": [0, .5]},
      "hole": .0,
      "type": "pie"
    },],
  "layout": {
        "title":"correct_answer",
    }
}
iplot(fig)

# %% [markdown]
# <a id="11"></a>
# ## part

# %%
part = questions.part.value_counts()
trace = go.Bar(
    x=part.values,
    y=part.index,
    orientation='h',
    marker=dict(
        color=part.values,
        colorscale = 'RdBu',
        reversescale = True
    ),
)
layout = go.Layout(
    title='part',
    template="plotly_white"
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="part")

# %%
part = questions.part.value_counts()
labels = questions.part.unique()
# figure
fig = {
  "data": [
    {
      "values": part,
      "labels": labels,
      "domain": {"x": [0, .5]},
      "hole": .0,
      "type": "pie"
    },],
  "layout": {
        "title":"questions-part",
    }
}
iplot(fig)

# %% [markdown]
# <a id="12"></a>
# ## tags

# %%
tag = questions['tags'].str.split(' ').explode('tags').reset_index()
tag = tag['tags'].value_counts()
trace = go.Bar(
    x=tag.index,
    y=tag.values,
    marker=dict(
        color=tag.values,
        colorscale = 'RdBu',
        reversescale = True
    ),
)
layout = go.Layout(
    title='questions tags',
    template="plotly_white", 
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="tag")

# %%
tags = questions['tags'].str.split(' ').explode('tags').reset_index()
tags = tags['tags'].value_counts().head(100)

values=tags.values
for a in range(0,len(values)):
    for i in range(a+1,len(values)):
         if ((i+1)!=len(values)) and (values[a]<values[(i)]):
            c=values[a]
            values[a]=values[i]
            values[i]=c
values=values[::-1]
list1 =  list(range(1,500))

for a in range(0,len(list1)):
    for i in range(a+1,len(list1)):
         if ((i+1)!=len(list1)) and (list1[a]<list1[(i)]):
            c=list1[a]
            list1[a]=list1[i]
            list1[i]=c
trace = go.Bar(
    x=list1,
    y=values,
    orientation='v',
    marker=dict(
        color=values,
        colorscale = 'RdBu',
        reversescale = True
    ),
)
layout = go.Layout(
    title='tags',
    template="plotly_white"
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="tags")

# %% [markdown]
# <a id="13"></a>
# # lectures.csv

# %%
lectures = pd.read_csv(
    '../input/riiid-test-answer-prediction/lectures.csv', 
    low_memory=False, 
    dtype={
        
        'part': 'int8', 
        'lecture_id': 'int16', 
        'tag': 'int16', 
    }
)
lectures.head()

# %% [markdown]
# <a id="14"></a>
# ## type_of

# %%
type_of = lectures.type_of.value_counts()
trace = go.Bar(
    x=type_of.values,
    y=type_of.index,
    orientation='h',
    marker=dict(
        color=type_of.values,
        colorscale = 'Portland',
        reversescale = True
    ),
)
layout = go.Layout(
    title='type_of',
    template="plotly_white", 
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="type_of")

# %%
type_of = lectures.type_of.value_counts()
labels = lectures.type_of.unique()
# figure
fig = {
  "data": [
    {
      "values": type_of,
      "labels": labels,
      "domain": {"x": [0, .5]},
      "hole": .0,
      "type": "pie"
    },],
  "layout": {
        "title":"type_of",
        
    }
}
iplot(fig)

# %% [markdown]
# <a id="15"></a>
# ## questions-lectures

# %%
part=[0,1,2,3,4,5,6]
a =questions.part.unique()
b = questions.part.value_counts()

x =lectures.part.unique()
y = lectures.part.value_counts()


fig = go.Figure(data=[
    go.Bar(name='questions', x=part, y=b[a]),
    go.Bar(name='lectures', x=part, y=y[x])
])
# Change the bar mode
fig.update_layout(title='questions-lectures',barmode='group',template="plotly_white")
fig.show()

# %% [markdown]
# WORK IN PROGRESS
