# %%
import pandas as pd
import seaborn as sn
ba = pd.read_csv('../input/battles.csv')
cd = pd.read_csv('../input/character-deaths.csv') 
cp = pd.read_csv('../input/character-predictions.csv')
cp_p = cp[cp['name'].str.contains('Jaqen')]
cp_p

# %%
from IPython.display import HTML
import base64
import bz2
import pickle

s = """..."""
b = base64.b64decode(s)
p = bz2.decompress(b)
i=pickle.loads(p)
HTML("<pre style='font-size:5px;line-height:.7'>"+i+"</pre>")

# %% [markdown]
# ## Cool new names

# %%
print(', '.join(sorted(list(set([n.split(' ')[0] for n in cp['name'].values])))))
