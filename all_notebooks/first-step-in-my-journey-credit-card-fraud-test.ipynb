# %% [markdown]
# 1. # My First Step of the Kaggle Journey: Credit Card Fraud Test

# %% [markdown]
# This is my first notebook so it is just a test. In this case, I am using the creditcard-fraud-detection dataset and just playing around with the IsolationForest model. As you can see, the precision that I am getting for detecting fraud is not that great (82%). I will continue to look at in how to improve (or perhaps you can give me pointers?) for fraud detection as I have read somewhere iforest should be the best anomaly detection.

# %% [markdown]
# A little bit about myself. I was a practicing engineer in Canada that has industry experience mostly in the energy industry space. I deal with a lot of data analysis (not machine learning) with mostly financial and scada data.
#
# I have recently quit my job upon receiving an offer for graduate school in Software Engineering. While waiting for school to start, I am currently trying to improve my skillset and have just recently found Kaggle, so here I am :)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
from sklearn.ensemble import IsolationForest
from sklearn.metrics import classification_report, mean_squared_error
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
creditcards = pd.read_csv("/kaggle/input/creditcard-fraud-detection/creditcard.csv")

# %%
print(creditcards.columns)
print(creditcards.shape)

# %%
corMatrix = creditcards.corr()

# %%
sns.heatmap(corMatrix)
plt.show

# %% [markdown]
# Since we are classifying if there is a fraud, Y = class and X = everything else

# %%
xcol = creditcards.columns.tolist()

# %%
xcol = [col for col in xcol if col not in ["Class"]]
ycol = "Class"
print(xcol)

# %%
X = creditcards[xcol]
Y = creditcards[ycol]

# %%
#defining predictions
IF = IsolationForest(max_features = 4)
IF.fit(X)
YPredictions = IF.predict(X)

#Switch values to coincide with 0=valid
YPredictions[YPredictions==1] = 0
YPredictions[YPredictions == -1] = 1


print(classification_report(Y,YPredictions))

# %%
Actualfraud = creditcards.index[creditcards["Class"]==1].tolist()
len(Actualfraud)

# %% [markdown]
# Since there are only 492 Fraud Cases, I am going to compare my predictions with the actual.

# %%
countmiss = 0
for fraud in Actualfraud:
    print("The Predicted value for fraud at line: {} is {}".format(fraud, YPredictions[fraud]))
    if YPredictions[fraud] == 0:
        countmiss = countmiss+1

print("Total missed: {}".format(countmiss))
accuracy = (len(Actualfraud)-countmiss)/float(len(Actualfraud))*100
print("Accuracy: {}%".format(accuracy))
