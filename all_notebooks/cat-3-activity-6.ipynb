# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Group number=    5
# Activity Number=  6

# Group members
# Krishan Mohan Yadav     18SCSE1010076
# Lakshya Ahlawat         18SCSE1010368  
# Mayank Rana             18SCSE1010384 

# LINL   https://www.kaggle.com/krishanm0han/cat-3-activity-6

# %%
#---------------KRISHAN MOHAN YADAV-- 18SCSE1010076

#Q.no-1) Read the dataset


import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df=pd.read_csv("/kaggle/input/human-resources-data-set/HRDataset_v13.csv")
df

# %%
#Q.No-2) Describe the dataset


df.describe()

# %%
df.info()

# %%
#Q No-3) Find mean,median and mode of columns


df.mean()

# %%
df.median()

# %%
df.mode()

# %%
#--------------Lakshya Ahlawat --18SCSE1010368

#Q.NO-4). Find the distribution of columns with numerical data. Evaluate if they are normal or not


df.dtypes

# %%
# from above we can figure out the column with numerical data i.e dayslatelast30,SpecialProjectsCount,EmpSatisfaction ,EngagementSurvey etc
sns.distplot(df['MarriedID']) #cheking distribution

# %%
sns.distplot(df['EmpSatisfaction'])

# %%
sns.distplot(df['EngagementSurvey'])

# %%
#Q.no-5) Draw different types of graphs to represent information hidden in the dataset.

plt.hist(df.PerfScoreID)
plt.xlabel('PerfScoreID')
plt.ylabel('Total Employee')

# %%
# graph to represent males and females in paricular field
plt.figure(figsize=(16,5))
sns.countplot(x=df['Department'],hue=df['Sex'])

# %%
print(df['Sex'].value_counts())
df['Sex'].value_counts().plot(kind='bar')

# %%
# count of people working at the position
count=df.groupby(df["Position"]).count()
count = pd.DataFrame(count.to_records())
count = count['Position']
count

import seaborn as sns
plt.figure(figsize=(15,10))
sns.countplot(y='Position', data=df,order=count )

# %%
# pic to show maritial status of emploies working
plt.figure(figsize=(10,6))
df['MaritalDesc'].value_counts().plot(kind='pie',autopct='%0.1f%%')

# %%
#Q. No-6). Find columns which are correlated


df4=df.corr(method='spearman', min_periods=1)
df4
#Positive column are correlated

# %%
#------------------------Mayank Rana -----18SCSE1010384 

# Q.No-7)   Find columns which are not correlated.


df.corr(method='spearman', min_periods=1)

# Negative column not correlated.

# %%
#Q.No-8). Compare different columns of dataset

df2=df.loc[0:300,'MarriedID':'GenderID']
df2
comp= np.where(df1["MaritalStatusID"] == df2["MaritalStatusID"], True, False)
df2["equal"] = comp
df2

# %%
df3=df.loc[0:300,'PerfScoreID':'PayRate']
df3
comp= np.where(df3["PerfScoreID"] == df3["PayRate"], True, False)
df3["equal"] = comp
df3

# %%
#Q.No-9). Is Any supervised machine learning possible ? if yes explain.

Yes it is possible, Machine learning is progressively employed in Human Resource analysis and 
has the potential to advance our understanding of a way to form up the personnel of a corporation, sector, industry, or economy.  
Machine learning offers new tools to beat challenges that ancient applied mathematics strategies do not seem to be well-suited. 
This knowledge set provides an summary of machine learning with a particular specialise in supervised learning 
(i.e., strategies that square measure designed to predict or classify associate outcome of interest).
