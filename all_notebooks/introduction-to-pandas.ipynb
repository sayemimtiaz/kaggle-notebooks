# %% [markdown]
# **Membuat Objek DataFrames**
#
# Contoh membuat objek dataframes dari objek dictionary

# %%
import pandas as pd
# Membuat dataframes dari dictionary
obj_dict = {'demam':[100,200,322,122],
            'ispa':[232,312,421,535],
            'kanker':[432,123,678,876],
            'jantung':[121,343,654,333]
            }

pd.DataFrame(obj_dict)

# %% [markdown]
# **Membaca data dari file**
#
# Contoh kode untuk membaca data tersebut dan assign ke dalam suatu variabel.

# %%
import pandas as pd

data = pd.read_csv('../input/datadiamonds/datadiamonds.csv')
data

# %% [markdown]
# **Practice Descriptif Statistik**
#
# Contoh kode untuk memeriksa data sederhana

# %%
import pandas as pd
data = pd.read_csv('../input/datadiamonds/datadiamonds.csv')
data.describe()
