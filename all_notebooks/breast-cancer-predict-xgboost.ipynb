# %%
import numpy as np
import pandas as pd
import category_encoders as ce
import random

from sklearn.metrics import classification_report, log_loss, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import ShuffleSplit

from xgboost import XGBClassifier
import matplotlib.pyplot as plt

# %%
data0 = pd.read_csv("../input/breast-cancer-wisconsin-data/data.csv")
data0[0:2].T

# %%
data0['diagnosis'].unique()

# %%
Name=['M','B']
Num=[0,1]

normal_mapping=dict(zip(Name,Num)) 
reverse_mapping=dict(zip(Num,Name)) 

def mapper(value):
    return reverse_mapping[value]

# %%
data0['diagnosis']=data0['diagnosis'].map(normal_mapping)
data0=data0.drop(['id','Unnamed: 32'],axis=1)

# %%
data0.iloc[:,:].hist(figsize=(15,15))
plt.show()

# %%
n=len(data0)
print(n)

# %%
N=[]
for i in range(n):
    N+=[i]
random.shuffle(N)

# %%
datay=data1['diagnosis']
data2=data1.drop(['diagnosis'],axis=1)

# %%
data3=np.array(data2)
datay3=np.array(datay)

# %%
train=data3[N[0:(n//10)*8]]
test=data3[N[(n//10)*8:]]
trainy=datay3[N[0:(n//10)*8]]
testy=datay3[N[(n//10)*8:]]

# %%
X = train
y = trainy

# %%
clf = XGBClassifier(max_depth=3, n_estimators=1000, learning_rate=0.01,use_label_encoder=False)

# %%
ss = ShuffleSplit(n_splits=5,train_size=0.8,test_size =0.2,random_state=0) 

for train_index, test_index in ss.split(X): 

    X_train, X_test = X[train_index], X[test_index]
    Y_train, Y_test = y[train_index], y[test_index]
    clf.fit(X_train, Y_train) 
    print(clf.score(X_test, Y_test))

# %%
PRED = clf.predict(test)
PRED[0:10]

# %%
ANS=testy
ANS[0:10]

# %%
accuracy=accuracy_score(ANS,PRED)
print(accuracy)
