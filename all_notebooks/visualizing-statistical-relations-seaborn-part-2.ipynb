# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
data=pd.read_csv('/kaggle/input/car-sale-advertisements/car_ad.csv',encoding ='iso-8859-9')

# %% [markdown]
# <span style="font-size:30px;color:crimson;font-family: 'Crimson Text', serif;"> If you like this notebook, Please UPVOTE ⭐️ as this Motivates ♡ to work more. </span>

# %% [markdown]
# <span style="font-size:30px;color:gray;font-family: 'Caveat', cursive;">  In Part 1, We already discussed tools for using scatterplots to visualize categorical data.</span>
#
# <b>[To visit Part 1 click here](https://www.kaggle.com/lazycoder00/plotting-categorical-data-seaborn-part-1)

# %% [markdown]
# <span style="font-size:30px;color:gray;font-family: 'Dancing Script',cursive;"> Before Reading this notebook, let me clear you with few assumptions: </span>
# - There is no observation of plots are mentioned(Why?, Answer is written downside)
# - This notebook is just to show you how to use seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.shape

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script',cursive;"> Let's check Null Value</span>

# %%
data.isnull().sum()

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script', cursive;"> Removing rows corresponding to null </span>

# %%
data.dropna(axis=0,inplace=True)

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script', cursive;">Now check Null count whether it is Zero or Not</span>

# %%
data.isnull().sum()

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script', cursive;">Let's check datatypes of each feature</span>

# %%
data.dtypes

# %% [markdown]
# # Visualizing statistical relationships

# %% [markdown]
# <div class="alert alert-block alert-info"> 📌 Statistical analysis is a process of understanding how variables in a dataset relate to each other and how those relationships depend on other variables. *italicized text*</div>

# %% [markdown]
# <div class="alert alert-block alert-info"> 📌 In this tutorial i'll be writing code along with documentation so that you can understand it better </div>

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script', cursive;">I'll will be using relplot() to show statistical relationship along with
# - Scatter Plot
# - line Plot  </span>

# %% [markdown]
# <span style="font-size:18px;color:black;font-family: 'Dancing Script', cursive;"><b>Relating variables with scatter plots: </b></span>
#
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script', cursive;"> Scatter plot helps you to depict relationship between two feature plotted on axis(x and y) using each observation of these features. This depiction allows the eye to infer a substantial amount of information about whether there is any meaningful relationship between them.</span>

# %%
data.shape

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#               color:white;">
#
#               We chose 150 rows(i.e. observation) to see plot clearly. Alot of observation will make it hard to understand indepth of these plots.
# </p>
# </div>

# %%
data=data[:150]

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script', cursive;"> That's a reason why i'm not going to give any observation about whole dataset. We are visualizing on a very low sample size. So that you can understand seaborn in better way ✌️</span>

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script', cursive;">⭐️ using sns.relplot() you can relate two axis; by default it uses ScatterPlot.
#
# The scatterplot() is the default kind in relplot() (it can also be forced by setting kind="scatter"): </span>

# %%
sns.relplot(x="price", y="engV", data=data)

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script', cursive;">Let's make X-axis attractive 😀, to make it more readable form i'm rotating ticks of x-axis  through some angle</span>

# %% [markdown]
# <span style="font-size:18px;color:crimson;">⭐️  Using <b> .set_xticklabels(rotation=30)</b> </span>

# %%
sns.relplot(x="price", y="engV", data=data).set_xticklabels(rotation=30)

# %%
sns.relplot(x="mileage", y="price", data=data)

# %%
sns.relplot(x="mileage", y="price", data=data)

# %%
sns.relplot(x="year", y="price", data=data).set_xticklabels(rotation=30)

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script', cursive;">⭐️ using hue</span>

# %%
sns.relplot(x="year", y="mileage", hue="engType", data=data).set_xticklabels(rotation=30);

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script',cursive;">We can make scatterplot more visually appealing by coloring each obervation based on another feature. In seaborn, this is referred to as using a “hue semantic”, because the color of the point gains meaning 💫</span>

# %%
data.head(5)

# %%
sns.relplot(x="year", y="mileage", hue="car", data=data).set_xticklabels(rotation=30);

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script', cursive;">⭐️ using style</span>
#
# To make it visually more understandable we can use a different marker style for each class.

# %%
sns.relplot(x="year", y="mileage", style="drive",hue="drive", data=data).set_xticklabels(rotation=30);

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script',cursive;">We can use four dimentions or features to draw scatter plot by using diffent features in 'hue' and 'style' 🖍<span>

# %%
sns.relplot(x="year", y="mileage",style="body", hue="body", data=data).set_xticklabels(rotation=30);

# %%
sns.relplot(x="mileage", y="price",style="drive",hue="engType",data=data).set_xticklabels(rotation=30)

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script', cursive;">⭐️ using size</span>

# %%
sns.relplot(x="year", y="price", size="drive",data=data).set_xticklabels(rotation=30);

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script',cursive;"> This kind of semantic variable changes the size of each point, the range of values in data units is normalized into a range in area units. This range can be customized: 🖌</span>

# %%
sns.relplot(x="year", y="price", size="drive",sizes=(15, 200),data=data).set_xticklabels(rotation=30);

# %% [markdown]
# # Emphasizing continuity with line plots

# %% [markdown]
# <div class="alert alert-block alert-info">📍 With some datasets, you may want to understand changes in one variable as a function of time, or a similarly continuous variable. In this situation, a good choice is to draw a line plot. In seaborn, this can be accomplished by the lineplot() function. There is one more method to do this.</div>

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script', cursive;"> ⭐️  kind="line" </span>

# %%
sns.relplot(x="year", y="price", kind="line", data=data).set_xticklabels(rotation=30);

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script',cursive;">Because lineplot() assumes that you are most often trying to draw y as a function of x, the default behavior is to sort the data by the x values before plotting. However, this can be disabled:</span>

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script', cursive;"> ⭐️  sort=False </span>

# %%
sns.relplot(x="year", y="price",sort=False ,kind="line", data=data).set_xticklabels(rotation=30);

# %%
data.head(5)

# %%
sns.relplot(x="year", y="mileage", kind="line", data=data).set_xticklabels(rotation=30);

# %% [markdown]
# # Aggregation and representing uncertainty

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script',cursive;"> More complex datasets will have multiple measurements for the same value of the x variable. The default behavior in seaborn is to aggregate the multiple measurements at each x value by plotting the mean and the 95% confidence interval around the mean:

# %%
sns.relplot(x="year", y="mileage", kind="line", data=data).set_xticklabels(rotation=30);

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script',cursive;">The confidence intervals are computed using bootstrapping, which can be time taking for larger datasets. So we can disable them setting ci=None

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script', cursive;"> ⭐️  ci=None </span>

# %%
sns.relplot(x="year", y="mileage",ci=None,kind="line", data=data).set_xticklabels(rotation=30);

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script',cursive;">Another good option, especially with larger data, is to represent the spread of the distribution at each timepoint by plotting the standard deviation instead of a confidence interval:

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script', cursive;"> ⭐️  ci="sd" </span>

# %%
sns.relplot(x="year", y="mileage",ci="sd",kind="line", data=data).set_xticklabels(rotation=30);

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script',cursive;">To turn off aggregation altogether, set the estimator parameter to None This might produce a strange effect when the data have multiple observations at each point.

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script', cursive;"> ⭐️  estimator=None </span>

# %%
sns.relplot(x="year", y="mileage",estimator=None,kind="line", data=data).set_xticklabels(rotation=30);

# %% [markdown]
# # Plotting subsets of data with semantic mappings

# %% [markdown]
# <div class="alert alert-block alert-info">📌 The lineplot() function has the same flexibility as scatterplot(): it can show up to three additional variables by modifying the hue, size, and style of the plot elements</div>

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script',cursive;"> Using semantics in lineplot() will also determine how the data get aggregated. For example, adding a hue semantic with two levels splits the plot into two lines and error bands, coloring each to indicate which subset of the data they correspond to:
#
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script', cursive;"> ⭐️  Using hue
#  ⭐️  kind="line" </span>

# %%
sns.relplot(x="year", y="mileage",hue="drive",kind="line", data=data).set_xticklabels(rotation=30);

# %%
sns.relplot(x="year", y="mileage",hue="drive",kind="line", data=data).set_xticklabels(rotation=30);

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script',cursive;"> Adding a style semantic to a line plot changes the pattern of dashes in the line by default:
#
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script', cursive;"> ⭐️  Using Style </span>

# %%
sns.relplot(x="year", y="mileage",hue="drive",style="body",kind="line", data=data).set_xticklabels(rotation=30);

# %% [markdown]
# But you can identify subsets by the markers used at each observation, either together with the dashes or instead of them:
#
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script', cursive;"> ⭐️  setting markers=True </span>

# %%
sns.relplot(x="year", y="mileage",hue="drive",style="body",markers=True,kind="line", data=data).set_xticklabels(rotation=30);

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script',cursive;"> But you can identify subsets by the markers used at each observation, either together with the dashes or instead of them:

# %%
sns.relplot(x="year", y="mileage",hue="drive",style="body",dashes=False,markers=True,kind="line", data=data).set_xticklabels(rotation=30);

# %% [markdown]
# # Showing multiple relationships with facets

# %% [markdown]
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script',cursive;"> The best approach may be to make more than one plot. Because relplot() is based on the FacetGrid, this is easy to do. To show the influence of an additional variable, instead of assigning it to one of the semantic roles in the plot, use it to “facet” the visualization. This means that you make multiple axes and plot subsets of the data on each of them: </span>
#
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script', cursive;"> ⭐️  Using col="feature_name" </span>

# %%
sns.relplot(x="year", y="price", hue="drive",
            col="body", data=data).set_xticklabels(rotation=30);

# %% [markdown]
# <span style="font-size:16px;color:gray;">You can also show the influence two variables this way: one by faceting on the columns and one by faceting on the rows. As you start adding more variables to the grid, you may want to decrease the figure size. Remember that the size FacetGrid is parameterized by the height and aspect ratio of each facet:
#
# <span style="font-size:18px;color:crimson;font-family: 'Dancing Script', cursive;"> ⭐️  Using col="feature_name"
# ⭐️  Using row="feature_name"
# ⭐️  Setting Height </span>

# %%
sns.relplot(x="year",y="mileage",hue="body",col="drive",row="engType",height=3,kind="line", estimator=None,data=data).set_xticklabels(rotation=30);

# %% [markdown]
# <span style="font-size:30px;color:gray;font-family: 'Indie Flower', cursive;">Thankyou for giving this a read✌️. 😊</span>
