# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

selected_country_1 = 'Kenya'
selected_country_2 = 'Kenya'

df1 = pd.read_csv('../input/covid19-global-dataset/worldometer_coronavirus_daily_data.csv',header = 0)
df1 = df1[df1['country']==selected_country_1]
          
df2 = pd.read_csv('../input/covid-world-vaccination-progress/country_vaccinations.csv',header = 0)
df2 = df2[df2['country']==selected_country_2]
          
df1.index = pd.to_datetime(df1['date'])
df2.index = pd.to_datetime(df2['date'])
#print(df1)
print(df1.columns)
print(df2.columns)
print(np.unique(df2['country']))

# %%
#Create a time serise
fig,ax = plt.subplots(figsize = (10,5))
ax.plot(df1.index,df1['daily_new_cases'],'y',label='daily_new_cases')
ax1 = ax.twinx()
ax1.plot(df2.index,df2['daily_vaccinations'],'r',label='daily_vaccinations')
ax.legend()
ax1.legend()
plt.show()

# %%
#Improved visualizaiton
from plotly.offline import iplot
import plotly.graph_objs as go

daily_new_cases = go.Scatter(x = df1.index, y = df1['daily_new_cases'], yaxis = 'y1',name= 'Daily confirm cases')
daily_vaccinations = go.Scatter(x = df2.index, y = df2['daily_vaccinations'], yaxis = 'y2',name= 'Daily vaccinations')

layout_obj = go.Layout(title = 'COVID vs. Vaccines', xaxis = dict(title='Date'),yaxis=dict(title='Daily cases'),yaxis2=dict(title='vaccination'))
fig = go.Figure(data=[daily_new_cases,daily_vaccinations],layout = layout_obj)
iplot(fig)
fig.write_html('outcome.html')

# %% [markdown]
# From the following table we can see that Apr.2nd, 2021 has the lagest daily cases, and this response to the 'Kenya Third Wave Response'.
#
# To address this problem, the Kenya government responded swiftly to increase measures that are aimed at taming rapid transmissions.  H.E President Kenyatta issued a public order restricting movement in or out of the declared disease infected zone consisting of 5 counties. In this Zone, comprising of the five counties that are contiguous, the daily curfew was tightened among other measures on public gatherings, bars and restaurant operations.

# %%
style_object = df1.style.background_gradient(cmap='jet').highlight_max('daily_new_cases').set_caption('Daily_cases')
display(style_object)

# %% [markdown]
# Kenya hasn't reach the top 50 of the total cases globaly. And the fully vaccinated people has no data.

# %%
#Ranking
df1 = pd.read_csv('../input/covid19-global-dataset/worldometer_coronavirus_daily_data.csv',header = 0)
df1 = df1.groupby('country').sum()['daily_new_cases'].sort_values(ascending = False)[0:50]
print(df1)
df2 = pd.read_csv('../input/covid-world-vaccination-progress/country_vaccinations.csv',header = 0)
df2 = df2.groupby('country').max()['people_fully_vaccinated_per_hundred'].sort_values(ascending = True)
print(df2)
print(df2.to_string())
