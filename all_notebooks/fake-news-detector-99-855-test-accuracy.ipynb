# %% [markdown]
# ### Here is my model (I ran it locally, which took 7+ hours that's why I'm posting a link to the GitHub repository, as I am unwilling to wait for another 7+ hours):
# [https://github.com/Julius-R-UI/Fake-News-Detector-Model/blob/main/Fake-News-Detector-Model.ipynb](http://)
