# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('/kaggle/input/pakistan-traffic-accident-dataset/traffic-accidents-annual-.csv')
df = df[1:]
df.columns = ["City", "Year", "Total number of accidents", "Fatal Accidents", "Non-Fatal Accidents", 
            "Killed", "Injured", "Total number of vehicles involved"]
df.head()

# %%
year = []
for y in df.Year:
    year.append(int(str(y)[0:4]))
df["Year"] = year 
df.head()

# %%
df["Total number of accidents"] = pd.to_numeric(df["Total number of accidents"])
df["Fatal Accidents"] = pd.to_numeric(df["Fatal Accidents"])
df["Non-Fatal Accidents"] = pd.to_numeric(df["Non-Fatal Accidents"])
df["Killed"] = pd.to_numeric(df["Killed"])
df["Injured"] = pd.to_numeric(df["Injured"])
df["Total number of vehicles involved"] = pd.to_numeric(df["Total number of vehicles involved"])
fatal_rate = df["Fatal Accidents"] / df["Total number of accidents"]
df["Fatal rate"] = fatal_rate

# %%
plt.figure(figsize=(10,5))
sns.countplot(data = df, x = "City")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(), annot=True, fmt="2.0%", cmap="coolwarm")
plt.show()

# %%
feature = "Total number of accidents"
plt.figure(figsize=(10,5))
for c in df.City.unique():
    sns.kdeplot(df[df["City"]==c][feature], label = c)
plt.legend()
plt.title(feature.upper())
plt.show()

# %%
feature = "Fatal Accidents"
plt.figure(figsize=(10,5))
for c in df.City.unique():
    sns.kdeplot(df[df["City"]==c][feature], label = c)
plt.legend()
plt.title(feature.upper())
plt.show()

# %%
feature = "Non-Fatal Accidents"
plt.figure(figsize=(10,5))
for c in df.City.unique():
    sns.kdeplot(df[df["City"]==c][feature], label = c)
plt.legend()
plt.title(feature.upper())
plt.show()

# %%
feature = "Killed"
plt.figure(figsize=(10,5))
for c in df.City.unique():
    sns.kdeplot(df[df["City"]==c][feature], label = c)
plt.legend()
plt.title(feature.upper())
plt.show()

# %%
feature = "Injured"
plt.figure(figsize=(10,5))
for c in df.City.unique():
    sns.kdeplot(df[df["City"]==c][feature], label = c)
plt.legend()
plt.title(feature.upper())
plt.show()

# %%
feature = "Total number of vehicles involved"
plt.figure(figsize=(10,5))
for c in df.City.unique():
    sns.kdeplot(df[df["City"]==c][feature], label = c)
plt.legend()
plt.title(feature.upper())
plt.show()

# %%
feature = "Fatal rate"
plt.figure(figsize=(10,5))
for c in df.City.unique():
    sns.kdeplot(df[df["City"]==c][feature], label = c)
plt.legend()
plt.title(feature.upper())
plt.show()

# %%
df.groupby("City")["Total number of accidents"].sum().reset_index().style.background_gradient("Reds")

# %%
df.groupby("City")["Total number of accidents"].sum().reset_index().style.background_gradient("Reds")

# %%
df.groupby("City")["Killed"].sum().reset_index().style.background_gradient("Reds")

# %%
df.groupby("City")["Killed"].sum().reset_index().style.background_gradient("Reds")

# %%
df.groupby("City")["Injured"].sum().reset_index().style.background_gradient("Reds")

# %%
df.groupby("Year")["Total number of accidents"].sum().reset_index().set_index("Year").style.background_gradient("Reds")

# %%
df.groupby("Year")["Total number of accidents"].sum().reset_index().set_index("Year").plot(figsize=(10, 5))
plt.show()

# %%
ax = df.groupby(["Year", "City"])["Total number of accidents"].sum().reset_index().set_index("Year")
plt.figure(figsize=(10,5))
sns.lineplot(data = ax, x="Year", y="Total number of accidents", hue="City")
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, fancybox=True, shadow=True)
plt.show()

# %%
df.groupby("City")["Fatal rate"].mean().reset_index().set_index("City").style.background_gradient("Reds")

# %%
df.groupby("City")["Fatal rate"].mean().reset_index().set_index("City").plot(figsize=(10, 5))
plt.show()

# %%
df.groupby("City")["Fatal rate"].mean().reset_index().max()

# %%
df.groupby("City")["Fatal rate"].mean().reset_index().min()
