# %%
import pandas as pd

# %%
titanic = pd.read_csv('../input/titanic/titanic_train.csv')

# %%
titanic

# %%
ages = titanic["Age"]

ages.head()

# %%
type(titanic["Age"])

# %%
titanic["Age"].shape

# %%
age_sex = titanic[["Age", "Sex"]]

age_sex.head()

# %%
type(titanic[["Age", "Sex"]])

# %%
titanic[["Age", "Sex"]].shape
