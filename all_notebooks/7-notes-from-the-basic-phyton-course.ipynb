# %% [markdown]
# # 7 notes from the basic Phyton course
#
# After taking an [awesome Phyton course on Kagle](https://www.kaggle.com/learn/python) i've notices that there are 7 notebooks created, one for each lesson.
# Here i'm cutting all to one Notebook, in really short, just as a reminder to......
#
# and ye ..Python was named for the British comedy troupe Monty Python :)

# %% [markdown]
# 1. Syntax, Variables, re/assignment and Numbers
# 2. Functions, docString
# 3. Booleans and Conditionals
# 4. Lists
# 5. Loops - for, while
# 6. Strings, dictionaries
# 7. working with External Libraries

# %% [markdown]
# # 1 - Syntax, Variables, and Numbers
#
# - variable re/assignment
# - meaningful spaces
# - operations
# - conditionals
# - comment
#
# [more on full lesson1: Hello,Phyton](https://www.kaggle.com/colinmorris/hello-python)

# %%
print("Tli la la", 2 + 4)
a = 2
b = 3
c = a + b
c
# available arithmetic operations + - * / // % ** -

# %%
#Swip array values

a = [1, 2, 3]
b = [3, 2, 1]

tmp = a
a = b
b = tmp

a, b = b, a   #tuples!

# %%
## Meaningfull spaces !!

# %%
spam_amount = 2
if spam_amount > 0:
    print("But I don't want ANY spam!")

viking_song = "Spam " * spam_amount
print(viking_song)

type(spam_amount)
type(19.95)

print(max(1, 2, 3))
print(abs(-32))
print(int('807') + 1)

# %% [markdown]
# # 2 - Functions and Getting Help
#
# - defining functions
# - docstring
# - help()
#
# [more on full lesson2: Functions and Getting Help](https://www.kaggle.com/colinmorris/functions-and-getting-help)

# %%
help(round)
help(round(-2.01))

# %%
def least_difference(a, b, c):
    """Return the smallest difference between any two numbers
    among a, b and c.
    
    >>> least_difference(1, 5, -5)
    4
    """
    diff1 = abs(a - b)
    diff2 = abs(b - c)
    diff3 = abs(a - c)
    return min(diff1, diff2, diff3)

help(least_difference)
print(least_difference(3,7,9))

# %%
print(1, 2, 3, sep=' < ')

# %% [markdown]
# # 3 - Booleans
#
# - booleans
# - comparison operations, [operator precedence ](https://docs.python.org/3/reference/expressions.html#operator-precedence)
# - conditionals
#
# [more on full lesson3: Booleans and Conditionals](https://www.kaggle.com/colinmorris/booleans-and-conditionals)

# %%
def is_odd(n):
    return (n % 2) == 1

print("Is 100 odd?", is_odd(100))
print("Is -1 odd?", is_odd(-1))

# %%
True or True and False

# %%
True + True + True + False

# %% [markdown]
# # 4 - Lists
# ​
# - lists
# - indexing
# - slicing
# - changing list
# - list function
# - list methods
# - search list
# - tuples
# ​
#
# [more on full lesson4: Lists](https://www.kaggle.com/colinmorris/lists)

# %%
primes = [2, 3, 5, 7]
planets = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']
hands = [
    ['J', 'Q', 'K'],
    ['2', '2', '2'],
    ['6', 'A', 'K'], # (Comma after the last element is optional)
]

# %%
# Indexing
planets[0]
planets[-2]

# %%
# Slicing
d = [1, 2, 3][1:]
print(d)

# %%
# List methods
planets.append('Pluto')
planets.pop()

# %%
#Searching lists
planets.index('Earth')

# Is Earth a planet?
"Earth" in planets

# %%
  [num > 3 for num in [1,2,3,4,5]]

# %% [markdown]
# # 5 - Loops and List Comprehensions
# ​
# - loops - for, while
# - list comprehensions
# ​
#
# [more on full lesson5: Loops and List Comprehensions](https://www.kaggle.com/colinmorris/loops-and-list-comprehensions)

# %%
multiplicands = (2, 2, 2, 3, 3, 5)
product = 1
for mult in multiplicands:
    product = product * mult
product

# %%
for i in range(5):
    print("Doing important work. i =", i)

# %%
i = 0
while i < 10:
    print(i, end=' ')
    i += 1

# %%
# List comprehensions
squares = [n**2 for n in range(10)]
squares

short_planets = [planet for planet in planets if len(planet) < 6]
short_planets

# str.upper() returns an all-caps version of a string
loud_short_planets = [planet.upper() + '!' for planet in planets if len(planet) < 6]
loud_short_planets

# %% [markdown]
# # 6 - Strings and Dictionaries
# ​
# - Strings
# - indexing
# - slicing
# - string methods
# - sictionaries
# ​
#
# [more on full lesson6: Strings and Dictionaries](https://www.kaggle.com/colinmorris/strings-and-dictionaries)

# %%
x = 'Pluto is a planet'
y = "Pluto is a planet"
x == y

# %%
hello = "hello\nworld"
print(hello)
print("hello", end='')
print("pluto", end='')

# %%
# Indexing
planet = 'Pluto'
planet[0]
# Slicing
planet[-3:]
# How long is this string?
len(planet)
# Yes, we can even loop over them
[char+'! ' for char in planet]

# %%
# String methods
claim = "Pluto is a planet!"
claim.upper()
claim
claim.lower()
claim
# Searching for the first index of a substring
claim.index('plan')
claim.startswith('Plu')

zip_code = '5546'
zip_code.isdigit()

# %%
words = claim.split()
words

# %%
numbers = {'one':1, 'two':2, 'three':3}
numbers['one']
numbers['one'] = 'Pluto'
for k in numbers:
    print("{} = {}".format(k, numbers[k]))

# %% [markdown]
# # 7 - Working with External Libraries
# ​
# - Imports
# - Submodules
# - Operator Overloading
# ​
#
# [more on full lesson7: Working with Libraries](https://www.kaggle.com/colinmorris/working-with-external-libraries)

# %%
import math
print(dir(math))

# %%
format(math.pi)
math.log(32, 2)

# %%
import math as mt
mt.pi

# %%
import numpy
# Roll 10 dice
rolls = numpy.random.randint(low=1, high=6, size=10)
rolls

# %% [markdown]
# # end
#
#
# That's all for now. Of course there is a lot to learn more...
#
#
# Here some liks:
#
# https://pyformat.info/
#
# https://docs.python.org/3/
