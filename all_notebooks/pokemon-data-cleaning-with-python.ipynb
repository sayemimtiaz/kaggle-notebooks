# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory


import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.

# %%
data = pd.read_csv('../input/pokemon.csv')
data.head() # datamızı ekledik ve bir de datamıza ufak bir göz atalım

# %%
data.tail() # ve sonra da son 5 sample mıza bakalım

# %%
data.columns # özniteliklerimizi inceleyelim ..

# %%
data.info() # özniteliklerimizi inceleyelim

# %%
data.shape # elimizdeki veri 800 satır ve 12 sütündan oluşuyor

# %%
print(data['Type 1'].value_counts(dropna=False))

# %%
 #explotary data analysis 
 data.describe()
#bize Q3 - Q1 -IQR ( ÇEYREK DEĞERLERİ) hesaplıyor

# %%
# visual explotary data analysis 
data.boxplot(column ='Attack' , by = 'Legendary')
plt.show()

# %%
data_new = data.head()
data_new

# %%
melted = pd.melt(frame=data_new , id_vars = 'Name' , value_vars=['Attack','Defense'])
melted

# %%
# PİVOTING DATA
melted.pivot(index = 'Name' , columns='variable',values ='value')

# %%
#CONCATENATING DATA
data1 = data.head()
data2 = data.tail()
conc_data_row = pd.concat([data1,data2],axis = 0 , ignore_index=True)
conc_data_row

# %%
data.dtypes

# %%
# typlerı değiştirme 
data['Type 1']=data['Type 1'].astype('category')
data['Speed'] =data['Speed'].astype('float')
data.dtypes

# %%
data.info()

# %%
data['Type 2'].value_counts(dropna=False)

# %%
#MİSSİN DATA AND TESTİNG
#daha önce tanımlanmamış değersiz verilerdir
#örnek bir pokemonun type 1 var ama type 2 si NaN ise gerçekten type 2 yok mu yoksa NaN mı ? 
data.info()
#çözümler yoksa yok ta olabilir
#yada dropna fonksiyonu kulllanarak datasetten çıkarabiliriz
#boş sa da NaN ile doldurabiliriz
#sayısal bir veri olsaydı diğer örneklerin ortalaması medyan... ile doldurabiliriz
#yaptığınız işlemin doğru olup olmadığının testi

# %%
data["Type 2"].value_counts(dropna=False)
#386 tane NaN değeri var

# %%
data1 = data  
data1["Type 2"].dropna(inplace =True)
#data1 den type 2 sinden NaN olanları at 
#inplace = True ise çıkardığın verileri data1 e kaydet
#yaptığınız şey işe yaradımı peki?

# %%
assert 1==1

# %%
assert data["Type 2"].notnull().all()  #sonuç yok çünkü hiçbirinde null değeri yok işlem başarılı

# %%
data["Type 2"].fillna('empty',inplace =True)

# %%
data.head(10)
