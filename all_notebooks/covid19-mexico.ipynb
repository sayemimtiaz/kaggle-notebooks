# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import plotly.offline as py
import plotly.express as px

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#https://www.kaggle.com/kshitijmohan/wine-recommendation-system-based-on-bert/comments

HAPPY_COLORS_PALETTE = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#ADFF02", "#8F00FF"]

sns.set_palette(sns.color_palette(HAPPY_COLORS_PALETTE))

# %%
df = pd.read_csv('../input/covid19-mexico-clean-order-by-states/Covid_19_Mexico_Clean_Complete.csv', encoding='ISO-8859-2')
df.head()

# %%
df.tail(10)

# %%
# For this project we are taking top 7 variety only
mask = df['Confirmed'].isin(['1', '2', '7', '15', '14', '22', '11', '9', '3'])
df1 = df[mask]
df1.head()

# %%
chart = sns.countplot(df1.Confirmed, palette=HAPPY_COLORS_PALETTE)
plt.title("Number of descriptions per Confirmed Cases")
chart.set_xticklabels(chart.get_xticklabels(), rotation=30, horizontalalignment='right');

# %%
# Splitting the dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df1.Date, df1.Confirmed, test_size = 0.2, random_state = 42)

# %%
train = { 'text': X_train, 'Deaths': y_train }
train_df = pd.DataFrame(train)
test = { 'text': X_test, 'Deaths': y_test }
test_df = pd.DataFrame(test)

# %%
train_df.head()

# %%
chart = sns.countplot(train_df.Deaths, palette=HAPPY_COLORS_PALETTE)
plt.title("Deaths Cases")
chart.set_xticklabels(chart.get_xticklabels(), rotation=30, horizontalalignment='right');

# %%
def plot_count(feature, title, df, size=1):
    f, ax = plt.subplots(1,1, figsize=(4*size,4))
    total = float(len(df))
    g = sns.countplot(df[feature], order = df[feature].value_counts().index[:20], palette='Set3')
    g.set_title("Number and percentage of {}".format(title))
    if(size > 2):
        plt.xticks(rotation=90, size=8)
    for p in ax.patches:
        height = p.get_height()
        ax.text(p.get_x()+p.get_width()/2.,
                height + 3,
                '{:1.2f}%'.format(100*height/total),
                ha="center") 
    plt.show()

# %%
plot_count("Confirmed", "Confirmed", df,4)

# %%
plot_count("Deaths", "Deaths", df,4)

# %%
plot_count("Active", "Active", df,4)

# %%
import plotly.express as px
fig = px.line(df, x="Date", y="Confirmed", color_discrete_sequence=['darksalmon'], 
              title="Mexico Covid19 Confirmed Cases ")
fig.show()

# %%
fig = px.scatter(df, x="Date", y="Deaths",color_discrete_sequence=['crimson'], title="Mexico Deaths by Covid19" )
fig.show()

# %%
fig = px.line(df, x="Date", y="Confirmed", color_discrete_sequence=['darksalmon'], template='plotly_dark',
              title="Mexico Covid-19 Confirmed Cases")
fig.show()

# %%
fig = px.scatter(df, x="Date", y="Active",color_discrete_sequence=['#4257f5'],template='plotly_dark', title="Mexico Covid19 Active Cases" )
fig.show()

# %%
#word cloud
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in df.State)
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200,colormap='Set3', background_color="black").generate(text)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='Bilinear')
plt.axis("off")
plt.figure(1,figsize=(12, 12))
plt.show()

# %% [markdown]
# Das War's Kaggle Notebook Runner: Marília Prata  @mpwolke
