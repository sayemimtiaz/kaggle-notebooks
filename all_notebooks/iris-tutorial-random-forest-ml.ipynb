# %% [markdown]
# **Importing Dataset and Libraries**

# %%
import numpy as np 
import pandas as pd 
dataset = pd.read_csv("../input/Iris.csv")

# %% [markdown]
# **Exploratory Data Analysis**

# %%
dataset.head()

# %%
dataset.info()

# %%
dataset.describe()

# %% [markdown]
# **Saggregating Independent and Dependent Variables**

# %%
X = dataset.iloc[:,1:5].values
y = dataset.iloc[:, 5].values

# %% [markdown]
# **Handling Categorical Data**

# %%
# Encoding categorical data
# Encoding the Independent Variable
from sklearn.preprocessing import LabelEncoder
labelencoder_y = LabelEncoder()
y = labelencoder_y.fit_transform(y)

# %%
y

# %% [markdown]
# **Preparing Data For ML**

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)

# %% [markdown]
# **Applying Random Forest**

# %%
# Fitting Random Forest Classification to the Training set
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 50, criterion = 'entropy')
classifier.fit(X_train, y_train)

# %% [markdown]
# **Predictions**

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %% [markdown]
# **Evaluating Result**

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
cm

# %% [markdown]
# **Results are great and now we'll Visualize Data for Correlation and Test Results**

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# **Firstly Visualizing Datasets Features**

# %%
sns.pairplot(data=dataset.drop(['Id'],axis=1),hue='Species')

# %%
sns.heatmap(dataset.drop(['Id'],axis=1).corr())

# %% [markdown]
# **Finally Visualizing Results with Original Values**

# %%
sns.kdeplot(data=y_test,data2=y_pred,shade=True,bw='scott', cbar=True, cmap='Reds')

# %% [markdown]
# **Cheers..!**
