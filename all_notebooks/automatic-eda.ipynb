# %% [markdown]
# **Automatic EDA tools like AUTOVIZ, DTALE, SWEETVIZ and PANDAS-PROFILING are discussed in this kernel**

# %% [markdown]
# ## Autoviz

# %%
# !pip install autoviz
# !pip install xlrd
import pandas as pd
from autoviz.AutoViz_Class import AutoViz_Class
autoviz = AutoViz_Class().AutoViz('../input/tips-data/tips_data.csv')

# %% [markdown]
# ## DTale

# %%
# !pip install dtale
import os
import dtale
import pandas as pd

dtale.show(pd.read_csv("../input/tips-data/tips_data.csv"))

# %% [markdown]
# ## Pandas profiling
# (Try it on local machine)

# %%
#Install the below libaries before importing
import pandas as pd
import os
from pandas_profiling import ProfileReport

path = "C://Users//venug//Downloads//ML1//PYTHON_UTILITIES"
dir_list = os.listdir(path)		
csvfiles =[]
for x in os.listdir(path):
    if x.endswith(".csv"):
        print(x)
        csvfiles.append(x)

for csv in csvfiles:
	#EDA using pandas-profiling
	profile = ProfileReport(pd.read_csv('titanic.csv'), explorative=True)

	#Saving results to a HTML file
	profile.to_file(csv+'_pandas_profiling.html')

# %% [markdown]
# ## Sweetviz

# %%
import pandas as  pd
import os
import sweetviz as sv
  
# Get the list of all files and directories
#path = "C://Users//Vanshi//Desktop//gfg"
path = "C://Users//venug//Downloads//ML1//PYTHON_UTILITIES"
dir_list = os.listdir(path)		
csvfiles =[]
for x in os.listdir(path):
    if x.endswith(".csv"):
        print(x)
        csvfiles.append(x)

print(csvfiles)

for csv in csvfiles:
	data = pd.read_csv(csv)
	report = sv.analyze(data)
	report.show_html(csv+'.html')
