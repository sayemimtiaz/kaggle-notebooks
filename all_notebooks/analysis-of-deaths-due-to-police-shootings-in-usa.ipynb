# %% [markdown]
# Importing the required libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading the dataset.

# %%
df = pd.read_csv("../input/data-police-shootings/fatal-police-shootings-data.csv")

# %% [markdown]
# Lets take a look at this dataset.

# %%
df.head()

# %% [markdown]
# The race of the victim is given in abbreviations, but it would be easier to understand if the expansions were used instead.

# %%
df.replace(to_replace = ['W'], value = ['White and Non-Hispanic'], inplace = True)
df.replace(to_replace = ['B'], value = ['Black and Non-Hispanic'], inplace = True)
df.replace(to_replace = ['H'], value = ['Hispanic'], inplace = True)
df.replace(to_replace = ['N'], value = ['Native American'], inplace = True)
df.replace(to_replace = ['O'], value = ['Other'], inplace = True)
df.replace(to_replace = ['A'], value = ['Asian'], inplace = True)

# %% [markdown]
# We now convert the date to a date time object and create two new columns for year and month.

# %%
df['date']=pd.to_datetime(df['date'])
df['year']=pd.to_datetime(df['date']).dt.year
df['month']=pd.to_datetime(df['date']).dt.month

# %%
df.head()

# %% [markdown]
# Lets take a look at the counts for certain categories in the data.

# %%
df['armed'].value_counts()

# %% [markdown]
# This shows that 3060 victims were armed with a gun and 353 victims were unarmed.

# %%
df['threat_level'].value_counts()

# %% [markdown]
# Shows the number of victims with different threat levels.

# %%
df['flee'].value_counts()

# %% [markdown]
# Shows the number of victims that were fleeing and throught what means. The study says that a huge majority of the victims were not fleeing.

# %%
df['signs_of_mental_illness'].value_counts()

# %% [markdown]
# Shows the number of victims who appeared to show signs of mental illness. This appears to be roughly 20% of the people that were shot.

# %%
df["age"].plot.hist()

# %% [markdown]
# This shows the distribution of the ages of the victims. The highest number of cases appears to be for the 20-40 years age group.

# %%
sns.countplot(x = "manner_of_death", data = df)

# %% [markdown]
# This shows how many people were shot and how many were both shot and tasered.

# %%
sns.set(rc={'figure.figsize':(15,5)})
sns.countplot(x = "race", data = df)

# %% [markdown]
# This shows the racial distribution of the victims. Around half of the total number of victims appear to be of white race.

# %%
sns.countplot(x = "state", data = df)

# %% [markdown]
# This shows the state distribution of the shootings. California appears to be the state with by far the most cases.
# Texas and Florida also have high number of cases.

# %%
sns.countplot(x = "signs_of_mental_illness", data = df)

# %% [markdown]
# This shows around 20% of the victims appeared to show signs of mental illness.

# %%
sns.countplot(x = "flee", data = df)

# %% [markdown]
# A majority of the victims were not fleeing from the police.

# %%
sns.countplot(x = "body_camera", data = df)

# %% [markdown]
# A huge majority of the police on scene did not have a body cam.

# %%
sns.countplot(x = "year", data = df)

# %% [markdown]
# This shows the distribution of the data by years from 2015 to 2020 june.
# The number of cases appears to be almost 1000 ever year.

# %%
sns.countplot(x = "race", hue = "flee",data = df, palette = 'Set2')

# %% [markdown]
# This again shows that most of the victims were not fleeing and that fact remains consistant with respect to the race.

# %%
sns.countplot(x = "race", hue = "body_camera",data = df, palette = 'Set2')

# %% [markdown]
# This again shows that most of the shooting officers did not have a body cam and that fact remains consistant with respect to the race of the victim.

# %%
sns.countplot(x = "state", hue = "flee",data = df, palette = 'Set2')
