# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
# !ls -l ../input/mining-core-sampling-dataset

# %%
pd.read_csv('../input/mining-core-sampling-dataset/train.csv')

# %%
pd.read_csv('../input/mining-core-sampling-dataset/test.csv')
