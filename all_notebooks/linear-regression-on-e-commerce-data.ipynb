# %% [markdown]
# # E-Commerce customers usage

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df=pd.read_csv('/kaggle/input/focusing-on-mobile-app-or-website/Ecommerce Customers')

# %% [markdown]
# # Uploading Data

# %%
df.head()

# %% [markdown]
# # Finding any missing values in the data

# %%
df.isna().sum()

# %% [markdown]
# # Data Exploration

# %%
sns.jointplot(x='Time on App',y='Yearly Amount Spent',data=df)

# %%
sns.jointplot(x='Avg. Session Length',y='Yearly Amount Spent',data=df)

# %%
sns.pairplot(df)

# %% [markdown]
# # Assigning x and y values for linear regression

# %%
df.columns

# %%
X=df[ ['Avg. Session Length', 'Time on App','Time on Website', 'Length of Membership']]
y=df['Yearly Amount Spent']

# %% [markdown]
# # Applying training data for the algorithem

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)

# %% [markdown]
# # Coefficient value for the model

# %%
print(lr.coef_)

# %%
predit=lr.predict(X_test)

# %% [markdown]
# # Test result

# %%
plt.scatter(predit,y_test)
plt.xlabel('Predited value')
plt.ylabel('Amount spent')

# %%
sns.distplot(y_test-predit)

# %% [markdown]
# # Total Coefficient for to increase the sales

# %%
pd.DataFrame(lr.coef_, X.columns, columns = ['Coefficient'])

# %% [markdown]
# # Intercept value

# %%
print(lr.intercept_)

# %% [markdown]
# # Finding for any error in the model

# %%
from sklearn.metrics import r2_score
print('R Square',r2_score(y_test,predit)*100,'%')

# %%
from sklearn import metrics
print ("Mean absolute error",metrics.mean_absolute_error(y_test, predit))
print ('Mean squared error',metrics.mean_squared_error(y_test, predit))
print ('Root Mean squared error',np.sqrt (metrics.mean_squared_error(y_test, predit)))
