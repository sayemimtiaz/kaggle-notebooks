# %% [markdown]
# # **Import Libraries**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy

# %% [markdown]
# # **First look at data**

# %%
df = pd.read_csv('../input/average-rainfall-and-temperature-in-uk20102019/avg_rainfalltemp in UK - Sheet1.csv')

# %%
df

# %%
df.shape

# %%
df.nunique()

# %%
df.describe()

# %% [markdown]
# # **Removing any outliers and missing data**

# %%
df.isnull().sum()

# %% [markdown]
# No missing data.

# %% [markdown]
# Remove outliers using interquartile range.

# %%
Q1 = df[['Avg rainfall(in mm)', 'Avg temp(in centigrade)']].quantile(0.25)
Q3 = df[['Avg rainfall(in mm)', 'Avg temp(in centigrade)']].quantile(0.75)
IQR = Q3 - Q1
print(IQR)

# %%
df = df[~((df[['Avg rainfall(in mm)', 'Avg temp(in centigrade)']] < (Q1 - 1.5 * IQR)) |(df[['Avg rainfall(in mm)', 'Avg temp(in centigrade)']] > (Q3 + 1.5 * IQR))).any(axis=1)]
df.shape

# %%
df.describe()

# %% [markdown]
# # **Data Visualizations**

# %%
plt.figure(figsize=(20,10))
c= df.corr()
sns.heatmap(c,cmap='Blues',annot=True)
c

# %% [markdown]
# Not much coorelation in the dataset.

# %%
sns.histplot(df['Avg temp(in centigrade)'])

# %% [markdown]
# Not much of a skew.

# %%
sns.histplot(df['Avg rainfall(in mm)'])

# %% [markdown]
# Right skew here.

# %%
sns.pairplot(df)

# %% [markdown]
# As expected, we don't see any trends in the scatterplots.

# %%
sns.relplot(x=df['Avg temp(in centigrade)'], y=df['Period'], hue='Type of period', data=df)

# %%
sns.relplot(x=df['Avg rainfall(in mm)'], y=df['Period'], hue='Type of period', data=df)

# %% [markdown]
# Spring has less avg rainfall than other seasons.

# %%
sns.boxplot(x=df['Avg temp(in centigrade)'], data=df)

# %%
sns.boxplot(x=df['Avg rainfall(in mm)'], data=df)
