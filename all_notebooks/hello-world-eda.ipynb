# %% [markdown]
# # Simple EDA for [Hello World In Programming Languages](https://www.kaggle.com/ihelon/hello-world-in-programming-languages) dataset
#
#
# ![](https://i.imgur.com/2uCQiXd.png)

# %% [markdown]
# ###### Please Upvote [this](https://www.kaggle.com/ihelon/hello-world-in-programming-languages) dataset 😀

# %% [markdown]
# <a id="top"></a>
#
# <div class="list-group" id="list-tab" role="tablist">
# <h3 class="list-group-item list-group-item-action active" data-toggle="list" style='background:darkred; border:0' role="tab" aria-controls="home"><center>Quick Navigation</center></h3>
#
# * [1. Overview](#1)
# * [2. Python3 program](#2)
# * [3. Emojicode program](#3)
# * [4. C++ program](#4)
# * [5. Longest and shortest programs](#5)

# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
BASE_DIR = '../input/hello-world-in-programming-languages/'

# %% [markdown]
# <a id="1"></a>
# <h2 style='background:darkred; border:0; color:white'><center>Overview<center><h2>

# %%
df = pd.read_csv(os.path.join(BASE_DIR, 'index.csv'), index_col=0)
print(f'Shape of the dataset: {df.shape}')

# %%
print('Example of some languages:')
df.sample(10)

# %%
print('Number of NULL values:')
df.isna().sum()

# %% [markdown]
# <a id="2"></a>
# <h2 style='background:darkred; border:0; color:white'><center>Python3 program<center><h2>

# %%
df[df['language_name'] == 'Python3']

# %%
program = df[df['language_name'] == 'Python3']['program'].values[0]
print(program)

# %% [markdown]
# <a id="3"></a>
# <h2 style='background:darkred; border:0; color:white'><center>Emojicode program<center><h2>

# %%
df[df['language_name'] == 'Emojicode']

# %%
program = df[df['language_name'] == 'Emojicode']['program'].values[0]
print(program)

# %% [markdown]
# <a id="4"></a>
# <h2 style='background:darkred; border:0; color:white'><center>C++ program<center><h2>

# %%
df[df['language_name'] == 'C++']

# %%
program = df[df['language_name'] == 'C++']['program'].values[0]
print(program)

# %% [markdown]
# <a id="5"></a>
# <h2 style='background:darkred; border:0; color:white'><center>Longest and shortest programs<center><h2>

# %%
max_len = df['program'].str.len().max()
max_ind = df['program'].str.len().argmax()
min_len = df['program'].str.len().min()
min_ind = df['program'].str.len().argmin()

# %%
print('One of the languages with the smallest program length:')
df.iloc[min_ind]

# %%
print('One of the languages with the longest program length:')
df.iloc[max_ind]
