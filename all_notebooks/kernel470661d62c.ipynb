# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
import pandas as pd
import geopandas as gpd
import geoplot
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")

# %% [markdown]
# ## Cargando y dando un vistazo a los datos
# ### Se trata de un dataset que contiene aproximadamente 1400 datos sobre un listado  obtenido de "Dream Market's "cocaine" category. un sitio de la dark net

# %%
perico = "../input/cocaine-listings/dream_market_cocaine_listings.csv"

coca_data = pd.read_csv(perico)

coca_data.head()

# %% [markdown]
# ### Dataset info
#
# En realidad no es un dataset muy grande pero podemos observar que tiene varias columnas que pueden ser utiles al momento de analizar los datos. O si nos ponemos en el caso de los compradores podriamos darnos una idea de como tomar una buena decision en estos sitios.

# %%
list(coca_data.columns.values)

# %% [markdown]
# ### Algo que me llamo la atencion es la forma en la que escriben los anuncios.
#
# !!!!!INTRO OFFER!!!!! 1GR COCAINE 90%
#
# no se por que, siento como si el producto que tienen para vender es de lo peor y estan desesperados por venderselo al mas wey. Algo asi como los que venden
# herbalife o esas cosas
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTNp6WqJtYGf12_Z2BE4ODb5AzynkqtJL2_8Zf8fFUL_gB09PSW)
#
# aunque hay datos que pueden ser importantes al momento de realizar una compra online, no puedo dejar de pensar en eso.
#
# entonces lo primero que me da curiosidad analizar son los vendedores.

# %%
#estos son todos los vendedores que estan en el dataset
coca_data.vendor_name.unique()

# %% [markdown]
# ### Pues ya viendo los nombres no estaba esperando algo muy formal como nombre y apellido
# pero cuando le cuentes a alguien que estas muy indignado por que gastaste un dineral en coca, estaba bien mala y se la compraste a un wey de la dark net que se llamaba "pablopablito" o "Speedy-Gonzales", en ese momento uno mismo agarra el rollo.
#
# Entonces  quisiera yo saber que tanto spam hace cada vendedor, para mi eso es una muestra lo desesperados que estan por vender y en mi mente existe una relacion que dice que entre mas spam haga una persona sobre un producto, menor es la calidad  del producto que vende.

# %%
#esta es una muestra de las veces que aparece cada vendedor en las publicaciones 
#en total son 180 vendedores y el que mas se anuncia sale 25 veces
vendedores = coca_data.pivot_table(index=['vendor_name'], aggfunc='size')
v=vendedores.sort_values(ascending=True)

# %%
vendedores.values
a=vendedores.sort_values(ascending=True)
a

# %% [markdown]
# En esta grafica podemos observar los vendedores que mas se anuncian y las veces que se anuncian.

# %%
# grafica de las veces que aparece cada vendedor en las publicaciones  

v.plot(figsize=(35,15))

# %% [markdown]
# en esa grafica solo se observan los datos en general y pues no se ve muy chilo pero da una idea del rango de las publicaciones

# %%
plt.figure(figsize=(30,10))
plt.xticks(rotation='vertical')
plt.margins(0.5)
sns.barplot (x=v.index, y=a )

# %% [markdown]
# Como decia sobre los vendedores, aquellos con el mayor numero de publicaciones en una pagina son los que venden lo peor
# y gracias a que el dataset contiene informacion sobre la calidad (pureza) del producto que venden podriamos aclarar toda esa iquietud que tengo.
#
# * graficare tambien a el vendedor con la calidad del producto que vende
# ![](http://)

# %%
plt.figure(figsize=(35,10))
plt.xticks(rotation='vertical')
plt.margins(0.4)
sns.barplot (x=coca_data['vendor_name'], y=coca_data['quality'] )

# %%
coca_data[['quality']].mean()

# %% [markdown]
# ![](https://mamby.com/images/screenshot-text-human%20face-poster-57110_maxres.jpg)

# %% [markdown]
# ##  parece que me salio el tiro por la culata
#
# la grafica muestra que en general los vendedores (incluyendo a aquellos que casi no se anuncian ) manejan una buena calidad del producto
# asi que lo que yo pensaba esta mal.
#
# pues no del todo, segun una publicacion de vice news : **"What 100 Percent Pure Cocaine Actually Does to You" ****
# https://www.vice.com/en_us/article/zmbkay/what-100-percent-pure-cocaine-actually-does-to-you)
#
# en la que hablan sobre  los riesgos de la pureza de la cocaína
#
# existe algo de lo que yo comentaba sobre la calidad, es bastante dificil encontrar cocaina que sea muy pura, cerca del 100% es casi imposible, solo en los laboratorios que se encuentran en la selva peruana, al mismo tiempo hablan sobre la que se consigue normalmente de dealers callejeros tipo *"trust me—this shit bangs" * que en méxico seria *" nombre compa esta madre pega bien masizo pariente"*  que en realidad es la que vienen comprando y solo tiene un 10% maximo 40%.
#
# * Otro aspecto importante sobre la calidad
#
# segun la publicacion muchos de los vendedores (vendedores de bajo nivel )no saben la calidad de la cocaina que venden, por lo que puedes obtener un producto
# de pesima calidad por un alto precio o un producto de buena calidad por un precio bajo.

# %% [markdown]
# ### Dejando a un lado el tema sobre el spam
#
# se puede comprar basados en otro feature de nuestro dataset, podemos comprar basados en el rating como en amazon o en cualquier sitio de compras online, me imagino que es lo que la gente ve primero cuando quiere hacer una compra.

# %%
plt.figure(figsize=(35,10))
plt.xticks(rotation='vertical')
plt.margins(0.4)
sns.barplot (x=coca_data['vendor_name'], y=coca_data['rating'] )

# %%
coca_data[['rating']].mean()

# %% [markdown]
# ## La mayoria de los vendedores tienen buena calificacion
#
# eso no quiere decir que vendan algo bueno, solo que cumplen con las entregas y por eso no son penalizados
#
# ### una forma de ver la calidad de un vendedor con respecto a los demas es graficarlo contra todos
#
# este tipo de grafica es util en este caso por que puedes observarlo como un diagrama de caja (pero menos aburrido), se pueden ver los valores atipicos, donde se concentra
# la mayoria de los datos y con la particularidad de que puedes monitorear a un vendedor en especifico, como es el caso de "thebestchemist" que fue uno
# de los que mas se anuncia y con calidad decente, de hecho en la grafica podemos ver que anda manejando una pureza entre 90 y 100  y para rematar el nombresillo lo dice todo, "el mejor quimico"

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x=coca_data['quality'], y=coca_data['cost_per_gram'],hue =coca_data['vendor_name']=="thebestchemist") # Your code here

# %% [markdown]
# la verdad no se hasta donde tenia que llegar con esta tarea segun yo era un resumen o algo asi.
