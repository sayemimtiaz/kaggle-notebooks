# %% [markdown]
# Setup aus führen:

# %%
# Datenbank laden
import pandas as pd

# Pfad der benutzten Daten
iowa_file_path = '../input/home-data-for-ml-course/train.csv'

home_data = pd.read_csv(iowa_file_path)

# Set up code checking
from learntools.core import binder
binder.bind(globals())
from learntools.machine_learning.ex3 import *

print("Setup Complete")

# %% [markdown]
# # Übung
#
# ## Schritt 1: Vorhersageziel festlegen
# Speichern sie die Verkaufspreis in der Variable y.
#
# Hinweis: Um das passende Attribut zu finden, müssen sie das Schema der Tabelle ausgeben!

# %%
# Schema ausgeben umd das Vorhersageziel festzulegen

# %%
y = ____

# Check your answer
step_1.check()

# %%
# The lines below will show you a hint or the solution.
# step_1.hint() 
# step_1.solution()

# %% [markdown]
# ## Schritt 2: X festlegen
# Es sollen die Eigenschaften der Vorhersage in `X`  gespeichert werden.
#
# Folgende Eigenschaften sollen benutzt werden:
#     * LotArea
#     * YearBuilt
#     * 1stFlrSF
#     * 2ndFlrSF
#     * FullBath
#     * BedroomAbvGr
#     * TotRmsAbvGrd

# %%
# Aufzählung der Eigenschaften
feature_names = ___

# Daten auswählen, welche die Eigenschaften enthalten
X = ____

# Check your answer
step_2.check()

# %%
# step_2.hint()
# step_2.solution()

# %% [markdown]
# ## Daten begutachten
# Bevor das Modell erstellt wird, stelle den Inhalt von **X** kurz dar und entscheide ob diese entscheidend für die Kaufpreis sind.

# %%
# Daten begutachten
# print description or statistics from X
#print(_)

# print the top few lines
#print(_)

# %% [markdown]
# ## Schritt 3: Modell auswählen und anpassen
# * Erstelle ein `DecisionTreeRegressor` und speicher ihn in iowa_model.
# * Passe das Modell mit den Daten aus `X` und  `y` an.

# %%
# from _ import _
# Modell festlegen
# Zur Reproduzierbarkeit soll noch ein random_state  gesetzt werden
iowa_model = ____

# Anpassen
____

# Check your answer
step_3.check()

# %%
# step_3.hint()
# step_3.solution()

# %% [markdown]
# ## Schritt 4: Vorhersage
# Benutze die `predict` Methode für `X` und speichere das Ergebnis in `predictions`.

# %%
predictions = ____
print(predictions)

# Check your answer
step_4.check()

# %%
# step_4.hint()
# step_4.solution()

# %% [markdown]
# ## Evaluation
#
# Benutzte die `head` Methode umd die Preise mit den Originalpreisen zu vergleichen. Gibt es Auffälligkeiten?

# %%
# Code kommt hier rein

# %% [markdown]
# # Fortsetzung
#
# Weiter mit **[Modell Bewertung](https://www.kaggle.com/infvogel/6-modellbewertung/).**

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [Learn Discussion forum](https://www.kaggle.com/learn-forum/161285) to chat with other Learners.*
