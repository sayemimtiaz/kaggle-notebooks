# %% [markdown]
# **Name: Yap Tee Ying
# Student ID: 18B00168**
#
#
# In this assignment, I have selected the country Chile to analyze their COVID-19 cases and vaccination progress. It is expected that an increase in vaccination will lead to a drop in daily new cases.
# However, from the analysis, we can see that this is not the case for Chile.
#
#
# The global ranking of Chile for the highest total number of cases is 23rd out of 220 countries.
# On the other hand, the global ranking for the highest total vaccinations per number of people is 9th out of 211 countries.
#
#
# I asked my part-time co-worker from Chile about his country's situation.
# According to him, a lot of Chilean people did not treat the pandemic seriously. They went to clandestine parties even when it's prohibited. These parties became sources of outbreak.
# Just as the restrictions were loosened by the government, people started to travel across provinces and flocking to shopping malls. Traffic jams resumed. The malls were packed and people were not social distancing.
#
# Chile serves as a warning for other countries to not rush on easing restrictions even when most of the population is vaccinated.
#
#
# **Source:**
#
#
# > My friend, Juan Pablo Parra
#
#
# > Taylor, L.. (2021, May 5). Reckless Rush to Reopen Threatens Chile’s Exemplary Vaccination Strategy. *Scientific American*. https://www.scientificamerican.com/article/reckless-rush-to-reopen-threatens-chiles-exemplary-vaccination-strategy/

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

selected_country = "Chile"

df1 = pd.read_csv("../input/covid19-global-dataset/worldometer_coronavirus_daily_data.csv", header=0)
df1 = df1[df1['country']==selected_country]
df2 = pd.read_csv("../input/covid-world-vaccination-progress/country_vaccinations.csv", header=0)
df2 = df2[df2['country']==selected_country]

df1.index = pd.to_datetime(df1['date'])
df2.index = pd.to_datetime(df2['date'])

print(df1)

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(df1.index, df1['daily_new_cases'])
ax1 = ax.twinx()
ax1.plot(df2.index, df2['daily_vaccinations'], 'r')
plt.show()

# %% [markdown]
# # Improved visualization

# %%
from plotly.offline import iplot
import plotly.graph_objs as go

daily_new_cases = go.Scatter(x=df1.index, y=df1['daily_new_cases'],yaxis='y1',name='Daily confirmed cases')
daily_vaccinations = go.Scatter(x=df2.index, y=df2['daily_vaccinations'],yaxis='y2',name='Daily vaccinations')

layout_obj = go.Layout(title='COVID vs Vaccines', xaxis=dict(title='Date'), yaxis=dict(title='Daily cases'), yaxis2=dict(title='Vaccinations', side='right', overlaying='y'))
fig = go.Figure(data=[daily_new_cases, daily_vaccinations], layout=layout_obj)
iplot(fig)
fig.write_html('outcome.html')

# %% [markdown]
# # Colored table

# %%
style_object = df1.style.background_gradient(cmap='jet').highlight_max('daily_new_cases').set_caption('Daily cases')
# display(style_object)

# %%
df1 = pd.read_csv("../input/covid19-global-dataset/worldometer_coronavirus_daily_data.csv", header=0)
df1 = df1.groupby('country').sum()['daily_new_cases'].sort_values(ascending=False)
print(df1.to_string())
print(len(df1))
print()
df2 = pd.read_csv("../input/covid-world-vaccination-progress/country_vaccinations.csv", header=0)
df2 = df2.groupby('country').max()['people_fully_vaccinated_per_hundred'].sort_values(ascending=False)
print(df2.to_string())
print(len(df2))

# %% [markdown]
# ## Bonus
#
# Chilean meme provided by my friend.
#
# (Top: Actual situation in Chilean shopping mall)
# ![](https://64.media.tumblr.com/56b6a240e912ed178f5718fef4e7c04c/tumblr_qf86nbLi0E1xzrtw4o1_1280.jpg)
