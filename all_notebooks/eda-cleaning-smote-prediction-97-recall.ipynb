# %% [markdown]
# # **CHURN ANALYSIS EDA & PREDICTION & FRIENDLY EXPLANATIONS**
#
# ![chrn](https://cdn.coil.com/cdn-cgi/image/format=auto,fit=scale-down,w=1920/images/iZjzZF7ZTWOX87Fx_Uv9qw.png)

# %% [markdown]
# Now, this dataset consists of 10,000 customers mentioning their age, salary, marital_status, credit card limit, credit card category, etc. There are nearly 18 features.
#
# We have only 16.07% of customers who have churned. Thus, it's a bit difficult to train our model to predict churning customers. We will see what to do about it :))
#
# * **Attrition_Flag** ;          target		;categorical
# * **Customer_Age**  ;         feature-1	;numerical
# * **Gender**          ;            feature-2	;categorical
# * **Dependent_count**  ;           feature-3	;categorical
# * **Education_Level**   ;          feature-4	;categorical; Has Unknowns
# * **Marital_Status**     ;         feature-5	;categorical; Has Unknowns
# * **Income_Category**     ;        feature-6	;;categorical; Has Unknowns
# * **Card_Category**        ;       feature-7	;categorical
# * **Months_on_book**        ;      feature-8	;numerical
# * **Total_Relationship_Count** ;   feature-9	;categorical
# * **Months_Inactive_12_mon**    ;  feature-10	;categorical
# * **Contacts_Count_12_mon**      ; feature-11	; categorical
# * **Credit_Limit**     ;           feature-12	;numerical
# * **Total_Revolving_Bal** ;        feature-13	;numerical
# * **Avg_Open_To_Buy**      ;       feature-14	;numerical
# * **Total_Amt_Chng_Q4_Q1**  ;      feature-15	;numerical
# * **Total_Trans_Amt**;             feature-16	;numerical
# * **Total_Trans_Ct**  ;            feature-17	;numerical
# * **Total_Ct_Chng_Q4_Q1**    ;     feature-18	;df19;numerical
# * **Avg_Utilization_Ratio**   ;    feature-19	;df20;numerical

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import sklearn
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_validate
import warnings
from plotly.offline import iplot
warnings.filterwarnings("ignore")

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        path=(os.path.join(dirname, filename))

data = pd.read_csv(path)

# %%
data=data.iloc[:,1:21]
print("original shape is:",data.shape)
data.head()

# %% [markdown]
# Be sure if there is any null or NA value in the dataframe, luckly we do not have.

# %%
data.isnull().sum()
#data.isna().sum()

# %%
data.describe()

# %% [markdown]
# # 1. Feature Deep Dive & EDA

# %% [markdown]
# **1.1 Target (Output) : Attrition_Flag**
#
# * Categorical

# %%
from sklearn import preprocessing
df1=data.iloc[:,0:1]
le = preprocessing.LabelEncoder()
df1=le.fit_transform(df1)
df1=pd.DataFrame(data=df1, index=range(df1.shape[0]),columns=["Attrition_Flag"])

# %%
sns.set_style("ticks", {"xtick.major.size": 8, "ytick.major.size": 8})
plt.figure(figsize=(7, 5))
sns.countplot(x="Attrition_Flag", data=data, palette='pastel');

# %% [markdown]
# **1.2 Feature-1 : Customer_Age**
#
# * Numerical

# %%
df2=data.iloc[:,1:2]
#df2.head()

# %%
g=sns.distplot(df2,color="r",  label="Customer_Age")
g.legend()
plt.show()

# %% [markdown]
# **1.3 Feature-2 : Gender**
# * Categorical

# %%
df3=data.iloc[:,2:3]
#df3.head()

# %%
df3=le.fit_transform(df3)
df3=pd.DataFrame(data=df3, index=range(df3.shape[0]),columns=["Gender"])

# %%
g=sns.distplot(df3,color="r",  label="Gender")
g.legend()
plt.show()

# %% [markdown]
# **1.4 Feature-3 : Dependent_count**
#
# * Categorical

# %%
df4=data.iloc[:,3:4]
#df4.head()

# %%
g=sns.distplot(df4,color="r",  label=" Dependent_count")
g.legend()
plt.show()

# %% [markdown]
# **1.5 Feature-4 : Education_Level**
#
# * Categorical

# %%
df5=data.iloc[:,4:5]
#df5.head()

# %%
df5=le.fit_transform(df5)
df5=pd.DataFrame(data=df5, index=range(df5.shape[0]),columns=["Education_Level"])

g=sns.distplot(df5,color="r",  label="Education_Level")
g.legend()
plt.show()

# %% [markdown]
# **1.6 Feature-5 : Marital_Status**
#
# * Categorical

# %%
df6=data.iloc[:,5:6]
#df6.head()

# %%
df6=le.fit_transform(df6)
df6=pd.DataFrame(data=df6, index=range(df6.shape[0]),columns=["Maritial_Status"])

g=sns.distplot(df6,color="r",  label="Maritial_Status")
g.legend()
plt.show()

# %% [markdown]
# **1.7 Feature-6 : Income_Category**
# * Categorical

# %%
df7=data.iloc[:,6:7]
#df7.head(4)

# %%
df7=le.fit_transform(df7)
df7=pd.DataFrame(data=df7, index=range(df7.shape[0]),columns=["Income_Category"])

g=sns.distplot(df7,color="r",  label="Income_Category")
g.legend()
plt.show()

# %% [markdown]
# **1.8 Feature-7 : Card_Category**
# * Categorical

# %%
df8=data.iloc[:,7:8]
#df8.head()

# %%
df8=le.fit_transform(df8)
df8=pd.DataFrame(data=df8, index=range(df8.shape[0]),columns=["Card_Category"])

g=sns.distplot(df8,color="r",  label="Card_Category")
g.legend()
plt.show()

# %% [markdown]
# **1.9 Feature-8 : Months_on_book**
# * Numerical

# %%
df9=data.iloc[:,8:9]
#df9.head()

# %%
df9=le.fit_transform(df9)
df9=pd.DataFrame(data=df9, index=range(df9.shape[0]), columns=["Months_on_book"])

g=sns.distplot(df9,color="r",  label="Months_on_book")
g.legend()
plt.show()

# %% [markdown]
# **1.10 Feature-9 : Total_Relationship_Count**
# * Categorical

# %%
df10=data.iloc[:,9:10]
#df10.head()
#df10.describe()

# %%
g=sns.distplot(df10,color="r",  label="Months_on_book")
g.legend()
plt.show()

# %% [markdown]
# **1.11 Feature-10 : Months_Inactive_12_mon**
#
# * Categorical

# %%
df11=data.iloc[:,10:11]
#df11.head()

# %%
g=sns.distplot(df11,color="r",  label="Months_Inactive_12_mon")
g.legend()
plt.show()

# %% [markdown]
# **1.12 Feature-11 : Contacts_Count_12_mon**
#
# * Categorical

# %%
df12=data.iloc[:,11:12]
#df12.head()
#df12.describe()

# %%
g=sns.distplot(df12,color="r",  label="Contacts_Count_12_mon")
g.legend()
plt.show()

# %% [markdown]
# **1.13 Feature-12 : Credit_Limit**
#
# * Numerical

# %%
df13=data.iloc[:,12:13]
#df13.head()
#df13.describe()

# %%
g=sns.distplot(df13,color="r",  label="Credit_Limit")
g.legend()
plt.show()

# %% [markdown]
# **1.14 Feature-13 : Total_Revolving_Bal**
#
# * Numerical

# %%
df14=data.iloc[:,13:14]
#df14.head()
#df14.describe()

# %%
g=sns.distplot(df14,color="r",  label="Total_Revolving_Bal")
g.legend()
plt.show()

# %% [markdown]
# **1.15 Feature-14 : Avg_Open_To_Buy**
#
# * Numerical

# %%
df15=data.iloc[:,14:15]
#df15.head()
#df15.describe()

# %%
g=sns.distplot(df15,color="r",  label="Avg_Open_To_Buy")
g.legend()
plt.show()

# %% [markdown]
# **1.16 Feature-15 : Total_Amt_Chng_Q4_Q1**
#
# * Numerical

# %%
df16=data.iloc[:,15:16]
#df16.head()
#df16.describe()

# %%
g=sns.distplot(df16,color="r",  label="Total_Amt_Chng_Q4_Q1")
g.legend()
plt.show()

# %% [markdown]
# **1.17 Feature-16 : Total_Trans_Amt**
#
# * Numerical

# %%
df17=data.iloc[:,16:17]
#df17.head()
#df17.describe()

# %%
g=sns.distplot(df17,color="r",  label="Total_Trans_Amt")
g.legend()
plt.show()

# %% [markdown]
# **1.18 Feature-17 : Total_Trans_Ct**
#
# * Numerical

# %%
df18=data.iloc[:,17:18]
#df18.head()
#df18.describe()

# %%
g=sns.distplot(df18,color="r",  label="Total_Trans_Ct")
g.legend()
plt.show()

# %% [markdown]
# **1.19 Feature-18 : Total_Ct_Chng_Q4_Q1**
#
# * Numerical

# %%
df19=data.iloc[:,18:19]
#df19.head()
#df19.describe()

# %%
g=sns.distplot(df19,color="r",  label="Total_Ct_Chng_Q4_Q1")
g.legend()
plt.show()

# %% [markdown]
# **1.20 Feature-19 : Avg_Utilization_Ratio**
#
# * Numerical

# %%
df20=data.iloc[:,19:20]
#df20.head()
#df20.describe()

# %%
g=sns.distplot(df20,color="r",  label="Avg_Utilization_Ratio")
g.legend()
plt.show()

# %% [markdown]
# # **2. EDA**
#
# **2.1 Exploratory Data Anaylsis**
#
# We will check :
#
# * Multi collinearity
# * P-values
# * Outlier Clear by Feature deep-dive & IQR Method

# %% [markdown]
# Numerical features

# %%
numerical = pd.concat([df2,df9,df13,df14,df15,df16,df17,df18,df19,df20],axis=1)
print("numerical dataframe's shape is:", numerical.shape)
#numerical.head()

# %% [markdown]
# Categorical Features

# %%
categorical = pd.concat([df3,df4,df5,df6,df7,df8,df10,df11,df12],axis=1)
print("categorical dataframe's shape is:", categorical.shape)
#categorical.head()

# %% [markdown]
# Total DataFrame

# %%
dataframe = pd.concat([df1,df3,df4,df5,df6,df7,df8,df10,df11,df12,df2,df9,df13,df14,df15,df16,df17,df18,df19,df20],axis=1)
print("dataframe's shape is:", dataframe.shape)

# %%
korelasyon=dataframe.corr()
matrix = np.triu(dataframe.corr())
figure, axis=plt.subplots(figsize=(18,15))
sns.heatmap(korelasyon, annot=True,mask=matrix,cmap="rocket")

# %% [markdown]
# * Credit limit and Avg_Open_To_Buy features are directly correlated = 1. Thus, we can eliminate one of them
# * Customer age and Months_On_book are higly correlated >0.75
# * Total_Trans_Ct and Total_Trans_Amt are higly correlated >0.75

# %% [markdown]
# **2.2 Categorical Featur Cramer’s V**
#
# Cramer’s V is a number between 0 and 1 that indicates how strongly two categorical variables are associated. If we'd like to know if 2 categorical variables are associated, our first option is the chi-square independence test. A p-value close to zero means that our variables are very unlikely to be completely unassociated in some population. However, this does not mean the variables are strongly associated; a weak association in a large sample size may also result in p = 0.000.

# %%
import scipy.stats as ss   #Statistic 

categ = pd.concat([df1,categorical],axis=1)

def cramers_corrected_stat(x, y):
    result = -1
    conf_matrix = pd.crosstab(x, y)
    if conf_matrix.shape[0] == 2:
        correct = False
    else:
        correct = True
    chi2, p = ss.chi2_contingency(conf_matrix, correction=correct)[0:2]
    n = sum(conf_matrix.sum())
    phi2 = chi2/n
    r, k = conf_matrix.shape
    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))
    rcorr = r - ((r-1)**2)/(n-1)
    kcorr = k - ((k-1)**2)/(n-1)
    result = np.sqrt(phi2corr / min((kcorr-1), (rcorr-1)))
    return round(result, 6), round(p, 6)


for var in categorical:
    
    x = categorical[var]
    y = categ['Attrition_Flag']
    cramersV, p = cramers_corrected_stat(x, y)
    print(f'For variable {var}, Cramer\'s V: {cramersV} and p value: {p}')

# %% [markdown]
# * "Feature-7: Card category" has a p-value > 0.05 which is 0.525 and correlated with credit limit and avg_open to buy so we can eliminate it
# * "Feature-5: Maritial status" has a p-value > 0.05 which is 0.108
# * "Feature-3: Dependent Count" has a p-value > 0.05 which is 0.091 but still can be acceptable

# %% [markdown]
# **2.3 Numerical Features Handling: Kruskal-Wallis H-test**
#
#
# The Kruskal-Wallis H test is also called the "one-way ANOVA on ranks". It is a rank-based nonparametric test that can be used to determine if there are statistically significant differences between two or more groups of an independent variable on a continuous or ordinal dependent variable.

# %%
num = pd.concat([df1,numerical],axis=1)
for var in numerical:
    gp = num[[var, 'Attrition_Flag']].groupby(['Attrition_Flag'])
    gp_array = [group[var].to_numpy() for name, group in gp]
    kstat, p = ss.kruskal(*gp_array)
    kstat, p = round(kstat, 6), round(p, 6)
    print(f'For variable {var}, Kruskal-Wallis H-test: {kstat} and p value: {p}')

# %% [markdown]
# * "Feature-8: Months on book" has a p value > 0.05 which is 0.123, and it is correlated with customer age. Thus, we will eliminate it.
# * "Feature-1: Customer Age" has a p value > 0.05 which is 0.078, but still can be used since it is close to the edge.

# %% [markdown]
# **Conclusion of correlation and p-value check**
#
# *We will drop the features:*
#
# *  Feature-7 : Card Category (df8)
# *  Feature-14: Avg_Open_To_Buy (df15)
# *  Feature-8 : Months on book (df9)
#
# *We will check the performance of the parameters with k-fold cross validation:*
#
# * Feature-5: Maritial Status (df6)
# * Feature-3: Dependent Count (df4)
# * Feature-1: Customer Age (df2)

# %% [markdown]
# # 3. Outlier Cleaning
#
# For outlier detection, the best practice is to use IQR method. This method helps us to illustrate the data distrubution as a box plot. The difference between Q3 (75%) and Q1 (25%) is called the Inter-Quartile Range It tells about the distribution characteristics of the data. It gives data's range, boundries and skewness. As can be seen the figure below that a box plot enables us to draw inference from it for an ordered data.
#
# IQR = Q3 - Q1 Lower Bound: (Q1 - 1.5 IQR) Upper Bound: (Q3 + 1.5 IQR)

# %%
dataframe=pd.concat([df1,df2,df3,df4,df5,df6,df7,df10,df11,df12,df13,df14,df16,df17,df18,df19,df20],axis=1)
numlist=dataframe.loc[:,dataframe.nunique()>7].columns
print(numlist)

# %%
def clean_outliers(df, features):
    for i in features:
        Q1=df[i].quantile(0.25)
        Q3=df[i].quantile(0.75)
        IQR= (Q3-Q1)
        print("Feature {} has min value: {} max value: {}".format(i, Q1-IQR*1.5,Q3+IQR*1.5))
        df=df[((df[i]>(Q1-IQR*1.5))&(df[i]<(Q3+IQR*1.5)))]
    return df

# %%
df_clean=clean_outliers(dataframe, numlist)
print("New shape: ",df_clean.shape)

# %% [markdown]
# We clean the outliers due to IQR analysis.

# %% [markdown]
# **Data Augmentation by SMOTE**

# %%
y=df_clean["Attrition_Flag"]
x=df_clean.iloc[:,1:]

# %%
from imblearn.over_sampling import SMOTENC
xv=x.values
yv=y.values
smote_nc = SMOTENC(categorical_features=[df_clean["Attrition_Flag"].min(), df_clean["Attrition_Flag"].max()], random_state=0)
x, y = smote_nc.fit_resample(xv, yv)
x = pd.DataFrame(data=x, index=range(x.shape[0]))
y= pd.DataFrame(data=y, index=range(y.shape[0]),columns=["Attrition_Flag"])
print("new feature shape: ",x.shape)
print("new target shape: ",y.shape)

# %% [markdown]
# Attrition flag data distrubition after :)

# %%
sns.set_style("ticks", {"xtick.major.size": 8, "ytick.major.size": 8})
plt.figure(figsize=(7, 5))
sns.countplot(x="Attrition_Flag", data=y, palette='pastel');

# %% [markdown]
# # 4. Prediction Models

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score as ass
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_validate
from sklearn.metrics import make_scorer
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.model_selection import cross_val_score, KFold, GridSearchCV,train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report, confusion_matrix
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.covariance import LedoitWolf
from sklearn.covariance import MinCovDet
from sklearn.covariance import OAS
from sklearn.covariance import GraphicalLasso
from sklearn.datasets import make_hastie_10_2
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from numpy import loadtxt
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from numpy import loadtxt
from xgboost import XGBClassifier

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.2, random_state=42)

# %% [markdown]
# Standartization is neccessary for the scale of the features

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
model = [DecisionTreeClassifier(), RandomForestClassifier(), GradientBoostingClassifier()]

# %%
for i in model:
    params={'max_leaf_nodes':[i for i in range(2,20)]}
    score = GridSearchCV(i, param_grid=params, scoring='recall')
    score.fit(x_train,y_train)
    print(score.best_params_)
    print(score.best_estimator_)
    print(f"Recall score: {score.best_score_}")
    pred=score.predict(x_test)
    print(f"Recall score of test data: {recall_score(y_test, pred)}")
    print(classification_report(y_test,pred))
    sns.heatmap(confusion_matrix(y_test,pred), annot=True)
    plt.show()

# %% [markdown]
# # 5. Results
#
# * Decision tree 90%
# * Random Forest 93%
# * Gradient Boost 97%
#
#
# We got 97.2& Recall and 97% f1 score with Gradient Boosting. But still it is a mystery that how it will work on real life since we increase the data with SMOTE.
