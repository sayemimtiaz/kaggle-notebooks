# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
# load libraries
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
# set the filepath and load in a shapefile
fp = "/kaggle/input/allegheny-county/Allegheny_County_Municipal_Boundaries.shp"

map_df = gpd.read_file(fp)

# %%
# check data type so we can see that this is not a normal dataframe, but a GEOdataframe
map_df.head()

# %%
# now let's preview what our map looks like with no data in it
map_df.plot()

# %%
map_data= pd.read_csv("/kaggle/input/allegheny-covid-timeseries/allegheny41.csv")
county = map_data['county']
map_data = map_data.drop(columns = ['county'], axis = 1)
map_data.rename(columns = {'3/27/2020':pd.to_datetime('3/27/2020')}, inplace = True)
map_data.rename(columns = {'3/28/2020':pd.to_datetime('3/28/2020')}, inplace = True)
map_data.rename(columns = {'3/29/2020':pd.to_datetime('3/29/2020')}, inplace = True)
map_data.rename(columns = {'3/30/2020':pd.to_datetime('3/30/2020')}, inplace = True)
map_data.rename(columns = {'4/1/2020':pd.to_datetime('4/1/2020')}, inplace = True)
map_data.head()

# %%
upsampled = map_data.resample(rule = 'H', axis =1).mean()
upsampled2 = upsampled.interpolate(method = 'linear', axis = 1)
upsampled2['county'] = county
upsampled2

# %%
    merged = map_df.set_index('LABEL').join(upsampled2.set_index('county'))
    merged.head()

# %%
merged.columns[139]

# %%
    variable = merged.columns[19]
    # create figure and axes for Matplotlib
    fig, ax = plt.subplots(1, figsize=(10, 6))

    ax.annotate(variable, xy=(0.25, .1), xycoords='figure fraction', fontsize=15, color='#555555')

    # create map
    merged.plot(column=variable, cmap='Reds', linewidth=0.8, ax=ax, edgecolor='0.8', 
                #scheme="User_Defined", 
             legend=True, 
                #classification_kwds=dict(bins=[0,5,10,50,100, 500, 1000, 5000])
               )

    #leg = ax.get_legend()
    #leg.set_bbox_to_anchor((1.2, 0.7, 0.2, 0.2))

    ax.set_title('COVID-19 cases in PA by County', fontdict={'fontsize': '15', 'fontweight' : '5'})



    #new_labels=['0', '0-5', '5-10', '10-50', '50-100', '100-500', '500-1000', '1000+' ]



    #leg = ax.get_legend()
    #for text, label in zip(leg.get_texts(), new_labels):
    #    text.set_text(label)
    ax.axis('off')

# %%
    kw = ['2020-03-07']
    #map_data0 = map_data[map_data["date"].isin(kw)]
    #map_data0 = map_data0.drop(columns = ['date', 'state', 'fips'])
    #merged = map_df.set_index('NAME').join(map_data0.set_index('county'))
    #merged.append(dummy, ignore_index = True)
    #merged['cases'][66] = 1000
    variable = 'cases'
    # create figure and axes for Matplotlib
    fig, ax = plt.subplots(1, figsize=(10, 6))

    ax.annotate(kw[0], xy=(0.25, .1), xycoords='figure fraction', fontsize=15, color='#555555')

    # create map
    merged.plot(column=variable, cmap='Reds', linewidth=0.8, ax=ax, edgecolor='0.8', 
                scheme="User_Defined", 
             legend=True, 
                classification_kwds=dict(bins=[0,5,10,50,100, 500, 1000, 5000])
               )

    leg = ax.get_legend()
    leg.set_bbox_to_anchor((.92, 0.7, 0.2, 0.2))

    ax.set_title('COVID-19 cases in PA by County', fontdict={'fontsize': '15', 'fontweight' : '5'})



    new_labels=['0', '0-5', '5-10', '10-50', '50-100', '100-500', '500-1000', '1000+' ]



    leg = ax.get_legend()
    for text, label in zip(leg.get_texts(), new_labels):
        text.set_text(label)
    ax.axis('off')

# %%
for i in range (19, 139):

    variable = merged.columns[i]
    # create figure and axes for Matplotlib
    fig, ax = plt.subplots(1, figsize=(10, 6))

    ax.annotate(variable, xy=(0.25, .1), xycoords='figure fraction', fontsize=15, color='#555555')

    # create map
    merged.plot(column=variable, cmap='Reds', linewidth=0.8, ax=ax, edgecolor='0.8', 
                scheme="User_Defined", 
             legend=True, 
                classification_kwds=dict(bins=[0,5,10,50,100, 500])
               )

    leg = ax.get_legend()
    leg.set_bbox_to_anchor((1.2, 0.7, 0.2, 0.2))

    ax.set_title('COVID-19 cases in PA by County', fontdict={'fontsize': '15', 'fontweight' : '5'})



    new_labels=['0', '0-5', '5-10', '10-50', '50-100', '100-500']



    leg = ax.get_legend()
    for text, label in zip(leg.get_texts(), new_labels):
        text.set_text(label)
    ax.axis('off')
    
    fig.savefig('pacovid' + str(i), dpi=300)

# %%
merged = map_df.set_index('NAME').join(map_data06.set_index('county'))
pd.set_option('display.max_rows', None)
merged.head()

# %%
variable = 'cases'


# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(10, 6))

ax.annotate(variable, xy=(0.25, .1), xycoords='figure fraction', fontsize=15, color='#555555')

# create map
merged.plot(column = variable, cmap='Reds', linewidth=0.8, ax=ax, edgecolor='0.8', scheme="User_Defined", 
         legend=True, classification_kwds=dict(bins=[0,1,3,5,10, 50, 100, 200, 300]))
leg = ax.get_legend()
leg.set_bbox_to_anchor((1.0, 0.7, 0.2, 0.2))

new_labels=[ '0',
                '0-1',
                '1-3',
                '3-5',
                '5-10',
                '10-50',
        '50-100', '100-200', '200-300'
]


ax.set_title('COVID-19 cases in Allegheny County by Municipality', fontdict={'fontsize': '15', 'fontweight' : '5'})


leg = ax.get_legend()
for text, label in zip(leg.get_texts(), new_labels):
    text.set_text(label)
ax.axis('off')


#chart = fig.get_figure()
#fig.savefig('test', dpi=300)

# %%
import imageio
images = []
for i in range (19, 139):
    images.append(imageio.imread('/kaggle/working/pacovid' + str(i) + '.png'))
imageio.mimsave('patime.gif', images, duration = 0.3)
