# %%
import pandas as pd

# %%
df=pd.read_csv('../input/gufhtugu-publications-dataset-challenge/GP Orders - 5.csv')

# %%
df.head(4)

# %%
df['Book Name'].value_counts().head(10)

# %%
df['Book Name'].value_counts().nlargest(10).index.tolist()

# %%
import matplotlib.pyplot as plt

df['Book Name'].value_counts().head(10).plot(kind='bar')

plt.show()

# %%
import seaborn as sns
# %matplotlib inline

# %%
df['Payment Method'].unique()

# %%
df['Order Status'].unique()

# %%
df[df['Order Status'] == 'Returned']

# %%
returned_order = df[df['Order Status'] == 'Returned']

# %%
returned_order.corr()

# %%
sns.heatmap(returned_order.corr())

# %%
completed_order = df[df['Order Status'] == 'Completed']

# %%
completed_order.corr()

# %%
sns.heatmap(completed_order.corr())

# %%
cancelled_order = df[df['Order Status'] == 'Cancelled']

# %%
cancelled_order.corr()

# %%
sns.heatmap(cancelled_order.corr())
