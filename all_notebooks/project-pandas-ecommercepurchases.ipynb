# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd

# %%
ecom = pd.read_csv('../input/ecommercepurchasescsv/EcommercePurchases.csv')

# %%
ecom.head()

# %%
ecom.columns

# %%
len(ecom.columns)

# %%
ecom.info()

# %%
ecom['Purchase Price'].mean()

# %%
ecom['Purchase Price'].max()

# %%
ecom['Purchase Price'].min()

# %%
ecom['Language'] == 'en'

# %%
ecom[ecom['Language'] == 'en']

# %%
ecom[ecom['Language'] == 'en']['Language'].count()

# %%
ecom[ecom['Job']=='Lawyer'].head(5)

# %%
ecom[ecom['Job']=='Lawyer'].info()

# %%
ecom[ecom['Job']=='Lawyer'].count()

# %%
#How many people made a purchase during the AM and how many purchases during the PM?
ecom['AM or PM'].value_counts()

# %%
ecom['Job'].value_counts().head(5)

# %%
ecom[ecom['Lot']=='90 WT']

# %%
ecom[ecom['Lot']=='90 WT']['Purchase Price']

# %%
ecom[ecom['Credit Card']==4040542728940631]['Email']

# %%
ecom[(ecom['CC Provider']=='American Express') & (ecom['Purchase Price']>95)]

# %%
ecom[(ecom['CC Provider']=='American Express') & (ecom['Purchase Price']>95)].count()

# %%
ecom['CC Exp Date'].apply(lambda exp: exp[3:]=='25')

# %%
ecom['CC Exp Date'].apply(lambda exp: exp[3:]=='25').count()
#returns the number of 'TRUE'

# %%
ecom['Email']

# %%
#What are the Top 5 most popular email hosts?
example_email = ecom['Email'].iloc[0]

# %%
example_email

# %%
example_email.split('@')

# %%
example_email.split('@')[1]

# %%
ecom['Email'].apply(lambda email: email.split('@')[1])

# %%
ecom['Email'].apply(lambda email: email.split('@')[1]).head(5)
