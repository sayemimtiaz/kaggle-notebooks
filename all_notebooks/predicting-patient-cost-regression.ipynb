# %% [markdown]
# APPLYING VARIOUS REGRESSION MODELS TO PREDICT THE COST OF TREATMENT OF PATIENTS.

# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#importing dataset
ds = pd.read_csv('../input/insurance/insurance.csv')
ds.head()

# %%
#assigning dependent and independent variables
x = ds.iloc[:,:-1].values
y = ds.iloc[:,-1].values

# %%
#checking for missing values
ds.isnull().any()

# %% [markdown]
# **NO MISSING VALUES**

# %% [markdown]
# # ENCODING CATEGORICAL DATA

# %%
#applying label encoding on column 1 and 4
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
x[:,1]=le.fit_transform(x[:,1])
x[:,4]=le.fit_transform(x[:,4])

# %%
print(x)

# %%
#applying lone hot encoding on column 5
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers = [('encoder',OneHotEncoder(),[5])],remainder = 'passthrough')
x = np.array(ct.fit_transform(x))
print(x)

# %%
#splitting into training and test set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# # APPLYING VARIOUS MODELS

# %% [markdown]
# **LINEAR REGRESSION**

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
lr=LinearRegression()
lr.fit(x_train,y_train)
lra = lr.score(x_test,y_test)
print(lr.score(x_test,y_test))

# %% [markdown]
# **POLYNOMIAL REGRESSION**

# %%
from sklearn.preprocessing import PolynomialFeatures
pf = PolynomialFeatures(degree = 4)
x_new = pf.fit_transform(x_train)
plr=LinearRegression()
plr.fit(x_new,y_train)
lra2 = plr.score(pf.transform(x_test),y_test)
print(plr.score(pf.transform(x_test),y_test))

# %% [markdown]
# **DECISON TREE REGRESSION**

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
dt.fit(x_train, y_train)
dta = dt.score(x_test,y_test)
print(dt.score(x_test,y_test))

# %% [markdown]
# **RANDOM FOREST REGRESSION**

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators = 100, random_state = 0)
rf.fit(x_train, y_train)
rfa = rf.score(x_test,y_test)
print(rf.score(x_test,y_test))

# %%
#comparing accuracy
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['LR', 'PR', 'DTR', 'RFR']
students = [lra,lra2,dta,rfa]
ax.bar(langs,students)
plt.show()

# %% [markdown]
# **AS YOU CAN SEE THE BEST ACCURACY CAME FOR RANDOM FOREST REGRESSION THAT IS 87.6% AND HENCE IT'S THE BEST MODEL FOR OUR DATASET**
