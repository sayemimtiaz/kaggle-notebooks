# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Importing the data

# %%
data = pd.read_csv("../input/spotify-dataset-19212020-160k-tracks/data_by_year.csv")

# %% [markdown]
# # Preparing data for Flourish
#
# Flourish charts call for the years to be columns, and the items to be plotted over time to be the rows. To convert our data, we need to transpose the rows and columns.

# %%
data = data.astype(object).T
data.columns= data.iloc[0]
data= data.drop(['year', 'key', "mode","tempo", "duration_ms", "loudness", "popularity"])

data

# %% [markdown]
# # Images for labels

# %%
acoustic = "https://cdn.mos.cms.futurecdn.net/BuapRk5pEfVWde4uc2F5YB.jpg"
dance = "https://i.pinimg.com/originals/e1/db/58/e1db58057eed82e5f49c2daf743da5e3.jpg"
energy = "https://teachengineering.org/content/cub_/lessons/cub_energy2/cub_energy2_lesson05_image1_new1.jpg"
instrumental = "data:image/jpeg;base64,..."
liveness =  "https://broadstonemidtown.com/wp-content/uploads/2018/07/livemusic-1000x500.jpg"
speech = "https://prod-images-static.radiopaedia.org/images/25452701/ec8a92c069a84aa235f907e2c0c0ca_jumbo.jpeg"
valence = "data:image/jpeg;base64,..."

# %%
data["image"] = [acoustic, dance, energy, instrumental, liveness, speech, valence]

# %% [markdown]
# # Convert to CSV for flourish

# %%
data.to_csv("musicdata.csv")

# %% [markdown]
# # Embed Flourish Chart

# %%
from IPython.core.display import HTML

# %% [markdown]
# # Attributes over time

# %%
HTML('''<div class="flourish-embed flourish-chart" data-src="visualisation/5195145"><script src="https://public.flourish.studio/resources/embed.js"></script></div>''')

# %% [markdown]
# # Danceability vs Valence (happiness/positivity) by genre

# %%
HTML('''<div class="flourish-embed flourish-scatter" data-src="visualisation/5195584"><script src="https://public.flourish.studio/resources/embed.js"></script></div>''')

# %% [markdown]
# # What do you think of these charts? I would like to add more to this soon, likely starting with breaking down trends by genre.
