# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)

import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

#pd.pandas.set_option('display.max_columns',None)
#pd.pandas.set_option('display.max_rows',None)
import warnings
warnings.filterwarnings('ignore')

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # General Outlook of the Data

# %%
data = pd.read_csv('/kaggle/input/weather-dataset-rattle-package/weatherAUS.csv')
tdf = data.copy()

# %%
tdf

# %%
tdf.tail()

# %%
unique_val = []
for i in tdf.columns:
    u = tdf[i].nunique()
    unique_val.append(u)
    
pd.DataFrame({"No. of unique values": unique_val}, index=tdf.columns)

# %% [markdown]
# # 1. MissingNo visualizations
# # Missing Values

# %%
tdf.isnull().sum()

# %%
# Features with missing values
miss = tdf.isnull().sum().sort_values(ascending = False).head(5)
miss_per = (miss/len(tdf))*100

# Percentage of missing values
pd.DataFrame({'No. missing values': miss, '% of missing data': miss_per.values})

# %%
import missingno as msno
msno.matrix(tdf);

# %%
msno.bar(tdf);

# %%
msno.heatmap(tdf);

# %%
tdf.info()

# %%
tdf['Date'] = pd.to_datetime(tdf['Date'])
tdf['Year'] = tdf['Date'].dt.year.astype('int16')
tdf['Month'] = tdf['Date'].dt.month.astype('int16')

# %%
tdf.info()

# %% [markdown]
# # Data Visualisations

# %% [markdown]
# ## Distribution of Categorical Variables

# %%
tdf = tdf[tdf['RainToday'].notna()]
tdf = tdf[tdf['RainTomorrow'].notna()]

# %%
fig = px.histogram(tdf, x="Location")
fig.show()

# %%
fig = px.histogram(tdf, color= "RainToday", x="WindGustDir")
fig.show()

# %%
fig = px.histogram(tdf, color= "RainTomorrow", x="WindGustDir")
fig.show()

# %%
fig = px.histogram(tdf, x="RainTomorrow")
fig.show()

# %%
fig = px.histogram(tdf, x="RainToday")
fig.show()

# %%
tdf.info()

# %%
fig = px.bar(y=tdf.RainToday.value_counts()[0:20],x=tdf.RainTomorrow.value_counts().index[0:20])
fig.show()

# %%
tdf.info()

# %% [markdown]
# ## Distribution of Numerical Variables

# %%
fig = px.histogram(tdf, color="RainTomorrow", x="Sunshine")
fig.show()

# %%
fig = px.histogram(tdf, color="RainTomorrow", x="Evaporation")
fig.show()

# %%
fig = px.histogram(tdf, color="RainTomorrow", x="Pressure3pm")
fig.show()

# %%
fig = px.histogram(tdf, color="RainTomorrow", x="WindGustSpeed")
fig.show()

# %%
fig = px.histogram(tdf, color="RainTomorrow", x="MinTemp", nbins=20)
fig.show()

# %%
fig = px.histogram(tdf, color="RainTomorrow", x="MaxTemp", nbins=10 )
fig.show()

# %%
fig = px.histogram(tdf, color="RainTomorrow", x="MaxTemp", nbins=10, histfunc='avg')
fig.show()

# %%
tdf.info()

# %%
fig = px.violin(tdf, y="Rainfall", color="RainTomorrow")
fig.show()

# %%
fig = px.violin(tdf, y="Evaporation", color="RainTomorrow")
fig.show()

# %%
tdf.columns

# %% [markdown]
# ## Correleations between Numerical Variables

# %%
continuous_features  = ['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
       'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
       'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
       'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
       'Temp3pm', 'RainToday', 'RainTomorrow']
fig = px.imshow(tdf[continuous_features].corr());
fig.show()

# %% [markdown]
# ## Analysis of RainTommorrow across different variables

# %%
fig = px.box(tdf, y="MaxTemp",x='RainTomorrow')
fig.show()

# %%
fig = px.box(tdf, y="MinTemp",x='RainTomorrow')
fig.show()

# %%
fig = px.box(tdf, y="Pressure3pm",x='Date',color='RainTomorrow',)
fig.show()

# %%
fig = px.box(tdf, y="Humidity3pm",x='Date',color='RainTomorrow',)
fig.show()

# %%
fig = px.histogram(tdf, y="Humidity3pm",x='Date',color='RainTomorrow',  histfunc='avg')
fig.show()

# %%
fig = px.scatter(tdf, y='Rainfall', x="Date", color='RainTomorrow', trendline='ols')
fig.show()

# %%
fig = px.scatter(tdf, y='Pressure3pm', x="Date", color='RainTomorrow', trendline='ols')
fig.show()

# %%
fig = px.scatter(tdf, y='Humidity3pm', x="Date", color='RainTomorrow', trendline='ols')
fig.show()

# %%
fig = px.scatter_matrix(tdf, dimensions=['MaxTemp','MinTemp','Humidity9am'],color='RainTomorrow')
fig.show()

# %%
    fig = px.line(tdf, x="Date", y="Humuditypm", color='RainTomorrow')
    fig.show()

# %% [markdown]
# -Scatter matrix and/or OLS Scatter Plot for numerical variables

# %%
cols_s=[
 'MinTemp',
 'MaxTemp',
 'Rainfall',
 'Evaporation',
 'Sunshine',
 'WindGustSpeed',
 'WindSpeed9am',
 'WindSpeed3pm',
 'Humidity9am',
 'Humidity3pm',
 'Pressure9am',
 'Pressure3pm',
 'Cloud9am',
 'Cloud3pm',
 'Temp9am',
 'Temp3pm',
 ]

# %%
tdf1 = tdf.groupby(['Year_Month','RainTomorrow'])[cols_s].agg('mean').reset_index()

# %%
for i in cols_s[:-1]:
    
    fig = px.scatter(tdf1, x=i,color="RainTomorrow"
                    
                     )
    fig.show()

# %% [markdown]
# - Time series (preferably monthly) line chart for numerical variables

# %%
tdf['Year_Month']=tdf['Date'].array.strftime('%Y-%m')

# %%
cols=[
 'MinTemp',
 'MaxTemp',
 'Rainfall',
 'Evaporation',
 'Sunshine',
 'WindGustSpeed',
 'WindSpeed9am',
 'WindSpeed3pm',
 'Humidity9am',
 'Humidity3pm',
 'Pressure9am',
 'Pressure3pm',
 'Cloud9am',
 'Cloud3pm',
 'Temp9am',
 'Temp3pm',
  'Year',
 'Month']

# %%
cls_1 = ['MinTemp', 'MaxTemp', 'Different_Temp','Rainfall', 'Evaporation',
       'Sunshine','WindGustSpeed','WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
       'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
       'Temp3pm']

# %%
tdf1 = tdf.groupby(['Year_Month','RainTomorrow'])[cols].agg('mean').reset_index()
tdf1

# %%
cols_t= ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
       'Sunshine','WindGustSpeed','WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
       'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
       'Temp3pm']

# %%
for i in cols_t:
    
    fig = px.line(tdf1, x='Year_Month', y=i, 
                     color='RainTomorrow',
                 )
    fig.show()
