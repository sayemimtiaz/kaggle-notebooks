# %%
import pandas as pd

# %%
df=pd.read_csv("../input/titanic-train-dataset/train.csv")

# %%
df

# %%
# !pip install pandas-profiling

# %%
from pandas_profiling import ProfileReport
prof=ProfileReport(df)
prof.to_file(output_file='newoutput.html')

# %%
prof.to_notebook_iframe()

# %%
prof.to_widgets()

# %%
# As a string
json_data = prof.to_json()

# As a file
prof.to_file("your_report.json")
