# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
training = pd.read_csv('/kaggle/input/msm-techgig/MSM_Training_Data.csv')
testing = pd.read_csv('/kaggle/input/msm-techgig/MSM_Test_Data.csv')
click = pd.read_csv('/kaggle/input/msm-techgig/MSM_click_log.csv')
submission = pd.read_csv('/kaggle/input/msm-techgig/MSM_sample_submission.csv')

# %%
training.head()

# %%
training.size

# %%
len(testing.columns)

# %% [raw]
# training.info()
# #clientid_cr, clmbuserid_cr, imprid_cr,adslotdimid_cr,clickbid_cr,ip_cr,itemcolumbiaid_cr,site_Id,
# #goalid_cr,odId_cr,browserId_cr, cityId_cr, stateId_cr, ispDimId_cr,countryDimId_cr,osVerDimId_cr,
# deviceId_cr,time_cr  ,v_cr.

# %%
click.columns
training.info()

# %%
len(click.columns)

# %%
f_training = pd.DataFrame(training,columns=["clientid_cr","pubclientid_cr","clmbuserid_cr","imprid_cr","adslotdimid_cr","clickbid_cr","itemcolumbiaid_cr","siteId_cr","goalid_cr","browserId_cr", "cityId_cr", "stateId_cr", "ispDimId_cr","countryDimId_cr","osVerDimId_cr","conversiontime_cr","deviceId_cr","time_cr","v_cr"])
#training[["clientid_cr","pubclientid_cr","clmbuserid_cr","imprid_cr","adslotdimid_cr","clickbid_cr","itemcolumbiaid_cr","siteId_cr","goalid_cr","browserId_cr", "cityId_cr", "stateId_cr", "ispDimId_cr","countryDimId_cr","osVerDimId_cr","conversiontime_cr","deviceId_cr","time_cr","v_cr"]]

# %%
#f_training = pd.Dataframe(training[["clientid_cr","pubclientid_cr","clmbuserid_cr","imprid_cr","adslotdimid_cr","clickbid_cr","itemcolumbiaid_cr","siteId_cr","goalid_cr","browserId_cr", "cityId_cr", "stateId_cr", "ispDimId_cr","countryDimId_cr","osVerDimId_cr","conversiontime_cr","deviceId_cr","time_cr","v_cr"]])

# %%
f_training.head()

# %%
f_training['deviceId_cr'].fillna(f_training['deviceId_cr'].mean(),inplace=True)

# %%
f_training.head()

# %%
f_training.info()

# %%
f_training.dropna(inplace=True)

# %%
len(f_training)

# %%
len(f_training['clientid_cr'])

# %%
f_training.isna().any()

# %%
f_training.shape

# %%
f_training.head()

# %%
click['pubClientId'].value_counts()

# %%
f_training['pubclientid_cr'].value_counts()

# %%
click.info()

# %%
training.info()

# %%
training['clmbuserid_cr'].value_counts()

# %%
sorted(click.columns)

# %%
click.shape

# %%
#["advClientId","pubClientId","imprId","clickIp","crtd","clmbUserId","siteId","countryDimId","osVerDimId","devTypeDimId","ispDimId","itmClmbLId","adSltDimId","browserDimId","stateDimId","cityDimId","fraud"]

# %%
f_click = pd.DataFrame(click,columns=["advClientId","pubClientId","imprId","clickIp","crtd","clmbUserId","siteId","countryDimId","osVerDimId","devTypeDimId","ispDimId","itmClmbLId","adSltDimId","browserDimId","stateDimId","cityDimId","fraud"])

# %%
f_click.sample(5)

# %%
f_click['fraud'].value_counts()

# %%
def func(x):
    if pd.isna(x):
        x=0
    else:
        x=1
    return x

# %%
f_click['fraud'] = f_click['fraud'].apply(lambda x:func(x))

# %%
f_click.head()

# %%
f_click.info()

# %%
f_click.dropna(inplace=True)

# %%
f_click.drop_duplicates(subset=['imprId','clickIp','clmbUserId','browserDimId'],keep='first')

# %%
f_click.head(10)

# %%
f_click.corr()

# %%
f_click.info()

# %%
f_click.head()

# %%
f_click["browserDimId"].value_counts()

# %%
type(f_click["browserDimId"].values)

# %%
f_click.drop(columns = ["browserDimId"], inplace = True)

# %%
f_click.drop(columns = ["crtd", "clickIp", "imprId"], inplace = True)

# %%
f_click.info()

# %%
f_click.drop(columns = ["clmbUserId"], inplace = True)

# %%
f_click.corr()

# %%
# from sklearn.model_selection import train_test_split
# f_train , f_test, f2_train, f2_test = train_test_split(f_click, ,test_size=0.2,random_state=1)
# #SVM
# from sklearn.svm import SVC
