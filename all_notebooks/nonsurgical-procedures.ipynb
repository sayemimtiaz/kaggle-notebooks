# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import warnings
warnings.filterwarnings("ignore")

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ![](https://media2.giphy.com/media/MAoMKQuYw8pW4kmn4S/200w.webp?cid=ecf05e47xndet1l4th840sc3kdtogm2kiu3c8xrhojqnb3cv&rid=200w.webp&ct=g)giphy.com

# %% [markdown]
# #Nonsurgical Procedures
#
# "While news and pop culture will have you believe that women are the primary recipients of plastic surgery, it’s a little-known fact that men are just as likely to opt for cosmetic treatments as women. Among men, invasive surgeries like liposuction, tummy tucks, and breast reduction surgery are common. Of course, non-surgical procedures are popular as well."
#
# "Interested in learning more about what non-surgical procedures men flock to most?"
#
# "The top 5 most popular non-surgical cosmetic procedures for men: chemical peels, Botox injections, dermal fillers, laser hair removal and nonsurgical fat reduction."
#
# https://www.sieberplasticsurgery.com/articles/5-most-popular-non-surgical-procedures-for-men/

# %%
df = pd.read_csv("/kaggle/input/cusersmarilonedrivedocumentosnonsurgcsv/nonsurg.csv", low_memory=False, encoding ='ISO-8859-1',sep=";")
print(df.shape)
df.head().style.set_properties(**{'background-color':'purple',
                                     'color': 'white'})

# %% [markdown]
# #Why the percent column has so many zeros. In the excel table and the Dataset,those zeros don't appear.

# %%
fig = px.bar(df, 
             x='total_2019', y='nonsurgical_procedures', color_discrete_sequence=['#FFD700'],
             title='Nonsurgical Procedures', text='percent')
fig.show()

# %% [markdown]
# #I don't understand why those bars above are growing if the percent is getting lower. Any clue?

# %%
#Code by Siti K https://www.kaggle.com/khotijahs1/2020-indonesia-university-rank/comments

#10 Nonsurgical Procedures performed by Plastic Surgeons
top_procedure = df.sort_values(by='percent', ascending=False)[:10]
figure = plt.figure(figsize=(10,6))
sns.barplot(y=top_procedure.nonsurgical_procedures, x=top_procedure.percent, color='g')
plt.xticks()
plt.xlabel('Percent')
plt.ylabel('Nonsurgical Procedures')
plt.title('Nonsurgical Procedures performed by Plastic Surgeons')
plt.show;

# %%
from collections import Counter
procedure_data = df['nonsurgical_procedures']
procedure_count = pd.Series(dict(Counter(','.join(procedure_data).replace(' ,',',').replace(
    ', ',',').split(',')))).sort_values(ascending=False)

# %%
top10procedure = procedure_count.head(10)

# %%
#Code by Mohammad Inran Shaikh https://www.kaggle.com/shikhnu/data-analysis-and-visualization-netflix-data
from matplotlib import gridspec

fig = plt.figure(figsize=(20, 7))
gs = gridspec.GridSpec(nrows=1, ncols=2, height_ratios=[6], width_ratios=[10, 5])

ax = plt.subplot(gs[0])
sns.barplot(top10procedure.index, top10procedure, ax=ax, palette="RdGy")
ax.set_xticklabels(top10procedure.index, rotation='90')
ax.set_title('Nonsurgical Procedures', fontsize=15, fontweight='bold')

ax2 = plt.subplot(gs[1])
ax2.pie(top10procedure, labels=top10procedure.index, shadow=True, startangle=0, colors=sns.color_palette("RdGy", n_colors=20),
       autopct='%1.2f%%')
ax2.axis('equal') 

plt.show()

# %%
#word cloud
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in df.nonsurgical_procedures)
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200,colormap='Set2', background_color="black").generate(text)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='Bilinear')
plt.axis("off")
plt.figure(1,figsize=(12, 12))
plt.show()

# %% [markdown]
# #Are you ready for Botox? What about the other procedures?
