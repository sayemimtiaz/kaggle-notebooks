# %% [markdown]
# Nesta bring bold ideas to life to change the world for good.
# Nesta is an innovation foundation. For them, innovation means turning bold ideas into reality. It also means changing lives for the better. This is what keeps them awake at night and gets them out of bed in the morning.https://www.nesta.org.uk/about-us/
#
# Nesta mission is in some ways very simple. They exist to back innovations for the common good. They balance the distortions that drive too much investment in innovation either to harmful or trivial ends. Instead, They grow new ideas that tackle the challenges our society faces and change the world for the better.https://www.nesta.org.uk/blog/the-nesta-story/

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcS8tOEWWnDQYce1N4YGPXMICzPtzsudVDSIRujRmsxd6C72Gp88',width=400,height=400)

# %% [markdown]
# eciaplatform.eu

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTWtxCzazRUMWgQcfxYWQYwjFvko9x8Xw-aZRdAweUHdgqOKSsE',width=400,height=400)

# %% [markdown]
# networkcultures.org

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/1. R_D/NESTA/Women in AI/Women_in_ai_country_data.xlsx')
df.head()

# %%
df.dtypes

# %%
df["year"].plot.hist()
plt.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQOWYw1m3602py3CEmM45ohQv6rP_-GMJm70SxsBJjTc1slbX97',width=400,height=400)

# %% [markdown]
# nesta.org.uk

# %%
df["year"].plot.box()
plt.show()

# %%
sns.pairplot(df, x_vars=['year'], y_vars='Country', markers="+", size=4)
plt.show()

# %%
dfcorr=df.corr()
dfcorr

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQAZO3JoPBbJRgLA8ZoTLLGCJJhRd-DxWiPmGDbGuMgukHdXiOR',width=400,height=400)

# %% [markdown]
# twitter.com

# %%
sns.heatmap(dfcorr,annot=True,cmap='winter')
plt.show()

# %%
fig, axes = plt.subplots(1, 1, figsize=(12, 4))
sns.boxplot(x='year', y='Country', data=df, showfliers=False);

# %%
df.plot.area(y=['year','Country'],alpha=0.4,figsize=(12, 6));

# %% [markdown]
# That's a swimming pool.

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTjLTrCj0o2CDMtWwCoSfMdl7C03y0YDx20u5e4SuByQsHInUgz',width=400,height=400)

# %% [markdown]
# 1strategy.com

# %% [markdown]
# #Six inspiring women in computer science: Dr Amanda Prorok (Robots); Professor Cecilia Mascolo (Smartphones + digital healthcare);
#
# #Professor Ann Copestake (Computational linguistics + digital democracy); Alice Hutchings (Cybercrime); Dr Paula Buttery (Dr Paula
#
# #Buttery); Karen Spärck Jones (Established the basis of search engines) https://www.cst.cam.ac.uk/six-inspiring-women-computer-science

# %% [markdown]
# #Kaggle Women in DS: Alexis Cook (AI Educator); Jessica Li (Data Scientist); usharengaraju (Principal Data Scientist at Infinite Sum
#
# #Modelling); Anastasia Karpovich (Data Scientist at DocMatter); Parul Pandey (Data Science Evangelist at H2O.ai); Rachael Tatman (Data
#
# #Scientist at Rasa); Megan Risdal (Product Manager at Kaggle); Wendy Kan (DS), Anna Montoya (Head of Marketing), Meghan O'Connell
# #Business Development Manager), Julia Elliott (Customer Success Manager), Maggie Demkin (Customer Success), Camille McMorrow
# #(Designer), Elizabeth Park (Customer Success), Rebecca Ysteboe (Developer), Chelsea Raerek (Designer), Erica Brick (User Experience
#
# #Research), Leonie (Software Engineer at ?) And so many others that I may have forgotten (I'm so sorry).

# %% [markdown]
# Kaggle Notebook Runner: Marília Prata @mpwolke
