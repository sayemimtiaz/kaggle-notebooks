# %% [markdown]
# # Quiz - Elementary Statistics and Data Visualization
# Lab Exercises - 28th March, 2019
#
# ----------

# %%
import os
print(os.listdir("../input"))

# %% [markdown]
# Share your notebook as provided in the quiz instructions.
