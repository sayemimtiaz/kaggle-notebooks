# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#loading data
data = pd.read_csv("../input/covid-data-india-statewise/covid_data_India - Sheet1.csv")

# %%
#1 Understanding the data

# %%
data.head()

# %%
data.tail()

# %%
data.shape

# %%
data.columns

# %%
data = data.drop('Sl. No',axis = 1)
data.head()

# %%
data.nunique()

# %%
data.describe()

# %%
#2 cleaning the data

# %%
data.isnull().sum()

# %%
#3 Relationship analysis

# %%
correlation = data.corr()
correlation

# %%
sns.heatmap(correlation, xticklabels = correlation.columns, yticklabels = correlation.columns, annot = True)

# %%
sns.pairplot(data)

# %%
data.sort_values (['No.of Confirmed cases'], inplace=True, ascending=False)

# %%
df = data.head(10)
df

# %%
sns.relplot(x = 'No.of Confirmed cases', y ='No. of Deaths', hue = 'State/UT', data = df)

# %%
sns.relplot(x = 'No.of Confirmed cases', y ='Cure/Discharged/Migrated', hue = 'State/UT', data = df)

# %%
sns.displot(data['No.of Confirmed cases'])

# %%
sns.displot(data['No. of Deaths'])

# %%
sns.catplot(x = 'No.of Confirmed cases', kind = 'box', data = data)
