# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("../input/insurance/insurance.csv")

# Let's store the original dataframe in another variable.
original_df = df.copy()

# %%
df.head()

# %%
df.isnull().sum()

# %%
df.info()

# %%
df.describe()

# %%
df.columns

# %%
sns.pairplot(df)

# %%
sns.distplot(df['charges'])

# %% [markdown]
# The curve of charges is right skewed.

# %%
sns.distplot(df['age'].dropna(),kde=False,color='darkred',bins=30)

# %%
df.head()

# %%
sex = pd.get_dummies(df['sex'],drop_first=True)
smoker = pd.get_dummies(df['smoker'],drop_first=True)

# %%
df.head()

# %%
df['smoker'] = smoker

# %%
df['male'] = sex

# %%
df.head()

# %%
 df = pd.concat([df, pd.get_dummies(df['region'])], axis=1)

# %%
df.drop(['sex','region','southwest'],axis=1,inplace=True)

# %%
df.head()

# %%
sns.catplot(x="smoker", kind="count",hue = 'male', palette="pink", data=df)

# %%
sns.catplot(x="male", y="charges", hue="smoker", kind="violin", data=df, palette = 'magma')

# %%
plt.figure(figsize=(12,5))
plt.title("Box plot for charges of women")
sns.boxplot(y="smoker", x="charges", data =  df[(df.male == 0)] , orient="h", palette = 'magma')

# %%
plt.figure(figsize=(12,5))
plt.title("Box plot for charges of men")
sns.boxplot(y="smoker", x="charges", data =  df[(df.male == 1)] , orient="h", palette = 'magma')

# %%
sns.jointplot(x='age',y='charges',kind='hex',data=df,color='blue')

# %%
sns.lmplot(x='age',y='charges',data=df,hue='smoker')

# %%
sns.lmplot(x='bmi',y='charges',data=df,hue='smoker')

# %%
plt.figure(figsize=(12,5))
plt.title("Distribution of bmi")
ax = sns.distplot(df["bmi"], color = 'm')

# %%
plt.figure(figsize=(12,5))
plt.title("age")
ax = sns.distplot(df["age"], color = 'm')

# %%
plt.figure(figsize=(12,5))
plt.title("Box plot for charges with number of children")
sns.boxplot(y="charges", x="children", data =  df , orient="v", palette = 'magma')

# %%
plt.figure(figsize=(12,5))
plt.title("Box plot for charges with number of children")
sns.boxplot(y="charges", x="children", data =  df[df['smoker']==1] , orient="v", palette = 'magma')

# %%
plt.figure(figsize=(12,5))
plt.title("Box plot for charges with number of children")
sns.boxplot(y="charges", x="children", data =  df[df['smoker']==0] , orient="v", palette = 'magma')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score,mean_squared_error

# %%
x = df.drop(['charges'], axis = 1)
y = df.charges

x_train,x_test,y_train,y_test = train_test_split(x,y, random_state = 0)
lr = LinearRegression().fit(x_train,y_train)

y_train_pred = lr.predict(x_train)
y_test_pred = lr.predict(x_test)

print(lr.score(x_test,y_test))

# %%
X = df.drop(['charges'], axis = 1)
Y = df.charges

quad = PolynomialFeatures (degree = 2)
x_quad = quad.fit_transform(X)

X_train,X_test,Y_train,Y_test = train_test_split(x_quad,Y, random_state = 0)

plr = LinearRegression().fit(X_train,Y_train)

Y_train_pred = plr.predict(X_train)
Y_test_pred = plr.predict(X_test)

print(plr.score(X_test,Y_test))

# %%
print('MSE train data: %.3f, MSE test data: %.3f' % (
mean_squared_error(y_train,Y_train_pred),
mean_squared_error(y_test,Y_test_pred)))
print('R2 train data: %.3f, R2 test data: %.3f' % (
r2_score(y_train,Y_train_pred),
r2_score(y_test,Y_test_pred)))
