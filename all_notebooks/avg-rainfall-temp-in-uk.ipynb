# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#loading data
data = pd.read_csv("../input/average-rainfall-and-temperature-in-uk20102019/avg_rainfalltemp in UK - Sheet1.csv")

# %%
#1 Understanding the data

# %%
data.head()

# %%
data.tail()

# %%
data.shape

# %%
data.columns

# %%
data.nunique()

# %%
data.isnull().sum()

# %%
data.describe()

# %%
#3 Relationship analysis

# %%
correlation = data.corr()

# %%
sns.heatmap(correlation, xticklabels = correlation.columns, yticklabels = correlation.columns, annot = True)

# %%
sns.pairplot(data)

# %%
sns.relplot(x = 'Avg rainfall(in mm)', y ='Period', hue = 'Type of period', data = data)

# %%
sns.relplot(x = 'Avg temp(in centigrade)', y ='Period', hue = 'Type of period', data = data)

# %%
sns.histplot(data['Avg temp(in centigrade)'])

# %%
sns.histplot(data['Avg rainfall(in mm)'])

# %%
sns.catplot(x = 'Avg temp(in centigrade)', kind = 'box', data = data)

# %%
sns.catplot(x = 'Avg rainfall(in mm)', kind = 'box', data = data)
