# %% [markdown]
# * In this notebook, we observe the data about popular programming languages.
# * If you like, please feel free to upvote.
#
# # Data Source
# * [Most Popular Programming Languages Since 2004](https://www.kaggle.com/muhammadkhalid/most-popular-programming-languages-since-2004)

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
# !pip install bar_chart_race
import numpy as np
import pandas as pd
from IPython.display import HTML,display
import bar_chart_race as bcr
import plotly.express as px
import plotly.graph_objects as go

# %%
popular_lang= pd.read_csv('../input/most-popular-programming-languages-since-2004/Most Popular Programming Languages from 2004 to 2020 V3.csv')

# %% [markdown]
# # Programming Languages

# %% [markdown]
# * There are many programming languages and each language has own characteristics and strengths.
# * Then, how many languages does this data contain?

# %%
popular_lang.columns[1:]

# %% [markdown]
# # Popular Languages (December 2020)

# %% [markdown]
# * What is the most popular language now?

# %%
popular_lang.tail(1).T.drop(['Date'])[197].values

# %%
popular = pd.DataFrame({"Languages":popular_lang.tail(1).T.drop(['Date']).index,"Popularity":popular_lang.tail(1).T.drop(['Date'])[197].values})

# %%
popular

# %%
fig = px.pie(popular, values='Popularity', names='Languages',
             title='Popular Programming Languages')
fig.update_traces(textposition='inside',textinfo='percent+label')
fig.show()

# %% [markdown]
# # Animated bar chart race

# %% [markdown]
# * We look at the data more closely by making a animated bar chart.

# %%
popular_lang = popular_lang.set_index("Date")

# %%
bcr.bar_chart_race(df=popular_lang, n_bars=10,figsize=(10, 2),filter_column_colors=True)
