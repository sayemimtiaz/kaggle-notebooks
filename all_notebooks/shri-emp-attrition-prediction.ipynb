# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("/kaggle/input/employee-attrition/HR-Employee-Attrition.csv")

# %%
df.head()

# %%
df.dtypes.value_counts()

# %%
df.dtypes

# %%
df.shape

# %%
df.isna().sum()

# %%
#age ranges b/w 18 till 60 with total of 43 different inputs.
#min 18 max 60
df["Age"].unique()

# %%
sns.distplot(df['Age'], hist=False)

# %%
sns.barplot(x="Attrition", y="Age", data=df)

# %%
df["BusinessTravel"].value_counts()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='BusinessTravel',hue='Attrition', data=df)
plt.title("Attrition With BusinessTravel")
plt.show()

# %%
#Department
df['Department'].value_counts()

# %%
# Department / Attrition
plt.figure(figsize=(8,5))
sns.countplot(x='Department',hue='Attrition', data=df)
plt.title("Attrition With Department")
plt.show()

# %%
#EducationField
df['EducationField'].value_counts()

# %%
# Department wrt Attrition
plt.figure(figsize=(10,8))
sns.countplot(x='EducationField',hue='Attrition', data=df)
plt.title("Attrition w.r.t EducationField")
plt.xticks(rotation=90)
plt.show()

# %%
#Gender
df['Gender'].value_counts()

# %%
# most male of female employes Attriate
# Department wrt Attrition
plt.figure(figsize=(7,5))
sns.countplot(x='Gender',hue='Attrition', data=df)
plt.title("Gender with Attrition")
plt.show()

# %%
# Department wrt Attrition
plt.figure(figsize=(7,5))
sns.countplot(x='Gender',hue='MaritalStatus', data=df)
plt.title("Marital Stats")
plt.show()

# %%
#JobRole
df['JobRole'].nunique()

# %%
# JobRole
plt.figure(figsize=(8,5))
sns.countplot(x='JobRole',hue='Attrition', data=df)
plt.title("JobRole with Attrition")
plt.xticks(rotation=90)
plt.show()

# %%
#OverTime
df['OverTime'].value_counts()

# %%
plt.figure(figsize=(7,5))
sns.countplot(x='OverTime',hue='Attrition', data=df)
plt.title("OverTime with Attrition")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.countplot(x=df['Education'], hue='Attrition', data=df)
plt.title("Education with Attrition")
plt.show()

# %%
##EnvironmentSatisfaction
df["EnvironmentSatisfaction"].value_counts()

# %%
#JobInvolvement
df['JobInvolvement'].value_counts()

# %%
#MonthlyIncome
sns.distplot(df['MonthlyIncome'],hist=False)
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.boxplot(df['MonthlyIncome'])
plt.show()

# %%
df.groupby('Age')['EmployeeCount'].sum().sort_values(ascending=False).head()

# %%
df['JobLevel'].value_counts()

# %%
#job level 1 contriubutes to the most attrition
sns.countplot(x='JobLevel',hue='Attrition',data=df)
plt.show()

# %%
df['StockOptionLevel'].value_counts()

# %%
df.groupby('StockOptionLevel')['JobLevel'].sum().sort_values(ascending=False).head()

# %%
sns.countplot(x='JobLevel',hue='StockOptionLevel',data=df)
plt.show()

# %%
sns.countplot(x='JobLevel',hue='BusinessTravel',data=df)
plt.show()

# %%
sns.countplot(x='JobLevel',hue='JobInvolvement',data=df)
plt.show()

# %%
#standard hours is the same for all, so dropping this off
df["StandardHours"].value_counts()

# %%
df.shape

# %%
#this has the same value for all, dropping this off
df["EmployeeCount"].value_counts()

# %%
#EmployeeNumber is unique SID 
df["EmployeeNumber"].unique()

# %%
df.drop(['EmployeeCount','EmployeeNumber','StandardHours'],axis=1, inplace=True)

# %%
df[:2]

# %%
# Target Variable(Attrition)
df['Attrition'] = df['Attrition'].replace({'No':0,'Yes':1})

# %%
df["Attrition"].value_counts()

# %%
#encode binary variables
df['OverTime'] = df['OverTime'].replace({'No':0,'Yes':1})
df['Gender'] = df['Gender'].replace({'Male':0,'Female':1})

# %%
df['OverTime'].value_counts()

# %%
df['Gender'].value_counts()

# %%
df["Over18"].value_counts()
df.drop('Over18',axis=1,inplace=True)

# %%
df[:4]

# %%
pd.set_option ('display.max_columns', None)

# %%
df["Gender"].value_counts()

# %%
df_number_columns = df.select_dtypes(include=np.number).columns
df_number_columns

# %%
df_category_columns = df.select_dtypes(exclude=np.number).columns
df_category_columns

# %%
data_to_encode = df[df_category_columns]
data_to_encode

# %%
data_encoded = pd.get_dummies(data_to_encode, drop_first = True)

data_encoded.shape

# %%
data_encoded.info()

# %%
df[:3]

# %%
df[df_number_columns][:3]

# %%
data_encoded[:3]

# %%
final_df = pd.concat([df[df_number_columns], data_encoded], axis = 1) 
final_df

# %%
x = final_df.drop('Attrition',axis=1)
y = final_df['Attrition']

# %%
y

# %%
x.head()

# %%
from sklearn.preprocessing import MinMaxScaler

min_max = MinMaxScaler()

x_scaled = min_max.fit(x).transform(x)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report

x_train_scaled,x_test_scaled,y_train_scaled,y_test_scaled = train_test_split(x_scaled,y,test_size=0.30,random_state=42)

# %%
print("training shape: ",x_train_scaled.shape)
print("testing shape: ",x_test_scaled.shape)

# %%
# log reg
model = LogisticRegression()
model.fit(x_train_scaled, y_train_scaled)

# %%
train_pred = model.predict(x_train_scaled)
test_pred = model.predict(x_test_scaled)

# %%
def metric_score(actual, pred):
    print('confusion matrix: ', confusion_matrix(actual, pred))
    print('accuracy score: ', accuracy_score(actual, pred))
    print('roc auc score: ', roc_auc_score(actual, pred))
    print('classification report : ', classification_report(actual, pred))

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score
from sklearn.metrics import plot_roc_curve
from sklearn import metrics
metric_score(y_train_scaled, train_pred)

# %%
metric_score(y_test_scaled, test_pred)

# %%
from sklearn.neighbors import KNeighborsClassifier  
KNN = KNeighborsClassifier(n_neighbors = 5, metric = 'manhattan', weights = 'uniform', n_jobs = -1)
KNN.fit(x_train_scaled, y_train_scaled)
predict_test = KNN.predict(x_test_scaled)
predict_train = KNN.predict(x_train_scaled)
predict_train

# %%
metric_score(y_train_scaled, predict_train)

# %%
metric_score(y_test_scaled, predict_test)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.model_selection import cross_val_score, train_test_split

# %%
#x_train_scaled,x_test_scaled,y_train_scaled,y_test_scaled = train_test_split(x_scaled,y,test_size=0.30,random_state=42)

clf = GaussianNB()
clf.fit(x_train_scaled, y_train_scaled)
target_pred = clf.predict(x_test_scaled)
train_pred = clf.predict(x_train_scaled)

# %%
accuracy_score(y_test_scaled, target_pred)

# %%
accuracy_score(y_train_scaled, train_pred)

# %%
df.groupby(['JobLevel','StockOptionLevel'])['Attrition'].value_counts()

# %%
from imblearn.combine import SMOTETomek
