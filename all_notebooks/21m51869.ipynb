# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

selected_country = 'Brazil'

df1 = pd.read_csv("../input/covid19-global-dataset/worldometer_coronavirus_daily_data.csv", header=0)
df1 = df1[df1['country']==selected_country]
df2 = pd.read_csv("../input/covid-world-vaccination-progress/country_vaccinations.csv", header=0)
df2 = df2[df2['country']==selected_country]
df1.index = pd.to_datetime(df1['date'])
df2.index = pd.to_datetime(df2['date'])

# %%
print(np.unique(df1['country']))
print(np.unique(df2['country']))

# %%
fig,ax = plt.subplots(figsize=(10,5))
ax.plot(df1.index, df1['daily_new_cases'])
ax1 = ax.twinx()
ax1.plot(df2.index, df2['daily_vaccinations'],'r')
plt.show()

# %%
from plotly.offline import iplot
import plotly.graph_objs as go

daily_new_cases = go.Scatter(x=df1.index,y=df1['daily_new_cases'],yaxis='y1', name='Daily confirmed cases')
daily_vaccinations = go.Scatter(x=df2.index,y=df2['daily_vaccinations'],yaxis='y2', name='Daily Vaccinations')

layout_obj = go.Layout(title='COVID vs. Vaccines',xaxis=dict(title='Date'),yaxis=dict(title='Daily cases'),yaxis2=dict(title='Vaccinations', side='right', overlaying='y'))
fig = go.Figure(data=[daily_new_cases,daily_vaccinations],layout=layout_obj)
iplot(fig)

# %%
df1 = pd.read_csv("../input/covid19-global-dataset/worldometer_coronavirus_daily_data.csv", header=0)
df1 = df1.groupby('country').sum()['daily_new_cases'].sort_values(ascending=False)[0:10]
print(df1)
df2 = pd.read_csv("../input/covid-world-vaccination-progress/country_vaccinations.csv", header=0)
df2 = df2.groupby('country').max()['people_fully_vaccinated_per_hundred'].sort_values(ascending=False)
print(df2.to_string())

# %% [markdown]
# The country I chose is Brazil. And the ranking of total number of cases of Brazil is the third place in the world. And the people who fully vaccinated per hundred rate of Brazil is only 8.34, which is ralatively low with regard to the third place of total number of cases. However, from the diagram we can see that the vaccination is keep increasing since 2021.3.
#
# And the daily COVID-19 cases is still increasing, especially under the current circumstance which several kinds of Mutated virus was found. And the death curve has been falling as more of its population is vaccinated, while Brazil still suffers from a lack of vaccines.
#
# Brazil’s ability to combat the deadly virus is hampered by extreme political and social polarization. At the same time that many governors and mayors have imposed protective restrictions on economic activities, President Jair Bolsonaro claims that the real threat comes from the economic disruption that the pandemic can cause. He has mocked the efficacy of vaccines and ignored the use of masks when appearing in several large public events. And he is not alone. Throughout Brazil’s major cities, “it is easy to find maskless crowds walking the streets, conversing in close quarters.”
#
# references:https://www.theregreview.org/2021/05/24/guerra-filho-risk-regulation-brazil-battle-against-covid-19/
