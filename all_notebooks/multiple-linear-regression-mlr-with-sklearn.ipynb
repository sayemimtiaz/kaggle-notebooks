# %% [markdown]
# ## Machine Learning Algorithm - Regression(MLR)

# %% [markdown]
# #### 1 - Importing the libraries

# %%
import numpy as np 
import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
        
       
    import matplotlib.pyplot as plt
    import seaborn as sns
    
    import sklearn
    
    from sklearn.linear_model import LinearRegression
    from sklearn.model_selection import train_test_split
    from sklearn.metrics import r2_score

# %% [markdown]
# #### 2 - Importing the dataset

# %%
dataset = pd.read_csv('/kaggle/input/50-startups/50_Startups.csv')

# %%
type(dataset)

# %%
len(dataset)

# %%
dataset.shape

# %%
dataset.ndim

# %%
dataset.head()

# %%
dataset.tail()

# %%
dataset.iloc[31:36]

# %%
dataset.sample(3)

# %% [markdown]
# #### 3 - EDA

# %%
dataset.info()

# %%
dataset.describe()

# %%
dataset.columns

# %%
dataset['Profit'].max()

# %%
dataset['Profit'].min()

# %%
dataset.sort_values(by="Profit").tail()

# %%
dataset.loc[:, ["R&D Spend", "Marketing Spend"]].head()

# %%
dataset.isnull().sum()

# %%
# To drop any rows that have missing data.
# dataset.dropna(how="any")

# %%
dataset.groupby("State").sum()

# %%
dataset.groupby("State").count()

# %%
dataset.groupby("State").count()

# %%
dataset.groupby("State").size()

# %%
sns.countplot(x="State", data=dataset)
plt.show()

# %%
# sns.regplot( data=dataset, x="Administration", y="Profit")
# plt.show()

# %%
# sns.lmplot( data=dataset, x="Marketing Spend", y="Profit")
# plt.show()

# %%
sns.scatterplot(data=dataset, x="State", y="Profit")
plt.show()

# %%
sns.distplot(dataset['R&D Spend'], color='red')
plt.show()

# %%
sns.distplot(dataset['Administration'], color='green')
plt.show()

# %%
sns.distplot(dataset['Marketing Spend'], color='blue')
plt.show()

# %%
dataset.head()

# %%
# Encoding Catagorical data

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
state=pd.get_dummies(dataset['State'], drop_first=True)

# %%
state.head()

# %%
dataset = pd.concat([state, dataset], axis=1)

# %%
dataset.head()

# %%
dataset.drop(['State'], axis=1, inplace=True)

# %%
dataset.head()

# %%
X = dataset.iloc[:, :-1].values  # features 
y = dataset.iloc[:, -1].values   # target

# %%
type(X)

# %%
type(y)

# %%
X.shape

# %%
X.ndim

# %%
y.shape

# %%
y.ndim

# %%
X[:3, :]

# %%
np.set_printoptions(precision=2, suppress=True)
# suppress : bool, optional
#     If True, always print floating point numbers using fixed point
#     notation, in which case numbers equal to zero in the current precision
#     will print as zero.  If False, then scientific notation is used when
#     absolute value of the smallest number is < 1e-4 or the ratio of the
#     maximum absolute value to the minimum is > 1e3. The default is False.

# %%
np.array(4372.56921)  # Example

# %%
X[: 3,: ]

# %%
y

# %% [markdown]
# #### 4- Spliting tThe dataset innto Taining Set and Test Set

# %%
# from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# #### 5 - Train the Multiple Linear Regression Model on the Training set

# %%
# from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression().fit(X_train, y_train)

# %% [markdown]
# #### 6- Predicting the Testing Result

# %%
y_pred = model.predict(X_test)

# %%
y_pred

# %%
# Comparing the predicted_Profit with actual Profit
# -------------------------------------------------


np.concatenate(( y_pred.reshape(len(y_pred), 1), y_test.reshape(len(y_test), 1) ), axis=1)

# %%
for p1, p2 in np.nditer((y_test, y_pred)):
    print(f"[{p2}], [{p1}]")

# %%
# Evaluate the test & train score performance

# %%
model.score(X_test, y_test)

# %%
model.score(X_train, y_train)

# %%
# from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)

# %%
model.coef_

# %%
model.intercept_

# %%
# Index(['Florida', 'New York', 'R&D Spend', 'Administration', 'Marketing Spend',

# %%
# Y = b0 + b1X1 + b2X2 + ... bnXn  + e           # MLR

# %%
# Y = b0 + b1X1 + b2X2 + b3X3 + b4X4 + b5X5 + e   # MLR

# %% [markdown]
# ## Question 1:¶

# %% [markdown]
# #### How do I use my multiple linear regression model to make a single prediction, for example, the profit of a startup with R&D Spend = 160000, Administration Spend = 130000, Marketing Spend = 300000 and State = California?

# %%
print(model.predict([[0, 0, 160000, 130000, 300000]]))

# %%
# 0, 0, 160000, 130000, 300000     --> scalars
# [0, 0, 160000, 130000, 300000]   --> 1D array
# [[0, 0, 160000, 130000, 300000]] --> 2D array

# %% [markdown]
# ##### Important Note : Notice also that the "California" state was not input as a string in the last column but as "0, 0" in the first two columns. That's because of course the predict method expects the one-hot-encoded (categorical) values of the state, and as we see in the second row of the matrix of features X, "California" was encoded as "0, 0". And be careful to include these values in the first two columns, not the last two ones, because the dummy variables are always created in the first columns.

# %% [markdown]
# ## Question 2:

# %% [markdown]
# #### How do I get the final regression equation y = b0 + b1 x1 + b2 x2 + ... with the final values of the coefficients?

# %%
model.coef_

# %%
model.intercept_

# %% [markdown]
# ### Equation of MLR:

# %%
# Y = b0 + b1X1 + b2X2 + b3X3 + b4X4 + b5X5

# %%
Profit = 42554.168 + -959.28416006 * 0 + 699.36905251 * 0 + 0.77346719 * 160000 + 0.0328846 * 130000 + 0.03661003 * 300000

# %%
Profit
