# %%
import pandas as pd
df = pd.read_csv('../input/solar-power-generation-data/Plant_1_Weather_Sensor_Data.csv')
df.head()

# %%
df.nunique()

# %%
df.info()

# %%
df['DATE_TIME'] = pd.to_datetime(df['DATE_TIME'],format = '%Y-%m-%d %H:%M')

# %%
df['DATE'] = pd.to_datetime(df['DATE_TIME'],format = '%Y-%m-%d %H:%M').dt.date

# %%
df['DATE'] = pd.to_datetime(df['DATE'])

# %%
df.info()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10)) # To increase the size of the graph
plt.plot(df['DATE_TIME'],df['AMBIENT_TEMPERATURE'],label = 'Ambient')
plt.legend()
plt.grid()
plt.margins(0.05)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10)) # To increase the size of the graph
plt.plot(df['DATE_TIME'],df['MODULE_TEMPERATURE'],label = 'Module')
plt.legend()
plt.grid()
plt.margins(0.05)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10)) # To increase the size of the graph
plt.plot(df['DATE_TIME'],df['MODULE_TEMPERATURE']-df['AMBIENT_TEMPERATURE'],label = 'Difference')
plt.legend()
plt.grid()
plt.margins(0.05)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10)) # To increase the size of the graph
plt.plot(df['DATE_TIME'],df['AMBIENT_TEMPERATURE'],label = 'Ambient')
plt.plot(df['DATE_TIME'],df['MODULE_TEMPERATURE'],label = 'Module')
plt.plot(df['DATE_TIME'],df['MODULE_TEMPERATURE']-df['AMBIENT_TEMPERATURE'],label = 'Difference')
plt.legend()
plt.grid()
plt.margins(0.05)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10)) # To increase the size of the graph
plt.plot(df['DATE_TIME'],df['AMBIENT_TEMPERATURE'].rolling(window=20).mean(),label = 'Ambient')
plt.plot(df['DATE_TIME'],df['MODULE_TEMPERATURE'].rolling(window=20).mean(),label = 'Module')
plt.plot(df['DATE_TIME'],(df['MODULE_TEMPERATURE']-df['AMBIENT_TEMPERATURE']).rolling(window=20).mean(),label = 'Difference')
plt.legend()
plt.grid()
plt.margins(0.05)
plt.show()

# %%
#dataframe.rolling

# %%
# Scatter plot
import numpy as np
a = np.random.randint(1,1000,500)
b = np.random.randint(1,100,500)

# %%
#plt.scatter(a,b)
plt.plot(a,b,marker='o',linestyle='')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.scatter(df['AMBIENT_TEMPERATURE'],df['MODULE_TEMPERATURE'],s = 50,label='Temperature Graph',alpha = 0.5)
plt.plot()
plt.legend()
plt.grid()
plt.margins(0.05)
plt.show()

# %%
plt.legend?

# %%
plt.figure(figsize=(20,10))
plt.plot(df['AMBIENT_TEMPERATURE'],df['MODULE_TEMPERATURE'],ms = 10,label='Temperature Graph',
         alpha = 0.5,marker='o',linestyle='')
plt.plot()
plt.legend()
plt.grid()
plt.margins(0.05)
plt.show()

# %%
a = np.random.randint(0,300,len(df['AMBIENT_TEMPERATURE']))
plt.figure(figsize=(20,10))
plt.scatter(df['AMBIENT_TEMPERATURE'],df['MODULE_TEMPERATURE'],s =a,label='Temperature Graph',alpha = 0.5)
plt.plot()
plt.legend()
plt.grid()
plt.margins(0.05)
plt.show()

# Try for increasing sizes of bubbles for increasing of temperature

# %%
# IRRADIATION
# > 0 -Daytime
# == 0 - NightTime

# %%
df['DATE']=='2020-05-15'

# %%
dates = df['DATE'].unique()
dates

# %%
df[df['DATE']==dates[0]] # I want all the other values for this specific date

# %%
df[df['DATE']==dates[0]][df['IRRADIATION']>0] # The Dataframe for the first date where IRRADIATION IS >0

# %%
data = df[df['DATE']==dates[0]][df['IRRADIATION']>0]
plt.plot(data['AMBIENT_TEMPERATURE'],data['MODULE_TEMPERATURE'],marker='o',linestyle='',
        label=pd.to_datetime(dates[0],format='%Y-%m-%d').date())
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,10))
for date in dates:
    data = df[df['DATE']==date][df['IRRADIATION']>0]
              
    plt.plot(data['AMBIENT_TEMPERATURE'],data['MODULE_TEMPERATURE'],marker='o',linestyle='',
        label=pd.to_datetime(date,format='%Y-%m-%d').date())
plt.legend()
plt.show()

# %%
df.columns

# %%
plt.figure(figsize=(20,10))
plt.plot(df['IRRADIATION'],df['MODULE_TEMPERATURE'],ms=10,marker='o',linestyle='',alpha=0.5,label='Module Temp')
plt.legend()

# %%
data = df[df['IRRADIATION']>0.1]
plt.figure(figsize=(20,10))
plt.plot(data['IRRADIATION'],data['MODULE_TEMPERATURE']-data['AMBIENT_TEMPERATURE'],marker='o',linestyle='',alpha=0.5,label='Difference Temp')
plt.legend()
plt.ylabel('Temperature Difference')
plt.xlabel('Irradiation')

# %%
df.info()

# %%
df_gen = pd.read_csv('../input/solar-power-generation-data/Plant_1_Generation_Data.csv')
df_gen['DATE_TIME'] = pd.to_datetime(df_gen['DATE_TIME'],format='%d-%m-%Y %H:%M')
df_gen['DATE'] = pd.to_datetime(df_gen['DATE_TIME'],format='%d-%m-%Y %H:%M').dt.date
df_gen['DATE'] = pd.to_datetime(df_gen['DATE'])
df_gen.info()

# %%
inv_lst = df_gen['SOURCE_KEY'].unique()
inv_lst

# %%
df_gen.groupby('SOURCE_KEY')['TOTAL_YIELD'].max()

# %%
plt.figure(figsize=(20,10))
plt.bar(inv_lst,df_gen.groupby('SOURCE_KEY')['TOTAL_YIELD'].max())
plt.xticks(rotation=90)
plt.grid()

# %% [markdown]
# # **Assignment : Put the respective numbers on top of every bar**
#
#
# Hint: Annotate or Text

# %%
df_gen.info()

# %%
df.info()

# %%
r_left = pd.merge(df_gen,df,on='DATE_TIME',how='left')
r_left

# %%
r_left.info()

# %%
# LEFT MERGE
# 2 DataFrames
# MERGED DATAFRAME = LEFT+ RIGHT
# Left Side - df_gen :68778 rows, 8 columns
# Right Side - df : 3182, 7 columns
# Output: 68778 rows - 14(15-1)columns

# %%
r_left.isnull().sum()

# %%
r_left['AMBIENT_TEMPERATURE'].isnull().value_counts()

# %%
null_data1 = r_left[r_left.isnull().any(axis=1)]
null_data1

# %%
# Sensor was down at this specific time stamp

# %%
# RIGHT MERGE
# 2 DataFrames
# MERGED DATAFRAME = LEFT+ RIGHT
# Left Side - df_gen :68778 rows, 8 columns
# Right Side - df : 3182, 7 columns
# Output: 68778 rows - 14(15-1)columns

# %%
plt.figure(figsize=(20,10))
plt.plot(r_left['IRRADIATION'],r_left['DC_POWER'],marker='o',linestyle='',alpha=0.5,label='DC Power')
plt.legend()

plt.xlabel('Irradiation')
plt.ylabel('DC Power')

# %%
plt.figure(figsize=(20,10))
plt.plot(r_left['MODULE_TEMPERATURE'],r_left['DC_POWER'],marker='o',linestyle='',alpha=0.5,label='DC Power')
plt.legend()

plt.xlabel('Module temperature')
plt.ylabel('DC Power')

# %%
dates = r_left['DATE_x'].unique()
dates

# %%
r_left[r_left['DATE_x']==dates[0]][r_left['IRRADIATION']>0.1]

# %%
data = r_left[r_left['DATE_x']==dates[1]][r_left['IRRADIATION']>0.1]
plt.plot(data['MODULE_TEMPERATURE'],data['DC_POWER'],marker='o',linestyle='',
         label = pd.to_datetime(dates[1],format='%Y-%m-%d').date())
plt.legend()
print(dates[1])

# %%
# For all 34 dates
plt.figure(figsize=(20,10))
for date in dates:
    data = r_left[r_left['DATE_x']==date][r_left['IRRADIATION']>0.1]
    plt.plot(data['MODULE_TEMPERATURE'],data['DC_POWER'],marker='o',linestyle='',
             label = pd.to_datetime(date,format='%Y-%m-%d').date())
plt.legend()
plt.grid()
plt.xlabel('Module Temperature')
plt.ylabel('DC Power')
plt.title('MODULE TEMPERATURE VS DC POWER')
plt.show()

# %%
# Inverters
plt.figure(figsize=(20,10))
date = dates[4]  # One specifi date
inverters = r_left['SOURCE_KEY_x'].unique()
print(inverters)
for inverter in inverters:
    data = data = r_left[r_left['DATE_x']==date][r_left['SOURCE_KEY_x']==inverter]
    plt.scatter(data['MODULE_TEMPERATURE'],data['DC_POWER'],label=inverter)
plt.legend()

# %%
# df_gen summary data

# %%
data_summary = df_gen.groupby(['SOURCE_KEY','DATE']).agg(READINGS = ('TOTAL_YIELD','count'),
                                                         INV = ('SOURCE_KEY',max),
                                                        DATE = ('DATE',max))
data_summary

# %%
# Total readings from an inverter :
4*24

# %%
plt.scatter(data_summary['DATE'],data_summary['READINGS'])
plt.xticks(rotation=90)

# %%
plt.figure(figsize=(12,8))
for inv in data_summary['INV'].unique():
    plt.scatter(data_summary[data_summary['INV']==inv]['DATE'],
            data_summary[data_summary['INV']==inv]['READINGS'],label=inv,s = 80)
plt.legend()
plt.title('Readings vs Date')
plt.xlabel('Date')
plt.ylabel('Number of Readings')
plt.show()

# %%
r_left.info()

# %%
# Linear Regression
# Input(x) - Independent Variable [Irradiation] 12    
# Output(y) - Dependent Variable [Dc Power] 3

#NOTE: Sklearn library accepts inputs only in 2 DImension

# %%
# FIlling Irradiation column with 0 for null values
r_left['IRRADIATION'] = r_left['IRRADIATION'].fillna(0) 
r_left['AMBIENT_TEMPERATURE'] = r_left['AMBIENT_TEMPERATURE'].fillna(0) 
r_left['MODULE_TEMPERATURE'] = r_left['MODULE_TEMPERATURE'].fillna(0) 
r_left.info()

# %%
#x = r_left.iloc[:,[12]].values
x = r_left.iloc[:,12:13].values
x.ndim

# %%
y = r_left.iloc[:,3].values
y

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,s=1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape

# %%
x_test.shape

# %%
55022+13756

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train,y_train)

# %%
y_pred = model.predict(x_test)
y_pred

# %%
y_test

# %%
# Visualization of Best Fit Line
# Training Data
plt.scatter(x_train,y_train,s=1)
plt.scatter(x_train,model.predict(x_train),s=1)
plt.show()

# %%
# Testing Data
plt.scatter(x_test,y_test,s=1)
plt.scatter(x_test,model.predict(x_test),s=1)
plt.show()

# %%
model.predict([[0.6]])

# %%
# Plotting for Predicted vs Real Output in the test data
plt.scatter(y_pred,y_test,s=1)

# %%
df1 = pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
df2 = df1.head(10)

# %%
df2.plot(figsize=(20,8))

# %%
# Research
import seaborn as sns
sns.regplot(x='Actual',y='Predicted',data=df1)
plt.show()

# %%
sns.regplot?

# %%
from sklearn.metrics import r2_score,mean_squared_error
print(mean_squared_error(y_pred,y_test))

# %%
import numpy as np
MSE = np.square(np.subtract(y_pred,y_test)).mean()
MSE

# %%
r2_score(y_pred,y_test)

# %%
x1 = r_left.iloc[:,11:12].values
y1 = r_left.iloc[:,4].values
plt.scatter(x1,y1,s=1)

# %%
from sklearn.model_selection import train_test_split
x1_train,x1_test,y1_train,y1_test = train_test_split(x1,y1,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x1_train,y1_train)
y_pred = model.predict(x1_test)

# %%
# Testing Data
plt.scatter(x1_test,y1_test,s=1)
plt.scatter(x1_test,model.predict(x1_test),s=1)
plt.xlabel('Ambient Temperature')
plt.ylabel('AC Power')
plt.show()

# %%
model.predict([[30]])

# %%
import pickle
pickle.dump(model, open('model.pkl','wb'))

# %%
# !pip install streamlit
# !pip install pyngrok

# %%
# %%writefile app1.py
import streamlit as st
import pickle

st.title("Temperature vs AC Power")
st.subheader('Prediction')
st.write('This project is based on Linear Regression')

model = pickle.load(open('model.pkl', 'rb'))
temp = st.number_input('Enter temperature')
op = model.predict([[temp]])
if st.button("Predict"):
  st.title(f'The AC Power is {op}')

# %%
from pyngrok import ngrok
public_url = ngrok.connect(port='8501')
print(public_url)

# %%
# !streamlit run app1.py

# %%
# Forecasting - Predict the future based on Past events

# %%
df.info()

# %%
day_summary = df.groupby('DATE').agg(TOTAL_IRRADIANCE=('IRRADIATION',sum),DATE=('DATE',max))
day_summary

# %%
day_summary = day_summary.rename(columns={'DATE':'ds','TOTAL_IRRADIANCE':'y'})
day_summary.info()

# %%
import fbprophet
op = fbprophet.Prophet(changepoint_prior_scale=0.25)
op.fit(day_summary)

# %%
# Make a future possible prediction (df) for 1 month
forecast = op.make_future_dataframe(periods = 30,freq='D')
forecast = op.predict(forecast)

# %%
op.plot(forecast,xlabel='Date',ylabel='Irradiation')
plt.title('Irradiation Prediction');

# %%
forecast['ds'].value_counts()

# %%
df_new = df[['DATE_TIME','IRRADIATION']]

# %%
df_new

# %%
df_new = df_new.rename(columns={'DATE_TIME':'ds','IRRADIATION':'y'})
df_new

# %%
import fbprophet
op = fbprophet.Prophet(changepoint_prior_scale=0.25)
op.fit(df_new)

# %%
# Make a future possible prediction (df) for H Hours
forecast = op.make_future_dataframe(periods = 300,freq='H')
forecast = op.predict(forecast)

# %%
op.plot(forecast,xlabel='Date',ylabel='Irradiation')
plt.title('Irradiation Prediction');

# %%
op.plot_components(forecast);

# %%
forecast

# %%
r_left.info()

# %%
# correlation matrix
cor = r_left.drop(['PLANT_ID_x','PLANT_ID_y'],axis=1)
cor = cor.corr()
cor

# %%
# plotting correlations on a heatmap

# figure size
plt.figure(figsize=(8,4))

# heatmap
sns.heatmap(cor, cmap="YlGnBu", annot=True)
plt.show()

# %%
# Clustering daily yield in different clusters

# %%
plt.scatter(r_left['AMBIENT_TEMPERATURE'],r_left['DAILY_YIELD'],s=0.1)

# %%
plt.scatter(r_left['TOTAL_YIELD'],r_left['DAILY_YIELD'],s=0.1)

# %% [markdown]
# **FLASK APP**

# %%
import pickle
pickle.dump(model, open('model.pkl','wb'))

# %%
# !pip install flask-ngrok

# %%
from flask_ngrok import run_with_ngrok
from flask import Flask,jsonify
import numpy as np
import pickle
app = Flask(_name_)
run_with_ngrok(app) 

model = pickle.load(open('model.pkl', 'rb'))

@app.route('/')
def home():
  return 'Hi. Welcome to the ML Model'

@app.route("/<float:x>")
def ml(x):
    arr = np.array([x])
    result = model.predict([arr]).tolist()
    return jsonify(result)
app.run()
