# %% [markdown]
# # How good is drug against Corona Virus? And when its not?
#
# *<font size=3 color="#616A6B"> "Researchers and companies are trying not to rush into widespread use of any particular drug without first making sure the benefits outweigh any potential risks. Yet the urgency of the coronavirus threat has prompted some doctors to repurpose medicines"</font>* ~ Brianna Abbott, Wall Street Journal
#
# ### Introduction
# In the recent corona virus outbreak around the world, many researches search for a drug to the virus. Every now and then an article is published offering a new trial experiment done to threat corona virus.
# As known today, the researchers doesn’t agree on one drug that is the best to threat corona virus. Even if there was an agreement in the scientific community, when does the drug fails?
#
# As stated above, in order to globally market a drug, it has to be very efficient in dealing with the corona virus. It is known that in the personalized medicine world, one drug will not affect the same on different people.
#
# ### About the Notebook
# Thus, in this notebook I will present efficient and fast method for searching literature, articles, medical reports, and rank a drug based on the sentence sentiment. Meaning, I will check if the drug was related in a positive way or a negative way.
# Further work will analyze each one of the paragraph and will automatically offer the circumstances for the chosen sentiment.
#
# ### The Method
# I used to this end the idea presented in Fine-grained Sentiment Classification using BERT, including their source code published.
# The idea is to use BERT to fine tune it to solve fine-grained sentiment classification task, which is more accurate.
# BERT is very efficient in fine tuning, since it support adding just one classification layer for the specific task.
# The following figure shows the BERT architrecture. Further reading can be done [here](https://towardsdatascience.com/bert-explained-state-of-the-art-language-model-for-nlp-f8b21a9b6270?gi=e561367aa480).
# ![image.png](attachment:image.png)
#
# ### Resources
# To write this kernel I used:
# The clean data in [here](https://www.kaggle.com/xhlulu/cord-19-eda-parse-json-and-generate-clean-csv ):
#
# The drugs found in the following [analysis](https://www.kaggle.com/arpitrathi/extracting-effective-covid-19-vaccination-drugs)
#
# I have trained the model on SST dateset using the code in [here](https://github.com/munikarmanish/bert-sentiment)
#
# They didn't support new datasets for evaluation, so I changed their code, and the final version can be found in [here](sshttps://github.com/rangit3/corona-sentiment)

# %% [markdown]
# ### Results
#
# The following graph shows the sentiment counts for each drug.
# We can see that although some drugs appear to be better than others, there are substantial cases where those drugs mentioned in negative way, and further work should get insight from those references.
# I used drugs found in previous work, but any one can use my code to run on any drug.
#
# ![image.png](attachment:image.png)
