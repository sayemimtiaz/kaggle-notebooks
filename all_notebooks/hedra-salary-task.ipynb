# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Read Salaries.csv as a dataframe called sal
sal = pd.read_csv('../input/salary-task/Salaries.csv')

# %%
#Check the head of the DataFrame
sal.head()

# %%
#Use the .info() method to find out how many entries there are
sal.info()

# %%
sal.shape

# %% [markdown]
# # What is the average BasePay ?

# %%
sal['BasePay'].mean()

# %% [markdown]
# # What is the highest amount of OvertimePay in the dataset ?

# %%
sal['OvertimePay'].max()

# %% [markdown]
# # What is the job title of JOSEPH DRISCOLL ?

# %%
sal['JobTitle']

# %%
sal[sal['EmployeeName']=="JOSEPH DRISCOLL"]

# %%
#sal['JobTitle']  if [sal['EmployeeName']=='JOSEPH DRISCOLL'] == True
sal[sal['EmployeeName']=='JOSEPH DRISCOLL']['JobTitle']

# %% [markdown]
# #  How much does JOSEPH DRISCOLL make (including benefits)?

# %%
#sal['TotalPayBenefits']  if [sal['EmployeeName']=='JOSEPH DRISCOLL'] == True
sal[sal['EmployeeName']=='JOSEPH DRISCOLL']['TotalPayBenefits']

# %% [markdown]
# #  What is the name of highest paid person (including benefits)?

# %%
sal['TotalPayBenefits'].max()

# %%
sal['TotalPayBenefits'].idxmax()

# %%
i = sal['TotalPayBenefits'].idxmax()
sal.loc[i]

# %%
sal.loc[i]['EmployeeName']

# %%
#or
sal[sal['TotalPayBenefits']==sal['TotalPayBenefits'].max()]

# %% [markdown]
# # What is the name of lowest paid person (including benefits)? Do you notice something strange about how much he or she is paid?

# %%
sal[sal['TotalPayBenefits']==sal['TotalPayBenefits'].min()]

# %% [markdown]
# **we notice something strange about how much he or she is paid : that the value is negative¶
# that maybe he was borrow**

# %% [markdown]
# # What was the average (mean) BasePay of all employees per year? (2011-2014) ?

# %%
sal.groupby('Year').mean()['BasePay']

# %% [markdown]
# # How many unique job titles are there?

# %%
sal['JobTitle'].nunique()

# %%
sal.loc[2159]['EmployeeName']

# %%
sal.loc[2159]

# %%
sal.loc[2159]['JobTitle']

# %% [markdown]
# # What are the top 5 most common jobs?

# %%
sal['JobTitle'].value_counts()

# %%
sal['JobTitle'].value_counts()[0:5]

# %%
#or  [0:5]==.head()
sal['JobTitle'].value_counts().head()

# %% [markdown]
# # How many Job Titles were represented by only one person in 2013? (e.g. Job Titles with only one occurence in 2013?)

# %%
sal[sal['Year']==2013]['JobTitle'].value_counts()

# %%
(sal[sal['Year']==2013]['JobTitle'].value_counts()==1)

# %%
(sal[sal['Year']==2013]['JobTitle'].value_counts()==1).sum()

# %% [markdown]
# # How many people have the word Chief in their job title? (This is pretty tricky)

# %%
sal['JobTitle'].apply(lambda str:('chief' in str.lower()))

# %%
sal['JobTitle'].apply(lambda str:('chief' in str.lower())).sum()

# %% [markdown]
# # Bonus: Is there a correlation between length of the Job Title string and Salary?

# %%
sal['title_str_len'] = sal['JobTitle'].apply(len)

# %%
sal[['title_str_len','TotalPayBenefits']].corr()

# %% [markdown]
# # Great Job!
# ---------------------------
