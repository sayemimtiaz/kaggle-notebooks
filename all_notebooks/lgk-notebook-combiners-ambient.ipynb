# %%
import pandas as pd
import numpy as np
import plotly.express as px
df = pd.read_csv('/kaggle/input/multistage-continuousflow-manufacturing-process/continuous_factory_process.csv')
combiner = [coluna for coluna in df.columns if coluna.startswith('FirstStage')]
df = df[combiner]
df
fig = px.line(df)
fig.show()

# %% [markdown]
# * Remover outlier cominer de temp 1
# * Remover outlier cominer de temp 2
# * Temp 3 não precisa de remoção de outliers

# %%
df = pd.read_csv('/kaggle/input/multistage-continuousflow-manufacturing-process/continuous_factory_process.csv')
ambientcond = [coluna for coluna in df.columns if coluna.startswith('AmbientConditions')]
df = df[ambientcond]
df
fig = px.line(df)
fig.show()

# %% [markdown]
# * Sem outliers
# * A humidade variou um pouco mais que a temp
