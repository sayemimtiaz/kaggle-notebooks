# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        x=os.path.join(dirname, filename)
        table = pd.read_csv(x) 
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Importing the tabel

# %%
table

# %% [markdown]
# # Select a category

# %%
n=input("Select a category 1, 2, 3, 4 or q for Quit \n1)Public Specialist\n2)Public Non-Specialist\n3)Private Specialist\n4)Private Non-specialist")
if(n=='q'):
    sys.exit()
elif(n=='1'):
    category='Public Specialist'
elif(n=='2'):
    category="Public Non-Specialist"
elif(n=='3'):
    category="Private Specialist"
elif(n=='4'):
    category="Private Non-Specialist"
print("Category is \n " ,category)

# %%
table['Year'] = table['Year'].astype(int)
table

# %% [markdown]
# # Question no 2a

# %%
que2t=table[(table['Year']>2009) & (table['Year']<2016) ]
que2a=que2t[category].mean()
print("Average no of doctors rom 2006 to 2015 in selected category is ", que2a)

# %%
table=que2t.sort_values(by=category)
print(table)

# %% [markdown]
# # Question no 2b

# %%
print('The three lowest no of doctors in 2010 to 2015 are in the year\n' ,table[["Year",category ]][0:3])

# %%
table["Year Percentage Change"] = table['Year'].pct_change()
print("NEW TABLE\n",table)
pct_id=list(table[["Year Percentage Change"]].idxmax(axis=0))

# %% [markdown]
# # Question no 3

# %%
print("The highest percentage change and year it occured is \n",table[["Year Percentage Change","Year"]].iloc[pct_id[0]])

# %%
table["total"]=table.sum(axis=1)
table["total specalist"] = table[["Public Specialist" , "Private Specialist"]].sum(axis=1)
table

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Question No 4

# %%
fig = plt.figure()
ax = plt.axes()
ax.plot( table['Year'],table['total'] ,"-g",label="Total Doctor")
ax.plot(table['Year'],table['total specalist'] ,"-r" , label="Public+Private Specialist")
plt.ylabel("no of doctors")
plt.xlabel("Years")
plt.legend()
plt.title("Que 4a Line Plot")

# %%
table.columns

# %%
ind = np.arange(len( table['Year']))
plt.figure(figsize=(10,5))
width=0.3
plt.xticks(ind+width/2,table["Year"])
plt.bar(ind,table['Public Non-Specialist'] ,width,label="Public Non-Specialist")
plt.bar(width+ind , table['Private  Non-Specialist'] , width , label="Private Non-Specialist")
plt.ylabel("No of Non-Specialists")
plt.legend()
plt.title("Que 4b Bar Plot")
