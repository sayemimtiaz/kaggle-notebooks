# %%
import pandas as pd

# %%
data = pd.read_csv('/kaggle/input/preprocessed-trec-2007-public-corpus-dataset/processed_data.csv')

# %%
data.head()

# %%
data.tail()

# %%
data.shape

# %%
data.describe()

# %%
data.columns

# %%
data['label'].hist()

# %%
for i in range(10):
    print("Message: " + data.loc[i]['message'])
