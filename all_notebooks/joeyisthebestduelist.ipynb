# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
data=pd.read_csv("/kaggle/input/yugioh-trading-cards-dataset/card_data.csv")
data=data.drop_duplicates()
data.head()

# %%
data.shape

# %% [markdown]
# 6500 Yugioh Card. Joey The Passion have 400 card.

# %%
traps=data[data["Type"]=="Trap Card"]
traps[0:10]

# %% [markdown]
# Skull Dice is Trap card But  Graceful Dice is a Spell Card.

# %%
traps[10:20]

# %% [markdown]
# Yugioh is best card game ever. Syncro and XYZ etc kill this game also that much card is also horrific.

# %%
data[data["Name"].str.contains("Solem")]

# %% [markdown]
# Solemn Wishes is my Favorite card. Exodia Decks should have Solemn Wishes. Every Turn 500 LifePoints :) .
# Solemn Judgement is Bakura and Jaden Yuki Type Card. I love Solemn Series.

# %%
data[data["Name"].str.contains("Blue-Eyes")]

# %% [markdown]
# Blue Eyes Alternative White Dragon is interesting but It's hard to summon in early Yugioh cards.

# %%
data[data["Name"].str.contains("Kaiba")]

# %% [markdown]
# Blue Eyes White Dragon men. Yugioh the Abridged Series is the best.

# %% [markdown]
# Goblin Attack Force İs MY Favorite Card.

# %%
data[data["Name"].str.contains("Goblin Attack Force")]

# %% [markdown]
# Where is my Dearaset Goblin Attack Force.

# %% [markdown]
# My Second favorite Card is Slate Warrior.

# %%
data[data["Name"].str.contains("Slate")]

# %% [markdown]
# Slate Warrior Where are you?

# %% [markdown]
# Gemini ELF?

# %%
data[data["Name"].str.contains("Gemini Elf")]

# %% [markdown]
# 1900 Attack point and only 4 star.

# %% [markdown]
# What about Joey The Passion's Default Card Penguin Soldier:

# %%
data[data["Name"].str.contains("Penguin Soldier")]

# %% [markdown]
# Okay. This card list is not complete.

# %%
monstacardo=data[data["Type"].str.contains("Monst")]
monstacardo.head()

# %% [markdown]
# ### How Many 1 Sacrifice Monster in this Yugioh Dataset?

# %%
onetribute=monstacardo[(monstacardo["Level"]>=5) & (monstacardo["Level"]<7)]
len(onetribute)

# %% [markdown]
# 708 One Tribute Monster in This Dataset.

# %%
onetribute.sort_values(by="ATK",ascending=False)[0:20]

# %% [markdown]
# XYZ cards........ JawsMan is very good card but Cannot be special summoned.

# %%
onetribute.sort_values(by="ATK",ascending=False)[20:30]

# %%
onetribute.sort_values(by="ATK",ascending=False)[30:40]

# %% [markdown]
# ### What About 2 Tribute Monster?

# %%
twotribute=monstacardo[(monstacardo["Level"]>=7) & (monstacardo["Level"]<9)]
len(twotribute)

# %% [markdown]
# 553 2 sacrifice monster. Red Eyes, Black Magician, Blue Eyes this iconic monster's is in this group.

# %%
twotribute.sort_values(by="ATK",ascending=False)[0:20]

# %% [markdown]
# Valkirayon the Magna Warrior. Little Yugies card.

# %%
twotribute.sort_values(by="ATK",ascending=False)[20:30]

# %%
twotribute.sort_values(by="ATK",ascending=True)[0:20]

# %% [markdown]
# All Defensive and Effect Monster is here. İt's hard to classify.

# %%
moretribute=monstacardo[monstacardo["Level"]>=9]
len(moretribute)

# %%
moretribute[0:10]

# %%
moretribute[moretribute["Name"].str.contains("Obeli")]

# %%
moretribute[moretribute["Name"].str.contains("Sli")]

# %%
moretribute[moretribute["Name"].str.contains("The Wing")]

# %% [markdown]
# This cards is just a scam. Hard to summon and also hard to maintain. İn  Slifer Attacks points is usually 1000 or 2000.

# %%
data.sort_values(by=["ATK","DEF"],ascending=False)[0:30]

# %% [markdown]
# Master Of Oz is Chumley's Card Des Kangoraa and Big Koala Fusion. He defeat Vellian Crowler with this Monster.

# %%
data.sort_values(by=["DEF","ATK"],ascending=False)[0:10]

# %% [markdown]
# Okay Fusion Monster a still a thing in Yugioh. Cyber Stein is still usable card????

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(20,20))
sns.relplot(data=monstacardo,x="ATK",y="DEF",hue="Attribute")

# %%
plt.figure(figsize=(24,24))
sns.relplot(data=monstacardo,x="ATK",y="DEF",hue="Type")

# %%
plt.figure(figsize=(24,24))
sns.relplot(data=monstacardo,x="ATK",y="DEF",hue="Race")

# %%
plt.figure(figsize=(24,24))
sns.relplot(data=monstacardo,x="ATK",y="DEF",hue="Level")

# %% [markdown]
# Okay Last PLot has meaningful result. Hovewer it's so obvious.

# %% [markdown]
# ## Machine Learning Time

# %%
monstacardo.head()

# %%
x=monstacardo[["ATK","DEF"]]
y=monstacardo["Level"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=320)

from tpot import TPOTRegressor
tpot = TPOTRegressor(generations=1, population_size=50, verbosity=2,max_time_mins=35)
tpot.fit(x_train,y_train)
print(tpot.score(x_test, y_test))
tpot.export('tpot_result.py')

# %% [markdown]
# Work just fine.

# %%
tpot.predict([[1200,400]])

# %%
tpot.predict([[2500,1400]])

# %% [markdown]
# Summoned Skull and Cyber Tech Alligator like monster is like 1 Tribute monster.

# %%
for i in range(12,30):
    level=tpot.predict([[2500,i*100]])[0] 
    print("Defense: ",i*100,"  ",level)

# %% [markdown]
# 2500 2700 monster maybe 2 tribute monster.

# %%
from sklearn.tree import DecisionTreeRegressor
dtreg=DecisionTreeRegressor()
dtreg.fit(x_train,y_train)
print(dtreg.score(x_test, y_test))

# %%
for i in range(12,30):
    level=dtreg.predict([[2500,i*100]])[0] 
    print("Defense: ",i*100,"  ",level)

# %% [markdown]
# 2900 is goes to 3 tribute monster it is interesting. Howewer this values is not look good. Overfit is occurs. We handle this with max_depth=3

# %%
from sklearn.tree import DecisionTreeRegressor
dtregmax2=DecisionTreeRegressor(max_depth=3)
dtregmax2.fit(x_train,y_train)
print(dtregmax2.score(x_test, y_test))

for i in range(12,30):
    level=dtreg.predict([[2500,i*100]])[0] 
    print("Defense: ",i*100,"  ",level)

# %%
from sklearn import tree
from sklearn import tree

tree.plot_tree(dtreg,filled=True)  
plt.show()

# %% [markdown]
# This Decision Tree looks horrific. Overfit is everywhere

# %%
plt.figure(figsize=(30,30))
tree.plot_tree(dtregmax2,filled=True,)
plt.show()

# %% [markdown]
# This tree is look better howewer values are too strict.

# %% [markdown]
# Okay I add 1 more column atk+def column. This col increase the accuracy I thing.

# %%
monstacardo["atkdef"]=monstacardo["ATK"]+monstacardo["DEF"]
x=monstacardo[["ATK","DEF","atkdef"]]
y=monstacardo["Level"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=320)
from tpot import TPOTRegressor
tpot = TPOTRegressor(generations=1, population_size=50, verbosity=2,max_time_mins=35)
tpot.fit(x_train,y_train)
print(tpot.score(x_test, y_test))
tpot.export('tpot_result.py')
