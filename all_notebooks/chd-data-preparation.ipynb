# %%
import numpy as np 
import pandas as pd

# %%
chd_data = pd.read_csv("../input/coronary-heart-disease/CHDdata.csv")
chd_data.describe()

# %%
#drop "famhist" column
chd_data = chd_data.drop(columns= "famhist")
#check that it worked
chd_data.head()

# %%
for key in chd_data.keys()[0:8]:
    print("Standardizing "+key+".")
    chd_data[key] = chd_data[key] - np.mean(chd_data[key])
    chd_data[key] = chd_data[key] / np.std(chd_data[key])

# %%
# Check that it worked
chd_data.describe()

# %%
chd_positive = chd_data[chd_data.chd == 1]
chd_negative = chd_data[chd_data.chd == 0]

# %%
# Check that it worked
chd_positive.describe()

# %%
# Check that it worked
chd_negative.describe()

# %% [markdown]
# **Here is a standard textbook question for this data:**
# Perform a Bayesian analysis of these data that finds the posterior marginal probability distributions for the means for the data of patients with and without  CHD.  Your  priors  for  both  groups  should  assume  means  of  0  for  all  variables and a correlation of 0 between all pairs of variables.  You should assume all variances for the variables are 1.  Use a prior alpha equal to one plus the number of predictor variables.  Compute and compare the Bayesian estimates for the posterior means for each group.
#
# We aren't going to provide the solution here, but we can easily check that there apears to be some seperation between the means of these two classes.  The Bayesian analysis in the textbook question would help us decide how meanigful this seperation is.

# %%
# Lets check the mean of each class to get a first look at the seperation
print("Mean for CHD Positive:")
print(np.array([chd_positive.mean()[0:8]]))
print("Mean for CHD Negative:")
print(np.array([chd_negative.mean()[0:8]]))
