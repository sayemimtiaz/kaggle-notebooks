# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.

# %%
import pandas as pd
import numpy as np
import seaborn as sn
sn.set(color_codes=True, style="white")
import matplotlib.pyplot as ml
import numpy as np 
import pandas as pd 
import statsmodels.formula.api as stats
from statsmodels.formula.api import ols
import sklearn
from sklearn import linear_model, datasets
from sklearn.metrics import mean_squared_error
import plotly.plotly as py 
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
import warnings
warnings.filterwarnings("ignore")
hap=pd.read_csv("../input/2017.csv",sep=",",header=0)

# %% [markdown]
# **Shape of the dataset World happiness'17 **

# %%
print(hap.shape)

# %% [markdown]
# In the dataset there are 12 columns and 155 rows

# %% [markdown]
# ** Head of the dataset**
#
# First 10 rows of data

# %%
print(hap.head(11))

# %% [markdown]
# **Correlation**

# %%
hap_cor=hap.corr()
print(hap_cor)

# %% [markdown]
# **Correlation** **Hitmap**

# %%
sn.heatmap(hap_cor, 
        xticklabels=hap_cor.columns,
        yticklabels=hap_cor.columns)

# %% [markdown]
# We can see that out of all the attributes Generocity  affects the Hapiness rank and Hapiness score the least.
#
#
# **strong positive corelation** between:
#
# 1)Hapiness score has a linear correclation with Whisker.high and Whisker.low
#
# 2)Hapiness score is related to Economy GDP per capital, Family and Health, life and Expectancy
#
# 3)Whiskey.high and Whiskey.low are also corelated to Economy GDP per capital, Family and Health, life and Expectancy
#
#
# There is a **moderate correlation** between Hapiness score and  level of Government Corruption and Dystopia.Residual (Dystopia is an imaginary country that has the world’s least-happy people. )

# %%
data6 = dict(type = 'choropleth', 
           locations = hap['Country'],
           locationmode = 'country names',
           z = hap['Happiness.Rank'], 
           text = hap['Country'],
          colorscale = 'Viridis', reversescale = False)
layout = dict(title = 'Happiness Rank World Map', 
             geo = dict(showframe = False, 
                       projection = {'type': 'Mercator'}))
choromap6 = go.Figure(data = [data6], layout=layout)
iplot(choromap6)

# %% [markdown]
# The map demonstrates the geograghy of happy contries.
#
# The darker is the color - the happier is a country.
#
# There are large differences across countries.
#
# According to 2017 numbers, Nordic countries top the ranking: Denmark, Iseland, the Netherlands, Switzerland and Finland  have the highest scores. North America, Australia and New Zealand are also on the top.
#
#  The higest ranks correspond to countries of Afica and South Asia: Central African Republic, Syria, Tanzania, South Sudan, Rwanda and others..

# %%
trace4 = go.Scatter(
    x = hap["Economy..GDP.per.Capita."],
    y = hap["Happiness.Rank"],
    mode = 'markers'
)
data4 = [trace4]
layout = go.Layout(
    title='Happiness Rank Determined by Economy',
    xaxis=dict(
        title='Economy, GDP',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    ),
    yaxis=dict(
        title='Happiness Rank',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    )
)

fig4 = go.Figure(data=data4, layout=layout)
iplot(fig4)

# %% [markdown]
# We can see a negative relationship between the level of economy of the country and a rank of happiness, it means the higher is GDR - the lower is the rank and happier people who lives in the country. Still there is some decrepentcy so it is not an exact linear correlation but very close.
