# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        path = os.path.join(dirname, filename)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Importing the dataset
#
# importing the dataset using the pandas libray

# %%
df = pd.read_csv(path,index_col=False)

# %% [markdown]
# Printing the raw dataframe

# %%
df

# %% [markdown]
# Checking the data frames feature value types and the coloums in it

# %%
df.info()

# %% [markdown]
# Checking is there is any null values in the dataframe

# %%
df.isnull().sum()

# %% [markdown]
# # Data processing

# %% [markdown]
# Extracting the X(features) and the Y(Class) from the raw dataframe

# %%
X = df.drop(['class'],axis=1)
y = df['class']

# %% [markdown]
# > checking the X wheather all the features are extracted

# %%
X

# %% [markdown]
#  checking the y wheather all the class are extracted

# %%
y

# %% [markdown]
# Splitting into training and test data for both features and class

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=33)

# %% [markdown]
# Fitting the Decision Tree Classifier

# %%
from sklearn import tree
dt = tree.DecisionTreeClassifier()
model = dt.fit(X_train,y_train)

# %% [markdown]
# Predicting the test data

# %%
predicted= model.predict(X_test)

# %% [markdown]
# Getting the accuracy score from the metrics

# %%
from sklearn.metrics import accuracy_score

# %%
score = accuracy_score(y_test,predicted)

# %%
print(score)

# %% [markdown]
# Getting the features name and the class name

# %%
names = X.columns
classes =  ['class 0','class 1']

# %% [markdown]
# Visualising the decission tree tha we have created

# %%
import graphviz
# DOT data
dot_data = tree.export_graphviz(model,feature_names=names,class_names=classes)
graph = graphviz.Source(dot_data,format="png") 
graph

# %% [markdown]
# Visualising the confusion matrix to analyse how many False negative and False positive produced

# %%
from sklearn.metrics import confusion_matrix

# %%
matrix = confusion_matrix(y_test,predicted)

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(model, X_test, y_test)
