# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
file = pd.read_csv ("../input/videogames-sales-dataset/Video_Games_Sales_as_at_22_Dec_2016.csv")

# %%
file.head(10)

# %%
file.describe()

# %%
file.boxplot()

# %%
file.hist()

# %%
file.info()

# %%
file.isnull()

# %%
file.isnull().sum()

# %%
file.Rating

# %%
print(file.isnull().sum())

# %%
threshold = len(file)* 0.1
threshold

# %%
file.dropna(thresh=threshold, axis=1, inplace=True)

# %%
file.shape

# %% [markdown]
#     Having Kaggle to analyze data like this is incredible, especially whne you have to sift through a lot of it. When I started this final project I thought it was going to be extremely difficult or time consuming, but it really wasnt. I had learned a lot from this project and I still plan to find out more with data analysis on Kaggle.
#     As I started the beginning process I didn't know what data to use so I just went with something that inerests me and I decided to use Video Game Sales. It was interesting to see so much data that someone had compiled for so long and put it all into one spreadsheet. Data is a really interesting subject to talk about and could take hours to analize it but know I could use kaggle to do it for me.
#     The best part about Kaggle is that you dont have to use their datasets. You can use one of your own that you have made and start analyzing it in Kaggle, but it is a different set of skills and processes. Analyzing my own data will be amazing because there is so much to keep track of. I will definitely keep using this and trying to find better ways to analyze but for now this is amazing.
