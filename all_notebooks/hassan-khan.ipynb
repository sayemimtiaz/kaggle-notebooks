# %%
# dataset classes
# !ls /kaggle/input/sports-classification/train

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('/kaggle/input/sports-classification/train/archery/001.jpg')
plt.imshow(img)
