# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# #  World Happiness Report:
# The World Happiness Report is an annual publication of the United Nations Sustainable Development Solutions Network. It contains articles, and rankings of national happiness based on respondent ratings of their own lives.

# %%
world_happiness_2015=pd.read_csv('../input/world-happiness/2015.csv')
world_happiness_2016=pd.read_csv('../input/world-happiness/2016.csv')
world_happiness_2017=pd.read_csv('../input/world-happiness/2017.csv')
world_happiness_2018=pd.read_csv('../input/world-happiness/2018.csv')
world_happiness_2019=pd.read_csv('../input/world-happiness/2019.csv')

# %%
world_happiness_2015.where(world_happiness_2015.Region=='Latin America and Caribbean').dropna()

# %%
bins=[0,15,100,178]
label=['Top 15 countries','countries up till 100th rank','lowestranking_country']
world_happiness_2015['binned'] = pd.cut(world_happiness_2015['Happiness Rank'], bins=bins, labels=label)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
world_happiness_2015.rename(columns={'Happiness Score':'Score_Happiness','Happiness Rank':'Rank',
                                     'Economy (GDP per Capita)':'Gdp','Health (Life Expectancy)':'Lfeexp',
                                     'Trust (Government Corruption)':'Truth','Dystopia Residual':'dystopiaResidual'},inplace=True)

# %%
General_correlation=world_happiness_2015.copy()
General_correlation=General_correlation.drop(['Region','Standard Error','Rank'],axis=1)
General_correlation=General_correlation.corr(method ='pearson')
plt.figure(figsize=(8,8))
sns.heatmap(General_correlation,annot=True,cmap='gnuplot_r').set_title('Factors Governing Rank');

# %% [markdown]
# If you look closely happiness score is highly dependent on factors like **"GDP", "Life Expectancy" & "Family Satisfaction"** there are other
# factors too that can be taken into account like **Freedom**. Factors like** Trust in government** and **Generosity** donot play much of a role.
# You will see a series of heat map for every region and based on that we can decide what are the factors that have influenced that certain countries ranking.

# %%
north_america=world_happiness_2015.where(world_happiness_2015.Region=='North America')
north_america=north_america.dropna()
north_america=north_america.drop(['Region','Rank','binned','Standard Error'],axis=1)
north_america=north_america.corr(method ='pearson')
plt.figure(figsize=(10,10))
plt.title('Region:North America')
sns.heatmap(north_america,annot=True,cmap='BuGn');

# %% [markdown]
# # **North America**
# Above is the heatmap of the region ** North America**. The heatmap shows high correlation values. These are one of the most influencal counties on the Globe with High Economy, Life expectancy etc.
# Canada was the 4th happiest county while USA stood 15th on the list of 158 Countries.

# %%
western_europe=world_happiness_2015.where(world_happiness_2015.Region=='Western Europe')
western_europe=western_europe.drop('binned',axis=1)
western_europe=western_europe.dropna()
western_europe=western_europe.drop(['Rank','Region','Country','Standard Error'],axis=1)
western_europe=western_europe.corr(method ='pearson')
plt.figure(figsize=(10,10))
plt.title('Western-Europe')
sns.heatmap(western_europe,annot=True,cmap="YlGnBu");

# %% [markdown]
# # **Western Europe.**
# The Heatmap looks quite promising. Counties that lie in Western Europe Region lie within top 20 of the happiest counties. The Gdp Family satisfaction looks promising. People in these countries are quite Generous.

# %%
Australia_Newzeland=world_happiness_2015.where(world_happiness_2015.Region=='Australia and New Zealand')
Australia_Newzeland=Australia_Newzeland.dropna()
Australia_Newzeland=Australia_Newzeland.corr(method ='pearson')
plt.figure(figsize=(10,10))
plt.title('Australia and New-Zeland')
sns.heatmap(Australia_Newzeland,annot=True,cmap='winter');

# %% [markdown]
# # Australia & New-Zeland:
# This Region Consists of Two major countries, "Australia and New-Zeland".
# Both these countries tend to be happy counties.
# New Zeland being the 8th Happiest country while Australia being 9th on the list.

# %%
Eastern_Asia=world_happiness_2015.where(world_happiness_2015.Region=='Eastern Asia')
Eastern_Asia=world_happiness_2015.dropna()
Eastern_Asia=Eastern_Asia.drop(['Rank','Standard Error'],axis=1)
Eastern_Asia=Eastern_Asia.corr(method ='pearson')
plt.figure(figsize=(10,10))
plt.title('Eastern Asia')
sns.heatmap(Eastern_Asia,annot=True);

# %% [markdown]
# # Eastern Asia:
# This Heatmap looks Quite Intresting for Eastern Asia.Countries in these region exibit low correlational values for Generosity and Trust in Government.The Gdp of countries in these region are strong. When looked closely only Gdp Stands out showing high positive corelation, while most other factors exibit weaker correlation.

# %%
Central_Eastern_Europe=world_happiness_2015.where(world_happiness_2015.Region=='Central and Eastern Europe')
Central_Eastern_Europe=Central_Eastern_Europe.dropna()
Central_Eastern_Europe=Central_Eastern_Europe.drop(['Rank','binned','Standard Error'],axis=1)
Central_Eastern_Europe=Central_Eastern_Europe.corr(method ='pearson')
plt.figure(figsize=(10,10))
plt.title('Central Eastern Europe')
sns.heatmap(Central_Eastern_Europe, annot=True,cmap='OrRd_r');

# %% [markdown]
# # Central Eastern Europe
# Eastern Europe is just the opposite of Western Europe, where Western Europe, showing strong positive correlational values and setting out as the most favourable and happiest country Central Eastern Europe has a different story to tell. Low GDP, Family Satisfaction, Life Expectancy, Trust in government, Freedom  Values.
# These aren't ideally the happiest and vibrant country. Some of the Countries that lie in these regions are Russia, Armenia, Belarus.

# %%
SouthernAsia=world_happiness_2015.where(world_happiness_2015.Region=='Southern Asia')
SouthernAsia=SouthernAsia.dropna()
SouthernAsia=SouthernAsia.drop(['binned','Rank','Region','Standard Error'],axis=1)
SouthernAsia=SouthernAsia.corr(method ='pearson')
plt.figure(figsize=(10,10))
sns.heatmap(SouthernAsia,annot=True,cmap='mako').set_title('Southern Asia');

# %% [markdown]
# # Southern Asia
# The heat map for southern Asia shows a moderate positive correlation for most of its factors, like GDP, Life Expectancy.
# It does show a negative correlation mostly for Dystopia Residual. The overall heatmap consists of average correlation values for both negative and positive correlations.

# %%
southeasternasia=world_happiness_2015.where(world_happiness_2015.Region=='Southeastern Asia')
southeasternasia=southeasternasia.dropna()
southeasternasia=southeasternasia.drop(['binned','Rank','Region','Standard Error'],axis=1)
southeasternasia=southeasternasia.corr(method ='pearson')
plt.figure(figsize=(10,10))
sns.heatmap(southeasternasia,annot=True,cmap="viridis").set_title('South East Asia');

# %% [markdown]
# # South East Asia:
# The heat map for south East Asia shows strong and positive correlation values for Gdp Life Expectancy and Family satisfaction and Life Expectancy. These are primary reasons for a country's development which is good.  However, Happiness Score is not primarily bound to these three factors, freedom and Generosity take a negative toll with average negative correlation value. Countries included in These regions are Thailand, Cambodia, Indonesia, Singapore.Countries in this region rank between 33 to 144. Thailand being the most prominent COuntry and Cambodia ranking lowest among these Regions.

# %%
subsharaafrica=world_happiness_2015.where(world_happiness_2015.Region=='Sub-Saharan Africa')
subsharaafrica=subsharaafrica.dropna()
subsharaafrica=subsharaafrica.drop(['binned','Rank','Region','Standard Error'],axis=1)
subsharaafrica=subsharaafrica.corr(method ='pearson')
plt.figure(figsize=(10,10))
sns.heatmap(subsharaafrica,annot=True,cmap='rocket_r').set_title('Sub Shara Africa');

# %% [markdown]
# # Sub Shara Africa:
# None of the Variable contributes to a strong correaltion value. Countries that lie in this region can have huge poverty due to their low Gdp and Very low Life expectancy. There is a very low negative correlation value between Trust in Government and Gdp. Countries that lie in this region are Mauritius, Chad, South Africa, Guinea, it is a region of 33 Countries and lies between 70 to 157 Ranks.

# %%
Middle_east_africa=world_happiness_2015.where(world_happiness_2015.Region=='Middle East and Northern Africa')
Middle_east_africa=Middle_east_africa.dropna()
Middle_east_africa=Middle_east_africa.drop(['binned','Rank','Region','Standard Error'],axis=1)
Middle_east_africa=Middle_east_africa.corr(method ='pearson')
plt.figure(figsize=(10,10))
sns.heatmap(Middle_east_africa,annot=True,cmap='flag').set_title('Middle East  and Northern Africa');

# %% [markdown]
# Unlike the other Region of Africa, this heatmap does show some promising correlation values for Gdp, Family Satisfaction, Life expectancy, Freedom and moderate value for Trust in Government. Countries that lie in this region are UAE, Oman, Qatar which are very peaceful and high economical countries. However, it does include some countries like Syria, Yemen, Iran, Egypt that do not rank good because they are torn between Religion, War & Terrorism.
# It is due to Countries like UAE, Saudi Arabia, Dubai, Qatar the heat map is showing positive correlational values.

# %%
Latin_america=world_happiness_2015.where(world_happiness_2015.Region=='Latin America and Caribbean')
Latin_america=Latin_america.dropna()
Latin_america=Latin_america.drop(['binned','Rank','Region','Standard Error'],axis=1)
Latin_america=Latin_america.corr(method ='pearson')
plt.figure(figsize=(10,10))
sns.heatmap(Latin_america,annot=True,cmap="cubehelix").set_title("Latin America and Caribbean");

# %% [markdown]
# # Latin African and Caribbean
# The heatmap doesn't contain any strong positive or negative values. The Gdp and Life expectancy of these regions seem to be pretty good. The Generosity of these regions seems to be negative for all values. Average family expectancy and Freedom can be expected by the countries in these Region. Counties that lie in these Region Mexico, Argentina, Costa Rica etc. Most of these countries are evenly ranked between 11 to 118 with counties like Costa Rica, Mexico and Argentina at the top.

# %%
world_happiness_2015.sort_values('Gdp',ascending=False,inplace=True)
highest_economy=world_happiness_2015
highest_economy=highest_economy[['Country','Gdp','Region']].head(10)
plt.figure(figsize=(8,8))
plt.title('Highest Econmy 2015')
sns.barplot(highest_economy.Gdp,highest_economy.Country,hue=highest_economy.Region).legend(loc='best',bbox_to_anchor=(1.8, 0.5), ncol=1);

# %% [markdown]
# # Top Ten countries with Highest Economy.
# Majority of these countries are form the Region of **Middle East**.They outshine many counties interms of Economy due to its oil and Gas reserves that help them shape majority of its Economy.
# Other countries that lie in this chart are from **Western Europe** countries like Luxembourg, Switzerland and Norway. Their major source of Economy relies on Factors like Tourism,oil and gas production account for 20 percent of its economy.
# The rest of country belog to Asian Regions that solely depend on  Electronics; chemicals; financial services.

# %%
world_happiness_2015.sort_values('Family',ascending=False,inplace=True)
world_happiness_2015[['Country','Family']].head(10)

# %% [markdown]
# # Family satisfaction, Top 10 Countries:
#
# Seven out of Ten countries belong to western Europe. The Factors that Influence the Life expectancy of a country are GDP, Life expectancy, Even Freedom as they play a very important Psychological factor, western Europe satisfies all the condition. The other countries that belong to Europe, Australia and New Zealand and North America Region.

# %%
plt.figure(figsize=(10,10))
plt.title("Family Satisfaction")
sns.pointplot(world_happiness_2015.Country.head(10),world_happiness_2015.Family.head(10),data=world_happiness_2015,hue=world_happiness_2015.Region).legend(loc='best',bbox_to_anchor=(1.8, 0.5), ncol=1).set_title('Life expectancy');

# %%
world_happiness_2015.sort_values('Truth',ascending=False,inplace=True)
world_happiness_2015[['Country','Truth']].head(15)

# %% [markdown]
# # Trust in the Government
# The list consists of Country from all the region With Rwanda topping the Chart followed by Qatar, Singapore.
# The one thing that stands out is Rwanda is one of the unhappiest countries tops the chart. if you look closely Except Rwanda and Somaliland Region and Georgia all the other countries rank higher in the happiest country ranks.

# %%
plt.figure(figsize=(10,10))
plt.title('Trust in the Government')
sns.pointplot(world_happiness_2015.Truth.head(15),world_happiness_2015.Country.head(15),data=world_happiness_2015,hue=world_happiness_2015.Region).legend(loc='best',bbox_to_anchor=(1.8, 0.5), ncol=1).set_title('Trust In Government');

# %%
world_happiness_2015.sort_values('Freedom',ascending=False,inplace=True)
world_happiness_2015[['Country','Freedom']].head(10)

# %% [markdown]
# # Freedom
# Majority of these countries belong to the region of Western Europe and some belong to Australia and the Middle East. However, the one standing out happens to be that of Cambodia, a country placed so low on the happiness rank is among the top ten countries with maximum value for freedom. We know that Freedom as a Factor does not implement as a whole for these ranking. since Freedom is quite high in Cambodia and it is placed so low it suggests that Other factors like Economy, Family satisfaction would have been very low.

# %%
world_happiness_2015.sort_values('Freedom',ascending=False,inplace=True)
freedom=world_happiness_2015[['Country','Freedom']].head(10)
plt.figure(figsize=(7,7))
plt.title('Freedom')
sns.pointplot(world_happiness_2015.Freedom.head(10),world_happiness_2015.Country.head(10),data=world_happiness_2015,hue=world_happiness_2015.Region).legend(loc='best',bbox_to_anchor=(1.8, 0.5), ncol=1).set_title('Freedom');

# %%
world_happiness_2015.sort_values('Generosity',ascending=False,inplace=True)
world_happiness_2015[['Country','Generosity']].head(10)

# %%
plt.figure(figsize=(7,7))
sns.pointplot(world_happiness_2015.Generosity.head(15),world_happiness_2015.Country.head(15),data=world_happiness_2015,hue=world_happiness_2015.Region).legend(loc='best',bbox_to_anchor=(1.8, 0.5), ncol=1).set_title('Freedom');

# %% [markdown]
# # Generosity.
#
# Although the top two spots for the most generous country is occupied by Mynmar and Thailand. Countries that belong to western Europe fill up most of the list.

# %%
world_happiness_2015.sort_values('dystopiaResidual',ascending=False,inplace=True)
world_happiness_2015[['Country','dystopiaResidual']].head(10)

# %%
plt.figure(figsize=(7,7))
sns.pointplot(world_happiness_2015.dystopiaResidual.head(15),world_happiness_2015.Country.head(15),data=world_happiness_2015,hue=world_happiness_2015.Region).legend(loc='best',bbox_to_anchor=(1.8, 0.5), ncol=1).set_title('dystopian Residual');

# %% [markdown]
# # Dystopian Residual
# Whats strange about this is none of the counties that are ranked among top 20 countries lie in this graph. Majority of this county belong to the Region of Latin America. Followed by some Asian and European Countries.

# %% [markdown]
# # Conclusion:
# We have focused on the exploratory analysis as to what factors affect the happiness ranking of a country.
# I have tried to focus mostly on the top ten countries and what they are doing right.
# Overall we can say that the happiest region is that of Western Europe because of its good Economy,Family Expectancy, Family Satisfacction etc.
# Followed by North America, Australia and New Zealand.
