# %% [markdown]
# # Let's take a look at what types of fruit originate from which states.

# %%
import pandas as pd
import sqlite3

# Read in SQLite databases
con = sqlite3.connect("../input/database.sqlite")
results = pd.read_sql_query("SELECT * from resultsdata15", con)
samples = pd.read_sql_query("SELECT * from sampledata15", con)

con.close()

# %% [markdown]
# # By looking at commodity_codes.csv, we can figure out what type of produce is referenced in the _commod_ column. We can get a better clue by looking at the _variety_ column (i.e. Fuji is a type of apple).

# %%
samples.head()

# %%
samples.tail()

# %%
samples = samples[['state', 'commod', 'variety']]
samples.head()

# %% [markdown]
# # Where did most of the apple samples come from?

# %%
apples = samples.loc[samples['commod'] == 'AP']

# %%
apples.head()

# %%
apples['state'].value_counts()

# %% [markdown]
# # What are the most common types of apples in the study?

# %%
apples['variety'].value_counts()

# %% [markdown]
# # Other ideas to explore:
# * Looking at the results database, what are the tested pesticide levels on apples? Do they all meet EPA standards?
# * Are the states with the highest number of samples producing the most common type of apples? Or do certain states specialize in particular types?
# * What are the most common types of pesticides used on apples in each state? If there is a difference, why do you think that is? Do certain types of pesticides work better on certain apple types, or produce types?
