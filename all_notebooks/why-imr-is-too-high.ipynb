# %% [markdown]
# <br>
# <h2 style = "font-size:40px; font-family:Garamond ; font-weight : normal; background-color: #007580; color :#fed049   ; text-align: center; border-radius: 5px 5px; padding: 5px">Infant mortality rate</h2>

# %% [markdown]
# <img src="https://guardian.ng/wp-content/uploads/2017/11/infant-mortality.jpg"></img>

# %% [markdown]
# * **Let's  try to discuss in a first place,the meaning of infant mortality rate infant means a baby/child i can say that again mortality means death in a combination of both we can say it is called as infant mortality rate also called an infant death rate**

# %% [markdown]
# * **Infant mortality can measure how well being of an infant,children and pregnant women because it is associated with many factors like such as maternal health,quality and medicare ,socio economic conditions ,public health practices**

# %% [markdown]
# <br>
# <h2 style = "font-size:40px; font-family:Garamond ; font-weight : normal; background-color: #007580; color :#fed049   ; text-align: center; border-radius: 5px 5px; padding: 5px">How can we measure infant mortality rate</h2>

# %% [markdown]
# * **Infant mortality rate can be measures if he/she happen to death before his/her birthday.**
#
#
#
# * **Again it is countable it is completely fine how can we are able to measure per year**
#
#
#
#
# * **If we measures for a country how much percentage of people dies for every 1,000 births**

# %% [markdown]
# <br>
# <h2 style = "font-size:40px; font-family:Garamond ; font-weight : normal; background-color: #007580; color :#fed049   ; text-align: center; border-radius: 5px 5px; padding: 5px">What Cause this??</h2>

# %% [markdown]
# * **Poor sanitation and water quality**
#
#
#
#
#
# * **Breast feeding controversies**
#
#
#
#
#
#
# * **Pre-natal care**
#
#
#
#
#
# * **Low birth weight**
#
#
#
# * **Race and Infant mortality**

# %% [markdown]
# <br>
# <h2 style = "font-size:40px; font-family:Garamond ; font-weight : normal; background-color: #007580; color :#fed049   ; text-align: center; border-radius: 5px 5px; padding: 5px">Who can decide infant mortality death specific ratio and what is the prior knowledge required??</h2>

# %% [markdown]
# * **To compute a given year’s infant mortality rate in a certain area, one would need to know how many babies were born alive in the area during the period and how many babies who were born alive died before their first birthday during that time. The number of infant deaths is then divided by the number of infant births, and the results are multiplied by 1,000 so that the rate reflects the number of infant deaths per 1,000 births in a standardized manner. Alternately, the rate could be multiplied by 10,000 or 1,000,000, depending on the desired comparison level.**

# %% [markdown]
# <br>
# <h2 style = "font-size:40px; font-family:Garamond ; font-weight : normal; background-color: #007580; color :#fed049   ; text-align: center; border-radius: 5px 5px; padding: 5px">How can we prevent this in order to decrease the infant mortality rate?</h2>

# %% [markdown]
# * **Advocacy groups estimate that the deaths of several million children yearly could be prevented by the use of a simple low-cost oral rehydration solution.**

# %% [markdown]
# * **Premature infants (born at less than 37 weeks gestation) have a higher risk of death not only because of low birth weight but also because their respiratory and digestive systems are not fully matures**

# %% [markdown]
# * **Maintaining such a schedule requires time, effort, and—most important—access to a system of affordable health care, which is lacking in many LDCs and even in some industrialized countries**

# %% [markdown]
# <br>
# <h2 style = "font-size:40px; font-family:Garamond ; font-weight : normal; background-color: #007580; color :#fed049   ; text-align: center; border-radius: 5px 5px; padding: 5px">Importing required libraries</h2>

# %%
from IPython.display import clear_output 
# !pip install fast_ml 
clear_output()

# %%
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt 
import plotly.express as px 
import seaborn as sns 
import warnings
warnings.filterwarnings("ignore")

# %%
from fast_ml.outlier_treatment import OutlierTreatment

# %%
df = pd.read_csv(r"../input/infant-mortality/InfantMortalityRate.csv")

# %%
df

# %% [markdown]
# <br>
# <h2 style = "font-size:40px; font-family:Garamond ; font-weight : normal; background-color: #007580; color :#fed049   ; text-align: center; border-radius: 5px 5px; padding: 5px">shape of an dataset</h2>

# %%
df.shape

# %% [markdown]
# <br>
# <h2 style = "font-size:40px; font-family:Garamond ; font-weight : normal; background-color: #007580; color :#fed049   ; text-align: center; border-radius: 5px 5px; padding: 5px">Columns in  dataset</h2>

# %%
df.columns.tolist()

# %% [markdown]
# <br>
# <h2 style = "font-size:40px; font-family:Garamond ; font-weight : normal; background-color: #007580; color :#fed049   ; text-align: center; border-radius: 5px 5px; padding: 5px">Number of unique values in a each column</h2>

# %%
df.nunique()

# %%
original = df[df["Gender"].isin(["Male","Female"])]

# %%
original

# %%
plt.figure(figsize=(16,8))
plt.plot(df["Infant Mortality Rate"].head(100))

# %%
px.line(df,x="Year",y="Infant Mortality Rate",template="plotly_dark")

# %%
gen = original['Gender'].value_counts().reset_index() 
gen.columns = ["gender","counts"] 
fig = px.pie(gen,names="gender",values="counts",title="Percentage distribution of male and female in a dataset",template="ggplot2",color_discrete_sequence=px.colors.sequential.dense_r) 
fig.update_traces(textinfo="percent+label")

# %%
sns.displot(data=original,x=original["Infant Mortality Rate"],hue=original["Gender"],height=6,aspect=4)

# %% [markdown]
# <h1 style = "font-family: Comic Sans MS;color:Green">It is not even following normal distribution</h1>

# %%
plt.figure(figsize=(16,8))
fig = plt.boxplot(original["Infant Mortality Rate"])

# %% [markdown]
# <br>
# <h2 style = "font-size:40px; font-family:Garamond ; font-weight : normal; background-color: #007580; color :#fed049   ; text-align: center; border-radius: 5px 5px; padding: 5px">Outliers problem fixed</h2>

# %%
ot = OutlierTreatment()

# %%
ot.fit(original,variables=["Infant Mortality Rate"]) 
modified_out = ot.transform(original) 
modified_out.shape

# %%
plt.figure(figsize=(16,8))
fig = plt.boxplot(modified_out["Infant Mortality Rate"])

# %%
sns.displot(data=modified_out,x=modified_out["Infant Mortality Rate"],hue=modified_out["Gender"],height=6,aspect=4)

# %%
original.sort_values(by="Infant Mortality Rate",ascending=False)

# %%
original["Gender"]

# %%
original.columns

# %%
plt.figure(figsize=(16,8))
fig = sns.catplot(data=original,x="Gender",y="Infant Mortality Rate",hue="Year",kind="swarm",height=8,aspect=2)

# %%
original.groupby("Year")["Infant Mortality Rate"].agg([sum])

# %% [markdown]
# <br>
# <h2 style = "font-size:40px; font-family:Garamond ; font-weight : normal; background-color: #007580; color :#fed049   ; text-align: center; border-radius: 5px 5px; padding: 5px">Highest Infant Mortality Rate respective to their Countries</h2>

# %%
original.nlargest(10,"Infant Mortality Rate")

# %% [markdown]
# <br>
# <h2 style = "font-size:40px; font-family:Garamond ; font-weight : normal; background-color: #007580; color :#fed049   ; text-align: center; border-radius: 5px 5px; padding: 5px">Smallest Infant mortality rate respective to their countries</h2>

# %%
original.nsmallest(10,"Infant Mortality Rate")

# %% [markdown]
# <br>
# <h2 style = "font-size:40px; font-family:Garamond ; font-weight : normal; background-color: #007580; color :#fed049   ; text-align: center; border-radius: 5px 5px; padding: 5px">Infant mortality rate in India</h2>

# %%
original[original["Country"].isin(["India"])]

# %% [markdown]
# <br>
# <h2 style = "font-size:40px; font-family:Garamond ; font-weight : normal; background-color: #007580; color :#fed049   ; text-align: center; border-radius: 5px 5px; padding: 5px">What are the things I have done in my notebook:</h2>

# %% [markdown]
# * **Domain Knowledge about Infant mortality rate**

# %% [markdown]
# * **Yearly distribution of infant mortality rate**

# %% [markdown]
# * **Distribution of infant mortallity rate respective to their gender**

# %% [markdown]
# * **Outlier problem fixed about infant mortality rate**

# %% [markdown]
# * **Infant mortality rate respective to their gender,year wise**

# %% [markdown]
# * **Smallest number of Infant mortality rate respective to their countries**

# %% [markdown]
# * **Highest number of Infant mortality rate respective to their countries**
