# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('../input/cardiogoodfitness/CardioGoodFitness.csv')

# %%
df.head()

# %%
df.info()

# %%
df.describe()

# %%
df['Age'].max()

# %%
df['Product'].unique()

# %%
df[df['Product']=='TM195']['Gender'].value_counts()

# %%
df[(df['Product']=='TM195') & (df['Gender']=='Female')]['Age'].mean()

# %%
a=df[(df['Product']=='TM195') & (df['Gender']=='Female')]['Age'].max()
b=df[(df['Product']=='TM195') & (df['Gender']=='Male')]['Age'].max()
print(a,b)

# %%
df['Product'].value_counts()

# %%
df[df['Product']=='TM498']['Age'].std()

# %%
df['Age'].idxmax()

# %%
df.iloc[79]

# %%
df[df['Age']<30].count()

# %%
df[(df['Age']<30) & (df['Age']>20)]['Gender'].value_counts()

# %%
df[(df['Age']<30) & (df['Age']>20) & (df['Gender']=='Male')]['Product'].value_counts()

# %%
df[(df['Age']<30) & (df['Age']>20) & (df['Gender']=='Male')]['MaritalStatus'].value_counts()

# %%
df['Income'].idxmax()
df.iloc[df['Income'].idxmax()]

# %%
#df['Income'].Q3==33
df[(df['Income']>33) & (df['Age']>30) & (df['Gender']=='Male')]['Product'].value_counts()

# %%
df[(df['Income']>33) & (df['Age']>30) & (df['Gender']=='Male') & (df['Product']=='TM798')].head(10)

# %%
df[(df['Income']>33) & (df['Age']>30) & (df['Gender']=='Male') & (df['Product']=='TM798')]['Miles'].mean()

# %%
df[(df['Gender']=='Female') & (df['Age']<30)]['Usage'].value_counts()

# %%
df[(df['Gender']=='Female')]['Income'].mean()

# %%
df[(df['Gender']=='Female') & (df['Income']<49828.90789473684)]['Education'].value_counts()

# %%
df[(df['Gender']=='Female') & (df['Income']<49828.90789473684) & (df['Education']==14)]['Usage'].value_counts()

# %%
df[(df['Gender']=='Female') & (df['Income']<49828.90789473684) & (df['Education']==14) & (df['Usage']==3)]['Fitness'].value_counts()

# %%
df['Education'].max()

# %%
df[df['Education']==21]

# %%
df[df['Gender']=='Female']['Education'].value_counts()

# %%
df[(df['Gender']=='Female') & (df['Education']==18)]['Income'].describe()

# %%
df[(df['Gender']=='Female') & (df['Education']==18)]

# %%
sb.distplot(df['Age'],bins='auto',hist_kws=dict(edgecolor='black',linewidth=2))

# %%
plt.figure(figsize=(8,5),dpi=75)

plt.subplot(1,2,1)

sb.kdeplot(df['Miles'])

plt.subplot(1,2,2)

sb.kdeplot(df['Income'])

# %%
sb.swarmplot(x='Fitness',y='Miles',data=df,size=10,hue='Gender')

# %%
sb.rugplot(df['Income'],height=0.3)

# %%
sb.scatterplot(data=df,x='Age',y='Miles',hue='Gender',palette='Set1',s=100,alpha=0.5)

# %%
sb.jointplot(data=df,x='Income',y='Age',kind='kde')

# %%
plt.figure(figsize=(8,5),dpi=70)
sb.pairplot(df,hue='MaritalStatus',corner=True)

# %%
plt.subplot(1,3,1)
sb.countplot(data=df,x='Fitness')

plt.subplot(1,3,2)
sb.countplot(data=df,x='Product')

plt.subplot(1,3,3)
sb.countplot(data=df,x='MaritalStatus')

# %%
sb.boxplot(data=df,x='Education',y='Income',hue='Product')

# %%
sb.violinplot(x='Usage',y='Age',data=df,split=True,hue='Gender')

# %%
df2=df.pivot_table(index='Income',columns='Age',values='Miles')

# %%
plt.figure(figsize=(10,8),dpi=80)
sb.heatmap(df2)
