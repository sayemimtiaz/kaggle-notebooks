# %% [markdown]
# Burning Glass Technologies, a leading labor market analytics firm. Burning Glass makes use of the power of data and AI technologies that have cracked the genetic code of the job market.  Powered by the world’s largest and most sophisticated database of jobs and talent, Burning Glass delivers real-time data and breakthrough planning tools that inform careers, define academic programs, and shape workforces. Burning Glass has helped to fill millions of jobs and its data drive initiatives for more than a dozen state and national governments. Matt Sigelman the CEO is consulted frequently by national media, by researchers, and industry leaders.https://www.burning-glass.com/about/leadership/

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/png;base64,...',width=400,height=400)

# %% [markdown]
# Image burning-glass.com

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
df = pd.read_excel('/kaggle/input/the-2019-ai-index-report/AI INDEX 2019 PUBLIC DATA/4. The Economy/4.1. Jobs/Burning Glass/US State Data.xlsx')
df.head()

# %%
df = df.rename(columns={'AI Postings by State': 'postings', 'Unnamed:1':'unnamed', 'Unnamed:2': 'year', 'Unnamed:3': 'total', 'Unnamed:4': 'ITpostings', 'Unnamed:5': 'AIpostings', 'Unnamed:6': 'AIshare', 'Unanamed:7': 'AIsharetotal'})

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQCKImILst2cMzxMZe6d7r7U8_flYiAk9VstR8SmKBPNWftbMjw&s',width=400,height=400)

# %% [markdown]
# Image knowledgeleadersgroup.com

# %%
#word cloud
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in df.postings)
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200, background_color="black").generate(text)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='Bilinear')
plt.axis("off")
plt.show()

# %%
df.dtypes

# %%
categorical_cols = [cname for cname in df.columns if
                    df[cname].nunique() < 10 and 
                    df[cname].dtype == "object"]


# Select numerical columns
numerical_cols = [cname for cname in df.columns if 
                df[cname].dtype in ['int64', 'float64']]
print(numerical_cols)
print(categorical_cols)

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTqL8ehDAe9UXfvqO75IXo0ZJ_OWCNHvCncrclUVzVXhaHew1KQhg&s',width=400,height=400)

# %% [markdown]
# Image campusmanagement.com

# %%
plt.figure(figsize=(10, 6))
pd.value_counts(df['postings']).plot.bar()
plt.xticks(rotation=90)
plt.show()

# %%
df.describe()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTPEX2DS1Na1pU2krXCNJuFcIwssRx96zhiU4Qt7Xx-h6NACzwF&s',width=400,height=400)

# %% [markdown]
# Image vimeo.com

# %%
x = ['postings', 'initials']
y = ['year', 'total']
plt.barh(x,y)
plt.title("Burning Glass Technologies")
plt.xlabel("postings")
plt.ylabel('year')
plt.style.use('seaborn-dark-palette')

# %%
labels1=df.postings.value_counts().index
sizes1=df.postings.value_counts().values
plt.figure(figsize=(9,9))
plt.pie(sizes1,labels=labels1,autopct="%1.1f%%")
plt.title("Burning Glass Technologies",size=15)
plt.show()

# %%
sns.countplot(df["postings"])
plt.xticks(rotation=90)
plt.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTgXfKptBM0_zJx816LfwbRTfBqisZ_2472YdKAkeuD8Lr0aZ29JQ&s',width=400,height=400)

# %% [markdown]
# Image youtube.com

# %%
import plotly.offline as pyo
import plotly.graph_objs as go
lowerdf1 = df.groupby('postings').size()/df['Unnamed: 3'].count()*100
labels = lowerdf1.index
values = lowerdf1.values

# Use `hole` to create a donut-like pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=.6)])
fig.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRhkYInrMicP_zuAl75JgLLuqf0_CoFUrcPsbMyjgK23l02RZo0gg&s',width=400,height=400)

# %% [markdown]
# Image owler.com

# %% [markdown]
# <iframe width="727" height="409" src="https://www.youtube.com/embed/h3vj24izHwY" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# * Webinar - Skills not Jobs: Pathways to Success in the Emerging Job Landscape
#
#
# * Brought to you by SkillsFuture Singapore and BURNING GLASS TECHNOLOGIES
# * Presented by Matt Sigelman, CEO of **BURNING GLASS TECHNOLOGIES**

# %% [markdown]
# Kaggle Notebook Runner: Marília Prata @mpwolke.
