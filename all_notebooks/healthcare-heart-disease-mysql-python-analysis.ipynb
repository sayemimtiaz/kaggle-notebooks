# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#import mysql.connector
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input/health-care-data-set-on-heart-attack-possibility/heart.csv'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
pip install mysql-connector

# %% [markdown]
# Import all the packages needed to run the query

# %%
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
import mysql.connector

# %%
dataframe = pd.read_csv('/kaggle/input/health-care-data-set-on-heart-attack-possibility/heart.csv')
dataframe

# %%
dataframe.head()

# %%
dataframe.info()

# %%
## check for missing values
dataframe.isnull().sum()

# %%
# the columns
dataframe.columns

# %%
## plot the age feature 
sns.distplot(dataframe["age"])

# %%
## plot the target variable
sns.countplot(dataframe["target"])

# %%
## plot the heat map
g = dataframe.corr()
df_ = g.index
g = sns.heatmap(dataframe[df_].corr())

# %% [markdown]
# **Modeling and Prediction**

# %%
## select dependent and independent features 
X = dataframe.drop("target", axis=1)
y = dataframe["target"]

# %%
## split the dataset into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
## import the model
## we'll be using the random forest classidier 

random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X_train, y_train)

Y_prediction = random_forest.predict(X_test)

random_forest.score(X_train, y_train)

# %%
print(classification_report(y_test, Y_prediction))

# %%
print(confusion_matrix(y_test, Y_prediction))

# %%
## plot the confusion matrix in a heat map
sns.heatmap(confusion_matrix(y_test, Y_prediction), annot=True, cmap="mako")

# %%
## feature importance
feat_importances = pd.Series(random_forest.feature_importances_, index=X.columns)
feat_importances.nlargest(13).plot(kind='barh')

# %%
try:
    conn = mysql.connector.connect(user='talhaamjad1@databasedemomysqlserver',
                                   password='Rubina123456',
                                   database='world',
                                   host="databasedemomysqlserver.mysql.database.azure.com",
                                   ssl_ca="/kaggle/input/ssl-connection/BaltimoreCyberTrustRoot.crt.pem")
                                   
    print(conn)
except mysql.connector.Error as err:
    print(err)

# %%
try:
    display = pd.read_sql_query("select * from country", conn)
    display
except mysql.connector.Error as err:
    print(err)

# %%
display.head()

# %%
display.info()

# %%
## plot the age feature 
sns.distplot(display["Population"])

# %%
## plot the age feature 
#sns.title(['Life Expantancy'])
sns.distplot(display["LifeExpectancy"])

# %%
try:
    language = pd.read_sql_query("Select country.Name, country.Continent, countrylanguage.Language, countrylanguage.Percentage from country inner join countrylanguage ON country.Code = countrylanguage.CountryCode", conn)
except mysql.connector.Error as err:
    print(err)

# %%
language.head()

# %%
sns.distplot(language["Percentage"])

# %%
try:
    perlang = pd.read_sql_query("select * from countrylanguage where CountryCode='ABW'", conn)
except mysql.connector.Error as err:
    print(err)

# %%
perlang

# %%
sizes = perlang['Percentage']
labels = perlang["Language"]

plt.pie(sizes, labels = labels, autopct = "%.2f")
plt.axes().set_aspect("equal")
plt.show()

# %%
try:
    perlanging = pd.read_sql_query("select * from countrylanguage where CountryCode='ABW'", conn)
except mysql.connector.Error as err:
    print(err)

# %%
perlanging

# %%
cur = conn.cursor()
x_query = cur.execute("Select country.Name, country.Continent, countrylanguage.Language, countrylanguage.Percentage from country inner join countrylanguage ON country.Code = countrylanguage.CountryCode LIMIT 50")

plt.xlabel('Country Name')
plt.ylabel('Population')

rows = cur.fetchall()
df = pd.DataFrame([[xy for xy in x] for x in rows])

x=df[0]
y=df[3]

plt.bar(x,y)
plt.figure(figsize=(30,5))

plt.show()
cur.close()

# %%
try:
    englanging = pd.read_sql_query("select * from countrylanguage where Language='English'", conn)
except mysql.connector.Error as err:
    print(err)

# %%
englanging

# %%
plt.xlabel('Country Name')
plt.ylabel('Population')

rows = cur.fetchall()
df = pd.DataFrame([[xy for xy in x] for x in rows])

x=df[0]
y=df[3]

sizes = englanging['Percentage']
labels = englanging["Language"]

#plt.pie(sizes, labels = labels, autopct = "%.2f")
#plt.axes().set_aspect("equal")
plt.bar(sizes,labels)
plt.figure(figsize=(30,5))
plt.show()
