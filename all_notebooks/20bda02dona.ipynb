# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from datetime import datetime
from sklearn import preprocessing
# %matplotlib inline

# %%
#importing the dataset
df=pd.read_csv("../input/ml-lab-exam/traindata_SJC.csv")

# %% [markdown]
# # Loading Dataset

# %%
#loading dataset
df

# %%
df.head()

# %% [markdown]
# # Data Preprocessing

# %%
df.info()   #data frame summary

# %%
df.describe(include="all")  #data summary

# %%
df.columns

# %%
df_clean=df[df!=' ?']

# %%
df_clean.shape,df.shape

# %%
df_clean[df_clean==" ?"].count()

# %%
df_clean.isnull().sum()

# %%
df_clean=df_clean.dropna()

# %%
df_clean.shape,df.shape

# %%
df_clean['MaritalStatus'].value_counts()

# %%
df_mode=df[df!=" ?"]

# %%
df_mode['MaritalStatus'].mode()

# %%
type(df_mode['MaritalStatus'].mode()) # Private is a series.so this won't be helpful

# %%
df_mode['MaritalStatus'].fillna(df_mode['MaritalStatus'].mode()).isnull().sum()## still there are missing values.fillna can't impute series

# %%
type(df_mode['MaritalStatus'].mode()[0])

# %%
df_mode['MaritalStatus']=df_mode['MaritalStatus'].fillna(df_mode['MaritalStatus'].mode()[0])

# %%
df_mode.isnull().sum()

# %%
df['WeeklyWages'].fillna(df['WeeklyWages'].mean(),inplace=True)

# %%
df['HoursWorkedPerWeek'].fillna(df['HoursWorkedPerWeek'].mean(),inplace=True)

# %%
df.isnull().sum()

# %%
df.columns

# %%
df.T

# %%
# Claim number seems to rise with time. Extract number  
df['ClaimNumberInt'] = df['ClaimNumber'].str[2:].astype(int)

# %%
# Some date features
df['YearOfAccident']  = pd.DatetimeIndex(df['DateTimeOfAccident']).year
df['MonthOfAccident']  = pd.DatetimeIndex(df['DateTimeOfAccident']).month
df['DayOfAccident']  = pd.DatetimeIndex(df['DateTimeOfAccident']).day
df['WeekdayOfAccident']  = pd.DatetimeIndex(df['DateTimeOfAccident']).day_name()
df['HourOfAccident']  = pd.DatetimeIndex(df['DateTimeOfAccident']).hour
df['YearReported']  = pd.DatetimeIndex(df['DateReported']).year

# %%
# Reporting delay in weeks 
df['DaysReportDelay'] = pd.DatetimeIndex(df['DateReported']).date - pd.DatetimeIndex(df['DateTimeOfAccident']).date
df['DaysReportDelay'] = (df['DaysReportDelay']  / np.timedelta64(1, 'D')).astype(int)
df['WeeksReportDelay'] = np.floor(df['DaysReportDelay'] / 7.).astype(int)
df['WeeksReportDelay'] = np.clip(df['WeeksReportDelay'], a_max=55, a_min=None)

# %%
# drop unneccessary columns
df.drop(['ClaimNumber','DateTimeOfAccident','DaysReportDelay','DateReported','ClaimDescription'],axis=1,inplace=True)
df.shape

# %%
df.head()

# %% [markdown]
# # EDA

# %%
plt.hist(data=df, x='Gender', bins=5,color='violet')
plt.xlabel('Gender')
plt.show()

# %%
plt.hist(data=df, x='PartTimeFullTime', bins=3,color='palevioletred')
plt.xlabel('PartTimeFullTime')
plt.show()

# %%
plt.hist(data=df, x='WeekdayOfAccident',color='skyblue')
plt.xlabel('WeekdayOfAccident')
plt.show()

# %%
sns.catplot(data=df,x='Age',col='Gender',kind='box',color='palevioletred')

# %%
sns.catplot(data=df,x='WeeklyWages',col='Gender',kind='violin',color='cyan')

# %%
sns.boxplot(data=df,x='DaysWorkedPerWeek')

# %%
# calcuate correlation matrix
corrmat = df.corr()

# Draw the heatmap 
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, annot=True, square=True, cmap='rainbow')
plt.show()

# %% [markdown]
# # Label Encoding

# %%
df.info()

# %%
import sklearn.preprocessing as pre
import sklearn.model_selection as ms

# %%
le=pre.LabelEncoder()

# %%
list_df=['Age','WeeklyWages','Gender','MaritalStatus','PartTimeFullTime','HoursWorkedPerWeek']

# %%
for x in list_df:
  df[x]=le.fit_transform(df[x].astype(str))

# %%
df

# %%
df.info()

# %% [markdown]
# # Model Selection

# %%
import sklearn.model_selection as ms
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df.columns

# %%
features = ['Age', 'Gender','MaritalStatus','DependentChildren', 'DependentsOther', 'WeeklyWages',
       'PartTimeFullTime', 'HoursWorkedPerWeek', 'DaysWorkedPerWeek',
        'InitialIncurredCalimsCost']
X = df[features]
Y = df['UltimateIncurredClaimCost']

# %%
x_train,x_test,y_train,y_test=ms.train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape

# %%
# Model initialization
regression_model = LinearRegression()
# Fit the data(train the model)
regression_model.fit(x_train,y_train)
# Predict
y_predicted = regression_model.predict(x_test)

# %%
y_predicted

# %%
regression_model.score(x_train,y_train)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from datetime import datetime
from sklearn import preprocessing
# %matplotlib inline

# %%
#importing the dataset
df1=pd.read_csv("../input/machine-learning-24-hrs-hackathon/Test_SJC.csv")

# %%
#loading dataset
df1

# %%
df1.head()

# %%
df1.info()   #data frame summary

# %%
df1.describe(include="all")  #data summary

# %%
df1.columns

# %%
df1_clean=df[df!=' ?']

# %%
df1_clean.shape,df.shape

# %%
df1_clean[df_clean==" ?"].count()

# %%
df1_clean.isnull().sum()

# %%
df1_clean=df_clean.dropna()

# %%
df1_clean.shape,df.shape

# %%
df1_clean['MaritalStatus'].value_counts()

# %%
df1_mode=df[df!=" ?"]

# %%
df1_mode['MaritalStatus'].mode()

# %%
type(df1_mode['MaritalStatus'].mode())

# %%
df1_mode['MaritalStatus'].fillna(df_mode['MaritalStatus'].mode()).isnull().sum()

# %%
type(df1_mode['MaritalStatus'].mode()[0])

# %%
df1_mode['MaritalStatus']=df_mode['MaritalStatus'].fillna(df_mode['MaritalStatus'].mode()[0])

# %%
df1_mode.isnull().sum()

# %%
df1.columns

# %%
df1.T

# %%
# Claim number seems to rise with time. Extract number  
df1['ClaimNumberInt'] = df1['ClaimNumber'].str[2:].astype(int)

# %%
# Some date features
df1['YearOfAccident']  = pd.DatetimeIndex(df1['DateTimeOfAccident']).year
df1['MonthOfAccident']  = pd.DatetimeIndex(df1['DateTimeOfAccident']).month
df1['DayOfAccident']  = pd.DatetimeIndex(df1['DateTimeOfAccident']).day
df1['WeekdayOfAccident']  = pd.DatetimeIndex(df1['DateTimeOfAccident']).day_name()
df1['HourOfAccident']  = pd.DatetimeIndex(df1['DateTimeOfAccident']).hour
df1['YearReported']  = pd.DatetimeIndex(df1['DateReported']).year

# %%
# Reporting delay in weeks 
df1['DaysReportDelay'] = pd.DatetimeIndex(df1['DateReported']).date - pd.DatetimeIndex(df1['DateTimeOfAccident']).date
df1['DaysReportDelay'] = (df1['DaysReportDelay']  / np.timedelta64(1, 'D')).astype(int)
df1['WeeksReportDelay'] = np.floor(df1['DaysReportDelay'] / 7.).astype(int)
df1['WeeksReportDelay'] = np.clip(df1['WeeksReportDelay'], a_max=55, a_min=None)

# %%
# drop unneccessary columns
df1.drop(['ClaimNumber','DateTimeOfAccident','DaysReportDelay','DateReported','ClaimDescription'],axis=1,inplace=True)
df1.shape

# %%
df1.head()

# %%
df1.info()

# %%
import sklearn.preprocessing as pre
import sklearn.model_selection as ms

# %%
le=pre.LabelEncoder()

# %%
list_df1=['Age','WeeklyWages','Gender','MaritalStatus','PartTimeFullTime','HoursWorkedPerWeek']

# %%
for x in list_df1:
  df1[x]=le.fit_transform(df1[x].astype(str))

# %%
df1

# %%
df1.info()

# %%
features = ['Age', 'Gender','MaritalStatus','DependentChildren', 'DependentsOther', 'WeeklyWages',
       'PartTimeFullTime', 'HoursWorkedPerWeek', 'DaysWorkedPerWeek',
        'InitialIncurredCalimsCost']
X_new = df1[features]

# %%
x_train,x_test,y_train,y_test=ms.train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
regression_model.predict(X_new)

# %%
sub=pd.read_csv('../input/machine-learning-24-hrs-hackathon/sample_submission.csv')
sub['UltimateIncurredClaimCost'] = regression_model.predict(X_new)
sub.to_csv('Regression.csv', index = False)
sub.head(5)
print(np.mean(sub['UltimateIncurredClaimCost']))
