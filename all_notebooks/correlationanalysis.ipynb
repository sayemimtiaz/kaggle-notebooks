# %% [markdown]
# ## Correlation Analysis between Beds num in a hospital and deaths

# %%
import pandas as pd

# %%
deaths_data = pd.read_csv("../input/data-cds-countries/data_cds_countries.csv")

# %%
deaths_data

# %% [markdown]
# ### Dropping unrelevant columns

# %%
columns_to_drop = ["city", "county", "state", "growth_factor"]
deaths_data.drop(columns_to_drop, axis=1, inplace=True)

# %%
deaths_data

# %%
percent_missing = deaths_data.isnull().sum() * 100 / len(deaths_data)
missing_value_df = pd.DataFrame({'column_name': deaths_data.columns,
                                 'percent_missing': percent_missing})
missing_value_df

# %% [markdown]
# Observable column has 50% missinng values out of all data which is bad

# %%
deaths_data = deaths_data[deaths_data['deaths'].notna()]

# %%
deaths_data

# %%
deaths_data = deaths_data.groupby(['country']).agg({'deaths': 'sum'}, inplace=True)

# %%
deaths_data

# %%
iso_codes = {"AF":"Afghanistan",
"AX":"Aland Islands",
"AL":"Albania",
"DZ":"Algeria",
"AS":"American Samoa",
"AD":"Andorra",
"AO":"Angola",
"AI":"Anguilla",
"AQ":"Antarctica",
"AG":"Antigua and Barbuda",
"AR":"Argentina",
"AM":"Armenia",
"AW":"Aruba",
"AU":"Australia",
"AT":"Austria",
"AZ":"Azerbaijan",
"BS":"Bahamas",
"BH":"Bahrain",
"BD":"Bangladesh",
"BB":"Barbados",
"BY":"Belarus",
"BE":"Belgium",
"BZ":"Belize",
"BJ":"Benin",
"BM":"Bermuda",
"BT":"Bhutan",
"BO":"Bolivia, Plurinational State of",
"BQ":"Bonaire, Sint Eustatius and Saba",
"BA":"Bosnia and Herzegovina",
"BW":"Botswana",
"BV":"Bouvet Island",
"BR":"Brazil",
"IO":"British Indian Ocean Territory",
"BN":"Brunei Darussalam",
"BG":"Bulgaria",
"BF":"Burkina Faso",
"BI":"Burundi",
"KH":"Cambodia",
"CM":"Cameroon",
"CA":"Canada",
"CV":"Cape Verde",
"KY":"Cayman Islands",
"CF":"Central African Republic",
"TD":"Chad",
"CL":"Chile",
"CN":"China",
"CX":"Christmas Island",
"CC":"Cocos (Keeling) Islands",
"CO":"Colombia",
"KM":"Comoros",
"CG":"Congo",
"CD":"Congo, The Democratic Republic of the",
"CK":"Cook Islands",
"CR":"Costa Rica",
"CI":"Côte d'Ivoire",
"HR":"Croatia",
"CU":"Cuba",
"CW":"Curaçao",
"CY":"Cyprus",
"CZ":"Czech Republic",
"DK":"Denmark",
"DJ":"Djibouti",
"DM":"Dominica",
"DO":"Dominican Republic",
"EC":"Ecuador",
"EG":"Egypt",
"SV":"El Salvador",
"GQ":"Equatorial Guinea",
"ER":"Eritrea",
"EE":"Estonia",
"ET":"Ethiopia",
"FK":"Falkland Islands (Malvinas)",
"FO":"Faroe Islands",
"FJ":"Fiji",
"FI":"Finland",
"FR":"France",
"GF":"French Guiana",
"PF":"French Polynesia",
"TF":"French Southern Territories",
"GA":"Gabon",
"GM":"Gambia",
"GE":"Georgia",
"DE":"Germany",
"GH":"Ghana",
"GI":"Gibraltar",
"GR":"Greece",
"GL":"Greenland",
"GD":"Grenada",
"GP":"Guadeloupe",
"GU":"Guam",
"GT":"Guatemala",
"GG":"Guernsey",
"GN":"Guinea",
"GW":"Guinea-Bissau",
"GY":"Guyana",
"HT":"Haiti",
"HM":"Heard Island and McDonald Islands",
"VA":"Holy See (Vatican City State)",
"HN":"Honduras",
"HK":"Hong Kong",
"HU":"Hungary",
"IS":"Iceland",
"IN":"India",
"ID":"Indonesia",
"IR":"Iran, Islamic Republic of",
"IQ":"Iraq",
"IE":"Ireland",
"IM":"Isle of Man",
"IL":"Israel",
"IT":"Italy",
"JM":"Jamaica",
"JP":"Japan",
"JE":"Jersey",
"JO":"Jordan",
"KZ":"Kazakhstan",
"KE":"Kenya",
"KI":"Kiribati",
"KP":"Korea, Democratic People's Republic of",
"KR":"Korea, Republic of",
"KW":"Kuwait",
"KG":"Kyrgyzstan",
"LA":"Lao People's Democratic Republic",
"LV":"Latvia",
"LB":"Lebanon",
"LS":"Lesotho",
"LR":"Liberia",
"LY":"Libya",
"LI":"Liechtenstein",
"LT":"Lithuania",
"LU":"Luxembourg",
"MO":"Macao",
"MK":"Macedonia, Republic of",
"MG":"Madagascar",
"MW":"Malawi",
"MY":"Malaysia",
"MV":"Maldives",
"ML":"Mali",
"MT":"Malta",
"MH":"Marshall Islands",
"MQ":"Martinique",
"MR":"Mauritania",
"MU":"Mauritius",
"YT":"Mayotte",
"MX":"Mexico",
"FM":"Micronesia, Federated States of",
"MD":"Moldova, Republic of",
"MC":"Monaco",
"MN":"Mongolia",
"ME":"Montenegro",
"MS":"Montserrat",
"MA":"Morocco",
"MZ":"Mozambique",
"MM":"Myanmar",
"NA":"Namibia",
"NR":"Nauru",
"NP":"Nepal",
"NL":"Netherlands",
"NC":"New Caledonia",
"NZ":"New Zealand",
"NI":"Nicaragua",
"NE":"Niger",
"NG":"Nigeria",
"NU":"Niue",
"NF":"Norfolk Island",
"MP":"Northern Mariana Islands",
"NO":"Norway",
"OM":"Oman",
"PK":"Pakistan",
"PW":"Palau",
"PS":"Palestinian Territory, Occupied",
"PA":"Panama",
"PG":"Papua New Guinea",
"PY":"Paraguay",
"PE":"Peru",
"PH":"Philippines",
"PN":"Pitcairn",
"PL":"Poland",
"PT":"Portugal",
"PR":"Puerto Rico",
"QA":"Qatar",
"RE":"Réunion",
"RO":"Romania",
"RU":"Russian Federation",
"RW":"Rwanda",
"BL":"Saint Barthélemy",
"SH":"Saint Helena, Ascension and Tristan da Cunha",
"KN":"Saint Kitts and Nevis",
"LC":"Saint Lucia",
"MF":"Saint Martin (French part)",
"PM":"Saint Pierre and Miquelon",
"VC":"Saint Vincent and the Grenadines",
"WS":"Samoa",
"SM":"San Marino",
"ST":"Sao Tome and Principe",
"SA":"Saudi Arabia",
"SN":"Senegal",
"RS":"Serbia",
"SC":"Seychelles",
"SL":"Sierra Leone",
"SG":"Singapore",
"SX":"Sint Maarten (Dutch part)",
"SK":"Slovakia",
"SI":"Slovenia",
"SB":"Solomon Islands",
"SO":"Somalia",
"ZA":"South Africa",
"GS":"South Georgia and the South Sandwich Islands",
"ES":"Spain",
"LK":"Sri Lanka",
"SD":"Sudan",
"SR":"Suriname",
"SS":"South Sudan",
"SJ":"Svalbard and Jan Mayen",
"SZ":"Swaziland",
"SE":"Sweden",
"CH":"Switzerland",
"SY":"Syrian Arab Republic",
"TW":"Taiwan, Province of China",
"TJ":"Tajikistan",
"TZ":"Tanzania, United Republic of",
"TH":"Thailand",
"TL":"Timor-Leste",
"TG":"Togo",
"TK":"Tokelau",
"TO":"Tonga",
"TT":"Trinidad and Tobago",
"TN":"Tunisia",
"TR":"Turkey",
"TM":"Turkmenistan",
"TC":"Turks and Caicos Islands",
"TV":"Tuvalu",
"UG":"Uganda",
"UA":"Ukraine",
"AE":"United Arab Emirates",
"GB":"United Kingdom",
"US":"United States",
"UM":"United States Minor Outlying Islands",
"UY":"Uruguay",
"UZ":"Uzbekistan",
"VU":"Vanuatu",
"VE":"Venezuela, Bolivarian Republic of",
"VN":"Viet Nam",
"VG":"Virgin Islands, British",
"VI":"Virgin Islands, U.S.",
"WF":"Wallis and Futuna",
"EH":"Western Sahara",
"YE":"Yemen",
"ZM":"Zambia",
"ZW":"Zimbabwe"}

# %%
data1 = pd.read_csv("../input/global-hospital-beds-capacity-for-covid19/hospital_beds_global_regional_v1.csv")

# %%
data1

# %%
data1.iloc[0]

# %%
data1.replace({"country": iso_codes}, inplace=True)

# %%
data1

# %%
beds_num = []
for x in range(len(data1)):
    beds_num.append((data1.iloc[x]["beds"] * data1.iloc[x]["population"])/1000)

beds_num

# %%
data1["beds"] = beds_num

# %%
data1

# %%
data1 = data1.groupby(['country']).agg({'beds': 'sum'})

# %%
merged_data = pd.merge(data1, deaths_data, on="country")

# %%
merged_data

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Deaths number distribution

# %%
import matplotlib.pyplot as plt

merged_data.deaths.plot.line(title="Deaths Number Distribution", legend="deaths")

# %% [markdown]
# Given column is not normally distributed and has a lot of outliers (imbalanced data).

# %% [markdown]
# ### Most affected countries by Covid-19

# %%
df = merged_data.nlargest(10, ["deaths"])
df.deaths.plot.bar(title="Top 10 countries by deaths number", align='center', legend="deaths")

# %% [markdown]
# ### Beds number in hospitals distribution

# %%
import matplotlib.pyplot as plt

merged_data.beds.plot.line(title="Beds Number in Hospitals Distribution", legend="beds")

# %% [markdown]
# The same tendency here. Data is imbalanced.

# %%
df = merged_data.nlargest(10, ["beds"])
df.deaths.plot.bar(title="Top 10 countries by number of hospital beds", align='center', legend="number of hospital beds")

# %% [markdown]
# This chart shows us countries that have a lot of beds in hospitals for ill people. Sadly, Italy is not here which resulted in high mortality.

# %% [markdown]
# ### Joint line which represents the relationship between two vars

# %%
merged_data.plot.line(title="Beds number in hospitals and deaths for each country")

# %% [markdown]
# It is clear that beds num and deaths are dependent but not linearly (loot at the plot). Now let's conduct some correlation analysis.

# %% [markdown]
# ### Correlation Analysis

# %%
from scipy.stats import pearsonr
corr, _ = pearsonr(merged_data["beds"], merged_data["deaths"])

# %% [markdown]
# #### Pearson

# %%
print("Pearson correlation is: ", corr)

# %% [markdown]
# A Pearson correlation is a number between -1 and 1 that indicates the extent to which two variables are linearly related.
# #### In our case, beds and deaths are not linearly dependet which we already could see in plot above.

# %%
from scipy.stats import spearmanr

corr, _ = spearmanr(merged_data["beds"], merged_data["deaths"])

# %% [markdown]
# #### Spearman

# %%
print("Spearman correlation is: ", corr)

# %% [markdown]
# The Spearman's rank-order correlation is the nonparametric version of the Pearson product-moment correlation. Spearman's correlation coefficient, (ρ, also signified by rs) measures the strength and direction of association between two ranked variables.
#
# #### There are definately dependent (0.7 is not long way from one). A correlation of 0.4 may not be strong enough to make a decision about relationship between two factors.

# %% [markdown]
# ### Correlation Matrix

# %%
merged_data.corr()
