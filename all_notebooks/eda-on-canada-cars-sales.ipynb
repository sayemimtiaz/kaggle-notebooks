# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#importing additional libariries
import matplotlib as plt
import missingno as msno
import seaborn as sns
# %matplotlib inline

# %%
#loading the data to start working with
df = pd.read_csv('/kaggle/input/canada-cars-sales-figures-20192021/Canadasalesdata.csv')

# %%
#understanding the data
#showing the first 10 rows
df.head(10)

# %%
#showing the last 10 of rows
df.tail(10)

# %%
#getting info about the data
df.info()

# %%
#how many rows and columns in the data?respectivelly
df.shape

# %%
#printing the columns names
df.columns

# %%
#is there any missing value in the data?
df.isnull().sum()

# %% [markdown]
# # ********** there is no missing value**

# %%
#now let us get summary statstics of the data
df.describe()

# %% [markdown]
# # ****Now let us answer some questions ****

# %% [markdown]
# # ************How meny cars were sold in canada in the last 3 years?
# *******

# %%
df.sum()['Sumofsales']

# %% [markdown]
# # How many number of cars were sold in each year?

# %%
df.groupby('Year').sum()['Sumofsales'].reset_index

# %% [markdown]
# **we can see that the 2019 has the hieghst sales and 2021 has the least sales******

# %% [markdown]
# #  what are the top 10 Cars by sales?

# %%
df.nlargest(10, ['Sumofsales'])

# %% [markdown]
# # How many number of sales of cars per category?

# %%
df.groupby('Category').sum()['Sumofsales'].reset_index

# %% [markdown]
# # How many number of cars were sold per category in each year?

# %%
df.groupby(['Category','Year']).sum()['Sumofsales'].reset_index

# %% [markdown]
# # How many number of sales per model?

# %%
df.groupby('Model').sum()['Sumofsales']

# %% [markdown]
# # How many number of sales per model for each year?

# %%
df.groupby(['Category','Model']).sum()['Sumofsales']
