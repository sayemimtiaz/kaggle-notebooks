# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv("/kaggle/input/the-human-freedom-index/hfi_cc_2018.csv")

# %%
df

# %%
#Obtener información de las columnas

df.info(verbose=True)

# %%
#Forma automatizada de obtener si la columna es cuantitativa o cualitativa

lista = list()

for i in df.iloc[0].values: #Analiza la primera fila
    try:
        if type(float(i)) == float:
            lista.append("cuantitativo")
    except:
        lista.append("cualitativo")
        
lista

# %%
columnas_cualitativas = list()

for i in range(1,4):
    columnas_cualitativas.append(df.columns[i])
    
columnas_cualitativas

# %%
columnas_cuantitativas = list()
columnas_cuantitativas.append(df.columns[0])
columnas_cuantitativas.extend(df.columns[4:])
columnas_cuantitativas

# %%
#Rango columnas cuantitativas

rangos = list()
for i in columnas_cuantitativas:
    rango = df.loc[:,i].max() - df.loc[:,i].min()
    rangos.append(rango)
    
rangos

# %%
#Promedio columnas cuantitativas

promedio = list()

for i in columnas_cuantitativas:
    promedio.append(df.loc[:,i].mean())
    
promedio

# %%
#Moda columnas cualitativas

from scipy import stats
moda = list()

for i in columnas_cualitativas:
    moda.append(stats.mode(df[i]))
    
moda

# %%
#Varianza columnas cuantitativas

varianza = list()

for i in columnas_cuantitativas:
    varianza.append(np.var(df[i]))
    
varianza

# %%
#Desviación estándar columnas cuantitativas

desviacion = list()

for i in columnas_cuantitativas:
    desviacion.append(np.std(df[i]))
    
desviacion
