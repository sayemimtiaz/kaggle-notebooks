# %% [markdown]
# # *India Covid 19 Data Analysis With Top 10 most affected States*

# %% [markdown]
# # What is Corona Virus :
# Coronavirus is a family of viruses that can cause illness, which can vary from common cold and cough to sometimes more severe disease. SARS-CoV-2 (n-coronavirus) is the new virus of the coronavirus family, which first discovered in 2019, which has not been identified in humans before. It is a contiguous virus which started from Wuhan in December 2019. Which later declared as Pandemic by WHO due to high rate spreads throughout the world. Currently (on date 27 March 2020), this leads to a total of 24K+ Deaths across the globe, including 16K+ deaths alone in Europe.Pandemic is spreading all over the world; it becomes more important to understand about this spread. This NoteBook is an effort to analyze the cumulative data of confirmed, deaths, and recovered cases over time. In this notebook, the main focus is to analyze the spread trend of this virus all over the india.
#
# # History of Covid 19 :
# On January 30, India reported its first case of COVID-19 in Kerala, which rose to three cases by February 3; all were students who had returned from Wuhan, China.No significant rise in cases was seen in the rest of February.
#
# On 22 March 2020, India observed a 14-hour voluntary public curfew at the instance of the prime minister Narendra Modi.The government followed it up with lockdowns in 75 districts where COVID cases had occurred as well as all major cities.Further, on 24 March, the prime minister ordered a nationwide lockdown for 21 days, affecting the entire 1.3 billion population of India.
#
# The transmission escalated during March, after several cases were reported all over the country, most of which were linked to people with a travel history to affected countries. On 12 March, a 76-year-old man who had returned from Saudi Arabia became the first victim of the virus in the country.On 4 March, 22 new cases came to light, including those of an Italian tourist group with 14 infected members.But number of cases start increasing dramtically after 19th March, but in the month of April it has been its peak.
#
# Experts suggest the number of infections could be much higher as India's testing rates are among the lowest in the world.The infection rate of COVID-19 in India is reported to be 1.7, significantly lower than in the worst affected countries.

# %%
import pandas as pd
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt

# %%
world_df = pd.read_csv("../input/covid19-india/world.csv")
vaccine_df = pd.read_csv("../input/covid19-in-india/covid_vaccine_statewise.csv")
cases_df = pd.read_csv("../input/covid19-in-india/covid_19_india.csv")
vaccine = vaccine_df[vaccine_df.State =="India"]

# %%
india_df = world_df[world_df.location == "India"]

# %%
india_df.head(10)

# %%
fig = px.line(india_df , x="date",y="new_cases" , title ="New Cases in India")

# %%
fig.show()

# %%
fig1 = px.line(india_df , x = "date" , y = "new_deaths" , title = " Deaths in india(due to covid)" )

# %%
fig1.show()

# %%
px.line(vaccine , x="Updated On" , y="Total Individuals Vaccinated",title = "Vaccination")

# %%
test_df = pd.read_csv("../input/covid19-in-india/StatewiseTestingDetails.csv")
test_df.head(10)

# %%
positivity_rate = (test_df["Positive"].sum() / test_df["TotalSamples"].sum()) *100

# %%
positivity_rate

# %%
pop =1380004385
toatl = cases_df.groupby(["Date"])["Confirmed"].sum()
for i in toatl:
    total_cases = i
total_cases

# %%
fig3 = px.pie(names = ["Total Population " , "Infected People"] , values = [pop , total_cases],title = "Percentage of people Infected in India")

# %%
fig3.show()

# %%
vaccine.tail(10)

# %%
male = vaccine.loc[110]["Male(Individuals Vaccinated)"]
female = vaccine.loc[110]["Female(Individuals Vaccinated)"]
trans = vaccine.loc[110]["Transgender(Individuals Vaccinated)"]

# %%
fig4 = px.pie(names = ["Male Vaccinated" , "Female Vaccinated" , "Transgender Vaccinated" , "Population"] , values =[male,female,trans,pop],title = "Male Female Vaccinated ratio in India")

# %%
fig4.show()

# %% [markdown]
# # Andhra Pradesh

# %%
Andhra_df_test = test_df[test_df["State"]=="Andhra Pradesh"]
Andhra_df_vaccine = vaccine_df[vaccine_df["State"]=="Andhra Pradesh"]
Andhra_df = cases_df[cases_df["State/UnionTerritory"]=="Andhra Pradesh"]

# %%
px.line(Andhra_df, x= "Date",y="Confirmed",title = "Cases in Andhra Pradesh")

# %%
px.line(Andhra_df_test , x = "Date" , y = "TotalSamples" , title = "Testing in Andhra Pradesh" )

# %%
px.line(Andhra_df , x="Date", y= "Deaths",title = "Deaths In Andhra Pradesh")

# %%
px.line(Andhra_df_vaccine , x="Updated On" , y = "Total Individuals Vaccinated",title ="Vaccination In Andhra Pradesh")

# %%
andhra_pop =49634314
cases = Andhra_df.loc[14619]["Confirmed"]

# %%
px.pie(names =["Total Population of Andhra Pradesh" , "Infected people in Andhra Pradesh"],values = [andhra_pop , cases],title = "Percentage of people infected in Andhra Pradesh")

# %%
male = Andhra_df_vaccine.loc[333]["Male(Individuals Vaccinated)"]
female = Andhra_df_vaccine.loc[333]["Female(Individuals Vaccinated)"]
trans = Andhra_df_vaccine.loc[333]["Transgender(Individuals Vaccinated)"]
px.pie(names = ["Male(Individuals Vaccinated)" , "Female(Individuals Vaccinated)" ,"Transgender(Individuals Vaccinated)"],values=[male,female,trans],title= "Male Female Vaccinated Ratio in Andhra Pradesh")

# %% [markdown]
# # Maharashtra

# %%
m_df = cases_df[cases_df["State/UnionTerritory"] == "Maharashtra"]
mv_df = vaccine_df[vaccine_df["State"]=="Maharashtra"]
mt_df = test_df[test_df["State"]=="Maharashtra"]

# %%
m_df.tail()

# %%
mv_df.tail()

# %%
mt_df.tail()

# %%
px.line(m_df , x = "Date" , y="Confirmed" , title = "Cases In Maharashta")

# %%
px.line(m_df , x = "Date" , y= "Deaths" , title = "Deaths in Maharashtra")

# %%
px.line(mt_df , x = "Date" , y="TotalSamples"  , title ="Tests in Maharashtra")

# %%
px.line(mv_df , x = "Updated On" , y="Total Individuals Vaccinated" , title = "Vaccination in Maharshtra")

# %%
m_pop = 20668000
total_cases = m_df.loc[14638]["Confirmed"]
px.pie(names =["Total Population" , "Cases"] ,values = [m_pop , total_cases] , title = "Infected people Percentage")

# %%
male  = mv_df.loc[2460]["Male(Individuals Vaccinated)"]
female =mv_df.loc[2460]["Female(Individuals Vaccinated)"]
trans = mv_df.loc[2460]["Transgender(Individuals Vaccinated)"]
px.pie(names = ["Male (Individual Vaccinated)" , "Female (Individual Vaccinated)", "Transgender (Individual Vaccinated)","Population"] , values =[male,female,trans,m_pop],title = "Male female Vaccinated Ration In Maharashtra")

# %% [markdown]
# # Karnataka

# %%
k_df = cases_df[cases_df["State/UnionTerritory"] == "Karnataka"]
kv_df = vaccine_df[vaccine_df["State"]=="Karnataka"]
kt_df = test_df[test_df["State"]=="Karnataka"]

# %%
fig=px.line(k_df , x = "Date" , y="Confirmed" , title = "Cases In Karnataka")
fig1=px.line(k_df , x = "Date" , y= "Deaths" , title = "Deaths in Karnataka")
fig3 = px.line(kt_df , x = "Date" , y="TotalSamples"  , title ="Tests in Karnataka")
fig4 = px.line(kv_df , x = "Updated On" , y="Total Individuals Vaccinated" , title = "Vaccination in Karnataka")

# %%
fig.show()

# %%
fig1.show()

# %%
fig3.show()

# %%
fig4.show()

# %%
k_pop = 61095297
total_cases = k_df.loc[14633]["Confirmed"]
px.pie(names =["Total Population" , "Cases"] , values =[k_pop,total_cases])

# %%
male  = kv_df.loc[1900]["Male(Individuals Vaccinated)"]
female =kv_df.loc[1900]["Female(Individuals Vaccinated)"]
trans = kv_df.loc[1900]["Transgender(Individuals Vaccinated)"]
px.pie(names = ["Male (Individual Vaccinated)" , "Female (Individual Vaccinated)", "Transgender (Individual Vaccinated)","Population"] , values =[male,female,trans,k_pop],title = "Male female Vaccinated Ration In Karnataka")

# %% [markdown]
# # Kerala

# %%
ke_df = cases_df[cases_df["State/UnionTerritory"] == "Kerala"]
kev_df = vaccine_df[vaccine_df["State"]=="Kerala"]
ket_df = test_df[test_df["State"]=="Kerala"]
fig=px.line(k_df , x = "Date" , y="Confirmed" , title = "Cases In Kerala")
fig1=px.line(k_df , x = "Date" , y= "Deaths" , title = "Deaths in Kerala")
fig3 = px.line(kt_df , x = "Date" , y="TotalSamples"  , title ="Tests in Kerala")
fig4 = px.line(kv_df , x = "Updated On" , y="Total Individuals Vaccinated" , title = "Vaccination in kerala")

# %%
fig.show()

# %%
fig1.show()

# %%
fig3.show()

# %%
fig4.show()

# %%
ke_pop = 33406061
total_cases = ke_df.loc[14634]["Confirmed"]
px.pie(names =["Total Population" , "Cases"] , values =[ke_pop,total_cases],title = "Infected people in Kerala")

# %%
male  = kev_df.loc[2012]["Male(Individuals Vaccinated)"]
female =kev_df.loc[2012]["Female(Individuals Vaccinated)"]
trans = kev_df.loc[2012]["Transgender(Individuals Vaccinated)"]
px.pie(names = ["Male (Individual Vaccinated)" , "Female (Individual Vaccinated)", "Transgender (Individual Vaccinated)","Population"] , values =[male,female,trans,k_pop],title = "Male female Vaccinated Ration In Kerala")

# %% [markdown]
# # Uttar Pradesh

# %%
up_df = cases_df[cases_df["State/UnionTerritory"] == "Uttar Pradesh"]
upv_df = vaccine_df[vaccine_df["State"]=="Uttar Pradesh"]
upt_df = test_df[test_df["State"]=="Uttar Pradesh"]
fig=px.line(up_df , x = "Date" , y="Confirmed" , title = "Cases In Uttar Pradesh")
fig1=px.line(up_df , x = "Date" , y= "Deaths" , title = "Deaths in Uttar Pradesh")
fig3 = px.line(upt_df , x = "Date" , y="TotalSamples"  , title ="Tests in Uttar Pradesh")
fig4 = px.line(upv_df , x = "Updated On" , y="Total Individuals Vaccinated" , title = "Vaccination in Uttar Pradesh")

# %%
fig.show()

# %%
fig1.show()

# %%
fig3.show()

# %%
fig4.show()

# %%
up_pop = 199812341
total_cases = up_df.loc[14652]["Confirmed"]
fig5 =px.pie(names =["Total Population" , "Cases"] , values =[up_pop,total_cases],title = "Infected people in Uttar pradesh")
male  = upv_df.loc[3916]["Male(Individuals Vaccinated)"]
female =upv_df.loc[3916]["Female(Individuals Vaccinated)"]
trans = upv_df.loc[3916]["Transgender(Individuals Vaccinated)"]
fig6 = px.pie(names = ["Male (Individual Vaccinated)" , "Female (Individual Vaccinated)", "Transgender (Individual Vaccinated)","Population"] , values =[male,female,trans,up_pop],title = "Male female Vaccinated Ratio In Uttar pradesh")

# %%
fig5.show()

# %%
fig6.show()

# %% [markdown]
# # Tamil Nadu

# %%
tn_df = cases_df[cases_df["State/UnionTerritory"] == "Tamil Nadu"]
tnv_df = vaccine_df[vaccine_df["State"]=="Tamil Nadu"]
tnt_df = test_df[test_df["State"]=="Tamil Nadu"]
fig=px.line(tn_df , x = "Date" , y="Confirmed" , title = "Cases In Tamil Nadu")
fig1=px.line(tn_df , x = "Date" , y= "Deaths" , title = "Deaths in Tamil Nadu")
fig3 = px.line(tnt_df , x = "Date" , y="TotalSamples"  , title ="Tests in Tamil Nadu")
fig4 = px.line(tnv_df , x = "Updated On" , y="Total Individuals Vaccinated" , title = "Vaccination in Tamil Nadu")
tn_pop = 77841267
total_cases = tn_df.loc[14648]["Confirmed"]
fig5 =px.pie(names =["Total Population" , "Cases"] , values =[tn_pop,total_cases],title = "Infected in Tamil Nadu")
male  = tnv_df.loc[3580]["Male(Individuals Vaccinated)"]
female =tnv_df.loc[3580]["Female(Individuals Vaccinated)"]
trans = tnv_df.loc[3580]["Transgender(Individuals Vaccinated)"]
fig6 = px.pie(names = ["Male (Individual Vaccinated)" , "Female (Individual Vaccinated)", "Transgender (Individual Vaccinated)","Population"] , values =[male,female,trans,tn_pop],title = "Male female Vaccinated Ratio In Tamil Nadu")

# %%
fig.show()

# %%
fig1.show()

# %%
fig3.show()

# %%
fig4.show()

# %%
fig5.show()

# %%
fig6.show()

# %% [markdown]
# # Delhi

# %%
de_df = cases_df[cases_df["State/UnionTerritory"] == "Delhi"]
dev_df = vaccine_df[vaccine_df["State"]=="Delhi"]
det_df = test_df[test_df["State"]=="Delhi"]
fig=px.line(de_df , x = "Date" , y="Confirmed" , title = "Cases In Delhi")
fig1=px.line(de_df , x = "Date" , y= "Deaths" , title = "Deaths in Delhi")
fig3 = px.line(det_df , x = "Date" , y="TotalSamples"  , title ="Tests in Delhi")
fig4 = px.line(dev_df , x = "Updated On" , y="Total Individuals Vaccinated" , title = "Vaccination in Delhi")
de_pop = 31181000
total_cases = de_df.loc[14626]["Confirmed"]
fig5 =px.pie(names =["Total Population" , "Cases"] , values =[de_pop,total_cases],title ="Infected people in Delhi")
male  = dev_df.loc[1117]["Male(Individuals Vaccinated)"]
female =dev_df.loc[1117]["Female(Individuals Vaccinated)"]
trans = dev_df.loc[1117]["Transgender(Individuals Vaccinated)"]
fig6 = px.pie(names = ["Male (Individual Vaccinated)" , "Female (Individual Vaccinated)", "Transgender (Individual Vaccinated)","Population"] , values =[male,female,trans,de_pop],title = "Male female Vaccinated Ratio In Delhi")

# %%
fig.show()

# %%
fig1.show()

# %%
fig3.show()

# %%
fig4.show()

# %%
fig5.show()

# %%
fig6.show()

# %% [markdown]
# # West Bengal

# %%
wb_df = cases_df[cases_df["State/UnionTerritory"] == "West Bengal"]
wbv_df = vaccine_df[vaccine_df["State"]=="West Bengal"]
wbt_df = test_df[test_df["State"]=="West Bengal"]
fig=px.line(wb_df , x = "Date" , y="Confirmed" , title = "Cases In West Bengal")
fig1=px.line(wb_df , x = "Date" , y= "Deaths" , title = "Deaths in West Bengal")
fig3 = px.line(wbt_df , x = "Date" , y="TotalSamples"  , title ="Tests in West Bengal")
fig4 = px.line(wbv_df , x = "Updated On" , y="Total Individuals Vaccinated" , title = "Vaccination in West Bengal")
wb_pop = 99609303
total_cases = wb_df.loc[14653]["Confirmed"]
fig5 =px.pie(names =["Total Population" , "Cases"] , values =[wb_pop,total_cases],title ="Infected people in West Bengal")
male  = wbv_df.loc[4140]["Male(Individuals Vaccinated)"]
female =wbv_df.loc[4140]["Female(Individuals Vaccinated)"]
trans = wbv_df.loc[4140]["Transgender(Individuals Vaccinated)"]
fig6 = px.pie(names = ["Male (Individual Vaccinated)" , "Female (Individual Vaccinated)", "Transgender (Individual Vaccinated)","Population"] , values =[male,female,trans,wb_pop],title = "Male female Vaccinated Ratio In West Bengal")

# %%
fig.show()

# %%
fig1.show()

# %%
fig3.show()

# %%
fig4.show()

# %%
fig5.show()

# %%
fig6.show()

# %% [markdown]
# # Chhattisgarh

# %%
c_df = cases_df[cases_df["State/UnionTerritory"] == "Chhattisgarh"]
cv_df = vaccine_df[vaccine_df["State"]=="Chhattisgarh"]
ct_df = test_df[test_df["State"]=="Chhattisgarh"]
fig=px.line(de_df , x = "Date" , y="Confirmed" , title = "Cases In Chhattisgarh")
fig1=px.line(de_df , x = "Date" , y= "Deaths" , title = "Deaths in Chhattisgarh")
fig3 = px.line(det_df , x = "Date" , y="TotalSamples"  , title ="Tests in Chhattisgarh")
fig4 = px.line(dev_df , x = "Updated On" , y="Total Individuals Vaccinated" , title = "Vaccination in Chhattisgarh")
c_pop = 25545198
total_cases = c_df.loc[14624]["Confirmed"]
fig5 =px.pie(names =["Total Population" , "Cases"] , values =[c_pop,total_cases],title ="Infected people in Chhattisgarh")
male  = cv_df.loc[893]["Male(Individuals Vaccinated)"]
female =cv_df.loc[893]["Female(Individuals Vaccinated)"]
trans = cv_df.loc[893]["Transgender(Individuals Vaccinated)"]
fig6 = px.pie(names = ["Male (Individual Vaccinated)" , "Female (Individual Vaccinated)", "Transgender (Individual Vaccinated)","Population"] , values =[male,female,trans,c_pop],title = "Male female Vaccinated Ratio In Chhattisgarh")

# %%
fig.show()

# %%
fig1.show()

# %%
fig3.show()

# %%
fig4.show()

# %%
fig5.show()

# %%
fig6.show()

# %% [markdown]
# # Rajasthan

# %%
r_df = cases_df[cases_df["State/UnionTerritory"] == "Rajasthan"]
rv_df = vaccine_df[vaccine_df["State"]=="Rajasthan"]
rt_df = test_df[test_df["State"]=="Rajasthan"]
fig=px.line(r_df , x = "Date" , y="Confirmed" , title = "Cases In Rajasthan")
fig1=px.line(r_df , x = "Date" , y= "Deaths" , title = "Deaths in Rajasthan")
fig3 = px.line(rt_df , x = "Date" , y="TotalSamples"  , title ="Tests in Rajasthan")
fig4 = px.line(rv_df , x = "Updated On" , y="Total Individuals Vaccinated" , title = "Vaccination in Rajasthan")
r_pop = 68548437
total_cases = r_df.loc[14646]["Confirmed"]
fig5 =px.pie(names =["Total Population" , "Cases"] , values =[r_pop,total_cases],title ="Infected people in Rajasthan")
male  = rv_df.loc[3356]["Male(Individuals Vaccinated)"]
female =rv_df.loc[3356]["Female(Individuals Vaccinated)"]
trans = rv_df.loc[3356]["Transgender(Individuals Vaccinated)"]
fig6 = px.pie(names = ["Male (Individual Vaccinated)" , "Female (Individual Vaccinated)", "Transgender (Individual Vaccinated)","Population"] , values =[male,female,trans,r_pop],title = "Male female Vaccinated Ratio In Rajasthan")

# %%
fig.show()

# %%
fig1.show()

# %%
fig3.show()

# %%
fig4.show()

# %%
fig5.show()

# %%
fig6.show()
