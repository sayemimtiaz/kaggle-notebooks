# %%
from IPython.display import Image
Image("../input/seshat-images/Seshat 1.jpg")

# %%
Image("../input/seshat-images/Seshat 2.jpg")

# %% [markdown]
# <h2 style = "font-family: garamond; font-size: 40px; font-style: normal; letter-spcaing: 3px; background-color:Gray; color : #fed049; border-radius: 5px 5px; text-align:center; font-weight: bold" >A brief history</h2>
#
# The concept of the axial age, initially proposed by the philosopher Karl Jaspers to refer to a period  that spans between 5300 BCE and 1800 CE that saw the rise of major religious and philosophical figures and ideas has gained an established position in a number of fields, including historical sociology, cultural sociology, and the sociology of religion.
#
# According to Jaspers the Axial Age is "an interregnum between two ages of great empire, a pause for liberty, a deep breath bringing the most lucid consciousness". It has also been suggested that the Axial Age was a historically liminal period, when old certainties had lost their validity and new ones were still not ready.
#
# <h2 style = "font-family: garamond; font-size: 40px; font-style: normal; letter-spcaing: 3px; background-color:Gray; color : #fed049; border-radius: 5px 5px; text-align:center; font-weight: bold" >About the Organisation</h2>
#
# The Seshat: Global History Databank is an international scientific research project of the nonprofit Evolution Institute. Founded in 2011, the Seshat: Global History Databank gathers data into a single, large database that can be used to test scientific hypotheses.
#
# The Seshat: Global History Databank is an umbrella organization for numerous research projects that examine different facets or themes of human life. Each project is headed by various members of the Seshat Team along with a group of consultants and contributing experts. Support for our research comes from a variety of private donors, academic, and governmental funding sources.
#
#
# The Seshat: Global History Databank claims to be a scientific approach to historical research and its large dataset, though compiled with the intention of being theory-neutral, is frequently of interest to researchers of cliodynamics. The main goal of cliodynamics researchers is to use the scientific method to produce the data necessary to empirically test competing theories.
#
# <h2 style = "font-family: garamond; font-size: 40px; font-style: normal; letter-spcaing: 3px; background-color:Gray; color : #fed049; border-radius: 5px 5px; text-align:center; font-weight: bold" >About the Dataset and the Project</h2>
#
# The  vast  amount  of  knowledge  about  past  human  societies  has  not  been  systematically  organized  and,  therefore,  remains  inaccessible  for empirically   testing   theories   about   cultural   evolution   and   historical  dynamics.  For  example,  what  evolutionary  mechanisms  were  involved  in  the  transition  from  the small-scale,  uncentralized societies, in which humans lived 10,000 years ago, to the large-scalesocieties  with  an  extensive  division  of  labor,  great  differentials  in  wealth  and  power,  and elaborate  governance  structures  of  today? Why do modern states sometimes fail to meet the basic needs of their populations?  Why  do  economies  decline,  or  fail  to  grow?  In  this  article, we describe  the  structure  and  uses  of a  massive  databank of historical and archaeological information, Seshat: The Global History Databank. The data that we are currently entering in Seshat will allow us  and  others  to  test  theories  explaining  how  modern  societies  evolved from ancestral ones, and why modern societies vary so much in their capacity to satisfy their members’ basic human needs.
#
# There are 15 variables, let's understand them.
#
# * Date.From :- This refers to the Year from which the data about the particular region is taken into account. Negative dates refer to the BCE.
#
# * NGA :- NGA stands for "Natural Geographic Area". These regions are mentioned below.Image is taken from Bhuvan's notebook : https://www.kaggle.com/bhuvanchennoju/ancient-roots-of-agriculture-a-data-overview

# %%
Image("../input/image-seshat/Screenshot (427).png")

# %% [markdown]
# * Moralistic Punishment : This column on a scale of 0 to 1 gives the information about the moral punishment followed in that particular NGA in the given period of time.
#
# * Moralizing Norms : Moral norms are the rules of morality that people ought to follow. An evolutionary explanation of the emergence of moral norms proceeds in stages
#
# * Promotion of Prosociality : Prosocial behavior, or intent to benefit others is a social behavior that "benefits other people or society as a whole such as helping, sharing, donating, co-operating, and volunteering.
#
# * Omniscient supernatural beings : On a scale of 0 to 1, belief of that civilisation in the given period in existence of supernatural beings.
#
# * Rulers not gods : Believing in the rulers and not gods
#
# * Equating elites and commoners : How much equality was practiced between the elites and the commoners.
#
# * Equating rulers and commoners : Equality between rulers and commoners. Although this seems like same as the previous column but looking at the data there are difference between the values given to them. Essentially the difference might be on the basis that not every noble belonged to the ruling class.
#
# * Formal legal code :  A code of law that purports to exhaustively cover a complete system of laws or a particular area of law as it existed at the time the code was enacted, by a process of codification.
#
# * General Applicability of Law : If law was followed and were decisions made were based on formal legal code.
#
# * Constraint on executive : How freely were executives allowed to make the final decision
#
# * Full-time bureaucrats
#
# * 12. Impeachment : Impeachment, in common law, a proceeding instituted by a legislative body to address serious misconduct by a public official
#
# * Sum : Total sum of all these parameters mentioned above.

# %% [markdown]
# **Let's start working on the dataset now.**

# %% [markdown]
# <a id = '1.1'></a>
# <h2 style = "font-size:30px; font-family:Garamond ; font-weight : normal; background-color: Gray; color :#fed049   ; text-align: center; border-radius: 5px 5px; padding: 5px"> Imports and Understanding the data</h2>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import missingno as msno
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("../input/axial-age-dataset/AxialAgeDataset.csv")
df.head()

# %%
df.info()

# %% [markdown]
# **Observations :**
#
# * So,there are 428 rows and 15 columns in our dataset.
# * We can also take a glance at the Data types of all the columns.
# * We can see that there are a lot of null values in few of the columns.
# * Let's explore it in a bit more detail.

# %% [markdown]
# <a id = '1.1'></a>
# <h2 style = "font-size:30px; font-family:Garamond ; font-weight : normal; background-color: Gray; color :#fed049   ; text-align: center; border-radius: 5px 5px; padding: 5px"> Data Cleaning and Preprocessing</h2>

# %%
msno.matrix(df)

# %% [markdown]
# MSNO matrix gives us the information on the missingness of the data. Looking at the graph above, we can conclude that most of the missing values are in the same rows, i.e very less information is there about the NGA from so and so period.

# %%
msno.dendrogram(df)

# %% [markdown]
# A dendrogram is a diagram that shows the hierarchical relationship between objects. It is most commonly created as an output from hierarchical clustering.The key to interpreting a dendrogram is to focus on the height at which any two objects are joined together.

# %%
import random

fig = plt.figure(figsize=(10,5),dpi=100)
axes = fig.add_axes([0.1,0.1,0.9,0.9])

# Create a donut chart
cols = [i for i in df.columns if df[i].isnull().sum()!=0]

vals = [df[i].isnull().sum() for i in df.columns if df[i].isnull().sum()!=0]



colors = []

for i in range(18):
    colors.append((random.uniform(0,1),random.uniform(0,1),random.uniform(0,1)))

plt.pie(vals,colors=colors,labels=cols,autopct='%1.1f%%')
my_circle=plt.Circle( (0,0), 0.7, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('Percentage of Null Values')
plt.show()

# %% [markdown]
# **Observations :**
#
# Looking at the MSNO matrix and the donut chart above, almost all the columns except two have the approximate same percentage of missing values and those values belongs to same rows.

# %%
plt.figure(figsize=(12,12))
msno.heatmap(df,cmap='PiYG')

# %% [markdown]
# **The heatmap shows a positive correlation. The darker the shade, the more the correlation.** Heatmap also shows the same kind of relationship between the null values.

# %%
df.isna().sum()

# %% [markdown]
# Since the data that is not available for the given NGA, the most logical reason might be that there is not that parameter introduced in that region during that period of time.
# So let's replace all NA values with 0.

# %%
df = df.fillna(0)

# %% [markdown]
# **Let's clean the names of the columns, like omit spaces,numbers and any other special symbols and reassign then to dataframe.**

# %%
cols = pd.Series(df.columns)
cols = cols.apply(lambda x: x[3:].replace(' ','_') if x[0].isdigit()==True else x)
cols[11:14] = cols[11:14].apply(lambda x: x[1:])
cols
df.columns = cols
df

# %%
df.columns = ['Date.From', 'NGA', 'Moralistic_punishment', 'Moralizing_norms',
       'Promotion_of_prosociality', 'Omniscient_supernatural_beings',
       'Rulers_not_gods', 'Equating_elites_and_commoners',
       'Equating_rulers_and_commoners', 'Formal_legal_code',
       'General_applicability_of_law', 'Constraint_on_executive',
       'Full-time_bureaucrats', 'Impeachment', 'sum']
#df.rename(columns= "onstraint_on_executive": "Constraint_on_executive", "ull-time_bureaucrats": "Full-time_bureaucrats","mpeachment" : "Impeachment")

# %% [markdown]
# **Make another df for all the interger values seperated.**

# %%
Parameter_col = df[['Moralistic_punishment','Moralizing_norms','Promotion_of_prosociality',
                     'Omniscient_supernatural_beings','Rulers_not_gods',
'Equating_elites_and_commoners','Equating_rulers_and_commoners','Formal_legal_code','General_applicability_of_law','Constraint_on_executive', 'Full-time_bureaucrats',
                     'Impeachment']]

# %%
Parameter_colS = df[['NGA', 'Moralistic_punishment','Moralizing_norms','Promotion_of_prosociality',
                     'Omniscient_supernatural_beings','Rulers_not_gods',
'Equating_elites_and_commoners','Equating_rulers_and_commoners','Formal_legal_code','General_applicability_of_law','Constraint_on_executive', 'Full-time_bureaucrats',
                     'Impeachment']]

# %% [markdown]
# <a id = '1.1'></a>
# <h2 style = "font-size:30px; font-family:Garamond ; font-weight : normal; background-color: Gray; color :#fed049   ; text-align: center; border-radius: 5px 5px; padding: 5px"> Exploratory Data Analysis </h2>

# %%
plt.figure(figsize=(12,12))
corr = df.corr()
#sns.heatmap(corr, cmap='Purple')
sns.heatmap(corr, cmap='Reds', vmax=.3, center=0,
           square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot = True)

# %% [markdown]
# * Formal_regal_code goes is highly corelated with Moralizing_norms, general applicability of law and moralizing norms as we can see from their correlations.
# * Moralistic Punishment is correlated with Omniscient and Supernatural beings and we can probably assume this way that the belief of gods in people impacted the moralistic punishments
# * Equating elites with commoners has a high correlation with equating rulers with commoners as we already saw the similar trends in various graphs
# * In the places where people believed that their rulers are supreme, we can see that the equality of elites and commoners and equality of rulers and commoners is nearly equal to 0.

# %%
plt.figure(figsize=(14,10))
plt.scatter(df['Date.From'],df['NGA'],marker= '+', color='red')
plt.xlabel("Date",fontweight='bold',fontsize=12)
plt.ylabel("NGA",fontweight='bold',fontsize=12)
plt.title("NGAs vs Time Periods", fontweight='bold',fontsize=16)
plt.tight_layout()
plt.xticks(rotation=50)

# %% [markdown]
# **Observation:** The above graph shows the NGAs and their existence with respect to the time frame.
# For example Kansai NGA is the oldest or say was the oldest as it does not have any existence since 1800 according to our data. Cambodian Basin is the most recent NGA that is still prevalent.

# %%
ts=df.groupby(["Date.From"])["NGA"].count()
plt.figure(figsize=(16,10))
plt.title('Count of NGAs running through the period', fontweight='bold',fontsize=16)
plt.xlabel('Time',fontweight='bold',fontsize=12)
plt.ylabel('Count',fontweight='bold',fontsize=12)
plt.plot(ts,color='red');

# %% [markdown]
# **Observation: As we can see from plot above, the number of NGAs with increasing morals and laws were increasing till 1800s but a slight decline from there.**

# %%
td=df.groupby(["Date.From"])["sum"].mean()
plt.figure(figsize=(16,10))
plt.title('Mean of parameters with Time',fontweight='bold',fontsize=16)
plt.xlabel('Time',fontweight='bold',fontsize=12)
plt.ylabel('Mean of Sum',fontweight='bold',fontsize=12)
plt.plot(td,color='red');

# %% [markdown]
# **Observation: The above graph is in correlation with the number of NGAs increase, as their mean of sum of all parameters are going to increase as well. But what we see here is that their is not that much increase in the number of NGAs from BCE 1000 to AD 0 , but the parameters mean increased, suggesting that this was the period where most of the existing NGAs adopted more equality , more law and order and more morality.**

# %%
td=df.groupby(["Date.From"])["sum"].mean()
plt.figure(figsize=(16,10))
plt.title('Mean of parameters with Time',fontweight='bold',fontsize=16)
plt.xlabel('Time')
plt.ylabel('Mean of Sum')
pd.plotting.lag_plot(td, lag=2)
plt.xlabel('Time',fontweight='bold',fontsize=12)
plt.ylabel('Mean of Sum',fontweight='bold',fontsize=16)

# %% [markdown]
# > The basic idea of the periods of the NGAs.

# %%
plt.figure(figsize=(14,10))
sns.barplot(data=df, y="NGA",x='Date.From', palette="pastel")
plt.title('Occurence of NGA',fontweight='bold',fontsize=16)
plt.xlabel('Time',fontweight='bold',fontsize=12)
plt.ylabel('NGA',fontweight='bold',fontsize=12)

# %%
import statsmodels.api as sm
# multiplicative
res = sm.tsa.seasonal_decompose(ts.values,period=12,model="multiplicative")
plt.figure(figsize=(16,12))
fig = res.plot()

# %% [markdown]
# > Trend of the NGAs Count.

# %%
print(df['NGA'].value_counts())
plt.figure(figsize=(12,10))
sns.countplot(df['NGA'],palette='terrain')
plt.title('NGA counts',fontweight='bold',fontsize=16)
plt.xlabel('NGA',fontweight='bold',fontsize=12)
plt.ylabel('Count',fontweight='bold',fontsize=12)
plt.xticks(rotation=50)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.hist(df['Date.From'],color='lightcoral')
plt.title('Frequency of NGA',fontweight='bold',fontsize=16)
plt.xlabel('Year',fontweight='bold',fontsize=12)
plt.ylabel('NGA Count',fontweight='bold',fontsize=12)
plt.xticks(rotation=50)

# %% [markdown]
# > The above graph shows the frequency of the NGAs in every time period.

# %%
fig=plt.figure(figsize=(20,30))
background_color = '#f6f5f7'
fig.patch.set_facecolor(background_color) 
plt.title('Sociopolitical Norms Counts')
for indx,val in enumerate(Parameter_col.columns):
    ax=plt.subplot(6,2,indx+1)
    ax.set_facecolor(background_color)
    #ax.set_title(val,fontweight='bold',fontfamily='serif')
    ax.set_xlabel(val,fontweight='bold',fontfamily='serif',fontsize=12)
    ax.set_ylabel('count',fontweight='bold',fontfamily='serif',fontsize=12)

    for i in ['top','right']:
        ax.spines[i].set_visible(False)
    ax.grid(linestyle=':',axis='y')
    sns.countplot(Parameter_col[val],palette='OrRd')

# %% [markdown]
# **Observation:**
#
# **The above plot can show us that promotion of proscality was important to people regardless of the NGA or the timeperiod.**
#
# **Similarly, by seeing the counts we can predict many things like there was almost no impeachmment and that there was very little equality between the rulers and commoners.**
#
# **Most of the NGAs have the proper law and order.**

# %%
fig=plt.figure(figsize=(20,30))
background_color = '#f6f5f7'
fig.patch.set_facecolor(background_color) 
for indx,val in enumerate(Parameter_col.columns):
    ax=plt.subplot(6,2,indx+1)
    leg=plt.legend()
    ax.get_legend().remove()
    ax.set_facecolor(background_color)
    ax.set_xlabel(val,fontweight='bold',fontfamily='serif',fontsize=12)
    ax.set_ylabel('count',fontweight='bold',fontfamily='serif',fontsize=12)

    for i in ['top','right']:
        ax.spines[i].set_visible(False)
    ax.grid(linestyle=':',axis='y')
    sns.countplot(Parameter_col[val],palette='OrRd',hue=df['NGA'])

# %% [markdown]
# **The above plot shows the count of each parameter with respect to the NGAs.**

# %% [markdown]
# **Grouping by NGA and taking the mean of all the parameters seperately.**

# %%
t1=df.groupby(["NGA"])["Moralizing_norms"].mean()
t2=df.groupby(["NGA"])["Promotion_of_prosociality"].mean()
t3=df.groupby(["NGA"])["Omniscient_supernatural_beings"].mean()
t4=df.groupby(["NGA"])["Rulers_not_gods"].mean()
t5=df.groupby(["NGA"])["Equating_elites_and_commoners"].mean()
t6=df.groupby(["NGA"])["Equating_rulers_and_commoners"].mean()
t7=df.groupby(["NGA"])["Formal_legal_code"].mean()
t8=df.groupby(["NGA"])["General_applicability_of_law"].mean()
t9=df.groupby(["NGA"])["Constraint_on_executive"].mean()
t10=df.groupby(["NGA"])["Full-time_bureaucrats"].mean()
t11=df.groupby(["NGA"])["Moralistic_punishment"].mean()

# %%
tz=df.groupby(["NGA"])["Moralistic_punishment"].mean()

plt.figure(figsize=(16,8))
plt.title('Mean of Moralistic punishment with NGA', fontweight='bold',fontsize=16)
plt.xlabel('NGA',fontweight='bold',fontsize=12)
plt.ylabel('Mean Values',fontweight='bold',fontsize=12)
plt.plot(tz,color='red');

# %% [markdown]
# **The above chart shows that the Moralistic Punishment was the least in Kansai and Middle Yellow River Valley and highest in the Gailee region across the Axial Age.**

# %% [markdown]
# > **Similarly let's plot every Sociopolitical norms to help us get the idea of all the variables across every NGA in the Axial Age.**

# %%
plt.figure(figsize=(20,25))

plt.subplot(6, 2, 1)
plt.plot(t1,color='red')
plt.xticks(rotation=90)
plt.title('Mean of Moralizing_norms with NGA', fontweight='bold',fontsize=12)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off



plt.subplot(6,2,2)
plt.plot(t2,color='red')
plt.xticks(rotation=90)
plt.title('Mean of Promotion_of_prosociality with NGA', fontweight='bold',fontsize=12)

plt.tick_params(
    axis='x',          
    which='both',      
    bottom=False,      
    top=False,         
    labelbottom=False)


plt.subplot(6, 2, 3)
plt.plot(t3,color='red')
plt.xticks(rotation=90)
plt.title('Mean of Omniscient_supernatural_beings with NGA', fontweight='bold',fontsize=12)

plt.tick_params(
    axis='x',          
    which='both',       
    bottom=False,      
    top=False,          
    labelbottom=False) 

plt.subplot(6,2,4)
plt.plot(t4,color='red')
plt.xticks(rotation=90)
plt.title('Mean of Rulers_not_gods with NGA', fontweight='bold',fontsize=12)

plt.tick_params(
    axis='x',          
    which='both',       
    bottom=False,      
    top=False,          
    labelbottom=False) 

plt.subplot(6, 2, 5)
plt.plot(t5,color='red')
plt.xticks(rotation=90)
plt.title('Mean of Equating_elites_and_commoners with NGA', fontweight='bold',fontsize=12)

plt.tick_params(
    axis='x',          
    which='both',       
    bottom=False,      
    top=False,          
    labelbottom=False) 

plt.subplot(6,2,6)
plt.plot(t6,color='red')
plt.xticks(rotation=90)
plt.title('Mean of Equating_rulers_and_commoners with NGA', fontweight='bold',fontsize=12)

plt.tick_params(
    axis='x',          
    which='both',       
    bottom=False,      
    top=False,          
    labelbottom=False) 

plt.subplot(6, 2, 7)
plt.plot(t7,color='red')
plt.xticks(rotation=90)
plt.title('Mean of Formal_legal_code with NGA', fontweight='bold',fontsize=12)

plt.tick_params(
    axis='x',          
    which='both',       
    bottom=False,      
    top=False,          
    labelbottom=False) 

plt.subplot(6,2,8)
plt.plot(t8,color='red')
plt.xticks(rotation=90)
plt.title('Mean of General_applicability_of_law with NGA', fontweight='bold',fontsize=12)

plt.tick_params(
    axis='x',          
    which='both',       
    bottom=False,      
    top=False,          
    labelbottom=False) 

plt.subplot(6, 2, 9)
plt.plot(t9,color='red')
plt.xticks(rotation=90)
plt.title('Mean of Constraint_on_executive with NGA', fontweight='bold',fontsize=12)

plt.tick_params(
    axis='x',          
    which='both',       
    bottom=False,      
    top=False,          
    labelbottom=False) 

plt.subplot(6,2,10)
plt.plot(t10,color='red')
plt.xticks(rotation=90)
plt.title('Mean of Full-time_bureaucrats with NGA', fontweight='bold',fontsize=12)

plt.tick_params(
    axis='x',          
    which='both',       
    bottom=False,      
   top=False,          
    labelbottom=False) 

plt.subplot(6, 2, 11)
plt.plot(t11,color='red')
plt.xticks(rotation=90,fontweight='bold',fontsize=12)
plt.title('Mean of Impeachment with NGA', fontweight='bold',fontsize=12)


plt.subplot(6,2,12)
plt.plot(tz,color='red')
plt.xticks(rotation=90,fontweight='bold',fontsize=12)
plt.title('Mean of Moralistic_punishment with NGA', fontweight='bold',fontsize=12)


plt.show()

# %% [markdown]
# <a id = '1.1'></a>
# <h2 style = "font-size:30px; font-family:Garamond ; font-weight : normal; background-color: Gray; color :#fed049   ; text-align: center; border-radius: 5px 5px; padding: 5px"> Conclusion</h2>

# %% [markdown]
# **1.** Moralistic Punishment was the least in Kansai and Middle Yellow River Valley and highest in the Gailee region across the Axial Age.
#
# **2.** Promotion of proscality was important to people regardless of the NGA or the timeperiod.
#
# **3.** We can see that the social norms of equality between elites and commoners and rulers and commoners are literally same in Cambodian Basin region,. This can be interpreted as the social norm grew in existence in these time periods due to a variety of factors not known.
#
# **4.** In the Upper Egypt region, commoners were treated equally with the elites for a prolonged period of time while the notion of treating rulers and commoners equally came around in the late 1000 CE.
#
# **5.** The number of NGAs with increasing morals and laws were increasing till 1800s but a slight decline from there.
#
# **6.** Formal_regal_code goes is highly corelated with Moralizing_norms, general applicability of law and moralizing norms as we can see from their correlations.
#
# **7.** Moralistic Punishment is correlated with Omniscient and Supernatural beings and we can probably assume this way that the belief of gods in people impacted the moralistic punishments.
#
# **8.** Equating elites with commoners has a high correlation with equating rulers with commoners as we already saw the similar trends in various graphs.
#
# **9.** In the places where people believed that their rulers are supreme, we can see that the equality of elites and commoners and equality of rulers and commoners is nearly equal to 0.
#
# **10.** There has been a constant increase in the sociopolitical norms in every NGA with time. More following of norms and this might have happened with awareness, as people became more aware with time, the norms spread.

# %% [markdown]
#  <p style = "font-size:30px; color: lightcoral"><strong> Thanks for following up the notebook this far. I will keep updating this as I learn more and till then happy analysing.
#     Please upvote if you like the work!
#    </strong></p>
