# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
kg = pd.read_csv("../input/covid19-healthy-diet-dataset/Food_Supply_Quantity_kg_Data.csv")
pt = pd.read_csv("../input/covid19-healthy-diet-dataset/Protein_Supply_Quantity_Data.csv")
kcal = pd.read_csv("../input/covid19-healthy-diet-dataset/Food_Supply_kcal_Data.csv")
fat = pd.read_csv("../input/covid19-healthy-diet-dataset/Fat_Supply_Quantity_Data.csv")
cols = [
 'Alcoholic Beverages',
 'Animal Products',
 'Animal fats',
 'Aquatic Products, Other',
 'Cereals - Excluding Beer',
 'Eggs',
 'Fish, Seafood',
 'Fruits - Excluding Wine',
 'Meat',
 'Milk - Excluding Butter',
 'Offals',
 'Oilcrops',
 'Pulses',
 'Spices',
 'Starchy Roots',
 'Stimulants',
 'Sugar Crops',
 'Sugar & Sweeteners',
 'Treenuts',
 'Vegetal Products',
 'Vegetable Oils',
 'Vegetables',
 'Miscellaneous',
 'Obesity',
 'Undernourished',
]
cols = ["Animal Products", "Vegetal Products"]

# %%
kg_mat = kg[cols]
fat_mat = fat[cols]
pt_mat = pt[cols]
kcal_mat = kcal[cols]

# %%
kg_mat = np.array(kg_mat.dropna(axis=1))
fat_mat = np.array(fat_mat.dropna(axis=1))
pt_mat = np.array(pt_mat.dropna(axis=1))
kcal_mat = np.array(kcal_mat.dropna(axis=1))

# %%
list((fat_mat*kg_mat).sum(axis=1))

# %%
list((pt_mat*kg_mat).sum(axis=1))
