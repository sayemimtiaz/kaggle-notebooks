# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.linear_model import LinearRegression
import math
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("../input/pharmacokinetics-of-theophylline/Theoph.csv")

# %%
df

# %%
df = df.drop("Unnamed: 0",axis = 1)

# %%
df

# %%
df_conc = df.reset_index()["conc"]

# %%
plt.plot(df_conc)

# %%
df_conc

# %%
grouped = df.groupby(df.Subject)

# %%
# names = []
# for num in range(1,12):
#     df_name = 'df_'+str(int(num))
#     names.append(df_name)

# %%
df_person_1 = grouped.get_group(1)

# %%
df_person_1

# %%
df_person_1_conc = df_person_1[["conc"]]

# %%
plt.xlabel("Time")
plt.ylabel("Concentration")
plt.plot(df_person_1_conc.Time,df_person_1_conc.conc)

# %%
scaler = MinMaxScaler(feature_range=(0,1))
df_person_1_conc = scaler.fit_transform(np.array(df_person_1_conc).reshape(-1,1))

# %%
df_person_1_conc

# %%
plt.plot(df_person_1_conc)
