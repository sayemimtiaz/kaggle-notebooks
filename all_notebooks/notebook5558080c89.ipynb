# %%
# !mv ../input/yolov5/* ./

# %%
# !python detect.py  --img 1024 --weights ../input/newyolov5/best.pt ../input/newyolov5/last.pt --source ../input/aicrowdwheatdata/test --save-txt --save-conf --nosave --augment
