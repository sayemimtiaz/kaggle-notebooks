# %% [markdown]
# # Amazon Top 50 Bestselling Books 2009-2019

# %% [markdown]
# ![amazon](https://images.hindustantimes.com/img/2021/02/18/550x309/2021-02-17T190607Z_1_LYNXMPEH1G1JH_RTROPTP_3_AMAZON-INDIA-OPERATION_1613626487873_1613626497052.JPG)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
book = pd.read_csv("/kaggle/input/amazon-top-50-bestselling-books-2009-2019/bestsellers with categories.csv")
book.head()

# %% [markdown]
# # Exploring the Dataset

# %%
print(f"The dataset contains {book.shape[0]} records and {book.shape[1]} columns.")

# %%
book.info()

# %%
book.isnull().sum()

# %%
book['Name'].value_counts()

# %%
Categorical_data = list(book.select_dtypes(exclude=('int', 'float')).columns)
print(f'Сolumns with categorical data are: {", ".join(Categorical_data)}.')

# %%
for i in Categorical_data:
    if book[i].duplicated().any() == True:
        print(f"{i} contains dulpicate values.")
    else:
        continue

# %%
book.drop_duplicates(Categorical_data, keep = 'first', inplace = True)
book

# %%
book['User Rating'] >= book['User Rating'].max()

# %% [markdown]
# # **Exploratory Data Analysis** 📊📈

# %%
x = book['Price']
y = book['Reviews']
rng = np.random.RandomState(0)
colors = rng.rand(351)
sizes = 1000 * rng.rand(351)

plt.scatter(x, y,s=sizes, c=colors, alpha=0.3,
            cmap='viridis')
plt.colorbar();

# %%
sns.lineplot(
    data=book, x="User Rating", y="Price", hue="Genre",
    sizes=(.25, 2.5),
)
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(16,10))
fig.delaxes(axs[1,1])

axs[0, 0].hist(book['Reviews'])
axs[1,0].hist(book['Year'], bins=50)
axs[0,1].hist2d(book['User Rating'], book['Reviews'])

plt.show()

# %%
# A pairplot visualizes how each variable depends on other variables
sns.pairplot(book)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.violinplot(x ='Year', y ='Reviews', data = book, hue ='Genre', split = True) 
plt.show()

# %% [markdown]
# # ****Random Forests Classifiers: To predict Genre****

# %%
X = np.array(book[['Reviews', 'Price', 'Year', 'User Rating']])
Y = np.array(book[['Genre']]).ravel()

# %%
# Import train_test_split function
from sklearn.model_selection import train_test_split

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.3,random_state=109) # 70% training and 30% test

# %%
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model 
clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# %%
y1_pred = clf.predict(X_test)
y1_pred
