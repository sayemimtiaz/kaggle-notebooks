# %% [markdown]
# ![](https://media.wired.com/photos/5909610d76f462691f012d7a/master/w_1600%2Cc_limit/BALL_GIRL_FIELDS_GROUNDER.gif)
# ##### [Source](https://media.wired.com/photos/5909610d76f462691f012d7a/master/w_1600%2Cc_limit/BALL_GIRL_FIELDS_GROUNDER.gif)

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">Do you know?</h1>
#     <h3 style="text-align:center;font-weight: bold">1) The record for the most wins in Olympic baseball is Cuba which earned its 3rd gold medal in 2004.</h3>
#     <h3 style="text-align:center;font-weight: bold">2) Leroy Robert `Satchel’ Paige is the oldest baseball player at 59 years 80 days on September 25, 1965.</h3>
#     <h3 style="text-align:center;font-weight: bold">3) The first and only woman ever inducted into the Baseball Hall of Fame is American sports executive Effa Louise Manley.</h3>
#
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold"> Introduction </h1></div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold">About the Dataset</h1>
#     <h3 style="text-align:left;font-weight: bold">A data frame with 322 observations of major league players on the following 20 variables.
#     </h3>
# <ul>
# <li>AtBat: Number of times at bat in 1986</li>
# <li>Hits: Number of hits in 1986</li>
# <li>HmRun: Number of home runs in 1986</li>
# <li>Runs: Number of runs in 1986</li>
# <li>RBI: Number of runs batted in in 1986</li>
# <li>Walks: Number of walks in 1986</li>
# <li>Years: Number of years in the major leagues</li>
# <li>CAtBat: Number of times at bat during his career</li>
# <li>CHits: Number of hits during his career</li>
#     <li>CHmRun: Number of home runs during his career</li>
#     <li>CRuns: Number of runs during his career</li>
#     <li>CRBI: Number of runs batted in during his career</li>
#     <li>CWalks: Number of walks during his career</li>
#     <li>League: A factor with levels A and N indicating player's league at the end of 1986</li>
#     <li>Division: A factor with levels E and W indicating player's division at the end of 1986</li>
#     <li>PutOuts: Number of put outs in 1986</li>
#     <li>Assists: Number of assists in 1986</li>
#     <li>Errors: Number of errors in 1986</li>
#     <li>Salary: 1987 annual salary on opening day in thousands of dollars</li>
#     <li>NewLeague: A factor with levels A and N indicating player's league at the beginning of 1987</li>
# </ul>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold">Importing Libraries</h1></div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold">LuciferML</h1>
#     <h3 style="text-align:center;font-weight: bold">This is my own ML-Library whose purpose is to take away all your hassles and does all the hard work for you. It's currently in development stage. Preprocesses and Trains different models on your Data. More about LuciferML <a href = "https://github.com/d4rk-lucif3r/LuciferML">here</a></h3>
#
#
# </div>

# %%
pip install lucifer-ml

# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
plt.style.use('dark_background')
import pandas as pd
import seaborn as sns
import plotly.express as px

## Importing LuciferML
from luciferml.supervised.regression import Regression

import warnings
warnings.simplefilter(action='ignore', category=Warning)

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold">Importing Dataset</h1></div>

# %%
dataset = pd.read_csv('../input/hitters-baseball-data/Hitters.csv')

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold">Exploratory Data Analysis</h1></div>

# %%
dataset.head()

# %%
dataset.shape

# %%
dataset.isnull().sum()

# %%
dataset.info()

# %%
dataset = dataset.dropna()

# %%
dataset.describe().T.style.bar(
    subset=['mean'],
    color='#606ff2').background_gradient(
    subset=['std'], cmap='PuBu').background_gradient(subset=['50%'], cmap='PuBu')

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold">✨Visualisations✨</h2></div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold">Bar Plots</h2></div>

# %%
fig = px.bar(dataset, y = 'NewLeague',color="Salary", template = 'plotly_dark')
fig.show()

# %% [markdown]
# ### Above plots shows the distribution of New Leagues among Different Salaries

# %%
fig = px.histogram(dataset, y="League", x="Salary", color="Runs",
                   hover_data=dataset.columns, template = 'plotly_dark', title = 'Salary with League in relation with Runs')
fig.show()

# %% [markdown]
# ### Above plots shows the Current Leagues with Salary represented by Runs

# %%
plt.figure(figsize=(12, 6))
sns.countplot(y="League", data=dataset, palette='husl');

# %% [markdown]
# ### Above plot shows there are around 140 count for Player's of League A and around 125 for League N

# %%
plt.figure(figsize=(12, 6))
sns.countplot(y="NewLeague", data=dataset, palette='husl');

# %% [markdown]
# ### Above plot shows the Count for each New League

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold">Bubbled Scatter</h2></div>

# %%
fig = px.scatter(dataset,
                 x="Hits", y='CAtBat', size="Salary", color="Runs",
                 log_x=True, size_max=60,
                 template='plotly_dark', title='Hits vs CAtBat')
fig.show()

# %% [markdown]
# ### Above plot shows the **Hits** for different **CAtBat** intensified by their respective **Runs** and their size is the representation of their **Salary**.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold">Heatmaps</h2></div>

# %%
fig = px.density_heatmap(dataset, x="Salary", y ="Years",title = 'Salary vs Years of Experience', template = 'plotly_dark')
fig.show()

# %% [markdown]
# ### Above Heatmap shows the intensity Salary of Players with respect to their Years of Experience.
# ## From above plot we can conclude that Salary is proportional to Years of Experience of Players and there are large number of players with lesser experience

# %%
fig = px.density_heatmap(dataset, x="Salary", y ="Runs",title = 'Salary vs Runs', template = 'plotly_dark')
fig.show()

# %% [markdown]
# ### Above Heatmap shows the intensity of Salary with respect to their Runs.
# ## From above plot we can conclude that Salary of a Player is Linearly proportional to Runs scored by them.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold">Ternary Scatter</h2></div>

# %%
fig = px.scatter_ternary(dataset, a="Salary", b="Assists", c="Errors",hover_name="Division",
    color="Runs", template = 'plotly_dark',size="Hits", size_max=30,)
fig.show()

# %% [markdown]
# ### Above plot shows the ratio of Salary , Assists and Errors of a Player intensified by their Runs.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold">3-D Scatter</h2></div>

# %%
fig = px.scatter_3d(dataset, x='Runs', y='Salary', z='Years',
              color='CRuns', template = 'plotly_dark', title = 'Distribution of Runs and Salary of players with Carreer Runs')
fig.show()

# %% [markdown]
# ### Above plot is a 3-d Representaion of Runs of players with their Salary and Years of Experience.
#
# ## From Above plot we the player with highest carreer run have highest salaries

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold">Box Plot</h2></div>

# %%
fig = px.box(dataset, x="Salary", y="League", template = 'plotly_dark', 
             title = 'Salary with League')
fig.show()

# %% [markdown]
# ## From Above plot we can conclude
# 1. Players in League A have High Max Salary
# 2. Players in League N have Low Max Salary

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold">Pie Charts</h2></div>

# %%
fig = px.pie(dataset, names='NewLeague', values='Errors', template = 'plotly_dark', 
             title = 'Representation of New Leagues with Errors')
fig.show()

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold">Correlation Plot</h2></div>

# %%
fig = px.imshow(dataset.corr(), template = 'plotly_dark')
fig.show()

# %% [markdown]
# ## From above Correlation Heatmap we can conclude:
# 1. AtBat have high correlation with Runs

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold">Pairplot</h2></div>

# %%
sns.pairplot(dataset, hue="Salary", palette="husl");

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold">Data Preprocessing</h1></div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h3 style="text-align:center;font-weight: bold">Splitting Dataset into Features and Labels. Features are independent Variable and Labels are dependentn Variable. I have Selected Salary as Dependent Variable and will predict them in next stage.</h3></div>

# %%
dataset.head()

# %%
features = dataset.drop('Salary', axis = 1)
labels = dataset.iloc[:, -2]

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold">Let's Train Some Models</h1></div>

# %%
accuracy_scores =  {}
RMSE= {}
regression = {}

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold">Linear Regression</h2></div>

# %%
params_lin ={'fit_intercept': True, 'positive': True}
regressor = Regression(predictor = 'lin', params=params_lin, pca='y', pca_kernel = 'rbf', n_components_pca =3)
regressor.fit(features, labels)
result = regressor.result()
accuracy_scores[result['Regressor']] = result['Accuracy']
RMSE[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold">Support Vector Regressor</h2></div>

# %%
params_svr = {'C': 10000.0, 'gamma': 0.8, 'kernel': 'rbf'}
regressor = Regression(predictor = 'svr', params= params_svr, pca='y', pca_kernel = 'rbf',n_components_pca =3)
regressor.fit(features, labels)
result = regressor.result()
accuracy_scores[result['Regressor']] = result['Accuracy']
RMSE[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold">K-Neighbours Regressor</h2></div>

# %%
params_knr={'algorithm': 'auto', 'n_neighbors': 15, 'weights': 'distance'}
regressor = Regression(predictor = 'knr',params= params_knr, pca='y', pca_kernel = 'rbf', n_components_pca =3)
regressor.fit(features, labels)
result = regressor.result()
accuracy_scores[result['Regressor']] = result['Accuracy']
RMSE[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold">Stochastic Gradient Descent Regressor</h2></div>

# %%
params_sgd ={'alpha': 0.4, 'eta0': 100, 'fit_intercept': True, 'learning_rate': 'optimal', 'loss': 'squared_loss', 'penalty': 'l1'}
regressor = Regression(predictor = 'sgd', params= params_sgd, pca='y', pca_kernel = 'rbf', n_components_pca =3)
regressor.fit(features, labels)
result = regressor.result()
accuracy_scores[result['Regressor']] = result['Accuracy']
RMSE[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold">Elastic Net Regressor</h2></div>

# %%
params_elas={'alpha': 1, 'l1_ratio': 1}
regressor = Regression(predictor = 'elas', params= params_elas, pca='y', pca_kernel = 'rbf', n_components_pca =3)
regressor.fit(features, labels)
result = regressor.result()
accuracy_scores[result['Regressor']] = result['Accuracy']
RMSE[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold">Kernel Ridge Regressor</h2></div>

# %%
params_krr = {'alpha': 1, 'gamma': 0.1}
regressor = Regression(predictor = 'krr', params= params_krr, pca='y', pca_kernel = 'rbf', n_components_pca =3)
regressor.fit(features, labels)
result = regressor.result()
accuracy_scores[result['Regressor']] = result['Accuracy']
RMSE[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold">Bayessian Ridge Regressor</h2></div>

# %%
params_br = {'alpha_1': 0.0001, 'alpha_2': 0.9, 'lambda_1': 0.001}
regressor = Regression(predictor = 'br', params= params_br, pca='y', pca_kernel = 'rbf', n_components_pca =3)
regressor.fit(features, labels)
result = regressor.result()
accuracy_scores[result['Regressor']] = result['Accuracy']
RMSE[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold">Decision Trees</h2></div>

# %%
params_dt = {'criterion': 'mse', 'max_depth': 6, 'max_leaf_nodes': 20, 'min_samples_leaf': 20}
regressor = Regression(predictor = 'dt',params= params_dt, pca='y', pca_kernel = 'rbf', n_components_pca =3)
regressor.fit(features, labels)
result = regressor.result()
accuracy_scores[result['Regressor']] = result['Accuracy']
RMSE[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold">Random Forest</h2></div>

# %%
params_rfr = {}
regressor = Regression(predictor = 'rfr',params= params_rfr, pca='y', pca_kernel = 'rbf', n_components_pca =3)
regressor.fit(features, labels)
result = regressor.result()
accuracy_scores[result['Regressor']] = result['Accuracy']
RMSE[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold">XGBoost Regressor</h2></div>

# %%
params_xgb = {}

regressor = Regression(predictor = 'xgb',params= params_xgb, pca='y', pca_kernel = 'rbf', n_components_pca =3)
regressor.fit(features, labels)
result = regressor.result()
accuracy_scores[result['Regressor']] = result['Accuracy']
RMSE[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold">Gradient Boosting Regressor</h2></div>

# %%
params_gbr = {'criterion': 'mae', 'learning_rate': 0.02, 'loss': 'ls', 'max_depth': 4, 
              'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 300, 'subsample': 0.2}
regressor = Regression(predictor = 'gbr',params= params_gbr, pca='y', pca_kernel = 'rbf', n_components_pca =3)
regressor.fit(features, labels)
result = regressor.result()
accuracy_scores[result['Regressor']] = result['Accuracy']
RMSE[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold">LightGradient Boosting Machine</h2></div>

# %%
params_lgbm = {'colsample_bytree': 1.0, 'min_child_weight': 1, 
               'n_estimators': 100, 'reg_alpha': 100, 'reg_lambda': 100, 'subsample': 0.6}

regressor = Regression(predictor = 'lgbm',params= params_lgbm, pca='y', pca_kernel = 'rbf', n_components_pca =3)
regressor.fit(features, labels)
result = regressor.result()
accuracy_scores[result['Regressor']] = result['Accuracy']
RMSE[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold">CatBoost</h2></div>

# %%
params_cat ={'depth': 4, 'iterations': 30, 'l2_leaf_reg': 0.5, 'learning_rate': 0.1}

regressor = Regression(predictor = 'cat',params= params_cat, pca='y', pca_kernel = 'rbf', n_components_pca =3)
regressor.fit(features, labels)
result = regressor.result()
accuracy_scores[result['Regressor']] = result['Accuracy']
RMSE[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold">Neural Network</h2></div>

# %%
regressor = Regression(predictor = 'ann', pca='y', pca_kernel = 'rbf', 
                       n_components_pca =3,batch_size = 20, input_units = 10, epochs = 300)
regressor.fit(features, labels)
result = regressor.result()
accuracy_scores[result['Regressor']] = result['Accuracy']
RMSE[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold">Finding which model performed better.</h2></div>

# %%
maxKey = max(accuracy_scores, key=lambda x: accuracy_scores[x])
print('The model with highest K-Fold Validation Accuracy score is  {0} with an accuracy of  {1:.2f}'.format(
    maxKey, accuracy_scores[maxKey]))

# %%
maxKey = min(RMSE, key=lambda x: RMSE[x])
print('The model with Lowest RMSE is {0} with RMSE of  {1:.2f}'.format(
    maxKey, RMSE[maxKey]))

# %%
plt.figure(figsize=(12, 6))
model_accuracies = list(accuracy_scores.values())
model_names = list(accuracy_scores.keys())
sns.barplot(x=model_accuracies, y=model_names, palette='YlOrBr');
plt.title('Accuracy for Regressors');

# %%
plt.figure(figsize=(12, 6))
model_accuracies = list(RMSE.values())
model_names = list(RMSE.keys())
sns.barplot(x=model_accuracies, y=model_names, palette='YlOrBr');
plt.title('RMSE for Regressors');

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold">🎉And the Winners are🎉</h1>
# <h2 style="text-align:center;font-weight: bold">Highest R2 Score - Support Vector Regressor</h2>
#     <h2 style="text-align:center;font-weight: bold">Lowest RMSE - K-Neighbors Regressor</h2>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#8fa2ff;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold">Please share your feedback in the comment section. I'll be more than happy to hear ya'll and If you liked my work and learned from it Please Consider Upvoting.</h1>
#
# </div>
