# %% [markdown]
# # https://github.com/Tarunkumar111/Human-Activity-Recognition-Problem-ML/blob/master/Human%20Activity%20Recognition%20Problem.ipynb

# %% [markdown]
# # If you like it, please upvote.
