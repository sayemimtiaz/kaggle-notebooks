# %% [markdown]
# **Top 250 de las transferencias mas costosas del futbol**

# %% [markdown]
# ## Objectivo
#
#
# El futbol mueve millones de dolares en la transferencia de jugadores de futbol,
# me gustaria saber si los equipos y/o ligas que mas mueven jugadores son los mas ganadores?
# o hay equipos que aunque no sean los mas ganadores se dedican es al negocio de tranferir jugadores?
#
# Cuales son las ligas que mas mueven jugadores?
#
# que posiciones en el campo de juego son las mas buscadas por los equipos,o que posiciones son las mas
# transferidas.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import re

from sklearn.preprocessing import MinMaxScaler
import seaborn           as sns   # visualizations
import matplotlib.pyplot as plt   # visualizations
from bokeh.io import output_notebook, show

import folium
import pylab as pl

import scipy.stats                # statistics
from sklearn import preprocessing

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['top250-00-19.csv']

# %%
data_topsoccer0="../input/top250-00-19.csv"
df_topsoccer0 = pd.read_csv(data_topsoccer0)
df_topsoccer=pd.DataFrame(data=df_topsoccer0)
df_topsoccer.head()
# Out:
#                 Name        Position     ...       Market_value Transfer_fee
# 0          Luís Figo    Right Winger     ...                nan     60000000
# 1      Hernán Crespo  Centre-Forward     ...                nan     56810000
# 2      Marc Overmars     Left Winger     ...                nan     40000000
# 3  Gabriel Batistuta  Centre-Forward     ...                nan     36150000
# 4     Nicolas Anelka  Centre-Forward     ...                nan     34500000
#
# [5 rows x 10 columns]

# %%
print(df_topsoccer.head(3))
print(df_topsoccer.info())
print(df_topsoccer.columns)
print(df_topsoccer.dtypes)
print(df_topsoccer.tail(3))
type(df_topsoccer)
# Out:
#             Name        Position     ...       Market_value Transfer_fee
# 0      Luís Figo    Right Winger     ...                nan     60000000
# 1  Hernán Crespo  Centre-Forward     ...                nan     56810000
# 2  Marc Overmars     Left Winger     ...                nan     40000000
#
# [3 rows x 10 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4700 entries, 0 to 4699
# Data columns (total 10 columns):
# Name            4700 non-null object
# Position        4700 non-null object
# Age             4700 non-null int64
# Team_from       4700 non-null object
# League_from     4700 non-null object
# Team_to         4700 non-null object
# League_to       4700 non-null object
# Season          4700 non-null object
# Market_value    3440 non-null float64
# Transfer_fee    4700 non-null int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 367.3+ KB
# None
# Index(['Name', 'Position', 'Age', 'Team_from', 'League_from', 'Team_to',
#        'League_to', 'Season', 'Market_value', 'Transfer_fee'],
#       dtype='object')
# Name             object
# Position         object
# Age               int64
# Team_from        object
# League_from      object
# Team_to          object
# League_to        object
# Season           object
# Market_value    float64
# Transfer_fee      int64
# dtype: object
#                Name        Position     ...       Market_value Transfer_fee
# 4697  Silvan Widmer      Right-Back     ...         8500000.00      4500000
# 4698     Yuya Osako  Second Striker     ...         4500000.00      4500000
# 4699   Kyle Bartley     Centre-Back     ...         3500000.00      4500000
#
# [3 rows x 10 columns]
# pandas.core.frame.DataFrame

# %% [markdown]
#  ## Exploracion de  Datos

# %% [markdown]
# Contamos con informacion de 4.700 transacciones de transferencias a traves de 10 variables

# %%
pd.options.display.float_format = '{:.2f}'.format
df_topsoccer.describe()
# Out:
#           Age  Market_value  Transfer_fee
# count 4700.00       3440.00       4700.00
# mean    24.34    8622469.48    9447586.17
# std      3.23    8795180.75   10437719.32
# min      0.00      50000.00     825000.00
# 25%     22.00    3500000.00    4000000.00
# 50%     24.00    6000000.00    6500000.00
# 75%     27.00   10000000.00   10820000.00
# max     35.00  120000000.00  222000000.00

# %% [markdown]
# ## Tratamiento de valores nulos y ceros

# %% [markdown]
# * Con el objetivo de tener una data mas limpia, procedemos a reemplazar la edad minima de 0 por la media de las edades.
#
# * De la misma manera los valores de mercado que se encuentran en 0 se reemplazaran por la media

# %%
df_topsoccer.replace({'Age' : 0}, 24, inplace=True) # reempplazar las edades en 0 por la media 
df_topsoccer['Market_value'] = df_topsoccer['Market_value'].fillna(0) # llenamos los valores vacios a 0
df_topsoccer.replace({'Market_value' : 0}, df_topsoccer['Market_value'].mean(), inplace=True) # reempplazar losn 0 por la media 
df_topsoccer.describe()
# Out:
#           Age  Market_value  Transfer_fee
# count 4700.00       4700.00       4700.00
# mean    24.34    8002775.84    9447586.17
# std      3.21    7593528.31   10437719.32
# min     15.00      50000.00     825000.00
# 25%     22.00    4500000.00    4000000.00
# 50%     24.00    6310913.83    6500000.00
# 75%     27.00    8050000.00   10820000.00
# max     35.00  120000000.00  222000000.00

# %%
df_topsoccer
# Out:
#                          Name     ...      Transfer_fee
# 0                   Luís Figo     ...          60000000
# 1               Hernán Crespo     ...          56810000
# 2               Marc Overmars     ...          40000000
# 3           Gabriel Batistuta     ...          36150000
# 4              Nicolas Anelka     ...          34500000
# 5               Rio Ferdinand     ...          26000000
# 6            Flávio Conceicao     ...          25000000
# 7              Savo Milosevic     ...          25000000
# 8             David Trézéguet     ...          23240000
# 9               Claudio López     ...          23000000
# 10    Jimmy Floyd Hasselbaink     ...          22500000
# 11               Gerard López     ...          21600000
# 12                      Lucas     ...          21300000
# 13                Pablo Aimar     ...          21250000
# 14              Wálter Samuel     ...          20800000
# 15              Shabani Nonda     ...          20000000
# 16               Robbie Keane     ...          19500000
# 17                  José Mari     ...          19000000
# 18            Jonathan Zebina     ...          18400000
# 19                    Émerson     ...          18000000
# 20             Tore André Flo     ...          18000000
# 21              Sergiy Rebrov     ...          18000000
# 22             Angelo Peruzzi     ...          17900000
# 23              Diego Tristán     ...          17750000
# 24            Sylvain Wiltord     ...          17500000
# 25           Fernando Redondo     ...          17500000
# 26                     Jardel     ...          17050000
# 27                 Nuno Gomes     ...          17000000
# 28           Sérgio Conceição     ...          17000000
# 29                    Alfonso     ...          16500000
# ...                       ...     ...               ...
# 4670         Benedikt Höwedes     ...           5000000
# 4671           Gonzalo Castro     ...           5000000
# 4672              Sergi Gómez     ...           5000000
# 4673              Adam Masina     ...           5000000
# 4674       Christophe Hérelle     ...           5000000
# 4675            Firmin Mubele     ...           5000000
# 4676      Florent Hadergjonaj     ...           5000000
# 4677       Nemanja Maksimovic     ...           5000000
# 4678              Juan Iturbe     ...           5000000
# 4679                  Sidcley     ...           5000000
# 4680                 Fabrício     ...           5000000
# 4681             Johan Mojica     ...           5000000
# 4682                   Petros     ...           5000000
# 4683         Christian Kouamé     ...           5000000
# 4684         Luca Waldschmidt     ...           5000000
# 4685             Marc Muniesa     ...           5000000
# 4686          Pietro Iemmello     ...           5000000
# 4687             Felipe Vizeu     ...           5000000
# 4688         Marco Tumminello     ...           5000000
# 4689             Jens Odgaard     ...           5000000
# 4690            Marco Carraro     ...           5000000
# 4691           Jonathan Ikoné     ...           5000000
# 4692      Giangiacomo Magnani     ...           5000000
# 4693      Giangiacomo Magnani     ...           5000000
# 4694             Evan N'Dicka     ...           5000000
# 4695            Jasmin Kurtic     ...           4800000
# 4696                Tchê Tchê     ...           4800000
# 4697            Silvan Widmer     ...           4500000
# 4698               Yuya Osako     ...           4500000
# 4699             Kyle Bartley     ...           4500000
#
# [4700 rows x 10 columns]

# %% [markdown]
# ## Exploración de Datos

# %%
Position_count=df_topsoccer.groupby ('Position')['Position'].count()
Age_count=df_topsoccer.groupby ('Age')['Age'].count()
TeamFrom_count=df_topsoccer.groupby ('Team_from')['Team_from'].count()
League_from_count=df_topsoccer.groupby ('League_from')['League_from'].count()
Season_count=df_topsoccer.groupby ('Season')['Season'].count()

# %% [markdown]
# realizamos una verificacion de la volumetria de los datos mas importantes , mas adelante verificamos su distribucion.

# %%
Position_count
# Out:
# Position
# Attacking Midfield     426
# Central Midfield       487
# Centre-Back            714
# Centre-Forward        1218
# Defender                 1
# Defensive Midfield     411
# Forward                  3
# Goalkeeper             180
# Left Midfield           87
# Left Winger            267
# Left-Back              225
# Midfielder               1
# Right Midfield          63
# Right Winger           305
# Right-Back             181
# Second Striker         130
# Sweeper                  1
# Name: Position, dtype: int64

# %%
Age_count
# Out:
# Age
# 15      1
# 16     10
# 17     23
# 18     82
# 19    165
# 20    302
# 21    371
# 22    461
# 23    519
# 24    537
# 25    524
# 26    481
# 27    404
# 28    327
# 29    223
# 30    157
# 31     59
# 32     30
# 33     15
# 34      5
# 35      4
# Name: Age, dtype: int64

# %%
TeamFrom_count
# Out:
# Team_from
# 1. FC Köln         10
# 1.FC K'lautern      5
# 1.FC Nuremberg      9
# 1.FSV Mainz 05     16
# 1860 Munich         4
# AC Le Havre         4
# AC Milan           44
# AEK Athens          2
# AFC Ajax           37
# AIK Solna           1
# AJ Auxerre         17
# AO Xanthi           1
# AS Livorno          6
# AS Nancy            8
# AS Roma            43
# AZ Alkmaar         21
# Aalborg BK          1
# Aalesund            1
# Ahly                2
# Ajax U19            2
# Akademisk BK        2
# Akhisarspor         1
# Al Arabi            2
# Al Gharafa          1
# Al Qadisiyah        1
# Al Rayyan           1
# Al Sadd             3
# Al-Ahli (UAE)       1
# Al-Ain FC           3
# Al-Ettifaq          1
#                    ..
# VfL Bochum          5
# VfL Wolfsburg      20
# Vicenza             3
# Viking FK           1
# Viktoria Plzen      1
# Villarreal CF      31
# Vit. Guimarães      5
# Vitesse            11
# Vitória Setúbal     2
# Vojvodina           1
# Vélez Sarsfield    18
# Wanderers           1
# Watford            12
# Wattenscheid 09     1
# Werder Bremen      25
# West Brom          13
# West Ham           33
# Wigan              18
# Willem II           2
# Wisla Kraków        3
# Wolves              9
# YB Funde            1
# Yokohama F. M.      2
# ZJ Greentown        3
# Zbrojovka Brno      1
# Zenit S-Pb         16
# Zorya Lugansk       1
# Zulte Waregem       1
# Örgryte             3
# Östers IF           1
# Name: Team_from, Length: 570, dtype: int64

# %%
League_from_count
# Out:
# League_from
#  Argentina                         66
#  Australia                          1
#  Brazil                            89
#  Bulgaria                           6
#  Canada                             1
#  Chile                             10
#  China                              4
#  Colombia                           5
#  Croatia                           12
#  Czech Republic                     8
#  Denmark                            7
#  Ecuador                            1
#  England                           27
#  Finland                            1
#  France                             2
#  Ghana                              1
#  Iran                               2
#  Korea, South                       3
#  Latvia                             1
#  Mexico                            12
#  Moldova                            2
#  Paraguay                           3
#  Peru                               1
#  Portugal                           7
#  Qatar                              4
#  Romania                            8
#  Russia                             9
#  Saudi Arabia                       2
#  Scotland                          16
#  Serbia                            16
#                                  ...
# Primera B Nacional                  4
# Primera Div. Apertura               1
# Primera División                   46
# Professional League                 6
# Proximus League                     1
# Regionalliga Nord                   1
# Rel. Ligue 1                        2
# Second Division (bis 03/04)         3
# Segunda División                    1
# Serie A                           602
# Serie A Segunda Etapa               1
# Serie B                           100
# Serie C - A                         4
# Serie C - B                         2
# Stars League                        3
# Super League                      108
# SuperLiga                          19
# Superettan                          1
# Superligaen                        21
# Superligaen Championship round      1
# Série A                           199
# Série B                             4
# Süper Lig                         100
# Torneo Final                       84
# Torneo Inicial                      4
# U18 Premier League                  1
# U19 Eredivisie                      2
# UAE Gulf League                     8
# Virsliga                            1
# Vysheyshaya Liga                    2
# Name: League_from, Length: 118, dtype: int64

# %%
Season_count
# Out:
# Season
# 2000-2001    248
# 2001-2002    250
# 2002-2003    244
# 2003-2004    242
# 2004-2005    248
# 2005-2006    247
# 2006-2007    249
# 2007-2008    248
# 2008-2009    250
# 2009-2010    249
# 2010-2011    245
# 2011-2012    249
# 2012-2013    248
# 2013-2014    250
# 2014-2015    246
# 2015-2016    248
# 2016-2017    250
# 2017-2018    244
# 2018-2019    245
# Name: Season, dtype: int64

# %% [markdown]
# Se realizan cruces entre variables, como edades de los jugadores en las diferenetes posiciones.

# %%
# Visualization League_from vs Age
df = df_topsoccer.sort_values(['Age'],ascending=False).reset_index(drop=True)
plt.figure(figsize=(25,25))
sns.barplot(x=df["Age"],y=df["Position"])
plt.xlabel("Player Age",fontsize=15)
plt.ylabel("Position",fontsize=15)
plt.title("player Position by age",fontsize=15)
plt.show()
# Out:
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.set(style='darkgrid')
sns.countplot(x = 'Age',
              data = df_topsoccer,
              order = df_topsoccer['Age'].value_counts().index)
plt.show()

# %% [markdown]
# la mayor parte de los jugadores se encuentran entre los 23-25

# %% [markdown]
# Barcharts to understand the distribution of categorical variables

# %%
sns.set(style='darkgrid')
sns.countplot(y = 'Position',
              data = df_topsoccer,
              order = df_topsoccer['Position'].value_counts().index)
plt.show()

# %% [markdown]
# por una amplia diferencia los jugadores con posicion de delantero centro tienen la mayor cvantidad de movimiento en cuenta a transferencias se refiere.

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(15,25))
sns.countplot(y = 'League_from',
              data = df_topsoccer,
              order = df_topsoccer['League_from'].value_counts().index)
plt.show()

# %% [markdown]
# la premier league y la serie A son las ligas que mas transferencia efectua en cada temporada.

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(15,25))
sns.countplot(y = 'League_to',
              data = df_topsoccer,
              order = df_topsoccer['League_to'].value_counts().index)
plt.show()

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(15,25))
sns.countplot(y = 'Season',
              data = df_topsoccer,
              order = df_topsoccer['Season'].value_counts().index)
plt.show()

# %% [markdown]
# de manera uniforme se observa la cantidad de transferencias que se hacen an cada una de las temporadas, manteniendose de una manera estable desde la temporada 2004-2005

# %%
# Display the histogram to undestand the data

f, axes = plt.subplots(3, figsize=(15, 15))
sns.distplot( df_topsoccer["Age"], ax=axes[0])
sns.distplot( df_topsoccer["Transfer_fee"]/1000, ax=axes[1])
sns.distplot( df_topsoccer["Market_value"]/1000, ax=axes[2])
# Out:
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# En cuanto a la edad, ratificamos que los jugadores con tendencua a ser transferidos entre los diferentes equipos, oscilan entre los 23-25

# %%
f, axes = plt.subplots(1, figsize=(10, 5))

sns.scatterplot(x="Transfer_fee", y="Market_value", data=df_topsoccer)

# %% [markdown]
# ## Analisis de información

# %%
# tabla de contingencia en porcentajes relativos total
pd.crosstab(index=df_topsoccer['Position'], columns=df_topsoccer['League_from'],
            margins=True).apply(lambda r: r/len(df_topsoccer) *100,
                                axis=1)
# Out:
# League_from          Argentina   Australia  ...    Vysheyshaya Liga    All
# Position                                    ...
# Attacking Midfield        0.26        0.00  ...                0.00   9.06
# Central Midfield          0.13        0.00  ...                0.00  10.36
# Centre-Back               0.26        0.00  ...                0.00  15.19
# Centre-Forward            0.30        0.00  ...                0.04  25.91
# Defender                  0.00        0.00  ...                0.00   0.02
# Defensive Midfield        0.09        0.00  ...                0.00   8.74
# Forward                   0.02        0.00  ...                0.00   0.06
# Goalkeeper                0.06        0.00  ...                0.00   3.83
# Left Midfield             0.02        0.00  ...                0.00   1.85
# Left Winger               0.02        0.00  ...                0.00   5.68
# Left-Back                 0.06        0.00  ...                0.00   4.79
# Midfielder                0.00        0.00  ...                0.00   0.02
# Right Midfield            0.04        0.02  ...                0.00   1.34
# Right Winger              0.02        0.00  ...                0.00   6.49
# Right-Back                0.04        0.00  ...                0.00   3.85
# Second Striker            0.09        0.00  ...                0.00   2.77
# Sweeper                   0.00        0.00  ...                0.00   0.02
# All                       1.40        0.02  ...                0.04 100.00
#
# [18 rows x 119 columns]

# %% [markdown]
# Las ligas de donde mas se transfieren jugadores son
# **Premier league 12.94%
# Serie A 12.81%**

# %%
# tabla de contingencia en porcentajes relativos total
pd.crosstab(index=df_topsoccer['Position'], columns=df_topsoccer['League_to'],
            margins=True).apply(lambda r: r/len(df_topsoccer) *100,
                                axis=1)
# Out:
# League_to            Argentina   Belgium  ...    UAE Gulf League    All
# Position                                  ...
# Attacking Midfield        0.04      0.00  ...               0.11   9.06
# Central Midfield          0.02      0.00  ...               0.02  10.36
# Centre-Back               0.09      0.00  ...               0.00  15.19
# Centre-Forward            0.00      0.00  ...               0.11  25.91
# Defender                  0.00      0.02  ...               0.00   0.02
# Defensive Midfield        0.00      0.00  ...               0.04   8.74
# Forward                   0.00      0.00  ...               0.00   0.06
# Goalkeeper                0.00      0.00  ...               0.00   3.83
# Left Midfield             0.00      0.00  ...               0.02   1.85
# Left Winger               0.00      0.00  ...               0.06   5.68
# Left-Back                 0.00      0.00  ...               0.00   4.79
# Midfielder                0.00      0.00  ...               0.00   0.02
# Right Midfield            0.00      0.00  ...               0.00   1.34
# Right Winger              0.00      0.00  ...               0.04   6.49
# Right-Back                0.00      0.00  ...               0.00   3.85
# Second Striker            0.00      0.00  ...               0.02   2.77
# Sweeper                   0.00      0.00  ...               0.00   0.02
# All                       0.15      0.02  ...               0.43 100.00
#
# [18 rows x 66 columns]

# %% [markdown]
# El 25.91% de los centro delanteros son los mas transferidos dentro de las diferentes ligas de origen y destino
#
# la premier League con 26.72% es la liga que mas adquiere jugadores.
# la Serie A con 15.72% es la segunda liga que mas adquiere jugadores.

# %%
pd.crosstab(index=df_topsoccer['Season'], columns=df_topsoccer['Position'],
            margins=True).apply(lambda r: r/len(df_topsoccer) *100,
                                axis=1)
# Out:
# Position   Attacking Midfield  Central Midfield  ...    Sweeper    All
# Season                                           ...
# 2000-2001                0.34              0.28  ...       0.00   5.28
# 2001-2002                0.60              0.43  ...       0.02   5.32
# 2002-2003                0.38              0.47  ...       0.00   5.19
# 2003-2004                0.64              0.45  ...       0.00   5.15
# 2004-2005                0.40              0.53  ...       0.00   5.28
# 2005-2006                0.32              0.66  ...       0.00   5.26
# 2006-2007                0.57              0.45  ...       0.00   5.30
# 2007-2008                0.43              0.62  ...       0.00   5.28
# 2008-2009                0.60              0.57  ...       0.00   5.32
# 2009-2010                0.53              0.51  ...       0.00   5.30
# 2010-2011                0.70              0.40  ...       0.00   5.21
# 2011-2012                0.45              0.81  ...       0.00   5.30
# 2012-2013                0.45              0.40  ...       0.00   5.28
# 2013-2014                0.62              0.66  ...       0.00   5.32
# 2014-2015                0.43              0.53  ...       0.00   5.23
# 2015-2016                0.32              0.74  ...       0.00   5.28
# 2016-2017                0.55              0.53  ...       0.00   5.32
# 2017-2018                0.38              0.66  ...       0.00   5.19
# 2018-2019                0.36              0.66  ...       0.00   5.21
# All                      9.06             10.36  ...       0.02 100.00
#
# [20 rows x 18 columns]

# %% [markdown]
# a traves de todas las temporadas se mantienen con el 25.91% que el centro delantero esl el jugador mas transferido, con los jugadores liberos y mediocampistas son los menos transferidos y tienden a permanecer mas tiempo en sus equipos.

# %%
# tabla de contingencia en porcentajes relativos total
pd.crosstab(index=df_topsoccer['Season'], columns=df_topsoccer['Age'],
            margins=True).apply(lambda r: r/len(df_topsoccer) *100,
                                axis=1)
# Out:
# Age         15   16   17   18   19   20  ...     31   32   33   34   35    All
# Season                                   ...
# 2000-2001 0.00 0.00 0.00 0.06 0.17 0.11  ...   0.09 0.09 0.00 0.00 0.02   5.28
# 2001-2002 0.00 0.00 0.00 0.09 0.21 0.36  ...   0.09 0.02 0.04 0.04 0.02   5.32
# 2002-2003 0.00 0.00 0.06 0.09 0.11 0.19  ...   0.02 0.00 0.00 0.00 0.00   5.19
# 2003-2004 0.00 0.04 0.02 0.11 0.19 0.60  ...   0.06 0.06 0.11 0.00 0.00   5.15
# 2004-2005 0.00 0.02 0.02 0.09 0.09 0.38  ...   0.04 0.02 0.02 0.02 0.00   5.28
# 2005-2006 0.02 0.06 0.02 0.04 0.13 0.34  ...   0.11 0.02 0.00 0.02 0.00   5.26
# 2006-2007 0.00 0.00 0.06 0.17 0.19 0.23  ...   0.06 0.11 0.02 0.02 0.00   5.30
# 2007-2008 0.00 0.00 0.04 0.06 0.23 0.38  ...   0.09 0.04 0.00 0.00 0.00   5.28
# 2008-2009 0.00 0.02 0.02 0.11 0.21 0.26  ...   0.02 0.02 0.00 0.00 0.00   5.32
# 2009-2010 0.00 0.00 0.00 0.09 0.11 0.32  ...   0.09 0.00 0.00 0.00 0.02   5.30
# 2010-2011 0.00 0.00 0.09 0.06 0.17 0.28  ...   0.02 0.04 0.02 0.00 0.00   5.21
# 2011-2012 0.00 0.00 0.02 0.11 0.23 0.36  ...   0.09 0.02 0.00 0.00 0.02   5.30
# 2012-2013 0.00 0.00 0.00 0.15 0.19 0.23  ...   0.04 0.00 0.00 0.00 0.00   5.28
# 2013-2014 0.00 0.02 0.06 0.06 0.19 0.38  ...   0.04 0.04 0.00 0.00 0.00   5.32
# 2014-2015 0.00 0.00 0.02 0.11 0.21 0.40  ...   0.04 0.09 0.00 0.00 0.00   5.23
# 2015-2016 0.00 0.00 0.00 0.09 0.19 0.32  ...   0.09 0.02 0.02 0.00 0.00   5.28
# 2016-2017 0.00 0.00 0.02 0.09 0.23 0.36  ...   0.13 0.02 0.04 0.00 0.00   5.32
# 2017-2018 0.00 0.02 0.02 0.06 0.17 0.60  ...   0.06 0.02 0.00 0.00 0.00   5.19
# 2018-2019 0.00 0.02 0.00 0.13 0.28 0.32  ...   0.09 0.00 0.04 0.00 0.00   5.21
# All       0.02 0.21 0.49 1.74 3.51 6.43  ...   1.26 0.64 0.32 0.11 0.09 100.00
#
# [20 rows x 22 columns]

# %% [markdown]
# El promedio de edad con mayor porcentaje de transferencias en la mayoria de las temporadas es
# 23 , 24 , 25 con 11.04%, 11.43% y 11.15% respectivamente

# %% [markdown]
# ## Nuevas Características

# %% [markdown]
# Con el objetivo de determinar si la transferencia fue rentable para cada una de las posiciones , calculamos la media por posicion y por liga de origen, el jugador vendido por encima de la media fue una transferencia rentable, de lo contrario no lo fue tanto

# %%
SumPosition = df_topsoccer.reset_index().groupby(('Position','League_from'))['Transfer_fee'].sum()
CountPosition= df_topsoccer.reset_index().groupby(('Position','League_from'))['Transfer_fee'].count()

MedPosition= SumPosition/CountPosition
df_topsoccer1=pd.DataFrame(data=MedPosition)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Interpreting tuple 'by' as a list of keys, rather than a single key. Use 'by=[...]' instead of 'by=(...)'. In the future, a tuple will always mean a single key.
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: Interpreting tuple 'by' as a list of keys, rather than a single key. Use 'by=[...]' instead of 'by=(...)'. In the future, a tuple will always mean a single key.

# %%
df_topsoccer1
# Out:
#                                                 Transfer_fee
# Position           League_from
# Attacking Midfield  Argentina                     5879166.67
#                     Brazil                        5476086.96
#                     Chile                         5350000.00
#                     Croatia                       1500000.00
#                     Czech Republic               14500000.00
#                     England                       3750000.00
#                     Iran                          2500000.00
#                     Romania                       2500000.00
#                     Scotland                      1500000.00
#                     Serbia                        3400000.00
#                     United Arab Emirates          6000000.00
#                     Uruguay                       4500000.00
#                    1.Bundesliga                  16152173.91
#                    1.HNL                          6260000.00
#                    2.Bundesliga                   4083333.33
#                    2ª B - Grupo III               6000000.00
#                    Bundesliga                     4250000.00
#                    Championship                   9570000.00
#                    Ekstraklasa                    3625000.00
#                    Eliteserien                    4000000.00
#                    Eredivisie                     9775000.00
#                    First Division                 6950000.00
#                    HET Liga                       4200000.00
#                    J1 - 2nd Stage                 4166666.67
#                    J2 League                      4000000.00
#                    Jupiler Pro League             6600000.00
#                    LaLiga                        12502571.43
#                    LaLiga2                        7166666.67
#                    League One                     7043333.33
#                    Liga 1 - Championship group    8200000.00
# ...                                                      ...
# Second Striker      Slovakia                      6750000.00
#                     Uruguay                       3000000.00
#                    1.Bundesliga                  12183333.33
#                    2.Bundesliga                   7000000.00
#                    Championship                   9087500.00
#                    Eredivisie                     5500000.00
#                    First Division                 7500000.00
#                    HET Liga                       3250000.00
#                    Jupiler Pro League             4250000.00
#                    K League 1                     4000000.00
#                    LaLiga                         8445833.33
#                    LaLiga2                        5750000.00
#                    Liga MX Clausura               6400000.00
#                    Liga Águila II                 4000000.00
#                    Ligat ha'Al                    7230000.00
#                    Ligue 1                        7833333.33
#                    Ligue 2                        3000000.00
#                    MLS                            3000000.00
#                    Premier League                11035000.00
#                    Premier Liga                   8937500.00
#                    Premiership                    1750000.00
#                    Primera B Nacional            11900000.00
#                    Primera División              10500000.00
#                    Serie A                        8977666.67
#                    Serie B                        9040000.00
#                    Super League                   4300000.00
#                    Superligaen                    3000000.00
#                    Série A                       13016666.67
#                    Torneo Final                   8066666.67
# Sweeper            1.Bundesliga                   2250000.00
#
# [585 rows x 1 columns]

# %%
df_topsoccer2 = pd.merge(df_topsoccer1, df_topsoccer, on='Position' and 'League_from')
df_topsoccer2
# Out:
#                       League_from       ...        Transfer_fee_y
# 0                       Argentina       ...              21250000
# 1                       Argentina       ...              20800000
# 2                       Argentina       ...              14400000
# 3                       Argentina       ...               9300000
# 4                       Argentina       ...               7600000
# 5                       Argentina       ...               7300000
# 6                       Argentina       ...               6000000
# 7                       Argentina       ...               6000000
# 8                       Argentina       ...               5300000
# 9                       Argentina       ...               5300000
# 10                      Argentina       ...               4700000
# 11                      Argentina       ...               4500000
# 12                      Argentina       ...               4200000
# 13                      Argentina       ...               1850000
# 14                      Argentina       ...              35900000
# 15                      Argentina       ...              11000000
# 16                      Argentina       ...               7800000
# 17                      Argentina       ...               5620000
# 18                      Argentina       ...               5250000
# 19                      Argentina       ...               5000000
# 20                      Argentina       ...               4800000
# 21                      Argentina       ...               3800000
# 22                      Argentina       ...               3500000
# 23                      Argentina       ...               3000000
# 24                      Argentina       ...              10000000
# 25                      Argentina       ...               7500000
# 26                      Argentina       ...               6500000
# 27                      Argentina       ...               6000000
# 28                      Argentina       ...               4000000
# 29                      Argentina       ...               3000000
# ...                           ...       ...                   ...
# 57153                  1.Division       ...               4000000
# 57154                       1.Lig       ...               1700000
# 57155               Korean FA Cup       ...               5000000
# 57156                      Canada       ...              10000000
# 57157                      Latvia       ...               2800000
# 57158                       Qatar       ...               3000000
# 57159                       Qatar       ...               2700000
# 57160                       Qatar       ...               5000000
# 57161                       Qatar       ...              20200000
# 57162                       Qatar       ...               3000000
# 57163                       Qatar       ...               2700000
# 57164                       Qatar       ...               5000000
# 57165                       Qatar       ...              20200000
# 57166                       Qatar       ...               3000000
# 57167                       Qatar       ...               2700000
# 57168                       Qatar       ...               5000000
# 57169                       Qatar       ...              20200000
# 57170                1.Liga gr. 1       ...               3250000
# 57171        Championnat National       ...               4000000
# 57172                 Ligue I Pro       ...               4250000
# 57173             Proximus League       ...               8250000
# 57174       Serie A Segunda Etapa       ...               4950000
# 57175          U18 Premier League       ...               7840000
# 57176            Segunda División       ...               9600000
# 57177                   Australia       ...               1800000
# 57178                   Venezuela       ...               2000000
# 57179                        Peru       ...               3500000
# 57180  A Grupa - Championship gr.       ...               7500000
# 57181                    Slovakia       ...               6750000
# 57182                  K League 1       ...               4000000
#
# [57183 rows x 11 columns]

# %%
print(df_topsoccer2.columns)
# Out:
# Index(['League_from', 'Transfer_fee_x', 'Name', 'Position', 'Age', 'Team_from',
#        'Team_to', 'League_to', 'Season', 'Market_value', 'Transfer_fee_y'],
#       dtype='object')

# %%
df_topsoccer2 = df_topsoccer2.rename(columns={'Transfer_fee_x': 'MediaXpos'})
df_topsoccer2 = df_topsoccer2.rename(columns={'Transfer_fee_y': 'Transfer_Value'})
df_topsoccer2['Rentable']= np.where(df_topsoccer2['Transfer_Value']>= df_topsoccer2['MediaXpos'],1,0)

# %% [markdown]
# Determinamos si la transferencia es rentable = 1, de lo contrario es 0

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(3,5))
sns.countplot(x = 'Rentable',
              data = df_topsoccer2,
              order = df_topsoccer2['Rentable'].value_counts().index)
plt.show()

# %% [markdown]
# Se observa que hay mas jugadores que se transfieren por debajo de la media por posocion y liga

# %%
f, axes = plt.subplots(1,1, figsize=(10, 5), sharex=True, sharey=True)

sns.scatterplot(x="Transfer_Value", y="MediaXpos", data=df_topsoccer2)

# %%
x1_bp = df_topsoccer2[(df_topsoccer2['Position']== 'Attacking Midfield') & (df_topsoccer2['Rentable'] == 1) & (df_topsoccer2['Season']=='2017-2018')]
x1_mp = df_topsoccer2[(df_topsoccer2['Position']== 'Attacking Midfield') & (df_topsoccer2['Rentable'] == 0) & (df_topsoccer2['Season']=='2017-2018')]

x2_bp = df_topsoccer2[(df_topsoccer2['Position']== 'Central Midfield') & (df_topsoccer2['Rentable'] == 1) & (df_topsoccer2['Season']=='2017-2018')]
x2_mp = df_topsoccer2[(df_topsoccer2['Position']== 'Central Midfield') & (df_topsoccer2['Rentable'] == 0) & (df_topsoccer2['Season']=='2017-2018')]

x3_bp = df_topsoccer2[(df_topsoccer2['Position']== 'Centre-Back') & (df_topsoccer2['Rentable'] == 1) & (df_topsoccer2['Season']=='2017-2018')]
x3_mp = df_topsoccer2[(df_topsoccer2['Position']== 'Centre-Back') & (df_topsoccer2['Rentable'] == 0) & (df_topsoccer2['Season']=='2017-2018')]

# %%
pl.figure(figsize = (20, 10))
pl.plot(x1_bp['Transfer_Value'], x1_bp['MediaXpos'], 'o', label="Attacking Midfield (Bien pago)");
pl.plot(x1_mp['Transfer_Value'], x1_mp['MediaXpos'], 'x', label="Attacking Midfield (Mal Pago)");
pl.plot(x2_bp['Transfer_Value'], x2_bp['MediaXpos'], 'o', label="Central Midfield (Bien pago)");
pl.plot(x2_mp['Transfer_Value'], x2_mp['MediaXpos'], 'x', label="Central Midfield (Mal Pago)");
pl.plot(x3_bp['Transfer_Value'], x3_bp['MediaXpos'], 'o', label="Centre-Back (Bien pago)");
pl.plot(x3_mp['Transfer_Value'], x3_mp['MediaXpos'], 'x', label="Centre-Back (Mal Pago)");
pl.xlabel('Valor de transferencia en el periodo 2017-2018')
pl.ylabel('Transferencia Media')
pl.legend(loc='best');

# %% [markdown]
# Con este Grafico buscamos mostrar la posicion de los jugadores mejores pagos
# con el analisis realizado
#
# Concluyendo que:
# Las ligas que mas realizan transferencias de  jugadores :
# la premier League con 26.72%
# la Serie A con 15.72%
#
#
# que las posiciones mas transadad entre cada una de las ligas son:
# Atacando el mediocampo
# Centro defensa
# Medio centro
