# %% [markdown]
# # RIL Stock Price Prediction using Facebook Prophet

# %% [markdown]
# # Import the libraries

# %%
import math
import pandas_datareader as web
import numpy as np
import pandas as pd
from datetime import datetime
import math

from fbprophet import Prophet
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %% [markdown]
# # Read the data

# %%
ril_price= pd.read_csv("../input/reliance-industries-ril-share-price-19962020/Reliance Industries 1996 to 2020.csv")
#Show the data 
ril_price

# %% [markdown]
# Lots of rows have NaN value. lets delete those

# %%
ril_price=ril_price.dropna()
ril_price

# %% [markdown]
# Even after removing NaN values, we have 2200+ rows and 9+ years of data. good enough for the analysis

# %%
ril_price.info()

# %% [markdown]
# date is a string object not a date. lets fix this
#  and also select only the close price and the date

# %%
ril_price["ds"]=pd.to_datetime(ril_price["Date"], format="%d-%m-%Y")
ril_price["y"]=ril_price["Close"]
ril_price=ril_price[['ds', 'y']]
ril_price

# %% [markdown]
# # Fit the Model

# %%
model = Prophet()
model.fit(ril_price)

# %% [markdown]
# # Forecast for the next year

# %%
future = model.make_future_dataframe(periods=365)
future.tail()

# %% [markdown]
# # Forecast the expected values and the forecast range

# %%
forecast = model.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()

# %%
fig = model.plot(forecast)

# %%
fig2 = model.plot_components(forecast)

# %% [markdown]
# # Plotly to show different time periods of Forecast

# %%
from fbprophet.plot import plot_plotly
import plotly.offline as py
py.init_notebook_mode()

fig = plot_plotly(model, forecast)  # This returns a plotly Figure
py.iplot(fig)

# %% [markdown]
# Look at some other notebooks using this dataset!
#
# Look at:
#
# 1) [RIL Stock Price Prediction- LSTM](https://www.kaggle.com/kmldas/ril-stock-price-prediction-lstm)
#
# 2) [Reliance: Technical Analysis: Bollinger Bands, MA](https://www.kaggle.com/kmldas/reliance-technical-analysis-bollinger-bands-ma)
