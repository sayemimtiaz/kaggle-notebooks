# %% [markdown]
# # Introduction
# Turkey is a country staying in the earthquake zone. For this reason, it is very likely to suffer a severe earthquake. In this context, it is necessary to demolish the structures that will endanger the safety of life and property and construct strong structures against earthquakes instead. However, the methods used for the static analysis of structures are very time-consuming and costly. In this case, it is necessary to develop a fast and cheap method that can analyze the large building stock in the country.
#
# <font color = 'blue'>
# Content:
#
# 1. [Variable Description](#1)
#     * [Univariate Variable Analysis](#2)
#         * [Categorical Variable](#3)
#         * [Numerical Variable](#4)
# 1. [Basic Data Analysis](#5)
# 1. [Missing Value](#6)
# 1. [Visualization](#7)
#     * [Correlation Between TKY -- TYA -- YC -- DD --KA-- TS](#8)
#     * [KA -- TS](#9)
#     * [TYA -- TS](#10)
#     * [YC -- TS](#11)
#     * [DD -- TS](#12)
#     * [YC -- TS -- DD](#13)
#     * [YC -- TS -- KA](#14)
#     * [DT -- TDT --TYA -- TS](#15)
# 1. [Feature Engineering](#16)
#     * [KA -- KS](#17)
# 1. [Modeling](#18)
#     * [Train - Test Split](#19)
#     * [Normalization](#20)
#     * [Simple Logistic Regression](#21)
#     * [Model Selection Grid search CV with logistic regression](#22)
#     * [K-Fold Cross Validation: Avoid overfitting with logistic regression](#23)
#     * [KNN modeling](#24)
#     * [Model Selection K-FOLD Cross Validation: Avoid overfitting with KNN](#25)
#     * [Decision tree and Random forest regression](#27)
#     * [Unsupervised leraning Kmeans clusturing](#26)
#     * [Hiyerartical cluster dendogram](#28)
#     * [Hiyerartical cluster analysis](#29)
#     * [Hyperparameter Tuning -- Grid Search -- Cross Validation](#30)
#     * [Ensemble Modeling](#31)
#     * [Prediction and Submission](#32)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
plt.style.use("seaborn-whitegrid")

import seaborn as sns

from collections import Counter

import warnings
warnings.filterwarnings("ignore")

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
train_df = pd.read_csv("/kaggle/input/publishphd/nMLYG.csv",sep=";")
test_df = pd.read_csv("/kaggle/input/publishphd/nMLYT.csv",sep=";")



testh_df3 = pd.read_csv("/kaggle/input/publishphd/damage.csv",sep=";")

# %%
train_df.columns

# %%
testh_df3

# %%
train_df.info

# %% [markdown]
# ## <a id = "1"></a><br>
# # Variable Description
# 1. Visual Damage=VD=YC (Categorical Variable)
# 1. Vertical İrregularities=VI=DD (Categorical Variable)
# 1. Earthquake Zone=EZ (Categorical Variable)
# 1. Number of Floors=NF=KA (Numerical Variable)
# 1. Floor system type =FT=DT (Categorical Variable)
# 1. Wall Material Type=WT = TDT(Categorical Variable)
# 1. Typical Plan Area= TA=TYA (Categorical Variable)
# 1. Typical Story Height =TY=TKY (Categorical Variable)
# 1. Result of Seismic Risk=RS=TS (Categorical Variable)
# * (1 var 0 yok)

# %% [markdown]
# ## <a id = "2"></a><br>
# #Univariate Variable Analysis
# 1. Categorical Variable: DB=Deprem Bolgesi, DT=Doseme Tipi, DD=Dusey Duzensizlik, YC=Yapisal Çatlak, TDT=Tasiyici Duvar Tipi, TKY=Tipik Kat Yuksekligi, TYA=Tipik Kat Alanı, TS=Tespit Sonucu
# 1. Numerical Variable: KA=Kat Adeti

# %% [markdown]
# ## <a id = "3"></a><br>
# 1. Categorical Variable

# %%
def bar_plot(variable):
    """
        input: variable ex: "VI"
        output: bar plot & value count
    """
    # get feature
    var = train_df[variable]
    # count number of categorical variable(value/sample)
    varValue = var.value_counts()
    
    # visualize
    plt.figure(figsize = (9,3))
    plt.bar(varValue.index, varValue)
    plt.xticks(varValue.index, varValue.index.values)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n {}".format(variable,varValue))

# %%
category1 = ["EZ","NF","FT","VI","VD","WT","TY","TA","RS"]
for c in category1:
    bar_plot(c)

# %% [markdown]
# ## <a id = "4"></a><br>
# 2. Numerical Variable

# %%
def plot_hist(variable):
    plt.figure(figsize = (9,3))
    plt.hist(train_df[variable], bins = 50)
    plt.xlabel(variable)
    plt.ylabel("Frequency")
    plt.title("{} distribution with hist".format(variable))
    plt.show()

# %% [markdown]
# numericVar = ["RS"]
# for n in numericVar:
#     plot_his
#
#
#
# #Yıgmalarda tek katlı yapılar yogunlukta

# %% [markdown]
# ## <a id = "5"></a><br>
# # Basic Data Analysis
# ## <a id = "1"></a><br>
# # Variable Description
# 1. Visual Damage=VD=YC (Categorical Variable)
# 1. Vertical İrregularities=VI=DD (Categorical Variable)
# 1. Earthquake Zone=EZ (Categorical Variable)
# 1. Number of Floors=NF=KA (Numerical Variable)
# 1. Floor system type =FT=DT (Categorical Variable)
# 1. Wall Material Type=WT = TDT(Categorical Variable)
# 1. Typical Plan Area= TA=TYA (Categorical Variable)
# 1. Typical Story Height =TY=TKY (Categorical Variable)
# 1. Result of Seismic Risk=RS=TS (Categorical Variable)
# * (1 var 0 yok)

# %%
# EZ vs RS (little relationship)
train_df[["EZ","RS"]].groupby(["EZ"], as_index = False).mean().sort_values(by="RS",ascending = False)

# %%
# KA vs TS (KA => Up  RS converge 1(riskli) )
train_df[["NF","RS"]].groupby(["NF"], as_index = False).mean().sort_values(by="RS",ascending = False)

# %% [markdown]
# Katsayısı arttıkça 1'e gitme eğiliminde. mantıklı

# %%
# FT vs RS (little relationship)
train_df[["FT","RS"]].groupby(["FT"], as_index = False).mean().sort_values(by="RS",ascending = False)

# %% [markdown]
# 1. Visual Damage=VD=YC (Categorical Variable)
# 1. Vertical İrregularities=VI=DD (Categorical Variable)
# 1. Earthquake Zone=EZ (Categorical Variable)
# 1. Number of Floors=NF=KA (Numerical Variable)
# 1. Floor system type =FT=DT (Categorical Variable)
# 1. Wall Material Type=WT = TDT(Categorical Variable)
# 1. Typical Plan Area= TA=TYA (Categorical Variable)
# 1. Typical Story Height =TY=TKY (Categorical Variable)
# 1. Result of Seismic Risk=RS=TS (Categorical Variable)
# * (1 var 0 yok)

# %%
# VI vs TS ((if dd=1 (var) => RS converge 1(riskli) )
train_df[["VI","RS"]].groupby(["VI"], as_index = False).mean().sort_values(by="RS",ascending = False)

# %% [markdown]
# Düşey düzensizlil varsa riskliye gitmiş. mantıklı

# %%
# VD vs RS ((if RC=1 (var) => RS converge 1(riskli) )
train_df[["VD","RS"]].groupby(["VD"], as_index = False).mean().sort_values(by="RS",ascending = False)

# %%
# WT vs TS (little relationship)
train_df[["WT","RS"]].groupby(["WT"], as_index = False).mean().sort_values(by="RS",ascending = False)

# %%
# TY vs RS (TKY => Up  RS converge 1 )
train_df[["TY","RS"]].groupby(["TY"], as_index = False).mean().sort_values(by="RS",ascending = False)

# %%
# TA vs RS (KA => Up  TS converge 0 )
train_df[["TA","RS"]].groupby(["TA"], as_index = False).mean().sort_values(by="RS",ascending = False)

# %% [markdown]
# ## <a id = "6"></a><br>
# # Missing Value (noun is not)

# %%
train_df.columns[train_df.isnull().any()]

# %% [markdown]
# ### combine

# %%
train_df_len = len(train_df)
train_df = pd.concat([train_df,test_df],axis = 0).reset_index(drop = True)

# %% [markdown]
# <a id = "7"></a><br>
# # Visualization
# ****

# %% [markdown]
# ## <a id = "1"></a><br>
# # Variable Description
# 1. Visual Damage=VD=YC (Categorical Variable)
# 1. Vertical İrregularities=VI=DD (Categorical Variable)
# 1. Earthquake Zone=EZ (Categorical Variable)
# 1. Number of Floors=NF=KA (Numerical Variable)
# 1. Floor system type =FT=DT (Categorical Variable)
# 1. Wall Material Type=WT = TDT(Categorical Variable)
# 1. Typical Plan Area= TA=TYA (Categorical Variable)
# 1. Typical Story Height =TY=TKY (Categorical Variable)
# 1. Result of Seismic Risk=RS=TS (Categorical Variable)
# * (1 var 0 yok)

# %% [markdown]
# <a id = "8"></a><br>
# ## Correlation Between TY -- TA -- VD -- VI --NS-- RS

# %%
list1 = ["EZ", "FT", "WT", "TY", "TA", "VD", "VI", "NF", "RS"]
plt.figure(figsize=(20,10))
sns.heatmap(train_df[list1].corr(), annot = True, fmt = ".2f")
plt.show()

# %% [markdown]
# BEST Correlation KA with TS  (KA>DD>YC>TYA>TKY)

# %% [markdown]
# <a id = "9"></a><br>
# ## NF -- RS

# %%
g = sns.factorplot(x = "NF", y = "RS", data = train_df, kind = "bar", size = 4)
g.set_ylabels("TS Probability")
plt.show()

# %% [markdown]
# * Having a lot of KA have less chance to risksiz.
# * if ka == 5 or 6 or 7, structer is riskli.
# * can be categorized

# %% [markdown]
# <a id = "10"></a><br>
# ## TA -- RS

# %%
g = sns.factorplot(x = "TA", y = "RS", data = train_df, kind = "bar", size = 4)
g.set_ylabels("TS Probability")
plt.show()

# %% [markdown]
# * Having a lot of TYA have less chance to risksiz.
# * if x == 2, structer is riskli.

# %% [markdown]
# <a id = "11"></a><br>
# ## VD -- RS

# %%
g = sns.factorplot(x = "VD", y = "RS", data = train_df, kind = "bar", size = 4)
g.set_ylabels("RS Probability")
plt.show()

# %% [markdown]
# <a id = "12"></a><br>
# ## VI -- RS

# %%
g = sns.factorplot(x = "VI", y = "RS", data = train_df, kind = "bar", size = 4)
g.set_ylabels("RS Probability")
plt.show()

# %% [markdown]
# * dd corelation with ts

# %% [markdown]
# <a id = "13"></a><br>
# ## VD -- RS -- VI
# (From the close correlation of yc dd with ts, we are looking for the answer to the relationship between yc and dd)

# %%
g = sns.FacetGrid(train_df, col = "RS", row = "VD", size = 2)
g.map(plt.hist, "VI", bins = 25)
g.add_legend()
plt.show()

# %% [markdown]
# <a id = "14"></a><br>
# ## VD-- RS -- NF

# %%
##yc=0 iken katın artmasında riskli olmuş beklemediğimiz bir durum.

# %%
g = sns.FacetGrid(train_df, col = "RS", row = "VD", size = 2)
g.map(plt.hist, "NF", bins = 25)
g.add_legend()
plt.show()

# %% [markdown]
# <a id = "15"></a><br>
# ## FT -- WT --TA -- RS

# %%
g = sns.FacetGrid(train_df, row = "FT", size = 2)
g.map(sns.pointplot, "WT","RS","TA")
g.add_legend()
plt.show()

# %% [markdown]
# tdt only having a relationship when td = 2, in addition to when dt correlation is poor
# tdt, dt korelasyonunun zayıf olduğu duruma ek olarak, yalnızca td = 2 olduğunda bir ilişkiye sahiptir

# %% [markdown]
# <a id = "16"></a><br>
# # Feature Engineering

# %% [markdown]
# <a id = "17"></a><br>
# ## NF -- NS

# %%
g = sns.factorplot(x = "NF", y = "RS", data = train_df, kind = "bar", size = 4)
g.set_ylabels("RS Probability")
plt.show()

# %% [markdown]
# ##can be categorized (KA Drop new variable KS)
# train_df["NS"] = train_df["NF"].replace(["1","2","3","4","5","6","7"],"other")
# train_df["NS"] = [0 if i < 2 else 1 if i < 3 else 2 if i < 5 else 3 for i in train_df["NF"]]
# train_df["NS"].head(20)
#
# test_df["NS"] = test_df["NF"].replace(["1","2","3","4","5","6","7"],"other")
# test_df["NS"] = [0 if i < 2 else 1 if i < 3 else 2 if i < 5 else 3 for i in test_df["NF"]]
# test_df["NS"].head(20)
#
# testh_df["NS"] = testh_df["NF"].replace(["1","2","3","4","5","6","7"],"other")
# testh_df["NS"] = [0 if i < 2 else 1 if i < 3 else 2 if i < 5 else 3 for i in testh_df["NF"]]
# testh_df["NS"].head(20)
#
#
# testh_dfl["NS"] = testh_dfl["NF"].replace(["1","2","3","4","5","6","7"],"other")
# testh_dfl["NS"] = [0 if i < 2 else 1 if i < 3 else 2 if i < 5 else 3 for i in testh_dfl["NF"]]
# testh_dfl["NS"].head(20)
#
#
# g = sns.factorplot(x = "NS", y = "RS", data = train_df, kind = "bar", size = 4)
# g.set_ylabels("RS Probability")
# plt.show()

# %% [markdown]
# train_df.drop(labels = ["NF"], axis = 1, inplace = True)

# %%
train_df

# %% [markdown]
# <a id = "18"></a><br>
# # Modeling

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, GradientBoostingClassifier
from sklearn.metrics import classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# <a id = "19"></a><br>
# # Train - Test Split

# %% [markdown]
# <a id = "20"></a><br>
# ## normalization ((x - min(x))/(max(x)-min(x))

# %%
train_df_len

# %%
test_t = train_df[train_df_len:]
testy=test_t.RS.values
test_t.drop(labels = ["RS"],axis = 1, inplace = True)
test=(test_t - np.min(test_t))/(np.max(test_t)-np.min(test_t)).values

# %%
test

# %%
train_t = train_df[:train_df_len]
y_train = train_t["RS"]
X_trains = train_t.drop(labels = "RS", axis = 1)
X_train=(X_trains - np.min(X_trains))/(np.max(X_trains)-np.min(X_trains)).values


Y_traind = testh_df3["RS"]
X_traind = testh_df3.drop(labels = "RS", axis = 1)


X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size = 0.1, random_state = 42)
print("X_train",len(X_train))
print("X_traindamage",len(X_traind))
print("X_test",len(X_test))
print("y_train",len(y_train))
print("y_test",len(y_test))
print("test",len(test))

# %% [markdown]
# <a id = "21"></a><br>
# # Simple Logistic Regression

# %%
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
acc_log_train = round(logreg.score(X_train, y_train)*100,2) 
acc_log_test = round(logreg.score(X_test,y_test)*100,2)
print("Training Accuracy: % {}".format(acc_log_train))
print("Testing Accuracy: % {}".format(acc_log_test))

# %%
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
logreg.fit(X_traind,Y_traind)
acc_log_train = round(logreg.score(X_train, y_train)*100,2) 
acc_log_test = round(logreg.score(X_traind,Y_traind)*100,2)
print("Training Accuracy: % {}".format(acc_log_train))
print("Testing Accuracy: % {}".format(acc_log_test))

# %% [markdown]
# <a id = "22"></a><br>
# # Model Selection Grid search CV with logistic regression

# %%
from sklearn.linear_model import LogisticRegression
grid = {"C":np.logspace(-3,3,7),"penalty":["l1","l2"]}  # l1 = lasso ve l2 = ridge
logreg = LogisticRegression()
logreg_cv = GridSearchCV(logreg,grid,cv = 10)
logreg_cv.fit(X_train,y_train)
print("tuned hyperparameters: (best parameters): ",logreg_cv.best_params_)
print("accuracy: ",logreg_cv.best_score_)

# %%
logreg2 = LogisticRegression(C=100,penalty="l2")
logreg2.fit(X_train,y_train)
print("score: ", logreg2.score(X_test,y_test))

# %% [markdown]
# **<a id = "23"></a><br>**
# # Model Selection K-Fold Cross Validation: Avoid overfitting with logistic regression

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = logreg2, X = X_train, y= y_train, cv = 10)
print("average accuracy: ",np.mean(accuracies))
print("average std: ",np.std(accuracies))

# %%
##new test K fold CV to logisticRegression
logreg2.fit(X_train,y_train)
print("test accuracy: ",logreg2.score(test,testy))  ##new data test

# %% [markdown]
# ## confusion_matrix

# %%
logreg2.fit(X_train,y_train)
print("score: ", logreg2.score(test,testy))
y_pred = logreg_cv.predict(test)
y_true = testy
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true,y_pred)
print("tuned hyperparameters: (best parameters): ",logreg_cv.votingC)
print("accuracy: ",logreg_cv.best_score_)

# %%
cm

# %%
from sklearn.metrics import confusion_matrix
cm2 = confusion_matrix(y_true,y_pred)

# %%
f, ax = plt.subplots(figsize =(5,5))
sns.heatmap(cm,annot = True,linewidths=0.5,linecolor="red",fmt = ".0f",ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()

# %% [markdown]
# **<a id = "24"></a><br>**
# # KNN modeling

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
prediction=knn.predict(X_test)
print(" {} knn score: {}".format(3,knn.score(X_test, y_test)))

# %% [markdown]
# ## Find k value

# %%
score_list = []
for each in range(1,15):
    knn2 = KNeighborsClassifier(n_neighbors = each)
    knn2.fit(X_train,y_train)
    score_list.append(knn2.score(X_test,y_test))
plt.plot(range(1,15),score_list)
plt.xlabel("k values")
plt.ylabel("accuracy")
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=10)
knn.fit(X_train, y_train)
prediction=knn.predict(X_test)
print(" {} knn score: {}".format(14,knn.score(X_test, y_test)))

# %%
###new test
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=10)
knn.fit(X_train, y_train)
prediction=knn.predict(test)
print(" {} knn score: {}".format(14,knn.score(test, testy)))

# %% [markdown]
# **<a id = "25"></a><br>**
# # K-Fold Cross Validation: Avoid overfitting with KNN

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = knn, X = X_train, y= y_train, cv = 12)
print("average accuracy: ",np.mean(accuracies))
print("average std: ",np.std(accuracies))
##new test
knn.fit(X_train,y_train)
print("test accuracy: ",knn.score(test,testy))

# %% [markdown]
# **<a id = "27"></a><br>**
# # Decision tree and Random forest regression

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)
print("decision tree score: ", dt.score(X_test, y_test))

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=10,random_state=1)
rf.fit(X_train, y_train)
print("random forest algo result:", rf.score(X_test, y_test))

# %% [markdown]
# **<a id = "26"></a><br>**
# # Unsupervised leraning Kmeans clusturing

# %%
from sklearn.cluster import KMeans
wcss = []

for k in range(1,15):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(X_train)
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1,15),wcss)
plt.xlabel("number of k (cluster) value")
plt.ylabel("wcss")
plt.show()
#kmeans uygulama   6 cluster but we apply 2
kmeans2 = KMeans(n_clusters=2)
clusters3 = kmeans2.fit_predict(X_train)

X_train["label"] = clusters3
data=X_train
#but 7 cluster
#10 centers plot
plt.scatter(kmeans2.cluster_centers_[:,0],kmeans2.cluster_centers_[:,1],color = "yellow")
plt.show()

# %%
X_train

# %% [markdown]
# **<a id = "28"></a><br>**
# # HC cluster dendogram

# %%
from scipy.cluster.hierarchy import linkage, dendrogram

merg = linkage(X_train,method="ward")
dendrogram(merg,leaf_rotation = 90)
plt.xlabel("data points")
plt.ylabel("euclidean distance")
plt.show()

# %% [markdown]
# **<a id = "29"></a><br>**
# # HC cluster analysis

# %%
from sklearn.cluster import AgglomerativeClustering
hiyerartical_cluster = AgglomerativeClustering(n_clusters = 4,affinity= "euclidean",linkage = "ward")
cluster = hiyerartical_cluster.fit_predict(X_train)
X_train["label"] = cluster
ay=X_train.label
plt.show()

# %%
ay.to_csv("ay.csv", index = False)

# %%
del X_train["label"]

# %% [markdown]
# <a id = "30"></a><br>
# ## Hyperparameter Tuning -- Grid Search -- Cross Validation
# We will compare 5 ml classifier and evaluate mean accuracy of each of them by stratified cross validation.
#
# * Decision Tree
# * SVM
# * Random Forest
# * KNN
# * Logistic Regression

# %%
random_state = 42
classifier = [DecisionTreeClassifier(random_state = random_state),
             SVC(random_state = random_state),
             RandomForestClassifier(random_state = random_state),
             LogisticRegression(random_state = random_state),
             KNeighborsClassifier(),
             GradientBoostingClassifier()]

dt_param_grid = {"min_samples_split" : range(10,500,20),
                "max_depth": range(1,20,2)}

svc_param_grid = {"kernel" : ["rbf"],
                 "gamma": [0.001, 0.01, 0.1, 1],
                 "C": [1,10,50,100,200,300,1000]}

rf_param_grid = {"max_features": [1,3,10],
                "min_samples_split":[2,3,10],
                "min_samples_leaf":[1,3,10],
                "bootstrap":[False],
                "n_estimators":[100,300],
                "criterion":["gini"]}

logreg_param_grid = {"C":np.logspace(-3,3,7),
                    "penalty": ["l1","l2"]}

knn_param_grid = {"n_neighbors": np.linspace(1,19,10, dtype = int).tolist(),
                 "weights": ["uniform","distance"],
                 "metric":["euclidean","manhattan"]}
gbc_grid = {"loss":["deviance"],
    "learning_rate": [0.05, 0.1, 0.15, 0.2],
    "min_samples_split":[2],
    "min_samples_leaf":[1],
    "max_depth":[12],
    "max_features":["log2","sqrt"],
    "criterion": ["friedman_mse",  "mae"],
    "subsample":[0.1],
    "n_estimators":[100]}

classifier_param = [dt_param_grid,
                   svc_param_grid,
                   rf_param_grid,
                   logreg_param_grid,
                   knn_param_grid,
                    gbc_grid]

# %%
cv_result = []
best_estimators = []
for i in range(len(classifier)):
    clf = GridSearchCV(classifier[i], param_grid=classifier_param[i], cv = StratifiedKFold(n_splits = 10), scoring = "accuracy", n_jobs = -1,verbose = 1)
    clf.fit(X_train,y_train)
    cv_result.append(clf.best_score_)
    best_estimators.append(clf.best_estimator_)
    print(cv_result[i])

# %%
cv_results = pd.DataFrame({"Cross Validation Means":cv_result, "ML Models":["DecisionTreeClassifier", "SVM","RandomForestClassifier",
             "LogisticRegression",
             "KNeighborsClassifier", "GradientBoostingClassifier"]})

g = sns.barplot("Cross Validation Means", "ML Models", data = cv_results)
g.set_xlabel("Mean Accuracy")
g.set_title("Cross Validation Scores")

# %% [markdown]
# <a id = "31"></a><br>
# ## Ensemble Modeling

# %%
votingC = VotingClassifier(estimators = [("svc",best_estimators[1]),
                                         ("rfc",best_estimators[2]),
                                        ("lr",best_estimators[3]),
                                        ("dt",best_estimators[0]),
                                        ("gbc", best_estimators[4])],
                                        voting = "hard", n_jobs = -1)
votingC = votingC.fit(X_train, y_train)
print(accuracy_score(votingC.predict(test),testy))

# %%
votingC = VotingClassifier(estimators = [("svc",best_estimators[1]),
                                         ("rfc",best_estimators[2]),
                                        ("lr",best_estimators[3]),
                                        ("dt",best_estimators[0]),
                                        ("gbc", best_estimators[4])],
                                        voting = "hard", n_jobs = 1)
votingC = votingC.fit(X_traind, Y_traind)
votingC = votingC.fit(X_train, y_train)
votingC = votingC.fit(test, testy)

print(accuracy_score(votingC.predict(X_traind),Y_traind))

# %% [markdown]
# YT

# %%
votingC = VotingClassifier(estimators = [("svc",best_estimators[1]),
                                         ("rfc",best_estimators[2]),
                                        ("lr",best_estimators[3]),
                                        ("dt",best_estimators[0]),
                                        ("gbc", best_estimators[5])],
                                        voting = "hard", n_jobs = -1)
votingC = votingC.fit(X_train, y_train)
print(accuracy_score(votingC.predict(test),testy))

# %%
votingC = VotingClassifier(estimators = [("svc",best_estimators[1]),
                                         ("rfc",best_estimators[2]),
                                        ("lr",best_estimators[3]),
                                        ("dt",best_estimators[0]),
                                        ("gbc", best_estimators[5])],
                                        voting = "hard", n_jobs = -1)
votingC = votingC.fit(X_train, y_train)
print(accuracy_score(votingC.predict(X_traind),Y_traind))
print(classification_report(votingC.predict(X_traind),Y_traind))

# %%
X_traind

# %%
Y_traind

# %% [markdown]
# <a id = "32"></a><br>
# ## Prediction and Submission

# %%
test_survived = pd.Series(votingC.predict(test), name = "TS").astype(int)
votingC = VotingClassifier(estimators = [("svc",best_estimators[1]),
                                         ("rfc",best_estimators[2]),
                                        ("lr",best_estimators[3]),
                                        ("dt",best_estimators[0]),
                                        ("gbc", best_estimators[5])],
                                        voting = "hard", n_jobs = -1)
votingC = votingC.fit(X_train, y_train)
print(accuracy_score(votingC.predict(test),testy))
print(classification_report(votingC.predict(test),testy))

# %%
test_survived = pd.Series(votingC.predict(test), name = "TS").astype(int)
votingC = VotingClassifier(estimators = [("dt",best_estimators[0]),
                                        ("rfc",best_estimators[2]),
                                        ("db",best_estimators[5])],
                                        voting = "hard", n_jobs = -1)
votingC = votingC.fit(X_train, y_train)
print(accuracy_score(votingC.predict(X_test), y_test))
print(classification_report(votingC.predict(X_test), y_test))

# %%
CX=pd.concat([X_train, X_traind],axis =0)

# %%
CY=pd.concat([y_train, Y_traind],axis =0)

# %%
CY

# %%
CX

# %%
X_train

# %%
X_traind

# %%
test_survived = pd.Series(votingC.predict(test), name = "TS").astype(int)
votingC = VotingClassifier(estimators = [("dt",best_estimators[0]),
                                        ("rfc",best_estimators[2]),
                                        ("db",best_estimators[5])],
                                        voting = "hard", n_jobs = -1)
votingC = votingC.fit(X_train, y_train)
print(accuracy_score(votingC.predict(X_test), y_test))
print(classification_report(votingC.predict(X_test), y_test))

# %%
votingC = votingC.fit(CX, CY)
print("score: ", votingC.score(X_traind,Y_traind))
y_pred2 = votingC.predict(X_traind)
y_true2 = Y_traind
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true2,y_pred2)

# %%
cm

# %%
f, ax = plt.subplots(figsize =(5,5))
sns.heatmap(cm,annot = True,linewidths=0.5,linecolor="red",fmt = ".0f",ax=ax)
plt.xlabel("y_pred2")
plt.ylabel("y_true2")
plt.show()

# %%
votingC = VotingClassifier(estimators = [("svc",best_estimators[1]),
                                         ("rfc",best_estimators[2]),
                                        ("lr",best_estimators[3]),
                                        ("dt",best_estimators[0]),
                                        ("gbc", best_estimators[5])],
                                        voting = "hard", n_jobs = -1)
votingC = votingC.fit(CX, CY)
print(accuracy_score(votingC.predict(X_traind),Y_traind))
print(classification_report(votingC.predict(X_traind),Y_traind))
