# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import seaborn as sn
import os
import re

# %%
os.getcwd()
os.chdir('/kaggle/working')

# %%
pulwa=pd.read_csv("../input/pulwama-killing-twitter-data/kashmir.csv")
pulwa

# %%
pul=pulwa['text']

# %%
pul

# %%
from nltk.corpus import stopwords as stop
from wordcloud import WordCloud as wc
from nltk.tokenize import word_tokenize  as wordt , sent_tokenize as sent

# %%
jp=' '.join(pul)

# %%
type(jp)

# %%
jp

# %%
import nltk
nltk.word_tokenize(jp)

# %%
jp1=re.sub("[^A-Za-z]"," " ,jp).replace("https","  ").replace("co"," " ).replace('amp',"  ")
jp1

# %%
import nltk
nltk.word_tokenize(jp1)

# %%
stopw=stop.words("english")
stopw

# %%
pwc=wc(max_words=150,stopwords=stopw,background_color='white')
pwc.generate(jp1)

# %%
plot.figure(figsize=(18,18))
plot.imshow(pwc)
