# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets
import altair as alt
alt.renderers.enable('notebook')
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder


# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['combats.csv', 'pokemon.csv', 'tests.csv']

# %%
#load data
data = pd.read_csv("../input/pokemon.csv", skipinitialspace=True)

# %% [markdown]
# <h1>Learning Details About Dataframe</h1>

# %%
#print out top 5 data from dataframe
data.head()
# Out:
#    #           Name Type 1    ...     Speed  Generation  Legendary
# 0  1      Bulbasaur  Grass    ...        45           1      False
# 1  2        Ivysaur  Grass    ...        60           1      False
# 2  3       Venusaur  Grass    ...        80           1      False
# 3  4  Mega Venusaur  Grass    ...        80           1      False
# 4  5     Charmander   Fire    ...        65           1      False
#
# [5 rows x 12 columns]

# %%
#check info about the dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          799 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.6+ KB

# %% [markdown]
# Above infos tell us:
# <li>We have 800 rows of data</li>
# <li>We have 12 columns</li>
# <li>We have 1 boolean variable, 8 integer variables, and 3 objects</li>
# <li>We only have null varibles from Name and Type 2 columns</li>
# <li>Dataset size is 69.6+ KB</li>

# %%
#check NaN values
data.isnull().sum()
# Out:
# #               0
# Name            1
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %% [markdown]
# We have 1 null value from Name column and 386 null values from Type 2 column

# %%
#we can drop NaN values from our dataframe
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# #             0
# Name          0
# Type 1        0
# Type 2        0
# HP            0
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Generation    0
# Legendary     0
# dtype: int64

# %%
#correlation between features
f, ax = plt.subplots(figsize = (18, 18))
sns.heatmap(data.corr(), annot = True, linewidth = .5, fmt = ".1f", ax = ax)
plt.show()

# %% [markdown]
# higher correlation means higher proportion between  features
#
# if correlation is positive then we can give this example: if the quantity of a room in a house increase, then the price of the house also increase.

# %% [markdown]
# <h1>Virtualization and Analysing</h1>

# %%
data1 = data.loc[:, ["Attack", "Speed", "Defense", "HP"]]
data1.plot()
plt.show()

# %%
data1.plot(subplots = True)
plt.show()

# %%
#we can also use scatter graph
data.plot(kind = "scatter", x = "Attack", y = "Defense", color = "b", linewidth = 1)
plt.xlabel("Attack")
plt.ylabel("Defense")
plt.show()

# %% [markdown]
# from above graph:
# <li>Most of the attack power gather around 50-100</li>
# <li>Most of the defense power gather around 50-100</li>
# <li>We have some exaggeration attack values which are greater than 175</li>
# <li>We have some exaggeration defense values which are greater than 200</li>

# %%
#we can plot histogram graph
data.Attack.plot(kind = "hist", bins = 50, figsize = (15, 15))
plt.xlabel("Attack")
plt.show()

# %%
#we can see count, mean, std, min, max values of numeric data
data.describe()
# Out:
#                 #          HP     ...           Speed  Generation
# count  414.000000  414.000000     ...      414.000000  414.000000
# mean   415.456522   70.649758     ...       70.514493    3.410628
# std    235.907863   22.896557     ...       28.521408    1.663010
# min      1.000000    1.000000     ...        5.000000    1.000000
# 25%    221.500000   55.000000     ...       50.000000    2.000000
# 50%    416.000000   70.000000     ...       70.000000    3.000000
# 75%    622.750000   85.000000     ...       91.000000    5.000000
# max    800.000000  150.000000     ...      160.000000    6.000000
#
# [8 rows x 8 columns]

# %%
#we can also plot outlier 
data.boxplot(column = "Attack", by = "Legendary")
plt.show()

# %% [markdown]
# <p>black circles are representing outliers</p>

# %%
@ipywidgets.interact
def plot(color = ['red', 'steelblue', 'green', 'blue']):
    (sns.barplot(y = 'Name', x = 'Attack', data = data.head(10), orient = 'h', color = color))
# Out:
# interactive(children=(Dropdown(description='color', options=('red', 'steelblue', 'green', 'blue'), value='red'…

# %%
#we can also create pivot table
pd.pivot_table(data,index=["Name"])
# Out:
#                           #  Attack  Defense  ...    Sp. Atk  Sp. Def  Speed
# Name                                          ...
# Abomasnow               511      92       75  ...         92       85     60
# Aegislash Blade Forme   751     150       50  ...        150       50     60
# Aegislash Shield Forme  752      50      150  ...         50      150     60
# Aerodactyl              154     105       65  ...         60       75    130
# Aggron                  333     110      180  ...         60       60     50
# Altaria                 366      70       90  ...         70      105     80
# Amaura                  769      59       50  ...         67       63     46
# Amoonguss               653      85       70  ...         85       80     30
# Anorith                 380      95       50  ...         40       50     75
# Archen                  628     112       45  ...         74       45     70
# Archeops                629     140       65  ...        112       65    110
# Ariados                 183      90       70  ...         60       60     40
# Armaldo                 381     125      100  ...         70       80     45
# Aron                    331      70      100  ...         40       40     30
# Articuno                157      85      100  ...         95      125     85
# Aurorus                 770      77       72  ...         99       92     58
# Azumarill               200      50       80  ...         60       80     50
# Azurill                 323      20       40  ...         20       40     20
# Baltoy                  376      40       55  ...         40       70     55
# Barbaracle              760     105      115  ...         54       86     68
# Barboach                372      48       43  ...         46       41     60
# Bastiodon               457      52      168  ...         47      138     30
# Beautifly               291      70       50  ...        100       50     65
# Beedrill                 19      90       40  ...         45       80     75
# Beldum                  411      55       80  ...         35       60     30
# Bellsprout               76      75       35  ...         70       30     40
# Bibarel                 446      85       60  ...         55       60     71
# Binacle                 759      52       67  ...         39       56     50
# Bisharp                 687     125      100  ...         60       70     70
# Blaziken                279     120       70  ...        110       70     80
# ...                     ...     ...      ...  ...        ...      ...    ...
# Vileplume                51      80       85  ...        110       90     50
# Virizion                702      90       72  ...         90      129    108
# Vivillon                735      52       50  ...         90       50     89
# Volcanion               800     110      120  ...        130       90     70
# Volcarona               699      60       65  ...        135      105    100
# Vullaby                 691      55       75  ...         45       65     60
# Walrein                 401      80       90  ...         95       90     65
# Wash Rotom              534      65      107  ...        105      107     86
# Weavile                 513     120       65  ...         45       85    125
# Weedle                   17      35       30  ...         20       20     50
# Weepinbell               77      90       50  ...         85       45     55
# Whimsicott              608      67       85  ...         77       75    116
# Whirlipede              605      55       99  ...         40       79     47
# Whiscash                373      78       73  ...         76       71     60
# Wigglytuff               46      70       45  ...         85       50     45
# Wingull                 302      30       30  ...         55       30     85
# Woobat                  587      45       43  ...         55       43     72
# Wooper                  210      45       45  ...         25       25     15
# Wormadam Plant Cloak    459      59       85  ...         79      105     36
# Wormadam Sandy Cloak    460      79      105  ...         59       85     36
# Wormadam Trash Cloak    461      69       95  ...         69       95     36
# Xatu                    193      75       70  ...         95       70     95
# Yanma                   209      65       45  ...         75       45     95
# Yanmega                 521      76       86  ...        116       56     95
# Yveltal                 794     131       95  ...        131       98     99
# Zapdos                  158      90       85  ...        125       90    100
# Zekrom                  708     150      120  ...        120      100     90
# Zubat                    47      45       35  ...         30       40     55
# Zweilous                696      85       70  ...         65       70     58
# Zygarde Half Forme      795     100      121  ...         81       95     95
#
# [414 rows x 9 columns]

# %% [markdown]
# <p>Before feeding KNN Classifier with our data, we have to do some removing and categorizing</p>

# %%
#we have to remove Name
data = data.drop('Name', axis = 1)

# %%
#we have to give numerical values to Legendary column
data.iloc[:, 5:6] = data.iloc[:, 5:6].apply(LabelEncoder().fit_transform)

# %%
from collections import Counter
count  = pd.Series(data['Type 1'].str.replace('[\[\]\']','').str.split(',').map(Counter).sum())
ln_list = range(0, len(count))
categorize = list(ln_list)
type(categorize[0])
# Out:
# int

# %%
#we also have to categorize Type 1 and Type 2
#data['Type 1'] = pd.Categorical(data['Type 1'], categories= data['Type 1'].unique()).codes

# %%
data.iloc[:, 1:3] = data.iloc[:, 1:3].apply(LabelEncoder().fit_transform)
data.head()
# Out:
#    #  Type 1  Type 2  HP    ...      Sp. Def  Speed  Generation  Legendary
# 0  1       9      13  45    ...           65     45           1      False
# 1  2       9      13  60    ...           80     60           1      False
# 2  3       9      13  80    ...          100     80           1      False
# 3  4       9      13  80    ...          120     80           1      False
# 6  7       6       7  78    ...           85    100           1      False
#
# [5 rows x 11 columns]

# %%
data = data.drop('#', axis = 1)

# %%
#assign target value
target = data['Legendary']
#drop target value from the dataframe
data = data.drop('Legendary', axis = 1)

# %%
#create KNN object
knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(data, target)
KNeighborsClassifier(algorithm = 'auto', leaf_size = 30, 
                    metric = "minkowski", metric_params = None, n_jobs = None, 
                    n_neighbors = 5, p = 2, weights = 'uniform')
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
poke = [157,133,30,70,120,100,135,95, 0]
poke = np.array(poke).reshape(1, -1)
poke
# Out:
# array([[157, 133,  30,  70, 120, 100, 135,  95,   0]])

# %%
prediction = knn.predict(poke)
result = 'Legendary' if prediction == True else 'Not Legendary'
print(result)
# Out:
# Not Legendary
