# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import cufflinks as cf
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import seaborn as sns

init_notebook_mode(connected = True)
cf.go_offline()
# %matplotlib inline

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
pip install plotly==4.8.1

# %%
pip install cufflinks

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

print(__version__) # requires version atleast>= 4.8.1

# %%
import cufflinks as cf

# %%
# For Notebooks
init_notebook_mode(connected=True)

# %%
# For offline use
cf.go_offline()

# %%
df = pd.read_csv('../input/buildingdatagenomeproject2/solar_cleaned.csv')
df.head()

# %% [markdown]
# #Codes from Omar Hany https://www.kaggle.com/omarhanyy/using-matplotlib-seaborn-and-plotly/comments

# %%
df.iplot(kind='scatter',x='timestamp',y='Bobcat_education_Dylan',mode='markers',size=10, color='pink', title='Bobcat Education Dylan')

# %%
df.iplot(kind='bar',x='timestamp',y='Bobcat_education_Dylan',colors='Red' , title='Bobcat Education Dylan')

# %%
df.iplot(kind='bar',x='timestamp',y='Bobcat_education_Alissa',color="blue",title='Bobcat Education Alissa' )

# %%
df.iplot(kind='bar',x='timestamp',y='Bobcat_education_Coleman',color="green",title='Bobcat Education Coleman')

# %%
df.iplot(kind='bar',x='timestamp',y='Bobcat_other_Timothy',color="purple",title='Bobcat Other Timothy')

# %%
df.drop(columns=["timestamp","Bobcat_education_Dylan"]).iplot(kind='box')

# %% [markdown]
# #3D Surface

# %%
#df = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})
df.drop(columns=["timestamp","Bobcat_education_Dylan"]).iplot(kind='surface',colorscale='rdylbu')

# %%
df.iplot(x = 'timestamp', y = 'Bobcat_education_Dylan', color='pink', title='Bobcat Education dylan')

# %%
df['Bobcat_education_Dylan'].iplot(kind = 'hist', color='green', bins = 25, title= 'Bobcat Education Dylan')

# %%
# Box plot for our dataset 
df.iplot(kind = 'box', title='Bobcats Building Data')

# %%
df.iplot()

# %%
# Using a Scatter plot for the Building Data (Bobcat location site)   
df.iplot(kind = 'scatter', x = 'timestamp', y = 'Bobcat_education_Dylan', mode='markers',symbol='circle-dot',colors=['teal'], size=20, title='Bobcat Education Dylan')

# %%
df.Bobcat_education_Dylan.iplot()

# %%
df.timestamp.iplot()

# %% [markdown]
# Das War´s Kaggle Notebook Runner: Marília Prata   @mpwolke
