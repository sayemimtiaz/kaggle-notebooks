# %% [markdown]
# # Imporing Library

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df= pd.read_csv(r"/kaggle/input/netflix-original-films-imdb-scores/NetflixOriginals.csv", encoding='ISO-8859-1')

# %%
df.head()

# %%
# Check The shape Of DataFrame

print("The Shape Of DataFrame:-", df.shape)

# %%
# Check the Information of DataFrame
df.info()

# %%
# Describe the Data Frame
df.describe()

# %% [markdown]
# # According to above analyis we can say that Max Scroe is 9.0 and Min Score is 2.5

# %%
# Now count the Genre 

df["Genre"].value_counts()

# %% [markdown]
# ### <b> According:- </b>
# To above analysis we can say that Documentary Genre Have the highest Number of Movie Count :- 159

# %%
# Now Get Only those Movie Which Have Thosse Score is Greater than

# %%
mask1 = df[df["IMDB Score"] >= 8.0]

# %%
mask1

# %%
# ploting the Graph


plt.figure(figsize=(12,12))

sns.barplot(x='IMDB Score', y= "Title", hue="Genre", data=mask1)

# %%
# Above Are Those Movie Which have High ImDb Score Is more than 8.0

# %%
#
score_5 = df[df["IMDB Score"]<=5]

# %%
sns.set(rc={"figure.figsize":(20,18)})
sns.barplot(x='IMDB Score', y= "Title", data=score_5)

# %%
# Above Are these Movies which Rating are Lesss than or equal to 5

# %%
Genre_low = df[df['IMDB Score']<=5][["Title","Genre","IMDB Score","Language" ]].sort_values("IMDB Score", ascending=True)

# %%
Genre_low

# %%
sns.catplot(x="Genre", kind="count", data=Genre_low[:15], aspect= 49/11)

# %%
# Top Genre Which Have Ratting Below 5

# %%
plt.figure(figsize=(28,9))

df["Genre"].value_counts().plot(kind= "bar")

# %% [markdown]
# ### Above are the Top Genre In the Data Sets
# Documentary, Drama, Comedy, Romantic comedy, Thriller

# %%
# Genre High 

Genre_High = df[df["IMDB Score"]>=7][["Title","Genre","IMDB Score","Language"]].sort_values("IMDB Score", ascending=True)

# %%
Genre_High

# %%
sns.catplot(x="Genre", kind="count",data= Genre_High[:15], aspect=50.7/11.2)

# %%
# Top Genre Where IMDB Score is Greater Than 7

Genre_High[:40].value_counts().plot(kind = "pie", autopct= "%.2f")

# %%
df["Genre"].value_counts().plot(kind= "pie", autopct= "%.2f")

# %%
df["Language"].value_counts().plot(kind= "bar")

# %%
df["Language"].value_counts().plot(kind= "pie",autopct= "%.2f")

# %%
plt.figure(figsize=(12,12))

sns.barplot(x = "IMDB Score", y= "Title", hue="Language", data= mask1)

# %% [markdown]
# <b> Obervation </b> In the Above Obervation we Can Say That There are Only 3 Movies which Are NON- English ANd Have Score

# %%
sns.catplot(x= "Language", kind="count",data= Genre_low, aspect=50.2/11)

# %%
# Imdb Movies less than 5 and There Language

# %%
# List Of 20 Movies Which Have Genre = Documentary
df[df["Genre"]=="Documentary"][:20].value_counts().plot(kind="pie")
