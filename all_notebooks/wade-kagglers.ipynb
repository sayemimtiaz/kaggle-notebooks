# %% [markdown]
# <a id="1.1"></a>
# <h3 style="background-color:skyblue;font-family:newtimeroman;font-size:200%;text-align:center">Wade in the Water</h3>

# %% [markdown]
# "Wade in the Water" is an African American jubilee song, a spiritual—in reference to a genre of music "created and first sung by African Americans in slavery". The lyrics to "Wade in the Water" were first co-published in 1901 in New Jubilee Songs as Sung by the Fisk Jubilee Singers by Frederick J. Work and his brother, John Wesley Work Jr., an educator at the historically black college in Nashville, Tennessee, Fisk University.
#
# Work Jr. (1871 – 1925)—who is also known as John Work II—spent thirty years collecting, promoting, and reviving the songcraft of the original Fisk Jubilee Singers, which included being a member and director of the Fisk Jubilee Quartet. The Sunset Four Jubilee Singers made the first commercial recording of "Wade in the Water" in 1925—released by Paramount Records. W. E. B. Du Bois, who called this genre of songs, the Sorrow Songs, reviewed the Sunset Four Jubilee Singers' performance of "Wade in the Water" in a 1925.
#
# INTERPRETATION OF THE LYRICS
#
# Fisk University was founded by the American Missionary Association. Many of the songs in the original Fisk Jubilee Singers songbooks dealt with themes from both the Old and New Testament. According to a 2002 article written by Dave Watermulder, J. Amber Hudlin, and Ellie Kaufman at George Washington University, the song reflect the Israelites' escape out of Egypt as found in Exodus.
#
# According to a 2007 anthology by California State University in Fresno, the singer "warns of the coming signs of the end" but says the "victory of Heaven over Hell" is assured, and "looks forward to future freedom.
#
# https://en.wikipedia.org/wiki/Wade_in_the_Water

# %% [markdown]
# ![](https://m.media-amazon.com/images/M/MV5BMTc3MTU2MjMyNl5BMl5BanBnXkFtZTcwMTg5Mzk5Mw@@._V1_.jpg)imdb.com

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# <iframe width="677" height="381" src="https://www.youtube.com/embed/QfmHWavDhZc" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# #Wade in the Water  https://www.youtube.com/watch?v=QfmHWavDhZc

# %%
# !pip install -U spacy

# %% [markdown]
# <a id="1.1"></a>
# <h3 style="background-color:skyblue;font-family:newtimeroman;font-size:200%;text-align:center">Wade in the water.
# Wade in the water
# Children. Wade, in the water.
# God's gonna trouble the water</h3>

# %%
# !python -m spacy download en_core_web_lg

# %%
# !python -m spacy download en_core_web_sm

# %% [markdown]
# <a id="1.1"></a>
# <h3 style="background-color:skyblue;font-family:newtimeroman;font-size:200%;text-align:center">Well, who are these children all dressed in red?
# God's a-gonna trouble the water.
# Must be the children that Moses led.
# God's a-gonna trouble the water.</h3>

# %%
# !pip install wordcloud

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# <a id="1.1"></a>
# <h3 style="background-color:skyblue;font-family:newtimeroman;font-size:200%;text-align:center">Who's that young girl dressed in white?
# Wade in the Water.
# Must be the Children of Israelites.
# God's gonna trouble the Water.</h3>

# %%
#Code By Paul Mooney

church_file = '../input/the-church-in-the-southern-black-community/texts/church-duboisau-dubois.txt'
with open(church_file) as f: # The with keyword automatically closes the file when you are done
    print (f.read(3000))

# %%
#Tokenization

import spacy

nlp = spacy.load('en_core_web_sm')
doc = nlp("The sky of brightest grey seems dark, To one whose sky was ever white, To one who never knew a spark")
for token in doc:
    print(token.text)

# %% [markdown]
# <a id="1.1"></a>
# <h3 style="background-color:skyblue;font-family:newtimeroman;font-size:200%;text-align:center">Jordan's water is chilly and cold.
# God's gonna trouble the water.
# It chills the body, but not the soul.
# God's gonna trouble the water.</h3>

# %%
from spacy import displacy

doc = nlp("Thro' all his life of love or light, The greyest cloud seems overbright. By Dunbar")
displacy.render(doc, style="dep" , jupyter=True)

# %% [markdown]
# <a id="1.1"></a>
# <h3 style="background-color:skyblue;font-family:newtimeroman;font-size:200%;text-align:center">Who's that young girl dressed in blue?
# Wade in the water.
# Must be the children that's coming through.
# God's gonna trouble the water.</h3>

# %%
#Code By Paul Mooney

morals_file = '../input/the-church-in-the-southern-black-community/texts/church-morals-dubois.txt'
with open(morals_file) as f: # The with keyword automatically closes the file when you are done
    print (f.read(3000))

# %%
#Lemmatization

nlp = spacy.load('en_core_web_sm')

# Create an nlp object
doc = nlp("OH THOU, who didst with pitfall and with gin, Beset the Road I was to wander in")
 
# Iterate over the tokens
for token in doc:
    # Print the token and its part-of-speech tag
    print(token.text, "-->", token.lemma_)

# %%
nlp = spacy.load('en_core_web_sm')

# Create an nlp object
doc = nlp("Thou wilt not with Predestin'd Evil round. Enmesh, and then impute my Fall to Sin!")
 
sentences = list(doc.sents)
len(sentences)

# %% [markdown]
# <a id="1.1"></a>
# <h3 style="background-color:skyblue;font-family:newtimeroman;font-size:200%;text-align:center">Wade in the water.
# Wade in the water
# Children. Wade, in the water.
# God's gonna trouble the water</h3>

# %%
for sentence in sentences:
     print (sentence)

# %%
from spacy import displacy
nlp = spacy.load("en_core_web_sm")
doc= nlp(u"""Atlanta University is an institution for the higher education of Negro youth. It seeks by maintaining a high standard of scholarship and deportment, to sift out and train thoroughly, talented members of this race to be leaders of thought and missionaries of culture among the masses. three investigations: One in 1896 into the Mortality of Negroes in Cities; another in 1897 into the General Social and Physical Condition of 5,000 Negroes living in selected parts of certain Southern cities; finally, in 1898, inquiry has been made to ascertain what efforts Negroes are themselves making to better their social condition by means of organization.
The results of this last investigation are presented in this pamphlet. Next year some phases of the economic situation of the Negro will be studied. It is hoped that these studies will have the active aid and co-operation of all those who are interested in this method of making easier the solution of the Negro problems.
""")

entities=[(i, i.label_, i.label) for i in doc.ents]
entities

# %%
displacy.render(doc, style = "ent",jupyter = True)

# %%
nlp = spacy.load("en_core_web_lg")
tokens = nlp("we must depend for the peace and progress of the world upon the formation of a horizontal upper layer of cultured persons among all the more civiized peoples—a cross-section, as it were, of the nations, whose convictions and sentiments shall supply the moral force on which international arbitration courts and similar agencies will have to depend.—Felix Adler")

for token in tokens:
    print(token.text, token.has_vector, token.vector_norm, token.is_oov)

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
nlp = spacy.load("en_core_web_lg")  # make sure to use larger model!
tokens = nlp("There is only one sure basis of social reform and that is Truth — a careful, detailed knowledge of the essential facts of each social problem. Without this there is no logical starting place for reform and uplift. Social difficulties may be clear and we may inveigh against them, but the causes proximate and remote are seldom clear to the casual observer and usually are quite hidden from the man who suffers from, or is sensitive to, the results of the snarl. To no set of problems are these truths more applicable than to the so-called Negro problems. One of the most fundamental of these problems is that of the manners of the Negro race. On this question the most diverse and contradictory opinions are confidently exprest, leaving the real inquirer for truth in great bewilderment.")

newText =''
for word in tokens:
 if word.pos_ in ['ADJ', 'NOUN']:
  newText = " ".join((newText, word.text.lower()))

wordcloud = WordCloud(stopwords=STOPWORDS, colormap='Reds', background_color="green").generate(newText)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
df = pd.read_csv('../input/the-church-in-the-southern-black-community/toc.csv', encoding='utf8')
pd.set_option('display.max_columns', None)
df.tail()

# %%
df["Date"].value_counts()

# %% [markdown]
# <a id="1.1"></a>
# <h3 style="background-color:skyblue;font-family:newtimeroman;font-size:200%;text-align:center">Wade in the water.
# Wade in the water
# Children. Wade, in the water.
# God's gonna trouble the water.</h3>

# %%
#word cloud
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in df.Title)
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200,colormap='Set3', background_color="salmon").generate(text)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='Bilinear')
plt.axis("off")
plt.figure(1,figsize=(12, 12))
plt.show()

# %%
#word cloud
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in df.Filename)
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200,colormap='Set3', background_color="silver").generate(text)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='Bilinear')
plt.axis("off")
plt.figure(1,figsize=(12, 12))
plt.show()

# %%
# !pip install beautifulsoup4

# %%
# !pip install selenium

# %%
# !pip install scrapy

# %%
# !pip install praw

# %%
# !pip install newspaper3k

# %% [markdown]
# <a id="1.1"></a>
# <h3 style="background-color:skyblue;font-family:newtimeroman;font-size:200%;text-align:center">You don't believe I've been redeemed.
# Wade in the water.
# Just so the whole lake goes looking for me.
# God's gonna trouble the water.</h3>

# %%
# importing basic libraries
import datetime as dt


# importing libraries for scraping
#from twitterscraper import query_tweets
from urllib.request import urlopen
from selenium import webdriver
from bs4 import BeautifulSoup
from newspaper import Article
import scrapy
import praw

# %%
#Fifth column, URL, 4th Row

df.iloc[4,4]

# %%
#A new article from TOI 
url = "https://docsouth.unc.edu/church/gaineswj/menu.html"

# %%
#For different language newspaper refer above table 
toi_article = Article(url, language="en") # en for English

# %%
import nltk
nltk.download('punkt')

# %% [markdown]
# <a id="1.1"></a>
# <h3 style="background-color:skyblue;font-family:newtimeroman;font-size:200%;text-align:center">Wade in the water.
# Wade in the water
# Children. Wade, in the water.
# God's gonna trouble the water</h3>

# %%
#To download the article 
toi_article.download() 
  
#To parse the article 
toi_article.parse() 
  
#To perform natural language processing ie..nlp 
toi_article.nlp()

# %% [markdown]
# #We should work with URL, because URL text only didn't return anything

# %%
#To extract title 
print("Article's Title:") 
print(toi_article.title) 
print("n") 
  
#To extract text 
print("Article's Text:") 
print(toi_article.text) 
print("n") 
  
#To extract summary 
print("Article's Summary:") 
print(toi_article.summary) 
print("n") 
  
#To extract keywords 
print("Article's Keywords:") 
print(toi_article.keywords)

# %% [markdown]
# <a id="1.1"></a>
# <h3 style="background-color:skyblue;font-family:newtimeroman;font-size:200%;text-align:center">If you get there before I do.
# God's gonna trouble the water.
# Tell all of my friends I'm coming too.
# God's gonna trouble the water.</h3>
