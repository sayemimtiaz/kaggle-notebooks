# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df1=pd.read_csv("../input/summer-products-and-sales-in-ecommerce-wish/summer-products-with-rating-and-performance_2020-08.csv")

# %%
df1

# %%
df1.columns

# %%
df1=df1.drop(columns=['title','title_orig'])

# %%
df1

# %%
df1=df1.drop(columns=['merchant_id','product_url','product_picture','product_id'])

# %%
df1

# %%
df1=df1.drop(columns=['merchant_title','merchant_name','merchant_info_subtitle'])

# %%
df1

# %%
df1=df1.drop(columns=['urgency_text'])

# %%
df1

# %%
df1.info()

# %%
df1['currency_buyer'].unique()

# %%
df1=df1.drop(columns=['tags','product_color','product_variation_size_id','shipping_option_name','origin_country','merchant_profile_picture','crawl_month'])

# %%
df1.info()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df1['currency_buyer']=le.fit_transform(df1['currency_buyer'])

# %%
df1.info()

# %%
df1['theme']=le.fit_transform(df1['theme'])

# %%
df1.info()

# %%
df1

# %%
df1.duplicated().sum()

# %%
df1.drop_duplicates(inplace=True)

# %%
df1

# %%
df1=df1.drop(columns=['currency_buyer'])

# %%
df1

# %%
df1=df1.drop(columns=['rating_count'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(16,6))
sns.barplot(x='retail_price',y='price',data=df1)

# %%
df1

# %%
df1.head().T

# %%
df1.isnull().sum()

# %%
df1['has_urgency_banner']=df1['has_urgency_banner'].fillna(0)

# %%
df1.isnull().sum()

# %%
mean=df1['rating_five_count'].mean()
df1['rating_five_count']=df1['rating_five_count'].fillna(mean)

# %%
mean_4=df1['rating_four_count'].mean()
df1['rating_four_count']=df1['rating_four_count'].fillna(mean_4)
mean_3=df1['rating_three_count'].mean()
df1['rating_three_count']=df1['rating_three_count'].fillna(mean_3)

# %%
df1.isnull().sum()

# %%
df1['rating_two_count'].mean()

# %%
mean_2=df1['rating_two_count'].mean()
df1['rating_two_count']=df1['rating_two_count'].fillna(mean_2)
mean_1=df1['rating_one_count'].mean()
df1['rating_one_count']=df1['rating_one_count'].fillna(mean_1)

# %%
df1.isnull().sum()

# %%
df1.columns

# %%
X=df1.drop(columns=['units_sold'])

# %%
X

# %%
Y=df1['units_sold']

# %%
Y

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
#Linear Regression
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,Y_train)
Y_pred=regressor.predict(X_test)
from sklearn.metrics import r2_score
r2_score(Y_pred,Y_test)

# %%
# Decision Tree
from sklearn.tree import DecisionTreeRegressor
regressor=DecisionTreeRegressor()
regressor.fit(X_train,Y_train)
Y_pred=regressor.predict(X_test)
from sklearn.metrics import r2_score
r2_score(Y_pred,Y_test)

# %%
#random-forest
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor(n_estimators=10000)
regressor.fit(X_train,Y_train)
Y_pred=regressor.predict(X_test)
from sklearn.metrics import r2_score
r2_score(Y_pred,Y_test)

# %%
# XG BOost
from xgboost import XGBRegressor
reagressor=XGBRegressor()
regressor.fit(X_train,Y_train)
Y_pred=regressor.predict(X_test)
from sklearn.metrics import r2_score
r2_score(Y_pred,Y_test)
