# %%
import numpy as np
import pandas as pd
import os

# %%
df = pd.read_csv('/kaggle/input/lending-club-dataset/lending_club_loan_two.csv')
df.shape

# %%
df['purpose'].value_counts()

# %%
df_auto = df[df['purpose'] == 'car'].copy()
df_auto.shape

# %%
df_auto.to_csv('AutoLoans.csv')

# %%
df_auto.columns
