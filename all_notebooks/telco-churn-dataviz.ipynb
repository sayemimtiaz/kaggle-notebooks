# %% [markdown]
# # A graph of computed lifts
#
#
# I uploaded the dataset to [Visao-data.com](https://visao-data.com/graph_explorer.php?dataset_id=38) to display all the lifts between all the attributes.
#
#
#
# <img src= "https://visao-data.com/screen_shots/Screen Shot telco churn.png" alt ="Telco Churn" style='width: 800px;'>
#
# This screen capture shows all the attributes that explain the churn
#
# <img src= "https://visao-data.com/screen_shots/Screen Shot telco churn_2.png" alt ="Telco Churn" style='width: 800px;'>
