# %%
import tensorflow as tf
print(tf.__version__)
import numpy as np
import pandas as pd
from numpy.random import seed
seed(1)

# %%
pred1 =np.load('../input/preds-from-berts/pred.npy')

# %%
pred1[:10]

# %%
#preds_flat_test = np.round(pred1).astype(int).flatten()
#preds_flat_test[:10]

# %%
pred2 = np.load('../input/5langcased/amine-bert-base-5lang-cased.npy')

# %%
pred3 =np.load('../input/pred-multi/pred_multi.npy')

# %%
len(pred3)

# %%
pred_5_lang = pred2[:,1:]

# %%
pred_5_lang[:5]

# %%
pred = 0.55*pred1 + 0.35*pred3# + 0.1*pred2[:,1]

# %%
pred2[:,1]

# %%
pred[:5]

# %%
#pred_flats = np.round(np.reshape(pred, 30000)).astype(int)

#preds_flat[:5]

preds_flat = np.round(pred).astype(int).flatten() 
#preds_flat = np.argmax(pred, axis =1)#.astype(int)#.flatten()

# %%
preds_flat[:10]

# %%
len(preds_flat)

# %%
test = pd.read_csv('../input/tunuzi-test/Test.csv')

# %%
sub = test.drop(['text'],axis =1)
sub['label'] = preds_flat
sub['label'] = sub['label'].replace(0, -1)

# %%
sub.head()

# %%
sub.label.value_counts()

# %%
zero = pd.read_csv('../input/predzero2/zero2.csv')

# %%
new = sub

# %%
new.loc[zero.label == 0, 'label'] = 0

# %%
new.label.value_counts()

# %%
new.to_csv('55_35_3multi.csv', index=False)
