# %%
import pandas as pd
import numba as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import missingno as mion

# %%
data=pd.read_csv("../input/game-of-thronesgot/game of thrones.csv")

# %%
data.head()

# %%
data.info()

# %%
mion.bar(data)

# %%
data['Original air date']=pd.to_datetime(data['Original air date'])

# %%
plt.figure(figsize=(12,7))
sns.countplot(data['Directed by'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,7))
sns.countplot(data['Written by'])
plt.xticks(rotation=90)
plt.show()

# %%
data['Novel(s) adapted'].value_counts()

# %%
plt.figure(figsize=(12,7))
plt.style.use("ggplot")
sns.lineplot(x='Original air date',y='U.S. viewers(millions)',data=data )

# %%
plt.figure(figsize=(12,7))
plt.style.use("ggplot")
sns.lineplot(x='Season',y='U.S. viewers(millions)',data=data )

# %%
top10=data.sort_values(by="Imdb rating",ascending=False).head(10)

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=data,x="Original air date",y="Imdb rating",marker='o')

# %%
top10.style.highlight_max("Imdb rating",color='red')

# %%
data.sort_values(by="Imdb rating",ascending=True).head(10)

# %%
data.sort_values(by="U.S. viewers(millions)",ascending=True).head(10)

# %%
data.sort_values(by="U.S. viewers(millions)",ascending=False).head(10)

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=data,x="Original air date",y="U.S. viewers(millions)",marker='o',hue="Written by")
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=data,x="Original air date",y="U.S. viewers(millions)",marker='o',hue="Directed by")
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=data,x="Original air date",y="Imdb rating",marker='o',hue="Written by")
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=data,x="Original air date",y="Imdb rating",marker='o',hue="Directed by")
plt.show()

# %%
from pandas_profiling import ProfileReport

# %%
y=ProfileReport(data)

# %%
y
