# %% [markdown]
# # Heatmap View using Clustergrammer2

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['StudentsPerformance.csv']

# %%
from clustergrammer2 import net
df = {}
# Out:
# clustergrammer2 backend version 0.2.10

# %%
df['ini'] = pd.read_csv('../input/StudentsPerformance.csv')
print(df['ini'].shape)
df['ini'].head()
# Out:
# (1000, 8)
#    gender race/ethnicity      ...      reading score writing score
# 0  female        group B      ...                 72            74
# 1  female        group C      ...                 90            88
# 2  female        group B      ...                 95            93
# 3    male        group A      ...                 57            44
# 4    male        group C      ...                 78            75
#
# [5 rows x 8 columns]

# %%
rows = df['ini'].index.tolist()

# %%
keep_cols = df['ini'].columns.tolist()[5:]
mat = df['ini'][keep_cols].get_values()
mat.shape
# Out:
# (1000, 3)

# %%
rows[0]
# Out:
# 0

# %%
new_rows = [('S' + str(x),
             'Gender: ' + df['ini']['gender'][x],
             'Education: ' + df['ini']['parental level of education'][x], 
             'Lunch: ' + df['ini']['lunch'][x], 
             'Test Prep: ' + df['ini']['test preparation course'][x] 
            ) for x in rows]

# %%
new_rows[:3]
# Out:
# [('S0',
#   'Gender: female',
#   "Education: bachelor's degree",
#   'Lunch: standard',
#   'Test Prep: none'),
#  ('S1',
#   'Gender: female',
#   'Education: some college',
#   'Lunch: standard',
#   'Test Prep: completed'),
#  ('S2',
#   'Gender: female',
#   "Education: master's degree",
#   'Lunch: standard',
#   'Test Prep: none')]

# %%
clean_cols = [x.replace(' score','') for x in keep_cols]
df['cat'] = pd.DataFrame(data=mat, columns=clean_cols, index=new_rows).transpose()
df['cat'].head()
# Out:
#          (S0, Gender: female, Education: bachelor's degree, Lunch: standard, Test Prep: none)                                          ...                                            (S999, Gender: female, Education: some college, Lunch: free/reduced, Test Prep: none)
# math                                                    72                                                                             ...                                                                                           77
# reading                                                 72                                                                             ...                                                                                           86
# writing                                                 74                                                                             ...                                                                                           86
#
# [3 rows x 1000 columns]

# %%
net.load_df(df['cat'])
net.normalize(axis='row', norm_type='zscore')
net.widget()
# Out:
# ExampleWidget(network='{"row_nodes": [{"name": "math", "ini": 3, "clust": 0, "rank": 1, "rankvar": 0, "group":…
