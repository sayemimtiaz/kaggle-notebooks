# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# The Iris flower data set or Fisher's Iris data set is a multivariate data set introduced by the British statistician and biologist Ronald Fisher in his 1936 paper The use of multiple measurements in taxonomic problems as an example of linear discriminant analysis. It is sometimes called Anderson's Iris data set because Edgar Anderson collected the data to quantify the morphologic variation of Iris flowers of three related species. Two of the three species were collected in the Gaspé Peninsula "all from the same pasture, and picked on the same day and measured at the same time by the same person with the same apparatus".

# %% [markdown]
# ![iris flowers](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Machine+Learning+R/iris-machinelearning.png)

# %%
import pandas as pd
iris_dataset = pd.read_csv('/kaggle/input/iris-flower-dataset/IRIS.csv')
iris = iris_dataset.copy()
iris.tail()

# %% [markdown]
# # Common details of dataset

# %%
def basic_details(data):
    print(f"shape of dataset:{data.shape}\n Number of rows:{iris.shape[0]} \n Number of Coulmns:{iris.shape[1]}")
    print(f"Coolumn names:{iris.columns}")
    print(f"Data types:{iris.dtypes}")
    
basic_details(iris)

# %% [markdown]
# ### Observations
# 1. 5 variables (4 independent , 1 dependent)
# 2. 'species' is dependent variable
# 3. it has only continuous variable ('float')

# %%
iris['species'].value_counts()

# %% [markdown]
# * 'species' is target/lable column
# ### Observation
# 1. Our objective is to make a classification model
# 2. it has 3 classes
# 3. balanced dataset all classes have equal number of datapoints

# %% [markdown]
# # Uni-variate analysis
# 1. look for only one variable at time
# 2. more helpful for 'Regression problems"

# %%
# Tabular method
def UniVariate_tabular(data):
    print("Central tendency:\n",iris.describe())
UniVariate_tabular(iris)

# %% [markdown]
# ### observations
# 1. mean of sepal_length is higher than other variable(see the imge)

# %%
#Graphical Method
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
def UniVariate_graphical(dataset):
    data_types = dataset.select_dtypes([np.int, np.float])
    for i, col in enumerate(data_types.columns):
        plt.figure(i)
        sns.boxplot(x = col,orient='v',width=0.4,data = data_types)
UniVariate_graphical(iris)

# %% [markdown]
# * Univariate analysis help us to detect outliers too but we could see that only sepal_width has few outliers

# %% [markdown]
# # Bivariate Analysis
# * two variables are studied together for empirical relationship
# * for this will draw scatterplot

# %%
sns.set_style('darkgrid')
sns.scatterplot(x="sepal_length", y="sepal_width", data=iris)

# %% [markdown]
# * we have 3 labels but by above plot we are unable to figureout class crossponding to datapoint.
# * define hue in scatterplot

# %%
sns.set_style('darkgrid')
sns.scatterplot(x="sepal_length", y="sepal_width",hue='species',data=iris)

# %% [markdown]
# * setosa is represented by blue points , we can easily distinguish 'setosa' from other two labels.
# ### Observation
# 1. sepal_width and sepal_length can be important feature to classify labels

# %% [markdown]
# * We can draw plair plot to see the relationship among other variables
# * pairplor:'pair wise scatter plot'

# %%
sns.set_style('darkgrid')
sns.pairplot(iris, hue='species',height=3,corner= True)

# %% [markdown]
# ### Observations
# 1. petal_length and petal_width is good to seperate setosa( if petal_length <=2 than setos)
# 2. 'virginica' and 'vercicolor' is also lineraly seperable with some error.

# %% [markdown]
# ### Apply Algorithm
# 1. Logistic Regression
# 2. KNN

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
def change_label(col):
    if col == 'Iris-virginica':
        return 1
    elif col == 'Iris-setosa':
        return 2
    elif col == 'Iris-versicolor':
        return 3

# %%
iris['species'] = iris['species'].apply(lambda x : change_label(x))

# %%
x = iris.iloc[:,:-1] # features
y = iris.iloc[:,-1:] # labels
#print(type(y))
#print(y.head())

# %% [markdown]
# * accuracy will vary if you wont set random_state =
# * **random_state**:Controls the shuffling applied to the data before applying the split

# %%
train_x,test_x,train_y,test_y = train_test_split(x,y,test_size=0.3,random_state = 42)

#print(train_x.head())
#print(train_y.head())
#print(test_x.head())
#print(test_y.head())

# %%
def model_used(train_x,train_y,test_x,test_y):
    model_knn = KNeighborsClassifier(n_neighbors=3)
    model_knn.fit(train_x,train_y.values.ravel())
    prediction_knn = model_knn.predict(test_x)
    print("prediction_knn",prediction_knn)
    print('The accuracy of the KNN is',accuracy_score(prediction_knn,test_y))
    print("*******Logistic Regression**********")
    model_lr = LogisticRegression()
    model_lr.fit(train_x,train_y.values.ravel())
    prediction_lr = model_lr.predict(test_x)
    print("prediction Logistic Regression",prediction_lr)
    print('The accuracy of the Logistic Regression is',accuracy_score(prediction_lr,test_y))
    
model_used(train_x,train_y,test_x,test_y)

# %% [markdown]
# * here we are geeting 100% accuracy
# ### will verify our one observation
# 1. petal_length and petal_width is good to seperate setosa( if petal_length <=2 than setos)
# 2. 'virginica' and 'vercicolor' is also lineraly seperable with some error.

# %% [markdown]
# ### scatter plot for "petal_length and petal_width"

# %%
sns.set_style('darkgrid')
sns.scatterplot(x="petal_length", y="petal_width",hue='species',data=iris_dataset)

# %% [markdown]
# * we will make ou model based on these two features

# %%
iris_dataset.species.value_counts()

# %%
x_p = iris.iloc[:,[2,3]]
print(x_p.head())
y_p = iris.iloc[:,-1:]
print(y_p.head())

# %%
xp_train,xp_test,yp_train,yp_test = train_test_split(x_p,y_p,test_size=0.3)

# %%
def model_used_only_petal(xp_train,yp_train,xp_test,yp_test):
    model_knn = KNeighborsClassifier(n_neighbors=3)
    model_knn.fit(xp_train,yp_train.values.ravel())
    prediction_knn = model_knn.predict(xp_test)
    print("prediction_knn",prediction_knn)
    print('The accuracy of the KNN is',accuracy_score(prediction_knn,yp_test))
    print("*******Logistic Regression**********")
    model_lr = LogisticRegression()
    model_lr.fit(xp_train,yp_train.values.ravel())
    prediction_lr = model_lr.predict(xp_test)
    print("prediction Logistic Regression",prediction_lr)
    print('The accuracy of the Logistic Regression is',accuracy_score(prediction_lr,yp_test))
    
model_used_only_petal(xp_train,yp_train,xp_test,yp_test)
