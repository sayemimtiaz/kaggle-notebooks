# %% [markdown]
# https://www.kaggle.com/alexisbcook/titanic-tutorial 튜토리얼 리뷰

# %%
# %matplotlib inline
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import re as re

train_data = pd.read_csv('/kaggle/input/train.csv', header = 0, dtype={'Age' : np.float64})
test = pd.read_csv('/kaggle/input/test.csv', header = 0, dtype={'Age': np.float64})
#import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
#  for filename in filenames:
#    print(os.path.join(dirname, filename))

full_data = [train_data, test]

print(train_data.info())

# %% [markdown]
# * train_data 데이타 헤드를 출력

# %%
train_data.head()

# %% [markdown]
# 변수 의미
#
# 변수명	해석(의미)	Type
# * PassengerID	승객을 구별하는 고유 ID number	Int
# * Survived	승객의 생존 여부를 나타내며 생존은 1, 사망은 0 입니다.	Factor
# * Pclass	선실의 등급으로서 1등급(1)부터 3등급(3)까지 3개 범주입니다.	Ord.Factor
# * Name	승객의 이름	Factor
# * Sex	승객의 성별	Factor
# * Age	승객의 나이	Numeric
# * SibSp	각 승객과 동반하는 형제 또는 배우자의 수를 설명하는 변수이며 0부터 8까지 존재합니다.	Integer
# * Parch	각 승객과 동반하는 부모님 또는 자녀의 수를 설명하는 변수이며 0부터 9까지 존재합니다.	Integer
# * Ticket	승객이 탑승한 티켓에 대한 문자열 변수	Factor
# * Fare	승객이 지금까지 여행하면서 지불한 금액에 대한 변수	Numeric
# * Cabin	각 승객의 선실을 구분하는 변수이며 범주와 결측치가 너무 많습니다.	Factor
# * Embarked	승선항, 출항지를 나타내며 C, Q, S 3개 범주이다.	Factor

# %% [markdown]
# Feature 검토
#
# 1. Pclass
# 티켓 클래스 값으로 1 = 1st, 2 = 2nd, 3 = 3rd 클래스다. categorical feature
# 클래스 별로 생존(Survived)를 체크하자

# %%
print(train_data[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).sum())
print(train_data[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean())

# %% [markdown]
# 생존자 중, 여성 비율은?

# %%
women = train_data.loc[train_data.Sex == 'female']["Survived"]
rate_women = sum(women) / len(women)

print("% of women who survived:", rate_women)

# %%
생존자 중, 남성 비율은?

# %%
men = train_data.loc[train.Sex == 'male']["Survived"]
rate_men = sum(men)/len(men)

print("% of men who survived:", rate_men)

# %% [raw]
# random forest model을 적용.
# feature => Pclass, Sex, SibSp, Parch
# prediction : Survived => my_submission.csv로 저장

# %%
from sklearn.ensemble import RandomForestClassifier
y = train_data["Survived"]

features = ["Pclass", "Sex", "SibSp", "Parch"]
X = pd.get_dummies(train_data[features])
X_test = pd.get_dummies(test[features])

model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=1)
model.fit(X, y)
predictions = model.predict(X_test)

output = pd.DataFrame({'PassengerId': test.PassengerId, 'Survived': predictions})
output.to_csv('my_submission.csv', index=False)
print("Your submission was successfully saved!")

# %% [markdown]
# ============================================================

# %% [markdown]
# * https://www.kaggle.com/omarelgabry/a-journey-through-titanic
# * https://kaggle-kr.tistory.com/17#2_6 캐글코리아 블로그 - 타이타닉 분석하기
# 참고를 해서, 연습

# %% [markdown]
# * 타이타닉 희생자 : 1,5000 여명
# * 탑승자 신상 정보로 생존 여부 예측 모델
# * 시각화 도구 : matplotlib, seaborn, plotly
# * 데이타 분석 도구 : pandas, numpy
# * 머신 러닝 도구 : sklearn

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# seaborn scheme을 matplotlib에 설정하고, seaborn font_scale 사용
plt.style.use('seaborn')
sns.set(font_scale=2.5) 

import missingno as msno



#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %% [markdown]
# 1. Dataset 확인 : 캐글 데이타에 null data가 있는지 체크하자
# 2. 모든 feature를 하나 하나 분석하고, 상관관계 확인하자, 시각화 툴로 insight를 얻어야함 => 탐색적 데이타 분석(exploratory data analysis)
# 3. feature engineering : 모델 만들기 전, 성능 높이기 위해 one-hot encoding, class 나누기, 구간 나누기, 텍스트 데이타 처리 등.
# 4. 모델 만들기 : sklearn 사용, ( tensorflow, pytorch 등도 있음 )
# 5. 모델 학습, 예측 : trainset으로 모델 학습 후, testset으로 prediction
# 6. 모델 평가 : 예측 결과와 비교

# %% [markdown]
# 1. Dataset 확인

# %%
df_train = pd.read_csv('../input/train.csv')
df_test = pd.read_csv('../input/test.csv')

# %%
df_train.head()

# %% [markdown]
# * survival : 생존여부, target label임. 1, 0으로 표현, integer
# * Pclass : 티켓 클래스, 1 = 1st, 2 = 2nd, 3 = 3rd ( Categorical feature ), integer
# * sex : 성별, male/female 구분 binary, string
# * Age : 나이, continuous, integer
# * SibSp : 함께 탑승한 형제와 배우자 수, quantitative, integer
# * parch : 함께 탑승한 부모, 아이 수, quantitative, integer
# * ticket : 티켓 번호, alphabet + integer, string
# * fare : 탑승료, continuous, float
# * cabin : 객실 번호, alphabet + integer, string
# * embared : 탑승 항구, C = Cherbourg, Q = Queenstown, S = Southampton, string

# %% [markdown]
# * 중요한 feature라면, Pclass, Age, SibSp, Parch, Fare이고,
# * 예측 target label은 Survived 임.

# %% [markdown]
# * pandas로 통계치를 리뷰하자

# %%
df_train.describe()

# %%
df_test.describe()

# %% [markdown]
# ==> count 수치가 다르고, null data가 있는 feature가 있는 것 같아서, 시작화해서 살펴볼 수 있다

# %% [markdown]
# 1.1 Null data check

# %%
for col in df_train.columns:
    msg = 'column: {:>10}\t Percent of NaN value: {:.2f}%'.format(col, 100 * (df_train[col].isnull().sum() / df_train[col].shape[0]))
    print(msg)

# %% [markdown]
# **==> Train data : Null data check**
# * Age : 약 20%
# * Cabin : 약 80%
# * Embarked : 약 0.22%

# %%
for col in df_test.columns:
    msg = 'column: {:>10}\t Percent of NaN value: {:.2f}%'.format(col, 100 * (df_test[col].isnull().sum() / df_test[col].shape[0]))
    print(msg)

# %% [markdown]
# **==> test data : Null data check**
# * Age : 약 20%
# * Cabin : 약 80%

# %% [markdown]
# * missingno 라이브러리를 사용하면 Null Data 존재 찾기 쉬움

# %%
msno.matrix(df=df_train.iloc[:, :], figsize=(8, 8), color=(0.8, 0.5, 0.2))

# %% [markdown]
# ==> Age, Cabin 에 Null Data 있음을 차트로 확인

# %%
msno.bar(df=df_train.iloc[:, :], figsize=(8, 8), color=(0.8, 0.5, 0.2))

# %% [markdown]
# => Age, Cabin Null Data 확인

# %%
msno.bar(df=df_test.iloc[:, :], figsize=(8, 8), color=(0.8, 0.5, 0.2))

# %% [markdown]
# => Age, Cabin Null Data 확인

# %% [markdown]
# 1.2 Target label 확인
# * Target label(Survived) distribution 타입 확인
# * binary claasification 문제는 1과 0 분표에 따라 모델 평가 방법이 달라짐

# %%
f, ax = plt.subplots(1, 2, figsize=(18,8))

df_train['Survived'].value_counts().plot.pie(explode=[0, 0.1], autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title('Pie plot - Survived')
ax[0].set_ylabel('')
sns.countplot('Survived', data=df_train, ax=ax[1])
ax[1].set_title('Count plot - Survived')

plt.show()

# %% [markdown]
# => 죽은 사람이 많은데(61.6%), 38.4% 생존
# * target label 분포가 균일(balanced) 하다고 판단
# * 예, 불균형 의미는 100중 1이 99, 0이 1개인 경우에는 모델이 모든 것을 1이라 해도 정화도가 99%임. 0을 찾는 문제면, 이 모델은 원하는 결과를 줄 수 없다.

# %% [markdown]
# **2. Exploratory data analysis**
# - 많은 데이타안에서 숨겨진 사실을 찾으려면 다양한 시각화 시도 필요
# - 시각화 라이브러리 : matplotlib, seaborn, plotply

# %% [markdown]
# **2.1  Pclass**

# %% [markdown]
# * Pclass : ordinal, 서수형 데이타, 카테고리, 순서가 있는 데이타 타입
# * Pclass에 따라 생존률 차이 리뷰
# * pandas DataFrame에서는 groupby 사용으로 파악 가능하고, pivot 메소드도 가능
# * 'Pclass', 'Survived' feature를 가져와서 Pclass로 groupby. 결과는 Pclass맏 0, 1이 count되는데 평균을 내면 Pclass 별 생존율임.

# %% [markdown]
# * 아래와 같이 count() 하면, 각 class에 몇명이 있는지 확인할 수 있음

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).count()

# %% [markdown]
# * sum() 으로 Pclass=1, 216 명 중 생존한(Survived=1) 사람 136명을 보여줌.

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).sum()

# %% [markdown]
# * pandas, crosstab을 사용하면 쉬운 차트 모양으로 표시 가능

# %%
pd.crosstab(df_train['Pclass'], df_train['Survived'], margins=True).style.background_gradient(cmap='summer_r')

# %% [markdown]
# * grouped 객체에 mean()을 하면, 각 클래스 별 생존율을 얻을 수 있음.
# * class 1이면,
# 80 / (80 + 136 ) = 0.63

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar()

# %% [markdown]
# => Pclass가 좋을 수록 생존율이 높다

# %% [markdown]
# * seaborn, countplot 을 사용하면 label에 따른 개수 확인 가능

# %%
y_position = 1.02
f, ax = plt.subplots(1, 2, figsize=(18,8))
df_train['Pclass'].value_counts().plot.bar(color=['#CD7F32', '#FFDF00', '#D3D3D3'], ax=ax[0])
ax[0].set_title('Number of Passengers By Pclass', y=y_position)
ax[0].set_ylabel('Count')
sns.countplot('Pclass', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Pclass: Survived vs Dead', y=y_position)
plt.show()

# %% [markdown]
# * => 클래스가 높을 수록 생존 확률이 높다
# * Pclass 1, 2, 3 => 63% 48% 25% 임.
# * 따라서, 생존에 Pclass가 큰 영향을 미친다고 판단 가능하고, 모델 세울 때 이 Pclass feature 사용하는 것 이 좋다고 판단함

# %% [markdown]
# **2.2 Sex**

# %% [markdown]
# * 성 별로 생존률 체크하기
# * pandas groupby, seabon countplot 사용

# %%
f, ax = plt.subplots(1, 2, figsize=(18,8))
df_train[['Sex', 'Survived']].groupby(['Sex'], as_index=True).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Sex: Survived vs Dead')
plt.show()

# %% [markdown]
# * => 확실히 여자 생존율이 높음.

# %%
df_train[['Sex', 'Survived']].groupby(['Sex'], as_index=False).mean().sort_values(by='Survived', ascending=False)

# %%
pd.crosstab(df_train['Sex'], df_train['Survived'], margins=True).style.background_gradient(cmap='summer_r')

# %% [markdown]
# * => Sex도 예측 모델에 중요하다고 판단

# %% [markdown]
# **2.3 Sex와 Pclass**

# %% [markdown]
# * Sex, Pclass feature로 생존율을 체크
# * seaborn factorplot 사용하면, 3개 차원 그래프 가능

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', data=df_train, size=6, aspect=1.5)

# %% [markdown]
# * => 모든 클래스에서 female 생존율이 높음

# %% [markdown]
# * hue => column 으로 변경하면,

# %%
sns.factorplot(x='Sex', y='Survived', col='Pclass', data=df_train, satureation=.5, size=9, aspect=1)

# %% [markdown]
# **2.4 Age**

# %% [markdown]
# * Age feature로 생존율 체크

# %%
print('제일 나이 많은 탑승객 : {:.1f} Years'.format(df_train['Age'].max()))
print('제일 어린 탑승객 : {:.1f} Years'.format(df_train['Age'].min()))
print('탑승객 평균 나이 : {:.1f} Years'.format(df_train['Age'].mean()))

# %%
* 생존에 따른 Age histogram은?

# %%
fig, ax = plt.subplots(1, 1, figsize=(9,5))
sns.kdeplot(df_train[df_train['Survived'] == 1]['Age'], ax=ax)
sns.kdeplot(df_train[df_train['Survived'] == 0]['Age'], ax=ax)
plt.legend(['Survived == 1', 'Survived == 0'])
plt.show()

# %% [markdown]
# * => 근소한 차이로, 생존자 중 나이가 어린 경우가 많다.

# %% [markdown]
# * Pclass, 나이 분포도

# %%
plt.figure(figsize=(8, 6))
df_train['Age'][df_train['Pclass'] == 1].plot(kind='kde')
df_train['Age'][df_train['Pclass'] == 2].plot(kind='kde')
df_train['Age'][df_train['Pclass'] == 3].plot(kind='kde')

plt.xlabel('Age')
plt.title('Age Distribution within classes')
plt.legend(['1st Class', '2nd Class', '3rd Class'])

# %% [markdown]
# * => Pclass(Class)가 높을 수록 나이 많음

# %% [markdown]
# * 나이 별, 생존율은 어떨까?
# * 나이 범위가 넓어지면 생존율이 어떨까?

# %%
cummulate_survival_ratio = []
for i in range(1, 80):
    cummulate_survival_ratio.append(df_train[df_train['Age'] < i]['Survived'].sum() / len(df_train[df_train['Age'] < i]['Survived']))
    
plt.figure(figsize=(7,7))
plt.plot(cummulate_survival_ratio)
plt.title('Survival rate change depending on range of Age', y=1.02)
plt.ylabel('Survival rate')
plt.xlabel('Range of Age(0~x)')
plt.show()

# %% [markdown]
# * => 나이가 어릴 수록 생존율이 높음
# * => 나이 또한 중요한 feature라고 확신함

# %% [markdown]
# **2.5 Pclass, Sex, Age**

# %% [markdown]
# * 세 가지 모든 조건에서 Survived 는 어떨지?
# * seaborn violinplot 이 좋음
# * x 축은 Pclass, Sex이고 y축은 distribution(Age)

# %%
f, ax = plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass", "Age", hue="Survived", data=df_train, scale='count', split=True, ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex", "Age", hue="Survived", data=df_train, scale='count', split=True, ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %% [markdown]
# * => 모든 클래스에서 나이가 어릴 수록 생존율이 높아 보임
# * => 오른쪽 그림에서는 여자 생존율 명확하게 보임
# * => 배가 가라앉을 때, 여자와 아이를 먼저 살린것 같다.

# %% [markdown]
# **2.6 Embarked**

# %% [markdown]
# * 탑승한 항구

# %%
f, ax = plt.subplots(1, 1, figsize=(7,7))
df_train[['Embarked', 'Survived']].groupby(['Embarked'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar(ax=ax)

# %% [markdown]
# * ==> 비슷하지만, C 에서 탑승한 생존율이 높음
# * ==> C = Cherbourg, Q = Queenstown, S = Southampton
# * ==> 모델 만들 때, 어떤 영향을 줄지 판단 불가

# %% [markdown]
# * 다른 feature랑 같이 비교

# %%
f, ax = plt.subplots(2, 2, figsize=(20,15))

sns.countplot('Embarked', data=df_train, ax=ax[0,0])
ax[0,0].set_title('(1) No. of Passengers Boarded')

sns.countplot('Embarked', hue='Sex', data=df_train, ax=ax[0,1])
ax[0,1].set_title('(2) Male-Female Split for Embarked')

sns.countplot('Embarked', hue='Survived', data=df_train, ax=ax[1,0])
ax[1,0].set_title('(3) Embarked vs Survivied')

sns.countplot('Embarked', hue='Pclass', data=df_train, ax=ax[1,1])
ax[1,1].set_title('(4) Embarked vs Pclass')

plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()

# %% [markdown]
# * ==> C = Cherbourg, Q = Queenstown, S = Southampton
# * f(1) : Southampton 에서 가장 많이 탑승함.
# * f(2) : Cherbourg와 Queenstown 에서 탑승한 남여 비율 비슷하지만, Southampton 에서는 남자가 많이 탐
# * f(3) : Southampton 탑승객 생존율이 낮음
# * f(4) : Pclass 로 split 했는데, Cherbourg 탑승객 생존율이 높은 것은 1등칸 탑승객이 많아서 그렇고, Southampton 탑승객 생존율이 낮은데 3등칸 탑승객이 많았음

# %% [markdown]
# **2.7 Family - SibSp(형제 자매) + Parch(부모, 자녀)**

# %% [markdown]
# * SibSp와 Parch를 합치면 Family임

# %%
df_train['FamilySize'] = df_train['SibSp'] + df_train['Parch'] + 1 # 자신 포함이므로 +1
df_test['FamilySize'] = df_test['SibSp'] + df_test['Parch'] + 1

print("Maximum size of Family: ", df_train['FamilySize'].max())
print("Minimum size of Family: ", df_train['FamilySize'].min())

# %% [markdown]
# * FamilySize vs Survived 관계는?

# %%
f, ax = plt.subplots(1, 3, figsize=(40,10))
sns.countplot('FamilySize', data=df_train, ax=ax[0])
ax[0].set_title('(1) No. Of Passengers Boarded', y=1.02)

sns.countplot('FamilySize', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('(2) Survived countplot depending on FamilySize', y=1.02)

df_train[['FamilySize', 'Survived']].groupby(['FamilySize'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar(ax=ax[2])
ax[2].set_title('(3) Survived rate depending on FamilySize', y=1.02)

plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()

# %% [markdown]
# * => F(1) : 가족 수가 1~11명. 대부분 1명이고, 2~4가 다수임
# * => F(2), F(3) : 가족 크기에 따른 생존 수임. 가족이 4명인 경우, 생존확율이 높음. 가족 수가 많아질 수록(5,6,7,8,11) 생존율이 떨어짐. 가족수가 작아도(1), 너무 커도(5,6,8,11) 생존율이 낮음. 3~4명 수가 생존 확율이 높은 걸 알 수 있음.

# %% [markdown]
# **2.8 Fare**

# %% [markdown]
# * Fare : 탑승 요금
# * continuous feature임.

# %%
fig, ax = plt.subplots(1, 1, figsize=(8,8))
g = sns.distplot(df_train['Fare'], color='b', label='Skewness : {:.2f}'.format(df_train['Fare'].skew()), ax=ax)
g =  g.legend(loc='best')

# %% [markdown]
# * => distribution이 비대칭(한쪽으로 치우침)->High Skewness, 이 모델에 이 피처를 입력하면 학습이 실패할 가능성 높음. 대게 outlier 수가 적을 때는 민감하게 반응하고, 실제 예측 시에 좋지 못한 결과
# * => Outlier 영향을 줄이기 위해 Fare에 log
# * => pandas DataFrame 특정 columns에 공통 함수 적용, map() or apply()

# %% [markdown]
# * Fare columns => log 값 적용
# * Python lamda 함수 사용, map에 인수로 넣으면 됨.

# %%
df_test.loc[df_test.Fare.isnull(), 'Fare'] = df_test['Fare'].mean()

df_train['Fare'] = df_train['Fare'].map(lambda i: np.log(i) if i > 0 else 0)
df_test['Fare'] = df_test['Fare'].map(lambda i: np.log(i) if i > 0 else 0)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8,8))
g = sns.distplot(df_train['Fare'], color='b', label='Skewness : {:.2f}'.format(df_train['Fare'].skew()), ax=ax)
g = g.legend(loc='best')

# %% [markdown]
# * => log 결과이고, 비대칭성은 사라짐
# * => log 결과 값으로 모델에 사용하면 좋은 성능 가질 수 있을 거라 기대
# * => feature engineering(모델 학습 목적과 모델 성능 높이기 위해 feature 조작이나 새로운 feature 추가) 단계에서 사용하는게 일반적임

# %% [markdown]
# **2.9 Cabin**

# %% [markdown]
# * cabin : 객실 번호, alphabet + integer, string
# * cabin 데이타 체크

# %%
df_train.head()

# %% [markdown]
# * => cabin 데이타는 80% 정도가 NaN 임
# * => 모델에 포함 안하는게 좋음 ( NaN 을 적절한 값을 채우고 시도해봐도 상관없음 )

# %% [markdown]
# **2.10 Ticket**

# %% [markdown]
# * 이 피처에는 NaN 이 없음
# * ticket : 티켓 번호, alphabet + integer, string
# * 이 데이타로는 직접 모델에 사용할 수 없음.... 음..

# %%
df_train['Ticket'].value_counts()

# %%
df_train['Ticket'].head()

# %% [markdown]
# **3. Feature Engineering**

# %% [markdown]
# * dataset에 존재하는 null data 정리
# * null data를 포함하는 feature statistics 참고 하거나, 다른 아이디어를 적용해서 채워야 함
# * Feature Engineering은 실제 모델 학습에 사용하려는 목적이다. 따라서, train과 test 모두 채우는게 좋음.

# %% [markdown]
# **3.1 Fill Null**

# %% [markdown]
# **3.1.1 Fill Null in Age using title**

# %% [markdown]
# * Age에 Null data 수는 177개.
# * title + statistics 로 시도
# * title : Miss, Mrr, Mrs
# * pandas, data => string 바꿔주는 str method 사용, 정규 표현식 extract method

# %%
df_train['Initial'] = df_train.Name.str.extract('([A-Za-z]+)\.') # Mr. 에서 .을 찾자
df_test['Initial'] = df_test.Name.str.extract('([A-Za-z]+)\.')

# %% [markdown]
# * pandas crosstab : 추출한 Initial 과 Sex 사이, count는?

# %%
pd.crosstab(df_train['Initial'], df_train['Sex']).T.style.background_gradient(cmap='summer_r')

# %% [markdown]
# * 이 결과를 가지고, 남자/여자가 사용하는 initial 구분
# * replace 메소드를 사용하면 특정 데이타 값을 원하는 값으로 치환 가능

# %%
df_train['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don','Dona'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr','Mr'],inplace=True)
df_test['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don','Dona'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr','Mr'],inplace=True)

# %%
df_train.groupby('Initial').mean()

# %% [markdown]
# * => 여성관 관계 있는 Miss, Mr, Mrs 생존율이 높다.

# %%
df_train.groupby('Initial')['Survived'].mean().plot.bar()

# %% [markdown]
# * Null 채우기 시작
# * statistics 활용으로
# * statistics는 train data 의미.
# * test data는 unseen 상태로 둬야 함
# * train에서 얻은 statistics 기반으로 test data에 null data를 채워야 함

# %%
df_train.groupby('Initial').mean()

# %% [markdown]
# * => Age 평균으로 Null value 채우는 아이디어
# * => pandas dataframe, boolean array 사용해서 indexing하면 편함

# %%
# isnull() 이고, Mr인 조건이면 row(탑승객) Age 값을 33으로 치환

df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Mr'),'Age'] = 33
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Mrs'),'Age'] = 36
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Master'),'Age'] = 5
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Miss'),'Age'] = 22
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Other'),'Age'] = 46

df_test.loc[(df_test.Age.isnull())&(df_test.Initial=='Mr'),'Age'] = 33
df_test.loc[(df_test.Age.isnull())&(df_test.Initial=='Mrs'),'Age'] = 36
df_test.loc[(df_test.Age.isnull())&(df_test.Initial=='Master'),'Age'] = 5
df_test.loc[(df_test.Age.isnull())&(df_test.Initial=='Miss'),'Age'] = 22
df_test.loc[(df_test.Age.isnull())&(df_test.Initial=='Other'),'Age'] = 46

# %% [markdown]
# **3.1.2 Fill Null in Embarked**

# %%
print('Embarked has ', sum(df_train['Embarked'].isnull()), ' Null values')

# %% [markdown]
# * => Null data가 2개있음
# * => 음, 어디서 탔으려나???
# * => 그냥 Southampton 에서 가장 많이 탔으니, 모두 S 로 채우자
# * => dataframe fillna method 사용, inplace=True 조건이면 df_train에 fillna를 실제로 적용함

# %%
df_train['Embarked'].fillna('S', inplace=True)

# %%
print('Embarked has ', sum(df_train['Embarked'].isnull()), ' Null values')

# %% [markdown]
# * => Null data가 없음

# %% [markdown]
# **3.2 Change Age ( continuous to categorical**

# %% [markdown]
# * 음, continuous feature
# * Age를 몇 개 그룹 category
# * 대게, 이렇게 처리하면 Information loss가 발생한다고 알려짐

# %% [markdown]
# * dataframe loc를 사용해서 직접 categorize or apply
# * 나이는 10살 간격으로 나눌 수 있음

# %%
df_train['Age_cat'] = 0
df_train.loc[df_train['Age'] < 10, 'Age_cat'] = 0
df_train.loc[(10 <= df_train['Age']) & (df_train['Age'] < 20), 'Age_cat'] = 1
df_train.loc[(20 <= df_train['Age']) & (df_train['Age'] < 30), 'Age_cat'] = 2
df_train.loc[(30 <= df_train['Age']) & (df_train['Age'] < 40), 'Age_cat'] = 3
df_train.loc[(40 <= df_train['Age']) & (df_train['Age'] < 50), 'Age_cat'] = 4
df_train.loc[(50 <= df_train['Age']) & (df_train['Age'] < 60), 'Age_cat'] = 5
df_train.loc[(60 <= df_train['Age']) & (df_train['Age'] < 70), 'Age_cat'] = 6
df_train.loc[70 <= df_train['Age'], 'Age_cat'] = 7

df_test['Age_cat'] = 0
df_test.loc[df_test['Age'] < 10, 'Age_cat'] = 0
df_test.loc[(10 <= df_test['Age']) & (df_test['Age'] < 20), 'Age_cat'] = 1
df_test.loc[(20 <= df_test['Age']) & (df_test['Age'] < 30), 'Age_cat'] = 2
df_test.loc[(30 <= df_test['Age']) & (df_test['Age'] < 40), 'Age_cat'] = 3
df_test.loc[(40 <= df_test['Age']) & (df_test['Age'] < 50), 'Age_cat'] = 4
df_test.loc[(50 <= df_test['Age']) & (df_test['Age'] < 60), 'Age_cat'] = 5
df_test.loc[(60 <= df_test['Age']) & (df_test['Age'] < 70), 'Age_cat'] = 6
df_test.loc[70 <= df_test['Age'], 'Age_cat'] = 7

# %% [markdown]
# * 다른 방법으로 apply 메소드로...

# %% [markdown]
# **3.3 Change Initial, Embarked and Sex ( String to numerical)**

# %% [markdown]
# * Initial은 Mr, Mrs, Miss, Master, Other 총 5개다. 이 값을 수치화 해야함
# * map method로 간단하게 가능
# * 사전 순서대로 정리해서 mapping

# %%
df_train['Initial'] = df_train['Initial'].map({'Master': 0, 'Miss': 1, 'Mr': 2, 'Mrs': 3, 'Other': 4})
df_test['Initial'] = df_test['Initial'].map({'Master': 0, 'Miss': 1, 'Mr': 2, 'Mrs': 3, 'Other': 4})

# %% [markdown]
# * Embarked : C, Q, S => map으로 수치화

# %%
df_train['Embarked'].unique()

# %%
df_train['Embarked'].value_counts()

# %%
df_train['Embarked'] = df_train['Embarked'].map({'C': 0, 'Q': 1, 'S': 2})
df_test['Embarked'] = df_test['Embarked'].map({'C': 0, 'Q': 1, 'S': 2})

# %%
df_train['Embarked'].isnull().any()

# %% [markdown]
# * Sex : Femail / male

# %%
df_train['Sex'] = df_train['Sex'].map({'female': 0, 'male': 1})
df_test['Sex'] = df_test['Sex'].map({'female': 0, 'male': 1})

# %% [markdown]
# **각 feature 간 상관관계**

# %% [markdown]
# * 두 변수 간 Pearson correlation 구하면 (-1,1) 사이 값 얻을 수 있음.
# * -1로 갈수록 음 상관관계, 1로 갈수록 양 상관관계 의미
# * 0은 상관 관계가 없다 것을 의미함.

# %% [markdown]
# * matrix 로 보면 편함
# * heatmap plot으로 가능하고, dataframe corr() 메소드와 seaborn으로 그릴 수 있음

# %%
heatmap_data = df_train[['Survived', 'Pclass', 'Sex', 'Fare', 'Embarked', 'FamilySize', 'Initial', 'Age_cat']] 

colormap = plt.cm.RdBu
plt.figure(figsize=(14,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(heatmap_data.astype(float).corr(), linewidths=0.1, vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True,annot_kws={"size":16})

del heatmap_data

# %% [markdown]
# * => Sex와 Pclass Survived 상관관계가 어느 정도 있었고, 위 차트에서도 알 수 있다
# * => Fare와 Embarked도 상관관계가 있다.
# * => 그런데, 강한 상관 관계를 가지는 feature들은 없는 거 같다.
# * => 의미는.... 모델 학습 시킬 때 불필요한(redundant, superfluous) feature가 없다는 것이다.
# * => 1 혹은 -1 상관 관계를 가진 feature A, B 의미는 우리가 얻을 수 있는 정보는 단 하나다.

# %% [markdown]
# **3.4 One-hot encoding on Initial and Embarked**

# %% [markdown]
# * 모델 성능 높이기 위해, one-hot encoding 사용
# * Master == 0, Miss == 1, Mr == 2, Mrs == 3, Other == 4로 맵핑
# * One-hot encoding은 위 카테고리를 아래와 같이 (0,1)로 이루어진 5차원 벡터로 나타내는 것을 의미함

# %% [markdown]
# * pandas get_dummies 사용해서 가능
# * 총 5개 카테고리니, one-hot encoding 결과로 새로운 5개 column 만들어짐
# * Initial을 prefix로

# %%
df_train = pd.get_dummies(df_train, columns=['Initial'], prefix='Initial')
df_test = pd.get_dummies(df_test, columns=['Initial'], prefix='Initial')

# %%
df_train.head()

# %% [markdown]
# * => Initial_1... 등 one-hot encoded columns 만들어짐

# %% [markdown]
# * Embarked에도 적용

# %%
df_train = pd.get_dummies(df_train, columns=['Embarked'], prefix='Embarked')
df_test = pd.get_dummies(df_test, columns=['Embarked'], prefix='Embarked')

# %% [markdown]
# * => 다른 방법으로 sklearn Labelencoder + OneHotencoder 있음
# * => 음, category가 100개 넘는 경우에는 column이 100개 넘게 만들어지는데.... 학습 할 때 번거롭다. 다른 방법도 있는데... 찾아봐야함...

# %% [markdown]
# **3.5 Drop columns**

# %% [markdown]
# * 불필요한 컬럼은 삭제하자

# %%
df_train.drop(['PassengerId', 'Name', 'SibSp', 'Parch', 'Ticket', 'Cabin'], axis=1, inplace=True)
df_test.drop(['PassengerId', 'Name',  'SibSp', 'Parch', 'Ticket', 'Cabin'], axis=1, inplace=True)

# %%
df_train.head()

# %%
df_test.head()

# %% [markdown]
# **Building machine learning model and prediction using the trained model**

# %% [markdown]
# * sklearn을 사용해서 모델 만들자

# %%
#importing all the required ML packages
from sklearn.ensemble import RandomForestClassifier # 유명한 randomforestclassfier 입니다. 
from sklearn import metrics # 모델의 평가를 위해서 씁니다
from sklearn.model_selection import train_test_split # traning set을 쉽게 나눠주는 함수입니다.

# %%
X_train = df_train.drop('Survived', axis=1).values
target_label = df_train['Survived'].values
X_test = df_test.values

# %%
X_tr, X_vld, y_tr, y_vld = train_test_split(X_train, target_label, test_size=0.3, random_state=2018)

# %%
model = RandomForestClassifier()
model.fit(X_tr, y_tr)
prediction = model.predict(X_vld)

# %%
print('총 {}명 중 {:.2f}% 정확도로 생존을 맞춤'.format(y_vld.shape[0], 100 * metrics.accuracy_score(prediction, y_vld)))
