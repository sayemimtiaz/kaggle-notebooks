# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
pip install pandas

# %%
import pandas as pd

# %%
mydataset={
    'cars':['bmw',"volvo","ford"],
    'passings':[3,7,2]
}
myvar=pandas.DataFrame(mydataset)
myvar

# %%
mydataset={
    'shape':['Rectangular','Round'],
    'weight':[1000,100],
    'Target':['Bat','Ball']
}
myvar=pandas.DataFrame(mydataset)
myvar

# %%
mydataset={
    'shape':['Rectangular','Round','Rectangular','Round'],
    'weight':[1000,100,1010,1020],
    'Target':['Bat','Ball','Bat','Ball']
}
myvar=pd.DataFrame(mydataset)
myvar

# %%
a=[11,17,12]
myvar=pd.Series(a)
myvar

# %%
a=[1,7,2]
myvar=pd.Series(a)
myvar[2]

# %%
a=[11,17,12]
myvar=pd.Series(a,index=["small","middle]","large"])
myvar

# %%
a=[11,17,12]
myvar=pd.Series(a,index=["small","middle]","large"])
myvar["large"]

# %%
calories={"day1":32,"day2":52,"day3":82}
var=pd.Series(calories)
var

# %%
data={
    "calories":[400,350,340],
    "duration":[40,35,30]
}
var=pd.DataFrame(data)
var

# %%
data={
    "calories":[400,350,340],
    "duration":[40,35,30]
}
df=pd.DataFrame(data)
df

# %%
df.loc[1]

# %%
df.loc[[0,1]]

# %%
df.loc[[1]]

# %%
data={
    "calories":[400,350,340],
    "duration":[40,35,30]
}
df=pd.DataFrame(data,index=["day1","day2","day3"])
df

# %%
data={
    "calories":[400,350,340],
    "duration":[40,35,30]
}
df=pd.DataFrame(data,index=["day1","day2","day3"])
df.loc["day1"]

# %%
data={
    "calories":[400,350,340],
    "duration":[40,35,30]
}
df=pd.DataFrame(data,index=["day1","day2","day3"])
df.loc[["day1"]]

# %%
import pandas as pd
df=pd.read_csv("../input/epitope-prediction/input_bcell.csv")
#print(df.to_string())
df

# %%
import pandas as pd
df=pd.read_csv("../input/epitope-prediction/input_bcell.csv")
#print(df.to_string())
df.head(17)

# %%
import pandas as pd
df=pd.read_csv("../input/epitope-prediction/input_bcell.csv")
#print(df.to_string())
df.tail(14)

# %%
df.info()

# %%
import pandas as pd
df=pd.read_csv("../input/null-removed-dataset/null_removed.csv")
#print(df.to_string())
df

# %%
df.info()

# %%
import pandas as pd
df=pd.read_csv("../input/heights-and-weights/data.csv")
#print(df.to_string())
df

# %%
import pandas as pd
df=pd.read_csv("../input/heights-and-weights/data.csv")
#print(df.to_string())
#df.head(7)
df.tail(7)

# %%
df.info()
