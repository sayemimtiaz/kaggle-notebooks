# %%
import numpy as np 
import pandas as pd 

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# # 1. Data Import & Loading

# %%
df = pd.read_csv('/kaggle/input/credit-risk-classification-dataset/payment_data.csv')
df.head()

# %%
df = pd.read_csv('/kaggle/input/credit-risk-classification-dataset/customer_data.csv')
df.head()
