# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# %%
test=pd.read_csv('../input/aug-2021/testdata/test.csv')
test.head()

# %%
dataset_user=pd.read_csv('../input/aug-2021/traindata/user_features_data/user_features_data.csv',sep='\t')
dataset_user.head()

# %%
dataset_video=pd.read_csv('../input/aug-2021/traindata/video_features_data/video_features_data.csv',sep='\t')
dataset_video.head()

# %%
dataset_behavior=pd.read_csv('../input/history-behavior-data/behavior.csv',sep='\t')
dataset_behavior.head()

# %%
dataset_user.shape,dataset_video.shape,dataset_behavior.shape

# %%
dataset_behavior['watch_start_time'].value_counts()

# %%
tmp=pd.merge(left=dataset_behavior, right=dataset_video, how='left', left_on='video_id', right_on='video_id')
dataset=pd.merge(left=tmp, right=dataset_user, how='left', left_on='user_id', right_on='user_id')
