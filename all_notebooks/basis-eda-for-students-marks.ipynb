# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
df= pd.read_csv('/kaggle/input/students-performance-in-exams/StudentsPerformance.csv')
print('df Read Successfully')

# %%
df.head()

# %%
df.shape

# %%
df.columns

# %%
df.info()

# %%
df.describe()

# %%
df[df['math score']==0]

# %%
df.isnull().sum()

# %%
#Freature Engineering
#Firstly, we create a new column which has mean score of all three scores
import numpy as np

df['mean score']=np.NaN
df['mean score']= ((df['math score']+ df['reading score']+ df['writing score'])/3).round()

# %%
df.head()

# %%
#EDA
categorical_columns=['gender', 'race/ethnicity', 'parental level of education', 'lunch','test preparation course']
categorical_columns

# %%
df.columns

# %%
categorical_columnss= df.select_dtypes(exclude=['int64', 'float64']).columns
categorical_columnss

# %%
for i in categorical_columnss:
    plt.figure(figsize=(5,5))
    sns.countplot(x=i, data=df, palette='hot')
    plt.title(f"Graph of {i}")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot('gender', data=df)
plt.title(f'Plot of {i}')

# %%
numerical_columns=df.select_dtypes(exclude=['object']).columns

# %%
df.info()

# %%
for i in numerical_columns:
    plt.figure(figsize=(5,5))
    sns.distplot(df[i])
    plt.title(f'This is the graph of {i}')

# %%
#Hypothesis that women get higher grade than men

df1=df.groupby('gender')['math score', 'reading score', 'writing score', 'mean score'].mean().reset_index()

# %%
for i in numerical_columns:
    plt.figure(figsize=(5,5))
    sns.barplot(df1['gender'],df1[i], palette='winter')
    plt.title(f'Graph of {i} Showing Comparision between Male and Female')
    
#Hence Male students are better at Math then female. But overall, females are scoring more than males.

# %%
#Correlation between Reading and Math Score
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['math score'], y=df['reading score'], hue=df['gender'], palette='hot')

# %%
#Hypothesis: The higher the parents level the higher the students grade

df['parental level of education'].unique()

# %%
df2=df.groupby('parental level of education')['math score', 'reading score', 'writing score','mean score'].mean()
df2=df2.reset_index()

# %%
df2

# %%
for i in numerical_columns:
    plt.figure(figsize=(5,5))
    ax= sns.barplot(df2['parental level of education'], df2[i])
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
    plt.title(f'Graph of {i}', fontsize=20)
    
    
#Thus as we can see if the parents have studied till masters degree, there is a chance that student has better grading overall and individually in each subject too.

# %%
#Hypothesis: The students who have completed their preperation course do better

df3=df.groupby('test preparation course')['math score', 'reading score', 'writing score','mean score'].mean().reset_index()

# %%
df.columns

# %%
for i in numerical_columns:
    plt.figure(figsize=(5,5))
    sns.barplot(df3['test preparation course'], df3[i], palette='dark')
    plt.title(f'Graph of {i}', fontsize=15)
    
    
#Those who have completed have better score than those not

# %%
df['lunch'].unique()

# %%
#Hypothesis: Those whho get free lunch comes more often to school and thus have better grades

df4=df.groupby('lunch')[numerical_columns].mean().reset_index()

# %%
df4

# %%
for i in numerical_columns:
    plt.figure(figsize=(5,5))
    sns.barplot(df4['lunch'], df4[i], palette='summer')
    plt.title(f'Graph of {i}', fontsize=20)
    
    
#Strikingy, we seea reverse conclusion. The students who pay full for lunch have much better score than those whi get free food.

# %%
#Correlation between reading and writing tests
plt.figure(figsize=(10,10))
sns.scatterplot(df['reading score'], df['writing score'], hue=df['gender'])
plt.title('Graph of Comparision of Reading VS Writing Skills', fontsize=20)

#Hence, students having higher Reading Skills Grade have higher Writing Skills grades also

# %%
#Effect of Ethinicity on grades
df5=df.groupby('race/ethnicity')[numerical_columns].mean().reset_index()

# %%
df.columns

# %%
df5

# %%
for i in numerical_columns:
    plt.figure(figsize=(5,5))
    sns.barplot(df5['race/ethnicity'], df5[i])
    
#So, Ethinicity does have a higher impact on the scores as group E has higher average than Group A in all aspects.

# %%
#Drawing the correlation matrix
corr_mat= df.corr()
corr_mat

# %%
plt.figure(figsize=(10,10))
plt.title('Correlation Graph')
sns.heatmap(corr_mat, annot=True, linewidths=1)

# %%
X=df.drop('mean score', axis=1)
y=df['mean score']
y

# %%
categorical_columns

# %%
from sklearn.preprocessing import LabelEncoder

le= LabelEncoder()

X[categorical_columns]=X[categorical_columns].apply(lambda x: le.fit_transform(x))

# %%
X[categorical_columns]

# %%
#Preparig the data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test= train_test_split(X,y, test_size=0.2)

# %%
#Fitting the model
from sklearn.ensemble import RandomForestRegressor

rf=RandomForestRegressor()

# %%
rf.fit(X_train, y_train)

# %%
#Making prediction
y_preds= rf.predict(X_test)

# %%
y_preds

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_preds)

# %%
rf.score(X_test, y_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

mean_squared_error(y_test, y_preds)
mean_absolute_error(y_test, y_preds)

# %%
print('Hence the predicted values are ', y_preds)

# %%
y_test
