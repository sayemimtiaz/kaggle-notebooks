# %%
## DO NOT CHANGE CODE IN THIS CELL
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
## DO NOT CHANGE CODE IN THIS CELL
from check import c # checks answers to given questions
#Created By 
#Suraj Perdoor
#Sumanth VS
#With Guidance from Dr.Kavitha Sooda
#B.M.S. College of Engineering

# %% [markdown]
# # Dataset Page
# https://www.kaggle.com/benroshan/factors-affecting-campus-placement

# %%
# Read csv file in df using 
path = '/kaggle/input/factors-affecting-campus-placement/Placement_Data_Full_Class.csv'
df = pd.read_csv(path)

# First Five entries from the dataframe
df.head()

# %% [markdown]
# # Column Name
# - sl_no ==> Serial Number
#  <br />  <br />
# - gender ==> Gender- Male='M',Female='F'
#  <br />  <br />
# - ssc_p ==> Secondary Education percentage- 10th Grade
#  <br />  <br />
# - ssc_b ==> Board of Education- Central/ Others
#  <br />  <br />
# - hsc_p ==> Higher Secondary Education percentage- 12th Grade
#  <br />  <br />
# - hsc_b ==> Board of Education- Central/ Others
#  <br />  <br />
# - hsc_s ==> Specialization in Higher Secondary Education
#  <br />  <br />
# - degree_p ==> Degree Percentage
#  <br />  <br />
# - degree_t ==> Under Graduation(Degree type)- Field of degree education
#  <br />  <br />
# - workex ==> Work Experience
#  <br />  <br />
# - etest_p ==> Employability test percentage ( conducted by college)
#  <br />  <br />
# - specialisation ==> Post Graduation(MBA)- Specialization
#  <br />  <br />
# - mba_p ==> MBA percentage
#  <br />  <br />
# - status ==> Status of placement- Placed/Not placed
#  <br />  <br />
# - salary ==> Salary offered by corporate to candidates

# %% [markdown]
# # Question 0
# Select the first 5 rows

# %%
#YOUR ANSWER HERE
five_rows = 

five_rows

# %%
#Check your answer
c.check0(five_rows, df)

# %%
#HINT Uncomment to see
#c.hint0()

# %%
#SOLUTION Uncomment to see
#c.solution0()

# %% [markdown]
# # .loc Funtion
# https://www.kaggle.com/residentmario/indexing-selecting-assigning

# %% [markdown]
# # Question 1
# Select the rows of students with sl_no(Serial Number) more than 100(inclusive)

# %%
# YOUR ANSWER HERE
students = 
students.head()

# %%
# Check your answer
c.check1(students, df)

# %%
## HINT Uncomment to see
#c.hint1()

# %%
## SOLUTION Uncomment to see
#c.solution1()

# %% [markdown]
# # Question 2
# Select the 10th and 12th Percentages columns

# %%
# YOUR ANSWER HERE
percentages = 
percentages.head()

# %%
# Check your answer
c.check2(percentages, df)

# %%
## HINT Uncomment to see
#c.hint2()

# %%
## SOLUTION Uncomment to see
#c.solution2()

# %% [markdown]
# # Question 3
# Select all the students who speacialized in Science during their Higher Secondary Education

# %%
# YOUR ANSWER HERE
scientists = 
scientists.head()

# %%
# Check your answer
c.check3(scientists, df)

# %%
## HINT Uncomment to see
#c.hint3()

# %%
## SOLUTION Uncomment to see
#c.solution3()

# %% [markdown]
# # .groupby
# https://www.kaggle.com/residentmario/grouping-and-sorting

# %% [markdown]
# # Question 4
# Find out highest salary of Male and Female students

# %%
# YOUR ANSWER HERE
salaries = 
salaries.head()

# %%
# Check your answer
c.check4(salaries, df)

# %%
## HINT Uncomment to see
#c.hint4()

# %%
## SOLUTION Uncomment to see 
#c.solution4()

# %% [markdown]
# # Question 5
# For every Specialization select scores
# - of 12th grade toppers
# - in decending order

# %%
scores = 
scores.head()

# %%
# Check your answer
c.check5(scores, df)

# %%
## HINT Uncomment to see
#c.hint5()

# %%
## SOLUTION Uncomment to see 
#c.solution5()

# %% [markdown]
# # Thank you for listening

# %% [markdown]
# # Practise question
# Try it yourself

# %% [markdown]
# # Question 6
#
# Select the student who is the 10th Grade Topper

# %%
# YOUR ANSWER HERE

# Set this variable to the topper's marks
topper_marks = 

# Set topper to the Student info of the topper
topper = 
topper.head()

# %%
# Check your answer
c.check6(topper, df)

# %%
## HINT Uncomment to see
#c.hint6()

# %%
## SOLUTION Uncomment to see 
#c.solution6()

# %% [markdown]
# # Question 7
# Select the students who got Placed with Degree percentage less than 65%

# %%
# YOUR ANSWER HERE
placed_students = 
placed_students.head()

# %%
# Check your answer
c.check7(placed_students, df)

# %%
## HINT Uncomment to see
#c.hint7()

# %%
## SOLUTION Uncomment to see 
#c.solution7()

# %% [markdown]
# # Question 8
# Select the min and max of Employabilty test for each Field of Undergraduate Degree

# %%
emp_test = 
emp_test

# %%
# Check your answer
c.check8(emp_test, df)

# %%
## HINT Uncomment to see
#c.hint8()

# %%
## SOLUTION Uncomment to see 
#c.solution8()

# %% [markdown]
# # Question 9
# Highest Salary for Field of degree education and Specialization in Higher Secondary Education and Gender

# %%
highest_salary = 
highest_salary

# %%
# Check your answer
c.check9(highest_salary, df)

# %%
## HINT Uncomment to see
#c.hint9()

# %%
## SOLUTION Uncomment to see 
#c.solution9()

# %% [markdown]
# # Question 10
# 1. Mean of the salaries
# 2. Select all the students whose Salaries are above the mean
#      - Return the salaries colomn to reflect difference of student salary from the mean

# %%
#1.  Salary mean
salary_mean = 
salary_mean

# %%
#2. Students with Salary more than mean
std_sal_more_mean = 
std_sal_more_mean.head()

# %%
#Change salary column to refelct, difference from mean
def diff(row):
    pass

std_sal_more_mean = 
std_sal_more_mean.head()

# %%
# Check your answer
c.check10(std_sal_more_mean, df)

# %%
## HINT Uncomment to see
#c.hint10()

# %%
## SOLUTION Uncomment to see 
#c.solution10()
