# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("../input/nyc-property-sales/nyc-rolling-sales.csv")
df.head()

# %%
df.columns

# %%
df_Unnamed=df['Unnamed: 0']

# %%
df1=df.copy()
df1=df1.drop("Unnamed: 0",axis=1)
df1.columns

# %%
df1.info()

# %%
df1.isnull().sum()

# %%
df1['BOROUGH'].value_counts()

# %%
df1['BOROUGH']=df1['BOROUGH'].replace({1:'Manhattan',2:'Bronx',3:'Brooklyn',4:'Queens',5:'Staten Island'})

# %%
df1['BOROUGH'].value_counts()

# %%
df1['BOROUGH']=df1['BOROUGH'].astype('object')

# %%
df1['NEIGHBORHOOD'].value_counts().head(20)

# %%
df1.shape

# %%
df1['BUILDING CLASS CATEGORY'].value_counts()

# %%
df1['TAX CLASS AT PRESENT'].value_counts()

# %%
df1['TAX CLASS AT PRESENT']=df1['TAX CLASS AT PRESENT'].replace({'1':'Class_1','1A':'Class_1','1B':'Class_1','1C':'Class_1','2':'Class_2','2A':'Class_2','2B':'Class_2','2C':'Class_2','3':'Class_3','4':'Class_4'})

# %%
df1['TAX CLASS AT PRESENT'].value_counts()

# %%
l=[]
for i in range(len(df1)):
    if (df1['TAX CLASS AT PRESENT'][i]!='Class_1') and (df1['TAX CLASS AT PRESENT'][i]!='Class_2') and (df1['TAX CLASS AT PRESENT'][i]!='Class_3') and (df1['TAX CLASS AT PRESENT'][i]!='Class_4'):
        l.append(df1['TAX CLASS AT PRESENT'][i])
    else:
        pass

# %%
len(l)

# %%
l

# %%
df1['TAX CLASS AT PRESENT']=df1['TAX CLASS AT PRESENT'].replace({" ":np.nan})

# %%
df1['TAX CLASS AT PRESENT'].isnull().sum()

# %%
df1['TAX CLASS AT PRESENT']=df1['TAX CLASS AT PRESENT'].fillna(method='bfill')

# %%
df1['TAX CLASS AT PRESENT'].value_counts()

# %%
df1['BLOCK'].plot(kind='kde')

# %%
df1['LOT'].plot(kind='kde')

# %%
df1['EASE-MENT'].value_counts()

# %%
df1['EASE-MENT'].head()

# %%
df1=df1.drop('EASE-MENT',axis=1)

# %%
df1['BUILDING CLASS AT PRESENT'].value_counts()

# %%
df1.columns

# %%
df1['ADDRESS'].value_counts()

# %%
df1=df1.drop('ADDRESS',axis=1)

# %%
df1['APARTMENT NUMBER'].value_counts()

# %%
df1=df1.drop('APARTMENT NUMBER',axis=1)

# %%
df1['ZIP CODE'].value_counts()

# %%
df1['RESIDENTIAL UNITS'].plot(kind='kde')

# %%
df1['COMMERCIAL UNITS'].plot(kind='kde')

# %%
df1['TOTAL UNITS'].plot(kind='kde')

# %%
df1['LAND SQUARE FEET'].value_counts()

# %%
df1=df1.drop('LAND SQUARE FEET',axis=1)

# %%
df1['GROSS SQUARE FEET'].value_counts()

# %%
df1=df1.drop("GROSS SQUARE FEET",axis=1)

# %%
df1['YEAR BUILT'].value_counts()

# %%
df1.info()

# %%
df1['YEAR BUILT']=df1['YEAR BUILT'].astype('object')

# %%
df1['YEAR BUILT']=df1['YEAR BUILT'].replace({0:np.nan})

# %%
df1['YEAR BUILT']=df1['YEAR BUILT'].fillna(method='bfill')

# %%
df1['YEAR BUILT']=df1['YEAR BUILT'].astype('int64')

# %%
df1['TAX CLASS AT TIME OF SALE'].value_counts()

# %%
df1['TAX CLASS AT TIME OF SALE']=df1['TAX CLASS AT TIME OF SALE'].replace({1:'Class_1',2:'Class_2',3:'Class_3',4:'Class_4'})

# %%
df1['TAX CLASS AT TIME OF SALE'].value_counts()

# %%
df1['BUILDING CLASS AT TIME OF SALE'].value_counts()

# %%
df1['SALE PRICE'].value_counts()

# %%
for i in range(len(df1)):
    if df1['SALE PRICE'][i]==' -  ':
        df1['SALE PRICE'][i]=np.nan
    else:
        pass

# %%
df1['SALE PRICE'].value_counts()

# %%
df1['SALE PRICE']=df1['SALE PRICE'].astype('float64')

# %%
df1['SALE PRICE'].plot(kind='kde')

# %%
df1['SALE PRICE'].isnull().sum()

# %%
df1['SALE PRICE'].mean()

# %%
df1['SALE PRICE']=df1['SALE PRICE'].fillna(1276456.497)

# %%
df1['SALE PRICE'].isnull().sum()

# %%
df1['SALE DATE'].value_counts()

# %%
df1['SALE DATE']=df1['SALE DATE'].astype('object')

# %%
for i in range(len(df1)):
    df1['SALE DATE'][i]=str(df1['SALE DATE'][i])
    df1['SALE DATE'][i]=df1['SALE DATE'][i][0:10]

# %%
df1['SALE DATE']=df1['SALE DATE'].astype('datetime64')

# %%
df1['SALE DATE'].head()

# %%
df1['SALE_YEAR']=pd.DatetimeIndex(df1['SALE DATE']).year

# %%
df1['SALE_MONTH']=pd.DatetimeIndex(df1['SALE DATE']).month

# %%
df1.columns

# %%
df1['SALE_YEAR'].value_counts()

# %%
df1['SALE_MONTH'].value_counts()

# %%
df1=df1.drop("SALE DATE",axis=1)

# %%
df1['SALE_YEAR']=df1['SALE_YEAR'].astype('object')

# %%
df1.info()

# %%
df_cat=df1.select_dtypes(include='object')
df_num=df1.select_dtypes(exclude='object')

# %%
plt.figure(figsize=[10,10])
sns.heatmap(df_num.corr(),annot=True)
plt.show()

# %%
for i in df_num.columns:
    sns.boxplot(df_num[i])
    plt.show()

# %%
df_num.columns

# %%
df_num=df_num.drop(['BLOCK', 'LOT', 'ZIP CODE','YEAR BUILT','SALE_MONTH'],axis=1)

# %%
df_num['RESIDENTIAL UNITS']=df_num['RESIDENTIAL UNITS'].astype('float64')
df_num['COMMERCIAL UNITS']=df_num['COMMERCIAL UNITS'].astype('float64')
df_num['TOTAL UNITS']=df_num['TOTAL UNITS'].astype('float64')

# %%
df_num.head()

# %%
df_num['SALE PRICE'].skew()

# %%
from sklearn.preprocessing import PowerTransformer

# %%
pt=PowerTransformer()
df_num_pt=pt.fit_transform(df_num)
df_num_pt=pd.DataFrame(df_num_pt)
df_num_pt.columns=df_num.columns
df_num_pt.head()

# %%
df_num_pt['SALE PRICE'].skew()

# %%
df_cat.columns

# %%
df_cat=df_cat.drop(['NEIGHBORHOOD', 'BUILDING CLASS CATEGORY','BUILDING CLASS AT PRESENT','BUILDING CLASS AT TIME OF SALE'],axis=1)

# %%
df_cat.columns

# %%
df_cat_dum=pd.get_dummies(df_cat,columns=['BOROUGH', 'TAX CLASS AT PRESENT', 'TAX CLASS AT TIME OF SALE',
       'SALE_YEAR'],drop_first=True)

# %%
df_cat_dum.head()

# %%
final=pd.concat([df_num_pt,df_cat_dum],axis=1)

# %%
x=final.drop('SALE PRICE',axis=1)
y=final['SALE PRICE']

# %%
from sklearn.model_selection import train_test_split

# %%
import statsmodels.api as sm

# %%
xc=sm.add_constant(x)
ols=sm.OLS(y,xc)
ols_mod=ols.fit()
ols_mod.summary()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=48)

# %%
lr=LinearRegression()
lr.fit(xtrain,ytrain)
ypred_test=lr.predict(xtest)
r2_test=r2_score(ytest,ypred_test)
r2_test

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
vif['feature']=x.columns
vif.sort_values('VIF',ascending=False)

# %%
x1=x.drop('TAX CLASS AT PRESENT_Class_3',axis=1)
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(x1.values,i) for i in range(x1.shape[1])]
vif['feature']=x1.columns
vif.sort_values('VIF',ascending=False)

# %%
x2=x1.drop('TAX CLASS AT TIME OF SALE_Class_2',axis=1)
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(x2.values,i) for i in range(x2.shape[1])]
vif['feature']=x2.columns
vif.sort_values('VIF',ascending=False)

# %%
x3=x2.drop('TAX CLASS AT PRESENT_Class_4',axis=1)
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(x3.values,i) for i in range(x3.shape[1])]
vif['feature']=x3.columns
vif.sort_values('VIF',ascending=False)

# %%
x4=x3.drop('RESIDENTIAL UNITS',axis=1)
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(x4.values,i) for i in range(x4.shape[1])]
vif['feature']=x4.columns
vif.sort_values('VIF',ascending=False)

# %%
xc=sm.add_constant(x4)
ols=sm.OLS(y,xc)
ols_mod=ols.fit()
ols_mod.summary()

# %%
#R2 is very very less, hence dataset is not suitable for the regression.
