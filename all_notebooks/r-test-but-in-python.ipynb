# %%
import numpy as np 
import pandas as pd 

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))


#Reading in the data
happinessData = pd.read_csv("../input/world-happiness/2019.csv")

#Dropping the column of country names (closest to cleaning)
happinessData.drop(columns=["Country or region"])

#Our initial exploration of the data!
happinessData.head()

# %%
#Summarizing the data in the most basic way possible
#while simultaneously continuing to explore
happinessData.describe()

# %%
# I don't really have anything to clean... If I were to, say,
# make a new column that does nothing, I would do this:
#empty_list = [This would have 156 values]
#happinessData.insert(2, "UselessColumn", empty_list, True)

# Or I could remove empty tiles in said column with this:
#for i in range(len(happinessData.Score)):
#    if (happinessData.UselessColumn[i] == None):
#        happinessData.UselessColumn[i] = "I am useless"
#Which I will not do in this case, as the list is empty and it will break


#Summarizing a specific column! What would a bell curve of
#average happiness look like?
#This one is harder in Python...
import statistics
standev = statistics.stdev(happinessData.Score)
print("Standard Deviation: ", standev)
mean = sum(happinessData.Score) / len(happinessData.Score)
print("Mean: ", mean)

# %%
#Visualizing Data...
#Is there is a correlation between average wealth and generosity?
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(16,10))
plt.title("Well... Is there?")
plt.xticks(rotation=70)
sns.scatterplot(x= happinessData['Generosity'], y= happinessData['GDP per capita'])

#It would seem there is not.
