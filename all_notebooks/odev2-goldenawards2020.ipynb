# %% [markdown]
# Hocam nihai amacım; Eğer bir film, best actor veya best actriss ödülünü kazanmışsa o filmin aynı zamanda best film ödülünü de kazanma olasılığını çıkarmaktı. Epey çabaladıktan sonra, daha fazla gecikmemek adına sonuca ulaşamadan size gönderiyorum. Uygun olan ilk ödevde tamamlamayı umuyorum.

# %%
# Ayhan Kamas tarafından Data Science ve Python dersinin 2. ödevi olarak yazıldı.
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline


# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
awards=pd.read_csv("/kaggle/input/golden-globe-awards/golden_globe_awards.csv")

# %%
awards.info()

# %%
awards.tail(10)

# %%
# awards["category"].unique()
# son 20 senelik veri seti üzerinde çalışılacağım
awards2000=awards[awards["year_award"]>1999]
#awards2000.head(10)
awards2000.tail(20)
aw=awards.head(3)
aw

# %% [markdown]
# # Veritabanının/Verisetinin ölçüleri (Dimensions of dataset)

# %%
# veri setindei satır sayısı
print('Number of rows in the dataset :', awards.shape[0])
# veri setindeki sütun sayısı
print('Number of columns in the dataset :', awards.shape[1])

# %% [markdown]
# # Veri Setinden bilgi almak
# .info ile genel bilgi

# %%
awards.info()

# %% [markdown]
# # Sütun başlıklarının bilgisini almak

# %%
awards.columns

# %% [markdown]
# # Veri girişi yapılmamış hücreler var mı kontrol  etmek

# %%
null_values=awards.isnull().sum() 
null_values=pd.DataFrame(null_values, columns=['Missing Values']) # evet notlarda buraya dikkat pd.DataFrame kullanılacak
null_values  # bu arada run edilince anlaşılacak ki her sütun karşılığında yazan sayı kadar boş veri girilmemiş hücre var

# %% [markdown]
# film kategorisinde 1800 adet girilmemiş veri var

# %% [markdown]
# # Ödül verilen kategorileri bulmak
# Bunun için category sütununa * .unique metodu ile bakmak yeterli olacaktır
# .unique metodu ile veri girişlerini sıraladığımızda yalnızca birbirinden farklı olanları sayar
# aynı veriden tekrarlandığında onu dikkate almaz

# %% [markdown]
# Ben daha önce bunun için aşağıdaki kodu çalıştırmıştım ve işe yaramıştı

# %%
awards["category"].unique()

# %% [markdown]
#  Burada kategori isimleri alt alta yazdırılıyor
#  sıra nosu vs. olmadığından ve çok fazla kategori olduğundan
#  daha anlaşılabilir bir liste oluşturmak için yeni bir yaklaşıma geçeceğiz

# %% [markdown]
# # Kategoriler

# %%
listNumbersCtg=list(range(awards['category'].nunique())) # nunique()  sanırım unique den kaçtane demek
listCategories=list(awards['category'].unique())
print('---------------  CATEGORIES  -----------------')
for item in zip(listNumbersCtg, listCategories):
    print(item[0], ':', item[1])
    
# Evet listNumberCtg yi sadece 1,2,3... diye sayılarını kullanmak için oluşturmuş. Item[0] onları temsil ediyor

# %% [markdown]
# # Best Filmler ve seneleri

# %%
# içinde best taşıyan ödüller - Bunu best film i bulmak için yapıyorum

# BEST FİLMLER BÜTÜN DALLARDA
bestList=[s for s in listCategories if "Best Motion" in s]  
# aranan kelimeyi yazarkem büyük, küçük harf duyarlı old. unutma "best" değil "Best"
for item in bestList:
    print(item)

# BEST PERFORMANSLAR BÜTÜN DALLARDA
bests=[s for s in listCategories if "Best Performance by an" in s]
bests

# %% [markdown]
# # Ben yapacağım kıyasta "Best film" ler içinden yalnızca "Drama" dalında kazananları kullanacağım.
# # Yani best film listem

# %%
winnerFilms=awards[(awards.win==True)&(awards.category=='Best Motion Picture - Drama')]
winnerFilms

# %% [markdown]
# # Oyuncu ödülleri için de "drama" kategorisini temel alacağım

# %% [markdown]
# # BİR VERİ SETİNDEN SADECE BAZI KOLONLARI ALARAK YENİ BİR VERİ SETİ OLUŞTURMAK

# %%
# winner best performance

winnerPerformances=awards[(awards.win==True)&((awards.category=='Best Performance by an Actress in a Motion Picture - Drama')|(awards.category=='Best Performance by an Actor in a Motion Picture - Drama'))]
winnerPerformances.tail(50)
winnerPerformances

#seneVeNominee=winnerPerformances[["year_award","nominee"]]
#seneVeNominee

# %% [markdown]
# Elimizde
# kazanan filmler (yıl bazında)ve
# kazanan oyuncular(yıl bazında) listesi var
# şimdi çift for döngüsü ile
#
# önce kazanan filmleri döndürüp film isimlerini/'nominee' alıp
#     oyuncu listesini döndürürken "film" isminin aynı olup olmadğına bakmak

# %%
for film in winnerFilms.nominee:
    for performance in winnerPerformances.film:
        if film==performance:
            print(film,"-- >",winnerPerformances.nominee)
            #print(winnerPerformances.nominee)

# %% [markdown]
# Yukarıdakini yaptıktan sonra ,
# Bu listede hem erkek ve hem de kadın oyuncunun ödülünün aynı filme gittiği bir yıl olmuş mu? ona bakayım
