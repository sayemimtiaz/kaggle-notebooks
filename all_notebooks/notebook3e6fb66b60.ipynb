# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("../input/amazon-top-50-bestselling-books-2009-2019/bestsellers with categories.csv")
data.head()

# %% [markdown]
# first of all we will look at the data summary.********

# %%
data.describe()

# %% [raw]
# here as we can see in the above summary of dataset, Reviews column has differnce in mean value and avrage value which is clearly show that it has outlier values.morever most of datapoint lie between 50-70 persentile.

# %%
data.isna().sum()

# %%
As we can see this data doesn't containg any missing values.

# %%
data.info()

# %% [markdown]
# **Category data :** Author , Genre
# <br>
# **numerical data :** User Rating,Reviews,Price , Year

# %%
category_data = data[["Author","Genre"]]
numerical_data = data[["User Rating","Reviews","Price","Year"]]

# %% [markdown]
# now we will find which aurthor write most books.

# %%
category_data["Author"].value_counts().head(10)

# %%
category_data["Author"].value_counts().head(10).plot(kind="bar")

# %%
category_data.Genre.value_counts()

# %%
sns.countplot(data.Genre)

# %%
now we performe eda on numerical data.

# %%
numerical_data

# %%
numerical_data["User Rating"].value_counts()

# %%
a = data.sort_values("User Rating",ascending=False).groupby('Author').mean()

# %%
top10=a.sort_values(["User Rating","Reviews"],ascending=False).head(10)

# %%
top10.Price.plot(kind="bar")
