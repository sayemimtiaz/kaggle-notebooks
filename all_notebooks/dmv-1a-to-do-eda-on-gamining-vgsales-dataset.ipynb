# %% [markdown]
# **About the Attributes in the dataset**
#
# Rank - Ranking of overall sales
#
# Name - The games name
#
# Platform - Platform of the games release (i.e. PC,PS4, etc.)
#
# Year - Year of the game's release
#
# Genre - Genre of the game
#
# Publisher - Publisher of the game
#
# NA_Sales - Sales in North America (in millions)
#
# EU_Sales - Sales in Europe (in millions)
#
# JP_Sales - Sales in Japan (in millions)
#
# Other_Sales - Sales in the rest of the world (in millions)
#
# Global_Sales - Total worldwide sales.

# %% [markdown]
# Market Overview
#
# The global gaming market was valued at USD 151.55 billion in 2019 and is expected to reach a value of USD 256.97 billion by 2025, registering a CAGR of 9.17% over the forecast period (2020 – 2025). Game developers across emerging economies are continually striving to enhance gamer's experience, launching, and rewriting codes for diverse console/platforms, such as PlayStation, Xbox, and Windows PC, which are incorporated into one product provided to the gamers through the cloud platform.
# The world is currently undergoing a harrowing and unprecedented event: the COVID-19 pandemic. During these trying times, gaming has become a means of escapism and time filling for many.As a result, one of this year’s growth drivers is an increased interest in gaming due to COVID-19-related lockdown measures. However, the launch of the next-generation consoles toward the end of the year is also a key contributing factor.

# %% [markdown]
# 1) What data domain you have selected?
#
# Domain is sales of video games indusries on different platforms.
#
# 2) What are the information that the dataset contains?
#
# the dataset contains sales data of games in north america, europe , japan , rest of the world. The dataset also contains the details of publisher and platform and year of release of each and every game.
#
# 3) what are the insights we can generate from the data ?
#
# We can generate that which genere sports is sold more in particular area of the world and how the interest of the people changes by location. We can check that the game genre we want to release is more liked by which part of the world and we can lauch the game in that language more early eg chinese version, english version, french version...  we can gererate insights that which platform is more prefered in which country so we can make the game in that platform earlier and then focus on another platforms as we generate income from one of the platform.
#
# We can also generate insights like video game release by year, Video Game Global Sales by Release Year, Publisher Wise Video Game Release, Publisher Wise Video Game Count,  Publisher Wise Video Game Sales (Overall), Top 5 Publisher - Yearwise, Top 5 Publisher - Reagion Wise, Platform wise Video Game Count, platform wordcount, Region Wise Game Sales by Platform, genre wise video games, genre wise game sales, top 5 games by genre, region wise sales per genre and many more ...
#
# 4) What are the pattern available in the dataset?
# the dataset contains patterns of which game is sold in which platform in which country. the rank is given by sorting the whole dataset by global sales. The global sales is summation of all the individual sales column so the correlation exists between all the sales columns with the global sales.
#
# the more early the game is released, the more it would earned. so there is a pattern of date of release and gross earning. but after approx 5 year people dont tend to buy that old game.
#
# WE SHOULD ALSO CONSIDER THE INFLATION OF CURRENCY, OLDER SALES OF 500 DOLLAR MAY BE ALMOST EQUIVALENT TO CURRENT SALES OF 1000 DOLLARS OR MORE .... IF WE CONSIDER THAT THAN WE CAN SEE THAT IN OLDER DAYS THE GAMES WERE SOLD MORE AND PROFIT WERE MADE MORE AND NOW A DAYS AFTER THE INTERNET ERA, PEOPLES ARE DOING PIRACY OR EXCHANGING GAMES VIA GOOGLE DRIVES OR PEN DRIVES... WE SHOULD NOT SEE THE DATA LIKE LESS DOLLAR SALES IN PAST MEANS LESS PROFIT...... THE PRICE OF DOLLAR MUST BE KEPT IN MIND TO DO COMAPRISON...
#
# 5) identify the characteristics of various fields in the dataset.
#
# RangeIndex: 16598 entries, 0 to 16597
#
# Data columns (total 11 columns):

# %%
#Data Analysis & Data wrangling
import numpy as np
import pandas as pd
import missingno as mn
from collections import Counter

#Visualization
import matplotlib.pyplot as plt
import matplotlib.style as style
from matplotlib.colors import ListedColormap
from matplotlib import cm
import seaborn as sns
# %matplotlib inline
vgdata = pd.read_csv('../input/videogamesales/vgsales.csv')
print("Database dimension     :",vgdata.shape)
print("Database size          :",vgdata.size)

vgdata.info()

# %%
vgdata.describe()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
game = pd.read_csv("../input/videogamesales/vgsales.csv")
game

# %%
top_10 = game[0:10]
top_10

# %%
plt.figure(figsize = (18,8))
plt.barh(top_10["Name"],top_10["Global_Sales"])
plt.title("Top 10 games Global Sales",fontdict = {"fontsize":20})
plt.savefig("Top 10 games Global Sales.jpg",dpi = 300)
plt.show()

# %%
#Top 5 Publisher
Publisher = list(game.Publisher.unique())
global_sale_of_every_Publisher = pd.Series(dtype = float)
for pub in Publisher :
    data = game.loc[game.Publisher == pub]
    global_sale = sum(data.Global_Sales)
    global_sale_of_every_Publisher[pub] = global_sale

top_5 = global_sale_of_every_Publisher[:5]
plt.figure(figsize = (10.5,9))
plt.pie(top_5,labels = top_5.index,autopct = "%.2f%%",textprops = {"fontsize":13},labeldistance = 1.05)
plt.legend(loc = 4,fontsize  = 12)
plt.title("Top 5 Publisher of Games",fontdict = {"fontsize":25,"fontweight":100})
plt.savefig("Top 5 Publisher of Games",dpi = 300)
plt.show()

# %%
#Growth of the 1st Publisher of games over years
Nintendo = game.loc[game.Publisher == "Nintendo"]
Nintendo_1 = Nintendo.sort_values(by = "Year")
Nintendo_1 = Nintendo_1.dropna()
Nintendo_years = Nintendo.Year.unique()
Nintendo_profit_year = pd.Series(dtype = float)
for yea in Nintendo_years:
    data_of_year = Nintendo_1.loc[Nintendo_1.Year == yea]
    total_of_year = data_of_year.Global_Sales.sum(axis = 0)
    Nintendo_profit_year[yea] = total_of_year
Nintendo_profit_year = Nintendo_profit_year.sort_index()
Nintendo_profit_year = Nintendo_profit_year
plt.plot(Nintendo_profit_year)
plt.xlabel("Years",size = 14)
plt.ylabel("Unit Sales",size = 14)
plt.title("Nintendo Global Sales from 1983 to 2017",fontdict = {"fontsize":15})
plt.xticks([i for i in range(1980,2019,2)])
plt.savefig("Nintendo Global Sales from 1983 to 2017",dpi = 300)
plt.show()

# %%
Genre = game.Genre
Genre = Genre.value_counts()
plt.figure(figsize = (8,8))
labels = Genre.index

plt.pie(Genre,labels = labels,autopct = "%.2f%%") 
plt.title("Games Top Genres",fontdict = {"fontsize":20})
plt.savefig("Games Top Genres",dpi = 300)
plt.show()

# %%
import os
import numpy as np 
import pandas as pd 
import plotly.express as px
import plotly.graph_objs as go
from plotly.subplots import make_subplots
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)

# %%
vidgme_df = pd.read_csv("../input/videogamesales/vgsales.csv")
vidgme_df = vidgme_df.dropna()
sales = ["NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales"]

# %%
desc = vidgme_df.groupby(["Year"])[["Global_Sales"]].describe()
desc = desc.drop("min",level=1, axis=1)
desc.style.background_gradient(cmap ='Spectral')

# %%
vidgme_df.corr(method = 'pearson')

# %%
#Company sales analysis
top_50_pubs = vidgme_df.groupby(["Publisher"]).sum().nlargest(50, columns=["Global_Sales"])[sales]
top_50_pubs

# %%
df=game
year_freq = pd.crosstab(index=df['Year'], columns='count')
temp = []
for i in year_freq['count']:
  p = 100 * (i/df.shape[0])
  temp.append(p)
year_freq['Percent'] = temp
year_freq.sort_values('count', ascending = False)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(year_freq.index,year_freq['count'])
plt.xlabel('year')
plt.ylabel('frequency')
plt.show()

# %%
global_sales_freq = pd.crosstab(index=df['Global_Sales'], columns='count')
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(5)
ax = f.add_axes([0,0,1,1])
ax.bar(global_sales_freq.index,global_sales_freq['count'])
plt.xlabel('total worldwide sales (in millions)')
plt.ylabel('frequency of the games in this region')
plt.show()

# %% [markdown]
# mostly all games are sold world wide under 2 million.

# %%
plat_freq = pd.crosstab(index=df['Platform'], columns='Frequency')
temp = []
for i in plat_freq['Frequency']:
  p = 100 * (i/df.shape[0])
  temp.append(p)
plat_freq['Percent'] = temp
plat_freq = plat_freq.sort_values('Frequency', ascending = False)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(10)
plt.pie(labels = plat_freq.index[0:10],x = plat_freq.iloc[0:10,0], autopct='%1.0f%%')
plt.show()

# %%
#number of sales per platform per region 

val = []
x = df.sort_values('Platform')
x = x['Platform'].unique()
for i in x:
  t = df[df['Platform'] == i].sum()
  val.append(t.loc['NA_Sales'])
fig = plt.figure()
fig.set_figwidth(10)
fig.set_figheight(5)
plt.title("north america sales")
plt.xlabel('Platform')
plt.xticks(rotation='vertical')
plt.ylabel('Total NA Sales in Millions')
plt.plot(x,val)
plt.show()
val = []
x = df.sort_values('Platform')
x = x['Platform'].unique()
for i in x:
  t = df[df['Platform'] == i].sum()
  val.append(t.loc['EU_Sales'])
fig = plt.figure()
fig.set_figwidth(10)
fig.set_figheight(5)
plt.xlabel('Platform')
plt.xticks(rotation='vertical')
plt.ylabel('Total EU Sales in Millions')
plt.title("europe sales")
plt.plot(x,val)
plt.show()
val = []
x = df.sort_values('Platform')
x = x['Platform'].unique()
for i in x:
  t = df[df['Platform'] == i].sum()
  val.append(t.loc['JP_Sales'])
fig = plt.figure()
fig.set_figwidth(10)
fig.set_figheight(5)
plt.xlabel('Platform')
plt.xticks(rotation='vertical')
plt.ylabel('Total JP Sales in Millions')
plt.title("japan sales")
plt.plot(x,val)
plt.show()

# %%
x = df.sort_values('NA_Sales', ascending = False).head(10)
fig = plt.figure()
fig.set_figwidth(10)
fig.set_figheight(5)
ax = fig.add_axes([0,0,1,1])
ax.bar(x['Name'],x['NA_Sales'],color="gray")
plt.xlabel('Name')
plt.ylabel('NA Sales in Millions')
plt.xticks(rotation='vertical')
plt.title("NORTH AMERICA SALES")
plt.show()
x = df.sort_values('EU_Sales', ascending = False).head(10)
fig = plt.figure()
fig.set_figwidth(10)
fig.set_figheight(5)
ax = fig.add_axes([0,0,1,1])
ax.bar(x['Name'],x['EU_Sales'],color="red")
plt.xlabel('Name')
plt.title("EUROPE SALES")
plt.xticks(rotation='vertical')
plt.ylabel('EU Sales in Millions')
plt.show()
x = df.sort_values('JP_Sales', ascending = False).head(10)
fig = plt.figure()
fig.set_figwidth(10)
fig.set_figheight(5)
ax = fig.add_axes([0,0,1,1])
ax.bar(x['Name'],x['JP_Sales'],color="violet")
plt.xlabel('Name')
plt.title("JAPAN SALES")
plt.xticks(rotation='vertical')
plt.ylabel('JP Sales in Millions')
plt.show()
x = df.sort_values('Global_Sales', ascending = False).head(10)
fig = plt.figure()
fig.set_figwidth(10)
fig.set_figheight(5)
ax = fig.add_axes([0,0,1,1])
ax.bar(x['Name'],x['Global_Sales'],color="pink")
plt.title("GLOBAL SALES")
plt.xlabel('Name')
plt.xticks(rotation='vertical')
plt.ylabel('Global Sales in Millions')
plt.show()

# %%
# Boxplot Representations
fig, axs = plt.subplots(4,1, figsize=(15,10))
fig.tight_layout(h_pad=4)
axs[0].boxplot(df['NA_Sales'], 0, "rs", 0)
axs[0].set_title("north america sales")
axs[1].boxplot(df['JP_Sales'], 0, "rs", 0)
axs[1].set_title("Japan sales")
axs[2].boxplot(df['EU_Sales'], 0, "rs", 0)
axs[2].set_title("europe sales")
axs[3].boxplot(df['Other_Sales'], 0, "rs", 0)
axs[3].set_title("others sales")

# %%
df.describe()

# %%
import numpy
from numpy import percentile
sales_loc = ['NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']
indices = ['iqr']
summary_data = pd.DataFrame(columns=sales_loc, index=indices)
for i in sales_loc:
  temp = []
  quartiles = percentile(df[i], [25, 75])
  temp.append(quartiles[1]-quartiles[0])
  summary_data.loc[:,i] = temp

summary_data

# %% [markdown]
# Conclusion: We have done exploratory data analysis to check how our data is distributed. We have made pie charts, box plots, and many graphs. We have seen top 5 publishers and top 5 generes. We have made box plot analysis in which we can find that there are a lot of outliers in the data. Mostly only some games were sold more so that is considered outlier by the box plot. The histogram of frequency of sell vs year shows that it is normally distributed. We can see that the games that are recently launced has not yet made money because they are still in stores and have not sold many copies. And in earlier years the price of games were too low because of the price of dollar was high. There fore the games that were released too early  have got less sales. To compare the profits we must take the inflation of money in our mind and should act accodingly.
