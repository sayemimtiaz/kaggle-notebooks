# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../input/cardio-train/cardio_train.csv', sep=';')
df.head(4)

#
df.info()

#
df.describe().T

# Height and age
plt.scatter(df['age'], df['height']);

sns.jointplot(x='height', y='weight', data=df);
