# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df=pd.read_csv("/kaggle/input/weight-height/weight-height.csv")
df

# %%
#checking first five columns
df.head()

# %%
#removing  weight columns
df1=df.iloc[0:,0:2]
df1.head()

# %%
#checking rows and columns
df1.shape

# %%
df1.Height.describe()

# %%
#visualization using seaborn,ploting histogram
sns.histplot(df1.Height,kde=True)

# %%
#using std deviation removing outliers
mean=df1.Height.mean()
mean

# %%
std=df1.Height.std()
std

# %%
#using 3 std 
mean-3*std

# %%
mean+3*std

# %%
#if our data is leass than 54.82 and greater than 77.91 then we said that outliers

# %%
#filtering
df1[(df1.Height<54.82)|(df1.Height>77.91)]

# %%
df1_outliers=df1[(df1.Height<77.91) & (df1.Height>54.82)]
df1_outliers.shape

# %%
df1_outliers.shape
#here we can conclude that we can't see the seven ouliers

# %%
df1.head()

# %%
#calculating z-score

# %%
#formula for finding z-score in a data set
df1["zscore"]=(df1.Height-df1.Height.mean())/df1.Height.std()
df1.head()

# %%
df1[(df1.zscore<-3)|(df1.zscore>3)]
