# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import statistics

# %%
ETC_filepath='../input/temperature-change/Environment_Temperature_change_E_All_Data_NOFLAG.csv'
ETC_data=pd.read_csv(ETC_filepath,encoding ='latin1', parse_dates=True)
FAO_filepath='../input/temperature-change/FAOSTAT_data_11-24-2020.csv'
FAO_data=pd.read_csv(FAO_filepath)

# %%
ETC_data.head()

# %%
FAO_data.head()

# %%
FAO_data['Country'].unique()

# %%
FAO_data.loc[FAO_data.Country=="United States of America"]

# %%
ETC_data.Area.unique()

# %%
set(ETC_data['Area'].tolist())

# %%
US_data=ETC_data.loc[ETC_data.Area=='United States of America']

# %%
US_data.head()

# %%
US_data.Element.unique()

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x=US_data.Months,y=US_data.Y2019.loc[US_data.Element=='Temperature change'], label='Y2019', sort=False)
sns.lineplot(x=US_data.Months,y=US_data.Y2018.loc[US_data.Element=='Temperature change'], label='Y2018', sort=False)
sns.lineplot(x=US_data.Months,y=US_data.Y2017.loc[US_data.Element=='Temperature change'], label='Y2017', sort=False)
sns.lineplot(x=US_data.Months,y=US_data.Y2000.loc[US_data.Element=='Temperature change'], label='Y2000', sort=False)
plt.legend()

# %%
US_data.Months.unique()

# %%
US_data1=US_data.loc[US_data.Months.isin(['January', 'February', 'March', 'April', 'May', 'June', 'July','August', 'September', 'October', 'November', 'December'])]

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x=US_data1.Months,y=US_data.Y2019.loc[US_data.Element=='Temperature change'], label='Y2019', sort=False)
sns.lineplot(x=US_data1.Months,y=US_data.Y2018.loc[US_data.Element=='Temperature change'], label='Y2018', sort=False)
sns.lineplot(x=US_data1.Months,y=US_data.Y2017.loc[US_data.Element=='Temperature change'], label='Y2017', sort=False)
sns.lineplot(x=US_data1.Months,y=US_data.Y2000.loc[US_data.Element=='Temperature change'], label='Y2000', sort=False)
plt.legend()

# %%
def avg(list):
    return sum(list)/len(list)

# %%
US_data1["Y2019"].loc[US_data.Element=='Standard Deviation']

# %%
US_data1["Y2018"].loc[US_data.Element=='Standard Deviation']

# %%
d= {'Years':[i for i in range(1961,2020)] , 'Temperature_change':[avg(US_data1["Y"+str(i)].loc[US_data.Element=='Temperature change']) for i in range(1961,2020)] }
df = pd.DataFrame(data=d)
df.head()

# %%
US_data2=US_data.loc[US_data.Months=='Meteorological year']
US_data2.head()

# %%
d1= {'Years':[i for i in range(1961,2020)] , 'Temperature_change':[avg(US_data2["Y"+str(i)].loc[US_data.Element=='Temperature change']) for i in range(1961,2020)] }
Meteorological_year = pd.DataFrame(data=d1)
Meteorological_year.head()

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x=Meteorological_year.Years, y=Meteorological_year.Temperature_change, label= 'evolution of temperature change by meteorological years')
plt.legend()

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x=df.Years, y=df.Temperature_change, label= 'evolution of temperature change by years')
plt.legend()

# %%
US_data3=US_data.loc[US_data.Months.isin(['Dec\x96Jan\x96Feb', 'Mar\x96Apr\x96May', 'Jun\x96Jul\x96Aug','Sep\x96Oct\x96Nov'])]

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x=US_data3.Months,y=US_data.Y2019.loc[US_data.Element=='Temperature change'], label='Y2019', sort=False)
sns.lineplot(x=US_data3.Months,y=US_data.Y2018.loc[US_data.Element=='Temperature change'], label='Y2018', sort=False)
sns.lineplot(x=US_data3.Months,y=US_data.Y2017.loc[US_data.Element=='Temperature change'], label='Y2017', sort=False)
sns.lineplot(x=US_data3.Months,y=US_data.Y2000.loc[US_data.Element=='Temperature change'], label='Y2000', sort=False)
plt.legend()

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x=US_data1.Months,y=US_data.Y2019.loc[US_data.Element=='Temperature change'], label='Y2019', sort=False)
sns.lineplot(x=US_data1.Months,y=US_data.Y2018.loc[US_data.Element=='Temperature change'], label='Y2018', sort=False)
sns.lineplot(x=US_data1.Months,y=US_data.Y2017.loc[US_data.Element=='Temperature change'], label='Y2017', sort=False)
sns.lineplot(x=US_data1.Months,y=US_data.Y2000.loc[US_data.Element=='Temperature change'], label='Y2000', sort=False)
plt.legend()

# %%
ma_data=ETC_data.loc[ETC_data.Area=='Morocco']

# %%
ma_data.Months.unique()

# %%
ma_data.Element.unique()

# %%
ma_data1=ma_data.loc[ma_data.Months.isin(['January', 'February', 'March', 'April', 'May', 'June', 'July','August', 'September', 'October', 'November', 'December'])]
ma_data2=ma_data.loc[ma_data.Months=='Meteorological year']
ma_data3=ma_data.loc[ma_data.Months.isin(['Dec\x96Jan\x96Feb', 'Mar\x96Apr\x96May', 'Jun\x96Jul\x96Aug','Sep\x96Oct\x96Nov'])]

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x=ma_data1.Months ,y=ma_data1.Y2019.loc[ma_data.Element=='Temperature change'], label='Y2019', sort=False)
sns.lineplot(x=ma_data1.Months ,y=ma_data1.Y2018.loc[ma_data.Element=='Temperature change'], label='Y2018', sort=False)
sns.lineplot(x=ma_data1.Months ,y=ma_data1.Y2017.loc[ma_data.Element=='Temperature change'], label='Y2017', sort=False)
sns.lineplot(x=ma_data1.Months ,y=ma_data1.Y2017.loc[ma_data.Element=='Temperature change'], label='Y2017', sort=False)
plt.legend()
plt.savefig('MA 2019 2018 2017.png')

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x=ma_data3.Months ,y=ma_data3.Y2019.loc[ma_data.Element=='Temperature change'], label='Y2019', sort=False)
sns.lineplot(x=ma_data3.Months ,y=ma_data3.Y2018.loc[ma_data.Element=='Temperature change'], label='Y2018', sort=False)
sns.lineplot(x=ma_data3.Months ,y=ma_data3.Y2017.loc[ma_data.Element=='Temperature change'], label='Y2017', sort=False)
sns.lineplot(x=ma_data3.Months ,y=ma_data3.Y2016.loc[ma_data.Element=='Temperature change'], label='Y2016', sort=False)
plt.legend()
plt.savefig('TC 2019 2018 2017 METE.png')

# %%
ma1= {'Years':[i for i in range(1961,2020)] , 'Temperature_change':[avg(ma_data1["Y"+str(i)].loc[ma_data.Element=='Temperature change']) for i in range(1961,2020)] , 'Standard_Deviation':[avg(ma_data1["Y"+str(i)].loc[ma_data.Element=='Standard Deviation']) for i in range(1961,2020)] }
dfMA = pd.DataFrame(data=ma1)
dfMA.head()

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x=dfMA.Years, y=dfMA.Temperature_change, label= 'evolution of temperature change by years MOROCCO')
sns.lineplot(x=df.Years, y=df.Temperature_change, label= 'evolution of temperature change by years US')
plt.legend()
plt.savefig('save_as_a_png.png')

# %%
FAO_data.head()
