# %% [markdown]
# # CONTENTS
#
# <font color="red">
#
#
# 1. [Introduction](#1)
# 2. [Libraries](#2)
# 3. [Uploading Data](#3)
# 4. [Multivariate Linear Regression](#4)
#     * 4.1. [Dependent And Independent Variables](#5)
#     * 4.2. [Diving Data For Training And Test](#6)
#     * 4.3. [Scaling](#7)
#     * 4.4. [Multivariate Linear Regression and Prediction](#8)
# 5. [Simple Linear Regression](#9)
#     * 5.1. [Dependent and Independent Variables](#10)
#     * 5.2. [Diving Data For Training And Test](#11)
#     * 5.3. [Multivariate Linear Regression and Prediction](#12)
#     * 5.4. [$𝑅^2$  Score For Simple Linear Regression](#13)
#     * 5.5. [Visualization For Simple Linear Regression](#14)
# 6. [Backward Elimination For Simple Linear Regression](#15)
#     * 6.1. [Uploading Data](#16)
#     * 6.2. [Dependent and Independent Variables](#17)
#     * 6.3. [One Hot Encoder](#18)
#     * 6.4. [Transforming Numpy Arrays To Dataframe](#19)
#     * 6.5. [Concatinating Dataframes](#20)
#     * 6.6. [Diving Data For Training And Test](#21)
#     * 6.7. [Simple Linear Regression And Prediction](#22)
#     * 6.8. [Backward Elimination For Simple Linear Regression](#23)
#     * 6.9. [Information About Data](#24)
#     * 6.10. [OLS Regression Results](#25)
#     * 6.11. [Creating A New OLS Model According To First OLS Model](#26)
# 7. [Polynomial Regression](#27)
#     * 7.1. [Dependent And Independent Variables](#28)
#     * 7.2. [Linear Model(1st Order)](#29)
#     * 7.3. [Nonlinear Model](#30)
#         * 7.3.1. [2nd Order](#31)
#         * 7.3.2. [4th Order](#32)
#     * 7.4. [Visualization Of Polynomial Regression](#33)
#     * 7.5. [Predictions](#34)
#     * 7.6. [$𝑅^2$ Score For Polynomial Regression](#35)
# 8. [SVR (Support Vector Regression](#36)
#     * 8.1. [Scaling](#37)
#     * 8.2. [Support Vector Regression](#38)
#     * 8.3. [Prediction Of SVR](#39)
#     * 8.4. [$𝑅^2$ Score For SVR](#40)
# 9. [Decision Tree Regression](#41)
#     * 9.1. [Decision Tree Regression](#42)
#     * 9.2. [Prediction Of Decision Tree Regression](#43)
#     * 9.3. [$𝑅^2$  Score Of Decision Tree Regression](#44)
# 10. [Random Forest Regression](#45)
#     * 10.1. [Random Forest Regression](#46)
#     * 10.2. [Prediction Of Decision Tree Regression](#47)
#     * 10.3. [Visualization For Random Forest Regression](#48)
#     * 10.4. [$𝑅^2$  Score Of Random Forest Regression](#49)
# 11. [$𝑅^2$  Scores Abstract](#50)

# %% [markdown]
# <a id="1"></a><br>
# # 1. Introduction
# In statistical modeling, regression analysis is a set of statistical processes for estimating the relationships between a dependent variable and one or more independent variables.
# # $$Y_i = f(X_i,β) + e_i$$

# %% [markdown]
# * $Y_i$ = dependent variable
# * f = function
# * $X_i$ = independent variable
# * β = unknown parameters
# * $e_i$ = error terms

# %% [markdown]
# <a id="2"></a><br>
# # 2. Libraries

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# <a id="3"></a><br>
# # 3. Uploading Data

# %%
data = pd.read_csv("/kaggle/input/car-price-prediction/CarPrice_Assignment.csv")
data

# %% [markdown]
# <a id="4"></a><br>
# # 4. Multivariate Linear Regression

# %% [markdown]
# <a id="5"></a><br>
# ## 4.1. Dependent And Independent Variables

# %%
x = data[["wheelbase","carwidth","curbweight","compressionratio","horsepower","highwaympg"]].values
y = data[["price"]].values
x

# %%
y

# %%
x.size

# %%
#s1=pd.DataFrame(data=x, columns=["wheelbase","carwidth","curbweight","compressionratio","horsepower","highwaympg"])
#s1

# %%
#s2=pd.DataFrame(data=y)
#s2

# %% [markdown]
# <a id="6"></a><br>
# ## 4.2. Diving Data For Training And Test

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3,random_state=0)

# %%
x_train

# %%
x_test

# %%
y_train

# %%
y_test

# %% [markdown]
# <a id="7"></a><br>
# ## 4.3. Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

X_train = sc.fit_transform(x_train)
X_test = sc.fit_transform(x_test)

Y_train = sc.fit_transform(y_train)
Y_test = sc.fit_transform(y_test)

# %% [markdown]
# <a id="8"></a><br>
# ## 4.4. Multivariate Linear Regression and Prediction

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)

pred1 = lr.predict(x_test)

# %%
y_test

# %%
pred1

# %% [markdown]
# <a id="9"></a><br>
# # 5. Simple Linear Regression

# %%
data

# %% [markdown]
# <a id="10"></a><br>
# ## 5.1. Dependent and Independent Variables

# %%
x2=data[["curbweight"]]
x2

# %%
y2 = data[["price"]]
y2

# %% [markdown]
# <a id="11"></a><br>
# ## 5.2. Diving Data For Training And Test

# %%
from sklearn.model_selection import train_test_split
x_train2, x_test2, y_train2, y_test2 = train_test_split(x2, y2, test_size=0.33,random_state=0)

# %% [markdown]
# <a id="12"></a><br>
# ## 5.3. Multivariate Linear Regression and Prediction

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train2,y_train2)

pred2 = lr.predict(x_test2)

# %%
y_test2

# %%
pred2

# %% [markdown]
# <a id="13"></a><br>
# ## 5.4. $R^2$ Score For Simple Linear Regression

# %%
from sklearn.metrics import r2_score
print("Simple linear regression R2 score:", r2_score(y2,lr.predict(x2)))

# %% [markdown]
# <a id="14"></a><br>
# ## 5.5. Visualization For Simple Linear Regression

# %%
x_train2=x_train2.sort_values(by="curbweight")
y_train2=y_train2.sort_index()

plt.plot(x_train2,y_train2,)
plt.plot(x_test2,pred2)

plt.title("car prices")
plt.xlabel("curbweight")
plt.ylabel("price")

# %%
y_train2

# %% [markdown]
# <a id="15"></a><br>
# # 6. Backward Elimination For Simple Linear Regression

# %% [markdown]
# <a id="16"></a><br>
# ## 6.1. Uploading Data

# %%
data

# %% [markdown]
# <a id="17"></a><br>
# ## 6.2. Dependent And Independent Variables

# %%
carbody=data[["carbody"]].values
carbody

# %%
data3=data[["horsepower"]].values
data3

# %%
price3=data[["price"]].values
price3

# %%
"""door=data[["doornumber"]].values
door"""

# %% [markdown]
# <a id="18"></a><br>
# ## 6.3. One Hot Encoder

# %%
#OneHotEncoder
from sklearn import preprocessing

ohe=preprocessing.OneHotEncoder()
carbody=ohe.fit_transform(carbody).toarray()
print(carbody)

# %%
"""ohe=preprocessing.OneHotEncoder()
door=ohe.fit_transform(door).toarray()
print(door)"""

# %% [markdown]
# <a id="19"></a><br>
# ## 6.4. Transforming Numpy Arrays To Dataframe

# %%
cb1=pd.DataFrame(data=carbody,index=range(205),columns=["convertible","hardtop","hatchback","sedan","wagon"])
cb1

# %%
cb2=pd.DataFrame(data=data3,index=range(205),columns=["horsepower"])
cb2

# %%
cb3=pd.DataFrame(data=price3,index=range(205),columns=["price3"])
cb3

# %% [markdown]
# <a id="20"></a><br>
# ## 6.5. Concatinating Dataframes

# %%
concat1=pd.concat([cb1,cb2],axis=1)
concat1

# %% [markdown]
# <a id="21"></a><br>
# ## 6.6. Diving Data For Training And Test

# %%
from sklearn.model_selection import train_test_split
x_train3,x_test3,y_train3,y_test3 = train_test_split(concat1,cb3,test_size=0.33, random_state=0)

# %% [markdown]
# <a id="22"></a><br>
# ## 6.7. Simple Linear Regression And Prediction

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train3,y_train3)
pred3=regressor.predict(x_test3)

# %%
pred3

# %%
y_test3

# %% [markdown]
# <a id="23"></a><br>
# ## 6.8. Backward Elimination For Simple Linear Regression

# %%
data_b=pd.concat([concat1,cb3],axis=1)
data_b

# %%
sym=data[["symboling"]].values
sym

# %%
x_train4,x_test4,y_train4,y_test4 = train_test_split(data_b,sym,test_size=0.33,random_state=0)

# %%
r4 = LinearRegression()
r4.fit(x_train4,y_train4)

pred4 = r4.predict(x_test4)

# %%
pred4

# %%
y_test4

# %% [markdown]
# <a id="24"></a><br>
# ## 6.9. Information About Data

# %%
data_b.info()

# %% [markdown]
# <a id="25"></a><br>
# ## 6.10. OLS Regression Results

# %% [markdown]
# > OLS = Ordinary Least Squares

# %%
import statsmodels.api as sm

x4=np.append(arr=np.ones((205,1)).astype(int),values=data_b,axis=1) #column x0

X4_l = data_b.iloc[:,[0,1,2,3,4,5,6]].values #we get all columns
X4_l= np.array(X4_l,dtype=float)
model = sm.OLS(sym,X4_l).fit() #generate a report with OLS
print(model.summary())

# %% [markdown]
# > For more: [https://www.datarobot.com/blog/ordinary-least-squares-in-python/](https://www.datarobot.com/blog/ordinary-least-squares-in-python/)

# %% [markdown]
# > For $x_5$, P>|t| value is large. So, we can delete that column.

# %% [markdown]
# <a id="26"></a><br>
# ## 6.11. Creating A New OLS Model According To First OLS Model

# %%
#new OLS model
X4_l = data_b.iloc[:,[0,1,2,3,5,6]].values #we get all columns
X4_l= np.array(X4_l,dtype=float)
model = sm.OLS(sym,X4_l).fit() #generate a report with OLS
print(model.summary())

# %% [markdown]
# <a id="27"></a><br>
# # 7. Polynomial Regression

# %% [markdown]
# <a id="28"></a><br>
# ## 7.1. Dependent And Independent Variables

# %%
x=data[["wheelbase"]].values
y=data[["price"]].values

# %% [markdown]
# <a id="29"></a><br>
# ## 7.2. Linear Model (1st Order)

# %%
linreg1 = LinearRegression()
linreg1.fit(x,y)

# %% [markdown]
# <a id="30"></a><br>
# ## 7.3. Nonlinear Model

# %% [markdown]
# <a id="31"></a><br>
# ### 7.3.1. 2nd Order

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg2=PolynomialFeatures(degree=2)
x_poly2=poly_reg2.fit_transform(x)
linreg2=LinearRegression()
linreg2.fit(x_poly2,y)

# %%
x_poly2

# %% [markdown]
# <a id="32"></a><br>
# ### 7.3.2. 4th Order

# %%
#4th order
poly_reg4=PolynomialFeatures(degree=4)
x_poly4=poly_reg4.fit_transform(x)
linreg4=LinearRegression()
linreg4.fit(x_poly4,y)

# %%
x_poly4

# %% [markdown]
# <a id="33"></a><br>
# ## 7.4. Visualization Of Polynomial Regression

# %%
plt.scatter(x,y,color='red')
plt.plot(x,linreg1.predict(x), color = 'blue')
plt.show()

plt.scatter(x,y,color = 'red')
plt.plot(x,linreg2.predict(poly_reg2.fit_transform(x)), color = 'blue')
plt.show()

plt.scatter(x,y,color = 'red')
plt.plot(x,linreg4.predict(poly_reg4.fit_transform(x)), color = 'blue')
plt.show()

# %% [markdown]
# <a id="34"></a><br>
# ## 7.5. Predictions

# %%
print("lin reg 1st order(linear): ",linreg1.predict([[6.6]]))
print("lin reg 1st order(linear): ",linreg1.predict([[110]]))

print("lin reg 2nd order(linear): ",linreg2.predict(poly_reg2.fit_transform([[6.6]])))
print("lin reg 2nd order(linear): ",linreg2.predict(poly_reg2.fit_transform([[110]])))

print("lin reg 4th order(linear): ",linreg4.predict(poly_reg4.fit_transform([[6.6]])))
print("lin reg 4th order(linear): ",linreg4.predict(poly_reg4.fit_transform([[110]])))

# %% [markdown]
# <a id="35"></a><br>
# ## 7.6. $R^2$ Score For Polynomial Regression

# %%
from sklearn.metrics import r2_score
print("Polynomial regression R2 score:", r2_score(y,linreg2.predict(x_poly2)))

# %% [markdown]
# <a id="36"></a><br>
# # 8. SVR (Support Vector Regression)

# %% [markdown]
# <a id="37"></a><br>
# ## 8.1. Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc1=StandardScaler()
x_scaled = sc1.fit_transform(x)
sc2=StandardScaler()
y_scaled = np.ravel(sc2.fit_transform(y.reshape(-1,1)))

# %% [markdown]
# <a id="38"></a><br>
# ## 8.2. Support Vector Regression

# %%
from sklearn.svm import SVR

svr_reg = SVR(kernel='rbf')
svr_reg.fit(x_scaled,y_scaled)

plt.scatter(x_scaled,y_scaled,color='red')
plt.plot(x_scaled,svr_reg.predict(x_scaled),color='blue')
plt.show()

# %%
svr_reg2 = SVR(kernel='poly')
svr_reg2.fit(x_scaled,y_scaled)

plt.scatter(x_scaled,y_scaled,color='red')
plt.plot(x_scaled,svr_reg2.predict(x_scaled),color='blue')
plt.show()

# %% [markdown]
# <a id="39"></a><br>
# ## 8.3. Prediction Of SVR

# %%
print("SVR rbf pred:", svr_reg.predict([[110]]))
print("SVR rbf pred:", svr_reg.predict([[6.6]]))

# %%
print("SVR poly pred:", svr_reg2.predict([[110]]))
print("SVR poly pred:", svr_reg2.predict([[6.6]]))

# %% [markdown]
# <a id="40"></a><br>
# ## 8.4. $R^2$ Score For SVR

# %%
print("SVR rbf  R2 score:" ,r2_score(y_scaled,svr_reg.predict(x_scaled)))
print("SVR poly R2 score:",r2_score(y_scaled,svr_reg2.predict(x_scaled)))

# %% [markdown]
# > **rbf** is more convinient than **poly** *(0.42>0.12)*

# %% [markdown]
# <a id="41"></a><br>
# # 9. Decision Tree Regression

# %% [markdown]
# <a id="42"></a><br>
# ## 9.1. Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor(random_state=0)
dtr.fit(x,y)
Z = x + 0.5
K = y - 0.4

plt.scatter(x,y, color='red')
plt.plot(x,dtr.predict(x), color='blue')
plt.plot(x,dtr.predict(Z),color='green')
plt.plot(x,dtr.predict(K),color='yellow')
plt.show()

# %% [markdown]
# <a id="43"></a><br>
# ## 9.2. Prediction Of Decision Tree Regression

# %%
print(dtr.predict([[110]]))
print(dtr.predict([[11]]))
print(dtr.predict([[6.6]]))

# %% [markdown]
# <a id="44"></a><br>
# ## 9.3. $R^2$ Score Of Decision Tree Regression

# %%
print("Decision tree regression R2 score:", r2_score(y,dtr.predict(x)))

# %% [markdown]
# <a id="45"></a><br>
# # 10. Random Forest Regression

# %% [markdown]
# <a id="46"></a><br>
# ## 10.1. Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(n_estimators = 10,random_state=0) #We give how many decision trees to draw with #n_estimators
rfr.fit(x,y.ravel()) #ravel combines individual data. Because we separate the random forest, we reunite it.

# %% [markdown]
# <a id="47"></a><br>
# ## 10.2. Prediction Of Random Forest Regression

# %%
print(rfr.predict([[6.6]]))
print(rfr.predict([[11]]))
print(rfr.predict([[110]]))

# %% [markdown]
# <a id="48"></a><br>
# ## 10.3. Visualization For Random Forest Regression

# %%
plt.scatter(x,y,color='red')
plt.plot(x,rfr.predict(x),color='blue')

plt.plot(x,rfr.predict(Z),color='green')
plt.plot(x,rfr.predict(K),color='yellow')
plt.show()

# %% [markdown]
# <a id="49"></a><br>
# ## 10.4. $R^2$  Score Of Random Forest Regression

# %%
print("Random forest R2 score", r2_score(y,rfr.predict(x)))
print("Random forest R2 score", r2_score(y,rfr.predict(K)))
print("Random forest R2 score", r2_score(y,rfr.predict(Z)))

# %% [markdown]
# <a id="50"></a><br>
# # 11. $R^2$ Scores Abstract

# %%
print('-----------------------')
print('Linear R2 degeri')
print("Simple linear regression R2 score:", r2_score(y2,lr.predict(x2)))

print('\nPolynomial R2 degeri')
print("Polynomial regression R2 score:", r2_score(y,linreg2.predict(x_poly2)))

print('\nSVR R2 degeri')
print("SVR poly R2 score:",r2_score(y_scaled,svr_reg2.predict(x_scaled)))

print('\nDecision Tree R2 degeri')
print("Decision tree regression R2 score:", r2_score(y,dtr.predict(x)))

print('\nRandom Forest R2 degeri')
print("Random forest R2 score", r2_score(y,rfr.predict(x)))

print("\n")
