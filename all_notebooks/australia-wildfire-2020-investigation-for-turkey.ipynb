# %% [markdown]
# # HISTORY
#
# #### AUSTRALIA WILDFIRES DATA
#
# **BE CAREFUL OF THE FILE NAMES.**
#
# **IT CONTAINS THE DATA NEEDED TO RESEARCH LATEST FOREST FIRES IN TURKEY.**
#
# **PAY ATTENTION TO THE DATE INTERVALS.**
#
# #### Content
#
# Data on recent forest fires in Turkey, published with permission from NASA Portal.
#
# The data was created based on the hotspots and obtained from the satellite.
#
# 3 SEPARATE SATELLITE DATA:
#
# * MODIS C6.1
# * SUOMI VIIRS C2
# * J1 VIIRS C1
#
# #### GENERAL ATTRIBUTES
#
# * Latitude
# Center of nominal 375 m fire pixel
#
# * Longitude
# Center of nominal 375 m fire pixel
#
# * Bright_ti4
#
# (Brightness temperature I-4)
# VIIRS I-4: channel brightness temperature of the fire pixel measured in Kelvin.
#
# * Scan
#
# (Along Scan pixel size)
# The algorithm produces approximately 375 m pixels at nadir. Scan and track reflect actual pixel size.
#
# * Track
#
# (Along Track pixel size)
# The algorithm produces approximately 375 m pixels at nadir. Scan and track reflect actual pixel size.
#
# * Acq_Date
#
# (Acquisition Date)
# Date of VIIRS acquisition.
#
# * Acq_Time
#
# (Acquisition Time)
# Time of acquisition/overpass of the satellite (in UTC).
#
# * Satellite
#
# N Suomi National Polar-orbiting Partnership (Suomi NPP)
#
# * Confidence
#
# This value is based on a collection of intermediate algorithm quantities used in the detection process. It is intended to help users gauge the quality of individual hotspot/fire pixels. Confidence values are set to low, nominal and high. Low confidence daytime fire pixels are typically associated with areas of sun glint and lower relative temperature anomaly (15K) temperature anomaly in either day or nighttime data. High confidence fire pixels are associated with day or nighttime saturated pixels.
#
# #### Please note:
#
# Low confidence nighttime pixels occur only over the geographic area extending from 11° E to 110° W and 7° N to 55° S. This area describes the region of influence of the South Atlantic Magnetic Anomaly which can cause spurious brightness temperatures in the mid-infrared channel I4 leading to potential false positive alarms. These have been removed from the NRT data distributed by FIRMS.
#
# * Version
#
# Version identifies the collection (e.g. VIIRS Collection 1) and source of data processing: Near Real-Time (NRT suffix added to collection) or Standard Processing (collection only).
# "1.0NRT" - Collection 1 NRT processing.
#
# "1.0" - Collection 1 Standard processing.
#
# * Bright_ti5
#
# (Brightness temperature I-5)
# I-5 Channel brightness temperature of the fire pixel measured in Kelvin.
#
# * FRP
#
# (Fire Radiative Power)
#
# FRP depicts the pixel-integrated fire radiative power in MW (megawatts). Given the unique spatial and spectral resolution of the data, the VIIRS 375 m fire detection algorithm was customized and tuned in order to optimize its response over small fires while balancing the occurrence of false alarms. Frequent saturation of the mid-infrared I4 channel (3.55-3.93 µm) driving the detection of active fires requires additional tests and procedures to avoid pixel classification errors. As a result, sub-pixel fire characterization (e.g., fire radiative power [FRP] retrieval) is only viable across small and/or low-intensity fires. Systematic FRP retrievals are based on a hybrid approach combining 375 and 750 m data. In fact, starting in 2015 the algorithm incorporated additional VIIRS channel M13 (3.973-4.128 µm) 750 m data in both aggregated and unaggregated format.
#
# Satellite measurements of fire radiative power (FRP) are increasingly used to estimate the contribution of biomass burning to local and global carbon budgets. Without an associated uncertainty, however, FRP-based biomass burning estimates cannot be confidently compared across space and time, or against estimates derived from alternative methodologies. Differences in the per-pixel FRP measured near-simultaneously in consecutive MODIS scans are approximately normally distributed with a standard deviation (ση) of 26.6%. Simulations demonstrate that this uncertainty decreases to less than ~5% (at ±1 ση) for aggregations larger than ~50 MODIS active fire pixels. Although FRP uncertainties limit the confidence in flux estimates on a per-pixel basis, the sensitivity of biomass burning estimates to FRP uncertainties can be mitigated by conducting inventories at coarser spatiotemporal resolutions.
#
# http://cedadocs.ceda.ac.uk/770/1/SEVIRI_FRP_documentdesc.pdf
#
# * Type
#
# (Inferred hot spot type)
#
# 0 = presumed vegetation fire
#
# 1 = active volcano
#
# 2 = other static land source
#
# 3 = offshore detection (includes all detections over water)
#
# * DayNight
#
# (Day or Night)
#
# D= Daytime fire
#
# N= Nighttime fire

# %% [markdown]
# #### WHAT IS LONGITUDE AND LATITUDE
#
# Latitude and longitude are a system of lines used to describe the location of any place on Earth. Lines of latitude run in an east-west direction across Earth. Lines of longitude run in a north-south direction. Although these are only imaginary lines, they appear on maps and globes as if they actually existed.
#
# #### ACQUISITION TIME EXAMPLE
#
# Based on UTC time. You have to think in decimal.

# %% [markdown]
# * The 2019–20 Australian bushfire season, colloquially known as Black Summer, was a period of unusually intense bushfires in many parts of Australia. In June 2019, the Queensland Fire and Emergency Service acting director warned of the potential for an early start to the bushfire season which normally starts in August. The first major bushfires began even before the official arrival of spring in June and then new out-of-control fires sprung up at the beginning of September 2019.
#
# * The fire was extinguished on 10 February 2020, having burnt approximately 191,000 hectares (471,971 acres) over 79 days

# %% [markdown]
# # PACKAGES AND LIBRARIES

# %%
# !pip install dataprep by

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from warnings import filterwarnings
from datetime import datetime
from mpl_toolkits.mplot3d import Axes3D
import statsmodels.api as sm
import missingno as msno
import statsmodels.stats.api as sms
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.neighbors import LocalOutlierFactor
from scipy.stats import levene
from scipy.stats import shapiro
from scipy.stats.stats import pearsonr
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from sklearn.preprocessing import scale
from sklearn.model_selection import ShuffleSplit, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import model_selection
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import BaggingRegressor
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LinearRegression
from sklearn.cross_decomposition import PLSRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import LassoCV
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import ElasticNetCV
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
import xgboost as xgb
from xgboost import XGBRegressor, XGBClassifier
from lightgbm import LGBMRegressor, LGBMClassifier
from catboost import CatBoostRegressor, CatBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn import tree
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, roc_auc_score, roc_curve
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans
from sklearn.pipeline import Pipeline
from sklearn.manifold import Isomap,TSNE
from sklearn.feature_selection import mutual_info_classif
from tqdm.notebook import tqdm
from scipy.stats import ttest_ind
import plotly.offline as pyo
import scipy.stats as stats
import pymc3 as pm
from dataprep.eda import *
from dataprep.eda import plot
from dataprep.eda import plot_diff
from dataprep.eda import plot_correlation
from dataprep.eda import plot_missing
import plotly.figure_factory as ff
from collections import Counter
import pandas_profiling as pp
from mpl_toolkits.basemap import Basemap
import datetime as dt
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import folium
from folium import plugins

# %%
filterwarnings("ignore", category=DeprecationWarning) 
filterwarnings("ignore", category=FutureWarning) 
filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# # INVESTIGATION BASED ON AUSTRALIA

# %% [markdown]
# ### READING

# %%
AUST_2017 = pd.read_csv("../input/australia-and-investigative-special-wildfires-data/INVESTIGATION SPECIAL COORDINATES/AUSTRALIA/modis_2017_Australia.csv")
AUST_2018 = pd.read_csv("../input/australia-and-investigative-special-wildfires-data/INVESTIGATION SPECIAL COORDINATES/AUSTRALIA/modis_2018_Australia.csv")
AUST_2019 = pd.read_csv("../input/australia-and-investigative-special-wildfires-data/INVESTIGATION SPECIAL COORDINATES/AUSTRALIA/modis_2019_Australia.csv")
AUST_2020 = pd.read_csv("../input/australia-and-investigative-special-wildfires-data/INVESTIGATION SPECIAL COORDINATES/AUSTRALIA/modis_2020_Australia.csv")

# %%
AUST_2017

# %%
AUST_2018

# %%
AUST_2019

# %%
AUST_2020

# %% [markdown]
# ### GENERAL INFORMATIONS

# %%
AUST_ALL = [AUST_2017,AUST_2018,AUST_2019,AUST_2020]
FOUR_YEARS = ["2017","2018","2019","2020"]

# %%
for aust_data,years in zip(AUST_ALL,FOUR_YEARS):
    print("DESCRIBE {0}:\n {1} ".format(years, aust_data[["frp","brightness","bright_t31"]].describe().T))
    print("-------"*20)

# %% [markdown]
# #### **ATTENTION**
# * MEAN OF FRP 2017: 73.042409
# * MEAN OF FRP 2018: 66.583566
# * MEAN OF FRP 2019: 76.205352
# * MEAN OF FRP 2020: 62.392569
#
#
#
#
# * MAX OF FRP 2017: 7401.1
# * MAX OF FRP 2018: 7395.4
# * MAX OF FRP 2019: 7454.5
# * MAX OF FRP 2020: 11164.1

# %% [markdown]
# #### **ATTENTION**
# * LOOK CAREFULLY FOR THE JUMP BETWEEN 2019 AND 2020.
# * WHILE THE AVERAGE DECREASES, THERE IS A HIGH INCREASE IN THE MAXIMUM VALUE.
# * THIS SITUATION INDICATES THAT LARGE FRP VALUES ARE ACCURATING IN SOME LOCALS.

# %% [markdown]
# ### TERRA CHECKING

# %%
TERRA_2017 = AUST_2017[AUST_2017["satellite"] == "Terra"]
TERRA_2018 = AUST_2018[AUST_2018["satellite"] == "Terra"]
TERRA_2019 = AUST_2019[AUST_2019["satellite"] == "Terra"]
TERRA_2020 = AUST_2020[AUST_2020["satellite"] == "Terra"]

# %%
print("DESCRIBE 2017:\n")
print(TERRA_2017[["frp","brightness","bright_t31"]].describe().T)

# %%
print("DESCRIBE 2018:\n")
print(TERRA_2018[["frp","brightness","bright_t31"]].describe().T)

# %%
print("DESCRIBE 2019:\n")
print(TERRA_2019[["frp","brightness","bright_t31"]].describe().T)

# %%
print("DESCRIBE 2020:\n")
print(TERRA_2020[["frp","brightness","bright_t31"]].describe().T)

# %% [markdown]
# #### **ATTENTION**
# * MAX FRP VALUE IS IN TERRA AREA TYPE FOR 2020

# %%
print("2017 MAX FRP:\n")
print(TERRA_2017[TERRA_2017["frp"] == TERRA_2017["frp"].max()])
print("\n")
print("2018 MAX FRP:\n")
print(TERRA_2018[TERRA_2018["frp"] == TERRA_2018["frp"].max()])
print("\n")
print("2019 MAX FRP:\n")
print(TERRA_2019[TERRA_2019["frp"] == TERRA_2019["frp"].max()])
print("\n")
print("2020 MAX FRP:\n")
print(TERRA_2020[TERRA_2020["frp"] == TERRA_2020["frp"].max()])

# %% [markdown]
# #### **ATTENTION**
# * THE HIGHEST 2017 FRP VALUE LATITUDE: -23.1649
# * THE HIGHEST 2017 FRP VALUE LONGITUDE: 114.8384
# * THE HIGHEST 2017 FRP VALUE DATE: 2017-12-25
#
#
#
# * THE HIGHEST 2018 FRP VALUE LATITUDE: -33.2769
# * THE HIGHEST 2018 FRP VALUE LONGITUDE: 123.7772
# * THE HIGHEST 2018 FRP VALUE DATE: 2018-01-04
#
#
#
#
# * THE HIGHEST 2019 FRP VALUE LATITUDE: -30.4163
# * THE HIGHEST 2019 FRP VALUE LONGITUDE: 152.2871
# * THE HIGHEST 2019 FRP VALUE DATE: 2019-11-16
#
#
#
#
# * THE HIGHEST 2020 FRP VALUE LATITUDE: -32.8923
# * THE HIGHEST 2020 FRP VALUE LONGITUDE: 124.0954
# * THE HIGHEST 2020 FRP VALUE DATE: 2020-01-08

# %%
MAP_FUNCTION = folium.Map(location=[-25.27,133.77],
                  tiles='openstreetmap',
                  zoom_start=4.4)

folium.CircleMarker(
    location=[-23.1649,114.8384],
    radius=20,
    popup="<b>MAXIMUM FRP (FOR 2017)<b>",
    tooltip="Click me",
    color='#FF0000',
    fill=True,
    fill_color='#FF0000',
).add_to(MAP_FUNCTION)

folium.CircleMarker(
    location=[-33.2769,123.7772],
    radius=20,
    popup="<b>MAXIMUM FRP (FOR 2018)<b>",
    tooltip="Click me",
    color='#AFFF33',
    fill=True,
    fill_color='#AFFF33',
).add_to(MAP_FUNCTION)

folium.CircleMarker(
    location=[-30.4163,152.2871],
    radius=20,
    popup="<b>MAXIMUM FRP (FOR 2019)<b>",
    tooltip="Click me",
    color='#2F4F4F',
    fill=True,
    fill_color='#2F4F4F',
).add_to(MAP_FUNCTION)

folium.CircleMarker(
    location=[-32.8923,124.0954],
    radius=20,
    popup="<b>MAXIMUM FRP (FOR 2020)<b>",
    tooltip="Click me",
    color='#FF3333',
    fill=True,
    fill_color='#FF3333',
).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %%
BRIGHT_2017 = TERRA_2017[TERRA_2017["brightness"] == TERRA_2017["brightness"].max()]
BRIGHT_2018 = TERRA_2018[TERRA_2018["brightness"] == TERRA_2018["brightness"].max()]
BRIGHT_2019 = TERRA_2019[TERRA_2019["brightness"] == TERRA_2019["brightness"].max()]
BRIGHT_2020 = TERRA_2020[TERRA_2020["brightness"] == TERRA_2020["brightness"].max()]

# %%
LAT_LONG_2020 = TERRA_2017[["latitude","longitude"]]

LAT_LONG_2020.latitude = LAT_LONG_2020.latitude.astype(float)
LAT_LONG_2020.longitude = LAT_LONG_2020.longitude.astype(float)

HEAT_2020 = list(zip(LAT_LONG_2020.latitude,LAT_LONG_2020.longitude))



LAT_LONG_2019 = TERRA_2018[["latitude","longitude"]]

LAT_LONG_2019.latitude = LAT_LONG_2019.latitude.astype(float)
LAT_LONG_2019.longitude = LAT_LONG_2019.longitude.astype(float)

HEAT_2019 = list(zip(LAT_LONG_2019.latitude,LAT_LONG_2019.longitude))



LAT_LONG_2018 = TERRA_2019[["latitude","longitude"]]

LAT_LONG_2018.latitude = LAT_LONG_2018.latitude.astype(float)
LAT_LONG_2018.longitude = LAT_LONG_2018.longitude.astype(float)

HEAT_2018 = list(zip(LAT_LONG_2018.latitude,LAT_LONG_2018.longitude))



LAT_LONG_2017 = TERRA_2020[["latitude","longitude"]]

LAT_LONG_2017.latitude = LAT_LONG_2017.latitude.astype(float)
LAT_LONG_2017.longitude = LAT_LONG_2017.longitude.astype(float)

HEAT_2017 = list(zip(LAT_LONG_2017.latitude,LAT_LONG_2017.longitude))

# %%
MAP_FUNCTION = folium.Map(location=[-25.27,133.77],
                  tiles='Stamen Terrain',
                  zoom_start=5.0)

plugins.MarkerCluster(LAT_LONG_2020[:500]).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# ![](https://ichef.bbci.co.uk/news/1024/branded_news/D36A/production/_110422145_firemapanthony.jpg)

# %%
MAP_FUNCTION = folium.Map(location=[-25.27,133.77],
                  tiles='Stamen Terrain',
                  zoom_start=4.8)

plugins.HeatMap(HEAT_2020[:700]).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### **ATTENTION**
# * FIRE STARTED CLOSE AND GROWTH IN THE SECTIONS WITH THE HIGHEST FRP VALUE
# * 2017-2018-2019 MAP VALUES ARE ALSO SIMILAR

# %% [markdown]
# ### SPECIFIC INFORMATIONS

# %%
TERRA_2017.sort_values(by=["acq_date"],ascending=True,inplace=True)
TERRA_2018.sort_values(by=["acq_date"],ascending=True,inplace=True)
TERRA_2019.sort_values(by=["acq_date"],ascending=True,inplace=True)
TERRA_2020.sort_values(by=["acq_date"],ascending=True,inplace=True)

TERRA_2017 = TERRA_2017.reset_index(drop=True)
TERRA_2018 = TERRA_2018.reset_index(drop=True)
TERRA_2019 = TERRA_2019.reset_index(drop=True)
TERRA_2020 = TERRA_2020.reset_index(drop=True)

# %% [markdown]
# #### **ATTENTION**
# * DATE FROM JANUARY 1 TO DECEMBER 12

# %% [markdown]
# ### FRP

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(TERRA_2017["acq_date"],TERRA_2017["frp"],color=('red'))
plt.title("FRP-DATE")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(TERRA_2018["acq_date"],TERRA_2018["frp"],color=('red'))
plt.title("FRP-DATE")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(TERRA_2019["acq_date"],TERRA_2019["frp"],color=('red'))
plt.title("FRP-DATE")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(TERRA_2020["acq_date"],TERRA_2020["frp"],color=('red'))
plt.title("FRP-DATE")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### BRIGHTNESS

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(pd.DatetimeIndex(TERRA_2017["acq_date"]),TERRA_2017["brightness"],color=('green'))
plt.title("BRIGHTNESS-DATE")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(pd.DatetimeIndex(TERRA_2018["acq_date"]),TERRA_2018["brightness"],color=('green'))
plt.title("BRIGHTNESS-DATE")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(pd.DatetimeIndex(TERRA_2019["acq_date"]),TERRA_2019["brightness"],color=('green'))
plt.title("BRIGHTNESS-DATE")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(pd.DatetimeIndex(TERRA_2020["acq_date"]),TERRA_2020["brightness"],color=('green'))
plt.title("BRIGHTNESS-DATE")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### FRP-BRIGHTNESS COMPARING

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(TERRA_2017["brightness"],TERRA_2017["frp"],color=('black'))
plt.title("BRIGHTNESS-FRP")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(TERRA_2018["brightness"],TERRA_2018["frp"],color=('black'))
plt.title("BRIGHTNESS-FRP")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(TERRA_2019["brightness"],TERRA_2019["frp"],color=('black'))
plt.title("BRIGHTNESS-FRP")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(TERRA_2020["brightness"],TERRA_2020["frp"],color=('black'))
plt.title("BRIGHTNESS-FRP")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **ATTENTION**
# * THE DIFFERENCE BETWEEN THE TWO VALUES IN THE YEAR THE FIRE HAS BEEN INCREASED.

# %% [markdown]
# ### BASED ON DECEMBER 28,2020

# %% [markdown]
# #### **ATTENTION**
# * DON'T FORGET CONTINENTAL SEASONAL DIFFERENCES. WE ARE TRYING TO EQUAL THE SAME TIME INTERVALS.

# %%
DEC_28_2017 = TERRA_2017[TERRA_2017["acq_date"] == "2017-12-28"]
DEC_28_2017.sort_values(by=["acq_time"],ascending=True,inplace=True)
DEC_28_2017 = DEC_28_2017.reset_index(drop=True)

DEC_28_2018 = TERRA_2018[TERRA_2018["acq_date"] == "2018-12-28"]
DEC_28_2018.sort_values(by=["acq_time"],ascending=True,inplace=True)
DEC_28_2018 = DEC_28_2018.reset_index(drop=True)

DEC_28_2019 = TERRA_2019[TERRA_2019["acq_date"] == "2019-12-28"]
DEC_28_2019.sort_values(by=["acq_time"],ascending=True,inplace=True)
DEC_28_2019 = DEC_28_2019.reset_index(drop=True)

DEC_28_2020 = TERRA_2020[TERRA_2020["acq_date"] == "2020-12-28"]
DEC_28_2020.sort_values(by=["acq_time"],ascending=True,inplace=True)
DEC_28_2020 = DEC_28_2020.reset_index(drop=True)

# %% [markdown]
# #### **ATTENTION**
# * FROM AM TO PM

# %%
print(DEC_28_2017[DEC_28_2017["frp"] == DEC_28_2017["frp"].max()])

# %%
print(DEC_28_2018[DEC_28_2018["frp"] == DEC_28_2018["frp"].max()])

# %%
print(DEC_28_2019[DEC_28_2019["frp"] == DEC_28_2019["frp"].max()])

# %%
print(DEC_28_2020[DEC_28_2020["frp"] == DEC_28_2020["frp"].max()])

# %% [markdown]
# #### **ATTENTION**
# * OTHER HOURS EXCEPT THE HOUR OF THE YEAR OF FIRE 2020, CLOSE TO EACH OTHER

# %% [markdown]
# ### TIME-FRP

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(DEC_28_2017["acq_time"],DEC_28_2017["frp"],color=('blue'))
plt.title("TIME-FRP")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(DEC_28_2018["acq_time"],DEC_28_2018["frp"],color=('blue'))
plt.title("TIME-FRP")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(DEC_28_2019["acq_time"],DEC_28_2019["frp"],color=('blue'))
plt.title("TIME-FRP")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(DEC_28_2020["acq_time"],DEC_28_2020["frp"],color=('blue'))
plt.title("TIME-FRP")
plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **ATTENTION**
# * JUST LIKE TURKEY, THERE IS A STEM RISE HERE

# %% [markdown]
# ### TIME-BRIGHTNESS

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(DEC_28_2017["acq_time"],DEC_28_2017["brightness"],color=('blue'))
plt.title("TIME-BRIGHTNESS")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(DEC_28_2018["acq_time"],DEC_28_2018["brightness"],color=('blue'))
plt.title("TIME-BRIGHTNESS")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(DEC_28_2019["acq_time"],DEC_28_2019["brightness"],color=('blue'))
plt.title("TIME-BRIGHTNESS")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(DEC_28_2020["acq_time"],DEC_28_2020["brightness"],color=('blue'))
plt.title("TIME-BRIGHTNESS")
plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### BASED ON OCTOBER 10, 2020

# %% [markdown]
# #### **ATTENTION**
# * This was the longest burning fire this fire season up to 14 December 2020 as it had been burning since October, over two months, and as of that date, more than half the island had been "blackened" by fire.

# %% [markdown]
# * WE WILL CHECK ONLY FRP FOR COMPARING

# %%
OCT_10_2017 = TERRA_2017[TERRA_2017["acq_date"] == "2017-10-10"]
OCT_10_2017.sort_values(by=["acq_time"],ascending=True,inplace=True)
OCT_10_2017 = OCT_10_2017.reset_index(drop=True)

OCT_10_2018 = TERRA_2018[TERRA_2018["acq_date"] == "2018-10-10"]
OCT_10_2018.sort_values(by=["acq_time"],ascending=True,inplace=True)
OCT_10_2018 = OCT_10_2018.reset_index(drop=True)

OCT_10_2019 = TERRA_2019[TERRA_2019["acq_date"] == "2019-10-10"]
OCT_10_2019.sort_values(by=["acq_time"],ascending=True,inplace=True)
OCT_10_2019 = OCT_10_2019.reset_index(drop=True)

OCT_10_2020 = TERRA_2020[TERRA_2020["acq_date"] == "2020-10-10"]
OCT_10_2020.sort_values(by=["acq_time"],ascending=True,inplace=True)
OCT_10_2020 = OCT_10_2020.reset_index(drop=True)

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(OCT_10_2017["acq_time"],OCT_10_2017["frp"],color=('purple'))
plt.title("TIME-FRP")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(OCT_10_2018["acq_time"],OCT_10_2018["frp"],color=('purple'))
plt.title("TIME-FRP")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(OCT_10_2019["acq_time"],OCT_10_2019["frp"],color=('purple'))
plt.title("TIME-FRP")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(OCT_10_2020["acq_time"],OCT_10_2020["frp"],color=('purple'))
plt.title("TIME-FRP")
plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### BASED ON DECEMBER 1, 2020

# %% [markdown]
# * ONE OF THE FIRE HAPPENED DATES

# %%
DEC_01_2017 = TERRA_2017[TERRA_2017["acq_date"] == "2017-12-01"]
DEC_28_2017.sort_values(by=["acq_time"],ascending=True,inplace=True)
DEC_28_2017 = DEC_28_2017.reset_index(drop=True)

DEC_01_2018 = TERRA_2018[TERRA_2018["acq_date"] == "2018-12-01"]
DEC_01_2018.sort_values(by=["acq_time"],ascending=True,inplace=True)
DEC_01_2018 = DEC_01_2018.reset_index(drop=True)

DEC_01_2019 = TERRA_2019[TERRA_2019["acq_date"] == "2019-12-01"]
DEC_01_2019.sort_values(by=["acq_time"],ascending=True,inplace=True)
DEC_01_2019 = DEC_01_2019.reset_index(drop=True)

DEC_01_2020 = TERRA_2020[TERRA_2020["acq_date"] == "2020-12-01"]
DEC_01_2020.sort_values(by=["acq_time"],ascending=True,inplace=True)
DEC_01_2020 = DEC_01_2020.reset_index(drop=True)

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(DEC_01_2017["acq_time"],DEC_01_2017["frp"],color=('red'))
plt.title("TIME-FRP")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(DEC_01_2018["acq_time"],DEC_01_2018["frp"],color=('red'))
plt.title("TIME-FRP")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(DEC_01_2019["acq_time"],DEC_01_2019["frp"],color=('red'))
plt.title("TIME-FRP")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(DEC_01_2020["acq_time"],DEC_01_2020["frp"],color=('red'))
plt.title("TIME-FRP")
plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### DECEMBER 28, OCTOBER 10, DECEMBER 01

# %%
LAT_LONG_DEC_28 = DEC_28_2020[["latitude","longitude"]]

LAT_LONG_DEC_28.latitude = LAT_LONG_DEC_28.latitude.astype(float)
LAT_LONG_DEC_28.longitude = LAT_LONG_DEC_28.longitude.astype(float)

HEAT_DEC_28 = list(zip(LAT_LONG_DEC_28.latitude,LAT_LONG_DEC_28.longitude))



LAT_LONG_OCT_10 = OCT_10_2020[["latitude","longitude"]]

LAT_LONG_OCT_10.latitude = LAT_LONG_OCT_10.latitude.astype(float)
LAT_LONG_OCT_10.longitude = LAT_LONG_OCT_10.longitude.astype(float)

HEAT_OCT_10 = list(zip(LAT_LONG_OCT_10.latitude,LAT_LONG_OCT_10.longitude))



LAT_LONG_DEC_01 = DEC_01_2020[["latitude","longitude"]]

LAT_LONG_DEC_01.latitude = LAT_LONG_DEC_01.latitude.astype(float)
LAT_LONG_DEC_01.longitude = LAT_LONG_DEC_01.longitude.astype(float)

HEAT_DEC_01 = list(zip(LAT_LONG_DEC_01.latitude,LAT_LONG_DEC_01.longitude))

# %%
plugins.MarkerCluster(LAT_LONG_OCT_10).add_to(MAP_FUNCTION)
plugins.MarkerCluster(LAT_LONG_DEC_01).add_to(MAP_FUNCTION)

# %%
MAP_FUNCTION = folium.Map(location=[-25.27,133.77],
                  tiles='Stamen Terrain',
                  zoom_start=5.0)

plugins.MarkerCluster(LAT_LONG_DEC_28).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %%
MAP_FUNCTION = folium.Map(location=[-25.27,133.77],
                  tiles='Stamen Terrain',
                  zoom_start=5.0)

plugins.MarkerCluster(LAT_LONG_OCT_10).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %%
MAP_FUNCTION = folium.Map(location=[-25.27,133.77],
                  tiles='Stamen Terrain',
                  zoom_start=5.0)

plugins.MarkerCluster(LAT_LONG_DEC_01).add_to(MAP_FUNCTION)

MAP_FUNCTION
