# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from plotly.offline import iplot
import cufflinks as cf
import plotly as py
import plotly.tools as tls
import matplotlib.pyplot as plt
import seaborn as sns

# %%
book_data = pd.read_csv('/kaggle/input/amazon-top-50-bestselling-books-2009-2019/bestsellers with categories.csv')
book_data

# %%
book_data.info()

# %%
book_data.shape

# %%
book_type = book_data['Genre'].value_counts()
book_type

# %%
py.offline.init_notebook_mode(connected = True)

# %%
cf.go_offline()

# %%
book_type.iplot(kind = 'bar')

# %%
book_data.head(20)

# %%
df = book_data.drop('Year',axis = 1,inplace = True)

# %%
book_data.shape

# %%
row = book_data.shape[0]
row

# %%
book_data.sort_values('Reviews',ascending = False)

# %%
# Most expensive book by price is Non-Fiction
book_data.sort_values('Price',ascending = False)

# %%
# Average price and rating of book
book_data[['Price','User Rating']].mean()

# %%
dupl_data = book_data.copy()

# %%
rep_genre = {'Genre':{'Non Fiction':0,'Fiction':1}}

# %%
dupl_data.replace(rep_genre,inplace = True)

# %%
dupl_data

# %%
dupl_data[['Reviews']].iplot(kind = 'box')

# %%
dupl_data[['Price']].iplot(kind = 'histogram',color = 'blue')
dupl_data[['Reviews']].iplot(kind = 'histogram',color = 'green')
dupl_data[['User Rating']].iplot(kind = 'histogram',color = 'orange')

# %%
dupl_data[['Price']].iplot(kind = 'box')
dupl_data[['Reviews']].iplot(kind = 'box')
dupl_data[['User Rating']].iplot(kind = 'box')

# %%
dupl_data[['Price']].mean()

# %%
dupl_data[['Reviews']].mean()

# %% [markdown]
# In the above data since the median is greater than the mean value we can say that the price distribution is right skewed with few outliers present at the higher end of the graph with respect to price, also the reviews distribution is right skewed with fewer outliers present in the higher end of the graph.
#
# The data is left skewed with respect to the User Rating since median is less than the mean value i.e 4.7 > 4.6 with outliers that can be ignored when taking the data to create a model

# %%
df = book_data[['Author','Reviews','Genre','User Rating']]

# %%
df.groupby(['Author','Genre','User Rating']).max().iplot(kind = 'bar',bins = 50,orientation = 'h')

# %% [markdown]
# Seeing the number of reviews and rating people loved reading Delia Owens fiction with rating of 4.8 which happens to be greater than the average rating and review count of more than 80000.

# %%
df = book_data[['Name','Author','Reviews','Genre','User Rating']]
df.groupby(['Name','Author','Genre','User Rating']).max().iplot(kind = 'line',bins = 50,orientation = 'h')

# %%
sns.pairplot(book_data)

# %% [markdown]
# Seeing at the above pairplot we can say that there is no or very less correlation that exist in the data between different variables.
# People mostly pay between 0 to 50 rupees for books that have a User Rating greater than 4.5. and no of reviews exist between 20000.
