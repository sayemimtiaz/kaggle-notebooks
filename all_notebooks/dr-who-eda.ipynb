# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

df_scripts = pd.read_csv('/kaggle/input/doctor-who/all-scripts.csv')
df_episodes = pd.read_csv('/kaggle/input/doctor-who/all-detailsepisodes.csv')

# %%
df_scripts

# %%
df_episodes

# %%
df_scripts['weeping angel'] = df_scripts['text'].apply(lambda x: True if 'weeping angel' in str(x).lower() else False)

# %%
df_scripts[df_scripts['weeping angel']==True].drop('idx',axis=1)
