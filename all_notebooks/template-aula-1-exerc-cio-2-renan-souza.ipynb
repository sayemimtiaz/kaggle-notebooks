# %% [markdown]
# <div align="center">
#  <img src="https://raw.githubusercontent.com/matheusmota/dataviz2018/master/resources/images/logo_facens_pos.png" width="150px">
#  <h1> Dataviz - Data Science Specialization Program - FACENS</h1>
# </div>
# <br><br>
# # Aula1 | Exercício 2
# (valendo nota)
#
# * **Data de entrega:** 01/06/2019
# * **Professor:**  Matheus Mota
# * **Aluno:** Renan Souza
# * **RA:** 070487

# %% [markdown]
# ## Questão 1
# **Enunciado:**  Este notebook está associado ao *Kaggle Dataset* chamado "Aula1 | Exercício 2". Este *Kaggle Dataset* possui dois arquivos em formato CSV (anv.csv e BR_eleitorado_2016_municipio ). Escolha um dos datasets disponíveis e já conhecidos, a seu critério. Uma vez definido o csv, escolha no mínimo 7 e no máximo 12 variáveis (colunas) que você avalia como sendo relevantes. Para cada uma das suas variáveis escolhidas, forneça:
#
#
# ### Questão 1 - Item A - Classificação das variáveis
#
# Classifique todas as variáveis escolhidas, e construa um dataframe com sua resposta.
# Exemplo:

# %%
import pandas as pd
import numpy as np
resposta = [["idade", "Quantitativa Discreta"],["sexo","Qualitativa Nominal"]] #variáveis relacionadas a tempo são contínuas, mas podem ser discretas pois não há perdas -- (discretização)
resposta = pd.DataFrame(resposta, columns=["Variavel", "Classificação"])
resposta
# Out:
#   Variavel          Classificação
# 0    idade  Quantitativa Discreta
# 1     sexo    Qualitativa Nominal

# %%
df = pd.read_csv('../input/anv.csv', delimiter=',')
df.head(5)
# Out:
#    codigo_ocorrencia          ...          aeronave_dia_extracao
# 0    201106142171203          ...                     2018-07-09
# 1    200804256669287          ...                     2018-07-09
# 2    201205209591320          ...                     2018-07-09
# 3    201012015549851          ...                     2018-07-09
# 4    201708190325167          ...                     2018-07-09
#
# [5 rows x 25 columns]

# %%
resposta = [["aeronave_operador_categoria","Qualitativa Nominal"],
            ["aeronave_tipo_veiculo","Qualitativa Nominal"],
            ["aeronave_motor_quantidade","Qualitativa Nominal"],
            ["aeronave_assentos","Quantitativa Discreta"],
            ["aeronave_pais_fabricante","Qualitativa Nominal"],
            ["aeronave_fase_operacao","Qualitativa Nominal"],
            ["total_fatalidades","Quantitativa Discreta"]] #variáveis relacionadas a tempo são contínuas, mas podem ser discretas pois não há perdas -- (discretização)
resposta = pd.DataFrame(resposta, columns=["Variavel", "Classificação"])
resposta
# Out:
#                       Variavel          Classificação
# 0  aeronave_operador_categoria    Qualitativa Nominal
# 1        aeronave_tipo_veiculo    Qualitativa Nominal
# 2    aeronave_motor_quantidade    Qualitativa Nominal
# 3            aeronave_assentos  Quantitativa Discreta
# 4     aeronave_pais_fabricante    Qualitativa Nominal
# 5       aeronave_fase_operacao    Qualitativa Nominal
# 6            total_fatalidades  Quantitativa Discreta

# %% [markdown]
# ### Questão 1 - Item B - Tabela de frequência
#
# Construa uma tabela de frequência para cada uma das **variáveis qualitativas** que você escolheu (caso não tenha escolhido nenhuma, deixe esta questão em branco). Uma dica: a função *value_counts()* do Pandas pode ser muito útil. =)

# %%
df[resposta["Variavel"]]
# Out:
#      aeronave_operador_categoria        ...        total_fatalidades
# 0                      AEROCLUBE        ...                        0
# 1                      AEROCLUBE        ...                        0
# 2           OPERADOR DE AERONAVE        ...                        0
# 3           OPERADOR DE AERONAVE        ...                        0
# 4            OPERADOR PARTICULAR        ...                        0
# 5                      AEROCLUBE        ...                        0
# 6                      AEROCLUBE        ...                        0
# 7                      AEROCLUBE        ...                        0
# 8           OPERADOR DE AERONAVE        ...                        0
# 9           OPERADOR DE AERONAVE        ...                        0
# 10          OPERADOR DE AERONAVE        ...                        0
# 11          OPERADOR DE AERONAVE        ...                        0
# 12          OPERADOR DE AERONAVE        ...                        0
# 13                 ÓRGÃO PÚBLICO        ...                        0
# 14           OPERADOR PARTICULAR        ...                        0
# 15          OPERADOR DE AERONAVE        ...                        0
# 16          OPERADOR DE AERONAVE        ...                        0
# 17           OPERADOR PARTICULAR        ...                        0
# 18           OPERADOR PARTICULAR        ...                        0
# 19          OPERADOR DE AERONAVE        ...                        0
# 20                     AEROCLUBE        ...                        0
# 21          OPERADOR DE AERONAVE        ...                        0
# 22          OPERADOR DE AERONAVE        ...                        0
# 23          OPERADOR DE AERONAVE        ...                        0
# 24           OPERADOR PARTICULAR        ...                        0
# 25          OPERADOR DE AERONAVE        ...                        0
# 26                 ÓRGÃO PÚBLICO        ...                        0
# 27                 ÓRGÃO PÚBLICO        ...                        0
# 28           OPERADOR PARTICULAR        ...                        0
# 29          OPERADOR DE AERONAVE        ...                        0
# ...                          ...        ...                      ...
# 5158         OPERADOR PARTICULAR        ...                        0
# 5159         OPERADOR PARTICULAR        ...                        0
# 5160         OPERADOR PARTICULAR        ...                        0
# 5161         OPERADOR PARTICULAR        ...                        0
# 5162         OPERADOR PARTICULAR        ...                        0
# 5163        OPERADOR DE AERONAVE        ...                        0
# 5164        OPERADOR DE AERONAVE        ...                        0
# 5165        OPERADOR DE AERONAVE        ...                        0
# 5166        OPERADOR DE AERONAVE        ...                        0
# 5167      FABRICANTE AERONÁUTICO        ...                        0
# 5168         OPERADOR PARTICULAR        ...                        0
# 5169        OPERADOR DE AERONAVE        ...                        0
# 5170         OPERADOR PARTICULAR        ...                        0
# 5171         OPERADOR PARTICULAR        ...                        0
# 5172         OPERADOR PARTICULAR        ...                        0
# 5173        OPERADOR DE AERONAVE        ...                        0
# 5174         OPERADOR PARTICULAR        ...                        0
# 5175        OPERADOR DE AERONAVE        ...                        0
# 5176         OPERADOR PARTICULAR        ...                        0
# 5177         OPERADOR PARTICULAR        ...                        0
# 5178         OPERADOR PARTICULAR        ...                        0
# 5179        OPERADOR DE AERONAVE        ...                        0
# 5180               ÓRGÃO PÚBLICO        ...                        0
# 5181         OPERADOR PARTICULAR        ...                        0
# 5182         OPERADOR PARTICULAR        ...                        0
# 5183         OPERADOR PARTICULAR        ...                        0
# 5184         OPERADOR PARTICULAR        ...                        1
# 5185         OPERADOR PARTICULAR        ...                        0
# 5186         OPERADOR PARTICULAR        ...                        1
# 5187         OPERADOR PARTICULAR        ...                        0
#
# [5188 rows x 7 columns]

# %%
var1 = pd.DataFrame(df["aeronave_operador_categoria"].value_counts())
var1
# Out:
#                         aeronave_operador_categoria
# OPERADOR DE AERONAVE                           2292
# OPERADOR PARTICULAR                            1958
# AEROCLUBE                                       505
# ESCOLA DE AVIAÇÃO                               245
# ÓRGÃO PÚBLICO                                   176
# FABRICANTE AERONÁUTICO                           12

# %%
var2 = pd.DataFrame(df["aeronave_tipo_veiculo"].value_counts())
var2.index
#arr2 = np.array(var2)
#var2
#arr2
# Out:
# Index(['AVIÃO', 'HELICÓPTERO', 'ULTRALEVE', 'PLANADOR', 'INDETERMINADA',
#        'ANFÍBIO', 'TRIKE', 'DIRIGÍVEL', 'HIDROAVIÃO', 'BALÃO'],
#       dtype='object')

# %%
var3 = pd.DataFrame(df["aeronave_motor_quantidade"].value_counts())
var3
# Out:
#              aeronave_motor_quantidade
# MONOMOTOR                         2632
# BIMOTOR                           2389
# TRIMOTOR                            80
# SEM TRAÇÃO                          46
# ***                                 27
# QUADRIMOTOR                         14

# %%
var4 = pd.DataFrame(df["aeronave_pais_fabricante"].value_counts())
var4
# Out:
#                   aeronave_pais_fabricante
# ESTADOS UNIDOS                        2254
# BRASIL                                1377
# FRANÇA                                 690
# NÃO IDENTIFICADO                       357
# ARGENTINA                              234
# HOLANDA                                 64
# CANADÁ                                  49
# ITÁLIA                                  41
# REPÚBLICA TCHECA                        16
# ALEMANHA                                16
# JAPÃO                                   16
# AUSTRIA                                 16
# SUIÇA                                   16
# INGLATERRA                               6
# POLÔNIA                                  4
# UCRÂNIA                                  1

# %%
var5 = pd.DataFrame(pd.DataFrame(df["aeronave_fase_operacao"].value_counts()))
var5
# Out:
#                                  aeronave_fase_operacao
# POUSO                                               914
# DECOLAGEM                                           795
# CRUZEIRO                                            660
# CORRIDA APÓS POUSO                                  602
# TÁXI                                                439
# SUBIDA                                              359
# APROXIMAÇÃO FINAL                                   234
# DESCIDA                                             192
# ESPECIALIZADA                                       173
# MANOBRA                                             161
# CIRCUITO DE TRÁFEGO                                 125
# OUTRA FASE                                          101
# ESTACIONAMENTO                                       72
# INDETERMINADA                                        71
# NAVEGAÇÃO A BAIXA ALTURA                             60
# OPERAÇÃO DE SOLO                                     46
# ARREMETIDA NO SOLO                                   42
# PARTIDA DO MOTOR                                     30
# ARREMETIDA NO AR                                     25
# PAIRADO                                              20
# RETA FINAL                                           16
# CHEQUE DE MOTOR OU ROTOR                             13
# DECOLAGEM VERTICAL                                    8
# PROCEDIMENTO DE APROXIMAÇÃO IFR                       7
# SAÍDA IFR                                             7
# PUSHBACK                                              6
# ESPERA                                                4
# DESCIDA DE EMERGÊNCIA                                 2
# DESCIDA DESCONTROLADA                                 2
# ***                                                   1
# EMPREGO MILITAR                                       1

# %% [markdown]
# ### Questão 1 - Item C - Representação Gráfica
# Para cada uma das variáveis, produza um ou mais gráficos, usando matplotlib, que descreva seu comportamento / caracteristica. Lembre-se que estes gráficos precisam ser compatíveis com a classificação da variável.

# %% [markdown]
# # Dicas
#
# - Exemplo de acesso aos CSVs disponíveis no dataset
# > df = pd.read_csv('../input/anv.csv', delimiter=',')

# %%
df["aeronave_operador_categoria"].value_counts().plot(kind='bar', title='Categoria Operador - Completo')

# %%
df["aeronave_operador_categoria"].value_counts().head(3).plot(kind='pie', title='Categoria Operador - Top3')

# %%
df["aeronave_tipo_veiculo"].value_counts().plot(kind='bar', title='Tipo de Aeronave - Completo')

# %%
df["aeronave_tipo_veiculo"].value_counts().head(3).plot(kind='pie', title='Tipo de Aeronave - Top 3')

# %%
df["aeronave_motor_quantidade"].value_counts().plot(kind='bar', title='Quantidade Motor')

# %%
df["aeronave_fase_operacao"].value_counts().plot(kind='bar', title='Fase de Operação - Completo')

# %%
df["aeronave_fase_operacao"].value_counts().head(10).plot(kind='bar', title='Fase de Operação - Top 10')

# %%
df["aeronave_pais_fabricante"].value_counts().plot(kind='bar', title='Pais Fabricante - Completo')

# %%
df["aeronave_pais_fabricante"].value_counts().head(5).plot(kind='bar', title='Pais Fabricante - Top 5')
