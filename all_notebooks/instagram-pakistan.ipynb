# %% [markdown]
# # Instagram top 25 Accounts

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="darkgrid")
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../input/pakistans-top-25-instagram-accounts/Top Instragram.csv')
df.head()

# %%
df = df[['Name', 'Category', 'Followers']]
df.head()

# %%
df.shape

# %%
df.columns

# %%
def followers_to_float(x):
    if type(x) == float or type(x) == int:
        return x
    if 'K' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
        return 1000.0
    if 'M' in x:
        if len(x) > 1:
            return float(x.replace('M', '')) * 1000000
        return 1000000.0
    
df['Followers'] = df['Followers'].apply(followers_to_float)
df.head()

# %%
df.isnull().sum()

# %%
df['Category'].unique()

# %%
# Changing category "Singer/Musician" to "Singer"
df.replace("Singer/Musician", "Singer", inplace=True)
df['Category'].unique()

# %%
plt.figure(figsize=(10, 10))
dfCat = df.groupby(by=['Category']).sum()
subs = list(dfCat['Followers'])
names = list(df['Category'].unique())
colors = ['#baff9e', '#ff9c59', '#85dae6', '#e6859c', '#e69585', '#c1e685', '#87e685', '#e685dc', '#edabcc', '#c8e8c5']
plt.pie(subs, labels=names, autopct='%1.1f%%', colors=colors)
plt.show()

# %% [markdown]
# **Actors have consuming 3/4 part of pakistani Instagram**

# %%
plt.figure(figsize=(17, 7))
plt.xticks(rotation=90)
graph = sns.barplot(x='Name', y='Followers', data=df.query('Followers >= 5000000'))

# %% [markdown]
# **Accounts with more than *5Million* Followers**

# %%
plt.figure(figsize=(10, 10))
channels = df.query('Category == "Actor"')
subs = list(channels['Followers'])
names = list(channels['Name'])
colors = ['#baff9e', '#ff9c59', '#85dae6', '#e6859c', '#e69585', '#c1e685', '#87e685', '#e685dc', '#edabcc', '#c8e8c5']
plt.pie(subs, labels=names, autopct='%1.1f%%', colors=colors)
plt.show()

# %% [markdown]
# **Actors in Top 25 Instagram Accounts**

# %%
plt.figure(figsize=(10, 10))
channels = df.query('Category == "Politician"')
subs = list(channels['Followers'])
names = list(channels['Name'])
colors = ['#baff9e', '#ff9c59', '#85dae6', '#e6859c', '#e69585', '#c1e685', '#87e685', '#e685dc', '#edabcc', '#c8e8c5']
plt.pie(subs, labels=names, autopct='%1.1f%%', colors=colors)
plt.show()

# %% [markdown]
# **Seems like only IK made upto top 25 instagramers in Politician Category**

# %%
plt.figure(figsize=(10, 10))
channels = df.query('Category == "Singer"')
subs = list(channels['Followers'])
names = list(channels['Name'])
colors = ['#baff9e', '#ff9c59', '#85dae6', '#e6859c', '#e69585', '#c1e685', '#87e685', '#e685dc', '#edabcc', '#c8e8c5']
plt.pie(subs, labels=names, autopct='%1.1f%%', colors=colors)
plt.show()

# %% [markdown]
# **Singers in Top 25**

# %%
plt.figure(figsize=(10, 10))
channels = df.query('Category == "Fashion brand"')
subs = list(channels['Followers'])
names = list(channels['Name'])
colors = ['#baff9e', '#ff9c59', '#85dae6', '#e6859c', '#e69585', '#c1e685', '#87e685', '#e685dc', '#edabcc', '#c8e8c5']
plt.pie(subs, labels=names, autopct='%1.1f%%', colors=colors)
plt.show()

# %% [markdown]
# **Fashion brand in top 25 Instagram accounts**

# %%
plt.figure(figsize=(10, 10))
channels = df.query('Category == "Media Channel"')
subs = list(channels['Followers'])
names = list(channels['Name'])
colors = ['#baff9e', '#ff9c59', '#85dae6', '#e6859c', '#e69585', '#c1e685', '#87e685', '#e685dc', '#edabcc', '#c8e8c5']
plt.pie(subs, labels=names, autopct='%1.1f%%', colors=colors)
plt.show()

# %% [markdown]
# **Media Channel in top 25**

# %% [markdown]
# ## Thank you for your time. Please upvote the notebook if you like it.
