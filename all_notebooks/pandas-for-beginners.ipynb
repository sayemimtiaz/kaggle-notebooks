# %%
import os
import numpy as np
import seaborn as sns
import pandas as pd 
import matplotlib.pyplot as plt
sns.set(style='dark')

# %% [raw]
# Pandas is a software library written for the Python programming language for data manipulation and analysis.
# In particular, it offers data structures and operations for manipulating numerical tables and time series.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Numpy is a library for Python that supports large, multidimensional arrays and matrices, along with a large collection of high-level mathematical functions to operate on these arrays
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.

# %%
train=pd.read_csv(r'../input/mathcohack/train.csv') # Importing a random dataset

# %%
train.head(3)

# %%
a=pd.Series([1,[2,2],3]) # Generates a pd series

# %%
type(a)

# %%
b=[1]
type(b)

# %%
a.axes # Can check the index of series , and only series

# %%
a.size # Check size of series

# %%
a.values # Displays just the values of pd series

# %%
b=pd.Series([1,2,[3,2,1,3]], index=[3,2,'one']) # Custom index

# %%
b.index # Shows only indexes

# %%
list(b.items()) # Makes a list of pd Series

# %%
3 in a # Check if a particular value is present or not

# %%
print(a)
a[[1,2]] # Show specific part of a Series

# %%
a

# %%
train.Model # Same as train['Model']

# %%
train.iloc[[0,1,2,3]] # Slicing dataframe

# %%
train.iloc[[0,1,2,3],[1]] # Slicing a specific row

# %%
train.iloc[[0,1,2,3],[1,3]] # Slicing a specific rows

# %%
train.iloc[0:10] # Slicing a specific part of df

# %%
train.iloc[0:10,[0,1,2,3]] # Slicing part of df with specific columns

# %%
train.loc[0:2]

# %%
train.iloc[0:2]

# %%
train.loc[0:,'Model']

# %% [raw]
# ~~~ SYNTAX ~~~
# loc[row_label, column_label]
# iloc[row_position, column_position]
# ~~~ END ~~~

# %%
train.loc[0:10,'Manufacturer']

# %%
train.iloc[:,3]

# %% [raw]
# ^ same stuff but look at the syntax

# %%
train.loc[[0,1,4,6],'Model'] # Custom column for custom rows(indexes)

# %%
train.Price[1] # here the [1] shows the row

# %%
train[train['Manufacturer']=='HONDA'].sort_values('Price') # Shows part of train where train's Manufacturer is only HONDA

# %%
train.loc[train['Model']=='FIT'] # Similar as above

# %%
train[(train['Model']=='FIT') | (train['Manufacturer']=='HONDA')] # Multiple conditions

# %%
train[(train['Model']=='FIT') | ~(train['Manufacturer']=='HONDA')] # ~ means NOT

# %%
train.filter(items=['Price','Model']) # a way to get a slice of required columns in a df

# %%
train.filter(regex='type$',axis=1) # a way to filter out df by regex column names

# %%
animals=pd.DataFrame({"Name":['Cat','Dog','Frog','Lion'],"Habitat": ['Domestic','Domestic','Amphibian','Wild'],"Diet":['Cat Food','Dog Food','Insects','Other animals']})

# %%
animals

# %%
animals.append({"Name":'Mosquito'},ignore_index=True)

# %%
animals.append({"Name":'Mosquito',"Size":'TeenyTiny'},ignore_index=True) #Can append new columns and the rest of the df becomes NaN for that Column

# %%
animals.append({"Name":'Mosquito',"Size":'TeenyTiny',"Diet":'Blood',"Habitat":'Everywhere'},ignore_index=True)

# %%
animals=animals.append({"Name":'Mosquito',"Size":'Tiny',"Diet":'Blood',"Habitat":'Everywhere'},ignore_index=True) 
# if df=df.append() is not done then the original df remains the same and the change observed is only temporary

# %%
animals=animals.append({"Name":'Fly',"Size":'TeenyTiny',"Diet":'ANYTHING',"Habitat":'Everywhere'},ignore_index=True)

# %%
animals

# %%
animals

# %%
animals.drop(index=animals[animals['Diet']=='Blood'].index)

# %%
animals

# %%
animals=animals.drop(5)

# %%
animals

# %%
animals.reset_index(inplace=True) # Reset index 
animals

# %%
animals=animals.drop(columns=['index'])

# %%
animals

# %%
animals[['Diet','Name']]

# %% [raw]
# Axis 0 will act on all the ROWS in each COLUMN
# Axis 1 will act on all the COLUMNS in each ROW
# So a mean on axis 0 will be the mean of all the rows in each column, and a mean on axis 1 will be a mean of all the columns in each row.

# %%
animals2=pd.DataFrame({"Name":['Octopus','Sloth','Eagle'],"Habitat":['Oceans','Forests','Tree Tops Maybe'],"Diet":['Mermaids','Leaves and stuff','Angels'],'Face':[':O','Meh','Epic']})

# %%
pd.concat([animals,animals2],ignore_index=True) # Concats df's while giving them new index

# %%
animals2

# %%
animals

# %%
pd.merge(animals,animals2,how='right') # Left and right to have columns of both df's but rows of a specific df

# %%
train['Price'].nlargest(10) # Largest 10 values of a column

# %%
train['Price'].nsmallest(10).sort_values(ascending=False) # Smallest 10 values of a column

# %%
train[16992:16993] # A specific row by slicing

# %%
train.count() # Count of elements in every column

# %%
train.mean()

# %%
train.median()

# %%
train.shape[0]-train["ID"].nunique()

# %%
train.sum() # Sum of each column

# %%
train.min() # Minimum value of each column | Also works for max()

# %%
train.std() # Calculates std dev. of numeric columns | also works for var() i.e variance

# %%
train.sem() #

# %%
animals.groupby(['Diet'])['Name'].value_counts()

# %%
animals

# %%
  train.groupby(['Manufacturer']).sum()['Price'].sort_values() # Groupby 1st categorical then numerical

# %%
train[train['Manufacturer']=='ROLLS-ROYCE']

# %%
train.groupby(['Manufacturer']).median()['Price'].sort_values() # Can do mean, median, etc.

# %%
train.groupby(['Manufacturer'])['Price'].describe() # Describe works like this

# %%
train.groupby(['Model']).agg(['min','mean','median','max']) # This shit is possible too

# %%
train.groupby(['Model']).agg(['min','mean','median','max'])['Airbags'] # Above for a single column

# %%
train.groupby(['Manufacturer']).agg({'Price':'mean','Airbags':'median'}) # OH. THIS IS POSSIBLE TOO !

# %%
def spike(x):
    return x+100
    
train['Frice']=train['Price'].transform(spike) # Defining a function and creating a column by applying that function

# %%
train

# %%
train['Frice']=train['Frice'].transform(lambda x:x+1000) # Lambda for the same

# %%
train[['Prod. year','Airbags']].transform('sqrt') # This is a way

# %%
train['Manufacturer'].apply(len).sort_values(ascending=False) # Apply method

# %%
def increase_frice(x):
    return x*100

# %%
train['Frice']=train['Frice'].apply(increase_frice) # Apply method calls a function

# %%
train

# %%
train['Frice'].apply(lambda x:x*23) # Apply with lambda

# %%
train.apply(np.sum) # Apply with built in np functions

# %%
train.groupby('Manufacturer')['Price'].apply(np.sum) # Sum of prices per manufacturer

# %%
train.groupby('Airbags')['Price'].apply(np.max) # Max price of each unique value

# %%
train.loc[:,['Price','Airbags','Cylinders']].apply(['max','min','median','mean']) # Applying different functions to a select columns

# %% [raw]
# ~~~
# Use map when you want to transform a pandas series elementwise
# Use apply when you want to transform a Series or dataframe row/column wise
# Use applymap to transform a dataframe elementwise
# ~~~

# %%
animals2.applymap(len) # Len of each row element i.e elementwise application of function using applymap()

# %%
animals[['Name']].applymap(str.upper) # Applymap to a single column

# %%
animals['Name'].map({'Cat':'Kat'}) # Individually searches for Cat to turn to Kat

# %%
animals[['Name']].replace({'Cat':'Kat'}) # Replace works better?

# %%
animals['Diet'].replace({'Cat Food':'Human food'},inplace=True) # Inplace=True

# %%
animals

# %%
train

# %%
pd.cut(train['Airbags'],[0,2,4,6,8,10,14],labels=['ek','do','teen','chaar','paanch','che'],retbins=True) # Binning with labels

# %%
animals['Size'].fillna(animals['Size'].mode()) #Fill NA, can be done to the whole df or to a single column

# %%
animals

# %%
animals['Size'].fillna('Tiny')

# %%
train.describe(include=[object,'int64','category']).T # Describing everything

# %%
# Can set index to a aolumn by df.set_index('Column_name',inplace=True)
