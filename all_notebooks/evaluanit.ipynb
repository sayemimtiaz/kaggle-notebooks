# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
magazine=pd.read_csv("/kaggle/input/magazine-covers/archive.csv")
magazine.head()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(18,10))
sns.countplot(data=magazine,x="Country")

# %% [markdown]
# As we see United States is dominated this Award. What about after 2000?

# %%
mag2000s=magazine[magazine["Year"]>=2000]
sns.countplot(data=mag2000s,x="Country")

# %% [markdown]
# United States still domainating. But have İnteresting countries also. Vatican city????

# %%
mag2000s[mag2000s["Country"]=="Vatican City"]

# %% [markdown]
# Pope won the award. OKay.

# %%
mag2000s[mag2000s["Country"]!="United States"]

# %% [markdown]
# 2006 good old days of web. I have mybb forums and Some blogs back in days. İnternet is so funny and proactive than.

# %% [markdown]
# Who is the youngest person get this award?

# %%
ages=magazine["Year"]-magazine["Birth Year"]
magazine["Age"]=ages

# %%
minindex=magazine["Age"].argmin()
print(magazine.iloc[minindex,:])

# %% [markdown]
# Charles Lindberg get this award in age 25. Solo Transatlantic flight. İt is action!!!

# %% [markdown]
# Oldest to won this award?

# %%
minindex=magazine["Age"].argmax()
print(magazine.iloc[minindex,:])

# %% [markdown]
# Not a suprise POPE !!!!

# %% [markdown]
# median age of all winners?

# %%
import statistics
statistics.median(ages.dropna())

# %% [markdown]
# 57 Time Magazine love old people or Old people rule the world??

# %% [markdown]
# What about Turkey?

# %%
magazine[magazine["Country"]=="Turkey"]

# %% [markdown]
# İt's sad. Turkey one of the active country in the world.

# %%
magazine[magazine["Country"]=="Greece"]

# %%
magazine[magazine["Country"]=="China"]

# %%
magazine[magazine["Country"]=="Israel"]

# %% [markdown]
# New Question Categories is important. How Many categories and plot it?

# %%
set(magazine["Category"])

# %%
plt.figure(figsize=(18,10))
sns.countplot(data=magazine,x="Category")

# %% [markdown]
# Environment and Technology is under the radar. İt is also sad!!!!

# %% [markdown]
# What about after 2000

# %%
mag2000s=magazine[magazine["Year"]>=2000]
plt.figure(figsize=(18,10))
sns.countplot(data=mag2000s,x="Category")

# %% [markdown]
# ## Still Politics rule the world. War and Economies also have politics. So World is not Changing!

# %%
grouping=magazine.groupby(["Country","Category"]).count()["Year"]
print(grouping)

# %% [markdown]
# United States domainated politics and war. Only Vatican won religion based award. Iran has Economy Awards!

# %%
magazine[magazine["Country"]=="Iran"]

# %% [markdown]
# Abadan Crisis I don't know. PETROL

# %%
grouping=magazine.groupby(["Country"]).median()["Age"]
grouping

# %% [markdown]
# Poland and Ethiopia youngest. United States also not bad. Vatican is ...

# %%
magazine[(magazine["Country"]=="Poland")|(magazine["Country"]=="Ethiopia")]

# %% [markdown]
# ## This Awards Depressed me.

# %%
magazine[magazine["Category"]=="Science"]

# %% [markdown]
# 1960 American Scientist ??? COntext?
