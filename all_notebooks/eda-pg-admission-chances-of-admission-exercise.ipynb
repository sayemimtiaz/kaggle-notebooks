# %% [markdown]
# # Graduate Admission Analysis for UCLA

# %% [markdown]
# ## Importing packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='white')
sns.set(style='whitegrid', color_codes=True)

# %% [markdown]
# ## Import data

# %%
#data = pd.read_csv("../input/graduate-admission-data/Admission_Predict.csv")
#data.head()

# %% [markdown]
# Data Description
# The dataset contains information about a student's:
#
# -GRE Score
# -TOEFL Score
# -University Ratings
# -Statement of Purpose Score (SOP)
# -Letter of Recomendation Score (LOR)
# -CGPA
# -Whether the Student Has Done Any Research
# -Chance of Admission (What We're Trying to Predict)

# %% [markdown]
# ## Basic Statistics

# %% [markdown]
# **Find the basic statistics (describe) related to the 'data'**

# %%
#data._____()

# %% [markdown]
# **Find the basic Information (info) related to the 'data'**

# %%
#data._____()

# %% [markdown]
# <font color='blue'>**OBSERVATION :** All the features numerical in nature</font>

# %% [markdown]
# ## Correlation

# %% [markdown]
# **Find the heatmap of correlation(corr) of the features in the 'data'**

# %%
#ax = plt.subplots(figsize=(12, 5));
#ax = sns.heatmap(data._____(), annot = True) ;

# %% [markdown]
# <font color='blue'>**OBSERVATION :** All the features have strong +ve correlation with "Chance of Admit"</font>

# %% [markdown]
# **Compare the features 'GRE Score','University Rating','Chance of Admit' using pairplot**

# %%
#sns.pairplot(data=data[['_____','_____','_____']],height=3, kind='scatter')

# %% [markdown]
# **Compare the features 'SOP','LOR','Chance of Admit' using pairplot**

# %% [markdown]
# <font color='blue'>**OBSERVATION :** "Chance of Admit" is directly proportional to "University Rating" and "GRE Scores".  "University Rating" follows the Bell curve</font>

# %%
#sns.pairplot(data=data[['_____','_____','_____']],height=3, kind='scatter')

# %% [markdown]
# <font color='blue'>**OBSERVATION :** "Chance of Admit" is directly proportional to "LOR" and "SOP"</font>

# %% [markdown]
# **Compare the features 'CGPA','Research','Chance of Admit' using pairplot**

# %%
#sns.pairplot(data=data[['_____','_____','_____']],height=3, kind='scatter')

# %% [markdown]
# <font color='blue'>**OBSERVATION :** "Chance of Admission" is directly proportional to "CGPA"</font>
