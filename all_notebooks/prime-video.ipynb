# %% [markdown]
# # **Amazon Prime Video Dataset**
#
# ### What is it?
# The dataset contains data on shows from Amazon Prime Video Streaming Sevice which can be used to classify and create models
#
# ### What to do?
# Amazon Prime Video dataset contains many parameters on which we can classify the data, let's have a look at few examples

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
prime_ds = pd.read_csv("../input/amazon-prime-series/Prime TV Shows.csv")
prime_ds

# %%
prime_ds.info()

# %%
import seaborn as sns
#Age of viewers plotted visually
sns.set(style="darkgrid")
ax = sns.countplot(x = "Age of viewers", data = prime_ds)

# %%
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(8, 4))
sns.countplot(y = "Language", data = prime_ds)

# %%
# Let us take a look at the top 20 high rated shows on Amazon Prime
prime_ds.sort_values(by = "IMDb rating", ascending = False).head(20)
