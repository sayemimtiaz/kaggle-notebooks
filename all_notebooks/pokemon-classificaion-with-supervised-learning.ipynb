# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
data = pd.read_csv('../input/pokemon/pokemon.csv', usecols = ['attack', 'defense', 'hp', 'sp_attack', 'sp_defense' ,'speed' ,'type1', 'is_legendary'])
data.head(10)

# %%
data.info()

# %%
data["type1"].unique()

# %%
data.describe()

# %%
color_list = ['yellow' if i==1 else 'red' for i in data.loc[:,'is_legendary']]
pd.plotting.scatter_matrix(data.loc[:, data.columns != 'is_legendary'],
                                       c=color_list,
                                       figsize= [15,15],
                                       diagonal='hist',
                                       alpha=0.5,
                                       s = 200,
                                       marker = '.',
                                       edgecolor= "black")
plt.show()

# %%
sns.countplot(x="type1", data=data)
data.loc[:,'type1'].value_counts()

# %% [markdown]
# > **K-NEAREST NEIGHBORS (KNN)**

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=4)
data_knn = data.loc[:,data.columns != 'is_legendary']
x = data_knn.loc[:,data_knn.columns != 'type1'] 
y = data_knn.loc[:,'type1']

print(x.head(), y.head())

# %%
knn.fit(x,y)
pred = knn.predict(x)
pred

# %%
# train and test split data
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3, random_state = 4)
# KNN
knn = KNeighborsClassifier(n_neighbors=4)
# data 
data_knn = data.loc[:,data.columns != 'is_legendary']
# type1 classification
x = data_knn.loc[:,data_knn.columns != 'type1'] 
y = data.loc[:,'type1']


# fit model with train data
knn.fit(x_train,y_train)
pred = knn.predict(x_test)
print('With KNN (K=4) accuracy is: ', knn.score(x_test,y_test))

# %%
x

# %%
neig = np.arange(1, 25)
train_accuracy = []
test_accuracy = []
for i, k in enumerate(neig):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x1_train,y1_train)
    train_accuracy.append(knn.score(x1_train, y1_train))
    test_accuracy.append(knn.score(x1_test, y1_test))

plt.figure(figsize=[13,8])
plt.plot(neig, test_accuracy, label = 'Testing Accuracy')
plt.plot(neig, train_accuracy, label = 'Training Accuracy')
plt.legend()
plt.title('-value VS Accuracy')
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.xticks(neig)
plt.savefig('graph.png')
plt.show()
print("Best accuracy is {} with K = {}".format(np.max(test_accuracy),1+test_accuracy.index(np.max(test_accuracy))))

# %% [markdown]
# > **REGRESSION**

# %%
y.unique()

# %%
y_temp = []
for i in y:
    if i == 'grass':
        y_temp.append(1)
    elif i == 'fire':
        y_temp.append(2)
    elif i == 'water':
        y_temp.append(3)
    elif i == 'bug':
        y_temp.append(4)
    elif i == 'normal':
        y_temp.append(5)
    elif i == 'poison':
        y_temp.append(6)
    elif i == 'electric':
        y_temp.append(7)
    elif i == 'ground':
        y_temp.append(8)
    elif i == 'fairy':
        y_temp.append(9)
    elif i == 'fighting':
        y_temp.append(10)
    elif i == 'psychic':
        y_temp.append(11)
    elif i == 'rock':
        y_temp.append(12)
    elif i == 'ghost':
        y_temp.append(13)
    elif i == 'ice':
        y_temp.append(14)
    elif i == 'dragon':
        y_temp.append(15)
    elif i == 'dark':
        y_temp.append(16)
    elif i == 'steel':
        y_temp.append(17)
    elif i == 'flying':
        y_temp.append(18)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
#pred = np.linspace(min(x), max(x)).reshape(-1,1)
lr.fit(x,y_temp)
#predicted = lr.predict(pred)
print("R_square: ", lr.score(x,y_temp))
