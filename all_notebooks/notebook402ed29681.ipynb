# %%
from pandas_profiling import ProfileReport
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
data=pd.read_csv("../input/men-women-shoes-reviews/Shoes_Data.csv")

# %%
data.head()

# %%
data.info()

# %%
data.describe()

# %%
sns.heatmap(data.isna())

# %%
data['price']=data['price'].str.replace("₹","")

# %%
data['price']=data['price'].astype(float)

# %%
data['rating']=data['rating'].str.replace("out of 5 stars","")

# %%
data['rating']=data['rating'].astype(float)

# %%
data['total_reviews']=data['total_reviews'].str.replace("ratings","")

# %%
data['total_reviews']=data['total_reviews'].str.replace("rating","")

# %%
data['total_reviews']=data['total_reviews'].astype(float)

# %%
data.head()

# %%
data.info()

# %%
data.describe()

# %%
plt.figure(figsize=(15,7))
plt.style.use("fivethirtyeight")
sns.lineplot(x='price',y='rating',data=data ,hue="Shoe Type")

# %%
plt.figure(figsize=(15,7))
plt.style.use("fivethirtyeight")
sns.lineplot(x='rating',y='total_reviews',data=data ,hue="Shoe Type")

# %%
sns.countplot(data['Shoe Type'])

# %%
plt.figure(figsize=(15,7))
sns.countplot(data['rating'])

# %%
data.groupby('Shoe Type').price.mean()

# %%
plt.pie(data.groupby('Shoe Type').price.mean())
plt.show()

# %%
df=ProfileReport(data)

# %%
df
