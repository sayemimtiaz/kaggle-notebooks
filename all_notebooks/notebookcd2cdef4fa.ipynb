# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import os
import missingno as misn
from pandas_profiling import ProfileReport

# %%
data=pd.read_csv("../input/278k-us-wildfires-due-to-lightning-2004-2015/US_Lightning_Forest_Fires.csv")

# %%
data.head()

# %%
data.info()

# %%
data.describe()

# %%
misn.bar(data)

# %%
plt.style.use("fivethirtyeight")
plt.figure(figsize=(20,10))
sns.lineplot(x='FIRE_YEAR',y='FIRE_SIZE',data=data)

# %%
plt.figure(figsize=(20,7))
sns.countplot(data['STATE'])

# %%
plt.figure(figsize=(20,7))
sns.lineplot(x="STATE",y='FIRE_SIZE',data=data ,hue="FIRE_SIZE_CLASS")

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x='FIRE_YEAR',y='Days_to_extinguish_fire',data=data)

# %%
x=ProfileReport(data)

# %%
x
