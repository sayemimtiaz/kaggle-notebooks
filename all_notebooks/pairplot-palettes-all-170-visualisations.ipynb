# %% [markdown]
# # **What is pairplot?**

# %% [markdown]
# In a dataset, the pairplot will plot pairwise the relationships between the dataset.
#
# By design, this feature creates a grid of axes such that each numeric variable in the data is shared between the y-axes in a single row and the x-axes in a single column. Diagonal plots are treated differently: a univariate distribution plot is drawn to indicate the marginal distribution of the data in each column.
#
# It is also possible to display a subset of variables or to map various variables on rows and columns.
#
# This is a high-level gui for PairGrid that is designed to make it simple to draw a few popular types. If you need more versatility, you can use PairGrid directly.

# %% [markdown]
# * * Do Upvote if you like the kernel!

# %% [markdown]
# **Import the required libraries:**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# **Import the dataset:**

# %%
df = pd.read_csv('../input/advertising/advertising.csv')

# %% [markdown]
# # ***Seaborn has 170 different palette choices to start with. So Let's Jump in the visualisations!!!***

# %% [markdown]
# 1) palette = 'Accent'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Accent')

# %% [markdown]
# 2) palette = 'Accent_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Accent_r')

# %% [markdown]
# 3) palette = 'Blues'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Blues')

# %% [markdown]
# 4) palette = 'Blues_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Blues_r')

# %% [markdown]
# 5) palette = 'BrBG'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='BrBG')

# %% [markdown]
# 6) palette = 'BrBG_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='BrBG_r')

# %% [markdown]
# 7) palette = 'BuGn'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='BuGn')

# %% [markdown]
# 8) palette = 'BuGn_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='BuGn_r')

# %% [markdown]
# 9) palette = 'BuPu'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='BuPu')

# %% [markdown]
# 10) palette = 'BuPu_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='BuPu_r')

# %% [markdown]
# 11) palette = 'CMRmap'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='CMRmap')

# %% [markdown]
# 12) palette = 'CMRmap_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='CMRmap_r')

# %% [markdown]
# 13) palette = 'Dark2'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Dark2')

# %% [markdown]
# 14) palette = 'Dark2_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Dark2_r')

# %% [markdown]
# 15) palette = 'GnBu'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='GnBu')

# %% [markdown]
# 16) palette = 'GnBu_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='GnBu_r')

# %% [markdown]
# 17) palette = 'Greens'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Greens')

# %% [markdown]
# 18) palette = 'Greens_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Greens_r')

# %% [markdown]
# 19) palette = 'Greys'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Greys')

# %% [markdown]
# 20) palette = 'Greys_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Greys_r')

# %% [markdown]
# 21) palette = 'OrRd'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='OrRd')

# %% [markdown]
# 22) palette = 'OrRd_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='OrRd_r')

# %% [markdown]
# 23) palette = 'Oranges'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Oranges')

# %% [markdown]
# 24) palette = 'Oranges_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Oranges_r')

# %% [markdown]
# 25) palette = 'PRGn'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='PRGn')

# %% [markdown]
# 26) palette = 'PRGn_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='PRGn_r')

# %% [markdown]
# 27) palette = 'Paired'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Paired')

# %% [markdown]
# 28) palette = 'Paired_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Paired_r')

# %% [markdown]
# 29) palette = 'Pastel1'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Pastel1')

# %% [markdown]
# 30) palette = 'Pastel1_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Pastel1_r')

# %% [markdown]
# 31) palette = 'Pastel2'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Pastel2')

# %% [markdown]
# 32) palette = 'Pastel2_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Pastel2_r')

# %% [markdown]
# 33) palette = 'PiYG'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='PiYG')

# %% [markdown]
# 34) palette = 'PiYG_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='PiYG_r')

# %% [markdown]
# 35) palette = 'PuBu'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='PuBu')

# %% [markdown]
# 36) palette = 'PuBu_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='PuBu_r')

# %% [markdown]
# 37) palette = 'PuBuGn'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='PuBuGn')

# %% [markdown]
# 38) palette = 'PuBuGn_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='PuBuGn_r')

# %% [markdown]
# 39) palette = 'PuOr'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='PuOr')

# %% [markdown]
# 40) palette = 'PuOr_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='PuOr_r')

# %% [markdown]
# 41) palette = 'PuRd'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='PuRd')

# %% [markdown]
# 42) palette = 'PuRd_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='PuRd_r')

# %% [markdown]
# 43) palette = 'Purples'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Purples')

# %% [markdown]
# 44) palette = 'Purples_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Purples_r')

# %% [markdown]
# 45) palette = 'RdBu'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='RdBu')

# %% [markdown]
# 46) palette = 'RdBu_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='RdBu_r')

# %% [markdown]
# 47) palette = 'RdGy'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='RdGy')

# %% [markdown]
# 48) palette = 'RdGy_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='RdGy_r')

# %% [markdown]
# 49) palette = 'RdPu'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='RdPu')

# %% [markdown]
# 50) palette = 'RdPu_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='RdPu_r')

# %% [markdown]
# 51) palette = 'RdYlBu'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='RdYlBu')

# %% [markdown]
# 52) palette = 'RdYlBu_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='RdYlBu_r')

# %% [markdown]
# 53) palette = 'RdYlGn'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='RdYlGn')

# %% [markdown]
# 54) palette = 'RdYlGn_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='RdYlGn_r')

# %% [markdown]
# 55) palette = 'Reds'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Reds')

# %% [markdown]
# 56) palette = 'Reds_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Reds_r')

# %% [markdown]
# 57) palette = 'Set1'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Set1')

# %% [markdown]
# 58) palette = 'Set1_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Set1_r')

# %% [markdown]
# 59) palette = 'Set2'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Set2')

# %% [markdown]
# 60) palette = 'Set2_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Set2_r')

# %% [markdown]
# 61) palette = 'Set3'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Set3')

# %% [markdown]
# 62) palette = 'Set3_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Set3_r')

# %% [markdown]
# 63) palette = 'Spectral'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Spectral')

# %% [markdown]
# 64) palette = 'Spectral_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Spectral_r')

# %% [markdown]
# 65) palette = 'Wistia'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Wistia')

# %% [markdown]
# 66) palette = 'Wistia_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='Wistia_r')

# %% [markdown]
# 67) palette = 'YlGn'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='YlGn')

# %% [markdown]
# 68) palette = 'YlGn_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='YlGn_r')

# %% [markdown]
# 69) palette = 'YlGnBu'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='YlGnBu')

# %% [markdown]
# 70) palette = 'YlGnBu_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='YlGnBu_r')

# %% [markdown]
# 71) palette = 'YlOrBr'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='YlOrBr')

# %% [markdown]
# 72) palette = 'YlOrBr_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='YlOrBr_r')

# %% [markdown]
# 73) palette = 'YlOrRd'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='YlOrRd')

# %% [markdown]
# 74) palette = 'YlOrRd_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='YlOrRd_r')

# %% [markdown]
# 75) palette = 'afmhot'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='afmhot')

# %% [markdown]
# 76) palette = 'afmhot_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='afmhot_r')

# %% [markdown]
# 77) palette = 'autumn'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='autumn')

# %% [markdown]
# 78) palette = 'autumn_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='autumn_r')

# %% [markdown]
# 79) palette = 'binary'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='binary')

# %% [markdown]
# 80) palette = 'binary_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='binary_r')

# %% [markdown]
# 81) palette = 'bone'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='bone')

# %% [markdown]
# 82) palette = 'bone_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='bone_r')

# %% [markdown]
# 83) palette = 'brg'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='brg')

# %% [markdown]
# 84) palette = 'brg_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='brg_r')

# %% [markdown]
# 85) palette = 'bwr'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='bwr')

# %% [markdown]
# 86) palette = 'bwr_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='bwr_r')

# %% [markdown]
# 87) palette = 'cividis'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='cividis')

# %% [markdown]
# 88) palette = 'cividis_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='cividis_r')

# %% [markdown]
# 89) palette = 'cool'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='cool')

# %% [markdown]
# 90) palette = 'cool_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='cool_r')

# %% [markdown]
# 91) palette = 'coolwarm'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='coolwarm')

# %% [markdown]
# 92) palette = 'coolwarm_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='coolwarm_r')

# %% [markdown]
# 93) palette = 'copper'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='copper')

# %% [markdown]
# 94) palette = 'copper_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='copper_r')

# %% [markdown]
# 95) palette = 'cubehelix'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='cubehelix')

# %% [markdown]
# 96) palette = 'cubehelix_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='cubehelix_r')

# %% [markdown]
# 97) palette = 'flag'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='flag')

# %% [markdown]
# 98) palette = 'flag_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='flag_r')

# %% [markdown]
# 99) palette = 'gist_earth'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='gist_earth')

# %% [markdown]
# 100) palette = 'gist_earth_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='gist_earth_r')

# %% [markdown]
# 101) palette = 'gist_gray'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='gist_gray')

# %% [markdown]
# 102) palette = 'gist_gray_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='gist_gray_r')

# %% [markdown]
# 103) palette = 'gist_heat'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='gist_heat')

# %% [markdown]
# 104) palette = 'gist_heat_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='gist_heat_r')

# %% [markdown]
# 105) palette = 'gist_ncar'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='gist_ncar')

# %% [markdown]
# 106) palette = 'gist_ncar_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='gist_ncar_r')

# %% [markdown]
# 107) palette = 'gist_rainbow'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='gist_rainbow')

# %% [markdown]
# 108) palette = 'gist_rainbow_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='gist_rainbow_r')

# %% [markdown]
# 109) palette = 'gist_stern'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='gist_stern')

# %% [markdown]
# 110) palette = 'gist_stern_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='gist_stern_r')

# %% [markdown]
# 111) palette = 'gist_yarg'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='gist_yarg')

# %% [markdown]
# 112) palette = 'gist_yarg_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='gist_yarg_r')

# %% [markdown]
# 113) palette = 'gnuplot'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='gnuplot')

# %% [markdown]
# 114) palette = 'gnuplot_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='gnuplot_r')

# %% [markdown]
# 115) palette = 'gnuplot2'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='gnuplot2')

# %% [markdown]
# 116) palette = 'gnuplot2_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='gnuplot2_r')

# %% [markdown]
# 117) palette = 'gray'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='gray')

# %% [markdown]
# 118) palette = 'gray_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='gray_r')

# %% [markdown]
# 119) palette = 'hot'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='hot')

# %% [markdown]
# 120) palette = 'hot_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='hot_r')

# %% [markdown]
# 121) palette = 'hsv'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='hsv')

# %% [markdown]
# 122) palette = 'hsv_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='hsv_r')

# %% [markdown]
# 123) palette = 'icefire'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='icefire')

# %% [markdown]
# 124) palette = 'icefire_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='icefire_r')

# %% [markdown]
# 125) palette = 'inferno'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='inferno')

# %% [markdown]
# 126) palette = 'inferno_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='inferno_r')

# %% [markdown]
# 127) palette = 'magma'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='magma')

# %% [markdown]
# 128) palette = 'magma_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='magma_r')

# %% [markdown]
# 129) palette = 'mako'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='mako')

# %% [markdown]
# 130) palette = 'mako_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='mako_r')

# %% [markdown]
# 131) palette = 'nipy_spectral'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='nipy_spectral')

# %% [markdown]
# 132) palette = 'nipy_spectral_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='nipy_spectral_r')

# %% [markdown]
# 133) palette = 'ocean'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='ocean')

# %% [markdown]
# 134) palette = 'ocean_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='ocean_r')

# %% [markdown]
# 135) palette = 'pink'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='pink')

# %% [markdown]
# 136) palette = 'pink_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='pink_r')

# %% [markdown]
# 137) palette = 'plasma'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='plasma')

# %% [markdown]
# 138) palette = 'plasma_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='plasma_r')

# %% [markdown]
# 139) palette = 'prism'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='prism')

# %% [markdown]
# 140) palette = 'prism_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='prism_r')

# %% [markdown]
# 141) palette = 'rainbow'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='rainbow')

# %% [markdown]
# 142) palette = 'rainbow_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='rainbow_r')

# %% [markdown]
# 143) palette = 'rocket'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='rocket')

# %% [markdown]
# 144) palette = 'rocket_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='rocket_r')

# %% [markdown]
# 145) palette = 'seismic'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='seismic')

# %% [markdown]
# 146) palette = 'seismic_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='seismic_r')

# %% [markdown]
# 147) palette = 'spring'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='spring')

# %% [markdown]
# 148) palette = 'spring_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='spring_r')

# %% [markdown]
# 149) palette = 'summer'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='summer')

# %% [markdown]
# 150) palette = 'summer_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='summer_r')

# %% [markdown]
# 151) palette = 'tab10'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='tab10')

# %% [markdown]
# 152) palette = 'tab10_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='tab10_r')

# %% [markdown]
# 153) palette = 'tab20'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='tab20')

# %% [markdown]
# 154) palette = 'tab20_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='tab20_r')

# %% [markdown]
# 155) palette = 'tab20b'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='tab20b')

# %% [markdown]
# 156) palette = 'tab20b_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='tab20b_r')

# %% [markdown]
# 157) palette = 'tab20c'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='tab20c')

# %% [markdown]
# 158) palette = 'tab20c_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='tab20c_r')

# %% [markdown]
# 159) palette = 'terrain'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='terrain')

# %% [markdown]
# 160) palette = 'terrain_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='terrain_r')

# %% [markdown]
# 161) palette = 'twilight'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='twilight')

# %% [markdown]
# 162) palette = 'twilight_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='twilight_r')

# %% [markdown]
# 163) palette = 'twilight_shifted'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='twilight_shifted')

# %% [markdown]
# 164) palette = 'twilight_shifted_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='twilight_shifted_r')

# %% [markdown]
# 165) palette = 'viridis'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='viridis')

# %% [markdown]
# 166) palette = 'viridis_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='viridis_r')

# %% [markdown]
# 167) palette = 'vlag'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='vlag')

# %% [markdown]
# 168) palette = 'vlag_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='vlag_r')

# %% [markdown]
# 169) palette = 'winter'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='winter')

# %% [markdown]
# 170) palette = 'winter_r'

# %%
sns.pairplot(df, hue='Clicked on Ad', palette='winter_r')
