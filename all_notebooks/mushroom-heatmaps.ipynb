# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("../input/mushroom-classification/mushrooms.csv")
df.head()

# %% [markdown]
# **Please note, due to the latest matplotlib breaking parts of Seaborn, annotations will not be shown unless you downgrade matplotlib or use edit mode**

# %%
#Get to columns to be compared

X = df[['class','cap-shape']]
X=pd.get_dummies(X,prefix_sep = ',')
X.head(2)

# %%
#Cap Shape
#Wittle down correlations further to properly compare the two relevant columns

plt.subplots(figsize=(20,15))
corr = X.corr()
sub_corr = corr[['cap-shape,b','cap-shape,c', 'cap-shape,f','cap-shape,k','cap-shape,s','cap-shape,x']]


sub_corr.head(2)
ax = sns.heatmap(sub_corr.iloc[0:2],#Gets relevant rows
                 vmin=-1, vmax=1, center=0,#Set the key properly
                 cmap=sns.diverging_palette(20, 220, n=200),square=True, annot = True) #Set colors

ax.set_title('Correlation between Mushroom Cap Shape and Edibility')
ax.set_ylabel('Edibility')
ax.set_xlabel('Cap Shape')

# %%
#Cap Surface
#Get to columns to be compared

X = df[['class','cap-surface']]
X=pd.get_dummies(X,prefix_sep = ',')
X.head(2)

# %%
#Wittle down correlations further to properly compare the two relevant columns

plt.subplots(figsize=(20,15))
corr = X.corr()
sub_corr = corr[['cap-surface,f','cap-surface,g', 'cap-surface,s','cap-surface,y']]


sub_corr.head(2)
ax = sns.heatmap(sub_corr.iloc[0:2],#Gets relevant rows
                 vmin=-1, vmax=1, center=0,#Set the key properly
                 cmap=sns.diverging_palette(20, 220, n=200),square=True, annot = True) #Set colors

ax.set_title('Correlation between Mushroom Cap Surface and Edibility')
ax.set_ylabel('Edibility')
ax.set_xlabel('Cap Surface')

# %%
#Cap Color
#Get to columns to be compared

X = df[['class','cap-color']]
X=pd.get_dummies(X,prefix_sep = ',')
X.head(2)

# %%
#Wittle down correlations further to properly compare the two relevant columns

plt.subplots(figsize=(20,15))
corr = X.corr()
sub_corr = corr[['cap-color,b', 'cap-color,c', 'cap-color,e', 'cap-color,g', 'cap-color,n', 'cap-color,p', 'cap-color,r', 'cap-color,u', 'cap-color,w', 'cap-color,y']]


sub_corr.head(2)
ax = sns.heatmap(sub_corr.iloc[0:2],#Gets relevant rows
                 vmin=-1, vmax=1, center=0,#Set the key properly
                 cmap=sns.diverging_palette(20, 220, n=200),square=True, annot = True) #Set colors

ax.set_title('Correlation between Mushroom Cap Color and Edibility')
ax.set_ylabel('Edibility')
ax.set_xlabel('Cap Color')

# %%
#Bruisers
#Get to columns to be compared

X = df[['class','bruises']]
X=pd.get_dummies(X,prefix_sep = ',')
X.head(2)

# %%
#Wittle down correlations further to properly compare the two relevant columns

plt.subplots(figsize=(20,15))
corr = X.corr()
sub_corr = corr[['bruises,f', 'bruises,t']]

sub_corr.head(2)
ax = sns.heatmap(sub_corr.iloc[0:2],#Gets relevant rows
                 vmin=-1, vmax=1, center=0,#Set the key properly
                 cmap=sns.diverging_palette(20, 220, n=200),square=True, annot = True) #Set colors

ax.set_title('Correlation between Mushroom Bruises and Edibility')
ax.set_ylabel('Edibility')
ax.set_xlabel('Bruises')

# %%
#Odor
#Get to columns to be compared

X = df[['class','odor']]
X=pd.get_dummies(X,prefix_sep = ',')
X.head(2)

# %%
#Wittle down correlations further to properly compare the two relevant columns

plt.subplots(figsize=(20,15))
corr = X.corr()
sub_corr = corr[['odor,a','odor,c','odor,f','odor,l','odor,m','odor,n','odor,p','odor,s','odor,y']]

sub_corr.head(2)
ax = sns.heatmap(sub_corr.iloc[0:2],#Gets relevant rows
                 vmin=-1, vmax=1, center=0,#Set the key properly
                 cmap=sns.diverging_palette(20, 220, n=200),square=True, annot = True) #Set colors

ax.set_title('Correlation between Mushroom Odor and Edibility')
ax.set_ylabel('Edibility')
ax.set_xlabel('Odor')

# %%
#Odor
#Get to columns to be compared

X = df[['class','gill-attachment']]
X=pd.get_dummies(X,prefix_sep = ',')
X.head(2)

# %%
#Wittle down correlations further to properly compare the two relevant columns

plt.subplots(figsize=(20,15))
corr = X.corr()
sub_corr = corr[['gill-attachment,a','gill-attachment,f']]

sub_corr.head(2)
ax = sns.heatmap(sub_corr.iloc[0:2],#Gets relevant rows
                 vmin=-1, vmax=1, center=0,#Set the key properly
                 cmap=sns.diverging_palette(20, 220, n=200),square=True, annot = True) #Set colors

ax.set_title('Correlation between Mushroom Gill Attachment and Edibility')
ax.set_ylabel('Edibility')
ax.set_xlabel('Gill Attachment')

# %%
#Gill Spacing
#Get to columns to be compared

X = df[['class','gill-spacing']]
X=pd.get_dummies(X,prefix_sep = ',')
X.head(2)

# %%
#Wittle down correlations further to properly compare the two relevant columns

plt.subplots(figsize=(20,15))
corr = X.corr()
sub_corr = corr[['gill-spacing,c','gill-spacing,w']]

sub_corr.head(2)
ax = sns.heatmap(sub_corr.iloc[0:2],#Gets relevant rows
                 vmin=-1, vmax=1, center=0,#Set the key properly
                 cmap=sns.diverging_palette(20, 220, n=200),square=True, annot = True) #Set colors

ax.set_title('Correlation between Mushroom Gill Spacing and Edibility')
ax.set_ylabel('Edibility')
ax.set_xlabel('Gill Spacing')

# %%
#Gill Spacing
#Get to columns to be compared

X = df[['class','gill-size']]
X=pd.get_dummies(X,prefix_sep = ',')
X.head(2)

# %%
#Wittle down correlations further to properly compare the two relevant columns

plt.subplots(figsize=(20,15))
corr = X.corr()
sub_corr = corr[['gill-size,b','gill-size,n']]

sub_corr.head(2)
ax = sns.heatmap(sub_corr.iloc[0:2],#Gets relevant rows
                 vmin=-1, vmax=1, center=0,#Set the key properly
                 cmap=sns.diverging_palette(20, 220, n=200),square=True, annot = True) #Set colors

ax.set_title('Correlation between Mushroom Gill Size and Edibility')
ax.set_ylabel('Edibility')
ax.set_xlabel('Gill Size')

# %%
#Gill Spacing
#Get to columns to be compared

X = df[['class','gill-color']]
X=pd.get_dummies(X,prefix_sep = ',')
X.head(2)

# %%
#Wittle down correlations further to properly compare the two relevant columns

plt.subplots(figsize=(20,15))
corr = X.corr()
sub_corr = corr[['gill-color,b','gill-color,e','gill-color,g','gill-color,h','gill-color,k','gill-color,n','gill-color,o','gill-color,p','gill-color,r','gill-color,u','gill-color,w','gill-color,y']]

sub_corr.head(2)
ax = sns.heatmap(sub_corr.iloc[0:2],#Gets relevant rows
                 vmin=-1, vmax=1, center=0,#Set the key properly
                 cmap=sns.diverging_palette(20, 220, n=200),square=True, annot = True) #Set colors

ax.set_title('Correlation between Mushroom Gill Color and Edibility')
ax.set_ylabel('Edibility')
ax.set_xlabel('Gill Color')
