# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px
import plotly.graph_objs as go

# %%
pip install sweetviz

# %%
df = pd.read_csv('../input/drug-classification/drug200.csv')

# %%
df.head()

# %%
import sweetviz as sv

analyzed_report = sv.analyze(df)
analyzed_report.show_html('SWEETVIZ_REPORT.html')

# %%
from IPython.display import IFrame
IFrame(src = 'SWEETVIZ_REPORT.html',width=1000,height=600)

# %%
fig = px.bar(df, x="Age", y="Sex", color="Drug")
fig.show()

# %%
fig = px.bar(df, x="Drug", y="Age",color='Drug')
fig.show()

# %%
fig = px.bar(df, x="BP", y="Drug",color='Drug')

fig.show()

# %%
fig = px.bar(df, x="Cholesterol", y="Drug",color='Drug')

fig.show()

# %%
fig = px.bar(df, x="Age", y="Sex",color='Sex')
fig.show()

# %%
fig = px.bar(df, x="Age", y="BP",color='Sex')
fig.show()

# %%
fig = px.bar(df, x="Age", y="Cholesterol",color='Cholesterol')
fig.show()

# %%
fig = px.bar(df, x="Sex", y="Cholesterol",color='Sex')
fig.show()

# %%
fig = px.bar(df, x="Sex", y="BP",color='Sex')
fig.show()

# %%
fig = px.bar(df, x="Sex", y="Na_to_K",color='Sex')
fig.show()

# %%
fig = px.bar(df, x="Cholesterol", y="Na_to_K",color='Cholesterol')
fig.show()

# %%
fig = px.scatter(df, x="Age", y="Na_to_K", color="Drug")
fig.show()

# %%
X = df.drop(columns=["Drug"])
y = df["Drug"]

# %%
from sklearn.model_selection import train_test_split

#Splitting data

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=44, shuffle =True)

# %%
X_train = pd.get_dummies(pd.DataFrame(X_train))
X_test = pd.get_dummies(pd.DataFrame(X_test))

# %%
#Import Libraries
from sklearn.ensemble import GradientBoostingClassifier

#Applying GradientBoostingClassifier Model 



GBCModel = GradientBoostingClassifier(n_estimators=100,max_depth=3,random_state=33) 
GBCModel.fit(X_train, y_train)

#Calculating Details
print('GBCModel Train Score is : ' , GBCModel.score(X_train, y_train))
print('GBCModel Test Score is : ' , GBCModel.score(X_test, y_test))
#print('----------------------------------------------------')

#Calculating Prediction
y_pred = GBCModel.predict(X_test)
y_pred_prob = GBCModel.predict_proba(X_test)
#print('Predicted Value for GBCModel is : ' , y_pred[:10])
#print('Prediction Probabilities Value for GBCModel is : ' , y_pred_prob[:10])

# %%
from sklearn.metrics import recall_score

#Calculating Recall Score : (Sensitivity) (TP / float(TP + FN))   1 / 1+2  
# recall_score(y_true, y_pred, labels=None, pos_label=1, average=’binary’, sample_weight=None)

RecallScore = recall_score(y_test, y_pred, average='micro')

# %%
#Import Libraries
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

#Calculating Confusion Matrix
CM = confusion_matrix(y_test, y_pred)
print('Confusion Matrix is : \n', CM)

# drawing confusion matrix
sns.heatmap(CM, center = True,cmap='PuBu')
plt.show()
