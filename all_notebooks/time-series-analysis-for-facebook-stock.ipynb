# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('../input/facebook-stock-data/FB.csv',
                parse_dates = ['Date'],
                index_col = 0)

# %%
df.head(10)

# %%
df.info()

# %% [markdown]
# # **Dictionary**
#
# * **Open**      : Price from the first transaction of a trading day
# * **High**      : Maximum price in a trading day
# * **Low**       : Minimum price in a trading day
# * **Close**     : Price from the last transaction of a trading day
# * **Adj Close** : Closing price adjusted to reflect the value after                     accounting for any corporate actions
# * **Volume**    : Number of units traded in a day

# %%
sum(df['Close'] - df['Adj Close'])

# %% [markdown]
# > In general, the **adjusted closing** price is considered to be a **more technically** accurate reflection of the true value of the stock.
# [Adjusted Closing Price vs. Closing Price](http://finance.zacks.com/adjusted-closing-price-vs-closing-price-9991.html)
#
# ##### but here the two columns are equale

# %%
df.drop('Adj Close' , inplace = True , axis = 1)

# %%
df.head()

# %%
df.tail()

# %% [markdown]
# ## Make an Analysis on (Open, High, Low, Close)

# %%
df1 = df.drop('Volume', axis = 1)

# %%
df1.head()

# %% [markdown]
# # Facebook Stocks in 2012 From May to December

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df1.loc['2012'],
             linewidth=2,
             markers = True)
plt.title('Facebook Stocks in 2012 ( May - December )')
plt.show()

# %% [markdown]
# > From **Augest** To the Second week in **November** The Price is less than 25 Dollars
# >

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df1.loc['2013'],
             linewidth=2,
             markers = True)
plt.title('Facebook Stocks in 2013')
plt.show()

# %% [markdown]
# > From **February** to **July** The Price is more than 30 Dollars and From **August** to **December** The Price is more than 35 Dollars

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df1.loc['2014'],
             linewidth=2,
             markers = True)
plt.title('Facebook Stocks in 2014')
plt.show()

# %% [markdown]
# > From **Febuary** to **April** there is **sudden rise** in **Febuary** and the **decrease** in begin of **April**
# >
# > From **August** to **Dacember** is The Highest rate in the year

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df1.loc['2015'],
             linewidth=2,
             markers = True)
plt.title('Facebook Stocks in 2015')
plt.show()

# %%
df1.loc['2015-08']

# %% [markdown]
# > From **begin** of the Year to the half of **August** there is stability in the Stock Market and there is in the day of **(2015-08-24)** an **unexpected drop** in the Stock Market

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df1.loc['2016'],
             linewidth=2,
             markers = True)
plt.title('Facebook Stocks in 2016')
plt.show()

# %% [markdown]
# > The Highest Rate in the Price from **August** to **November**

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df1.loc['2017'],
             linewidth=2,
             markers = True)
plt.title('Facebook Stocks in 2017')
plt.show()

# %% [markdown]
# > From the **begin to the end** of the year there is **increasing** in stock exchange

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df1.loc['2018'],
             linewidth=2,
             markers = True)
plt.title('Facebook Stocks in 2018')
plt.show()

# %%
df1.loc['2018-07']

# %% [markdown]
# > From the **begin** of the Year to the half of **March** there is **stability**
# > , From the half of **March**  to **May** there is **decreasing** then **stability**
# > , From **May** to **July** there is **increasing**
# > and in **(2018-07-26)** There is an **unexpected drop**
# > , From **August** to the **December** there is  **decreasing**

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df1.loc['2019'],
             linewidth=2,
             markers = True)
plt.title('Facebook Stocks in 2019')
plt.show()

# %%
df1.loc['2019-01']

# %% [markdown]
# > In **(2019-01-31)** there is **sudden rise** , From this date there is **stablity**

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df1.loc['2020'],
             linewidth=2,
             markers = True)
plt.title('Facebook Stocks in 2020')
plt.show()

# %%
df1.loc['2020-02']

# %%
df1.loc['2020-04']

# %% [markdown]
# > In **(2020-02-28)** there is **sudden drop** and still **decreasing** to **(2020-04-24)**
# > , From This date there is **increasing**

# %%
df1.tail()

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df1.loc['2021'],
             linewidth=2,
             markers = True)
plt.title('Facebook Stocks in 2021( Junuary to August )')
plt.show()

# %% [markdown]
# > From the **begin** to **March** there is **stability** and then there is **increasing**

# %% [markdown]
# # Analysis for Volume

# %%
volume = df['Volume']
volume.head()

# %%
plt.figure(figsize = (15,8))
sns.lineplot(data=volume.loc['2012'],
             linewidth=1,
            color = 'green')
plt.title('The Volume in 2012 ( May - December )')
plt.show()

# %%
plt.figure(figsize = (15,8))
sns.lineplot(data=volume.loc['2013'],
             linewidth=1,
            color = 'green')
plt.title('The Volume in 2013')
plt.show()

# %%
plt.figure(figsize = (15,8))
sns.lineplot(data=volume.loc['2014'],
             linewidth=1,
            color = 'green')
plt.title('The Volume in 2014')
plt.show()

# %%
plt.figure(figsize = (15,8))
sns.lineplot(data=volume.loc['2015'],
             linewidth=1,
            color = 'green')
plt.title('The Volume in 2015')
plt.show()

# %%
plt.figure(figsize = (15,8))
sns.lineplot(data=volume.loc['2016'],
             linewidth=1,
            color = 'green')
plt.title('The Volume in 2016')
plt.show()

# %%
plt.figure(figsize = (15,8))
sns.lineplot(data=volume.loc['2017'],
             linewidth=1,
            color = 'green')
plt.title('The Volume in 2017')
plt.show()

# %%
plt.figure(figsize = (15,8))
sns.lineplot(data=volume.loc['2018'],
             linewidth=1,
            color = 'green')
plt.title('The Volume in 2019')
plt.show()

# %%
plt.figure(figsize = (15,8))
sns.lineplot(data=volume.loc['2020'],
             linewidth=1,
            color = 'green')
plt.title('The Volume in 2020')
plt.show()

# %%
plt.figure(figsize = (15,8))
sns.lineplot(data=volume.loc['2021'],
             linewidth=1,
            color = 'green')
plt.title('The Volume in 2021')
plt.show()

# %% [markdown]
# > In General the **Highest** Volume in **August**
