# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("../input/loandata/Loan payments data.csv", parse_dates =["effective_date","due_date","paid_off_time"])

df.head()

# %% [markdown]
# #### Dataset info

# %%
df.info()

# %% [markdown]
# #### Dataset Shape

# %%
df.shape

# %% [markdown]
# #### Describing Data

# %%
df.describe()

# %% [markdown]
# #### Check Missing Values

# %%
df.isnull().sum()

# %% [markdown]
# #### Checking unique values and replacing them with integers

# %%
df['past_due_days'].unique()

# %%
df["past_due_days"]= df["past_due_days"].fillna(0)
df["past_due_days"]= df["past_due_days"].replace([  76., 61., 75., 60., 59., 74., 29., 44., 58., 73., 28.,  2.,
        4., 13.,  5.,  3., 12., 27.,  1., 25., 24., 36.,  7., 14., 23.,
        6., 38., 19., 52., 51.,  9., 56.,  8.], "1")

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()

# %% [markdown]
# #### Visualising Data

# %% [markdown]
# #### Comparison between gender and paying Loan in time:

# %%
sns.countplot(df['Gender'],hue=df['past_due_days'])
print(pd.crosstab(df['Gender'],df['past_due_days']))

# %% [markdown]
# We can see that males paid their loans in time compared to females

# %% [markdown]
# #### Comparison between level of  education and paying Loan in time:

# %%
sns.countplot(df['education'],hue=df['past_due_days'])
print(pd.crosstab(df['education'],df['past_due_days']))

# %% [markdown]
# Students in High School or Below  and College paid their loans in time before due date

# %% [markdown]
# #### Comparison between Loan Status and paying Loan in time:

# %%
sns.countplot(df['loan_status'],hue=df['past_due_days'])
print(pd.crosstab(df['loan_status'],df['past_due_days']))

# %% [markdown]
# #### Comparison between Terms  offered and payng Loan:

# %%
sns.countplot(df['terms'],hue=df['past_due_days'])
print(pd.crosstab(df['terms'],df['past_due_days']))

# %% [markdown]
# Customers with higher terms paid in time compared to those with lower terms

# %%
df['loan_status'].unique()

# %%
df["loan_status"]= df["loan_status"].replace(['PAIDOFF', 'COLLECTION_PAIDOFF'],["0","1"])

# %%
df['Gender'].unique()

# %%
df["Gender"]= df["Gender"].replace(['male', 'female'],["0","1"])

# %%
df['terms'].unique()

# %%
df["past_due_days"] = df["past_due_days"].astype("int")

# %%
#df.info()

# %%
df['education'].unique()

# %%
df["education"]= df["education"].replace(['High School or Below', 'Bechalor', 'college', 'Master or Above'],["0","1","2","3"])

# %% [markdown]
# ### Display the Correlation Matrix

# %%
plt.figure(figsize=(16,5))
sns.heatmap(df.corr(),annot=True)
plt.title('Correlation Matrix (for Loan Payment)')

# %% [markdown]
# From the above figure, we can see that terms  has the maximum correlation with Pricipal Which denotes that the terms is heavily dependent on the Principal.

# %%
df['Loan_ID'] =df['Loan_ID'].str[3:]
df.head()

# %%
df.drop(['effective_date', 'due_date' , 'paid_off_time'] ,axis = 1, inplace = True)
df.head(1)

# %%
df.info()

# %% [markdown]
# ### Importing Packages for Classification algorithms

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# %% [markdown]
# ### Splitting the data into Train and Test set

# %%
X = df.iloc[1:400,1:7].values
y = df.iloc[1:400,2].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=0)

# %%
print(X_train)

# %%
print(X_test)

# %%
print(y_train)

# %% [markdown]
# ### Logistic Regression (LR)

# %%
model = LogisticRegression()
model.fit(X_train,y_train)

lr_prediction = model.predict(X_test)
print('Logistic Regression accuracy = ', metrics.accuracy_score(lr_prediction,y_test))

# %% [markdown]
# ### Support Vector Machine (SVM)

# %%
model = svm.SVC()
model.fit(X_train,y_train)

svc_prediction = model.predict(X_test)
print('SVM accuracy = ', metrics.accuracy_score(svc_prediction,y_test))

# %% [markdown]
# ### Decision Tree

# %%
model = DecisionTreeClassifier()
model.fit(X_train,y_train)

dt_prediction = model.predict(X_test)
print('Decision Tree accuracy = ', metrics.accuracy_score(dt_prediction,y_test))

# %% [markdown]
# ### K-Nearest Neighbors (KNN)

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)

knn_prediction = model.predict(X_test)
print('KNN accuracy = ', metrics.accuracy_score(knn_prediction,y_test))

# %% [markdown]
# **CONCLUSION:**
#
# 1. The Terms is heavily dependent on the Principal for Predictions.
# 2. The Decision Tree algorithm gives us the maximum Accuracy (98.3% approx) compared to the other 3 Machine Learning Classification Algorithms.

# %% [markdown]
# By Makhosi Golide.
# Suggestions accepted
