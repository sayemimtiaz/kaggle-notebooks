# %% [markdown]
# Aşağıda ihtiyacımız doğrultusunda kullanacağımız kütüphaneleri yükleyelim.

# %%
import numpy as np
import pandas as pd 
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, roc_curve, classification_report
from sklearn.metrics import roc_auc_score,roc_curve
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import recall_score, f1_score, precision_score
from sklearn.tree import DecisionTreeClassifier
from warnings import filterwarnings
import matplotlib.pyplot as plt
from sklearn import ensemble
from sklearn.metrics import confusion_matrix as cm

# %% [markdown]
# Veri çerçevemizi bulunduğumuz dizinden yükleyelim ve bir veri çerçevesi haline getirerek df değişkenine atayalım. (pd.read_csv(...csv))

# %%
df = pd.read_csv('../input/tablet-prediction/tablet.csv')

# %% [markdown]
# ## Veri Setini Tanımak ve Sindirmek

# %% [markdown]
# Veri çerçevesinin ilk 5 gözlemini görüntüleyelim.

# %%
df.head()

# %% [markdown]
# Veri çerçevesinin son 5 gözlemini görüntüleyelim.

# %%
df.tail()

# %% [markdown]
# Veri çerçevesinin kaç öznitelik ve kaç gözlemden oluştuğunu görüntüleyelim.

# %%
df.shape

# %% [markdown]
# Veri çerçevesindeki değişkenlerin hangi tipte olduğunu ve bellek kullanımını görüntüleyelim.

# %%
df.info()

# %% [markdown]
# ### Benzersiz Değerleri Görüntüleme

# %%
df["BataryaGucu"].unique()

# %%
df["Bluetooth"].unique()

# %%
df["MikroislemciHizi"].unique()

# %%
df["CiftHat"].unique()

# %%
df["OnKameraMP"].unique()

# %%
df["4G"].unique()

# %%
df["DahiliBellek"].unique()

# %%
df["Kalinlik"].unique()

# %%
df["Agirlik"].unique()

# %%
df["CekirdekSayisi"].unique()

# %%
df["ArkaKameraMP"].unique()

# %%
df["CozunurlukYükseklik"].unique()

# %%
df["CozunurlukGenislik"].unique()

# %%
df["RAM"].unique()

# %%
df["BataryaOmru"].unique()

# %%
df["3G"].unique()

# %%
df["Dokunmatik"].unique()

# %%
df["WiFi"].unique()

# %%
df["FiyatAraligi"].unique()

# %%
df["Renk"].unique()

# %% [markdown]
# ### Benzersiz Değerlerin Dağılımı

# %%
df["BataryaGucu"].value_counts()

# %%
df["Bluetooth"].value_counts()

# %%
df["MikroislemciHizi"].value_counts()

# %%
df["CiftHat"].value_counts()

# %%
df["OnKameraMP"].value_counts()

# %%
df["4G"].value_counts()

# %%
df["DahiliBellek"].value_counts()

# %%
df["Kalinlik"].value_counts()

# %%
df["Agirlik"].value_counts()

# %%
df["CekirdekSayisi"].value_counts()

# %%
df["ArkaKameraMP"].value_counts()

# %%
df["CozunurlukYükseklik"].value_counts()

# %%
df["CozunurlukGenislik"].value_counts()

# %%
df["RAM"].value_counts()

# %%
df["BataryaOmru"].value_counts()

# %%
df["3G"].value_counts()

# %%
df["Dokunmatik"].value_counts()

# %%
df["WiFi"].value_counts()

# %%
df["FiyatAraligi"].value_counts()

# %%
df["Renk"].value_counts()

# %% [markdown]
# ### BataryaGucu Distrubiton

# %%
df["BataryaGucu"].describe()

# %%
sns.violinplot(df["BataryaGucu"]);

# %%
sns.distplot(df["BataryaGucu"], bins = 20);

# %%
sns.boxplot(df["BataryaGucu"]);

# %% [markdown]
# ### Bluetooth Distrubiton

# %%
df["Bluetooth"].describe()

# %%
sns.countplot(df["Bluetooth"]);

# %% [markdown]
# ### MikroislemciHizi Distrubiton

# %%
df["MikroislemciHizi"].describe()

# %%
sns.violinplot(df["MikroislemciHizi"]);

# %%
sns.distplot(df["MikroislemciHizi"], bins = 15);

# %%
sns.boxplot(df["MikroislemciHizi"]);

# %% [markdown]
# ### CiftHat Distrubiton

# %%
df["CiftHat"].describe()

# %%
sns.countplot(df["CiftHat"]);

# %% [markdown]
# ### OnKameraMP Distrubiton

# %%
df["OnKameraMP"].describe()

# %%
sns.violinplot(df["OnKameraMP"]);

# %%
sns.distplot(df["OnKameraMP"], bins = 15);

# %%
sns.boxplot(df["OnKameraMP"]);

# %% [markdown]
# ### 4G Distrubiton

# %%
df["4G"].describe()

# %%
sns.countplot(df["4G"]);

# %% [markdown]
# ### DahiliBellek Distrubiton

# %%
df["DahiliBellek"].describe()

# %%
sns.violinplot(df["DahiliBellek"]);

# %%
sns.distplot(df["DahiliBellek"], bins = 15);

# %%
sns.boxplot(df["DahiliBellek"]);

# %% [markdown]
# ### Kalinlik Distrubiton

# %%
df["Kalinlik"].describe()

# %%
sns.violinplot(df["Kalinlik"]);

# %%
sns.distplot(df["Kalinlik"], bins = 15);

# %%
sns.boxplot(df["Kalinlik"]);

# %% [markdown]
# ### Agirlik Distrubiton

# %%
df["Agirlik"].describe()

# %%
sns.violinplot(df["Agirlik"]);

# %%
sns.distplot(df["Agirlik"], bins = 15);

# %%
sns.boxplot(df["Agirlik"]);

# %% [markdown]
# ### CekirdekSayisi Distrubiton

# %%
df["CekirdekSayisi"].describe()

# %%
sns.violinplot(df["CekirdekSayisi"]);

# %%
sns.distplot(df["CekirdekSayisi"], bins = 15);

# %%
sns.boxplot(df["CekirdekSayisi"]);

# %% [markdown]
# ### ArkaKameraMP Distrubiton

# %%
df["ArkaKameraMP"].describe()

# %%
sns.violinplot(df["ArkaKameraMP"]);

# %%
sns.distplot(df["ArkaKameraMP"], bins = 15);

# %%
sns.boxplot(df["ArkaKameraMP"]);

# %% [markdown]
# ### CozunurlukYükseklik Distrubiton

# %%
df["CozunurlukYükseklik"].describe()

# %%
sns.violinplot(df["CozunurlukYükseklik"]);

# %%
sns.distplot(df["CozunurlukYükseklik"], bins = 15);

# %%
sns.boxplot(df["CozunurlukYükseklik"]);

# %% [markdown]
# ### CozunurlukGenislik Distrubiton

# %%
df["CozunurlukGenislik"].describe()

# %%
sns.violinplot(df["CozunurlukGenislik"]);

# %%
sns.distplot(df["CozunurlukGenislik"], bins = 15);

# %%
sns.boxplot(df["CozunurlukGenislik"]);

# %% [markdown]
# ### RAM Distrubiton

# %%
df["RAM"].describe()

# %%
sns.violinplot(df["RAM"]);

# %%
sns.distplot(df["RAM"], bins = 15);

# %%
sns.boxplot(df["RAM"]);

# %% [markdown]
# ### BataryaOmru Distrubiton

# %%
df["BataryaOmru"].describe()

# %%
sns.violinplot(df["BataryaOmru"]);

# %%
sns.distplot(df["BataryaOmru"], bins = 15);

# %%
sns.boxplot(df["BataryaOmru"]);

# %% [markdown]
# ### 3G Distrubiton

# %%
df["3G"].value_counts()

# %%
sns.countplot(df["3G"]);

# %% [markdown]
# ### Dokunmatik Distrubiton

# %%
df["Dokunmatik"].value_counts()

# %%
sns.countplot(df["Dokunmatik"]);

# %% [markdown]
# ### WiFi Distrubiton

# %%
df["WiFi"].value_counts()

# %%
sns.countplot(df["WiFi"]);

# %% [markdown]
# ### FiyatAraligi Distrubiton

# %%
df["FiyatAraligi"].value_counts()

# %%
sns.countplot(df["FiyatAraligi"]);

# %% [markdown]
# ### Renk Distrubiton

# %%
df["Renk"].value_counts()

# %%
sns.countplot(df["Renk"]);

# %% [markdown]
# ## İki Boyutlu Fiyat Aralığı Analizleri

# %%
sns.catplot(x = "BataryaGucu", y = "FiyatAraligi", data = df, height = 8, alpha = .5);

# %%
sns.catplot(x = "Bluetooth", y = "FiyatAraligi", data = df, height = 8, alpha = .5);

# %%
sns.catplot(x = "MikroislemciHizi", y = "FiyatAraligi", data = df, height = 8, alpha = .5);

# %%
sns.catplot(x = "CiftHat", y = "FiyatAraligi", data = df, height = 8, alpha = .5);

# %%
sns.catplot(x = "RAM", y = "FiyatAraligi", data = df, height = 8, alpha = .5);

# %%
sns.catplot(x = "4G", y = "FiyatAraligi", data = df, height = 8, alpha = .5);

# %%
sns.catplot(x = "DahiliBellek", y = "FiyatAraligi", data = df, height = 8, alpha = .5);

# %%
sns.catplot(x = "Kalinlik", y = "FiyatAraligi", data = df, height = 8, alpha = .5);

# %%
sns.catplot(x = "Agirlik", y = "FiyatAraligi", data = df, height = 8, alpha = .5);

# %%
sns.catplot(x = "CekirdekSayisi", y = "FiyatAraligi", data = df, height = 8, alpha = .5);

# %%
sns.catplot(x = "ArkaKameraMP", y = "FiyatAraligi", data = df, height = 8, alpha = .5);

# %%
sns.catplot(x = "CozunurlukYükseklik", y = "FiyatAraligi", data = df, height = 8, alpha = .5);

# %%
sns.catplot(x = "CozunurlukGenislik", y = "FiyatAraligi", data = df, height = 8, alpha = .5);

# %%
sns.catplot(x = "BataryaOmru", y = "FiyatAraligi", data = df, height = 8, alpha = .5);

# %%
sns.catplot(x = "3G", y = "FiyatAraligi", data = df, height = 8, alpha = .5);

# %%
sns.catplot(x = "Dokunmatik", y = "FiyatAraligi", data = df, height = 8, alpha = .5);

# %%
sns.catplot(x = "WiFi", y = "FiyatAraligi", data = df, height = 8, alpha = .5);

# %%
sns.catplot(x = "Renk", y = "FiyatAraligi", data = df, height = 8, alpha = .5);

# %% [markdown]
# Veri çerçevemizin ne kadar dengeli dağıldığını sorgulayalım.

# %%
df.value_counts().T

# %% [markdown]
# Veri çerçevemizin ne kadar dengeli olduğunu value_counts ile zaten görmüştük, ancak bunu görsel olarak ifade etmek için sns.countplot() fonksiyonuna FiyatAraligi parametresini verelim.

# %%
sns.countplot(x = "FiyatAraligi", data = df);

# %% [markdown]
# Veri çerçevemizin FiyatAraligi değişkeninin benzersiz kaç adet değer içerdiğini görüntüleyelim.

# %%
df["FiyatAraligi"].nunique()

# %% [markdown]
# value_counts() fonksiyonu ile hedef değişkenimizin ne kadar dengeli dağıldığını sorgulayalım.

# %%
df.FiyatAraligi.value_counts()

# %% [markdown]
# Korelasyon matrisi çizdirelim.

# %%
df.corr()

# %% [markdown]
# * Korelasyon katsayısı yorumu: İki değer arasındaki ilişki Korelasyon "1" değerine yaklaştıkça artar ve güçlenir.
# * Bu bilgiler ile veri setimizin "1" e yakın olup pozitif değere sahip olan değerlerimiz 0.645697 korelasyon katsayısı ile "OnKameraMP" ve "ArkaKameraMP	" değeridir.

# %%
corr = df.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values);

# %% [markdown]
# * Isı haritasını kullanmamızın sebebi renklendirme ile daha rahat korelasyon yorumu yapabildiğimizdir.
# * Açık renkler: Korelasyon yüksek yani bire yakın değerler. Mesela: "OnKameraMP" ve "ArkaKameraMP"

# %% [markdown]
# ArkaKameraMP ve OnKameraMP arasındaki korelasyonu daha iyi görebilmek için scatterplot çizdirelim.

# %%
sns.scatterplot(x = "ArkaKameraMP", y = "OnKameraMP", data = df);

# %% [markdown]
# OnKameraMP ve ArkaKameraMP arasında pozitif yönlü ve doğrusal bir artış vardır.

# %% [markdown]
# Veri çerçevesinin temel istatistik değerlerini görüntüleyelim.

# %%
df.describe().T

# %% [markdown]
# * Eğer bir veri ortalamaya yakın ise Standart Sapma'da düşük olacaktır. Eğer ortalamaya uzakta bir yaygın dağılım söz konusuysa standart sapma değeri de büyük olacaktır. Standart sapma varyansın kare kökü olduğundan dolayı ortalamaları ve standart sapma değerleri ile Varyans yorumu yapabiliriz.
# * Standart sapması en yüksek olan değer "RAM" dir. Bu yüzden en yüksek varyansa sahiptir.
# * Standart sapması en düşük değer ise "Kalinlik" dir. Bu yüzden en küçük varyans değerine sahiptir.

# %%
df.hist(figsize =(13,10))
plt.show()

# %% [markdown]
# * Histogram grafikleri genelde dağılıma bakmak için kullanılır.
# * figsize:Grafiğin boyutunu belirler. Parantez içinde yazılan ilk değer grafiğin enini, ikincisi boyutunu belirtir.
# * Sayısal özniteliklerin değişimine göre tablet sayılarının dağılımı

# %% [markdown]
# Veri çerçevesindeki RAM, MikroislemciHizi ve FiyatAraligi değişkenlerini görselleştirmek için önce scatterplot kullanalım.

# %%
sns.scatterplot(x = "RAM", y = "MikroislemciHizi",hue = df["FiyatAraligi"], data = df);

# %% [markdown]
# RAM ve MikroislemciHizi nın FiyatAraligi üzerindeki etkisi.

# %% [markdown]
# RAM ve FiyatAraligi verilerini farklı bir açıdan frekanslarıyla incelemek için jointplot kullanarak görselleştirelim.

# %%
sns.jointplot(x = "RAM", y = "FiyatAraligi", data = df, color="purple");

# %% [markdown]
# CekirdekSayisi ve FiyatAraligi verilerini farklı bir açıdan frekanslarıyla incelemek için jointplot kullanarak görselleştirelim.

# %%
sns.jointplot(x = "CekirdekSayisi", y = "FiyatAraligi", data = df, color="purple");

# %% [markdown]
# Keman grafiği çizdirerek RAM değişkeninin dağılımını inceleyin.
#
# Söz konusu dağılım bizim için ne ifade ediyor, normal bir dağılım olduğunu söyleyebilir miyiz?

# %%
sns.violinplot(x="RAM", data=df);

# %% [markdown]
# Normal bir dağılım olduğunu söyleyebiliriz.

# %% [markdown]
# Daha iyi anlayabilmek için RAM üzerine bir distplot çizdirelim.

# %%
sns.distplot(df["RAM"],bins=16, color="purple");

# %% [markdown]
#  FiyatAraligi değişkeni için dört farklı keman grafiğini RAM değişkeninin dağılımı üzerine tek bir satır ile görselleştirelim.

# %%
sns.violinplot(df["FiyatAraligi"],df["RAM"])

# %% [markdown]
# Veri çerçevesindeki RAM, BataryaGucu ve FiyatAraligi değişkenlerini görselleştirmek için önce scatterplot kullanalım.

# %%
sns.scatterplot(x=df["RAM"],y=df["BataryaGucu"],hue=df["FiyatAraligi"])

# %% [markdown]
# RAM ve BataryaGucu nün FiyatAraligi üzerindeki etkisi.

# %% [markdown]
# Veri çerçevesinde hangi öznitelikte kaç adet eksik değer olduğunu gözlemleyelim.

# %%
df.isnull().sum()

# %% [markdown]
# RAM ve OnKameraMP özniteliklerimizin Null değerleri yerine ortalama değerler yazdıralım.
#
# Bunun için daha önce görüntülemiş olduğumuz temel istatistik değerleri tekrar görüntüleyelim. Çoğunluğun sahip olduğu RAM ve OnKameraMP değerlerini Null alanlara yazdıralım.
#
# Daha sonra RAM ve OnKameraMP değerlerinde Null değer kalmış mı kontrol edelim.

# %%
df.describe().T

# %%
yeni_RAM= df[df["RAM"].isnull()].index
yeni_RAM

# %%
df.loc[yeni_RAM, "RAM"]= 2116.243964

# %%
df.isnull().sum()

# %%
yeni_OnKameraMP= df[df["OnKameraMP"].isnull()].index
yeni_OnKameraMP

# %%
df.loc[yeni_OnKameraMP, "OnKameraMP"]= 4.312281

# %%
df.isnull().sum()

# %% [markdown]
# Veri çerçevemizin Bluetooth özniteliğinin benzersiz değerlerini görüntüleyelim.

# %%
df["Bluetooth"].unique()

# %% [markdown]
# Kategorik değişkenlerin sıralanabilir(ordered) veya sıralanamaz(nominal) olma durumlarına göre uygun sayısallaştırma işlemleri yapılmalıdır.

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()

# %%
df["Bluetooth"] = le.fit_transform(df["Bluetooth"])
df.head()

# %%
df["CiftHat"] = le.fit_transform(df["CiftHat"])
df.head()

# %%
df["4G"] = le.fit_transform(df["4G"])
df.head()

# %%
df["3G"] = le.fit_transform(df["3G"])
df.head()

# %%
df["Renk"] = le.fit_transform(df["Renk"])
df.head()

# %%
df["Dokunmatik"] = le.fit_transform(df["Dokunmatik"])
df.head()

# %%
df["WiFi"] = le.fit_transform(df["WiFi"])
df.head()

# %% [markdown]
# Veri çerçevemizi bağımlı ve bağımsız değişkenler olmak üzere bölütleyelim.

# %%
X = df.drop("FiyatAraligi", axis = 1) #bağımsız değişkenler 
y = df["FiyatAraligi"] #bağımlı değişkenler

# %% [markdown]
# Bağımlı ve bağımsız değişkenleri kontrol edelim.

# %%
X #bağımsız değişkenler

# %%
y #bağımlı değişkenler

# %% [markdown]
# Bu bağımlı ve bağımsız değişkenlerden train ve test olmak üzere 4 parça oluşturalım. Bunu yapmak için  bağımlı ve bağımsız değişkenleri %85 oranında eğitim ve %15 oranında test olmak üzere “train_test_split” metodu kullanılarak ayrılmalıdır.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state = 42)

# %% [markdown]
# 4 parça değişkeni kontrol edelim.

# %%
X_train

# %%
X_test

# %%
y_train

# %%
y_test

# %% [markdown]
# Veriler üzerinden KNN modeli kuralım ve eğitelim.

# %%
knn = KNeighborsClassifier()
knn_model = knn.fit(X_train, y_train)

# %% [markdown]
# Bu parametre değerleri üzerinden eğitilen modelimizin tüm gözlemler için tahminde bulunmasını isteyelim.

# %%
y_pred = knn_model.predict(X_test)

# %% [markdown]
# Tüm gözlemler için bulunduğu tahminlere göre doğruluk skorunu görüntüleyelim.

# %%
accuracy_score(y_test, y_pred)

# %% [markdown]
# Modelin tüm verileri öğrendiği görülmekte. Karmaşıklık matrisini görüntüleyelim.

# %%
karmasiklik_matrisi = confusion_matrix(y_test, y_pred)
print(karmasiklik_matrisi)

# %% [markdown]
# Hedef özniteliğin değerlerine göre sınıflandırma raporunu görüntüleyelim.

# %%
print(classification_report(y_test, y_pred))

# %% [markdown]
# KNN modelini parametre optimizasyonu yaparak kuralım ve eğitelim.

# %%
knn_params = {"n_neighbors": np.arange(2,50)}

# %%
knn = KNeighborsClassifier()
knn_cv = GridSearchCV(knn, knn_params, cv = 3)
knn_cv.fit(X_train, y_train)

# %% [markdown]
# En yakın komşu sayısını 2 ile 50 arasında hepsini deneyecek.

# %%
print("En iyi skor: " + str(knn_cv.best_score_))
print("En iyi parametreler: " + str(knn_cv.best_params_))

# %%
knn = KNeighborsClassifier(13)
knn_tuned = knn.fit(X_train, y_train)

# %%
y_pred = knn_tuned.predict(X_test)

# %%
accuracy_score(y_test, y_pred)

# %% [markdown]
# Modelin k değerini nasıl seçtiğini görüntülemek için, 50 adet k değeri için doğruluk skorlarını görselleştirelim.

# %%
score_list = []

for each in range(2,50):
    knn2 = KNeighborsClassifier(n_neighbors = each)
    knn2.fit(X_train,y_train)
    score_list.append(knn2.score(X_test, y_test))
    
plt.plot(range(2,50),score_list)
plt.xlabel("k değerleri")
plt.ylabel("doğruluk skoru")
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# GaussianNB modeli yaratalım ve modelin eğitimini "tüm gözlemler üzerinde" gerçekleştirelim.

# %%
nb = GaussianNB() # modeli inşa ediyoruz.
nb_model = nb.fit(X, y) # modelin eğitimini sadece eğitim değil,  [eğitim + test] tüm gözlemler üzerinde yapıyoruz.

# %% [markdown]
# Veri çerçevesindeki tüm gözlemleri tahmin edip y_pred değişkenine atayalım.

# %%
y_pred = nb_model.predict(X_test)

# %% [markdown]
# Confusion Matrix skoru olan accuracy değerine bakalım.

# %%
accuracy_score(y_test, y_pred)

# %% [markdown]
#  Karmaşıklık matrisini çizdirelim.

# %%
karmasiklik_matrisi = confusion_matrix(y_test, y_pred)
print(karmasiklik_matrisi)

# %% [markdown]
# Sınıflandırma raporu çizdirelim.

# %%
print(classification_report(y_test, y_pred))

# %% [markdown]
# Modelimizi inşa edelim ve eğitelim. Varsayılan olarak (criterion = “gini”) parametre değerini  criterion parametresini (criterion = “entropy”) olarak değiştirelim.

# %%
treeModel = DecisionTreeClassifier(random_state = 42, criterion='entropy')
treeModel.fit(X_train, y_train)

# %% [markdown]
# Modelin haberdar olmadığı X_test gözlemlerini tahmin ettirelim ve y_pred'e atayalım.

# %%
y_pred = treeModel.predict(X_test)

# %% [markdown]
# Daha önce hiç görmediği X_test verileri için bulunduğu tahminlere göre doğruluk skorunu görüntüleyelim.

# %%
accuracy_score(y_test, y_pred)

# %% [markdown]
# Karmaşıklık matrisini görüntüleyelim.

# %%
karmasiklik_matrisi = confusion_matrix(y_test, y_pred)
print(karmasiklik_matrisi)

# %% [markdown]
# Hedef özniteliğin değerlerine göre sınıflandırma raporunu görüntüleyelim.

# %%
print(classification_report(y_test, y_pred))
