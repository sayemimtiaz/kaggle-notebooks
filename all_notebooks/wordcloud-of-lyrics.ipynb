# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # GOAL: Create a word cloud for each artist.

# %%
# Install word_cloud 
# !ssh-keygen -F github.com || ssh-keyscan github.com >> ~/.ssh/known_hosts
# !pip install git+https://github.com/kavgan/word_cloud.git
from word_cloud.word_cloud_generator import WordCloud
from IPython.core.display import HTML

# %% [markdown]
# **Lets try it out, who is the lucky first: ColdPlay 🎉**

# %%
songs = "../input/song-lyrics-dataset/csv files/EdSheeran.csv"
df = pd.read_csv(cold_play_songs,index_col=False)
df.reset_index(drop=True, inplace=False)
df.head()

# %%
# for each column in the dataframe
all_lyrics = []
lyrics = df["Lyrics"]
for lyric in lyrics:
    all_lyrics.append(str(lyric))

# %%
# initialize WordCloud
wc=WordCloud()

# get html code
embed_code=wc.get_embed_code(text=all_lyrics,random_color=True,topn=40)

# display
HTML(embed_code)

# %% [markdown]
# That does not look, good, maybe throw out these notes, like Verse, Chorus..., just everything that is in these square brackets. With this regex: \[.*?\]

# %%
import re
clean_all_lyrics = []
for lyric in all_lyrics:
    entry = re.sub("\[.*?\]","",lyric)
    clean_all_lyrics.append(entry)

# %% [markdown]
# Looks good, lets try the next word cloud on it.

# %%
# get html code
embed_code=wc.get_embed_code(text=clean_all_lyrics,random_color=True,topn=24)

# display
HTML(embed_code)

# %% [markdown]
# That looks nice, but I wanna do only a percentage of words.

# %%
total_word_count = 0
for clean_lyric in clean_all_lyrics:
    split_string = clean_lyric.split()
    #print(split_string)
    word_count = len(split_string)
    #print(word_count)
    total_word_count += word_count
print(total_word_count)
word_cloud_topn = int(np.floor(total_word_count * 0.001))
print(word_cloud_topn)

# %%
# get html code
embed_code=wc.get_embed_code(text=clean_all_lyrics,random_color=True,topn=word_cloud_topn)

# display
HTML(embed_code)
