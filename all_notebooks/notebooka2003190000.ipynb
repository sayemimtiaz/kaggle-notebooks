# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt

df =pd.read_csv('/kaggle/input/titanic/train.csv')

df.head()

df.info()

# %%
def clean_missing(df):
    from sklearn.impute import SimpleImputer
    from sklearn.pipeline import Pipeline
    from sklearn.compose import ColumnTransformer
    
    df_missing_values=df.isnull().sum()
    
    df_numeric_columns=df.select_dtypes(include=["int64","float64"]).keys()
    columns_numeric_missing=[var for var in df_numeric_columns if df_missing_values[var]>0]
    
    df_categorical_columns=df.select_dtypes(include=["object"]).keys()
    columns_categorical_missing=[var for var in df_categorical_columns if df_missing_values[var]>0]
    
    numeric_value_mean_imputer=Pipeline(steps=[("imputer",SimpleImputer(strategy='mean'))])

    categorical_value_mode_imputer=Pipeline(steps=[("imputer",SimpleImputer(strategy='most_frequent'))])

    preprocessing=ColumnTransformer(transformers=[("mean_imputer", numeric_value_mean_imputer, columns_numeric_missing),
                                              ("mode_imputer", categorical_value_mode_imputer, columns_categorical_missing)])
    
    df_clean_null_value=preprocessing.fit_transform(df)
    
    df_missing_value_solve=pd.DataFrame(df_clean_null_value, columns=columns_categorical_missing+columns_numeric_missing)
    
    df.update(df_missing_value_solve)
    
    return df

# %%
df=clean_missing(df)
df.info()

# %%
df.Sex.value_counts()
df.Survived.value_counts()

# %%
df.groupby('Sex').Survived.mean().plot(kind='pie', normalize=False)
print (df.groupby('Sex').Survived.value_counts())

# %%
df.Survived.value_counts().plot(kind='pie', normalize=True)
print (df.groupby('Sex').Survived.value_counts())

# %%
#plt.figure(figsize=(5,5))
df.Sex.value_counts().plot(kind = 'bar')
print (df.Sex.value_counts())

# %%
x=df['Age']
y=df['PassengerId'].astype(np.float64)

plt.plot(x, y)
plt.xlabel("Age")  
plt.ylabel("PassengerId")  
plt.title("Age Vs PassengerId")  
plt.show()

# %%
plt.subplot(2,2,1)
plt.hist(df['Survived'], bins = 15)
plt.title('A Histogram of Survived from the Titanic Data Set')

plt.subplot(2,2,2)
plt.hist(df['PassengerId'], bins = 15)
plt.title('A Histogram of PassengerId from the Titanic Data Set')

plt.subplot(2,2,3)
plt.hist(df['Pclass'], bins = 15)
plt.title('A Histogram of Pclass from the Titanic Data Set')

plt.subplot(2,2,4)
plt.hist(df['Name'], bins = 15)
plt.title('A Histogram of Name from the Titanic Data Set')

plt.subplot(2,2,4)
plt.hist(df['Age'], bins = 15)
plt.title('A Histogram of Age from the Titanic Data Set')

plt.subplot(2,2,4)
plt.hist(df['Sex'], bins = 15)
plt.title('A Histogram of Sex from the Titanic Data Set')

plt.subplot(2,2,4)
plt.hist(df['SibSp'], bins = 15)
plt.title('A Histogram of SibSp from the Titanic Data Set')

plt.subplot(2,2,4)
plt.hist(df['Parch'], bins = 15)
plt.title('A Histogram of Parch from the Titanic Data Set')

plt.subplot(2,2,4)
plt.hist(df['Ticket'], bins = 15)
plt.title('A Histogram of Ticket from the Titanic Data Set')

plt.subplot(2,2,4)
plt.hist(df['Fare'], bins = 15)
plt.title('A Histogram of Fare from the Titanic Data Set')

plt.subplot(2,2,4)
plt.hist(df['Cabin'], bins = 15)
plt.title('A Histogram of Cabin from the Titanic Data Set')

plt.subplot(2,2,4)
plt.hist(df['Embarked'], bins = 15)
plt.title('A Histogram of Embarked from the Titanic Data Set')

# %%
df.hist(bins=10, figsize=(10, 7), grid = False);
