# %%
import pandas as pd
data = pd.Series([0.25, 0.5, 0.75, 1.0],
                 index=['a', 'b', 'c', 'd'])
data

data['b']

'a' in data

data.keys()

list(data.items())

data['a':'c']


data[0:2]

data[(data > 0.3) & (data < 0.8)]

area = pd.Series({'California': 423967, 'Texas': 695662,
                  'New York': 141297, 'Florida': 170312,
                  'Illinois': 149995})
pop = pd.Series({'California': 38332521, 'Texas': 26448193,
                 'New York': 19651127, 'Florida': 19552860,
                 'Illinois': 12882135})
data = pd.DataFrame({'area':area, 'pop':pop})
data

data['area']

data.area

data.area is data['area']

data.pop is data['pop']

data['density'] = data['pop'] / data['area']
data

data.values

data.T

data.iloc[:3, :2]

data.loc[:'Illinois', :'pop']

data.loc[data.density > 100, ['pop', 'density']]

import pandas as pd
import numpy as np

rng = np.random.RandomState(42)
ser = pd.Series(rng.randint(0, 10, 4))
ser

df = pd.DataFrame(rng.randint(0,10, (3, 4)),
                  columns=['A', 'B', 'C', 'D'])
df

np.exp(ser)

area = pd.Series({'Alaska': 1723337, 'Texas': 695662,
                  'California': 423967}, name='area')
population = pd.Series({'California': 38332521, 'Texas': 26448193,
                        'New York': 19651127}, name='population')

population / area

area.index | population.index

A = pd.Series([2, 4, 6], index=[0, 1, 2])
B = pd.Series([1, 3, 5], index=[1, 2, 3])
A + B

A.add(B, fill_value=0)

A = pd.DataFrame(rng.randint(0, 20, (2, 2)),
                 columns=list('AB'))
A

B = pd.DataFrame(rng.randint(0, 10, (3, 3)),
                 columns=list('BAC'))
B

A+B

A = rng.randint(10, size=(3, 4))
A


A - A[0]

import numpy as np
import pandas as pd
df = pd.read_csv("/home/mohi/Downloads/Churn_Modelling.csv")
df.shape
(10000,14)
df.columns

df_spec = pd.read_csv("/home/mohi/Downloads/Churn_Modelling.csv", usecols=['Gender', 'Age', 'Tenure', 'Balance'])
df_spec.head()

df_partial = pd.read_csv("/home/mohi/Downloads/Churn_Modelling.csv", nrows=5000)
df_partial.shape

df_sample = df.sample(n=1000)
df_sample.shape

df_sample2 = df.sample(frac=0.1)
df_sample2.shape

df.isna().sum()

missing_index = np.random.randint(10000, size=20)

df.loc[missing_index, ['Balance','Geography']] = np.nan

df.iloc[missing_index, -1] = np.nan

df.isna().sum()

mode = df['Geography'].value_counts().index[0]
df['Geography'].fillna(value=mode, inplace=True)

df['Geography'].value_counts()

avg = df['Balance'].mean()
df['Balance'].fillna(value=avg, inplace=True)

df.dropna(axis=0, how='any', inplace=True)

df.isna().sum()

france_churn = df[(df.Geography == 'France') & (df.Exited == 1)]
france_churn.Geography.value_counts()

#The query function provides a more flexible way of passing the conditions.
df2 = df.query('80000 < Balance < 100000')

df2['Balance'].plot(kind='hist', figsize=(8,5))

df[df['Tenure'].isin([4,6,9,10])][:3]

df[['Geography','Gender','Exited']].groupby(['Geography','Gender']).mean()

df[['Geography','Gender','Exited']].groupby(['Geography','Gender']).agg(['mean','count'])

df_new = df[['Geography','Exited','Balance']]\
.groupby(['Geography','Exited']).mean().reset_index()
df_new

df[['Geography','Exited','Balance']].sample(n=6).reset_index()

df_new.set_index('Geography')

group = np.random.randint(10, size=6)
df_new['Group'] = group
df_new

df_new['Balance'] = df_new['Balance'].where(df_new['Group'] >= 6, 0)
df_new

df_new['rank'] = df_new['Balance'].rank(method='first', ascending=False).astype('int')
df_new

df['Geography'] = df['Geography'].astype('category')

df.memory_usage()

 df['Balance'].plot(kind='hist', figsize=(10,6),title='Customer Balance')

#Styling a dataframe
df_new.style.highlight_max(axis=0, color='darkgreen')
