# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('../input/car-purchasing-model/Car_Purchasing_Data.csv')

# %%
dataset.shape

# %%
len(dataset)

# %%
dataset.head(10)

# %%
dataset.tail(10)

# %%
dataset.info()

# %%
dataset.columns

# %%
dataset.describe()

# %%
len(dataset["Customer Name"].unique())

# %%
dataset["Customer Name"].nunique()

# %%
dataset.isna().sum()

# %%
#Univariate Data Analysis(UDA)

# %%
dataset['Country'].value_counts()

# %%
sns.countplot(dataset['Country'])

# %%
dataset['Gender'].value_counts()

# %%
sns.countplot(dataset['Gender'])

# %%
sns.distplot(dataset['Age'])

# %%
sns.boxplot(dataset['Age'])

# %%
sns.boxplot(dataset['Annual Salary'])

# %%
sns.distplot(dataset['Annual Salary'])

# %%
sns.distplot(dataset['Credit Card Debt'])

# %%
sns.boxplot(dataset['Credit Card Debt'])

# %%
sns.distplot(dataset['Net Worth'])

# %%
sns.boxplot(dataset['Net Worth'])

# %%
sns.distplot(dataset['Car Purchase Amount'])

# %%
sns.boxplot(dataset['Car Purchase Amount'])

# %%
dataset.corr()

# %%
sns.pairplot(dataset)

# %%
#Data Preparation

# %%
dataset.drop(['Customer Name','Customer e-mail', 'Country'] , axis = 1, inplace=True)

# %%
dataset.head()

# %%
X = dataset.iloc[:,:-1]
Y = dataset.iloc[:,-1]

# %%
X

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,random_state=0)

# %%
X_train

# %%
X_test

# %%
Y_train

# %%
Y_test

# %%
#Modelling using Linear Regression

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,Y_train)

# %%
regressor.coef_

# %%
regressor.intercept_

# %%
Y_pred = regressor.predict(X_test)

# %%
Y_test

# %%
np.stack((Y_test,Y_pred),axis=1)

# %%
from sklearn.metrics import r2_score
rsq = r2_score(Y_test,Y_pred)
rsq

# %%
X_test.shape

# %%
n = X_test.shape[0]
p = X_test.shape[1]

adj_rsq = 1-(1-rsq)*(n/1)/(n/-p-1)
adj_rsq

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor()
regressor.fit(X_train,Y_train)

# %%
Y_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
rsq = r2_score(Y_test,Y_pred)
print(rsq)

# %%
X_test.shape

n = X_test.shape[0]
p = X_test.shape[1]

adj_rsq = 1-(1-rsq)*(n/1)/(n-p-1)
adj_rsq

# %%
#Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train,Y_train)

# %%
Y_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
rsq = r2_score(Y_test,Y_pred)
print(rsq)

X_test.shape

n = X_test.shape[0]
p = X_test.shape[1]

adj_rsq = 1-(1-rsq)*(n/1)/(n-p-1)
adj_rsq
