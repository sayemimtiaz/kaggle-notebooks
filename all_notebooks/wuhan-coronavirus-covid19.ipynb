# %% [markdown]
# ## Wuhan Coronavirus - Covid19

# %% [markdown]
# ### What is Corona Virus(COVID-19)?
#
# Coronavirus is a family of viruses that can cause illness, which can vary from common cold and cough to sometimes more severe disease. SARS-CoV-2 (n-coronavirus) is the new virus of the coronavirus family, which first discovered in 2019, which has not been identified in humans before. It is a contiguous virus which started from Wuhan in December 2019. Which later declared as Pandemic by WHO due to high rate spreads throughout the world. Currently (on date 27 March 2020), this leads to a total of 24K+ Deaths across the globe, including 16K+ deaths alone in Europe.Pandemic is spreading all over the world; it becomes more important to understand about this spread. This NoteBook is an effort to analyze the cumulative data of confirmed, deaths, and recovered cases over time. In this notebook, the main focus is to analyze the spread trend of this virus all over the india.
#
# ### History of COVID-19 in India
# On January 30, India reported its first case of COVID-19 in Kerala, which rose to three cases by February 3; all were students who had returned from Wuhan, China.No significant rise in cases was seen in the rest of February.
#
# On 22 March 2020, India observed a 14-hour voluntary public curfew at the instance of the prime minister Narendra Modi.The government followed it up with lockdowns in 75 districts where COVID cases had occurred as well as all major cities.Further, on 24 March, the prime minister ordered a nationwide lockdown for 21 days, affecting the entire 1.3 billion population of India.
#
# The transmission escalated during March, after several cases were reported all over the country, most of which were linked to people with a travel history to affected countries. On 12 March, a 76-year-old man who had returned from Saudi Arabia became the first victim of the virus in the country.On 4 March, 22 new cases came to light, including those of an Italian tourist group with 14 infected members.But number of cases start increasing dramtically after 19th March, but in the month of April it has been its peak.
#
# Experts suggest the number of infections could be much higher as India's testing rates are among the lowest in the world.The infection rate of COVID-19 in India is reported to be 1.7, significantly lower than in the worst affected countries.

# %% [markdown]
# ### Import Libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import plotly as py
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go
import  folium
import requests

# %% [markdown]
# ### Datatsets

# %%
df_conf = pd.read_csv('../input/novel-corona-virus-2019-dataset/time_series_covid_19_confirmed.csv')
df_death = pd.read_csv('../input/novel-corona-virus-2019-dataset/time_series_covid_19_deaths.csv')
df_recover = pd.read_csv('../input/novel-corona-virus-2019-dataset/time_series_covid_19_recovered.csv')
df_India = pd.read_csv('../input/covid19-in-india/covid_19_india.csv')
df_country = pd.read_csv('../input/corona-virus-report/covid_19_clean_complete.csv')
df = pd.read_json('https://www.mohfw.gov.in/data/datanew.json')

# %%
df = df.iloc[:-1:,1:]

# %% [markdown]
# ### Total Number of Cases in India

# %%
df_state = df.set_index('state_name')
report = pd.DataFrame(pd.to_numeric(df.iloc[:,1:9].sum()),dtype=np.int64).transpose()
report.style.background_gradient(cmap='Wistia',axis=1).format("{:.2f}").format("{:.0f}",subset=["active","positive","cured","death","new_active","new_positive","new_cured","new_death"])

# %%
total_c = np.arange(len(df['state_name']))
df_sorted= df.sort_values('positive')

# %% [markdown]
# ### Stack all the column in Bar Chart

# %%
state_index = df.set_index('state_name', drop = True)
state_index.head()
state_index.plot.barh(stacked = True, figsize = (12,8))
plt.title('Corona Cases')

# %% [markdown]
# ### Comparison between Positive and Recovered Cases

# %%
bar_plot = state_index.iloc[:,1:3]
bar_plot.plot.barh(figsize=(12,8))
plt.title('Positive Vs Cured')
plt.show()

# %% [markdown]
# ### Comparison between Active and Death Cases

# %%
active_death = state_index.iloc[:,[0,3]]
active_death.plot.barh(figsize =(12,10))

# %% [markdown]
# ### Total Number of Cases in Percentage

# %%
Total_confirmed = df['active'].sum()
Total_recovered =  df['cured'].sum()
Total_death = df['death'].sum()
Total_positive = df['positive'].sum()
data12 = [['Active', Total_confirmed], ['Recovered', Total_recovered], ['Death', Total_death],['Positive',Total_positive]] 
df123 = pd.DataFrame(data12, columns = ['Cases', 'count']) 
fig = px.pie(df123,
             values= 'count',labels=['Active Cases','Cured','Death'],
             names="Cases",
             title="Total Number of Cases",
             template="seaborn")
fig.update_traces(hoverinfo='label+percent', textinfo='value', textfont_size=14,
                  marker=dict(colors=['#263fa3', '#2fcc41','#ff0000','#ff8800'], line=dict(color='#FFFFFF', width=2)))
fig.update_traces(textposition='inside')
#fig.update_layout(uniformtext_minsize=12, uniformtext_mode='hide')
fig.update_traces(rotation=90, pull=0.05, textinfo="percent+label")
fig.show()

# %% [markdown]
# ### Distribution of Cases in India

# %%
df.style.background_gradient(cmap='Reds',subset=["death"])\
                        .background_gradient(cmap='Pastel1_r',subset=["positive"])\
                        .background_gradient(cmap='Greens',subset=["cured"])\
                        .background_gradient(cmap='Purples',subset=["active"])\
                        .background_gradient(cmap='Blues',subset=["new_active"])\
                        .background_gradient(cmap='Oranges',subset=["new_positive"])\
                        .background_gradient(cmap='Greys',subset=["new_cured"])

# %% [markdown]
# ### Following Visualization Made from flourish

# %% [markdown]
# ### Top-10 Countries in Confirmed Cases

# %%
# %%HTML
# <iframe src='https://flo.uri.sh/visualisation/4170852/embed' title='Interactive or visual content' frameborder='0' scrolling='no' style='width:100%;height:450px;'></iframe>
# <div style='width:100%!;margin-top:4px!important;text-align:right!important;'><a class='flourish-credit' href='https://public.flourish.studio/visualisation/4170852/?utm_source=embed&utm_campaign=visualisation/4170852' target='_top' style='text-decoration:none!important'><img alt='Made with Flourish' src='https://public.flourish.studio/resources/made_with_flourish.svg' style='width:105px!important;height:16px!important;border:none!important;margin:0!important;'> </a></div>

# %% [markdown]
# ### Top-10 Countries in Recovered Cases

# %%
# %%HTML
# <iframe src='https://flo.uri.sh/visualisation/4169789/embed' title='Interactive or visual content' frameborder='0' scrolling='no' style='width:100%;height:450px;'></iframe>
# <div style='width:100%!;margin-top:4px!important;text-align:right!important;'><a class='flourish-credit' href='https://public.flourish.studio/visualisation/4169789/?utm_source=embed&utm_campaign=visualisation/4169789' target='_top' style='text-decoration:none!important'><img alt='Made with Flourish' src='https://public.flourish.studio/resources/made_with_flourish.svg' style='width:105px!important;height:16px!important;border:none!important;margin:0!important;'> </a></div>

# %% [markdown]
# ### Top-10  Countries in Death Cases

# %%
# %%HTML
# <iframe src='https://flo.uri.sh/visualisation/4170505/embed' title='Interactive or visual content' frameborder='0' scrolling='no' style='width:100%;height:450px;'></iframe>
# <div style='width:100%!;margin-top:4px!important;text-align:right!important;'><a class='flourish-credit' href='https://public.flourish.studio/visualisation/4170505/?utm_source=embed&utm_campaign=visualisation/4170505' target='_top' style='text-decoration:none!important'><img alt='Made with Flourish' src='https://public.flourish.studio/resources/made_with_flourish.svg' style='width:105px!important;height:16px!important;border:none!important;margin:0!important;'> </a></div>

# %% [markdown]
# ### Number of Active Cases, Confirmed Cases, Recovered Cases and Death Cases
# We can choose different categories from below dropdown.

# %%
# %%HTML
# <iframe src='https://flo.uri.sh/visualisation/4172415/embed' title='Interactive or visual content' frameborder='0' scrolling='no' style='width:100%;height:400px;'></iframe>
# <div style='width:100%!;margin-top:4px!important;text-align:right!important;'><a class='flourish-credit' href='https://public.flourish.studio/visualisation/4172415/?utm_source=embed&utm_campaign=visualisation/4172415' target='_top' style='text-decoration:none!important'><img alt='Made with Flourish' src='https://public.flourish.studio/resources/made_with_flourish.svg' style='width:105px!important;height:16px!important;border:none!important;margin:0!important;'> </a></div>

# %% [markdown]
# ### Offline Plotly Usage
# Get imports and set everything up to be working offline.

# %%
py.offline.init_notebook_mode(connected=True)
cf.go_offline()

# %% [markdown]
# ### State-wise Confirmed Cases

# %%
fig = px.line(df_India, x='Date', y='Confirmed', color='State/UnionTerritory', title='India: State-wise Confirmed Cases')
fig.update_layout(hovermode='closest',template='seaborn',width=700,xaxis=dict(mirror=True,linewidth=2,linecolor='black',showgrid=False),
                 yaxis=dict(mirror=True,linewidth=2,linecolor='black'))
fig.show()

# %% [markdown]
# ### State-wise Death Cases

# %%
fig = px.line(df_India, x='Date', y='Deaths', color='State/UnionTerritory', title='India: State-wise Death Cases')
fig.update_layout(hovermode='closest',template='seaborn',width=700,xaxis=dict(mirror=True,linewidth=2,linecolor='black',showgrid=False),
                 yaxis=dict(mirror=True,linewidth=2,linecolor='black'))
fig.show()

# %% [markdown]
# ### State-wise Recovered Cases

# %%
fig = px.line(df_India, x='Date', y='Cured', color='State/UnionTerritory', title='India: State-wise Recovered Cases')
fig.update_layout(hovermode='closest',template='seaborn',width=700,xaxis=dict(mirror=True,linewidth=2,linecolor='black',showgrid=False),
                 yaxis=dict(mirror=True,linewidth=2,linecolor='black'))
fig.show()

# %% [markdown]
# ### Country-wise Confirmed Cases

# %%
fig = px.line(df_country, x='Date', y='Confirmed', color='Country/Region', title='Country-wise Confirmed Cases')
fig.update_layout(hovermode='closest',template='seaborn',width=700,xaxis=dict(mirror=True,linewidth=2,linecolor='black',showgrid=False),
                 yaxis=dict(mirror=True,linewidth=2,linecolor='black'))
fig.show()

# %% [markdown]
# ### Top 10 Countries with Confirmed Cases

# %%
df_country.groupby('Country/Region')['Confirmed'].sum().nlargest(10).iplot(xTitle = "Top 10 Countries", yTitle= "Number of Cases",title = 'Top 10 Countries with Confirmed Cases')

# %% [markdown]
# ### Top 10 Countries with Death Cases

# %%
df_country.groupby('Country/Region')['Deaths'].sum().nlargest(10).iplot(xTitle = "Top 10 Countries", yTitle= "Number of Cases",title = 'Top 10 Countries with Death Cases')

# %% [markdown]
# ### Top 10 Countries with Recovered Cases

# %%
df_country.groupby('Country/Region')['Recovered'].sum().nlargest(10).iplot(xTitle = "Top 10 Countries", yTitle= "Number of Cases",title = 'Top 10 Countries with Recovered Cases')

# %% [markdown]
# ### Number of Active Cases State Wise

# %%
df.iplot(x = 'state_name', y ='active', title = "Number of Active Cases")

# %% [markdown]
# ### Number of Death Cases State Wise

# %%
df.iplot(x = 'state_name', y ='death', title = "Number of Death Cases")

# %% [markdown]
# ### Number of New active, recovered and death cases

# %%
df.iloc[:,[6,8,9]].iplot(title =" Number of New Active ,Recovered and Death Cases")

# %% [markdown]
# ### Number of Cases in Worldwide at Starting of Every Month

# %% [markdown]
# ### 1 February

# %%
df_conf.iplot(x = 'Country/Region', y = '2/1/20', title='Number of Cases on 1 February', xTitle='Countries', yTitle='Number of Cases')

# %% [markdown]
# ### 1 March

# %%
df_conf.iplot(x = 'Country/Region', y = '3/1/20', title='Number of Cases on 1 March', xTitle='Countries', yTitle='Number of Cases')

# %% [markdown]
# ### 4 April

# %%
df_conf.iplot(x = 'Country/Region', y = '4/1/20', title='Number of Cases on 1 April', xTitle='Countries', yTitle='Number of Cases')

# %% [markdown]
# ### 1 May

# %%
df_conf.iplot(x = 'Country/Region', y = '5/1/20', title='Number of Cases on 1 May', xTitle='Countries', yTitle='Number of Cases')

# %% [markdown]
# ### 1 June

# %%
df_conf.iplot(x = 'Country/Region', y = '6/1/20', title='Number of Cases on 1 June', xTitle='Countries', yTitle='Number of Cases')

# %% [markdown]
# ### 1 July

# %%
df_conf.iplot(x = 'Country/Region', y = '7/1/20', title='Number of Cases on 1 July', xTitle='Countries', yTitle='Number of Cases')

# %% [markdown]
# ### 1 August

# %%
df_conf.iplot(x = 'Country/Region', y = '8/1/20', title='Number of Cases on 1 August', xTitle='Countries', yTitle='Number of Cases')

# %% [markdown]
# ### 1 September

# %%
df_conf.iplot(x = 'Country/Region', y = '9/1/20', title='Number of Cases on 1 September', xTitle='Countries', yTitle='Number of Cases')

# %%
df_India[['Confirmed','Deaths']].iplot(kind ='spread')
