# %% [markdown]
# ## This is a project for my math class and is constructed using a basic computer-dataset ##
#
#  - Liam Larsen
#  - June 12, 2017
#  - Algebra 2
#  - Unit 6 Lesson 10

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
df = pd.read_csv("../input/Computers.csv")
import matplotlib.pyplot as plt
from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

# %% [markdown]
# Part 1
# ------
#
# Collect a set of data with at least 30 data points. The data should be quantitative,
# which means that it should be measured using numbers. You can be as creative as
# you’d like, but here are some suggestions for things that you can survey.
#
#  - the heights of a large number of people
#  - the number of pages in a set of books on a bookshelf
#  - the number of hits earned by different professional baseball players
#    in a season
#
# Part 2
# ------
#
# Create a visual representation of your data. If the data is continuous, use a
# histogram. If the data is discrete, use a bar graph. Make sure to label the axes with
# appropriate titles and incorporate the appropriate scale on each axis.
#
# Part 3
# ------
#
# Respond to the following questions.
#
#  1. What are the mean and standard deviation of the set of data?
#  2. Does the data follow a normal distribution? Be sure to mathematically justify
# your answer.
#  3. Answer one of the following questions.
# a. If your sample follows a normal distribution, does this makes sense to
# you? Explain why.
# b. If your sample does not follow a normal distribution (e.g., it could be
# skewed left or right, have a uniform distribution, or have some other
# shape), then why might this be the reason?
#  4. Describe your survey process. What are some sources of possible bias in
# your sample? Alternatively, what did you do to ensure a random sample?
#  5. What is a set of data that you would like to study in the future? How could
# you go about ensuring an unbiased random sample?

# %% [markdown]
# Let us take a look at the data and extract the columns we want.

# %%
prices = df.price # Extracting the prices column
prices.head(10) # Printing the first 10 values

# %% [markdown]
# This was the first attempt at graphing the data, it seems as I might need to use more datapoints
# ------------------------------------------------------------------------

# %%
fig, ax = plt.subplots(figsize=(15, 7))
plt.xticks(rotation=45)
plt.yticks()
plt.style.use('ggplot')
plt.title("Computer Prices in the Early 90's")
plt.xlabel("Number")
plt.ylabel("Price")
ax.plot(prices.head(80))
plt.show()

# %% [markdown]
# With the boxplot
# ----------------

# %%
fig = plt.subplots(figsize=(15, 10))
plt.xticks()
plt.yticks()
plt.title("Computer Prices in the Early 90's")
plt.xlabel("Number")
plt.ylabel("Price")
plt.boxplot(prices.head(300), 0, 'rs', 0)
plt.show()

# %% [markdown]
# ## Now to part 2 ##
#  1. What are the mean and standard deviation of the set of data?
#  2. Does the data follow a normal distribution? Be sure to mathematically justify
# your answer.
#  3. Answer one of the following questions.
# If your sample follows a normal distribution, does this makes sense to
# you? Explain why.
# If your sample does not follow a normal distribution (e.g., it could be
# skewed left or right, have a uniform distribution, or have some other
# shape), then why might this be the reason?
#  4. Describe your survey process. What are some sources of possible bias in
# your sample? Alternatively, what did you do to ensure a random sample?
#
#  5. What is a set of data that you would like to study in the future? How could
# you go about ensuring an unbiased random sample?

# %% [markdown]
# ## Number 1 ##

# %%
# How to calculate mean, sum of all values / number of values
mean = prices.sum() / prices.size  

# Print values
print("Mean of data: " + str(mean) )
print("Mean of data using built in function: " + str(prices.mean()) )

# %% [markdown]
# ## Number 2 ##

# %%
# Lets plot a histogram to see if our data is normally distributed
fig= plt.subplots(figsize=(15, 10))
plt.xticks()
plt.yticks()
plt.title("Histogram of data")
plt.xlabel("Price")
plt.ylabel("Number")
plt.hist(prices)
plt.show()

# %% [markdown]
# It seems that the data is more skewed to the left. So, no - the data is not normally distributed.
# ------------------------------------------------------------------------

# %% [markdown]
# ## Number 3 ##

# %% [markdown]
# The reason why the data is skewed to the left is that most of the computer prices are in the $2000's, while the maximum is in the $5000's. This causes an uneven distribution in the dataset.

# %% [markdown]
# ## Number 4 ##

# %% [markdown]
# A. Sources of possible bias
#     I think sources of possible bias were in the graphs when the entire set is almost 6000 datapoints.
#
#
# ----------
#
#
# B. What did you do to ensure a random sample?
#     I created this dataset from old computer prices, the data was always static and the prices were taken with mindfulness to potential bias in the data.

# %% [markdown]
# ## Number 5 ##

# %% [markdown]
# A set of data that I would like to study in the future?
# With kaggle.com I can basically analyze and look at all walks of data, I'm really into data analysis and most of my kernels are here: [https://www.kaggle.com/kingburrito666/kernels][1]
# When getting unbias random samples, you want to ask unbiased general (not too general) questions about what you are collecting data for. If your data is purely statistical and requires no question/answer, it's much different for random sampling and is based upon the task at hand.
#
#   [1]: https://www.kaggle.com/kingburrito666/kernels
