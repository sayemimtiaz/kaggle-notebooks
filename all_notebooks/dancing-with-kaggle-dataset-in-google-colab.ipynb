# %% [markdown]
# # This is just a draft!
# **Please comment if you know any questions about this topic**
# * Thank you

# %% [markdown]
# **Note:** Google Colab got an outdated Version of Kaggle API so you need to run this code before

# %%
# !pip install --upgrade --force-reinstall --no-deps kaggle

# %% [markdown]
# # get_gcs_path

# %% [markdown]
# a copy of All Kaggle Datasets alrady in Google Cloud Storage
#
# **Note:** The path chnaged every few days.

# %%
from kaggle_datasets import KaggleDatasets
digit_recognizer = KaggleDatasets().get_gcs_path('digit-recognizer')
print(f'digit_recognizer  = "{digit_recognizer}"')

# %%
# !gsutil -m cp -r gs://kds-151185c9501c719fba9ac40576b098ab63a00f8cf73f44636acf89d3/ /content/

# %% [markdown]
# https://cloud.google.com/storage/docs/gsutil/commands/cp

# %% [markdown]
# (-r) enables directories, buckets, and bucket subdirectories to be copied recursively.
#
# (- m) performs a parallel multi-threaded/multi-processing copy
#
# https://cloud.google.com/storage/docs/gsutil/commands/cp
# https://cloud.google.com/storage/docs/gsutil/addlhelp/TopLevelCommandLineOptions

# %% [markdown]
# # gsutil supports URI wildcards.

# %% [markdown]
# * you can (navigate to each dicom image file & process ) in Google Colab without downloading the dataset.
# * a copy of All Kaggle Datasets already in Google Cloud Storage as public access bucket and gsutil supports URI wildcards.

# %% [markdown]
# * https://cloud.google.com/storage/docs/gsutil/addlhelp/WildcardNames

# %%
#Kaggle notebook 
# !pip install ../input/timm-pytorch-image-models/pytorch-image-models-master/
#Google Colab 
# !pip install gs://kds-9cdb42462ac185d28648de5905946fddca69d44aa09c63f25082a55a/

#Google Colab 
import sys
sys.path.append("/content/kds-9cdb42462ac185d28648de5905946fddca69d44aa09c63f25082a55a/"+"/pytorch-image-models-master")

# %%
#Kaggle notebook 
# !pip install ../input/torchlibrosa/torchlibrosa-0.0.5-py3-none-any.whl

#Google Colab 
# !pip install gs://kds-2a359513a2af9af7db51ebf2e9f3222dce14827bf9bdeb642f110a40/torchlibrosa-0.0.5-py3-none-any.whl

# %%
#copy gcs csv files locally (Google Colab)
# !gsutil cp gs://kds-151185c9501c719fba9ac40576b098ab63a00f8cf73f44636acf89d3/train.csv .

# %%
from pathlib import Path
#Kaggle notebook 
train_datadir = Path("../input/birdclef-2021/train_short_audio")

#Google Colab 
train_datadir = Path("/content/kds-d6119928c930d5b081b37a40cc2be59607d2b9cdfd6c20090a0f0ae4/train_short_audio")

# %% [markdown]
# Happy Kaggling on Colab Pro & Google Drive
#
# * https://hippocampus-garden.com/kaggle_colab/

# %% [markdown]
# fastest method to download Kaggle dataset
#
# * https://www.kaggle.com/c/birdclef-2021/discussion/242372#1326676

# %% [markdown]
# The pros and cons of the 3 options to deal with Kaggle Datasets in Colab .
#
# * https://www.kaggle.com/c/birdclef-2021/discussion/241414

# %% [markdown]
# How to fetch Kaggle Datasets into Google Colab
#
# * https://medium.com/analytics-vidhya/how-to-fetch-kaggle-datasets-into-google-colab-ea682569851a

# %% [markdown]
# using Kaggle API for pushing your models into a Kaggle Dataset.
#
# * https://www.kaggle.com/c/commonlitreadabilityprize/discussion/242996
# * https://www.kaggle.com/c/commonlitreadabilityprize/discussion/242966#1330390

# %% [markdown]
# A simple method to install packages offline
# * https://www.kaggle.com/feifeizaici/a-simple-method-to-install-packages-offline
