# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import seaborn as sb
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ## Reading data

# %%
df=pd.read_csv("/kaggle/input/how-much-faster-is-the-tokyo-track/track OL vs WCh.csv")
df.head()

# %%
df.tail()

# %% [markdown]
# ## Size of the data

# %%
df.shape

# %% [markdown]
# ## Statistical Descriptive values

# %%
df.describe()

# %% [markdown]
# ## Data types of Features

# %%
df.dtypes

# %% [markdown]
# ## Null values

# %%
df.isnull().sum()

# %% [markdown]
# ## Replace nulls
# - Replace null values with median of column Lane.

# %%
df["Lane"]=df["Lane"].fillna(df["Lane"].median())

# %%
df.isnull().sum()

# %% [markdown]
# - Raplacing nulls in column Rank by value 33.

# %%
df["Rank"].unique()

# %%
df["Rank"]=df["Rank"].fillna(33)

# %%
df["Rank"]=df["Rank"].replace("�",33)

# %%
df.isnull().sum()

# %% [markdown]
# - Not handling nulls of column Notes.

# %%
df["Notes"].unique()

# %%
df.head()

# %% [markdown]
# ## Visualization

# %%
plt.subplot(1,4,1)
plt.subplots_adjust(left=0,right=2,bottom=1,top=2,wspace=0.2,hspace=0.4)
label_age=['Olympics', 'World Championship']
plt.title("Where")
plt.pie(df.groupby(df["Where"]).size(),labels=label_age)

plt.subplot(1,4,2)
label_gen=[2021, 2016, 2015, 2019]
plt.title("Year")
plt.pie(df.groupby(df["Year"]).size(),labels=label_gen)

plt.subplot(1,4,3)
label_ed=['Run', 'Hurdles', 'Steeplechase']
plt.title("Event")
plt.pie(df.groupby(df["Event"]).size(),labels=label_ed)

plt.subplot(1,4,4)
label_lw=['M', 'F']
plt.title("Sex")
plt.pie(df.groupby(df["Sex"]).size(),labels=label_lw)
plt.show()

# %%
df["Rank"]=df["Rank"].astype("int")

# %%
plt.subplot(1,2,1)
plt.subplots_adjust(left=0,right=2,bottom=1,top=2,wspace=0.2,hspace=0.4)
plt.xticks(rotation = "vertical")
plt.title("Event vs Distance")
sb.barplot(x="Event" ,y="Distance", data=df)

plt.subplot(1,2,2)
plt.title("Year")
sb.countplot(x="Year", data=df)
plt.show()

# %% [markdown]
# ## Boxplot

# %%
fig = px.box(df, y="Distance")
fig.show()

# %%
fig = px.box(df, y="Rank")
fig.show()

# %%
fig = px.box(df, y="Lane")
fig.show()
