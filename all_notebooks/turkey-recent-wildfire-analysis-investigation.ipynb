# %% [markdown]
# # HISTORY
#
# #### Data on Recent Forest Fires in Turkey
#
# Content
#
# Data on recent forest fires in Turkey, published with permission from NASA Portal.
# The data was created based on the hotspots and obtained from the satellite.
#
# #### 3 SEPARATE SATELLITE DATA:
#
# MODIS C6.1
#
# SUOMI VIIRS C2
#
# J1 VIIRS C1
#
# #### DATE:
#
# Start Date : 2021-07-17
# End Date : 2021-07-31
#
# ALSO, ALL THE DATA FOR THE YEAR 2020 IS ADDED FOR COMPARISON.
#
# #### GENERAL ATTRIBUTES
#
# * Latitude
#
# Center of nominal 375 m fire pixel
#
# * Longitude
#
# Center of nominal 375 m fire pixel
#
# * Bright_ti4
# (Brightness temperature I-4)
#
# VIIRS I-4: channel brightness temperature of the fire pixel measured in Kelvin.
#
# * Scan
# (Along Scan pixel size)
#
# The algorithm produces approximately 375 m pixels at nadir. Scan and track reflect actual pixel size.
#
# * Track
# (Along Track pixel size)
#
# The algorithm produces approximately 375 m pixels at nadir. Scan and track reflect actual pixel size.
#
# * Acq_Date
# (Acquisition Date)
#
# Date of VIIRS acquisition.
#
# * Acq_Time
# (Acquisition Time)
#
# Time of acquisition/overpass of the satellite (in UTC).
#
# * Satellite
#
# N Suomi National Polar-orbiting Partnership (Suomi NPP)
#
# * Confidence
#
# This value is based on a collection of intermediate algorithm quantities used in the detection process. It is intended to help users gauge the quality of individual hotspot/fire pixels. Confidence values are set to low, nominal and high. Low confidence daytime fire pixels are typically associated with areas of sun glint and lower relative temperature anomaly (15K) temperature anomaly in either day or nighttime data. High confidence fire pixels are associated with day or nighttime saturated pixels.
#
# Please note: Low confidence nighttime pixels occur only over the geographic area extending from 11° E to 110° W and 7° N to 55° S. This area describes the region of influence of the South Atlantic Magnetic Anomaly which can cause spurious brightness temperatures in the mid-infrared channel I4 leading to potential false positive alarms. These have been removed from the NRT data distributed by FIRMS.
#
# * Version
#
# Version identifies the collection (e.g. VIIRS Collection 1) and source of data processing: Near Real-Time (NRT suffix added to collection) or Standard Processing (collection only).
#
# "1.0NRT" - Collection 1 NRT processing.
#
# "1.0" - Collection 1 Standard processing.
#
# * Bright_ti5
# (Brightness temperature I-5)
#
# I-5 Channel brightness temperature of the fire pixel measured in Kelvin.
#
# * FRP
# (Fire Radiative Power)
#
# FRP depicts the pixel-integrated fire radiative power in MW (megawatts). Given the unique spatial and spectral resolution of the data, the VIIRS 375 m fire detection algorithm was customized and tuned in order to optimize its response over small fires while balancing the occurrence of false alarms. Frequent saturation of the mid-infrared I4 channel (3.55-3.93 µm) driving the detection of active fires requires additional tests and procedures to avoid pixel classification errors. As a result, sub-pixel fire characterization (e.g., fire radiative power [FRP] retrieval) is only viable across small and/or low-intensity fires. Systematic FRP retrievals are based on a hybrid approach combining 375 and 750 m data. In fact, starting in 2015 the algorithm incorporated additional VIIRS channel M13 (3.973-4.128 µm) 750 m data in both aggregated and unaggregated format.
#
# Satellite measurements of fire radiative power (FRP) are increasingly used to estimate the contribution of biomass burning to local and global carbon budgets. Without an associated uncertainty, however, FRP-based biomass burning estimates cannot be confidently compared across space and time, or against estimates derived from alternative methodologies. Differences in the per-pixel FRP measured near-simultaneously in consecutive MODIS scans are approximately normally distributed with a standard deviation (ση) of 26.6%. Simulations demonstrate that this uncertainty decreases to less than ~5% (at ±1 ση) for aggregations larger than ~50 MODIS active fire pixels. Although FRP uncertainties limit the confidence in flux estimates on a per-pixel basis, the sensitivity of biomass burning estimates to FRP uncertainties can be mitigated by conducting inventories at coarser spatiotemporal resolutions.
#
# http://cedadocs.ceda.ac.uk/770/1/SEVIRI_FRP_documentdesc.pdf
#
# * Type
# (Inferred hot spot type)
#
# 0 = presumed vegetation fire
#
# 1 = active volcano
#
# 2 = other static land source
#
# 3 = offshore detection (includes all detections over water)
#
# * DayNight
# (Day or Night)
#
# D= Daytime fire
#
# N= Nighttime fire

# %% [markdown]
# #### WHAT IS LONGITUDE AND LATITUDE
#
# * Latitude and longitude are a system of lines used to describe the location of any place on Earth. Lines of latitude run in an east-west direction across Earth. Lines of longitude run in a north-south direction. Although these are only imaginary lines, they appear on maps and globes as if they actually existed.

# %% [markdown]
# #### ACQUISITION TIME EXAMPLE
#
# * Based on UTC time.

# %% [markdown]
# #### PLEASE NOTE:
# * WE WILL USE A SINGLE SATELLITE DATA AS A CASE STUDY. OUR PURPOSE IS TO CREATE MEANINGS WITH THE LIGHT OF THESE DATA.

# %% [markdown]
# # PACKAGES AND LIBRARIES

# %%
# !pip install dataprep by

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from warnings import filterwarnings
from mpl_toolkits.mplot3d import Axes3D
import statsmodels.api as sm
import missingno as msno
import statsmodels.stats.api as sms
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.neighbors import LocalOutlierFactor
from scipy.stats import levene
from scipy.stats import shapiro
from scipy.stats.stats import pearsonr
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from sklearn.preprocessing import scale
from sklearn.model_selection import ShuffleSplit, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import model_selection
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import BaggingRegressor
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LinearRegression
from sklearn.cross_decomposition import PLSRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import LassoCV
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import ElasticNetCV
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
import xgboost as xgb
from xgboost import XGBRegressor, XGBClassifier
from lightgbm import LGBMRegressor, LGBMClassifier
from catboost import CatBoostRegressor, CatBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn import tree
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, roc_auc_score, roc_curve
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans
from sklearn.pipeline import Pipeline
from sklearn.manifold import Isomap,TSNE
from sklearn.feature_selection import mutual_info_classif
from tqdm.notebook import tqdm
from scipy.stats import ttest_ind
import plotly.offline as pyo
import scipy.stats as stats
import pymc3 as pm
from dataprep.eda import *
from dataprep.eda import plot
from dataprep.eda import plot_diff
from dataprep.eda import plot_correlation
from dataprep.eda import plot_missing
import plotly.figure_factory as ff
from collections import Counter
import pandas_profiling as pp
from mpl_toolkits.basemap import Basemap
import datetime as dt
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio

filterwarnings("ignore", category=DeprecationWarning) 
filterwarnings("ignore", category=FutureWarning) 
filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# # DATA REVIEW AND RE-BUILT

# %% [markdown]
# ### PATH

# %%
J1V_C2_DATA_PATH = "../input/turkey-recent-forest-fire-csv-nasa/TURKEY-FIRE/fire_nrt_J1V-C2_212247.csv"

# %% [markdown]
# ### READING

# %%
J1V_C2_CSV = pd.read_csv(J1V_C2_DATA_PATH)

Data = J1V_C2_CSV.copy()

# %%
J1V_C2_CSV

# %% [markdown]
# ### RE-BUILT

# %%
Data.drop(["satellite","instrument","version"],inplace=True,axis=1)

# %% [markdown]
# * THEY ALL HAVE THE SAME VALUE AND ARE NOT NECESSARY FOR OUR EXAMINATION.

# %%
Data["confidence"].replace({"n":"nominal","l":"low","h":"high"},inplace=True)

# %%
Data["daynight"].replace({"N":"Nighttime","D":"Daytime "},inplace=True)

# %% [markdown]
# * WE TURNED VALUES INTO THEIR OWN MEANING.

# %% [markdown]
# ### INFORMATION

# %%
print("INFO:\n")
print(Data.info())

# %%
print("DESCRIBE:\n")
print(Data.describe().T)

# %% [markdown]
# * LOOKING AT THE LAST 1 WEEK OF DATA, THE BRIGHTNESS VALUE IS HIGH FOR MOST OF THIS DATA.

# %% [markdown]
# #### BRIGHT T31
#
# * %50 = 304
# * %75 = 377
#
# #### BRIGHTNESS
#
# * %50 = 337
# * %75 = 367
#
#
# WE CAN UNDERSTAND THE SEVERITY OF THE FIRE BY LOOKING AT THE BRIGHTNESS VALUES.

# %%
print("BASIC CORRELATION:\n")
print(Data.corr())

# %% [markdown]
# * IT APPEARS A HIGH - DIRECTIONAL CORRELATION BETWEEN LATITUDE AND BRIGHTNESS.

# %%
print("BASIC COVARIANCE:\n")
print(Data.cov())

# %%
print("COLUMN:\n")
print(Data.columns)

# %%
print("SHAPE: ",Data.shape)
print("SIZE: ",Data.size)

# %%
print("DUPLICATED VALUES:\n")
print(Data.duplicated().sum())

# %% [markdown]
# #### PLEASE NOTE:
# * DO NOT DELETE DUPLICATED VALUES.
# * VALUES MAY BE THE SAME BECAUSE IT IS DATE BASED.

# %%
print("NAN VALUES:\n")
print(Data.isna().sum())

# %% [markdown]
# ### VALUE CONTROL

# %%
print("VALUES:\n")
print(Data["acq_date"].value_counts())

# %%
print("VALUES:\n")
print(Data["confidence"].value_counts())

# %%
print("VALUES:\n")
print(Data["daynight"].value_counts())

# %% [markdown]
# ### DATA TYPES

# %%
Data = Data.reset_index(drop=True)

# %% [markdown]
# #### SORTED
# * WE WILL USE THEM DIRECTLY TO REACH HIGH VALUES.

# %%
DATE_SORTED = Data.copy()
DATE_SORTED.sort_values(by=["acq_date"],inplace=True,ascending=False)
DATE_SORTED = DATE_SORTED.reset_index(drop=True)

FRP_SORTED = Data.copy()
FRP_SORTED.sort_values(by=["frp"],inplace=True,ascending=False)
FRP_SORTED = FRP_SORTED.reset_index(drop=True)

BRIGHTNESS_SORTED = Data.copy()
BRIGHTNESS_SORTED.sort_values(by=["brightness"],inplace=True,ascending=False)
BRIGHTNESS_SORTED = BRIGHTNESS_SORTED.reset_index(drop=True)

# %%
DATE_SORTED

# %%
FRP_SORTED

# %%
BRIGHTNESS_SORTED

# %% [markdown]
# #### DATETIME FORMAT

# %% [markdown]
# * TO USE IN GRAPHICS.

# %%
DATETIME_FORMAT = Data.copy()
DATETIME_FORMAT.sort_values(by=["acq_date"],inplace=True,ascending=False)
DATETIME_FORMAT = DATETIME_FORMAT.reset_index(drop=True)
DATETIME_FORMAT["acq_date"] = pd.to_datetime(DATETIME_FORMAT["acq_date"])

# %%
DATETIME_FORMAT

# %%
print("INFO:\n")
print(DATETIME_FORMAT.info())

# %%
print(DATETIME_FORMAT["acq_date"])

# %% [markdown]
# #### DATETIME INDEX DATA

# %% [markdown]
# * TO LOOK AT DATE RANGE.

# %%
DATE_INDEX = Data.copy()
DATE_INDEX.sort_values(by=["acq_date"],inplace=True,ascending=False)
DATE_INDEX = DATE_INDEX.reset_index(drop=True)

DATE_INDEX.set_index(["acq_date"],inplace=True)
DATE_INDEX.index.name = None

# %%
DATE_INDEX

# %% [markdown]
# #### GROUPBY DATA

# %% [markdown]
# * FOR DATE-DAY-RELIABILITY CHECKING.

# %%
GROUP_BY = Data.copy()
GROUP_BY.sort_values(by=["acq_date"],inplace=True,ascending=False)
GROUP_BY = GROUP_BY.reset_index(drop=True)

GROUP_BY = GROUP_BY.groupby(["acq_date","daynight","confidence"]).mean()

# %%
print(GROUP_BY.head(10))

# %% [markdown]
# ### CORRELATION HEATMAP

# %%
plt.style.use("dark_background")

# %%
PEARSON_CORR = Data.corr(method="pearson")
SPEARMAN_CORR = Data.corr(method="spearman")

# %%
figure = plt.figure(figsize=(25,10))

sns.heatmap(PEARSON_CORR,annot=True,center=0,linewidths=2,linecolor="black",cmap="jet")

plt.title("PEARSON CORRELATION")
plt.tight_layout()
plt.show()

# %%
print(Data.columns)

# %%
figure = plt.figure(figsize=(25,10))

sns.heatmap(SPEARMAN_CORR,annot=True,center=0,linewidths=2,linecolor="black",cmap="jet")

plt.title("PEARSON CORRELATION")
plt.tight_layout()
plt.show()

# %% [markdown]
# * There is a +-direction correlation between "brightness" and "bright_t31". This is what we expected.
# * There is a +-direction correlation between track and scan. This is what we expected.
#
# * IN GENERAL, THE CORRELATION BETWEEN THE VALUES IS COMPATIBLE.

# %% [markdown]
# ### COVARIANCE HEATMAP

# %%
COV_DATA = Data.cov()

# %%
figure = plt.figure(figsize=(25,10))

sns.heatmap(COV_DATA,annot=True,vmin=-1,center=0,vmax=1,linewidths=2,linecolor="black",cmap="Spectral")
plt.title("COVARIANCE")
plt.tight_layout()
plt.show()

# %% [markdown]
# * MOSTLY WE SEE VALUES AFFECTING EACH OTHER DIRECTIONS.

# %% [markdown]
# ### GROUPBY MEANING

# %%
print("INFO:\n")
print(Data.info())

# %%
print("DESCRIBE:\n")
print(Data.describe().T)

# %%
Data.columns

# %% [markdown]
# #### FRP WITH VALUES

# %%
print("CONFIDENCE-FRP MAX\n")
print(Data.groupby(["confidence"])["frp"].max())
print("\n")
print("CONFIDENCE-FRP MEAN\n")
print(Data.groupby(["confidence"])["frp"].mean())
print("\n")
print("CONFIDENCE-FRP MIN\n")
print(Data.groupby(["confidence"])["frp"].min())

# %% [markdown]
# * WE SEE THE HIGHEST FRP VALUE IN NOMINAL CLASS.

# %%
print("DAY/NIGHT-FRP MAX\n")
print(Data.groupby(["daynight"])["frp"].max())
print("\n")
print("DAY/NIGHT-FRP MEAN\n")
print(Data.groupby(["daynight"])["frp"].mean())
print("\n")
print("DAY/NIGHT-FRP MIN\n")
print(Data.groupby(["daynight"])["frp"].min())

# %% [markdown]
# * NIGHT HOURS WHEN THE FRP VALUE IS HIGHEST OBSERVED.

# %%
print("DAY/NIGHT AND CONFIDENCE-FRP MAX\n")
print(Data.groupby(["daynight","confidence"])["frp"].max())
print("\n")
print("DAY/NIGHT AND CONFIDENCE-FRP MEAN\n")
print(Data.groupby(["daynight","confidence"])["frp"].mean())
print("\n")
print("DAY/NIGHT AND CONFIDENCE-FRP MIN\n")
print(Data.groupby(["daynight","confidence"])["frp"].min())

# %% [markdown]
# * AGAIN, WE SEE THE HIGHEST FRP VALUE IN THE NOMINAL CLASS.
# * THIS NOMINAL OBSERVATION HAS BEEN MEASURED AT NIGHT.

# %%
print("DATE-FRP MAX\n")
print(Data.groupby(["acq_date"])["frp"].max())
print("\n")
print("DATE-FRP MIN\n")
print(Data.groupby(["acq_date"])["frp"].min())

# %% [markdown]
# * ESPECIALLY THE HIGHEST FRP VALUE WAS OBSERVED ON JULY 28 AND 29. THIS MEANS THE DAYS WHERE THE FIRE STARTED.
# * BECAUSE WE COLLECTED THIS DATA ON THE MORNING OF JULY 30, IT HAS LOW VALUE, DUE TO DAILY RENEWAL OF THE DATA.

# %%
print("TIME-FRP MAX\n")
print(Data.groupby(["acq_time"])["frp"].max())
print("\n")
print("TIME-FRP MIN\n")
print(Data.groupby(["acq_time"])["frp"].min())

# %%
print(Data[Data["frp"] == Data["frp"].max()])

# %% [markdown]
# ##### THE HIGHEST FRP VALUE WAS OBSERVED
#
# * JULY 29,2021

# %% [markdown]
# * HERE IS TOPALLI,ALADAG - ADANA

# %% [markdown]
# #### BRIGHTNESS WITH VALUES

# %%
print("CONFIDENCE-BRIGHTNESS MAX\n")
print(Data.groupby(["confidence"])["bright_t31"].max())
print("\n")
print("CONFIDENCE-BRIGHTNESS MEAN\n")
print(Data.groupby(["confidence"])["bright_t31"].mean())
print("\n")
print("CONFIDENCE-BRIGHTNESS MIN\n")
print(Data.groupby(["confidence"])["bright_t31"].min())

# %%
print("DAY/NIGHT-BRIGHTNESS MAX\n")
print(Data.groupby(["daynight"])["bright_t31"].max())
print("\n")
print("DAY/NIGHT-BRIGHTNESS MEAN\n")
print(Data.groupby(["daynight"])["bright_t31"].mean())
print("\n")
print("DAY/NIGHT-BRIGHTNESS MIN\n")
print(Data.groupby(["daynight"])["bright_t31"].min())

# %% [markdown]
# * THE HIGHEST BRIGHTNESS WAS OBSERVED IN THE DAY HOURS.
# * THIS IS DUE TO INCREASING TEMPERATURE AND REFLECTION OF EARTH TEMPERATURE WITH SUNLIGHT.

# %%
print("DATE-BRIGHTNESS MAX\n")
print(Data.groupby(["acq_date"])["bright_t31"].max())
print("\n")
print("DATE-BRIGHTNESS MIN\n")
print(Data.groupby(["acq_date"])["bright_t31"].min())

# %% [markdown]
# * WE SEE THE HIGHEST BRIGHTNESS VALUE ON JULY 28.
# * JULY 27 IS THE DAY MANAVGAT FIRE STARTED.
# * THE DAY WHERE THE FIRE WAS THE STRONGEST IS JULY 29.

# %% [markdown]
# ![](https://i.hurimg.com/i/hdn/75/0x0/610242b94e3fe0116c56ade5.jpeg)

# %%
print("TIME-BRIGHTNESS MAX\n")
print(Data.groupby(["acq_time"])["bright_t31"].max())
print("\n")
print("TIME-BRIGHTNESS MIN\n")
print(Data.groupby(["acq_time"])["bright_t31"].min())

# %%
print(Data[Data["bright_t31"] == Data["bright_t31"].max()])

# %% [markdown]
# ##### THE HIGHEST BRIGHTNESS VALUE WAS OBSERVED
#
# * JULY 29,2021

# %% [markdown]
# * HERE IS BOZTAHTA - ADANA

# %%
print(Data[Data["brightness"] == Data["brightness"].max()]["acq_date"].value_counts())

# %% [markdown]
# * WHEN LOOKING AT THE TOTAL BRIGHTNESS VALUES, WE SEE THAT JULY 29 HAS THE HIGHEST VALUES.

# %% [markdown]
# ![](https://idsb.tmgrup.com.tr/ly/uploads/images/2021/07/28/131861.jpg)
#
# * A man watches as flames destroy a shack inside the forest in Manavgat district, in Antalya, southern Turkey, July 28, 2021. (İHA PHOTO)

# %% [markdown]
# # MAPS

# %%
import folium
from folium import plugins

# %% [markdown]
# ### GENERAL

# %%
figure = plt.figure(figsize=(20,8))
Map_Plot = Basemap(projection="cyl",resolution="c")
Map_Plot.drawmapboundary(fill_color="w")
Map_Plot.drawcoastlines(linewidth=0.5)
Map_Plot.drawmeridians(range(0, 360, 20),linewidth=0.8)
Map_Plot.drawparallels([-66,-23,0.0,23,66],linewidth=0.8)
lon,lat = Map_Plot(Data["longitude"],Data["latitude"])
Map_Plot.scatter(lon,lat,marker="*",alpha=0.20,color="r",edgecolor="None")
plt.title("COORDINATES")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(17,12))
Map_Plot = Basemap(projection='cyl',llcrnrlat=33,llcrnrlon=20,urcrnrlat=45,urcrnrlon=55,resolution='c')
Map_Plot.bluemarble()
Map_Plot.drawcountries()

Map_Plot.scatter(Data.longitude,Data.latitude,edgecolor='none',color='r',alpha=0.6)

plt.title("TURKEY GENERAL", fontsize=15)
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(17,12))
Map_Plot = Basemap(projection='cyl',llcrnrlat=33,llcrnrlon=20,urcrnrlat=45,urcrnrlon=55,resolution='c')
Map_Plot.bluemarble()
Map_Plot.drawcountries()

Map_Plot.plot(Data.longitude,Data.latitude,color='r',alpha=0.4)

plt.title("TURKEY GENERAL", fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### BASED ON DATE

# %%
DATE_28 = Data[Data["acq_date"] == "2021-07-28"]
DATE_29 = Data[Data["acq_date"] == "2021-07-29"]

DATE_28 = DATE_28.reset_index(drop=True)
DATE_29 = DATE_29.reset_index(drop=True)

# %%
DATE_28

# %%
DATE_29

# %% [markdown]
# #### 28 JULY 2021

# %%
figure = plt.figure(figsize=(17,12))
Map_Plot = Basemap(projection='cyl',llcrnrlat=33,llcrnrlon=20,urcrnrlat=45,urcrnrlon=55,resolution='c')
Map_Plot.bluemarble()
Map_Plot.drawcountries()

Map_Plot.scatter(DATE_28.longitude,DATE_28.latitude,edgecolor='none',color='r',alpha=0.3,linewidth=10,s=170)

plt.title("JULY 28,2021", fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# * AS YOU CAN SEE, FIRE AREAS BIGGER THAN OTHERS.

# %% [markdown]
# #### 29 JULY 2021

# %%
figure = plt.figure(figsize=(17,12))
Map_Plot = Basemap(projection='cyl',llcrnrlat=33,llcrnrlon=20,urcrnrlat=45,urcrnrlon=55,resolution='c')
Map_Plot.bluemarble()
Map_Plot.drawcountries()

Map_Plot.scatter(DATE_29.longitude,DATE_29.latitude,edgecolor='none',color='r',alpha=0.3,linewidth=10,s=170)

plt.title("JULY 29,2021", fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# * WE OBSERVED A SIGNIFICANT INCREASE IN FIRE POINTS ON JULY 29.

# %% [markdown]
# #### 28 JULY 2021 AND 29 JULY 2021

# %%
figure = plt.figure(figsize=(17,12))
Map_Plot = Basemap(projection='cyl',llcrnrlat=33,llcrnrlon=20,urcrnrlat=45,urcrnrlon=55,resolution='c')
Map_Plot.bluemarble()
Map_Plot.drawcountries()

Map_Plot.scatter(DATE_28.longitude,DATE_28.latitude,edgecolor='none',color='g',alpha=0.9,linewidth=10,s=100)
Map_Plot.scatter(DATE_29.longitude,DATE_29.latitude,edgecolor='none',color='r',alpha=0.9,linewidth=10,s=100)

plt.title("JULY 29 - 28,2021", fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# * YOU SEE THE AMOUNT OF INCREASE AFTER 1 DAY.
#
# GREEN: 28 JULY
#
# RED: 29 JULY

# %% [markdown]
# #### COMPARISON WITH THE BEGINNING OF THE WEEK

# %% [markdown]
# * WE WILL LOOK AT THE DIFFERENCE BETWEEN DIFFERENT DATES.

# %%
figure = plt.figure(figsize=(17,12))
Map_Plot = Basemap(projection='cyl',llcrnrlat=33,llcrnrlon=20,urcrnrlat=45,urcrnrlon=55,resolution='c')
Map_Plot.bluemarble()
Map_Plot.drawcountries()

Map_Plot.scatter(Data[Data["acq_date"] == "2021-07-15"].longitude,Data[Data["acq_date"] == "2021-07-15"].latitude,edgecolor='none',color='y',alpha=0.9,linewidth=10,s=100)
Map_Plot.scatter(DATE_29.longitude,DATE_29.latitude,edgecolor='none',color='r',alpha=0.9,linewidth=10,s=100)

plt.title("JULY 29 - 15,2021", fontsize=15)
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(17,12))
Map_Plot = Basemap(projection='cyl',llcrnrlat=33,llcrnrlon=20,urcrnrlat=45,urcrnrlon=55,resolution='c')
Map_Plot.bluemarble()
Map_Plot.drawcountries()

Map_Plot.scatter(Data[Data["acq_date"] == "2021-07-18"].longitude,Data[Data["acq_date"] == "2021-07-18"].latitude,edgecolor='none',color='y',alpha=0.9,linewidth=10,s=100)
Map_Plot.scatter(DATE_29.longitude,DATE_29.latitude,edgecolor='none',color='r',alpha=0.9,linewidth=10,s=100)

plt.title("JULY 29 - 18,2021", fontsize=15)
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(17,12))
Map_Plot = Basemap(projection='cyl',llcrnrlat=33,llcrnrlon=20,urcrnrlat=45,urcrnrlon=55,resolution='c')
Map_Plot.bluemarble()
Map_Plot.drawcountries()

Map_Plot.scatter(Data[Data["acq_date"] == "2021-07-15"].longitude,Data[Data["acq_date"] == "2021-07-15"].latitude,edgecolor='none',color='y',alpha=0.9,linewidth=10,s=100)

plt.title("JULY 15,2021", fontsize=15)
plt.tight_layout()
plt.show()

figure = plt.figure(figsize=(17,12))
Map_Plot = Basemap(projection='cyl',llcrnrlat=33,llcrnrlon=20,urcrnrlat=45,urcrnrlon=55,resolution='c')
Map_Plot.bluemarble()
Map_Plot.drawcountries()

Map_Plot.scatter(DATE_29.longitude,DATE_29.latitude,edgecolor='none',color='r',alpha=0.9,linewidth=10,s=100)

plt.title("JULY 29,2021", fontsize=15)
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(17,12))
Map_Plot = Basemap(projection='cyl',llcrnrlat=33,llcrnrlon=20,urcrnrlat=45,urcrnrlon=55,resolution='c')
Map_Plot.bluemarble()
Map_Plot.drawcountries()

Map_Plot.scatter(Data[Data["acq_date"] == "2021-07-18"].longitude,Data[Data["acq_date"] == "2021-07-18"].latitude,edgecolor='none',color='y',alpha=0.9,linewidth=10,s=100)

plt.title("JULY 18,2021", fontsize=15)
plt.tight_layout()
plt.show()

figure = plt.figure(figsize=(17,12))
Map_Plot = Basemap(projection='cyl',llcrnrlat=33,llcrnrlon=20,urcrnrlat=45,urcrnrlon=55,resolution='c')
Map_Plot.bluemarble()
Map_Plot.drawcountries()

Map_Plot.scatter(DATE_29.longitude,DATE_29.latitude,edgecolor='none',color='r',alpha=0.9,linewidth=10,s=100)

plt.title("JULY 29,2021", fontsize=15)
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(17,12))
Map_Plot = Basemap(projection='cyl',llcrnrlat=33,llcrnrlon=20,urcrnrlat=45,urcrnrlon=55,resolution='c')
Map_Plot.bluemarble()
Map_Plot.drawcountries()

Map_Plot.scatter(Data[Data["acq_date"] == "2021-07-22"].longitude,Data[Data["acq_date"] == "2021-07-22"].latitude,edgecolor='none',color='y',alpha=0.9,linewidth=10,s=100)

plt.title("JULY 22,2021", fontsize=15)
plt.tight_layout()
plt.show()

figure = plt.figure(figsize=(17,12))
Map_Plot = Basemap(projection='cyl',llcrnrlat=33,llcrnrlon=20,urcrnrlat=45,urcrnrlon=55,resolution='c')
Map_Plot.bluemarble()
Map_Plot.drawcountries()

Map_Plot.scatter(DATE_29.longitude,DATE_29.latitude,edgecolor='none',color='r',alpha=0.9,linewidth=10,s=100)

plt.title("JULY 29,2021", fontsize=15)
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(17,12))
Map_Plot = Basemap(projection='cyl',llcrnrlat=33,llcrnrlon=20,urcrnrlat=45,urcrnrlon=55,resolution='c')
Map_Plot.bluemarble()
Map_Plot.drawcountries()

Map_Plot.scatter(Data[Data["acq_date"] == "2021-07-25"].longitude,Data[Data["acq_date"] == "2021-07-25"].latitude,edgecolor='none',color='y',alpha=0.9,linewidth=10,s=100)

plt.title("JULY 25,2021", fontsize=15)
plt.tight_layout()
plt.show()

figure = plt.figure(figsize=(17,12))
Map_Plot = Basemap(projection='cyl',llcrnrlat=33,llcrnrlon=20,urcrnrlat=45,urcrnrlon=55,resolution='c')
Map_Plot.bluemarble()
Map_Plot.drawcountries()

Map_Plot.scatter(DATE_29.longitude,DATE_29.latitude,edgecolor='none',color='r',alpha=0.9,linewidth=10,s=100)

plt.title("JULY 29,2021", fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### DETAIL

# %% [markdown]
# * USE INTERACTIVE MAPS

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433], # TURKEY
                    tiles='Stamen Terrain',zoom_start=5.5)
MAP_FUNCTION

# %%
print(DATE_29[DATE_29["frp"] == DATE_29["frp"].max()])

print("\n")
print("----"*10)
print("\n")

print(DATE_28[DATE_28["frp"] == DATE_28["frp"].max()])

# %%
print(DATE_29[DATE_29["bright_t31"] == DATE_29["bright_t31"].max()])

print("\n")
print("----"*10)
print("\n")

print(DATE_28[DATE_28["bright_t31"] == DATE_28["bright_t31"].max()])

# %% [markdown]
# * CLICK THE ROUNDS

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='openstreetmap',
                  zoom_start=6.0)

folium.CircleMarker(
    location=[36.89363,31.36536],
    radius=20,
    popup="DATE:<b>28 JULY MAXIMUM BRIGHTNESS<b>",
    tooltip="Click me",
    color='#2F4F4F',
    fill=True,
    fill_color='#00000',
).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='openstreetmap',
                  zoom_start=6.0)

folium.CircleMarker(
    location=[37.3512,35.45154],
    radius=20,
    popup="DATE:<b>29 JULY MAXIMUM BRIGHTNESS<b>",
    tooltip="Click me",
    color='#2F4F4F',
    fill=True,
    fill_color='#00000',
).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='openstreetmap',
                  zoom_start=6.0)

folium.CircleMarker(
    location=[36.89363,31.36536],
    radius=20,
    popup="DATE:<b>28 JULY MAXIMUM BRIGHTNESS<b>",
    tooltip="Click me",
    color='#2F4F4F',
    fill=True,
    fill_color='#FF0000',
).add_to(MAP_FUNCTION)

folium.CircleMarker(
    location=[37.3512,35.45154],
    radius=20,
    popup="DATE:<b>29 JULY MAXIMUM BRIGHTNESS<b>",
    tooltip="Click me",
    color='#2F4F4F',
    fill=True,
    fill_color='#00000',
).add_to(MAP_FUNCTION)



MAP_FUNCTION

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Watercolor',
                  zoom_start=6.0)

folium.CircleMarker(
    location=[36.89363,31.36536],
    radius=20,
    popup="DATE:<b>28 JULY MAXIMUM BRIGHTNESS<b>",
    tooltip="Click me",
    color='#2F4F4F',
    fill=True,
    fill_color='#FF0000',
).add_to(MAP_FUNCTION)

folium.CircleMarker(
    location=[37.3512,35.45154],
    radius=20,
    popup="DATE:<b>29 JULY MAXIMUM BRIGHTNESS<b>",
    tooltip="Click me",
    color='#2F4F4F',
    fill=True,
    fill_color='#00000',
).add_to(MAP_FUNCTION)



MAP_FUNCTION

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Toner',
                  zoom_start=6.0)

folium.CircleMarker(
    location=[36.89363,31.36536],
    radius=20,
    popup="DATE:<b>28 JULY MAXIMUM BRIGHTNESS<b>",
    tooltip="Click me",
    color='#2F4F4F',
    fill=True,
    fill_color='#FF0000',
).add_to(MAP_FUNCTION)

folium.CircleMarker(
    location=[37.3512,35.45154],
    radius=20,
    popup="DATE:<b>29 JULY MAXIMUM BRIGHTNESS<b>",
    tooltip="Click me",
    color='#2F4F4F',
    fill=True,
    fill_color='#00000',
).add_to(MAP_FUNCTION)

folium.Marker(location=[36.89363,31.36536],popup="ANTALYA").add_to(MAP_FUNCTION)
folium.Marker(location=[37.3512,35.45154],popup="ADANA").add_to(MAP_FUNCTION)



MAP_FUNCTION

# %% [markdown]
# * WE WILL LOOK AT ALL THE POINTS.
# * USE THE INTERACTIVE MAP.

# %%
LAT_LON_29 = DATE_29[["latitude","longitude"]]
LAT_LON_28 = DATE_28[["latitude","longitude"]]

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='openstreetmap',
                  zoom_start=6.0)

plugins.MarkerCluster(LAT_LON_28).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='openstreetmap',
                  zoom_start=6.0)

plugins.MarkerCluster(LAT_LON_29).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### ATTENTION
#
# * WHILE THE TOTAL TEMPERATURE STRESS POINT WAS 538 POINTS ON JULY 28, THIS NUMBER INCREASED TO 2590 POINTS ON JULY 29.
# * THE BIGGEST REASON FOR THIS INCREASED IS ANTALYA, MERSIN, ADANA AND MUĞLA.
# * INCREASES IN OTHER CITIES DID NOT AFFECT THIS JUMP, BECAUSE THE INCREASE IN OTHER CITIES HAS NOT HAPPENED MUCH.

# %%
DATE_30 = Data[Data["acq_date"] == "2021-07-30"]

DATE_30 = DATE_30.reset_index(drop=True)

DATE_30

# %%
LAT_LON_30 = DATE_30[["latitude","longitude"]]

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='openstreetmap',
                  zoom_start=6.0)

plugins.MarkerCluster(LAT_LON_30).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# * BECAUSE WE RECEIVED THE DATA ON THE MORNING OF JULY 30, THERE ARE VALUES UNTIL THAT HOUR.

# %%
LAT_LON_30.latitude = LAT_LON_30.latitude.astype(float)
LAT_LON_30.longitude = LAT_LON_30.longitude.astype(float)

LAT_LON_29.latitude = LAT_LON_29.latitude.astype(float)
LAT_LON_29.longitude = LAT_LON_29.longitude.astype(float)

LAT_LON_28.latitude = LAT_LON_28.latitude.astype(float)
LAT_LON_28.longitude = LAT_LON_28.longitude.astype(float)

HEAT_30 = list(zip(LAT_LON_30.latitude,LAT_LON_30.longitude))
HEAT_29 = list(zip(LAT_LON_29.latitude,LAT_LON_29.longitude))
HEAT_28 = list(zip(LAT_LON_28.latitude,LAT_LON_28.longitude))

# %% [markdown]
# ##### 28 JULY 2021

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Terrain',
                  zoom_start=6.0)

plugins.HeatMap(HEAT_28).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# ##### 29 JULY 2021

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Terrain',
                  zoom_start=6.0)

plugins.HeatMap(HEAT_29).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# ##### 30 JULY 2021

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Terrain',
                  zoom_start=6.0)

plugins.HeatMap(HEAT_30).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# # GRAPHIC

# %% [markdown]
# ### GENERAL CONTROL

# %%
figure = plt.figure(figsize=(25,14))

plt.plot(Data["bright_t31"])
plt.title("BRIGHTNESS")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))

plt.plot(Data["frp"])
plt.title("Fire Radiative Power")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))

sns.scatterplot(Data["bright_t31"],Data["acq_date"],hue=Data["daynight"])
plt.title("BRIGHTNESS-DATE / DAY OR NIGHT")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))

sns.scatterplot(Data["frp"],Data["acq_date"],hue=Data["daynight"])
plt.title("FRP-DATE / DAY OR NIGHT")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### SORTED CHECKING

# %%
figure = plt.figure(figsize=(25,14))

sns.lineplot(DATE_SORTED["frp"],DATE_SORTED["bright_t31"],color=('red'))
plt.title("BRIGHTNESS-FRP")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))

plt.plot(DATE_SORTED["acq_date"],DATE_SORTED["bright_t31"])
plt.title("BRIGHTNESS-DATE")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))

sns.lineplot(DATE_SORTED["acq_date"],DATE_SORTED["bright_t31"],color=('red'))
plt.title("BRIGHTNESS-DATE")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))

sns.lineplot(DATE_SORTED["acq_date"],DATE_SORTED["frp"],color=('yellow'))
plt.title("FRP-DATE")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### DATE CHECKING

# %% [markdown]
# #### 28 JULY

# %%
figure = plt.figure(figsize=(25,14))

sns.lineplot(DATE_28["acq_time"],DATE_28["frp"],color=('yellow'))
plt.title("FRP-TIME FOR JULY 28")
plt.tight_layout()
plt.show()

# %%
print(DATE_28[DATE_28["frp"] == DATE_28["frp"].max()])

# %% [markdown]
# * THE HIGHEST FRP VALUES WAS SEEN IN THE MORNING ON JULY 28.

# %%
figure = plt.figure(figsize=(25,14))

sns.lineplot(DATE_28["acq_time"],DATE_28["bright_t31"],color=('yellow'))
plt.title("BRIGHTNESS-TIME FOR JULY 28")
plt.tight_layout()
plt.show()

# %%
print(DATE_28[DATE_28["bright_t31"] == DATE_28["bright_t31"].max()])

# %% [markdown]
# * THE HIGHEST BRIGHTNESS VALUE WAS SEEN IN THE MORNING ON JULY 28.

# %% [markdown]
# * WE CAN SAY THAT IT IS WHEN MAJOR FIRES ARE DETECTED.

# %% [markdown]
# ![](https://static.euronews.com/articles/stories/05/93/38/34/808x608_cmsv2_b6d0e089-4849-54ab-bb60-07e5ca69ce98-5933834.jpg)

# %% [markdown]
# #### 29 JULY

# %%
figure = plt.figure(figsize=(25,14))

sns.lineplot(DATE_29["acq_time"],DATE_29["frp"],color=('yellow'))
plt.title("FRP-TIME FOR JULY 29")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))

sns.lineplot(DATE_29["acq_time"],DATE_29["bright_t31"],color=('yellow'))
plt.title("BRIGHTNESS-TIME FOR JULY 28")
plt.tight_layout()
plt.show()

# %% [markdown]
# * YOU SEE THE BRIGHTNESS INCREASED SHARPLY ON JULY 28 AND 29.

# %% [markdown]
# # COMPARING JULY 30,2021 FULL DATA

# %%
JULY_30_CSV_PATH = "../input/huge-wildfire-data-last/mission_f32_jv1_nasa_sec.csv"

JULY_30_READING = pd.read_csv(JULY_30_CSV_PATH)

JULY_30 = JULY_30_READING[JULY_30_READING["acq_date"] == "2021-07-30"]

JULY_30 = JULY_30.reset_index(drop=True)

JULY_30

# %%
LAT_LON_JULY_30 = JULY_30[["latitude","longitude"]]

# %% [markdown]
# #### JULY 28

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='openstreetmap',
                  zoom_start=6.0)

plugins.MarkerCluster(LAT_LON_28).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### JULY 29

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='openstreetmap',
                  zoom_start=6.0)

plugins.MarkerCluster(LAT_LON_29).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### JULY 30

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='openstreetmap',
                  zoom_start=6.0)

plugins.MarkerCluster(LAT_LON_JULY_30).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# * THE HOTSPOTS DETECTED ARE DECREASING BY DAY. THIS SHOWS EXTINGUISHING INTERVENTION.

# %%
print(JULY_30[JULY_30["bright_t31"] == JULY_30["bright_t31"].max()])

# %% [markdown]
# * THE HIGHEST VALUE IS SEEN IN THE MORNING HOURS

# %%
print(JULY_30[JULY_30["frp"] == JULY_30["frp"].max()])

# %% [markdown]
# * THE HIGHEST VALUE IS SEEN IN THE MORNING HOURS

# %% [markdown]
# #### ALL BRIGHTNESS AND FRP

# %%
print("JULY 28\n")
print(DATE_28[DATE_28["bright_t31"] == DATE_28["bright_t31"].max()])
print("\n")
print(DATE_28[DATE_28["frp"] == DATE_28["frp"].max()])
print("---"*10)
print("JULY 29\n")
print(DATE_29[DATE_29["bright_t31"] == DATE_29["bright_t31"].max()])
print("\n")
print(DATE_29[DATE_29["frp"] == DATE_29["frp"].max()])
print("---"*10)
print("JULY 30\n")
print(JULY_30[JULY_30["bright_t31"] == JULY_30["bright_t31"].max()])
print("\n")
print(JULY_30[JULY_30["frp"] == JULY_30["frp"].max()])

# %% [markdown]
# #### ATTENTION
# * HIGHEST VALUES ARE VISIBLE DURING DAY HOURS IN 3 DAYS.
#
# * 28 JULY
# * 29 JULY
# * 30 JULY

# %% [markdown]
# #### 30 JULY,2021 HEATMAP

# %%
LAT_LON_JULY_30.latitude = LAT_LON_JULY_30.latitude.astype(float)
LAT_LON_JULY_30.longitude = LAT_LON_JULY_30.longitude.astype(float)

HEAT_JULY_30 = list(zip(LAT_LON_JULY_30.latitude,LAT_LON_JULY_30.longitude))

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Terrain',
                  zoom_start=6.0)

plugins.HeatMap(HEAT_JULY_30).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# # COMPARING JULY 29,2021 AND ENTIRE YEAR 2020

# %%
Reading_2020 = pd.read_csv("../input/turkey-recent-forest-fire-csv-nasa/TURKEY-FIRE/modis_2020_Turkey.csv")

# %%
LAT_LON_2020 = Reading_2020[["latitude","longitude"]]

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='openstreetmap',
                  zoom_start=6.0)

plugins.MarkerCluster(LAT_LON_2020).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### REMEMBER THAT RESULT FOR 29 JULY 2021:

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='openstreetmap',
                  zoom_start=6.0)

plugins.MarkerCluster(LAT_LON_29).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# * THIS IS THE ENTIRE YEAR 2020.
#
# * AS YOU CAN SEE, THERE IS AN EXTREME ANOMALY FOR THE MEDITERRANEAN REGION.

# %% [markdown]
# * THE HOTSPOTS DETECTED IN THE LAST 3 DAYS ARE MUCH MORE THAN THE TOTAL OF 2020.

# %% [markdown]
# #### REMEMBER THAT RESULT FOR 29 JULY 2021:

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Terrain',
                  zoom_start=6.0)

plugins.HeatMap(HEAT_29).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %%
LAT_LON_2020.latitude = LAT_LON_2020.latitude.astype(float)
LAT_LON_2020.longitude = LAT_LON_2020.longitude.astype(float)

HEAT_2020 = list(zip(LAT_LON_2020.latitude,LAT_LON_2020.longitude))

# %% [markdown]
# * SEE ALL CITIES. USE THE INTERACTIVE MAP.

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Terrain',
                  zoom_start=6.0)

plugins.HeatMap(HEAT_2020).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# * WHEN YOU LOOK AT THE LOCATION, THE DENSITY IS LOW FOR 2020

# %% [markdown]
# # COMPARING 2018,2019 AND 2020

# %%
READING_2019 = pd.read_csv("../input/2019-fire-data/modis_2019_Turkey.csv")
READING_2018 = pd.read_csv("../input/2018-fre-data/modis_2018_Turkey.csv")

# %%
LAT_LON_2018 = READING_2018[["latitude","longitude"]]
LAT_LON_2019 = READING_2019[["latitude","longitude"]]

# %%
LAT_LON_2018.latitude = LAT_LON_2018.latitude.astype(float)
LAT_LON_2018.longitude = LAT_LON_2018.longitude.astype(float)

HEAT_2018 = list(zip(LAT_LON_2018.latitude,LAT_LON_2018.longitude))

LAT_LON_2019.latitude = LAT_LON_2019.latitude.astype(float)
LAT_LON_2019.longitude = LAT_LON_2019.longitude.astype(float)

HEAT_2019 = list(zip(LAT_LON_2019.latitude,LAT_LON_2019.longitude))

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='openstreetmap',
                  zoom_start=6.0)

plugins.MarkerCluster(LAT_LON_2020).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='openstreetmap',
                  zoom_start=6.0)

plugins.MarkerCluster(LAT_LON_2019).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='openstreetmap',
                  zoom_start=6.0)

plugins.MarkerCluster(LAT_LON_2018).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# * IN 3 YEARS, ANOMALIES REGARDING THIS YEAR DO NOT APPEAR.

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Terrain',
                  zoom_start=6.0)

plugins.HeatMap(HEAT_2020).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Terrain',
                  zoom_start=6.0)

plugins.HeatMap(HEAT_2019).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Terrain',
                  zoom_start=6.0)

plugins.HeatMap(HEAT_2018).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# * THERE IS AN INCREASE DUE TO YEARS.
# * THE TEMPERATURE RISE IN THE MEDITERRANEAN IS VERY HIGH IN GENERAL.

# %% [markdown]
# # GLOBAL TEMPERATURE AND FORECAST

# %% [markdown]
# ![](https://climatereanalyzer.org/wx_frames/gfs/ds/gfs_world-ced_t2_1-day.png)
#
# * Real Density Map

# %% [markdown]
# ![](https://climatereanalyzer.org/clim/explore/img/tn/gen3ens_arc-lea_t2anom_2001-2012_minus_1979-2000_sm.jpg)

# %% [markdown]
# ![](https://climatereanalyzer.org/clim/ecm/images/ECM_19_3_6_3.jpg)

# %% [markdown]
# ![](https://www.giss.nasa.gov/research/news/20210114/temp-2020_comparison-plot.jpg)
# * NASA

# %% [markdown]
# #### ATTENTION
#
# * ALL IMAGES ARE REAL AND BASED ON OBSERVATION.

# %% [markdown]
# #### ANOMALIES

# %%
ANOMALIES_DATA = pd.read_csv("../input/anomalies-data/GLB.TsdSST - GLB.TsdSST.csv")

# %%
ANOMALIES_DATA

# %%
print("COLUMNS:\n")
print(ANOMALIES_DATA.columns)

# %%
print(ANOMALIES_DATA[ANOMALIES_DATA["Year"] == 2021])

# %%
ANOMALIES_DATA.replace({"*******":"OBSERVATION NOT MADE - WAITING"},inplace=True)

print(ANOMALIES_DATA[ANOMALIES_DATA["Year"] == 2021])

# %%
CLEAR_ANOMALIES = ANOMALIES_DATA[["Year","Jan","Feb","Mar","Apr","May","Jun"]]

CLEAR_ANOMALIES = CLEAR_ANOMALIES.reset_index(drop=True)

CLEAR_ANOMALIES

# %%
figure = plt.figure(figsize=(18,7))

sns.pairplot(CLEAR_ANOMALIES,hue="Year")

plt.tight_layout()
plt.show()

# %% [markdown]
# * THERE IS A DIRECT INCREASE IN ALL MONTHS.

# %%
figure = plt.figure(figsize=(18,7))

sns.lineplot(CLEAR_ANOMALIES["Year"],CLEAR_ANOMALIES["Jan"])

plt.tight_layout()
plt.show()

figure = plt.figure(figsize=(18,7))

sns.lineplot(CLEAR_ANOMALIES["Year"],CLEAR_ANOMALIES["Feb"])

plt.tight_layout()
plt.show()

figure = plt.figure(figsize=(18,7))

sns.lineplot(CLEAR_ANOMALIES["Year"],CLEAR_ANOMALIES["Mar"])

plt.tight_layout()
plt.show()

figure = plt.figure(figsize=(18,7))

sns.lineplot(CLEAR_ANOMALIES["Year"],CLEAR_ANOMALIES["Apr"])

plt.tight_layout()
plt.show()

figure = plt.figure(figsize=(18,7))

sns.lineplot(CLEAR_ANOMALIES["Year"],CLEAR_ANOMALIES["May"])

plt.tight_layout()
plt.show()

figure = plt.figure(figsize=(18,7))

sns.lineplot(CLEAR_ANOMALIES["Year"],CLEAR_ANOMALIES["Jun"])

plt.tight_layout()
plt.show()

# %% [markdown]
# * PAY ATTENTION TO BREAK POINTS.
# * IN THE LAST MEASURED MONTH (JUNE), THE BREAKING POINT IS MUCH HIGHER.
# * THERE IS A STABLE RISE DEPENDING ON YEARS.

# %%
CLEAR_ANOMALIES["LAST 2 MONTHS DIFF"] = CLEAR_ANOMALIES["May"] - CLEAR_ANOMALIES["Jun"]

CLEAR_ANOMALIES

# %% [markdown]
# * LOOK AT THE DIFFERENCE BETWEEN 2020 AND 2021. - SIGN EXPRESSES THE MULTIPLE DIFFERENCE. THERE IS A HUGE DIFFERENCE BETWEEN 2 YEARS.
#
# * THE YEAR 2021 IS RICH IN ANOMALIES AND THERE IS A HIGH INCREASE.
#
# * EACH YEAR, THE JUMP IS INCREASING MONTHLY. THE DIFFERENCE IS BIGGER.

# %% [markdown]
# #### END OF THE PROJECT
#
# * FOLLOW ALL STAGES CAREFULLY.
#
# * READ THE NOTES.
#
# -------
#
# * GLOBAL WARMING IS REAL.
#
# * PROTECT FORESTS.
#
# * PROTECT THE ANIMALS.
#
# #### THANK YOU SO MUCH
