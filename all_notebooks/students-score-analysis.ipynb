# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/kaggle/input/student-grade-prediction/student-mat.csv')

# %%
df

# %%
df.isnull().sum()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#rata-rata nilai
df['average_grade']=(df['G1']+df['G2']+df['G3'])/3

# %%
df=df.drop(['G1','G2','G3'],axis=1)

# %%
df.head(5)

# %%
sns.barplot(x=df['school'],y=df['average_grade'],data=df)

# %%
#Sekolah tidak terlalu berperan besar dalam rata-rata nilai muridnya

# %%
sns.barplot(x=df['sex'],y=df['average_grade'],data=df)

# %%
#Rata-rata nilai murid laki-laki, lebih besar sedikit dibanding murid perempuan

# %%
sns.barplot(x=df['age'],y=df['average_grade'],data=df)

# %%
#Murid dengan umur 20 memiliki rata-rata nilai yang tinggi

# %%
sns.barplot(x=df['Mjob'],y=df['average_grade'],data=df)

# %%
#Dibandingkan dengan yang lain, murid dengan Ibu yang bekerja di bidang kesehatan memiliki rata-rata nilai yang tinggi

# %%
sns.barplot(x=df['Fjob'],y=df['average_grade'],data=df)

# %%
#Murid dengan ayah seorang guru, memiliki rata-rata nilai yang tinggi dibanding dengan yang lain

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in list(df.columns):
    df[i]=le.fit_transform(df[i])
df.head(5)

# %%
y=df['average_grade']
x=df.drop(['average_grade'],axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
lr=LinearRegression()
lr.fit(x_train,y_train)
pred_1=lr.predict(x_test)
score_1=r2_score(y_test,pred_1)
error_1=mean_squared_error(y_test,pred_1)

# %%
error_1
