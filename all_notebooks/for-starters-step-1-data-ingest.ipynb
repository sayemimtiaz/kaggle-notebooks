# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
 
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ### We know the dataset name and url now. Lets load up the data into base_data data frame using pandas. Our favourite panda after Po!!

# %%
base_data = pd.read_csv('../input/google-trends-dataset/trends.csv')

# %% [markdown]
# ### **Let check if the data is loaded properly or as you would like to say in in data enginnering you would call it like "lets check if the data is ingested properly". We will take a look at few  sample records. We will use pandas head() function for this.**

# %%
base_data.head(5)

# %% [markdown]
# **What, you want to look at records at bottom. Oh so you are curious type. Good! **
#
# Yes, you can do it in pandas. we will use tail function.

# %%
base_data.tail(-5)

# %% [markdown]
# ### Want to get fancy and take a look at both top and bottom records at once. Try adding minus (-) sign to either head() or tail() function

# %%
base_data.head(-5)

# %%
### Now that the data is loaded properly, lets check how many variables  and total records are present in this dataset. we will use shape propery for that.

# %%
base_data.shape

# %% [markdown]
# ### so the dataset havbe 26955 records and 5 variables. How do we know name of each variable?
# ### Well, lets check the variable name using columns property.

# %%
base_data.columns

# %% [markdown]
# ### So this dataset has five variables location, year, category, rank and query.  Do you want to know the data type of each variables?
#
# ### Well, we have one more property dtypes that we can use.

# %%
base_data.dtypes

# %%
print("Sample data : " )
print("\nFirst five countries found are :" ,list(base_data['location'].unique()[:5]))
print("\nsample five year found are :" ,list(base_data['year'].unique()[:5]))
print("\nsample five ranks found are :" ,list(base_data['rank'].unique()[:5]))
print("\nsample five queries found are :" ,list(base_data['query'].unique()[:5]))
#print(list(base_data['year'].unique()))
#print(list(base_data['rank'].unique()))
#print(list(base_data['query'].unique()))

# %% [markdown]
# ### After the data is loaded and we have basic details, I am curious about what
# * Each details each field has
# * Does all field have good quality information or not i.e is there any missing data present.
#
# ### Lets check each variable now.
# we can take a look at year wise trend using either table or a line chart

# %%
# historical query trend, draw line chart 
print(base_data.groupby('year').size())
base_data.groupby('year').size().plot()

# %% [markdown]
# ### As we can see starting year 2011, the total queries has jumped from around 500 range to 2500, this is a 5 times incrased tracffic to google. That means Business for Google.

# %% [markdown]
# ### Learn filtering
#
# #### If you look closely at top entries of country variable, you would see Global is one of the categories. Lets assume this is top level category above all countries.
#
# #### Lets filter data for this category

# %%
 base_data_global  = base_data[base_data.location=="Global"]

# %% [markdown]
# ### Lets check how many records are filtered. we will use same shape property used earlier.

# %%
base_data_global.shape

# %%
 
base_data_sorted = base_data.groupby('location', sort=False).size().reset_index()
