# %% [markdown]
# # MEI Introduction to Data Science
# # Lesson 3 - Activity 3 (AQA)
#
# This activity is an opportunity to practise the methods covered in this lesson on the AQA large data set. The comments in each section make suggestions for what you could do.
#
# The code you used for grouping was:
#
# `print(travel_2011_data.groupby(['Region'])['Bicycle percent'].mean())`
#
# The code you used for filtering was:
#
# `petrol_data = cars_data[cars_data['PropulsionTypeId'] == 'Petrol']
# print(petrol_data['CO2'].mean())
# print(petrol_data['CO2'].std())`

# %% [markdown]
# ## Problem
# > Which types of cars have higher emissions?
#
# You could explore CO2, CO or NOX for:
# * different makes of cars
# * different propulsion types
# * different body types

# %% [markdown]
# ## Getting the data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# importing the data
cars_data=pd.read_csv('../input/aqalds/AQA-large-data-set.csv')

# inspecting the dataset to check that it has imported correctly
cars_data.head()

# %% [markdown]
# ## Exploring the data

# %%
# check the datatypes

# use describe for any fields you are going to investigate and filter out any unusable values

# replace body type and propulsion type with appropriate text values

# %% [markdown]
# ## Analysing the data

# %%
# find the means and standard deviations for different groups

# create box plots for the different groups

# %% [markdown]
# ## Communicating the result

# %%
# communicate the result
