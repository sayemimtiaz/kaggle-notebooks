# %% [markdown]
# <iframe width="713" height="535" src="https://www.youtube.com/embed/NENUeJDHChU" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# Heitor Villa-Lobos. Floresta do Amazonas. Maria Luisa Tamez / OSNM / E.A. Diemecke.

# %% [markdown]
# https://www.youtube.com/watch?v=1LbpjOyi2c4    Heitor Villa-Lobos: music Amazonas (1917). Below opinions in Youtube.
# * This really raises the bar in just astonishingly fresh and captivating. It's tropical but from a western color palette.
# * Spannende Interpretation dieses ein bisschen expressionistischen Meisterwerks mit farbenreichen und gut vereinigten Töne aller Instrumente. Die Virtuosität aller Einzelspieler ist echt hoch. Der geniale Dirigent leitet das ausgezeichnete Orchester im gut artikulierten Tempo mit effektiv kontrollierter Dynamik. Atemberaubend von A bis Z!
# * Un génie de l'orchestration méconnu en France, quel dommage !!!
# * Entre los Añangu primero y en Sharamentsa más tarde sentí el doble filo de la Amazonía. Insectos que revolotean, sonidos intensos, aullar de monos, pero también otros apacibles y la fuerza del silencio… Mientras a orillas de Añangucocha la noche se diferencia radicalmente del día por el contraste sonoro, pudiendo sentir la profundidad del silencio, en Sharamentsa, al caer la noche, rumores e intervalos van diseñando un paisaje sonoro dominado por el canto solitario del anju. Melodioso,  largo y pausado. El pájaro se adueña de la noche y le procura un ritmo al modo del corazón al cuerpo. Ellos dos dominan adentro y afuera. Si entre los Añangu, al amanecer me sentía abrumado por el desbarate hasta que el ojo procuraba un equilibrio al ruido de una naturaleza que despierta de golpe. En Sharamentsa, al contrario, el amanecer es silencioso. Nada que ver con la explosión de vida del Yasuni, con la proliferación de sonidos de aves, monos, sapos... En aquel meandro del Pastaza ni siquiera el guacamayo, que dicen abunda, se anuncia. Al rato se oye la llamada de un pájaro y a poco que afino el oído, otros que puntean el paisaje sonoro. Mi sordera puede que amengüe este relieve. De ello me percato nada más salir del cuarto, mientras escribo sentado en el  porche, oigo tenues los cantos y llamadas. Puede que la bruma y la incesante lluvia manejaran los sonidos, pero también mi debilidad auditiva. La Amazonía es un universo complejo. Tanto como el del ser que no acepta límites ni asertos. A la imagen del alma virgen que no espera otra recompensa que la de vivir su oculta grandeza.

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# Image youtube   Heitor Villa-Lobos: Amazonas (1917) music youtube. Painting from Tarsila do Amaral: O lago (the lake).

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ_qUVgGVwlGCoJO5XY2V8iyEXEyHZIkmAleL5njqlVGBFHaM0N&s',width=400,height=400)

# %% [markdown]
# Image musicabrasileira.org

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
df = pd.read_csv('../input/tserof.csv', delimiter=';', nrows = nRowsRead)
df.dataframeName = 'tserof.csv'
nRow, nCol = df.shape
print(f'There are {nRow} rows and {nCol} columns')

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSQNYpnypiH_4JyaAcOgJ_nzL9AGdYCN1k2KHkUOCH5O8p3Ie86&s',width=400,height=400)

# %% [markdown]
# Image br.freepik.com

# %%
df.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRSZ2BWTEiQIMqLBisGW1Gpg-fzrW3ezZ0yiw2zQjNU4JRM4-eu&s',width=400,height=400)

# %% [markdown]
# Uirapuru bird. Image mitoselendas.com.br

# %%
df.info

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSi1EpXK6tOu7hxwCbnVwrRrr1y2PuPBw45ol4KAc29w9zxiGb2&s',width=400,height=400)

# %% [markdown]
# Image arcoweb.com.br    AMAZONIA UNDER CONSTRUCTION: THE ARCHITECTURE OF FLYING RIVERS

# %%
df.describe()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQw5LQ2hPde5K2Qvbw7XiymsJZ3ohvWj-idfyuq03TNZdBOLy5A&s',width=400,height=400)

# %% [markdown]
# Cloud condensation nuclei - New particles formation in outflow. Image jornal.usp.br

# %%
categorical_cols = [cname for cname in df.columns if
                    df[cname].nunique() < 10 and 
                    df[cname].dtype == "object"]


# Select numerical columns
numerical_cols = [cname for cname in df.columns if 
                df[cname].dtype in ['int64', 'float64']]
print(numerical_cols)

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRVxCn7lUR6dTQDF3wvkKiro4ydZAWjjG2yTGyuwKboCiAngHLPCA&s',width=400,height=400)

# %% [markdown]
# Image pisa.tur.br

# %% [markdown]
# Encoding categorical columns.

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(handle_unknown='ignore')
categorical_feature_mask = df.dtypes==object
categorical_cols = df.columns[categorical_feature_mask].tolist()
df_ohe = pd.get_dummies(df, prefix=categorical_cols, drop_first=True)
df_ohe = pd.get_dummies(df, prefix=categorical_cols, drop_first=True)

# %% [markdown]
# Another code to encode categorical columns.

# %%
import category_encoders as ce

encoder_x = ce.OrdinalEncoder()

df_encoded = encoder_x.fit_transform(df)

# %%
fig, ax =plt.subplots(figsize=(16,12))
sns.scatterplot(x='uc_name', y='prodes_2012', data=df)
plt.xticks(rotation=90)
plt.yticks(rotation=45)
plt.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRFgie8jllhtIVMvjS7pVjj8juoPAPQW0qi8vehBi_28_Af_HM3qw&s',width=400,height=400)

# %% [markdown]
# Image ultimosegundo.ig.com.br

# %%
fig, ax =plt.subplots(figsize=(16,12))
sns.scatterplot(x='uc_name', y='prodes_2016', data=df)
plt.xticks(rotation=90)
plt.yticks(rotation=45)
plt.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSIfph3FDIdYY5Y_i8N6PohZO2qel3prNmw2QS7hCjcmyxbfmw6&s',width=400,height=400)

# %% [markdown]
# Image jornalggn.com.br

# %%
fig, ax =plt.subplots(figsize=(12,10))
sns.countplot(df["prodes_2016"])
plt.xticks(rotation=90)
plt.yticks(rotation=45)
plt.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQmJ3CHA8pTruaJ2qYFIJfSAmbYbI_hPe1Wj2Tqkf19-1Us7ajZ1Q&s',width=400,height=400)

# %% [markdown]
# Image forbes.com.br

# %%
#word cloud
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in df.uc_name)
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200, background_color="black").generate(text)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='Bilinear')
plt.axis("off")
plt.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSm4btozGwQx698KUpF-OwHK_rB2eoXhxUCy1x-G9ZWWO2kYc24&s',width=400,height=400)

# %% [markdown]
# Image jornal.usp.br

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTzpAoVnp6MJu_h5QIePew6nCJmrFICxqu112N2LnXRTODb-H4G&s',width=400,height=400)

# %% [markdown]
# Image gauchazh.clicrbs.com.br

# %%
import plotly.offline as pyo
import plotly.graph_objs as go
lowerdf = df.groupby('uc_name').size()/df['prodes_2016'].count()*100
labels = lowerdf.index
values = lowerdf.values

# Use `hole` to create a donut-like pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=.6)])
fig.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR8PFfy9ysVMGO2xrXV3Mh2srum0JyV3BPckoxtW123AGbINZ18&s',width=400,height=400)

# %% [markdown]
# Image animalbusiness.com.br

# %%
df.isnull().sum()

# %%
df.notnull().sum()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQwMgZGvqyYLPdxZm9QvScQr628mcLv_vEeIg4hXvkGyiOS8e19&s',width=400,height=400)

# %% [markdown]
# Image outrapalavras.net

# %%
object_df=df.select_dtypes(include=['object'])
object_df.columns

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ7_3o8KfLu9wvsBsGZD_i70I5UXJi8L56CbHQN1FHVfq84QsOqBQ&s',width=400,height=400)

# %% [markdown]
# Image slideshare.net

# %%
for i in object_df.columns:
    print(df[i].value_counts())
    print('-'*40)

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRaj9YiHup56ihREIJCseo5_svVc9GXiYdxYeNaDtWjPywEdyys&s',width=400,height=400)

# %% [markdown]
# Image amazoniareal.com.br

# %%
num_df=df.select_dtypes(include=['int','float'])
num_df.columns

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTfEmSoi6uNNIXGUHToqymmewVUf0MVtp4RlFPV55U2rsNpfC-C&s',width=400,height=400)

# %% [markdown]
# Image meumundoviagens.com.br

# %%
#Use Series.unique() to get unique values in columns
for i in object_df.columns:
    print(i)
    print(df[i].unique())
    print('-'*40)

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQJIX4aE6qqq4cnPuH6ZGL7UC_VImpblNgd0nW9cjPLkWdB5Ef9&s',width=400,height=400)

# %% [markdown]
# The Harpy Eagle. Image: newsrondonia.com.br

# %%
#Access the values of a certain column
df['uc_name'].head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSCOtdH7MmwzRwYrwksumbhjGfodP2T_UKtRJ3DKIQ8ZSB6p_7L&s',width=400,height=400)

# %% [markdown]
# Sister Dorothy Mae Stang, S.N.D., (7 June 1931 – 12 February 2005) was an American-born, Brazilian member of the Congregation of the Sisters of Notre Dame de Namur. She was murdered in Anapu, a city in the state of Pará, in the Amazon Basin of Brazil. Stang had been outspoken in her efforts on behalf of the poor and the environment, and had previously received death threats from loggers and land owners. Her cause for canonization as a martyr and model of sanctity is underway within the Congregation for the Causes of Saints https://en.wikipedia.org/wiki/Dorothy_Stang

# %% [markdown]
# Image filmow.com

# %% [markdown]
# https://www.youtube.com/watch?v=3jS5c_al5Uk 5 quotes from Chico Mendes.

# %%
print('variance of each column')
df.var()

# %% [markdown]
# Chico Mendes a Brazilian environmentalist that was murdered (December 22,1988). The Chico Mendes Institute is named in his honor. *"At first I thought I was fighting to save rubber trees, then I thought I was fighting to save the Amazon rainforest. Now I realize I am fighting for humanity. — said Chico Mendes".

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcStyZL-Ld2N4IpepMje8qmX63WwINZYivIgNzNe0qoDXDJbTmfy&s',width=400,height=400)

# %% [markdown]
# ICMBio, author of this Dataset. The Chico Mendes Institute is named in honor of the environmentalist murdered in 1988.

# %% [markdown]
# Image planeta.macboot.com.br

# %% [markdown]
# Dataset title: Deforestation in Federal Conservation Units.Data including Legal Amazon. Therefore is about the whole country not only Amazon.

# %% [markdown]
# * K-Notebook runner: Marília Prata   @mpwolke.
# * Executive Producer: Marília Prata  @mpwolke.
