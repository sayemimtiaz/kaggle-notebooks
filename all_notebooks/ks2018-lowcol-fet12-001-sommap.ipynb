# %% [markdown]
# [som](https://github.com/darecophoenixx/wordroid.sblo.jp/wiki/%5Bsom%5D-scikit-learn-api)

# %%
# !pip install japanize-matplotlib

# %%
# !pip install git+https://github.com/darecophoenixx/wordroid.sblo.jp

# %%
# %matplotlib inline
from IPython.display import SVG, Image
from keras.utils.vis_utils import model_to_dot

import random

import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn import preprocessing
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
import seaborn as sns

import japanize_matplotlib
plt.rcParams['font.family']

# %%
def hexbin(x, y, color, **kwargs):
    cmap = sns.light_palette(color, as_cmap=True)
    plt.hexbin(x, y, cmap=cmap, **kwargs)
def scatter(x, y, color, **kwargs):
    plt.scatter(x, y, marker='.')

# %%
df_part = pd.read_csv('../input/ks2018-encode-data-001/res_all_01.csv', index_col=0)
df_part.head()

# %%
df_out_wgt_user = pd.read_csv('../input/ks2018-lowcol-fet12-001/out_user.csv', index_col=0)
X_df_user = df_out_wgt_user
wgt_user = df_out_wgt_user.values
df_out_wgt_user.head()

# %%
df_out_wgt_col = pd.read_csv('../input/ks2018-lowcol-fet12-001/out_col.csv', index_col=0)
X_df_col = df_out_wgt_col
wgt_prod = df_out_wgt_col.values
df_out_wgt_col.head()

# %%
som_out_user = pd.read_csv('../input/ks2018-lowcol-fet12-001-somcls/som_out_user.csv', index_col=0)
som_out_col = pd.read_csv('../input/ks2018-lowcol-fet12-001-somcls/som_out_col.csv', index_col=0)
som_out_user.head()

# %%
kshape1 = 4

# %%
X_df = df_out_wgt_user
X_df['som0'] = np.array([divmod(c, kshape1) for c in som_out_user['cls'].values])[:,0]
X_df['som1'] = np.array([divmod(c, kshape1) for c in som_out_user['cls'].values])[:,1]
X_df_col['som0'] = np.array([divmod(c, kshape1) for c in som_out_col['cls'].values])[:,0]
X_df_col['som1'] = np.array([divmod(c, kshape1) for c in som_out_col['cls'].values])[:,1]
X_df.head()

# %%
X_df_col.head()

# %%
from som import som

K_shape = (30, 40)
sinit = som.SimpleSOM(K_shape, initialization_func='linear')
sinit._initialize(X_df.values)

# %%
img = som.conv2img(sinit.K, K_shape)
plt.figure(figsize=(10, 10))
plt.imshow(img)

# %%
K_init = sinit.K
sobj = som.sksom(K_shape, init_K=K_init, it=500, verbose=2, early_stopping=False)

# %%
df1= pd.DataFrame(sobj.landmarks_[:,:5])
df1['cls'] = 'K'
df1.head()
df2 = pd.DataFrame(X_df.values[:,:5])
df2['cls'] = 'X'
df2.head()
df = pd.concat([df2, df1], axis=0)
df.head()
df.shape
sns.pairplot(df, markers=['.', 's'], hue='cls', plot_kws={'alpha': 0.5}, diag_kind='hist')

# %%
# %%time
sobj.r = (5.0, 1.0)
sobj.fit(X_df.values)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8,8))
ax.plot(list(range(len(sobj.meanDist))), sobj.meanDist, label="mean distance to closest landmark")

# %%
img = som.conv2img(sobj.landmarks_, K_shape)
plt.figure(figsize=(10, 10))
plt.imshow(img)

# %%
img = som.conv2img(sobj.landmarks_, K_shape)
plt.figure(figsize=(20, 20))
plt.imshow(img)

for i, m in enumerate(sobj.predict(X_df_col.values)):
    b, a = divmod(m, sobj.kshape[1])
    txt = X_df_col.index.values[i]
    plt.text(a, b, txt, ha='center', va='center',
           bbox=dict(facecolor='lightblue', alpha=0.5, lw=0))

# %%
sobj.predict(X_df.values)

# %%
df1= pd.DataFrame(sobj.landmarks_[:,:5])
df1['cls'] = 'K'
df1.head()
df2 = pd.DataFrame(X_df.values[:,:5])
df2['cls'] = 'X'
df2.head()
df = pd.concat([df2, df1], axis=0)
df.head()
df.shape
sns.pairplot(df, markers=['.', 's'], hue='cls', plot_kws={'alpha': 0.5}, diag_kind='hist')

# %%
# %%time
'''002'''
sobj.verbose = 2
sobj.r = 1.0
sobj.alpha = 2.0
sobj.it = 500
sobj.early_stopping = (15, 1.0e-7)
sobj.fit(X_df.values)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8,8))
ax.plot(list(range(len(sobj.meanDist))), sobj.meanDist, label="mean distance to closest landmark")

# %%
img = som.conv2img(sobj.landmarks_, K_shape)
plt.figure(figsize=(10, 10))
plt.imshow(img)

# %%
img = som.conv2img(sobj.landmarks_, K_shape)
plt.figure(figsize=(20, 20))
plt.imshow(img)

for i, m in enumerate(sobj.predict(X_df_col.values)):
    b, a = divmod(m, sobj.kshape[1])
    txt = X_df_col.index.values[i]
    plt.text(a, b, txt, ha='center', va='center',
           bbox=dict(facecolor='lightblue', alpha=0.5, lw=0))

# %%
df1= pd.DataFrame(sobj.landmarks_[:,:5])
df1['cls'] = 'K'
df1.head()
df2 = pd.DataFrame(X_df.values[:,:5])
df2['cls'] = 'X'
df2.head()
df = pd.concat([df2, df1], axis=0)
df.head()
df.shape
sns.pairplot(df, markers=['.', 's'], hue='cls', plot_kws={'alpha': 0.5}, diag_kind='hist')

# %%
# %%time
'''003'''
sobj.verbose = 2
sobj.r = 1.0
sobj.alpha = 1.0
sobj.it = 500
sobj.early_stopping = (15, 1.0e-7)
sobj.fit(X_df.values)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8,8))
ax.plot(list(range(len(sobj.meanDist))), sobj.meanDist, label="mean distance to closest landmark")

# %%
img = som.conv2img(sobj.landmarks_, K_shape)
plt.figure(figsize=(10, 10))
plt.imshow(img)

# %%
img = som.conv2img(sobj.landmarks_, K_shape)
plt.figure(figsize=(20, 20))
plt.imshow(img)

for i, m in enumerate(sobj.predict(X_df_col.values)):
    b, a = divmod(m, sobj.kshape[1])
    txt = X_df_col.index.values[i]
    plt.text(a, b, txt, ha='center', va='center',
           bbox=dict(facecolor='lightblue', alpha=0.5, lw=0))

# %%
df1= pd.DataFrame(sobj.landmarks_[:,:5])
df1['cls'] = 'K'
df1.head()
df2 = pd.DataFrame(X_df.values[:,:5])
df2['cls'] = 'X'
df2.head()
df = pd.concat([df2, df1], axis=0)
df.head()
df.shape
sns.pairplot(df, markers=['.', 's'], hue='cls', plot_kws={'alpha': 0.5}, diag_kind='hist')

# %%
# %%time
'''004'''
sobj.verbose = 2
sobj.r = 1.0
sobj.it = 500
sobj.early_stopping = (15, 1.0e-7)
sobj.fit(X_df.values)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8,8))
ax.plot(list(range(len(sobj.meanDist))), sobj.meanDist, label="mean distance to closest landmark")

# %%
img = som.conv2img(sobj.landmarks_, K_shape)
plt.figure(figsize=(10, 10))
plt.imshow(img)

# %%
img = som.conv2img(sobj.landmarks_, K_shape)
plt.figure(figsize=(20, 20))
plt.imshow(img)

for i, m in enumerate(sobj.predict(X_df_col.values)):
    b, a = divmod(m, sobj.kshape[1])
    txt = X_df_col.index.values[i]
    plt.text(a, b, txt, ha='center', va='center',
           bbox=dict(facecolor='lightblue', alpha=0.5, lw=0))

# %%
df1= pd.DataFrame(sobj.landmarks_[:,:5])
df1['cls'] = 'K'
df1.head()
df2 = pd.DataFrame(X_df.values[:,:5])
df2['cls'] = 'X'
df2.head()
df = pd.concat([df2, df1], axis=0)
df.head()
df.shape
sns.pairplot(df, markers=['.', 's'], hue='cls', plot_kws={'alpha': 0.5}, diag_kind='hist')

# %%
# %%time
# '''005'''
# sobj.verbose = 2
# sobj.r = 1.0
# sobj.it = 500
# sobj.early_stopping = (15, 1.0e-7)
# sobj.fit(X_df.values)

# %%
# fig, ax = plt.subplots(1, 1, figsize=(8,8))
# ax.plot(list(range(len(sobj.meanDist))), sobj.meanDist, label="mean distance to closest landmark")

# %%
# img = som.conv2img(sobj.landmarks_, K_shape)
# plt.figure(figsize=(10, 10))
# plt.imshow(img)

# %%
# img = som.conv2img(sobj.landmarks_, K_shape)
# plt.figure(figsize=(20, 20))
# plt.imshow(img)

# for i, m in enumerate(sobj.predict(X_df_col.values)):
#     b, a = divmod(m, sobj.kshape[1])
#     txt = X_df_col.index.values[i]
#     plt.text(a, b, txt, ha='center', va='center',
#            bbox=dict(facecolor='lightblue', alpha=0.5, lw=0))

# %%
# df1= pd.DataFrame(sobj.landmarks_[:,:5])
# df1['cls'] = 'K'
# df1.head()
# df2 = pd.DataFrame(X_df.values[:,:5])
# df2['cls'] = 'X'
# df2.head()
# df = pd.concat([df2, df1], axis=0)
# df.head()
# df.shape
# sns.pairplot(df, markers=['.', 's'], hue='cls', plot_kws={'alpha': 0.5}, diag_kind='hist')

# %%
som_xy = []
for ii, c in enumerate(sobj.predict(X_df.values)):
    b, a = divmod(c, sobj.kshape[1])
    som_xy.append((b, a))
som_xy = np.array(som_xy)
som_xy

plt.figure(figsize=(15,15))
ax = sns.kdeplot(som_xy[:,1], som_xy[:,0],
                 cmap="Reds", shade=True, thresh=0.05)

for ii, c in enumerate(sobj.predict(X_df_col.values)):
    colname = X_df_col.index.values[ii]
    text = colname
    b, a = divmod(c, sobj.kshape[1])
    xy = (a, b)
    ax.scatter(a, b, c='darkgreen')
    ax.annotate(text, xy=xy)

# %%
plt.figure(figsize=(13,9))
ax = sns.kdeplot(som_xy[:,1], som_xy[:,0],
                 cmap="Reds", shade=True, thresh=0.05)

for ii, c in enumerate(sobj.predict(X_df_col.values)):
    colname = X_df_col.index.values[ii]
    text = colname
    b, a = divmod(c, sobj.kshape[1])
    xy = (a, b)
    ax.scatter(a, b, c='darkgreen', s=200, marker='x')
    ax.annotate(text, xy=xy, size=15)

# %%
df_out_wgt_user['sommap_cls'] = sobj.predict(X_df.values)
df_out_wgt_col['sommap_cls'] = sobj.predict(X_df_col.values)

df_out_wgt_user.to_csv('sommap_out_user.csv')
df_out_wgt_col.to_csv('sommap_out_col.csv')
pd.DataFrame(sobj.landmarks_).to_csv('sommap_out_LM.csv')
