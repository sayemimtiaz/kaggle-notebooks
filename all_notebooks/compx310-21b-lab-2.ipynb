# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Name: Wilson Au ID:1506360

# %%
dataframe =pd.read_csv('/kaggle/input/wisconsin-breast-cancer-cytology-features/wisconsin_breast_cancer.csv')
dataframe.info()

# %% [markdown]
# #dataframe is inputing the csv files that are needed ^

# %%
dataframe=dataframe.fillna(0)
dataframe.info()

# %% [markdown]
# it only show 699 of the non-null count, if its less than 699 it will not show it on the dataframe info

# %%
dataframe.head(5)

# %% [markdown]
# It runs the top 5 lines of the data

# %%
import seaborn as sns
sns.pairplot (data=dataframe, hue='class')

# %% [markdown]
# tup a kNN classifier with k = 1,  train, predict, and
#   generate confusion_matrix + classification_report for the
#   (all features included) x_train and x_tesIt creates graphs from the dataframe as data as X and class as Y

# %%
X= dataframe.iloc[:,1:-1]
X
Y= dataframe.iloc[:,-1]
Y

# %% [markdown]
# X= dataframe.iloc[:,1:-1] is doing the second coloum to the last coloum
#
# Y= dataframe.iloc[:,-1] is counting the last coloum

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test= train_test_split(X,Y, test_size =0.2, random_state=1506360)

X_train.shape 
X_train.columns
feature =['thickness','size','single','nuclei']
xsub_train = X_train[feature]

X_test.shape 
X_test.columns

xsub_test = X_test[feature]

# %% [markdown]
# Split the dataset into 20% (test): 80%(train) ratio
#
# generate an xsub_train from x_train and an xsub_test from x_test

# %%
from sklearn.svm import SVC
A=SVC()
A
A.fit(xsub_train, Y_train)

# %% [markdown]
# SVC is a default hyperparameters

# %%
P=A.predict(xsub_test)
P

# %% [markdown]
# A.predict is listing all 0 and 1 value of the X_test

# %%
Y_test[:5]

# %% [markdown]
# output 5 values of the Y_test

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_test,P)

# %% [markdown]
# It prints out the confusion matrix for P and Y_test

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, P))

# %% [markdown]
# Creats classification_report and printing out classification_report for Y_test and P
#
# based on the graph the output of accuracy have dop from 0.96 to 0.95, the number got lower

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_clf = KNeighborsClassifier(n_neighbors=1)
#print (X_train.shape)
#print (Y_train.shape)
knn_clf.fit(X_train, Y_train)

# %% [markdown]
# The n_neibour=1

# %%
New=knn_clf.predict(X_test)
New

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_test,New)

# %%
print(classification_report(Y_test, New))

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_clf = KNeighborsClassifier(n_neighbors=5)
knn_clf.fit(X_train, Y_train)

# %%
New2=knn_clf.predict(X_test)
New2

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_test,New2)

# %%
print(classification_report(Y_test, New2))

# %% [markdown]
# n_neibour=5, this take the average of 5 data point around the graph

# %% [markdown]
# Compare to K=1 and K=5 by using the Y_test K=1 have a better averge value but K=5 have a lower score because it takes more values and averageing out from it
