# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/kaggle/input/trumps-legacy/Trumps Legcy.csv", delimiter=',')
df.head()

# %%
df.shape

# %%
df.describe()

# %%
df.info()

# %%
df['device'].unique()

# %% [markdown]
# # EDA

# %% [markdown]
# **Most Retweeted Tweet**

# %%
df.groupby(['text'])['retweets'].value_counts().unstack()[6].idxmax()

# %% [markdown]
# **Most Favorites Tweet**

# %%
df.groupby(['text'])['favorites'].value_counts().unstack()[0].idxmax()
