# %% [markdown]
# # Importing the data

# %%
import pandas as pd

heathrow_2015_data = pd.read_csv("../input/edexcelldsheathrow/heathrow-2015.csv")
heathrow_2015_data.head(6)

# %%
heathrow_2015_data.dtypes

# %% [markdown]
# ## a) Comparing the temperatures

# %%
heathrow_2015_data['Daily Mean Temperature'].describe()

# %% [markdown]
# (i) Change the code below so that it imports the data to a dataset named heathrow_1987_data and gives the mean temperature.

# %%
heathrow_2015_data = pd.read_csv("../input/edexcelldsheathrow/heathrow-2015.csv")
heathrow_2015_data['Daily Mean Temperature'].describe()

# %% [markdown]
# (ii) What do the values represent count, mean, std, min, 25%, 50%, 75% and max represent? How might you use these statistics?

# %% [markdown]
# (iii) Using the values given what differences can you identify between the temperature for the two years?

# %% [markdown]
# ## b) Comparing rainfall across the two years

# %% [markdown]
# The code in block below gives the statistics for ‘Daily Total Rainfall’ for 2015.

# %%
heathrow_2015_data['Daily Total Rainfall'].describe()

# %% [markdown]
# (i) You should notive that the statistics calculated are different. Pandas functions can’t cope with some numbers and some text in a field. Using your knowledge of the large data set explain why this is occuring for this Daily Total Rainfall.

# %% [markdown]
# The code in the blocks below replaces the “tr” values with 0.025 for both years and reformats them as a “float” data type: i.e. a real number.

# %%
heathrow_2015_data['Daily Total Rainfall'] = heathrow_2015_data['Daily Total Rainfall'].replace({'tr': 0})
heathrow_2015_data['Daily Total Rainfall'] = heathrow_2015_data['Daily Total Rainfall'].astype('float')
heathrow_2015_data['Daily Total Rainfall'].describe()

# %%
heathrow_1987_data['Daily Total Rainfall'] = heathrow_1987_data['Daily Total Rainfall'].replace({'tr': 0.025})
heathrow_1987_data['Daily Total Rainfall'] = heathrow_1987_data['Daily Total Rainfall'].astype('float')
heathrow_1987_data['Daily Total Rainfall'].describe()

# %% [markdown]
# (ii) Exploring the difference it would make if you replaced tr with 0, instead of 0.025, by editing the code. Is it big enough to be concerned about? Are the good arguments for either?

# %% [markdown]
# (iii) What is the importance of the line: <br>
# `heathrow_2015_data['Daily Total Rainfall'] = heathrow_2015_data['Daily Total Rainfall'].astype('float')`<br>
# What happens if you remove this line and run the code?

# %% [markdown]
# ## c) Comparing the wind for the two years:

# %% [markdown]
# The code below find the counts of different categories.

# %%
heathrow_2015_data['Mean Cardinal Direction'].value_counts()

# %%
heathrow_1987_data['Mean Cardinal Direction'].value_counts()

# %% [markdown]
# (i) The total for 1987 is <184. Using your knowledge of the large data set explain why this is the case. Note that pandas default is to ignore "N/A".

# %% [markdown]
# (ii) Do the two outputs suggest that the predominant wind directions are similar for the two years?

# %% [markdown]
# (iii) For which other fields in the dataset would value_counts() be appropriate for? Change the code in the box below to these fields and explore the differences between the two years.

# %%
heathrow_2015_data['Mean Cardinal Direction'].value_counts()

# %%
heathrow_2015_data['Mean Cardinal Direction'].value_counts()

# %% [markdown]
# ## d) Extension activity

# %% [markdown]
# Try applying these to other fields and other locations. Are there consistent differences between the weather at different locations? {Note: other csv files are needed and names to be given. Also need a note that "print" has been used to output mulitple blocks.}.

# %%
heathrow_2015_data = pd.read_csv("../input/edexcelldsheathrow/heathrow-2015.csv")
print(heathrow_2015_data['Daily Mean Temperature'].describe())
print(heathrow_2015_data['Mean Cardinal Direction'].value_counts())

# %%
heathrow_1987_data = pd.read_csv("../input/edexcelldsheathrow/heathrow-1987.csv")
print(heathrow_1987_data['Daily Mean Temperature'].describe())
print(heathrow_1987_data['Mean Cardinal Direction'].value_counts())
