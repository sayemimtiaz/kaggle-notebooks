# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

from PIL import Image
import matplotlib.pyplot as plt        
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# TODO 1: EDA
# Univariate Analysis:
# Trình bày các quan sát về phân phối của các biến
# Bộ Data có các điểm nào cần chú ý (để thực hiện trong bước Data Processing)?
' Đây là bộ dataset gồm 8 cột, gồm:
' 5 cột có giá trị Số: Avg. Session Length, Time on App, Time on Website, Length of Membership, Yearly Amount Spent
' 2 cột String: Address có 500 unique values, Avatar có 138 unique values
' 1 cột là địa chỉ Email: 500 unique values
' Hình bên dưới'

# %% [markdown]
# ![](https://storage.googleapis.com/kagglesdsdata/datasets/1412331/2339391/data7_2.PNG?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=databundle-worker-v2%40kaggle-161607.iam.gserviceaccount.com%2F20210616%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20210616T123113Z&X-Goog-Expires=345599&X-Goog-SignedHeaders=host&X-Goog-Signature=...)

# %%
# Multivariate Analysis:
# Trình bày các tương tác thú vị giữa các biến, giải thích thêm theo ý kiến và suy nghĩ của bạn
'Hình bên dưới'

# %% [markdown]
# ![](https://storage.googleapis.com/kagglesdsdata/datasets/1412331/2339341/data7_1.PNG?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=databundle-worker-v2%40kaggle-161607.iam.gserviceaccount.com%2F20210616%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20210616T121433Z&X-Goog-Expires=345599&X-Goog-SignedHeaders=host&X-Goog-Signature=...)

# %% [markdown]
# ![](https://storage.googleapis.com/kagglesdsdata/datasets/1412331/2339404/data7_3.PNG?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=databundle-worker-v2%40kaggle-161607.iam.gserviceaccount.com%2F20210616%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20210616T123442Z&X-Goog-Expires=345599&X-Goog-SignedHeaders=host&X-Goog-Signature=...)

# %% [markdown]
# ![](https://storage.googleapis.com/kagglesdsdata/datasets/1412331/2339404/data7_4.PNG?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=databundle-worker-v2%40kaggle-161607.iam.gserviceaccount.com%2F20210616%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20210616T123509Z&X-Goog-Expires=345599&X-Goog-SignedHeaders=host&X-Goog-Signature=...)

# %% [markdown]
# ![](https://storage.googleapis.com/kagglesdsdata/datasets/1412331/2339425/data7_5.PNG?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=databundle-worker-v2%40kaggle-161607.iam.gserviceaccount.com%2F20210616%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20210616T124041Z&X-Goog-Expires=345599&X-Goog-SignedHeaders=host&X-Goog-Signature=...)

# %%
# Customer Yearly Amount Spent
# Yếu tố chúng ta quan tâm nhất là Yearly Amount Spent (Số tiền giao dịch của khách hàng trong năm)
# Tự đặt các giả thuyết về yếu tố ảnh hướng (trong bộ data) và làm các bước phân tích, 
# Vẽ các biểu đồ để tìm hiểu các giả thuyết đó.
