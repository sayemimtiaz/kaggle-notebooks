# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))

# Any results you write to the current directory are saved as output.
df = pd.read_csv('../input/pokemon-spawns.csv',header = 0)

# %%
df.head(10)

# %%
df.dtypes

# %%
df.info()

# %%
df.describe()

# %%
import datetime
datetime.datetime.fromtimestamp(df['encounter_ms'][0]/1000.0)

# %%
datetime.datetime.fromtimestamp(df['disppear_ms'][0]/1000.0)

# %%
false_timeorder_count = (df['encounter_ms'] > df['disppear_ms'] ).sum()
logical_timeorder_count = (df['encounter_ms'] < df['disppear_ms'] ).sum()
false_timeorder_count/logical_timeorder_count

# %%
false_lng_count = (df['lng'] > 0).sum()  #all of them are larger then 139
logical_lng_count = (df['lng'] < 0).sum()
false_lng_count/logical_lng_count

# %%
df = df[df['lng'] < -100]

# %%
(df['name']=='Muk').sum()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# %%
map = Basemap(projection='ortho',lat_0=37.44,lon_0=-117.21,resolution='l')
m = Basemap(llcrnrlon=-120.,llcrnrlat=36.,urcrnrlon=-105.,urcrnrlat=38., resolution='l',projection='merc',lat_0=37.44.,lon_0=-117.21.)

# %%
l = Basemap(llcrnrlon=-120.,llcrnrlat=36.,urcrnrlon=-105.,urcrnrlat=38.,\
            resolution='h',width = 1000000000,height = 1000000000)

# %%
l.drawmapboundary(fill_color='aqua')
#l.fillcontinents(color='coral',lake_color='aqua')
l.drawcoastlines()

# %%
df[df['name']=='Sandslash']

# %%
sandslash= df[df['name']=='Sandslash']
pidgey = df[df['name']=='Pidgey']

# %%
sandslash[['lat','lng']]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(sandslash[['disppear_ms']]/1000,sandslash[['lat']], 'ro')
plt.ylabel('lat')
plt.xlabel('disappear_s')
plt.title('time-lat')
#plt.axis([1.468*1e9,1.47*1e9,  36.5, 38])
plt.show()

# %%
plt.plot(pidgey[['disppear_ms']]/1000,pidgey[['lat']], 'ro')
plt.ylabel('lat')
plt.xlabel('disappear_s')
plt.title('time-lat')
#plt.axis([1.468*1e9,1.47*1e9,  36.5, 38])
plt.show()

# %%
plt.plot(sandslash[['lng']],sandslash[['lat']], 'ro')
plt.xlabel('lng')
plt.ylabel('lat')
plt.title('lng-lat')
#plt.axis([-123, -121, 36.5, 38])
plt.show()

# %%
plt.plot(pidgey[['lng']],pidgey[['lat']], 'ro')
plt.xlabel('lng')
plt.ylabel('lat')
plt.title('lng-lat')
#plt.axis([-123, -121, 36.5, 38])
plt.show()
