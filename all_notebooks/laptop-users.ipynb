# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv('../input/dataset-of-laptop-users/Laptop-Users.csv')
df

# %% [markdown]
# **Data Preprocessing**

# %%
x = df.iloc[:,:-1]
x

# %%
y = df.iloc[:,5]
y

# %%
label = LabelEncoder()

# %%
x = x.apply(LabelEncoder().fit_transform)
x

# %% [markdown]
# **Decision Tree Model**

# %%
Dec = DecisionTreeClassifier()

# %%
X = Dec.fit(x,y)

# %%
predict = X.predict([[19,1,1,1,10]])
predict

# %% [markdown]
# **Visualization**

# %%
sb.pairplot(df, hue="Has Laptop", palette="dark")

# %%
sb.heatmap(x, cmap="YlGn")
