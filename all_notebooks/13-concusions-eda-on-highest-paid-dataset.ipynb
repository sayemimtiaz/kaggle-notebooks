# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
rich = pd.read_csv('../input/forbes-highest-paid-athletes-19902019/Forbes Richest Atheletes (Forbes Richest Athletes 1990-2020).csv')
rich.head()

# %%
rich.tail()

# %%
rich.describe()

# %%
rich.info()

# %%
rich.isnull().sum()

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='most_frequent')
rich.iloc[:,:] = imputer.fit_transform(rich)

# %%
rich.head()

# %%
rich.isnull().sum()

# %%
rich[rich["Nationality"]=="USA"]

# %%
rich.shape
#out of 301 players most of them are usa players-->206 players are from usa

# %%
rich.corr()

# %%
rich.cov()

# %%
rich["Nationality"].value_counts()

# %%
#top 10 countries from where players were most
rich["Nationality"].value_counts()[0:10]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,9))
plt.bar(list(rich["Nationality"].value_counts().keys()),list(rich["Nationality"].value_counts()))
plt.title("Players with their native country")
plt.ylabel("count")
plt.xlabel("country names")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.pie(list(rich["Nationality"].value_counts()),labels=list(rich["Nationality"].value_counts().keys()),autopct="%0.1f%%")
plt.show()

# %%
rich["Sport"].value_counts()
#Basketball is the most popular sport among the dataset

# %%
plt.figure(figsize=(20,9))
plt.bar(list(rich["Sport"].value_counts().keys()),list(rich["Sport"].value_counts()))

# %%
plt.figure(figsize=(10,5))
plt.pie(list(rich["Sport"].value_counts()),labels=list(rich["Sport"].value_counts().keys()),autopct="%0.1f%%")
plt.show()

# %%
rich["Year"].value_counts()
#2002 is the most repeated year

# %%
Rank=((rich["Current Rank"]==rich["Previous Year Rank"]))
Rank.value_counts()
#there is no row where current rank is equal to previous year rank

# %%
rank_1=rich[rich["Current Rank"]==1]
rank_1

# %%
rank_1["Name"].value_counts()
#tiger woods been the top earnings most of the time

# %%
rank_1["Sport"].value_counts()
#golf is the sport where most of the players been the top paid players.

# %%
rank_1[rank_1["Name"]=="Tiger Woods"]
#tiger woods been the top earner in the following years.

# %%
plt.figure(figsize=(10,5))
plt.bar(list(rank_1["Name"].value_counts().keys()),list(rank_1["Name"].value_counts()),align="center")

# %%
import seaborn as sns
rich_df=rich.iloc[:,3:8]
sns.pairplot(rich_df)

# %%
rich["earnings ($ million)"].unique()

# %%
top_earnings=rich.sort_values(by = "earnings ($ million)",ascending=False)
top_earnings.head()
# $ 300.0 millions is the top paid amount in the field of boxing and ppaid to the player Floyd Mayweather.

# %%
top_earnings.tail()
# $ 8.1 millions is the least amount paid to Michael Jordan in the field of basketball

# %%
rich_golf=rich[rich["Sport"]=="golf"]
rich_golf.sort_values(by="earnings ($ million)",ascending=False)
# in the field of golf sport $ 115.0 million is the top amount been paid to the players and $ 8.1 million is the least amount been paid

# %%
rich_boxing=rich[rich["Sport"]=="Boxing"]
rich_boxing.sort_values(by="earnings ($ million)",ascending=False)
# in the field of boxing sport $ 300.0 million is the top amount been paid to the players and $ 12.0 million is the least amount been paid

# %%
rich_basketball=rich[rich["Sport"]=="Basketball"]
rich_basketball.sort_values(by="earnings ($ million)",ascending=False)
# in the field of basketball sport $ 89.0 million is the top amount been paid to the players and $ 12.9 million is the least amount been paid

# %%
rich_soccer=rich[rich["Sport"]=="Soccer"]
rich_soccer.sort_values(by="earnings ($ million)",ascending=False)
# in the field of soccer sport $ 127.0 million is the top amount been paid to the players and $ 41.3 million is the least amount been paid

# %%
rich[rich["Sport"]=="Golf"]
rich_golf.sort_values(by="earnings ($ million)",ascending=False)
# in the field of golf sport $ 115.0 million is the top amount been paid to the players and $ 8.1 million is the least amount been paid

# %%
rich_autoracing=rich[rich["Sport"]=="Auto Racing"]
rich_autoracing.sort_values(by="earnings ($ million)",ascending=False)
# in the field of autoracing sport $ 59.0 million is the top amount been paid to the players and $ 11.3 million is the least amount been paid

# %%
#conclusions:
#out of 301 players most of them are usa players-->206 players are from usa
#Basketball is the most popular sport among the dataset
#2002 is the most repeated year
#there is no row where current rank is equal to previous year rank
#tiger woods been the top earnings most of the time
# $ 300.0 millions is the top paid amount in the field of boxing and ppaid to the player Floyd Mayweather.
# $ 8.1 millions is the least amount paid to Michael Jordan in the field of basketball
# in the field of golf sport $ 115.0 million is the top amount been paid to the players and $ 8.1 million is the least amount been paid
# in the field of boxing sport $ 300.0 million is the top amount been paid to the players and $ 12.0 million is the least amount been paid
# in the field of basketball sport $ 89.0 million is the top amount been paid to the players and $ 12.9 million is the least amount been paid
# in the field of soccer sport $ 127.0 million is the top amount been paid to the players and $ 41.3 million is the least amount been paid
# in the field of golf sport $ 115.0 million is the top amount been paid to the players and $ 8.1 million is the least amount been paid
# in the field of autoracing sport $ 59.0 million is the top amount been paid to the players and $ 11.3 million is the least amount been paid
