# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
car_data=pd.read_csv("/kaggle/input/vehicle-dataset-from-cardekho/car data.csv")

# %%
car_data.head()

# %%
car_data.info()

# %%
car_data.describe()

# %%
car_data[car_data.Year>2005]

# %%
car_data[car_data.Fuel_Type=='Petrol']

# %%
df=car_data[car_data.Fuel_Type=='Diesel']

# %%
df.info()

# %%
car_data[(car_data.Fuel_Type!='Petrol')&(car_data.Fuel_Type!='Diesel')]

# %%
df1=car_data[(car_data.Fuel_Type=='Diesel')&(car_data.Year>=2005)&(car_data.Year<=2008)]
print(df1)

# %%
df1.info()

# %%
df1.to_csv('Diesel.csv')

# %%
print(car_data.Fuel_Type.unique())
print(car_data.Fuel_Type.nunique())

# %%
car_data[(car_data.Car_Name=='city')|(car_data.Car_Name=='brio')]

# %%
car_data[(car_data.Car_Name=='swift')&(car_data.Year>=2013)]

# %%
car_data[(car_data.Kms_Driven<27000)&(car_data.Fuel_Type=='Petrol')]

# %%
car_data[(car_data.Seller_Type=='Dealer')&(car_data.Fuel_Type=='Diesel')]

# %%
car_data[(car_data.Seller_Type=='Dealer')&(car_data.Seller_Type=='Individual')].count()

# %%
car_data.drop_duplicates()

# %%
df=car_data.drop_duplicates()
df.to_csv('Unique_Data.csv')

# %%
car_data[car_data.duplicated()]

# %%
df=car_data[car_data.duplicated()]
df.to_csv('Duplicate_Data.csv')

# %%
car_data.loc[(car_data['Car_Name']=='city')]='honda_city'

# %%
car_data
