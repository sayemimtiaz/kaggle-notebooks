# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#An EDA checklist
#1. What question(s) are you trying to solve (or prove wrong)?
#2. What kind of data do you have and how do you treat different types?
#3. What’s missing from the data and how do you deal with it?
#4. Where are the outliers and why should you care about them?
#5. How can you add, change or remove features to get more out of your data?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import missingno

# %%
df = pd.read_csv('../input/stroke-prediction-dataset/healthcare-dataset-stroke-data.csv')

# %%
df.shape

# %%
df.head()

# %%
#Removing Redundant variables'id'
df = df.drop(columns=df.columns[0])

# %%
df.head()

# %%
#understanding of variables in the data set
df.columns

# %%
cont_features= ['age','avg_glucose_level','bmi']
cat_features= ['gender','hypertension','heart_disease','ever_married','work_type','Residence_type','smoking_status']
target='stroke'

# %%
df[["gender", "ever_married", "work_type", "Residence_type", "smoking_status"]].values

# %%
df.dtypes

# %%
df['gender'].unique()

# %%
df.info()

# %%
#check for null values
df.isnull().sum()

# %%
missingno.matrix(df)
plt.show()

# %%
df['bmi'].fillna((df)['bmi'].mean(), inplace = True)

# %%
missingno.matrix(df)
plt.show()

# %%
df.describe()

# %%
#Univariate analysis of Numerical Continous variable 'age'
df['age'].hist(bins=8)

# %%
#Univariate analysis of Numerical Continous variable 'avg_glucose_level'
df['avg_glucose_level'].hist(bins=10)

# %%
#Univariate analysis of Numerical Continous variable 'bmi'
sns.boxplot(x=df['bmi'])

# %%
#Univariate analysis of Categorical variable 'work_type'
work_type = df['work_type'].value_counts()
print('work_type')

sns.countplot(x=df['work_type'])
plt.show()

# %%
#Univariate analysis of Categorical variable 'hypertension'
hypertension = df['hypertension'].value_counts()
print('hypertension')

sns.countplot(x=df['hypertension'])
plt.show()

# %%
#Univariate analysis of Categorical variable 'heart_disease'
heart_disease = df['heart_disease'].value_counts()
print('heart_disease')

sns.countplot(x=df['heart_disease'])
plt.show()

# %%
#Univariate analysis of Categorical variable 'ever_married'
ever_married = df['ever_married'].value_counts()
print('ever_married')

sns.countplot(x=df['ever_married'])
plt.show()

# %%
#Univariate analysis of Categorical variable 'Residence_type'
Residence_type = df['Residence_type'].value_counts()
print('smoking_status')

sns.countplot(x=df['Residence_type'])
plt.show()

# %%
smoking_status = df['smoking_status'].value_counts()
print('smoking_status')
sns.countplot(x=df['smoking_status'])
plt.show()

# %%
smoking_status = df['smoking_status'].value_counts()
print('smoking_status')
sns.countplot(x=df['smoking_status'])
plt.show()

# %%
# Create the countplot by gender
sns.countplot(x="work_type", data=df, 
              hue="gender")            # set hue=gender

# %%
# Change the hue order 
sns.countplot(x="work_type", data=df, hue="gender", 
              hue_order=["Female","Male","Others"])  # Set hue_order as a list

# %%
plt.figure(figsize=(10, 8))
sns.swarmplot(x="smoking_status", y="bmi", hue='gender', data=df)

# %%
# Using parplot to get scatterplots between all variables in the dataset
sns.pairplot(data=df)

# %%
# Using pairplot to get scatterplots between all variables in the dataset.We can use hue for pairplot
sns.pairplot(data=df, hue='gender')

# %%
# Create a crosstab: location by gender
df_crosstab = pd.crosstab(df['gender'], df['Residence_type'])
df_crosstab

# %%
# Create a simple stacked bar plot
# We create from the crosstable
df_crosstab.plot.bar(stacked=True, xlabel='ever_married', ylabel='stroke_count', linewidth=0.0)

# %%
# Create a crosstab: Stroke by gender
df_crosstab = pd.crosstab(df['gender'], df['stroke'])
df_crosstab

# %%
# Create a simple stacked bar plot
# We create from the crosstable
df_crosstab.plot.bar(stacked=True, xlabel='ever_married', ylabel='stroke_count', linewidth=0.0)

# %%
# Create a crosstab: Stroke by gender
df_crosstab = pd.crosstab(df['smoking_status'], df['stroke'])
df_crosstab

# %%
# Create a simple stacked bar plot
# We create from the crosstable
df_crosstab.plot.bar(stacked=True, xlabel='ever_married', ylabel='stroke_count', linewidth=0.0)

# %%
# Create a crosstab: Stroke by gender
df_crosstab = pd.crosstab(df['work_type'], df['stroke'])
df_crosstab

# %%
# Create a simple stacked bar plot
# We create from the crosstable
df_crosstab.plot.bar(stacked=True, xlabel='ever_married', ylabel='stroke_count', linewidth=0.0)

# %%
# Create a crosstab: Stroke by gender
df_crosstab = pd.crosstab(df['ever_married'], df['stroke'])
df_crosstab

# %%
# Create a simple stacked bar plot
# We create from the crosstable
df_crosstab.plot.bar(stacked=True, xlabel='ever_married', ylabel='stroke_count', linewidth=0.0)
