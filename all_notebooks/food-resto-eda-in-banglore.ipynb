# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as ws
ws.filterwarnings("ignore")

# %%
# Load the  NoteBook
df = pd.read_csv("/kaggle/input/restaurants-in-bangalore/CleanedBangaloreHotels.csv")

# %%
df.head()

# %% [markdown]
# ### After the initial look i will convert the two coloumns to the float i.e. price and ratings

# %%
df.dtypes

# %%
temp = df[["price", "ratings"]]

# %% [markdown]
# <div>
#             <h1 stype = "color: white;text-align:center;"> Let's Do Some EDA </h1>
#     <img src = "https://i.pinimg.com/564x/25/16/e2/2516e271b4f6ff08e87d81e5db8e197c.jpg" height = 350, width = 350/>
#     </div>

# %% [markdown]
# <div> <h2 style = "color: skyblue;"> Dealing with the some unnecessary values which are perticularty not cachable  </h2> </div>
# <br>
#
# <p style = "text-align: justify;"> While performing the eda  i detected some unusual rating and the prices for the some resto. <br> Hence, i replaced the ratings with the initial rating and then converted them to the float values and with the prices i replaced them with <i>  nan </i>  which later i will manage bu using the imputer </p>

# %%
temp[temp.price.str.contains("\n")]

# %%
sample = temp.price.str.replace("<bound method Series.mean of 1 100\n2 ...", 'NA')

# %%
sample.iloc[sample[sample.str.contains("\n")].index] = np.nan

# %%
df.price = sample.astype(float)

# %%
temp.ratings = temp.ratings.str[:3]

# %%
df.ratings = temp.ratings.astype(float)

# %%
df.dtypes

# %%
df.head()

# %%
df.cuisine.nunique ()

# %% [markdown]
# ### ** Finding the Most Occuring Cuisine in the Banglore**

# %%
top_cuisine = df.cuisine.value_counts().reset_index().sort_values("cuisine", ascending = False)[:5]

# %%
# %matplotlib inline
sns.set(font_scale = 1.5)
plt.figure(figsize = (15,6))
sns.barplot(x=top_cuisine["index"], y = top_cuisine["cuisine"], palette="coolwarm")
plt.show()

# %% [markdown]
# <div>
#             <h1 stype = "color: white;text-align:center;"> South Indian Food is Famous here and we can find reasons furthur </h1>
#     <img src = "https://i.pinimg.com/564x/1e/56/f7/1e56f78f1c196e654c766f7286e14f91.jpg" height = 350, width = 350/>
#     </div>

# %% [markdown]
# ## Now we will find the average price distribution for the top food typs in the  above category

# %%
mean_price = []
for i in top_cuisine["index"].to_list():
    avg_price = df[df["cuisine"] == i]["price"].mean()
    mean_price.append(avg_price)
mean_price_df = pd.DataFrame(top_cuisine["index"])
mean_price_df["avg_price"] = mean_price
mean_price_df.rename(columns = {"index": "cuisine"}, inplace = True)

# %%
sns.set(font_scale = 1.5)
plt.figure(figsize = (8,6))
plt.title("Average Price of each most occuring food type in banglore", fontdict={'fontsize':20})
sns.barplot(x=mean_price_df["avg_price"], y = mean_price_df["cuisine"], palette="inferno")
plt.show()

# %% [markdown]
# ### The Pattern is that the most occuring south indian food is quite cheaper than that of the other food types.
# ### This is also a reason to be  the best and most demanding food in the locality.

# %% [markdown]
# We will describe the Rating distribution

# %%
ratings_view = df.ratings.value_counts().reset_index().sort_values(by= "index", ascending = False)

# %%
sns.set()
plt.figure(figsize = (15,8))
plt.title("Distribution of the rating for resto in banglore", fontdict={'fontsize':20})
sns.barplot(x=ratings_view["index"], y = ratings_view["ratings"], palette="inferno")
plt.show()

# %% [markdown]
# ### As we can clearly see, th most of the resto bears the ratings of the 3.5 to 4.0. The Most occuring one is 3.9 this denotes that the all the resto delivers the good food and gives the proper customer service in order to serve the customers

# %%
sns.set(font_scale = 1.5)
plt.figure(figsize = (25,8))
plt.title("Distribution of the Price with rating for resto in banglore", fontdict={'fontsize':20})
sns.lineplot(y=df["price"], x = df["ratings"])
plt.show()

# %% [markdown]
# #  From the above line graph we can conclude the  normal aspects of business. i.e. quality demands pricing. The above graph clearly denotes that. We can see the sudden rise in the price as soon as we passes the ratings of the  4.0

# %%
top_resto = pd.DataFrame()
new_temp = pd.DataFrame()
for i in mean_price_df["cuisine"]:
    temp = df[df["cuisine"] == i]
    print("Top restaurants for " , i.upper() , "(according to ratings)")
    print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
    print(temp[temp['ratings'] > 4.0]["name"][:5])
    print("-------------------------------------")

# %%
plt.figure(figsize = (8,8))
sns.set(font_scale = 1.5)
plt.title("Most occuring food tags in banglore", fontdict={'fontsize':30})
sns.barplot(y="index", x="tags" , data = df.tags.value_counts()[:10].reset_index())
plt.show()

# %% [markdown]
# ### Relation between the Price and the ratings

# %% [markdown]
# **Scatter plot for price and ratings**

# %%
sns.set(font_scale = 1.2)
plt.figure(figsize = (8,8))
sns.scatterplot(y="price", x="ratings", data = df, hue=df["ratings"],size=df["ratings"] , palette="rainbow")
plt.show()

# %% [markdown]
# # ---------------------------------------------------------------------

# %% [markdown]
# <div>
#     <h1> Final thoughts :- </h1>
#     <ol>
#    <h3> <li> Quick Bites is the most occuring food tag in the  banglore</li></h3>
#     <h3><li> South Indian Food is most popular in banglore</li></h3>
#    <h3> <li> It is also cheaper</li></h3>
#    <h3> <li> price and ratings have good correlation</li></h3>
#    <h3><li>  Fair amount of  Resto's bear good ratings like (3.5 - 4.0) </li></h3>
#    <h3> <li> Price distribution shows the sudding peak once it reached the high rating like above 4.0</li></h3>
#    <h3> <li> Untill ratings below the 4.0 the price follows the common trend</li></h3>
#     </ol>
# </div>

# %% [markdown]
# # UPVOTE IT ^ :)
# if you find it useful
