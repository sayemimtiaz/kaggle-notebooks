# %%
import pandas as pd

data = pd.read_csv('../input/piratesvsglobalwarmingcorrelationcausation/pirates-vs-global-warming.csv')
data['Temp'] = data['global-average-temperature']
data['Pirates'] = data['number-of-pirates']
data

# %%
(data.plot(x='Year', y='Temp'))
(data.plot(x='Year', y='Pirates'))
(data.plot(x='Pirates', y='Temp'))
data.corr()
