# %% [markdown]
# # 🎯Will you get Hired? 🎯: Prediction Modelling with Random Forests
# <img src="https://akm-img-a-in.tosshub.com/indiatoday/images/story/201905/job_options_CV.jpeg?Yh8tPiCRdxAiao.8LFlak862XkdGBrZo" width=400>
# This data set consists of Placement data of students in our campus. It includes secondary and higher secondary school percentage and specialization. It also includes degree specialization, type and Work experience and salary offers to the placed students.<br>
# In this Notebook I aim to build a predictive model using Random Forests.

# %% [markdown]
# ## My EDA Notebook : [🎯Will you get Hired? 🎯: A Placement EDA](https://www.kaggle.com/hod101s/will-you-get-hired-a-placement-eda#Who-doesnt-get-Placed-in-MBA?)

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, plot_confusion_matrix, confusion_matrix

# %%
data = pd.read_csv('../input/factors-affecting-campus-placement/Placement_Data_Full_Class.csv')
data.head()

# %% [markdown]
# # Label Encoded DataFrame

# %%
lbldata = data.copy()
lbldata.drop(['sl_no','salary'],axis=1,inplace=True)
categorical = ['gender','ssc_b','hsc_b','hsc_s','degree_t','workex','specialisation','status']
for col in categorical:
    lbldata[col]  = LabelEncoder().fit_transform(lbldata[col])
lbldata.head()

# %%
X_train,X_test,y_train,y_test = train_test_split(lbldata.drop('status',axis=1),lbldata.status,test_size=0.2)

# %% [markdown]
# # Random Forests

# %%
parameters = {
    'n_estimators'      : [320,330,340],
    'max_depth'         : [8,16,32,64],
    'random_state'      : [0,32,42]
}

clf = GridSearchCV(RandomForestClassifier(), parameters, cv=10, n_jobs=-1)
clf.fit(X_train,y_train)

# %%
preds = clf.predict(X_test)
print(classification_report(y_test,preds))

# %%
plot_confusion_matrix(clf,X_test,y_test)

# %%
clf.score(X_test,y_test)

# %% [markdown]
# **Observations**:
# - Using Random Forests we've got an average accuracy of 90.69%

# %% [markdown]
# If you found this interesting do UPVOTE! And do check out my EDA Notebook : [🎯Will you get Hired? 🎯: A Placement EDA](https://www.kaggle.com/hod101s/will-you-get-hired-a-placement-eda#Who-doesnt-get-Placed-in-MBA?)
# <br>Thanks!
