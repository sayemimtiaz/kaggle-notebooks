# %% [markdown]
# Parking in Washington D.C.
#
# We will try to look at the data and how it can be usefull and what we can learn and use the data for

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
df = pd.read_csv('../input/parking.csv')
df.head(n=3)

# %% [markdown]
# We will start by looking at the license plate of the cars. Most of them come from the state of Maryland then Virginia and District of Columbia, if ads need to be taken and with presuming limited resources Maryland ads can be taken in the state to limit violation.

# %%
a = df['RP_PLATE_STATE'].value_counts()
print (a)

# %% [markdown]
# The type of violations that happens around Washington D. C. park meter expired followed by failure to display multispace meter receipt and disobeying official signs. Therefore this should be an encouraging sign to try maybe provide some warning to motorist or give them more option to pay for the parking lots of interesting interpretation.

# %%
b = df['VIOLATION_DESCRIPTION'].value_counts()
print (b)

# %% [markdown]
# I thought to look at the day to see when most parking violations happen it turned out Wednesday, which is interesting. During the start of the week of the working week Monday is the lowest and it max out on Wednesday and then declines gradually to the weekend.

# %%
c = df['DAY_OF_WEEK'].value_counts()
print (c)

# %% [markdown]
# I thought to look at the vehicle body style to determine the demographic of the parking offenders but as you can see it clearly did not help. Number one is 4D which I guess stand for four door which can be a luxury vehicle or normal sedan. However in second place UT which I am only guessing here stand for Utilities vehicle.

# %%
d = df['BODY_STYLE'].value_counts()
print (d)

# %% [markdown]
# One of the major questions that needed to be answered, which area has the highest concentration of parking violations and simply looking through the value count it is C, K, G, H and S NW North Side.

# %%
e = df['LOCATION'].value_counts()
print (e)

# %% [markdown]
# Finally I will try to answer the question does parking violations change over the month of December  using the object ID for each car and address ID for each location and indexing it over the days of the week it seems to increase on Wednesdays as previously and thins out gradually

# %%
f = df['OBJECTID'].value_counts()
print (f)

# %%
g = df['ADDRESS_ID'].value_counts()
print (g)

# %%
df.plot(x='ADDRESS_ID', y='OBJECTID', style='.')

# %%
threedee = plt.figure().gca(projection='3d')
threedee.scatter(df.index, df['ADDRESS_ID'], df['OBJECTID'])
threedee.set_xlabel('Index')
threedee.set_ylabel('ADDRESS ID')
threedee.set_zlabel('OBJECTID')
plt.show()
