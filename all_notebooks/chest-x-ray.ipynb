# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# ## Encoding Categorical Features

# %%
df = pd.read_csv('../input/nodules-in-chest-xrays-jsrt/jsrt_metadata.csv')

# %%
df.head()

# %%
gender_labels = pd.get_dummies(df['gender'])

# %%
gender_labels

# %%
gender_meta_data = {'female':1,'male':0}

# %%
df['gender'] = gender_labels

# %%
df.head()

# %%
df['state'].unique()

# %%
df.groupby('state').count()

# %%
labels_metadata = {'malignant':2,'non-nodule':0,'benign':1}

# %%
df['state'] = df['state'].map(labels_metadata)

# %%
df.head()

# %%
len(df['position'].unique())

# %%
df['diagnosis'].unique()

# %%
new_df = df.drop(['position','diagnosis'],axis=1)

# %%
new_df.head()

# %%
new_df.to_csv('cleaned_metadata.csv',index=False)

# %%
x = new_df.drop('state',axis=1)

# %%
y = pd.get_dummies(new_df['state'])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=42,test_size=0.2)
