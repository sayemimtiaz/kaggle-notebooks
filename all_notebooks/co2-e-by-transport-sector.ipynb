# %% [markdown]
# ![](https://media2.giphy.com/media/ZnaODGlDcAISY/200.webp?cid=790b7611bcaa870871a583a5bfed96538abe847d7a7a9656&rid=200.webp)

# %% [markdown]
# Carbon dioxide, chemical formula CO2, is a colorless gas . Carbon dioxide consists of a carbon atom covalently double bonded to two oxygen atoms. It occurs naturally in Earth's atmosphere as a trace gas. The current concentration is about 0.04% (410 ppm) by volume, having risen from pre-industrial levels of 280 ppm. Carbon dioxide is the most significant long-lived greenhouse gas in Earth's atmosphere. Since the Industrial Revolution anthropogenic emissions – primarily from use of fossil fuels and deforestation – have rapidly increased its concentration in the atmosphere, leading to global warming. Carbon dioxide also causes ocean acidification because it dissolves in water to form carbonic acid. https://en.wikipedia.org/wiki/Carbon_dioxide

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ_TXuwb5plSTxglEZduU80WnkM6BoJGw_kewRGaKaBOJ_TbAtV',width=400,height=400)

# %% [markdown]
# Image shutterstock.com

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ8F1HtjVOZAHakZIXUYZo-j3rB0HfVS83PRecxMC96yNqAJN2P',width=400,height=400)

# %% [markdown]
# Image thegwpf.com - The world will keep burning fossils fuels.

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
df = pd.read_csv('../input/cusersmarildownloadsdioxidecsv/dioxide.csv', delimiter=';', encoding = "ISO-8859-1", nrows = nRowsRead)
df.dataframeName = 'dioxide.csv'
nRow, nCol = df.shape
print(f'There are {nRow} rows and {nCol} columns')

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# Image ourworldindata.org - CO₂ and Greenhouse Gas Emissions

# %%
df.head()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# Image en.wikipedia.org - List of countries by carbon dioxide emissions

# %%
df.dtypes

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# Image youtube.com - Top 10 Countries by CO2 emissions per capita (1800-2014)

# %%
sns.distplot(df["2016"].apply(lambda x: x**4))
plt.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTDPSYbf0uSmg4sLyUYlxndQgotcRKCPscz938c3U77BFeFshwF9A&s',width=400,height=400)

# %% [markdown]
# Image data.jma.go.jp - Japan Meteorological Agency.

# %%
fig, ax =plt.subplots(figsize=(8,6))
sns.scatterplot(x='Category', y='2016', data=df)
plt.xticks(rotation=90)
plt.yticks(rotation=45)
plt.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSbC9We00VUH-JNlo3UdrvUEi0wO8mxodM3vjpI3bPZgMptLntq0A&s',width=400,height=400)

# %% [markdown]
# Image dw.com  - English village strives for carbon neutrality.

# %%
plt.figure(figsize=(10,10))
plt.title('GAS EMISSIONS')
ax=sns.heatmap(df.corr(),
               linewidth=2.6,
               annot=True,
               center=1)

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTBmhsVSd9IPmnf0s-XEYy55dWrxNnijB0ln3D9XPZ4axL7w7al',width=400,height=400)

# %% [markdown]
# Image researchgate.net  - CO2 emissions (Mt) divided by sector (base-case) -Italy - Figure - uploaded by Michel Noussan

# %%
import plotly.offline as pyo
import plotly.graph_objs as go
lowerdf1 = df.groupby('Category').size()/df['2016'].count()*100
labels = lowerdf1.index
values = lowerdf1.values

# Use `hole` to create a donut-like pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=.6)])
fig.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRs0XnSEurbkr6eoNm4783riVGSnZ1Uxn2Ve7VJ3onYPUEfQCLF',width=400,height=400)

# %% [markdown]
# Image thepolicytime.com - Increasing CO2 Emissions is the Death of Breathes

# %%
#word cloud
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(each) for each in df.Category)
# Create and generate a word cloud image:
wordcloud = WordCloud(max_words=200, background_color="black").generate(text)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='Bilinear')
plt.axis("off")
plt.figure(1,figsize=(8, 8))
plt.show()

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQjKFialBwLoM-cWVYJebt78cRou8aSs__hXDRLwV8q1azz3JD4',width=400,height=400)

# %% [markdown]
# Image towardsdatascience.com - Predicting CO2 Emissions Growth with Decision Tree Modeling.

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTfVWSn0p-jBgqmArMBpf58MFr-KuTM2KglRzGgjw_MoaIn3VpR',width=400,height=400)

# %% [markdown]
# Image visualcapitalist.com - CHART OF THE WEEKAll the World’s Carbon Emissions in One Chart - by Iman Ghosh.

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# Image quickmeme.com

# %%
#codes from Rodrigo Lima  @rodrigolima82
from IPython.display import Image
Image(url = 'data:image/jpeg;base64,...',width=400,height=400)

# %% [markdown]
# Image makeameme.org

# %% [markdown]
# Kaggle Notebook Runner: Marília Prata   @mpwolke
