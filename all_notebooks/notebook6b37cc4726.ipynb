# %%
import pandas as pd
import numba as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
data=pd.read_csv("../input/tesla-stock-data-updated-till-28jun2021/TSLA.csv")

# %%
data.head()

# %%
data.shape

# %%
data.info()

# %%
data.describe()

# %%
data['Date']=pd.to_datetime(data['Date'])

# %%
data['Day']=data['Date'].dt.day_name()

# %%
data.head()

# %%
data['Day'].value_counts()

# %% [markdown]
# # No working in Saturday and Sunday

# %%
sns.countplot(data['Day'])

# %%
plt.figure(figsize=(12,7))
plt.style.use("fivethirtyeight")
sns.lineplot(x='Date',y='Open',data=data)

# %%
plt.figure(figsize=(12,7))
plt.style.use("fivethirtyeight")
sns.lineplot(x='Date',y='High',data=data)

# %%
plt.figure(figsize=(12,7))
plt.style.use("fivethirtyeight")
sns.lineplot(x='Date',y='Low',data=data)

# %%
plt.figure(figsize=(12,7))
plt.style.use("fivethirtyeight")
sns.lineplot(x='Date',y='Close',data=data)

# %%
plt.figure(figsize=(12,7))
plt.style.use("fivethirtyeight")
sns.lineplot(x='Date',y='Adj Close',data=data)

# %%
plt.figure(figsize=(12,7))
plt.style.use("fivethirtyeight")
sns.lineplot(x='Date',y='Volume',data=data)

# %%
sns.pairplot(data=data, hue="Day")

# %%
from pandas_profiling import ProfileReport
x=ProfileReport(data)

# %%
x
