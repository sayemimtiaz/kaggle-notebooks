# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# **Reading the dataFrame using pandas **

# %% [markdown]
# # **Read Salaries.csv as a dataframe called df**

# %%
df = pd.read_csv("../input/salaries-data-set/Salaries.csv")
df.head()

# %%
df.describe()

# %% [markdown]
# # Use the .info() method to find out how many entries there are.

# %%
df.info()

# %% [markdown]
# #  is the highest amount of OvertimePay in the dataset ?

# %%
df['OvertimePay'].max()

# %% [markdown]
# # What is the average BasePay ?

# %%
df['BasePay'].mean()

# %% [markdown]
# # What is the job title of JOSEPH DRISCOLL ? Note use allcaps (there is also a lowercase Joseph Driscoll);

# %%
# note here we get row that's match ups
df[df['EmployeeName']=='JOSEPH DRISCOLL']

# %%
# add extra [] set of  square bracket and grab what ever column you need ! 
# For example the code look like this The code look like this!
df[df['EmployeeName']=='JOSEPH DRISCOLL']['JobTitle']

# %% [markdown]
# # How much does JOSEPH DRISCOLL make (including benefits)?

# %%
df[df['EmployeeName']=='JOSEPH DRISCOLL']['TotalPayBenefits']

# %% [markdown]
# # What is the name of highest paid person (including benefits)?

# %%
df[df['TotalPayBenefits']== df['TotalPayBenefits'].max()] #['EmployeeName']
# or
# df.loc[sal['TotalPayBenefits'].idxmax()
df[df['TotalPayBenefits'] == df["TotalPayBenefits"].max()]['TotalPayBenefits']

# %% [markdown]
# # What was the average (mean) BasePay of all employees per year? (2011-2014) ?

# %%
df.groupby('Year').mean()['BasePay']

# %% [markdown]
# # How many unique job titles are there?
# ## Two ways we can done this !

# %%
df['JobTitle'].nunique()
# or
len(df['JobTitle'].unique())

# %% [markdown]
# # What are the top 5 most common jobs?

# %%
df['JobTitle'].value_counts()[:5]
# or 
df['JobTitle'].value_counts().head(5)

# %% [markdown]
# # How many people have the word Chief in their job title?

# %%
def cheif_find(title):
    if 'chief' in title.lower():
        return True
    else:
        return False

# %%
sum(df['JobTitle'].apply(lambda x: cheif_find(x)))

# %% [markdown]
# # Finding the co-relation of the dataset !!!

# %%
df.corr()
