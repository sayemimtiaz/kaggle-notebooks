# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Testing Coffee Consumotion Dataset..
#
#    This notebook to test the data of **Coffee Consumotion** and try to play around with it.</br>
# All the data are FAKE and Random generated.
#
#
# **Last-Update: 7-8-2021**

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# create the dateframe df
df = pd.read_csv("../input/coffee-consumption-datasetv1/coffee_consumption_alihr20.csv")#"../input/building-permit-applications-data/Building_Permits.csv")

# print first 5 rows on the date
df.head()

# %% [markdown]
# # Here we display the df shape, and the list of columns.

# %%
# show all columns in the df
print('\n DataFrame shape: ',df.shape)

print('\n List of Columns: ',df.columns)

# %% [markdown]
# # Here is the data-type of each column

# %%
# Get all column data type
df.dtypes

# %%
df.describe()

# %% [markdown]
# # Create a variable named male holding all data with sex='m'

# %%
# create two variable Male, Female with 

male = df.loc[df["sex"]=='m']

male

# %% [markdown]
# # Create a variable named female holding all data with sex='f'

# %%
female = df.loc[df["sex"]=='f']

female

# %% [markdown]
# # From the male dataset, we can get sort the most coffee ordered on c_name (Coffee Name)

# %%
#male_drink
male_most_drink =male_drink.groupby('c_name').size().sort_values(ascending = False)
male_most_drink

# %% [markdown]
# so, iced coffee is the most ordered among males.

# %% [markdown]
# # Let's get the most Mug Size requierd.

# %%
male_most_mugSize = male.groupby('c_size').size().sort_values(ascending = False)
male_most_mugSize

# %% [markdown]
# We are saving the data in a variables so we can use it later.

# %%
# What male drinks

male_most_drink =male.groupby('c_name').size().sort_values(ascending = False)
male_most_drink

# %%
print('\n Maximum value:',male.groupby('c_name').size().max())

# %%
print(' Minimum Value:',male.groupby('c_name').size().min())

# %%
# What female drinks
print(female.groupby('c_name').size().sort_values(ascending = False))

# %% [markdown]
# From the main DF we will create a sub-set of coffee-name and rank.

# %%
# new dataset of 'c_name', 'rank'

c_name_rank = df.loc[:,['c_name','rank']]

c_name_rank

# %% [markdown]
# Then we can print-out for each Coffee Name, the sum of ranks it get. Here we are printing only 20 rows.

# %%
coffee_ranks = c_name_rank.groupby(['c_name','rank'])['rank'].agg('sum')

coffee_ranks.head(20)

# %%
# Add title 

plt.title("Male - Popularty of the Coffees") 

# Bar chart showing average arrival delay for Spirit Airlines flights by month 
sns.barplot(x=male.index, y=male['c_name']) 
#sns.barplot() 

#sns.barplot(x='rank', y='c_name',data=df,order=df.sort_values('rank')) 

# Add label for vertical axis 
plt.ylabel("Coffee Name")

# %% [markdown]
# This is just a test notebook using my dataset, the data is FAKE generated by multi random Functions, I will work on another notebook later to use more pandas command.
#
# Ali
# @alihr20
