# %% [markdown]
# # HISTORY
#
# **Data on Recent Forest Fires in Turkey**
#
# Content
#
# Data on recent forest fires in Turkey, published with permission from NASA Portal. The data was created based on the hotspots and obtained from the satellite.
#
#
#
# #### GENERAL ATTRIBUTES
#
# * Latitude
# Center of nominal 375 m fire pixel
#
# * Longitude
# Center of nominal 375 m fire pixel
#
# * Bright_ti4
#
# (Brightness temperature I-4)
#
# VIIRS I-4: channel brightness temperature of the fire pixel measured in Kelvin.
#
# * Scan
#
# (Along Scan pixel size)
#
# The algorithm produces approximately 375 m pixels at nadir. Scan and track reflect actual pixel size.
#
# * Track
#
# (Along Track pixel size)
#
# The algorithm produces approximately 375 m pixels at nadir. Scan and track reflect actual pixel size.
#
# * Acq_Date
#
# (Acquisition Date)
#
# Date of VIIRS acquisition.
#
# * Acq_Time
#
# (Acquisition Time)
#
# Time of acquisition/overpass of the satellite (in UTC).
#
# * Satellite
#
# N Suomi National Polar-orbiting Partnership (Suomi NPP)
#
# * Confidence
#
# This value is based on a collection of intermediate algorithm quantities used in the detection process. It is intended to help users gauge the quality of individual hotspot/fire pixels. Confidence values are set to low, nominal and high. Low confidence daytime fire pixels are typically associated with areas of sun glint and lower relative temperature anomaly (15K) temperature anomaly in either day or nighttime data. High confidence fire pixels are associated with day or nighttime saturated pixels.
#
# #### Please note:
#
# Low confidence nighttime pixels occur only over the geographic area extending from 11° E to 110° W and 7° N to 55° S. This area describes the region of influence of the South Atlantic Magnetic Anomaly which can cause spurious brightness temperatures in the mid-infrared channel I4 leading to potential false positive alarms. These have been removed from the NRT data distributed by FIRMS.
#
# * Version
#
# Version identifies the collection (e.g. VIIRS Collection 1) and source of data processing: Near Real-Time (NRT suffix added to collection) or Standard Processing (collection only).
#
# "1.0NRT" - Collection 1 NRT processing.
#
# "1.0" - Collection 1 Standard processing.
#
# * Bright_ti5
#
# (Brightness temperature I-5)
#
# I-5 Channel brightness temperature of the fire pixel measured in Kelvin.
#
# * FRP
#
# (Fire Radiative Power)
#
# FRP depicts the pixel-integrated fire radiative power in MW (megawatts). Given the unique spatial and spectral resolution of the data, the VIIRS 375 m fire detection algorithm was customized and tuned in order to optimize its response over small fires while balancing the occurrence of false alarms. Frequent saturation of the mid-infrared I4 channel (3.55-3.93 µm) driving the detection of active fires requires additional tests and procedures to avoid pixel classification errors. As a result, sub-pixel fire characterization (e.g., fire radiative power [FRP] retrieval) is only viable across small and/or low-intensity fires. Systematic FRP retrievals are based on a hybrid approach combining 375 and 750 m data. In fact, starting in 2015 the algorithm incorporated additional VIIRS channel M13 (3.973-4.128 µm) 750 m data in both aggregated and unaggregated format.
#
# Satellite measurements of fire radiative power (FRP) are increasingly used to estimate the contribution of biomass burning to local and global carbon budgets. Without an associated uncertainty, however, FRP-based biomass burning estimates cannot be confidently compared across space and time, or against estimates derived from alternative methodologies. Differences in the per-pixel FRP measured near-simultaneously in consecutive MODIS scans are approximately normally distributed with a standard deviation (ση) of 26.6%. Simulations demonstrate that this uncertainty decreases to less than ~5% (at ±1 ση) for aggregations larger than ~50 MODIS active fire pixels. Although FRP uncertainties limit the confidence in flux estimates on a per-pixel basis, the sensitivity of biomass burning estimates to FRP uncertainties can be mitigated by conducting inventories at coarser spatiotemporal resolutions.
#
# http://cedadocs.ceda.ac.uk/770/1/SEVIRI_FRP_documentdesc.pdf
#
# * Type (Inferred hot spot type)
#
# 0 = presumed vegetation fire
#
# 1 = active volcano
#
# 2 = other static land source
#
# 3 = offshore detection (includes all detections over water)
#
# * DayNight (Day or Night)
#
# D= Daytime fire
#
# N= Nighttime fire
#
# #### WHAT IS LONGITUDE AND LATITUDE
#
# Latitude and longitude are a system of lines used to describe the location of any place on Earth. Lines of latitude run in an east-west direction across Earth. Lines of longitude run in a north-south direction. Although these are only imaginary lines, they appear on maps and globes as if they actually existed.
#
# #### ACQUISITION TIME EXAMPLE
#
# Based on UTC time. You have to think in decimal.

# %% [markdown]
# # PACKAGES AND LIBRARIES

# %%
# !pip install dataprep by

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from warnings import filterwarnings
from mpl_toolkits.mplot3d import Axes3D
import statsmodels.api as sm
import missingno as msno
import statsmodels.stats.api as sms
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.neighbors import LocalOutlierFactor
from scipy.stats import levene
from scipy.stats import shapiro
from scipy.stats.stats import pearsonr
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from sklearn.preprocessing import scale
from sklearn.model_selection import ShuffleSplit, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import model_selection
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import BaggingRegressor
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LinearRegression
from sklearn.cross_decomposition import PLSRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import LassoCV
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import ElasticNetCV
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
import xgboost as xgb
from xgboost import XGBRegressor, XGBClassifier
from lightgbm import LGBMRegressor, LGBMClassifier
from catboost import CatBoostRegressor, CatBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn import tree
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, roc_auc_score, roc_curve
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans
from sklearn.pipeline import Pipeline
from sklearn.manifold import Isomap,TSNE
from sklearn.feature_selection import mutual_info_classif
from tqdm.notebook import tqdm
from scipy.stats import ttest_ind
import plotly.offline as pyo
import scipy.stats as stats
import pymc3 as pm
from dataprep.eda import *
from dataprep.eda import plot
from dataprep.eda import plot_diff
from dataprep.eda import plot_correlation
from dataprep.eda import plot_missing
import plotly.figure_factory as ff
from collections import Counter
import pandas_profiling as pp
from mpl_toolkits.basemap import Basemap
import datetime as dt
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import folium
from folium import plugins

filterwarnings("ignore", category=DeprecationWarning) 
filterwarnings("ignore", category=FutureWarning) 
filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# # INVESTIGATION BASED ON YEARS

# %% [markdown]
# ### READING

# %%
YEAR_2017 = pd.read_csv("../input/investigative-wildfire-data-for-turkey-nasa/INVESTIGATIVE WILDFIRE DATA FOR TURKEY_NASA/LAST YEARS ALL COUNTRIES/modis_single/2017/modis_2017_Turkey.csv")
YEAR_2018 = pd.read_csv("../input/investigative-wildfire-data-for-turkey-nasa/INVESTIGATIVE WILDFIRE DATA FOR TURKEY_NASA/LAST YEARS ALL COUNTRIES/modis_single/2018/modis_2018_Turkey.csv")
YEAR_2019 = pd.read_csv("../input/investigative-wildfire-data-for-turkey-nasa/INVESTIGATIVE WILDFIRE DATA FOR TURKEY_NASA/LAST YEARS ALL COUNTRIES/modis_single/2019/modis_2019_Turkey.csv")
YEAR_2020 = pd.read_csv("../input/investigative-wildfire-data-for-turkey-nasa/INVESTIGATIVE WILDFIRE DATA FOR TURKEY_NASA/LAST YEARS ALL COUNTRIES/modis_single/2020/modis_2020_Turkey.csv")

# %% [markdown]
# ### DATA

# %%
YEAR_2017

# %%
YEAR_2018

# %%
YEAR_2019

# %%
YEAR_2020

# %% [markdown]
# ### TYPE 0 DATA

# %% [markdown]
# #### **ATTENTION**
#
# * TYPE 0 MEANS FOREST FIRES

# %%
TYPE_0_2017 = YEAR_2017[YEAR_2017["type"] == 0]
TYPE_0_2018 = YEAR_2018[YEAR_2018["type"] == 0]
TYPE_0_2019 = YEAR_2019[YEAR_2019["type"] == 0]
TYPE_0_2020 = YEAR_2020[YEAR_2020["type"] == 0]

# %%
TYPE_0_2017 = TYPE_0_2017.reset_index(drop=True)
TYPE_0_2018 = TYPE_0_2018.reset_index(drop=True)
TYPE_0_2019 = TYPE_0_2019.reset_index(drop=True)
TYPE_0_2020 = TYPE_0_2020.reset_index(drop=True)

# %%
TYPE_0_2017

# %%
TYPE_0_2018

# %%
TYPE_0_2019

# %%
TYPE_0_2020

# %% [markdown]
# ### INFORMATIONS

# %%
print("2017 DATE COUNT:\n")
print(TYPE_0_2017["acq_date"].max())
print("\n")
print("2018 DATE COUNT:\n")
print(TYPE_0_2018["acq_date"].max())
print("\n")
print("2019 DATE COUNT:\n")
print(TYPE_0_2019["acq_date"].max())
print("\n")
print("2020 DATE COUNT:\n")
print(TYPE_0_2020["acq_date"].max())

# %% [markdown]
# #### **ATTENTION**
# * MOST DATA WAS COLLECTED IN DECEMBER.

# %%
print("2017 DATE COUNT:\n")
print(TYPE_0_2017["acq_date"].min())
print("\n")
print("2018 DATE COUNT:\n")
print(TYPE_0_2018["acq_date"].min())
print("\n")
print("2019 DATE COUNT:\n")
print(TYPE_0_2019["acq_date"].min())
print("\n")
print("2020 DATE COUNT:\n")
print(TYPE_0_2020["acq_date"].min())

# %% [markdown]
# #### **ATTENTION**
# * AT LEAST DATA WAS COLLECTED IN JANUARY.

# %% [markdown]
# #### **ATTENTION**
# * DATA COLLECTION TIMES ARE STACKED ACCORDING TO ANNUAL PERIODS. THAT'S WHY THESE RESULTS ARISE.

# %%
print("DESCRIBE:\n")
print(TYPE_0_2017.describe().T)

# %%
print("DESCRIBE:\n")
print(TYPE_0_2018.describe().T)

# %%
print("DESCRIBE:\n")
print(TYPE_0_2019.describe().T)

# %%
print("DESCRIBE:\n")
print(TYPE_0_2020.describe().T)

# %% [markdown]
# #### **ATTENTION**
#
# * MEAN 2017 FRP: 27.52
# * MEAN 2018 FRP: 25.26
# * MEAN 2019 FRP: 22.64
# * MEAN 2020 FRP: 27.96
#
#
#
#
# * MAX 2017 FRP: 1147.60
# * MAX 2018 FRP: 672.70
# * MAX 2019 FRP: 1160.30
# * MAX 2020 FRP: 2787.60

# %% [markdown]
# #### **ATTENTION**
#
# * MEAN 2017 BRIGHTNESS: 321.91
# * MEAN 2018 BRIGHTNESS: 321.85
# * MEAN 2019 BRIGHTNESS: 319.62
# * MEAN 2020 BRIGHTNESS: 320.87
#
#
#
#
# * MAX 2017 BRIGHTNESS: 435
# * MAX 2018 BRIGHTNESS: 448
# * MAX 2019 BRIGHTNESS: 433
# * MAX 2020 BRIGHTNESS: 500

# %% [markdown]
# #### ATTENTION
# * THERE IS A LOT OF DIFFERENCE BETWEEN 2019 MAX FRP VALUE AND 2020.
#
# * EVERY YEAR THIS DIFFERENCE IS INCREASING, THE DIFFERENCE FROM THE LAST 2 YEARS IS MUCH MORE.

# %%
print(TYPE_0_2017[TYPE_0_2017["brightness"] == TYPE_0_2017["brightness"].max()])

# %% [markdown]
# #### **ATTENTION**
#
# * THE HIGHEST 2017 BRIGHTNESS VALUE LATITUDE: 37.1329
# * THE HIGHEST 2017 BRIGHTNESS VALUE LONGITUDE: 36.0004
# * THE HIGHEST 2017 BRIGHTNESS VALUE DATE: 2017-08-22

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='openstreetmap',
                  zoom_start=6.4)

folium.CircleMarker(
    location=[37.1329,36.0004],
    radius=20,
    popup="<b>MAXIMUM BRIGHTNESS (FOR 2017)<b>",
    tooltip="Click me",
    color='#2F4F4F',
    fill=True,
    fill_color='#00000',
).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %%
print(TYPE_0_2018[TYPE_0_2018["brightness"] == TYPE_0_2018["brightness"].max()])

# %% [markdown]
# #### **ATTENTION**
# * THE HIGHEST 2018 BRIGHTNESS VALUE LATITUDE: 36.9329
# * THE HIGHEST 2018 BRIGHTNESS VALUE LONGITUDE: 35.4883
# * THE HIGHEST 2018 BRIGHTNESS VALUE DATE: 2017-08-28

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='openstreetmap',
                  zoom_start=6.4)

folium.CircleMarker(
    location=[36.9329,35.4883],
    radius=20,
    popup="<b>MAXIMUM BRIGHTNESS (FOR 2018)<b>",
    tooltip="Click me",
    color='#2F4F4F',
    fill=True,
    fill_color='#00000',
).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %%
print(TYPE_0_2019[TYPE_0_2019["brightness"] == TYPE_0_2019["brightness"].max()])

# %% [markdown]
# #### **ATTENTION**
# * THE HIGHEST 2019 BRIGHTNESS VALUE LATITUDE: 38.297
# * THE HIGHEST 2019 BRIGHTNESS VALUE LONGITUDE: 27.0276
# * THE HIGHEST 2019 BRIGHTNESS VALUE DATE: 2017-08-18

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='openstreetmap',
                  zoom_start=6.4)

folium.CircleMarker(
    location=[38.297,27.0276],
    radius=20,
    popup="<b>MAXIMUM BRIGHTNESS (FOR 2019)<b>",
    tooltip="Click me",
    color='#2F4F4F',
    fill=True,
    fill_color='#00000',
).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %%
print(TYPE_0_2020[TYPE_0_2020["brightness"] == TYPE_0_2020["brightness"].max()])

# %% [markdown]
# #### **ATTENTION**
# * THE HIGHEST 2020 BRIGHTNESS VALUE LATITUDE: 38.4068
# * THE HIGHEST 2020 BRIGHTNESS VALUE LONGITUDE: 26.5102
# * THE HIGHEST 2020 BRIGHTNESS VALUE DATE: 2017-08-13

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='openstreetmap',
                  zoom_start=6.4)

folium.CircleMarker(
    location=[38.4068,26.5102],
    radius=20,
    popup="<b>MAXIMUM BRIGHTNESS (FOR 2020)<b>",
    tooltip="Click me",
    color='#2F4F4F',
    fill=True,
    fill_color='#00000',
).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %%
print(TYPE_0_2017[TYPE_0_2017["frp"] == TYPE_0_2017["frp"].max()])

# %%
print(TYPE_0_2018[TYPE_0_2018["frp"] == TYPE_0_2018["frp"].max()])

# %%
print(TYPE_0_2019[TYPE_0_2019["frp"] == TYPE_0_2019["frp"].max()])

# %%
print(TYPE_0_2019[TYPE_0_2020["frp"] == TYPE_0_2020["frp"].max()])

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='openstreetmap',
                  zoom_start=6.0)

folium.CircleMarker(
    location=[36.458,32.3077],
    radius=20,
    popup="<b>2017 MAX FRP<b>",
    tooltip="Click me",
    color='#2F4F4F',
    fill=True,
    fill_color='#FF0000',
).add_to(MAP_FUNCTION)

folium.CircleMarker(
    location=[36.9329,35.4883],
    radius=20,
    popup="<b>2018 MAX FRP<b>",
    tooltip="Click me",
    color='#2F4F4F',
    fill=True,
    fill_color='#AFFF33',
).add_to(MAP_FUNCTION)

folium.CircleMarker(
    location=[36.8772,40.1193],
    radius=20,
    popup="<b>2019 MAX FRP<b>",
    tooltip="Click me",
    color='#2F4F4F',
    fill=True,
    fill_color='#FF3333',
).add_to(MAP_FUNCTION)

folium.CircleMarker(
    location=[37.0759,35.8128],
    radius=20,
    popup="<b>2020 MAX FRP<b>",
    tooltip="Click me",
    color='#2F4F4F',
    fill=True,
    fill_color='#009BFF',
).add_to(MAP_FUNCTION)



MAP_FUNCTION

# %% [markdown]
# #### **ATTENTION**
# * VIEW INTERACTIVE MAP
# * CLİCK THE ROUNDS

# %%
LAT_LONG_2017 = TYPE_0_2017[["latitude","longitude"]]

LAT_LONG_2017.latitude = LAT_LONG_2017.latitude.astype(float)
LAT_LONG_2017.longitude = LAT_LONG_2017.longitude.astype(float)

HEAT_2017 = list(zip(LAT_LONG_2017.latitude,LAT_LONG_2017.longitude))



LAT_LONG_2018 = TYPE_0_2018[["latitude","longitude"]]

LAT_LONG_2018.latitude = LAT_LONG_2018.latitude.astype(float)
LAT_LONG_2018.longitude = LAT_LONG_2018.longitude.astype(float)

HEAT_2018 = list(zip(LAT_LONG_2018.latitude,LAT_LONG_2018.longitude))



LAT_LONG_2019 = TYPE_0_2019[["latitude","longitude"]]

LAT_LONG_2019.latitude = LAT_LONG_2019.latitude.astype(float)
LAT_LONG_2019.longitude = LAT_LONG_2019.longitude.astype(float)

HEAT_2019 = list(zip(LAT_LONG_2019.latitude,LAT_LONG_2019.longitude))



LAT_LONG_2020 = TYPE_0_2020[["latitude","longitude"]]

LAT_LONG_2020.latitude = LAT_LONG_2020.latitude.astype(float)
LAT_LONG_2020.longitude = LAT_LONG_2020.longitude.astype(float)

HEAT_2020 = list(zip(LAT_LONG_2020.latitude,LAT_LONG_2020.longitude))

# %% [markdown]
# #### 2017

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,30.2433],
                  tiles='Stamen Terrain',
                  zoom_start=5.0)

plugins.MarkerCluster(LAT_LONG_2017).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,30.2433],
                  tiles='Stamen Terrain',
                  zoom_start=5.8)

plugins.HeatMap(HEAT_2017).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### 2018

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,30.2433],
                  tiles='Stamen Terrain',
                  zoom_start=5.0)

plugins.MarkerCluster(LAT_LONG_2018).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,30.2433],
                  tiles='Stamen Terrain',
                  zoom_start=5.8)

plugins.HeatMap(HEAT_2018).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### 2019

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,30.2433],
                  tiles='Stamen Terrain',
                  zoom_start=5.0)

plugins.MarkerCluster(LAT_LONG_2019).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,30.2433],
                  tiles='Stamen Terrain',
                  zoom_start=5.8)

plugins.HeatMap(HEAT_2019).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### 2020

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,30.2433],
                  tiles='Stamen Terrain',
                  zoom_start=5.0)

plugins.MarkerCluster(LAT_LONG_2020).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### **ATTENTION**
# * REVIEW ALL ISSUES.
#
# * USE THE INTERACTIVE MAP.
#
# * LOOK AT THE DIFFERENCE BETWEEN THE YEARS.

# %% [markdown]
# ### BRIGHTNESS FOR YEARS

# %%
plt.style.use("dark_background")

# %%
figure = plt.figure(figsize=(25,14))

plt.plot(TYPE_0_2017["bright_t31"])
plt.title("BRIGHTNESS 2017")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))

plt.plot(TYPE_0_2018["bright_t31"])
plt.title("BRIGHTNESS 2018")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))

plt.plot(TYPE_0_2019["bright_t31"])
plt.title("BRIGHTNESS 2019")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))

plt.plot(TYPE_0_2020["bright_t31"])
plt.title("BRIGHTNESS 2020")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### FRP FOR YEARS

# %%
figure = plt.figure(figsize=(25,14))

plt.plot(TYPE_0_2017["frp"])
plt.title("FRP 2017")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))

plt.plot(TYPE_0_2018["frp"])
plt.title("FRP 2018")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))

plt.plot(TYPE_0_2019["frp"])
plt.title("FRP 2019")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))

plt.plot(TYPE_0_2020["frp"])
plt.title("FRP 2020")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 28 AUGUST FOR ALL YEARS

# %%
AU_2020 = TYPE_0_2020[TYPE_0_2020["acq_date"] == "2020-08-28"]
AU_2019 = TYPE_0_2019[TYPE_0_2019["acq_date"] == "2019-08-28"]
AU_2018 = TYPE_0_2018[TYPE_0_2018["acq_date"] == "2018-08-28"]
AU_2017 = TYPE_0_2017[TYPE_0_2017["acq_date"] == "2017-08-28"]

# %%
AU_2020 = AU_2020.reset_index(drop=True)
AU_2019 = AU_2019.reset_index(drop=True)
AU_2018 = AU_2018.reset_index(drop=True)
AU_2017 = AU_2017.reset_index(drop=True)

# %%
AU_2020.sort_values(by=["acq_time"],inplace=True)
AU_2019.sort_values(by=["acq_time"],inplace=True)
AU_2018.sort_values(by=["acq_time"],inplace=True)
AU_2017.sort_values(by=["acq_time"],inplace=True)

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(x=AU_2020["acq_time"],y=AU_2020["frp"])
plt.title("FRP AUGUST 2020")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(x=AU_2019["acq_time"],y=AU_2019["frp"])
plt.title("FRP AUGUST 2019")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(x=AU_2018["acq_time"],y=AU_2018["frp"])
plt.title("FRP AUGUST 2018")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(x=AU_2017["acq_time"],y=AU_2017["frp"])
plt.title("FRP AUGUST 2017")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(x=AU_2020["acq_time"],y=AU_2020["brightness"])
plt.title("BRIGHTNESS AUGUST 2020")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(x=AU_2019["acq_time"],y=AU_2019["brightness"])
plt.title("BRIGHTNESS AUGUST 2019")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(x=AU_2018["acq_time"],y=AU_2018["brightness"])
plt.title("BRIGHTNESS AUGUST 2018")
plt.tight_layout()
plt.show()

# %%
figure = plt.figure(figsize=(25,14))
sns.lineplot(x=AU_2017["acq_time"],y=AU_2017["brightness"])
plt.title("BRIGHTNESS AUGUST 2017")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **ATTENTION**
#
# * WHEN THERE IS A DECREASE EVERY YEAR DEPENDING ON TIME ON AUGUST 28, A COMPLETE RISE IS SEEN IN 2020.
#
# * THIS IS A BIG ANOMALY.

# %% [markdown]
# #### **ATTENTION**
#
# * BEFORE THIS STUDY PLEASE CHECK
#
# * https://www.kaggle.com/brsdincer/anomalies-investigation-for-turkey-wildfire
#
# * https://www.kaggle.com/brsdincer/turkey-recent-wildfire-analysis-investigation
