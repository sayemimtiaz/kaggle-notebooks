# %%
import pandas as pd
import sqlite3

# Read in SQLite databases
con = sqlite3.connect("../input/database.sqlite")
results = pd.read_sql_query("SELECT * from resultsdata13", con)
samples = pd.read_sql_query("SELECT * from sampledata13", con)

con.close()

# %%
samples.head()

# %% [markdown]
# # Let's take a look at the squashes that were picked for testing.

# %%
squash = samples.loc[samples['commod'] == 'SS']
squash.head()

# %% [markdown]
# #What types of squash were used for this sampling?

# %%
squash['variety'].value_counts()

# %% [markdown]
# # Looks like this dataset could use some cleaning. For example, _Yellow Straightneck_ and _Yellow Straight Neck_ squashes should be listed as the same type. Perhaps this is why most of this database uses codes!
#
# # Where do most of the squashes in this study come from?

# %%
squash['state'].value_counts()

# %% [markdown]
# # Other ideas to consider:
# * Based on sampling data, does California specialize in a type of squash?
# * Are certain types of squash more available in certain states?
# * What types of pesticides are used in squash, and does it vary based in variety or state grown?
