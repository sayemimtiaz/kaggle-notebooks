# %%
import numpy as np
import pandas as pd
import os

# %%
df = pd.read_csv("../input/train.csv")

# %%
df.count()

# %% [markdown]
# The cabin column is missing a lot of values, thus we will remove it from our dataframe. Age also seems to be missing few values, looking at the amount I believe we can fill the missing data here and still have it be profitable for our model.

# %%
df = df.drop('Cabin', axis = 1)

# %%
df.describe()

# %% [markdown]
# Lets just try out the mean value and see what happens when we apply a model.

# %%
from sklearn.preprocessing import Imputer

#Split the data and get values for sklearn
x = df.iloc[:,2:].values
y = df.iloc[:,1].values

imp = Imputer(missing_values = 'NaN', strategy = 'mean', axis = 1)

x[:,3] = imp.fit_transform(np.asmatrix(x[:,3]))

# %%
x
