# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# %%
df_unv = pd.read_csv("/kaggle/input/world-university-rankings/cwurData.csv")

# %%
df_unv.head()

# %%
df_unv.info()

# %%
df_unv.shape

# %%
df_unv.isna().sum()

# %%
df_unv.nunique()

# %%
df_unv['year'].value_counts()

# %%
# For better visualization we can segment our data as per each year
# Taking the 2012 data first

df_2012= df_unv[df_unv.year.eq(2012)]

# %%
df_2012.shape

# %%
# Which country has the most no of of ranking universities
sns.countplot(df_2012.country)
plt.xticks(rotation=45)

# %%
# take top 100 rows for better visualization
df = df_2012.iloc[:100,:]

# %%
# Line chart between world rank and national rank of universities

# import graph objects as "go"
import plotly.graph_objs as go

# Creating trace1
trace1 = go.Scatter(
                    x = df.world_rank,
                    y = df.world_rank,
                    mode = "lines",
                    name = "citations",
                    marker = dict(color = 'rgba(16, 112, 2, 0.8)'),
                    text= df.university_name)
# Creating trace2
trace2 = go.Scatter(
                    x = df.world_rank,
                    y = df.teaching,
                    mode = "lines+markers",
                    name = "teaching",

# %%
# Visualizing the top 10 universities of the world in the year 2012

# %%
# For better visualization we can d
# make the data
df = df_unv.iloc[:100,:]
