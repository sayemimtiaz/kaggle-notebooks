# %% [markdown]
# We are going to put all the functions we have just learned to the test! With a much bigger dataset, your job is to find the mean, median, quantile, variance, standard deviation, and also use the describe function on the data provided.

# %% [markdown]
# The data you have given is NBA team data about certain players. To help you out, we will set up the beginning of the problem for you.
# Your findings must be clear enough to read, so please add labels for all the infomation you find. For example, the mean cannot just be a number, have a label "Mean:" for the mean, and the same for the rest of the functions.

# %%
import pandas as pd 

# open csv file and read it 
df = pd.read_csv("../input/nba-data/nba.csv")

# dropping null values 
drop_values = df.dropna()

# Your turn! 
# Use mean, median, minimum value, maximum value, quantile, variance, standard deviation, and describe on the Salary column of the NBA Data
# For the quantile function please find the 10% , 25%, 50%, and 75% quantile

# %% [markdown]
# Hint: Try to find a way to isolate the Salary Column!
