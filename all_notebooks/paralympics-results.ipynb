# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from matplotlib import dates

import matplotlib
import statsmodels.tsa.api as tsa

# %matplotlib inline

matplotlib.style.use("Solarize_Light2")

from pylab import rcParams
import statsmodels.api as sm

import warnings
warnings.simplefilter(action='ignore', category=Warning)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# <center style="font-family:verdana;"><h1 style="font-size:200%; padding: 10px; background: #8B0000;"><b style="color:white;">Paralympic Games</b></h1></center
#
# "The Paralympic Games or Paralympics are a periodic series of international multi-sport events involving athletes with a range of disabilities, including impaired muscle power (e.g. paraplegia and quadriplegia, muscular dystrophy, post-polio syndrome, spina bifida), impaired passive range of movement, limb deficiency (e.g. amputation or dysmelia), leg length difference, short stature, hypertonia, ataxia, athetosis, vision impairment and intellectual impairment."
#
# "There are Winter and Summer Paralympic Games, which since the 1988 Summer Olympics in Seoul, South Korea, are held almost immediately following the respective Olympic Games. All Paralympic Games are governed by the International Paralympic Committee (IPC)."
#
# https://en.wikipedia.org/wiki/Paralympic_Games

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQJKfoq_u_2MtsntEy4QHRkIX54Th2_-j0V6w&usqp=CAU)wessexscene.co.uk

# %% [markdown]
# #"It is not the moment or trip that defines you, it is how you react to it that defines you.”

# %%
df = pd.read_csv("/kaggle/input/cusersmarildownloadsparathleticscsv/parathletics.csv", delimiter=';', encoding='ISO-8859-2')
df.tail()

# %%
df.isnull().sum()

# %%
import altair as alt
alt.data_transformers.disable_max_rows()
from datetime import date
from dateutil import parser

# %%
#Code by Aristotle  https://www.kaggle.com/aristotle609/kickstarter-project-eda/notebook

def HChart(df,x_axis,y_axis,color_axis):
    chart = alt.Chart(df).mark_bar().encode(
        x = x_axis,
        y = y_axis,
        color = color_axis
    )
    display(chart)

# %%
#Code by Aristotle  https://www.kaggle.com/aristotle609/kickstarter-project-eda/notebook

#Plotting the state of the project
HChart(df.sample(100) , "region" , "count()" , 'region')

# %%
#Code by Aristotle  https://www.kaggle.com/aristotle609/kickstarter-project-eda/notebook

#Plotting the state of the project
HChart(df.sample(100) , "gender" , "count()" , 'gender')

# %%
#Code by Aristotle  https://www.kaggle.com/aristotle609/kickstarter-project-eda/notebook

#Plotting the state of the project
HChart(df.sample(100) , "city" , "count()" , 'city')

# %%
#Code by Aristotle  https://www.kaggle.com/aristotle609/kickstarter-project-eda/notebook

#Plotting the state of the project
HChart(df.sample(100) , "event" , "count()" , 'event')

# %%
#Code by Aristotle  https://www.kaggle.com/aristotle609/kickstarter-project-eda/notebook

#Plotting the state of the project

HChart(df.sample(100) , "npc" , "count()" , 'npc')

# %%
#Code by Aristotle  https://www.kaggle.com/aristotle609/kickstarter-project-eda/notebook

#Plotting the state of the project

HChart(df.sample(100) , "country" , "count()" , 'country')

# %% [markdown]
# #Athletes with severe co-ordination impairment (hypertonia, ataxia, athetosis) competing in RaceRunning events in Sport Classes RR1, RR2 and RR3
#
# #RR2: Moderate involvement of lower limbs and trunk. Asymmetry but more effective propulsion than RR1.

# %%
hundredRR2 = df[(df['event_code']=='ATM00102010000')].reset_index(drop=True)
hundredRR2.head(10)

# %% [markdown]
# #RR2: Moderate involvement of lower limbs and trunk. Asymmetry but more effective propulsion than RR1.
#
# RaceRunning RR2
#
# ![](https://live-production.wcms.abc-cdn.net.au/a80a24b5455ced244dbf89571af22dc5?impolicy=wcms_crop_resize&cropH=843&cropW=1500&xPos=0&yPos=0&width=862&height=485)abc.net.au

# %%
hundredRR2.sort_values(by='rank', ascending=False)[:10]

# %%
fig = px.bar(hundredRR2, 
             x='rank', y='family_name',color_discrete_sequence=['blue'],
             title='Men s 100m Race Running 2',  text='result')
fig.show()

# %% [markdown]
# #That above is Not good since the 7th place has the bigger bar. It was suppose to be the other way around.

# %%
fig = px.bar(hundredRR2, 
             x='date', y='rank',color_discrete_sequence=['#DC143C'],
             title='Men s 100m Race Running 2',  text='time-_ms')
fig.show()

# %%
ATXRX164230000 = df[(df['event_code']=='ATXRX164230000')].reset_index(drop=True)
ATXRX164230000.head()

# %% [markdown]
# #Men’s 4x100m Relay showcases sportsmanship in London
#
# The US 4x100m T42-46 relay team of Blake Leeper, Jarryd Wallace, Richard Browne and Jerome Singleton poses after their final at the London 2012 Paralympic Games. - ⒸGetty Images
#
# ![](https://www.paralympic.org/sites/default/files/styles/large_original/public/images/121017170329746_151293620.jpg?itok=gXl3p6N1)paralympic.org

# %% [markdown]
# <h1><span class="label label-default" style="background-color:black;border-radius:100px 100px; font-weight: bold; font-family:Garamond; font-size:20px; color:#03e8fc; padding:10px">Disqualifications: a sort of Shake-ups</span></h1><br>
#
# "The disqualifications of Brazil, France and USA that may have led to some of the night’s most memorable moments.
# (London 2012 )
#
# "In particular, the valiant reactions of those teams who were disqualified personified the Paralympic spirit at its finest hour."
#
# "Brazil finished the race in second place but were later disqualified for not touching the baton within the take-over zone. USA finished in third place but were also disqualified for a lane infringement."
#
# "Brazil and USA’s relay squads both paraded around the Olympic Stadium after the race, though, as they did not find out about their disqualifications until nearly 30 minutes afterwards."
#
# "“It was an amazing opportunity, and I think a lot of the disqualifications were in direct relation the hype that was brought upon that one race,”
#
# "The result for all of them, has just encouraged them to work harder for next time around."
#
# “Besides the obvious initial disappointment, they know their own potential.
#
# https://www.paralympic.org/feature/no-43-men-s-4x100m-relay-showcases-sportsmanship-london

# %%
fig = px.bar(ATXRX164230000, 
             x='rank', y='npc',color_discrete_sequence=['#2B3A67'],
             title='4x100m Universal Relay',  text='result')
fig.show()

# %%
fig = px.line(ATXRX164230000, x="npc", y="result", color_discrete_sequence=['darksalmon'], 
              title="4x100m Universal Relay")
fig.show()

# %% [markdown]
# #That's not a good chart too since the slowest results are on top.

# %%
fig = px.scatter(df, x="npc", y="result",color_discrete_sequence=['#4257f5'], title="Paralympics Results" )
fig.show()

# %% [markdown]
# <h1><span class="label label-default" style="background-color:black;border-radius:100px 100px; font-weight: bold; font-family:Garamond; font-size:20px; color:#03e8fc; padding:10px">Sport doesn't care who you are. So do Codes</span></h1><br>
#
# “Sport doesn’t care who you are. And so do Codes.
#
# That's all for now.
