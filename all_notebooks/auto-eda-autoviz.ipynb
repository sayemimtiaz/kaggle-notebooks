# %%
# !pip install autoviz
# !pip install xlrd

# %%
import pandas as pd
from autoviz.AutoViz_Class import AutoViz_Class

# %%
#autoviz = AutoViz_Class().AutoViz('../input/telcom-customer-churn/customer_churn_data.csv')
#autoviz = AutoViz_Class().AutoViz('../input/avocado-prices/avacado_data.csv')
#autoviz = AutoViz_Class().AutoViz('../input/bigmart-sales/bigmart_sales.csv')
#autoviz = AutoViz_Class().AutoViz('../input/employee-atrition/employee_attrition_data.csv')
#autoviz = AutoViz_Class().AutoViz('../input/graduate-admission-data/Admission_Predict.csv')
#autoviz = AutoViz_Class().AutoViz('../input/heart-disease-data/heart.csv')
#autoviz = AutoViz_Class().AutoViz('../input/height-weight-gender/heights_weights.csv')
#autoviz = AutoViz_Class().AutoViz('../input/life-expectancy/life_expectancy.csv')
#autoviz = AutoViz_Class().AutoViz('../input/strokes-data/strokes_data.csv')
#autoviz = AutoViz_Class().AutoViz('../input/students-performance/StudentsPerformance.csv')
#autoviz = AutoViz_Class().AutoViz('../input/telcom-customer-churn/customer_churn_data.csv')
autoviz = AutoViz_Class().AutoViz('../input/students-performance/StudentsPerformance.csv')
