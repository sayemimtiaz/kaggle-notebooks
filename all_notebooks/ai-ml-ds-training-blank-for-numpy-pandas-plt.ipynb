# %% [markdown]
# ## Dataset [Ammonium prediction in river water](https://www.kaggle.com/vbmokin/ammonium-prediction-in-river-water)

# %% [markdown]
# Dataset to has data about the water quality at the upper part of the river Pivdenny Bug (first 200 km from 809 km) for 1997-2019.
#
# Target is the water quality in the river crossection with the water intake of the Vinnytsia city.

# %% [markdown]
# ## This is a blank for the workshop tasks for library: Numpy, Pandas and Matplotlib

# %% [markdown]
# ## Acknowledgements
# * [Data Science for tabular data: Advanced Techniques](https://www.kaggle.com/vbmokin/data-science-for-tabular-data-advanced-techniques)
# * [EDA for tabular data: Advanced Techniques](https://www.kaggle.com/vbmokin/eda-for-tabular-data-advanced-techniques)
# * [Datasets for river water quality prediction](https://www.kaggle.com/vbmokin/datasets-for-river-water-quality-prediction)
# * [Heart Disease - Automatic AdvEDA & FE & 20 models](https://www.kaggle.com/vbmokin/heart-disease-automatic-adveda-fe-20-models)
# * [BOD prediction in river - 15 regression models](https://www.kaggle.com/vbmokin/bod-prediction-in-river-15-regression-models)
# * [The system "MONITORING AND ENVIRONMENTAL ASSESSMENT OF WATER RESOURCES OF UKRAINE", State Agency of Water Resources of Ukraine](http://monitoring.davr.gov.ua/EcoWaterMon/GDKMap/Index)

# %% [markdown]
# ### The tasks are to adapt to the data of these datasets at least 25% of the tips and tricks from such notebooks:
# * [sklearn: 50 best tips and tricks](https://www.kaggle.com/python10pm/sklearn-50-best-tips-and-tricks)
# * [Learn Numpy the hard way: 70 exercises+solutions](https://www.kaggle.com/python10pm/learn-numpy-the-hard-way-70-exercises-solutions)
# * [Pandas 100 tricks](https://www.kaggle.com/python10pm/pandas-100-tricks)
# * [Pandas 75 exercises with solutions](https://www.kaggle.com/python10pm/pandas-75-exercises-with-solutions)
# * [Plotting with Python: learn 80 plots STEP by STEP](https://www.kaggle.com/python10pm/plotting-with-python-learn-80-plots-step-by-step)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
# Download training data
train = pd.read_csv('/kaggle/input/ammonium-prediction-in-river-water/train.csv')
train = train.drop(['Id','3','4','5','6','7'], axis = 1)
train = train.dropna().reset_index(drop=True)
train.info()

# %%
train.head()
