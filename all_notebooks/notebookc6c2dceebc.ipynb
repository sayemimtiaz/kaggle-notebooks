# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# 1) Load the data.
# Sort the data by total SAT scores in descending order to show the highest scoring states first.

# %%
df = pd.read_csv('/kaggle/input/sat-score-data-by-state/Guber1999data.csv')
df.sort_values('SATT', ascending = False)

# %% [markdown]
# 2) State a logical conclusion, based on the data you see not on your own opinions of the states, that may explain why certain states may have higher average scores than other states which may have nothing to do with the quality of the students' ability in general.

# %% [markdown]
# The prcntTake varies directly with the total score. I assume that it means what percent of students take the SAT, so maybe certain states have higher averages because they have less people participating.

# %% [markdown]
# 3) Use a scatter plot to plot the salary as the independent variable and total SAT score as the dependent variable.

# %%
df.plot.scatter(x = 'Salary', y = 'SATT', s = 0.1, title = 'Scatter 1')

# %% [markdown]
# 4) Make a conjecture about what this graph (#3) means about salary and SAT scores. Explain why you came up with this conjecture based off of the graph.

# %% [markdown]
# Given that the data seems to have no line of best fit, it is easy to assume that salary and total SAT have no correlation.

# %% [markdown]
# 5) Make a box plot using both the SAT Verbal scores and the SAT Math scores.

# %%
df.boxplot(column=['SATV','SATM'])

# %% [markdown]
# 6)
# a. Describe what information you can easily see by using a box plot (do not talk about your graph directly).
# b. Using only your box plot graph, what could you say about a state who has an average Math SAT score of 460?

# %% [markdown]
# a) The graph shows that schools typically have a higher math score than a verbal score.

# %% [markdown]
# b) A math score of 460 is below the box on the graph so it is likely that the verbal score is also below the box. Therfore, the verbal score is likely between the range of 400 and 425.

# %% [markdown]
# 7) Display a histogram with 25 bins of the percent of students who take the exam in each state.

# %%
df.hist(column= 'PrcntTake', bins = 25)

# %% [markdown]
# 8) Describe what a 'bin' is.

# %% [markdown]
# A bin is a group of data from the graph fit into one section or "bin" and then graphed by how many data points are within that "bin".

# %% [markdown]
# 9) Sort the graph by the SAT Verbal scores, then create a regular line graph that graphs the Verbal scores vs the Math scores.

# %%
df.sort_values('SATV').plot(x = 'SATV', y = 'SATM')

# %% [markdown]
# 10) Why is it a good idea to first sort the values by your indepedent variable before doing a line graph?

# %% [markdown]
# Because a line graph works but increasing the independent variable and then graphing the change of the dependent variable. Without sorting,the line would be going back and forth all over the place (see below)

# %%
df.plot(x = 'SATV', y = 'SATM')
