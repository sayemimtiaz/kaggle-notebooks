# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %% [markdown]
# ı am a begginner for data science. This is my first code. Initially I import datas.

# %%
frame = pd.read_csv("../input/IRIS.csv")

# %% [markdown]
# Then I learned informations about my data.

# %%
frame.info()

# %%
I learned what columns I have.

# %%
frame.columns

# %% [markdown]
# I obtained what type of flowers are in data document.

# %%
frame["species"].unique()

# %% [markdown]
# I seperated my data according to the flowers.

# %%
setosa = frame[frame["species"] == "Iris-setosa"]
versicolor =  frame[frame["species"] == "Iris-versicolor"]
virginica = frame[frame["species"] == "Iris-virginica"]

# %% [markdown]
# I created a function that find average values for every each column.

# %%
def findaverage(x):
 sum = 0
 for value in x:
    sum = sum + value
 t = sum/50
 return t

# %% [markdown]
# I import plot library and plotted histogram graphs to show about details of columns.I did it for every each specie and column.

# %%
import matplotlib.pyplot as plt
plt.hist(setosa["sepal_length"],color = "cyan")
plt.title("Iris-Setosa Sepal Length",color = "darkblue",fontsize=18)
plt.xlabel("Sepal Length",color = "red",fontsize=20)
plt.ylabel("number of Sepal Lengths",color = "turquoise",fontsize=15)
plt.show()

# %%
plt.hist(setosa["sepal_width"])
plt.title("Iris-Setosa Sepal Width",color = "blue",fontsize=18)
plt.xlabel("Sepal Width",color = "pink",fontsize=20)
plt.ylabel("number of Sepal Widths",color = "black",fontsize=15)
plt.show()

# %%
plt.hist(setosa["petal_length"],color= (0.1232,0.99999,0.1))
plt.title("Iris-Setosa Petal Length",color = "red",fontsize=18)
plt.xlabel("petal Length",color = "black",fontsize=20)
plt.ylabel("number of petal lengths",color = "blue",fontsize=15)
plt.show()

# %%
plt.hist(setosa["petal_width"],color= "purple")
plt.title("Iris-Setosa Petal Width",color = (0.1,0.3,0.10),fontsize=18)
plt.xlabel("petal Width",color = "brown",fontsize=20)
plt.ylabel("number of petal Widths",color = "purple",fontsize=15)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(versicolor["sepal_length"],color = "cyan")
plt.title("Iris-VersiColor Sepal Length",color = "darkblue",fontsize=18)
plt.xlabel("Sepal Length",color = "red",fontsize=20)
plt.ylabel("number of Sepal Lengths",color = "turquoise",fontsize=15)
plt.show()

# %%
plt.hist(versicolor["sepal_width"])
plt.title("Iris-VersiColor Sepal Width",color = "blue",fontsize=18)
plt.xlabel("Sepal Width",color = "pink",fontsize=20)
plt.ylabel("number of Sepal Widths",color = "black",fontsize=15)
plt.show()

# %%
plt.hist(versicolor["petal_length"],color= (0.1232,0.99999,0.1))
plt.title("Iris-VersiColor Petal Length",color = "red",fontsize=18)
plt.xlabel("petal Length",color = "black",fontsize=20)
plt.ylabel("number of petal lengths",color = "blue",fontsize=15)
plt.show()

# %%
plt.hist(versicolor["petal_width"],color= "purple")
plt.title("Iris-VersiColor Petal Width",color = (0.1,0.3,0.10),fontsize=18)
plt.xlabel("petalWidth",color = "brown",fontsize=20)
plt.ylabel("number of petal Widths",color = "purple",fontsize=15)
plt.show()

# %%
plt.hist(virginica["sepal_length"],color = "cyan")
plt.title("Iris-Virginica Sepal Length",color = "darkblue",fontsize=18)
plt.xlabel("Sepal Length",color = "red",fontsize=20)
plt.ylabel("number of Sepal Lengths",color = "turquoise",fontsize=15)
plt.show()

# %%
plt.hist(virginica["sepal_width"])
plt.title("Iris-Virginica Sepal Width",color = "blue",fontsize=18)
plt.xlabel("Sepal Width",color = "pink",fontsize=20)
plt.ylabel("number of Sepal Widths",color = "black",fontsize=15)
plt.show()

# %%
plt.hist(virginica["petal_length"],color= (0.1232,0.99999,0.1))
plt.title("Iris-Virginica Petal Length",color = "red",fontsize=18)
plt.xlabel("petal Length",color = "black",fontsize=20)
plt.ylabel("number of petal lengths",color = "blue",fontsize=15)
plt.show()

# %%
plt.hist(virginica["petal_width"],color= "purple")
plt.title("Iris-Virginica Petal Width",color = (0.1,0.3,0.10),fontsize=18)
plt.xlabel("petal Width",color = "brown",fontsize=20)
plt.ylabel("number of petal Widths",color = "purple",fontsize=15)
plt.show()

# %% [markdown]
# I created this function to find max values for every each column.

# %%
def findmaxvalue(x):
    t = 0
    for value in x:
        if value>t:
            j=0
            t = value
        if t == value:
            j+=1
    return t,j

# %%
def findcorrvalue(x,maxi,j):
    liste = []
    a=2
    for y in range(1,j+1):
        i = 0
        for value in x.values:
            if a!=i:
               if value == maxi:
                    liste.append(i)
                    break
            i = i + 1
        a=i
    return liste

# %%
def corrvalue(x,y):
    value = []
    for t in x:
        value.append(y[t])
    return value

# %% [markdown]
# max setosa values.

# %%
max_setosa_sepal_length=findmaxvalue(setosa["sepal_length"])[0]
max_setosa_sepal_width = findmaxvalue(setosa["sepal_width"])[0]
max_setosa_petal_length = findmaxvalue(setosa["petal_length"])[0]
max_setosa_petal_width = findmaxvalue(setosa["petal_width"])[0]

# %%
count_setosa_sepal_length = findmaxvalue(setosa["sepal_length"])[1]
count_setosa_sepal_width =   findmaxvalue(setosa["sepal_width"])[1]
count_setosa_petal_length = findmaxvalue(setosa["petal_length"])[1]
count_setosa_petal_width = findmaxvalue(setosa["petal_width"])[1]

# %%
corr_setosa_sepal_length = corrvalue(findcorrvalue(setosa["sepal_length"],max_setosa_sepal_length,count_setosa_sepal_length),setosa["sepal_width"])
corr_setosa_sepal_width = corrvalue(findcorrvalue(setosa["sepal_width"],max_setosa_sepal_width,count_setosa_sepal_width),setosa["sepal_length"])
corr_setosa_petal_length = corrvalue(findcorrvalue(setosa["petal_length"],max_setosa_petal_length,count_setosa_petal_length),setosa["petal_width"])
corr_setosa_petal_width = corrvalue(findcorrvalue(setosa["petal_width"],max_setosa_petal_width,count_setosa_petal_width),setosa["petal_length"])

# %% [markdown]
# average setosa values.

# %%
avg_setosa_sepal_length = findaverage(setosa["sepal_length"])
avg_setosa_sepal_width =  findaverage(setosa["sepal_width"])
avg_setosa_petal_length =  findaverage(setosa["petal_length"])
avg_setosa_petal_width =  findaverage(setosa["petal_width"])

# %% [markdown]
# I plotted scatter graphs for every each specie to show relation between the columns.

# %%
plt.scatter(setosa["sepal_length"],setosa["sepal_width"],color = "blue",label = "")
c = plt.scatter(avg_setosa_sepal_length,avg_setosa_sepal_width , color = "red",label= "avg intersection point")
plt.scatter(max_setosa_sepal_length,max_setosa_sepal_width,color = "olive",label = "max intersection point")
plt.scatter(max_setosa_sepal_length,corr_setosa_sepal_length,color = "gray",label = "max sepal length")
plt.scatter(max_setosa_sepal_width,corr_setosa_sepal_length,color="pink",label = "max sepal width")
plt.legend()
plt.xlabel("Sepal Length",color = "red",fontsize = 18)
plt.ylabel("Sepal Width",color = "purple",fontsize = 18)
plt.grid()
plt.title("Relation between Sepal Length and Sepal Width\nfor Iris-Setosa",color = "black",fontsize= 13)

# %%
plt.scatter(setosa["petal_length"],setosa["petal_width"],label="")
plt.scatter(avg_setosa_petal_length,avg_setosa_petal_width,color = "yellow",label = "avg intersection point")
plt.scatter(max_setosa_petal_length,max_setosa_petal_width,color="red",label = "max intersection point")
plt.scatter((max_setosa_petal_length,max_setosa_petal_length),corr_setosa_petal_length,color = "purple",label = "max petal length")
plt.scatter(max_setosa_petal_width,corr_setosa_petal_width,color = "darkblue",label = "max petal width")
plt.legend()
plt.grid()
plt.xlabel("Petal Length",color = "brown",fontsize = 18)
plt.ylabel("Petal Width",color = "blue",fontsize = 18)
plt.title("Relation between Petal Length and Petal Width\nfor Iris-Setosa",color="red",fontsize= 13)

# %% [markdown]
# **** average versicolor values.

# %%
avg_versicolor_sepal_length = findaverage(versicolor["sepal_length"])
avg_versicolor_sepal_width =  findaverage(versicolor["sepal_width"])
avg_versicolor_petal_length =  findaverage(versicolor["petal_length"])
avg_versicolor_petal_width =  findaverage(versicolor["petal_width"])

# %% [markdown]
# max versicolor values.

# %%
max_versicolor_sepal_length=findmaxvalue(versicolor["sepal_length"])[0]
max_versicolor_sepal_width = findmaxvalue(versicolor["sepal_width"])[0]
max_versicolor_petal_length = findmaxvalue(versicolor["petal_length"])[0]
max_versicolor_petal_width = findmaxvalue(versicolor["petal_width"])[0]

# %%
plt.scatter(versicolor["sepal_length"],versicolor["sepal_width"],color="green",label="")
plt.scatter(avg_versicolor_sepal_length,avg_versicolor_sepal_width,color = "black",label = "avg intersection point")
plt.scatter(max_versicolor_sepal_length,max_versicolor_sepal_width,color = "red",label = "max intersection point")
plt.legend(loc = "upper left")
plt.grid()
plt.xlabel("Sepal Length",color = "red",fontsize = 18)
plt.ylabel("Sepal Width",color = "purple",fontsize = 18)
plt.title("Relation between Sepal Length and Sepal Width\nfor Irish-Versicolor",color = "black",fontsize= 13)

# %%
plt.scatter(versicolor["petal_length"],versicolor["petal_width"],color="cyan",label = "")
plt.scatter(avg_versicolor_petal_length,avg_versicolor_petal_width,color = "purple",label = "avg intersection point")
plt.scatter(max_versicolor_petal_length,max_versicolor_petal_width,color = "olive",label = "max intersection point")
plt.legend(loc="upper left")
plt.grid()
plt.xlabel("Petal Length",color = "brown",fontsize = 18)
plt.ylabel("Petal Width",color = "blue",fontsize = 18)
plt.title("Relation between Petal Length and Petal Width\nfor Iris-Versicolor",color="red",fontsize= 13)

# %% [markdown]
# Average virginica values.

# %%
avg_virginica_sepal_length = findaverage(versicolor["sepal_length"])
avg_virginica_sepal_width =  findaverage(versicolor["sepal_width"])
avg_virginica_petal_length =  findaverage(versicolor["petal_length"])
avg_virginica_petal_width =  findaverage(versicolor["petal_width"])

# %% [markdown]
# maximum values for virginica.

# %%
max_virginica_sepal_length=findmaxvalue(virginica["sepal_length"])[0]
max_virginica_sepal_width = findmaxvalue(virginica["sepal_width"])[0]
max_virginica_petal_length = findmaxvalue(virginica["petal_length"])[0]
max_virginica_petal_width = findmaxvalue(virginica["petal_width"])[0]

# %%
plt.scatter(virginica["sepal_length"],virginica["sepal_width"],color= "olive",label="")
plt.scatter(avg_virginica_sepal_length,avg_virginica_sepal_width,color = "black",label = "avg intersection point")
plt.scatter(max_virginica_sepal_length,max_virginica_sepal_width,color = "blue",label = "max intersection point")
plt.legend(loc="upper left")
plt.grid()
plt.xlabel("Sepal Length",color = "red",fontsize = 18)
plt.ylabel("Sepal Width",color = "purple",fontsize = 18)
plt.title("Relation between Sepal Length and Sepal Width\nfor Iris-Virginica",color = "black",fontsize= 13)

# %%
plt.scatter(virginica["petal_length"],virginica["petal_width"],color = "palegreen",label = "")
plt.scatter(avg_virginica_petal_length,avg_virginica_petal_width,color ="olive",label = "avg intersection point")
plt.scatter(max_virginica_petal_length,max_virginica_petal_width,color = "purple",label="max intersection point")
plt.legend(loc = "lower right")
plt.grid()
plt.xlabel("Petal Length",color = "brown",fontsize = 18)
plt.ylabel("Petal Width",color = "blue",fontsize = 18)
plt.title("Relation between Petal Length and Petal Width\nfor Iris-Virginica",color="red",fontsize= 13)

# %% [markdown]
# I plotted line plots to show columns relations.I drawed them separately.

# %%
setosa.plot()

# %%
versicolor.plot()

# %%
virginica.plot()
