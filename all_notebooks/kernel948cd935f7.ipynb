# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %% [markdown]
# **Read the content from spam.csv**

# %%
spam = pd.read_csv('//kaggle//input//sms-spam-collection-dataset//spam.csv',encoding = "latin-1",usecols=['v1','v2'])
spam.head()

# %% [markdown]
# ** Split the features and target variables in to different dataframes**

# %%
spam_text = spam.v2
spam_label = spam.v1

# %% [markdown]
# **Check for any null values in the label, as that data is of no use**

# %%
spam_label[spam_label.isnull()]

# %% [markdown]
# **Split the data into trin and test datasets**

# %%
spam_text_train,spam_text_test,spam_label_train,spam_label_test = train_test_split(spam_text,spam_label,test_size=0.3,random_state=42)
spam_text_train.shape,spam_text_test.shape,spam_label_train.shape,spam_label_test.shape

# %% [markdown]
# **Create a Count Vectorizer object to perform tokenization, eliminate stop words, perfrom lemmatization**

# %%
count_vec = CountVectorizer(stop_words="english")

# %% [markdown]
# **Transform the train data into bag of words**

# %%
count_train = count_vec.fit_transform(spam_text_train)
count_train.shape

# %% [markdown]
# **Transform the test data to bag of words**

# %%
count_test = count_vec.transform(spam_text_test)
count_test.shape

# %% [markdown]
# **Create a Naive Bayes object**

# %%
nb = MultinomialNB()

# %% [markdown]
# **Fit the train data and predict labels of test_data.**

# %%
nb.fit(count_train,spam_label_train)
spam_pred=nb.predict(count_test)

# %% [markdown]
# **Check accuracy of the outcome using accuracy_score**

# %%
accuracy_score(spam_label_test,spam_pred)

# %% [markdown]
# **Generate classification report to analyze the results in detail**

# %%
classification_report(spam_label_test,spam_pred)

# %%
spam_label_test

# %%
spam_pred

# %% [markdown]
# **Im going commit another version of this to handle the skewness of data**
