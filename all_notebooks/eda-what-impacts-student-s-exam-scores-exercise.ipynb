# %% [markdown]
# # Analysing the factors affecting the Exam scores

# %% [markdown]
# ## Import packages

# %%
#Import python libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
sns.set_style('darkgrid')

# %% [markdown]
# ## Import data

# %%
#data=pd.read_csv('StudentsPerformance.csv')
#data.head()

# %% [markdown]
# ## Basic Statistics

# %% [markdown]
# **Display Information(info) about the 'data'**

# %%
#data._____()

# %% [markdown]
# **Display size(shape) about the 'data'**

# %%
#data._____

# %% [markdown]
# ## Analysing the impact of reading, writing and math score on Total marks

# %% [markdown]
# **Compare the features in 'data' against 'gender' using pairplot**

# %%
#sns.pairplot(data=_____,hue='_____')

# %% [markdown]
# <font color='blue'>**OBSERVATION :** Total score is directly propertional to writing score, reading score and math score (as the total is formed by these marks)</font>

# %% [markdown]
# **Visualize the 'data' using boxplot/boxenplot/violinplot - 'gender' vs 'Total score'**

# %%
#fig, axes = plt.subplots(1, 3, figsize=(12, 6))
#sns.boxplot(ax=axes[0], data=data, x='_____', y='_____')
#sns.boxenplot(ax=axes[1], data=data, x='_____', y='_____')
#sns.violinplot(ax=axes[2], data=data, x='_____', y='_____')

# %% [markdown]
# <font color='blue'>**OBSERVATION :** Females have higher exam scores as compared to males</font>

# %% [markdown]
# **Visualize the 'data' using boxplot/boxenplot - 'race/ethnicity' vs 'Total score'**

# %%
#fig, axes = plt.subplots(1, 2, figsize=(12, 6))
#sns.boxplot(ax=axes[0], data=data, x='_____', y='_____')
#sns.boxenplot(ax=axes[1], data=data, x='_____', y='_____')

# %% [markdown]
# <font color='blue'>**OBSERVATION :** Group A gets lesser exam scores as compared to others</font>

# %% [markdown]
# **Visualize the 'data' using boxplot - 'parental level of education' vs 'Total score'**

# %%
#plt.subplots(figsize=(12, 6))
#sns.boxplot(data=data, x='_____', y='Total _____')

# %% [markdown]
# <font color='blue'>**OBSERVATION :** Students whose parents have just completed high school get less marks in the exam</font>

# %% [markdown]
# **Visualize the 'data' using boxplot/boxenplot/violinplot - 'lunch' vs 'Total score'**

# %%
#fig, axes = plt.subplots(1, 3, figsize=(12, 6))
#sns.boxplot(ax=axes[0], data=data, x='_____', y='_____')
#sns.boxenplot(ax=axes[1], data=data, x='_____', y='_____')
#sns.violinplot(ax=axes[2], data=data, x='_____', y='_____')

# %% [markdown]
# <font color='blue'>**OBSERVATION :** Students getting free/reduced lunch get less marks in the exam</font>

# %% [markdown]
# **Visualize the 'data' using boxplot/boxenplot/violinplot  - 'test preparation course' vs 'Total score'**

# %%
#fig, axes = plt.subplots(1, 3, figsize=(12, 6))
#sns.boxplot(ax=axes[0], data=data, x='_____', y='_____')
#sns.boxenplot(ax=axes[1], data=data, x='_____', y='_____')
#sns.violinplot(ax=axes[2], data=data, x='_____', y='_____')

# %% [markdown]
# <font color='blue'>**OBSERVATION :** Students who have completed test perpartion course get more marks in the exam</font>
