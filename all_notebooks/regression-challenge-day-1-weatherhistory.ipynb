# %%
#lib

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df  = pd.read_csv('../input/szeged-weather/weatherHistory.csv')
df.head()

# %%
#data Preprocessing
#check for null/ NaN values
df.isnull().any().any()
#check for missing values
df.isnull().values.any()

# %% [markdown]
# No NaN/null and missing value in data
#
# Let find data types of valirables:
#
# * Count - Formatted Date, Wind Bearing (degrees),
# * Continuous - Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Visibility (km), Pressure (millibars)
# * Categorical - Summary, Precip Type, Daily Summary
#
# Loud Cover has all 0 value
#
#  Predict 'Precip Type' based on Temperature.
#  We are going to use Logistic Regression based on data type.

# %%
#Visualise 
plt.title('Precip Type Vs. Temperature')
plt.xlabel('Temperature')
plt.ylabel('Precip Type')
plt.plot(
        df['Temperature (C)'].values, df['Precip Type'].values,'or',alpha=0.5
)
plt.show()
