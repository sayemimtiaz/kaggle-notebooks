# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import diff

covid_1=pd.read_csv("/kaggle/input/guiadcovid/datos/estadisticasUY_porDepto.csv", index_col='fecha',parse_dates=False, encoding='latin_1')
covid_2=pd.read_csv("/kaggle/input/guiadcovid/datos/estadisticasUY_porDepto_detalle.csv", index_col='fecha',parse_dates=False, encoding='latin_1')
covid_3=pd.read_csv("/kaggle/input/guiadcovid/datos/estadisticasUY.csv",parse_dates=True, encoding='latin_1')

items=list(covid_2.columns)
print(items)
#print(covid_2.search_type.str.contains('Colonia',na=False))
#print(ver)t
#zona1=covid_3.loc[(covid_3.cantTest <= 4000)]
#zona2=covid_3.loc[(covid_3.cantTest >= 4000)]
#print(covid_2.tail())
#plt.figure(figsize=(12,6))
#plt.title('?')
#sns.scatterplot(x=covid(1-_3.cantTest, y=covid_3.cantCasosNuevos))

#sns.regplot(x=zona1.cantTest, y=zona1.cantCasosNuevos)
#sns.regplot(x=zona2.cantTest, y=zona2.cantCasosNuevos)
# 2D KDE plot

#
#sns.regplot(x=covid_3.cant, y=covid_3.cantCasosNuevos)

#sns.heatmap(data=ign_data, annot=True)
#for i in range(len()):
#import statsmodels.api as sm
#import statsmodels.formula.api as smf

#print(items[10])    
#descriptor=covid_3.iloc[:,10]
#print(descriptor)
#sns.lineplot(data=descriptor)
#from numpy import diff
#dx = 1
#y = list(descriptor[:])
#print(y)
#dy = diff(y)/dx
#print(dy)

#z = zip(y,dy)
#with open("R_data.dat", "w") as f :
 #     f.write("\n".join(",".join(map(str,x)) for x in z))

#sns.lineplot(data=dy)
#array([ 10.,  10.,  10.,   0.,  10.,  10.])

plt.figure(figsize=(12,6))
plt.title('Casos nuevos colonia')
colonia=covid_2[covid_2.departamento=='Colonia(UY-CO)']
print(colonia.tail())

casos_nuevos=list(colonia.iloc[:,3])
sns.lineplot(data=casos_nuevos)
plt.show()

# %%
items=list(covid_3.columns)
for i in range(2,len(items)):  
    casos_activos=covid_3.iloc[:,i]
    plt.figure(figsize=(12,6))
    plt.title('Grafico actualizado para todo el país de  '+ items[i])
    sns.lineplot(data=casos_activos)
#sns.scatterplot(x=covid_3.iloc[,y=casos_activos[14])
