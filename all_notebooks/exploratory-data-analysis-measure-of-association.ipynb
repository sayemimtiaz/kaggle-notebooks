# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('../input/leads-dataset/Leads.csv')

# %% [markdown]
# # EDA Section

# %%
pd.set_option('display.max_columns', None)
dataset.head()

# %%
dataset = dataset.replace('Select', np.nan)

# %%
dataset.isna().sum()/len(dataset)

# %%
dataset.Converted.value_counts(normalize=True)

# %% [markdown]
# **Lead Origin**

# %%
dataset['Lead Origin'].unique()

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.countplot(data = dataset, x ='Lead Origin', hue='Converted', ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %% [markdown]
# **Lead Source**

# %%
dataset['Lead Source'].unique()

# %%
dataset['Lead Source'] = dataset['Lead Source'].replace('google', 'Google')

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.countplot(data = dataset, x ='Lead Source', hue='Lead Origin', ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
dataset['Lead Source'].value_counts(normalize=True)

# %%
insignificant_source = pd.Series(dataset['Lead Source'].unique())
insignificant_source = list(insignificant_source[~insignificant_source.isin(['Google', 'Direct Traffic', 'Olark Chat', 
                                                                             'Organic Search', 'Reference', 'Welingak Website',
                                                                            'Referral Sites'])])

# %%
dataset['Lead Source'] = dataset['Lead Source'].apply(lambda x : 'Other' if x in insignificant_source else x)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.countplot(data = dataset, x ='Lead Source', hue='Lead Origin', ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.countplot(data = dataset, x ='Lead Source', hue='Converted', ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
dataset.isna().sum()/len(dataset)

# %%
sns.countplot(data = dataset, x ='Do Not Email', hue='Converted')

# %%
sns.countplot(data = dataset, x ='Do Not Call', hue='Converted')

# %% [markdown]
# **Total Visits**

# %%
sns.displot(data=dataset.TotalVisits, height=10, aspect=1)

# %%
sns.boxplot(data=dataset.TotalVisits)

# %%
sns.boxplot(data=dataset, x='Converted', y='TotalVisits')

# %%
dataset.TotalVisits = dataset.TotalVisits.fillna(int(dataset.TotalVisits.median()))

# %% [markdown]
# **Total Time Spent on Website**

# %%
sns.displot(data=dataset['Total Time Spent on Website'], height=7, aspect=1, kind='hist')

# %%
sns.boxplot(data=dataset, x='Converted', y='Total Time Spent on Website')

# %%
dataset.isna().sum()/len(dataset)

# %% [markdown]
# **Page Views Per Visit**

# %%
sns.displot(data=dataset['Page Views Per Visit'], height=7, aspect=1, kind='hist')

# %%
sns.boxplot(data=dataset, x='Converted', y='Page Views Per Visit')

# %%
dataset['Page Views Per Visit'] = dataset['Page Views Per Visit'].fillna(int(dataset['Page Views Per Visit'].median()))

# %% [markdown]
# **Last Activity** and **Last Notable Activity**

# %%
dataset['Last Activity'].unique()

# %%
dataset['Last Notable Activity'].unique()

# %%
g = sns.countplot(data=dataset, x='Last Activity', hue='Converted')
g.set_xticklabels(g.get_xticklabels(), rotation=90)

# %%
g = sns.countplot(data=dataset, x='Last Notable Activity', hue='Converted')
g.set_xticklabels(g.get_xticklabels(), rotation=90)

# %%
dataset['Last Activity'] = dataset['Last Activity'].fillna('Unreachable')

# %%
dataset.isna().sum()/len(dataset)

# %% [markdown]
# **Country**

# %%
g = sns.countplot(data=dataset, x='Country', hue='Converted')
g.set_xticklabels(g.get_xticklabels(), rotation=90)

# %% [markdown]
# **Specialization**

# %%
g = sns.countplot(data=dataset, x='Specialization', hue='Converted')
g.set_xticklabels(g.get_xticklabels(), rotation=90)

# %%
dataset.Specialization = dataset.Specialization.fillna('Others')

# %%
g = sns.countplot(data=dataset, x='Specialization', hue='Converted')
g.set_xticklabels(g.get_xticklabels(), rotation=90)

# %%
dataset.isna().sum()/len(dataset)

# %% [markdown]
# **What Is Your Current Occupation**

# %%
g = sns.countplot(data=dataset, x='What is your current occupation', hue='Converted')
g.set_xticklabels(g.get_xticklabels(), rotation=90)

# %%
dataset['What is your current occupation'] = dataset['What is your current occupation'].fillna('Other')

# %%
g = sns.countplot(data=dataset, x='What is your current occupation', hue='Converted')
g.set_xticklabels(g.get_xticklabels(), rotation=90)

# %%
dataset.isna().sum()

# %% [markdown]
# **What matters most to you in choosing a course**

# %%
dataset['What matters most to you in choosing a course'].unique()
g = sns.countplot(data=dataset, x='What matters most to you in choosing a course', hue='Converted')
g.set_xticklabels(g.get_xticklabels(), rotation=90)

# %%
dataset['What matters most to you in choosing a course'] = dataset['What matters most to you in choosing a course'].fillna('Other')

# %%
g = sns.countplot(data=dataset, x='What matters most to you in choosing a course', hue='Converted')
g.set_xticklabels(g.get_xticklabels(), rotation=90)

# %% [markdown]
# **Search**

# %%
g = sns.countplot(data=dataset, x='Search', hue='Converted')

# %% [markdown]
# **Through Recommendations**

# %%
sns.countplot(data=dataset, x='Through Recommendations', hue='Converted')

# %% [markdown]
# **Receive More Updates About Our Courses**

# %%
sns.countplot(data=dataset, x='Receive More Updates About Our Courses')

# %%
dataset.isna().sum()/len(dataset)

# %% [markdown]
# **Tags**

# %%
dataset.Tags.unique()

# %%
g = sns.countplot(data=dataset, x='Tags', hue='Converted')
g.set_xticklabels(g.get_xticklabels(), rotation=90)

# %%
dataset['Tags'] = dataset['Tags'].fillna('Other Tags')

# %% [markdown]
# **Lead Quality**

# %%
g = sns.countplot(data=dataset, x='Lead Quality', hue='Converted')
g.set_xticklabels(g.get_xticklabels(), rotation=90)

# %%
dataset['Lead Quality'] = dataset['Lead Quality'].fillna('Not Sure')

# %%
g = sns.countplot(data=dataset, x='Lead Quality', hue='Converted')
g.set_xticklabels(g.get_xticklabels(), rotation=90)

# %%
dataset.isna().sum()/len(dataset)

# %% [markdown]
# **Update me on Supply Chain Content**

# %%
dataset['Update me on Supply Chain Content'].unique()

# %%
dataset['Update me on Supply Chain Content'].unique()

# %% [markdown]
# **Get updates on DM Content**

# %%
dataset['Get updates on DM Content'].unique()

# %% [markdown]
# **City**

# %%
g = sns.countplot(data=dataset, x='City', hue='Converted')
g.set_xticklabels(g.get_xticklabels(), rotation=90)

# %%
dataset.isna().sum()/len(dataset)

# %% [markdown]
# I agree to pay the amount through cheque

# %%
dataset['I agree to pay the amount through cheque'].unique()

# %% [markdown]
# **A free copy of Mastering The Interview**

# %%
dataset['A free copy of Mastering The Interview'].unique()

# %%
sns.countplot(data=dataset, x='A free copy of Mastering The Interview', hue='Converted')

# %% [markdown]
# # Theil's U Test

# %%
dataset.head()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
cat_dataset = dataset[['Lead Origin', 'Lead Source', 'Do Not Email', 'Do Not Call',
                                'Last Activity', 'Country', 'Specialization', 'How did you hear about X Education',
                                'What is your current occupation', 'What matters most to you in choosing a course',
                                'Search', 'Magazine', 'Newspaper Article', 'X Education Forums', 'Newspaper',
                                'Digital Advertisement', 'Through Recommendations', 'Receive More Updates About Our Courses',
                                'Tags', 'Lead Quality', 'Update me on Supply Chain Content', 'Get updates on DM Content',
                                'Lead Profile', 'City', 'Asymmetrique Activity Index', 'Asymmetrique Profile Index',
                                'I agree to pay the amount through cheque', 'A free copy of Mastering The Interview',
                                'Last Notable Activity', 'Converted']]

# %%
cat_dataset.head()

# %%
for cat in cat_dataset.columns:
    enc = LabelEncoder()
    cat_dataset[cat] = enc.fit_transform(cat_dataset[cat])

# %%
from collections import Counter
import math
import scipy.stats as ss

# %%
def conditional_entropy(x,y):
    # entropy of x given y
    y_counter = Counter(y)
    xy_counter = Counter(list(zip(x,y)))
    total_occurrences = sum(y_counter.values())
    entropy = 0
    for xy in xy_counter.keys():
        p_xy = xy_counter[xy] / total_occurrences
        p_y = y_counter[xy[1]] / total_occurrences
        entropy += p_xy * math.log(p_y/p_xy)
    return entropy

def theil_u(x,y):
    s_xy = conditional_entropy(x,y)
    x_counter = Counter(x)
    total_occurrences = sum(x_counter.values())
    p_x = list(map(lambda n: n/total_occurrences, x_counter.values()))
    s_x = ss.entropy(p_x)
    if s_x == 0:
        return 1
    else:
        return (s_x - s_xy) / s_x

# %%
theilu = pd.DataFrame(index=['class'],columns=cat_dataset.columns)
columns = cat_dataset.columns
for j in range(0,len(columns)):
    u = theil_u(cat_dataset['Converted'].tolist(),cat_dataset[columns[j]].tolist())
    theilu.loc[:,columns[j]] = u

# %%
theilu.fillna(value=np.nan,inplace=True)
plt.figure(figsize=(20,1))
sns.heatmap(theilu,annot=True,fmt='.2f')
plt.show()

# %% [markdown]
# # Correlation Ratio

# %%
dataset['Asymmetrique Activity Score'] = dataset['Asymmetrique Activity Score'].fillna(dataset['Asymmetrique Activity Score'].mean())

# %%
dataset['Asymmetrique Profile Score'] = dataset['Asymmetrique Profile Score'].fillna(dataset['Asymmetrique Profile Score'].mean())

# %%
cont_dataset = dataset[['TotalVisits', 'Total Time Spent on Website', 'Page Views Per Visit',
                       'Asymmetrique Activity Score', 'Asymmetrique Profile Score', 'Converted']]

# %%
corr = cont_dataset.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
sns.heatmap(corr, mask=mask, cmap='BrBG', vmin=-1, vmax=1, annot=True)

# %% [markdown]
# Drop Unused columns based on Measure of Association or Null Values

# %%
dataset.drop(['How did you hear about X Education', 'Lead Profile'], axis=1, inplace=True)
dataset.drop('Country', axis=1, inplace=True)
dataset.drop(['Search', 'Magazine', 'Newspaper Article',
             'X Education Forums', 'Newspaper', 'Digital Advertisement'], axis=1, inplace=True)
dataset.drop('Through Recommendations', axis=1, inplace=True)
dataset.drop(['Receive More Updates About Our Courses'], axis=1, inplace=True)
dataset.drop(['Update me on Supply Chain Content', 'Get updates on DM Content'], axis=1, inplace=True)
dataset.drop(['City', 'Assymetrique Activity Index', 'Assymetrique Profile Index'], axis=1, inplace=True)
dataset.drop(['I agree to pay the amount through cheque', 'A free copy of Mastering The Interview'], axis=1, inplace=True)

# %%
dataset.drop(['TotalVisits', 'Page Views Per Visit'], axis=1, inplace=True)
