# %% [markdown]
# Ever wondered how you have fared in the Kaggle over time?
#
# This kernel is to look at the kaggle journey of you (and probably the people whom we silently stalk at) and understand more about the journey !
#
# Please enter the `username` of the person in the below cell and execute the notebook to look at the journey.

# %%
import os
import string
import datetime
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()

# %matplotlib inline

from plotly import tools
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go

pd.options.mode.chained_assignment = None
pd.options.display.max_columns = 999

print(os.listdir("../input"))
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ['UserOrganizations.csv', 'KernelTags.csv', 'Kernels.csv', 'KernelVersions.csv', 'DatasourceObjects.csv', 'Tags.csv', 'UserAchievements.csv', 'ForumTopics.csv', 'Teams.csv', 'ForumMessages.csv', 'Datasources.csv', 'DatasetVotes.csv', 'CompetitionTags.csv', 'KernelVersionDatasetSources.csv', 'Organizations.csv', 'DatasourceVersionObjectTables.csv', 'DatasetVersions.csv', 'Datasets.csv', 'KernelVotes.csv', 'KernelLanguages.csv', 'Forums.csv', 'KernelVersionOutputFiles.csv', 'ForumMessageVotes.csv', 'KernelVersionKernelSources.csv', 'UserFollowers.csv', 'DatasetTags.csv', 'KernelVersionCompetitionSources.csv', 'Users.csv', 'TeamMemberships.csv', 'Competitions.csv', 'Submissions.csv']

# %%
### Enter the user name here ###
user_name = "tunguz"

# %%
users_df = pd.read_csv("../input/Users.csv")
user_df = users_df[users_df["UserName"]==user_name]
user_id = user_df["Id"].values[0]
user_display = user_df["DisplayName"].values[0]
print("The user id for the given user name is : ",user_id)
print("The display name for the given user name is : ",user_display)
# Out:
# The user id for the given user name is :  417337
# The display name for the given user name is :  Bojan Tunguz

# %% [markdown]
# ## Competitions Journey

# %%
team_members_df = pd.read_csv("../input/TeamMemberships.csv")
team_df = pd.read_csv("../input/Teams.csv")
comp_df = pd.read_csv("../input/Competitions.csv")

temp_df = team_members_df[team_members_df["UserId"]==user_id]
temp_df = pd.merge(temp_df, team_df, left_on="TeamId", right_on="Id", how="left")
temp_df = pd.merge(temp_df, comp_df, left_on="CompetitionId", right_on="Id", how="left")
temp_df["DeadlineDate"] = pd.to_datetime(temp_df["DeadlineDate"], format="%m/%d/%Y %H:%M:%S")
temp_df["DeadlineYear"] = temp_df["DeadlineDate"].dt.year
temp_df["DeadlineDate"] = temp_df["DeadlineDate"].apply(lambda x: datetime.date(x.year,x.month,1))

temp_df = temp_df[~np.isnan(temp_df["PrivateLeaderboardRank"])]
temp_df.head()
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning:
#
# Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#      Id_x  TeamId  UserId RequestDate    Id_y  CompetitionId  TeamLeaderId  \
# 0  245724  217811  417337  09/15/2015  217811           4488      417337.0
# 1  246256  218347  417337  09/17/2015  218347           4481      417337.0
# 2  246502  218587  417337  09/18/2015  218587           4487      417337.0
# 3  246557  218648  417337  09/18/2015  218648           4493      417337.0
# 4  247468  219552  417337  09/22/2015  219552           4521      417337.0
#
#        TeamName ScoreFirstSubmittedDate LastSubmissionDate  \
# 0  Bojan Tunguz              10/12/2015         10/12/2015
# 1  Bojan Tunguz              09/29/2015         09/29/2015
# 2  Bojan Tunguz              09/19/2015         10/11/2015
# 3  Bojan Tunguz              09/18/2015         09/26/2015
# 4  Bojan Tunguz              09/22/2015         09/22/2015
#
#    PublicLeaderboardSubmissionId  PrivateLeaderboardSubmissionId  IsBenchmark  \
# 0                      2029965.0                       2029965.0        False
# 1                      1991779.0                       1991779.0        False
# 2                      1961744.0                       1961744.0        False
# 3                      1983556.0                       1960743.0        False
# 4                      1969980.0                       1969980.0        False
#
#    Medal MedalAwardDate  PublicLeaderboardRank  PrivateLeaderboardRank    Id  \
# 0    3.0     07/15/2016                   89.0                    82.0  4488
# 1    NaN            NaN                  220.0                   224.0  4481
# 2    NaN            NaN                  573.0                   584.0  4487
# 3    NaN            NaN                  218.0                   233.0  4493
# 4    NaN            NaN                  299.0                   297.0  4521
#
#                             Slug                                   Title  \
# 0            flavours-of-physics  Flavours of Physics: Finding τ  →  μμμ
# 1     coupon-purchase-prediction              Coupon Purchase Prediction
# 2  springleaf-marketing-response           Springleaf Marketing Response
# 3                    dato-native                           Truly Native?
# 4   noaa-right-whale-recognition                 Right Whale Recognition
#
#                                             Subtitle HostSegmentTitle  \
# 0                   Identify a rare decay phenomenon         Featured
# 1          Predict which coupons a customer will buy         Featured
# 2  Determine whether to send a direct mail piece ...         Featured
# 3  Predict which web pages served by StumbleUpon ...         Featured
# 4  Identify endangered right whales in aerial pho...         Research
#
#    ForumId  OrganizationId  CompetitionTypeId     HostName  \
# 0    764.0             NaN                  1  CERN/Yandex
# 1    761.0          1022.0                  1      Recruit
# 2    771.0             NaN                  1   Springleaf
# 3    767.0             NaN                  1         Dato
# 4    782.0            22.0                  1         NOAA
#
#            EnabledDate DeadlineDate ProhibitNewEntrantsDeadlineDate  \
# 0  07/20/2015 22:50:02   2015-10-01             10/05/2015 23:59:00
# 1  07/16/2015 00:45:00   2015-09-01             09/23/2015 23:59:00
# 2  08/14/2015 14:23:08   2015-10-01             10/12/2015 23:59:00
# 3  08/06/2015 21:33:47   2015-10-01             10/07/2015 23:59:00
# 4  08/27/2015 22:57:00   2016-01-01             12/31/2015 23:59:00
#
#   TeamMergerDeadlineDate TeamModelDeadlineDate ModelSubmissionDeadlineDate  \
# 0    10/05/2015 23:59:00   11/30/2015 23:59:00                         NaN
# 1    09/23/2015 23:59:00   10/30/2015 23:59:00                         NaN
# 2    10/12/2015 23:59:00   11/12/2015 23:59:00                         NaN
# 3    10/07/2015 23:59:00   11/21/2015 23:59:00                         NaN
# 4    12/31/2015 23:59:00   02/07/2016 23:59:00                         NaN
#
#    FinalLeaderboardHasBeenVerified  HasKernels  OnlyAllowKernelSubmissions  \
# 0                             True        True                       False
# 1                             True        True                       False
# 2                             True        True                       False
# 3                             True        True                       False
# 4                             True        True                       False
#
#    HasLeaderboard  LeaderboardPercentage  LeaderboardDisplayFormat  \
# 0            True                      1                       NaN
# 1            True                     30                       NaN
# 2            True                     30                       NaN
# 3            True                     40                       NaN
# 4            True                     35                       NaN
#
#   EvaluationAlgorithmAbbreviation  \
# 0                 CernWeightedAuc
# 1                         MAP@{K}
# 2                             AUC
# 3                             AUC
# 4                  MulticlassLoss
#
#                              EvaluationAlgorithmName  \
# 0  Weighted AUC, with agreement check and correla...
# 1                                                NaN
# 2  Area Under Receiver Operating Characteristic C...
# 3  Area Under Receiver Operating Characteristic C...
# 4                                    Multiclass Loss
#
#                       EvaluationAlgorithmDescription EvaluationAlgorithmIsMax  \
# 0  Weighted Area Under Receiver Operating Charact...                     True
# 1                        Mean Average Precision at K                     True
# 2  Measures discrimination. Calculates how well a...                     True
# 3  Measures discrimination. Calculates how well a...                     True
# 4  Negative log likelihood divided by the number ...                    False
#
#        ValidationSetName ValidationSetValue  MaxDailySubmissions  \
# 0  Predicted Probability              [0,1]                    5
# 1  Predicted Probability              [0,1]                    5
# 2  Predicted Probability              [0,1]                    5
# 3  Predicted Probability              [0,1]                    3
# 4  Predicted Probability              [0,1]                    5
#
#    NumScoredSubmissions  MaxTeamSize  BanTeamMergers  EnableTeamModels  \
# 0                     2          4.0           False              True
# 1                     2          NaN           False              True
# 2                     2          NaN           False              True
# 3                     2          NaN           False              True
# 4                     2          NaN           False              True
#
#    EnableSubmissionModelHashes  EnableSubmissionModelAttachments RewardType  \
# 0                        False                             False        USD
# 1                        False                             False        USD
# 2                        False                             False        USD
# 3                        False                             False        USD
# 4                        False                             False        USD
#
#    RewardQuantity  NumPrizes  UserRankMultiplier  CanQualifyTiers  TotalTeams  \
# 0         15000.0          3                 1.0             True         673
# 1         50000.0          3                 1.0             True        1076
# 2        100000.0          5                 1.0             True        2226
# 3         10000.0          1                 1.0             True         274
# 4         10000.0          3                 1.0             True         364
#
#    TotalCompetitors  TotalSubmissions  DeadlineYear
# 0               706             10124          2015
# 1              1192             18477          2015
# 2              2508             39439          2015
# 3               426              3224          2015
# 4               474              4789          2016

# %%
def scatter_plot(cnt_srs, color):
    trace = go.Scatter(
        x=cnt_srs.index[::-1],
        y=cnt_srs.values[::-1],
        showlegend=False,
        marker=dict(
            color=color,
        ),
    )
    return trace

cnt_df = temp_df.groupby('DeadlineYear')['PrivateLeaderboardRank'].agg(["size", "mean", "min"])
cnt_srs = cnt_df["size"]
cnt_srs = cnt_srs.sort_index()
trace = go.Bar(
    x=cnt_srs.index,
    y=cnt_srs.values,
    marker=dict(
        color="green",
    ),
)

layout = go.Layout(
    title='Count of competitions over years',
    font=dict(size=14),
    width=800,
    height=500,
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="TargetCount")


### Mean Private Rank ###
cnt_srs = cnt_df["mean"]
cnt_srs = cnt_srs.sort_index()
trace = go.Bar(
    x=cnt_srs.index,
    y=cnt_srs.values,
    marker=dict(
        color="blue",
    ),
)

layout = go.Layout(
    title='Mean Rank over years',
    font=dict(size=14),
    width=800,
    height=500,
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="TargetCount")



### Best rank each year ###
cnt_srs = cnt_df["min"]
cnt_srs = cnt_srs.sort_index()
trace = go.Bar(
    x=cnt_srs.index,
    y=cnt_srs.values,
    marker=dict(
        color="red",
    ),
)

layout = go.Layout(
    title='Best Rank in each year',
    font=dict(size=14),
    width=800,
    height=500,
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="TargetCount")
# Out:
# <div>
#
#
#             <div id="baad30b0-c091-4492-83dc-de93cc1adda5" class="plotly-graph-div" style="height:500px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("baad30b0-c091-4492-83dc-de93cc1adda5")) {
#                     Plotly.newPlot(
#                         'baad30b0-c091-4492-83dc-de93cc1adda5',
#                         [{"marker": {"color": "green"}, "type": "bar", "uid": "45067fc4-42fa-419d-91ed-0d81ce8da435", "x": [2015, 2016, 2017, 2018, 2019], "y": [7, 26, 31, 33, 12]}],
#                         {"font": {"size": 14}, "height": 500, "title": {"text": "Count of competitions over years"}, "width": 800},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('baad30b0-c091-4492-83dc-de93cc1adda5');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# <div>
#
#
#             <div id="65a791e5-3b4a-48b7-bb14-6e87e1078c62" class="plotly-graph-div" style="height:500px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("65a791e5-3b4a-48b7-bb14-6e87e1078c62")) {
#                     Plotly.newPlot(
#                         '65a791e5-3b4a-48b7-bb14-6e87e1078c62',
#                         [{"marker": {"color": "blue"}, "type": "bar", "uid": "a7094f41-3ec9-4a8b-a586-c667b6d812a8", "x": [2015, 2016, 2017, 2018, 2019], "y": [380.42857142857144, 367.4230769230769, 181.09677419354838, 249.03030303030303, 324.4166666666667]}],
#                         {"font": {"size": 14}, "height": 500, "title": {"text": "Mean Rank over years"}, "width": 800},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('65a791e5-3b4a-48b7-bb14-6e87e1078c62');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# <div>
#
#
#             <div id="df78cd40-89c6-45e2-88cb-35da28e55ef2" class="plotly-graph-div" style="height:500px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("df78cd40-89c6-45e2-88cb-35da28e55ef2")) {
#                     Plotly.newPlot(
#                         'df78cd40-89c6-45e2-88cb-35da28e55ef2',
#                         [{"marker": {"color": "red"}, "type": "bar", "uid": "9da02642-db4b-4622-9027-ff893a85e0d5", "x": [2015, 2016, 2017, 2018, 2019], "y": [82.0, 15.0, 22.0, 1.0, 4.0]}],
#                         {"font": {"size": 14}, "height": 500, "title": {"text": "Best Rank in each year"}, "width": 800},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('df78cd40-89c6-45e2-88cb-35da28e55ef2');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
#temp_df["Medal"].value_counts()

cnt_df = temp_df.pivot_table(index="DeadlineYear", columns="Medal", values="PrivateLeaderboardRank", aggfunc="count")
cnt_df = cnt_df.fillna(0)

def get_bar_chart(cnt_srs, name, color):
    trace = go.Bar(
        x=cnt_srs.index,
        y=cnt_srs.values,
        name=name,
        marker=dict(
            color=color,
        ),
    )
    return trace

medal_map = {1.:"Gold", 2.:"Silver", 3.:"Bronze"}
color_map = {1.:"gold", 2.:"silver", 3.:"darkorange"}
traces = []
for col in np.array(cnt_df.columns)[::-1]:
    cnt_srs = cnt_df[col]
    traces.append(get_bar_chart(cnt_srs, medal_map[col], color_map[col]))

layout = go.Layout(
    title='Competition Medals in each year',
    font=dict(size=14),
    barmode='stack',
    width=800,
    height=500,
)

fig = go.Figure(data=traces, layout=layout)
py.iplot(fig, filename='stacked-bar')
# Out:
# <div>
#
#
#             <div id="27c0d35e-4bd9-4501-a797-46dcb7f28d7b" class="plotly-graph-div" style="height:500px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("27c0d35e-4bd9-4501-a797-46dcb7f28d7b")) {
#                     Plotly.newPlot(
#                         '27c0d35e-4bd9-4501-a797-46dcb7f28d7b',
#                         [{"marker": {"color": "darkorange"}, "name": "Bronze", "type": "bar", "uid": "b84b71e1-0284-434d-818f-c82711760127", "x": [2015, 2016, 2017, 2018, 2019], "y": [1.0, 5.0, 6.0, 5.0, 3.0]}, {"marker": {"color": "silver"}, "name": "Silver", "type": "bar", "uid": "0d324667-680b-4d00-b9f4-422702e4ad2d", "x": [2015, 2016, 2017, 2018, 2019], "y": [0.0, 3.0, 5.0, 3.0, 2.0]}, {"marker": {"color": "gold"}, "name": "Gold", "type": "bar", "uid": "00f8bf92-c2fc-4062-b762-57d289755038", "x": [2015, 2016, 2017, 2018, 2019], "y": [0.0, 0.0, 0.0, 3.0, 1.0]}],
#                         {"barmode": "stack", "font": {"size": 14}, "height": 500, "title": {"text": "Competition Medals in each year"}, "width": 800},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('27c0d35e-4bd9-4501-a797-46dcb7f28d7b');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
cnt_srs = temp_df["HostSegmentTitle"].value_counts()

labels = (np.array(cnt_srs.index))
sizes = (np.array((cnt_srs / cnt_srs.sum())*100))

trace = go.Pie(labels=labels, values=sizes)
layout = go.Layout(
    title='Competition Type Distribution',
    font=dict(size=14),
    width=600,
    height=600,
)
data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="usertype")
# Out:
# <div>
#
#
#             <div id="8045303f-4580-4e44-9175-b0b2be024be6" class="plotly-graph-div" style="height:600px; width:600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8045303f-4580-4e44-9175-b0b2be024be6")) {
#                     Plotly.newPlot(
#                         '8045303f-4580-4e44-9175-b0b2be024be6',
#                         [{"labels": ["Featured", "Research", "Recruitment", "Playground"], "type": "pie", "uid": "3efe9579-75c9-455e-938a-5f30a9b0555d", "values": [66.97247706422019, 21.100917431192663, 6.422018348623854, 5.5045871559633035]}],
#                         {"font": {"size": 14}, "height": 600, "title": {"text": "Competition Type Distribution"}, "width": 600},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('8045303f-4580-4e44-9175-b0b2be024be6');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
comp_tags_df = pd.read_csv("../input/CompetitionTags.csv")
tags_df = pd.read_csv("../input/Tags.csv")
cnt_df = pd.merge(temp_df[["CompetitionId"]], comp_tags_df, on="CompetitionId", how="inner")
cnt_df = pd.merge(cnt_df, tags_df, left_on="TagId", right_on="Id", how="inner")
cnt_df["Name"].value_counts()

def bar_chart(cnt_srs, color):
    trace = go.Bar(
        x=cnt_srs.index,
        y=cnt_srs.values,
        showlegend=False,
        marker=dict(
            color=color,
        ),
    )
    return trace

cnt_srs = cnt_df["Name"].value_counts().head(10)
traces = [bar_chart(cnt_srs, "orange")]
layout = go.Layout(
    title='Data type of competitions',
    font=dict(size=14),
    barmode='stack',
    width=800,
    height=500,
)

fig = go.Figure(data=traces, layout=layout)
py.iplot(fig, filename='stacked-bar')
# Out:
# <div>
#
#
#             <div id="db990d07-9df2-4859-a25d-05a39071c90f" class="plotly-graph-div" style="height:500px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("db990d07-9df2-4859-a25d-05a39071c90f")) {
#                     Plotly.newPlot(
#                         'db990d07-9df2-4859-a25d-05a39071c90f',
#                         [{"marker": {"color": "orange"}, "showlegend": false, "type": "bar", "uid": "d5bbbf3e-eab0-4b1b-8921-24d164c58ccd", "x": ["tabular data", "image data", "multiclass classification", "binary classification", "text data", "future prediction", "banking", "internet", "regression", "basketball"], "y": [43, 33, 15, 13, 10, 9, 8, 8, 8, 5]}],
#                         {"barmode": "stack", "font": {"size": 14}, "height": 500, "title": {"text": "Data type of competitions"}, "width": 800},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('db990d07-9df2-4859-a25d-05a39071c90f');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
cnt_srs = temp_df["TeamName"].value_counts().head(5)
traces = [bar_chart(cnt_srs, "blue")]
layout = go.Layout(
    title='Favorite Team Name',
    font=dict(size=14),
    barmode='stack',
    width=800,
    height=500,
)

fig = go.Figure(data=traces, layout=layout)
py.iplot(fig, filename='stacked-bar')
# Out:
# <div>
#
#
#             <div id="75aaad28-8fcd-4cae-829e-73692e27890d" class="plotly-graph-div" style="height:500px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("75aaad28-8fcd-4cae-829e-73692e27890d")) {
#                     Plotly.newPlot(
#                         '75aaad28-8fcd-4cae-829e-73692e27890d',
#                         [{"marker": {"color": "blue"}, "showlegend": false, "type": "bar", "uid": "3303c4ad-7f40-4a74-bf85-83aa6cd727e6", "x": ["Bojan Tunguz", "camel", "Shiny happy people", "Giovanni + 2 random dudes", "Lake Side"], "y": [88, 1, 1, 1, 1]}],
#                         {"barmode": "stack", "font": {"size": 14}, "height": 500, "title": {"text": "Favorite Team Name"}, "width": 800},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('75aaad28-8fcd-4cae-829e-73692e27890d');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
temp_df = team_members_df[team_members_df["UserId"]==user_id]
temp_df = pd.merge(team_members_df, temp_df, on="TeamId", how="inner", suffixes=('', '_y'))
temp_df = temp_df[temp_df["UserId"]!=user_id]
temp_df = pd.merge(temp_df, users_df, left_on="UserId", right_on="Id", how="left")

cnt_srs = temp_df["DisplayName"].value_counts().head(7)
traces = [bar_chart(cnt_srs, "green")]
layout = go.Layout(
    title='Number of competitions with favorite team members ',
    font=dict(size=14),
    barmode='stack',
    width=800,
    height=500,
)

fig = go.Figure(data=traces, layout=layout)
py.iplot(fig, filename='stacked-bar')
# Out:
# <div>
#
#
#             <div id="1475f10b-894d-4ff4-bc6b-26fe8d4b91e8" class="plotly-graph-div" style="height:500px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("1475f10b-894d-4ff4-bc6b-26fe8d4b91e8")) {
#                     Plotly.newPlot(
#                         '1475f10b-894d-4ff4-bc6b-26fe8d4b91e8',
#                         [{"marker": {"color": "green"}, "showlegend": false, "type": "bar", "uid": "cb140327-7e04-4f52-af2a-983f48da89f7", "x": ["NxGTR", "Miha Skalic", "Dieter", "Andre Naef", "Silogram", "ryches", "Alexander Ryzhkov"], "y": [3, 3, 3, 2, 2, 2, 2]}],
#                         {"barmode": "stack", "font": {"size": 14}, "height": 500, "title": {"text": "Number of competitions with favorite team members "}, "width": 800},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('1475f10b-894d-4ff4-bc6b-26fe8d4b91e8');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# ## Kernels Journey

# %%
kernels_df = pd.read_csv("../input/Kernels.csv")
temp_df = kernels_df[kernels_df["AuthorUserId"]==user_id]
temp_df["MadePublicDate"] = pd.to_datetime(temp_df["MadePublicDate"], format="%m/%d/%Y")
temp_df["MadePublicYear"] = temp_df["MadePublicDate"].dt.year
temp_df.head()
# Out:
#          Id  AuthorUserId  CurrentKernelVersionId  ForkParentKernelVersionId  \
# 4706  18064        417337                 75825.0                    20180.0
# 5128  19193        417337                 83410.0                    81355.0
# 5195  19425        417337                 83431.0                    83366.0
# 5210  19455        417337                 86889.0                    83496.0
# 5291  19663        417337                 85149.0                    84690.0
#
#       ForumTopicId  FirstKernelVersionId         CreationDate EvaluationDate  \
# 4706           NaN               73611.0  09/24/2015 00:58:47     09/26/2015
# 5128       16921.0               82141.0  10/07/2015 16:18:19     10/09/2015
# 5195           NaN               83415.0  10/09/2015 14:56:12     10/09/2015
# 5210       16978.0               83651.0  10/10/2015 00:09:20     10/14/2015
# 5291           NaN               85149.0  10/12/2015 02:27:07     10/12/2015
#
#      MadePublicDate  IsProjectLanguageTemplate                 CurrentUrlSlug  \
# 4706     2015-09-24                      False                       pca-svm1
# 5128     2015-10-07                      False  h2o-starter-gbm-lr-015-cut-70
# 5195     2015-10-09                      False  agreement-correlation-and-roc
# 5210     2015-10-10                      False                gbm-inches-only
# 5291     2015-10-12                      False               ensemble-boost-3
#
#       Medal MedalAwardDate  TotalViews  TotalComments  TotalVotes  \
# 4706    NaN            NaN         494              0           2
# 5128    NaN            NaN        1517              4           2
# 5195    NaN            NaN         288              0           2
# 5210    3.0     07/15/2016        4644             12          10
# 5291    NaN            NaN         122              0           0
#
#       MadePublicYear
# 4706            2015
# 5128            2015
# 5195            2015
# 5210            2015
# 5291            2015

# %%
# Number of kernels
cnt_srs = temp_df["MadePublicYear"].value_counts()
traces = [bar_chart(cnt_srs, "blue")]
layout = go.Layout(
    title='Number of kernels in each year',
    font=dict(size=14),
    width=800,
    height=500,
)

fig = go.Figure(data=traces, layout=layout)
py.iplot(fig, filename='stacked-bar')


# Number of views
cnt_srs = temp_df.groupby("MadePublicYear")["TotalViews"].mean()
traces = [bar_chart(cnt_srs, "green")]
layout = go.Layout(
    title='Mean number of views per kernel',
    font=dict(size=14),
    width=800,
    height=500,
)

fig = go.Figure(data=traces, layout=layout)
py.iplot(fig, filename='stacked-bar')

# Number of votes
cnt_srs = temp_df.groupby("MadePublicYear")["TotalVotes"].mean()
traces = [bar_chart(cnt_srs, "red")]
layout = go.Layout(
    title='Mean number of votes per kernel',
    font=dict(size=14),
    width=800,
    height=500,
)

fig = go.Figure(data=traces, layout=layout)
py.iplot(fig, filename='stacked-bar')
# Out:
# <div>
#
#
#             <div id="a2f7ed52-bfa7-44e4-b1ae-b12964e3b53b" class="plotly-graph-div" style="height:500px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a2f7ed52-bfa7-44e4-b1ae-b12964e3b53b")) {
#                     Plotly.newPlot(
#                         'a2f7ed52-bfa7-44e4-b1ae-b12964e3b53b',
#                         [{"marker": {"color": "blue"}, "showlegend": false, "type": "bar", "uid": "c88b7e9f-9cb2-493c-b6d3-54483829dca0", "x": [2018, 2017, 2016, 2015, 2019], "y": [69, 53, 53, 20, 10]}],
#                         {"font": {"size": 14}, "height": 500, "title": {"text": "Number of kernels in each year"}, "width": 800},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('a2f7ed52-bfa7-44e4-b1ae-b12964e3b53b');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# <div>
#
#
#             <div id="1abb1773-9040-41c1-a4ae-397e570dcd1d" class="plotly-graph-div" style="height:500px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("1abb1773-9040-41c1-a4ae-397e570dcd1d")) {
#                     Plotly.newPlot(
#                         '1abb1773-9040-41c1-a4ae-397e570dcd1d',
#                         [{"marker": {"color": "green"}, "showlegend": false, "type": "bar", "uid": "9b9348bc-911e-4803-9e95-77b0e806b421", "x": [2015, 2016, 2017, 2018, 2019], "y": [656.5, 324.45283018867923, 1271.1509433962265, 2044.695652173913, 1421.1]}],
#                         {"font": {"size": 14}, "height": 500, "title": {"text": "Mean number of views per kernel"}, "width": 800},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('1abb1773-9040-41c1-a4ae-397e570dcd1d');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
# <div>
#
#
#             <div id="ca068c10-d0c6-436f-85d8-b416b5f64e08" class="plotly-graph-div" style="height:500px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ca068c10-d0c6-436f-85d8-b416b5f64e08")) {
#                     Plotly.newPlot(
#                         'ca068c10-d0c6-436f-85d8-b416b5f64e08',
#                         [{"marker": {"color": "red"}, "showlegend": false, "type": "bar", "uid": "10db2a9f-a535-49f8-b65b-b5999576f7eb", "x": [2015, 2016, 2017, 2018, 2019], "y": [1.0, 0.7735849056603774, 14.037735849056604, 28.014492753623188, 31.9]}],
#                         {"font": {"size": 14}, "height": 500, "title": {"text": "Mean number of votes per kernel"}, "width": 800},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('ca068c10-d0c6-436f-85d8-b416b5f64e08');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
cnt_df = temp_df.pivot_table(index="MadePublicYear", columns="Medal", values="AuthorUserId", aggfunc="count")
cnt_df = cnt_df.fillna(0)

def get_bar_chart(cnt_srs, name, color):
    trace = go.Bar(
        x=cnt_srs.index,
        y=cnt_srs.values,
        name=name,
        marker=dict(
            color=color,
        ),
    )
    return trace

medal_map = {1.:"Gold", 2.:"Silver", 3.:"Bronze"}
color_map = {1.:"gold", 2.:"silver", 3.:"darkorange"}
traces = []
for col in np.array(cnt_df.columns)[::-1]:
    cnt_srs = cnt_df[col]
    traces.append(get_bar_chart(cnt_srs, medal_map[col], color_map[col]))

layout = go.Layout(
    title='Kernel Medals in each year',
    font=dict(size=14),
    barmode='stack',
    width=800,
    height=500,
)

fig = go.Figure(data=traces, layout=layout)
py.iplot(fig, filename='stacked-bar')
# Out:
# <div>
#
#
#             <div id="388d4513-b53c-4fba-bbd7-4d709014cfa2" class="plotly-graph-div" style="height:500px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("388d4513-b53c-4fba-bbd7-4d709014cfa2")) {
#                     Plotly.newPlot(
#                         '388d4513-b53c-4fba-bbd7-4d709014cfa2',
#                         [{"marker": {"color": "darkorange"}, "name": "Bronze", "type": "bar", "uid": "0fbdd674-f311-481f-bb82-4961ebd1aec7", "x": [2015, 2016, 2017, 2018, 2019], "y": [1.0, 1.0, 14.0, 20.0, 4.0]}, {"marker": {"color": "silver"}, "name": "Silver", "type": "bar", "uid": "1b93c94d-1aff-4e92-abf2-677e2621a399", "x": [2015, 2016, 2017, 2018, 2019], "y": [0.0, 0.0, 7.0, 13.0, 4.0]}, {"marker": {"color": "gold"}, "name": "Gold", "type": "bar", "uid": "0efbc96b-4a70-4095-b195-0741b2a0dc17", "x": [2015, 2016, 2017, 2018, 2019], "y": [0.0, 0.0, 2.0, 6.0, 1.0]}],
#                         {"barmode": "stack", "font": {"size": 14}, "height": 500, "title": {"text": "Kernel Medals in each year"}, "width": 800},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('388d4513-b53c-4fba-bbd7-4d709014cfa2');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
temp_df = kernels_df[kernels_df["AuthorUserId"]==user_id]
kernel_tags_df = pd.read_csv("../input/KernelTags.csv")
temp_df = pd.merge(temp_df, kernel_tags_df, left_on="Id", right_on="KernelId", how="inner")
temp_df = pd.merge(temp_df, tags_df, left_on="TagId", right_on="Id", how="inner")

cnt_srs = temp_df["Name"].value_counts().head(10)
traces = [bar_chart(cnt_srs, "orange")]
layout = go.Layout(
    title='Tag count of the kernels',
    font=dict(size=14),
    barmode='stack',
    width=800,
    height=500,
)

fig = go.Figure(data=traces, layout=layout)
py.iplot(fig, filename='stacked-bar')
# Out:
# <div>
#
#
#             <div id="e3cff997-a44c-4a81-bf30-1928e45fa119" class="plotly-graph-div" style="height:500px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e3cff997-a44c-4a81-bf30-1928e45fa119")) {
#                     Plotly.newPlot(
#                         'e3cff997-a44c-4a81-bf30-1928e45fa119',
#                         [{"marker": {"color": "orange"}, "showlegend": false, "type": "bar", "uid": "903aa917-036f-44ed-9cae-4f708c49ac5e", "x": ["forecasting", "beginner", "eda", "time series", "deep learning"], "y": [1, 1, 1, 1, 1]}],
#                         {"barmode": "stack", "font": {"size": 14}, "height": 500, "title": {"text": "Tag count of the kernels"}, "width": 800},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('e3cff997-a44c-4a81-bf30-1928e45fa119');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# ## Discussion Journey

# %%
#temp_df = kernels_df[kernels_df["AuthorUserId"]==user_id]
forum_message_df = pd.read_csv("../input/ForumMessages.csv")
temp_df = forum_message_df[forum_message_df["PostUserId"]==user_id]
temp_df["PostDate"] = pd.to_datetime(temp_df["PostDate"], format="%m/%d/%Y %H:%M:%S")
temp_df["PostYear"] = temp_df["PostDate"].dt.year
temp_df.head()
# Out:
#            Id  ForumTopicId  PostUserId            PostDate  \
# 83346  103159         18107      417337 2015-12-29 15:05:08
# 84427  114177         20008      417337 2016-04-08 00:08:01
# 90992  117660         20446      417337 2016-04-30 02:25:02
# 91385  117730         20336      417337 2016-04-30 15:41:39
# 91421  117739         20336      417337 2016-04-30 16:23:29
#
#        ReplyToForumMessageId  \
# 83346                    NaN
# 84427                    NaN
# 90992                    NaN
# 91385                    NaN
# 91421                    NaN
#
#                                                  Message  Medal  \
# 83346  <p>[quote=Kele XU;102976]</p>\n\n<p>You can re...    NaN
# 84427  <p>Here is the link to the ResNet model that I...    3.0
# 90992  <p>[quote=Jonathan Chung;117581]</p>\n\n<p>An ...    NaN
# 91385  <p>[quote=SecondPlan;116753]</p>\n\n<p>Pre-tra...    NaN
# 91421  <p>Here is a good example of extracting featur...    2.0
#
#       MedalAwardDate  PostYear
# 83346            NaN      2015
# 84427     07/15/2016      2016
# 90992            NaN      2016
# 91385            NaN      2016
# 91421     07/15/2016      2016

# %%
# Number of kernels
cnt_srs = temp_df["PostYear"].value_counts()
traces = [bar_chart(cnt_srs, "blue")]
layout = go.Layout(
    title='Number of forum posts in each year',
    font=dict(size=14),
    width=800,
    height=500,
)

fig = go.Figure(data=traces, layout=layout)
py.iplot(fig, filename='stacked-bar')
# Out:
# <div>
#
#
#             <div id="065713d9-520c-43ad-8e82-19ae680102ae" class="plotly-graph-div" style="height:500px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("065713d9-520c-43ad-8e82-19ae680102ae")) {
#                     Plotly.newPlot(
#                         '065713d9-520c-43ad-8e82-19ae680102ae',
#                         [{"marker": {"color": "blue"}, "showlegend": false, "type": "bar", "uid": "d362fab2-1c40-4324-8e5b-7166d80bcb2b", "x": [2017, 2018, 2019, 2016, 2015], "y": [428, 422, 96, 62, 1]}],
#                         {"font": {"size": 14}, "height": 500, "title": {"text": "Number of forum posts in each year"}, "width": 800},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('065713d9-520c-43ad-8e82-19ae680102ae');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
cnt_df = temp_df.pivot_table(index="PostYear", columns="Medal", values="PostUserId", aggfunc="count")
cnt_df = cnt_df.fillna(0)

def get_bar_chart(cnt_srs, name, color):
    trace = go.Bar(
        x=cnt_srs.index,
        y=cnt_srs.values,
        name=name,
        marker=dict(
            color=color,
        ),
    )
    return trace

medal_map = {1.:"Gold", 2.:"Silver", 3.:"Bronze"}
color_map = {1.:"gold", 2.:"silver", 3.:"darkorange"}
traces = []
for col in np.array(cnt_df.columns)[::-1]:
    cnt_srs = cnt_df[col]
    traces.append(get_bar_chart(cnt_srs, medal_map[col], color_map[col]))

layout = go.Layout(
    title='Discussion Medals in each year',
    font=dict(size=14),
    barmode='stack',
    width=800,
    height=500,
)

fig = go.Figure(data=traces, layout=layout)
py.iplot(fig, filename='stacked-bar')
# Out:
# <div>
#
#
#             <div id="89683aec-0ea0-4ac8-add9-2f6d60b22a60" class="plotly-graph-div" style="height:500px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("89683aec-0ea0-4ac8-add9-2f6d60b22a60")) {
#                     Plotly.newPlot(
#                         '89683aec-0ea0-4ac8-add9-2f6d60b22a60',
#                         [{"marker": {"color": "darkorange"}, "name": "Bronze", "type": "bar", "uid": "583ef4e4-b5fa-40c5-bc19-29bbc4925f83", "x": [2016, 2017, 2018, 2019], "y": [25, 223, 210, 40]}, {"marker": {"color": "silver"}, "name": "Silver", "type": "bar", "uid": "cb88561b-7ff4-476d-8f6c-7c469e40651f", "x": [2016, 2017, 2018, 2019], "y": [5, 52, 46, 16]}, {"marker": {"color": "gold"}, "name": "Gold", "type": "bar", "uid": "422d9c03-0ed1-4dad-8906-a2987c3775f6", "x": [2016, 2017, 2018, 2019], "y": [1, 23, 40, 13]}],
#                         {"barmode": "stack", "font": {"size": 14}, "height": 500, "title": {"text": "Kernel Medals in each year"}, "width": 800},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('89683aec-0ea0-4ac8-add9-2f6d60b22a60');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
import re
def clean_string(txt):
    txt = str(txt)
    txt = re.sub("<.*?>", "", txt)
    txt = re.sub(' +', ' ', txt)
    return txt

temp_df["Message"] = temp_df["Message"].apply(lambda x: clean_string(x))
#temp_df.head()

from wordcloud import WordCloud, STOPWORDS

# Thanks : https://www.kaggle.com/aashita/word-clouds-of-various-shapes ##
def plot_wordcloud(text, mask=None, max_words=200, max_font_size=100, figure_size=(24.0,16.0), 
                   title = None, title_size=40, image_color=False):
    stopwords = set(STOPWORDS)
    more_stopwords = {'one', 'br', 'Po', 'th', 'sayi', 'fo', 'Unknown'}
    stopwords = stopwords.union(more_stopwords)

    wordcloud = WordCloud(background_color='black',
                    stopwords = stopwords,
                    max_words = max_words,
                    max_font_size = max_font_size, 
                    random_state = 42,
                    width=800, 
                    height=400,
                    mask = mask)
    wordcloud.generate(str(text))
    
    plt.figure(figsize=figure_size)
    if image_color:
        image_colors = ImageColorGenerator(mask);
        plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation="bilinear");
        plt.title(title, fontdict={'size': title_size,  
                                  'verticalalignment': 'bottom'})
    else:
        plt.imshow(wordcloud);
        plt.title(title, fontdict={'size': title_size, 'color': 'black', 
                                  'verticalalignment': 'bottom'})
    plt.axis('off');
    plt.tight_layout()  
    
plot_wordcloud(temp_df["Message"], title="Word Cloud of the common words in forum messages")

# %% [markdown]
# ### More to come. Stay tuned!
#
# Some of the ideas are
# * Kagglers who upvote your kernels
# * Kagglers who upvote your forum posts
# * Number of followers over time
