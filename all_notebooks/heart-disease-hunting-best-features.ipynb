# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# Importing basic libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Read data as ususal whatever you have done previously ryt ;p

# %%
main_data=pd.read_csv('/kaggle/input/heart-disease-uci/heart.csv')
main_data.head()

# %%
target=main_data['target']
data=main_data.drop(['target'],axis=1)

data.head()

# %%
target.head()

# %% [markdown]
# How feature importances are taken using Extra Trees classifier is given in an awesome geeksforgeeks post mentioned in README

# %%
from sklearn.ensemble import ExtraTreesClassifier

model=ExtraTreesClassifier(n_estimators=100)
model.fit(data,target)
k=model.feature_importances_
print(k)

# %%
indic=np.argmax(k)
indic

# %%
data.columns[indic]

# %%
data.columns

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.bar(np.arange(len(k)),k,align='center',alpha=0.5)
plt.xticks([i for i in range(len(data.columns))],data.columns)
plt.show()

# %%
new_k=sorted(k,reverse=True)
top3_features=new_k[:6]
top3_features

# %%
for i in top3_features:
    indx=np.where(k==i)
    print(data.columns[indx])

# %%
import seaborn as sns
imp = pd.Series(k, index=data.columns).sort_values(ascending=False)
sns.barplot(y=imp.index, x=imp.values, palette="Blues_d", orient='h')

# %% [markdown]
# From all these we can see that cp is the most important in determining heart disease perfectly among the whole data bunch
