# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
data= pd.read_csv('/kaggle/input/health-insurance-cross-sell-prediction/train.csv')
data.head()

# %%
df = pd.DataFrame(data)
df

# %%
# Note here df.columns is of type -> object here we are converting it into list inorder to print the data 
list(df.columns)

# %%
df.dtypes

# %%
# check for any NULL's 
# as there are not many nulls we can proceed for MODELLING 
df.isna().any()

# %%
# slicing the data frame into sub dataframe
first_slice = df[['Annual_Premium','Age','Gender','Region_Code']]
first_slice

# %%
# Mean Age of the persons in the Dataset.
first_slice['Age'].mean()

# %%
# Average of Annual Premium, Age, Region_Code

first_slice[[i for i in first_slice.columns if (first_slice[i].dtype != 'O')]].mean()

# %%
# List out all the Columns Average which are not of Type Objects
# Because there is no point of having averages for string type values.
# Cause it is trivial.

df = df[[i for i in df.columns if df[i].dtype != 'O']]
print(df.mean())

# %%
# R: Count the number of people who doesn't have Driving license But has taken Insurance Previously.

len(df[(df['Driving_License']==0) & (df['Previously_Insured'] == 1)])
# there are 241 people who dont have driving license,and has a premium Health insurance.

# %%
# R: Count the number of people who doesn't have both Driving license, and Insurance.

len(df[(df['Driving_License']==0) & (df['Previously_Insured']==0)])
# there are 571 people who dont have driving license, and also doesn't has a premium Health insurance.

# %%
# R: Count the number of people who has both driving license,and insurance
len(df[(df['Driving_License']==1) & (df['Previously_Insured']==1)])
# there are 174387 people who have driving license and health insurance.

# %%
# lists the maximum value for their respective columns.
df.max()

# %%
# R: Print out the minimum value for their respective columns
df.min()

# %%
# R: Print the Record with the Maximum Annual Premium.
max_premium = df.loc[df['Annual_Premium'].idxmax()]
print(max_premium)
df.iloc[int(max_premium['id'])].plot(kind = 'bar')

# R: Print the Record with the Minimum Annual Premium.
min_premium = df.loc[df['Annual_Premium'].idxmin()]
print(min_premium)
#df.iloc[int(min_premium['id'])].plot(kind = 'area')

# %%
# Find the max value record in the pandas and print only the age.
print(f'Age of person who pays the maximum Annual Premium ',df.loc[df['Annual_Premium'].idxmax()]['Age'])
# Find the max Value record in the dataframe and print only the Policy sales channel
print(f'Policy Sales Channel of the person who pays Max Annual Premium ',df.loc[df['Annual_Premium'].idxmax()]['Policy_Sales_Channel'])

# %%
# What is the percentage of total people who has previously insured.
x= (len(df[df['Previously_Insured']==1])/len(df))*100
print(f'Insured Percentage is: ',x)
print(f'uninsured percentage is: ',100-x)

# %%
# How many Sales channels are there in the data set?
k =1
for i in sorted(df['Policy_Sales_Channel'].unique()):
          k+=1
if len(set(df['Policy_Sales_Channel'].unique())) == len(df['Policy_Sales_Channel'].unique()):
          print("Validated")
          print(len(df['Policy_Sales_Channel'].unique()))
        
len(df['Policy_Sales_Channel'].unique())

# %%
# Capture the Age  Distribution of the Users in the Dataset.
# This is the sample code for the users in the age 20 and 30.

print(len(df[(df['Age'] >= 20)& (df['Age']<30)]))


x =20
res = []
for i in range(30,110,10):
              res.append(len(df[(df['Age'] >= x)&(df['Age'] < i)]))
              x = i
print(res)

# %%
# Plot the Data of the "Age" using KDE "Kernel Density Estimation!"
age = df['Age']
age.plot.kde(color = 'g')#,ind = [10,20,30,40,50,60,70,80,90])
# we can also send our own parameters like ind "which is an index that we pass to the graph".
# try to uncomment the ind and remove paranthesis and run the code the plot distribution changes.

# %%
annual = df['Annual_Premium']
annual.plot.kde(color = 'r')

# %%
# Find the Insurance Premium Annual interval Based on the Price with 5000 increment.
maxi = -float('inf')
k= 0
res= []
for i in range(0,600000,5000):
                 x =len(df[df['Annual_Premium'] < i])
                 if (x > maxi): 
                    res.append((i,x))
                    k+=1

for i in range(0,len(res)):
    if i==0:
              print(f'no of Premium payers with amount b/w ',res[i][0],'and',res[i][0],'is ',res[i][1])
    elif res[i][1] != len(df):
              print(f'no of Premium payers with amount b/w ',res[i][0]-5000,'and',res[i][0]-1,'is ',res[i][1])
    else:
              print(f'no of Premium payers with amount b/w ',res[i][0]-5000,'and',res[i][0]-1,'is ',res[i][1])
              break

# %%
print(len(df[df['Annual_Premium'] < 10000]))
