# %% [markdown]
# # **Lecture 6 LIU Yifeng 19M58481**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
np.set_printoptions(threshold=np.inf)

selected_country = 'South Korea'
cv = pd.read_csv('../input/novel-corona-virus-2019-dataset/covid_19_data.csv', header=0)
#print(cv.columns)
cv = cv[cv['Country/Region']==selected_country]
cv = cv.groupby('ObservationDate').sum()
print(cv)

# %%
cv['Daily_confirmed'] = cv['Confirmed'].diff()
cv['Daily_deaths'] = cv['Deaths'].diff()
cv['Daily_recovered'] = cv['Recovered'].diff()
cv['Daily_confirmed'].plot()
cv['Daily_recovered'].plot()
plt.show()

# %%
from plotly.offline import iplot
import plotly.graph_objs as go

Daily_confirmed_object = go.Scatter(x=cv.index, y=cv['Daily_confirmed'].values, name='Daily_confirmed')
Daily_death_object = go.Scatter(x=cv.index, y=cv['Daily_deaths'].values, name='Daily_deaths')

layout_object = go.Layout(title='South Korea daily cases 19M58481', xaxis=dict(title='Date'), yaxis=dict(title='Number of People'))
fig = go.Figure(data=[Daily_confirmed_object, Daily_death_object], layout=layout_object)
iplot(fig)

# %% [markdown]
# We can see that 03/03 had the largest daily cases, which is 851 people per day. In April, it had been decreased to a very low level, which was about 2 people per day, but from May, there was a secondary rebound, daily cases increased to 50 people per day, so the situation is not clear yet now.

# %%
cv1 = cv
cv1 = cv1.fillna(0.)


styled_object1 = cv1.style.background_gradient(cmap='gist_ncar').highlight_max('Daily_confirmed').set_caption('Daily Summaries')
display(styled_object1)

# %%
cv = pd.read_csv('../input/novel-corona-virus-2019-dataset/covid_19_data.csv')

date_rank = cv
date_rank = date_rank.groupby('Country/Region').sum()
date_rank = date_rank.sort_values(by='Confirmed',ascending=False).reset_index()

print('Ranking of South Korea: ', date_rank[date_rank['Country/Region']=='South Korea'].index.values[0]+1)

# %% [markdown]
# Measure:
# **1. Testing, testing and testing**
# Experts interviewed by the World Health Organization and the BBC agreed that detecting cases as early as possible through testing is the fundamental means of controlling the epidemic. (As of March) South Korea has tested more than 10,000 people every day.
# **2. Close public area**
# The public facilities such as museums and art galleries will be temporarily closed. It is recommended to suspend the operation of cram schools, Internet cafes, and singing rooms.
# **3. Information transparency and publicity**
# Information transparency and publicity help alleviate people’s fears and prevent widespread panic.The South Korean government has continuously carried out large-scale publicity activities on personal hygiene and social alienation, holding two press conferences every day, continuously updating online information, and sending outbreak-related text messages to the public.Coupled with a wide range of testing and publicity, people's fears and misunderstandings have been reduced or reduced to the greatest extent.
