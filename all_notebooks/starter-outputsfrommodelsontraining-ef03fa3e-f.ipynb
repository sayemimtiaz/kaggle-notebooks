# %% [markdown]
# this data set contains outputs from serval models run on the reduced jane street data set https://www.kaggle.com/jamespett/notebook857ba5a22d
# the first model consists of https://www.kaggle.com/a763337092/mlp012003weights outputs from the first 4 models with 4 fold cross validation used, followed by the first three models from https://www.kaggle.com/jamespett/models
# the second data set contains outputs of https://www.kaggle.com/code1110/jane-street-with-keras-nn-overfit model.
