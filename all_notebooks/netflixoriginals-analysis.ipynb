# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('default')
# %matplotlib inline

# %%
file=pd.read_csv(r"../input/netflixoriginals/NetflixOriginals.csv")
file.head(15)

# %%
file.info()

# %%
#Checking for null
file.isnull().sum()

# %%
#reading the column
file['Title']

# %%
#Converting premiere to date
file['Premiere']= pd.to_datetime(file['Premiere'])

# %%
file.head(1)

# %%
sns.pairplot(file)

# %%
file1=file.head(10)
plt.figure(figsize=(10,5))
sns.lineplot(x='Runtime',y='IMDB Score',data=file1,ci='None')

# %%
sns.scatterplot(x='Runtime',y='Title',data=file)
