# %% [markdown]
# # Classifying News Headlines and Explaining the Result

# %% [markdown]
# Data is from Kaggle's [News Aggregator Dataset](https://www.kaggle.com/uciml/news-aggregator-dataset)

# %%
import pandas as pd

# %% [markdown]
# I sampled 10% of the data to speed up the analysis.

# %%
news = pd.read_csv('../input/uci-news-aggregator.csv').sample(frac=0.1)

# %%
len(news)

# %%
news.head(3)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
X = news['TITLE']
y = encoder.fit_transform(news['CATEGORY'])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# We count the number of occurences of each word and use it as our features.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vectorizer = CountVectorizer(min_df=3)

# %%
train_vectors = vectorizer.fit_transform(X_train)
test_vectors = vectorizer.transform(X_test)

train_vectors

# %% [markdown]
# We use a random forest for classification.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=20)
rf.fit(train_vectors, y_train)

# %%
from sklearn.metrics import accuracy_score

# %%
pred = rf.predict(test_vectors)
accuracy_score(y_test, pred, )

# %% [markdown]
# 85% accuracy, not a bad score.

# %% [markdown]
# ## Explaining the result

# %% [markdown]
# We need lime to explain the model. Unfortunately, Kaggle doesn't have lime installed. You can view the rest of the notebook [here](http://nbviewer.jupyter.org/github/dreamgonfly/lime-examples/blob/master/Classifying%20News%20Headlines%20and%20Explaining%20the%20Result.ipynb)
