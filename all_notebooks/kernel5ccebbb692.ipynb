# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report,accuracy_score

# %%
#load the data and tske the outcome as the output and check for empty cells 
df = pd.read_csv('../input/docspot/datasets_228_482_diabetes.csv')
y = df["Outcome"]
df = df.drop(["Outcome"], axis = 1)
df.isnull().sum()

# %%
# the values og Glucose content, BP, SkinThickness, Insulin and BMI cannot be zero so we replace the  zero values with suitable values i.e. with the mean values of the columns.
df['Glucose']=np.where(df['Glucose']==0,df['Glucose'].mean(),df['Glucose'])
df['BloodPressure']=np.where(df['BloodPressure']==0,df['BloodPressure'].mean(),df['BloodPressure'])
df['SkinThickness']=np.where(df['SkinThickness']==0,df['SkinThickness'].median(),df['SkinThickness'])
df['Insulin']=np.where(df['Insulin']==0,df['Insulin'].median(),df['Insulin'])
df['BMI']=np.where(df['BMI']==0,df['BMI'].mean(),df['BMI'])

# %%
#split data into test and split data
x_train, x_test, y_train, y_test = train_test_split(
    df, y, test_size=0.25, random_state=0)

# %%
#classifier model with various tuning to give max accuracy score 
model=GradientBoostingClassifier(n_estimators=1000,
                             max_features='sqrt',min_samples_leaf=4,random_state=0).fit(x_train,y_train)
y_t=model.predict(x_test)
print(accuracy_score(y_test,y_t))
print(classification_report(y_test,y_t))

# %%
model?

# %%
knn?

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train, y_train)

# %%
y_t = lr.predict(x_test)

# %%
round(lr.score(x_test, y_test), 2)
