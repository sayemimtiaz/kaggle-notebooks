# %% [markdown]
# # Before importing Fastai v1.x
# ***Important***
#
# > ***Before the code please add the data [fastaiv1](https://www.kaggle.com/robertlangdonvinci/fastaiv1) to the input file.***

# %% [markdown]
# This notebook is for those offline Competition which cannot use `!pip install fastai==1.x`
#
# A big thanks to [RobertLangdonVinci](https://www.kaggle.com/robertlangdonvinci) for upload this data

# %% [markdown]
# # Default Fastai version in kaggle
# version=='**2.0.19**' as in 22/11/2020

# %%
import fastai
fastai.__version__

# %% [markdown]
# # To import Fastai v1

# %%
# %cd /kaggle/input
from fastaiv1 import fastai
# %cd /kaggle/

# %%
fastai.__version__

# %% [markdown]
# # Importing fastai.vision version 1.x

# %%
# %cd /kaggle/input
from fastaiv1.fastai.vision import *
# %cd /kaggle/

# %%
vision.__version__
