# %% [markdown]
# **If you find this kernel useful, UPVOTE¶
# **

# %% [markdown]
# This data set contains the following:
# * 'Daily Time Spent on Site': time Spend by the consumer on site(minutes).
# * 'Age': age of cumtomer (years).
# * 'Area Income': Avg. Income of geographical area of consumer
# * 'Daily Internet Usage': Avg. minutes a day consumer is on the internet
# * 'Ad Topic Line': Headline Topic of the advertisement
# * 'City': consumer's city
# * 'Male': Catogerical male Column
# * 'Country': Country of consumer
# * 'Timestamp': Time at which consumer clicked on Ad or closed window
# * 'Clicked on Ad': 0 or 1 indicated weather Ad was clicked or not

# %% [markdown]
# **Inspiration**
# Explore the data to find predict who is more likely to click the add!

# %% [markdown]
# As it is Classification Problem we will use ***Logistic Regression***

# %% [markdown]
# Importing required libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt # graphical representation
import seaborn as sns
# %matplotlib inline

# %%
# Getting the data
# Reading the data as df
ad_data = pd.read_csv("/kaggle/input/advertising/advertising.csv")
ad_data.head()

# %%
# data description
ad_data.info()
# no null values

# %%
# Statical Description
ad_data.describe()

# %% [markdown]
# # Exploratory Data Analysis(E.D.A)
# Using Seaborn

# %%
# Age Distribution using histogram
ad_data['Age'].hist(bins=35)

# %%
# Area income as per age
sns.jointplot(x= 'Age',y = 'Area Income',data=ad_data)

# %%
# Daily time spend on website as per age

sns.jointplot(x='Age',y='Daily Time Spent on Site', data= ad_data, kind = 'kde', color ='red')

# %%
# Joint plot for daily time spend and daily internet use

sns.jointplot(x='Daily Time Spent on Site',y='Daily Internet Usage',data = ad_data )
# seems like formation of cluster

# %%
# Pair plot for the whole data set based on y(clicked on ad)
sns.pairplot(ad_data, hue= 'Clicked on Ad')

# %% [markdown]
# # [Logistic Regression](http://https://en.wikipedia.org/wiki/Logistic_regression)

# %% [markdown]
# **Feature engineering**: Choosing feature which makes sense to our output

# %%
#from sklearn.model_selection import train_test_split
ad_data.columns

# %%
# Selecting x and y 
# x is usually the input and y is output
y = ad_data['Clicked on Ad']

# need to remove string data 
x = ad_data[['Daily Time Spent on Site', 'Age', 'Area Income','Daily Internet Usage', 'Male']]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=101)

# %% [markdown]
# **Train and fit Logistic Regression Model on the training set**

# %%
from sklearn.linear_model import LogisticRegression
logit = LogisticRegression()

# %%
# Fitting Logistic regression on our training data
logit.fit(x_train,y_train)

# %% [markdown]
# # **Predicting and Evoluating our Model**
# Let's Predict values for our Test Data

# %%
ad_pred = logit.predict(x_test)

# %%
# Creating a Classification report
from sklearn.metrics import classification_report
print(classification_report(y_test,ad_pred))
# 93% accuracy

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,ad_pred))

# %% [markdown]
# # ** Over & Out**
# Don't forget to **UPVOTE**
