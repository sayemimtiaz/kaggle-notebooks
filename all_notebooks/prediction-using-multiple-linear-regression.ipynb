# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

### Importing the libraries ### 
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt 
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12.0 , 9.0)

# %%
### Importing The Dataset ### 
dataset = pd.read_csv('../input/50-startups/50_Startups.csv')
dataset.head()

# %%
##Creating matrix of features
x = dataset.iloc[ : , : -1].values
## Creating Dependent Variable vector
y = dataset.iloc[ : , -1].values

# %%
x

# %%
y

# %%
### Encoding Categorical Data #### 

## Encoding the independent variable
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers = [('encoder' , OneHotEncoder() , [3])], remainder = 'passthrough')
x = np.array(ct.fit_transform(x))

# %%
x

# %%
### Spliting the dataset into the Training Set and Test Set ###
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2 , random_state = 1)

# %%
### Feature Scaling ###
from sklearn.preprocessing import StandardScaler
ssc = StandardScaler()
x_train[ : , 3: ] = ssc.fit_transform(x_train[ : , 3: ])
x_test[ : , 3: ] = ssc.fit_transform(x_test[ : , 3: ])

# %%
x_train

# %%
x_test

# %%
y_train

# %%
y_test

# %%
### Training the Multiple linear Regression Model on the training set ###
from sklearn.linear_model import LinearRegression
mlr = LinearRegression()
mlr.fit(x_train , y_train)

# %%
### Predicting the test set results ###
y_pred = mlr.predict(x_test)
np.set_printoptions(precision= 3)
y_pred

# %%
print(np.concatenate((y_pred.reshape(len(y_pred) , 1) , y_test.reshape(len(y_test),1)) , 1))

# %%
### Making a Single Prediction ###
#ex (R&D Spend = 28754.33, Administration Spend = 118546.05 , Marketing Spend = 172795.67 and State = 'California')
print(mlr.predict([[1.0, 0.0, 0.0, -0.6028815991418002, 0.29723825358317, -0.36470435652588457]]))

# %%
### Getting the final linear regression equation with the values of the coefficients ###

# In this case hypothesis equation , h = b0x0 + b1x1 + b2x2 + b3x3 + b4x4
# where x0 = State , x1 = R&D Spend , x2 = Administration , x3 = Marketing Spend , x4 = 1 and b4 = intercept
print(mlr.coef_)

# %%
print(mlr.intercept_)
