# %% [markdown]
# ## Merging and Reshaping Exercises: SF Bike Share
#
# The following exercises were created as a lab for the Python class I am teaching. It contains applications of `.merge(), .pivot(), .melt()` and related methods. (For teaching purposes, solutions are not provided.)
#
# Update 2019/11/12 11:10pm: There is currently some loading error for the original [SF Bay Area Bike Share](https://www.kaggle.com/benhamner/sf-bay-area-bike-share) dataset, so a temporary dataset (consisting of 2 csv files) is provided.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %% [markdown]
# ## Overview
#
# There are 70 stations in the San Francisco Bay Area bike share system, located across 5 cities.
#
# The goal of this lab is to create two tables that summarize the number of trips between locations:
#
# **Table 1** is a 70x70 table that displays the total number of trips between every pair of stations.
#
# **Table 2** is a 5x5 table that displays the total number of trips between every pair of cities.
#
# We will create these tables using a combination of `.groupby(), .pivot(), .melt(), .merge()`, as well as other methods for cleaning up the aesthetics.
#
# ## Data
#
# Load the following files and display the first few rows:
#
# - `.../trip.csv`: This file contains details for individual trips, including the `start_station_id` and `end_station_id`.
#
# - `.../station.csv`: This file contains the details for each station, including the `id` and the `city`.

# %% [markdown]
# ## 1. Summarize trips for each pair of stations using `.groupby()`
#
# Hint 1: After the split-apply-combine operation, use `.reset_index()` to convert the grouped multi-index back into columns.
#
# Hint 2: Use `.rename(columns={...})` to rename the trip count column.

# %% [markdown]
# ## 2. Reshape the previous DataFrame into wide format with `.pivot()`
#
# This is creates **Table 1: Number of trips between stations**.
#
# Hint: After pivoting, use `.fillna(0)` to replace missing values with 0.

# %% [markdown]
# ## 3. Reshape the previous DataFrame into long format with `.melt()`
#
# The results should look similar to that of Problem 1 except that there are more rows (why?).

# %% [markdown]
# ## 4. Merge the previous DataFrame with the city of each station using `.merge()`
#
# Hint: Check intermediate results to see where the suffixes `_x` and `_y` come from.

# %% [markdown]
# ## 5. Summarize and reshape the previous DataFrame.
#
# This creates **Table 2: Number of trips between cities**.
#
# Hint: This is similar to Steps 1 and 2.

# %% [markdown]
# What does this table tell us about the marginal benefit of having a unified bike share system across cities (as opposed to each city having its own system)?
