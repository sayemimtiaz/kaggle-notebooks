# %% [markdown]
# # *Veri setimizde kalp hastalığı olup olmadığını tespit edebilmek için oluşturulmuştur. *

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# *Veri Setimizi alıyoruz*

# %%
df= pd.read_csv('/kaggle/input/heart-disease-uci/heart.csv')

# %% [markdown]
# ***Burada verimizdeki ilk 5 satırı gösteriyoruz***

# %%
df.head()

# %% [markdown]
# **Veri seti hakkında bilgi alıyoruz**

# %%
df.info()

# %% [markdown]
# **Veri setimizde 303 adet satır(veri) var **
# **14 adette sütunumuz var **
# Veri setindeki sütunlar
# * yaş
# * seks
# * göğüs ağrısı tipi (4 değer)
# * dinlenme kan basıncı
# * mg / dl olarak serum kolestoral
# * açlık kan şekeri> 120 mg / dl
# * dinlenme elektrokardiyografik sonuçları (değerler 0,1,2)
# * elde edilen maksimum kalp atış hızı
# * egzersize bağlı anjina
# * oldpeak = egzersize göre egzersize bağlı ST depresyonu
# * pik egzersiz ST segmentinin eğimi
# * floroskopi ile renklendirilmiş büyük damar (0-3) sayısı
# * thal: 3 = normal; 6 = sabit kusur; 7 = tersinir kusur

# %%
df.corr()

# %% [markdown]
# # Verimize koralasyon yaparak sütunlar arasındaki ilişkiye bakıyoruz

# %%
f,ax =plt.subplots(figsize=(18,18))
sns.heatmap(df.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %%
df.columns

# %%
#plot
df.oldpeak.plot(kind='line', color='g', label ='oldpeak',linewidth=1, alpha=0.5,grid=True,linestyle=':')
df.age.plot(color='r', label ='age',linewidth=1, alpha=0.5,grid=True,linestyle='-.')
plt.legend(loc='upper right')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Line Plot')
plt.show()

# %%
# x=age , y=target
df.plot(kind='scatter', x='age', y='target', alpha=0.1, color='g',grid=True)
plt.xlabel('age')
plt.ylabel('target')

plt.show()

# %%
#Histogram
#bins = number of bar in figure
df.age.plot(kind='hist', bins=50,figsize=(12,12),grid=True)
plt.show()

# %% [markdown]
# # Yaşı 40 dan büyük olanları yazdırdık

# %%
# Filtering pandas data frame
x=df['age']>40   
df[x]

# %% [markdown]
# # Yaşı 40 dan büyük olanlar ve target bölümü 1 olanlar

# %%
x=(df['age']>40)& (df['target']== 1)  
df[x]

# %% [markdown]
# (1 = erkek; 0 = kadın)
# * sadece erkekleri veren bir liste

# %%
male=df['sex'] == 1
df[male]

# %% [markdown]
# **Yaşı 50 ila 55 arasında kadınları listeliyoruz**

# %%
data=(df['age']<=55) & (df['age']>=50) & (df['sex'] == 0) 
df[data]
