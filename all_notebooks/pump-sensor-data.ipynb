# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
data = pd.read_csv('/kaggle/input/pump-sensor-data/sensor.csv',parse_dates=[1],index_col = [1])
data.head()

# %%
data.info()

# %%
data.index

# %%
data.isnull().sum()

# %%
data.duplicated().sum()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
sns.set_theme(style="whitegrid")

import sys

if not sys.warnoptions:
    warnings.simplefilter("ignore")

# %matplotlib inline

# %%
fig,ax = plt.subplots(figsize = (15,15))
new_data = data.drop(['machine_status'],axis = 1)
sns.heatmap(new_data.isnull(),cbar = False)

# %%
new_data.columns

# %%
data = data.drop(['sensor_15','Unnamed: 0'],axis = 1)

# %%
data.shape

# %%
data.columns

# %%
data.describe().T

# %%
new_data = data

# %%
data.corr()

# %%
data['machine_status'].nunique()

# %%
data['machine_status'].unique()

# %%
new_data['machine_status'].replace({'NORMAL' : 0,'BROKEN' : 1,'RECOVERING' : 2},inplace = True)

# %%
new_data['machine_status']

# %%
corr = new_data.corr()['machine_status']

# %%
val = corr.abs().sort_values(ascending=False)

# %%
val.to_dict()

# %%
new_list = ['sensor_04','sensor_10','sensor_11','sensor_00','sensor_02','sensor_06','sensor_12','sensor_50','sensor_07','sensor_01','sensor_03','sensor_08','sensor_09','sensor_05','sensor_40','sensor_48','sensor_38','sensor_49','sensor_13','sensor_47','sensor_44']

# %%
len(new_list)

# %%
new_data.var().sort_values(ascending = False)

# %%
data.skew().sort_values(ascending = False)

# %%
data.std().sort_values(ascending = False)

# %%
new_data = new_data[new_list]

# %%
new_data.head(5)

# %%
data = new_data

# %%
data.head(5)

# %%
data.isnull().sum().sort_values(ascending = False)

# %%
data['sensor_50'].describe().T

# %%
data['sensor_50'].nunique()

# %%
data['sensor_50'].median()

# %%
fig,ax = plt.subplots(figsize = (15,15))
sns.countplot(x = data['sensor_50'].head(20),data = data)

# %%
sns.distplot(a = data['sensor_50'])

# %% [markdown]
# # The thumb rule is :
#
# If the skewness is between -0.5 to +0.5 then we can say data is fairly symmetrical. If the skewness is between -1 to -0.5 or 0.5 to 1 then data is moderately skewed.
#
# And if the skewness is less than -1 and greater than +1 then our data is heavily skewed.

# %%
data['sensor_50'].skew()

# %%
data['sensor_50'].fillna((data['sensor_50'].mean()),inplace = True)

# %%
data['sensor_50'].isnull().sum()

# %%
sns.distplot(a = data['sensor_50'])

# %%
fig,ax = plt.subplots(figsize = (15,15))
sns.boxplot(x = data['sensor_50'])

# %%
def std_based(col_name,df):
    mean = df[col_name].mean()
    std = df[col_name].std()
    cut_off = std * 3
    lower, upper = mean - cut_off, mean + cut_off
    new_df = df[(df[col_name] < upper) & (df[col_name] > lower)]
    return new_df

# %%
data = std_based('sensor_50',data)

# %%
data.sensor_50.shape

# %%
fig,ax = plt.subplots(figsize = (15,15))
sns.boxplot(x = data['sensor_50'])

# %%
data = std_based('sensor_50',data)

# %%
data.sensor_50.shape

# %%
fig,ax = plt.subplots(figsize = (15,15))
sns.boxplot(x = data['sensor_50'])

# %%
data.sensor_50.std()

# %%
count = 0
for i in data.sensor_50:
  if i > (3 * data.sensor_50.std()): 
    count += 1

print(count)

# %%
data = std_based('sensor_50',data)

# %%
data.sensor_50.shape

# %%
fig,ax = plt.subplots(figsize = (15,15))
sns.boxplot(x = data['sensor_50'])

# %%
data.shape
