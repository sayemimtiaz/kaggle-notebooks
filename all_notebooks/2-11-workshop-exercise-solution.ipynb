# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Add data to your notebook on the right sight beneath the 'Save Version' button --> we want to work with a dataset called 'ramen ratings'
# Load your data into a pandas DataFrame --> You can copy the path by clicking next to the csv file on the right side

df = pd.read_csv('../input/ramen-ratings/ramen-ratings.csv', index_col=0)

# print out the first 5 rows of the dataset
df.head()

# Make sure the your index is set correctly by the review number  (you can select the row for pandas to use as your index in the function read_csv)

# %%
# use the describe function to get an overview of the whole DataFrame
df.describe()

# %%
# Use the describe function for the column 'Stars' 
# You might get an error or an unwanted result. What could have gone wrong?
df.Stars.describe()

# %%
# Convert the column 'Stars' from object to float
# You might need to replace unwanted text e.g. with 'np.nan'
df.Stars[df.Stars=='Unrated'] = np.nan
df.Stars = df.Stars.astype(float)

# Use the describe function for the column 'Stars' 
df.Stars.describe()

# %%
plt.figure(figsize=(14,7))
# Create a boxplot with 'Style' as x axis and 'Stars' as y axis
sns.barplot(data=df, x="Style", y="Stars")
