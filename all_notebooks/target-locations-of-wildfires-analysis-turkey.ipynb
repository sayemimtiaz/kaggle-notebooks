# %%
# !pip install dataprep by

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from warnings import filterwarnings
from mpl_toolkits.mplot3d import Axes3D
import statsmodels.api as sm
import missingno as msno
import statsmodels.stats.api as sms
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.neighbors import LocalOutlierFactor
from scipy.stats import levene
from scipy.stats import shapiro
from scipy.stats.stats import pearsonr
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from sklearn.preprocessing import scale
from sklearn.model_selection import ShuffleSplit, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import model_selection
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import BaggingRegressor
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LinearRegression
from sklearn.cross_decomposition import PLSRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import LassoCV
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import ElasticNetCV
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
import xgboost as xgb
from xgboost import XGBRegressor, XGBClassifier
from lightgbm import LGBMRegressor, LGBMClassifier
from catboost import CatBoostRegressor, CatBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn import tree
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, roc_auc_score, roc_curve
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans
from sklearn.pipeline import Pipeline
from sklearn.manifold import Isomap,TSNE
from sklearn.feature_selection import mutual_info_classif
from tqdm.notebook import tqdm
from scipy.stats import ttest_ind
import plotly.offline as pyo
import scipy.stats as stats
import pymc3 as pm
from dataprep.eda import *
from dataprep.eda import plot
from dataprep.eda import plot_diff
from dataprep.eda import plot_correlation
from dataprep.eda import plot_missing
import plotly.figure_factory as ff
from collections import Counter
import pandas_profiling as pp
from mpl_toolkits.basemap import Basemap
import datetime as dt
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import folium
from folium import plugins

filterwarnings("ignore", category=DeprecationWarning) 
filterwarnings("ignore", category=FutureWarning) 
filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# # DATA PROCESS

# %% [markdown]
# ### MAIN READING

# %% [markdown]
# #### LOCAL CSV

# %%
LOC_1_READING = pd.read_csv("../input/target-locations-of-wildfires-turkey/TARGET_LOCATIONS_OF_WILDFIRES/2000-2021/LOC_1 - fire_archive_M-C61_214692.csv",low_memory=False)
LOC_2_READING = pd.read_csv("../input/target-locations-of-wildfires-turkey/TARGET_LOCATIONS_OF_WILDFIRES/2000-2021/LOC_2 - fire_archive_M-C61_214695.csv",low_memory=False)
LOC_3_READING = pd.read_csv("../input/target-locations-of-wildfires-turkey/TARGET_LOCATIONS_OF_WILDFIRES/2000-2021/LOC_3 - fire_archive_M-C61_214696.csv",low_memory=False)
LOC_4_READING = pd.read_csv("../input/target-locations-of-wildfires-turkey/TARGET_LOCATIONS_OF_WILDFIRES/2000-2021/LOC_4 - fire_archive_M-C61_214697.csv",low_memory=False)
LOC_5_READING = pd.read_csv("../input/target-locations-of-wildfires-turkey/TARGET_LOCATIONS_OF_WILDFIRES/2000-2021/LOC_5 - fire_archive_M-C61_214698.csv",low_memory=False)
LOC_6_READING = pd.read_csv("../input/target-locations-of-wildfires-turkey/TARGET_LOCATIONS_OF_WILDFIRES/2000-2021/LOC_6 - fire_archive_M-C61_214699.csv",low_memory=False)
LOC_7_READING = pd.read_csv("../input/target-locations-of-wildfires-turkey/TARGET_LOCATIONS_OF_WILDFIRES/2000-2021/LOC_7 - fire_archive_M-C61_214701.csv",low_memory=False)
LOC_8_READING = pd.read_csv("../input/target-locations-of-wildfires-turkey/TARGET_LOCATIONS_OF_WILDFIRES/2000-2021/LOC_8 - fire_archive_M-C61_214702.csv",low_memory=False)

# %%
TYPE_ZERO_LOC_1 = LOC_1_READING[LOC_1_READING["type"] == 0]
TYPE_ZERO_LOC_1.reset_index(drop=True,inplace=True)

TYPE_ZERO_LOC_2 = LOC_2_READING[LOC_2_READING["type"] == 0]
TYPE_ZERO_LOC_2.reset_index(drop=True,inplace=True)

TYPE_ZERO_LOC_3 = LOC_3_READING[LOC_3_READING["type"] == 0]
TYPE_ZERO_LOC_3.reset_index(drop=True,inplace=True)

TYPE_ZERO_LOC_4 = LOC_4_READING[LOC_4_READING["type"] == 0]
TYPE_ZERO_LOC_4.reset_index(drop=True,inplace=True)

TYPE_ZERO_LOC_5 = LOC_5_READING[LOC_5_READING["type"] == 0]
TYPE_ZERO_LOC_5.reset_index(drop=True,inplace=True)

TYPE_ZERO_LOC_6 = LOC_6_READING[LOC_6_READING["type"] == 0]
TYPE_ZERO_LOC_6.reset_index(drop=True,inplace=True)

TYPE_ZERO_LOC_7 = LOC_7_READING[LOC_7_READING["type"] == 0]
TYPE_ZERO_LOC_7.reset_index(drop=True,inplace=True)

TYPE_ZERO_LOC_8 = LOC_8_READING[LOC_8_READING["type"] == 0]
TYPE_ZERO_LOC_8.reset_index(drop=True,inplace=True)

# %% [markdown]
# #### LOCAL LATITUDE AND LONGITUDE

# %%
LOC_1_LAT_LONG = TYPE_ZERO_LOC_1[["latitude","longitude"]]
LOC_2_LAT_LONG = TYPE_ZERO_LOC_2[["latitude","longitude"]]
LOC_3_LAT_LONG = TYPE_ZERO_LOC_3[["latitude","longitude"]]
LOC_4_LAT_LONG = TYPE_ZERO_LOC_4[["latitude","longitude"]]
LOC_5_LAT_LONG = TYPE_ZERO_LOC_5[["latitude","longitude"]]
LOC_6_LAT_LONG = TYPE_ZERO_LOC_6[["latitude","longitude"]]
LOC_7_LAT_LONG = TYPE_ZERO_LOC_7[["latitude","longitude"]]
LOC_8_LAT_LONG = TYPE_ZERO_LOC_8[["latitude","longitude"]]

# %%
LOC_1_LAT_LONG.latitude = LOC_1_LAT_LONG.latitude.astype(float)
LOC_1_LAT_LONG.longitude = LOC_1_LAT_LONG.longitude.astype(float)

LOC_2_LAT_LONG.latitude = LOC_2_LAT_LONG.latitude.astype(float)
LOC_2_LAT_LONG.longitude = LOC_2_LAT_LONG.longitude.astype(float)

LOC_3_LAT_LONG.latitude = LOC_3_LAT_LONG.latitude.astype(float)
LOC_3_LAT_LONG.longitude = LOC_3_LAT_LONG.longitude.astype(float)

LOC_4_LAT_LONG.latitude = LOC_4_LAT_LONG.latitude.astype(float)
LOC_4_LAT_LONG.longitude = LOC_4_LAT_LONG.longitude.astype(float)

LOC_5_LAT_LONG.latitude = LOC_5_LAT_LONG.latitude.astype(float)
LOC_5_LAT_LONG.longitude = LOC_5_LAT_LONG.longitude.astype(float)

LOC_6_LAT_LONG.latitude = LOC_6_LAT_LONG.latitude.astype(float)
LOC_6_LAT_LONG.longitude = LOC_6_LAT_LONG.longitude.astype(float)

LOC_7_LAT_LONG.latitude = LOC_7_LAT_LONG.latitude.astype(float)
LOC_7_LAT_LONG.longitude = LOC_7_LAT_LONG.longitude.astype(float)

LOC_8_LAT_LONG.latitude = LOC_8_LAT_LONG.latitude.astype(float)
LOC_8_LAT_LONG.longitude = LOC_8_LAT_LONG.longitude.astype(float)

# %%
LOC_1_HEAT = list(zip(LOC_1_LAT_LONG.latitude,LOC_1_LAT_LONG.longitude))
LOC_2_HEAT = list(zip(LOC_2_LAT_LONG.latitude,LOC_2_LAT_LONG.longitude))
LOC_3_HEAT = list(zip(LOC_3_LAT_LONG.latitude,LOC_3_LAT_LONG.longitude))
LOC_4_HEAT = list(zip(LOC_4_LAT_LONG.latitude,LOC_4_LAT_LONG.longitude))
LOC_5_HEAT = list(zip(LOC_5_LAT_LONG.latitude,LOC_5_LAT_LONG.longitude))
LOC_6_HEAT = list(zip(LOC_6_LAT_LONG.latitude,LOC_6_LAT_LONG.longitude))
LOC_7_HEAT = list(zip(LOC_7_LAT_LONG.latitude,LOC_7_LAT_LONG.longitude))
LOC_8_HEAT = list(zip(LOC_8_LAT_LONG.latitude,LOC_8_LAT_LONG.longitude))

# %% [markdown]
# ### LOCATIONS

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Terrain',
                  zoom_start=4.5)

plugins.MarkerCluster(LOC_1_LAT_LONG).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### **ATTENTION**
# * OREN

# %%
OREN_TYPE = TYPE_ZERO_LOC_1.copy()

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Terrain',
                  zoom_start=4.5)

plugins.MarkerCluster(LOC_2_LAT_LONG).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### **ATTENTION**
# * MANAVGAT-AYDINCIK

# %%
MANAVGAT_AYDINCIK_TYPE = TYPE_ZERO_LOC_2.copy()

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Terrain',
                  zoom_start=4.5)

plugins.MarkerCluster(LOC_3_LAT_LONG).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### ATTENTION
# * AYDINCIK-MERSIN

# %%
MERSIN_AYDINCIK_TYPE = TYPE_ZERO_LOC_3.copy()

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Terrain',
                  zoom_start=4.5)

plugins.MarkerCluster(LOC_4_LAT_LONG).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### **ATTENTION**
# * KOYCEGIZ

# %%
KOYCEGIZ_TYPE = TYPE_ZERO_LOC_4.copy()

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Terrain',
                  zoom_start=4.5)

plugins.MarkerCluster(LOC_5_LAT_LONG).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### **ATTENTION**
# * ADANA

# %%
ADANA_TYPE = TYPE_ZERO_LOC_5.copy()

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Terrain',
                  zoom_start=4.5)

plugins.MarkerCluster(LOC_6_LAT_LONG).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### **ATTENTION**
# * BODRUM

# %%
BODRUM_TYPE = TYPE_ZERO_LOC_6.copy()

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Terrain',
                  zoom_start=4.5)

plugins.MarkerCluster(LOC_7_LAT_LONG).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### **ATTENTION**
# * ISPARTA-BURDUR

# %%
BURDUR_ISPARTA_TYPE = TYPE_ZERO_LOC_7.copy()

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Terrain',
                  zoom_start=4.5)

plugins.MarkerCluster(LOC_8_LAT_LONG).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# #### **ATTENTION**
# * MARMARIS

# %%
MARMARIS_TYPE = TYPE_ZERO_LOC_8.copy()

# %% [markdown]
# # PLOT

# %%
PLACE_TYPE_LIST = [OREN_TYPE,MANAVGAT_AYDINCIK_TYPE,MERSIN_AYDINCIK_TYPE,KOYCEGIZ_TYPE,
                  ADANA_TYPE,BODRUM_TYPE,BURDUR_ISPARTA_TYPE,MARMARIS_TYPE]

# %%
PLACE_NAME_LIST = ["OREN","MANAVGAT-AYDINCIK","MERSIN-AYDINCIK","KOYCEGIZ","ADANA","BODRUM","BURDUR-ISPARTA","MARMARIS"]

# %% [markdown]
# ### FRP-BRIGHT_T31-BRIGHTNESS

# %%
for i_place,n_place in zip(PLACE_TYPE_LIST,PLACE_NAME_LIST):
    
    figure = plt.figure(figsize=(20,7))
    sns.lineplot(x=pd.DatetimeIndex(i_place["acq_date"]),y=i_place["frp"])
    plt.title(f"DATE-FRP / {n_place}")
    plt.show()

# %%
for i_place,n_place in zip(PLACE_TYPE_LIST,PLACE_NAME_LIST):
    
    figure = plt.figure(figsize=(20,7))
    sns.lineplot(x=pd.DatetimeIndex(i_place["acq_date"]),y=i_place["brightness"])
    plt.title(f"DATE-BRIGHTNESS / {n_place}")
    plt.show()

# %%
for i_place,n_place in zip(PLACE_TYPE_LIST,PLACE_NAME_LIST):
    
    figure = plt.figure(figsize=(20,7))
    sns.lineplot(x=pd.DatetimeIndex(i_place["acq_date"]),y=i_place["bright_t31"])
    plt.title(f"DATE-KELVIN / {n_place}")
    plt.show()

# %% [markdown]
# # DESCRIBE AND VARIABLES

# %%
for i_place,n_place in zip(PLACE_TYPE_LIST,PLACE_NAME_LIST):
    print("\n")
    print(n_place)
    print("---"*10)
    print(i_place.describe().T)
    print("\n")
    print("---"*22)

# %% [markdown]
# # BASED ON 2021

# %% [markdown]
# ### MAIN READING

# %%
OREN_BASED = pd.read_csv("../input/target-locations-of-wildfires-turkey/TARGET_LOCATIONS_OF_WILDFIRES/fire_nrt_M-C61_214692.csv")
MANAVGAT_AYDINCIK_BASED = pd.read_csv("../input/target-locations-of-wildfires-turkey/TARGET_LOCATIONS_OF_WILDFIRES/fire_nrt_M-C61_214695.csv")
MERSIN_AYDINCIK_BASED = pd.read_csv("../input/target-locations-of-wildfires-turkey/TARGET_LOCATIONS_OF_WILDFIRES/fire_nrt_M-C61_214696.csv")
KOYCEGIZ_BASED = pd.read_csv("../input/target-locations-of-wildfires-turkey/TARGET_LOCATIONS_OF_WILDFIRES/fire_nrt_M-C61_214697.csv")
ADANA_BASED = pd.read_csv("../input/target-locations-of-wildfires-turkey/TARGET_LOCATIONS_OF_WILDFIRES/fire_nrt_M-C61_214698.csv")
BODRUM_BASED = pd.read_csv("../input/target-locations-of-wildfires-turkey/TARGET_LOCATIONS_OF_WILDFIRES/fire_nrt_M-C61_214699.csv")
BURDUR_ISPARTA_BASED = pd.read_csv("../input/target-locations-of-wildfires-turkey/TARGET_LOCATIONS_OF_WILDFIRES/fire_nrt_M-C61_214701.csv")
MARMARIS_BASED = pd.read_csv("../input/target-locations-of-wildfires-turkey/TARGET_LOCATIONS_OF_WILDFIRES/fire_nrt_M-C61_214702.csv")

# %%
PLACE_2021_TARGET = [OREN_BASED,MANAVGAT_AYDINCIK_BASED,MERSIN_AYDINCIK_BASED,
                    KOYCEGIZ_BASED,ADANA_BASED,BODRUM_BASED,BURDUR_ISPARTA_BASED,MARMARIS_BASED]

# %% [markdown]
# ### LATITUDE AND LONGITUDE

# %%
OREN_LAT_LONG = OREN_BASED[["latitude","longitude"]]

OREN_LAT_LONG.latitude = OREN_LAT_LONG.latitude.astype(float)
OREN_LAT_LONG.longitude = OREN_LAT_LONG.longitude.astype(float)

HEAT_OREN = list(zip(OREN_LAT_LONG.latitude,OREN_LAT_LONG.longitude))



MANAVGAT_AYDINCIK_LAT_LONG = MANAVGAT_AYDINCIK_BASED[["latitude","longitude"]]

MANAVGAT_AYDINCIK_LAT_LONG.latitude = MANAVGAT_AYDINCIK_LAT_LONG.latitude.astype(float)
MANAVGAT_AYDINCIK_LAT_LONG.longitude = MANAVGAT_AYDINCIK_LAT_LONG.longitude.astype(float)

HEAT_MANAVGAT_AYDINCIK = list(zip(MANAVGAT_AYDINCIK_LAT_LONG.latitude,MANAVGAT_AYDINCIK_LAT_LONG.longitude))



MERSIN_AYDINCIK_LAT_LONG = MERSIN_AYDINCIK_BASED[["latitude","longitude"]]

MERSIN_AYDINCIK_LAT_LONG.latitude = MERSIN_AYDINCIK_LAT_LONG.latitude.astype(float)
MERSIN_AYDINCIK_LAT_LONG.longitude = MERSIN_AYDINCIK_LAT_LONG.longitude.astype(float)

HEAT_MERSIN_AYDINCIK = list(zip(MERSIN_AYDINCIK_LAT_LONG.latitude,MERSIN_AYDINCIK_LAT_LONG.longitude))



KOYCEGIZ_LAT_LONG = KOYCEGIZ_BASED[["latitude","longitude"]]

KOYCEGIZ_LAT_LONG.latitude = KOYCEGIZ_LAT_LONG.latitude.astype(float)
KOYCEGIZ_LAT_LONG.longitude = KOYCEGIZ_LAT_LONG.longitude.astype(float)

HEAT_KOYCEGIZ = list(zip(KOYCEGIZ_LAT_LONG.latitude,KOYCEGIZ_LAT_LONG.longitude))



ADANA_LAT_LONG = ADANA_BASED[["latitude","longitude"]]

ADANA_LAT_LONG.latitude = ADANA_LAT_LONG.latitude.astype(float)
ADANA_LAT_LONG.longitude = ADANA_LAT_LONG.longitude.astype(float)

HEAT_ADANA = list(zip(ADANA_LAT_LONG.latitude,ADANA_LAT_LONG.longitude))



BODRUM_LAT_LONG = BODRUM_BASED[["latitude","longitude"]]

BODRUM_LAT_LONG.latitude = BODRUM_LAT_LONG.latitude.astype(float)
BODRUM_LAT_LONG.longitude = BODRUM_LAT_LONG.longitude.astype(float)

HEAT_BODRUM = list(zip(BODRUM_LAT_LONG.latitude,BODRUM_LAT_LONG.longitude))



BURDUR_ISPARTA_LAT_LONG = BURDUR_ISPARTA_BASED[["latitude","longitude"]]

BURDUR_ISPARTA_LAT_LONG.latitude = BURDUR_ISPARTA_LAT_LONG.latitude.astype(float)
BURDUR_ISPARTA_LAT_LONG.longitude = BURDUR_ISPARTA_LAT_LONG.longitude.astype(float)

HEAT_BURDUR_ISPARTA = list(zip(BURDUR_ISPARTA_LAT_LONG.latitude,BURDUR_ISPARTA_LAT_LONG.longitude))



MARMARIS_LAT_LONG = MARMARIS_BASED[["latitude","longitude"]]

MARMARIS_LAT_LONG.latitude = MARMARIS_LAT_LONG.latitude.astype(float)
MARMARIS_LAT_LONG.longitude = MARMARIS_LAT_LONG.longitude.astype(float)

HEAT_MARMARIS = list(zip(MARMARIS_LAT_LONG.latitude,MARMARIS_LAT_LONG.longitude))

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Terrain',
                  zoom_start=4.5)

plugins.MarkerCluster(OREN_LAT_LONG).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Terrain',
                  zoom_start=4.5)

plugins.MarkerCluster(MANAVGAT_AYDINCIK_LAT_LONG).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Terrain',
                  zoom_start=4.5)

plugins.MarkerCluster(MERSIN_AYDINCIK_LAT_LONG).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Terrain',
                  zoom_start=4.5)

plugins.MarkerCluster(KOYCEGIZ_LAT_LONG).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Terrain',
                  zoom_start=4.5)

plugins.MarkerCluster(ADANA_LAT_LONG).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Terrain',
                  zoom_start=4.5)

plugins.MarkerCluster(BODRUM_LAT_LONG).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Terrain',
                  zoom_start=4.5)

plugins.MarkerCluster(BURDUR_ISPARTA_LAT_LONG).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %%
MAP_FUNCTION = folium.Map(location=[38.9637,35.2433],
                  tiles='Stamen Terrain',
                  zoom_start=4.5)

plugins.MarkerCluster(MARMARIS_LAT_LONG).add_to(MAP_FUNCTION)

MAP_FUNCTION

# %% [markdown]
# ### PLOT

# %% [markdown]
# #### FRP

# %%
for i_place,n_place in zip(PLACE_2021_TARGET,PLACE_NAME_LIST):
    
    figure = plt.figure(figsize=(20,7))
    sns.lineplot(x=pd.DatetimeIndex(i_place["acq_date"]),y=i_place["frp"])
    plt.title(f"DATE-FRP / {n_place}")
    plt.show()

# %% [markdown]
# #### BRIGHTNESS

# %%
for i_place,n_place in zip(PLACE_2021_TARGET,PLACE_NAME_LIST):
    
    figure = plt.figure(figsize=(20,7))
    sns.lineplot(x=pd.DatetimeIndex(i_place["acq_date"]),y=i_place["brightness"])
    plt.title(f"DATE-BRIGHTNESS / {n_place}")
    plt.show()

# %% [markdown]
# #### KELVIN

# %%
for i_place,n_place in zip(PLACE_2021_TARGET,PLACE_NAME_LIST):
    
    figure = plt.figure(figsize=(20,7))
    sns.lineplot(x=pd.DatetimeIndex(i_place["acq_date"]),y=i_place["bright_t31"])
    plt.title(f"DATE-KELVIN / {n_place}")
    plt.show()

# %%
for i_place,n_place in zip(PLACE_2021_TARGET,PLACE_NAME_LIST):
    
    figure = plt.figure(figsize=(20,7))
    fig_plot = px.line(x=i_place["acq_date"],y=i_place["bright_t31"],title=f"DATE-KELVIN / {n_place}")
    fig_plot.show()
    plt.show()

# %%
for i_place,n_place in zip(PLACE_2021_TARGET,PLACE_NAME_LIST):
    
    figure = plt.figure(figsize=(20,7))
    fig_plot = px.line(x=i_place["acq_date"],y=i_place["frp"],title=f"DATE-FRP / {n_place}")
    fig_plot.show()
    plt.show()

# %%
for i_place,n_place in zip(PLACE_2021_TARGET,PLACE_NAME_LIST):
    
    figure = plt.figure(figsize=(20,7))
    fig_plot = px.line(x=i_place["acq_date"],y=i_place["brightness"],title=f"DATE-BRIGHTNESS / {n_place}")
    fig_plot.show()
    plt.show()

# %% [markdown]
# # BEFORE 2021

# %%
BEFORE_OREN_BASED = pd.read_csv("../input/target-locations-of-wildfires-turkey/TARGET_LOCATIONS_OF_WILDFIRES/fire_archive_M-C61_214692.csv")
BEFORE_MANAVGAT_AYDINCIK_BASED = pd.read_csv("../input/target-locations-of-wildfires-turkey/TARGET_LOCATIONS_OF_WILDFIRES/fire_archive_M-C61_214695.csv")
BEFORE_MERSIN_AYDINCIK_BASED = pd.read_csv("../input/target-locations-of-wildfires-turkey/TARGET_LOCATIONS_OF_WILDFIRES/fire_archive_M-C61_214696.csv")
BEFORE_KOYCEGIZ_BASED = pd.read_csv("../input/target-locations-of-wildfires-turkey/TARGET_LOCATIONS_OF_WILDFIRES/fire_archive_M-C61_214697.csv")
BEFORE_ADANA_BASED = pd.read_csv("../input/target-locations-of-wildfires-turkey/TARGET_LOCATIONS_OF_WILDFIRES/fire_archive_M-C61_214698.csv")
BEFORE_BODRUM_BASED = pd.read_csv("../input/target-locations-of-wildfires-turkey/TARGET_LOCATIONS_OF_WILDFIRES/fire_archive_M-C61_214699.csv")
BEFORE_BURDUR_ISPARTA_BASED = pd.read_csv("../input/target-locations-of-wildfires-turkey/TARGET_LOCATIONS_OF_WILDFIRES/fire_archive_M-C61_214701.csv")
BEFORE_MARMARIS_BASED = pd.read_csv("../input/target-locations-of-wildfires-turkey/TARGET_LOCATIONS_OF_WILDFIRES/fire_archive_M-C61_214702.csv")

# %%
BEFORE_TIME_LIST = [BEFORE_OREN_BASED,BEFORE_MANAVGAT_AYDINCIK_BASED,BEFORE_MERSIN_AYDINCIK_BASED,
                   BEFORE_KOYCEGIZ_BASED,BEFORE_ADANA_BASED,BEFORE_BODRUM_BASED,BEFORE_BURDUR_ISPARTA_BASED,BEFORE_MARMARIS_BASED]

# %%
BEFORE_OREN_BASED

# %%
for i_place,n_place in zip(BEFORE_TIME_LIST,PLACE_NAME_LIST):
    
    figure = plt.figure(figsize=(20,7))
    fig_plot = px.line(x=i_place["acq_date"],y=i_place["frp"],title=f"DATE-FRP / {n_place}")
    fig_plot.show()
    plt.show()

# %%
for i_place,n_place in zip(BEFORE_TIME_LIST,PLACE_NAME_LIST):
    
    figure = plt.figure(figsize=(20,7))
    fig_plot = px.line(x=i_place["acq_date"],y=i_place["bright_t31"],title=f"DATE-KELVIN / {n_place}")
    fig_plot.show()
    plt.show()

# %%
for i_place,n_place in zip(BEFORE_TIME_LIST,PLACE_NAME_LIST):
    
    figure = plt.figure(figsize=(20,7))
    fig_plot = px.line(x=i_place["acq_date"],y=i_place["brightness"],title=f"DATE-BRIGHTNESS / {n_place}")
    fig_plot.show()
    plt.show()

# %% [markdown]
# # SPECIAL DAYS BASED ON KELVIN

# %%
AUG_22_2014_OREN = BEFORE_OREN_BASED[BEFORE_OREN_BASED["acq_date"] == "2014-08-22"]
AUG_22_2014_OREN.sort_values(by=["acq_time"],inplace=True)
AUG_22_2014_OREN.reset_index(drop=True,inplace=True)

JUL_02_2008_MANAVGAT_AYDINCIK = BEFORE_MANAVGAT_AYDINCIK_BASED[BEFORE_MANAVGAT_AYDINCIK_BASED["acq_date"] == "2008-07-02"]
JUL_02_2008_MANAVGAT_AYDINCIK.sort_values(by=["acq_time"],inplace=True)
JUL_02_2008_MANAVGAT_AYDINCIK.reset_index(drop=True,inplace=True)

SEP_02_2012_MERSIN_AYDINCIK = BEFORE_MERSIN_AYDINCIK_BASED[BEFORE_MERSIN_AYDINCIK_BASED["acq_date"] == "2012-09-02"]
SEP_02_2012_MERSIN_AYDINCIK.sort_values(by=["acq_time"],inplace=True)
SEP_02_2012_MERSIN_AYDINCIK.reset_index(drop=True,inplace=True)

AUG_26_2004_KOYCEGIZ = BEFORE_KOYCEGIZ_BASED[BEFORE_KOYCEGIZ_BASED["acq_date"] == "2004-08-26"]
AUG_26_2004_KOYCEGIZ.sort_values(by=["acq_time"],inplace=True)
AUG_26_2004_KOYCEGIZ.reset_index(drop=True,inplace=True)

JUL_31_2008_ADANA = BEFORE_ADANA_BASED[BEFORE_ADANA_BASED["acq_date"] == "2008-07-31"]
JUL_31_2008_ADANA.sort_values(by=["acq_time"],inplace=True)
JUL_31_2008_ADANA.reset_index(drop=True,inplace=True)

JUL_07_2007_BODRUM = BEFORE_BODRUM_BASED[BEFORE_BODRUM_BASED["acq_date"] == "2007-07-07"]
JUL_07_2007_BODRUM.sort_values(by=["acq_time"],inplace=True)
JUL_07_2007_BODRUM.reset_index(drop=True,inplace=True)

AUG_17_2014_BURDUR_ISPARTA = BEFORE_BURDUR_ISPARTA_BASED[BEFORE_BURDUR_ISPARTA_BASED["acq_date"] == "2014-08-17"]
AUG_17_2014_BURDUR_ISPARTA.sort_values(by=["acq_time"],inplace=True)
AUG_17_2014_BURDUR_ISPARTA.reset_index(drop=True,inplace=True)

JUL_15_2008_MARMARIS = BEFORE_MARMARIS_BASED[BEFORE_MARMARIS_BASED["acq_date"] == "2008-07-15"]
JUL_15_2008_MARMARIS.sort_values(by=["acq_time"],inplace=True)
JUL_15_2008_MARMARIS.reset_index(drop=True,inplace=True)

# %%
SPECIAL_DAY_LIST = [AUG_22_2014_OREN,JUL_02_2008_MANAVGAT_AYDINCIK,SEP_02_2012_MERSIN_AYDINCIK,
                   AUG_26_2004_KOYCEGIZ,JUL_31_2008_ADANA,JUL_07_2007_BODRUM,AUG_17_2014_BURDUR_ISPARTA,JUL_15_2008_MARMARIS]

# %% [markdown]
# #### KELVIN

# %%
for i_place,n_place in zip(SPECIAL_DAY_LIST,PLACE_NAME_LIST):
    
    figure = plt.figure(figsize=(20,7))
    sns.lineplot(x=i_place["acq_time"],y=i_place["bright_t31"])
    plt.title(f"TIME-KELVIN / {n_place}")
    plt.show()

# %% [markdown]
# #### FRP

# %%
for i_place,n_place in zip(SPECIAL_DAY_LIST,PLACE_NAME_LIST):
    
    figure = plt.figure(figsize=(20,7))
    sns.lineplot(x=i_place["acq_time"],y=i_place["frp"])
    plt.title(f"TIME-FRP / {n_place}")
    plt.show()

# %% [markdown]
# #### BRIGHTNESS

# %%
for i_place,n_place in zip(SPECIAL_DAY_LIST,PLACE_NAME_LIST):
    
    figure = plt.figure(figsize=(20,7))
    sns.lineplot(x=i_place["acq_time"],y=i_place["frp"])
    plt.title(f"TIME-BRIGHTNESS / {n_place}")
    plt.show()
