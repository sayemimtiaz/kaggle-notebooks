# %% [markdown]
# Imports

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# Load Dataset

# %%
df = pd.read_csv('../input/suicide-rates-overview-1985-to-2016/master.csv')
df1= df.fillna(0)

# %% [markdown]
# Number of rows and columns in the data set:

# %%
print('Rows     :',df.shape[0])
print('Columns  :',df.shape[1])

# %% [markdown]
# Features containing blank, null or empty values:

# %%
# missing values
print('Missing values:',df.isnull().values.sum())

df.isnull().sum()

# %% [markdown]
# Columns

# %%
print('Columns are:\n', df1.columns)

# %% [markdown]
# Columns with Data type

# %%
print('Columns and type\n',  df1.info())

# %% [markdown]
# Describing the Data

# %%
print('Describing the data\n', df1.describe())

# %% [markdown]
# Number of different generations:

# %%
print(df1.generation.value_counts())

# %% [markdown]
# Number and type of different age groups:

# %%
print('Number of age groups:', df1.age.nunique(),'\n','Types of age group:', df1.age.unique())

# %% [markdown]
# Total number of countries:

# %%
print(df1.country.nunique())

# %% [markdown]
# Total number of suicides:

# %%
print('Total number of deaths from 1985 to 2016:', df1.suicides_no.sum())
