# %%
import pandas as pd
import numpy as np
import seaborn as sns
import missingno   
from sklearn import preprocessing

# %% [markdown]
# Veri çerçevemizi çekirdeğe dahil edelim.

# %%
df = pd.read_csv("../input/tabletpc-priceclassification/tablet.csv")

# %%
df.head()

# %% [markdown]
# Kaç öznitelik ve gözlemden oluştuğuna bakarak devam edelim.

# %%
df.shape

# %% [markdown]
# 20 öznitelik ve 2000 adet gozlemden olustugunu goruyoruz. Veri türlerimizi ogrenerelim.

# %%
df.dtypes

# %% [markdown]
# Farklı türlerdeki veriler bize göz kırpıyor. İlk gözlemlerimize devam edelim ve 0 ya da null verilere doğru ilerleyelim.

# %%
df.info()

# %% [markdown]
# Görüyoruz ki az da olsa null olan değerlerimiz var. Peki öznitelik bazında kaçar tane?

# %%
df.isna().sum()

# %% [markdown]
# Göz ile de sayabileceğimiz derecede az olan null değerimiz var. Peki ya daha karmaşık olsaydı göz ile saymak mantıklı olur
# muydu? Fonksiyonumuza bir sum() daha ekleyerek devam edelim.

# %%
df.isna().sum().sum()

# %% [markdown]
# 17 adet null değişkenimiz var. Bunları ileride ya dolduracağız ya da sileceğiz. Veriye ilk bakış çerçevesinde devam edelim ve
# sayısal verilere bir göz atalım.

# %%
df.describe().T

# %% [markdown]
# Bataryaya baktığımızda standart sapmasının bu denli yüksek olması dikkatimizi çekiyor. Demek ki batarya kapasitesinin bir standardı yok. Değerler birbirinden oldukça uzak. Min ve max değerlerine baktığımızda iki uç değerin arasındaki fark standart sapmanın bu denli büyük olmasını destekliyor. Aynı şey ram için de geçerli. Min ve max değerlerinin bu denli uzak olması standart sapmasının oldukça büyümesine sebep olmuş. Biraz da birbirinden çok da uzak olmayan verilere sahip olan kalınlık değerine bakalım. Standart sapmasına baktığımız zaman bizi en kuçuk std değeri karşılıyor. Min ve max değerlerinin de birbirine bu denli yakın olması bunu destekliyor. Ram ve batarya aksine kalınlıkta bir standart izlendiğini söylemek oldukça mümkün. Korelasyon ile devam edelim ve diğer yorumlarımızı ısı haritasına saklayalım.

# %%
df.corr()

# %% [markdown]
# Öznitelik sayısı çok olduğu için sayısal tablodan bir çıkarım yapmak oldukça zor. İşi görselleştirerek devam edelim.

# %%
corr = df.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values);

# %% [markdown]
# Korelasyon matrisinden sonra ısı haritası ile gözlerimiz bayram etmeli. Gerçekten seaborn burada imdadımıza yetişti. Baktığımızda gözümüze çarpan ilk ilişki ön ve arka kameranın mp değerleri. Demek ki telefonların arka kamerası iyi ise ön kamerası da iyi, aynı şekilde ön kamerası iyiyse arka kamerası da iyi oluyor. Gözümüze ikinci çarpan kesişme ise çözünürlüğün genişliği ve yüksekliği. Bunu da telefon ekranının iyi bir çözünürlük vermek istemesi durumunda yükseklik ve genislik miktarlarının doğru oranda artacağını söylemek mümkün. Şaşırtıcı derecede birbirlerini anlam ifade edecek derecede pozitif etkileyen başka iki öznitelik yok.

# %% [markdown]
# Biraz da benzersiz değişkenlerimizi inceleyelim

# %%
df["Bluetooth"].unique() # Sadece iki adet benzersiz değişkenimiz olduğunu görüyoruz.

# %%
df["OnKameraMP"].nunique() # on kameramızın benzersiz değişkenleri bluetooth ile kıyasladığımızda oldukça fazla.

# %%
df["FiyatAraligi"].unique() # 5 adet fiyat benzersiz değişkenimiz mevcut. Son olarak renklere de göz atalım.

# %%
df["Renk"].unique() # renk tarafından da zengin bir içeriğe sahip olduğumuzu söylemek yanlış olmaz.

# %% [markdown]
# Peki bu dağılımlar dengeli mi?

# %%
df["Renk"].value_counts() # Renk dağılımı çok da dengeli değil.

# %%
df["WiFi"].value_counts() # Wifi özniteliğimizin dağılımına baktığımızda neredeyse dengeli olduğunu söyleyebiliriz.

# %%
df["BataryaOmru"].value_counts() # Batarya ömürlerine baktığımızda ise bizi biraz daha farklı bir dağılım karşılıyor.

# %% [markdown]
# Biraz da görselleştirme teknikleri ile çalışıp yorumlayalım.

# %%
sns.countplot(x = "BataryaOmru", data = df)

# %% [markdown]
# Value counts fonksiyonunun aksine görselleştirerek baktığımızda çok daha rahat analiz edebildiğimizi görüyoruz. Grafiğe bakarak eşit olmaya çok da yakın bir şekilde dağıldıklarını söylemek mümkün değil. Peki ya renklerin dağılımı, fiyatların dağılımı?

# %%
sns.countplot(x = "Renk", data = df)

# %% [markdown]
# Renk özniteliğimizin benzersiz değerleri batarya ömrünün benzersiz değerlerine kıyasla biraz daha dengeli bir dağılım göstermekte.

# %%
sns.countplot(x = "FiyatAraligi", data = df)

# %% [markdown]
# Fiyatların dengeli dağıldığını görüyoruz.

# %%
sns.countplot(x = "DahiliBellek", data = df)

# %% [markdown]
# Bellek dağılımımıza baktığımızda ise dengeli olmayan bir dağılım bize göz kırpıyor. Çeşitliliğin çok olduğunu söylemek mümkün.

# %%
sns.countplot(x = "Agirlik", data = df)

# %% [markdown]
# Ağırlık değişkenimize baktığımızda isi bizi daha da karmaşık bir dağılım bekliyor. Çeşitliliğin bellekten bile daha fazla olduğunu rahatça söyleyebiliyoruz.

# %%
sns.distplot(df["BataryaGucu"], bins = 16, color = "red");

# %% [markdown]
# Batarya gücü öznitelik verilerimizin normal dağılıma uymadığını görüyoruz.

# %%
sns.distplot(df["DahiliBellek"], bins = 16, color = "red");

# %% [markdown]
# Aynı şekilde dahili bellek özniteliğimizin de normal dağılıma uymadığını söylemek mümkün.

# %%
sns.distplot(df["OnKameraMP"], bins = 16, color = "red");

# %% [markdown]
# Ön kamera değerlerine baktığımızda ise normal dağılıma biraz daha yaklaşmış bir veri kümesi ile karşılaşıyoruz.

# %%
sns.jointplot(x = "ArkaKameraMP", y = "OnKameraMP", data = df, color = "purple");

# %% [markdown]
# Aralarında güçlü pozitif ilişki bulunan ön ve arka kamera değerlerimize baktığımız zaman ise arka kamera mp değerlerinin hemen hemen her zaman ön kamera değerlerinden fazla olduğunu görüyoruz. Bu veri gerçek hayatta da aynen bu şekilde. Ön kamera değerleri çok yüksek değerlere ulaşamıyorken arka kamera değerlerinin böyle bir sorunu yok. Hatırlayalım ki bu iki öznitelik arasında pozitif etkileşim vardı. Burada da görüyoruz ki ön kamera değerimiz arttıkça arka kamera değerimiz de artış gösteriyor.

# %% [markdown]
# Bir de bu iki özniteliğin yoğunluk haritasına bakalım.

# %%
sns.jointplot(x = "ArkaKameraMP", y = "OnKameraMP", data = df, color = "blue", kind = "kde");

# %% [markdown]
# Yoğunluk haritasına bakarak aralarında pozitif bir etkileşim olsa da arka kamera mp değerinin ön kamera mp değerinden
# daha yüksek oranlarda arttığını söyleyebiliriz.

# %% [markdown]
# Şimdiye kadar sadece sürekli değişkenlerle çalıştık. Kategorik değişkenlerimizi de dahil ederek devam edelim.

# %%
sns.barplot(x = "FiyatAraligi", y = "RAM", data = df);

# %% [markdown]
# Görüyoruz ki ram miktarının fiyata doğrudan bir etkisi var.

# %%
sns.barplot(x = "FiyatAraligi", y = "CekirdekSayisi", data = df);

# %% [markdown]
# Çekirdek sayısı ile fiyat kategorilendirmesi arasında bir ilişki var mı sorusuna karşın yukarıdaki barplotu çalıştırdım. Görünüşe göre yok.

# %%
sns.barplot(x = "WiFi", y = "BataryaGucu", data = df);

# %% [markdown]
# Aynı şekilde wifi olup olmaması ile batarya gücü arasında da bir ilişki olmadığını gördük.

# %%
sns.barplot(x = "ArkaKameraMP", y = "BataryaGucu", data = df);

# %% [markdown]
# Burada ise arka kamera mp değeri ile batarya gücü arasındaki ilişkiyi görselleştiriyoruz. Görünüşe göre bu ikili arasında da
# göze fazla çarpan bir ilişki yok.

# %% [markdown]
# Pekala, yüksek mp değeri demek fotoğraf ve video karesi başına daha fazla depolama alanı demek. Acaba dahili bellek ile
# arka kamera mp değeri arasındaki durum nedir? Önce korelasyon değerlerini tekrar görüntüleyelim. Ardından görselleştirerek ilerleyelim.

# %%
df.corr()["ArkaKameraMP"]["DahiliBellek"]

# %%
sns.scatterplot(x = "ArkaKameraMP", y = "DahiliBellek", data = df, color="purple");

# %% [markdown]
# Korelasyon kat sayısının da bize söylediği üzere aralarında pozitif ilişki olmadığı gibi negatif bir ilişki var.Isı haritasından hatırladığımız kadarıyla aralarında pek de iyi bir ilişki olmamasına rağmen bu derece anlamsız bir ilişkiyi görmeyi beklemiyordum. Aralarındaki etkileşimin alakasız olduğunu söylemek yanlış olmaz. Görselleştirmelerimize dokunmatik ve ekran boyu kapsamında devam edelim.

# %%
sns.lmplot(x = "CozunurlukYükseklik", y = "CozunurlukGenislik", data = df, hue = "Dokunmatik");

# %% [markdown]
# Burada ise çözünürlüğü düşük cihazların genelde dokunmatik olduğunu söylemek mümkün. Fakat çözünürlük arttıkça dokunmatik
# olmama durumu da artıyor.

# %% [markdown]
# Peki ya bellek kapasitelerinin dağılımı nasıl?

# %%
sns.violinplot(y = "DahiliBellek", data = df);

# %% [markdown]
# Genelde 10 ila 60 gb arasında olduğunu söylemek mümkün. Peki bataryayı daha fazla tüketen 4g ve bluetooth özellikleri arasında bir görselleştirme yapsak nasıl bir görüntü elde ederiz?

# %%
sns.violinplot(x = "4G", y = "BataryaOmru", data = df);

# %% [markdown]
# 4g özelliğine sahip cihazların batarya ömrü alt limitinin olmayanlara göre biraz daha geniş olduğunu görüyoruz.

# %%
sns.violinplot(x = "Bluetooth", y = "BataryaOmru", data = df);

# %% [markdown]
# Buraya baktığımızda ise bluetooth özelliği olan cihazların orta segment batarya ömrüne sahip olanlarda sayıca
# bir azalma görüyoruz.

# %% [markdown]
# Şimdi de fiyat-performans bazlı bir görselleştirme yapıp ram, batarya gücü ve fiyat arasındaki ilişkiyi inceleyelim.

# %%
sns.scatterplot(x = "RAM", y = "BataryaGucu",hue = "FiyatAraligi",data = df);

# %% [markdown]
# Belli ki fiyat arttıkça ram miktarı da artıyor. Biraz daha dikkatli baktığımızda ise ram miktarı normalin biraz üstünde olsa dahi batarya gücünün fazlalığı sebebiyle fiyatlandırmadaki pahalılığı görebiliyoruz. Yani batarya gücü de fiyatı doğru orantılı olarak etkiliyor.

# %% [markdown]
# Peki kalınlık ve ağırlık arasında nasıl bir ilişki var?

# %%
sns.jointplot(x = "Kalinlik", y = "Agirlik", data = df, kind = "kde")

# %% [markdown]
# Yoğunluk grafiğini incelediğimizde iki öznitelik arasında pek bir ilişki olduğunu söyleyemiyoruz. Fakat karesel izohipslenmeye bakarak kalınlık ve ağırlığın bir standarta yakın seyrettiğini söyleyebiliriz.

# %% [markdown]
# Peki ya lüks diyebileceğimiz bir karşılaştırma yapsak? Fiyat, kalınlık değerlerini harmanlayıp ne elde edeceğimize bir bakalım. Pahalı telefonun lüks olacağını varsayıp daha ince daha ergonomik olacağını düşünüyorum.

# %%
sns.barplot(x ="FiyatAraligi" , y = "Kalinlik" , data = df);

# %% [markdown]
# Buraya bakarak ucuz telefonların biraz daha kalın olduğunu söyleyebiliriz. Ama değerlerin birbirine bu denli yakın olması tatmin edici değil.

# %%
sns.barplot(x ="FiyatAraligi" , y = "ArkaKameraMP" , data = df);

# %% [markdown]
# Yine tatmin edici olmasa da çok ucuzdan pahalıya gittikçe kamera mp değerinin arttığını görebiliyoruz.

# %%
df.sample(5)

# %% [markdown]
# Son olarak birden çok kategorik değişkeni parametre olarak alan bir gösterim yapalım. Şirket içi ve dışı görüşmelerin hiç kesilmediği(batarya gücüne ihtiyac duyan) ve gerektiğinde çift hat kullanılan aynı zamanda da ekonomik açıdan değerlendirdiğimizde nasıl bir görünüm çıkacağına bakalım.

# %%
sns.factorplot("FiyatAraligi", "BataryaGucu", "CiftHat", data = df, kind = "bar");

# %% [markdown]
# Ucuz, çok ucuz, normal ve pahalı kategorilerine baktığımızda batarya gücü ile doğru orantılı olduğunu söyleyebiliyoruz. Aynı zamanda çift hat olduğu durumlarda ucuz ve çok ucuz kategorisindeki fiyat artışını görmek mümkün.

# %% [markdown]
# Hatırlayalım, ram ile fiyat doğru orantılı. Peki rengin fiyat üzerine etkisi var mı?

# %%
sns.factorplot("FiyatAraligi", "RAM", "Renk", data = df, kind = "bar");

# %% [markdown]
# Renk ile fiyatın bir ilişkisi olmadığını görüyoruz. İleride renk özniteliğimizi çıkartacağız.

# %% [markdown]
# Sıra geldi eksik verilerimizi tamamlamaya. Missing no sınıfınından yardım alıp matrisimizi çizdirelim.

# %%
missingno.matrix(df,figsize=(20, 10));

# %% [markdown]
# Çok fazla eksik değerimiz yok. Bu iyiye işaret. Hatırlamak adına isnull fonksiyonunu bir kez daha çalıştıralım.

# %%
df.isnull().sum().sum()

# %% [markdown]
# Daha önceden de hatırlayabileceğimiz üzere 17 eksik değerimiz var. Eksik verilerin ısı haritasını çizdirerek devam edelim. Aralarındaki ilişkiyi görmek adına bize yardımcı olacak.

# %%
missingno.heatmap(df, figsize= (20,8));

# %% [markdown]
# Görüyoruz ki aralarında bir ilişki yok. Eksik değerlerin ne kadara tekabül ettiğine bir bakalım.

# %%
def eksik_deger_tablosu(df): 
    eksik_deger = df.isnull().sum()
    eksik_deger_yuzde = 100 * df.isnull().sum()/len(df)
    eksik_deger_tablo = pd.concat([eksik_deger, eksik_deger_yuzde], axis=1)
    eksik_deger_tablo_son = eksik_deger_tablo.rename(columns = {0 : 'Eksik Değerler', 1 : '% Değeri'})
    return eksik_deger_tablo_son

# %%
eksik_deger_tablosu(df)

# %% [markdown]
# Yüzdelik açıdan oldukça düşük hatta önemsiz denecek sayıda eksik değerimiz olduğunu görüyoruz. % değeri en fazla olan RAM özniteliğimizin benzersiz değerlerine bir bakalım.

# %%
df["RAM"].unique() # Acaba kaç tane?

# %%
df["RAM"].nunique() # 1554 adet benzersiz değerimiz var. Ram miktarının fiyatlandırmayı etkileyip etkilemediğine tekrar bakalım.

# %%
sns.barplot(x = "FiyatAraligi", y = "RAM", data = df);

# %% [markdown]
# Çok bariz şekilde görülüyor ki ram miktarı fiyatı kritik derecede etkiliyor. Ramdeki eksik verileri kesinlikle doldurmamız gerektiğini buradan anlıyoruz. Peki ya ön kamera ne kadar etkiliyor? Öncelikle benzersiz değerlerine bakalım.

# %%
df["OnKameraMP"].unique() # Acaba kaç tane?

# %%
df["OnKameraMP"].nunique() # Ram özniteliğine kıyasla oldukça az benzersiz değere sahip olduğunu görüyoruz.

# %% [markdown]
# Peki ya fiyat üzerindeki etkisi?

# %%
sns.barplot(x = "FiyatAraligi", y = "OnKameraMP", data = df);

# %% [markdown]
# Pahalı segmentinde bir düşüş olsa dahi on kamera mp değerinin fiyata bağlı olarak arttığını söylemek mümkün.

# %% [markdown]
# Acaba ram değerinin null olması başka bir veri ile bağlantılı mı?

# %%
sns.countplot(df[df["RAM"].isnull()]["FiyatAraligi"]);

# %% [markdown]
# Zaten 12 adet null ram değişkenimiz var ve hepsi pahalı kategorisinde bulunuyor. Buradan anlıyoruz ki pahalı kategorisindeki telefonların ram ortalaması ile doldurmamız fiyat belirlememizde işimizi kolaylaştıracaktır. Peki ya ön kamera?

# %%
sns.countplot(df[df["OnKameraMP"].isnull()]["FiyatAraligi"]);

# %% [markdown]
# Ön kameradaki eksik değerler de sadece çok ucuz kategorisinde bulunuyor. Ya telefonun kamerası yoksa? Bunu da kontrol edelim. Telefonun diğer özelliklerine göre bir kıyaslama yapalım. Kamerası olmayan verilere bir bakalım.

# %%
df[(df["OnKameraMP"].isnull())]

# %% [markdown]
# Görüyoruz ki 5 verimizin 4 tanesinde 4g var. Bu 4 verimizin on kamera değerlerini çok ucuz kategorisindeki kamera mp ortalamasıyla doldurmalıyız. Peki ya diğer 4g olmayan cihaz? Onun diğer verilerine baktığımız zaman ise arka kamerasının da olmadığını görüyoruz. Hatta bluetooth özelliği de yok. O cihazın ön kamerasız olması oldukça beklenilir bir durum. Kameramızdan eksik değerleri doldurmaya başlayalım.

# %%
kamerasi_gercekten_eksik_olanlar = df[(df["4G"] == "Var") & (df["OnKameraMP"].isnull())].index
kamerasi_gercekten_eksik_olanlar

# %% [markdown]
# Şu anda üzerinde çalışacağımız o 4 indisi bir arraye attık. Çok ucuz kategorisinin on kamera mp ortalamasına ihtiyacımız var.

# %%
df.groupby("FiyatAraligi").mean()

# %% [markdown]
# Görüyoruz ki çok ucuz kategorisinin ön kamera ortalaması 4.01 mp. Bunu kullanalım ve eksik kamera değerlerini dolduralım.

# %%
df.loc[kamerasi_gercekten_eksik_olanlar,"OnKameraMP"] = 4.01

# %% [markdown]
# Bir üst satırda kamerasının eksik olduğunu düşündüğümüz verilerin ön kamera değerlerini 4 yaptık. Sırada özellikleri kötü olan cihazın ön kamerasının null olduğu veriyi değiştirmek geliyor.

# %%
kamera_verisi_degisecekler = df[(df["4G"] == "Yok") & (df["OnKameraMP"].isnull())].index
kamera_verisi_degisecekler

# %% [markdown]
# Gerekli indisi, indisleri aldık. Şimdi onların on kamera değerini 0 yapalım.

# %%
df.loc[kamera_verisi_degisecekler,"OnKameraMP"] = 0

# %% [markdown]
# ön kameranın null olanlarını tekrar kontrol edelim.

# %%
kamera_null_kontrolu = df[(df["4G"] == "Var") & (df["OnKameraMP"].isnull())].index
kamera_null_kontrolu

# %% [markdown]
# Görüyoruz ki sorunu çözdük. Şimdi eksik ram değerlerimizle çalışalım.

# %%
ram_degeri_null_olanlar = df[(df["RAM"].isnull())].index
ram_degeri_null_olanlar

# %% [markdown]
# Hatırlayalım, ram değeri eksik olanların hepsi pahalı kategorisindeki cihazları. Pahalı cihazların ram ortalamasını bularak devam edelim.

# %%
df.groupby("FiyatAraligi").mean()

# %% [markdown]
# Görüyoruz ki pahalı kategorisindeki cihazların ram ortalaması 3449 mb. Bunu kullanacağız.

# %%
df.loc[ram_degeri_null_olanlar,"RAM"] = 3449 ## Gerekli atamayı yapıyoruz. Ardından tekrardan kontrol edelim.

# %%
ram_degeri_null_kontrol = df[(df["RAM"].isnull())].index
ram_degeri_null_kontrol

# %% [markdown]
# İşlem başarılı. Eksik değerlerimizin kalmadığından emin olmak için bir kez daha kontrol edelim.

# %%
df.isnull().sum().sum()

# %% [markdown]
# Eksik değerlerimizden tamamıyla kurtulduk. Ama işimiz daha bitmedi. Peki ya bazı değerler null değil de 0 olarak girilmişse?
# Bunu anlamak için öznitelik bazında kontrolümüzü gerçekleştirelim.

# %%
o_kontrolu = df[(df["BataryaGucu"] == 0)]
o_kontrolu

# %% [markdown]
# Batarya gücümüzde eksiklik yok. Tek tek kontrol ederek ilerleyelim.

# %%
o_kontrolu = df[(df["MikroislemciHizi"] == 0)]
o_kontrolu

# %%
o_kontrolu = df[(df["OnKameraMP"] == 0)]
o_kontrolu.head(10)

# %% [markdown]
# Görüyoruz ki onkamerası olmayan veriler var. Bunları fiyat kategorisindeki ortalamalarla dolduracağız. Fakat şuna dikkat çekmek istiyorum. Çok ucuz olanlarda ve bir ihtimal ucuz olanlarda telefonun diğer özelliklerine de bakmak gerekecek. Çünkü telefonun gerçekten de ön kamerası olmayabilir. Fiyat kategorilerine göre kategori ortalamalarıyla doldurarak devam edelim.

# %% [markdown]
# Pahalı olanların indekslerini alalım.

# %%
o_kontrolu_on_pahali = df[(df["OnKameraMP"] == 0) & (df["FiyatAraligi"] == "Pahalı")].index
o_kontrolu_on_pahali

# %% [markdown]
# Doldurmak için grupsal bazdaki ortalamalara bakalım.

# %%
df.groupby("FiyatAraligi").mean()

# %% [markdown]
# Pahalı kategorisinin on kamera degeri 4.31 imiş. Bunu kullanacağız.

# %%
df.loc[o_kontrolu_on_pahali,"OnKameraMP"] = 4.31

# %% [markdown]
# Kontrolümüzü sağlayalım.

# %%
o_kontrolu_on_pahali = df[(df["OnKameraMP"] == 0) & (df["FiyatAraligi"] == "Pahalı")].index
o_kontrolu_on_pahali

# %% [markdown]
# Görünüşe göre pahalı olanları hallettik. Diğer fiyat kategorilerindeki kontroller ile devam edelim.

# %%
o_kontrolu_on_normal = df[(df["OnKameraMP"] == 0) & (df["FiyatAraligi"] == "Normal")].index
o_kontrolu_on_normal

# %% [markdown]
# Tablomuzdaki değer ile dolduralım.

# %%
df.groupby("FiyatAraligi").mean()

# %%
df.loc[o_kontrolu_on_normal,"OnKameraMP"] = 4.5

# %% [markdown]
# Tekrar kontrol edelim.

# %%
o_kontrolu_on_normal = df[(df["OnKameraMP"] == 0) & (df["FiyatAraligi"] == "Normal")].index
o_kontrolu_on_normal

# %% [markdown]
# Sırada ucuz kategorisi var. Burada birkaç öznitelik sorgusu daha yapmak istiyorum. öncelikle bir listeleyelim ve yorumlayalım.

# %%
o_kontrolu_on_ucuz = df[(df["OnKameraMP"] == 0) & (df["FiyatAraligi"] == "Ucuz")]
o_kontrolu_on_ucuz

# %% [markdown]
# Hatırlamak adına fiyat bazlı ortalamalara tekrar bakalım

# %%
df.groupby("FiyatAraligi").mean()

# %% [markdown]
# Ucuz kategorisinin ram ortalaması 1679. Kendisinden bir üst ve bir alt kategorilere baktığmızda belirgin bir fark var. Bunu kullanalım ve ortalamanın birazcık altından başlayan alt limit ile indislerimizi alıp gerekli ortalama ile dolduralım. Tahminen bu ram miktarının üstü ram sahibi olan cihazların on kamerası olabilir.

# %%
o_kontrolu_on_ucuz = df[(df["OnKameraMP"] == 0) & (df["FiyatAraligi"] == "Ucuz") & (df["RAM"] > 1500)].index
o_kontrolu_on_ucuz

# %%
df.loc[o_kontrolu_on_ucuz,"OnKameraMP"] = 4.34

# %% [markdown]
# Kontrolümüzü yapalım ve ramin üst sınırına 1500 vererek devam edelim. Burada incelemelerimiz olacak.

# %%
o_kontrolu_on_ucuz = df[(df["OnKameraMP"] == 0) & (df["FiyatAraligi"] == "Ucuz") & (df["RAM"] > 1500)].index
o_kontrolu_on_ucuz

# %% [markdown]
# 1550 üstü için sorun çözülmüş görünüyor. Altına geçelim.

# %%
o_kontrolu_on_ucuz = df[(df["OnKameraMP"] == 0) & (df["FiyatAraligi"] == "Ucuz")]
o_kontrolu_on_ucuz

# %% [markdown]
# Yorumlarımızı yaparak ilerlememiz şart. Ön kameradan beklentilerimiz nelerdir? Fotoğraf çekmek elbette var fakat görüntülü konuşma yapabilen bir cihaz olmasını da katar bize. Sonuçta görüntülü konuşurken ön kamerayı kullanıyoruz. Bu da bizi internet bağlantısına götürüyor. Wifi olanlar veya en azından 3g olanlara bir bakalım.

# %%
o_kontrolu_on_ucuz = df[(df["OnKameraMP"] == 0) & (df["FiyatAraligi"] == "Ucuz")& (df["WiFi"] == "Var")]
o_kontrolu_on_ucuz

# %% [markdown]
# Bu kategorinin ön kamarası olması beklenir. Gerekli doldurmayı yapalım.

# %%
o_kontrolu_on_ucuz = df[(df["OnKameraMP"] == 0) & (df["FiyatAraligi"] == "Ucuz")& (df["WiFi"] == "Var")].index
o_kontrolu_on_ucuz

# %%
df.groupby("FiyatAraligi").mean()

# %%
df.loc[o_kontrolu_on_ucuz,"OnKameraMP"] = 4.95

# %% [markdown]
# Kontrolümüzü sağlayalım.

# %%
o_kontrolu_on_ucuz = df[(df["OnKameraMP"] == 0) & (df["FiyatAraligi"] == "Ucuz") & (df["WiFi"] == "Var")].index
o_kontrolu_on_ucuz

# %% [markdown]
# Aynı işlemleri 3g için yapalım

# %%
o_kontrolu_on_ucuz = df[(df["OnKameraMP"] == 0) & (df["FiyatAraligi"] == "Ucuz") & (df["3G"] == "Var")].index
o_kontrolu_on_ucuz

# %%
df.loc[o_kontrolu_on_ucuz,"OnKameraMP"] = 4.95

# %%
o_kontrolu_on_ucuz = df[(df["OnKameraMP"] == 0) & (df["FiyatAraligi"] == "Ucuz")& (df["3G"] == "Var")].index
o_kontrolu_on_ucuz

# %% [markdown]
# Bir önceki sorgumuza geri dönüp neler yapabiliriz bir bakalım.

# %%
o_kontrolu_on_ucuz = df[(df["OnKameraMP"] == 0) & (df["FiyatAraligi"] == "Ucuz")]
o_kontrolu_on_ucuz

# %% [markdown]
# Burada arka kamera değerlerini kriter olarak alacağım. Arka kamera degeri 10 üstü olanlarda bir ihtimal de olsa ön kamera vardır diyerek devam edip gerekli işlemleri yapalım.

# %%
o_kontrolu_on_ucuz = df[(df["OnKameraMP"] == 0) & (df["FiyatAraligi"] == "Ucuz")& (df["ArkaKameraMP"] > 10)].index
o_kontrolu_on_ucuz

# %%
df.loc[o_kontrolu_on_ucuz,"OnKameraMP"] = 4.95

# %%
o_kontrolu_on_ucuz = df[(df["OnKameraMP"] == 0) & (df["FiyatAraligi"] == "Ucuz")]
o_kontrolu_on_ucuz

# %% [markdown]
# Kalanların ön kameraya sahip olması için bir sebep yok. Bu yüzden bunları 0 olarak bırakacağım.

# %% [markdown]
# Çok ucuz ile devam edelim.

# %%
o_kontrolu_on_cok_ucuz = df[(df["OnKameraMP"] == 0) & (df["FiyatAraligi"] == "Çok Ucuz")]
o_kontrolu_on_cok_ucuz

# %% [markdown]
# Daha önce de yaptığımız gibi 4g ve 3g üzerinden gideceğim. Wifi durumu da olabilir fakat onu tek özniteliğe bağlı kullanmak bu kategori açısından yanıltıcı olacaktır. Duruma göre ek parametre kullanılabilir.

# %%
o_kontrolu_on_cok_ucuz = df[(df["OnKameraMP"] == 0) & (df["FiyatAraligi"] == "Çok Ucuz")& (df["4G"] == "Var")].index
o_kontrolu_on_cok_ucuz

# %% [markdown]
# Ortalamaları alıp doldurmaya başlayalım.

# %%
df.groupby("FiyatAraligi").mean()

# %%
df.loc[o_kontrolu_on_cok_ucuz,"OnKameraMP"] = 4

# %% [markdown]
# 3g ile davam edelim.

# %%
o_kontrolu_on_cok_ucuz = df[(df["OnKameraMP"] == 0) & (df["FiyatAraligi"] == "Çok Ucuz")& (df["3G"] == "Var")].index
o_kontrolu_on_cok_ucuz

# %%
df.loc[o_kontrolu_on_cok_ucuz,"OnKameraMP"] = 4

# %% [markdown]
# Verimize tekrar bakalım.

# %%
o_kontrolu_on_cok_ucuz = df[(df["OnKameraMP"] == 0) & (df["FiyatAraligi"] == "Çok Ucuz")]
o_kontrolu_on_cok_ucuz

# %% [markdown]
# Sonraki adımımız için arka kamera özniteliği ile çalışacağım. Hatırlamak adına kategoriksel ortalamalara tekrar bakalım.

# %%
df.groupby("FiyatAraligi").mean()

# %% [markdown]
# Cok ucuz kategorisinin arka kamera ortalaması 9.5. Buraya bakarak bu ortalama altında on kamerası olmayan telefonları doğal karşılamak mümkün.

# %%
o_kontrolu_on_cok_ucuz = df[(df["OnKameraMP"] == 0) & (df["FiyatAraligi"] == "Çok Ucuz")& (df["ArkaKameraMP"] > 9)].index
o_kontrolu_on_cok_ucuz

# %% [markdown]
# Bu verileri de dolduralım ve kalanları 0 olarak bırakalım.

# %%
df.loc[o_kontrolu_on_cok_ucuz,"OnKameraMP"] = 4

# %%
o_kontrolu_on_cok_ucuz = df[(df["OnKameraMP"] == 0) & (df["FiyatAraligi"] == "Çok Ucuz")]
o_kontrolu_on_cok_ucuz

# %% [markdown]
# 0 kontrolümüze devam edelim.

# %%
o_kontrolu_on_ucuz = df[(df["DahiliBellek"] == 0)]
o_kontrolu_on_ucuz

# %%
o_kontrolu = df[(df["Kalinlik"] == 0)]
o_kontrolu

# %%
o_kontrolu = df[(df["Agirlik"] == 0)]
o_kontrolu

# %%
o_kontrolu = df[(df["CekirdekSayisi"] == 0)]
o_kontrolu

# %%
o_kontrolu = df[(df["ArkaKameraMP"] == 0)]
o_kontrolu

# %% [markdown]
# Görüyoruz ki 101 tane eksik verimiz var. Bunları fiyatlarına göre kategorize edelim. Pahalı ve normal olanları direkt ortalama ile doldurup geçeceğim. ucuz ve çok ucuz olanlarda ise diğer özniteliklerden faydalanacağım.

# %%
o_kontrolu_arka_pahali = df[(df["ArkaKameraMP"] == 0) & (df["FiyatAraligi"] == "Pahalı")].index
o_kontrolu_arka_pahali

# %%
df.groupby("FiyatAraligi").mean()

# %%
df.loc[o_kontrolu_arka_pahali,"ArkaKameraMP"] = 10.1

# %% [markdown]
# Normal olanlar ile devam edelim.

# %%
o_kontrolu_arka_normal = df[(df["ArkaKameraMP"] == 0) & (df["FiyatAraligi"] == "Normal")].index
o_kontrolu_arka_normal

# %%
df.loc[o_kontrolu_arka_normal,"ArkaKameraMP"] = 10

# %% [markdown]
# Sırada ucuz var. Burada eğer ihtiyacım olursa diğer özniteliklerden faydalanacağım.

# %%
o_kontrolu_arka_ucuz = df[(df["ArkaKameraMP"] == 0) & (df["FiyatAraligi"] == "Ucuz")]
o_kontrolu_arka_ucuz

# %% [markdown]
# Yorumlayacak olursak cihazlarda arka kamera olmaması için belirgin bir sebep yok. Hepsinde olabilir.

# %%
df.groupby("FiyatAraligi").mean()

# %%
o_kontrolu_arka_ucuz = df[(df["ArkaKameraMP"] == 0) & (df["FiyatAraligi"] == "Ucuz")].index
o_kontrolu_arka_ucuz

# %%
df.loc[o_kontrolu_arka_ucuz,"ArkaKameraMP"] = 9.9

# %% [markdown]
# Kontrol edelim.

# %%
o_kontrolu_arka_ucuz = df[(df["ArkaKameraMP"] == 0) & (df["FiyatAraligi"] == "Ucuz")& (df["WiFi"] == "Var")].index
o_kontrolu_arka_ucuz

# %% [markdown]
# Arka kamera değeri 0 olanlar için çok ucuz kategorisi ile devam edelim.

# %%
o_kontrolu_arka_cok_ucuz = df[(df["ArkaKameraMP"] == 0) & (df["FiyatAraligi"] == "Çok Ucuz")]
o_kontrolu_arka_cok_ucuz

# %% [markdown]
# Burada 4g ve 3g öznitelikleri ile başlayacağım. Bu iki özniteliğe sahip olduktan sonra arka kameranın olmaması söz konusu bile olamaz.

# %%
o_kontrolu_arka_cok_ucuz = df[(df["ArkaKameraMP"] == 0) & (df["FiyatAraligi"] == "Çok Ucuz")& (df["4G"] == "Var")].index
o_kontrolu_arka_cok_ucuz

# %% [markdown]
# Ortalamalarımızı hatırlayalım ve verileri dolduralım.

# %%
df.groupby("FiyatAraligi").mean()

# %%
df.loc[o_kontrolu_arka_cok_ucuz,"ArkaKameraMP"] = 9.5

# %% [markdown]
# 3g ile devam edelim.

# %%
o_kontrolu_arka_cok_ucuz = df[(df["ArkaKameraMP"] == 0) & (df["FiyatAraligi"] == "Çok Ucuz")& (df["3G"] == "Var")].index
o_kontrolu_arka_cok_ucuz

# %%
df.loc[o_kontrolu_arka_cok_ucuz,"ArkaKameraMP"] = 9.5

# %% [markdown]
# Verilerimize tekrar bakalım.

# %%
o_kontrolu_arka_cok_ucuz = df[(df["ArkaKameraMP"] == 0) & (df["FiyatAraligi"] == "Çok Ucuz")]
o_kontrolu_arka_cok_ucuz

# %%
o_kontrolu_arka_cok_ucuz = df[(df["ArkaKameraMP"] == 0) & (df["FiyatAraligi"] == "Çok Ucuz")].index
o_kontrolu_arka_cok_ucuz

# %% [markdown]
# Kalan verilerin çekirdek sayılarına bakılırsa arka kameraya sahip olmamaları için bir sebep yok fakat özellik olarak düşük cihazlar olduğunu söylemek mümkün. Bu yüzden ortalama altında olan değerleri vereceğim.

# %%
df.loc[o_kontrolu_arka_cok_ucuz,"ArkaKameraMP"] = 5

# %% [markdown]
# Arka kamera ile ilgili işimiz de bitti. 0 kontrolümüze devam edelim.

# %%
o_kontrolu = df[(df["CozunurlukYükseklik"] == 0)]
o_kontrolu

# %% [markdown]
# Buraya baktığımızda bir değer pahalı ve diğeri ise ucuz kategorisinde. İlgili kategorilerin ortalamaları ile dolduralım.

# %%
df.groupby("FiyatAraligi").mean()

# %%
df.loc[662,"CozunurlukYükseklik"] = 666

# %%
df.loc[856,"CozunurlukYükseklik"] = 744

# %% [markdown]
# Kontrol edelim ve diğer 0 sorguları ile ilerleyelim.

# %%
o_kontrolu = df[(df["CozunurlukYükseklik"] == 0)]
o_kontrolu

# %%
o_kontrolu = df[(df["CozunurlukGenislik"] == 0)]
o_kontrolu

# %%
o_kontrolu = df[(df["BataryaOmru"] == 0)]
o_kontrolu

# %% [markdown]
# Sırada kategorik değişkenleri süreklilere dönüştürmek var.

# %%
df.head()

# %% [markdown]
# Bluetooth özniteliği ile başlayalım. Etiket encoderımızı yaratalım ve ilgili öznitelğimizi sürekli hale getirelim.

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
df['Bluetooth'] = label_encoder.fit_transform(df['Bluetooth'])
df.head()

# %% [markdown]
# Görüyoruz ki 0-1'leri ters koyduk. Hemen bunu düzeltelim

# %%
blue_1_olanlar = df[(df["Bluetooth"] == 1)].index
blue_0_olanlar = df[(df["Bluetooth"] == 0)].index
df.loc[blue_1_olanlar,"Bluetooth"] = 0
df.loc[blue_0_olanlar,"Bluetooth"] = 1

# %%
df.head()

# %% [markdown]
# Sorunu çözdük. Diger kategorik değişkenlerimizle ilerleyelim.

# %%
df['4G'] = label_encoder.fit_transform(df['4G'])
df.head()

# %% [markdown]
# Aynı hata oldu. Aynı işlemleri gerçekleştirip düzeltiyorum.

# %%
dortg_1_olanlar = df[(df["4G"] == 1)].index
dortg_0_olanlar = df[(df["4G"] == 0)].index
df.loc[dortg_1_olanlar,"4G"] = 0
df.loc[dortg_0_olanlar,"4G"] = 1

# %%
df.head()

# %% [markdown]
# Bunu da düzelttik. Devam edelim.

# %%
df['WiFi'] = label_encoder.fit_transform(df['WiFi'])
df.head()

# %%
wifi_1_olanlar = df[(df["WiFi"] == 1)].index
wifi_0_olanlar = df[(df["WiFi"] == 0)].index
df.loc[wifi_1_olanlar,"WiFi"] = 0
df.loc[wifi_0_olanlar,"WiFi"] = 1
df.head()

# %%
df['3G'] = label_encoder.fit_transform(df['3G'])
df.head()

# %%
ucg_1_olanlar = df[(df["3G"] == 1)].index
ucg_0_olanlar = df[(df["3G"] == 0)].index
df.loc[ucg_1_olanlar,"3G"] = 0
df.loc[ucg_0_olanlar,"3G"] = 1
df.head()

# %%
df['Dokunmatik'] = label_encoder.fit_transform(df['Dokunmatik'])
df.head()

# %%
dokunmatik_1_olanlar = df[(df["Dokunmatik"] == 1)].index
dokunmatik_0_olanlar = df[(df["Dokunmatik"] == 0)].index
df.loc[dokunmatik_1_olanlar,"Dokunmatik"] = 0
df.loc[dokunmatik_0_olanlar,"Dokunmatik"] = 1
df.head()

# %%
df['CiftHat'] = label_encoder.fit_transform(df['CiftHat'])
df.head()

# %%
cifthat_1_olanlar = df[(df["CiftHat"] == 1)].index
cifthat_0_olanlar = df[(df["CiftHat"] == 0)].index
df.loc[cifthat_1_olanlar,"CiftHat"] = 0
df.loc[cifthat_0_olanlar,"CiftHat"] = 1
df.head()

# %% [markdown]
# Sıra geldi verimizi eğitmeye.İlk olarak Gaussian nb train test split metodunu kullancağız. Ardından etkisi az olan özniteliği, öznitelikleri çıkartıp skorlarımızı kontrol edeceğiz. Gerekli modülleri ekleyerek devam edelim.

# %%
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.metrics import roc_auc_score, roc_curve, recall_score, f1_score, precision_score
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# Hatırlayalım, renk değişkenimizi çıkaracaktık. Hemen ardından bağımlı ve bağımsız değişkenlerimizi ayıralım.

# %%
df.drop("Renk", axis = 1, inplace = True)## Renk ile fiyatın alakalı olma durumunu elediğimiz için renk öznieliğini 
#veri setinden çıkartıyoruz.
y = df['FiyatAraligi']
X = df.drop(['FiyatAraligi'], axis=1)
df.head()

# %%
y.head()

# %%
X.head()

# %%
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y, 
                                                    test_size = 0.25, 
                                                    random_state = 42)

# %% [markdown]
# Her bir yeni veri setimizin sayılarını kontrol ederek devam edelim.

# %%
X_train.info() # x train veri setimiz 1500 gözlemden oluşuyor.

# %%
X_test.info() # x test veri setimiz ise 500 gözlem içeriyor. %25 olduğunu buradan da görüyoruz.

# %%
y_train.value_counts() # Bagımlı değişken olan y değerimiz sürekli olmadığı için info fonksiyonunu kullanmayıp 
#value_counts kullanıyoruz

# %%
y_test.value_counts() # y train ile y testi karşılaştırdığımızda yine %25 olduğunu görüyoruz.

# %%
df.head()

# %% [markdown]
# GaussianNb modelini yaratıp eğitim verileri ile eğitelim.

# %%
nb = GaussianNB()
nb_model = nb.fit(X_train, y_train)

# %% [markdown]
# Modelimizi eğittik. Sıra tahmin ettirmeye geldi. 10 adet veriyi tahmin etmesini isteyelim. Bunu yaparken de tahminlerimizi bir arraye atalım ki ileride skorlarını görüntülerken lazım olacak.

# %%
fiyat_tahmin_nb = nb_model.predict(X_test)

# %% [markdown]
# Sıra geldi confusion matrix skoru olan accuracy değerini görüntülemekte.

# %%
accuracy_score(y_test, fiyat_tahmin_nb)

# %% [markdown]
# 0.81 çok da iyi değil. Bunu geliştirmeliyiz. Ama önce kontrol amaçlı karmaşıklık matrisimizi çizdirelim.

# %%
karmasiklik_matrisi = confusion_matrix(y_test, fiyat_tahmin_nb)
print(karmasiklik_matrisi)

# %% [markdown]
# Hatırlayalım ki fiyat kategorimizin sırası normal, pahalı, ucuz ve çok ucuz olarak gidiyordu. İlk satir için normal ve son satır için çok ucuz dersek en fazla başarıyı çok ucuz kategorisinde gösterdiğini söylemek mümkün. Bu tarz başarılar durumlarını sınıflandırma raporunda da göreceğiz.

# %% [markdown]
# Cross validation değerine geçelim. Farklı gözlemlerle deneyip skora tekrar bakalım.(cv atlanan veri sayısını gösteriyor.)

# %%
cross_val_score(nb_model, X_test, y_test, cv = 10)

# %% [markdown]
# Şimdi de bunların ortalamasını alalım.

# %%
cross_val_score(nb_model,X_test, y_test, cv = 10).mean()

# %% [markdown]
# Accuracy skorumuz ile neredeyse aynı.

# %% [markdown]
# Kesinlik skorumuzu yazdırarak skorları yazdırmaya devam edelim.

# %%
PrecisionScore = precision_score(y_test, fiyat_tahmin_nb, average='weighted')
PrecisionScore

# %% [markdown]
# Accuracy skorumuz ile neredeyse aynı. Sırada hassaslık - yakalama skoru var.

# %%
RecallScore = recall_score(y_test, fiyat_tahmin_nb, average='weighted')
RecallScore

# %% [markdown]
# F1 skorumuza da bakalım.

# %%
F1Score = f1_score(y_test, fiyat_tahmin_nb, average = 'weighted')  
F1Score

# %% [markdown]
# Bagımlı degiskenimiz çok kategorili oldugu için roc auc skorunu görüntüleyemedik.

# %% [markdown]
# Sıra geldi sınıflandırma raporumuza.

# %%
print(classification_report(y_test, fiyat_tahmin_nb))

# %% [markdown]
# Görüyoruz ki tahminlerimiz çok ucuz ve pahalı ürünlerde neredeyse tamamen doğru. Ucuz ve normal kategorileri için ise yine de kabul edilebilir bir düzeyde. Precision ve recall değerlerinin de kafa kafaya gittiğini görüyoruz. Demek ki yanlış pozitif ve yanlış negatif sayıları da birbirine çok yakın. Precision ve recall skorlarını tek bakışta görebileceğimiz f1 skorlarımızın değerleri de öngörülebilir seviyede.

# %% [markdown]
# Hangi özniteliğin ne kadar etkilediğini öğreneceğimiz öznitelik budama işlemine geçelim.

# %% [markdown]
# Gerekli modülleri ekleyerek devam edelim.

# %%
from numpy import set_printoptions
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif

test = SelectKBest(score_func = f_classif, k = 'all')

# %% [markdown]
# Verimizi fit edelim.

# %%
fit = test.fit(X, y)

# %%
fit # k parametremizin all olduğunu görüyoruz.

# %%
set_printoptions(precision = 3)
print(fit.scores_.astype(int))

# %% [markdown]
# Burada her özniteliğin ne etkide bağımlı değişkeni etkilediğini görüyoruz.

# %%
X.columns

# %% [markdown]
# Verilere baktığımızda fiyat aralığını en çok etkileyen özniteliğin ram olduğunu, ardından batarya gücü ve çözünürlüğün genişlik değeri olduğunu görüyoruz. En çok etkileyenler ile devam edelim.

# %%
y = df['FiyatAraligi']
X = pd.concat([df["RAM"],df["BataryaGucu"], df["CozunurlukGenislik"],df["CozunurlukYükseklik"],df["Agirlik"]], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y, 
                                                    test_size = 0.25, 
                                                    random_state = 42)

# %% [markdown]
# Setimizi tekrar eğitelim ve skoruna bakalım. Gaussian modelimizi oluşturarak başlayalım.

# %%
nb = GaussianNB()
nb_model = nb.fit(X_train, y_train)

# %% [markdown]
# Modelimizi egittik.

# %%
nb_model # priors özelliğinin none olduğunu görüyoruz.

# %%
fiyat_tahmini_nb_sifirsiz= nb_model.predict(X_test)

# %% [markdown]
# Tahmin edilen değerlerimizi bir arraye atıyoruz ki matris çizdirirken ve diğer yerlerde lazım olacak.

# %%
accuracy_score(y_test, fiyat_tahmini_nb_sifirsiz)

# %% [markdown]
# Etkisi olmayanları ve çok az olanları çıkardığımızdaki skorumuz 0.81. Peki etkisi 0 olan öznitelikleri çıkarmadan önceki skorumuz kaçtı?

# %%
accuracy_score(y_test, fiyat_tahmin_nb)

# %% [markdown]
# Skorumuzun biraz da olsa arttığını söylemek mümkün. Peki karmaşıklık matrisimizde neleri söyleyebiliriz?

# %%
karmasiklik_matrisi = confusion_matrix(y_test, fiyat_tahmini_nb_sifirsiz)
print(karmasiklik_matrisi)

# %% [markdown]
# Hatırlayalım ki fiyat kategorimizin sırası normal, pahalı, ucuz ve çok ucuz olarak gidiyordu. İlk satir için normal ve son satır için çok ucuz dersek en fazla başarıyı çok ucuz kategorisinde gösterdiğini söylemek mümkün. Hemen arkasından pahalı kategorisindeki başarı geliyor. Budama öncesindeki skorlara kıyasla daha yüksek başarılar elde ettik.

# %% [markdown]
# Bir de çapraz değişkenlemeye sokalım ve skorunu gözlemleyelim.

# %%
cross_val_score(nb_model, X_test, y_test, cv = 10) # 10 veri atlayarak test ettik.

# %%
cross_val_score(nb_model, X_test, y_test, cv = 10).mean() ## verilerimizin ortalamlarını alalım. Ve sonucumuzu skorumuz ile karşılaştıralım.

# %% [markdown]
# Hemen hemen aynı.

# %% [markdown]
# Kesinlik skorumuza tekrar bakalım.

# %%
PrecisionScore = precision_score(y_test, fiyat_tahmini_nb_sifirsiz, average='weighted')
PrecisionScore

# %% [markdown]
# Hassaslık - yakınlık skorumuza tekrar bakalım.

# %%
RecallScore = recall_score(y_test, fiyat_tahmini_nb_sifirsiz, average='weighted')
RecallScore

# %% [markdown]
# Son olarak f1 skorumuza da tekrardan bakalım.

# %%
F1Score = f1_score(y_test, fiyat_tahmini_nb_sifirsiz, average = 'weighted')  
F1Score

# %% [markdown]
# Skorlarımızın confusion matrix skoru olan accuracy değeri ile uyuştuğunu görüyoruz.

# %% [markdown]
# Raporlamayı unutmamak lazım.

# %%
print(classification_report(y_test,fiyat_tahmini_nb_sifirsiz))

# %% [markdown]
# Etkisi düşük olan ya da etkisi hiç olmayan öznitelikleri çıkarttığımızda skorlarımız genel olarak çok az da olsa arttı . Pahalı ve çok ucuz kategorisindeki başarı artarak devam ederken normal ve ucuz olanlar o kadar başarılı değil.

# %% [markdown]
# Karşılaştırmak için öznitelik seçmeden yaptığımız modelin raporlamasını da alta alalım ve öyle karşılaştıralım.

# %%
print(classification_report(y_test, fiyat_tahmin_nb)) # Bir önceki raporlama

# %% [markdown]
# Bir diğer algoritmamız olan karar ağaçları ile devam edelim. Gerekli modülleri ekleyerek başlayalım.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import recall_score, f1_score, precision_score
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn import ensemble
from sklearn.metrics import confusion_matrix as cm
from matplotlib.legend_handler import HandlerLine2D

# %%
df.head()

# %% [markdown]
# Bağımlı ve bağımsız değişkenlere ayırarak başlayalım.

# %%
y = df["FiyatAraligi"]
X = df.drop(["FiyatAraligi"], axis=1)

# %%
y.head()

# %%
y.value_counts() # dagılımın dengeli olduğunu görüyoruz.

# %%
sns.countplot(x = "FiyatAraligi", data = df)

# %%
X.head()

# %%
X.sample()

# %%
X_train.sample() # kontrol amaçlı kullandım.

# %%
y_test.sample() # kontrol amaçlı kullandım.

# %% [markdown]
# Verilerimizi test ve eğitim olarak bölelim.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.25, 
                                                    random_state=42)

# %% [markdown]
# Modelimiz için kritik parametreleri girip modeli inşa edelim.

# %%
cart_grid = {"max_depth": range(1,20),
            "min_samples_split" : range(2,50)}

# %%
cart = DecisionTreeClassifier(random_state = 42 ,criterion="gini")
cart_cv = GridSearchCV(cart, cart_grid, cv = 10, n_jobs = -1, verbose = 2)

# %%
cart_cv_model = cart_cv.fit(X_train, y_train)# Parametre iyileştirmesi yapabilmek için ilk eğitimimiz.

# %% [markdown]
# Şimdi de modelin en iyi parametrelerine bakıp parametre iyileştirmesi yapalım. Skorumuzu arttırmak için önemli bir adım.

# %%
print("En iyi parametreler : " + str(cart_cv_model.best_params_))
print("En iyi skor : " + str(cart_cv_model.best_score_))

# %%
cart = DecisionTreeClassifier(max_depth = 8, min_samples_split = 2)
cart_tuned = cart.fit(X_train, y_train)

# %% [markdown]
# Kolon adlarımızı  vererek ağacı biraz daha anlaşılır kılacak bir görüntülemeyle devam edelim. Gerekli modülü import edip kolon isimlerimizi verelim.

# %%
X.columns

# %%
from sklearn.tree.export import export_text
r = export_text(cart, feature_names = ['BataryaGucu', 'Bluetooth', 'MikroislemciHizi', 'CiftHat', 'OnKameraMP',
       '4G', 'DahiliBellek', 'Kalinlik', 'Agirlik', 'CekirdekSayisi',
       'ArkaKameraMP', 'CozunurlukYükseklik', 'CozunurlukGenislik', 'RAM',
       'BataryaOmru', '3G', 'Dokunmatik', 'WiFi'])
print(r)

# %% [markdown]
# Artık daha anlaşılır bir görünümümüz var. Ramin çok kritik bir ayraç olduğunu söyleyebiliriz. Ramden sonra çözünürlük ve batarya gücünün bu derece etkili olması gözümüzden kaçmıyor.Sırada graphviz yardımı ile görselleştirmek var. Os modülümüzü projeye dahil edip dosya konumu verdikten sonra graphviz için gereken son eklemeleri yapalım.

# %%
import os
os.environ["PATH"] += os.pathsep + 'C:\Program Files (x86)\Graphviz2.38\bin'
os.environ["PATH"]

# %%
from sklearn.tree import export_graphviz
from sklearn import tree
from IPython.display import SVG
from graphviz import Source
from IPython.display import display

graph = Source(tree.export_graphviz(cart, out_file = None, feature_names = X.columns, filled = True))
display(SVG(graph.pipe(format = 'svg')))

# %% [markdown]
# Ağac dallarını metinselleştirdiğimiz bir önceki görünüme göre daha anlaşılır bir görsele bakıyoruz. Yine ram ve batarya gücünün oldukça ayırt edici olduğunu söyleyebiliriz. Sırada modelimizi deneyip tahminlerimizi alalım.

# %%
y_pred = cart_tuned.predict(X_test)

# %% [markdown]
# Peki bu tahminlerin accuracy skoru kaç?

# %%
accuracy_score(y_test, y_pred)

# %% [markdown]
# Karmaşıklık matrisimiz ile devam edelim.

# %%
karmasiklik_matrisi = confusion_matrix(y_test, y_pred)
print(karmasiklik_matrisi)

# %% [markdown]
# Hatırlayalım ki fiyat kategorimizin sırası normal, pahalı, ucuz ve çok ucuz olarak gidiyordu. İlk satir için normal ve son satır için çok ucuz dersek en fazla başarıyı çok ucuz kategorisinde gösterdiğini söylemek mümkün.

# %% [markdown]
# Çapraz validasyon ile rastgele verilerle skoru tekrar hesaplayalım.

# %%
cross_val_score(cart_tuned, X_test, y_test, cv = 10)

# %%
cross_val_score(cart_tuned, X, y, cv = 10).mean()

# %% [markdown]
# Accuracy skorunu ile aynı diyebileceğimiz bir değer elde ettik.

# %% [markdown]
# Sınıflama raporumuza bakalım.

# %%
print(classification_report(y_test, y_pred))

# %% [markdown]
# [](http://)Çok ucuz ve pahalı olanları tahmin etmede oldukça başarılı olduğunu söyleyebiliriz. Diğer kategorilerde de tatmin edici olsa da çok başarılı olmadı.

# %% [markdown]
# Peki karar aşamasında hangi öznitelik ne kadar etkili?

# %%
ranking = cart.feature_importances_
features = np.argsort(ranking)[::-1][:10]
columns = X.columns

plt.figure(figsize = (16, 9))
plt.title("Karar Ağacına Göre Özniteliklerin Önem Derecesi", y = 1.03, size = 18)
plt.bar(range(len(features)), ranking[features], color="lime", align="center")
plt.xticks(range(len(features)), columns[features], rotation=80)
plt.show()

# %% [markdown]
# Gnb kısmından da hatırlayacağımız, hatta ağacımızı text ve görsel olarak görüntüledeğimizde de aynı sonuçları aldığımız gibi burada da ramin farkla en etkili karar verme faktörünü olduğunu görüyoruz.

# %% [markdown]
# Biliyoruz ki karar ağacının default parametresi gini. Bunu entropy yaparsak daha başarılı olacağımızı söyleyen patronumuzu dikkate alalım ve entropy ile ilerleyip skorlarımı karşılaştıralım. Önce gini kullandığımızdaki skorlara tekrar bakalım. Ardından entropy ile işlemlerimizi tekrarlayalım.

# %%
print(classification_report(y_test, y_pred)) # Gini parametremizin verdiği sonuçlar

# %% [markdown]
# Alışık olduğumuz üzere çok ucuz ve pahalı kategorisindeki yüksek skorlarımızı görmeye devam ediyoruz. Normal için biraz daha yol almamız gerekirken ucuz kategorisi için ise yavaş yavaş tatmin edici sonuçlar almaya başladığımızı söylemek yanlış olmaz.

# %% [markdown]
# Kullanacağımız veri setlerini ayıralım.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.25, 
                                                    random_state=42)

# %%
cart_grid = {"max_depth": range(1,20),
            "min_samples_split" : range(2,50)}

# %% [markdown]
# Gerekli parametreleri verip entropy parametremizi tanımlayalım.

# %%
cart = DecisionTreeClassifier(random_state = 42, criterion="entropy")
cart_cv = GridSearchCV(cart, cart_grid, cv = 10, n_jobs = -1, verbose = 2)

# %% [markdown]
# Modelimizi eğitim verileri ile en iyi parametreleri almak için fitleyelim.

# %%
cart_cv_model = cart_cv.fit(X_train, y_train)

# %%
cart = DecisionTreeClassifier(max_depth = 8, min_samples_split = 2) # Gini ile aldığımız en iyi parametreler bilgisinde dolduruldu.
cart_tuned = cart.fit(X_train, y_train)

# %%
y_pred_ent = cart_tuned.predict(X_test)

# %%
accuracy_score(y_test, y_pred_ent) ## entropy skoru

# %%
accuracy_score(y_test, y_pred) ## gini skoru

# %% [markdown]
# Patron haklıymış. Entropy ile biraz da olsa daha başarılı olduk.

# %%
karmasiklik_matrisi = confusion_matrix(y_test, y_pred_ent)
print(karmasiklik_matrisi)

# %% [markdown]
# Hatırlayalım ki fiyat kategorimizin sırası normal, pahalı, ucuz ve çok ucuz olarak gidiyordu. İlk satir için normal ve son satır için çok ucuz dersek en fazla başarıyı yine çok ucuz kategorisinde gösterdiğini söylemek mümkün. Bunun yanında normal ve ucuz kategorilerinde de oldukça tatmin edici veriler görüyoruz.

# %%
print(classification_report(y_test, y_pred_ent)) # entropy parametremizin verdigi sonuclar

# %%
print(classification_report(y_test, y_pred)) # Gini parametremizin verdiği sonuçlar

# %% [markdown]
# Entropy ile normal, ucuz ve çok ucuz kategorisindeki cihazların skorlarında bir artma meydana geldi. Patron haklıymış.

# %% [markdown]
# Son olarak en yakın komşu (knn) modeli ile eğitelim. İlk parametre ayarlarını yaparak devam edelim ve parametre geliştirmesi için ilk tahminlerimizi yaptıralım.

# %%
knn_params = {"n_neighbors": np.arange(1,15)} # Komşularda 1'den başlayıp 14'e kadar hepsini deneyecek.

# %%
knn = KNeighborsClassifier()
knn_cv = GridSearchCV(knn, knn_params, cv = 3)
knn_cv.fit(X_train, y_train)

# %% [markdown]
# İlk tahminimizi yaptırdık. Bu tahmin için en iyi parametreleri görüntüleyelim.

# %%
print("En iyi skor: " + str(knn_cv.best_score_))
print("En iyi parametreler: " + str(knn_cv.best_params_))

# %% [markdown]
# Görüyoruz ki en yakın komşu numarası 9.

# %% [markdown]
# 9 numaralı komşuya göre eğittikten sonra tahminlerimizi alıp doğruluk(accuracy) skorumuza bakalım.

# %%
knn = KNeighborsClassifier(9)
knn_tuned = knn.fit(X_train, y_train)

# %%
y_pred = knn_tuned.predict(X_test)

# %%
accuracy_score(y_test, y_pred)

# %% [markdown]
# Oldukça tatmin edici bir skor. Peki bu komşu değerini nasıl seçti? Görselleştirmeden yardım alalım.

# %%
karmasiklik_matrisi = confusion_matrix(y_test, y_pred)
print(karmasiklik_matrisi)

# %% [markdown]
# Çok ucuz kategorisinin baskınlığının sürdüğünü söylemek mümkün. Bunun yanında diğer kategoriler için de tatmin edici denilebilir.

# %%
score_list = []

for each in range(1,30):
    knn2 = KNeighborsClassifier(n_neighbors = each)
    knn2.fit(X_train,y_train)
    score_list.append(knn2.score(X_test, y_test))
    
plt.plot(range(1,30),score_list)
plt.xlabel("k değerleri")
plt.ylabel("doğruluk skoru")
plt.show()

# %% [markdown]
# Grafiğe baktığmız zaman en iyi komşunun 11 olduğunu görüyoruz. Fakat bize 9 olduğu sonucu gelmişti. Hangi komşuda hangi skoru alacağımızı daha rahat görmek için 2-15 arasındaki komşuların değerlerini  görselleştirme yaparak devam edelim.

# %%
komsu_indeksleri = []
skorlar = []
temp = 2
while temp <= 15:
    knn = KNeighborsClassifier(temp)
    knn_tuned = knn.fit(X_train, y_train)
    y_pred = knn_tuned.predict(X_test)
    komsu_indeksleri.append(temp)
    skorlar.append(accuracy_score(y_test, y_pred))
    temp +=1
        
komsular = pd.DataFrame({'Komşu İndeksi':komsu_indeksleri, 
                    'Skor':skorlar})

# %% [markdown]
# Komsu indislerini ve skorlarını tutmak için birer arrayimiz var. While ile on beşe kadar dönüp her indeks için eğitimimizi yapıp verileri arraylere atıyoruz. Ardından komsular adlı dataframe içine atıyoruz ki görselleştirken kullanabilelim.

# %%
sns.lmplot(x = "Komşu İndeksi", y = "Skor", data = komsular)

# %%
sns.scatterplot(x = "Komşu İndeksi", y = "Skor", data = komsular)

# %% [markdown]
# Score_list görünümününden farklı olarak üst sınırı 15 olarak ayarlandı. Buraya baktığımızda en iyi parametreleri almak için eğittiğimiz ilk modelin en iyi komşusunun indeksi 9 idi. Fakat burada da 11.komşunun daha iyi bir skor verdiğini görüyoruz. Bu yüzden komşu parametremi 11 olarak güncelliyorum.

# %%
knn = KNeighborsClassifier(11)
knn_tuned = knn.fit(X_train, y_train)

# %%
y_pred = knn_tuned.predict(X_test)

# %%
accuracy_score(y_test, y_pred)

# %% [markdown]
# Neredeyse %94'lük bir başarısı var. Kesinlikle tatmin edici bir değer.

# %% [markdown]
# Sınıflandırma raporuna bakarak sonlandıralım.

# %%
print(classification_report(y_test, y_pred))

# %% [markdown]
# Neresinden bakarsak bakalım en iyisinin knn olduğunu anladık. Karşılaştırmak için karar ağaçlarında daha iyi sonuç aldığımız entropy parametreli sınıflandırma raporunu da bir alta ekliyorum.

# %%
print(classification_report(y_test, y_pred_ent))
