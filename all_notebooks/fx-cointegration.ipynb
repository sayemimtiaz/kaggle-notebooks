# %%
import numpy as np 
import pandas as pd 
import os

from statsmodels.tsa.stattools import grangercausalitytests as granger

# %% [markdown]
# This is work in progress - I want to test Granger causality across a range of FX time series.

# %%
xdat = pd.read_csv('../input/foreign-exchange-rates-2003-2021/combined_data.csv')
xdat.columns
