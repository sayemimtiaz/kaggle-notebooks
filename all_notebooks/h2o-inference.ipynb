# %%
# load a saved binary h2o model and predict on test set
import h2o

# %%
# initialize the h2o cluster
h2o.init()

# %%
df = h2o.import_file(path='/kaggle/input/bank-marketing-campaigns-dataset/bank-additional-full.csv')
df_sample = df.head(5)

# %%
model = h2o.load_model('../input/automated-machine-learning-with-h2o/binary_model/StackedEnsemble_AllModels_AutoML_20210805_130512')

# %%
model.predict(df_sample)
