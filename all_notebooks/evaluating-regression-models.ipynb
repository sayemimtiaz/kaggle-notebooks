# %% [markdown]
# After completing mine **Evaluation of Classifiaction Model** Notebook (link below) I thought let's do the same for regression model.
# [https://www.kaggle.com/iabhishekmaurya/classification-model-evaluation](http://)
#
# So, I found a dataset [https://www.kaggle.com/dronio/SolarEnergy](http://)
#
# Read sklearn documentation [https://scikit-learn.org/](http://)
#
# and completed this notebook within 30mins (ofcourse I am taking about approx)🥳🥳🥳🥳🥳

# %% [markdown]
# # Evaluating Regression Models
#
# I will be using 2 different models for our datsets:
# 1. Linear Regression
# 2. RandomForestRegressor
#
# So, yeah let's start our journey🚴
#
# Before going forward :
# <font color="Red">Please Upvote ( It motivates me )</font>

# %% [markdown]
# ## Preprocesing

# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
# Reading the Dataset
train_data = pd.read_csv('../input/SolarEnergy/SolarPrediction.csv')
train_data.head()

# %% [markdown]
# ### Let's first find out details of our dataset
#
# Looking it's description, info, a head look gives us a rough idea of our data.

# %%
train_data.shape

# %%
train_data.describe()

# %% [markdown]
# ### Is there any NULL values?
#
# We hate Null values😠

# %%
train_data.isnull().sum()

# %% [markdown]
# Yeee 🤩🤩🤩
#
# We don't have it

# %%
train_data.info()

# %%
train_data.columns

# %% [markdown]
# As our focus is on model evaluation let's just drop all object columns (to make our work easy)

# %%
train_data = train_data.iloc[:,3:9]
train_data.head()

# %% [markdown]
# Let's have a look over our dependend column

# %%
train_data['Radiation'].describe()

# %%
f, ax = plt.subplots(figsize=(15,8))
sns.distplot(train_data['Radiation'])
plt.xlim([-10,1602])

# %% [markdown]
# Cleary most of data remains on the left side of plot.
#
# We have a lot of noise here, but we are neglecting it(yes accuracy would decrease), as our focus is on different evaluation measures.

# %% [markdown]
# Again let's look at our **heat map**
#
# ### 🔥Heat Map

# %%
plt.figure(figsize=(10,10))
sns.heatmap(train_data.corr(),annot=True,cmap='RdYlGn')
plt.show()

# %% [markdown]
# **Colourful NA?**
#
# I love this colour combination.
# But our Models hates and dark green accept the diagonal.

# %% [markdown]
# Now, let's differentiate our Independent and Dependend Columns follwed by spliting them to test and train

# %%
X = train_data.iloc[:,1:]
y = train_data.iloc[:,0]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 25)

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
regresor= LinearRegression()
regresor.fit(X_train, y_train)
regresor_pred = regresor.predict(X_test)

# %% [markdown]
# ## Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf_reg = RandomForestRegressor()
rf_reg.fit(X_train, y_train)
randomforest_pred= rf_reg.predict(X_test)

# %% [markdown]
# ## Evaluation (Our Finale)

# %% [markdown]
# ### Explained variance regression score
#
# Best possible score is 1.0, lower values are worse.

# %%
from sklearn.metrics import explained_variance_score
print(explained_variance_score(y_test, regresor_pred))
print(explained_variance_score(y_test, randomforest_pred))

# %% [markdown]
# ### Mean absolute error regression loss
# [https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_absolute_error.html](http://)

# %%
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(y_test, regresor_pred))
print(mean_absolute_error(y_test, randomforest_pred))

# %% [markdown]
# ## Mean squared error regression loss
# [https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html#sklearn.metrics.mean_squared_error](http://)

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, regresor_pred))
print(mean_squared_error(y_test, randomforest_pred))

# %% [markdown]
# ## Median absolute error regression loss
#
# Median absolute error output is non-negative floating point. The best value is 0.0

# %%
from sklearn.metrics import median_absolute_error
print(median_absolute_error(y_test, regresor_pred))
print(median_absolute_error(y_test, randomforest_pred))

# %% [markdown]
# ## R^2 (coefficient of determination) regression score
#
# Best possible score is 1.0 and it can be negative (because the model can be arbitrarily worse). A constant model that always predicts the expected value of y, disregarding the input features, would get a R^2 score of 0.0.
#
# [https://scikit-learn.org/stable/modules/generated/sklearn.metrics.r2_score.html#sklearn.metrics.r2_score](http://)

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test, regresor_pred))
print(r2_score(y_test, randomforest_pred))

# %% [markdown]
# We have the following more for regression model:
# * metrics.max_error(y_test, y_pred)
# * metrics.mean_squared_log_error(y_test, y_pred)
# * metrics.mean_tweedie_deviance(y_true, y_pred, \*)
# * metrics.mean_gamma_deviance(y_true, y_pred, \*)
# * metrics.mean_poisson_deviance(y_true, y_pred, \*)
#
# In future I will try to add them here.
#
# Read them out here: [https://scikit-learn.org/stable/modules/model_evaluation.html](http://)

# %% [markdown]
# So, Finally this NoteBook End here 🤵🏻
#
# Before going a humble request if you liked the notebook the
#
# <font color="Red">Please Upvote ( It motivates me )</font>
#
# <font color="Green">Do check my other notebooks: </font>
#
# [https://www.kaggle.com/iabhishekmaurya/classification-model-evaluation](http://)
# https://www.kaggle.com/iabhishekmaurya/used-car-price-prediction
# https://www.kaggle.com/iabhishekmaurya/applied-machine-learning/notebook
#
#
# Happy Coding 💻 👨‍💻
#
# LinkedIn: [https://www.linkedin.com/in/abhishek-5b642580/](http://)
