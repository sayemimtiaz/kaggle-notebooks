# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sn # data visualisation
sn.set(color_codes = True, style = "white")
import matplotlib.pyplot as ml # data visualisation
import warnings
warnings.filterwarnings("ignore")
import os
dt = pd.read_csv("../input/character-deaths.csv", sep=",", header = 0)
print(dt.shape)


# Any results you write to the current directory are saved as output.

# %% [markdown]
# **A peak at the first 10 rows of data**

# %%
dt.head(10)

# %% [markdown]
# **Comparing variables to each other**

# %%
dt .corr()

# %% [markdown]
# **Deleting gaps in variables and replacing NaN values with 0**

# %%
dt.columns = [col.replace(' ', '_').lower() for col in dt.columns]
print(dt.columns)
dt.fillna(method='bfill', inplace=True)

# %% [markdown]
# **Heatmap**

# %%
co = dt.corr()
sn.heatmap(co)

# %% [markdown]
# **Death in books. Book 3 has the highest number of deaths **

# %%
sn.distplot(dt.book_of_death)

# %% [markdown]
# Men and women in Game Of Thrones. Men are majority.

# %%
sn.countplot(data = dt, y= "gender");

# %% [markdown]
# **Year of death. 299 year was the most deadly in GoT.**

# %%
sn.distplot(dt.death_year)

# %% [markdown]
# **Nobile and non-nobile characters. Non-nobile are majority**

# %%
sn.countplot(data = dt, x= "nobility");
