# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px
import plotly.graph_objs as go

# %%
df = pd.read_csv('../input/diamonds/diamonds.csv')

# %%
df.head()

# %%
df.drop(['Unnamed: 0'] , axis=1 , inplace=True)

# %%
df.info()

# %%
df.shape

# %%
df.describe()

# %%
len(df[(df['x']==0) | (df['y']==0) | (df['z']==0)])

# %%
df = df[(df[['x','y','z']] != 0).all(axis=1)]

# %% [markdown]
#  Carat weight of the Diamond.

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['carat'], color='r')
plt.show()

# %%
fig = px.scatter(df, x='carat' , y='price')
fig.show()

# %% [markdown]
# Depth : The Height of a Diamond, measured from the Culet to the table, divided by its average Girdle Diameter.

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['depth'], color='r')
plt.show()

# %%
fig = px.scatter(df, x='depth' , y='price')
fig.show()

# %%
df = df[(df["depth"]<75)&(df["depth"]>50)]

# %%
fig = px.scatter(df, x='depth' , y='price')
fig.show()

# %% [markdown]
# Price can vary heavily for the same Depth

# %% [markdown]
# Cut : Describe cut quality of the diamond.

# %%
fig = px.pie(df, names = "cut", color_discrete_sequence=px.colors.qualitative.Set2)
fig.show()

# %%
sns.catplot(x="cut", y="price", kind="box", data=df);

# %% [markdown]
#  As we can see Premium Cut on Diamonds are the most Expensive, followed by Excellent / Very Good Cut.

# %% [markdown]
# Table : The Width of the Diamond's Table expressed as a Percentage of its Average Diameter.

# %%
fig = px.histogram(
    df, 
    "table", 
    nbins=80, 
    title ='table ', 
    width=800,
    height=500
)

fig.show()

# %%
sns.regplot(x="table", y="price", data=df)

# %% [markdown]
# The Color of a Diamond refers to the Tone and Saturation of Color, or the Depth of Color in a Diamond.

# %%
sns.countplot(df.color)

# %%
sns.catplot(x="color", y="price", kind="box", data=df);

# %% [markdown]
#  Diamond Clarity refers to the absence of the Inclusions and Blemishes.

# %%
fig = px.pie(df, names = "clarity",color_discrete_sequence=px.colors.qualitative.Set1)
fig.show()

# %%
sns.catplot(x="clarity", y="price", kind="box", data=df);

# %%
df['dimensions'] = df['x']*df['y']*df['z']

# %%
df.drop(['x','y','z'], axis=1, inplace= True)

# %%
df.head()

# %%
fig = px.histogram(
    df, 
    "dimensions", 
    nbins=50, 
    title ='dimensions ', 
    width=800,
    height=500
)

fig.show()

# %%
fig = px.scatter(df, x='dimensions' , y='price')
fig.show()

# %%
df = df[(df["dimensions"]<800)]

# %%
fig = px.scatter(df, x='dimensions' , y='price')
fig.show()

# %% [markdown]
# Correlation Between Features

# %%
fig = px.histogram(
    df, 
    "price", 
    nbins=80, 
    title ='price ', 
    width=800,
    height=500
)

fig.show()

# %%
fig = px.scatter(df, x="carat", y="depth")
fig.show()

# %%
fig = px.scatter(df, x="carat", y="table")
fig.show()

# %%
df = df[(df["table"]<90)]

# %%
fig = px.scatter(df, x="carat", y="table")
fig.show()

# %%
fig = px.scatter(df, x="carat", y="dimensions")
fig.show()

# %%
df = df[(df["dimensions"]<800)]

# %%
fig = px.scatter(df, x="carat", y="dimensions")
fig.show()

# %%
fig = px.scatter(df, x="depth", y="table")
fig.show()

# %%
fig = px.scatter(df, x="table", y="dimensions")
fig.show()

# %%
sns.catplot(x="cut", y="carat", kind="box", data=df)

# %%
sns.factorplot(x='depth', y='cut', data=df, kind='box' ,aspect=1 )

# %%
sns.factorplot(x='carat', y='clarity', data=df, kind='box' ,aspect=1 )

# %%
df.corr
f,ax = plt.subplots(figsize=(30,30))
sns.heatmap(df.corr(), annot =True, linewidth =".5", fmt =".2f", cmap='cividis')
plt.show()

# %%
df=pd.get_dummies(df)
df.head()

# %%
X = df.drop(columns=["price"])
y = df["price"]

# %% [markdown]
# Splitting data

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=44, shuffle =True)

# %% [markdown]
# Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression


LinearRegressionModel = LinearRegression(fit_intercept=True, normalize=True,copy_X=True,n_jobs=-1)
LinearRegressionModel.fit(X_train, y_train)

#Calculating Details
print('Linear Regression Train Score is : ' , LinearRegressionModel.score(X_train, y_train))
print('Linear Regression Test Score is : ' , LinearRegressionModel.score(X_test, y_test))


#Calculating Prediction
y_pred = LinearRegressionModel.predict(X_test)
#print('Predicted Value for Linear Regression is : ' , y_pred[:10])
