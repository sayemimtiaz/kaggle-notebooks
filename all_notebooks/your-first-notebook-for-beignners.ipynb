# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# After running above cell copy the output which is in my case is "/kaggle/input/rainfall-in-pakistan/Rainfall_1901_2016_PAK.csv"

# %% [markdown]
# Now paste your filepath and save it in a variable

# %%
data="/kaggle/input/rainfall-in-pakistan/Rainfall_1901_2016_PAK.csv"

# %% [markdown]
# Reading our data

# %% [markdown]
# using pd.read_csv function

# %%
data=pd.read_csv(data)

# %% [markdown]
# Shape of our dataset

# %% [markdown]
# Our data has 1392 rows and 3 columns

# %%
data.shape

# %% [markdown]
# info function will show the data types of columns in the dataset

# %%
data.info()

# %% [markdown]
# head function will display first 5 rows of our dataset

# %%
data.head()

# %% [markdown]
# But we can also specify the number of rows

# %%
data.head(12)

# %% [markdown]
# tail function will display last 5 rows of dataset

# %%
data.tail()

# %% [markdown]
# Now we have done very basic data analysis on Pakistan rainfalls dataset
# Also take this course to learn everything in detail https://www.kaggle.com/learn/pandas
# please upvote if you liked this notebook
