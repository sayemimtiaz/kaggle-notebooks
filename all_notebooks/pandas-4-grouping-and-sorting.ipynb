# %% [markdown]
# **This notebook is an exercise in the [Pandas](https://www.kaggle.com/learn/pandas) course.  You can reference the tutorial at [this link](https://www.kaggle.com/residentmario/grouping-and-sorting).**
#
# ---

# %% [markdown]
# # 介绍
#
# 在这些练习中，我们将对数据集应用组分析。
#
# 在运行练习之前，运行下面的代码单元来加载数据。

# %%
import pandas as pd

reviews = pd.read_csv("../input/wine-reviews/winemag-data-130k-v2.csv", index_col=0)
#pd.set_option("display.max_rows", 5)

from learntools.core import binder; binder.bind(globals())
from learntools.pandas.grouping_and_sorting import *
print("Setup complete.")

# %% [markdown]
# # Exercises

# %% [markdown]
# ## 1.
# 数据集中最常见的葡萄酒审稿人是谁? 创建一个序列，其索引为数据集的taster_twitter_handle类别，其值计算每个人写了多少篇评论。

# %%
# Your code here
reviews_written = ____

# Check your answer
q1.check()

# %%
#q1.hint()
#q1.solution()

# %% [markdown]
# ## 2.
# 我能用一定数额的钱买到最好的葡萄酒是什么?创建一个系列，其指数为葡萄酒价格，其值为某款葡萄酒在评论中给出的最大点数。按价格排序，升序排列(因此4.0美元在顶部，3300.0美元在底部)。

# %%
best_rating_per_price = ____

# Check your answer
q2.check()

# %%
#q2.hint()
#q2.solution()

# %% [markdown]
# ## 3.
# 每一种葡萄酒的最低和最高价格是多少? 创建一个“DataFrame”，它的索引是来自数据集的“品种”类别，它的值是其“最小”和“最大”值。

# %%
price_extremes = ____

# Check your answer
q3.check()

# %%
#q3.hint()
#q3.solution()

# %% [markdown]
# ## 4.
# 最昂贵的葡萄酒品种是什么?创建一个变量' sorted_变种'，其中包含来自上一个问题的数据aframe的一个副本，其中变种是根据最低价格降序排序的，然后是根据最高价格排序的(为了断开连接)。

# %%
sorted_varieties = ____

# Check your answer
q4.check()

# %%
#q4.hint()
#q4.solution()

# %% [markdown]
# ## 5.
# 创建一个“系列”，其索引是评论者，其值是评论者给出的平均评分。提示:您将需要' taster_name '和' points '列。

# %%
reviewer_mean_ratings = ____

# Check your answer
q5.check()

# %%
#q5.hint()
#q5.solution()

# %% [markdown]
# 不同的审稿人给出的平均分数是否有显著差异?运行下面的单元格，使用' describe() '方法查看值范围的摘要。

# %%
reviewer_mean_ratings.describe()

# %% [markdown]
# ## 6.
# 哪种国家和品种的组合最常见?创建一个“Series”，其索引是“{国家，品种}”对的“多索引”。例如，在美国生产的黑皮诺应该映射到' {"US"， "黑皮诺"}'。将“系列”中的值根据葡萄酒数量降序排序。

# %%
country_variety_counts = ____

# Check your answer
q6.check()

# %%
#q6.hint()
#q6.solution()

# %% [markdown]
# # Keep going
#
# Move on to the [**data types and missing data**](https://www.kaggle.com/residentmario/data-types-and-missing-values).

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [Learn Discussion forum](https://www.kaggle.com/learn-forum/161299) to chat with other Learners.*
