# %%
import numpy as np 
import pandas as pd 

import os
for dirname, _, filenames in os.walk('/kaggle/input/mall-customers'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
dataset = pd.read_csv('/kaggle/input/mall-customers/Mall_Customers.csv')
dataset.head()

# %%
import matplotlib.pyplot as plt

# %%
len(datasetset)

# %%
#independant variable
x = dataset.iloc[:,3:5].values
x

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++')
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)

# %%
#Eucledian Distances
wcss

# %%
plt.plot(range(1,11),wcss)

# %% [markdown]
# Elbow Joint is at cluster:5
# From there we can say that 5 is the ideal number of clusters

# %%
kmeans = KMeans(n_clusters=5, init = 'k-means++')
y_kmeans = kmeans.fit_predict(x)
y_kmeans

# %%
pd.concat([dataset,pd.DataFrame(y_kmeans)], axis=1)

# %%
plt.scatter(x[y_kmeans==0,0], x[y_kmeans==0,1], s=50, c='red')
plt.scatter(x[y_kmeans==1,0], x[y_kmeans==1,1], s=50, c='blue')
plt.scatter(x[y_kmeans==2,0], x[y_kmeans==2,1], s=50, c='green')
plt.scatter(x[y_kmeans==3,0], x[y_kmeans==3,1], s=50, c='yellow')
plt.scatter(x[y_kmeans==4,0], x[y_kmeans==4,1], s=50, c='pink')
