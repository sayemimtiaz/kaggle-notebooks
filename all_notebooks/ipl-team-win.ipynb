# %%
import numpy as np 
import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# **Help teams decide what should they opt for upon winning toss on a specific venue given the historic data of the venue.**

# %%
base_path = os.path.join('/kaggle', 'input', 'ipl-complete-dataset-20082020')
ipl_team_df = pd.read_csv(os.path.join(base_path, 'IPL Matches 2008-2020.csv'))

# %%
ipl_team_df.head()

# %% [markdown]
# **Starting EDA**

# %%
ipl_team_df.info()

# %% [markdown]
# **Observation 1**
# 1. 816 rows
# 2. Winner is dependent attribute. Venue, team1, team2, toss_winner, toss_decision are independent attributes
# 3. Winner has 4 null values.

# %%
# Removing the matches where winner is null
ipl_team_df = ipl_team_df[ipl_team_df.winner.notna()]

# %%
ipl_team_df.info()

# %%
from sklearn.model_selection import train_test_split

# %%
# Forming the train and test set
train_set, test_set = train_test_split(ipl_team_df, test_size = 0.2, random_state=42)

# %%
train_set.info()

# %%
test_set.info()

# %%
from sklearn.linear_model import LinearRegression

# %%
X = train_set['venue', 'team1', 'team2', 'toss_winner', 'toss_decision']
y = train_set['winner']
