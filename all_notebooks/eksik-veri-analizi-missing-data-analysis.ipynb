# %% [markdown]
# # Kütüphaneler

# %%
#Missinno Kütüphanesi için
# !pip install missingno

# %%
import pandas as pd
import numpy  as np
import seaborn as sns
import missingno as msno

# %% [markdown]
# # Hitters Veri Seti Yükeleme

# %%
hitters = pd.read_csv("../input/hitters/Hitters.csv")
df=hitters.copy()

# %% [markdown]
# Veri Set içerisindeki kolonlara genel bir bakış yapabilmek için kullanıyoruz.Dikkat edilirse **Salary** kolonu içerisinde boşluklar mevcur. Normalde 322 boş olmayan satır olmalı fakat Salary de 263

# %%
df.info()

# %%
df[df.isnull().any(axis=1)]

# %%
df.isnull().sum()

# %%
df[df.isnull().any(axis=1)]

# %% [markdown]
# ## Eksik Veri Görselleştirmesi

# %%
msno.bar(df)

# %%
msno.matrix(df)
