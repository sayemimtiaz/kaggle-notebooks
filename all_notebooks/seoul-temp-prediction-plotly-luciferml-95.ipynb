# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">Introduction</h1>
#
#
#
# </div>

# %% [markdown]
# ![](https://cdn.zmescience.com/wp-content/uploads/2020/05/thermometer-4294021_960_720.jpg)
#
# [Source](https://cdn.zmescience.com/wp-content/uploads/2020/05/thermometer-4294021_960_720.jpg)

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold">Global Temperature Rise </h1>
#     <h3 style="text-align:center;font-weight: bold">The planet's average surface temperature has risen about 2.12 degrees Fahrenheit (1.18 degrees Celsius) since the late 19th century, a change driven largely by increased carbon dioxide emissions into the atmosphere and other human activities.</h3>
#
#
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold">About the Dataset</h1>
#     <h3 style="text-align:left;font-weight: bold">
# This data is for the purpose of bias correction of next-day maximum and minimum air temperatures forecast of the LDAPS model operated by the Korea Meteorological Administration over Seoul, South Korea. This data consists of summer data from 2013 to 2017. The input data is largely composed of the LDAPS model's next-day forecast data, in-situ maximum and minimum temperatures of present-day, and geographic auxiliary variables. There are two outputs (i.e. next-day maximum and minimum air temperatures) in this data. Hindcast validation was conducted for the period from 2015 to 2017.
#     Attribute Information:
#
# For more information, read [Cho et al, 2020].    Attribute Information:
#
# For more information, read [Cho et al, 2020].
#     </h3>
# <ul>
#
# <li>station - used weather station number: 1 to 25</li>
# <li>Date - Present day: yyyy-mm-dd ('2013-06-30' to '2017-08-30')</li>
# <li>Present_Tmax - Maximum air temperature between 0 and 21 h on the present day (Â°C): 20 to 37.6</li>
# <li>Present_Tmin - Minimum air temperature between 0 and 21 h on the present day (Â°C): 11.3 to 29.9</li>
# <li>LDAPS_RHmin - LDAPS model forecast of next-day minimum relative humidity (%): 19.8 to 98.5</li>
# <li>LDAPS_RHmax - LDAPS model forecast of next-day maximum relative humidity (%): 58.9 to 100</li>
# <li>LDAPSTmaxlapse - LDAPS model forecast of next-day maximum air temperature applied lapse rate (Â°C): 17.6 to 38.5</li>
# <li>LDAPSTminlapse - LDAPS model forecast of next-day minimum air temperature applied lapse rate (Â°C): 14.3 to 29.6</li>
# <li>LDAPS_WS - LDAPS model forecast of next-day average wind speed (m/s): 2.9 to 21.9</li>
# <li>LDAPS_LH - LDAPS model forecast of next-day average latent heat flux (W/m2): -13.6 to 213.4</li>
# <li>LDAPS_CC1 - LDAPS model forecast of next-day 1st 6-hour split average cloud cover (0-5 h) (%): 0 to 0.97</li>
# <li>LDAPS_CC2 - LDAPS model forecast of next-day 2nd 6-hour split average cloud cover (6-11 h) (%): 0 to 0.97</li>
# <li>LDAPS_CC3 - LDAPS model forecast of next-day 3rd 6-hour split average cloud cover (12-17 h) (%): 0 to 0.98</li>
# <li>LDAPS_CC4 - LDAPS model forecast of next-day 4th 6-hour split average cloud cover (18-23 h) (%): 0 to 0.97</li>
# <li>LDAPS_PPT1 - LDAPS model forecast of next-day 1st 6-hour split average precipitation (0-5 h) (%): 0 to 23.7</li>
# <li>LDAPS_PPT2 - LDAPS model forecast of next-day 2nd 6-hour split average precipitation (6-11 h) (%): 0 to 21.6</li>
# <li>LDAPS_PPT3 - LDAPS model forecast of next-day 3rd 6-hour split average precipitation (12-17 h) (%): 0 to 15.8</li>
# <li>LDAPS_PPT4 - LDAPS model forecast of next-day 4th 6-hour split average precipitation (18-23 h) (%): 0 to 16.7</li>
#     <li>lat - Latitude (Â°): 37.456 to 37.645</li>
#     <li>lon - Longitude (Â°): 126.826 to 127.135</li>
#     <li>DEM - Elevation (m): 12.4 to 212.3</li>
#     <li>Slope - Slope (Â°): 0.1 to 5.2</li>
#     <li>Solar radiation - Daily incoming solar radiation (wh/m2): 4329.5 to 5992.9</li>
#     <li>Next_Tmax - The next-day maximum air temperature (Â°C): 17.4 to 38.9</li>
#     <li>Next_Tmin - The next-day minimum air temperature (Â°C): 11.3 to 29.8T</li>
#
# </ul>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold">LuciferML</h1>
#     <h3 style="text-align:center;font-weight: bold">This is my own ML-Library whose purpose is to take away all your hassles and does all the hard work for you. It's currently in development stage. Preprocesses and Trains different models on your Data. More about LuciferML <a href = "https://github.com/d4rk-lucif3r/LuciferML">here</a></h3>
#
#
# </div>

# %%
# !pip install lucifer-ml

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">Importing Libraries</h1>
#
#
#
# </div>

# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
plt.style.use('dark_background')
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff

## Importing LuciferML
from luciferml.supervised.regression import Regression

import warnings
warnings.simplefilter(action='ignore', category=Warning)

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">Importing Dataset</h1>
#
#
#
# </div>

# %%
dataset = pd.read_csv('../input/temperature-forecast-project-using-ml/temp.csv')

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">Exploratory Data Analysis</h1>
#
#
#
# </div>

# %%
dataset.head()

# %%
dataset.shape

# %%
dataset.isnull().sum()

# %%
dataset.info()

# %%
dataset = dataset.dropna().reset_index()

# %% [markdown]
# ### Here, I dropped Null values

# %%
dataset.isnull().sum()

# %%
dataset.describe().T.style.bar(
    subset=['mean'],
    color='#606ff2').background_gradient(
    subset=['std'], cmap='PuBu').background_gradient(subset=['50%'], cmap='PuBu')

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">🎇Visualisations🎇</h1>
#
#
#
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">📏Line Plots📏</h1>
#
#
#
# </div>

# %%
fig = px.line(dataset,x = 'Date', y = ['Present_Tmax', 'Present_Tmin',], template = 'plotly_dark', title = 'Variation of Temperature with Time')
fig.show()

# %%
fig = px.line(dataset,x = 'Date', y = ['LDAPS_RHmax', 'LDAPS_RHmin'], template = 'plotly_dark', title = 'Variation of Humidity with Time')
fig.show()

# %%
fig = px.line(dataset,x = 'Date', y = ['LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4'], template = 'plotly_dark', title = 'Variation of Cloud Cover with Time')
fig.show()

# %%
fig = px.line(dataset,x = 'Date', y = ['LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4'], template = 'plotly_dark', title = 'Variation of Precipitation with Time')
fig.show()

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">🌏Some Geography🌏</h1>
#
#
#
# </div>

# %%
fig = px.density_mapbox(dataset, lat='lat', lon='lon', z='Present_Tmax', hover_data=['LDAPS_RHmin', 'LDAPS_RHmax'],
                        
                        mapbox_style="stamen-terrain", template = 'plotly_dark', title = 'Maximum Temperature on Lat Long')
fig.show()

# %%
fig = px.density_mapbox(dataset, lat='lat', lon='lon', z='Present_Tmin',  hover_data=['LDAPS_RHmin', 'LDAPS_RHmax'],
                        
                        mapbox_style="stamen-terrain", template = 'plotly_dark', title = 'Minimum Temperature on Lat Long')

fig.show()

# %%
fig = px.density_mapbox(dataset, lat='lat', lon='lon', z='LDAPS_WS', hover_data=['LDAPS_RHmin', 'LDAPS_RHmax'],
                        
                        mapbox_style="stamen-terrain", template = 'plotly_dark', title = 'Wind Speed on Lat Long')
fig.show()

# %%
fig = px.scatter_geo(dataset, lat='lat', lon='lon', color='Solar radiation', hover_data=['LDAPS_RHmin', 'LDAPS_RHmax'],animation_frame="Date",
                        
                         template = 'plotly_dark', title = 'Solar Radiation on Lat Long')
fig.update_geos(
center=dict(lon=126.9780, lat=37.5665),
scope = 'asia'

)
fig.show()

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">📦Box-xy Plots📦</h1>
#
#
#
# </div>

# %%
fig = px.box(dataset, y=['Present_Tmax', 'Present_Tmin',
       'LDAPS_RHmin', 'LDAPS_RHmax', 
       'LDAPS_WS', 'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3',
       'LDAPS_CC4', 'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4',] ,template = 'plotly_dark')
fig.show()

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">🎃Join 'em All🎃</h1>
#
#
#
# </div>

# %%
sns.jointplot('Present_Tmax', 'Solar radiation', dataset, kind='scatter', color='seagreen');

# %% [markdown]
# ### This plots tells us that generally higher values of Solar Radiation is Associated with Lower Values of Maximum Temperature

# %%
sns.jointplot('Present_Tmin', 'Solar radiation', dataset, kind='scatter', color='seagreen');

# %% [markdown]
# ### This plots tells us that higher values of Solar Radiation are associated with lower values of minimum temperature

# %%
sns.jointplot('Present_Tmax', 'LDAPS_WS', dataset, kind='scatter', color='seagreen');

# %% [markdown]
# ### This plots tells us that lower values of wind speeds are associated with high temperatures

# %%
sns.jointplot('Present_Tmin', 'LDAPS_WS', dataset, kind='scatter', color='seagreen');

# %% [markdown]
# ### This plots tells us that lower values of wind speeds are associated with high temperatures

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">Let's Find Some Correlations</h1>
#
#
#
# </div>

# %%
df = dataset.drop(['Date', 'index'], axis = 1)

# %%
fig = px.imshow(df.corr(), template = 'plotly_dark')
fig.show()

# %% [markdown]
# ### This plot tells us there occurs some very high correlation b/w certain features

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">🎞️Let's 3d-fy it🎞️</h1>
#
#
#
# </div>

# %%
fig = px.scatter_3d(dataset, x='Present_Tmax', y='Present_Tmin', z='DEM',
              color='LDAPS_WS', template = 'plotly_dark', title = 'Distribution of Max Temp., Min Temp. and Elevation represented by Wind Speed')
fig.show()

# %% [markdown]
# ### From above plot we can conclude that Most the temperature recordings are from Days when Elevation Values are low

# %%
fig = px.scatter_3d(dataset, x='Present_Tmax', y='Present_Tmin', z='Slope',
              color='LDAPS_WS', template = 'plotly_dark', title = 'Distribution of Max Temp., Min Temp. and Slope represented by Wind Speed')
fig.show()

# %% [markdown]
# ### From above plot we can conclude that Most the temperature recordings are from Days when Slope Values are low

# %%
fig = px.scatter_3d(dataset, x='Present_Tmax', y='Present_Tmin', z='Solar radiation',
              color='LDAPS_WS', template = 'plotly_dark', title = 'Distribution of Max Temp., Min Temp. and Solar Radiation represented by Wind Speed')
fig.show()

# %% [markdown]
# ### This plot tells us that there seems to be no trend b/w Max Temp , Low Temp and Solar Radiations

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">Preprocess it</h1>
#
#
#
# </div>

# %%
features = dataset.drop(['index', 'Date', 'Next_Tmax', 'Next_Tmin'], axis = 1)
labels_max = dataset['Next_Tmax']
labels_min = dataset['Next_Tmin']

# %% [markdown]
# ### Here im taking features from all columns except Index, Date ,and both of or labels Max temp and Low temp

# %%
features.head(), labels_max.head(), labels_min.head()

# %%
features.shape, labels_max.shape, labels_min.shape

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">🎠Fav Part -> Predictions🎠</h1>
#
#
#
# </div>

# %%
accuracy_scores_max =  {}
RMSE_min= {}
accuracy_scores_min =  {}
RMSE_max= {}

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">📉Linear Regression📉</h1>
#
#
#
# </div>

# %%
params = {}
regressor = Regression(predictor = 'lin', params = params)
print('\n########################################## For Maximum Temperature###################################\n')
regressor.fit(features, labels_max)
result = regressor.result()
accuracy_scores_max[result['Regressor']] = result['Accuracy']
RMSE_max[result['Regressor']] = result['RMSE']
print('\n########################################## For Minimum Temperature###################################\n')
regressor.fit(features, labels_min)
result = regressor.result()
accuracy_scores_min[result['Regressor']] = result['Accuracy']
RMSE_min[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">💁‍♂️Support Vector Regressor💁‍♂️</h1>
#
#
#
# </div>

# %%
params = {}
regressor = Regression(predictor = 'svr', params = params,)
print('\n########################################## For Maximum Temperature###################################\n')
regressor.fit(features, labels_max)
result = regressor.result()
accuracy_scores_max[result['Regressor']] = result['Accuracy']
RMSE_max[result['Regressor']] = result['RMSE']
print('\n########################################## For Minimum Temperature###################################\n')
regressor.fit(features, labels_min)
result = regressor.result()
accuracy_scores_min[result['Regressor']] = result['Accuracy']
RMSE_min[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">🏡K-Nearest Neighbors Regressor🏡</h1>
#
#
#
# </div>

# %%
params_knr={}
regressor = Regression(predictor = 'knr',params= params_knr,)
print('\n########################################## For Maximum Temperature###################################\n')
regressor.fit(features, labels_max)
result = regressor.result()
accuracy_scores_max[result['Regressor']] = result['Accuracy']
RMSE_max[result['Regressor']] = result['RMSE']
print('\n########################################## For Minimum Temperature###################################\n')
regressor.fit(features, labels_min)
result = regressor.result()
accuracy_scores_min[result['Regressor']] = result['Accuracy']
RMSE_min[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">🌙Stochastic Gradient Descent Regressor🌙</h1>
#
#
#
# </div>

# %%
params_sgd ={}
regressor = Regression(predictor = 'sgd', params= params_sgd,)
print('\n########################################## For Maximum Temperature###################################\n')
regressor.fit(features, labels_max)
result = regressor.result()
accuracy_scores_max[result['Regressor']] = result['Accuracy']
RMSE_max[result['Regressor']] = result['RMSE']
print('\n########################################## For Minimum Temperature###################################\n')
regressor.fit(features, labels_min)
result = regressor.result()
accuracy_scores_min[result['Regressor']] = result['Accuracy']
RMSE_min[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">🥅Elastic Net Regressor🥅</h1>
#
#
#
# </div>

# %%
params_elas={}
regressor = Regression(predictor = 'elas', params= params_elas,)
print('\n########################################## For Maximum Temperature###################################\n')
regressor.fit(features, labels_max)
result = regressor.result()
accuracy_scores_max[result['Regressor']] = result['Accuracy']
RMSE_max[result['Regressor']] = result['RMSE']
print('\n########################################## For Minimum Temperature###################################\n')
regressor.fit(features, labels_min)
result = regressor.result()
accuracy_scores_min[result['Regressor']] = result['Accuracy']
RMSE_min[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">🏔️Bayesian Ridge🏔️</h1>
#
#
#
# </div>

# %%
params_br = {'alpha_1': 0.001, 'alpha_2': 0.001, 'lambda_1': 0.001}
regressor = Regression(predictor = 'br', params= params_br)
print('\n########################################## For Maximum Temperature###################################\n')
regressor.fit(features, labels_max)
result = regressor.result()
accuracy_scores_max[result['Regressor']] = result['Accuracy']
RMSE_max[result['Regressor']] = result['RMSE']
print('\n########################################## For Minimum Temperature###################################\n')
regressor.fit(features, labels_min)
result = regressor.result()
accuracy_scores_min[result['Regressor']] = result['Accuracy']
RMSE_min[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">🌳Decision Trees🌳</h1>
#
#
#
# </div>

# %%
params_dt = {}
regressor = Regression(predictor = 'dt',params= params_dt,)
print('\n########################################## For Maximum Temperature###################################\n')
regressor.fit(features, labels_max)
result = regressor.result()
accuracy_scores_max[result['Regressor']] = result['Accuracy']
RMSE_max[result['Regressor']] = result['RMSE']
print('\n########################################## For Minimum Temperature###################################\n')
regressor.fit(features, labels_min)
result = regressor.result()
accuracy_scores_min[result['Regressor']] = result['Accuracy']
RMSE_min[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">🌲Random Forest Regressor🌲</h1>
#
#
#
# </div>

# %%
params_rfr = {}
regressor = Regression(predictor = 'rfr',params= params_rfr,)
print('\n########################################## For Maximum Temperature###################################\n')
regressor.fit(features, labels_max)
result = regressor.result()
accuracy_scores_max[result['Regressor']] = result['Accuracy']
RMSE_max[result['Regressor']] = result['RMSE']
print('\n########################################## For Minimum Temperature###################################\n')
regressor.fit(features, labels_min)
result = regressor.result()
accuracy_scores_min[result['Regressor']] = result['Accuracy']
RMSE_min[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">💥XGBoost Regressor💥</h1>
#
#
#
# </div>

# %%
params_xgb = {}

regressor = Regression(predictor = 'xgb',params= params_xgb,)
print('\n########################################## For Maximum Temperature###################################\n')
regressor.fit(features, labels_max)
result = regressor.result()
accuracy_scores_max[result['Regressor']] = result['Accuracy']
RMSE_max[result['Regressor']] = result['RMSE']
print('\n########################################## For Minimum Temperature###################################\n')
regressor.fit(features, labels_min)
result = regressor.result()
accuracy_scores_min[result['Regressor']] = result['Accuracy']
RMSE_min[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">🌌Gradient Boosting Regressor🌌</h1>
#
#
#
# </div>

# %%
params_gbr = {}
regressor = Regression(predictor = 'gbr',params= params_gbr,)
print('\n########################################## For Maximum Temperature###################################\n')
regressor.fit(features, labels_max)
result = regressor.result()
accuracy_scores_max[result['Regressor']] = result['Accuracy']
RMSE_max[result['Regressor']] = result['RMSE']
print('\n########################################## For Minimum Temperature###################################\n')
regressor.fit(features, labels_min)
result = regressor.result()
accuracy_scores_min[result['Regressor']] = result['Accuracy']
RMSE_min[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">🤖Light Gradient Boosting Machine🤖</h1>
#
#
#
# </div>

# %%
params_lgbm = {}

regressor = Regression(predictor = 'lgbm',params= params_lgbm)
print('\n########################################## For Maximum Temperature###################################\n')
regressor.fit(features, labels_max)
result = regressor.result()
accuracy_scores_max[result['Regressor']] = result['Accuracy']
RMSE_max[result['Regressor']] = result['RMSE']
print('\n########################################## For Minimum Temperature###################################\n')
regressor.fit(features, labels_min)
result = regressor.result()
accuracy_scores_min[result['Regressor']] = result['Accuracy']
RMSE_min[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">😸CatBoost Regressor😸</h1>
#
#
#
# </div>

# %%
params_cat ={}

regressor = Regression(predictor = 'cat',params= params_cat)
print('\n########################################## For Maximum Temperature###################################\n')
regressor.fit(features, labels_max)
result = regressor.result()
accuracy_scores_max[result['Regressor']] = result['Accuracy']
RMSE_max[result['Regressor']] = result['RMSE']
print('\n########################################## For Minimum Temperature###################################\n')
regressor.fit(features, labels_min)
result = regressor.result()
accuracy_scores_min[result['Regressor']] = result['Accuracy']
RMSE_min[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">🕸️Neural Network🕸️</h1>
#
#
#
# </div>

# %%
regressor = Regression(predictor = 'ann')
print('\n########################################## For Maximum Temperature###################################\n')
regressor.fit(features, labels_max)
result = regressor.result()
accuracy_scores_max[result['Regressor']] = result['Accuracy']
RMSE_max[result['Regressor']] = result['RMSE']
print('\n########################################## For Minimum Temperature###################################\n')
regressor.fit(features, labels_min)
result = regressor.result()
accuracy_scores_min[result['Regressor']] = result['Accuracy']
RMSE_min[result['Regressor']] = result['RMSE']

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">Yay!! Time for Results</h1>
#
#
#
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">Maximum Temperature Prediction </h1>
#
#
#
# </div>

# %%
maxKey = max(accuracy_scores_max, key=lambda x: accuracy_scores_max[x])
print('The model with highest K-Fold Validation Accuracy score for Maxium temp. is  {0} with an accuracy of  {1:.2f}'.format(
    maxKey, accuracy_scores_max[maxKey]))

# %%
minKey = min(RMSE_max, key=lambda x: RMSE_max[x])
print('The model with Lowest RMSE fr Max temp. is {0} with RMSE of  {1:.2f}'.format(
    minKey, RMSE_max[minKey]))

# %%
plt.figure(figsize=(12, 6))
model_accuracies = list(accuracy_scores_max.values())
model_names = list(accuracy_scores_max.keys())
sns.barplot(x=model_accuracies, y=model_names, palette='YlOrBr');
plt.title('Accuracy for Regressors (Maximum Temp)');

# %%
plt.figure(figsize=(12, 6))
model_accuracies = list(RMSE_max.values())
model_names = list(RMSE_max.keys())
sns.barplot(x=model_accuracies, y=model_names, palette='YlOrBr');
plt.title('RMSE for Regressors (Maximum Temperature)');

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">Minimum Temperature Prediciton</h1>
#
#
#
# </div>

# %%
maxKey = max(accuracy_scores_min, key=lambda x: accuracy_scores_min[x])
print('The model with highest K-Fold Validation Accuracy score for Min temp. is  {0} with an accuracy of  {1:.2f}'.format(
    maxKey, accuracy_scores_min[maxKey]))

# %%
minKey = min(RMSE_min, key=lambda x: RMSE_min[x])
print('The model with Lowest RMSE for Min temp. is {0} with RMSE of  {1:.2f}'.format(
    minKey, RMSE_min[minKey]))

# %%
plt.figure(figsize=(12, 6))
model_accuracies = list(accuracy_scores_min.values())
model_names = list(accuracy_scores_min.keys())
sns.barplot(x=model_accuracies, y=model_names, palette='YlOrBr');
plt.title('Accuracy for Regressors (Minimum Temp)');

# %%
plt.figure(figsize=(12, 6))
model_accuracies = list(RMSE_min.values())
model_names = list(RMSE_min.keys())
sns.barplot(x=model_accuracies, y=model_names, palette='YlOrBr');
plt.title('RMSE for Regressors (Maximum Temperature)');

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#ff05da;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold">Please share your feedback in the comment section. I'll be more than happy to hear ya'll and If you liked my work and learned from it Please Consider Upvoting.</h1>
#
# </div>
