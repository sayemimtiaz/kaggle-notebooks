# %% [markdown]
# Notebook relating to Diabetes incidence prediction including EDA, multivariate imputation and testing, feature engineering, basic classification, model tuning and model stacking.
# Within, i provide a guide for switching between R and Python within R Markdown, which can be very useful.
#
# The notebook is uploaded at R pubs below:
# https://rpubs.com/JakeTuricchi/DPPpredictionJT
