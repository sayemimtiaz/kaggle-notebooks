# %% [markdown]
# <h1>Importing the Libraries

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['tmdb_5000_credits.csv', 'tmdb_5000_movies.csv']

# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import seaborn as sns

import json
import warnings
warnings.filterwarnings('ignore')
import base64
import io
from scipy.misc import imread
import codecs
from IPython.display import HTML

# %% [markdown]
# <h1>Reading Input

# %%
movies=pd.read_csv('../input/tmdb_5000_movies.csv')
mov=pd.read_csv('../input/tmdb_5000_credits.csv')

# %% [markdown]
# <h1>Converting JSON entries to list

# %%
def from_json(df,attr):
    df[attr] = df[attr].apply(json.loads)
    
    for index,i in zip(df.index, df[attr]):
        l=[]
        for j in range(len(i)):
            l.append(i[j]['name'])
        df.loc[index,attr] = str(l)

# %%
json_columns = ['keywords','production_companies','production_countries','spoken_languages']

# %%
for c in json_columns:
    from_json(movies,c)

# %%
from_json(mov,'cast')

# %% [markdown]
# <h1>Selecting only Director from Crew

# %%
def director(x):
    for i in x:
        if i['job'] == 'Director':
            return i['name']
    else:
        return "Unknown"

# %%
mov['crew']=mov['crew'].apply(json.loads)
mov['crew']=mov['crew'].apply(director)
mov.rename(columns={'crew':'director'},inplace=True)

# %% [markdown]
# <h1>Creating a Single DataFrame from the two

# %%
movies = movies.merge(mov, left_on='id', right_on='movie_id',how='left')

# %%
movies.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title_x', 'vote_average',
#        'vote_count', 'movie_id', 'title_y', 'cast', 'director'],
#       dtype='object')

# %%
movies.head(1)
# Out:
#       budget     ...             PoL
# 0  237000000     ...      2550965087
#
# [1 rows x 25 columns]

# %% [markdown]
# <h1>Adding New Column: Profit/Loss

# %%
movies['PoL']=movies.revenue - movies.budget

# %%
df=movies[['id','original_title','genres','cast','vote_average','vote_count','popularity','director','keywords','runtime','budget','revenue','PoL']]

# %%
df.head(2)
# Out:
#       id   ...   runtime
# 0  19995   ...     162.0
# 1    285   ...     169.0
#
# [2 rows x 10 columns]

# %% [markdown]
# <h1>Bubble Plot of Top 30 Movies by Vote_Average,Vote_count,Popularity and Profit/Loss

# %%
import plotly.plotly as py
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = movies.sort_values(by='budget',ascending=False).iloc[:20,:]

# %%
df = df[df.vote_count>1000].iloc[:30,:]
df = df.sort_values(by='vote_average',ascending=False)

# %%
data = [
    {
        'y': df.vote_average,
        'x': df.original_title,
        'mode': 'markers',
        'marker': {
            'color': df.popularity,
            'size': df.vote_count//100,
            'showscale': True
        },
        "text" :df.PoL//1000000
    }
]
iplot(data)
# Out:
# <div>
#
#
#             <div id="0965ed47-4b3d-4755-8262-17b442a73ffe" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0965ed47-4b3d-4755-8262-17b442a73ffe")) {
#                     Plotly.newPlot(
#                         '0965ed47-4b3d-4755-8262-17b442a73ffe',
#                         [{"marker": {"color": [136.747729, 143.659698, 118.968562, 192.528841, 105.79293600000001, 121.463076, 146.75739099999998, 104.469351, 63.65424399999999, 78.51783, 187.322927, 49.549984, 49.336397, 73.56723199999999, 127.525581, 138.133331, 103.698022, 59.259204000000004, 93.06786600000001, 60.732738], "showscale": true, "size": [82, 58, 38, 42, 33, 84, 94, 43, 31, 58, 120, 19, 10, 30, 29, 79, 40, 20, 23, 19]}, "mode": "markers", "text": [3.0, 239.0, 259.0, 9.0, 34.0, 205.0, 37.0, 299.0, 21.0, 520.0, 819.0, 210.0, -30.0, 3.0, 105.0, 622.0, 224.0, 0.0, 31.0, 132.0], "type": "scatter", "uid": "3184e3e7-8aaf-4eae-866c-b97eed45ffba", "x": ["The Shawshank Redemption", "The Godfather", "\u5343\u3068\u5343\u5c0b\u306e\u795e\u96a0\u3057", "Whiplash", "The Godfather: Part II", "Pulp Fiction", "Fight Club", "Schindler's List", "GoodFellas", "The Empire Strikes Back", "The Dark Knight", "\u30cf\u30a6\u30eb\u306e\u52d5\u304f\u57ce", "Once Upon a Time in America", "American History X", "One Flew Over the Cuckoo's Nest", "Forrest Gump", "The Green Mile", "12 Angry Men", "Psycho", "\u3082\u306e\u306e\u3051\u59eb"], "y": [8.5, 8.4, 8.3, 8.3, 8.3, 8.3, 8.3, 8.3, 8.2, 8.2, 8.2, 8.2, 8.2, 8.2, 8.2, 8.2, 8.2, 8.2, 8.2, 8.2]}],
#                         {},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('0965ed47-4b3d-4755-8262-17b442a73ffe');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# <h1>WordCloud of Keywords

# %%
from wordcloud import WordCloud

# %%
kw = movies['keywords'].values.tolist()

# %%
kw = [eval(x) for x in kw]

# %%
kw = sum(kw,[])

# %%
plt.subplots(figsize=(20,10))
wordcloud = WordCloud(
                          background_color='white',
                          width=720,
                          height=480
                         ).generate(" ".join(kw))
plt.imshow(wordcloud)
plt.axis('off')
#plt.savefig('graph.png')

plt.show()

# %% [markdown]
# <h1>WordCloud Tagline

# %%
movies.tagline.isnull().sum()
# Out:
# 844

# %%
tg = movies['tagline'].dropna().values.tolist()

plt.subplots(figsize=(20,10))
wordcloud = WordCloud(
                          background_color='black',
                          width=720,
                          height=480
                         ).generate(" ".join(tg))
plt.imshow(wordcloud)
plt.axis('off')
#plt.savefig('graph.png')

plt.show()

# %% [markdown]
# <h1>Bubble Plot of Top 20 Directors by Profit and No. of Movies directed

# %%
dirpol = movies[['director','PoL']]

# %%
dirpol = dirpol.groupby(['director']).sum()

# %%
topdir = dirpol.sort_values(by='PoL',ascending=False).iloc[:20,:]

# %%
dirmovcnt = movies[['director','original_title']].groupby(['director']).count()

# %%
dirmovcnt.columns = ['Num_movies']

# %%
topdirmovcnt = dirmovcnt.sort_values(by='Num_movies',ascending=False)

# %%
type(topdir.index.tolist())
# Out:
# list

# %%
sizes = []
for name in topdir.index.tolist():
    sizes.append(topdirmovcnt[topdirmovcnt.index==name]['Num_movies'].values[0])

# %%
sizes
# Out:
# [27, 9, 7, 12, 8, 11, 5, 13, 3, 5, 14, 11, 4, 7, 8, 7, 7, 5, 13, 16]

# %%
data = [
    {
        'y': topdir.PoL,
        'x': topdir.index,
        'mode': 'markers',
        'marker': {
            'color': 'red',
            'size': sizes,
            'showscale': False
        },
        "text" :sizes
    }
]
iplot(data)
# Out:
# <div>
#
#
#             <div id="f1eb381a-338d-4c6f-abd1-d41681909a7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f1eb381a-338d-4c6f-abd1-d41681909a7d")) {
#                     Plotly.newPlot(
#                         'f1eb381a-338d-4c6f-abd1-d41681909a7d',
#                         [{"marker": {"color": "red", "showscale": false, "size": [27, 9, 7, 12, 8, 11, 5, 13, 3, 5, 14, 11, 4, 7, 8, 7, 7, 5, 13, 16]}, "mode": "markers", "text": ["27", "9", "7", "12", "8", "11", "5", "13", "3", "5", "14", "11", "4", "7", "8", "7", "7", "5", "13", "16"], "type": "scatter", "uid": "19df125c-4f6c-4c56-86a7-0a36f972d64d", "x": ["Steven Spielberg", "Peter Jackson", "James Cameron", "Michael Bay", "Christopher Nolan", "Chris Columbus", "George Lucas", "Robert Zemeckis", "Joss Whedon", "Francis Lawrence", "Tim Burton", "Sam Raimi", "Carlos Saldanha", "James Wan", "Roland Emmerich", "Gore Verbinski", "Sam Mendes", "Andrew Adamson", "Ron Howard", "Ridley Scott"], "y": [7479893164, 5205642820, 5136669439, 4422524638, 3222483234, 3098631503, 2979336893, 2600622002, 2424831068, 2349457182, 2340418241, 2208951462, 2169451792, 2091614787, 2088321040, 2070013357, 2049548809, 1991859447, 1903390547, 1899557997]}],
#                         {},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('f1eb381a-338d-4c6f-abd1-d41681909a7d');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# <h1>Bubble Plot of Top 20 lead actors by Profit and No. of movies acted

# %%
for i in range(len(movies)):
    try:
        movies.loc[i,'Lead'] = eval(movies.cast[i])[0]
    except:
        movies.loc[i,'Lead']='Unknown'

# %%
leadpol = movies[['Lead','PoL']]
leadpol = leadpol.groupby(['Lead']).sum()

toplead = leadpol.sort_values(by='PoL',ascending=False).iloc[:20,:]
leadmovcnt = movies[['Lead','original_title']].groupby(['Lead']).count()


leadmovcnt.columns = ['Num_movies']

topleadmovcnt = leadmovcnt.sort_values(by='Num_movies',ascending=False)

sizes = []
for name in toplead.index.tolist():
    sizes.append(topleadmovcnt[topleadmovcnt.index==name]['Num_movies'].values[0])

data = [
    {
        'y': toplead.PoL,
        'x': toplead.index,
        'mode': 'markers',
        'marker': {
            'color': 'red',
            'size': sizes,
            'showscale': False
        },
        "text" :sizes
    }
]
iplot(data)
# Out:
# <div>
#
#
#             <div id="6f3bc534-6fa8-43a2-afac-f983b8e00c8f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6f3bc534-6fa8-43a2-afac-f983b8e00c8f")) {
#                     Plotly.newPlot(
#                         '6f3bc534-6fa8-43a2-afac-f983b8e00c8f',
#                         [{"marker": {"color": "red", "showscale": false, "size": [24, 23, 12, 7, 16, 27, 22, 10, 30, 10, 16, 4, 19, 20, 16, 7, 8, 20, 8, 23]}, "mode": "markers", "text": ["24", "23", "12", "7", "16", "27", "22", "10", "30", "10", "16", "4", "19", "20", "16", "7", "8", "20", "8", "23"], "type": "scatter", "uid": "85d5345f-4f99-429e-9183-1344280ee4a1", "x": ["Tom Hanks", "Tom Cruise", "Robert Downey Jr.", "Daniel Radcliffe", "Will Smith", "Johnny Depp", "Ben Stiller", "Mike Myers", "Bruce Willis", "Elijah Wood", "Leonardo DiCaprio", "Sam Worthington", "Harrison Ford", "Sandra Bullock", "Christian Bale", "Kristen Stewart", "Jennifer Lawrence", "Jim Carrey", "Daniel Craig", "Arnold Schwarzenegger"], "y": [5644446178, 5570390285, 5073496153, 4616792293, 4238331885, 3693230820, 3640397222, 3065102901, 3033881368, 2892919895, 2836908116, 2813899415, 2754908280, 2721066195, 2623471019, 2580280443, 2544515327, 2502089177, 2499673641, 2462946539]}],
#                         {},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('6f3bc534-6fa8-43a2-afac-f983b8e00c8f');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# <h1>Compare Two Directors based on Profit/Loss

# %%
def comp_dirs(d1,d2):
    

    trace0 = go.Box(
        y=movies[movies.director==d1].PoL,
        name = d1,
        marker = dict(
            color = 'rgb(12, 12, 140)',
        )
    )
    trace1 = go.Box(
        y=movies[movies.director==d2].PoL,
        name = d2,
        marker = dict(
            color = 'rgb(12, 128, 128)',
        )
    )
    data = [trace0, trace1]
    layout = dict(
        title="Director Comparision P/L"
    )
    fig = dict(
        data = data,
        layout = layout
    )
    iplot(fig)

# %%
comp_dirs('James Cameron', 'Christopher Nolan')
# Out:
# <div>
#
#
#             <div id="0ba74649-3edf-4780-80d5-4b32ca0bbcf2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0ba74649-3edf-4780-80d5-4b32ca0bbcf2")) {
#                     Plotly.newPlot(
#                         '0ba74649-3edf-4780-80d5-4b32ca0bbcf2',
#                         [{"marker": {"color": "rgb(12, 12, 140)"}, "name": "James Cameron", "type": "box", "uid": "1a49b37d-5a61-4e6d-bd04-8e269d2a72d7", "y": [2550965087, 1645034188, 420000000, 263882411, 20000098, 164816455, 71971200]}, {"marker": {"color": "rgb(12, 128, 128)"}, "name": "Christopher Nolan", "type": "box", "uid": "1f313db5-5a01-4650-9c22-331a7da6eb77", "y": [834939099, 819558444, 510120017, 665532764, 224218673, 67714830, 69676311, 30723096]}],
#                         {"title": {"text": "Director Comparision P/L"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('0ba74649-3edf-4780-80d5-4b32ca0bbcf2');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
comp_dirs('Sam Raimi', 'Christopher Nolan')
# Out:
# <div>
#
#
#             <div id="edc8ebd9-1483-4480-96cd-23f1d2e71153" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("edc8ebd9-1483-4480-96cd-23f1d2e71153")) {
#                     Plotly.newPlot(
#                         'edc8ebd9-1483-4480-96cd-23f1d2e71153',
#                         [{"marker": {"color": "rgb(12, 12, 140)"}, "name": "Sam Raimi", "type": "box", "uid": "1468e45d-96c5-472a-a011-e33f162f27e4", "y": [632871626, 583766341, 291868548, 682708551, -50000000, -13447540, 60810892, 0, -11000000, 2323044, 29050000]}, {"marker": {"color": "rgb(12, 128, 128)"}, "name": "Christopher Nolan", "type": "box", "uid": "53c5ed40-6e13-4d82-9c0c-a58a8efbb50c", "y": [834939099, 819558444, 510120017, 665532764, 224218673, 67714830, 69676311, 30723096]}],
#                         {"title": {"text": "Director Comparision P/L"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('edc8ebd9-1483-4480-96cd-23f1d2e71153');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
import random

# %%
D1 = random.choice(topdir.index.tolist())
D2 = random.choice(topdir.index.tolist())
comp_dirs(D1,D2)
# Out:
# <div>
#
#
#             <div id="f1695740-f11c-40de-95cb-34c1001b7b50" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f1695740-f11c-40de-95cb-34c1001b7b50")) {
#                     Plotly.newPlot(
#                         'f1695740-f11c-40de-95cb-34c1001b7b50',
#                         [{"marker": {"color": "rgb(12, 12, 140)"}, "name": "Roland Emmerich", "type": "box", "uid": "e7e89282-0193-4bbe-9422-229b429564d6", "y": [569653595, 224681935, 55366737, 419272402, 105294342, 741969268, -14604913, -13312326]}, {"marker": {"color": "rgb(12, 128, 128)"}, "name": "Carlos Saldanha", "type": "box", "uid": "52d4fc89-8c3d-43d0-acd5-40badc346089", "y": [397188435, 796686817, 394635760, 580940780]}],
#                         {"title": {"text": "Director Comparision P/L"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('f1695740-f11c-40de-95cb-34c1001b7b50');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# <h1>Compare Two Lead Actors based on Profit/Loss

# %%
def comp_leads_V(l1,l2):
    trace0 = go.Violin(
        y=movies[movies.Lead==l1].PoL,
        name = l1,
        marker = dict(
            color = 'rgb(12, 12, 140)',
        )
    )
    trace1 = go.Violin(
        y=movies[movies.Lead==l2].PoL,
        name = l2,
        marker = dict(
            color = 'rgb(12, 128, 128)',
        )
    )
    data = [trace0, trace1]
    layout = dict(
        title="Lead Actror Comparision P/L"
    )
    fig = dict(
        data = data,
        layout = layout
    )
    iplot(fig)

# %%
def comp_leads_B(l1,l2):
    trace0 = go.Box(
        y=movies[movies.Lead==l1].PoL,
        name = l1,
        marker = dict(
            color = 'rgb(12, 12, 140)',
        )
    )
    trace1 = go.Box(
        y=movies[movies.Lead==l2].PoL,
        name = l2,
        marker = dict(
            color = 'rgb(12, 128, 128)',
        )
    )
    data = [trace0, trace1]
    layout = dict(
        title="Lead Actror Comparision P/L"
    )
    fig = dict(
        data = data,
        layout = layout
    )
    iplot(fig)

# %%
L1 = random.choice(toplead.index.tolist())
L2 = random.choice(toplead.index.tolist())
comp_leads_V(L1,L2)
# Out:
# <div>
#
#
#             <div id="20d58ecf-7bf2-4e93-8e06-13ebcf129809" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("20d58ecf-7bf2-4e93-8e06-13ebcf129809")) {
#                     Plotly.newPlot(
#                         '20d58ecf-7bf2-4e93-8e06-13ebcf129809',
#                         [{"marker": {"color": "rgb(12, 12, 140)"}, "name": "Robert Downey Jr.", "type": "violin", "uid": "3288153f-4ad0-4c32-98c0-49039e305f22", "y": [1125403694, 1299557910, 1015439994, 445174222, 423933331, 209615000, 434028679, 146780824, -28279842, 785148, 0, 1057193]}, {"marker": {"color": "rgb(12, 128, 128)"}, "name": "Sam Worthington", "type": "violin", "uid": "2d80447c-4891-496b-9547-9a10c070178c", "y": [2550965087, 151000000, 107713139, 4221189]}],
#                         {"title": {"text": "Lead Actror Comparision P/L"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('20d58ecf-7bf2-4e93-8e06-13ebcf129809');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
L1 = random.choice(toplead.index.tolist())
L2 = random.choice(toplead.index.tolist())
comp_leads_B(L1,L2)
# Out:
# <div>
#
#
#             <div id="8ae46b89-c91c-4a82-af01-3f642f00ae7f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8ae46b89-c91c-4a82-af01-3f642f00ae7f")) {
#                     Plotly.newPlot(
#                         '8ae46b89-c91c-4a82-af01-3f642f00ae7f',
#                         [{"marker": {"color": "rgb(12, 12, 140)"}, "name": "Kristen Stewart", "type": "box", "uid": "199ccd5f-9c67-4dce-ac20-6b9aaae9f4db", "y": [226600000, 709000000, 630491347, 659827462, 355616625, -1297136, 42145]}, {"marker": {"color": "rgb(12, 128, 128)"}, "name": "Daniel Radcliffe", "type": "box", "uid": "cf2cfcce-99a9-4bdf-9045-874160f5a40f", "y": [683959197, 788212738, 745921036, 659804554, 851475550, 776688482, 110730736]}],
#                         {"title": {"text": "Lead Actror Comparision P/L"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('8ae46b89-c91c-4a82-af01-3f642f00ae7f');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# <h1>To be continued...Stay Tuned! xD
