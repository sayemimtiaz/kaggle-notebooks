# %%
import pandas as pd
import numba as np
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as mosn
import os

# %%
data=pd.read_csv("../input/global-co2-emissions/CO2Emission_LifeExp.csv")

# %%
data.head()

# %%
data.info()

# %%
data.describe()

# %%
mosn.bar(data)

# %% [markdown]
# No Missing Data

# %%
data["Country"].value_counts()

# %%
data.set_index('Country', inplace=True)

# %%
data.plot(figsize=(20,10))

# %%
plt.figure(figsize=(30,10))
sns.lineplot(data=data, x="Country", y="CO2Emissions")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(30,10))
sns.lineplot(data=data, x="Country", y="YearlyChange")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(30,10))
sns.lineplot(data=data, x="Country", y="Population")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(30,10))
sns.lineplot(data=data, x="Country", y="LifeExpectancy")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,15))

sns.heatmap(data=data.corr(), annot =True)

# %%
data.head(10).sort_values('CO2Emissions',ascending=False)

# %% [markdown]
# Top 4 Country [ Australia , Argentina , Algeria, Angola ] in CO2 Emissions

# %%
df = data[(data["Code"]=="AUS")|(data["Code"]=='ARG') |(data["Code"]=='DZA')|(data["Code"]=='AGO')]

# %%
df[['YearlyChange']].plot()
df[['Percapita']].plot()
df[['Population']].plot()
df[['LifeExpectancy']].plot()

# %%
data.head(10).sort_values('LifeExpectancy',ascending=False)

# %%
data.head(10).sort_values('Population',ascending=False)

# %%
data.head(10).sort_values('CO2Emissions',ascending=True)

# %% [markdown]
# the less country in CO2 Emissions [Anguilla]

# %%
plt.figure(figsize=(30,10))
sns.scatterplot(data=data, x="Code", y="Population")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Top 2 Country in Population ( Argentina ,Algeria)

# %%
plt.figure(figsize=(30,10))
sns.scatterplot(data=data, x="Code", y="LifeExpectancy" , color="red")
plt.xticks(rotation=90)
plt.show()

# %%
sns.pairplot(data=data)
