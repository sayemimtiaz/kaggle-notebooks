# %% [markdown]
# Серебряков Михаил Николаевич
#
# **IPL MATCHES EDA**
#
# https://www.kaggle.com/anandhuh/ipl-matches-eda-visualizations
#
#
# IPL (Индийская Премьер-лига)

# %% [markdown]
# **1. Importing Libraries**
#
# **1. Импортируем библиотеки**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("whitegrid")

# %% [markdown]
# **2. Loading Data into Dataframe**
#
# **2. Загружаем данные**

# %%
df_matches = pd.read_csv('../input/ipl-data-set/matches.csv')

# %% [markdown]
# **3. Exploratory Data Analysis**
#
# **3. Исследовательский анализ данных**

# %%
# printing first five rows
# печатем первые пять строк
df_matches.head()

# %%
# Shape Of the Dataset
# Форма набора данных
print('Shape of matches data',df_matches.shape)

# %%
# Concise summary of the dataset
# Краткое изложение набора данных
df_matches.info()

# %%
# Checking Null Values
# Проверяем пустые значения
df_matches.isnull().sum()

# %% [markdown]
# ### **VISUALIZATIONS**
#
# ### **Визуализация**

# %% [markdown]
# *  Number of matches played in each IPL season
#
# *  Количество сыгранных матчей в каждом сезоне IPL

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='Season',
              data=df_matches,
              order = df_matches['Season'].value_counts().index.sort_values()
              )
plt.xlabel('Season',fontsize=12)
plt.ylabel('No: of matches',fontsize=12)
plt.title('Number of matches played in each IPL season',fontsize=16)

# %% [markdown]
# Most number of matches were played in IPL-2013 Season
#
# Наибольшее количесвто матчей сыграно в сезоне IPL-2013

# %% [markdown]
# * **Matches won by the Teams**
# * **Матчи, выигранные командами**

# %%
# Matches won by the Teams
# Матчи, выигранные командами
plt.figure(figsize = (11,9))
sns.countplot(y = 'winner',
              data = df_matches,
              order= df_matches['winner'].value_counts().index,
              palette = 'copper' )
plt.xlabel('No: of Wins',fontsize=12)
plt.ylabel('Team',fontsize=12)
plt.title('Matches won by the Teams',fontsize=16)

# %% [markdown]
# Mumbai Indians won most number of matches followed by Chennai Super Kings
#
# Mumbai Indians выиграли наибольшее количество матчей, за ними следуют Chennai Super Kings

# %% [markdown]
# *  **No of matches played in stadium, Top 10**
#
# * **Количество сыгранных матчей на стадионе, Топ-10**

# %%
plt.figure(figsize = (12,8))
sns.countplot(y = 'venue',
              data = df_matches,
              order = df_matches['venue'].value_counts().iloc[:10].index,
              palette='gist_heat')
plt.xlabel('No: of matches',fontsize=12)
plt.ylabel('Venue',fontsize=12)
plt.title('Number of matches played in each Stadium',fontsize=16)

# %% [markdown]
# Most number of IPL matches were played in Eden Gardens Stadium, Kolkata
#
# Наибольшее количество матчей IPL было сыграно на стадионе Eden Gardens, Kolkata

# %% [markdown]
# * **Toss Decision**
#
# * **Отбросить Решение**

# %%
plt.figure(figsize=(6,6))
sizes = df_matches.toss_decision.value_counts()
labels = df_matches.toss_decision.value_counts().index
plt.pie(sizes,colors = ['#ff9999','#66b3ff'],
         labels=labels,
         autopct='%1.1f%%',
         startangle=90,
         pctdistance=0.75,
         explode = (0.025,0.025))

#draw white circle
#нарисуем белый круг
centre_circle = plt.Circle((0,0),0.60,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# %% [markdown]
# In more than 61% of matches, teams chose to field after winning the toss.

# %% [markdown]
# * **Toss Decision to field or bat in each IPL season**
#
# * **Отбросить решения о выходе на поле или битой в каждом сезоне IPL**

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='Season',
              hue='toss_decision',
              data=df_matches,
              order = df_matches['Season'].value_counts().index.sort_values(),
              palette='deep')
plt.xlabel('Season',fontsize=12)
plt.ylabel('Count',fontsize=12)
plt.title('Decision to field or bat in each IPL season', fontsize=16)

# %% [markdown]
# We can see a trend that, decisions to field are more from IPL-2016 Season
#
# Мы видим тенденцию к тому, что решения о выходе на поле больше связаны с сезоном IPL-2016

# %% [markdown]
# * **Player of the Match**
# * **Игрок матча**

# %%
plt.figure(figsize=(15,7))
player_of_match=df_matches['player_of_match'].value_counts()[:10]
sns.barplot(player_of_match.index,
            player_of_match.values,
            palette='cividis')

plt.title("Player of the Match",fontsize=15)
plt.xlabel('Player',fontsize=12)
plt.ylabel('Count',fontsize=12)

# %% [markdown]
# Chris Gayle won most Man of the Match Awards
# Chris Gayle получил наибольшее количество наград "Лучший игрок матча"
#
# Please give suggestions in the comment section below.
# Пожалуйста, дайте предложения в разделе комментариев ниже.
#
# Upvote if you like the notebook
# Проголосуйте, если вам нравится блокнот
#
# THANK YOU
# СПАСИБО ВАМ
