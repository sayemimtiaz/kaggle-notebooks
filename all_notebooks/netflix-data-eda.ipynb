# %% [markdown]
# I prepare this dataset for one of my courses to show how Netflix’s subscription figures and Netflix's revenue($) have grown in four different regions:
#
# the United States and Canada,
# Europe, the Middle East, and Africa,
# Latin America,
# Asia-Pacific
# over the last 2.5 years. According to the final month of the quarter 2020(March) was being the start of the global coronavirus pandemic in many countries, Netflix noted that it added 26 million paid new subscribers in the first two quarters of 2020 alone; in 2019, the company added 28 million subscribers in total.
# Dataset Description:
# This dataset contains four CSV files.
#
# DataNetflixRevenue2020_V2.csv: three columns
# Area, Years, Revenue.
#
# DataNetflixSubscriber2020_V2.csv: three columns
# Area, Years, Subscribers.
#
# NetflixSubscribersbyCountryfrom2018toQ2_2020.csv: eleven columns
# Area, Q1 - 2018, Q2 - 2018, Q3 - 2018, Q4 - 2018, Q1 - 2019, Q2 - 2019,
# Q3 - 2019, Q4 - 2019, Q1 - 2020, Q2 - 2020
#
# Netflix'sRevenue2018toQ2_2020.csv: eleven columns
# Area, Q1 - 2018, Q2 - 2018, Q3 - 2018, Q4 - 2018, Q1 - 2019, Q2 - 2019,
# Q3 - 2019, Q4 - 2019, Q1 - 2020, Q2 - 2020

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('../input/netflix2020/DataNetflixRevenue2020_V2.csv') 
df1.head() #DataNetflixRevenue2020

# %%
df2=pd.read_csv('../input/netflix2020/DataNetflixSubscriber2020_V2.csv')
df2.head() #DataNetflixSubscriber2020

# %%
df3=pd.read_csv('../input/netflix2020/NetflixSubscribersbyCountryfrom2018toQ2_2020.csv')
df3.head() #NetflixSubscribersbyCountryfrom2018toQ2_2020

# %%
df4=pd.read_csv('../input/netflix2020/NetflixsRevenue2018toQ2_2020.csv')
df4.head() #Netflix'sRevenue2018toQ2_2020

# %%
print(df1.shape)
print(df2.shape)
print(df3.shape)
print(df4.shape)

# %%
rev_sub=pd.concat([df1,df2],axis=1)
rev_sub=rev_sub.iloc[:,2:]
rev_sub.head()

# %%
rev_sub.info()

# %% [markdown]
# No null entries

# %%
rev_sub.Years.unique()

# %%
plt.bar(rev_sub.Years,rev_sub.Revenue)
plt.xticks(rotation=45)
plt.xlabel('Year')
plt.ylabel('Dollars ($)')
plt.legend()
plt.show()

# %% [markdown]
# Revenue has increased with time

# %%
plt.bar(rev_sub.Years,rev_sub.Subscribers,color='g')
plt.xticks(rotation=45)
plt.xlabel('Year')
plt.ylabel('Dollars ($)')
plt.legend()
plt.show()

# %% [markdown]
# Subscribers have increased with time

# %%
rev_sub.groupby(['Area']).mean()

# %%
df1.groupby(['Area']).mean().plot(kind='bar')
df2.groupby(['Area']).mean().plot(kind='bar')
plt.grid()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 1. Highest revenue is generated from US and Canada
# 2. US and Canada have highest nubmer of subscribers
# 3. Asia-Pacific carry huge potential for revenue generation

# %%
rev_sub.groupby(['Area','Years']).mean()
