# %% [markdown]
# #Employee Attrition: All You Need to Know
#
# Author: Suzanne Lucas
#
# Employee attrition is when an employee leaves the company through any method, including voluntary resignations, layoffs, failure to return from a leave of absence, or even illness or death. Whenever anyone ceases working for the company for any reason and is not replaced for a long time (if ever), that would be employee attrition.
#
# Voluntary and Involuntary attrition.
#
# Causes: Low unemployment, Workforce demographics, Toxic workplace, Business relocation, Reorganizations/restructuring and Covid-19 shutdowns.
#
# https://www.digitalhrtech.com/employee-attrition/

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTvr95xObsc-43hf_Pe5N1awUZ8GD14Wy_EHTBwtANR-NJfu9zvGLEAUmuGcciyJGCIu2c&usqp=CAU)clipartszone.com

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('../input/hr-employee-attrition/HR-Employee-Attrition.csv', encoding='ISO-8859-2')
pd.set_option('display.max_columns', None)
df.head()

# %%
df.isnull().sum()

# %%
#Codes by https://www.kaggle.com/muhammadismail99/data-analysis-of-guf-pub-dataset/notebook

sns.countplot(data = df, x = 'Attrition')
plt.title('Employee Attrition')

# %%
#Codes by https://www.kaggle.com/muhammadismail99/data-analysis-of-guf-pub-dataset/notebook

sns.countplot(data = df, x = 'BusinessTravel')
plt.title('Business Travel')

# %%
#Codes by https://www.kaggle.com/muhammadismail99/data-analysis-of-guf-pub-dataset/notebook

sns.countplot(data = df, x = 'Gender')
plt.title('Employee Gender')

# %%
#Codes by https://www.kaggle.com/muhammadismail99/data-analysis-of-guf-pub-dataset/notebook

sns.countplot(data = df, x = 'Department')
plt.title('Department')

# %%
#Codes by https://www.kaggle.com/muhammadismail99/data-analysis-of-guf-pub-dataset/notebook

sns.countplot(data = df, x = 'EducationField')
plt.title('Employee Education Field')
plt.xticks(rotation=45)

# %%
#Codes by https://www.kaggle.com/muhammadismail99/data-analysis-of-guf-pub-dataset/notebook

sns.countplot(data = df, x = 'EnvironmentSatisfaction')
plt.title('Employee Environment Satisfaction')
#plt.xticks(rotation=45)

# %%
#Codes by https://www.kaggle.com/muhammadismail99/data-analysis-of-guf-pub-dataset/notebook

sns.countplot(data = df, x = 'JobRole')
plt.title('Job Role')
plt.xticks(rotation=45)

# %%
#Codes by https://www.kaggle.com/muhammadismail99/data-analysis-of-guf-pub-dataset/notebook

sns.countplot(data = df, x = 'Over18')
plt.title('Over18')
#plt.xticks(rotation=45)

# %%
#Codes by https://www.kaggle.com/muhammadismail99/data-analysis-of-guf-pub-dataset/notebook

sns.countplot(data = df, x = 'TrainingTimesLastYear')
plt.title('Training Times LastYear')

# %%
#Codes by https://www.kaggle.com/muhammadismail99/data-analysis-of-guf-pub-dataset/notebook

sns.countplot(data = df, x = 'PerformanceRating')
plt.title('Performance Rating')

# %%
#Codes by https://www.kaggle.com/muhammadismail99/data-analysis-of-guf-pub-dataset/notebook

sns.countplot(data = df, x = 'WorkLifeBalance')
plt.title('Work Life Balance')

# %% [markdown]
# ![](https://www.jobsoid.com/wp-content/uploads/2020/10/What-is-Employee-Attrition-Blog-Image.jpg)jobsoid.com
#
# #Fui!
