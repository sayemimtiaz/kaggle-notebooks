# %% [markdown]
# # **Final Ödevim**

# %% [markdown]
# **Kullandığım Kütüphaneler**

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np 
import os 
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.naive_bayes import GaussianNB
import sklearn.tree as skltdtc
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# **Kullandığım Data**

# %%
df1 = pd.read_csv('/kaggle/input/tablet.csv')
df1.dataframeName = 'tablet.csv'

# %% [markdown]
# **Verilerin Nasıl Dağıldığını Görüyoruz.**

# %%
df1.hist(layout=(5,4), figsize=(30,20))

plt.show()

# %% [markdown]
# * Ağırlık Sütünü Dengeli Dağılmıştır.
# * Çekirdek Sayısı 3 ve 5 olmadığını görüyoruz.
# * Kalınlığı az olan ürünler daha fazla bulunmaktadır.
# * Arka Kamera MP Sütünü Dengeli Dağılmıştır.
# * Çözünürlük Genişliği Sütünü Dengeli Dağılmıştır.
# * Batarya Gücü Sütünü Dengeli Dağılmıştır.
# * Ön Kamera MP Artıkça Ürünler Giderek Azalmıştır.
# * Çözünürlük Yüksekliği Artıkça Ürünler Giderek Azalmıştır.
# * Mikro İşlemci Hızı az olan ürünler daha fazla bulunmaktadır.
# * Batarya Ömrü Sütünü Dengeli Dağılmıştır.
# * Dahilli Bellek Sütünü Dengeli Dağılmıştır.
# * Ram Sütünü Dengeli Dağılmıştır.

# %%
def countplot(baslik): 
    sns.countplot(x=baslik, data=df1)
    plt.xticks(rotation=50)
    plt.show()
    
    print(df1[baslik].value_counts())

# %%
countplot("Bluetooth")

# %% [markdown]
# * Bluetooth olup olmaması çok yakın bu nedenle dengeli dağılmıştır.

# %%
countplot("CiftHat")

# %% [markdown]
# * Çift Hat olup olmaması çok yakın bu nedenle dengeli dağılmıştır.

# %%
countplot("4G")

# %% [markdown]
# * 4G olup olmaması çok yakın bu nedenle dengeli dağılmıştır.

# %%
countplot("3G")

# %% [markdown]
# * 3G olup olmaması farkları çok fazla var bu nedenle dengesiz dağılmıştır.

# %%
countplot("WiFi")

# %% [markdown]
# * Wifi olup olmaması çok yakın bu nedenle dengeli dağılmıştır.

# %%
countplot("Renk")

# %% [markdown]
# * Renkler dengeli dağılmıştır.

# %%
countplot("FiyatAraligi")

# %% [markdown]
# * Hedef Değişkenimiz "Fiyat Aralığı" Dengeli Dağılmıştır.

# %% [markdown]
# **Kolerasyon Matrisinin Isı Haritasının Kod Bloğu**

# %%
corr = df1.corr()
cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "7pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]

corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Kolerasyon Matrisinin Isı Haritası")\
    .set_precision(2)\
    .set_table_styles(magnify())

# %% [markdown]
# * Ön Kamera MP si ile Arka Kamera Mp si arasında pozitif bir ilişki vardır.
# * Çözünürlük Yüksekliği ile Çözünürlülük Genişli Arasında pozitif bir ilişki vardır.

# %% [markdown]
# **Datayı İnceliyoruz**

# %%
df1.info() # bu kod bloğunda datanın hakkında bilgi sahibi oluyoruz

# %%
df1.isnull().sum() # bu kod bloğunda datanın içinde toplamda 17 tane null değer olduğunu görüyoruz

# %% [markdown]
#  **Sütununların Ortalaması, Medyanı Ve Standart Sapmasını Buluyoruz**

# %%
print("BataryaGucu Ortalaması :",df1.BataryaGucu.mean())
print("BataryaGucu Medyanı :",df1.BataryaGucu.median())
print("BataryaGucu Standart Sapması :",df1.BataryaGucu.std())
print("Ortalama Medyana Çok Yakın")
print("Ortalama Standart Sapmadan Büyüktür.")

# %%
print("MikroislemciHizi Ortalaması :",df1.MikroislemciHizi.mean())
print("MikroislemciHizi Medyanı :",df1.MikroislemciHizi.median())
print("MikroislemciHizi Standart Sapması :",df1.MikroislemciHizi.std())
print("Ortalama Medyana Çok Yakın")
print("Ortalama Standart Sapmadan Büyüktür.")

# %%
print("OnKameraMP Ortalaması :",df1.OnKameraMP.mean())
print("OnKameraMP Medyanı :",df1.OnKameraMP.median())
print("OnKameraMP Standart Sapması :",df1.OnKameraMP.std())
print("Ortalama Medyana Yakın Değil")
print("Ortalama Standart Sapmaya Yakındır.")

# %%
print("DahiliBellek Ortalaması :",df1.DahiliBellek.mean())
print("DahiliBellek Medyanı :",df1.DahiliBellek.median())
print("DahiliBellek Standart Sapması :",df1.DahiliBellek.std())
print("Ortalama Medyana Çok Yakın")
print("Ortalama Standart Sapmadan Büyüktür.")

# %%
print("Kalinlik Ortalaması :",df1.Kalinlik.mean())
print("Kalinlik Medyanı :",df1.Kalinlik.median())
print("Kalinlik Standart Sapması :",df1.Kalinlik.std())
print("Ortalama Medyana Çok Yakın")
print("Ortalama Standart Sapmadan Büyüktür.")

# %%
print("Agirlik Ortalaması :",df1.Agirlik.mean())
print("Agirlik Medyanı :",df1.Agirlik.median())
print("Agirlik Standart Sapması :",df1.Agirlik.std())
print("Ortalama Medyana Çok Yakın")
print("Ortalama Standart Sapmadan Büyüktür.")

# %%
print("CekirdekSayisi Ortalaması :",df1.CekirdekSayisi.mean())
print("CekirdekSayisi Medyanı :",df1.CekirdekSayisi.median())
print("CekirdekSayisi Standart Sapması :",df1.CekirdekSayisi.std())
print("Ortalama Medyana Çok Yakın")
print("Ortalama Standart Sapmadan Büyüktür.")

# %%
print("ArkaKameraMP Ortalaması :",df1.ArkaKameraMP.mean())
print("ArkaKameraMP Medyanı :",df1.ArkaKameraMP.median())
print("ArkaKameraMP Standart Sapması :",df1.ArkaKameraMP.std())
print("Ortalama Medyana Çok Yakın")
print("Ortalama Standart Sapmadan Büyüktür.")

# %%
print("CozunurlukYükseklik Ortalaması :",df1.CozunurlukYükseklik.mean())
print("CozunurlukYükseklik Medyanı :",df1.CozunurlukYükseklik.median())
print("CozunurlukYükseklik Standart Sapması :",df1.CozunurlukYükseklik.std())
print("Ortalama Medyana Yakın Değil")
print("Ortalama Standart Sapmadan Büyüktür.")

# %%
print("CozunurlukGenislik Ortalaması :",df1.CozunurlukGenislik.mean())
print("CozunurlukGenislik Medyanı :",df1.CozunurlukGenislik.median())
print("CozunurlukGenislik Standart Sapması :",df1.CozunurlukGenislik.std())
print("Ortalama Medyana Çok Yakın")
print("Ortalama Standart Sapmadan Büyüktür.")

# %%
print("RAM Ortalaması :",df1.RAM.mean())
print("RAM Medyanı :",df1.RAM.median())
print("RAM Standart Sapması :",df1.RAM.std())
print("Ortalama Medyana Çok Yakın")
print("Ortalama Standart Sapmadan Büyüktür.")

# %% [markdown]
# **Datamızın İçinde Null Değerlerin Yerlerine Ortalama Değerler Koyuyoruz  **

# %%
df1.RAM = df1.RAM.fillna(df1.RAM.mean())

# %%
df1.OnKameraMP= df1.OnKameraMP.fillna(df1.OnKameraMP.mean())

# %% [markdown]
# **Artık Null Değer Bulunmuyor**

# %%
df1.isnull().sum()

# %% [markdown]
# **Nominal Değerleri Sıranabilmesi İçin Değiştiriyoruz**

# %% [markdown]
# **Sütünlarda "Var" Yazanları 1 "Yok" yazanları ise 0 a dönüştüyoruz.[](http://)**

# %%
df1.Bluetooth = df1.Bluetooth.eq('Var').mul(1)

# %%
df1.CiftHat = df1.CiftHat.eq('Var').mul(1)

# %%
df1['4G'] = df1['4G'].eq('Var').mul(1)

# %%
df1['3G'] = df1['3G'].eq('Var').mul(1)

# %%
df1.WiFi = df1.WiFi.eq('Var').mul(1)

# %%
df1.Dokunmatik = df1.Dokunmatik.eq('Var').mul(1)

# %%
likert_scale = {'Pahalı':3, 'Normal':2, 'Ucuz':1, 'Çok Ucuz':0}
df1['FiyatAraligi'] = df1.FiyatAraligi.apply(lambda x: likert_scale[x])

# %%
renk_scale = {'Kırmızı':1 ,'Turkuaz':2, 'Gri':3, 'Turuncu':4, 'Kahverengi':5, 'Mor':6, 'Sarı':7, 'Yeşil':8, 'Siyah':9 ,'Mavi':10 , 'Beyaz':11,'Pembe':12}
df1['Renk'] = df1.Renk.apply(lambda x: renk_scale[x])

# %% [markdown]
# **Göründüğü Gibi Değerlerimiz Değişti**

# %%
df1.sample(5)

# %% [markdown]
# **Program Fiyat Aralığını Tahmin Etmesi İçin Bağımlı Değişken olarak Fiyat Aralığını Seçiyoruz**

# %%
Bagimsiz_degisken_x = df1.drop("FiyatAraligi",axis=1)
Bagimli_degisken_y= df1["FiyatAraligi"]

# %% [markdown]
# **%75 Oranında Eğitim Ve %25 Oranında Test Olması İçin test_sizemısızı 1/4 Seçiyoruz.**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(Bagimsiz_degisken_x,Bagimli_degisken_y, test_size = 1/4, random_state = 2, shuffle=1)

# %%
X_train

# %%
X_test

# %%
Y_train

# %%
Y_test

# %% [markdown]
# **Logistic Regression Modeli**

# %%
logmodel = LogisticRegression(solver = "liblinear") #  (solver = "liblinear") PARAMETRE UFAK VERİLER İÇİN DAHA TUTARLI OLUŞTUYOR
logmodel.fit(X_train,Y_train)
y_pred_logistic = logmodel.predict(X_test)

# %%
print(classification_report(Y_test,y_pred_logistic))

# %% [markdown]
# * **Çok Ucuzlar İçin 0.86**
# * **Ucuzlar İçin 0.67**
# * **Normal İçin 0.64**
# * **Pahalı İçin 0.84**
# * **Genel Başarı 0.76**

# %%
confusion_matrix = pd.crosstab(Y_test,y_pred_logistic, rownames=['Actual'], colnames=['Predicted'])
print (confusion_matrix)

# %% [markdown]
# * **Çok Ucuzlar İçin 112 tanesini çok ucuz 9 tanesini ucuz 1 tanesini normal 0 tanesini pahalı demiştir **
# * **Ucuzlar İçin 27 tanesini çok ucuz 82 tanesini ucuz 30 tanesini normal 0 tanesini pahalı demiştir **
# * **Normal İçin 0 tanesini çok ucuz 14 tanesini ucuz 75 tanesini normal 35 tanesini pahalı demiştir **
# * **Pahalı İçin 0 tanesini çok ucuz 2 tanesini ucuz 4 tanesini normal 109 tanesini pahalı demiştir **

# %% [markdown]
# **GaussianNB Modeli**

# %%
NB = GaussianNB()

# %%
logmodel_NB = NB.fit(X_train,Y_train)
y_pred_NB = logmodel_NB.predict(X_test)

# %%
print(classification_report(Y_test,y_pred_NB))

# %% [markdown]
# * **Çok Ucuzlar İçin 0.91**
# * **Ucuzlar İçin 0.76**
# * **Normal İçin 0.71**
# * **Pahalı İçin 0.84**
# * **Genel Başarı 0.80**

# %%
confusion_matrix = pd.crosstab(Y_test,y_pred_NB, rownames=['Actual'], colnames=['Predicted'])
print (confusion_matrix)

# %% [markdown]
# * **Çok Ucuzlar İçin 110 tanesini çok ucuz 12 tanesini ucuz 0 tanesini normal 0 tanesini pahalı demiştir **
# * **Ucuzlar İçin 11 tanesini çok ucuz 104 tanesini ucuz 24 tanesini normal 0 tanesini pahalı demiştir **
# * **Normal İçin 0 tanesini çok ucuz 15 tanesini ucuz 90 tanesini normal 19 tanesini pahalı demiştir **
# * **Pahalı İçin 0 tanesini çok ucuz 2 tanesini ucuz 15 tanesini normal 98 tanesini pahalı demiştir **

# %% [markdown]
# **Decision Tree Modeli Parmetre Olarak (criterion = 'gini') Alıyor.**

# %%
tree = skltdtc.DecisionTreeClassifier()

# %%
logmodel_tree = tree.fit(X_train,Y_train)
y_pred_tree = logmodel_tree.predict(X_test)

# %%
print(classification_report(Y_test,y_pred_tree))

# %% [markdown]
# * **Çok Ucuzlar İçin 0.87**
# * **Ucuzlar İçin 0.76**
# * **Normal İçin 0.75**
# * **Pahalı İçin 0.84**
# * **Genel Başarı 0.80**

# %%
confusion_matrix = pd.crosstab(Y_test,y_pred_tree, rownames=['Actual'], colnames=['Predicted'])
print (confusion_matrix)

# %% [markdown]
# * **Çok Ucuzlar İçin 112 tanesini çok ucuz 10 tanesini ucuz 0 tanesini normal 0 tanesini pahalı demiştir **
# * **Ucuzlar İçin 23 tanesini çok ucuz 97 tanesini ucuz 19 tanesini normal 0 tanesini pahalı demiştir **
# * **Normal İçin 0 tanesini çok ucuz 9 tanesini ucuz 97 tanesini normal 18 tanesini pahalı demiştir **
# * **Pahalı İçin 0 tanesini çok ucuz 0 tanesini ucuz 19 tanesini normal 96 tanesini pahalı demiştir **

# %% [markdown]
# **Decision Tree Modeli Parmetre Olarak (criterion = 'entropy') Alıyor**

# %%
parametreli_tree = skltdtc.DecisionTreeClassifier(criterion = 'entropy')

# %%
logmodel_parametreli_tree = parametreli_tree.fit(X_train,Y_train)
y_pred_parametreli_tree = logmodel_parametreli_tree.predict(X_test)

# %%
print(classification_report(Y_test,y_pred_parametreli_tree))

# %% [markdown]
# * **Çok Ucuzlar İçin 0.90**
# * **Ucuzlar İçin 0.81**
# * **Normal İçin 0.73**
# * **Pahalı İçin 0.83**
# * **Genel Başarı 0.82**

# %%
confusion_matrix = pd.crosstab(Y_test,y_pred_parametreli_tree, rownames=['Actual'], colnames=['Predicted'])
print (confusion_matrix)

# %% [markdown]
# * **Çok Ucuzlar İçin 111 tanesini çok ucuz 11 tanesini ucuz 0 tanesini normal 0 tanesini pahalı demiştir **
# * **Ucuzlar İçin 14 tanesini çok ucuz 112 tanesini ucuz 13 tanesini normal 0 tanesini pahalı demiştir **
# * **Normal İçin 0 tanesini çok ucuz 15 tanesini ucuz 90 tanesini normal 19 tanesini pahalı demiştir **
# * **Pahalı İçin 0 tanesini çok ucuz 0 tanesini ucuz 19 tanesini normal 96 tanesini pahalı demiştir **

# %% [markdown]
# ****KNN Modeli Komşu Sayısı Belirtmeden (Default Olarak 5 Geliyor.)****

# %%
knn = KNeighborsClassifier()
logmodel_knn = knn.fit(X_train,Y_train)
y_pred_knn = logmodel_knn.predict(X_test)

# %%
print(classification_report(Y_test,y_pred_knn))

# %% [markdown]
# * **Çok Ucuzlar İçin 0.96**
# * **Ucuzlar İçin 0.92**
# * **Normal İçin 0.88**
# * **Pahalı İçin 0.91**
# * **Genel Başarı 0.92**

# %%
confusion_matrix = pd.crosstab(Y_test,y_pred_knn, rownames=['Actual'], colnames=['Predicted'])
print (confusion_matrix)

# %% [markdown]
# * **Çok Ucuzlar İçin 120 tanesini çok ucuz 2 tanesini ucuz 0 tanesini normal 0 tanesini pahalı demiştir **
# * **Ucuzlar İçin 7 tanesini çok ucuz 129 tanesini ucuz 3 tanesini normal 0 tanesini pahalı demiştir **
# * **Normal İçin 0 tanesini çok ucuz 8 tanesini ucuz 110 tanesini normal 6 tanesini pahalı demiştir **
# * **Pahalı İçin 0 tanesini çok ucuz 1 tanesini ucuz 12 tanesini normal 102 tanesini pahalı demiştir **

# %% [markdown]
# **KNN Modeli Komşu Sayısı 2 den 15 e Kadar**

# %%
knn_array = []
for sayac in range(2,15):
    knn = KNeighborsClassifier(n_neighbors = sayac)
    logmodel_knn_sayacli = knn.fit(X_train,Y_train)
    y_pred_knn = logmodel_knn_sayacli.predict(X_test)
    print("KOMŞU SAYISI : " , sayac)
    print(logmodel_knn_sayacli.score(X_test,Y_test))
    knn_array.insert(sayac,logmodel_knn_sayacli.score(X_test,Y_test))

# %% [markdown]
# **Modelde Komşu Sayısı 2 den 15 e Kadar Başarı Oranlarını Çizdiriyoruz.**

# %%
plt.plot(knn_array)
plt.xlabel("Komşu Sayısı - 2 ")
plt.ylabel("Başarı Oranı")

# %% [markdown]
# **Bir Array Oluşturuyoruz Ve Bulduğumuz Sonuçları İçine Atıyoruz**

# %%
karsilastirma_array = []
karsilastirma_array.insert(1,"LogisticRegression = " + str(logmodel.score(X_test,Y_test)))
karsilastirma_array.insert(2,"GaussianNB = " + str(logmodel_NB.score(X_test,Y_test)))
karsilastirma_array.insert(3,"DecisionTree gini = " + str(logmodel_tree.score(X_test,Y_test)))
karsilastirma_array.insert(4,"DecisionTree entropy = " + str(logmodel_parametreli_tree.score(X_test,Y_test)))
karsilastirma_array.insert(5,"Parametresiz KNN = " + str(logmodel_knn.score(X_test,Y_test)))
for i in range(6,19):
    karsilastirma_array.insert(i,"KNN komşu sayısı " + str(i-4) + " =  " + str(knn_array[i-6]))
karsilastirma_array

# %% [markdown]
# **KNN Modeli Diğer Modellerden Açık Ara Fark İle Daha Başarılı Olmuştur.**
