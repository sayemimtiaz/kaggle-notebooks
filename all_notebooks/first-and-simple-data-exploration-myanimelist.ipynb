# %%
import pandas_profiling as pp
import pandas as pd

# %%
df = pd.read_csv('../input/anime-recommendation-database-2020/anime.csv')
df.head()

# %%
report = pp.ProfileReport(df, title='Anime dataset Report', progress_bar=False)

# %%
report
