# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../input/insurance/insurance.csv')

# %%
df.head()

# %%
f = plt.figure(figsize=(14,6))

sns.boxplot(x=df['sex'], y=df['charges'],)

plt.title('box plot sex vs charges')
plt.show()

# %%
f = plt.figure(figsize=(14,6))

sns.lineplot(x=df['age'], y=df['charges'],)

plt.title('line plot age vs charges')
plt.show()

# %%
f = plt.figure(figsize=(14,6))

sns.lineplot(x=df['bmi'], y=df['charges'],)

plt.title('box plot sex vs charges')
plt.show()

# %%
f = plt.figure(figsize=(9,6))

sns.boxplot(y=df['bmi'])

plt.title('box plot sex vs charges')
plt.show()

# %%
f = plt.figure(figsize=(14,6))

sns.boxplot(x=df['children'], y=df['charges'],)

plt.title('box plot sex vs charges')
plt.show()

# %%
f = plt.figure(figsize=(14,6))

sns.boxplot(x=df['smoker'], y=df['charges'],)

plt.title('box plot sex vs charges')
plt.show()

# %%
f = plt.figure(figsize=(14,6))

sns.boxplot(x=df['region'], y=df['charges'],)

plt.title('box plot sex vs charges')
plt.show()

# %%
f = plt.figure(figsize=(9,6))

sns.boxplot(y=df['charges'],)

plt.title('box plot sex vs charges')
plt.show()

# %%
f = plt.figure(figsize=(12,4))

sns.heatmap(df.isnull(), cmap='viridis', cbar=False, yticklabels=False)

plt.show()

# %%
f = plt.figure(figsize=(12,4))

sns.heatmap(df.corr(), annot=True, cmap='viridis', )
plt.show()

# %%
f= plt.figure(figsize=(12,4))

ax=f.add_subplot(121)

sns.distplot(df['charges'],bins=50,color='r',ax=ax)
ax.set_title('Distribution of insurance charges')

ax=f.add_subplot(122)

sns.distplot(np.log10(df['charges']),bins=40,color='b',ax=ax)
ax.set_title('Distribution of insurance charges in $log$ sacle')
ax.set_xscale('log');

# %%
df.head()

# %%
categorical_columns = ['sex', 'children','smoker','region']

df_encoded = pd.get_dummies(df, prefix='OHE', columns=categorical_columns, drop_first=True)

# %%
df_encoded.head()

# %%
## Log transform
df_encoded['charges'] = np.log(df_encoded['charges'])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model    import LinearRegression
from sklearn.metrics         import mean_squared_error

# %%
X = df_encoded.drop('charges', axis=1)
y = df_encoded['charges']

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.3, random_state=23)

# %%
line_reg = LinearRegression()

line_reg.fit(X_train,y_train)

# %%
predict = line_reg.predict(X_test)

# %%
f = plt.figure(figsize=(14,6))

sns.scatterplot(x=y_test, y=predict , color='red')
sns.lineplot(x=y_test, y=y_test , color='green')
plt.show()

# %%
#  Check for Linearity
f = plt.figure(figsize=(14,5))

ax = f.add_subplot(121)
sns.scatterplot(y_test,predict,ax=ax,color='r', )
ax.set_title('Check for Linearity:\n Actual Vs Predicted value')

# Check for Residual normality & mean
ax = f.add_subplot(122)
sns.distplot((y_test - predict),ax=ax,color='b')
ax.axvline((y_test - predict).mean(),color='k',linestyle='--')
ax.set_title('Check for Residual normality & mean: \n Residual eror');

# %%
# Check for Multivariate Normality
# Quantile-Quantile plot 
f,ax = plt.subplots(1,2,figsize=(14,6))

import scipy as sp

_,(_,_,r) = sp.stats.probplot((y_test - predict), fit=True , plot=ax[0])
ax[0].set_title("Check for Multivariate Normality: \nQ-Q Plot")

#Check for Homoscedasticity
sns.scatterplot(y = (y_test - predict), x= predict, ax = ax[1],color='r') 
ax[1].set_title('Check for Homoscedasticity: \nResidual Vs Predicted');

# %%
print('Mean Squre Error (MSE) :' , np.round(mean_squared_error(predict,y_test) *100,2),'%')

# %%
R_square_sk = line_reg.score(X_test,y_test)
R_square_sk *100

# %%
1/(1-R_square_sk)

# %% [markdown]
# _____________
#
# # Polynomial Regression:
# _________

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(8)

# %%
x_poly = poly.fit_transform(X)

# %%
line_reg2  = LinearRegression()

# %%
line_reg2.fit(x_poly, y)

# %%
predict2 = line_reg2.predict(x_poly)

# %%
sns.scatterplot(y,predict2)
sns.scatterplot(y,y)

# %%
print('Mean Squre Error (MSE) :' , np.round(mean_squared_error(predict2,y) *100,2),'%')

# %%
plt.figure(figsize=(10,5))

import scipy as sp

sp.stats.probplot((y - predict2), fit=True, plot=plt )
plt.title('Check for Multivariate Normality: \nQ-Q Plot')

plt.show()

# %%
f = plt.figure(figsize=(14,5))

ax = f.add_subplot(121)
sns.scatterplot(y,predict2,ax=ax,color='r', )
ax.set_title('Check for Linearity:\n Actual Vs Predicted value')

# Check for Residual normality & mean
ax = f.add_subplot(122)
sns.distplot((y-predict2),ax=ax,color='b')
ax.axvline((y - predict2).mean(),color='k',linestyle='--')
ax.set_title('Check for Residual normality & mean: \n Residual eror');
