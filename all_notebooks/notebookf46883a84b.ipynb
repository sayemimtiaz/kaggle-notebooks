# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd 
df = pd.read_csv('../input/up-crime-data-year-2019/MR data - Compiled Data Set.csv')
df.head(40)

# %%
df.describe()

# %%
df = df.drop(['Title'],axis=1)

# %%
df = df.fillna(0)

# %%
df.head()

# %%
col = df.columns

# %%
df.columns = [i for i in range(0,len(df.columns))]

# %%
df.head(15)

# %%
import matplotlib.pyplot as plt
relation = []
for i in range(0,len(df)):
    str(df.iloc[i,9]).replace(" ","")
    
    if ',' in str(df.iloc[i,9]):
         
          relation.append(df.iloc[i,9])
for i in range(len(relation)):
    relation[i].replace(" ","")
relation

# %%
dic ={ '0' : 0}
j = 0
for  i  in relation:
    if i not in relation[:j]:
        dic[i]= relation.count(i)
    j+=1

# %%
a = dic.keys()
b = dic.values()
width = 0.5

f = plt.figure()
f.set_figwidth(15)
plt.bar(a,b,color='green')
plt.xlabel('')
#since there are spaces in betwwen so I have considered 2 cases 7,10 and 7, 10.

# %%
#clearly 7,10 occurs most frequeently
df[11]=0
df[12]=0

# %%
for i in range(0,len(df)):
    if ',' in str(df.iloc[i,9]):
        cl=df.iloc[i,9].split(',')
        df.iloc[i,9]=int(cl[0])
        df.iloc[i,11]=int(cl[1])
        if(len(cl))>2:
           df.iloc[i,12]=int(cl[2])
    elif int(df.iloc[i,9])>100:
           df.iloc[i,11]=int(df.iloc[i,9])%100
           df.iloc[i,9]=int(df.iloc[i,9])//100

# %%
df.head(55)

# %%
citycrimecount = df[0].value_counts()
crime=list(citycrimecount)

# %%
city = list(citycrimecount.keys())

city

# %%
import matplotlib.pyplot as plt
plt.bar(city,crime,color='orange')
print(crime)

# %%
rea = df[2].value_counts()
reasons=list(rea)
reasons

# %%
reasons.remove(319)

# %%
frequency = ['Property Disputes','Family Dispute','Petty Quarrels','Money Disputes','Personal Vendetta','Love Affairs','Casteism','Unknown reasons']

# %%
f=plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.bar(frequency,reasons,color='red')
plt.title('Reasons of crime vs cases')
plt.xlabel('REASONS')
plt.ylabel('CASES')

# %%
ghaziabad = 0.0
lucknow = 0.0
kanpur = 0.0 
for i in range(0,len(df)):
    if(df.iloc[i,3]!=0):
        if(df.iloc[i,0]=='Ghaziabad'):
            ghaziabad+=df.iloc[i,3]
        elif(df.iloc[i,0]=='Lucknow'):
            lucknow+=df.iloc[i,3]
        elif(df.iloc[i,0]=='Kanpur'):
            kanpur+=df.iloc[i,3]

# %%
plt.bar(city,[lucknow,ghaziabad,kanpur],color='pink')
plt.title('city VS childvictim')
plt.xlabel('CITY')
plt.ylabel('CASES')

# %%
ghaziabad1 = 0.0
lucknow1 = 0.0
kanpur1 = 0.0 
for i in range(0,len(df)):
    if(df.iloc[i,4]!=0):
        if(df.iloc[i,0]=='Ghaziabad'):
            ghaziabad1+=df.iloc[i,4]
        elif(df.iloc[i,0]=='Lucknow'):
            lucknow1+=df.iloc[i,4]
        elif(df.iloc[i,0]=='Kanpur'):
            kanpur1+=df.iloc[i,4]

# %%
import matplotlib.pyplot as plt
plt.bar(city,[lucknow1,ghaziabad1,kanpur1],color='blue')
plt.title('CITY vs Male victims')
plt.xlabel('CITY')
plt.ylabel('CASES')

# %%
 mr=0 #Murder with Rape
dd=0#Dowry Deaths 
suc=0#Suicide(sec 305/306)
kidn=0#Kidnapping(All)
aa=0#Acid Attack(Sec. 326A IPC)
cbh=0#Cruelty by Husband/in-laws((Sec.498 A IPC)
rape=0#Rape only(Sec. 376 or 511 IPC)
assault=0#Assault on Women with Intent to Outrage her Modesty (Sec. 354 IPC)
cc=0#Cyber Crimes against Women
poc=0#Protection of Children from Sexual Offences Act

for i in range(0,len(df)):
    if(df.iloc[i,9]!=0):
        if(df.iloc[i,9]==1):
            mr+=1
        elif(df.iloc[i,9]==2):
            dd+=1
        elif(df.iloc[i,9]==3):
            suc+=1
        elif(df.iloc[i,9]==4):
            kidn+=1
        elif(df.iloc[i,9]==5):
            aa+=1
        elif(df.iloc[i,9]==6):
            cbh+=1
        elif(df.iloc[i,9]==7):
            rape+=1
        elif(df.iloc[i,9]==8):
            assault+=1
        elif(df.iloc[i,9]==9):
            cc+=1
        elif(df.iloc[i,9]==10):
            poc+=1

# %%
for i in range(0,len(df)):
    if(df.iloc[i,11]!=0):
        if(df.iloc[i,11]==1):
            mr+=1
        elif(df.iloc[i,11]==2):
            dd+=1
        elif(df.iloc[i,11]==3):
            suc+=1
        elif(df.iloc[i,11]==4):
            kidn+=1
        elif(df.iloc[i,11]==5):
            aa+=1
        elif(df.iloc[i,11]==6):
            cbh+=1
        elif(df.iloc[i,11]==7):
            rape+=1
        elif(df.iloc[i,11]==8):
            assault+=1
        elif(df.iloc[i,11]==9):
            cc+=1
        elif(df.iloc[i,11]==10):
            poc+=1

# %%
for i in range(0,len(df)):
    if(df.iloc[i,12]!=0):
        if(df.iloc[i,12]==1):
            mr+=1
        elif(df.iloc[i,12]==2):
            dd+=1
        elif(df.iloc[i,12]==3):
            suc+=1
        elif(df.iloc[i,12]==4):
            kidn+=1
        elif(df.iloc[i,11]==5):
            aa+=1
        elif(df.iloc[i,12]==6):
            cbh+=1
        elif(df.iloc[i,12]==7):
            rape+=1
        elif(df.iloc[i,12]==8):
            assault+=1
        elif(df.iloc[i,12]==9):
            cc+=1
        elif(df.iloc[i,12]==10):
            poc+=1

# %%
plt.bar(['mr','dd','suc','kidn','aa','cbh','rape','assault','cc','poc'],[mr,dd,suc,kidn,aa,cbh,rape,assault,cc,poc])
plt.title('Crime against women ')
plt.xlabel('crime type')
plt.ylabel('no. of cases')
