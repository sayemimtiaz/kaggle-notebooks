# %% [markdown]
# **Uses of EDA(Exploratory Data Analysis)** -
# Used filter the data from redundancies.
#
# Steps In EDA are following:
# 1. Understand the data
# 2. Clean the data
# 3. Analysis of relationship between varaibles

# %% [markdown]
# Import libraries which is mainly used in this

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# so we have to approach this data that's why am using pd libraries for import the dataset.

# %%
df=pd.read_csv(r'../input/videogamesales/vgsales.csv')

# %% [markdown]
# Yeah..file run successfully..Move forward to 1 step.

# %% [markdown]
# #1 Understanding the data

# %%
df.head()

# %% [markdown]
# If you want to check where your datasets are ended you have run thius command *data.tail()*
#
# so we have to check shape of dataset.. you will see in output like(rows,columns)

# %%
df.shape

# %% [markdown]
# If want separate columns

# %%
df.columns

# %% [markdown]
# for types of variables

# %%
df.info()

# %% [markdown]
# when we use describe method it's only showing int values not strings values.

# %%
df.describe()

# %% [markdown]
# for descriptive statistics of non-numeric variables

# %%
df.describe(include='object')

# %% [markdown]
# checking unique values present in data

# %%
df.nunique()

# %% [markdown]
# find unique value in specific data

# %%
df['Platform'].unique()

# %% [markdown]
# for distinct values for categorical variables

# %%
df['Platform'].value_counts()

# %% [markdown]
# for percentage of distinct values

# %%
df['Platform'].value_counts(normalize='True')
