# %% [markdown]
# ***Importing needed packages***

# %%
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np
import pylab as pl
from sklearn import preprocessing
# %matplotlib inline

# %% [markdown]
# ***Reading in the dataset***

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv("../input/human-resources-data-set/HRDataset_v14.csv")

# %% [markdown]
# ***Data Exploration***

# %%
df.head(10)

# %%
df["ManagerName"].value_counts()

# %%
plt.figure(figsize=(30,10))
plt.bar(df.ManagerName, df.PerfScoreID, color = "blue")
plt.xlabel("ManagerName")
plt.ylabel("PerfScoreID")
plt.show()

# %% [markdown]
# ***Identifying overall diversity profile of the company***

# %%
df["MaritalStatusID"].value_counts()

# %% [markdown]
# From above, we can see the marital status of the employees in the company - 137 single employees, 124 married employees,30 divorced employees, 12 separated employees, 8 widowed employees

# %%
df["GenderID"].value_counts()

# %% [markdown]
# Gender of employees - 176 female, 135 male

# %%
df["CitizenDesc"].value_counts()

# %% [markdown]
# Citizenship of employees - 215 US citizens, 12 eligible non-citizens, 4 non-citizens

# %%
df["RaceDesc"].value_counts()

# %% [markdown]
# Race of the employees - 187 white, 80 African American/ Black, 29 Asian, 11 bi racial or more, 3 American indian or Alaska native, 1 Hispanic

# %% [markdown]
# ***Identifying the best recruiting source for a diverse organization***

# %%
df["RecruitmentSource"].value_counts()

# %% [markdown]
# Using the groupby function to group the different recruitment sources

# %%
grouping = df.groupby("RecruitmentSource")

# %% [markdown]
# At this point, we keep interchanging the recruitment sources in the get_group() function, till we achieve our best recruiting source

# %%
RecSour = grouping.get_group("Indeed")
RecSour["RaceDesc"].value_counts()

# %% [markdown]
# Indeed is the best recruiting source for a diverse organization after interchanging recruiting sources.

# %% [markdown]
# ***Selecting features/inputs***

# %%
x = np.array([df["MaritalStatusID"], df["DeptID"], df["PerfScoreID"], df["Salary"], df["PositionID"], df["EmpSatisfaction"], df["Absences"]])
x

# %% [markdown]
# ***The label/ouput***

# %% [markdown]
# ***Note:*** Since the column, "Termd", which is our label column, is categorical, hence a classification task, we need to convert it to numerical information so the machine understands it. We use "label encoding" to carry this out. In this technique, each label is assigned a unique integer based on alphabetical ordering.

# %%
y = np.array(df["Termd"])
y

# %%
x.shape

# %%
y.shape

# %% [raw]
# From above, we can see that x and y aren't in the same shape, so we need to transpose x

# %%
x = x.transpose()

# %%
x.shape

# %%
y.shape

# %% [markdown]
# Now we can move on to modelling

# %% [markdown]
# ***Modelling***

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state= 4)

# %%
from sklearn.tree import DecisionTreeClassifier
classif = DecisionTreeClassifier().fit(x_train, y_train)
classif

# %%
y_hat = classif.predict(x_test)

# %% [markdown]
# ***Evaluation***

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_hat)

# %% [markdown]
# Always remember, accuracy of your model always depends on what you are working on. For certain tasks, accuracy tends to be higher and for certain other tasks could be lower, a lot factors come into consideration when evaluating a model so don't always think your model is not good enough till you look at a host of given factors.
