# %%
import pandas as pd
import numpy as np

# %% [markdown]
# It's a small csv file that contains lists of battles occuring in my second favorite show (first: Breaking Bad, of course!). Find the dataset on kaggle [here](http://www.kaggle.com/mylesoneill/game-of-thrones#battles.csv)

# %%
data = pd.read_csv("../input/battles.csv")

# %% [markdown]
# Let's start by knowing the dimensions of this data

# %%
data.shape

# %% [markdown]
# Glance through the data to catch null values.

# %%
data.head()

# %% [markdown]
# Ouch! A lot of null values indeed! Let's simply get rid of such data

# %% [markdown]
# Delete all the rows from dataset that has null values

# %%
data.dropna()

# %% [markdown]
# Hey, we just deleted all the rows that has missing values. So why 38 rows and 25 columns still?

# %%
data.shape

# %% [markdown]
# It is so because dropna is kind of aware of its power and is careful enough not to misuse them. Hence to make changes in the actual dataset you have to have to exclusively mention that you want to see the reflected changes.

# %%
data.dropna(inplace=True)

# %%
data.shape

# %% [markdown]
# Let's retrieve our dataset

# %%
data = pd.read_csv("../input/battles.csv")

# %% [markdown]
# If you want to delete only the rows that have "all" data points as null. see below

# %%
data.dropna(how='all')
data.shape

# %% [markdown]
# Same thing can be applied to a column too

# %%
data.dropna(how='all',axis=1)
data.shape

# %% [markdown]
# If you want to tidy only a single column of your datset.

# %%
data['attacker_2'].dropna()
